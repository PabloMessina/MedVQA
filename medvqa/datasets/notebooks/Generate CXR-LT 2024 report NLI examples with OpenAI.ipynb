# %%
# !python ../../scripts/mimiccxr/generate_cxrlt2024_report_nli_examples_with_openai.py \
--num_samples 20000 \
--split "train" \
--queries_to_skip_filepaths \
"/mnt/workspace/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-1106-preview_cxrlt2024_report_nli_queries_dev.jsonl" \
--chest_imagenome_image_id_to_labels_filepath \
"/mnt/data/pamessina/workspaces/medvqa-workspace/cache/chest_imagenome/imageId2labels(min_freq=0,num_labels=832).pkl" \
--chest_imagenome_label_names_filepath \
"/mnt/data/pamessina/workspaces/medvqa-workspace/cache/chest_imagenome/labels(min_freq=0,num_labels=832).pkl" \
--mimiccxr_background_findings_and_impression_per_report_filepath \
"/mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/background_findings_and_impression_20230612_174143.json" \
--max_requests_per_minute 9000 \
--max_tokens_per_minute 1500000 \
--max_tokens_per_request 200 \
--logging_level "INFO" \
--api_key_name "OPENAI_API_KEY_1" \
--openai_model_name "gpt-4-1106-preview" \
--use_batch_api \
--batch_description "cxrlt2024 label-driven report NLI"
# Out:
# 2024-07-22 16:02:37,515 - INFO - Loaded 99548 queries to skip from /mnt/workspace/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-1106-preview_cxrlt2024_report_nli_queries_dev.jsonl
# 2024-07-22 16:02:38,937 - INFO - Loaded 155823 allowed study IDs from the train set
# 2024-07-22 16:02:40,439 - INFO - Loading candidate study IDs per class from /mnt/workspace/pamessina/medvqa-workspace/cache/mimiccxr/cxrlt2024_candidate_study_ids_per_class.pkl
# 2024-07-22 16:02:40,585 - INFO - Sampling 20000 queries (379 positive, 66 negative) per class
# 2024-07-22 16:02:40,585 - INFO - Processing class: Adenopathy
# 2024-07-22 16:02:42,133 - INFO - Added 446 queries for class Adenopathy
# 2024-07-22 16:02:42,133 - INFO - Processing class: Atelectasis
# 2024-07-22 16:02:42,621 - INFO - Added 447 queries for class Atelectasis
# 2024-07-22 16:02:42,621 - INFO - Processing class: Azygos Lobe
# 2024-07-22 16:02:42,781 - WARNING - A deficit of 380 positive examples for class Azygos Lobe
# 2024-07-22 16:02:43,015 - INFO - Added 446 queries for class Azygos Lobe
# 2024-07-22 16:02:43,016 - INFO - Processing class: Calcification of the Aorta
# 2024-07-22 16:02:43,413 - INFO - Added 447 queries for class Calcification of the Aorta
# 2024-07-22 16:02:43,413 - INFO - Processing class: Cardiomegaly
# 2024-07-22 16:02:43,807 - INFO - Added 447 queries for class Cardiomegaly
# 2024-07-22 16:02:43,807 - INFO - Processing class: Clavicle Fracture
# 2024-07-22 16:02:45,076 - WARNING - A deficit of 381 positive examples for class Clavicle Fracture
# 2024-07-22 16:02:45,313 - INFO - Added 447 queries for class Clavicle Fracture
# 2024-07-22 16:02:45,313 - INFO - Processing class: Consolidation
# 2024-07-22 16:02:45,674 - INFO - Added 447 queries for class Consolidation
# 2024-07-22 16:02:45,674 - INFO - Processing class: Edema
# 2024-07-22 16:02:46,064 - INFO - Added 447 queries for class Edema
# 2024-07-22 16:02:46,064 - INFO - Processing class: Emphysema
# 2024-07-22 16:02:46,550 - INFO - Added 447 queries for class Emphysema
# 2024-07-22 16:02:46,550 - INFO - Processing class: Enlarged Cardiomediastinum
# 2024-07-22 16:02:46,983 - INFO - Added 447 queries for class Enlarged Cardiomediastinum
# 2024-07-22 16:02:46,983 - INFO - Processing class: Fibrosis
# 2024-07-22 16:02:48,947 - WARNING - A deficit of 380 positive examples for class Fibrosis
# 2024-07-22 16:02:49,171 - INFO - Added 446 queries for class Fibrosis
# 2024-07-22 16:02:49,171 - INFO - Processing class: Fissure
# 2024-07-22 16:02:52,227 - WARNING - A deficit of 380 positive examples for class Fissure
# 2024-07-22 16:02:52,449 - INFO - Added 446 queries for class Fissure
# 2024-07-22 16:02:52,449 - INFO - Processing class: Fracture
# 2024-07-22 16:02:52,806 - INFO - Added 447 queries for class Fracture
# 2024-07-22 16:02:52,806 - INFO - Processing class: Granuloma
# 2024-07-22 16:02:56,265 - WARNING - A deficit of 324 positive examples for class Granuloma
# 2024-07-22 16:02:56,550 - INFO - Added 447 queries for class Granuloma
# 2024-07-22 16:02:56,550 - INFO - Processing class: Hernia
# 2024-07-22 16:02:57,415 - INFO - Added 447 queries for class Hernia
# 2024-07-22 16:02:57,415 - INFO - Processing class: Hydropneumothorax
# 2024-07-22 16:02:58,240 - INFO - Added 447 queries for class Hydropneumothorax
# 2024-07-22 16:02:58,240 - INFO - Processing class: Infarction
# 2024-07-22 16:02:59,102 - WARNING - A deficit of 380 positive examples for class Infarction
# 2024-07-22 16:02:59,330 - INFO - Added 446 queries for class Infarction
# 2024-07-22 16:02:59,330 - INFO - Processing class: Infiltration
# 2024-07-22 16:02:59,685 - INFO - Added 447 queries for class Infiltration
# 2024-07-22 16:02:59,685 - INFO - Processing class: Kyphosis
# 2024-07-22 16:03:00,660 - WARNING - A deficit of 380 positive examples for class Kyphosis
# 2024-07-22 16:03:00,885 - INFO - Added 446 queries for class Kyphosis
# 2024-07-22 16:03:00,885 - INFO - Processing class: Lobar Atelectasis
# 2024-07-22 16:03:01,331 - INFO - Added 447 queries for class Lobar Atelectasis
# 2024-07-22 16:03:01,331 - INFO - Processing class: Lung Lesion
# 2024-07-22 16:03:01,691 - INFO - Added 447 queries for class Lung Lesion
# 2024-07-22 16:03:01,691 - INFO - Processing class: Lung Opacity
# 2024-07-22 16:03:02,217 - INFO - Added 447 queries for class Lung Opacity
# 2024-07-22 16:03:02,217 - INFO - Processing class: Mass
# 2024-07-22 16:03:02,583 - INFO - Added 447 queries for class Mass
# 2024-07-22 16:03:02,583 - INFO - Processing class: Nodule
# 2024-07-22 16:03:02,935 - INFO - Added 447 queries for class Nodule
# 2024-07-22 16:03:02,935 - INFO - Processing class: Normal
# 2024-07-22 16:03:03,192 - INFO - Added 446 queries for class Normal
# 2024-07-22 16:03:03,192 - INFO - Processing class: Pleural Effusion
# 2024-07-22 16:03:03,708 - INFO - Added 447 queries for class Pleural Effusion
# 2024-07-22 16:03:03,708 - INFO - Processing class: Pleural Other
# 2024-07-22 16:03:04,286 - INFO - Added 446 queries for class Pleural Other
# 2024-07-22 16:03:04,287 - INFO - Processing class: Pleural Thickening
# 2024-07-22 16:03:04,940 - INFO - Added 446 queries for class Pleural Thickening
# 2024-07-22 16:03:04,940 - INFO - Processing class: Pneumomediastinum
# 2024-07-22 16:03:05,813 - INFO - Added 447 queries for class Pneumomediastinum
# 2024-07-22 16:03:05,813 - INFO - Processing class: Pneumonia
# 2024-07-22 16:03:06,212 - INFO - Added 447 queries for class Pneumonia
# 2024-07-22 16:03:06,212 - INFO - Processing class: Pneumoperitoneum
# 2024-07-22 16:03:07,236 - WARNING - A deficit of 380 positive examples for class Pneumoperitoneum
# 2024-07-22 16:03:07,471 - INFO - Added 446 queries for class Pneumoperitoneum
# 2024-07-22 16:03:07,471 - INFO - Processing class: Pneumothorax
# 2024-07-22 16:03:07,892 - INFO - Added 447 queries for class Pneumothorax
# 2024-07-22 16:03:07,892 - INFO - Processing class: Pulmonary Embolism
# 2024-07-22 16:03:09,364 - WARNING - A deficit of 380 positive examples for class Pulmonary Embolism
# 2024-07-22 16:03:09,593 - INFO - Added 446 queries for class Pulmonary Embolism
# 2024-07-22 16:03:09,593 - INFO - Processing class: Pulmonary Hypertension
# 2024-07-22 16:03:10,702 - WARNING - A deficit of 380 positive examples for class Pulmonary Hypertension
# 2024-07-22 16:03:10,943 - INFO - Added 446 queries for class Pulmonary Hypertension
# 2024-07-22 16:03:10,943 - INFO - Processing class: Rib Fracture
# 2024-07-22 16:03:11,311 - INFO - Added 447 queries for class Rib Fracture
# 2024-07-22 16:03:11,312 - INFO - Processing class: Round(ed) Atelectasis
# 2024-07-22 16:03:11,481 - WARNING - A deficit of 380 positive examples for class Round(ed) Atelectasis
# 2024-07-22 16:03:11,713 - INFO - Added 446 queries for class Round(ed) Atelectasis
# 2024-07-22 16:03:11,713 - INFO - Processing class: Subcutaneous Emphysema
# 2024-07-22 16:03:12,725 - INFO - Added 447 queries for class Subcutaneous Emphysema
# 2024-07-22 16:03:12,725 - INFO - Processing class: Support Devices
# 2024-07-22 16:03:13,233 - INFO - Added 447 queries for class Support Devices
# 2024-07-22 16:03:13,233 - INFO - Processing class: Tortuous Aorta
# 2024-07-22 16:03:13,608 - INFO - Added 447 queries for class Tortuous Aorta
# 2024-07-22 16:03:13,608 - INFO - Processing class: Tuberculosis
# 2024-07-22 16:03:15,163 - WARNING - A deficit of 380 positive examples for class Tuberculosis
# 2024-07-22 16:03:15,386 - INFO - Added 446 queries for class Tuberculosis
# 2024-07-22 16:03:15,386 - INFO - Processing class: Bulla
# 2024-07-22 16:03:16,414 - WARNING - A deficit of 380 positive examples for class Bulla
# 2024-07-22 16:03:16,644 - INFO - Added 446 queries for class Bulla
# 2024-07-22 16:03:16,644 - INFO - Processing class: Cardiomyopathy
# 2024-07-22 16:03:17,306 - WARNING - A deficit of 379 positive examples for class Cardiomyopathy
# 2024-07-22 16:03:17,536 - INFO - Added 445 queries for class Cardiomyopathy
# 2024-07-22 16:03:17,536 - INFO - Processing class: Hilum
# 2024-07-22 16:03:17,869 - INFO - Added 446 queries for class Hilum
# 2024-07-22 16:03:17,869 - INFO - Processing class: Osteopenia
# 2024-07-22 16:03:18,231 - WARNING - A deficit of 379 positive examples for class Osteopenia
# 2024-07-22 16:03:18,458 - INFO - Added 445 queries for class Osteopenia
# 2024-07-22 16:03:18,458 - INFO - Processing class: Scoliosis
# 2024-07-22 16:03:18,869 - INFO - Added 446 queries for class Scoliosis
# 2024-07-22 16:03:18,996 - INFO - Total number of queries to process: 20094
# 2024-07-22 16:03:18,996 - INFO - Example queries to process:
# 2024-07-22 16:03:18,997 - INFO - 1. #R: indication: History: M with chest pain // acute process. Findings: Single frontal view of the chest. No focal consolidation is seen. There is no large pleural effusion or pneumothorax. The cardiac silhouette is top-normal. The aorta is slightly tortuous. There is slight prominence of the hila which may be due to pulmonary vascular engorgement without overt pulmonary edema ; cannot exclude right hilar lymphadenopathy. Dedicated PA and lateral views may be helpful for further evaluation. Impression: No focal consolidation, pleural effusion, or pulmonary edema. Mild prominence of the right hilum may relate to vascular engorgement however, underlying lymphadenopathy is not excluded. Dedicated PA and lateral views may be helpful for further evaluation. | #H: adenopathy seen
# 2024-07-22 16:03:18,997 - INFO - 5024. #R: indication: Fever. Findings: Lung volumes are low accentuating the cardiac silhouette and pulmonary vasculature. Left subclavian approach Port-A-Cath tip terminates in the high right atrium. Heart size is normal. Cardiomediastinal silhouette and hilar contours are unremarkable. Lungs are clear. Pleural surfaces are clear without effusion or pneumothorax. Impression: No obvious evidence of pneumonia, though lung volumes are low and a lateral view would be helpful for more complete evaluation. | #H: fissure seen
# 2024-07-22 16:03:18,997 - INFO - 10047. #R: reason for exam: Patient with history of lymphoma and sarcoidosis, status post bronchoscopy, assess for pneumothorax. Findings: Cardiac size is top normal. Mediastinal lymph nodes are better seen in prior CT. There is no pneumothorax or pleural effusion. Bilateral lung nodules including a conglomerate of nodules in the left lower lobe are better seen in prior CT. There is no evidence of new consolidation. Impression: No pneumothorax. | #H: mass seen
# 2024-07-22 16:03:18,997 - INFO - 15070. #R: indication: F with syncope // eval for pna. Findings: 6:54 PM No acute cardiopulmonary process. Minimal height loss of a mid thoracic vertebral body, age indeterminate and clinical correlation will be necessary. The lungs are clear. The cardiomediastinal silhouette is within normal limits. There is minimal height loss of a mid thoracic vertebral body, age indeterminate without priors. Osseous structures are otherwise unremarkable. Impression: No acute cardiopulmonary process. Minimal height loss of a mid thoracic vertebral body, age indeterminate and clinical correlation will be necessary. | #H: pulmonary hypertension seen
# 2024-07-22 16:03:18,997 - INFO - 20094. #R: history: Recurrent pseudomonas empyema, check tube placement. Findings: There is a dual-lumen central line on the right, with both lead tips over the right atrium. There is a right-sided PICC line, with tip over mid/lower SVC. No pneumothorax is detected. A pigtail-type catheter overlies the right lung base, now over the mid portion of the right hemidiaphragm. On the prior film, it was somewhat more medial in position. There is upper zone re-distribution and diffuse vascular blurring, consistent with CHF. The right hemidiaphragm is slightly elevated, with atelectasis at the right base. Possible trace bilateral effusions. Cardiomediastinal silhouette is unchanged. Impression: Right pigtail catheter present, lying slightly more lateral than on the prior film. CHF, right base atelectasis, and possible small bilateral effusions. No pneumothorax detected. | #H: scoliosis seen
# 2024-07-22 16:03:19,375 - INFO - Saving batch API requests to /home/pamessina/medvqa-workspace/tmp/mimiccxr/openai/batch_api_requests_20240722_160319.jsonl
# 2024-07-22 16:03:23,557 - INFO - HTTP Request: POST https://api.openai.com/v1/files "HTTP/1.1 200 OK"
# 2024-07-22 16:03:23,559 - INFO - Creating batch with input file ID file-AMYTkyc7ozp19yYhVFpyxi5T
# 2024-07-22 16:03:24,415 - INFO - HTTP Request: POST https://api.openai.com/v1/batches "HTTP/1.1 200 OK"
# 2024-07-22 16:03:24,422 - INFO - Batch object: Batch(id='batch_Y6GOz4QTeGBtb0gcf9MT3NLn', completion_window='24h', created_at=1721678604, endpoint='/v1/chat/completions', input_file_id='file-AMYTkyc7ozp19yYhVFpyxi5T', object='batch', status='validating', cancelled_at=None, cancelling_at=None, completed_at=None, error_file_id=None, errors=None, expired_at=None, expires_at=1721765004, failed_at=None, finalizing_at=None, in_progress_at=None, metadata={'description': 'cxrlt2024 label-driven report NLI'}, output_file_id=None, request_counts=BatchRequestCounts(completed=0, failed=0, total=0))
# 2024-07-22 16:03:24,422 - INFO - Saving batch object to /home/pamessina/medvqa-workspace/tmp/mimiccxr/openai/batch_api/file-AMYTkyc7ozp19yYhVFpyxi5T.pkl
# 2024-07-22 16:03:24,423 - INFO - Deleting batch API requests at /home/pamessina/medvqa-workspace/tmp/mimiccxr/openai/batch_api_requests_20240722_160319.jsonl

# %%
# !python ../../scripts/mimiccxr/generate_cxrlt2024_report_nli_examples_with_openai.py \
--batch_input_file_id "file-AMYTkyc7ozp19yYhVFpyxi5T" \
--split "dev" \
--logging_level "INFO" \
--openai_model_name "gpt-4-1106-preview" \
--api_key_name "OPENAI_API_KEY_1" \
--use_batch_api
# Out:
# 2024-07-22 17:09:04,670 - INFO - Checking status of batch with input file ID file-AMYTkyc7ozp19yYhVFpyxi5T
# 2024-07-22 17:09:04,974 - INFO - Batch object: Batch(id='batch_Y6GOz4QTeGBtb0gcf9MT3NLn', completion_window='24h', created_at=1721678604, endpoint='/v1/chat/completions', input_file_id='file-AMYTkyc7ozp19yYhVFpyxi5T', object='batch', status='validating', cancelled_at=None, cancelling_at=None, completed_at=None, error_file_id=None, errors=None, expired_at=None, expires_at=1721765004, failed_at=None, finalizing_at=None, in_progress_at=None, metadata={'description': 'cxrlt2024 label-driven report NLI'}, output_file_id=None, request_counts=BatchRequestCounts(completed=0, failed=0, total=0))
# 2024-07-22 17:09:05,384 - INFO - HTTP Request: GET https://api.openai.com/v1/batches/batch_Y6GOz4QTeGBtb0gcf9MT3NLn "HTTP/1.1 200 OK"
# 2024-07-22 17:09:05,392 - INFO - Batch: Batch(id='batch_Y6GOz4QTeGBtb0gcf9MT3NLn', completion_window='24h', created_at=1721678604, endpoint='/v1/chat/completions', input_file_id='file-AMYTkyc7ozp19yYhVFpyxi5T', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1721682462, error_file_id=None, errors=None, expired_at=None, expires_at=1721765004, failed_at=None, finalizing_at=1721681285, in_progress_at=1721678619, metadata={'description': 'cxrlt2024 label-driven report NLI'}, output_file_id='file-5N0uEzseGf81qAS2doCHDhR3', request_counts=BatchRequestCounts(completed=20094, failed=0, total=20094))
# 2024-07-22 17:09:05,392 - INFO - Batch status: completed
# 2024-07-22 17:09:05,392 - INFO - Batch with input file ID file-AMYTkyc7ozp19yYhVFpyxi5T is completed
# 2024-07-22 17:09:05,392 - INFO - Retrieving batch input file ID file-AMYTkyc7ozp19yYhVFpyxi5T
# 2024-07-22 17:09:06,261 - INFO - HTTP Request: GET https://api.openai.com/v1/files/file-AMYTkyc7ozp19yYhVFpyxi5T/content "HTTP/1.1 200 OK"
# 2024-07-22 17:09:07,564 - INFO - Retrieved metadata for 20094 queries
# 2024-07-22 17:09:07,564 - INFO - Retrieving batch output file ID file-5N0uEzseGf81qAS2doCHDhR3
# 2024-07-22 17:09:08,336 - INFO - HTTP Request: GET https://api.openai.com/v1/files/file-5N0uEzseGf81qAS2doCHDhR3/content "HTTP/1.1 200 OK"
# 2024-07-22 17:09:09,757 - INFO - Succesfully processed 20094 of 20094 API responses.
#                                     0 of 20094 API responses could not be processed.
#                                     Saving processed texts to /mnt/workspace/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-1106-preview_cxrlt2024_report_nli_queries_dev.jsonl

# %%
# !python ../../scripts/mimiccxr/generate_cxrlt2024_report_nli_examples_with_openai.py \
--integrate_nli_queries_for_fact_classification \
--queries_to_integrate_filepaths \
"/mnt/workspace/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-1106-preview_cxrlt2024_report_nli_queries_dev.jsonl" \
--fact_encoder_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240629_084405_MIMIC-CXR(triplets+classif+entcont+nli+radgraph+autoencoder)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)" \
--mimiccxr_background_findings_and_impression_per_report_filepath \
"/mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/background_findings_and_impression_20230612_174143.json"
# Out:
# 2024-07-22 17:11:11,971 - INFO - Loaded 119642 queries to integrate
# 2024-07-22 17:11:12,254 - INFO - Label distribution: Counter({'definitely true': 46312, 'unknown': 22967, 'likely false': 21566, 'definitely false': 20324, 'likely true': 8473})
# 2024-07-22 17:11:12,254 - INFO - Creating mapping from reports to binary labels
# 2024-07-22 17:11:12,976 - INFO - Loading CXR-LT 2024 train and dev study IDs
# 2024-07-22 17:11:14,524 - INFO - Loaded 155823 train study IDs and 23800 dev study IDs
# 2024-07-22 17:11:14,524 - INFO - Mapping dicom ids to labels
# 2024-07-22 17:11:16,363 - WARNING - Found 131 anomalous study IDs
# 2024-07-22 17:11:16,363 - WARNING - Example anomalous study IDs: [59721204, 54605567, 57868784, 59838466, 50377768]
# 2024-07-22 17:11:16,363 - INFO - len(output['train']) = 128427
# 2024-07-22 17:11:16,364 - INFO - len(output['dev']) = 13136
# 2024-07-22 17:11:16,364 - INFO - len(reports_that_matched) = 83913
# checkpoint_names = ['checkpoint_196_cacc+chf1+chf1+cscc+encc+hscc+nlcc+sass+spss+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9189.pt']
#   0%|                                                    | 0/45 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=441,505879158912416539).pkl
# len(self.cache["hashes"]) = 599219
# self.cache["embeddings"].shape = (599219, 128)
# 100%|███████████████████████████████████████████| 45/45 [00:00<00:00, 96.56it/s]
# 2024-07-22 17:11:17,379 - INFO - Computed class sentence embeddings
# 2024-07-22 17:11:17,479 - INFO - Saved integrated NLI queries for fact classification to /mnt/workspace/pamessina/medvqa-workspace/cache/mimiccxr/cxrlt2024_integrated_nli_queries_for_fact_classification.pkl

# %%
from importlib import reload
import  medvqa

# %%
reload(medvqa.scripts.mimiccxr.generate_cxrlt2024_report_nli_examples_with_openai)
# Out:
# <module 'medvqa.scripts.mimiccxr.generate_cxrlt2024_report_nli_examples_with_openai' from '/home/pamessina/medvqa/medvqa/scripts/mimiccxr/generate_cxrlt2024_report_nli_examples_with_openai.py'>

# %%
from medvqa.scripts.mimiccxr.generate_cxrlt2024_report_nli_examples_with_openai import eval_nli_queries_for_fact_classification

# %%
mistakes = eval_nli_queries_for_fact_classification('/mnt/workspace/pamessina/medvqa-workspace/cache/mimiccxr/cxrlt2024_integrated_nli_queries_for_fact_classification.pkl')
# Out:
# 13136 dicom ids not found in the train set
# Total mistakes: 38557

# %%
len(mistakes['Tuberculosis'])
# Out:
# 2006

# %%
mistakes['Tuberculosis'][0]
# Out:
# ('0ea12e1b-947002d1-ef34ad4b-50fc563d-52f8b072', 'fn')

# %%
aux = load_pickle('/mnt/workspace/pamessina/medvqa-workspace/cache/mimiccxr/cxrlt2024_integrated_nli_queries_for_fact_classification.pkl')

# %%
aux.keys()
# Out:
# dict_keys(['train', 'dev', 'class_sentences', 'class_sentence_embeddings'])

# %%
len(aux['train'])
# Out:
# 70458

# %%
for x in [9, 15, 16]:
    print(aux['class_sentences'][x])
# Out:
# enlarged cardiomediastinum seen
# hydropneumothorax seen
# infarction seen

# %%
from medvqa.datasets.mimiccxr import get_imageId2reportId
from medvqa.utils.files import load_pickle, save_pickle
from medvqa.datasets.mimiccxr import load_mimiccxr_reports_detailed_metadata
from medvqa.scripts.mimiccxr.generate_cxrlt2024_report_nli_examples_with_openai import _build_report

# %%
metadata = load_mimiccxr_reports_detailed_metadata(background_findings_and_impression_per_report_filepath="/mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/background_findings_and_impression_20230612_174143.json")

# %%
from medvqa.utils.files import load_jsonl

queries = load_jsonl('/mnt/workspace/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-1106-preview_cxrlt2024_report_nli_queries_dev.jsonl')

# %%
len(queries)
# Out:
# 119642

# %%
hilar_queries = []
for q in queries:
    if q['metadata']['query'].endswith('hilar abnormalities seen'):
        hilar_queries.append(q)
print(len(hilar_queries))
# Out:
# 2079

# %%
random.choice(hilar_queries)
# Out:
# {'metadata': {'query': '#R: indication: year old woman with STEMI, s/p PCI, now SOB // Eval for pna, pulm edema. Findings: Portable semi-erect chest radiograph. There has been interval removal of the single lead pacer. Continued enlargement of the cardiomediastinal silhouettes. Prominence of the bilateral hila. No frank pulmonary edema. No consolidation or pneumothorax seen. Left lower lobe atelectasis. Severe degenerative changes at the right glenohumeral joint. Impression: No significant interval change, except to note removal of the single lead pacer. | #H: hilar abnormalities seen'},
#  'parsed_response': {'reason': 'The report mentions "Prominence of the bilateral hila," which indicates an abnormality in that area.',
#   'label': 'definitely true'}}

# %%
queries[-10]
# Out:
# {'metadata': {'query': '#R: history: -year-old female with tracheostomy and desaturations. Findings: Single portable view of the chest. Extremely low lung volumes are seen. Patchy opacities seen in the lungs bilaterally, specifically in the right mid lung and at the bilateral bases which could be chronic. Tracheostomy tube is identified. Cardiomediastinal silhouette is within normal limits for technique and low inspiratory volumes. No acute osseous abnormality is detected. Mid thoracic dextroscoliosis is noted. Impression: Bilateral parenchymal opacities which could due to chronic underlying changes or atelectasis however superimposed acute infection or aspiration is also possible. | #H: scoliosis seen'},
#  'parsed_response': {'reason': 'The report mentions "Mid thoracic dextroscoliosis is noted," which directly confirms the presence of scoliosis.',
#   'label': 'definitely true'}}

# %%
import random
# class_name = 'Tuberculosis'
class_name = 'Emphysema'
fp_idxs = [i for i, x in enumerate(mistakes[class_name]) if x[1] == 'fp']
fn_idxs = [i for i, x in enumerate(mistakes[class_name]) if x[1] == 'fn']
print(len(fp_idxs), len(fn_idxs))
# Out:
# 989 44

# %%
# dicom_id = 'ce6924bb-208a9c54-bddbbee8-e393f892-d7077380'

idx = random.choice(fp_idxs)
# idx = random.choice(fn_idxs)
print(idx)
print()
dicom_id, error = mistakes[class_name][idx]
print(error)
print()

ridx = get_imageId2reportId()[dicom_id]
r = _build_report(metadata, ridx)
print(dicom_id)
print()
print(ridx)
print()
print(r)
print()
for q in queries:
    if q['metadata']['query'][4:].startswith(r):
        print(q)
        print()
# Out:
# 831
#
# fp
#
# fce80fc0-bd39af5b-393d2afd-3e01ac2a-363b5fec
#
# 174798
#
# clinical information: Fevers, HIV, malaise. Findings: Frontal and lateral views of the chest are obtained. The lungs are hyperinflated with flattening of the diaphragms, suggesting chronic obstructive pulmonary disease. There are areas of left mid-to-lower lung linear atelectasis/scarring. There is also mild interstitial edema. There is mild vascular congestion. No pleural effusion or pneumothorax is seen. Cardiac and mediastinal silhouettes are stable.
#
# {'metadata': {'query': '#R: clinical information: Fevers, HIV, malaise. Findings: Frontal and lateral views of the chest are obtained. The lungs are hyperinflated with flattening of the diaphragms, suggesting chronic obstructive pulmonary disease. There are areas of left mid-to-lower lung linear atelectasis/scarring. There is also mild interstitial edema. There is mild vascular congestion. No pleural effusion or pneumothorax is seen. Cardiac and mediastinal silhouettes are stable. | #H: emphysema seen'}, 'parsed_response': {'reason': 'The report describes the lungs as hyperinflated with flattening of the diaphragms, which are findings suggestive of chronic obstructive pulmonary disease (COPD). Emphysema is a type of COPD characterized by lung hyperinflation.', 'label': 'likely true'}}
#
# {'metadata': {'query': '#R: clinical information: Fevers, HIV, malaise. Findings: Frontal and lateral views of the chest are obtained. The lungs are hyperinflated with flattening of the diaphragms, suggesting chronic obstructive pulmonary disease. There are areas of left mid-to-lower lung linear atelectasis/scarring. There is also mild interstitial edema. There is mild vascular congestion. No pleural effusion or pneumothorax is seen. Cardiac and mediastinal silhouettes are stable. | #H: subcutaneous emphysema seen'}, 'parsed_response': {'reason': 'The report describes findings related to the lungs and mentions hyperinflation, atelectasis/scarring, interstitial edema, and vascular congestion, but does not mention the presence of air in the subcutaneous tissue, which would indicate subcutaneous emphysema.', 'label': 'definitely false'}}

# %%
reload(medvqa.scripts.mimiccxr.generate_cxrlt2024_report_nli_examples_with_openai)
# Out:
# <module 'medvqa.scripts.mimiccxr.generate_cxrlt2024_report_nli_examples_with_openai' from '/home/pamessina/medvqa/medvqa/scripts/mimiccxr/generate_cxrlt2024_report_nli_examples_with_openai.py'>

# %%
from medvqa.scripts.mimiccxr.generate_cxrlt2024_report_nli_examples_with_openai import generate_dataframe_for_manual_inspection

# %%
df = generate_dataframe_for_manual_inspection(
    cxrlt2024_integrated_nli_queries_for_fact_classification_filepath='/mnt/workspace/pamessina/medvqa-workspace/cache/mimiccxr/cxrlt2024_integrated_nli_queries_for_fact_classification.pkl',
    background_findings_and_impression_per_report_filepath='/mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/background_findings_and_impression_20230612_174143.json',
    processed_queries_filepath='/mnt/workspace/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-1106-preview_cxrlt2024_report_nli_queries_dev.jsonl',
)
# Out:
# 5594 dicom ids not found in the train set

# %%
df
# Out:
#     case         class  CXRLT2024_label  GPT-4_label  \
# 0     tp    Adenopathy                1            1
# 1     tp    Adenopathy                1            1
# 2     fp    Adenopathy                0            1
# 3     fp    Adenopathy                0            1
# 4     tn    Adenopathy                0            0
# ..   ...           ...              ...          ...
# 310   fp  Tuberculosis                0            1
# 311   tn  Tuberculosis                0            0
# 312   tn  Tuberculosis                0            0
# 313   fn  Tuberculosis                1            0
# 314   fn  Tuberculosis                1            0
#
#                                               filepath  part_id  subject_id  \
# 0    /mnt/data/mimic-cxr/files/p13/p13346039/s52626...       13    13346039
# 1    /mnt/data/mimic-cxr/files/p17/p17705092/s53217...       17    17705092
# 2    /mnt/data/mimic-cxr/files/p15/p15929369/s55678...       15    15929369
# 3    /mnt/data/mimic-cxr/files/p12/p12137322/s54407...       12    12137322
# 4    /mnt/data/mimic-cxr/files/p11/p11200955/s56691...       11    11200955
# ..                                                 ...      ...         ...
# 310  /mnt/data/mimic-cxr/files/p14/p14105780/s56278...       14    14105780
# 311  /mnt/data/mimic-cxr/files/p15/p15426182/s52070...       15    15426182
# 312  /mnt/data/mimic-cxr/files/p18/p18629400/s51440...       18    18629400
# 313  /mnt/data/mimic-cxr/files/p18/p18322831/s58710...       18    18322831
# 314  /mnt/data/mimic-cxr/files/p10/p10916587/s57266...       10    10916587
#
#      study_id                                    original_report  \
# 0    52626868                                   FINAL REPORT\...
# 1    53217502   WET READ: ___ ___ ___ 10:26 PM\n  Multifocal ...
# 2    55678690   WET READ: ___ ___ ___ 9:47 PM\n  IMPRESSION: ...
# 3    54407166                                   FINAL REPORT\...
# 4    56691216   WET READ: ___ ___ ___ 7:27 AM\n  \n  \n  \n  ...
# ..        ...                                                ...
# 310  56278888                                   FINAL REPORT\...
# 311  52070276                                   FINAL REPORT\...
# 312  51440418                                   FINAL REPORT\...
# 313  58710201                                   FINAL REPORT\...
# 314  57266726                                   FINAL REPORT\...
#
#                                          parsed_report  \
# 0    history: -year-old man status post thoracentes...
# 1    history: -year-old woman with a cough. Suspect...
# 2    history: "Not feeling well.". Findings: 9:47 P...
# 3    history: Axillary and cervical masses suggesti...
# 4    indication: year old man with prior apical lun...
# ..                                                 ...
# 310  indication: year old woman with cough x1 month...
# 311  indication: Status post extubation, evaluation...
# 312  indication: Chest pain. Findings: Heart size i...
# 313  indication: year old man with dialysis depende...
# 314  indication: History: F with cough and positive...
#
#                                            GPT-4_query  \
# 0    #R: history: -year-old man status post thorace...
# 1    #R: history: -year-old woman with a cough. Sus...
# 2    #R: history: "Not feeling well.". Findings: 9:...
# 3    #R: history: Axillary and cervical masses sugg...
# 4    #R: indication: year old man with prior apical...
# ..                                                 ...
# 310  #R: indication: year old woman with cough x1 m...
# 311  #R: indication: Status post extubation, evalua...
# 312  #R: indication: Chest pain. Findings: Heart si...
# 313  #R: indication: year old man with dialysis dep...
# 314  #R: indication: History: F with cough and posi...
#
#                                           GPT-4_reason      GPT-4_answer
# 0    The report mentions "hilar and mediastinal lym...   definitely true
# 1    The report mentions "symmetric central adenopa...   definitely true
# 2    The report mentions slight apparent density pr...       likely true
# 3    The report mentions axillary and cervical mass...   definitely true
# 4    The report mentions "No bulky lymphadenopathy,...  definitely false
# ..                                                 ...               ...
# 310  The report mentions "asymmetric opacification ...       likely true
# 311  The report mentions moderate pulmonary edema, ...      likely false
# 312  The report mentions findings consistent with e...      likely false
# 313  The report mentions the patient is being worke...           unknown
# 314  The report specifically states "no findings to...  definitely false
#
# [315 rows x 13 columns]

# %%
df.to_csv('/home/pamessina/tmp/GP4_vs_CXRLT2024labels_examples.csv')

# %%
from medvqa.utils.files import list_filepaths_with_prefix_and_timestamps

# %%
list_filepaths_with_prefix_and_timestamps('/home/pamessina/medvqa-workspace/tmp/mimiccxr/openai/batch_api/')[:5]
# Out:
# [('/home/pamessina/medvqa-workspace/tmp/mimiccxr/openai/batch_api/file-nCFra4wj88IXxzfy2jSZHpbG.pkl',
#   '2024-07-11 11:19:28'),
#  ('/home/pamessina/medvqa-workspace/tmp/mimiccxr/openai/batch_api/file-JNDkwuEL9ycEOjpYsYGr3536.pkl',
#   '2024-07-11 10:39:41'),
#  ('/home/pamessina/medvqa-workspace/tmp/mimiccxr/openai/batch_api/file-VvUAjxNrAdYCZMLy6EbXRMM3.pkl',
#   '2024-06-27 09:18:01'),
#  ('/home/pamessina/medvqa-workspace/tmp/mimiccxr/openai/batch_api/file-433RPIK1kg9AQPx97UPLp3qh.pkl',
#   '2024-06-27 04:01:59'),
#  ('/home/pamessina/medvqa-workspace/tmp/mimiccxr/openai/batch_api/file-HD33DD5WiV9eRSErBX86EC7F.pkl',
#   '2024-06-27 01:20:41')]

# %%
from collections import Counter

# %%
Counter(x['parsed_response']['label'] for x in queries)
# Out:
# Counter({'definitely true': 46312,
#          'likely true': 8473,
#          'definitely false': 20324,
#          'likely false': 21566,
#          'unknown': 22967})

# %%
# !ls -lh "/mnt/workspace/pamessina/medvqa-workspace/cache/mimiccxr/cxrlt2024_candidate_study_ids_per_class.pkl"
# Out:
# -rw-rw-r-- 1 pamessina socvis 13M Jul 10 16:40 /mnt/workspace/pamessina/medvqa-workspace/cache/mimiccxr/cxrlt2024_candidate_study_ids_per_class.pkl

# %%
from medvqa.utils.files import load_pickle, save_pickle
from medvqa.datasets.mimiccxr import load_mimiccxr_reports_detailed_metadata
from medvqa.scripts.mimiccxr.generate_cxrlt2024_report_nli_examples_with_openai import _build_report

# %%
tmp = load_pickle('/mnt/workspace/pamessina/medvqa-workspace/cache/mimiccxr/cxrlt2024_candidate_study_ids_per_class.pkl')

# %%
tmp.keys()
# Out:
# dict_keys(['Adenopathy', 'Atelectasis', 'Azygos Lobe', 'Calcification of the Aorta', 'Cardiomegaly', 'Clavicle Fracture', 'Consolidation', 'Edema', 'Emphysema', 'Enlarged Cardiomediastinum', 'Fibrosis', 'Fissure', 'Fracture', 'Granuloma', 'Hernia', 'Hydropneumothorax', 'Infarction', 'Infiltration', 'Kyphosis', 'Lobar Atelectasis', 'Lung Lesion', 'Lung Opacity', 'Mass', 'Nodule', 'Normal', 'Pleural Effusion', 'Pleural Other', 'Pleural Thickening', 'Pneumomediastinum', 'Pneumonia', 'Pneumoperitoneum', 'Pneumothorax', 'Pulmonary Embolism', 'Pulmonary Hypertension', 'Rib Fracture', 'Round(ed) Atelectasis', 'Subcutaneous Emphysema', 'Support Devices', 'Tortuous Aorta', 'Tuberculosis', 'Bulla', 'Cardiomyopathy', 'Hilum', 'Osteopenia', 'Scoliosis'])

# %%
tmp['Scoliosis'].keys()
# Out:
# dict_keys(['ChestImageNome', 'Regex'])

# %%
len(tmp['Scoliosis']['ChestImageNome'])
# Out:
# 8918

# %%
def show_report(study_id):
    idx = metadata['study_ids'].index(study_id)
    return _build_report(metadata, idx)

# %%
import random
# class_name = 'Scoliosis'
class_name = 'Hilum'
source_name = 'ChestImageNome'
# source_name = 'Regex'
# source_name = 'CXRLT2024'

for key, val in tmp[class_name].items():
    print (key, len(val))

study_id = random.choice(tmp[class_name][source_name])
show_report(study_id)
# Out:
# ChestImageNome 8423
# Regex 55915
# 'indication: year old woman with respiratory failure, CHF, AMS, intubated // Interval change Interval change. Findings: As compared to the previous image, no relevant change is seen. The endotracheal tube and the right internal jugular vein catheter are constant position. Moderate cardiomegaly. Unchanged mild enlargement of the right hilus. . Overall low lung volumes with mild fluid overload but no overt pulmonary edema. No evidence of pneumonia.'

# %%
import re
n_reports = len(metadata['backgrounds'])
reports = [_build_report(metadata, i) for i in range(n_reports)]
regex = re.compile(r'\beffusion', re.IGNORECASE)
study_ids = []
for study_id, report in zip(metadata['study_ids'], reports):
    if regex.search(report):
        study_ids.append(study_id)
assert len(study_ids) > 0

# %%
len(study_ids)
# Out:
# 179842

# %%
show_report(study_ids[5])
# Out:
# 'indication: Chest pain. Findings: The lungs are clear without consolidation or edema. There is no pleural effusion or pneumothorax. The lungs are hyperexpanded, consistent with COPD. The cardiomediastinal silhouette is normal. A chronic wedge compression fracture is noted in the mid thoracic spine, unchanged from prior exams. Impression: 1. No acute cardiopulmonary process. 2. Stable mid thoracic compression fracture.'

# %%
tmp['Pleural Effusion']['Regex'] = study_ids

# %%
save_pickle(tmp, '/mnt/workspace/pamessina/medvqa-workspace/cache/mimiccxr/cxrlt2024_candidate_study_ids_per_class.pkl')
