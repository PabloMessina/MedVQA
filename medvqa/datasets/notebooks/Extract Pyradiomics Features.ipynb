# %%
# !python ../../scripts/iuxray/extract_pyradiomics_features.py \
    --n-chunks 15 \
    --output-filename "pyradiomics_features.pkl"
# Out:
# ----------------------------------------------------
# Extracting pyradiomics features for IU X-Ray images
# ----------------------------------------------------
# Splitting 7470 images into 15 chunks
# #### starting process 0
# Command = python /home/pamessina/medvqa/medvqa/scripts/iuxray/extract_pyradiomic_features.py --chunk-mode --chunk-id 0 --input-path /mnt/workspace/iu-x-ray/dataset-pamessina/__tmp/chunk_0_input.csv --output-path /mnt/workspace/iu-x-ray/dataset-pamessina/__tmp/chunk_0_output.pkl
# #### starting process 1
# Command = python /home/pamessina/medvqa/medvqa/scripts/iuxray/extract_pyradiomic_features.py --chunk-mode --chunk-id 1 --input-path /mnt/workspace/iu-x-ray/dataset-pamessina/__tmp/chunk_1_input.csv --output-path /mnt/workspace/iu-x-ray/dataset-pamessina/__tmp/chunk_1_output.pkl
# #### starting process 2
# ...

# %%
# !python ../../scripts/mimiccxr/extract_pyradiomics_features.py \
    --n-chunks 16 \
    --output-filename "pyradiomics_features.pkl"
# Out:
# -----------------------------------------------------
# Extracting pyradiomics features for MIMIC-CXR images
# -----------------------------------------------------
# Splitting 377110 images into 16 chunks
# #### starting process 0
# Command = python /home/pamessina/medvqa/medvqa/scripts/mimiccxr/extract_pyradiomics_features.py --chunk-mode --chunk-id 0 --input-path /mnt/workspace/mimic-cxr-jpg/dataset-pamessina/__tmp/chunk_0_input.csv --output-path /mnt/workspace/mimic-cxr-jpg/dataset-pamessina/__tmp/chunk_0_output.pkl
# #### starting process 1
# Command = python /home/pamessina/medvqa/medvqa/scripts/mimiccxr/extract_pyradiomics_features.py --chunk-mode --chunk-id 1 --input-path /mnt/workspace/mimic-cxr-jpg/dataset-pamessina/__tmp/chunk_1_input.csv --output-path /mnt/workspace/mimic-cxr-jpg/dataset-pamessina/__tmp/chunk_1_output.pkl
# #### starting process 2
# ...

# %%
# !python ../../scripts/chexpert/extract_pyradiomics_features.py \
    --n-chunks 16 \
    --output-filename "pyradiomics_features.pkl"
# Out:
# ----------------------------------------------------
# Extracting pyradiomics features for CheXpert images
# ----------------------------------------------------
# Splitting 223648 images into 16 chunks
# #### starting process 0
# Command = python /home/pamessina/medvqa/medvqa/scripts/chexpert/extract_pyradiomics_features.py --chunk-mode --chunk-id 0 --input-path /mnt/workspace/chexpert/dataset-pamessina/__tmp/chunk_0_input.csv --output-path /mnt/workspace/chexpert/dataset-pamessina/__tmp/chunk_0_output.pkl
# #### starting process 1
# Command = python /home/pamessina/medvqa/medvqa/scripts/chexpert/extract_pyradiomics_features.py --chunk-mode --chunk-id 1 --input-path /mnt/workspace/chexpert/dataset-pamessina/__tmp/chunk_1_input.csv --output-path /mnt/workspace/chexpert/dataset-pamessina/__tmp/chunk_1_output.pkl
# #### starting process 2
# ...

# %%
# !ls -lh /mnt/workspace/chexpert/dataset-pamessina/pyradiomics_features.pkl
# Out:
# -rw-rw-r-- 1 pamessina socvis 1.3G Jul 22 10:50 /mnt/workspace/chexpert/dataset-pamessina/pyradiomics_features.pkl

# %%
# !ls -lh /mnt/workspace/mimic-cxr-jpg/dataset-pamessina/pyradiomics_features.pkl
# Out:
# -rw-rw-r-- 1 pamessina mimic-cxr 2.2G Jul 21 21:38 /mnt/workspace/mimic-cxr-jpg/dataset-pamessina/pyradiomics_features.pkl

# %%
# !ls -lh /mnt/workspace/iu-x-ray/dataset-pamessina/pyradiomics_features.pkl
# Out:
# -rw-rw-r-- 1 pamessina socvis 44M Jul 20 23:14 /mnt/workspace/iu-x-ray/dataset-pamessina/pyradiomics_features.pkl

# %%
tmp = load_pickle('/mnt/workspace/chexpert/dataset-pamessina/pyradiomics_features.pkl')

# %%
tmp['features'].shape
# Out:
# (223648, 753)
