# %%
import json
import re
from tqdm import tqdm
from random import randint
from nltk.tokenize import wordpunct_tokenize

# %%
with open('/mnt/workspace/iu-x-ray/dataset/reports/qa_adapted_reports.json', 'r') as f:
    vqa_dataset_iuxray = json.load(f)

# %%
with open('/mnt/data/mimic-cxr/qa_adapted_reports.json', 'r') as f:
    vqa_dataset_mimiccxr = json.load(f)

# %%
def get_sentences():
    for report in vqa_dataset_iuxray['reports']:
        for idx in report['matched']:
            yield report['sentences'][idx].lower()
        for idx in report['unmatched']:
            yield report['sentences'][idx].lower()
    for report in vqa_dataset_mimiccxr['reports']:
        for idx in report['matched']:
            yield report['sentences'][idx].lower()
        for idx in report['unmatched']:
            yield report['sentences'][idx].lower()

# %%
unknown_regex = re.compile(r'^(\d+(cm|mm|st|th|nd|rd)?|xxxx|jj|[().\-\\/+#*=><%?;!].*|[:,].+)$')

# %%
vocab = dict()
for sentence in tqdm(get_sentences()):
    tokens = wordpunct_tokenize(sentence)
    for token in tokens:
        if unknown_regex.search(token):
            continue
        vocab[token] = vocab.get(token, 0) + 1
# Out:
# 1149350it [00:07, 148502.68it/s]

# %%
filtered_vocab = [word for word, freq in vocab.items() if freq >= 4]

# %%
filtered_vocab.sort()

# %%
len(filtered_vocab)
# Out:
# 5183

# %%
filtered_vocab[:1000]
# Out:
# ['"',
#  "'",
#  ',',
#  ':',
#  'a',
#  'aa',
#  'aaa',
#  'abandoned',
#  'abdomen',
#  'abdominal',
#  'aberrant',
#  'ability',
#  'ablation',
#  'able',
#  'abnormal',
#  'abnormalities',
#  'abnormality',
#  'abnormally',
#  'about',
#  'above',
#  'abpa',
#  'abrupt',
#  'abruptly',
#  'abscess',
#  'abscesses',
#  'absence',
#  'absent',
#  'absolute',
#  'abundant',
#  'abuse',
#  'abut',
#  'abuts',
#  'abutting',
#  'ac',
#  'accelerated',
#  'accentuate',
#  'accentuated',
#  'accentuates',
#  'accentuating',
#  'accentuation',
#  'acceptable',
#  'access',
#  'accessed',
#  'accessible',
#  'accessory',
#  'accident',
#  'accompanied',
#  'accompanies',
#  'accompany',
#  'accompanying',
#  'accomplished',
#  'according',
#  'accordingly',
#  'account',
#  'accounted',
#  'accounting',
#  'accounts',
#  'accumulate',
#  'accumulated',
#  'accumulating',
#  'accumulation',
#  'accumulations',
#  'accurate',
#  'accurately',
#  'acdf',
#  'acentuated',
#  'achalasia',
#  'achieve',
#  'achieved',
#  'acid',
#  'acknowledged',
#  'acromial',
#  'acromio',
#  'acromioclavicular',
#  'acromiohumeral',
#  'acromion',
#  'across',
#  'action',
#  'active',
#  'activity',
#  'actual',
#  'actually',
#  'acuity',
#  'acute',
#  'acutely',
#  'add',
#  'added',
#  'addendum',
#  'addition',
#  'additional',
#  'additionally',
#  'addressed',
#  'adenocarcinoma',
#  'adenopathy',
#  'adequate',
#  'adequately',
#  'adhesion',
#  'adhesions',
#  'adipose',
#  'adiposity',
#  'adjacent',
#  'adjoining',
#  'adjusted',
#  'adjusting',
#  'adjustment',
#  'administered',
#  'administration',
#  'admission',
#  'admitted',
#  'advance',
#  'advanced',
#  'advancement',
#  'advancing',
#  'advantage',
#  'advisable',
#  'advised',
#  'adynamic',
#  'aerated',
#  'aeration',
#  'affect',
#  'affected',
#  'affecting',
#  'affects',
#  'afib',
#  'aforementioned',
#  'after',
#  'again',
#  'against',
#  'age',
#  'agent',
#  'aggravated',
#  'aggressive',
#  'ago',
#  'aicd',
#  'aid',
#  'aids',
#  'air',
#  'airless',
#  'airlessness',
#  'airspace',
#  'airtrapping',
#  'airway',
#  'airways',
#  'al',
#  'albeit',
#  'alcohol',
#  'alcoholic',
#  'align',
#  'aligned',
#  'alignment',
#  'aligns',
#  'alimentary',
#  'all',
#  'allergic',
#  'alleviated',
#  'allow',
#  'allowances',
#  'allowing',
#  'almost',
#  'alone',
#  'along',
#  'alongside',
#  'alpha',
#  'already',
#  'also',
#  'alteration',
#  'alterations',
#  'altered',
#  'alternative',
#  'alternatively',
#  'alternatives',
#  'alters',
#  'although',
#  'altogether',
#  'alveolar',
#  'alveolitis',
#  'always',
#  'am',
#  'amelioration',
#  'amenable',
#  'amiodarone',
#  'aml',
#  'among',
#  'amorphous',
#  'amount',
#  'amounts',
#  'amplatz',
#  'ample',
#  'amputation',
#  'an',
#  'anasarca',
#  'anastomosis',
#  'anastomotic',
#  'anatomic',
#  'anatomical',
#  'anatomically',
#  'anatomy',
#  'anchor',
#  'anchors',
#  'ancillary',
#  'and',
#  'anemia',
#  'aneurysm',
#  'aneurysmal',
#  'aneurysmally',
#  'aneurysmatic',
#  'angle',
#  'angled',
#  'angles',
#  'angular',
#  'angulated',
#  'angulation',
#  'ankle',
#  'annular',
#  'annuloplasty',
#  'annulus',
#  'anomalies',
#  'anomalous',
#  'anomaly',
#  'anorexia',
#  'another',
#  'anterior',
#  'anteriorly',
#  'antero',
#  'anterolateral',
#  'anterolisthesis',
#  'anteromedial',
#  'anteroposterior',
#  'antibiotic',
#  'antibiotics',
#  'anticipated',
#  'antitrypsin',
#  'antral',
#  'antrum',
#  'anulus',
#  'any',
#  'anymore',
#  'anything',
#  'anywhere',
#  'aorta',
#  'aortic',
#  'aorticopulmonary',
#  'aorto',
#  'aortopulmonary',
#  'aortopulmonic',
#  'aortosclerosis',
#  'ap',
#  'apart',
#  'apex',
#  'apical',
#  'apically',
#  'apices',
#  'apicolateral',
#  'apparatus',
#  'apparent',
#  'apparently',
#  'appear',
#  'appearance',
#  'appearances',
#  'appeared',
#  'appearence',
#  'appearing',
#  'appears',
#  'appendage',
#  'apperance',
#  'appliances',
#  'appreciable',
#  'appreciably',
#  'appreciate',
#  'appreciated',
#  'approach',
#  'approached',
#  'approaches',
#  'approaching',
#  'appropriate',
#  'appropriately',
#  'approved',
#  'approximate',
#  'approximately',
#  'approximates',
#  'approximating',
#  'approximatively',
#  'arc',
#  'arch',
#  'arches',
#  'architectural',
#  'architecture',
#  'ards',
#  'are',
#  'area',
#  'areas',
#  'argue',
#  'argues',
#  'arguing',
#  'arise',
#  'arising',
#  'arm',
#  'arms',
#  'around',
#  'arrest',
#  'arterial',
#  'arteries',
#  'arteriosum',
#  'artery',
#  'arthritic',
#  'arthritis',
#  'arthropathy',
#  'arthroplasties',
#  'arthroplasty',
#  'articular',
#  'articulation',
#  'artifact',
#  'artifacts',
#  'artifactual',
#  'artificial',
#  'artificially',
#  'as',
#  'asbestos',
#  'asbestosis',
#  'ascending',
#  'ascends',
#  'ascertain',
#  'ascertained',
#  'ascites',
#  'ascribe',
#  'ascribed',
#  'asd',
#  'aside',
#  'aspect',
#  'aspects',
#  'aspergilloma',
#  'aspergillosis',
#  'aspergillus',
#  'aspirate',
#  'aspirated',
#  'aspiration',
#  'aspirations',
#  'assess',
#  'assessable',
#  'assessed',
#  'assessing',
#  'assessment',
#  'assist',
#  'assisting',
#  'associated',
#  'association',
#  'assume',
#  'assumed',
#  'assumes',
#  'assuming',
#  'assumption',
#  'assymetric',
#  'assymetry',
#  'asthma',
#  'asymmetric',
#  'asymmetrical',
#  'asymmetrically',
#  'asymmetry',
#  'asymptomatic',
#  'at',
#  'atalectasis',
#  'atelctasis',
#  'atelecasis',
#  'atelecatsis',
#  'atelectais',
#  'atelectases',
#  'atelectasis',
#  'atelectatic',
#  'ateletasis',
#  'atherosclerosis',
#  'atherosclerotic',
#  'atlectasis',
#  'atresia',
#  'atria',
#  'atrial',
#  'atrio',
#  'atriobiventricular',
#  'atriocaval',
#  'atrioventricular',
#  'atrium',
#  'attached',
#  'attempt',
#  'attempted',
#  'attempts',
#  'attendant',
#  'attending',
#  'attention',
#  'attenuated',
#  'attenuation',
#  'attest',
#  'attests',
#  'attributable',
#  'attribute',
#  'attributed',
#  'atypical',
#  'augmentation',
#  'augmented',
#  'av',
#  'available',
#  'avascular',
#  'avid',
#  'avm',
#  'avoid',
#  'avr',
#  'avulsion',
#  'aware',
#  'away',
#  'axial',
#  'axilla',
#  'axillae',
#  'axillary',
#  'axis',
#  'azygos',
#  'azygous',
#  'b',
#  'back',
#  'background',
#  'backwards',
#  'bacteremia',
#  'bacterial',
#  'bal',
#  'balance',
#  'balanced',
#  'balloon',
#  'band',
#  'banding',
#  'bandlike',
#  'bands',
#  'barely',
#  'barium',
#  'barotrauma',
#  'barrel',
#  'basal',
#  'basalar',
#  'basally',
#  'base',
#  'based',
#  'baseline',
#  'bases',
#  'basilar',
#  'basilic',
#  'basis',
#  'basolateral',
#  'bat',
#  'battery',
#  'batwing',
#  'bb',
#  'bbs',
#  'be',
#  'bears',
#  'because',
#  'become',
#  'becomes',
#  'becoming',
#  'bed',
#  'bedside',
#  'been',
#  'before',
#  'beginning',
#  'begun',
#  'behind',
#  'being',
#  'believe',
#  'believed',
#  'belongs',
#  'below',
#  'bend',
#  'beneath',
#  'beneficial',
#  'benefit',
#  'benign',
#  'bent',
#  'besides',
#  'best',
#  'better',
#  'between',
#  'beyond',
#  'bi',
#  'biapical',
#  'biatrial',
#  'bibasal',
#  'bibasalar',
#  'bibasilar',
#  'bicameral',
#  'biconcave',
#  'bielectrode',
#  'bifid',
#  'bifurcation',
#  'bifurcations',
#  'big',
#  'bigger',
#  'bihilar',
#  'bilateral',
#  'bilaterality',
#  'bilaterally',
#  'bile',
#  'bileaflet',
#  'biliary',
#  'bilobed',
#  'binder',
#  'biopsied',
#  'biopsies',
#  'biopsy',
#  'bipolar',
#  'bit',
#  'biv',
#  'biventricular',
#  'bladder',
#  'blanket',
#  'blastic',
#  'bleb',
#  'blebectomy',
#  'blebs',
#  'bleed',
#  'bleeding',
#  'block',
#  'blood',
#  'blossoming',
#  'blunt',
#  'blunted',
#  'blunting',
#  'blunts',
#  'blurred',
#  'blurring',
#  'board',
#  'bochdalek',
#  'bodies',
#  'body',
#  'bold',
#  'bolus',
#  'bone',
#  'bones',
#  'bony',
#  'border',
#  'bordering',
#  'borderline',
#  'borders',
#  'bore',
#  'both',
#  'bottle',
#  'bottom',
#  'bowel',
#  'bowing',
#  'bracheocephalic',
#  'brachial',
#  'brachiocephalic',
#  'brachycephalic',
#  'brachytherapy',
#  'bradycardia',
#  'brain',
#  'branch',
#  'branches',
#  'branching',
#  'break',
#  'breakage',
#  'breaks',
#  'breast',
#  'breasts',
#  'breath',
#  'breathing',
#  'bridge',
#  'bridging',
#  'broad',
#  'broken',
#  'bronchi',
#  'bronchial',
#  'bronchiectasis',
#  'bronchiectatic',
#  'bronchiolar',
#  'bronchiolitis',
#  'bronchioloalveolar',
#  'bronchitis',
#  'broncho',
#  'bronchoalveolar',
#  'bronchocentric',
#  'bronchogenic',
#  'bronchogram',
#  'bronchograms',
#  'bronchopleural',
#  'bronchopneumonia',
#  'bronchopneumonic',
#  'bronchopulmonary',
#  'bronchoscopic',
#  'bronchoscopy',
#  'bronchospasm',
#  'bronchovascular',
#  'bronchovasculature',
#  'bronchus',
#  'brought',
#  'brushing',
#  'bubble',
#  'bubbles',
#  'buckshot',
#  'bulb',
#  'bulbous',
#  'bulge',
#  'bulges',
#  'bulging',
#  'bulk',
#  'bulky',
#  'bulla',
#  'bullae',
#  'bullectomy',
#  'bullet',
#  'bullous',
#  'bundles',
#  'burden',
#  'bursitis',
#  'burst',
#  'but',
#  'button',
#  'by',
#  'bypass',
#  'c',
#  'c3',
#  'c4',
#  'c5',
#  'c6',
#  'c7',
#  'ca',
#  'cabg',
#  'cable',
#  'cables',
#  'cachexia',
#  'cage',
#  'calcific',
#  'calcification',
#  'calcifications',
#  'calcified',
#  'calcium',
#  'calculus',
#  'caliber',
#  'call',
#  'called',
#  'callous',
#  'callus',
#  'can',
#  'canal',
#  'cancer',
#  'candidate',
#  'cannot',
#  'cannula',
#  'cannulate',
#  'cannulates',
#  'cannulating',
#  'cannulation',
#  'canted',
#  'canula',
#  'cap',
#  'capable',
#  'capacity',
#  'capping',
#  'caps',
#  'capsulated',
#  'capsule',
#  'captured',
#  'carcinoid',
#  'carcinoma',
#  'carcinomatosis',
#  'cardia',
#  'cardiac',
#  'cardial',
#  'cardio',
#  'cardioesophageal',
#  'cardiogenic',
#  'cardiomediastinal',
#  'cardiomediastinum',
#  'cardiomegally',
#  'cardiomegaly',
#  'cardiomyopathy',
#  'cardiopericardial',
#  'cardiophrenic',
#  'cardiopulmoanry',
#  'cardiopulmonary',
#  'cardiothoracic',
#  'cardiovascular',
#  'cardipulmonary',
#  'care',
#  'careful',
#  'carefully',
#  'carina',
#  'carinal',
#  'carinatum',
#  'caring',
#  'carotid',
#  'carotids',
#  'carries',
#  'cart',
#  'cartilage',
#  'cartilages',
#  'cartilaginous',
#  'case',
#  'cases',
#  'cath',
#  'catheter',
#  'catheterization',
#  'catheters',
#  'cathter',
#  'caudal',
#  'cause',
#  'caused',
#  'causes',
#  'causing',
#  'cava',
#  'caval',
#  'cavitary',
#  'cavitated',
#  'cavitating',
#  'cavitation',
#  'cavitations',
#  'cavities',
#  'cavity',
#  'cavo',
#  'cavoatrial',
#  'cbd',
#  'cc',
#  'cd4',
#  'cell',
#  'cells',
#  'cellulitis',
#  'cement',
#  'center',
#  'centered',
#  'centimeter',
#  'centimeters',
#  'central',
#  'centralized',
#  'centrally',
#  'centrilobular',
#  'cephalad',
#  'cephalic',
#  'cephalization',
#  'cephalized',
#  'cerclage',
#  'cerebral',
#  'certain',
#  'certainly',
#  'certainty',
#  'cervical',
#  'cervicothoracic',
#  'chain',
#  'chains',
#  'challenging',
#  'chamber',
#  'chambers',
#  'change',
#  'changed',
#  'changes',
#  'changing',
#  'channel',
#  'character',
#  'characteristic',
#  'characteristics',
#  'characterization',
#  'characterize',
#  'characterized',
#  'check',
#  'checked',
#  'chemo',
#  'chemoembolization',
#  'chemotherapy',
#  'chest',
#  'chf',
#  'chiladiti',
#  'chilaiditi',
#  'childhood',
#  'chills',
#  'chin',
#  'choice',
#  'cholangiocarcinoma',
#  'cholecystectomy',
#  'cholecystostomy',
#  'cholelithiasis',
#  'chondral',
#  'chondrocalcinosis',
#  'chondroid',
#  'chronic',
#  'chronically',
#  'chronicity',
#  'churg',
#  'chylothorax',
#  'cicatricial',
#  'cigarette',
#  'circuitous',
#  'circular',
#  'circulating',
#  'circulation',
#  'circumference',
#  'circumferential',
#  'circumflex',
#  'circumscribed',
#  'circumstance',
#  'circumstances',
#  'cirrhosis',
#  'clamped',
#  'clamping',
#  'clarification',
#  'clarified',
#  'clarify',
#  'clavicle',
#  'clavicles',
#  'clavicular',
#  'clear',
#  'clearance',
#  'cleared',
#  'clearing',
#  'clearly',
#  'clears',
#  'climb',
#  'clincal',
#  'clinical',
#  'clinically',
#  'clinician',
#  'clip',
#  'clips',
#  'cll',
#  'close',
#  'closely',
#  'closer',
#  'closure',
#  'clot',
#  'clothing',
#  'cluster',
#  'clustered',
#  'cm',
#  'co',
#  'coalesced',
#  'coalescence',
#  'coalescent',
#  'coalescing',
#  'coalition',
#  'coarse',
#  'coarsened',
#  'coarseness',
#  'coarsening',
#  'cocaine',
#  'coexistent',
#  'coexisting',
#  'coil',
#  'coiled',
#  'coiling',
#  'coils',
#  'coincide',
#  'coincides',
#  'coinciding',
#  'cold',
#  'colectomy',
#  'colitis',
#  'collapse',
#  'collapsed',
#  'collapsing',
#  'collar',
#  'collected',
#  'collecting',
#  'collection',
#  'collections',
#  'collpase',
#  'colon',
#  'colonic',
#  'colonoscopy',
#  'column',
#  'combination',
#  'combinations',
#  'combine',
#  'combined',
#  'combines',
#  'come',
#  'coming',
#  'comment',
#  'comments',
#  'comminuted',
#  'common',
#  'commonly',
#  'communicated',
#  'communication',
#  'compact',
#  'companion',
#  'company',
#  'comparable',
#  'comparably',
#  'comparative',
#  'compare',
#  'compared',
#  'compares',
#  'comparing',
#  'comparison',
#  'comparisons',
#  'compartment',
#  'compartments',
#  'compatible',
#  'compelling',
#  'compensation',
#  'compensatorily',
#  'compensatory',
#  'complete',
#  'completely',
#  'complex',
#  'complicated',
#  'complicates',
#  'complicating',
#  'complication',
#  'complications',
#  'component',
#  'components',
#  'composite',
#  'compressed',
#  'compressing',
#  'compression',
#  'compressions',
#  'compressive',
#  'compromise',
#  'compromised',
#  'compromising',
#  'con',
#  'concave',
#  'concavity',
#  'conceal',
#  'concealed',
#  'conceivable',
#  'conceivably',
#  'concentrated',
#  'concern',
#  'concerned',
#  'concerning',
#  'concerns',
#  'concluded',
#  'conclusion',
#  'conclusive',
#  'conclusively',
#  'concomitant',
#  'concurrent',
#  'concurrently',
#  'condition',
#  'conditions',
#  'conduction',
#  'conduit',
#  'confidently',
#  'configuration',
#  'configurational',
#  'confined',
#  'confines',
#  'confirm',
#  'confirmation',
#  'confirmed',
#  'confirming',
#  'confirms',
#  'confluence',
#  'confluent',
#  'confluenting',
#  'conform',
#  'conforms',
#  'confounded',
#  'confounding',
#  'confused',
#  'confusing',
#  'confusion',
#  'congenital',
#  'congesion',
#  'congested',
#  'congestion',
#  'congestions',
#  'congestive',
#  'conglomerate',
#  'conglomeration',
#  'conjunction',
#  'connected',
#  'connection',
#  'connections',
#  'consecutive',
#  'consequence',
#  'consequent',
#  'consequently',
#  'consider',
#  'considerable',
#  'considerably',
#  'consideration',
#  'considerations',
#  'considered',
#  'considering',
#  'consist',
#  'consistency',
#  'consistent',
#  'consistently',
#  'consisting',
#  'consists',
#  'conslidation',
#  'consolidaiton',
#  'consolidate',
#  'consolidated',
#  'consolidating',
#  'consolidation',
#  'consolidations',
#  'consolidative',
#  'conspicious',
#  'conspicuity',
#  'conspicuous',
#  'constant',
#  'constellation',
#  'constitute',
#  'constrictive']

# %%
len(filtered_vocab)
# Out:
# 5219

# %%
vocab['<unknown>']
# Out:
# 30975

# %%
filtered_vocab[:1000]
# Out:
# [(1152929, '.'),
#  (583778, 'the'),
#  (455235, 'is'),
#  (332737, 'no'),
#  (248441, ','),
#  (244565, 'are'),
#  (237329, 'of'),
#  (205917, 'and'),
#  (184234, 'right'),
#  (182524, 'pleural'),
#  (178767, 'there'),
#  (162589, 'in'),
#  (149624, 'effusion'),
#  (146540, 'left'),
#  (145986, 'pneumothorax'),
#  (133122, 'or'),
#  (117990, 'normal'),
#  (105757, 'pulmonary'),
#  (100152, 'lung'),
#  (90580, 'with'),
#  (83697, 'a'),
#  (79888, 'acute'),
#  (75729, 'atelectasis'),
#  (72672, 'unchanged'),
#  (70553, 'lungs'),
#  (69876, 'seen'),
#  (69382, 'edema'),
#  (67449, 'consolidation'),
#  (66971, '-'),
#  (66566, 'size'),
#  (64800, 'clear'),
#  (63207, 'heart'),
#  (63178, 'to'),
#  (61557, 'silhouette'),
#  (1869, 'exam'),
#  (1851, 'inflated'),
#  (1836, 'current'),
#  (1819, 'only'),
#  (1818, 'parenchyma'),
#  (1817, 'medial'),
#  (1803, 'scoliosis'),
#  (1802, 'advanced'),
#  (1797, 'fully'),
#  (1790, 'significantly'),
#  (1785, 'cervical'),
#  (1780, 'apparent'),
#  (1777, 'appreciated'),
#  (1772, 'infiltrates'),
#  (1764, 'angles'),
#  (1755, 'defined'),
#  (1731, 'single'),
#  (1723, 'severity'),
#  (1721, 'mm'),
#  (1715, 'either'),
#  (1702, 'marked'),
#  (1692, 'pneumomediastinum'),
#  (1681, 'throughout'),
#  (1680, 'worse'),
#  (1664, 'aspect'),
#  (1663, 'widened'),
#  (1658, 'pericardial'),
#  (1655, 'convincing'),
#  (1654, 'hyperinflation'),
#  (1652, 'recent'),
#  (1646, 'project'),
#  (1644, 'healed'),
#  (1623, 'completely'),
#  (1622, 'heterogeneous'),
#  (1621, 'shows'),
#  (1612, 'persist'),
#  (1596, 'improving'),
#  (1594, 'complications'),
#  (1581, 'representing'),
#  (1581, 'particularly'),
#  (1580, 'better'),
#  (1578, 'esophageal'),
#  (1570, 'might'),
#  (1565, 'placements'),
#  (1564, 'atrial'),
#  (1562, 'today'),
#  (1544, 'near'),
#  (1531, 'positioned'),
#  (1528, 'gastric'),
#  (1526, 'distended'),
#  (1523, 'developed'),
#  (1519, 'made'),
#  (1519, 'examination'),
#  (1517, 'worrisome'),
#  (1501, 'newly'),
#  (1497, 'setting'),
#  (1487, 'smaller'),
#  (1476, 'multilevel'),
#  (1464, 'diaphragms'),
#  (1459, 'inferior'),
#  (1458, 'degree'),
#  (1430, 'involving'),
#  (1428, 'drain'),
#  (1424, 'rounded'),
#  (1418, 'following'),
#  (1404, 'removal'),
#  (1402, 'all'),
#  (1400, 'granuloma'),
#  (1390, 'film'),
#  (1390, 'brachiocephalic'),
#  (1389, 'bowel'),
#  (1388, 'shoulder'),
#  (1388, 'ill'),
#  (1386, 'just'),
#  (1376, 'ge'),
#  (1373, 'widespread'),
#  (1370, 'additional'),
#  (1366, 'lymphadenopathy'),
#  (1365, 'subsequent'),
#  (1356, 'biapical'),
#  (1352, 'specifically'),
#  (1346, 'bones'),
#  (1344, 'main'),
#  (1343, 'after'),
#  (1338, 'ap'),
#  (1331, 'bibasal'),
#  (1327, 'ribs'),
#  (1325, 'several'),
#  (1322, 'frank'),
#  (1316, 'would'),
#  (1316, 'carinal'),
#  (1303, 'alveolar'),
#  (1302, 'positions'),
#  (1302, 'dilated'),
#  (1298, 'gas'),
#  (1297, 'notably'),
#  (1293, 'little'),
#  (1292, 'space'),
#  (1292, 'aside'),
#  (1279, 'tissues'),
#  (1278, 'hilum'),
#  (1277, 'transvenous'),
#  (1277, 'allowing'),
#  (1274, 'presumed'),
#  (1272, 'diffusely'),
#  (1270, 'lucency'),
#  (1260, 'hypertension'),
#  (1255, 'pronounced'),
#  (1251, 'hemi'),
#  (1249, 'tension'),
#  (1248, 'humeral'),
#  (1247, 'apices'),
#  (1246, 'surgery'),
#  (1244, 'markedly'),
#  (1240, 'unfolded'),
#  (1240, 'radiographs'),
#  (1238, 'configuration'),
#  (1232, 'deformities'),
#  (1218, 'hemorrhage'),
#  (1215, 'suspected'),
#  (1212, 'mitral'),
#  (1205, 'entirely'),
#  (1199, 'projection'),
#  (1198, 'described'),
#  (1194, 'two'),
#  (1192, 'infrahilar'),
#  (1186, 'radiopaque'),
#  (1177, 'placed'),
#  (1177, 'except'),
#  (1176, 'indistinctness'),
#  (1167, 'lesion'),
#  (1166, 'spinal'),
#  (1166, 'remaining'),
#  (1165, 'addition'),
#  (1158, 'vena'),
#  (1156, 'cava'),
#  (1156, 'beneath'),
#  (1151, 'congestive'),
#  (1147, 'complete'),
#  (1145, 'lymph'),
#  (1141, 'coursing'),
#  (1139, 'sinus'),
#  (1134, 'opacifications'),
#  (1132, 'diameter'),
#  (1121, 'fields'),
#  (1120, 'correct'),
#  (1113, 'lingula'),
#  (1112, 'bronchial'),
#  (1112, 'adenopathy'),
#  (1107, 'aerated'),
#  (1105, 'coronary'),
#  (1104, 'included'),
#  (1104, 'clearly'),
#  (1102, 'regions'),
#  (1102, ':'),
#  (1098, 'upright'),
#  (1098, 'gastroesophageal'),
#  (1097, 'under'),
#  (1092, 'coiled'),
#  (1088, 'cabg'),
#  (1086, 'thoracolumbar'),
#  (1086, 'peribronchial'),
#  (1078, 'laterally'),
#  (1071, 'partial'),
#  (1059, 'joint'),
#  (1059, 'clavicle'),
#  (1058, 'hemidiaphragms'),
#  (1051, 'fibrosis'),
#  (1050, 'concern'),
#  (1044, 'inspiratory'),
#  (1043, 'currently'),
#  (1039, 'abdominal'),
#  (1036, 'flattening'),
#  (1035, 'head'),
#  (1033, 'part'),
#  (1033, 'one'),
#  (1029, 'distribution'),
#  (1026, 'fat'),
#  (1024, 'indeterminate'),
#  (1023, 'active'),
#  (1013, 'orogastric'),
#  (1010, 'posteriorly'),
#  (1009, 'fusion'),
#  (1007, 'foreign'),
#  (1006, 'subdiaphragmatic'),
#  (1003, 'demonstrate'),
#  (1002, 'through'),
#  (983, 'x'),
#  (975, 'like'),
#  (970, 'elsewhere'),
#  (970, 'difficult'),
#  (969, 'situ'),
#  (961, 'suspicious'),
#  (961, 'metastatic'),
#  (961, 'background'),
#  (953, 'redemonstrated'),
#  (953, 'pneumoperitoneum'),
#  (951, 'obscuration'),
#  (946, 'peripheral'),
#  (936, 'rightward'),
#  (936, 'back'),
#  (934, 'loops'),
#  (933, 'azygos'),
#  (931, 'elongation'),
#  (931, 'bronchus'),
#  (930, 'hilus'),
#  (928, 'predominantly'),
#  (927, 'malignancy'),
#  (925, 'hyperexpanded'),
#  (920, 'distention'),
#  (919, 'appropriately'),
#  (918, 'ending'),
#  (917, 'veins'),
#  (917, 'pacing'),
#  (916, 'terminate'),
#  (916, 'arteries'),
#  (915, 'aicd'),
#  (914, 'skeletal'),
#  (911, 'vague'),
#  (910, 'beyond'),
#  (909, 'i'),
#  (908, 'cholecystectomy'),
#  (908, 'axilla'),
#  (907, 'parts'),
#  (907, 'accentuated'),
#  (902, 'masses'),
#  (899, 'thyroid'),
#  (897, 'leftward'),
#  (896, 'comparison'),
#  (896, 'collection'),
#  (894, 'relative'),
#  (893, 'focus'),
#  (875, 'inlet'),
#  (873, 'second'),
#  (873, 'pain'),
#  (871, 'between'),
#  (870, 'incompletely'),
#  (859, 'does'),
#  (859, 'decompensation'),
#  (857, 'evaluated'),
#  (857, 'densities'),
#  (853, 'raises'),
#  (852, 'dialysis'),
#  (851, 'bodies'),
#  (848, 'show'),
#  (845, 'finding'),
#  (845, 'breast'),
#  (838, 'axillary'),
#  (834, 'nipple'),
#  (834, 'cleared'),
#  (828, 'suggestion'),
#  (828, 'diagnosis'),
#  (827, 'clavicular'),
#  (826, 'bronchograms'),
#  (825, 'aligned'),
#  (820, 'such'),
#  (816, 'intraperitoneal'),
#  (816, 'drains'),
#  (814, 'lumbar'),
#  (811, 'hyperexpansion'),
#  (807, 'positioning'),
#  (807, 'good'),
#  (804, 'progressed'),
#  (799, 'accentuate'),
#  (798, 'pattern'),
#  (798, 'exaggerated'),
#  (793, 'relate'),
#  (792, 'located'),
#  (790, 'non'),
#  (789, 'exclude'),
#  (788, 'alignment'),
#  (786, 'progression'),
#  (786, 'high'),
#  (784, 'atypical'),
#  (783, 'longer'),
#  (781, 'platelike'),
#  (781, 'bronchiectasis'),
#  (779, 'clinical'),
#  (778, 'sinuses'),
#  (778, 'differential'),
#  (777, 'margin'),
#  (777, 'defibrillator'),
#  (777, 'appearing'),
#  (774, 'glenohumeral'),
#  (770, 'midlung'),
#  (763, 'sized'),
#  (761, 'ascending'),
#  (760, 'semi'),
#  (760, 'satisfactory'),
#  (755, 'age'),
#  (753, 'lingular'),
#  (749, 'scattered'),
#  (748, 'ett'),
#  (746, 'incidental'),
#  (741, 'zones'),
#  (741, 'site'),
#  (741, 'lesions'),
#  (740, 'origin'),
#  (737, 'presumably'),
#  (737, ')'),
#  (733, 'indistinct'),
#  (731, 'fundus'),
#  (729, 'gross'),
#  (729, 'end'),
#  (728, 'lobar'),
#  (726, 'perhaps'),
#  (726, 'off'),
#  (726, 'appeared'),
#  (723, 'reticular'),
#  (720, 'intra'),
#  (719, 'superiorly'),
#  (719, 'paratracheal'),
#  (717, 'replacement'),
#  (715, 'approach'),
#  (714, 'infusion'),
#  (707, 'reflective'),
#  (706, 'rather'),
#  (703, 'lies'),
#  (703, 'eventration'),
#  (703, 'dextroscoliosis'),
#  (701, 'almost'),
#  (697, 'sulcus'),
#  (696, 'so'),
#  (696, 'congested'),
#  (693, 'icd'),
#  (692, 'supine'),
#  (690, 'ventilation'),
#  (690, 'shadow'),
#  (690, 'deviation'),
#  (688, 'obstructive'),
#  (688, 'generator'),
#  (687, 'resolving'),
#  (687, 'nonspecific'),
#  (684, 'pa'),
#  (683, 'wire'),
#  (683, 'obscuring'),
#  (683, 'fixation'),
#  (681, 'diaphragmatic'),
#  (680, 'obvious'),
#  (680, 'despite'),
#  (679, 'collapsed'),
#  (677, 'noting'),
#  (675, 'severely'),
#  (675, 'procedure'),
#  (674, 'much'),
#  (673, 'node'),
#  (670, 'time'),
#  (669, 'overlies'),
#  (669, 'before'),
#  (668, 'poor'),
#  (667, 'best'),
#  (662, 'additionally'),
#  (657, 'medially'),
#  (654, 'third'),
#  (654, 'fullness'),
#  (651, 'tips'),
#  (650, 'catheters'),
#  (648, 'plaques'),
#  (648, 'indwelling'),
#  (647, 'wedge'),
#  (647, 'shaped'),
#  (646, 'channel'),
#  (645, 'about'),
#  (642, 'where'),
#  (640, 'metallic'),
#  (637, 'even'),
#  (636, 'injury'),
#  (634, 'plate'),
#  (633, 'appreciably'),
#  (632, 'acromioclavicular'),
#  (630, 'joints'),
#  (630, 'dobhoff'),
#  (629, 'demineralized'),
#  (627, 'pleura'),
#  (626, 'towards'),
#  (626, 'supraclavicular'),
#  (625, 'respectively'),
#  (623, 'largely'),
#  (621, 'resection'),
#  (621, 'ray'),
#  (619, 'tracheal'),
#  (619, 'their'),
#  (617, 'pulled'),
#  (617, 'external'),
#  (616, 'sutures'),
#  (614, 'definitive'),
#  (612, 'emphysematous'),
#  (611, 'granulomas'),
#  (608, 'segment'),
#  (607, 'unfolding'),
#  (604, 'further'),
#  (603, 'considered'),
#  (603, 'close'),
#  (601, 'radiation'),
#  (601, 'postsurgical'),
#  (600, 'especially'),
#  (599, 'faint'),
#  (598, 'sixth'),
#  (598, 'obscures'),
#  (597, 'views'),
#  (596, 'access'),
#  (594, 'dependent'),
#  (593, 'resulting'),
#  (591, 'prosthetic'),
#  (590, 'massive'),
#  (589, 'lumen'),
#  (587, 'arterial'),
#  (585, 'nodes'),
#  (584, 'structure'),
#  (584, 'first'),
#  (583, 'unclear'),
#  (581, 'shunt'),
#  (581, 'concurrent'),
#  (579, 'stably'),
#  (579, 'caused'),
#  (577, 'granulomatous'),
#  (577, 'dilatation'),
#  (576, 'humerus'),
#  (575, 'major'),
#  (572, 'height'),
#  (571, 'caliber'),
#  (569, 'whether'),
#  (569, 'repositioned'),
#  (566, 'etiology'),
#  (564, 'seventh'),
#  (564, 'adequate'),
#  (563, 'filled'),
#  (562, 'indicate'),
#  (562, 'hemodialysis'),
#  (561, 'sheath'),
#  (561, 'osteophytes'),
#  (559, 'whose'),
#  (559, 'pathology'),
#  (559, 'expansion'),
#  (557, 'material'),
#  (557, 'inspiration'),
#  (557, 'balloon'),
#  (554, 'particular'),
#  (548, 'raising'),
#  (548, 'fifth'),
#  (542, 'cardiophrenic'),
#  (540, 'metastases'),
#  (539, 'scar'),
#  (535, 'measuring'),
#  (535, 'curvature'),
#  (533, 'overinflation'),
#  (527, 'silhouetting'),
#  (526, 'nearly'),
#  (524, 'interim'),
#  (521, 'colon'),
#  (519, 'intubation'),
#  (518, 'fibrotic'),
#  (517, '('),
#  (515, 'remote'),
#  (514, 'trauma'),
#  (508, 'withdrawn'),
#  (507, 'tuberculosis'),
#  (507, 'remarkable'),
#  (504, 'atelectases'),
#  (503, 'operative'),
#  (502, 'poorly'),
#  (501, 'sign'),
#  (500, 'progressive'),
#  (496, 'haziness'),
#  (495, 'assessment'),
#  (494, 'indicative'),
#  (493, 'extubation'),
#  (491, 'hydropneumothorax'),
#  (491, 'asymmetry'),
#  (490, 'replaced'),
#  (489, 'generally'),
#  (489, 'chamber'),
#  (487, 'bone'),
#  (484, 'normally'),
#  (484, 'chain'),
#  (482, 'hypertrophic'),
#  (481, 'skin'),
#  (481, 'includes'),
#  (480, 'causing'),
#  (479, 'transverse'),
#  (477, 'plethora'),
#  (477, 'cuffing'),
#  (477, 'contrast'),
#  (477, 'complication'),
#  (476, 'convex'),
#  (474, 'accentuates'),
#  (471, 'lobectomy'),
#  (468, 'breath'),
#  (466, 'pump'),
#  (465, 'periphery'),
#  (465, 'band'),
#  (462, 'ekg'),
#  (461, 'borders'),
#  (458, 'definition'),
#  (458, 'abnormal'),
#  (457, 'radiographically'),
#  (457, 'consolidative'),
#  (455, 'stents'),
#  (455, 'displacement'),
#  (453, 'discrete'),
#  (451, 'nondistended'),
#  (449, 'inferiorly'),
#  (443, 'continue'),
#  (443, 'asymmetrical'),
#  (442, 'clavicles'),
#  (441, 'mainstem'),
#  (439, 'hole'),
#  (438, 't'),
#  (438, 'shortness'),
#  (438, 'apparently'),
#  (437, 'shadows'),
#  (437, 'kyphosis'),
#  (437, 'based'),
#  (436, 'airways'),
#  (436, 'absence'),
#  (435, 'gaseous'),
#  (435, 'fourth'),
#  (434, 'airway'),
#  (432, 'nor'),
#  (432, 'local'),
#  (431, 'pneumonic')]

# %%
report = random.choice(vqa_dataset_mimiccxr['reports'])
report = ' '.join(report['sentences'])
report, wordpunct_tokenize(report)
# Out:
# ('There has been interval removal of a right IJ catheter. The right lung base opacity has improved since prior study and may represent atelectasis. There are no pleural effusions. Moderate cardiomegaly is stable. There is minimal pulmonary edema. There is no pneumothorax. Right lung base opacity has improved since prior study and may represent atelectasis.',
#  ['There',
#   'has',
#   'been',
#   'interval',
#   'removal',
#   'of',
#   'a',
#   'right',
#   'IJ',
#   'catheter',
#   '.',
#   'The',
#   'right',
#   'lung',
#   'base',
#   'opacity',
#   'has',
#   'improved',
#   'since',
#   'prior',
#   'study',
#   'and',
#   'may',
#   'represent',
#   'atelectasis',
#   '.',
#   'There',
#   'are',
#   'no',
#   'pleural',
#   'effusions',
#   '.',
#   'Moderate',
#   'cardiomegaly',
#   'is',
#   'stable',
#   '.',
#   'There',
#   'is',
#   'minimal',
#   'pulmonary',
#   'edema',
#   '.',
#   'There',
#   'is',
#   'no',
#   'pneumothorax',
#   '.',
#   'Right',
#   'lung',
#   'base',
#   'opacity',
#   'has',
#   'improved',
#   'since',
#   'prior',
#   'study',
#   'and',
#   'may',
#   'represent',
#   'atelectasis',
#   '.'])
