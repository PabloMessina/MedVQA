# %%
import pandas as pd
from collections import Counter

# %%
df = pd.read_csv('/mnt/data/chest-imagenome-v1.0.0/analysis/object_to_attribute_relation_stats.csv')

# %%
Counter(df['bbox'])
# Out:
# Counter({'abdomen': 7,
#          'aortic arch': 8,
#          'cardiac silhouette': 23,
#          'carina': 4,
#          'cavoatrial junction': 8,
#          'left apical zone': 18,
#          'left arm': 8,
#          'left breast': 4,
#          'left chest wall': 12,
#          'left clavicle': 12,
#          'left costophrenic angle': 22,
#          'left hemidiaphragm': 10,
#          'left hilar structures': 30,
#          'left lower lung zone': 37,
#          'left lung': 38,
#          'left mid lung zone': 36,
#          'left shoulder': 7,
#          'left upper lung zone': 38,
#          'mediastinum': 22,
#          'neck': 10,
#          'right apical zone': 18,
#          'right arm': 8,
#          'right atrium': 8,
#          'right breast': 4,
#          'right chest wall': 12,
#          'right clavicle': 13,
#          'right costophrenic angle': 22,
#          'right hemidiaphragm': 10,
#          'right hilar structures': 30,
#          'right lower lung zone': 37,
#          'right lung': 38,
#          'right mid lung zone': 36,
#          'right shoulder': 7,
#          'right upper lung zone': 38,
#          'spine': 8,
#          'svc': 8,
#          'trachea': 7,
#          'upper mediastinum': 25})

# %%
df2 = pd.read_csv('/mnt/data/chest-imagenome-v1.0.0/analysis/affirmed_attributes_eval4paper.csv')

# %%
df2
# Out:
#                                  attribute  freq    TP   FN   FP  precision  \
# 0                         nlp|yes|abnormal  1940  1805  135  183   0.907948
# 1                           nlp|yes|normal  1908  1695  213  159   0.914239
# 2       anatomicalfinding|yes|lung opacity  1345  1231  114   74   0.943295
# 3        anatomicalfinding|yes|atelectasis   501   475   26   23   0.953815
# 4   anatomicalfinding|yes|pleural effusion   345   317   28   34   0.903134
# ..                                     ...   ...   ...  ...  ...        ...
# 65       anatomicalfinding|yes|bone lesion     2     1    1    2   0.333333
# 66       anatomicalfinding|yes|cyst/bullae     1     1    0    0   1.000000
# 67     tubesandlines|yes|mediastinal drain     1     1    0    0   1.000000
# 68        disease|yes|pericardial effusion     1     1    0    0   1.000000
# 69             device|yes|prosthetic valve     1     1    0    0   1.000000
#
#       recall  f1-score
# 0   0.930412  0.919043
# 1   0.888365  0.901116
# 2   0.915242  0.929057
# 3   0.948104  0.950951
# 4   0.918841  0.910920
# ..       ...       ...
# 65  0.500000  0.400000
# 66  1.000000  1.000000
# 67  1.000000  1.000000
# 68  1.000000  1.000000
# 69  1.000000  1.000000
#
# [70 rows x 8 columns]

# %%
df3 = pd.read_csv('/mnt/data/chest-imagenome-v1.0.0/analysis/affirmed_bboxes_across_attributes_report_level.csv')

# %%
df3
# Out:
#                    bbox_name  freq    TP  FN   FP  precision    recall  \
# 0                  left lung  1453  1382  71  128   0.915232  0.951136
# 1                 right lung  1436  1363  73  110   0.925322  0.949164
# 2         cardiac silhouette   633   617  16   27   0.958075  0.974724
# 3       left lower lung zone   609   568  41   42   0.931148  0.932677
# 4                mediastinum   601   573  28   30   0.950249  0.953411
# 5      right lower lung zone   580   509  71   40   0.927140  0.877586
# 6     right hilar structures   572   541  31   45   0.923208  0.945804
# 7      left hilar structures   571   543  28   37   0.936207  0.950963
# 8          upper mediastinum   359   328  31   11   0.967552  0.913649
# 9    left costophrenic angle   298   276  22   34   0.890323  0.926174
# 10  right costophrenic angle   286   267  19   29   0.902027  0.933566
# 11        left mid lung zone   173   165   8   13   0.926966  0.953757
# 12       right mid lung zone   169   132  37   17   0.885906  0.781065
# 13               aortic arch   144   139   5    5   0.965278  0.965278
# 14                     spine   132    98  34    8   0.924528  0.742424
# 15                      neck   124   118   6    3   0.975207  0.951613
# 16     right upper lung zone   117    96  21    7   0.932039  0.820513
# 17          right chest wall    87    54  33   12   0.818182  0.620690
# 18      left upper lung zone    83    73  10   24   0.752577  0.879518
# 19                   abdomen    80    75   5   11   0.872093  0.937500
# 20           left chest wall    79    48  31   11   0.813559  0.607595
# 21       right hemidiaphragm    78    72   6    2   0.972973  0.923077
# 22            right clavicle    71    36  35   10   0.782609  0.507042
# 23             left clavicle    67    35  32    7   0.833333  0.522388
# 24        left hemidiaphragm    65    60   5    4   0.937500  0.923077
# 25         right apical zone    58    46  12    4   0.920000  0.793103
# 26                   trachea    57    57   0    2   0.966102  1.000000
# 27          left apical zone    47    45   2    4   0.918367  0.957447
# 28                    carina    41    39   2    0   1.000000  0.951220
# 29            right shoulder    29    28   1    3   0.903226  0.965517
# 30             left shoulder    28    27   1    3   0.900000  0.964286
# 31                       svc    19    18   1    0   1.000000  0.947368
# 32              right atrium    14    13   1    0   1.000000  0.928571
# 33               left breast     7     7   0    1   0.875000  1.000000
# 34       cavoatrial junction     5     5   0    0   1.000000  1.000000
# 35                 right arm     4     4   0    0   1.000000  1.000000
# 36              right breast     2     2   0    2   0.500000  1.000000
# 37                  left arm     1     1   0    0   1.000000  1.000000
#
#     f1-score
# 0   0.932838
# 1   0.937092
# 2   0.966327
# 3   0.931911
# 4   0.951827
# 5   0.901683
# 6   0.934370
# 7   0.943527
# 8   0.939828
# 9   0.907895
# 10  0.917526
# 11  0.940171
# 12  0.830189
# 13  0.965278
# 14  0.823529
# 15  0.963265
# 16  0.872727
# 17  0.705882
# 18  0.811111
# 19  0.903614
# 20  0.695652
# 21  0.947368
# 22  0.615385
# 23  0.642202
# 24  0.930233
# 25  0.851852
# 26  0.982759
# 27  0.937500
# 28  0.975000
# 29  0.933333
# 30  0.931034
# 31  0.972973
# 32  0.962963
# 33  0.933333
# 34  1.000000
# 35  1.000000
# 36  0.666667
# 37  1.000000

# %%
df4 = pd.read_csv('/mnt/data/chest-imagenome-v1.0.0/analysis/object_to_object_comparison_relation_stats.csv')

# %%
df4
# Out:
#                    bbox           comparison  \
# 0               abdomen             improved
# 1               abdomen             improved
# 2               abdomen             improved
# 3               abdomen  improved;;no change
# 4               abdomen  improved;;no change
# ...                 ...                  ...
# 2676  upper mediastinum             worsened
# 2677  upper mediastinum             worsened
# 2678  upper mediastinum             worsened
# 2679  upper mediastinum             worsened
# 2680  upper mediastinum             worsened
#
#                                         attribute  freq_nlp  freq_have_bboxes
# 0     anatomicalfinding|yes|sub-diaphragmatic air        92                92
# 1                                nlp|yes|abnormal       215               215
# 2                                  nlp|yes|normal        12                12
# 3     anatomicalfinding|yes|sub-diaphragmatic air         4                 4
# 4                                nlp|yes|abnormal         8                 8
# ...                                           ...       ...               ...
# 2676                      disease|yes|lung cancer         3                 3
# 2677                             nlp|yes|abnormal       777               774
# 2678                               nlp|yes|normal       111               110
# 2679             technicalassessment|yes|artifact         4                 4
# 2680              technicalassessment|yes|rotated         5                 5
#
# [2681 rows x 5 columns]
