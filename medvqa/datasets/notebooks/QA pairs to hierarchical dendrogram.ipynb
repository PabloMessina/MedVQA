# %%
from medvqa.datasets.utils import get_tfidf_matrix_from_qa_pairs, plot_tfidf_dendrogram

# %%
output = get_tfidf_matrix_from_qa_pairs(
    '/mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/qa_adapted_reports__20220904_095810.json',
    max_features=10000,
)
# Out:
# ...
# 100%|██████████| 97/97 [00:00<00:00, 274.08it/s]

# %%
plot_tfidf_dendrogram(output['tfidf_matrix'], output['questions'], figsize=(15, 30))
