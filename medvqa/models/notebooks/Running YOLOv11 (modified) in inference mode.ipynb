# %%
# %env CUDA_VISIBLE_DEVICES=0
# Out:
# env: CUDA_VISIBLE_DEVICES=0

# %%
from importlib import reload
import medvqa

# %%
reload(medvqa.models.model_debugging_utils)
# Out:
# <module 'medvqa.models.model_debugging_utils' from '/home/pamessina/medvqa/medvqa/models/model_debugging_utils.py'>

# %%
from medvqa.models.model_debugging_utils import YOLOv11Visualizer

# %% [markdown]
# ## Trained on VinDr-CXR + Chest ImaGenome (anat)

# %%
vis = YOLOv11Visualizer(model_checkpoint_folder_path="/mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20241122_163237_mim+vinbig_yolo11l(d:cig,vinbig)_dws=1,0.3")
# Out:
# self.device =  cuda
# Load phrase grounder
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20241122_163237_mim+vinbig_yolo11l(d:cig,vinbig)_dws=1,0.3/metadata.json
# MultiPurposeVisualModule()
#   Initializing raw_image_encoder: yolov11-for-det-mlc
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  2    173824  ultralytics.nn.modules.block.C3k2            [128, 256, 2, True, 0.25]
#   3                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   4                  -1  2    691712  ultralytics.nn.modules.block.C3k2            [256, 512, 2, True, 0.25]
# ...

# %%
vis.visualize_yolov11_predictions(
    image_path='/mnt/workspace/vinbig-cxr/dataset-jpg/images-512x512(keep_aspect_ratio)/77fb399d095bb11d1344a1a114f59376.jpg',
    dataset_name='vinbig',
    conf_thres=0.1,
    iou_thres=0.02,
    max_det=40,
)
# Out:
# image_path = /mnt/workspace/vinbig-cxr/dataset-jpg/images-512x512(keep_aspect_ratio)/77fb399d095bb11d1344a1a114f59376.jpg
# image.shape = torch.Size([3, 416, 416])
# image_size_before = (666, 512)
# image_size_after = (416, 416)
# Run model in inference mode
# self.model.training =  False
# image.shape = torch.Size([3, 416, 416])
# output.keys() = dict_keys(['detection'])
# predictions.shape = (4, 6)
# Visualize bbox predictions
# image_path=/mnt/workspace/vinbig-cxr/dataset-jpg/images-512x512(keep_aspect_ratio)/77fb399d095bb11d1344a1a114f59376.jpg

# %%
vis.visualize_yolov11_predictions(
    image_path='/mnt/workspace/vinbig-cxr/dataset-jpg/images-512x512(keep_aspect_ratio)/8a56a454dfea716a4d249144054974c1.jpg',
    dataset_name='vinbig',
    conf_thres=0.1,
    iou_thres=0.02,
    max_det=40,
)
# Out:
# image_path = /mnt/workspace/vinbig-cxr/dataset-jpg/images-512x512(keep_aspect_ratio)/8a56a454dfea716a4d249144054974c1.jpg
# image.shape = torch.Size([3, 416, 416])
# image_size_before = (512, 512)
# image_size_after = (416, 416)
# Run model in inference mode
# self.model.training =  False
# image.shape = torch.Size([3, 416, 416])
# output.keys() = dict_keys(['detection'])
# predictions.shape = (2, 6)
# Anomalous bboxes found: 29 of 37367
# class_id_offset: 0
# Anomalous bboxes found: 0 of 2697
# class_id_offset: 0
# Visualize bbox predictions
# image_path=/mnt/workspace/vinbig-cxr/dataset-jpg/images-512x512(keep_aspect_ratio)/8a56a454dfea716a4d249144054974c1.jpg

# %%
vis.visualize_yolov11_predictions(
    image_path='/mnt/workspace/vinbig-cxr/dataset-jpg/images-512x512(keep_aspect_ratio)/8a56a454dfea716a4d249144054974c1.jpg',
    dataset_name='cig',
    conf_thres=0.1,
    iou_thres=0.02,
    max_det=40,
    show_gt=False,
)
# Out:
# image_path = /mnt/workspace/vinbig-cxr/dataset-jpg/images-512x512(keep_aspect_ratio)/8a56a454dfea716a4d249144054974c1.jpg
# image.shape = torch.Size([3, 416, 416])
# image_size_before = (512, 512)
# image_size_after = (416, 416)
# Run model in inference mode
# self.model.training =  False
# image.shape = torch.Size([3, 416, 416])
# output.keys() = dict_keys(['detection'])
# predictions.shape = (36, 6)
# Visualize bbox predictions
# image_path=/mnt/workspace/vinbig-cxr/dataset-jpg/images-512x512(keep_aspect_ratio)/8a56a454dfea716a4d249144054974c1.jpg

# %%
vis.visualize_yolov11_predictions(
    image_path='/mnt/workspace/physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11255133/s50857798/d784c870-cccb726f-ba44b7d4-703efff1-45f36555.jpg',
    dataset_name='cig',
    conf_thres=0.1,
    iou_thres=0.02,
    max_det=40,
    figsize=(15, 15),
)
# Out:
# image_path = /mnt/workspace/physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11255133/s50857798/d784c870-cccb726f-ba44b7d4-703efff1-45f36555.jpg
# image.shape = torch.Size([3, 416, 416])
# image_size_before = (615, 512)
# image_size_after = (416, 416)
# Run model in inference mode
# self.model.training =  False
# image.shape = torch.Size([3, 416, 416])
# output.keys() = dict_keys(['detection'])
# predictions.shape = (36, 6)
# Visualize bbox predictions
# image_path=/mnt/workspace/physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11255133/s50857798/d784c870-cccb726f-ba44b7d4-703efff1-45f36555.jpg

# %%
vis.visualize_yolov11_predictions(
    image_path='/mnt/workspace/vinbig-cxr/dataset-jpg/images/8de301615cf3fca4c747a87d9b9505c1.jpg',
    dataset_name='vinbig',
    conf_thres=0.025,
    iou_thres=0.02,
    max_det=40,
)
# Out:
# image_path = /mnt/workspace/vinbig-cxr/dataset-jpg/images/8de301615cf3fca4c747a87d9b9505c1.jpg
# image.shape = torch.Size([3, 416, 416])
# image_size_before = (2895, 2663)
# image_size_after = (416, 416)
# Run model in inference mode
# self.model.training =  False
# image.shape = torch.Size([3, 416, 416])
# output.keys() = dict_keys(['detection'])
# predictions.shape = (7, 6)
# Visualize bbox predictions
# image_path=/mnt/workspace/vinbig-cxr/dataset-jpg/images/8de301615cf3fca4c747a87d9b9505c1.jpg

# %% [markdown]
# ## Trained on VinDr-CXR only

# %%
vis = YOLOv11Visualizer(model_checkpoint_folder_path="/mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20241123_031630_vinbig_yolo11l(d:vinbig)")
# Out:
# self.device =  cuda
# Load phrase grounder
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20241123_031630_vinbig_yolo11l(d:vinbig)/metadata.json
# MultiPurposeVisualModule()
#   Initializing raw_image_encoder: yolov11-for-det-mlc
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  2    173824  ultralytics.nn.modules.block.C3k2            [128, 256, 2, True, 0.25]
#   3                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   4                  -1  2    691712  ultralytics.nn.modules.block.C3k2            [256, 512, 2, True, 0.25]
#   5                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
# ...

# %%
vis.visualize_yolov11_predictions(
    image_path='/mnt/workspace/vinbig-cxr/dataset-jpg/images/706814b8f626ce46d5614029ec51dc44.jpg',
    dataset_name='vinbig',
    conf_thres=0.1,
    iou_thres=0.1,
    max_det=40,
    figsize=(15, 15),
)
# Out:
# image_path = /mnt/workspace/vinbig-cxr/dataset-jpg/images/706814b8f626ce46d5614029ec51dc44.jpg
# image.shape = torch.Size([3, 416, 416])
# image_size_before = (2312, 2048)
# image_size_after = (416, 416)
# Run model in inference mode
# self.model.training =  False
# image.shape = torch.Size([3, 416, 416])
# output.keys() = dict_keys(['detection'])
# predictions.shape = (8, 6)
# Visualize bbox predictions
# image_path=/mnt/workspace/vinbig-cxr/dataset-jpg/images/706814b8f626ce46d5614029ec51dc44.jpg

# %%
vis.visualize_yolov11_predictions(
    image_path='/mnt/workspace/vinbig-cxr/dataset-jpg/images/9c91dd728f43b2c18c80674c11321fb4.jpg',
    dataset_name='vinbig',
    conf_thres=0.1,
    iou_thres=0.1,
    max_det=40,
    figsize=(15, 15),
)
# Out:
# image_path = /mnt/workspace/vinbig-cxr/dataset-jpg/images/9c91dd728f43b2c18c80674c11321fb4.jpg
# image.shape = torch.Size([3, 416, 416])
# Run model in inference mode
# self.model.training =  False
# image.shape = torch.Size([3, 416, 416])
# output.keys() = dict_keys(['detection'])
# predictions.shape = (10, 6)
# Anomalous bboxes found: 29 of 37367
# class_id_offset: 0
# Anomalous bboxes found: 0 of 2697
# class_id_offset: 0
# Visualize bbox predictions
# image_path=/mnt/workspace/vinbig-cxr/dataset-jpg/images/9c91dd728f43b2c18c80674c11321fb4.jpg

# %% [markdown]
# ## YOLOv11 (fact-conditioned) - Trained on VinDr-CXR only

# %%
vis = YOLOv11Visualizer(
    model_checkpoint_folder_path="/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20241208_172651_vinbig_PhraseGrounder(yolo11l(fact_cond,cls,det,128,[256,128],256),AdaptiveFiLM_MLP_YOLOv11)",
    fact_conditioned=True,
    vinbig_phrase_embeddings_filepath="/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/vinbig/label_phrase_embeddings(hash=353,2491289492560726319).pkl",
)
# Out:
# self.device =  cuda
# Load model
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20241208_172651_vinbig_PhraseGrounder(yolo11l(fact_cond,cls,det,128,[256,128],256),AdaptiveFiLM_MLP_YOLOv11)/metadata.json
# WARNING: Unused kwargs: {'pretrained_checkpoint_folder_path': '/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20241208_123205_vinbig_PhraseGrounder(yolo11l(fact_cond,cls,det,128,[256,128],256),AdaptiveFiLM_MLP_YOLOv11)', 'pretrained_checkpoint_folder_paths': None}
# MultiPurposeVisualModule()
#   Initializing raw_image_encoder: yolov11-fact-conditioned
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
# ...

# %%
vis.visualize_yolov11_predictions(
    image_path='/mnt/workspace/vinbig-cxr/dataset-jpg/images/9c91dd728f43b2c18c80674c11321fb4.jpg',
    dataset_name='vinbig',
    conf_thres=0.1,
    iou_thres=0.1,
    max_det=40,
    figsize=(15, 15),
)
# Out:
# image_path = /mnt/workspace/vinbig-cxr/dataset-jpg/images/9c91dd728f43b2c18c80674c11321fb4.jpg
# image.shape = torch.Size([3, 416, 416])
# Run model in inference mode
# self.model.training =  False
# image.shape = torch.Size([3, 416, 416])
# output.keys() = dict_keys(['classification_logits', 'detection'])
# Classification probabilities:
# 	pulmonary fibrosis seen: 0.4900
# 	pleural thickening seen: 0.4513
# 	other lesion seen: 0.4238
# 	aortic enlargement seen: 0.4144
# 	lung opacity seen: 0.4006
# 	interstitial lung disease seen: 0.3622
# 	nodule/mass seen: 0.3516
# 	pleural effusion seen: 0.3468
# 	infiltration seen: 0.3279
# 	calcification seen: 0.2943
# 	atelectasis seen: 0.2752
# 	consolidation seen: 0.2677
# 	emphysema seen: 0.2273
# 	cardiomegaly seen: 0.2104
# 	rib fracture seen: 0.1862
# 	lung cavity seen: 0.1801
# 	pneumothorax seen: 0.1757
# 	mediastinal shift seen: 0.1655
# 	enlarged pulmonary artery seen: 0.1562
# 	lung cyst seen: 0.1187
# ...

# %%
vis.visualize_yolov11_predictions(
    image_path='/mnt/workspace/vinbig-cxr/dataset-jpg/images/706814b8f626ce46d5614029ec51dc44.jpg',
    dataset_name='vinbig',
    conf_thres=0.05,
    iou_thres=0.1,
    max_det=40,
    figsize=(15, 15),
)
# Out:
# image_path = /mnt/workspace/vinbig-cxr/dataset-jpg/images/706814b8f626ce46d5614029ec51dc44.jpg
# image.shape = torch.Size([3, 416, 416])
# Run model in inference mode
# self.model.training =  False
# image.shape = torch.Size([3, 416, 416])
# output.keys() = dict_keys(['classification_logits', 'detection'])
# Classification probabilities:
# 	aortic enlargement seen: 0.5039
# 	cardiomegaly seen: 0.3942
# 	pleural thickening seen: 0.3883
# 	pulmonary fibrosis seen: 0.3589
# 	pleural effusion seen: 0.3158
# 	lung opacity seen: 0.3140
# 	other lesion seen: 0.2890
# 	nodule/mass seen: 0.2697
# 	infiltration seen: 0.2388
# 	consolidation seen: 0.2264
# 	calcification seen: 0.2045
# 	mediastinal shift seen: 0.1642
# 	pneumothorax seen: 0.1558
# 	atelectasis seen: 0.1536
# 	enlarged pulmonary artery seen: 0.1312
# 	interstitial lung disease seen: 0.1296
# 	rib fracture seen: 0.1070
# 	emphysema seen: 0.0950
# 	lung cavity seen: 0.0726
# 	lung cyst seen: 0.0581
# ...

# %%
vis.visualize_yolov11_predictions(
    image_path='/mnt/workspace/vinbig-cxr/dataset-jpg/images/8de301615cf3fca4c747a87d9b9505c1.jpg',
    dataset_name='vinbig',
    conf_thres=0.05,
    iou_thres=0.1,
    max_det=40,
    figsize=(15, 15),
)
# Out:
# image_path = /mnt/workspace/vinbig-cxr/dataset-jpg/images/8de301615cf3fca4c747a87d9b9505c1.jpg
# image.shape = torch.Size([3, 416, 416])
# Run model in inference mode
# self.model.training =  False
# image.shape = torch.Size([3, 416, 416])
# output.keys() = dict_keys(['classification_logits', 'detection'])
# Classification probabilities:
# 	aortic enlargement seen: 0.6832
# 	cardiomegaly seen: 0.5176
# 	pleural thickening seen: 0.3663
# 	pulmonary fibrosis seen: 0.3003
# 	other lesion seen: 0.2772
# 	lung opacity seen: 0.2695
# 	pleural effusion seen: 0.2465
# 	nodule/mass seen: 0.2163
# 	interstitial lung disease seen: 0.1954
# 	calcification seen: 0.1953
# 	infiltration seen: 0.1827
# 	enlarged pulmonary artery seen: 0.1510
# 	consolidation seen: 0.1184
# 	atelectasis seen: 0.0939
# 	rib fracture seen: 0.0918
# 	mediastinal shift seen: 0.0849
# 	pneumothorax seen: 0.0507
# 	lung cavity seen: 0.0493
# 	emphysema seen: 0.0443
# 	lung cyst seen: 0.0386
# ...
