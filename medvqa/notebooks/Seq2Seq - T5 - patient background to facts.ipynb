# %%
# %env CUDA_VISIBLE_DEVICES=1
# Out:
# env: CUDA_VISIBLE_DEVICES=1

# %%
# !ls /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/
# Out:
#  gpt-3.5-turbo_parsed_backgrounds.jsonl
#  gpt-3.5-turbo_parsed_reports__backup.jsonl
#  gpt-3.5-turbo_parsed_reports.jsonl
# 'gpt-3.5-turbo_parsed_reports(old).jsonl'
#  gpt-3.5-turbo_parsed_sentences.jsonl
#  gpt-4-0613_parsed_reports.jsonl
#  gpt-4-0613_parsed_sentences.jsonl

# %%
# !python ../train_seq2seq.py \
        --epochs 60 \
        --batches_per_epoch 1000 \
        --batch_size 25 \
        --num_workers 2 \
        --iters_to_accumulate 4 \
        --optimizer_name "adamw" \
        --scheduler "exp-warmup+decay+cyclicdecay" \
        --lr 1e-6 \
        --warmup_decay_and_cyclic_decay_args "1e-6,3,2e-4,8,1e-6,2e-4,8,1e-6" \
        --task_name "background2facts" \
        --input_output_jsonl_filepaths \
            "/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo_parsed_backgrounds.jsonl" \
        --seq2seq_model_name "t5" \
        --t5_model_name "t5-small" \
        --use_amp \
        --save
# Out:
# script's arguments:
#    epochs: 60
#    batches_per_epoch: 1000
#    batch_size: 25
#    checkpoint_folder: None
#    seq2seq_model_name: t5
#    t5_model_name: t5-small
#    bart_model_name: facebook/bart-base
#    pretrained_checkpoint_folder_path: None
#    optimizer_name: adamw
#    lr: 1e-06
#    scheduler: exp-warmup+decay+cyclicdecay
#    lr_decay: 0.76
#    lr_decay_patience: 2
#    warmup_and_decay_args: None
#    warmup_and_cosine_args: None
#    warmup_decay_and_cyclic_decay_args: 1e-6,3,2e-4,8,1e-6,2e-4,8,1e-6
#    iters_to_accumulate: 4
#    override_lr: False
#    task_name: background2facts
#    val_size: 200
#    input_output_jsonl_filepaths: ['/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo_parsed_backgrounds.jsonl']
#    num_workers: 2
#    device: GPU
#    use_amp: True
#    save: True
# ----- Training model from scratch ------
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Creating instance of Seq2SeqModel ...
# Seq2Seq model:
#   model_name: t5-small
# --------------------------------------------------
# 3) Defining optimizer ...
# create_optimizer(): name = adamw
# --------------------------------------------------
# 4) Defining scheduler ...
# Using exp-warmup+decay+cyclicdecay scheduler: 1e-6,3,2e-4,8,1e-6,2e-4,8,1e-6
# 1e-06 3 0.0002 8 1e-06 0.0002 8 1e-06
# self.steps_to_restart = 8
# self.steps = -1
# self.initial_lr = 0.0002
# --------------------------------------------------
# 5) Creating trainer and validator engines ...
# GradientAccumulator.__init__(): num_accumulation_steps = 4
# --------------------------------------------------
# 6) Defining collate_batch_fn ...
# Loaded 20000 input/output pairs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo_parsed_backgrounds.jsonl
# Number of train examples: 19800
# Number of val examples: 200
# Number of total examples: 20000
# Input/output example:
# Input:
# indication: Patient with metastatic hepatocarcinoma, intubated, pneumonia versus edema.
# Output:
# Metastatic hepatocarcinoma
# Intubated
# Pneumonia
# Edema
# seq2seq_trainer.name =  background2facts(gpt-3.5-turbo_parsed_back)
# --------------------------------------------------
# 7) Attaching metrics, losses, timer and events to engines ...
# --------------------------------------------------
# 8) Defining learning rate scheduler handler ...
# --------------------------------------------------
# 9) Defining checkpoint folder path ...
# checkpoint_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/seq2seq/20230615_113851_background2facts(gpt-3.5-turbo_parsed_back)_Seq2Seq(t5-small)
# metadata saved to /mnt/data/pamessina/workspaces/medvqa-workspace/models/seq2seq/20230615_113851_background2facts(gpt-3.5-turbo_parsed_back)_Seq2Seq(t5-small)/metadata.json
# --------------------------------------------------
# 10) Defining log_metrics_handler ...
# MetricsLogger :: we'll be logging to /mnt/data/pamessina/workspaces/medvqa-workspace/models/seq2seq/20230615_113851_background2facts(gpt-3.5-turbo_parsed_back)_Seq2Seq(t5-small)/metrics_logs.csv
# --------------------------------------------------
# 11) Running trainer engine ...
# ---- Epoch 1/60
# (1) Training stage (lr = 0.000001) ...
# loss 3.99169, s2s_loss 3.66171, 99.71 secs
# (2) Validation stage ...
# Random output:
# Indi withsatic AAA s/p e // // upup //xr.s Indi Indi Indi Indi Indi Indi Indi Indi Indi Indi Indi Indi Indi Indi Indi Indi
# s2s_loss 3.22149, 0.38 secs
# New checkpoint saved: checkpoint_1_s2s_loss=0.2346.pt
# ---- Epoch 2/60
# (1) Training stage (lr = 0.000006) ...
# loss 4.06739, s2s_loss 2.82443, 107.05 secs
# (2) Validation stage ...
# Random output:
# woman M of M M M catheter catheter catheter catheter catheter placement in out catheter of to catheter catheter placement woman woman woman woman woman woman woman woman woman woman woman woman woman woman
# s2s_loss 2.02667, 0.36 secs
# New checkpoint saved: checkpoint_2_s2s_loss=0.3235.pt
# ---- Epoch 3/60
# (1) Training stage (lr = 0.000034) ...
# loss 2.97401, s2s_loss 1.81059, 114.41 secs
# (2) Validation stage ...
# Random output:
# male SVT to 180 rate 180 to 180sss palpitation indication indication male male male male male male male male male male male male male male male male male
# s2s_loss 1.33064, 0.40 secs
# New checkpoint saved: checkpoint_3_s2s_loss=0.4217.pt
# ---- Epoch 4/60
# (1) Training stage (lr = 0.000200) ...
# loss 1.63858, s2s_loss 1.22444, 119.80 secs
# (2) Validation stage ...
# Random output:
# male podtracheobrochoplasty podoperative  3 interval changeno specific information provided) provided male male male male male male male male male male male male male
# s2s_loss 0.93997, 0.58 secs
# New checkpoint saved: checkpoint_4_s2s_loss=0.5089.pt
# ---- Epoch 5/60
# (1) Training stage (lr = 0.000103) ...
# loss 0.88892, s2s_loss 1.01032, 122.61 secs
# (2) Validation stage ...
# Random output:
# male historys/p LUL increasedL lower extremlobe) increased oxygenB/conhortness of breath) decreased increased male male male male male male male male
# s2s_loss 0.86165, 0.48 secs
# New checkpoint saved: checkpoint_5_s2s_loss=0.5332.pt
# ---- Epoch 6/60
# (1) Training stage (lr = 0.000053) ...
# loss 0.92226, s2s_loss 0.94750, 122.14 secs
# (2) Validation stage ...
# Random output:
# female seizures angular radiodense lesion seen on lateral view female female female female female female female female female female female female female female female female female female
# s2s_loss 0.83165, 0.44 secs
# New checkpoint saved: checkpoint_6_s2s_loss=0.5427.pt
# ---- Epoch 7/60
# (1) Training stage (lr = 0.000027) ...
# loss 0.84541, s2s_loss 0.91867, 123.74 secs
# (2) Validation stage ...
# Random output:
# male cough productive volume volume of volume over evaluation out collapse evaluation male male male male male male male male male male male male male male male male male male male male male male
# s2s_loss 0.81956, 0.54 secs
# New checkpoint saved: checkpoint_7_s2s_loss=0.5467.pt
# ---- Epoch 8/60
# (1) Training stage (lr = 0.000014) ...
# loss 0.79285, s2s_loss 0.90196, 129.05 secs
# (2) Validation stage ...
# Random output:
# female Poperative day 0 placement of left Ommaya Reservoir  of pontine lesion le of leptomeng diseaseal disease evaluate for pneumonia
# s2s_loss 0.81032, 0.41 secs
# New checkpoint saved: checkpoint_8_s2s_loss=0.5497.pt
# ---- Epoch 9/60
# (1) Training stage (lr = 0.000007) ...
# loss 0.87350, s2s_loss 0.89402, 131.63 secs
# (2) Validation stage ...
# Random output:
# female worsening confusion thargy female female female female female female female female female female female female female female female female female female female female female female female female female
# s2s_loss 0.80495, 0.40 secs
# New checkpoint saved: checkpoint_9_s2s_loss=0.5514.pt
# ---- Epoch 10/60
# (1) Training stage (lr = 0.000004) ...
# loss 1.20892, s2s_loss 0.89385, 128.37 secs
# (2) Validation stage ...
# Random output:
# female Poperative day 0 placement of left Ommaya Reservoir history of pontine lesion le of leptomeng diseaseal disease evaluate for pneumonia
# s2s_loss 0.80306, 0.48 secs
# New checkpoint saved: checkpoint_10_s2s_loss=0.5520.pt
# ---- Epoch 11/60
# (1) Training stage (lr = 0.000002) ...
# loss 0.90312, s2s_loss 0.89051, 123.54 secs
# (2) Validation stage ...
# Random output:
# SG position
# s2s_loss 0.80197, 0.52 secs
# New checkpoint saved: checkpoint_11_s2s_loss=0.5523.pt
# ---- Epoch 12/60
# (1) Training stage (lr = 0.000001) ...
# loss 0.89852, s2s_loss 0.88730, 123.50 secs
# (2) Validation stage ...
# Random output:
# male copPD pneumonia new consolidation male male male male male male male male male male male male male male male male male male male male male male male male male male male male
# s2s_loss 0.80124, 0.65 secs
# New checkpoint saved: checkpoint_12_s2s_loss=0.5526.pt
# ---- Epoch 13/60
# (1) Training stage (lr = 0.000200) ...
# loss 0.84039, s2s_loss 0.85206, 131.76 secs
# (2) Validation stage ...
# Random output:
# non-responsiveness syncope pain with breathing pain pain non non non non non non non non non non non non non non non non non non non non non non
# s2s_loss 0.72477, 0.44 secs
# New checkpoint saved: checkpoint_13_s2s_loss=0.5758.pt
# ---- Epoch 14/60
# (1) Training stage (lr = 0.000094) ...
# loss 0.60921, s2s_loss 0.77444, 134.42 secs
# (2) Validation stage ...
# Random output:
# female Poperative day 3 A Aaortic valve replacement effusion alectasis female female female female female female female female female female female female female
# s2s_loss 0.69467, 0.40 secs
# New checkpoint saved: checkpoint_14_s2s_loss=0.5874.pt
# ---- Epoch 15/60
# (1) Training stage (lr = 0.000044) ...
# loss 0.74485, s2s_loss 0.74367, 128.91 secs
# (2) Validation stage ...
# Random output:
# female seizures smallangular radiodense lesion seen on lateral view female female female female female female female female female female female female female female female female female female
# s2s_loss 0.67993, 0.52 secs
# New checkpoint saved: checkpoint_15_s2s_loss=0.5931.pt
# ---- Epoch 16/60
# (1) Training stage (lr = 0.000021) ...
# loss 0.71220, s2s_loss 0.72805, 122.68 secs
# (2) Validation stage ...
# Random output:
# female nausea vomiting lightnessness rule out pneumonia rule out pleural infection female female female female female female female female female female female female female female female female female female female
# s2s_loss 0.67171, 0.45 secs
# New checkpoint saved: checkpoint_16_s2s_loss=0.5962.pt
# ---- Epoch 17/60
# (1) Training stage (lr = 0.000010) ...
# loss 0.82404, s2s_loss 0.72089, 126.18 secs
# (2) Validation stage ...
# Random output:
# male historys/p LUL increasedL lower extremlobe) increased shortB/shortness of breath) congestion increased male male male male male male male male
# s2s_loss 0.67149, 0.47 secs
# New checkpoint saved: checkpoint_17_s2s_loss=0.5965.pt
# ---- Epoch 18/60
# (1) Training stage (lr = 0.000005) ...
# loss 0.58531, s2s_loss 0.71808, 134.80 secs
# (2) Validation stage ...
# Random output:
# male copPD pneumonia new consolidation new male male male male male male male male male male male male male male male male male male male male male male male male male male male
# s2s_loss 0.67020, 0.55 secs
# New checkpoint saved: checkpoint_18_s2s_loss=0.5971.pt
# ---- Epoch 19/60
# (1) Training stage (lr = 0.000002) ...
# loss 0.80359, s2s_loss 0.71792, 134.34 secs
# (2) Validation stage ...
# Random output:
# female extensive cell start starting chemotherapy dropping  saturations 80s rule to recent imaging rule out pneumonia rule out new collapse female female female female female female female female female female female
# s2s_loss 0.66954, 0.70 secs
# New checkpoint saved: checkpoint_19_s2s_loss=0.5973.pt
# ---- Epoch 20/60
# (1) Training stage (lr = 0.000001) ...
# loss 0.73444, s2s_loss 0.71557, 129.89 secs
# (2) Validation stage ...
# Random output:
# female postoperative day 0 placement of left Ommaya Reservoir history of pontine lesion le of leptomeng diseaseal disease evaluate for pneumonia
# s2s_loss 0.66949, 0.56 secs
# New checkpoint saved: checkpoint_20_s2s_loss=0.5974.pt
# ---- Epoch 21/60
# (1) Training stage (lr = 0.000200) ...
# loss 0.66980, s2s_loss 0.70470, 128.32 secs
# (2) Validation stage ...
# Random output:
# SG positiond
# s2s_loss 0.63641, 0.46 secs
# New checkpoint saved: checkpoint_21_s2s_loss=0.6086.pt
# ---- Epoch 22/60
# (1) Training stage (lr = 0.000094) ...
# loss 0.65203, s2s_loss 0.65794, 131.95 secs
# (2) Validation stage ...
# Random output:
# male SVT to 180 rate of to 180 degreesspm palpitations male male male male male male male male male male male male male male male male male male male
# s2s_loss 0.61212, 0.52 secs
# New checkpoint saved: checkpoint_22_s2s_loss=0.6186.pt
# ---- Epoch 23/60
# (1) Training stage (lr = 0.000044) ...
# loss 0.51177, s2s_loss 0.63258, 142.09 secs
# (2) Validation stage ...
# Random output:
# male COPD pneumonia new consolidation new male male male male male male male male male male male male male male male male male male male male male male male male male male male
# s2s_loss 0.60388, 0.59 secs
# New checkpoint saved: checkpoint_23_s2s_loss=0.6224.pt
# ---- Epoch 24/60
# (1) Training stage (lr = 0.000021) ...
# loss 0.74839, s2s_loss 0.61854, 137.97 secs
# (2) Validation stage ...
# Random output:
# female M of Mral valve replacement went PA catheter placement in out pneu to PA catheter placement catheter female female female female female female female female female female female female female
# s2s_loss 0.59953, 0.58 secs
# New checkpoint saved: checkpoint_24_s2s_loss=0.6245.pt
# ---- Epoch 25/60
# (1) Training stage (lr = 0.000010) ...
# loss 0.45944, s2s_loss 0.61147, 132.14 secs
# (2) Validation stage ...
# Random output:
# male cough productive history history of volume stat rule out consolidation evaluation male male male male male male male male male male male male male male male male male male male male male male
# s2s_loss 0.59802, 0.49 secs
# New checkpoint saved: checkpoint_25_s2s_loss=0.6253.pt
# ---- Epoch 26/60
# (1) Training stage (lr = 0.000005) ...
# loss 0.68620, s2s_loss 0.61227, 127.55 secs
# (2) Validation stage ...
# Random output:
# male cough productive history history of volume stat rule out consolidation evaluation male male male male male male male male male male male male male male male male male male male male male male
# s2s_loss 0.59662, 0.51 secs
# New checkpoint saved: checkpoint_26_s2s_loss=0.6257.pt
# ---- Epoch 27/60
# (1) Training stage (lr = 0.000002) ...
# loss 0.60747, s2s_loss 0.61126, 134.76 secs
# (2) Validation stage ...
# Random output:
# male COPD pneumonia new consolidation new male male male male male male male male male male male male male male male male male male male male male male male male male male male
# s2s_loss 0.59660, 0.52 secs
# New checkpoint saved: checkpoint_27_s2s_loss=0.6258.pt
# ---- Epoch 28/60
# (1) Training stage (lr = 0.000001) ...
# loss 0.48108, s2s_loss 0.60563, 141.35 secs
# (2) Validation stage ...
# Random output:
# female fever immunosuppressed rule out pneumonia female female female female female female female female female female female female female female female female female female female female female female female female female
# s2s_loss 0.59662, 0.60 secs
# New checkpoint saved: checkpoint_28_s2s_loss=0.6260.pt
# ---- Epoch 29/60
# (1) Training stage (lr = 0.000200) ...
# loss 0.46491, s2s_loss 0.60955, 133.24 secs
# (2) Validation stage ...
# Random output:
# male cough productive volume volume of volume stat rule out consolidation male male male male male male male male male male male male male male male male male male male male male male
# s2s_loss 0.57919, 0.58 secs
# New checkpoint saved: checkpoint_29_s2s_loss=0.6320.pt
# ---- Epoch 30/60
# (1) Training stage (lr = 0.000094) ...
# loss 0.64281, s2s_loss 0.57821, 127.64 secs
# (2) Validation stage ...
# Random output:
# male podtracheobrochoplasty podoperative day 3 interval change (no specific information provided) provided male male male male male male male male male male male male male
# s2s_loss 0.56595, 0.67 secs
# New checkpoint saved: checkpoint_30_s2s_loss=0.6381.pt
# ---- Epoch 31/60
# (1) Training stage (lr = 0.000044) ...
# loss 0.42584, s2s_loss 0.55405, 129.26 secs
# (2) Validation stage ...
# Random output:
# male SVT (  rate of to 180 degreesspm palpitations male male male male male male male male male male male male male male male male male male male
# s2s_loss 0.55847, 0.47 secs
# New checkpoint saved: checkpoint_31_s2s_loss=0.6418.pt
# ---- Epoch 32/60
# (1) Training stage (lr = 0.000021) ...
# loss 0.42322, s2s_loss 0.54096, 140.39 secs
# (2) Validation stage ...
# Random output:
# male historys/p LUL increasedL upper lobe) increased shortB congestionshortness of breath) congestion increased male male male male male male male male
# s2s_loss 0.55883, 0.54 secs
# New checkpoint saved: checkpoint_32_s2s_loss=0.6422.pt
# ---- Epoch 33/60
# (1) Training stage (lr = 0.000010) ...
# loss 0.48260, s2s_loss 0.53703, 147.75 secs
# (2) Validation stage ...
# Random output:
# male COPD pneumonia new consolidation new male male male male male male male male male male male male male male male male male male male male male male male male male male male
# s2s_loss 0.55879, 0.49 secs
# New checkpoint saved: checkpoint_33_s2s_loss=0.6424.pt
# ---- Epoch 34/60
# (1) Training stage (lr = 0.000005) ...
# loss 0.60394, s2s_loss 0.53982, 137.38 secs
# (2) Validation stage ...
# Random output:
# female M of Mral valve replacement went PA catheter placement in out pneu with to PA catheter placement female female female female female female female female female female female female female female
# s2s_loss 0.55807, 0.48 secs
# New checkpoint saved: checkpoint_34_s2s_loss=0.6426.pt
# ---- Epoch 35/60
# (1) Training stage (lr = 0.000002) ...
# loss 0.48403, s2s_loss 0.53498, 128.11 secs
# (2) Validation stage ...
# Random output:
# female postoperative day 0 placement of left Ommaya Reservoir history of pontine lesion le of leptomeng diseaseal disease rule for pneumonia
# s2s_loss 0.55743, 0.43 secs
# New checkpoint saved: checkpoint_35_s2s_loss=0.6430.pt
# ---- Epoch 36/60
# (1) Training stage (lr = 0.000001) ...
# loss 0.56670, s2s_loss 0.53284, 126.93 secs
# (2) Validation stage ...
# Random output:
# male satic AAA s/p e ( (-up CXR patient male male male male male male male male male male male male male male male
# s2s_loss 0.55738, 0.62 secs
# New checkpoint saved: checkpoint_36_s2s_loss=0.6431.pt
# ---- Epoch 37/60
# (1) Training stage (lr = 0.000200) ...
# loss 0.51567, s2s_loss 0.53765, 132.71 secs
# (2) Validation stage ...
# Random output:
# female sub of subaortic membrane resection sept of septal myomectomy assess for pleural effusions assessment for pneumothorax pneu
# s2s_loss 0.54700, 0.50 secs
# New checkpoint saved: checkpoint_37_s2s_loss=0.6468.pt
# ---- Epoch 38/60
# (1) Training stage (lr = 0.000094) ...
# loss 0.45904, s2s_loss 0.50894, 274.04 secs
# (2) Validation stage ...
# Random output:
# 3 weeks cough weakness recent drug rash history of SJS history out pneumoniaeosinophilic syndrome rule out viral syndrome out pneumonia viral 3 3 3
# s2s_loss 0.54036, 5.02 secs
# New checkpoint saved: checkpoint_38_s2s_loss=0.6506.pt
# ---- Epoch 39/60
# (1) Training stage (lr = 0.000044) ...
# loss 0.45818, s2s_loss 0.49365, 1437.12 secs
# (2) Validation stage ...
# Random output:
# SG position.d
# s2s_loss 0.53145, 4.95 secs
# New checkpoint saved: checkpoint_39_s2s_loss=0.6546.pt
# ---- Epoch 40/60
# (1) Training stage (lr = 0.000021) ...
# loss 0.38068, s2s_loss 0.47909, 167.15 secs
# (2) Validation stage ...
# Random output:
# male SVT (  rate of to 180 degreesspm palpitations male male male male male male male male male male male male male male male male male male male
# s2s_loss 0.53580, 0.35 secs
# ---- Epoch 41/60
# (1) Training stage (lr = 0.000010) ...
# loss 0.45010, s2s_loss 0.47620, 101.55 secs
# (2) Validation stage ...
# Random output:
# female seizures smallangular radiodense lesion seen on lateral viewd female female female female female female female female female female female female female female female female female
# s2s_loss 0.53430, 0.31 secs
# ---- Epoch 42/60
# (1) Training stage (lr = 0.000005) ...
# loss 0.66856, s2s_loss 0.47794, 101.36 secs
# (2) Validation stage ...
# Random output:
# short.d short short short short short short short short short short short short short short short short short short short short short short short short short short short short short short
# s2s_loss 0.53338, 0.34 secs
# ---- Epoch 43/60
# (1) Training stage (lr = 0.000002) ...
# loss 0.59075, s2s_loss 0.47685, 101.08 secs
# (2) Validation stage ...
# Random output:
# female history of subaortic membrane resection of of septal myomectomy assess for pleural effusions assessment for pneumothorax pneu
# s2s_loss 0.53350, 0.34 secs
# ---- Epoch 44/60
# (1) Training stage (lr = 0.000001) ...
# loss 0.41506, s2s_loss 0.47110, 101.98 secs
# (2) Validation stage ...
# Random output:
# Osteogenesis imperfecta Hypoxic episode evaluation for interval changed evaluation evaluation evaluation hypo hypo hypo osteo osteo osteo osteo osteo osteo osteo osteo osteo osteo osteo osteo Ost Ost
# s2s_loss 0.53315, 0.32 secs
# New checkpoint saved: checkpoint_44_s2s_loss=0.6550.pt
# ---- Epoch 45/60
# (1) Training stage (lr = 0.000200) ...
# loss 0.45563, s2s_loss 0.48427, 101.60 secs
# (2) Validation stage ...
# Random output:
# Desaturation statusparotomy TAH-BASO T Des Des Des Des Des Des Des Des Des Des Des Des Des Des Des Des Des Des Des Des
# s2s_loss 0.53319, 0.35 secs
# ---- Epoch 46/60
# (1) Training stage (lr = 0.000094) ...
# loss 0.38001, s2s_loss 0.46032, 100.54 secs
# (2) Validation stage ...
# Random output:
# male pulmonary edema CHF desaturation sedative medic ruled male male male male male male male male male male male male male male male male male male
# s2s_loss 0.52214, 0.36 secs
# New checkpoint saved: checkpoint_46_s2s_loss=0.6598.pt
# ---- Epoch 47/60
# (1) Training stage (lr = 0.000044) ...
# loss 0.44265, s2s_loss 0.44204, 102.23 secs
# (2) Validation stage ...
# Random output:
# female extensive cell start starting chemotherapy dropping oxygen saturation to 80s compare to recent imaging rule out pneumonia rule out new collapsed female female female female female female female female female female female
# s2s_loss 0.52023, 0.38 secs
# New checkpoint saved: checkpoint_47_s2s_loss=0.6614.pt
# ---- Epoch 48/60
# (1) Training stage (lr = 0.000021) ...
# loss 0.42040, s2s_loss 0.43309, 103.11 secs
# (2) Validation stage ...
# Random output:
# female worsening confusion lethargy female female female female female female female female female female female female female female female female female female female female female female female female female
# s2s_loss 0.52303, 0.34 secs
# ---- Epoch 49/60
# (1) Training stage (lr = 0.000010) ...
# loss 0.31161, s2s_loss 0.43168, 103.43 secs
# (2) Validation stage ...
# Random output:
# male satic AAA s/p evaluatione ( follow-up CXR follow male male male male male male male male male male male male male male male
# s2s_loss 0.52348, 0.35 secs
# ---- Epoch 50/60
# (1) Training stage (lr = 0.000005) ...
# loss 0.48978, s2s_loss 0.43011, 101.66 secs
# (2) Validation stage ...
# Random output:
# female history of subaortic membrane resection of of septal myomectomy assess for pleural effusions assessment for pneumothorax
# s2s_loss 0.52300, 0.37 secs
# ---- Epoch 51/60
# (1) Training stage (lr = 0.000002) ...
# loss 0.40385, s2s_loss 0.42944, 103.16 secs
# (2) Validation stage ...
# Random output:
# female postoperative day 0 placement of left Ommaya Reservoir history of pontine lesion le of leptomengial disease rule for pneumonia
# s2s_loss 0.52238, 0.33 secs
# ---- Epoch 52/60
# (1) Training stage (lr = 0.000001) ...
# loss 0.31275, s2s_loss 0.42715, 104.01 secs
# (2) Validation stage ...
# Random output:
# female postoperative day 0 placement of left Ommaya Reservoir history of pontine lesion le of leptomengial disease rule for pneumonia
# s2s_loss 0.52230, 0.35 secs
# ---- Epoch 53/60
# (1) Training stage (lr = 0.000200) ...
# loss 0.39086, s2s_loss 0.43753, 103.68 secs
# (2) Validation stage ...
# Random output:
# Desaturation statusparotomy TAH-BASO T Des Des Des Des Des Des Des Des Des Des Des Des Des Des Des Des Des Des Des Des
# s2s_loss 0.52828, 0.35 secs
# ---- Epoch 54/60
# (1) Training stage (lr = 0.000094) ...
# loss 0.46593, s2s_loss 0.41597, 103.65 secs
# (2) Validation stage ...
# Random output:
# female extensive cell starting starting chemotherapy dropping oxygen saturation to 80s rule to recent imaging rule out pneumonia rule out new collapsed female female female female female female female female female female female
# s2s_loss 0.52432, 0.33 secs
# ---- Epoch 55/60
# (1) Training stage (lr = 0.000044) ...
# loss 0.30862, s2s_loss 0.40313, 103.77 secs
# (2) Validation stage ...
# Random output:
# non-responsiveness syncope pain with breathing syn pain pain non non non non non non non non non non non non non non non non non non non non non
# s2s_loss 0.52392, 0.33 secs
# New checkpoint saved: checkpoint_55_s2s_loss=0.6619.pt
# ---- Epoch 56/60
# (1) Training stage (lr = 0.000021) ...
# loss 0.38005, s2s_loss 0.39244, 103.51 secs
# (2) Validation stage ...
# Random output:
# -ged scapula.d
# s2s_loss 0.52324, 0.36 secs
# New checkpoint saved: checkpoint_56_s2s_loss=0.6627.pt
# ---- Epoch 57/60
# (1) Training stage (lr = 0.000010) ...
# loss 0.35785, s2s_loss 0.39102, 103.79 secs
# (2) Validation stage ...
# Random output:
# female postoperative day 3 after aortic valve replacement effusion alectasisd female female female female female female female female female female female female female
# s2s_loss 0.52379, 0.34 secs
# ---- Epoch 58/60
# (1) Training stage (lr = 0.000005) ...
# loss 0.39864, s2s_loss 0.39145, 89.46 secs
# (2) Validation stage ...
# Random output:
# short  present.e short short short short short short short short short short short short short short short short short short short short short short short short short short short short short short
# s2s_loss 0.52248, 0.35 secs
# New checkpoint saved: checkpoint_58_s2s_loss=0.6630.pt
# ---- Epoch 59/60
# (1) Training stage (lr = 0.000002) ...
# loss 0.48770, s2s_loss 0.38771, 103.26 secs
# (2) Validation stage ...
# Random output:
# male cough productive  rule of volume stat rule out consolidation male male male male male male male male male male male male male male male male male male male male male male
# s2s_loss 0.52277, 0.33 secs
# New checkpoint saved: checkpoint_59_s2s_loss=0.6631.pt
# ---- Epoch 60/60
# (1) Training stage (lr = 0.000001) ...
# loss 0.38659, s2s_loss 0.38700, 103.69 secs
# (2) Validation stage ...
# Random output:
# male historyeth CIrhosis ascites hemochosis CAD pneupeptic ulcer dis evaluation liver transplant evaluation assess for cardiopulmonary abnormalities
# s2s_loss 0.52281, 0.35 secs
# New checkpoint saved: checkpoint_60_s2s_loss=0.6631.pt

# %%
# !python ../train_seq2seq.py \
        --checkpoint_folder "models/seq2seq/20230615_113851_background2facts(gpt-3.5-turbo_parsed_back)_Seq2Seq(t5-small)" \
        --epochs 60 \
        --batches_per_epoch 1000 \
        --batch_size 25 \
        --num_workers 2 \
        --iters_to_accumulate 4 \
        --use_amp \
        --save
# Out:
# script's arguments:
#    epochs: 60
#    batches_per_epoch: 1000
#    batch_size: 25
#    checkpoint_folder: models/seq2seq/20230615_113851_background2facts(gpt-3.5-turbo_parsed_back)_Seq2Seq(t5-small)
#    seq2seq_model_name: None
#    t5_model_name: t5-small
#    bart_model_name: facebook/bart-base
#    pretrained_checkpoint_folder_path: None
#    optimizer_name: adamw
#    lr: 0.001
#    scheduler: reduce-lr-on-plateau
#    lr_decay: 0.76
#    lr_decay_patience: 2
#    warmup_and_decay_args: None
#    warmup_and_cosine_args: None
#    warmup_decay_and_cyclic_decay_args: None
#    iters_to_accumulate: 4
#    override_lr: False
#    task_name: None
#    val_size: 200
#    input_output_jsonl_filepaths: None
#    num_workers: 2
#    device: GPU
#    use_amp: True
#    save: True
# ----- Resuming training ------
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/seq2seq/20230615_113851_background2facts(gpt-3.5-turbo_parsed_back)_Seq2Seq(t5-small)/metadata.json
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Creating instance of Seq2SeqModel ...
# Seq2Seq model:
#   model_name: t5-small
# --------------------------------------------------
# 3) Defining optimizer ...
# create_optimizer(): name = adamw
# --------------------------------------------------
# 4) Defining scheduler ...
# Using exp-warmup+decay+cyclicdecay scheduler: 1e-6,3,2e-4,8,1e-6,2e-4,8,1e-6
# 1e-06 3 0.0002 8 1e-06 0.0002 8 1e-06
# self.steps_to_restart = 8
# self.steps = -1
# self.initial_lr = 0.0002
# --------------------------------------------------
# 5) Creating trainer and validator engines ...
# GradientAccumulator.__init__(): num_accumulation_steps = 4
# --------------------------------------------------
# 6) Defining collate_batch_fn ...
# Loaded 20000 input/output pairs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo_parsed_backgrounds.jsonl
# Number of train examples: 19800
# Number of val examples: 200
# Number of total examples: 20000
# Input/output example:
# Input:
# indication: year old woman with left and 8th rib fractures s/p mechanical fall, head laceration, pyuria and positive nitrites on U/A, now with vomiting and inability to take POs since . // Evaluate for possible aspiration pneumonia/lung changes from CT on and portable chest XR on Evaluate for possible aspiration pneumonia/lung changes from CT on and portable chest XR on.
# Output:
# ["female", "left and 8th rib fractures", "mechanical fall", "head laceration", "pyuria", "positive nitrites on U/A", "vomiting", "unable to take POs", "rule out aspiration pneumonia/lung changes from CT", "rule out aspiration pneumonia/lung changes from portable chest XR"]
# seq2seq_trainer.name =  background2facts(gpt-3.5-turbo_parsed_back)
# --------------------------------------------------
# 7) Attaching metrics, losses, timer and events to engines ...
# --------------------------------------------------
# 8) Defining learning rate scheduler handler ...
# checkpoint_names = ['checkpoint_60_s2s_loss=0.6631.pt']
# --------------------------------------------------
# 9) Loading model from checkpoint ...
# checkpoint_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/seq2seq/20230615_113851_background2facts(gpt-3.5-turbo_parsed_back)_Seq2Seq(t5-small)/checkpoint_60_s2s_loss=0.6631.pt
# Checkpoint successfully loaded!
# --------------------------------------------------
# 10) Defining log_metrics_handler ...
# MetricsLogger :: we'll be logging to /mnt/data/pamessina/workspaces/medvqa-workspace/models/seq2seq/20230615_113851_background2facts(gpt-3.5-turbo_parsed_back)_Seq2Seq(t5-small)/metrics_logs.csv
# --------------------------------------------------
# 11) Running trainer engine ...
# ---- Epoch 61/120
# (1) Training stage (lr = 0.000200) ...
# loss 3.08669, s2s_loss 0.53819, 106.46 secs
# (2) Validation stage ...
# Random output:
# ["female", "postoperative day 3 after aortic valve replacement", "effusion",alectasis""] [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [
# s2s_loss 0.38682, 0.35 secs
# New checkpoint saved: checkpoint_61_s2s_loss=0.7140.pt
# ---- Epoch 62/120
# (1) Training stage (lr = 0.000094) ...
# loss 0.33688, s2s_loss 0.39554, 107.51 secs
# (2) Validation stage ...
# Random output:
# ["female", "postoperative day 0 placement "Lment of left Ommaya Reservoir", "history of pontine lesion", "letory of leptomengial disease", "evaluate for pneumonia"]
# s2s_loss 0.37366, 0.36 secs
# New checkpoint saved: checkpoint_62_s2s_loss=0.7268.pt
# ---- Epoch 63/120
# (1) Training stage (lr = 0.000044) ...
# loss 0.33447, s2s_loss 0.37524, 107.80 secs
# (2) Validation stage ...
# Random output:
# ["male", "COPD/ "Pneumonia", "new consolidation"] [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [
# s2s_loss 0.36838, 0.39 secs
# New checkpoint saved: checkpoint_63_s2s_loss=0.7304.pt
# ---- Epoch 64/120
# (1) Training stage (lr = 0.000021) ...
# loss 0.36818, s2s_loss 0.36573, 107.36 secs
# (2) Validation stage ...
# Random output:
# ["male", "pulmonary edema", "CHF", "desaturation", "sedative medic",] [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [
# s2s_loss 0.36504, 0.38 secs
# New checkpoint saved: checkpoint_64_s2s_loss=0.7325.pt
# ---- Epoch 65/120
# (1) Training stage (lr = 0.000010) ...
# loss 0.25290, s2s_loss 0.36023, 108.43 secs
# (2) Validation stage ...
# Random output:
# ["female", "postoperative day 3 after aortic valve replacement", "effusion",alectasis""] [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [
# s2s_loss 0.36367, 0.37 secs
# New checkpoint saved: checkpoint_65_s2s_loss=0.7335.pt
# ---- Epoch 66/120
# (1) Training stage (lr = 0.000005) ...
# loss 0.43286, s2s_loss 0.35821, 107.20 secs
# (2) Validation stage ...
# Random output:
# ["female", "postoperative day 0 placement "Lment of left Ommaya Reservoir", "history of pontine lesion", "letory of leptomengial disease", "evaluate for pneumonia"]
# s2s_loss 0.36294, 0.38 secs
# New checkpoint saved: checkpoint_66_s2s_loss=0.7340.pt
# ---- Epoch 67/120
# (1) Training stage (lr = 0.000002) ...
# loss 0.41462, s2s_loss 0.35797, 106.98 secs
# (2) Validation stage ...
# Random output:
# ["male", "satic AAA", "s/p e (", "follow-up CXR"] [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [
# s2s_loss 0.36279, 0.38 secs
# New checkpoint saved: checkpoint_67_s2s_loss=0.7340.pt
# ---- Epoch 68/120
# (1) Training stage (lr = 0.000001) ...
# loss 0.32123, s2s_loss 0.35698, 107.09 secs
# (2) Validation stage ...
# Random output:
# ["male", "pulmonary edema", "CHF", "desaturation", "sedative medic",] [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [
# s2s_loss 0.36274, 0.34 secs
# New checkpoint saved: checkpoint_68_s2s_loss=0.7341.pt
# ---- Epoch 69/120
# (1) Training stage (lr = 0.000200) ...
# loss 0.33075, s2s_loss 0.35229, 108.18 secs
# (2) Validation stage ...
# Random output:
# ["female", "worsening confusion", "lethargy"] [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [
# s2s_loss 0.35162, 0.36 secs
# New checkpoint saved: checkpoint_69_s2s_loss=0.7398.pt
# ---- Epoch 70/120
# (1) Training stage (lr = 0.000094) ...
# loss 0.38508, s2s_loss 0.32685, 106.25 secs
# (2) Validation stage ...
# Random output:
# ["s "."] ( [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [
# s2s_loss 0.34384, 0.35 secs
# New checkpoint saved: checkpoint_70_s2s_loss=0.7451.pt
# ---- Epoch 71/120
# (1) Training stage (lr = 0.000044) ...
# loss 0.29443, s2s_loss 0.31461, 106.32 secs
# (2) Validation stage ...
# Random output:
# ["non-responsiveness", "syncope", "pain with breathing"]t [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [
# s2s_loss 0.34074, 0.35 secs
# New checkpoint saved: checkpoint_71_s2s_loss=0.7473.pt
# ---- Epoch 72/120
# (1) Training stage (lr = 0.000021) ...
# loss 0.39008, s2s_loss 0.30649, 108.34 secs
# (2) Validation stage ...
# Random output:
# ["Winight ged scapula."]d [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [
# s2s_loss 0.34118, 0.38 secs
# New checkpoint saved: checkpoint_72_s2s_loss=0.7476.pt
# ---- Epoch 73/120
# (1) Training stage (lr = 0.000010) ...
# loss 0.27004, s2s_loss 0.30345, 107.22 secs
# (2) Validation stage ...
# Random output:
# ["female", "seizures", "smallangular radiodense lesion seen "smallei on lateral view only"]d [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [
# s2s_loss 0.34067, 0.38 secs
# New checkpoint saved: checkpoint_73_s2s_loss=0.7480.pt
# ---- Epoch 74/120
# (1) Training stage (lr = 0.000005) ...
# loss 0.35131, s2s_loss 0.30354, 107.53 secs
# (2) Validation stage ...
# Random output:
# ["female", "postoperative day 3 after aortic valve replacement", "effusion",alectasis""] [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [
# s2s_loss 0.34046, 0.36 secs
# New checkpoint saved: checkpoint_74_s2s_loss=0.7481.pt
# ---- Epoch 75/120
# (1) Training stage (lr = 0.000002) ...
# loss 0.42736, s2s_loss 0.30324, 106.73 secs
# (2) Validation stage ...
# Random output:
# ["female", "retory of subaortic membrane andresection", "history of septal myomectomy", "assess for for pleural effusions", "assess for for pneumothorax"]
# s2s_loss 0.34043, 0.36 secs
# New checkpoint saved: checkpoint_75_s2s_loss=0.7482.pt
# ---- Epoch 76/120
# (1) Training stage (lr = 0.000001) ...
# loss 0.42088, s2s_loss 0.30226, 108.14 secs
# (2) Validation stage ...
# Random output:
# ["dessaturation", "Laparotomy", "TH-BASO"] [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [
# s2s_loss 0.34039, 0.36 secs
# New checkpoint saved: checkpoint_76_s2s_loss=0.7482.pt
# ---- Epoch 77/120
# (1) Training stage (lr = 0.000200) ...
# loss 0.29104, s2s_loss 0.30472, 108.36 secs
# (2) Validation stage ...
# Random output:
# ["throt pain", "back pain" "throbbing"] [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [
# s2s_loss 0.33429, 0.35 secs
# New checkpoint saved: checkpoint_77_s2s_loss=0.7512.pt
# ---- Epoch 78/120
# (1) Training stage (lr = 0.000094) ...
# loss 0.25734, s2s_loss 0.28809, 106.52 secs
# (2) Validation stage ...
# Random output:
# ["female", "fever", "immunosuppressed", "rule out pneumonia"] [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [
# s2s_loss 0.33381, 0.33 secs
# New checkpoint saved: checkpoint_78_s2s_loss=0.7524.pt
# ---- Epoch 79/120
# (1) Training stage (lr = 0.000044) ...
# loss 0.22165, s2s_loss 0.27692, 108.27 secs
# (2) Validation stage ...
# Random output:
# ["male", "satic AAA", "post/p eAR", "follow-up CXR"] [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [
# s2s_loss 0.33276, 0.35 secs
# New checkpoint saved: checkpoint_79_s2s_loss=0.7536.pt
# ---- Epoch 80/120
# (1) Training stage (lr = 0.000021) ...
# loss 0.26772, s2s_loss 0.27064, 108.56 secs
# (2) Validation stage ...
# Random output:
# ["female", "postoperative day 3 after aortic valve replacement", "effusion",alectasis""] [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [
# s2s_loss 0.33269, 0.35 secs
# New checkpoint saved: checkpoint_80_s2s_loss=0.7540.pt
# ---- Epoch 81/120
# (1) Training stage (lr = 0.000010) ...
# loss 0.30289, s2s_loss 0.26671, 106.60 secs
# (2) Validation stage ...
# Random output:
# ["SG position"] [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [
# s2s_loss 0.33184, 0.34 secs
# New checkpoint saved: checkpoint_81_s2s_loss=0.7547.pt
# ---- Epoch 82/120
# (1) Training stage (lr = 0.000005) ...
# loss 0.26318, s2s_loss 0.26769, 108.12 secs
# (2) Validation stage ...
# Random output:
# ["male", "SVT ( pal rate in to 180sspm", "palpitations"] [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [
# s2s_loss 0.33194, 0.37 secs
# ---- Epoch 83/120
# (1) Training stage (lr = 0.000002) ...
# loss 0.32452, s2s_loss 0.26732, 107.75 secs
# (2) Validation stage ...
# Random output:
# ["female", "postoperative day 3 after aortic valve replacement", "effusion",alectasis""] [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [
# s2s_loss 0.33200, 0.39 secs
# ---- Epoch 84/120
# (1) Training stage (lr = 0.000001) ...
# loss 0.31257, s2s_loss 0.26603, 108.67 secs
# (2) Validation stage ...
# Random output:
# ["Osteogenesis imperfecta", "hypoxic episode", "evaluation for interval change"] [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [
# s2s_loss 0.33198, 0.39 secs
# ---- Epoch 85/120
# (1) Training stage (lr = 0.000200) ...
# loss 0.27144, s2s_loss 0.27044, 107.24 secs
# (2) Validation stage ...
# Random output:
# ["female", "seizures", "smallangular radiodense lesion seen "presentei on lateral view only"]d [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [
# s2s_loss 0.33673, 0.37 secs
# ---- Epoch 86/120
# (1) Training stage (lr = 0.000094) ...
# loss 0.27317, s2s_loss 0.25862, 106.98 secs
# (2) Validation stage ...
# Random output:
# ["male", "histh CIrhosis", "ascites", "heochroosis", "cor", "pEP ulcer disease", "e liver transplant evaluation", "assess for cardiopulmonary abnormalities"]
# s2s_loss 0.32728, 0.36 secs
# New checkpoint saved: checkpoint_86_s2s_loss=0.7575.pt
# ---- Epoch 87/120
# (1) Training stage (lr = 0.000044) ...
# loss 0.30836, s2s_loss 0.24930, 106.51 secs
# (2) Validation stage ...
# Random output:
# ["female", "fever", "immunosuppressed", "rule out pneumonia"] [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [
# s2s_loss 0.32513, 0.34 secs
# New checkpoint saved: checkpoint_87_s2s_loss=0.7592.pt
# ---- Epoch 88/120
# (1) Training stage (lr = 0.000021) ...
# loss 0.22317, s2s_loss 0.24200, 107.83 secs
# (2) Validation stage ...
# Random output:
# ["non-responsiveness", "syncope", "pain with breathing"]t [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [
# s2s_loss 0.32670, 0.39 secs
# ---- Epoch 89/120
# (1) Training stage (lr = 0.000010) ...
# loss 0.18405, s2s_loss 0.23964, 108.40 secs
# (2) Validation stage ...
# Random output:
# ["female", "undertory of subaortic membrane andresection", "history of septal myomectomy", "assess for for pleural effusions", "assessment for pneumothorax"]
# s2s_loss 0.32694, 0.40 secs
# ---- Epoch 90/120
# (1) Training stage (lr = 0.000005) ...
# loss 0.20351, s2s_loss 0.24137, 108.81 secs
# (2) Validation stage ...
# Random output:
# ["dessaturation", "Laparotomy", "TH-BASO"] [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [
# s2s_loss 0.32637, 0.35 secs
# ---- Epoch 91/120
# (1) Training stage (lr = 0.000002) ...
# loss 0.21173, s2s_loss 0.24052, 108.28 secs
# (2) Validation stage ...
# Random output:
# ["male", "COPD", "pneumonia", "new consolidation"] [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [
# s2s_loss 0.32654, 0.39 secs
# ---- Epoch 92/120
# (1) Training stage (lr = 0.000001) ...
# loss 0.19535, s2s_loss 0.23753, 107.89 secs
# (2) Validation stage ...
# Random output:
# ["male", "his/p LUL",left upper lobe)", "increased shortB",shortness of breath)", "congestion"] [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [
# s2s_loss 0.32648, 0.34 secs
# New checkpoint saved: checkpoint_92_s2s_loss=0.7593.pt
# ---- Epoch 93/120
# (1) Training stage (lr = 0.000200) ...
# loss 0.26544, s2s_loss 0.24510, 107.77 secs
# (2) Validation stage ...
# Random output:
# ["male", "pulmonary edema", "CHF", "desaturation", "sedative medic",] [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [
# s2s_loss 0.33169, 0.35 secs
# ---- Epoch 94/120
# (1) Training stage (lr = 0.000094) ...
# loss 0.31947, s2s_loss 0.23407, 107.71 secs
# (2) Validation stage ...
# Random output:
# ["Winight ged scapula."]d [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [
# s2s_loss 0.32885, 0.36 secs
# ---- Epoch 95/120
# (1) Training stage (lr = 0.000044) ...
# loss 0.20814, s2s_loss 0.22627, 108.56 secs
# (2) Validation stage ...
# Random output:
# ["female", "undertory of subaortic membrane resection", "history of septal myomectomy", "assess for for pleural effusions", "assessment for pneumothorax"]
# s2s_loss 0.32735, 0.34 secs
# New checkpoint saved: checkpoint_95_s2s_loss=0.7596.pt
# ---- Epoch 96/120
# (1) Training stage (lr = 0.000021) ...
# loss 0.24501, s2s_loss 0.21986, 108.81 secs
# (2) Validation stage ...
# Random output:
# ["female", "ext cell",", "starting chemotherapy", "dropping oxygen saturation to 80s", "compare to recent imaging", "rule out pneumonia", "rule out new collapse"] [ [ [ [ [ [ [ [
# s2s_loss 0.32742, 0.37 secs
# New checkpoint saved: checkpoint_96_s2s_loss=0.7600.pt
# ---- Epoch 97/120
# (1) Training stage (lr = 0.000010) ...
# loss 0.23295, s2s_loss 0.21885, 107.07 secs
# (2) Validation stage ...
# Random output:
# ["female", "nausea", "vomiting", "lightheadedness", "rule out pneumonia", "rule out pleural infection"] [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [
# s2s_loss 0.32778, 0.36 secs
# ---- Epoch 98/120
# (1) Training stage (lr = 0.000005) ...
# loss 0.22386, s2s_loss 0.21887, 108.11 secs
# (2) Validation stage ...
# Random output:
# ["female", "Mtory of Mral valve replacement", "hiswent PA catheter placement", "enge out  with to PA catheter placement"] [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [
# s2s_loss 0.32772, 0.36 secs
# ---- Epoch 99/120
# (1) Training stage (lr = 0.000002) ...
# loss 0.31293, s2s_loss 0.21839, 108.71 secs
# (2) Validation stage ...
# Random output:
# ["male", "his/p LUL",left upper lobe)", "increased shortB",shortness of breath)", "congestion"] [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [
# s2s_loss 0.32789, 0.37 secs
# ---- Epoch 100/120
# (1) Training stage (lr = 0.000001) ...
# loss 0.14272, s2s_loss 0.21537, 106.78 secs
# (2) Validation stage ...
# Random output:
# ["female", "seizures", "smallangular radiodense lesion seen "presentei on lateral view only"]d [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [
# s2s_loss 0.32800, 0.35 secs
# New checkpoint saved: checkpoint_100_s2s_loss=0.7600.pt
# ---- Epoch 101/120
# (1) Training stage (lr = 0.000200) ...
# loss 0.15387, s2s_loss 0.22358, 108.62 secs
# (2) Validation stage ...
# Random output:
# ["male", "s/p LUL",left upper lobe)", "increased shortB (shortness of breath)", "congestion"] [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [
# s2s_loss 0.32721, 0.35 secs
# ---- Epoch 102/120
# (1) Training stage (lr = 0.000094) ...
# loss 0.27146, s2s_loss 0.21407, 107.62 secs
# (2) Validation stage ...
# Random output:
# ["female", "postoperative day 0", "Lment of L Ommaya Reservoir", "history of pontine lesion", "letory of leptomengial disease", "evaluate for pneumonia"]
# s2s_loss 0.32100, 0.39 secs
# New checkpoint saved: checkpoint_102_s2s_loss=0.7637.pt
# ---- Epoch 103/120
# (1) Training stage (lr = 0.000044) ...
# loss 0.20354, s2s_loss 0.20692, 108.48 secs
# (2) Validation stage ...
# Random output:
# ["dessaturation", "Laparotomy", "TH-BASO"] [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [
# s2s_loss 0.32397, 0.35 secs
# ---- Epoch 104/120
# (1) Training stage (lr = 0.000021) ...
# loss 0.14376, s2s_loss 0.19956, 106.67 secs
# (2) Validation stage ...
# Random output:
# ["male", "COPD", "pneumonia", "new consolidation"] [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [
# s2s_loss 0.32535, 0.35 secs
# ---- Epoch 105/120
# (1) Training stage (lr = 0.000010) ...
# loss 0.19415, s2s_loss 0.20012, 108.77 secs
# (2) Validation stage ...
# Random output:
# ["throt pain", "back pain" "throbbing"] [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [
# s2s_loss 0.32589, 0.40 secs
# ---- Epoch 106/120
# (1) Training stage (lr = 0.000005) ...
# loss 0.19555, s2s_loss 0.20109, 108.00 secs
# (2) Validation stage ...
# Random output:
# ["non-responsiveness", "syncope", "pain with breathing"]t [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [
# s2s_loss 0.32571, 0.37 secs
# ---- Epoch 107/120
# (1) Training stage (lr = 0.000002) ...
# loss 0.19185, s2s_loss 0.19930, 109.40 secs
# (2) Validation stage ...
# Random output:
# ["female", "postoperative day 0", "placement of left Ommaya Reservoir", "history of pontine lesion", "letory of leptomengial disease", "evaluate for pneumonia"]
# s2s_loss 0.32559, 0.35 secs
# ---- Epoch 108/120
# (1) Training stage (lr = 0.000001) ...
# loss 0.15973, s2s_loss 0.19777, 109.36 secs
# (2) Validation stage ...
# Random output:
# ["female", "postoperative day 3 after aortic valve replacement", "effusion",alectasis""] [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [
# s2s_loss 0.32575, 0.38 secs
# ---- Epoch 109/120
# (1) Training stage (lr = 0.000200) ...
# loss 0.23290, s2s_loss 0.20552, 106.26 secs
# (2) Validation stage ...
# Random output:
# ["male", "cough", "productive",", "evidation of volume stat", "rule out consolidation"] [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [
# s2s_loss 0.32882, 0.38 secs
# ---- Epoch 110/120
# (1) Training stage (lr = 0.000094) ...
# loss 0.26229, s2s_loss 0.19806, 107.76 secs
# (2) Validation stage ...
# Random output:
# ["male", "his/p LUL (left upper lobe)", "increased shortB",shortness of breath)", "congestion"] [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [
# s2s_loss 0.32441, 0.34 secs
# ---- Epoch 111/120
# (1) Training stage (lr = 0.000044) ...
# loss 0.21805, s2s_loss 0.18999, 107.62 secs
# (2) Validation stage ...
# Random output:
# ["female", "undertory of subaortic membrane resection", "history of septal myomectomy", "assess for for pleural effusions", "assessment for pneumothorax"]
# s2s_loss 0.32613, 0.36 secs
# ---- Epoch 112/120
# (1) Training stage (lr = 0.000021) ...
# loss 0.14014, s2s_loss 0.18432, 106.28 secs
# (2) Validation stage ...
# Random output:
# ["female", "nausea", "vomiting", "lightheadedness", "rule out pneumonia", "rule out pleural infection"] [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [
# s2s_loss 0.32847, 0.40 secs
# ---- Epoch 113/120
# (1) Training stage (lr = 0.000010) ...
# loss 0.18995, s2s_loss 0.18379, 108.48 secs
# (2) Validation stage ...
# Random output:
# ["female", "ext cell",", "starting chemotherapy", "dropping oxygen saturation to 80s", "compare to recent imaging", "rule out pneumonia", "rule out new collapse"] [ [ [ [ [ [ [ [
# s2s_loss 0.32863, 0.35 secs
# ---- Epoch 114/120
# (1) Training stage (lr = 0.000005) ...
# loss 0.15437, s2s_loss 0.18443, 108.14 secs
# (2) Validation stage ...
# Random output:
# ["s."."] [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [
# s2s_loss 0.32853, 0.34 secs
# ---- Epoch 115/120
# (1) Training stage (lr = 0.000002) ...
# loss 0.20669, s2s_loss 0.18241, 109.48 secs
# (2) Validation stage ...
# Random output:
# ["male", "SVT ( pal rate in to 180sbpm", "palpitations"] [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [
# s2s_loss 0.32853, 0.38 secs
# ---- Epoch 116/120
# (1) Training stage (lr = 0.000001) ...
# loss 0.25598, s2s_loss 0.18146, 109.59 secs
# (2) Validation stage ...
# Random output:
# ["female", "fever", "immunosuppressed", "rule out pneumonia"] [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [
# s2s_loss 0.32858, 0.36 secs
# ---- Epoch 117/120
# (1) Training stage (lr = 0.000200) ...
# loss 0.13465, s2s_loss 0.19025, 109.58 secs
# (2) Validation stage ...
# Random output:
# ["male", "COPD", "pneumonia", "new consolidation"] [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [
# s2s_loss 0.33231, 0.35 secs
# ---- Epoch 118/120
# (1) Training stage (lr = 0.000094) ...
# loss 0.18852, s2s_loss 0.18351, 108.93 secs
# (2) Validation stage ...
# Random output:
# ["female", "Mtory of Mral valve replacement", "hiswent PA catheter placement", "enge out  related to PA catheter placement"] [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [
# s2s_loss 0.33107, 0.36 secs
# ---- Epoch 119/120
# (1) Training stage (lr = 0.000044) ...
# loss 0.15537, s2s_loss 0.17551, 107.63 secs
# (2) Validation stage ...
# Random output:
# ["male", "postheobrochoplasty", "postoperative day 3", "interval change (no specific information provided)"] [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [
# s2s_loss 0.32912, 0.35 secs
# ---- Epoch 120/120
# (1) Training stage (lr = 0.000021) ...
# loss 0.15549, s2s_loss 0.17019, 108.58 secs
# (2) Validation stage ...
# Random output:
# ["male", "cough", "productive",", "evidation of volume stat", "rule out consolidation"] [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [ [
# s2s_loss 0.33079, 0.36 secs
