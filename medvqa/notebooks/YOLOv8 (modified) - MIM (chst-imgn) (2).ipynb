# %%
# %env CUDA_VISIBLE_DEVICES=1
# Out:
# env: CUDA_VISIBLE_DEVICES=1

# %%
# !/home/pamessina/venv2/bin/python ../train_visual_module.py \
    --epochs 40 \
    --batches-per-epoch 300 \
    --batch-size 60 \
    --num-workers 3 \
    --iters-to-accumulate 4 \
    --optimizer-name "adamw" \
    --scheduler "exp-warmup+decay+cyclicdecay" \
    --lr 1e-6 \
    --warmup-decay-and-cyclic-decay-args "1e-6,5,4e-4,10,1e-6,2e-5,8,1e-6" \
    --use-mimiccxr \
    --mimiccxr-weight 1.0 \
    --mimiccxr-view-mode "chest_imagenome" \
    --mimiccxr-balanced-sampling-mode "balanced_chest_imagenome_global_labels_batchwise" \
    --use-chest-imagenome-decent-images-only \
    --classify-chest-imagenome \
    --chest-imagenome-label-names-filename "labels(min_freq=1000).pkl" \
    --chest-imagenome-labels-filename "imageId2labels(min_freq=1000).pkl" \
    --predict-bboxes-chest-imagenome \
    --chest-imagenome-mlc-version "v1" \
    --clamp-bboxes-chest-imagenome \
    --binary-loss-name "wbce-c" \
    --raw-image-encoding "yolov8" \
    --yolov8-model-name-or-path "/home/pamessina/medvqa-workspace/cache/chest_imagenome/train4/weights/best.pt" \
    --yolov8-model-alias "yolov8l" \
    --image-size 416 416 \
    --image-local-feat-size 512 \
    --num-regions 169 \
    --img-aug-mode "random-spatial" \
    --use-amp \
    --save
# Out:
# script's arguments:
#    epochs: 40
#    batches_per_epoch: 300
#    checkpoint_folder: None
#    visual_input_mode: raw-image
#    raw_image_encoding: yolov8
#    image_local_feat_size: 512
#    image_encoder_pretrained_weights_path: None
#    freeze_image_encoder: False
#    imagenet_pretrained: False
#    visual_features_mlp_in_dim: None
#    visual_features_mlp_out_dim: None
#    visual_features_mlp_hidden_dims: None
#    iuxray_precomputed_visual_features_path: None
#    mimiccxr_precomputed_visual_features_path: None
#    chexpert_precomputed_visual_features_path: None
#    vinbig_precomputed_visual_features_path: None
#    clip_version: None
#    huggingface_model_name: None
#    chest_imagenome_bbox_hidden_size: 128
#    chest_imagenome_bbox_regressor_version: None
#    chest_imagenome_mlc_version: v1
#    chest_imagenome_mlc_hidden_size: 128
#    torchxrayvision_weights_name: None
#    detectron2_model_yaml: None
#    num_regions: 169
# ...

# %%
# !/home/pamessina/venv2/bin/python ../train_visual_module.py \
    --pretrained-checkpoint-folder-path "/mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230407_042934_mim_yolov8l" \
    --epochs 40 \
    --batches-per-epoch 300 \
    --batch-size 60 \
    --num-workers 3 \
    --iters-to-accumulate 4 \
    --optimizer-name "adamw" \
    --scheduler "exp-warmup+decay+cyclicdecay" \
    --lr 1e-6 \
    --warmup-decay-and-cyclic-decay-args "1e-6,5,1e-4,10,1e-6,2e-5,8,1e-6" \
    --use-mimiccxr \
    --mimiccxr-weight 1.0 \
    --mimiccxr-view-mode "chest_imagenome" \
    --mimiccxr-balanced-sampling-mode "balanced_chest_imagenome_global_labels_batchwise" \
    --use-chest-imagenome-decent-images-only \
    --classify-chest-imagenome \
    --chest-imagenome-label-names-filename "labels(min_freq=1000).pkl" \
    --chest-imagenome-labels-filename "imageId2labels(min_freq=1000).pkl" \
    --predict-bboxes-chest-imagenome \
    --chest-imagenome-mlc-version "v1" \
    --clamp-bboxes-chest-imagenome \
    --binary-loss-name "focal+bce+wbce-c" \
    --raw-image-encoding "yolov8" \
    --yolov8-model-name-or-path "/home/pamessina/medvqa-workspace/cache/chest_imagenome/train4/weights/best.pt" \
    --yolov8-model-alias "yolov8l" \
    --image-size 416 416 \
    --image-local-feat-size 512 \
    --num-regions 169 \
    --use-amp \
    --save
# Out:
# script's arguments:
#    epochs: 40
#    batches_per_epoch: 300
#    checkpoint_folder: None
#    visual_input_mode: raw-image
#    raw_image_encoding: yolov8
#    image_local_feat_size: 512
#    image_encoder_pretrained_weights_path: None
#    freeze_image_encoder: False
#    imagenet_pretrained: False
#    visual_features_mlp_in_dim: None
#    visual_features_mlp_out_dim: None
#    visual_features_mlp_hidden_dims: None
#    iuxray_precomputed_visual_features_path: None
#    mimiccxr_precomputed_visual_features_path: None
#    chexpert_precomputed_visual_features_path: None
#    vinbig_precomputed_visual_features_path: None
#    clip_version: None
#    huggingface_model_name: None
#    chest_imagenome_bbox_hidden_size: 128
#    chest_imagenome_bbox_regressor_version: None
#    chest_imagenome_mlc_version: v1
#    chest_imagenome_mlc_hidden_size: 128
#    torchxrayvision_weights_name: None
#    detectron2_model_yaml: None
#    num_regions: 169
# ...
