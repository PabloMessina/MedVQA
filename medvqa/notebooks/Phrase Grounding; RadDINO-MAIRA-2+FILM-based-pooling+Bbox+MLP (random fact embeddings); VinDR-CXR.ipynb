# %%
# %env CUDA_VISIBLE_DEVICES=2
# Out:
# env: CUDA_VISIBLE_DEVICES=2

# %%
# !python ../train_phrase_grounding.py \
--epochs 100 \
--batches_per_epoch 1000 \
--max_images_per_batch 6 \
--max_phrases_per_batch 1000 \
--max_phrases_per_image 45 \
--val_batch_size_factor 4 \
--raw_image_encoding "rad-dino-huggingface" \
--huggingface_model_name "microsoft/rad-dino-maira-2" \
--image_size 416 416 \
--image_local_feat_size 768 \
--num_regions 841 \
--regions_width 29 \
--regions_height 29 \
--img_aug_mode "random-color-and-spatial" \
--phrase_embedding_size 128 \
--phrase_grounding_mode "adaptive_film_based_pooling_mlp_with_bbox_regression" \
--phrase_mlp_hidden_dims 256 128 \
--visual_grounding_hidden_size 256 \
--num_train_workers 2 \
--num_val_workers 2 \
--gradient_accumulation_steps 5 \
--optimizer_name "adamw" \
--scheduler "exp-warmup+decay+cyclicdecay" \
--lr 1e-6 \
--warmup_decay_and_cyclic_decay_args "1e-6,3,8e-5,5,1e-6,8e-5,5,1e-6" \
--binary_multilabel_classif_loss_name "focal+bce+npbbce" \
--do_visual_grounding_with_bbox_regression \
--use_vinbig_for_train \
--use_vinbig_for_test \
--vinbig_phrase_embeddings_filepath \
"/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/vinbig/label_phrase_embeddings(hash=353,2491289492560726319).pkl" \
--replace_phrase_embeddings_with_random_vectors \
--use_amp \
--save
# Out:
# script's arguments:
#    epochs: 100
#    batches_per_epoch: 1000
#    max_images_per_batch: 6
#    max_phrases_per_batch: 1000
#    max_phrases_per_image: 45
#    val_batch_size_factor: 4.0
#    checkpoint_folder: None
#    pretrained_checkpoint_folder_path: None
#    pretrained_checkpoint_folder_paths: None
#    freeze_image_encoder: False
#    raw_image_encoding: rad-dino-huggingface
#    huggingface_model_name: microsoft/rad-dino-maira-2
#    num_regions: 841
#    image_local_feat_size: 768
#    image_encoder_pretrained_weights_path: None
#    image_encoder_dropout_p: 0
#    yolov8_model_name_or_path: None
#    yolov8_model_alias: None
#    phrase_embedding_size: 128
#    regions_width: 29
#    regions_height: 29
#    qkv_size: None
#    phrase_grounding_mode: adaptive_film_based_pooling_mlp_with_bbox_regression
#    phrase_classifier_hidden_size: None
#    transf_d_model: None
#    transf_nhead: None
#    transf_dim_feedforward: None
#    transf_dropout: 0
#    transf_num_layers: None
#    visual_feature_proj_size: None
#    visual_grounding_hidden_size: 256
#    phrase_mlp_hidden_dims: [256, 128]
#    predict_global_alignment: False
#    alignment_proj_size: None
#    yolov11_model_name_or_path: None
#    yolov11_model_alias: None
#    optimizer_name: adamw
#    lr: 1e-06
#    scheduler: exp-warmup+decay+cyclicdecay
#    lr_decay: 0.76
#    lr_decay_patience: 2
#    warmup_and_decay_args: None
#    warmup_and_cosine_args: None
#    warmup_decay_and_cyclic_decay_args: 1e-6,3,8e-5,5,1e-6,8e-5,5,1e-6
#    gradient_accumulation_steps: 5
#    override_lr: False
#    max_grad_norm: None
#    attention_supervision_loss_weight: 1.0
#    phrase_classifier_loss_weight: 1.0
#    foreground_loss_weight: 1.0
#    background_loss_weight: 1.0
#    focal_loss_weight: 1.0
#    bce_loss_weight: 1.0
#    wbce_loss_weight: 1.0
#    binary_multilabel_classif_loss_name: focal+bce+npbbce
#    use_weighted_phrase_classifier_loss: False
#    cluster_and_label_weights_for_facts_filepath: None
#    use_attention_regularization_loss: False
#    use_contrastive_phrase_grounding_loss: False
#    nt_xent_temperature: 0.1
#    num_train_workers: 2
#    num_val_workers: 2
#    device: GPU
#    use_amp: True
#    image_size: [416, 416]
#    dicom_id_to_pos_neg_facts_filepath: None
#    iuxray_image_id_to_pos_neg_facts_filepath: None
#    mscxr_phrase2embedding_filepath: None
#    chest_imagenome_bbox_phrase_embeddings_filepath: None
#    vinbig_phrase_embeddings_filepath: /mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/vinbig/label_phrase_embeddings(hash=353,2491289492560726319).pkl
#    chexlocalize_class_phrase_embeddings_filepath: None
#    chexpert_class_phrase_embeddings_filepath: None
#    mimiccxr_exclude_noisy_images: False
#    mimiccxr_facts_weight: 1.0
#    chest_imagenome_anatlocs_weight: 1.0
#    mscxr_weight: 1.0
#    cxrlt2024_weight: 1.0
#    vinbig_weight: 1.0
#    chexlocalize_weight: 1.0
#    chexpert_weight: 1.0
#    iuxray_weight: 1.0
#    img_aug_mode: random-color-and-spatial
#    pos_area_prior: 0.4
#    neg_area_prior: 0.0
#    use_mimiccxr_facts_for_train: False
#    use_mimiccxr_facts_for_test: False
#    use_mscxr_for_train: False
#    use_mscxr_for_test: False
#    use_chest_imagenome_for_train: False
#    use_chest_imagenome_gold_for_test: False
#    use_vinbig_for_train: True
#    use_vinbig_for_test: True
#    use_chexlocalize_for_train: False
#    use_chexlocalize_for_test: False
#    use_chexpert_for_train: False
#    use_chexpert_for_test: False
#    use_iuxray_for_train: False
#    use_iuxray_for_test: False
#    use_cxrlt2024_challenge_split: False
#    use_cxrlt2024_custom_labels: False
#    use_cxrlt2024_official_labels: False
#    use_all_cxrlt2024_official_labels_for_training: False
#    vinbig_training_data_mode: train
#    chexpert_training_data_mode: all
#    mimiccxr_balance_long_middle_short_tail: False
#    mimiccxr_long_middle_short_tail_thresholds: (0.02, 0.05)
#    mimiccxr_report_fact_nli_integrated_data_filepath: None
#    mimiccxr_use_interpret_cxr_challenge_split: False
#    mimiccxr_interpret_cxr_challenge_split_filepath: None
#    iuxray_use_interpret_cxr_challenge_split: False
#    iuxray_interpret_cxr_challenge_split_filepath: None
#    chexpert_use_interpret_cxr_challenge_split: False
#    chexpert_interpret_cxr_challenge_split_filepath: None
#    chexlocalize_use_interpret_cxr_challenge_split: False
#    chexlocalize_interpret_cxr_challenge_split_filepath: None
#    cxrlt2024_custom_dicom_id_to_pos_neg_facts_filepath: None
#    cxrlt2024_official_training_labels_for_fact_classification_filepath: None
#    cxrlt2024_do_balanced_sampling: False
#    do_visual_grounding_with_bbox_regression: True
#    do_visual_grounding_with_segmentation: False
#    replace_phrase_embeddings_with_random_vectors: True
#    save: True
# ----- Training model from scratch ------
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Creating instance of PhraseGrounder ...
# WARNING: Unused kwargs: {'pretrained_checkpoint_folder_path': None, 'pretrained_checkpoint_folder_paths': None}
# MultiPurposeVisualModule()
#   Initializing raw_image_encoder: rad-dino-huggingface
#   self.global_feat_size = 768
#   self.local_feat_size = 768
#   Initializing auxiliary tasks
# BoundingBoxRegressorSingleClass
#   local_feat_dim: 256
# --------------------------------------------------
# 3) Defining optimizer ...
# create_optimizer(): name = adamw
# --------------------------------------------------
# 4) Defining scheduler ...
# Using exp-warmup+decay+cyclicdecay scheduler: 1e-6,3,8e-5,5,1e-6,8e-5,5,1e-6
# 1e-06 3 8e-05 5 1e-06 8e-05 5 1e-06
# self.steps_to_restart = 5
# self.steps = -1
# self.initial_lr = 8e-05
# --------------------------------------------------
# 5) Creating trainer and validator engines ...
# Focal_BCE_NPBBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 npbbce_weight = 0.3333333333333333
# Focal_BCE_NPBBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 npbbce_weight = 0.3333333333333333
# Focal_BCE_WBCBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 wbcbce_weight = 0.3333333333333333
# foreground_loss_weight: 1.0
# background_loss_weight: 1.0
# GradientAccumulator.__init__(): num_accumulation_steps = 5, max_grad_norm = None
# Focal_BCE_NPBBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 npbbce_weight = 0.3333333333333333
# Focal_BCE_NPBBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 npbbce_weight = 0.3333333333333333
# Focal_BCE_WBCBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 wbcbce_weight = 0.3333333333333333
# foreground_loss_weight: 1.0
# background_loss_weight: 1.0
# --------------------------------------------------
# 6) Creating VinBig Phrase Grounding Trainer ...
# get_image_transform()
#   image_size = [416, 416]
#   mean = [0.5307, 0.5307, 0.5307]
#   std = [0.2583, 0.2583, 0.2583]
#   Using bounding box aware transforms
#     augmentation_mode = random-color-and-spatial
#     default_prob = 0.35
#     for_vinbig: returning vinbig transform
# get_train_transform(): Using bbox-aware transforms for VinBigData
#     Returning augmented transform with mode random-color-and-spatial
# get_image_transform()
#   image_size = [416, 416]
#   mean = [0.5307, 0.5307, 0.5307]
#   std = [0.2583, 0.2583, 0.2583]
#   Using bounding box aware transforms
#     Returning default transform (no augmentation)
# Loading bounding boxes
# Anomalous bboxes found: 29 of 37367
# class_id_offset: 0
# Anomalous bboxes found: 0 of 2697
# class_id_offset: 0
#   Loaded 18000 bounding boxes
# Loding phrase_embeddings and phrases from /mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/vinbig/label_phrase_embeddings(hash=353,2491289492560726319).pkl...
# NOTE: Replacing phrase embeddings with random vectors
# Random vectors already saved at /mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/vinbig/label_phrase_embeddings(hash=353,2491289492560726319).pkl.random_vectors.pkl
# phrase_embeddings.shape = (28, 128)
# phrase_embeddings.dtype = float32
# len(phrases) = 28
# 	 aortic enlargement seen
# 	 atelectasis seen
# 	 calcification seen
# 	 cardiomegaly seen
# 	 clavicle fracture seen
# 	 consolidation seen
# 	 edema seen
# 	 emphysema seen
# 	 enlarged pulmonary artery seen
# 	 interstitial lung disease seen
# 	 infiltration seen
# 	 lung opacity seen
# 	 lung cavity seen
# 	 lung cyst seen
# 	 mediastinal shift seen
# 	 nodule/mass seen
# 	 pleural effusion seen
# 	 pleural thickening seen
# 	 pneumothorax seen
# 	 pulmonary fibrosis seen
# 	 rib fracture seen
# 	 other lesion seen
# 	 copd seen
# 	 lung tumor seen
# 	 pneumonia seen
# 	 tuberculosis seen
# 	 other disease seen
# 	 no abnormalities seen
# Compute phrase grounding masks and labels
# self.phrase_grounding_masks.shape = (18000, 22, 841)
# self.phrase_classification_labels.shape = (18000, 22)
# Append additional labels to phrase_classification_labels
# len(non_bbox_labels) = 6
# non_bbox_labels = ['COPD', 'Lung tumor', 'Pneumonia', 'Tuberculosis', 'Other disease', 'No finding']
# self.phrase_classification_labels.shape = (18000, 28)
# Reorder phrases and phrase_embeddings
# len(phrases) = 28
# len(actual_phrases) = 28
# phrase_embeddings.shape = (28, 128)
# Generating train dataset and dataloader
# len(train_indices) = 15000
# No labels: 0
# Edema: 13
# Clavicle fracture: 27
# Lung cyst: 33
# COPD: 35
# Lung cavity: 51
# Emphysema: 81
# Rib fracture: 90
# Pneumothorax: 96
# Enlarged PA: 131
# Mediastinal shift: 150
# Atelectasis: 187
# Lung tumor: 291
# Consolidation: 353
# ILD: 397
# Calcification: 458
# Infiltration: 613
# Tuberculosis: 750
# Nodule/Mass: 841
# Pneumonia: 917
# Pleural effusion: 1038
# Other lesion: 1154
# Lung Opacity: 1331
# Pulmonary fibrosis: 1621
# Pleural thickening: 2010
# Cardiomegaly: 2316
# Aortic enlargement: 3098
# Other disease: 4288
# No finding: 10601
# Group sizes: [10478, 771, 323, 312, 286, 278, 258, 243, 241, 218, 215, 167, 159, 156, 122, 119, 112, 102, 84, 83, 79, 47, 45, 32, 70]
#   len(indices) = 10478, weight = 2381.9852437292775
#   len(indices) = 771, weight = 882.1360585110112
#   len(indices) = 323, weight = 579.1323556126193
#   len(indices) = 312, weight = 568.7753795323758
#   len(indices) = 286, weight = 543.3127950518186
#   len(indices) = 278, weight = 535.1778961104801
#   len(indices) = 258, weight = 514.1586596868186
#   len(indices) = 243, weight = 497.69925147612867
#   len(indices) = 241, weight = 495.4562099629317
#   len(indices) = 218, weight = 468.76865710351854
#   len(indices) = 215, weight = 465.15882500917724
#   len(indices) = 167, weight = 402.55283205217046
#   len(indices) = 159, weight = 391.0802349542582
#   len(indices) = 156, weight = 386.6879164039802
#   len(indices) = 122, weight = 332.9187999914028
#   len(indices) = 119, weight = 327.76937690454827
#   len(indices) = 112, weight = 315.45337872121524
#   len(indices) = 102, weight = 297.0647831080699
#   len(indices) = 84, weight = 261.20109767987407
#   len(indices) = 83, weight = 259.088791948487
#   len(indices) = 79, weight = 250.497443897163
#   len(indices) = 47, weight = 171.37827001640065
#   len(indices) = 45, weight = 165.6367630898417
#   len(indices) = 32, weight = 125.0
#   len(indices) = 70, weight = 230.2655804515992
# batch_size = 6
# Generating val dataset and dataloader
# len(test_indices) = 3000
# batch_size = 24
# --------------------------------------------------
# 7) Creating dataloaders ...
# len(vinbig_trainer.train_dataloader) = 166666666666666667
# len(vinbig_trainer.val_dataloader) = 125
# len(_train_dataloaders) = 1
# len(_val_dataloaders) = 1
# _train_weights = [1.0]
# merged_dataset_name = vinbig
# --------------------------------------------------
# 8) Attaching metrics, losses, timer and events to engines ...
# --------------------------------------------------
# 9) Defining learning rate scheduler handler ...
# --------------------------------------------------
# 10) Defining learning rate scheduler handler ...
# --------------------------------------------------
# 11) Defining checkpoint folder path ...
# checkpoint_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250130_194227_vinbig_PhraseGrounder(microsoft-rad-dino-maira-2,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)
# metadata saved to /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250130_194227_vinbig_PhraseGrounder(microsoft-rad-dino-maira-2,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/metadata.json
# --------------------------------------------------
# 12) Defining log_metrics_handler ...
# MetricsLogger :: we'll be logging to /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250130_194227_vinbig_PhraseGrounder(microsoft-rad-dino-maira-2,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/metrics_logs.csv
# --------------------------------------------------
# 13) Running trainer engine ...
# ---- Epoch 1/100
# (1) Training stage (lr = 0.000001) ...
# loss 4.33918, vbg_vgbbox_loss 1.31344, vbg_att_sup_loss 1.36599, vbg_phrcls_loss 1.65975, vbg_prc_auc 0.15678, 253.11 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.03087, vbg_prc_auc 0.07777, 103.25 secs
# New checkpoint saved: checkpoint_1_vbss+vbou+vbuc+vbss=0.0736.pt
# ---- Epoch 2/100
# (1) Training stage (lr = 0.000004) ...
# loss 3.32606, vbg_vgbbox_loss 0.59185, vbg_att_sup_loss 1.34458, vbg_phrcls_loss 1.38963, vbg_prc_auc 0.15772, 253.12 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.05911, vbg_prc_auc 0.08393, 103.19 secs
# New checkpoint saved: checkpoint_2_vbss+vbou+vbuc+vbss=0.0890.pt
# ---- Epoch 3/100
# (1) Training stage (lr = 0.000019) ...
# loss 2.75809, vbg_vgbbox_loss 0.36286, vbg_att_sup_loss 1.15300, vbg_phrcls_loss 1.24223, vbg_prc_auc 0.15213, 255.25 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.10356, vbg_prc_auc 0.07652, 103.75 secs
# New checkpoint saved: checkpoint_3_vbss+vbou+vbuc+vbss=0.1000.pt
# ---- Epoch 4/100
# (1) Training stage (lr = 0.000080) ...
# loss 2.05093, vbg_vgbbox_loss 0.28201, vbg_att_sup_loss 0.74557, vbg_phrcls_loss 1.02335, vbg_prc_auc 0.25893, 251.75 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.13096, vbg_prc_auc 0.21331, 104.67 secs
# New checkpoint saved: checkpoint_4_vbss+vbou+vbuc+vbss=0.2000.pt
# ---- Epoch 5/100
# (1) Training stage (lr = 0.000033) ...
# loss 1.56571, vbg_vgbbox_loss 0.21239, vbg_att_sup_loss 0.51098, vbg_phrcls_loss 0.84235, vbg_prc_auc 0.37430, 246.61 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.18857, vbg_prc_auc 0.30246, 104.06 secs
# New checkpoint saved: checkpoint_5_vbss+vbou+vbuc+vbss=0.2792.pt
# ---- Epoch 6/100
# (1) Training stage (lr = 0.000014) ...
# loss 1.38059, vbg_vgbbox_loss 0.18752, vbg_att_sup_loss 0.43083, vbg_phrcls_loss 0.76223, vbg_prc_auc 0.42339, 257.62 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.19423, vbg_prc_auc 0.32588, 103.85 secs
# New checkpoint saved: checkpoint_6_vbss+vbou+vbuc+vbss=0.2977.pt
# ---- Epoch 7/100
# (1) Training stage (lr = 0.000006) ...
# loss 1.30526, vbg_vgbbox_loss 0.17732, vbg_att_sup_loss 0.40106, vbg_phrcls_loss 0.72688, vbg_prc_auc 0.45745, 257.32 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.21132, vbg_prc_auc 0.33517, 103.76 secs
# New checkpoint saved: checkpoint_7_vbss+vbou+vbuc+vbss=0.3102.pt
# ---- Epoch 8/100
# (1) Training stage (lr = 0.000002) ...
# loss 1.26499, vbg_vgbbox_loss 0.17596, vbg_att_sup_loss 0.38494, vbg_phrcls_loss 0.70409, vbg_prc_auc 0.47633, 255.81 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.21474, vbg_prc_auc 0.33668, 103.37 secs
# New checkpoint saved: checkpoint_8_vbss+vbou+vbuc+vbss=0.3128.pt
# ---- Epoch 9/100
# (1) Training stage (lr = 0.000001) ...
# loss 1.24777, vbg_vgbbox_loss 0.17346, vbg_att_sup_loss 0.37785, vbg_phrcls_loss 0.69647, vbg_prc_auc 0.48270, 253.41 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.20416, vbg_prc_auc 0.34095, 103.08 secs
# ---- Epoch 10/100
# (1) Training stage (lr = 0.000080) ...
# loss 1.47844, vbg_vgbbox_loss 0.22448, vbg_att_sup_loss 0.46458, vbg_phrcls_loss 0.78938, vbg_prc_auc 0.41017, 255.89 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.17672, vbg_prc_auc 0.29478, 103.04 secs
# ---- Epoch 11/100
# (1) Training stage (lr = 0.000027) ...
# loss 1.24024, vbg_vgbbox_loss 0.18164, vbg_att_sup_loss 0.36856, vbg_phrcls_loss 0.69004, vbg_prc_auc 0.50431, 255.72 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.20674, vbg_prc_auc 0.34455, 102.84 secs
# New checkpoint saved: checkpoint_11_vbss+vbou+vbuc+vbss=0.3160.pt
# ---- Epoch 12/100
# (1) Training stage (lr = 0.000009) ...
# loss 1.13633, vbg_vgbbox_loss 0.16811, vbg_att_sup_loss 0.32687, vbg_phrcls_loss 0.64135, vbg_prc_auc 0.55745, 255.99 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.21621, vbg_prc_auc 0.36303, 102.50 secs
# New checkpoint saved: checkpoint_12_vbss+vbou+vbuc+vbss=0.3324.pt
# ---- Epoch 13/100
# (1) Training stage (lr = 0.000003) ...
# loss 1.08798, vbg_vgbbox_loss 0.16260, vbg_att_sup_loss 0.31099, vbg_phrcls_loss 0.61439, vbg_prc_auc 0.58703, 255.88 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.21425, vbg_prc_auc 0.36703, 102.74 secs
# New checkpoint saved: checkpoint_13_vbss+vbou+vbuc+vbss=0.3353.pt
# ---- Epoch 14/100
# (1) Training stage (lr = 0.000001) ...
#    iteration 13975

# %%
# !python ../train_phrase_grounding.py \
--checkpoint_folder "models/phrase_grounding/20250130_194227_vinbig_PhraseGrounder(microsoft-rad-dino-maira-2,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)" \
--epochs 100 \
--batches_per_epoch 1000 \
--max_images_per_batch 6 \
--max_phrases_per_batch 1000 \
--max_phrases_per_image 45 \
--val_batch_size_factor 4 \
--raw_image_encoding "rad-dino-huggingface" \
--huggingface_model_name "microsoft/rad-dino-maira-2" \
--image_size 416 416 \
--image_local_feat_size 768 \
--num_regions 841 \
--regions_width 29 \
--regions_height 29 \
--img_aug_mode "random-color-and-spatial" \
--phrase_embedding_size 128 \
--phrase_grounding_mode "adaptive_film_based_pooling_mlp_with_bbox_regression" \
--phrase_mlp_hidden_dims 256 128 \
--visual_grounding_hidden_size 256 \
--num_train_workers 2 \
--num_val_workers 2 \
--gradient_accumulation_steps 5 \
--optimizer_name "adamw" \
--scheduler "exp-warmup+decay+cyclicdecay" \
--lr 1e-6 \
--warmup_decay_and_cyclic_decay_args "1e-6,3,8e-5,5,1e-6,8e-5,5,1e-6" \
--binary_multilabel_classif_loss_name "focal+bce+npbbce" \
--do_visual_grounding_with_bbox_regression \
--use_vinbig_for_train \
--use_vinbig_for_test \
--vinbig_phrase_embeddings_filepath \
"/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/vinbig/label_phrase_embeddings(hash=353,2491289492560726319).pkl" \
--replace_phrase_embeddings_with_random_vectors \
--use_amp \
--save
# Out:
# script's arguments:
#    epochs: 100
#    batches_per_epoch: 1000
#    max_images_per_batch: 6
#    max_phrases_per_batch: 1000
#    max_phrases_per_image: 45
#    val_batch_size_factor: 4.0
#    checkpoint_folder: models/phrase_grounding/20250130_194227_vinbig_PhraseGrounder(microsoft-rad-dino-maira-2,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)
#    pretrained_checkpoint_folder_path: None
#    pretrained_checkpoint_folder_paths: None
#    freeze_image_encoder: False
#    raw_image_encoding: rad-dino-huggingface
#    huggingface_model_name: microsoft/rad-dino-maira-2
#    num_regions: 841
#    image_local_feat_size: 768
#    image_encoder_pretrained_weights_path: None
#    image_encoder_dropout_p: 0
#    yolov8_model_name_or_path: None
#    yolov8_model_alias: None
#    phrase_embedding_size: 128
#    regions_width: 29
#    regions_height: 29
#    qkv_size: None
#    phrase_grounding_mode: adaptive_film_based_pooling_mlp_with_bbox_regression
#    phrase_classifier_hidden_size: None
#    transf_d_model: None
#    transf_nhead: None
#    transf_dim_feedforward: None
#    transf_dropout: 0
#    transf_num_layers: None
#    visual_feature_proj_size: None
#    visual_grounding_hidden_size: 256
#    phrase_mlp_hidden_dims: [256, 128]
#    predict_global_alignment: False
#    alignment_proj_size: None
#    yolov11_model_name_or_path: None
#    yolov11_model_alias: None
#    optimizer_name: adamw
#    lr: 1e-06
#    scheduler: exp-warmup+decay+cyclicdecay
#    lr_decay: 0.76
#    lr_decay_patience: 2
#    warmup_and_decay_args: None
#    warmup_and_cosine_args: None
#    warmup_decay_and_cyclic_decay_args: 1e-6,3,8e-5,5,1e-6,8e-5,5,1e-6
#    gradient_accumulation_steps: 5
#    override_lr: False
#    max_grad_norm: None
#    attention_supervision_loss_weight: 1.0
#    phrase_classifier_loss_weight: 1.0
#    foreground_loss_weight: 1.0
#    background_loss_weight: 1.0
#    focal_loss_weight: 1.0
#    bce_loss_weight: 1.0
#    wbce_loss_weight: 1.0
#    binary_multilabel_classif_loss_name: focal+bce+npbbce
#    use_weighted_phrase_classifier_loss: False
#    cluster_and_label_weights_for_facts_filepath: None
#    use_attention_regularization_loss: False
#    use_contrastive_phrase_grounding_loss: False
#    nt_xent_temperature: 0.1
#    num_train_workers: 2
#    num_val_workers: 2
#    device: GPU
#    use_amp: True
#    image_size: [416, 416]
#    dicom_id_to_pos_neg_facts_filepath: None
#    iuxray_image_id_to_pos_neg_facts_filepath: None
#    mscxr_phrase2embedding_filepath: None
#    chest_imagenome_bbox_phrase_embeddings_filepath: None
#    vinbig_phrase_embeddings_filepath: /mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/vinbig/label_phrase_embeddings(hash=353,2491289492560726319).pkl
#    chexlocalize_class_phrase_embeddings_filepath: None
#    chexpert_class_phrase_embeddings_filepath: None
#    mimiccxr_exclude_noisy_images: False
#    mimiccxr_facts_weight: 1.0
#    chest_imagenome_anatlocs_weight: 1.0
#    mscxr_weight: 1.0
#    cxrlt2024_weight: 1.0
#    vinbig_weight: 1.0
#    chexlocalize_weight: 1.0
#    chexpert_weight: 1.0
#    iuxray_weight: 1.0
#    img_aug_mode: random-color-and-spatial
#    pos_area_prior: 0.4
#    neg_area_prior: 0.0
#    use_mimiccxr_facts_for_train: False
#    use_mimiccxr_facts_for_test: False
#    use_mscxr_for_train: False
#    use_mscxr_for_test: False
#    use_chest_imagenome_for_train: False
#    use_chest_imagenome_gold_for_test: False
#    use_vinbig_for_train: True
#    use_vinbig_for_test: True
#    use_chexlocalize_for_train: False
#    use_chexlocalize_for_test: False
#    use_chexpert_for_train: False
#    use_chexpert_for_test: False
#    use_iuxray_for_train: False
#    use_iuxray_for_test: False
#    use_cxrlt2024_challenge_split: False
#    use_cxrlt2024_custom_labels: False
#    use_cxrlt2024_official_labels: False
#    use_all_cxrlt2024_official_labels_for_training: False
#    vinbig_training_data_mode: train
#    chexpert_training_data_mode: all
#    mimiccxr_balance_long_middle_short_tail: False
#    mimiccxr_long_middle_short_tail_thresholds: (0.02, 0.05)
#    mimiccxr_report_fact_nli_integrated_data_filepath: None
#    mimiccxr_use_interpret_cxr_challenge_split: False
#    mimiccxr_interpret_cxr_challenge_split_filepath: None
#    iuxray_use_interpret_cxr_challenge_split: False
#    iuxray_interpret_cxr_challenge_split_filepath: None
#    chexpert_use_interpret_cxr_challenge_split: False
#    chexpert_interpret_cxr_challenge_split_filepath: None
#    chexlocalize_use_interpret_cxr_challenge_split: False
#    chexlocalize_interpret_cxr_challenge_split_filepath: None
#    cxrlt2024_custom_dicom_id_to_pos_neg_facts_filepath: None
#    cxrlt2024_official_training_labels_for_fact_classification_filepath: None
#    cxrlt2024_do_balanced_sampling: False
#    do_visual_grounding_with_bbox_regression: True
#    do_visual_grounding_with_segmentation: False
#    replace_phrase_embeddings_with_random_vectors: True
#    save: True
# ----- Resuming training ------
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250130_194227_vinbig_PhraseGrounder(microsoft-rad-dino-maira-2,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/metadata.json
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Creating instance of PhraseGrounder ...
# WARNING: Unused kwargs: {'pretrained_checkpoint_folder_path': None, 'pretrained_checkpoint_folder_paths': None}
# MultiPurposeVisualModule()
#   Initializing raw_image_encoder: rad-dino-huggingface
#   self.global_feat_size = 768
#   self.local_feat_size = 768
#   Initializing auxiliary tasks
# BoundingBoxRegressorSingleClass
#   local_feat_dim: 256
# --------------------------------------------------
# 3) Defining optimizer ...
# create_optimizer(): name = adamw
# --------------------------------------------------
# 4) Defining scheduler ...
# Using exp-warmup+decay+cyclicdecay scheduler: 1e-6,3,8e-5,5,1e-6,8e-5,5,1e-6
# 1e-06 3 8e-05 5 1e-06 8e-05 5 1e-06
# self.steps_to_restart = 5
# self.steps = -1
# self.initial_lr = 8e-05
# --------------------------------------------------
# 5) Creating trainer and validator engines ...
# Focal_BCE_NPBBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 npbbce_weight = 0.3333333333333333
# Focal_BCE_NPBBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 npbbce_weight = 0.3333333333333333
# Focal_BCE_WBCBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 wbcbce_weight = 0.3333333333333333
# foreground_loss_weight: 1.0
# background_loss_weight: 1.0
# GradientAccumulator.__init__(): num_accumulation_steps = 5, max_grad_norm = None
# Focal_BCE_NPBBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 npbbce_weight = 0.3333333333333333
# Focal_BCE_NPBBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 npbbce_weight = 0.3333333333333333
# Focal_BCE_WBCBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 wbcbce_weight = 0.3333333333333333
# foreground_loss_weight: 1.0
# background_loss_weight: 1.0
# --------------------------------------------------
# 6) Creating VinBig Phrase Grounding Trainer ...
# get_image_transform()
#   image_size = [416, 416]
#   mean = [0.5307, 0.5307, 0.5307]
#   std = [0.2583, 0.2583, 0.2583]
#   Using bounding box aware transforms
#     augmentation_mode = random-color-and-spatial
#     default_prob = 0.35
#     for_vinbig: returning vinbig transform
# get_train_transform(): Using bbox-aware transforms for VinBigData
#     Returning augmented transform with mode random-color-and-spatial
# get_image_transform()
#   image_size = [416, 416]
#   mean = [0.5307, 0.5307, 0.5307]
#   std = [0.2583, 0.2583, 0.2583]
#   Using bounding box aware transforms
#     Returning default transform (no augmentation)
# Loading bounding boxes
# Anomalous bboxes found: 29 of 37367
# class_id_offset: 0
# Anomalous bboxes found: 0 of 2697
# class_id_offset: 0
#   Loaded 18000 bounding boxes
# Loding phrase_embeddings and phrases from /mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/vinbig/label_phrase_embeddings(hash=353,2491289492560726319).pkl...
# NOTE: Replacing phrase embeddings with random vectors
# Random vectors already saved at /mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/vinbig/label_phrase_embeddings(hash=353,2491289492560726319).pkl.random_vectors.pkl
# phrase_embeddings.shape = (28, 128)
# phrase_embeddings.dtype = float32
# len(phrases) = 28
# 	 aortic enlargement seen
# 	 atelectasis seen
# 	 calcification seen
# 	 cardiomegaly seen
# 	 clavicle fracture seen
# 	 consolidation seen
# 	 edema seen
# 	 emphysema seen
# 	 enlarged pulmonary artery seen
# 	 interstitial lung disease seen
# 	 infiltration seen
# 	 lung opacity seen
# 	 lung cavity seen
# 	 lung cyst seen
# 	 mediastinal shift seen
# 	 nodule/mass seen
# 	 pleural effusion seen
# 	 pleural thickening seen
# 	 pneumothorax seen
# 	 pulmonary fibrosis seen
# 	 rib fracture seen
# 	 other lesion seen
# 	 copd seen
# 	 lung tumor seen
# 	 pneumonia seen
# 	 tuberculosis seen
# 	 other disease seen
# 	 no abnormalities seen
# Compute phrase grounding masks and labels
# self.phrase_grounding_masks.shape = (18000, 22, 841)
# self.phrase_classification_labels.shape = (18000, 22)
# Append additional labels to phrase_classification_labels
# len(non_bbox_labels) = 6
# non_bbox_labels = ['COPD', 'Lung tumor', 'Pneumonia', 'Tuberculosis', 'Other disease', 'No finding']
# self.phrase_classification_labels.shape = (18000, 28)
# Reorder phrases and phrase_embeddings
# len(phrases) = 28
# len(actual_phrases) = 28
# phrase_embeddings.shape = (28, 128)
# Generating train dataset and dataloader
# len(train_indices) = 15000
# No labels: 0
# Edema: 13
# Clavicle fracture: 27
# Lung cyst: 33
# COPD: 35
# Lung cavity: 51
# Emphysema: 81
# Rib fracture: 90
# Pneumothorax: 96
# Enlarged PA: 131
# Mediastinal shift: 150
# Atelectasis: 187
# Lung tumor: 291
# Consolidation: 353
# ILD: 397
# Calcification: 458
# Infiltration: 613
# Tuberculosis: 750
# Nodule/Mass: 841
# Pneumonia: 917
# Pleural effusion: 1038
# Other lesion: 1154
# Lung Opacity: 1331
# Pulmonary fibrosis: 1621
# Pleural thickening: 2010
# Cardiomegaly: 2316
# Aortic enlargement: 3098
# Other disease: 4288
# No finding: 10601
# Group sizes: [10478, 771, 323, 312, 286, 278, 258, 243, 241, 218, 215, 167, 159, 156, 122, 119, 112, 102, 84, 83, 79, 47, 45, 32, 70]
#   len(indices) = 10478, weight = 2381.9852437292775
#   len(indices) = 771, weight = 882.1360585110112
#   len(indices) = 323, weight = 579.1323556126193
#   len(indices) = 312, weight = 568.7753795323758
#   len(indices) = 286, weight = 543.3127950518186
#   len(indices) = 278, weight = 535.1778961104801
#   len(indices) = 258, weight = 514.1586596868186
#   len(indices) = 243, weight = 497.69925147612867
#   len(indices) = 241, weight = 495.4562099629317
#   len(indices) = 218, weight = 468.76865710351854
#   len(indices) = 215, weight = 465.15882500917724
#   len(indices) = 167, weight = 402.55283205217046
#   len(indices) = 159, weight = 391.0802349542582
#   len(indices) = 156, weight = 386.6879164039802
#   len(indices) = 122, weight = 332.9187999914028
#   len(indices) = 119, weight = 327.76937690454827
#   len(indices) = 112, weight = 315.45337872121524
#   len(indices) = 102, weight = 297.0647831080699
#   len(indices) = 84, weight = 261.20109767987407
#   len(indices) = 83, weight = 259.088791948487
#   len(indices) = 79, weight = 250.497443897163
#   len(indices) = 47, weight = 171.37827001640065
#   len(indices) = 45, weight = 165.6367630898417
#   len(indices) = 32, weight = 125.0
#   len(indices) = 70, weight = 230.2655804515992
# batch_size = 6
# Generating val dataset and dataloader
# len(test_indices) = 3000
# batch_size = 24
# --------------------------------------------------
# 7) Creating dataloaders ...
# len(vinbig_trainer.train_dataloader) = 166666666666666667
# len(vinbig_trainer.val_dataloader) = 125
# len(_train_dataloaders) = 1
# len(_val_dataloaders) = 1
# _train_weights = [1.0]
# merged_dataset_name = vinbig
# --------------------------------------------------
# 8) Attaching metrics, losses, timer and events to engines ...
# --------------------------------------------------
# 9) Defining learning rate scheduler handler ...
# --------------------------------------------------
# 10) Defining learning rate scheduler handler ...
# checkpoint_names = ['checkpoint_16_vbss+vbou+vbuc+vbss=0.3403.pt', 'checkpoint_13_vbss+vbou+vbuc+vbss=0.3353.pt']
# --------------------------------------------------
# 11) Loading model from checkpoint ...
# checkpoint_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250130_194227_vinbig_PhraseGrounder(microsoft-rad-dino-maira-2,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/checkpoint_16_vbss+vbou+vbuc+vbss=0.3403.pt
# Checkpoint successfully loaded!
# --------------------------------------------------
# 12) Defining log_metrics_handler ...
# MetricsLogger :: we'll be logging to /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250130_194227_vinbig_PhraseGrounder(microsoft-rad-dino-maira-2,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/metrics_logs.csv
# --------------------------------------------------
# 13) Running trainer engine ...
# ---- Epoch 17/116
# (1) Training stage (lr = 0.000009) ...
# loss 1.01204, vbg_vgbbox_loss 0.15835, vbg_att_sup_loss 0.28149, vbg_phrcls_loss 0.57220, vbg_prc_auc 0.63234, 262.54 secs
# (2) Validation stage ...
# loss 0.97701, vbg_vgbbox_loss 0.15607, vbg_att_sup_loss 0.27075, vbg_phrcls_loss 0.55019, vbg_prc_auc 0.66206, 258.08 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.22134, vbg_prc_auc 0.39367, 100.72 secs
# New checkpoint saved: checkpoint_18_vbss+vbou+vbuc+vbss=0.3566.pt
# ---- Epoch 19/116
# (1) Training stage (lr = 0.000001) ...
# loss 0.95321, vbg_vgbbox_loss 0.15253, vbg_att_sup_loss 0.26312, vbg_phrcls_loss 0.53756, vbg_prc_auc 0.66407, 259.06 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.22102, vbg_prc_auc 0.38873, 100.40 secs
# ---- Epoch 20/116
# (1) Training stage (lr = 0.000080) ...
# loss 1.21882, vbg_vgbbox_loss 0.19379, vbg_att_sup_loss 0.35264, vbg_phrcls_loss 0.67239, vbg_prc_auc 0.53026, 255.57 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.18994, vbg_prc_auc 0.32926, 101.53 secs
# ---- Epoch 21/116
# (1) Training stage (lr = 0.000027) ...
# loss 1.01983, vbg_vgbbox_loss 0.16358, vbg_att_sup_loss 0.27886, vbg_phrcls_loss 0.57738, vbg_prc_auc 0.63797, 251.34 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.21998, vbg_prc_auc 0.40770, 101.08 secs
# New checkpoint saved: checkpoint_21_vbss+vbou+vbuc+vbss=0.3643.pt
# ---- Epoch 22/116
# (1) Training stage (lr = 0.000009) ...
# loss 0.91565, vbg_vgbbox_loss 0.15169, vbg_att_sup_loss 0.24485, vbg_phrcls_loss 0.51910, vbg_prc_auc 0.69170, 252.33 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.22046, vbg_prc_auc 0.38930, 101.13 secs
# ---- Epoch 23/116
# (1) Training stage (lr = 0.000003) ...
# loss 0.87898, vbg_vgbbox_loss 0.14732, vbg_att_sup_loss 0.23507, vbg_phrcls_loss 0.49659, vbg_prc_auc 0.71629, 257.12 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.22337, vbg_prc_auc 0.39954, 101.05 secs
# ---- Epoch 24/116
# (1) Training stage (lr = 0.000001) ...
# loss 0.86776, vbg_vgbbox_loss 0.14761, vbg_att_sup_loss 0.23149, vbg_phrcls_loss 0.48866, vbg_prc_auc 0.72322, 250.90 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.22188, vbg_prc_auc 0.40147, 101.81 secs
# ---- Epoch 25/116
# (1) Training stage (lr = 0.000080) ...
# loss 1.11892, vbg_vgbbox_loss 0.18384, vbg_att_sup_loss 0.31861, vbg_phrcls_loss 0.61647, vbg_prc_auc 0.57791, 251.28 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.19478, vbg_prc_auc 0.35491, 101.77 secs
# ---- Epoch 26/116
# (1) Training stage (lr = 0.000027) ...
# loss 0.94446, vbg_vgbbox_loss 0.15895, vbg_att_sup_loss 0.25253, vbg_phrcls_loss 0.53297, vbg_prc_auc 0.68878, 254.47 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.21732, vbg_prc_auc 0.38136, 100.87 secs
# ---- Epoch 27/116
# (1) Training stage (lr = 0.000009) ...
# loss 0.83669, vbg_vgbbox_loss 0.14574, vbg_att_sup_loss 0.22030, vbg_phrcls_loss 0.47066, vbg_prc_auc 0.74835, 249.18 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.21665, vbg_prc_auc 0.39506, 101.09 secs
# ---- Epoch 28/116
# (1) Training stage (lr = 0.000003) ...
# loss 0.79223, vbg_vgbbox_loss 0.14387, vbg_att_sup_loss 0.20479, vbg_phrcls_loss 0.44357, vbg_prc_auc 0.77280, 250.46 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.21668, vbg_prc_auc 0.39792, 101.22 secs
# ---- Epoch 29/116
# (1) Training stage (lr = 0.000001) ...
# loss 0.78007, vbg_vgbbox_loss 0.14136, vbg_att_sup_loss 0.20551, vbg_phrcls_loss 0.43320, vbg_prc_auc 0.78652, 250.20 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.21654, vbg_prc_auc 0.39745, 101.50 secs
# ---- Epoch 30/116
# (1) Training stage (lr = 0.000080) ...
# loss 1.03963, vbg_vgbbox_loss 0.17607, vbg_att_sup_loss 0.28766, vbg_phrcls_loss 0.57590, vbg_prc_auc 0.63165, 249.17 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.20255, vbg_prc_auc 0.38141, 102.23 secs
# ---- Epoch 31/116
# (1) Training stage (lr = 0.000027) ...
# loss 0.87420, vbg_vgbbox_loss 0.15347, vbg_att_sup_loss 0.23457, vbg_phrcls_loss 0.48616, vbg_prc_auc 0.74076, 250.15 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.21875, vbg_prc_auc 0.38487, 102.08 secs
# ---- Epoch 32/116
# (1) Training stage (lr = 0.000009) ...
# loss 0.75624, vbg_vgbbox_loss 0.14127, vbg_att_sup_loss 0.19533, vbg_phrcls_loss 0.41964, vbg_prc_auc 0.80526, 258.01 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.22251, vbg_prc_auc 0.38721, 101.25 secs
# ---- Epoch 33/116
# (1) Training stage (lr = 0.000003) ...
# loss 0.71013, vbg_vgbbox_loss 0.13925, vbg_att_sup_loss 0.18372, vbg_phrcls_loss 0.38717, vbg_prc_auc 0.83964, 260.42 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.22415, vbg_prc_auc 0.38794, 100.94 secs
# ---- Epoch 34/116
# (1) Training stage (lr = 0.000001) ...
# loss 0.70590, vbg_vgbbox_loss 0.13775, vbg_att_sup_loss 0.18196, vbg_phrcls_loss 0.38618, vbg_prc_auc 0.84405, 258.23 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.21785, vbg_prc_auc 0.39008, 101.14 secs
# ---- Epoch 35/116
# (1) Training stage (lr = 0.000080) ...
# loss 0.98129, vbg_vgbbox_loss 0.17431, vbg_att_sup_loss 0.26678, vbg_phrcls_loss 0.54020, vbg_prc_auc 0.66798, 258.65 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.20613, vbg_prc_auc 0.37681, 101.42 secs
# ---- Epoch 36/116
# (1) Training stage (lr = 0.000027) ...
# loss 0.81228, vbg_vgbbox_loss 0.15107, vbg_att_sup_loss 0.21039, vbg_phrcls_loss 0.45082, vbg_prc_auc 0.78165, 258.89 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.22473, vbg_prc_auc 0.39006, 100.50 secs
# ---- Epoch 37/116
# (1) Training stage (lr = 0.000009) ...
# loss 0.69393, vbg_vgbbox_loss 0.14028, vbg_att_sup_loss 0.17907, vbg_phrcls_loss 0.37458, vbg_prc_auc 0.85509, 258.51 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.22263, vbg_prc_auc 0.39244, 101.05 secs
# ---- Epoch 38/116
# (1) Training stage (lr = 0.000003) ...
# loss 0.65311, vbg_vgbbox_loss 0.13656, vbg_att_sup_loss 0.16890, vbg_phrcls_loss 0.34765, vbg_prc_auc 0.87487, 259.66 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.22558, vbg_prc_auc 0.40008, 100.28 secs
# New checkpoint saved: checkpoint_38_vbss+vbou+vbuc+vbss=0.3684.pt
# ---- Epoch 39/116
# (1) Training stage (lr = 0.000001) ...
# loss 0.63801, vbg_vgbbox_loss 0.13540, vbg_att_sup_loss 0.16543, vbg_phrcls_loss 0.33718, vbg_prc_auc 0.88840, 258.47 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.22793, vbg_prc_auc 0.39853, 100.51 secs
# New checkpoint saved: checkpoint_39_vbss+vbou+vbuc+vbss=0.3685.pt
# ---- Epoch 40/116
# (1) Training stage (lr = 0.000080) ...
# loss 0.89009, vbg_vgbbox_loss 0.16409, vbg_att_sup_loss 0.23891, vbg_phrcls_loss 0.48709, vbg_prc_auc 0.73716, 261.08 secs
# (2) Validation stage ...
# ^C iteration 50
# Engine run is terminating due to exception:
# Engine run is terminating due to exception:
# Traceback (most recent call last):
#   File "/home/pamessina/medvqa/medvqa/notebooks/../train_phrase_grounding.py", line 1535, in <module>
#     resume_training(**args)
#   File "/home/pamessina/medvqa/medvqa/notebooks/../train_phrase_grounding.py", line 1491, in resume_training
#     return train_model(
#   File "/home/pamessina/medvqa/medvqa/notebooks/../train_phrase_grounding.py", line 918, in train_model
#     run_common_boilerplate_code_and_start_training(
#   File "/home/pamessina/medvqa/medvqa/training/utils.py", line 142, in run_common_boilerplate_code_and_start_training
#     trainer_engine.run(train_dataloader, max_epochs=epochs, epoch_length=batches_per_epoch)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 892, in run
#     return self._internal_run()
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 935, in _internal_run
#     return next(self._internal_run_generator)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 993, in _internal_run_as_gen
#     self._handle_exception(e)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 638, in _handle_exception
#     raise e
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 965, in _internal_run_as_gen
#     self._fire_event(Events.EPOCH_COMPLETED)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 425, in _fire_event
#     func(*first, *(event_args + others), **kwargs)
#   File "/home/pamessina/medvqa/medvqa/training/utils.py", line 129, in <lambda>
#     trainer_engine.add_event_handler(Events.EPOCH_COMPLETED, lambda : validator_engine.run(val_dataloader,
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 892, in run
#     return self._internal_run()
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 935, in _internal_run
#     return next(self._internal_run_generator)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 993, in _internal_run_as_gen
#     self._handle_exception(e)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 638, in _handle_exception
#     raise e
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 959, in _internal_run_as_gen
#     epoch_time_taken += yield from self._run_once_on_dataset_as_gen()
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 1068, in _run_once_on_dataset_as_gen
#     self.state.output = self._process_function(self, self.state.batch)
#   File "/home/pamessina/medvqa/medvqa/training/phrase_grounding.py", line 984, in step_fn
#     output = flag_to_step_fn[flag](batch)
#   File "/home/pamessina/medvqa/medvqa/training/phrase_grounding.py", line 509, in step_fn__vinbig_bbox_grounding
#     model_output = model(**model_kwargs)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1532, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1541, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/home/pamessina/medvqa/medvqa/models/phrase_grounding/phrase_grounder.py", line 671, in forward
#     predicted_bboxes, visual_grounding_binary_logits = self.visual_grounding_bbox_regressor(
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1532, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1541, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/home/pamessina/medvqa/medvqa/models/vision/bbox_regression.py", line 681, in forward
#     if bbox_coords_i.size(0) > 0:
# KeyboardInterrupt
