# %%
# %env CUDA_VISIBLE_DEVICES=0
# Out:
# env: CUDA_VISIBLE_DEVICES=0

# %%
# !python ../train_image2report.py \
    --epochs 69 \
    --batches-per-epoch 400 \
    --batch-size 45 \
    --num-workers 3 \
    --iters-to-accumulate 4 \
    --optimizer-name "adamw" \
    --scheduler "exp-warmup+decay+cyclicdecay" \
    --lr 1e-6 \
    --warmup-decay-and-cyclic-decay-args "1e-6,4,3e-4,8,1e-6,1e-4,8,1e-6" \
    --use-mimiccxr \
    --mimiccxr-weight 1.0 \
    --mimiccxr-view-mode "chest_imagenome" \
    --mimiccxr-balanced-sampling-mode "balanced_chest_imagenome_global_labels_batchwise" \
    --mimiccxr-balanced-batch-size 20 \
    --mimiccxr-qa-adapted-reports-filename "qa_adapted_reports__20220904_095810.json" \
    --use-chest-imagenome-decent-images-only \
    --classify-gender \
    --classify-chexpert \
    --mimiccxr-chexpert-labels-filename "chexpert_labels_per_report__20220904_113605.pkl" \
    --classify-chest-imagenome \
    --chest-imagenome-label-names-filename "labels(min_freq=100).pkl" \
    --chest-imagenome-labels-filename "imageId2labels(min_freq=100).pkl" \
    --predict-bboxes-chest-imagenome \
    --predict-labels-and-bboxes-chest-imagenome \
    --clamp-bboxes-chest-imagenome \
    --binary-loss-name "focal+bce+wbce-c" \
    --embedding-dim 512 \
    --transf-dec-hidden-dim 512 \
    --transf-dec-nhead 4 \
    --transf-dec-dim-forward 512 \
    --transf-dec-num-layers 3 \
    --use-medical-tokenization \
    --medical-terms-frequency-filename "medical_terms_frequency__20220918_184255.pkl" \
    --raw-image-encoding "densenet-121" \
    --image-size 256 256 \
    --image-local-feat-size 1024 \
    --num-regions 64 \
    --chexpert-mlc-version "v3" \
    --chest-imagenome-bbox-regressor-version "v4" \
    --img-aug-mode "random-color-and-spatial" \
    --use-amp \
    --save
# Out:
# script's arguments:
#    epochs: 69
#    batches_per_epoch: 400
#    batch_size: 45
#    checkpoint_folder: None
#    pretrained_checkpoint_folder_path: None
#    embedding_dim: 512
#    transf_dec_hidden_dim: 512
#    transf_dec_nhead: 4
#    transf_dec_dim_forward: 512
#    transf_dec_num_layers: 3
#    dropout_prob: 0
#    raw_image_encoding: densenet-121
#    image_local_feat_size: 1024
#    image_encoder_pretrained_weights_path: None
#    freeze_image_encoder: False
#    image_encoder_only_compute_features: False
#    chexpert_mlc_version: v3
#    chexpert_mlc_hidden_size: 128
#    chest_imagenome_mlc_version: None
#    chest_imagenome_mlc_hidden_size: 128
#    chest_imagenome_bbox_regressor_version: v4
#    chest_imagenome_bbox_hidden_size: 128
#    num_regions: 64
#    yolov8_model_name_or_path: None
#    yolov8_model_alias: None
#    vocab_min_freq: 10
#    use_medical_tokenization: True
#    medical_terms_frequency_filename: medical_terms_frequency__20220918_184255.pkl
# ...

# %%
# !python ../train_image2report.py \
    --checkpoint-folder "models/report_gen/20230507_200753_mim_Image2ReportModel(dn121->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))" \
    --epochs 69 \
    --batches-per-epoch 400 \
    --batch-size 45 \
    --num-workers 3 \
    --iters-to-accumulate 4 \
    --override-lr \
    --optimizer-name "adamw" \
    --scheduler "exp-warmup+decay+cyclicdecay" \
    --lr 1e-6 \
    --warmup-decay-and-cyclic-decay-args "1e-6,4,3e-4,8,5e-6,3e-4,8,5e-6" \
    --save
# Out:
# script's arguments:
#    epochs: 69
#    batches_per_epoch: 400
#    batch_size: 45
#    checkpoint_folder: models/report_gen/20230507_200753_mim_Image2ReportModel(dn121->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))
#    pretrained_checkpoint_folder_path: None
#    embedding_dim: 256
#    transf_dec_hidden_dim: 256
#    transf_dec_nhead: 2
#    transf_dec_dim_forward: 256
#    transf_dec_num_layers: 2
#    dropout_prob: 0
#    raw_image_encoding: densenet-121
#    image_local_feat_size: 1024
#    image_encoder_pretrained_weights_path: None
#    freeze_image_encoder: False
#    image_encoder_only_compute_features: False
#    chexpert_mlc_version: None
#    chexpert_mlc_hidden_size: 128
#    chest_imagenome_mlc_version: None
#    chest_imagenome_mlc_hidden_size: 128
#    chest_imagenome_bbox_regressor_version: None
#    chest_imagenome_bbox_hidden_size: 128
#    num_regions: None
#    yolov8_model_name_or_path: None
#    yolov8_model_alias: None
#    vocab_min_freq: 10
# ...

# %%
# !python ../train_image2report.py \
    --pretrained-checkpoint-folder-path "/mnt/data/pamessina/workspaces/medvqa-workspace/models/report_gen/20230507_200753_mim_Image2ReportModel(dn121->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))" \
    --epochs 60 \
    --batches-per-epoch 400 \
    --batch-size 30 \
    --num-workers 2 \
    --iters-to-accumulate 4 \
    --optimizer-name "adamw" \
    --scheduler "exp-warmup+decay+cyclicdecay" \
    --lr 1e-6 \
    --warmup-decay-and-cyclic-decay-args "1e-6,4,3e-4,8,3e-6,1e-4,8,3e-6" \
    --use-mimiccxr \
    --mimiccxr-weight 1.0 \
    --mimiccxr-view-mode "chest_imagenome" \
    --mimiccxr-balanced-sampling-mode "balanced_chest_imagenome_global_labels_batchwise" \
    --mimiccxr-balanced-batch-size 20 \
    --mimiccxr-qa-adapted-reports-filename "qa_adapted_reports__20220904_095810.json" \
    --use-chest-imagenome-decent-images-only \
    --classify-gender \
    --classify-chexpert \
    --mimiccxr-chexpert-labels-filename "chexpert_labels_per_report__20220904_113605.pkl" \
    --classify-chest-imagenome \
    --chest-imagenome-label-names-filename "labels(min_freq=100).pkl" \
    --chest-imagenome-labels-filename "imageId2labels(min_freq=100).pkl" \
    --predict-bboxes-chest-imagenome \
    --predict-labels-and-bboxes-chest-imagenome \
    --clamp-bboxes-chest-imagenome \
    --binary-loss-name "focal+bce+wbce-c" \
    --embedding-dim 512 \
    --transf-dec-hidden-dim 512 \
    --transf-dec-nhead 4 \
    --transf-dec-dim-forward 512 \
    --transf-dec-num-layers 3 \
    --use-medical-tokenization \
    --medical-terms-frequency-filename "medical_terms_frequency__20220918_184255.pkl" \
    --raw-image-encoding "densenet-121" \
    --image-size 256 256 \
    --image-local-feat-size 1024 \
    --num-regions 64 \
    --chexpert-mlc-version "v3" \
    --chest-imagenome-bbox-regressor-version "v4" \
    --img-aug-mode "random-color-and-spatial" \
    --use-amp \
    --save
# Out:
# script's arguments:
#    epochs: 60
#    batches_per_epoch: 400
#    batch_size: 30
#    checkpoint_folder: None
#    pretrained_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/report_gen/20230507_200753_mim_Image2ReportModel(dn121->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))
#    embedding_dim: 512
#    transf_dec_hidden_dim: 512
#    transf_dec_nhead: 4
#    transf_dec_dim_forward: 512
#    transf_dec_num_layers: 3
#    dropout_prob: 0
#    raw_image_encoding: densenet-121
#    image_local_feat_size: 1024
#    image_encoder_pretrained_weights_path: None
#    freeze_image_encoder: False
#    image_encoder_only_compute_features: False
#    chexpert_mlc_version: v3
#    chexpert_mlc_hidden_size: 128
#    chest_imagenome_mlc_version: None
#    chest_imagenome_mlc_hidden_size: 128
#    chest_imagenome_bbox_regressor_version: v4
#    chest_imagenome_bbox_hidden_size: 128
#    num_regions: 64
#    yolov8_model_name_or_path: None
# ...

# %%
# !python ../train_image2report.py \
    --pretrained-checkpoint-folder-path "/mnt/data/pamessina/workspaces/medvqa-workspace/models/report_gen/20230507_200753_mim_Image2ReportModel(dn121->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))" \
    --epochs 44 \
    --batches-per-epoch 400 \
    --batch-size 30 \
    --num-workers 2 \
    --iters-to-accumulate 4 \
    --optimizer-name "adamw" \
    --scheduler "exp-warmup+decay+cyclicdecay" \
    --lr 1e-6 \
    --warmup-decay-and-cyclic-decay-args "1e-6,4,3e-4,8,2e-6,1e-4,8,2e-6" \
    --use-mimiccxr \
    --mimiccxr-weight 1.0 \
    --mimiccxr-view-mode "chest_imagenome" \
    --mimiccxr-balanced-sampling-mode "balanced_chest_imagenome_global_labels_batchwise" \
    --mimiccxr-balanced-batch-size 20 \
    --mimiccxr-qa-adapted-reports-filename "qa_adapted_reports__20220904_095810.json" \
    --use-chest-imagenome-decent-images-only \
    --classify-gender \
    --classify-chexpert \
    --mimiccxr-chexpert-labels-filename "chexpert_labels_per_report__20220904_113605.pkl" \
    --classify-chest-imagenome \
    --chest-imagenome-label-names-filename "labels(min_freq=100).pkl" \
    --chest-imagenome-labels-filename "imageId2labels(min_freq=100).pkl" \
    --predict-bboxes-chest-imagenome \
    --predict-labels-and-bboxes-chest-imagenome \
    --clamp-bboxes-chest-imagenome \
    --binary-loss-name "focal+bce+wbce-c" \
    --predict-local-feature-coords \
    --local-features-width 8 \
    --local-features-height 8 \
    --embedding-dim 512 \
    --transf-dec-hidden-dim 512 \
    --transf-dec-nhead 4 \
    --transf-dec-dim-forward 512 \
    --transf-dec-num-layers 3 \
    --use-medical-tokenization \
    --medical-terms-frequency-filename "medical_terms_frequency__20220918_184255.pkl" \
    --raw-image-encoding "densenet-121" \
    --image-size 256 256 \
    --image-local-feat-size 1024 \
    --num-regions 64 \
    --chexpert-mlc-version "v3" \
    --chest-imagenome-bbox-regressor-version "v4" \
    --img-aug-mode "random-color-and-spatial" \
    --use-amp \
    --save
# Out:
# script's arguments:
#    epochs: 44
#    batches_per_epoch: 400
#    batch_size: 30
#    checkpoint_folder: None
#    pretrained_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/report_gen/20230507_200753_mim_Image2ReportModel(dn121->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))
#    embedding_dim: 512
#    transf_dec_hidden_dim: 512
#    transf_dec_nhead: 4
#    transf_dec_dim_forward: 512
#    transf_dec_num_layers: 3
#    dropout_prob: 0
#    raw_image_encoding: densenet-121
#    image_local_feat_size: 1024
#    image_encoder_pretrained_weights_path: None
#    freeze_image_encoder: False
#    image_encoder_only_compute_features: False
#    chexpert_mlc_version: v3
#    chexpert_mlc_hidden_size: 128
#    chest_imagenome_mlc_version: None
#    chest_imagenome_mlc_hidden_size: 128
#    chest_imagenome_bbox_regressor_version: v4
#    chest_imagenome_bbox_hidden_size: 128
#    num_regions: 64
#    yolov8_model_name_or_path: None
# ...

# %%
# !python ../train_image2report.py \
    --pretrained-checkpoint-folder-path "/mnt/data/pamessina/workspaces/medvqa-workspace/models/report_gen/20230507_200753_mim_Image2ReportModel(dn121->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))" \
    --epochs 44 \
    --batches-per-epoch 400 \
    --batch-size 30 \
    --num-workers 2 \
    --iters-to-accumulate 4 \
    --optimizer-name "adamw" \
    --scheduler "exp-warmup+decay+cyclicdecay" \
    --lr 1e-6 \
    --warmup-decay-and-cyclic-decay-args "1e-6,4,3e-4,8,2e-6,1e-4,8,2e-6" \
    --use-mimiccxr \
    --mimiccxr-weight 1.0 \
    --mimiccxr-view-mode "chest_imagenome" \
    --mimiccxr-balanced-sampling-mode "balanced_chest_imagenome_global_labels_batchwise" \
    --mimiccxr-balanced-batch-size 30 \
    --mimiccxr-qa-adapted-reports-filename "qa_adapted_reports__20220904_095810.json" \
    --use-chest-imagenome-decent-images-only \
    --classify-gender \
    --classify-chexpert \
    --mimiccxr-chexpert-labels-filename "chexpert_labels_per_report__20220904_113605.pkl" \
    --classify-chest-imagenome \
    --chest-imagenome-label-names-filename "labels(min_freq=100).pkl" \
    --chest-imagenome-labels-filename "imageId2labels(min_freq=100).pkl" \
    --predict-bboxes-chest-imagenome \
    --predict-labels-and-bboxes-chest-imagenome \
    --clamp-bboxes-chest-imagenome \
    --binary-loss-name "focal+bce+wbce-c" \
    --predict-local-feature-coords \
    --local-features-width 8 \
    --local-features-height 8 \
    --embedding-dim 512 \
    --transf-dec-hidden-dim 512 \
    --transf-dec-nhead 4 \
    --transf-dec-dim-forward 512 \
    --transf-dec-num-layers 3 \
    --input-pos-encoding-mode "learned" \
    --use-medical-tokenization \
    --medical-terms-frequency-filename "medical_terms_frequency__20220918_184255.pkl" \
    --raw-image-encoding "densenet-121" \
    --image-size 256 256 \
    --image-local-feat-size 1024 \
    --num-regions 64 \
    --chexpert-mlc-version "v3" \
    --chest-imagenome-bbox-regressor-version "v4" \
    --img-aug-mode "random-color-and-spatial" \
    --use-amp \
    --save
# Out:
# script's arguments:
#    epochs: 44
#    batches_per_epoch: 400
#    batch_size: 30
#    checkpoint_folder: None
#    pretrained_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/report_gen/20230507_200753_mim_Image2ReportModel(dn121->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))
#    embedding_dim: 512
#    transf_dec_hidden_dim: 512
#    transf_dec_nhead: 4
#    transf_dec_dim_forward: 512
#    transf_dec_num_layers: 3
#    dropout_prob: 0
#    input_pos_encoding_mode: learned
#    raw_image_encoding: densenet-121
#    image_local_feat_size: 1024
#    image_encoder_pretrained_weights_path: None
#    freeze_image_encoder: False
#    image_encoder_only_compute_features: False
#    chexpert_mlc_version: v3
#    chexpert_mlc_hidden_size: 128
#    chest_imagenome_mlc_version: None
#    chest_imagenome_mlc_hidden_size: 128
#    chest_imagenome_bbox_regressor_version: v4
#    chest_imagenome_bbox_hidden_size: 128
#    num_regions: 64
# ...
