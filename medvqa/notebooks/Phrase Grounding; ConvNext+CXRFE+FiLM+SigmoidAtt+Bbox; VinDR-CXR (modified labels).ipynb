# %%
# %env CUDA_VISIBLE_DEVICES=2
# Out:
# env: CUDA_VISIBLE_DEVICES=2

# %%
# !python ../train_phrase_grounding.py \
--epochs 100 \
--batches_per_epoch 1000 \
--max_images_per_batch 12 \
--max_phrases_per_batch 1000 \
--max_phrases_per_image 30 \
--val_batch_size_factor 4 \
--raw_image_encoding "convnextmodel-huggingface" \
--huggingface_model_name "facebook/convnext-small-224" \
--img_aug_mode "random-color-and-spatial" \
--image_size 416 416 \
--image_local_feat_size 768 \
--num_regions 169 \
--regions_width 13 \
--regions_height 13 \
--phrase_embedding_size 128 \
--phrase_grounding_mode "adaptive_film_based_pooling_mlp_with_bbox_regression" \
--visual_grounding_hidden_size 256 \
--phrase_mlp_hidden_dims 256 128 \
--num_train_workers 2 \
--num_val_workers 2 \
--gradient_accumulation_steps 3 \
--optimizer_name "adamw" \
--scheduler "exp-warmup+decay+cyclicdecay" \
--lr 1e-6 \
--warmup_decay_and_cyclic_decay_args "1e-6,3,8e-5,5,1e-6,8e-5,5,1e-6" \
--binary_multilabel_classif_loss_name "focal+bce+npbbce" \
--do_visual_grounding_with_bbox_regression \
--use_vinbig_for_train \
--use_vinbig_for_test \
--vinbig_phrase_embeddings_filepath \
"/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/vinbig/label_phrase_embeddings__modified(hash=572,2522233010228708301).pkl" \
--use_vinbig_with_modified_labels \
--use_amp \
--save
# Out:
# script's arguments:
#    epochs: 100
#    batches_per_epoch: 1000
#    max_images_per_batch: 12
#    max_phrases_per_batch: 1000
#    max_phrases_per_image: 30
#    val_batch_size_factor: 4.0
#    checkpoint_folder: None
#    pretrained_checkpoint_folder_path: None
#    pretrained_checkpoint_folder_paths: None
#    freeze_image_encoder: False
#    raw_image_encoding: convnextmodel-huggingface
#    huggingface_model_name: facebook/convnext-small-224
#    num_regions: 169
#    image_local_feat_size: 768
#    image_encoder_pretrained_weights_path: None
#    image_encoder_dropout_p: 0
#    yolov8_model_name_or_path: None
#    yolov8_model_alias: None
#    phrase_embedding_size: 128
#    regions_width: 13
#    regions_height: 13
#    qkv_size: None
#    phrase_grounding_mode: adaptive_film_based_pooling_mlp_with_bbox_regression
#    phrase_classifier_hidden_size: None
#    transf_d_model: None
#    transf_nhead: None
#    transf_dim_feedforward: None
#    transf_dropout: 0
#    transf_num_layers: None
#    visual_feature_proj_size: None
#    visual_grounding_hidden_size: 256
#    phrase_mlp_hidden_dims: [256, 128]
#    predict_global_alignment: False
#    alignment_proj_size: None
#    yolov11_model_name_or_path: None
#    yolov11_model_alias: None
#    optimizer_name: adamw
#    lr: 1e-06
#    scheduler: exp-warmup+decay+cyclicdecay
#    lr_decay: 0.76
#    lr_decay_patience: 2
#    warmup_and_decay_args: None
#    warmup_and_cosine_args: None
#    warmup_decay_and_cyclic_decay_args: 1e-6,3,8e-5,5,1e-6,8e-5,5,1e-6
#    gradient_accumulation_steps: 3
#    override_lr: False
#    max_grad_norm: None
#    attention_supervision_loss_weight: 1.0
#    phrase_classifier_loss_weight: 1.0
#    foreground_loss_weight: 1.0
#    background_loss_weight: 1.0
#    focal_loss_weight: 1.0
#    bce_loss_weight: 1.0
#    wbce_loss_weight: 1.0
#    binary_multilabel_classif_loss_name: focal+bce+npbbce
#    use_weighted_phrase_classifier_loss: False
#    cluster_and_label_weights_for_facts_filepath: None
#    use_attention_regularization_loss: False
#    use_contrastive_phrase_grounding_loss: False
#    nt_xent_temperature: 0.1
#    num_train_workers: 2
#    num_val_workers: 2
#    device: GPU
#    use_amp: True
#    image_size: [416, 416]
#    dicom_id_to_pos_neg_facts_filepath: None
#    iuxray_image_id_to_pos_neg_facts_filepath: None
#    mscxr_phrase2embedding_filepath: None
#    chest_imagenome_bbox_phrase_embeddings_filepath: None
#    vinbig_phrase_embeddings_filepath: /mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/vinbig/label_phrase_embeddings__modified(hash=572,2522233010228708301).pkl
#    chexlocalize_class_phrase_embeddings_filepath: None
#    chexpert_class_phrase_embeddings_filepath: None
#    mimiccxr_exclude_noisy_images: False
#    mimiccxr_facts_weight: 1.0
#    chest_imagenome_anatlocs_weight: 1.0
#    mscxr_weight: 1.0
#    cxrlt2024_weight: 1.0
#    vinbig_weight: 1.0
#    chexlocalize_weight: 1.0
#    chexpert_weight: 1.0
#    iuxray_weight: 1.0
#    img_aug_mode: random-color-and-spatial
#    pos_area_prior: 0.4
#    neg_area_prior: 0.0
#    use_mimiccxr_facts_for_train: False
#    use_mimiccxr_facts_for_test: False
#    use_mscxr_for_train: False
#    use_mscxr_for_test: False
#    use_chest_imagenome_for_train: False
#    use_chest_imagenome_gold_for_test: False
#    use_vinbig_for_train: True
#    use_vinbig_for_test: True
#    use_chexlocalize_for_train: False
#    use_chexlocalize_for_test: False
#    use_chexpert_for_train: False
#    use_chexpert_for_test: False
#    use_iuxray_for_train: False
#    use_iuxray_for_test: False
#    use_cxrlt2024_challenge_split: False
#    use_cxrlt2024_custom_labels: False
#    use_cxrlt2024_official_labels: False
#    use_all_cxrlt2024_official_labels_for_training: False
#    vinbig_training_data_mode: train
#    chexpert_training_data_mode: all
#    mimiccxr_balance_long_middle_short_tail: False
#    mimiccxr_long_middle_short_tail_thresholds: (0.02, 0.05)
#    mimiccxr_report_fact_nli_integrated_data_filepath: None
#    mimiccxr_use_interpret_cxr_challenge_split: False
#    mimiccxr_interpret_cxr_challenge_split_filepath: None
#    iuxray_use_interpret_cxr_challenge_split: False
#    iuxray_interpret_cxr_challenge_split_filepath: None
#    chexpert_use_interpret_cxr_challenge_split: False
#    chexpert_interpret_cxr_challenge_split_filepath: None
#    chexlocalize_use_interpret_cxr_challenge_split: False
#    chexlocalize_interpret_cxr_challenge_split_filepath: None
#    cxrlt2024_custom_dicom_id_to_pos_neg_facts_filepath: None
#    cxrlt2024_official_training_labels_for_fact_classification_filepath: None
#    cxrlt2024_do_balanced_sampling: False
#    do_visual_grounding_with_bbox_regression: True
#    do_visual_grounding_with_segmentation: False
#    replace_phrase_embeddings_with_random_vectors: False
#    use_vinbig_with_modified_labels: True
#    save: True
# ----- Training model from scratch ------
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Creating instance of PhraseGrounder ...
# WARNING: Unused kwargs: {'pretrained_checkpoint_folder_path': None, 'pretrained_checkpoint_folder_paths': None}
# MultiPurposeVisualModule()
#   Initializing raw_image_encoder: convnextmodel-huggingface
#   self.global_feat_size = 768
#   self.local_feat_size = 768
#   Initializing auxiliary tasks
# Using positional encoding for local features
# BoundingBoxRegressorSingleClass
#   local_feat_dim: 256
# --------------------------------------------------
# 3) Defining optimizer ...
# create_optimizer(): name = adamw
# --------------------------------------------------
# 4) Defining scheduler ...
# Using exp-warmup+decay+cyclicdecay scheduler: 1e-6,3,8e-5,5,1e-6,8e-5,5,1e-6
# 1e-06 3 8e-05 5 1e-06 8e-05 5 1e-06
# self.steps_to_restart = 5
# self.steps = -1
# self.initial_lr = 8e-05
# --------------------------------------------------
# 5) Creating trainer and validator engines ...
# Focal_BCE_NPBBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 npbbce_weight = 0.3333333333333333
# Focal_BCE_NPBBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 npbbce_weight = 0.3333333333333333
# Focal_BCE_WBCBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 wbcbce_weight = 0.3333333333333333
# foreground_loss_weight: 1.0
# background_loss_weight: 1.0
# GradientAccumulator.__init__(): num_accumulation_steps = 3, max_grad_norm = None
# Focal_BCE_NPBBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 npbbce_weight = 0.3333333333333333
# Focal_BCE_NPBBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 npbbce_weight = 0.3333333333333333
# Focal_BCE_WBCBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 wbcbce_weight = 0.3333333333333333
# foreground_loss_weight: 1.0
# background_loss_weight: 1.0
# --------------------------------------------------
# 6) Creating VinBig Phrase Grounding Trainer ...
# get_image_transform()
#   image_size = [416, 416]
#   mean = [0.485, 0.456, 0.406]
#   std = [0.229, 0.224, 0.225]
#   Using bounding box aware transforms
#     augmentation_mode = random-color-and-spatial
#     default_prob = 0.35
#     for_vinbig: returning vinbig transform
# get_train_transform(): Using bbox-aware transforms for VinBigData
#     Returning augmented transform with mode random-color-and-spatial
# get_image_transform()
#   image_size = [416, 416]
#   mean = [0.485, 0.456, 0.406]
#   std = [0.229, 0.224, 0.225]
#   Using bounding box aware transforms
#     Returning default transform (no augmentation)
# NOTE: Improving VinDr-CXR classification labels ...
# Loading bounding boxes
# Anomalous bboxes found: 29 of 37367
# NOTE: Improving VinDr-CXR bbox labels ...
# class_id_offset: 0
# Anomalous bboxes found: 0 of 2697
# NOTE: Improving VinDr-CXR bbox labels ...
# class_id_offset: 0
#   Loaded 18000 bounding boxes
# Loding phrase_embeddings and phrases from /mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/vinbig/label_phrase_embeddings__modified(hash=572,2522233010228708301).pkl...
# phrase_embeddings.shape = (28, 128)
# phrase_embeddings.dtype = float32
# len(phrases) = 28
# Compute phrase grounding masks and labels
# vinbig_bbox_names = ['Aortic enlargement', 'Atelectasis', 'Calcification', 'Cardiomegaly', 'Clavicle fracture', 'Consolidation', 'Edema', 'Emphysema', 'Enlarged PA', 'ILD', 'Infiltration', 'Lung Opacity', 'Lung cavity', 'Lung cyst', 'Mediastinal shift', 'Nodule/Mass', 'Other lesion', 'Pleural effusion', 'Pleural thickening', 'Pneumothorax', 'Pulmonary fibrosis', 'Rib fracture', 'Abnormal finding']
# vinbig_labels = ['Aortic enlargement', 'Atelectasis', 'Calcification', 'Cardiomegaly', 'Clavicle fracture', 'Consolidation', 'Edema', 'Emphysema', 'Enlarged PA', 'ILD', 'Infiltration', 'Lung Opacity', 'Lung cavity', 'Lung cyst', 'Mediastinal shift', 'Nodule/Mass', 'Pleural effusion', 'Pleural thickening', 'Pneumothorax', 'Pulmonary fibrosis', 'Rib fracture', 'Other lesion', 'COPD', 'Lung tumor', 'Pneumonia', 'Tuberculosis', 'Other disease', 'Abnormal finding']
# num_bbox_classes = 23
# self.phrase_grounding_masks.shape = (18000, 23, 169)
# self.phrase_classification_labels.shape = (18000, 23)
# Append additional labels to phrase_classification_labels
# len(non_bbox_labels) = 5
# non_bbox_labels = ['COPD', 'Lung tumor', 'Pneumonia', 'Tuberculosis', 'Other disease']
# self.phrase_classification_labels.shape = (18000, 28)
# Reorder phrases and phrase_embeddings
# len(phrases) = 28
# len(sorted_phrases) = 28
# phrase_embeddings.shape = (28, 128)
# 	aortic enlargement seen (Aortic enlargement)
# 	atelectasis seen (Atelectasis)
# 	calcification seen (Calcification)
# 	cardiomegaly seen (Cardiomegaly)
# 	clavicle fracture seen (Clavicle fracture)
# 	consolidation seen (Consolidation)
# 	edema seen (Edema)
# 	emphysema seen (Emphysema)
# 	enlarged pulmonary artery seen (Enlarged PA)
# 	interstitial lung disease seen (ILD)
# 	infiltration seen (Infiltration)
# 	lung opacity seen (Lung Opacity)
# 	lung cavity seen (Lung cavity)
# 	lung cyst seen (Lung cyst)
# 	mediastinal shift seen (Mediastinal shift)
# 	nodule/mass seen (Nodule/Mass)
# 	other lesion seen (Other lesion)
# 	pleural effusion seen (Pleural effusion)
# 	pleural thickening seen (Pleural thickening)
# 	pneumothorax seen (Pneumothorax)
# 	pulmonary fibrosis seen (Pulmonary fibrosis)
# 	rib fracture seen (Rib fracture)
# 	abnormal findings seen (Abnormal finding)
# 	copd seen (COPD)
# 	lung tumor seen (Lung tumor)
# 	pneumonia seen (Pneumonia)
# 	tuberculosis seen (Tuberculosis)
# 	other disease seen (Other disease)
# Generating train dataset and dataloader
# len(train_indices) = 15000
# Edema: 13
# Clavicle fracture: 27
# Lung cyst: 33
# COPD: 36
# Lung cavity: 51
# Emphysema: 81
# Rib fracture: 90
# Pneumothorax: 96
# Enlarged PA: 131
# Mediastinal shift: 150
# Atelectasis: 187
# Lung tumor: 291
# Consolidation: 353
# ILD: 397
# Calcification: 458
# Infiltration: 613
# Tuberculosis: 750
# Nodule/Mass: 841
# Pneumonia: 919
# Pleural effusion: 1038
# Other lesion: 1154
# Pulmonary fibrosis: 1621
# Pleural thickening: 2010
# Cardiomegaly: 2316
# Lung Opacity: 2709
# Aortic enlargement: 3098
# Other disease: 4377
# Abnormal finding: 4522
# No labels: 10478
# Group sizes: [10478, 794, 341, 312, 286, 278, 258, 243, 241, 218, 215, 198, 159, 156, 122, 119, 114, 102, 91, 83, 79, 63, 50]
#   len(indices) = 10478, weight = 2381.9852437292775
#   len(indices) = 794, weight = 893.8899020987899
#   len(indices) = 341, weight = 595.5934427021492
#   len(indices) = 312, weight = 568.7753795323758
#   len(indices) = 286, weight = 543.3127950518186
#   len(indices) = 278, weight = 535.1778961104801
#   len(indices) = 258, weight = 514.1586596868186
#   len(indices) = 243, weight = 497.69925147612867
#   len(indices) = 241, weight = 495.4562099629317
#   len(indices) = 218, weight = 468.76865710351854
#   len(indices) = 215, weight = 465.15882500917724
#   len(indices) = 198, weight = 444.08258972130596
#   len(indices) = 159, weight = 391.0802349542582
#   len(indices) = 156, weight = 386.6879164039802
#   len(indices) = 122, weight = 332.9187999914028
#   len(indices) = 119, weight = 327.76937690454827
#   len(indices) = 114, weight = 319.0166061056533
#   len(indices) = 102, weight = 297.0647831080699
#   len(indices) = 91, weight = 275.6141558688678
#   len(indices) = 83, weight = 259.088791948487
#   len(indices) = 79, weight = 250.497443897163
#   len(indices) = 63, weight = 213.55551164361594
#   len(indices) = 50, weight = 179.7743872238934
# batch_size = 12
# Generating val dataset and dataloader
# len(test_indices) = 3000
# batch_size = 48
# --------------------------------------------------
# 7) Creating dataloaders ...
# len(vinbig_trainer.train_dataloader) = 83333333333333334
# len(vinbig_trainer.val_dataloader) = 63
# len(_train_dataloaders) = 1
# len(_val_dataloaders) = 1
# _train_weights = [1.0]
# merged_dataset_name = vinbig
# --------------------------------------------------
# 8) Attaching metrics, losses, timer and events to engines ...
# --------------------------------------------------
# 9) Defining learning rate scheduler handler ...
# --------------------------------------------------
# 10) Defining checkpoint folder path ...
# checkpoint_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250215_012801_vinbig_PhraseGrounder(facebook-convnext-small-224,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)
# metadata saved to /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250215_012801_vinbig_PhraseGrounder(facebook-convnext-small-224,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/metadata.json
# --------------------------------------------------
# 11) Defining log_metrics_handler ...
# MetricsLogger :: we'll be logging to /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250215_012801_vinbig_PhraseGrounder(facebook-convnext-small-224,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/metrics_logs.csv
# --------------------------------------------------
# 12) Running trainer engine ...
# ---- Epoch 1/100
# (1) Training stage (lr = 0.000001) ...
# loss 4.63419, vbg_vgbbox_loss 1.59726, vbg_att_sup_loss 1.34321, vbg_phrcls_loss 1.69373, vbg_prc_auc 0.18466, 267.35 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.04720, vbg_prc_auc 0.06342, 69.31 secs
# Train metrics:
# vbg_vgbbox_loss: 0.3850, weight = 1.0
# vbg_att_sup_loss: 0.4268, weight = 1.0
# vbg_prc_auc: 0.1847, weight = 10.0
# num = 2.6583, den = 12.0000, score = 0.2215
# Val metrics:
# vbg_bbox_iou: 0.0472, weight = 1.0
# vbg_prc_auc: 0.0634, weight = 10.0
# num = 0.6814, den = 11.0000, score = 0.0619
# Train score = 0.2215, Val score = 0.0619, Final score = 0.0699
# w_train = 0.05, w_val = 0.95
# New checkpoint saved: checkpoint_1_vbss+vbou+vbuc+vbss=0.0699.pt
# ---- Epoch 2/100
# (1) Training stage (lr = 0.000004) ...
# loss 3.18942, vbg_vgbbox_loss 0.53416, vbg_att_sup_loss 1.16299, vbg_phrcls_loss 1.49227, vbg_prc_auc 0.18691, 279.66 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.09113, vbg_prc_auc 0.10024, 45.74 secs
# New checkpoint saved: checkpoint_2_vbss+vbou+vbuc+vbss=0.1069.pt
# ---- Epoch 3/100
# (1) Training stage (lr = 0.000019) ...
# loss 2.32051, vbg_vgbbox_loss 0.34683, vbg_att_sup_loss 0.72017, vbg_phrcls_loss 1.25351, vbg_prc_auc 0.26939, 280.50 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.14188, vbg_prc_auc 0.25179, 46.95 secs
# New checkpoint saved: checkpoint_3_vbss+vbou+vbuc+vbss=0.2465.pt
# ---- Epoch 4/100
# (1) Training stage (lr = 0.000080) ...
# loss 1.90976, vbg_vgbbox_loss 0.31991, vbg_att_sup_loss 0.52655, vbg_phrcls_loss 1.06330, vbg_prc_auc 0.36686, 280.84 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.15632, vbg_prc_auc 0.33853, 41.90 secs
# New checkpoint saved: checkpoint_4_vbss+vbou+vbuc+vbss=0.3270.pt
# ---- Epoch 5/100
# (1) Training stage (lr = 0.000033) ...
# loss 1.63710, vbg_vgbbox_loss 0.26304, vbg_att_sup_loss 0.43264, vbg_phrcls_loss 0.94142, vbg_prc_auc 0.43308, 279.60 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.17373, vbg_prc_auc 0.35746, 44.48 secs
# New checkpoint saved: checkpoint_5_vbss+vbou+vbuc+vbss=0.3480.pt
# ---- Epoch 6/100
# (1) Training stage (lr = 0.000014) ...
# loss 1.53850, vbg_vgbbox_loss 0.24827, vbg_att_sup_loss 0.40306, vbg_phrcls_loss 0.88718, vbg_prc_auc 0.46957, 284.08 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.17936, vbg_prc_auc 0.36857, 43.20 secs
# New checkpoint saved: checkpoint_6_vbss+vbou+vbuc+vbss=0.3597.pt
# ---- Epoch 7/100
# (1) Training stage (lr = 0.000006) ...
# loss 1.50043, vbg_vgbbox_loss 0.24599, vbg_att_sup_loss 0.39194, vbg_phrcls_loss 0.86249, vbg_prc_auc 0.49097, 283.20 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.17937, vbg_prc_auc 0.36821, 43.07 secs
# New checkpoint saved: checkpoint_7_vbss+vbou+vbuc+vbss=0.3603.pt
# ---- Epoch 8/100
# (1) Training stage (lr = 0.000002) ...
# loss 1.48279, vbg_vgbbox_loss 0.24289, vbg_att_sup_loss 0.38662, vbg_phrcls_loss 0.85329, vbg_prc_auc 0.49885, 276.94 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.17984, vbg_prc_auc 0.37084, 42.90 secs
# New checkpoint saved: checkpoint_8_vbss+vbou+vbuc+vbss=0.3629.pt
# ---- Epoch 9/100
# (1) Training stage (lr = 0.000001) ...
# loss 1.46707, vbg_vgbbox_loss 0.24097, vbg_att_sup_loss 0.38360, vbg_phrcls_loss 0.84250, vbg_prc_auc 0.50542, 275.87 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.17837, vbg_prc_auc 0.36849, 42.72 secs
# ---- Epoch 10/100
# (1) Training stage (lr = 0.000080) ...
# loss 1.52847, vbg_vgbbox_loss 0.26518, vbg_att_sup_loss 0.39255, vbg_phrcls_loss 0.87074, vbg_prc_auc 0.49320, 283.41 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.17678, vbg_prc_auc 0.39578, 42.37 secs
# New checkpoint saved: checkpoint_10_vbss+vbou+vbuc+vbss=0.3839.pt
# ---- Epoch 11/100
# (1) Training stage (lr = 0.000027) ...
# loss 1.36924, vbg_vgbbox_loss 0.23655, vbg_att_sup_loss 0.34898, vbg_phrcls_loss 0.78371, vbg_prc_auc 0.57055, 283.27 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.19191, vbg_prc_auc 0.40287, 42.45 secs
# New checkpoint saved: checkpoint_11_vbss+vbou+vbuc+vbss=0.3947.pt
# ---- Epoch 12/100
# (1) Training stage (lr = 0.000009) ...
# loss 1.30232, vbg_vgbbox_loss 0.22775, vbg_att_sup_loss 0.33187, vbg_phrcls_loss 0.74270, vbg_prc_auc 0.60301, 282.98 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.19314, vbg_prc_auc 0.40959, 42.22 secs
# New checkpoint saved: checkpoint_12_vbss+vbou+vbuc+vbss=0.4021.pt
# ---- Epoch 13/100
# (1) Training stage (lr = 0.000003) ...
# loss 1.27256, vbg_vgbbox_loss 0.22487, vbg_att_sup_loss 0.32692, vbg_phrcls_loss 0.72076, vbg_prc_auc 0.61961, 282.22 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.19633, vbg_prc_auc 0.40481, 42.62 secs
# ---- Epoch 14/100
# (1) Training stage (lr = 0.000001) ...
# loss 1.26753, vbg_vgbbox_loss 0.22464, vbg_att_sup_loss 0.32343, vbg_phrcls_loss 0.71946, vbg_prc_auc 0.62772, 278.91 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.19415, vbg_prc_auc 0.40693, 41.86 secs
# ---- Epoch 15/100
# (1) Training stage (lr = 0.000080) ...
# loss 1.35453, vbg_vgbbox_loss 0.24535, vbg_att_sup_loss 0.33983, vbg_phrcls_loss 0.76935, vbg_prc_auc 0.58546, 283.14 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.18738, vbg_prc_auc 0.41565, 42.94 secs
# New checkpoint saved: checkpoint_15_vbss+vbou+vbuc+vbss=0.4060.pt
# ---- Epoch 16/100
# (1) Training stage (lr = 0.000027) ...
# loss 1.19782, vbg_vgbbox_loss 0.22429, vbg_att_sup_loss 0.30319, vbg_phrcls_loss 0.67034, vbg_prc_auc 0.66843, 282.19 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.19331, vbg_prc_auc 0.41798, 41.99 secs
# New checkpoint saved: checkpoint_16_vbss+vbou+vbuc+vbss=0.4121.pt
# ---- Epoch 17/100
# (1) Training stage (lr = 0.000009) ...
# loss 1.12988, vbg_vgbbox_loss 0.21678, vbg_att_sup_loss 0.28921, vbg_phrcls_loss 0.62388, vbg_prc_auc 0.70638, 281.54 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.19623, vbg_prc_auc 0.41670, 41.83 secs
# New checkpoint saved: checkpoint_17_vbss+vbou+vbuc+vbss=0.4129.pt
# ---- Epoch 18/100
# (1) Training stage (lr = 0.000003) ...
# loss 1.10187, vbg_vgbbox_loss 0.21400, vbg_att_sup_loss 0.28317, vbg_phrcls_loss 0.60470, vbg_prc_auc 0.72553, 278.41 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.19234, vbg_prc_auc 0.41851, 41.92 secs
# New checkpoint saved: checkpoint_18_vbss+vbou+vbuc+vbss=0.4150.pt
# ---- Epoch 19/100
# (1) Training stage (lr = 0.000001) ...
# loss 1.09782, vbg_vgbbox_loss 0.21407, vbg_att_sup_loss 0.28370, vbg_phrcls_loss 0.60004, vbg_prc_auc 0.72344, 277.40 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.19982, vbg_prc_auc 0.41545, 41.48 secs
# ---- Epoch 20/100
# (1) Training stage (lr = 0.000080) ...
# loss 1.19368, vbg_vgbbox_loss 0.23463, vbg_att_sup_loss 0.30132, vbg_phrcls_loss 0.65773, vbg_prc_auc 0.67331, 281.48 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.18830, vbg_prc_auc 0.41644, 41.70 secs
# ---- Epoch 21/100
# (1) Training stage (lr = 0.000027) ...
# loss 1.04927, vbg_vgbbox_loss 0.21391, vbg_att_sup_loss 0.27020, vbg_phrcls_loss 0.56516, vbg_prc_auc 0.76356, 280.27 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.19731, vbg_prc_auc 0.42068, 41.71 secs
# New checkpoint saved: checkpoint_21_vbss+vbou+vbuc+vbss=0.4189.pt
# ---- Epoch 22/100
# (1) Training stage (lr = 0.000009) ...
# loss 0.97647, vbg_vgbbox_loss 0.20973, vbg_att_sup_loss 0.25610, vbg_phrcls_loss 0.51065, vbg_prc_auc 0.80644, 280.12 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.19927, vbg_prc_auc 0.42324, 41.25 secs
# New checkpoint saved: checkpoint_22_vbss+vbou+vbuc+vbss=0.4231.pt
# ---- Epoch 23/100
# (1) Training stage (lr = 0.000003) ...
# loss 0.95152, vbg_vgbbox_loss 0.20706, vbg_att_sup_loss 0.25086, vbg_phrcls_loss 0.49360, vbg_prc_auc 0.82403, 279.97 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.20135, vbg_prc_auc 0.43215, 41.22 secs
# New checkpoint saved: checkpoint_23_vbss+vbou+vbuc+vbss=0.4317.pt
# ---- Epoch 24/100
# (1) Training stage (lr = 0.000001) ...
# loss 0.94080, vbg_vgbbox_loss 0.20596, vbg_att_sup_loss 0.24954, vbg_phrcls_loss 0.48530, vbg_prc_auc 0.83078, 280.90 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.20295, vbg_prc_auc 0.42676, 41.34 secs
# ---- Epoch 25/100
# (1) Training stage (lr = 0.000080) ...
# loss 1.06597, vbg_vgbbox_loss 0.22630, vbg_att_sup_loss 0.27577, vbg_phrcls_loss 0.56390, vbg_prc_auc 0.75687, 279.40 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.19234, vbg_prc_auc 0.42275, 41.17 secs
# ---- Epoch 26/100
# (1) Training stage (lr = 0.000027) ...
# loss 0.92011, vbg_vgbbox_loss 0.20900, vbg_att_sup_loss 0.24497, vbg_phrcls_loss 0.46614, vbg_prc_auc 0.84713, 279.39 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.19757, vbg_prc_auc 0.42866, 41.52 secs
# ---- Epoch 27/100
# (1) Training stage (lr = 0.000009) ...
# loss 0.85390, vbg_vgbbox_loss 0.20196, vbg_att_sup_loss 0.23343, vbg_phrcls_loss 0.41852, vbg_prc_auc 0.88136, 273.33 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.20120, vbg_prc_auc 0.42628, 41.00 secs
# ---- Epoch 28/100
# (1) Training stage (lr = 0.000003) ...
# loss 0.82693, vbg_vgbbox_loss 0.19934, vbg_att_sup_loss 0.22790, vbg_phrcls_loss 0.39970, vbg_prc_auc 0.89775, 274.54 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.19669, vbg_prc_auc 0.42523, 41.14 secs
# ---- Epoch 29/100
# (1) Training stage (lr = 0.000001) ...
# loss 0.81487, vbg_vgbbox_loss 0.19873, vbg_att_sup_loss 0.22703, vbg_phrcls_loss 0.38910, vbg_prc_auc 0.90254, 278.44 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.20202, vbg_prc_auc 0.42335, 41.22 secs
# ---- Epoch 30/100
# (1) Training stage (lr = 0.000080) ...
# ^C
# Engine run is terminating due to exception:
# Traceback (most recent call last):
#   File "/home/pamessina/medvqa/medvqa/notebooks/../train_phrase_grounding.py", line 1552, in <module>
#     train_from_scratch(**args)
#   File "/home/pamessina/medvqa/medvqa/notebooks/../train_phrase_grounding.py", line 1418, in train_from_scratch
#     return train_model(
#   File "/home/pamessina/medvqa/medvqa/notebooks/../train_phrase_grounding.py", line 926, in train_model
#     run_common_boilerplate_code_and_start_training(
#   File "/home/pamessina/medvqa/medvqa/training/utils.py", line 137, in run_common_boilerplate_code_and_start_training
#     trainer_engine.run(train_dataloader, max_epochs=epochs, epoch_length=batches_per_epoch)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 892, in run
#     return self._internal_run()
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 935, in _internal_run
#     return next(self._internal_run_generator)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 993, in _internal_run_as_gen
#     self._handle_exception(e)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 638, in _handle_exception
#     raise e
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 959, in _internal_run_as_gen
#     epoch_time_taken += yield from self._run_once_on_dataset_as_gen()
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 1068, in _run_once_on_dataset_as_gen
#     self.state.output = self._process_function(self, self.state.batch)
#   File "/home/pamessina/medvqa/medvqa/training/phrase_grounding.py", line 991, in step_fn
#     output = flag_to_step_fn[flag](batch)
#   File "/home/pamessina/medvqa/medvqa/training/phrase_grounding.py", line 622, in step_fn__vinbig_bbox_grounding
#     gradient_accumulator.step(batch_loss, model)
#   File "/home/pamessina/medvqa/medvqa/losses/optimizers.py", line 35, in step
#     self.scaler.step(self.optimizer)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/amp/grad_scaler.py", line 453, in step
#     retval = self._maybe_opt_step(optimizer, optimizer_state, *args, **kwargs)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/amp/grad_scaler.py", line 351, in _maybe_opt_step
#     retval = optimizer.step(*args, **kwargs)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/optim/lr_scheduler.py", line 75, in wrapper
#     return wrapped(*args, **kwargs)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/optim/optimizer.py", line 391, in wrapper
#     out = func(*args, **kwargs)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/optim/optimizer.py", line 76, in _use_grad
#     ret = func(self, *args, **kwargs)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/optim/adamw.py", line 188, in step
#     adamw(
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/optim/adamw.py", line 340, in adamw
#     func(
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/optim/adamw.py", line 600, in _multi_tensor_adamw
#     bias_correction2_sqrt = [_dispatch_sqrt(bc) for bc in bias_correction2]
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/optim/adamw.py", line 600, in <listcomp>
#     bias_correction2_sqrt = [_dispatch_sqrt(bc) for bc in bias_correction2]
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/optim/optimizer.py", line 101, in _dispatch_sqrt
#     return math.sqrt(x)
# KeyboardInterrupt
