# %%
# %env CUDA_VISIBLE_DEVICES=1
# Out:
# env: CUDA_VISIBLE_DEVICES=1

# %%
# !/home/pamessina/venv2/bin/python ../train_yolov8.py \
    --decent-images-only \
    --epochs 5 \
    --model-name-or-path "yolov8l.pt" \
    --batch-size 25 \
    --workers 5
# Out:
# script's arguments:
#    model_name_or_path: yolov8l.pt
#    decent_images_only: True
#    validation_only: False
#    image_size: 416
#    batch_size: 25
#    epochs: 5
#    workers: 5
#    debug: False
# Found /home/pamessina/medvqa-workspace/cache/chest_imagenome/yolov5/images/train(decent_images_only).txt
# Found /home/pamessina/medvqa-workspace/cache/chest_imagenome/yolov5/images/val(decent_images_only).txt
# Found /home/pamessina/medvqa-workspace/cache/chest_imagenome/yolov5/images/test(decent_images_only).txt
# Found /mnt/workspace/mimic-cxr-jpg/chest_imagenome_yolov5_labels
# Found /home/pamessina/medvqa-workspace/cache/chest_imagenome/yolov5/config(decent_images_only).yaml
# Ultralytics YOLOv8.0.58 🚀 Python-3.10.10 torch-1.13.1+cu117 CUDA:0 (GeForce RTX 2080 Ti, 11019MiB)
# yolo/engine/trainer: task=detect, mode=train, model=yolov8l.pt, data=/home/pamessina/medvqa-workspace/cache/chest_imagenome/yolov5/config(decent_images_only).yaml, epochs=5, patience=50, batch=25, imgsz=416, save=True, save_period=-1, cache=False, device=None, workers=5, project=/home/pamessina/medvqa-workspace/cache/chest_imagenome, name=None, exist_ok=False, pretrained=False, optimizer=SGD, verbose=True, seed=0, deterministic=True, single_cls=False, image_weights=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, hide_labels=False, hide_conf=False, vid_stride=1, line_thickness=3, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, fl_gamma=0.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, v5loader=False, tracker=botsort.yaml, save_dir=/home/pamessina/medvqa-workspace/cache/chest_imagenome/train4
#
#
# *** DEBUG (ultralytics/yolo/engine/trainer.py): self.data = {'path': '/home/pamessina/medvqa-workspace/cache/chest_imagenome/yolov5', 'train': '/home/pamessina/medvqa-workspace/cache/chest_imagenome/yolov5/images/train(decent_images_only).txt', 'val': '/home/pamessina/medvqa-workspace/cache/chest_imagenome/yolov5/images/val(decent_images_only).txt', 'test': '/home/pamessina/medvqa-workspace/cache/chest_imagenome/yolov5/images/test(decent_images_only).txt', 'source_pattern': '/mnt/workspace/mimic-cxr-jpg/images-medium(512)', 'target_pattern': '/mnt/workspace/mimic-cxr-jpg/chest_imagenome_yolov5_labels', 'nc': 36, 'names': {0: 'right lung', 1: 'right upper lung zone', 2: 'right mid lung zone', 3: 'right lower lung zone', 4: 'right hilar structures', 5: 'right apical zone', 6: 'right costophrenic angle', 7: 'right cardiophrenic angle', 8: 'right hemidiaphragm', 9: 'left lung', 10: 'left upper lung zone', 11: 'left mid lung zone', 12: 'left lower lung zone', 13: 'left hilar structures', 14: 'left apical zone', 15: 'left costophrenic angle', 16: 'left hemidiaphragm', 17: 'trachea', 18: 'spine', 19: 'right clavicle', 20: 'left clavicle', 21: 'aortic arch', 22: 'mediastinum', 23: 'upper mediastinum', 24: 'svc', 25: 'cardiac silhouette', 26: 'left cardiac silhouette', 27: 'right cardiac silhouette', 28: 'cavoatrial junction', 29: 'right atrium', 30: 'descending aorta', 31: 'carina', 32: 'left upper abdomen', 33: 'right upper abdomen', 34: 'abdomen', 35: 'left cardiophrenic angle'}, 'yaml_file': '/home/pamessina/medvqa-workspace/cache/chest_imagenome/yolov5/config(decent_images_only).yaml'}
# Using custom path_transform_fn
# source_pattern =  /mnt/workspace/mimic-cxr-jpg/images-medium(512)
# target_pattern =  /mnt/workspace/mimic-cxr-jpg/chest_imagenome_yolov5_labels
#
# Overriding model.yaml nc=80 with nc=36
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.Conv                  [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.Conv                  [64, 128, 3, 2]
#   2                  -1  3    279808  ultralytics.nn.modules.C2f                   [128, 128, 3, True]
#   3                  -1  1    295424  ultralytics.nn.modules.Conv                  [128, 256, 3, 2]
#   4                  -1  6   2101248  ultralytics.nn.modules.C2f                   [256, 256, 6, True]
#   5                  -1  1   1180672  ultralytics.nn.modules.Conv                  [256, 512, 3, 2]
#   6                  -1  6   8396800  ultralytics.nn.modules.C2f                   [512, 512, 6, True]
#   7                  -1  1   2360320  ultralytics.nn.modules.Conv                  [512, 512, 3, 2]
#   8                  -1  3   4461568  ultralytics.nn.modules.C2f                   [512, 512, 3, True]
#   9                  -1  1    656896  ultralytics.nn.modules.SPPF                  [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.Concat                [1]
#  12                  -1  3   4723712  ultralytics.nn.modules.C2f                   [1024, 512, 3]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.Concat                [1]
#  15                  -1  3   1247744  ultralytics.nn.modules.C2f                   [768, 256, 3]
#  16                  -1  1    590336  ultralytics.nn.modules.Conv                  [256, 256, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.Concat                [1]
#  18                  -1  3   4592640  ultralytics.nn.modules.C2f                   [768, 512, 3]
#  19                  -1  1   2360320  ultralytics.nn.modules.Conv                  [512, 512, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.Concat                [1]
#  21                  -1  3   4723712  ultralytics.nn.modules.C2f                   [1024, 512, 3]
#  22        [15, 18, 21]  1   5610556  ultralytics.nn.modules.Detect                [36, [256, 512, 512]]
# Model summary: 365 layers, 43657596 parameters, 43657580 gradients, 165.6 GFLOPs
#
# Transferred 589/595 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir /home/pamessina/medvqa-workspace/cache/chest_imagenome/train4', view at http://localhost:6006/
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 97 weight(decay=0.0), 104 weight(decay=0.0005859375000000001), 103 bias
# train: Scanning /mnt/workspace/mimic-cxr-jpg/chest_imagenome_yolov5_labels/p10/p
# val: Scanning /mnt/workspace/mimic-cxr-jpg/chest_imagenome_yolov5_labels/p10/p10
# Plotting labels to /home/pamessina/medvqa-workspace/cache/chest_imagenome/train4/labels.jpg...
# Image sizes 416 train, 416 val
# Using 5 dataloader workers
# Logging results to /home/pamessina/medvqa-workspace/cache/chest_imagenome/train4
# Starting training for 5 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         1/5      6.98G      1.179     0.8584      1.388        950        416: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1934      69098       0.92      0.872      0.914      0.667
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         2/5      9.49G      1.008     0.5536      1.249       1214        416: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1934      69098      0.924      0.883      0.923      0.687
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         3/5      9.49G      1.003     0.5471      1.246       1292        416: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1934      69098      0.926      0.886      0.925      0.694
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         4/5      9.49G     0.9618     0.5198      1.223       1396        416: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1934      69098      0.926      0.882      0.925      0.694
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         5/5      9.49G     0.9457     0.5083      1.214       1035        416: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1934      69098      0.928      0.879      0.924      0.693
#
# 5 epochs completed in 4.542 hours.
# Optimizer stripped from /home/pamessina/medvqa-workspace/cache/chest_imagenome/train4/weights/last.pt, 87.6MB
# Optimizer stripped from /home/pamessina/medvqa-workspace/cache/chest_imagenome/train4/weights/best.pt, 87.6MB
#
# Validating /home/pamessina/medvqa-workspace/cache/chest_imagenome/train4/weights/best.pt...
# Ultralytics YOLOv8.0.58 🚀 Python-3.10.10 torch-1.13.1+cu117 CUDA:0 (GeForce RTX 2080 Ti, 11019MiB)
# Model summary (fused): 268 layers, 43634364 parameters, 0 gradients, 165.0 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mWARNING ⚠️ NMS time limit 3.000s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1934      69098      0.926      0.872      0.914      0.685
#             right lung       1934       1934      0.965      0.971      0.986      0.912
#  right upper lung zone       1934       1932       0.99      0.966      0.983       0.87
#    right mid lung zone       1934       1896      0.938      0.923      0.953      0.771
#  right lower lung zone       1934       1896      0.932      0.922      0.956      0.805
# right hilar structures       1934       1895      0.948      0.938      0.959      0.761
#      right apical zone       1934       1895      0.953       0.93      0.961      0.769
# right costophrenic angle       1934       1919      0.908       0.75      0.828      0.566
# right cardiophrenic angle       1934       1926      0.828      0.625      0.724      0.385
#    right hemidiaphragm       1934       1927      0.886       0.83      0.909      0.677
#              left lung       1934       1933      0.962      0.973      0.986       0.88
#   left upper lung zone       1934       1926      0.983       0.95      0.976      0.858
#     left mid lung zone       1934       1886      0.952      0.929      0.955      0.756
#   left lower lung zone       1934       1888       0.91      0.903      0.942      0.759
#  left hilar structures       1934       1886      0.943      0.934      0.949      0.728
#       left apical zone       1934       1886      0.954      0.921      0.955      0.766
# left costophrenic angle       1934       1924      0.881      0.651      0.754      0.482
#     left hemidiaphragm       1934       1929      0.864       0.81      0.894      0.613
#                trachea       1934       1930      0.931      0.899      0.932      0.586
#                  spine       1934       1930      0.992      0.974       0.98      0.765
#         right clavicle       1934       1919      0.922      0.836      0.914       0.69
#          left clavicle       1934       1915      0.928      0.838      0.906      0.658
#            aortic arch       1934       1914      0.951      0.883      0.919      0.658
#            mediastinum       1934       1934      0.945      0.947       0.97      0.787
#      upper mediastinum       1934       1933      0.964       0.94      0.957      0.749
#                    svc       1934       1928      0.932      0.894      0.913      0.635
#     cardiac silhouette       1934       1934      0.909      0.908      0.943      0.717
# left cardiac silhouette       1934       1930       0.94      0.919      0.954      0.691
# right cardiac silhouette       1934       1930       0.93      0.898       0.92      0.595
#    cavoatrial junction       1934       1927      0.879      0.724        0.8      0.422
#           right atrium       1934       1929      0.927      0.865        0.9      0.547
#       descending aorta       1934       1929      0.911      0.885      0.922      0.565
#                 carina       1934       1921      0.725      0.566      0.633      0.249
#     left upper abdomen       1934       1930      0.966       0.97      0.985      0.855
#    right upper abdomen       1934       1930      0.955      0.957      0.969      0.869
#                abdomen       1934       1930      0.963      0.978      0.987      0.895
# left cardiophrenic angle       1934       1927      0.857       0.59      0.731      0.383
# Speed: 0.1ms preprocess, 5.2ms inference, 0.0ms loss, 3.9ms postprocess per image
# Results saved to /home/pamessina/medvqa-workspace/cache/chest_imagenome/train4

# %%
# !/home/pamessina/venv2/bin/python ../eval_yolov8.py \
    --eval-dataset-name "chest_imagenome__mimiccxr_test_set" \
    --weights-path "/home/pamessina/medvqa-workspace/cache/chest_imagenome/train4/weights/best.pt" \
    --decent-images-only
# Out:
# script's arguments:
#    eval_dataset_name: chest_imagenome__mimiccxr_test_set
#    weights_path: /home/pamessina/medvqa-workspace/cache/chest_imagenome/train4/weights/best.pt
#    decent_images_only: True
#    conf: 0.1
#    max_det: 36
#    save_predictions: False
# --------------------------------------------------
# Evaluating YOLOv8
#
# 1) Preparing eval data for YOLOv8
# Found /home/pamessina/medvqa-workspace/cache/chest_imagenome/yolov5/images/chest_imagenome__mimiccxr_test_set(decent_images_only).txt
#
# 2) Running YOLOv8 in eval mode
# 3389it [00:52, 64.29it/s]
#
# 3) Computing and saving metrics
# Computing Mean Absolute Error (MAE) ...
# Computing Mean Intersection Over Union (IOU) ...
# Computing Precision, Recall, and F1 Score at IOU thresholds [0.5, 0.6, 0.7, 0.8, 0.9] ...
# Saved bbox metrics to: /mnt/data/pamessina/workspaces/medvqa-workspace/results/visual_module/20230331_073216_chest-imagenome_yolov8/chest_imagenome__mimiccxr_test_set__bbox_metrics(decent).pkl
# Saved metadata to: /mnt/data/pamessina/workspaces/medvqa-workspace/results/visual_module/20230331_073216_chest-imagenome_yolov8/chest_imagenome__mimiccxr_test_set__metadata(decent).pkl

# %%
# !/home/pamessina/venv2/bin/python ../eval_yolov8.py \
    --eval-dataset-name "chest_imagenome_gold" \
    --weights-path "/home/pamessina/medvqa-workspace/cache/chest_imagenome/train4/weights/best.pt" \
    --decent-images-only \
    --save-predictions
# Out:
# script's arguments:
#    eval_dataset_name: chest_imagenome_gold
#    weights_path: /home/pamessina/medvqa-workspace/cache/chest_imagenome/train4/weights/best.pt
#    decent_images_only: True
#    conf: 0.1
#    max_det: 36
#    save_predictions: True
# --------------------------------------------------
# Evaluating YOLOv8
#
# 1) Preparing eval data for YOLOv8
# Found /home/pamessina/medvqa-workspace/cache/chest_imagenome/yolov5/images/chest_imagenome_gold(decent_images_only).txt
#
# 2) Running YOLOv8 in eval mode
# 0it [00:00, ?it/s]DEBUG: from ultralytics.yolov.utils.ops.py
# len(prediction) = 2
# type(prediction[0]) = <class 'torch.Tensor'>
# len(prediction[0]) = 1
# prediction[0].shape = torch.Size([1, 40, 3003])
# type(prediction[1]) = <class 'list'>
# len(prediction[1]) = 3
# prediction[1][0].shape torch.Size([1, 100, 52, 44])
# prediction[1][1].shape torch.Size([1, 100, 26, 22])
# prediction[1][2].shape torch.Size([1, 100, 13, 11])
# conf_thres = 0.1
# iou_thres = 0.7
# classes = None
# agnostic = False
# multi_label = False
# labels = ()
# max_det = 36
# nc = 0
# max_time_img = 0.05
# max_nms = 30000
# max_wh = 7680
#
# 1it [00:02,  2.36s/it]DEBUG: from ultralytics.yolov.utils.ops.py
# len(prediction) = 2
# type(prediction[0]) = <class 'torch.Tensor'>
# len(prediction[0]) = 1
# prediction[0].shape = torch.Size([1, 40, 3003])
# type(prediction[1]) = <class 'list'>
# len(prediction[1]) = 3
# prediction[1][0].shape torch.Size([1, 100, 44, 52])
# prediction[1][1].shape torch.Size([1, 100, 22, 26])
# prediction[1][2].shape torch.Size([1, 100, 11, 13])
# conf_thres = 0.1
# iou_thres = 0.7
# classes = None
# agnostic = False
# multi_label = False
# labels = ()
# max_det = 36
# nc = 0
# max_time_img = 0.05
# max_nms = 30000
# max_wh = 7680
#
# DEBUG: from ultralytics.yolov.utils.ops.py
# len(prediction) = 2
# type(prediction[0]) = <class 'torch.Tensor'>
# len(prediction[0]) = 1
# prediction[0].shape = torch.Size([1, 40, 3003])
# type(prediction[1]) = <class 'list'>
# len(prediction[1]) = 3
# prediction[1][0].shape torch.Size([1, 100, 52, 44])
# prediction[1][1].shape torch.Size([1, 100, 26, 22])
# prediction[1][2].shape torch.Size([1, 100, 13, 11])
# conf_thres = 0.1
# iou_thres = 0.7
# classes = None
# agnostic = False
# multi_label = False
# labels = ()
# max_det = 36
# nc = 0
# max_time_img = 0.05
# max_nms = 30000
# max_wh = 7680
#
# DEBUG: from ultralytics.yolov.utils.ops.py
# len(prediction) = 2
# type(prediction[0]) = <class 'torch.Tensor'>
# len(prediction[0]) = 1
# prediction[0].shape = torch.Size([1, 40, 3276])
# type(prediction[1]) = <class 'list'>
# len(prediction[1]) = 3
# prediction[1][0].shape torch.Size([1, 100, 48, 52])
# prediction[1][1].shape torch.Size([1, 100, 24, 26])
# prediction[1][2].shape torch.Size([1, 100, 12, 13])
# conf_thres = 0.1
# iou_thres = 0.7
# classes = None
# agnostic = False
# multi_label = False
# labels = ()
# max_det = 36
# nc = 0
# max_time_img = 0.05
# max_nms = 30000
# max_wh = 7680
#
# DEBUG: from ultralytics.yolov.utils.ops.py
# len(prediction) = 2
# type(prediction[0]) = <class 'torch.Tensor'>
# len(prediction[0]) = 1
# prediction[0].shape = torch.Size([1, 40, 3276])
# type(prediction[1]) = <class 'list'>
# len(prediction[1]) = 3
# prediction[1][0].shape torch.Size([1, 100, 48, 52])
# prediction[1][1].shape torch.Size([1, 100, 24, 26])
# prediction[1][2].shape torch.Size([1, 100, 12, 13])
# conf_thres = 0.1
# iou_thres = 0.7
# classes = None
# agnostic = False
# multi_label = False
# labels = ()
# max_det = 36
# nc = 0
# max_time_img = 0.05
# max_nms = 30000
# max_wh = 7680
#
# DEBUG: from ultralytics.yolov.utils.ops.py
# len(prediction) = 2
# type(prediction[0]) = <class 'torch.Tensor'>
# len(prediction[0]) = 1
# prediction[0].shape = torch.Size([1, 40, 3276])
# type(prediction[1]) = <class 'list'>
# len(prediction[1]) = 3
# prediction[1][0].shape torch.Size([1, 100, 52, 48])
# prediction[1][1].shape torch.Size([1, 100, 26, 24])
# prediction[1][2].shape torch.Size([1, 100, 13, 12])
# conf_thres = 0.1
# iou_thres = 0.7
# classes = None
# agnostic = False
# multi_label = False
# labels = ()
# max_det = 36
# nc = 0
# max_time_img = 0.05
# max_nms = 30000
# max_wh = 7680
#
# DEBUG: from ultralytics.yolov.utils.ops.py
# len(prediction) = 2
# type(prediction[0]) = <class 'torch.Tensor'>
# len(prediction[0]) = 1
# prediction[0].shape = torch.Size([1, 40, 3003])
# type(prediction[1]) = <class 'list'>
# len(prediction[1]) = 3
# prediction[1][0].shape torch.Size([1, 100, 52, 44])
# prediction[1][1].shape torch.Size([1, 100, 26, 22])
# prediction[1][2].shape torch.Size([1, 100, 13, 11])
# conf_thres = 0.1
# iou_thres = 0.7
# classes = None
# agnostic = False
# multi_label = False
# labels = ()
# max_det = 36
# nc = 0
# max_time_img = 0.05
# max_nms = 30000
# max_wh = 7680
#
# 7it [00:02,  3.81it/s]DEBUG: from ultralytics.yolov.utils.ops.py
# len(prediction) = 2
# type(prediction[0]) = <class 'torch.Tensor'>
# len(prediction[0]) = 1
# prediction[0].shape = torch.Size([1, 40, 3003])
# type(prediction[1]) = <class 'list'>
# len(prediction[1]) = 3
# prediction[1][0].shape torch.Size([1, 100, 44, 52])
# prediction[1][1].shape torch.Size([1, 100, 22, 26])
# prediction[1][2].shape torch.Size([1, 100, 11, 13])
# conf_thres = 0.1
# iou_thres = 0.7
# classes = None
# agnostic = False
# multi_label = False
# labels = ()
# max_det = 36
# nc = 0
# max_time_img = 0.05
# max_nms = 30000
# max_wh = 7680
#
# DEBUG: from ultralytics.yolov.utils.ops.py
# len(prediction) = 2
# type(prediction[0]) = <class 'torch.Tensor'>
# len(prediction[0]) = 1
# prediction[0].shape = torch.Size([1, 40, 3549])
# type(prediction[1]) = <class 'list'>
# len(prediction[1]) = 3
# prediction[1][0].shape torch.Size([1, 100, 52, 52])
# prediction[1][1].shape torch.Size([1, 100, 26, 26])
# prediction[1][2].shape torch.Size([1, 100, 13, 13])
# conf_thres = 0.1
# iou_thres = 0.7
# classes = None
# agnostic = False
# multi_label = False
# labels = ()
# max_det = 36
# nc = 0
# max_time_img = 0.05
# max_nms = 30000
# max_wh = 7680
#
# DEBUG: from ultralytics.yolov.utils.ops.py
# len(prediction) = 2
# type(prediction[0]) = <class 'torch.Tensor'>
# len(prediction[0]) = 1
# prediction[0].shape = torch.Size([1, 40, 3003])
# type(prediction[1]) = <class 'list'>
# len(prediction[1]) = 3
# prediction[1][0].shape torch.Size([1, 100, 44, 52])
# prediction[1][1].shape torch.Size([1, 100, 22, 26])
# prediction[1][2].shape torch.Size([1, 100, 11, 13])
# conf_thres = 0.1
# iou_thres = 0.7
# classes = None
# agnostic = False
# multi_label = False
# labels = ()
# max_det = 36
# nc = 0
# max_time_img = 0.05
# max_nms = 30000
# max_wh = 7680
#
# DEBUG: from ultralytics.yolov.utils.ops.py
# len(prediction) = 2
# type(prediction[0]) = <class 'torch.Tensor'>
# len(prediction[0]) = 1
# prediction[0].shape = torch.Size([1, 40, 3003])
# type(prediction[1]) = <class 'list'>
# len(prediction[1]) = 3
# prediction[1][0].shape torch.Size([1, 100, 52, 44])
# prediction[1][1].shape torch.Size([1, 100, 26, 22])
# prediction[1][2].shape torch.Size([1, 100, 13, 11])
# conf_thres = 0.1
# iou_thres = 0.7
# classes = None
# agnostic = False
# multi_label = False
# labels = ()
# max_det = 36
# nc = 0
# max_time_img = 0.05
# max_nms = 30000
# max_wh = 7680
#
# DEBUG: from ultralytics.yolov.utils.ops.py
# len(prediction) = 2
# type(prediction[0]) = <class 'torch.Tensor'>
# len(prediction[0]) = 1
# prediction[0].shape = torch.Size([1, 40, 3003])
# type(prediction[1]) = <class 'list'>
# len(prediction[1]) = 3
# prediction[1][0].shape torch.Size([1, 100, 44, 52])
# prediction[1][1].shape torch.Size([1, 100, 22, 26])
# prediction[1][2].shape torch.Size([1, 100, 11, 13])
# conf_thres = 0.1
# iou_thres = 0.7
# classes = None
# agnostic = False
# multi_label = False
# labels = ()
# max_det = 36
# nc = 0
# max_time_img = 0.05
# max_nms = 30000
# max_wh = 7680
#
# DEBUG: from ultralytics.yolov.utils.ops.py
# len(prediction) = 2
# type(prediction[0]) = <class 'torch.Tensor'>
# len(prediction[0]) = 1
# prediction[0].shape = torch.Size([1, 40, 3003])
# type(prediction[1]) = <class 'list'>
# len(prediction[1]) = 3
# prediction[1][0].shape torch.Size([1, 100, 44, 52])
# prediction[1][1].shape torch.Size([1, 100, 22, 26])
# prediction[1][2].shape torch.Size([1, 100, 11, 13])
# conf_thres = 0.1
# iou_thres = 0.7
# classes = None
# agnostic = False
# multi_label = False
# labels = ()
# max_det = 36
# nc = 0
# max_time_img = 0.05
# max_nms = 30000
# max_wh = 7680
#
# 13it [00:02,  8.01it/s]DEBUG: from ultralytics.yolov.utils.ops.py
# len(prediction) = 2
# type(prediction[0]) = <class 'torch.Tensor'>
# len(prediction[0]) = 1
# prediction[0].shape = torch.Size([1, 40, 3549])
# type(prediction[1]) = <class 'list'>
# len(prediction[1]) = 3
# prediction[1][0].shape torch.Size([1, 100, 52, 52])
# prediction[1][1].shape torch.Size([1, 100, 26, 26])
# prediction[1][2].shape torch.Size([1, 100, 13, 13])
# conf_thres = 0.1
# iou_thres = 0.7
# classes = None
# agnostic = False
# multi_label = False
# labels = ()
# max_det = 36
# nc = 0
# max_time_img = 0.05
# max_nms = 30000
# max_wh = 7680
#
# DEBUG: from ultralytics.yolov.utils.ops.py
# len(prediction) = 2
# type(prediction[0]) = <class 'torch.Tensor'>
# len(prediction[0]) = 1
# prediction[0].shape = torch.Size([1, 40, 3003])
# type(prediction[1]) = <class 'list'>
# len(prediction[1]) = 3
# prediction[1][0].shape torch.Size([1, 100, 52, 44])
# prediction[1][1].shape torch.Size([1, 100, 26, 22])
# prediction[1][2].shape torch.Size([1, 100, 13, 11])
# conf_thres = 0.1
# iou_thres = 0.7
# classes = None
# agnostic = False
# multi_label = False
# labels = ()
# max_det = 36
# nc = 0
# max_time_img = 0.05
# max_nms = 30000
# max_wh = 7680
#
# DEBUG: from ultralytics.yolov.utils.ops.py
# len(prediction) = 2
# type(prediction[0]) = <class 'torch.Tensor'>
# len(prediction[0]) = 1
# prediction[0].shape = torch.Size([1, 40, 3549])
# type(prediction[1]) = <class 'list'>
# len(prediction[1]) = 3
# prediction[1][0].shape torch.Size([1, 100, 52, 52])
# prediction[1][1].shape torch.Size([1, 100, 26, 26])
# prediction[1][2].shape torch.Size([1, 100, 13, 13])
# conf_thres = 0.1
# iou_thres = 0.7
# classes = None
# agnostic = False
# multi_label = False
# labels = ()
# max_det = 36
# nc = 0
# max_time_img = 0.05
# max_nms = 30000
# max_wh = 7680
# DEBUG: from ultralytics.yolov.utils.ops.py
# len(prediction) = 2
# type(prediction[0]) = <class 'torch.Tensor'>
# len(prediction[0]) = 1
# prediction[0].shape = torch.Size([1, 40, 3003])
# type(prediction[1]) = <class 'list'>
# len(prediction[1]) = 3
# prediction[1][0].shape torch.Size([1, 100, 44, 52])
# prediction[1][1].shape torch.Size([1, 100, 22, 26])
# prediction[1][2].shape torch.Size([1, 100, 11, 13])
# conf_thres = 0.1
# iou_thres = 0.7
# classes = None
# agnostic = False
# multi_label = False
# labels = ()
# max_det = 36
# nc = 0
# max_time_img = 0.05
# max_nms = 30000
# max_wh = 7680
#
# DEBUG: from ultralytics.yolov.utils.ops.py
# len(prediction) = 2
# type(prediction[0]) = <class 'torch.Tensor'>
# len(prediction[0]) = 1
# prediction[0].shape = torch.Size([1, 40, 3003])
# type(prediction[1]) = <class 'list'>
# len(prediction[1]) = 3
# prediction[1][0].shape torch.Size([1, 100, 44, 52])
# prediction[1][1].shape torch.Size([1, 100, 22, 26])
# prediction[1][2].shape torch.Size([1, 100, 11, 13])
# conf_thres = 0.1
# iou_thres = 0.7
# classes = None
# agnostic = False
# multi_label = False
# labels = ()
# max_det = 36
# nc = 0
# max_time_img = 0.05
# max_nms = 30000
# max_wh = 7680
#
# DEBUG: from ultralytics.yolov.utils.ops.py
# len(prediction) = 2
# type(prediction[0]) = <class 'torch.Tensor'>
# len(prediction[0]) = 1
# prediction[0].shape = torch.Size([1, 40, 3003])
# type(prediction[1]) = <class 'list'>
# len(prediction[1]) = 3
# prediction[1][0].shape torch.Size([1, 100, 44, 52])
# prediction[1][1].shape torch.Size([1, 100, 22, 26])
# prediction[1][2].shape torch.Size([1, 100, 11, 13])
# conf_thres = 0.1
# iou_thres = 0.7
# classes = None
# agnostic = False
# multi_label = False
# labels = ()
# max_det = 36
# nc = 0
# max_time_img = 0.05
# max_nms = 30000
# max_wh = 7680
#
# DEBUG: from ultralytics.yolov.utils.ops.py
# len(prediction) = 2
# type(prediction[0]) = <class 'torch.Tensor'>
# len(prediction[0]) = 1
# prediction[0].shape = torch.Size([1, 40, 3003])
# type(prediction[1]) = <class 'list'>
# len(prediction[1]) = 3
# prediction[1][0].shape torch.Size([1, 100, 44, 52])
# prediction[1][1].shape torch.Size([1, 100, 22, 26])
# prediction[1][2].shape torch.Size([1, 100, 11, 13])
# conf_thres = 0.1
# iou_thres = 0.7
# classes = None
# agnostic = False
# multi_label = False
# labels = ()
# max_det = 36
# nc = 0
# max_time_img = 0.05
# max_nms = 30000
# max_wh = 7680
#
# 20it [00:02, 13.85it/s]DEBUG: from ultralytics.yolov.utils.ops.py
# len(prediction) = 2
# type(prediction[0]) = <class 'torch.Tensor'>
# len(prediction[0]) = 1
# prediction[0].shape = torch.Size([1, 40, 3003])
# type(prediction[1]) = <class 'list'>
# len(prediction[1]) = 3
# prediction[1][0].shape torch.Size([1, 100, 52, 44])
# prediction[1][1].shape torch.Size([1, 100, 26, 22])
# prediction[1][2].shape torch.Size([1, 100, 13, 11])
# conf_thres = 0.1
# iou_thres = 0.7
# classes = None
# agnostic = False
# multi_label = False
# labels = ()
# max_det = 36
# nc = 0
# max_time_img = 0.05
# max_nms = 30000
# max_wh = 7680
#
# DEBUG: from ultralytics.yolov.utils.ops.py
# len(prediction) = 2
# type(prediction[0]) = <class 'torch.Tensor'>
# len(prediction[0]) = 1
# prediction[0].shape = torch.Size([1, 40, 3003])
# type(prediction[1]) = <class 'list'>
# len(prediction[1]) = 3
# prediction[1][0].shape torch.Size([1, 100, 52, 44])
# prediction[1][1].shape torch.Size([1, 100, 26, 22])
# prediction[1][2].shape torch.Size([1, 100, 13, 11])
# conf_thres = 0.1
# iou_thres = 0.7
# classes = None
# agnostic = False
# multi_label = False
# labels = ()
# max_det = 36
# nc = 0
# max_time_img = 0.05
# max_nms = 30000
# max_wh = 7680
#
# DEBUG: from ultralytics.yolov.utils.ops.py
# len(prediction) = 2
# type(prediction[0]) = <class 'torch.Tensor'>
# len(prediction[0]) = 1
# prediction[0].shape = torch.Size([1, 40, 3003])
# type(prediction[1]) = <class 'list'>
# len(prediction[1]) = 3
# prediction[1][0].shape torch.Size([1, 100, 52, 44])
# prediction[1][1].shape torch.Size([1, 100, 26, 22])
# prediction[1][2].shape torch.Size([1, 100, 13, 11])
# conf_thres = 0.1
# iou_thres = 0.7
# classes = None
# agnostic = False
# multi_label = False
# labels = ()
# max_det = 36
# nc = 0
# max_time_img = 0.05
# max_nms = 30000
# max_wh = 7680
#
# DEBUG: from ultralytics.yolov.utils.ops.py
# len(prediction) = 2
# type(prediction[0]) = <class 'torch.Tensor'>
# len(prediction[0]) = 1
# prediction[0].shape = torch.Size([1, 40, 3003])
# type(prediction[1]) = <class 'list'>
# len(prediction[1]) = 3
# prediction[1][0].shape torch.Size([1, 100, 52, 44])
# prediction[1][1].shape torch.Size([1, 100, 26, 22])
# prediction[1][2].shape torch.Size([1, 100, 13, 11])
# conf_thres = 0.1
# iou_thres = 0.7
# classes = None
# agnostic = False
# multi_label = False
# labels = ()
# max_det = 36
# nc = 0
# max_time_img = 0.05
# max_nms = 30000
# max_wh = 7680
#
# DEBUG: from ultralytics.yolov.utils.ops.py
# len(prediction) = 2
# type(prediction[0]) = <class 'torch.Tensor'>
# len(prediction[0]) = 1
# prediction[0].shape = torch.Size([1, 40, 3003])
# type(prediction[1]) = <class 'list'>
# len(prediction[1]) = 3
# prediction[1][0].shape torch.Size([1, 100, 52, 44])
# prediction[1][1].shape torch.Size([1, 100, 26, 22])
# prediction[1][2].shape torch.Size([1, 100, 13, 11])
# conf_thres = 0.1
# iou_thres = 0.7
# classes = None
# agnostic = False
# multi_label = False
# labels = ()
# max_det = 36
# nc = 0
# max_time_img = 0.05
# max_nms = 30000
# max_wh = 7680
#
# DEBUG: from ultralytics.yolov.utils.ops.py
# len(prediction) = 2
# type(prediction[0]) = <class 'torch.Tensor'>
# len(prediction[0]) = 1
# prediction[0].shape = torch.Size([1, 40, 3003])
# type(prediction[1]) = <class 'list'>
# len(prediction[1]) = 3
# prediction[1][0].shape torch.Size([1, 100, 44, 52])
# prediction[1][1].shape torch.Size([1, 100, 22, 26])
# prediction[1][2].shape torch.Size([1, 100, 11, 13])
# conf_thres = 0.1
# iou_thres = 0.7
# classes = None
# agnostic = False
# multi_label = False
# labels = ()
# max_det = 36
# nc = 0
# max_time_img = 0.05
# max_nms = 30000
# max_wh = 7680
#
# DEBUG: from ultralytics.yolov.utils.ops.py
# len(prediction) = 2
# type(prediction[0]) = <class 'torch.Tensor'>
# len(prediction[0]) = 1
# prediction[0].shape = torch.Size([1, 40, 3003])
# type(prediction[1]) = <class 'list'>
# len(prediction[1]) = 3
# prediction[1][0].shape torch.Size([1, 100, 52, 44])
# prediction[1][1].shape torch.Size([1, 100, 26, 22])
# prediction[1][2].shape torch.Size([1, 100, 13, 11])
# conf_thres = 0.1
# iou_thres = 0.7
# classes = None
# agnostic = False
# multi_label = False
# labels = ()
# max_det = 36
# nc = 0
# max_time_img = 0.05
# max_nms = 30000
# max_wh = 7680
#
# 27it [00:02, 20.58it/s]DEBUG: from ultralytics.yolov.utils.ops.py
# len(prediction) = 2
# type(prediction[0]) = <class 'torch.Tensor'>
# len(prediction[0]) = 1
# prediction[0].shape = torch.Size([1, 40, 3003])
# type(prediction[1]) = <class 'list'>
# len(prediction[1]) = 3
# prediction[1][0].shape torch.Size([1, 100, 44, 52])
# prediction[1][1].shape torch.Size([1, 100, 22, 26])
# prediction[1][2].shape torch.Size([1, 100, 11, 13])
# conf_thres = 0.1
# iou_thres = 0.7
# classes = None
# agnostic = False
# multi_label = False
# labels = ()
# max_det = 36
# nc = 0
# max_time_img = 0.05
# max_nms = 30000
# max_wh = 7680
#
# DEBUG: from ultralytics.yolov.utils.ops.py
# len(prediction) = 2
# type(prediction[0]) = <class 'torch.Tensor'>
# len(prediction[0]) = 1
# prediction[0].shape = torch.Size([1, 40, 3003])
# type(prediction[1]) = <class 'list'>
# len(prediction[1]) = 3
# prediction[1][0].shape torch.Size([1, 100, 44, 52])
# prediction[1][1].shape torch.Size([1, 100, 22, 26])
# prediction[1][2].shape torch.Size([1, 100, 11, 13])
# conf_thres = 0.1
# iou_thres = 0.7
# classes = None
# agnostic = False
# multi_label = False
# labels = ()
# max_det = 36
# nc = 0
# max_time_img = 0.05
# max_nms = 30000
# max_wh = 7680
#
# DEBUG: from ultralytics.yolov.utils.ops.py
# len(prediction) = 2
# type(prediction[0]) = <class 'torch.Tensor'>
# len(prediction[0]) = 1
# prediction[0].shape = torch.Size([1, 40, 3003])
# type(prediction[1]) = <class 'list'>
# len(prediction[1]) = 3
# prediction[1][0].shape torch.Size([1, 100, 44, 52])
# prediction[1][1].shape torch.Size([1, 100, 22, 26])
# prediction[1][2].shape torch.Size([1, 100, 11, 13])
# conf_thres = 0.1
# iou_thres = 0.7
# classes = None
# agnostic = False
# multi_label = False
# labels = ()
# max_det = 36
# nc = 0
# max_time_img = 0.05
# max_nms = 30000
# max_wh = 7680
#
# DEBUG: from ultralytics.yolov.utils.ops.py
# len(prediction) = 2
# type(prediction[0]) = <class 'torch.Tensor'>
# len(prediction[0]) = 1
# prediction[0].shape = torch.Size([1, 40, 3003])
# type(prediction[1]) = <class 'list'>
# len(prediction[1]) = 3
# prediction[1][0].shape torch.Size([1, 100, 44, 52])
# prediction[1][1].shape torch.Size([1, 100, 22, 26])
# prediction[1][2].shape torch.Size([1, 100, 11, 13])
# conf_thres = 0.1
# iou_thres = 0.7
# classes = None
# agnostic = False
# multi_label = False
# labels = ()
# max_det = 36
# nc = 0
# max_time_img = 0.05
# max_nms = 30000
# max_wh = 7680
#
# DEBUG: from ultralytics.yolov.utils.ops.py
# len(prediction) = 2
# type(prediction[0]) = <class 'torch.Tensor'>
# len(prediction[0]) = 1
# prediction[0].shape = torch.Size([1, 40, 3003])
# type(prediction[1]) = <class 'list'>
# len(prediction[1]) = 3
# prediction[1][0].shape torch.Size([1, 100, 52, 44])
# prediction[1][1].shape torch.Size([1, 100, 26, 22])
# prediction[1][2].shape torch.Size([1, 100, 13, 11])
# conf_thres = 0.1
# iou_thres = 0.7
# classes = None
# agnostic = False
# multi_label = False
# labels = ()
# max_det = 36
# nc = 0
# max_time_img = 0.05
# max_nms = 30000
# max_wh = 7680
#
# DEBUG: from ultralytics.yolov.utils.ops.py
# len(prediction) = 2
# type(prediction[0]) = <class 'torch.Tensor'>
# len(prediction[0]) = 1
# prediction[0].shape = torch.Size([1, 40, 3276])
# type(prediction[1]) = <class 'list'>
# len(prediction[1]) = 3
# prediction[1][0].shape torch.Size([1, 100, 52, 48])
# prediction[1][1].shape torch.Size([1, 100, 26, 24])
# prediction[1][2].shape torch.Size([1, 100, 13, 12])
# conf_thres = 0.1
# iou_thres = 0.7
# classes = None
# agnostic = False
# multi_label = False
# labels = ()
# max_det = 36
# nc = 0
# max_time_img = 0.05
# max_nms = 30000
# max_wh = 7680
# DEBUG: from ultralytics.yolov.utils.ops.py
# len(prediction) = 2
# type(prediction[0]) = <class 'torch.Tensor'>
# len(prediction[0]) = 1
# prediction[0].shape = torch.Size([1, 40, 3003])
# type(prediction[1]) = <class 'list'>
# len(prediction[1]) = 3
# prediction[1][0].shape torch.Size([1, 100, 52, 44])
# prediction[1][1].shape torch.Size([1, 100, 26, 22])
# prediction[1][2].shape torch.Size([1, 100, 13, 11])
# conf_thres = 0.1
# iou_thres = 0.7
# classes = None
# agnostic = False
# multi_label = False
# labels = ()
# max_det = 36
# nc = 0
# max_time_img = 0.05
# max_nms = 30000
# max_wh = 7680
#
# 34it [00:02, 27.73it/s]DEBUG: from ultralytics.yolov.utils.ops.py
# len(prediction) = 2
# type(prediction[0]) = <class 'torch.Tensor'>
# len(prediction[0]) = 1
# prediction[0].shape = torch.Size([1, 40, 3003])
# type(prediction[1]) = <class 'list'>
# len(prediction[1]) = 3
# prediction[1][0].shape torch.Size([1, 100, 44, 52])
# prediction[1][1].shape torch.Size([1, 100, 22, 26])
# prediction[1][2].shape torch.Size([1, 100, 11, 13])
# conf_thres = 0.1
# iou_thres = 0.7
# classes = None
# agnostic = False
# multi_label = False
# labels = ()
# max_det = 36
# nc = 0
# max_time_img = 0.05
# max_nms = 30000
# max_wh = 7680
#
# DEBUG: from ultralytics.yolov.utils.ops.py
# len(prediction) = 2
# type(prediction[0]) = <class 'torch.Tensor'>
# len(prediction[0]) = 1
# prediction[0].shape = torch.Size([1, 40, 3003])
# type(prediction[1]) = <class 'list'>
# len(prediction[1]) = 3
# prediction[1][0].shape torch.Size([1, 100, 52, 44])
# prediction[1][1].shape torch.Size([1, 100, 26, 22])
# prediction[1][2].shape torch.Size([1, 100, 13, 11])
# conf_thres = 0.1
# iou_thres = 0.7
# classes = None
# agnostic = False
# multi_label = False
# labels = ()
# max_det = 36
# nc = 0
# max_time_img = 0.05
# max_nms = 30000
# max_wh = 7680
#
# DEBUG: from ultralytics.yolov.utils.ops.py
# len(prediction) = 2
# type(prediction[0]) = <class 'torch.Tensor'>
# len(prediction[0]) = 1
# prediction[0].shape = torch.Size([1, 40, 3003])
# type(prediction[1]) = <class 'list'>
# len(prediction[1]) = 3
# prediction[1][0].shape torch.Size([1, 100, 44, 52])
# prediction[1][1].shape torch.Size([1, 100, 22, 26])
# prediction[1][2].shape torch.Size([1, 100, 11, 13])
# conf_thres = 0.1
# iou_thres = 0.7
# classes = None
# agnostic = False
# multi_label = False
# labels = ()
# max_det = 36
# nc = 0
# max_time_img = 0.05
# max_nms = 30000
# max_wh = 7680
#
# DEBUG: from ultralytics.yolov.utils.ops.py
# len(prediction) = 2
# type(prediction[0]) = <class 'torch.Tensor'>
# len(prediction[0]) = 1
# prediction[0].shape = torch.Size([1, 40, 3003])
# type(prediction[1]) = <class 'list'>
# len(prediction[1]) = 3
# prediction[1][0].shape torch.Size([1, 100, 44, 52])
# prediction[1][1].shape torch.Size([1, 100, 22, 26])
# prediction[1][2].shape torch.Size([1, 100, 11, 13])
# conf_thres = 0.1
# iou_thres = 0.7
# classes = None
# agnostic = False
# multi_label = False
# labels = ()
# max_det = 36
# nc = 0
# max_time_img = 0.05
# max_nms = 30000
# max_wh = 7680
#
# DEBUG: from ultralytics.yolov.utils.ops.py
# len(prediction) = 2
# type(prediction[0]) = <class 'torch.Tensor'>
# len(prediction[0]) = 1
# prediction[0].shape = torch.Size([1, 40, 3003])
# type(prediction[1]) = <class 'list'>
# len(prediction[1]) = 3
# prediction[1][0].shape torch.Size([1, 100, 44, 52])
# prediction[1][1].shape torch.Size([1, 100, 22, 26])
# prediction[1][2].shape torch.Size([1, 100, 11, 13])
# conf_thres = 0.1
# iou_thres = 0.7
# classes = None
# agnostic = False
# multi_label = False
# labels = ()
# max_det = 36
# nc = 0
# max_time_img = 0.05
# max_nms = 30000
# max_wh = 7680
#
# DEBUG: from ultralytics.yolov.utils.ops.py
# len(prediction) = 2
# type(prediction[0]) = <class 'torch.Tensor'>
# len(prediction[0]) = 1
# prediction[0].shape = torch.Size([1, 40, 3003])
# type(prediction[1]) = <class 'list'>
# len(prediction[1]) = 3
# prediction[1][0].shape torch.Size([1, 100, 44, 52])
# prediction[1][1].shape torch.Size([1, 100, 22, 26])
# prediction[1][2].shape torch.Size([1, 100, 11, 13])
# conf_thres = 0.1
# iou_thres = 0.7
# classes = None
# agnostic = False
# multi_label = False
# labels = ()
# max_det = 36
# nc = 0
# max_time_img = 0.05
# max_nms = 30000
# max_wh = 7680
#
# DEBUG: from ultralytics.yolov.utils.ops.py
# len(prediction) = 2
# type(prediction[0]) = <class 'torch.Tensor'>
# len(prediction[0]) = 1
# prediction[0].shape = torch.Size([1, 40, 3003])
# type(prediction[1]) = <class 'list'>
# len(prediction[1]) = 3
# prediction[1][0].shape torch.Size([1, 100, 52, 44])
# prediction[1][1].shape torch.Size([1, 100, 26, 22])
# prediction[1][2].shape torch.Size([1, 100, 13, 11])
# conf_thres = 0.1
# iou_thres = 0.7
# classes = None
# agnostic = False
# multi_label = False
# labels = ()
# max_det = 36
# nc = 0
# max_time_img = 0.05
# max_nms = 30000
# max_wh = 7680
#
# 41it [00:02, 34.94it/s]DEBUG: from ultralytics.yolov.utils.ops.py
# len(prediction) = 2
# type(prediction[0]) = <class 'torch.Tensor'>
# len(prediction[0]) = 1
# prediction[0].shape = torch.Size([1, 40, 3276])
# type(prediction[1]) = <class 'list'>
# len(prediction[1]) = 3
# prediction[1][0].shape torch.Size([1, 100, 48, 52])
# prediction[1][1].shape torch.Size([1, 100, 24, 26])
# prediction[1][2].shape torch.Size([1, 100, 12, 13])
# conf_thres = 0.1
# iou_thres = 0.7
# classes = None
# agnostic = False
# multi_label = False
# labels = ()
# max_det = 36
# nc = 0
# max_time_img = 0.05
# max_nms = 30000
# max_wh = 7680
#
# DEBUG: from ultralytics.yolov.utils.ops.py
# len(prediction) = 2
# type(prediction[0]) = <class 'torch.Tensor'>
# len(prediction[0]) = 1
# prediction[0].shape = torch.Size([1, 40, 3003])
# type(prediction[1]) = <class 'list'>
# len(prediction[1]) = 3
# prediction[1][0].shape torch.Size([1, 100, 52, 44])
# prediction[1][1].shape torch.Size([1, 100, 26, 22])
# prediction[1][2].shape torch.Size([1, 100, 13, 11])
# conf_thres = 0.1
# iou_thres = 0.7
# classes = None
# agnostic = False
# multi_label = False
# labels = ()
# max_det = 36
# nc = 0
# max_time_img = 0.05
# max_nms = 30000
# max_wh = 7680
#
# DEBUG: from ultralytics.yolov.utils.ops.py
# len(prediction) = 2
# type(prediction[0]) = <class 'torch.Tensor'>
# len(prediction[0]) = 1
# prediction[0].shape = torch.Size([1, 40, 3003])
# type(prediction[1]) = <class 'list'>
# len(prediction[1]) = 3
# prediction[1][0].shape torch.Size([1, 100, 52, 44])
# prediction[1][1].shape torch.Size([1, 100, 26, 22])
# prediction[1][2].shape torch.Size([1, 100, 13, 11])
# conf_thres = 0.1
# iou_thres = 0.7
# classes = None
# agnostic = False
# multi_label = False
# labels = ()
# max_det = 36
# nc = 0
# max_time_img = 0.05
# max_nms = 30000
# max_wh = 7680
#
# DEBUG: from ultralytics.yolov.utils.ops.py
# len(prediction) = 2
# type(prediction[0]) = <class 'torch.Tensor'>
# len(prediction[0]) = 1
# prediction[0].shape = torch.Size([1, 40, 3549])
# type(prediction[1]) = <class 'list'>
# len(prediction[1]) = 3
# prediction[1][0].shape torch.Size([1, 100, 52, 52])
# prediction[1][1].shape torch.Size([1, 100, 26, 26])
# prediction[1][2].shape torch.Size([1, 100, 13, 13])
# conf_thres = 0.1
# iou_thres = 0.7
# classes = None
# agnostic = False
# multi_label = False
# labels = ()
# max_det = 36
# nc = 0
# max_time_img = 0.05
# max_nms = 30000
# max_wh = 7680
#
# DEBUG: from ultralytics.yolov.utils.ops.py
# len(prediction) = 2
# type(prediction[0]) = <class 'torch.Tensor'>
# len(prediction[0]) = 1
# prediction[0].shape = torch.Size([1, 40, 3003])
# type(prediction[1]) = <class 'list'>
# len(prediction[1]) = 3
# prediction[1][0].shape torch.Size([1, 100, 52, 44])
# prediction[1][1].shape torch.Size([1, 100, 26, 22])
# prediction[1][2].shape torch.Size([1, 100, 13, 11])
# conf_thres = 0.1
# iou_thres = 0.7
# classes = None
# agnostic = False
# multi_label = False
# labels = ()
# max_det = 36
# nc = 0
# max_time_img = 0.05
# max_nms = 30000
# max_wh = 7680
#
# DEBUG: from ultralytics.yolov.utils.ops.py
# len(prediction) = 2
# type(prediction[0]) = <class 'torch.Tensor'>
# len(prediction[0]) = 1
# prediction[0].shape = torch.Size([1, 40, 3003])
# type(prediction[1]) = <class 'list'>
# len(prediction[1]) = 3
# prediction[1][0].shape torch.Size([1, 100, 52, 44])
# prediction[1][1].shape torch.Size([1, 100, 26, 22])
# prediction[1][2].shape torch.Size([1, 100, 13, 11])
# conf_thres = 0.1
# iou_thres = 0.7
# classes = None
# agnostic = False
# multi_label = False
# labels = ()
# max_det = 36
# nc = 0
# max_time_img = 0.05
# max_nms = 30000
# max_wh = 7680
#
# DEBUG: from ultralytics.yolov.utils.ops.py
# len(prediction) = 2
# type(prediction[0]) = <class 'torch.Tensor'>
# len(prediction[0]) = 1
# prediction[0].shape = torch.Size([1, 40, 3003])
# type(prediction[1]) = <class 'list'>
# len(prediction[1]) = 3
# prediction[1][0].shape torch.Size([1, 100, 52, 44])
# prediction[1][1].shape torch.Size([1, 100, 26, 22])
# prediction[1][2].shape torch.Size([1, 100, 13, 11])
# conf_thres = 0.1
# iou_thres = 0.7
# classes = None
# agnostic = False
# multi_label = False
# labels = ()
# max_det = 36
# nc = 0
# max_time_img = 0.05
# max_nms = 30000
# max_wh = 7680
#
# 48it [00:03, 41.73it/s]DEBUG: from ultralytics.yolov.utils.ops.py
# len(prediction) = 2
# type(prediction[0]) = <class 'torch.Tensor'>
# len(prediction[0]) = 1
# prediction[0].shape = torch.Size([1, 40, 3549])
# type(prediction[1]) = <class 'list'>
# len(prediction[1]) = 3
# prediction[1][0].shape torch.Size([1, 100, 52, 52])
# prediction[1][1].shape torch.Size([1, 100, 26, 26])
# prediction[1][2].shape torch.Size([1, 100, 13, 13])
# conf_thres = 0.1
# iou_thres = 0.7
# classes = None
# agnostic = False
# multi_label = False
# labels = ()
# max_det = 36
# nc = 0
# max_time_img = 0.05
# max_nms = 30000
# max_wh = 7680
#
# DEBUG: from ultralytics.yolov.utils.ops.py
# len(prediction) = 2
# type(prediction[0]) = <class 'torch.Tensor'>
# len(prediction[0]) = 1
# prediction[0].shape = torch.Size([1, 40, 3003])
# type(prediction[1]) = <class 'list'>
# len(prediction[1]) = 3
# prediction[1][0].shape torch.Size([1, 100, 52, 44])
# prediction[1][1].shape torch.Size([1, 100, 26, 22])
# prediction[1][2].shape torch.Size([1, 100, 13, 11])
# conf_thres = 0.1
# iou_thres = 0.7
# classes = None
# agnostic = False
# multi_label = False
# labels = ()
# max_det = 36
# nc = 0
# max_time_img = 0.05
# max_nms = 30000
# max_wh = 7680
#
# DEBUG: from ultralytics.yolov.utils.ops.py
# len(prediction) = 2
# type(prediction[0]) = <class 'torch.Tensor'>
# len(prediction[0]) = 1
# prediction[0].shape = torch.Size([1, 40, 3003])
# type(prediction[1]) = <class 'list'>
# len(prediction[1]) = 3
# prediction[1][0].shape torch.Size([1, 100, 44, 52])
# prediction[1][1].shape torch.Size([1, 100, 22, 26])
# prediction[1][2].shape torch.Size([1, 100, 11, 13])
# conf_thres = 0.1
# iou_thres = 0.7
# classes = None
# agnostic = False
# multi_label = False
# labels = ()
# max_det = 36
# nc = 0
# max_time_img = 0.05
# max_nms = 30000
# max_wh = 7680
# DEBUG: from ultralytics.yolov.utils.ops.py
# len(prediction) = 2
# type(prediction[0]) = <class 'torch.Tensor'>
# len(prediction[0]) = 1
# prediction[0].shape = torch.Size([1, 40, 3003])
# type(prediction[1]) = <class 'list'>
# len(prediction[1]) = 3
# prediction[1][0].shape torch.Size([1, 100, 44, 52])
# prediction[1][1].shape torch.Size([1, 100, 22, 26])
# prediction[1][2].shape torch.Size([1, 100, 11, 13])
# conf_thres = 0.1
# iou_thres = 0.7
# classes = None
# agnostic = False
# multi_label = False
# labels = ()
# max_det = 36
# nc = 0
# max_time_img = 0.05
# max_nms = 30000
# max_wh = 7680
#
# DEBUG: from ultralytics.yolov.utils.ops.py
# len(prediction) = 2
# type(prediction[0]) = <class 'torch.Tensor'>
# len(prediction[0]) = 1
# prediction[0].shape = torch.Size([1, 40, 3003])
# type(prediction[1]) = <class 'list'>
# len(prediction[1]) = 3
# prediction[1][0].shape torch.Size([1, 100, 44, 52])
# prediction[1][1].shape torch.Size([1, 100, 22, 26])
# prediction[1][2].shape torch.Size([1, 100, 11, 13])
# conf_thres = 0.1
# iou_thres = 0.7
# classes = None
# agnostic = False
# multi_label = False
# labels = ()
# max_det = 36
# nc = 0
# max_time_img = 0.05
# max_nms = 30000
# max_wh = 7680
#
# DEBUG: from ultralytics.yolov.utils.ops.py
# len(prediction) = 2
# type(prediction[0]) = <class 'torch.Tensor'>
# len(prediction[0]) = 1
# prediction[0].shape = torch.Size([1, 40, 3003])
# type(prediction[1]) = <class 'list'>
# len(prediction[1]) = 3
# prediction[1][0].shape torch.Size([1, 100, 52, 44])
# prediction[1][1].shape torch.Size([1, 100, 26, 22])
# prediction[1][2].shape torch.Size([1, 100, 13, 11])
# conf_thres = 0.1
# iou_thres = 0.7
# classes = None
# agnostic = False
# multi_label = False
# labels = ()
# max_det = 36
# nc = 0
# max_time_img = 0.05
# max_nms = 30000
# max_wh = 7680
#
# DEBUG: from ultralytics.yolov.utils.ops.py
# len(prediction) = 2
# type(prediction[0]) = <class 'torch.Tensor'>
# len(prediction[0]) = 1
# prediction[0].shape = torch.Size([1, 40, 3003])
# type(prediction[1]) = <class 'list'>
# len(prediction[1]) = 3
# prediction[1][0].shape torch.Size([1, 100, 52, 44])
# prediction[1][1].shape torch.Size([1, 100, 26, 22])
# prediction[1][2].shape torch.Size([1, 100, 13, 11])
# conf_thres = 0.1
# iou_thres = 0.7
# classes = None
# agnostic = False
# multi_label = False
# labels = ()
# max_det = 36
# nc = 0
# max_time_img = 0.05
# max_nms = 30000
# max_wh = 7680
#
# DEBUG: from ultralytics.yolov.utils.ops.py
# len(prediction) = 2
# type(prediction[0]) = <class 'torch.Tensor'>
# len(prediction[0]) = 1
# prediction[0].shape = torch.Size([1, 40, 3003])
# type(prediction[1]) = <class 'list'>
# len(prediction[1]) = 3
# prediction[1][0].shape torch.Size([1, 100, 44, 52])
# prediction[1][1].shape torch.Size([1, 100, 22, 26])
# prediction[1][2].shape torch.Size([1, 100, 11, 13])
# conf_thres = 0.1
# iou_thres = 0.7
# classes = None
# agnostic = False
# multi_label = False
# labels = ()
# max_det = 36
# nc = 0
# max_time_img = 0.05
# max_nms = 30000
# max_wh = 7680
#
# DEBUG: from ultralytics.yolov.utils.ops.py
# len(prediction) = 2
# type(prediction[0]) = <class 'torch.Tensor'>
# len(prediction[0]) = 1
# prediction[0].shape = torch.Size([1, 40, 3003])
# type(prediction[1]) = <class 'list'>
# len(prediction[1]) = 3
# prediction[1][0].shape torch.Size([1, 100, 52, 44])
# prediction[1][1].shape torch.Size([1, 100, 26, 22])
# prediction[1][2].shape torch.Size([1, 100, 13, 11])
# conf_thres = 0.1
# iou_thres = 0.7
# classes = None
# agnostic = False
# multi_label = False
# labels = ()
# max_det = 36
# nc = 0
# max_time_img = 0.05
# max_nms = 30000
# max_wh = 7680
#
# DEBUG: from ultralytics.yolov.utils.ops.py
# len(prediction) = 2
# type(prediction[0]) = <class 'torch.Tensor'>
# len(prediction[0]) = 1
# prediction[0].shape = torch.Size([1, 40, 3003])
# type(prediction[1]) = <class 'list'>
# len(prediction[1]) = 3
# prediction[1][0].shape torch.Size([1, 100, 52, 44])
# prediction[1][1].shape torch.Size([1, 100, 26, 22])
# prediction[1][2].shape torch.Size([1, 100, 13, 11])
# conf_thres = 0.1
# iou_thres = 0.7
# classes = None
# agnostic = False
# multi_label = False
# labels = ()
# max_det = 36
# nc = 0
# max_time_img = 0.05
# max_nms = 30000
# max_wh = 7680
#
# ^C
# 60it [00:03, 18.39it/s]
# Traceback (most recent call last):
#   File "/home/pamessina/medvqa/medvqa/notebooks/../eval_yolov8.py", line 143, in <module>
#     eval_yolov8(**args)
#   File "/home/pamessina/medvqa/medvqa/notebooks/../eval_yolov8.py", line 99, in eval_yolov8
#     results = model([image_path], conf=conf, max_det=max_det, verbose=False)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ultralytics/yolo/engine/model.py", line 101, in __call__
#     return self.predict(source, stream, **kwargs)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/autograd/grad_mode.py", line 27, in decorate_context
#     return func(*args, **kwargs)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ultralytics/yolo/engine/model.py", line 230, in predict
#     return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ultralytics/yolo/engine/predictor.py", line 127, in __call__
#     return list(self.stream_inference(source, model))  # merge list of Result into one
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/autograd/grad_mode.py", line 43, in generator_context
#     response = gen.send(None)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ultralytics/yolo/engine/predictor.py", line 163, in stream_inference
#     self.setup_source(source if source is not None else self.args.source)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ultralytics/yolo/engine/predictor.py", line 141, in setup_source
#     self.dataset = load_inference_source(source=source,
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ultralytics/yolo/data/build.py", line 185, in load_inference_source
#     dataset = LoadPilAndNumpy(source, imgsz=imgsz, stride=stride, auto=auto, transforms=transforms)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ultralytics/yolo/data/dataloaders/stream_loaders.py", line 288, in __init__
#     self.im0 = [self._single_check(im) for im in im0]
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ultralytics/yolo/data/dataloaders/stream_loaders.py", line 288, in <listcomp>
#     self.im0 = [self._single_check(im) for im in im0]
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ultralytics/yolo/data/dataloaders/stream_loaders.py", line 303, in _single_check
#     im = np.asarray(im)[:, :, ::-1]
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/PIL/Image.py", line 701, in __array_interface__
#     new["data"] = self.tobytes()
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/PIL/Image.py", line 758, in tobytes
#     self.load()
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/PIL/ImageFile.py", line 269, in load
#     n, err_code = decoder.decode(b)
# KeyboardInterrupt

# %%
from medvqa.datasets.chest_imagenome.chest_imagenome_dataset_management import visualize_predicted_bounding_boxes__yolov8

# %%
visualize_predicted_bounding_boxes__yolov8(
    predictions_path='/mnt/data/pamessina/workspaces/medvqa-workspace/results/visual_module/20230331_073241_chest-imagenome_yolov8/chest_imagenome_gold__predictions(decent).pkl',
)
# Out:
# Predicted bounding boxes for 1b77c96e-849aa099-ab865966-6d4ac61d-92cb2a32:
# Predicted bounding boxes are in blue
# Ground truth bounding boxes are in red
