# %%
# %env CUDA_VISIBLE_DEVICES=2
# Out:
# env: CUDA_VISIBLE_DEVICES=2

# %%
# !python ../train_fact_embedding_NLI.py \
--pretrained_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240407_173847_NLI(Embedding-based)_EmbeddingBasedNLI(128,512-256-128)" \
--epochs 300 \
--batches_per_epoch 500 \
--batch_size 1000 \
--num_workers 4 \
--iters_to_accumulate 1 \
--optimizer_name "adamw" \
--scheduler "exp-warmup+decay+cyclicdecay" \
--lr 1e-6 \
--warmup_decay_and_cyclic_decay_args "1e-6,3,9e-5,10,2e-6,9e-5,10,2e-6" \
--fact_embedding_model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240629_084405_MIMIC-CXR(triplets+classif+entcont+nli+radgraph+autoencoder)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)" \
--fact_embedding_batch_size 50 \
--fact_embedding_num_workers 4 \
--use_report_nli \
--use_report_nli_entailment_dataset \
--use_report_nli_paraphrases_dataset \
--use_sentence2facts_for_nli \
--integrated_nli_jsonl_filepath \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(265719,34150895).jsonl" \
--sentence_to_facts_input_output_jsonl_filepaths \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_parsed_sentences__v2.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_parsed_sentences__v2(uniform).jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_facts_from_sentences(cluster-balanced,hardest)_part1.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_facts_from_sentences(cluster-balanced,hardest)_part2.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_parsed_sentences__v2.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_facts_from_sentences(cluster-balanced,hardest).jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_facts_from_sentences(cluster-balanced,hardest,conditional).jsonl" \
--integrated_report_facts_jsonl_filepath \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_report_facts(79040140).jsonl" \
--raw_report_nli_input_output_train_jsonl_filepaths \
"/mnt/workspace/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-1106-preview_cxrlt2024_report_nli_queries_dev.jsonl" \
--report_nli_input_output_train_jsonl_filepaths \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-1106-preview_fact_based_report_nli_queries(from_labels).jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-1106-preview_fact_based_report_nli_queries(from_facts).jsonl" \
--report_nli_input_output_val_jsonl_filepaths \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-1106-preview_fact_based_report_nli_queries(from_labels,v2).jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-1106-preview_fact_based_report_nli_queries(from_facts,v2).jsonl" \
--paraphrased_inputs_jsonl_filepaths \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_anatomical_locations__part1.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_anatomical_locations__part2.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-16k-0613_paraphrased_anatomical_locations__part3.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__single-words.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words__part1.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-16k-0613_paraphrased_observations__two-or-more-words__part2.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words__part3.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-16k-0613_paraphrased_observations__two-or-more-words__part4.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_paraphrased_observations__two-or-more-words_cluster-balanced.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words_cluster-balanced_1of5.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words_cluster-balanced_2of5.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words_cluster-balanced_3of5.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words_cluster-balanced_4of5.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_hard_triplets_from_facts(cluster-balanced,hardest)-part1.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_hard_triplets_from_facts(cluster-balanced,hardest)-part2.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_hard_triplets_from_facts(cluster-balanced,hardest)-part3.jsonl" \
--embedding_dim 128 \
--mlp_hidden_dims 512 256 128 \
--dropout 0 \
--use_amp \
--save
# Out:
# script's arguments:
#    epochs: 300
#    batches_per_epoch: 500
#    batch_size: 1000
#    num_workers: 4
#    checkpoint_folder: None
#    pretrained_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240407_173847_NLI(Embedding-based)_EmbeddingBasedNLI(128,512-256-128)
#    embedding_dim: 128
#    mlp_hidden_dims: [512, 256, 128]
#    dropout: 0.0
#    optimizer_name: adamw
#    lr: 1e-06
#    scheduler: exp-warmup+decay+cyclicdecay
#    warmup_decay_and_cyclic_decay_args: 1e-6,3,9e-5,10,2e-6,9e-5,10,2e-6
#    iters_to_accumulate: 1
#    override_lr: False
#    device: GPU
#    use_amp: True
#    integrated_nli_jsonl_filepath: /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(265719,34150895).jsonl
#    use_sentence2facts_for_nli: True
#    sentence_to_facts_input_output_jsonl_filepaths: ['/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_parsed_sentences__v2.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_parsed_sentences__v2(uniform).jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_facts_from_sentences(cluster-balanced,hardest)_part1.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_facts_from_sentences(cluster-balanced,hardest)_part2.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_parsed_sentences__v2.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_facts_from_sentences(cluster-balanced,hardest).jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_facts_from_sentences(cluster-balanced,hardest,conditional).jsonl']
#    use_anli: False
#    use_multinli: False
#    use_snli: False
#    use_report_nli: True
#    raw_report_nli_input_output_train_jsonl_filepaths: ['/mnt/workspace/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-1106-preview_cxrlt2024_report_nli_queries_dev.jsonl']
#    report_nli_input_output_train_jsonl_filepaths: ['/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-1106-preview_fact_based_report_nli_queries(from_labels).jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-1106-preview_fact_based_report_nli_queries(from_facts).jsonl']
#    report_nli_input_output_val_jsonl_filepaths: ['/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-1106-preview_fact_based_report_nli_queries(from_labels,v2).jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-1106-preview_fact_based_report_nli_queries(from_facts,v2).jsonl']
#    use_report_nli_entailment_dataset: True
#    use_report_nli_paraphrases_dataset: True
#    integrated_report_facts_jsonl_filepath: /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_report_facts(79040140).jsonl
#    paraphrased_inputs_jsonl_filepaths: ['/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_anatomical_locations__part1.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_anatomical_locations__part2.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-16k-0613_paraphrased_anatomical_locations__part3.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__single-words.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words__part1.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-16k-0613_paraphrased_observations__two-or-more-words__part2.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words__part3.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-16k-0613_paraphrased_observations__two-or-more-words__part4.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_paraphrased_observations__two-or-more-words_cluster-balanced.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words_cluster-balanced_1of5.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words_cluster-balanced_2of5.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words_cluster-balanced_3of5.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words_cluster-balanced_4of5.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_hard_triplets_from_facts(cluster-balanced,hardest)-part1.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_hard_triplets_from_facts(cluster-balanced,hardest)-part2.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_hard_triplets_from_facts(cluster-balanced,hardest)-part3.jsonl']
#    fact_embedding_model_name: microsoft/BiomedVLP-CXR-BERT-specialized
#    fact_embedding_model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240629_084405_MIMIC-CXR(triplets+classif+entcont+nli+radgraph+autoencoder)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)
#    fact_embedding_batch_size: 50
#    fact_embedding_num_workers: 4
#    save: True
# ----- Training model from scratch ------
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Creating instance of BertBasedNLI ...
# EmbeddingBasedNLI
#   embedding_dim: 128
#   mlp_hidden_dims: [512, 256, 128]
#   dropout: 0.0
# WARNING: unused_kwargs: {'pretrained_checkpoint_folder_path': '/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240407_173847_NLI(Embedding-based)_EmbeddingBasedNLI(128,512-256-128)'}
# --------------------------------------------------
# 3) Defining optimizer ...
# create_optimizer(): name = adamw
# --------------------------------------------------
# 4) Defining scheduler ...
# Using exp-warmup+decay+cyclicdecay scheduler: 1e-6,3,9e-5,10,2e-6,9e-5,10,2e-6
# 1e-06 3 9e-05 10 2e-06 9e-05 10 2e-06
# self.steps_to_restart = 10
# self.steps = -1
# self.initial_lr = 9e-05
# --------------------------------------------------
# 5) Creating trainer and validator engines ...
# GradientAccumulator.__init__(): num_accumulation_steps = 1, max_grad_norm = None
# --------------------------------------------------
# 6) Defining collate batch functions ...
# Loaded 19971 input/output pairs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_parsed_sentences__v2.jsonl
# Loaded 19984 input/output pairs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_parsed_sentences__v2(uniform).jsonl
# Loaded 14990 input/output pairs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_facts_from_sentences(cluster-balanced,hardest)_part1.jsonl
# Loaded 14991 input/output pairs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_facts_from_sentences(cluster-balanced,hardest)_part2.jsonl
# Loaded 9999 input/output pairs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_parsed_sentences__v2.jsonl
# Loaded 5000 input/output pairs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_facts_from_sentences(cluster-balanced,hardest).jsonl
# Loaded 9999 input/output pairs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_facts_from_sentences(cluster-balanced,hardest,conditional).jsonl
# Number of sentence2facts pairs: 90614
# Input/output example:
# Input:
# There is progression of left lower lobe opacity highly concerning for left lower lobe infectious process.
# Output:
# ["progression of left lower lobe opacity", "left lower lobe infectious process"]
# --------
# Loaded 9891 paraphrased inputs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_anatomical_locations__part1.jsonl
# Input:
# B
# Paraphrases:
# bilateral
# both sides
# both
# on both sides
# symmetrical
# equally on both sides
# present on both sides
# seen on both sides
# occurring on both sides
# appearing on both sides
# found on both sides
# noted on both sides
# noted bilaterally
# seen bilaterally
# observed bilaterally
# detected bilaterally
# --------
# Loaded 9890 paraphrased inputs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_anatomical_locations__part2.jsonl
# Input:
# left of the left hilus
# Paraphrases:
# left of the left hilum
# left to the left hilum
# left side of the left hilum
# leftward to the left hilum
# left of the hilum on the left side
# left of the pulmonary hilum on the left
# leftward to the pulmonary hilum on the left
# left to the hilum on the left side
# left side of the pulmonary hilum on the left
# leftward to the hilum on the left side
# --------
# Loaded 8511 paraphrased inputs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-16k-0613_paraphrased_anatomical_locations__part3.jsonl
# Input:
# peripheral pulmonary vasculature
# Paraphrases:
# peripheral lung vessels
# peripheral pulmonary blood vessels
# lung periphery vasculature
# vasculature of the peripheral lung
# blood vessels in the outer regions of the lung
# pulmonary vessels in the lung periphery
# vascular network in the peripheral lung
# peripheral pulmonary circulation
# blood vessels supplying the outer areas of the lung
# vasculature in the peripheral regions of the lung
# pulmonary vessels in the lung periphery
# vascular system in the outer regions of the lung
# --------
# Loaded 1864 paraphrased inputs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__single-words.jsonl
# Input:
# a
# Paraphrases:
# one
# single
# sole
# only
# individual
# lone
# solitary
# unique
# distinct
# singular
# --------
# Loaded 14993 paraphrased inputs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words__part1.jsonl
# Input:
# 5 cm
# Paraphrases:
# 5 centimeters
# 5 cm
# 5 centimetres
# 5 cm in size
# a length of 5 cm
# a measurement of 5 cm
# measuring 5 cm
# 5 centimeters in length
# a size of 5 cm
# 5 cm in dimension
# --------
# Loaded 14971 paraphrased inputs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-16k-0613_paraphrased_observations__two-or-more-words__part2.jsonl
# Input:
# limited base
# Paraphrases:
# restricted base
# constrained base
# narrowed base
# limited foundation
# restricted support
# constricted base
# reduced base
# diminished base
# restricted bottom
# constrained footing
# --------
# Loaded 14972 paraphrased inputs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words__part3.jsonl
# Input:
# not visible
# Paraphrases:
# not visualized
# not seen
# not apparent
# not detectable
# absent
# not present
# unable to visualize
# not observable
# not evident
# not identifiable
# --------
# Loaded 14965 paraphrased inputs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-16k-0613_paraphrased_observations__two-or-more-words__part4.jsonl
# Input:
# bowel loops
# Paraphrases:
# intestinal loops
# intestinal segments
# bowel segments
# intestinal coils
# intestinal twists
# intestinal convolutions
# intestinal turns
# intestinal curvatures
# intestinal windings
# intestinal meanders
# --------
# Loaded 10000 paraphrased inputs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_paraphrased_observations__two-or-more-words_cluster-balanced.jsonl
# Input:
# 5th rib
# Paraphrases:
# The fifth rib
# Rib number five
# Rib 5
# 5th rib bone
# Bone of the fifth rib
# Fifth rib structure
# Structure of the 5th rib
# 5th costal bone
# Fifth costal bone
# Costal bone number five
# 5th costae
# Costae number five
# Fifth costae structure
# Structure of the 5th costae
# --------
# Loaded 9999 paraphrased inputs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words_cluster-balanced_1of5.jsonl
# Input:
# CT 2
# Paraphrases:
# Computed tomography scan
# CT imaging
# CT examination
# CT scan
# CT imaging study
# Computed tomography imaging
# Computed tomography exam
# CT scan procedure
# CT scan test
# CT diagnostic imaging
# CT imaging technique
# CT scan investigation
# CT radiographic study
# Computed tomography imaging procedure
# CT scan evaluation
# --------
# Loaded 9997 paraphrased inputs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words_cluster-balanced_2of5.jsonl
# Input:
# line location
# Paraphrases:
# The line is located
# The position of the line is
# The line can be seen
# The line is situated
# The line is found
# The line appears
# The line is detected
# The line is identified
# The line is visible
# The line is present
# The line is observed
# The line is noted
# The line is seen
# The line is evident
# --------
# Loaded 9994 paraphrased inputs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words_cluster-balanced_3of5.jsonl
# Input:
# not apparent
# Paraphrases:
# No evidence of
# Not visible
# Not observable
# Not detected
# Not seen
# Not present
# Absence of
# Lack of
# Negative for
# No signs of
# No findings of
# No indications of
# No evidence suggesting
# No abnormalities detected
# --------
# Loaded 9996 paraphrased inputs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words_cluster-balanced_4of5.jsonl
# Input:
# CT on
# Paraphrases:
# Computed tomography performed
# CT scan done
# Imaging study using computed tomography
# Radiological examination using CT
# CT imaging conducted
# CT scan taken
# CT imaging performed
# Computed tomography examination
# CT scan carried out
# CT imaging study performed
# CT scan conducted
# Computed tomography study done
# CT imaging examination
# CT scan performed
# --------
# Loaded 19937 paraphrased inputs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_hard_triplets_from_facts(cluster-balanced,hardest)-part1.jsonl
# Input:
# no evidence of all-trans retinoic acid syndrome
# Paraphrases:
# no indication of all-trans retinoic acid syndrome
# absence of all-trans retinoic acid syndrome
# no signs of all-trans retinoic acid syndrome
# no presence of all-trans retinoic acid syndrome
# all-trans retinoic acid syndrome not detected
# all-trans retinoic acid syndrome is not observed
# --------
# Loaded 19937 paraphrased inputs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_hard_triplets_from_facts(cluster-balanced,hardest)-part2.jsonl
# Input:
# no evidence of significant constriction
# Paraphrases:
# no indication of notable narrowing
# absence of significant constriction
# no signs of substantial narrowing
# no evidence of significant narrowing
# lack of significant constriction
# no presence of notable constriction
# --------
# Loaded 19943 paraphrased inputs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_hard_triplets_from_facts(cluster-balanced,hardest)-part3.jsonl
# Input:
# no evidence of wheezing
# Paraphrases:
# no signs of wheezing
# absence of wheezing
# no wheezing detected
# no wheezing observed
# no wheezing present
# no wheezing found
# --------
# Number of unique inputs: 190083
# Number of total paraphrases: 2093173
# WARNING: Number of empty paraphrases: 2
# ----
# Loading integrated NLI from /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(265719,34150895).jsonl...
# Number of samples: 265719
# Number of sources: 7
# ----
# Loading sentence2facts input/output pairs for NLI...
# Number of entailment samples added: 214191
# ----
# Loading report NLI datasets...
# Loaded 85996 input/output pairs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-1106-preview_fact_based_report_nli_queries(from_facts).jsonl
# Loaded 63993 input/output pairs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-1106-preview_fact_based_report_nli_queries(from_labels).jsonl
# ----
# Loading raw report NLI examples from ['/mnt/workspace/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-1106-preview_cxrlt2024_report_nli_queries_dev.jsonl']...
# len(report2idx): 226964
# Loaded 152773 input/output pairs from /mnt/workspace/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-1106-preview_cxrlt2024_report_nli_queries_dev.jsonl
# Raw report: history: CSF leak with new leukocytosis. Findings: 7:23 PM Mediastinal/hilar fullness and rounded opacity on the lateral concerning for adenopathy. Consider CT with contrast for further assessment. 2 views were obtained of the chest. The lungs are low in volume but clear. The heart is top normal in size. Fullness and rounded contour of the mediastinal contour on the right suggests ascending aortic enlargement. Impression: Suspected ascending aortic enlargement. Consider CT with contrast for further assessment.
# Fact-based report: Mediastinal/hilar fullness. rounded opacity on the lateral. lateral concerning for adenopathy. 2 views obtained of the chest. low volume lungs. clear lungs. heart normal in size. fullness of the mediastinal contour on the right. rounded contour of the mediastinal contour on the right. suspected ascending aortic enlargement
# ----
# Building train NLI dataset...
# Source: gpt-4-0613 | Label: contradiction -> 79430 (4312.76)
# Example:
# Input:
# NLI1: Again noted is prominent mediastinal fat. #H: The patient's mediastinal fat is not visible.
# Output:
# contradiction
# Source: gpt-4-1106-preview_reasoning-prompt | Label: contradiction -> 46960 (3737.69)
# Example:
# Input:
# NLI1: 3. Asymmetric left upper lung opacification is stable and may represent aspiration #H: Otherwise, no definite infiltrate or evidence of aspiration.
# Output:
# contradiction
# Source: gpt-4-0613_reasoning-prompt | Label: contradiction -> 4170 (1739.18)
# Example:
# Input:
# NLI1: The cardiomediastinal contours are unremarkable. #H: The mediastinal and cardiac silhouettes are not well assessed due to the large right-sided opacity from pleural effusion, however, the right aspect of the mediastinum and heart appear unremarkable.
# Output:
# contradiction
# Source: mednli_train | Label: contradiction -> 3744 (1672.60)
# Example:
# Input:
# NLI1: He now presents for elective aortic valve repair with repair of left main outflow obstruction and coronary artery bypass grafting x 1. #H:  The patient has a normal heart.
# Output:
# contradiction
# Source: mednli_dev | Label: contradiction -> 465 (695.76)
# Example:
# Input:
# NLI1: Prior to transfer to [**Hospital1 1499**], the patient had received a total of 17 units of packed red blood cells, 7 units of fresh frozen plasma, one pack of platelets as well as two units of cryo. #H:  The patient had no blood loss
# Output:
# contradiction
# Source: mednli_test | Label: contradiction -> 474 (702.30)
# Example:
# Input:
# NLI1: 73 y/o female with severe atherosclerotic disease who has had multiple prior surgeries for significant claudication and initally had relief of symptoms, however, she now presents with new disease in her left femoral artery and a very small distal infrarenal abdominal aorta with very limited flow through the iliacs. #H:  Patient has normal patent vasculature
# Output:
# contradiction
# Source: radnli_dev | Label: contradiction -> 106 (304.54)
# Example:
# Input:
# NLI1: Mild cardiomegaly is again seen. #H: Cardiomediastinal silhouette is normal.
# Output:
# contradiction
# Source: report_nli_from_facts | Label: contradiction -> 15168 (2679.10)
# Example:
# Input:
# NLI1: 8 mm opacity projecting over the lateral right upper hemithorax. underlying pulmonary nodule not excluded. further assessment with bilateral shallow obliques chest radiographs. clear remainder of the lung fields. frontal view. lateral view. subtle mm opacity in the lateral right upper hemi thorax. subtle mm opacity above the level of the posterior lateral right sixth rib. unclear etiology of the opacity. finding may be external to the patient. shallow oblique radiographs for further assessment. clear left lung. no pleural effusion. no pneumothorax. unremarkable cardiac silhouette. unremarkable mediastinal silhouette. 8 mm opacity projecting over the lateral right upper hemi thorax #H: spiculated opacity projecting over the medial right upper hemithorax
# Output:
# contradiction
# Source: report_nli_from_labels | Label: contradiction -> 67119 (4122.50)
# Example:
# Input:
# NLI1: clear lungs. hyperexpanded lungs. no evidence of pneumonia. no evidence of pneumothorax. no evidence of pleural effusion. normal size cardiac silhouette. lungs without acute cardiopulmonary process #H: pneumonia seen
# Output:
# contradiction
# Medical datasets for label contradiction: 7
# Medical report from facts datasets for label contradiction: 1
# Medical report from labels datasets for label contradiction: 1
# Source: gpt-4-0613 | Label: entailment -> 13185 (2563.82)
# Example:
# Input:
# NLI1: Multiple clips are again noted in the right upper quadrant of the abdomen. #H: Multiple clips are is noted within the right upper quadrant of the abdomen.
# Output:
# entailment
# Source: gpt-4-1106-preview_reasoning-prompt | Label: entailment -> 35146 (3443.68)
# Example:
# Input:
# NLI1: 6:22 AM Findings consistent with decompensated congestive heart failure. #H: Findings suggestive of decompensated congestive heart failure.
# Output:
# entailment
# Source: gpt-4-0613_reasoning-prompt | Label: entailment -> 1770 (1256.05)
# Example:
# Input:
# NLI1: Interval improvement of pulmonary edema is seen. #H: Mild to moderate pulmonary edema, slightly improved compared to the prior study.
# Output:
# entailment
# Source: mednli_train | Label: entailment -> 3744 (1672.60)
# Example:
# Input:
# NLI1: Cath done on the [**12-6**] showed 70% left main with a totally occluded RCA, a 60% LAD lesion and diffuse circumflex disease. #H:  Cardiac catheterization was abnormal
# Output:
# entailment
# Source: mednli_dev | Label: entailment -> 465 (695.76)
# Example:
# Input:
# NLI1: Well controlled on Lipitor. #H:  He has hyperlipidemia
# Output:
# entailment
# Source: mednli_test | Label: entailment -> 473 (701.58)
# Example:
# Input:
# NLI1: About three weeks ago, patient reported an episode of chest "pressure" and "aching" spreading like a band across his upper chest and throat and slight radiation to both upper arms. #H:  The patient had angina
# Output:
# entailment
# Source: radnli_dev | Label: entailment -> 93 (279.62)
# Example:
# Input:
# NLI1: There are patchy bibasilar airspace opacities, likely reflective of atelectasis though infection cannot be completely excluded. #H: Bibasilar patchy opacities may reflect atelectasis though infection is not excluded.
# Output:
# entailment
# Source: s2f | Label: entailment -> 214191 (5553.26)
# Example:
# Input:
# NLI1: Middle retrocardiac streaky opacity likely reflects atelectasis. #H: atelectasis in the middle retrocardiac area
# Output:
# entailment
# Source: report_nli_from_facts | Label: entailment -> 46465 (3726.66)
# Example:
# Input:
# NLI1: left lower lobe consolidation developed. left lower lobe consolidation worsened. left lower lobe consolidation improved slightly. smaller region of consolidation in the right lower lung. worsening of consolidation in the right lower lung. areas of pneumonia. areas of atelectasis. borderline cardiomegaly. exaggerated by low lung volumes. small pleural effusions. no pneumothorax. ET tube in standard placement. nasogastric tube looped in the stomach. left central venous catheter ends in the upper right atrium #H: consolidated left lower lobe
# Output:
# entailment
# Source: report_nli_from_labels | Label: entailment -> 105725 (4649.07)
# Example:
# Input:
# NLI1: right chest wall port. catheter tip in the low portion of the SVC. kink in the catheter at the junction of the first rib and clavicle. mild pulmonary vascular congestion. no pulmonary edema. heart size is top normal. no pleural abnormality detected. kink in the mid clavicular line. kink along the course of the right subclavian catheter #H: subclavian line seen
# Output:
# entailment
# Medical datasets for label entailment: 8
# Loaded 227835 reports from /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_report_facts(79040140).jsonl
# FactBasedReportEntailmentDataset
# Loaded 227835 reports from /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_report_facts(79040140).jsonl
# FactBasedReportParaphrasesDataset
# Loaded 227835 reports from /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_report_facts(79040140).jsonl
# Number of facts: 586352
# Number of inputs with reports: 97257
# Number of inputs without reports: 92826
# Example:
# {'input_text': 'NLI1: low lung volumes. little overall change in the infrahilar opacification on the right. differences in degree of inspiration. atelectatic changes at the left base #H: Trivial overall variation in the right infrahilar opaqueness', 'output_text': 'entailment'}
# Example:
# {'input_text': 'NLI1: C-spine #H: upper spine', 'output_text': 'entailment'}
# Example:
# {'input_text': 'NLI1: PA view of the chest. lateral view of the chest. no prior chest x-ray for comparison. correlation made to images from CT scan of the abdomen and pelvis. low lung volumes. opacity in one of the lower lobes on the lateral view. clear area on prior chest CT. atelectasis in one of the lower lobes. blunting of the posterior costophrenic angles. normal cardiomediastinal silhouette. normal osseous structures. normal soft tissue structures. unremarkable chest x-ray #H: opacification in one of the lower lobes on the lateral view', 'output_text': 'entailment'}
# Medical report from facts datasets for label entailment: 2
# Medical report from labels datasets for label entailment: 2
# Source: gpt-4-0613 | Label: neutral -> 19123 (2877.24)
# Example:
# Input:
# NLI1: No signs of lung atelectasis or pneumothorax. #H: No signs of lung cancer, lung atelectasis, or pneumothorax.
# Output:
# neutral
# Source: gpt-4-1106-preview_reasoning-prompt | Label: neutral -> 47440 (3748.30)
# Example:
# Input:
# NLI1: There is no pneumothorax currently. #H: There is no pneumothorax, pneumonia, pulmonary edema or pleural effusion.
# Output:
# neutral
# Source: gpt-4-0613_reasoning-prompt | Label: neutral -> 3968 (1708.29)
# Example:
# Input:
# NLI1: No appreciable pleural effusions. #H: No new focal consolidation, pleural effusion, pneumothorax, or pulmonary edema is detected.
# Output:
# neutral
# Source: mednli_train | Label: neutral -> 3743 (1672.44)
# Example:
# Input:
# NLI1: 55 yo F w/ hx Hodgkin's s/p XRT in [**2849**] p/w severe abd pain x 3 weeks, worse over past week. #H:  Patient has metastatic disease
# Output:
# neutral
# Source: mednli_dev | Label: neutral -> 465 (695.76)
# Example:
# Input:
# NLI1: Lactate 3.4 . #H:  the patient is septic
# Output:
# neutral
# Source: mednli_test | Label: neutral -> 474 (702.30)
# Example:
# Input:
# NLI1: Since then, he has been experiencing worsening back pain, exacerbated with walking up and down stairs and lying on his back. #H:  The patient has degenerative chances in his lumbar spine.
# Output:
# neutral
# Source: radnli_dev | Label: neutral -> 281 (538.25)
# Example:
# Input:
# NLI1: There is a moderate left pleural effusion. #H: There is extensive scoliosis.
# Output:
# neutral
# Source: report_nli_from_facts | Label: neutral -> 24363 (3094.52)
# Example:
# Input:
# NLI1: new airspace opacities in the left perihilar region. worsening a previously reported left retrocardiac opacity. findings due to aspiration. findings due to evolving infectious pneumonia #H: worsening pneumonia in the right midlung
# Output:
# neutral
# Source: report_nli_from_labels | Label: neutral -> 43922 (3668.41)
# Example:
# Input:
# NLI1: indwelling support devices in standard position. monitoring devices in standard position. stable cardiomediastinal contours. bilateral lower lobe predominant fibrotic lung disease. superimposed patchy opacity at both bases. worsening of patchy opacity compared to previous exams. volume loss associated with patchy opacity at both bases. developing aspiration pneumonia. curvilinear opacity paralleling the right hemidiaphragm contour. area of linear basilar atelectasis adjacent to the diaphragm. possibility of a right basilar pneumothorax. possibility of free intraperitoneal air #H: pleural abnormalities seen
# Output:
# neutral
# Medical datasets for label neutral: 7
# Medical report from facts datasets for label neutral: 1
# Medical report from labels datasets for label neutral: 1
# ----
# Number of RadNLI test samples: 480
# Number of MS_CXR_T samples: 361
# Loaded 3845 input/output pairs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-1106-preview_fact_based_report_nli_queries(from_labels,v2).jsonl
# Loaded 2396 input/output pairs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-1106-preview_fact_based_report_nli_queries(from_facts,v2).jsonl
# Number of val NLI samples: 7082
# Input:
# NLI1: persistent left basal streaky opacities. persistent right basal streaky opacities. atelectasis clearing to some degree on the subsequent study. no focal consolidation. mild vascular congestion less pronounced than on the previous examination. no pleural effusion identified. no pneumothorax identified. heart likely normal in size. intact median sternotomy wires. normal cardiomediastinal silhouette. slight right sided indentation of the trachea. thyroid goiter. vascular congestion without overt edema #H: goiter seen
# Output:
# entailment
# Input:
# NLI1: presence of bilateral paramediastinal radiation fibrosis. slightly enlarged cardiomediastinal contour compared to prior chest radiograph. partially loculated left pleural effusion laterally. increased interstitial markings in both lung bases. interstitial markings present on the prior chest CT. interstitial markings may reflect mild pulmonary edema. interstitial markings may reflect lymphangitic spread. no new focal consolidation. no right-sided pleural effusion. no pneumothorax. distal posterior mediastinal clips. slightly increased size of the cardiomediastinal contour. presence of an increased pericardial effusion. unchanged appearance of small partially loculated left pleural effusion. increased interstitial opacities in the lung bases. similar compared to the prior chest CT. mild fluid overload. lymphangitic spread of tumor #H: fibrosis seen
# Output:
# entailment
# Input:
# NLI1: hyperinflated lungs. emphysematous changes in the lungs. scarring in the lung apices. scarring more so on the right. scarring unchanged. pulmonary vasculature not engorged. normal heart size. similar mediastinal contours. similar hilar contours. diffuse atherosclerotic calcifications in the aorta. no focal consolidation. no pleural effusion. no pneumothorax. no acute osseous abnormalities. biapical opacities. emphysema more so on the right. no acute cardiopulmonary process #H: calcification of the aorta seen
# Output:
# entailment
# Input:
# NLI1: stable post-radiation changes in the left upper lung. heart not enlarged. prominence of the right hila. known hilar lymphadenopathy. stable hilar lymphadenopathy. no pneumothorax. no pleural effusion. no consolidation. no acute cardiopulmonary process #H: unchanged scarring in the left mid/upper zone
# Output:
# entailment
# Input:
# NLI1: PA chest compared to previous study. lateral chest compared to previous study. increased radiodensity in the mid portions of both hemithoraces. small right pleural effusion. no left pleural effusion. no pneumothorax. clear lungs. normal heart size #H: low lung volumes seen
# Output:
# contradiction
# ----
# Building val NLI dataset...
# Number of general sentences: 0
# Number of medical sentences: 3034930
# Number of whole sentences: 2782837
# Number of splittable sentences: 252280
# Number of unique sentences (after sent_tokenize): 3348884
# Example train texts:
# {'input_text': 'NLI1: little overall change. no evidence of left pleural effusion. no evidence of acute pneumonia #H: pulmonary embolism seen', 'output_text': 'neutral'}
# {'input_text': 'NLI1: enlarged cardiac silhouette. scattered bilateral consolidations. no pneumothorax identified. Increased retrocardiac opacity. retrocardiac opacity reflecting atelectasis. retrocardiac opacity reflecting consolidation. known bilateral diffuse patchy consolidations #H: retrocardiac opacity reflecting consolidation', 'output_text': 'entailment'}
# {'input_text': 'NLI1: Multiple resultatn pathologic compression fractures are again seen within the thoracic spine but were better characterized by the recent chest CT examination. #H: recent chest CT examination of the thoracic spine', 'output_text': 'entailment'}
# Examples dev texts:
# {'input_text': 'NLI1: extensive subcutaneous emphysema has marginally decreased. pneumomediastinum has marginally decreased. small right apical pneumothorax has marginally decreased. median sternotomy with stable cardiac contours. mediastinal contours. persistent low lung volumes. stable parenchymal opacities in both lungs. parenchymal opacities in both lungs due to pulmonary fibrosis. bibasilar atelectasis unchanged. Right internal jugular Port-A-Cath unchanged in position. no pulmonary edema. minimal interval decrease in the extensive subcutaneous emphysema #H: subcutaneous air seen', 'output_text': 'entailment'}
# {'input_text': 'NLI1: large right pleural effusion. moderate left pleural effusion. increased right pleural effusion. increased left pleural effusion. Pulmonary edema mild if any. engorged mediastinal veins. mediastinal veins suggesting elevated central venous pressure. mediastinal veins suggesting elevated central venous volume. severe consolidation in the right perihilar lung. severe consolidation in the right lower lobe. consolidation in the right perihilar lung has not improved over several days. consolidation in the right lower lobe has not improved over several days. ET tube in standard placement. right jugular line ends in the upper SVC. nasogastric drainage tube traced to the low esophagus. tip of nasogastric drainage tube not visible #H: improvement in the interstitial pulmonary edema', 'output_text': 'neutral'}
# {'input_text': 'NLI1: AP chest taken at end expiration. AP chest taken at lateral view. low lung volumes. exaggerated airway abnormalities in the lungs. consolidation at the left lung base. consolidation that could be either atelectasis. consolidation that could be either pneumonia. no findings of pneumonia. exaggerated volume of the left apical pneumothorax. left apical pneumothorax entirely stable. Small left pleural effusion. normal physiologic progression of resorbing pneumothorax. mediastinal widening. low lung volume. normal heart size. no pulmonary edema #H: no evidence of pneumothorax after left upper lobe fiducial marker placement', 'output_text': 'contradiction'}
# checkpoint_names = ['checkpoint_196_cacc+chf1+chf1+cscc+encc+hscc+nlcc+sass+spss+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9189.pt']
#   0%|                                               | 0/3348884 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=441,505879158912416539).pkl
# len(self.cache["hashes"]) = 599219
# self.cache["embeddings"].shape = (599219, 128)
# 100%|█████████████████████████████| 3348884/3348884 [00:06<00:00, 537204.60it/s]
# Computing embeddings for 2752307 new texts
# checkpoint_names = ['checkpoint_196_cacc+chf1+chf1+cscc+encc+hscc+nlcc+sass+spss+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9189.pt']
# Loading model weights from /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240629_084405_MIMIC-CXR(triplets+classif+entcont+nli+radgraph+autoencoder)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/checkpoint_196_cacc+chf1+chf1+cscc+encc+hscc+nlcc+sass+spss+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9189.pt
# Warning: model state dict has 210 keys, loaded state dict has 257 keys, intersection has 210 keys, union has 257 keys.
# Examples of keys in loaded state dict but not in model:
#   chest_imagenome_anatloc_classifier.weight
#   spert_rel_classifier.bias
#   aux_task_hidden_layer.bias
#   nli_hidden_layer.bias
#   comparison_status_classifier.bias
#   fact_decoder.embedding_table.weight
#   spert_rel_classifier.weight
#   fact_decoder.start_idx
#   fact_decoder.W_vocab.weight
#   chest_imagenome_anatloc_classifier.bias
# 100%|█████████████████████████████████████| 55047/55047 [34:15<00:00, 26.78it/s]
# Saving updated cache to /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=441,505879158912416539).pkl
# 100%|█████████████████████████████| 2752307/2752307 [00:03<00:00, 773025.73it/s]
# embeddings.shape: (3348884, 128)
# Example train text (after wrapping):
# {'h_emb': array([-0.10234613, -0.0543058 , -0.0451985 , -0.07320194, -0.06167185,
#         0.05667709, -0.18683794, -0.0713241 ,  0.01610832,  0.01322492,
#         0.07425272, -0.06850319, -0.0132782 ,  0.04602237, -0.19394158,
#         0.04714797,  0.02577208, -0.05738147, -0.13035578, -0.0177027 ,
#         0.04874487, -0.01646605,  0.04105166, -0.00975742,  0.05133001,
#         0.12339652,  0.01148228, -0.08535995,  0.07415906, -0.20767595,
#         0.03834461, -0.12482446, -0.04820833, -0.00807818, -0.03451634,
#        -0.02765277,  0.12684184, -0.10061649,  0.15661718,  0.06774038,
#         0.00199521, -0.05437018, -0.00322001, -0.04423035, -0.15917999,
#        -0.02209407,  0.0523821 , -0.2881462 ,  0.02292445,  0.04518002,
#        -0.04332312, -0.08155452,  0.07088405,  0.1876811 ,  0.08114293,
#         0.04538614, -0.01666122,  0.09365848, -0.08950957,  0.04497973,
#         0.03331695,  0.03552702, -0.14565736, -0.08308753, -0.09547788,
#        -0.01011832, -0.02711477,  0.06473219, -0.0858443 , -0.0541753 ,
#         0.1734238 ,  0.02811848, -0.10046994, -0.05354129,  0.01348363,
#        -0.06142459,  0.09592043,  0.02492862, -0.17376947, -0.09518041,
#        -0.07124153, -0.11363138, -0.0537583 , -0.08487783,  0.00334908,
#         0.12065772, -0.07825268, -0.03148716,  0.25078365,  0.03051573,
#        -0.00489989, -0.06581983, -0.02589871, -0.05279306, -0.08456504,
#         0.08055752,  0.09392443,  0.04338942,  0.0294424 , -0.09249558,
#         0.04317208, -0.04412664,  0.10842361, -0.02517643,  0.00055133,
#        -0.13960184, -0.00045582, -0.06300975,  0.02047771,  0.1143223 ,
#         0.01275137, -0.01100292,  0.09873145,  0.113023  , -0.11046932,
#         0.1472509 ,  0.03075403, -0.08962183, -0.17883024, -0.07674727,
#        -0.00926813, -0.00088593,  0.1526916 , -0.07013839,  0.04625507,
#         0.00537269,  0.01627639, -0.11425742], dtype=float32), 'p_most_sim_emb': array([-0.18807346, -0.04836244, -0.05962717, -0.15194212, -0.05480756,
#         0.02367953, -0.05754997, -0.17111903, -0.03335383,  0.05231555,
#         0.02658607, -0.02424723,  0.08166022,  0.066192  , -0.09364304,
#         0.03834252, -0.02201449,  0.04546311, -0.05783189,  0.00234335,
#         0.03097358, -0.03810017,  0.06167279,  0.06592311,  0.07765307,
#        -0.04160798, -0.01849002, -0.09668475,  0.11083984, -0.13059674,
#        -0.013697  , -0.09626431, -0.12948962,  0.02512933, -0.05843458,
#        -0.01148653,  0.10319106,  0.02167019,  0.03053439,  0.06390113,
#         0.06005786,  0.01504439, -0.04798646,  0.00242195, -0.12459013,
#         0.06093511, -0.00705484, -0.2803878 ,  0.06750198, -0.02570941,
#        -0.04222429,  0.00899508, -0.03849959,  0.04747615,  0.02089424,
#         0.0337327 , -0.10531086,  0.0509364 , -0.00606308,  0.07759228,
#         0.01099789,  0.01137796, -0.13335086, -0.00748095,  0.01398305,
#        -0.11276034, -0.01002562,  0.10931193, -0.1573349 , -0.12581764,
#         0.28830972, -0.00548356, -0.12890062,  0.02055737,  0.00369928,
#        -0.1151236 ,  0.10010687,  0.05725773, -0.11680858, -0.09618342,
#        -0.01573824, -0.12547226, -0.10976174, -0.03667142, -0.02419522,
#         0.10381664, -0.01335035,  0.02630708,  0.11715199, -0.01900845,
#         0.10964405,  0.02680243,  0.06207933, -0.12341066, -0.03861592,
#        -0.00217018, -0.03249167, -0.02895511,  0.09105144, -0.06360003,
#        -0.03328156, -0.06408353,  0.17919993,  0.06997687, -0.02163071,
#        -0.10203619,  0.02383586,  0.03324285,  0.17078276,  0.13235778,
#        -0.13313144, -0.00819648,  0.1742199 ,  0.20128092, -0.05215772,
#         0.20066947, -0.03375704,  0.04055376, -0.14612716, -0.07571876,
#        -0.09886702,  0.02488389,  0.04054273, -0.00101347, -0.00995216,
#        -0.00577073,  0.12292039,  0.01708722], dtype=float32), 'p_least_sim_emb': array([ 0.05635346, -0.00324755, -0.01036698, -0.01073641,  0.02337553,
#        -0.01735471,  0.18763901,  0.09109423,  0.07121578,  0.02121183,
#        -0.01999255, -0.12853228,  0.00111315, -0.14927131, -0.04605617,
#        -0.01236127, -0.08190352, -0.05689987,  0.05850592,  0.11872771,
#         0.05975176, -0.07601471, -0.06260941, -0.09412863, -0.01481772,
#        -0.01510947, -0.16107799,  0.14670847, -0.11111819, -0.11250344,
#        -0.03069256,  0.06113786, -0.00967876, -0.00293677, -0.01830027,
#         0.0676696 , -0.07135615,  0.09462741, -0.02840521,  0.03631322,
#         0.041326  ,  0.05933524, -0.01720129, -0.00634183, -0.20590007,
#         0.04141239, -0.14603351,  0.00588614,  0.02855771,  0.04858313,
#        -0.04317427,  0.05342287, -0.0780599 ,  0.01357038, -0.17096028,
#        -0.01405145,  0.07776933, -0.19839182,  0.01702641,  0.08184126,
#        -0.057832  , -0.03112829,  0.13020623, -0.00958527, -0.00215351,
#         0.03021846, -0.16340224, -0.05161196,  0.02862689, -0.01765578,
#        -0.23256457,  0.00998246, -0.06542387, -0.03071977,  0.20548324,
#        -0.01148218,  0.00786143, -0.10853533, -0.07969492, -0.01976896,
#        -0.0405771 ,  0.04043487, -0.18204023, -0.25156403,  0.00380821,
#         0.08023245,  0.02685432,  0.00289952,  0.05594674, -0.2401216 ,
#         0.11560272, -0.00250873,  0.11483578, -0.1397744 ,  0.05452453,
#        -0.00466235,  0.10004325, -0.07559592, -0.12678222,  0.16212514,
#         0.09491646, -0.15216327, -0.01552794, -0.03604055,  0.11766325,
#         0.05176694,  0.01584718, -0.00219714,  0.08892628,  0.09718855,
#         0.03338775, -0.12432356, -0.06694525, -0.00623308, -0.00263567,
#         0.11228863, -0.08009163,  0.02685924, -0.09398578,  0.04481567,
#        -0.10058043, -0.03649197, -0.01788118,  0.05909077, -0.07498604,
#         0.02878336,  0.01150713, -0.02229372], dtype=float32), 'p_max_emb': array([ 0.10955444, -0.00324755,  0.00507992,  0.03215935,  0.02337553,
#         0.16040742,  0.18763901,  0.21107525,  0.07121578,  0.1600992 ,
#         0.02658607,  0.00277901,  0.13549879,  0.066192  ,  0.03553161,
#         0.03834252,  0.00468387,  0.12375485,  0.08143277,  0.23352896,
#         0.229768  ,  0.01404044,  0.08250763,  0.06592311,  0.14138135,
#        -0.01510947,  0.11280344,  0.14670847,  0.11606692, -0.01715657,
#         0.03555543,  0.14915422,  0.06156216,  0.04330875,  0.11733674,
#         0.07736702,  0.13317052,  0.1112319 ,  0.03053439,  0.09426611,
#         0.08011807,  0.05933524,  0.05357   ,  0.0136796 , -0.03814668,
#         0.12483448,  0.01231753,  0.10005757,  0.09097422,  0.06317887,
#         0.03611594,  0.08755308, -0.03227786,  0.07289807,  0.06459443,
#         0.07607884,  0.1048404 ,  0.14548466,  0.11731237,  0.13485798,
#         0.07579301,  0.01137796,  0.21716473,  0.09782558,  0.08552221,
#         0.0376568 , -0.01002562,  0.11368026,  0.0904253 , -0.01710308,
#         0.28830972,  0.04978114, -0.03121487,  0.08430095,  0.2589532 ,
#         0.00454845,  0.10010687,  0.05725773, -0.03393937, -0.01520295,
#         0.05299592,  0.08086614,  0.07494009, -0.03667142,  0.06891778,
#         0.10381664,  0.02685432,  0.08270865,  0.17024212, -0.01900845,
#         0.14512758,  0.08965866,  0.1466413 , -0.06504516,  0.06197796,
#         0.05955737,  0.1069525 , -0.01886985,  0.11869387,  0.18062928,
#         0.19325085,  0.05970057,  0.17919993,  0.18862024,  0.12062062,
#         0.14948058,  0.11241702,  0.1811721 ,  0.221237  ,  0.15569445,
#         0.06965646,  0.08077672,  0.1742199 ,  0.20128092,  0.00762327,
#         0.20066947, -0.01711072,  0.06418672, -0.0752366 ,  0.04481567,
#         0.02942011,  0.04661122,  0.05613647,  0.06239308,  0.00619596,
#         0.14520985,  0.12292039,  0.02646171], dtype=float32), 'p_avg_emb': array([-0.02726575, -0.03979206, -0.0359546 , -0.04708063, -0.01366545,
#         0.01005643,  0.00762663,  0.03595053, -0.01217731,  0.04314113,
#        -0.01825178, -0.08185116,  0.02858271, -0.05637457, -0.02295515,
#        -0.02013347, -0.06982218, -0.01513267,  0.0407175 ,  0.10930136,
#         0.07386508, -0.06178668, -0.01020803, -0.03400441,  0.05287893,
#        -0.0610113 , -0.04572468, -0.03862663, -0.03154435, -0.07688139,
#        -0.0295151 ,  0.03929258, -0.02658848,  0.00110326,  0.02881575,
#        -0.00516927,  0.04069783,  0.03605528, -0.02394781,  0.02462525,
#         0.05051433,  0.00993319, -0.03276449, -0.01218112, -0.16848773,
#         0.0510804 , -0.11890837, -0.07041516,  0.04274276,  0.01546919,
#        -0.00369943,  0.03533084, -0.07341161,  0.02779494, -0.03754511,
#         0.02657434,  0.02811565, -0.01773205,  0.04601424,  0.10027283,
#        -0.00199179, -0.04771284,  0.07875237,  0.03344838,  0.02137948,
#        -0.05341989, -0.13159579, -0.00277517, -0.03139476, -0.08747745,
#         0.02937217,  0.01555091, -0.0722493 ,  0.03819407,  0.14041433,
#        -0.06595527,  0.02118264, -0.02856065, -0.10786217, -0.04462204,
#        -0.02167284, -0.01603162, -0.03124088, -0.1893776 ,  0.0079873 ,
#         0.05747837, -0.03335329,  0.00210327,  0.09671649, -0.19668297,
#         0.10960598, -0.0079366 ,  0.07778312, -0.11801599,  0.02652298,
#        -0.00729759,  0.03374348, -0.05163517, -0.05368981,  0.05808194,
#         0.06075241, -0.05387192,  0.03835697,  0.04550578,  0.01014751,
#         0.04582623, -0.01080314,  0.04898625,  0.08273974,  0.06894914,
#        -0.01871562, -0.0706424 ,  0.03617528,  0.01101841, -0.03039484,
#         0.10684626, -0.06711854,  0.00099698, -0.11851435, -0.02185175,
#        -0.10718261, -0.01079661, -0.03062686,  0.0044344 , -0.04044018,
#         0.0560283 ,  0.0196197 , -0.0215859 ], dtype=float32), 'l': 1}
# Example dev text (after wrapping):
# {'h_emb': array([ 1.58468723e-01,  4.66857888e-02,  8.20147805e-04,  6.46373723e-03,
#        -2.79819649e-02, -9.59792435e-02, -5.80937117e-02, -7.82285184e-02,
#        -2.00628974e-02,  5.41812070e-02,  4.06512134e-02, -1.34059981e-01,
#         1.70365036e-01,  1.27436742e-02,  8.46902430e-02, -1.07722417e-01,
#        -1.41953811e-01,  5.13022020e-02,  7.58047849e-02, -1.26796424e-01,
#        -1.86039165e-01,  1.12164393e-01, -7.16369003e-02, -5.10101281e-02,
#        -2.36965469e-04,  6.38689920e-02, -8.89523253e-02,  4.47464436e-02,
#         1.17962323e-02, -9.31694061e-02, -5.75256720e-02, -8.77704695e-02,
#        -1.02571748e-01, -1.17819548e-01, -3.43059516e-03, -9.61136073e-02,
#        -7.25271255e-02, -7.09875003e-02, -2.72303112e-02, -4.77448180e-02,
#        -2.77650636e-02,  8.93109664e-02,  8.83228779e-02, -9.65251774e-02,
#         9.09288675e-02,  4.96772118e-02,  1.46056980e-01,  1.02384143e-01,
#        -7.04316199e-02, -6.86751455e-02,  9.02778432e-02, -4.74869683e-02,
#         6.97643384e-02, -5.87660410e-02,  8.28706939e-03,  8.74321684e-02,
#        -1.41946733e-01, -4.65863757e-02,  1.35594048e-02,  1.29410662e-02,
#        -5.95721789e-02, -7.36387521e-02, -9.40173566e-02, -4.53307070e-02,
#         1.67698767e-02,  4.98641618e-02,  7.99165741e-02, -5.09407632e-02,
#         1.56651497e-01,  7.37689361e-02, -1.36501133e-01, -3.85004878e-02,
#         1.23174295e-01,  9.64744575e-03, -6.95304200e-02,  1.92804590e-01,
#         7.28443936e-02,  1.28464296e-01, -2.20932011e-02,  4.59511317e-02,
#         2.55532712e-02,  7.04868585e-02, -1.88669972e-02,  2.60704756e-01,
#        -1.72761660e-02, -1.31606773e-01,  3.61474976e-02,  8.46703723e-02,
#        -1.11078642e-01,  1.30879566e-01, -1.26545757e-01, -3.43923308e-02,
#        -1.59757435e-01,  1.15365960e-01,  3.61219086e-02,  9.47862267e-02,
#        -4.18681768e-04,  4.44104560e-02,  1.71467423e-01, -3.15460889e-03,
#        -1.02140442e-01, -4.60572876e-02,  1.01062909e-01, -7.00536445e-02,
#         6.70155138e-02, -3.35598439e-02, -1.70941681e-01, -1.83431152e-02,
#        -4.09159213e-02, -1.25555322e-01, -6.70362785e-02,  1.27228424e-01,
#         3.23308143e-03, -8.74190778e-03,  6.30926490e-02,  7.73317041e-03,
#         6.11043610e-02,  1.38034180e-01,  1.51470676e-01, -2.41411272e-02,
# ...
# ---- Epoch 87/300
# (1) Training stage (lr = 0.000039) ...
# loss 0.34402, nli_loss 0.34402, nli_acc 0.86657, 43.33 secs
# (2) Validation stage ...
# nli_acc 0.73722, 1.42 secs
# ---- Epoch 88/300
# (1) Training stage (lr = 0.000025) ...
# loss 0.33880, nli_loss 0.33880, nli_acc 0.87020, 43.20 secs
# (2) Validation stage ...
# nli_acc 0.74259, 1.42 secs
# ---- Epoch 89/300
# (1) Training stage (lr = 0.000017) ...
# loss 0.33629, nli_loss 0.33629, nli_acc 0.87125, 43.23 secs
# (2) Validation stage ...
# nli_acc 0.73990, 1.42 secs
# ---- Epoch 90/300
# (1) Training stage (lr = 0.000011) ...
# loss 0.33193, nli_loss 0.33193, nli_acc 0.87393, 43.35 secs
# (2) Validation stage ...
# nli_acc 0.74612, 1.44 secs
# ---- Epoch 91/300
# (1) Training stage (lr = 0.000007) ...
# loss 0.33170, nli_loss 0.33170, nli_acc 0.87415, 43.49 secs
# (2) Validation stage ...
# nli_acc 0.73906, 1.43 secs
# ---- Epoch 92/300
# (1) Training stage (lr = 0.000005) ...
# loss 0.32983, nli_loss 0.32983, nli_acc 0.87521, 43.58 secs
# (2) Validation stage ...
# nli_acc 0.74259, 1.43 secs
# ---- Epoch 93/300
# (1) Training stage (lr = 0.000003) ...
# loss 0.32853, nli_loss 0.32853, nli_acc 0.87589, 43.28 secs
# (2) Validation stage ...
# nli_acc 0.74343, 1.45 secs
# ---- Epoch 94/300
# (1) Training stage (lr = 0.000002) ...
# loss 0.32978, nli_loss 0.32978, nli_acc 0.87554, 43.51 secs
# (2) Validation stage ...
# nli_acc 0.74202, 1.42 secs
# ---- Epoch 95/300
# (1) Training stage (lr = 0.000090) ...
# loss 0.35513, nli_loss 0.35513, nli_acc 0.85952, 43.40 secs
# (2) Validation stage ...
# nli_acc 0.73863, 1.42 secs
# ---- Epoch 96/300
# (1) Training stage (lr = 0.000059) ...
# loss 0.34422, nli_loss 0.34422, nli_acc 0.86589, 43.31 secs
# (2) Validation stage ...
# nli_acc 0.73637, 1.42 secs
# ---- Epoch 97/300
# (1) Training stage (lr = 0.000039) ...
# loss 0.33586, nli_loss 0.33586, nli_acc 0.87077, 43.40 secs
# (2) Validation stage ...
# nli_acc 0.75261, 1.43 secs
# ---- Epoch 98/300
# (1) Training stage (lr = 0.000025) ...
# loss 0.33005, nli_loss 0.33005, nli_acc 0.87415, 43.65 secs
# (2) Validation stage ...
# nli_acc 0.74358, 1.42 secs
# ---- Epoch 99/300
# (1) Training stage (lr = 0.000017) ...
# loss 0.32734, nli_loss 0.32734, nli_acc 0.87559, 43.44 secs
# (2) Validation stage ...
# nli_acc 0.74230, 1.43 secs
# ---- Epoch 100/300
# (1) Training stage (lr = 0.000011) ...
# loss 0.32458, nli_loss 0.32458, nli_acc 0.87704, 43.39 secs
# (2) Validation stage ...
# nli_acc 0.73581, 1.42 secs
# ---- Epoch 101/300
# (1) Training stage (lr = 0.000007) ...
# loss 0.32418, nli_loss 0.32418, nli_acc 0.87722, 43.33 secs
# (2) Validation stage ...
# nli_acc 0.73779, 1.45 secs
# ---- Epoch 102/300
# (1) Training stage (lr = 0.000005) ...
# loss 0.32080, nli_loss 0.32080, nli_acc 0.87880, 43.44 secs
# (2) Validation stage ...
# nli_acc 0.74358, 1.42 secs
# ---- Epoch 103/300
# (1) Training stage (lr = 0.000003) ...
# loss 0.32049, nli_loss 0.32049, nli_acc 0.87930, 43.79 secs
# (2) Validation stage ...
# nli_acc 0.74527, 1.42 secs
# ---- Epoch 104/300
# (1) Training stage (lr = 0.000002) ...
# loss 0.32056, nli_loss 0.32056, nli_acc 0.87914, 43.28 secs
# (2) Validation stage ...
# nli_acc 0.74132, 1.42 secs
# ---- Epoch 105/300
# (1) Training stage (lr = 0.000090) ...
# loss 0.34766, nli_loss 0.34766, nli_acc 0.86276, 43.27 secs
# (2) Validation stage ...
# nli_acc 0.74047, 1.42 secs
# ---- Epoch 106/300
# (1) Training stage (lr = 0.000059) ...
# loss 0.33711, nli_loss 0.33711, nli_acc 0.86973, 43.51 secs
# (2) Validation stage ...
# nli_acc 0.73397, 1.42 secs
# ---- Epoch 107/300
# (1) Training stage (lr = 0.000039) ...
# loss 0.32869, nli_loss 0.32869, nli_acc 0.87372, 43.14 secs
# (2) Validation stage ...
# nli_acc 0.74725, 1.42 secs
# ---- Epoch 108/300
# (1) Training stage (lr = 0.000025) ...
# loss 0.32225, nli_loss 0.32225, nli_acc 0.87710, 43.24 secs
# (2) Validation stage ...
# nli_acc 0.74103, 1.42 secs
# ---- Epoch 109/300
# (1) Training stage (lr = 0.000017) ...
# loss 0.32101, nli_loss 0.32101, nli_acc 0.87837, 43.22 secs
# (2) Validation stage ...
# nli_acc 0.73157, 1.42 secs
# ---- Epoch 110/300
# (1) Training stage (lr = 0.000011) ...
# loss 0.31583, nli_loss 0.31583, nli_acc 0.88080, 43.24 secs
# (2) Validation stage ...
# nli_acc 0.73581, 1.45 secs
# ---- Epoch 111/300
# (1) Training stage (lr = 0.000007) ...
# loss 0.31596, nli_loss 0.31596, nli_acc 0.88092, 43.37 secs
# (2) Validation stage ...
# nli_acc 0.74216, 1.44 secs
# ---- Epoch 112/300
# (1) Training stage (lr = 0.000005) ...
# loss 0.31456, nli_loss 0.31456, nli_acc 0.88175, 43.24 secs
# (2) Validation stage ...
# nli_acc 0.74569, 1.43 secs
# ---- Epoch 113/300
# (1) Training stage (lr = 0.000003) ...
# loss 0.31377, nli_loss 0.31377, nli_acc 0.88181, 43.36 secs
# (2) Validation stage ...
# nli_acc 0.74541, 1.42 secs
# ---- Epoch 114/300
# (1) Training stage (lr = 0.000002) ...
# loss 0.31269, nli_loss 0.31269, nli_acc 0.88245, 43.34 secs
# (2) Validation stage ...
# nli_acc 0.73962, 1.43 secs
# ---- Epoch 115/300
# (1) Training stage (lr = 0.000090) ...
# loss 0.34233, nli_loss 0.34233, nli_acc 0.86521, 43.31 secs
# (2) Validation stage ...
# nli_acc 0.74188, 1.43 secs
# ---- Epoch 116/300
# (1) Training stage (lr = 0.000059) ...
# loss 0.33036, nli_loss 0.33036, nli_acc 0.87189, 43.44 secs
# (2) Validation stage ...
# nli_acc 0.74202, 1.42 secs
# ---- Epoch 117/300
# (1) Training stage (lr = 0.000039) ...
# loss 0.32093, nli_loss 0.32093, nli_acc 0.87687, 43.41 secs
# (2) Validation stage ...
# nli_acc 0.74033, 1.44 secs
# ---- Epoch 118/300
# (1) Training stage (lr = 0.000025) ...
# loss 0.31668, nli_loss 0.31668, nli_acc 0.87957, 43.25 secs
# (2) Validation stage ...
# nli_acc 0.74075, 1.43 secs
# ---- Epoch 119/300
# (1) Training stage (lr = 0.000017) ...
# loss 0.31385, nli_loss 0.31385, nli_acc 0.88079, 43.48 secs
# (2) Validation stage ...
# nli_acc 0.73623, 1.42 secs
# ---- Epoch 120/300
# (1) Training stage (lr = 0.000011) ...
# loss 0.30909, nli_loss 0.30909, nli_acc 0.88363, 43.33 secs
# (2) Validation stage ...
# nli_acc 0.73652, 1.42 secs
# ---- Epoch 121/300
# (1) Training stage (lr = 0.000007) ...
# loss 0.30934, nli_loss 0.30934, nli_acc 0.88363, 43.28 secs
# (2) Validation stage ...
# nli_acc 0.74485, 1.41 secs
# ---- Epoch 122/300
# (1) Training stage (lr = 0.000005) ...
# loss 0.30611, nli_loss 0.30611, nli_acc 0.88511, 43.36 secs
# (2) Validation stage ...
# nli_acc 0.73962, 1.42 secs
# ---- Epoch 123/300
# (1) Training stage (lr = 0.000003) ...
# loss 0.30693, nli_loss 0.30693, nli_acc 0.88487, 43.35 secs
# (2) Validation stage ...
# nli_acc 0.74343, 1.42 secs
# ---- Epoch 124/300
# (1) Training stage (lr = 0.000002) ...
# loss 0.30723, nli_loss 0.30723, nli_acc 0.88452, 43.31 secs
# (2) Validation stage ...
# nli_acc 0.74188, 1.43 secs
# ---- Epoch 125/300
# (1) Training stage (lr = 0.000090) ...
# loss 0.33461, nli_loss 0.33461, nli_acc 0.86892, 43.44 secs
# (2) Validation stage ...
# nli_acc 0.73750, 1.43 secs
# ---- Epoch 126/300
# (1) Training stage (lr = 0.000059) ...
# loss 0.32343, nli_loss 0.32343, nli_acc 0.87526, 43.34 secs
# (2) Validation stage ...
# nli_acc 0.75261, 1.42 secs
# ---- Epoch 127/300
# (1) Training stage (lr = 0.000039) ...
# loss 0.31550, nli_loss 0.31550, nli_acc 0.87948, 43.48 secs
# (2) Validation stage ...
# nli_acc 0.73793, 1.42 secs
# ---- Epoch 128/300
# (1) Training stage (lr = 0.000025) ...
# loss 0.30998, nli_loss 0.30998, nli_acc 0.88210, 43.26 secs
# (2) Validation stage ...
# nli_acc 0.74160, 1.46 secs
# ---- Epoch 129/300
# (1) Training stage (lr = 0.000017) ...
# loss 0.30594, nli_loss 0.30594, nli_acc 0.88418, 43.22 secs
# (2) Validation stage ...
# nli_acc 0.73764, 1.43 secs
# ---- Epoch 130/300
# (1) Training stage (lr = 0.000011) ...
# loss 0.30326, nli_loss 0.30326, nli_acc 0.88542, 43.30 secs
# (2) Validation stage ...
# nli_acc 0.73411, 1.42 secs
# ---- Epoch 131/300
# (1) Training stage (lr = 0.000007) ...
# loss 0.30270, nli_loss 0.30270, nli_acc 0.88605, 43.44 secs
# (2) Validation stage ...
# nli_acc 0.74541, 1.42 secs
# ---- Epoch 132/300
# (1) Training stage (lr = 0.000005) ...
# loss 0.30052, nli_loss 0.30052, nli_acc 0.88698, 43.49 secs
# (2) Validation stage ...
# nli_acc 0.74132, 1.43 secs
# ---- Epoch 133/300
# (1) Training stage (lr = 0.000003) ...
# loss 0.30008, nli_loss 0.30008, nli_acc 0.88745, 43.35 secs
# (2) Validation stage ...
# nli_acc 0.74117, 1.42 secs
# ---- Epoch 134/300
# (1) Training stage (lr = 0.000002) ...
# loss 0.29955, nli_loss 0.29955, nli_acc 0.88757, 43.59 secs
# (2) Validation stage ...
# nli_acc 0.74005, 1.42 secs
# ---- Epoch 135/300
# (1) Training stage (lr = 0.000090) ...
# loss 0.32973, nli_loss 0.32973, nli_acc 0.87046, 43.42 secs
# (2) Validation stage ...
# nli_acc 0.74245, 1.43 secs
# ---- Epoch 136/300
# (1) Training stage (lr = 0.000059) ...
# loss 0.31898, nli_loss 0.31898, nli_acc 0.87663, 43.31 secs
# (2) Validation stage ...
# nli_acc 0.74103, 1.43 secs
# ---- Epoch 137/300
# (1) Training stage (lr = 0.000039) ...
# loss 0.30863, nli_loss 0.30863, nli_acc 0.88163, 44.48 secs
# (2) Validation stage ...
# nli_acc 0.74809, 1.45 secs
# ---- Epoch 138/300
# (1) Training stage (lr = 0.000025) ...
# loss 0.30390, nli_loss 0.30390, nli_acc 0.88474, 43.28 secs
# (2) Validation stage ...
# nli_acc 0.74160, 1.40 secs
# ---- Epoch 139/300
# (1) Training stage (lr = 0.000017) ...
# loss 0.30157, nli_loss 0.30157, nli_acc 0.88608, 43.39 secs
# (2) Validation stage ...
# nli_acc 0.74259, 1.46 secs
# ---- Epoch 140/300
# (1) Training stage (lr = 0.000011) ...
# loss 0.29658, nli_loss 0.29658, nli_acc 0.88798, 43.24 secs
# (2) Validation stage ...
# nli_acc 0.74117, 1.44 secs
# ---- Epoch 141/300
# (1) Training stage (lr = 0.000007) ...
# loss 0.29724, nli_loss 0.29724, nli_acc 0.88818, 43.46 secs
# (2) Validation stage ...
# nli_acc 0.74273, 1.42 secs
# ---- Epoch 142/300
# (1) Training stage (lr = 0.000005) ...
# loss 0.29519, nli_loss 0.29519, nli_acc 0.88898, 43.47 secs
# (2) Validation stage ...
# nli_acc 0.74555, 1.44 secs
# ---- Epoch 143/300
# (1) Training stage (lr = 0.000003) ...
# loss 0.29353, nli_loss 0.29353, nli_acc 0.88960, 43.42 secs
# (2) Validation stage ...
# nli_acc 0.74456, 1.42 secs
# ---- Epoch 144/300
# (1) Training stage (lr = 0.000002) ...
# loss 0.29397, nli_loss 0.29397, nli_acc 0.88961, 43.25 secs
# (2) Validation stage ...
# nli_acc 0.74343, 1.43 secs
# ---- Epoch 145/300
# (1) Training stage (lr = 0.000090) ...
# loss 0.32511, nli_loss 0.32511, nli_acc 0.87241, 43.48 secs
# (2) Validation stage ...
# nli_acc 0.73270, 1.44 secs
# ---- Epoch 146/300
# (1) Training stage (lr = 0.000059) ...
# loss 0.31180, nli_loss 0.31180, nli_acc 0.87976, 43.41 secs
# (2) Validation stage ...
# nli_acc 0.74103, 1.43 secs
# ---- Epoch 147/300
# (1) Training stage (lr = 0.000039) ...
# loss 0.30340, nli_loss 0.30340, nli_acc 0.88401, 43.35 secs
# (2) Validation stage ...
# nli_acc 0.74936, 1.44 secs
# ---- Epoch 148/300
# (1) Training stage (lr = 0.000025) ...
# loss 0.29856, nli_loss 0.29856, nli_acc 0.88666, 43.42 secs
# (2) Validation stage ...
# nli_acc 0.73652, 1.44 secs
# ---- Epoch 149/300
# (1) Training stage (lr = 0.000017) ...
# loss 0.29442, nli_loss 0.29442, nli_acc 0.88883, 43.26 secs
# (2) Validation stage ...
# nli_acc 0.73990, 1.43 secs
# ---- Epoch 150/300
# (1) Training stage (lr = 0.000011) ...
# loss 0.29156, nli_loss 0.29156, nli_acc 0.89023, 43.47 secs
# (2) Validation stage ...
# nli_acc 0.74499, 1.43 secs
# ---- Epoch 151/300
# (1) Training stage (lr = 0.000007) ...
# loss 0.29227, nli_loss 0.29227, nli_acc 0.88991, 43.43 secs
# (2) Validation stage ...
# nli_acc 0.74513, 1.43 secs
# ---- Epoch 152/300
# (1) Training stage (lr = 0.000005) ...
# loss 0.28838, nli_loss 0.28838, nli_acc 0.89124, 43.54 secs
# (2) Validation stage ...
# nli_acc 0.74174, 1.42 secs
# ---- Epoch 153/300
# (1) Training stage (lr = 0.000003) ...
# loss 0.28924, nli_loss 0.28924, nli_acc 0.89127, 43.32 secs
# (2) Validation stage ...
# nli_acc 0.74160, 1.45 secs
# ---- Epoch 154/300
# (1) Training stage (lr = 0.000002) ...
# loss 0.28842, nli_loss 0.28842, nli_acc 0.89156, 43.39 secs
# (2) Validation stage ...
# nli_acc 0.74259, 1.42 secs
# ---- Epoch 155/300
# (1) Training stage (lr = 0.000090) ...
# loss 0.32061, nli_loss 0.32061, nli_acc 0.87380, 43.34 secs
# (2) Validation stage ...
# nli_acc 0.74682, 1.42 secs
# ---- Epoch 156/300
# (1) Training stage (lr = 0.000059) ...
# loss 0.30747, nli_loss 0.30747, nli_acc 0.88181, 43.19 secs
# (2) Validation stage ...
# nli_acc 0.71491, 1.42 secs
# ---- Epoch 157/300
# (1) Training stage (lr = 0.000039) ...
# loss 0.29781, nli_loss 0.29781, nli_acc 0.88610, 43.27 secs
# (2) Validation stage ...
# nli_acc 0.73567, 1.44 secs
# ---- Epoch 158/300
# (1) Training stage (lr = 0.000025) ...
# loss 0.29348, nli_loss 0.29348, nli_acc 0.88848, 43.30 secs
# (2) Validation stage ...
# nli_acc 0.75007, 1.42 secs
# ---- Epoch 159/300
# (1) Training stage (lr = 0.000017) ...
# loss 0.28986, nli_loss 0.28986, nli_acc 0.89021, 43.50 secs
# (2) Validation stage ...
# nli_acc 0.74725, 1.42 secs
# ---- Epoch 160/300
# (1) Training stage (lr = 0.000011) ...
# loss 0.28612, nli_loss 0.28612, nli_acc 0.89197, 43.34 secs
# (2) Validation stage ...
# nli_acc 0.73722, 1.41 secs
# ---- Epoch 161/300
# (1) Training stage (lr = 0.000007) ...
# loss 0.28619, nli_loss 0.28619, nli_acc 0.89227, 43.60 secs
# (2) Validation stage ...
# nli_acc 0.73920, 1.45 secs
# ---- Epoch 162/300
# (1) Training stage (lr = 0.000005) ...
# loss 0.28389, nli_loss 0.28389, nli_acc 0.89317, 43.34 secs
# (2) Validation stage ...
# nli_acc 0.74216, 1.42 secs
# ---- Epoch 163/300
# (1) Training stage (lr = 0.000003) ...
# loss 0.28375, nli_loss 0.28375, nli_acc 0.89331, 43.31 secs
# (2) Validation stage ...
# nli_acc 0.73934, 1.43 secs
# ---- Epoch 164/300
# (1) Training stage (lr = 0.000002) ...
# loss 0.28284, nli_loss 0.28284, nli_acc 0.89339, 43.34 secs
# (2) Validation stage ...
# nli_acc 0.74569, 1.42 secs
# ---- Epoch 165/300
# (1) Training stage (lr = 0.000090) ...
# loss 0.31515, nli_loss 0.31515, nli_acc 0.87668, 43.45 secs
# (2) Validation stage ...
# nli_acc 0.73779, 1.42 secs
# ---- Epoch 166/300
# (1) Training stage (lr = 0.000059) ...
# ^C iteration 82525
# Engine run is terminating due to exception:
# Traceback (most recent call last):
#   File "/home/pamessina/medvqa/medvqa/notebooks/../train_fact_embedding_NLI.py", line 417, in <module>
#     train_from_scratch(**args)
#   File "/home/pamessina/medvqa/medvqa/notebooks/../train_fact_embedding_NLI.py", line 326, in train_from_scratch
#     return train_model(
#   File "/home/pamessina/medvqa/medvqa/notebooks/../train_fact_embedding_NLI.py", line 178, in train_model
#     run_common_boilerplate_code_and_start_training(
#   File "/home/pamessina/medvqa/medvqa/training/utils.py", line 135, in run_common_boilerplate_code_and_start_training
#     trainer_engine.run(train_dataloader, max_epochs=epochs, epoch_length=batches_per_epoch)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 892, in run
#     return self._internal_run()
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 935, in _internal_run
#     return next(self._internal_run_generator)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 993, in _internal_run_as_gen
#     self._handle_exception(e)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 638, in _handle_exception
#     raise e
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 959, in _internal_run_as_gen
#     epoch_time_taken += yield from self._run_once_on_dataset_as_gen()
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 1032, in _run_once_on_dataset_as_gen
#     self.state.batch = next(self._dataloader_iter)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 631, in __next__
#     data = self._next_data()
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1329, in _next_data
#     idx, data = self._get_data()
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1285, in _get_data
#     success, data = self._try_get_data()
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1133, in _try_get_data
#     data = self._data_queue.get(timeout=timeout)
#   File "/usr/lib/python3.10/queue.py", line 180, in get
#     self.not_empty.wait(remaining)
#   File "/usr/lib/python3.10/threading.py", line 324, in wait
#     gotit = waiter.acquire(True, timeout)
# KeyboardInterrupt
