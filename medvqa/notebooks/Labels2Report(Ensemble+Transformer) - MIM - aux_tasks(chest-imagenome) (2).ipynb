# %%
# %env CUDA_VISIBLE_DEVICES=0
# Out:
# env: CUDA_VISIBLE_DEVICES=0

# %%
# !/home/pamessina/venv2/bin/python ../train_labels2report.py \
    --generation-mode "ensemble2report" \
    --ensemble-model-checkpoint-folder-paths \
        "/mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230412_162837_mim_yolov8l/" \
        "/mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230324_093504_mim_dn121/" \
        "/mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230412_174336_mim_yolov8l/" \
        "/mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230412_215924_mim_yolov8x/" \
    --ensemble-batch-size 160 \
    --ensemble-num-workers 3 \
    --epochs 120 \
    --batches-per-epoch 300 \
    --batch-size 200 \
    --num-workers 3 \
    --iters-to-accumulate 2 \
    --optimizer-name "adamw" \
    --scheduler "exp-warmup+decay+cyclicdecay" \
    --lr 1e-6 \
    --warmup-decay-and-cyclic-decay-args "1e-6,6,4e-4,8,3e-6,4e-4,8,3e-6" \
    --use-mimiccxr \
    --mimiccxr-weight 1.0 \
    --mimiccxr-view-mode "chest_imagenome" \
    --mimiccxr-balanced-sampling-mode "balanced_chest_imagenome_global_labels_batchwise" \
    --mimiccxr-qa-adapted-reports-filename "qa_adapted_reports__20220904_095810.json" \
    --use-chest-imagenome \
    --use-chest-imagenome-decent-images-only \
    --chest-imagenome-label-names-filename "labels(min_freq=1000).pkl" \
    --chest-imagenome-labels-filename "imageId2labels(min_freq=1000).pkl" \
    --use-medical-tokenization \
    --medical-terms-frequency-filename "medical_terms_frequency__20220918_184255.pkl" \
    --binary-loss-name "focal+bce+wbce-c" \
    --labels-hidden-dim 1024 \
    --embedding-dim 512 \
    --transf-dec-num-memory-vecs 10 \
    --transf-dec-hidden-dim 512 \
    --transf-dec-nhead 4 \
    --transf-dec-dim-forward 512 \
    --transf-dec-num-layers 3 \
    --use-amp \
    --save
# Out:
# script's arguments:
#    epochs: 120
#    batches_per_epoch: 300
#    batch_size: 200
#    checkpoint_folder: None
#    generation_mode: ensemble2report
#    ensemble_model_checkpoint_folder_paths: ['/mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230412_162837_mim_yolov8l/', '/mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230324_093504_mim_dn121/', '/mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230412_174336_mim_yolov8l/', '/mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230412_215924_mim_yolov8x/']
#    ensemble_batch_size: 160
#    ensemble_num_workers: 3
#    pretrained_checkpoint_folder_path: None
#    labels_hidden_dim: 1024
#    embedding_dim: 512
#    transf_dec_num_memory_vecs: 10
#    transf_dec_hidden_dim: 512
#    transf_dec_nhead: 4
#    transf_dec_dim_forward: 512
#    transf_dec_num_layers: 3
#    dropout_prob: 0
#    vocab_min_freq: 10
#    use_medical_tokenization: True
#    medical_terms_frequency_filename: medical_terms_frequency__20220918_184255.pkl
#    optimizer_name: adamw
#    lr: 1e-06
#    scheduler: exp-warmup+decay+cyclicdecay
#    lr_decay: 0.76
#    lr_decay_patience: 2
#    warmup_and_decay_args: None
#    warmup_and_cosine_args: None
#    warmup_decay_and_cyclic_decay_args: 1e-6,6,4e-4,8,3e-6,4e-4,8,3e-6
#    iters_to_accumulate: 2
#    override_lr: False
#    binary_loss_name: focal+bce+wbce-c
#    focal_loss_weight: 1
#    bce_loss_weight: 1
#    wbce_loss_weight: 1
#    num_workers: 3
#    device: GPU
#    use_amp: True
#    train_mimiccxr: True
#    mimiccxr_weight: 1.0
#    mimiccxr_view_mode: chest_imagenome
#    mimiccxr_balanced_sampling_mode: balanced_chest_imagenome_global_labels_batchwise
#    mimiccxr_qa_adapted_reports_filename: qa_adapted_reports__20220904_095810.json
#    chest_imagenome_labels_filename: imageId2labels(min_freq=1000).pkl
#    chest_imagenome_label_names_filename: labels(min_freq=1000).pkl
#    use_chest_imagenome_decent_images_only: True
#    save: True
#    use_gender: False
#    use_chexpert: False
#    mimiccxr_chexpert_labels_filename: None
#    use_chest_imagenome: True
#    debug: False
# ----- Training model from scratch ------
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230412_162837_mim_yolov8l/metadata.json
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230324_093504_mim_dn121/metadata.json
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230412_174336_mim_yolov8l/metadata.json
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230412_215924_mim_yolov8x/metadata.json
# chest_imagenome_range: (0, 379)
# Precomputing sigmoid activations for ensemble ...
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230412_162837_mim_yolov8l/metadata.json
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230324_093504_mim_dn121/metadata.json
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230412_174336_mim_yolov8l/metadata.json
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230412_215924_mim_yolov8x/metadata.json
# ============================================================
# Model 1/4
# Processing model_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230412_162837_mim_yolov8l/
# checkpoint_names = ['checkpoint_40_chestimgbbmf1+chestimglauc+chestimglprcauc=0.7240.pt']
# model_checkpoint_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230412_162837_mim_yolov8l/checkpoint_40_chestimgbbmf1+chestimglauc+chestimglprcauc=0.7240.pt
# precomputed_chest_imagenome_sigmoids_path = /mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/precomputed_chest_imagenome_sigmoids(hash=284,2262195537685126541).pkl
# Precomputed sigmoids for Chest ImaGenome already exist.
# File size = 225.06 MB
# Skipping...
# ============================================================
# Model 2/4
# Processing model_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230324_093504_mim_dn121/
# checkpoint_names = ['checkpoint_44_chf1+chuc+chf1+chf1=0.5737.pt']
# model_checkpoint_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230324_093504_mim_dn121/checkpoint_44_chf1+chuc+chf1+chf1=0.5737.pt
# precomputed_chest_imagenome_sigmoids_path = /mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/precomputed_chest_imagenome_sigmoids(hash=259,3647660934550945948).pkl
# Precomputed sigmoids for Chest ImaGenome already exist.
# File size = 225.06 MB
# Skipping...
# ============================================================
# Model 3/4
# Processing model_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230412_174336_mim_yolov8l/
# checkpoint_names = ['checkpoint_40_chestimgbbmf1+chestimglauc+chestimglprcauc=0.7159.pt']
# model_checkpoint_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230412_174336_mim_yolov8l/checkpoint_40_chestimgbbmf1+chestimglauc+chestimglprcauc=0.7159.pt
# precomputed_chest_imagenome_sigmoids_path = /mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/precomputed_chest_imagenome_sigmoids(hash=284,1207809100160540199).pkl
# Precomputed sigmoids for Chest ImaGenome already exist.
# File size = 225.06 MB
# Skipping...
# ============================================================
# Model 4/4
# Processing model_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230412_215924_mim_yolov8x/
# checkpoint_names = ['checkpoint_100_chestimgbbmf1+chestimglauc+chestimglprcauc=0.7251.pt']
# model_checkpoint_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230412_215924_mim_yolov8x/checkpoint_100_chestimgbbmf1+chestimglauc+chestimglprcauc=0.7251.pt
# precomputed_chest_imagenome_sigmoids_path = /mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/precomputed_chest_imagenome_sigmoids(hash=285,1936848358687884602).pkl
# Precomputed sigmoids for Chest ImaGenome already exist.
# File size = 225.06 MB
# Skipping...
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Initializing tokenizer ...
# Loading /mnt/data/pamessina/workspaces/medvqa-workspace/cache/vocab(min_freq=10;mode=report;qa_adapted_reports__20220904_095810.json).pkl ...
# --------------------------------------------------
# 3) Creating instance of Labels2ReportModel ...
# Labels2ReportModel
#   vocab_size: 4833
#   embedding_dim: 512
#   num_input_labels: 1516
#   labels_hidden_dim: 1024
#   num_output_labels: 379
#   transf_dec_num_memory_vecs: 10
#   transf_dec_hidden_dim: 512
#   transf_dec_nhead: 4
#   transf_dec_dim_forward: 512
#   transf_dec_num_layers: 3
#   start_idx: 1
#   dropout_prob: 0
# --------------------------------------------------
# 4) Defining optimizer ...
# create_optimizer(): name = adamw
# --------------------------------------------------
# 5) Defining scheduler ...
# Using exp-warmup+decay+cyclicdecay scheduler: 1e-6,6,4e-4,8,3e-6,4e-4,8,3e-6
# 1e-06 6 0.0004 8 3e-06 0.0004 8 3e-06
# self.steps_to_restart = 8
# self.steps = -1
# self.initial_lr = 0.0004
# --------------------------------------------------
# 6) Creating trainer and validator engines ...
# Using focal+bce+wbce-c loss
# binary_loss_kwargs: {'focal_weight': 1, 'bce_weight': 1, 'wbce_weight': 1}
# Focal_BCE_WBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 wbce_weight = 0.3333333333333333
# --------------------------------------------------
# 7) Defining collate_batch_fn ...
# --------------------------------------------------
# 8) Creating MIMIC-CXR_Labels2ReportTrainer ...
# 227835it [00:23, 9554.12it/s]
# max_idx_count = 377110
# actual_idx_count = 239513
# ** NOTE: 137597 images were skipped because they were not in the allowed DICOM IDs
# Random report:
# <s> lung volumes decreased . crowding vascular bronchial structures lung base . mild areas atelectasis , atelectasis more severe left right . borderline size cardiac silhouette no pulmonary edema . blunting left costophrenic sinus , pleural effusion </s>
# len(self.train_indices) = 234217
# len(self.val_indices) = 1934
# Loading Chest Imagenome labels...
# Loading precomputed sigmoid paths for ensemble predictions...
#   Loading /mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/precomputed_chest_imagenome_sigmoids(hash=284,2262195537685126541).pkl
#     _probs.shape = (242280, 379)
#     len(_dids) = 242280
#   Loading /mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/precomputed_chest_imagenome_sigmoids(hash=259,3647660934550945948).pkl
#     _probs.shape = (242280, 379)
#     len(_dids) = 242280
#   Loading /mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/precomputed_chest_imagenome_sigmoids(hash=284,1207809100160540199).pkl
#     _probs.shape = (242280, 379)
#     len(_dids) = 242280
#   Loading /mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/precomputed_chest_imagenome_sigmoids(hash=285,1936848358687884602).pkl
#     _probs.shape = (242280, 379)
#     len(_dids) = 242280
# Done loading precomputed sigmoid paths for ensemble predictions
# Balanced sampling mode: balanced_chest_imagenome_global_labels_batchwise
# Regrouping indices by Chest Imagenome labels for balanced sampling...
# 379it [01:02,  6.05it/s]
# Global: airspace opacity                        , # images: 8595 (other: 225622)
# Global: atelectasis                             , # images: 79106 (other: 155111)
# Global: bone lesion                             , # images: 1485 (other: 232732)
# Global: bronchiectasis                          , # images: 796 (other: 233421)
# Global: calcified nodule                        , # images: 2708 (other: 231509)
# Global: consolidation                           , # images: 17769 (other: 216448)
# Global: costophrenic angle blunting             , # images: 5723 (other: 228494)
# Global: elevated hemidiaphragm                  , # images: 6412 (other: 227805)
# Global: enlarged cardiac silhouette             , # images: 57654 (other: 176563)
# Global: enlarged hilum                          , # images: 8983 (other: 225234)
# Global: hernia                                  , # images: 3025 (other: 231192)
# Global: hyperaeration                           , # images: 10306 (other: 223911)
# Global: increased reticular markings/ild pattern, # images: 1373 (other: 232844)
# Global: infiltration                            , # images: 2977 (other: 231240)
# Global: linear/patchy atelectasis               , # images: 12797 (other: 221420)
# Global: lobar/segmental collapse                , # images: 9531 (other: 224686)
# Global: lung lesion                             , # images: 13455 (other: 220762)
# Global: lung opacity                            , # images: 154881 (other: 79336)
# Global: mass/nodule (not otherwise specified)   , # images: 7782 (other: 226435)
# Global: mediastinal displacement                , # images: 3438 (other: 230779)
# Global: mediastinal widening                    , # images: 5070 (other: 229147)
# Global: multiple masses/nodules                 , # images: 3730 (other: 230487)
# Global: pleural effusion                        , # images: 72076 (other: 162141)
# Global: pleural/parenchymal scarring            , # images: 14199 (other: 220018)
# Global: pneumomediastinum                       , # images: 864 (other: 233353)
# Global: pneumothorax                            , # images: 10640 (other: 223577)
# Global: pulmonary edema/hazy opacity            , # images: 35280 (other: 198937)
# Global: rib fracture                            , # images: 7080 (other: 227137)
# Global: scoliosis                               , # images: 3201 (other: 231016)
# Global: shoulder osteoarthritis                 , # images: 2178 (other: 232039)
# Global: spinal degenerative changes             , # images: 6810 (other: 227407)
# Global: spinal fracture                         , # images: 3101 (other: 231116)
# Global: sub-diaphragmatic air                   , # images: 1234 (other: 232983)
# Global: subcutaneous air                        , # images: 3377 (other: 230840)
# Global: superior mediastinal mass/enlargement   , # images: 3295 (other: 230922)
# Global: tortuous aorta                          , # images: 13462 (other: 220755)
# Global: vascular calcification                  , # images: 10172 (other: 224045)
# Global: vascular congestion                     , # images: 24614 (other: 209603)
# Global: vascular redistribution                 , # images: 3199 (other: 231018)
# Global: cabg grafts                             , # images: 3839 (other: 230378)
# Global: cardiac pacer and wires                 , # images: 12453 (other: 221764)
# Global: prosthetic valve                        , # images: 2891 (other: 231326)
# Global: alveolar hemorrhage                     , # images: 1766 (other: 232451)
# Global: aspiration                              , # images: 8915 (other: 225302)
# Global: copd/emphysema                          , # images: 6553 (other: 227664)
# Global: fluid overload/heart failure            , # images: 6458 (other: 227759)
# Global: granulomatous disease                   , # images: 2423 (other: 231794)
# Global: interstitial lung disease               , # images: 1943 (other: 232274)
# Global: lung cancer                             , # images: 1752 (other: 232465)
# Global: pericardial effusion                    , # images: 1400 (other: 232817)
# Global: pneumonia                               , # images: 34201 (other: 200016)
# Global: abnormal                                , # images: 184487 (other: 49730)
# Global: breast/nipple shadows                   , # images: 1020 (other: 233197)
# Global: low lung volumes                        , # images: 28214 (other: 206003)
# Global: rotated                                 , # images: 2036 (other: 232181)
# Global: chest port                              , # images: 7247 (other: 226970)
# Global: chest tube                              , # images: 10271 (other: 223946)
# Global: endotracheal tube                       , # images: 22541 (other: 211676)
# Global: enteric tube                            , # images: 27915 (other: 206302)
# Global: ij line                                 , # images: 12109 (other: 222108)
# Global: picc                                    , # images: 14281 (other: 219936)
# Global: pigtail catheter                        , # images: 3538 (other: 230679)
# Global: subclavian line                         , # images: 3883 (other: 230334)
# Global: swan-ganz catheter                      , # images: 2197 (other: 232020)
# Global: tracheostomy tube                       , # images: 4756 (other: 229461)
# --------------------------------------------------
# 9) Creating dataloaders ...
# len(_train_dataloaders) = 1
# len(_val_dataloaders) = 1
# _train_weights = [1.0]
# merged_dataset_name = mim
# --------------------------------------------------
# 10) Attaching metrics, losses, timer and events to engines ...
# --------------------------------------------------
# 11) Defining learning rate scheduler handler ...
# --------------------------------------------------
# 12) Defining checkpoint folder path ...
# checkpoint_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/report_gen/20230426_145201_mim_Labels2ReportModel(10,1516->1024->379,TransfReportDec(es=512,hs=512,nl=3))
# metadata saved to /mnt/data/pamessina/workspaces/medvqa-workspace/models/report_gen/20230426_145201_mim_Labels2ReportModel(10,1516->1024->379,TransfReportDec(es=512,hs=512,nl=3))/metadata.json
# --------------------------------------------------
# 13) Defining log_metrics_handler ...
# MetricsLogger :: we'll be logging to /mnt/data/pamessina/workspaces/medvqa-workspace/models/report_gen/20230426_145201_mim_Labels2ReportModel(10,1516->1024->379,TransfReportDec(es=512,hs=512,nl=3))/metrics_logs.csv
# --------------------------------------------------
# 14) Running trainer engine ...
# ---- Epoch 1/120
# (1) Training stage (lr = 0.000001) ...
# loss 10.64282, wmdcmp 0.00425, report_loss 8.32660, chestimglprcaucmic 0.07542, chestimglprcaucmac 0.07830, chestimgl_loss 2.03848, 193.45 secs
# (2) Validation stage ...
# wmdcmp 0.00212, cD 0.00000, chestimglaucmic 0.48877, chestimglaucmac 0.48140, chestimglprcaucmic 0.06494, chestimglprcaucmac 0.06051, 29.75 secs
# ---- Epoch 2/120
# (1) Training stage (lr = 0.000003) ...
# loss 10.08851, wmdcmp 0.00050, report_loss 7.41710, chestimglprcaucmic 0.12116, chestimglprcaucmac 0.07246, chestimgl_loss 2.01189, 176.37 secs
# (2) Validation stage ...
# wmdcmp 0.00052, cD 0.00042, chestimglaucmic 0.55830, chestimglaucmac 0.42816, chestimglprcaucmic 0.17401, chestimglprcaucmac 0.05207, 22.51 secs
# ---- Epoch 3/120
# (1) Training stage (lr = 0.000007) ...
# loss 8.95941, wmdcmp 0.00350, report_loss 6.23117, chestimglprcaucmic 0.23326, chestimglprcaucmac 0.06407, chestimgl_loss 1.90058, 172.37 secs
# (2) Validation stage ...
# wmdcmp 0.01082, cD 0.00097, chestimglaucmic 0.62601, chestimglaucmac 0.39473, chestimglprcaucmic 0.22726, chestimglprcaucmac 0.04598, 23.82 secs
# ---- Epoch 4/120
# (1) Training stage (lr = 0.000020) ...
# loss 7.63359, wmdcmp 0.02817, report_loss 5.08549, chestimglprcaucmic 0.31619, chestimglprcaucmac 0.06265, chestimgl_loss 2.04717, 176.30 secs
# (2) Validation stage ...
# wmdcmp 0.01446, cD 0.00017, chestimglaucmic 0.79193, chestimglaucmac 0.45266, chestimglprcaucmic 0.35010, chestimglprcaucmac 0.06292, 24.56 secs
# ---- Epoch 5/120
# (1) Training stage (lr = 0.000054) ...
# loss 6.54521, wmdcmp 0.08189, report_loss 4.07937, chestimglprcaucmic 0.49657, chestimglprcaucmac 0.12945, chestimgl_loss 1.86666, 163.32 secs
# (2) Validation stage ...
# wmdcmp 0.03192, cD 0.02204, chestimglaucmic 0.85983, chestimglaucmac 0.61980, chestimglprcaucmic 0.48600, chestimglprcaucmac 0.11020, 22.73 secs
# ---- Epoch 6/120
# (1) Training stage (lr = 0.000147) ...
# loss 5.53703, wmdcmp 0.13626, report_loss 3.26844, chestimglprcaucmic 0.63714, chestimglprcaucmac 0.27268, chestimgl_loss 1.56489, 161.56 secs
# (2) Validation stage ...
# wmdcmp 0.10234, cD 0.22539, chestimglaucmic 0.89907, chestimglaucmac 0.73600, chestimglprcaucmic 0.54966, chestimglprcaucmac 0.16818, 22.62 secs
# ---- Epoch 7/120
# (1) Training stage (lr = 0.000400) ...
# loss 4.50473, wmdcmp 0.17982, report_loss 2.72487, chestimglprcaucmic 0.69678, chestimglprcaucmac 0.36867, chestimgl_loss 1.36373, 151.37 secs
# (2) Validation stage ...
# wmdcmp 0.08835, cD 0.20612, chestimglaucmic 0.90903, chestimglaucmac 0.77528, chestimglprcaucmic 0.55575, chestimglprcaucmac 0.19067, 23.59 secs
# ---- Epoch 8/120
# (1) Training stage (lr = 0.000217) ...
# loss 4.07439, wmdcmp 0.20706, report_loss 2.47109, chestimglprcaucmic 0.72909, chestimglprcaucmac 0.42906, chestimgl_loss 1.26486, 143.08 secs
# (2) Validation stage ...
# wmdcmp 0.11883, cD 0.30351, chestimglaucmic 0.91228, chestimglaucmac 0.78110, chestimglprcaucmic 0.55900, chestimglprcaucmac 0.19439, 24.62 secs
# ---- Epoch 9/120
# (1) Training stage (lr = 0.000118) ...
# loss 3.69086, wmdcmp 0.21600, report_loss 2.38904, chestimglprcaucmic 0.73535, chestimglprcaucmac 0.44702, chestimgl_loss 1.23700, 140.45 secs
# (2) Validation stage ...
# wmdcmp 0.10765, cD 0.27749, chestimglaucmic 0.91367, chestimglaucmac 0.78342, chestimglprcaucmic 0.55971, chestimglprcaucmac 0.19616, 23.03 secs
# ---- Epoch 10/120
# (1) Training stage (lr = 0.000064) ...
# loss 3.15826, wmdcmp 0.22155, report_loss 2.33898, chestimglprcaucmic 0.74184, chestimglprcaucmac 0.45590, chestimgl_loss 1.22529, 138.78 secs
# (2) Validation stage ...
# wmdcmp 0.12104, cD 0.31774, chestimglaucmic 0.91311, chestimglaucmac 0.78381, chestimglprcaucmic 0.55890, chestimglprcaucmac 0.19695, 25.57 secs
# ---- Epoch 11/120
# (1) Training stage (lr = 0.000035) ...
# loss 3.44487, wmdcmp 0.22440, report_loss 2.32142, chestimglprcaucmic 0.74321, chestimglprcaucmac 0.46309, chestimgl_loss 1.21213, 138.87 secs
# (2) Validation stage ...
# wmdcmp 0.12302, cD 0.32715, chestimglaucmic 0.91386, chestimglaucmac 0.78451, chestimglprcaucmic 0.55955, chestimglprcaucmac 0.19743, 24.00 secs
# ---- Epoch 12/120
# (1) Training stage (lr = 0.000019) ...
# loss 3.66985, wmdcmp 0.22683, report_loss 2.30629, chestimglprcaucmic 0.74324, chestimglprcaucmac 0.46335, chestimgl_loss 1.21467, 140.37 secs
# (2) Validation stage ...
# wmdcmp 0.12410, cD 0.32559, chestimglaucmic 0.91360, chestimglaucmac 0.78440, chestimglprcaucmic 0.55916, chestimglprcaucmac 0.19746, 23.56 secs
# ---- Epoch 13/120
# (1) Training stage (lr = 0.000010) ...
# loss 3.70368, wmdcmp 0.22616, report_loss 2.30638, chestimglprcaucmic 0.74498, chestimglprcaucmac 0.46607, chestimgl_loss 1.21277, 139.87 secs
# (2) Validation stage ...
# wmdcmp 0.12038, cD 0.32246, chestimglaucmic 0.91385, chestimglaucmac 0.78463, chestimglprcaucmic 0.55926, chestimglprcaucmac 0.19754, 23.89 secs
# ---- Epoch 14/120
# (1) Training stage (lr = 0.000006) ...
# loss 3.47159, wmdcmp 0.22669, report_loss 2.30154, chestimglprcaucmic 0.74588, chestimglprcaucmac 0.46729, chestimgl_loss 1.21025, 138.66 secs
# (2) Validation stage ...
# wmdcmp 0.12129, cD 0.31465, chestimglaucmic 0.91387, chestimglaucmac 0.78476, chestimglprcaucmic 0.55935, chestimglprcaucmac 0.19765, 23.97 secs
# ---- Epoch 15/120
# (1) Training stage (lr = 0.000003) ...
# loss 3.45173, wmdcmp 0.22640, report_loss 2.30208, chestimglprcaucmic 0.74630, chestimglprcaucmac 0.46635, chestimgl_loss 1.21219, 137.37 secs
# (2) Validation stage ...
# wmdcmp 0.12245, cD 0.32055, chestimglaucmic 0.91380, chestimglaucmac 0.78481, chestimglprcaucmic 0.55914, chestimglprcaucmac 0.19757, 24.40 secs
# ---- Epoch 16/120
# (1) Training stage (lr = 0.000400) ...
# loss 3.58557, wmdcmp 0.22604, report_loss 2.30082, chestimglprcaucmic 0.73955, chestimglprcaucmac 0.45809, chestimgl_loss 1.20327, 137.37 secs
# (2) Validation stage ...
# wmdcmp 0.12025, cD 0.33028, chestimglaucmic 0.91444, chestimglaucmac 0.78827, chestimglprcaucmic 0.56106, chestimglprcaucmac 0.20045, 24.97 secs
# ---- Epoch 17/120
# (1) Training stage (lr = 0.000199) ...
# loss 3.35154, wmdcmp 0.23847, report_loss 2.20239, chestimglprcaucmic 0.75082, chestimglprcaucmac 0.47908, chestimgl_loss 1.17627, 138.46 secs
# (2) Validation stage ...
# wmdcmp 0.12117, cD 0.33260, chestimglaucmic 0.91541, chestimglaucmac 0.79096, chestimglprcaucmic 0.55809, chestimglprcaucmac 0.20219, 26.67 secs
# ---- Epoch 18/120
# (1) Training stage (lr = 0.000099) ...
# loss 2.85245, wmdcmp 0.24527, report_loss 2.15865, chestimglprcaucmic 0.75504, chestimglprcaucmac 0.48897, chestimgl_loss 1.16310, 137.51 secs
# (2) Validation stage ...
# wmdcmp 0.13108, cD 0.36205, chestimglaucmic 0.91474, chestimglaucmac 0.79048, chestimglprcaucmic 0.55664, chestimglprcaucmac 0.20183, 23.45 secs
# ---- Epoch 19/120
# (1) Training stage (lr = 0.000049) ...
# loss 3.48214, wmdcmp 0.24927, report_loss 2.13491, chestimglprcaucmic 0.75713, chestimglprcaucmac 0.49330, chestimgl_loss 1.15473, 139.87 secs
# (2) Validation stage ...
# wmdcmp 0.12823, cD 0.36742, chestimglaucmic 0.91558, chestimglaucmac 0.79123, chestimglprcaucmic 0.55849, chestimglprcaucmac 0.20269, 23.19 secs
# ---- Epoch 20/120
# (1) Training stage (lr = 0.000024) ...
# loss 3.38675, wmdcmp 0.24947, report_loss 2.12752, chestimglprcaucmic 0.75755, chestimglprcaucmac 0.49514, chestimgl_loss 1.15438, 135.09 secs
# (2) Validation stage ...
# wmdcmp 0.13300, cD 0.39573, chestimglaucmic 0.91522, chestimglaucmac 0.79113, chestimglprcaucmic 0.55732, chestimglprcaucmac 0.20227, 22.88 secs
# ---- Epoch 21/120
# (1) Training stage (lr = 0.000012) ...
# loss 3.26976, wmdcmp 0.25074, report_loss 2.11949, chestimglprcaucmic 0.75925, chestimglprcaucmac 0.49909, chestimgl_loss 1.14852, 136.54 secs
# (2) Validation stage ...
# wmdcmp 0.12596, cD 0.36938, chestimglaucmic 0.91546, chestimglaucmac 0.79122, chestimglprcaucmic 0.55754, chestimglprcaucmac 0.20254, 23.20 secs
# ---- Epoch 22/120
# (1) Training stage (lr = 0.000006) ...
# loss 3.39627, wmdcmp 0.25063, report_loss 2.11681, chestimglprcaucmic 0.75988, chestimglprcaucmac 0.49906, chestimgl_loss 1.15109, 137.66 secs
# (2) Validation stage ...
# wmdcmp 0.13003, cD 0.38929, chestimglaucmic 0.91554, chestimglaucmac 0.79129, chestimglprcaucmic 0.55802, chestimglprcaucmac 0.20249, 23.57 secs
# ---- Epoch 23/120
# (1) Training stage (lr = 0.000003) ...
# loss 3.02436, wmdcmp 0.25194, report_loss 2.11312, chestimglprcaucmic 0.75949, chestimglprcaucmac 0.49838, chestimgl_loss 1.15077, 137.54 secs
# (2) Validation stage ...
# wmdcmp 0.12741, cD 0.37616, chestimglaucmic 0.91549, chestimglaucmac 0.79125, chestimglprcaucmic 0.55800, chestimglprcaucmac 0.20251, 23.15 secs
# ---- Epoch 24/120
# (1) Training stage (lr = 0.000400) ...
# loss 3.25327, wmdcmp 0.24580, report_loss 2.14596, chestimglprcaucmic 0.75098, chestimglprcaucmac 0.48484, chestimgl_loss 1.15541, 137.58 secs
# (2) Validation stage ...
# wmdcmp 0.13122, cD 0.37781, chestimglaucmic 0.91503, chestimglaucmac 0.79226, chestimglprcaucmic 0.55549, chestimglprcaucmac 0.20412, 25.78 secs
# ---- Epoch 25/120
# (1) Training stage (lr = 0.000199) ...
# loss 3.47654, wmdcmp 0.25711, report_loss 2.07699, chestimglprcaucmic 0.75896, chestimglprcaucmac 0.49840, chestimgl_loss 1.13773, 137.94 secs
# (2) Validation stage ...
# wmdcmp 0.13434, cD 0.39830, chestimglaucmic 0.91568, chestimglaucmac 0.79397, chestimglprcaucmic 0.55619, chestimglprcaucmac 0.20488, 24.94 secs
# ---- Epoch 26/120
# (1) Training stage (lr = 0.000099) ...
# loss 3.47307, wmdcmp 0.26136, report_loss 2.04338, chestimglprcaucmic 0.76330, chestimglprcaucmac 0.51088, chestimgl_loss 1.12239, 138.22 secs
# (2) Validation stage ...
# wmdcmp 0.12934, cD 0.40817, chestimglaucmic 0.91545, chestimglaucmac 0.79349, chestimglprcaucmic 0.55521, chestimglprcaucmac 0.20493, 22.98 secs
# ---- Epoch 27/120
# (1) Training stage (lr = 0.000049) ...
# loss 3.20701, wmdcmp 0.26397, report_loss 2.02407, chestimglprcaucmic 0.76405, chestimglprcaucmac 0.51538, chestimgl_loss 1.11749, 137.30 secs
# (2) Validation stage ...
# wmdcmp 0.13035, cD 0.38473, chestimglaucmic 0.91627, chestimglaucmac 0.79400, chestimglprcaucmic 0.55687, chestimglprcaucmac 0.20495, 23.19 secs
# ---- Epoch 28/120
# (1) Training stage (lr = 0.000024) ...
# loss 3.04126, wmdcmp 0.26568, report_loss 2.01366, chestimglprcaucmic 0.76383, chestimglprcaucmac 0.51324, chestimgl_loss 1.12075, 140.96 secs
# (2) Validation stage ...
# wmdcmp 0.12735, cD 0.38329, chestimglaucmic 0.91581, chestimglaucmac 0.79363, chestimglprcaucmic 0.55535, chestimglprcaucmac 0.20469, 24.19 secs
# ---- Epoch 29/120
# (1) Training stage (lr = 0.000012) ...
# loss 3.33136, wmdcmp 0.26657, report_loss 2.00881, chestimglprcaucmic 0.76605, chestimglprcaucmac 0.51709, chestimgl_loss 1.11594, 137.64 secs
# (2) Validation stage ...
# wmdcmp 0.12889, cD 0.38767, chestimglaucmic 0.91609, chestimglaucmac 0.79378, chestimglprcaucmic 0.55688, chestimglprcaucmac 0.20473, 23.35 secs
# ---- Epoch 30/120
# (1) Training stage (lr = 0.000006) ...
# loss 2.97185, wmdcmp 0.26598, report_loss 2.01451, chestimglprcaucmic 0.76607, chestimglprcaucmac 0.51773, chestimgl_loss 1.12223, 138.66 secs
# (2) Validation stage ...
# wmdcmp 0.12808, cD 0.38571, chestimglaucmic 0.91599, chestimglaucmac 0.79377, chestimglprcaucmic 0.55617, chestimglprcaucmac 0.20465, 23.04 secs
# ---- Epoch 31/120
# (1) Training stage (lr = 0.000003) ...
# loss 2.70244, wmdcmp 0.26709, report_loss 2.00287, chestimglprcaucmic 0.76654, chestimglprcaucmac 0.51893, chestimgl_loss 1.11360, 136.43 secs
# (2) Validation stage ...
# wmdcmp 0.12679, cD 0.39103, chestimglaucmic 0.91603, chestimglaucmac 0.79374, chestimglprcaucmic 0.55635, chestimglprcaucmac 0.20467, 25.20 secs
# ---- Epoch 32/120
# (1) Training stage (lr = 0.000400) ...
# ^C iteration 9575
# Engine run is terminating due to exception:
# Traceback (most recent call last):
#   File "/home/pamessina/medvqa/medvqa/notebooks/../train_labels2report.py", line 1019, in <module>
#     train_from_scratch(**args)
#   File "/home/pamessina/medvqa/medvqa/notebooks/../train_labels2report.py", line 911, in train_from_scratch
#     return train_model(
#   File "/home/pamessina/medvqa/medvqa/notebooks/../train_labels2report.py", line 663, in train_model
#     trainer_engine.run(train_dataloader, max_epochs=epochs, epoch_length=batches_per_epoch)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 892, in run
#     return self._internal_run()
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 935, in _internal_run
#     return next(self._internal_run_generator)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 993, in _internal_run_as_gen
#     self._handle_exception(e)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 638, in _handle_exception
#     raise e
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 959, in _internal_run_as_gen
#     epoch_time_taken += yield from self._run_once_on_dataset_as_gen()
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 1068, in _run_once_on_dataset_as_gen
#     self.state.output = self._process_function(self, self.state.batch)
#   File "/home/pamessina/medvqa/medvqa/training/report_gen.py", line 173, in step_fn
#     output = step_fn__mimiccxr(batch)
#   File "/home/pamessina/medvqa/medvqa/training/report_gen.py", line 101, in step_fn__mimiccxr
#     model_output = model(**model_kwargs)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1194, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/home/pamessina/medvqa/medvqa/models/report_generation/labels2report.py", line 158, in forward
#     if mode == 'train':
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1194, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/home/pamessina/medvqa/medvqa/models/report_generation/labels2report.py", line 88, in forward
#     return self.teacher_forcing_decoding(input_memory, reports, device)
#   File "/home/pamessina/medvqa/medvqa/models/report_generation/labels2report.py", line 55, in teacher_forcing_decoding
#     decoded = self.decoder(report_embeddings, input_memory, tgt_mask=tgt_mask)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1194, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/nn/modules/transformer.py", line 333, in forward
#     output = mod(output, memory, tgt_mask=tgt_mask,
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1194, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/nn/modules/transformer.py", line 653, in forward
#     x = self.norm3(x + self._ff_block(x))
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/nn/modules/transformer.py", line 677, in _ff_block
#     x = self.linear2(self.dropout(self.activation(self.linear1(x))))
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1194, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/nn/modules/dropout.py", line 59, in forward
#     return F.dropout(input, self.p, self.training, self.inplace)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/nn/functional.py", line 1252, in dropout
#     return _VF.dropout_(input, p, training) if inplace else _VF.dropout(input, p, training)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/_VF.py", line 26, in __getattr__
#     def __getattr__(self, attr):
# KeyboardInterrupt

# %%
# !/home/pamessina/venv2/bin/python ../train_labels2report.py \
    --generation-mode "ensemble2report" \
    --ensemble-model-checkpoint-folder-paths \
        "/mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230412_162837_mim_yolov8l/" \
        "/mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230324_093504_mim_dn121/" \
        "/mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230412_174336_mim_yolov8l/" \
    --ensemble-batch-size 160 \
    --ensemble-num-workers 3 \
    --pretrained-checkpoint-folder-path "/mnt/data/pamessina/workspaces/medvqa-workspace/models/report_gen/20230426_122947_mim_Labels2ReportModel(10,379->1024->379,TransfReportDec(es=512,hs=512,nl=3))" \
    --epochs 63 \
    --batches-per-epoch 300 \
    --batch-size 200 \
    --num-workers 3 \
    --iters-to-accumulate 2 \
    --optimizer-name "adamw" \
    --scheduler "exp-warmup+decay+cyclicdecay" \
    --lr 1e-6 \
    --warmup-decay-and-cyclic-decay-args "1e-6,6,4e-4,8,3e-6,4e-4,8,3e-6" \
    --use-mimiccxr \
    --mimiccxr-weight 1.0 \
    --mimiccxr-view-mode "chest_imagenome" \
    --mimiccxr-balanced-sampling-mode "balanced_chest_imagenome_global_labels_batchwise" \
    --mimiccxr-qa-adapted-reports-filename "qa_adapted_reports__20220904_095810.json" \
    --use-chest-imagenome \
    --use-chest-imagenome-decent-images-only \
    --chest-imagenome-label-names-filename "labels(min_freq=1000).pkl" \
    --chest-imagenome-labels-filename "imageId2labels(min_freq=1000).pkl" \
    --use-medical-tokenization \
    --medical-terms-frequency-filename "medical_terms_frequency__20220918_184255.pkl" \
    --binary-loss-name "focal+bce+wbce-c" \
    --labels-hidden-dim 1024 \
    --embedding-dim 512 \
    --transf-dec-num-memory-vecs 10 \
    --transf-dec-hidden-dim 512 \
    --transf-dec-nhead 4 \
    --transf-dec-dim-forward 512 \
    --transf-dec-num-layers 3 \
    --use-amp \
    --save
# Out:
# script's arguments:
#    epochs: 63
#    batches_per_epoch: 300
#    batch_size: 200
#    checkpoint_folder: None
#    generation_mode: ensemble2report
#    ensemble_model_checkpoint_folder_paths: ['/mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230412_162837_mim_yolov8l/', '/mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230324_093504_mim_dn121/', '/mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230412_174336_mim_yolov8l/']
#    ensemble_batch_size: 160
#    ensemble_num_workers: 3
#    pretrained_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/report_gen/20230426_122947_mim_Labels2ReportModel(10,379->1024->379,TransfReportDec(es=512,hs=512,nl=3))
#    labels_hidden_dim: 1024
#    embedding_dim: 512
#    transf_dec_num_memory_vecs: 10
#    transf_dec_hidden_dim: 512
#    transf_dec_nhead: 4
#    transf_dec_dim_forward: 512
#    transf_dec_num_layers: 3
#    dropout_prob: 0
#    vocab_min_freq: 10
#    use_medical_tokenization: True
#    medical_terms_frequency_filename: medical_terms_frequency__20220918_184255.pkl
#    optimizer_name: adamw
#    lr: 1e-06
#    scheduler: exp-warmup+decay+cyclicdecay
#    lr_decay: 0.76
#    lr_decay_patience: 2
#    warmup_and_decay_args: None
#    warmup_and_cosine_args: None
#    warmup_decay_and_cyclic_decay_args: 1e-6,6,4e-4,8,3e-6,4e-4,8,3e-6
#    iters_to_accumulate: 2
#    override_lr: False
#    binary_loss_name: focal+bce+wbce-c
#    focal_loss_weight: 1
#    bce_loss_weight: 1
#    wbce_loss_weight: 1
#    num_workers: 3
#    device: GPU
#    use_amp: True
#    train_mimiccxr: True
#    mimiccxr_weight: 1.0
#    mimiccxr_view_mode: chest_imagenome
#    mimiccxr_balanced_sampling_mode: balanced_chest_imagenome_global_labels_batchwise
#    mimiccxr_qa_adapted_reports_filename: qa_adapted_reports__20220904_095810.json
#    chest_imagenome_labels_filename: imageId2labels(min_freq=1000).pkl
#    chest_imagenome_label_names_filename: labels(min_freq=1000).pkl
#    use_chest_imagenome_decent_images_only: True
#    save: True
#    use_gender: False
#    use_chexpert: False
#    mimiccxr_chexpert_labels_filename: None
#    use_chest_imagenome: True
#    debug: False
# ----- Training model from scratch ------
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230412_162837_mim_yolov8l/metadata.json
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230324_093504_mim_dn121/metadata.json
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230412_174336_mim_yolov8l/metadata.json
# chest_imagenome_range: (0, 379)
# Precomputing sigmoid activations for ensemble ...
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230412_162837_mim_yolov8l/metadata.json
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230324_093504_mim_dn121/metadata.json
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230412_174336_mim_yolov8l/metadata.json
# ============================================================
# Model 1/3
# Processing model_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230412_162837_mim_yolov8l/
# checkpoint_names = ['checkpoint_40_chestimgbbmf1+chestimglauc+chestimglprcauc=0.7240.pt']
# model_checkpoint_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230412_162837_mim_yolov8l/checkpoint_40_chestimgbbmf1+chestimglauc+chestimglprcauc=0.7240.pt
# precomputed_chest_imagenome_sigmoids_path = /mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/precomputed_chest_imagenome_sigmoids(hash=284,2262195537685126541).pkl
# Precomputed sigmoids for Chest ImaGenome already exist.
# File size = 225.06 MB
# Skipping...
# ============================================================
# Model 2/3
# Processing model_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230324_093504_mim_dn121/
# checkpoint_names = ['checkpoint_44_chf1+chuc+chf1+chf1=0.5737.pt']
# model_checkpoint_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230324_093504_mim_dn121/checkpoint_44_chf1+chuc+chf1+chf1=0.5737.pt
# precomputed_chest_imagenome_sigmoids_path = /mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/precomputed_chest_imagenome_sigmoids(hash=259,3647660934550945948).pkl
# Precomputed sigmoids for Chest ImaGenome already exist.
# File size = 225.06 MB
# Skipping...
# ============================================================
# Model 3/3
# Processing model_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230412_174336_mim_yolov8l/
# checkpoint_names = ['checkpoint_40_chestimgbbmf1+chestimglauc+chestimglprcauc=0.7159.pt']
# model_checkpoint_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230412_174336_mim_yolov8l/checkpoint_40_chestimgbbmf1+chestimglauc+chestimglprcauc=0.7159.pt
# precomputed_chest_imagenome_sigmoids_path = /mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/precomputed_chest_imagenome_sigmoids(hash=284,1207809100160540199).pkl
# Precomputed sigmoids for Chest ImaGenome already exist.
# File size = 225.06 MB
# Skipping...
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Initializing tokenizer ...
# Loading /mnt/data/pamessina/workspaces/medvqa-workspace/cache/vocab(min_freq=10;mode=report;qa_adapted_reports__20220904_095810.json).pkl ...
# --------------------------------------------------
# 3) Creating instance of Labels2ReportModel ...
# Labels2ReportModel
#   vocab_size: 4833
#   embedding_dim: 512
#   num_input_labels: 1137
#   labels_hidden_dim: 1024
#   num_output_labels: 379
#   transf_dec_num_memory_vecs: 10
#   transf_dec_hidden_dim: 512
#   transf_dec_nhead: 4
#   transf_dec_dim_forward: 512
#   transf_dec_num_layers: 3
#   start_idx: 1
#   dropout_prob: 0
# --------------------------------------------------
# 4) Defining optimizer ...
# create_optimizer(): name = adamw
# --------------------------------------------------
# 5) Defining scheduler ...
# Using exp-warmup+decay+cyclicdecay scheduler: 1e-6,6,4e-4,8,3e-6,4e-4,8,3e-6
# 1e-06 6 0.0004 8 3e-06 0.0004 8 3e-06
# self.steps_to_restart = 8
# self.steps = -1
# self.initial_lr = 0.0004
# --------------------------------------------------
# 6) Creating trainer and validator engines ...
# Using focal+bce+wbce-c loss
# binary_loss_kwargs: {'focal_weight': 1, 'bce_weight': 1, 'wbce_weight': 1}
# Focal_BCE_WBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 wbce_weight = 0.3333333333333333
# --------------------------------------------------
# 7) Defining collate_batch_fn ...
# --------------------------------------------------
# 8) Creating MIMIC-CXR_Labels2ReportTrainer ...
# 227835it [00:15, 14761.54it/s]
# max_idx_count = 377110
# actual_idx_count = 239513
# ** NOTE: 137597 images were skipped because they were not in the allowed DICOM IDs
# Random report:
# <s> no . conjunction . heart mild enlarged . lungs expanded clear . large fluid filled gastric hiatus hernia projecting tortuous mild enlarged descending thoracic aorta . widening mediastinum thoracic inlet moderate size multinodular goiter , left lobe greater right </s>
# len(self.train_indices) = 234217
# len(self.val_indices) = 1934
# Loading Chest Imagenome labels...
# Loading precomputed sigmoid paths for ensemble predictions...
#   Loading /mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/precomputed_chest_imagenome_sigmoids(hash=284,2262195537685126541).pkl
#     _probs.shape = (242280, 379)
#     len(_dids) = 242280
#   Loading /mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/precomputed_chest_imagenome_sigmoids(hash=259,3647660934550945948).pkl
#     _probs.shape = (242280, 379)
#     len(_dids) = 242280
#   Loading /mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/precomputed_chest_imagenome_sigmoids(hash=284,1207809100160540199).pkl
#     _probs.shape = (242280, 379)
#     len(_dids) = 242280
# Done loading precomputed sigmoid paths for ensemble predictions
# Balanced sampling mode: balanced_chest_imagenome_global_labels_batchwise
# Regrouping indices by Chest Imagenome labels for balanced sampling...
# 379it [00:54,  6.96it/s]
# Global: airspace opacity                        , # images: 8595 (other: 225622)
# Global: atelectasis                             , # images: 79106 (other: 155111)
# Global: bone lesion                             , # images: 1485 (other: 232732)
# Global: bronchiectasis                          , # images: 796 (other: 233421)
# Global: calcified nodule                        , # images: 2708 (other: 231509)
# Global: consolidation                           , # images: 17769 (other: 216448)
# Global: costophrenic angle blunting             , # images: 5723 (other: 228494)
# Global: elevated hemidiaphragm                  , # images: 6412 (other: 227805)
# Global: enlarged cardiac silhouette             , # images: 57654 (other: 176563)
# Global: enlarged hilum                          , # images: 8983 (other: 225234)
# Global: hernia                                  , # images: 3025 (other: 231192)
# Global: hyperaeration                           , # images: 10306 (other: 223911)
# Global: increased reticular markings/ild pattern, # images: 1373 (other: 232844)
# Global: infiltration                            , # images: 2977 (other: 231240)
# Global: linear/patchy atelectasis               , # images: 12797 (other: 221420)
# Global: lobar/segmental collapse                , # images: 9531 (other: 224686)
# Global: lung lesion                             , # images: 13455 (other: 220762)
# Global: lung opacity                            , # images: 154881 (other: 79336)
# Global: mass/nodule (not otherwise specified)   , # images: 7782 (other: 226435)
# Global: mediastinal displacement                , # images: 3438 (other: 230779)
# Global: mediastinal widening                    , # images: 5070 (other: 229147)
# Global: multiple masses/nodules                 , # images: 3730 (other: 230487)
# Global: pleural effusion                        , # images: 72076 (other: 162141)
# Global: pleural/parenchymal scarring            , # images: 14199 (other: 220018)
# Global: pneumomediastinum                       , # images: 864 (other: 233353)
# Global: pneumothorax                            , # images: 10640 (other: 223577)
# Global: pulmonary edema/hazy opacity            , # images: 35280 (other: 198937)
# Global: rib fracture                            , # images: 7080 (other: 227137)
# Global: scoliosis                               , # images: 3201 (other: 231016)
# Global: shoulder osteoarthritis                 , # images: 2178 (other: 232039)
# Global: spinal degenerative changes             , # images: 6810 (other: 227407)
# Global: spinal fracture                         , # images: 3101 (other: 231116)
# Global: sub-diaphragmatic air                   , # images: 1234 (other: 232983)
# Global: subcutaneous air                        , # images: 3377 (other: 230840)
# Global: superior mediastinal mass/enlargement   , # images: 3295 (other: 230922)
# Global: tortuous aorta                          , # images: 13462 (other: 220755)
# Global: vascular calcification                  , # images: 10172 (other: 224045)
# Global: vascular congestion                     , # images: 24614 (other: 209603)
# Global: vascular redistribution                 , # images: 3199 (other: 231018)
# Global: cabg grafts                             , # images: 3839 (other: 230378)
# Global: cardiac pacer and wires                 , # images: 12453 (other: 221764)
# Global: prosthetic valve                        , # images: 2891 (other: 231326)
# Global: alveolar hemorrhage                     , # images: 1766 (other: 232451)
# Global: aspiration                              , # images: 8915 (other: 225302)
# Global: copd/emphysema                          , # images: 6553 (other: 227664)
# Global: fluid overload/heart failure            , # images: 6458 (other: 227759)
# Global: granulomatous disease                   , # images: 2423 (other: 231794)
# Global: interstitial lung disease               , # images: 1943 (other: 232274)
# Global: lung cancer                             , # images: 1752 (other: 232465)
# Global: pericardial effusion                    , # images: 1400 (other: 232817)
# Global: pneumonia                               , # images: 34201 (other: 200016)
# Global: abnormal                                , # images: 184487 (other: 49730)
# Global: breast/nipple shadows                   , # images: 1020 (other: 233197)
# Global: low lung volumes                        , # images: 28214 (other: 206003)
# Global: rotated                                 , # images: 2036 (other: 232181)
# Global: chest port                              , # images: 7247 (other: 226970)
# Global: chest tube                              , # images: 10271 (other: 223946)
# Global: endotracheal tube                       , # images: 22541 (other: 211676)
# Global: enteric tube                            , # images: 27915 (other: 206302)
# Global: ij line                                 , # images: 12109 (other: 222108)
# Global: picc                                    , # images: 14281 (other: 219936)
# Global: pigtail catheter                        , # images: 3538 (other: 230679)
# Global: subclavian line                         , # images: 3883 (other: 230334)
# Global: swan-ganz catheter                      , # images: 2197 (other: 232020)
# Global: tracheostomy tube                       , # images: 4756 (other: 229461)
# --------------------------------------------------
# 9) Creating dataloaders ...
# len(_train_dataloaders) = 1
# len(_val_dataloaders) = 1
# _train_weights = [1.0]
# merged_dataset_name = mim
# --------------------------------------------------
# 10) Attaching metrics, losses, timer and events to engines ...
# --------------------------------------------------
# 11) Defining learning rate scheduler handler ...
# --------------------------------------------------
# 12) Defining checkpoint folder path ...
# checkpoint_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/report_gen/20230426_162606_mim_Labels2ReportModel(10,1137->1024->379,TransfReportDec(es=512,hs=512,nl=3,nh=4,dff=512))
# metadata saved to /mnt/data/pamessina/workspaces/medvqa-workspace/models/report_gen/20230426_162606_mim_Labels2ReportModel(10,1137->1024->379,TransfReportDec(es=512,hs=512,nl=3,nh=4,dff=512))/metadata.json
# --------------------------------------------------
# 13) Loading pretrained weights ...
# checkpoint_names = ['checkpoint_118_chestimglauc+chestimglprcauc+cD+wmdcmp=0.4569.pt', 'checkpoint_74_chestimglauc+chestimglprcauc+cD+wmdcmp=0.4559.pt']
# pretrained_checkpoint_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/report_gen/20230426_122947_mim_Labels2ReportModel(10,379->1024->379,TransfReportDec(es=512,hs=512,nl=3))/checkpoint_118_chestimglauc+chestimglprcauc+cD+wmdcmp=0.4569.pt
# Skip loading parameter: input2output_labels_1.weight, required shape: torch.Size([1024, 1137]), loaded shape: torch.Size([1024, 379])
# Checkpoint successfully loaded!
# --------------------------------------------------
# 14) Defining log_metrics_handler ...
# MetricsLogger :: we'll be logging to /mnt/data/pamessina/workspaces/medvqa-workspace/models/report_gen/20230426_162606_mim_Labels2ReportModel(10,1137->1024->379,TransfReportDec(es=512,hs=512,nl=3,nh=4,dff=512))/metrics_logs.csv
# --------------------------------------------------
# 15) Running trainer engine ...
# ---- Epoch 1/63
# (1) Training stage (lr = 0.000001) ...
# loss 5.01312, wmdcmp 0.25029, report_loss 2.14701, chestimglprcaucmic 0.32285, chestimglprcaucmac 0.07166, chestimgl_loss 2.45936, 132.50 secs
# (2) Validation stage ...
# wmdcmp 0.08281, cD 0.16205, chestimglaucmic 0.76422, chestimglaucmac 0.50461, chestimglprcaucmic 0.31408, chestimglprcaucmac 0.06941, 20.68 secs
# ---- Epoch 2/63
# (1) Training stage (lr = 0.000003) ...
# loss 4.25032, wmdcmp 0.26205, report_loss 2.00601, chestimglprcaucmic 0.38983, chestimglprcaucmac 0.09800, chestimgl_loss 2.20563, 134.36 secs
# (2) Validation stage ...
# wmdcmp 0.09821, cD 0.27568, chestimglaucmic 0.83275, chestimglaucmac 0.68631, chestimglprcaucmic 0.41258, chestimglprcaucmac 0.10677, 22.85 secs
# ---- Epoch 3/63
# (1) Training stage (lr = 0.000007) ...
# loss 4.25654, wmdcmp 0.27239, report_loss 1.92992, chestimglprcaucmic 0.48908, chestimglprcaucmac 0.15767, chestimgl_loss 1.91143, 136.52 secs
# (2) Validation stage ...
# wmdcmp 0.10035, cD 0.27978, chestimglaucmic 0.89388, chestimglaucmac 0.73578, chestimglprcaucmic 0.50349, chestimglprcaucmac 0.13187, 23.13 secs
# ---- Epoch 4/63
# (1) Training stage (lr = 0.000020) ...
# loss 3.68405, wmdcmp 0.28009, report_loss 1.87716, chestimglprcaucmic 0.56011, chestimglprcaucmac 0.21489, chestimgl_loss 1.75877, 135.41 secs
# (2) Validation stage ...
# wmdcmp 0.12411, cD 0.37243, chestimglaucmic 0.91334, chestimglaucmac 0.76448, chestimglprcaucmic 0.54931, chestimglprcaucmac 0.15554, 24.62 secs
# ---- Epoch 5/63
# (1) Training stage (lr = 0.000054) ...
# loss 3.16432, wmdcmp 0.28634, report_loss 1.83594, chestimglprcaucmic 0.61289, chestimglprcaucmac 0.25943, chestimgl_loss 1.63164, 138.14 secs
# (2) Validation stage ...
# wmdcmp 0.12928, cD 0.37730, chestimglaucmic 0.91946, chestimglaucmac 0.78068, chestimglprcaucmic 0.57545, chestimglprcaucmac 0.17867, 23.44 secs
# ---- Epoch 6/63
# (1) Training stage (lr = 0.000147) ...
# loss 3.63193, wmdcmp 0.28915, report_loss 1.82592, chestimglprcaucmic 0.64184, chestimglprcaucmac 0.29667, chestimgl_loss 1.53075, 140.94 secs
# (2) Validation stage ...
# wmdcmp 0.13277, cD 0.40913, chestimglaucmic 0.92107, chestimglaucmac 0.79277, chestimglprcaucmic 0.57984, chestimglprcaucmac 0.19268, 25.39 secs
# ---- Epoch 7/63
# (1) Training stage (lr = 0.000400) ...
# loss 3.27081, wmdcmp 0.28255, report_loss 1.85761, chestimglprcaucmic 0.64985, chestimglprcaucmac 0.31789, chestimgl_loss 1.45385, 137.32 secs
# (2) Validation stage ...
# wmdcmp 0.11787, cD 0.33820, chestimglaucmic 0.92088, chestimglaucmac 0.79897, chestimglprcaucmic 0.57599, chestimglprcaucmac 0.20089, 22.88 secs
# ---- Epoch 8/63
# (1) Training stage (lr = 0.000217) ...
# loss 3.37552, wmdcmp 0.28996, report_loss 1.81865, chestimglprcaucmic 0.65957, chestimglprcaucmac 0.33841, chestimgl_loss 1.41474, 141.68 secs
# (2) Validation stage ...
# wmdcmp 0.13401, cD 0.40000, chestimglaucmic 0.92150, chestimglaucmac 0.79907, chestimglprcaucmic 0.57974, chestimglprcaucmac 0.20263, 23.03 secs
# ---- Epoch 9/63
# (1) Training stage (lr = 0.000118) ...
# loss 3.31646, wmdcmp 0.29227, report_loss 1.80499, chestimglprcaucmic 0.66369, chestimglprcaucmac 0.34524, chestimgl_loss 1.40471, 137.21 secs
# (2) Validation stage ...
# wmdcmp 0.13107, cD 0.38905, chestimglaucmic 0.92161, chestimglaucmac 0.79972, chestimglprcaucmic 0.57780, chestimglprcaucmac 0.20389, 24.45 secs
# ---- Epoch 10/63
# (1) Training stage (lr = 0.000064) ...
# loss 2.90982, wmdcmp 0.29540, report_loss 1.78217, chestimglprcaucmic 0.66571, chestimglprcaucmac 0.35058, chestimgl_loss 1.40190, 138.20 secs
# (2) Validation stage ...
# wmdcmp 0.12557, cD 0.36415, chestimglaucmic 0.92147, chestimglaucmac 0.80019, chestimglprcaucmic 0.57689, chestimglprcaucmac 0.20403, 23.56 secs
# ---- Epoch 11/63
# (1) Training stage (lr = 0.000035) ...
# loss 3.23770, wmdcmp 0.29573, report_loss 1.77980, chestimglprcaucmic 0.66647, chestimglprcaucmac 0.35442, chestimgl_loss 1.39390, 139.27 secs
# (2) Validation stage ...
# wmdcmp 0.12956, cD 0.40357, chestimglaucmic 0.92163, chestimglaucmac 0.80028, chestimglprcaucmic 0.57748, chestimglprcaucmac 0.20417, 23.66 secs
# ---- Epoch 12/63
# (1) Training stage (lr = 0.000019) ...
# loss 3.12520, wmdcmp 0.29733, report_loss 1.76935, chestimglprcaucmic 0.66908, chestimglprcaucmac 0.35459, chestimgl_loss 1.39554, 133.38 secs
# (2) Validation stage ...
# wmdcmp 0.12444, cD 0.36438, chestimglaucmic 0.92154, chestimglaucmac 0.80031, chestimglprcaucmic 0.57688, chestimglprcaucmac 0.20434, 22.66 secs
# ---- Epoch 13/63
# (1) Training stage (lr = 0.000010) ...
# loss 3.32723, wmdcmp 0.29906, report_loss 1.76331, chestimglprcaucmic 0.66716, chestimglprcaucmac 0.35561, chestimgl_loss 1.39782, 133.61 secs
# (2) Validation stage ...
# wmdcmp 0.12848, cD 0.38060, chestimglaucmic 0.92155, chestimglaucmac 0.80037, chestimglprcaucmic 0.57680, chestimglprcaucmac 0.20447, 22.87 secs
# ---- Epoch 14/63
# (1) Training stage (lr = 0.000006) ...
# loss 3.23916, wmdcmp 0.29894, report_loss 1.76305, chestimglprcaucmic 0.66530, chestimglprcaucmac 0.35538, chestimgl_loss 1.39548, 130.97 secs
# (2) Validation stage ...
# wmdcmp 0.12993, cD 0.38954, chestimglaucmic 0.92152, chestimglaucmac 0.80031, chestimglprcaucmic 0.57669, chestimglprcaucmac 0.20442, 22.13 secs
# ---- Epoch 15/63
# (1) Training stage (lr = 0.000003) ...
# loss 3.14691, wmdcmp 0.29907, report_loss 1.76412, chestimglprcaucmic 0.66823, chestimglprcaucmac 0.35522, chestimgl_loss 1.39331, 130.53 secs
# (2) Validation stage ...
# wmdcmp 0.12935, cD 0.39378, chestimglaucmic 0.92156, chestimglaucmac 0.80036, chestimglprcaucmic 0.57685, chestimglprcaucmac 0.20440, 22.14 secs
# ---- Epoch 16/63
# (1) Training stage (lr = 0.000400) ...
# loss 3.27542, wmdcmp 0.28632, report_loss 1.82694, chestimglprcaucmic 0.66090, chestimglprcaucmac 0.34538, chestimgl_loss 1.39756, 131.52 secs
# (2) Validation stage ...
# wmdcmp 0.11050, cD 0.33288, chestimglaucmic 0.92140, chestimglaucmac 0.80112, chestimglprcaucmic 0.57754, chestimglprcaucmac 0.20551, 22.95 secs
# ---- Epoch 17/63
# (1) Training stage (lr = 0.000199) ...
# loss 3.14871, wmdcmp 0.29091, report_loss 1.80032, chestimglprcaucmic 0.66724, chestimglprcaucmac 0.35617, chestimgl_loss 1.38066, 128.05 secs
# (2) Validation stage ...
# wmdcmp 0.12315, cD 0.38389, chestimglaucmic 0.92167, chestimglaucmac 0.80201, chestimglprcaucmic 0.57548, chestimglprcaucmac 0.20653, 23.88 secs
# ---- Epoch 18/63
# (1) Training stage (lr = 0.000099) ...
# loss 2.73028, wmdcmp 0.29784, report_loss 1.76853, chestimglprcaucmic 0.66966, chestimglprcaucmac 0.36206, chestimgl_loss 1.36906, 130.64 secs
# (2) Validation stage ...
# wmdcmp 0.12246, cD 0.35665, chestimglaucmic 0.92099, chestimglaucmac 0.80168, chestimglprcaucmic 0.57418, chestimglprcaucmac 0.20608, 22.52 secs
# ---- Epoch 19/63
# (1) Training stage (lr = 0.000049) ...
# loss 3.34634, wmdcmp 0.29836, report_loss 1.76198, chestimglprcaucmic 0.67144, chestimglprcaucmac 0.36487, chestimgl_loss 1.36609, 129.16 secs
# (2) Validation stage ...
# wmdcmp 0.12865, cD 0.38952, chestimglaucmic 0.92132, chestimglaucmac 0.80236, chestimglprcaucmic 0.57522, chestimglprcaucmac 0.20611, 20.89 secs
# ---- Epoch 20/63
# (1) Training stage (lr = 0.000024) ...
# loss 3.15356, wmdcmp 0.30143, report_loss 1.74967, chestimglprcaucmic 0.67233, chestimglprcaucmac 0.36639, chestimgl_loss 1.36743, 127.05 secs
# (2) Validation stage ...
# wmdcmp 0.12844, cD 0.38895, chestimglaucmic 0.92130, chestimglaucmac 0.80227, chestimglprcaucmic 0.57501, chestimglprcaucmac 0.20673, 22.13 secs
# ---- Epoch 21/63
# (1) Training stage (lr = 0.000012) ...
# loss 3.20994, wmdcmp 0.30169, report_loss 1.74172, chestimglprcaucmic 0.67225, chestimglprcaucmac 0.36752, chestimgl_loss 1.36320, 128.88 secs
# (2) Validation stage ...
# wmdcmp 0.12770, cD 0.39100, chestimglaucmic 0.92138, chestimglaucmac 0.80236, chestimglprcaucmic 0.57547, chestimglprcaucmac 0.20663, 22.05 secs
# ---- Epoch 22/63
# (1) Training stage (lr = 0.000006) ...
# loss 3.15935, wmdcmp 0.30179, report_loss 1.74060, chestimglprcaucmic 0.67070, chestimglprcaucmac 0.36642, chestimgl_loss 1.37024, 126.67 secs
# (2) Validation stage ...
# wmdcmp 0.12862, cD 0.38554, chestimglaucmic 0.92139, chestimglaucmac 0.80240, chestimglprcaucmic 0.57528, chestimglprcaucmac 0.20662, 20.21 secs
# ---- Epoch 23/63
# (1) Training stage (lr = 0.000003) ...
# loss 2.90682, wmdcmp 0.30104, report_loss 1.73996, chestimglprcaucmic 0.67311, chestimglprcaucmac 0.36493, chestimgl_loss 1.37139, 126.58 secs
# (2) Validation stage ...
# wmdcmp 0.12802, cD 0.38463, chestimglaucmic 0.92146, chestimglaucmac 0.80244, chestimglprcaucmic 0.57553, chestimglprcaucmac 0.20666, 22.00 secs
# ---- Epoch 24/63
# (1) Training stage (lr = 0.000400) ...
# loss 3.06583, wmdcmp 0.28814, report_loss 1.81033, chestimglprcaucmic 0.66600, chestimglprcaucmac 0.35642, chestimgl_loss 1.37064, 124.44 secs
# (2) Validation stage ...
# wmdcmp 0.12699, cD 0.35821, chestimglaucmic 0.92118, chestimglaucmac 0.80282, chestimglprcaucmic 0.57518, chestimglprcaucmac 0.20619, 22.05 secs
# ---- Epoch 25/63
# (1) Training stage (lr = 0.000199) ...
# loss 3.35220, wmdcmp 0.29491, report_loss 1.77761, chestimglprcaucmic 0.67064, chestimglprcaucmac 0.36435, chestimgl_loss 1.36312, 126.69 secs
# (2) Validation stage ...
# wmdcmp 0.12709, cD 0.39779, chestimglaucmic 0.92175, chestimglaucmac 0.80398, chestimglprcaucmic 0.57460, chestimglprcaucmac 0.20765, 21.36 secs
# ---- Epoch 26/63
# (1) Training stage (lr = 0.000099) ...
# loss 3.26217, wmdcmp 0.30135, report_loss 1.74422, chestimglprcaucmic 0.67320, chestimglprcaucmac 0.37093, chestimgl_loss 1.35343, 124.15 secs
# (2) Validation stage ...
# wmdcmp 0.12702, cD 0.39950, chestimglaucmic 0.92090, chestimglaucmac 0.80327, chestimglprcaucmic 0.57334, chestimglprcaucmac 0.20737, 21.84 secs
# ---- Epoch 27/63
# (1) Training stage (lr = 0.000049) ...
# loss 3.27804, wmdcmp 0.30263, report_loss 1.73390, chestimglprcaucmic 0.67449, chestimglprcaucmac 0.37333, chestimgl_loss 1.35342, 127.22 secs
# (2) Validation stage ...
# wmdcmp 0.12597, cD 0.37887, chestimglaucmic 0.92126, chestimglaucmac 0.80363, chestimglprcaucmic 0.57468, chestimglprcaucmac 0.20746, 21.88 secs
# ---- Epoch 28/63
# (1) Training stage (lr = 0.000024) ...
# loss 3.07292, wmdcmp 0.30397, report_loss 1.72447, chestimglprcaucmic 0.67466, chestimglprcaucmac 0.37246, chestimgl_loss 1.35252, 127.20 secs
# (2) Validation stage ...
# wmdcmp 0.13098, cD 0.40822, chestimglaucmic 0.92117, chestimglaucmac 0.80332, chestimglprcaucmic 0.57499, chestimglprcaucmac 0.20731, 16.67 secs
# ---- Epoch 29/63
# (1) Training stage (lr = 0.000012) ...
# loss 3.19895, wmdcmp 0.30541, report_loss 1.71788, chestimglprcaucmic 0.67633, chestimglprcaucmac 0.37694, chestimgl_loss 1.34456, 126.29 secs
# (2) Validation stage ...
# wmdcmp 0.12722, cD 0.39037, chestimglaucmic 0.92132, chestimglaucmac 0.80354, chestimglprcaucmic 0.57535, chestimglprcaucmac 0.20744, 21.09 secs
# ---- Epoch 30/63
# (1) Training stage (lr = 0.000006) ...
# loss 2.97382, wmdcmp 0.30471, report_loss 1.72002, chestimglprcaucmic 0.67681, chestimglprcaucmac 0.37635, chestimgl_loss 1.34629, 124.31 secs
# (2) Validation stage ...
# wmdcmp 0.13060, cD 0.40237, chestimglaucmic 0.92126, chestimglaucmac 0.80345, chestimglprcaucmic 0.57501, chestimglprcaucmac 0.20728, 21.68 secs
# ---- Epoch 31/63
# (1) Training stage (lr = 0.000003) ...
# loss 2.80119, wmdcmp 0.30481, report_loss 1.71576, chestimglprcaucmic 0.67665, chestimglprcaucmac 0.37559, chestimgl_loss 1.35121, 124.92 secs
# (2) Validation stage ...
# wmdcmp 0.12866, cD 0.39609, chestimglaucmic 0.92124, chestimglaucmac 0.80347, chestimglprcaucmic 0.57494, chestimglprcaucmac 0.20721, 21.24 secs
# ---- Epoch 32/63
# (1) Training stage (lr = 0.000400) ...
# loss 3.29252, wmdcmp 0.29252, report_loss 1.78432, chestimglprcaucmic 0.66765, chestimglprcaucmac 0.36250, chestimgl_loss 1.35940, 125.00 secs
# (2) Validation stage ...
# wmdcmp 0.13460, cD 0.41513, chestimglaucmic 0.92010, chestimglaucmac 0.80318, chestimglprcaucmic 0.57097, chestimglprcaucmac 0.20731, 21.56 secs
# ---- Epoch 33/63
# (1) Training stage (lr = 0.000199) ...
# loss 3.31065, wmdcmp 0.29616, report_loss 1.76284, chestimglprcaucmic 0.67300, chestimglprcaucmac 0.37054, chestimgl_loss 1.34548, 126.17 secs
# (2) Validation stage ...
# wmdcmp 0.13199, cD 0.39225, chestimglaucmic 0.92110, chestimglaucmac 0.80414, chestimglprcaucmic 0.57238, chestimglprcaucmac 0.20735, 21.68 secs
# ---- Epoch 34/63
# (1) Training stage (lr = 0.000099) ...
# loss 3.20332, wmdcmp 0.30319, report_loss 1.72856, chestimglprcaucmic 0.67476, chestimglprcaucmac 0.37679, chestimgl_loss 1.34324, 127.15 secs
# (2) Validation stage ...
# wmdcmp 0.12991, cD 0.40010, chestimglaucmic 0.92077, chestimglaucmac 0.80330, chestimglprcaucmic 0.57373, chestimglprcaucmac 0.20648, 21.89 secs
# ---- Epoch 35/63
# (1) Training stage (lr = 0.000049) ...
# loss 3.22672, wmdcmp 0.30548, report_loss 1.71467, chestimglprcaucmic 0.67676, chestimglprcaucmac 0.37800, chestimgl_loss 1.33451, 124.47 secs
# (2) Validation stage ...
# wmdcmp 0.13314, cD 0.41154, chestimglaucmic 0.92150, chestimglaucmac 0.80407, chestimglprcaucmic 0.57623, chestimglprcaucmac 0.20680, 21.88 secs
# ---- Epoch 36/63
# (1) Training stage (lr = 0.000024) ...
# loss 2.83045, wmdcmp 0.30823, report_loss 1.70094, chestimglprcaucmic 0.67754, chestimglprcaucmac 0.37988, chestimgl_loss 1.33764, 122.55 secs
# (2) Validation stage ...
# wmdcmp 0.12917, cD 0.39927, chestimglaucmic 0.92092, chestimglaucmac 0.80395, chestimglprcaucmic 0.57273, chestimglprcaucmac 0.20659, 21.79 secs
# ---- Epoch 37/63
# (1) Training stage (lr = 0.000012) ...
# loss 2.98969, wmdcmp 0.30798, report_loss 1.69950, chestimglprcaucmic 0.67924, chestimglprcaucmac 0.38381, chestimgl_loss 1.33983, 124.65 secs
# (2) Validation stage ...
# wmdcmp 0.12986, cD 0.40475, chestimglaucmic 0.92112, chestimglaucmac 0.80413, chestimglprcaucmic 0.57489, chestimglprcaucmac 0.20684, 22.48 secs
# ---- Epoch 38/63
# (1) Training stage (lr = 0.000006) ...
# loss 3.12542, wmdcmp 0.30854, report_loss 1.69637, chestimglprcaucmic 0.67865, chestimglprcaucmac 0.38092, chestimgl_loss 1.33502, 126.82 secs
# (2) Validation stage ...
# wmdcmp 0.12921, cD 0.40218, chestimglaucmic 0.92118, chestimglaucmac 0.80401, chestimglprcaucmic 0.57447, chestimglprcaucmac 0.20655, 21.77 secs
# ---- Epoch 39/63
# (1) Training stage (lr = 0.000003) ...
# loss 3.15315, wmdcmp 0.30970, report_loss 1.68977, chestimglprcaucmic 0.67747, chestimglprcaucmac 0.38131, chestimgl_loss 1.33874, 124.98 secs
# (2) Validation stage ...
# wmdcmp 0.12958, cD 0.40443, chestimglaucmic 0.92112, chestimglaucmac 0.80402, chestimglprcaucmic 0.57437, chestimglprcaucmac 0.20641, 21.83 secs
# ---- Epoch 40/63
# (1) Training stage (lr = 0.000400) ...
# loss 3.12895, wmdcmp 0.29472, report_loss 1.76309, chestimglprcaucmic 0.66908, chestimglprcaucmac 0.36836, chestimgl_loss 1.34764, 127.45 secs
# (2) Validation stage ...
# wmdcmp 0.13017, cD 0.42531, chestimglaucmic 0.91919, chestimglaucmac 0.80246, chestimglprcaucmic 0.56715, chestimglprcaucmac 0.20580, 22.08 secs
# ---- Epoch 41/63
# (1) Training stage (lr = 0.000199) ...
# loss 3.14906, wmdcmp 0.30031, report_loss 1.73468, chestimglprcaucmic 0.67459, chestimglprcaucmac 0.37511, chestimgl_loss 1.33747, 126.38 secs
# (2) Validation stage ...
# wmdcmp 0.13253, cD 0.39469, chestimglaucmic 0.92099, chestimglaucmac 0.80376, chestimglprcaucmic 0.57440, chestimglprcaucmac 0.20730, 21.75 secs
# ---- Epoch 42/63
# (1) Training stage (lr = 0.000099) ...
# loss 3.20105, wmdcmp 0.30646, report_loss 1.70894, chestimglprcaucmic 0.67747, chestimglprcaucmac 0.38147, chestimgl_loss 1.33082, 126.33 secs
# (2) Validation stage ...
# wmdcmp 0.12262, cD 0.37025, chestimglaucmic 0.92061, chestimglaucmac 0.80395, chestimglprcaucmic 0.57302, chestimglprcaucmac 0.20676, 21.72 secs
# ---- Epoch 43/63
# (1) Training stage (lr = 0.000049) ...
# loss 2.96438, wmdcmp 0.30797, report_loss 1.69797, chestimglprcaucmic 0.67804, chestimglprcaucmac 0.38316, chestimgl_loss 1.32715, 124.07 secs
# (2) Validation stage ...
# wmdcmp 0.12880, cD 0.40363, chestimglaucmic 0.92116, chestimglaucmac 0.80428, chestimglprcaucmic 0.57454, chestimglprcaucmac 0.20768, 21.62 secs
# ---- Epoch 44/63
# (1) Training stage (lr = 0.000024) ...
# loss 2.52754, wmdcmp 0.31158, report_loss 1.68050, chestimglprcaucmic 0.67885, chestimglprcaucmac 0.38484, chestimgl_loss 1.33039, 125.78 secs
# (2) Validation stage ...
# wmdcmp 0.12914, cD 0.39190, chestimglaucmic 0.92087, chestimglaucmac 0.80413, chestimglprcaucmic 0.57333, chestimglprcaucmac 0.20821, 21.85 secs
# ---- Epoch 45/63
# (1) Training stage (lr = 0.000012) ...
# loss 3.27756, wmdcmp 0.31118, report_loss 1.67735, chestimglprcaucmic 0.67972, chestimglprcaucmac 0.38670, chestimgl_loss 1.32859, 126.16 secs
# (2) Validation stage ...
# wmdcmp 0.12891, cD 0.39389, chestimglaucmic 0.92101, chestimglaucmac 0.80413, chestimglprcaucmic 0.57422, chestimglprcaucmac 0.20806, 21.81 secs
# ---- Epoch 46/63
# (1) Training stage (lr = 0.000006) ...
# loss 3.12814, wmdcmp 0.31146, report_loss 1.67507, chestimglprcaucmic 0.68130, chestimglprcaucmac 0.38690, chestimgl_loss 1.32915, 124.33 secs
# (2) Validation stage ...
# wmdcmp 0.12967, cD 0.40443, chestimglaucmic 0.92096, chestimglaucmac 0.80406, chestimglprcaucmic 0.57378, chestimglprcaucmac 0.20800, 21.90 secs
# ---- Epoch 47/63
# (1) Training stage (lr = 0.000003) ...
# loss 3.15574, wmdcmp 0.31200, report_loss 1.67293, chestimglprcaucmic 0.67906, chestimglprcaucmac 0.38773, chestimgl_loss 1.32221, 125.33 secs
# (2) Validation stage ...
# wmdcmp 0.12947, cD 0.39374, chestimglaucmic 0.92095, chestimglaucmac 0.80411, chestimglprcaucmic 0.57391, chestimglprcaucmac 0.20804, 21.88 secs
# ---- Epoch 48/63
# (1) Training stage (lr = 0.000400) ...
# loss 3.05050, wmdcmp 0.29872, report_loss 1.74284, chestimglprcaucmic 0.67188, chestimglprcaucmac 0.37248, chestimgl_loss 1.33895, 124.87 secs
# (2) Validation stage ...
# wmdcmp 0.11447, cD 0.31865, chestimglaucmic 0.92018, chestimglaucmac 0.80430, chestimglprcaucmic 0.57048, chestimglprcaucmac 0.20727, 21.75 secs
# ---- Epoch 49/63
# (1) Training stage (lr = 0.000199) ...
# loss 2.86938, wmdcmp 0.30365, report_loss 1.71411, chestimglprcaucmic 0.67789, chestimglprcaucmac 0.38029, chestimgl_loss 1.33648, 125.43 secs
# (2) Validation stage ...
# wmdcmp 0.12042, cD 0.35322, chestimglaucmic 0.92120, chestimglaucmac 0.80449, chestimglprcaucmic 0.57217, chestimglprcaucmac 0.20785, 20.34 secs
# ---- Epoch 50/63
# (1) Training stage (lr = 0.000099) ...
# loss 2.96177, wmdcmp 0.30893, report_loss 1.68813, chestimglprcaucmic 0.67791, chestimglprcaucmac 0.38553, chestimgl_loss 1.32513, 126.30 secs
# (2) Validation stage ...
# wmdcmp 0.13116, cD 0.41663, chestimglaucmic 0.92105, chestimglaucmac 0.80477, chestimglprcaucmic 0.57235, chestimglprcaucmac 0.20753, 21.81 secs
# ---- Epoch 51/63
# (1) Training stage (lr = 0.000049) ...
# loss 3.20127, wmdcmp 0.31125, report_loss 1.67555, chestimglprcaucmic 0.67942, chestimglprcaucmac 0.38583, chestimgl_loss 1.32476, 124.42 secs
# (2) Validation stage ...
# wmdcmp 0.12541, cD 0.38178, chestimglaucmic 0.92139, chestimglaucmac 0.80483, chestimglprcaucmic 0.57495, chestimglprcaucmac 0.20823, 21.80 secs
# ---- Epoch 52/63
# (1) Training stage (lr = 0.000024) ...
# loss 3.20966, wmdcmp 0.31428, report_loss 1.66112, chestimglprcaucmic 0.68209, chestimglprcaucmac 0.39095, chestimgl_loss 1.31932, 126.35 secs
# (2) Validation stage ...
# wmdcmp 0.12905, cD 0.39976, chestimglaucmic 0.92102, chestimglaucmac 0.80461, chestimglprcaucmic 0.57337, chestimglprcaucmac 0.20831, 21.50 secs
# ---- Epoch 53/63
# (1) Training stage (lr = 0.000012) ...
# loss 3.07494, wmdcmp 0.31491, report_loss 1.65863, chestimglprcaucmic 0.68173, chestimglprcaucmac 0.39164, chestimgl_loss 1.32010, 124.09 secs
# (2) Validation stage ...
# wmdcmp 0.12903, cD 0.39593, chestimglaucmic 0.92108, chestimglaucmac 0.80451, chestimglprcaucmic 0.57422, chestimglprcaucmac 0.20845, 21.89 secs
# ---- Epoch 54/63
# (1) Training stage (lr = 0.000006) ...
# loss 2.92627, wmdcmp 0.31495, report_loss 1.65732, chestimglprcaucmic 0.68214, chestimglprcaucmac 0.39164, chestimgl_loss 1.31606, 123.39 secs
# (2) Validation stage ...
# wmdcmp 0.12762, cD 0.38730, chestimglaucmic 0.92099, chestimglaucmac 0.80452, chestimglprcaucmic 0.57364, chestimglprcaucmac 0.20843, 21.50 secs
# ---- Epoch 55/63
# (1) Training stage (lr = 0.000003) ...
# loss 3.11319, wmdcmp 0.31483, report_loss 1.65326, chestimglprcaucmic 0.68184, chestimglprcaucmac 0.39113, chestimgl_loss 1.31921, 121.60 secs
# (2) Validation stage ...
# wmdcmp 0.12852, cD 0.39235, chestimglaucmic 0.92110, chestimglaucmac 0.80457, chestimglprcaucmic 0.57416, chestimglprcaucmac 0.20831, 21.74 secs
# ---- Epoch 56/63
# (1) Training stage (lr = 0.000400) ...
# loss 2.92885, wmdcmp 0.30072, report_loss 1.72846, chestimglprcaucmic 0.67390, chestimglprcaucmac 0.37691, chestimgl_loss 1.33523, 122.41 secs
# (2) Validation stage ...
# wmdcmp 0.11207, cD 0.33838, chestimglaucmic 0.92006, chestimglaucmac 0.80453, chestimglprcaucmic 0.56998, chestimglprcaucmac 0.20706, 21.85 secs
# ---- Epoch 57/63
# (1) Training stage (lr = 0.000199) ...
# loss 2.69281, wmdcmp 0.30710, report_loss 1.69559, chestimglprcaucmic 0.67840, chestimglprcaucmac 0.38487, chestimgl_loss 1.32480, 122.91 secs
# (2) Validation stage ...
# wmdcmp 0.11667, cD 0.34139, chestimglaucmic 0.92028, chestimglaucmac 0.80411, chestimglprcaucmic 0.56999, chestimglprcaucmac 0.20733, 21.61 secs
# ---- Epoch 58/63
# (1) Training stage (lr = 0.000099) ...
# loss 3.22411, wmdcmp 0.31144, report_loss 1.67406, chestimglprcaucmic 0.67895, chestimglprcaucmac 0.38788, chestimgl_loss 1.31897, 123.28 secs
# (2) Validation stage ...
# wmdcmp 0.12911, cD 0.41553, chestimglaucmic 0.92110, chestimglaucmac 0.80485, chestimglprcaucmic 0.57434, chestimglprcaucmac 0.20784, 23.04 secs
# ---- Epoch 59/63
# (1) Training stage (lr = 0.000049) ...
# loss 3.07276, wmdcmp 0.31394, report_loss 1.65929, chestimglprcaucmic 0.68117, chestimglprcaucmac 0.39134, chestimgl_loss 1.31888, 122.95 secs
# (2) Validation stage ...
# wmdcmp 0.12934, cD 0.39841, chestimglaucmic 0.92098, chestimglaucmac 0.80495, chestimglprcaucmic 0.57348, chestimglprcaucmac 0.20810, 21.71 secs
# ---- Epoch 60/63
# (1) Training stage (lr = 0.000024) ...
# loss 3.15956, wmdcmp 0.31565, report_loss 1.65003, chestimglprcaucmic 0.68199, chestimglprcaucmac 0.39392, chestimgl_loss 1.31194, 123.12 secs
# (2) Validation stage ...
# wmdcmp 0.12987, cD 0.41788, chestimglaucmic 0.92082, chestimglaucmac 0.80485, chestimglprcaucmic 0.57227, chestimglprcaucmac 0.20868, 21.58 secs
# ---- Epoch 61/63
# (1) Training stage (lr = 0.000012) ...
# loss 3.08800, wmdcmp 0.31677, report_loss 1.64328, chestimglprcaucmic 0.68083, chestimglprcaucmac 0.39213, chestimgl_loss 1.31876, 124.94 secs
# (2) Validation stage ...
# wmdcmp 0.12891, cD 0.39581, chestimglaucmic 0.92105, chestimglaucmac 0.80487, chestimglprcaucmic 0.57360, chestimglprcaucmac 0.20847, 21.85 secs
# ---- Epoch 62/63
# (1) Training stage (lr = 0.000006) ...
# loss 2.78519, wmdcmp 0.31832, report_loss 1.63556, chestimglprcaucmic 0.68554, chestimglprcaucmac 0.39638, chestimgl_loss 1.31568, 126.42 secs
# (2) Validation stage ...
# wmdcmp 0.13050, cD 0.41596, chestimglaucmic 0.92112, chestimglaucmac 0.80498, chestimglprcaucmic 0.57415, chestimglprcaucmac 0.20819, 21.74 secs
# ---- Epoch 63/63
# (1) Training stage (lr = 0.000003) ...
# loss 2.94187, wmdcmp 0.31775, report_loss 1.63895, chestimglprcaucmic 0.68362, chestimglprcaucmac 0.39700, chestimgl_loss 1.31211, 125.91 secs
# (2) Validation stage ...
# wmdcmp 0.12873, cD 0.40709, chestimglaucmic 0.92107, chestimglaucmac 0.80495, chestimglprcaucmic 0.57400, chestimglprcaucmac 0.20849, 21.90 secs
