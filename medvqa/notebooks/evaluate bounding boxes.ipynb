# %%
# %env CUDA_VISIBLE_DEVICES=0
# Out:
# env: CUDA_VISIBLE_DEVICES=0

# %%
# !python ../eval_bbox.py \
        --eval-mode "chest_imagenome_average_bbox" \
        --eval-dataset-name "mimiccxr_test_set" \
        --mimiccxr-qa-adapted-reports-filename "qa_adapted_reports__20220904_095810.json"
# Out:
# script's arguments:
#    eval_mode: chest_imagenome_average_bbox
#    eval_dataset_name: mimiccxr_test_set
#    mimiccxr_qa_adapted_reports_filename: qa_adapted_reports__20220904_095810.json
#
# ----- Evaluating model ------
# Loading cached detailed metadata from /mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/qa_adapted_reports__20220904_095810.json__detailed_metadata.pkl
# Computing Mean Absolute Error (MAE) ...
# Computing Mean Intersection Over Union (IOU) ...
# Computing Mean F1 Score ...
#    Computing F1 Score at IOU threshold 0.5 ...
#    Computing F1 Score at IOU threshold 0.6 ...
#    Computing F1 Score at IOU threshold 0.7 ...
#    Computing F1 Score at IOU threshold 0.8 ...
#    Computing F1 Score at IOU threshold 0.9 ...
# Saved bbox metrics to /mnt/data/pamessina/workspaces/medvqa-workspace/results/bbox/20230207_140832_chest_imagenome_average/mimiccxr_test_set__bbox_metrics(eval_mode=chest_imagenome_average_bbox).pkl

# %%
# !python ../eval_bbox.py \
        --eval-mode "chest_imagenome_average_bbox" \
        --eval-dataset-name "chest_imagenome_gold" \
        --mimiccxr-qa-adapted-reports-filename "qa_adapted_reports__20220904_095810.json" \
        --clamp-bbox-coords
# Out:
# script's arguments:
#    eval_mode: chest_imagenome_average_bbox
#    eval_dataset_name: chest_imagenome_gold
#    mimiccxr_qa_adapted_reports_filename: qa_adapted_reports__20220904_095810.json
#    checkpoint_folder: None
#    batch_size: 140
#    num_workers: 0
#    clamp_bbox_coords: True
#    save_predictions: False
#
# ----- Evaluating model ------
# Loading /mnt/data/pamessina/workspaces/medvqa-workspace/cache/chest_imagenome/chest_imagenome_train_average_bbox_coords(qa_adapted_reports__20220904_095810.json,clamped.pkl...
# pred_bbox_coords.shape: (1000, 104)
# pred_bbox_presences.shape: (1000, 26)
# test_bbox_coords[0].shape: (104,)
# test_bbox_presences[0].shape: (26,)
# Computing Mean Absolute Error (MAE) ...
# Computing Mean Intersection Over Union (IOU) ...
# Computing Mean F1 Score ...
#    Computing F1 Score at IOU threshold 0.5 ...
#    Computing F1 Score at IOU threshold 0.6 ...
#    Computing F1 Score at IOU threshold 0.7 ...
# ...

# %%
# !python ../eval_bbox.py \
        --eval-mode "chest_imagenome_average_bbox" \
        --eval-dataset-name "chest_imagenome_gold" \
        --mimiccxr-qa-adapted-reports-filename "qa_adapted_reports__20220904_095810.json" \
        --clamp-bbox-coords
# Out:
# script's arguments:
#    eval_mode: chest_imagenome_average_bbox
#    eval_dataset_name: chest_imagenome_gold
#    mimiccxr_qa_adapted_reports_filename: qa_adapted_reports__20220904_095810.json
#    checkpoint_folder: None
#    batch_size: 140
#    num_workers: 0
#    clamp_bbox_coords: True
#    save_predictions: False
#
# ----- Evaluating model ------
# Loading /mnt/data/pamessina/workspaces/medvqa-workspace/cache/chest_imagenome/chest_imagenome_train_average_bbox_coords(qa_adapted_reports__20220904_095810.json,clamped.pkl...
# pred_bbox_coords.shape: (1000, 104)
# pred_bbox_presences.shape: (1000, 26)
# test_bbox_coords[0].shape: (104,)
# test_bbox_presences[0].shape: (26,)
# Computing Mean Absolute Error (MAE) ...
# Computing Mean Intersection Over Union (IOU) ...
# Computing Mean F1 Score ...
#    Computing F1 Score at IOU threshold 0.5 ...
#    Computing F1 Score at IOU threshold 0.6 ...
#    Computing F1 Score at IOU threshold 0.7 ...
# ...

# %%
# !python ../eval_bbox.py \
        --eval-mode "chest_imagenome_average_bbox" \
        --eval-dataset-name "mimiccxr_test_set" \
        --mimiccxr-qa-adapted-reports-filename "qa_adapted_reports__20220904_095810.json" \
        --clamp-bbox-coords
# Out:
# script's arguments:
#    eval_mode: chest_imagenome_average_bbox
#    eval_dataset_name: mimiccxr_test_set
#    mimiccxr_qa_adapted_reports_filename: qa_adapted_reports__20220904_095810.json
#    checkpoint_folder: None
#    batch_size: 140
#    num_workers: 0
#    clamp_bbox_coords: True
#    save_predictions: False
#
# ----- Evaluating model ------
# Loading /mnt/data/pamessina/workspaces/medvqa-workspace/cache/chest_imagenome/chest_imagenome_train_average_bbox_coords(qa_adapted_reports__20220904_095810.json,clamped.pkl...
# Loading cached detailed metadata from /mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/qa_adapted_reports__20220904_095810.json__detailed_metadata.pkl
# pred_bbox_coords.shape: (3403, 144)
# pred_bbox_presences.shape: (3403, 36)
# test_bbox_coords[0].shape: (144,)
# test_bbox_presences[0].shape: (36,)
# Computing Mean Absolute Error (MAE) ...
# Computing Mean Intersection Over Union (IOU) ...
# Computing Mean F1 Score ...
# ...

# %%
# !python ../eval_bbox.py \
        --eval-mode "chest_imagenome_trained_model" \
        --eval-dataset-name "mimiccxr_test_set" \
        --mimiccxr-qa-adapted-reports-filename "qa_adapted_reports__20220904_095810.json" \
        --checkpoint-folder "models/vqa/20230207_121803_mim+mim(chex)_oevqa(dense121+onehot+transf)_visenc-pretr=0_dws=1.0,1.0_medtok_chx_amp" \
        --batch-size 140 \
        --num-workers 3
# Out:
# script's arguments:
#    eval_mode: chest_imagenome_trained_model
#    eval_dataset_name: mimiccxr_test_set
#    mimiccxr_qa_adapted_reports_filename: qa_adapted_reports__20220904_095810.json
#    checkpoint_folder: models/vqa/20230207_121803_mim+mim(chex)_oevqa(dense121+onehot+transf)_visenc-pretr=0_dws=1.0,1.0_medtok_chx_amp
#    batch_size: 140
#    num_workers: 3
#    clamp_bbox_coords: False
#
# ----- Evaluating model ------
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/vqa/20230207_121803_mim+mim(chex)_oevqa(dense121+onehot+transf)_visenc-pretr=0_dws=1.0,1.0_medtok_chx_amp/metadata.json
# clamp_bbox_coords: True
# Loading cached detailed metadata from /mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/qa_adapted_reports__20220904_095810.json__detailed_metadata.pkl
# Using default transform
# mean = (0.485, 0.456, 0.406), std = (0.229, 0.224, 0.225), image_size = [256, 256], use_center_crop = False
# ...

# %%
# !python ../eval_bbox.py \
        --eval-mode "chest_imagenome_trained_model" \
        --eval-dataset-name "mimiccxr_test_set" \
        --mimiccxr-qa-adapted-reports-filename "qa_adapted_reports__20220904_095810.json" \
        --checkpoint-folder "models/vqa/20230207_182450_mim+mim(chex)_oevqa(dense121+onehot+transf)_visenc-pretr=0_dws=1.0,1.0_medtok_chx_amp" \
        --batch-size 140 \
        --num-workers 3
# Out:
# script's arguments:
#    eval_mode: chest_imagenome_trained_model
#    eval_dataset_name: mimiccxr_test_set
#    mimiccxr_qa_adapted_reports_filename: qa_adapted_reports__20220904_095810.json
#    checkpoint_folder: models/vqa/20230207_182450_mim+mim(chex)_oevqa(dense121+onehot+transf)_visenc-pretr=0_dws=1.0,1.0_medtok_chx_amp
#    batch_size: 140
#    num_workers: 3
#    clamp_bbox_coords: False
#
# ----- Evaluating model ------
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/vqa/20230207_182450_mim+mim(chex)_oevqa(dense121+onehot+transf)_visenc-pretr=0_dws=1.0,1.0_medtok_chx_amp/metadata.json
# clamp_bbox_coords: True
# Loading cached detailed metadata from /mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/qa_adapted_reports__20220904_095810.json__detailed_metadata.pkl
# Using default transform
# mean = (0.485, 0.456, 0.406), std = (0.229, 0.224, 0.225), image_size = [256, 256], use_center_crop = False
# ...

# %%
# !python ../eval_bbox.py \
        --eval-mode "chest_imagenome_trained_model" \
        --eval-dataset-name "mimiccxr_test_set" \
        --mimiccxr-qa-adapted-reports-filename "qa_adapted_reports__20220904_095810.json" \
        --checkpoint-folder "models/vqa/20230209_000803_mim+mim(chex)_oevqa(CenIA-vit-mae-base-ft-mimic+onehot+transf)_visenc-pretr=0_dws=1.0,1.0_medtok_chx_amp" \
        --batch-size 140 \
        --num-workers 3
# Out:
# script's arguments:
#    eval_mode: chest_imagenome_trained_model
#    eval_dataset_name: mimiccxr_test_set
#    mimiccxr_qa_adapted_reports_filename: qa_adapted_reports__20220904_095810.json
#    checkpoint_folder: models/vqa/20230209_000803_mim+mim(chex)_oevqa(CenIA-vit-mae-base-ft-mimic+onehot+transf)_visenc-pretr=0_dws=1.0,1.0_medtok_chx_amp
#    batch_size: 140
#    num_workers: 3
#    clamp_bbox_coords: False
#
# ----- Evaluating model ------
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/vqa/20230209_000803_mim+mim(chex)_oevqa(CenIA-vit-mae-base-ft-mimic+onehot+transf)_visenc-pretr=0_dws=1.0,1.0_medtok_chx_amp/metadata.json
# clamp_bbox_coords: True
# Loading cached detailed metadata from /mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/qa_adapted_reports__20220904_095810.json__detailed_metadata.pkl
# Using Huggingface ViT model transform for CenIA/vit-mae-base-finetuned-mimic
# ...

# %%
# !python ../eval_bbox.py \
        --eval-mode "chest_imagenome_trained_model" \
        --eval-dataset-name "mimiccxr_test_set" \
        --mimiccxr-qa-adapted-reports-filename "qa_adapted_reports__20220904_095810.json" \
        --checkpoint-folder "models/vqa/20230208_231344_mim+mim(chex)_oevqa(dense121+onehot+transf)_visenc-pretr=0_dws=1.0,1.0_medtok_chx_amp" \
        --batch-size 140 \
        --num-workers 3
# Out:
# script's arguments:
#    eval_mode: chest_imagenome_trained_model
#    eval_dataset_name: mimiccxr_test_set
#    mimiccxr_qa_adapted_reports_filename: qa_adapted_reports__20220904_095810.json
#    checkpoint_folder: models/vqa/20230208_231344_mim+mim(chex)_oevqa(dense121+onehot+transf)_visenc-pretr=0_dws=1.0,1.0_medtok_chx_amp
#    batch_size: 140
#    num_workers: 3
#    clamp_bbox_coords: False
#
# ----- Evaluating model ------
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/vqa/20230208_231344_mim+mim(chex)_oevqa(dense121+onehot+transf)_visenc-pretr=0_dws=1.0,1.0_medtok_chx_amp/metadata.json
# clamp_bbox_coords: True
# Loading cached detailed metadata from /mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/qa_adapted_reports__20220904_095810.json__detailed_metadata.pkl
# Using default transform
# mean = (0.485, 0.456, 0.406), std = (0.229, 0.224, 0.225), image_size = [256, 256], use_center_crop = False
# ...

# %%
# !python ../eval_bbox.py \
        --eval-mode "chest_imagenome_trained_model" \
        --eval-dataset-name "mimiccxr_test_set" \
        --mimiccxr-qa-adapted-reports-filename "qa_adapted_reports__20220904_095810.json" \
        --checkpoint-folder "models/vqa/20230208_231030_mim+mim(chex)_oevqa(dense121+onehot+transf)_visenc-pretr=0_dws=1.0,1.0_medtok_chx_amp" \
        --batch-size 140 \
        --num-workers 3 \
        --save-predictions
# Out:
# script's arguments:
#    eval_mode: chest_imagenome_trained_model
#    eval_dataset_name: mimiccxr_test_set
#    mimiccxr_qa_adapted_reports_filename: qa_adapted_reports__20220904_095810.json
#    checkpoint_folder: models/vqa/20230208_231030_mim+mim(chex)_oevqa(dense121+onehot+transf)_visenc-pretr=0_dws=1.0,1.0_medtok_chx_amp
#    batch_size: 140
#    num_workers: 3
#    clamp_bbox_coords: False
#    save_predictions: True
#
# ----- Evaluating model ------
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/vqa/20230208_231030_mim+mim(chex)_oevqa(dense121+onehot+transf)_visenc-pretr=0_dws=1.0,1.0_medtok_chx_amp/metadata.json
# clamp_bbox_coords: True
# Loading cached detailed metadata from /mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/qa_adapted_reports__20220904_095810.json__detailed_metadata.pkl
# Using default transform
# mean = (0.485, 0.456, 0.406), std = (0.229, 0.224, 0.225), image_size = [256, 256], use_center_crop = False
# ...

# %%
# !python ../eval_bbox.py \
        --eval-mode "chest_imagenome_trained_model" \
        --eval-dataset-name "chest_imagenome_gold" \
        --mimiccxr-qa-adapted-reports-filename "qa_adapted_reports__20220904_095810.json" \
        --checkpoint-folder "models/vqa/20230208_231030_mim+mim(chex)_oevqa(dense121+onehot+transf)_visenc-pretr=0_dws=1.0,1.0_medtok_chx_amp" \
        --batch-size 140 \
        --num-workers 3 \
        --save-predictions
# Out:
# script's arguments:
#    eval_mode: chest_imagenome_trained_model
#    eval_dataset_name: chest_imagenome_gold
#    mimiccxr_qa_adapted_reports_filename: qa_adapted_reports__20220904_095810.json
#    checkpoint_folder: models/vqa/20230208_231030_mim+mim(chex)_oevqa(dense121+onehot+transf)_visenc-pretr=0_dws=1.0,1.0_medtok_chx_amp
#    batch_size: 140
#    num_workers: 3
#    clamp_bbox_coords: False
#    save_predictions: True
#
# ----- Evaluating model ------
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/vqa/20230208_231030_mim+mim(chex)_oevqa(dense121+onehot+transf)_visenc-pretr=0_dws=1.0,1.0_medtok_chx_amp/metadata.json
# clamp_bbox_coords: True
# get_image_transform()
# Using standard transform
# mean = (0.485, 0.456, 0.406), std = (0.229, 0.224, 0.225), image_size = [256, 256], use_center_crop = False
# Returning transform without augmentation
# Device: cuda
# ...

# %%
# !python ../eval_bbox.py \
        --eval-mode "chest_imagenome_trained_model" \
        --eval-dataset-name "mimiccxr_test_set" \
        --mimiccxr-qa-adapted-reports-filename "qa_adapted_reports__20220904_095810.json" \
        --checkpoint-folder "models/visual_module/20230215_124027_mim_dense121" \
        --batch-size 140 \
        --num-workers 3 \
        --save-predictions
# Out:
# script's arguments:
#    eval_mode: chest_imagenome_trained_model
#    eval_dataset_name: mimiccxr_test_set
#    mimiccxr_qa_adapted_reports_filename: qa_adapted_reports__20220904_095810.json
#    checkpoint_folder: models/visual_module/20230215_124027_mim_dense121
#    batch_size: 140
#    num_workers: 3
#    clamp_bbox_coords: False
#    save_predictions: True
#
# ----- Evaluating model ------
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230215_124027_mim_dense121/metadata.json
# Loading cached detailed metadata from /mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/qa_adapted_reports__20220904_095810.json__detailed_metadata.pkl
# get_image_transform()
# Using standard transform
# mean = (0.485, 0.456, 0.406), std = (0.229, 0.224, 0.225), image_size = [256, 256], use_center_crop = False
# Returning transform without augmentation
# Device: cuda
# ...

# %%
# !python ../eval_bbox.py \
        --eval-mode "chest_imagenome_trained_model" \
        --eval-dataset-name "chest_imagenome_gold" \
        --mimiccxr-qa-adapted-reports-filename "qa_adapted_reports__20220904_095810.json" \
        --checkpoint-folder "models/visual_module/20230215_124027_mim_dense121" \
        --batch-size 140 \
        --num-workers 3 \
        --save-predictions
# Out:
# script's arguments:
#    eval_mode: chest_imagenome_trained_model
#    eval_dataset_name: chest_imagenome_gold
#    mimiccxr_qa_adapted_reports_filename: qa_adapted_reports__20220904_095810.json
#    checkpoint_folder: models/visual_module/20230215_124027_mim_dense121
#    batch_size: 140
#    num_workers: 3
#    clamp_bbox_coords: False
#    save_predictions: True
#
# ----- Evaluating model ------
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230215_124027_mim_dense121/metadata.json
# get_image_transform()
# Using standard transform
# mean = (0.485, 0.456, 0.406), std = (0.229, 0.224, 0.225), image_size = [256, 256], use_center_crop = False
# Returning transform without augmentation
# Device: cuda
# checkpoint_names = ['checkpoint_13_chestimgbbmf1=0.8848.pt', 'checkpoint_33_chestimgbbmf1=0.9038.pt']
# create_densenet121_feature_extractor()
#    drop_rate: 0.0
#   self.global_feat_size = 2048
# BoundingBoxRegressor_v2:
# ...

# %%
# !python ../eval_bbox.py \
        --eval-mode "chest_imagenome_trained_model" \
        --eval-dataset-name "mimiccxr_test_set" \
        --mimiccxr-qa-adapted-reports-filename "qa_adapted_reports__20220904_095810.json" \
        --checkpoint-folder "models/visual_module/20230217_023459_mim_resnet-ae-txv(101-elastic)" \
        --batch-size 140 \
        --num-workers 3
# Out:
# script's arguments:
#    eval_mode: chest_imagenome_trained_model
#    eval_dataset_name: mimiccxr_test_set
#    mimiccxr_qa_adapted_reports_filename: qa_adapted_reports__20220904_095810.json
#    checkpoint_folder: models/visual_module/20230217_023459_mim_resnet-ae-txv(101-elastic)
#    batch_size: 140
#    num_workers: 3
#    clamp_bbox_coords: False
#    save_predictions: False
#
# ----- Evaluating model ------
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230217_023459_mim_resnet-ae-txv(101-elastic)/metadata.json
# Loading cached detailed metadata from /mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/qa_adapted_reports__20220904_095810.json__detailed_metadata.pkl
# get_image_transform()
# Using torchxrayvision transform (image_size = [224, 224])
# Setting XRayResizer engine to cv2 could increase performance.
# Device: cuda
# checkpoint_names = ['checkpoint_30_chestimgbbmf1=0.6970.pt']
# ...

# %%
# !python ../eval_bbox.py \
        --eval-mode "chest_imagenome_trained_model" \
        --eval-dataset-name "chest_imagenome_gold" \
        --mimiccxr-qa-adapted-reports-filename "qa_adapted_reports__20220904_095810.json" \
        --checkpoint-folder "models/visual_module/20230217_023459_mim_resnet-ae-txv(101-elastic)" \
        --batch-size 140 \
        --num-workers 3
# Out:
# script's arguments:
#    eval_mode: chest_imagenome_trained_model
#    eval_dataset_name: chest_imagenome_gold
#    mimiccxr_qa_adapted_reports_filename: qa_adapted_reports__20220904_095810.json
#    checkpoint_folder: models/visual_module/20230217_023459_mim_resnet-ae-txv(101-elastic)
#    batch_size: 140
#    num_workers: 3
#    clamp_bbox_coords: False
#    save_predictions: False
#
# ----- Evaluating model ------
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230217_023459_mim_resnet-ae-txv(101-elastic)/metadata.json
# get_image_transform()
# Using torchxrayvision transform (image_size = [224, 224])
# Setting XRayResizer engine to cv2 could increase performance.
# Device: cuda
# checkpoint_names = ['checkpoint_30_chestimgbbmf1=0.6970.pt']
# create_torchxrayvision_resnet_autoencoder_feature_extractor()
#   self.global_feat_size = 1024
# BoundingBoxRegressor_v2:
#   local_feat_dim: 512
#   global_feat_dim: 1024
#   hidden_dim: 128
# ...

# %%
# !python ../eval_bbox.py \
        --eval-mode "chest_imagenome_trained_model" \
        --eval-dataset-name "mimiccxr_test_set" \
        --mimiccxr-qa-adapted-reports-filename "qa_adapted_reports__20220904_095810.json" \
        --checkpoint-folder "models/visual_module/20230215_163739_mim_dn121-txv(densenet121-res224-all)" \
        --batch-size 140 \
        --num-workers 3
# Out:
# script's arguments:
#    eval_mode: chest_imagenome_trained_model
#    eval_dataset_name: mimiccxr_test_set
#    mimiccxr_qa_adapted_reports_filename: qa_adapted_reports__20220904_095810.json
#    checkpoint_folder: models/visual_module/20230215_163739_mim_dn121-txv(densenet121-res224-all)
#    batch_size: 140
#    num_workers: 3
#    clamp_bbox_coords: False
#    save_predictions: False
#
# ----- Evaluating model ------
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230215_163739_mim_dn121-txv(densenet121-res224-all)/metadata.json
# Loading cached detailed metadata from /mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/qa_adapted_reports__20220904_095810.json__detailed_metadata.pkl
# get_image_transform()
# Using torchxrayvision transform (image_size = [224, 224])
# Setting XRayResizer engine to cv2 could increase performance.
# Device: cuda
# checkpoint_names = ['checkpoint_23_chestimgbbmf1=0.8874.pt']
# ...

# %%
# !python ../eval_bbox.py \
        --eval-mode "chest_imagenome_trained_model" \
        --eval-dataset-name "chest_imagenome_gold" \
        --mimiccxr-qa-adapted-reports-filename "qa_adapted_reports__20220904_095810.json" \
        --checkpoint-folder "models/visual_module/20230215_163739_mim_dn121-txv(densenet121-res224-all)" \
        --batch-size 140 \
        --num-workers 3
# Out:
# script's arguments:
#    eval_mode: chest_imagenome_trained_model
#    eval_dataset_name: chest_imagenome_gold
#    mimiccxr_qa_adapted_reports_filename: qa_adapted_reports__20220904_095810.json
#    checkpoint_folder: models/visual_module/20230215_163739_mim_dn121-txv(densenet121-res224-all)
#    batch_size: 140
#    num_workers: 3
#    clamp_bbox_coords: False
#    save_predictions: False
#
# ----- Evaluating model ------
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230215_163739_mim_dn121-txv(densenet121-res224-all)/metadata.json
# get_image_transform()
# Using torchxrayvision transform (image_size = [224, 224])
# Setting XRayResizer engine to cv2 could increase performance.
# Device: cuda
# checkpoint_names = ['checkpoint_23_chestimgbbmf1=0.8874.pt']
# create_torchxrayvision_densenet121_feature_extractor()
#   self.global_feat_size = 2048
# BoundingBoxRegressor_v2:
#   local_feat_dim: 1024
#   global_feat_dim: 2048
# ...

# %%
# !python ../eval_bbox.py \
        --eval-mode "chest_imagenome_trained_model" \
        --eval-dataset-name "mimiccxr_test_set" \
        --mimiccxr-qa-adapted-reports-filename "qa_adapted_reports__20220904_095810.json" \
        --checkpoint-folder "models/visual_module/20230217_040800_mim_CenIA-vit-mae-base-ft-mimic" \
        --batch-size 140 \
        --num-workers 3
# Out:
# script's arguments:
#    eval_mode: chest_imagenome_trained_model
#    eval_dataset_name: mimiccxr_test_set
#    mimiccxr_qa_adapted_reports_filename: qa_adapted_reports__20220904_095810.json
#    checkpoint_folder: models/visual_module/20230217_040800_mim_CenIA-vit-mae-base-ft-mimic
#    batch_size: 140
#    num_workers: 3
#    clamp_bbox_coords: False
#    save_predictions: False
#
# ----- Evaluating model ------
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230217_040800_mim_CenIA-vit-mae-base-ft-mimic/metadata.json
# Loading cached detailed metadata from /mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/qa_adapted_reports__20220904_095810.json__detailed_metadata.pkl
# get_image_transform()
# Using Huggingface ViT model transform for CenIA/vit-mae-base-finetuned-mimic
# mean = (0.485, 0.456, 0.406), std = (0.229, 0.224, 0.225), image_size = (224, 224), use_center_crop = False
# Returning transform without augmentation
# ...

# %%
# !python ../eval_bbox.py \
        --eval-mode "chest_imagenome_trained_model" \
        --eval-dataset-name "chest_imagenome_gold" \
        --mimiccxr-qa-adapted-reports-filename "qa_adapted_reports__20220904_095810.json" \
        --checkpoint-folder "models/visual_module/20230217_040800_mim_CenIA-vit-mae-base-ft-mimic" \
        --batch-size 140 \
        --num-workers 3
# Out:
# script's arguments:
#    eval_mode: chest_imagenome_trained_model
#    eval_dataset_name: chest_imagenome_gold
#    mimiccxr_qa_adapted_reports_filename: qa_adapted_reports__20220904_095810.json
#    checkpoint_folder: models/visual_module/20230217_040800_mim_CenIA-vit-mae-base-ft-mimic
#    batch_size: 140
#    num_workers: 3
#    clamp_bbox_coords: False
#    save_predictions: False
#
# ----- Evaluating model ------
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230217_040800_mim_CenIA-vit-mae-base-ft-mimic/metadata.json
# get_image_transform()
# Using Huggingface ViT model transform for CenIA/vit-mae-base-finetuned-mimic
# mean = (0.485, 0.456, 0.406), std = (0.229, 0.224, 0.225), image_size = (224, 224), use_center_crop = False
# Returning transform without augmentation
# Device: cuda
# checkpoint_names = ['checkpoint_29_chestimgbbmf1=0.8666.pt']
#   self.global_feat_size = 768
# BoundingBoxRegressor_v2:
#   local_feat_dim: 768
# ...

# %%
from medvqa.utils.files import load_pickle

# %%
load_pickle('/mnt/data/pamessina/workspaces/medvqa-workspace/results/bbox/20230213_141008_chest-imagenome_average/chest_imagenome_gold__bbox_metrics(eval_mode=chest_imagenome_average_bbox,clamped).pkl')
# Out:
# {'mae': 0.05175780671098541,
#  'iou': 0.8495947162367532,
#  'f1@0.5': 0.9991134175694346,
#  'meanf1': 0.8572327024876966,
#  'f1@0.6': 0.9956266682930318,
#  'f1@0.7': 0.9751933015995852,
#  'f1@0.8': 0.8717351896824904,
#  'f1@0.9': 0.4444949352939415}

# %%
load_pickle('/mnt/data/pamessina/workspaces/medvqa-workspace/results/bbox/20230207_180549_chest-imagenome_average/mimiccxr_test_set__bbox_metrics(eval_mode=chest_imagenome_average_bbox,clamped).pkl')
# Out:
# {'mae': 0.06054711318900875,
#  'iou': 0.8349883804636834,
#  'f1@0.5': 0.9983760870775621,
#  'meanf1': 0.8431848291962218,
#  'f1@0.6': 0.9923746633560664,
#  'f1@0.7': 0.9653374024909578,
#  'f1@0.8': 0.846447186634495,
#  'f1@0.9': 0.41338880642202797}

# %%
load_pickle('/mnt/data/pamessina/workspaces/medvqa-workspace/results/vqa/20230207_121803_mim+mim(chex)_oevqa(dense121+onehot+transf)_visenc-pretr=0_dws=1.0,1.0_medtok_chx_amp/mimiccxr_test_set__bbox_metrics(eval_mode=chest_imagenome_trained_model,clamped).pkl')
# Out:
# {'mae': 0.06558675307133532,
#  'iou': 0.8212208103434535,
#  'f1@0.5': 0.9978929428922767,
#  'meanf1': 0.8169428743796147,
#  'f1@0.6': 0.9904285263029726,
#  'f1@0.7': 0.9546591286759463,
#  'f1@0.8': 0.807362376169439,
#  'f1@0.9': 0.3343713978574387}

# %%
load_pickle('/mnt/data/pamessina/workspaces/medvqa-workspace/results/vqa/20230207_182450_mim+mim(chex)_oevqa(dense121+onehot+transf)_visenc-pretr=0_dws=1.0,1.0_medtok_chx_amp/mimiccxr_test_set__bbox_metrics(eval_mode=chest_imagenome_trained_model,clamped).pkl')
# Out:
# {'mae': 0.06439650219942046,
#  'iou': 0.8244754922551972,
#  'f1@0.5': 0.9982061508210516,
#  'meanf1': 0.8227293495767993,
#  'f1@0.6': 0.9918918453162582,
#  'f1@0.7': 0.9591643412404045,
#  'f1@0.8': 0.817542182245784,
#  'f1@0.9': 0.34684222826049793}

# %%
load_pickle('/mnt/data/pamessina/workspaces/medvqa-workspace/results/vqa/20230209_000803_mim+mim(chex)_oevqa(CenIA-vit-mae-base-ft-mimic+onehot+transf)_visenc-pretr=0_dws=1.0,1.0_medtok_chx_amp/mimiccxr_test_set__bbox_metrics(eval_mode=chest_imagenome_trained_model,clamped).pkl')
# Out:
# {'mae': 0.04008974877188583,
#  'iou': 0.8862984755694859,
#  'f1@0.5': 0.9971864448049828,
#  'meanf1': 0.929402733635721,
#  'f1@0.6': 0.9949264072409407,
#  'f1@0.7': 0.9879433943087587,
#  'f1@0.8': 0.954167260242293,
#  'f1@0.9': 0.7127901615816298}

# %%
load_pickle('/mnt/data/pamessina/workspaces/medvqa-workspace/results/vqa/20230208_231344_mim+mim(chex)_oevqa(dense121+onehot+transf)_visenc-pretr=0_dws=1.0,1.0_medtok_chx_amp/mimiccxr_test_set__bbox_metrics(eval_mode=chest_imagenome_trained_model,clamped).pkl')
# Out:
# {'mae': 0.04537455660085485,
#  'iou': 0.8720729839591963,
#  'f1@0.5': 0.9980765376346444,
#  'meanf1': 0.904846796189409,
#  'f1@0.6': 0.9959275550822814,
#  'f1@0.7': 0.9881401658275135,
#  'f1@0.8': 0.948379006667797,
#  'f1@0.9': 0.5937107157348087}

# %%
load_pickle('/mnt/data/pamessina/workspaces/medvqa-workspace/results/vqa/20230208_231030_mim+mim(chex)_oevqa(dense121+onehot+transf)_visenc-pretr=0_dws=1.0,1.0_medtok_chx_amp/mimiccxr_test_set__bbox_metrics(eval_mode=chest_imagenome_trained_model,clamped).pkl')
# Out:
# {'mae': 0.03713379903714814,
#  'iou': 0.8945952095080029,
#  'f1@0.5': 0.9985695440094398,
#  'meanf1': 0.9428634753771838,
#  'f1@0.6': 0.9968469598981525,
#  'f1@0.7': 0.9913981058423258,
#  'f1@0.8': 0.9684087303745765,
#  'f1@0.9': 0.7590940367614247}

# %%
load_pickle('/mnt/data/pamessina/workspaces/medvqa-workspace/results/vqa/20230208_231030_mim+mim(chex)_oevqa(dense121+onehot+transf)_visenc-pretr=0_dws=1.0,1.0_medtok_chx_amp/chest_imagenome_gold__bbox_metrics(eval_mode=chest_imagenome_trained_model,clamped).pkl')
# Out:
# {'mae': 0.028969086090765917,
#  'iou': 0.9120880169587847,
#  'f1@0.5': 0.998494979680664,
#  'meanf1': 0.9597232510173663,
#  'f1@0.6': 0.997701535432391,
#  'f1@0.7': 0.9954880380677191,
#  'f1@0.8': 0.9862883188560079,
#  'f1@0.9': 0.8206433830500497}

# %%
load_pickle('/mnt/data/pamessina/workspaces/medvqa-workspace/results/visual_module/20230215_124027_mim_dense121/chest_imagenome_gold__bbox_metrics(eval_mode=chest_imagenome_trained_model).pkl')
# Out:
# {'mae': 0.02015108051637212,
#  'iou': 0.938668742294846,
#  'f1@0.5': 0.9980296063342884,
#  'meanf1': 0.9841178940942747,
#  'f1@0.6': 0.9971961595446389,
#  'f1@0.7': 0.9952524929842371,
#  'f1@0.8': 0.9904749879791248,
#  'f1@0.9': 0.9396362236290846}

# %%
load_pickle('/mnt/data/pamessina/workspaces/medvqa-workspace/results/visual_module/20230215_163739_mim_dn121-txv(densenet121-res224-all)/chest_imagenome_gold__bbox_metrics(eval_mode=chest_imagenome_trained_model).pkl')
# Out:
# {'mae': 0.02209131078109823,
#  'iou': 0.9329172907974228,
#  'f1@0.5': 0.9980099405153434,
#  'meanf1': 0.9813052261390851,
#  'f1@0.6': 0.9971571731920158,
#  'f1@0.7': 0.995289205098344,
#  'f1@0.8': 0.989119250497968,
#  'f1@0.9': 0.9269505613917541}

# %%
load_pickle('/mnt/data/pamessina/workspaces/medvqa-workspace/results/visual_module/20230216_131111_mim_dn121/chest_imagenome_gold__bbox_metrics(eval_mode=chest_imagenome_trained_model).pkl')
# Out:
# {'mae': 0.020170537268419317,
#  'iou': 0.9389695254263631,
#  'f1@0.5': 0.997855553755577,
#  'meanf1': 0.9834539408149727,
#  'f1@0.6': 0.9967095677997158,
#  'f1@0.7': 0.9945080216308574,
#  'f1@0.8': 0.9891312321748499,
#  'f1@0.9': 0.9390653287138636}

# %%
from medvqa.evaluation.visual_module import ChestImagenomeBboxPredictionsVisualizer

# %%
visualizer = ChestImagenomeBboxPredictionsVisualizer('/mnt/data/pamessina/workspaces/medvqa-workspace/results/visual_module/20230216_131111_mim_dn121/chest_imagenome_gold__bbox_predictions(eval_mode=chest_imagenome_trained_model).pkl')
# Out:
# 100%|██████████| 1000/1000 [00:00<00:00, 3300.04it/s]
# Loaded and processed 1000 predictions from /mnt/data/pamessina/workspaces/medvqa-workspace/results/visual_module/20230216_131111_mim_dn121/chest_imagenome_gold__bbox_predictions(eval_mode=chest_imagenome_trained_model).pkl
# IoU mean: 0.9380, std: 0.0452

# %%
visualizer.plot_iou_scores(figsize=(10, 5))

# %%
visualizer.visualize_bbox_predictions_example(-1)
# Out:
# IoU score: 0.9741
# DICOM ID: 29a9d3eb-0111a766-87addee4-0e24c217-0972fcfd
# Predicted bounding box coordinates: [0.03773293 0.08869231 0.46627405 0.76201314 0.15337381 0.11243226
#  0.47759873 0.3154572  0.09256484 0.3361878  0.43419814 0.49642348
#  0.04896823 0.4903342  0.43540326 0.7666587  0.27674106 0.28954595
#  0.46349192 0.5053651  0.16086064 0.10802699 0.46641865 0.25242582
#  0.00671282 0.70829344 0.11464823 0.8162159  0.04328763 0.60230887
#  0.512665   0.7754163  0.53427833 0.0895828  0.94704103 0.7552675
#  0.530603   0.11902214 0.8667185  0.34403872 0.5434289  0.34827155
#  0.88990647 0.49838543 0.5462299  0.4849004  0.9369639  0.72432476
#  0.53939444 0.29963148 0.71249044 0.5198613  0.53619945 0.09760923
#  0.83707863 0.2553438  0.8939704  0.6915728  1.0022144  0.77814317
#  0.5325422  0.6330218  0.9446388  0.7396915  0.38891447 0.04030489
#  0.55492795 0.4185416  0.02724919 0.09328232 0.4484635  0.25094855
# ...

# %%
visualizer.visualize_bbox_predictions_example(-100)
# Out:
# IoU score: 0.9633
# DICOM ID: 2e2c3a56-3b503c6c-dec4f6c9-2891feda-814b954a
# Predicted bounding box coordinates: [ 0.03831293  0.10127009  0.43972808  0.7900258   0.12198484  0.11266777
#   0.45018357  0.33729786  0.09544627  0.35821387  0.43225998  0.5034205
#   0.05039435  0.5144736   0.42295793  0.79877746  0.27091008  0.33698177
#   0.4562128   0.54880106  0.14555964  0.08816263  0.43198648  0.25256532
#  -0.00202937  0.71760404  0.10283598  0.8102407   0.04958448  0.65737396
#   0.51288986  0.77283305  0.52323854  0.11204915  0.8822095   0.7170253
#   0.51910204  0.11181194  0.83465195  0.34808537  0.51491666  0.353603
#   0.84536165  0.50372374  0.5124743   0.48294827  0.8656355   0.7334943
#   0.5049293   0.31299216  0.67454606  0.52924913  0.5105625   0.09292244
#   0.7836342   0.25168166  0.8715084   0.7087828   0.9846308   0.79886335
#   0.51111686  0.6635526   0.87875813  0.7597556   0.3840532   0.0312401
# ...

# %%
from importlib import reload
import medvqa

# %%
reload(medvqa.datasets.mimiccxr)
reload(medvqa.evaluation.visual_module)
# Out:
# <module 'medvqa.evaluation.visual_module' from '/home/pamessina/medvqa/medvqa/evaluation/visual_module.py'>

# %%
from medvqa.datasets.mimiccxr import get_detailed_metadata_for_dicom_id

# %%
get_detailed_metadata_for_dicom_id('a5fd5e55-4159fef2-6f0ac33c-f57ea303-1d5e8f7a', "qa_adapted_reports__20220904_095810.json")
# Out:
# Loading cached detailed metadata from /mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/qa_adapted_reports__20220904_095810.json__detailed_metadata.pkl
# [{'background': 'indication: Cough for several days.',
#   'report': 'The lungs are low in volume but clear.\n The cardiomediastinal silhouette , hilar contours , pleural surfaces are normal.\n No pleural effusion or pneumothorax is present.\n Note is made of left axillary clips.\n No acute intrathoracic process',
#   'part_id': 18,
#   'subject_id': 18978682,
#   'study_id': 52754826,
#   'dicom_id': 'a5fd5e55-4159fef2-6f0ac33c-f57ea303-1d5e8f7a',
#   'view_pos': 'PA',
#   'split': 'test',
#   'filepath': '/mnt/data/mimic-cxr/files/p18/p18978682/s52754826.txt',
#   'dicom_id_view_pos_pairs': [('033de00a-e5ba30d5-d1ea8a2f-f3bdaa8a-5e7a0f03',
#     'PA'),
#    ('a406f2bc-128ca407-f2400f61-701fd17b-17f85e90', 'PA'),
#    ('a5fd5e55-4159fef2-6f0ac33c-f57ea303-1d5e8f7a', 'PA')]}]

# %%
from medvqa.datasets.chest_imagenome.chest_imagenome_dataset_management import visualize_ground_truth_bounding_boxes

# %%
get_detailed_metadata_for_dicom_id('a5fd5e55-4159fef2-6f0ac33c-f57ea303-1d5e8f7a', "qa_adapted_reports__20220904_095810.json")
# Out:
# Loading cached detailed metadata from /mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/qa_adapted_reports__20220904_095810.json__detailed_metadata.pkl
# [{'background': 'indication: Cough for several days.',
#   'report': 'The lungs are low in volume but clear.\n The cardiomediastinal silhouette , hilar contours , pleural surfaces are normal.\n No pleural effusion or pneumothorax is present.\n Note is made of left axillary clips.\n No acute intrathoracic process',
#   'part_id': 18,
#   'subject_id': 18978682,
#   'study_id': 52754826,
#   'dicom_id': 'a5fd5e55-4159fef2-6f0ac33c-f57ea303-1d5e8f7a',
#   'view_pos': 'PA',
#   'split': 'test',
#   'filepath': '/mnt/data/mimic-cxr/files/p18/p18978682/s52754826.txt',
#   'dicom_id_view_pos_pairs': [('033de00a-e5ba30d5-d1ea8a2f-f3bdaa8a-5e7a0f03',
#     'PA'),
#    ('a406f2bc-128ca407-f2400f61-701fd17b-17f85e90', 'PA'),
#    ('a5fd5e55-4159fef2-6f0ac33c-f57ea303-1d5e8f7a', 'PA')]}]

# %%
visualizer = ChestImagenomeBboxPredictionsVisualizer('/mnt/data/pamessina/workspaces/medvqa-workspace/results/vqa/20230208_231030_mim+mim(chex)_oevqa(dense121+onehot+transf)_visenc-pretr=0_dws=1.0,1.0_medtok_chx_amp/chest_imagenome_gold__bbox_predictions(eval_mode=chest_imagenome_trained_model,clamped).pkl')
# Out:
# 100%|██████████| 1000/1000 [00:00<00:00, 3378.73it/s]
# Loaded and processed 1000 predictions from /mnt/data/pamessina/workspaces/medvqa-workspace/results/vqa/20230208_231030_mim+mim(chex)_oevqa(dense121+onehot+transf)_visenc-pretr=0_dws=1.0,1.0_medtok_chx_amp/chest_imagenome_gold__bbox_predictions(eval_mode=chest_imagenome_trained_model,clamped).pkl
# IoU mean: 0.9111, std: 0.0389

# %%
visualizer.print_iou_scores_statistics()
# Out:
# IoU mean: 0.9111
# IoU std: 0.0389
# IoU min: 0.4791
# IoU max: 0.9487
# IoU <= 0.1: 0, cumulative: 0
# 0.1 < IoU <= 0.2: 0, cumulative: 0
# 0.2 < IoU <= 0.3: 0, cumulative: 0
# 0.3 < IoU <= 0.4: 0, cumulative: 0
# 0.4 < IoU <= 0.5: 2, cumulative: 2
# 0.5 < IoU <= 0.6: 3, cumulative: 5
# 0.6 < IoU <= 0.7: 4, cumulative: 9
# 0.7 < IoU <= 0.8: 5, cumulative: 14
# 0.8 < IoU <= 0.9: 175, cumulative: 189
# 0.9 < IoU <= 1.0: 811, cumulative: 1000

# %%
visualizer.visualize_bbox_predictions_example(30)
# Out:
# IoU score: 0.8553
# DICOM ID: 933bbefd-442b6de4-02f6131d-03944fcb-0f82410b
# Predicted bounding box coordinates: [ 0.19591087  0.0124451   0.5616675   0.67853534  0.25233865  0.07293917
#   0.50329715  0.25946173  0.22254723  0.2700033   0.46498063  0.33231646
#   0.21371064  0.3987161   0.5085423   0.5708368   0.34015426  0.22873838
#   0.4565883   0.37896928  0.24751069  0.02285804  0.47686443  0.2147001
#   0.15290597  0.5042543   0.27182972  0.6211885   0.1862135   0.513698
#   0.5415608   0.75521266  0.5703928   0.03682348  1.0064932   0.6398258
#   0.5198557   0.03441175  0.8430863   0.28144303  0.46530744  0.20134756
#   0.6813408   0.29604423  0.47843182  0.3096573   0.6985191   0.52194136
#   0.48086408  0.23063451  0.6245706   0.3696798   0.39373648 -0.00170287
#   0.7062891   0.16116233  0.9095862   0.48330772  0.9473511   0.6062203
#   0.5523803   0.49333805  0.9225076   0.64925754  0.42230183  0.12614813
# ...
