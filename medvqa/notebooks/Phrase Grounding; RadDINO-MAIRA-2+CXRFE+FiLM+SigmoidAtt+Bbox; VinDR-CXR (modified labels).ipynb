# %%
# %env CUDA_VISIBLE_DEVICES=2
# Out:
# env: CUDA_VISIBLE_DEVICES=2

# %%
# !python ../train_phrase_grounding.py \
--epochs 100 \
--batches_per_epoch 1000 \
--max_images_per_batch 4 \
--max_phrases_per_batch 1000 \
--max_phrases_per_image 30 \
--val_batch_size_factor 4 \
--raw_image_encoding "rad-dino-huggingface" \
--huggingface_model_name "microsoft/rad-dino-maira-2" \
--image_size 416 416 \
--image_local_feat_size 768 \
--num_regions 841 \
--regions_width 29 \
--regions_height 29 \
--img_aug_mode "random-color-and-spatial" \
--phrase_embedding_size 128 \
--phrase_grounding_mode "adaptive_film_based_pooling_mlp_with_bbox_regression" \
--visual_grounding_hidden_size 256 \
--phrase_mlp_hidden_dims 256 128 \
--num_train_workers 2 \
--num_val_workers 2 \
--gradient_accumulation_steps 5 \
--optimizer_name "adamw" \
--scheduler "exp-warmup+decay+cyclicdecay" \
--lr 1e-6 \
--warmup_decay_and_cyclic_decay_args "1e-6,3,8e-5,5,1e-6,8e-5,5,1e-6" \
--binary_multilabel_classif_loss_name "focal+bce+npbbce" \
--do_visual_grounding_with_bbox_regression \
--use_vinbig_for_train \
--use_vinbig_for_test \
--vinbig_phrase_embeddings_filepath \
"/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/vinbig/label_phrase_embeddings__modified(hash=572,2522233010228708301).pkl" \
--use_vinbig_with_modified_labels \
--use_amp \
--save
# Out:
# script's arguments:
#    epochs: 100
#    batches_per_epoch: 1000
#    max_images_per_batch: 4
#    max_phrases_per_batch: 1000
#    max_phrases_per_image: 30
#    val_batch_size_factor: 4.0
#    checkpoint_folder: None
#    pretrained_checkpoint_folder_path: None
#    pretrained_checkpoint_folder_paths: None
#    freeze_image_encoder: False
#    raw_image_encoding: rad-dino-huggingface
#    huggingface_model_name: microsoft/rad-dino-maira-2
#    num_regions: 841
#    image_local_feat_size: 768
#    image_encoder_pretrained_weights_path: None
#    image_encoder_dropout_p: 0
#    yolov8_model_name_or_path: None
#    yolov8_model_alias: None
#    phrase_embedding_size: 128
#    regions_width: 29
#    regions_height: 29
#    qkv_size: None
#    phrase_grounding_mode: adaptive_film_based_pooling_mlp_with_bbox_regression
#    phrase_classifier_hidden_size: None
#    transf_d_model: None
#    transf_nhead: None
#    transf_dim_feedforward: None
#    transf_dropout: 0
#    transf_num_layers: None
#    visual_feature_proj_size: None
#    visual_grounding_hidden_size: 256
#    phrase_mlp_hidden_dims: [256, 128]
#    predict_global_alignment: False
#    alignment_proj_size: None
#    yolov11_model_name_or_path: None
#    yolov11_model_alias: None
#    optimizer_name: adamw
#    lr: 1e-06
#    scheduler: exp-warmup+decay+cyclicdecay
#    lr_decay: 0.76
#    lr_decay_patience: 2
#    warmup_and_decay_args: None
#    warmup_and_cosine_args: None
#    warmup_decay_and_cyclic_decay_args: 1e-6,3,8e-5,5,1e-6,8e-5,5,1e-6
#    gradient_accumulation_steps: 5
#    override_lr: False
#    max_grad_norm: None
#    attention_supervision_loss_weight: 1.0
#    phrase_classifier_loss_weight: 1.0
#    foreground_loss_weight: 1.0
#    background_loss_weight: 1.0
#    focal_loss_weight: 1.0
#    bce_loss_weight: 1.0
#    wbce_loss_weight: 1.0
#    binary_multilabel_classif_loss_name: focal+bce+npbbce
#    use_weighted_phrase_classifier_loss: False
#    cluster_and_label_weights_for_facts_filepath: None
#    use_attention_regularization_loss: False
#    use_contrastive_phrase_grounding_loss: False
#    nt_xent_temperature: 0.1
#    num_train_workers: 2
#    num_val_workers: 2
#    device: GPU
#    use_amp: True
#    image_size: [416, 416]
#    dicom_id_to_pos_neg_facts_filepath: None
#    iuxray_image_id_to_pos_neg_facts_filepath: None
#    mscxr_phrase2embedding_filepath: None
#    chest_imagenome_bbox_phrase_embeddings_filepath: None
#    vinbig_phrase_embeddings_filepath: /mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/vinbig/label_phrase_embeddings__modified(hash=572,2522233010228708301).pkl
#    chexlocalize_class_phrase_embeddings_filepath: None
#    chexpert_class_phrase_embeddings_filepath: None
#    mimiccxr_exclude_noisy_images: False
#    mimiccxr_facts_weight: 1.0
#    chest_imagenome_anatlocs_weight: 1.0
#    mscxr_weight: 1.0
#    cxrlt2024_weight: 1.0
#    vinbig_weight: 1.0
#    chexlocalize_weight: 1.0
#    chexpert_weight: 1.0
#    iuxray_weight: 1.0
#    img_aug_mode: random-color-and-spatial
#    pos_area_prior: 0.4
#    neg_area_prior: 0.0
#    use_mimiccxr_facts_for_train: False
#    use_mimiccxr_facts_for_test: False
#    use_mscxr_for_train: False
#    use_mscxr_for_test: False
#    use_chest_imagenome_for_train: False
#    use_chest_imagenome_gold_for_test: False
#    use_vinbig_for_train: True
#    use_vinbig_for_test: True
#    use_chexlocalize_for_train: False
#    use_chexlocalize_for_test: False
#    use_chexpert_for_train: False
#    use_chexpert_for_test: False
#    use_iuxray_for_train: False
#    use_iuxray_for_test: False
#    use_cxrlt2024_challenge_split: False
#    use_cxrlt2024_custom_labels: False
#    use_cxrlt2024_official_labels: False
#    use_all_cxrlt2024_official_labels_for_training: False
#    vinbig_training_data_mode: train
#    chexpert_training_data_mode: all
#    mimiccxr_balance_long_middle_short_tail: False
#    mimiccxr_long_middle_short_tail_thresholds: (0.02, 0.05)
#    mimiccxr_report_fact_nli_integrated_data_filepath: None
#    mimiccxr_use_interpret_cxr_challenge_split: False
#    mimiccxr_interpret_cxr_challenge_split_filepath: None
#    iuxray_use_interpret_cxr_challenge_split: False
#    iuxray_interpret_cxr_challenge_split_filepath: None
#    chexpert_use_interpret_cxr_challenge_split: False
#    chexpert_interpret_cxr_challenge_split_filepath: None
#    chexlocalize_use_interpret_cxr_challenge_split: False
#    chexlocalize_interpret_cxr_challenge_split_filepath: None
#    cxrlt2024_custom_dicom_id_to_pos_neg_facts_filepath: None
#    cxrlt2024_official_training_labels_for_fact_classification_filepath: None
#    cxrlt2024_do_balanced_sampling: False
#    do_visual_grounding_with_bbox_regression: True
#    do_visual_grounding_with_segmentation: False
#    replace_phrase_embeddings_with_random_vectors: False
#    use_vinbig_with_modified_labels: True
#    save: True
# ----- Training model from scratch ------
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Creating instance of PhraseGrounder ...
# WARNING: Unused kwargs: {'pretrained_checkpoint_folder_path': None, 'pretrained_checkpoint_folder_paths': None}
# MultiPurposeVisualModule()
#   Initializing raw_image_encoder: rad-dino-huggingface
#   self.global_feat_size = 768
#   self.local_feat_size = 768
#   Initializing auxiliary tasks
# BoundingBoxRegressorSingleClass
#   local_feat_dim: 256
# --------------------------------------------------
# 3) Defining optimizer ...
# create_optimizer(): name = adamw
# --------------------------------------------------
# 4) Defining scheduler ...
# Using exp-warmup+decay+cyclicdecay scheduler: 1e-6,3,8e-5,5,1e-6,8e-5,5,1e-6
# 1e-06 3 8e-05 5 1e-06 8e-05 5 1e-06
# self.steps_to_restart = 5
# self.steps = -1
# self.initial_lr = 8e-05
# --------------------------------------------------
# 5) Creating trainer and validator engines ...
# Focal_BCE_NPBBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 npbbce_weight = 0.3333333333333333
# Focal_BCE_NPBBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 npbbce_weight = 0.3333333333333333
# Focal_BCE_WBCBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 wbcbce_weight = 0.3333333333333333
# foreground_loss_weight: 1.0
# background_loss_weight: 1.0
# GradientAccumulator.__init__(): num_accumulation_steps = 5, max_grad_norm = None
# Focal_BCE_NPBBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 npbbce_weight = 0.3333333333333333
# Focal_BCE_NPBBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 npbbce_weight = 0.3333333333333333
# Focal_BCE_WBCBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 wbcbce_weight = 0.3333333333333333
# foreground_loss_weight: 1.0
# background_loss_weight: 1.0
# --------------------------------------------------
# 6) Creating VinBig Phrase Grounding Trainer ...
# get_image_transform()
#   image_size = [416, 416]
#   mean = [0.5307, 0.5307, 0.5307]
#   std = [0.2583, 0.2583, 0.2583]
#   Using bounding box aware transforms
#     augmentation_mode = random-color-and-spatial
#     default_prob = 0.35
#     for_vinbig: returning vinbig transform
# get_train_transform(): Using bbox-aware transforms for VinBigData
#     Returning augmented transform with mode random-color-and-spatial
# get_image_transform()
#   image_size = [416, 416]
#   mean = [0.5307, 0.5307, 0.5307]
#   std = [0.2583, 0.2583, 0.2583]
#   Using bounding box aware transforms
#     Returning default transform (no augmentation)
# NOTE: Improving VinDr-CXR classification labels ...
# Loading bounding boxes
# Anomalous bboxes found: 29 of 37367
# NOTE: Improving VinDr-CXR bbox labels ...
# class_id_offset: 0
# Anomalous bboxes found: 0 of 2697
# NOTE: Improving VinDr-CXR bbox labels ...
# class_id_offset: 0
#   Loaded 18000 bounding boxes
# Loding phrase_embeddings and phrases from /mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/vinbig/label_phrase_embeddings__modified(hash=572,2522233010228708301).pkl...
# phrase_embeddings.shape = (28, 128)
# phrase_embeddings.dtype = float32
# len(phrases) = 28
# Compute phrase grounding masks and labels
# vinbig_bbox_names = ['Aortic enlargement', 'Atelectasis', 'Calcification', 'Cardiomegaly', 'Clavicle fracture', 'Consolidation', 'Edema', 'Emphysema', 'Enlarged PA', 'ILD', 'Infiltration', 'Lung Opacity', 'Lung cavity', 'Lung cyst', 'Mediastinal shift', 'Nodule/Mass', 'Other lesion', 'Pleural effusion', 'Pleural thickening', 'Pneumothorax', 'Pulmonary fibrosis', 'Rib fracture', 'Abnormal finding']
# vinbig_labels = ['Aortic enlargement', 'Atelectasis', 'Calcification', 'Cardiomegaly', 'Clavicle fracture', 'Consolidation', 'Edema', 'Emphysema', 'Enlarged PA', 'ILD', 'Infiltration', 'Lung Opacity', 'Lung cavity', 'Lung cyst', 'Mediastinal shift', 'Nodule/Mass', 'Pleural effusion', 'Pleural thickening', 'Pneumothorax', 'Pulmonary fibrosis', 'Rib fracture', 'Other lesion', 'COPD', 'Lung tumor', 'Pneumonia', 'Tuberculosis', 'Other disease', 'Abnormal finding']
# num_bbox_classes = 23
# self.phrase_grounding_masks.shape = (18000, 23, 841)
# self.phrase_classification_labels.shape = (18000, 23)
# Append additional labels to phrase_classification_labels
# len(non_bbox_labels) = 5
# non_bbox_labels = ['COPD', 'Lung tumor', 'Pneumonia', 'Tuberculosis', 'Other disease']
# self.phrase_classification_labels.shape = (18000, 28)
# Reorder phrases and phrase_embeddings
# len(phrases) = 28
# len(sorted_phrases) = 28
# phrase_embeddings.shape = (28, 128)
# 	aortic enlargement seen (Aortic enlargement)
# 	atelectasis seen (Atelectasis)
# 	calcification seen (Calcification)
# 	cardiomegaly seen (Cardiomegaly)
# 	clavicle fracture seen (Clavicle fracture)
# 	consolidation seen (Consolidation)
# 	edema seen (Edema)
# 	emphysema seen (Emphysema)
# 	enlarged pulmonary artery seen (Enlarged PA)
# 	interstitial lung disease seen (ILD)
# 	infiltration seen (Infiltration)
# 	lung opacity seen (Lung Opacity)
# 	lung cavity seen (Lung cavity)
# 	lung cyst seen (Lung cyst)
# 	mediastinal shift seen (Mediastinal shift)
# 	nodule/mass seen (Nodule/Mass)
# 	other lesion seen (Other lesion)
# 	pleural effusion seen (Pleural effusion)
# 	pleural thickening seen (Pleural thickening)
# 	pneumothorax seen (Pneumothorax)
# 	pulmonary fibrosis seen (Pulmonary fibrosis)
# 	rib fracture seen (Rib fracture)
# 	abnormal findings seen (Abnormal finding)
# 	copd seen (COPD)
# 	lung tumor seen (Lung tumor)
# 	pneumonia seen (Pneumonia)
# 	tuberculosis seen (Tuberculosis)
# 	other disease seen (Other disease)
# Generating train dataset and dataloader
# len(train_indices) = 15000
# Edema: 13
# Clavicle fracture: 27
# Lung cyst: 33
# COPD: 36
# Lung cavity: 51
# Emphysema: 81
# Rib fracture: 90
# Pneumothorax: 96
# Enlarged PA: 131
# Mediastinal shift: 150
# Atelectasis: 187
# Lung tumor: 291
# Consolidation: 353
# ILD: 397
# Calcification: 458
# Infiltration: 613
# Tuberculosis: 750
# Nodule/Mass: 841
# Pneumonia: 919
# Pleural effusion: 1038
# Other lesion: 1154
# Pulmonary fibrosis: 1621
# Pleural thickening: 2010
# Cardiomegaly: 2316
# Lung Opacity: 2709
# Aortic enlargement: 3098
# Other disease: 4377
# Abnormal finding: 4522
# No labels: 10478
# Group sizes: [10478, 794, 341, 312, 286, 278, 258, 243, 241, 218, 215, 198, 159, 156, 122, 119, 114, 102, 91, 83, 79, 63, 50]
#   len(indices) = 10478, weight = 2381.9852437292775
#   len(indices) = 794, weight = 893.8899020987899
#   len(indices) = 341, weight = 595.5934427021492
#   len(indices) = 312, weight = 568.7753795323758
#   len(indices) = 286, weight = 543.3127950518186
#   len(indices) = 278, weight = 535.1778961104801
#   len(indices) = 258, weight = 514.1586596868186
#   len(indices) = 243, weight = 497.69925147612867
#   len(indices) = 241, weight = 495.4562099629317
#   len(indices) = 218, weight = 468.76865710351854
#   len(indices) = 215, weight = 465.15882500917724
#   len(indices) = 198, weight = 444.08258972130596
#   len(indices) = 159, weight = 391.0802349542582
#   len(indices) = 156, weight = 386.6879164039802
#   len(indices) = 122, weight = 332.9187999914028
#   len(indices) = 119, weight = 327.76937690454827
#   len(indices) = 114, weight = 319.0166061056533
#   len(indices) = 102, weight = 297.0647831080699
#   len(indices) = 91, weight = 275.6141558688678
#   len(indices) = 83, weight = 259.088791948487
#   len(indices) = 79, weight = 250.497443897163
#   len(indices) = 63, weight = 213.55551164361594
#   len(indices) = 50, weight = 179.7743872238934
# batch_size = 4
# Generating val dataset and dataloader
# len(test_indices) = 3000
# batch_size = 16
# --------------------------------------------------
# 7) Creating dataloaders ...
# len(vinbig_trainer.train_dataloader) = 250000000000000000
# len(vinbig_trainer.val_dataloader) = 188
# len(_train_dataloaders) = 1
# len(_val_dataloaders) = 1
# _train_weights = [1.0]
# merged_dataset_name = vinbig
# --------------------------------------------------
# 8) Attaching metrics, losses, timer and events to engines ...
# --------------------------------------------------
# 9) Defining learning rate scheduler handler ...
# --------------------------------------------------
# 10) Defining checkpoint folder path ...
# checkpoint_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250215_152817_vinbig_PhraseGrounder(microsoft-rad-dino-maira-2,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)
# metadata saved to /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250215_152817_vinbig_PhraseGrounder(microsoft-rad-dino-maira-2,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/metadata.json
# --------------------------------------------------
# 11) Defining log_metrics_handler ...
# MetricsLogger :: we'll be logging to /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250215_152817_vinbig_PhraseGrounder(microsoft-rad-dino-maira-2,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/metrics_logs.csv
# --------------------------------------------------
# 12) Running trainer engine ...
# ---- Epoch 1/100
# (1) Training stage (lr = 0.000001) ...
# loss 4.20192, vbg_vgbbox_loss 1.25289, vbg_att_sup_loss 1.35447, vbg_phrcls_loss 1.59456, vbg_prc_auc 0.18706, 190.37 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.03502, vbg_prc_auc 0.07796, 94.42 secs
# Train metrics:
# vbg_vgbbox_loss: 0.4439, weight = 1.0
# vbg_att_sup_loss: 0.4247, weight = 1.0
# vbg_prc_auc: 0.1871, weight = 10.0
# num = 2.7392, den = 12.0000, score = 0.2283
# Val metrics:
# vbg_bbox_iou: 0.0350, weight = 1.0
# vbg_prc_auc: 0.0780, weight = 10.0
# num = 0.8146, den = 11.0000, score = 0.0741
# Train score = 0.2283, Val score = 0.0741, Final score = 0.0818
# w_train = 0.05, w_val = 0.95
# New checkpoint saved: checkpoint_1_vbss+vbou+vbuc+vbss=0.0818.pt
# ---- Epoch 2/100
# (1) Training stage (lr = 0.000004) ...
# loss 3.15263, vbg_vgbbox_loss 0.49852, vbg_att_sup_loss 1.32098, vbg_phrcls_loss 1.33312, vbg_prc_auc 0.18593, 185.88 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.05079, vbg_prc_auc 0.07235, 95.94 secs
# ---- Epoch 3/100
# (1) Training stage (lr = 0.000019) ...
# loss 2.57696, vbg_vgbbox_loss 0.34438, vbg_att_sup_loss 1.06191, vbg_phrcls_loss 1.17067, vbg_prc_auc 0.18925, 193.27 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.10152, vbg_prc_auc 0.18214, 97.49 secs
# New checkpoint saved: checkpoint_3_vbss+vbou+vbuc+vbss=0.1791.pt
# ---- Epoch 4/100
# (1) Training stage (lr = 0.000080) ...
# loss 1.91815, vbg_vgbbox_loss 0.31681, vbg_att_sup_loss 0.69729, vbg_phrcls_loss 0.90405, vbg_prc_auc 0.28597, 192.32 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.13788, vbg_prc_auc 0.28223, 99.39 secs
# New checkpoint saved: checkpoint_4_vbss+vbou+vbuc+vbss=0.2732.pt
# ---- Epoch 5/100
# (1) Training stage (lr = 0.000033) ...
# loss 1.49410, vbg_vgbbox_loss 0.24331, vbg_att_sup_loss 0.49470, vbg_phrcls_loss 0.75609, vbg_prc_auc 0.37031, 192.43 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.16541, vbg_prc_auc 0.32731, 98.98 secs
# New checkpoint saved: checkpoint_5_vbss+vbou+vbuc+vbss=0.3185.pt
# ---- Epoch 6/100
# (1) Training stage (lr = 0.000014) ...
# loss 1.34026, vbg_vgbbox_loss 0.21559, vbg_att_sup_loss 0.43320, vbg_phrcls_loss 0.69148, vbg_prc_auc 0.41084, 193.78 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.19393, vbg_prc_auc 0.35679, 98.80 secs
# New checkpoint saved: checkpoint_6_vbss+vbou+vbuc+vbss=0.3483.pt
# ---- Epoch 7/100
# (1) Training stage (lr = 0.000006) ...
# loss 1.27587, vbg_vgbbox_loss 0.20633, vbg_att_sup_loss 0.40718, vbg_phrcls_loss 0.66237, vbg_prc_auc 0.43041, 189.60 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.20118, vbg_prc_auc 0.36893, 98.88 secs
# New checkpoint saved: checkpoint_7_vbss+vbou+vbuc+vbss=0.3603.pt
# ---- Epoch 8/100
# (1) Training stage (lr = 0.000002) ...
# loss 1.24392, vbg_vgbbox_loss 0.19776, vbg_att_sup_loss 0.39579, vbg_phrcls_loss 0.65038, vbg_prc_auc 0.44469, 193.40 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.20321, vbg_prc_auc 0.37687, 99.13 secs
# New checkpoint saved: checkpoint_8_vbss+vbou+vbuc+vbss=0.3680.pt
# ---- Epoch 9/100
# (1) Training stage (lr = 0.000001) ...
# loss 1.23024, vbg_vgbbox_loss 0.19686, vbg_att_sup_loss 0.39097, vbg_phrcls_loss 0.64242, vbg_prc_auc 0.45258, 194.00 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.20491, vbg_prc_auc 0.38466, 98.87 secs
# New checkpoint saved: checkpoint_9_vbss+vbou+vbuc+vbss=0.3752.pt
# ---- Epoch 10/100
# (1) Training stage (lr = 0.000080) ...
# loss 1.46865, vbg_vgbbox_loss 0.26310, vbg_att_sup_loss 0.46866, vbg_phrcls_loss 0.73689, vbg_prc_auc 0.38657, 193.19 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.18448, vbg_prc_auc 0.33938, 98.16 secs
# ---- Epoch 11/100
# (1) Training stage (lr = 0.000027) ...
# loss 1.23669, vbg_vgbbox_loss 0.20688, vbg_att_sup_loss 0.37938, vbg_phrcls_loss 0.65043, vbg_prc_auc 0.45567, 191.97 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.21358, vbg_prc_auc 0.39273, 97.86 secs
# New checkpoint saved: checkpoint_11_vbss+vbou+vbuc+vbss=0.3831.pt
# ---- Epoch 12/100
# (1) Training stage (lr = 0.000009) ...
# loss 1.13083, vbg_vgbbox_loss 0.19163, vbg_att_sup_loss 0.34215, vbg_phrcls_loss 0.59705, vbg_prc_auc 0.52129, 192.22 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.22305, vbg_prc_auc 0.40868, 98.64 secs
# New checkpoint saved: checkpoint_12_vbss+vbou+vbuc+vbss=0.4005.pt
# ---- Epoch 13/100
# (1) Training stage (lr = 0.000003) ...
# loss 1.09085, vbg_vgbbox_loss 0.18611, vbg_att_sup_loss 0.32931, vbg_phrcls_loss 0.57543, vbg_prc_auc 0.53776, 193.47 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.21631, vbg_prc_auc 0.40923, 98.92 secs
# New checkpoint saved: checkpoint_13_vbss+vbou+vbuc+vbss=0.4012.pt
# ---- Epoch 14/100
# (1) Training stage (lr = 0.000001) ...
# loss 1.06962, vbg_vgbbox_loss 0.18170, vbg_att_sup_loss 0.32023, vbg_phrcls_loss 0.56768, vbg_prc_auc 0.54806, 194.36 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.22175, vbg_prc_auc 0.41196, 102.87 secs
# New checkpoint saved: checkpoint_14_vbss+vbou+vbuc+vbss=0.4045.pt
# ---- Epoch 15/100
# (1) Training stage (lr = 0.000080) ...
# loss 1.28756, vbg_vgbbox_loss 0.22944, vbg_att_sup_loss 0.39343, vbg_phrcls_loss 0.66470, vbg_prc_auc 0.44983, 191.89 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.19307, vbg_prc_auc 0.37065, 100.83 secs
# ---- Epoch 16/100
# (1) Training stage (lr = 0.000027) ...
# loss 1.12447, vbg_vgbbox_loss 0.19473, vbg_att_sup_loss 0.33317, vbg_phrcls_loss 0.59657, vbg_prc_auc 0.53330, 192.82 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.20985, vbg_prc_auc 0.42470, 100.33 secs
# New checkpoint saved: checkpoint_16_vbss+vbou+vbuc+vbss=0.4137.pt
# ---- Epoch 17/100
# (1) Training stage (lr = 0.000009) ...
# loss 1.01773, vbg_vgbbox_loss 0.17893, vbg_att_sup_loss 0.29820, vbg_phrcls_loss 0.54060, vbg_prc_auc 0.59749, 195.27 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.23448, vbg_prc_auc 0.43109, 100.24 secs
# New checkpoint saved: checkpoint_17_vbss+vbou+vbuc+vbss=0.4242.pt
# ---- Epoch 18/100
# (1) Training stage (lr = 0.000003) ...
# loss 0.97890, vbg_vgbbox_loss 0.17322, vbg_att_sup_loss 0.28591, vbg_phrcls_loss 0.51977, vbg_prc_auc 0.61687, 182.58 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.23216, vbg_prc_auc 0.43227, 101.63 secs
# New checkpoint saved: checkpoint_18_vbss+vbou+vbuc+vbss=0.4259.pt
# ---- Epoch 19/100
# (1) Training stage (lr = 0.000001) ...
# loss 0.96835, vbg_vgbbox_loss 0.17385, vbg_att_sup_loss 0.28268, vbg_phrcls_loss 0.51182, vbg_prc_auc 0.62560, 177.55 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.23331, vbg_prc_auc 0.43402, 101.22 secs
# New checkpoint saved: checkpoint_19_vbss+vbou+vbuc+vbss=0.4278.pt
# ---- Epoch 20/100
# (1) Training stage (lr = 0.000080) ...
# loss 1.20380, vbg_vgbbox_loss 0.21735, vbg_att_sup_loss 0.36128, vbg_phrcls_loss 0.62517, vbg_prc_auc 0.49728, 193.89 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.20066, vbg_prc_auc 0.38098, 100.57 secs
# ---- Epoch 21/100
# (1) Training stage (lr = 0.000027) ...
# loss 1.03783, vbg_vgbbox_loss 0.18870, vbg_att_sup_loss 0.30273, vbg_phrcls_loss 0.54640, vbg_prc_auc 0.59516, 189.55 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.22762, vbg_prc_auc 0.43046, 100.56 secs
# ---- Epoch 22/100
# (1) Training stage (lr = 0.000009) ...
# loss 0.93544, vbg_vgbbox_loss 0.17172, vbg_att_sup_loss 0.27033, vbg_phrcls_loss 0.49339, vbg_prc_auc 0.65031, 194.21 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.23684, vbg_prc_auc 0.44526, 100.34 secs
# New checkpoint saved: checkpoint_22_vbss+vbou+vbuc+vbss=0.4389.pt
# ---- Epoch 23/100
# (1) Training stage (lr = 0.000003) ...
# loss 0.90410, vbg_vgbbox_loss 0.16963, vbg_att_sup_loss 0.26201, vbg_phrcls_loss 0.47246, vbg_prc_auc 0.67161, 187.07 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.23807, vbg_prc_auc 0.45770, 100.58 secs
# New checkpoint saved: checkpoint_23_vbss+vbou+vbuc+vbss=0.4507.pt
# ---- Epoch 24/100
# (1) Training stage (lr = 0.000001) ...
# loss 0.88166, vbg_vgbbox_loss 0.16212, vbg_att_sup_loss 0.25100, vbg_phrcls_loss 0.46855, vbg_prc_auc 0.68490, 192.10 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.24035, vbg_prc_auc 0.44912, 100.79 secs
# ---- Epoch 25/100
# (1) Training stage (lr = 0.000080) ...
# loss 1.12908, vbg_vgbbox_loss 0.21111, vbg_att_sup_loss 0.33720, vbg_phrcls_loss 0.58077, vbg_prc_auc 0.54136, 187.16 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.21061, vbg_prc_auc 0.39891, 101.38 secs
# ---- Epoch 26/100
# (1) Training stage (lr = 0.000027) ...
# loss 0.97044, vbg_vgbbox_loss 0.17801, vbg_att_sup_loss 0.28233, vbg_phrcls_loss 0.51010, vbg_prc_auc 0.63196, 179.13 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.24016, vbg_prc_auc 0.44543, 101.84 secs
# ---- Epoch 27/100
# (1) Training stage (lr = 0.000009) ...
# loss 0.87156, vbg_vgbbox_loss 0.16528, vbg_att_sup_loss 0.25047, vbg_phrcls_loss 0.45581, vbg_prc_auc 0.69204, 194.63 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.24124, vbg_prc_auc 0.44912, 101.01 secs
# ---- Epoch 28/100
# (1) Training stage (lr = 0.000003) ...
# loss 0.83868, vbg_vgbbox_loss 0.16130, vbg_att_sup_loss 0.24094, vbg_phrcls_loss 0.43644, vbg_prc_auc 0.71875, 182.76 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.24357, vbg_prc_auc 0.45121, 101.56 secs
# ---- Epoch 29/100
# (1) Training stage (lr = 0.000001) ...
# loss 0.82257, vbg_vgbbox_loss 0.15964, vbg_att_sup_loss 0.23383, vbg_phrcls_loss 0.42910, vbg_prc_auc 0.73355, 190.72 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.24368, vbg_prc_auc 0.45458, 101.89 secs
# New checkpoint saved: checkpoint_29_vbss+vbou+vbuc+vbss=0.4512.pt
# ---- Epoch 30/100
# (1) Training stage (lr = 0.000080) ...
# loss 1.05425, vbg_vgbbox_loss 0.19850, vbg_att_sup_loss 0.30971, vbg_phrcls_loss 0.54604, vbg_prc_auc 0.58554, 182.89 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.20598, vbg_prc_auc 0.39749, 105.31 secs
# ---- Epoch 31/100
# (1) Training stage (lr = 0.000027) ...
# loss 0.91370, vbg_vgbbox_loss 0.17564, vbg_att_sup_loss 0.26097, vbg_phrcls_loss 0.47709, vbg_prc_auc 0.67493, 196.76 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.24005, vbg_prc_auc 0.44013, 103.17 secs
# ---- Epoch 32/100
# (1) Training stage (lr = 0.000009) ...
# loss 0.82843, vbg_vgbbox_loss 0.16067, vbg_att_sup_loss 0.23552, vbg_phrcls_loss 0.43224, vbg_prc_auc 0.73451, 194.77 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.23771, vbg_prc_auc 0.45198, 102.12 secs
# ---- Epoch 33/100
# (1) Training stage (lr = 0.000003) ...
# loss 0.78881, vbg_vgbbox_loss 0.15634, vbg_att_sup_loss 0.22604, vbg_phrcls_loss 0.40643, vbg_prc_auc 0.75890, 193.96 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.24600, vbg_prc_auc 0.45021, 105.61 secs
# ---- Epoch 34/100
# (1) Training stage (lr = 0.000001) ...
# loss 0.77345, vbg_vgbbox_loss 0.15365, vbg_att_sup_loss 0.21936, vbg_phrcls_loss 0.40044, vbg_prc_auc 0.75993, 205.87 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.24309, vbg_prc_auc 0.45117, 105.22 secs
# ---- Epoch 35/100
# (1) Training stage (lr = 0.000080) ...
# loss 1.01667, vbg_vgbbox_loss 0.19374, vbg_att_sup_loss 0.29457, vbg_phrcls_loss 0.52836, vbg_prc_auc 0.60750, 197.13 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.21722, vbg_prc_auc 0.40621, 106.16 secs
# ---- Epoch 36/100
# (1) Training stage (lr = 0.000027) ...
# loss 0.87525, vbg_vgbbox_loss 0.16993, vbg_att_sup_loss 0.25020, vbg_phrcls_loss 0.45512, vbg_prc_auc 0.70029, 198.54 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.24097, vbg_prc_auc 0.46112, 103.31 secs
# New checkpoint saved: checkpoint_36_vbss+vbou+vbuc+vbss=0.4551.pt
# ---- Epoch 37/100
# (1) Training stage (lr = 0.000009) ...
# loss 0.78009, vbg_vgbbox_loss 0.15679, vbg_att_sup_loss 0.21962, vbg_phrcls_loss 0.40367, vbg_prc_auc 0.77495, 195.56 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.24402, vbg_prc_auc 0.46139, 102.15 secs
# New checkpoint saved: checkpoint_37_vbss+vbou+vbuc+vbss=0.4589.pt
# ---- Epoch 38/100
# (1) Training stage (lr = 0.000003) ...
# loss 0.74132, vbg_vgbbox_loss 0.15363, vbg_att_sup_loss 0.21016, vbg_phrcls_loss 0.37753, vbg_prc_auc 0.79135, 196.90 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.24523, vbg_prc_auc 0.46385, 101.33 secs
# New checkpoint saved: checkpoint_38_vbss+vbou+vbuc+vbss=0.4618.pt
# ---- Epoch 39/100
# (1) Training stage (lr = 0.000001) ...
# loss 0.73479, vbg_vgbbox_loss 0.15248, vbg_att_sup_loss 0.20910, vbg_phrcls_loss 0.37321, vbg_prc_auc 0.79211, 193.91 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.24453, vbg_prc_auc 0.46714, 101.50 secs
# New checkpoint saved: checkpoint_39_vbss+vbou+vbuc+vbss=0.4646.pt
# ---- Epoch 40/100
# (1) Training stage (lr = 0.000080) ...
# loss 0.99098, vbg_vgbbox_loss 0.19080, vbg_att_sup_loss 0.28975, vbg_phrcls_loss 0.51043, vbg_prc_auc 0.64620, 194.32 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.21289, vbg_prc_auc 0.41063, 101.23 secs
# ---- Epoch 41/100
# (1) Training stage (lr = 0.000027) ...
# loss 0.82485, vbg_vgbbox_loss 0.16662, vbg_att_sup_loss 0.23256, vbg_phrcls_loss 0.42566, vbg_prc_auc 0.73439, 194.98 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.22488, vbg_prc_auc 0.44824, 101.31 secs
# ---- Epoch 42/100
# (1) Training stage (lr = 0.000009) ...
# loss 0.74475, vbg_vgbbox_loss 0.15470, vbg_att_sup_loss 0.20952, vbg_phrcls_loss 0.38052, vbg_prc_auc 0.79224, 192.55 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.23819, vbg_prc_auc 0.44920, 100.46 secs
# ---- Epoch 43/100
# (1) Training stage (lr = 0.000003) ...
# loss 0.70968, vbg_vgbbox_loss 0.15075, vbg_att_sup_loss 0.20376, vbg_phrcls_loss 0.35517, vbg_prc_auc 0.81412, 177.66 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.23768, vbg_prc_auc 0.45560, 101.06 secs
# ---- Epoch 44/100
# (1) Training stage (lr = 0.000001) ...
# loss 0.68835, vbg_vgbbox_loss 0.14787, vbg_att_sup_loss 0.19230, vbg_phrcls_loss 0.34819, vbg_prc_auc 0.82664, 193.65 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.23761, vbg_prc_auc 0.45502, 100.48 secs
# ---- Epoch 45/100
# (1) Training stage (lr = 0.000080) ...
# loss 0.91617, vbg_vgbbox_loss 0.18431, vbg_att_sup_loss 0.26204, vbg_phrcls_loss 0.46983, vbg_prc_auc 0.67859, 193.07 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.22854, vbg_prc_auc 0.41732, 100.05 secs
# ---- Epoch 46/100
# (1) Training stage (lr = 0.000027) ...
# loss 0.78428, vbg_vgbbox_loss 0.15935, vbg_att_sup_loss 0.22169, vbg_phrcls_loss 0.40324, vbg_prc_auc 0.76424, 175.17 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.23694, vbg_prc_auc 0.43116, 100.52 secs
# ---- Epoch 47/100
# (1) Training stage (lr = 0.000009) ...
# loss 0.69402, vbg_vgbbox_loss 0.15033, vbg_att_sup_loss 0.19694, vbg_phrcls_loss 0.34675, vbg_prc_auc 0.83378, 194.93 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.24384, vbg_prc_auc 0.44623, 99.83 secs
# ---- Epoch 48/100
# (1) Training stage (lr = 0.000003) ...
# loss 0.66037, vbg_vgbbox_loss 0.14847, vbg_att_sup_loss 0.18723, vbg_phrcls_loss 0.32468, vbg_prc_auc 0.84605, 192.58 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.24189, vbg_prc_auc 0.44902, 100.02 secs
# ---- Epoch 49/100
# (1) Training stage (lr = 0.000001) ...
# loss 0.64396, vbg_vgbbox_loss 0.14399, vbg_att_sup_loss 0.18120, vbg_phrcls_loss 0.31877, vbg_prc_auc 0.84653, 191.72 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.24844, vbg_prc_auc 0.45021, 99.96 secs
# ---- Epoch 50/100
# (1) Training stage (lr = 0.000080) ...
# ^C
# Engine run is terminating due to exception:
# Traceback (most recent call last):
#   File "/home/pamessina/medvqa/medvqa/notebooks/../train_phrase_grounding.py", line 1552, in <module>
#     train_from_scratch(**args)
#   File "/home/pamessina/medvqa/medvqa/notebooks/../train_phrase_grounding.py", line 1418, in train_from_scratch
#     return train_model(
#   File "/home/pamessina/medvqa/medvqa/notebooks/../train_phrase_grounding.py", line 926, in train_model
#     run_common_boilerplate_code_and_start_training(
#   File "/home/pamessina/medvqa/medvqa/training/utils.py", line 137, in run_common_boilerplate_code_and_start_training
#     trainer_engine.run(train_dataloader, max_epochs=epochs, epoch_length=batches_per_epoch)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 892, in run
#     return self._internal_run()
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 935, in _internal_run
#     return next(self._internal_run_generator)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 993, in _internal_run_as_gen
#     self._handle_exception(e)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 638, in _handle_exception
#     raise e
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 959, in _internal_run_as_gen
#     epoch_time_taken += yield from self._run_once_on_dataset_as_gen()
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 1068, in _run_once_on_dataset_as_gen
#     self.state.output = self._process_function(self, self.state.batch)
#   File "/home/pamessina/medvqa/medvqa/training/phrase_grounding.py", line 991, in step_fn
#     output = flag_to_step_fn[flag](batch)
#   File "/home/pamessina/medvqa/medvqa/training/phrase_grounding.py", line 622, in step_fn__vinbig_bbox_grounding
#     gradient_accumulator.step(batch_loss, model)
#   File "/home/pamessina/medvqa/medvqa/losses/optimizers.py", line 29, in step
#     self.scaler.scale(batch_loss).backward()
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/_tensor.py", line 525, in backward
#     torch.autograd.backward(
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/autograd/__init__.py", line 267, in backward
#     _engine_run_backward(
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/autograd/graph.py", line 744, in _engine_run_backward
#     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# KeyboardInterrupt
