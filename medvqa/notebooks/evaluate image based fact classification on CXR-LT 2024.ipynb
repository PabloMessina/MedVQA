# %%
# %env CUDA_VISIBLE_DEVICES=2
# Out:
# env: CUDA_VISIBLE_DEVICES=2

# %%
# %env TOKENIZERS_PARALLELISM=false
# Out:
# env: TOKENIZERS_PARALLELISM=false

# %%
# !python ../eval_fact_classification.py \
--eval_mode "cxrlt_2024_custom_nli_based_labels_fact_classification" \
--checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240716_075455_mim-facts+chst-img-anat+cxrlt2024+vinbig+chexloc+chxp+iuxray_PhraseGrounder(dn121,FiLM_SigmoidAttention,128,256,256,256,1,256-128)" \
--num_workers 2 \
--max_images_per_batch 40 \
--max_facts_per_image 100 \
--device "cuda" \
--cxrlt2024_dicom_id_to_pos_neg_facts_filepath \
"/mnt/workspace/pamessina/medvqa-workspace/cache/mimiccxr/cxrlt2024_integrated_nli_queries_for_fact_classification.pkl"
# Out:
# script's arguments:
#    checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240716_075455_mim-facts+chst-img-anat+cxrlt2024+vinbig+chexloc+chxp+iuxray_PhraseGrounder(dn121,FiLM_SigmoidAttention,128,256,256,256,1,256-128)
#    num_workers: 2
#    max_images_per_batch: 40
#    max_facts_per_image: 100
#    device: cuda
#    eval_mode: cxrlt_2024_custom_nli_based_labels_fact_classification
#    fact_embedding_model_name: None
#    fact_embedding_model_checkpoint_folder_path: None
#    fact_embedding_batch_size: 32
#    fact_embedding_num_workers: 4
#    fact_embedding_device: cuda
#    mimiccxr_chexpert_labels_filepath: None
#    chest_imagenome_label_names_filepath: None
#    chest_imagenome_image_id_to_labels_filepath: None
#    mimiccxr_report_fact_nli_integrated_data_filepath: None
#    tune_thresholds: False
#    max_processes_for_chexpert_labeler: 14
#    background_findings_and_impression_per_report_filepath: None
# ...

# %%
# !python ../eval_fact_classification.py \
--eval_mode "cxrlt_2024_train_val_split_from_training_data" \
--checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240719_101753_cxrlt2024(Off)_PhraseGrounder(dn121,FiLM_SigmoidAttention,128,256,256,256,1,256-128)" \
--num_workers 2 \
--max_images_per_batch 40 \
--max_facts_per_image 100 \
--device "cuda" \
--cxrlt2024_official_training_labels_for_fact_classification_filepath \
"/mnt/workspace/pamessina/medvqa-workspace/cache/mimiccxr/cxrlt2024_offical_training_labels_for_fact_classification.pkl"
# Out:
# script's arguments:
#    checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240719_101753_cxrlt2024(Off)_PhraseGrounder(dn121,FiLM_SigmoidAttention,128,256,256,256,1,256-128)
#    num_workers: 2
#    max_images_per_batch: 40
#    max_facts_per_image: 100
#    device: cuda
#    eval_mode: cxrlt_2024_train_val_split_from_training_data
#    fact_embedding_model_name: None
#    fact_embedding_model_checkpoint_folder_path: None
#    fact_embedding_batch_size: 32
#    fact_embedding_num_workers: 4
#    fact_embedding_device: cuda
#    mimiccxr_chexpert_labels_filepath: None
#    chest_imagenome_label_names_filepath: None
#    chest_imagenome_image_id_to_labels_filepath: None
#    mimiccxr_report_fact_nli_integrated_data_filepath: None
#    tune_thresholds: False
#    max_processes_for_chexpert_labeler: 14
#    background_findings_and_impression_per_report_filepath: None
#    use_alternative_chexpert_template: False
# ...

# %%
# !python ../eval_fact_classification.py \
--eval_mode "cxrlt_2024_train_val_split_from_training_data" \
--checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240719_192640_cxrlt2024(Off)_PhraseGrounder(dn121,FiLM_SigmoidAttention,128,256,256,256,1,256-128)" \
--num_workers 2 \
--max_images_per_batch 40 \
--max_facts_per_image 100 \
--device "cuda" \
--cxrlt2024_official_training_labels_for_fact_classification_filepath \
"/mnt/workspace/pamessina/medvqa-workspace/cache/mimiccxr/cxrlt2024_offical_training_labels_for_fact_classification.pkl"
# Out:
# script's arguments:
#    checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240719_192640_cxrlt2024(Off)_PhraseGrounder(dn121,FiLM_SigmoidAttention,128,256,256,256,1,256-128)
#    num_workers: 2
#    max_images_per_batch: 40
#    max_facts_per_image: 100
#    device: cuda
#    eval_mode: cxrlt_2024_train_val_split_from_training_data
#    fact_embedding_model_name: None
#    fact_embedding_model_checkpoint_folder_path: None
#    fact_embedding_batch_size: 32
#    fact_embedding_num_workers: 4
#    fact_embedding_device: cuda
#    mimiccxr_chexpert_labels_filepath: None
#    chest_imagenome_label_names_filepath: None
#    chest_imagenome_image_id_to_labels_filepath: None
#    mimiccxr_report_fact_nli_integrated_data_filepath: None
#    tune_thresholds: False
#    max_processes_for_chexpert_labeler: 14
#    background_findings_and_impression_per_report_filepath: None
#    use_alternative_chexpert_template: False
# ...

# %%
# !python ../eval_fact_classification.py \
--eval_mode "cxrlt_2024_train_val_split_from_training_data__ensemble" \
--ensemble_checkpoint_folder_paths \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240720_191717_cxrlt2024(Off)_PhraseGrounder(dn121,FiLM_SigmoidAttention,128,256,256,256,1,256-128)" \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240720_003302_cxrlt2024(Off)_PhraseGrounder(dn121,FiLM_SigmoidAttention,128,256,256,256,1,256-128)" \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240720_174237_mim-facts+chst-img-anat+cxrlt2024(Off)+cxrlt2024(GPT4)+vinbig+chexloc+chxp+iuxray_PhraseGrounder(dn121,FiLM_SigmoidAttention,128,256,256,256,1,256-128)" \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240720_014226_mim-facts+cxrlt2024(Off)+cxrlt2024(GPT4)+vinbig+chexloc+chxp+iuxray_PhraseGrounder(dn121,FiLM_SigmoidAttention,128,256,256,256,1,256-128)" \
--num_workers 4 \
--max_images_per_batch 100 \
--max_facts_per_image 100 \
--device "cuda" \
--cxrlt2024_official_training_labels_for_fact_classification_filepath \
"/mnt/workspace/pamessina/medvqa-workspace/cache/mimiccxr/cxrlt2024_official_training_labels_for_fact_classification(n_train=240529,n_val=18342,pf=0.03).pkl"
# Out:
# script's arguments:
#    checkpoint_folder_path: None
#    num_workers: 4
#    max_images_per_batch: 100
#    max_facts_per_image: 100
#    device: cuda
#    eval_mode: cxrlt_2024_train_val_split_from_training_data__ensemble
#    fact_embedding_model_name: None
#    fact_embedding_model_checkpoint_folder_path: None
#    fact_embedding_batch_size: 32
#    fact_embedding_num_workers: 4
#    fact_embedding_device: cuda
#    mimiccxr_chexpert_labels_filepath: None
#    chest_imagenome_label_names_filepath: None
#    chest_imagenome_image_id_to_labels_filepath: None
#    mimiccxr_report_fact_nli_integrated_data_filepath: None
#    tune_thresholds: False
#    max_processes_for_chexpert_labeler: 14
#    background_findings_and_impression_per_report_filepath: None
#    use_alternative_chexpert_template: False
#    eval_chexpert_only: False
#    section_mode: None
#    dicom_id_to_pos_neg_facts_filepath: None
#    f1_threshold: 0.2
#    label_based_json_reports_filepath: None
# ...

# %%
from medvqa.utils.files import load_pickle

# %%
tmp = load_pickle('/mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20240719_192640_cxrlt2024(Off)_PhraseGrounder(dn121,FiLM_SigmoidAttention,128,256,256,256,1,256-128)/cxrlt_2024_train_val_split_results.pkl')

# %%
tmp.keys()
# Out:
# dict_keys(['class_names', 'train_pos_count', 'val_pos_count', 'train_neg_count', 'val_neg_count', 'train_prcauc', 'val_prcauc', 'train_rocauc', 'val_rocauc', 'train_f1', 'val_f1'])

# %% [markdown]
# # Plots

# %%
from importlib import reload
import pandas as pd
import medvqa

# %%
reload(medvqa.evaluation.plots)
# Out:
# <module 'medvqa.evaluation.plots' from '/home/pamessina/medvqa/medvqa/evaluation/plots.py'>

# %%
from medvqa.evaluation.plots import plot_metrics, plot_metric_bars_per_method

# %%
submission_results = """                                  AP       AUC        F1       ECE
Adenopathy                  0.038169  0.727796  0.008000  0.937238
Atelectasis                 0.544143  0.795577  0.259732  0.484868
Azygos Lobe                 0.015952  0.742401  0.000000  0.997944
Calcification of the Aorta  0.097296  0.860319  0.000000  0.927270
Cardiomegaly                0.630559  0.797996  0.393387  0.446373
Clavicle Fracture           0.008200  0.705911  0.000000  0.997386
Consolidation               0.185391  0.768292  0.009148  0.794258
Edema                       0.509964  0.837578  0.331259  0.662139
Emphysema                   0.229281  0.878584  0.144019  0.941230
Enlarged Cardiomediastinum  0.142221  0.574392  0.006080  0.661014
Fibrosis                    0.068544  0.869075  0.104265  0.980682
Fissure                     0.062539  0.788450  0.051020  0.940948
Fracture                    0.108988  0.700757  0.036320  0.827082
Granuloma                   0.019324  0.676244  0.000000  0.935106
Hernia                      0.450276  0.874315  0.481951  0.944502
Hydropneumothorax           0.153448  0.940906  0.184049  0.988715
Infarction                  0.003825  0.556112  0.000000  0.982426
Infiltration                0.049802  0.586086  0.000000  0.821492
Kyphosis                    0.104053  0.889805  0.105960  0.987019
Lobar Atelectasis           0.001671  0.724090  0.000000  0.995472
Lung Lesion                 0.032027  0.758717  0.000000  0.945736
Lung Opacity                0.545864  0.751101  0.196671  0.410013
Mass                        0.125906  0.761255  0.057075  0.905530
Nodule                      0.083890  0.733572  0.000000  0.872739
Normal                      0.315376  0.789435  0.006648  0.665894
Pleural Effusion            0.797475  0.905231  0.679111  0.577696
Pleural Other               0.010521  0.822218  0.000000  0.986598
Pleural Thickening          0.060118  0.801247  0.008114  0.936176
Pneumomediastinum           0.127942  0.816626  0.195652  0.988142
Pneumonia                   0.275469  0.630637  0.006483  0.556320
Pneumoperitoneum            0.115566  0.828633  0.194444  0.991836
Pneumothorax                0.412581  0.840059  0.369871  0.821897
Pulmonary Embolism          0.010415  0.556336  0.000000  0.961423
Pulmonary Hypertension      0.017916  0.767277  0.039735  0.983459
Rib Fracture                0.083397  0.698528  0.024634  0.847769
Round(ed) Atelectasis       0.005750  0.804094  0.000000  0.996653
Subcutaneous Emphysema      0.516594  0.975888  0.574324  0.973447
Support Devices             0.867569  0.920084  0.780740  0.542507
Tortuous Aorta              0.052272  0.812268  0.000000  0.932747
Tuberculosis                0.055178  0.776443  0.005128  0.950541
Mean                        0.198387  0.776108  0.131346  0.852507
"""

import pandas as pd
def parse_results(results):
    results = results.strip()
    lines = results.split('\n')
    metrics = lines[0].split()
    data = []
    numbers_idx = lines[1].index('0')
    for line in lines[1:]:
        data.append([line[:numbers_idx].strip()] + [float(x) for x in line[numbers_idx:].split()])
    df = pd.DataFrame(data, columns=['class'] + metrics)
    return df

test_results_df = parse_results(submission_results)
test_results_df
# Out:
#                          class        AP       AUC        F1       ECE
# 0                   Adenopathy  0.038169  0.727796  0.008000  0.937238
# 1                  Atelectasis  0.544143  0.795577  0.259732  0.484868
# 2                  Azygos Lobe  0.015952  0.742401  0.000000  0.997944
# 3   Calcification of the Aorta  0.097296  0.860319  0.000000  0.927270
# 4                 Cardiomegaly  0.630559  0.797996  0.393387  0.446373
# 5            Clavicle Fracture  0.008200  0.705911  0.000000  0.997386
# 6                Consolidation  0.185391  0.768292  0.009148  0.794258
# 7                        Edema  0.509964  0.837578  0.331259  0.662139
# 8                    Emphysema  0.229281  0.878584  0.144019  0.941230
# 9   Enlarged Cardiomediastinum  0.142221  0.574392  0.006080  0.661014
# 10                    Fibrosis  0.068544  0.869075  0.104265  0.980682
# 11                     Fissure  0.062539  0.788450  0.051020  0.940948
# ...

# %%
df = pd.DataFrame(columns=tmp['class_names'], data=[tmp['train_prcauc'], tmp['val_prcauc'], test_results_df.AP.values[:-1]])
df
# Out:
#    Adenopathy  Atelectasis  Azygos Lobe  Calcification of the Aorta  \
# 0    0.323192     0.661003     0.875990                    0.220326
# 1    0.146975     0.641577     0.254899                    0.133581
# 2    0.038169     0.544143     0.015952                    0.097296
#
#    Cardiomegaly  Clavicle Fracture  Consolidation     Edema  Emphysema  \
# 0      0.720726           0.872063       0.266488  0.615835   0.428686
# 1      0.700972           0.011546       0.264119  0.593139   0.239637
# 2      0.630559           0.008200       0.185391  0.509964   0.229281
#
#    Enlarged Cardiomediastinum  ...  Pneumoperitoneum  Pneumothorax  \
# 0                    0.234037  ...          0.803738      0.549270
# 1                    0.230650  ...          0.078546      0.452738
# 2                    0.142221  ...          0.115566      0.412581
#
#    Pulmonary Embolism  Pulmonary Hypertension  Rib Fracture  \
# 0            0.302522                0.564631      0.364774
# ...

# %%
plot_metric_bars_per_method(
    [df.iloc[0], df.iloc[1], df.iloc[2]],
    method_aliases=['Training Set', 'Validation Set', 'Test Set'],
    metric_names=tmp['class_names'],
    metric_aliases=[f"{x} (n_val={tmp['val_pos_count'][i]}, n_train={tmp['train_pos_count'][i]})" for i, x in enumerate(tmp['class_names'])],
    title='PRC-AUC per class (train & val)',
    figsize=(8, 12),
    row_idx_to_sort_by=2,
)

# %%
metric_names=[f"{tmp['class_names'][i]} (tp={tmp['tp'][i]}, tn={tmp['tn'][i]}, fp={tmp['fp'][i]}, fn={tmp['fn'][i]})" for i in range(len(tmp['class_names']))]
plot_metrics(
    metric_names=metric_names,
    metric_values=tmp['prcauc'],
    title='PRC-AUC per class',
    ylabel='Class',
    xlabel='PRC-AUC',
    append_average_to_title=True,
    horizontal=True,
    sort_metrics=True,
    show_metrics_above_bars=True,
    figsize=(5,10),
)

# %%
plot_metrics(
    metric_names=metric_names,
    metric_values=tmp['rocauc'],
    title='ROC-AUC per class',
    ylabel='Class',
    xlabel='ROC-AUC',
    append_average_to_title=True,
    horizontal=True,
    sort_metrics=True,
    show_metrics_above_bars=True,
    figsize=(5,10),
)

# %%
plot_metrics(
    metric_names=metric_names,
    metric_values=tmp['acc'],
    title='Accuracy per class',
    ylabel='Class',
    xlabel='Accuracy',
    append_average_to_title=True,
    horizontal=True,
    sort_metrics=True,
    show_metrics_above_bars=True,
    figsize=(5,10),
)

# %%
plot_metrics(
    metric_names=metric_names,
    metric_values=tmp['f1'],
    title='F1 per class',
    ylabel='Class',
    xlabel='F1',
    append_average_to_title=True,
    horizontal=True,
    sort_metrics=True,
    show_metrics_above_bars=True,
    figsize=(5,10),
)

# %%
from medvqa.datasets.mimiccxr import MIMIC_CXR_LT_2024_TASK1_DEV_CSV_PATH
import pandas as pd

# %%
df = pd.read_csv(MIMIC_CXR_LT_2024_TASK1_DEV_CSV_PATH)

# %%
df
# Out:
#                                            dicom_id  subject_id   study_id  \
# 0      8b88f03a-2004113d-4118def5-35820db5-d0913df8    10002221  s53781756
# 1      e4ee2428-245e9222-399ef211-62b44204-35580e8d    10002221  s53781756
# 2      e8c44648-ff02beea-3d5ff638-dec79b01-7df71a69    10002428  s50027225
# 3      7f51d06c-dad16fe6-ff21a632-edc5a3e6-ffa387bf    10002428  s50292543
# 4      85b903ac-bfc4d6cd-491d2a72-18e7c16e-23d2cafa    10002428  s50444997
# ...                                             ...         ...        ...
# 39288  d2cd4e14-8e2f2e2f-655e5e4b-9a7899b8-d2f32f1b    19995258  s57269721
# 39289  af56abbc-803d5997-25f51fc4-533fa2c6-d9d719d1    19995258  s57860851
# 39290  653f7936-09b7e7f7-3e5f154c-98d78fa3-faa4f78c    19995366  s58000912
# 39291  e591d474-a9222915-e7ec6372-97f02cc2-d14f8994    19995366  s58000912
# 39292  53e9b6d0-5d5317f5-f1a4c031-01d40558-fd14a425    19999376  s57540554
#
#       ViewPosition ViewCodeSequence_CodeMeaning  \
# ...

# %% [markdown]
# # Submissions

# %%
# !python ../eval_fact_classification.py \
--eval_mode "cxrlt_2024_tasks_1_2_3_dev_submission" \
--checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240716_075455_mim-facts+chst-img-anat+cxrlt2024+vinbig+chexloc+chxp+iuxray_PhraseGrounder(dn121,FiLM_SigmoidAttention,128,256,256,256,1,256-128)" \
--num_workers 3 \
--max_images_per_batch 90 \
--max_facts_per_image 100 \
--device "cuda" \
--cxrlt2024_dicom_id_to_pos_neg_facts_filepath \
"/mnt/workspace/pamessina/medvqa-workspace/cache/mimiccxr/cxrlt2024_integrated_nli_queries_for_fact_classification.pkl"
# Out:
# script's arguments:
#    checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240716_075455_mim-facts+chst-img-anat+cxrlt2024+vinbig+chexloc+chxp+iuxray_PhraseGrounder(dn121,FiLM_SigmoidAttention,128,256,256,256,1,256-128)
#    num_workers: 3
#    max_images_per_batch: 90
#    max_facts_per_image: 100
#    device: cuda
#    eval_mode: cxrlt_2024_tasks_1_2_3_dev_submission
#    fact_embedding_model_name: None
#    fact_embedding_model_checkpoint_folder_path: None
#    fact_embedding_batch_size: 32
#    fact_embedding_num_workers: 4
#    fact_embedding_device: cuda
#    mimiccxr_chexpert_labels_filepath: None
#    chest_imagenome_label_names_filepath: None
#    chest_imagenome_image_id_to_labels_filepath: None
#    mimiccxr_report_fact_nli_integrated_data_filepath: None
#    tune_thresholds: False
#    max_processes_for_chexpert_labeler: 14
#    background_findings_and_impression_per_report_filepath: None
# ...

# %%
# !python ../eval_fact_classification.py \
--eval_mode "cxrlt_2024_tasks_1_2_3_dev_submission" \
--checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240719_101753_cxrlt2024(Off)_PhraseGrounder(dn121,FiLM_SigmoidAttention,128,256,256,256,1,256-128)" \
--num_workers 3 \
--max_images_per_batch 90 \
--max_facts_per_image 100 \
--device "cuda" \
--use_cxrlt2024_official_labels \
--cxrlt2024_official_training_labels_for_fact_classification_filepath \
"/mnt/workspace/pamessina/medvqa-workspace/cache/mimiccxr/cxrlt2024_offical_training_labels_for_fact_classification.pkl"
# Out:
# script's arguments:
#    checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240719_101753_cxrlt2024(Off)_PhraseGrounder(dn121,FiLM_SigmoidAttention,128,256,256,256,1,256-128)
#    num_workers: 3
#    max_images_per_batch: 90
#    max_facts_per_image: 100
#    device: cuda
#    eval_mode: cxrlt_2024_tasks_1_2_3_dev_submission
#    fact_embedding_model_name: None
#    fact_embedding_model_checkpoint_folder_path: None
#    fact_embedding_batch_size: 32
#    fact_embedding_num_workers: 4
#    fact_embedding_device: cuda
#    mimiccxr_chexpert_labels_filepath: None
#    chest_imagenome_label_names_filepath: None
#    chest_imagenome_image_id_to_labels_filepath: None
#    mimiccxr_report_fact_nli_integrated_data_filepath: None
#    tune_thresholds: False
#    max_processes_for_chexpert_labeler: 14
#    background_findings_and_impression_per_report_filepath: None
#    use_alternative_chexpert_template: False
#    eval_chexpert_only: False
# ...

# %%
# !python ../eval_fact_classification.py \
--eval_mode "cxrlt_2024_tasks_1_2_3_dev_submission" \
--checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240719_192640_cxrlt2024(Off)_PhraseGrounder(dn121,FiLM_SigmoidAttention,128,256,256,256,1,256-128)" \
--num_workers 3 \
--max_images_per_batch 90 \
--max_facts_per_image 100 \
--device "cuda" \
--use_cxrlt2024_official_labels \
--cxrlt2024_official_training_labels_for_fact_classification_filepath \
"/mnt/workspace/pamessina/medvqa-workspace/cache/mimiccxr/cxrlt2024_offical_training_labels_for_fact_classification.pkl"
# Out:
# script's arguments:
#    checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240719_192640_cxrlt2024(Off)_PhraseGrounder(dn121,FiLM_SigmoidAttention,128,256,256,256,1,256-128)
#    num_workers: 3
#    max_images_per_batch: 90
#    max_facts_per_image: 100
#    device: cuda
#    eval_mode: cxrlt_2024_tasks_1_2_3_dev_submission
#    fact_embedding_model_name: None
#    fact_embedding_model_checkpoint_folder_path: None
#    fact_embedding_batch_size: 32
#    fact_embedding_num_workers: 4
#    fact_embedding_device: cuda
#    mimiccxr_chexpert_labels_filepath: None
#    chest_imagenome_label_names_filepath: None
#    chest_imagenome_image_id_to_labels_filepath: None
#    mimiccxr_report_fact_nli_integrated_data_filepath: None
#    tune_thresholds: False
#    max_processes_for_chexpert_labeler: 14
#    background_findings_and_impression_per_report_filepath: None
#    use_alternative_chexpert_template: False
#    eval_chexpert_only: False
# ...

# %%
# !python ../eval_fact_classification.py \
--eval_mode "cxrlt_2024_tasks_1_2_3_dev_submission" \
--checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240720_191717_cxrlt2024(Off)_PhraseGrounder(dn121,FiLM_SigmoidAttention,128,256,256,256,1,256-128)" \
--num_workers 3 \
--max_images_per_batch 90 \
--max_facts_per_image 100 \
--device "cuda" \
--use_cxrlt2024_official_labels \
--cxrlt2024_official_training_labels_for_fact_classification_filepath \
"/mnt/workspace/pamessina/medvqa-workspace/cache/mimiccxr/cxrlt2024_official_training_labels_for_fact_classification(n_train=240529,n_val=18342,pf=0.03).pkl"
# Out:
# script's arguments:
#    checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240720_191717_cxrlt2024(Off)_PhraseGrounder(dn121,FiLM_SigmoidAttention,128,256,256,256,1,256-128)
#    num_workers: 3
#    max_images_per_batch: 90
#    max_facts_per_image: 100
#    device: cuda
#    eval_mode: cxrlt_2024_tasks_1_2_3_dev_submission
#    fact_embedding_model_name: None
#    fact_embedding_model_checkpoint_folder_path: None
#    fact_embedding_batch_size: 32
#    fact_embedding_num_workers: 4
#    fact_embedding_device: cuda
#    mimiccxr_chexpert_labels_filepath: None
#    chest_imagenome_label_names_filepath: None
#    chest_imagenome_image_id_to_labels_filepath: None
#    mimiccxr_report_fact_nli_integrated_data_filepath: None
#    tune_thresholds: False
#    max_processes_for_chexpert_labeler: 14
#    background_findings_and_impression_per_report_filepath: None
#    use_alternative_chexpert_template: False
#    eval_chexpert_only: False
# ...

# %%
# !python ../eval_fact_classification.py \
--eval_mode "cxrlt_2024_tasks_1_2_3_dev_submission" \
--checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240720_003302_cxrlt2024(Off)_PhraseGrounder(dn121,FiLM_SigmoidAttention,128,256,256,256,1,256-128)" \
--num_workers 3 \
--max_images_per_batch 90 \
--max_facts_per_image 100 \
--device "cuda" \
--use_cxrlt2024_official_labels \
--cxrlt2024_official_training_labels_for_fact_classification_filepath \
"/mnt/workspace/pamessina/medvqa-workspace/cache/mimiccxr/cxrlt2024_official_training_labels_for_fact_classification(n_train=240529,n_val=18342,pf=0.03).pkl"
# Out:
# script's arguments:
#    checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240720_003302_cxrlt2024(Off)_PhraseGrounder(dn121,FiLM_SigmoidAttention,128,256,256,256,1,256-128)
#    num_workers: 3
#    max_images_per_batch: 90
#    max_facts_per_image: 100
#    device: cuda
#    eval_mode: cxrlt_2024_tasks_1_2_3_dev_submission
#    fact_embedding_model_name: None
#    fact_embedding_model_checkpoint_folder_path: None
#    fact_embedding_batch_size: 32
#    fact_embedding_num_workers: 4
#    fact_embedding_device: cuda
#    mimiccxr_chexpert_labels_filepath: None
#    chest_imagenome_label_names_filepath: None
#    chest_imagenome_image_id_to_labels_filepath: None
#    mimiccxr_report_fact_nli_integrated_data_filepath: None
#    tune_thresholds: False
#    max_processes_for_chexpert_labeler: 14
#    background_findings_and_impression_per_report_filepath: None
#    use_alternative_chexpert_template: False
#    eval_chexpert_only: False
# ...

# %%
# !python ../eval_fact_classification.py \
--eval_mode "cxrlt_2024_tasks_1_2_3_dev_submission" \
--checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240720_174237_mim-facts+chst-img-anat+cxrlt2024(Off)+cxrlt2024(GPT4)+vinbig+chexloc+chxp+iuxray_PhraseGrounder(dn121,FiLM_SigmoidAttention,128,256,256,256,1,256-128)" \
--num_workers 3 \
--max_images_per_batch 90 \
--max_facts_per_image 100 \
--device "cuda" \
--use_cxrlt2024_official_labels \
--cxrlt2024_official_training_labels_for_fact_classification_filepath \
"/mnt/workspace/pamessina/medvqa-workspace/cache/mimiccxr/cxrlt2024_official_training_labels_for_fact_classification(n_train=240529,n_val=18342,pf=0.03).pkl"
# Out:
# script's arguments:
#    checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240720_174237_mim-facts+chst-img-anat+cxrlt2024(Off)+cxrlt2024(GPT4)+vinbig+chexloc+chxp+iuxray_PhraseGrounder(dn121,FiLM_SigmoidAttention,128,256,256,256,1,256-128)
#    num_workers: 3
#    max_images_per_batch: 90
#    max_facts_per_image: 100
#    device: cuda
#    eval_mode: cxrlt_2024_tasks_1_2_3_dev_submission
#    fact_embedding_model_name: None
#    fact_embedding_model_checkpoint_folder_path: None
#    fact_embedding_batch_size: 32
#    fact_embedding_num_workers: 4
#    fact_embedding_device: cuda
#    mimiccxr_chexpert_labels_filepath: None
#    chest_imagenome_label_names_filepath: None
#    chest_imagenome_image_id_to_labels_filepath: None
#    mimiccxr_report_fact_nli_integrated_data_filepath: None
#    tune_thresholds: False
#    max_processes_for_chexpert_labeler: 14
#    background_findings_and_impression_per_report_filepath: None
# ...

# %%
# !python ../eval_fact_classification.py \
--eval_mode "cxrlt_2024_tasks_1_2_3_dev_submission" \
--checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240720_014226_mim-facts+cxrlt2024(Off)+cxrlt2024(GPT4)+vinbig+chexloc+chxp+iuxray_PhraseGrounder(dn121,FiLM_SigmoidAttention,128,256,256,256,1,256-128)" \
--num_workers 3 \
--max_images_per_batch 90 \
--max_facts_per_image 100 \
--device "cuda" \
--use_cxrlt2024_official_labels \
--cxrlt2024_official_training_labels_for_fact_classification_filepath \
"/mnt/workspace/pamessina/medvqa-workspace/cache/mimiccxr/cxrlt2024_official_training_labels_for_fact_classification(n_train=240529,n_val=18342,pf=0.03).pkl"
# Out:
# script's arguments:
#    checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240720_014226_mim-facts+cxrlt2024(Off)+cxrlt2024(GPT4)+vinbig+chexloc+chxp+iuxray_PhraseGrounder(dn121,FiLM_SigmoidAttention,128,256,256,256,1,256-128)
#    num_workers: 3
#    max_images_per_batch: 90
#    max_facts_per_image: 100
#    device: cuda
#    eval_mode: cxrlt_2024_tasks_1_2_3_dev_submission
#    fact_embedding_model_name: None
#    fact_embedding_model_checkpoint_folder_path: None
#    fact_embedding_batch_size: 32
#    fact_embedding_num_workers: 4
#    fact_embedding_device: cuda
#    mimiccxr_chexpert_labels_filepath: None
#    chest_imagenome_label_names_filepath: None
#    chest_imagenome_image_id_to_labels_filepath: None
#    mimiccxr_report_fact_nli_integrated_data_filepath: None
#    tune_thresholds: False
#    max_processes_for_chexpert_labeler: 14
#    background_findings_and_impression_per_report_filepath: None
# ...

# %%
# !python ../eval_fact_classification.py \
--eval_mode "cxrlt_2024_task_1_dev_submission__ensemble" \
--cxrlt2024_task1_dev_submission_csv_paths \
"/mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20240720_191717_cxrlt2024(Off)_PhraseGrounder(dn121,FiLM_SigmoidAttention,128,256,256,256,1,256-128)/cxrlt_2024_task1_dev_submission_20240721_161400.csv" \
"/mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20240720_003302_cxrlt2024(Off)_PhraseGrounder(dn121,FiLM_SigmoidAttention,128,256,256,256,1,256-128)/cxrlt_2024_task1_dev_submission_20240721_161804.csv" \
"/mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20240720_174237_mim-facts+chst-img-anat+cxrlt2024(Off)+cxrlt2024(GPT4)+vinbig+chexloc+chxp+iuxray_PhraseGrounder(dn121,FiLM_SigmoidAttention,128,256,256,256,1,256-128)/cxrlt_2024_task1_dev_submission_20240721_162209.csv" \
"/mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20240720_014226_mim-facts+cxrlt2024(Off)+cxrlt2024(GPT4)+vinbig+chexloc+chxp+iuxray_PhraseGrounder(dn121,FiLM_SigmoidAttention,128,256,256,256,1,256-128)/cxrlt_2024_task1_dev_submission_20240721_162613.csv" \
--ensemble_filepath \
"/mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20240720_191717_cxrlt2024(Off)_PhraseGrounder(dn121,FiLM_SigmoidAttention,128,256,256,256,1,256-128)/cxrlt_2024_val_split_results+ensemble(hash=1184,96664990883319546).pkl"
# Out:
# script's arguments:
#    checkpoint_folder_path: None
#    num_workers: 4
#    max_images_per_batch: 30
#    max_facts_per_image: 20
#    device: cuda
#    eval_mode: cxrlt_2024_task_1_dev_submission__ensemble
#    fact_embedding_model_name: None
#    fact_embedding_model_checkpoint_folder_path: None
#    fact_embedding_batch_size: 32
#    fact_embedding_num_workers: 4
#    fact_embedding_device: cuda
#    mimiccxr_chexpert_labels_filepath: None
#    chest_imagenome_label_names_filepath: None
#    chest_imagenome_image_id_to_labels_filepath: None
#    mimiccxr_report_fact_nli_integrated_data_filepath: None
#    tune_thresholds: False
#    max_processes_for_chexpert_labeler: 14
#    background_findings_and_impression_per_report_filepath: None
#    use_alternative_chexpert_template: False
#    eval_chexpert_only: False
#    section_mode: None
#    dicom_id_to_pos_neg_facts_filepath: None
#    f1_threshold: 0.2
#    label_based_json_reports_filepath: None
# ...

# %%
# !python ../eval_fact_classification.py \
--eval_mode "cxrlt_2024_task_2_dev_submission__ensemble" \
--cxrlt2024_task2_dev_submission_csv_paths \
"/mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20240720_191717_cxrlt2024(Off)_PhraseGrounder(dn121,FiLM_SigmoidAttention,128,256,256,256,1,256-128)/cxrlt_2024_task2_dev_submission_20240721_161400.csv" \
"/mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20240720_003302_cxrlt2024(Off)_PhraseGrounder(dn121,FiLM_SigmoidAttention,128,256,256,256,1,256-128)/cxrlt_2024_task2_dev_submission_20240721_161804.csv" \
"/mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20240720_174237_mim-facts+chst-img-anat+cxrlt2024(Off)+cxrlt2024(GPT4)+vinbig+chexloc+chxp+iuxray_PhraseGrounder(dn121,FiLM_SigmoidAttention,128,256,256,256,1,256-128)/cxrlt_2024_task2_dev_submission_20240721_162209.csv" \
"/mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20240720_014226_mim-facts+cxrlt2024(Off)+cxrlt2024(GPT4)+vinbig+chexloc+chxp+iuxray_PhraseGrounder(dn121,FiLM_SigmoidAttention,128,256,256,256,1,256-128)/cxrlt_2024_task2_dev_submission_20240721_162613.csv" \
--ensemble_filepath \
"/mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20240720_191717_cxrlt2024(Off)_PhraseGrounder(dn121,FiLM_SigmoidAttention,128,256,256,256,1,256-128)/cxrlt_2024_val_split_results+ensemble(hash=1184,96664990883319546).pkl"
# Out:
# script's arguments:
#    checkpoint_folder_path: None
#    num_workers: 4
#    max_images_per_batch: 30
#    max_facts_per_image: 20
#    device: cuda
#    eval_mode: cxrlt_2024_task_2_dev_submission__ensemble
#    fact_embedding_model_name: None
#    fact_embedding_model_checkpoint_folder_path: None
#    fact_embedding_batch_size: 32
#    fact_embedding_num_workers: 4
#    fact_embedding_device: cuda
#    mimiccxr_chexpert_labels_filepath: None
#    chest_imagenome_label_names_filepath: None
#    chest_imagenome_image_id_to_labels_filepath: None
#    mimiccxr_report_fact_nli_integrated_data_filepath: None
#    tune_thresholds: False
#    max_processes_for_chexpert_labeler: 14
#    background_findings_and_impression_per_report_filepath: None
#    use_alternative_chexpert_template: False
#    eval_chexpert_only: False
#    section_mode: None
#    dicom_id_to_pos_neg_facts_filepath: None
#    f1_threshold: 0.2
#    label_based_json_reports_filepath: None
# ...
