# %%
# %env CUDA_VISIBLE_DEVICES=0
# Out:
# env: CUDA_VISIBLE_DEVICES=0

# %%
from medvqa.utils.files import load_pickle
from medvqa.evaluation.plots import plot_metrics
from medvqa.datasets.chest_imagenome import CHEST_IMAGENOME_GOLD_BBOX_NAMES__SORTED
import numpy as np
import medvqa
from importlib import reload

# %% [markdown]
# # 1) Phrase Grounding: DenseNet121 + CXRFE + Sigmoid-based attention

# %%
# !python ../eval_phrase_grounding.py \
--checkpoint_folder_path "/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240618_175951_mscxr+chst-img-anat+vinbig+chexloc_PhraseGrounder(dn121,SigmoidAttention,128,256,256,1)" \
--max_images_per_batch 100 \
--max_phrases_per_batch 2000 \
--max_phrases_per_image 30 \
--eval_chest_imagenome_gold
# Out:
# script's arguments:
#    checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240618_175951_mscxr+chst-img-anat+vinbig+chexloc_PhraseGrounder(dn121,SigmoidAttention,128,256,256,1)
#    max_images_per_batch: 100
#    max_phrases_per_batch: 2000
#    max_phrases_per_image: 30
#    num_workers: 0
#    device: GPU
#    mscxr_phrase2embedding_filepath: None
#    eval_chest_imagenome_gold: True
#    eval_mscxr: False
# ----- Evaluating model -----
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240618_175951_mscxr+chst-img-anat+vinbig+chexloc_PhraseGrounder(dn121,SigmoidAttention,128,256,256,1)/metadata.json
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Creating instance of PhraseGrounder ...
# WARNING: Unused kwargs: {'pretrained_checkpoint_folder_path': '/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240505_224220_mim-facts+vinbig+chexloc+chxp_PhraseGrounder(dn121,128,256)/', 'pretrained_checkpoint_folder_paths': None}
# MultiPurposeVisualModule()
#   Initializing raw_image_encoder: densenet-121
# create_densenet121_feature_extractor()
#    drop_rate: 0.0
# DenseNet121's pretrained weights loaded from ImageNet
#   self.global_feat_size = 2048
#   self.local_feat_size = 1024
#   Initializing auxiliary tasks
# checkpoint_names = ['checkpoint_100_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.7635.pt', 'checkpoint_196_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.7787.pt']
# --------------------------------------------------
# 3) Loading model from checkpoint ...
# checkpoint_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240618_175951_mscxr+chst-img-anat+vinbig+chexloc_PhraseGrounder(dn121,SigmoidAttention,128,256,256,1)/checkpoint_196_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.7787.pt
# Loading model and epoch only
# Checkpoint successfully loaded!
# --------------------------------------------------
# 4) Creating MIMIC-CXR Phrase Grounding Trainer ...
# get_image_transform()
# Using standard transform
# mean = (0.485, 0.456, 0.406), std = (0.229, 0.224, 0.225), image_size = [416, 416], use_center_crop = False
# Returning transform without augmentation
# mask_exponent = 0.4
# len(forbidden_train_dicom_ids) = 2030
# Preparing Chest Imagenome dataset and dataloader for testing...
# Loding bbox_phrase_embeddings and bbox_phrases from /mnt/workspace/pamessina/medvqa-workspace/cache/chest_imagenome/bbox_phrase_embeddings(hash=333,2614535641242304201).pkl...
# bbox_phrase_embeddings.shape = (26, 128)
# len(bbox_phrases) = 26
# 	 right lung
# 	 right upper lung zone
# 	 right mid lung zone
# 	 right lower lung zone
# 	 right hilar structures
# 	 right apical zone
# 	 right costophrenic angle
# 	 right hemidiaphragm
# 	 left lung
# 	 left upper lung zone
# 	 left mid lung zone
# 	 left lower lung zone
# 	 left hilar structures
# 	 left apical zone
# 	 left costophrenic angle
# 	 left hemidiaphragm
# 	 trachea
# 	 right clavicle
# 	 left clavicle
# 	 aortic arch
# 	 upper mediastinum
# 	 svc
# 	 cardiac silhouette
# 	 cavoatrial junction
# 	 right atrium
# 	 carina
# Using image size mode: medium_512
# 227835it [00:02, 92231.98it/s]
# Total number of images: 1000
# --------------------------------------------------
# 5) ----- Evaluating on Chest ImaGenome Gold Bbox Phrase Grounding -----
# Creating evaluation engine ...
# binary_loss_kwargs: {'focal_weight': 1.0, 'bce_weight': 1.0, 'wbce_weight': 1.0}
# Focal_BCE_WBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 wbce_weight = 0.3333333333333333
# Focal_BCE_Loss(): focal_weight = 0.5 bce_weight = 0.5
# Focal_BCE_WBCBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 wbcbce_weight = 0.3333333333333333
# foreground_loss_weight: 1.0
# background_loss_weight: 1.0
# Defining log_metrics_handler ...
# Running engine ...
# segmask_iou 0.34338, 14.23 secs
# Final metrics:
# segmask_iou:
# \begin{tabular}{lr}
# \hline
#  bbox_name                &       iou \\
# \hline
#  right lung               & 0.64386   \\
#  right upper lung zone    & 0.318836  \\
#  right mid lung zone      & 0.287417  \\
#  right lower lung zone    & 0.422874  \\
#  right hilar structures   & 0.250524  \\
#  right apical zone        & 0.346079  \\
#  right costophrenic angle & 0.205673  \\
#  right hemidiaphragm      & 0.412735  \\
#  left lung                & 0.632739  \\
#  left upper lung zone     & 0.390948  \\
#  left mid lung zone       & 0.371296  \\
#  left lower lung zone     & 0.448535  \\
#  left hilar structures    & 0.215562  \\
#  left apical zone         & 0.33595   \\
#  left costophrenic angle  & 0.115988  \\
#  left hemidiaphragm       & 0.319295  \\
#  trachea                  & 0.459987  \\
#  right clavicle           & 0.322351  \\
#  left clavicle            & 0.39022   \\
#  aortic arch              & 0.253848  \\
#  upper mediastinum        & 0.499828  \\
#  svc                      & 0.224354  \\
#  cardiac silhouette       & 0.62513   \\
#  cavoatrial junction      & 0.140355  \\
#  right atrium             & 0.262303  \\
#  carina                   & 0.0312701 \\
# \hline
# \end{tabular}
# Saving metrics to file ...
# mean_iou = 0.4038836245627727
# Saved metrics to /mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20240618_175951_mscxr+chst-img-anat+vinbig+chexloc_PhraseGrounder(dn121,SigmoidAttention,128,256,256,1)/chest_imagenome_gold_metrics.pkl

# %%
tmp1 = load_pickle('/mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20240618_175951_mscxr+chst-img-anat+vinbig+chexloc_PhraseGrounder(dn121,SigmoidAttention,128,256,256,1)/chest_imagenome_gold_metrics.pkl')

# %%
tmp = tmp1

# %%
tmp.keys()
# Out:
# dict_keys(['image_paths', 'phrases', 'pred_masks', 'gt_masks', 'ious', 'segmask_iou'])

# %%
plot_metrics(
    metric_names=CHEST_IMAGENOME_GOLD_BBOX_NAMES__SORTED,
    metric_values=tmp['segmask_iou'],
    title='Chest ImaGenome Gold - Attention Map IoU',
    ylabel='Bbox class',
    xlabel='IOU',
    horizontal=True,
    sort_metrics=True,
    show_metrics_above_bars=True,
    draw_grid=True,
    figsize=(12, 8),
    append_average_to_title=True,
)

# %%
from medvqa.evaluation.plots import visualize_attention_maps

# %%
idxs = np.argsort(tmp['ious'])[::-1]

# %%
idx = idxs[-202]
print(tmp['ious'][idx])
print()
print(tmp['image_paths'][idx])
print()
print(tmp['phrases'][idx])
# Out:
# 0.014287461526691914
#
# /mnt/workspace/mimic-cxr-jpg/images-medium(512)/p12/p12844682/s54793393/fece80c0-7765caaf-cb169392-b913ef1e-f9769175.jpg
#
# left costophrenic angle

# %%
visualize_attention_maps(
    image_path=tmp['image_paths'][idx],
    figsize=(10,10),
    attention_factor=0.5,
    attention_maps=[
        tmp['gt_masks'][idx].reshape(13,13),
        tmp['pred_masks'][idx].reshape(13,13),
    ],
    titles=[
        f"{tmp['phrases'][idx]} (gt)",
        f"{tmp['phrases'][idx]} (pred)",
    ],
)

# %% [markdown]
# # 2) Phrase Grounding: DenseNet121 + CXRFE + Transformer Encoder

# %%
# !python ../eval_phrase_grounding.py \
--checkpoint_folder_path "/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240618_093614_mscxr+chst-img-anat+vinbig+chexloc_PhraseGrounder(dn121,TransformerEncoder,128,256,4,512,3)" \
--max_images_per_batch 100 \
--max_phrases_per_batch 2000 \
--max_phrases_per_image 30 \
--eval_chest_imagenome_gold
# Out:
# script's arguments:
#    checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240618_093614_mscxr+chst-img-anat+vinbig+chexloc_PhraseGrounder(dn121,TransformerEncoder,128,256,4,512,3)
#    max_images_per_batch: 100
#    max_phrases_per_batch: 2000
#    max_phrases_per_image: 30
#    num_workers: 0
#    device: GPU
#    mscxr_phrase2embedding_filepath: None
#    eval_chest_imagenome_gold: True
#    eval_mscxr: False
# ----- Evaluating model -----
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240618_093614_mscxr+chst-img-anat+vinbig+chexloc_PhraseGrounder(dn121,TransformerEncoder,128,256,4,512,3)/metadata.json
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Creating instance of PhraseGrounder ...
# WARNING: Unused kwargs: {'pretrained_checkpoint_folder_path': '/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240505_224220_mim-facts+vinbig+chexloc+chxp_PhraseGrounder(dn121,128,256)/', 'pretrained_checkpoint_folder_paths': None}
# MultiPurposeVisualModule()
#   Initializing raw_image_encoder: densenet-121
# create_densenet121_feature_extractor()
#    drop_rate: 0.0
# DenseNet121's pretrained weights loaded from ImageNet
#   self.global_feat_size = 2048
#   self.local_feat_size = 1024
#   Initializing auxiliary tasks
# checkpoint_names = ['checkpoint_152_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.6493.pt', 'checkpoint_99_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.6363.pt']
# --------------------------------------------------
# 3) Loading model from checkpoint ...
# checkpoint_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240618_093614_mscxr+chst-img-anat+vinbig+chexloc_PhraseGrounder(dn121,TransformerEncoder,128,256,4,512,3)/checkpoint_152_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.6493.pt
# Loading model and epoch only
# Checkpoint successfully loaded!
# --------------------------------------------------
# 4) Creating MIMIC-CXR Phrase Grounding Trainer ...
# get_image_transform()
# Using standard transform
# mean = (0.485, 0.456, 0.406), std = (0.229, 0.224, 0.225), image_size = [416, 416], use_center_crop = False
# Returning transform without augmentation
# mask_exponent = 0.4
# len(forbidden_train_dicom_ids) = 2030
# Preparing Chest Imagenome dataset and dataloader for testing...
# Loding bbox_phrase_embeddings and bbox_phrases from /mnt/workspace/pamessina/medvqa-workspace/cache/chest_imagenome/bbox_phrase_embeddings(hash=333,2614535641242304201).pkl...
# bbox_phrase_embeddings.shape = (26, 128)
# len(bbox_phrases) = 26
# 	 right lung
# 	 right upper lung zone
# 	 right mid lung zone
# 	 right lower lung zone
# 	 right hilar structures
# 	 right apical zone
# 	 right costophrenic angle
# 	 right hemidiaphragm
# 	 left lung
# 	 left upper lung zone
# 	 left mid lung zone
# 	 left lower lung zone
# 	 left hilar structures
# 	 left apical zone
# 	 left costophrenic angle
# 	 left hemidiaphragm
# 	 trachea
# 	 right clavicle
# 	 left clavicle
# 	 aortic arch
# 	 upper mediastinum
# 	 svc
# 	 cardiac silhouette
# 	 cavoatrial junction
# 	 right atrium
# 	 carina
# Using image size mode: medium_512
# 227835it [00:02, 93464.22it/s]
# Total number of images: 1000
# --------------------------------------------------
# 5) ----- Evaluating on Chest ImaGenome Gold Bbox Phrase Grounding -----
# Creating evaluation engine ...
# binary_loss_kwargs: {'focal_weight': 1.0, 'bce_weight': 1.0, 'wbce_weight': 1.0}
# Focal_BCE_WBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 wbce_weight = 0.3333333333333333
# Focal_BCE_Loss(): focal_weight = 0.5 bce_weight = 0.5
# Focal_BCE_WBCBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 wbcbce_weight = 0.3333333333333333
# foreground_loss_weight: 1.0
# background_loss_weight: 1.0
# Defining log_metrics_handler ...
# Running engine ...
# segmask_iou 0.09407, 15.66 secs
# Final metrics:
# segmask_iou:
# \begin{tabular}{lr}
# \hline
#  bbox_name                &        iou \\
# \hline
#  right lung               & 0.172974   \\
#  right upper lung zone    & 0.066365   \\
#  right mid lung zone      & 0.0786255  \\
#  right lower lung zone    & 0.123944   \\
#  right hilar structures   & 0.0974364  \\
#  right apical zone        & 0.0368345  \\
#  right costophrenic angle & 0.00816199 \\
#  right hemidiaphragm      & 0.101608   \\
#  left lung                & 0.217852   \\
#  left upper lung zone     & 0.0592429  \\
#  left mid lung zone       & 0.0965148  \\
#  left lower lung zone     & 0.191419   \\
#  left hilar structures    & 0.108993   \\
#  left apical zone         & 0.0340596  \\
#  left costophrenic angle  & 0.0163887  \\
#  left hemidiaphragm       & 0.120728   \\
#  trachea                  & 0.113413   \\
#  right clavicle           & 0.0284187  \\
#  left clavicle            & 0.0281303  \\
#  aortic arch              & 0.0353277  \\
#  upper mediastinum        & 0.12999    \\
#  svc                      & 0.0704256  \\
#  cardiac silhouette       & 0.312553   \\
#  cavoatrial junction      & 0.0669663  \\
#  right atrium             & 0.107832   \\
#  carina                   & 0.0216372  \\
# \hline
# \end{tabular}
# Saving metrics to file ...
# mean_iou = 0.10864106772046717
# Saved metrics to /mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20240618_093614_mscxr+chst-img-anat+vinbig+chexloc_PhraseGrounder(dn121,TransformerEncoder,128,256,4,512,3)/chest_imagenome_gold_metrics.pkl

# %%
tmp2 = load_pickle('/mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20240618_093614_mscxr+chst-img-anat+vinbig+chexloc_PhraseGrounder(dn121,TransformerEncoder,128,256,4,512,3)/chest_imagenome_gold_metrics.pkl')

# %%
tmp = tmp2

# %%
tmp.keys()
# Out:
# dict_keys(['image_paths', 'phrases', 'pred_masks', 'gt_masks', 'ious', 'segmask_iou'])

# %%
plot_metrics(
    metric_names=CHEST_IMAGENOME_GOLD_BBOX_NAMES__SORTED,
    metric_values=tmp['segmask_iou'],
    title='Chest ImaGenome Gold - Attention Map IoU',
    ylabel='Bbox class',
    xlabel='IOU',
    horizontal=True,
    sort_metrics=True,
    show_metrics_above_bars=True,
    draw_grid=True,
    figsize=(12, 8),
    append_average_to_title=True,
)

# %%
idxs = np.argsort(tmp['ious'])[::-1]

# %%
idx = idxs[-100]
print(tmp['ious'][idx])
print()
print(tmp['image_paths'][idx])
print()
print(tmp['phrases'][idx])
# Out:
# 8.083510329015553e-05
#
# /mnt/workspace/mimic-cxr-jpg/images-medium(512)/p16/p16141064/s54088587/a09cc2cb-d5300b7b-d92217b5-1e6e5149-34580368.jpg
#
# left costophrenic angle

# %%
visualize_attention_maps(
    image_path=tmp['image_paths'][idx],
    figsize=(10,10),
    attention_factor=0.5,
    attention_maps=[
        tmp['gt_masks'][idx].reshape(13,13),
        tmp['pred_masks'][idx].reshape(13,13),
    ],
    titles=[
        f"{tmp['phrases'][idx]} (gt)",
        f"{tmp['phrases'][idx]} (pred)",
    ],
)
