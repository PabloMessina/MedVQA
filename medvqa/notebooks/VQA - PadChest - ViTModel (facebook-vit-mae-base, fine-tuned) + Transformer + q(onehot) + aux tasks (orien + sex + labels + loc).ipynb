# %%
# %env CUDA_VISIBLE_DEVICES=0
# Out:
# env: CUDA_VISIBLE_DEVICES=0

# %%
# !ls -lh /mnt/data/pamessina/workspaces/medvqa-workspace/models/mae/20221228_105757_padchest_VitMAE/checkpoint_60_loss=0.9791.pt
# Out:
# -rw-rw-r-- 1 pamessina pamessina 1.3G Dec 28 12:05 '/mnt/data/pamessina/workspaces/medvqa-workspace/models/mae/20221228_105757_padchest_VitMAE/checkpoint_60_loss=0.9791.pt'

# %%
# !python ../train_vqa.py \
        --epochs 60 \
        --batches-per-epoch 300 \
        --batch-size 55 \
        --iters-to-accumulate 5 \
        --num-workers 3 \
        --optimizer-name "adamw" \
        --scheduler "warmup+decay" \
        --lr 1e-6 \
        --warmup-and-decay-args "1e-6,5,2e-4,55,1e-6" \
        --use-padchest \
        --padchest-use-validation \
        --padchest-weight 1 \
        --padchest-train-study-ids-path "/mnt/data/pamessina/workspaces/medvqa-workspace/cache/padchest/train_study_ids_20221226_161248.txt" \
        --padchest-val-study-ids-path "/mnt/data/pamessina/workspaces/medvqa-workspace/cache/padchest/val_study_ids_20221226_161248.txt" \
        --padchest-test-study-ids-path "/mnt/data/pamessina/workspaces/medvqa-workspace/cache/padchest/test_study_ids_20221226_161248.txt" \
        --classify-orientation \
        --raw-image-encoding "vitmodel-huggingface" \
        --huggingface-model-name "facebook/vit-mae-base" \
        --image-size 224 224 \
        --image-local-feat-size 768 \
        --image-encoder-pretrained-weights-path "/mnt/data/pamessina/workspaces/medvqa-workspace/models/mae/20221228_105757_padchest_VitMAE/checkpoint_60_loss=0.9791.pt" \
        --question-encoding "one-hot" \
        --answer-decoding "transformer" \
        --binary-loss-name "wbce-c" \
        --use-amp \
        --save
# Out:
# script's arguments:
#    epochs: 60
#    batches_per_epoch: 300
#    checkpoint_folder: None
#    iuxray_qa_adapted_reports_filename: None
#    mimiccxr_qa_adapted_reports_filename: None
#    vocab_min_freq: 10
#    embed_size: 256
#    question_encoding: one-hot
#    answer_decoding: transformer
#    question_hidden_size: 128
#    answer_hidden_size: 256
#    visual_input_mode: raw-image
#    raw_image_encoding: vitmodel-huggingface
#    image_local_feat_size: 768
#    image_encoder_pretrained_weights_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/mae/20221228_105757_padchest_VitMAE/checkpoint_60_loss=0.9791.pt
#    freeze_image_encoder: False
#    imagenet_pretrained: False
#    visual_features_mlp_in_dim: None
#    visual_features_mlp_out_dim: None
#    visual_features_mlp_hidden_dims: None
#    iuxray_precomputed_visual_features_path: None
#    mimiccxr_precomputed_visual_features_path: None
#    chexpert_precomputed_visual_features_path: None
#    vinbig_precomputed_visual_features_path: None
#    clip_version: None
#    huggingface_model_name: facebook/vit-mae-base
#    n_lstm_layers: 1
#    transf_dec_nhead: 2
#    transf_dec_dim_forward: 256
#    transf_dec_num_layers: 2
#    question_vec_size: 128
#    dropout_prob: 0
#    optimizer_name: adamw
#    lr: 1e-06
#    scheduler: warmup+decay
#    lr_decay: 0.76
#    lr_decay_patience: 2
#    warmup_and_decay_args: 1e-6,5,2e-4,55,1e-6
#    warmup_and_cosine_args: None
#    n_val_examples_per_question: 10
#    min_train_examples_per_question: 100
#    batch_size: 55
#    iters_to_accumulate: 5
#    num_workers: 3
#    device: GPU
#    img_aug_mode: None
#    image_size: [224, 224]
#    mimiccxr_weight: 1
#    chexpert_weight: 0.3
#    cxr14_weight: 0.3
#    vinbig_weight: 0.3
#    iuxray_weight: 0.05
#    mimiccxr_weight_chexpert_mode: 0.2
#    iuxray_weight_chexpert_mode: 0.05
#    padchest_weight: 1.0
#    mimiccxr_include_chexpert_mode: False
#    iuxray_include_chexpert_mode: False
#    use_chexpert_mode_only: False
#    val_answer_decoding: greedy-search
#    beam_search_k: None
#    use_amp: True
#    medical_tokenization: False
#    medical_terms_frequency_filename: None
#    allowed_questions: None
#    pretrained_checkpoint_folder_path: None
#    balanced_split: False
#    balanced_dataloading: False
#    imbalance_reduction_coef: 0.5
#    n_healthy_per_question: 2
#    n_unhealthy_per_question: 3
#    n_positive_per_chexpert_label: 7
#    min_question_count: 100
#    iuxray_balanced_metadata_filename: None
#    mimiccxr_balanced_metadata_filename: None
#    one_question_per_batch: False
#    save: True
#    override_lr: False
#    train_mimiccxr: False
#    train_iuxray: False
#    iuxray_train_with_all: False
#    train_chexpert: False
#    chexpert_mode: None
#    train_cxr14: False
#    train_vinbig: False
#    vinbig_training_data: all
#    vinbig_use_validation: False
#    train_padchest: True
#    padchest_training_data_mode: all
#    padchest_use_validation: True
#    padchest_train_study_ids_path: /mnt/data/pamessina/workspaces/medvqa-workspace/cache/padchest/train_study_ids_20221226_161248.txt
#    padchest_val_study_ids_path: /mnt/data/pamessina/workspaces/medvqa-workspace/cache/padchest/val_study_ids_20221226_161248.txt
#    padchest_test_study_ids_path: /mnt/data/pamessina/workspaces/medvqa-workspace/cache/padchest/test_study_ids_20221226_161248.txt
#    binary_loss_name: wbce-c
#    classify_tags: False
#    n_medical_tags: None
#    iuxray_medical_tags_per_report_filename: None
#    mimiccxr_medical_tags_per_report_filename: None
#    classify_orientation: True
#    classify_chexpert: False
#    iuxray_chexpert_labels_filename: None
#    mimiccxr_chexpert_labels_filename: None
#    classify_questions: False
#    n_questions: None
#    iuxray_question_labels_filename: None
#    mimiccxr_question_labels_filename: None
#    merge_findings: False
# ----- Training model from scratch ------
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Initializing tokenizer ...
# Loading /mnt/data/pamessina/workspaces/medvqa-workspace/cache/vocab(_mnt_data_padchest_PADCHEST_chest_x_ray_images_labels_160K_01.02.19.csv).pkl ...
# --------------------------------------------------
# 3) Creating instance of OpenEndedVQA model ...
# OpenEndedVQA():
#   image_encoder_pretrained_weights_path /mnt/data/pamessina/workspaces/medvqa-workspace/models/mae/20221228_105757_padchest_VitMAE/checkpoint_60_loss=0.9791.pt
# You are using a model of type vit_mae to instantiate a model of type vit. This is not supported for all configurations of models and can yield errors.
# Some weights of the model checkpoint at facebook/vit-mae-base were not used when initializing ViTModel: ['decoder.decoder_layers.1.attention.attention.key.weight', 'decoder.decoder_layers.1.attention.attention.key.bias', 'decoder.decoder_layers.7.intermediate.dense.bias', 'decoder.decoder_layers.1.layernorm_before.weight', 'decoder.decoder_layers.3.attention.attention.key.bias', 'decoder.decoder_layers.7.layernorm_after.weight', 'decoder.decoder_layers.4.intermediate.dense.weight', 'decoder.decoder_layers.5.layernorm_before.weight', 'decoder.decoder_norm.weight', 'decoder.decoder_layers.7.attention.attention.value.weight', 'decoder.decoder_layers.5.intermediate.dense.weight', 'decoder.decoder_layers.0.attention.attention.key.bias', 'decoder.decoder_layers.0.attention.attention.value.bias', 'decoder.decoder_layers.2.layernorm_after.bias', 'decoder.decoder_layers.1.layernorm_after.bias', 'decoder.decoder_layers.2.output.dense.bias', 'decoder.decoder_layers.0.layernorm_after.bias', 'decoder.decoder_layers.0.output.dense.bias', 'decoder.decoder_layers.2.attention.attention.key.weight', 'decoder.decoder_layers.3.attention.attention.value.bias', 'decoder.decoder_layers.7.attention.attention.query.bias', 'decoder.decoder_layers.1.output.dense.weight', 'decoder.decoder_layers.3.attention.output.dense.bias', 'decoder.decoder_layers.4.layernorm_after.weight', 'decoder.decoder_layers.6.attention.attention.key.weight', 'decoder.decoder_layers.5.attention.output.dense.weight', 'decoder.decoder_layers.3.attention.attention.value.weight', 'decoder.decoder_layers.0.attention.attention.value.weight', 'decoder.decoder_layers.7.attention.attention.key.weight', 'decoder.decoder_layers.0.attention.attention.query.bias', 'decoder.decoder_layers.7.output.dense.weight', 'decoder.decoder_layers.3.layernorm_before.bias', 'decoder.decoder_pos_embed', 'decoder.decoder_layers.4.layernorm_before.bias', 'decoder.decoder_layers.2.attention.attention.value.bias', 'decoder.decoder_layers.6.output.dense.bias', 'decoder.decoder_layers.7.layernorm_before.weight', 'decoder.decoder_layers.1.attention.attention.query.bias', 'decoder.decoder_layers.0.layernorm_after.weight', 'decoder.decoder_layers.7.layernorm_after.bias', 'decoder.decoder_layers.4.output.dense.bias', 'decoder.decoder_embed.bias', 'decoder.decoder_layers.4.attention.attention.query.bias', 'decoder.decoder_layers.4.attention.output.dense.bias', 'decoder.decoder_layers.2.layernorm_before.weight', 'decoder.decoder_layers.4.attention.attention.value.bias', 'decoder.decoder_layers.2.intermediate.dense.weight', 'decoder.decoder_layers.1.attention.attention.query.weight', 'decoder.decoder_layers.2.attention.output.dense.bias', 'decoder.decoder_layers.1.attention.attention.value.bias', 'decoder.decoder_layers.6.attention.attention.query.bias', 'decoder.decoder_layers.7.attention.attention.query.weight', 'decoder.decoder_layers.5.intermediate.dense.bias', 'decoder.decoder_layers.3.attention.attention.query.weight', 'decoder.decoder_layers.1.attention.output.dense.bias', 'decoder.decoder_layers.3.attention.output.dense.weight', 'decoder.decoder_layers.4.output.dense.weight', 'decoder.decoder_layers.2.attention.attention.key.bias', 'decoder.decoder_layers.3.intermediate.dense.weight', 'decoder.decoder_layers.4.attention.attention.query.weight', 'decoder.decoder_layers.2.output.dense.weight', 'decoder.decoder_layers.5.output.dense.bias', 'decoder.decoder_layers.2.attention.attention.query.bias', 'decoder.decoder_layers.4.attention.output.dense.weight', 'decoder.decoder_layers.5.attention.attention.query.weight', 'decoder.decoder_layers.6.intermediate.dense.weight', 'decoder.decoder_layers.3.attention.attention.query.bias', 'decoder.decoder_layers.7.attention.output.dense.weight', 'decoder.decoder_layers.0.attention.attention.query.weight', 'decoder.decoder_layers.6.attention.output.dense.weight', 'decoder.decoder_layers.7.attention.attention.key.bias', 'decoder.decoder_layers.3.layernorm_after.weight', 'decoder. ...
# - This IS expected if you are initializing ViTModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing ViTModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of ViTModel were not initialized from the model checkpoint at facebook/vit-mae-base and are newly initialized: ['vit.pooler.dense.bias', 'vit.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Pre-trained weights successfully loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/mae/20221228_105757_padchest_VitMAE/checkpoint_60_loss=0.9791.pt
#   self.global_feat_size = 768
#   n_questions = 196
#   n_questions_aux_task = None
#   question_encoding = one-hot
#   answer_decoding = transformer
#   visual_input_mode = raw-image
#   name = oevqa(facebook/vit-mae-base+onehot+transf)
# --------------------------------------------------
# 4) Defining optimizer ...
# create_optimizer(): name = adamw
# --------------------------------------------------
# 5) Defining scheduler ...
# Using warmup+decay scheduler: 1e-6,5,2e-4,55,1e-6
# 1e-06 5 0.0002 55 1e-06
# Adjusting learning rate of group 0 to 1.0000e-06.
# Adjusting learning rate of group 0 to 1.0000e-06.
# --------------------------------------------------
# 6) Creating trainer and validator engines ...
# get_engine(): shift_answer=True
# get_engine(): shift_answer=False
# --------------------------------------------------
# 7) Defining image transform ...
# Using Huggingface ViT model transform for facebook/vit-mae-base
# mean = (0.485, 0.456, 0.406), std = (0.229, 0.224, 0.225), image_size = (224, 224), use_center_crop = False
# Returning transform without augmentation
# --------------------------------------------------
# 8) Defining collate_batch_fn ...
# get_vqa_collate_batch_fn(): dataset_id=7, one_hot_question_offset=0
# --------------------------------------------------
# 9) Creating PadChest vqa trainer ...
# ../train_vqa.py:1497: DtypeWarning: Columns (19,20) have mixed types.Specify dtype option on import or set low_memory=False.
#   debug=debug)
# Number of rows before filtering: 160861
# Number of rows after filtering: 160754 (dropped nan rows)
# Number of rows after filtering: 160741 (dropped study ids not in all_study_ids_set)
# Number of rows after filtering: 160723 (dropped rows with unexpected PatientSex_DICOM)
# Number of rows after filtering: 160704 (dropped rows with unexpected Projection)
# Number of rows after filtering: 160692 (dropped rows with broken images)
# Number of rows after filtering: 109821 (dropped rows with duplicate StudyID)
# Number of labels: 193
# Number of localizations: 104
# Generating answers based on labels...
# 100%|███████████████████████████████| 109821/109821 [00:01<00:00, 104858.17it/s]
# Done. Example answer: <s> normal </s>
# Generating answers based on localizations...
# 100%|███████████████████████████████| 109821/109821 [00:01<00:00, 109606.22it/s]
# Done. Example answer: <s> loc bilateral , loc diffuse bilateral , loc perihilar </s>
# Number of non-empty answers: 63528
# Generating answers based on labels localizations by sentence...
# 100%|████████████████████████████████| 109821/109821 [00:01<00:00, 61616.30it/s]
# Done. Example answer: <s> normal , unchanged </s>
# Creating dataset and dataloader...
# Example of positive localization answer: <s> loc middle lung field , loc right , loc cardiac , loc lobar , loc aortic , loc lung field </s>
# Example of negative localization answer: <s> </s>
# 193it [00:30,  6.29it/s]
# Done!
# len(self.train_dataset) = 1000000000000000000
# Creating dataset and dataloader...
# Example of positive localization answer: <s> loc rib , loc right </s>
# Example of negative localization answer: <s> </s>
# 193it [00:00, 216.43it/s]
# Done!
# len(self.val_dataset) = 4398
# --------------------------------------------------
# 10) Creating dataloaders ...
# len(_train_dataloaders) = 1
# len(_val_dataloaders) = 1
# _train_weights = [1.0]
# merged_dataset_name = padchest(vqa)
# --------------------------------------------------
# 11) Attaching metrics, losses, timer and events to engines ...
# --------------------------------------------------
# 12) Defining learning rate scheduler handler ...
# --------------------------------------------------
# 13) Defining checkpoint folder path ...
# checkpoint_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/vqa/20221228_131234_padchest(vqa)_oevqa(facebook-vit-mae-base+onehot+transf)_visenc-pretr=1_orien_amp
# metadata saved to /mnt/data/pamessina/workspaces/medvqa-workspace/models/vqa/20221228_131234_padchest(vqa)_oevqa(facebook-vit-mae-base+onehot+transf)_visenc-pretr=1_orien_amp/metadata.json
# --------------------------------------------------
# 14) Defining log_metrics_handler ...
# MetricsLogger :: we'll be logging to /mnt/data/pamessina/workspaces/medvqa-workspace/models/vqa/20221228_131234_padchest(vqa)_oevqa(facebook-vit-mae-base+onehot+transf)_visenc-pretr=1_orien_amp/metrics_logs.csv
# --------------------------------------------------
# 15) Running trainer engine ...
# ---- Epoch 1/60
# (1) Training stage (lr = 0.000001) ...
# loss 12.24913, a_loss 8.12948, ema 0.00000, oracc 0.60715, orien_loss 1.48750, gacc 0.51685, gloss 0.69276, b1 0.00098, b2 0.00000, b3 0.00000, b4 0.00000, padchxlmacf1 0.01245, padchxlmicf1 0.01139, padchxlzmacf1 0.02273, padchxlzmicf1 0.02276, padchxl_loss 0.84783, padchxlz_loss 0.89944, 101.04 secs
# (2) Validation stage ...
# ema 0.00000, oracc 0.80559, gacc 0.52842, b1 0.00426, b2 0.00000, b3 0.00000, b4 0.00000, padchxlmacf1 0.01725, padchxlmicf1 0.01777, padchxlzmacf1 0.02879, padchxlzmicf1 0.02773, 22.93 secs
# Adjusting learning rate of group 0 to 2.8854e-06.
# ---- Epoch 2/60
# (1) Training stage (lr = 0.000003) ...
# loss 11.78271, a_loss 7.85192, ema 0.00000, oracc 0.81158, orien_loss 0.91620, gacc 0.52776, gloss 0.68938, b1 0.01920, b2 0.00042, b3 0.00000, b4 0.00000, padchxlmacf1 0.01516, padchxlmicf1 0.01472, padchxlzmacf1 0.02384, padchxlzmicf1 0.02620, padchxl_loss 0.83432, padchxlz_loss 0.88339, 100.41 secs
# (2) Validation stage ...
# ema 0.00000, oracc 0.80559, gacc 0.62119, b1 0.04943, b2 0.00000, b3 0.00000, b4 0.00000, padchxlmacf1 0.01952, padchxlmicf1 0.02219, padchxlzmacf1 0.03001, padchxlzmicf1 0.03727, 23.11 secs
# Adjusting learning rate of group 0 to 8.3255e-06.
# ---- Epoch 3/60
# (1) Training stage (lr = 0.000008) ...
# loss 10.44176, a_loss 6.91446, ema 0.00321, oracc 0.88364, orien_loss 0.40029, gacc 0.71012, gloss 0.61820, b1 0.04152, b2 0.00109, b3 0.00028, b4 0.00000, padchxlmacf1 0.01734, padchxlmicf1 0.02133, padchxlzmacf1 0.02321, padchxlzmicf1 0.02432, padchxl_loss 0.78670, padchxlz_loss 0.83541, 98.18 secs
# (2) Validation stage ...
# ema 0.00000, oracc 0.93065, gacc 0.82378, b1 0.00126, b2 0.00000, b3 0.00000, b4 0.00000, padchxlmacf1 0.01814, padchxlmicf1 0.02839, padchxlzmacf1 0.03098, padchxlzmicf1 0.03305, 23.95 secs
# Adjusting learning rate of group 0 to 2.4022e-05.
# ---- Epoch 4/60
# (1) Training stage (lr = 0.000024) ...
# loss 9.00364, a_loss 5.70124, ema 0.08061, oracc 0.93545, orien_loss 0.24000, gacc 0.83170, gloss 0.37847, b1 0.00001, b2 0.00000, b3 0.00000, b4 0.00000, padchxlmacf1 0.01941, padchxlmicf1 0.05499, padchxlzmacf1 0.03933, padchxlzmicf1 0.06816, padchxl_loss 0.65963, padchxlz_loss 0.72242, 95.67 secs
# (2) Validation stage ...
# ema 0.07026, oracc 0.93611, gacc 0.88063, b1 0.00000, b2 0.00000, b3 0.00000, b4 0.00000, padchxlmacf1 0.02123, padchxlmicf1 0.08059, padchxlzmacf1 0.04038, padchxlzmicf1 0.09519, 22.18 secs
# Adjusting learning rate of group 0 to 6.9314e-05.
# ---- Epoch 5/60
# (1) Training stage (lr = 0.000069) ...
# loss 6.84314, a_loss 4.51818, ema 0.05885, oracc 0.95188, orien_loss 0.16454, gacc 0.91194, gloss 0.21767, b1 0.00066, b2 0.00052, b3 0.00020, b4 0.00010, padchxlmacf1 0.02442, padchxlmicf1 0.09823, padchxlzmacf1 0.04179, padchxlzmicf1 0.09373, padchxl_loss 0.50559, padchxlz_loss 0.60427, 95.45 secs
# (2) Validation stage ...
# ema 0.06344, oracc 0.96157, gacc 0.93088, b1 0.09529, b2 0.04719, b3 0.02298, b4 0.01311, padchxlmacf1 0.02830, padchxlmicf1 0.09177, padchxlzmacf1 0.04656, padchxlzmicf1 0.10221, 22.94 secs
# Adjusting learning rate of group 0 to 2.0000e-04.
# ---- Epoch 6/60
# (1) Training stage (lr = 0.000200) ...
# loss 4.99369, a_loss 3.26844, ema 0.16418, oracc 0.90115, orien_loss 0.33848, gacc 0.83970, gloss 0.34390, b1 0.07371, b2 0.05254, b3 0.03527, b4 0.02527, padchxlmacf1 0.02499, padchxlmicf1 0.08334, padchxlzmacf1 0.03983, padchxlzmicf1 0.09459, padchxl_loss 0.46671, padchxlz_loss 0.59173, 96.24 secs
# (2) Validation stage ...
# ema 0.23852, oracc 0.94156, gacc 0.91792, b1 0.00701, b2 0.00467, b3 0.00301, b4 0.00212, padchxlmacf1 0.02986, padchxlmicf1 0.09067, padchxlzmacf1 0.04693, padchxlzmicf1 0.09948, 22.04 secs
# Adjusting learning rate of group 0 to 1.8163e-04.
# ---- Epoch 7/60
# (1) Training stage (lr = 0.000182) ...
# loss 4.09434, a_loss 2.43407, ema 0.35618, oracc 0.95715, orien_loss 0.14213, gacc 0.93606, gloss 0.15728, b1 0.24824, b2 0.16287, b3 0.10369, b4 0.06921, padchxlmacf1 0.02909, padchxlmicf1 0.10482, padchxlzmacf1 0.04834, padchxlzmicf1 0.10252, padchxl_loss 0.44107, padchxlz_loss 0.56183, 96.48 secs
# (2) Validation stage ...
# ema 0.33402, oracc 0.96976, gacc 0.94134, b1 0.18923, b2 0.12707, b3 0.07247, b4 0.04700, padchxlmacf1 0.03338, padchxlmicf1 0.09991, padchxlzmacf1 0.05155, padchxlzmicf1 0.14015, 22.70 secs
# Adjusting learning rate of group 0 to 1.6495e-04.
# ---- Epoch 8/60
# (1) Training stage (lr = 0.000165) ...
# loss 3.99530, a_loss 2.03939, ema 0.36994, oracc 0.96994, orien_loss 0.10641, gacc 0.94412, gloss 0.13868, b1 0.37245, b2 0.26237, b3 0.17970, b4 0.12726, padchxlmacf1 0.03324, padchxlmicf1 0.12185, padchxlzmacf1 0.05185, padchxlzmicf1 0.11655, padchxl_loss 0.42728, padchxlz_loss 0.55575, 95.96 secs
# (2) Validation stage ...
# ema 0.32970, oracc 0.96498, gacc 0.93997, b1 0.17767, b2 0.12610, b3 0.07827, b4 0.05356, padchxlmacf1 0.03855, padchxlmicf1 0.12045, padchxlzmacf1 0.06307, padchxlzmicf1 0.15045, 22.17 secs
# Adjusting learning rate of group 0 to 1.4980e-04.
# ---- Epoch 9/60
# (1) Training stage (lr = 0.000150) ...
# loss 2.92753, a_loss 1.87956, ema 0.36927, oracc 0.97212, orien_loss 0.09838, gacc 0.95042, gloss 0.12392, b1 0.41577, b2 0.29742, b3 0.20662, b4 0.14756, padchxlmacf1 0.03870, padchxlmicf1 0.12940, padchxlzmacf1 0.05919, padchxlzmicf1 0.13875, padchxl_loss 0.40918, padchxlz_loss 0.52963, 96.53 secs
# (2) Validation stage ...
# ema 0.32856, oracc 0.96430, gacc 0.94998, b1 0.22769, b2 0.16399, b3 0.11171, b4 0.08103, padchxlmacf1 0.04779, padchxlmicf1 0.11899, padchxlzmacf1 0.06852, padchxlzmicf1 0.14891, 22.40 secs
# Adjusting learning rate of group 0 to 1.3604e-04.
# ---- Epoch 10/60
# (1) Training stage (lr = 0.000136) ...
# loss 2.60248, a_loss 1.77774, ema 0.36776, oracc 0.97176, orien_loss 0.09548, gacc 0.95455, gloss 0.11036, b1 0.43968, b2 0.31770, b3 0.22363, b4 0.15993, padchxlmacf1 0.04307, padchxlmicf1 0.12824, padchxlzmacf1 0.06124, padchxlzmicf1 0.14144, padchxl_loss 0.40353, padchxlz_loss 0.53418, 95.94 secs
# (2) Validation stage ...
# ema 0.33106, oracc 0.97271, gacc 0.95975, b1 0.17320, b2 0.13258, b3 0.09702, b4 0.07409, padchxlmacf1 0.04866, padchxlmicf1 0.12355, padchxlzmacf1 0.06718, padchxlzmicf1 0.16632, 22.24 secs
# Adjusting learning rate of group 0 to 1.2355e-04.
# ---- Epoch 11/60
# (1) Training stage (lr = 0.000124) ...
# loss 2.90719, a_loss 1.72518, ema 0.36182, oracc 0.97709, orien_loss 0.08065, gacc 0.96152, gloss 0.09831, b1 0.45651, b2 0.33532, b3 0.24128, b4 0.17621, padchxlmacf1 0.04604, padchxlmicf1 0.12976, padchxlzmacf1 0.06405, padchxlzmicf1 0.14362, padchxl_loss 0.39741, padchxlz_loss 0.52955, 97.21 secs
# (2) Validation stage ...
# ema 0.34607, oracc 0.97704, gacc 0.96135, b1 0.22038, b2 0.16084, b3 0.11837, b4 0.09056, padchxlmacf1 0.05102, padchxlmicf1 0.13359, padchxlzmacf1 0.07352, padchxlzmicf1 0.16365, 22.40 secs
# Adjusting learning rate of group 0 to 1.1220e-04.
# ---- Epoch 12/60
# (1) Training stage (lr = 0.000112) ...
# loss 2.88442, a_loss 1.66344, ema 0.36794, oracc 0.97661, orien_loss 0.08663, gacc 0.96479, gloss 0.09055, b1 0.46258, b2 0.34411, b3 0.25194, b4 0.18729, padchxlmacf1 0.04764, padchxlmicf1 0.13419, padchxlzmacf1 0.06601, padchxlzmicf1 0.14587, padchxl_loss 0.39049, padchxlz_loss 0.52893, 96.09 secs
# (2) Validation stage ...
# ema 0.34516, oracc 0.98090, gacc 0.97385, b1 0.26849, b2 0.19588, b3 0.14629, b4 0.11253, padchxlmacf1 0.05406, padchxlmicf1 0.13356, padchxlzmacf1 0.07477, padchxlzmicf1 0.15955, 22.56 secs
# Adjusting learning rate of group 0 to 1.0190e-04.
# ---- Epoch 13/60
# (1) Training stage (lr = 0.000102) ...
# loss 2.79965, a_loss 1.61686, ema 0.36824, oracc 0.97897, orien_loss 0.07472, gacc 0.96261, gloss 0.08996, b1 0.47413, b2 0.35444, b3 0.25939, b4 0.19038, padchxlmacf1 0.04709, padchxlmicf1 0.13010, padchxlzmacf1 0.06489, padchxlzmicf1 0.14055, padchxl_loss 0.38980, padchxlz_loss 0.53095, 96.23 secs
# (2) Validation stage ...
# ema 0.33606, oracc 0.98249, gacc 0.97385, b1 0.27567, b2 0.19950, b3 0.14802, b4 0.11145, padchxlmacf1 0.05427, padchxlmicf1 0.13280, padchxlzmacf1 0.07411, padchxlzmicf1 0.16276, 22.92 secs
# Adjusting learning rate of group 0 to 9.2541e-05.
# ---- Epoch 14/60
# (1) Training stage (lr = 0.000093) ...
# loss 2.51222, a_loss 1.58979, ema 0.37455, oracc 0.97939, orien_loss 0.06873, gacc 0.97055, gloss 0.07783, b1 0.48195, b2 0.36081, b3 0.26498, b4 0.19536, padchxlmacf1 0.04887, padchxlmicf1 0.13320, padchxlzmacf1 0.06417, padchxlzmicf1 0.14150, padchxl_loss 0.38544, padchxlz_loss 0.52107, 96.60 secs
# (2) Validation stage ...
# ema 0.35107, oracc 0.98613, gacc 0.96021, b1 0.21754, b2 0.16371, b3 0.12709, b4 0.10068, padchxlmacf1 0.05559, padchxlmicf1 0.13505, padchxlzmacf1 0.07462, padchxlzmicf1 0.16491, 22.46 secs
# Adjusting learning rate of group 0 to 8.4042e-05.
# ---- Epoch 15/60
# (1) Training stage (lr = 0.000084) ...
# loss 2.75459, a_loss 1.55366, ema 0.37352, oracc 0.98152, orien_loss 0.06651, gacc 0.96691, gloss 0.07382, b1 0.47633, b2 0.36084, b3 0.27025, b4 0.20438, padchxlmacf1 0.04873, padchxlmicf1 0.13291, padchxlzmacf1 0.06641, padchxlzmicf1 0.14729, padchxl_loss 0.38297, padchxlz_loss 0.51648, 96.23 secs
# (2) Validation stage ...
# ema 0.35084, oracc 0.98545, gacc 0.97544, b1 0.23582, b2 0.17460, b3 0.13130, b4 0.10052, padchxlmacf1 0.05778, padchxlmicf1 0.13742, padchxlzmacf1 0.07563, padchxlzmicf1 0.15832, 22.07 secs
# Adjusting learning rate of group 0 to 7.6324e-05.
# ---- Epoch 16/60
# (1) Training stage (lr = 0.000076) ...
# loss 2.45238, a_loss 1.53823, ema 0.37030, oracc 0.98376, orien_loss 0.06116, gacc 0.96958, gloss 0.07549, b1 0.49195, b2 0.37506, b3 0.28124, b4 0.21166, padchxlmacf1 0.05156, padchxlmicf1 0.14164, padchxlzmacf1 0.07200, padchxlzmicf1 0.15022, padchxl_loss 0.37690, padchxlz_loss 0.51446, 96.21 secs
# (2) Validation stage ...
# ema 0.35380, oracc 0.98295, gacc 0.97885, b1 0.18202, b2 0.13200, b3 0.09836, b4 0.07431, padchxlmacf1 0.05792, padchxlmicf1 0.14415, padchxlzmacf1 0.07726, padchxlzmicf1 0.16000, 23.47 secs
# Adjusting learning rate of group 0 to 6.9314e-05.
# ---- Epoch 17/60
# (1) Training stage (lr = 0.000069) ...
# loss 2.67990, a_loss 1.51121, ema 0.37879, oracc 0.98273, orien_loss 0.06230, gacc 0.97588, gloss 0.06378, b1 0.48904, b2 0.37376, b3 0.28046, b4 0.21166, padchxlmacf1 0.05086, padchxlmicf1 0.13695, padchxlzmacf1 0.06940, padchxlzmicf1 0.14736, padchxl_loss 0.37781, padchxlz_loss 0.51219, 96.17 secs
# (2) Validation stage ...
# ema 0.35016, oracc 0.98568, gacc 0.97226, b1 0.25233, b2 0.18400, b3 0.13802, b4 0.10591, padchxlmacf1 0.06070, padchxlmicf1 0.14505, padchxlzmacf1 0.07813, padchxlzmicf1 0.16466, 22.67 secs
# Adjusting learning rate of group 0 to 6.2949e-05.
# ---- Epoch 18/60
# (1) Training stage (lr = 0.000063) ...
# loss 2.62217, a_loss 1.50346, ema 0.37830, oracc 0.98455, orien_loss 0.05609, gacc 0.97473, gloss 0.06676, b1 0.50040, b2 0.38119, b3 0.28391, b4 0.21302, padchxlmacf1 0.05448, padchxlmicf1 0.14305, padchxlzmacf1 0.07160, padchxlzmicf1 0.15215, padchxl_loss 0.37668, padchxlz_loss 0.51012, 97.18 secs
# (2) Validation stage ...
# ema 0.34402, oracc 0.98522, gacc 0.97999, b1 0.29793, b2 0.21652, b3 0.16248, b4 0.12451, padchxlmacf1 0.06364, padchxlmicf1 0.14488, padchxlzmacf1 0.08055, padchxlzmicf1 0.17375, 22.38 secs
# Adjusting learning rate of group 0 to 5.7168e-05.
# ---- Epoch 19/60
# (1) Training stage (lr = 0.000057) ...
# loss 2.89763, a_loss 1.48785, ema 0.37552, oracc 0.98558, orien_loss 0.05709, gacc 0.97642, gloss 0.06434, b1 0.49066, b2 0.37705, b3 0.28476, b4 0.21695, padchxlmacf1 0.05436, padchxlmicf1 0.14124, padchxlzmacf1 0.07171, padchxlzmicf1 0.14897, padchxl_loss 0.37283, padchxlz_loss 0.51297, 96.46 secs
# (2) Validation stage ...
# ema 0.34197, oracc 0.98681, gacc 0.97590, b1 0.31130, b2 0.22747, b3 0.17159, b4 0.13269, padchxlmacf1 0.06310, padchxlmicf1 0.14571, padchxlzmacf1 0.08131, padchxlzmicf1 0.17483, 22.81 secs
# Adjusting learning rate of group 0 to 5.1917e-05.
# ---- Epoch 20/60
# (1) Training stage (lr = 0.000052) ...
# loss 2.42249, a_loss 1.47930, ema 0.38055, oracc 0.98527, orien_loss 0.05898, gacc 0.97624, gloss 0.06530, b1 0.49963, b2 0.38307, b3 0.28818, b4 0.21725, padchxlmacf1 0.05403, padchxlmicf1 0.14237, padchxlzmacf1 0.07280, padchxlzmicf1 0.15059, padchxl_loss 0.37261, padchxlz_loss 0.51479, 96.39 secs
# (2) Validation stage ...
# ema 0.33947, oracc 0.98613, gacc 0.98317, b1 0.28759, b2 0.20614, b3 0.15382, b4 0.11648, padchxlmacf1 0.06555, padchxlmicf1 0.14886, padchxlzmacf1 0.08112, padchxlzmicf1 0.17272, 23.48 secs
# Adjusting learning rate of group 0 to 4.7149e-05.
# ---- Epoch 21/60
# (1) Training stage (lr = 0.000047) ...
# loss 2.25527, a_loss 1.47255, ema 0.37909, oracc 0.98679, orien_loss 0.05028, gacc 0.97764, gloss 0.06485, b1 0.50013, b2 0.38367, b3 0.28894, b4 0.21842, padchxlmacf1 0.05807, padchxlmicf1 0.14618, padchxlzmacf1 0.07560, padchxlzmicf1 0.15138, padchxl_loss 0.36743, padchxlz_loss 0.51423, 96.32 secs
# (2) Validation stage ...
# ema 0.33333, oracc 0.99090, gacc 0.98613, b1 0.32197, b2 0.23226, b3 0.17415, b4 0.13238, padchxlmacf1 0.06748, padchxlmicf1 0.14750, padchxlzmacf1 0.08239, padchxlzmicf1 0.17431, 22.61 secs
# Adjusting learning rate of group 0 to 4.2819e-05.
# ---- Epoch 22/60
# (1) Training stage (lr = 0.000043) ...
# loss 2.37145, a_loss 1.45557, ema 0.38273, oracc 0.98661, orien_loss 0.05081, gacc 0.97927, gloss 0.05891, b1 0.50372, b2 0.38656, b3 0.29196, b4 0.22165, padchxlmacf1 0.05789, padchxlmicf1 0.14501, padchxlzmacf1 0.07680, padchxlzmicf1 0.15324, padchxl_loss 0.36817, padchxlz_loss 0.50804, 97.29 secs
# (2) Validation stage ...
# ema 0.34447, oracc 0.98931, gacc 0.98795, b1 0.30565, b2 0.21966, b3 0.16453, b4 0.12307, padchxlmacf1 0.06941, padchxlmicf1 0.15069, padchxlzmacf1 0.08322, padchxlzmicf1 0.17561, 22.71 secs
# Adjusting learning rate of group 0 to 3.8887e-05.
# ---- Epoch 23/60
# (1) Training stage (lr = 0.000039) ...
# loss 2.40834, a_loss 1.43263, ema 0.38667, oracc 0.98764, orien_loss 0.04750, gacc 0.97903, gloss 0.05922, b1 0.50231, b2 0.38829, b3 0.29380, b4 0.22303, padchxlmacf1 0.05908, padchxlmicf1 0.15108, padchxlzmacf1 0.07836, padchxlzmicf1 0.16075, padchxl_loss 0.36402, padchxlz_loss 0.49686, 96.84 secs
# (2) Validation stage ...
# ema 0.34266, oracc 0.99022, gacc 0.98658, b1 0.32744, b2 0.24209, b3 0.18534, b4 0.14427, padchxlmacf1 0.07041, padchxlmicf1 0.15229, padchxlzmacf1 0.08341, padchxlzmicf1 0.17656, 22.50 secs
# Adjusting learning rate of group 0 to 3.5316e-05.
# ---- Epoch 24/60
# (1) Training stage (lr = 0.000035) ...
# loss 2.14865, a_loss 1.43419, ema 0.37594, oracc 0.99042, orien_loss 0.04240, gacc 0.98133, gloss 0.05303, b1 0.50370, b2 0.39061, b3 0.29759, b4 0.22750, padchxlmacf1 0.06177, padchxlmicf1 0.15204, padchxlzmacf1 0.07672, padchxlzmicf1 0.16090, padchxl_loss 0.36612, padchxlz_loss 0.50205, 96.47 secs
# (2) Validation stage ...
# ema 0.33811, oracc 0.99068, gacc 0.98363, b1 0.29360, b2 0.21222, b3 0.16058, b4 0.12367, padchxlmacf1 0.07466, padchxlmicf1 0.15071, padchxlzmacf1 0.08477, padchxlzmicf1 0.17912, 23.26 secs
# Adjusting learning rate of group 0 to 3.2072e-05.
# ---- Epoch 25/60
# (1) Training stage (lr = 0.000032) ...
# loss 3.04098, a_loss 1.42150, ema 0.38685, oracc 0.98897, orien_loss 0.04550, gacc 0.98115, gloss 0.05205, b1 0.51258, b2 0.39729, b3 0.30350, b4 0.23214, padchxlmacf1 0.05914, padchxlmicf1 0.14960, padchxlzmacf1 0.07595, padchxlzmicf1 0.15580, padchxl_loss 0.36051, padchxlz_loss 0.50098, 96.77 secs
# (2) Validation stage ...
# ema 0.33356, oracc 0.99022, gacc 0.99045, b1 0.32931, b2 0.24185, b3 0.18288, b4 0.13771, padchxlmacf1 0.07486, padchxlmicf1 0.15204, padchxlzmacf1 0.08708, padchxlzmicf1 0.18033, 22.89 secs
# Adjusting learning rate of group 0 to 2.9127e-05.
# ---- Epoch 26/60
# (1) Training stage (lr = 0.000029) ...
# loss 2.37014, a_loss 1.42787, ema 0.37879, oracc 0.98800, orien_loss 0.04745, gacc 0.98133, gloss 0.05400, b1 0.51161, b2 0.39736, b3 0.30382, b4 0.23281, padchxlmacf1 0.06167, padchxlmicf1 0.15199, padchxlzmacf1 0.07684, padchxlzmicf1 0.15692, padchxl_loss 0.36020, padchxlz_loss 0.50228, 96.50 secs
# (2) Validation stage ...
# ema 0.34447, oracc 0.99318, gacc 0.99159, b1 0.31211, b2 0.23102, b3 0.17524, b4 0.13263, padchxlmacf1 0.07593, padchxlmicf1 0.15431, padchxlzmacf1 0.08808, padchxlzmicf1 0.18080, 22.66 secs
# Adjusting learning rate of group 0 to 2.6452e-05.
# ---- Epoch 27/60
# (1) Training stage (lr = 0.000026) ...
# loss 2.17175, a_loss 1.41645, ema 0.38558, oracc 0.98976, orien_loss 0.04706, gacc 0.98485, gloss 0.04438, b1 0.51359, b2 0.39924, b3 0.30621, b4 0.23491, padchxlmacf1 0.06228, padchxlmicf1 0.15436, padchxlzmacf1 0.07824, padchxlzmicf1 0.15993, padchxl_loss 0.36145, padchxlz_loss 0.49927, 96.64 secs
# (2) Validation stage ...
# ema 0.34243, oracc 0.99318, gacc 0.99204, b1 0.32911, b2 0.24153, b3 0.18321, b4 0.14021, padchxlmacf1 0.07633, padchxlmicf1 0.15410, padchxlzmacf1 0.08733, padchxlzmicf1 0.18110, 23.06 secs
# Adjusting learning rate of group 0 to 2.4022e-05.
# ---- Epoch 28/60
# (1) Training stage (lr = 0.000024) ...
# loss 2.28496, a_loss 1.40497, ema 0.38776, oracc 0.99000, orien_loss 0.04183, gacc 0.98430, gloss 0.04656, b1 0.51124, b2 0.39799, b3 0.30475, b4 0.23372, padchxlmacf1 0.06405, padchxlmicf1 0.15611, padchxlzmacf1 0.08110, padchxlzmicf1 0.16468, padchxl_loss 0.35853, padchxlz_loss 0.49534, 96.50 secs
# (2) Validation stage ...
# ema 0.35357, oracc 0.99363, gacc 0.99068, b1 0.32099, b2 0.23601, b3 0.17843, b4 0.13513, padchxlmacf1 0.08047, padchxlmicf1 0.15855, padchxlzmacf1 0.08871, padchxlzmicf1 0.18510, 23.01 secs
# Adjusting learning rate of group 0 to 2.1816e-05.
# ---- Epoch 29/60
# (1) Training stage (lr = 0.000022) ...
# loss 2.32008, a_loss 1.40203, ema 0.39061, oracc 0.98958, orien_loss 0.04203, gacc 0.98739, gloss 0.04062, b1 0.51043, b2 0.39804, b3 0.30640, b4 0.23591, padchxlmacf1 0.06346, padchxlmicf1 0.15550, padchxlzmacf1 0.07791, padchxlzmicf1 0.16053, padchxl_loss 0.35462, padchxlz_loss 0.48831, 96.48 secs
# (2) Validation stage ...
# ema 0.35312, oracc 0.99363, gacc 0.99363, b1 0.30472, b2 0.22124, b3 0.16643, b4 0.12591, padchxlmacf1 0.08247, padchxlmicf1 0.16456, padchxlzmacf1 0.08926, padchxlzmicf1 0.18383, 22.64 secs
# Adjusting learning rate of group 0 to 1.9813e-05.
# ---- Epoch 30/60
# (1) Training stage (lr = 0.000020) ...
# loss 2.40397, a_loss 1.39670, ema 0.38303, oracc 0.99188, orien_loss 0.03430, gacc 0.98515, gloss 0.03965, b1 0.51490, b2 0.40236, b3 0.30897, b4 0.23817, padchxlmacf1 0.06250, padchxlmicf1 0.15737, padchxlzmacf1 0.07924, padchxlzmicf1 0.16384, padchxl_loss 0.35740, padchxlz_loss 0.49797, 97.58 secs
# (2) Validation stage ...
# ema 0.34993, oracc 0.99204, gacc 0.99045, b1 0.33001, b2 0.24120, b3 0.18214, b4 0.13853, padchxlmacf1 0.08162, padchxlmicf1 0.16707, padchxlzmacf1 0.08861, padchxlzmicf1 0.18642, 22.61 secs
# Adjusting learning rate of group 0 to 1.7993e-05.
# ---- Epoch 31/60
# (1) Training stage (lr = 0.000018) ...
# loss 2.48006, a_loss 1.39767, ema 0.38733, oracc 0.99006, orien_loss 0.04033, gacc 0.98745, gloss 0.04146, b1 0.51878, b2 0.40294, b3 0.30690, b4 0.23342, padchxlmacf1 0.06554, padchxlmicf1 0.16005, padchxlzmacf1 0.08184, padchxlzmicf1 0.16540, padchxl_loss 0.35223, padchxlz_loss 0.49254, 97.03 secs
# (2) Validation stage ...
# ema 0.35061, oracc 0.99454, gacc 0.99363, b1 0.31569, b2 0.23321, b3 0.17783, b4 0.13646, padchxlmacf1 0.08092, padchxlmicf1 0.16148, padchxlzmacf1 0.09534, padchxlzmicf1 0.18653, 23.01 secs
# Adjusting learning rate of group 0 to 1.6341e-05.
# ---- Epoch 32/60
# (1) Training stage (lr = 0.000016) ...
# loss 2.12192, a_loss 1.38989, ema 0.38400, oracc 0.99042, orien_loss 0.04104, gacc 0.98848, gloss 0.03647, b1 0.52357, b2 0.40970, b3 0.31516, b4 0.24224, padchxlmacf1 0.06517, padchxlmicf1 0.15388, padchxlzmacf1 0.08221, padchxlzmicf1 0.16565, padchxl_loss 0.35733, padchxlz_loss 0.48998, 96.55 secs
# (2) Validation stage ...
# ema 0.34720, oracc 0.99545, gacc 0.99318, b1 0.32076, b2 0.23441, b3 0.17756, b4 0.13504, padchxlmacf1 0.08141, padchxlmicf1 0.16256, padchxlzmacf1 0.09359, padchxlzmicf1 0.18835, 22.44 secs
# Adjusting learning rate of group 0 to 1.4840e-05.
# ---- Epoch 33/60
# (1) Training stage (lr = 0.000015) ...
# loss 2.15492, a_loss 1.38853, ema 0.38952, oracc 0.99309, orien_loss 0.03120, gacc 0.99036, gloss 0.03390, b1 0.51833, b2 0.40489, b3 0.31083, b4 0.23874, padchxlmacf1 0.06825, padchxlmicf1 0.15900, padchxlzmacf1 0.08263, padchxlzmicf1 0.16671, padchxl_loss 0.35340, padchxlz_loss 0.48696, 96.91 secs
# (2) Validation stage ...
# ema 0.34470, oracc 0.99500, gacc 0.99250, b1 0.34022, b2 0.25021, b3 0.18993, b4 0.14593, padchxlmacf1 0.07909, padchxlmicf1 0.16174, padchxlzmacf1 0.09479, padchxlzmicf1 0.18727, 23.26 secs
# Adjusting learning rate of group 0 to 1.3477e-05.
# ---- Epoch 34/60
# (1) Training stage (lr = 0.000013) ...
# loss 2.67202, a_loss 1.38468, ema 0.39358, oracc 0.99418, orien_loss 0.02648, gacc 0.99145, gloss 0.03422, b1 0.52104, b2 0.40654, b3 0.31204, b4 0.24079, padchxlmacf1 0.06514, padchxlmicf1 0.16025, padchxlzmacf1 0.08587, padchxlzmicf1 0.16613, padchxl_loss 0.35039, padchxlz_loss 0.48515, 97.02 secs
# (2) Validation stage ...
# ema 0.34970, oracc 0.99432, gacc 0.99341, b1 0.32612, b2 0.23862, b3 0.18043, b4 0.13700, padchxlmacf1 0.08210, padchxlmicf1 0.16592, padchxlzmacf1 0.09807, padchxlzmicf1 0.18840, 22.80 secs
# Adjusting learning rate of group 0 to 1.2239e-05.
# ---- Epoch 35/60
# (1) Training stage (lr = 0.000012) ...
# loss 2.09685, a_loss 1.36449, ema 0.39606, oracc 0.99236, orien_loss 0.03270, gacc 0.99061, gloss 0.03486, b1 0.52367, b2 0.40871, b3 0.31461, b4 0.24213, padchxlmacf1 0.06856, padchxlmicf1 0.16204, padchxlzmacf1 0.08423, padchxlzmicf1 0.16743, padchxl_loss 0.34777, padchxlz_loss 0.48473, 96.77 secs
# (2) Validation stage ...
# ema 0.34379, oracc 0.99523, gacc 0.99409, b1 0.33173, b2 0.24365, b3 0.18449, b4 0.13942, padchxlmacf1 0.08260, padchxlmicf1 0.16213, padchxlzmacf1 0.09770, padchxlzmicf1 0.18958, 22.41 secs
# Adjusting learning rate of group 0 to 1.1115e-05.
# ---- Epoch 36/60
# (1) Training stage (lr = 0.000011) ...
# loss 2.40882, a_loss 1.36954, ema 0.39206, oracc 0.99297, orien_loss 0.03277, gacc 0.99279, gloss 0.02928, b1 0.52126, b2 0.40784, b3 0.31468, b4 0.24331, padchxlmacf1 0.07025, padchxlmicf1 0.16260, padchxlzmacf1 0.08763, padchxlzmicf1 0.16811, padchxl_loss 0.35048, padchxlz_loss 0.47929, 97.16 secs
# (2) Validation stage ...
# ema 0.35243, oracc 0.99613, gacc 0.99500, b1 0.32811, b2 0.24126, b3 0.18288, b4 0.13832, padchxlmacf1 0.08338, padchxlmicf1 0.16501, padchxlzmacf1 0.09796, padchxlzmicf1 0.18989, 22.68 secs
# Adjusting learning rate of group 0 to 1.0095e-05.
# ---- Epoch 37/60
# (1) Training stage (lr = 0.000010) ...
# loss 1.96448, a_loss 1.37076, ema 0.39133, oracc 0.99358, orien_loss 0.02702, gacc 0.99248, gloss 0.02964, b1 0.52350, b2 0.41008, b3 0.31522, b4 0.24134, padchxlmacf1 0.06832, padchxlmicf1 0.15980, padchxlzmacf1 0.08290, padchxlzmicf1 0.16728, padchxl_loss 0.35040, padchxlz_loss 0.48947, 97.19 secs
# (2) Validation stage ...
# ema 0.34493, oracc 0.99591, gacc 0.99659, b1 0.33329, b2 0.24631, b3 0.18624, b4 0.14179, padchxlmacf1 0.08060, padchxlmicf1 0.16358, padchxlzmacf1 0.09650, padchxlzmicf1 0.18885, 23.38 secs
# Adjusting learning rate of group 0 to 9.1675e-06.
# ---- Epoch 38/60
# (1) Training stage (lr = 0.000009) ...
# loss 2.32749, a_loss 1.38046, ema 0.39067, oracc 0.99364, orien_loss 0.02912, gacc 0.99309, gloss 0.02490, b1 0.52322, b2 0.40879, b3 0.31375, b4 0.24136, padchxlmacf1 0.06997, padchxlmicf1 0.16383, padchxlzmacf1 0.08502, padchxlzmicf1 0.17011, padchxl_loss 0.35058, padchxlz_loss 0.48438, 96.36 secs
# (2) Validation stage ...
# ema 0.34948, oracc 0.99682, gacc 0.99568, b1 0.34273, b2 0.25177, b3 0.19052, b4 0.14496, padchxlmacf1 0.08506, padchxlmicf1 0.16461, padchxlzmacf1 0.09800, padchxlzmicf1 0.19301, 21.96 secs
# Adjusting learning rate of group 0 to 8.3255e-06.
# ---- Epoch 39/60
# (1) Training stage (lr = 0.000008) ...
# loss 2.09326, a_loss 1.35569, ema 0.39364, oracc 0.99455, orien_loss 0.02944, gacc 0.99248, gloss 0.02890, b1 0.52711, b2 0.41435, b3 0.32091, b4 0.24929, padchxlmacf1 0.06986, padchxlmicf1 0.16565, padchxlzmacf1 0.08486, padchxlzmicf1 0.17335, padchxl_loss 0.34553, padchxlz_loss 0.48232, 94.47 secs
# (2) Validation stage ...
# ema 0.34197, oracc 0.99523, gacc 0.99591, b1 0.35187, b2 0.25882, b3 0.19598, b4 0.14849, padchxlmacf1 0.08616, padchxlmicf1 0.15881, padchxlzmacf1 0.09531, padchxlzmicf1 0.18874, 21.72 secs
# Adjusting learning rate of group 0 to 7.5609e-06.
# ---- Epoch 40/60
# (1) Training stage (lr = 0.000008) ...
# loss 2.21792, a_loss 1.35734, ema 0.39673, oracc 0.99527, orien_loss 0.02171, gacc 0.99224, gloss 0.02617, b1 0.52077, b2 0.40862, b3 0.31626, b4 0.24488, padchxlmacf1 0.07226, padchxlmicf1 0.16267, padchxlzmacf1 0.08715, padchxlzmicf1 0.16810, padchxl_loss 0.34530, padchxlz_loss 0.47845, 94.41 secs
# (2) Validation stage ...
# ema 0.34925, oracc 0.99523, gacc 0.99500, b1 0.34375, b2 0.25198, b3 0.18987, b4 0.14381, padchxlmacf1 0.08600, padchxlmicf1 0.16661, padchxlzmacf1 0.09881, padchxlzmicf1 0.19127, 21.84 secs
# Adjusting learning rate of group 0 to 6.8665e-06.
# ---- Epoch 41/60
# (1) Training stage (lr = 0.000007) ...
# loss 2.34643, a_loss 1.35233, ema 0.39982, oracc 0.99497, orien_loss 0.02518, gacc 0.99400, gloss 0.02407, b1 0.52716, b2 0.41454, b3 0.32139, b4 0.24952, padchxlmacf1 0.06931, padchxlmicf1 0.16227, padchxlzmacf1 0.08571, padchxlzmicf1 0.16989, padchxl_loss 0.34255, padchxlz_loss 0.47670, 94.46 secs
# (2) Validation stage ...
# ema 0.35221, oracc 0.99659, gacc 0.99568, b1 0.31919, b2 0.23802, b3 0.18183, b4 0.13945, padchxlmacf1 0.08723, padchxlmicf1 0.16971, padchxlzmacf1 0.09876, padchxlzmicf1 0.19350, 21.94 secs
# Adjusting learning rate of group 0 to 6.2359e-06.
# ---- Epoch 42/60
# (1) Training stage (lr = 0.000006) ...
# loss 2.02117, a_loss 1.35301, ema 0.39170, oracc 0.99533, orien_loss 0.02430, gacc 0.99539, gloss 0.02309, b1 0.52792, b2 0.41431, b3 0.32069, b4 0.24793, padchxlmacf1 0.07052, padchxlmicf1 0.16513, padchxlzmacf1 0.09135, padchxlzmicf1 0.17440, padchxl_loss 0.34446, padchxlz_loss 0.48012, 94.79 secs
# (2) Validation stage ...
# ema 0.35039, oracc 0.99636, gacc 0.99704, b1 0.34774, b2 0.25770, b3 0.19665, b4 0.15130, padchxlmacf1 0.08852, padchxlmicf1 0.16608, padchxlzmacf1 0.09671, padchxlzmicf1 0.19084, 22.07 secs
# Adjusting learning rate of group 0 to 5.6632e-06.
# ---- Epoch 43/60
# (1) Training stage (lr = 0.000006) ...
# loss 1.85206, a_loss 1.35557, ema 0.39273, oracc 0.99473, orien_loss 0.02514, gacc 0.99503, gloss 0.02328, b1 0.53348, b2 0.41920, b3 0.32398, b4 0.25028, padchxlmacf1 0.07246, padchxlmicf1 0.16793, padchxlzmacf1 0.08881, padchxlzmicf1 0.17448, padchxl_loss 0.34315, padchxlz_loss 0.48033, 94.38 secs
# (2) Validation stage ...
# ema 0.35448, oracc 0.99613, gacc 0.99613, b1 0.33590, b2 0.25031, b3 0.19172, b4 0.14738, padchxlmacf1 0.09092, padchxlmicf1 0.16928, padchxlzmacf1 0.09926, padchxlzmicf1 0.19554, 21.69 secs
# Adjusting learning rate of group 0 to 5.1431e-06.
# ---- Epoch 44/60
# (1) Training stage (lr = 0.000005) ...
# loss 2.19903, a_loss 1.34860, ema 0.39624, oracc 0.99588, orien_loss 0.02022, gacc 0.99430, gloss 0.02411, b1 0.52560, b2 0.41245, b3 0.31862, b4 0.24684, padchxlmacf1 0.07145, padchxlmicf1 0.16766, padchxlzmacf1 0.08719, padchxlzmicf1 0.17467, padchxl_loss 0.33928, padchxlz_loss 0.47502, 94.80 secs
# (2) Validation stage ...
# ema 0.35289, oracc 0.99591, gacc 0.99659, b1 0.33784, b2 0.24998, b3 0.19040, b4 0.14546, padchxlmacf1 0.09302, padchxlmicf1 0.17100, padchxlzmacf1 0.10648, padchxlzmicf1 0.19533, 21.71 secs
# Adjusting learning rate of group 0 to 4.6708e-06.
# ---- Epoch 45/60
# (1) Training stage (lr = 0.000005) ...
# loss 2.44141, a_loss 1.35647, ema 0.39612, oracc 0.99630, orien_loss 0.01939, gacc 0.99636, gloss 0.01839, b1 0.53385, b2 0.41598, b3 0.31853, b4 0.24416, padchxlmacf1 0.07300, padchxlmicf1 0.16483, padchxlzmacf1 0.08790, padchxlzmicf1 0.17454, padchxl_loss 0.34439, padchxlz_loss 0.48218, 94.79 secs
# (2) Validation stage ...
# ema 0.35107, oracc 0.99682, gacc 0.99636, b1 0.33377, b2 0.24714, b3 0.18897, b4 0.14480, padchxlmacf1 0.09379, padchxlmicf1 0.16935, padchxlzmacf1 0.09891, padchxlzmicf1 0.19437, 21.69 secs
# Adjusting learning rate of group 0 to 4.2418e-06.
# ---- Epoch 46/60
# (1) Training stage (lr = 0.000004) ...
# loss 2.25194, a_loss 1.35509, ema 0.39418, oracc 0.99527, orien_loss 0.02431, gacc 0.99624, gloss 0.02222, b1 0.52883, b2 0.41561, b3 0.32093, b4 0.24841, padchxlmacf1 0.07128, padchxlmicf1 0.16680, padchxlzmacf1 0.08681, padchxlzmicf1 0.17522, padchxl_loss 0.34342, padchxlz_loss 0.47523, 95.17 secs
# (2) Validation stage ...
# ema 0.35766, oracc 0.99659, gacc 0.99727, b1 0.33981, b2 0.25343, b3 0.19457, b4 0.15021, padchxlmacf1 0.09229, padchxlmicf1 0.17090, padchxlzmacf1 0.10680, padchxlzmicf1 0.19369, 21.66 secs
# Adjusting learning rate of group 0 to 3.8523e-06.
# ---- Epoch 47/60
# (1) Training stage (lr = 0.000004) ...
# loss 1.93012, a_loss 1.34860, ema 0.39812, oracc 0.99648, orien_loss 0.01940, gacc 0.99673, gloss 0.01836, b1 0.53629, b2 0.42116, b3 0.32559, b4 0.25159, padchxlmacf1 0.07247, padchxlmicf1 0.17134, padchxlzmacf1 0.09210, padchxlzmicf1 0.17704, padchxl_loss 0.33653, padchxlz_loss 0.47733, 94.22 secs
# (2) Validation stage ...
# ema 0.35152, oracc 0.99704, gacc 0.99750, b1 0.34146, b2 0.25303, b3 0.19287, b4 0.14788, padchxlmacf1 0.09425, padchxlmicf1 0.17172, padchxlzmacf1 0.10026, padchxlzmicf1 0.19606, 21.75 secs
# Adjusting learning rate of group 0 to 3.4985e-06.
# ---- Epoch 48/60
# (1) Training stage (lr = 0.000003) ...
# loss 2.39628, a_loss 1.36176, ema 0.39170, oracc 0.99570, orien_loss 0.02064, gacc 0.99648, gloss 0.01895, b1 0.52824, b2 0.41307, b3 0.31767, b4 0.24423, padchxlmacf1 0.07467, padchxlmicf1 0.16786, padchxlzmacf1 0.08777, padchxlzmicf1 0.17172, padchxl_loss 0.33958, padchxlz_loss 0.47331, 94.67 secs
# (2) Validation stage ...
# ema 0.35130, oracc 0.99750, gacc 0.99704, b1 0.34549, b2 0.25635, b3 0.19565, b4 0.15034, padchxlmacf1 0.09409, padchxlmicf1 0.16884, padchxlzmacf1 0.10537, padchxlzmicf1 0.19475, 21.98 secs
# Adjusting learning rate of group 0 to 3.1772e-06.
# ---- Epoch 49/60
# (1) Training stage (lr = 0.000003) ...
# loss 2.64296, a_loss 1.35374, ema 0.39636, oracc 0.99552, orien_loss 0.02304, gacc 0.99642, gloss 0.01780, b1 0.52960, b2 0.41613, b3 0.32151, b4 0.24820, padchxlmacf1 0.07359, padchxlmicf1 0.16791, padchxlzmacf1 0.08926, padchxlzmicf1 0.17986, padchxl_loss 0.34214, padchxlz_loss 0.47237, 94.31 secs
# (2) Validation stage ...
# ema 0.34993, oracc 0.99682, gacc 0.99750, b1 0.34924, b2 0.25759, b3 0.19571, b4 0.14908, padchxlmacf1 0.09427, padchxlmicf1 0.16926, padchxlzmacf1 0.10584, padchxlzmicf1 0.19592, 21.68 secs
# Adjusting learning rate of group 0 to 2.8854e-06.
# ---- Epoch 50/60
# (1) Training stage (lr = 0.000003) ...
# loss 1.99415, a_loss 1.34607, ema 0.39764, oracc 0.99624, orien_loss 0.02175, gacc 0.99606, gloss 0.01874, b1 0.53214, b2 0.41730, b3 0.32159, b4 0.24817, padchxlmacf1 0.07271, padchxlmicf1 0.16753, padchxlzmacf1 0.09096, padchxlzmicf1 0.17640, padchxl_loss 0.33768, padchxlz_loss 0.46895, 93.88 secs
# (2) Validation stage ...
# ema 0.34925, oracc 0.99727, gacc 0.99750, b1 0.35160, b2 0.26009, b3 0.19804, b4 0.15158, padchxlmacf1 0.09292, padchxlmicf1 0.16955, padchxlzmacf1 0.10613, padchxlzmicf1 0.19655, 21.68 secs
# Adjusting learning rate of group 0 to 2.6204e-06.
# ---- Epoch 51/60
# (1) Training stage (lr = 0.000003) ...
# loss 2.06834, a_loss 1.35211, ema 0.39200, oracc 0.99685, orien_loss 0.02014, gacc 0.99606, gloss 0.02166, b1 0.53234, b2 0.41862, b3 0.32412, b4 0.25259, padchxlmacf1 0.07337, padchxlmicf1 0.16705, padchxlzmacf1 0.08877, padchxlzmicf1 0.17967, padchxl_loss 0.34216, padchxlz_loss 0.47335, 94.45 secs
# (2) Validation stage ...
# ema 0.35425, oracc 0.99727, gacc 0.99773, b1 0.34519, b2 0.25593, b3 0.19618, b4 0.15151, padchxlmacf1 0.09524, padchxlmicf1 0.17356, padchxlzmacf1 0.10120, padchxlzmicf1 0.19801, 21.72 secs
# Adjusting learning rate of group 0 to 2.3798e-06.
# ---- Epoch 52/60
# (1) Training stage (lr = 0.000002) ...
# loss 2.50133, a_loss 1.35538, ema 0.39721, oracc 0.99655, orien_loss 0.01944, gacc 0.99630, gloss 0.01928, b1 0.52588, b2 0.41102, b3 0.31552, b4 0.24210, padchxlmacf1 0.07270, padchxlmicf1 0.16958, padchxlzmacf1 0.09134, padchxlzmicf1 0.17247, padchxl_loss 0.34008, padchxlz_loss 0.47234, 93.98 secs
# (2) Validation stage ...
# ema 0.35562, oracc 0.99750, gacc 0.99750, b1 0.33104, b2 0.24525, b3 0.18719, b4 0.14344, padchxlmacf1 0.09824, padchxlmicf1 0.17460, padchxlzmacf1 0.10770, padchxlzmicf1 0.19823, 21.81 secs
# Adjusting learning rate of group 0 to 2.1612e-06.
# ---- Epoch 53/60
# (1) Training stage (lr = 0.000002) ...
# loss 1.95121, a_loss 1.36292, ema 0.39315, oracc 0.99588, orien_loss 0.02333, gacc 0.99667, gloss 0.01731, b1 0.53001, b2 0.41664, b3 0.32189, b4 0.24852, padchxlmacf1 0.07371, padchxlmicf1 0.16527, padchxlzmacf1 0.08984, padchxlzmicf1 0.17578, padchxl_loss 0.34081, padchxlz_loss 0.47335, 94.94 secs
# (2) Validation stage ...
# ema 0.35334, oracc 0.99727, gacc 0.99773, b1 0.34516, b2 0.25454, b3 0.19331, b4 0.14747, padchxlmacf1 0.09789, padchxlmicf1 0.17173, padchxlzmacf1 0.10617, padchxlzmicf1 0.19722, 21.77 secs
# Adjusting learning rate of group 0 to 1.9627e-06.
# ---- Epoch 54/60
# (1) Training stage (lr = 0.000002) ...
# loss 2.07235, a_loss 1.33979, ema 0.40139, oracc 0.99564, orien_loss 0.02324, gacc 0.99667, gloss 0.01879, b1 0.53350, b2 0.42016, b3 0.32625, b4 0.25337, padchxlmacf1 0.07297, padchxlmicf1 0.17339, padchxlzmacf1 0.08963, padchxlzmicf1 0.17911, padchxl_loss 0.33709, padchxlz_loss 0.46786, 94.43 secs
# (2) Validation stage ...
# ema 0.35607, oracc 0.99750, gacc 0.99773, b1 0.33143, b2 0.24686, b3 0.18885, b4 0.14542, padchxlmacf1 0.09543, padchxlmicf1 0.17409, padchxlzmacf1 0.10803, padchxlzmicf1 0.19854, 21.63 secs
# Adjusting learning rate of group 0 to 1.7825e-06.
# ---- Epoch 55/60
# (1) Training stage (lr = 0.000002) ...
# loss 2.19675, a_loss 1.35967, ema 0.39224, oracc 0.99618, orien_loss 0.02252, gacc 0.99721, gloss 0.01585, b1 0.52782, b2 0.41477, b3 0.32053, b4 0.24758, padchxlmacf1 0.07345, padchxlmicf1 0.17151, padchxlzmacf1 0.09068, padchxlzmicf1 0.17835, padchxl_loss 0.33969, padchxlz_loss 0.46965, 94.47 secs
# (2) Validation stage ...
# ema 0.34675, oracc 0.99750, gacc 0.99773, b1 0.34921, b2 0.25986, b3 0.19841, b4 0.15181, padchxlmacf1 0.09558, padchxlmicf1 0.16953, padchxlzmacf1 0.10615, padchxlzmicf1 0.19777, 21.95 secs
# Adjusting learning rate of group 0 to 1.6188e-06.
# ---- Epoch 56/60
# (1) Training stage (lr = 0.000002) ...
# loss 2.23861, a_loss 1.35433, ema 0.39988, oracc 0.99685, orien_loss 0.01753, gacc 0.99764, gloss 0.01493, b1 0.53604, b2 0.42148, b3 0.32680, b4 0.25389, padchxlmacf1 0.07668, padchxlmicf1 0.17274, padchxlzmacf1 0.09061, padchxlzmicf1 0.17678, padchxl_loss 0.33884, padchxlz_loss 0.47167, 93.34 secs
# (2) Validation stage ...
# ema 0.35061, oracc 0.99682, gacc 0.99773, b1 0.34746, b2 0.25767, b3 0.19612, b4 0.14964, padchxlmacf1 0.09773, padchxlmicf1 0.17218, padchxlzmacf1 0.10638, padchxlzmicf1 0.19813, 21.69 secs
# Adjusting learning rate of group 0 to 1.4701e-06.
# ---- Epoch 57/60
# (1) Training stage (lr = 0.000001) ...
# loss 2.26070, a_loss 1.34940, ema 0.39400, oracc 0.99727, orien_loss 0.01548, gacc 0.99648, gloss 0.01631, b1 0.53232, b2 0.41867, b3 0.32351, b4 0.25004, padchxlmacf1 0.07203, padchxlmicf1 0.17011, padchxlzmacf1 0.09114, padchxlzmicf1 0.17820, padchxl_loss 0.33849, padchxlz_loss 0.47165, 94.85 secs
# (2) Validation stage ...
# ema 0.35471, oracc 0.99795, gacc 0.99773, b1 0.33281, b2 0.24801, b3 0.18958, b4 0.14522, padchxlmacf1 0.09939, padchxlmicf1 0.17474, padchxlzmacf1 0.10775, padchxlzmicf1 0.19822, 21.69 secs
# Adjusting learning rate of group 0 to 1.3351e-06.
# ---- Epoch 58/60
# (1) Training stage (lr = 0.000001) ...
# loss 2.01112, a_loss 1.35163, ema 0.39897, oracc 0.99655, orien_loss 0.02092, gacc 0.99655, gloss 0.01689, b1 0.53121, b2 0.41577, b3 0.31980, b4 0.24534, padchxlmacf1 0.07545, padchxlmicf1 0.16919, padchxlzmacf1 0.09100, padchxlzmicf1 0.17490, padchxl_loss 0.33410, padchxlz_loss 0.47363, 94.44 secs
# (2) Validation stage ...
# ema 0.35266, oracc 0.99773, gacc 0.99750, b1 0.33971, b2 0.25228, b3 0.19209, b4 0.14668, padchxlmacf1 0.09986, padchxlmicf1 0.17441, padchxlzmacf1 0.10695, padchxlzmicf1 0.19784, 21.79 secs
# Adjusting learning rate of group 0 to 1.2125e-06.
# ---- Epoch 59/60
# (1) Training stage (lr = 0.000001) ...
# loss 2.34597, a_loss 1.34200, ema 0.39455, oracc 0.99745, orien_loss 0.01840, gacc 0.99691, gloss 0.01610, b1 0.53875, b2 0.42416, b3 0.33012, b4 0.25750, padchxlmacf1 0.07716, padchxlmicf1 0.17057, padchxlzmacf1 0.09283, padchxlzmicf1 0.18007, padchxl_loss 0.33594, padchxlz_loss 0.46633, 94.07 secs
# (2) Validation stage ...
# ema 0.35402, oracc 0.99818, gacc 0.99773, b1 0.33923, b2 0.25188, b3 0.19167, b4 0.14635, padchxlmacf1 0.09883, padchxlmicf1 0.17512, padchxlzmacf1 0.10794, padchxlzmicf1 0.19845, 21.87 secs
# Adjusting learning rate of group 0 to 1.1011e-06.
# ---- Epoch 60/60
# (1) Training stage (lr = 0.000001) ...
# loss 2.26286, a_loss 1.35805, ema 0.39521, oracc 0.99679, orien_loss 0.01878, gacc 0.99709, gloss 0.01793, b1 0.53459, b2 0.41905, b3 0.32320, b4 0.24944, padchxlmacf1 0.07664, padchxlmicf1 0.17117, padchxlzmacf1 0.08823, padchxlzmicf1 0.17693, padchxl_loss 0.33587, padchxlz_loss 0.46665, 95.01 secs
# (2) Validation stage ...
# ema 0.35175, oracc 0.99818, gacc 0.99773, b1 0.34044, b2 0.25231, b3 0.19204, b4 0.14672, padchxlmacf1 0.09595, padchxlmicf1 0.17239, padchxlzmacf1 0.10770, padchxlzmicf1 0.19826, 21.60 secs
# Adjusting learning rate of group 0 to 1.0000e-06.
