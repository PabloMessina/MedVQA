# %%
# %env CUDA_VISIBLE_DEVICES=0

# %%
from medvqa.evaluation.report_generation import get_report_level_metrics_dataframe

# %%
# !python ../eval_report_generation.py \
        --checkpoint-folder "models/vqa/20220925_174700_mim+mim(chex)+iu+iu(chex)+chexp(vqa)+cxr14(vqa)+vinbig(vqa)_oevqa(CenIA-clip-vte-vit-lp16bcbf+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16,0.5,0.4,0.4_medtok_orien_chx_ql_amp" \
        --eval-mode "ground-truth" \
        --no-iuxray \
        --batch-size 160 \
        --num-workers 5 \
        --max-processes-for-chexpert-labeler 5
# Out:
# script's arguments:
#    checkpoint_folder: models/vqa/20220925_174700_mim+mim(chex)+iu+iu(chex)+chexp(vqa)+cxr14(vqa)+vinbig(vqa)_oevqa(CenIA-clip-vte-vit-lp16bcbf+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16,0.5,0.4,0.4_medtok_orien_chx_ql_amp
#    eval_mode: ground-truth
#    n_questions_per_report: None
#    qclass_threshold: None
#    batch_size: 160
#    device: GPU
#    num_workers: 5
#    answer_decoding: greedy-search
#    eval_checkpoint_folder: None
#    precomputed_question_probs_path: None
#    precomputed_question_thresholds_path: None
#    eval_iuxray: False
#    eval_mimiccxr: True
#    use_amp: False
#    max_processes_for_chexpert_labeler: 5
# ----- Evaluating model ------
# metadata loaded from /home/pamessina/medvqa-workspace/models/vqa/20220925_174700_mim+mim(chex)+iu+iu(chex)+chexp(vqa)+cxr14(vqa)+vinbig(vqa)_oevqa(CenIA-clip-vte-vit-lp16bcbf+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16,0.5,0.4,0.4_medtok_orien_chx_ql_amp/metadata.json
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Loading iuxray and mimiccxr QA adapted reports ...
# --------------------------------------------------
# 3) Initializing tokenizer ...
# Loading /home/pamessina/medvqa-workspace/cache/vocab__min_freq=10__mode=report__from(qa_adapted_reports__20220904_091601.json;qa_adapted_reports__20220904_095810.json).pkl ...
# --------------------------------------------------
# 4) Estimating maximum answer length ...
# max_answer_length = 15
# --------------------------------------------------
# 5) Defining image transform ...
# mean = (0.5, 0.5, 0.5), std = (0.5, 0.5, 0.5)
# Returning default transform
# --------------------------------------------------
# 6) Defining collate_batch_fn ...
# get_vqa_collate_batch_fn(): dataset_id=1, one_hot_question_offset=0
# checkpoint_names = ['checkpoint_79_chxlmacf1+chxlmicf1+cD+cxr14macf1+cxr14micf1+ema+gacc+oracc+qlmacf1+qlmicf1+vnbgmacf1+vnbgmicf1+wmdcmp=0.5666.pt']
# --------------------------------------------------
# 7) Loading model from checkpoint ...
# checkpoint_path =  /home/pamessina/medvqa-workspace/models/vqa/20220925_174700_mim+mim(chex)+iu+iu(chex)+chexp(vqa)+cxr14(vqa)+vinbig(vqa)_oevqa(CenIA-clip-vte-vit-lp16bcbf+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16,0.5,0.4,0.4_medtok_orien_chx_ql_amp/checkpoint_79_chxlmacf1+chxlmicf1+cD+cxr14macf1+cxr14micf1+ema+gacc+oracc+qlmacf1+qlmicf1+vnbgmacf1+vnbgmicf1+wmdcmp=0.5666.pt
# pretrained_checkpoint_path = /home/pamessina/medvqa-workspace/models/vqa/20220925_174700_mim+mim(chex)+iu+iu(chex)+chexp(vqa)+cxr14(vqa)+vinbig(vqa)_oevqa(CenIA-clip-vte-vit-lp16bcbf+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16,0.5,0.4,0.4_medtok_orien_chx_ql_amp/checkpoint_79_chxlmacf1+chxlmicf1+cD+cxr14macf1+cxr14micf1+ema+gacc+oracc+qlmacf1+qlmicf1+vnbgmacf1+vnbgmicf1+wmdcmp=0.5666.pt
# --------------------------------------------------
# 8) Creating MIMIC-CXR vqa evaluator ...
# report_eval_mode = ground-truth
# Checking if data is already cached in path /home/pamessina/medvqa-workspace/cache/mimiccxr/mimiccxr_preprocessed_test_data__(dataset=qa_adapted_reports__20220904_095810.json;tokenizer=4838,39196,466463750150781738;report_eval_mode=ground-truth).pkl ...
# 	Yes, it is, data successfully loaded :)
# batch_size = 160
# len(self.report_ids) = 32697, len(set(self.report_ids)) = 3258
# VQA_Evaluator():
#   len(self.test_indices) = 32697, len(set(self.report_ids)) = 3258
# generating test dataset ...
# generating test dataloader ...
# done!
# --------------------------------------------------
# 9) Creating instance of OpenEndedVQA model ...
# OpenEndedVQA():
#   image_encoder_pretrained_weights_path None
#   self.global_feat_size = 1024
#   n_questions = 154
#   n_questions_aux_task = 97
#   question_encoding = one-hot
#   answer_decoding = transformer
#   visual_input_mode = raw-image
#   name = oevqa(CenIA/clip-vte-vit-lp16bcbf+onehot+transf)
# --------------------------------------------------
# 10) Creating evaluator engine ...
# get_engine(): shift_answer=False
# --------------------------------------------------
# 11) Attaching metrics, losses, timer and events to engines ...
#
# ========================
# --------------------------------------------------
# 12) Running evaluator engine on MIMIC-CXR test split ...
# len(dataset) = 32697
# len(dataloader) = 205
# Evaluating model ...
# oracc 0.99023, chxlmicf1 0.57301, chxlmacf1 0.48025, chxlacc 0.68912, chxlrocaucmic 0.80234, chxlrocaucmac 0.75660, qlmacf1 0.22144, 207.71 secs
# Computing metrics ...
# recovered reports: len(gen_reports)=3258, len(gt_reports)=3258
# Cache successfully loaded from /home/pamessina/medvqa-workspace/cache/chexpert_labeler_cache.pkl
# (*) Chexpert: labeling 3258 texts ...
# All labels found in cache, no need to invoke chexpert labeler
# (*) Chexpert: labeling 3258 texts ...
# Chexpert labeler: running a maximum of 5 concurrent processes over 5 chunks
# chunk: i=0, b=0, e=649, chunk_size=649
# chunk: i=1, b=649, e=1298, chunk_size=649
# chunk: i=2, b=1298, e=1947, chunk_size=649
# chunk: i=3, b=1947, e=2596, chunk_size=649
# chunk: i=4, b=2596, e=3245, chunk_size=646
# 	#### process 1: running chexpert labeler over 649 texts ...
# 	Command = docker run -v /home/pamessina/medvqa-workspace/tmp/chexpert-labeler:/data chexpert-labeler:latest python label.py --reports_path /data/labeler-input_20220926_001037_0.5800969455209021_0.csv --output_path /data/labeler-output_20220926_001037_0.5800969455209021_0.csv
# 	#### process 2: running chexpert labeler over 649 texts ...
# 	Command = docker run -v /home/pamessina/medvqa-workspace/tmp/chexpert-labeler:/data chexpert-labeler:latest python label.py --reports_path /data/labeler-input_20220926_001037_0.5800969455209021_1.csv --output_path /data/labeler-output_20220926_001037_0.5800969455209021_1.csv
# 	#### process 3: running chexpert labeler over 649 texts ...
# 	Command = docker run -v /home/pamessina/medvqa-workspace/tmp/chexpert-labeler:/data chexpert-labeler:latest python label.py --reports_path /data/labeler-input_20220926_001037_0.5800969455209021_2.csv --output_path /data/labeler-output_20220926_001037_0.5800969455209021_2.csv
# 	#### process 4: running chexpert labeler over 649 texts ...
# 	Command = docker run -v /home/pamessina/medvqa-workspace/tmp/chexpert-labeler:/data chexpert-labeler:latest python label.py --reports_path /data/labeler-input_20220926_001037_0.5800969455209021_3.csv --output_path /data/labeler-output_20220926_001037_0.5800969455209021_3.csv
# 	#### process 5: running chexpert labeler over 646 texts ...
# 	Command = docker run -v /home/pamessina/medvqa-workspace/tmp/chexpert-labeler:/data chexpert-labeler:latest python label.py --reports_path /data/labeler-input_20220926_001037_0.5800969455209021_4.csv --output_path /data/labeler-output_20220926_001037_0.5800969455209021_4.csv
# Generating LALR tables
# Downloading 'http://search.maven.org/remotecontent?filepath=edu/stanford/nlp/stanford-corenlp/3.5.2/stanford-corenlp-3.5.2.jar' -> '/root/.local/share/pystanforddeps/stanford-corenlp-3.5.2.jar'
# Generating LALR tables
# Downloading 'http://search.maven.org/remotecontent?filepath=edu/stanford/nlp/stanford-corenlp/3.5.2/stanford-corenlp-3.5.2.jar' -> '/root/.local/share/pystanforddeps/stanford-corenlp-3.5.2.jar'
# Downloading 'http://search.maven.org/remotecontent?filepath=edu/stanford/nlp/stanford-corenlp/3.5.2/stanford-corenlp-3.5.2.jar' -> '/root/.local/share/pystanforddeps/stanford-corenlp-3.5.2.jar'
# Generating LALR tables
# Generating LALR tables
# Downloading 'http://search.maven.org/remotecontent?filepath=edu/stanford/nlp/stanford-corenlp/3.5.2/stanford-corenlp-3.5.2.jar' -> '/root/.local/share/pystanforddeps/stanford-corenlp-3.5.2.jar'
# 	**** process 1 finished, elapsed time = 556.7407703399658
# 	**** process 2 finished, elapsed time = 556.7409474849701
# 	**** process 3 finished, elapsed time = 556.7410180568695
# Generating LALR tables
# Downloading 'http://search.maven.org/remotecontent?filepath=edu/stanford/nlp/stanford-corenlp/3.5.2/stanford-corenlp-3.5.2.jar' -> '/root/.local/share/pystanforddeps/stanford-corenlp-3.5.2.jar'
# 	**** process 4 finished, elapsed time = 565.4032056331635
# 	**** process 5 finished, elapsed time = 565.4033243656158
# Report-level metrics successfully saved to /home/pamessina/medvqa-workspace/results/vqa/20220925_174700_mim+mim(chex)+iu+iu(chex)+chexp(vqa)+cxr14(vqa)+vinbig(vqa)_oevqa(CenIA-clip-vte-vit-lp16bcbf+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16,0.5,0.4,0.4_medtok_orien_chx_ql_amp/mimiccxr_report_level_metrics(eval_mode=ground-truth).pkl

# %%
# !python ../eval_report_generation.py \
        --checkpoint-folder "models/vqa/20220925_174700_mim+mim(chex)+iu+iu(chex)+chexp(vqa)+cxr14(vqa)+vinbig(vqa)_oevqa(CenIA-clip-vte-vit-lp16bcbf+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16,0.5,0.4,0.4_medtok_orien_chx_ql_amp" \
        --eval-mode "chexpert-labels" \
        --no-iuxray \
        --batch-size 160 \
        --num-workers 5 \
        --max-processes-for-chexpert-labeler 5
# Out:
# script's arguments:
#    checkpoint_folder: models/vqa/20220925_174700_mim+mim(chex)+iu+iu(chex)+chexp(vqa)+cxr14(vqa)+vinbig(vqa)_oevqa(CenIA-clip-vte-vit-lp16bcbf+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16,0.5,0.4,0.4_medtok_orien_chx_ql_amp
#    eval_mode: chexpert-labels
#    n_questions_per_report: None
#    qclass_threshold: None
#    batch_size: 160
#    device: GPU
#    num_workers: 5
#    answer_decoding: greedy-search
#    eval_checkpoint_folder: None
#    precomputed_question_probs_path: None
#    precomputed_question_thresholds_path: None
#    eval_iuxray: False
#    eval_mimiccxr: True
#    use_amp: False
#    max_processes_for_chexpert_labeler: 5
# ----- Evaluating model ------
# metadata loaded from /home/pamessina/medvqa-workspace/models/vqa/20220925_174700_mim+mim(chex)+iu+iu(chex)+chexp(vqa)+cxr14(vqa)+vinbig(vqa)_oevqa(CenIA-clip-vte-vit-lp16bcbf+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16,0.5,0.4,0.4_medtok_orien_chx_ql_amp/metadata.json
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Loading iuxray and mimiccxr QA adapted reports ...
# --------------------------------------------------
# 3) Initializing tokenizer ...
# Loading /home/pamessina/medvqa-workspace/cache/vocab__min_freq=10__mode=report__from(qa_adapted_reports__20220904_091601.json;qa_adapted_reports__20220904_095810.json).pkl ...
# --------------------------------------------------
# 4) Estimating maximum answer length ...
# max_answer_length = 15
# --------------------------------------------------
# 5) Defining image transform ...
# mean = (0.5, 0.5, 0.5), std = (0.5, 0.5, 0.5)
# Returning default transform
# --------------------------------------------------
# 6) Defining collate_batch_fn ...
# get_vqa_collate_batch_fn(): dataset_id=1, one_hot_question_offset=97
# checkpoint_names = ['checkpoint_79_chxlmacf1+chxlmicf1+cD+cxr14macf1+cxr14micf1+ema+gacc+oracc+qlmacf1+qlmicf1+vnbgmacf1+vnbgmicf1+wmdcmp=0.5666.pt']
# --------------------------------------------------
# 7) Loading model from checkpoint ...
# checkpoint_path =  /home/pamessina/medvqa-workspace/models/vqa/20220925_174700_mim+mim(chex)+iu+iu(chex)+chexp(vqa)+cxr14(vqa)+vinbig(vqa)_oevqa(CenIA-clip-vte-vit-lp16bcbf+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16,0.5,0.4,0.4_medtok_orien_chx_ql_amp/checkpoint_79_chxlmacf1+chxlmicf1+cD+cxr14macf1+cxr14micf1+ema+gacc+oracc+qlmacf1+qlmicf1+vnbgmacf1+vnbgmicf1+wmdcmp=0.5666.pt
# pretrained_checkpoint_path = /home/pamessina/medvqa-workspace/models/vqa/20220925_174700_mim+mim(chex)+iu+iu(chex)+chexp(vqa)+cxr14(vqa)+vinbig(vqa)_oevqa(CenIA-clip-vte-vit-lp16bcbf+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16,0.5,0.4,0.4_medtok_orien_chx_ql_amp/checkpoint_79_chxlmacf1+chxlmicf1+cD+cxr14macf1+cxr14micf1+ema+gacc+oracc+qlmacf1+qlmicf1+vnbgmacf1+vnbgmicf1+wmdcmp=0.5666.pt
# --------------------------------------------------
# 8) Creating MIMIC-CXR vqa evaluator ...
# report_eval_mode = chexpert-labels
# Checking if data is already cached in path /home/pamessina/medvqa-workspace/cache/mimiccxr/mimiccxr_preprocessed_test_data__(dataset=qa_adapted_reports__20220904_095810.json;tokenizer=4838,39196,466463750150781738;report_eval_mode=chexpert-labels).pkl ...
# 	Yes, it is, data successfully loaded :)
# batch_size = 160
# len(self.report_ids) = 45766, len(set(self.report_ids)) = 3269
# VQA_Evaluator():
#   len(self.test_indices) = 45766, len(set(self.report_ids)) = 3269
# generating test dataset ...
# generating test dataloader ...
# done!
# --------------------------------------------------
# 9) Creating instance of OpenEndedVQA model ...
# OpenEndedVQA():
#   image_encoder_pretrained_weights_path None
#   self.global_feat_size = 1024
#   n_questions = 154
#   n_questions_aux_task = 97
#   question_encoding = one-hot
#   answer_decoding = transformer
#   visual_input_mode = raw-image
#   name = oevqa(CenIA/clip-vte-vit-lp16bcbf+onehot+transf)
# --------------------------------------------------
# 10) Creating evaluator engine ...
# get_engine(): shift_answer=False
# --------------------------------------------------
# 11) Attaching metrics, losses, timer and events to engines ...
#
# ========================
# --------------------------------------------------
# 12) Running evaluator engine on MIMIC-CXR test split ...
# len(dataset) = 45766
# len(dataloader) = 287
# Evaluating model ...
# oracc 0.99013, chxlmicf1 0.54912, chxlmacf1 0.46030, chxlacc 0.68258, chxlrocaucmic 0.79972, chxlrocaucmac 0.75172, qlmacf1 0.20424, 288.48 secs
# Computing metrics ...
# recovered reports: len(gen_reports)=3269, len(gt_reports)=3269
# Cache successfully loaded from /home/pamessina/medvqa-workspace/cache/chexpert_labeler_cache.pkl
# (*) Chexpert: labeling 3269 texts ...
# All labels found in cache, no need to invoke chexpert labeler
# (*) Chexpert: labeling 3269 texts ...
# Chexpert labeler: running a maximum of 5 concurrent processes over 5 chunks
# chunk: i=0, b=0, e=160, chunk_size=160
# chunk: i=1, b=160, e=320, chunk_size=160
# chunk: i=2, b=320, e=480, chunk_size=160
# chunk: i=3, b=480, e=640, chunk_size=160
# chunk: i=4, b=640, e=800, chunk_size=158
# 	#### process 1: running chexpert labeler over 160 texts ...
# 	Command = docker run -v /home/pamessina/medvqa-workspace/tmp/chexpert-labeler:/data chexpert-labeler:latest python label.py --reports_path /data/labeler-input_20220926_002546_0.7768480186936311_0.csv --output_path /data/labeler-output_20220926_002546_0.7768480186936311_0.csv
# 	#### process 2: running chexpert labeler over 160 texts ...
# 	Command = docker run -v /home/pamessina/medvqa-workspace/tmp/chexpert-labeler:/data chexpert-labeler:latest python label.py --reports_path /data/labeler-input_20220926_002546_0.7768480186936311_1.csv --output_path /data/labeler-output_20220926_002546_0.7768480186936311_1.csv
# 	#### process 3: running chexpert labeler over 160 texts ...
# 	Command = docker run -v /home/pamessina/medvqa-workspace/tmp/chexpert-labeler:/data chexpert-labeler:latest python label.py --reports_path /data/labeler-input_20220926_002546_0.7768480186936311_2.csv --output_path /data/labeler-output_20220926_002546_0.7768480186936311_2.csv
# 	#### process 4: running chexpert labeler over 160 texts ...
# 	Command = docker run -v /home/pamessina/medvqa-workspace/tmp/chexpert-labeler:/data chexpert-labeler:latest python label.py --reports_path /data/labeler-input_20220926_002546_0.7768480186936311_3.csv --output_path /data/labeler-output_20220926_002546_0.7768480186936311_3.csv
# 	#### process 5: running chexpert labeler over 158 texts ...
# 	Command = docker run -v /home/pamessina/medvqa-workspace/tmp/chexpert-labeler:/data chexpert-labeler:latest python label.py --reports_path /data/labeler-input_20220926_002546_0.7768480186936311_4.csv --output_path /data/labeler-output_20220926_002546_0.7768480186936311_4.csv
# Generating LALR tables
# Downloading 'http://search.maven.org/remotecontent?filepath=edu/stanford/nlp/stanford-corenlp/3.5.2/stanford-corenlp-3.5.2.jar' -> '/root/.local/share/pystanforddeps/stanford-corenlp-3.5.2.jar'
# Generating LALR tables
# Downloading 'http://search.maven.org/remotecontent?filepath=edu/stanford/nlp/stanford-corenlp/3.5.2/stanford-corenlp-3.5.2.jar' -> '/root/.local/share/pystanforddeps/stanford-corenlp-3.5.2.jar'
# 	**** process 1 finished, elapsed time = 84.65729570388794
# 	**** process 2 finished, elapsed time = 85.07169580459595
# Generating LALR tables
# Downloading 'http://search.maven.org/remotecontent?filepath=edu/stanford/nlp/stanford-corenlp/3.5.2/stanford-corenlp-3.5.2.jar' -> '/root/.local/share/pystanforddeps/stanford-corenlp-3.5.2.jar'
# 	**** process 3 finished, elapsed time = 87.66118240356445
# Generating LALR tables
# Downloading 'http://search.maven.org/remotecontent?filepath=edu/stanford/nlp/stanford-corenlp/3.5.2/stanford-corenlp-3.5.2.jar' -> '/root/.local/share/pystanforddeps/stanford-corenlp-3.5.2.jar'
# Generating LALR tables
# Downloading 'http://search.maven.org/remotecontent?filepath=edu/stanford/nlp/stanford-corenlp/3.5.2/stanford-corenlp-3.5.2.jar' -> '/root/.local/share/pystanforddeps/stanford-corenlp-3.5.2.jar'
# 	**** process 4 finished, elapsed time = 88.66583967208862
# 	**** process 5 finished, elapsed time = 88.71975302696228
# Report-level metrics successfully saved to /home/pamessina/medvqa-workspace/results/vqa/20220925_174700_mim+mim(chex)+iu+iu(chex)+chexp(vqa)+cxr14(vqa)+vinbig(vqa)_oevqa(CenIA-clip-vte-vit-lp16bcbf+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16,0.5,0.4,0.4_medtok_orien_chx_ql_amp/mimiccxr_report_level_metrics(eval_mode=chexpert-labels).pkl

# %%
# !python ../eval_report_generation.py \
        --checkpoint-folder "models/vqa/20220926_004746_mim+mim(chex)+iu+iu(chex)+chexp(vqa)+cxr14(vqa)+vinbig(vqa)_oevqa(CenIA-clip-vte-vit-lp16bcbf+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16,0.5,0.4,0.4_medtok_orien_chx_ql_amp" \
        --eval-mode "ground-truth" \
        --no-iuxray \
        --batch-size 160 \
        --num-workers 5 \
        --max-processes-for-chexpert-labeler 5
# Out:
# script's arguments:
#    checkpoint_folder: models/vqa/20220926_004746_mim+mim(chex)+iu+iu(chex)+chexp(vqa)+cxr14(vqa)+vinbig(vqa)_oevqa(CenIA-clip-vte-vit-lp16bcbf+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16,0.5,0.4,0.4_medtok_orien_chx_ql_amp
#    eval_mode: ground-truth
#    n_questions_per_report: None
#    qclass_threshold: None
#    batch_size: 160
#    device: GPU
#    num_workers: 5
#    answer_decoding: greedy-search
#    eval_checkpoint_folder: None
#    precomputed_question_probs_path: None
#    precomputed_question_thresholds_path: None
#    eval_iuxray: False
#    eval_mimiccxr: True
#    use_amp: False
#    max_processes_for_chexpert_labeler: 5
# ----- Evaluating model ------
# metadata loaded from /home/pamessina/medvqa-workspace/models/vqa/20220926_004746_mim+mim(chex)+iu+iu(chex)+chexp(vqa)+cxr14(vqa)+vinbig(vqa)_oevqa(CenIA-clip-vte-vit-lp16bcbf+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16,0.5,0.4,0.4_medtok_orien_chx_ql_amp/metadata.json
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Loading iuxray and mimiccxr QA adapted reports ...
# --------------------------------------------------
# 3) Initializing tokenizer ...
# Loading /home/pamessina/medvqa-workspace/cache/vocab__min_freq=10__mode=report__from(qa_adapted_reports__20220904_091601.json;qa_adapted_reports__20220904_095810.json).pkl ...
# --------------------------------------------------
# 4) Estimating maximum answer length ...
# max_answer_length = 15
# --------------------------------------------------
# 5) Defining image transform ...
# mean = (0.5, 0.5, 0.5), std = (0.5, 0.5, 0.5)
# Returning default transform
# --------------------------------------------------
# 6) Defining collate_batch_fn ...
# get_vqa_collate_batch_fn(): dataset_id=1, one_hot_question_offset=0
# checkpoint_names = ['checkpoint_79_chxlmacf1+chxlmicf1+cD+cxr14macf1+cxr14micf1+ema+gacc+oracc+qlmacf1+qlmicf1+vnbgmacf1+vnbgmicf1+wmdcmp=0.6036.pt']
# --------------------------------------------------
# 7) Loading model from checkpoint ...
# checkpoint_path =  /home/pamessina/medvqa-workspace/models/vqa/20220926_004746_mim+mim(chex)+iu+iu(chex)+chexp(vqa)+cxr14(vqa)+vinbig(vqa)_oevqa(CenIA-clip-vte-vit-lp16bcbf+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16,0.5,0.4,0.4_medtok_orien_chx_ql_amp/checkpoint_79_chxlmacf1+chxlmicf1+cD+cxr14macf1+cxr14micf1+ema+gacc+oracc+qlmacf1+qlmicf1+vnbgmacf1+vnbgmicf1+wmdcmp=0.6036.pt
# pretrained_checkpoint_path = /home/pamessina/medvqa-workspace/models/vqa/20220926_004746_mim+mim(chex)+iu+iu(chex)+chexp(vqa)+cxr14(vqa)+vinbig(vqa)_oevqa(CenIA-clip-vte-vit-lp16bcbf+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16,0.5,0.4,0.4_medtok_orien_chx_ql_amp/checkpoint_79_chxlmacf1+chxlmicf1+cD+cxr14macf1+cxr14micf1+ema+gacc+oracc+qlmacf1+qlmicf1+vnbgmacf1+vnbgmicf1+wmdcmp=0.6036.pt
# --------------------------------------------------
# 8) Creating MIMIC-CXR vqa evaluator ...
# report_eval_mode = ground-truth
# Checking if data is already cached in path /home/pamessina/medvqa-workspace/cache/mimiccxr/mimiccxr_preprocessed_test_data__(dataset=qa_adapted_reports__20220904_095810.json;tokenizer=4838,39196,466463750150781738;report_eval_mode=ground-truth).pkl ...
# 	Yes, it is, data successfully loaded :)
# batch_size = 160
# len(self.report_ids) = 32697, len(set(self.report_ids)) = 3258
# VQA_Evaluator():
#   len(self.test_indices) = 32697, len(set(self.report_ids)) = 3258
# generating test dataset ...
# generating test dataloader ...
# done!
# --------------------------------------------------
# 9) Creating instance of OpenEndedVQA model ...
# OpenEndedVQA():
#   image_encoder_pretrained_weights_path None
#   self.global_feat_size = 1024
#   n_questions = 154
#   n_questions_aux_task = 97
#   question_encoding = one-hot
#   answer_decoding = transformer
#   visual_input_mode = raw-image
#   name = oevqa(CenIA/clip-vte-vit-lp16bcbf+onehot+transf)
# --------------------------------------------------
# 10) Creating evaluator engine ...
# get_engine(): shift_answer=False
# --------------------------------------------------
# 11) Attaching metrics, losses, timer and events to engines ...
#
# ========================
# --------------------------------------------------
# 12) Running evaluator engine on MIMIC-CXR test split ...
# len(dataset) = 32697
# len(dataloader) = 205
# Evaluating model ...
# oracc 0.99693, chxlmicf1 0.60683, chxlmacf1 0.49148, chxlacc 0.75250, chxlrocaucmic 0.82386, chxlrocaucmac 0.74964, qlmacf1 0.23994, 207.20 secs
# Computing metrics ...
# recovered reports: len(gen_reports)=3258, len(gt_reports)=3258
# Cache successfully loaded from /home/pamessina/medvqa-workspace/cache/chexpert_labeler_cache.pkl
# (*) Chexpert: labeling 3258 texts ...
# All labels found in cache, no need to invoke chexpert labeler
# (*) Chexpert: labeling 3258 texts ...
# Chexpert labeler: running a maximum of 5 concurrent processes over 5 chunks
# chunk: i=0, b=0, e=650, chunk_size=650
# chunk: i=1, b=650, e=1300, chunk_size=650
# chunk: i=2, b=1300, e=1950, chunk_size=650
# chunk: i=3, b=1950, e=2600, chunk_size=650
# chunk: i=4, b=2600, e=3250, chunk_size=647
# 	#### process 1: running chexpert labeler over 650 texts ...
# 	Command = docker run -v /home/pamessina/medvqa-workspace/tmp/chexpert-labeler:/data chexpert-labeler:latest python label.py --reports_path /data/labeler-input_20220926_071525_0.2222731719208465_0.csv --output_path /data/labeler-output_20220926_071525_0.2222731719208465_0.csv
# 	#### process 2: running chexpert labeler over 650 texts ...
# 	Command = docker run -v /home/pamessina/medvqa-workspace/tmp/chexpert-labeler:/data chexpert-labeler:latest python label.py --reports_path /data/labeler-input_20220926_071525_0.2222731719208465_1.csv --output_path /data/labeler-output_20220926_071525_0.2222731719208465_1.csv
# 	#### process 3: running chexpert labeler over 650 texts ...
# 	Command = docker run -v /home/pamessina/medvqa-workspace/tmp/chexpert-labeler:/data chexpert-labeler:latest python label.py --reports_path /data/labeler-input_20220926_071525_0.2222731719208465_2.csv --output_path /data/labeler-output_20220926_071525_0.2222731719208465_2.csv
# 	#### process 4: running chexpert labeler over 650 texts ...
# 	Command = docker run -v /home/pamessina/medvqa-workspace/tmp/chexpert-labeler:/data chexpert-labeler:latest python label.py --reports_path /data/labeler-input_20220926_071525_0.2222731719208465_3.csv --output_path /data/labeler-output_20220926_071525_0.2222731719208465_3.csv
# 	#### process 5: running chexpert labeler over 647 texts ...
# 	Command = docker run -v /home/pamessina/medvqa-workspace/tmp/chexpert-labeler:/data chexpert-labeler:latest python label.py --reports_path /data/labeler-input_20220926_071525_0.2222731719208465_4.csv --output_path /data/labeler-output_20220926_071525_0.2222731719208465_4.csv
# Generating LALR tables
# Downloading 'http://search.maven.org/remotecontent?filepath=edu/stanford/nlp/stanford-corenlp/3.5.2/stanford-corenlp-3.5.2.jar' -> '/root/.local/share/pystanforddeps/stanford-corenlp-3.5.2.jar'
# Downloading 'http://search.maven.org/remotecontent?filepath=edu/stanford/nlp/stanford-corenlp/3.5.2/stanford-corenlp-3.5.2.jar' -> '/root/.local/share/pystanforddeps/stanford-corenlp-3.5.2.jar'
# Generating LALR tables
# Downloading 'http://search.maven.org/remotecontent?filepath=edu/stanford/nlp/stanford-corenlp/3.5.2/stanford-corenlp-3.5.2.jar' -> '/root/.local/share/pystanforddeps/stanford-corenlp-3.5.2.jar'
# Generating LALR tables
# Generating LALR tables
# Downloading 'http://search.maven.org/remotecontent?filepath=edu/stanford/nlp/stanford-corenlp/3.5.2/stanford-corenlp-3.5.2.jar' -> '/root/.local/share/pystanforddeps/stanford-corenlp-3.5.2.jar'
# Generating LALR tables
# Downloading 'http://search.maven.org/remotecontent?filepath=edu/stanford/nlp/stanford-corenlp/3.5.2/stanford-corenlp-3.5.2.jar' -> '/root/.local/share/pystanforddeps/stanford-corenlp-3.5.2.jar'
# 	**** process 1 finished, elapsed time = 630.0864055156708
# 	**** process 2 finished, elapsed time = 630.086606502533
# 	**** process 3 finished, elapsed time = 630.0866782665253
# 	**** process 4 finished, elapsed time = 630.08673787117
# 	**** process 5 finished, elapsed time = 630.0868294239044
# Report-level metrics successfully saved to /home/pamessina/medvqa-workspace/results/vqa/20220926_004746_mim+mim(chex)+iu+iu(chex)+chexp(vqa)+cxr14(vqa)+vinbig(vqa)_oevqa(CenIA-clip-vte-vit-lp16bcbf+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16,0.5,0.4,0.4_medtok_orien_chx_ql_amp/mimiccxr_report_level_metrics(eval_mode=ground-truth).pkl

# %%
# !python ../eval_report_generation.py \
        --checkpoint-folder "models/vqa/20220926_004746_mim+mim(chex)+iu+iu(chex)+chexp(vqa)+cxr14(vqa)+vinbig(vqa)_oevqa(CenIA-clip-vte-vit-lp16bcbf+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16,0.5,0.4,0.4_medtok_orien_chx_ql_amp" \
        --eval-mode "chexpert-labels" \
        --no-iuxray \
        --batch-size 160 \
        --num-workers 5 \
        --max-processes-for-chexpert-labeler 5
# Out:
# script's arguments:
#    checkpoint_folder: models/vqa/20220926_004746_mim+mim(chex)+iu+iu(chex)+chexp(vqa)+cxr14(vqa)+vinbig(vqa)_oevqa(CenIA-clip-vte-vit-lp16bcbf+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16,0.5,0.4,0.4_medtok_orien_chx_ql_amp
#    eval_mode: chexpert-labels
#    n_questions_per_report: None
#    qclass_threshold: None
#    batch_size: 160
#    device: GPU
#    num_workers: 5
#    answer_decoding: greedy-search
#    eval_checkpoint_folder: None
#    precomputed_question_probs_path: None
#    precomputed_question_thresholds_path: None
#    eval_iuxray: False
#    eval_mimiccxr: True
#    use_amp: False
#    max_processes_for_chexpert_labeler: 5
# ----- Evaluating model ------
# metadata loaded from /home/pamessina/medvqa-workspace/models/vqa/20220926_004746_mim+mim(chex)+iu+iu(chex)+chexp(vqa)+cxr14(vqa)+vinbig(vqa)_oevqa(CenIA-clip-vte-vit-lp16bcbf+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16,0.5,0.4,0.4_medtok_orien_chx_ql_amp/metadata.json
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Loading iuxray and mimiccxr QA adapted reports ...
# --------------------------------------------------
# 3) Initializing tokenizer ...
# Loading /home/pamessina/medvqa-workspace/cache/vocab__min_freq=10__mode=report__from(qa_adapted_reports__20220904_091601.json;qa_adapted_reports__20220904_095810.json).pkl ...
# --------------------------------------------------
# 4) Estimating maximum answer length ...
# max_answer_length = 15
# --------------------------------------------------
# 5) Defining image transform ...
# mean = (0.5, 0.5, 0.5), std = (0.5, 0.5, 0.5)
# Returning default transform
# --------------------------------------------------
# 6) Defining collate_batch_fn ...
# get_vqa_collate_batch_fn(): dataset_id=1, one_hot_question_offset=97
# checkpoint_names = ['checkpoint_79_chxlmacf1+chxlmicf1+cD+cxr14macf1+cxr14micf1+ema+gacc+oracc+qlmacf1+qlmicf1+vnbgmacf1+vnbgmicf1+wmdcmp=0.6036.pt']
# --------------------------------------------------
# 7) Loading model from checkpoint ...
# checkpoint_path =  /home/pamessina/medvqa-workspace/models/vqa/20220926_004746_mim+mim(chex)+iu+iu(chex)+chexp(vqa)+cxr14(vqa)+vinbig(vqa)_oevqa(CenIA-clip-vte-vit-lp16bcbf+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16,0.5,0.4,0.4_medtok_orien_chx_ql_amp/checkpoint_79_chxlmacf1+chxlmicf1+cD+cxr14macf1+cxr14micf1+ema+gacc+oracc+qlmacf1+qlmicf1+vnbgmacf1+vnbgmicf1+wmdcmp=0.6036.pt
# pretrained_checkpoint_path = /home/pamessina/medvqa-workspace/models/vqa/20220926_004746_mim+mim(chex)+iu+iu(chex)+chexp(vqa)+cxr14(vqa)+vinbig(vqa)_oevqa(CenIA-clip-vte-vit-lp16bcbf+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16,0.5,0.4,0.4_medtok_orien_chx_ql_amp/checkpoint_79_chxlmacf1+chxlmicf1+cD+cxr14macf1+cxr14micf1+ema+gacc+oracc+qlmacf1+qlmicf1+vnbgmacf1+vnbgmicf1+wmdcmp=0.6036.pt
# --------------------------------------------------
# 8) Creating MIMIC-CXR vqa evaluator ...
# report_eval_mode = chexpert-labels
# Checking if data is already cached in path /home/pamessina/medvqa-workspace/cache/mimiccxr/mimiccxr_preprocessed_test_data__(dataset=qa_adapted_reports__20220904_095810.json;tokenizer=4838,39196,466463750150781738;report_eval_mode=chexpert-labels).pkl ...
# 	Yes, it is, data successfully loaded :)
# batch_size = 160
# len(self.report_ids) = 45766, len(set(self.report_ids)) = 3269
# VQA_Evaluator():
#   len(self.test_indices) = 45766, len(set(self.report_ids)) = 3269
# generating test dataset ...
# generating test dataloader ...
# done!
# --------------------------------------------------
# 9) Creating instance of OpenEndedVQA model ...
# OpenEndedVQA():
#   image_encoder_pretrained_weights_path None
#   self.global_feat_size = 1024
#   n_questions = 154
#   n_questions_aux_task = 97
#   question_encoding = one-hot
#   answer_decoding = transformer
#   visual_input_mode = raw-image
#   name = oevqa(CenIA/clip-vte-vit-lp16bcbf+onehot+transf)
# --------------------------------------------------
# 10) Creating evaluator engine ...
# get_engine(): shift_answer=False
# --------------------------------------------------
# 11) Attaching metrics, losses, timer and events to engines ...
#
# ========================
# --------------------------------------------------
# 12) Running evaluator engine on MIMIC-CXR test split ...
# len(dataset) = 45766
# len(dataloader) = 287
# Evaluating model ...
# oracc 0.99671, chxlmicf1 0.58698, chxlmacf1 0.47594, chxlacc 0.75010, chxlrocaucmic 0.82248, chxlrocaucmac 0.74795, qlmacf1 0.22294, 288.60 secs
# Computing metrics ...
# recovered reports: len(gen_reports)=3269, len(gt_reports)=3269
# Cache successfully loaded from /home/pamessina/medvqa-workspace/cache/chexpert_labeler_cache.pkl
# (*) Chexpert: labeling 3269 texts ...
# All labels found in cache, no need to invoke chexpert labeler
# (*) Chexpert: labeling 3269 texts ...
# Chexpert labeler: running a maximum of 5 concurrent processes over 5 chunks
# chunk: i=0, b=0, e=182, chunk_size=182
# chunk: i=1, b=182, e=364, chunk_size=182
# chunk: i=2, b=364, e=546, chunk_size=182
# chunk: i=3, b=546, e=728, chunk_size=182
# chunk: i=4, b=728, e=910, chunk_size=178
# 	#### process 1: running chexpert labeler over 182 texts ...
# 	Command = docker run -v /home/pamessina/medvqa-workspace/tmp/chexpert-labeler:/data chexpert-labeler:latest python label.py --reports_path /data/labeler-input_20220926_073142_0.7897313963856547_0.csv --output_path /data/labeler-output_20220926_073142_0.7897313963856547_0.csv
# 	#### process 2: running chexpert labeler over 182 texts ...
# 	Command = docker run -v /home/pamessina/medvqa-workspace/tmp/chexpert-labeler:/data chexpert-labeler:latest python label.py --reports_path /data/labeler-input_20220926_073142_0.7897313963856547_1.csv --output_path /data/labeler-output_20220926_073142_0.7897313963856547_1.csv
# 	#### process 3: running chexpert labeler over 182 texts ...
# 	Command = docker run -v /home/pamessina/medvqa-workspace/tmp/chexpert-labeler:/data chexpert-labeler:latest python label.py --reports_path /data/labeler-input_20220926_073142_0.7897313963856547_2.csv --output_path /data/labeler-output_20220926_073142_0.7897313963856547_2.csv
# 	#### process 4: running chexpert labeler over 182 texts ...
# 	Command = docker run -v /home/pamessina/medvqa-workspace/tmp/chexpert-labeler:/data chexpert-labeler:latest python label.py --reports_path /data/labeler-input_20220926_073142_0.7897313963856547_3.csv --output_path /data/labeler-output_20220926_073142_0.7897313963856547_3.csv
# 	#### process 5: running chexpert labeler over 178 texts ...
# 	Command = docker run -v /home/pamessina/medvqa-workspace/tmp/chexpert-labeler:/data chexpert-labeler:latest python label.py --reports_path /data/labeler-input_20220926_073142_0.7897313963856547_4.csv --output_path /data/labeler-output_20220926_073142_0.7897313963856547_4.csv
# Generating LALR tables
# Downloading 'http://search.maven.org/remotecontent?filepath=edu/stanford/nlp/stanford-corenlp/3.5.2/stanford-corenlp-3.5.2.jar' -> '/root/.local/share/pystanforddeps/stanford-corenlp-3.5.2.jar'
# Generating LALR tables
# Downloading 'http://search.maven.org/remotecontent?filepath=edu/stanford/nlp/stanford-corenlp/3.5.2/stanford-corenlp-3.5.2.jar' -> '/root/.local/share/pystanforddeps/stanford-corenlp-3.5.2.jar'
# Generating LALR tables
# Downloading 'http://search.maven.org/remotecontent?filepath=edu/stanford/nlp/stanford-corenlp/3.5.2/stanford-corenlp-3.5.2.jar' -> '/root/.local/share/pystanforddeps/stanford-corenlp-3.5.2.jar'
# 	**** process 1 finished, elapsed time = 94.55685687065125
# 	**** process 2 finished, elapsed time = 94.79779481887817
# Generating LALR tables
# Downloading 'http://search.maven.org/remotecontent?filepath=edu/stanford/nlp/stanford-corenlp/3.5.2/stanford-corenlp-3.5.2.jar' -> '/root/.local/share/pystanforddeps/stanford-corenlp-3.5.2.jar'
# Generating LALR tables
# Downloading 'http://search.maven.org/remotecontent?filepath=edu/stanford/nlp/stanford-corenlp/3.5.2/stanford-corenlp-3.5.2.jar' -> '/root/.local/share/pystanforddeps/stanford-corenlp-3.5.2.jar'
# 	**** process 3 finished, elapsed time = 97.69550228118896
# 	**** process 4 finished, elapsed time = 97.69561624526978
# 	**** process 5 finished, elapsed time = 97.6956799030304
# Report-level metrics successfully saved to /home/pamessina/medvqa-workspace/results/vqa/20220926_004746_mim+mim(chex)+iu+iu(chex)+chexp(vqa)+cxr14(vqa)+vinbig(vqa)_oevqa(CenIA-clip-vte-vit-lp16bcbf+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16,0.5,0.4,0.4_medtok_orien_chx_ql_amp/mimiccxr_report_level_metrics(eval_mode=chexpert-labels).pkl

# %%
# !python ../eval_report_generation.py \
        --checkpoint-folder "models/vqa/20220926_074409_mim+mim(chex)+iu+iu(chex)_oevqa(CenIA-clip-vte-vit-lp16bcbf+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16_medtok_orien_chx_ql_amp" \
        --eval-mode "ground-truth" \
        --no-iuxray \
        --batch-size 160 \
        --num-workers 5 \
        --max-processes-for-chexpert-labeler 5
# Out:
# script's arguments:
#    checkpoint_folder: models/vqa/20220926_074409_mim+mim(chex)+iu+iu(chex)_oevqa(CenIA-clip-vte-vit-lp16bcbf+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16_medtok_orien_chx_ql_amp
#    eval_mode: ground-truth
#    n_questions_per_report: None
#    qclass_threshold: None
#    batch_size: 160
#    device: GPU
#    num_workers: 5
#    answer_decoding: greedy-search
#    eval_checkpoint_folder: None
#    precomputed_question_probs_path: None
#    precomputed_question_thresholds_path: None
#    eval_iuxray: False
#    eval_mimiccxr: True
#    use_amp: False
#    max_processes_for_chexpert_labeler: 5
# ----- Evaluating model ------
# metadata loaded from /home/pamessina/medvqa-workspace/models/vqa/20220926_074409_mim+mim(chex)+iu+iu(chex)_oevqa(CenIA-clip-vte-vit-lp16bcbf+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16_medtok_orien_chx_ql_amp/metadata.json
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Loading iuxray and mimiccxr QA adapted reports ...
# --------------------------------------------------
# 3) Initializing tokenizer ...
# Loading /home/pamessina/medvqa-workspace/cache/vocab__min_freq=10__mode=report__from(qa_adapted_reports__20220904_091601.json;qa_adapted_reports__20220904_095810.json).pkl ...
# --------------------------------------------------
# 4) Estimating maximum answer length ...
# max_answer_length = 15
# --------------------------------------------------
# 5) Defining image transform ...
# mean = (0.5, 0.5, 0.5), std = (0.5, 0.5, 0.5)
# Returning default transform
# --------------------------------------------------
# 6) Defining collate_batch_fn ...
# get_vqa_collate_batch_fn(): dataset_id=1, one_hot_question_offset=0
# checkpoint_names = ['checkpoint_75_chxlmacf1+chxlmicf1+cD+ema+oracc+qlmacf1+qlmicf1+wmdcmp=0.5985.pt']
# --------------------------------------------------
# 7) Loading model from checkpoint ...
# checkpoint_path =  /home/pamessina/medvqa-workspace/models/vqa/20220926_074409_mim+mim(chex)+iu+iu(chex)_oevqa(CenIA-clip-vte-vit-lp16bcbf+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16_medtok_orien_chx_ql_amp/checkpoint_75_chxlmacf1+chxlmicf1+cD+ema+oracc+qlmacf1+qlmicf1+wmdcmp=0.5985.pt
# pretrained_checkpoint_path = /home/pamessina/medvqa-workspace/models/vqa/20220926_074409_mim+mim(chex)+iu+iu(chex)_oevqa(CenIA-clip-vte-vit-lp16bcbf+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16_medtok_orien_chx_ql_amp/checkpoint_75_chxlmacf1+chxlmicf1+cD+ema+oracc+qlmacf1+qlmicf1+wmdcmp=0.5985.pt
# --------------------------------------------------
# 8) Creating MIMIC-CXR vqa evaluator ...
# report_eval_mode = ground-truth
# Checking if data is already cached in path /home/pamessina/medvqa-workspace/cache/mimiccxr/mimiccxr_preprocessed_test_data__(dataset=qa_adapted_reports__20220904_095810.json;tokenizer=4838,39196,466463750150781738;report_eval_mode=ground-truth).pkl ...
# 	Yes, it is, data successfully loaded :)
# batch_size = 160
# len(self.report_ids) = 32697, len(set(self.report_ids)) = 3258
# VQA_Evaluator():
#   len(self.test_indices) = 32697, len(set(self.report_ids)) = 3258
# generating test dataset ...
# generating test dataloader ...
# done!
# --------------------------------------------------
# 9) Creating instance of OpenEndedVQA model ...
# OpenEndedVQA():
#   image_encoder_pretrained_weights_path None
#   self.global_feat_size = 1024
#   n_questions = 111
#   n_questions_aux_task = 97
#   question_encoding = one-hot
#   answer_decoding = transformer
#   visual_input_mode = raw-image
#   name = oevqa(CenIA/clip-vte-vit-lp16bcbf+onehot+transf)
# --------------------------------------------------
# 10) Creating evaluator engine ...
# get_engine(): shift_answer=False
# --------------------------------------------------
# 11) Attaching metrics, losses, timer and events to engines ...
#
# ========================
# --------------------------------------------------
# 12) Running evaluator engine on MIMIC-CXR test split ...
# len(dataset) = 32697
# len(dataloader) = 205
# Evaluating model ...
# oracc 0.99693, chxlmicf1 0.60974, chxlmacf1 0.48507, chxlacc 0.75695, chxlrocaucmic 0.82429, chxlrocaucmac 0.74375, qlmacf1 0.23596, 206.94 secs
# Computing metrics ...
# recovered reports: len(gen_reports)=3258, len(gt_reports)=3258
# Cache successfully loaded from /home/pamessina/medvqa-workspace/cache/chexpert_labeler_cache.pkl
# (*) Chexpert: labeling 3258 texts ...
# All labels found in cache, no need to invoke chexpert labeler
# (*) Chexpert: labeling 3258 texts ...
# Chexpert labeler: running a maximum of 5 concurrent processes over 5 chunks
# chunk: i=0, b=0, e=650, chunk_size=650
# chunk: i=1, b=650, e=1300, chunk_size=650
# chunk: i=2, b=1300, e=1950, chunk_size=650
# chunk: i=3, b=1950, e=2600, chunk_size=650
# chunk: i=4, b=2600, e=3250, chunk_size=647
# 	#### process 1: running chexpert labeler over 650 texts ...
# 	Command = docker run -v /home/pamessina/medvqa-workspace/tmp/chexpert-labeler:/data chexpert-labeler:latest python label.py --reports_path /data/labeler-input_20220926_144703_0.31393482779859616_0.csv --output_path /data/labeler-output_20220926_144703_0.31393482779859616_0.csv
# 	#### process 2: running chexpert labeler over 650 texts ...
# 	Command = docker run -v /home/pamessina/medvqa-workspace/tmp/chexpert-labeler:/data chexpert-labeler:latest python label.py --reports_path /data/labeler-input_20220926_144703_0.31393482779859616_1.csv --output_path /data/labeler-output_20220926_144703_0.31393482779859616_1.csv
# 	#### process 3: running chexpert labeler over 650 texts ...
# 	Command = docker run -v /home/pamessina/medvqa-workspace/tmp/chexpert-labeler:/data chexpert-labeler:latest python label.py --reports_path /data/labeler-input_20220926_144703_0.31393482779859616_2.csv --output_path /data/labeler-output_20220926_144703_0.31393482779859616_2.csv
# 	#### process 4: running chexpert labeler over 650 texts ...
# 	Command = docker run -v /home/pamessina/medvqa-workspace/tmp/chexpert-labeler:/data chexpert-labeler:latest python label.py --reports_path /data/labeler-input_20220926_144703_0.31393482779859616_3.csv --output_path /data/labeler-output_20220926_144703_0.31393482779859616_3.csv
# 	#### process 5: running chexpert labeler over 647 texts ...
# 	Command = docker run -v /home/pamessina/medvqa-workspace/tmp/chexpert-labeler:/data chexpert-labeler:latest python label.py --reports_path /data/labeler-input_20220926_144703_0.31393482779859616_4.csv --output_path /data/labeler-output_20220926_144703_0.31393482779859616_4.csv
# Downloading 'http://search.maven.org/remotecontent?filepath=edu/stanford/nlp/stanford-corenlp/3.5.2/stanford-corenlp-3.5.2.jar' -> '/root/.local/share/pystanforddeps/stanford-corenlp-3.5.2.jar'
# Generating LALR tables
# Downloading 'http://search.maven.org/remotecontent?filepath=edu/stanford/nlp/stanford-corenlp/3.5.2/stanford-corenlp-3.5.2.jar' -> '/root/.local/share/pystanforddeps/stanford-corenlp-3.5.2.jar'
# Generating LALR tables
# Downloading 'http://search.maven.org/remotecontent?filepath=edu/stanford/nlp/stanford-corenlp/3.5.2/stanford-corenlp-3.5.2.jar' -> '/root/.local/share/pystanforddeps/stanford-corenlp-3.5.2.jar'
# Generating LALR tables
# Generating LALR tables
# Downloading 'http://search.maven.org/remotecontent?filepath=edu/stanford/nlp/stanford-corenlp/3.5.2/stanford-corenlp-3.5.2.jar' -> '/root/.local/share/pystanforddeps/stanford-corenlp-3.5.2.jar'
# Downloading 'http://search.maven.org/remotecontent?filepath=edu/stanford/nlp/stanford-corenlp/3.5.2/stanford-corenlp-3.5.2.jar' -> '/root/.local/share/pystanforddeps/stanford-corenlp-3.5.2.jar'
# Generating LALR tables
# 	**** process 1 finished, elapsed time = 569.8580322265625
# 	**** process 2 finished, elapsed time = 569.8582220077515
# 	**** process 3 finished, elapsed time = 569.8582923412323
# 	**** process 4 finished, elapsed time = 569.858350276947
# 	**** process 5 finished, elapsed time = 569.8584067821503
# Report-level metrics successfully saved to /home/pamessina/medvqa-workspace/results/vqa/20220926_074409_mim+mim(chex)+iu+iu(chex)_oevqa(CenIA-clip-vte-vit-lp16bcbf+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16_medtok_orien_chx_ql_amp/mimiccxr_report_level_metrics(eval_mode=ground-truth).pkl

# %%
# !python ../eval_report_generation.py \
        --checkpoint-folder "models/vqa/20220926_074409_mim+mim(chex)+iu+iu(chex)_oevqa(CenIA-clip-vte-vit-lp16bcbf+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16_medtok_orien_chx_ql_amp" \
        --eval-mode "chexpert-labels" \
        --no-iuxray \
        --batch-size 160 \
        --num-workers 5 \
        --max-processes-for-chexpert-labeler 5
# Out:
# script's arguments:
#    checkpoint_folder: models/vqa/20220926_074409_mim+mim(chex)+iu+iu(chex)_oevqa(CenIA-clip-vte-vit-lp16bcbf+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16_medtok_orien_chx_ql_amp
#    eval_mode: chexpert-labels
#    n_questions_per_report: None
#    qclass_threshold: None
#    batch_size: 160
#    device: GPU
#    num_workers: 5
#    answer_decoding: greedy-search
#    eval_checkpoint_folder: None
#    precomputed_question_probs_path: None
#    precomputed_question_thresholds_path: None
#    eval_iuxray: False
#    eval_mimiccxr: True
#    use_amp: False
#    max_processes_for_chexpert_labeler: 5
# ----- Evaluating model ------
# metadata loaded from /home/pamessina/medvqa-workspace/models/vqa/20220926_074409_mim+mim(chex)+iu+iu(chex)_oevqa(CenIA-clip-vte-vit-lp16bcbf+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16_medtok_orien_chx_ql_amp/metadata.json
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Loading iuxray and mimiccxr QA adapted reports ...
# --------------------------------------------------
# 3) Initializing tokenizer ...
# Loading /home/pamessina/medvqa-workspace/cache/vocab__min_freq=10__mode=report__from(qa_adapted_reports__20220904_091601.json;qa_adapted_reports__20220904_095810.json).pkl ...
# --------------------------------------------------
# 4) Estimating maximum answer length ...
# max_answer_length = 15
# --------------------------------------------------
# 5) Defining image transform ...
# mean = (0.5, 0.5, 0.5), std = (0.5, 0.5, 0.5)
# Returning default transform
# --------------------------------------------------
# 6) Defining collate_batch_fn ...
# get_vqa_collate_batch_fn(): dataset_id=1, one_hot_question_offset=97
# checkpoint_names = ['checkpoint_75_chxlmacf1+chxlmicf1+cD+ema+oracc+qlmacf1+qlmicf1+wmdcmp=0.5985.pt']
# --------------------------------------------------
# 7) Loading model from checkpoint ...
# checkpoint_path =  /home/pamessina/medvqa-workspace/models/vqa/20220926_074409_mim+mim(chex)+iu+iu(chex)_oevqa(CenIA-clip-vte-vit-lp16bcbf+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16_medtok_orien_chx_ql_amp/checkpoint_75_chxlmacf1+chxlmicf1+cD+ema+oracc+qlmacf1+qlmicf1+wmdcmp=0.5985.pt
# pretrained_checkpoint_path = /home/pamessina/medvqa-workspace/models/vqa/20220926_074409_mim+mim(chex)+iu+iu(chex)_oevqa(CenIA-clip-vte-vit-lp16bcbf+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16_medtok_orien_chx_ql_amp/checkpoint_75_chxlmacf1+chxlmicf1+cD+ema+oracc+qlmacf1+qlmicf1+wmdcmp=0.5985.pt
# --------------------------------------------------
# 8) Creating MIMIC-CXR vqa evaluator ...
# report_eval_mode = chexpert-labels
# Checking if data is already cached in path /home/pamessina/medvqa-workspace/cache/mimiccxr/mimiccxr_preprocessed_test_data__(dataset=qa_adapted_reports__20220904_095810.json;tokenizer=4838,39196,466463750150781738;report_eval_mode=chexpert-labels).pkl ...
# 	Yes, it is, data successfully loaded :)
# batch_size = 160
# len(self.report_ids) = 45766, len(set(self.report_ids)) = 3269
# VQA_Evaluator():
#   len(self.test_indices) = 45766, len(set(self.report_ids)) = 3269
# generating test dataset ...
# generating test dataloader ...
# done!
# --------------------------------------------------
# 9) Creating instance of OpenEndedVQA model ...
# OpenEndedVQA():
#   image_encoder_pretrained_weights_path None
#   self.global_feat_size = 1024
#   n_questions = 111
#   n_questions_aux_task = 97
#   question_encoding = one-hot
#   answer_decoding = transformer
#   visual_input_mode = raw-image
#   name = oevqa(CenIA/clip-vte-vit-lp16bcbf+onehot+transf)
# --------------------------------------------------
# 10) Creating evaluator engine ...
# get_engine(): shift_answer=False
# --------------------------------------------------
# 11) Attaching metrics, losses, timer and events to engines ...
#
# ========================
# --------------------------------------------------
# 12) Running evaluator engine on MIMIC-CXR test split ...
# len(dataset) = 45766
# len(dataloader) = 287
# Evaluating model ...
# oracc 0.99671, chxlmicf1 0.59033, chxlmacf1 0.47128, chxlacc 0.75477, chxlrocaucmic 0.82335, chxlrocaucmac 0.74281, qlmacf1 0.21872, 288.15 secs
# Computing metrics ...
# recovered reports: len(gen_reports)=3269, len(gt_reports)=3269
# Cache successfully loaded from /home/pamessina/medvqa-workspace/cache/chexpert_labeler_cache.pkl
# (*) Chexpert: labeling 3269 texts ...
# All labels found in cache, no need to invoke chexpert labeler
# (*) Chexpert: labeling 3269 texts ...
# Chexpert labeler: running a maximum of 5 concurrent processes over 5 chunks
# chunk: i=0, b=0, e=195, chunk_size=195
# chunk: i=1, b=195, e=390, chunk_size=195
# chunk: i=2, b=390, e=585, chunk_size=195
# chunk: i=3, b=585, e=780, chunk_size=195
# chunk: i=4, b=780, e=975, chunk_size=191
# 	#### process 1: running chexpert labeler over 195 texts ...
# 	Command = docker run -v /home/pamessina/medvqa-workspace/tmp/chexpert-labeler:/data chexpert-labeler:latest python label.py --reports_path /data/labeler-input_20220926_150218_0.8411607264154969_0.csv --output_path /data/labeler-output_20220926_150218_0.8411607264154969_0.csv
# 	#### process 2: running chexpert labeler over 195 texts ...
# 	Command = docker run -v /home/pamessina/medvqa-workspace/tmp/chexpert-labeler:/data chexpert-labeler:latest python label.py --reports_path /data/labeler-input_20220926_150218_0.8411607264154969_1.csv --output_path /data/labeler-output_20220926_150218_0.8411607264154969_1.csv
# 	#### process 3: running chexpert labeler over 195 texts ...
# 	Command = docker run -v /home/pamessina/medvqa-workspace/tmp/chexpert-labeler:/data chexpert-labeler:latest python label.py --reports_path /data/labeler-input_20220926_150218_0.8411607264154969_2.csv --output_path /data/labeler-output_20220926_150218_0.8411607264154969_2.csv
# 	#### process 4: running chexpert labeler over 195 texts ...
# 	Command = docker run -v /home/pamessina/medvqa-workspace/tmp/chexpert-labeler:/data chexpert-labeler:latest python label.py --reports_path /data/labeler-input_20220926_150218_0.8411607264154969_3.csv --output_path /data/labeler-output_20220926_150218_0.8411607264154969_3.csv
# 	#### process 5: running chexpert labeler over 191 texts ...
# 	Command = docker run -v /home/pamessina/medvqa-workspace/tmp/chexpert-labeler:/data chexpert-labeler:latest python label.py --reports_path /data/labeler-input_20220926_150218_0.8411607264154969_4.csv --output_path /data/labeler-output_20220926_150218_0.8411607264154969_4.csv
# Downloading 'http://search.maven.org/remotecontent?filepath=edu/stanford/nlp/stanford-corenlp/3.5.2/stanford-corenlp-3.5.2.jar' -> '/root/.local/share/pystanforddeps/stanford-corenlp-3.5.2.jar'
# Generating LALR tables
# Generating LALR tables
# Downloading 'http://search.maven.org/remotecontent?filepath=edu/stanford/nlp/stanford-corenlp/3.5.2/stanford-corenlp-3.5.2.jar' -> '/root/.local/share/pystanforddeps/stanford-corenlp-3.5.2.jar'
# 	**** process 1 finished, elapsed time = 95.21625113487244
# 	**** process 2 finished, elapsed time = 95.30228185653687
# Generating LALR tables
# Downloading 'http://search.maven.org/remotecontent?filepath=edu/stanford/nlp/stanford-corenlp/3.5.2/stanford-corenlp-3.5.2.jar' -> '/root/.local/share/pystanforddeps/stanford-corenlp-3.5.2.jar'
# Downloading 'http://search.maven.org/remotecontent?filepath=edu/stanford/nlp/stanford-corenlp/3.5.2/stanford-corenlp-3.5.2.jar' -> '/root/.local/share/pystanforddeps/stanford-corenlp-3.5.2.jar'
# Generating LALR tables
# 	**** process 3 finished, elapsed time = 98.23486256599426
# Generating LALR tables
# Downloading 'http://search.maven.org/remotecontent?filepath=edu/stanford/nlp/stanford-corenlp/3.5.2/stanford-corenlp-3.5.2.jar' -> '/root/.local/share/pystanforddeps/stanford-corenlp-3.5.2.jar'
# 	**** process 4 finished, elapsed time = 98.73843121528625
# 	**** process 5 finished, elapsed time = 98.73853707313538
# Report-level metrics successfully saved to /home/pamessina/medvqa-workspace/results/vqa/20220926_074409_mim+mim(chex)+iu+iu(chex)_oevqa(CenIA-clip-vte-vit-lp16bcbf+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16_medtok_orien_chx_ql_amp/mimiccxr_report_level_metrics(eval_mode=chexpert-labels).pkl

# %%
# !python ../eval_report_generation.py \
        --checkpoint-folder "models/vqa/20220926_073839_mim+mim(chex)+iu+iu(chex)+chexp(vqa)+cxr14(vqa)+vinbig(vqa)_oevqa(CenIA-clip-vte-vit-bp16bcbf+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16,0.5,0.4,0.4_medtok_orien_chx_ql_amp" \
        --eval-mode "ground-truth" \
        --no-iuxray \
        --batch-size 160 \
        --num-workers 5 \
        --max-processes-for-chexpert-labeler 5
# Out:
# script's arguments:
#    checkpoint_folder: models/vqa/20220926_073839_mim+mim(chex)+iu+iu(chex)+chexp(vqa)+cxr14(vqa)+vinbig(vqa)_oevqa(CenIA-clip-vte-vit-bp16bcbf+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16,0.5,0.4,0.4_medtok_orien_chx_ql_amp
#    eval_mode: ground-truth
#    n_questions_per_report: None
#    qclass_threshold: None
#    batch_size: 160
#    device: GPU
#    num_workers: 5
#    answer_decoding: greedy-search
#    eval_checkpoint_folder: None
#    precomputed_question_probs_path: None
#    precomputed_question_thresholds_path: None
#    eval_iuxray: False
#    eval_mimiccxr: True
#    use_amp: False
#    max_processes_for_chexpert_labeler: 5
# ----- Evaluating model ------
# metadata loaded from /home/pamessina/medvqa-workspace/models/vqa/20220926_073839_mim+mim(chex)+iu+iu(chex)+chexp(vqa)+cxr14(vqa)+vinbig(vqa)_oevqa(CenIA-clip-vte-vit-bp16bcbf+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16,0.5,0.4,0.4_medtok_orien_chx_ql_amp/metadata.json
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Loading iuxray and mimiccxr QA adapted reports ...
# --------------------------------------------------
# 3) Initializing tokenizer ...
# Loading /home/pamessina/medvqa-workspace/cache/vocab__min_freq=10__mode=report__from(qa_adapted_reports__20220904_091601.json;qa_adapted_reports__20220904_095810.json).pkl ...
# --------------------------------------------------
# 4) Estimating maximum answer length ...
# max_answer_length = 15
# --------------------------------------------------
# 5) Defining image transform ...
# mean = (0.5, 0.5, 0.5), std = (0.5, 0.5, 0.5)
# Returning default transform
# --------------------------------------------------
# 6) Defining collate_batch_fn ...
# get_vqa_collate_batch_fn(): dataset_id=1, one_hot_question_offset=0
# checkpoint_names = ['checkpoint_52_chxlmacf1+chxlmicf1+cD+cxr14macf1+cxr14micf1+ema+gacc+oracc+qlmacf1+qlmicf1+vnbgmacf1+vnbgmicf1+wmdcmp=0.6052.pt']
# --------------------------------------------------
# 7) Loading model from checkpoint ...
# checkpoint_path =  /home/pamessina/medvqa-workspace/models/vqa/20220926_073839_mim+mim(chex)+iu+iu(chex)+chexp(vqa)+cxr14(vqa)+vinbig(vqa)_oevqa(CenIA-clip-vte-vit-bp16bcbf+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16,0.5,0.4,0.4_medtok_orien_chx_ql_amp/checkpoint_52_chxlmacf1+chxlmicf1+cD+cxr14macf1+cxr14micf1+ema+gacc+oracc+qlmacf1+qlmicf1+vnbgmacf1+vnbgmicf1+wmdcmp=0.6052.pt
# pretrained_checkpoint_path = /home/pamessina/medvqa-workspace/models/vqa/20220926_073839_mim+mim(chex)+iu+iu(chex)+chexp(vqa)+cxr14(vqa)+vinbig(vqa)_oevqa(CenIA-clip-vte-vit-bp16bcbf+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16,0.5,0.4,0.4_medtok_orien_chx_ql_amp/checkpoint_52_chxlmacf1+chxlmicf1+cD+cxr14macf1+cxr14micf1+ema+gacc+oracc+qlmacf1+qlmicf1+vnbgmacf1+vnbgmicf1+wmdcmp=0.6052.pt
# --------------------------------------------------
# 8) Creating MIMIC-CXR vqa evaluator ...
# report_eval_mode = ground-truth
# Checking if data is already cached in path /home/pamessina/medvqa-workspace/cache/mimiccxr/mimiccxr_preprocessed_test_data__(dataset=qa_adapted_reports__20220904_095810.json;tokenizer=4838,39196,466463750150781738;report_eval_mode=ground-truth).pkl ...
# 	Yes, it is, data successfully loaded :)
# batch_size = 160
# len(self.report_ids) = 32697, len(set(self.report_ids)) = 3258
# VQA_Evaluator():
#   len(self.test_indices) = 32697, len(set(self.report_ids)) = 3258
# generating test dataset ...
# generating test dataloader ...
# done!
# --------------------------------------------------
# 9) Creating instance of OpenEndedVQA model ...
# OpenEndedVQA():
#   image_encoder_pretrained_weights_path None
#   self.global_feat_size = 768
#   n_questions = 154
#   n_questions_aux_task = 97
#   question_encoding = one-hot
#   answer_decoding = transformer
#   visual_input_mode = raw-image
#   name = oevqa(CenIA/clip-vte-vit-bp16bcbf+onehot+transf)
# --------------------------------------------------
# 10) Creating evaluator engine ...
# get_engine(): shift_answer=False
# --------------------------------------------------
# 11) Attaching metrics, losses, timer and events to engines ...
#
# ========================
# --------------------------------------------------
# 12) Running evaluator engine on MIMIC-CXR test split ...
# len(dataset) = 32697
# len(dataloader) = 205
# Evaluating model ...
# oracc 0.99771, chxlmicf1 0.60435, chxlmacf1 0.49120, chxlacc 0.75532, chxlrocaucmic 0.82475, chxlrocaucmac 0.75664, qlmacf1 0.23795, 95.34 secs
# Computing metrics ...
# recovered reports: len(gen_reports)=3258, len(gt_reports)=3258
# Cache successfully loaded from /home/pamessina/medvqa-workspace/cache/chexpert_labeler_cache.pkl
# (*) Chexpert: labeling 3258 texts ...
# All labels found in cache, no need to invoke chexpert labeler
# (*) Chexpert: labeling 3258 texts ...
# Chexpert labeler: running a maximum of 5 concurrent processes over 5 chunks
# chunk: i=0, b=0, e=650, chunk_size=650
# chunk: i=1, b=650, e=1300, chunk_size=650
# chunk: i=2, b=1300, e=1950, chunk_size=650
# chunk: i=3, b=1950, e=2600, chunk_size=650
# chunk: i=4, b=2600, e=3250, chunk_size=650
# 	#### process 1: running chexpert labeler over 650 texts ...
# 	Command = docker run -v /home/pamessina/medvqa-workspace/tmp/chexpert-labeler:/data chexpert-labeler:latest python label.py --reports_path /data/labeler-input_20220926_150626_0.858387872594716_0.csv --output_path /data/labeler-output_20220926_150626_0.858387872594716_0.csv
# 	#### process 2: running chexpert labeler over 650 texts ...
# 	Command = docker run -v /home/pamessina/medvqa-workspace/tmp/chexpert-labeler:/data chexpert-labeler:latest python label.py --reports_path /data/labeler-input_20220926_150626_0.858387872594716_1.csv --output_path /data/labeler-output_20220926_150626_0.858387872594716_1.csv
# 	#### process 3: running chexpert labeler over 650 texts ...
# 	Command = docker run -v /home/pamessina/medvqa-workspace/tmp/chexpert-labeler:/data chexpert-labeler:latest python label.py --reports_path /data/labeler-input_20220926_150626_0.858387872594716_2.csv --output_path /data/labeler-output_20220926_150626_0.858387872594716_2.csv
# 	#### process 4: running chexpert labeler over 650 texts ...
# 	Command = docker run -v /home/pamessina/medvqa-workspace/tmp/chexpert-labeler:/data chexpert-labeler:latest python label.py --reports_path /data/labeler-input_20220926_150626_0.858387872594716_3.csv --output_path /data/labeler-output_20220926_150626_0.858387872594716_3.csv
# 	#### process 5: running chexpert labeler over 650 texts ...
# 	Command = docker run -v /home/pamessina/medvqa-workspace/tmp/chexpert-labeler:/data chexpert-labeler:latest python label.py --reports_path /data/labeler-input_20220926_150626_0.858387872594716_4.csv --output_path /data/labeler-output_20220926_150626_0.858387872594716_4.csv
# Generating LALR tables
# Downloading 'http://search.maven.org/remotecontent?filepath=edu/stanford/nlp/stanford-corenlp/3.5.2/stanford-corenlp-3.5.2.jar' -> '/root/.local/share/pystanforddeps/stanford-corenlp-3.5.2.jar'
# Generating LALR tables
# Downloading 'http://search.maven.org/remotecontent?filepath=edu/stanford/nlp/stanford-corenlp/3.5.2/stanford-corenlp-3.5.2.jar' -> '/root/.local/share/pystanforddeps/stanford-corenlp-3.5.2.jar'
# Generating LALR tables
# Downloading 'http://search.maven.org/remotecontent?filepath=edu/stanford/nlp/stanford-corenlp/3.5.2/stanford-corenlp-3.5.2.jar' -> '/root/.local/share/pystanforddeps/stanford-corenlp-3.5.2.jar'
# 	**** process 1 finished, elapsed time = 524.2227559089661
# Downloading 'http://search.maven.org/remotecontent?filepath=edu/stanford/nlp/stanford-corenlp/3.5.2/stanford-corenlp-3.5.2.jar' -> '/root/.local/share/pystanforddeps/stanford-corenlp-3.5.2.jar'
# Generating LALR tables
# 	**** process 2 finished, elapsed time = 526.0827276706696
# 	**** process 3 finished, elapsed time = 526.0828444957733
# Generating LALR tables
# Downloading 'http://search.maven.org/remotecontent?filepath=edu/stanford/nlp/stanford-corenlp/3.5.2/stanford-corenlp-3.5.2.jar' -> '/root/.local/share/pystanforddeps/stanford-corenlp-3.5.2.jar'
# 	**** process 4 finished, elapsed time = 532.4333679676056
# 	**** process 5 finished, elapsed time = 532.4334754943848
# Report-level metrics successfully saved to /home/pamessina/medvqa-workspace/results/vqa/20220926_073839_mim+mim(chex)+iu+iu(chex)+chexp(vqa)+cxr14(vqa)+vinbig(vqa)_oevqa(CenIA-clip-vte-vit-bp16bcbf+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16,0.5,0.4,0.4_medtok_orien_chx_ql_amp/mimiccxr_report_level_metrics(eval_mode=ground-truth).pkl

# %%
# !python ../eval_report_generation.py \
        --checkpoint-folder "models/vqa/20220926_073839_mim+mim(chex)+iu+iu(chex)+chexp(vqa)+cxr14(vqa)+vinbig(vqa)_oevqa(CenIA-clip-vte-vit-bp16bcbf+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16,0.5,0.4,0.4_medtok_orien_chx_ql_amp" \
        --eval-mode "chexpert-labels" \
        --no-iuxray \
        --batch-size 160 \
        --num-workers 5 \
        --max-processes-for-chexpert-labeler 5
# Out:
# script's arguments:
#    checkpoint_folder: models/vqa/20220926_073839_mim+mim(chex)+iu+iu(chex)+chexp(vqa)+cxr14(vqa)+vinbig(vqa)_oevqa(CenIA-clip-vte-vit-bp16bcbf+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16,0.5,0.4,0.4_medtok_orien_chx_ql_amp
#    eval_mode: chexpert-labels
#    n_questions_per_report: None
#    qclass_threshold: None
#    batch_size: 160
#    device: GPU
#    num_workers: 5
#    answer_decoding: greedy-search
#    eval_checkpoint_folder: None
#    precomputed_question_probs_path: None
#    precomputed_question_thresholds_path: None
#    eval_iuxray: False
#    eval_mimiccxr: True
#    use_amp: False
#    max_processes_for_chexpert_labeler: 5
# ----- Evaluating model ------
# metadata loaded from /home/pamessina/medvqa-workspace/models/vqa/20220926_073839_mim+mim(chex)+iu+iu(chex)+chexp(vqa)+cxr14(vqa)+vinbig(vqa)_oevqa(CenIA-clip-vte-vit-bp16bcbf+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16,0.5,0.4,0.4_medtok_orien_chx_ql_amp/metadata.json
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Loading iuxray and mimiccxr QA adapted reports ...
# --------------------------------------------------
# 3) Initializing tokenizer ...
# Loading /home/pamessina/medvqa-workspace/cache/vocab__min_freq=10__mode=report__from(qa_adapted_reports__20220904_091601.json;qa_adapted_reports__20220904_095810.json).pkl ...
# --------------------------------------------------
# 4) Estimating maximum answer length ...
# max_answer_length = 15
# --------------------------------------------------
# 5) Defining image transform ...
# mean = (0.5, 0.5, 0.5), std = (0.5, 0.5, 0.5)
# Returning default transform
# --------------------------------------------------
# 6) Defining collate_batch_fn ...
# get_vqa_collate_batch_fn(): dataset_id=1, one_hot_question_offset=97
# checkpoint_names = ['checkpoint_52_chxlmacf1+chxlmicf1+cD+cxr14macf1+cxr14micf1+ema+gacc+oracc+qlmacf1+qlmicf1+vnbgmacf1+vnbgmicf1+wmdcmp=0.6052.pt']
# --------------------------------------------------
# 7) Loading model from checkpoint ...
# checkpoint_path =  /home/pamessina/medvqa-workspace/models/vqa/20220926_073839_mim+mim(chex)+iu+iu(chex)+chexp(vqa)+cxr14(vqa)+vinbig(vqa)_oevqa(CenIA-clip-vte-vit-bp16bcbf+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16,0.5,0.4,0.4_medtok_orien_chx_ql_amp/checkpoint_52_chxlmacf1+chxlmicf1+cD+cxr14macf1+cxr14micf1+ema+gacc+oracc+qlmacf1+qlmicf1+vnbgmacf1+vnbgmicf1+wmdcmp=0.6052.pt
# pretrained_checkpoint_path = /home/pamessina/medvqa-workspace/models/vqa/20220926_073839_mim+mim(chex)+iu+iu(chex)+chexp(vqa)+cxr14(vqa)+vinbig(vqa)_oevqa(CenIA-clip-vte-vit-bp16bcbf+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16,0.5,0.4,0.4_medtok_orien_chx_ql_amp/checkpoint_52_chxlmacf1+chxlmicf1+cD+cxr14macf1+cxr14micf1+ema+gacc+oracc+qlmacf1+qlmicf1+vnbgmacf1+vnbgmicf1+wmdcmp=0.6052.pt
# --------------------------------------------------
# 8) Creating MIMIC-CXR vqa evaluator ...
# report_eval_mode = chexpert-labels
# Checking if data is already cached in path /home/pamessina/medvqa-workspace/cache/mimiccxr/mimiccxr_preprocessed_test_data__(dataset=qa_adapted_reports__20220904_095810.json;tokenizer=4838,39196,466463750150781738;report_eval_mode=chexpert-labels).pkl ...
# 	Yes, it is, data successfully loaded :)
# batch_size = 160
# len(self.report_ids) = 45766, len(set(self.report_ids)) = 3269
# VQA_Evaluator():
#   len(self.test_indices) = 45766, len(set(self.report_ids)) = 3269
# generating test dataset ...
# generating test dataloader ...
# done!
# --------------------------------------------------
# 9) Creating instance of OpenEndedVQA model ...
# OpenEndedVQA():
#   image_encoder_pretrained_weights_path None
#   self.global_feat_size = 768
#   n_questions = 154
#   n_questions_aux_task = 97
#   question_encoding = one-hot
#   answer_decoding = transformer
#   visual_input_mode = raw-image
#   name = oevqa(CenIA/clip-vte-vit-bp16bcbf+onehot+transf)
# --------------------------------------------------
# 10) Creating evaluator engine ...
# get_engine(): shift_answer=False
# --------------------------------------------------
# 11) Attaching metrics, losses, timer and events to engines ...
#
# ========================
# --------------------------------------------------
# 12) Running evaluator engine on MIMIC-CXR test split ...
# len(dataset) = 45766
# len(dataloader) = 287
# Evaluating model ...
# oracc 0.99704, chxlmicf1 0.58536, chxlmacf1 0.47509, chxlacc 0.75375, chxlrocaucmic 0.82311, chxlrocaucmac 0.75392, qlmacf1 0.22050, 130.45 secs
# Computing metrics ...
# recovered reports: len(gen_reports)=3269, len(gt_reports)=3269
# Cache successfully loaded from /home/pamessina/medvqa-workspace/cache/chexpert_labeler_cache.pkl
# (*) Chexpert: labeling 3269 texts ...
# All labels found in cache, no need to invoke chexpert labeler
# (*) Chexpert: labeling 3269 texts ...
# Chexpert labeler: running a maximum of 5 concurrent processes over 5 chunks
# chunk: i=0, b=0, e=180, chunk_size=180
# chunk: i=1, b=180, e=360, chunk_size=180
# chunk: i=2, b=360, e=540, chunk_size=180
# chunk: i=3, b=540, e=720, chunk_size=180
# chunk: i=4, b=720, e=900, chunk_size=178
# 	#### process 1: running chexpert labeler over 180 texts ...
# 	Command = docker run -v /home/pamessina/medvqa-workspace/tmp/chexpert-labeler:/data chexpert-labeler:latest python label.py --reports_path /data/labeler-input_20220926_151822_0.2720934361811249_0.csv --output_path /data/labeler-output_20220926_151822_0.2720934361811249_0.csv
# 	#### process 2: running chexpert labeler over 180 texts ...
# 	Command = docker run -v /home/pamessina/medvqa-workspace/tmp/chexpert-labeler:/data chexpert-labeler:latest python label.py --reports_path /data/labeler-input_20220926_151822_0.2720934361811249_1.csv --output_path /data/labeler-output_20220926_151822_0.2720934361811249_1.csv
# 	#### process 3: running chexpert labeler over 180 texts ...
# 	Command = docker run -v /home/pamessina/medvqa-workspace/tmp/chexpert-labeler:/data chexpert-labeler:latest python label.py --reports_path /data/labeler-input_20220926_151822_0.2720934361811249_2.csv --output_path /data/labeler-output_20220926_151822_0.2720934361811249_2.csv
# 	#### process 4: running chexpert labeler over 180 texts ...
# 	Command = docker run -v /home/pamessina/medvqa-workspace/tmp/chexpert-labeler:/data chexpert-labeler:latest python label.py --reports_path /data/labeler-input_20220926_151822_0.2720934361811249_3.csv --output_path /data/labeler-output_20220926_151822_0.2720934361811249_3.csv
# 	#### process 5: running chexpert labeler over 178 texts ...
# 	Command = docker run -v /home/pamessina/medvqa-workspace/tmp/chexpert-labeler:/data chexpert-labeler:latest python label.py --reports_path /data/labeler-input_20220926_151822_0.2720934361811249_4.csv --output_path /data/labeler-output_20220926_151822_0.2720934361811249_4.csv
# Generating LALR tables
# Downloading 'http://search.maven.org/remotecontent?filepath=edu/stanford/nlp/stanford-corenlp/3.5.2/stanford-corenlp-3.5.2.jar' -> '/root/.local/share/pystanforddeps/stanford-corenlp-3.5.2.jar'
# Generating LALR tables
# Downloading 'http://search.maven.org/remotecontent?filepath=edu/stanford/nlp/stanford-corenlp/3.5.2/stanford-corenlp-3.5.2.jar' -> '/root/.local/share/pystanforddeps/stanford-corenlp-3.5.2.jar'
# 	**** process 1 finished, elapsed time = 89.98683714866638
# 	**** process 2 finished, elapsed time = 90.17595648765564
# Generating LALR tables
# Downloading 'http://search.maven.org/remotecontent?filepath=edu/stanford/nlp/stanford-corenlp/3.5.2/stanford-corenlp-3.5.2.jar' -> '/root/.local/share/pystanforddeps/stanford-corenlp-3.5.2.jar'
# Generating LALR tables
# Downloading 'http://search.maven.org/remotecontent?filepath=edu/stanford/nlp/stanford-corenlp/3.5.2/stanford-corenlp-3.5.2.jar' -> '/root/.local/share/pystanforddeps/stanford-corenlp-3.5.2.jar'
# Generating LALR tables
# Downloading 'http://search.maven.org/remotecontent?filepath=edu/stanford/nlp/stanford-corenlp/3.5.2/stanford-corenlp-3.5.2.jar' -> '/root/.local/share/pystanforddeps/stanford-corenlp-3.5.2.jar'
# 	**** process 3 finished, elapsed time = 93.13962864875793
# 	**** process 4 finished, elapsed time = 93.26753997802734
# 	**** process 5 finished, elapsed time = 93.26765608787537
# Report-level metrics successfully saved to /home/pamessina/medvqa-workspace/results/vqa/20220926_073839_mim+mim(chex)+iu+iu(chex)+chexp(vqa)+cxr14(vqa)+vinbig(vqa)_oevqa(CenIA-clip-vte-vit-bp16bcbf+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16,0.5,0.4,0.4_medtok_orien_chx_ql_amp/mimiccxr_report_level_metrics(eval_mode=chexpert-labels).pkl

# %%
df = get_report_level_metrics_dataframe([
#     '/home/pamessina/medvqa-workspace/results/vqa/20220827_134655_mim+mim(chex)+iu+iu(chex)_oevqa(dense121+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16_medtok_orien_chx_ql_amp/mimiccxr_report_level_metrics(eval_mode=question-classification;n_q_per_report=20;qclass_threshold=0.5;chkpt=20220827_134655).pkl',
#     '/home/pamessina/medvqa-workspace/results/vqa/20220827_134655_mim+mim(chex)+iu+iu(chex)_oevqa(dense121+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16_medtok_orien_chx_ql_amp/mimiccxr_report_level_metrics(eval_mode=ground-truth).pkl',
#     '/home/pamessina/medvqa-workspace/results/vqa/20220827_134655_mim+mim(chex)+iu+iu(chex)_oevqa(dense121+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16_medtok_orien_chx_ql_amp/mimiccxr_report_level_metrics(eval_mode=question-classification;n_q_per_rep=20;qclass_thr=0.5;probs=20220827_134655).pkl',
#     '/home/pamessina/medvqa-workspace/results/vqa/20220827_134655_mim+mim(chex)+iu+iu(chex)_oevqa(dense121+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16_medtok_orien_chx_ql_amp/mimiccxr_report_level_metrics(eval_mode=question-classification;n_q_per_rep=20;qclass_thr=0.5;probs=20220907_084600;epoch=162).pkl',
#     '/home/pamessina/medvqa-workspace/results/vqa/20220827_134655_mim+mim(chex)+iu+iu(chex)_oevqa(dense121+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16_medtok_orien_chx_ql_amp/mimiccxr_report_level_metrics(eval_mode=question-classification;n_q_per_rep=20;qclass_thr=0.5;probs=20220907_084600;epoch=568).pkl',
#     '/home/pamessina/medvqa-workspace/results/vqa/20220827_134655_mim+mim(chex)+iu+iu(chex)_oevqa(dense121+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16_medtok_orien_chx_ql_amp/mimiccxr_report_level_metrics(eval_mode=question-classification;n_q_per_rep=30;qclass_thr=0.4712;probs=multimodal;epoch=-1).pkl',
#     '/home/pamessina/medvqa-workspace/results/vqa/20220827_134655_mim+mim(chex)+iu+iu(chex)_oevqa(dense121+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16_medtok_orien_chx_ql_amp/mimiccxr_report_level_metrics(eval_mode=question-classification;n_q_per_rep=30;qclass_thr=0.4756;probs=multimodal;epoch=-1).pkl',
#     '/home/pamessina/medvqa-workspace/results/vqa/20220827_134655_mim+mim(chex)+iu+iu(chex)_oevqa(dense121+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16_medtok_orien_chx_ql_amp/mimiccxr_report_level_metrics(eval_mode=question-classification;n_q_per_rep=30;ensemble=(n=4,score=0.9137,t=20220914_063812)).pkl',
#     '/home/pamessina/medvqa-workspace/results/vqa/20220827_134655_mim+mim(chex)+iu+iu(chex)_oevqa(dense121+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16_medtok_orien_chx_ql_amp/mimiccxr_report_level_metrics(eval_mode=chexpert+qclass;n_q_per_rep=30;ensemble=(n=4,score=0.9137,t=20220914_063812)).pkl',
#     '/home/pamessina/medvqa-workspace/results/vqa/20220919_011422_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(dense121+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16,0.5_medtok_orien_chx_ql_amp/mimiccxr_report_level_metrics(eval_mode=ground-truth).pkl',
#     '/home/pamessina/medvqa-workspace/results/vqa/20220919_011422_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(dense121+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16,0.5_medtok_orien_chx_ql_amp/mimiccxr_report_level_metrics(eval_mode=chexpert-labels).pkl',
#     '/home/pamessina/medvqa-workspace/results/vqa/20220919_140350_mim+mim(chex)+iu+iu(chex)+chexp(vqa)+cxr14(vqa)+vinbig(vqa)_oevqa(dense121+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16,0.5,0.4,0.4_medtok_orien_chx_ql_amp/mimiccxr_report_level_metrics(eval_mode=ground-truth).pkl',
#     '/home/pamessina/medvqa-workspace/results/vqa/20220919_140350_mim+mim(chex)+iu+iu(chex)+chexp(vqa)+cxr14(vqa)+vinbig(vqa)_oevqa(dense121+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16,0.5,0.4,0.4_medtok_orien_chx_ql_amp/mimiccxr_report_level_metrics(eval_mode=chexpert-labels).pkl',
#     '/home/pamessina/medvqa-workspace/results/vqa/20220920_184735_mim+mim(chex)+iu+iu(chex)+chexp(vqa)+cxr14(vqa)+vinbig(vqa)_oevqa(dense121+onehot+lstm)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16,0.5,0.4,0.4_medtok_orien_chx_ql_amp/mimiccxr_report_level_metrics(eval_mode=ground-truth).pkl',
#     '/home/pamessina/medvqa-workspace/results/vqa/20220920_184735_mim+mim(chex)+iu+iu(chex)+chexp(vqa)+cxr14(vqa)+vinbig(vqa)_oevqa(dense121+onehot+lstm)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16,0.5,0.4,0.4_medtok_orien_chx_ql_amp/mimiccxr_report_level_metrics(eval_mode=chexpert-labels).pkl',
#     '/home/pamessina/medvqa-workspace/results/vqa/20220920_132652_mim+mim(chex)+iu+iu(chex)+chexp(vqa)+cxr14(vqa)+vinbig(vqa)_oevqa(dense121+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16,0.5,0.4,0.4_medtok_orien_chx_ql_amp/mimiccxr_report_level_metrics(eval_mode=ground-truth).pkl',
#     '/home/pamessina/medvqa-workspace/results/vqa/20220920_132652_mim+mim(chex)+iu+iu(chex)+chexp(vqa)+cxr14(vqa)+vinbig(vqa)_oevqa(dense121+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16,0.5,0.4,0.4_medtok_orien_chx_ql_amp/mimiccxr_report_level_metrics(eval_mode=chexpert-labels).pkl',
    '/home/pamessina/medvqa-workspace/results/vqa/20220925_181231_mim+mim(chex)+iu+iu(chex)+chexp(vqa)+cxr14(vqa)+vinbig(vqa)_oevqa(CenIA-clip-vte-vit-bp16bcbf+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16,0.5,0.4,0.4_medtok_orien_chx_ql_amp/mimiccxr_report_level_metrics(eval_mode=ground-truth).pkl',
    '/home/pamessina/medvqa-workspace/results/vqa/20220925_181231_mim+mim(chex)+iu+iu(chex)+chexp(vqa)+cxr14(vqa)+vinbig(vqa)_oevqa(CenIA-clip-vte-vit-bp16bcbf+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16,0.5,0.4,0.4_medtok_orien_chx_ql_amp/mimiccxr_report_level_metrics(eval_mode=chexpert-labels).pkl',
    '/home/pamessina/medvqa-workspace/results/vqa/20220925_174700_mim+mim(chex)+iu+iu(chex)+chexp(vqa)+cxr14(vqa)+vinbig(vqa)_oevqa(CenIA-clip-vte-vit-lp16bcbf+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16,0.5,0.4,0.4_medtok_orien_chx_ql_amp/mimiccxr_report_level_metrics(eval_mode=ground-truth).pkl',
    '/home/pamessina/medvqa-workspace/results/vqa/20220925_174700_mim+mim(chex)+iu+iu(chex)+chexp(vqa)+cxr14(vqa)+vinbig(vqa)_oevqa(CenIA-clip-vte-vit-lp16bcbf+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16,0.5,0.4,0.4_medtok_orien_chx_ql_amp/mimiccxr_report_level_metrics(eval_mode=chexpert-labels).pkl',
    '/home/pamessina/medvqa-workspace/results/vqa/20220926_004746_mim+mim(chex)+iu+iu(chex)+chexp(vqa)+cxr14(vqa)+vinbig(vqa)_oevqa(CenIA-clip-vte-vit-lp16bcbf+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16,0.5,0.4,0.4_medtok_orien_chx_ql_amp/mimiccxr_report_level_metrics(eval_mode=ground-truth).pkl',
    '/home/pamessina/medvqa-workspace/results/vqa/20220926_004746_mim+mim(chex)+iu+iu(chex)+chexp(vqa)+cxr14(vqa)+vinbig(vqa)_oevqa(CenIA-clip-vte-vit-lp16bcbf+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16,0.5,0.4,0.4_medtok_orien_chx_ql_amp/mimiccxr_report_level_metrics(eval_mode=chexpert-labels).pkl',
    '/home/pamessina/medvqa-workspace/results/vqa/20220926_074409_mim+mim(chex)+iu+iu(chex)_oevqa(CenIA-clip-vte-vit-lp16bcbf+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16_medtok_orien_chx_ql_amp/mimiccxr_report_level_metrics(eval_mode=ground-truth).pkl',
    '/home/pamessina/medvqa-workspace/results/vqa/20220926_074409_mim+mim(chex)+iu+iu(chex)_oevqa(CenIA-clip-vte-vit-lp16bcbf+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16_medtok_orien_chx_ql_amp/mimiccxr_report_level_metrics(eval_mode=chexpert-labels).pkl',
    '/home/pamessina/medvqa-workspace/results/vqa/20220926_073839_mim+mim(chex)+iu+iu(chex)+chexp(vqa)+cxr14(vqa)+vinbig(vqa)_oevqa(CenIA-clip-vte-vit-bp16bcbf+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16,0.5,0.4,0.4_medtok_orien_chx_ql_amp/mimiccxr_report_level_metrics(eval_mode=ground-truth).pkl',
    '/home/pamessina/medvqa-workspace/results/vqa/20220926_073839_mim+mim(chex)+iu+iu(chex)+chexp(vqa)+cxr14(vqa)+vinbig(vqa)_oevqa(CenIA-clip-vte-vit-bp16bcbf+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16,0.5,0.4,0.4_medtok_orien_chx_ql_amp/mimiccxr_report_level_metrics(eval_mode=chexpert-labels).pkl',
])
df[df.columns[:20]]
# Out:
#                                         metrics_path        b1        b2  \
# 0  /home/pamessina/medvqa-workspace/results/vqa/2...  0.311050  0.182289
# 1  /home/pamessina/medvqa-workspace/results/vqa/2...  0.297485  0.168769
# 2  /home/pamessina/medvqa-workspace/results/vqa/2...  0.320108  0.187390
# 3  /home/pamessina/medvqa-workspace/results/vqa/2...  0.298004  0.168776
# 4  /home/pamessina/medvqa-workspace/results/vqa/2...  0.303779  0.177621
# 5  /home/pamessina/medvqa-workspace/results/vqa/2...  0.296238  0.166488
# 6  /home/pamessina/medvqa-workspace/results/vqa/2...  0.307875  0.180749
# 7  /home/pamessina/medvqa-workspace/results/vqa/2...  0.294988  0.164696
# 8  /home/pamessina/medvqa-workspace/results/vqa/2...  0.320490  0.186891
# 9  /home/pamessina/medvqa-workspace/results/vqa/2...  0.297630  0.167762
#
#          b3        b4        cD      rg-L       met     mdcmp    wmdcmp  \
# 0  0.105447  0.060095  0.137949  0.264437  0.239679  0.176180  0.159286
# 1  0.094768  0.049226  0.040825  0.200204  0.188816  0.086914  0.066313
# 2  0.107688  0.060916  0.143051  0.267179  0.241110  0.177480  0.159992
# 3  0.095184  0.050351  0.041335  0.200282  0.188707  0.087520  0.066866
# 4  0.101914  0.057489  0.122372  0.263362  0.241083  0.173110  0.156225
# 5  0.094025  0.050064  0.040010  0.199703  0.188812  0.087040  0.066649
# 6  0.104167  0.059246  0.131478  0.265232  0.241943  0.175444  0.158589
# 7  0.092501  0.049122  0.039515  0.199351  0.188057  0.086687  0.066477
# 8  0.107263  0.060948  0.146676  0.267078  0.239056  0.177343  0.160046
# 9  0.094945  0.050615  0.040754  0.200426  0.190390  0.087720  0.067200
#
#    chxlabf1(hard)  p(micro)  r(micro)  f1(micro)  p(macro)  r(macro)  \
# 0        0.642122  0.624808  0.793620   0.699169  0.533453  0.677922
# 1        0.479217  0.375769  0.848442   0.520855  0.366841  0.787875
# 2        0.633187  0.601815  0.799291   0.686636  0.528748  0.674958
# 3        0.481301  0.388255  0.818785   0.526738  0.372965  0.756064
# 4        0.641499  0.609479  0.803367   0.693119  0.531462  0.684505
# 5        0.516385  0.433534  0.798867   0.562050  0.380492  0.706232
# 6        0.649519  0.632621  0.792556   0.703615  0.552388  0.663482
# 7        0.533446  0.464463  0.778683   0.581861  0.389259  0.652986
# 8        0.648856  0.652839  0.753035   0.699366  0.560542  0.641684
# 9        0.517402  0.437421  0.792050   0.563591  0.389765  0.699889
#
#    f1(macro)       acc     p(NF)     p(EC)
# 0   0.592004  0.831031  0.460674  0.503369
# 1   0.440346  0.614714  0.450000  0.312474
# 2   0.585289  0.819499  0.528662  0.493682
# 3   0.439116  0.636848  0.448276  0.309888
# 4   0.593475  0.823994  0.515306  0.500446
# 5   0.464667  0.692719  0.381356  0.313268
# 6   0.598003  0.834802  0.525714  0.480642
# 7   0.471842  0.723769  0.363636  0.333692
# 8   0.591848  0.839823  0.479167  0.551980
# 9   0.470728  0.697242  0.418033  0.311558

# %%
df = get_report_level_metrics_dataframe([
    '/home/pamessina/medvqa-workspace/results/vqa/20220827_134655_mim+mim(chex)+iu+iu(chex)_oevqa(dense121+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16_medtok_orien_chx_ql_amp/mimiccxr_report_level_metrics(eval_mode=question-classification;n_q_per_report=20;qclass_threshold=0.5;chkpt=20220827_134655).pkl',
    '/home/pamessina/medvqa-workspace/results/vqa/20220827_134655_mim+mim(chex)+iu+iu(chex)_oevqa(dense121+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16_medtok_orien_chx_ql_amp/mimiccxr_report_level_metrics(eval_mode=ground-truth).pkl',
    '/home/pamessina/medvqa-workspace/results/vqa/20220827_134655_mim+mim(chex)+iu+iu(chex)_oevqa(dense121+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16_medtok_orien_chx_ql_amp/mimiccxr_report_level_metrics(eval_mode=question-classification;n_q_per_rep=20;qclass_thr=0.5;probs=20220827_134655).pkl',
])
df[df.columns[:20]]
# Out:
#    ** Not cached key: ('/home/pamessina/medvqa-workspace/results/vqa/20220827_134655_mim+mim(chex)+iu+iu(chex)_oevqa(dense121+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16_medtok_orien_chx_ql_amp/mimiccxr_report_level_metrics(eval_mode=question-classification;n_q_per_rep=20;qclass_thr=0.5;probs=20220827_134655).pkl', 1662580065.1798313)
# Report level metrics updated and saved to /home/pamessina/medvqa-workspace/cache/report_level_metrics_cache.pkl
#                                         metrics_path        b1        b2  \
# 0  /home/pamessina/medvqa-workspace/results/vqa/2...  0.160418  0.087716
# 1  /home/pamessina/medvqa-workspace/results/vqa/2...  0.310955  0.184470
# 2  /home/pamessina/medvqa-workspace/results/vqa/2...  0.171091  0.096853
#
#          b3        b4        cD      rg-L       met     mdcmp    wmdcmp  \
# 0  0.046617  0.023529  0.016854  0.155766  0.160804  0.086769  0.071221
# 1  0.105573  0.058011  0.153280  0.264432  0.233540  0.177028  0.158837
# 2  0.052650  0.027238  0.021405  0.169709  0.177139  0.100769  0.085600
#
#    chxlabf1(hard)  p(micro)  r(micro)  f1(micro)  p(macro)  r(macro)  \
# 0        0.466409  0.416401  0.686019   0.518240  0.309865  0.510130
# 1        0.666134  0.655914  0.796518   0.719410  0.595590  0.675522
# 2        0.515177  0.479922  0.715500   0.574499  0.385841  0.561077
#
#    f1(macro)       acc     p(NF)     p(EC)
# 0   0.373347  0.691824  0.100000  0.269763
# 1   0.622770  0.848895  0.563291  0.527668
# 2   0.431254  0.743915  0.370370  0.326260
