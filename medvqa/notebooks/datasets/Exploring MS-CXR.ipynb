# %%
# !ls /mnt/data/physionet.org/files/ms-cxr/1.1.0/
# Out:
# convert_coco_json_to_csv.py  MS_CXR_Local_Alignment_v1.1.0.csv
# index.html		     MS_CXR_Local_Alignment_v1.1.0.json
# LICENSE.txt		     SHA256SUMS.txt

# %%
import pandas as pd

# %%
ms_cxr_local_alignment_df = pd.read_csv('/mnt/data/physionet.org/files/ms-cxr/1.1.0/MS_CXR_Local_Alignment_v1.1.0.csv')

# %%
ms_cxr_local_alignment_df
# Out:
#                                           dicom_id     category_name  \
# 0     675d792f-a3521e48-5eec8573-1e81d644-e60c34f8         Pneumonia
# 1     675d792f-a3521e48-5eec8573-1e81d644-e60c34f8         Pneumonia
# 2     5318d353-daae9c3d-2ee8648e-32b65198-aeff801e         Pneumonia
# 3     5318d353-daae9c3d-2ee8648e-32b65198-aeff801e         Pneumonia
# 4     4decce85-c6ede74e-7a8bc81c-e81edee9-5ec17116      Pneumothorax
# ...                                            ...               ...
# 1443  18e1246d-a9c790ca-6b40ea18-81b9ccc8-3469c113  Pleural Effusion
# 1444  f7e3f8a3-7299389e-84a7eb76-0cb81c79-06875895  Pleural Effusion
# 1445  f7e3f8a3-7299389e-84a7eb76-0cb81c79-06875895  Pleural Effusion
# 1446  0677ec27-61328435-0dfee3b9-356bfc03-8cbd3353  Pleural Effusion
# 1447  0677ec27-61328435-0dfee3b9-356bfc03-8cbd3353  Pleural Effusion
#
#                                              label_text  \
# 0                                   Bibasilar opacities
# 1                                   Bibasilar opacities
# 2           Bilateral multifocal areas of consolidation
# 3           Bilateral multifocal areas of consolidation
# 4                        Large right-sided pneumothorax
# ...                                                 ...
# 1443                  Small bilateral pleural effusions
# 1444  Persistent moderate-to-large bilateral pleural...
# 1445  Persistent moderate-to-large bilateral pleural...
# 1446     Small bilateral pleural effusions are presumed
# 1447     Small bilateral pleural effusions are presumed
#
#                                                    path     x     y     w  \
# 0     files/p10/p10233088/s54276838/675d792f-a3521e4...   196  1136   532
# 1     files/p10/p10233088/s54276838/675d792f-a3521e4...  1009  1134   491
# 2     files/p10/p10123147/s50230934/5318d353-daae9c3...  1510  1268   755
# 3     files/p10/p10123147/s50230934/5318d353-daae9c3...   454   690   637
# 4     files/p10/p10500801/s58577720/4decce85-c6ede74...   265    90   880
# ...                                                 ...   ...   ...   ...
# 1443  files/p15/p15445857/s50967054/18e1246d-a9c790c...  1057  1198   760
# 1444  files/p12/p12668169/s54438962/f7e3f8a3-7299389...   322   972  1076
# 1445  files/p12/p12668169/s54438962/f7e3f8a3-7299389...  1755   907   748
# 1446  files/p13/p13859188/s52811469/0677ec27-6132843...   601  1515   998
# 1447  files/p13/p13859188/s52811469/0677ec27-6132843...  1813  1336   978
#
#          h  image_width  image_height  split
# 0      315         1767          2021  train
# 1      350         1767          2021  train
# 2      796         2539          3050  train
# 3      670         2539          3050  train
# 4     2198         3056          2544  train
# ...    ...          ...           ...    ...
# 1443   435         1950          1826   test
# 1444  1239         2539          3050  train
# 1445  1304         2539          3050  train
# 1446   412         3056          2544  train
# 1447   491         3056          2544  train
#
# [1448 rows x 11 columns]

# %%
ms_cxr_local_alignment_df[ms_cxr_local_alignment_df.dicom_id == '09d5f30e-922a26ad-712b751d-defb41d7-f206cded']
# Out:
#                                           dicom_id category_name  \
# 814   09d5f30e-922a26ad-712b751d-defb41d7-f206cded         Edema
# 815   09d5f30e-922a26ad-712b751d-defb41d7-f206cded         Edema
# 1128  09d5f30e-922a26ad-712b751d-defb41d7-f206cded  Cardiomegaly
#
#                        label_text  \
# 814      Moderate pulmonary edema
# 815      Moderate pulmonary edema
# 1128  enlarged cardiac silhouette
#
#                                                    path     x     y     w  \
# 814   files/p19/p19155768/s56844524/09d5f30e-922a26a...   502   931   707
# 815   files/p19/p19155768/s56844524/09d5f30e-922a26a...  1742  1010   811
# 1128  files/p19/p19155768/s56844524/09d5f30e-922a26a...  1162  1175  1388
#
#          h  image_width  image_height  split
# 814    993         3056          2544  train
# 815   1027         3056          2544  train
# 1128   809         3056          2544  train

# %%
# q = 'AP chest compared to DEID: Left lower lobe collapse is new'
# ms_cxr_local_alignment_df[ms_cxr_local_alignment_df.label_text == q]

q = 'DEID'
print(ms_cxr_local_alignment_df[ms_cxr_local_alignment_df.label_text.str.contains(q)].label_text.tolist())
ms_cxr_local_alignment_df[ms_cxr_local_alignment_df.label_text.str.contains(q)]
# Out:
# ['AP chest compared to DEID and DEID: Severe right lung consolidation has developed or worsened appreciably since DEID', 'AP chest compared to DEID: Left lower lobe collapse is new']
#                                          dicom_id  category_name  \
# 535  b87403e9-8463e40a-a104367f-cb96ab7e-b13e08a2  Consolidation
# 648  2e0e4c28-77275236-9695b5f1-bedff2d6-f816e6f7    Atelectasis
#
#                                             label_text  \
# 535  AP chest compared to DEID and DEID: Severe rig...
# 648  AP chest compared to DEID: Left lower lobe col...
#
#                                                   path     x    y    w     h  \
# 535  files/p13/p13263843/s54651626/b87403e9-8463e40...   157  355  659  1305
# 648  files/p10/p10500792/s52823815/2e0e4c28-7727523...  1384  730  640   932
#
#      image_width  image_height  split
# 535         1804          2021   test
# 648         2539          2611  train

# %%
len(ms_cxr_local_alignment_df.dicom_id.unique())
# Out:
# 1047

# %%
len(ms_cxr_local_alignment_df.label_text.unique())
# Out:
# 715

# %%
len(ms_cxr_local_alignment_df[['dicom_id', 'label_text']].drop_duplicates())
# Out:
# 1160

# %%
len(ms_cxr_local_alignment_df[['dicom_id', 'split']].drop_duplicates())
# Out:
# 1047

# %%
from collections import Counter

Counter(ms_cxr_local_alignment_df.split)
# Out:
# Counter({'train': 1020, 'val': 212, 'test': 216})

# %%
Counter(ms_cxr_local_alignment_df.category_name)
# Out:
# Counter({'Pneumonia': 231,
#          'Pneumothorax': 264,
#          'Consolidation': 185,
#          'Atelectasis': 98,
#          'Edema': 87,
#          'Cardiomegaly': 333,
#          'Lung Opacity': 108,
#          'Pleural Effusion': 142})

# %%
from importlib import reload
import medvqa

# %%
reload(medvqa.datasets.ms_cxr)
# Out:
# <module 'medvqa.datasets.ms_cxr' from '/home/pamessina/medvqa/medvqa/datasets/ms_cxr/__init__.py'>

# %%
from medvqa.datasets.ms_cxr import PhraseGroundingAnnotationsVisualizer, export_images_and_annotations_to_zip

# %%
pgav = PhraseGroundingAnnotationsVisualizer()

# %%
pgav.visualize_row(1)
# Out:
# Image path: /mnt/workspace/physionet.org/files/mimic-cxr-jpg/2.0.0/files/p10/p10233088/s54276838/675d792f-a3521e48-5eec8573-1e81d644-e60c34f8.jpg
# Label text: Bibasilar opacities
# Category name: Pneumonia
# x: 1009, y: 1134, w: 491, h: 350

# %%
pgav.visualize_dicom_id('675d792f-a3521e48-5eec8573-1e81d644-e60c34f8')
# pgav.visualize_dicom_id('4decce85-c6ede74e-7a8bc81c-e81edee9-5ec17116')
# pgav.visualize_dicom_id('2c84c825-2889fd51-2e46959d-586c6113-74033204')
# Out:
# Found 2 rows for dicom_id 675d792f-a3521e48-5eec8573-1e81d644-e60c34f8
# Image path: /mnt/workspace/physionet.org/files/mimic-cxr-jpg/2.0.0/files/p10/p10233088/s54276838/675d792f-a3521e48-5eec8573-1e81d644-e60c34f8.jpg
# Label text: Bibasilar opacities
# Category name: Pneumonia
# x: 56.792303338992646, y: 328.8273132112816, w: 154.1505376344086, h: 91.18010885700149
# Label text: Bibasilar opacities
# Category name: Pneumonia
# x: 292.36445953593665, y: 328.24839188520536, w: 142.27051499717035, h: 101.311232063335

# %%
# pgav.visualize_dicom_id('675d792f-a3521e48-5eec8573-1e81d644-e60c34f8')
# pgav.visualize_dicom_id('4decce85-c6ede74e-7a8bc81c-e81edee9-5ec17116')
pgav.visualize_dicom_id('2c84c825-2889fd51-2e46959d-586c6113-74033204')
# Out:
# Found 5 rows for dicom_id 2c84c825-2889fd51-2e46959d-586c6113-74033204
# Image path: /mnt/workspace/physionet.org/files/mimic-cxr-jpg/2.0.0/files/p18/p18341991/s56421788/2c84c825-2889fd51-2e46959d-586c6113-74033204.jpg
# Label text: bilateral edema, consolidation, ground-glass opacities
# Category name: Consolidation
# x: 107.87704918032786, y: 61.90783773139031, w: 182.68524590163935, h: 352.4915320992517
# Label text: bilateral edema, consolidation, ground-glass opacities
# Category name: Consolidation
# x: 342.5852459016393, y: 88.3245372193777, w: 201.23606557377047, h: 342.61047656557696
# Label text: bilateral edema, consolidation, ground-glass opacities
# Category name: Edema
# x: 107.87704918032786, y: 61.90783773139031, w: 182.68524590163935, h: 352.4915320992517
# Label text: bilateral edema, consolidation, ground-glass opacities
# Category name: Edema
# x: 342.5852459016393, y: 88.3245372193777, w: 201.23606557377047, h: 342.61047656557696
# Label text: enlarged cardiac silhouette
# Category name: Cardiomegaly
# x: 218.57704918032786, y: 260.33556518314293, w: 312.7426229508197, h: 165.7597479322568

# %%
pgav.visualize_dicom_id('95c32485-da7e26a7-53e671b5-6a7687d4-0347ee81')
# Out:
# Found 1 rows for dicom_id 95c32485-da7e26a7-53e671b5-6a7687d4-0347ee81
# Image path: /mnt/workspace/physionet.org/files/mimic-cxr-jpg/2.0.0/files/p10/p10476869/s52231166/95c32485-da7e26a7-53e671b5-6a7687d4-0347ee81.jpg
# Label text: Moderate right pleural effusion is still present
# Category name: Pleural Effusion
# x: 84.92473821989529, y: 374.94339622641513, w: 209.89692408376965, h: 110.8930817610063

# %%
pgav.visualize_dicom_id('30fe40e1-ab514475-aa387b0a-e1718b1b-ba680a97')
# Out:
# Found 2 rows for dicom_id 30fe40e1-ab514475-aa387b0a-e1718b1b-ba680a97
# Image path: /mnt/workspace/physionet.org/files/mimic-cxr-jpg/2.0.0/files/p10/p10530041/s51640314/30fe40e1-ab514475-aa387b0a-e1718b1b-ba680a97.jpg
# Label text: Right apical pneumothorax
# Category name: Pneumothorax
# x: 109.77602701181767, y: 120.37407224146462, w: 167.1131119864941, h: 79.48144482929243
# Label text: left perihilar and lower lobe opacities
# Category name: Pneumonia
# x: 316.3624085537423, y: 301.51113310242454, w: 107.18289251547553, h: 164.72241464621473

# %%
pgav.visualize_dicom_id('288a7d41-dfc9638d-24b10d18-6dc6eafc-df0208d2')
# Out:
# Found 2 rows for dicom_id 288a7d41-dfc9638d-24b10d18-6dc6eafc-df0208d2
# Image path: /mnt/workspace/physionet.org/files/mimic-cxr-jpg/2.0.0/files/p10/p10640977/s52825690/288a7d41-dfc9638d-24b10d18-6dc6eafc-df0208d2.jpg
# Label text: Widespread opacities in the right lung and left lower lung
# Category name: Pneumonia
# x: 98.81823860087445, y: 142.50304035378662, w: 130.79825109306682, h: 234.8424543946932
# Label text: Widespread opacities in the right lung and left lower lung
# Category name: Pneumonia
# x: 327.155527795128, y: 254.33278054173576, w: 129.1992504684572, h: 152.08844665561082

# %%
pgav.visualize_random_dicom_id()
# Out:
# Found 3 rows for dicom_id dfb7d0af-c4934461-1f3e54d3-d13567bc-45021a07
# Image path: /mnt/workspace/physionet.org/files/mimic-cxr-jpg/2.0.0/files/p10/p10844573/s50817977/dfb7d0af-c4934461-1f3e54d3-d13567bc-45021a07.jpg
# Label text: diffuse hazy opacities likely represent pulmonary edema
# Category name: Edema
# x: 239.0943396226415, y: 129.8020287958115, w: 211.72327044025158, h: 344.52879581151836
# Label text: diffuse hazy opacities likely represent pulmonary edema
# Category name: Edema
# x: 20.125786163522015, y: 140.2666884816754, w: 172.0754716981132, h: 303.67637434554973
# Label text: mild cardiomegaly
# Category name: Cardiomegaly
# x: 124.17610062893083, y: 295.8278795811518, w: 276.12578616352204, h: 146.907722513089

# %%
pgav.visualize_random_dicom_id()
# Out:
# Found 2 rows for dicom_id c75d44a3-9721af75-c6c723d7-54bc997d-65b06f50
# Image path: /mnt/workspace/physionet.org/files/mimic-cxr-jpg/2.0.0/files/p11/p11665626/s58718017/c75d44a3-9721af75-c6c723d7-54bc997d-65b06f50.jpg
# Label text: bilateral patchy parenchymal opacities, compatible with consolidation
# Category name: Consolidation
# x: 71.38032786885246, y: 128.25206774320597, w: 180.26557377049178, h: 266.38519102008667
# Label text: bilateral patchy parenchymal opacities, compatible with consolidation
# Category name: Consolidation
# x: 332.5032786885246, y: 119.58093737692005, w: 178.04754098360655, h: 278.68609688853877

# %%
ms_cxr_local_alignment_df.split.unique()
# Out:
# array(['train', 'val', 'test'], dtype=object)

# %%
train_dicom_ids = ms_cxr_local_alignment_df[ms_cxr_local_alignment_df.split == 'train'].dicom_id.unique()
print(f'len(train_dicom_ids) = {len(train_dicom_ids)}')

val_dicom_ids = ms_cxr_local_alignment_df[ms_cxr_local_alignment_df.split == 'val'].dicom_id.unique()
print(f'len(val_dicom_ids) = {len(val_dicom_ids)}')

test_dicom_ids = ms_cxr_local_alignment_df[ms_cxr_local_alignment_df.split == 'test'].dicom_id.unique()
print(f'len(test_dicom_ids) = {len(test_dicom_ids)}')
# Out:
# len(train_dicom_ids) = 737
# len(val_dicom_ids) = 155
# len(test_dicom_ids) = 155

# %%
pgav.visualize_dicom_id(val_dicom_ids[0])
# Out:
# Found 1 rows for dicom_id 08c206fa-15bc2f42-f8918f67-9efc66b9-c01f6feb
# Image path: /mnt/workspace/physionet.org/files/mimic-cxr-jpg/2.0.0/files/p10/p10388470/s51417242/08c206fa-15bc2f42-f8918f67-9efc66b9-c01f6feb.jpg
# Label text: More dense consolidation at the right lung base raises possibility of superimposed infection
# Category name: Pneumonia
# x: 88.54712041884817, y: 264.8553459119497, w: 152.5425392670157, h: 66.81761006289308

# %%
best_x = None
max_rows = 0
for x, rows in pgav.dicom_id_2_rows.items():
    if len(rows) > max_rows:
        max_rows = len(rows)
        best_x = x

# %%
best_x, max_rows
# Out:
# ('2c84c825-2889fd51-2e46959d-586c6113-74033204', 5)

# %%
ls /home/pamessina/
# Out:
#  chexpert/                   radgraph_conllformat/
# 'Diplomado IALab 2020-1'/    radgraph_conllformat.tar.gz
#  downloaded_binaries/        radiology_annotation_web_app/
#  dygiepp/                    radiology_annotation_web_app_2/
#  installers/                 tmp.jpg
#  medvqa/                    'Tutorial NLG iHEALTH 2022-2'/
#  medvqa-workspace/           venv/
#  miniconda3/                 venv2/
#  nltk_data/                  wheels/
#  openai-quickstart-node/     YOLOv5/
#  openai-quickstart-python/

# %%
export_images_and_annotations_to_zip('/home/pamessina/', 'ms_cxr_images_and_annotations.zip', num_images=100)
# Out:
# Images and annotations exported to ms_cxr_images_and_annotations.zip in /home/pamessina/

# %%
from medvqa.utils.files import list_filepaths_with_prefix_and_timestamps

list_filepaths_with_prefix_and_timestamps("/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/mimiccxr_dicom_id_to_pos_neg_facts")
# Out:
# [('/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/mimiccxr_dicom_id_to_pos_neg_facts_with_GPT4_mined_labels(nf=403416,nl=28,ngpt4=87528)(hash=741,3592138487644435704).pkl',
#   '2025-02-06 10:29:07'),
#  ('/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/mimiccxr_dicom_id_to_pos_neg_facts_with_GPT4_mined_labels(num_facts=403416)(hash=667,519549387085821745).pkl',
#   '2025-02-05 23:06:36'),
#  ('/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/mimiccxr_dicom_id_to_pos_neg_facts(num_rel_facts=404064,num_clusters=100,max_neg=500,skip_nli)(hash=980,2800495312613355816).pkl.random_vectors.pkl',
#   '2025-02-03 17:07:33'),
#  ('/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/mimiccxr_dicom_id_to_pos_neg_facts(num_rel_facts=404064,num_clusters=100,max_neg=500,skip_nli)(hash=980,2800495312613355816).pkl',
#   '2025-02-03 05:03:43'),
#  ('/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/mimiccxr_dicom_id_to_pos_neg_facts(num_rel_facts=317035,num_clusters=100,max_neg=500,ent_th=0.172)(hash=1200,2067390724509563020).pkl',
#   '2025-01-20 14:13:32'),
#  ('/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/mimiccxr_dicom_id_to_pos_neg_facts(num_rel_facts=160797,num_clusters=300,max_neg=500,ent_th=0.172)(hash=1231,1671346674768132252).pkl',
#   '2025-01-17 11:21:28'),
#  ('/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/mimiccxr_dicom_id_to_pos_neg_facts(num_sim_facts=550410,num_clusters=300,max_neg=500,ent_th=0.172)(hash=997,752767386763313321).pkl',
#   '2025-01-07 17:31:51'),
#  ('/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/mimiccxr_dicom_id_to_pos_neg_facts(num_facts=596394)(hash=469,647223496013944140).pkl',
#   '2024-10-15 08:09:04')]

# %%
from medvqa.utils.files import load_pickle

tmp = load_pickle('/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/mimiccxr_dicom_id_to_pos_neg_facts_with_GPT4_mined_labels(nf=403416,nl=28,ngpt4=87528)(hash=741,3592138487644435704).pkl')

# %%
tmp.keys()
# Out:
# dict_keys(['facts', 'embeddings', 'dicom_id_to_pos_facts', 'dicom_id_to_strong_neg_facts', 'dicom_id_to_weak_neg_facts'])

# %%
from medvqa.datasets.mimiccxr import get_detailed_metadata_for_dicom_id

# %%
from medvqa.utils.logging import print_bold
from medvqa.utils.files import read_txt

dicom_id = 'c75d44a3-9721af75-c6c723d7-54bc997d-65b06f50'

metadata = get_detailed_metadata_for_dicom_id(dicom_id)
print_bold('metadata:')
print(metadata)

print()
print_bold('report:')
print(read_txt(metadata[0]['filepath']))

print()
print_bold('positive facts:')
for i in tmp['dicom_id_to_pos_facts'][dicom_id]:
    print(tmp['facts'][i])
    
print()
print_bold('strong negative facts:')
for i in tmp['dicom_id_to_strong_neg_facts'][dicom_id]:
    print(tmp['facts'][i])
    
print()
print_bold('weak negative facts:')
count = 0
for i in tmp['dicom_id_to_weak_neg_facts'][dicom_id]:
    print(tmp['facts'][i])
    count += 1
    if count == 30: break
# Out:
# metadata:
# [{'report_index': 36085, 'part_id': 11, 'subject_id': 11665626, 'study_id': 58718017, 'dicom_id': 'c75d44a3-9721af75-c6c723d7-54bc997d-65b06f50', 'view_pos': 'AP', 'split': 'train', 'filepath': '/mnt/data/mimic-cxr/files/p11/p11665626/s58718017.txt', 'dicom_id_view_pos_pairs': [('c75d44a3-9721af75-c6c723d7-54bc997d-65b06f50', 'AP')]}]
#
# report:
#                                  FINAL REPORT
#  EXAMINATION:  CHEST (PORTABLE AP)
#
#  INDICATION:  ___ year old man with PCP PNA ___/p extubation on CVVH  // eval
#  interval change      eval interval change
#
#  COMPARISON:  Prior chest radiographs ___ through ___ at 13:37.
#
#  IMPRESSION:
#
#  Lung volumes are lower.  This may account in part for greater of opacification
#  in the left lung today.  Both lungs are still affected by heterogeneous
#  opacification greatest in the lower lobes.  There is no pleural effusion.
#  Mild cardiomegaly is chronic.  Feeding tube ends in the upper stomach.  Left
#  supraclavicular central venous catheter ends in the mid SVC.  Vascular stents
#  project over the left axilla and subclavian regions.  No pneumothorax.
#
#
# positive facts:
# heterogeneous opacification
# opacification greatest in the lower lobes
# heterogeneous opacification in both lungs
# chronic mild cardiomegaly
# greater opacification in the lung
# greater opacification in the left lung
# opacification in the lower lobes
#
# strong negative facts:
# pneumothorax
# pleural effusion
#
# weak negative facts:
# recommendation for follow-up radiograph after treatment of atelectasis
# cavitated central portion of the consolidation
# right lower lobe calcified mass similar to prior exams
# left retrocardiac edema
# rounded atelectasis not identified
# worsened severe perihilar pulmonary consolidation
# left biapical pleural thickening
# atelectasis in the setting of chronic severe pleural thickening move
# right upper lobe consolidation might represent loculated pleural effusion
# small region of atelectasis adjacent to fissural pleural fluid just above the right hemidiaphragm
# atelectasis in the region of known metastatic disease
# right cardiophrenic mass may represent a pericardial cyst
# regression of scattered multiple parenchymal patchy infiltrates in the right lower lung field
# calcified liver cyst better characterized on the prior CT abdomen and pelvis
# unclear cavitation in consolidation
# soft tissue mass associated with rib lesion
# little interval change in biapical pulmonary edema
# atelectasis associated with decreased pleural effusions
# no interval change in calcified pleural thickening on the left
# acute consolidation near an area of pleural thickening
# mask at the site of previously seen subcutaneous emphysema
# prominent pulmonary arterial hump
# right upper lobe cavitary consolidation concerning for post-primary TB
# pulmonary edema shifted into the mediastinal space
# 1.5 mm right apical pulmonary nodule not appreciated radiographically
# concern for consolidation in left mid lung due to infection
# associated effusion with developing pneumonia
# unclear amount of preexisting consolidation that was edema
# calcified pulmonary nodules consistent with prior granulomatous infection
# bulla or pneumatocele wall in the right upper lobe

# %%
import numpy as np
import matplotlib.pyplot as plt
from shapely.geometry import box as shapely_box
from shapely.ops import unary_union

def compute_probability_map_iou(prob_map, gt_coords, conf_th):
    """
    Compute the Intersection over Union (IoU) between the predicted probability map and ground truth bounding boxes.

    Parameters:
    - prob_map (numpy.ndarray): A 2D array (height, width) representing the probability map.
    - gt_coords (numpy.ndarray): An array of shape (num_boxes, 4) containing normalized ground truth bounding boxes in (x_min, y_min, x_max, y_max) format.
    - conf_th (float): Confidence threshold for binarizing the probability map.

    Returns:
    - float: The computed IoU between the binary probability map and the ground truth bounding boxes.
    """
    assert prob_map.ndim == 2, "Probability map must be a 2D array"
    height, width = prob_map.shape
    binary_map = prob_map > conf_th
    
    # Generate predicted bounding boxes based on the binary probability map
    pred_boxes = []
    cell_w, cell_h = 1 / width, 1 / height
    for y in range(height):
        for x in range(width):
            if binary_map[y, x]:
                x_min, y_min = x * cell_w, y * cell_h
                x_max, y_max = (x + 1) * cell_w, (y + 1) * cell_h
                pred_boxes.append(shapely_box(x_min, y_min, x_max, y_max))
    
    if not pred_boxes:
        return 0.0  # No predicted bounding boxes, IoU is 0
    
    # Compute union of predicted bounding boxes
    pred_union = unary_union(pred_boxes)
    
    # Compute union of ground truth bounding boxes
    gt_boxes = [shapely_box(x_min, y_min, x_max, y_max) for x_min, y_min, x_max, y_max in gt_coords]
    gt_union = unary_union(gt_boxes)
    
    # Compute intersection
    intersection = pred_union.intersection(gt_union).area
    union = pred_union.area + gt_union.area - intersection
    
    return intersection / union if union > 0 else 0.0

# Example usage and visualization
height, width = 10, 10
prob_map = np.random.rand(height, width)  # Generate a random probability map
conf_th = 0.5

gt_coords = np.array([[0.1, 0.1, 0.7, 0.7], [0.6, 0.6, 0.8, 0.8]])  # Normalized ground truth boxes

# Compute IoU
iou = compute_probability_map_iou(prob_map, gt_coords, conf_th)
print(f"Computed IoU: {iou:.4f}")

# Visualization
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
ax[0].imshow(prob_map, cmap='jet', interpolation='nearest')
ax[0].set_title("Probability Map")
ax[0].axis("off")

binary_map = prob_map > conf_th
ax[1].imshow(binary_map, cmap='gray', interpolation='nearest')
ax[1].set_title("Thresholded Binary Map")
ax[1].axis("off")

for x_min, y_min, x_max, y_max in gt_coords:
    rect = plt.Rectangle((x_min * width, y_min * height), (x_max - x_min) * width, (y_max - y_min) * height, fill=False, edgecolor='red', linewidth=2)
    ax[1].add_patch(rect)

plt.show()
# Out:
# Computed IoU: 0.2958

# %%
import numpy as np
np.random.choice(10, size=10, replace=True)
# Out:
# array([1, 5, 4, 9, 8, 4, 1, 4, 3, 6])
