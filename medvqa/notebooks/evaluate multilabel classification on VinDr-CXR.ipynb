# %%
# %env CUDA_VISIBLE_DEVICES=0
# Out:
# env: CUDA_VISIBLE_DEVICES=0

# %%
# !python ../eval_multilabel_classification.py \
--eval_dataset_name "vinbig_test_set" \
--checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20250121_034338_vinbig_aehrc-cxrmate-rrg24-uniformer" \
--batch_size 200 \
--num_workers 3
# Out:
# script's arguments:
#    eval_dataset_name: vinbig_test_set
#    checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20250121_034338_vinbig_aehrc-cxrmate-rrg24-uniformer
#    batch_size: 200
#    device: GPU
#    num_workers: 3
#    use_amp: False
#    calibrate_thresholds: False
#    save_probs: False
#    use_ensemble: False
#    model_names_for_ensemble: None
#    label_name_for_ensemble: None
#    chest_imagenome_label_names_filename: None
#    chest_imagenome_labels_filename: None
#    cheat: False
#
# ----- Evaluating model ------
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20250121_034338_vinbig_aehrc-cxrmate-rrg24-uniformer/metadata.json
# get_image_transform()
#   image_size = [384, 384]
#   mean = [0.485, 0.456, 0.406]
#   std = [0.229, 0.224, 0.225]
# Using standard transform (only images, no bounding boxes, no masks)
# ...

# %%
# !python ../eval_multilabel_classification.py \
--eval_dataset_name "vinbig_test_set" \
--checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20250217_152002_vinbig_aehrc-cxrmate-rrg24-uniformer" \
--batch_size 200 \
--num_workers 3
# Out:
# script's arguments:
#    eval_dataset_name: vinbig_test_set
#    checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20250217_152002_vinbig_aehrc-cxrmate-rrg24-uniformer
#    batch_size: 200
#    device: GPU
#    num_workers: 3
#    use_amp: False
#    calibrate_thresholds: False
#    save_probs: False
#    use_ensemble: False
#    model_names_for_ensemble: None
#    label_name_for_ensemble: None
#    chest_imagenome_label_names_filename: None
#    chest_imagenome_labels_filename: None
#    cheat: False
#
# ----- Evaluating model ------
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20250217_152002_vinbig_aehrc-cxrmate-rrg24-uniformer/metadata.json
# get_image_transform()
#   image_size = [384, 384]
#   mean = [0.485, 0.456, 0.406]
#   std = [0.229, 0.224, 0.225]
# Using standard transform (only images, no bounding boxes, no masks)
# ...

# %%
# !python ../eval_multilabel_classification.py \
--eval_dataset_name "vinbig_test_set" \
--checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20250121_093830_vinbig_microsoft-rad-dino-maira-2" \
--batch_size 50 \
--num_workers 3
# Out:
# script's arguments:
#    eval_dataset_name: vinbig_test_set
#    checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20250121_093830_vinbig_microsoft-rad-dino-maira-2
#    batch_size: 50
#    device: GPU
#    num_workers: 3
#    use_amp: False
#    calibrate_thresholds: False
#    save_probs: False
#    use_ensemble: False
#    model_names_for_ensemble: None
#    label_name_for_ensemble: None
#    chest_imagenome_label_names_filename: None
#    chest_imagenome_labels_filename: None
#    cheat: False
#
# ----- Evaluating model ------
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20250121_093830_vinbig_microsoft-rad-dino-maira-2/metadata.json
# get_image_transform()
#   image_size = [518, 518]
#   mean = [0.5307, 0.5307, 0.5307]
#   std = [0.2583, 0.2583, 0.2583]
# Using standard transform (only images, no bounding boxes, no masks)
# ...

# %%
# !python ../eval_multilabel_classification.py \
--eval_dataset_name "vinbig_test_set" \
--checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20250217_164034_vinbig_microsoft-rad-dino-maira-2" \
--batch_size 50 \
--num_workers 3
# Out:
# script's arguments:
#    eval_dataset_name: vinbig_test_set
#    checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20250217_164034_vinbig_microsoft-rad-dino-maira-2
#    batch_size: 50
#    device: GPU
#    num_workers: 3
#    use_amp: False
#    calibrate_thresholds: False
#    save_probs: False
#    use_ensemble: False
#    model_names_for_ensemble: None
#    label_name_for_ensemble: None
#    chest_imagenome_label_names_filename: None
#    chest_imagenome_labels_filename: None
#    cheat: False
#
# ----- Evaluating model ------
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20250217_164034_vinbig_microsoft-rad-dino-maira-2/metadata.json
# get_image_transform()
#   image_size = [518, 518]
#   mean = [0.5307, 0.5307, 0.5307]
#   std = [0.2583, 0.2583, 0.2583]
# Using standard transform (only images, no bounding boxes, no masks)
# ...

# %%
# !python ../eval_multilabel_classification.py \
--eval_dataset_name "vinbig_test_set" \
--checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20250121_052130_vinbig_microsoft-rad-dino" \
--batch_size 50 \
--num_workers 3
# Out:
# script's arguments:
#    eval_dataset_name: vinbig_test_set
#    checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20250121_052130_vinbig_microsoft-rad-dino
#    batch_size: 50
#    device: GPU
#    num_workers: 3
#    use_amp: False
#    calibrate_thresholds: False
#    save_probs: False
#    use_ensemble: False
#    model_names_for_ensemble: None
#    label_name_for_ensemble: None
#    chest_imagenome_label_names_filename: None
#    chest_imagenome_labels_filename: None
#    cheat: False
#
# ----- Evaluating model ------
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20250121_052130_vinbig_microsoft-rad-dino/metadata.json
# get_image_transform()
#   image_size = [518, 518]
#   mean = [0.5307, 0.5307, 0.5307]
#   std = [0.2583, 0.2583, 0.2583]
# Using standard transform (only images, no bounding boxes, no masks)
# ...

# %%
# !python ../eval_multilabel_classification.py \
--eval_dataset_name "vinbig_test_set" \
--checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20250217_195733_vinbig_microsoft-rad-dino" \
--batch_size 50 \
--num_workers 3
# Out:
# script's arguments:
#    eval_dataset_name: vinbig_test_set
#    checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20250217_195733_vinbig_microsoft-rad-dino
#    batch_size: 50
#    device: GPU
#    num_workers: 3
#    use_amp: False
#    calibrate_thresholds: False
#    save_probs: False
#    use_ensemble: False
#    model_names_for_ensemble: None
#    label_name_for_ensemble: None
#    chest_imagenome_label_names_filename: None
#    chest_imagenome_labels_filename: None
#    cheat: False
#
# ----- Evaluating model ------
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20250217_195733_vinbig_microsoft-rad-dino/metadata.json
# get_image_transform()
#   image_size = [518, 518]
#   mean = [0.5307, 0.5307, 0.5307]
#   std = [0.2583, 0.2583, 0.2583]
# Using standard transform (only images, no bounding boxes, no masks)
# ...

# %%
# !python ../eval_multilabel_classification.py \
--eval_dataset_name "vinbig_test_set" \
--checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20250212_173558_vinbig_facebook-convnext-small-224" \
--batch_size 50 \
--num_workers 3
# Out:
# script's arguments:
#    eval_dataset_name: vinbig_test_set
#    checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20250212_173558_vinbig_facebook-convnext-small-224
#    batch_size: 50
#    device: GPU
#    num_workers: 3
#    use_amp: False
#    calibrate_thresholds: False
#    save_probs: False
#    use_ensemble: False
#    model_names_for_ensemble: None
#    label_name_for_ensemble: None
#    chest_imagenome_label_names_filename: None
#    chest_imagenome_labels_filename: None
#    cheat: False
#
# ----- Evaluating model ------
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20250212_173558_vinbig_facebook-convnext-small-224/metadata.json
# get_image_transform()
#   image_size = [416, 416]
#   mean = [0.485, 0.456, 0.406]
#   std = [0.229, 0.224, 0.225]
# Using standard transform (only images, no bounding boxes, no masks)
# ...
