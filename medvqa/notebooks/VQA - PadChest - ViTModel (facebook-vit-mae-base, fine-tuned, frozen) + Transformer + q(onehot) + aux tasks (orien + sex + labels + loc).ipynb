# %%
# %env CUDA_VISIBLE_DEVICES=2
# Out:
# env: CUDA_VISIBLE_DEVICES=2

# %%
# !ls -lh /mnt/data/pamessina/workspaces/medvqa-workspace/models/mae/20221228_105757_padchest_VitMAE/checkpoint_60_loss=0.9791.pt
# Out:
# -rw-rw-r-- 1 pamessina pamessina 1.3G Dec 28 12:05 '/mnt/data/pamessina/workspaces/medvqa-workspace/models/mae/20221228_105757_padchest_VitMAE/checkpoint_60_loss=0.9791.pt'

# %%
# !python ../train_vqa.py \
        --epochs 30 \
        --batches-per-epoch 200 \
        --batch-size 150 \
        --iters-to-accumulate 2 \
        --num-workers 4 \
        --optimizer-name "adamw" \
        --scheduler "warmup+decay" \
        --lr 1e-6 \
        --warmup-and-decay-args "1e-6,5,4e-4,25,1e-6" \
        --use-padchest \
        --padchest-use-validation \
        --padchest-weight 1 \
        --padchest-train-study-ids-path "/mnt/data/pamessina/workspaces/medvqa-workspace/cache/padchest/train_study_ids_20221226_161248.txt" \
        --padchest-val-study-ids-path "/mnt/data/pamessina/workspaces/medvqa-workspace/cache/padchest/val_study_ids_20221226_161248.txt" \
        --padchest-test-study-ids-path "/mnt/data/pamessina/workspaces/medvqa-workspace/cache/padchest/test_study_ids_20221226_161248.txt" \
        --classify-orientation \
        --raw-image-encoding "vitmodel-huggingface" \
        --huggingface-model-name "facebook/vit-mae-base" \
        --image-size 224 224 \
        --image-local-feat-size 768 \
        --image-encoder-pretrained-weights-path "/mnt/data/pamessina/workspaces/medvqa-workspace/models/mae/20221228_105757_padchest_VitMAE/checkpoint_60_loss=0.9791.pt" \
        --freeze-image-encoder \
        --question-encoding "one-hot" \
        --answer-decoding "transformer" \
        --binary-loss-name "wbce-c" \
        --use-amp \
        --save
# Out:
# script's arguments:
#    epochs: 30
#    batches_per_epoch: 200
#    checkpoint_folder: None
#    iuxray_qa_adapted_reports_filename: None
#    mimiccxr_qa_adapted_reports_filename: None
#    vocab_min_freq: 10
#    embed_size: 256
#    question_encoding: one-hot
#    answer_decoding: transformer
#    question_hidden_size: 128
#    answer_hidden_size: 256
#    visual_input_mode: raw-image
#    raw_image_encoding: vitmodel-huggingface
#    image_local_feat_size: 768
#    image_encoder_pretrained_weights_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/mae/20221228_105757_padchest_VitMAE/checkpoint_60_loss=0.9791.pt
#    freeze_image_encoder: True
#    imagenet_pretrained: False
#    visual_features_mlp_in_dim: None
#    visual_features_mlp_out_dim: None
#    visual_features_mlp_hidden_dims: None
#    iuxray_precomputed_visual_features_path: None
#    mimiccxr_precomputed_visual_features_path: None
#    chexpert_precomputed_visual_features_path: None
#    vinbig_precomputed_visual_features_path: None
#    clip_version: None
#    huggingface_model_name: facebook/vit-mae-base
#    n_lstm_layers: 1
#    transf_dec_nhead: 2
#    transf_dec_dim_forward: 256
#    transf_dec_num_layers: 2
#    question_vec_size: 128
#    dropout_prob: 0
#    optimizer_name: adamw
#    lr: 1e-06
#    scheduler: warmup+decay
#    lr_decay: 0.76
#    lr_decay_patience: 2
#    warmup_and_decay_args: 1e-6,5,4e-4,25,1e-6
#    warmup_and_cosine_args: None
#    n_val_examples_per_question: 10
#    min_train_examples_per_question: 100
#    batch_size: 150
#    iters_to_accumulate: 2
#    num_workers: 4
#    device: GPU
#    img_aug_mode: None
#    image_size: [224, 224]
#    mimiccxr_weight: 1
#    chexpert_weight: 0.3
#    cxr14_weight: 0.3
#    vinbig_weight: 0.3
#    iuxray_weight: 0.05
#    mimiccxr_weight_chexpert_mode: 0.2
#    iuxray_weight_chexpert_mode: 0.05
#    padchest_weight: 1.0
#    mimiccxr_include_chexpert_mode: False
#    iuxray_include_chexpert_mode: False
#    use_chexpert_mode_only: False
#    val_answer_decoding: greedy-search
#    beam_search_k: None
#    use_amp: True
#    medical_tokenization: False
#    medical_terms_frequency_filename: None
#    allowed_questions: None
#    pretrained_checkpoint_folder_path: None
#    balanced_split: False
#    balanced_dataloading: False
#    imbalance_reduction_coef: 0.5
#    n_healthy_per_question: 2
#    n_unhealthy_per_question: 3
#    n_positive_per_chexpert_label: 7
#    min_question_count: 100
#    iuxray_balanced_metadata_filename: None
#    mimiccxr_balanced_metadata_filename: None
#    one_question_per_batch: False
#    save: True
#    override_lr: False
#    train_mimiccxr: False
#    train_iuxray: False
#    iuxray_train_with_all: False
#    train_chexpert: False
#    chexpert_mode: None
#    train_cxr14: False
#    train_vinbig: False
#    vinbig_training_data: all
#    vinbig_use_validation: False
#    train_padchest: True
#    padchest_training_data_mode: all
#    padchest_use_validation: True
#    padchest_train_study_ids_path: /mnt/data/pamessina/workspaces/medvqa-workspace/cache/padchest/train_study_ids_20221226_161248.txt
#    padchest_val_study_ids_path: /mnt/data/pamessina/workspaces/medvqa-workspace/cache/padchest/val_study_ids_20221226_161248.txt
#    padchest_test_study_ids_path: /mnt/data/pamessina/workspaces/medvqa-workspace/cache/padchest/test_study_ids_20221226_161248.txt
#    binary_loss_name: wbce-c
#    classify_tags: False
#    n_medical_tags: None
#    iuxray_medical_tags_per_report_filename: None
#    mimiccxr_medical_tags_per_report_filename: None
#    classify_orientation: True
#    classify_chexpert: False
#    iuxray_chexpert_labels_filename: None
#    mimiccxr_chexpert_labels_filename: None
#    classify_questions: False
#    n_questions: None
#    iuxray_question_labels_filename: None
#    mimiccxr_question_labels_filename: None
#    merge_findings: False
# ----- Training model from scratch ------
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Initializing tokenizer ...
# Loading /mnt/data/pamessina/workspaces/medvqa-workspace/cache/vocab(_mnt_data_padchest_PADCHEST_chest_x_ray_images_labels_160K_01.02.19.csv).pkl ...
# --------------------------------------------------
# 3) Creating instance of OpenEndedVQA model ...
# OpenEndedVQA():
#   image_encoder_pretrained_weights_path /mnt/data/pamessina/workspaces/medvqa-workspace/models/mae/20221228_105757_padchest_VitMAE/checkpoint_60_loss=0.9791.pt
# You are using a model of type vit_mae to instantiate a model of type vit. This is not supported for all configurations of models and can yield errors.
# Some weights of the model checkpoint at facebook/vit-mae-base were not used when initializing ViTModel: ['decoder.decoder_layers.7.layernorm_after.weight', 'decoder.decoder_layers.7.attention.attention.value.bias', 'decoder.decoder_layers.4.intermediate.dense.bias', 'decoder.decoder_layers.2.layernorm_before.weight', 'decoder.decoder_layers.2.attention.attention.value.weight', 'decoder.decoder_pos_embed', 'decoder.decoder_layers.5.attention.attention.query.weight', 'decoder.decoder_layers.6.attention.attention.value.bias', 'decoder.decoder_layers.1.intermediate.dense.bias', 'decoder.decoder_layers.2.layernorm_before.bias', 'decoder.decoder_layers.7.attention.attention.query.weight', 'decoder.decoder_layers.1.attention.attention.key.weight', 'decoder.decoder_layers.7.intermediate.dense.bias', 'decoder.decoder_layers.6.intermediate.dense.bias', 'decoder.decoder_layers.4.layernorm_after.weight', 'decoder.decoder_layers.4.attention.attention.key.bias', 'decoder.decoder_layers.1.attention.output.dense.bias', 'decoder.decoder_layers.6.attention.attention.query.bias', 'decoder.decoder_layers.5.output.dense.weight', 'decoder.decoder_layers.2.attention.output.dense.weight', 'decoder.decoder_layers.4.attention.attention.key.weight', 'decoder.decoder_layers.0.attention.attention.query.weight', 'decoder.decoder_layers.0.attention.output.dense.bias', 'decoder.decoder_layers.6.attention.attention.value.weight', 'decoder.decoder_layers.2.attention.attention.key.bias', 'decoder.decoder_layers.4.attention.output.dense.weight', 'decoder.decoder_layers.3.attention.output.dense.bias', 'decoder.decoder_layers.0.attention.attention.key.bias', 'decoder.decoder_layers.5.attention.attention.key.weight', 'decoder.decoder_layers.3.attention.attention.query.weight', 'decoder.decoder_layers.5.layernorm_before.bias', 'decoder.decoder_layers.7.output.dense.weight', 'decoder.decoder_layers.4.output.dense.weight', 'decoder.decoder_layers.7.layernorm_before.weight', 'decoder.decoder_layers.2.output.dense.bias', 'decoder.decoder_layers.7.attention.output.dense.weight', 'decoder.decoder_layers.4.layernorm_before.bias', 'decoder.decoder_layers.4.output.dense.bias', 'decoder.decoder_layers.0.intermediate.dense.bias', 'decoder.decoder_layers.2.intermediate.dense.bias', 'decoder.decoder_layers.5.attention.attention.query.bias', 'decoder.decoder_layers.0.attention.attention.value.bias', 'decoder.decoder_layers.7.layernorm_after.bias', 'decoder.decoder_layers.3.intermediate.dense.weight', 'decoder.decoder_layers.5.attention.output.dense.bias', 'decoder.decoder_layers.4.attention.attention.value.bias', 'decoder.decoder_layers.4.attention.attention.query.bias', 'decoder.decoder_norm.weight', 'decoder.decoder_layers.5.intermediate.dense.weight', 'decoder.decoder_layers.5.attention.attention.key.bias', 'decoder.decoder_layers.7.layernorm_before.bias', 'decoder.decoder_layers.3.output.dense.bias', 'decoder.decoder_layers.6.layernorm_before.bias', 'decoder.decoder_layers.1.layernorm_after.bias', 'decoder.decoder_layers.1.attention.attention.key.bias', 'decoder.decoder_layers.1.attention.attention.value.bias', 'decoder.decoder_layers.6.layernorm_after.bias', 'decoder.decoder_layers.6.attention.output.dense.bias', 'decoder.decoder_layers.3.layernorm_after.weight', 'decoder.decoder_layers.1.intermediate.dense.weight', 'decoder.decoder_layers.4.intermediate.dense.weight', 'decoder.decoder_layers.0.layernorm_before.bias', 'decoder.decoder_layers.2.layernorm_after.weight', 'decoder.decoder_norm.bias', 'decoder.decoder_layers.1.attention.attention.query.bias', 'decoder.decoder_embed.bias', 'decoder.decoder_layers.6.attention.attention.key.weight', 'decoder.decoder_layers.5.output.dense.bias', 'decoder.decoder_layers.6.layernorm_before.weight', 'decoder.decoder_layers.7.attention.attention.key.bias', 'decoder.decoder_layers.3.attention.attention.value.bias', 'decoder.decoder_layers.2.attention.output.dense.bias', 'decoder.decoder_pred.bias', 'decoder.decoder_layers.7.attention.outp ...
# - This IS expected if you are initializing ViTModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing ViTModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of ViTModel were not initialized from the model checkpoint at facebook/vit-mae-base and are newly initialized: ['vit.pooler.dense.weight', 'vit.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Pre-trained weights successfully loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/mae/20221228_105757_padchest_VitMAE/checkpoint_60_loss=0.9791.pt
# Ignore freezing parameter: pooler.dense.weight
# Ignore freezing parameter: pooler.dense.bias
#   self.global_feat_size = 768
#   n_questions = 196
#   n_questions_aux_task = None
#   question_encoding = one-hot
#   answer_decoding = transformer
#   visual_input_mode = raw-image
#   name = oevqa(facebook/vit-mae-base+onehot+transf)
# --------------------------------------------------
# 4) Defining optimizer ...
# create_optimizer(): name = adamw
# --------------------------------------------------
# 5) Defining scheduler ...
# Using warmup+decay scheduler: 1e-6,5,4e-4,25,1e-6
# 1e-06 5 0.0004 25 1e-06
# Adjusting learning rate of group 0 to 1.0000e-06.
# Adjusting learning rate of group 0 to 1.0000e-06.
# --------------------------------------------------
# 6) Creating trainer and validator engines ...
# get_engine(): shift_answer=True
# get_engine(): shift_answer=False
# --------------------------------------------------
# 7) Defining image transform ...
# Using Huggingface ViT model transform for facebook/vit-mae-base
# mean = (0.485, 0.456, 0.406), std = (0.229, 0.224, 0.225), image_size = (224, 224), use_center_crop = False
# Returning transform without augmentation
# --------------------------------------------------
# 8) Defining collate_batch_fn ...
# get_vqa_collate_batch_fn(): dataset_id=7, one_hot_question_offset=0
# --------------------------------------------------
# 9) Creating PadChest vqa trainer ...
# ../train_vqa.py:1497: DtypeWarning: Columns (19,20) have mixed types.Specify dtype option on import or set low_memory=False.
#   debug=debug)
# Number of rows before filtering: 160861
# Number of rows after filtering: 160754 (dropped nan rows)
# Number of rows after filtering: 160741 (dropped study ids not in all_study_ids_set)
# Number of rows after filtering: 160723 (dropped rows with unexpected PatientSex_DICOM)
# Number of rows after filtering: 160704 (dropped rows with unexpected Projection)
# Number of rows after filtering: 160692 (dropped rows with broken images)
# Number of rows after filtering: 109821 (dropped rows with duplicate StudyID)
# Number of labels: 193
# Number of localizations: 104
# Generating answers based on labels...
# 100%|███████████████████████████████| 109821/109821 [00:00<00:00, 109835.53it/s]
# Done. Example answer: <s> alveolar pattern , pneumonia , scoliosis , copd signs , increased density </s>
# Generating answers based on localizations...
# 100%|███████████████████████████████| 109821/109821 [00:00<00:00, 113636.23it/s]
# Done. Example answer: <s> </s>
# Number of non-empty answers: 63528
# Generating answers based on labels localizations by sentence...
# 100%|████████████████████████████████| 109821/109821 [00:01<00:00, 65212.07it/s]
# Done. Example answer: <s> normal , pacemaker , exclude </s>
# Creating dataset and dataloader...
# Example of positive localization answer: <s> loc retrocardiac </s>
# Example of negative localization answer: <s> </s>
# 193it [00:27,  6.97it/s]
# Done!
# len(self.train_dataset) = 1000000000000000000
# Creating dataset and dataloader...
# Example of positive localization answer: <s> loc apical , loc pleural </s>
# Example of negative localization answer: <s> </s>
# 193it [00:00, 219.25it/s]
# Done!
# len(self.val_dataset) = 4398
# --------------------------------------------------
# 10) Creating dataloaders ...
# len(_train_dataloaders) = 1
# len(_val_dataloaders) = 1
# _train_weights = [1.0]
# merged_dataset_name = padchest(vqa)
# --------------------------------------------------
# 11) Attaching metrics, losses, timer and events to engines ...
# --------------------------------------------------
# 12) Defining learning rate scheduler handler ...
# --------------------------------------------------
# 13) Defining checkpoint folder path ...
# checkpoint_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/vqa/20221228_130824_padchest(vqa)_oevqa(facebook-vit-mae-base+onehot+transf)_visenc-pretr=1_orien_amp
# metadata saved to /mnt/data/pamessina/workspaces/medvqa-workspace/models/vqa/20221228_130824_padchest(vqa)_oevqa(facebook-vit-mae-base+onehot+transf)_visenc-pretr=1_orien_amp/metadata.json
# --------------------------------------------------
# 14) Defining log_metrics_handler ...
# MetricsLogger :: we'll be logging to /mnt/data/pamessina/workspaces/medvqa-workspace/models/vqa/20221228_130824_padchest(vqa)_oevqa(facebook-vit-mae-base+onehot+transf)_visenc-pretr=1_orien_amp/metrics_logs.csv
# --------------------------------------------------
# 15) Running trainer engine ...
# ---- Epoch 1/30
# (1) Training stage (lr = 0.000001) ...
# loss 12.61992, a_loss 8.07680, ema 0.00000, oracc 0.03903, orien_loss 1.73963, gacc 0.49330, gloss 0.69287, b1 0.00068, b2 0.00000, b3 0.00000, b4 0.00000, padchxlmacf1 0.01235, padchxlmicf1 0.01185, padchxlzmacf1 0.01770, padchxlzmicf1 0.01472, padchxl_loss 0.95048, padchxlz_loss 1.01754, 127.57 secs
# (2) Validation stage ...
# ema 0.00000, oracc 0.04434, gacc 0.48658, b1 0.00139, b2 0.00000, b3 0.00000, b4 0.00000, padchxlmacf1 0.01742, padchxlmicf1 0.01778, padchxlzmacf1 0.02353, padchxlzmicf1 0.02190, 33.22 secs
# Adjusting learning rate of group 0 to 3.3145e-06.
# ---- Epoch 2/30
# (1) Training stage (lr = 0.000003) ...
# loss 12.31386, a_loss 7.76028, ema 0.03190, oracc 0.51080, orien_loss 1.50710, gacc 0.55397, gloss 0.69158, b1 0.00119, b2 0.00000, b3 0.00000, b4 0.00000, padchxlmacf1 0.01243, padchxlmicf1 0.01125, padchxlzmacf1 0.01815, padchxlzmicf1 0.01873, padchxl_loss 0.94380, padchxlz_loss 1.00680, 124.56 secs
# (2) Validation stage ...
# ema 0.07890, oracc 0.81287, gacc 0.57640, b1 0.00000, b2 0.00000, b3 0.00000, b4 0.00000, padchxlmacf1 0.01601, padchxlmicf1 0.01390, padchxlzmacf1 0.02472, padchxlzmicf1 0.03068, 32.92 secs
# Adjusting learning rate of group 0 to 1.0986e-05.
# ---- Epoch 3/30
# (1) Training stage (lr = 0.000011) ...
# loss 11.52411, a_loss 6.54040, ema 0.12593, oracc 0.81447, orien_loss 0.99843, gacc 0.53150, gloss 0.68852, b1 0.00000, b2 0.00000, b3 0.00000, b4 0.00000, padchxlmacf1 0.01247, padchxlmicf1 0.01028, padchxlzmacf1 0.02481, padchxlzmicf1 0.03509, padchxl_loss 0.91551, padchxlz_loss 0.98833, 121.88 secs
# (2) Validation stage ...
# ema 0.07890, oracc 0.81287, gacc 0.51796, b1 0.00000, b2 0.00000, b3 0.00000, b4 0.00000, padchxlmacf1 0.01258, padchxlmicf1 0.03160, padchxlzmacf1 0.03196, padchxlzmicf1 0.07541, 33.33 secs
# Adjusting learning rate of group 0 to 3.6411e-05.
# ---- Epoch 4/30
# (1) Training stage (lr = 0.000036) ...
# loss 8.93525, a_loss 4.90789, ema 0.12463, oracc 0.81613, orien_loss 0.61521, gacc 0.70537, gloss 0.67863, b1 0.00000, b2 0.00000, b3 0.00000, b4 0.00000, padchxlmacf1 0.01713, padchxlmicf1 0.07112, padchxlzmacf1 0.02991, padchxlzmicf1 0.05106, padchxl_loss 0.80618, padchxlz_loss 0.90693, 121.72 secs
# (2) Validation stage ...
# ema 0.07890, oracc 0.81287, gacc 0.70941, b1 0.00000, b2 0.00000, b3 0.00000, b4 0.00000, padchxlmacf1 0.02241, padchxlmicf1 0.08137, padchxlzmacf1 0.03350, padchxlzmicf1 0.06777, 33.58 secs
# Adjusting learning rate of group 0 to 1.2068e-04.
# ---- Epoch 5/30
# (1) Training stage (lr = 0.000121) ...
# loss 7.03236, a_loss 3.53337, ema 0.14053, oracc 0.82347, orien_loss 0.47277, gacc 0.73220, gloss 0.63875, b1 0.02138, b2 0.01592, b3 0.01148, b4 0.00829, padchxlmacf1 0.02723, padchxlmicf1 0.09539, padchxlzmacf1 0.04498, padchxlzmicf1 0.08202, padchxl_loss 0.70081, padchxlz_loss 0.82763, 122.54 secs
# (2) Validation stage ...
# ema 0.12324, oracc 0.84584, gacc 0.79241, b1 0.06194, b2 0.03533, b3 0.01926, b4 0.01218, padchxlmacf1 0.03042, padchxlmicf1 0.09625, padchxlzmacf1 0.05059, padchxlzmicf1 0.10019, 33.10 secs
# Adjusting learning rate of group 0 to 4.0000e-04.
# ---- Epoch 6/30
# (1) Training stage (lr = 0.000400) ...
# loss 4.85954, a_loss 2.19567, ema 0.21117, oracc 0.91830, orien_loss 0.26437, gacc 0.82033, gloss 0.47610, b1 0.31942, b2 0.23292, b3 0.16067, b4 0.11298, padchxlmacf1 0.03350, padchxlmicf1 0.08604, padchxlzmacf1 0.05442, padchxlzmicf1 0.08954, padchxl_loss 0.65709, padchxlz_loss 0.77942, 122.66 secs
# (2) Validation stage ...
# ema 0.17735, oracc 0.93179, gacc 0.84993, b1 0.15069, b2 0.11550, b3 0.08497, b4 0.06545, padchxlmacf1 0.04077, padchxlmicf1 0.09058, padchxlzmacf1 0.06352, padchxlzmicf1 0.11059, 33.30 secs
# Adjusting learning rate of group 0 to 3.1476e-04.
# ---- Epoch 7/30
# (1) Training stage (lr = 0.000315) ...
# loss 3.85277, a_loss 1.73257, ema 0.29303, oracc 0.94107, orien_loss 0.18702, gacc 0.86650, gloss 0.34353, b1 0.42447, b2 0.31779, b3 0.23190, b4 0.17046, padchxlmacf1 0.03652, padchxlmicf1 0.09160, padchxlzmacf1 0.05788, padchxlzmicf1 0.09180, padchxl_loss 0.63289, padchxlz_loss 0.77176, 123.01 secs
# (2) Validation stage ...
# ema 0.30446, oracc 0.94543, gacc 0.86971, b1 0.18400, b2 0.14319, b3 0.10660, b4 0.08128, padchxlmacf1 0.04539, padchxlmicf1 0.10154, padchxlzmacf1 0.06980, padchxlzmicf1 0.11092, 33.44 secs
# Adjusting learning rate of group 0 to 2.4768e-04.
# ---- Epoch 8/30
# (1) Training stage (lr = 0.000248) ...
# loss 3.59829, a_loss 1.58684, ema 0.35487, oracc 0.95143, orien_loss 0.16202, gacc 0.87997, gloss 0.30729, b1 0.45515, b2 0.34478, b3 0.25809, b4 0.19517, padchxlmacf1 0.04031, padchxlmicf1 0.09671, padchxlzmacf1 0.06023, padchxlzmicf1 0.09815, padchxl_loss 0.62567, padchxlz_loss 0.76668, 122.80 secs
# (2) Validation stage ...
# ema 0.35653, oracc 0.95771, gacc 0.88085, b1 0.13140, b2 0.09681, b3 0.07377, b4 0.05666, padchxlmacf1 0.04767, padchxlmicf1 0.10781, padchxlzmacf1 0.07190, padchxlzmicf1 0.11693, 33.24 secs
# Adjusting learning rate of group 0 to 1.9490e-04.
# ---- Epoch 9/30
# (1) Training stage (lr = 0.000195) ...
# loss 3.70431, a_loss 1.49942, ema 0.36680, oracc 0.95777, orien_loss 0.15142, gacc 0.88650, gloss 0.28761, b1 0.46824, b2 0.35999, b3 0.27462, b4 0.21173, padchxlmacf1 0.04121, padchxlmicf1 0.09972, padchxlzmacf1 0.06137, padchxlzmicf1 0.10065, padchxl_loss 0.61793, padchxlz_loss 0.75620, 123.05 secs
# (2) Validation stage ...
# ema 0.34379, oracc 0.96157, gacc 0.88313, b1 0.24977, b2 0.18530, b3 0.14219, b4 0.11161, padchxlmacf1 0.05101, padchxlmicf1 0.11045, padchxlzmacf1 0.07257, padchxlzmicf1 0.12331, 33.12 secs
# Adjusting learning rate of group 0 to 1.5337e-04.
# ---- Epoch 10/30
# (1) Training stage (lr = 0.000153) ...
#    iteration 1975
