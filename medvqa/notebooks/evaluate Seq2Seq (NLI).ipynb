# %%
# %env CUDA_VISIBLE_DEVICES=0
# Out:
# env: CUDA_VISIBLE_DEVICES=0

# %%
# %run -n ../eval_seq2seq.py

# %%
output = evaluate(
    checkpoint_folder_path="/mnt/data/pamessina/workspaces/medvqa-workspace/models/seq2seq/20231227_013137_multitask(s2f+f2m+f2c+s2co+s2cal+nli)_Seq2Seq(t5-small)",
    device="gpu",
    batch_size=300,
    num_workers=3,
    max_length=10,
    num_beams=1,
    logging_level='INFO',
    task_name='nli',
    plot_confusion_matrix=True,
    return_outputs=True,
)
# Out:
# 2023-12-31 10:42:39,430 - INFO - Example sentences to process:
# 2023-12-31 10:42:39,431 - INFO - 769: NLI1: There is no pleural effusion or pneumothorax. #Hypothesis: There are no pleural effusions.
# 2023-12-31 10:42:39,431 - INFO - 1017: NLI1: volume of right pleural effusion, substantially loculated in the upper hemithorax, is unchanged. #Hypothesis: volume of right pleural effusion, substantially loculated in the upper hemithorax, is increased.
# 2023-12-31 10:42:39,432 - INFO - 1073: NLI1: stable mild pulmonary edema. #Hypothesis: new mild pulmonary edema.
# 2023-12-31 10:42:39,432 - INFO - 687: NLI1: There is no free intraperitoneal air. #Hypothesis: There is no focal lung consolidation.
# 2023-12-31 10:42:39,433 - INFO - 1050: NLI1: mild generalized pulmonary edema has improved. #Hypothesis: mild generalized pulmonary edema has resolved.
# ...

# %%
output = evaluate(
    checkpoint_folder_path="/mnt/data/pamessina/workspaces/medvqa-workspace/models/seq2seq/20231231_145653_multitask(s2f+f2m+f2c+s2co+s2cal+nli)_Seq2Seq(t5-small)",
    device="gpu",
    batch_size=300,
    num_workers=3,
    max_length=10,
    num_beams=1,
    logging_level='INFO',
    task_name='nli',
    plot_confusion_matrix=True,
    return_outputs=True,
)
# Out:
# 2023-12-31 19:52:21,745 - INFO - Example sentences to process:
# 2023-12-31 19:52:21,747 - INFO - 1037: NLI1: improved left upper lung aeration with moderate re - expansion pulmonary edema. #Hypothesis: worsened left upper lung aeration with moderate re - expansion pulmonary edema.
# 2023-12-31 19:52:21,748 - INFO - 650: NLI1: No pleural effusions. #Hypothesis: The small bilateral pleural effusions are unchanged in size.
# 2023-12-31 19:52:21,749 - INFO - 1229: NLI1: There is some hazy opacity at the right base which is unchanged. #Hypothesis: In comparison with the study of ___, there is increasing hazy opacification at the right base.
# 2023-12-31 19:52:21,749 - INFO - 613: NLI1: No acute bony abnormalities are seen. #Hypothesis: There are no acute osseous abnormalities.
# 2023-12-31 19:52:21,750 - INFO - 1008: NLI1: small left apical pneumothorax slightly larger today than on ___. #Hypothesis: small left apical pneumothorax slightly smaller today than on ___.
# ...

# %%
output = evaluate(
#     checkpoint_folder_path="/mnt/data/pamessina/workspaces/medvqa-workspace/models/seq2seq/20240101_135046_multitask(s2f+f2m+f2c+s2co+s2cal+nli+mlm)_Seq2Seq(t5-small)",
    checkpoint_folder_path="/mnt/data/pamessina/workspaces/medvqa-workspace/models/seq2seq/20240101_222821_multitask(s2f+f2m+f2c+s2co+s2cal+nli+mlm)_Seq2Seq(t5-small)",
    device="gpu",
    batch_size=300,
    num_workers=3,
    max_length=10,
    num_beams=1,
    logging_level='INFO',
    task_name='nli',
    plot_confusion_matrix=True,
    return_outputs=True,
)
# Out:
# 2024-01-02 02:43:56,901 - INFO - Example sentences to process:
# 2024-01-02 02:43:56,902 - INFO - 701: NLI1: Compared with the prior study, the cardiomediastinal silhouette is probably unchanged. #Hypothesis: The cardiomediastinal silhouette is unremarkable.
# 2024-01-02 02:43:56,903 - INFO - 168: NLI1: No pleural effusion, focal consolidation or pneumothorax. #Hypothesis: Large left pleural effusion persists.
# 2024-01-02 02:43:56,903 - INFO - 1171: NLI1: interval increase of a pre - existing right basal parenchymal opacity. #Hypothesis: interval progression of a pre - existing right basal parenchymal opacity.
# 2024-01-02 02:43:56,904 - INFO - 988: NLI1: bibasal atelectasis has slightly improved in the interim. #Hypothesis: bibasal atelectasis has slightly decreased in the interim.
# 2024-01-02 02:43:56,905 - INFO - 1312: NLI1: Slight interval decrease of bilateral pleural effusions. #Hypothesis: Slight interval improvement in bilateral pleural effusions.
# ...

# %%
output = evaluate(
#     checkpoint_folder_path="/mnt/data/pamessina/workspaces/medvqa-workspace/models/seq2seq/20240101_135046_multitask(s2f+f2m+f2c+s2co+s2cal+nli+mlm)_Seq2Seq(t5-small)",
#     checkpoint_folder_path="/mnt/data/pamessina/workspaces/medvqa-workspace/models/seq2seq/20240101_222821_multitask(s2f+f2m+f2c+s2co+s2cal+nli+mlm)_Seq2Seq(t5-small)",
#     checkpoint_folder_path="/mnt/data/pamessina/workspaces/medvqa-workspace/models/seq2seq/20240105_123953_multitask(s2f+f2m+f2c+s2co+s2cal+nli+mlm)_Seq2Seq(t5-small)",
#     checkpoint_folder_path="/mnt/data/pamessina/workspaces/medvqa-workspace/models/seq2seq/20240105_162937_multitask(s2f+f2m+f2c+s2co+s2cal+nli+mlm)_Seq2Seq(t5-small)",
#     checkpoint_folder_path="/mnt/data/pamessina/workspaces/medvqa-workspace/models/seq2seq/20240105_180720_multitask(s2f+f2m+f2c+s2co+s2cal+nli+mlm)_Seq2Seq(t5-small)",
#     checkpoint_folder_path="/mnt/data/pamessina/workspaces/medvqa-workspace/models/seq2seq/20240106_002348_multitask(s2f+f2m+f2c+s2co+s2cal+nli+mlm)_Seq2Seq(t5-small)",
    checkpoint_folder_path="/mnt/data/pamessina/workspaces/medvqa-workspace/models/seq2seq/20240116_111115_multitask(s2f+f2m+f2c+s2co+s2cal+nli+mlm)_Seq2Seq(t5-small)",
    device="gpu",
    batch_size=300,
    num_workers=3,
    max_length=10,
    num_beams=1,
    logging_level='INFO',
    task_name='nli',
    gpt4_nli_examples_filepaths=[
    "/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-1106-preview_nli_queries_around_radnli_mscxrt.jsonl",
    "/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_nli_queries_around_radnli_mscxrt.jsonl",
    ],
    plot_confusion_matrix=True,
    return_outputs=True,
)
# Out:
# Number of RadNLI dev samples: 480
# Number of RadNLI test samples: 480
# Number of MS_CXR_T samples: 361
# 2024-01-17 05:18:17,975 - INFO - Example sentences to process:
# 2024-01-17 05:18:17,977 - INFO - 18494: NLI1: The lungs appear clear without focal consolidation, effusion or pneumothorax. #Hypothesis: There is no focal consolidation, effusion, or pneumothorax seen.
# 2024-01-17 05:18:17,978 - INFO - 16841: NLI1: Possible small left pleural effusion developing. #Hypothesis: Tiny left-sided pleural effusion.
# 2024-01-17 05:18:17,979 - INFO - 10863: NLI1: No new pleural effusions. #Hypothesis: No interval increase in pleural effusions demonstrated.
# 2024-01-17 05:18:17,980 - INFO - 16100: NLI1: Mediastinal and hilar contours are otherwise within normal limits. #Hypothesis: The cardiomediastinal hilar contours are unremarkable.
# ...

# %%
output.keys()
# Out:
# dict_keys(['radnli_dev_input_texts', 'radnli_dev_gen_outputs', 'radnli_dev_output_texts', 'radnli_test_input_texts', 'radnli_test_gen_outputs', 'radnli_test_output_texts', 'mscxrt_input_texts', 'mscxrt_gen_outputs', 'mscxrt_output_texts'])

# %%
radnli_error_indices = []
for i in range(len(output['radnli_test_output_texts'])):
    if output['radnli_test_output_texts'][i] != output['radnli_test_gen_outputs'][i]:
        radnli_error_indices.append(i)

# %%
len(radnli_error_indices)
# Out:
# 89

# %%
import random
i = random.choice(radnli_error_indices)
print(output['radnli_test_input_texts'][i])
print()
print(output['radnli_test_output_texts'][i])
print()
print(output['radnli_test_gen_outputs'][i])
# Out:
# NLI1: Moderate cardiomegaly and mediastinal vascular engorgement is stable. #Hypothesis: Cardiomediastinal and hilar silhouettes are normal.
#
# Most likely: contradiction
#
# Most likely: neutral

# %%
output['radnli_test_gen_outputs'][0]
# Out:
# 'Most likely: contradiction'

# %%
output['radnli_test_output_texts'][0]
# Out:
# 'Most likely: neutral'

# %%
mscxrt_error_indices = []
for i in range(len(output['mscxrt_output_texts'])):
    if output['mscxrt_output_texts'][i] != output['mscxrt_gen_outputs'][i]:
        mscxrt_error_indices.append(i)

# %%
import random

# %%
i = random.choice(mscxrt_error_indices)
print(i)
print()
print(output['mscxrt_input_texts'][i])
print()
print(output['mscxrt_output_texts'][i])
print()
print(output['mscxrt_gen_outputs'][i])
# Out:
# 92
#
# NLI1: interval improvement in mild pulmonary edema. #Hypothesis: interval decrease in mild pulmonary edema.
#
# Most likely: entailment
#
# Most likely: contradiction

# %%
# %run -n ../datasets/seq2seq/seq2seq_dataset_management.py

# %%
dataset = _prepare_masked_lm_dataset([
    "The currently is no evidence of acute lung disease such as pneumonia or pulmonary edema.",
    "Assessment of the lung apices is obscured by the patient's neck and chin projecting over and obscuring this region.",
    "Assessment of the lung apices is obscured by the patient's neck .......... . . . . . . "
], min_token_count=1, apply_task_prefix=True)
# Out:
# Preparing masked LM dataset with masking
# 	min_token_count: 1
# 	masking_fraction: 0.2
# 	len(sentences): 3
# Tokenizing sentences...
# Lowercasing tokens...
# 100%|██████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 30030.82it/s]
# 	len(valid_tokens): 17
# 100%|██████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 34379.54it/s]
# Number of sentences: 3
# Examples:
# Input:
# MLM: The currently is no evidence of acute <tok1> disease such as pneumonia or <tok2> edema .
# Output:
# <tok1> lung <tok2> pulmonary
# Input:
# MLM: The currently is no evidence of <tok1> lung disease such as pneumonia or <tok2> edema .
# Output:
# <tok1> acute <tok2> pulmonary
# Input:
# MLM: Assessment of the <tok1> apices is obscured by the patient 's <tok2> and chin projecting over and obscuring this region .
# Output:
# <tok1> lung <tok2> neck
# Input:
# ...

# %%
dataset[2]
# Out:
# {'input_text': "MLM: Assessment of the lung <tok1> is <tok2> by the patient 's neck .......... . . . . . .",
#  'output_text': '<tok1> apices <tok2> obscured'}

# %%
import string
punctuactions = set(string.punctuation)

# %%
import re
from string import punctuation
has_puctuation = re.compile(f'[{punctuation}]')

# %%
has_puctuation.search('adfasdf\'adfasd')
# Out:
# <re.Match object; span=(7, 8), match="'">
