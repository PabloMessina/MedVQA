# %%
from medvqa.evaluation.plots import plot_train_val_curves
from medvqa.utils.constants import MetricNames

# %%
plot_train_val_curves('/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250108_070909_mim-facts+vinbig_PhraseGrounder(aehrc-cxrmate-rrg24-uniformer,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/metrics_logs.csv')

# %%
plot_train_val_curves('/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250107_231026_mim-facts_PhraseGrounder(aehrc-cxrmate-rrg24-uniformer,AdaptiveFiLM_MLP,128,256,256-128)/metrics_logs.csv')

# %%
# plot_train_val_curves('/mnt/data/pamessina/workspaces/medvqa-workspace/models/seq2seq/20250114_104632_report2negative_facts(r2nf)_Seq2Seq(facebook-bart-base)/metrics_logs.csv')
plot_train_val_curves('/mnt/data/pamessina/workspaces/medvqa-workspace/models/seq2seq/20250114_142005_report2negative_facts(r2nf)_Seq2Seq(t5-small)/metrics_logs.csv')

# %%
plot_train_val_curves('/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240426_072308_mim-facts_PhraseGrounder(dn121,128,256)/metrics_logs.csv',
# plot_train_val_curves('/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20231201_095118_mscxr+chst-img-anat_PhraseGrounder(yolov8l,128,256)/metrics_logs.csv',
# plot_train_val_curves('/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20231122_083436_chst-img-anat_PhraseGrounder(yolov8l,128,256)/metrics_logs.csv',
# plot_train_val_curves('/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20231122_141052_chst-img-anat_PhraseGrounder(yolov8l,128,256)/metrics_logs.csv',
                [
                    MetricNames.LOSS,
#                     'cibg_segmask_iou',
#                     'pg_segmask_iou',
#                     MetricNames.CHESTIMAGENOMEBBOXIOU,
                    'fg_cpg_loss',
                    'fg_att_reg_loss',
                    'fg_phrcls_loss',
                ],
                [
                    'Loss',
#                     'Chest ImaGenome Bbox Grounding IoU ',
#                     'MS-CXR Phrase Grounding IoU ',
#                     'Bbox IoU',
                    'Contrastive Loss',
                    'Attention Regularization Loss',
                    'Classification Loss',
                ], 
                use_min_with_these_metrics=[
                    MetricNames.LOSS,
                    'fg_cpg_loss',
                    'fg_att_reg_loss',
                    'fg_phrcls_loss',
                ],
                single_plot_figsize=(7,6))

# %%
plot_train_val_curves('/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240426_072308_mim-facts_PhraseGrounder(dn121,128,256)/metrics_logs.csv',
# plot_train_val_curves('/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20231201_095118_mscxr+chst-img-anat_PhraseGrounder(yolov8l,128,256)/metrics_logs.csv',
# plot_train_val_curves('/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20231122_083436_chst-img-anat_PhraseGrounder(yolov8l,128,256)/metrics_logs.csv',
# plot_train_val_curves('/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20231122_141052_chst-img-anat_PhraseGrounder(yolov8l,128,256)/metrics_logs.csv',
                [
                    MetricNames.LOSS,
#                     'cibg_segmask_iou',
#                     'pg_segmask_iou',
#                     MetricNames.CHESTIMAGENOMEBBOXIOU,
                    'fg_cpg_loss',
                    'fg_att_reg_loss',
                    'fg_phrcls_loss',
                ],
                [
                    'Loss',
#                     'Chest ImaGenome Bbox Grounding IoU ',
#                     'MS-CXR Phrase Grounding IoU ',
#                     'Bbox IoU',
                    'Contrastive Loss',
                    'Attention Regularization Loss',
                    'Classification Loss',
                ], 
                use_min_with_these_metrics=[
                    MetricNames.LOSS,
                    'fg_cpg_loss',
                    'fg_att_reg_loss',
                    'fg_phrcls_loss',
                ],
                single_plot_figsize=(7,6))

# %% [markdown]
# # Phrase Grounding: DenseNet121 + CXRFE + Sigmoid-based attention

# %%
plot_train_val_curves('/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240618_175951_mscxr+chst-img-anat+vinbig+chexloc_PhraseGrounder(dn121,SigmoidAttention,128,256,256,1)/metrics_logs.csv',
                [
                    'cibg_segmask_iou',
                    'vbg_prc_auc',
                    'vbg_segmask_iou',
                    'cl_segmask_iou',
                    'cl_phrase_acc',
                    'pg_segmask_iou',
                ],
                [
                    'Chest ImaGenome Bbox IoU ',
                    'VinDR-CXR PRC AUC',
                    'VinDR-CXR Bbox IoU',
                    'CheXlocalize Segmentation Mask IoU',
                    'CheXlocalize Accuracy',
                    'MS-CXR Phrase Grounding IoU ',
                ],
                single_plot_figsize=(7,6))

# %% [markdown]
# # Phrase Grounding: DenseNet121 + CXRFE + Transformer Encoder

# %%
plot_train_val_curves('/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240618_093614_mscxr+chst-img-anat+vinbig+chexloc_PhraseGrounder(dn121,TransformerEncoder,128,256,4,512,3)/metrics_logs.csv',
                [
                    'cibg_segmask_iou',
                    'vbg_prc_auc',
                    'vbg_segmask_iou',
                    'cl_segmask_iou',
                    'cl_phrase_acc',
                    'pg_segmask_iou',
                ],
                [
                    'Chest ImaGenome Bbox IoU ',
                    'VinDR-CXR PRC AUC',
                    'VinDR-CXR Bbox IoU',
                    'CheXlocalize Segmentation Mask IoU',
                    'CheXlocalize Accuracy',
                    'MS-CXR Phrase Grounding IoU ',
                ],
                single_plot_figsize=(7,6))

# %%
plot_train_val_curves('/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240825_183204_mim-facts+chst-img-anat+cxrlt2024(Off)+cxrlt2024(GPT4)+vinbig+chexloc+chxp+iuxray_PhraseGrounder(aehrc-cxrmate-rrg24,FiLM_SigmoidAttention,128,256,256,256,1,256-128)/metrics_logs.csv',
                [
                    'cxrlt2024c_prc_auc', 'cxrlt2024o_prc_auc', 'cl_phrase_acc', 'vbg_prc_auc', 'mimfg_prc_auc'
                ],
                [
                    'PRC-AUC(c)', 'PRC-AUC(o)', 'cl_phrase_acc', 'vbg_prc_auc', 'mimfg_prc_auc'
                ],
                single_plot_figsize=(7,6))

# %%
plot_train_val_curves('/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240825_115146_mim-facts+chst-img-anat+cxrlt2024(Off)+cxrlt2024(GPT4)+vinbig+chexloc+chxp+iuxray_PhraseGrounder(aehrc-cxrmate-rrg24,FiLM_SigmoidAttention,128,256,256,256,1,256-128)/metrics_logs.csv',
                [
                    'cxrlt2024c_prc_auc', 'cxrlt2024o_prc_auc', 'cl_phrase_acc', 'vbg_prc_auc', 'mimfg_prc_auc'
                ],
                [
                    'PRC-AUC(c)', 'PRC-AUC(o)', 'cl_phrase_acc', 'vbg_prc_auc', 'mimfg_prc_auc'
                ],
                single_plot_figsize=(7,6))

# %%
plot_train_val_curves('/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240830_183246_mim-facts+chst-img-anat+cxrlt2024(Off)+cxrlt2024(GPT4)+vinbig+chexloc+chxp+iuxray_PhraseGrounder(google-siglip-base-p16-224,FiLM_SigmoidAttention,128,256,256,256,1,256-128)/metrics_logs.csv',
                [
                    'cxrlt2024c_prc_auc', 'cxrlt2024o_prc_auc', 'cl_phrase_acc', 'vbg_prc_auc', 'mimfg_prc_auc'
                ],
                [
                    'PRC-AUC(c)', 'PRC-AUC(o)', 'cl_phrase_acc', 'vbg_prc_auc', 'mimfg_prc_auc'
                ],
                single_plot_figsize=(7,6))

# %%
plot_train_val_curves('/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240909_220146_mim-facts+chst-img-anat+cxrlt2024(Off)+cxrlt2024(GPT4)+vinbig+chexloc+chxp+iuxray_PhraseGrounder(aehrc-cxrmate-rrg24-uniformer,FiLM_SigmoidAttention,128,256,256,256,1,256-128)/metrics_logs.csv',
                [
                    'cxrlt2024c_prc_auc', 'cxrlt2024o_prc_auc', 'cl_phrase_acc', 'vbg_prc_auc', 'mimfg_prc_auc', 'cxrlt2024c_gac_loss'
                ],
                [
                    'PRC-AUC(c)', 'PRC-AUC(o)', 'cl_phrase_acc', 'vbg_prc_auc', 'mimfg_prc_auc', 'cxrlt2024c_gac_loss'
                ],
                single_plot_figsize=(7,6), use_min_with_these_metrics=['cxrlt2024c_gac_loss'])

# %%
plot_train_val_curves('/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240909_215724_mim-facts+chst-img-anat+cxrlt2024(Off)+cxrlt2024(GPT4)+vinbig+chexloc+chxp+iuxray_PhraseGrounder(dn121,FiLM_SigmoidAttention,128,256,256,256,1,256-128)/metrics_logs.csv',
                [
                    'cxrlt2024c_prc_auc', 'cxrlt2024o_prc_auc', 'cl_phrase_acc', 'vbg_prc_auc', 'mimfg_prc_auc', 'cxrlt2024c_gac_loss', 'vbg_gac_loss'
                ],
                [
                    'PRC-AUC(c)', 'PRC-AUC(o)', 'cl_phrase_acc', 'vbg_prc_auc', 'mimfg_prc_auc', 'cxrlt2024c_gac_loss', 'vbg_gac_loss'
                ],
                single_plot_figsize=(7,6), use_min_with_these_metrics=['cxrlt2024c_gac_loss', 'vbg_gac_loss'])
