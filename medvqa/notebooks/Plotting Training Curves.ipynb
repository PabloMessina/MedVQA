# %%
from medvqa.evaluation.plots import plot_train_val_curves
from medvqa.utils.constants import MetricNames

# %%
plot_train_val_curves('/home/pamessina/medvqa-workspace/models/multimodal/20220907_084600_mim+iu+chexp+cxr14+vinbig_imgtxtenc(dense121+chx-emb+txtenc=bilstm+txtdec=lstm)_visenc-pretr=0_dws=1.0,0.2,0.3,0.25,0.25_orien_chx_ql_amp/metrics_logs.csv',
                 [
#                   MetricNames.WMEDCOMP, MetricNames.CIDER_D, MetricNames.EXACTMATCH_ANSWER,
                    MetricNames.BLEU_BACKGROUND,
                    MetricNames.CHXLABELMACROAVGF1, MetricNames.CHXLABELMICROAVGF1,
                    MetricNames.CHXLABELACC,
                    MetricNames.CHXLABEL_ROCAUC_MACRO, MetricNames.CHXLABEL_ROCAUC_MICRO,                  
                    MetricNames.QLABELS_MACROAVGF1, MetricNames.QLABELS_MICROAVGF1,
                    MetricNames.ORIENACC,
                    MetricNames.GENDER_ACC,
                    MetricNames.CXR14MACROAVGF1, MetricNames.CXR14MICROAVGF1,
                    MetricNames.VINBIGMACROAVGF1, MetricNames.VINBIGMICROAVGF1,
                 ],
                 [
#                   'Weighted Medical Completeness (QA)', 'cider-D (QA)', 'Exact Match (QA)',
                    'BLEU (background)',
                    'Chexpert-F1 (Macro Avg)', 'Chexpert-F1 (Micro Avg)',
                    'Chexpert Acc',
                    'Chexpert ROC-AUC (Macro Avg)', 'Chexpert ROC-AUC (Micro Avg)',                  
                    'Questions-F1 (Macro Avg)', 'Questions-F1 (Micro Avg)',
                    'Orientation Acc',
                    'Gender Acc',
                    'CXR14-F1 (Macro Avg)', 'CXR14-F1 (Micro Avg)',
                    'VinBig-F1 (Macro Avg)', 'VinBig-F1 (Micro Avg)',                  
                 ],
                 single_plot_figsize=(8,6))

# %%
# plot_train_val_curves('/home/pamessina/medvqa-workspace/models/multimodal/20220913_062801_mim+iu+chexp_imgtxtenc(dense121+chx-emb+txtenc=bilstm+txtdec=lstm)_visenc-pretr=0_dws=1.0,0.2,0.3_orien_chx_ql_amp/metrics_logs.csv',
#                  [
# #                   MetricNames.WMEDCOMP, MetricNames.CIDER_D, MetricNames.EXACTMATCH_ANSWER,
#                     MetricNames.BLEU_BACKGROUND,
#                     MetricNames.CHXLABELMACROAVGF1, MetricNames.CHXLABELMICROAVGF1,
#                     MetricNames.CHXLABELACC,
#                     MetricNames.CHXLABEL_ROCAUC_MACRO, MetricNames.CHXLABEL_ROCAUC_MICRO,                  
#                     MetricNames.QLABELS_MACROAVGF1, MetricNames.QLABELS_MICROAVGF1,
#                     MetricNames.ORIENACC,
#                     MetricNames.GENDER_ACC,
# #                     MetricNames.CXR14MACROAVGF1, MetricNames.CXR14MICROAVGF1,
# #                     MetricNames.VINBIGMACROAVGF1, MetricNames.VINBIGMICROAVGF1,
#                  ],
#                  [
# #                   'Weighted Medical Completeness (QA)', 'cider-D (QA)', 'Exact Match (QA)',
#                     'BLEU (background)',
#                     'Chexpert-F1 (Macro Avg)', 'Chexpert-F1 (Micro Avg)',
#                     'Chexpert Acc',
#                     'Chexpert ROC-AUC (Macro Avg)', 'Chexpert ROC-AUC (Micro Avg)',                  
#                     'Questions-F1 (Macro Avg)', 'Questions-F1 (Micro Avg)',
#                     'Orientation Acc',
#                     'Gender Acc',
# #                     'CXR14-F1 (Macro Avg)', 'CXR14-F1 (Micro Avg)',
# #                     'VinBig-F1 (Macro Avg)', 'VinBig-F1 (Micro Avg)',                  
#                  ],
#                  single_plot_figsize=(8,6))

# %%
# plot_train_val_curves('/home/pamessina/medvqa-workspace/models/vqa/20220926_004746_mim+mim(chex)+iu+iu(chex)+chexp(vqa)+cxr14(vqa)+vinbig(vqa)_oevqa(CenIA-clip-vte-vit-lp16bcbf+onehot+transf)_visenc-pretr=0_dws=1.0,0.8,0.2,0.16,0.5,0.4,0.4_medtok_orien_chx_ql_amp/metrics_logs.csv',
#                  [
#                   MetricNames.WMEDCOMP, MetricNames.CIDER_D, MetricNames.EXACTMATCH_ANSWER,
# #                     MetricNames.BLEU_BACKGROUND,
#                     MetricNames.CHXLABELMACROAVGF1, MetricNames.CHXLABELMICROAVGF1,
#                     MetricNames.CHXLABELACC,
#                     MetricNames.CHXLABEL_ROCAUC_MACRO, MetricNames.CHXLABEL_ROCAUC_MICRO,                  
#                     MetricNames.QLABELS_MACROAVGF1, MetricNames.QLABELS_MICROAVGF1,
#                     MetricNames.ORIENACC,
#                     MetricNames.GENDER_ACC,
#                     MetricNames.CXR14MACROAVGF1, MetricNames.CXR14MICROAVGF1,
#                     MetricNames.VINBIGMACROAVGF1, MetricNames.VINBIGMICROAVGF1,
#                  ],
#                  [
#                   'Weighted Medical Completeness (QA)', 'cider-D (QA)', 'Exact Match (QA)',
# #                     'BLEU (background)',
#                     'Chexpert-F1 (Macro Avg)', 'Chexpert-F1 (Micro Avg)',
#                     'Chexpert Acc',
#                     'Chexpert ROC-AUC (Macro Avg)', 'Chexpert ROC-AUC (Micro Avg)',                  
#                     'Questions-F1 (Macro Avg)', 'Questions-F1 (Micro Avg)',
#                     'Orientation Acc',
#                     'Gender Acc',
#                     'CXR14-F1 (Macro Avg)', 'CXR14-F1 (Micro Avg)',
#                     'VinBig-F1 (Macro Avg)', 'VinBig-F1 (Micro Avg)',                  
#                  ],
#                  single_plot_figsize=(8,6))

# %% [markdown]
# ##  VQA - PadChest - DenseNet121 + Transformer + q(onehot) + aux tasks (orien + sex + labels + loc)

# %%
# plot_train_val_curves('/mnt/data/pamessina/workspaces/medvqa-workspace/models/vqa/20221226_163919_padchest(vqa)_oevqa(dense121+onehot+transf)_visenc-pretr=0_orien_amp/metrics_logs.csv',
#                  [
#                      MetricNames.LOSS,
#                      MetricNames.EXACTMATCH_ANSWER,
#                      MetricNames.BLEU_1,
#                      MetricNames.BLEU_2,
#                      MetricNames.BLEU_3,
#                      MetricNames.BLEU_4,
#                      MetricNames.ORIENACC,
#                      MetricNames.GENDER_ACC,
#                      MetricNames.PADCHEST_LABEL_MACROAVGF1,
#                      MetricNames.PADCHEST_LABEL_MICROAVGF1,
#                      MetricNames.PADCHEST_LOC_MACROAVGF1,
#                      MetricNames.PADCHEST_LOC_MICROAVGF1,
#                  ],
#                  [
#                      'Loss',
#                      'Exact Match (QA)',
#                      'BLEU 1', 'BLEU 2', 'BLEU 3', 'BLEU 4',
#                      'Orientation Acc',
#                      'Gender Acc',
#                      'Labels F1 (Macro)', 'Labels F1 (Micro)',
#                      'Localizations F1 (Macro)', 'Localizations F1 (Micro)',
#                  ],
#                  single_plot_figsize=(8,6),
#                  use_min_with_these_metrics=[
#                      MetricNames.LOSS,
#                  ])

# %% [markdown]
# ## VQA - PadChest - ViTModel (facebook-vit-mae-base) + Transformer + q(onehot) + aux tasks (orien + sex + labels + loc)

# %%
# plot_train_val_curves('/mnt/data/pamessina/workspaces/medvqa-workspace/models/vqa/20221228_093550_padchest(vqa)_oevqa(facebook-vit-mae-base+onehot+transf)_visenc-pretr=0_orien_amp/metrics_logs.csv',
#                  [
#                      MetricNames.LOSS,
#                      MetricNames.EXACTMATCH_ANSWER,
#                      MetricNames.BLEU_1,
#                      MetricNames.BLEU_2,
#                      MetricNames.BLEU_3,
#                      MetricNames.BLEU_4,
#                      MetricNames.ORIENACC,
#                      MetricNames.GENDER_ACC,
#                      MetricNames.PADCHEST_LABEL_MACROAVGF1,
#                      MetricNames.PADCHEST_LABEL_MICROAVGF1,
#                      MetricNames.PADCHEST_LOC_MACROAVGF1,
#                      MetricNames.PADCHEST_LOC_MICROAVGF1,
#                  ],
#                  [
#                      'Loss',
#                      'Exact Match (QA)',
#                      'BLEU 1', 'BLEU 2', 'BLEU 3', 'BLEU 4',
#                      'Orientation Acc',
#                      'Gender Acc',
#                      'Labels F1 (Macro)', 'Labels F1 (Micro)',
#                      'Localizations F1 (Macro)', 'Localizations F1 (Micro)',
#                  ],
#                  single_plot_figsize=(8,6),
#                  use_min_with_these_metrics=[
#                      MetricNames.LOSS,
#                  ])

# %% [markdown]
# ## VQA - PadChest - ViTModel (facebook-vit-mae-base, frozen) + Transformer + q(onehot) + aux tasks (orien + sex + labels + loc)

# %%
# plot_train_val_curves('/mnt/data/pamessina/workspaces/medvqa-workspace/models/vqa/20221228_100704_padchest(vqa)_oevqa(facebook-vit-mae-base+onehot+transf)_visenc-pretr=0_orien_amp/metrics_logs.csv',
#                  [
#                      MetricNames.LOSS,
#                      MetricNames.EXACTMATCH_ANSWER,
#                      MetricNames.BLEU_1,
#                      MetricNames.BLEU_2,
#                      MetricNames.BLEU_3,
#                      MetricNames.BLEU_4,
#                      MetricNames.ORIENACC,
#                      MetricNames.GENDER_ACC,
#                      MetricNames.PADCHEST_LABEL_MACROAVGF1,
#                      MetricNames.PADCHEST_LABEL_MICROAVGF1,
#                      MetricNames.PADCHEST_LOC_MACROAVGF1,
#                      MetricNames.PADCHEST_LOC_MICROAVGF1,
#                  ],
#                  [
#                      'Loss',
#                      'Exact Match (QA)',
#                      'BLEU 1', 'BLEU 2', 'BLEU 3', 'BLEU 4',
#                      'Orientation Acc',
#                      'Gender Acc',
#                      'Labels F1 (Macro)', 'Labels F1 (Micro)',
#                      'Localizations F1 (Macro)', 'Localizations F1 (Micro)',
#                  ],
#                  single_plot_figsize=(8,6),
#                  use_min_with_these_metrics=[
#                      MetricNames.LOSS,
#                  ])

# %% [markdown]
# ## VQA - PadChest - ViTModel (facebook-vit-mae-base, fine-tuned) + Transformer + q(onehot) + aux tasks (orien + sex + labels + loc)

# %%
# plot_train_val_curves('/mnt/data/pamessina/workspaces/medvqa-workspace/models/vqa/20221228_131234_padchest(vqa)_oevqa(facebook-vit-mae-base+onehot+transf)_visenc-pretr=1_orien_amp/metrics_logs.csv',
#                  [
#                      MetricNames.LOSS,
#                      MetricNames.EXACTMATCH_ANSWER,
#                      MetricNames.BLEU_1,
#                      MetricNames.BLEU_2,
#                      MetricNames.BLEU_3,
#                      MetricNames.BLEU_4,
#                      MetricNames.ORIENACC,
#                      MetricNames.GENDER_ACC,
#                      MetricNames.PADCHEST_LABEL_MACROAVGF1,
#                      MetricNames.PADCHEST_LABEL_MICROAVGF1,
#                      MetricNames.PADCHEST_LOC_MACROAVGF1,
#                      MetricNames.PADCHEST_LOC_MICROAVGF1,
#                  ],
#                  [
#                      'Loss',
#                      'Exact Match (QA)',
#                      'BLEU 1', 'BLEU 2', 'BLEU 3', 'BLEU 4',
#                      'Orientation Acc',
#                      'Gender Acc',
#                      'Labels F1 (Macro)', 'Labels F1 (Micro)',
#                      'Localizations F1 (Macro)', 'Localizations F1 (Micro)',
#                  ],
#                  single_plot_figsize=(8,6),
#                  use_min_with_these_metrics=[
#                      MetricNames.LOSS,
#                  ])

# %%
# plot_train_val_curves('/mnt/data/pamessina/workspaces/medvqa-workspace/models/vqa/20230131_072359_mim+mim(chst-imgn)_oevqa(dense121+onehot+transf)_visenc-pretr=0_dws=1.0,1.0_medtok_amp/metrics_logs.csv',
#                  [
#                      MetricNames.ANSWER_LOSS,
#                      MetricNames.CHEST_IMAGENOME_LABEL_LOSS,                     
#                      MetricNames.WMEDCOMP, MetricNames.CIDER_D, MetricNames.EXACTMATCH_ANSWER,
#                      MetricNames.CHESTIMAGENOMELABELMACROAVGF1, MetricNames.CHESTIMAGENOMELABELMICROAVGF1,
#                      MetricNames.CHESTIMAGENOMELABELACC,
#                      MetricNames.CHESTIMAGENOMELABELROCAUC_MACRO, MetricNames.CHESTIMAGENOMELABELROCAUC_MICRO,
#                  ],
#                  [
#                      'Loss (Answer)',
#                      'Loss (ChestImaGenome)',
#                      'Weighted Medical Completeness (QA)', 'cider-D (QA)', 'Exact Match (QA)',                     
#                      'ChestImaGenome-F1 (Macro Avg)', 'ChestImaGenome-F1 (Micro Avg)',
#                      'ChestImaGenome Acc',
#                      'ChestImaGenome ROC-AUC (Macro Avg)', 'ChestImaGenome ROC-AUC (Micro Avg)',                     
#                  ], use_min_with_these_metrics=[MetricNames.LOSS],
#                  single_plot_figsize=(8,6))

# %%
# plot_train_val_curves('/mnt/data/pamessina/workspaces/medvqa-workspace/models/vqa/20230131_072359_mim+mim(chst-imgn)_oevqa(dense121+onehot+transf)_visenc-pretr=0_dws=1.0,1.0_medtok_amp/metrics_logs.csv',
#                  [
#                      MetricNames.ANSWER_LOSS,
#                      MetricNames.CHEST_IMAGENOME_LABEL_LOSS,                     
#                      MetricNames.WMEDCOMP, MetricNames.CIDER_D, MetricNames.EXACTMATCH_ANSWER,
#                      MetricNames.CHESTIMAGENOMELABELMACROAVGF1, MetricNames.CHESTIMAGENOMELABELMICROAVGF1,
#                      MetricNames.CHESTIMAGENOMELABELACC,
#                      MetricNames.CHESTIMAGENOMELABELROCAUC_MACRO, MetricNames.CHESTIMAGENOMELABELROCAUC_MICRO,
#                  ],
#                  [
#                      'Loss (Answer)',
#                      'Loss (ChestImaGenome)',
#                      'Weighted Medical Completeness (QA)', 'cider-D (QA)', 'Exact Match (QA)',                     
#                      'ChestImaGenome-F1 (Macro Avg)', 'ChestImaGenome-F1 (Micro Avg)',
#                      'ChestImaGenome Acc',
#                      'ChestImaGenome ROC-AUC (Macro Avg)', 'ChestImaGenome ROC-AUC (Micro Avg)',                     
#                  ], use_min_with_these_metrics=[MetricNames.LOSS],
#                  single_plot_figsize=(8,6))

# %%
# plot_train_val_curves('/mnt/data/pamessina/workspaces/medvqa-workspace/models/vqa/20230203_160851_mim+mim(chex)_oevqa(dense121+onehot+transf)_visenc-pretr=0_dws=1.0,1.0_medtok_chx_amp/metrics_logs.csv',
#                  [
#                      MetricNames.ANSWER_LOSS,
#                      MetricNames.CHEST_IMAGENOME_LABEL_LOSS,                     
#                      MetricNames.WMEDCOMP,
#                      MetricNames.CIDER_D, MetricNames.EXACTMATCH_ANSWER,
#                      MetricNames.CHXLABELMACROAVGF1, MetricNames.CHXLABELMICROAVGF1,
#                      MetricNames.CHXLABELACC,
#                      MetricNames.CHXLABEL_ROCAUC_MACRO, MetricNames.CHXLABEL_ROCAUC_MICRO,                  
#                      MetricNames.CHESTIMAGENOMELABELMACROAVGF1, MetricNames.CHESTIMAGENOMELABELMICROAVGF1,
#                      MetricNames.CHESTIMAGENOMELABELACC,
#                      MetricNames.CHESTIMAGENOMELABELROCAUC_MACRO, MetricNames.CHESTIMAGENOMELABELROCAUC_MICRO,
#                      MetricNames.CHESTIMAGENOMEBBOXIOU, MetricNames.CHESTIMAGENOMEBBOXMAE,
#                  ],
#                  [
#                      'Loss (Answer)',
#                      'Loss (ChestImaGenome)',
#                      'Weighted Medical Completeness (QA)',
#                      'cider-D (QA)', 'Exact Match (QA)',
#                      'Chexpert-F1 (Macro Avg)', 'Chexpert-F1 (Micro Avg)',
#                      'Chexpert Acc',
#                      'Chexpert ROC-AUC (Macro Avg)', 'Chexpert ROC-AUC (Micro Avg)',
#                      'ChestImaGenome-F1 (Macro Avg)', 'ChestImaGenome-F1 (Micro Avg)',
#                      'ChestImaGenome Acc',
#                      'ChestImaGenome ROC-AUC (Macro Avg)', 'ChestImaGenome ROC-AUC (Micro Avg)',
#                      'ChestImaGenome BBox IoU', 'ChestImaGenome BBox MAE',
#                  ], 
#                     use_min_with_these_metrics=[
#                         MetricNames.ANSWER_LOSS,
#                         MetricNames.CHEST_IMAGENOME_LABEL_LOSS,
#                         MetricNames.CHESTIMAGENOMEBBOXMAE,
#                     ],
#                     single_plot_figsize=(8,6))

# %%
plot_train_val_curves('/mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230302_221214_mim_dn121/metrics_logs.csv',
                 [
#                      MetricNames.ANSWER_LOSS,
                     MetricNames.CHEST_IMAGENOME_LABEL_LOSS,                     
#                      MetricNames.WMEDCOMP,
#                      MetricNames.CIDER_D, MetricNames.EXACTMATCH_ANSWER,
#                      MetricNames.CHXLABELMACROAVGF1, MetricNames.CHXLABELMICROAVGF1,
#                      MetricNames.CHXLABELACC,
#                      MetricNames.CHXLABEL_ROCAUC_MACRO, MetricNames.CHXLABEL_ROCAUC_MICRO,                  
                     MetricNames.CHESTIMAGENOMELABELMACROAVGF1, MetricNames.CHESTIMAGENOMELABELMICROAVGF1,
                     MetricNames.CHESTIMAGENOMELABELACC,
                     MetricNames.CHESTIMAGENOMELABELROCAUC_MACRO, MetricNames.CHESTIMAGENOMELABELROCAUC_MICRO,
#                      MetricNames.CHESTIMAGENOMEBBOXMEANF1,
#                      MetricNames.CHESTIMAGENOMEBBOXIOU, MetricNames.CHESTIMAGENOMEBBOXMAE,
                 ],
                 [
#                      'Loss (Answer)',
                     'Loss (ChestImaGenome)',
#                      'Weighted Medical Completeness (QA)',
#                      'cider-D (QA)', 'Exact Match (QA)',
#                      'Chexpert-F1 (Macro Avg)', 'Chexpert-F1 (Micro Avg)',
#                      'Chexpert Acc',
#                      'Chexpert ROC-AUC (Macro Avg)', 'Chexpert ROC-AUC (Micro Avg)',
                     'ChestImaGenome-F1 (Macro Avg)', 'ChestImaGenome-F1 (Micro Avg)',
                     'ChestImaGenome Acc',
                     'ChestImaGenome ROC-AUC (Macro Avg)', 'ChestImaGenome ROC-AUC (Micro Avg)',
#                      'ChestImaGenome BBox F1 (iou >= 0.9)',
#                      'ChestImaGenome BBox IoU', 'ChestImaGenome BBox MAE',
                 ], 
                    use_min_with_these_metrics=[
#                         MetricNames.ANSWER_LOSS,
                        MetricNames.CHEST_IMAGENOME_LABEL_LOSS,
#                         MetricNames.CHESTIMAGENOMEBBOXMAE,
                    ],
                    single_plot_figsize=(8,6))

# %%
plot_train_val_curves('/mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230215_124027_mim_dense121/metrics_logs.csv',
                [                     
                    MetricNames.CHEST_IMAGENOME_BBOX_LOSS,
                    MetricNames.CHESTIMAGENOMEBBOXMEANF1,
                    MetricNames.CHESTIMAGENOMEBBOXIOU, MetricNames.CHESTIMAGENOMEBBOXMAE,
                ],
                [
                    'Loss (ChestImaGenome Bbox loss)',
                    'ChestImaGenome BBox F1 (iou >= 0.9)',
                    'ChestImaGenome BBox IoU', 'ChestImaGenome BBox MAE',
                ], 
                use_min_with_these_metrics=[
                    MetricNames.CHEST_IMAGENOME_BBOX_LOSS,
                    MetricNames.CHESTIMAGENOMEBBOXMAE,
                ],
                single_plot_figsize=(8,6))

# %%
plot_train_val_curves('/mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230227_130158_mim_dn121/metrics_logs.csv',
                [                     
                    MetricNames.CHEST_IMAGENOME_BBOX_LOSS,
                    MetricNames.CHESTIMAGENOMEBBOXMEANF1,
                    MetricNames.CHESTIMAGENOMEBBOXIOU, MetricNames.CHESTIMAGENOMEBBOXMAE,
                ],
                [
                    'Loss (ChestImaGenome Bbox loss)',
                    'ChestImaGenome BBox F1 (iou >= 0.9)',
                    'ChestImaGenome BBox IoU', 'ChestImaGenome BBox MAE',
                ], 
                use_min_with_these_metrics=[
                    MetricNames.CHEST_IMAGENOME_BBOX_LOSS,
                    MetricNames.CHESTIMAGENOMEBBOXMAE,
                ],
                single_plot_figsize=(7,6))

# %%
plot_train_val_curves('/mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230302_080016_mim_dn121/metrics_logs.csv',
                [                     
                    MetricNames.CHEST_IMAGENOME_BBOX_LOSS,
                    MetricNames.CHESTIMAGENOMEBBOXMEANF1,
                    MetricNames.CHESTIMAGENOMEBBOXIOU, MetricNames.CHESTIMAGENOMEBBOXMAE,
                ],
                [
                    'Loss (ChestImaGenome Bbox loss)',
                    'ChestImaGenome BBox F1 (iou >= 0.9)',
                    'ChestImaGenome BBox IoU', 'ChestImaGenome BBox MAE',
                ], 
                use_min_with_these_metrics=[
                    MetricNames.CHEST_IMAGENOME_BBOX_LOSS,
                    MetricNames.CHESTIMAGENOMEBBOXMAE,
                ],
                single_plot_figsize=(7,6))

# %%
plot_train_val_curves('/mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230304_140940_mim_dn121/metrics_logs.csv',
                [                     
                    MetricNames.CHEST_IMAGENOME_BBOX_LOSS,
                    MetricNames.CHEST_IMAGENOME_LABEL_LOSS,                     
                    MetricNames.CHESTIMAGENOMEBBOXMEANF1,
                    MetricNames.CHESTIMAGENOMEBBOXIOU, MetricNames.CHESTIMAGENOMEBBOXMAE,
                    MetricNames.CHESTIMAGENOMELABELMACROAVGF1, MetricNames.CHESTIMAGENOMELABELMICROAVGF1,
                    MetricNames.CHESTIMAGENOMELABELACC,
#                     MetricNames.CHESTIMAGENOMELABELROCAUC_MACRO, MetricNames.CHESTIMAGENOMELABELROCAUC_MICRO,
                    MetricNames.CHESTIMAGENOMELABELAUC_MACRO, MetricNames.CHESTIMAGENOMELABELAUC_MICRO,
                    
                ],
                [
                    'Loss (ChestImaGenome Bbox)',
                    'Loss (ChestImaGenome MLC)',
                    'ChestImaGenome BBox F1 (iou >= 0.9)',
                    'ChestImaGenome BBox IoU', 'ChestImaGenome BBox MAE',
                    'ChestImaGenome-F1 (Macro Avg)', 'ChestImaGenome-F1 (Micro Avg)',
                    'ChestImaGenome Acc',
#                     'ChestImaGenome ROC-AUC (Macro Avg)', 'ChestImaGenome ROC-AUC (Micro Avg)',
                    'ChestImaGenome AUC (Macro Avg)', 'ChestImaGenome AUC (Micro Avg)',
                ], 
                use_min_with_these_metrics=[
                    MetricNames.CHEST_IMAGENOME_BBOX_LOSS,
                    MetricNames.CHEST_IMAGENOME_LABEL_LOSS,
                    MetricNames.CHESTIMAGENOMEBBOXMAE,
                ],
                single_plot_figsize=(7,6))
# Out:
# /home/pamessina/venv/lib/python3.6/site-packages/numpy/core/_asarray.py:83: UserWarning: Warning: converting a masked element to nan.
#   return array(a, dtype, copy=False, order=order)

# %%
plot_train_val_curves('/mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230412_215924_mim_yolov8x/metrics_logs.csv',
                [                     
#                     MetricNames.CHEST_IMAGENOME_BBOX_LOSS,
#                     MetricNames.DETECTRON2_BOX_REG_LOSS,
#                     MetricNames.DETECTRON2_CLS_LOSS,
                    MetricNames.CHESTIMAGENOMELABELPRCAUC_MACRO,
#                     MetricNames.CHESTIMAGENOMEBBOXIOU, MetricNames.CHESTIMAGENOMEBBOXMAE,
                ],
                [
#                     'Loss (ChestImaGenome Bbox loss)',
#                     'Bbox Regression Loss',
#                     'Class Loss',
                    'ChestImaGenome PR_AUC Macro Avg',
#                     'ChestImaGenome BBox IoU', 'ChestImaGenome BBox MAE',
                ], 
                use_min_with_these_metrics=[
#                     MetricNames.CHEST_IMAGENOME_BBOX_LOSS,
#                     MetricNames.CHESTIMAGENOMEBBOXMAE,
#                     MetricNames.DETECTRON2_BOX_REG_LOSS,
#                     MetricNames.DETECTRON2_CLS_LOSS,
                ],
                single_plot_figsize=(7,6))

# %%
plot_train_val_curves('/mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230413_065041_mim_yolov8x/metadata.json/metrics_logs.csv',
                [                     
#                     MetricNames.CHEST_IMAGENOME_BBOX_LOSS,
#                     MetricNames.DETECTRON2_BOX_REG_LOSS,
#                     MetricNames.DETECTRON2_CLS_LOSS,
                    MetricNames.CHESTIMAGENOMELABELPRCAUC_MACRO,
#                     MetricNames.CHESTIMAGENOMEBBOXIOU, MetricNames.CHESTIMAGENOMEBBOXMAE,
                ],
                [
#                     'Loss (ChestImaGenome Bbox loss)',
#                     'Bbox Regression Loss',
#                     'Class Loss',
                    'ChestImaGenome PR_AUC Macro Avg',
#                     'ChestImaGenome BBox IoU', 'ChestImaGenome BBox MAE',
                ], 
                use_min_with_these_metrics=[
#                     MetricNames.CHEST_IMAGENOME_BBOX_LOSS,
#                     MetricNames.CHESTIMAGENOMEBBOXMAE,
#                     MetricNames.DETECTRON2_BOX_REG_LOSS,
#                     MetricNames.DETECTRON2_CLS_LOSS,
                ],
                single_plot_figsize=(7,6))

# %%
plot_train_val_curves('/mnt/data/pamessina/workspaces/medvqa-workspace/models/report_gen/20230424_144147_mim_Labels2ReportModel(10,641->1024->641,TransfReportDec(es=512,hs=512,nl=3))/metrics_logs.csv',
                [
                    MetricNames.CIDER_D,
                    MetricNames.WMEDCOMP,
                ],
                [
                    'CiderD',
                    'Weighted Medical Completeness',
                ], 
                use_min_with_these_metrics=[
                ],
                single_plot_figsize=(7,6))
# Out:
# /home/pamessina/venv2/lib/python3.10/site-packages/matplotlib/axes/_base.py:2503: UserWarning: Warning: converting a masked element to nan.
#   xys = np.asarray(xys)

# %%
plot_train_val_curves('/mnt/data/pamessina/workspaces/medvqa-workspace/models/report_gen/20230511_161625_mim(gt)_Labels2ReportModel(t5-small)/metrics_logs.csv',
                [
                    MetricNames.REPORT_LOSS,
                    MetricNames.REPORT_LOSS_GT,
                ],
                [
                    'Report Loss (pred)',
                    'Report Loss (gt)',
                ], 
                use_min_with_these_metrics=[
                    MetricNames.REPORT_LOSS,
                    MetricNames.REPORT_LOSS_GT,
                ],
                single_plot_figsize=(7,6))
# Out:
# WARNING: Report Loss (gt) train_scores has some nans, but not all. Replacing nans with nearest non-nan values

# %%
plot_train_val_curves('/mnt/data/pamessina/workspaces/medvqa-workspace/models/report_gen/20230522_160720_mim_Image2ReportModel(dn121->TransfTextDec(posenc,es=512,hs=512,nl=3,nh=4,dff=512))/metrics_logs.csv',
                [
                    MetricNames.CIDER_D,
                    MetricNames.WMEDCOMP,
                    MetricNames.CHESTIMAGENOMELABELPRCAUC_MACRO,
                    MetricNames.CHESTIMAGENOMELABELAUC_MACRO,
                ],
                [
                    'CiderD',
                    'Weighted Medical Completeness',
                    'ChestImaGenome PR_AUC Macro Avg',
                    'ChestImaGenome ROC_AUC Macro Avg',
                ], 
                use_min_with_these_metrics=[
                ],
                single_plot_figsize=(7,6))

# %%
plot_train_val_curves('/mnt/data/pamessina/workspaces/medvqa-workspace/models/report_gen/20230522_155310_mim_Image2ReportModel(yolov8l->TransfTextDec(posenc,es=512,hs=512,nl=3,nh=4,dff=512))/metrics_logs.csv',
                [
                    MetricNames.CIDER_D,
                    MetricNames.WMEDCOMP,
                    MetricNames.CHESTIMAGENOMELABELPRCAUC_MACRO,
                    MetricNames.CHESTIMAGENOMELABELAUC_MACRO,
                ],
                [
                    'CiderD',
                    'Weighted Medical Completeness',
                    'ChestImaGenome PR_AUC Macro Avg',
                    'ChestImaGenome ROC_AUC Macro Avg',
                ], 
                use_min_with_these_metrics=[
                ],
                single_plot_figsize=(7,6))

# %%
plot_train_val_curves('/mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230525_232710_vinbig_yolov8l/metrics_logs.csv',
                [
                    MetricNames.VINBIGBBOXIOU,
                    MetricNames.VINBIGBBOXMEANF1,
                    MetricNames.VINBIGLABELPRCAUC_MACRO,
                    MetricNames.VINBIGLABELAUC_MACRO,
                ],
                [
                    'VinDR-CXR IoU',
                    'VinDR-CXR F1 (Iou >= 0.5)',
                    'VinDR-CXR PR_AUC Macro Avg',
                    'VinDR-CXR ROC_AUC Macro Avg',
                ], 
                use_min_with_these_metrics=[
                ],
                single_plot_figsize=(7,6))

# %%
# !ls '/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230719_132018_MIMIC-CXR(GPT3.5+CXR-Bert-based-labels)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/'
# Out:
# 'checkpoint_42_cacc+cscc+hscc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)=0.9201.pt'
#  metadata.json
#  metrics_logs.csv

# %%
plot_train_val_curves('/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230728_075327_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/metrics_logs.csv',
                [
                    MetricNames.LOSS,
                    'chestimg_macro_f1',
                ],
                [
                    'Loss',
                    'chestimg_macro_f1',
                ], 
                use_min_with_these_metrics=[
                    MetricNames.LOSS
                ],
                single_plot_figsize=(7,6))

# %%
plot_train_val_curves('/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230730_012705_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/metrics_logs.csv',
                [
                    MetricNames.LOSS,
                    'chestimg_macro_f1',
                ],
                [
                    'Loss',
                    'chestimg_macro_f1',
                ], 
                use_min_with_these_metrics=[
                    MetricNames.LOSS
                ],
                single_plot_figsize=(7,6))

# %%
# !ls "/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230730_012705_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)"
# Out:
# 'checkpoint_99_cacc+chf1+cscc+hscc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)=0.9559.pt'
#  metadata.json
#  metrics_logs.csv
