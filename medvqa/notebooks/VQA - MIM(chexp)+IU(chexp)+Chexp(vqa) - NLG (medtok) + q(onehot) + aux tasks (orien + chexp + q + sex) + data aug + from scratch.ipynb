# %%
# %env CUDA_VISIBLE_DEVICES=0
# Out:
# env: CUDA_VISIBLE_DEVICES=0

# %%
# !python ../train_vqa.py \
        --epochs 100 \
        --batches-per-epoch 300 \
        --batch-size 140 \
        --num-workers 7 \
        --optimizer-name "adamw" \
        --lr-decay-patience 3 \
        --answer-hidden-size 512 \
        --n-lstm-layers 1 \
        --iuxray-qa-adapted-reports-filename "qa_adapted_reports__20220629_042239.json" \
        --mimiccxr-qa-adapted-reports-filename "qa_adapted_reports__20220629_050643.json" \
        --classify-orientation \
        --classify-chexpert \
        --iuxray-chexpert-labels-filename "chexpert_labels_per_report__20220629_055107.pkl" \
        --mimiccxr-chexpert-labels-filename "chexpert_labels_per_report__20220629_055159.pkl" \
        --classify-questions \
        --n-questions 97 \
        --iuxray-question-labels-filename "question_labels_per_report__20220629_052841.pkl" \
        --mimiccxr-question-labels-filename "question_labels_per_report__20220629_052842.pkl" \
        --balanced-split \
        --iuxray-balanced-metadata-filename "balanced_dataloading_metadata__20220629_123626.pkl" \
        --mimiccxr-balanced-metadata-filename "balanced_dataloading_metadata__20220629_123956.pkl" \
        --balanced-dataloading \
        --medical-tokenization \
        --medical-terms-frequency-filename "medical_terms_frequency__20220629_052724.pkl" \
        --question-encoding "one-hot" \
        --binary-loss-name "wbce-c" \
        --img-aug-mode "random-color-and-spatial" \
        --chexpert-mode "vqa" \
        --mimiccxr-include-chexpert-mode \
        --iuxray-include-chexpert-mode \
        --use-amp \
        --save
# Out:
# script's arguments:
#    epochs: 100
#    batches_per_epoch: 300
#    checkpoint_folder: None
#    iuxray_qa_adapted_reports_filename: qa_adapted_reports__20220629_042239.json
#    mimiccxr_qa_adapted_reports_filename: qa_adapted_reports__20220629_050643.json
#    vocab_min_freq: 5
#    embed_size: 128
#    question_encoding: one-hot
#    question_hidden_size: 128
#    answer_hidden_size: 512
#    n_lstm_layers: 1
#    question_vec_size: 128
#    image_local_feat_size: 1024
#    dropout_prob: 0
#    densenet_pretrained_weights_path:
#    optimizer_name: adamw
#    lr: 0.001
#    lr_decay: 0.76
#    lr_decay_patience: 3
#    n_val_examples_per_question: 10
#    min_train_examples_per_question: 100
#    batch_size: 140
#    num_workers: 7
#    device: GPU
#    img_aug_mode: random-color-and-spatial
#    freeze_cnn: False
#    mimiccxr_weight: 0.73
#    chexpert_weight: 0.2
#    iuxray_weight: 0.07
#    mimiccxr_weight_chexpert_mode: 0.15
#    iuxray_weight_chexpert_mode: 0.03
# ...

# %% [markdown]
# ### Training-Validation plots

# %%
from medvqa.evaluation.plots import plot_train_val_curves
from medvqa.utils.constants import MetricNames

# %%
plot_train_val_curves('/home/pamessina/medvqa-workspace/models/vqa/20220711_200138_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(densenet121+bilstm+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretr)_cnn-pretr=0_dws=0.73,0.15,0.07,0.03,0.2_medtok_orien_chx_ql_amp/metrics_logs.csv',
                 [MetricNames.WMEDCOMP, MetricNames.CIDER_D, MetricNames.EXACTMATCH_ANSWER,
                  MetricNames.CHXLABELMACROAVGF1, MetricNames.CHXLABELMICROAVGF1,
                  MetricNames.CHXLABELACC,
                  MetricNames.CHXLABEL_ROCAUC_MACRO, MetricNames.CHXLABEL_ROCAUC_MICRO,
                  MetricNames.ORIENACC, 
                 ],
                 ['Weighted Medical Completeness (QA)', 'cider-D (QA)', 'Exact Match (QA)',
                  'Chexpert-F1 (Macro Avg)', 'Chexpert-F1 (Micro Avg)',
                  'Chexpert Acc',
                  'Chexpert ROC-AUC (Macro Avg)', 'Chexpert ROC-AUC (Micro Avg)',
                  'Orientation Acc',
                 ],
                 single_plot_figsize=(8,6))

# %% [markdown]
# # Test Set Evaluation

# %% [markdown]
# # Report-level Results

# %%
# !python ../eval_report_generation.py \
        --checkpoint-folder "models/vqa/20220711_200138_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(densenet121+bilstm+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretr)_cnn-pretr=0_dws=0.73,0.15,0.07,0.03,0.2_medtok_orien_chx_ql_amp" \
        --eval-mode "ground-truth" \
        --no-iuxray \
        --batch-size 160
# Out:
# script's arguments:
#    checkpoint_folder: models/vqa/20220711_200138_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(densenet121+bilstm+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretr)_cnn-pretr=0_dws=0.73,0.15,0.07,0.03,0.2_medtok_orien_chx_ql_amp
#    eval_mode: ground-truth
#    n_questions_per_report: None
#    qclass_threshold: 0
#    batch_size: 160
#    device: GPU
#    num_workers: 0
#    answer_decoding: greedy-search
#    eval_iuxray: False
#    eval_mimiccxr: True
#    use_amp: False
# ----- Evaluating model ------
# metadata loaded from /home/pamessina/medvqa-workspace/models/vqa/20220711_200138_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(densenet121+bilstm+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretr)_cnn-pretr=0_dws=0.73,0.15,0.07,0.03,0.2_medtok_orien_chx_ql_amp/metadata.json
# 1) device = cuda
# 2) Loading iuxray and mimiccxr QA adapted reports ...
# 3) Initializing tokenizer ...
# ...

# %%
# !python ../eval_report_generation.py \
        --checkpoint-folder "models/vqa/20220711_200138_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(densenet121+bilstm+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretr)_cnn-pretr=0_dws=0.73,0.15,0.07,0.03,0.2_medtok_orien_chx_ql_amp" \
        --eval-mode "chexpert-labels" \
        --no-iuxray \
        --batch-size 160
# Out:
# script's arguments:
#    checkpoint_folder: models/vqa/20220711_200138_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(densenet121+bilstm+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretr)_cnn-pretr=0_dws=0.73,0.15,0.07,0.03,0.2_medtok_orien_chx_ql_amp
#    eval_mode: chexpert-labels
#    n_questions_per_report: None
#    qclass_threshold: 0
#    batch_size: 160
#    device: GPU
#    num_workers: 0
#    answer_decoding: greedy-search
#    eval_iuxray: False
#    eval_mimiccxr: True
#    use_amp: False
# ----- Evaluating model ------
# metadata loaded from /home/pamessina/medvqa-workspace/models/vqa/20220711_200138_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(densenet121+bilstm+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretr)_cnn-pretr=0_dws=0.73,0.15,0.07,0.03,0.2_medtok_orien_chx_ql_amp/metadata.json
# 1) device = cuda
# 2) Loading iuxray and mimiccxr QA adapted reports ...
# 3) Initializing tokenizer ...
# ...

# %%
# !python ../eval_report_generation.py \
        --checkpoint-folder "models/vqa/20220711_200138_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(densenet121+bilstm+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretr)_cnn-pretr=0_dws=0.73,0.15,0.07,0.03,0.2_medtok_orien_chx_ql_amp" \
        --eval-mode "question-classification" \
        --n-questions-per-report 20 \
        --qclass-threshold 0.3 \
        --no-iuxray \
        --batch-size 160
# Out:
# script's arguments:
#    checkpoint_folder: models/vqa/20220711_200138_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(densenet121+bilstm+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretr)_cnn-pretr=0_dws=0.73,0.15,0.07,0.03,0.2_medtok_orien_chx_ql_amp
#    eval_mode: question-classification
#    n_questions_per_report: 20
#    qclass_threshold: 0.3
#    batch_size: 160
#    device: GPU
#    num_workers: 0
#    answer_decoding: greedy-search
#    eval_iuxray: False
#    eval_mimiccxr: True
#    use_amp: False
# ----- Evaluating model ------
# metadata loaded from /home/pamessina/medvqa-workspace/models/vqa/20220711_200138_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(densenet121+bilstm+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretr)_cnn-pretr=0_dws=0.73,0.15,0.07,0.03,0.2_medtok_orien_chx_ql_amp/metadata.json
# 1) device = cuda
# 2) Loading iuxray and mimiccxr QA adapted reports ...
# 3) Initializing tokenizer ...
# ...

# %%
# !python ../eval_report_generation.py \
        --checkpoint-folder "models/vqa/20220711_200138_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(densenet121+bilstm+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretr)_cnn-pretr=0_dws=0.73,0.15,0.07,0.03,0.2_medtok_orien_chx_ql_amp" \
        --eval-mode "question-classification" \
        --n-questions-per-report 20 \
        --qclass-threshold 0.2 \
        --no-iuxray \
        --batch-size 160
# Out:
# script's arguments:
#    checkpoint_folder: models/vqa/20220711_200138_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(densenet121+bilstm+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretr)_cnn-pretr=0_dws=0.73,0.15,0.07,0.03,0.2_medtok_orien_chx_ql_amp
#    eval_mode: question-classification
#    n_questions_per_report: 20
#    qclass_threshold: 0.2
#    batch_size: 160
#    device: GPU
#    num_workers: 0
#    answer_decoding: greedy-search
#    eval_iuxray: False
#    eval_mimiccxr: True
#    use_amp: False
# ----- Evaluating model ------
# metadata loaded from /home/pamessina/medvqa-workspace/models/vqa/20220711_200138_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(densenet121+bilstm+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretr)_cnn-pretr=0_dws=0.73,0.15,0.07,0.03,0.2_medtok_orien_chx_ql_amp/metadata.json
# 1) device = cuda
# 2) Loading iuxray and mimiccxr QA adapted reports ...
# 3) Initializing tokenizer ...
# ...

# %%
# !python ../eval_report_generation.py \
        --checkpoint-folder "models/vqa/20220711_200138_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(densenet121+bilstm+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretr)_cnn-pretr=0_dws=0.73,0.15,0.07,0.03,0.2_medtok_orien_chx_ql_amp" \
        --eval-mode "question-classification" \
        --n-questions-per-report 20 \
        --qclass-threshold 0.1 \
        --no-iuxray \
        --batch-size 160
# Out:
# script's arguments:
#    checkpoint_folder: models/vqa/20220711_200138_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(densenet121+bilstm+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretr)_cnn-pretr=0_dws=0.73,0.15,0.07,0.03,0.2_medtok_orien_chx_ql_amp
#    eval_mode: question-classification
#    n_questions_per_report: 20
#    qclass_threshold: 0.1
#    batch_size: 160
#    device: GPU
#    num_workers: 0
#    answer_decoding: greedy-search
#    eval_iuxray: False
#    eval_mimiccxr: True
#    use_amp: False
# ----- Evaluating model ------
# metadata loaded from /home/pamessina/medvqa-workspace/models/vqa/20220711_200138_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(densenet121+bilstm+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretr)_cnn-pretr=0_dws=0.73,0.15,0.07,0.03,0.2_medtok_orien_chx_ql_amp/metadata.json
# 1) device = cuda
# 2) Loading iuxray and mimiccxr QA adapted reports ...
# 3) Initializing tokenizer ...
# ...

# %%
# !python ../eval_report_generation.py \
        --checkpoint-folder "models/vqa/20220711_200138_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(densenet121+bilstm+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretr)_cnn-pretr=0_dws=0.73,0.15,0.07,0.03,0.2_medtok_orien_chx_ql_amp" \
        --eval-checkpoint-folder "models/visual_module/20220712_143821_mimiccxr+iuxray_densenet121_model-args=(densenet-121,1024,pretrained)_cnn-pretr=0_dataset_weights=1.0,0.08_img-aug=random-color-and-spatial_tags=0_orien=0_chx=0_ql=1_use_amp" \
        --eval-mode "question-classification" \
        --n-questions-per-report 20 \
        --qclass-threshold 0.4 \
        --no-iuxray \
        --batch-size 160
# Out:
# script's arguments:
#    checkpoint_folder: models/vqa/20220711_200138_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(densenet121+bilstm+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretr)_cnn-pretr=0_dws=0.73,0.15,0.07,0.03,0.2_medtok_orien_chx_ql_amp
#    eval_mode: question-classification
#    n_questions_per_report: 20
#    qclass_threshold: 0.4
#    batch_size: 160
#    device: GPU
#    num_workers: 0
#    answer_decoding: greedy-search
#    eval_checkpoint_folder: models/visual_module/20220712_143821_mimiccxr+iuxray_densenet121_model-args=(densenet-121,1024,pretrained)_cnn-pretr=0_dataset_weights=1.0,0.08_img-aug=random-color-and-spatial_tags=0_orien=0_chx=0_ql=1_use_amp
#    eval_iuxray: False
#    eval_mimiccxr: True
#    use_amp: False
# ----- Evaluating model ------
# ...

# %%
from medvqa.evaluation.report_generation import get_report_level_metrics_dataframe
from medvqa.utils.files import load_pickle

# %% [markdown]
# ### MIMIC-CXR metrics

# %%
mimiccxr_report_metrics = load_pickle('/home/pamessina/medvqa-workspace/results/vqa/20220711_200138_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(densenet121+bilstm+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretr)_cnn-pretr=0_dws=0.73,0.15,0.07,0.03,0.2_medtok_orien_chx_ql_amp/mimiccxr_report_level_metrics(eval_mode=ground-truth).pkl')
mimiccxr_report_level_df = get_report_level_metrics_dataframe(mimiccxr_report_metrics, 'gt')
mimiccxr_report_level_df[mimiccxr_report_level_df.columns[:20]]
# Out:
# 1it [00:00,  1.01it/s]
#   method_name        b1        b2        b3        b4        cD      rg-L  \
# 0          gt  0.313624  0.185564  0.106245  0.058769  0.153437  0.265824
#
#         met     mdcmp    wmdcmp  chxlabf1(hard)  p(micro)  r(micro)  \
# 0  0.234788  0.178079  0.159842        0.663826  0.646159  0.794644
#
#    f1(micro)  p(macro)  r(macro)  f1(macro)       acc     p(NF)  p(EC)
# 0    0.71275  0.574578  0.671371   0.608196  0.843557  0.589041    0.5

# %%
mimiccxr_report_metrics = load_pickle('/home/pamessina/medvqa-workspace/results/vqa/20220711_200138_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(densenet121+bilstm+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretr)_cnn-pretr=0_dws=0.73,0.15,0.07,0.03,0.2_medtok_orien_chx_ql_amp/mimiccxr_report_level_metrics(eval_mode=chexpert-labels).pkl')
mimiccxr_report_level_df = get_report_level_metrics_dataframe(mimiccxr_report_metrics, 'chexpert')
mimiccxr_report_level_df[mimiccxr_report_level_df.columns[:20]]
# Out:
# 1it [00:01,  1.08s/it]
#   method_name        b1        b2        b3       b4        cD     rg-L  \
# 0    chexpert  0.295106  0.163013  0.091631  0.04846  0.040935  0.19748
#
#         met     mdcmp    wmdcmp  chxlabf1(hard)  p(micro)  r(micro)  \
# 0  0.184809  0.086884  0.066234        0.508709  0.446064  0.759922
#
#    f1(micro)  p(macro)  r(macro)  f1(macro)       acc     p(NF)    p(EC)
# 0   0.562152   0.38387  0.671387   0.458864  0.712813  0.390909  0.32567

# %%
mimiccxr_report_metrics = load_pickle('/home/pamessina/medvqa-workspace/results/vqa/20220711_200138_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(densenet121+bilstm+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretr)_cnn-pretr=0_dws=0.73,0.15,0.07,0.03,0.2_medtok_orien_chx_ql_amp/mimiccxr_report_level_metrics(eval_mode=question-classification;n_q_per_report=20;qclass_threshold=0.3).pkl')
mimiccxr_report_level_df = get_report_level_metrics_dataframe(mimiccxr_report_metrics, 'qclass(20,0.3)')
mimiccxr_report_level_df[mimiccxr_report_level_df.columns[:20]]
# Out:
# 1it [00:01,  1.15s/it]
#       method_name        b1       b2        b3       b4        cD      rg-L  \
# 0  qclass(20,0.3)  0.216288  0.11879  0.063351  0.03246  0.050328  0.181183
#
#         met   mdcmp    wmdcmp  chxlabf1(hard)  p(micro)  r(micro)  f1(micro)  \
# 0  0.169947  0.1082  0.092013         0.51979  0.524958  0.638342   0.576124
#
#    p(macro)  r(macro)  f1(macro)       acc     p(NF)     p(EC)
# 0   0.40469  0.487469   0.426306  0.772122  0.359375  0.304636

# %%
mimiccxr_report_metrics = load_pickle('/home/pamessina/medvqa-workspace/results/vqa/20220711_200138_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(densenet121+bilstm+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretr)_cnn-pretr=0_dws=0.73,0.15,0.07,0.03,0.2_medtok_orien_chx_ql_amp/mimiccxr_report_level_metrics(eval_mode=question-classification;n_q_per_report=20;qclass_threshold=0.2).pkl')
mimiccxr_report_level_df = get_report_level_metrics_dataframe(mimiccxr_report_metrics, 'qclass(20,0.2)')
mimiccxr_report_level_df[mimiccxr_report_level_df.columns[:20]]
# Out:
# 1it [00:01,  1.06s/it]
#       method_name        b1        b2        b3        b4        cD      rg-L  \
# 0  qclass(20,0.2)  0.210026  0.115893  0.062003  0.031857  0.044339  0.180491
#
#         met     mdcmp    wmdcmp  chxlabf1(hard)  p(micro)  r(micro)  \
# 0  0.171466  0.107659  0.091602        0.520596  0.520412  0.651135
#
#    f1(micro)  p(macro)  r(macro)  f1(macro)       acc     p(NF)     p(EC)
# 0    0.57848  0.402054  0.499441   0.429616  0.769788  0.344262  0.304217

# %%
mimiccxr_report_metrics = load_pickle('/home/pamessina/medvqa-workspace/results/vqa/20220711_200138_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(densenet121+bilstm+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretr)_cnn-pretr=0_dws=0.73,0.15,0.07,0.03,0.2_medtok_orien_chx_ql_amp/mimiccxr_report_level_metrics(eval_mode=question-classification;n_q_per_report=20;qclass_threshold=0.1).pkl')
mimiccxr_report_level_df = get_report_level_metrics_dataframe(mimiccxr_report_metrics, 'qclass(20,0.1)')
mimiccxr_report_level_df[mimiccxr_report_level_df.columns[:20]]
# Out:
# 1it [00:01,  1.05s/it]
#       method_name        b1        b2        b3        b4        cD     rg-L  \
# 0  qclass(20,0.1)  0.202426  0.112234  0.060197  0.030956  0.041356  0.17924
#
#         met     mdcmp    wmdcmp  chxlabf1(hard)  p(micro)  r(micro)  \
# 0  0.173056  0.106703  0.090862        0.519973  0.512264  0.663087
#
#    f1(micro)  p(macro)  r(macro)  f1(macro)       acc     p(NF)     p(EC)
# 0   0.577998    0.3959  0.510526   0.430164  0.765099  0.322034  0.296599

# %%
mimiccxr_report_metrics = load_pickle('/home/pamessina/medvqa-workspace/results/vqa/20220711_200138_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(densenet121+bilstm+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretr)_cnn-pretr=0_dws=0.73,0.15,0.07,0.03,0.2_medtok_orien_chx_ql_amp/mimiccxr_report_level_metrics(eval_mode=question-classification;n_q_per_report=20;qclass_threshold=0.1;chkpt=20220712_143821).pkl')
mimiccxr_report_level_df = get_report_level_metrics_dataframe(mimiccxr_report_metrics, 'qclass(20,0.1,20220712_143821)')
mimiccxr_report_level_df[mimiccxr_report_level_df.columns[:20]]
# Out:
# 1it [00:01,  1.07s/it]
#                       method_name        b1       b2      b3       b4  \
# 0  qclass(20,0.1,20220712_143821)  0.202634  0.11289  0.0607  0.03126
#
#          cD      rg-L       met     mdcmp    wmdcmp  chxlabf1(hard)  p(micro)  \
# 0  0.039757  0.179236  0.174155  0.107165  0.091167         0.52256  0.507652
#
#    r(micro)  f1(micro)  p(macro)  r(macro)  f1(macro)      acc     p(NF)  \
# 0  0.669063   0.577287  0.404122  0.509015   0.432265  0.76229  0.464286
#
#       p(EC)
# 0  0.297136

# %%
mimiccxr_report_metrics = load_pickle('/home/pamessina/medvqa-workspace/results/vqa/20220711_200138_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(densenet121+bilstm+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretr)_cnn-pretr=0_dws=0.73,0.15,0.07,0.03,0.2_medtok_orien_chx_ql_amp/mimiccxr_report_level_metrics(eval_mode=question-classification;n_q_per_report=20;qclass_threshold=0.3;chkpt=20220712_143821).pkl')
mimiccxr_report_level_df = get_report_level_metrics_dataframe(mimiccxr_report_metrics, 'qclass(20,0.3,20220712_143821)')
mimiccxr_report_level_df[mimiccxr_report_level_df.columns[:20]]
# Out:
# 1it [00:01,  1.05s/it]
#                       method_name        b1        b2        b3        b4  \
# 0  qclass(20,0.3,20220712_143821)  0.224065  0.122895  0.065525  0.033579
#
#          cD      rg-L       met     mdcmp    wmdcmp  chxlabf1(hard)  p(micro)  \
# 0  0.050744  0.181786  0.166936  0.109225  0.092684        0.521598  0.533845
#
#    r(micro)  f1(micro)  p(macro)  r(macro)  f1(macro)       acc     p(NF)  \
# 0  0.623774   0.575317  0.415281  0.474283   0.430569  0.776585  0.408163
#
#       p(EC)
# 0  0.295492

# %%
mimiccxr_report_metrics = load_pickle('/home/pamessina/medvqa-workspace/results/vqa/20220711_200138_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(densenet121+bilstm+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretr)_cnn-pretr=0_dws=0.73,0.15,0.07,0.03,0.2_medtok_orien_chx_ql_amp/mimiccxr_report_level_metrics(eval_mode=question-classification;n_q_per_report=20;qclass_threshold=0.05;chkpt=20220712_143821).pkl')
mimiccxr_report_level_df = get_report_level_metrics_dataframe(mimiccxr_report_metrics, 'qclass(20,0.05,20220712_143821)')
mimiccxr_report_level_df[mimiccxr_report_level_df.columns[:20]]
# Out:
# 1it [00:01,  1.07s/it]
#                        method_name        b1        b2        b3        b4  \
# 0  qclass(20,0.05,20220712_143821)  0.202865  0.112967  0.060789  0.031326
#
#         cD      rg-L       met     mdcmp    wmdcmp  chxlabf1(hard)  p(micro)  \
# 0  0.03994  0.179024  0.173082  0.107097  0.091042        0.521919  0.509186
#
#    r(micro)  f1(micro)  p(macro)  r(macro)  f1(macro)       acc     p(NF)  \
# 0  0.665141   0.576808  0.402505  0.506525   0.432966  0.763219  0.426471
#
#      p(EC)
# 0  0.28972

# %%
mimiccxr_report_metrics = load_pickle('/home/pamessina/medvqa-workspace/results/vqa/20220711_200138_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(densenet121+bilstm+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretr)_cnn-pretr=0_dws=0.73,0.15,0.07,0.03,0.2_medtok_orien_chx_ql_amp/mimiccxr_report_level_metrics(eval_mode=question-classification;n_q_per_report=20;qclass_threshold=0.0;chkpt=20220712_143821).pkl')
mimiccxr_report_level_df = get_report_level_metrics_dataframe(mimiccxr_report_metrics, 'qclass(20,0,20220712_143821)')
mimiccxr_report_level_df[mimiccxr_report_level_df.columns[:20]]
# Out:
# 1it [00:01,  1.07s/it]
#                     method_name        b1        b2        b3        b4  \
# 0  qclass(20,0,20220712_143821)  0.154943  0.089459  0.049378  0.025781
#
#          cD      rg-L       met     mdcmp    wmdcmp  chxlabf1(hard)  p(micro)  \
# 0  0.006573  0.162074  0.183495  0.096432  0.082481        0.514688  0.449545
#
#    r(micro)  f1(micro)  p(macro)  r(macro)  f1(macro)       acc  p(NF)   p(EC)
# 0  0.766271   0.566654  0.370391  0.592688   0.421326  0.715668    0.5  0.2885

# %%
mimiccxr_report_metrics = load_pickle('/home/pamessina/medvqa-workspace/results/vqa/20220711_200138_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(densenet121+bilstm+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretr)_cnn-pretr=0_dws=0.73,0.15,0.07,0.03,0.2_medtok_orien_chx_ql_amp/mimiccxr_report_level_metrics(eval_mode=question-classification;n_q_per_report=20;qclass_threshold=0.4;chkpt=20220712_143821).pkl')
mimiccxr_report_level_df = get_report_level_metrics_dataframe(mimiccxr_report_metrics, 'qclass(20,0.4,20220712_143821)')
mimiccxr_report_level_df[mimiccxr_report_level_df.columns[:20]]
# Out:
# 1it [00:01,  1.05s/it]
#                       method_name        b1        b2        b3        b4  \
# 0  qclass(20,0.4,20220712_143821)  0.172238  0.098169  0.053661  0.027887
#
#          cD      rg-L       met     mdcmp    wmdcmp  chxlabf1(hard)  p(micro)  \
# 0  0.018976  0.170547  0.181176  0.101774  0.086938        0.521441  0.474241
#
#    r(micro)  f1(micro)  p(macro)  r(macro)  f1(macro)       acc     p(NF)  \
# 0  0.732375   0.575696  0.384225   0.56245   0.431563  0.738095  0.483871
#
#       p(EC)
# 0  0.292407

# %%
mimiccxr_report_level_df = get_report_level_metrics_dataframe('/home/pamessina/medvqa-workspace/results/vqa/20220711_200138_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(densenet121+bilstm+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretr)_cnn-pretr=0_dws=0.73,0.15,0.07,0.03,0.2_medtok_orien_chx_ql_amp/mimiccxr_report_level_metrics(eval_mode=question-classification;n_q_per_report=20;qclass_threshold=0.4;chkpt=20220712_143821).pkl',
                                                              'qclass(20,0.4,20220712_143821)')
mimiccxr_report_level_df[mimiccxr_report_level_df.columns[:20]]
# Out:
# 1it [00:00, 1114.62it/s]
#                       method_name        b1        b2        b3        b4  \
# 0  qclass(20,0.4,20220712_143821)  0.172238  0.098169  0.053661  0.027887
#
#          cD      rg-L       met     mdcmp    wmdcmp  chxlabf1(hard)  p(micro)  \
# 0  0.018976  0.170547  0.181176  0.101774  0.086938        0.521441  0.474241
#
#    r(micro)  f1(micro)  p(macro)  r(macro)  f1(macro)       acc     p(NF)  \
# 0  0.732375   0.575696  0.384225   0.56245   0.431563  0.738095  0.483871
#
#       p(EC)
# 0  0.292407
