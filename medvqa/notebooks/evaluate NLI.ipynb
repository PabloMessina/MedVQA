# %%
# %env CUDA_VISIBLE_DEVICES=2
# Out:
# env: CUDA_VISIBLE_DEVICES=2

# %% [markdown]
# # CXR Fact Embedding (T)

# %%
# !python ../eval_NLI_v2.py \
--huggingface_model_name "microsoft/BiomedVLP-CXR-BERT-specialized" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230927_194923_MIMIC-CXR(triplets-only)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)" \
--device "GPU" \
--batch_size 100 \
--num_workers 3 \
--integrated_nli_jsonl_filepath \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(162036,21465751).jsonl"
# Out:
# script's arguments:
#    huggingface_model_name: microsoft/BiomedVLP-CXR-BERT-specialized
#    model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230927_194923_MIMIC-CXR(triplets-only)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)
#    device: GPU
#    batch_size: 100
#    num_workers: 3
#    integrated_nli_jsonl_filepath: /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(162036,21465751).jsonl
#    similarity_metric: cosine
#    average_token_embeddings: False
#    calibrate_on_test_set: False
# checkpoint_names = ['checkpoint_40_ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9355.pt']
# Train entailment pairs: 26442
# Train contradiction pairs: 95777
# Example train entailment pairs:
# ('The alignment of the sternotomy wires is constant.', 'There are sternotomy wires in place.')
# ('Minimal opacification in right lung base may represent atelectasis.', 'Area of opacity in the right lung base is likely atelectasis.')
# ('There is discontinuity in the tubing at the level of the mandible.', 'The tubing is not continuous at the level of the mandible.')
# ('PAST MEDICAL HISTORY:  [**Location (un) 842**]-Gastaut syndrome diagnosed at age 10 associated with approximately six seizures a month.', ' Patient has a congenital disorder')
# Example train contradiction pairs:
# ('Known proximal tracheal stent was equally visible on prior exam.', 'Known proximal tracheal stent was better seen on prior exam.')
# ('Mediastinal silhouette and hilar contours are normal allowing for low lung volumes.', 'Mediastinal silhouette and hilar contours are normal allowing for high lung volumes.')
# ('He does not do much outside exercise during cold weather as it adversely affects his breathing with the sarcoidosis.', ' The patient has no autoimmune disease. ')
# ("The patient's chest X-ray shows no signs of pulmonary edema.", 'Bilateral upper lobe ground-glass opacity and central pulmonary vascular engorgement compatible with pulmonary edema.')
# Test radnli entailment pairs: 102
# Test radnli contradiction pairs: 98
# Example test radnli entailment pairs:
# ('No acute osseous abnormality seen.', 'No acute osseous abnormalities are visualized.')
# ('There is no effusion.', 'There is no pleural effusion.')
# ('There is no pneumothorax, pulmonary edema, pneumonia, or pleural effusion.', 'There is no pneumothorax.')
# ('Opacities involving the right middle lobe and left lower lobe are again demonstrated and may represent atelectasis or infection in the appropriate setting.', 'Minimal left basilar opacity suggests minor atelectasis.')
# Example test radnli contradiction pairs:
# ('Mild pulmonary edema is redemonstrated, stable since prior chest x-ray.', 'No pulmonary edema is seen.')
# ('Moderate to large bilateral pleural effusions are again seen, likely right greater than left.', 'There is no pulmonary edema or pleural effusions.')
# ('Mild pulmonary vascular congestion is present and probable trace bilateral pleural effusions.', 'No pleural effusion or pneumothorax is seen.')
# ('No pleural effusion or pneumothorax is clearly noted on this supine exam, though the left costophrenic angle is not completely included in the field of view.', 'The costophrenic angles are not fully included on the image and pleural effusions are difficult to exclude.')
# Test mscxrt entailment pairs: 141
# Test mscxrt contradiction pairs: 220
# Example test mscxrt entailment pairs:
# ('moderate right and small left pleural effusions unchanged.', 'moderate right and small left pleural effusions stable.')
# ('opacities in the left base have minimally improved.', 'opacities in the left base have minimally decreased.')
# ('possible slight worsening of hazy opacity at right base.', 'possible slight progression of hazy opacity at right base.')
# ('Slight decrease in moderate pulmonary edema.', 'Slight improvement in moderate pulmonary edema.')
# Example test mscxrt contradiction pairs:
# ('the extent of the right pleural effusion has decreased.', 'the extent of the right pleural effusion has increased.')
# ('the right basal consolidation is unchanged.', 'the right basal consolidation is improved.')
# ('As compared to the previous image, the right upper lobe pneumonia is unchanged.', 'Likely developing right upper lobe pneumonia.')
# ('there is stable mild perihilar and interstitial edema.', 'there is new mild perihilar and interstitial edema.')
# Total sentences: 102464
#   0%|                                                | 0/102464 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=359,388447562913600091).pkl
# len(self.cache["hashes"]) = 42198
# self.cache["embeddings"].shape = (42198, 128)
# 100%|███████████████████████████████| 102464/102464 [00:00<00:00, 315464.26it/s]
# Computing embeddings for 102087 new texts
# Explicitly passing a `revision` is encouraged when loading a configuration with custom code to ensure no malicious code has been contributed in a newer revision.
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# checkpoint_names = ['checkpoint_40_ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9355.pt']
# Loading model weights from /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230927_194923_MIMIC-CXR(triplets-only)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/checkpoint_40_ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9355.pt
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# 100%|███████████████████████████████████████| 1021/1021 [02:07<00:00,  7.99it/s]
# Saving updated cache to /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=359,388447562913600091).pkl
# 100%|███████████████████████████████| 102087/102087 [00:00<00:00, 397767.43it/s]
# embeddings.shape: (102464, 128)
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (26442, 128)
# train_h_ent_embeddings.shape: (26442, 128)
# train_p_con_embeddings.shape: (95777, 128)
# train_h_con_embeddings.shape: (95777, 128)
# train_ent_cosine_sim.shape: (26442,)
# train_con_cosine_sim.shape: (95777,)
# 100%|█████████████████████████████████████| 1000/1000 [00:00<00:00, 6430.37it/s]
# best_threshold: 0.7131551247578602
# best_acc: 0.6873097436787927
# best_ent_acc: 0.7916193933893049
# best_con_acc: 0.5830000939682805
# --------------
# Evaluating on RadNLI test set
# test_p_ent_embeddings.shape: (102, 128)
# test_h_ent_embeddings.shape: (102, 128)
# test_p_con_embeddings.shape: (98, 128)
# test_h_con_embeddings.shape: (98, 128)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 0.696078431372549
# contradiction_acc: 0.8979591836734694
# test_acc: 0.7970188075230091
# --------------
# --------------
# Evaluating on MS-CXR-T Temporal Sentence Similarity v1
# test_p_ent_embeddings.shape: (141, 128)
# test_h_ent_embeddings.shape: (141, 128)
# test_p_con_embeddings.shape: (220, 128)
# test_h_con_embeddings.shape: (220, 128)
# test_ent_cosine_sim.shape: (141,)
# test_con_cosine_sim.shape: (220,)
# entailment_acc: 1.0
# contradiction_acc: 0.21818181818181817
# test_acc: 0.6090909090909091
# --------------

# %%
# !python ../eval_NLI_v2.py \
--huggingface_model_name "microsoft/BiomedVLP-CXR-BERT-specialized" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230927_194923_MIMIC-CXR(triplets-only)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)" \
--device "GPU" \
--batch_size 100 \
--num_workers 3 \
--integrated_nli_jsonl_filepath \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(169025,21838032).jsonl"
# Out:
# script's arguments:
#    huggingface_model_name: microsoft/BiomedVLP-CXR-BERT-specialized
#    model_name: None
#    model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230927_194923_MIMIC-CXR(triplets-only)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)
#    device: GPU
#    batch_size: 100
#    num_workers: 3
#    integrated_nli_jsonl_filepath: /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(169025,21838032).jsonl
#    similarity_metric: cosine
#    average_token_embeddings: False
#    calibrate_on_test_set: False
# checkpoint_names = ['checkpoint_40_ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9355.pt']
# Train entailment pairs: 25175
# Train contradiction pairs: 99121
# Example train entailment pairs:
# ('Again there is some hyperexpansion of the lungs with mild prominence of interstitial markings.', "The patient's lungs are hyperexpanded and show mild prominence of interstitial markings.")
# ('There it is central pulmonary vascular engorgement.', "The patient's central pulmonary vessels are enlarged.")
# ('Retrocardiac opacity may reflect atelectasis.', 'Streaky retrocardiac opacity may reflect atelectasis.')
# ('Note is made of new moderate gastric distension.', "The patient's stomach is moderately distended.")
# Example train contradiction pairs:
# ('The tracheostomy tube ends in the distal trachea, and the cardiac and mediastinal contours are normal.', 'The mediastinal contours are abnormal.')
# ('fiducial markers are noted within the left upper lobe laterally with adjacent opacity compatible with radiation fibrosis with pleural thickening.', "There are no signs of radiation fibrosis in the patient's lungs.")
# ('The heart is unchanged in size, mildly enlarged, and the mediastinal and hilar contours are also stable.', 'The heart is unchanged in size, but not mildly enlarged, and the mediastinal and hilar contours are also stable.')
# ('Mild pulmonary vascular congestion and mild cardiomegaly.', 'Severe pulmonary vascular congestion and severe cardiomegaly are present.')
# Test radnli entailment pairs: 102
# Test radnli contradiction pairs: 98
# Example test radnli entailment pairs:
# ('The lungs are hyperinflated but clear without consolidation, effusion, or pneumothorax.', 'No large effusion or pneumothorax is seen.')
# ('The lungs are clear without focal consolidation, pleural effusion or pneumothorax.', 'No pleural effusions.')
# ('There is no pneumothorax, pulmonary edema, pneumonia, or pleural effusion.', 'There is no pneumothorax.')
# ('No pleural effusion or pneumothorax is seen.', 'No pneumothorax is seen.')
# Example test radnli contradiction pairs:
# ('There is no pneumothorax or pleural effusion.', 'Small right pleural effusion has decreased.')
# ('Mild pulmonary edema is redemonstrated, stable since prior chest x-ray.', 'No pulmonary edema is seen.')
# ('Lung volumes are low, and the cardiac silhouette is enlarged.', 'Cardiac silhouette is normal in size.')
# ('There is evidence of a right pleural effusion.', 'There is no pleural effusion or pneumothorax.')
# Test mscxrt entailment pairs: 141
# Test mscxrt contradiction pairs: 220
# Example test mscxrt entailment pairs:
# ('there has been improvement in the pulmonary vascular congestion', 'there has been decrease in the pulmonary vascular congestion')
# ('interval improvement in mild pulmonary edema.', 'interval decrease in mild pulmonary edema.')
# ('pulmonary edema has also increased.', 'pulmonary edema has also worsened.')
# ('Improved mild interstitial edema.', 'Improved but persistent mild interstitial edema.')
# Example test mscxrt contradiction pairs:
# ('right lower lobe consolidation has only slightly improved.', 'right lower lobe consolidation has only slightly worsened.')
# ('severely atelectatic left lower lobe is unchanged.', 'severely atelectatic left lower lobe is new.')
# ('interval decrease in right pleural effusion.', 'interval increase in right pleural effusion.')
# ('Interval worsening of the right-sided pneumothorax.', 'No definite interval change in right-sided pneumothorax with details as above.')
# Total sentences: 98658
#   0%|                                                 | 0/98658 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=359,388447562913600091).pkl
# len(self.cache["hashes"]) = 146286
# self.cache["embeddings"].shape = (146286, 128)
# 100%|█████████████████████████████████| 98658/98658 [00:00<00:00, 215750.25it/s]
# Computing embeddings for 18445 new texts
# Explicitly passing a `revision` is encouraged when loading a configuration with custom code to ensure no malicious code has been contributed in a newer revision.
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# checkpoint_names = ['checkpoint_40_ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9355.pt']
# Loading model weights from /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230927_194923_MIMIC-CXR(triplets-only)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/checkpoint_40_ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9355.pt
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# 100%|█████████████████████████████████████████| 185/185 [00:14<00:00, 12.52it/s]
# Saving updated cache to /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=359,388447562913600091).pkl
# 100%|█████████████████████████████████| 18445/18445 [00:00<00:00, 311727.62it/s]
# embeddings.shape: (98658, 128)
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (25175, 128)
# train_h_ent_embeddings.shape: (25175, 128)
# train_p_con_embeddings.shape: (99121, 128)
# train_h_con_embeddings.shape: (99121, 128)
# train_ent_cosine_sim.shape: (25175,)
# train_con_cosine_sim.shape: (99121,)
# 100%|█████████████████████████████████████| 1000/1000 [00:00<00:00, 7396.59it/s]
# best_threshold: 0.6404617552284722
# best_acc: 0.6848592797021469
# best_ent_acc: 0.7980536246276068
# best_con_acc: 0.5716649347766871
# --------------
# Evaluating on RadNLI test set
# test_p_ent_embeddings.shape: (102, 128)
# test_h_ent_embeddings.shape: (102, 128)
# test_p_con_embeddings.shape: (98, 128)
# test_h_con_embeddings.shape: (98, 128)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 0.696078431372549
# contradiction_acc: 0.8979591836734694
# test_acc: 0.7970188075230091
# --------------
# --------------
# Evaluating on MS-CXR-T Temporal Sentence Similarity v1
# test_p_ent_embeddings.shape: (141, 128)
# test_h_ent_embeddings.shape: (141, 128)
# test_p_con_embeddings.shape: (220, 128)
# test_h_con_embeddings.shape: (220, 128)
# test_ent_cosine_sim.shape: (141,)
# test_con_cosine_sim.shape: (220,)
# entailment_acc: 1.0
# contradiction_acc: 0.18636363636363637
# test_acc: 0.5931818181818181
# --------------

# %%
# !python ../eval_NLI_v2.py \
--huggingface_model_name "microsoft/BiomedVLP-CXR-BERT-specialized" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230927_194923_MIMIC-CXR(triplets-only)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)" \
--device "GPU" \
--batch_size 100 \
--num_workers 3 \
--calibrate_on_test_set
# Out:
# script's arguments:
#    huggingface_model_name: microsoft/BiomedVLP-CXR-BERT-specialized
#    model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230927_194923_MIMIC-CXR(triplets-only)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)
#    device: GPU
#    batch_size: 100
#    num_workers: 3
#    integrated_nli_jsonl_filepath: None
#    similarity_metric: cosine
#    average_token_embeddings: False
#    calibrate_on_test_set: True
# checkpoint_names = ['checkpoint_40_ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9355.pt']
# Test radnli entailment pairs: 102
# Test radnli contradiction pairs: 98
# Example test radnli entailment pairs:
# ('No pleural effusion or pneumothorax is seen.', 'No pneumothorax is seen.')
# ('The lungs are clear without focal consolidation.', 'There is no focal consolidation.')
# ('No pleural effusion or pneumothorax is seen.', 'There is no pleural effusion')
# ('Cardiomediastinal silhouette and hilar contours are unremarkable.', 'Cardiomediastinal and hilar contours are normal.')
# Example test radnli contradiction pairs:
# ('Pleural effusions are likely present.', 'There is no focal consolidation, pleural effusion or pneumothorax.')
# ('Known small left pneumothorax is not well seen.', 'No pneumothorax.')
# ('The costophrenic angles are not fully included on the image and pleural effusions are difficult to exclude.', 'No pleural effusion or pneumothorax is clearly noted on this supine exam, though the left costophrenic angle is not completely included in the field of view.')
# ('There is scattered atelectasis and there are tiny bilateral pleural effusions.', 'There is no pleural effusion or pneumothorax in the left.')
# Test mscxrt entailment pairs: 141
# Test mscxrt contradiction pairs: 220
# Example test mscxrt entailment pairs:
# ('small - to - moderate right pleural effusion has decreased.', 'small - to - moderate right pleural effusion has improved.')
# ('mild pulmonary edema is stable.', 'mild pulmonary edema is unchanged.')
# ('interval worsening of the right - sided pneumothorax.', 'interval increase of the right - sided pneumothorax.')
# ('bilateral pleural effusions are moderate, unchanged.', 'bilateral pleural effusions are moderate, stable.')
# Example test mscxrt contradiction pairs:
# ('and apparent decrease in size in bilateral pleural effusions.', 'and apparent increase in size in bilateral pleural effusions.')
# ('subsegmental atelectasis at the left lung base has worsened.', 'subsegmental atelectasis at the left lung base has improved.')
# ('there is a marked decrease in extent of the right pleural effusion.', 'there is a marked increase in extent of the right pleural effusion.')
# ('worsening left - sided pleural effusion.', 'stable left - sided pleural effusion.')
# Total sentences: 825
#   0%|                                                   | 0/825 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=359,388447562913600091).pkl
# len(self.cache["hashes"]) = 144285
# self.cache["embeddings"].shape = (144285, 128)
# 100%|███████████████████████████████████████| 825/825 [00:00<00:00, 2805.52it/s]
# embeddings.shape: (825, 128)
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (102, 128)
# train_h_ent_embeddings.shape: (102, 128)
# train_p_con_embeddings.shape: (98, 128)
# train_h_con_embeddings.shape: (98, 128)
# train_ent_cosine_sim.shape: (102,)
# train_con_cosine_sim.shape: (98,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 30294.50it/s]
# best_threshold: 0.20671933477705307
# best_acc: 0.8730492196878752
# best_ent_acc: 0.9705882352941176
# best_con_acc: 0.7755102040816326
# --------------
# Evaluating on RadNLI test set
# test_p_ent_embeddings.shape: (102, 128)
# test_h_ent_embeddings.shape: (102, 128)
# test_p_con_embeddings.shape: (98, 128)
# test_h_con_embeddings.shape: (98, 128)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 0.9705882352941176
# contradiction_acc: 0.7755102040816326
# test_acc: 0.8730492196878752
# --------------
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (141, 128)
# train_h_ent_embeddings.shape: (141, 128)
# train_p_con_embeddings.shape: (220, 128)
# train_h_con_embeddings.shape: (220, 128)
# train_ent_cosine_sim.shape: (141,)
# train_con_cosine_sim.shape: (220,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 30377.00it/s]
# best_threshold: 0.9956195610421557
# best_acc: 0.78033526756931
# best_ent_acc: 0.6879432624113475
# best_con_acc: 0.8727272727272727
# --------------
# Evaluating on MS-CXR-T Temporal Sentence Similarity v1
# test_p_ent_embeddings.shape: (141, 128)
# test_h_ent_embeddings.shape: (141, 128)
# test_p_con_embeddings.shape: (220, 128)
# test_h_con_embeddings.shape: (220, 128)
# test_ent_cosine_sim.shape: (141,)
# test_con_cosine_sim.shape: (220,)
# entailment_acc: 0.6879432624113475
# contradiction_acc: 0.8727272727272727
# test_acc: 0.78033526756931
# --------------

# %% [markdown]
# # CXR Fact Embedding (T -> T+EC)

# %%
# !python ../eval_NLI_v2.py \
--huggingface_model_name "microsoft/BiomedVLP-CXR-BERT-specialized" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230927_234549_MIMIC-CXR(triplets+entcont)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)" \
--device "GPU" \
--batch_size 100 \
--num_workers 3 \
--integrated_nli_jsonl_filepath \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(162036,21465751).jsonl"
# Out:
# script's arguments:
#    huggingface_model_name: microsoft/BiomedVLP-CXR-BERT-specialized
#    model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230927_234549_MIMIC-CXR(triplets+entcont)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)
#    device: GPU
#    batch_size: 100
#    num_workers: 3
#    integrated_nli_jsonl_filepath: /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(162036,21465751).jsonl
#    similarity_metric: cosine
#    average_token_embeddings: False
#    calibrate_on_test_set: False
# checkpoint_names = ['checkpoint_47_encc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9451.pt']
# Train entailment pairs: 26442
# Train contradiction pairs: 95777
# Example train entailment pairs:
# ('Interval right chest wall port catheter is in standard position.', 'Right chest wall port is seen in stable position.')
# ('A right PICC terminates at the cavoatrial junction as before.', 'The right PICC terminates in the cavoatrial junction.')
# ('Minimal blunting of the right costophrenic angle is consistent with a small right pleural effusion.', 'There is blunting of the right costophrenic angle consistent with a small right pleural effusion.')
# ('Moderate cardiomegaly and mild to moderate pulmonary edema persists.', 'Moderate cardiomegaly, mild to moderate pulmonary edema.')
# Example train contradiction pairs:
# ('Severe bilateral pulmonary opacities and obscuration of the hemidiaphragms have significantly improved', 'Severe bilateral pulmonary opacities and obscuration of the hemidiaphragms are unchanged concerning for bilateral consolidations with pulmonary edema.')
# ('There is again seen a left-sided Port-A-Cath with the distal lead tip in the SVC.', 'There is a right-sided Port-A-Cath with the distal lead tip in the SVC.')
# ('There is no atelectasis in the left lower lobe adjacent to a large left-sided hiatal hernia.', 'Unchanged left lower lobe atelectasis adjacent to a large left-sided hiatal hernia.')
# ('There are no other interval changes from prior.', 'There has been interval removal of a endotracheal tube and enteric tube.')
# Test radnli entailment pairs: 102
# Test radnli contradiction pairs: 98
# Example test radnli entailment pairs:
# ('The cardiomediastinal silhouette and pulmonary vasculature are normal.', 'Pulmonary vascularity is normal.')
# ('Hilar and mediastinal silhouettes are unremarkable.', 'The mediastinal and hilar contours are normal.')
# ('No pleural effusion or pneumothorax is seen although the left costophrenic angle is excluded from the field of view.', 'No pleural effusions.')
# ('The lungs are clear without focal consolidation, pleural effusion or pneumothorax.', 'There are no pleural effusions.')
# Example test radnli contradiction pairs:
# ('No pleural effusions.', 'The small bilateral pleural effusions are unchanged in size.')
# ('There is no focal consolidation, pleural effusion or pneumothorax.', 'Pleural effusions are likely present.')
# ('The lungs are well expanded and clear.', 'The lungs are otherwise clear.')
# ('There is no focal consolidation, pleural effusion or pneumothorax.', 'The right atelectasis and pleural effusion has increased.')
# Test mscxrt entailment pairs: 141
# Test mscxrt contradiction pairs: 220
# Example test mscxrt entailment pairs:
# ('more severe consolidation in the left lower lobe has worsened as well.', 'more severe consolidation in the left lower lobe has increased as well.')
# ('slightly increased moderate pulmonary edema.', 'slightly worsened moderate pulmonary edema.')
# ('right basal opacities have minimally improved.', 'right basal opacities have minimally decreased.')
# ('mild pulmonary edema on ___ has decreased.', 'mild pulmonary edema on ___ has improved.')
# Example test mscxrt contradiction pairs:
# ('Significant interval decrease in size of right pleural effusion.', 'No significant interval change in size right pleural effusion.')
# ('As compared to the previous radiograph, the extent of the pre-existing right pneumothorax has substantially increased.', 'The known right pneumothorax is not substantially changed.')
# ('left small - to - moderate pneumothorax has slightly decreased in size.', 'left small - to - moderate pneumothorax has slightly increased in size.')
# ('Consolidation of left lung is increased.', 'Consolidation in the left lung has improved.')
# Total sentences: 102464
#   0%|                                                | 0/102464 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=367,2428892134441720844).pkl
# len(self.cache["hashes"]) = 32416
# self.cache["embeddings"].shape = (32416, 128)
# 100%|███████████████████████████████| 102464/102464 [00:00<00:00, 519184.27it/s]
# Computing embeddings for 102438 new texts
# Explicitly passing a `revision` is encouraged when loading a configuration with custom code to ensure no malicious code has been contributed in a newer revision.
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# checkpoint_names = ['checkpoint_47_encc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9451.pt']
# Loading model weights from /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230927_234549_MIMIC-CXR(triplets+entcont)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/checkpoint_47_encc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9451.pt
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# 100%|███████████████████████████████████████| 1025/1025 [01:48<00:00,  9.46it/s]
# Saving updated cache to /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=367,2428892134441720844).pkl
# 100%|███████████████████████████████| 102438/102438 [00:00<00:00, 668137.92it/s]
# embeddings.shape: (102464, 128)
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (26442, 128)
# train_h_ent_embeddings.shape: (26442, 128)
# train_p_con_embeddings.shape: (95777, 128)
# train_h_con_embeddings.shape: (95777, 128)
# train_ent_cosine_sim.shape: (26442,)
# train_con_cosine_sim.shape: (95777,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 11436.29it/s]
# best_threshold: 0.4087020511980408
# best_acc: 0.9206713429147622
# best_ent_acc: 0.95643294758339
# best_con_acc: 0.8849097382461343
# --------------
# Evaluating on RadNLI test set
# test_p_ent_embeddings.shape: (102, 128)
# test_h_ent_embeddings.shape: (102, 128)
# test_p_con_embeddings.shape: (98, 128)
# test_h_con_embeddings.shape: (98, 128)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 0.9705882352941176
# contradiction_acc: 0.8367346938775511
# test_acc: 0.9036614645858343
# --------------
# --------------
# Evaluating on MS-CXR-T Temporal Sentence Similarity v1
# test_p_ent_embeddings.shape: (141, 128)
# test_h_ent_embeddings.shape: (141, 128)
# test_p_con_embeddings.shape: (220, 128)
# test_h_con_embeddings.shape: (220, 128)
# test_ent_cosine_sim.shape: (141,)
# test_con_cosine_sim.shape: (220,)
# entailment_acc: 0.9858156028368794
# contradiction_acc: 0.7681818181818182
# test_acc: 0.8769987105093489
# --------------

# %%
# !python ../eval_NLI_v2.py \
--huggingface_model_name "microsoft/BiomedVLP-CXR-BERT-specialized" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230927_234549_MIMIC-CXR(triplets+entcont)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)" \
--device "GPU" \
--batch_size 100 \
--num_workers 3 \
--calibrate_on_test_set
# Out:
# script's arguments:
#    huggingface_model_name: microsoft/BiomedVLP-CXR-BERT-specialized
#    model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230927_234549_MIMIC-CXR(triplets+entcont)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)
#    device: GPU
#    batch_size: 100
#    num_workers: 3
#    integrated_nli_jsonl_filepath: None
#    similarity_metric: cosine
#    average_token_embeddings: False
#    calibrate_on_test_set: True
# checkpoint_names = ['checkpoint_47_encc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9451.pt']
# Test radnli entailment pairs: 102
# Test radnli contradiction pairs: 98
# Example test radnli entailment pairs:
# ('There is no pleural effusion, pneumothorax, or pulmonary vascular congestion.', 'Left pleural effusion has also completely resolved.')
# ('Cardiomediastinal silhouette and hilar contours are normal.', 'Cardiomediastinal silhouette is normal size.')
# ('No acute osseous abnormality seen.', 'No acute osseous abnormalities are visualized.')
# ('There is a tiny right pleural effusion.', 'Trace pleural effusion at the right base.')
# Example test radnli contradiction pairs:
# ('The heart is top normal in size, which is exaggerated by the low lung volumes.', 'The heart is mildly enlarged, unchanged.')
# ('Heart size is normal accounting for the low lung volumes.', 'Lung volumes are normal.')
# ('The heart is mildly enlarged, unchanged.', 'The heart is top normal in size, which is exaggerated by the low lung volumes.')
# ('Moderate cardiomegaly and mediastinal vascular engorgement is stable.', 'Cardiomediastinal and hilar silhouettes are normal.')
# Test mscxrt entailment pairs: 141
# Test mscxrt contradiction pairs: 220
# Example test mscxrt entailment pairs:
# ('left retrocardiac opacity is unchanged.', 'left retrocardiac opacity is stable.')
# ('Stable appearance of moderate pulmonary edema since ___.', 'Stable, moderate pulmonary edema.')
# ('small right pleural effusions stable.', 'small right pleural effusions unchanged.')
# ('linear atelectasis of the left lung base has improved since yesterday.', 'linear atelectasis of the left lung base has decreased since yesterday.')
# Example test mscxrt contradiction pairs:
# ('amount of bilateral pleural effusions is stable', 'amount of bilateral pleural effusions is increased')
# ('the left retrocardiac and basal opacity has improved.', 'the left retrocardiac and basal opacity has increased.')
# ('extensive diffuse consolidations have markedly worsened.', 'extensive diffuse consolidations have markedly improved.')
# ('minimal increase in extent of a pre - existing right pleural effusion.', 'minimal improvement in extent of a pre - existing right pleural effusion.')
# Total sentences: 825
#   0%|                                                   | 0/825 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=367,2428892134441720844).pkl
# len(self.cache["hashes"]) = 134854
# self.cache["embeddings"].shape = (134854, 128)
# 100%|███████████████████████████████████████| 825/825 [00:00<00:00, 3908.45it/s]
# embeddings.shape: (825, 128)
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (102, 128)
# train_h_ent_embeddings.shape: (102, 128)
# train_p_con_embeddings.shape: (98, 128)
# train_h_con_embeddings.shape: (98, 128)
# train_ent_cosine_sim.shape: (102,)
# train_con_cosine_sim.shape: (98,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 44306.81it/s]
# best_threshold: 0.7542987570270998
# best_acc: 0.9252701080432173
# best_ent_acc: 0.9117647058823529
# best_con_acc: 0.9387755102040817
# --------------
# Evaluating on RadNLI test set
# test_p_ent_embeddings.shape: (102, 128)
# test_h_ent_embeddings.shape: (102, 128)
# test_p_con_embeddings.shape: (98, 128)
# test_h_con_embeddings.shape: (98, 128)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 0.9117647058823529
# contradiction_acc: 0.9387755102040817
# test_acc: 0.9252701080432173
# --------------
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (141, 128)
# train_h_ent_embeddings.shape: (141, 128)
# train_p_con_embeddings.shape: (220, 128)
# train_h_con_embeddings.shape: (220, 128)
# train_ent_cosine_sim.shape: (141,)
# train_con_cosine_sim.shape: (220,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 43074.61it/s]
# best_threshold: 0.9286137572279922
# best_acc: 0.9367182462927144
# best_ent_acc: 0.900709219858156
# best_con_acc: 0.9727272727272728
# --------------
# Evaluating on MS-CXR-T Temporal Sentence Similarity v1
# test_p_ent_embeddings.shape: (141, 128)
# test_h_ent_embeddings.shape: (141, 128)
# test_p_con_embeddings.shape: (220, 128)
# test_h_con_embeddings.shape: (220, 128)
# test_ent_cosine_sim.shape: (141,)
# test_con_cosine_sim.shape: (220,)
# entailment_acc: 0.900709219858156
# contradiction_acc: 0.9727272727272728
# test_acc: 0.9367182462927144
# --------------

# %%
# !python ../eval_NLI_v2.py \
--huggingface_model_name "microsoft/BiomedVLP-CXR-BERT-specialized" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20231003_001641_MIMIC-CXR(triplets+entcont)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)" \
--device "GPU" \
--batch_size 100 \
--num_workers 3 \
--integrated_nli_jsonl_filepath \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(162036,21465751).jsonl"
# Out:
# script's arguments:
#    huggingface_model_name: microsoft/BiomedVLP-CXR-BERT-specialized
#    model_name: None
#    model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20231003_001641_MIMIC-CXR(triplets+entcont)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)
#    device: GPU
#    batch_size: 100
#    num_workers: 3
#    integrated_nli_jsonl_filepath: /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(162036,21465751).jsonl
#    similarity_metric: cosine
#    average_token_embeddings: False
#    calibrate_on_test_set: False
# checkpoint_names = ['checkpoint_1_encc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9444.pt']
# Train entailment pairs: 26442
# Train contradiction pairs: 95777
# Example train entailment pairs:
# ('Moderate cardiomegaly with areas of atelectasis at both lung bases.', 'Moderate cardiomegaly with atelectasis at both lung bases.')
# ('Again seen are extensive bilateral pulmonary infiltrates unchanged since the previous study.', 'Again seen are multi focal, bilateral infiltrates which appear similar compared to prior.')
# ('Persistent largely unchanged left upper lobe, right upper lobe and left lower lobe peribronchial consolidation.', "The patient's left upper, right upper, and left lower lobe peribronchial consolidation remains largely unchanged.")
# ('74 F c hx poorly controlled hypertension, hyperlipidemia, renal cell cancer s/p L nephrectomy, breast cancer s/p L mastectomy/ tamoxifen presenting c chest pain.', ' The patient has multiple medical conditions')
# Example train contradiction pairs:
# ('Diffuse bronchiectasis consistent with chronic changes of cystic fibrosis.', "The patient's lungs show no signs of chronic disease.")
# ("The patient's hematocrit dropped from 29.7 to 22.8.", ' The patient has a high hemoglobin count. ')
# ('- d/w (IV RN by phone at 8: pm .', 'The IV RN was not contacted at all.')
# ("The patient's left lung is completely healthy with no signs of effusion or atelectasis.", 'Minimal left pleural effusion and small left retrocardiac atelectasis.')
# Test radnli entailment pairs: 102
# Test radnli contradiction pairs: 98
# Example test radnli entailment pairs:
# ('The heart is not enlarged.', 'The cardiac silhouette is top normal.')
# ('The mediastinal and hilar contours are normal.', 'Hilar and mediastinal silhouettes are unremarkable.')
# ('There are low lung volumes, though allowing for this, the lungs are clear bilaterally with no focal consolidation, effusion, or pneumothorax.', 'No pleural effusion or pneumothorax is seen.')
# ('Heart size and cardiomediastinal contours are normal.', 'Heart size is normal.')
# Example test radnli contradiction pairs:
# ('No pleural effusion or pneumothorax is present.', 'The left apical pneumothorax is likely unchanged.')
# ('No pleural effusion or pneumothorax is seen.', 'A small residual right effusion is present.')
# ('Cardiac silhouette is normal in size.', 'Lung volumes are low, and the cardiac silhouette is enlarged.')
# ('Moderate right pleural effusion is likely.', 'There is no pleural effusion or pneumothorax.')
# Test mscxrt entailment pairs: 141
# Test mscxrt contradiction pairs: 220
# Example test mscxrt entailment pairs:
# ('bibasal atelectasis is unchanged.', 'bibasal atelectasis is stable.')
# ('Slight interval decrease of bilateral pleural effusions.', 'Slight interval improvement in bilateral pleural effusions.')
# ('more severe consolidation in the left lower lobe has worsened as well.', 'more severe consolidation in the left lower lobe has increased as well.')
# ('interval worsening of now moderate - severe diffuse pulmonary edema.', 'interval progression of now moderate - severe diffuse pulmonary edema.')
# Example test mscxrt contradiction pairs:
# ('there has been development of a vague opacity within the right upper lobe.', 'there has been resolution of a vague opacity within the right upper lobe.')
# ('opacities in the left base have minimally improved.', 'opacities in the left base have minimally worsened.')
# ('increased left basilar opacity.', 'improved left basilar opacity.')
# ('there has been improvement in the pulmonary vascular congestion', 'there has been increase in the pulmonary vascular congestion')
# Total sentences: 102464
# 100%|███████████████████████████████| 102464/102464 [00:00<00:00, 454458.63it/s]
# Computing embeddings for 102464 new texts
# Explicitly passing a `revision` is encouraged when loading a configuration with custom code to ensure no malicious code has been contributed in a newer revision.
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# checkpoint_names = ['checkpoint_1_encc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9444.pt']
# Loading model weights from /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20231003_001641_MIMIC-CXR(triplets+entcont)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/checkpoint_1_encc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9444.pt
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# 100%|███████████████████████████████████████| 1025/1025 [02:48<00:00,  6.09it/s]
# Saving updated cache to /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=366,4246634492375333681).pkl
# 100%|███████████████████████████████| 102464/102464 [00:00<00:00, 580958.44it/s]
# embeddings.shape: (102464, 128)
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (26442, 128)
# train_h_ent_embeddings.shape: (26442, 128)
# train_p_con_embeddings.shape: (95777, 128)
# train_h_con_embeddings.shape: (95777, 128)
# train_ent_cosine_sim.shape: (26442,)
# train_con_cosine_sim.shape: (95777,)
# 100%|█████████████████████████████████████| 1000/1000 [00:00<00:00, 9475.87it/s]
# best_threshold: 0.36261273743034717
# best_acc: 0.9229716412331153
# best_ent_acc: 0.951365252250208
# best_con_acc: 0.8945780302160227
# --------------
# Evaluating on RadNLI test set
# test_p_ent_embeddings.shape: (102, 128)
# test_h_ent_embeddings.shape: (102, 128)
# test_p_con_embeddings.shape: (98, 128)
# test_h_con_embeddings.shape: (98, 128)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 0.9803921568627451
# contradiction_acc: 0.8163265306122449
# test_acc: 0.898359343737495
# --------------
# --------------
# Evaluating on MS-CXR-T Temporal Sentence Similarity v1
# test_p_ent_embeddings.shape: (141, 128)
# test_h_ent_embeddings.shape: (141, 128)
# test_p_con_embeddings.shape: (220, 128)
# test_h_con_embeddings.shape: (220, 128)
# test_ent_cosine_sim.shape: (141,)
# test_con_cosine_sim.shape: (220,)
# entailment_acc: 0.9716312056737588
# contradiction_acc: 0.7545454545454545
# test_acc: 0.8630883301096066
# --------------

# %%
# !python ../eval_NLI_v2.py \
--huggingface_model_name "microsoft/BiomedVLP-CXR-BERT-specialized" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20231003_001641_MIMIC-CXR(triplets+entcont)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)" \
--device "GPU" \
--batch_size 100 \
--num_workers 3 \
--calibrate_on_test_set
# Out:
# script's arguments:
#    huggingface_model_name: microsoft/BiomedVLP-CXR-BERT-specialized
#    model_name: None
#    model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20231003_001641_MIMIC-CXR(triplets+entcont)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)
#    device: GPU
#    batch_size: 100
#    num_workers: 3
#    integrated_nli_jsonl_filepath: None
#    similarity_metric: cosine
#    average_token_embeddings: False
#    calibrate_on_test_set: True
# checkpoint_names = ['checkpoint_1_encc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9444.pt']
# Test radnli entailment pairs: 102
# Test radnli contradiction pairs: 98
# Example test radnli entailment pairs:
# ('No acute osseous abnormality seen.', 'No acute osseous abnormalities are visualized.')
# ('Atherosclerotic calcifications are noted at the aortic arch.', 'Mild aortic calcification noted.')
# ('The osseous structures are grossly unremarkable, although evaluation is limited secondary to body habitus.', 'Osseous structures are without an acute abnormality.')
# ('The mediastinal silhouette, hilar contours, and pleural surfaces are normal.', 'The hilar and mediastinal silhouettes are unremarkable.')
# Example test radnli contradiction pairs:
# ('Lung volumes are normal.', 'Heart size is normal accounting for the low lung volumes.')
# ('A small left pleural effusion may be present.', 'There is no pleural effusion or pneumothorax.')
# ('No pleural effusion or pneumothorax is present.', 'There is subtle blunting of the left CP angle suggesting a tiny effusion or pleural thickening.')
# ('There is no pneumothorax or pleural effusion.', 'Small right pleural effusion has decreased.')
# Test mscxrt entailment pairs: 141
# Test mscxrt contradiction pairs: 220
# Example test mscxrt entailment pairs:
# ('unchanged moderate to large layering right pleural effusion.', 'stable moderate to large layering right pleural effusion.')
# ('Stable small left pneumothorax.', 'Stable small pneumothorax on the left.')
# ('Signs indicative of pulmonary edema have minimally decreased.', 'There is persistent pulmonary edema which has improved minimally.')
# ('Stable extent of the pre-existing left pleural effusion.', 'Stable extent of a previously existing left pleural effusion.')
# Example test mscxrt contradiction pairs:
# ('possible slight worsening of hazy opacity at right base.', 'possible slight improvement of hazy opacity at right base.')
# ('minimal increase in the right - sided loculated hydro pneumothorax.', 'minimal decrease in the right - sided loculated hydro pneumothorax.')
# ('moderate right pleural effusion stable.', 'moderate right pleural effusion increased.')
# ('the hazy opacification at the bases has decreased.', 'the hazy opacification at the bases has increased.')
# Total sentences: 825
#   0%|                                                   | 0/825 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=366,4246634492375333681).pkl
# len(self.cache["hashes"]) = 102464
# self.cache["embeddings"].shape = (102464, 128)
# 100%|███████████████████████████████████████| 825/825 [00:00<00:00, 3453.82it/s]
# embeddings.shape: (825, 128)
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (102, 128)
# train_h_ent_embeddings.shape: (102, 128)
# train_p_con_embeddings.shape: (98, 128)
# train_h_con_embeddings.shape: (98, 128)
# train_ent_cosine_sim.shape: (102,)
# train_con_cosine_sim.shape: (98,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 38431.90it/s]
# best_threshold: 0.4735328536611181
# best_acc: 0.9493797519007603
# best_ent_acc: 0.9803921568627451
# best_con_acc: 0.9183673469387755
# --------------
# Evaluating on RadNLI test set
# test_p_ent_embeddings.shape: (102, 128)
# test_h_ent_embeddings.shape: (102, 128)
# test_p_con_embeddings.shape: (98, 128)
# test_h_con_embeddings.shape: (98, 128)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 0.9803921568627451
# contradiction_acc: 0.9183673469387755
# test_acc: 0.9493797519007603
# --------------
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (141, 128)
# train_h_ent_embeddings.shape: (141, 128)
# train_p_con_embeddings.shape: (220, 128)
# train_h_con_embeddings.shape: (220, 128)
# train_ent_cosine_sim.shape: (141,)
# train_con_cosine_sim.shape: (220,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 38514.83it/s]
# best_threshold: 0.8242696534405958
# best_acc: 0.9291747259832366
# best_ent_acc: 0.9219858156028369
# best_con_acc: 0.9363636363636364
# --------------
# Evaluating on MS-CXR-T Temporal Sentence Similarity v1
# test_p_ent_embeddings.shape: (141, 128)
# test_h_ent_embeddings.shape: (141, 128)
# test_p_con_embeddings.shape: (220, 128)
# test_h_con_embeddings.shape: (220, 128)
# test_ent_cosine_sim.shape: (141,)
# test_con_cosine_sim.shape: (220,)
# entailment_acc: 0.9219858156028369
# contradiction_acc: 0.9363636363636364
# test_acc: 0.9291747259832366
# --------------

# %%
# !python ../eval_NLI_v2.py \
--huggingface_model_name "microsoft/BiomedVLP-CXR-BERT-specialized" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240129_080646_MIMIC-CXR(triplets+entcon)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)" \
--device "GPU" \
--batch_size 100 \
--num_workers 3 \
--integrated_nli_jsonl_filepath \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(169025,21838032).jsonl"
# Out:
# script's arguments:
#    huggingface_model_name: microsoft/BiomedVLP-CXR-BERT-specialized
#    model_name: None
#    model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240129_080646_MIMIC-CXR(triplets+entcon)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)
#    device: GPU
#    batch_size: 100
#    num_workers: 3
#    integrated_nli_jsonl_filepath: /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(169025,21838032).jsonl
#    similarity_metric: cosine
#    average_token_embeddings: False
#    calibrate_on_test_set: False
# checkpoint_names = ['checkpoint_98_encc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9440.pt']
# Train entailment pairs: 25175
# Train contradiction pairs: 99121
# Example train entailment pairs:
# ('There is again some obliquity of the patient to the left, which makes it difficult to assess the position of central mediastinal structures.', "The patient's leftward obliquity is causing challenges in assessing the position of central mediastinal structures.")
# ('Right PICC terminates near the low SVC.', 'The right PICC line ends close to the lower part of the Superior Vena Cava.')
# ('No concerning focal consolidation, pleural effusion, pneumothorax, or pulmonary edema is seen.', 'No pleural effusions noted.')
# ('Again there are bilateral pleural effusions with overlying atelectasis.', 'Small to moderate layering bilateral pleural effusions with overlying atelectasis.')
# Example train contradiction pairs:
# ('There is no focal airspace opacity suggestive of pneumonia.', 'Patchy ill-defined opacity within the right lung base is concerning for an infectious process.')
# ('There is mild right scoliosis.', 'There is mild right kyphosis.')
# ('No evidence of pneumothorax is present.', 'There is a large right-sided pneumothorax with mediastinal shift to the left.')
# ('There is a left effusion.', 'The left lung is clear without any effusion.')
# Test radnli entailment pairs: 102
# Test radnli contradiction pairs: 98
# Example test radnli entailment pairs:
# ('No focal consolidation, pleural effusion or pneumothorax is identified.', 'No focal infiltrate is identified.')
# ('The cardiomediastinal and hilar contours are within normal limits.', 'Heart and mediastinal contours appear normal.')
# ('No large pleural effusion or pneumothorax is seen.', 'There is no pneumothorax.')
# ('There is no pleural effusion, pneumothorax, or pulmonary vascular congestion.', 'There is no pneumothorax.')
# Example test radnli contradiction pairs:
# ('The right atelectasis and pleural effusion has increased.', 'There is no focal consolidation, pleural effusion or pneumothorax.')
# ('There is no pleural effusion or pneumothorax.', 'Moderate right pleural effusion is likely.')
# ('Small bilateral pleural effusions are noted.', 'No right-sided pleural effusion is seen.')
# ('There is no focal consolidation, pleural effusion or pneumothorax.', 'Small left pleural effusion is difficult to exclude.')
# Test mscxrt entailment pairs: 141
# Test mscxrt contradiction pairs: 220
# Example test mscxrt entailment pairs:
# ('Decrease in extent of the bilateral pleural effusions that, however, remain clearly visible.', 'Decrease in bilateral pleural effusions.')
# ('small right and moderate left pleural effusions have minimally increased since ___.', 'small right and moderate left pleural effusions have minimally worsened since ___.')
# ('mild edema in the left lung has worsened, probably a function of reexpansion and general mild edema.', 'mild edema in the left lung has increased, probably a function of reexpansion and general mild edema.')
# ('on the left, the pre - existing opacities are stable in extent and severity.', 'on the left, the pre - existing opacities are unchanged in extent and severity.')
# Example test mscxrt contradiction pairs:
# ('Bibasal consolidations have increased in the interim.', 'Bibasal consolidations are unchanged.')
# ('multifocal consolidations in the right lung are grossly unchanged.', 'multifocal consolidations in the right lung are grossly worsened.')
# ('there is stable mild perihilar and interstitial edema.', 'there is new mild perihilar and interstitial edema.')
# ('Small bilateral apical pneumothoraces have decreased since ___.', 'Small bilateral apical pneumothoraces new since ___.')
# Total sentences: 98658
#   0%|                                                 | 0/98658 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=366,313298442480815119).pkl
# len(self.cache["hashes"]) = 3166
# self.cache["embeddings"].shape = (3166, 128)
# 100%|█████████████████████████████████| 98658/98658 [00:00<00:00, 522272.40it/s]
# Computing embeddings for 97521 new texts
# Explicitly passing a `revision` is encouraged when loading a configuration with custom code to ensure no malicious code has been contributed in a newer revision.
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# checkpoint_names = ['checkpoint_98_encc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9440.pt']
# Loading model weights from /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240129_080646_MIMIC-CXR(triplets+entcon)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/checkpoint_98_encc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9440.pt
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# 100%|█████████████████████████████████████████| 976/976 [02:20<00:00,  6.93it/s]
# Saving updated cache to /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=366,313298442480815119).pkl
# 100%|█████████████████████████████████| 97521/97521 [00:00<00:00, 574355.09it/s]
# embeddings.shape: (98658, 128)
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (25175, 128)
# train_h_ent_embeddings.shape: (25175, 128)
# train_p_con_embeddings.shape: (99121, 128)
# train_h_con_embeddings.shape: (99121, 128)
# train_ent_cosine_sim.shape: (25175,)
# train_con_cosine_sim.shape: (99121,)
# 100%|█████████████████████████████████████| 1000/1000 [00:00<00:00, 6629.48it/s]
# best_threshold: 0.3077401789101035
# best_acc: 0.9534687023063813
# best_ent_acc: 0.9698907646474677
# best_con_acc: 0.9370466399652949
# --------------
# Evaluating on RadNLI test set
# test_p_ent_embeddings.shape: (102, 128)
# test_h_ent_embeddings.shape: (102, 128)
# test_p_con_embeddings.shape: (98, 128)
# test_h_con_embeddings.shape: (98, 128)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 0.9803921568627451
# contradiction_acc: 0.9387755102040817
# test_acc: 0.9595838335334134
# --------------
# --------------
# Evaluating on MS-CXR-T Temporal Sentence Similarity v1
# test_p_ent_embeddings.shape: (141, 128)
# test_h_ent_embeddings.shape: (141, 128)
# test_p_con_embeddings.shape: (220, 128)
# test_h_con_embeddings.shape: (220, 128)
# test_ent_cosine_sim.shape: (141,)
# test_con_cosine_sim.shape: (220,)
# entailment_acc: 0.9645390070921985
# contradiction_acc: 0.6954545454545454
# test_acc: 0.829996776273372
# --------------

# %%
# !python ../eval_NLI_v2.py \
--huggingface_model_name "microsoft/BiomedVLP-CXR-BERT-specialized" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240129_080646_MIMIC-CXR(triplets+entcon)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)" \
--device "GPU" \
--batch_size 100 \
--num_workers 3 \
--calibrate_on_test_set
# Out:
# script's arguments:
#    huggingface_model_name: microsoft/BiomedVLP-CXR-BERT-specialized
#    model_name: None
#    model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240129_080646_MIMIC-CXR(triplets+entcon)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)
#    device: GPU
#    batch_size: 100
#    num_workers: 3
#    integrated_nli_jsonl_filepath: None
#    similarity_metric: cosine
#    average_token_embeddings: False
#    calibrate_on_test_set: True
# checkpoint_names = ['checkpoint_98_encc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9440.pt']
# Test radnli entailment pairs: 102
# Test radnli contradiction pairs: 98
# Example test radnli entailment pairs:
# ('The pulmonary vasculature is normal.', 'The pulmonary vascularity is normal.')
# ('The lungs are clear and well expanded.', 'The lungs are well expanded.')
# ('Heart and mediastinal contours appear normal.', 'The cardiomediastinal and hilar contours are within normal limits.')
# ('There is no focal consolidation, effusion, or pneumothorax.', 'There is no pneumothorax.')
# Example test radnli contradiction pairs:
# ('There is no pleural effusion or pneumothorax in the left.', 'There is scattered atelectasis and there are tiny bilateral pleural effusions.')
# ('Cardiomediastinal and hilar contours are unremarkable with the exception of a tortuous aorta.', 'PA and lateral chest radiographs demonstrate a normal cardiomediastinal silhouette.')
# ('Moderate right pleural effusion is likely.', 'There is no pleural effusion or pneumothorax.')
# ('PA and lateral chest radiographs demonstrate a normal cardiomediastinal silhouette.', 'Cardiomediastinal and hilar contours are unremarkable with the exception of a tortuous aorta.')
# Test mscxrt entailment pairs: 141
# Test mscxrt contradiction pairs: 220
# Example test mscxrt entailment pairs:
# ('unchanged tiny left pleural effusion.', 'stable tiny left pleural effusion.')
# ('right basal opacities have minimally improved.', 'right basal opacities have minimally decreased.')
# ('mild interstitial edema has worsened.', 'mild interstitial edema has increased.')
# ('Small right pneumothorax is minimally bigger than on ___ chest radiograph.', 'Small right pneumothorax has minimally increased.')
# Example test mscxrt contradiction pairs:
# ('moderate right pleural effusion is larger.', 'moderate right pleural effusion is unchanged.')
# ('There is some hazy opacity at the right base which is unchanged.', 'In comparison with the study of ___, there is increasing hazy opacification at the right base.')
# ('slight decrease in small right pleural effusion.', 'slight improvement in small right pleural effusion.')
# ('There is improvement of the pulmonary interstitial edema.', 'Interstitial pulmonary edema, increased since the prior study.')
# Total sentences: 825
#   0%|                                                   | 0/825 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=366,313298442480815119).pkl
# len(self.cache["hashes"]) = 2412
# self.cache["embeddings"].shape = (2412, 128)
# 100%|█████████████████████████████████████| 825/825 [00:00<00:00, 143082.24it/s]
# Computing embeddings for 754 new texts
# Explicitly passing a `revision` is encouraged when loading a configuration with custom code to ensure no malicious code has been contributed in a newer revision.
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# checkpoint_names = ['checkpoint_98_encc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9440.pt']
# Loading model weights from /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240129_080646_MIMIC-CXR(triplets+entcon)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/checkpoint_98_encc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9440.pt
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# 100%|█████████████████████████████████████████████| 8/8 [00:02<00:00,  3.24it/s]
# Saving updated cache to /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=366,313298442480815119).pkl
# 100%|█████████████████████████████████████| 754/754 [00:00<00:00, 628229.09it/s]
# embeddings.shape: (825, 128)
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (102, 128)
# train_h_ent_embeddings.shape: (102, 128)
# train_p_con_embeddings.shape: (98, 128)
# train_h_con_embeddings.shape: (98, 128)
# train_ent_cosine_sim.shape: (102,)
# train_con_cosine_sim.shape: (98,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 33045.53it/s]
# best_threshold: 0.42999745453442184
# best_acc: 0.9648859543817527
# best_ent_acc: 0.9705882352941176
# best_con_acc: 0.9591836734693877
# --------------
# Evaluating on RadNLI test set
# test_p_ent_embeddings.shape: (102, 128)
# test_h_ent_embeddings.shape: (102, 128)
# test_p_con_embeddings.shape: (98, 128)
# test_h_con_embeddings.shape: (98, 128)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 0.9705882352941176
# contradiction_acc: 0.9591836734693877
# test_acc: 0.9648859543817527
# --------------
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (141, 128)
# train_h_ent_embeddings.shape: (141, 128)
# train_p_con_embeddings.shape: (220, 128)
# train_h_con_embeddings.shape: (220, 128)
# train_ent_cosine_sim.shape: (141,)
# train_con_cosine_sim.shape: (220,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 32870.98it/s]
# best_threshold: 0.8272264973895327
# best_acc: 0.9334461637653126
# best_ent_acc: 0.9078014184397163
# best_con_acc: 0.9590909090909091
# --------------
# Evaluating on MS-CXR-T Temporal Sentence Similarity v1
# test_p_ent_embeddings.shape: (141, 128)
# test_h_ent_embeddings.shape: (141, 128)
# test_p_con_embeddings.shape: (220, 128)
# test_h_con_embeddings.shape: (220, 128)
# test_ent_cosine_sim.shape: (141,)
# test_con_cosine_sim.shape: (220,)
# entailment_acc: 0.9078014184397163
# contradiction_acc: 0.9590909090909091
# test_acc: 0.9334461637653126
# --------------

# %% [markdown]
# # CXR Fact Embedding (T -> T+NLI)

# %%
# !python ../eval_NLI_v2.py \
--huggingface_model_name "microsoft/BiomedVLP-CXR-BERT-specialized" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240129_125012_MIMIC-CXR(triplets+nli)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)" \
--device "GPU" \
--batch_size 100 \
--num_workers 3 \
--integrated_nli_jsonl_filepath \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(169025,21838032).jsonl"
# Out:
# script's arguments:
#    huggingface_model_name: microsoft/BiomedVLP-CXR-BERT-specialized
#    model_name: None
#    model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240129_125012_MIMIC-CXR(triplets+nli)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)
#    device: GPU
#    batch_size: 100
#    num_workers: 3
#    integrated_nli_jsonl_filepath: /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(169025,21838032).jsonl
#    similarity_metric: cosine
#    average_token_embeddings: False
#    calibrate_on_test_set: False
# checkpoint_names = ['checkpoint_116_nlcc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9199.pt']
# Train entailment pairs: 25175
# Train contradiction pairs: 99121
# Example train entailment pairs:
# ('ICP draining serosanguinous drainage.', ' There is blood mixed with fluids in the drain')
# ('The lungs are clear with no signs of pneumonia, pleural effusion, or pneumothorax.', 'There is no pneumonia present.')
# ('represent rib bony island versus lung nodule, possibly old calcified granuloma.', 'The chest X-ray shows a possible old calcified granuloma.')
# ('MATERNAL PRENATAL LABS:  Blood type A positive, antibody negative, RPR nonreactive, rubella immune, hepatitis B surface antigen negative, GBS unknown.', ' Patient has blood type A+')
# Example train contradiction pairs:
# ('There is again seen a nipple shadow on the right side.', 'There is no shadow of any kind seen on the right side.')
# ('The pneumothorax seen at CT on can not be appreciated.', 'No pleural effusions or pneumothoraces appreciated.')
# ('There is pulmonary vascular congestion but no overt pulmonary edema.', "The patient's lungs are filled with fluid, indicating pulmonary edema.")
# ('The right upper lobe infiltrate is old, not new.', 'New right upper lobe infiltrate.')
# Test radnli entailment pairs: 102
# Test radnli contradiction pairs: 98
# Example test radnli entailment pairs:
# ('Cardiomediastinal and hilar contours are within normal limits.', 'The cardiomediastinal silhouette is within normal limits.')
# ('The mediastinal silhouette, hilar contours, and pleural surfaces are normal.', 'The hilar and mediastinal silhouettes are unremarkable.')
# ('The cardiomediastinal silhouette and pulmonary vasculature are normal.', 'Pulmonary vascularity is normal.')
# ('The lungs are clear and well expanded.', 'The lungs are well expanded.')
# Example test radnli contradiction pairs:
# ('Lung volumes are low, and the cardiac silhouette is enlarged.', 'Cardiac silhouette is normal in size.')
# ('No right-sided pleural effusion is seen.', 'Small bilateral pleural effusions are noted.')
# ('Small left pleural effusion is difficult to exclude.', 'There is no focal consolidation, pleural effusion or pneumothorax.')
# ('No pleural effusion or pneumothorax is seen.', 'Mild pulmonary vascular congestion is present and probable trace bilateral pleural effusions.')
# Test mscxrt entailment pairs: 141
# Test mscxrt contradiction pairs: 220
# Example test mscxrt entailment pairs:
# ('pulmonary edema has improved.', 'pulmonary edema has decreased.')
# ('left basal opacity is unchanged.', 'left basal opacity is stable.')
# ('retrocardiac atelectasis is unchanged.', 'retrocardiac atelectasis is stable.')
# ('status post right thoracentesis with interval decrease in right pleural effusion, which is now trace in size.', 'status post right thoracentesis with interval improvement in right pleural effusion, which is now trace in size.')
# Example test mscxrt contradiction pairs:
# ('As compared to the previous image, the right upper lobe pneumonia is unchanged.', 'Likely developing right upper lobe pneumonia.')
# ('small left effusion has minimally increased.', 'small left effusion has minimally decreased.')
# ('Slightly improved right-sided pneumothorax.', 'Compared to the prior study the right-sided pneumothorax is slightly larger.')
# ('Widespread consolidations have progressed in the interim.', 'Widespread consolidations are unchanged.')
# Total sentences: 98658
#   0%|                                                 | 0/98658 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=364,459173252947772357).pkl
# len(self.cache["hashes"]) = 2412
# self.cache["embeddings"].shape = (2412, 128)
# 100%|█████████████████████████████████| 98658/98658 [00:00<00:00, 354745.10it/s]
# Computing embeddings for 98275 new texts
# Explicitly passing a `revision` is encouraged when loading a configuration with custom code to ensure no malicious code has been contributed in a newer revision.
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# checkpoint_names = ['checkpoint_116_nlcc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9199.pt']
# Loading model weights from /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240129_125012_MIMIC-CXR(triplets+nli)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/checkpoint_116_nlcc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9199.pt
# Warning: model state dict has 211 keys, loaded state dict has 215 keys, intersection has 211 keys, union has 215 keys.
# Examples of keys in loaded state dict but not in model:
#   nli_classifier.bias
#   nli_hidden_layer.weight
#   nli_classifier.weight
#   nli_hidden_layer.bias
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# 100%|█████████████████████████████████████████| 983/983 [02:25<00:00,  6.78it/s]
# Saving updated cache to /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=364,459173252947772357).pkl
# 100%|█████████████████████████████████| 98275/98275 [00:00<00:00, 374416.59it/s]
# embeddings.shape: (98658, 128)
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (25175, 128)
# train_h_ent_embeddings.shape: (25175, 128)
# train_p_con_embeddings.shape: (99121, 128)
# train_h_con_embeddings.shape: (99121, 128)
# train_ent_cosine_sim.shape: (25175,)
# train_con_cosine_sim.shape: (99121,)
# 100%|█████████████████████████████████████| 1000/1000 [00:00<00:00, 5199.37it/s]
# best_threshold: 0.23314446777672138
# best_acc: 0.8397906704200027
# best_ent_acc: 0.8931082423038729
# best_con_acc: 0.7864730985361326
# --------------
# Evaluating on RadNLI test set
# test_p_ent_embeddings.shape: (102, 128)
# test_h_ent_embeddings.shape: (102, 128)
# test_p_con_embeddings.shape: (98, 128)
# test_h_con_embeddings.shape: (98, 128)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 0.9901960784313726
# contradiction_acc: 0.9387755102040817
# test_acc: 0.9644857943177272
# --------------
# --------------
# Evaluating on MS-CXR-T Temporal Sentence Similarity v1
# test_p_ent_embeddings.shape: (141, 128)
# test_h_ent_embeddings.shape: (141, 128)
# test_p_con_embeddings.shape: (220, 128)
# test_h_con_embeddings.shape: (220, 128)
# test_ent_cosine_sim.shape: (141,)
# test_con_cosine_sim.shape: (220,)
# entailment_acc: 1.0
# contradiction_acc: 0.759090909090909
# test_acc: 0.8795454545454545
# --------------

# %%
# !python ../eval_NLI_v2.py \
--huggingface_model_name "microsoft/BiomedVLP-CXR-BERT-specialized" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240129_125012_MIMIC-CXR(triplets+nli)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)" \
--device "GPU" \
--batch_size 100 \
--num_workers 3 \
--calibrate_on_test_set
# Out:
# script's arguments:
#    huggingface_model_name: microsoft/BiomedVLP-CXR-BERT-specialized
#    model_name: None
#    model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240129_125012_MIMIC-CXR(triplets+nli)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)
#    device: GPU
#    batch_size: 100
#    num_workers: 3
#    integrated_nli_jsonl_filepath: None
#    similarity_metric: cosine
#    average_token_embeddings: False
#    calibrate_on_test_set: True
# checkpoint_names = ['checkpoint_116_nlcc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9199.pt']
# Test radnli entailment pairs: 102
# Test radnli contradiction pairs: 98
# Example test radnli entailment pairs:
# ('There is no pneumothorax or pleural effusion.', 'No pneumothorax is identified.')
# ('There are no acute osseous abnormalities.', 'No acute bony abnormalities are seen.')
# ('The pulmonary vascularity is normal.', 'The pulmonary vasculature is normal.')
# ('Lung volumes are low, and the cardiac silhouette is enlarged.', 'Lung volume is small.')
# Example test radnli contradiction pairs:
# ('Trace pleural effusion at the right base.', 'There is no pleural effusion or pneumothorax.')
# ('Small right pleural effusion has decreased.', 'There is no pneumothorax or pleural effusion.')
# ('There is no focal consolidation, pleural effusion or pneumothorax.', 'Small left pleural effusion is difficult to exclude.')
# ('No right-sided pleural effusion is seen.', 'Small bilateral pleural effusions are noted.')
# Test mscxrt entailment pairs: 141
# Test mscxrt contradiction pairs: 220
# Example test mscxrt entailment pairs:
# ('No significant interval change in small right apical pneumothorax.', 'In comparison to study obtained seven hours prior, there is no significant interval change in small right apical pneumothorax.')
# ('there is atelectasis at the lung bases, unchanged.', 'there is atelectasis at the lung bases, stable.')
# ('tiny right apical pneumothorax, slightly decreased.', 'tiny right apical pneumothorax, slightly smaller.')
# ('opacities in the left base have minimally improved.', 'opacities in the left base have minimally decreased.')
# Example test mscxrt contradiction pairs:
# ('bibasilar atelectasis have improved.', 'bibasilar atelectasis have resolved.')
# ('AP chest compared to ___ through ___: Previous bibasilar opacification improved substantially from ___ through ___, and has subsequently worsened.', 'Bibasilar opacities have not substantially changed.')
# ('Previous mild pulmonary edema has substantially improved.', 'Mild pulmonary edema has not substantially changed since the previous examination.')
# ('Left basal consolidation has slightly improved.', 'Left basal consolidation has slightly increased.')
# Total sentences: 825
#   0%|                                                   | 0/825 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=364,459173252947772357).pkl
# len(self.cache["hashes"]) = 100687
# self.cache["embeddings"].shape = (100687, 128)
# 100%|███████████████████████████████████████| 825/825 [00:00<00:00, 2349.59it/s]
# embeddings.shape: (825, 128)
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (102, 128)
# train_h_ent_embeddings.shape: (102, 128)
# train_p_con_embeddings.shape: (98, 128)
# train_h_con_embeddings.shape: (98, 128)
# train_ent_cosine_sim.shape: (102,)
# train_con_cosine_sim.shape: (98,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 25641.79it/s]
# best_threshold: 0.2715945803486668
# best_acc: 0.9697879151660664
# best_ent_acc: 0.9803921568627451
# best_con_acc: 0.9591836734693877
# --------------
# Evaluating on RadNLI test set
# test_p_ent_embeddings.shape: (102, 128)
# test_h_ent_embeddings.shape: (102, 128)
# test_p_con_embeddings.shape: (98, 128)
# test_h_con_embeddings.shape: (98, 128)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 0.9803921568627451
# contradiction_acc: 0.9591836734693877
# test_acc: 0.9697879151660664
# --------------
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (141, 128)
# train_h_ent_embeddings.shape: (141, 128)
# train_p_con_embeddings.shape: (220, 128)
# train_h_con_embeddings.shape: (220, 128)
# train_ent_cosine_sim.shape: (141,)
# train_con_cosine_sim.shape: (220,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 25419.25it/s]
# best_threshold: 0.796235703729891
# best_acc: 0.9565441650548033
# best_ent_acc: 0.9858156028368794
# best_con_acc: 0.9272727272727272
# --------------
# Evaluating on MS-CXR-T Temporal Sentence Similarity v1
# test_p_ent_embeddings.shape: (141, 128)
# test_h_ent_embeddings.shape: (141, 128)
# test_p_con_embeddings.shape: (220, 128)
# test_h_con_embeddings.shape: (220, 128)
# test_ent_cosine_sim.shape: (141,)
# test_con_cosine_sim.shape: (220,)
# entailment_acc: 0.9858156028368794
# contradiction_acc: 0.9272727272727272
# test_acc: 0.9565441650548033
# --------------

# %% [markdown]
# # CXR Fact Embedding (T -> T+C)

# %%
# !python ../eval_NLI_v2.py \
--huggingface_model_name "microsoft/BiomedVLP-CXR-BERT-specialized" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230928_013825_MIMIC-CXR(triplets+classif)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)" \
--device "GPU" \
--batch_size 100 \
--num_workers 3 \
--integrated_nli_jsonl_filepath \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(162036,21465751).jsonl"
# Out:
# script's arguments:
#    huggingface_model_name: microsoft/BiomedVLP-CXR-BERT-specialized
#    model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230928_013825_MIMIC-CXR(triplets+classif)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)
#    device: GPU
#    batch_size: 100
#    num_workers: 3
#    integrated_nli_jsonl_filepath: /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(162036,21465751).jsonl
#    similarity_metric: cosine
#    average_token_embeddings: False
#    calibrate_on_test_set: False
# checkpoint_names = ['checkpoint_64_cacc+chf1+chf1+cscc+hscc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9474.pt']
# Train entailment pairs: 26442
# Train contradiction pairs: 95777
# Example train entailment pairs:
# ('Mild pulmonary vascular congestion versus apical scarring.', "The patient's chest X-ray shows signs of either mild pulmonary vascular congestion or apical scarring.")
# ('There is a right basilar opacity which silhouettes the right hemidiaphragm.', 'There is increasing opacification at the right base.')
# ('Chronic opacities suggesting minor scarring without definite evidence for acute disease.', 'The patient has signs of chronic scarring in their lungs.')
# ('Compared to chest radiographs through at : .', 'The patient has undergone chest radiographs.')
# Example train contradiction pairs:
# ('The central line tip is unchanged.', 'The central line tip has changed slightly.')
# ('No changes are noted.', 'Significant changes are observed.')
# ('There is minimal atelectasis at the lung bases.', 'There is extensive atelectasis at the lung bases.')
# ("The patient's chest X-ray shows a clear pneumothorax.", 'No definite pneumothorax is seen on the current examination.')
# Test radnli entailment pairs: 102
# Test radnli contradiction pairs: 98
# Example test radnli entailment pairs:
# ('No pleural effusion or pneumothorax is seen although the left costophrenic angle is excluded from the field of view.', 'No pleural effusions.')
# ('The lungs are hyperinflated but clear without consolidation, effusion, or pneumothorax.', 'No large effusion or pneumothorax is seen.')
# ('There is no pleural effusion or pneumothorax.', 'There are no pleural effusions.')
# ('Cardiomediastinal and hilar contours are normal.', 'Cardiomediastinal silhouette and hilar contours are unremarkable.')
# Example test radnli contradiction pairs:
# ('A small right pleural effusion cannot be excluded.', 'There is no pleural effusion, pneumothorax, or pulmonary edema.')
# ('No pleural effusion or pneumothorax is seen.', 'A small residual right effusion is present.')
# ('Small right pleural effusion, similar.', 'There is no pleural effusion or pneumothorax.')
# ('Moderate right pleural effusion is likely.', 'There is no pleural effusion or pneumothorax.')
# Test mscxrt entailment pairs: 141
# Test mscxrt contradiction pairs: 220
# Example test mscxrt entailment pairs:
# ('Persistent right upper lobe opacification has only mildly improved since ___.', 'Mildly improved right upper lobe opacity compared to ___.')
# ('interval worsening of now moderate - severe diffuse pulmonary edema.', 'interval progression of now moderate - severe diffuse pulmonary edema.')
# ('unchanged tiny left pleural effusion.', 'stable tiny left pleural effusion.')
# ('large right pleural effusion stable since ___.', 'large right pleural effusion unchanged since ___.')
# Example test mscxrt contradiction pairs:
# ('Mild to moderate vascular congestion has increased.', 'Mild to moderate vascular congestion is probably unchanged.')
# ('small medial left pneumothorax and pneumomediastinum are unchanged.', 'small medial left pneumothorax and pneumomediastinum are new.')
# ('small right apical pneumothorax is stable.', 'small right apical pneumothorax is new.')
# ('the widespread bilateral diffuse parenchymal opacities are unchanged.', 'the widespread bilateral diffuse parenchymal opacities are improved.')
# Total sentences: 102464
#   0%|                                                | 0/102464 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=387,2492157991032224976).pkl
# len(self.cache["hashes"]) = 32416
# self.cache["embeddings"].shape = (32416, 128)
# 100%|███████████████████████████████| 102464/102464 [00:00<00:00, 527563.26it/s]
# Computing embeddings for 102438 new texts
# Explicitly passing a `revision` is encouraged when loading a configuration with custom code to ensure no malicious code has been contributed in a newer revision.
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# checkpoint_names = ['checkpoint_64_cacc+chf1+chf1+cscc+hscc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9474.pt']
# Loading model weights from /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230928_013825_MIMIC-CXR(triplets+classif)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/checkpoint_64_cacc+chf1+chf1+cscc+hscc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9474.pt
# Warning: model state dict has 211 keys, loaded state dict has 223 keys, intersection has 211 keys, union has 223 keys.
# Examples of keys in loaded state dict but not in model:
#   category_classifier.weight
#   aux_task_hidden_layer.bias
#   comparison_status_classifier.bias
#   chest_imagenome_anatloc_classifier.weight
#   health_status_classifier.weight
#   chest_imagenome_obs_classifier.bias
#   aux_task_hidden_layer.weight
#   category_classifier.bias
#   chest_imagenome_obs_classifier.weight
#   chest_imagenome_anatloc_classifier.bias
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# 100%|███████████████████████████████████████| 1025/1025 [01:50<00:00,  9.25it/s]
# Saving updated cache to /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=387,2492157991032224976).pkl
# 100%|███████████████████████████████| 102438/102438 [00:00<00:00, 670027.98it/s]
# embeddings.shape: (102464, 128)
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (26442, 128)
# train_h_ent_embeddings.shape: (26442, 128)
# train_p_con_embeddings.shape: (95777, 128)
# train_h_con_embeddings.shape: (95777, 128)
# train_ent_cosine_sim.shape: (26442,)
# train_con_cosine_sim.shape: (95777,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 11294.47it/s]
# best_threshold: 0.9494494607856683
# best_acc: 0.5943619381556104
# best_ent_acc: 0.45306709023523184
# best_con_acc: 0.735656786075989
# --------------
# Evaluating on RadNLI test set
# test_p_ent_embeddings.shape: (102, 128)
# test_h_ent_embeddings.shape: (102, 128)
# test_p_con_embeddings.shape: (98, 128)
# test_h_con_embeddings.shape: (98, 128)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 0.39215686274509803
# contradiction_acc: 0.9591836734693877
# test_acc: 0.6756702681072428
# --------------
# --------------
# Evaluating on MS-CXR-T Temporal Sentence Similarity v1
# test_p_ent_embeddings.shape: (141, 128)
# test_h_ent_embeddings.shape: (141, 128)
# test_p_con_embeddings.shape: (220, 128)
# test_h_con_embeddings.shape: (220, 128)
# test_ent_cosine_sim.shape: (141,)
# test_con_cosine_sim.shape: (220,)
# entailment_acc: 0.9787234042553191
# contradiction_acc: 0.11363636363636363
# test_acc: 0.5461798839458414
# --------------

# %%
# !python ../eval_NLI_v2.py \
--huggingface_model_name "microsoft/BiomedVLP-CXR-BERT-specialized" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230928_013825_MIMIC-CXR(triplets+classif)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)" \
--device "GPU" \
--batch_size 100 \
--num_workers 3 \
--calibrate_on_test_set
# Out:
# script's arguments:
#    huggingface_model_name: microsoft/BiomedVLP-CXR-BERT-specialized
#    model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230928_013825_MIMIC-CXR(triplets+classif)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)
#    device: GPU
#    batch_size: 100
#    num_workers: 3
#    integrated_nli_jsonl_filepath: None
#    similarity_metric: cosine
#    average_token_embeddings: False
#    calibrate_on_test_set: True
# checkpoint_names = ['checkpoint_64_cacc+chf1+chf1+cscc+hscc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9474.pt']
# Test radnli entailment pairs: 102
# Test radnli contradiction pairs: 98
# Example test radnli entailment pairs:
# ('No focal consolidation, pleural effusion, pulmonary edema, or pneumothorax.', 'No pneumothorax is evident.')
# ('The right lung and pleural space and visible mediastinal contours and structures are normal.', 'Cardiomediastinal contours are normal.')
# ('There is a tiny right pleural effusion.', 'Trace pleural effusion at the right base.')
# ('The lungs are well expanded and clear.', 'The lungs are clear.')
# Example test radnli contradiction pairs:
# ('Moderate size right pleural effusion is new from the previous radiograph with associated right basilar atelectasis.', 'No pleural abnormality is seen.')
# ('There is scattered atelectasis and there are tiny bilateral pleural effusions.', 'There is no pleural effusion or pneumothorax in the left.')
# ('The heart appears mildly enlarged.', 'The heart and mediastinal contours are normal.')
# ('There is evidence of a right pleural effusion.', 'There is no pleural effusion or pneumothorax.')
# Test mscxrt entailment pairs: 141
# Test mscxrt contradiction pairs: 220
# Example test mscxrt entailment pairs:
# ('unchanged mild bilateral pulmonary edema.', 'stable mild bilateral pulmonary edema.')
# ('interval worsening of the right - sided pneumothorax.', 'interval increase of the right - sided pneumothorax.')
# ('nearly resolved bilateral pleural effusions.', 'nearly cleared bilateral pleural effusions.')
# ('bibasilar retrocardiac atelectasis is unchanged.', 'bibasilar retrocardiac atelectasis is stable.')
# Example test mscxrt contradiction pairs:
# ('minimal increase in extent of a pre - existing right pleural effusion.', 'minimal decrease in extent of a pre - existing right pleural effusion.')
# ('Significant interval decrease in size of right pleural effusion.', 'No significant interval change in size right pleural effusion.')
# ('As compared to the previous radiograph, the extent of the pre-existing right pneumothorax has substantially increased.', 'The known right pneumothorax is not substantially changed.')
# ('moderate left lower lobe atelectasis has worsened.', 'moderate left lower lobe atelectasis has improved.')
# Total sentences: 825
#   0%|                                                   | 0/825 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=387,2492157991032224976).pkl
# len(self.cache["hashes"]) = 134854
# self.cache["embeddings"].shape = (134854, 128)
# 100%|███████████████████████████████████████| 825/825 [00:00<00:00, 3948.74it/s]
# embeddings.shape: (825, 128)
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (102, 128)
# train_h_ent_embeddings.shape: (102, 128)
# train_p_con_embeddings.shape: (98, 128)
# train_h_con_embeddings.shape: (98, 128)
# train_ent_cosine_sim.shape: (102,)
# train_con_cosine_sim.shape: (98,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 44019.44it/s]
# best_threshold: 0.595275108878677
# best_acc: 0.7734093637454982
# best_ent_acc: 0.8529411764705882
# best_con_acc: 0.6938775510204082
# --------------
# Evaluating on RadNLI test set
# test_p_ent_embeddings.shape: (102, 128)
# test_h_ent_embeddings.shape: (102, 128)
# test_p_con_embeddings.shape: (98, 128)
# test_h_con_embeddings.shape: (98, 128)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 0.8529411764705882
# contradiction_acc: 0.6938775510204082
# test_acc: 0.7734093637454982
# --------------
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (141, 128)
# train_h_ent_embeddings.shape: (141, 128)
# train_p_con_embeddings.shape: (220, 128)
# train_h_con_embeddings.shape: (220, 128)
# train_ent_cosine_sim.shape: (141,)
# train_con_cosine_sim.shape: (220,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 44208.74it/s]
# best_threshold: 0.9991406272123525
# best_acc: 0.6470664087685365
# best_ent_acc: 0.7304964539007093
# best_con_acc: 0.5636363636363636
# --------------
# Evaluating on MS-CXR-T Temporal Sentence Similarity v1
# test_p_ent_embeddings.shape: (141, 128)
# test_h_ent_embeddings.shape: (141, 128)
# test_p_con_embeddings.shape: (220, 128)
# test_h_con_embeddings.shape: (220, 128)
# test_ent_cosine_sim.shape: (141,)
# test_con_cosine_sim.shape: (220,)
# entailment_acc: 0.7304964539007093
# contradiction_acc: 0.5636363636363636
# test_acc: 0.6470664087685365
# --------------

# %%
# !python ../eval_NLI_v2.py \
--huggingface_model_name "microsoft/BiomedVLP-CXR-BERT-specialized" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20231004_155915_MIMIC-CXR(triplets+classif)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)" \
--device "GPU" \
--batch_size 80 \
--num_workers 3 \
--integrated_nli_jsonl_filepath \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(162036,21465751).jsonl"
# Out:
# script's arguments:
#    huggingface_model_name: microsoft/BiomedVLP-CXR-BERT-specialized
#    model_name: None
#    model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20231004_155915_MIMIC-CXR(triplets+classif)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)
#    device: GPU
#    batch_size: 80
#    num_workers: 3
#    integrated_nli_jsonl_filepath: /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(162036,21465751).jsonl
#    similarity_metric: cosine
#    average_token_embeddings: False
#    calibrate_on_test_set: False
# checkpoint_names = ['checkpoint_29_cacc+chf1+chf1+cscc+hscc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9495.pt']
# Train entailment pairs: 26442
# Train contradiction pairs: 95777
# Example train entailment pairs:
# ('No acute cardiopulmonary abnormality.', 'There is no acute abnormality in the heart and lungs.')
# ('The patient was intubated within 2 to 3 minutes of life with excellent response and normal heart rate, good respiratory effort, pink and good activity.', ' The patient responded well after intubation')
# ('The findings were discussed with Dr. the phone by radiology resident Dr. at 9:15 p.m. at the time of discovery.', 'The radiology resident Dr. communicated the findings to Dr. over the phone.')
# ('History of tuberculosis.', ' The patient has had an infection problem. ')
# Example train contradiction pairs:
# ('The prior chest radiograph shows higher lung volumes.', 'Lower lung volumes compared to the prior chest radiograph.')
# ('The heart is top- normal size.', 'The heart size has increased mildly.')
# ('There is a moderate-to-large right pleural effusion with dense right lung base consolidation.', 'There is a small left and possibly right pleural effusion without pneumothorax.')
# ('The above findings were discussed with Dr. at 1:15 p.m. on .', 'Findings were discussed with Dr. on at 5:06 p.m. by phone.')
# Test radnli entailment pairs: 102
# Test radnli contradiction pairs: 98
# Example test radnli entailment pairs:
# ('The lungs are clear without focal consolidation, pleural effusion or pneumothorax.', 'No pleural effusions.')
# ('The lungs are clear without focal consolidation.', 'Lungs are clear.')
# ('Cardiac silhouette is top-normal.', 'The heart appears top-normal in size.')
# ('No acute bony abnormalities are seen.', 'There are no acute osseous abnormalities.')
# Example test radnli contradiction pairs:
# ('Since the prior radiograph, no significant change in the widespread parenchymal opacities and moderate cardiomegaly.', 'Allowing for these limitation, there are no focal parenchymal opacities.')
# ('The lungs are well expanded and clear.', 'The lungs are otherwise clear.')
# ('There is no focal consolidation, pleural effusion or pneumothorax.', 'Small left pleural effusion is difficult to exclude.')
# ('Moderate to large bilateral pleural effusions are again seen, likely right greater than left.', 'There is no pulmonary edema or pleural effusions.')
# Test mscxrt entailment pairs: 141
# Test mscxrt contradiction pairs: 220
# Example test mscxrt entailment pairs:
# ('There has also been a slight increase in left basal consolidation.', 'There is slight interval progression of left basal consolidation.')
# ('Stable small left pneumothorax.', 'Stable small pneumothorax on the left.')
# ('pulmonary edema has improved.', 'pulmonary edema has decreased.')
# ('slight interval improvement in moderate widespread pulmonary edema.', 'slight interval decrease in moderate widespread pulmonary edema.')
# Example test mscxrt contradiction pairs:
# ('moderate right pleural effusion stable.', 'moderate right pleural effusion increased.')
# ('Mild decrease in severity of pulmonary edema.', 'Mild increase in severity of the pre-existing pulmonary edema.')
# ('and apparent decrease in size in bilateral pleural effusions.', 'and apparent increase in size in bilateral pleural effusions.')
# ('opacities in the left base have minimally improved.', 'opacities in the left base have minimally worsened.')
# Total sentences: 102464
#   0%|                                                | 0/102464 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=387,1308360022390228203).pkl
# len(self.cache["hashes"]) = 42978
# self.cache["embeddings"].shape = (42978, 128)
# 100%|███████████████████████████████| 102464/102464 [00:00<00:00, 491061.42it/s]
# Computing embeddings for 101307 new texts
# Explicitly passing a `revision` is encouraged when loading a configuration with custom code to ensure no malicious code has been contributed in a newer revision.
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# checkpoint_names = ['checkpoint_29_cacc+chf1+chf1+cscc+hscc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9495.pt']
# Loading model weights from /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20231004_155915_MIMIC-CXR(triplets+classif)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/checkpoint_29_cacc+chf1+chf1+cscc+hscc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9495.pt
# Warning: model state dict has 211 keys, loaded state dict has 223 keys, intersection has 211 keys, union has 223 keys.
# Examples of keys in loaded state dict but not in model:
#   category_classifier.bias
#   chest_imagenome_obs_classifier.weight
#   aux_task_hidden_layer.weight
#   aux_task_hidden_layer.bias
#   chest_imagenome_obs_classifier.bias
#   comparison_status_classifier.weight
#   chest_imagenome_anatloc_classifier.bias
#   category_classifier.weight
#   health_status_classifier.bias
#   chest_imagenome_anatloc_classifier.weight
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# 100%|███████████████████████████████████████| 1267/1267 [01:56<00:00, 10.90it/s]
# Saving updated cache to /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=387,1308360022390228203).pkl
# 100%|███████████████████████████████| 101307/101307 [00:00<00:00, 686882.45it/s]
# embeddings.shape: (102464, 128)
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (26442, 128)
# train_h_ent_embeddings.shape: (26442, 128)
# train_p_con_embeddings.shape: (95777, 128)
# train_h_con_embeddings.shape: (95777, 128)
# train_ent_cosine_sim.shape: (26442,)
# train_con_cosine_sim.shape: (95777,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 11648.22it/s]
# best_threshold: 0.9415425257281855
# best_acc: 0.5911544203491685
# best_ent_acc: 0.4602148097723319
# best_con_acc: 0.7220940309260052
# --------------
# Evaluating on RadNLI test set
# test_p_ent_embeddings.shape: (102, 128)
# test_h_ent_embeddings.shape: (102, 128)
# test_p_con_embeddings.shape: (98, 128)
# test_h_con_embeddings.shape: (98, 128)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 0.4117647058823529
# contradiction_acc: 0.9591836734693877
# test_acc: 0.6854741896758703
# --------------
# --------------
# Evaluating on MS-CXR-T Temporal Sentence Similarity v1
# test_p_ent_embeddings.shape: (141, 128)
# test_h_ent_embeddings.shape: (141, 128)
# test_p_con_embeddings.shape: (220, 128)
# test_h_con_embeddings.shape: (220, 128)
# test_ent_cosine_sim.shape: (141,)
# test_con_cosine_sim.shape: (220,)
# entailment_acc: 0.9787234042553191
# contradiction_acc: 0.12727272727272726
# test_acc: 0.5529980657640232
# --------------

# %%
# !python ../eval_NLI_v2.py \
--huggingface_model_name "microsoft/BiomedVLP-CXR-BERT-specialized" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20231004_155915_MIMIC-CXR(triplets+classif)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)" \
--device "GPU" \
--batch_size 80 \
--num_workers 3 \
--integrated_nli_jsonl_filepath \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(169025,21838032).jsonl"
# Out:
# script's arguments:
#    huggingface_model_name: microsoft/BiomedVLP-CXR-BERT-specialized
#    model_name: None
#    model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20231004_155915_MIMIC-CXR(triplets+classif)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)
#    device: GPU
#    batch_size: 80
#    num_workers: 3
#    integrated_nli_jsonl_filepath: /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(169025,21838032).jsonl
#    similarity_metric: cosine
#    average_token_embeddings: False
#    calibrate_on_test_set: False
# checkpoint_names = ['checkpoint_29_cacc+chf1+chf1+cscc+hscc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9495.pt']
# Train entailment pairs: 25175
# Train contradiction pairs: 99121
# Example train entailment pairs:
# ('There is no focal consolidation or pleural effusion or pneumothorax.', 'No focal consolidation, pleural effusion or pneumothorax is evident.')
# ('Unchanged heterogeneous bibasilar right greater than left opacities likely represent atelectasis; however, could represent infection or aspiration in the appropriate clinical setting.', "The patient's chest X-ray shows bibasilar opacities that could be a sign of atelectasis.")
# ('Linear subsegmental atelectasis is noted in both lower lobes.', "The patient's chest X-ray shows signs of atelectasis in the lower lobes of both lungs.")
# ('However mild interstitial edema is new.', "There is a recent development of mild interstitial edema in the patient's chest X-ray.")
# Example train contradiction pairs:
# ('New, more prominent opacities in the left lingula and lower lung, which may be secondary to pulmonary edema.', 'The left lingula and lower lung are completely clear with no opacities.')
# ('Normal chest, without intraperitoneal free air.', "The patient's chest X-ray reveals the presence of intraperitoneal free air.")
# ('There is blunting of the left costophrenic angle, which could not be due to a small effusion.', 'There is blunting of the left costophrenic angle, which could be due to a small effusion.')
# ('Patient rotation does not affect the evaluation of the left base.', 'The evaluation of the left base is difficult due to patient rotation.')
# Test radnli entailment pairs: 102
# Test radnli contradiction pairs: 98
# Example test radnli entailment pairs:
# ('There is no pleural effusion, pneumothorax, or pulmonary vascular congestion.', 'There is no pneumothorax.')
# ('There are low lung volumes, though allowing for this, the lungs are clear bilaterally with no focal consolidation, effusion, or pneumothorax.', 'No pleural effusion or pneumothorax is seen.')
# ('The lungs are clear without focal consolidation.', 'There is no focal consolidation.')
# ('Hilar and mediastinal silhouettes are unremarkable.', 'The mediastinal and hilar contours are normal.')
# Example test radnli contradiction pairs:
# ('The left apical pneumothorax is likely unchanged.', 'No pleural effusion or pneumothorax is present.')
# ('Small right pleural effusion, similar.', 'There is no pleural effusion or pneumothorax.')
# ('Allowing for these limitation, there are no focal parenchymal opacities.', 'Since the prior radiograph, no significant change in the widespread parenchymal opacities and moderate cardiomegaly.')
# ('Since the prior radiograph, no significant change in the widespread parenchymal opacities and moderate cardiomegaly.', 'Allowing for these limitation, there are no focal parenchymal opacities.')
# Test mscxrt entailment pairs: 141
# Test mscxrt contradiction pairs: 220
# Example test mscxrt entailment pairs:
# ('There is a persistent right perihilar opacity which is stable.', 'Right perihilar opacity appears to be similar to previous examination.')
# ('a right perihilar opacity is unchanged.', 'a right perihilar opacity is stable.')
# ('there is atelectasis at the lung bases, unchanged.', 'there is atelectasis at the lung bases, stable.')
# ('severely atelectatic left lower lobe is unchanged.', 'severely atelectatic left lower lobe is stable.')
# Example test mscxrt contradiction pairs:
# ('unchanged small - to - moderate right pleural effusion.', 'new small - to - moderate right pleural effusion.')
# ('the severity of the pre - existing pulmonary edema has decreased.', 'the severity of the pre - existing pulmonary edema has increased.')
# ('there are multifocal opacities bilaterally, unchanged.', 'there are multifocal opacities bilaterally, worsened.')
# ('Mild decrease in severity of pulmonary edema.', 'Mild increase in severity of the pre-existing pulmonary edema.')
# Total sentences: 98658
#   0%|                                                 | 0/98658 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=387,1308360022390228203).pkl
# len(self.cache["hashes"]) = 162832
# self.cache["embeddings"].shape = (162832, 128)
# 100%|█████████████████████████████████| 98658/98658 [00:00<00:00, 188893.94it/s]
# embeddings.shape: (98658, 128)
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (25175, 128)
# train_h_ent_embeddings.shape: (25175, 128)
# train_p_con_embeddings.shape: (99121, 128)
# train_h_con_embeddings.shape: (99121, 128)
# train_ent_cosine_sim.shape: (25175,)
# train_con_cosine_sim.shape: (99121,)
# 100%|█████████████████████████████████████| 1000/1000 [00:00<00:00, 7082.47it/s]
# best_threshold: 0.9344568716155157
# best_acc: 0.5664381730705854
# best_ent_acc: 0.43392254220456805
# best_con_acc: 0.6989538039366028
# --------------
# Evaluating on RadNLI test set
# test_p_ent_embeddings.shape: (102, 128)
# test_h_ent_embeddings.shape: (102, 128)
# test_p_con_embeddings.shape: (98, 128)
# test_h_con_embeddings.shape: (98, 128)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 0.4411764705882353
# contradiction_acc: 0.9591836734693877
# test_acc: 0.7001800720288115
# --------------
# --------------
# Evaluating on MS-CXR-T Temporal Sentence Similarity v1
# test_p_ent_embeddings.shape: (141, 128)
# test_h_ent_embeddings.shape: (141, 128)
# test_p_con_embeddings.shape: (220, 128)
# test_h_con_embeddings.shape: (220, 128)
# test_ent_cosine_sim.shape: (141,)
# test_con_cosine_sim.shape: (220,)
# entailment_acc: 0.9787234042553191
# contradiction_acc: 0.12272727272727273
# test_acc: 0.5507253384912959
# --------------

# %%
# !python ../eval_NLI_v2.py \
--huggingface_model_name "microsoft/BiomedVLP-CXR-BERT-specialized" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20231004_155915_MIMIC-CXR(triplets+classif)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)" \
--device "GPU" \
--batch_size 100 \
--num_workers 3 \
--calibrate_on_test_set
# Out:
# script's arguments:
#    huggingface_model_name: microsoft/BiomedVLP-CXR-BERT-specialized
#    model_name: None
#    model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20231004_155915_MIMIC-CXR(triplets+classif)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)
#    device: GPU
#    batch_size: 100
#    num_workers: 3
#    integrated_nli_jsonl_filepath: None
#    similarity_metric: cosine
#    average_token_embeddings: False
#    calibrate_on_test_set: True
# checkpoint_names = ['checkpoint_29_cacc+chf1+chf1+cscc+hscc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9495.pt']
# Test radnli entailment pairs: 102
# Test radnli contradiction pairs: 98
# Example test radnli entailment pairs:
# ('The mediastinal silhouette, hilar contours, and pleural surfaces are normal.', 'The hilar and mediastinal silhouettes are unremarkable.')
# ('There is no pleural effusion, pneumothorax, or pulmonary vascular congestion.', 'Left pleural effusion has also completely resolved.')
# ('No pleural effusion or pneumothorax is seen although the left costophrenic angle is excluded from the field of view.', 'No pleural effusions.')
# ('The pulmonary vasculature demonstrates an upper zone redistribution pattern, but there is no sign of an advanced interstitial or alveolar edema.', 'There is mild vascular congestion, but no overt pulmonary edema.')
# Example test radnli contradiction pairs:
# ('No pleural effusion or pneumothorax is seen.', 'Dense retrocardiac opacification persists, consistent with left lower lobe consolidation and small pleural effusion.')
# ('There is no pulmonary edema or pleural effusions.', 'Moderate to large bilateral pleural effusions are again seen, likely right greater than left.')
# ('No pleural effusion or pneumothorax is clearly noted on this supine exam, though the left costophrenic angle is not completely included in the field of view.', 'The costophrenic angles are not fully included on the image and pleural effusions are difficult to exclude.')
# ('No pleural effusion or pneumothorax is seen.', 'There are small bilateral pleural effusions.')
# Test mscxrt entailment pairs: 141
# Test mscxrt contradiction pairs: 220
# Example test mscxrt entailment pairs:
# ('Previous mild interstitial edema has improved and lung volumes have increased.', 'Lung volumes have improved, and mild interstitial edema has decreased.')
# ('right basal opacities have minimally improved.', 'right basal opacities have minimally decreased.')
# ('interval worsening of the right - sided pneumothorax.', 'interval increase of the right - sided pneumothorax.')
# ('stable moderate - sized loculated left pleural effusion.', 'unchanged moderate - sized loculated left pleural effusion.')
# Example test mscxrt contradiction pairs:
# ('the extent of the pre - existing pleural effusion has substantially decreased.', 'the extent of the pre - existing pleural effusion has substantially increased.')
# ('right lower lobe consolidation has only slightly improved.', 'right lower lobe consolidation has only slightly worsened.')
# ('A right middle lobe atelectasis continues to be present, in virtually unchanged manner.', 'Right middle lobe collapse has resolved.')
# ('right basal opacities have minimally improved.', 'right basal opacities have minimally increased.')
# Total sentences: 825
#   0%|                                                   | 0/825 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=387,1308360022390228203).pkl
# len(self.cache["hashes"]) = 42198
# self.cache["embeddings"].shape = (42198, 128)
# 100%|███████████████████████████████████████| 825/825 [00:00<00:00, 5024.72it/s]
# Computing embeddings for 780 new texts
# Explicitly passing a `revision` is encouraged when loading a configuration with custom code to ensure no malicious code has been contributed in a newer revision.
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# checkpoint_names = ['checkpoint_29_cacc+chf1+chf1+cscc+hscc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9495.pt']
# Loading model weights from /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20231004_155915_MIMIC-CXR(triplets+classif)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/checkpoint_29_cacc+chf1+chf1+cscc+hscc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9495.pt
# Warning: model state dict has 211 keys, loaded state dict has 223 keys, intersection has 211 keys, union has 223 keys.
# Examples of keys in loaded state dict but not in model:
#   chest_imagenome_obs_classifier.bias
#   health_status_classifier.weight
#   category_classifier.bias
#   aux_task_hidden_layer.bias
#   category_classifier.weight
#   comparison_status_classifier.bias
#   aux_task_hidden_layer.weight
#   comparison_status_classifier.weight
#   chest_imagenome_anatloc_classifier.weight
#   chest_imagenome_obs_classifier.weight
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# 100%|█████████████████████████████████████████████| 8/8 [00:01<00:00,  4.68it/s]
# Saving updated cache to /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=387,1308360022390228203).pkl
# 100%|█████████████████████████████████████| 780/780 [00:00<00:00, 488729.78it/s]
# embeddings.shape: (825, 128)
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (102, 128)
# train_h_ent_embeddings.shape: (102, 128)
# train_p_con_embeddings.shape: (98, 128)
# train_h_con_embeddings.shape: (98, 128)
# train_ent_cosine_sim.shape: (102,)
# train_con_cosine_sim.shape: (98,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 38780.85it/s]
# best_threshold: 0.7867447524457365
# best_acc: 0.7541016406562625
# best_ent_acc: 0.5490196078431373
# best_con_acc: 0.9591836734693877
# --------------
# Evaluating on RadNLI test set
# test_p_ent_embeddings.shape: (102, 128)
# test_h_ent_embeddings.shape: (102, 128)
# test_p_con_embeddings.shape: (98, 128)
# test_h_con_embeddings.shape: (98, 128)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 0.5490196078431373
# contradiction_acc: 0.9591836734693877
# test_acc: 0.7541016406562625
# --------------
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (141, 128)
# train_h_ent_embeddings.shape: (141, 128)
# train_p_con_embeddings.shape: (220, 128)
# train_h_con_embeddings.shape: (220, 128)
# train_ent_cosine_sim.shape: (141,)
# train_con_cosine_sim.shape: (220,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 43929.07it/s]
# best_threshold: 0.9992987133778848
# best_acc: 0.6262411347517731
# best_ent_acc: 0.6524822695035462
# best_con_acc: 0.6
# --------------
# Evaluating on MS-CXR-T Temporal Sentence Similarity v1
# test_p_ent_embeddings.shape: (141, 128)
# test_h_ent_embeddings.shape: (141, 128)
# test_p_con_embeddings.shape: (220, 128)
# test_h_con_embeddings.shape: (220, 128)
# test_ent_cosine_sim.shape: (141,)
# test_con_cosine_sim.shape: (220,)
# entailment_acc: 0.6524822695035462
# contradiction_acc: 0.6
# test_acc: 0.6262411347517731
# --------------

# %% [markdown]
# # CXR Fact Embedding (T -> T+EC+NLI)

# %%
# !python ../eval_NLI_v2.py \
--huggingface_model_name "microsoft/BiomedVLP-CXR-BERT-specialized" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230928_045139_MIMIC-CXR(triplets+entcon+nli)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)" \
--device "GPU" \
--batch_size 100 \
--num_workers 3 \
--integrated_nli_jsonl_filepath \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(162036,21465751).jsonl"
# Out:
# script's arguments:
#    huggingface_model_name: microsoft/BiomedVLP-CXR-BERT-specialized
#    model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230928_045139_MIMIC-CXR(triplets+entcon+nli)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)
#    device: GPU
#    batch_size: 100
#    num_workers: 3
#    integrated_nli_jsonl_filepath: /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(162036,21465751).jsonl
#    similarity_metric: cosine
#    average_token_embeddings: False
#    calibrate_on_test_set: False
# checkpoint_names = ['checkpoint_17_encc+nlcc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.8973.pt']
# Train entailment pairs: 26442
# Train contradiction pairs: 95777
# Example train entailment pairs:
# ('Stable findings of chronic interstitial lung disease without definite evidence for superimposed process.', 'Chronic interstitial lung disease without definite evidence of an acute intrathoracic abnormality.')
# ('He states that he may have used 2x100mc fentanyl patches instead of his normal 50mcg and 100mcg as prescribed.', ' Patient has been overmedicated')
# ('The cardiomediastinal silhouette is unchanged, with a postoperative appearance of the mediastinal and mild enlargement of the heart.', 'The patient has had a previous operation affecting the mediastinal.')
# ('140cc mL of pleural fluid was drained.', ' There was fluid in the pleural cavity. ')
# Example train contradiction pairs:
# ('The left lower lobe is clear.', 'There is a left lower lobe opacity.')
# ("This is consistent with the patient's known malignancy.", "This is consistent with the patient's known benign condition.")
# ('There is a pacemaker overlying the left chest with leads in the right atrium and right ventricle, which appears unchanged in comparison to the prior radiograph.', 'There is a pacemaker overlying the right chest with leads in the right atrium and right ventricle.')
# ('P-MIBI [**12-25**]: There is a moderate, fixed defect involving the basilar portion of the lateral wall.', ' There are no abnormal findings ')
# Test radnli entailment pairs: 102
# Test radnli contradiction pairs: 98
# Example test radnli entailment pairs:
# ('Cardiomediastinal and hilar contours are within normal limits.', 'The cardiomediastinal silhouette is within normal limits.')
# ('No pleural effusion or pneumothorax is seen.', 'No pneumothorax is seen.')
# ('Severe cardiomegaly and cardiomediastinal hilar silhouettes are unchanged.', 'Cardiomediastinal silhouette is stable.')
# ('No focal consolidation, pleural effusion or pneumothorax is identified.', 'No focal infiltrate is identified.')
# Example test radnli contradiction pairs:
# ('Known small left pneumothorax is not well seen.', 'No pneumothorax.')
# ('The heart and mediastinal contours are normal.', 'The heart appears mildly enlarged.')
# ('Cardiac silhouette size is normal.', 'The cardiac silhouette remains enlarged.')
# ('No pleural effusions.', 'The small bilateral pleural effusions are unchanged in size.')
# Test mscxrt entailment pairs: 141
# Test mscxrt contradiction pairs: 220
# Example test mscxrt entailment pairs:
# ('small - to - moderate right pleural effusion has decreased.', 'small - to - moderate right pleural effusion has improved.')
# ('Increasing right effusion.', 'Increasing effusion on the right.')
# ('Decrease in extent of the bilateral pleural effusions that, however, remain clearly visible.', 'Decrease in bilateral pleural effusions.')
# ('small left pleural effusion stable since ___.', 'small left pleural effusion unchanged since ___.')
# Example test mscxrt contradiction pairs:
# ('The right basilar atelectasis is also increased.', 'Subsequent right basilar atelectasis is also unchanged.')
# ('very small right apical pneumothorax is unchanged.', 'very small right apical pneumothorax is new.')
# ('tiny right apical pneumothorax, slightly decreased.', 'tiny right apical pneumothorax, slightly increased.')
# ('In comparison with the study of ___, there is decrease in the diffuse bilateral pulmonary opacifications.', 'In comparison with the study of ___, there is worsening of the diffuse bilateral pulmonary opacifications.')
# Total sentences: 102464
#   0%|                                                | 0/102464 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=375,696859487587268917).pkl
# len(self.cache["hashes"]) = 32416
# self.cache["embeddings"].shape = (32416, 128)
# 100%|███████████████████████████████| 102464/102464 [00:00<00:00, 517568.61it/s]
# Computing embeddings for 102438 new texts
# Explicitly passing a `revision` is encouraged when loading a configuration with custom code to ensure no malicious code has been contributed in a newer revision.
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# checkpoint_names = ['checkpoint_17_encc+nlcc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.8973.pt']
# Loading model weights from /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230928_045139_MIMIC-CXR(triplets+entcon+nli)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/checkpoint_17_encc+nlcc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.8973.pt
# Warning: model state dict has 211 keys, loaded state dict has 215 keys, intersection has 211 keys, union has 215 keys.
# Examples of keys in loaded state dict but not in model:
#   nli_hidden_layer.bias
#   nli_classifier.weight
#   nli_hidden_layer.weight
#   nli_classifier.bias
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# 100%|███████████████████████████████████████| 1025/1025 [01:52<00:00,  9.12it/s]
# Saving updated cache to /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=375,696859487587268917).pkl
# 100%|███████████████████████████████| 102438/102438 [00:00<00:00, 685464.68it/s]
# embeddings.shape: (102464, 128)
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (26442, 128)
# train_h_ent_embeddings.shape: (26442, 128)
# train_p_con_embeddings.shape: (95777, 128)
# train_h_con_embeddings.shape: (95777, 128)
# train_ent_cosine_sim.shape: (26442,)
# train_con_cosine_sim.shape: (95777,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 11855.05it/s]
# best_threshold: 0.28856349892325106
# best_acc: 0.9211969294404747
# best_ent_acc: 0.9623704712200287
# best_con_acc: 0.8800233876609207
# --------------
# Evaluating on RadNLI test set
# test_p_ent_embeddings.shape: (102, 128)
# test_h_ent_embeddings.shape: (102, 128)
# test_p_con_embeddings.shape: (98, 128)
# test_h_con_embeddings.shape: (98, 128)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 0.9803921568627451
# contradiction_acc: 0.8163265306122449
# test_acc: 0.898359343737495
# --------------
# --------------
# Evaluating on MS-CXR-T Temporal Sentence Similarity v1
# test_p_ent_embeddings.shape: (141, 128)
# test_h_ent_embeddings.shape: (141, 128)
# test_p_con_embeddings.shape: (220, 128)
# test_h_con_embeddings.shape: (220, 128)
# test_ent_cosine_sim.shape: (141,)
# test_con_cosine_sim.shape: (220,)
# entailment_acc: 0.9929078014184397
# contradiction_acc: 0.6545454545454545
# test_acc: 0.8237266279819471
# --------------

# %%
# !python ../eval_NLI_v2.py \
--huggingface_model_name "microsoft/BiomedVLP-CXR-BERT-specialized" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230928_045139_MIMIC-CXR(triplets+entcon+nli)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)" \
--device "GPU" \
--batch_size 100 \
--num_workers 3 \
--calibrate_on_test_set
# Out:
# script's arguments:
#    huggingface_model_name: microsoft/BiomedVLP-CXR-BERT-specialized
#    model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230928_045139_MIMIC-CXR(triplets+entcon+nli)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)
#    device: GPU
#    batch_size: 100
#    num_workers: 3
#    integrated_nli_jsonl_filepath: None
#    similarity_metric: cosine
#    average_token_embeddings: False
#    calibrate_on_test_set: True
# checkpoint_names = ['checkpoint_17_encc+nlcc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.8973.pt']
# Test radnli entailment pairs: 102
# Test radnli contradiction pairs: 98
# Example test radnli entailment pairs:
# ('No pleural effusion or pneumothorax is seen although the left costophrenic angle is excluded from the field of view.', 'No pleural effusions.')
# ('Cardiomediastinal and hilar contours are within normal limits.', 'The cardiomediastinal silhouette is within normal limits.')
# ('Areas of increased opacification is seen at the bases, suggestive of atelectatic change.', 'Streaky opacities at the left lung base indicate mild atelectasis.')
# ('Cardiomediastinal and hilar contours are normal.', 'Cardiomediastinal silhouette and hilar contours are unremarkable.')
# Example test radnli contradiction pairs:
# ('The lungs however are clear.', 'The lungs are otherwise clear without focal consolidation.')
# ('No pneumothorax.', 'Known small left pneumothorax is not well seen.')
# ('The cardiac silhouette remains enlarged.', 'Cardiac silhouette size is normal.')
# ('No right-sided pleural effusion is seen.', 'Small bilateral pleural effusions are noted.')
# Test mscxrt entailment pairs: 141
# Test mscxrt contradiction pairs: 220
# Example test mscxrt entailment pairs:
# ('mild interstitial edema elsewhere is stable.', 'mild interstitial edema elsewhere is unchanged.')
# ('unchanged, tiny left apical pneumothorax.', 'stable, tiny left apical pneumothorax.')
# ('linear atelectasis of the left lung base has improved since yesterday.', 'linear atelectasis of the left lung base has decreased since yesterday.')
# ('mild edema in the left lung has worsened, probably a function of reexpansion and general mild edema.', 'mild edema in the left lung has increased, probably a function of reexpansion and general mild edema.')
# Example test mscxrt contradiction pairs:
# ('worsening of moderate right pneumothorax.', 'resolution of moderate right pneumothorax.')
# ('small left effusion has minimally increased.', 'small left effusion has minimally decreased.')
# ('there is atelectasis at the lung bases, unchanged.', 'there is atelectasis at the lung bases, new.')
# ('there is a stable small right apical pneumothorax.', 'there is a new small right apical pneumothorax.')
# Total sentences: 825
#   0%|                                                   | 0/825 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=375,696859487587268917).pkl
# len(self.cache["hashes"]) = 134854
# self.cache["embeddings"].shape = (134854, 128)
# 100%|███████████████████████████████████████| 825/825 [00:00<00:00, 4009.35it/s]
# embeddings.shape: (825, 128)
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (102, 128)
# train_h_ent_embeddings.shape: (102, 128)
# train_p_con_embeddings.shape: (98, 128)
# train_h_con_embeddings.shape: (98, 128)
# train_ent_cosine_sim.shape: (102,)
# train_con_cosine_sim.shape: (98,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 44490.57it/s]
# best_threshold: 0.5790026187896729
# best_acc: 0.9101640656262505
# best_ent_acc: 0.9019607843137255
# best_con_acc: 0.9183673469387755
# --------------
# Evaluating on RadNLI test set
# test_p_ent_embeddings.shape: (102, 128)
# test_h_ent_embeddings.shape: (102, 128)
# test_p_con_embeddings.shape: (98, 128)
# test_h_con_embeddings.shape: (98, 128)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 0.9019607843137255
# contradiction_acc: 0.9183673469387755
# test_acc: 0.9101640656262505
# --------------
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (141, 128)
# train_h_ent_embeddings.shape: (141, 128)
# train_p_con_embeddings.shape: (220, 128)
# train_h_con_embeddings.shape: (220, 128)
# train_ent_cosine_sim.shape: (141,)
# train_con_cosine_sim.shape: (220,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 44552.48it/s]
# best_threshold: 0.8751740219356776
# best_acc: 0.9398130238555771
# best_ent_acc: 0.9432624113475178
# best_con_acc: 0.9363636363636364
# --------------
# Evaluating on MS-CXR-T Temporal Sentence Similarity v1
# test_p_ent_embeddings.shape: (141, 128)
# test_h_ent_embeddings.shape: (141, 128)
# test_p_con_embeddings.shape: (220, 128)
# test_h_con_embeddings.shape: (220, 128)
# test_ent_cosine_sim.shape: (141,)
# test_con_cosine_sim.shape: (220,)
# entailment_acc: 0.9432624113475178
# contradiction_acc: 0.9363636363636364
# test_acc: 0.9398130238555771
# --------------

# %%
# !python ../eval_NLI_v2.py \
--huggingface_model_name "microsoft/BiomedVLP-CXR-BERT-specialized" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20231002_220207_MIMIC-CXR(triplets+entcon+nli)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)" \
--device "GPU" \
--batch_size 100 \
--num_workers 3 \
--integrated_nli_jsonl_filepath \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(162036,21465751).jsonl"
# Out:
# script's arguments:
#    huggingface_model_name: microsoft/BiomedVLP-CXR-BERT-specialized
#    model_name: None
#    model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20231002_220207_MIMIC-CXR(triplets+entcon+nli)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)
#    device: GPU
#    batch_size: 100
#    num_workers: 3
#    integrated_nli_jsonl_filepath: /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(162036,21465751).jsonl
#    similarity_metric: cosine
#    average_token_embeddings: False
#    calibrate_on_test_set: False
# checkpoint_names = ['checkpoint_52_encc+nlcc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9002.pt']
# Train entailment pairs: 26442
# Train contradiction pairs: 95777
# Example train entailment pairs:
# ('Pt awoke this morning, and was noted to be febrile to 101.', ' Patient has a fever')
# ('AT [**Hospital1 22**], she was found to have cholelithiasis and it was felt that she may need ERCP for presumed gallstone pancreatitis.', ' the patient has cholelithiasis')
# ('She was restarted on imipenem at [**Hospital3 **] from [**Date range (1) 1615**] presumably for a repeat urine culture with Klebsiella, although that data is not available.', ' the patient had a UTI')
# ('Comparison is made to study from .', 'The current study is being compared to a previous one.')
# Example train contradiction pairs:
# ('was paged for notification, 8:44 a.m., on .', 'via telephone at 6:23 a.m. on .')
# ('Bilateral pleural effusion is large and has changed.', 'Bilateral pleural effusion is small and unchanged.')
# ('There is no severe hyperinflation present.', 'Severe hyperinflation is due to pronounced emphysema.')
# ('ET tube terminates approximately 5.3 cm from the carina in the mid thoracic trachea.', 'The ET tube is located outside the trachea.')
# Test radnli entailment pairs: 102
# Test radnli contradiction pairs: 98
# Example test radnli entailment pairs:
# ('Opacities involving the right middle lobe and left lower lobe are again demonstrated and may represent atelectasis or infection in the appropriate setting.', 'Minimal left basilar opacity suggests minor atelectasis.')
# ('Hilar and mediastinal silhouettes are unremarkable.', 'The mediastinal and hilar contours are normal.')
# ('There is no focal consolidation, effusion, or pneumothorax.', 'There is no pneumothorax.')
# ('The lungs are clear.', 'Allowing for this, the lungs are clear.')
# Example test radnli contradiction pairs:
# ('Cardiomediastinal and hilar silhouettes are normal.', 'Moderate cardiomegaly and mediastinal vascular engorgement is stable.')
# ('Interval placement of right-sided chest tube with apparent resolution of right pleural effusion but development of a small pneumothorax.', 'There is no pleural effusion or pneumothorax.')
# ('No pleural effusions.', 'The small bilateral pleural effusions are unchanged in size.')
# ('There is no pleural effusion or pneumothorax.', 'A small left pleural effusion may be present.')
# Test mscxrt entailment pairs: 141
# Test mscxrt contradiction pairs: 220
# Example test mscxrt entailment pairs:
# ('severe bilateral lower lobe atelectasis is unchanged.', 'severe bilateral lower lobe atelectasis is stable.')
# ('As compared to the previous radiograph, the pre-existing pulmonary edema has clearly decreased in extent and severity but is still visible.', 'As compared to the previous radiograph, the pre-existing pulmonary edema has decreased in extent and severity.')
# ('Small left apical pneumothorax slightly larger today than on ___.', 'Small left apical pneumothorax is slightly bigger.')
# ('interval increase of a pre - existing right basal parenchymal opacity.', 'interval progression of a pre - existing right basal parenchymal opacity.')
# Example test mscxrt contradiction pairs:
# ('As compared to the previous radiograph, the retrocardiac consolidation is progressing.', 'Retrocardiac consolidation is unchanged.')
# ('There is interval improvement of the right lower lobe atelectasis.', 'Interval worsening of right lower lobe atelectasis.')
# ('stable moderate - sized loculated left pleural effusion.', 'new moderate - sized loculated left pleural effusion.')
# ('amount of bilateral pleural effusions is stable', 'amount of bilateral pleural effusions is increased')
# Total sentences: 102464
# 100%|███████████████████████████████| 102464/102464 [00:00<00:00, 430319.85it/s]
# Computing embeddings for 102464 new texts
# Explicitly passing a `revision` is encouraged when loading a configuration with custom code to ensure no malicious code has been contributed in a newer revision.
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# checkpoint_names = ['checkpoint_52_encc+nlcc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9002.pt']
# Loading model weights from /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20231002_220207_MIMIC-CXR(triplets+entcon+nli)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/checkpoint_52_encc+nlcc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9002.pt
# Warning: model state dict has 211 keys, loaded state dict has 215 keys, intersection has 211 keys, union has 215 keys.
# Examples of keys in loaded state dict but not in model:
#   nli_hidden_layer.bias
#   nli_hidden_layer.weight
#   nli_classifier.bias
#   nli_classifier.weight
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# 100%|███████████████████████████████████████| 1025/1025 [02:31<00:00,  6.77it/s]
# Saving updated cache to /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=375,1493189425621868816).pkl
# 100%|███████████████████████████████| 102464/102464 [00:00<00:00, 590789.60it/s]
# embeddings.shape: (102464, 128)
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (26442, 128)
# train_h_ent_embeddings.shape: (26442, 128)
# train_p_con_embeddings.shape: (95777, 128)
# train_h_con_embeddings.shape: (95777, 128)
# train_ent_cosine_sim.shape: (26442,)
# train_con_cosine_sim.shape: (95777,)
# 100%|█████████████████████████████████████| 1000/1000 [00:00<00:00, 9498.70it/s]
# best_threshold: 0.31329633153833303
# best_acc: 0.9298788081635978
# best_ent_acc: 0.9600635352847742
# best_con_acc: 0.8996940810424214
# --------------
# Evaluating on RadNLI test set
# test_p_ent_embeddings.shape: (102, 128)
# test_h_ent_embeddings.shape: (102, 128)
# test_p_con_embeddings.shape: (98, 128)
# test_h_con_embeddings.shape: (98, 128)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 0.9901960784313726
# contradiction_acc: 0.8979591836734694
# test_acc: 0.944077631052421
# --------------
# --------------
# Evaluating on MS-CXR-T Temporal Sentence Similarity v1
# test_p_ent_embeddings.shape: (141, 128)
# test_h_ent_embeddings.shape: (141, 128)
# test_p_con_embeddings.shape: (220, 128)
# test_h_con_embeddings.shape: (220, 128)
# test_ent_cosine_sim.shape: (141,)
# test_con_cosine_sim.shape: (220,)
# entailment_acc: 0.9858156028368794
# contradiction_acc: 0.7136363636363636
# test_acc: 0.8497259832366215
# --------------

# %%
# !python ../eval_NLI_v2.py \
--huggingface_model_name "microsoft/BiomedVLP-CXR-BERT-specialized" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20231002_220207_MIMIC-CXR(triplets+entcon+nli)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)" \
--device "GPU" \
--batch_size 100 \
--num_workers 3 \
--calibrate_on_test_set
# Out:
# script's arguments:
#    huggingface_model_name: microsoft/BiomedVLP-CXR-BERT-specialized
#    model_name: None
#    model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20231002_220207_MIMIC-CXR(triplets+entcon+nli)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)
#    device: GPU
#    batch_size: 100
#    num_workers: 3
#    integrated_nli_jsonl_filepath: None
#    similarity_metric: cosine
#    average_token_embeddings: False
#    calibrate_on_test_set: True
# checkpoint_names = ['checkpoint_52_encc+nlcc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9002.pt']
# Test radnli entailment pairs: 102
# Test radnli contradiction pairs: 98
# Example test radnli entailment pairs:
# ('Hilar and mediastinal silhouettes are unremarkable.', 'The mediastinal and hilar contours are normal.')
# ('There are low lung volumes, though allowing for this, the lungs are clear bilaterally with no focal consolidation, effusion, or pneumothorax.', 'No pleural effusion or pneumothorax is seen.')
# ('The osseous structures are grossly unremarkable, although evaluation is limited secondary to body habitus.', 'Osseous structures are without an acute abnormality.')
# ('The lungs are clear.', 'The lungs are clear without focal consolidation.')
# Example test radnli contradiction pairs:
# ('No pneumothoraces are present.', 'Known small left pneumothorax is not well seen.')
# ('There is no pleural effusion or pneumothorax in the left.', 'There is scattered atelectasis and there are tiny bilateral pleural effusions.')
# ('The lungs are clear bilaterally.', 'The lungs are mostly clear aside from mild lower lung atelectasis.')
# ('Lung volumes are normal.', 'Heart size is normal accounting for the low lung volumes.')
# Test mscxrt entailment pairs: 141
# Test mscxrt contradiction pairs: 220
# Example test mscxrt entailment pairs:
# ('Stable small left pneumothorax.', 'Stable small pneumothorax on the left.')
# ('Since ___, the left lower lobe has been collapsed.', 'Left lower lobe remains collapsed.')
# ('small right pleural effusions stable.', 'small right pleural effusions unchanged.')
# ('Small left apical pneumothorax slightly larger today than on ___.', 'Small left apical pneumothorax is slightly bigger.')
# Example test mscxrt contradiction pairs:
# ('minimal increase in the right - sided loculated hydro pneumothorax.', 'minimal decrease in the right - sided loculated hydro pneumothorax.')
# ('interval worsening of the right - sided pneumothorax.', 'interval resolution of the right - sided pneumothorax.')
# ('There is worsening of the left perihilar opacity.', 'Left perihilar opacity is unchanged.')
# ('Moderate right pneumothorax has enlarged since the ___ study.', 'No change in moderate right pneumothorax.')
# Total sentences: 825
#   0%|                                                   | 0/825 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=375,1493189425621868816).pkl
# len(self.cache["hashes"]) = 102464
# self.cache["embeddings"].shape = (102464, 128)
# 100%|███████████████████████████████████████| 825/825 [00:00<00:00, 3098.65it/s]
# embeddings.shape: (825, 128)
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (102, 128)
# train_h_ent_embeddings.shape: (102, 128)
# train_p_con_embeddings.shape: (98, 128)
# train_h_con_embeddings.shape: (98, 128)
# train_ent_cosine_sim.shape: (102,)
# train_con_cosine_sim.shape: (98,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 37628.55it/s]
# best_threshold: 0.10578770632739065
# best_acc: 0.9489795918367347
# best_ent_acc: 1.0
# best_con_acc: 0.8979591836734694
# --------------
# Evaluating on RadNLI test set
# test_p_ent_embeddings.shape: (102, 128)
# test_h_ent_embeddings.shape: (102, 128)
# test_p_con_embeddings.shape: (98, 128)
# test_h_con_embeddings.shape: (98, 128)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 1.0
# contradiction_acc: 0.8979591836734694
# test_acc: 0.9489795918367347
# --------------
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (141, 128)
# train_h_ent_embeddings.shape: (141, 128)
# train_p_con_embeddings.shape: (220, 128)
# train_h_con_embeddings.shape: (220, 128)
# train_ent_cosine_sim.shape: (141,)
# train_con_cosine_sim.shape: (220,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 37398.39it/s]
# best_threshold: 0.8490338679906484
# best_acc: 0.9440844616376531
# best_ent_acc: 0.9290780141843972
# best_con_acc: 0.9590909090909091
# --------------
# Evaluating on MS-CXR-T Temporal Sentence Similarity v1
# test_p_ent_embeddings.shape: (141, 128)
# test_h_ent_embeddings.shape: (141, 128)
# test_p_con_embeddings.shape: (220, 128)
# test_h_con_embeddings.shape: (220, 128)
# test_ent_cosine_sim.shape: (141,)
# test_con_cosine_sim.shape: (220,)
# entailment_acc: 0.9290780141843972
# contradiction_acc: 0.9590909090909091
# test_acc: 0.9440844616376531
# --------------

# %%
# !python ../eval_NLI_v2.py \
--huggingface_model_name "microsoft/BiomedVLP-CXR-BERT-specialized" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240128_173216_MIMIC-CXR(triplets+entcon+nli)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)" \
--device "GPU" \
--batch_size 100 \
--num_workers 3 \
--integrated_nli_jsonl_filepath \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(169025,21838032).jsonl"
# Out:
# script's arguments:
#    huggingface_model_name: microsoft/BiomedVLP-CXR-BERT-specialized
#    model_name: None
#    model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240128_173216_MIMIC-CXR(triplets+entcon+nli)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)
#    device: GPU
#    batch_size: 100
#    num_workers: 3
#    integrated_nli_jsonl_filepath: /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(169025,21838032).jsonl
#    similarity_metric: cosine
#    average_token_embeddings: False
#    calibrate_on_test_set: False
# checkpoint_names = ['checkpoint_92_encc+nlcc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9209.pt']
# Train entailment pairs: 25175
# Train contradiction pairs: 99121
# Example train entailment pairs:
# ('Left lower lobe consolidation may be present, which was not present at the time of the CT of .', "The patient's condition has changed since the time of the CT scan.")
# ('He was also found to be withdrawing from ETOH (tachycardic, hypertensive, hyperthermic and tremulous).', ' The patient requires benzodiazepines to treat his withdrawal. ')
# ('Increased mild to moderate pulmonary edema.', 'Findings concerning for mild pulmonary edema.')
# ('It is obscured by the lung abnormality.', 'There is a lung abnormality present.')
# Example train contradiction pairs:
# ('The apical region is normal.', 'Mild apical thickening.')
# ('The left lung is completely healthy without any signs of bullous disease.', 'Unchanged appearance of the left lung with extensive bullous disease in the upper and mid lung portions.')
# ('Small right pleural effusion has increased in size and linear focus of atelectasis in the right lung base is unchanged.', 'The right pleural effusion has decreased in size.')
# ('The upper lobe vessels are acutely dilated.', 'The upper lobe vessels are chronically dilated.')
# Test radnli entailment pairs: 102
# Test radnli contradiction pairs: 98
# Example test radnli entailment pairs:
# ('There is no focal consolidation, pleural effusion, pneumothorax, or pulmonary edema.', 'There is no pleural effusion, focal consolidation or pneumothorax.')
# ('No pleural effusion or pneumothorax is seen.', 'There is no pleural effusion')
# ('Heart and mediastinal contours appear normal.', 'The cardiomediastinal and hilar contours are within normal limits.')
# ('The lungs are clear without focal consolidation.', 'There is no focal consolidation.')
# Example test radnli contradiction pairs:
# ('No pulmonary edema is seen.', 'Mild pulmonary edema is redemonstrated, stable since prior chest x-ray.')
# ('The heart and mediastinal contours are normal.', 'The heart appears mildly enlarged.')
# ('There is no pleural effusion or pneumothorax in the left.', 'There is scattered atelectasis and there are tiny bilateral pleural effusions.')
# ('No pleural effusion or pneumothorax is present.', 'The left apical pneumothorax is likely unchanged.')
# Test mscxrt entailment pairs: 141
# Test mscxrt contradiction pairs: 220
# Example test mscxrt entailment pairs:
# ('interval worsening of now moderate - severe diffuse pulmonary edema.', 'interval progression of now moderate - severe diffuse pulmonary edema.')
# ('moderate left lower lobe atelectasis has worsened.', 'moderate left lower lobe atelectasis has increased.')
# ('unchanged mild bilateral pulmonary edema.', 'stable mild bilateral pulmonary edema.')
# ('stable moderate bilateral pleural effusions.', 'unchanged moderate bilateral pleural effusions.')
# Example test mscxrt contradiction pairs:
# ('As compared to previous study from earlier the same date, a right pneumothorax has increased in size and is now moderate.', 'Compared to ___ at 09:30, there is a moderate right pneumothorax that is unchanged in size.')
# ('mild pulmonary edema is stable.', 'mild pulmonary edema is new.')
# ('Slight improvement in mild pulmonary edema.', 'Slight worsening of mild pulmonary edema.')
# ('unchanged mild bilateral pulmonary edema.', 'new mild bilateral pulmonary edema.')
# Total sentences: 98658
#   0%|                                                 | 0/98658 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=375,2949907930748449873).pkl
# len(self.cache["hashes"]) = 2412
# self.cache["embeddings"].shape = (2412, 128)
# 100%|█████████████████████████████████| 98658/98658 [00:00<00:00, 395390.67it/s]
# Computing embeddings for 98275 new texts
# Explicitly passing a `revision` is encouraged when loading a configuration with custom code to ensure no malicious code has been contributed in a newer revision.
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# checkpoint_names = ['checkpoint_92_encc+nlcc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9209.pt']
# Loading model weights from /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240128_173216_MIMIC-CXR(triplets+entcon+nli)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/checkpoint_92_encc+nlcc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9209.pt
# Warning: model state dict has 211 keys, loaded state dict has 215 keys, intersection has 211 keys, union has 215 keys.
# Examples of keys in loaded state dict but not in model:
#   nli_hidden_layer.bias
#   nli_classifier.bias
#   nli_classifier.weight
#   nli_hidden_layer.weight
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# 100%|█████████████████████████████████████████| 983/983 [02:26<00:00,  6.70it/s]
# Saving updated cache to /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=375,2949907930748449873).pkl
# 100%|█████████████████████████████████| 98275/98275 [00:00<00:00, 629119.35it/s]
# embeddings.shape: (98658, 128)
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (25175, 128)
# train_h_ent_embeddings.shape: (25175, 128)
# train_p_con_embeddings.shape: (99121, 128)
# train_h_con_embeddings.shape: (99121, 128)
# train_ent_cosine_sim.shape: (25175,)
# train_con_cosine_sim.shape: (99121,)
# 100%|█████████████████████████████████████| 1000/1000 [00:00<00:00, 7243.07it/s]
# best_threshold: 0.2667851801271792
# best_acc: 0.9498929695298737
# best_ent_acc: 0.9672691161866932
# best_con_acc: 0.9325168228730542
# --------------
# Evaluating on RadNLI test set
# test_p_ent_embeddings.shape: (102, 128)
# test_h_ent_embeddings.shape: (102, 128)
# test_p_con_embeddings.shape: (98, 128)
# test_h_con_embeddings.shape: (98, 128)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 0.9803921568627451
# contradiction_acc: 0.9387755102040817
# test_acc: 0.9595838335334134
# --------------
# --------------
# Evaluating on MS-CXR-T Temporal Sentence Similarity v1
# test_p_ent_embeddings.shape: (141, 128)
# test_h_ent_embeddings.shape: (141, 128)
# test_p_con_embeddings.shape: (220, 128)
# test_h_con_embeddings.shape: (220, 128)
# test_ent_cosine_sim.shape: (141,)
# test_con_cosine_sim.shape: (220,)
# entailment_acc: 0.9929078014184397
# contradiction_acc: 0.8409090909090909
# test_acc: 0.9169084461637653
# --------------

# %%
# !python ../eval_NLI_v2.py \
--huggingface_model_name "microsoft/BiomedVLP-CXR-BERT-specialized" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240128_173216_MIMIC-CXR(triplets+entcon+nli)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)" \
--device "GPU" \
--batch_size 100 \
--num_workers 3 \
--calibrate_on_test_set
# Out:
# script's arguments:
#    huggingface_model_name: microsoft/BiomedVLP-CXR-BERT-specialized
#    model_name: None
#    model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240128_173216_MIMIC-CXR(triplets+entcon+nli)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)
#    device: GPU
#    batch_size: 100
#    num_workers: 3
#    integrated_nli_jsonl_filepath: None
#    similarity_metric: cosine
#    average_token_embeddings: False
#    calibrate_on_test_set: True
# checkpoint_names = ['checkpoint_92_encc+nlcc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9209.pt']
# Test radnli entailment pairs: 102
# Test radnli contradiction pairs: 98
# Example test radnli entailment pairs:
# ('No effusion or pneumothorax is seen.', 'No large pleural effusion or pneumothorax.')
# ('The pulmonary vasculature demonstrates an upper zone redistribution pattern, but there is no sign of an advanced interstitial or alveolar edema.', 'There is mild vascular congestion, but no overt pulmonary edema.')
# ('Heart size is top normal.', 'The cardiac silhouette is normal in size.')
# ('No acute osseous abnormality detected.', 'Imaged osseous structures are intact.')
# Example test radnli contradiction pairs:
# ('There is no focal consolidation, pleural effusion or pneumothorax.', 'Pleural effusions are likely present.')
# ('Cardiomediastinal and hilar silhouettes are normal.', 'Moderate cardiomegaly and mediastinal vascular engorgement is stable.')
# ('There is scattered atelectasis and there are tiny bilateral pleural effusions.', 'There is no pleural effusion or pneumothorax in the left.')
# ('The lungs are well expanded and clear.', 'The lungs are otherwise clear.')
# Test mscxrt entailment pairs: 141
# Test mscxrt contradiction pairs: 220
# Example test mscxrt entailment pairs:
# ('small medial left pneumothorax and pneumomediastinum are unchanged.', 'small medial left pneumothorax and pneumomediastinum are stable.')
# ('The extent of the pre-existing mild to moderate left pleural effusion is stable.', 'Mild to moderate left pleural effusion is unchanged.')
# ('There is a stable tiny right apical pneumothorax.', 'There remains a very tiny right apical pneumothorax, unchanged.')
# ('Persistent right upper lobe opacification has only mildly improved since ___.', 'Mildly improved right upper lobe opacity compared to ___.')
# Example test mscxrt contradiction pairs:
# ('improved left upper lung aeration with moderate re - expansion pulmonary edema.', 'worsened left upper lung aeration with moderate re - expansion pulmonary edema.')
# ('As compared to the previous radiograph, the extent of the pre-existing right pneumothorax has substantially increased.', 'The known right pneumothorax is not substantially changed.')
# ('minimal increase in extent of a pre - existing right basal parenchymal opacity.', 'minimal improvement in extent of a pre - existing right basal parenchymal opacity.')
# ('On the right consolidation at the lung base improved between ___ and ___ and has remained stable ever since.', 'Right lung base consolidation is increased compared to ___.')
# Total sentences: 825
#   0%|                                                   | 0/825 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=375,2949907930748449873).pkl
# len(self.cache["hashes"]) = 100687
# self.cache["embeddings"].shape = (100687, 128)
# 100%|███████████████████████████████████████| 825/825 [00:00<00:00, 2155.49it/s]
# embeddings.shape: (825, 128)
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (102, 128)
# train_h_ent_embeddings.shape: (102, 128)
# train_p_con_embeddings.shape: (98, 128)
# train_h_con_embeddings.shape: (98, 128)
# train_ent_cosine_sim.shape: (102,)
# train_con_cosine_sim.shape: (98,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 25442.85it/s]
# best_threshold: 0.2982218177826912
# best_acc: 0.9697879151660664
# best_ent_acc: 0.9803921568627451
# best_con_acc: 0.9591836734693877
# --------------
# Evaluating on RadNLI test set
# test_p_ent_embeddings.shape: (102, 128)
# test_h_ent_embeddings.shape: (102, 128)
# test_p_con_embeddings.shape: (98, 128)
# test_h_con_embeddings.shape: (98, 128)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 0.9803921568627451
# contradiction_acc: 0.9591836734693877
# test_acc: 0.9697879151660664
# --------------
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (141, 128)
# train_h_ent_embeddings.shape: (141, 128)
# train_p_con_embeddings.shape: (220, 128)
# train_h_con_embeddings.shape: (220, 128)
# train_ent_cosine_sim.shape: (141,)
# train_con_cosine_sim.shape: (220,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 25079.55it/s]
# best_threshold: 0.7715845619355355
# best_acc: 0.975725338491296
# best_ent_acc: 0.9787234042553191
# best_con_acc: 0.9727272727272728
# --------------
# Evaluating on MS-CXR-T Temporal Sentence Similarity v1
# test_p_ent_embeddings.shape: (141, 128)
# test_h_ent_embeddings.shape: (141, 128)
# test_p_con_embeddings.shape: (220, 128)
# test_h_con_embeddings.shape: (220, 128)
# test_ent_cosine_sim.shape: (141,)
# test_con_cosine_sim.shape: (220,)
# entailment_acc: 0.9787234042553191
# contradiction_acc: 0.9727272727272728
# test_acc: 0.975725338491296
# --------------

# %% [markdown]
# # CXR Fact Embedding (T -> T+R)

# %%
# !python ../eval_NLI_v2.py \
--huggingface_model_name "microsoft/BiomedVLP-CXR-BERT-specialized" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230928_110825_MIMIC-CXR(triplets+radgraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)" \
--device "GPU" \
--batch_size 100 \
--num_workers 3 \
--integrated_nli_jsonl_filepath \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(162036,21465751).jsonl"
# Out:
# script's arguments:
#    huggingface_model_name: microsoft/BiomedVLP-CXR-BERT-specialized
#    model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230928_110825_MIMIC-CXR(triplets+radgraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)
#    device: GPU
#    batch_size: 100
#    num_workers: 3
#    integrated_nli_jsonl_filepath: /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(162036,21465751).jsonl
#    similarity_metric: cosine
#    average_token_embeddings: False
#    calibrate_on_test_set: False
# checkpoint_names = ['checkpoint_93_spss+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9415.pt']
# Train entailment pairs: 26442
# Train contradiction pairs: 95777
# Example train entailment pairs:
# ('There is a persistent left pleural effusion.', 'There is persistent small left-sided pleural effusion.')
# ('Arctic Sun cooling protocol was initiated.', ' the patient was cooled')
# ('The tip terminates in the proximal right main pulmonary artery.', 'The tip now projects over the right pulmonary artery.')
# ('The ET tube remains in good position.', 'The ET tube placement has not changed.')
# Example train contradiction pairs:
# ('The left upper lobe shows no signs of heterogeneous opacity.', 'Heterogeneous opacity in the left upper lobe is consistent with infection.')
# ('Interstitial disease is detected in the X-ray.', 'No evidence of interstitial disease.')
# ('There appears to be slightly improved aeration within the right upper lobe.', 'There appears to be no improvement in aeration within the right upper lobe.')
# ('There is no pulmonary vascular congestion present', 'Mild pulmonary vascular congestion, unchanged compared to the prior study.')
# Test radnli entailment pairs: 102
# Test radnli contradiction pairs: 98
# Example test radnli entailment pairs:
# ('No pleural effusion or pneumothorax is noted.', 'No definite effusion or pneumothorax is seen.')
# ('The pulmonary vasculature demonstrates an upper zone redistribution pattern, but there is no sign of an advanced interstitial or alveolar edema.', 'There is mild vascular congestion, but no overt pulmonary edema.')
# ('No acute bony abnormalities are seen.', 'There are no acute osseous abnormalities.')
# ('The cardiomediastinal silhouette is normal.', 'The cardiomediastinal silhouette and contour are within normal limits.')
# Example test radnli contradiction pairs:
# ('There is no pulmonary edema.', 'There has been improvement in the pulmonary edema, now moderate.')
# ('There is a small pneumothorax in the left apex.', 'No pleural effusion or pneumothorax is seen.')
# ('There are small bilateral pleural effusions.', 'No pleural effusion or pneumothorax is seen.')
# ('No pulmonary edema is seen.', 'Mild pulmonary edema is redemonstrated, stable since prior chest x-ray.')
# Test mscxrt entailment pairs: 141
# Test mscxrt contradiction pairs: 220
# Example test mscxrt entailment pairs:
# ('mild - to - moderate degree of left basilar atelectasis is stable.', 'mild - to - moderate degree of left basilar atelectasis is unchanged.')
# ('stable moderate bilateral pleural effusions.', 'unchanged moderate bilateral pleural effusions.')
# ('more severe consolidation in the left lower lobe has worsened as well.', 'more severe consolidation in the left lower lobe has increased as well.')
# ('stable size of right apical pneumothorax.', 'unchanged size of right apical pneumothorax.')
# Example test mscxrt contradiction pairs:
# ('severely atelectatic left lower lobe is unchanged.', 'severely atelectatic left lower lobe is new.')
# ('worsening left - sided pleural effusion.', 'stable left - sided pleural effusion.')
# ('there is unchanged mild to moderate pulmonary edema.', 'there is new mild to moderate pulmonary edema.')
# ('opacities in the left base have minimally improved.', 'opacities in the left base have minimally worsened.')
# Total sentences: 102464
#   0%|                                                | 0/102464 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=368,1866338409828607810).pkl
# len(self.cache["hashes"]) = 32416
# self.cache["embeddings"].shape = (32416, 128)
# 100%|███████████████████████████████| 102464/102464 [00:00<00:00, 524273.93it/s]
# Computing embeddings for 102438 new texts
# Explicitly passing a `revision` is encouraged when loading a configuration with custom code to ensure no malicious code has been contributed in a newer revision.
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# checkpoint_names = ['checkpoint_93_spss+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9415.pt']
# Loading model weights from /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230928_110825_MIMIC-CXR(triplets+radgraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/checkpoint_93_spss+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9415.pt
# Warning: model state dict has 211 keys, loaded state dict has 216 keys, intersection has 211 keys, union has 216 keys.
# Examples of keys in loaded state dict but not in model:
#   spert_entity_classifier.weight
#   spert_rel_classifier.bias
#   spert_size_embeddings.weight
#   spert_rel_classifier.weight
#   spert_entity_classifier.bias
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# 100%|███████████████████████████████████████| 1025/1025 [01:49<00:00,  9.37it/s]
# Saving updated cache to /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=368,1866338409828607810).pkl
# 100%|███████████████████████████████| 102438/102438 [00:00<00:00, 668206.50it/s]
# embeddings.shape: (102464, 128)
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (26442, 128)
# train_h_ent_embeddings.shape: (26442, 128)
# train_p_con_embeddings.shape: (95777, 128)
# train_h_con_embeddings.shape: (95777, 128)
# train_ent_cosine_sim.shape: (26442,)
# train_con_cosine_sim.shape: (95777,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 11231.05it/s]
# best_threshold: 0.6514655535404867
# best_acc: 0.6827099768429143
# best_ent_acc: 0.8245594130549883
# best_con_acc: 0.5408605406308404
# --------------
# Evaluating on RadNLI test set
# test_p_ent_embeddings.shape: (102, 128)
# test_h_ent_embeddings.shape: (102, 128)
# test_p_con_embeddings.shape: (98, 128)
# test_h_con_embeddings.shape: (98, 128)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 0.7058823529411765
# contradiction_acc: 0.9183673469387755
# test_acc: 0.812124849939976
# --------------
# --------------
# Evaluating on MS-CXR-T Temporal Sentence Similarity v1
# test_p_ent_embeddings.shape: (141, 128)
# test_h_ent_embeddings.shape: (141, 128)
# test_p_con_embeddings.shape: (220, 128)
# test_h_con_embeddings.shape: (220, 128)
# test_ent_cosine_sim.shape: (141,)
# test_con_cosine_sim.shape: (220,)
# entailment_acc: 0.9929078014184397
# contradiction_acc: 0.17272727272727273
# test_acc: 0.5828175370728562
# --------------

# %%
# !python ../eval_NLI_v2.py \
--huggingface_model_name "microsoft/BiomedVLP-CXR-BERT-specialized" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230928_110825_MIMIC-CXR(triplets+radgraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)" \
--device "GPU" \
--batch_size 100 \
--num_workers 3 \
--integrated_nli_jsonl_filepath \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(169025,21838032).jsonl"
# Out:
# script's arguments:
#    huggingface_model_name: microsoft/BiomedVLP-CXR-BERT-specialized
#    model_name: None
#    model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230928_110825_MIMIC-CXR(triplets+radgraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)
#    device: GPU
#    batch_size: 100
#    num_workers: 3
#    integrated_nli_jsonl_filepath: /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(169025,21838032).jsonl
#    similarity_metric: cosine
#    average_token_embeddings: False
#    calibrate_on_test_set: False
# checkpoint_names = ['checkpoint_93_spss+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9415.pt']
# Train entailment pairs: 25175
# Train contradiction pairs: 99121
# Example train entailment pairs:
# ('A left total shoulder arthroplasty is seen.', 'The patient has had a left shoulder replacement surgery.')
# ('The cardiac silhouette remains within normal limits for size.', 'HEART IS NORMAL SIZE.')
# ('Old healed posterior right rib fractures are again noted.', 'The patient has a history of right rib fractures.')
# ('Well known abdominal aortic aneurysm 4.5 cm, last     ultrasound [**3461-9-9**] with no changes.', ' Enlarged abdominal aorta ')
# Example train contradiction pairs:
# ('No pneumothoraces are seen.', 'Tiny left-sided pneumothorax present, decreased compared with .')
# ("The patient's apical region is completely free from pneumothorax.", 'Small apical pneumothorax is present.')
# ('The cardiac, mediastinal and hilar contours are unchanged, without any calcification of the thoracic aorta.', 'The cardiac, mediastinal and hilar contours are unchanged, with calcification of the thoracic aorta.')
# ('No mediastinal free air is seen.', 'There is a clear presence of mediastinal free air.')
# Test radnli entailment pairs: 102
# Test radnli contradiction pairs: 98
# Example test radnli entailment pairs:
# ('Heart size is top normal.', 'The cardiac silhouette is normal in size.')
# ('The hilar and cardiomediastinal contours are normal.', 'The cardiomediastinal silhouette is normal.')
# ('No focal consolidation, pleural effusion, pulmonary edema, or pneumothorax.', 'No pneumothorax is evident.')
# ('Cardiomediastinal silhouette and hilar contours are unremarkable.', 'Cardiomediastinal and hilar contours are normal.')
# Example test radnli contradiction pairs:
# ('There is no pleural effusion or pneumothorax.', 'Pleura: Likely there is a right pleural effusion is well as a small left pleural effusion.')
# ('Dense retrocardiac opacification persists, consistent with left lower lobe consolidation and small pleural effusion.', 'No pleural effusion or pneumothorax is seen.')
# ('Moderate cardiomegaly and minimal left pleural effusion.', 'No pleural effusion or pneumothorax is seen.')
# ('Cardiomegaly, extensive right pleural effusion with subsequent right middle and lower lung consolidations, likely to represent atelectasis, pneumonia, or a combination of both.', 'No right pleural effusion.')
# Test mscxrt entailment pairs: 141
# Test mscxrt contradiction pairs: 220
# Example test mscxrt entailment pairs:
# ('Slight decrease in moderate pulmonary edema.', 'Slight improvement in moderate pulmonary edema.')
# ('there is unchanged mild to moderate pulmonary edema.', 'there is stable mild to moderate pulmonary edema.')
# ('Atelectasis at the bases has improved.', 'In comparison with the study of ___, the atelectatic changes at the bases have decreased.')
# ('moderate right pleural effusion is larger today than on ___.', 'moderate right pleural effusion is worse today than on ___.')
# Example test mscxrt contradiction pairs:
# ('interval improvement in mild pulmonary edema.', 'interval increase in mild pulmonary edema.')
# ('Vascular congestion in the left lung is improved.', 'Vascular congestion in the left lung is unchanged since ___.')
# ('Moderate subpulmonic right pleural effusion smaller today than on ___.', 'Right moderate pleural effusion with a subpulmonic component is unchanged since ___.')
# ('subsegmental atelectasis at the left lung base has worsened.', 'subsegmental atelectasis at the left lung base has improved.')
# Total sentences: 98658
#   0%|                                                 | 0/98658 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=368,1866338409828607810).pkl
# len(self.cache["hashes"]) = 146286
# self.cache["embeddings"].shape = (146286, 128)
# 100%|█████████████████████████████████| 98658/98658 [00:00<00:00, 194242.34it/s]
# Computing embeddings for 18445 new texts
# Explicitly passing a `revision` is encouraged when loading a configuration with custom code to ensure no malicious code has been contributed in a newer revision.
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# checkpoint_names = ['checkpoint_93_spss+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9415.pt']
# Loading model weights from /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230928_110825_MIMIC-CXR(triplets+radgraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/checkpoint_93_spss+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9415.pt
# Warning: model state dict has 211 keys, loaded state dict has 216 keys, intersection has 211 keys, union has 216 keys.
# Examples of keys in loaded state dict but not in model:
#   spert_rel_classifier.weight
#   spert_rel_classifier.bias
#   spert_entity_classifier.bias
#   spert_size_embeddings.weight
#   spert_entity_classifier.weight
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# 100%|█████████████████████████████████████████| 185/185 [00:15<00:00, 12.02it/s]
# Saving updated cache to /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=368,1866338409828607810).pkl
# 100%|█████████████████████████████████| 18445/18445 [00:00<00:00, 354378.14it/s]
# embeddings.shape: (98658, 128)
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (25175, 128)
# train_h_ent_embeddings.shape: (25175, 128)
# train_p_con_embeddings.shape: (99121, 128)
# train_h_con_embeddings.shape: (99121, 128)
# train_ent_cosine_sim.shape: (25175,)
# train_con_cosine_sim.shape: (99121,)
# 100%|█████████████████████████████████████| 1000/1000 [00:00<00:00, 5440.08it/s]
# best_threshold: 0.6064302835378563
# best_acc: 0.6790902704083692
# best_ent_acc: 0.815571002979146
# best_con_acc: 0.5426095378375925
# --------------
# Evaluating on RadNLI test set
# test_p_ent_embeddings.shape: (102, 128)
# test_h_ent_embeddings.shape: (102, 128)
# test_p_con_embeddings.shape: (98, 128)
# test_h_con_embeddings.shape: (98, 128)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 0.7058823529411765
# contradiction_acc: 0.8979591836734694
# test_acc: 0.801920768307323
# --------------
# --------------
# Evaluating on MS-CXR-T Temporal Sentence Similarity v1
# test_p_ent_embeddings.shape: (141, 128)
# test_h_ent_embeddings.shape: (141, 128)
# test_p_con_embeddings.shape: (220, 128)
# test_h_con_embeddings.shape: (220, 128)
# test_ent_cosine_sim.shape: (141,)
# test_con_cosine_sim.shape: (220,)
# entailment_acc: 1.0
# contradiction_acc: 0.16818181818181818
# test_acc: 0.5840909090909091
# --------------

# %%
# !python ../eval_NLI_v2.py \
--huggingface_model_name "microsoft/BiomedVLP-CXR-BERT-specialized" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230928_110825_MIMIC-CXR(triplets+radgraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)" \
--device "GPU" \
--batch_size 100 \
--num_workers 3 \
--calibrate_on_test_set
# Out:
# script's arguments:
#    huggingface_model_name: microsoft/BiomedVLP-CXR-BERT-specialized
#    model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230928_110825_MIMIC-CXR(triplets+radgraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)
#    device: GPU
#    batch_size: 100
#    num_workers: 3
#    integrated_nli_jsonl_filepath: None
#    similarity_metric: cosine
#    average_token_embeddings: False
#    calibrate_on_test_set: True
# checkpoint_names = ['checkpoint_93_spss+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9415.pt']
# Test radnli entailment pairs: 102
# Test radnli contradiction pairs: 98
# Example test radnli entailment pairs:
# ('There is no pleural effusion, focal consolidation or pneumothorax.', 'There is no pneumothorax or pleural effusion.')
# ('No definite effusion or pneumothorax is seen.', 'No pleural effusion or pneumothorax is noted.')
# ('The lungs are clear without consolidation, effusion, or pneumothorax.', 'No pneumothorax is identified.')
# ('The heart appears top-normal in size.', 'Cardiac silhouette is top-normal.')
# Example test radnli contradiction pairs:
# ('Interval placement of right-sided chest tube with apparent resolution of right pleural effusion but development of a small pneumothorax.', 'There is no pleural effusion or pneumothorax.')
# ('There is scattered atelectasis and there are tiny bilateral pleural effusions.', 'There is no pleural effusion or pneumothorax in the left.')
# ('Lung volumes are low, and the cardiac silhouette is enlarged.', 'Cardiac silhouette is normal in size.')
# ('There is no pleural effusion or pneumothorax.', 'Pleura: Likely there is a right pleural effusion is well as a small left pleural effusion.')
# Test mscxrt entailment pairs: 141
# Test mscxrt contradiction pairs: 220
# Example test mscxrt entailment pairs:
# ('Since ___, the left lower lobe has been collapsed.', 'Left lower lobe remains collapsed.')
# ('stable size of right apical pneumothorax.', 'unchanged size of right apical pneumothorax.')
# ('the hazy opacification at the bases has decreased.', 'the hazy opacification at the bases has improved.')
# ('Right apical pneumothorax is unchanged and minimal.', 'Minimal right apical pneumothorax is unchanged.')
# Example test mscxrt contradiction pairs:
# ('the hazy opacification at the bases has decreased.', 'the hazy opacification at the bases has increased.')
# ('there is substantial interval improvement of pulmonary edema.', 'there is substantial interval progression of pulmonary edema.')
# ('Small right pneumothorax has developed at the base of the right lung.', 'Small pneumothorax at the base of the right lung is unchanged.')
# ('The pre-existing opacity at the level of the right upper lobe is decreasing in extent and severity.', 'The right upper lobe opacity is stable in extent and severity.')
# Total sentences: 825
#   0%|                                                   | 0/825 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=368,1866338409828607810).pkl
# len(self.cache["hashes"]) = 134854
# self.cache["embeddings"].shape = (134854, 128)
# 100%|███████████████████████████████████████| 825/825 [00:00<00:00, 4031.09it/s]
# embeddings.shape: (825, 128)
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (102, 128)
# train_h_ent_embeddings.shape: (102, 128)
# train_p_con_embeddings.shape: (98, 128)
# train_h_con_embeddings.shape: (98, 128)
# train_ent_cosine_sim.shape: (102,)
# train_con_cosine_sim.shape: (98,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 43970.06it/s]
# best_threshold: 0.4160644064794432
# best_acc: 0.8599439775910365
# best_ent_acc: 0.8627450980392157
# best_con_acc: 0.8571428571428571
# --------------
# Evaluating on RadNLI test set
# test_p_ent_embeddings.shape: (102, 128)
# test_h_ent_embeddings.shape: (102, 128)
# test_p_con_embeddings.shape: (98, 128)
# test_h_con_embeddings.shape: (98, 128)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 0.8627450980392157
# contradiction_acc: 0.8571428571428571
# test_acc: 0.8599439775910365
# --------------
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (141, 128)
# train_h_ent_embeddings.shape: (141, 128)
# train_p_con_embeddings.shape: (220, 128)
# train_h_con_embeddings.shape: (220, 128)
# train_ent_cosine_sim.shape: (141,)
# train_con_cosine_sim.shape: (220,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 44004.20it/s]
# best_threshold: 0.9911037832051068
# best_acc: 0.7852514506769825
# best_ent_acc: 0.7659574468085106
# best_con_acc: 0.8045454545454546
# --------------
# Evaluating on MS-CXR-T Temporal Sentence Similarity v1
# test_p_ent_embeddings.shape: (141, 128)
# test_h_ent_embeddings.shape: (141, 128)
# test_p_con_embeddings.shape: (220, 128)
# test_h_con_embeddings.shape: (220, 128)
# test_ent_cosine_sim.shape: (141,)
# test_con_cosine_sim.shape: (220,)
# entailment_acc: 0.7659574468085106
# contradiction_acc: 0.8045454545454546
# test_acc: 0.7852514506769825
# --------------

# %% [markdown]
# # CXR Fact Embedding (T -> T+C+EC+NLI+R)

# %%
# !python ../eval_NLI_v2.py \
--huggingface_model_name "microsoft/BiomedVLP-CXR-BERT-specialized" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230928_144824_MIMIC-CXR(triplets+classif+entcont+nli+radgraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/" \
--device "GPU" \
--batch_size 100 \
--num_workers 3 \
--integrated_nli_jsonl_filepath \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(162036,21465751).jsonl"
# Out:
# script's arguments:
#    huggingface_model_name: microsoft/BiomedVLP-CXR-BERT-specialized
#    model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230928_144824_MIMIC-CXR(triplets+classif+entcont+nli+radgraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/
#    device: GPU
#    batch_size: 100
#    num_workers: 3
#    integrated_nli_jsonl_filepath: /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(162036,21465751).jsonl
#    similarity_metric: cosine
#    average_token_embeddings: False
#    calibrate_on_test_set: False
# checkpoint_names = ['checkpoint_67_cacc+chf1+chf1+cscc+encc+hscc+nlcc+spss+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9336.pt']
# Train entailment pairs: 26442
# Train contradiction pairs: 95777
# Example train entailment pairs:
# ('There is stable dextroconvex curvature centered over the lower thoracic spine and interval development of a compression deformity of a mid thoracic vertebral body of unclear chronicity.', "The patient's X-ray shows a compression deformity of a mid thoracic vertebral body.")
# ('[**Known patient lastname 24761**] is a 26 y.o. female with resistant and progressive AML diagnosed [**2-2**].', ' Patient has malignancy')
# ('No pleural effusions, pneumothorax or focal airspace consolidation.', "The patient's chest X-ray shows no signs of fluid accumulation in the pleural space, no collapsed lung, and no areas of lung tissue filled with fluid or pus.")
# ('The monitoring and support devices, including the left pectoral pacemaker, are unchanged in position.', 'The left pectoral pacemaker is in the same position as before.')
# Example train contradiction pairs:
# ('Again seen is a large hiatal hernia within the left hemithorax.', 'Again seen is a moderate hiatal hernia which is stable.')
# ('There is significant atelectasis in the left lung base, but no focal consolidation, pleural effusion or pneumothorax is visualized.', 'There is minimal atelectasis in the left lung base, but no focal consolidation, pleural effusion or pneumothorax is visualized.')
# ("The patient's chest X-ray is clear with no opacifications.", 'Multiple opacifications are seen within the right middle lobe and right lower lobe as well as a left lower lobe opacification.')
# ('The vague left mid lung nodule is identical to the previous one.', 'A vague left mid lung nodule is similar to but new since .')
# Test radnli entailment pairs: 102
# Test radnli contradiction pairs: 98
# Example test radnli entailment pairs:
# ('Heart and mediastinal contours appear normal.', 'The cardiomediastinal and hilar contours are within normal limits.')
# ('The osseous structures are grossly unremarkable, although evaluation is limited secondary to body habitus.', 'Osseous structures are without an acute abnormality.')
# ('The heart is not enlarged.', 'The cardiac silhouette is top normal.')
# ('There is no pleural effusion, focal consolidation or pneumothorax.', 'There is no pneumothorax or pleural effusion.')
# Example test radnli contradiction pairs:
# ('There is no focal consolidation, pleural effusion or pneumothorax.', 'The right atelectasis and pleural effusion has increased.')
# ('There is no pleural effusion or pneumothorax in the left.', 'There is scattered atelectasis and there are tiny bilateral pleural effusions.')
# ('Moderate cardiomegaly and mediastinal vascular engorgement is stable.', 'Cardiomediastinal and hilar silhouettes are normal.')
# ('No pleural effusion or pneumothorax is seen.', 'Dense retrocardiac opacification persists, consistent with left lower lobe consolidation and small pleural effusion.')
# Test mscxrt entailment pairs: 141
# Test mscxrt contradiction pairs: 220
# Example test mscxrt entailment pairs:
# ('unchanged tiny left pleural effusion.', 'stable tiny left pleural effusion.')
# ('significant interval decrease in size of the right pleural effusion.', 'significant interval improvement in size of the right pleural effusion.')
# ('Stable extent of the pre-existing left pleural effusion.', 'Stable extent of a previously existing left pleural effusion.')
# ('unchanged mild bilateral pulmonary edema.', 'stable mild bilateral pulmonary edema.')
# Example test mscxrt contradiction pairs:
# ('improved left upper lung aeration with moderate re - expansion pulmonary edema.', 'increased left upper lung aeration with moderate re - expansion pulmonary edema.')
# ('right basal opacities have minimally improved.', 'right basal opacities have minimally increased.')
# ('slight improvement of the mild pulmonary vascular congestion and edema.', 'slight worsening of the mild pulmonary vascular congestion and edema.')
# ('Left basal consolidation has slightly improved.', 'Left basal consolidation has slightly increased.')
# Total sentences: 102464
#   0%|                                                | 0/102464 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=423,543192558617698066).pkl
# len(self.cache["hashes"]) = 32416
# self.cache["embeddings"].shape = (32416, 128)
# 100%|███████████████████████████████| 102464/102464 [00:00<00:00, 527833.45it/s]
# Computing embeddings for 102438 new texts
# Explicitly passing a `revision` is encouraged when loading a configuration with custom code to ensure no malicious code has been contributed in a newer revision.
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# checkpoint_names = ['checkpoint_67_cacc+chf1+chf1+cscc+encc+hscc+nlcc+spss+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9336.pt']
# Loading model weights from /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230928_144824_MIMIC-CXR(triplets+classif+entcont+nli+radgraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/checkpoint_67_cacc+chf1+chf1+cscc+encc+hscc+nlcc+spss+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9336.pt
# Warning: model state dict has 211 keys, loaded state dict has 232 keys, intersection has 211 keys, union has 232 keys.
# Examples of keys in loaded state dict but not in model:
#   nli_hidden_layer.bias
#   aux_task_hidden_layer.bias
#   aux_task_hidden_layer.weight
#   category_classifier.weight
#   spert_entity_classifier.weight
#   chest_imagenome_anatloc_classifier.bias
#   nli_hidden_layer.weight
#   health_status_classifier.bias
#   chest_imagenome_anatloc_classifier.weight
#   chest_imagenome_obs_classifier.weight
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# 100%|███████████████████████████████████████| 1025/1025 [01:49<00:00,  9.40it/s]
# Saving updated cache to /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=423,543192558617698066).pkl
# 100%|███████████████████████████████| 102438/102438 [00:00<00:00, 676990.55it/s]
# embeddings.shape: (102464, 128)
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (26442, 128)
# train_h_ent_embeddings.shape: (26442, 128)
# train_p_con_embeddings.shape: (95777, 128)
# train_h_con_embeddings.shape: (95777, 128)
# train_ent_cosine_sim.shape: (26442,)
# train_con_cosine_sim.shape: (95777,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 11834.54it/s]
# best_threshold: 0.5075950467431389
# best_acc: 0.9030302908290917
# best_ent_acc: 0.9642614023144996
# best_con_acc: 0.8417991793436838
# --------------
# Evaluating on RadNLI test set
# test_p_ent_embeddings.shape: (102, 128)
# test_h_ent_embeddings.shape: (102, 128)
# test_p_con_embeddings.shape: (98, 128)
# test_h_con_embeddings.shape: (98, 128)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 0.9607843137254902
# contradiction_acc: 0.8571428571428571
# test_acc: 0.9089635854341737
# --------------
# --------------
# Evaluating on MS-CXR-T Temporal Sentence Similarity v1
# test_p_ent_embeddings.shape: (141, 128)
# test_h_ent_embeddings.shape: (141, 128)
# test_p_con_embeddings.shape: (220, 128)
# test_h_con_embeddings.shape: (220, 128)
# test_ent_cosine_sim.shape: (141,)
# test_con_cosine_sim.shape: (220,)
# entailment_acc: 1.0
# contradiction_acc: 0.7045454545454546
# test_acc: 0.8522727272727273
# --------------

# %%
# !python ../eval_NLI_v2.py \
--huggingface_model_name "microsoft/BiomedVLP-CXR-BERT-specialized" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230928_144824_MIMIC-CXR(triplets+classif+entcont+nli+radgraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/" \
--device "GPU" \
--batch_size 100 \
--num_workers 3 \
--calibrate_on_test_set
# Out:
# script's arguments:
#    huggingface_model_name: microsoft/BiomedVLP-CXR-BERT-specialized
#    model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230928_144824_MIMIC-CXR(triplets+classif+entcont+nli+radgraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/
#    device: GPU
#    batch_size: 100
#    num_workers: 3
#    integrated_nli_jsonl_filepath: None
#    similarity_metric: cosine
#    average_token_embeddings: False
#    calibrate_on_test_set: True
# checkpoint_names = ['checkpoint_67_cacc+chf1+chf1+cscc+encc+hscc+nlcc+spss+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9336.pt']
# Test radnli entailment pairs: 102
# Test radnli contradiction pairs: 98
# Example test radnli entailment pairs:
# ('Lungs are clear.', 'The lungs are clear without focal consolidation.')
# ('Imaged osseous structures are intact.', 'No acute osseous abnormality detected.')
# ('The lungs are clear.', 'The lungs are unremarkable.')
# ('There is no focal consolidation, pleural effusion, pneumothorax, or pulmonary edema.', 'There is no pneumothorax.')
# Example test radnli contradiction pairs:
# ('The lungs are otherwise clear without focal consolidation.', 'The lungs however are clear.')
# ('No pneumothoraces are present.', 'Known small left pneumothorax is not well seen.')
# ('No pleural effusion or pneumothorax is seen.', 'There is a small left pleural effusion.')
# ('Allowing for these limitation, there are no focal parenchymal opacities.', 'Since the prior radiograph, no significant change in the widespread parenchymal opacities and moderate cardiomegaly.')
# Test mscxrt entailment pairs: 141
# Test mscxrt contradiction pairs: 220
# Example test mscxrt entailment pairs:
# ('small - to - moderate right pleural effusion has decreased.', 'small - to - moderate right pleural effusion has improved.')
# ('there has been interval improvement in the mild interstitial edema.', 'there has been interval decrease in the mild interstitial edema.')
# ('as a consequence, the basal atelectasis has also increased.', 'as a consequence, the basal atelectasis has also worsened.')
# ('bibasal consolidations are unchanged.', 'bibasal consolidations are stable.')
# Example test mscxrt contradiction pairs:
# ('There may be a region of consolidation at the right base which has developed over the past 24 hr.', 'There is persistent consolidation at the right base, unchanged since previous.')
# ('Atelectasis in the left mid lung is new.', 'Atelectasis at the left mid lung is unchanged.')
# ('moderate bilateral pulmonary edema has decreased in extent and severity.', 'moderate bilateral pulmonary edema has increased in extent and severity.')
# ('Mild to moderate vascular congestion has increased.', 'Mild to moderate vascular congestion is probably unchanged.')
# Total sentences: 825
#   0%|                                                   | 0/825 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=423,543192558617698066).pkl
# len(self.cache["hashes"]) = 134854
# self.cache["embeddings"].shape = (134854, 128)
# 100%|███████████████████████████████████████| 825/825 [00:00<00:00, 4014.37it/s]
# embeddings.shape: (825, 128)
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (102, 128)
# train_h_ent_embeddings.shape: (102, 128)
# train_p_con_embeddings.shape: (98, 128)
# train_h_con_embeddings.shape: (98, 128)
# train_ent_cosine_sim.shape: (102,)
# train_con_cosine_sim.shape: (98,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 45085.01it/s]
# best_threshold: 0.6566349210085216
# best_acc: 0.9203681472589036
# best_ent_acc: 0.9019607843137255
# best_con_acc: 0.9387755102040817
# --------------
# Evaluating on RadNLI test set
# test_p_ent_embeddings.shape: (102, 128)
# test_h_ent_embeddings.shape: (102, 128)
# test_p_con_embeddings.shape: (98, 128)
# test_h_con_embeddings.shape: (98, 128)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 0.9019607843137255
# contradiction_acc: 0.9387755102040817
# test_acc: 0.9203681472589036
# --------------
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (141, 128)
# train_h_ent_embeddings.shape: (141, 128)
# train_p_con_embeddings.shape: (220, 128)
# train_h_con_embeddings.shape: (220, 128)
# train_ent_cosine_sim.shape: (141,)
# train_con_cosine_sim.shape: (220,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 43732.58it/s]
# best_threshold: 0.8526261139202405
# best_acc: 0.9511766602192134
# best_ent_acc: 0.9432624113475178
# best_con_acc: 0.9590909090909091
# --------------
# Evaluating on MS-CXR-T Temporal Sentence Similarity v1
# test_p_ent_embeddings.shape: (141, 128)
# test_h_ent_embeddings.shape: (141, 128)
# test_p_con_embeddings.shape: (220, 128)
# test_h_con_embeddings.shape: (220, 128)
# test_ent_cosine_sim.shape: (141,)
# test_con_cosine_sim.shape: (220,)
# entailment_acc: 0.9432624113475178
# contradiction_acc: 0.9590909090909091
# test_acc: 0.9511766602192134
# --------------

# %%
# !python ../eval_NLI_v2.py \
--huggingface_model_name "microsoft/BiomedVLP-CXR-BERT-specialized" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20231002_152825_MIMIC-CXR(triplets+classif+entcont+nli+radgraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/" \
--device "GPU" \
--batch_size 100 \
--num_workers 3 \
--integrated_nli_jsonl_filepath \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(162036,21465751).jsonl"
# Out:
# script's arguments:
#    huggingface_model_name: microsoft/BiomedVLP-CXR-BERT-specialized
#    model_name: None
#    model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20231002_152825_MIMIC-CXR(triplets+classif+entcont+nli+radgraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/
#    device: GPU
#    batch_size: 100
#    num_workers: 3
#    integrated_nli_jsonl_filepath: /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(162036,21465751).jsonl
#    similarity_metric: cosine
#    average_token_embeddings: False
#    calibrate_on_test_set: False
# checkpoint_names = ['checkpoint_26_cacc+chf1+chf1+cscc+encc+hscc+nlcc+spss+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9386.pt']
# Train entailment pairs: 26442
# Train contradiction pairs: 95777
# Example train entailment pairs:
# ('The aorta is mildly tortuous with calcifications at the aortic knob.', 'The aorta is tortuous and there are calcifications at the aortic knob.')
# ('Mediastinal silhouettes are stable.', 'There are no significant changes in the mediastinal silhouettes.')
# ('When compared to prior study dated , there is an essentially no change.', 'The left-sided chest tube is again seen, unchanged.')
# ('The heart is mildly enlarged with borderline redistribution of the pulmonary vessels, unchanged from the prior exam.', "The patient's heart enlargement is consistent with previous examinations.")
# Example train contradiction pairs:
# ('No increased pulmonary congestion.', 'Pulmonary congestion has significantly increased.')
# ('Moderate degenerative changes are in the thoracic spine.', 'Severe degenerative changes are noted in the thoracic spine.')
# ('The sternotomy wires are not visible in the X-ray.', 'There are sternotomy wires seen unchanged in position.')
# ('There has been little change in comparison to prior radiograph from .', 'There has been no change in comparison to prior radiograph.')
# Test radnli entailment pairs: 102
# Test radnli contradiction pairs: 98
# Example test radnli entailment pairs:
# ('Heart size is top normal.', 'The cardiac silhouette is normal in size.')
# ('Cardiomediastinal and hilar contours are normal.', 'Cardiomediastinal silhouette and hilar contours are unremarkable.')
# ('The lungs are clear without focal consolidation.', 'There is no focal consolidation.')
# ('The lungs are clear without focal consolidation.', 'Lungs are clear.')
# Example test radnli contradiction pairs:
# ('Small bilateral pleural effusions are noted.', 'No right-sided pleural effusion is seen.')
# ('Moderate cardiomegaly and mediastinal vascular engorgement is stable.', 'Cardiomediastinal and hilar silhouettes are normal.')
# ('There is no pleural effusion or pneumothorax.', 'Trace pleural effusion at the right base.')
# ('No pleural effusion or pneumothorax is present.', 'There is subtle blunting of the left CP angle suggesting a tiny effusion or pleural thickening.')
# Test mscxrt entailment pairs: 141
# Test mscxrt contradiction pairs: 220
# Example test mscxrt entailment pairs:
# ('Atelectasis at the bases has improved.', 'In comparison with the study of ___, the atelectatic changes at the bases have decreased.')
# ('retrocardiac atelectasis is unchanged.', 'retrocardiac atelectasis is stable.')
# ('Slight interval decrease of bilateral pleural effusions.', 'Slight interval improvement in bilateral pleural effusions.')
# ('small right pleural effusion is unchanged.', 'small right pleural effusion is stable.')
# Example test mscxrt contradiction pairs:
# ('bibasal atelectasis is unchanged.', 'bibasal atelectasis is new.')
# ('Left retrocardiac consolidation is also unchanged.', 'Left retrocardiac consolidation, increased ___ to ___, warrants CT evaluation.')
# ('slightly increased moderate pulmonary edema.', 'slightly improved moderate pulmonary edema.')
# ('pulmonary edema has also increased.', 'pulmonary edema has also improved.')
# Total sentences: 102464
# 100%|███████████████████████████████| 102464/102464 [00:00<00:00, 611965.72it/s]
# Computing embeddings for 102464 new texts
# Explicitly passing a `revision` is encouraged when loading a configuration with custom code to ensure no malicious code has been contributed in a newer revision.
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# checkpoint_names = ['checkpoint_26_cacc+chf1+chf1+cscc+encc+hscc+nlcc+spss+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9386.pt']
# Loading model weights from /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20231002_152825_MIMIC-CXR(triplets+classif+entcont+nli+radgraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/checkpoint_26_cacc+chf1+chf1+cscc+encc+hscc+nlcc+spss+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9386.pt
# Warning: model state dict has 211 keys, loaded state dict has 232 keys, intersection has 211 keys, union has 232 keys.
# Examples of keys in loaded state dict but not in model:
#   nli_hidden_layer.weight
#   health_status_classifier.weight
#   nli_classifier.bias
#   category_classifier.bias
#   spert_size_embeddings.weight
#   aux_task_hidden_layer.weight
#   comparison_status_classifier.bias
#   spert_entity_classifier.bias
#   nli_hidden_layer.bias
#   chest_imagenome_obs_classifier.weight
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# 100%|███████████████████████████████████████| 1025/1025 [01:50<00:00,  9.28it/s]
# Saving updated cache to /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=423,141429923173682938).pkl
# 100%|███████████████████████████████| 102464/102464 [00:00<00:00, 723151.24it/s]
# embeddings.shape: (102464, 128)
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (26442, 128)
# train_h_ent_embeddings.shape: (26442, 128)
# train_p_con_embeddings.shape: (95777, 128)
# train_h_con_embeddings.shape: (95777, 128)
# train_ent_cosine_sim.shape: (26442,)
# train_con_cosine_sim.shape: (95777,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 11595.38it/s]
# best_threshold: 0.4549498177386142
# best_acc: 0.896720759169445
# best_ent_acc: 0.9608199077225625
# best_con_acc: 0.8326216106163276
# --------------
# Evaluating on RadNLI test set
# test_p_ent_embeddings.shape: (102, 128)
# test_h_ent_embeddings.shape: (102, 128)
# test_p_con_embeddings.shape: (98, 128)
# test_h_con_embeddings.shape: (98, 128)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 0.9803921568627451
# contradiction_acc: 0.7959183673469388
# test_acc: 0.8881552621048419
# --------------
# --------------
# Evaluating on MS-CXR-T Temporal Sentence Similarity v1
# test_p_ent_embeddings.shape: (141, 128)
# test_h_ent_embeddings.shape: (141, 128)
# test_p_con_embeddings.shape: (220, 128)
# test_h_con_embeddings.shape: (220, 128)
# test_ent_cosine_sim.shape: (141,)
# test_con_cosine_sim.shape: (220,)
# entailment_acc: 1.0
# contradiction_acc: 0.6681818181818182
# test_acc: 0.8340909090909091
# --------------

# %%
# !python ../eval_NLI_v2.py \
--huggingface_model_name "microsoft/BiomedVLP-CXR-BERT-specialized" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20231002_152825_MIMIC-CXR(triplets+classif+entcont+nli+radgraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/" \
--device "GPU" \
--batch_size 100 \
--num_workers 3 \
--calibrate_on_test_set
# Out:
# script's arguments:
#    huggingface_model_name: microsoft/BiomedVLP-CXR-BERT-specialized
#    model_name: None
#    model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20231002_152825_MIMIC-CXR(triplets+classif+entcont+nli+radgraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/
#    device: GPU
#    batch_size: 100
#    num_workers: 3
#    integrated_nli_jsonl_filepath: None
#    similarity_metric: cosine
#    average_token_embeddings: False
#    calibrate_on_test_set: True
# checkpoint_names = ['checkpoint_26_cacc+chf1+chf1+cscc+encc+hscc+nlcc+spss+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9386.pt']
# Test radnli entailment pairs: 102
# Test radnli contradiction pairs: 98
# Example test radnli entailment pairs:
# ('The lungs are clear without focal consolidation, pleural effusion or pneumothorax.', 'There are no pleural effusions.')
# ('Heart size is upper limit of normal with no signs of pleural effusion or pulmonary congestion.', 'There is no pulmonary vascular congestion.')
# ('Widespread pulmonary opacities appear slightly more confluent at the right lung base, though there is slightly improved aeration in the retrocardiac region.', 'There are likely patchy opacities in the lung bases reflective of atelectasis.')
# ('There is no focal consolidation, pleural effusion, pneumothorax, or pulmonary edema.', 'There is no pleural effusion, focal consolidation or pneumothorax.')
# Example test radnli contradiction pairs:
# ('A small residual right effusion is present.', 'No pleural effusion or pneumothorax is seen.')
# ('There is no pleural effusion or pulmonary edema.', 'Small right pleural effusion has decreased.')
# ('The heart appears mildly enlarged.', 'The heart and mediastinal contours are normal.')
# ('No pleural effusion or pneumothorax is seen.', 'The right atelectasis and pleural effusion has increased.')
# Test mscxrt entailment pairs: 141
# Test mscxrt contradiction pairs: 220
# Example test mscxrt entailment pairs:
# ('pulmonary edema has improved.', 'pulmonary edema has decreased.')
# ('Right apical pneumothorax is unchanged and minimal.', 'Minimal right apical pneumothorax is unchanged.')
# ('Stable small left pneumothorax.', 'Stable small pneumothorax on the left.')
# ('moderate left lower lobe atelectasis has worsened.', 'moderate left lower lobe atelectasis has increased.')
# Example test mscxrt contradiction pairs:
# ('the severity of the pre - existing pulmonary edema has decreased.', 'the severity of the pre - existing pulmonary edema has increased.')
# ('unchanged, tiny left apical pneumothorax.', 'new, tiny left apical pneumothorax.')
# ('As compared to the previous radiograph, the retrocardiac consolidation is progressing.', 'Retrocardiac consolidation is unchanged.')
# ('interval worsening of the right - sided pneumothorax.', 'interval resolution of the right - sided pneumothorax.')
# Total sentences: 825
#   0%|                                                   | 0/825 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=423,141429923173682938).pkl
# len(self.cache["hashes"]) = 102464
# self.cache["embeddings"].shape = (102464, 128)
# 100%|███████████████████████████████████████| 825/825 [00:00<00:00, 3948.85it/s]
# embeddings.shape: (825, 128)
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (102, 128)
# train_h_ent_embeddings.shape: (102, 128)
# train_p_con_embeddings.shape: (98, 128)
# train_h_con_embeddings.shape: (98, 128)
# train_ent_cosine_sim.shape: (102,)
# train_con_cosine_sim.shape: (98,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 44155.68it/s]
# best_threshold: 0.6245844377292409
# best_acc: 0.9297719087635055
# best_ent_acc: 0.9411764705882353
# best_con_acc: 0.9183673469387755
# --------------
# Evaluating on RadNLI test set
# test_p_ent_embeddings.shape: (102, 128)
# test_h_ent_embeddings.shape: (102, 128)
# test_p_con_embeddings.shape: (98, 128)
# test_h_con_embeddings.shape: (98, 128)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 0.9411764705882353
# contradiction_acc: 0.9183673469387755
# test_acc: 0.9297719087635055
# --------------
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (141, 128)
# train_h_ent_embeddings.shape: (141, 128)
# train_p_con_embeddings.shape: (220, 128)
# train_h_con_embeddings.shape: (220, 128)
# train_ent_cosine_sim.shape: (141,)
# train_con_cosine_sim.shape: (220,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 43599.38it/s]
# best_threshold: 0.8487064852728858
# best_acc: 0.9499032882011605
# best_ent_acc: 0.9361702127659575
# best_con_acc: 0.9636363636363636
# --------------
# Evaluating on MS-CXR-T Temporal Sentence Similarity v1
# test_p_ent_embeddings.shape: (141, 128)
# test_h_ent_embeddings.shape: (141, 128)
# test_p_con_embeddings.shape: (220, 128)
# test_h_con_embeddings.shape: (220, 128)
# test_ent_cosine_sim.shape: (141,)
# test_con_cosine_sim.shape: (220,)
# entailment_acc: 0.9361702127659575
# contradiction_acc: 0.9636363636363636
# test_acc: 0.9499032882011605
# --------------

# %%
# !python ../eval_NLI_v2.py \
--huggingface_model_name "microsoft/BiomedVLP-CXR-BERT-specialized" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20231004_174626_MIMIC-CXR(triplets+classif+entcont+nli+radgraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/" \
--device "GPU" \
--batch_size 100 \
--num_workers 3 \
--integrated_nli_jsonl_filepath \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(162036,21465751).jsonl"
# Out:
# script's arguments:
#    huggingface_model_name: microsoft/BiomedVLP-CXR-BERT-specialized
#    model_name: None
#    model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20231004_174626_MIMIC-CXR(triplets+classif+entcont+nli+radgraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/
#    device: GPU
#    batch_size: 100
#    num_workers: 3
#    integrated_nli_jsonl_filepath: /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(162036,21465751).jsonl
#    similarity_metric: cosine
#    average_token_embeddings: False
#    calibrate_on_test_set: False
# checkpoint_names = ['checkpoint_50_cacc+chf1+chf1+cscc+encc+hscc+nlcc+spss+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9373.pt']
# Train entailment pairs: 26442
# Train contradiction pairs: 95777
# Example train entailment pairs:
# ('In comparison with the study of , there is enlargement of the cardiac silhouette no evidence of congestive failure, pneumonia, or acute focal pneumonia.', "The patient's heart is larger than in the previous study but there are no signs of congestive failure, pneumonia, or acute focal pneumonia.")
# ('Evaluation for subtle superimposed pneumonia is limited.', 'The diagnosis of superimposed pneumonia is not definitive.')
# ('After this her PCW pressure dropped to 15.', ' Her pulmonary wedge pressure dropped to within normal range ')
# ('Also complains of "full body pain" from her fall the other day.', ' The patient has pain complaints. ')
# Example train contradiction pairs:
# ('The left apical lesion has decreased in size since the last chest radiographs.', 'The left apical lesion is also larger today than it was on subsequent conventional chest radiographs, more likely infectious.')
# ('Moderate right pleural effusion and small left pleural effusion are unchanged.', 'There is no moderate right pleural effusion and small left pleural effusion.')
# ('A left pleural pigtail catheter is unchanged in position in the left lung base.', 'A left basilar pigtail the chest tube remains in place with a large pneumothorax, increased from prior.')
# ('There is mild shift of the mediastinal structures towards the left.', 'There is mild shift of the mediastinal structures towards the right.')
# Test radnli entailment pairs: 102
# Test radnli contradiction pairs: 98
# Example test radnli entailment pairs:
# ('The pulmonary vasculature is not engorged.', 'Pulmonary vascularity is not engorged.')
# ('Lungs are clear.', 'The lungs are unremarkable.')
# ('No focal consolidation, pleural effusion, or pneumothorax is detected.', 'No pneumothorax.')
# ('No focal consolidation, pleural effusion, or pneumothorax.', 'No pneumothorax seen.')
# Example test radnli contradiction pairs:
# ('The heart appears mildly enlarged.', 'The heart and mediastinal contours are normal.')
# ('No pleural effusion or pneumothorax is clearly noted on this supine exam, though the left costophrenic angle is not completely included in the field of view.', 'The costophrenic angles are not fully included on the image and pleural effusions are difficult to exclude.')
# ('There is no pleural effusion or pneumothorax.', 'There is evidence of a right pleural effusion.')
# ('No pleural effusions.', 'The small bilateral pleural effusions are unchanged in size.')
# Test mscxrt entailment pairs: 141
# Test mscxrt contradiction pairs: 220
# Example test mscxrt entailment pairs:
# ('interval worsening of the right - sided pneumothorax.', 'interval increase of the right - sided pneumothorax.')
# ('mild improvement in right upper lung opacity, possibly a hematoma, status post right upper lobe resection.', 'mild decrease in right upper lung opacity, possibly a hematoma, status post right upper lobe resection.')
# ('Loculated left pneumothorax is unchanged.', 'The loculated left pneumothorax is not significantly changed.')
# ('there has been improvement in the pulmonary vascular congestion', 'there has been decrease in the pulmonary vascular congestion')
# Example test mscxrt contradiction pairs:
# ('As compared to the previous image, the right upper lobe pneumonia is unchanged.', 'Likely developing right upper lobe pneumonia.')
# ('there is interval decrease in right pleural effusion.', 'there is interval increase in right pleural effusion.')
# ('The pre-existing opacity at the level of the right upper lobe is decreasing in extent and severity.', 'The right upper lobe opacity is stable in extent and severity.')
# ('small - to - moderate right pleural effusion has decreased.', 'small - to - moderate right pleural effusion has increased.')
# Total sentences: 102464
#   0%|                                                | 0/102464 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=423,3677907674814022869).pkl
# len(self.cache["hashes"]) = 42198
# self.cache["embeddings"].shape = (42198, 128)
# 100%|███████████████████████████████| 102464/102464 [00:00<00:00, 498406.16it/s]
# Computing embeddings for 102087 new texts
# Explicitly passing a `revision` is encouraged when loading a configuration with custom code to ensure no malicious code has been contributed in a newer revision.
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# checkpoint_names = ['checkpoint_50_cacc+chf1+chf1+cscc+encc+hscc+nlcc+spss+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9373.pt']
# Loading model weights from /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20231004_174626_MIMIC-CXR(triplets+classif+entcont+nli+radgraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/checkpoint_50_cacc+chf1+chf1+cscc+encc+hscc+nlcc+spss+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9373.pt
# Warning: model state dict has 211 keys, loaded state dict has 232 keys, intersection has 211 keys, union has 232 keys.
# Examples of keys in loaded state dict but not in model:
#   nli_hidden_layer.weight
#   chest_imagenome_anatloc_classifier.weight
#   nli_classifier.weight
#   category_classifier.weight
#   spert_entity_classifier.bias
#   health_status_classifier.bias
#   health_status_classifier.weight
#   aux_task_hidden_layer.weight
#   chest_imagenome_anatloc_classifier.bias
#   spert_rel_classifier.bias
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# 100%|███████████████████████████████████████| 1021/1021 [02:01<00:00,  8.37it/s]
# Saving updated cache to /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=423,3677907674814022869).pkl
# 100%|███████████████████████████████| 102087/102087 [00:00<00:00, 667445.92it/s]
# embeddings.shape: (102464, 128)
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (26442, 128)
# train_h_ent_embeddings.shape: (26442, 128)
# train_p_con_embeddings.shape: (95777, 128)
# train_h_con_embeddings.shape: (95777, 128)
# train_ent_cosine_sim.shape: (26442,)
# train_con_cosine_sim.shape: (95777,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 11399.83it/s]
# best_threshold: 0.4912829340637863
# best_acc: 0.8929471116730681
# best_ent_acc: 0.9556009379018229
# best_con_acc: 0.8302932854443134
# --------------
# Evaluating on RadNLI test set
# test_p_ent_embeddings.shape: (102, 128)
# test_h_ent_embeddings.shape: (102, 128)
# test_p_con_embeddings.shape: (98, 128)
# test_h_con_embeddings.shape: (98, 128)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 0.9607843137254902
# contradiction_acc: 0.8163265306122449
# test_acc: 0.8885554221688676
# --------------
# --------------
# Evaluating on MS-CXR-T Temporal Sentence Similarity v1
# test_p_ent_embeddings.shape: (141, 128)
# test_h_ent_embeddings.shape: (141, 128)
# test_p_con_embeddings.shape: (220, 128)
# test_h_con_embeddings.shape: (220, 128)
# test_ent_cosine_sim.shape: (141,)
# test_con_cosine_sim.shape: (220,)
# entailment_acc: 1.0
# contradiction_acc: 0.6136363636363636
# test_acc: 0.8068181818181819
# --------------

# %%
# !python ../eval_NLI_v2.py \
--huggingface_model_name "microsoft/BiomedVLP-CXR-BERT-specialized" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20231004_174626_MIMIC-CXR(triplets+classif+entcont+nli+radgraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/" \
--device "GPU" \
--batch_size 100 \
--num_workers 3 \
--calibrate_on_test_set
# Out:
# script's arguments:
#    huggingface_model_name: microsoft/BiomedVLP-CXR-BERT-specialized
#    model_name: None
#    model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20231004_174626_MIMIC-CXR(triplets+classif+entcont+nli+radgraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/
#    device: GPU
#    batch_size: 100
#    num_workers: 3
#    integrated_nli_jsonl_filepath: None
#    similarity_metric: cosine
#    average_token_embeddings: False
#    calibrate_on_test_set: True
# checkpoint_names = ['checkpoint_50_cacc+chf1+chf1+cscc+encc+hscc+nlcc+spss+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9373.pt']
# Test radnli entailment pairs: 102
# Test radnli contradiction pairs: 98
# Example test radnli entailment pairs:
# ('No acute osseous abnormalities are visualized.', 'No acute osseous abnormality seen.')
# ('The lungs are clear without consolidation, effusion, or pneumothorax.', 'No pneumothorax is identified.')
# ('The lungs are clear without focal consolidation, pleural effusion or pneumothorax.', 'There are no pleural effusions.')
# ('The lungs are clear.', 'The lungs are clear without focal consolidation.')
# Example test radnli contradiction pairs:
# ('Mild pulmonary edema is redemonstrated, stable since prior chest x-ray.', 'No pulmonary edema is seen.')
# ('There is no pleural effusion or pneumothorax.', 'Interval placement of right-sided chest tube with apparent resolution of right pleural effusion but development of a small pneumothorax.')
# ('There is no focal consolidation, pleural effusion or pneumothorax.', 'Small left pleural effusion is difficult to exclude.')
# ('A small residual right effusion is present.', 'No pleural effusion or pneumothorax is seen.')
# Test mscxrt entailment pairs: 141
# Test mscxrt contradiction pairs: 220
# Example test mscxrt entailment pairs:
# ('subsegmental atelectasis at the left lung base has worsened.', 'subsegmental atelectasis at the left lung base has increased.')
# ('stable size of right apical pneumothorax.', 'unchanged size of right apical pneumothorax.')
# ('right apical linear opacity is unchanged.', 'right apical linear opacity is stable.')
# ('Small right pneumothorax is minimally bigger than on ___ chest radiograph.', 'Small right pneumothorax has minimally increased.')
# Example test mscxrt contradiction pairs:
# ('Pulmonary edema is substantial, unchanged.', 'In comparison with the study of ___, there has been substantial increase in the degree of pulmonary edema.')
# ('Small right pneumothorax has developed at the base of the right lung.', 'Small pneumothorax at the base of the right lung is unchanged.')
# ('stable small left pleural effusion.', 'new small left pleural effusion.')
# ('There is improvement of the pulmonary interstitial edema.', 'Interstitial pulmonary edema, increased since the prior study.')
# Total sentences: 825
#   0%|                                                   | 0/825 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=423,3677907674814022869).pkl
# len(self.cache["hashes"]) = 144285
# self.cache["embeddings"].shape = (144285, 128)
# 100%|███████████████████████████████████████| 825/825 [00:00<00:00, 3523.96it/s]
# embeddings.shape: (825, 128)
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (102, 128)
# train_h_ent_embeddings.shape: (102, 128)
# train_p_con_embeddings.shape: (98, 128)
# train_h_con_embeddings.shape: (98, 128)
# train_ent_cosine_sim.shape: (102,)
# train_con_cosine_sim.shape: (98,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 43772.28it/s]
# best_threshold: 0.7437091226930972
# best_acc: 0.9305722288915566
# best_ent_acc: 0.9019607843137255
# best_con_acc: 0.9591836734693877
# --------------
# Evaluating on RadNLI test set
# test_p_ent_embeddings.shape: (102, 128)
# test_h_ent_embeddings.shape: (102, 128)
# test_p_con_embeddings.shape: (98, 128)
# test_h_con_embeddings.shape: (98, 128)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 0.9019607843137255
# contradiction_acc: 0.9591836734693877
# test_acc: 0.9305722288915566
# --------------
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (141, 128)
# train_h_ent_embeddings.shape: (141, 128)
# train_p_con_embeddings.shape: (220, 128)
# train_h_con_embeddings.shape: (220, 128)
# train_ent_cosine_sim.shape: (141,)
# train_con_cosine_sim.shape: (220,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 43730.75it/s]
# best_threshold: 0.8839709950877619
# best_acc: 0.9489039329464861
# best_ent_acc: 0.9432624113475178
# best_con_acc: 0.9545454545454546
# --------------
# Evaluating on MS-CXR-T Temporal Sentence Similarity v1
# test_p_ent_embeddings.shape: (141, 128)
# test_h_ent_embeddings.shape: (141, 128)
# test_p_con_embeddings.shape: (220, 128)
# test_h_con_embeddings.shape: (220, 128)
# test_ent_cosine_sim.shape: (141,)
# test_con_cosine_sim.shape: (220,)
# entailment_acc: 0.9432624113475178
# contradiction_acc: 0.9545454545454546
# test_acc: 0.9489039329464861
# --------------

# %%
# !python ../eval_NLI_v2.py \
--huggingface_model_name "microsoft/BiomedVLP-CXR-BERT-specialized" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240129_213433_MIMIC-CXR(triplets+classif+entcont+nli+radgraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)" \
--device "GPU" \
--batch_size 100 \
--num_workers 3 \
--integrated_nli_jsonl_filepath \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(169025,21838032).jsonl"
# Out:
# script's arguments:
#    huggingface_model_name: microsoft/BiomedVLP-CXR-BERT-specialized
#    model_name: None
#    model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240129_213433_MIMIC-CXR(triplets+classif+entcont+nli+radgraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)
#    device: GPU
#    batch_size: 100
#    num_workers: 3
#    integrated_nli_jsonl_filepath: /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(169025,21838032).jsonl
#    similarity_metric: cosine
#    average_token_embeddings: False
#    calibrate_on_test_set: False
# checkpoint_names = ['checkpoint_184_cacc+chf1+chf1+cscc+encc+hscc+nlcc+spss+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9569.pt']
# Train entailment pairs: 25175
# Train contradiction pairs: 99121
# Example train entailment pairs:
# ('The lungs are grossly clear without consolidation, effusion, or pneumothorax.', 'No pneumothorax identified now.')
# ('There are clips from prior cholecystectomy in the right upper quadrant of the abdomen.', 'Surgical clips are again noted in the right upper quadrant of the abdomen.')
# ('Normal hilar and mediastinal structures on both the frontal and the lateral view.', 'The hila mediastinum are within normal limits.')
# ('During admission, patient was noted to have acute renal failure on top of CRI secondary to multiple myeloma.', ' the patient has acute renal failure')
# Example train contradiction pairs:
# ('There is a presence of a lung infection and abnormalities in the cardiomediastinal silhouette.', 'Lungs are clear, the cardiomediastinal silhouette and hila are normal.')
# ('There is no eventration of the right hemidiaphragm.', 'the eventration of the right hemidiaphragm is again seen.')
# ('There is a new moderate right-sided pneumothorax.', 'The lungs are fully inflated without any pneumothorax.')
# ('Worsening left retrocardiac opacity may reflect either atelectasis or developing pneumonia.', "The patient's left retrocardiac opacity has improved, suggesting recovery from atelectasis or pneumonia.")
# Test radnli entailment pairs: 102
# Test radnli contradiction pairs: 98
# Example test radnli entailment pairs:
# ('The lungs are clear without focal consolidation.', 'There is no focal consolidation to suggest pneumonia.')
# ('Imaged osseous structures are intact.', 'No acute osseous abnormality detected.')
# ('There are low lung volumes, though allowing for this, the lungs are clear bilaterally with no focal consolidation, effusion, or pneumothorax.', 'No pleural effusion or pneumothorax is seen.')
# ('The heart is not enlarged.', 'The cardiac silhouette is top normal.')
# Example test radnli contradiction pairs:
# ('Allowing for these limitation, there are no focal parenchymal opacities.', 'Since the prior radiograph, no significant change in the widespread parenchymal opacities and moderate cardiomegaly.')
# ('There are unchanged small bilateral layering pleural effusions.', 'No pleural effusion or pneumothorax is seen on this supine exam.')
# ('Dense retrocardiac opacification persists, consistent with left lower lobe consolidation and small pleural effusion.', 'No pleural effusion or pneumothorax is seen.')
# ('Small right pleural effusion, similar.', 'There is no pleural effusion or pneumothorax.')
# Test mscxrt entailment pairs: 141
# Test mscxrt contradiction pairs: 220
# Example test mscxrt entailment pairs:
# ('linear atelectasis of the left lung base has improved since yesterday.', 'linear atelectasis of the left lung base has decreased since yesterday.')
# ('slightly increased moderate pulmonary edema.', 'slightly worsened moderate pulmonary edema.')
# ('stable size of right apical pneumothorax.', 'unchanged size of right apical pneumothorax.')
# ('right mid lung opacity has slightly improved.', 'right mid lung opacity has slightly decreased.')
# Example test mscxrt contradiction pairs:
# ('retrocardiac atelectasis is constant.', 'retrocardiac atelectasis is new.')
# ('there is also improvement in pulmonary edema.', 'there is also increase in pulmonary edema.')
# ('Interval decrease in size of a small left apical pneumothorax which is barely seen on the current examination.', 'Interval increase in size of a small left apical pneumothorax.')
# ('there has been improvement in the pulmonary vascular congestion', 'there has been increase in the pulmonary vascular congestion')
# Total sentences: 98658
#   0%|                                                 | 0/98658 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=424,3351509109300070142).pkl
# len(self.cache["hashes"]) = 2412
# self.cache["embeddings"].shape = (2412, 128)
# 100%|█████████████████████████████████| 98658/98658 [00:00<00:00, 354484.05it/s]
# Computing embeddings for 98275 new texts
# Explicitly passing a `revision` is encouraged when loading a configuration with custom code to ensure no malicious code has been contributed in a newer revision.
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# checkpoint_names = ['checkpoint_184_cacc+chf1+chf1+cscc+encc+hscc+nlcc+spss+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9569.pt']
# Loading model weights from /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240129_213433_MIMIC-CXR(triplets+classif+entcont+nli+radgraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/checkpoint_184_cacc+chf1+chf1+cscc+encc+hscc+nlcc+spss+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9569.pt
# Warning: model state dict has 211 keys, loaded state dict has 232 keys, intersection has 211 keys, union has 232 keys.
# Examples of keys in loaded state dict but not in model:
#   chest_imagenome_anatloc_classifier.weight
#   chest_imagenome_anatloc_classifier.bias
#   aux_task_hidden_layer.bias
#   health_status_classifier.weight
#   comparison_status_classifier.weight
#   spert_rel_classifier.weight
#   spert_entity_classifier.bias
#   chest_imagenome_obs_classifier.bias
#   category_classifier.weight
#   spert_entity_classifier.weight
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# 100%|█████████████████████████████████████████| 983/983 [02:26<00:00,  6.73it/s]
# Saving updated cache to /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=424,3351509109300070142).pkl
# 100%|█████████████████████████████████| 98275/98275 [00:00<00:00, 431869.02it/s]
# embeddings.shape: (98658, 128)
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (25175, 128)
# train_h_ent_embeddings.shape: (25175, 128)
# train_p_con_embeddings.shape: (99121, 128)
# train_h_con_embeddings.shape: (99121, 128)
# train_ent_cosine_sim.shape: (25175,)
# train_con_cosine_sim.shape: (99121,)
# 100%|█████████████████████████████████████| 1000/1000 [00:00<00:00, 6746.91it/s]
# best_threshold: 0.43145271249719563
# best_acc: 0.8911914667364065
# best_ent_acc: 0.9521350546176762
# best_con_acc: 0.8302478788551366
# --------------
# Evaluating on RadNLI test set
# test_p_ent_embeddings.shape: (102, 128)
# test_h_ent_embeddings.shape: (102, 128)
# test_p_con_embeddings.shape: (98, 128)
# test_h_con_embeddings.shape: (98, 128)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 0.9901960784313726
# contradiction_acc: 0.8979591836734694
# test_acc: 0.944077631052421
# --------------
# --------------
# Evaluating on MS-CXR-T Temporal Sentence Similarity v1
# test_p_ent_embeddings.shape: (141, 128)
# test_h_ent_embeddings.shape: (141, 128)
# test_p_con_embeddings.shape: (220, 128)
# test_h_con_embeddings.shape: (220, 128)
# test_ent_cosine_sim.shape: (141,)
# test_con_cosine_sim.shape: (220,)
# entailment_acc: 1.0
# contradiction_acc: 0.5909090909090909
# test_acc: 0.7954545454545454
# --------------

# %%
# !python ../eval_NLI_v2.py \
--huggingface_model_name "microsoft/BiomedVLP-CXR-BERT-specialized" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240129_213433_MIMIC-CXR(triplets+classif+entcont+nli+radgraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)" \
--device "GPU" \
--batch_size 100 \
--num_workers 3 \
--calibrate_on_test_set
# Out:
# script's arguments:
#    huggingface_model_name: microsoft/BiomedVLP-CXR-BERT-specialized
#    model_name: None
#    model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240129_213433_MIMIC-CXR(triplets+classif+entcont+nli+radgraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)
#    device: GPU
#    batch_size: 100
#    num_workers: 3
#    integrated_nli_jsonl_filepath: None
#    similarity_metric: cosine
#    average_token_embeddings: False
#    calibrate_on_test_set: True
# checkpoint_names = ['checkpoint_184_cacc+chf1+chf1+cscc+encc+hscc+nlcc+spss+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9569.pt']
# Test radnli entailment pairs: 102
# Test radnli contradiction pairs: 98
# Example test radnli entailment pairs:
# ('Opacities involving the right middle lobe and left lower lobe are again demonstrated and may represent atelectasis or infection in the appropriate setting.', 'Minimal left basilar opacity suggests minor atelectasis.')
# ('Atelectasis within the left lung base is noted, but no focal consolidation, pleural effusion or pneumothorax is present.', 'Streaky atelectasis is seen at the left lung base.')
# ('No discrete consolidation, pleural effusion, pneumothorax, or pulmonary edema is identified.', 'No pleural effusions.')
# ('The cardiomediastinal silhouette and contour are within normal limits.', 'The cardiomediastinal silhouette is normal.')
# Example test radnli contradiction pairs:
# ('There are unchanged small bilateral layering pleural effusions.', 'No pleural effusion or pneumothorax is seen on this supine exam.')
# ('The left apical pneumothorax is likely unchanged.', 'No pleural effusion or pneumothorax is present.')
# ('Dense retrocardiac opacification persists, consistent with left lower lobe consolidation and small pleural effusion.', 'No pleural effusion or pneumothorax is seen.')
# ('The heart is mildly enlarged, unchanged.', 'The heart is top normal in size, which is exaggerated by the low lung volumes.')
# Test mscxrt entailment pairs: 141
# Test mscxrt contradiction pairs: 220
# Example test mscxrt entailment pairs:
# ('moderate left lower lobe atelectasis has worsened.', 'moderate left lower lobe atelectasis has increased.')
# ('there is interval decrease in right pleural effusion.', 'there is interval improvement in right pleural effusion.')
# ('stable moderate - sized loculated left pleural effusion.', 'unchanged moderate - sized loculated left pleural effusion.')
# ('Interval decrease in the opacities at the right lung base.', 'Interval improvement of right lung base opacities.')
# Example test mscxrt contradiction pairs:
# ('interval decrease in right pleural effusion.', 'interval increase in right pleural effusion.')
# ('severely atelectatic left lower lobe is unchanged.', 'severely atelectatic left lower lobe is new.')
# ('bibasilar retrocardiac atelectasis is unchanged.', 'bibasilar retrocardiac atelectasis is new.')
# ('As compared to previous study from earlier the same date, a right pneumothorax has increased in size and is now moderate.', 'Compared to ___ at 09:30, there is a moderate right pneumothorax that is unchanged in size.')
# Total sentences: 825
#   0%|                                                   | 0/825 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=424,3351509109300070142).pkl
# len(self.cache["hashes"]) = 100687
# self.cache["embeddings"].shape = (100687, 128)
# 100%|███████████████████████████████████████| 825/825 [00:00<00:00, 2194.83it/s]
# embeddings.shape: (825, 128)
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (102, 128)
# train_h_ent_embeddings.shape: (102, 128)
# train_p_con_embeddings.shape: (98, 128)
# train_h_con_embeddings.shape: (98, 128)
# train_ent_cosine_sim.shape: (102,)
# train_con_cosine_sim.shape: (98,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 27531.44it/s]
# best_threshold: 0.6133114415126759
# best_acc: 0.9550820328131252
# best_ent_acc: 0.9509803921568627
# best_con_acc: 0.9591836734693877
# --------------
# Evaluating on RadNLI test set
# test_p_ent_embeddings.shape: (102, 128)
# test_h_ent_embeddings.shape: (102, 128)
# test_p_con_embeddings.shape: (98, 128)
# test_h_con_embeddings.shape: (98, 128)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 0.9509803921568627
# contradiction_acc: 0.9591836734693877
# test_acc: 0.9550820328131252
# --------------
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (141, 128)
# train_h_ent_embeddings.shape: (141, 128)
# train_p_con_embeddings.shape: (220, 128)
# train_h_con_embeddings.shape: (220, 128)
# train_ent_cosine_sim.shape: (141,)
# train_con_cosine_sim.shape: (220,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 25959.83it/s]
# best_threshold: 0.8589229352242713
# best_acc: 0.9850902643455834
# best_ent_acc: 0.9929078014184397
# best_con_acc: 0.9772727272727273
# --------------
# Evaluating on MS-CXR-T Temporal Sentence Similarity v1
# test_p_ent_embeddings.shape: (141, 128)
# test_h_ent_embeddings.shape: (141, 128)
# test_p_con_embeddings.shape: (220, 128)
# test_h_con_embeddings.shape: (220, 128)
# test_ent_cosine_sim.shape: (141,)
# test_con_cosine_sim.shape: (220,)
# entailment_acc: 0.9929078014184397
# contradiction_acc: 0.9772727272727273
# test_acc: 0.9850902643455834
# --------------

# %% [markdown]
# # CXR Fact Embedding (T -> T+SD)

# %%
# !python ../eval_NLI_v2.py \
--huggingface_model_name "microsoft/BiomedVLP-CXR-BERT-specialized" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20231010_210936_MIMIC-CXR(triplets+autoencoder)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/" \
--device "GPU" \
--batch_size 100 \
--num_workers 3 \
--integrated_nli_jsonl_filepath \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(162036,21465751).jsonl"
# Out:
# script's arguments:
#    huggingface_model_name: microsoft/BiomedVLP-CXR-BERT-specialized
#    model_name: None
#    model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20231010_210936_MIMIC-CXR(triplets+autoencoder)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/
#    device: GPU
#    batch_size: 100
#    num_workers: 3
#    integrated_nli_jsonl_filepath: /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(162036,21465751).jsonl
#    similarity_metric: cosine
#    average_token_embeddings: False
#    calibrate_on_test_set: False
# checkpoint_names = ['checkpoint_166_sass+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9026.pt']
# Train entailment pairs: 26442
# Train contradiction pairs: 95777
# Example train entailment pairs:
# ('Mild pulmonary edema, small right pleural effusion, and mediastinal venous engorgement are new suggesting volume overload.', 'Moderate cardiomegaly is stable, but mediastinal venous engorgement also attests to volume overload.')
# ('Mediastinal drain and right chest tube are unchanged in position.', 'Mediastinal drainage catheter still in place.')
# ('Bilateral perihilar and right basilar opacities could relate to fluid overload although atypical infection is not excluded.', "The patient's chest X-ray shows signs of possible fluid overload or infection.")
# ('Streaky left perihilar opacity could represent atypical infection.', 'Left perihilar opacity raises concern for infection.')
# Example train contradiction pairs:
# ('The Port-A-Cath has been removed from the left side.', 'Left-sided Port-A-Cath is re- demonstrated with tip in the proximal right atrium, unchanged.')
# ('Mild degenerative changes are similar.', 'Mild regenerative changes are similar.')
# ('There is destruction of the left sixth rib associated with the mass.', 'The left sixth rib is intact and shows no signs of destruction.')
# ('The previously seen granulomas in the right lung apex are unchanged.', 'The previously seen granulomas in the right lung apex have decreased in size.')
# Test radnli entailment pairs: 102
# Test radnli contradiction pairs: 98
# Example test radnli entailment pairs:
# ('The mediastinal silhouette, hilar contours, and pleural surfaces are normal.', 'The hilar and mediastinal silhouettes are unremarkable.')
# ('The cardiomediastinal silhouette is normal.', 'The cardiomediastinal silhouette and contour are within normal limits.')
# ('Widespread pulmonary opacities appear slightly more confluent at the right lung base, though there is slightly improved aeration in the retrocardiac region.', 'There are likely patchy opacities in the lung bases reflective of atelectasis.')
# ('The pulmonary vasculature is not engorged.', 'Pulmonary vascularity is not engorged.')
# Example test radnli contradiction pairs:
# ('Lung volumes are low, and the cardiac silhouette is enlarged.', 'Cardiac silhouette is normal in size.')
# ('Small bilateral pleural effusions are noted.', 'No right-sided pleural effusion is seen.')
# ('No pleural effusion or pneumothorax is seen.', 'There is a small pneumothorax in the left apex.')
# ('There is no pleural effusion or pulmonary edema.', 'Small right pleural effusion has decreased.')
# Test mscxrt entailment pairs: 141
# Test mscxrt contradiction pairs: 220
# Example test mscxrt entailment pairs:
# ('Stable appearance of moderate pulmonary edema since ___.', 'Stable, moderate pulmonary edema.')
# ('Increasing right effusion.', 'Increasing effusion on the right.')
# ('Since ___, the left lower lobe has been collapsed.', 'Left lower lobe remains collapsed.')
# ('right mid lung opacity has slightly improved.', 'right mid lung opacity has slightly decreased.')
# Example test mscxrt contradiction pairs:
# ('small left effusion has minimally increased.', 'small left effusion has minimally decreased.')
# ('pulmonary edema has improved.', 'pulmonary edema has worsened.')
# ('Moderate bibasilar atelectasis is improved on the right, worsened on the left.', 'Moderate bibasilar atelectasis stable on the right, improved on the left.')
# ('there has been interval improvement in the mild interstitial edema.', 'there has been interval increase in the mild interstitial edema.')
# Total sentences: 102464
#   0%|                                                | 0/102464 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=372,2533955929466572136).pkl
# len(self.cache["hashes"]) = 42198
# self.cache["embeddings"].shape = (42198, 128)
# 100%|███████████████████████████████| 102464/102464 [00:00<00:00, 480682.41it/s]
# Computing embeddings for 102087 new texts
# Explicitly passing a `revision` is encouraged when loading a configuration with custom code to ensure no malicious code has been contributed in a newer revision.
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# checkpoint_names = ['checkpoint_166_sass+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9026.pt']
# Loading model weights from /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20231010_210936_MIMIC-CXR(triplets+autoencoder)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/checkpoint_166_sass+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9026.pt
# Warning: model state dict has 211 keys, loaded state dict has 237 keys, intersection has 211 keys, union has 237 keys.
# Examples of keys in loaded state dict but not in model:
#   fact_decoder.decoder.layers.0.multihead_attn.in_proj_weight
#   fact_decoder.decoder.layers.0.multihead_attn.out_proj.weight
#   fact_decoder_input_layer.bias
#   fact_decoder.decoder.layers.0.linear1.weight
#   fact_decoder.decoder.layers.0.self_attn.in_proj_weight
#   fact_decoder.decoder.layers.0.multihead_attn.in_proj_bias
#   fact_decoder_embedding_table.weight
#   fact_decoder.decoder.layers.0.norm3.weight
#   fact_decoder.pos_encoder.pe
#   fact_decoder.decoder.layers.0.self_attn.out_proj.bias
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# 100%|███████████████████████████████████████| 1021/1021 [01:58<00:00,  8.60it/s]
# Saving updated cache to /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=372,2533955929466572136).pkl
# 100%|███████████████████████████████| 102087/102087 [00:00<00:00, 643334.15it/s]
# embeddings.shape: (102464, 128)
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (26442, 128)
# train_h_ent_embeddings.shape: (26442, 128)
# train_p_con_embeddings.shape: (95777, 128)
# train_h_con_embeddings.shape: (95777, 128)
# train_ent_cosine_sim.shape: (26442,)
# train_con_cosine_sim.shape: (95777,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 11349.98it/s]
# best_threshold: 0.6289648879039753
# best_acc: 0.5973409843315147
# best_ent_acc: 0.7102337190832766
# best_con_acc: 0.48444824957975297
# --------------
# Evaluating on RadNLI test set
# test_p_ent_embeddings.shape: (102, 128)
# test_h_ent_embeddings.shape: (102, 128)
# test_p_con_embeddings.shape: (98, 128)
# test_h_con_embeddings.shape: (98, 128)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 0.7843137254901961
# contradiction_acc: 0.7959183673469388
# test_acc: 0.7901160464185675
# --------------
# --------------
# Evaluating on MS-CXR-T Temporal Sentence Similarity v1
# test_p_ent_embeddings.shape: (141, 128)
# test_h_ent_embeddings.shape: (141, 128)
# test_p_con_embeddings.shape: (220, 128)
# test_h_con_embeddings.shape: (220, 128)
# test_ent_cosine_sim.shape: (141,)
# test_con_cosine_sim.shape: (220,)
# entailment_acc: 0.9929078014184397
# contradiction_acc: 0.1318181818181818
# test_acc: 0.5623629916183107
# --------------

# %%
# !python ../eval_NLI_v2.py \
--huggingface_model_name "microsoft/BiomedVLP-CXR-BERT-specialized" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20231010_210936_MIMIC-CXR(triplets+autoencoder)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/" \
--device "GPU" \
--batch_size 100 \
--num_workers 3 \
--integrated_nli_jsonl_filepath \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(169025,21838032).jsonl"
# Out:
# script's arguments:
#    huggingface_model_name: microsoft/BiomedVLP-CXR-BERT-specialized
#    model_name: None
#    model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20231010_210936_MIMIC-CXR(triplets+autoencoder)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/
#    device: GPU
#    batch_size: 100
#    num_workers: 3
#    integrated_nli_jsonl_filepath: /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(169025,21838032).jsonl
#    similarity_metric: cosine
#    average_token_embeddings: False
#    calibrate_on_test_set: False
# checkpoint_names = ['checkpoint_166_sass+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9026.pt']
# Train entailment pairs: 25175
# Train contradiction pairs: 99121
# Example train entailment pairs:
# ('A left Port-A-Cath has its tip terminating near the superior cavoatrial junction.', 'The tip of the left Port-A-Cath is located near the superior cavoatrial junction.')
# ('The extensive bilateral parenchymal opacities are constant in appearance.', 'The extensive bilateral parenchymal opacities are constant in appearance.')
# ('Known right upper mediastinal mass, presumably a goiter, that causes substantial narrowing of the tracheal diameter and deviation of the trachea to the left.', "The patient's trachea is deviated to the left due to a mass in the right upper mediastinum, likely a goiter.")
# ('The right-sided PICC line ends at the cavoatrial junction.', 'Right-sided PICC line tip is at the cavoatrial junction.')
# Example train contradiction pairs:
# ('There is right base atelectasis but no pleural effusion.', 'Right base atelectasis with small pleural effusion.')
# ('Multiple pulmonary nodules are seen in the right upper lung.', 'Multiple pulmonary nodules are seen in the left upper lung.')
# ('It is stable since .', 'There has been a significant change since .')
# ('Moderate cardiomegaly and mild pulmonary central vascular congestion without evidence of pulmonary edema.', 'The pulmonary central vascular congestion is severe, not mild.')
# Test radnli entailment pairs: 102
# Test radnli contradiction pairs: 98
# Example test radnli entailment pairs:
# ('The lungs are clear.', 'The lungs are clear without focal consolidation.')
# ('There is no pleural effusion, pneumothorax, or pulmonary vascular congestion.', 'There is no pneumothorax.')
# ('Heart size is top normal.', 'The cardiac silhouette is normal in size.')
# ('The lungs are clear.', 'Allowing for this, the lungs are clear.')
# Example test radnli contradiction pairs:
# ('Interval placement of right-sided chest tube with apparent resolution of right pleural effusion but development of a small pneumothorax.', 'There is no pleural effusion or pneumothorax.')
# ('No pleural effusion or pneumothorax is seen.', 'The right atelectasis and pleural effusion has increased.')
# ('Allowing for these limitation, there are no focal parenchymal opacities.', 'Since the prior radiograph, no significant change in the widespread parenchymal opacities and moderate cardiomegaly.')
# ('There is no pleural effusion or pneumothorax.', 'Pleura: Likely there is a right pleural effusion is well as a small left pleural effusion.')
# Test mscxrt entailment pairs: 141
# Test mscxrt contradiction pairs: 220
# Example test mscxrt entailment pairs:
# ('Right lung consolidations are extensive, similar to previous examination.', 'Extensive consolidation on the right lung is unchanged.')
# ('unchanged mild bilateral pulmonary edema.', 'stable mild bilateral pulmonary edema.')
# ('severely atelectatic left lower lobe is unchanged.', 'severely atelectatic left lower lobe is stable.')
# ('left basal consolidation has slightly improved.', 'left basal consolidation has slightly decreased.')
# Example test mscxrt contradiction pairs:
# ('minimal increase in extent of a pre - existing right pleural effusion.', 'minimal improvement in extent of a pre - existing right pleural effusion.')
# ('minimal increase in extent of a pre - existing right pleural effusion.', 'minimal decrease in extent of a pre - existing right pleural effusion.')
# ('since ___, substantial right lower lobe atelectasis has developed.', 'since ___, substantial right lower lobe atelectasis has resolved.')
# ('however, a 2 - 3 cm post interventional pneumothorax has developed.', 'however, a 2 - 3 cm post interventional pneumothorax has decreased.')
# Total sentences: 98658
#   0%|                                                 | 0/98658 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=372,2533955929466572136).pkl
# len(self.cache["hashes"]) = 146286
# self.cache["embeddings"].shape = (146286, 128)
# 100%|█████████████████████████████████| 98658/98658 [00:00<00:00, 181903.07it/s]
# Computing embeddings for 18445 new texts
# Explicitly passing a `revision` is encouraged when loading a configuration with custom code to ensure no malicious code has been contributed in a newer revision.
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# checkpoint_names = ['checkpoint_166_sass+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9026.pt']
# Loading model weights from /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20231010_210936_MIMIC-CXR(triplets+autoencoder)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/checkpoint_166_sass+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9026.pt
# Warning: model state dict has 211 keys, loaded state dict has 237 keys, intersection has 211 keys, union has 237 keys.
# Examples of keys in loaded state dict but not in model:
#   fact_decoder.W_vocab.bias
#   fact_decoder.pos_encoder.pe
#   fact_decoder.decoder.layers.0.linear2.bias
#   fact_decoder.decoder.layers.0.self_attn.in_proj_weight
#   fact_decoder.decoder.layers.0.linear2.weight
#   fact_decoder_input_layer.weight
#   fact_decoder.decoder.layers.0.linear1.weight
#   fact_decoder.start_idx
#   fact_decoder.decoder.layers.0.linear1.bias
#   fact_decoder.W_vocab.weight
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# 100%|█████████████████████████████████████████| 185/185 [00:14<00:00, 12.35it/s]
# Saving updated cache to /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=372,2533955929466572136).pkl
# 100%|█████████████████████████████████| 18445/18445 [00:00<00:00, 267832.44it/s]
# embeddings.shape: (98658, 128)
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (25175, 128)
# train_h_ent_embeddings.shape: (25175, 128)
# train_p_con_embeddings.shape: (99121, 128)
# train_h_con_embeddings.shape: (99121, 128)
# train_ent_cosine_sim.shape: (25175,)
# train_con_cosine_sim.shape: (99121,)
# 100%|█████████████████████████████████████| 1000/1000 [00:00<00:00, 4676.21it/s]
# best_threshold: 0.6202552338858862
# best_acc: 0.5930751221809718
# best_ent_acc: 0.6811916583912612
# best_con_acc: 0.5049585859706823
# --------------
# Evaluating on RadNLI test set
# test_p_ent_embeddings.shape: (102, 128)
# test_h_ent_embeddings.shape: (102, 128)
# test_p_con_embeddings.shape: (98, 128)
# test_h_con_embeddings.shape: (98, 128)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 0.8137254901960784
# contradiction_acc: 0.7959183673469388
# test_acc: 0.8048219287715086
# --------------
# --------------
# Evaluating on MS-CXR-T Temporal Sentence Similarity v1
# test_p_ent_embeddings.shape: (141, 128)
# test_h_ent_embeddings.shape: (141, 128)
# test_p_con_embeddings.shape: (220, 128)
# test_h_con_embeddings.shape: (220, 128)
# test_ent_cosine_sim.shape: (141,)
# test_con_cosine_sim.shape: (220,)
# entailment_acc: 0.9929078014184397
# contradiction_acc: 0.10909090909090909
# test_acc: 0.5509993552546744
# --------------

# %%
# !python ../eval_NLI_v2.py \
--huggingface_model_name "microsoft/BiomedVLP-CXR-BERT-specialized" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20231010_210936_MIMIC-CXR(triplets+autoencoder)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/" \
--device "GPU" \
--batch_size 100 \
--num_workers 3 \
--calibrate_on_test_set
# Out:
# script's arguments:
#    huggingface_model_name: microsoft/BiomedVLP-CXR-BERT-specialized
#    model_name: None
#    model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20231010_210936_MIMIC-CXR(triplets+autoencoder)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/
#    device: GPU
#    batch_size: 100
#    num_workers: 3
#    integrated_nli_jsonl_filepath: None
#    similarity_metric: cosine
#    average_token_embeddings: False
#    calibrate_on_test_set: True
# checkpoint_names = ['checkpoint_166_sass+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9026.pt']
# Test radnli entailment pairs: 102
# Test radnli contradiction pairs: 98
# Example test radnli entailment pairs:
# ('There is a tiny right pleural effusion.', 'Trace pleural effusion at the right base.')
# ('Pulmonary vascularity is not engorged.', 'The pulmonary vasculature is not engorged.')
# ('Widespread pulmonary opacities appear slightly more confluent at the right lung base, though there is slightly improved aeration in the retrocardiac region.', 'There are likely patchy opacities in the lung bases reflective of atelectasis.')
# ('No discrete consolidation, pleural effusion, pneumothorax, or pulmonary edema is identified.', 'No pleural effusions.')
# Example test radnli contradiction pairs:
# ('There is no pleural effusion or pneumothorax.', 'Pleura: Likely there is a right pleural effusion is well as a small left pleural effusion.')
# ('The right atelectasis and pleural effusion has increased.', 'There is no focal consolidation, pleural effusion or pneumothorax.')
# ('The lungs are mostly clear aside from mild lower lung atelectasis.', 'The lungs are clear bilaterally.')
# ('No pulmonary edema is seen.', 'Mild pulmonary edema is redemonstrated, stable since prior chest x-ray.')
# Test mscxrt entailment pairs: 141
# Test mscxrt contradiction pairs: 220
# Example test mscxrt entailment pairs:
# ('the widespread bilateral diffuse parenchymal opacities are unchanged.', 'the widespread bilateral diffuse parenchymal opacities are stable.')
# ('bibasal atelectasis is unchanged.', 'bibasal atelectasis is stable.')
# ('bibasal atelectasis has slightly improved in the interim.', 'bibasal atelectasis has slightly decreased in the interim.')
# ('on the right, the amount of pleural effusion is constant and small.', 'on the right, the amount of pleural effusion is unchanged and small.')
# Example test mscxrt contradiction pairs:
# ('stable mild pulmonary edema.', 'new mild pulmonary edema.')
# ('tiny right apical pneumothorax, slightly decreased.', 'tiny right apical pneumothorax, slightly increased.')
# ('minimal increase in the right - sided loculated hydro pneumothorax.', 'minimal decrease in the right - sided loculated hydro pneumothorax.')
# ('A millimetric pneumothorax, that has newly appeared, is now seen on the left.', 'The millimetric left pneumothorax is unchanged.')
# Total sentences: 825
#   0%|                                                   | 0/825 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=372,2533955929466572136).pkl
# len(self.cache["hashes"]) = 144285
# self.cache["embeddings"].shape = (144285, 128)
# 100%|███████████████████████████████████████| 825/825 [00:00<00:00, 3395.03it/s]
# embeddings.shape: (825, 128)
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (102, 128)
# train_h_ent_embeddings.shape: (102, 128)
# train_p_con_embeddings.shape: (98, 128)
# train_h_con_embeddings.shape: (98, 128)
# train_ent_cosine_sim.shape: (102,)
# train_con_cosine_sim.shape: (98,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 44260.52it/s]
# best_threshold: 0.5967385109748927
# best_acc: 0.8191276510604242
# best_ent_acc: 0.8627450980392157
# best_con_acc: 0.7755102040816326
# --------------
# Evaluating on RadNLI test set
# test_p_ent_embeddings.shape: (102, 128)
# test_h_ent_embeddings.shape: (102, 128)
# test_p_con_embeddings.shape: (98, 128)
# test_h_con_embeddings.shape: (98, 128)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 0.8627450980392157
# contradiction_acc: 0.7755102040816326
# test_acc: 0.8191276510604242
# --------------
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (141, 128)
# train_h_ent_embeddings.shape: (141, 128)
# train_p_con_embeddings.shape: (220, 128)
# train_h_con_embeddings.shape: (220, 128)
# train_ent_cosine_sim.shape: (141,)
# train_con_cosine_sim.shape: (220,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 44134.31it/s]
# best_threshold: 0.8691059135579251
# best_acc: 0.7027079303675048
# best_ent_acc: 0.7872340425531915
# best_con_acc: 0.6181818181818182
# --------------
# Evaluating on MS-CXR-T Temporal Sentence Similarity v1
# test_p_ent_embeddings.shape: (141, 128)
# test_h_ent_embeddings.shape: (141, 128)
# test_p_con_embeddings.shape: (220, 128)
# test_h_con_embeddings.shape: (220, 128)
# test_ent_cosine_sim.shape: (141,)
# test_con_cosine_sim.shape: (220,)
# entailment_acc: 0.7872340425531915
# contradiction_acc: 0.6181818181818182
# test_acc: 0.7027079303675048
# --------------

# %% [markdown]
# # CXR Fact Embedding (T -> T+C+EC+NLI+SD)

# %%
# !python ../eval_NLI_v2.py \
--huggingface_model_name "microsoft/BiomedVLP-CXR-BERT-specialized" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20231013_073812_MIMIC-CXR(triplets+classif+entcont+nli+autoencoder)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/" \
--device "GPU" \
--batch_size 100 \
--num_workers 3 \
--integrated_nli_jsonl_filepath \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(162036,21465751).jsonl"
# Out:
# script's arguments:
#    huggingface_model_name: microsoft/BiomedVLP-CXR-BERT-specialized
#    model_name: None
#    model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20231013_073812_MIMIC-CXR(triplets+classif+entcont+nli+autoencoder)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/
#    device: GPU
#    batch_size: 100
#    num_workers: 3
#    integrated_nli_jsonl_filepath: /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(162036,21465751).jsonl
#    similarity_metric: cosine
#    average_token_embeddings: False
#    calibrate_on_test_set: False
# checkpoint_names = ['checkpoint_1_cacc+chf1+chf1+cscc+encc+hscc+nlcc+sass+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9160.pt']
# Train entailment pairs: 26442
# Train contradiction pairs: 95777
# Example train entailment pairs:
# ('Patient is status post bilateral rotator cuff repair.', 'The patient has undergone surgery for both rotator cuffs.')
# ('Peribronchial wall thickening, particularly in the mid to lower lungs, right greater than left, without definite focal consolidation.', "The patient's right lung shows more peribronchial wall thickening than the left lung.")
# ('Calcified nodes and cardiomediastinal contours are unchanged.', 'Mediastinal calcified lymph nodes are unchanged.')
# ('Overall no significant interval change from the most recent exam.', "The patient's chest condition has remained stable since the last examination.")
# Example train contradiction pairs:
# ('Right pneumothorax.', 'The right lung is fully inflated without any signs of pneumothorax.')
# ('Previous cardiomegaly and mediastinal vascular engorgement have resolved.', 'Severe cardiomegaly and mediastinal venous engorgement stable.')
# ('Marked thickening of the right apical pleura may be related to to nodular lung lesions.', "The patient's right apical pleura is normal without any thickening.")
# ('Again there is diffuse bilateral pulmonary opacifications.', 'Interval improvement in bilateral pulmonary opacities.')
# Test radnli entailment pairs: 102
# Test radnli contradiction pairs: 98
# Example test radnli entailment pairs:
# ('No pleural effusion, edema, or pneumothorax.', 'There is no pneumothorax.')
# ('Cardiomediastinal silhouette and hilar contours are unremarkable.', 'Cardiomediastinal and hilar contours are normal.')
# ('The hilar and cardiomediastinal contours are normal.', 'The cardiomediastinal silhouette is normal.')
# ('Lungs are clear.', 'The lungs are clear without focal consolidation.')
# Example test radnli contradiction pairs:
# ('The heart is top normal in size, which is exaggerated by the low lung volumes.', 'The heart is mildly enlarged, unchanged.')
# ('Known small left pneumothorax is not well seen.', 'No pneumothoraces are present.')
# ('There is no pleural effusion or pneumothorax.', 'There is evidence of a right pleural effusion.')
# ('No pleural effusion or pneumothorax is seen.', 'Mild pulmonary vascular congestion is present and probable trace bilateral pleural effusions.')
# Test mscxrt entailment pairs: 141
# Test mscxrt contradiction pairs: 220
# Example test mscxrt entailment pairs:
# ('as a consequence, the basal atelectasis has also increased.', 'as a consequence, the basal atelectasis has also worsened.')
# ('Stable small left pneumothorax.', 'Stable small pneumothorax on the left.')
# ('bibasal consolidations are unchanged.', 'bibasal consolidations are stable.')
# ('there has been interval improvement in the mild interstitial edema.', 'there has been interval decrease in the mild interstitial edema.')
# Example test mscxrt contradiction pairs:
# ('unchanged, tiny left apical pneumothorax.', 'new, tiny left apical pneumothorax.')
# ('There is interval improvement of the right lower lobe atelectasis.', 'Interval worsening of right lower lobe atelectasis.')
# ('small right pleural effusion is unchanged.', 'small right pleural effusion is new.')
# ('Moderately severe pulmonary edema worsened slightly since ___.', 'AP chest compared to ___ through ___: Moderately severe pulmonary edema has improved slightly since ___.')
# Total sentences: 102464
#   0%|                                                | 0/102464 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=425,2776001221282427137).pkl
# len(self.cache["hashes"]) = 42198
# self.cache["embeddings"].shape = (42198, 128)
# 100%|███████████████████████████████| 102464/102464 [00:00<00:00, 494466.62it/s]
# Computing embeddings for 102087 new texts
# Explicitly passing a `revision` is encouraged when loading a configuration with custom code to ensure no malicious code has been contributed in a newer revision.
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# checkpoint_names = ['checkpoint_1_cacc+chf1+chf1+cscc+encc+hscc+nlcc+sass+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9160.pt']
# Loading model weights from /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20231013_073812_MIMIC-CXR(triplets+classif+entcont+nli+autoencoder)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/checkpoint_1_cacc+chf1+chf1+cscc+encc+hscc+nlcc+sass+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9160.pt
# Warning: model state dict has 211 keys, loaded state dict has 253 keys, intersection has 211 keys, union has 253 keys.
# Examples of keys in loaded state dict but not in model:
#   nli_classifier.weight
#   fact_decoder.decoder.layers.0.multihead_attn.out_proj.weight
#   health_status_classifier.weight
#   chest_imagenome_obs_classifier.bias
#   fact_decoder.decoder.layers.0.norm3.bias
#   comparison_status_classifier.bias
#   fact_decoder_input_layer.bias
#   chest_imagenome_obs_classifier.weight
#   chest_imagenome_anatloc_classifier.weight
#   fact_decoder.W_vocab.bias
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# 100%|███████████████████████████████████████| 1021/1021 [02:13<00:00,  7.65it/s]
# Saving updated cache to /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=425,2776001221282427137).pkl
# 100%|███████████████████████████████| 102087/102087 [00:00<00:00, 653339.85it/s]
# embeddings.shape: (102464, 128)
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (26442, 128)
# train_h_ent_embeddings.shape: (26442, 128)
# train_p_con_embeddings.shape: (95777, 128)
# train_h_con_embeddings.shape: (95777, 128)
# train_ent_cosine_sim.shape: (26442,)
# train_con_cosine_sim.shape: (95777,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 11184.63it/s]
# best_threshold: 0.512158183006195
# best_acc: 0.8877694370297209
# best_ent_acc: 0.9579835110808562
# best_con_acc: 0.8175553629785857
# --------------
# Evaluating on RadNLI test set
# test_p_ent_embeddings.shape: (102, 128)
# test_h_ent_embeddings.shape: (102, 128)
# test_p_con_embeddings.shape: (98, 128)
# test_h_con_embeddings.shape: (98, 128)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 0.9509803921568627
# contradiction_acc: 0.8367346938775511
# test_acc: 0.8938575430172069
# --------------
# --------------
# Evaluating on MS-CXR-T Temporal Sentence Similarity v1
# test_p_ent_embeddings.shape: (141, 128)
# test_h_ent_embeddings.shape: (141, 128)
# test_p_con_embeddings.shape: (220, 128)
# test_h_con_embeddings.shape: (220, 128)
# test_ent_cosine_sim.shape: (141,)
# test_con_cosine_sim.shape: (220,)
# entailment_acc: 1.0
# contradiction_acc: 0.509090909090909
# test_acc: 0.7545454545454545
# --------------

# %%
# !python ../eval_NLI_v2.py \
--huggingface_model_name "microsoft/BiomedVLP-CXR-BERT-specialized" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20231013_073812_MIMIC-CXR(triplets+classif+entcont+nli+autoencoder)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/" \
--device "GPU" \
--batch_size 100 \
--num_workers 3 \
--calibrate_on_test_set
# Out:
# script's arguments:
#    huggingface_model_name: microsoft/BiomedVLP-CXR-BERT-specialized
#    model_name: None
#    model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20231013_073812_MIMIC-CXR(triplets+classif+entcont+nli+autoencoder)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/
#    device: GPU
#    batch_size: 100
#    num_workers: 3
#    integrated_nli_jsonl_filepath: None
#    similarity_metric: cosine
#    average_token_embeddings: False
#    calibrate_on_test_set: True
# checkpoint_names = ['checkpoint_1_cacc+chf1+chf1+cscc+encc+hscc+nlcc+sass+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9160.pt']
# Test radnli entailment pairs: 102
# Test radnli contradiction pairs: 98
# Example test radnli entailment pairs:
# ('The pulmonary vascularity is normal.', 'The pulmonary vasculature is normal.')
# ('There is no pleural effusion, pneumothorax, or pulmonary vascular congestion.', 'There is no pneumothorax.')
# ('Severe cardiomegaly and cardiomediastinal hilar silhouettes are unchanged.', 'Cardiomediastinal silhouette is stable.')
# ('No acute osseous abnormality detected.', 'Imaged osseous structures are intact.')
# Example test radnli contradiction pairs:
# ('The costophrenic angles are not fully included on the image and pleural effusions are difficult to exclude.', 'No pleural effusion or pneumothorax is clearly noted on this supine exam, though the left costophrenic angle is not completely included in the field of view.')
# ('A small right pleural effusion cannot be excluded.', 'There is no pleural effusion, pneumothorax, or pulmonary edema.')
# ('There is no pleural effusion or pneumothorax.', 'There is evidence of a right pleural effusion.')
# ('There is no pulmonary edema.', 'There has been improvement in the pulmonary edema, now moderate.')
# Test mscxrt entailment pairs: 141
# Test mscxrt contradiction pairs: 220
# Example test mscxrt entailment pairs:
# ('Substantial decrease in extent of the pre-existing right pleural effusion.', 'As compared to the previous examination, there is a substantial decrease in extent of the known right pleural effusion.')
# ('Moderate pulmonary edema is exaggerated by low lung volumes, but also worsened.', 'Lung volumes are lower exaggerating what is at least worsened moderate pulmonary edema.')
# ('stable size of right apical pneumothorax.', 'unchanged size of right apical pneumothorax.')
# ('Small right pneumothorax is minimally bigger than on ___ chest radiograph.', 'Small right pneumothorax has minimally increased.')
# Example test mscxrt contradiction pairs:
# ('There is some hazy opacity at the right base which is unchanged.', 'In comparison with the study of ___, there is increasing hazy opacification at the right base.')
# ('mild generalized pulmonary edema has improved.', 'mild generalized pulmonary edema has worsened.')
# ('slight decrease in small right pleural effusion.', 'slight increase in small right pleural effusion.')
# ('the minimal left pleural effusion is stable.', 'the minimal left pleural effusion is new.')
# Total sentences: 825
#   0%|                                                   | 0/825 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=425,2776001221282427137).pkl
# len(self.cache["hashes"]) = 144285
# self.cache["embeddings"].shape = (144285, 128)
# 100%|███████████████████████████████████████| 825/825 [00:00<00:00, 3419.01it/s]
# embeddings.shape: (825, 128)
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (102, 128)
# train_h_ent_embeddings.shape: (102, 128)
# train_p_con_embeddings.shape: (98, 128)
# train_h_con_embeddings.shape: (98, 128)
# train_ent_cosine_sim.shape: (102,)
# train_con_cosine_sim.shape: (98,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 43765.89it/s]
# best_threshold: 0.6871704620284005
# best_acc: 0.9354741896758703
# best_ent_acc: 0.9117647058823529
# best_con_acc: 0.9591836734693877
# --------------
# Evaluating on RadNLI test set
# test_p_ent_embeddings.shape: (102, 128)
# test_h_ent_embeddings.shape: (102, 128)
# test_p_con_embeddings.shape: (98, 128)
# test_h_con_embeddings.shape: (98, 128)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 0.9117647058823529
# contradiction_acc: 0.9591836734693877
# test_acc: 0.9354741896758703
# --------------
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (141, 128)
# train_h_ent_embeddings.shape: (141, 128)
# train_p_con_embeddings.shape: (220, 128)
# train_h_con_embeddings.shape: (220, 128)
# train_ent_cosine_sim.shape: (141,)
# train_con_cosine_sim.shape: (220,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 43655.65it/s]
# best_threshold: 0.8821004306947864
# best_acc: 0.9486299161831077
# best_ent_acc: 0.9290780141843972
# best_con_acc: 0.9681818181818181
# --------------
# Evaluating on MS-CXR-T Temporal Sentence Similarity v1
# test_p_ent_embeddings.shape: (141, 128)
# test_h_ent_embeddings.shape: (141, 128)
# test_p_con_embeddings.shape: (220, 128)
# test_h_con_embeddings.shape: (220, 128)
# test_ent_cosine_sim.shape: (141,)
# test_con_cosine_sim.shape: (220,)
# entailment_acc: 0.9290780141843972
# contradiction_acc: 0.9681818181818181
# test_acc: 0.9486299161831077
# --------------

# %%
# !python ../eval_NLI_v2.py \
--huggingface_model_name "microsoft/BiomedVLP-CXR-BERT-specialized" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240129_151525_MIMIC-CXR(triplets+classif+entcont+nli+autoencoder)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)" \
--device "GPU" \
--batch_size 100 \
--num_workers 3 \
--integrated_nli_jsonl_filepath \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(169025,21838032).jsonl"
# Out:
# script's arguments:
#    huggingface_model_name: microsoft/BiomedVLP-CXR-BERT-specialized
#    model_name: None
#    model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240129_151525_MIMIC-CXR(triplets+classif+entcont+nli+autoencoder)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)
#    device: GPU
#    batch_size: 100
#    num_workers: 3
#    integrated_nli_jsonl_filepath: /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(169025,21838032).jsonl
#    similarity_metric: cosine
#    average_token_embeddings: False
#    calibrate_on_test_set: False
# checkpoint_names = ['checkpoint_98_cacc+chf1+chf1+cscc+encc+hscc+nlcc+sass+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9322.pt']
# Train entailment pairs: 25175
# Train contradiction pairs: 99121
# Example train entailment pairs:
# ('There is bilateral bronchial wall thickening, which is consistent with bronchiectasis.', 'The patient shows signs of bronchiectasis.')
# ('No evidence of pneumothorax.', 'The lungs are not collapsed.')
# ('Severe cardiomegaly and dilated pulmonary arteries have improved slightly since suggesting improvement in previous cardiac decompensation.', "The patient's heart enlargement and widened pulmonary arteries have shown some signs of recovery.")
# ('Other mediastinal and hilar contours and pleural surfaces are normal.', 'There are no abnormalities in the mediastinal and hilar contours and pleural surfaces.')
# Example train contradiction pairs:
# ('There is no associated crowding of the central bronchovascular structures.', 'The lung volumes are mildly decreased with associated crowding of the central bronchovascular structures.')
# ('There are slightly high lung volumes on the frontal view.', 'There are slightly low lung volumes on the frontal view.')
# ('Small left pneumothorax cannot be excluded.', 'New is a millimetric pneumothorax on the left.')
# ('In the ED, he was noted to have a Tc of 103.8 (rectally), HR 134, BP 124/74, RR 42, SaO2 88%/NRB.', ' Vitals were within normal limits')
# Test radnli entailment pairs: 102
# Test radnli contradiction pairs: 98
# Example test radnli entailment pairs:
# ('The pulmonary vasculature is not engorged.', 'Pulmonary vascularity is not engorged.')
# ('The cardiac and mediastinal silhouettes are unremarkable.', 'The cardiac silhouette is not enlarged.')
# ('The hilar and cardiomediastinal contours are normal.', 'The cardiomediastinal silhouette is normal.')
# ('There is no pleural effusion, pneumothorax, or pulmonary vascular congestion.', 'Left pleural effusion has also completely resolved.')
# Example test radnli contradiction pairs:
# ('There is no pleural effusion or pneumothorax.', 'Small right pleural effusion, similar.')
# ('The lungs are well expanded and clear.', 'The lungs are otherwise clear.')
# ('Moderate size right pleural effusion is new from the previous radiograph with associated right basilar atelectasis.', 'No pleural abnormality is seen.')
# ('There is no pleural effusion or pneumothorax.', 'A small left pleural effusion may be present.')
# Test mscxrt entailment pairs: 141
# Test mscxrt contradiction pairs: 220
# Example test mscxrt entailment pairs:
# ('mild interstitial edema has worsened.', 'mild interstitial edema has increased.')
# ('possible slight worsening of hazy opacity at right base.', 'possible slight progression of hazy opacity at right base.')
# ('Interstitial pulmonary edema, which has increased slightly since ___.', 'Interstitial pulmonary edema has slightly progressed.')
# ('unchanged moderate to large layering right pleural effusion.', 'stable moderate to large layering right pleural effusion.')
# Example test mscxrt contradiction pairs:
# ('left retrocardiac opacity is unchanged.', 'left retrocardiac opacity is new.')
# ('moderate pleural effusions are larger.', 'moderate pleural effusions are unchanged.')
# ('increasing left retrocardiac atelectasis.', 'stable left retrocardiac atelectasis.')
# ('The pre-existing opacity at the level of the right upper lobe is decreasing in extent and severity.', 'The right upper lobe opacity is stable in extent and severity.')
# Total sentences: 98658
#   0%|                                                 | 0/98658 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=426,3489013806009299070).pkl
# len(self.cache["hashes"]) = 2412
# self.cache["embeddings"].shape = (2412, 128)
# 100%|█████████████████████████████████| 98658/98658 [00:00<00:00, 356799.38it/s]
# Computing embeddings for 98275 new texts
# Explicitly passing a `revision` is encouraged when loading a configuration with custom code to ensure no malicious code has been contributed in a newer revision.
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# checkpoint_names = ['checkpoint_98_cacc+chf1+chf1+cscc+encc+hscc+nlcc+sass+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9322.pt']
# Loading model weights from /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240129_151525_MIMIC-CXR(triplets+classif+entcont+nli+autoencoder)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/checkpoint_98_cacc+chf1+chf1+cscc+encc+hscc+nlcc+sass+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9322.pt
# Warning: model state dict has 211 keys, loaded state dict has 253 keys, intersection has 211 keys, union has 253 keys.
# Examples of keys in loaded state dict but not in model:
#   fact_decoder.decoder.layers.0.norm2.weight
#   health_status_classifier.weight
#   fact_decoder.decoder.layers.0.self_attn.in_proj_bias
#   fact_decoder.decoder.layers.0.multihead_attn.in_proj_bias
#   category_classifier.bias
#   fact_decoder.decoder.layers.0.self_attn.in_proj_weight
#   nli_classifier.weight
#   fact_decoder.W_vocab.weight
#   fact_decoder.decoder.layers.0.multihead_attn.out_proj.weight
#   health_status_classifier.bias
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# 100%|█████████████████████████████████████████| 983/983 [02:39<00:00,  6.17it/s]
# Saving updated cache to /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=426,3489013806009299070).pkl
# 100%|█████████████████████████████████| 98275/98275 [00:00<00:00, 542160.97it/s]
# embeddings.shape: (98658, 128)
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (25175, 128)
# train_h_ent_embeddings.shape: (25175, 128)
# train_p_con_embeddings.shape: (99121, 128)
# train_h_con_embeddings.shape: (99121, 128)
# train_ent_cosine_sim.shape: (25175,)
# train_con_cosine_sim.shape: (99121,)
# 100%|█████████████████████████████████████| 1000/1000 [00:00<00:00, 4844.76it/s]
# best_threshold: 0.47999684624485783
# best_acc: 0.9200837869340219
# best_ent_acc: 0.9662760675273089
# best_con_acc: 0.8738915063407351
# --------------
# Evaluating on RadNLI test set
# test_p_ent_embeddings.shape: (102, 128)
# test_h_ent_embeddings.shape: (102, 128)
# test_p_con_embeddings.shape: (98, 128)
# test_h_con_embeddings.shape: (98, 128)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 0.9901960784313726
# contradiction_acc: 0.8979591836734694
# test_acc: 0.944077631052421
# --------------
# --------------
# Evaluating on MS-CXR-T Temporal Sentence Similarity v1
# test_p_ent_embeddings.shape: (141, 128)
# test_h_ent_embeddings.shape: (141, 128)
# test_p_con_embeddings.shape: (220, 128)
# test_h_con_embeddings.shape: (220, 128)
# test_ent_cosine_sim.shape: (141,)
# test_con_cosine_sim.shape: (220,)
# entailment_acc: 1.0
# contradiction_acc: 0.7045454545454546
# test_acc: 0.8522727272727273
# --------------

# %%
# !python ../eval_NLI_v2.py \
--huggingface_model_name "microsoft/BiomedVLP-CXR-BERT-specialized" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240129_151525_MIMIC-CXR(triplets+classif+entcont+nli+autoencoder)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)" \
--device "GPU" \
--batch_size 100 \
--num_workers 3 \
--calibrate_on_test_set
# Out:
# script's arguments:
#    huggingface_model_name: microsoft/BiomedVLP-CXR-BERT-specialized
#    model_name: None
#    model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240129_151525_MIMIC-CXR(triplets+classif+entcont+nli+autoencoder)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)
#    device: GPU
#    batch_size: 100
#    num_workers: 3
#    integrated_nli_jsonl_filepath: None
#    similarity_metric: cosine
#    average_token_embeddings: False
#    calibrate_on_test_set: True
# checkpoint_names = ['checkpoint_98_cacc+chf1+chf1+cscc+encc+hscc+nlcc+sass+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9322.pt']
# Test radnli entailment pairs: 102
# Test radnli contradiction pairs: 98
# Example test radnli entailment pairs:
# ('The pulmonary vasculature demonstrates an upper zone redistribution pattern, but there is no sign of an advanced interstitial or alveolar edema.', 'There is mild vascular congestion, but no overt pulmonary edema.')
# ('Heart and mediastinal contours appear normal.', 'The cardiomediastinal and hilar contours are within normal limits.')
# ('The lungs are clear without focal consolidation, pleural effusion or pneumothorax.', 'There are no pleural effusions.')
# ('The lungs are clear.', 'Allowing for this, the lungs are clear.')
# Example test radnli contradiction pairs:
# ('There is no pleural effusion or pneumothorax.', 'There is evidence of a right pleural effusion.')
# ('Moderate to large bilateral pleural effusions are again seen, likely right greater than left.', 'There is no pulmonary edema or pleural effusions.')
# ('A small left pleural effusion is also likely present.', 'No pleural effusions.')
# ('There is also increased volume overload, with central venous congestion and interstitial edema.', 'In comparison to ___ portable chest radiograph, there is mild improvement of the pulmonary vascular congestion and bilateral interstitial edema.')
# Test mscxrt entailment pairs: 141
# Test mscxrt contradiction pairs: 220
# Example test mscxrt entailment pairs:
# ('moderate left lower lobe atelectasis has worsened.', 'moderate left lower lobe atelectasis has increased.')
# ('status post right thoracentesis with interval decrease in right pleural effusion, which is now trace in size.', 'status post right thoracentesis with interval improvement in right pleural effusion, which is now trace in size.')
# ('bibasal atelectasis has slightly improved in the interim.', 'bibasal atelectasis has slightly decreased in the interim.')
# ('bibasilar retrocardiac atelectasis is unchanged.', 'bibasilar retrocardiac atelectasis is stable.')
# Example test mscxrt contradiction pairs:
# ('There is interval improvement of vascular congestion.', 'There is interval development of vascular congestion.')
# ('Interval decrease in small bilateral pleural effusions.', 'Interval development of small bilateral pleural effusion, otherwise no interval change.')
# ('Interval worsening of the right-sided pneumothorax.', 'No definite interval change in right-sided pneumothorax with details as above.')
# ('bilateral areas of basilar atelectasis are developing.', 'bilateral areas of basilar atelectasis are unchanged.')
# Total sentences: 825
#   0%|                                                   | 0/825 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=426,3489013806009299070).pkl
# len(self.cache["hashes"]) = 100687
# self.cache["embeddings"].shape = (100687, 128)
# 100%|███████████████████████████████████████| 825/825 [00:00<00:00, 1405.91it/s]
# embeddings.shape: (825, 128)
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (102, 128)
# train_h_ent_embeddings.shape: (102, 128)
# train_p_con_embeddings.shape: (98, 128)
# train_h_con_embeddings.shape: (98, 128)
# train_ent_cosine_sim.shape: (102,)
# train_con_cosine_sim.shape: (98,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 14965.23it/s]
# best_threshold: 0.6541430273571529
# best_acc: 0.9554821928771509
# best_ent_acc: 0.9313725490196079
# best_con_acc: 0.9795918367346939
# --------------
# Evaluating on RadNLI test set
# test_p_ent_embeddings.shape: (102, 128)
# test_h_ent_embeddings.shape: (102, 128)
# test_p_con_embeddings.shape: (98, 128)
# test_h_con_embeddings.shape: (98, 128)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 0.9313725490196079
# contradiction_acc: 0.9795918367346939
# test_acc: 0.9554821928771509
# --------------
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (141, 128)
# train_h_ent_embeddings.shape: (141, 128)
# train_p_con_embeddings.shape: (220, 128)
# train_h_con_embeddings.shape: (220, 128)
# train_ent_cosine_sim.shape: (141,)
# train_con_cosine_sim.shape: (220,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 21617.90it/s]
# best_threshold: 0.8261064126923516
# best_acc: 0.936266924564797
# best_ent_acc: 0.9361702127659575
# best_con_acc: 0.9363636363636364
# --------------
# Evaluating on MS-CXR-T Temporal Sentence Similarity v1
# test_p_ent_embeddings.shape: (141, 128)
# test_h_ent_embeddings.shape: (141, 128)
# test_p_con_embeddings.shape: (220, 128)
# test_h_con_embeddings.shape: (220, 128)
# test_ent_cosine_sim.shape: (141,)
# test_con_cosine_sim.shape: (220,)
# entailment_acc: 0.9361702127659575
# contradiction_acc: 0.9363636363636364
# test_acc: 0.936266924564797
# --------------

# %% [markdown]
# # CXR Fact Embedding (T -> T+C+EC+NLI)

# %%
# !python ../eval_NLI_v2.py \
--huggingface_model_name "microsoft/BiomedVLP-CXR-BERT-specialized" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240207_235928_MIMIC-CXR(triplets+classif+entcont+nli)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)" \
--device "GPU" \
--batch_size 100 \
--num_workers 3 \
--integrated_nli_jsonl_filepath \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(169025,21838032).jsonl"
# Out:
# script's arguments:
#    huggingface_model_name: microsoft/BiomedVLP-CXR-BERT-specialized
#    model_name: None
#    model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240207_235928_MIMIC-CXR(triplets+classif+entcont+nli)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)
#    device: GPU
#    batch_size: 100
#    num_workers: 3
#    integrated_nli_jsonl_filepath: /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(169025,21838032).jsonl
#    similarity_metric: cosine
#    average_token_embeddings: False
#    calibrate_on_test_set: False
# checkpoint_names = ['checkpoint_193_cacc+chf1+chf1+cscc+encc+hscc+nlcc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9472.pt']
# Train entailment pairs: 25175
# Train contradiction pairs: 99121
# Example train entailment pairs:
# ('Stable cardiopulmonary findings when compared to the earlier study on .', "The patient's cardiopulmonary condition has not worsened since the last study.")
# ('No pulmonary edema is observed.', 'There is no evidence of pulmonary edema, lung consolidation, or pneumothorax.')
# ('No signs of atelectasis or lung consolidation.', 'There is no atelectasis or lung consolidation.')
# ('There is no evidence of pneumothorax.', 'The lungs do not show any signs of collapsed air spaces.')
# Example train contradiction pairs:
# ('The left pleural effusion has completely resolved.', 'There is a moderate left pleural effusion with adjacent atelectasis.')
# ('There is prominence of the pulmonary vasculature and predominantly perihilar airspace opacities most consistent with pulmonary edema and infection can be definitively excluded.', 'There is prominence of the pulmonary vasculature and predominantly perihilar airspace opacities most consistent with pulmonary edema however infection cannot be excluded.')
# ('The cardiomediastinal silhouette remains enlarged, and is unchanged.', 'The cardiomediastinal silhouette is not enlarged, but has significantly changed.')
# ('Per NH records and family patient had developed cold-like symptoms [**2-23**] days ago.', ' The patient has been healthy')
# Test radnli entailment pairs: 102
# Test radnli contradiction pairs: 98
# Example test radnli entailment pairs:
# ('Cardiomediastinal silhouette and hilar contours are normal.', 'The cardiac and mediastinal silhouettes are unremarkable.')
# ('There is a tiny right pleural effusion.', 'Trace pleural effusion at the right base.')
# ('The cardiomediastinal and hilar contours are normal.', 'Cardiomediastinal contours are normal.')
# ('The right lung and pleural space and visible mediastinal contours and structures are normal.', 'Cardiomediastinal contours are normal.')
# Example test radnli contradiction pairs:
# ('Interval placement of right-sided chest tube with apparent resolution of right pleural effusion but development of a small pneumothorax.', 'There is no pleural effusion or pneumothorax.')
# ('No pneumothorax.', 'Known small left pneumothorax is not well seen.')
# ('No pneumothoraces are present.', 'Known small left pneumothorax is not well seen.')
# ('There has been improvement in the pulmonary edema, now moderate.', 'There is no pulmonary edema.')
# Test mscxrt entailment pairs: 141
# Test mscxrt contradiction pairs: 220
# Example test mscxrt entailment pairs:
# ('slight interval improvement in moderate widespread pulmonary edema.', 'slight interval decrease in moderate widespread pulmonary edema.')
# ('very small right apical pneumothorax is unchanged.', 'very small right apical pneumothorax is stable.')
# ('mild interstitial edema has worsened.', 'mild interstitial edema has increased.')
# ('small left pleural effusion stable since ___.', 'small left pleural effusion unchanged since ___.')
# Example test mscxrt contradiction pairs:
# ('Left basal opacity has progressed as well.', 'Left basal opacity is similar to previous study.')
# ('the left retrocardiac and basal opacity has improved.', 'the left retrocardiac and basal opacity has increased.')
# ('Slight improvement in mild pulmonary edema.', 'Slight worsening of mild pulmonary edema.')
# ('new moderate tension pneumothorax on the right.', 'unchanged moderate tension pneumothorax on the right.')
# Total sentences: 98658
#   0%|                                                 | 0/98658 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=410,2647990738830975744).pkl
# len(self.cache["hashes"]) = 34826
# self.cache["embeddings"].shape = (34826, 128)
# 100%|█████████████████████████████████| 98658/98658 [00:00<00:00, 312331.89it/s]
# Computing embeddings for 98257 new texts
# Explicitly passing a `revision` is encouraged when loading a configuration with custom code to ensure no malicious code has been contributed in a newer revision.
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# checkpoint_names = ['checkpoint_193_cacc+chf1+chf1+cscc+encc+hscc+nlcc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9472.pt']
# Loading model weights from /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240207_235928_MIMIC-CXR(triplets+classif+entcont+nli)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/checkpoint_193_cacc+chf1+chf1+cscc+encc+hscc+nlcc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9472.pt
# Warning: model state dict has 211 keys, loaded state dict has 227 keys, intersection has 211 keys, union has 227 keys.
# Examples of keys in loaded state dict but not in model:
#   aux_task_hidden_layer.weight
#   category_classifier.bias
#   comparison_status_classifier.bias
#   aux_task_hidden_layer.bias
#   health_status_classifier.weight
#   comparison_status_classifier.weight
#   nli_hidden_layer.bias
#   health_status_classifier.bias
#   nli_classifier.weight
#   nli_hidden_layer.weight
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# 100%|█████████████████████████████████████████| 983/983 [01:09<00:00, 14.05it/s]
# Saving updated cache to /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=410,2647990738830975744).pkl
# 100%|█████████████████████████████████| 98257/98257 [00:00<00:00, 563085.09it/s]
# embeddings.shape: (98658, 128)
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (25175, 128)
# train_h_ent_embeddings.shape: (25175, 128)
# train_p_con_embeddings.shape: (99121, 128)
# train_h_con_embeddings.shape: (99121, 128)
# train_ent_cosine_sim.shape: (25175,)
# train_con_cosine_sim.shape: (99121,)
# 100%|█████████████████████████████████████| 1000/1000 [00:00<00:00, 8841.86it/s]
# best_threshold: 0.2875927609127682
# best_acc: 0.8863439454052362
# best_ent_acc: 0.9489572989076465
# best_con_acc: 0.8237305919028258
# --------------
# Evaluating on RadNLI test set
# test_p_ent_embeddings.shape: (102, 128)
# test_h_ent_embeddings.shape: (102, 128)
# test_p_con_embeddings.shape: (98, 128)
# test_h_con_embeddings.shape: (98, 128)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 0.9901960784313726
# contradiction_acc: 0.9183673469387755
# test_acc: 0.954281712685074
# --------------
# --------------
# Evaluating on MS-CXR-T Temporal Sentence Similarity v1
# test_p_ent_embeddings.shape: (141, 128)
# test_h_ent_embeddings.shape: (141, 128)
# test_p_con_embeddings.shape: (220, 128)
# test_h_con_embeddings.shape: (220, 128)
# test_ent_cosine_sim.shape: (141,)
# test_con_cosine_sim.shape: (220,)
# entailment_acc: 1.0
# contradiction_acc: 0.759090909090909
# test_acc: 0.8795454545454545
# --------------

# %%
# !python ../eval_NLI_v2.py \
--huggingface_model_name "microsoft/BiomedVLP-CXR-BERT-specialized" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240207_235928_MIMIC-CXR(triplets+classif+entcont+nli)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)" \
--device "GPU" \
--batch_size 100 \
--num_workers 3 \
--calibrate_on_test_set
# Out:
# script's arguments:
#    huggingface_model_name: microsoft/BiomedVLP-CXR-BERT-specialized
#    model_name: None
#    model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240207_235928_MIMIC-CXR(triplets+classif+entcont+nli)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)
#    device: GPU
#    batch_size: 100
#    num_workers: 3
#    integrated_nli_jsonl_filepath: None
#    similarity_metric: cosine
#    average_token_embeddings: False
#    calibrate_on_test_set: True
# checkpoint_names = ['checkpoint_193_cacc+chf1+chf1+cscc+encc+hscc+nlcc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9472.pt']
# Test radnli entailment pairs: 102
# Test radnli contradiction pairs: 98
# Example test radnli entailment pairs:
# ('The lungs are clear without focal consolidation.', 'The lungs are clear.')
# ('The lungs are clear without focal consolidation, pleural effusion or pneumothorax.', 'No pleural effusions.')
# ('Lung volumes are low, and the cardiac silhouette is enlarged.', 'Lung volume is small.')
# ('Trace pleural effusion at the right base.', 'There is a tiny right pleural effusion.')
# Example test radnli contradiction pairs:
# ('Pleural effusions are stable.', 'There is no focal consolidation, pleural effusion or pneumothorax.')
# ('Small left pleural effusion is difficult to exclude.', 'There is no focal consolidation, pleural effusion or pneumothorax.')
# ('No pleural effusion or pneumothorax is seen on this supine exam.', 'There are unchanged small bilateral layering pleural effusions.')
# ('A small left pleural effusion is also likely present.', 'No pleural effusions.')
# Test mscxrt entailment pairs: 141
# Test mscxrt contradiction pairs: 220
# Example test mscxrt entailment pairs:
# ('there is atelectasis at the lung bases, unchanged.', 'there is atelectasis at the lung bases, stable.')
# ('there is also improvement in pulmonary edema.', 'there is also decrease in pulmonary edema.')
# ('slightly increased moderate pulmonary edema.', 'slightly worsened moderate pulmonary edema.')
# ('Persistent right upper lobe opacification has only mildly improved since ___.', 'Mildly improved right upper lobe opacity compared to ___.')
# Example test mscxrt contradiction pairs:
# ('retrocardiac atelectasis have increased.', 'retrocardiac atelectasis have improved.')
# ('There is some hazy opacity at the right base which is unchanged.', 'In comparison with the study of ___, there is increasing hazy opacification at the right base.')
# ('Interval worsening of the right-sided pneumothorax.', 'No definite interval change in right-sided pneumothorax with details as above.')
# ('moderate right pleural effusion is larger today than on ___.', 'moderate right pleural effusion is smaller today than on ___.')
# Total sentences: 825
#   0%|                                                   | 0/825 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=410,2647990738830975744).pkl
# len(self.cache["hashes"]) = 133083
# self.cache["embeddings"].shape = (133083, 128)
# 100%|███████████████████████████████████████| 825/825 [00:00<00:00, 2015.49it/s]
# embeddings.shape: (825, 128)
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (102, 128)
# train_h_ent_embeddings.shape: (102, 128)
# train_p_con_embeddings.shape: (98, 128)
# train_h_con_embeddings.shape: (98, 128)
# train_ent_cosine_sim.shape: (102,)
# train_con_cosine_sim.shape: (98,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 28879.03it/s]
# best_threshold: 0.41682094765139066
# best_acc: 0.959983993597439
# best_ent_acc: 0.9607843137254902
# best_con_acc: 0.9591836734693877
# --------------
# Evaluating on RadNLI test set
# test_p_ent_embeddings.shape: (102, 128)
# test_h_ent_embeddings.shape: (102, 128)
# test_p_con_embeddings.shape: (98, 128)
# test_h_con_embeddings.shape: (98, 128)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 0.9607843137254902
# contradiction_acc: 0.9591836734693877
# test_acc: 0.959983993597439
# --------------
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (141, 128)
# train_h_ent_embeddings.shape: (141, 128)
# train_p_con_embeddings.shape: (220, 128)
# train_h_con_embeddings.shape: (220, 128)
# train_ent_cosine_sim.shape: (141,)
# train_con_cosine_sim.shape: (220,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 28584.60it/s]
# best_threshold: 0.7095909027962595
# best_acc: 0.9724532559638943
# best_ent_acc: 0.9858156028368794
# best_con_acc: 0.9590909090909091
# --------------
# Evaluating on MS-CXR-T Temporal Sentence Similarity v1
# test_p_ent_embeddings.shape: (141, 128)
# test_h_ent_embeddings.shape: (141, 128)
# test_p_con_embeddings.shape: (220, 128)
# test_h_con_embeddings.shape: (220, 128)
# test_ent_cosine_sim.shape: (141,)
# test_con_cosine_sim.shape: (220,)
# entailment_acc: 0.9858156028368794
# contradiction_acc: 0.9590909090909091
# test_acc: 0.9724532559638943
# --------------

# %% [markdown]
# # CXR Fact Embedding (T -> T+C+EC+NLI+ER+SD)

# %%
# !python ../eval_NLI_v2.py \
--huggingface_model_name "microsoft/BiomedVLP-CXR-BERT-specialized" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240207_184445_MIMIC-CXR(triplets+classif+entcont+nli+radgraph+autoencoder)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)" \
--device "GPU" \
--batch_size 100 \
--num_workers 3 \
--integrated_nli_jsonl_filepath \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(169025,21838032).jsonl"
# Out:
# script's arguments:
#    huggingface_model_name: microsoft/BiomedVLP-CXR-BERT-specialized
#    model_name: None
#    model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240207_184445_MIMIC-CXR(triplets+classif+entcont+nli+radgraph+autoencoder)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)
#    device: GPU
#    batch_size: 100
#    num_workers: 3
#    integrated_nli_jsonl_filepath: /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(169025,21838032).jsonl
#    similarity_metric: cosine
#    average_token_embeddings: False
#    calibrate_on_test_set: False
# checkpoint_names = ['checkpoint_91_cacc+chf1+chf1+cscc+encc+hscc+nlcc+sass+spss+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9337.pt']
# Train entailment pairs: 25175
# Train contradiction pairs: 99121
# Example train entailment pairs:
# ('The trachea is midline.', 'The trachea is in the midline, but the evaluation is limited due to body habitus.')
# ('It it obscures much of the right lung, but there is a suggestion of greater consolidation in the lateral aspect of the right middle lung.', 'It it obscures much of the right lung, but there is a suggestion of greater consolidation in the lateral aspect of the right middle lung.')
# ('No pleural effusion or pneumothorax.', 'There is no fluid or air in the pleural space.')
# ('No h/o w/d seizures, no h/o DTs.', ' Patient has social history of alcoholism')
# Example train contradiction pairs:
# ('No large pleural effusion or pneumothorax is clearly visualized.', 'There are bilateral pleural effusions with pulmonary vascular congestion.')
# ('Lung volumes are slightly low, but given this, there is no evidence of opacities to suggest infection.', "The patient's chest X-ray shows clear signs of lung infection.")
# ('Endotracheal tube remains in standard position.', 'Endotracheal tube has been removed.')
# ('There are no vertebral compression fractures in the thoracic spine.', 'Multiple levels of vertebral compression fractures in the thoracic spine are grossly unchanged and probably pathologic given provided history.')
# Test radnli entailment pairs: 102
# Test radnli contradiction pairs: 98
# Example test radnli entailment pairs:
# ('Areas of increased opacification is seen at the bases, suggestive of atelectatic change.', 'Streaky opacities at the left lung base indicate mild atelectasis.')
# ('The cardiac silhouette is top normal.', 'The heart is not enlarged.')
# ('Lungs are clear.', 'The lungs are unremarkable.')
# ('No large pleural effusion or pneumothorax is seen.', 'There is no pneumothorax.')
# Example test radnli contradiction pairs:
# ('No pleural effusion or pneumothorax is clearly noted on this supine exam, though the left costophrenic angle is not completely included in the field of view.', 'The costophrenic angles are not fully included on the image and pleural effusions are difficult to exclude.')
# ('There is no focal consolidation, pleural effusion or pneumothorax.', 'Small left pleural effusion is difficult to exclude.')
# ('There is no pleural effusion or pneumothorax.', 'Moderate right pleural effusion is likely.')
# ('No pleural effusion or pneumothorax is seen.', 'There is a small left pleural effusion.')
# Test mscxrt entailment pairs: 141
# Test mscxrt contradiction pairs: 220
# Example test mscxrt entailment pairs:
# ('there is stable mild perihilar and interstitial edema.', 'there is unchanged mild perihilar and interstitial edema.')
# ('Interval decrease in the opacities at the right lung base.', 'Interval improvement of right lung base opacities.')
# ('There is a stable tiny right apical pneumothorax.', 'There remains a very tiny right apical pneumothorax, unchanged.')
# ('extensive diffuse consolidations have markedly worsened.', 'extensive diffuse consolidations have markedly progressed.')
# Example test mscxrt contradiction pairs:
# ('increase in pulmonary edema.', 'improvement in pulmonary edema.')
# ('Interval improved right basilar atelectasis.', 'Interval worsening of right basilar atelectasis.')
# ('Interval decrease in small bilateral pleural effusions.', 'Interval development of small bilateral pleural effusion, otherwise no interval change.')
# ('mild interstitial edema has worsened.', 'mild interstitial edema has improved.')
# Total sentences: 98658
#   0%|                                                 | 0/98658 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=440,3465006188639683439).pkl
# len(self.cache["hashes"]) = 34826
# self.cache["embeddings"].shape = (34826, 128)
# 100%|█████████████████████████████████| 98658/98658 [00:00<00:00, 403267.10it/s]
# Computing embeddings for 98257 new texts
# Explicitly passing a `revision` is encouraged when loading a configuration with custom code to ensure no malicious code has been contributed in a newer revision.
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# checkpoint_names = ['checkpoint_91_cacc+chf1+chf1+cscc+encc+hscc+nlcc+sass+spss+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9337.pt']
# Loading model weights from /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240207_184445_MIMIC-CXR(triplets+classif+entcont+nli+radgraph+autoencoder)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/checkpoint_91_cacc+chf1+chf1+cscc+encc+hscc+nlcc+sass+spss+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9337.pt
# Warning: model state dict has 211 keys, loaded state dict has 258 keys, intersection has 211 keys, union has 258 keys.
# Examples of keys in loaded state dict but not in model:
#   fact_decoder.W_vocab.bias
#   nli_classifier.bias
#   aux_task_hidden_layer.bias
#   fact_decoder.pos_encoder.pe
#   chest_imagenome_anatloc_classifier.weight
#   fact_decoder.start_idx
#   fact_decoder.decoder.layers.0.norm3.weight
#   health_status_classifier.bias
#   comparison_status_classifier.bias
#   fact_decoder.decoder.layers.0.norm2.bias
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# 100%|█████████████████████████████████████████| 983/983 [01:10<00:00, 13.89it/s]
# Saving updated cache to /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=440,3465006188639683439).pkl
# 100%|█████████████████████████████████| 98257/98257 [00:00<00:00, 299255.95it/s]
# embeddings.shape: (98658, 128)
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (25175, 128)
# train_h_ent_embeddings.shape: (25175, 128)
# train_p_con_embeddings.shape: (99121, 128)
# train_h_con_embeddings.shape: (99121, 128)
# train_ent_cosine_sim.shape: (25175,)
# train_con_cosine_sim.shape: (99121,)
# 100%|█████████████████████████████████████| 1000/1000 [00:00<00:00, 5535.46it/s]
# best_threshold: 0.4545690916680001
# best_acc: 0.9204169049119516
# best_ent_acc: 0.9706852035749751
# best_con_acc: 0.8701486062489281
# --------------
# Evaluating on RadNLI test set
# test_p_ent_embeddings.shape: (102, 128)
# test_h_ent_embeddings.shape: (102, 128)
# test_p_con_embeddings.shape: (98, 128)
# test_h_con_embeddings.shape: (98, 128)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 0.9803921568627451
# contradiction_acc: 0.9183673469387755
# test_acc: 0.9493797519007603
# --------------
# --------------
# Evaluating on MS-CXR-T Temporal Sentence Similarity v1
# test_p_ent_embeddings.shape: (141, 128)
# test_h_ent_embeddings.shape: (141, 128)
# test_p_con_embeddings.shape: (220, 128)
# test_h_con_embeddings.shape: (220, 128)
# test_ent_cosine_sim.shape: (141,)
# test_con_cosine_sim.shape: (220,)
# entailment_acc: 1.0
# contradiction_acc: 0.7272727272727273
# test_acc: 0.8636363636363636
# --------------

# %%
# !python ../eval_NLI_v2.py \
--huggingface_model_name "microsoft/BiomedVLP-CXR-BERT-specialized" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240207_184445_MIMIC-CXR(triplets+classif+entcont+nli+radgraph+autoencoder)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)" \
--device "GPU" \
--batch_size 100 \
--num_workers 3 \
--calibrate_on_test_set
# Out:
# script's arguments:
#    huggingface_model_name: microsoft/BiomedVLP-CXR-BERT-specialized
#    model_name: None
#    model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240207_184445_MIMIC-CXR(triplets+classif+entcont+nli+radgraph+autoencoder)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)
#    device: GPU
#    batch_size: 100
#    num_workers: 3
#    integrated_nli_jsonl_filepath: None
#    similarity_metric: cosine
#    average_token_embeddings: False
#    calibrate_on_test_set: True
# checkpoint_names = ['checkpoint_91_cacc+chf1+chf1+cscc+encc+hscc+nlcc+sass+spss+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9337.pt']
# Test radnli entailment pairs: 102
# Test radnli contradiction pairs: 98
# Example test radnli entailment pairs:
# ('No acute osseous abnormality detected.', 'Imaged osseous structures are intact.')
# ('No definite effusion or pneumothorax is seen.', 'No pleural effusion or pneumothorax is noted.')
# ('There are likely patchy opacities in the lung bases reflective of atelectasis.', 'Improved aeration at the lung bases with residual subsegmental atelectasis at the left lung base.')
# ('The cardiomediastinal silhouette and pulmonary vasculature are normal.', 'Pulmonary vascularity is normal.')
# Example test radnli contradiction pairs:
# ('The heart is mildly enlarged, unchanged.', 'The heart is top normal in size, which is exaggerated by the low lung volumes.')
# ('The lungs are clear bilaterally.', 'The lungs are mostly clear aside from mild lower lung atelectasis.')
# ('Moderate cardiomegaly and mediastinal vascular engorgement is stable.', 'Cardiomediastinal and hilar silhouettes are normal.')
# ('No pleural effusion or pneumothorax is seen on this supine exam.', 'There are unchanged small bilateral layering pleural effusions.')
# Test mscxrt entailment pairs: 141
# Test mscxrt contradiction pairs: 220
# Example test mscxrt entailment pairs:
# ('Left lower lobe collapse stable.', 'Persistent left lower lobe collapse.')
# ('unchanged, tiny left apical pneumothorax.', 'stable, tiny left apical pneumothorax.')
# ('unchanged tiny left pleural effusion.', 'stable tiny left pleural effusion.')
# ('bibasal atelectasis has slightly improved in the interim.', 'bibasal atelectasis has slightly decreased in the interim.')
# Example test mscxrt contradiction pairs:
# ('worsening left - sided pleural effusion.', 'stable left - sided pleural effusion.')
# ('the widespread bilateral diffuse parenchymal opacities are unchanged.', 'the widespread bilateral diffuse parenchymal opacities are improved.')
# ('mild generalized pulmonary edema has improved.', 'mild generalized pulmonary edema has resolved.')
# ('small left pleural effusion decreased.', 'small left pleural effusion unchanged.')
# Total sentences: 825
#   0%|                                                   | 0/825 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=440,3465006188639683439).pkl
# len(self.cache["hashes"]) = 133083
# self.cache["embeddings"].shape = (133083, 128)
# 100%|███████████████████████████████████████| 825/825 [00:00<00:00, 1877.72it/s]
# embeddings.shape: (825, 128)
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (102, 128)
# train_h_ent_embeddings.shape: (102, 128)
# train_p_con_embeddings.shape: (98, 128)
# train_h_con_embeddings.shape: (98, 128)
# train_ent_cosine_sim.shape: (102,)
# train_con_cosine_sim.shape: (98,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 23151.33it/s]
# best_threshold: 0.6064428896517366
# best_acc: 0.959983993597439
# best_ent_acc: 0.9607843137254902
# best_con_acc: 0.9591836734693877
# --------------
# Evaluating on RadNLI test set
# test_p_ent_embeddings.shape: (102, 128)
# test_h_ent_embeddings.shape: (102, 128)
# test_p_con_embeddings.shape: (98, 128)
# test_h_con_embeddings.shape: (98, 128)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 0.9607843137254902
# contradiction_acc: 0.9591836734693877
# test_acc: 0.959983993597439
# --------------
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (141, 128)
# train_h_ent_embeddings.shape: (141, 128)
# train_p_con_embeddings.shape: (220, 128)
# train_h_con_embeddings.shape: (220, 128)
# train_ent_cosine_sim.shape: (141,)
# train_con_cosine_sim.shape: (220,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 23140.60it/s]
# best_threshold: 0.8415030949227922
# best_acc: 0.9595422308188266
# best_ent_acc: 0.9645390070921985
# best_con_acc: 0.9545454545454546
# --------------
# Evaluating on MS-CXR-T Temporal Sentence Similarity v1
# test_p_ent_embeddings.shape: (141, 128)
# test_h_ent_embeddings.shape: (141, 128)
# test_p_con_embeddings.shape: (220, 128)
# test_h_con_embeddings.shape: (220, 128)
# test_ent_cosine_sim.shape: (141,)
# test_con_cosine_sim.shape: (220,)
# entailment_acc: 0.9645390070921985
# contradiction_acc: 0.9545454545454546
# test_acc: 0.9595422308188266
# --------------

# %% [markdown]
# # CXR Fact Embedding

# %%
# !python ../eval_NLI_v2.py \
--huggingface_model_name "microsoft/BiomedVLP-CXR-BERT-specialized" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230923_132315_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph,NLI)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)" \
--device "GPU" \
--batch_size 100 \
--num_workers 3 \
--integrated_nli_jsonl_filepath \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(162036,21465751).jsonl"
# Out:
# script's arguments:
#    huggingface_model_name: microsoft/BiomedVLP-CXR-BERT-specialized
#    model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230923_132315_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph,NLI)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)
#    device: GPU
#    batch_size: 100
#    num_workers: 3
#    integrated_nli_jsonl_filepath: /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(96629,13236055).jsonl
#    similarity_metric: cosine
# Train entailment pairs: 24072
# Train contradiction pairs: 37975
# Example train entailment pairs:
# ('There is no pneumothorax or large effusion and no confluent consolidation.', "The patient's chest X-ray shows no signs of pneumothorax, large effusion, or confluent consolidation.")
# ('The views reveal a small pneumothorax, a calcified granuloma, and a moderate pericardial effusion.', 'There is a minor lung collapse, which could be due to the small pneumothorax.')
# ('Partially calcified right pleural abnormality is chronic, accompanied by likely rounded atelectasis responsible for the medial convexity at the base of the right hemi thorax laterally.', 'The patient has a chronic right pleural abnormality that is partially calcified.')
# ('Consider thyroid ultrasound for further evaluation.', 'The patient may need further diagnostic procedures.')
# Example train contradiction pairs:
# ('There continues to be volume loss at both bases, but it is improved compared to the prior study.', 'There is volume loss at both bases that is increased compared to the prior exam.')
# ('The esophageal drainage tube is not present in the stomach.', 'Esophageal drainage tube ends in the mid portion of a mildly distended stomach.')
# ('He was thought by the Medical Intensive Care Unit Team to be most likely dehydrated and in rapid atrial fibrillation; his hypotension and atrial fibrillation were not thought to be secondary to sepsis and cultures throughout his hospital course afforded this assumption.', ' The patient was hypervolemic. ')
# ('Similar appearing hyperinflated lungs with flattened diaphragms representing COPD-related changes.', "The patient's lungs show no signs of Chronic Obstructive Pulmonary Disease (COPD).")
# Test entailment pairs: 102
# Test contradiction pairs: 98
# Example test entailment pairs:
# ('No focal consolidation, pleural effusion, pneumothorax, or pulmonary edema.', 'There is no pleural effusion pneumothorax.')
# ('No acute osseous abnormalities are visualized.', 'No acute osseous abnormality seen.')
# ('Cardiomediastinal and hilar contours are within normal limits.', 'The cardiomediastinal silhouette is within normal limits.')
# ('Atelectasis within the left lung base is noted, but no focal consolidation, pleural effusion or pneumothorax is present.', 'Streaky atelectasis is seen at the left lung base.')
# Example test contradiction pairs:
# ('Trace pleural effusion at the right base.', 'There is no pleural effusion or pneumothorax.')
# ('The cardiac silhouette remains enlarged.', 'Cardiac silhouette size is normal.')
# ('No pulmonary edema is seen.', 'Mild pulmonary edema is redemonstrated, stable since prior chest x-ray.')
# ('There is no pulmonary edema or pleural effusions.', 'Moderate to large bilateral pleural effusions are again seen, likely right greater than left.')
# Total sentences: 65730
#   0%|                                                 | 0/65730 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=328,692998140110977986).pkl
# len(self.cache["hashes"]) = 65730
# self.cache["embeddings"].shape = (65730, 128)
# 100%|█████████████████████████████████| 65730/65730 [00:00<00:00, 385502.32it/s]
# embeddings.shape: (65730, 128)
# train_p_ent_embeddings.shape: (24072, 128)
# train_h_ent_embeddings.shape: (24072, 128)
# train_p_con_embeddings.shape: (37975, 128)
# train_h_con_embeddings.shape: (37975, 128)
# train_ent_cosine_sim.shape: (24072,)
# train_con_cosine_sim.shape: (37975,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 18564.62it/s]
# best_threshold: 0.1899796505948087
# best_acc: 0.7440929521070321
# best_ent_acc: 0.8325440345629778
# best_con_acc: 0.6556418696510863
# --------------
# Evaluating on test set
# test_p_ent_embeddings.shape: (102, 128)
# test_h_ent_embeddings.shape: (102, 128)
# test_p_con_embeddings.shape: (98, 128)
# test_h_con_embeddings.shape: (98, 128)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 1.0
# contradiction_acc: 0.3469387755102041
# test_acc: 0.673469387755102
# --------------

# %%
# !python ../eval_NLI_v2.py \
--huggingface_model_name "microsoft/BiomedVLP-CXR-BERT-specialized" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230924_175553_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph,NLI)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)" \
--device "GPU" \
--batch_size 100 \
--num_workers 3 \
--integrated_nli_jsonl_filepath \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(162036,21465751).jsonl"
# Out:
# script's arguments:
#    huggingface_model_name: microsoft/BiomedVLP-CXR-BERT-specialized
#    model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230924_175553_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph,NLI)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)
#    device: GPU
#    batch_size: 100
#    num_workers: 3
#    integrated_nli_jsonl_filepath: /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(96629,13236055).jsonl
#    similarity_metric: cosine
#    average_token_embeddings: False
# checkpoint_names = ['checkpoint_57_cacc+chf1+chf1+cscc+encc+hscc+nlcc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9310.pt']
# Train entailment pairs: 24072
# Train contradiction pairs: 37975
# Example train entailment pairs:
# ('Recent urinary tract infection approximately one month ago which was treated and resolved.', ' Patient has recent UTI')
# ('Otherwise, the previously seen right upper lobe pneumonia has resolved.', 'In comparison to chest x-ray , the right upper lobe opacity has resolved.')
# ('There are mild diffuse degenerative changes of the thoracic spine.', 'There are mild degenerative changes in the thoracic spine :.')
# ('Frontal radiograph of the chest demonstrates a left pigtail catheter in unchanged position.', 'The left pigtail catheters in unchanged position.')
# Example train contradiction pairs:
# ('There is a moderate amount of air in the stomach.', 'Prominent amount of gas within the distended stomach.')
# ('Consolidation at the right lung base likely represents atelectasis, unchanged.', 'The right lung base is clear with no signs of atelectasis.')
# ('A paracentesis was also done during that admission and showed no evidence of spontaneous bacterial peritonitis, and the patient was placed on ciprofloxacin for prophylaxis.', ' the patient has a normal abdominal ultrasound')
# ('The mediastinum appears widened compared to prior studies, which could be technical and due to low lung volume however but it also raises the possibility of acute aortic syndrome.', "The patient's mediastinum has not changed in size since the last X-ray.")
# Test radnli entailment pairs: 102
# Test radnli contradiction pairs: 98
# Example test radnli entailment pairs:
# ('No focal consolidation, pleural effusion or pneumothorax is identified.', 'No focal infiltrate is identified.')
# ('Hilar and mediastinal silhouettes are unremarkable.', 'The mediastinal and hilar contours are normal.')
# ('There is no focal consolidation, pleural effusion, pneumothorax, or pulmonary edema.', 'There is no pleural effusion, focal consolidation or pneumothorax.')
# ('The heart appears top-normal in size.', 'Cardiac silhouette is top-normal.')
# Example test radnli contradiction pairs:
# ('Mild pulmonary vascular congestion is present and probable trace bilateral pleural effusions.', 'No pleural effusion or pneumothorax is seen.')
# ('The small bilateral pleural effusions are unchanged in size.', 'No pleural effusions.')
# ('No pleural effusion or pneumothorax is present.', 'The left apical pneumothorax is likely unchanged.')
# ('There is no pleural effusion or pneumothorax.', 'Moderate right pleural effusion is likely.')
# Test mscxrt entailment pairs: 141
# Test mscxrt contradiction pairs: 220
# Example test mscxrt entailment pairs:
# ('Increasing right effusion.', 'Increasing effusion on the right.')
# ('interval decrease in right pleural effusion.', 'interval improvement in right pleural effusion.')
# ('Improved mild interstitial edema.', 'Improved but persistent mild interstitial edema.')
# ('there has been interval improvement in the mild interstitial edema.', 'there has been interval decrease in the mild interstitial edema.')
# Example test mscxrt contradiction pairs:
# ('a right perihilar opacity is unchanged.', 'a right perihilar opacity is worsened.')
# ('retrocardiac atelectasis is unchanged.', 'retrocardiac atelectasis is new.')
# ('bibasilar atelectasis have improved.', 'bibasilar atelectasis have resolved.')
# ('moderate left pleural effusion has increased since ___.', 'moderate left pleural effusion has decreased since ___.')
# Total sentences: 66343
#   0%|                                                 | 0/66343 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=442,1737136993231307477).pkl
# len(self.cache["hashes"]) = 65730
# self.cache["embeddings"].shape = (65730, 128)
# 100%|█████████████████████████████████| 66343/66343 [00:00<00:00, 353440.58it/s]
# Computing embeddings for 613 new texts
# Explicitly passing a `revision` is encouraged when loading a configuration with custom code to ensure no malicious code has been contributed in a newer revision.
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# checkpoint_names = ['checkpoint_57_cacc+chf1+chf1+cscc+encc+hscc+nlcc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9310.pt']
# Loading model weights from /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230924_175553_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph,NLI)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/checkpoint_57_cacc+chf1+chf1+cscc+encc+hscc+nlcc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9310.pt
# Warning: model state dict has 211 keys, loaded state dict has 227 keys, intersection has 211 keys, union has 227 keys.
# Examples of keys in loaded state dict but not in model:
#   category_classifier.bias
#   health_status_classifier.weight
#   comparison_status_classifier.bias
#   aux_task_hidden_layer.weight
#   nli_hidden_layer.bias
#   comparison_status_classifier.weight
#   chest_imagenome_obs_classifier.bias
#   chest_imagenome_anatloc_classifier.bias
#   health_status_classifier.bias
#   nli_classifier.bias
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# 100%|█████████████████████████████████████████████| 7/7 [00:01<00:00,  4.36it/s]
# Saving updated cache to /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=442,1737136993231307477).pkl
# 100%|█████████████████████████████████████| 613/613 [00:00<00:00, 261397.76it/s]
# embeddings.shape: (66343, 128)
# train_p_ent_embeddings.shape: (24072, 128)
# train_h_ent_embeddings.shape: (24072, 128)
# train_p_con_embeddings.shape: (37975, 128)
# train_h_con_embeddings.shape: (37975, 128)
# train_ent_cosine_sim.shape: (24072,)
# train_con_cosine_sim.shape: (37975,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 18413.60it/s]
# best_threshold: 0.4548566509056855
# best_acc: 0.9158821965090027
# best_ent_acc: 0.9562146892655368
# best_con_acc: 0.8755497037524688
# --------------
# Evaluating on RadNLI test set
# test_p_ent_embeddings.shape: (102, 128)
# test_h_ent_embeddings.shape: (102, 128)
# test_p_con_embeddings.shape: (98, 128)
# test_h_con_embeddings.shape: (98, 128)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 0.9117647058823529
# contradiction_acc: 0.8367346938775511
# test_acc: 0.874249699879952
# --------------
# --------------
# Evaluating on MS-CXR-T Temporal Sentence Similarity v1
# test_p_ent_embeddings.shape: (141, 128)
# test_h_ent_embeddings.shape: (141, 128)
# test_p_con_embeddings.shape: (220, 128)
# test_h_con_embeddings.shape: (220, 128)
# test_ent_cosine_sim.shape: (141,)
# test_con_cosine_sim.shape: (220,)
# entailment_acc: 1.0
# contradiction_acc: 0.7136363636363636
# test_acc: 0.8568181818181818
# --------------

# %%
# !python ../eval_NLI_v2.py \
--huggingface_model_name "microsoft/BiomedVLP-CXR-BERT-specialized" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230924_175553_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph,NLI)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)" \
--device "GPU" \
--batch_size 100 \
--num_workers 3 \
--integrated_nli_jsonl_filepath \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(96629,13236055).jsonl" \
--calibrate_on_test_set
# Out:
# script's arguments:
#    huggingface_model_name: microsoft/BiomedVLP-CXR-BERT-specialized
#    model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230924_175553_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph,NLI)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)
#    device: GPU
#    batch_size: 100
#    num_workers: 3
#    integrated_nli_jsonl_filepath: /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(96629,13236055).jsonl
#    similarity_metric: cosine
#    average_token_embeddings: False
#    calibrate_on_test_set: True
# checkpoint_names = ['checkpoint_57_cacc+chf1+chf1+cscc+encc+hscc+nlcc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9310.pt']
# Test radnli entailment pairs: 102
# Test radnli contradiction pairs: 98
# Example test radnli entailment pairs:
# ('No pleural effusion or pneumothorax is noted.', 'No definite effusion or pneumothorax is seen.')
# ('Heart and mediastinal contours appear normal.', 'The cardiomediastinal and hilar contours are within normal limits.')
# ('The lungs are clear without focal consolidation, pleural effusion or pneumothorax.', 'No pleural effusions.')
# ('The lungs are well expanded and clear.', 'The lungs are clear.')
# Example test radnli contradiction pairs:
# ('The heart is mildly enlarged, unchanged.', 'The heart is top normal in size, which is exaggerated by the low lung volumes.')
# ('Since the prior radiograph, no significant change in the widespread parenchymal opacities and moderate cardiomegaly.', 'Allowing for these limitation, there are no focal parenchymal opacities.')
# ('No right-sided pleural effusion is seen.', 'Small bilateral pleural effusions are noted.')
# ('Small right pleural effusion has decreased.', 'There is no pleural effusion or pulmonary edema.')
# Test mscxrt entailment pairs: 141
# Test mscxrt contradiction pairs: 220
# Example test mscxrt entailment pairs:
# ('mild pulmonary edema, nearly resolved over two weeks.', 'mild pulmonary edema, nearly cleared over two weeks.')
# ('interval decrease in right pleural effusion.', 'interval improvement in right pleural effusion.')
# ('stable moderate bilateral pleural effusions.', 'unchanged moderate bilateral pleural effusions.')
# ('moderate right pleural effusion stable.', 'moderate right pleural effusion unchanged.')
# Example test mscxrt contradiction pairs:
# ('stable moderate - sized loculated left pleural effusion.', 'new moderate - sized loculated left pleural effusion.')
# ('Moderate bibasilar atelectasis is improved on the right, worsened on the left.', 'Moderate bibasilar atelectasis stable on the right, improved on the left.')
# ('As compared to the previous radiograph, the extent of the pre-existing right pneumothorax has substantially increased.', 'The known right pneumothorax is not substantially changed.')
# ('unchanged, tiny left apical pneumothorax.', 'new, tiny left apical pneumothorax.')
# Total sentences: 825
#   0%|                                                   | 0/825 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=442,1737136993231307477).pkl
# len(self.cache["hashes"]) = 66343
# self.cache["embeddings"].shape = (66343, 128)
# 100%|███████████████████████████████████████| 825/825 [00:00<00:00, 5013.00it/s]
# embeddings.shape: (825, 128)
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (102, 128)
# train_h_ent_embeddings.shape: (102, 128)
# train_p_con_embeddings.shape: (98, 128)
# train_h_con_embeddings.shape: (98, 128)
# train_ent_cosine_sim.shape: (102,)
# train_con_cosine_sim.shape: (98,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 40536.03it/s]
# best_threshold: 0.5632322785016652
# best_acc: 0.8799519807923168
# best_ent_acc: 0.8823529411764706
# best_con_acc: 0.8775510204081632
# --------------
# Evaluating on RadNLI test set
# test_p_ent_embeddings.shape: (102, 128)
# test_h_ent_embeddings.shape: (102, 128)
# test_p_con_embeddings.shape: (98, 128)
# test_h_con_embeddings.shape: (98, 128)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 0.8823529411764706
# contradiction_acc: 0.8775510204081632
# test_acc: 0.8799519807923168
# --------------
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (141, 128)
# train_h_ent_embeddings.shape: (141, 128)
# train_p_con_embeddings.shape: (220, 128)
# train_h_con_embeddings.shape: (220, 128)
# train_ent_cosine_sim.shape: (141,)
# train_con_cosine_sim.shape: (220,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 44539.70it/s]
# best_threshold: 0.7707272485211805
# best_acc: 0.9388136686009027
# best_ent_acc: 0.950354609929078
# best_con_acc: 0.9272727272727272
# --------------
# Evaluating on MS-CXR-T Temporal Sentence Similarity v1
# test_p_ent_embeddings.shape: (141, 128)
# test_h_ent_embeddings.shape: (141, 128)
# test_p_con_embeddings.shape: (220, 128)
# test_h_con_embeddings.shape: (220, 128)
# test_ent_cosine_sim.shape: (141,)
# test_con_cosine_sim.shape: (220,)
# entailment_acc: 0.950354609929078
# contradiction_acc: 0.9272727272727272
# test_acc: 0.9388136686009027
# --------------

# %%
# !python ../eval_NLI_v2.py \
--huggingface_model_name "microsoft/BiomedVLP-CXR-BERT-specialized" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230925_020631_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph,NLI)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)" \
--device "GPU" \
--batch_size 200 \
--num_workers 3 \
--integrated_nli_jsonl_filepath \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(162036,21465751).jsonl"
# Out:
# script's arguments:
#    huggingface_model_name: microsoft/BiomedVLP-CXR-BERT-specialized
#    model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230925_020631_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph,NLI)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)
#    device: GPU
#    batch_size: 200
#    num_workers: 3
#    integrated_nli_jsonl_filepath: /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(162036,21465751).jsonl
#    similarity_metric: cosine
#    average_token_embeddings: False
#    calibrate_on_test_set: False
# checkpoint_names = ['checkpoint_38_cacc+chf1+chf1+cscc+encc+hscc+nlcc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9311.pt']
# Train entailment pairs: 26442
# Train contradiction pairs: 95777
# Example train entailment pairs:
# ('Right PICC line tip is at the level of cavoatrial junction, unchanged.', 'The right PICC line tip is at the level of cavoatrial junction.')
# ('No central vascular congestion or overt pulmonary edema.', '6:47 PM No vascular congestion or pulmonary edema.')
# ('The patient was weaned successfully off pressors with aggressive IVF administration.', ' The patient received IV fluids')
# ('On arrival to ED, she was febrile to 102.2, HR 109, RR 22.', ' The patient meets SIRS criteria. ')
# Example train contradiction pairs:
# ('Otherwise, there has been no significant change.', 'There has been a significant change.')
# ('Mild chronic findings are again seen the left base, but no acute consolidation or vascular congestion.', 'New hazy opacity at the right lower lung zone concerning for aspiration.')
# ('There is left lower lung atelectasis.', 'The left lower lung is fully inflated.')
# ('Feeding tube terminates in the proximal stomach.', 'An enteric tube terminates in the mid stomach.')
# Test radnli entailment pairs: 102
# Test radnli contradiction pairs: 98
# Example test radnli entailment pairs:
# ('No focal consolidation, pleural effusion, pulmonary edema, or pneumothorax.', 'No pneumothorax is evident.')
# ('The lungs are clear without focal consolidation, pleural effusion or pneumothorax.', 'There are no pleural effusions.')
# ('The lungs are clear.', 'Allowing for this, the lungs are clear.')
# ('The cardiomediastinal silhouette is normal.', 'The cardiomediastinal silhouette and contour are within normal limits.')
# Example test radnli contradiction pairs:
# ('There is subtle blunting of the left CP angle suggesting a tiny effusion or pleural thickening.', 'No pleural effusion or pneumothorax is present.')
# ('The heart and mediastinal contours are normal.', 'The heart appears mildly enlarged.')
# ('The heart is top normal in size, which is exaggerated by the low lung volumes.', 'The heart is mildly enlarged, unchanged.')
# ('The left apical pneumothorax is likely unchanged.', 'No pleural effusion or pneumothorax is present.')
# Test mscxrt entailment pairs: 141
# Test mscxrt contradiction pairs: 220
# Example test mscxrt entailment pairs:
# ('more severe consolidation in the left lower lobe has worsened as well.', 'more severe consolidation in the left lower lobe has increased as well.')
# ('on the left, the pre - existing opacities are stable in extent and severity.', 'on the left, the pre - existing opacities are unchanged in extent and severity.')
# ('bilateral pleural effusions are moderate, unchanged.', 'bilateral pleural effusions are moderate, stable.')
# ('severely atelectatic left lower lobe is unchanged.', 'severely atelectatic left lower lobe is stable.')
# Example test mscxrt contradiction pairs:
# ('mild generalized pulmonary edema has improved.', 'mild generalized pulmonary edema has worsened.')
# ('severely atelectatic left lower lobe is unchanged.', 'severely atelectatic left lower lobe is new.')
# ('interval increase of a pre - existing right basal parenchymal opacity.', 'interval improvement of a pre - existing right basal parenchymal opacity.')
# ('interval improvement in mild pulmonary edema.', 'interval increase in mild pulmonary edema.')
# Total sentences: 102464
#   0%|                                                | 0/102464 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=442,4081940466550139603).pkl
# len(self.cache["hashes"]) = 102464
# self.cache["embeddings"].shape = (102464, 128)
# 100%|███████████████████████████████| 102464/102464 [00:00<00:00, 383893.36it/s]
# embeddings.shape: (102464, 128)
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (26442, 128)
# train_h_ent_embeddings.shape: (26442, 128)
# train_p_con_embeddings.shape: (95777, 128)
# train_h_con_embeddings.shape: (95777, 128)
# train_ent_cosine_sim.shape: (26442,)
# train_con_cosine_sim.shape: (95777,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 11637.36it/s]
# best_threshold: 0.5128866294482808
# best_acc: 0.9033652802190171
# best_ent_acc: 0.9570380455336207
# best_con_acc: 0.8496925149044133
# --------------
# Evaluating on RadNLI test set
# test_p_ent_embeddings.shape: (102, 128)
# test_h_ent_embeddings.shape: (102, 128)
# test_p_con_embeddings.shape: (98, 128)
# test_h_con_embeddings.shape: (98, 128)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 0.9705882352941176
# contradiction_acc: 0.8367346938775511
# test_acc: 0.9036614645858343
# --------------
# --------------
# Evaluating on MS-CXR-T Temporal Sentence Similarity v1
# test_p_ent_embeddings.shape: (141, 128)
# test_h_ent_embeddings.shape: (141, 128)
# test_p_con_embeddings.shape: (220, 128)
# test_h_con_embeddings.shape: (220, 128)
# test_ent_cosine_sim.shape: (141,)
# test_con_cosine_sim.shape: (220,)
# entailment_acc: 1.0
# contradiction_acc: 0.8
# test_acc: 0.9
# --------------

# %%
# !python ../eval_NLI_v2.py \
--huggingface_model_name "microsoft/BiomedVLP-CXR-BERT-specialized" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230925_020631_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph,NLI)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)" \
--device "GPU" \
--batch_size 100 \
--num_workers 3 \
--calibrate_on_test_set
# Out:
# script's arguments:
#    huggingface_model_name: microsoft/BiomedVLP-CXR-BERT-specialized
#    model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230925_020631_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph,NLI)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)
#    device: GPU
#    batch_size: 100
#    num_workers: 3
#    integrated_nli_jsonl_filepath: None
#    similarity_metric: cosine
#    average_token_embeddings: False
#    calibrate_on_test_set: True
# checkpoint_names = ['checkpoint_38_cacc+chf1+chf1+cscc+encc+hscc+nlcc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9311.pt']
# Test radnli entailment pairs: 102
# Test radnli contradiction pairs: 98
# Example test radnli entailment pairs:
# ('The pulmonary vascularity is normal.', 'The pulmonary vasculature is normal.')
# ('The lungs are clear without focal consolidation, pleural effusion or pneumothorax.', 'No pleural effusions.')
# ('The lungs are clear without focal consolidation, pleural effusion or pneumothorax.', 'There are no pleural effusions.')
# ('There is no focal consolidation, pleural effusion, pneumothorax, or pulmonary edema.', 'There is no pneumothorax.')
# Example test radnli contradiction pairs:
# ('There is no pleural effusion or pneumothorax.', 'Pleura: Likely there is a right pleural effusion is well as a small left pleural effusion.')
# ('No pleural effusion or pneumothorax is seen.', 'Moderate cardiomegaly and minimal left pleural effusion.')
# ('No pleural effusion or pneumothorax is seen.', 'There are small bilateral pleural effusions.')
# ('Moderate size right pleural effusion is new from the previous radiograph with associated right basilar atelectasis.', 'No pleural abnormality is seen.')
# Test mscxrt entailment pairs: 141
# Test mscxrt contradiction pairs: 220
# Example test mscxrt entailment pairs:
# ('status post right thoracentesis with interval decrease in right pleural effusion, which is now trace in size.', 'status post right thoracentesis with interval improvement in right pleural effusion, which is now trace in size.')
# ('bibasilar retrocardiac atelectasis is unchanged.', 'bibasilar retrocardiac atelectasis is stable.')
# ('left basal consolidation has slightly improved.', 'left basal consolidation has slightly decreased.')
# ('a right perihilar opacity is unchanged.', 'a right perihilar opacity is stable.')
# Example test mscxrt contradiction pairs:
# ('mild interstitial pulmonary edema is slightly worse.', 'mild interstitial pulmonary edema is slightly improved.')
# ('unchanged, tiny left apical pneumothorax.', 'new, tiny left apical pneumothorax.')
# ('there is a persistent small right pneumothorax.', 'there is a new small right pneumothorax.')
# ('interval decrease in right pleural effusion.', 'interval increase in right pleural effusion.')
# Total sentences: 825
#   0%|                                                   | 0/825 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=442,4081940466550139603).pkl
# len(self.cache["hashes"]) = 102464
# self.cache["embeddings"].shape = (102464, 128)
# 100%|███████████████████████████████████████| 825/825 [00:00<00:00, 4316.75it/s]
# embeddings.shape: (825, 128)
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (102, 128)
# train_h_ent_embeddings.shape: (102, 128)
# train_p_con_embeddings.shape: (98, 128)
# train_h_con_embeddings.shape: (98, 128)
# train_ent_cosine_sim.shape: (102,)
# train_con_cosine_sim.shape: (98,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 44120.38it/s]
# best_threshold: 0.6464180277513194
# best_acc: 0.9350740296118447
# best_ent_acc: 0.9313725490196079
# best_con_acc: 0.9387755102040817
# --------------
# Evaluating on RadNLI test set
# test_p_ent_embeddings.shape: (102, 128)
# test_h_ent_embeddings.shape: (102, 128)
# test_p_con_embeddings.shape: (98, 128)
# test_h_con_embeddings.shape: (98, 128)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 0.9313725490196079
# contradiction_acc: 0.9387755102040817
# test_acc: 0.9350740296118447
# --------------
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (141, 128)
# train_h_ent_embeddings.shape: (141, 128)
# train_p_con_embeddings.shape: (220, 128)
# train_h_con_embeddings.shape: (220, 128)
# train_ent_cosine_sim.shape: (141,)
# train_con_cosine_sim.shape: (220,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 44079.58it/s]
# best_threshold: 0.7618035521354523
# best_acc: 0.949451966473243
# best_ent_acc: 0.9716312056737588
# best_con_acc: 0.9272727272727272
# --------------
# Evaluating on MS-CXR-T Temporal Sentence Similarity v1
# test_p_ent_embeddings.shape: (141, 128)
# test_h_ent_embeddings.shape: (141, 128)
# test_p_con_embeddings.shape: (220, 128)
# test_h_con_embeddings.shape: (220, 128)
# test_ent_cosine_sim.shape: (141,)
# test_con_cosine_sim.shape: (220,)
# entailment_acc: 0.9716312056737588
# contradiction_acc: 0.9272727272727272
# test_acc: 0.949451966473243
# --------------

# %%
# !python ../eval_NLI_v2.py \
--huggingface_model_name "microsoft/BiomedVLP-CXR-BERT-specialized" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230923_184632_NLI(MedNLI+RadNLI+GPT-4)_BerBasedNLI(microsoft-BiomedVLP-CXR-BERT-specialized,128,128)" \
--device "GPU" \
--batch_size 100 \
--num_workers 3 \
--integrated_nli_jsonl_filepath \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(96629,13236055).jsonl"
# Out:
# script's arguments:
#    huggingface_model_name: microsoft/BiomedVLP-CXR-BERT-specialized
#    model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230923_184632_NLI(MedNLI+RadNLI+GPT-4)_BerBasedNLI(microsoft-BiomedVLP-CXR-BERT-specialized,128,128)
#    device: GPU
#    batch_size: 100
#    num_workers: 3
#    integrated_nli_jsonl_filepath: /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(96629,13236055).jsonl
#    similarity_metric: cosine
# Train entailment pairs: 24072
# Train contradiction pairs: 37975
# Example train entailment pairs:
# ('There is no pleural effusion or pneumothorax.', 'No pneumothorax or large effusions.')
# ('No acute cardiopulmonary abnormality. The lungs are clear. No pneumothorax or pleural effusion.', 'There is no acute cardiopulmonary abnormality.')
# ('The appearance of the chest remains otherwise unchanged compared to the exam from approximately min earlier.', 'The chest X-ray shows no significant changes from the previous exam.')
# ('There is left pectoral pacemaker with its leads terminating at right atrium and right ventricle.', 'Left pectoral pacemaker has to leads terminating in right atrium and right ventricle.')
# Example train contradiction pairs:
# ('The visible parts of the right lung are unremarkable.', 'The pre-existing opacities in the right lung have increased in severity.')
# ('Two AP portable upright views of the chest and upper abdomen.', 'One AP view of the chest and upper abdomen.')
# ('The patient did not have any other scans on the same day.', 'This was better evaluated on the CTA of abdomen and pelvis from the same day.')
# ('There are increased lung markings at both bases, but no focal infiltrate or effusion.', 'There is increasing left lower lobe consolidation which may represent atelectasis or effusion.')
# Test entailment pairs: 102
# Test contradiction pairs: 98
# Example test entailment pairs:
# ('The lungs are unremarkable.', 'The lungs are clear.')
# ('The cardiac silhouette is top normal.', 'The heart is not enlarged.')
# ('Cardiomediastinal silhouette and hilar contours are unremarkable.', 'Cardiomediastinal and hilar contours are normal.')
# ('The lungs are clear without focal consolidation.', 'The lungs are clear.')
# Example test contradiction pairs:
# ('Dense retrocardiac opacification persists, consistent with left lower lobe consolidation and small pleural effusion.', 'No pleural effusion or pneumothorax is seen.')
# ('Moderate to large bilateral pleural effusions are again seen, likely right greater than left.', 'There is no pulmonary edema or pleural effusions.')
# ('Mild pulmonary vascular congestion is present and probable trace bilateral pleural effusions.', 'No pleural effusion or pneumothorax is seen.')
# ('No pleural effusions.', 'A small left pleural effusion is also likely present.')
# Total sentences: 65730
#   0%|                                                 | 0/65730 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=288,1681971427734235240).pkl
# len(self.cache["hashes"]) = 65730
# self.cache["embeddings"].shape = (65730, 128)
# 100%|█████████████████████████████████| 65730/65730 [00:00<00:00, 390638.01it/s]
# embeddings.shape: (65730, 128)
# train_p_ent_embeddings.shape: (24072, 128)
# train_h_ent_embeddings.shape: (24072, 128)
# train_p_con_embeddings.shape: (37975, 128)
# train_h_con_embeddings.shape: (37975, 128)
# train_ent_cosine_sim.shape: (24072,)
# train_con_cosine_sim.shape: (37975,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 18418.53it/s]
# best_threshold: 0.2170986455004733
# best_acc: 0.8042534898048885
# best_ent_acc: 0.880317381189764
# best_con_acc: 0.7281895984200132
# --------------
# Evaluating on test set
# test_p_ent_embeddings.shape: (102, 128)
# test_h_ent_embeddings.shape: (102, 128)
# test_p_con_embeddings.shape: (98, 128)
# test_h_con_embeddings.shape: (98, 128)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 0.9705882352941176
# contradiction_acc: 0.5102040816326531
# test_acc: 0.7403961584633854
# --------------

# %% [markdown]
# # CXR BERT specialized

# %%
# !python ../eval_NLI_v2.py \
--huggingface_model_name "microsoft/BiomedVLP-CXR-BERT-specialized" \
--device "GPU" \
--batch_size 200 \
--num_workers 3 \
--integrated_nli_jsonl_filepath \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(162036,21465751).jsonl"
# Out:
# script's arguments:
#    huggingface_model_name: microsoft/BiomedVLP-CXR-BERT-specialized
#    model_checkpoint_folder_path: None
#    device: GPU
#    batch_size: 200
#    num_workers: 3
#    integrated_nli_jsonl_filepath: /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(162036,21465751).jsonl
#    similarity_metric: cosine
#    average_token_embeddings: False
#    calibrate_on_test_set: False
# Train entailment pairs: 26442
# Train contradiction pairs: 95777
# Example train entailment pairs:
# ('The heart size is upper limits of normal, but stable.', 'Heart size is at the upper limits of normal.')
# ('The cardiac, mediastinal, and hilar contours appear stable including mediastinal and left hilar lymphadenopathy.', 'The cardiac, mediastinal and left hilar contours are unchanged.')
# ('Lung volumes are low now than earlier, and mild interstitial edema has developed.', 'Lung volumes are low in there is mild to moderate pulmonary edema.')
# ('No marked interval change.', 'No signficant interval change.')
# Example train contradiction pairs:
# ('No relevant changes noted.', "The patient's chest X-ray shows significant abnormalities compared to the previous one.")
# ('There is substantial interval progression of the prior study with increase in the left lower lobe consolidation and substantial increase in the right lower lung consolidation.', 'There has been interval partial clearing of the bilateral infiltrates which are now most apparent in the right mid lung and left lower lobe.')
# ('Bilateral calcified granulomas are again seen.', 'No cavitations or calcified granulomas are seen.')
# ('There is a right pectoral cardiac pacer with a single lead terminating in the right ventricle.', "There is no cardiac pacer present in the patient's body.")
# Test radnli entailment pairs: 102
# Test radnli contradiction pairs: 98
# Example test radnli entailment pairs:
# ('The lungs are clear without consolidation, effusion, or pneumothorax.', 'No pneumothorax is identified.')
# ('There is a tiny right pleural effusion.', 'Trace pleural effusion at the right base.')
# ('No pleural effusion or pneumothorax is noted.', 'No definite effusion or pneumothorax is seen.')
# ('Cardiomediastinal and hilar contours are normal.', 'Cardiomediastinal silhouette and hilar contours are unremarkable.')
# Example test radnli contradiction pairs:
# ('Small right pleural effusion has decreased.', 'There is no pneumothorax or pleural effusion.')
# ('No right-sided pleural effusion is seen.', 'Small bilateral pleural effusions are noted.')
# ('Known small left pneumothorax is not well seen.', 'No pneumothorax.')
# ('The lungs are otherwise clear.', 'The lungs are well expanded and clear.')
# Test mscxrt entailment pairs: 141
# Test mscxrt contradiction pairs: 220
# Example test mscxrt entailment pairs:
# ('Improved mild interstitial edema.', 'Improved but persistent mild interstitial edema.')
# ('moderate left lower lobe atelectasis has worsened.', 'moderate left lower lobe atelectasis has increased.')
# ('Small left apical pneumothorax slightly larger today than on ___.', 'Small left apical pneumothorax is slightly bigger.')
# ('on the left, the pre - existing opacities are stable in extent and severity.', 'on the left, the pre - existing opacities are unchanged in extent and severity.')
# Example test mscxrt contradiction pairs:
# ('stable small left pleural effusion.', 'new small left pleural effusion.')
# ('pulmonary vascular congestion has improved', 'pulmonary vascular congestion has worsened')
# ('As compared to the previous image, the right upper lobe pneumonia is unchanged.', 'Likely developing right upper lobe pneumonia.')
# ('Interval decrease in small bilateral pleural effusions.', 'Interval development of small bilateral pleural effusion, otherwise no interval change.')
# Total sentences: 102464
#   0%|                                                | 0/102464 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=116,1396652957813721259).pkl
# len(self.cache["hashes"]) = 66343
# self.cache["embeddings"].shape = (66343, 128)
# 100%|███████████████████████████████| 102464/102464 [00:00<00:00, 402545.82it/s]
# Computing embeddings for 36121 new texts
# Explicitly passing a `revision` is encouraged when loading a configuration with custom code to ensure no malicious code has been contributed in a newer revision.
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# 100%|█████████████████████████████████████████| 181/181 [00:17<00:00, 10.61it/s]
# Saving updated cache to /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=116,1396652957813721259).pkl
# 100%|█████████████████████████████████| 36121/36121 [00:00<00:00, 527289.69it/s]
# embeddings.shape: (102464, 128)
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (26442, 128)
# train_h_ent_embeddings.shape: (26442, 128)
# train_p_con_embeddings.shape: (95777, 128)
# train_h_con_embeddings.shape: (95777, 128)
# train_ent_cosine_sim.shape: (26442,)
# train_con_cosine_sim.shape: (95777,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 11648.77it/s]
# best_threshold: 0.7129643878063283
# best_acc: 0.6161670695897556
# best_ent_acc: 0.7406398910823689
# best_con_acc: 0.4916942480971423
# --------------
# Evaluating on RadNLI test set
# test_p_ent_embeddings.shape: (102, 128)
# test_h_ent_embeddings.shape: (102, 128)
# test_p_con_embeddings.shape: (98, 128)
# test_h_con_embeddings.shape: (98, 128)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 0.5980392156862745
# contradiction_acc: 0.8979591836734694
# test_acc: 0.7479991996798719
# --------------
# --------------
# Evaluating on MS-CXR-T Temporal Sentence Similarity v1
# test_p_ent_embeddings.shape: (141, 128)
# test_h_ent_embeddings.shape: (141, 128)
# test_p_con_embeddings.shape: (220, 128)
# test_h_con_embeddings.shape: (220, 128)
# test_ent_cosine_sim.shape: (141,)
# test_con_cosine_sim.shape: (220,)
# entailment_acc: 1.0
# contradiction_acc: 0.12272727272727273
# test_acc: 0.5613636363636364
# --------------

# %%
# !python ../eval_NLI_v2.py \
--huggingface_model_name "microsoft/BiomedVLP-CXR-BERT-specialized" \
--device "GPU" \
--batch_size 200 \
--num_workers 3 \
--integrated_nli_jsonl_filepath \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(169025,21838032).jsonl"
# Out:
# script's arguments:
#    huggingface_model_name: microsoft/BiomedVLP-CXR-BERT-specialized
#    model_name: None
#    model_checkpoint_folder_path: None
#    device: GPU
#    batch_size: 200
#    num_workers: 3
#    integrated_nli_jsonl_filepath: /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(169025,21838032).jsonl
#    similarity_metric: cosine
#    average_token_embeddings: False
#    calibrate_on_test_set: False
# Train entailment pairs: 25175
# Train contradiction pairs: 99121
# Example train entailment pairs:
# ('The patient is status median sternotomy and CABG.', 'The patient is after median sternotomy and CABG.')
# ('She is unsure whether she has received Pneumovax and Influenza vaccines.', ' She is not sure whether her immunizations are up-to-date')
# ('Again there is increased opacification at the left base consistent with volume loss in the lower lobe and pleural effusion.', 'Continued increased opacification at the left base consistent with volume loss in the left lower lobe and pleural effusion.')
# ('There is extensive calcification in the aortic arch and descending portion.', 'Dense calcifications of the aortic arch are noted.')
# Example train contradiction pairs:
# ('Moderate to severe pulmonary edema has worsened again.', 'Since , extensive pulmonary edema is mildly improved.')
# ('The right heart border is obscured by the elevated hemidiaphragm.', 'The elevated hemidiaphragm does not affect the visibility of the right heart border.')
# ('In the ED he was started on propofol and BP dropped to 80s systolic.', ' Patient has normal blood pressures')
# ('Mild pleural effusions are absent and there is no pulmonary edema.', 'Mild pleural effusions and pulmonary edema.')
# Test radnli entailment pairs: 102
# Test radnli contradiction pairs: 98
# Example test radnli entailment pairs:
# ('Allowing for this, the lungs are clear.', 'The lungs are clear.')
# ('The lungs are unremarkable.', 'Lungs are clear.')
# ('Pulmonary vascularity is not engorged.', 'The pulmonary vasculature is not engorged.')
# ('The lungs are clear without focal consolidation.', 'There is no focal consolidation.')
# Example test radnli contradiction pairs:
# ('Small right pleural effusion has decreased.', 'There is no pneumothorax or pleural effusion.')
# ('Mild pulmonary vascular congestion is present and probable trace bilateral pleural effusions.', 'No pleural effusion or pneumothorax is seen.')
# ('Heart size is normal accounting for the low lung volumes.', 'Lung volumes are normal.')
# ('Cardiomediastinal and hilar contours are unremarkable with the exception of a tortuous aorta.', 'PA and lateral chest radiographs demonstrate a normal cardiomediastinal silhouette.')
# Test mscxrt entailment pairs: 141
# Test mscxrt contradiction pairs: 220
# Example test mscxrt entailment pairs:
# ('Atelectasis at the bases has improved.', 'In comparison with the study of ___, the atelectatic changes at the bases have decreased.')
# ('right mid lung opacity has slightly improved.', 'right mid lung opacity has slightly decreased.')
# ('unchanged moderate right pleural effusion.', 'stable moderate right pleural effusion.')
# ('there is also improvement in pulmonary edema.', 'there is also decrease in pulmonary edema.')
# Example test mscxrt contradiction pairs:
# ('moderate left pleural effusion has increased since ___.', 'moderate left pleural effusion has decreased since ___.')
# ('since ___, substantial right lower lobe atelectasis has developed.', 'since ___, substantial right lower lobe atelectasis has resolved.')
# ('stable moderate - sized loculated left pleural effusion.', 'new moderate - sized loculated left pleural effusion.')
# ('Left basal consolidation is unchanged.', 'Left basal consolidation has improved as well.')
# Total sentences: 98658
#   0%|                                                 | 0/98658 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=116,1396652957813721259).pkl
# len(self.cache["hashes"]) = 146286
# self.cache["embeddings"].shape = (146286, 128)
# 100%|█████████████████████████████████| 98658/98658 [00:00<00:00, 175898.53it/s]
# Computing embeddings for 18445 new texts
# Explicitly passing a `revision` is encouraged when loading a configuration with custom code to ensure no malicious code has been contributed in a newer revision.
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# 100%|███████████████████████████████████████████| 93/93 [00:15<00:00,  6.16it/s]
# Saving updated cache to /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=116,1396652957813721259).pkl
# 100%|█████████████████████████████████| 18445/18445 [00:00<00:00, 325282.70it/s]
# embeddings.shape: (98658, 128)
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (25175, 128)
# train_h_ent_embeddings.shape: (25175, 128)
# train_p_con_embeddings.shape: (99121, 128)
# train_h_con_embeddings.shape: (99121, 128)
# train_ent_cosine_sim.shape: (25175,)
# train_con_cosine_sim.shape: (99121,)
# 100%|█████████████████████████████████████| 1000/1000 [00:00<00:00, 8170.14it/s]
# best_threshold: 0.6199498780377515
# best_acc: 0.607536347373252
# best_ent_acc: 0.7693346573982125
# best_con_acc: 0.4457380373482915
# --------------
# Evaluating on RadNLI test set
# test_p_ent_embeddings.shape: (102, 128)
# test_h_ent_embeddings.shape: (102, 128)
# test_p_con_embeddings.shape: (98, 128)
# test_h_con_embeddings.shape: (98, 128)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 0.7352941176470589
# contradiction_acc: 0.8571428571428571
# test_acc: 0.796218487394958
# --------------
# --------------
# Evaluating on MS-CXR-T Temporal Sentence Similarity v1
# test_p_ent_embeddings.shape: (141, 128)
# test_h_ent_embeddings.shape: (141, 128)
# test_p_con_embeddings.shape: (220, 128)
# test_h_con_embeddings.shape: (220, 128)
# test_ent_cosine_sim.shape: (141,)
# test_con_cosine_sim.shape: (220,)
# entailment_acc: 1.0
# contradiction_acc: 0.08636363636363636
# test_acc: 0.5431818181818182
# --------------

# %%
# !python ../eval_NLI_v2.py \
--huggingface_model_name "microsoft/BiomedVLP-CXR-BERT-specialized" \
--device "GPU" \
--batch_size 200 \
--num_workers 3 \
--calibrate_on_test_set
# Out:
# script's arguments:
#    huggingface_model_name: microsoft/BiomedVLP-CXR-BERT-specialized
#    model_checkpoint_folder_path: None
#    device: GPU
#    batch_size: 200
#    num_workers: 3
#    integrated_nli_jsonl_filepath: None
#    similarity_metric: cosine
#    average_token_embeddings: False
#    calibrate_on_test_set: True
# Test radnli entailment pairs: 102
# Test radnli contradiction pairs: 98
# Example test radnli entailment pairs:
# ('No focal consolidation, pleural effusion, pulmonary edema, or pneumothorax.', 'No pneumothorax is evident.')
# ('There is no pleural effusion, pneumothorax, or pulmonary vascular congestion.', 'Left pleural effusion has also completely resolved.')
# ('No acute bony abnormalities are seen.', 'There are no acute osseous abnormalities.')
# ('There is no pleural effusion, pneumothorax, or pulmonary vascular congestion.', 'There is no pneumothorax.')
# Example test radnli contradiction pairs:
# ('No pleural effusions.', 'The small bilateral pleural effusions are unchanged in size.')
# ('Moderate cardiomegaly and minimal left pleural effusion.', 'No pleural effusion or pneumothorax is seen.')
# ('Small bilateral pleural effusions are noted.', 'No right-sided pleural effusion is seen.')
# ('Lung volumes are normal.', 'Heart size is normal accounting for the low lung volumes.')
# Test mscxrt entailment pairs: 141
# Test mscxrt contradiction pairs: 220
# Example test mscxrt entailment pairs:
# ('left basal opacity is unchanged.', 'left basal opacity is stable.')
# ('stable moderate - sized loculated left pleural effusion.', 'unchanged moderate - sized loculated left pleural effusion.')
# ('very small right apical pneumothorax is unchanged.', 'very small right apical pneumothorax is stable.')
# ('There is persistent patchy consolidation in both lung bases which is stable.', 'There is stable patchy consolidation in both lung bases.')
# Example test mscxrt contradiction pairs:
# ('Moderate vascular congestion, which has increased in comparison to the prior.', 'moderate vascular congestion is stable.')
# ('subsequent decrease of and atelectasis at the right lung bases.', 'subsequent worsening of and atelectasis at the right lung bases.')
# ('there is unchanged mild to moderate pulmonary edema.', 'there is new mild to moderate pulmonary edema.')
# ('Small bilateral apical pneumothoraces have decreased since ___.', 'Small bilateral apical pneumothoraces new since ___.')
# Total sentences: 825
#   0%|                                                   | 0/825 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=116,1396652957813721259).pkl
# len(self.cache["hashes"]) = 102464
# self.cache["embeddings"].shape = (102464, 128)
# 100%|███████████████████████████████████████| 825/825 [00:00<00:00, 4359.63it/s]
# embeddings.shape: (825, 128)
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (102, 128)
# train_h_ent_embeddings.shape: (102, 128)
# train_p_con_embeddings.shape: (98, 128)
# train_h_con_embeddings.shape: (98, 128)
# train_ent_cosine_sim.shape: (102,)
# train_con_cosine_sim.shape: (98,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 44144.99it/s]
# best_threshold: 0.1641095735289313
# best_acc: 0.8232292917166867
# best_ent_acc: 0.9117647058823529
# best_con_acc: 0.7346938775510204
# --------------
# Evaluating on RadNLI test set
# test_p_ent_embeddings.shape: (102, 128)
# test_h_ent_embeddings.shape: (102, 128)
# test_p_con_embeddings.shape: (98, 128)
# test_h_con_embeddings.shape: (98, 128)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 0.9117647058823529
# contradiction_acc: 0.7346938775510204
# test_acc: 0.8232292917166867
# --------------
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (141, 128)
# train_h_ent_embeddings.shape: (141, 128)
# train_p_con_embeddings.shape: (220, 128)
# train_h_con_embeddings.shape: (220, 128)
# train_ent_cosine_sim.shape: (141,)
# train_con_cosine_sim.shape: (220,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 43991.27it/s]
# best_threshold: 0.9922392592654453
# best_acc: 0.7754352030947775
# best_ent_acc: 0.7872340425531915
# best_con_acc: 0.7636363636363637
# --------------
# Evaluating on MS-CXR-T Temporal Sentence Similarity v1
# test_p_ent_embeddings.shape: (141, 128)
# test_h_ent_embeddings.shape: (141, 128)
# test_p_con_embeddings.shape: (220, 128)
# test_h_con_embeddings.shape: (220, 128)
# test_ent_cosine_sim.shape: (141,)
# test_con_cosine_sim.shape: (220,)
# entailment_acc: 0.7872340425531915
# contradiction_acc: 0.7636363636363637
# test_acc: 0.7754352030947775
# --------------

# %% [markdown]
# # BiomedVLP-BioViL-T

# %%
# !python ../eval_NLI_v2.py \
--huggingface_model_name "microsoft/BiomedVLP-BioViL-T" \
--device "GPU" \
--batch_size 200 \
--num_workers 3 \
--integrated_nli_jsonl_filepath \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(162036,21465751).jsonl"
# Out:
# script's arguments:
#    huggingface_model_name: microsoft/BiomedVLP-BioViL-T
#    model_checkpoint_folder_path: None
#    device: GPU
#    batch_size: 200
#    num_workers: 3
#    integrated_nli_jsonl_filepath: /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(162036,21465751).jsonl
#    similarity_metric: cosine
#    average_token_embeddings: False
#    calibrate_on_test_set: False
# Train entailment pairs: 26442
# Train contradiction pairs: 95777
# Example train entailment pairs:
# ('According to a report, the patient had a stress echocardiogram performed in [**State 107**] which showed no change from his [** Location **]us findings.', ' patient had stable stress echocardiogram')
# ('As compared to the previous radiograph, there is no change in position of the leads in the right atrium and right ventricle.', 'As compared to the previous radiograph, no relevant change is seen, one lead projecting over the right atrium and one over the right ventricle.')
# ('A left pectoral cardiac pacer is stable in location with the leads terminating in the right atrium and right ventricle.', 'The patient has a cardiac pacer located in the left pectoral region.')
# ('The patient began complaining of worsening pain and then was uncooperative with further history/interview.', ' The patient has severe pain. ')
# Example train contradiction pairs:
# ('The pacemaker is slightly moved from its previous position.', 'The pacemaker is unchanged in position.')
# ('Bilateral chest tubes remain in place.', 'Bilateral chest tubes arm place.')
# ('No pleural effusion is noted.', 'The patient has a minor pleural effusion.')
# ('Known left hilar mass is well appreciated on the current study.', 'Known left hilar mass is not well appreciated on the current study.')
# Test radnli entailment pairs: 102
# Test radnli contradiction pairs: 98
# Example test radnli entailment pairs:
# ('Pulmonary vascularity is not engorged.', 'The pulmonary vasculature is not engorged.')
# ('There is no pneumothorax, pulmonary edema, pneumonia, or pleural effusion.', 'There is no pneumothorax.')
# ('The cardiac silhouette is top normal.', 'The heart is not enlarged.')
# ('The pulmonary vasculature is not engorged.', 'Pulmonary vascularity is not engorged.')
# Example test radnli contradiction pairs:
# ('No pleural effusions.', 'A small left pleural effusion is also likely present.')
# ('No pleural effusion or pneumothorax is seen.', 'Moderate cardiomegaly and minimal left pleural effusion.')
# ('Small left pleural effusion is difficult to exclude.', 'There is no focal consolidation, pleural effusion or pneumothorax.')
# ('A small left pleural effusion may be present.', 'There is no pleural effusion or pneumothorax.')
# Test mscxrt entailment pairs: 141
# Test mscxrt contradiction pairs: 220
# Example test mscxrt entailment pairs:
# ('Substantial atelectasis persists in the lingula and left lower lobe.', 'There remains substantial atelectasis within the left lower lobe and lingula.')
# ('Interstitial pulmonary edema, which has increased slightly since ___.', 'Interstitial pulmonary edema has slightly progressed.')
# ('slight improvement of the mild pulmonary vascular congestion and edema.', 'slight decrease of the mild pulmonary vascular congestion and edema.')
# ('The extensive bilateral parenchymal opacities are unchanged in extent and severity.', 'The extensive bilateral parenchymal opacities are constant in extent and severity.')
# Example test mscxrt contradiction pairs:
# ('there is stable mild perihilar and interstitial edema.', 'there is new mild perihilar and interstitial edema.')
# ('moderate right pleural effusion is larger.', 'moderate right pleural effusion is unchanged.')
# ('the left pleural effusion may have slightly decreased in size.', 'the left pleural effusion may have slightly increased in size.')
# ('small - to - moderate right pleural effusion has decreased.', 'small - to - moderate right pleural effusion has increased.')
# Total sentences: 102464
#   0%|                                                | 0/102464 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=104,2678825193822464594).pkl
# len(self.cache["hashes"]) = 66343
# self.cache["embeddings"].shape = (66343, 128)
# 100%|███████████████████████████████| 102464/102464 [00:00<00:00, 428287.15it/s]
# Computing embeddings for 36121 new texts
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# 100%|█████████████████████████████████████████| 181/181 [00:16<00:00, 10.70it/s]
# Saving updated cache to /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=104,2678825193822464594).pkl
# 100%|█████████████████████████████████| 36121/36121 [00:00<00:00, 588901.07it/s]
# embeddings.shape: (102464, 128)
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (26442, 128)
# train_h_ent_embeddings.shape: (26442, 128)
# train_p_con_embeddings.shape: (95777, 128)
# train_h_con_embeddings.shape: (95777, 128)
# train_ent_cosine_sim.shape: (26442,)
# train_con_cosine_sim.shape: (95777,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 10882.06it/s]
# best_threshold: 0.7349799721090642
# best_acc: 0.6249958982804897
# best_ent_acc: 0.7297103093563271
# best_con_acc: 0.5202814872046525
# --------------
# Evaluating on RadNLI test set
# test_p_ent_embeddings.shape: (102, 128)
# test_h_ent_embeddings.shape: (102, 128)
# test_p_con_embeddings.shape: (98, 128)
# test_h_con_embeddings.shape: (98, 128)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 0.5882352941176471
# contradiction_acc: 0.9387755102040817
# test_acc: 0.7635054021608644
# --------------
# --------------
# Evaluating on MS-CXR-T Temporal Sentence Similarity v1
# test_p_ent_embeddings.shape: (141, 128)
# test_h_ent_embeddings.shape: (141, 128)
# test_p_con_embeddings.shape: (220, 128)
# test_h_con_embeddings.shape: (220, 128)
# test_ent_cosine_sim.shape: (141,)
# test_con_cosine_sim.shape: (220,)
# entailment_acc: 1.0
# contradiction_acc: 0.1
# test_acc: 0.55
# --------------

# %%
# !python ../eval_NLI_v2.py \
--huggingface_model_name "microsoft/BiomedVLP-BioViL-T" \
--device "GPU" \
--batch_size 200 \
--num_workers 3 \
--integrated_nli_jsonl_filepath \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(169025,21838032).jsonl"
# Out:
# script's arguments:
#    huggingface_model_name: microsoft/BiomedVLP-BioViL-T
#    model_name: None
#    model_checkpoint_folder_path: None
#    device: GPU
#    batch_size: 200
#    num_workers: 3
#    integrated_nli_jsonl_filepath: /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(169025,21838032).jsonl
#    similarity_metric: cosine
#    average_token_embeddings: False
#    calibrate_on_test_set: False
# Train entailment pairs: 25175
# Train contradiction pairs: 99121
# Example train entailment pairs:
# ('The mediastinal and hilar contours otherwise unremarkable.', 'Mediastinal silhouette and hilar contours are unremarkable.')
# ('The cardiomediastinal silhouette appears grossly within normal limits.', 'The cardiomediastinal silhouette appears unremarkable.')
# ('Increased interstitial markings are seen, similar in appearance when compared to prior.', "The patient's interstitial markings have not reduced since the last examination.")
# ('No evidence of acute pulmonary disease or pleural effusion is observed.', 'There is no acute pulmonary disease.')
# Example train contradiction pairs:
# ("The patient's lungs are clear with no signs of pulmonary edema.", 'There are diffuse alveolar opacities, with vascular indistinctness suggestive of moderate pulmonary edema.')
# ('right central catheter tip is in the cavoatrial junction.', 'Right central catheter tip is in the pulmonary artery.')
# ('There is increased retrocardiac opacity seen on lateral view, which may represent a healthy lung in the correct clinical setting.', 'There is increased retrocardiac opacity seen on lateral view, which may represent pneumonia in the correct clinical setting.')
# ('There is a small right-sided pneumothorax.', 'No pneumothorax is seen.')
# Test radnli entailment pairs: 102
# Test radnli contradiction pairs: 98
# Example test radnli entailment pairs:
# ('The cardiac and mediastinal silhouettes are unremarkable.', 'The cardiac silhouette is not enlarged.')
# ('The cardiac silhouette is normal in size.', 'Heart size is top normal.')
# ('The lungs are clear without focal consolidation, pleural effusion or pneumothorax.', 'No pleural effusions.')
# ('The osseous structures are grossly unremarkable, although evaluation is limited secondary to body habitus.', 'Osseous structures are without an acute abnormality.')
# Example test radnli contradiction pairs:
# ('Since the prior radiograph, no significant change in the widespread parenchymal opacities and moderate cardiomegaly.', 'Allowing for these limitation, there are no focal parenchymal opacities.')
# ('The heart is mildly enlarged, unchanged.', 'The heart is top normal in size, which is exaggerated by the low lung volumes.')
# ('No pleural effusion or pneumothorax is present.', 'There is subtle blunting of the left CP angle suggesting a tiny effusion or pleural thickening.')
# ('There is no pleural effusion or pneumothorax.', 'A small left pleural effusion may be present.')
# Test mscxrt entailment pairs: 141
# Test mscxrt contradiction pairs: 220
# Example test mscxrt entailment pairs:
# ('small right apical pneumothorax is stable.', 'small right apical pneumothorax is unchanged.')
# ('there has been interval improvement in the mild interstitial edema.', 'there has been interval decrease in the mild interstitial edema.')
# ('Interval decrease in the opacities at the right lung base.', 'Interval improvement of right lung base opacities.')
# ('Improved mild interstitial edema.', 'Improved but persistent mild interstitial edema.')
# Example test mscxrt contradiction pairs:
# ('stable moderate bilateral pleural effusions.', 'new moderate bilateral pleural effusions.')
# ('interval worsening of the right - sided pneumothorax.', 'interval resolution of the right - sided pneumothorax.')
# ('left retrocardiac opacity is unchanged.', 'left retrocardiac opacity is new.')
# ('minimal increase in the right - sided loculated hydro pneumothorax.', 'minimal decrease in the right - sided loculated hydro pneumothorax.')
# Total sentences: 98658
#   0%|                                                 | 0/98658 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=104,2678825193822464594).pkl
# len(self.cache["hashes"]) = 4452094
# self.cache["embeddings"].shape = (4452094, 128)
# 100%|██████████████████████████████████| 98658/98658 [00:06<00:00, 15660.54it/s]
# Computing embeddings for 4099 new texts
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# 100%|███████████████████████████████████████████| 21/21 [00:04<00:00,  4.35it/s]
# Saving updated cache to /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=104,2678825193822464594).pkl
# 100%|███████████████████████████████████| 4099/4099 [00:00<00:00, 186283.23it/s]
# embeddings.shape: (98658, 128)
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (25175, 128)
# train_h_ent_embeddings.shape: (25175, 128)
# train_p_con_embeddings.shape: (99121, 128)
# train_h_con_embeddings.shape: (99121, 128)
# train_ent_cosine_sim.shape: (25175,)
# train_con_cosine_sim.shape: (99121,)
# 100%|█████████████████████████████████████| 1000/1000 [00:00<00:00, 9454.38it/s]
# best_threshold: 0.709214224829688
# best_acc: 0.6119174597342217
# best_ent_acc: 0.7094736842105264
# best_con_acc: 0.5143612352579171
# --------------
# Evaluating on RadNLI test set
# test_p_ent_embeddings.shape: (102, 128)
# test_h_ent_embeddings.shape: (102, 128)
# test_p_con_embeddings.shape: (98, 128)
# test_h_con_embeddings.shape: (98, 128)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 0.5882352941176471
# contradiction_acc: 0.8979591836734694
# test_acc: 0.7430972388955582
# --------------
# --------------
# Evaluating on MS-CXR-T Temporal Sentence Similarity v1
# test_p_ent_embeddings.shape: (141, 128)
# test_h_ent_embeddings.shape: (141, 128)
# test_p_con_embeddings.shape: (220, 128)
# test_h_con_embeddings.shape: (220, 128)
# test_ent_cosine_sim.shape: (141,)
# test_con_cosine_sim.shape: (220,)
# entailment_acc: 1.0
# contradiction_acc: 0.07727272727272727
# test_acc: 0.5386363636363636
# --------------

# %%
# !python ../eval_NLI_v2.py \
--huggingface_model_name "microsoft/BiomedVLP-BioViL-T" \
--device "GPU" \
--batch_size 200 \
--num_workers 3 \
--calibrate_on_test_set
# Out:
# script's arguments:
#    huggingface_model_name: microsoft/BiomedVLP-BioViL-T
#    model_checkpoint_folder_path: None
#    device: GPU
#    batch_size: 200
#    num_workers: 3
#    integrated_nli_jsonl_filepath: None
#    similarity_metric: cosine
#    average_token_embeddings: False
#    calibrate_on_test_set: True
# Test radnli entailment pairs: 102
# Test radnli contradiction pairs: 98
# Example test radnli entailment pairs:
# ('No large pleural effusion or pneumothorax is seen.', 'There is no pneumothorax.')
# ('No pleural effusion or pneumothorax is noted.', 'No definite effusion or pneumothorax is seen.')
# ('There is no pleural effusion or pneumothorax.', 'There are no pleural effusions.')
# ('The lungs are clear without focal consolidation, pleural effusion or pneumothorax.', 'No pleural effusions.')
# Example test radnli contradiction pairs:
# ('Dense retrocardiac opacification persists, consistent with left lower lobe consolidation and small pleural effusion.', 'No pleural effusion or pneumothorax is seen.')
# ('Small right pleural effusion has decreased.', 'There is no pleural effusion or pulmonary edema.')
# ('There is subtle blunting of the left CP angle suggesting a tiny effusion or pleural thickening.', 'No pleural effusion or pneumothorax is present.')
# ('A small residual right effusion is present.', 'No pleural effusion or pneumothorax is seen.')
# Test mscxrt entailment pairs: 141
# Test mscxrt contradiction pairs: 220
# Example test mscxrt entailment pairs:
# ('interval worsening of the right - sided pneumothorax.', 'interval increase of the right - sided pneumothorax.')
# ('small right apical pneumothorax is stable.', 'small right apical pneumothorax is unchanged.')
# ('Stable extent of the pre-existing left pleural effusion.', 'Stable extent of a previously existing left pleural effusion.')
# ('slight interval improvement in moderate widespread pulmonary edema.', 'slight interval decrease in moderate widespread pulmonary edema.')
# Example test mscxrt contradiction pairs:
# ('there is interval decrease in right pleural effusion.', 'there is interval increase in right pleural effusion.')
# ('increased left basilar opacity.', 'improved left basilar opacity.')
# ('Moderate vascular congestion, which has increased in comparison to the prior.', 'moderate vascular congestion is stable.')
# ('there has been interval improvement in the mild interstitial edema.', 'there has been interval increase in the mild interstitial edema.')
# Total sentences: 825
#   0%|                                                   | 0/825 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=104,2678825193822464594).pkl
# len(self.cache["hashes"]) = 102464
# self.cache["embeddings"].shape = (102464, 128)
# 100%|███████████████████████████████████████| 825/825 [00:00<00:00, 4362.39it/s]
# embeddings.shape: (825, 128)
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (102, 128)
# train_h_ent_embeddings.shape: (102, 128)
# train_p_con_embeddings.shape: (98, 128)
# train_h_con_embeddings.shape: (98, 128)
# train_ent_cosine_sim.shape: (102,)
# train_con_cosine_sim.shape: (98,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 45935.27it/s]
# best_threshold: 0.42461222633943185
# best_acc: 0.7799119647859143
# best_ent_acc: 0.7843137254901961
# best_con_acc: 0.7755102040816326
# --------------
# Evaluating on RadNLI test set
# test_p_ent_embeddings.shape: (102, 128)
# test_h_ent_embeddings.shape: (102, 128)
# test_p_con_embeddings.shape: (98, 128)
# test_h_con_embeddings.shape: (98, 128)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 0.7843137254901961
# contradiction_acc: 0.7755102040816326
# test_acc: 0.7799119647859143
# --------------
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (141, 128)
# train_h_ent_embeddings.shape: (141, 128)
# train_p_con_embeddings.shape: (220, 128)
# train_h_con_embeddings.shape: (220, 128)
# train_ent_cosine_sim.shape: (141,)
# train_con_cosine_sim.shape: (220,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 44203.61it/s]
# best_threshold: 0.9862975983529
# best_acc: 0.8778046421663444
# best_ent_acc: 0.851063829787234
# best_con_acc: 0.9045454545454545
# --------------
# Evaluating on MS-CXR-T Temporal Sentence Similarity v1
# test_p_ent_embeddings.shape: (141, 128)
# test_h_ent_embeddings.shape: (141, 128)
# test_p_con_embeddings.shape: (220, 128)
# test_h_con_embeddings.shape: (220, 128)
# test_ent_cosine_sim.shape: (141,)
# test_con_cosine_sim.shape: (220,)
# entailment_acc: 0.851063829787234
# contradiction_acc: 0.9045454545454545
# test_acc: 0.8778046421663444
# --------------

# %% [markdown]
# # Bio_ClinicalBERT

# %%
# !python ../eval_NLI_v2.py \
--huggingface_model_name "emilyalsentzer/Bio_ClinicalBERT" \
--device "GPU" \
--batch_size 200 \
--num_workers 3 \
--integrated_nli_jsonl_filepath \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(162036,21465751).jsonl"
# Out:
# script's arguments:
#    huggingface_model_name: emilyalsentzer/Bio_ClinicalBERT
#    model_checkpoint_folder_path: None
#    device: GPU
#    batch_size: 200
#    num_workers: 3
#    integrated_nli_jsonl_filepath: /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(162036,21465751).jsonl
#    similarity_metric: cosine
#    average_token_embeddings: False
#    calibrate_on_test_set: False
# Train entailment pairs: 26442
# Train contradiction pairs: 95777
# Example train entailment pairs:
# ('The right PICC tip projects in the mid SVC.', 'Right PICC tip seen in the mid SVC.')
# ('No focal consolidation, pleural effusion or pneumothorax is otherwise noted.', 'No focal consolidation, pleural effusion or pneumothorax is definitively noted.')
# ('Heart size is and mediastinal contours appear stable from .', 'Heart size and upper mediastinal contours are stable.')
# ('No rib fractures are identified.', 'Rib fractures are not identified.')
# Example train contradiction pairs:
# ('There is a moderate left apicolateral pneumothorax with small basilar hydro-pneumothorax component.', 'Again there are areas of increased opacification bilaterally consistent with pulmonary vascular congestion and diffuse airspace opacities.')
# ('The cardiomediastinal silhouette may be very slightly smaller.', 'The cardiomediastinal silhouette has significantly enlarged.')
# ('Left lower lobe atelectasis new or worsened.', 'Left lower lobe atelectasis has nearly resolved.')
# ('Stable thoracic curve convex to the right.', "The patient's thoracic curve is convex to the left.")
# Test radnli entailment pairs: 102
# Test radnli contradiction pairs: 98
# Example test radnli entailment pairs:
# ('There is no effusion.', 'There is no pleural effusion.')
# ('The cardiomediastinal and hilar contours are within normal limits.', 'Heart and mediastinal contours appear normal.')
# ('No focal consolidation, pleural effusion, or pneumothorax is detected.', 'No pneumothorax.')
# ('The cardiac silhouette is normal in size.', 'Heart size is top normal.')
# Example test radnli contradiction pairs:
# ('No pneumothorax.', 'Known small left pneumothorax is not well seen.')
# ('There is no pulmonary edema.', 'There has been improvement in the pulmonary edema, now moderate.')
# ('Moderate right pleural effusion is likely.', 'There is no pleural effusion or pneumothorax.')
# ('No pleural effusion or pneumothorax is seen.', 'Mild pulmonary vascular congestion is present and probable trace bilateral pleural effusions.')
# Test mscxrt entailment pairs: 141
# Test mscxrt contradiction pairs: 220
# Example test mscxrt entailment pairs:
# ('Stable small left pneumothorax.', 'Stable small pneumothorax on the left.')
# ('there is unchanged mild to moderate pulmonary edema.', 'there is stable mild to moderate pulmonary edema.')
# ('Signs indicative of pulmonary edema have minimally decreased.', 'There is persistent pulmonary edema which has improved minimally.')
# ('stable moderate - sized loculated left pleural effusion.', 'unchanged moderate - sized loculated left pleural effusion.')
# Example test mscxrt contradiction pairs:
# ('small right apical pneumothorax is stable.', 'small right apical pneumothorax is new.')
# ('interval decrease in size of the left pleural effusion, which is now moderate in extent.', 'interval increase in size of the left pleural effusion, which is now moderate in extent.')
# ('subsequent decrease of and atelectasis at the right lung bases.', 'subsequent worsening of and atelectasis at the right lung bases.')
# ('mild generalized pulmonary edema has improved.', 'mild generalized pulmonary edema has resolved.')
# Total sentences: 102464
#   0%|                                                | 0/102464 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=107,1542209846559636901).pkl
# len(self.cache["hashes"]) = 66343
# self.cache["embeddings"].shape = (66343, 768)
# 100%|███████████████████████████████| 102464/102464 [00:00<00:00, 329497.95it/s]
# Computing embeddings for 36121 new texts
# Some weights of the model checkpoint at emilyalsentzer/Bio_ClinicalBERT were not used when initializing BertModel: ['cls.predictions.bias', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 100%|█████████████████████████████████████████| 181/181 [00:17<00:00, 10.36it/s]
# Saving updated cache to /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=107,1542209846559636901).pkl
# 100%|█████████████████████████████████| 36121/36121 [00:00<00:00, 510967.77it/s]
# embeddings.shape: (102464, 768)
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (26442, 768)
# train_h_ent_embeddings.shape: (26442, 768)
# train_p_con_embeddings.shape: (95777, 768)
# train_h_con_embeddings.shape: (95777, 768)
# train_ent_cosine_sim.shape: (26442,)
# train_con_cosine_sim.shape: (95777,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 11200.10it/s]
# best_threshold: -0.2526228926083944
# best_acc: 0.5000313227601616
# best_ent_acc: 1.0
# best_con_acc: 6.264552032325088e-05
# --------------
# Evaluating on RadNLI test set
# test_p_ent_embeddings.shape: (102, 768)
# test_h_ent_embeddings.shape: (102, 768)
# test_p_con_embeddings.shape: (98, 768)
# test_h_con_embeddings.shape: (98, 768)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 1.0
# contradiction_acc: 0.0
# test_acc: 0.5
# --------------
# --------------
# Evaluating on MS-CXR-T Temporal Sentence Similarity v1
# test_p_ent_embeddings.shape: (141, 768)
# test_h_ent_embeddings.shape: (141, 768)
# test_p_con_embeddings.shape: (220, 768)
# test_h_con_embeddings.shape: (220, 768)
# test_ent_cosine_sim.shape: (141,)
# test_con_cosine_sim.shape: (220,)
# entailment_acc: 1.0
# contradiction_acc: 0.0
# test_acc: 0.5
# --------------

# %%
# !python ../eval_NLI_v2.py \
--huggingface_model_name "emilyalsentzer/Bio_ClinicalBERT" \
--device "GPU" \
--batch_size 200 \
--num_workers 3 \
--integrated_nli_jsonl_filepath \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(169025,21838032).jsonl"
# Out:
# script's arguments:
#    huggingface_model_name: emilyalsentzer/Bio_ClinicalBERT
#    model_name: None
#    model_checkpoint_folder_path: None
#    device: GPU
#    batch_size: 200
#    num_workers: 3
#    integrated_nli_jsonl_filepath: /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(169025,21838032).jsonl
#    similarity_metric: cosine
#    average_token_embeddings: False
#    calibrate_on_test_set: False
# Train entailment pairs: 25175
# Train contradiction pairs: 99121
# Example train entailment pairs:
# ('Right lung focal opacity consistent with mass better delineated on same day CT. 2.', 'The patient has a mass in their right lung.')
# ('No evidence of acute pulmonary disease.', 'There is no sign of lung disease.')
# ('A right IJ central venous catheter terminates in the distal SVC, unchanged.', 'The right IJ central venous catheter is in the same position as before, ending in the distal SVC.')
# ('There is a mild interstitial pattern of opacities.', 'The chest X-ray shows some areas of cloudiness.')
# Example train contradiction pairs:
# ('The cardiac, mediastinal, and hilar contours are abnormal and changed.', 'The cardiac, mediastinal, and hilar contours are normal and unchanged.')
# ('There has been no change in the moderate residual of previously large left pleural effusion or severe left lower lobe atelectasis.', "The patient's left pleural effusion and left lower lobe atelectasis have significantly improved.")
# ('Diabetes type 1 diagnosed at age 18 months with retinopathy, neuropathy, nephropathy, status post multiple laser surgeries, as well as bilateral vitrectomies, and chronic kidney disease.', ' The patient has a normally functioning pancreas. ')
# ('Right lung atelectasis.', 'Right lung atelectasis has resolved')
# Test radnli entailment pairs: 102
# Test radnli contradiction pairs: 98
# Example test radnli entailment pairs:
# ('There is no pneumothorax or pleural effusion.', 'No pneumothorax is identified.')
# ('The cardiac silhouette is normal in size.', 'Heart size is top normal.')
# ('The cardiomediastinal and hilar contours are within normal limits.', 'Heart and mediastinal contours appear normal.')
# ('Heart size and cardiomediastinal contours are normal.', 'Heart size is normal.')
# Example test radnli contradiction pairs:
# ('Cardiomediastinal and hilar contours are unremarkable with the exception of a tortuous aorta.', 'PA and lateral chest radiographs demonstrate a normal cardiomediastinal silhouette.')
# ('No pleural effusion or pneumothorax is present.', 'The left apical pneumothorax is likely unchanged.')
# ('Mild pulmonary edema is redemonstrated, stable since prior chest x-ray.', 'No pulmonary edema is seen.')
# ('A small right pleural effusion cannot be excluded.', 'There is no pleural effusion, pneumothorax, or pulmonary edema.')
# Test mscxrt entailment pairs: 141
# Test mscxrt contradiction pairs: 220
# Example test mscxrt entailment pairs:
# ('nearly resolved bilateral pleural effusions.', 'nearly cleared bilateral pleural effusions.')
# ('moderate right pleural effusion stable.', 'moderate right pleural effusion unchanged.')
# ('mild interstitial edema elsewhere is stable.', 'mild interstitial edema elsewhere is unchanged.')
# ('Slight decrease in moderate pulmonary edema.', 'Slight improvement in moderate pulmonary edema.')
# Example test mscxrt contradiction pairs:
# ('Mild decrease in severity of pulmonary edema.', 'Mild increase in severity of the pre-existing pulmonary edema.')
# ('slight improvement of the mild pulmonary vascular congestion and edema.', 'slight worsening of the mild pulmonary vascular congestion and edema.')
# ('Interval decrease in size of a small left apical pneumothorax which is barely seen on the current examination.', 'Interval increase in size of a small left apical pneumothorax.')
# ('right pleural effusion has slightly decreased.', 'right pleural effusion has slightly increased.')
# Total sentences: 98658
#   0%|                                                 | 0/98658 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=107,1542209846559636901).pkl
# len(self.cache["hashes"]) = 144285
# self.cache["embeddings"].shape = (144285, 768)
# 100%|█████████████████████████████████| 98658/98658 [00:00<00:00, 110674.70it/s]
# Computing embeddings for 18547 new texts
# Some weights of the model checkpoint at emilyalsentzer/Bio_ClinicalBERT were not used when initializing BertModel: ['cls.predictions.transform.dense.bias', 'cls.seq_relationship.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.bias', 'cls.predictions.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 100%|███████████████████████████████████████████| 93/93 [00:15<00:00,  6.14it/s]
# Saving updated cache to /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=107,1542209846559636901).pkl
# 100%|█████████████████████████████████| 18547/18547 [00:00<00:00, 435542.20it/s]
# embeddings.shape: (98658, 768)
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (25175, 768)
# train_h_ent_embeddings.shape: (25175, 768)
# train_p_con_embeddings.shape: (99121, 768)
# train_h_con_embeddings.shape: (99121, 768)
# train_ent_cosine_sim.shape: (25175,)
# train_con_cosine_sim.shape: (99121,)
# 100%|█████████████████████████████████████| 1000/1000 [00:00<00:00, 8862.75it/s]
# best_threshold: 1.000000238418579
# best_acc: 0.5001588877855014
# best_ent_acc: 0.0003177755710029791
# best_con_acc: 1.0
# --------------
# Evaluating on RadNLI test set
# test_p_ent_embeddings.shape: (102, 768)
# test_h_ent_embeddings.shape: (102, 768)
# test_p_con_embeddings.shape: (98, 768)
# test_h_con_embeddings.shape: (98, 768)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 0.0
# contradiction_acc: 1.0
# test_acc: 0.5
# --------------
# --------------
# Evaluating on MS-CXR-T Temporal Sentence Similarity v1
# test_p_ent_embeddings.shape: (141, 768)
# test_h_ent_embeddings.shape: (141, 768)
# test_p_con_embeddings.shape: (220, 768)
# test_h_con_embeddings.shape: (220, 768)
# test_ent_cosine_sim.shape: (141,)
# test_con_cosine_sim.shape: (220,)
# entailment_acc: 0.0
# contradiction_acc: 1.0
# test_acc: 0.5
# --------------

# %%
# !python ../eval_NLI_v2.py \
--huggingface_model_name "emilyalsentzer/Bio_ClinicalBERT" \
--device "GPU" \
--batch_size 200 \
--num_workers 3 \
--calibrate_on_test_set
# Out:
# script's arguments:
#    huggingface_model_name: emilyalsentzer/Bio_ClinicalBERT
#    model_checkpoint_folder_path: None
#    device: GPU
#    batch_size: 200
#    num_workers: 3
#    integrated_nli_jsonl_filepath: None
#    similarity_metric: cosine
#    average_token_embeddings: False
#    calibrate_on_test_set: True
# Test radnli entailment pairs: 102
# Test radnli contradiction pairs: 98
# Example test radnli entailment pairs:
# ('There are likely patchy opacities in the lung bases reflective of atelectasis.', 'Improved aeration at the lung bases with residual subsegmental atelectasis at the left lung base.')
# ('The cardiomediastinal and hilar contours are normal.', 'Cardiomediastinal contours are normal.')
# ('Lungs are clear.', 'The lungs are unremarkable.')
# ('No discrete consolidation, pleural effusion, pneumothorax, or pulmonary edema is identified.', 'No pleural effusions.')
# Example test radnli contradiction pairs:
# ('There is no focal consolidation, pleural effusion or pneumothorax.', 'Pleural effusions are likely present.')
# ('Small right pleural effusion has decreased.', 'There is no pneumothorax or pleural effusion.')
# ('No pleural effusion or pneumothorax is seen.', 'The right atelectasis and pleural effusion has increased.')
# ('Moderate to large bilateral pleural effusions are again seen, likely right greater than left.', 'There is no pulmonary edema or pleural effusions.')
# Test mscxrt entailment pairs: 141
# Test mscxrt contradiction pairs: 220
# Example test mscxrt entailment pairs:
# ('on the left, the pre - existing opacities are stable in extent and severity.', 'on the left, the pre - existing opacities are unchanged in extent and severity.')
# ('left basal consolidation has slightly improved.', 'left basal consolidation has slightly decreased.')
# ('there has been interval improvement in the mild interstitial edema.', 'there has been interval decrease in the mild interstitial edema.')
# ('status post right thoracentesis with interval decrease in right pleural effusion, which is now trace in size.', 'status post right thoracentesis with interval improvement in right pleural effusion, which is now trace in size.')
# Example test mscxrt contradiction pairs:
# ('There may be a region of consolidation at the right base which has developed over the past 24 hr.', 'There is persistent consolidation at the right base, unchanged since previous.')
# ('there is a persistent small right pneumothorax.', 'there is a new small right pneumothorax.')
# ('there is interval improvement of the right lower lobe atelectasis.', 'there is interval worsening of the right lower lobe atelectasis.')
# ('In comparison with the study of ___, there is decrease in the diffuse bilateral pulmonary opacifications.', 'In comparison with the study of ___, there is worsening of the diffuse bilateral pulmonary opacifications.')
# Total sentences: 825
#   0%|                                                   | 0/825 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=107,1542209846559636901).pkl
# len(self.cache["hashes"]) = 102464
# self.cache["embeddings"].shape = (102464, 768)
# 100%|███████████████████████████████████████| 825/825 [00:00<00:00, 2733.11it/s]
# embeddings.shape: (825, 768)
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (102, 768)
# train_h_ent_embeddings.shape: (102, 768)
# train_p_con_embeddings.shape: (98, 768)
# train_h_con_embeddings.shape: (98, 768)
# train_ent_cosine_sim.shape: (102,)
# train_con_cosine_sim.shape: (98,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 44740.67it/s]
# best_threshold: 0.9739107119070517
# best_acc: 0.6095438175270108
# best_ent_acc: 0.38235294117647056
# best_con_acc: 0.8367346938775511
# --------------
# Evaluating on RadNLI test set
# test_p_ent_embeddings.shape: (102, 768)
# test_h_ent_embeddings.shape: (102, 768)
# test_p_con_embeddings.shape: (98, 768)
# test_h_con_embeddings.shape: (98, 768)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 0.38235294117647056
# contradiction_acc: 0.8367346938775511
# test_acc: 0.6095438175270108
# --------------
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (141, 768)
# train_h_ent_embeddings.shape: (141, 768)
# train_p_con_embeddings.shape: (220, 768)
# train_h_con_embeddings.shape: (220, 768)
# train_ent_cosine_sim.shape: (141,)
# train_con_cosine_sim.shape: (220,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 44260.05it/s]
# best_threshold: 0.996637875313038
# best_acc: 0.5262894906511928
# best_ent_acc: 0.18439716312056736
# best_con_acc: 0.8681818181818182
# --------------
# Evaluating on MS-CXR-T Temporal Sentence Similarity v1
# test_p_ent_embeddings.shape: (141, 768)
# test_h_ent_embeddings.shape: (141, 768)
# test_p_con_embeddings.shape: (220, 768)
# test_h_con_embeddings.shape: (220, 768)
# test_ent_cosine_sim.shape: (141,)
# test_con_cosine_sim.shape: (220,)
# entailment_acc: 0.18439716312056736
# contradiction_acc: 0.8681818181818182
# test_acc: 0.5262894906511928
# --------------

# %%
# !python ../eval_NLI_v2.py \
--huggingface_model_name "emilyalsentzer/Bio_ClinicalBERT" \
--device "GPU" \
--batch_size 200 \
--num_workers 3 \
--integrated_nli_jsonl_filepath \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(162036,21465751).jsonl" \
--average_token_embeddings
# Out:
# script's arguments:
#    huggingface_model_name: emilyalsentzer/Bio_ClinicalBERT
#    model_checkpoint_folder_path: None
#    device: GPU
#    batch_size: 200
#    num_workers: 3
#    integrated_nli_jsonl_filepath: /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(162036,21465751).jsonl
#    similarity_metric: cosine
#    average_token_embeddings: True
#    calibrate_on_test_set: False
# Train entailment pairs: 26442
# Train contradiction pairs: 95777
# Example train entailment pairs:
# ('Old healed right-sided rib fractures are again identified.', 'Multiple right-sided rib fractures are again demonstrated.')
# ('In comparison with the study of , there again is substantial enlargement of the cardiac silhouette with mild to moderate pulmonary edema and bilateral pleural effusions with compressive atelectasis at the bases.', 'In comparison with the study of , there is continued enlargement of the cardiac silhouette with pulmonary edema and bilateral pleural effusions with compressive atelectasis at the bases.')
# ('Minimally increasing overall small left pleural effusion as well as right basal parenchymal opacity, likely reflecting atelectasis, given the elevation of the right hemidiaphragm.', "The patient's chest X-ray shows signs of a small left pleural effusion and right basal parenchymal opacity.")
# ('Patient denies chills.', ' Patient has no evidence of fever')
# Example train contradiction pairs:
# ("The patient's pulmonary vessels are less engorged than in the previous study.", 'In comparison with the study of , there is increased indistinctness of engorged pulmonary vessels, consistent with volume overload.')
# ('The fracture of the most superior sternal wire has worsened.', 'A fracture of the most superior sternal wire is unchanged.')
# ('The patient has a minor pleural effusion.', 'No pleural effusion is noted.')
# ('There is mild atelectasis in the lung bases.', 'There is no atelectasis in the lung bases.')
# Test radnli entailment pairs: 102
# Test radnli contradiction pairs: 98
# Example test radnli entailment pairs:
# ('There is no focal consolidation, effusion, or pneumothorax.', 'There is no pneumothorax.')
# ('The lungs are clear without consolidation, effusion, or pneumothorax.', 'No pneumothorax is identified.')
# ('The lungs are clear bilaterally without focal consolidation, effusion, or pneumothorax.', 'No pneumothorax or pleural effusion is present.')
# ('Hilar and mediastinal silhouettes are unremarkable.', 'The mediastinal and hilar contours are normal.')
# Example test radnli contradiction pairs:
# ('No pleural effusion or pneumothorax is seen.', 'There is a small pneumothorax in the left apex.')
# ('There are unchanged small bilateral layering pleural effusions.', 'No pleural effusion or pneumothorax is seen on this supine exam.')
# ('There is no pulmonary edema or pleural effusions.', 'Moderate to large bilateral pleural effusions are again seen, likely right greater than left.')
# ('A small right pleural effusion cannot be excluded.', 'There is no pleural effusion, pneumothorax, or pulmonary edema.')
# Test mscxrt entailment pairs: 141
# Test mscxrt contradiction pairs: 220
# Example test mscxrt entailment pairs:
# ('mild edema in the left lung has worsened, probably a function of reexpansion and general mild edema.', 'mild edema in the left lung has increased, probably a function of reexpansion and general mild edema.')
# ('the right basal consolidation is unchanged.', 'the right basal consolidation is stable.')
# ('slightly increased moderate pulmonary edema.', 'slightly worsened moderate pulmonary edema.')
# ('mild - to - moderate degree of left basilar atelectasis is stable.', 'mild - to - moderate degree of left basilar atelectasis is unchanged.')
# Example test mscxrt contradiction pairs:
# ('there is interval improvement of the right lower lobe atelectasis.', 'there is interval worsening of the right lower lobe atelectasis.')
# ('possible slight worsening of hazy opacity at right base.', 'possible slight improvement of hazy opacity at right base.')
# ('Moderate bibasilar atelectasis has worsened since ___.', 'Moderate bibasilar atelectasis is stable.')
# ('minimal increase in the right - sided loculated hydro pneumothorax.', 'minimal decrease in the right - sided loculated hydro pneumothorax.')
# Total sentences: 102464
#   0%|                                                | 0/102464 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=132,412155249657523952).pkl
# len(self.cache["hashes"]) = 66343
# self.cache["embeddings"].shape = (66343, 768)
# 100%|███████████████████████████████| 102464/102464 [00:00<00:00, 325608.53it/s]
# Computing embeddings for 36121 new texts
# Some weights of the model checkpoint at emilyalsentzer/Bio_ClinicalBERT were not used when initializing BertModel: ['cls.predictions.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 100%|█████████████████████████████████████████| 181/181 [00:17<00:00, 10.33it/s]
# Saving updated cache to /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=132,412155249657523952).pkl
# 100%|█████████████████████████████████| 36121/36121 [00:00<00:00, 507806.19it/s]
# embeddings.shape: (102464, 768)
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (26442, 768)
# train_h_ent_embeddings.shape: (26442, 768)
# train_p_con_embeddings.shape: (95777, 768)
# train_h_con_embeddings.shape: (95777, 768)
# train_ent_cosine_sim.shape: (26442,)
# train_con_cosine_sim.shape: (95777,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 11608.79it/s]
# best_threshold: 0.6602070313674193
# best_acc: 0.5000052204600269
# best_ent_acc: 1.0
# best_con_acc: 1.0440920053875148e-05
# --------------
# Evaluating on RadNLI test set
# test_p_ent_embeddings.shape: (102, 768)
# test_h_ent_embeddings.shape: (102, 768)
# test_p_con_embeddings.shape: (98, 768)
# test_h_con_embeddings.shape: (98, 768)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 1.0
# contradiction_acc: 0.0
# test_acc: 0.5
# --------------
# --------------
# Evaluating on MS-CXR-T Temporal Sentence Similarity v1
# test_p_ent_embeddings.shape: (141, 768)
# test_h_ent_embeddings.shape: (141, 768)
# test_p_con_embeddings.shape: (220, 768)
# test_h_con_embeddings.shape: (220, 768)
# test_ent_cosine_sim.shape: (141,)
# test_con_cosine_sim.shape: (220,)
# entailment_acc: 1.0
# contradiction_acc: 0.0
# test_acc: 0.5
# --------------

# %%
# !python ../eval_NLI_v2.py \
--huggingface_model_name "emilyalsentzer/Bio_ClinicalBERT" \
--device "GPU" \
--batch_size 200 \
--num_workers 3 \
--integrated_nli_jsonl_filepath \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(169025,21838032).jsonl" \
--average_token_embeddings
# Out:
# script's arguments:
#    huggingface_model_name: emilyalsentzer/Bio_ClinicalBERT
#    model_name: None
#    model_checkpoint_folder_path: None
#    device: GPU
#    batch_size: 200
#    num_workers: 3
#    integrated_nli_jsonl_filepath: /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(169025,21838032).jsonl
#    similarity_metric: cosine
#    average_token_embeddings: True
#    calibrate_on_test_set: False
# Train entailment pairs: 25175
# Train contradiction pairs: 99121
# Example train entailment pairs:
# ('There is a small right pleural effusion.', 'Minimal right basal pleural effusion.')
# ('Prominence of the bilateral hila and pulmonary vascular structures is less apparent than on the prior study.', 'The visibility of the bilateral hila and pulmonary vascular structures has decreased compared to the previous study.')
# ('Unchanged areas of atelectasis and scarring in the left lung.', 'Again seen is linear scarring in the left mid zone.')
# ('This triplet emerged with spontaneous cry, required blow by oxygen, Apgars were 8 at one minute and 9 at five minutes.', ' The triplet was born before 42 weeks.')
# Example train contradiction pairs:
# ('Mild pulmonary congestion.', 'There is no pulmonary congestion.')
# ('Cardiac silhouette is within normal size.', 'Again there are low lung volumes with enlargement of the cardiac silhouette.')
# ('Prominent bilateral interstitial opacities could reflect healthy lung tissue.', 'Prominent bilateral interstitial opacities could reflect interstitial lung disease versus interstitial edema.')
# ('Bibasilar opacities cannot be effusions and or atelectasis.', 'Bibasilar opacities can be effusions and or atelectasis.')
# Test radnli entailment pairs: 102
# Test radnli contradiction pairs: 98
# Example test radnli entailment pairs:
# ('Severe cardiomegaly and cardiomediastinal hilar silhouettes are unchanged.', 'Cardiomediastinal silhouette is stable.')
# ('There are low lung volumes, though allowing for this, the lungs are clear bilaterally with no focal consolidation, effusion, or pneumothorax.', 'No pleural effusion or pneumothorax is seen.')
# ('There is no pleural effusion.', 'There is no effusion.')
# ('The lungs are clear without focal consolidation.', 'The lungs are clear.')
# Example test radnli contradiction pairs:
# ('A small left pleural effusion is also likely present.', 'No pleural effusions.')
# ('The lungs are mostly clear aside from mild lower lung atelectasis.', 'The lungs are clear bilaterally.')
# ('The small bilateral pleural effusions are unchanged in size.', 'No pleural effusions.')
# ('No pleural effusion or pneumothorax is seen.', 'The right atelectasis and pleural effusion has increased.')
# Test mscxrt entailment pairs: 141
# Test mscxrt contradiction pairs: 220
# Example test mscxrt entailment pairs:
# ('there are multifocal opacities bilaterally, unchanged.', 'there are multifocal opacities bilaterally, stable.')
# ('Widespread parenchymal opacities are unchanged.', 'Widespread parenchymal opacities are similar to previous study obtained the same day earlier.')
# ('small right pleural loculation is unchanged.', 'small right pleural loculation is stable.')
# ('there has been improvement in the pulmonary vascular congestion', 'there has been decrease in the pulmonary vascular congestion')
# Example test mscxrt contradiction pairs:
# ('small medial left pneumothorax and pneumomediastinum are unchanged.', 'small medial left pneumothorax and pneumomediastinum are new.')
# ('there has been interval improvement in the mild interstitial edema.', 'there has been interval increase in the mild interstitial edema.')
# ('small left pleural effusion stable since ___.', 'small left pleural effusion increased since ___.')
# ('pulmonary edema has also increased.', 'pulmonary edema has also improved.')
# Total sentences: 98658
#   0%|                                                 | 0/98658 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=132,412155249657523952).pkl
# len(self.cache["hashes"]) = 146286
# self.cache["embeddings"].shape = (146286, 768)
# 100%|█████████████████████████████████| 98658/98658 [00:00<00:00, 165024.00it/s]
# Computing embeddings for 18445 new texts
# Some weights of the model checkpoint at emilyalsentzer/Bio_ClinicalBERT were not used when initializing BertModel: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 100%|███████████████████████████████████████████| 93/93 [00:15<00:00,  6.02it/s]
# Saving updated cache to /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=132,412155249657523952).pkl
# 100%|█████████████████████████████████| 18445/18445 [00:00<00:00, 530838.95it/s]
# embeddings.shape: (98658, 768)
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (25175, 768)
# train_h_ent_embeddings.shape: (25175, 768)
# train_p_con_embeddings.shape: (99121, 768)
# train_h_con_embeddings.shape: (99121, 768)
# train_ent_cosine_sim.shape: (25175,)
# train_con_cosine_sim.shape: (99121,)
# 100%|█████████████████████████████████████| 1000/1000 [00:00<00:00, 7123.84it/s]
# best_threshold: 0.9996597643371101
# best_acc: 0.5092930371370503
# best_ent_acc: 0.018828202581926513
# best_con_acc: 0.9997578716921742
# --------------
# Evaluating on RadNLI test set
# test_p_ent_embeddings.shape: (102, 768)
# test_h_ent_embeddings.shape: (102, 768)
# test_p_con_embeddings.shape: (98, 768)
# test_h_con_embeddings.shape: (98, 768)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 0.0
# contradiction_acc: 1.0
# test_acc: 0.5
# --------------
# --------------
# Evaluating on MS-CXR-T Temporal Sentence Similarity v1
# test_p_ent_embeddings.shape: (141, 768)
# test_h_ent_embeddings.shape: (141, 768)
# test_p_con_embeddings.shape: (220, 768)
# test_h_con_embeddings.shape: (220, 768)
# test_ent_cosine_sim.shape: (141,)
# test_con_cosine_sim.shape: (220,)
# entailment_acc: 0.0
# contradiction_acc: 1.0
# test_acc: 0.5
# --------------

# %%
# !python ../eval_NLI_v2.py \
--huggingface_model_name "emilyalsentzer/Bio_ClinicalBERT" \
--device "GPU" \
--batch_size 100 \
--num_workers 3 \
--average_token_embeddings \
--calibrate_on_test_set
# Out:
# script's arguments:
#    huggingface_model_name: emilyalsentzer/Bio_ClinicalBERT
#    model_checkpoint_folder_path: None
#    device: GPU
#    batch_size: 100
#    num_workers: 3
#    integrated_nli_jsonl_filepath: None
#    similarity_metric: cosine
#    average_token_embeddings: True
#    calibrate_on_test_set: True
# Test radnli entailment pairs: 102
# Test radnli contradiction pairs: 98
# Example test radnli entailment pairs:
# ('The osseous structures are grossly unremarkable, although evaluation is limited secondary to body habitus.', 'Osseous structures are without an acute abnormality.')
# ('Atelectasis within the left lung base is noted, but no focal consolidation, pleural effusion or pneumothorax is present.', 'Streaky atelectasis is seen at the left lung base.')
# ('Heart size is top normal.', 'The cardiac silhouette is normal in size.')
# ('Lungs are clear.', 'Right lung is clear.')
# Example test radnli contradiction pairs:
# ('No pleural effusion or pneumothorax is seen.', 'Mild pulmonary vascular congestion is present and probable trace bilateral pleural effusions.')
# ('Small bilateral pleural effusions are noted.', 'No right-sided pleural effusion is seen.')
# ('Small right pleural effusion has decreased.', 'There is no pleural effusion or pulmonary edema.')
# ('Since the prior radiograph, no significant change in the widespread parenchymal opacities and moderate cardiomegaly.', 'Allowing for these limitation, there are no focal parenchymal opacities.')
# Test mscxrt entailment pairs: 141
# Test mscxrt contradiction pairs: 220
# Example test mscxrt entailment pairs:
# ('small left effusion has minimally increased.', 'small left effusion has minimally worsened.')
# ('stable moderate bilateral pleural effusions.', 'unchanged moderate bilateral pleural effusions.')
# ('There is a stable tiny right apical pneumothorax.', 'There remains a very tiny right apical pneumothorax, unchanged.')
# ('severe bilateral lower lobe atelectasis is unchanged.', 'severe bilateral lower lobe atelectasis is stable.')
# Example test mscxrt contradiction pairs:
# ('In comparison with the study of ___, the bilateral pulmonary opacifications have increased.', 'In comparison with the earlier study of this date, there has been some decrease in the bilateral pulmonary opacifications.')
# ('unchanged moderate right pleural effusion.', 'new moderate right pleural effusion.')
# ('significant interval decrease in size of the right pleural effusion.', 'significant interval increase in size of the right pleural effusion.')
# ('minimal increase in extent of a pre - existing right pleural effusion.', 'minimal decrease in extent of a pre - existing right pleural effusion.')
# Total sentences: 825
#   0%|                                                   | 0/825 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=132,412155249657523952).pkl
# len(self.cache["hashes"]) = 102464
# self.cache["embeddings"].shape = (102464, 768)
# 100%|███████████████████████████████████████| 825/825 [00:00<00:00, 2774.42it/s]
# embeddings.shape: (825, 768)
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (102, 768)
# train_h_ent_embeddings.shape: (102, 768)
# train_p_con_embeddings.shape: (98, 768)
# train_h_con_embeddings.shape: (98, 768)
# train_ent_cosine_sim.shape: (102,)
# train_con_cosine_sim.shape: (98,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 44659.21it/s]
# best_threshold: 0.9387002919648622
# best_acc: 0.6920768307322929
# best_ent_acc: 0.5882352941176471
# best_con_acc: 0.7959183673469388
# --------------
# Evaluating on RadNLI test set
# test_p_ent_embeddings.shape: (102, 768)
# test_h_ent_embeddings.shape: (102, 768)
# test_p_con_embeddings.shape: (98, 768)
# test_h_con_embeddings.shape: (98, 768)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 0.5882352941176471
# contradiction_acc: 0.7959183673469388
# test_acc: 0.6920768307322929
# --------------
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (141, 768)
# train_h_ent_embeddings.shape: (141, 768)
# train_p_con_embeddings.shape: (220, 768)
# train_h_con_embeddings.shape: (220, 768)
# train_ent_cosine_sim.shape: (141,)
# train_con_cosine_sim.shape: (220,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 43905.16it/s]
# best_threshold: 0.9855858240876947
# best_acc: 0.5611540941328175
# best_ent_acc: 0.6950354609929078
# best_con_acc: 0.42727272727272725
# --------------
# Evaluating on MS-CXR-T Temporal Sentence Similarity v1
# test_p_ent_embeddings.shape: (141, 768)
# test_h_ent_embeddings.shape: (141, 768)
# test_p_con_embeddings.shape: (220, 768)
# test_h_con_embeddings.shape: (220, 768)
# test_ent_cosine_sim.shape: (141,)
# test_con_cosine_sim.shape: (220,)
# entailment_acc: 0.6950354609929078
# contradiction_acc: 0.42727272727272725
# test_acc: 0.5611540941328175
# --------------

# %% [markdown]
# # BioLinkBERT-large

# %%
# !python ../eval_NLI_v2.py \
--huggingface_model_name "michiyasunaga/BioLinkBERT-large" \
--device "GPU" \
--batch_size 200 \
--num_workers 3 \
--integrated_nli_jsonl_filepath \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(162036,21465751).jsonl"
# Out:
# script's arguments:
#    huggingface_model_name: michiyasunaga/BioLinkBERT-large
#    model_checkpoint_folder_path: None
#    device: GPU
#    batch_size: 200
#    num_workers: 3
#    integrated_nli_jsonl_filepath: /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(162036,21465751).jsonl
#    similarity_metric: cosine
#    average_token_embeddings: False
#    calibrate_on_test_set: False
# Train entailment pairs: 26442
# Train contradiction pairs: 95777
# Example train entailment pairs:
# ('This could represent an area of atelectasis though developing infection cannot be completely excluded.', 'This could reflect an area of atelectasis but infection cannot be excluded in the correct clinical setting.')
# ('She has been continuing the tube feeds at 70cc/hr over 14 hours during the day (75% calculated caloric needs), but was noted to have lost 1 lb at a recent appointment.', ' the patient has a feeding tube')
# ('The right-sided approach including Swan-Ganz catheter has been removed.', 'The right Swan-Ganz catheter has been removed.')
# ('A right chest tube projects in the right mid chest and to the mediastinum.', 'A chest tube projects over the right hemithorax.')
# Example train contradiction pairs:
# ('Mild pulmonary edema has worsened, moderate cardiomegaly is stable.', 'Mild pulmonary edema has worsened, moderate cardiomegaly has improved.')
# ('There is no evidence of CHF with mild interstitial edema.', 'CHF with mild interstitial edema.')
# ('Severe cardiomegaly, without evidence of pulmonary edema.', 'Moderate cardiomegaly without evidence of overt pulmonary edema.')
# ('Midline skin is absent.', 'Midline skin are still present.')
# Test radnli entailment pairs: 102
# Test radnli contradiction pairs: 98
# Example test radnli entailment pairs:
# ('There is no focal consolidation, pleural effusion, pneumothorax, or pulmonary edema.', 'There is no pneumothorax.')
# ('Severe cardiomegaly and cardiomediastinal hilar silhouettes are unchanged.', 'Cardiomediastinal silhouette is stable.')
# ('There is no focal consolidation, pleural effusion, pneumothorax, or pulmonary edema.', 'There is no pleural effusion, focal consolidation or pneumothorax.')
# ('The mediastinal and hilar contours are normal.', 'Hilar and mediastinal silhouettes are unremarkable.')
# Example test radnli contradiction pairs:
# ('No pleural effusion or pneumothorax is seen.', 'Mild pulmonary vascular congestion is present and probable trace bilateral pleural effusions.')
# ('There is a small left pleural effusion.', 'No pleural effusion or pneumothorax is seen.')
# ('There are small bilateral pleural effusions.', 'No pleural effusion or pneumothorax is seen.')
# ('Cardiomegaly, extensive right pleural effusion with subsequent right middle and lower lung consolidations, likely to represent atelectasis, pneumonia, or a combination of both.', 'No right pleural effusion.')
# Test mscxrt entailment pairs: 141
# Test mscxrt contradiction pairs: 220
# Example test mscxrt entailment pairs:
# ('the hazy opacification at the bases has decreased.', 'the hazy opacification at the bases has improved.')
# ('No significant change in left lower lobe consolidation.', 'Persistent left lower lobe consolidation; no significant change.')
# ('Since ___, the left lower lobe has been collapsed.', 'Left lower lobe remains collapsed.')
# ('Slight decrease in moderate pulmonary edema.', 'Slight improvement in moderate pulmonary edema.')
# Example test mscxrt contradiction pairs:
# ('left basal opacity is unchanged.', 'left basal opacity is improved.')
# ('and apparent decrease in size in bilateral pleural effusions.', 'and apparent increase in size in bilateral pleural effusions.')
# ('There is worsening of the left perihilar opacity.', 'Left perihilar opacity is unchanged.')
# ('bibasal atelectasis is unchanged.', 'bibasal atelectasis is new.')
# Total sentences: 102464
#   0%|                                                | 0/102464 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=107,40983794350539675).pkl
# len(self.cache["hashes"]) = 66343
# self.cache["embeddings"].shape = (66343, 1024)
# 100%|███████████████████████████████| 102464/102464 [00:00<00:00, 307416.70it/s]
# Computing embeddings for 36121 new texts
# 100%|█████████████████████████████████████████| 181/181 [00:47<00:00,  3.81it/s]
# Saving updated cache to /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=107,40983794350539675).pkl
# 100%|█████████████████████████████████| 36121/36121 [00:00<00:00, 514266.70it/s]
# embeddings.shape: (102464, 1024)
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (26442, 1024)
# train_h_ent_embeddings.shape: (26442, 1024)
# train_p_con_embeddings.shape: (95777, 1024)
# train_h_con_embeddings.shape: (95777, 1024)
# train_ent_cosine_sim.shape: (26442,)
# train_con_cosine_sim.shape: (95777,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 11486.46it/s]
# best_threshold: 1.0
# best_acc: 0.5000567279328342
# best_ent_acc: 0.00011345586566825505
# best_con_acc: 1.0
# --------------
# Evaluating on RadNLI test set
# test_p_ent_embeddings.shape: (102, 1024)
# test_h_ent_embeddings.shape: (102, 1024)
# test_p_con_embeddings.shape: (98, 1024)
# test_h_con_embeddings.shape: (98, 1024)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 0.0
# contradiction_acc: 1.0
# test_acc: 0.5
# --------------
# --------------
# Evaluating on MS-CXR-T Temporal Sentence Similarity v1
# test_p_ent_embeddings.shape: (141, 1024)
# test_h_ent_embeddings.shape: (141, 1024)
# test_p_con_embeddings.shape: (220, 1024)
# test_h_con_embeddings.shape: (220, 1024)
# test_ent_cosine_sim.shape: (141,)
# test_con_cosine_sim.shape: (220,)
# entailment_acc: 0.0
# contradiction_acc: 1.0
# test_acc: 0.5
# --------------

# %%
# !python ../eval_NLI_v2.py \
--huggingface_model_name "michiyasunaga/BioLinkBERT-large" \
--device "GPU" \
--batch_size 200 \
--num_workers 3 \
--calibrate_on_test_set
# Out:
# script's arguments:
#    huggingface_model_name: michiyasunaga/BioLinkBERT-large
#    model_checkpoint_folder_path: None
#    device: GPU
#    batch_size: 200
#    num_workers: 3
#    integrated_nli_jsonl_filepath: None
#    similarity_metric: cosine
#    average_token_embeddings: False
#    calibrate_on_test_set: True
# Test radnli entailment pairs: 102
# Test radnli contradiction pairs: 98
# Example test radnli entailment pairs:
# ('Mediastinal silhouette and hilar contours are normal.', 'Hilar and mediastinal silhouettes are unremarkable.')
# ('No definite effusion or pneumothorax is seen.', 'No pleural effusion or pneumothorax is noted.')
# ('The lungs are clear.', 'Allowing for this, the lungs are clear.')
# ('The osseous structures are grossly unremarkable, although evaluation is limited secondary to body habitus.', 'Osseous structures are without an acute abnormality.')
# Example test radnli contradiction pairs:
# ('Mild pulmonary edema is redemonstrated, stable since prior chest x-ray.', 'No pulmonary edema is seen.')
# ('There are unchanged small bilateral layering pleural effusions.', 'No pleural effusion or pneumothorax is seen on this supine exam.')
# ('No pleural effusions.', 'The small bilateral pleural effusions are unchanged in size.')
# ('There is no pulmonary edema.', 'There has been improvement in the pulmonary edema, now moderate.')
# Test mscxrt entailment pairs: 141
# Test mscxrt contradiction pairs: 220
# Example test mscxrt entailment pairs:
# ('Slight interval decrease of bilateral pleural effusions.', 'Slight interval improvement in bilateral pleural effusions.')
# ('significant interval decrease in size of the right pleural effusion.', 'significant interval improvement in size of the right pleural effusion.')
# ('retrocardiac atelectasis is unchanged.', 'retrocardiac atelectasis is stable.')
# ('There is persistent patchy consolidation in both lung bases which is stable.', 'There is stable patchy consolidation in both lung bases.')
# Example test mscxrt contradiction pairs:
# ('stable moderate - sized loculated left pleural effusion.', 'new moderate - sized loculated left pleural effusion.')
# ('minimal increase in the right - sided loculated hydro pneumothorax.', 'minimal decrease in the right - sided loculated hydro pneumothorax.')
# ('increased left basilar opacity.', 'improved left basilar opacity.')
# ('the minimal left pleural effusion is stable.', 'the minimal left pleural effusion is new.')
# Total sentences: 825
#   0%|                                                   | 0/825 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=107,40983794350539675).pkl
# len(self.cache["hashes"]) = 102464
# self.cache["embeddings"].shape = (102464, 1024)
# 100%|███████████████████████████████████████| 825/825 [00:00<00:00, 2517.44it/s]
# embeddings.shape: (825, 1024)
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (102, 1024)
# train_h_ent_embeddings.shape: (102, 1024)
# train_p_con_embeddings.shape: (98, 1024)
# train_h_con_embeddings.shape: (98, 1024)
# train_ent_cosine_sim.shape: (102,)
# train_con_cosine_sim.shape: (98,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 43706.60it/s]
# best_threshold: 0.9334880309300618
# best_acc: 0.5572228891556623
# best_ent_acc: 0.19607843137254902
# best_con_acc: 0.9183673469387755
# --------------
# Evaluating on RadNLI test set
# test_p_ent_embeddings.shape: (102, 1024)
# test_h_ent_embeddings.shape: (102, 1024)
# test_p_con_embeddings.shape: (98, 1024)
# test_h_con_embeddings.shape: (98, 1024)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 0.19607843137254902
# contradiction_acc: 0.9183673469387755
# test_acc: 0.5572228891556623
# --------------
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (141, 1024)
# train_h_ent_embeddings.shape: (141, 1024)
# train_p_con_embeddings.shape: (220, 1024)
# train_h_con_embeddings.shape: (220, 1024)
# train_ent_cosine_sim.shape: (141,)
# train_con_cosine_sim.shape: (220,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 43161.04it/s]
# best_threshold: 0.9706439932545383
# best_acc: 0.5788684719535784
# best_ent_acc: 0.5531914893617021
# best_con_acc: 0.6045454545454545
# --------------
# Evaluating on MS-CXR-T Temporal Sentence Similarity v1
# test_p_ent_embeddings.shape: (141, 1024)
# test_h_ent_embeddings.shape: (141, 1024)
# test_p_con_embeddings.shape: (220, 1024)
# test_h_con_embeddings.shape: (220, 1024)
# test_ent_cosine_sim.shape: (141,)
# test_con_cosine_sim.shape: (220,)
# entailment_acc: 0.5531914893617021
# contradiction_acc: 0.6045454545454545
# test_acc: 0.5788684719535784
# --------------

# %%
# !python ../eval_NLI_v2.py \
--huggingface_model_name "michiyasunaga/BioLinkBERT-large" \
--device "GPU" \
--batch_size 200 \
--num_workers 3 \
--integrated_nli_jsonl_filepath \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(162036,21465751).jsonl" \
--average_token_embeddings
# Out:
# script's arguments:
#    huggingface_model_name: michiyasunaga/BioLinkBERT-large
#    model_checkpoint_folder_path: None
#    device: GPU
#    batch_size: 200
#    num_workers: 3
#    integrated_nli_jsonl_filepath: /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(162036,21465751).jsonl
#    similarity_metric: cosine
#    average_token_embeddings: True
#    calibrate_on_test_set: False
# Train entailment pairs: 26442
# Train contradiction pairs: 95777
# Example train entailment pairs:
# ('The large aneurysm was seen on a non-contrast head CT and then confirmed on an MRA.', ' Head CT and MRA were abnormal ')
# ('There is hyperexpansion of the lungs with flattening of the hemidiaphragms, consistent with chronic pulmonary disease.', 'There is hyperexpansion of the lungs with flattening of the hemidiaphragms consistent with the clinical diagnosis of chronic pulmonary disease.')
# ('Right lung is hyperexpanded but grossly clear except for a few scattered calcified granulomas.', "The patient's right lung is larger than normal and has some calcified granulomas.")
# ('There is a new right-sided pigtail catheter with interval decrease in the size of the right pleural effusion.', 'Compared to the prior exam there is a new right pigtail catheter with interval decrease in the right pleural effusion.')
# Example train contradiction pairs:
# ('There is a recurrent collection of air projecting along the lower mediastinum bilaterally.', 'There is no recurrent collection of air projecting along the lower mediastinum bilaterally.')
# ('Minimal improvement in right lower lobe atelectasis with persistent elevation of right hemidiaphragm.', 'Increase in right lower lobe atelectasis with a slight elevation of the right hemidiaphragm.')
# ('A right PICC line is again seen terminating in the upper SVC.', 'A right PICC line is seen but it does not terminate in the upper SVC.')
# ('There is volume loss in the right lung and consolidation.', 'The right lung shows no signs of volume loss or consolidation.')
# Test radnli entailment pairs: 102
# Test radnli contradiction pairs: 98
# Example test radnli entailment pairs:
# ('The lungs are hyperinflated but clear without consolidation, effusion, or pneumothorax.', 'No large effusion or pneumothorax is seen.')
# ('There is no pleural effusion, pneumothorax, or pulmonary vascular congestion.', 'Left pleural effusion has also completely resolved.')
# ('No focal consolidation, pleural effusion or pneumothorax is identified.', 'No focal infiltrate is identified.')
# ('The lungs are unremarkable.', 'The lungs are clear.')
# Example test radnli contradiction pairs:
# ('There is no pleural effusion or pneumothorax.', 'Moderate right pleural effusion is likely.')
# ('There is no pleural effusion or pneumothorax.', 'A small left pleural effusion may be present.')
# ('No pleural effusion or pneumothorax is present.', 'The left apical pneumothorax is likely unchanged.')
# ('The lungs are well expanded and clear.', 'The lungs are otherwise clear.')
# Test mscxrt entailment pairs: 141
# Test mscxrt contradiction pairs: 220
# Example test mscxrt entailment pairs:
# ('there is interval decrease in right pleural effusion.', 'there is interval improvement in right pleural effusion.')
# ('Signs indicative of pulmonary edema have minimally decreased.', 'There is persistent pulmonary edema which has improved minimally.')
# ('The extensive bilateral parenchymal opacities are unchanged in extent and severity.', 'The extensive bilateral parenchymal opacities are constant in extent and severity.')
# ('on the left, the pre - existing opacities are stable in extent and severity.', 'on the left, the pre - existing opacities are unchanged in extent and severity.')
# Example test mscxrt contradiction pairs:
# ('As compared to the previous radiograph, the known right pneumothorax is improved.', 'Right pneumothorax unchanged.')
# ('Bibasal consolidations have increased in the interim.', 'Bibasal consolidations are unchanged.')
# ('As compared to previous study from earlier the same date, a right pneumothorax has increased in size and is now moderate.', 'Compared to ___ at 09:30, there is a moderate right pneumothorax that is unchanged in size.')
# ('mild pulmonary edema on ___ has decreased.', 'mild pulmonary edema on ___ has worsened.')
# Total sentences: 102464
#   0%|                                                | 0/102464 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=132,1253761809285128054).pkl
# len(self.cache["hashes"]) = 66343
# self.cache["embeddings"].shape = (66343, 1024)
# 100%|███████████████████████████████| 102464/102464 [00:00<00:00, 304203.82it/s]
# Computing embeddings for 36121 new texts
# 100%|█████████████████████████████████████████| 181/181 [00:47<00:00,  3.82it/s]
# Saving updated cache to /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=132,1253761809285128054).pkl
# 100%|█████████████████████████████████| 36121/36121 [00:00<00:00, 511366.17it/s]
# embeddings.shape: (102464, 1024)
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (26442, 1024)
# train_h_ent_embeddings.shape: (26442, 1024)
# train_p_con_embeddings.shape: (95777, 1024)
# train_h_con_embeddings.shape: (95777, 1024)
# train_ent_cosine_sim.shape: (26442,)
# train_con_cosine_sim.shape: (95777,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 11704.10it/s]
# best_threshold: 0.9999113082885742
# best_acc: 0.5000189093109447
# best_ent_acc: 3.781862188941835e-05
# best_con_acc: 1.0
# --------------
# Evaluating on RadNLI test set
# test_p_ent_embeddings.shape: (102, 1024)
# test_h_ent_embeddings.shape: (102, 1024)
# test_p_con_embeddings.shape: (98, 1024)
# test_h_con_embeddings.shape: (98, 1024)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 0.0
# contradiction_acc: 1.0
# test_acc: 0.5
# --------------
# --------------
# Evaluating on MS-CXR-T Temporal Sentence Similarity v1
# test_p_ent_embeddings.shape: (141, 1024)
# test_h_ent_embeddings.shape: (141, 1024)
# test_p_con_embeddings.shape: (220, 1024)
# test_h_con_embeddings.shape: (220, 1024)
# test_ent_cosine_sim.shape: (141,)
# test_con_cosine_sim.shape: (220,)
# entailment_acc: 0.0
# contradiction_acc: 1.0
# test_acc: 0.5
# --------------

# %%
# !python ../eval_NLI_v2.py \
--huggingface_model_name "michiyasunaga/BioLinkBERT-large" \
--device "GPU" \
--batch_size 200 \
--num_workers 3 \
--integrated_nli_jsonl_filepath \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(169025,21838032).jsonl" \
--average_token_embeddings
# Out:
# script's arguments:
#    huggingface_model_name: michiyasunaga/BioLinkBERT-large
#    model_name: None
#    model_checkpoint_folder_path: None
#    device: GPU
#    batch_size: 200
#    num_workers: 3
#    integrated_nli_jsonl_filepath: /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(169025,21838032).jsonl
#    similarity_metric: cosine
#    average_token_embeddings: True
#    calibrate_on_test_set: False
# Train entailment pairs: 25175
# Train contradiction pairs: 99121
# Example train entailment pairs:
# ('Cardiac silhouette remains at the upper limits of normal.', 'The cardiac silhouette remains at the upper limits of normal.')
# ('Retrocardiac atelectasis of moderate extent.', 'Partial retrocardiac atelectasis is present.')
# ('The right subcutaneous emphysema has substantially cleared.', 'Right subcutaneous emphysema is minimal.')
# ('The lung volumes have slightly decreased, causing a minimally progressive appearance of the pre-existing known parenchymal opacities and the relatively extensive right pleural effusion.', "The patient's lung volumes are not at their normal levels.")
# Example train contradiction pairs:
# ('Mild venous congestion.', 'There is only arterial congestion, not venous.')
# ('The mid thoracic spine is perfectly straight.', 'Mild scoliosis of the mid thoracic spine convex to the right.')
# ('In the Emergency Room, the patient was noted to be in diabetic ketoacidosis with a finger stick blood sugar of 498 mg per deciliter with serum enduring ketones.', ' the patient has normal blood sugar')
# ('Increase in extent and severity of a pre-existing right basal parenchymal opacity.', 'Constant appearance of the postoperative right basal lateral parenchymal opacities.')
# Test radnli entailment pairs: 102
# Test radnli contradiction pairs: 98
# Example test radnli entailment pairs:
# ('No pleural effusion, edema, or pneumothorax.', 'There is no pneumothorax.')
# ('Cardiac silhouette is top-normal.', 'The heart appears top-normal in size.')
# ('No effusion or pneumothorax is seen.', 'No large pleural effusion or pneumothorax.')
# ('Lungs are clear.', 'The lungs are unremarkable.')
# Example test radnli contradiction pairs:
# ('A small right pleural effusion cannot be excluded.', 'There is no pleural effusion, pneumothorax, or pulmonary edema.')
# ('No pleural effusion or pneumothorax is seen.', 'A small residual right effusion is present.')
# ('No pleural effusion or pneumothorax is present.', 'There is subtle blunting of the left CP angle suggesting a tiny effusion or pleural thickening.')
# ('Moderate cardiomegaly and minimal left pleural effusion.', 'No pleural effusion or pneumothorax is seen.')
# Test mscxrt entailment pairs: 141
# Test mscxrt contradiction pairs: 220
# Example test mscxrt entailment pairs:
# ('bibasal atelectasis is unchanged.', 'bibasal atelectasis is stable.')
# ('small right pleural effusion is unchanged.', 'small right pleural effusion is stable.')
# ('unchanged tiny left pleural effusion.', 'stable tiny left pleural effusion.')
# ('stable small left pleural effusion.', 'unchanged small left pleural effusion.')
# Example test mscxrt contradiction pairs:
# ('Left retrocardiac consolidation is also unchanged.', 'Left retrocardiac consolidation, increased ___ to ___, warrants CT evaluation.')
# ('interval worsening of the right - sided pneumothorax.', 'interval resolution of the right - sided pneumothorax.')
# ('moderate bilateral pulmonary edema has decreased in extent and severity.', 'moderate bilateral pulmonary edema has increased in extent and severity.')
# ('Previous mild pulmonary edema has substantially improved.', 'Mild pulmonary edema has not substantially changed since the previous examination.')
# Total sentences: 98658
#   0%|                                                 | 0/98658 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=132,1253761809285128054).pkl
# len(self.cache["hashes"]) = 146286
# self.cache["embeddings"].shape = (146286, 1024)
# 100%|██████████████████████████████████| 98658/98658 [00:01<00:00, 71938.97it/s]
# Computing embeddings for 18445 new texts
# 100%|███████████████████████████████████████████| 93/93 [00:42<00:00,  2.21it/s]
# Saving updated cache to /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=132,1253761809285128054).pkl
# 100%|█████████████████████████████████| 18445/18445 [00:00<00:00, 346110.20it/s]
# embeddings.shape: (98658, 1024)
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (25175, 1024)
# train_h_ent_embeddings.shape: (25175, 1024)
# train_p_con_embeddings.shape: (99121, 1024)
# train_h_con_embeddings.shape: (99121, 1024)
# train_ent_cosine_sim.shape: (25175,)
# train_con_cosine_sim.shape: (99121,)
# 100%|█████████████████████████████████████| 1000/1000 [00:00<00:00, 8592.37it/s]
# best_threshold: 0.9994073414110445
# best_acc: 0.5093929747745845
# best_ent_acc: 0.018947368421052633
# best_con_acc: 0.9998385811281162
# --------------
# Evaluating on RadNLI test set
# test_p_ent_embeddings.shape: (102, 1024)
# test_h_ent_embeddings.shape: (102, 1024)
# test_p_con_embeddings.shape: (98, 1024)
# test_h_con_embeddings.shape: (98, 1024)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 0.0
# contradiction_acc: 1.0
# test_acc: 0.5
# --------------
# --------------
# Evaluating on MS-CXR-T Temporal Sentence Similarity v1
# test_p_ent_embeddings.shape: (141, 1024)
# test_h_ent_embeddings.shape: (141, 1024)
# test_p_con_embeddings.shape: (220, 1024)
# test_h_con_embeddings.shape: (220, 1024)
# test_ent_cosine_sim.shape: (141,)
# test_con_cosine_sim.shape: (220,)
# entailment_acc: 0.0
# contradiction_acc: 1.0
# test_acc: 0.5
# --------------

# %%
# !python ../eval_NLI_v2.py \
--huggingface_model_name "michiyasunaga/BioLinkBERT-large" \
--device "GPU" \
--batch_size 200 \
--num_workers 3 \
--average_token_embeddings \
--calibrate_on_test_set
# Out:
# script's arguments:
#    huggingface_model_name: michiyasunaga/BioLinkBERT-large
#    model_checkpoint_folder_path: None
#    device: GPU
#    batch_size: 200
#    num_workers: 3
#    integrated_nli_jsonl_filepath: None
#    similarity_metric: cosine
#    average_token_embeddings: True
#    calibrate_on_test_set: True
# Test radnli entailment pairs: 102
# Test radnli contradiction pairs: 98
# Example test radnli entailment pairs:
# ('The cardiomediastinal silhouette and pulmonary vasculature are normal.', 'Pulmonary vascularity is normal.')
# ('Severe cardiomegaly and cardiomediastinal hilar silhouettes are unchanged.', 'Cardiomediastinal silhouette is stable.')
# ('Cardiomediastinal and hilar contours are within normal limits.', 'The cardiomediastinal silhouette is within normal limits.')
# ('The lungs are clear.', 'Allowing for this, the lungs are clear.')
# Example test radnli contradiction pairs:
# ('There is no pleural effusion or pneumothorax.', 'Interval placement of right-sided chest tube with apparent resolution of right pleural effusion but development of a small pneumothorax.')
# ('Cardiac silhouette size is normal.', 'The cardiac silhouette remains enlarged.')
# ('There has been improvement in the pulmonary edema, now moderate.', 'There is no pulmonary edema.')
# ('No pulmonary edema is seen.', 'Mild pulmonary edema is redemonstrated, stable since prior chest x-ray.')
# Test mscxrt entailment pairs: 141
# Test mscxrt contradiction pairs: 220
# Example test mscxrt entailment pairs:
# ('the widespread bilateral diffuse parenchymal opacities are unchanged.', 'the widespread bilateral diffuse parenchymal opacities are stable.')
# ('small left pleural effusion stable.', 'small left pleural effusion unchanged.')
# ('As compared to the previous radiograph, the pre-existing pulmonary edema has clearly decreased in extent and severity but is still visible.', 'As compared to the previous radiograph, the pre-existing pulmonary edema has decreased in extent and severity.')
# ('Small left apical pneumothorax slightly larger today than on ___.', 'Small left apical pneumothorax is slightly bigger.')
# Example test mscxrt contradiction pairs:
# ('the extent of the pre - existing pleural effusion has substantially decreased.', 'the extent of the pre - existing pleural effusion has substantially increased.')
# ('Right basal consolidation appears to be progressed since the prior study.', 'Right basal consolidation has improved.')
# ('As compared to the previous radiograph, the extent of the pre-existing right pneumothorax has substantially increased.', 'The known right pneumothorax is not substantially changed.')
# ('the right basal consolidation is unchanged.', 'the right basal consolidation is improved.')
# Total sentences: 825
#   0%|                                                   | 0/825 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=132,1253761809285128054).pkl
# len(self.cache["hashes"]) = 102464
# self.cache["embeddings"].shape = (102464, 1024)
# 100%|███████████████████████████████████████| 825/825 [00:00<00:00, 2468.02it/s]
# embeddings.shape: (825, 1024)
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (102, 1024)
# train_h_ent_embeddings.shape: (102, 1024)
# train_p_con_embeddings.shape: (98, 1024)
# train_h_con_embeddings.shape: (98, 1024)
# train_ent_cosine_sim.shape: (102,)
# train_con_cosine_sim.shape: (98,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 43555.46it/s]
# best_threshold: 0.9542286798760697
# best_acc: 0.6593637454981993
# best_ent_acc: 0.4411764705882353
# best_con_acc: 0.8775510204081632
# --------------
# Evaluating on RadNLI test set
# test_p_ent_embeddings.shape: (102, 1024)
# test_h_ent_embeddings.shape: (102, 1024)
# test_p_con_embeddings.shape: (98, 1024)
# test_h_con_embeddings.shape: (98, 1024)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 0.4411764705882353
# contradiction_acc: 0.8775510204081632
# test_acc: 0.6593637454981993
# --------------
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (141, 1024)
# train_h_ent_embeddings.shape: (141, 1024)
# train_p_con_embeddings.shape: (220, 1024)
# train_h_con_embeddings.shape: (220, 1024)
# train_ent_cosine_sim.shape: (141,)
# train_con_cosine_sim.shape: (220,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 42773.27it/s]
# best_threshold: 0.97635623141452
# best_acc: 0.581060606060606
# best_ent_acc: 0.6666666666666666
# best_con_acc: 0.4954545454545455
# --------------
# Evaluating on MS-CXR-T Temporal Sentence Similarity v1
# test_p_ent_embeddings.shape: (141, 1024)
# test_h_ent_embeddings.shape: (141, 1024)
# test_p_con_embeddings.shape: (220, 1024)
# test_h_con_embeddings.shape: (220, 1024)
# test_ent_cosine_sim.shape: (141,)
# test_con_cosine_sim.shape: (220,)
# entailment_acc: 0.6666666666666666
# contradiction_acc: 0.4954545454545455
# test_acc: 0.581060606060606
# --------------

# %% [markdown]
# # BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext

# %%
# !python ../eval_NLI_v2.py \
--huggingface_model_name "microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext" \
--device "GPU" \
--batch_size 200 \
--num_workers 3 \
--integrated_nli_jsonl_filepath \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(162036,21465751).jsonl"
# Out:
# script's arguments:
#    huggingface_model_name: microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext
#    model_checkpoint_folder_path: None
#    device: GPU
#    batch_size: 200
#    num_workers: 3
#    integrated_nli_jsonl_filepath: /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(162036,21465751).jsonl
#    similarity_metric: cosine
#    average_token_embeddings: False
#    calibrate_on_test_set: False
# Train entailment pairs: 26442
# Train contradiction pairs: 95777
# Example train entailment pairs:
# ('The lungs are clear and there is no pleural effusion or pneumothorax.', 'There are no signs of lung disease or fluid accumulation.')
# ('Minimal streaky left lower lobe atelectasis is present.', "The patient's chest X-ray shows signs of atelectasis in the left lower lobe.")
# ('There is no displaced rib or sternal fracture.', 'There is no distracted rib fracture.')
# ('She was treated with two units of FFP, bringing her hematocrit to 15.9.', ' Her hematocrit is low ')
# Example train contradiction pairs:
# ('There are abnormalities in the osseous structures.', 'osseous structures unremarkable.')
# ('Mediastinal air is visible.', 'No pneumothorax or mediastinal air.')
# ('Thoracic aorta appears unremarkable.', 'The thoracic aorta shows signs of aneurysm.')
# ('Endotracheal tube is in place with its tip approximately 3.5 cm above the carina.', 'Endotracheal tube is essentially unchanged with the tip approximately 5 cm above the carina.')
# Test radnli entailment pairs: 102
# Test radnli contradiction pairs: 98
# Example test radnli entailment pairs:
# ('There is no pleural effusion or pneumothorax.', 'There are no pleural effusions.')
# ('No pleural effusion, edema, or pneumothorax.', 'There is no pneumothorax.')
# ('There is no pleural effusion, pneumothorax, or pulmonary vascular congestion.', 'Left pleural effusion has also completely resolved.')
# ('Widespread pulmonary opacities appear slightly more confluent at the right lung base, though there is slightly improved aeration in the retrocardiac region.', 'There are likely patchy opacities in the lung bases reflective of atelectasis.')
# Example test radnli contradiction pairs:
# ('The costophrenic angles are not fully included on the image and pleural effusions are difficult to exclude.', 'No pleural effusion or pneumothorax is clearly noted on this supine exam, though the left costophrenic angle is not completely included in the field of view.')
# ('The lungs are clear bilaterally.', 'The lungs are mostly clear aside from mild lower lung atelectasis.')
# ('Mild pulmonary vascular congestion is present and probable trace bilateral pleural effusions.', 'No pleural effusion or pneumothorax is seen.')
# ('No pleural effusion or pneumothorax is seen.', 'There is a small left pleural effusion.')
# Test mscxrt entailment pairs: 141
# Test mscxrt contradiction pairs: 220
# Example test mscxrt entailment pairs:
# ('interval improvement in mild pulmonary edema.', 'interval decrease in mild pulmonary edema.')
# ('the right basal consolidation is unchanged.', 'the right basal consolidation is stable.')
# ('small left effusion has minimally increased.', 'small left effusion has minimally worsened.')
# ('The extensive bilateral parenchymal opacities are unchanged in extent and severity.', 'The extensive bilateral parenchymal opacities are constant in extent and severity.')
# Example test mscxrt contradiction pairs:
# ('the left pleural effusion may have slightly decreased in size.', 'the left pleural effusion may have slightly increased in size.')
# ('there is a marked decrease in extent of the right pleural effusion.', 'there is a marked increase in extent of the right pleural effusion.')
# ('There is interval improvement of the right lower lobe atelectasis.', 'Interval worsening of right lower lobe atelectasis.')
# ('there is interval improvement of the right lower lobe atelectasis.', 'there is interval worsening of the right lower lobe atelectasis.')
# Total sentences: 102464
#   0%|                                                | 0/102464 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=137,1948119357925567498).pkl
# len(self.cache["hashes"]) = 66343
# self.cache["embeddings"].shape = (66343, 768)
# 100%|███████████████████████████████| 102464/102464 [00:00<00:00, 330506.98it/s]
# Computing embeddings for 36121 new texts
# Some weights of the model checkpoint at microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext were not used when initializing BertModel: ['cls.predictions.transform.dense.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.predictions.decoder.bias', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 100%|█████████████████████████████████████████| 181/181 [00:15<00:00, 11.70it/s]
# Saving updated cache to /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=137,1948119357925567498).pkl
# 100%|█████████████████████████████████| 36121/36121 [00:00<00:00, 510525.26it/s]
# embeddings.shape: (102464, 768)
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (26442, 768)
# train_h_ent_embeddings.shape: (26442, 768)
# train_p_con_embeddings.shape: (95777, 768)
# train_h_con_embeddings.shape: (95777, 768)
# train_ent_cosine_sim.shape: (26442,)
# train_con_cosine_sim.shape: (95777,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 11608.67it/s]
# best_threshold: 1.0000001192092896
# best_acc: 0.5000189093109447
# best_ent_acc: 3.781862188941835e-05
# best_con_acc: 1.0
# --------------
# Evaluating on RadNLI test set
# test_p_ent_embeddings.shape: (102, 768)
# test_h_ent_embeddings.shape: (102, 768)
# test_p_con_embeddings.shape: (98, 768)
# test_h_con_embeddings.shape: (98, 768)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 0.0
# contradiction_acc: 1.0
# test_acc: 0.5
# --------------
# --------------
# Evaluating on MS-CXR-T Temporal Sentence Similarity v1
# test_p_ent_embeddings.shape: (141, 768)
# test_h_ent_embeddings.shape: (141, 768)
# test_p_con_embeddings.shape: (220, 768)
# test_h_con_embeddings.shape: (220, 768)
# test_ent_cosine_sim.shape: (141,)
# test_con_cosine_sim.shape: (220,)
# entailment_acc: 0.0
# contradiction_acc: 1.0
# test_acc: 0.5
# --------------

# %%
# !python ../eval_NLI_v2.py \
--huggingface_model_name "microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext" \
--device "GPU" \
--batch_size 100 \
--num_workers 3 \
--calibrate_on_test_set
# Out:
# script's arguments:
#    huggingface_model_name: microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext
#    model_checkpoint_folder_path: None
#    device: GPU
#    batch_size: 100
#    num_workers: 3
#    integrated_nli_jsonl_filepath: None
#    similarity_metric: cosine
#    average_token_embeddings: False
#    calibrate_on_test_set: True
# Test radnli entailment pairs: 102
# Test radnli contradiction pairs: 98
# Example test radnli entailment pairs:
# ('Severe cardiomegaly and cardiomediastinal hilar silhouettes are unchanged.', 'Cardiomediastinal silhouette is stable.')
# ('The cardiomediastinal silhouette is normal and the lungs fairly well-aerated, without focal consolidation, pleural effusion, or pneumothorax.', 'There is no large pleural effusion or pneumothorax.')
# ('There is no focal consolidation, effusion, or pneumothorax.', 'There is no pneumothorax.')
# ('No focal consolidation, pleural effusion, pulmonary edema, or pneumothorax.', 'No pneumothorax is evident.')
# Example test radnli contradiction pairs:
# ('There is no pleural effusion or pneumothorax.', 'Moderate right pleural effusion is likely.')
# ('No right-sided pleural effusion is seen.', 'Small bilateral pleural effusions are noted.')
# ('Lung volumes are low, and the cardiac silhouette is enlarged.', 'Cardiac silhouette is normal in size.')
# ('No pleural effusions.', 'The small bilateral pleural effusions are unchanged in size.')
# Test mscxrt entailment pairs: 141
# Test mscxrt contradiction pairs: 220
# Example test mscxrt entailment pairs:
# ('stable size of right apical pneumothorax.', 'unchanged size of right apical pneumothorax.')
# ('Substantial decrease in extent of the pre-existing right pleural effusion.', 'As compared to the previous examination, there is a substantial decrease in extent of the known right pleural effusion.')
# ('left retrocardiac opacity is unchanged.', 'left retrocardiac opacity is stable.')
# ('There is persistent patchy consolidation in both lung bases which is stable.', 'There is stable patchy consolidation in both lung bases.')
# Example test mscxrt contradiction pairs:
# ('significant interval decrease in size of the right pleural effusion.', 'significant interval increase in size of the right pleural effusion.')
# ('Interval decrease in size of a small left apical pneumothorax which is barely seen on the current examination.', 'Interval increase in size of a small left apical pneumothorax.')
# ('stable mild pulmonary edema.', 'new mild pulmonary edema.')
# ('Moderate vascular congestion, which has increased in comparison to the prior.', 'moderate vascular congestion is stable.')
# Total sentences: 825
#   0%|                                                   | 0/825 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=137,1948119357925567498).pkl
# len(self.cache["hashes"]) = 102464
# self.cache["embeddings"].shape = (102464, 768)
# 100%|███████████████████████████████████████| 825/825 [00:00<00:00, 2877.48it/s]
# embeddings.shape: (825, 768)
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (102, 768)
# train_h_ent_embeddings.shape: (102, 768)
# train_p_con_embeddings.shape: (98, 768)
# train_h_con_embeddings.shape: (98, 768)
# train_ent_cosine_sim.shape: (102,)
# train_con_cosine_sim.shape: (98,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 43915.28it/s]
# best_threshold: 0.9649368558560047
# best_acc: 0.6944777911164466
# best_ent_acc: 0.47058823529411764
# best_con_acc: 0.9183673469387755
# --------------
# Evaluating on RadNLI test set
# test_p_ent_embeddings.shape: (102, 768)
# test_h_ent_embeddings.shape: (102, 768)
# test_p_con_embeddings.shape: (98, 768)
# test_h_con_embeddings.shape: (98, 768)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 0.47058823529411764
# contradiction_acc: 0.9183673469387755
# test_acc: 0.6944777911164466
# --------------
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (141, 768)
# train_h_ent_embeddings.shape: (141, 768)
# train_p_con_embeddings.shape: (220, 768)
# train_h_con_embeddings.shape: (220, 768)
# train_ent_cosine_sim.shape: (141,)
# train_con_cosine_sim.shape: (220,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 44615.03it/s]
# best_threshold: 0.9721991786727676
# best_acc: 0.630883301096067
# best_ent_acc: 0.7163120567375887
# best_con_acc: 0.5454545454545454
# --------------
# Evaluating on MS-CXR-T Temporal Sentence Similarity v1
# test_p_ent_embeddings.shape: (141, 768)
# test_h_ent_embeddings.shape: (141, 768)
# test_p_con_embeddings.shape: (220, 768)
# test_h_con_embeddings.shape: (220, 768)
# test_ent_cosine_sim.shape: (141,)
# test_con_cosine_sim.shape: (220,)
# entailment_acc: 0.7163120567375887
# contradiction_acc: 0.5454545454545454
# test_acc: 0.630883301096067
# --------------

# %%
# !python ../eval_NLI_v2.py \
--huggingface_model_name "microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext" \
--device "GPU" \
--batch_size 200 \
--num_workers 3 \
--integrated_nli_jsonl_filepath \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(162036,21465751).jsonl" \
--average_token_embeddings
# Out:
# script's arguments:
#    huggingface_model_name: microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext
#    model_checkpoint_folder_path: None
#    device: GPU
#    batch_size: 200
#    num_workers: 3
#    integrated_nli_jsonl_filepath: /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(162036,21465751).jsonl
#    similarity_metric: cosine
#    average_token_embeddings: True
#    calibrate_on_test_set: False
# Train entailment pairs: 26442
# Train contradiction pairs: 95777
# Example train entailment pairs:
# ('A left-sided Port-A-Cath catheter terminates in the mid to lower SVC.', 'Left-sided Port-A-Cath tip terminates in the mid/lower SVC.')
# ('Redemonstrated are bibasilar streaky airspace opacities compatible atelectasis versus infection.', "The patient's chest X-ray shows signs of possible atelectasis or infection.")
# ('No free air is demonstrated under the diaphragms.', 'No free air underneath diaphragm.')
# ('As compared to the previous radiograph, the endotracheal tube, the nasogastric tube and the left subclavian line are unchanged.', 'As compared to the previous radiograph, the patient is still intubated and a nasogastric tube is in place.')
# Example train contradiction pairs:
# ('Right upper lobe lung lesion is redemonstrated.', 'Left upper lobe lung lesion is redemonstrated.')
# ('Unchanged normal appearance of the left hemithorax.', 'The left hemithorax has changed from its normal appearance.')
# ('No hilar or mediastinal changes.', 'Hilar changes are present.')
# ('There is a large pneumothorax on the right side.', 'There is no visible pneumothorax, pleural effusion or lung mass.')
# Test radnli entailment pairs: 102
# Test radnli contradiction pairs: 98
# Example test radnli entailment pairs:
# ('Atelectasis within the left lung base is noted, but no focal consolidation, pleural effusion or pneumothorax is present.', 'Streaky atelectasis is seen at the left lung base.')
# ('Atherosclerotic calcifications are noted at the aortic arch.', 'Mild aortic calcification noted.')
# ('Cardiomediastinal and hilar contours are within normal limits.', 'The cardiomediastinal silhouette is within normal limits.')
# ('The pulmonary vasculature is not engorged.', 'Pulmonary vascularity is not engorged.')
# Example test radnli contradiction pairs:
# ('Allowing for these limitation, there are no focal parenchymal opacities.', 'Since the prior radiograph, no significant change in the widespread parenchymal opacities and moderate cardiomegaly.')
# ('There is subtle blunting of the left CP angle suggesting a tiny effusion or pleural thickening.', 'No pleural effusion or pneumothorax is present.')
# ('The lungs are well expanded and clear.', 'The lungs are otherwise clear.')
# ('Moderate cardiomegaly and mediastinal vascular engorgement is stable.', 'Cardiomediastinal and hilar silhouettes are normal.')
# Test mscxrt entailment pairs: 141
# Test mscxrt contradiction pairs: 220
# Example test mscxrt entailment pairs:
# ('Left lower lobe collapse stable.', 'Persistent left lower lobe collapse.')
# ('There is a large right-sided pneumothorax which has developed since the previous study.', 'As compared to the previous radiograph, the patient has developed a large right-sided pneumothorax.')
# ('right mid lung opacity has slightly improved.', 'right mid lung opacity has slightly decreased.')
# ('small right pleural effusion is unchanged.', 'small right pleural effusion is stable.')
# Example test mscxrt contradiction pairs:
# ('AP chest compared to ___ through ___: Previous bibasilar opacification improved substantially from ___ through ___, and has subsequently worsened.', 'Bibasilar opacities have not substantially changed.')
# ('right apical linear opacity is unchanged.', 'right apical linear opacity is new.')
# ('Atelectasis in the left mid lung is new.', 'Atelectasis at the left mid lung is unchanged.')
# ('there is interval decrease in right pleural effusion.', 'there is interval increase in right pleural effusion.')
# Total sentences: 102464
#   0%|                                                | 0/102464 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=162,1758876944325999998).pkl
# len(self.cache["hashes"]) = 66343
# self.cache["embeddings"].shape = (66343, 768)
# 100%|███████████████████████████████| 102464/102464 [00:00<00:00, 331128.33it/s]
# Computing embeddings for 36121 new texts
# Some weights of the model checkpoint at microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext were not used when initializing BertModel: ['cls.predictions.transform.dense.weight', 'cls.seq_relationship.bias', 'cls.predictions.decoder.bias', 'cls.predictions.decoder.weight', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 100%|█████████████████████████████████████████| 181/181 [00:15<00:00, 11.64it/s]
# Saving updated cache to /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=162,1758876944325999998).pkl
# 100%|█████████████████████████████████| 36121/36121 [00:00<00:00, 522717.86it/s]
# embeddings.shape: (102464, 768)
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (26442, 768)
# train_h_ent_embeddings.shape: (26442, 768)
# train_p_con_embeddings.shape: (95777, 768)
# train_h_con_embeddings.shape: (95777, 768)
# train_ent_cosine_sim.shape: (26442,)
# train_con_cosine_sim.shape: (95777,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 11723.14it/s]
# best_threshold: 0.8331254124641418
# best_acc: 0.5
# best_ent_acc: 1.0
# best_con_acc: 0.0
# --------------
# Evaluating on RadNLI test set
# test_p_ent_embeddings.shape: (102, 768)
# test_h_ent_embeddings.shape: (102, 768)
# test_p_con_embeddings.shape: (98, 768)
# test_h_con_embeddings.shape: (98, 768)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 1.0
# contradiction_acc: 0.0
# test_acc: 0.5
# --------------
# --------------
# Evaluating on MS-CXR-T Temporal Sentence Similarity v1
# test_p_ent_embeddings.shape: (141, 768)
# test_h_ent_embeddings.shape: (141, 768)
# test_p_con_embeddings.shape: (220, 768)
# test_h_con_embeddings.shape: (220, 768)
# test_ent_cosine_sim.shape: (141,)
# test_con_cosine_sim.shape: (220,)
# entailment_acc: 1.0
# contradiction_acc: 0.0
# test_acc: 0.5
# --------------

# %%
# !python ../eval_NLI_v2.py \
--huggingface_model_name "microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext" \
--device "GPU" \
--batch_size 200 \
--num_workers 3 \
--integrated_nli_jsonl_filepath \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(169025,21838032).jsonl" \
--average_token_embeddings
# Out:
# script's arguments:
#    huggingface_model_name: microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext
#    model_name: None
#    model_checkpoint_folder_path: None
#    device: GPU
#    batch_size: 200
#    num_workers: 3
#    integrated_nli_jsonl_filepath: /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(169025,21838032).jsonl
#    similarity_metric: cosine
#    average_token_embeddings: True
#    calibrate_on_test_set: False
# Train entailment pairs: 25175
# Train contradiction pairs: 99121
# Example train entailment pairs:
# ('Pleural thickening on the right is stable.', 'Right pleural thickening is stable.')
# ('Cardiac, mediastinal and hilar contours are within normal limits.', 'The heart remains within normal limits in size.')
# ('New complete left lower lobe collapse.', "The patient's left lower lobe of the lung is not functioning properly.")
# ('Moderate to large bilateral pleural effusions are increased from .', "The patient's bilateral pleural effusions have worsened.")
# Example train contradiction pairs:
# ('There is increasing airspace consolidation at the right base concerning for pneumonia or aspiration most likely within the right middle lobe.', 'There is decreasing airspace consolidation at the right base concerning for pneumonia or aspiration most likely within the right middle lobe.')
# ('Interval decrease in right apical pneumothorax.', 'Slight increase in size of right pneumothorax.')
# ('Two subtle areas of opacity projecting over the left upper lung may be sites of infection, correlate to see if there is any external artifact that could be in that area.', 'Two clear areas are projecting over the left upper lung, indicating no signs of infection.')
# ('Left lung and right upper lobe are not clear.', 'Left lung and right upper lobe are clear.')
# Test radnli entailment pairs: 102
# Test radnli contradiction pairs: 98
# Example test radnli entailment pairs:
# ('Atherosclerotic calcifications are noted at the aortic arch.', 'Mild aortic calcification noted.')
# ('No focal consolidation, pleural effusion or pneumothorax is identified.', 'No focal infiltrate is identified.')
# ('The lungs are unremarkable.', 'Lungs are clear.')
# ('There is no pleural effusion, focal consolidation or pneumothorax.', 'There is no pneumothorax or pleural effusion.')
# Example test radnli contradiction pairs:
# ('The lungs are well expanded and clear.', 'The lungs are otherwise clear.')
# ('The lungs are mostly clear aside from mild lower lung atelectasis.', 'The lungs are clear bilaterally.')
# ('Moderate to large bilateral pleural effusions are again seen, likely right greater than left.', 'There is no pulmonary edema or pleural effusions.')
# ('No pulmonary edema is seen.', 'Mild pulmonary edema is redemonstrated, stable since prior chest x-ray.')
# Test mscxrt entailment pairs: 141
# Test mscxrt contradiction pairs: 220
# Example test mscxrt entailment pairs:
# ('slight interval improvement in moderate widespread pulmonary edema.', 'slight interval decrease in moderate widespread pulmonary edema.')
# ('Interval decrease in the opacities at the right lung base.', 'Interval improvement of right lung base opacities.')
# ('right apical linear opacity is unchanged.', 'right apical linear opacity is stable.')
# ('retrocardiac atelectasis is unchanged.', 'retrocardiac atelectasis is stable.')
# Example test mscxrt contradiction pairs:
# ('There is worsening of the left perihilar opacity.', 'Left perihilar opacity is unchanged.')
# ('A millimetric pneumothorax, that has newly appeared, is now seen on the left.', 'The millimetric left pneumothorax is unchanged.')
# ('volume of right pleural effusion, substantially loculated in the upper hemithorax, is unchanged.', 'volume of right pleural effusion, substantially loculated in the upper hemithorax, is increased.')
# ('Persistent but decreased small right apical pneumothorax.', 'Very small right apical pneumothorax is unchanged.')
# Total sentences: 98658
#   0%|                                                 | 0/98658 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=162,1758876944325999998).pkl
# len(self.cache["hashes"]) = 146286
# self.cache["embeddings"].shape = (146286, 768)
# 100%|██████████████████████████████████| 98658/98658 [00:01<00:00, 96556.88it/s]
# Computing embeddings for 18445 new texts
# Some weights of the model checkpoint at microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext were not used when initializing BertModel: ['cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias', 'cls.predictions.decoder.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 100%|███████████████████████████████████████████| 93/93 [00:13<00:00,  6.97it/s]
# Saving updated cache to /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=162,1758876944325999998).pkl
# 100%|█████████████████████████████████| 18445/18445 [00:00<00:00, 351996.66it/s]
# embeddings.shape: (98658, 768)
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (25175, 768)
# train_h_ent_embeddings.shape: (25175, 768)
# train_p_con_embeddings.shape: (99121, 768)
# train_h_con_embeddings.shape: (99121, 768)
# train_ent_cosine_sim.shape: (25175,)
# train_con_cosine_sim.shape: (99121,)
# 100%|█████████████████████████████████████| 1000/1000 [00:00<00:00, 8779.60it/s]
# best_threshold: 0.9998333156407178
# best_acc: 0.5084049169558914
# best_ent_acc: 0.018867924528301886
# best_con_acc: 0.9979419093834808
# --------------
# Evaluating on RadNLI test set
# test_p_ent_embeddings.shape: (102, 768)
# test_h_ent_embeddings.shape: (102, 768)
# test_p_con_embeddings.shape: (98, 768)
# test_h_con_embeddings.shape: (98, 768)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 0.0
# contradiction_acc: 1.0
# test_acc: 0.5
# --------------
# --------------
# Evaluating on MS-CXR-T Temporal Sentence Similarity v1
# test_p_ent_embeddings.shape: (141, 768)
# test_h_ent_embeddings.shape: (141, 768)
# test_p_con_embeddings.shape: (220, 768)
# test_h_con_embeddings.shape: (220, 768)
# test_ent_cosine_sim.shape: (141,)
# test_con_cosine_sim.shape: (220,)
# entailment_acc: 0.0
# contradiction_acc: 1.0
# test_acc: 0.5
# --------------

# %%
# !python ../eval_NLI_v2.py \
--huggingface_model_name "microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext" \
--device "GPU" \
--batch_size 100 \
--num_workers 3 \
--average_token_embeddings \
--calibrate_on_test_set
# Out:
# script's arguments:
#    huggingface_model_name: microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext
#    model_checkpoint_folder_path: None
#    device: GPU
#    batch_size: 100
#    num_workers: 3
#    integrated_nli_jsonl_filepath: None
#    similarity_metric: cosine
#    average_token_embeddings: True
#    calibrate_on_test_set: True
# Test radnli entailment pairs: 102
# Test radnli contradiction pairs: 98
# Example test radnli entailment pairs:
# ('Cardiomediastinal silhouette and hilar contours are normal.', 'Cardiomediastinal silhouette is normal size.')
# ('No focal consolidation, pleural effusion, pneumothorax, or pulmonary edema.', 'There is no pleural effusion pneumothorax.')
# ('There is no pneumothorax, pulmonary edema, pneumonia, or pleural effusion.', 'There is no pneumothorax.')
# ('The cardiomediastinal silhouette is normal.', 'The cardiomediastinal silhouette and contour are within normal limits.')
# Example test radnli contradiction pairs:
# ('There is no pleural effusion or pneumothorax in the left.', 'There is scattered atelectasis and there are tiny bilateral pleural effusions.')
# ('The heart and mediastinal contours are normal.', 'The heart appears mildly enlarged.')
# ('No pneumothoraces are present.', 'Known small left pneumothorax is not well seen.')
# ('Small left pleural effusion is difficult to exclude.', 'There is no focal consolidation, pleural effusion or pneumothorax.')
# Test mscxrt entailment pairs: 141
# Test mscxrt contradiction pairs: 220
# Example test mscxrt entailment pairs:
# ('bibasal consolidations are unchanged.', 'bibasal consolidations are stable.')
# ('large right pleural effusion stable since ___.', 'large right pleural effusion unchanged since ___.')
# ('unchanged moderate left pneumothorax.', 'stable moderate left pneumothorax.')
# ('Small left apical pneumothorax is unchanged.', 'Small left apical pneumothorax not appreciably changed since ___.')
# Example test mscxrt contradiction pairs:
# ('Interval decrease in small bilateral pleural effusions.', 'Interval development of small bilateral pleural effusion, otherwise no interval change.')
# ('slight decrease in small right pleural effusion.', 'slight improvement in small right pleural effusion.')
# ('There has been improvement of the loculated pleural effusion along the right lateral chest wall.', 'Loculated right pleural effusion along the right lateral chest wall unchanged since yesterday.')
# ('bibasilar atelectasis have improved.', 'bibasilar atelectasis have worsened.')
# Total sentences: 825
#   0%|                                                   | 0/825 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=162,1758876944325999998).pkl
# len(self.cache["hashes"]) = 102464
# self.cache["embeddings"].shape = (102464, 768)
# 100%|███████████████████████████████████████| 825/825 [00:00<00:00, 2831.34it/s]
# embeddings.shape: (825, 768)
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (102, 768)
# train_h_ent_embeddings.shape: (102, 768)
# train_p_con_embeddings.shape: (98, 768)
# train_h_con_embeddings.shape: (98, 768)
# train_ent_cosine_sim.shape: (102,)
# train_con_cosine_sim.shape: (98,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 44159.40it/s]
# best_threshold: 0.9847022324233681
# best_acc: 0.6377551020408163
# best_ent_acc: 0.5
# best_con_acc: 0.7755102040816326
# --------------
# Evaluating on RadNLI test set
# test_p_ent_embeddings.shape: (102, 768)
# test_h_ent_embeddings.shape: (102, 768)
# test_p_con_embeddings.shape: (98, 768)
# test_h_con_embeddings.shape: (98, 768)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 0.5
# contradiction_acc: 0.7755102040816326
# test_acc: 0.6377551020408163
# --------------
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (141, 768)
# train_h_ent_embeddings.shape: (141, 768)
# train_p_con_embeddings.shape: (220, 768)
# train_h_con_embeddings.shape: (220, 768)
# train_ent_cosine_sim.shape: (141,)
# train_con_cosine_sim.shape: (220,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 43934.13it/s]
# best_threshold: 0.9931069118482573
# best_acc: 0.5650548033526757
# best_ent_acc: 0.6028368794326241
# best_con_acc: 0.5272727272727272
# --------------
# Evaluating on MS-CXR-T Temporal Sentence Similarity v1
# test_p_ent_embeddings.shape: (141, 768)
# test_h_ent_embeddings.shape: (141, 768)
# test_p_con_embeddings.shape: (220, 768)
# test_h_con_embeddings.shape: (220, 768)
# test_ent_cosine_sim.shape: (141,)
# test_con_cosine_sim.shape: (220,)
# entailment_acc: 0.6028368794326241
# contradiction_acc: 0.5272727272727272
# test_acc: 0.5650548033526757
# --------------

# %% [markdown]
# # CheXbert

# %%
# !python ../eval_NLI_v2.py \
--model_name "CheXbert" \
--device "cuda" \
--batch_size 100 \
--num_workers 3 \
--integrated_nli_jsonl_filepath \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(162036,21465751).jsonl"
# Out:
# script's arguments:
#    huggingface_model_name: None
#    model_name: CheXbert
#    model_checkpoint_folder_path: None
#    device: cuda
#    batch_size: 100
#    num_workers: 3
#    integrated_nli_jsonl_filepath: /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(162036,21465751).jsonl
#    similarity_metric: cosine
#    average_token_embeddings: False
#    calibrate_on_test_set: False
# Train entailment pairs: 26442
# Train contradiction pairs: 95777
# Example train entailment pairs:
# ('Discussed with Dr. at 9:35 p.m. on via telephone.', 'The doctor was contacted for a discussion.')
# ('Again seen is atelectasis in the right middle lobe and left lower lobe, with chronic elevation of the left hemidiaphragm.', 'The lung volumes remain low with unchanged left lower lobe atelectasis and elevation of the left hemidiaphragm.')
# ('Low lung volumes and increasing right basilar opacity which may reflect atelectasis versus infection.', "The patient's lung volumes are reduced and there is an increase in opacity in the right basilar region.")
# ('Cardiac silhouette size is top normal, unchanged.', 'The size of the cardiac silhouette has remained consistent.')
# Example train contradiction pairs:
# ('Postsurgical changes of the right hemithorax are stable.', 'Postsurgical changes of the left hemithorax are stable.')
# ("The patient's heart size has remained stable and there is no sign of fluid in the lungs.", 'Continued enlargement of the cardiac silhouettes with some improvement in pulmonary edema.')
# ('Right central catheter tip is at the cavoatrial junction.', 'Left central catheter tip is at the cavoatrial junction.')
# ('Possible mild central hilar congestion.', 'Central hilar congestion is definitely absent.')
# Test radnli entailment pairs: 102
# Test radnli contradiction pairs: 98
# Example test radnli entailment pairs:
# ('Heart and mediastinal contours appear normal.', 'The cardiomediastinal and hilar contours are within normal limits.')
# ('Allowing for this, the lungs are clear.', 'The lungs are clear.')
# ('No discrete consolidation, pleural effusion, pneumothorax, or pulmonary edema is identified.', 'No pleural effusions.')
# ('The cardiomediastinal silhouette and pulmonary vasculature are normal.', 'Pulmonary vascularity is normal.')
# Example test radnli contradiction pairs:
# ('The lungs are well expanded and clear.', 'The lungs are otherwise clear.')
# ('There is no pleural effusion or pneumothorax.', 'Small right pleural effusion, similar.')
# ('Since the prior radiograph, no significant change in the widespread parenchymal opacities and moderate cardiomegaly.', 'Allowing for these limitation, there are no focal parenchymal opacities.')
# ('No pleural effusions.', 'A small left pleural effusion is also likely present.')
# Test mscxrt entailment pairs: 141
# Test mscxrt contradiction pairs: 220
# Example test mscxrt entailment pairs:
# ('Right lung consolidations are extensive, similar to previous examination.', 'Extensive consolidation on the right lung is unchanged.')
# ('unchanged moderate left pneumothorax.', 'stable moderate left pneumothorax.')
# ('There is persistent patchy consolidation in both lung bases which is stable.', 'There is stable patchy consolidation in both lung bases.')
# ('Signs indicative of pulmonary edema have minimally decreased.', 'There is persistent pulmonary edema which has improved minimally.')
# Example test mscxrt contradiction pairs:
# ('Moderate subpulmonic right pleural effusion smaller today than on ___.', 'Right moderate pleural effusion with a subpulmonic component is unchanged since ___.')
# ('minimal increase in extent of a pre - existing right basal parenchymal opacity.', 'minimal improvement in extent of a pre - existing right basal parenchymal opacity.')
# ('amount of bilateral pleural effusions is stable', 'amount of bilateral pleural effusions is increased')
# ('significant interval decrease in size of the right pleural effusion.', 'significant interval increase in size of the right pleural effusion.')
# Total sentences: 102464
# 100%|███████████████████████████████████| 102464/102464 [24:53<00:00, 68.62it/s]
# embeddings.shape: (102464, 768)
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (26442, 768)
# train_h_ent_embeddings.shape: (26442, 768)
# train_p_con_embeddings.shape: (95777, 768)
# train_h_con_embeddings.shape: (95777, 768)
# train_ent_cosine_sim.shape: (26442,)
# train_con_cosine_sim.shape: (95777,)
# 100%|█████████████████████████████████████| 1000/1000 [00:00<00:00, 6590.76it/s]
# best_threshold: 0.5983450096529407
# best_acc: 0.6007728180517138
# best_ent_acc: 0.8563270554420996
# best_con_acc: 0.3452185806613279
# --------------
# Evaluating on RadNLI test set
# test_p_ent_embeddings.shape: (102, 768)
# test_h_ent_embeddings.shape: (102, 768)
# test_p_con_embeddings.shape: (98, 768)
# test_h_con_embeddings.shape: (98, 768)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 0.9117647058823529
# contradiction_acc: 0.8571428571428571
# test_acc: 0.884453781512605
# --------------
# --------------
# Evaluating on MS-CXR-T Temporal Sentence Similarity v1
# test_p_ent_embeddings.shape: (141, 768)
# test_h_ent_embeddings.shape: (141, 768)
# test_p_con_embeddings.shape: (220, 768)
# test_h_con_embeddings.shape: (220, 768)
# test_ent_cosine_sim.shape: (141,)
# test_con_cosine_sim.shape: (220,)
# entailment_acc: 1.0
# contradiction_acc: 0.01818181818181818
# test_acc: 0.509090909090909
# --------------

# %%
# !python ../eval_NLI_v2.py \
--model_name "CheXbert" \
--device "cuda" \
--batch_size 100 \
--num_workers 3 \
--integrated_nli_jsonl_filepath \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(169025,21838032).jsonl"
# Out:
# script's arguments:
#    huggingface_model_name: None
#    model_name: CheXbert
#    model_checkpoint_folder_path: None
#    device: cuda
#    batch_size: 100
#    num_workers: 3
#    integrated_nli_jsonl_filepath: /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(169025,21838032).jsonl
#    similarity_metric: cosine
#    average_token_embeddings: False
#    calibrate_on_test_set: False
# Train entailment pairs: 25175
# Train contradiction pairs: 99121
# Example train entailment pairs:
# ('She awoke up more and she tore off her BiPAP.', ' patient is on bipap')
# ('Minimal blunting of the left costophrenic sulcus may reflect a trace pleural effusion.', 'The patient may have a small amount of fluid in the left pleural space.')
# ('He was then transferred here where his sx did not seem compatible with ACS, and his heparin gtt was discontinued. .', ' The patient was initially treated for acute coronary syndrome. ')
# ('No pneumothorax, pleural effusion, pulmonary edema, pneumothorax, or focal consolidation.', 'No appreciable pleural effusion or evidence of pneumothorax.')
# Example train contradiction pairs:
# ('The cardiomediastinal silhouette is improved.', 'The cardiomediastinal silhouette is not improved.')
# ('and multiple prior studies dating back to at least .', 'There are no prior studies available.')
# ('The right lower lobe has pneumonia, but the upper lobe is clear.', 'Right upper and lower lobe pneumonia.')
# ('Patchy bibasilar opacities may be due to infection, aspiration, and/or atelectasis.', 'Patchy bibasilar opacities are not due to infection, aspiration, and/or atelectasis.')
# Test radnli entailment pairs: 102
# Test radnli contradiction pairs: 98
# Example test radnli entailment pairs:
# ('There is no pneumothorax or pleural effusion.', 'No pneumothorax is identified.')
# ('Cardiomediastinal silhouette and hilar contours are normal.', 'The cardiac and mediastinal silhouettes are unremarkable.')
# ('The lungs are clear without focal consolidation.', 'The lungs are clear.')
# ('Lung volumes are low, and the cardiac silhouette is enlarged.', 'Lung volume is small.')
# Example test radnli contradiction pairs:
# ('No right pleural effusion.', 'Cardiomegaly, extensive right pleural effusion with subsequent right middle and lower lung consolidations, likely to represent atelectasis, pneumonia, or a combination of both.')
# ('Lung volumes are normal.', 'Heart size is normal accounting for the low lung volumes.')
# ('Moderate cardiomegaly and mediastinal vascular engorgement is stable.', 'Cardiomediastinal and hilar silhouettes are normal.')
# ('Small right pleural effusion, similar.', 'There is no pleural effusion or pneumothorax.')
# Test mscxrt entailment pairs: 141
# Test mscxrt contradiction pairs: 220
# Example test mscxrt entailment pairs:
# ('there is mild pulmonary edema, stable.', 'there is mild pulmonary edema, unchanged.')
# ('right mid lung opacity has slightly improved.', 'right mid lung opacity has slightly decreased.')
# ('the widespread bilateral diffuse parenchymal opacities are unchanged.', 'the widespread bilateral diffuse parenchymal opacities are stable.')
# ('small left pleural effusion stable since ___.', 'small left pleural effusion unchanged since ___.')
# Example test mscxrt contradiction pairs:
# ('Small bilateral apical pneumothoraces have decreased since ___.', 'Small bilateral apical pneumothoraces new since ___.')
# ('extensive diffuse consolidations have markedly worsened.', 'extensive diffuse consolidations have markedly improved.')
# ('following right thoracentesis, a moderate right pleural effusion has decreased in size.', 'following right thoracentesis, a moderate right pleural effusion has increased in size.')
# ('Small bilateral pleural effusions unchanged since ___ and slightly smaller since ___.', 'Small bilateral pleural effusions appear slightly increased but positional differences limit comparison to the previous study.')
# Total sentences: 98658
# 100%|█████████████████████████████████████| 98658/98658 [24:58<00:00, 65.84it/s]
# embeddings.shape: (98658, 768)
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (25175, 768)
# train_h_ent_embeddings.shape: (25175, 768)
# train_p_con_embeddings.shape: (99121, 768)
# train_h_con_embeddings.shape: (99121, 768)
# train_ent_cosine_sim.shape: (25175,)
# train_con_cosine_sim.shape: (99121,)
# 100%|█████████████████████████████████████| 1000/1000 [00:00<00:00, 4298.33it/s]
# best_threshold: 0.5569334764917333
# best_acc: 0.6101555969924994
# best_ent_acc: 0.8825422045680238
# best_con_acc: 0.3377689894169752
# --------------
# Evaluating on RadNLI test set
# test_p_ent_embeddings.shape: (102, 768)
# test_h_ent_embeddings.shape: (102, 768)
# test_p_con_embeddings.shape: (98, 768)
# test_h_con_embeddings.shape: (98, 768)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 0.9607843137254902
# contradiction_acc: 0.8367346938775511
# test_acc: 0.8987595038015206
# --------------
# --------------
# Evaluating on MS-CXR-T Temporal Sentence Similarity v1
# test_p_ent_embeddings.shape: (141, 768)
# test_h_ent_embeddings.shape: (141, 768)
# test_p_con_embeddings.shape: (220, 768)
# test_h_con_embeddings.shape: (220, 768)
# test_ent_cosine_sim.shape: (141,)
# test_con_cosine_sim.shape: (220,)
# entailment_acc: 1.0
# contradiction_acc: 0.01818181818181818
# test_acc: 0.509090909090909
# --------------

# %%
# !python ../eval_NLI_v2.py \
--model_name "CheXbert" \
--device "cuda" \
--batch_size 100 \
--num_workers 3 \
--calibrate_on_test_set
# Out:
# script's arguments:
#    huggingface_model_name: None
#    model_name: CheXbert
#    model_checkpoint_folder_path: None
#    device: cuda
#    batch_size: 100
#    num_workers: 3
#    integrated_nli_jsonl_filepath: None
#    similarity_metric: cosine
#    average_token_embeddings: False
#    calibrate_on_test_set: True
# Test radnli entailment pairs: 102
# Test radnli contradiction pairs: 98
# Example test radnli entailment pairs:
# ('No focal consolidation, pleural effusion, or pneumothorax.', 'No pneumothorax seen.')
# ('No pleural effusion or pneumothorax is seen.', 'There is no pleural effusion')
# ('The lungs are unremarkable.', 'Lungs are clear.')
# ('No discrete consolidation, pleural effusion, pneumothorax, or pulmonary edema is identified.', 'No pleural effusions.')
# Example test radnli contradiction pairs:
# ('In comparison to ___ portable chest radiograph, there is mild improvement of the pulmonary vascular congestion and bilateral interstitial edema.', 'There is also increased volume overload, with central venous congestion and interstitial edema.')
# ('No pulmonary edema is seen.', 'Mild pulmonary edema is redemonstrated, stable since prior chest x-ray.')
# ('No right-sided pleural effusion is seen.', 'Small bilateral pleural effusions are noted.')
# ('There is scattered atelectasis and there are tiny bilateral pleural effusions.', 'There is no pleural effusion or pneumothorax in the left.')
# Test mscxrt entailment pairs: 141
# Test mscxrt contradiction pairs: 220
# Example test mscxrt entailment pairs:
# ('In comparison with the study of ___, there is still diffuse bilateral pulmonary opacification, though slightly decreased from the previous study.', 'The diffuse bilateral pulmonary opacification is again seen, though it may be slightly less than on the previous study.')
# ('there is stable mild perihilar and interstitial edema.', 'there is unchanged mild perihilar and interstitial edema.')
# ('The extensive bilateral parenchymal opacities are unchanged in extent and severity.', 'The extensive bilateral parenchymal opacities are constant in extent and severity.')
# ('unchanged mild bilateral pulmonary edema.', 'stable mild bilateral pulmonary edema.')
# Example test mscxrt contradiction pairs:
# ('small - to - moderate right pleural effusion has decreased.', 'small - to - moderate right pleural effusion has increased.')
# ('Small bilateral pleural effusions unchanged since ___ and slightly smaller since ___.', 'Small bilateral pleural effusions appear slightly increased but positional differences limit comparison to the previous study.')
# ('left basal opacity is unchanged.', 'left basal opacity is improved.')
# ('Moderately severe pulmonary edema worsened slightly since ___.', 'AP chest compared to ___ through ___: Moderately severe pulmonary edema has improved slightly since ___.')
# Total sentences: 825
# 100%|█████████████████████████████████████████| 825/825 [00:10<00:00, 80.52it/s]
# embeddings.shape: (825, 768)
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (102, 768)
# train_h_ent_embeddings.shape: (102, 768)
# train_p_con_embeddings.shape: (98, 768)
# train_h_con_embeddings.shape: (98, 768)
# train_ent_cosine_sim.shape: (102,)
# train_con_cosine_sim.shape: (98,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 37649.15it/s]
# best_threshold: 0.5650092255961787
# best_acc: 0.9040616246498598
# best_ent_acc: 0.9509803921568627
# best_con_acc: 0.8571428571428571
# --------------
# Evaluating on RadNLI test set
# test_p_ent_embeddings.shape: (102, 768)
# test_h_ent_embeddings.shape: (102, 768)
# test_p_con_embeddings.shape: (98, 768)
# test_h_con_embeddings.shape: (98, 768)
# test_ent_cosine_sim.shape: (102,)
# test_con_cosine_sim.shape: (98,)
# entailment_acc: 0.9509803921568627
# contradiction_acc: 0.8571428571428571
# test_acc: 0.9040616246498598
# --------------
# --------------
# Calibrating threshold
# train_p_ent_embeddings.shape: (141, 768)
# train_h_ent_embeddings.shape: (141, 768)
# train_p_con_embeddings.shape: (220, 768)
# train_h_con_embeddings.shape: (220, 768)
# train_ent_cosine_sim.shape: (141,)
# train_con_cosine_sim.shape: (220,)
# 100%|████████████████████████████████████| 1000/1000 [00:00<00:00, 37120.03it/s]
# best_threshold: 0.9929838097310281
# best_acc: 0.632688588007737
# best_ent_acc: 0.574468085106383
# best_con_acc: 0.6909090909090909
# --------------
# Evaluating on MS-CXR-T Temporal Sentence Similarity v1
# test_p_ent_embeddings.shape: (141, 768)
# test_h_ent_embeddings.shape: (141, 768)
# test_p_con_embeddings.shape: (220, 768)
# test_h_con_embeddings.shape: (220, 768)
# test_ent_cosine_sim.shape: (141,)
# test_con_cosine_sim.shape: (220,)
# entailment_acc: 0.574468085106383
# contradiction_acc: 0.6909090909090909
# test_acc: 0.632688588007737
# --------------
