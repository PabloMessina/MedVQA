# %%
# %env CUDA_VISIBLE_DEVICES=0
# Out:
# env: CUDA_VISIBLE_DEVICES=0

# %%
# !ls /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/
# Out:
#  gpt-3.5-turbo-0301_parsed_sentences.jsonl
#  gpt-3.5-turbo-0613_parsed_facts__hard.jsonl
#  gpt-3.5-turbo-0613_parsed_facts__uniform.jsonl
#  gpt-3.5-turbo-0613_parsed_facts__v2.jsonl
# 'gpt-3.5-turbo-0613_parsed_facts__v2_offset=20000.jsonl'
#  gpt-3.5-turbo-0613_parsed_sentences__v2.jsonl
# 'gpt-3.5-turbo-0613_parsed_sentences__v2(uniform).jsonl'
#  gpt-3.5-turbo_parsed_backgrounds.jsonl
#  gpt-3.5-turbo_parsed_reports__backup.jsonl
#  gpt-3.5-turbo_parsed_reports.jsonl
# 'gpt-3.5-turbo_parsed_reports(old).jsonl'
#  gpt-3.5-turbo_parsed_sentences.jsonl
#  gpt-4-0613_parsed_reports.jsonl
#  gpt-4-0613_parsed_sentences.jsonl
#  gpt-4-0613_parsed_sentences__v2.jsonl

# %%
# !python ../train_seq2seq.py \
        --pretrained_checkpoint_folder_path "/mnt/data/pamessina/workspaces/medvqa-workspace/models/seq2seq/20230615_222151_sentence2facts(gpt-3.5-..tences;gpt-4-06..tences;gpt-3.5-..tences)_Seq2Seq(t5-small)/" \
        --epochs 60 \
        --batches_per_epoch 1000 \
        --batch_size 100 \
        --num_workers 3 \
        --iters_to_accumulate 2 \
        --optimizer_name "adamw" \
        --scheduler "exp-warmup+decay+cyclicdecay" \
        --lr 1e-6 \
        --warmup_decay_and_cyclic_decay_args "1e-6,3,2e-4,8,1e-6,2e-4,8,1e-6" \
        --task_name "fact2details" \
        --input_output_jsonl_filepaths \
            "/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_parsed_facts__hard.jsonl" \
            "/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_parsed_facts__uniform.jsonl" \
        --seq2seq_model_name "t5" \
        --t5_model_name "t5-small" \
        --use_amp \
        --save
# Out:
# script's arguments:
#    epochs: 60
#    batches_per_epoch: 1000
#    batch_size: 100
#    checkpoint_folder: None
#    seq2seq_model_name: t5
#    t5_model_name: t5-small
#    bart_model_name: facebook/bart-base
#    pretrained_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/seq2seq/20230615_222151_sentence2facts(gpt-3.5-..tences;gpt-4-06..tences;gpt-3.5-..tences)_Seq2Seq(t5-small)/
#    optimizer_name: adamw
#    lr: 1e-06
#    scheduler: exp-warmup+decay+cyclicdecay
#    lr_decay: 0.76
#    lr_decay_patience: 2
#    warmup_and_decay_args: None
#    warmup_and_cosine_args: None
#    warmup_decay_and_cyclic_decay_args: 1e-6,3,2e-4,8,1e-6,2e-4,8,1e-6
#    iters_to_accumulate: 2
#    override_lr: False
#    task_name: fact2details
#    val_size: 200
# ...

# %%
# !python ../train_seq2seq.py \
        --pretrained_checkpoint_folder_path "/mnt/data/pamessina/workspaces/medvqa-workspace/models/seq2seq/20230627_214323_fact2details(gpt-3.5-..__hard;gpt-3.5-..niform)_Seq2Seq(t5-small)" \
        --epochs 60 \
        --batches_per_epoch 1000 \
        --batch_size 100 \
        --num_workers 3 \
        --iters_to_accumulate 2 \
        --optimizer_name "adamw" \
        --scheduler "exp-warmup+decay+cyclicdecay" \
        --lr 1e-6 \
        --warmup_decay_and_cyclic_decay_args "1e-6,3,2e-4,8,1e-6,2e-4,8,1e-6" \
        --task_name "fact2details" \
        --input_output_jsonl_filepaths \
            "/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_parsed_facts__hard.jsonl" \
            "/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_parsed_facts__uniform.jsonl" \
        --seq2seq_model_name "t5" \
        --t5_model_name "t5-small" \
        --use_amp \
        --save
# Out:
# script's arguments:
#    epochs: 60
#    batches_per_epoch: 1000
#    batch_size: 100
#    checkpoint_folder: None
#    seq2seq_model_name: t5
#    t5_model_name: t5-small
#    bart_model_name: facebook/bart-base
#    pretrained_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/seq2seq/20230627_214323_fact2details(gpt-3.5-..__hard;gpt-3.5-..niform)_Seq2Seq(t5-small)
#    optimizer_name: adamw
#    lr: 1e-06
#    scheduler: exp-warmup+decay+cyclicdecay
#    lr_decay: 0.76
#    lr_decay_patience: 2
#    warmup_and_decay_args: None
#    warmup_and_cosine_args: None
#    warmup_decay_and_cyclic_decay_args: 1e-6,3,2e-4,8,1e-6,2e-4,8,1e-6
#    iters_to_accumulate: 2
#    override_lr: False
#    task_name: fact2details
#    val_size: 200
# ...

# %%
# !python ../train_seq2seq.py \
        --pretrained_checkpoint_folder_path "/mnt/data/pamessina/workspaces/medvqa-workspace/models/seq2seq/20230628_001338_fact2details(gpt-3.5-..__hard;gpt-3.5-..niform)_Seq2Seq(t5-small)" \
        --epochs 60 \
        --batches_per_epoch 1000 \
        --batch_size 100 \
        --num_workers 3 \
        --iters_to_accumulate 2 \
        --optimizer_name "adamw" \
        --scheduler "exp-warmup+decay+cyclicdecay" \
        --lr 1e-6 \
        --warmup_decay_and_cyclic_decay_args "1e-6,3,2e-4,8,1e-6,2e-4,8,1e-6" \
        --task_name "fact2metadata" \
        --input_output_jsonl_filepaths \
            "/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_parsed_facts__v2.jsonl" \
            "/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_parsed_facts__v2_offset=20000.jsonl" \
        --seq2seq_model_name "t5" \
        --t5_model_name "t5-small" \
        --use_amp \
        --save
# Out:
# script's arguments:
#    epochs: 60
#    batches_per_epoch: 1000
#    batch_size: 100
#    checkpoint_folder: None
#    seq2seq_model_name: t5
#    t5_model_name: t5-small
#    bart_model_name: facebook/bart-base
#    pretrained_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/seq2seq/20230628_001338_fact2details(gpt-3.5-..__hard;gpt-3.5-..niform)_Seq2Seq(t5-small)
#    optimizer_name: adamw
#    lr: 1e-06
#    scheduler: exp-warmup+decay+cyclicdecay
#    lr_decay: 0.76
#    lr_decay_patience: 2
#    warmup_and_decay_args: None
#    warmup_and_cosine_args: None
#    warmup_decay_and_cyclic_decay_args: 1e-6,3,2e-4,8,1e-6,2e-4,8,1e-6
#    iters_to_accumulate: 2
#    override_lr: False
#    task_name: fact2metadata
#    val_size: 200
# ...

# %%
# !python ../train_seq2seq.py \
        --epochs 60 \
        --batches_per_epoch 1000 \
        --batch_size 100 \
        --num_workers 3 \
        --iters_to_accumulate 2 \
        --optimizer_name "adamw" \
        --scheduler "exp-warmup+decay+cyclicdecay" \
        --lr 1e-6 \
        --warmup_decay_and_cyclic_decay_args "1e-6,3,2e-4,8,1e-6,2e-4,8,1e-6" \
        --task_name "fact2metadata" \
        --input_output_jsonl_filepaths \
            "/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_parsed_facts__v2.jsonl" \
            "/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_parsed_facts__v2_offset=20000.jsonl" \
            "/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_parsed_facts__v2_offset=40000_uniform.jsonl" \
        --seq2seq_model_name "t5" \
        --t5_model_name "t5-small" \
        --use_amp \
        --save
# Out:
# script's arguments:
#    epochs: 60
#    batches_per_epoch: 1000
#    batch_size: 100
#    checkpoint_folder: None
#    seq2seq_model_name: t5
#    t5_model_name: t5-small
#    bart_model_name: facebook/bart-base
#    pretrained_checkpoint_folder_path: None
#    optimizer_name: adamw
#    lr: 1e-06
#    scheduler: exp-warmup+decay+cyclicdecay
#    lr_decay: 0.76
#    lr_decay_patience: 2
#    warmup_and_decay_args: None
#    warmup_and_cosine_args: None
#    warmup_decay_and_cyclic_decay_args: 1e-6,3,2e-4,8,1e-6,2e-4,8,1e-6
#    iters_to_accumulate: 2
#    override_lr: False
#    task_name: fact2metadata
#    val_size: 200
# ...

# %%
# !python ../train_seq2seq.py \
--epochs 200 \
--batches_per_epoch 1000 \
--batch_size 30 \
--num_workers 3 \
--iters_to_accumulate 2 \
--optimizer_name "adamw" \
--scheduler "exp-warmup+decay+cyclicdecay" \
--lr 1e-6 \
--warmup_decay_and_cyclic_decay_args "1e-6,3,2e-4,8,1e-6,2e-4,8,1e-6" \
--task_name "fact2metadata_v2" \
--fact_to_metadata_v2_input_output_jsonl_filepaths \
"/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4o-mini_fact_to_metadata.jsonl" \
--seq2seq_model_name "t5" \
--t5_model_name "t5-small" \
--experiment_name "F2Mv2" \
--use_amp \
--save
# Out:
# script's arguments:
#    epochs: 200
#    batches_per_epoch: 1000
#    batch_size: 30
#    checkpoint_folder: None
#    seq2seq_model_name: t5
#    t5_model_name: t5-small
#    bart_model_name: facebook/bart-base
#    pretrained_checkpoint_folder_path: None
#    optimizer_name: adamw
#    lr: 1e-06
#    scheduler: exp-warmup+decay+cyclicdecay
#    lr_decay: 0.76
#    lr_decay_patience: 2
#    warmup_and_decay_args: None
#    warmup_and_cosine_args: None
#    warmup_decay_and_cyclic_decay_args: 1e-6,3,2e-4,8,1e-6,2e-4,8,1e-6
#    iters_to_accumulate: 2
#    override_lr: False
#    task_name: fact2metadata_v2
#    experiment_name: F2Mv2
#    multitask_name_list: None
#    task2weight: {}
#    val_size: 200
#    mlm_min_token_count: 20
#    mlm_masking_fraction: 0.15
#    integrated_facts_metadata_jsonl_filepath: None
#    paraphrased_inputs_jsonl_filepaths: None
#    chest_imagenome_phrases2labels_filepath: None
#    sentence_to_facts_input_output_jsonl_filepaths: None
# ...
