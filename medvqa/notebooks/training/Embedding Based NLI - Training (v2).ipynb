# %%
# %env CUDA_VISIBLE_DEVICES=2
# Out:
# env: CUDA_VISIBLE_DEVICES=2

# %%
# !python ../train_fact_embedding_NLI.py \
--epochs 200 \
--batches_per_epoch 500 \
--batch_size 1000 \
--num_workers 4 \
--iters_to_accumulate 1 \
--optimizer_name "adamw" \
--scheduler "exp-warmup+decay+cyclicdecay" \
--lr 1e-6 \
--warmup_decay_and_cyclic_decay_args "1e-6,3,9e-5,10,2e-6,9e-5,10,2e-6" \
--fact_embedding_model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240207_184445_MIMIC-CXR(triplets+classif+entcont+nli+radgraph+autoencoder)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)" \
--fact_embedding_batch_size 50 \
--fact_embedding_num_workers 4 \
--use_report_nli \
--use_report_nli_entailment_dataset \
--use_sentence2facts_for_nli \
--integrated_nli_jsonl_filepath \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(169025,21838032).jsonl" \
--sentence_to_facts_input_output_jsonl_filepaths \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_parsed_sentences__v2.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_parsed_sentences__v2(uniform).jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_facts_from_sentences(cluster-balanced,hardest)_part1.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_facts_from_sentences(cluster-balanced,hardest)_part2.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_parsed_sentences__v2.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_facts_from_sentences(cluster-balanced,hardest).jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_facts_from_sentences(cluster-balanced,hardest,conditional).jsonl" \
--integrated_report_facts_jsonl_filepath \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_report_facts(79040140).jsonl" \
--report_nli_input_output_jsonl_filepaths \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-1106-preview_fact_based_report_nli_queries(from_labels).jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-1106-preview_fact_based_report_nli_queries(from_facts).jsonl" \
--embedding_dim 128 \
--mlp_hidden_dims 512 256 128 \
--dropout 0 \
--use_amp \
--save
# Out:
# script's arguments:
#    epochs: 200
#    batches_per_epoch: 500
#    batch_size: 1000
#    num_workers: 4
#    checkpoint_folder: None
#    embedding_dim: 128
#    mlp_hidden_dims: [512, 256, 128]
#    dropout: 0.0
#    optimizer_name: adamw
#    lr: 1e-06
#    scheduler: exp-warmup+decay+cyclicdecay
#    warmup_decay_and_cyclic_decay_args: 1e-6,3,9e-5,10,2e-6,9e-5,10,2e-6
#    iters_to_accumulate: 1
#    override_lr: False
#    device: GPU
#    use_amp: True
#    integrated_nli_jsonl_filepath: /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(169025,21838032).jsonl
#    use_sentence2facts_for_nli: True
#    sentence_to_facts_input_output_jsonl_filepaths: ['/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_parsed_sentences__v2.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_parsed_sentences__v2(uniform).jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_facts_from_sentences(cluster-balanced,hardest)_part1.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_facts_from_sentences(cluster-balanced,hardest)_part2.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_parsed_sentences__v2.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_facts_from_sentences(cluster-balanced,hardest).jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_facts_from_sentences(cluster-balanced,hardest,conditional).jsonl']
#    use_anli: False
#    use_multinli: False
#    use_snli: False
#    use_report_nli: True
#    report_nli_input_output_jsonl_filepaths: ['/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-1106-preview_fact_based_report_nli_queries(from_labels).jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-1106-preview_fact_based_report_nli_queries(from_facts).jsonl']
#    use_report_nli_entailment_dataset: True
#    integrated_report_facts_jsonl_filepath: /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_report_facts(79040140).jsonl
#    fact_embedding_model_name: microsoft/BiomedVLP-CXR-BERT-specialized
#    fact_embedding_model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240207_184445_MIMIC-CXR(triplets+classif+entcont+nli+radgraph+autoencoder)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)
#    fact_embedding_batch_size: 50
#    fact_embedding_num_workers: 4
#    save: True
# ----- Training model from scratch ------
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Creating instance of BertBasedNLI ...
# EmbeddingBasedNLI
#   embedding_dim: 128
#   mlp_hidden_dims: [512, 256, 128]
#   dropout: 0.0
# --------------------------------------------------
# 3) Defining optimizer ...
# create_optimizer(): name = adamw
# --------------------------------------------------
# 4) Defining scheduler ...
# Using exp-warmup+decay+cyclicdecay scheduler: 1e-6,3,9e-5,10,2e-6,9e-5,10,2e-6
# 1e-06 3 9e-05 10 2e-06 9e-05 10 2e-06
# self.steps_to_restart = 10
# self.steps = -1
# self.initial_lr = 9e-05
# --------------------------------------------------
# 5) Creating trainer and validator engines ...
# GradientAccumulator.__init__(): num_accumulation_steps = 1, max_grad_norm = None
# --------------------------------------------------
# 6) Defining collate batch functions ...
# Loaded 19971 input/output pairs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_parsed_sentences__v2.jsonl
# Loaded 19984 input/output pairs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_parsed_sentences__v2(uniform).jsonl
# Loaded 14990 input/output pairs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_facts_from_sentences(cluster-balanced,hardest)_part1.jsonl
# Loaded 14991 input/output pairs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_facts_from_sentences(cluster-balanced,hardest)_part2.jsonl
# Loaded 9999 input/output pairs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_parsed_sentences__v2.jsonl
# Loaded 5000 input/output pairs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_facts_from_sentences(cluster-balanced,hardest).jsonl
# Loaded 9999 input/output pairs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_facts_from_sentences(cluster-balanced,hardest,conditional).jsonl
# Number of sentence2facts pairs: 90614
# Input/output example:
# Input:
# Lungs are clear though lucent and hyperinflated which likely reflect COPD.
# Output:
# ["clear lungs", "lucent lungs", "hyperinflated lungs", "lungs likely reflect COPD"]
# ----
# Loading integrated NLI from /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(169025,21838032).jsonl...
# Number of samples: 169025
# Number of sources: 7
# ----
# Loading sentence2facts input/output pairs for NLI...
# Number of entailment samples added: 214191
# ----
# Loading report NLI datasets...
# Loaded 80000 input/output pairs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-1106-preview_fact_based_report_nli_queries(from_facts).jsonl
# Loaded 58072 input/output pairs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-1106-preview_fact_based_report_nli_queries(from_labels).jsonl
# ----
# Building train NLI dataset...
# Source: gpt-4-0613 | Label: contradiction -> 79430 (4312.76)
# Example:
# Input:
# NLI1: Acute rib fractures have been detected. #H: No acute rib fractures are seen.
# Output:
# contradiction
# Source: gpt-4-1106-preview_reasoning-prompt | Label: contradiction -> 10732 (2400.52)
# Example:
# Input:
# NLI1: There is no mediastinal air. #H: Possible slight increase in mediastinal emphysema.
# Output:
# contradiction
# Source: gpt-4-0613_reasoning-prompt | Label: contradiction -> 4170 (1739.18)
# Example:
# Input:
# NLI1: Lungs are not well inflated. #H: The lungs are well aerated and clear.
# Output:
# contradiction
# Source: mednli_train | Label: contradiction -> 3744 (1672.60)
# Example:
# Input:
# NLI1: The RASP was 22 mm Hg, RVEDP 30 mm Hg, PASP 57 mm Hg, PCWP 35 mm Hg and LVEDP 40 mm Hg. #H:  the patient has normal pulmonary artery pressures
# Output:
# contradiction
# Source: mednli_dev | Label: contradiction -> 465 (695.76)
# Example:
# Input:
# NLI1: As lab results returned, the ED physicians had become concerned for impending sepsis given elevated wbc count and fever. #H:  The patient is hypothermic.
# Output:
# contradiction
# Source: mednli_test | Label: contradiction -> 474 (702.30)
# Example:
# Input:
# NLI1: She was in mild respiratory distress with a respiratory rate of 24 and was saturating 96% on 4 liters. #H:  Her vitals and O2 saturation level was normal
# Output:
# contradiction
# Source: radnli_dev | Label: contradiction -> 106 (304.54)
# Example:
# Input:
# NLI1: No acute focal pneumonia or pleural effusion. #H: Again noted are diffuse infiltrative parenchymal opacities, right worse than left; this is largely due to pulmonary edema and the right-sided pleural effusion, but underlying pneumonia cannot be excluded.
# Output:
# contradiction
# Source: report_nli_from_facts | Label: contradiction -> 14141 (2620.99)
# Example:
# Input:
# NLI1: frontal lateral views of the chest. status post median sternotomy. hyperinflated lungs. flattening of the diaphragms. chronic obstructive pulmonary disease. subtle right upper lobe scarring. evidence of right upper lobe blebs/bulla. ovoid calcified opacity best seen on the lateral view. opacity projecting retrocardiac at the inferior chest measuring 1.4 cm. opacity may represent a calcified granuloma. opacity may represent a node. opacity similar to prior. unremarkable cardiac silhouette. unremarkable mediastinal silhouette. aorta is somewhat tortuous. no focal consolidation. no pleural effusion. no evidence of pneumothorax. COPD. no acute cardiopulmonary process #H: soft tissue density nodule better appreciated on the frontal view
# Output:
# contradiction
# Source: report_nli_from_labels | Label: contradiction -> 11641 (2464.16)
# Example:
# Input:
# NLI1: post-operative mediastinal widening. increased slightly. unchanged. no tracheal displacement. heart size is top normal. band of atelectasis in the right mid lung. clear lungs. lungs without focal abnormality. mild pulmonary vascular congestion. no pulmonary edema. small pleural effusion. transvenous pacer lead passing to the anterior wall of the right ventricle. left pleural drains still in place. left supraclavicular introducer ends above the thoracic inlet. left PICC line passes as far as the low SVC #H: cardiomegaly seen
# Output:
# contradiction
# Medical datasets for label contradiction: 7
# Medical report from facts datasets for label contradiction: 1
# Medical report from labels datasets for label contradiction: 1
# Source: gpt-4-0613 | Label: entailment -> 13185 (2563.82)
# Example:
# Input:
# NLI1: On the lateral view, however, there is suggestion of some increased opacification in the retrocardiac region that does not definitely silhouette the hemidiaphragm. #H: The lateral view of the chest X-ray shows possible increased opacification in the retrocardiac region.
# Output:
# entailment
# Source: gpt-4-1106-preview_reasoning-prompt | Label: entailment -> 5445 (1911.57)
# Example:
# Input:
# NLI1: AICD and pacer leads end in the right atrium and ventricle, as expected. #H: Transvenous pacing leads and in the right atrium and right ventricle.
# Output:
# entailment
# Source: gpt-4-0613_reasoning-prompt | Label: entailment -> 1770 (1256.05)
# Example:
# Input:
# NLI1: Subsegmental atelectasis in the left lung base is present. #H: Subsegmental atelectasis in the left lung base is demonstrated.
# Output:
# entailment
# Source: mednli_train | Label: entailment -> 3744 (1672.60)
# Example:
# Input:
# NLI1: Given the new Q waves on ECG and negative cardiac enzymes, pt likely had an MI sometime in the weeks preceding admission. #H:  The patient has an abnormal EKG.
# Output:
# entailment
# Source: mednli_dev | Label: entailment -> 465 (695.76)
# Example:
# Input:
# NLI1: Dr. [**Last Name (STitle) 659**], his PCP came in and a family meeting was held with Dr. [**Last Name (STitle) **], the MICU resident and the patient's 3 daughters. #H:  There was a family meeting about the patient.
# Output:
# entailment
# Source: mednli_test | Label: entailment -> 473 (701.58)
# Example:
# Input:
# NLI1: He was felt to be a good candidate for transplant and will receive a kidney from his sister. #H:  The patient is in renal failure.
# Output:
# entailment
# Source: radnli_dev | Label: entailment -> 93 (279.62)
# Example:
# Input:
# NLI1: PA and lateral views demonstrate dilation of the azygos, tiny pleural effursion, and faint interlobular septal thickening. #H: There is blunting of the left costophrenic angle which may be related to small pleural effusion.
# Output:
# entailment
# Source: s2f | Label: entailment -> 214191 (5553.26)
# Example:
# Input:
# NLI1: Cardio mediastinal contours are grossly unchanged. #H: grossly unchanged cardio mediastinal contours
# Output:
# entailment
# Source: report_nli_from_facts | Label: entailment -> 43411 (3656.37)
# Example:
# Input:
# NLI1: no evidence of appreciable pneumothorax. increased opacification at the bases. poor definition of the hemidiaphragms. layering pleural fluid in the lower lobes. volume loss in the lower lobes. streaks of plate-like atelectasis. engorgement of pulmonary vessels. elevated pulmonary venous pressure. tracheal tube with its tip above the superior level of the clavicles. tracheal tube with its tip approximately 5.3 cm above the carina #H: ET tube tip above the level of the medial clavicular heads
# Output:
# entailment
# Source: report_nli_from_labels | Label: entailment -> 33940 (3409.34)
# Example:
# Input:
# NLI1: no relevant change. calcified right upper lobe granuloma. borderline size of the cardiac silhouette. severe elongation of the descending aorta. no pneumonia. no pulmonary edema. no pleural effusions #H: calcified nodule seen
# Output:
# entailment
# Medical datasets for label entailment: 8
# Loaded 227835 reports from /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_report_facts(79040140).jsonl
# FactBasedReportEntailmentDataset
# Loaded 227835 reports from /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_report_facts(79040140).jsonl
# Medical report from facts datasets for label entailment: 2
# Medical report from labels datasets for label entailment: 1
# Source: gpt-4-0613 | Label: neutral -> 19123 (2877.24)
# Example:
# Input:
# NLI1: Left IJ catheter again extends to the upper to mid SVC. #H: The right lung field is clear.
# Output:
# neutral
# Source: gpt-4-1106-preview_reasoning-prompt | Label: neutral -> 16675 (2758.96)
# Example:
# Input:
# NLI1: New small right pneumothorax of the right lower lung not seen in chest radiograph. #H: A 2 mm pneumothorax is seen at the right lung apex.
# Output:
# neutral
# Source: gpt-4-0613_reasoning-prompt | Label: neutral -> 3968 (1708.29)
# Example:
# Input:
# NLI1: No pleural effusion or pneumothorax is detected on this view. #H: No new consolidation, pneumothorax, or pleural effusion is present.
# Output:
# neutral
# Source: mednli_train | Label: neutral -> 3743 (1672.44)
# Example:
# Input:
# NLI1: She improved and was extubated and weanted from pressors. #H:  THe patient was in septic shock
# Output:
# neutral
# Source: mednli_dev | Label: neutral -> 465 (695.76)
# Example:
# Input:
# NLI1: Her son found her sitting on the floor yesterday evening and called 911. #H:  the patient had an acute MI
# Output:
# neutral
# Source: mednli_test | Label: neutral -> 474 (702.30)
# Example:
# Input:
# NLI1: Patient also on coumadin for h/o DVT. #H:  The patient has a hypercoaguable condition.
# Output:
# neutral
# Source: radnli_dev | Label: neutral -> 281 (538.25)
# Example:
# Input:
# NLI1: There is no effusion. #H: There is no focal consolidation, effusion, or pneumothorax.
# Output:
# neutral
# Source: report_nli_from_facts | Label: neutral -> 22448 (3019.89)
# Example:
# Input:
# NLI1: marked leftward patient rotation. right internal jugular catheter placed. tip of catheter directed laterally into the right subclavian vein. tip of catheter potentially terminating at the junction of the subclavian and axillary veins. questionable small right basilar pneumothorax. difficult to assess in the setting of overlapping artifact in the right basilar region. no relevant change since recent study. repeat nonrotated chest radiograph recommended. removal or repositioning of external structures recommended. to exclude or confirm a small right basilar pneumothorax #H: soft tissues outside the lung
# Output:
# neutral
# Source: report_nli_from_labels | Label: neutral -> 12491 (2520.23)
# Example:
# Input:
# NLI1: increasing opacification at the bases. increasing opacification on the right. pleural effusion in the lower lung. volume loss in the lower lung. dilatation of bowel loops persists. nasogastric tube remains in place in the upper portion of the stomach. gas around the right kidney #H: subclavian line seen
# Output:
# neutral
# Medical datasets for label neutral: 7
# Medical report from facts datasets for label neutral: 1
# Medical report from labels datasets for label neutral: 1
# ----
# Number of RadNLI test samples: 480
# Number of MS_CXR_T samples: 361
# Number of report NLI samples added to val: 300
# Number of report NLI samples added to val: 300
# Number of val NLI samples: 1441
# Input:
# NLI1: bibasilar retrocardiac atelectasis is unchanged. #H: bibasilar retrocardiac atelectasis is new.
# Output:
# contradiction
# Input:
# NLI1: There is no focal consolidation. #H: The lungs are clear without focal consolidation.
# Output:
# neutral
# Input:
# NLI1: Small calcified granulomas are again noted. #H: The aortic knob is calcified.
# Output:
# neutral
# Input:
# NLI1: normal size of the cardiac silhouette. normal hilar contours. normal mediastinal contours. no pneumonia. no pulmonary edema. no pleural effusions #H: pneumonia seen
# Output:
# contradiction
# Input:
# NLI1: There is no pulmonary vascular congestion. #H: There is no effusion or edema.
# Output:
# neutral
# ----
# Building val NLI dataset...
# Number of general sentences: 0
# Number of medical sentences: 1076067
# Number of whole sentences: 824560
# Number of splittable sentences: 251694
# Number of unique sentences (after sent_tokenize): 1390772
# Example train texts:
# {'input_text': 'NLI1: possible increased opacity at the left base. left hemidiaphragm slightly less distinct. left-sided dual lead pacemaker. lead tips over the right atrium. lead tips over the right ventricle. pacemaker leads well seen on the lateral view. other pacemaker leads obscured due to motion. nominal positioning. borderline heart size. exaggerated heart size by technique. no pneumothorax detected. arm overlying the chest on the lateral view. limiting assessment for subtle infiltrate. well seen lowermost portion of the lower lobes. well seen posteriormost portion of the lower lobes. possible minimal blunting of the posterior costophrenic angles. clear portion of the lower lobes. assessment limited by the overlying arm. ossification of the anterior longitudinal ligament (DISH). dual lead pacemaker with lead tips in the right atrium. dual lead pacemaker with lead tips in the right ventricle. probable atelectasis in the left lower lung. atelectasis in the left lower lung may be slightly worse. slightly lower inspiratory volumes. minimal blunting of posterior costophrenic angle. no other evidence of effusion #H: mild increase in bibasilar atelectasis on the right', 'output_text': 'neutral'}
# {'input_text': 'NLI1: endotracheal tube tip terminates approximately 3 cm from the carina. overlying trauma board slightly limit assessment. normal heart size. unremarkable mediastinal contours. unremarkable hilar contours. mild upper zone pulmonary vascular redistribution. supine positioning without overt pulmonary edema. minimal patchy opacities in the upper lobes. minimal patchy opacities in the lower lobes. minimal patchy opacities bilaterally. minimal patchy opacities reflecting atelectasis. minimal patchy opacities reflecting aspiration. limited assessment of the left costophrenic angle. exclusion of the left costophrenic angle from the field of view. no large focal consolidation identified. no gross pleural effusion identified. no pneumothorax identified. no displaced fractures visualized. standard position of endotracheal tube. patchy opacities in the upper lobes bilaterally. patchy opacities in the lower lobes bilaterally. potential atelectasis in the upper lobes bilaterally. potential atelectasis in the lower lobes bilaterally. aspiration not excluded in the upper lobes bilaterally. aspiration not excluded in the lower lobes bilaterally #H: vascular redistribution seen', 'output_text': 'entailment'}
# {'input_text': 'NLI1: This could be atelectasis or pneumonia. #H: This could not be atelectasis or pneumonia.', 'output_text': 'contradiction'}
# Examples dev texts:
# {'input_text': 'NLI1: endotracheal tube terminates above the level of the carina. side hole of the oro-gastric tube around the level of the GE junction. well expanded lungs. clear lungs. no focal consolidation. no effusion. no pneumothorax. no displaced rib fracture. no acute cardiopulmonary process. oro-gastric tube side-port at the level around the GE junction. oro-gastric tube should be advanced. oro-gastric tube should be well within the stomach #H: NG tube tip probably in the distal stomach', 'output_text': 'contradiction'}
# {'input_text': 'NLI1: Left lower lobe collapse stable. #H: Persistent left lower lobe collapse.', 'output_text': 'entailment'}
# {'input_text': 'NLI1: small bilateral effusions are unchanged. #H: small bilateral effusions are stable.', 'output_text': 'entailment'}
# checkpoint_names = ['checkpoint_91_cacc+chf1+chf1+cscc+encc+hscc+nlcc+sass+spss+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9337.pt']
#   0%|                                               | 0/1390772 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=440,3465006188639683439).pkl
# len(self.cache["hashes"]) = 2863612
# self.cache["embeddings"].shape = (2863612, 128)
# 100%|█████████████████████████████| 1390772/1390772 [00:05<00:00, 239615.09it/s]
# embeddings.shape: (1390772, 128)
# Example train text (after wrapping):
# {'h_emb': array([ 0.05474726,  0.13440429, -0.01074891,  0.0061397 ,  0.01843307,
#         0.1271964 , -0.0503246 , -0.22645043, -0.07098435,  0.11518212,
#         0.03563033,  0.14103806, -0.04689234,  0.09817811, -0.00215031,
#        -0.04508452, -0.08077789,  0.03725615,  0.04607357, -0.14501296,
#        -0.22440025,  0.03989301, -0.12745732,  0.14260197, -0.01379089,
#         0.03677665,  0.01603569,  0.03526961, -0.04533499, -0.19006692,
#         0.042218  , -0.11748315, -0.02760557,  0.05562029,  0.00990562,
#        -0.08532353, -0.17210282, -0.14349365, -0.08100469, -0.11877979,
#         0.01454815, -0.18697217,  0.09855588, -0.01516585,  0.0725722 ,
#        -0.05125386,  0.10881934,  0.0781251 , -0.01425133, -0.05624896,
#        -0.00180826,  0.06562101,  0.04426374, -0.10440391, -0.01056925,
#        -0.0390352 , -0.0870422 , -0.0139011 , -0.07158753, -0.09573471,
#         0.01192282, -0.07473107, -0.25714478, -0.06979927,  0.06694553,
#        -0.03456752,  0.02366035, -0.11296804,  0.1152137 ,  0.01851621,
#        -0.155148  , -0.0497277 ,  0.00544673, -0.0764905 , -0.07276369,
#         0.08483566, -0.01294853,  0.0826451 ,  0.03111663,  0.01563848,
#         0.01710703, -0.03607995,  0.05230726,  0.19986673, -0.03360276,
#        -0.0219782 ,  0.00420017,  0.0103154 , -0.04577157,  0.19197564,
#         0.01648979,  0.07377932, -0.0842039 ,  0.02893852, -0.15280046,
#        -0.07488739, -0.0290277 ,  0.00392961,  0.12131541, -0.06285413,
#        -0.13826293, -0.07610539,  0.01954788, -0.14660718,  0.09610052,
#         4.69085313e-02, -3.10367178e-02, -1.28301680e-01,  1.78164423e-01,
#         1.25749968e-02,  1.02642283e-01,  1.00554071e-01, -2.06265841e-02,
#         3.37317064e-02,  6.40485808e-02,  2.54298508e-01, -4.13829088e-02,
#         1.47450492e-01,  5.21206819e-02,  6.14846125e-02,  5.19895144e-02,
#         1.12261608e-01, -8.56433138e-02,  5.43917529e-02,  5.08076809e-02],
#       dtype=float32), 'l': 2}
# nli_trainer.name =  NLI(Embedding-based)
# --------------------------------------------------
# 7) Attaching metrics, losses, timer and events to engines ...
# --------------------------------------------------
# 8) Defining learning rate scheduler handler ...
# --------------------------------------------------
# 9) Defining learning rate scheduler handler ...
# --------------------------------------------------
# 10) Defining checkpoint folder path ...
# checkpoint_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240405_100022_NLI(Embedding-based)_EmbeddingBasedNLI(128,512-256-128)
# metadata saved to /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240405_100022_NLI(Embedding-based)_EmbeddingBasedNLI(128,512-256-128)/metadata.json
# --------------------------------------------------
# 11) Defining log_metrics_handler ...
# MetricsLogger :: we'll be logging to /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240405_100022_NLI(Embedding-based)_EmbeddingBasedNLI(128,512-256-128)/metrics_logs.csv
# --------------------------------------------------
# 12) Running trainer engine ...
# ---- Epoch 1/200
# (1) Training stage (lr = 0.000001) ...
# loss 1.09815, nli_loss 1.09815, nli_acc 0.34391, 72.84 secs
# (2) Validation stage ...
# nli_acc 0.42679, 0.60 secs
# New checkpoint saved: checkpoint_1_nli_acc=0.4185.pt
# ---- Epoch 2/200
# (1) Training stage (lr = 0.000004) ...
# loss 1.08828, nli_loss 1.08828, nli_acc 0.50870, 71.20 secs
# (2) Validation stage ...
# nli_acc 0.58085, 0.62 secs
# New checkpoint saved: checkpoint_2_nli_acc=0.5736.pt
# ---- Epoch 3/200
# (1) Training stage (lr = 0.000020) ...
# loss 0.83735, nli_loss 0.83735, nli_acc 0.63452, 73.07 secs
# (2) Validation stage ...
# nli_acc 0.70854, 0.61 secs
# New checkpoint saved: checkpoint_3_nli_acc=0.7011.pt
# ---- Epoch 4/200
# (1) Training stage (lr = 0.000090) ...
# loss 0.59115, nli_loss 0.59115, nli_acc 0.74457, 73.14 secs
# (2) Validation stage ...
# nli_acc 0.77099, 0.62 secs
# New checkpoint saved: checkpoint_4_nli_acc=0.7684.pt
# ---- Epoch 5/200
# (1) Training stage (lr = 0.000062) ...
# loss 0.52855, nli_loss 0.52855, nli_acc 0.77411, 73.55 secs
# (2) Validation stage ...
# nli_acc 0.79181, 0.64 secs
# New checkpoint saved: checkpoint_5_nli_acc=0.7900.pt
# ---- Epoch 6/200
# (1) Training stage (lr = 0.000042) ...
# loss 0.50963, nli_loss 0.50963, nli_acc 0.78305, 73.35 secs
# (2) Validation stage ...
# nli_acc 0.79181, 0.62 secs
# New checkpoint saved: checkpoint_6_nli_acc=0.7909.pt
# ---- Epoch 7/200
# (1) Training stage (lr = 0.000029) ...
# loss 0.49854, nli_loss 0.49854, nli_acc 0.78832, 73.21 secs
# (2) Validation stage ...
# nli_acc 0.80569, 0.60 secs
# New checkpoint saved: checkpoint_7_nli_acc=0.8040.pt
# ---- Epoch 8/200
# (1) Training stage (lr = 0.000020) ...
# loss 0.49294, nli_loss 0.49294, nli_acc 0.79089, 76.44 secs
# (2) Validation stage ...
# nli_acc 0.79736, 0.65 secs
# ---- Epoch 9/200
# (1) Training stage (lr = 0.000013) ...
# loss 0.48857, nli_loss 0.48857, nli_acc 0.79284, 75.98 secs
# (2) Validation stage ...
# nli_acc 0.80638, 0.61 secs
# New checkpoint saved: checkpoint_9_nli_acc=0.8050.pt
# ---- Epoch 10/200
# (1) Training stage (lr = 0.000009) ...
# loss 0.48553, nli_loss 0.48553, nli_acc 0.79467, 75.09 secs
# (2) Validation stage ...
# nli_acc 0.80014, 0.61 secs
# ---- Epoch 11/200
# (1) Training stage (lr = 0.000006) ...
# loss 0.48449, nli_loss 0.48449, nli_acc 0.79516, 75.06 secs
# (2) Validation stage ...
# nli_acc 0.80222, 0.60 secs
# ---- Epoch 12/200
# (1) Training stage (lr = 0.000004) ...
# loss 0.48319, nli_loss 0.48319, nli_acc 0.79572, 74.27 secs
# (2) Validation stage ...
# nli_acc 0.80430, 0.64 secs
# ---- Epoch 13/200
# (1) Training stage (lr = 0.000003) ...
# loss 0.48116, nli_loss 0.48116, nli_acc 0.79660, 77.07 secs
# (2) Validation stage ...
# nli_acc 0.80222, 0.64 secs
# ---- Epoch 14/200
# (1) Training stage (lr = 0.000002) ...
# loss 0.48130, nli_loss 0.48130, nli_acc 0.79686, 75.85 secs
# (2) Validation stage ...
# nli_acc 0.80500, 0.62 secs
# ---- Epoch 15/200
# (1) Training stage (lr = 0.000090) ...
# loss 0.48327, nli_loss 0.48327, nli_acc 0.79555, 74.89 secs
# (2) Validation stage ...
# nli_acc 0.80361, 0.63 secs
# ---- Epoch 16/200
# (1) Training stage (lr = 0.000059) ...
# loss 0.47012, nli_loss 0.47012, nli_acc 0.80258, 75.74 secs
# (2) Validation stage ...
# nli_acc 0.81194, 0.65 secs
# New checkpoint saved: checkpoint_16_nli_acc=0.8110.pt
# ---- Epoch 17/200
# (1) Training stage (lr = 0.000039) ...
# loss 0.46158, nli_loss 0.46158, nli_acc 0.80669, 76.19 secs
# (2) Validation stage ...
# nli_acc 0.80985, 0.58 secs
# ---- Epoch 18/200
# (1) Training stage (lr = 0.000025) ...
# loss 0.45519, nli_loss 0.45519, nli_acc 0.80997, 76.76 secs
# (2) Validation stage ...
# nli_acc 0.81888, 0.59 secs
# New checkpoint saved: checkpoint_18_nli_acc=0.8180.pt
# ---- Epoch 19/200
# (1) Training stage (lr = 0.000017) ...
# loss 0.45150, nli_loss 0.45150, nli_acc 0.81156, 75.52 secs
# (2) Validation stage ...
# nli_acc 0.82026, 0.65 secs
# New checkpoint saved: checkpoint_19_nli_acc=0.8194.pt
# ---- Epoch 20/200
# (1) Training stage (lr = 0.000011) ...
# loss 0.44980, nli_loss 0.44980, nli_acc 0.81256, 75.46 secs
# (2) Validation stage ...
# nli_acc 0.81610, 0.58 secs
# ---- Epoch 21/200
# (1) Training stage (lr = 0.000007) ...
# loss 0.44686, nli_loss 0.44686, nli_acc 0.81398, 75.69 secs
# (2) Validation stage ...
# nli_acc 0.81541, 0.62 secs
# ---- Epoch 22/200
# (1) Training stage (lr = 0.000005) ...
# loss 0.44619, nli_loss 0.44619, nli_acc 0.81426, 76.12 secs
# (2) Validation stage ...
# nli_acc 0.81818, 0.63 secs
# ---- Epoch 23/200
# (1) Training stage (lr = 0.000003) ...
# loss 0.44586, nli_loss 0.44586, nli_acc 0.81451, 75.54 secs
# (2) Validation stage ...
# nli_acc 0.81888, 0.64 secs
# ---- Epoch 24/200
# (1) Training stage (lr = 0.000002) ...
# loss 0.44500, nli_loss 0.44500, nli_acc 0.81474, 75.99 secs
# (2) Validation stage ...
# nli_acc 0.81749, 0.67 secs
# ---- Epoch 25/200
# (1) Training stage (lr = 0.000090) ...
# loss 0.45196, nli_loss 0.45196, nli_acc 0.81150, 78.77 secs
# (2) Validation stage ...
# nli_acc 0.82096, 0.65 secs
# New checkpoint saved: checkpoint_25_nli_acc=0.8200.pt
# ---- Epoch 26/200
# (1) Training stage (lr = 0.000059) ...
# loss 0.44043, nli_loss 0.44043, nli_acc 0.81711, 77.06 secs
# (2) Validation stage ...
# nli_acc 0.81749, 0.60 secs
# ---- Epoch 27/200
# (1) Training stage (lr = 0.000039) ...
# ...
# (2) Validation stage ...
# nli_acc 0.86954, 0.65 secs
# ---- Epoch 114/200
# (1) Training stage (lr = 0.000002) ...
# loss 0.25525, nli_loss 0.25525, nli_acc 0.91101, 80.92 secs
# (2) Validation stage ...
# nli_acc 0.86537, 0.63 secs
# ---- Epoch 115/200
# (1) Training stage (lr = 0.000090) ...
# loss 0.28366, nli_loss 0.28366, nli_acc 0.89331, 80.37 secs
# (2) Validation stage ...
# nli_acc 0.85010, 0.70 secs
# ---- Epoch 116/200
# (1) Training stage (lr = 0.000059) ...
# loss 0.26764, nli_loss 0.26764, nli_acc 0.90244, 78.61 secs
# (2) Validation stage ...
# nli_acc 0.86190, 0.64 secs
# ---- Epoch 117/200
# (1) Training stage (lr = 0.000039) ...
# loss 0.26046, nli_loss 0.26046, nli_acc 0.90683, 77.95 secs
# (2) Validation stage ...
# nli_acc 0.87162, 0.63 secs
# New checkpoint saved: checkpoint_117_nli_acc=0.8751.pt
# ---- Epoch 118/200
# (1) Training stage (lr = 0.000025) ...
# loss 0.24996, nli_loss 0.24996, nli_acc 0.91276, 76.78 secs
# (2) Validation stage ...
# nli_acc 0.87509, 0.65 secs
# New checkpoint saved: checkpoint_118_nli_acc=0.8789.pt
# ---- Epoch 119/200
# (1) Training stage (lr = 0.000017) ...
# loss 0.24737, nli_loss 0.24737, nli_acc 0.91438, 76.43 secs
# (2) Validation stage ...
# nli_acc 0.87231, 0.64 secs
# ---- Epoch 120/200
# (1) Training stage (lr = 0.000011) ...
# loss 0.24535, nli_loss 0.24535, nli_acc 0.91572, 77.80 secs
# (2) Validation stage ...
# nli_acc 0.86745, 0.64 secs
# ---- Epoch 121/200
# (1) Training stage (lr = 0.000007) ...
# loss 0.24250, nli_loss 0.24250, nli_acc 0.91709, 80.30 secs
# (2) Validation stage ...
# nli_acc 0.87786, 0.64 secs
# New checkpoint saved: checkpoint_121_nli_acc=0.8818.pt
# ---- Epoch 122/200
# (1) Training stage (lr = 0.000005) ...
# loss 0.24132, nli_loss 0.24132, nli_acc 0.91745, 79.16 secs
# (2) Validation stage ...
# nli_acc 0.87092, 0.62 secs
# ---- Epoch 123/200
# (1) Training stage (lr = 0.000003) ...
# loss 0.24042, nli_loss 0.24042, nli_acc 0.91827, 77.01 secs
# (2) Validation stage ...
# nli_acc 0.87647, 0.65 secs
# ---- Epoch 124/200
# (1) Training stage (lr = 0.000002) ...
# loss 0.23866, nli_loss 0.23866, nli_acc 0.91904, 79.50 secs
# (2) Validation stage ...
# nli_acc 0.87925, 0.63 secs
# New checkpoint saved: checkpoint_124_nli_acc=0.8832.pt
# ---- Epoch 125/200
# (1) Training stage (lr = 0.000090) ...
# loss 0.27257, nli_loss 0.27257, nli_acc 0.89848, 77.94 secs
# (2) Validation stage ...
# nli_acc 0.85774, 0.60 secs
# ---- Epoch 126/200
# (1) Training stage (lr = 0.000059) ...
# loss 0.25287, nli_loss 0.25287, nli_acc 0.90929, 67.97 secs
# (2) Validation stage ...
# nli_acc 0.87578, 0.55 secs
# ---- Epoch 127/200
# (1) Training stage (lr = 0.000039) ...
# loss 0.24509, nli_loss 0.24509, nli_acc 0.91373, 67.31 secs
# (2) Validation stage ...
# nli_acc 0.87509, 0.56 secs
# ---- Epoch 128/200
# (1) Training stage (lr = 0.000025) ...
# loss 0.23759, nli_loss 0.23759, nli_acc 0.91842, 66.49 secs
# (2) Validation stage ...
# nli_acc 0.87092, 0.58 secs
# ---- Epoch 129/200
# (1) Training stage (lr = 0.000017) ...
# loss 0.23328, nli_loss 0.23328, nli_acc 0.92112, 64.69 secs
# (2) Validation stage ...
# nli_acc 0.87647, 0.58 secs
# ---- Epoch 130/200
# (1) Training stage (lr = 0.000011) ...
# loss 0.23056, nli_loss 0.23056, nli_acc 0.92258, 64.46 secs
# (2) Validation stage ...
# nli_acc 0.87786, 0.56 secs
# ---- Epoch 131/200
# (1) Training stage (lr = 0.000007) ...
# loss 0.22844, nli_loss 0.22844, nli_acc 0.92391, 64.30 secs
# (2) Validation stage ...
# nli_acc 0.88064, 0.58 secs
# New checkpoint saved: checkpoint_131_nli_acc=0.8850.pt
# ---- Epoch 132/200
# (1) Training stage (lr = 0.000005) ...
# loss 0.22720, nli_loss 0.22720, nli_acc 0.92430, 67.23 secs
# (2) Validation stage ...
# nli_acc 0.87578, 0.57 secs
# ---- Epoch 133/200
# (1) Training stage (lr = 0.000003) ...
# loss 0.22637, nli_loss 0.22637, nli_acc 0.92459, 65.17 secs
# (2) Validation stage ...
# nli_acc 0.87786, 0.56 secs
# ---- Epoch 134/200
# (1) Training stage (lr = 0.000002) ...
# loss 0.22543, nli_loss 0.22543, nli_acc 0.92529, 65.67 secs
# (2) Validation stage ...
# nli_acc 0.88133, 0.58 secs
# New checkpoint saved: checkpoint_134_nli_acc=0.8857.pt
# ---- Epoch 135/200
# (1) Training stage (lr = 0.000090) ...
# loss 0.25832, nli_loss 0.25832, nli_acc 0.90447, 64.74 secs
# (2) Validation stage ...
# nli_acc 0.87786, 0.54 secs
# ---- Epoch 136/200
# (1) Training stage (lr = 0.000059) ...
# loss 0.23921, nli_loss 0.23921, nli_acc 0.91575, 63.84 secs
# (2) Validation stage ...
# nli_acc 0.86607, 0.55 secs
# ---- Epoch 137/200
# (1) Training stage (lr = 0.000039) ...
# loss 0.23102, nli_loss 0.23102, nli_acc 0.92062, 64.36 secs
# (2) Validation stage ...
# nli_acc 0.87439, 0.56 secs
# ---- Epoch 138/200
# (1) Training stage (lr = 0.000025) ...
# loss 0.22417, nli_loss 0.22417, nli_acc 0.92453, 63.94 secs
# (2) Validation stage ...
# nli_acc 0.88133, 0.59 secs
# ---- Epoch 139/200
# (1) Training stage (lr = 0.000017) ...
# loss 0.21902, nli_loss 0.21902, nli_acc 0.92726, 63.72 secs
# (2) Validation stage ...
# nli_acc 0.88203, 0.56 secs
# New checkpoint saved: checkpoint_139_nli_acc=0.8865.pt
# ---- Epoch 140/200
# (1) Training stage (lr = 0.000011) ...
# loss 0.21754, nli_loss 0.21754, nli_acc 0.92841, 64.00 secs
# (2) Validation stage ...
# nli_acc 0.88550, 0.55 secs
# New checkpoint saved: checkpoint_140_nli_acc=0.8898.pt
# ---- Epoch 141/200
# (1) Training stage (lr = 0.000007) ...
# loss 0.21536, nli_loss 0.21536, nli_acc 0.92945, 64.74 secs
# (2) Validation stage ...
# nli_acc 0.88619, 0.55 secs
# New checkpoint saved: checkpoint_141_nli_acc=0.8905.pt
# ---- Epoch 142/200
# (1) Training stage (lr = 0.000005) ...
# loss 0.21469, nli_loss 0.21469, nli_acc 0.93016, 64.39 secs
# (2) Validation stage ...
# nli_acc 0.88203, 0.58 secs
# ---- Epoch 143/200
# (1) Training stage (lr = 0.000003) ...
# loss 0.21219, nli_loss 0.21219, nli_acc 0.93129, 63.43 secs
# (2) Validation stage ...
# nli_acc 0.88688, 0.56 secs
# New checkpoint saved: checkpoint_143_nli_acc=0.8913.pt
# ---- Epoch 144/200
# (1) Training stage (lr = 0.000002) ...
# loss 0.21244, nli_loss 0.21244, nli_acc 0.93112, 63.60 secs
# (2) Validation stage ...
# nli_acc 0.88411, 0.56 secs
# ---- Epoch 145/200
# (1) Training stage (lr = 0.000090) ...
# loss 0.24924, nli_loss 0.24924, nli_acc 0.90848, 65.18 secs
# (2) Validation stage ...
# nli_acc 0.87578, 0.57 secs
# ---- Epoch 146/200
# (1) Training stage (lr = 0.000059) ...
# loss 0.22672, nli_loss 0.22672, nli_acc 0.92099, 64.50 secs
# (2) Validation stage ...
# nli_acc 0.88133, 0.55 secs
# ---- Epoch 147/200
# (1) Training stage (lr = 0.000039) ...
# loss 0.21871, nli_loss 0.21871, nli_acc 0.92600, 64.70 secs
# (2) Validation stage ...
# nli_acc 0.87231, 0.56 secs
# ---- Epoch 148/200
# (1) Training stage (lr = 0.000025) ...
# loss 0.21189, nli_loss 0.21189, nli_acc 0.92979, 63.48 secs
# (2) Validation stage ...
# nli_acc 0.88341, 0.56 secs
# ---- Epoch 149/200
# (1) Training stage (lr = 0.000017) ...
# loss 0.20794, nli_loss 0.20794, nli_acc 0.93215, 63.54 secs
# (2) Validation stage ...
# nli_acc 0.88341, 0.54 secs
# ---- Epoch 150/200
# (1) Training stage (lr = 0.000011) ...
# loss 0.20586, nli_loss 0.20586, nli_acc 0.93305, 63.59 secs
# (2) Validation stage ...
# nli_acc 0.88341, 0.59 secs
# ---- Epoch 151/200
# (1) Training stage (lr = 0.000007) ...
# loss 0.20307, nli_loss 0.20307, nli_acc 0.93467, 64.49 secs
# (2) Validation stage ...
# nli_acc 0.88411, 0.56 secs
# ---- Epoch 152/200
# (1) Training stage (lr = 0.000005) ...
# loss 0.20169, nli_loss 0.20169, nli_acc 0.93500, 63.70 secs
# (2) Validation stage ...
# nli_acc 0.88758, 0.56 secs
# New checkpoint saved: checkpoint_152_nli_acc=0.8923.pt
# ---- Epoch 153/200
# (1) Training stage (lr = 0.000003) ...
# loss 0.20157, nli_loss 0.20157, nli_acc 0.93535, 64.39 secs
# (2) Validation stage ...
# nli_acc 0.88550, 0.55 secs
# ---- Epoch 154/200
# (1) Training stage (lr = 0.000002) ...
# loss 0.19982, nli_loss 0.19982, nli_acc 0.93618, 64.74 secs
# (2) Validation stage ...
# nli_acc 0.88966, 0.56 secs
# New checkpoint saved: checkpoint_154_nli_acc=0.8943.pt
# ---- Epoch 155/200
# (1) Training stage (lr = 0.000090) ...
# loss 0.23806, nli_loss 0.23806, nli_acc 0.91345, 65.83 secs
# (2) Validation stage ...
# nli_acc 0.87786, 0.59 secs
# ---- Epoch 156/200
# (1) Training stage (lr = 0.000059) ...
# loss 0.21728, nli_loss 0.21728, nli_acc 0.92485, 65.68 secs
# (2) Validation stage ...
# nli_acc 0.87370, 0.58 secs
# ---- Epoch 157/200
# (1) Training stage (lr = 0.000039) ...
# loss 0.20684, nli_loss 0.20684, nli_acc 0.93083, 65.36 secs
# (2) Validation stage ...
# nli_acc 0.88341, 0.56 secs
# ---- Epoch 158/200
# (1) Training stage (lr = 0.000025) ...
# loss 0.20078, nli_loss 0.20078, nli_acc 0.93406, 65.12 secs
# (2) Validation stage ...
# nli_acc 0.88619, 0.56 secs
# ---- Epoch 159/200
# (1) Training stage (lr = 0.000017) ...
# loss 0.19754, nli_loss 0.19754, nli_acc 0.93606, 64.39 secs
# (2) Validation stage ...
# nli_acc 0.89244, 0.56 secs
# New checkpoint saved: checkpoint_159_nli_acc=0.8968.pt
# ---- Epoch 160/200
# (1) Training stage (lr = 0.000011) ...
# loss 0.19434, nli_loss 0.19434, nli_acc 0.93767, 65.59 secs
# (2) Validation stage ...
# nli_acc 0.88827, 0.56 secs
# ---- Epoch 161/200
# (1) Training stage (lr = 0.000007) ...
# loss 0.19293, nli_loss 0.19293, nli_acc 0.93817, 64.49 secs
# (2) Validation stage ...
# nli_acc 0.88688, 0.57 secs
# ---- Epoch 162/200
# (1) Training stage (lr = 0.000005) ...
# loss 0.19118, nli_loss 0.19118, nli_acc 0.93903, 63.87 secs
# (2) Validation stage ...
# nli_acc 0.88688, 0.59 secs
# ---- Epoch 163/200
# (1) Training stage (lr = 0.000003) ...
# loss 0.19052, nli_loss 0.19052, nli_acc 0.93942, 64.51 secs
# (2) Validation stage ...
# nli_acc 0.88897, 0.59 secs
# ---- Epoch 164/200
# (1) Training stage (lr = 0.000002) ...
# loss 0.18946, nli_loss 0.18946, nli_acc 0.93965, 64.99 secs
# (2) Validation stage ...
# nli_acc 0.88966, 0.58 secs
# ---- Epoch 165/200
# (1) Training stage (lr = 0.000090) ...
# loss 0.23006, nli_loss 0.23006, nli_acc 0.91624, 63.67 secs
# (2) Validation stage ...
# nli_acc 0.88272, 0.56 secs
# ---- Epoch 166/200
# (1) Training stage (lr = 0.000059) ...
# loss 0.20671, nli_loss 0.20671, nli_acc 0.92889, 63.98 secs
# (2) Validation stage ...
# nli_acc 0.88827, 0.55 secs
# ---- Epoch 167/200
# (1) Training stage (lr = 0.000039) ...
# loss 0.19814, nli_loss 0.19814, nli_acc 0.93382, 64.46 secs
# (2) Validation stage ...
# nli_acc 0.89313, 0.57 secs
# New checkpoint saved: checkpoint_167_nli_acc=0.8972.pt
# ---- Epoch 168/200
# (1) Training stage (lr = 0.000025) ...
# loss 0.19143, nli_loss 0.19143, nli_acc 0.93738, 64.89 secs
# (2) Validation stage ...
# nli_acc 0.88272, 0.56 secs
# ---- Epoch 169/200
# (1) Training stage (lr = 0.000017) ...
# loss 0.18749, nli_loss 0.18749, nli_acc 0.93959, 65.15 secs
# (2) Validation stage ...
# nli_acc 0.88897, 0.56 secs
# ---- Epoch 170/200
# (1) Training stage (lr = 0.000011) ...
# loss 0.18494, nli_loss 0.18494, nli_acc 0.94080, 63.99 secs
# (2) Validation stage ...
# nli_acc 0.89521, 0.55 secs
# New checkpoint saved: checkpoint_170_nli_acc=0.8998.pt
# ---- Epoch 171/200
# (1) Training stage (lr = 0.000007) ...
# loss 0.18334, nli_loss 0.18334, nli_acc 0.94144, 64.81 secs
# (2) Validation stage ...
# nli_acc 0.88966, 0.56 secs
# ---- Epoch 172/200
# (1) Training stage (lr = 0.000005) ...
# loss 0.18233, nli_loss 0.18233, nli_acc 0.94174, 65.00 secs
# (2) Validation stage ...
# nli_acc 0.89105, 0.55 secs
# ---- Epoch 173/200
# (1) Training stage (lr = 0.000003) ...
# loss 0.18067, nli_loss 0.18067, nli_acc 0.94262, 64.41 secs
# (2) Validation stage ...
# nli_acc 0.89105, 0.59 secs
# ---- Epoch 174/200
# (1) Training stage (lr = 0.000002) ...
# loss 0.18028, nli_loss 0.18028, nli_acc 0.94284, 65.66 secs
# (2) Validation stage ...
# nli_acc 0.89591, 0.57 secs
# New checkpoint saved: checkpoint_174_nli_acc=0.9006.pt
# ---- Epoch 175/200
# (1) Training stage (lr = 0.000090) ...
# loss 0.22119, nli_loss 0.22119, nli_acc 0.91998, 66.40 secs
# (2) Validation stage ...
# nli_acc 0.88411, 0.55 secs
# ---- Epoch 176/200
# (1) Training stage (lr = 0.000059) ...
# loss 0.19773, nli_loss 0.19773, nli_acc 0.93249, 65.77 secs
# (2) Validation stage ...
# nli_acc 0.88619, 0.57 secs
# ---- Epoch 177/200
# (1) Training stage (lr = 0.000039) ...
# loss 0.18782, nli_loss 0.18782, nli_acc 0.93760, 65.95 secs
# (2) Validation stage ...
# nli_acc 0.88688, 0.57 secs
# ---- Epoch 178/200
# (1) Training stage (lr = 0.000025) ...
# loss 0.18237, nli_loss 0.18237, nli_acc 0.94045, 66.08 secs
# (2) Validation stage ...
# nli_acc 0.89174, 0.58 secs
# ---- Epoch 179/200
# (1) Training stage (lr = 0.000017) ...
# loss 0.17761, nli_loss 0.17761, nli_acc 0.94255, 64.81 secs
# (2) Validation stage ...
# nli_acc 0.89591, 0.57 secs
# ---- Epoch 180/200
# (1) Training stage (lr = 0.000011) ...
# loss 0.17678, nli_loss 0.17678, nli_acc 0.94301, 64.77 secs
# (2) Validation stage ...
# nli_acc 0.89313, 0.56 secs
# ---- Epoch 181/200
# (1) Training stage (lr = 0.000007) ...
# loss 0.17396, nli_loss 0.17396, nli_acc 0.94431, 65.20 secs
# (2) Validation stage ...
# nli_acc 0.89174, 0.56 secs
# ---- Epoch 182/200
# (1) Training stage (lr = 0.000005) ...
# loss 0.17333, nli_loss 0.17333, nli_acc 0.94472, 64.63 secs
# (2) Validation stage ...
# nli_acc 0.89521, 0.57 secs
# ---- Epoch 183/200
# (1) Training stage (lr = 0.000003) ...
# loss 0.17210, nli_loss 0.17210, nli_acc 0.94511, 64.57 secs
# (2) Validation stage ...
# nli_acc 0.89799, 0.55 secs
# New checkpoint saved: checkpoint_183_nli_acc=0.9027.pt
# ---- Epoch 184/200
# (1) Training stage (lr = 0.000002) ...
# loss 0.17214, nli_loss 0.17214, nli_acc 0.94501, 65.20 secs
# (2) Validation stage ...
# nli_acc 0.90007, 0.58 secs
# New checkpoint saved: checkpoint_184_nli_acc=0.9046.pt
# ---- Epoch 185/200
# (1) Training stage (lr = 0.000090) ...
# loss 0.21605, nli_loss 0.21605, nli_acc 0.92253, 64.22 secs
# (2) Validation stage ...
# nli_acc 0.88550, 0.57 secs
# ---- Epoch 186/200
# (1) Training stage (lr = 0.000059) ...
# loss 0.18981, nli_loss 0.18981, nli_acc 0.93513, 65.41 secs
# (2) Validation stage ...
# nli_acc 0.88758, 0.55 secs
# ---- Epoch 187/200
# (1) Training stage (lr = 0.000039) ...
# loss 0.18059, nli_loss 0.18059, nli_acc 0.93986, 66.33 secs
# (2) Validation stage ...
# nli_acc 0.88341, 0.59 secs
# ---- Epoch 188/200
# (1) Training stage (lr = 0.000025) ...
# loss 0.17517, nli_loss 0.17517, nli_acc 0.94281, 64.74 secs
# (2) Validation stage ...
# nli_acc 0.89938, 0.55 secs
# ---- Epoch 189/200
# (1) Training stage (lr = 0.000017) ...
# loss 0.17166, nli_loss 0.17166, nli_acc 0.94442, 64.32 secs
# (2) Validation stage ...
# nli_acc 0.89382, 0.55 secs
# ---- Epoch 190/200
# (1) Training stage (lr = 0.000011) ...
# loss 0.16823, nli_loss 0.16823, nli_acc 0.94598, 64.63 secs
# (2) Validation stage ...
# nli_acc 0.89799, 0.55 secs
# ---- Epoch 191/200
# (1) Training stage (lr = 0.000007) ...
# loss 0.16718, nli_loss 0.16718, nli_acc 0.94612, 64.68 secs
# (2) Validation stage ...
# nli_acc 0.89521, 0.56 secs
# ---- Epoch 192/200
# (1) Training stage (lr = 0.000005) ...
# loss 0.16659, nli_loss 0.16659, nli_acc 0.94645, 64.72 secs
# (2) Validation stage ...
# nli_acc 0.89799, 0.55 secs
# ---- Epoch 193/200
# (1) Training stage (lr = 0.000003) ...
# loss 0.16493, nli_loss 0.16493, nli_acc 0.94727, 63.83 secs
# (2) Validation stage ...
# nli_acc 0.90076, 0.58 secs
# New checkpoint saved: checkpoint_193_nli_acc=0.9054.pt
# ---- Epoch 194/200
# (1) Training stage (lr = 0.000002) ...
# loss 0.16411, nli_loss 0.16411, nli_acc 0.94757, 63.98 secs
# (2) Validation stage ...
# nli_acc 0.89938, 0.56 secs
# ---- Epoch 195/200
# (1) Training stage (lr = 0.000090) ...
# loss 0.20881, nli_loss 0.20881, nli_acc 0.92408, 64.47 secs
# (2) Validation stage ...
# nli_acc 0.88758, 0.57 secs
# ---- Epoch 196/200
# (1) Training stage (lr = 0.000059) ...
# loss 0.18154, nli_loss 0.18154, nli_acc 0.93818, 65.75 secs
# (2) Validation stage ...
# nli_acc 0.88480, 0.59 secs
# ---- Epoch 197/200
# (1) Training stage (lr = 0.000039) ...
# loss 0.17293, nli_loss 0.17293, nli_acc 0.94244, 65.65 secs
# (2) Validation stage ...
# nli_acc 0.89868, 0.56 secs
# ---- Epoch 198/200
# (1) Training stage (lr = 0.000025) ...
# loss 0.16832, nli_loss 0.16832, nli_acc 0.94487, 65.39 secs
# (2) Validation stage ...
# nli_acc 0.90215, 0.56 secs
# New checkpoint saved: checkpoint_198_nli_acc=0.9064.pt
# ---- Epoch 199/200
# (1) Training stage (lr = 0.000017) ...
# loss 0.16383, nli_loss 0.16383, nli_acc 0.94680, 66.45 secs
# (2) Validation stage ...
# nli_acc 0.89660, 0.56 secs
# ---- Epoch 200/200
# (1) Training stage (lr = 0.000011) ...
# loss 0.16132, nli_loss 0.16132, nli_acc 0.94761, 66.08 secs
# (2) Validation stage ...
# nli_acc 0.89521, 0.55 secs

# %%
# !python ../train_fact_embedding_NLI.py \
--epochs 300 \
--batches_per_epoch 500 \
--batch_size 1000 \
--num_workers 4 \
--iters_to_accumulate 1 \
--optimizer_name "adamw" \
--scheduler "exp-warmup+decay+cyclicdecay" \
--lr 1e-6 \
--warmup_decay_and_cyclic_decay_args "1e-6,3,9e-5,10,2e-6,9e-5,10,2e-6" \
--fact_embedding_model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240207_184445_MIMIC-CXR(triplets+classif+entcont+nli+radgraph+autoencoder)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)" \
--fact_embedding_batch_size 50 \
--fact_embedding_num_workers 4 \
--use_report_nli \
--use_report_nli_entailment_dataset \
--use_report_nli_paraphrases_dataset \
--use_sentence2facts_for_nli \
--integrated_nli_jsonl_filepath \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(169025,21838032).jsonl" \
--sentence_to_facts_input_output_jsonl_filepaths \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_parsed_sentences__v2.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_parsed_sentences__v2(uniform).jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_facts_from_sentences(cluster-balanced,hardest)_part1.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_facts_from_sentences(cluster-balanced,hardest)_part2.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_parsed_sentences__v2.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_facts_from_sentences(cluster-balanced,hardest).jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_facts_from_sentences(cluster-balanced,hardest,conditional).jsonl" \
--integrated_report_facts_jsonl_filepath \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_report_facts(79040140).jsonl" \
--report_nli_input_output_train_jsonl_filepaths \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-1106-preview_fact_based_report_nli_queries(from_labels).jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-1106-preview_fact_based_report_nli_queries(from_facts).jsonl" \
--report_nli_input_output_val_jsonl_filepaths \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-1106-preview_fact_based_report_nli_queries(from_labels,v2).jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-1106-preview_fact_based_report_nli_queries(from_facts,v2).jsonl" \
--paraphrased_inputs_jsonl_filepaths \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_anatomical_locations__part1.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_anatomical_locations__part2.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-16k-0613_paraphrased_anatomical_locations__part3.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__single-words.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words__part1.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-16k-0613_paraphrased_observations__two-or-more-words__part2.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words__part3.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-16k-0613_paraphrased_observations__two-or-more-words__part4.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_paraphrased_observations__two-or-more-words_cluster-balanced.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words_cluster-balanced_1of5.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words_cluster-balanced_2of5.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words_cluster-balanced_3of5.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words_cluster-balanced_4of5.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_hard_triplets_from_facts(cluster-balanced,hardest)-part1.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_hard_triplets_from_facts(cluster-balanced,hardest)-part2.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_hard_triplets_from_facts(cluster-balanced,hardest)-part3.jsonl" \
--embedding_dim 128 \
--mlp_hidden_dims 512 256 128 \
--dropout 0 \
--use_amp \
--save
# Out:
# script's arguments:
#    epochs: 300
#    batches_per_epoch: 500
#    batch_size: 1000
#    num_workers: 4
#    checkpoint_folder: None
#    embedding_dim: 128
#    mlp_hidden_dims: [512, 256, 128]
#    dropout: 0.0
#    optimizer_name: adamw
#    lr: 1e-06
#    scheduler: exp-warmup+decay+cyclicdecay
#    warmup_decay_and_cyclic_decay_args: 1e-6,3,9e-5,10,2e-6,9e-5,10,2e-6
#    iters_to_accumulate: 1
#    override_lr: False
#    device: GPU
#    use_amp: True
#    integrated_nli_jsonl_filepath: /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(169025,21838032).jsonl
#    use_sentence2facts_for_nli: True
#    sentence_to_facts_input_output_jsonl_filepaths: ['/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_parsed_sentences__v2.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_parsed_sentences__v2(uniform).jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_facts_from_sentences(cluster-balanced,hardest)_part1.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_facts_from_sentences(cluster-balanced,hardest)_part2.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_parsed_sentences__v2.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_facts_from_sentences(cluster-balanced,hardest).jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_facts_from_sentences(cluster-balanced,hardest,conditional).jsonl']
#    use_anli: False
#    use_multinli: False
#    use_snli: False
#    use_report_nli: True
#    report_nli_input_output_train_jsonl_filepaths: ['/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-1106-preview_fact_based_report_nli_queries(from_labels).jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-1106-preview_fact_based_report_nli_queries(from_facts).jsonl']
#    report_nli_input_output_val_jsonl_filepaths: ['/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-1106-preview_fact_based_report_nli_queries(from_labels,v2).jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-1106-preview_fact_based_report_nli_queries(from_facts,v2).jsonl']
#    use_report_nli_entailment_dataset: True
#    use_report_nli_paraphrases_dataset: True
#    integrated_report_facts_jsonl_filepath: /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_report_facts(79040140).jsonl
#    paraphrased_inputs_jsonl_filepaths: ['/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_anatomical_locations__part1.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_anatomical_locations__part2.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-16k-0613_paraphrased_anatomical_locations__part3.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__single-words.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words__part1.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-16k-0613_paraphrased_observations__two-or-more-words__part2.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words__part3.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-16k-0613_paraphrased_observations__two-or-more-words__part4.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_paraphrased_observations__two-or-more-words_cluster-balanced.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words_cluster-balanced_1of5.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words_cluster-balanced_2of5.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words_cluster-balanced_3of5.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words_cluster-balanced_4of5.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_hard_triplets_from_facts(cluster-balanced,hardest)-part1.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_hard_triplets_from_facts(cluster-balanced,hardest)-part2.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_hard_triplets_from_facts(cluster-balanced,hardest)-part3.jsonl']
#    fact_embedding_model_name: microsoft/BiomedVLP-CXR-BERT-specialized
#    fact_embedding_model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240207_184445_MIMIC-CXR(triplets+classif+entcont+nli+radgraph+autoencoder)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)
#    fact_embedding_batch_size: 50
#    fact_embedding_num_workers: 4
#    save: True
# ----- Training model from scratch ------
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Creating instance of BertBasedNLI ...
# EmbeddingBasedNLI
#   embedding_dim: 128
#   mlp_hidden_dims: [512, 256, 128]
#   dropout: 0.0
# --------------------------------------------------
# 3) Defining optimizer ...
# create_optimizer(): name = adamw
# --------------------------------------------------
# 4) Defining scheduler ...
# Using exp-warmup+decay+cyclicdecay scheduler: 1e-6,3,9e-5,10,2e-6,9e-5,10,2e-6
# 1e-06 3 9e-05 10 2e-06 9e-05 10 2e-06
# self.steps_to_restart = 10
# self.steps = -1
# self.initial_lr = 9e-05
# --------------------------------------------------
# 5) Creating trainer and validator engines ...
# GradientAccumulator.__init__(): num_accumulation_steps = 1, max_grad_norm = None
# --------------------------------------------------
# 6) Defining collate batch functions ...
# Loaded 19971 input/output pairs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_parsed_sentences__v2.jsonl
# Loaded 19984 input/output pairs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_parsed_sentences__v2(uniform).jsonl
# Loaded 14990 input/output pairs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_facts_from_sentences(cluster-balanced,hardest)_part1.jsonl
# Loaded 14991 input/output pairs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_facts_from_sentences(cluster-balanced,hardest)_part2.jsonl
# Loaded 9999 input/output pairs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_parsed_sentences__v2.jsonl
# Loaded 5000 input/output pairs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_facts_from_sentences(cluster-balanced,hardest).jsonl
# Loaded 9999 input/output pairs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_facts_from_sentences(cluster-balanced,hardest,conditional).jsonl
# Number of sentence2facts pairs: 90614
# Input/output example:
# Input:
# The tip of the PICC line lies in a similar position as it was on the prior occasion with the tip pointing cephalad near the junction of the subclavian and right IJ.
# Output:
# ["tip of the PICC line in a similar position as on the prior occasion", "tip of the PICC line pointing cephalad near the junction of the subclavian and right IJ"]
# --------
# Loaded 9891 paraphrased inputs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_anatomical_locations__part1.jsonl
# Input:
# B
# Paraphrases:
# bilateral
# both sides
# both
# on both sides
# symmetrical
# equally on both sides
# present on both sides
# seen on both sides
# occurring on both sides
# appearing on both sides
# found on both sides
# noted on both sides
# noted bilaterally
# seen bilaterally
# observed bilaterally
# detected bilaterally
# --------
# Loaded 9890 paraphrased inputs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_anatomical_locations__part2.jsonl
# Input:
# left of the left hilus
# Paraphrases:
# left of the left hilum
# left to the left hilum
# left side of the left hilum
# leftward to the left hilum
# left of the hilum on the left side
# left of the pulmonary hilum on the left
# leftward to the pulmonary hilum on the left
# left to the hilum on the left side
# left side of the pulmonary hilum on the left
# leftward to the hilum on the left side
# --------
# Loaded 8511 paraphrased inputs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-16k-0613_paraphrased_anatomical_locations__part3.jsonl
# Input:
# peripheral pulmonary vasculature
# Paraphrases:
# peripheral lung vessels
# peripheral pulmonary blood vessels
# lung periphery vasculature
# vasculature of the peripheral lung
# blood vessels in the outer regions of the lung
# pulmonary vessels in the lung periphery
# vascular network in the peripheral lung
# peripheral pulmonary circulation
# blood vessels supplying the outer areas of the lung
# vasculature in the peripheral regions of the lung
# pulmonary vessels in the lung periphery
# vascular system in the outer regions of the lung
# --------
# Loaded 1864 paraphrased inputs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__single-words.jsonl
# Input:
# a
# Paraphrases:
# one
# single
# sole
# only
# individual
# lone
# solitary
# unique
# distinct
# singular
# --------
# Loaded 14993 paraphrased inputs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words__part1.jsonl
# Input:
# 5 cm
# Paraphrases:
# 5 centimeters
# 5 cm
# 5 centimetres
# 5 cm in size
# a length of 5 cm
# a measurement of 5 cm
# measuring 5 cm
# 5 centimeters in length
# a size of 5 cm
# 5 cm in dimension
# --------
# Loaded 14971 paraphrased inputs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-16k-0613_paraphrased_observations__two-or-more-words__part2.jsonl
# Input:
# limited base
# Paraphrases:
# restricted base
# constrained base
# narrowed base
# limited foundation
# restricted support
# constricted base
# reduced base
# diminished base
# restricted bottom
# constrained footing
# --------
# Loaded 14972 paraphrased inputs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words__part3.jsonl
# Input:
# not visible
# Paraphrases:
# not visualized
# not seen
# not apparent
# not detectable
# absent
# not present
# unable to visualize
# not observable
# not evident
# not identifiable
# --------
# Loaded 14965 paraphrased inputs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-16k-0613_paraphrased_observations__two-or-more-words__part4.jsonl
# Input:
# bowel loops
# Paraphrases:
# intestinal loops
# intestinal segments
# bowel segments
# intestinal coils
# intestinal twists
# intestinal convolutions
# intestinal turns
# intestinal curvatures
# intestinal windings
# intestinal meanders
# --------
# Loaded 10000 paraphrased inputs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_paraphrased_observations__two-or-more-words_cluster-balanced.jsonl
# Input:
# 5th rib
# Paraphrases:
# The fifth rib
# Rib number five
# Rib 5
# 5th rib bone
# Bone of the fifth rib
# Fifth rib structure
# Structure of the 5th rib
# 5th costal bone
# Fifth costal bone
# Costal bone number five
# 5th costae
# Costae number five
# Fifth costae structure
# Structure of the 5th costae
# --------
# Loaded 9999 paraphrased inputs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words_cluster-balanced_1of5.jsonl
# Input:
# CT 2
# Paraphrases:
# Computed tomography scan
# CT imaging
# CT examination
# CT scan
# CT imaging study
# Computed tomography imaging
# Computed tomography exam
# CT scan procedure
# CT scan test
# CT diagnostic imaging
# CT imaging technique
# CT scan investigation
# CT radiographic study
# Computed tomography imaging procedure
# CT scan evaluation
# --------
# Loaded 9997 paraphrased inputs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words_cluster-balanced_2of5.jsonl
# Input:
# line location
# Paraphrases:
# The line is located
# The position of the line is
# The line can be seen
# The line is situated
# The line is found
# The line appears
# The line is detected
# The line is identified
# The line is visible
# The line is present
# The line is observed
# The line is noted
# The line is seen
# The line is evident
# --------
# Loaded 9994 paraphrased inputs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words_cluster-balanced_3of5.jsonl
# Input:
# not apparent
# Paraphrases:
# No evidence of
# Not visible
# Not observable
# Not detected
# Not seen
# Not present
# Absence of
# Lack of
# Negative for
# No signs of
# No findings of
# No indications of
# No evidence suggesting
# No abnormalities detected
# --------
# Loaded 9996 paraphrased inputs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words_cluster-balanced_4of5.jsonl
# Input:
# CT on
# Paraphrases:
# Computed tomography performed
# CT scan done
# Imaging study using computed tomography
# Radiological examination using CT
# CT imaging conducted
# CT scan taken
# CT imaging performed
# Computed tomography examination
# CT scan carried out
# CT imaging study performed
# CT scan conducted
# Computed tomography study done
# CT imaging examination
# CT scan performed
# --------
# Loaded 19937 paraphrased inputs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_hard_triplets_from_facts(cluster-balanced,hardest)-part1.jsonl
# Input:
# no evidence of all-trans retinoic acid syndrome
# Paraphrases:
# no indication of all-trans retinoic acid syndrome
# absence of all-trans retinoic acid syndrome
# no signs of all-trans retinoic acid syndrome
# no presence of all-trans retinoic acid syndrome
# all-trans retinoic acid syndrome not detected
# all-trans retinoic acid syndrome is not observed
# --------
# Loaded 19937 paraphrased inputs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_hard_triplets_from_facts(cluster-balanced,hardest)-part2.jsonl
# Input:
# no evidence of significant constriction
# Paraphrases:
# no indication of notable narrowing
# absence of significant constriction
# no signs of substantial narrowing
# no evidence of significant narrowing
# lack of significant constriction
# no presence of notable constriction
# --------
# Loaded 19943 paraphrased inputs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_hard_triplets_from_facts(cluster-balanced,hardest)-part3.jsonl
# Input:
# no evidence of wheezing
# Paraphrases:
# no signs of wheezing
# absence of wheezing
# no wheezing detected
# no wheezing observed
# no wheezing present
# no wheezing found
# --------
# Number of unique inputs: 190083
# Number of total paraphrases: 2093173
# WARNING: Number of empty paraphrases: 2
# ----
# Loading integrated NLI from /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(169025,21838032).jsonl...
# Number of samples: 169025
# Number of sources: 7
# ----
# Loading sentence2facts input/output pairs for NLI...
# Number of entailment samples added: 214191
# ----
# Loading report NLI datasets...
# Loaded 85996 input/output pairs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-1106-preview_fact_based_report_nli_queries(from_facts).jsonl
# Loaded 63993 input/output pairs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-1106-preview_fact_based_report_nli_queries(from_labels).jsonl
# ----
# Building train NLI dataset...
# Source: gpt-4-0613 | Label: contradiction -> 79430 (4312.76)
# Example:
# Input:
# NLI1: There is no spinal stimulator in the lower thoracic spine area. #H: A spinal stimulator projects over the lower thoracic spine.
# Output:
# contradiction
# Source: gpt-4-1106-preview_reasoning-prompt | Label: contradiction -> 10732 (2400.52)
# Example:
# Input:
# NLI1: Pre-existing parenchymal opacity at the right lung base has decreased. #H: The right medial and basal parenchymal opacities are essentially unchanged.
# Output:
# contradiction
# Source: gpt-4-0613_reasoning-prompt | Label: contradiction -> 4170 (1739.18)
# Example:
# Input:
# NLI1: A small left pleural effusion is unchanged in appearance. #H: A moderate left pleural effusion is slighter larger.
# Output:
# contradiction
# Source: mednli_train | Label: contradiction -> 3744 (1672.60)
# Example:
# Input:
# NLI1: Per patient's wife, she heard a thud in the other room and found the patient "jerking" on the ground. #H:  The patient has no history of abnormal movements
# Output:
# contradiction
# Source: mednli_dev | Label: contradiction -> 465 (695.76)
# Example:
# Input:
# NLI1: Bilateral carotid stenosis 80 to 90% right greater then left. #H:  The patient has normal carotid arteries.
# Output:
# contradiction
# Source: mednli_test | Label: contradiction -> 474 (702.30)
# Example:
# Input:
# NLI1: PAST MEDICAL HISTORY:  Significant for diabetes type 2 treated with insulin, gastroesophageal reflux disease, Schatzki's ring, cerebrovascular accident in [**2948**] with residual left hemiparesis treated with Coumadin, TAH/BSO, peripheral vascular disease, status post appendectomy, coronary artery disease with coronary artery bypass graft in [**9-/2953**] with a left internal mammary artery to the left anterior descending, right saphenous vein graft to the obtuse marginal number one and radial to the posterior descending artery. #H:  The patient has no medical history.
# Output:
# contradiction
# Source: radnli_dev | Label: contradiction -> 106 (304.54)
# Example:
# Input:
# NLI1: The moderate right pleural effusion is unchanged with associated atelectasis. #H: Right lower lobe opacity is slightly increased since ___, and it corresponds to a known right pleural effusion.
# Output:
# contradiction
# Source: report_nli_from_facts | Label: contradiction -> 15168 (2679.10)
# Example:
# Input:
# NLI1: minimally enlarged heart. aorta is tortuous. potential aneurysmal dilatation at the level of mid thoracic aorta up to 4 cm. enlarged dilatation at the level of mid thoracic aorta 3.4 cm on the previous study. clear lungs. lungs without evidence of infectious process. calcification in the right first rib. multiple compression fractures. known diagnosis of multiple may Loma. no new consolidations. no infectious process. abdominal aortic stenting #H: possible aortic injury post trauma
# Output:
# contradiction
# Source: report_nli_from_labels | Label: contradiction -> 12772 (2538.11)
# Example:
# Input:
# NLI1: focal scarring at right lung base. volume loss at right lung base. sequela of previous surgery for lung cancer. no new opacity concerning for pneumonia. right lateral costophrenic sulcus blunting. pleural thickening. possible small component of pleural fluid. normal size cardiomediastinal silhouette. normal size hilar silhouette. no radiographic evidence of pneumonia #H: enlarged cardiomediastinum seen
# Output:
# contradiction
# Medical datasets for label contradiction: 7
# Medical report from facts datasets for label contradiction: 1
# Medical report from labels datasets for label contradiction: 1
# Source: gpt-4-0613 | Label: entailment -> 13185 (2563.82)
# Example:
# Input:
# NLI1: Atelectasis is seen at the right lung base, where there is asymmetric elevation of the right hemidiaphragm. #H: The patient's right lung base shows signs of atelectasis.
# Output:
# entailment
# Source: gpt-4-1106-preview_reasoning-prompt | Label: entailment -> 5445 (1911.57)
# Example:
# Input:
# NLI1: Heart size and mediastinum are unremarkable except for tortuous aorta. #H: Mediastinal contours are unremarkable aside for a slightly tortuous aorta.
# Output:
# entailment
# Source: gpt-4-0613_reasoning-prompt | Label: entailment -> 1770 (1256.05)
# Example:
# Input:
# NLI1: No pulmonary edema is appreciated. #H: Pulmonary vasculature is normal, there is no pulmonary edema.
# Output:
# entailment
# Source: mednli_train | Label: entailment -> 3744 (1672.60)
# Example:
# Input:
# NLI1: Respiratory distress syndrome. #H:  A syndrome where there is impaired oxygen exchange within the lungs.
# Output:
# entailment
# Source: mednli_dev | Label: entailment -> 465 (695.76)
# Example:
# Input:
# NLI1: The birth weight was 2,005 grams, birth length 44.5 cm, and the birth head circumference 30.5 cm. #H:  Patient has just been born
# Output:
# entailment
# Source: mednli_test | Label: entailment -> 473 (701.58)
# Example:
# Input:
# NLI1: He has no complaint of chest pain. #H:  the patient denies chest pain
# Output:
# entailment
# Source: radnli_dev | Label: entailment -> 93 (279.62)
# Example:
# Input:
# NLI1: The cardiomediastinal and hilar contours are unremarkable. #H: Mediastinal and hilar contours are normal.
# Output:
# entailment
# Source: s2f | Label: entailment -> 214191 (5553.26)
# Example:
# Input:
# NLI1: PICC tip appears to be flipped in the interval, potentially within the azygos. #H: flipped PICC tip within the azygos
# Output:
# entailment
# Source: report_nli_from_facts | Label: entailment -> 46465 (3726.66)
# Example:
# Input:
# NLI1: mild edema on the lateral view. substantial bilateral pleural effusions. lower lobe atelectasis. complete collapse on the left. heart is top-normal size. no pneumothorax. moderate cardiomegaly. substantial left atrial enlargement. unchanged left atrial enlargement. difficult to recognize when the lungs are abnormal. difficult to recognize when the pleura are abnormal #H: findings suggestive of mild edema
# Output:
# entailment
# Source: report_nli_from_labels | Label: entailment -> 37159 (3498.95)
# Example:
# Input:
# NLI1: no relevant change. moderate cardiomegaly. no evidence of pulmonary edema. no evidence of other acute lung disease. normal mediastinal reflections. no pleural effusions. no pneumonia. presence of pericardial effusion #H: pericardial effusion seen
# Output:
# entailment
# Medical datasets for label entailment: 8
# Loaded 227835 reports from /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_report_facts(79040140).jsonl
# FactBasedReportEntailmentDataset
# Loaded 227835 reports from /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_report_facts(79040140).jsonl
# FactBasedReportParaphrasesDataset
# Loaded 227835 reports from /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_report_facts(79040140).jsonl
# Number of facts: 586352
# Number of inputs with reports: 97257
# Number of inputs without reports: 92826
# Example:
# {'input_text': 'NLI1: frontal view of the chest was obtained. lateral view of the chest was obtained. hyperinflated lungs. well expanded lungs. costochondral calcification. no definite focal consolidation. no pleural effusion. no pneumothorax. stable cardiac silhouette. stable mediastinal silhouette. no acute cardiopulmonary process #H: Calcium deposits identified in the costochondral junction', 'output_text': 'entailment'}
# Example:
# {'input_text': 'NLI1: combination of atelectasis and pulmonary vasculature #H: Atelectasis accompanied by changes in the pulmonary vasculature', 'output_text': 'entailment'}
# Example:
# {'input_text': 'NLI1: dual leads in the expected position #H: dual leads in the desired position', 'output_text': 'entailment'}
# Medical report from facts datasets for label entailment: 2
# Medical report from labels datasets for label entailment: 2
# Source: gpt-4-0613 | Label: neutral -> 19123 (2877.24)
# Example:
# Input:
# NLI1: Overall, the appearance is that of CHF which is worsened in the interval. #H: Overall findings are most compatible with mild fluid overload.
# Output:
# neutral
# Source: gpt-4-1106-preview_reasoning-prompt | Label: neutral -> 16675 (2758.96)
# Example:
# Input:
# NLI1: Small right-sided pleural effusion has decreased. #H: Again there is pulmonary edema with areas with hazy opacification, especially at the left base, consistent with layering pleural effusion.
# Output:
# neutral
# Source: gpt-4-0613_reasoning-prompt | Label: neutral -> 3968 (1708.29)
# Example:
# Input:
# NLI1: In comparison with the study of , despite the a PleurX 2 in place, there is substantial increase in the amount of right pleural effusion. #H: Continued enlargement of the cardiac silhouette with residual pleural fluid with atelectasis at the right base.
# Output:
# neutral
# Source: mednli_train | Label: neutral -> 3743 (1672.44)
# Example:
# Input:
# NLI1: She had a KUB performed at the rehabilitation facility. #H:  The patient had a bowel obstruction
# Output:
# neutral
# Source: mednli_dev | Label: neutral -> 465 (695.76)
# Example:
# Input:
# NLI1: ALT, AST, and lactate were elevated as noted above. #H:  patient has shock liver
# Output:
# neutral
# Source: mednli_test | Label: neutral -> 474 (702.30)
# Example:
# Input:
# NLI1: Cardiac review of systems is notable for absence of chest pain, dyspnea on exertion, paroxysmal nocturnal dyspnea, orthopnea, ankle edema, palpitations, syncope or presyncope. . #H:  the EKG is normal
# Output:
# neutral
# Source: radnli_dev | Label: neutral -> 281 (538.25)
# Example:
# Input:
# NLI1: No new consolidation is seen. #H: No pulmonary edema is seen.
# Output:
# neutral
# Source: report_nli_from_facts | Label: neutral -> 24363 (3094.52)
# Example:
# Input:
# NLI1: PA chest compared to previous study. lateral chest compared to previous study. vague areas of focal ground-glass opacification in both lungs. difficult to define areas of focal ground-glass opacification on prior bedside chest radiograph. technical limitations. discrete abnormalities projecting over the left fourth anterior rib. discrete abnormalities projecting over the right second through fourth anterior interspaces laterally. no cavitation. no frank consolidation. suggestion of mild interstitial pulmonary abnormality at the right lung base laterally. septal lines at the right lung base laterally. mild bronchial cuffing. Hila are not enlarged. right paratracheal stripe is partially obliterated. question of central lymph node enlargement. normal heart size. small bilateral pleural effusion. thickening of the posterior wall of the bronchus intermedius. edema in the posterior wall of the bronchus intermedius. lymph node enlargement in the posterior wall of the bronchus intermedius. no way to know. acute interstitial abnormality. chronic interstitial abnormality. multifocal vague lung lesions. atypical infection. virus. nodular opacity in the right sixth anterior interspace. nipple shadow in the right sixth anterior interspace. lung nodule in the right sixth anterior interspace. suggestion of a lung nodule. lung nodule projecting through the liver. lung nodule at the level of the same interspace. lung nodule more anteromedially. clinical condition does not improve. CT scanning would be important for documenting the type of abnormality. CT scanning would be important for documenting the extent of abnormality #H: calcifications within the pericardium
# Output:
# neutral
# Source: report_nli_from_labels | Label: neutral -> 14062 (2616.39)
# Example:
# Input:
# NLI1: no change in the position of the tubes. no change in the position of the lines. widespread subcutaneous air. widespread parenchymal changes #H: spinal fracture seen
# Output:
# neutral
# Medical datasets for label neutral: 7
# Medical report from facts datasets for label neutral: 1
# Medical report from labels datasets for label neutral: 1
# ----
# Number of RadNLI test samples: 480
# Number of MS_CXR_T samples: 361
# Loaded 934 input/output pairs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-1106-preview_fact_based_report_nli_queries(from_labels,v2).jsonl
# Loaded 1198 input/output pairs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-1106-preview_fact_based_report_nli_queries(from_facts,v2).jsonl
# Number of val NLI samples: 2973
# Input:
# NLI1: frontal view of the chest performed. lateral view of the chest performed. decreased size of the heart. mildly enlarged heart. prominence of the central vasculature. no overt signs of pulmonary edema. bibasilar atelectasis. no pleural effusion. no pneumothorax. tortuous aorta. dilated aorta. Sternotomy wires unchanged. mediastinal clips unchanged. decrease in heart size. heart without an acute cardiopulmonary process #H: enlarged cardiac silhouette seen
# Output:
# contradiction
# Input:
# NLI1: normally expanded lungs. no focal airspace opacity. minimal atelectasis at the left base. minimal atelectasis similar to the prior study. heart not enlarged. normal mediastinal contours. normal hilar contours. no pleural effusion. no pneumothorax. no evidence of acute cardiopulmonary abnormality #H: linear/patchy atelectasis seen
# Output:
# entailment
# Input:
# NLI1: interval increase in size of multiple bilateral lung metastases. largest lung metastasis in the right lower lobe measuring 3.4 cm. no focal consolidation. no pleural effusion. no pneumothorax. normal cardiac silhouette. normal mediastinal contours. normal pulmonary vasculature. no superimposed pneumonia #H: malignancy involving a majority of the left lung
# Output:
# contradiction
# Input:
# NLI1: increasing opacification at both bases. significant atelectatic changes. superimposed pneumonia. indistinctness of pulmonary vessels. elevated pulmonary venous pressure. Right IJ catheter extends to the mid portion of the SVC #H: obscuration by adjacent atelectasis
# Output:
# entailment
# Input:
# NLI1: unchanged evidence of the two right-sided chest tubes. unchanged evidence of the pre-existing monitoring and support devices. enlarged heart. relatively large retrocardiac atelectasis. presence of a minimal left pleural effusion. no new parenchymal opacities. no evidence of pulmonary edema. more transparent lung bases on the right. improved ventilation #H: chest tube seen
# Output:
# entailment
# ----
# Building val NLI dataset...
# Number of general sentences: 0
# Number of medical sentences: 3002384
# Number of whole sentences: 2750291
# Number of splittable sentences: 252280
# Number of unique sentences (after sent_tokenize): 3316516
# Example train texts:
# {'input_text': 'NLI1: bibasilar patchy opacities in the lungs. unchanged heart size. stable mediastinal contours. stable hilar contours. endotracheal tube placement tip 7 cm above the level of the carina. endotracheal tube should be advanced 2 cm. no large pleural effusion. no pneumothorax. mild basilar atelectasis. aspiration. endotracheal tube should be advanced 2cm for more appropriate position #H: diffuse reticular opacities with a basal predominance', 'output_text': 'neutral'}
# {'input_text': 'NLI1: left pigtail pleural catheter placement. substantial decrease in left pleural effusion. development of a moderate sized left hydro pneumothorax. substantial basilar component in left hydro pneumothorax. right pigtail pleural catheter remains in place. increasing small right pleural effusion. adjacent right basal atelectasis. no other relevant change #H: elevated hemidiaphragm seen', 'output_text': 'neutral'}
# {'input_text': 'NLI1: AP single view of the chest obtained. patient in semi-erect position. status post recent VATS procedure on the left side. left-sided chest tube advanced from the lower lateral chest wall. left-sided chest tube reaching the apical area. aerated lung. regressed pulmonary parenchymal abnormalities in the left hemithorax. regressed pleural abnormalities in the left hemithorax. unremarkable right hemithorax. no pneumothorax on either side. space that accommodates the apical portion of the left-sided chest tube #H: interval placement of a left base chest tube', 'output_text': 'contradiction'}
# Examples dev texts:
# {'input_text': 'NLI1: no definite ET tube identified. folded tubing over the upper airway. possible NG tube outside the patient. possible NG tube related to the patient. NG tube present. NG tube tip extends beneath the diaphragm. NG tube loops over the expected site of the fundus. Swan-Ganz catheter present. tip of Swan-Ganz catheter over proximal right pulmonary artery. left subclavian central line present. tip of central line not well delineated. tip of central line likely over the distal SVC. no pneumothorax detected. left-sided battery device seen. lead extending cephalad over left neck. low inspiratory volumes. dense retrocardiac opacity. left lower lobe collapse. left lower lobe consolidation. patchy opacity at the right lung base. no gross effusion. no normal appearance of an ET tube. ET tube with tip above the level of the clavicular heads. other lines. other tubes. Increased retrocardiac opacity. similar to the prior film. possible pneumonic infiltrates. areas of aspiration pneumonitis #H: not appreciably', 'output_text': 'neutral'}
# {'input_text': 'NLI1: no relevant change in severity of the known pulmonary fibrosis. no evidence of pulmonary edema. no pleural effusions. moderate cardiomegaly #H: fibrosis seen', 'output_text': 'entailment'}
# {'input_text': 'NLI1: moderate right pleural effusion is larger. #H: moderate right pleural effusion is unchanged.', 'output_text': 'contradiction'}
# checkpoint_names = ['checkpoint_91_cacc+chf1+chf1+cscc+encc+hscc+nlcc+sass+spss+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9337.pt']
#   0%|                                               | 0/3316516 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash
#        -0.04731753, -0.11156414,  0.03730897,  0.04049457, -0.06334582,
#         0.04829811, -0.06375155,  0.00550773, -0.21850277, -0.00872395,
#        -0.05470997, -0.04015589, -0.07563653,  0.0479679 , -0.003454  ,
#         0.10454676,  0.10416044,  0.01940109], dtype=float32), 'p_least_sim_emb': array([-0.0021271 , -0.05015088, -0.05991602, -0.01320867, -0.00388791,
#         0.0284736 , -0.11946866,  0.09049741, -0.0961078 , -0.02516454,
#        -0.01998675, -0.05051574, -0.02759187, -0.06552914, -0.04873766,
#        -0.02556087, -0.00190112,  0.00518062,  0.09456248,  0.20548396,
#         0.1573916 , -0.07024314, -0.04481354, -0.0030475 ,  0.09825411,
#        -0.10263709, -0.05502521,  0.00989543, -0.0498198 , -0.05910564,
# ...
# (2) Validation stage ...
# nli_acc 0.74134, 1.05 secs
# ---- Epoch 163/300
# (1) Training stage (lr = 0.000003) ...
# loss 0.22782, nli_loss 0.22782, nli_acc 0.92413, 63.11 secs
# (2) Validation stage ...
# nli_acc 0.74268, 1.04 secs
# ---- Epoch 164/300
# (1) Training stage (lr = 0.000002) ...
# loss 0.22845, nli_loss 0.22845, nli_acc 0.92383, 62.72 secs
# (2) Validation stage ...
# nli_acc 0.74067, 1.06 secs
# ---- Epoch 165/300
# (1) Training stage (lr = 0.000090) ...
# loss 0.26272, nli_loss 0.26272, nli_acc 0.90241, 63.25 secs
# (2) Validation stage ...
# nli_acc 0.73293, 1.04 secs
# ---- Epoch 166/300
# (1) Training stage (lr = 0.000059) ...
# loss 0.24465, nli_loss 0.24465, nli_acc 0.91289, 62.92 secs
# (2) Validation stage ...
# nli_acc 0.73966, 1.04 secs
# ---- Epoch 167/300
# (1) Training stage (lr = 0.000039) ...
# loss 0.23509, nli_loss 0.23509, nli_acc 0.91834, 62.52 secs
# (2) Validation stage ...
# nli_acc 0.73394, 1.05 secs
# ---- Epoch 168/300
# (1) Training stage (lr = 0.000025) ...
# loss 0.22958, nli_loss 0.22958, nli_acc 0.92164, 62.65 secs
# (2) Validation stage ...
# nli_acc 0.73932, 1.04 secs
# ---- Epoch 169/300
# (1) Training stage (lr = 0.000017) ...
# loss 0.22489, nli_loss 0.22489, nli_acc 0.92409, 62.64 secs
# (2) Validation stage ...
# nli_acc 0.73798, 1.03 secs
# ---- Epoch 170/300
# (1) Training stage (lr = 0.000011) ...
# loss 0.22202, nli_loss 0.22202, nli_acc 0.92569, 62.39 secs
# (2) Validation stage ...
# nli_acc 0.73898, 1.00 secs
# ---- Epoch 171/300
# (1) Training stage (lr = 0.000007) ...
# loss 0.22127, nli_loss 0.22127, nli_acc 0.92646, 62.51 secs
# (2) Validation stage ...
# nli_acc 0.73831, 1.04 secs
# ---- Epoch 172/300
# (1) Training stage (lr = 0.000005) ...
# loss 0.21927, nli_loss 0.21927, nli_acc 0.92738, 63.12 secs
# (2) Validation stage ...
# nli_acc 0.74672, 1.06 secs
# ---- Epoch 173/300
# (1) Training stage (lr = 0.000003) ...
# loss 0.21807, nli_loss 0.21807, nli_acc 0.92771, 62.95 secs
# (2) Validation stage ...
# nli_acc 0.74268, 1.05 secs
# ---- Epoch 174/300
# (1) Training stage (lr = 0.000002) ...
# loss 0.21823, nli_loss 0.21823, nli_acc 0.92787, 62.57 secs
# (2) Validation stage ...
# nli_acc 0.74134, 1.04 secs
# ---- Epoch 175/300
# (1) Training stage (lr = 0.000090) ...
# loss 0.25416, nli_loss 0.25416, nli_acc 0.90635, 63.19 secs
# (2) Validation stage ...
# nli_acc 0.72856, 1.05 secs
# ---- Epoch 176/300
# (1) Training stage (lr = 0.000059) ...
# loss 0.23478, nli_loss 0.23478, nli_acc 0.91697, 62.57 secs
# (2) Validation stage ...
# nli_acc 0.72385, 1.04 secs
# ---- Epoch 177/300
# (1) Training stage (lr = 0.000039) ...
# loss 0.22573, nli_loss 0.22573, nli_acc 0.92184, 62.91 secs
# (2) Validation stage ...
# nli_acc 0.73360, 1.04 secs
# ---- Epoch 178/300
# (1) Training stage (lr = 0.000025) ...
# loss 0.22013, nli_loss 0.22013, nli_acc 0.92546, 63.02 secs
# (2) Validation stage ...
# nli_acc 0.74100, 1.05 secs
# ---- Epoch 179/300
# (1) Training stage (lr = 0.000017) ...
# loss 0.21768, nli_loss 0.21768, nli_acc 0.92741, 62.55 secs
# (2) Validation stage ...
# nli_acc 0.73562, 1.03 secs
# ---- Epoch 180/300
# (1) Training stage (lr = 0.000011) ...
# loss 0.21267, nli_loss 0.21267, nli_acc 0.92954, 63.25 secs
# (2) Validation stage ...
# nli_acc 0.73865, 1.04 secs
# ---- Epoch 181/300
# (1) Training stage (lr = 0.000007) ...
# loss 0.21163, nli_loss 0.21163, nli_acc 0.93019, 62.64 secs
# (2) Validation stage ...
# nli_acc 0.74302, 1.04 secs
# ---- Epoch 182/300
# (1) Training stage (lr = 0.000005) ...
# loss 0.21039, nli_loss 0.21039, nli_acc 0.93077, 62.59 secs
# (2) Validation stage ...
# nli_acc 0.73629, 1.05 secs
# ---- Epoch 183/300
# (1) Training stage (lr = 0.000003) ...
# loss 0.20898, nli_loss 0.20898, nli_acc 0.93133, 62.59 secs
# (2) Validation stage ...
# nli_acc 0.74168, 1.05 secs
# ---- Epoch 184/300
# (1) Training stage (lr = 0.000002) ...
# loss 0.20933, nli_loss 0.20933, nli_acc 0.93152, 63.03 secs
# (2) Validation stage ...
# nli_acc 0.74033, 1.04 secs
# ---- Epoch 185/300
# (1) Training stage (lr = 0.000090) ...
# loss 0.24741, nli_loss 0.24741, nli_acc 0.90867, 63.02 secs
# (2) Validation stage ...
# nli_acc 0.73360, 1.04 secs
# ---- Epoch 186/300
# (1) Training stage (lr = 0.000059) ...
# loss 0.22876, nli_loss 0.22876, nli_acc 0.91898, 62.85 secs
# (2) Validation stage ...
# nli_acc 0.74268, 1.04 secs
# ---- Epoch 187/300
# (1) Training stage (lr = 0.000039) ...
# loss 0.21792, nli_loss 0.21792, nli_acc 0.92568, 62.52 secs
# (2) Validation stage ...
# nli_acc 0.74201, 1.03 secs
# ---- Epoch 188/300
# (1) Training stage (lr = 0.000025) ...
# loss 0.21090, nli_loss 0.21090, nli_acc 0.92902, 62.42 secs
# (2) Validation stage ...
# nli_acc 0.73966, 1.06 secs
# ---- Epoch 189/300
# (1) Training stage (lr = 0.000017) ...
# loss 0.20903, nli_loss 0.20903, nli_acc 0.93031, 62.99 secs
# (2) Validation stage ...
# nli_acc 0.73764, 1.07 secs
# ---- Epoch 190/300
# (1) Training stage (lr = 0.000011) ...
# loss 0.20441, nli_loss 0.20441, nli_acc 0.93275, 63.04 secs
# (2) Validation stage ...
# nli_acc 0.74033, 1.04 secs
# ---- Epoch 191/300
# (1) Training stage (lr = 0.000007) ...
# loss 0.20429, nli_loss 0.20429, nli_acc 0.93290, 62.89 secs
# (2) Validation stage ...
# nli_acc 0.73831, 1.04 secs
# ---- Epoch 192/300
# (1) Training stage (lr = 0.000005) ...
# loss 0.20200, nli_loss 0.20200, nli_acc 0.93387, 63.02 secs
# (2) Validation stage ...
# nli_acc 0.74437, 1.04 secs
# ---- Epoch 193/300
# (1) Training stage (lr = 0.000003) ...
# loss 0.20198, nli_loss 0.20198, nli_acc 0.93397, 63.14 secs
# (2) Validation stage ...
# nli_acc 0.74235, 1.04 secs
# ---- Epoch 194/300
# (1) Training stage (lr = 0.000002) ...
# loss 0.20127, nli_loss 0.20127, nli_acc 0.93431, 62.37 secs
# (2) Validation stage ...
# nli_acc 0.73966, 1.04 secs
# ---- Epoch 195/300
# (1) Training stage (lr = 0.000090) ...
# loss 0.24252, nli_loss 0.24252, nli_acc 0.91082, 62.58 secs
# (2) Validation stage ...
# nli_acc 0.75177, 1.05 secs
# ---- Epoch 196/300
# (1) Training stage (lr = 0.000059) ...
# loss 0.21941, nli_loss 0.21941, nli_acc 0.92300, 62.30 secs
# (2) Validation stage ...
# nli_acc 0.73764, 1.06 secs
# ---- Epoch 197/300
# (1) Training stage (lr = 0.000039) ...
# loss 0.20954, nli_loss 0.20954, nli_acc 0.92861, 62.54 secs
# (2) Validation stage ...
# nli_acc 0.74268, 1.04 secs
# ---- Epoch 198/300
# (1) Training stage (lr = 0.000025) ...
# loss 0.20459, nli_loss 0.20459, nli_acc 0.93161, 62.74 secs
# (2) Validation stage ...
# nli_acc 0.73596, 1.04 secs
# ---- Epoch 199/300
# (1) Training stage (lr = 0.000017) ...
# loss 0.20085, nli_loss 0.20085, nli_acc 0.93339, 62.58 secs
# (2) Validation stage ...
# nli_acc 0.74369, 1.04 secs
# ---- Epoch 200/300
# (1) Training stage (lr = 0.000011) ...
# loss 0.19705, nli_loss 0.19705, nli_acc 0.93513, 62.84 secs
# (2) Validation stage ...
# nli_acc 0.74403, 1.04 secs
# ---- Epoch 201/300
# (1) Training stage (lr = 0.000007) ...
# loss 0.19745, nli_loss 0.19745, nli_acc 0.93517, 62.57 secs
# (2) Validation stage ...
# nli_acc 0.74033, 1.06 secs
# ---- Epoch 202/300
# (1) Training stage (lr = 0.000005) ...
# loss 0.19547, nli_loss 0.19547, nli_acc 0.93626, 62.49 secs
# (2) Validation stage ...
# nli_acc 0.74807, 1.03 secs
# ---- Epoch 203/300
# (1) Training stage (lr = 0.000003) ...
# loss 0.19421, nli_loss 0.19421, nli_acc 0.93648, 63.43 secs
# (2) Validation stage ...
# nli_acc 0.74134, 1.04 secs
# ---- Epoch 204/300
# (1) Training stage (lr = 0.000002) ...
# loss 0.19443, nli_loss 0.19443, nli_acc 0.93654, 63.41 secs
# (2) Validation stage ...
# nli_acc 0.74201, 1.04 secs
# ---- Epoch 205/300
# (1) Training stage (lr = 0.000090) ...
# loss 0.23708, nli_loss 0.23708, nli_acc 0.91337, 63.03 secs
# (2) Validation stage ...
# nli_acc 0.74571, 1.04 secs
# ---- Epoch 206/300
# (1) Training stage (lr = 0.000059) ...
# loss 0.21159, nli_loss 0.21159, nli_acc 0.92664, 63.02 secs
# (2) Validation stage ...
# nli_acc 0.73226, 1.04 secs
# ---- Epoch 207/300
# (1) Training stage (lr = 0.000039) ...
# loss 0.20272, nli_loss 0.20272, nli_acc 0.93142, 63.02 secs
# (2) Validation stage ...
# nli_acc 0.75042, 1.04 secs
# ---- Epoch 208/300
# (1) Training stage (lr = 0.000025) ...
# loss 0.19721, nli_loss 0.19721, nli_acc 0.93396, 63.04 secs
# (2) Validation stage ...
# nli_acc 0.75177, 1.05 secs
# ---- Epoch 209/300
# (1) Training stage (lr = 0.000017) ...
# loss 0.19375, nli_loss 0.19375, nli_acc 0.93601, 62.88 secs
# (2) Validation stage ...
# nli_acc 0.73898, 1.05 secs
# ---- Epoch 210/300
# (1) Training stage (lr = 0.000011) ...
# loss 0.19084, nli_loss 0.19084, nli_acc 0.93746, 62.69 secs
# (2) Validation stage ...
# nli_acc 0.74336, 1.04 secs
# ---- Epoch 211/300
# (1) Training stage (lr = 0.000007) ...
# loss 0.19068, nli_loss 0.19068, nli_acc 0.93751, 63.19 secs
# (2) Validation stage ...
# nli_acc 0.74571, 1.07 secs
# ---- Epoch 212/300
# (1) Training stage (lr = 0.000005) ...
# loss 0.18750, nli_loss 0.18750, nli_acc 0.93870, 62.65 secs
# (2) Validation stage ...
# nli_acc 0.73932, 1.05 secs
# ---- Epoch 213/300
# (1) Training stage (lr = 0.000003) ...
# loss 0.18726, nli_loss 0.18726, nli_acc 0.93888, 62.72 secs
# (2) Validation stage ...
# nli_acc 0.74336, 1.04 secs
# ---- Epoch 214/300
# (1) Training stage (lr = 0.000002) ...
# loss 0.18753, nli_loss 0.18753, nli_acc 0.93906, 62.79 secs
# (2) Validation stage ...
# nli_acc 0.74739, 1.04 secs
# ---- Epoch 215/300
# (1) Training stage (lr = 0.000090) ...
# loss 0.23424, nli_loss 0.23424, nli_acc 0.91344, 62.53 secs
# (2) Validation stage ...
# nli_acc 0.74369, 1.04 secs
# ---- Epoch 216/300
# (1) Training stage (lr = 0.000059) ...
# loss 0.20472, nli_loss 0.20472, nli_acc 0.92865, 62.91 secs
# (2) Validation stage ...
# nli_acc 0.73461, 1.08 secs
# ---- Epoch 217/300
# (1) Training stage (lr = 0.000039) ...
# loss 0.19542, nli_loss 0.19542, nli_acc 0.93383, 63.18 secs
# (2) Validation stage ...
# nli_acc 0.74302, 1.04 secs
# ---- Epoch 218/300
# (1) Training stage (lr = 0.000025) ...
# loss 0.19089, nli_loss 0.19089, nli_acc 0.93663, 62.83 secs
# (2) Validation stage ...
# nli_acc 0.74067, 1.07 secs
# ---- Epoch 219/300
# (1) Training stage (lr = 0.000017) ...
# loss 0.18883, nli_loss 0.18883, nli_acc 0.93744, 62.42 secs
# (2) Validation stage ...
# nli_acc 0.74168, 1.03 secs
# ---- Epoch 220/300
# (1) Training stage (lr = 0.000011) ...
# loss 0.18446, nli_loss 0.18446, nli_acc 0.93940, 63.20 secs
# (2) Validation stage ...
# nli_acc 0.74840, 1.05 secs
# ---- Epoch 221/300
# (1) Training stage (lr = 0.000007) ...
# loss 0.18416, nli_loss 0.18416, nli_acc 0.93959, 62.89 secs
# (2) Validation stage ...
# nli_acc 0.73865, 1.04 secs
# ---- Epoch 222/300
# (1) Training stage (lr = 0.000005) ...
# loss 0.18188, nli_loss 0.18188, nli_acc 0.94069, 62.61 secs
# (2) Validation stage ...
# nli_acc 0.74403, 1.04 secs
# ---- Epoch 223/300
# (1) Training stage (lr = 0.000003) ...
# loss 0.18156, nli_loss 0.18156, nli_acc 0.94094, 62.66 secs
# (2) Validation stage ...
# nli_acc 0.74773, 1.04 secs
# ---- Epoch 224/300
# (1) Training stage (lr = 0.000002) ...
# loss 0.18097, nli_loss 0.18097, nli_acc 0.94104, 62.34 secs
# (2) Validation stage ...
# nli_acc 0.74975, 1.02 secs
# ---- Epoch 225/300
# (1) Training stage (lr = 0.000090) ...
# loss 0.22757, nli_loss 0.22757, nli_acc 0.91733, 62.52 secs
# (2) Validation stage ...
# nli_acc 0.72856, 1.05 secs
# ---- Epoch 226/300
# (1) Training stage (lr = 0.000059) ...
# loss 0.20030, nli_loss 0.20030, nli_acc 0.93031, 62.97 secs
# (2) Validation stage ...
# nli_acc 0.75109, 1.07 secs
# ---- Epoch 227/300
# (1) Training stage (lr = 0.000039) ...
# loss 0.19061, nli_loss 0.19061, nli_acc 0.93554, 62.89 secs
# (2) Validation stage ...
# nli_acc 0.74638, 1.04 secs
# ---- Epoch 228/300
# (1) Training stage (lr = 0.000025) ...
# loss 0.18422, nli_loss 0.18422, nli_acc 0.93835, 62.84 secs
# (2) Validation stage ...
# nli_acc 0.74638, 1.03 secs
# ---- Epoch 229/300
# (1) Training stage (lr = 0.000017) ...
# loss 0.18237, nli_loss 0.18237, nli_acc 0.93951, 62.29 secs
# (2) Validation stage ...
# nli_acc 0.75076, 1.07 secs
# ---- Epoch 230/300
# (1) Training stage (lr = 0.000011) ...
# loss 0.17866, nli_loss 0.17866, nli_acc 0.94109, 62.57 secs
# (2) Validation stage ...
# nli_acc 0.74403, 1.08 secs
# ---- Epoch 231/300
# (1) Training stage (lr = 0.000007) ...
# loss 0.17905, nli_loss 0.17905, nli_acc 0.94170, 62.60 secs
# (2) Validation stage ...
# nli_acc 0.74302, 1.04 secs
# ---- Epoch 232/300
# (1) Training stage (lr = 0.000005) ...
# loss 0.17535, nli_loss 0.17535, nli_acc 0.94266, 62.99 secs
# (2) Validation stage ...
# nli_acc 0.74672, 1.04 secs
# ---- Epoch 233/300
# (1) Training stage (lr = 0.000003) ...
# ^C iteration 116075
# Engine run is terminating due to exception:
# Traceback (most recent call last):
#   File "/home/pamessina/medvqa/medvqa/notebooks/../train_fact_embedding_NLI.py", line 411, in <module>
#     train_from_scratch(**args)
#   File "/home/pamessina/medvqa/medvqa/notebooks/../train_fact_embedding_NLI.py", line 320, in train_from_scratch
# Exception in thread Thread-8 (_pin_memory_loop):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     return train_model(
#   File "/home/pamessina/medvqa/medvqa/notebooks/../train_fact_embedding_NLI.py", line 176, in train_model
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     run_common_boilerplate_code_and_start_training(
#   File "/home/pamessina/medvqa/medvqa/training/utils.py", line 134, in run_common_boilerplate_code_and_start_training
#     trainer_engine.run(train_dataloader, max_epochs=epochs, epoch_length=batches_per_epoch)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 892, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/utils/data/_utils/pin_memory.py", line 49, in _pin_memory_loop
#     do_one_step()
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/utils/data/_utils/pin_memory.py", line 26, in do_one_step
#     return self._internal_run()
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 935, in _internal_run
#     r = in_queue.get(timeout=MP_STATUS_CHECK_INTERVAL)
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/multiprocessing/reductions.py", line 305, in rebuild_storage_fd
#     return next(self._internal_run_generator)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 993, in _internal_run_as_gen
#     fd = df.detach()
#   File "/usr/lib/python3.10/multiprocessing/resource_sharer.py", line 57, in detach
#     self._handle_exception(e)
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 638, in _handle_exception
#   File "/usr/lib/python3.10/multiprocessing/resource_sharer.py", line 86, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/usr/lib/python3.10/multiprocessing/connection.py", line 502, in Client
#     raise e
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 959, in _internal_run_as_gen
#     c = SocketClient(address)
#   File "/usr/lib/python3.10/multiprocessing/connection.py", line 630, in SocketClient
#     epoch_time_taken += yield from self._run_once_on_dataset_as_gen()
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 1032, in _run_once_on_dataset_as_gen
#     s.connect(address)
# FileNotFoundError: [Errno 2] No such file or directory
#     self.state.batch = next(self._dataloader_iter)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 628, in __next__
#     data = self._next_data()
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1316, in _next_data
#     idx, data = self._get_data()
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1272, in _get_data
#     success, data = self._try_get_data()
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1120, in _try_get_data
#     data = self._data_queue.get(timeout=timeout)
#   File "/usr/lib/python3.10/queue.py", line 180, in get
#     self.not_empty.wait(remaining)
#   File "/usr/lib/python3.10/threading.py", line 324, in wait
#     gotit = waiter.acquire(True, timeout)
# KeyboardInterrupt
