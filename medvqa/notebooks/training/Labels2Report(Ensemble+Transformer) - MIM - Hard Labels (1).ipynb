# %%
# %env CUDA_VISIBLE_DEVICES=0
# Out:
# env: CUDA_VISIBLE_DEVICES=0

# %%
# !/home/pamessina/venv2/bin/python ../train_labels2report.py \
    --generation-mode "pred2rep" \
    --use-ensemble \
    --ensemble-model-checkpoint-folder-paths \
        "/mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/" \
    --ensemble-batch-size 160 \
    --ensemble-num-workers 3 \
    --use-hard-predictions \
    --epochs 79 \
    --batches-per-epoch 300 \
    --batch-size 200 \
    --num-workers 3 \
    --iters-to-accumulate 2 \
    --optimizer-name "adamw" \
    --scheduler "exp-warmup+decay+cyclicdecay" \
    --lr 1e-6 \
    --warmup-decay-and-cyclic-decay-args "1e-6,6,4e-4,8,3e-6,4e-4,8,3e-6" \
    --use-mimiccxr \
    --mimiccxr-weight 1.0 \
    --mimiccxr-view-mode "chest_imagenome" \
    --mimiccxr-balanced-sampling-mode "balanced_chest_imagenome_global_labels_batchwise" \
    --mimiccxr-balanced-batch-size 30 \
    --mimiccxr-qa-adapted-reports-filename "qa_adapted_reports__20220904_095810.json" \
    --use-chest-imagenome \
    --use-chest-imagenome-decent-images-only \
    --chest-imagenome-label-names-filename "labels(min_freq=100).pkl" \
    --chest-imagenome-labels-filename "imageId2labels(min_freq=100).pkl" \
    --use-chexpert \
    --mimiccxr-chexpert-labels-filename "chexpert_labels_per_report__20220904_113605.pkl" \
    --use-medical-tokenization \
    --medical-terms-frequency-filename "medical_terms_frequency__20220918_184255.pkl" \
    --binary-loss-name "focal+bce+wbce-c" \
    --labels-hidden-dim 1024 \
    --embedding-dim 512 \
    --transf-dec-num-memory-vecs 10 \
    --transf-dec-hidden-dim 512 \
    --transf-dec-nhead 4 \
    --transf-dec-dim-forward 512 \
    --transf-dec-num-layers 3 \
    --use-amp \
    --save
# Out:
# script's arguments:
#    epochs: 79
#    batches_per_epoch: 300
#    batch_size: 200
#    checkpoint_folder: None
#    generation_mode: pred2rep
#    use_ensemble: True
#    ensemble_model_checkpoint_folder_paths: ['/mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/']
#    ensemble_batch_size: 160
#    ensemble_num_workers: 3
#    use_hard_predictions: True
#    pretrained_checkpoint_folder_path: None
#    labels_hidden_dim: 1024
#    embedding_dim: 512
#    transf_dec_num_memory_vecs: 10
#    transf_dec_hidden_dim: 512
#    transf_dec_nhead: 4
#    transf_dec_dim_forward: 512
#    transf_dec_num_layers: 3
#    dropout_prob: 0
#    vocab_min_freq: 10
#    use_medical_tokenization: True
#    medical_terms_frequency_filename: medical_terms_frequency__20220918_184255.pkl
#    optimizer_name: adamw
#    lr: 1e-06
#    scheduler: exp-warmup+decay+cyclicdecay
#    lr_decay: 0.76
#    lr_decay_patience: 2
#    warmup_and_decay_args: None
#    warmup_and_cosine_args: None
#    warmup_decay_and_cyclic_decay_args: 1e-6,6,4e-4,8,3e-6,4e-4,8,3e-6
#    iters_to_accumulate: 2
#    override_lr: False
#    binary_loss_name: focal+bce+wbce-c
#    focal_loss_weight: 1
#    bce_loss_weight: 1
#    wbce_loss_weight: 1
#    num_workers: 3
#    device: GPU
#    use_amp: True
#    train_mimiccxr: True
#    mimiccxr_weight: 1.0
#    mimiccxr_view_mode: chest_imagenome
#    mimiccxr_balanced_sampling_mode: balanced_chest_imagenome_global_labels_batchwise
#    mimiccxr_balanced_batch_size: 30
#    mimiccxr_qa_adapted_reports_filename: qa_adapted_reports__20220904_095810.json
#    chest_imagenome_labels_filename: imageId2labels(min_freq=100).pkl
#    chest_imagenome_label_names_filename: labels(min_freq=100).pkl
#    use_chest_imagenome_decent_images_only: True
#    save: True
#    use_gender: False
#    use_chexpert: True
#    mimiccxr_chexpert_labels_filename: chexpert_labels_per_report__20220904_113605.pkl
#    use_chest_imagenome: True
#    debug: False
# ----- Training model from scratch ------
# Computing number of labels and ranges for ensemble ...
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/metadata.json
# chest_imagenome_range: (0, 627)
# chexpert_range: (627, 641)
# ============================================================
# Precomputing sigmoid activations for ensemble ...
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/metadata.json
# ============================================================
# Model 1/1
# model_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/
# checkpoint_names = ['checkpoint_79_chou+chuc+chuc+chuc+chuc+cD+gacc+wmmp=0.6677.pt', 'checkpoint_135_chou+chuc+chuc+chuc+chuc+cD+gacc+wmmp=0.6689.pt']
# model_checkpoint_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/checkpoint_135_chou+chuc+chuc+chuc+chuc+cD+gacc+wmmp=0.6689.pt
# precomputed_chexpert_sigmoids_path = /mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/precomputed_chexpert_sigmoids(hash=340,3716123060218160099).pkl
# Precomputed sigmoids for CheXpert already exist.
# File size = 56.39 MB
# precomputed_chest_imagenome_sigmoids_path = /mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/precomputed_chest_imagenome_sigmoids(hash=347,2103260294420767687).pkl
# Precomputed sigmoids for Chest ImaGenome already exist.
# File size = 339.66 MB
# Skipping...
# precomputed_sigmoid_paths: [{'model_folder_path': '/mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/', 'chexpert_sigmoids_path': '/mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/precomputed_chexpert_sigmoids(hash=340,3716123060218160099).pkl', 'chest_imagenome_sigmoids_path': '/mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/precomputed_chest_imagenome_sigmoids(hash=347,2103260294420767687).pkl'}]
# ============================================================
# Precomputing thresholds (for hard predictions) for ensemble ...
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/metadata.json
# ============================================================
# Model 1/1
# model_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/
# checkpoint_names = ['checkpoint_79_chou+chuc+chuc+chuc+chuc+cD+gacc+wmmp=0.6677.pt', 'checkpoint_135_chou+chuc+chuc+chuc+chuc+cD+gacc+wmmp=0.6689.pt']
# model_checkpoint_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/checkpoint_135_chou+chuc+chuc+chuc+chuc+cD+gacc+wmmp=0.6689.pt
# results_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/results/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/
# get_image_transform()
#   Using bounding box aware transforms
#     Returning default transform (no augmentation)
# Calibrating thresholds on MIMIC-CXR validation set
# score_name: f1
# Thresholds for CheXpert already cached at /mnt/data/pamessina/workspaces/medvqa-workspace/results/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/thresholds_chexpert(f1).pkl
# Thresholds for Chest ImaGenome already cached at /mnt/data/pamessina/workspaces/medvqa-workspace/results/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/thresholds_chest_imagenome(f1).pkl
# precomputed_thresholds_paths: [{'chexpert': '/mnt/data/pamessina/workspaces/medvqa-workspace/results/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/thresholds_chexpert(f1).pkl', 'chest_imagenome': '/mnt/data/pamessina/workspaces/medvqa-workspace/results/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/thresholds_chest_imagenome(f1).pkl'}]
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Initializing tokenizer ...
# Loading /mnt/data/pamessina/workspaces/medvqa-workspace/cache/vocab(min_freq=10;mode=report;qa_adapted_reports__20220904_095810.json).pkl ...
# --------------------------------------------------
# 3) Creating instance of Labels2ReportModel ...
# Labels2ReportModel
#   gen_mode: pred2rep
#   vocab_size: 4833
#   embedding_dim: 512
#   num_input_labels: 641
#   labels_hidden_dim: 1024
#   num_output_labels: 641
#   transf_dec_num_memory_vecs: 10
#   transf_dec_hidden_dim: 512
#   transf_dec_nhead: 4
#   transf_dec_dim_forward: 512
#   transf_dec_num_layers: 3
#   start_idx: 1
#   dropout_prob: 0
# --------------------------------------------------
# 4) Defining optimizer ...
# create_optimizer(): name = adamw
# --------------------------------------------------
# 5) Defining scheduler ...
# Using exp-warmup+decay+cyclicdecay scheduler: 1e-6,6,4e-4,8,3e-6,4e-4,8,3e-6
# 1e-06 6 0.0004 8 3e-06 0.0004 8 3e-06
# self.steps_to_restart = 8
# self.steps = -1
# self.initial_lr = 0.0004
# --------------------------------------------------
# 6) Creating trainer and validator engines ...
# Using focal+bce+wbce-c loss
# binary_loss_kwargs: {'focal_weight': 1, 'bce_weight': 1, 'wbce_weight': 1}
# --------------------------------------------------
# 7) Defining collate_batch_fn ...
# --------------------------------------------------
# 8) Creating MIMIC-CXR_Labels2ReportTrainer ...
# 227835it [00:17, 13235.31it/s]
# max_idx_count = 377110
# actual_idx_count = 239513
# ** NOTE: 137597 images were skipped because they were not in the allowed DICOM IDs
# Random report:
# <s> heart size normal . mild unfolded descending aorta . hilar normal . no pleural effusion pneumothorax . lungs expanded clear no focal consolidation pneumonia . no cardiopulmonary process </s>
# len(self.train_indices) = 234217
# len(self.val_indices) = 1934
# Loading CheXpert labels...
# Loading Chest Imagenome labels...
# Loading precomputed sigmoid paths for ensemble predictions...
#   Loading /mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/precomputed_chexpert_sigmoids(hash=340,3716123060218160099).pkl
#     _probs.shape = (242280, 14)
#     len(_dids) = 242280
#     _thresholds.shape = (14,)
#     _probs has been thresholded
#     Sanity checking chexpert labels
#     f1_score(val_gt_labels, val_pred_labels, average="micro") = 0.5885286783042394
#     f1_score(val_gt_labels, val_pred_labels, average="macro") = 0.48877588205948314
#   Loading /mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/precomputed_chest_imagenome_sigmoids(hash=347,2103260294420767687).pkl
#     _probs.shape = (242280, 627)
#     len(_dids) = 242280
#     _thresholds.shape = (627,)
#     _probs has been thresholded
#     Sanity checking chest_imagenome labels
#     f1_score(val_gt_labels, val_pred_labels, average="micro") = 0.2304808503177002
#     f1_score(val_gt_labels, val_pred_labels, average="macro") = 0.22673751197996303
# Done loading precomputed sigmoid paths for ensemble predictions
# Balanced sampling mode: balanced_chest_imagenome_global_labels_batchwise
# Regrouping indices by Chest Imagenome labels for balanced sampling...
# 627it [01:02, 10.04it/s]
# Global: airspace opacity                        , # images: 8595 (other: 225622)
# Global: atelectasis                             , # images: 79106 (other: 155111)
# Global: bone lesion                             , # images: 1692 (other: 232525)
# Global: bronchiectasis                          , # images: 905 (other: 233312)
# Global: calcified nodule                        , # images: 2708 (other: 231509)
# Global: clavicle fracture                       , # images: 862 (other: 233355)
# Global: consolidation                           , # images: 17769 (other: 216448)
# Global: costophrenic angle blunting             , # images: 5723 (other: 228494)
# Global: cyst/bullae                             , # images: 874 (other: 233343)
# Global: elevated hemidiaphragm                  , # images: 6412 (other: 227805)
# Global: enlarged cardiac silhouette             , # images: 57654 (other: 176563)
# Global: enlarged hilum                          , # images: 8983 (other: 225234)
# Global: hernia                                  , # images: 3025 (other: 231192)
# Global: hydropneumothorax                       , # images: 954 (other: 233263)
# Global: hyperaeration                           , # images: 10306 (other: 223911)
# Global: increased reticular markings/ild pattern, # images: 1373 (other: 232844)
# Global: infiltration                            , # images: 2977 (other: 231240)
# Global: linear/patchy atelectasis               , # images: 12797 (other: 221420)
# Global: lobar/segmental collapse                , # images: 9531 (other: 224686)
# Global: lung lesion                             , # images: 13455 (other: 220762)
# Global: lung opacity                            , # images: 154881 (other: 79336)
# Global: mass/nodule (not otherwise specified)   , # images: 7782 (other: 226435)
# Global: mediastinal displacement                , # images: 3438 (other: 230779)
# Global: mediastinal widening                    , # images: 5070 (other: 229147)
# Global: multiple masses/nodules                 , # images: 3730 (other: 230487)
# Global: pleural effusion                        , # images: 72076 (other: 162141)
# Global: pleural/parenchymal scarring            , # images: 14199 (other: 220018)
# Global: pneumomediastinum                       , # images: 864 (other: 233353)
# Global: pneumothorax                            , # images: 10640 (other: 223577)
# Global: pulmonary edema/hazy opacity            , # images: 35280 (other: 198937)
# Global: rib fracture                            , # images: 7080 (other: 227137)
# Global: scoliosis                               , # images: 3201 (other: 231016)
# Global: shoulder osteoarthritis                 , # images: 2178 (other: 232039)
# Global: spinal degenerative changes             , # images: 6810 (other: 227407)
# Global: spinal fracture                         , # images: 3101 (other: 231116)
# Global: sub-diaphragmatic air                   , # images: 1234 (other: 232983)
# Global: subcutaneous air                        , # images: 3377 (other: 230840)
# Global: superior mediastinal mass/enlargement   , # images: 3295 (other: 230922)
# Global: tortuous aorta                          , # images: 13462 (other: 220755)
# Global: vascular calcification                  , # images: 10172 (other: 224045)
# Global: vascular congestion                     , # images: 24614 (other: 209603)
# Global: vascular redistribution                 , # images: 3199 (other: 231018)
# Global: aortic graft/repair                     , # images: 115 (other: 234102)
# Global: cabg grafts                             , # images: 3839 (other: 230378)
# Global: cardiac pacer and wires                 , # images: 12453 (other: 221764)
# Global: prosthetic valve                        , # images: 2891 (other: 231326)
# Global: alveolar hemorrhage                     , # images: 1766 (other: 232451)
# Global: aspiration                              , # images: 8915 (other: 225302)
# Global: copd/emphysema                          , # images: 6553 (other: 227664)
# Global: fluid overload/heart failure            , # images: 6458 (other: 227759)
# Global: goiter                                  , # images: 614 (other: 233603)
# Global: granulomatous disease                   , # images: 2423 (other: 231794)
# Global: interstitial lung disease               , # images: 1943 (other: 232274)
# Global: lung cancer                             , # images: 1752 (other: 232465)
# Global: pericardial effusion                    , # images: 1400 (other: 232817)
# Global: pneumonia                               , # images: 34201 (other: 200016)
# Global: abnormal                                , # images: 184517 (other: 49700)
# Global: artifact                                , # images: 299 (other: 233918)
# Global: breast/nipple shadows                   , # images: 1020 (other: 233197)
# Global: low lung volumes                        , # images: 28214 (other: 206003)
# Global: rotated                                 , # images: 2036 (other: 232181)
# Global: skin fold                               , # images: 216 (other: 234001)
# Global: chest port                              , # images: 7247 (other: 226970)
# Global: chest tube                              , # images: 10271 (other: 223946)
# Global: endotracheal tube                       , # images: 22541 (other: 211676)
# Global: enteric tube                            , # images: 27915 (other: 206302)
# Global: ij line                                 , # images: 12109 (other: 222108)
# Global: intra-aortic balloon pump               , # images: 562 (other: 233655)
# Global: mediastinal drain                       , # images: 436 (other: 233781)
# Global: picc                                    , # images: 14281 (other: 219936)
# Global: pigtail catheter                        , # images: 3538 (other: 230679)
# Global: subclavian line                         , # images: 3883 (other: 230334)
# Global: swan-ganz catheter                      , # images: 2197 (other: 232020)
# Global: tracheostomy tube                       , # images: 4756 (other: 229461)
# --------------------------------------------------
# 9) Creating dataloaders ...
# len(_train_dataloaders) = 1
# len(_val_dataloaders) = 1
# _train_weights = [1.0]
# merged_dataset_name = mim
# --------------------------------------------------
# 10) Attaching metrics, losses, timer and events to engines ...
# --------------------------------------------------
# 11) Defining learning rate scheduler handler ...
# --------------------------------------------------
# 12) Defining checkpoint folder path ...
# checkpoint_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/report_gen/20230503_200609_mim_Labels2ReportModel(641,10,TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))
# metadata saved to /mnt/data/pamessina/workspaces/medvqa-workspace/models/report_gen/20230503_200609_mim_Labels2ReportModel(641,10,TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/metadata.json
# --------------------------------------------------
# 13) Defining log_metrics_handler ...
# MetricsLogger :: we'll be logging to /mnt/data/pamessina/workspaces/medvqa-workspace/models/report_gen/20230503_200609_mim_Labels2ReportModel(641,10,TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/metrics_logs.csv
# --------------------------------------------------
# 14) Running trainer engine ...
# ---- Epoch 1/79
# (1) Training stage (lr = 0.000001) ...
# loss 8.73609, wmdcmp 0.00267, report_loss 8.48201, 173.06 secs
# (2) Validation stage ...
# wmdcmp 0.00248, cD 0.00002, 15.78 secs
# ---- Epoch 2/79
# (1) Training stage (lr = 0.000003) ...
# loss 8.23264, wmdcmp 0.00050, report_loss 7.53364, 151.12 secs
# (2) Validation stage ...
# wmdcmp 0.00052, cD 0.00042, 13.53 secs
# ---- Epoch 3/79
# (1) Training stage (lr = 0.000007) ...
# loss 6.94540, wmdcmp 0.00395, report_loss 6.19028, 153.55 secs
# (2) Validation stage ...
# wmdcmp 0.00927, cD 0.00012, 13.36 secs
# ---- Epoch 4/79
# (1) Training stage (lr = 0.000020) ...
# loss 5.64697, wmdcmp 0.03189, report_loss 4.97685, 155.24 secs
# (2) Validation stage ...
# wmdcmp 0.03037, cD 0.00041, 13.78 secs
# ---- Epoch 5/79
# (1) Training stage (lr = 0.000054) ...
# loss 4.46258, wmdcmp 0.10356, report_loss 3.86953, 137.68 secs
# (2) Validation stage ...
# wmdcmp 0.08713, cD 0.17231, 11.89 secs
# ---- Epoch 6/79
# (1) Training stage (lr = 0.000147) ...
# loss 3.38537, wmdcmp 0.16134, report_loss 3.03867, 140.25 secs
# (2) Validation stage ...
# wmdcmp 0.12173, cD 0.34848, 12.49 secs
# ---- Epoch 7/79
# (1) Training stage (lr = 0.000400) ...
# loss 2.89379, wmdcmp 0.20496, report_loss 2.57760, 143.94 secs
# (2) Validation stage ...
# wmdcmp 0.13606, cD 0.42006, 12.72 secs
# ---- Epoch 8/79
# (1) Training stage (lr = 0.000217) ...
# loss 2.40410, wmdcmp 0.23016, report_loss 2.34506, 139.50 secs
# (2) Validation stage ...
# wmdcmp 0.13437, cD 0.38935, 12.50 secs
# ---- Epoch 9/79
# (1) Training stage (lr = 0.000118) ...
# loss 2.30352, wmdcmp 0.23886, report_loss 2.26600, 134.80 secs
# (2) Validation stage ...
# wmdcmp 0.12846, cD 0.36283, 12.49 secs
# ---- Epoch 10/79
# (1) Training stage (lr = 0.000064) ...
# loss 2.29574, wmdcmp 0.24201, report_loss 2.23646, 129.02 secs
# (2) Validation stage ...
# wmdcmp 0.12845, cD 0.33948, 12.74 secs
# ---- Epoch 11/79
# (1) Training stage (lr = 0.000035) ...
# loss 2.28066, wmdcmp 0.24445, report_loss 2.21612, 120.83 secs
# (2) Validation stage ...
# wmdcmp 0.12905, cD 0.35010, 12.53 secs
# ---- Epoch 12/79
# (1) Training stage (lr = 0.000019) ...
# loss 2.35531, wmdcmp 0.24818, report_loss 2.20186, 127.30 secs
# (2) Validation stage ...
# wmdcmp 0.12974, cD 0.36179, 12.56 secs
# ---- Epoch 13/79
# (1) Training stage (lr = 0.000010) ...
# loss 2.26007, wmdcmp 0.24793, report_loss 2.19842, 126.35 secs
# (2) Validation stage ...
# wmdcmp 0.12869, cD 0.35601, 12.56 secs
# ---- Epoch 14/79
# (1) Training stage (lr = 0.000006) ...
# loss 2.15857, wmdcmp 0.24789, report_loss 2.19619, 126.78 secs
# (2) Validation stage ...
# wmdcmp 0.13198, cD 0.37609, 12.64 secs
# ---- Epoch 15/79
# (1) Training stage (lr = 0.000003) ...
# loss 2.04708, wmdcmp 0.24789, report_loss 2.19441, 120.55 secs
# (2) Validation stage ...
# wmdcmp 0.13202, cD 0.36780, 12.36 secs
# ---- Epoch 16/79
# (1) Training stage (lr = 0.000400) ...
# loss 2.14119, wmdcmp 0.24742, report_loss 2.19171, 117.53 secs
# (2) Validation stage ...
# wmdcmp 0.13913, cD 0.42097, 12.53 secs
# ---- Epoch 17/79
# (1) Training stage (lr = 0.000199) ...
# loss 2.05709, wmdcmp 0.25930, report_loss 2.11052, 116.89 secs
# (2) Validation stage ...
# wmdcmp 0.12726, cD 0.34995, 12.52 secs
# ---- Epoch 18/79
# (1) Training stage (lr = 0.000099) ...
# loss 2.06130, wmdcmp 0.26423, report_loss 2.06710, 116.96 secs
# (2) Validation stage ...
# wmdcmp 0.13602, cD 0.37514, 12.33 secs
# ---- Epoch 19/79
# (1) Training stage (lr = 0.000049) ...
# loss 2.03969, wmdcmp 0.26676, report_loss 2.05227, 119.04 secs
# (2) Validation stage ...
# wmdcmp 0.13492, cD 0.38547, 12.42 secs
# ---- Epoch 20/79
# (1) Training stage (lr = 0.000024) ...
# loss 2.00880, wmdcmp 0.26711, report_loss 2.04609, 116.32 secs
# (2) Validation stage ...
# wmdcmp 0.13519, cD 0.39269, 12.57 secs
# ---- Epoch 21/79
# (1) Training stage (lr = 0.000012) ...
# loss 1.90934, wmdcmp 0.26818, report_loss 2.04304, 117.70 secs
# (2) Validation stage ...
# wmdcmp 0.13200, cD 0.37382, 12.57 secs
# ---- Epoch 22/79
# (1) Training stage (lr = 0.000006) ...
# loss 1.93625, wmdcmp 0.26915, report_loss 2.03580, 120.23 secs
# (2) Validation stage ...
# wmdcmp 0.13222, cD 0.38814, 12.58 secs
# ---- Epoch 23/79
# (1) Training stage (lr = 0.000003) ...
# loss 2.07663, wmdcmp 0.26954, report_loss 2.03392, 117.30 secs
# (2) Validation stage ...
# wmdcmp 0.13205, cD 0.38135, 12.55 secs
# ---- Epoch 24/79
# (1) Training stage (lr = 0.000400) ...
# loss 2.04441, wmdcmp 0.26477, report_loss 2.05732, 117.28 secs
# (2) Validation stage ...
# wmdcmp 0.13359, cD 0.38282, 14.03 secs
# ---- Epoch 25/79
# (1) Training stage (lr = 0.000199) ...
# loss 2.14991, wmdcmp 0.27442, report_loss 2.00098, 115.76 secs
# (2) Validation stage ...
# wmdcmp 0.12702, cD 0.35401, 12.48 secs
# ---- Epoch 26/79
# (1) Training stage (lr = 0.000099) ...
# loss 2.01197, wmdcmp 0.27819, report_loss 1.97058, 115.60 secs
# (2) Validation stage ...
# wmdcmp 0.12950, cD 0.36438, 12.18 secs
# ---- Epoch 27/79
# (1) Training stage (lr = 0.000049) ...
# loss 1.94641, wmdcmp 0.28153, report_loss 1.95625, 115.85 secs
# (2) Validation stage ...
# wmdcmp 0.13377, cD 0.40266, 12.40 secs
# ---- Epoch 28/79
# (1) Training stage (lr = 0.000024) ...
# loss 1.89539, wmdcmp 0.28260, report_loss 1.94173, 115.49 secs
# (2) Validation stage ...
# wmdcmp 0.13843, cD 0.42906, 12.43 secs
# ---- Epoch 29/79
# (1) Training stage (lr = 0.000012) ...
# loss 1.87242, wmdcmp 0.28189, report_loss 1.94554, 115.62 secs
# (2) Validation stage ...
# wmdcmp 0.13451, cD 0.38475, 12.49 secs
# ---- Epoch 30/79
# (1) Training stage (lr = 0.000006) ...
# loss 1.95182, wmdcmp 0.28393, report_loss 1.93497, 115.98 secs
# (2) Validation stage ...
# wmdcmp 0.13014, cD 0.37896, 12.37 secs
# ---- Epoch 31/79
# (1) Training stage (lr = 0.000003) ...
# loss 1.94441, wmdcmp 0.28346, report_loss 1.93261, 115.27 secs
# (2) Validation stage ...
# wmdcmp 0.13407, cD 0.39808, 12.34 secs
# ---- Epoch 32/79
# (1) Training stage (lr = 0.000400) ...
# loss 1.86478, wmdcmp 0.27648, report_loss 1.97332, 115.55 secs
# (2) Validation stage ...
# wmdcmp 0.13765, cD 0.42474, 12.39 secs
# ---- Epoch 33/79
# (1) Training stage (lr = 0.000199) ...
# loss 2.01687, wmdcmp 0.28468, report_loss 1.92853, 119.49 secs
# (2) Validation stage ...
# wmdcmp 0.12917, cD 0.34995, 12.31 secs
# ---- Epoch 34/79
# (1) Training stage (lr = 0.000099) ...
# loss 1.92278, wmdcmp 0.28920, report_loss 1.89405, 121.15 secs
# (2) Validation stage ...
# wmdcmp 0.12764, cD 0.39661, 12.45 secs
# ---- Epoch 35/79
# (1) Training stage (lr = 0.000049) ...
# loss 1.87156, wmdcmp 0.28985, report_loss 1.88605, 122.52 secs
# (2) Validation stage ...
# wmdcmp 0.13367, cD 0.39021, 12.53 secs
# ---- Epoch 36/79
# (1) Training stage (lr = 0.000024) ...
# loss 1.90931, wmdcmp 0.29361, report_loss 1.87104, 115.08 secs
# (2) Validation stage ...
# wmdcmp 0.12905, cD 0.37012, 12.42 secs
# ---- Epoch 37/79
# (1) Training stage (lr = 0.000012) ...
# loss 1.84370, wmdcmp 0.29375, report_loss 1.86638, 115.79 secs
# (2) Validation stage ...
# wmdcmp 0.13250, cD 0.40515, 12.46 secs
# ---- Epoch 38/79
# (1) Training stage (lr = 0.000006) ...
# loss 1.81090, wmdcmp 0.29383, report_loss 1.86714, 114.66 secs
# (2) Validation stage ...
# wmdcmp 0.13103, cD 0.38070, 12.54 secs
# ---- Epoch 39/79
# (1) Training stage (lr = 0.000003) ...
# loss 1.90859, wmdcmp 0.29437, report_loss 1.86400, 116.27 secs
# (2) Validation stage ...
# wmdcmp 0.13222, cD 0.39040, 12.50 secs
# ---- Epoch 40/79
# (1) Training stage (lr = 0.000400) ...
# loss 1.77983, wmdcmp 0.28622, report_loss 1.90545, 114.91 secs
# (2) Validation stage ...
# wmdcmp 0.13650, cD 0.41831, 12.48 secs
# ---- Epoch 41/79
# (1) Training stage (lr = 0.000199) ...
# loss 1.97881, wmdcmp 0.29246, report_loss 1.86683, 113.91 secs
# (2) Validation stage ...
# wmdcmp 0.13800, cD 0.39150, 12.61 secs
# ---- Epoch 42/79
# (1) Training stage (lr = 0.000099) ...
# loss 1.93202, wmdcmp 0.29776, report_loss 1.83470, 116.81 secs
# (2) Validation stage ...
# wmdcmp 0.12339, cD 0.35413, 12.52 secs
# ---- Epoch 43/79
# (1) Training stage (lr = 0.000049) ...
# loss 1.87512, wmdcmp 0.30011, report_loss 1.82062, 117.40 secs
# (2) Validation stage ...
# wmdcmp 0.13131, cD 0.39806, 12.31 secs
# ---- Epoch 44/79
# (1) Training stage (lr = 0.000024) ...
# loss 1.83021, wmdcmp 0.30075, report_loss 1.81692, 116.19 secs
# (2) Validation stage ...
# wmdcmp 0.13566, cD 0.39900, 12.54 secs
# ---- Epoch 45/79
# (1) Training stage (lr = 0.000012) ...
# loss 1.79413, wmdcmp 0.30147, report_loss 1.81354, 117.61 secs
# (2) Validation stage ...
# wmdcmp 0.13421, cD 0.40286, 12.49 secs
# ---- Epoch 46/79
# (1) Training stage (lr = 0.000006) ...
# loss 1.84754, wmdcmp 0.30172, report_loss 1.81419, 116.25 secs
# (2) Validation stage ...
# wmdcmp 0.13257, cD 0.40609, 13.68 secs
# ---- Epoch 47/79
# (1) Training stage (lr = 0.000003) ...
# loss 1.87273, wmdcmp 0.30283, report_loss 1.80742, 113.79 secs
# (2) Validation stage ...
# wmdcmp 0.13404, cD 0.40550, 12.47 secs
# ---- Epoch 48/79
# (1) Training stage (lr = 0.000400) ...
# loss 1.90788, wmdcmp 0.29271, report_loss 1.85284, 116.64 secs
# (2) Validation stage ...
# wmdcmp 0.12555, cD 0.35251, 12.51 secs
# ---- Epoch 49/79
# (1) Training stage (lr = 0.000199) ...
# loss 1.89323, wmdcmp 0.29940, report_loss 1.81997, 116.95 secs
# (2) Validation stage ...
# wmdcmp 0.13579, cD 0.41260, 12.38 secs
# ---- Epoch 50/79
# (1) Training stage (lr = 0.000099) ...
# loss 1.92000, wmdcmp 0.30492, report_loss 1.79012, 115.77 secs
# (2) Validation stage ...
# wmdcmp 0.12937, cD 0.37387, 12.31 secs
# ---- Epoch 51/79
# (1) Training stage (lr = 0.000049) ...
# loss 1.83035, wmdcmp 0.30611, report_loss 1.77637, 116.38 secs
# (2) Validation stage ...
# wmdcmp 0.12505, cD 0.34220, 12.56 secs
# ---- Epoch 52/79
# (1) Training stage (lr = 0.000024) ...
# loss 1.80050, wmdcmp 0.30840, report_loss 1.76663, 117.76 secs
# (2) Validation stage ...
# wmdcmp 0.13351, cD 0.38734, 12.51 secs
# ---- Epoch 53/79
# (1) Training stage (lr = 0.000012) ...
# loss 1.63882, wmdcmp 0.30941, report_loss 1.76252, 121.81 secs
# (2) Validation stage ...
# wmdcmp 0.13263, cD 0.39732, 12.15 secs
# ---- Epoch 54/79
# (1) Training stage (lr = 0.000006) ...
# loss 1.81864, wmdcmp 0.30998, report_loss 1.76076, 121.83 secs
# (2) Validation stage ...
# wmdcmp 0.13239, cD 0.40414, 12.53 secs
# ---- Epoch 55/79
# (1) Training stage (lr = 0.000003) ...
# loss 1.77065, wmdcmp 0.30966, report_loss 1.75876, 118.35 secs
# (2) Validation stage ...
# wmdcmp 0.13117, cD 0.37384, 12.42 secs
# ---- Epoch 56/79
# (1) Training stage (lr = 0.000400) ...
# loss 1.71583, wmdcmp 0.30080, report_loss 1.80912, 117.11 secs
# (2) Validation stage ...
# wmdcmp 0.12807, cD 0.36828, 12.61 secs
# ---- Epoch 57/79
# (1) Training stage (lr = 0.000199) ...
# loss 1.64109, wmdcmp 0.30696, report_loss 1.76970, 117.02 secs
# (2) Validation stage ...
# wmdcmp 0.13520, cD 0.42134, 12.56 secs
# ---- Epoch 58/79
# (1) Training stage (lr = 0.000099) ...
# loss 1.65716, wmdcmp 0.31233, report_loss 1.74516, 115.98 secs
# (2) Validation stage ...
# wmdcmp 0.12471, cD 0.37608, 12.55 secs
# ---- Epoch 59/79
# (1) Training stage (lr = 0.000049) ...
# loss 1.65821, wmdcmp 0.31306, report_loss 1.73865, 116.21 secs
# (2) Validation stage ...
# wmdcmp 0.13447, cD 0.41093, 12.45 secs
# ---- Epoch 60/79
# (1) Training stage (lr = 0.000024) ...
# loss 1.69496, wmdcmp 0.31506, report_loss 1.72509, 118.06 secs
# (2) Validation stage ...
# wmdcmp 0.13346, cD 0.39211, 12.50 secs
# ---- Epoch 61/79
# (1) Training stage (lr = 0.000012) ...
# loss 1.72773, wmdcmp 0.31632, report_loss 1.72109, 121.83 secs
# (2) Validation stage ...
# wmdcmp 0.13408, cD 0.38404, 12.46 secs
# ---- Epoch 62/79
# (1) Training stage (lr = 0.000006) ...
# loss 1.74177, wmdcmp 0.31586, report_loss 1.72171, 119.91 secs
# (2) Validation stage ...
# wmdcmp 0.13000, cD 0.37049, 12.50 secs
# ---- Epoch 63/79
# (1) Training stage (lr = 0.000003) ...
# loss 1.70243, wmdcmp 0.31686, report_loss 1.71682, 115.97 secs
# (2) Validation stage ...
# wmdcmp 0.12874, cD 0.36821, 12.29 secs
# ---- Epoch 64/79
# (1) Training stage (lr = 0.000400) ...
# loss 1.66739, wmdcmp 0.30459, report_loss 1.77347, 117.81 secs
# (2) Validation stage ...
# wmdcmp 0.13496, cD 0.43401, 12.57 secs
# ---- Epoch 65/79
# (1) Training stage (lr = 0.000199) ...
# loss 1.67177, wmdcmp 0.31232, report_loss 1.73891, 121.92 secs
# (2) Validation stage ...
# wmdcmp 0.13011, cD 0.38870, 12.40 secs
# ---- Epoch 66/79
# (1) Training stage (lr = 0.000099) ...
# loss 1.65429, wmdcmp 0.31777, report_loss 1.70916, 119.02 secs
# (2) Validation stage ...
# wmdcmp 0.13908, cD 0.42679, 12.54 secs
# ---- Epoch 67/79
# (1) Training stage (lr = 0.000049) ...
# loss 1.65868, wmdcmp 0.31889, report_loss 1.69953, 117.10 secs
# (2) Validation stage ...
# wmdcmp 0.12776, cD 0.35837, 12.51 secs
# ---- Epoch 68/79
# (1) Training stage (lr = 0.000024) ...
# loss 1.70290, wmdcmp 0.32115, report_loss 1.68860, 116.83 secs
# (2) Validation stage ...
# wmdcmp 0.13007, cD 0.37139, 12.44 secs
# ---- Epoch 69/79
# (1) Training stage (lr = 0.000012) ...
# loss 1.73338, wmdcmp 0.32314, report_loss 1.68446, 116.54 secs
# (2) Validation stage ...
# wmdcmp 0.12956, cD 0.36922, 13.72 secs
# ---- Epoch 70/79
# (1) Training stage (lr = 0.000006) ...
# loss 1.69912, wmdcmp 0.32389, report_loss 1.67932, 117.63 secs
# (2) Validation stage ...
# wmdcmp 0.12997, cD 0.37983, 12.50 secs
# ---- Epoch 71/79
# (1) Training stage (lr = 0.000003) ...
# loss 1.66697, wmdcmp 0.32369, report_loss 1.67797, 115.09 secs
# (2) Validation stage ...
# wmdcmp 0.13184, cD 0.39478, 12.47 secs
# ---- Epoch 72/79
# (1) Training stage (lr = 0.000400) ...
# loss 1.65616, wmdcmp 0.31156, report_loss 1.73167, 115.95 secs
# (2) Validation stage ...
# wmdcmp 0.13017, cD 0.36545, 12.51 secs
# ---- Epoch 73/79
# (1) Training stage (lr = 0.000199) ...
# loss 1.81801, wmdcmp 0.31753, report_loss 1.70697, 116.73 secs
# (2) Validation stage ...
# wmdcmp 0.12666, cD 0.36222, 12.47 secs
# ---- Epoch 74/79
# (1) Training stage (lr = 0.000099) ...
# loss 1.72597, wmdcmp 0.32378, report_loss 1.67452, 116.70 secs
# (2) Validation stage ...
# wmdcmp 0.12650, cD 0.36564, 12.42 secs
# ---- Epoch 75/79
# (1) Training stage (lr = 0.000049) ...
# loss 1.63190, wmdcmp 0.32458, report_loss 1.66515, 115.65 secs
# (2) Validation stage ...
# wmdcmp 0.12864, cD 0.36821, 12.43 secs
# ---- Epoch 76/79
# (1) Training stage (lr = 0.000024) ...
# loss 1.69930, wmdcmp 0.32867, report_loss 1.65184, 120.98 secs
# (2) Validation stage ...
# wmdcmp 0.13024, cD 0.37182, 12.58 secs
# ---- Epoch 77/79
# (1) Training stage (lr = 0.000012) ...
# loss 1.63982, wmdcmp 0.32821, report_loss 1.65124, 120.92 secs
# (2) Validation stage ...
# wmdcmp 0.12875, cD 0.37412, 12.47 secs
# ---- Epoch 78/79
# (1) Training stage (lr = 0.000006) ...
# loss 1.65928, wmdcmp 0.32782, report_loss 1.64738, 115.47 secs
# (2) Validation stage ...
# wmdcmp 0.12908, cD 0.37448, 12.46 secs
# ---- Epoch 79/79
# (1) Training stage (lr = 0.000003) ...
# loss 1.68851, wmdcmp 0.32821, report_loss 1.64717, 116.17 secs
# (2) Validation stage ...
# wmdcmp 0.13095, cD 0.39197, 12.52 secs

# %%
# !/home/pamessina/venv2/bin/python ../train_labels2report.py \
    --generation-mode "pred2rep" \
    --use-ensemble \
    --ensemble-model-checkpoint-folder-paths \
        "/mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/" \
    --ensemble-batch-size 160 \
    --ensemble-num-workers 3 \
    --use-hard-predictions \
    --epochs 68 \
    --batches-per-epoch 300 \
    --batch-size 200 \
    --num-workers 3 \
    --iters-to-accumulate 2 \
    --optimizer-name "adamw" \
    --scheduler "exp-warmup+decay+cyclicdecay" \
    --lr 1e-6 \
    --warmup-decay-and-cyclic-decay-args "1e-6,3,4e-4,8,3e-6,4e-4,8,3e-6" \
    --use-mimiccxr \
    --mimiccxr-weight 1.0 \
    --mimiccxr-view-mode "chest_imagenome" \
    --mimiccxr-balanced-sampling-mode "balanced_chexpert_labels_batchwise" \
    --mimiccxr-balanced-batch-size 30 \
    --mimiccxr-qa-adapted-reports-filename "qa_adapted_reports__20220904_095810.json" \
    --use-chest-imagenome-decent-images-only \
    --use-chexpert \
    --mimiccxr-chexpert-labels-filename "chexpert_labels_per_report__20220904_113605.pkl" \
    --use-medical-tokenization \
    --medical-terms-frequency-filename "medical_terms_frequency__20220918_184255.pkl" \
    --binary-loss-name "focal+bce+wbce-c" \
    --labels-hidden-dim 1024 \
    --embedding-dim 512 \
    --transf-dec-num-memory-vecs 10 \
    --transf-dec-hidden-dim 512 \
    --transf-dec-nhead 4 \
    --transf-dec-dim-forward 512 \
    --transf-dec-num-layers 3 \
    --use-amp \
    --save
# Out:
# script's arguments:
#    epochs: 68
#    batches_per_epoch: 300
#    batch_size: 200
#    checkpoint_folder: None
#    generation_mode: pred2rep
#    use_ensemble: True
#    ensemble_model_checkpoint_folder_paths: ['/mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/']
#    ensemble_batch_size: 160
#    ensemble_num_workers: 3
#    use_hard_predictions: True
#    pretrained_checkpoint_folder_path: None
#    labels_hidden_dim: 1024
#    embedding_dim: 512
#    transf_dec_num_memory_vecs: 10
#    transf_dec_hidden_dim: 512
#    transf_dec_nhead: 4
#    transf_dec_dim_forward: 512
#    transf_dec_num_layers: 3
#    dropout_prob: 0
#    vocab_min_freq: 10
#    use_medical_tokenization: True
#    medical_terms_frequency_filename: medical_terms_frequency__20220918_184255.pkl
#    optimizer_name: adamw
#    lr: 1e-06
#    scheduler: exp-warmup+decay+cyclicdecay
#    lr_decay: 0.76
#    lr_decay_patience: 2
#    warmup_and_decay_args: None
#    warmup_and_cosine_args: None
#    warmup_decay_and_cyclic_decay_args: 1e-6,3,4e-4,8,3e-6,4e-4,8,3e-6
#    iters_to_accumulate: 2
#    override_lr: False
#    binary_loss_name: focal+bce+wbce-c
#    focal_loss_weight: 1
#    bce_loss_weight: 1
#    wbce_loss_weight: 1
#    num_workers: 3
#    device: GPU
#    use_amp: True
#    train_mimiccxr: True
#    mimiccxr_weight: 1.0
#    mimiccxr_view_mode: chest_imagenome
#    mimiccxr_balanced_sampling_mode: balanced_chexpert_labels_batchwise
#    mimiccxr_balanced_batch_size: 30
#    mimiccxr_qa_adapted_reports_filename: qa_adapted_reports__20220904_095810.json
#    chest_imagenome_labels_filename: None
#    chest_imagenome_label_names_filename: None
#    use_chest_imagenome_decent_images_only: True
#    save: True
#    use_gender: False
#    use_chexpert: True
#    mimiccxr_chexpert_labels_filename: chexpert_labels_per_report__20220904_113605.pkl
#    use_chest_imagenome: False
#    debug: False
# ----- Training model from scratch ------
# Computing number of labels and ranges for ensemble ...
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/metadata.json
# chexpert_range: (0, 14)
# ============================================================
# Precomputing sigmoid activations for ensemble ...
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/metadata.json
# ============================================================
# Model 1/1
# model_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/
# checkpoint_names = ['checkpoint_79_chou+chuc+chuc+chuc+chuc+cD+gacc+wmmp=0.6677.pt', 'checkpoint_135_chou+chuc+chuc+chuc+chuc+cD+gacc+wmmp=0.6689.pt']
# model_checkpoint_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/checkpoint_135_chou+chuc+chuc+chuc+chuc+cD+gacc+wmmp=0.6689.pt
# precomputed_chexpert_sigmoids_path = /mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/precomputed_chexpert_sigmoids(hash=340,3716123060218160099).pkl
# Precomputed sigmoids for CheXpert already exist.
# File size = 56.39 MB
# Skipping...
# precomputed_sigmoid_paths: [{'model_folder_path': '/mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/', 'chexpert_sigmoids_path': '/mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/precomputed_chexpert_sigmoids(hash=340,3716123060218160099).pkl'}]
# ============================================================
# Precomputing thresholds (for hard predictions) for ensemble ...
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/metadata.json
# ============================================================
# Model 1/1
# model_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/
# checkpoint_names = ['checkpoint_79_chou+chuc+chuc+chuc+chuc+cD+gacc+wmmp=0.6677.pt', 'checkpoint_135_chou+chuc+chuc+chuc+chuc+cD+gacc+wmmp=0.6689.pt']
# model_checkpoint_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/checkpoint_135_chou+chuc+chuc+chuc+chuc+cD+gacc+wmmp=0.6689.pt
# results_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/results/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/
# get_image_transform()
#   Using bounding box aware transforms
#     Returning default transform (no augmentation)
# Calibrating thresholds on MIMIC-CXR validation set
# score_name: f1
# Thresholds for CheXpert already cached at /mnt/data/pamessina/workspaces/medvqa-workspace/results/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/thresholds_chexpert(f1).pkl
# precomputed_thresholds_paths: [{'chexpert': '/mnt/data/pamessina/workspaces/medvqa-workspace/results/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/thresholds_chexpert(f1).pkl'}]
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Initializing tokenizer ...
# Loading /mnt/data/pamessina/workspaces/medvqa-workspace/cache/vocab(min_freq=10;mode=report;qa_adapted_reports__20220904_095810.json).pkl ...
# --------------------------------------------------
# 3) Creating instance of Labels2ReportModel ...
# Labels2ReportModel
#   gen_mode: pred2rep
#   vocab_size: 4833
#   embedding_dim: 512
#   num_input_labels: 14
#   labels_hidden_dim: 1024
#   num_output_labels: 14
#   transf_dec_num_memory_vecs: 10
#   transf_dec_hidden_dim: 512
#   transf_dec_nhead: 4
#   transf_dec_dim_forward: 512
#   transf_dec_num_layers: 3
#   start_idx: 1
#   dropout_prob: 0
# --------------------------------------------------
# 4) Defining optimizer ...
# create_optimizer(): name = adamw
# --------------------------------------------------
# 5) Defining scheduler ...
# Using exp-warmup+decay+cyclicdecay scheduler: 1e-6,3,4e-4,8,3e-6,4e-4,8,3e-6
# 1e-06 3 0.0004 8 3e-06 0.0004 8 3e-06
# self.steps_to_restart = 8
# self.steps = -1
# self.initial_lr = 0.0004
# --------------------------------------------------
# 6) Creating trainer and validator engines ...
# Using focal+bce+wbce-c loss
# binary_loss_kwargs: {'focal_weight': 1, 'bce_weight': 1, 'wbce_weight': 1}
# --------------------------------------------------
# 7) Defining collate_batch_fn ...
# --------------------------------------------------
# 8) Creating MIMIC-CXR_Labels2ReportTrainer ...
# 227835it [00:17, 13274.71it/s]
# max_idx_count = 377110
# actual_idx_count = 239513
# ** NOTE: 137597 images were skipped because they were not in the allowed DICOM IDs
# Random report:
# <s> lungs clear . cardiomediastinal silhouette normal . atherosclerotic calcified aorta arch . no osseous abnormality . no cardiopulmonary process </s>
# len(self.train_indices) = 234217
# len(self.val_indices) = 1934
# Loading CheXpert labels...
# Loading precomputed sigmoid paths for ensemble predictions...
#   Loading /mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/precomputed_chexpert_sigmoids(hash=340,3716123060218160099).pkl
#     _probs.shape = (242280, 14)
#     len(_dids) = 242280
#     _thresholds.shape = (14,)
#     _probs has been thresholded
#     Sanity checking chexpert labels
#     len(self.val_indices) = 1934
#     f1_score(_gt_labels, _pred_labels, average="micro") = 0.5885286783042394
#     f1_score(_gt_labels, _pred_labels, average="macro") = 0.48877588205948314
# Done loading precomputed sigmoid paths for ensemble predictions
# Balanced sampling mode: balanced_chexpert_labels_batchwise
# Regrouping indices by CheXpert labels for balanced sampling...
# 100%|████████████████████████████████| 234217/234217 [00:10<00:00, 22505.05it/s]
# Label: Lung Opacity              , # images: 77214 (other: 157003)
# Label: Pneumonia                 , # images: 38778 (other: 195439)
# Label: Atelectasis               , # images: 73131 (other: 161086)
# Label: Cardiomegaly              , # images: 75024 (other: 159193)
# Label: No Finding                , # images: 46379 (other: 187838)
# Label: Enlarged Cardiomediastinum, # images: 45700 (other: 188517)
# Label: Fracture                  , # images: 8993 (other: 225224)
# Label: Pleural Effusion          , # images: 71831 (other: 162386)
# Label: Consolidation             , # images: 20853 (other: 213364)
# Label: Pleural Other             , # images: 5183 (other: 229034)
# Label: Edema                     , # images: 45317 (other: 188900)
# Label: Lung Lesion               , # images: 10062 (other: 224155)
# Label: Support Devices           , # images: 94467 (other: 139750)
# Label: Pneumothorax              , # images: 13989 (other: 220228)
# --------------------------------------------------
# 9) Creating dataloaders ...
# len(_train_dataloaders) = 1
# len(_val_dataloaders) = 1
# _train_weights = [1.0]
# merged_dataset_name = mim
# --------------------------------------------------
# 10) Attaching metrics, losses, timer and events to engines ...
# --------------------------------------------------
# 11) Defining learning rate scheduler handler ...
# --------------------------------------------------
# 12) Defining checkpoint folder path ...
# checkpoint_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/report_gen/20230504_221528_mim_Labels2ReportModel(14,10,TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))
# metadata saved to /mnt/data/pamessina/workspaces/medvqa-workspace/models/report_gen/20230504_221528_mim_Labels2ReportModel(14,10,TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/metadata.json
# --------------------------------------------------
# 13) Defining log_metrics_handler ...
# MetricsLogger :: we'll be logging to /mnt/data/pamessina/workspaces/medvqa-workspace/models/report_gen/20230504_221528_mim_Labels2ReportModel(14,10,TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/metrics_logs.csv
# --------------------------------------------------
# 14) Running trainer engine ...
# ---- Epoch 1/68
# (1) Training stage (lr = 0.000001) ...
# loss 8.68585, wmdcmp 0.00611, report_loss 8.45434, 159.71 secs
# (2) Validation stage ...
# wmdcmp 0.00629, cD 0.00034, 16.60 secs
# ---- Epoch 2/68
# (1) Training stage (lr = 0.000007) ...
# loss 8.22349, wmdcmp 0.00143, report_loss 6.84237, 145.75 secs
# (2) Validation stage ...
# wmdcmp 0.01131, cD 0.00632, 12.21 secs
# ---- Epoch 3/68
# (1) Training stage (lr = 0.000054) ...
# loss 6.01942, wmdcmp 0.06994, report_loss 4.43875, 142.27 secs
# (2) Validation stage ...
# wmdcmp 0.05933, cD 0.13813, 13.81 secs
# ---- Epoch 4/68
# (1) Training stage (lr = 0.000400) ...
# loss 3.63605, wmdcmp 0.17551, report_loss 2.89861, 113.54 secs
# (2) Validation stage ...
# wmdcmp 0.10859, cD 0.28194, 12.06 secs
# ---- Epoch 5/68
# (1) Training stage (lr = 0.000217) ...
# loss 2.59169, wmdcmp 0.22105, report_loss 2.44309, 111.92 secs
# (2) Validation stage ...
# wmdcmp 0.10637, cD 0.25942, 12.24 secs
# ---- Epoch 6/68
# (1) Training stage (lr = 0.000118) ...
# loss 2.30617, wmdcmp 0.23282, report_loss 2.34060, 111.27 secs
# (2) Validation stage ...
# wmdcmp 0.10880, cD 0.27120, 11.82 secs
# ---- Epoch 7/68
# (1) Training stage (lr = 0.000064) ...
# loss 2.29109, wmdcmp 0.23787, report_loss 2.30062, 111.44 secs
# (2) Validation stage ...
# wmdcmp 0.10875, cD 0.29396, 12.02 secs
# ---- Epoch 8/68
# (1) Training stage (lr = 0.000035) ...
# loss 2.28221, wmdcmp 0.24140, report_loss 2.28017, 109.23 secs
# (2) Validation stage ...
# wmdcmp 0.10723, cD 0.27156, 12.26 secs
# ---- Epoch 9/68
# (1) Training stage (lr = 0.000019) ...
# loss 2.22464, wmdcmp 0.24204, report_loss 2.26642, 109.34 secs
# (2) Validation stage ...
# wmdcmp 0.10758, cD 0.26713, 12.33 secs
# ---- Epoch 10/68
# (1) Training stage (lr = 0.000010) ...
# loss 2.22715, wmdcmp 0.24425, report_loss 2.25309, 114.20 secs
# (2) Validation stage ...
# wmdcmp 0.10681, cD 0.27207, 12.29 secs
# ---- Epoch 11/68
# (1) Training stage (lr = 0.000006) ...
# loss 2.29204, wmdcmp 0.24191, report_loss 2.25961, 114.46 secs
# (2) Validation stage ...
# wmdcmp 0.10769, cD 0.26959, 12.31 secs
# ---- Epoch 12/68
# (1) Training stage (lr = 0.000003) ...
# loss 2.32779, wmdcmp 0.24313, report_loss 2.25861, 112.69 secs
# (2) Validation stage ...
# wmdcmp 0.10680, cD 0.26537, 12.29 secs
# ---- Epoch 13/68
# (1) Training stage (lr = 0.000400) ...
# loss 2.25634, wmdcmp 0.24475, report_loss 2.23440, 109.14 secs
# (2) Validation stage ...
# wmdcmp 0.11567, cD 0.32661, 12.06 secs
# ---- Epoch 14/68
# (1) Training stage (lr = 0.000199) ...
# loss 2.14786, wmdcmp 0.25721, report_loss 2.14749, 109.65 secs
# (2) Validation stage ...
# wmdcmp 0.11019, cD 0.27991, 11.96 secs
# ---- Epoch 15/68
# (1) Training stage (lr = 0.000099) ...
# loss 2.01040, wmdcmp 0.26220, report_loss 2.11275, 108.28 secs
# (2) Validation stage ...
# wmdcmp 0.10867, cD 0.27239, 8.59 secs
# ---- Epoch 16/68
# (1) Training stage (lr = 0.000049) ...
# loss 2.09312, wmdcmp 0.26488, report_loss 2.10088, 112.07 secs
# (2) Validation stage ...
# wmdcmp 0.10771, cD 0.27567, 12.21 secs
# ---- Epoch 17/68
# (1) Training stage (lr = 0.000024) ...
# loss 2.10131, wmdcmp 0.26719, report_loss 2.08585, 109.19 secs
# (2) Validation stage ...
# wmdcmp 0.10966, cD 0.27322, 11.97 secs
# ---- Epoch 18/68
# (1) Training stage (lr = 0.000012) ...
# loss 2.15116, wmdcmp 0.26837, report_loss 2.07899, 108.63 secs
# (2) Validation stage ...
# wmdcmp 0.10869, cD 0.28097, 12.25 secs
# ---- Epoch 19/68
# (1) Training stage (lr = 0.000006) ...
# loss 2.02332, wmdcmp 0.26715, report_loss 2.08226, 110.82 secs
# (2) Validation stage ...
# wmdcmp 0.11064, cD 0.30091, 12.00 secs
# ---- Epoch 20/68
# (1) Training stage (lr = 0.000003) ...
# loss 2.01271, wmdcmp 0.26749, report_loss 2.07907, 112.16 secs
# (2) Validation stage ...
# wmdcmp 0.11109, cD 0.30390, 12.62 secs
# ---- Epoch 21/68
# (1) Training stage (lr = 0.000400) ...
# loss 1.91246, wmdcmp 0.26331, report_loss 2.09542, 113.00 secs
# (2) Validation stage ...
# wmdcmp 0.11845, cD 0.33869, 12.64 secs
# ---- Epoch 22/68
# (1) Training stage (lr = 0.000199) ...
# loss 1.98203, wmdcmp 0.27184, report_loss 2.04306, 109.15 secs
# (2) Validation stage ...
# wmdcmp 0.10759, cD 0.28233, 12.35 secs
# ---- Epoch 23/68
# (1) Training stage (lr = 0.000099) ...
# loss 2.09561, wmdcmp 0.27665, report_loss 2.01129, 108.80 secs
# (2) Validation stage ...
# wmdcmp 0.11758, cD 0.36178, 12.07 secs
# ---- Epoch 24/68
# (1) Training stage (lr = 0.000049) ...
# loss 2.12106, wmdcmp 0.27856, report_loss 2.00531, 109.58 secs
# (2) Validation stage ...
# wmdcmp 0.10857, cD 0.30212, 11.93 secs
# ---- Epoch 25/68
# (1) Training stage (lr = 0.000024) ...
# loss 2.02645, wmdcmp 0.28105, report_loss 1.98939, 109.98 secs
# (2) Validation stage ...
# wmdcmp 0.11982, cD 0.34762, 11.21 secs
# ---- Epoch 26/68
# (1) Training stage (lr = 0.000012) ...
# loss 1.98263, wmdcmp 0.28012, report_loss 1.98600, 109.48 secs
# (2) Validation stage ...
# wmdcmp 0.10460, cD 0.27095, 12.17 secs
# ---- Epoch 27/68
# (1) Training stage (lr = 0.000006) ...
# loss 2.05762, wmdcmp 0.28125, report_loss 1.98185, 108.71 secs
# (2) Validation stage ...
# wmdcmp 0.10579, cD 0.27644, 12.24 secs
# ---- Epoch 28/68
# (1) Training stage (lr = 0.000003) ...
# loss 1.94600, wmdcmp 0.28009, report_loss 1.98467, 107.72 secs
# (2) Validation stage ...
# wmdcmp 0.10624, cD 0.27890, 12.19 secs
# ---- Epoch 29/68
# (1) Training stage (lr = 0.000400) ...
# loss 1.92415, wmdcmp 0.27569, report_loss 2.01262, 109.20 secs
# (2) Validation stage ...
# wmdcmp 0.11730, cD 0.35038, 12.28 secs
# ---- Epoch 30/68
# (1) Training stage (lr = 0.000199) ...
# loss 1.88011, wmdcmp 0.28211, report_loss 1.97355, 108.10 secs
# (2) Validation stage ...
# wmdcmp 0.11712, cD 0.32690, 12.12 secs
# ---- Epoch 31/68
# (1) Training stage (lr = 0.000099) ...
# loss 1.99658, wmdcmp 0.28608, report_loss 1.94648, 106.71 secs
# (2) Validation stage ...
# wmdcmp 0.10734, cD 0.26587, 11.98 secs
# ---- Epoch 32/68
# (1) Training stage (lr = 0.000049) ...
# loss 1.98907, wmdcmp 0.28850, report_loss 1.93818, 108.21 secs
# (2) Validation stage ...
# wmdcmp 0.10340, cD 0.27249, 12.13 secs
# ---- Epoch 33/68
# (1) Training stage (lr = 0.000024) ...
# loss 2.03373, wmdcmp 0.28976, report_loss 1.92828, 108.43 secs
# (2) Validation stage ...
# wmdcmp 0.11856, cD 0.32971, 12.27 secs
# ---- Epoch 34/68
# (1) Training stage (lr = 0.000012) ...
# loss 1.92924, wmdcmp 0.28928, report_loss 1.92683, 108.36 secs
# (2) Validation stage ...
# wmdcmp 0.10767, cD 0.27546, 12.27 secs
# ---- Epoch 35/68
# (1) Training stage (lr = 0.000006) ...
# loss 2.03907, wmdcmp 0.29069, report_loss 1.91941, 107.83 secs
# (2) Validation stage ...
# wmdcmp 0.10729, cD 0.27765, 11.86 secs
# ---- Epoch 36/68
# (1) Training stage (lr = 0.000003) ...
# loss 1.82884, wmdcmp 0.28943, report_loss 1.92701, 109.89 secs
# (2) Validation stage ...
# wmdcmp 0.10726, cD 0.27589, 12.18 secs
# ---- Epoch 37/68
# (1) Training stage (lr = 0.000400) ...
# loss 1.87608, wmdcmp 0.28313, report_loss 1.96207, 110.08 secs
# (2) Validation stage ...
# wmdcmp 0.08969, cD 0.26311, 12.31 secs
# ---- Epoch 38/68
# (1) Training stage (lr = 0.000199) ...
# loss 1.95057, wmdcmp 0.28839, report_loss 1.92302, 107.21 secs
# (2) Validation stage ...
# wmdcmp 0.11367, cD 0.31659, 12.87 secs
# ---- Epoch 39/68
# (1) Training stage (lr = 0.000099) ...
# loss 2.00381, wmdcmp 0.29262, report_loss 1.90087, 109.21 secs
# (2) Validation stage ...
# wmdcmp 0.10145, cD 0.26988, 12.34 secs
# ---- Epoch 40/68
# (1) Training stage (lr = 0.000049) ...
# loss 1.85478, wmdcmp 0.29526, report_loss 1.88815, 109.61 secs
# (2) Validation stage ...
# wmdcmp 0.10682, cD 0.28060, 12.12 secs
# ---- Epoch 41/68
# (1) Training stage (lr = 0.000024) ...
# loss 1.80187, wmdcmp 0.29629, report_loss 1.88571, 109.49 secs
# (2) Validation stage ...
# wmdcmp 0.10608, cD 0.28197, 11.92 secs
# ---- Epoch 42/68
# (1) Training stage (lr = 0.000012) ...
# loss 1.82146, wmdcmp 0.29612, report_loss 1.87934, 108.07 secs
# (2) Validation stage ...
# wmdcmp 0.10663, cD 0.27851, 12.18 secs
# ---- Epoch 43/68
# (1) Training stage (lr = 0.000006) ...
# loss 1.85222, wmdcmp 0.29752, report_loss 1.87294, 109.50 secs
# (2) Validation stage ...
# wmdcmp 0.10425, cD 0.27574, 12.23 secs
# ---- Epoch 44/68
# (1) Training stage (lr = 0.000003) ...
# loss 1.85353, wmdcmp 0.29656, report_loss 1.87564, 108.80 secs
# (2) Validation stage ...
# wmdcmp 0.10512, cD 0.27834, 12.22 secs
# ---- Epoch 45/68
# (1) Training stage (lr = 0.000400) ...
# loss 1.88778, wmdcmp 0.28935, report_loss 1.91376, 108.73 secs
# (2) Validation stage ...
# wmdcmp 0.10627, cD 0.30903, 12.31 secs
# ---- Epoch 46/68
# (1) Training stage (lr = 0.000199) ...
# loss 2.04670, wmdcmp 0.29534, report_loss 1.88297, 110.08 secs
# (2) Validation stage ...
# wmdcmp 0.11748, cD 0.32652, 11.57 secs
# ---- Epoch 47/68
# (1) Training stage (lr = 0.000099) ...
# loss 1.96437, wmdcmp 0.29935, report_loss 1.86199, 108.13 secs
# (2) Validation stage ...
# wmdcmp 0.10690, cD 0.27589, 11.85 secs
# ---- Epoch 48/68
# (1) Training stage (lr = 0.000049) ...
# loss 1.82139, wmdcmp 0.30081, report_loss 1.85017, 106.22 secs
# (2) Validation stage ...
# wmdcmp 0.10618, cD 0.28148, 12.05 secs
# ---- Epoch 49/68
# (1) Training stage (lr = 0.000024) ...
# loss 1.78175, wmdcmp 0.30063, report_loss 1.84798, 107.29 secs
# (2) Validation stage ...
# wmdcmp 0.10786, cD 0.29542, 12.17 secs
# ---- Epoch 50/68
# (1) Training stage (lr = 0.000012) ...
# loss 1.68651, wmdcmp 0.30195, report_loss 1.84084, 112.50 secs
# (2) Validation stage ...
# wmdcmp 0.10839, cD 0.29258, 12.08 secs
# ---- Epoch 51/68
# (1) Training stage (lr = 0.000006) ...
# loss 1.87304, wmdcmp 0.30209, report_loss 1.83777, 111.43 secs
# (2) Validation stage ...
# wmdcmp 0.10801, cD 0.29093, 12.10 secs
# ---- Epoch 52/68
# (1) Training stage (lr = 0.000003) ...
# loss 1.89480, wmdcmp 0.30135, report_loss 1.84341, 109.74 secs
# (2) Validation stage ...
# wmdcmp 0.10845, cD 0.29284, 12.09 secs
# ---- Epoch 53/68
# (1) Training stage (lr = 0.000400) ...
# loss 1.93212, wmdcmp 0.29434, report_loss 1.87972, 109.89 secs
# (2) Validation stage ...
# wmdcmp 0.10029, cD 0.28638, 12.28 secs
# ---- Epoch 54/68
# (1) Training stage (lr = 0.000199) ...
# loss 1.94472, wmdcmp 0.29977, report_loss 1.85307, 109.11 secs
# (2) Validation stage ...
# wmdcmp 0.10054, cD 0.27785, 12.03 secs
# ---- Epoch 55/68
# (1) Training stage (lr = 0.000099) ...
# loss 1.83662, wmdcmp 0.30376, report_loss 1.82988, 107.75 secs
# (2) Validation stage ...
# wmdcmp 0.10877, cD 0.27992, 12.72 secs
# ---- Epoch 56/68
# (1) Training stage (lr = 0.000049) ...
# loss 1.77718, wmdcmp 0.30408, report_loss 1.82209, 107.05 secs
# (2) Validation stage ...
# wmdcmp 0.10428, cD 0.27610, 12.08 secs
# ---- Epoch 57/68
# (1) Training stage (lr = 0.000024) ...
# loss 1.80031, wmdcmp 0.30666, report_loss 1.81229, 107.57 secs
# (2) Validation stage ...
# wmdcmp 0.10460, cD 0.27333, 12.23 secs
# ---- Epoch 58/68
# (1) Training stage (lr = 0.000012) ...
# loss 1.85979, wmdcmp 0.30725, report_loss 1.80630, 106.95 secs
# (2) Validation stage ...
# wmdcmp 0.10494, cD 0.27385, 12.01 secs
# ---- Epoch 59/68
# (1) Training stage (lr = 0.000006) ...
# loss 1.87312, wmdcmp 0.30783, report_loss 1.80229, 106.90 secs
# (2) Validation stage ...
# wmdcmp 0.10483, cD 0.27412, 12.10 secs
# ---- Epoch 60/68
# (1) Training stage (lr = 0.000003) ...
# loss 1.82766, wmdcmp 0.30629, report_loss 1.81184, 107.35 secs
# (2) Validation stage ...
# wmdcmp 0.10457, cD 0.27185, 12.13 secs
# ---- Epoch 61/68
# (1) Training stage (lr = 0.000400) ...
# loss 1.86312, wmdcmp 0.29945, report_loss 1.84514, 107.14 secs
# (2) Validation stage ...
# wmdcmp 0.10224, cD 0.27275, 12.57 secs
# ---- Epoch 62/68
# (1) Training stage (lr = 0.000199) ...
# loss 1.88620, wmdcmp 0.30373, report_loss 1.82869, 108.52 secs
# (2) Validation stage ...
# wmdcmp 0.10307, cD 0.25779, 12.09 secs
# ---- Epoch 63/68
# (1) Training stage (lr = 0.000099) ...
# loss 1.68888, wmdcmp 0.30616, report_loss 1.80534, 108.22 secs
# (2) Validation stage ...
# wmdcmp 0.11852, cD 0.35016, 12.11 secs
# ---- Epoch 64/68
# (1) Training stage (lr = 0.000049) ...
# loss 1.74597, wmdcmp 0.30910, report_loss 1.79429, 112.24 secs
# (2) Validation stage ...
# wmdcmp 0.11548, cD 0.33484, 12.13 secs
# ---- Epoch 65/68
# (1) Training stage (lr = 0.000024) ...
# loss 1.78362, wmdcmp 0.30973, report_loss 1.78729, 112.00 secs
# (2) Validation stage ...
# wmdcmp 0.10481, cD 0.28161, 12.15 secs
# ---- Epoch 66/68
# (1) Training stage (lr = 0.000012) ...
# loss 1.82118, wmdcmp 0.31049, report_loss 1.78207, 107.11 secs
# (2) Validation stage ...
# wmdcmp 0.10524, cD 0.27373, 12.08 secs
# ---- Epoch 67/68
# (1) Training stage (lr = 0.000006) ...
# loss 1.77399, wmdcmp 0.31027, report_loss 1.78021, 110.03 secs
# (2) Validation stage ...
# wmdcmp 0.10523, cD 0.27515, 12.02 secs
# ---- Epoch 68/68
# (1) Training stage (lr = 0.000003) ...
# loss 1.75621, wmdcmp 0.31119, report_loss 1.78059, 107.46 secs
# (2) Validation stage ...
# wmdcmp 0.10574, cD 0.28246, 12.10 secs

# %%
# !/home/pamessina/venv2/bin/python ../train_labels2report.py \
    --generation-mode "pred2rep" \
    --use-ensemble \
    --ensemble-model-checkpoint-folder-paths \
        "/mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/" \
    --ensemble-batch-size 160 \
    --ensemble-num-workers 3 \
    --use-hard-predictions \
    --filter-labels \
    --label-score-threshold 0.7 \
    --epochs 68 \
    --batches-per-epoch 300 \
    --batch-size 200 \
    --num-workers 3 \
    --iters-to-accumulate 2 \
    --optimizer-name "adamw" \
    --scheduler "exp-warmup+decay+cyclicdecay" \
    --lr 1e-6 \
    --warmup-decay-and-cyclic-decay-args "1e-6,3,4e-4,8,3e-6,4e-4,8,3e-6" \
    --use-mimiccxr \
    --mimiccxr-weight 1.0 \
    --mimiccxr-view-mode "chest_imagenome" \
    --mimiccxr-balanced-sampling-mode "balanced_chest_imagenome_global_labels_batchwise" \
    --mimiccxr-balanced-batch-size 30 \
    --mimiccxr-qa-adapted-reports-filename "qa_adapted_reports__20220904_095810.json" \
    --use-chest-imagenome \
    --use-chest-imagenome-decent-images-only \
    --chest-imagenome-label-names-filename "labels(min_freq=100).pkl" \
    --chest-imagenome-labels-filename "imageId2labels(min_freq=100).pkl" \
    --use-chexpert \
    --mimiccxr-chexpert-labels-filename "chexpert_labels_per_report__20220904_113605.pkl" \
    --use-medical-tokenization \
    --medical-terms-frequency-filename "medical_terms_frequency__20220918_184255.pkl" \
    --binary-loss-name "focal+bce+wbce-c" \
    --labels-hidden-dim 1024 \
    --embedding-dim 512 \
    --transf-dec-num-memory-vecs 10 \
    --transf-dec-hidden-dim 512 \
    --transf-dec-nhead 4 \
    --transf-dec-dim-forward 512 \
    --transf-dec-num-layers 3 \
    --use-amp \
    --save
# Out:
# script's arguments:
#    epochs: 68
#    batches_per_epoch: 300
#    batch_size: 200
#    checkpoint_folder: None
#    generation_mode: pred2rep
#    use_ensemble: True
#    ensemble_model_checkpoint_folder_paths: ['/mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/']
#    ensemble_batch_size: 160
#    ensemble_num_workers: 3
#    use_hard_predictions: True
#    pretrained_checkpoint_folder_path: None
#    labels_hidden_dim: 1024
#    embedding_dim: 512
#    transf_dec_num_memory_vecs: 10
#    transf_dec_hidden_dim: 512
#    transf_dec_nhead: 4
#    transf_dec_dim_forward: 512
#    transf_dec_num_layers: 3
#    dropout_prob: 0
#    vocab_min_freq: 10
#    use_medical_tokenization: True
#    medical_terms_frequency_filename: medical_terms_frequency__20220918_184255.pkl
#    optimizer_name: adamw
#    lr: 1e-06
#    scheduler: exp-warmup+decay+cyclicdecay
#    lr_decay: 0.76
#    lr_decay_patience: 2
#    warmup_and_decay_args: None
#    warmup_and_cosine_args: None
#    warmup_decay_and_cyclic_decay_args: 1e-6,3,4e-4,8,3e-6,4e-4,8,3e-6
#    iters_to_accumulate: 2
#    override_lr: False
#    binary_loss_name: focal+bce+wbce-c
#    focal_loss_weight: 1
#    bce_loss_weight: 1
#    wbce_loss_weight: 1
#    num_workers: 3
#    device: GPU
#    use_amp: True
#    train_mimiccxr: True
#    mimiccxr_weight: 1.0
#    mimiccxr_view_mode: chest_imagenome
#    mimiccxr_balanced_sampling_mode: balanced_chest_imagenome_global_labels_batchwise
#    mimiccxr_balanced_batch_size: 30
#    mimiccxr_qa_adapted_reports_filename: qa_adapted_reports__20220904_095810.json
#    chest_imagenome_labels_filename: imageId2labels(min_freq=100).pkl
#    chest_imagenome_label_names_filename: labels(min_freq=100).pkl
#    use_chest_imagenome_decent_images_only: True
#    save: True
#    use_gender: False
#    use_chexpert: True
#    mimiccxr_chexpert_labels_filename: chexpert_labels_per_report__20220904_113605.pkl
#    use_chest_imagenome: True
#    filter_labels: True
#    top_k_chexpert_labels: None
#    top_k_chest_imagenome_labels: None
#    label_score_threshold: 0.7
#    debug: False
# ----- Training model from scratch ------
# Computing number of labels and ranges for ensemble ...
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/metadata.json
# chest_imagenome_range: (0, 627)
# chexpert_range: (627, 641)
# ============================================================
# Precomputing sigmoid activations for ensemble ...
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/metadata.json
# ============================================================
# Model 1/1
# model_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/
# checkpoint_names = ['checkpoint_79_chou+chuc+chuc+chuc+chuc+cD+gacc+wmmp=0.6677.pt', 'checkpoint_135_chou+chuc+chuc+chuc+chuc+cD+gacc+wmmp=0.6689.pt']
# model_checkpoint_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/checkpoint_135_chou+chuc+chuc+chuc+chuc+cD+gacc+wmmp=0.6689.pt
# precomputed_chexpert_sigmoids_path = /mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/precomputed_chexpert_sigmoids(hash=340,3716123060218160099).pkl
# Precomputed sigmoids for CheXpert already exist.
# File size = 56.39 MB
# precomputed_chest_imagenome_sigmoids_path = /mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/precomputed_chest_imagenome_sigmoids(hash=347,2103260294420767687).pkl
# Precomputed sigmoids for Chest ImaGenome already exist.
# File size = 339.66 MB
# Skipping...
# precomputed_sigmoid_paths: [{'model_folder_path': '/mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/', 'chexpert_sigmoids_path': '/mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/precomputed_chexpert_sigmoids(hash=340,3716123060218160099).pkl', 'chest_imagenome_sigmoids_path': '/mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/precomputed_chest_imagenome_sigmoids(hash=347,2103260294420767687).pkl'}]
# ============================================================
# Precomputing thresholds (for hard predictions) for ensemble ...
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/metadata.json
# ============================================================
# Model 1/1
# model_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/
# checkpoint_names = ['checkpoint_79_chou+chuc+chuc+chuc+chuc+cD+gacc+wmmp=0.6677.pt', 'checkpoint_135_chou+chuc+chuc+chuc+chuc+cD+gacc+wmmp=0.6689.pt']
# model_checkpoint_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/checkpoint_135_chou+chuc+chuc+chuc+chuc+cD+gacc+wmmp=0.6689.pt
# results_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/results/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/
# get_image_transform()
#   Using bounding box aware transforms
#     Returning default transform (no augmentation)
# Calibrating thresholds on MIMIC-CXR validation set
# score_name: f1
# Thresholds for CheXpert already cached at /mnt/data/pamessina/workspaces/medvqa-workspace/results/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/thresholds_chexpert(f1).pkl
# Thresholds for Chest ImaGenome already cached at /mnt/data/pamessina/workspaces/medvqa-workspace/results/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/thresholds_chest_imagenome(f1).pkl
# precomputed_thresholds_paths: [{'chexpert': '/mnt/data/pamessina/workspaces/medvqa-workspace/results/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/thresholds_chexpert(f1).pkl', 'chest_imagenome': '/mnt/data/pamessina/workspaces/medvqa-workspace/results/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/thresholds_chest_imagenome(f1).pkl'}]
# ============================================================
# Precomputing filtered labels for ensemble ...
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/metadata.json
# ============================================================
# Model 1/1
# model_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/
# results_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/results/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/
# get_image_transform()
#   Using bounding box aware transforms
#     Returning default transform (no augmentation)
# Loading cached chexpert predictions and ground truth...
# len(dicom_id_to_pred_chexpert_probs): 3389
# len(dicom_id_to_gt_chexpert_labels): 3389
# Loading cached chest imagenome predictions and ground truth...
# len(dicom_id_to_pred_chest_imagenome_probs): 3389
# len(dicom_id_to_gt_chest_imagenome_labels): 3389
# Top 3 label classes with the highest f1 scores:
# 1. Support Devices: 0.8737220226581928
# 2. Pleural Effusion: 0.743933588761175
# 3. Cardiomegaly: 0.7198264171413074
# Top 25 label classes with the highest f1 scores:
# 1. ('nlp', 'abnormal'): 0.9645215788665336
# 2. ('anatomicalfinding', 'lung opacity'): 0.9258260283209708
# 3. ('right lung', 'nlp', 'abnormal'): 0.902990264255911
# 4. ('left lung', 'nlp', 'abnormal'): 0.8949362728212196
# 6. ('left lung', 'anatomicalfinding', 'lung opacity'): 0.8683655872772562
# 7. ('mediastinum', 'device', 'cardiac pacer and wires'): 0.84472049689441
# 8. ('cardiac silhouette', 'device', 'cardiac pacer and wires'): 0.8446115288220551
# 9. ('trachea', 'tubesandlines', 'endotracheal tube'): 0.7786096256684492
# 11. ('device', 'cardiac pacer and wires'): 0.7708333333333333
# 12. ('tubesandlines', 'endotracheal tube'): 0.7704918032786885
# 13. ('anatomicalfinding', 'pleural effusion'): 0.7588336192109778
# 14. ('anatomicalfinding', 'subcutaneous air'): 0.7428571428571429
# 16. ('cardiac silhouette', 'nlp', 'abnormal'): 0.7306573589296103
# 17. ('tubesandlines', 'enteric tube'): 0.7296849087893864
# 18. ('mediastinum', 'tubesandlines', 'enteric tube'): 0.7274233637116817
# 19. ('right costophrenic angle', 'anatomicalfinding', 'pleural effusion'): 0.7223903177004539
# 21. ('neck', 'tubesandlines', 'enteric tube'): 0.7194899817850637
# 22. ('anatomicalfinding', 'enlarged cardiac silhouette'): 0.7153047989623865
# 23. ('right lung', 'anatomicalfinding', 'pleural effusion'): 0.7146974063400577
# 25. ('right costophrenic angle', 'anatomicalfinding', 'lung opacity'): 0.7143381004767144
# precomputed_filtered_labels_paths: [{'chexpert_indices_path': '/mnt/data/pamessina/workspaces/medvqa-workspace/results/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/chexpert_top_3_out_of_14_labels_f1_(score_threshold_0.70)_indices.pkl', 'chexpert_num_indices': 3, 'chest_imagenome_indices_path': '/mnt/data/pamessina/workspaces/medvqa-workspace/results/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/chest_imagenome_top_25_out_of_627_labels_f1_(score_threshold_0.70)_indices.pkl', 'chest_imagenome_num_indices': 25}]
# num_input_labels (after update): 28
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Initializing tokenizer ...
# Loading /mnt/data/pamessina/workspaces/medvqa-workspace/cache/vocab(min_freq=10;mode=report;qa_adapted_reports__20220904_095810.json).pkl ...
# --------------------------------------------------
# 3) Creating instance of Labels2ReportModel ...
# Labels2ReportModel
#   gen_mode: pred2rep
#   vocab_size: 4833
#   embedding_dim: 512
#   num_input_labels: 28
#   labels_hidden_dim: 1024
#   num_output_labels: 641
#   transf_dec_num_memory_vecs: 10
#   transf_dec_hidden_dim: 512
#   transf_dec_nhead: 4
#   transf_dec_dim_forward: 512
#   transf_dec_num_layers: 3
#   start_idx: 1
#   dropout_prob: 0
# --------------------------------------------------
# 4) Defining optimizer ...
# create_optimizer(): name = adamw
# --------------------------------------------------
# 5) Defining scheduler ...
# Using exp-warmup+decay+cyclicdecay scheduler: 1e-6,3,4e-4,8,3e-6,4e-4,8,3e-6
# 1e-06 3 0.0004 8 3e-06 0.0004 8 3e-06
# self.steps_to_restart = 8
# self.steps = -1
# self.initial_lr = 0.0004
# --------------------------------------------------
# 6) Creating trainer and validator engines ...
# Using focal+bce+wbce-c loss
# binary_loss_kwargs: {'focal_weight': 1, 'bce_weight': 1, 'wbce_weight': 1}
# --------------------------------------------------
# 7) Defining collate_batch_fn ...
# --------------------------------------------------
# 8) Creating MIMIC-CXR_Labels2ReportTrainer ...
# 227835it [00:17, 13274.60it/s]
# max_idx_count = 377110
# actual_idx_count = 239513
# ** NOTE: 137597 images were skipped because they were not in the allowed DICOM IDs
# Random report:
# <s> ight sided pacemaker normal position . cardiomegaly . left base atelectasis . multiple distended loops bowel , abdomen . no . distended bowel loops </s>
# len(self.train_indices) = 234217
# len(self.val_indices) = 1934
# Loading CheXpert labels...
# Loading Chest Imagenome labels...
# Loading precomputed sigmoid paths for ensemble predictions...
#   Loading /mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/precomputed_chexpert_sigmoids(hash=340,3716123060218160099).pkl
#     _probs.shape = (242280, 14)
#     len(_dids) = 242280
#     _thresholds.shape = (14,)
#     _probs has been thresholded
#     _label_indices.shape = (3,)
#     _probs has been filtered
#     Sanity checking chexpert labels
#     len(self.val_indices) = 1934
#     f1_score(_gt_labels, _pred_labels, average="micro") = 0.7682291666666667
#     f1_score(_gt_labels, _pred_labels, average="macro") = 0.7639848780031259
#   Loading /mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/precomputed_chest_imagenome_sigmoids(hash=347,2103260294420767687).pkl
#     _probs.shape = (242280, 627)
#     len(_dids) = 242280
#     _thresholds.shape = (627,)
#     _probs has been thresholded
#     _label_indices.shape = (25,)
#     _probs has been filtered
#     Sanity checking chest_imagenome labels
#     len(self.val_indices) = 1934
#     f1_score(_gt_labels, _pred_labels, average="micro") = 0.794793560114256
#     f1_score(_gt_labels, _pred_labels, average="macro") = 0.7549020071170479
# Done loading precomputed sigmoid paths for ensemble predictions
# Balanced sampling mode: balanced_chest_imagenome_global_labels_batchwise
# Regrouping indices by Chest Imagenome labels for balanced sampling...
# 627it [01:00, 10.30it/s]
# Global: airspace opacity                        , # images: 8595 (other: 225622)
# Global: atelectasis                             , # images: 79106 (other: 155111)
# Global: bone lesion                             , # images: 1692 (other: 232525)
# Global: bronchiectasis                          , # images: 905 (other: 233312)
# Global: calcified nodule                        , # images: 2708 (other: 231509)
# Global: clavicle fracture                       , # images: 862 (other: 233355)
# Global: consolidation                           , # images: 17769 (other: 216448)
# Global: costophrenic angle blunting             , # images: 5723 (other: 228494)
# Global: cyst/bullae                             , # images: 874 (other: 233343)
# Global: elevated hemidiaphragm                  , # images: 6412 (other: 227805)
# Global: enlarged cardiac silhouette             , # images: 57654 (other: 176563)
# Global: enlarged hilum                          , # images: 8983 (other: 225234)
# Global: hernia                                  , # images: 3025 (other: 231192)
# Global: hydropneumothorax                       , # images: 954 (other: 233263)
# Global: hyperaeration                           , # images: 10306 (other: 223911)
# Global: increased reticular markings/ild pattern, # images: 1373 (other: 232844)
# Global: infiltration                            , # images: 2977 (other: 231240)
# Global: linear/patchy atelectasis               , # images: 12797 (other: 221420)
# Global: lobar/segmental collapse                , # images: 9531 (other: 224686)
# Global: lung lesion                             , # images: 13455 (other: 220762)
# Global: lung opacity                            , # images: 154881 (other: 79336)
# Global: mass/nodule (not otherwise specified)   , # images: 7782 (other: 226435)
# Global: mediastinal displacement                , # images: 3438 (other: 230779)
# Global: mediastinal widening                    , # images: 5070 (other: 229147)
# Global: multiple masses/nodules                 , # images: 3730 (other: 230487)
# Global: pleural effusion                        , # images: 72076 (other: 162141)
# Global: pleural/parenchymal scarring            , # images: 14199 (other: 220018)
# Global: pneumomediastinum                       , # images: 864 (other: 233353)
# Global: pneumothorax                            , # images: 10640 (other: 223577)
# Global: pulmonary edema/hazy opacity            , # images: 35280 (other: 198937)
# Global: rib fracture                            , # images: 7080 (other: 227137)
# Global: scoliosis                               , # images: 3201 (other: 231016)
# Global: shoulder osteoarthritis                 , # images: 2178 (other: 232039)
# Global: spinal degenerative changes             , # images: 6810 (other: 227407)
# Global: spinal fracture                         , # images: 3101 (other: 231116)
# Global: sub-diaphragmatic air                   , # images: 1234 (other: 232983)
# Global: subcutaneous air                        , # images: 3377 (other: 230840)
# Global: superior mediastinal mass/enlargement   , # images: 3295 (other: 230922)
# Global: tortuous aorta                          , # images: 13462 (other: 220755)
# Global: vascular calcification                  , # images: 10172 (other: 224045)
# Global: vascular congestion                     , # images: 24614 (other: 209603)
# Global: vascular redistribution                 , # images: 3199 (other: 231018)
# Global: aortic graft/repair                     , # images: 115 (other: 234102)
# Global: cabg grafts                             , # images: 3839 (other: 230378)
# Global: cardiac pacer and wires                 , # images: 12453 (other: 221764)
# Global: prosthetic valve                        , # images: 2891 (other: 231326)
# Global: alveolar hemorrhage                     , # images: 1766 (other: 232451)
# Global: aspiration                              , # images: 8915 (other: 225302)
# Global: copd/emphysema                          , # images: 6553 (other: 227664)
# Global: fluid overload/heart failure            , # images: 6458 (other: 227759)
# Global: goiter                                  , # images: 614 (other: 233603)
# Global: granulomatous disease                   , # images: 2423 (other: 231794)
# Global: interstitial lung disease               , # images: 1943 (other: 232274)
# Global: lung cancer                             , # images: 1752 (other: 232465)
# Global: pericardial effusion                    , # images: 1400 (other: 232817)
# Global: pneumonia                               , # images: 34201 (other: 200016)
# Global: abnormal                                , # images: 184517 (other: 49700)
# Global: artifact                                , # images: 299 (other: 233918)
# Global: breast/nipple shadows                   , # images: 1020 (other: 233197)
# Global: low lung volumes                        , # images: 28214 (other: 206003)
# Global: rotated                                 , # images: 2036 (other: 232181)
# Global: skin fold                               , # images: 216 (other: 234001)
# Global: chest port                              , # images: 7247 (other: 226970)
# Global: chest tube                              , # images: 10271 (other: 223946)
# Global: endotracheal tube                       , # images: 22541 (other: 211676)
# Global: enteric tube                            , # images: 27915 (other: 206302)
# Global: ij line                                 , # images: 12109 (other: 222108)
# Global: intra-aortic balloon pump               , # images: 562 (other: 233655)
# Global: mediastinal drain                       , # images: 436 (other: 233781)
# Global: picc                                    , # images: 14281 (other: 219936)
# Global: pigtail catheter                        , # images: 3538 (other: 230679)
# Global: subclavian line                         , # images: 3883 (other: 230334)
# Global: swan-ganz catheter                      , # images: 2197 (other: 232020)
# Global: tracheostomy tube                       , # images: 4756 (other: 229461)
# --------------------------------------------------
# 9) Creating dataloaders ...
# len(_train_dataloaders) = 1
# len(_val_dataloaders) = 1
# _train_weights = [1.0]
# merged_dataset_name = mim
# --------------------------------------------------
# 10) Attaching metrics, losses, timer and events to engines ...
# --------------------------------------------------
# 11) Defining learning rate scheduler handler ...
# --------------------------------------------------
# 12) Defining checkpoint folder path ...
# checkpoint_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/report_gen/20230505_045954_mim_Labels2ReportModel(28,10,TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))
# metadata saved to /mnt/data/pamessina/workspaces/medvqa-workspace/models/report_gen/20230505_045954_mim_Labels2ReportModel(28,10,TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/metadata.json
# --------------------------------------------------
# 13) Defining log_metrics_handler ...
# MetricsLogger :: we'll be logging to /mnt/data/pamessina/workspaces/medvqa-workspace/models/report_gen/20230505_045954_mim_Labels2ReportModel(28,10,TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/metrics_logs.csv
# --------------------------------------------------
# 14) Running trainer engine ...
# ---- Epoch 1/68
# (1) Training stage (lr = 0.000001) ...
# loss 8.64347, wmdcmp 0.00502, report_loss 8.41293, 160.62 secs
# (2) Validation stage ...
# wmdcmp 0.00338, cD 0.00104, 12.43 secs
# ---- Epoch 2/68
# (1) Training stage (lr = 0.000007) ...
# loss 8.18476, wmdcmp 0.00117, report_loss 6.83898, 150.88 secs
# (2) Validation stage ...
# wmdcmp 0.00893, cD 0.00179, 13.87 secs
# ---- Epoch 3/68
# (1) Training stage (lr = 0.000054) ...
# loss 5.99966, wmdcmp 0.06003, report_loss 4.53334, 147.28 secs
# (2) Validation stage ...
# wmdcmp 0.05262, cD 0.13409, 13.25 secs
# ---- Epoch 4/68
# (1) Training stage (lr = 0.000400) ...
# loss 3.76684, wmdcmp 0.16686, report_loss 2.98155, 130.52 secs
# (2) Validation stage ...
# wmdcmp 0.11445, cD 0.33197, 12.35 secs
# ---- Epoch 5/68
# (1) Training stage (lr = 0.000217) ...
# loss 2.55096, wmdcmp 0.20909, report_loss 2.52000, 128.57 secs
# (2) Validation stage ...
# wmdcmp 0.10721, cD 0.28187, 12.59 secs
# ---- Epoch 6/68
# (1) Training stage (lr = 0.000118) ...
# loss 2.50108, wmdcmp 0.22115, report_loss 2.41543, 120.84 secs
# (2) Validation stage ...
# wmdcmp 0.11522, cD 0.32353, 12.44 secs
# ---- Epoch 7/68
# (1) Training stage (lr = 0.000064) ...
# loss 2.45215, wmdcmp 0.22680, report_loss 2.37172, 118.94 secs
# (2) Validation stage ...
# wmdcmp 0.12482, cD 0.35112, 12.62 secs
# ---- Epoch 8/68
# (1) Training stage (lr = 0.000035) ...
# loss 2.33518, wmdcmp 0.22932, report_loss 2.35484, 122.19 secs
# (2) Validation stage ...
# wmdcmp 0.12661, cD 0.37741, 12.67 secs
# ---- Epoch 9/68
# (1) Training stage (lr = 0.000019) ...
# loss 2.32671, wmdcmp 0.23043, report_loss 2.34064, 120.98 secs
# (2) Validation stage ...
# wmdcmp 0.12851, cD 0.37103, 12.54 secs
# ---- Epoch 10/68
# (1) Training stage (lr = 0.000010) ...
# loss 2.33921, wmdcmp 0.23005, report_loss 2.33831, 119.51 secs
# (2) Validation stage ...
# wmdcmp 0.12724, cD 0.37189, 12.65 secs
# ---- Epoch 11/68
# (1) Training stage (lr = 0.000006) ...
# loss 2.39430, wmdcmp 0.23135, report_loss 2.32997, 121.59 secs
# (2) Validation stage ...
# wmdcmp 0.12915, cD 0.37498, 13.33 secs
# ---- Epoch 12/68
# (1) Training stage (lr = 0.000003) ...
# loss 2.44190, wmdcmp 0.23114, report_loss 2.32582, 122.60 secs
# (2) Validation stage ...
# wmdcmp 0.12875, cD 0.38010, 12.32 secs
# ---- Epoch 13/68
# (1) Training stage (lr = 0.000400) ...
# loss 2.32705, wmdcmp 0.23295, report_loss 2.30625, 116.75 secs
# (2) Validation stage ...
# wmdcmp 0.10536, cD 0.30680, 12.67 secs
# ---- Epoch 14/68
# (1) Training stage (lr = 0.000199) ...
# loss 2.28519, wmdcmp 0.24490, report_loss 2.21641, 114.56 secs
# (2) Validation stage ...
# wmdcmp 0.12606, cD 0.33957, 12.58 secs
# ---- Epoch 15/68
# (1) Training stage (lr = 0.000099) ...
# loss 2.03647, wmdcmp 0.24906, report_loss 2.18005, 115.75 secs
# (2) Validation stage ...
# wmdcmp 0.11073, cD 0.32096, 12.76 secs
# ---- Epoch 16/68
# (1) Training stage (lr = 0.000049) ...
# loss 2.12452, wmdcmp 0.25246, report_loss 2.15683, 116.63 secs
# (2) Validation stage ...
# wmdcmp 0.12337, cD 0.35204, 15.63 secs
# ---- Epoch 17/68
# (1) Training stage (lr = 0.000024) ...
# loss 2.12202, wmdcmp 0.25429, report_loss 2.14924, 117.43 secs
# (2) Validation stage ...
# wmdcmp 0.11073, cD 0.30838, 12.87 secs
# ---- Epoch 18/68
# (1) Training stage (lr = 0.000012) ...
# loss 2.06421, wmdcmp 0.25414, report_loss 2.14692, 116.69 secs
# (2) Validation stage ...
# wmdcmp 0.12925, cD 0.38057, 12.71 secs
# ---- Epoch 19/68
# (1) Training stage (lr = 0.000006) ...
# loss 2.18081, wmdcmp 0.25465, report_loss 2.14216, 116.16 secs
# (2) Validation stage ...
# wmdcmp 0.12983, cD 0.38012, 12.63 secs
# ---- Epoch 20/68
# (1) Training stage (lr = 0.000003) ...
# loss 2.05246, wmdcmp 0.25426, report_loss 2.13929, 116.27 secs
# (2) Validation stage ...
# wmdcmp 0.12138, cD 0.33754, 12.91 secs
# ---- Epoch 21/68
# (1) Training stage (lr = 0.000400) ...
# loss 2.14729, wmdcmp 0.25175, report_loss 2.15678, 116.68 secs
# (2) Validation stage ...
# wmdcmp 0.12547, cD 0.35225, 13.04 secs
# ---- Epoch 22/68
# (1) Training stage (lr = 0.000199) ...
# loss 2.20234, wmdcmp 0.26007, report_loss 2.10065, 117.39 secs
# (2) Validation stage ...
# wmdcmp 0.11363, cD 0.31959, 13.90 secs
# ---- Epoch 23/68
# (1) Training stage (lr = 0.000099) ...
# loss 2.17708, wmdcmp 0.26593, report_loss 2.06651, 117.11 secs
# (2) Validation stage ...
# wmdcmp 0.10471, cD 0.30340, 12.96 secs
# ---- Epoch 24/68
# (1) Training stage (lr = 0.000049) ...
# loss 1.99291, wmdcmp 0.26681, report_loss 2.05417, 118.67 secs
# (2) Validation stage ...
# wmdcmp 0.12083, cD 0.34427, 14.69 secs
# ---- Epoch 25/68
# (1) Training stage (lr = 0.000024) ...
# loss 2.17446, wmdcmp 0.26824, report_loss 2.04546, 119.36 secs
# (2) Validation stage ...
# wmdcmp 0.11792, cD 0.32096, 12.90 secs
# ---- Epoch 26/68
# (1) Training stage (lr = 0.000012) ...
# loss 1.99490, wmdcmp 0.26749, report_loss 2.04347, 118.97 secs
# (2) Validation stage ...
# wmdcmp 0.11864, cD 0.32528, 12.89 secs
# ---- Epoch 27/68
# (1) Training stage (lr = 0.000006) ...
# loss 2.07189, wmdcmp 0.26941, report_loss 2.03797, 118.97 secs
# (2) Validation stage ...
# wmdcmp 0.12614, cD 0.37620, 12.88 secs
# ---- Epoch 28/68
# (1) Training stage (lr = 0.000003) ...
# loss 1.92505, wmdcmp 0.26963, report_loss 2.03603, 118.75 secs
# (2) Validation stage ...
# wmdcmp 0.11886, cD 0.32690, 13.18 secs
# ---- Epoch 29/68
# (1) Training stage (lr = 0.000400) ...
# loss 1.91763, wmdcmp 0.26471, report_loss 2.06396, 117.97 secs
# (2) Validation stage ...
# wmdcmp 0.11117, cD 0.31393, 12.50 secs
# ---- Epoch 30/68
# (1) Training stage (lr = 0.000199) ...
# loss 2.01044, wmdcmp 0.27080, report_loss 2.01511, 118.12 secs
# (2) Validation stage ...
# wmdcmp 0.11203, cD 0.31070, 13.06 secs
# ---- Epoch 31/68
# (1) Training stage (lr = 0.000099) ...
# loss 2.04179, wmdcmp 0.27658, report_loss 1.98907, 116.62 secs
# (2) Validation stage ...
# wmdcmp 0.10208, cD 0.28827, 13.12 secs
# ---- Epoch 32/68
# (1) Training stage (lr = 0.000049) ...
# loss 1.95373, wmdcmp 0.27726, report_loss 1.98123, 119.84 secs
# (2) Validation stage ...
# wmdcmp 0.11998, cD 0.34711, 13.68 secs
# ---- Epoch 33/68
# (1) Training stage (lr = 0.000024) ...
# loss 1.93515, wmdcmp 0.27849, report_loss 1.97364, 118.76 secs
# (2) Validation stage ...
# wmdcmp 0.11753, cD 0.32357, 12.52 secs
# ---- Epoch 34/68
# (1) Training stage (lr = 0.000012) ...
# loss 2.00026, wmdcmp 0.27871, report_loss 1.96892, 118.59 secs
# (2) Validation stage ...
# wmdcmp 0.11629, cD 0.32631, 12.65 secs
# ---- Epoch 35/68
# (1) Training stage (lr = 0.000006) ...
# loss 1.99365, wmdcmp 0.27894, report_loss 1.96908, 117.86 secs
# (2) Validation stage ...
# wmdcmp 0.11775, cD 0.32352, 13.08 secs
# ---- Epoch 36/68
# (1) Training stage (lr = 0.000003) ...
# loss 1.87035, wmdcmp 0.27930, report_loss 1.96590, 117.35 secs
# (2) Validation stage ...
# wmdcmp 0.11690, cD 0.32183, 14.45 secs
# ---- Epoch 37/68
# (1) Training stage (lr = 0.000400) ...
# loss 2.03082, wmdcmp 0.27334, report_loss 1.99856, 119.82 secs
# (2) Validation stage ...
# wmdcmp 0.11772, cD 0.32352, 13.18 secs
# ---- Epoch 38/68
# (1) Training stage (lr = 0.000199) ...
# loss 1.97826, wmdcmp 0.27888, report_loss 1.96313, 118.78 secs
# (2) Validation stage ...
# wmdcmp 0.10694, cD 0.29941, 13.18 secs
# ---- Epoch 39/68
# (1) Training stage (lr = 0.000099) ...
# loss 2.01926, wmdcmp 0.28273, report_loss 1.94102, 118.02 secs
# (2) Validation stage ...
# wmdcmp 0.11553, cD 0.31664, 12.75 secs
# ---- Epoch 40/68
# (1) Training stage (lr = 0.000049) ...
# loss 1.86102, wmdcmp 0.28547, report_loss 1.92482, 117.60 secs
# (2) Validation stage ...
# wmdcmp 0.11743, cD 0.36451, 12.86 secs
# ---- Epoch 41/68
# (1) Training stage (lr = 0.000024) ...
# loss 1.87490, wmdcmp 0.28638, report_loss 1.92152, 118.83 secs
# (2) Validation stage ...
# wmdcmp 0.11752, cD 0.33443, 12.88 secs
# ---- Epoch 42/68
# (1) Training stage (lr = 0.000012) ...
# loss 1.92126, wmdcmp 0.28667, report_loss 1.91655, 117.44 secs
# (2) Validation stage ...
# wmdcmp 0.11768, cD 0.32183, 13.03 secs
# ---- Epoch 43/68
# (1) Training stage (lr = 0.000006) ...
# loss 1.90294, wmdcmp 0.28778, report_loss 1.91111, 117.10 secs
# (2) Validation stage ...
# wmdcmp 0.11897, cD 0.33724, 12.89 secs
# ---- Epoch 44/68
# (1) Training stage (lr = 0.000003) ...
# loss 1.84423, wmdcmp 0.28643, report_loss 1.91287, 119.93 secs
# (2) Validation stage ...
# wmdcmp 0.11803, cD 0.32789, 14.54 secs
# ---- Epoch 45/68
# (1) Training stage (lr = 0.000400) ...
# loss 2.01188, wmdcmp 0.28055, report_loss 1.94856, 119.89 secs
# (2) Validation stage ...
# wmdcmp 0.12028, cD 0.37401, 12.70 secs
# ---- Epoch 46/68
# (1) Training stage (lr = 0.000199) ...
# loss 2.01941, wmdcmp 0.28647, report_loss 1.91983, 118.72 secs
# (2) Validation stage ...
# wmdcmp 0.12526, cD 0.35644, 13.90 secs
# ---- Epoch 47/68
# (1) Training stage (lr = 0.000099) ...
# loss 1.94383, wmdcmp 0.28832, report_loss 1.89619, 117.08 secs
# (2) Validation stage ...
# wmdcmp 0.11839, cD 0.33268, 12.91 secs
# ---- Epoch 48/68
# (1) Training stage (lr = 0.000049) ...
# loss 1.96495, wmdcmp 0.29066, report_loss 1.88537, 117.14 secs
# (2) Validation stage ...
# wmdcmp 0.11499, cD 0.31711, 12.81 secs
# ---- Epoch 49/68
# (1) Training stage (lr = 0.000024) ...
# loss 1.96216, wmdcmp 0.29251, report_loss 1.87493, 118.38 secs
# (2) Validation stage ...
# wmdcmp 0.11642, cD 0.31977, 13.11 secs
# ---- Epoch 50/68
# (1) Training stage (lr = 0.000012) ...
# loss 1.92799, wmdcmp 0.29392, report_loss 1.87072, 118.21 secs
# (2) Validation stage ...
# wmdcmp 0.11995, cD 0.32673, 13.77 secs
# ---- Epoch 51/68
# (1) Training stage (lr = 0.000006) ...
# loss 1.91912, wmdcmp 0.29440, report_loss 1.86596, 119.84 secs
# (2) Validation stage ...
# wmdcmp 0.11559, cD 0.32657, 12.81 secs
# ---- Epoch 52/68
# (1) Training stage (lr = 0.000003) ...
# loss 1.82011, wmdcmp 0.29319, report_loss 1.86896, 119.28 secs
# (2) Validation stage ...
# wmdcmp 0.11672, cD 0.32645, 12.96 secs
# ---- Epoch 53/68
# (1) Training stage (lr = 0.000400) ...
# loss 1.81023, wmdcmp 0.28569, report_loss 1.90866, 120.02 secs
# (2) Validation stage ...
# wmdcmp 0.10904, cD 0.26235, 12.65 secs
# ---- Epoch 54/68
# (1) Training stage (lr = 0.000199) ...
# loss 1.92650, wmdcmp 0.29056, report_loss 1.88128, 119.80 secs
# (2) Validation stage ...
# wmdcmp 0.12411, cD 0.36558, 12.69 secs
# ---- Epoch 55/68
# (1) Training stage (lr = 0.000099) ...
# loss 1.82614, wmdcmp 0.29523, report_loss 1.85919, 119.42 secs
# (2) Validation stage ...
# wmdcmp 0.12043, cD 0.31907, 12.72 secs
# ---- Epoch 56/68
# (1) Training stage (lr = 0.000049) ...
# loss 1.79001, wmdcmp 0.29703, report_loss 1.84537, 118.18 secs
# (2) Validation stage ...
# wmdcmp 0.12044, cD 0.32413, 14.32 secs
# ---- Epoch 57/68
# (1) Training stage (lr = 0.000024) ...
# loss 1.72676, wmdcmp 0.29763, report_loss 1.84334, 119.49 secs
# (2) Validation stage ...
# wmdcmp 0.11519, cD 0.33313, 13.92 secs
# ---- Epoch 58/68
# (1) Training stage (lr = 0.000012) ...
# loss 1.77981, wmdcmp 0.29824, report_loss 1.83478, 118.40 secs
# (2) Validation stage ...
# wmdcmp 0.12438, cD 0.36173, 12.70 secs
# ---- Epoch 59/68
# (1) Training stage (lr = 0.000006) ...
# loss 1.86605, wmdcmp 0.29743, report_loss 1.83691, 119.71 secs
# (2) Validation stage ...
# wmdcmp 0.11615, cD 0.32236, 12.83 secs
# ---- Epoch 60/68
# (1) Training stage (lr = 0.000003) ...
# loss 1.83221, wmdcmp 0.29834, report_loss 1.83276, 117.13 secs
# (2) Validation stage ...
# wmdcmp 0.11625, cD 0.32577, 12.63 secs
# ---- Epoch 61/68
# (1) Training stage (lr = 0.000400) ...
# loss 1.79545, wmdcmp 0.29066, report_loss 1.87787, 119.21 secs
# (2) Validation stage ...
# wmdcmp 0.11170, cD 0.30896, 12.91 secs
# ---- Epoch 62/68
# (1) Training stage (lr = 0.000199) ...
# loss 1.93167, wmdcmp 0.29353, report_loss 1.84981, 120.43 secs
# (2) Validation stage ...
# wmdcmp 0.12486, cD 0.37656, 12.69 secs
# ---- Epoch 63/68
# (1) Training stage (lr = 0.000099) ...
# loss 1.80054, wmdcmp 0.29927, report_loss 1.82696, 120.07 secs
# (2) Validation stage ...
# wmdcmp 0.11769, cD 0.33228, 12.90 secs
# ---- Epoch 64/68
# (1) Training stage (lr = 0.000049) ...
# loss 1.75041, wmdcmp 0.30128, report_loss 1.81760, 119.21 secs
# (2) Validation stage ...
# wmdcmp 0.12527, cD 0.35689, 12.77 secs
# ---- Epoch 65/68
# (1) Training stage (lr = 0.000024) ...
# loss 1.77192, wmdcmp 0.30233, report_loss 1.81063, 119.23 secs
# (2) Validation stage ...
# wmdcmp 0.11529, cD 0.31016, 13.80 secs
# ---- Epoch 66/68
# (1) Training stage (lr = 0.000012) ...
# loss 1.66003, wmdcmp 0.30304, report_loss 1.80739, 118.10 secs
# (2) Validation stage ...
# wmdcmp 0.11681, cD 0.31717, 13.83 secs
# ---- Epoch 67/68
# (1) Training stage (lr = 0.000006) ...
# loss 1.78192, wmdcmp 0.30349, report_loss 1.80217, 119.14 secs
# (2) Validation stage ...
# wmdcmp 0.11754, cD 0.32452, 12.62 secs
# ---- Epoch 68/68
# (1) Training stage (lr = 0.000003) ...
# loss 1.77767, wmdcmp 0.30341, report_loss 1.80470, 119.20 secs
# (2) Validation stage ...
# wmdcmp 0.11664, cD 0.32533, 13.62 secs
