# %%
# %env CUDA_VISIBLE_DEVICES=0
# Out:
# env: CUDA_VISIBLE_DEVICES=0

# %%
# !python ../../scripts/mimiccxr/export_sentences_and_cluster_ids.py \
--integrated_sentence_facts_filepath \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_sentence_facts(58655550,50990861).jsonl" \
--integrated_facts_metadata_filepath \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_fact_metadata(606074,61621903).jsonl" \
--paraphrased_anatomical_locations_filepaths \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_anatomical_locations__part1.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_anatomical_locations__part2.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-16k-0613_paraphrased_anatomical_locations__part3.jsonl" \
--paraphrased_observations_filepaths \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__single-words.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words__part1.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-16k-0613_paraphrased_observations__two-or-more-words__part2.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words__part3.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-16k-0613_paraphrased_observations__two-or-more-words__part4.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_paraphrased_observations__two-or-more-words_cluster-balanced.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words_cluster-balanced_1of5.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words_cluster-balanced_2of5.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words_cluster-balanced_3of5.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words_cluster-balanced_4of5.jsonl" \
--hard_triplets_filepaths \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_hard_triplets_from_facts(cluster-balanced,hardest)-part1.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_hard_triplets_from_facts(cluster-balanced,hardest)-part2.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_hard_triplets_from_facts(cluster-balanced,hardest)-part3.jsonl" \
--revised_groundings_file \
"/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/chest_imagenome/integrated_llm_revised_phrase_groundings.pkl" \
--batch_size 400 \
--num_workers 3 \
--model_name "microsoft/BiomedVLP-CXR-BERT-specialized"
# Out:
# 2025-06-02 11:44:05,778 - INFO - root - Logging configured (Color: True).
# 2025-06-02 11:44:05,778 - INFO - root - Logging configured (Color: True).
# 2025-06-02 11:44:05,780 - INFO - __main__ - Loading integrated sentence facts from /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_sentence_facts(58655550,50990861).jsonl
# 2025-06-02 11:44:11,748 - INFO - __main__ - Loading integrated facts metadata from /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_fact_metadata(606074,61621903).jsonl
# 2025-06-02 11:44:18,315 - INFO - __main__ - Loding paraphrased anatomical locations from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_anatomical_locations__part1.jsonl
# 2025-06-02 11:44:18,430 - INFO - __main__ - Loding paraphrased anatomical locations from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_anatomical_locations__part2.jsonl
# 2025-06-02 11:44:18,560 - INFO - __main__ - Loding paraphrased anatomical locations from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-16k-0613_paraphrased_anatomical_locations__part3.jsonl
# 2025-06-02 11:44:18,708 - INFO - __main__ - Loding paraphrased observations from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__single-words.jsonl
# 2025-06-02 11:44:18,726 - INFO - __main__ - Loding paraphrased observations from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words__part1.jsonl
# 2025-06-02 11:44:18,890 - INFO - __main__ - Loding paraphrased observations from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-16k-0613_paraphrased_observations__two-or-more-words__part2.jsonl
# 2025-06-02 11:44:19,063 - INFO - __main__ - Loding paraphrased observations from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words__part3.jsonl
# 2025-06-02 11:44:19,235 - INFO - __main__ - Loding paraphrased observations from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-16k-0613_paraphrased_observations__two-or-more-words__part4.jsonl
# 2025-06-02 11:44:20,448 - INFO - __main__ - Loding paraphrased observations from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_paraphrased_observations__two-or-more-words_cluster-balanced.jsonl
# 2025-06-02 11:44:20,584 - INFO - __main__ - Loding paraphrased observations from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words_cluster-balanced_1of5.jsonl
# 2025-06-02 11:44:20,716 - INFO - __main__ - Loding paraphrased observations from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words_cluster-balanced_2of5.jsonl
# 2025-06-02 11:44:20,851 - INFO - __main__ - Loding paraphrased observations from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words_cluster-balanced_3of5.jsonl
# 2025-06-02 11:44:20,988 - INFO - __main__ - Loding paraphrased observations from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words_cluster-balanced_4of5.jsonl
# 2025-06-02 11:44:21,202 - INFO - __main__ - Loding hard triplets from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_hard_triplets_from_facts(cluster-balanced,hardest)-part1.jsonl
# 2025-06-02 11:44:21,513 - INFO - __main__ - Loding hard triplets from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_hard_triplets_from_facts(cluster-balanced,hardest)-part2.jsonl
# 2025-06-02 11:44:21,841 - INFO - __main__ - Loding hard triplets from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_hard_triplets_from_facts(cluster-balanced,hardest)-part3.jsonl
# 2025-06-02 11:44:22,166 - INFO - __main__ - Loading revised groundings from /mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/chest_imagenome/integrated_llm_revised_phrase_groundings.pkl
# 2025-06-02 11:44:30,885 - INFO - __main__ - Loaded 243310 entries from /mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/chest_imagenome/integrated_llm_revised_phrase_groundings.pkl
# 2025-06-02 11:44:31,179 - INFO - medvqa.scripts.chest_imagenome.generate_phrase_groundings_from_scene_graphs - Collected 6217 phrases from padchest-gr
# 2025-06-02 11:44:31,181 - INFO - medvqa.scripts.chest_imagenome.generate_phrase_groundings_from_scene_graphs - Collected 1160 phrases from ms-cxr
# 2025-06-02 11:44:31,182 - INFO - __main__ - Collected 7377 groundings from PadChest-GR and MS-CXR
# 2025-06-02 11:44:38,428 - INFO - __main__ - Number of sentences: 3578518
# 2025-06-02 11:45:02,943 - INFO - medvqa.models.huggingface_utils - Loading cached text embeddings from /mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=144,90025341481394601).pkl
# 2025-06-02 11:45:04,609 - INFO - medvqa.models.huggingface_utils - len(self.cache["hashes"]) = 4256155
# 2025-06-02 11:45:04,609 - INFO - medvqa.models.huggingface_utils - self.cache["embeddings"].shape = (4256155, 128)
# 2025-06-02 11:45:06,146 - INFO - medvqa.models.huggingface_utils - Loading cached kmeans labels from /mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/kmeans_labels(180664559,3536210917935012421).pkl
# 2025-06-02 11:45:09,497 - INFO - __main__ - Saving sentence cluster ids to /mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/sentence_cluster_ids(2506, 2260387000448473611).pkl

# %%
# !python ../../train_fact_embedding.py \
--pretrained_checkpoint_folder_paths \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240629_084405_MIMIC-CXR(triplets+classif+entcont+nli+radgraph+autoencoder)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)" \
--epochs 200 \
--batches_per_epoch 800 \
--batch_size 25 \
--val_batch_size 150 \
--num_workers 3 \
--iters_to_accumulate 20 \
--optimizer_name "adamw" \
--scheduler "exp-warmup+decay+cyclicdecay" \
--lr 1e-6 \
--warmup_decay_and_cyclic_decay_args "1e-6,3,7e-5,6,1e-6,7e-5,6,1e-6" \
--triplets_filepath \
"/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/mimiccxr/triplets(4550211,318620,2395255,637929,208058,3002000,1000,1000,274,1091231605151220188).pkl" \
--triplet_rule_weights \
"{'anatomical_locations': [1., 2., 1.], 'observations': [1., 2., 1.5, 1., 1., 1., 1., 2., 2.]}" \
--integrated_facts_metadata_jsonl_filepath \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_fact_metadata(595880,60579117).improved_comparison(6741113).jsonl" \
--paraphrases_jsonl_filepaths \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_anatomical_locations__part1.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_anatomical_locations__part2.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-16k-0613_paraphrased_anatomical_locations__part3.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__single-words.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words__part1.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-16k-0613_paraphrased_observations__two-or-more-words__part2.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words__part3.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-16k-0613_paraphrased_observations__two-or-more-words__part4.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_paraphrased_observations__two-or-more-words_cluster-balanced.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words_cluster-balanced_1of5.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words_cluster-balanced_2of5.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words_cluster-balanced_3of5.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words_cluster-balanced_4of5.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_hard_triplets_from_facts(cluster-balanced,hardest)-part1.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_hard_triplets_from_facts(cluster-balanced,hardest)-part2.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_hard_triplets_from_facts(cluster-balanced,hardest)-part3.jsonl" \
--integrated_chest_imagenome_observations_filepath \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_chest_imagenome_observations(9).pkl" \
--integrated_chest_imagenome_anatomical_locations_filepath \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_chest_imagenome_anatomical_locations(5).pkl" \
--integrated_nli_jsonl_filepath \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(265719,34150895).jsonl" \
--integrated_sentence_facts_jsonl_filepath \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_sentence_facts(58655550,50990861).jsonl" \
--sentences_and_cluster_ids_filepath \
"/mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/sentence_cluster_ids(2506, 2260387000448473611).pkl" \
--n_chest_imagenome_observations 74 \
--n_chest_imagenome_anatomical_locations 38 \
--triplets_weight 5.0 \
--metadata_classification_weight 1.0 \
--chest_imagenome_observations_classification_weight 1.0 \
--chest_imagenome_anatomical_locations_classification_weight 1.0 \
--nli_weight 2.0 \
--entcon_weight 1.0 \
--sentence_autoencoder_weight 2.0 \
--triplet_loss_weight 2.0 \
--sentence_autoencoder_loss_weight 1.5 \
--dataset_name "MIMIC-CXR(triplets+classif+entcont+nli+autoencoder)" \
--huggingface_model_name "microsoft/BiomedVLP-CXR-BERT-specialized" \
--embedding_size 128 \
--use_aux_task_hidden_layer \
--aux_task_hidden_layer_size 512 \
--nli_hidden_layer_size 128 \
--train_metrics_weight 0.25 \
--use_amp \
--save
# Out:
# 2025-06-02 12:21:56,892 - INFO - root - Logging configured (Color: True).
# 2025-06-02 12:21:56,896 - INFO - medvqa.utils.common -
# script's arguments:
#    epochs: 200
#    batches_per_epoch: 800
#    batch_size: 25
#    train_metrics_weight: 0.25
#    val_batch_size: 150
#    radgraph_spert_batch_size: None
#    checkpoint_folder: None
#    huggingface_model_name: microsoft/BiomedVLP-CXR-BERT-specialized
#    embedding_size: 128
#    n_chest_imagenome_observations: 74
#    n_chest_imagenome_anatomical_locations: 38
#    use_aux_task_hidden_layer: True
#    aux_task_hidden_layer_size: 512
#    nli_hidden_layer_size: 128
#    pretrained_checkpoint_folder_path: None
#    pretrained_checkpoint_folder_paths: ['/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240629_084405_MIMIC-CXR(triplets+classif+entcont+nli+radgraph+autoencoder)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)']
#    freeze_huggingface_model: False
#    spert_size_embedding: 25
#    spert_max_pairs: 1000
#    spert_prop_drop: 0.1
#    fact_decoder_embed_size: 256
#    fact_decoder_hidden_size: 256
#    fact_decoder_nhead: 1
#    fact_decoder_dim_feedforward: 256
#    fact_decoder_num_layers: 1
#    optimizer_name: adamw
#    lr: 1e-06
#    scheduler: exp-warmup+decay+cyclicdecay
#    lr_decay: 0.76
#    lr_decay_patience: 2
#    warmup_and_decay_args: None
#    warmup_and_cosine_args: None
#    warmup_decay_and_cyclic_decay_args: 1e-6,3,7e-5,6,1e-6,7e-5,6,1e-6
#    iters_to_accumulate: 20
#    override_lr: False
#    max_grad_norm: None
#    triplet_loss_weight: 2.0
#    category_classif_loss_weight: 1.0
#    health_status_classif_loss_weight: 1.0
#    comparison_status_classif_loss_weight: 1.0
#    chest_imagenome_obs_classif_loss_weight: 1.0
#    chest_imagenome_anatloc_classif_loss_weight: 1.0
#    nli_loss_weight: 1.0
#    entcon_loss_weight: 1.0
#    sentence_autoencoder_loss_weight: 1.5
#    triplets_filepath: /mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/mimiccxr/triplets(4550211,318620,2395255,637929,208058,3002000,1000,1000,274,1091231605151220188).pkl
#    triplet_rule_weights: {'anatomical_locations': [1.0, 2.0, 1.0], 'observations': [1.0, 2.0, 1.5, 1.0, 1.0, 1.0, 1.0, 2.0, 2.0]}
#    integrated_facts_metadata_jsonl_filepath: /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_fact_metadata(595880,60579117).improved_comparison(6741113).jsonl
#    paraphrases_jsonl_filepaths: ['/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_anatomical_locations__part1.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_anatomical_locations__part2.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-16k-0613_paraphrased_anatomical_locations__part3.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__single-words.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words__part1.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-16k-0613_paraphrased_observations__two-or-more-words__part2.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words__part3.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-16k-0613_paraphrased_observations__two-or-more-words__part4.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_paraphrased_observations__two-or-more-words_cluster-balanced.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words_cluster-balanced_1of5.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words_cluster-balanced_2of5.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words_cluster-balanced_3of5.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words_cluster-balanced_4of5.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_hard_triplets_from_facts(cluster-balanced,hardest)-part1.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_hard_triplets_from_facts(cluster-balanced,hardest)-part2.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_hard_triplets_from_facts(cluster-balanced,hardest)-part3.jsonl']
#    integrated_chest_imagenome_observations_filepath: /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_chest_imagenome_observations(9).pkl
#    integrated_chest_imagenome_anatomical_locations_filepath: /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_chest_imagenome_anatomical_locations(5).pkl
#    integrated_nli_jsonl_filepath: /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(265719,34150895).jsonl
#    integrated_sentence_facts_jsonl_filepath: /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_sentence_facts(58655550,50990861).jsonl
#    sentences_and_cluster_ids_filepath: /mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/sentence_cluster_ids(2506, 2260387000448473611).pkl
#    dataset_name: MIMIC-CXR(triplets+classif+entcont+nli+autoencoder)
#    triplets_weight: 5.0
#    metadata_classification_weight: 1.0
#    chest_imagenome_observations_classification_weight: 1.0
#    chest_imagenome_anatomical_locations_classification_weight: 1.0
#    nli_weight: 2.0
#    entcon_weight: 1.0
#    radgraph_ner_re_weight: 0
#    sentence_autoencoder_weight: 2.0
#    use_nli_val_in_train: False
#    use_anli: False
#    use_multinli: False
#    use_snli: False
#    num_workers: 3
#    device: GPU
#    use_amp: True
#    save: True
# 2025-06-02 12:21:56,896 - INFO - __main__ - ========== Training model from scratch ==========
# 2025-06-02 12:21:56,896 - INFO - __main__ - train_metrics_weight = 0.25
# 2025-06-02 12:21:56,896 - INFO - __main__ - ========== Defining collate batch functions ==========
# Loading triplets from /mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/mimiccxr/triplets(4550211,318620,2395255,637929,208058,3002000,1000,1000,274,1091231605151220188).pkl...
# ----
# Building train triplet ranking dataset and dataloader...
# anatomical_locations -> rule 0: "Rank paraphrases very highly"
# 	Number of triplets: 3440250
# 	Weight: 1.0
# anatomical_locations -> rule 1: "Rank paraphrases very highly - Hard negative"
# 	Number of triplets: 3419308
# 	Weight: 2.0
# anatomical_locations -> rule 2: "Rule 3 (AnatLoc): Rank triplets by Embedding, BLEU-1, & Leveinshtein consensus"
# 	Number of triplets: 3184200
# 	Weight: 1.0
# observations -> rule 0: "Rank paraphrases very highly"
# 	Number of triplets: 4057104
# 	Weight: 1.0
# observations -> rule 1: "Rank paraphrases very highly - Hard negative"
# 	Number of triplets: 4048671
# 	Weight: 2.0
# observations -> rule 2: "Rank triplets by Embedding, BLEU-1, Leveinshtein consensus, A&P same health status"
# 	Number of triplets: 4427826
# 	Weight: 1.5
# observations -> rule 3: "Hard health-status-vs-others triplets"
# 	Number of triplets: 2688197
# 	Weight: 1.0
# observations -> rule 4: "Short observation, detailed observation, and fact must be close to each other"
# 	Number of triplets: 6247265
# 	Weight: 1.0
# observations -> rule 5: "Rank triplets according to Chest ImaGenome labels"
# 	Number of triplets: 3222723
# 	Weight: 1.0
# observations -> rule 6: "RadGraph-based triplets"
# 	Number of triplets: 3173422
# 	Weight: 1.0
# observations -> rule 7: "Hard negative triplets generated by ChatGPT"
# 	Number of triplets: 3044784
# 	Weight: 2.0
# observations -> rule 8: "Abnormal visual findings triplets"
# 	Number of triplets: 3108268
# 	Weight: 2.0
# ----
# Building train metadata classification dataset and dataloader...
# Loading paraphrases from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_anatomical_locations__part1.jsonl...
# Input:
# B
# Paraphrases:
# bilateral
# both sides
# both
# on both sides
# symmetrical
# equally on both sides
# present on both sides
# seen on both sides
# occurring on both sides
# appearing on both sides
# found on both sides
# noted on both sides
# noted bilaterally
# seen bilaterally
# observed bilaterally
# detected bilaterally
# Loading paraphrases from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_anatomical_locations__part2.jsonl...
# Input:
# left of the left hilus
# Paraphrases:
# left of the left hilum
# left to the left hilum
# left side of the left hilum
# leftward to the left hilum
# left of the hilum on the left side
# left of the pulmonary hilum on the left
# leftward to the pulmonary hilum on the left
# left to the hilum on the left side
# left side of the pulmonary hilum on the left
# leftward to the hilum on the left side
# Loading paraphrases from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-16k-0613_paraphrased_anatomical_locations__part3.jsonl...
# Input:
# peripheral pulmonary vasculature
# Paraphrases:
# peripheral lung vessels
# peripheral pulmonary blood vessels
# lung periphery vasculature
# vasculature of the peripheral lung
# blood vessels in the outer regions of the lung
# pulmonary vessels in the lung periphery
# vascular network in the peripheral lung
# peripheral pulmonary circulation
# blood vessels supplying the outer areas of the lung
# vasculature in the peripheral regions of the lung
# pulmonary vessels in the lung periphery
# vascular system in the outer regions of the lung
# Loading paraphrases from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__single-words.jsonl...
# Input:
# a
# Paraphrases:
# one
# single
# sole
# only
# individual
# lone
# solitary
# unique
# distinct
# singular
# Loading paraphrases from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words__part1.jsonl...
# Input:
# 5 cm
# Paraphrases:
# 5 centimeters
# 5 cm
# 5 centimetres
# 5 cm in size
# a length of 5 cm
# a measurement of 5 cm
# measuring 5 cm
# 5 centimeters in length
# a size of 5 cm
# 5 cm in dimension
# Loading paraphrases from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-16k-0613_paraphrased_observations__two-or-more-words__part2.jsonl...
# Input:
# limited base
# Paraphrases:
# restricted base
# constrained base
# narrowed base
# limited foundation
# restricted support
# constricted base
# reduced base
# diminished base
# restricted bottom
# constrained footing
# Loading paraphrases from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words__part3.jsonl...
# Input:
# not visible
# Paraphrases:
# not visualized
# not seen
# not apparent
# not detectable
# absent
# not present
# unable to visualize
# not observable
# not evident
# not identifiable
# Loading paraphrases from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-16k-0613_paraphrased_observations__two-or-more-words__part4.jsonl...
# Input:
# bowel loops
# Paraphrases:
# intestinal loops
# intestinal segments
# bowel segments
# intestinal coils
# intestinal twists
# intestinal convolutions
# intestinal turns
# intestinal curvatures
# intestinal windings
# intestinal meanders
# Loading paraphrases from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_paraphrased_observations__two-or-more-words_cluster-balanced.jsonl...
# Input:
# 5th rib
# Paraphrases:
# The fifth rib
# Rib number five
# Rib 5
# 5th rib bone
# Bone of the fifth rib
# Fifth rib structure
# Structure of the 5th rib
# 5th costal bone
# Fifth costal bone
# Costal bone number five
# 5th costae
# Costae number five
# Fifth costae structure
# Structure of the 5th costae
# Loading paraphrases from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words_cluster-balanced_1of5.jsonl...
# Input:
# CT 2
# Paraphrases:
# Computed tomography scan
# CT imaging
# CT examination
# CT scan
# CT imaging study
# Computed tomography imaging
# Computed tomography exam
# CT scan procedure
# CT scan test
# CT diagnostic imaging
# CT imaging technique
# CT scan investigation
# CT radiographic study
# Computed tomography imaging procedure
# CT scan evaluation
# Loading paraphrases from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words_cluster-balanced_2of5.jsonl...
# Input:
# line location
# Paraphrases:
# The line is located
# The position of the line is
# The line can be seen
# The line is situated
# The line is found
# The line appears
# The line is detected
# The line is identified
# The line is visible
# The line is present
# The line is observed
# The line is noted
# The line is seen
# The line is evident
# Loading paraphrases from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words_cluster-balanced_3of5.jsonl...
# Input:
# not apparent
# Paraphrases:
# No evidence of
# Not visible
# Not observable
# Not detected
# Not seen
# Not present
# Absence of
# Lack of
# Negative for
# No signs of
# No findings of
# No indications of
# No evidence suggesting
# No abnormalities detected
# Loading paraphrases from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words_cluster-balanced_4of5.jsonl...
# Input:
# CT on
# Paraphrases:
# Computed tomography performed
# CT scan done
# Imaging study using computed tomography
# Radiological examination using CT
# CT imaging conducted
# CT scan taken
# CT imaging performed
# Computed tomography examination
# CT scan carried out
# CT imaging study performed
# CT scan conducted
# Computed tomography study done
# CT imaging examination
# CT scan performed
# Loading paraphrases from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_hard_triplets_from_facts(cluster-balanced,hardest)-part1.jsonl...
# Input:
# no evidence of all-trans retinoic acid syndrome
# Paraphrases:
# no indication of all-trans retinoic acid syndrome
# absence of all-trans retinoic acid syndrome
# no signs of all-trans retinoic acid syndrome
# no presence of all-trans retinoic acid syndrome
# all-trans retinoic acid syndrome not detected
# all-trans retinoic acid syndrome is not observed
# Loading paraphrases from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_hard_triplets_from_facts(cluster-balanced,hardest)-part2.jsonl...
# Input:
# no evidence of significant constriction
# Paraphrases:
# no indication of notable narrowing
# absence of significant constriction
# no signs of substantial narrowing
# no evidence of significant narrowing
# lack of significant constriction
# no presence of notable constriction
# Loading paraphrases from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_hard_triplets_from_facts(cluster-balanced,hardest)-part3.jsonl...
# Input:
# no evidence of wheezing
# Paraphrases:
# no signs of wheezing
# absence of wheezing
# no wheezing detected
# no wheezing observed
# no wheezing present
# no wheezing found
# Number of sentences with paraphrases: 190085
# Number of paraphrases: 2093173
# Loading integrated facts metadata...
# Number of facts: 2829627
# Number of sources: 2
# Number of improved comparisons: 538573/595880
# Category: anatomical finding -> 2047605
# Category: tubes and lines -> 288612
# Category: technical assessment -> 178206
# Category: disease -> 163951
# Category: device -> 145682
# Category: other -> 5571
# Health status: abnormal -> 1718135
# Health status: unknown -> 681307
# Health status: normal -> 277984
# Health status: ambiguous -> 150972
# Health status: other -> 1229
# Comparison status: no comparison -> 1672099
# Comparison status: stable/unchanged -> 296144
# Comparison status: worsened -> 145020
# Comparison status: improved -> 115910
# Comparison status: resolved -> 111802
# Comparison status: new finding -> 102734
# Comparison status: unclear comparison -> 96372
# Comparison status: position changed -> 70304
# Comparison status: increase -> 62671
# Comparison status: decrease -> 40961
# Comparison status: progressed -> 35661
# Comparison status: smaller -> 29576
# Comparison status: larger -> 28278
# Comparison status: reappeared -> 21333
# Comparison status: other -> 762
# Example fact: narrowing
# Category: anatomical finding
# Health status: abnormal
# Comparison status: no comparison
# Example fact: persistent plate-like atelectasis
# Category: anatomical finding
# Health status: abnormal
# Comparison status: stable/unchanged
# Example fact: Complete opacification of lung tissue
# Category: anatomical finding
# Health status: abnormal
# Comparison status: resolved
# Example fact: advancement extended by roughly 3 cm for standard positioning
# Category: technical assessment
# Health status: unknown
# Comparison status: no comparison
# Example fact: collapsed region
# Category: anatomical finding
# Health status: abnormal
# Comparison status: no comparison
# Example fact: tube for enteral nutrition with its tip in the stomach
# Category: tubes and lines
# Health status: normal
# Comparison status: no comparison
# Example fact: minimal streaky opacity projecting over the lower thoracic spine
# Category: anatomical finding
# Health status: abnormal
# Comparison status: no comparison
# Example fact: The left main bronchial stent is still in place
# Category: device
# Health status: normal
# Comparison status: resolved
# Example fact: isolated
# Category: anatomical finding
# Health status: abnormal
# Comparison status: no comparison
# Example fact: There is a slight change observed compared to the study of 113
# Category: technical assessment
# Health status: unknown
# Comparison status: resolved
# Comparison status: no comparison
# Number of samples: 1672099
# 	Source: gpt-3.5-turbo-0613
# 		Number of samples: 373949
# 	Source: t5-small-finetuned
# 		Number of samples: 1298150
# 	Weight: 8835.37396061336
# Comparison status: worsened
# Number of samples: 145020
# 	Source: gpt-3.5-turbo-0613
# 		Number of samples: 8360
# 	Source: t5-small-finetuned
# 		Number of samples: 136660
# 	Weight: 5040.577289150058
# Comparison status: resolved
# Number of samples: 111802
# 	Source: gpt-3.5-turbo-0613
# 		Number of samples: 31751
# 	Source: t5-small-finetuned
# 		Number of samples: 80051
# 	Weight: 4716.770555027595
# Comparison status: stable/unchanged
# Number of samples: 296144
# 	Source: gpt-3.5-turbo-0613
# 		Number of samples: 15182
# 	Source: t5-small-finetuned
# 		Number of samples: 280962
# 	Weight: 6004.6900271393515
# Comparison status: progressed
# Number of samples: 35661
# 	Source: gpt-3.5-turbo-0613
# 		Number of samples: 1287
# 	Source: t5-small-finetuned
# 		Number of samples: 34374
# 	Weight: 3458.062441162537
# Comparison status: larger
# Number of samples: 28278
# 	Source: gpt-3.5-turbo-0613
# 		Number of samples: 3635
# 	Source: t5-small-finetuned
# 		Number of samples: 24643
# 	Weight: 3233.5143931132666
# Comparison status: improved
# Number of samples: 115910
# 	Source: gpt-3.5-turbo-0613
# 		Number of samples: 13043
# 	Source: t5-small-finetuned
# 		Number of samples: 102867
# 	Weight: 4760.832266455671
# Comparison status: reappeared
# Number of samples: 21333
# 	Source: gpt-3.5-turbo-0613
# 		Number of samples: 321
# 	Source: t5-small-finetuned
# 		Number of samples: 21012
# 	Weight: 2974.0555116759224
# Comparison status: smaller
# Number of samples: 29576
# 	Source: gpt-3.5-turbo-0613
# 		Number of samples: 1227
# 	Source: t5-small-finetuned
# 		Number of samples: 28349
# 	Weight: 3276.1746389034083
# Comparison status: position changed
# Number of samples: 70304
# 	Source: gpt-3.5-turbo-0613
# 		Number of samples: 644
# 	Source: t5-small-finetuned
# 		Number of samples: 69660
# 	Weight: 4174.306898106601
# Comparison status: new finding
# Number of samples: 102734
# 	Source: gpt-3.5-turbo-0613
# 		Number of samples: 1777
# 	Source: t5-small-finetuned
# 		Number of samples: 100957
# 	Weight: 4614.552302549111
# Comparison status: unclear comparison
# Number of samples: 96372
# 	Source: gpt-3.5-turbo-0613
# 		Number of samples: 1316
# 	Source: t5-small-finetuned
# 		Number of samples: 95056
# 	Weight: 4538.2868333666065
# Comparison status: increase
# Number of samples: 62671
# 	Source: gpt-3.5-turbo-0613
# 		Number of samples: 263
# 	Source: t5-small-finetuned
# 		Number of samples: 62408
# 	Weight: 4046.6713412668914
# Comparison status: decrease
# Number of samples: 40961
# 	Source: gpt-3.5-turbo-0613
# 		Number of samples: 420
# 	Source: t5-small-finetuned
# 		Number of samples: 40541
# 	Weight: 3597.0233304520843
# Comparison status: other
# Number of samples: 762
# 	Source: t5-small-finetuned
# 		Number of samples: 762
# 	Weight: 877.4699568538347
# ----
# Building train chest imagenome observations classification dataset and dataloader...
# Loading integrated chest imagenome observations from /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_chest_imagenome_observations(9).pkl...
# len(phrases): 3462801
# len(label_names): 74
# labels.shape: (3462801, 74)
# Label: lung opacity
# 	Number of idxs: 588071
# 	Weight: 7039.95
# 	Sub-datasets: [(t5-small-finetuned, 291982.00), (chest-imagenome, 286405.00), (gpt-3.5-turbo-0613, 9492.00), (gpt-4-0613, 192.00)]
# Label: pleural effusion
# 	Number of idxs: 270526
# 	Weight: 5876.25
# 	Sub-datasets: [(t5-small-finetuned, 183558.00), (chest-imagenome, 81683.00), (gpt-3.5-turbo-0613, 5191.00), (gpt-4-0613, 94.00)]
# Label: atelectasis
# 	Number of idxs: 178891
# 	Weight: 5312.40
# 	Sub-datasets: [(t5-small-finetuned, 88199.00), (chest-imagenome, 87994.00), (gpt-3.5-turbo-0613, 2653.00), (gpt-4-0613, 45.00)]
# Label: lung lesion
# 	Number of idxs: 168279
# 	Weight: 5232.22
# 	Sub-datasets: [(t5-small-finetuned, 147433.00), (chest-imagenome, 17973.00), (gpt-3.5-turbo-0613, 2798.00), (gpt-4-0613, 75.00)]
# Label: pneumonia
# 	Number of idxs: 133413
# 	Weight: 4935.18
# 	Sub-datasets: [(t5-small-finetuned, 89098.00), (chest-imagenome, 42282.00), (gpt-3.5-turbo-0613, 1949.00), (gpt-4-0613, 84.00)]
# Label: airspace opacity
# 	Number of idxs: 126491
# 	Weight: 4868.64
# 	Sub-datasets: [(t5-small-finetuned, 115908.00), (chest-imagenome, 9387.00), (gpt-3.5-turbo-0613, 1174.00), (gpt-4-0613, 22.00)]
# Label: consolidation
# 	Number of idxs: 120940
# 	Weight: 4813.05
# 	Sub-datasets: [(t5-small-finetuned, 97762.00), (chest-imagenome, 20613.00), (gpt-3.5-turbo-0613, 2540.00), (gpt-4-0613, 25.00)]
# Label: pulmonary edema/hazy opacity
# 	Number of idxs: 109715
# 	Weight: 4693.87
# 	Sub-datasets: [(t5-small-finetuned, 67972.00), (chest-imagenome, 40115.00), (gpt-3.5-turbo-0613, 1567.00), (gpt-4-0613, 61.00)]
# Label: mass/nodule (not otherwise specified)
# 	Number of idxs: 108657
# 	Weight: 4682.12
# 	Sub-datasets: [(t5-small-finetuned, 96494.00), (chest-imagenome, 10296.00), (gpt-3.5-turbo-0613, 1812.00), (gpt-4-0613, 55.00)]
# Label: enteric tube
# 	Number of idxs: 108021
# 	Weight: 4675.02
# 	Sub-datasets: [(t5-small-finetuned, 82792.00), (chest-imagenome, 23240.00), (gpt-3.5-turbo-0613, 1875.00), (gpt-4-0613, 114.00)]
# Label: increased reticular markings/ild pattern
# 	Number of idxs: 100126
# 	Weight: 4583.77
# 	Sub-datasets: [(t5-small-finetuned, 96814.00), (chest-imagenome, 1728.00), (gpt-3.5-turbo-0613, 1560.00), (gpt-4-0613, 24.00)]
# Label: ij line
# 	Number of idxs: 95012
# 	Weight: 4521.45
# 	Sub-datasets: [(t5-small-finetuned, 84277.00), (chest-imagenome, 8992.00), (gpt-3.5-turbo-0613, 1695.00), (gpt-4-0613, 48.00)]
# Label: vascular congestion
# 	Number of idxs: 94906
# 	Weight: 4520.13
# 	Sub-datasets: [(t5-small-finetuned, 70730.00), (chest-imagenome, 22801.00), (gpt-3.5-turbo-0613, 1348.00), (gpt-4-0613, 27.00)]
# Label: enlarged cardiac silhouette
# 	Number of idxs: 85028
# 	Weight: 4391.33
# 	Sub-datasets: [(t5-small-finetuned, 51304.00), (chest-imagenome, 32665.00), (gpt-3.5-turbo-0613, 1033.00), (gpt-4-0613, 26.00)]
# Label: pleural/parenchymal scarring
# 	Number of idxs: 75175
# 	Weight: 4249.93
# 	Sub-datasets: [(t5-small-finetuned, 58143.00), (chest-imagenome, 15563.00), (gpt-3.5-turbo-0613, 1431.00), (gpt-4-0613, 38.00)]
# Label: infiltration
# 	Number of idxs: 73266
# 	Weight: 4220.78
# 	Sub-datasets: [(t5-small-finetuned, 68627.00), (chest-imagenome, 3460.00), (gpt-3.5-turbo-0613, 1149.00), (gpt-4-0613, 30.00)]
# Label: endotracheal tube
# 	Number of idxs: 73212
# 	Weight: 4219.95
# 	Sub-datasets: [(t5-small-finetuned, 52977.00), (chest-imagenome, 18994.00), (gpt-3.5-turbo-0613, 1159.00), (gpt-4-0613, 82.00)]
# Label: picc
# 	Number of idxs: 72349
# 	Weight: 4206.56
# 	Sub-datasets: [(t5-small-finetuned, 59562.00), (chest-imagenome, 11375.00), (gpt-3.5-turbo-0613, 1357.00), (gpt-4-0613, 55.00)]
# Label: cardiac pacer and wires
# 	Number of idxs: 71225
# 	Weight: 4188.93
# 	Sub-datasets: [(t5-small-finetuned, 59149.00), (chest-imagenome, 10754.00), (gpt-3.5-turbo-0613, 1265.00), (gpt-4-0613, 57.00)]
# Label: rib fracture
# 	Number of idxs: 68569
# 	Weight: 4146.33
# 	Sub-datasets: [(t5-small-finetuned, 60071.00), (chest-imagenome, 6984.00), (gpt-3.5-turbo-0613, 1445.00), (gpt-4-0613, 69.00)]
# Label: pneumothorax
# 	Number of idxs: 68103
# 	Weight: 4138.72
# 	Sub-datasets: [(t5-small-finetuned, 53208.00), (chest-imagenome, 13285.00), (gpt-3.5-turbo-0613, 1559.00), (gpt-4-0613, 51.00)]
# Label: mediastinal widening
# 	Number of idxs: 63696
# 	Weight: 4064.53
# 	Sub-datasets: [(t5-small-finetuned, 57715.00), (chest-imagenome, 4859.00), (gpt-3.5-turbo-0613, 1108.00), (gpt-4-0613, 14.00)]
# Label: artifact
# 	Number of idxs: 62070
# 	Weight: 4036.09
# 	Sub-datasets: [(t5-small-finetuned, 60987.00), (gpt-3.5-turbo-0613, 567.00), (chest-imagenome, 486.00), (gpt-4-0613, 30.00)]
# Label: lobar/segmental collapse
# 	Number of idxs: 60370
# 	Weight: 4005.70
# 	Sub-datasets: [(t5-small-finetuned, 48794.00), (chest-imagenome, 10554.00), (gpt-3.5-turbo-0613, 1005.00), (gpt-4-0613, 17.00)]
# Label: chest tube
# 	Number of idxs: 58194
# 	Weight: 3965.76
# 	Sub-datasets: [(t5-small-finetuned, 47496.00), (chest-imagenome, 9523.00), (gpt-3.5-turbo-0613, 1133.00), (gpt-4-0613, 42.00)]
# Label: sub-diaphragmatic air
# 	Number of idxs: 51974
# 	Weight: 3844.44
# 	Sub-datasets: [(t5-small-finetuned, 49591.00), (chest-imagenome, 1569.00), (gpt-3.5-turbo-0613, 804.00), (gpt-4-0613, 10.00)]
# Label: subclavian line
# 	Number of idxs: 49016
# 	Weight: 3782.54
# 	Sub-datasets: [(t5-small-finetuned, 45312.00), (chest-imagenome, 2907.00), (gpt-3.5-turbo-0613, 797.00)]
# Label: enlarged hilum
# 	Number of idxs: 47903
# 	Weight: 3758.45
# 	Sub-datasets: [(t5-small-finetuned, 37127.00), (chest-imagenome, 9915.00), (gpt-3.5-turbo-0613, 833.00), (gpt-4-0613, 28.00)]
# Label: hyperaeration
# 	Number of idxs: 45517
# 	Weight: 3705.25
# 	Sub-datasets: [(t5-small-finetuned, 38156.00), (chest-imagenome, 6728.00), (gpt-3.5-turbo-0613, 633.00)]
# Label: linear/patchy atelectasis
# 	Number of idxs: 44585
# 	Weight: 3683.85
# 	Sub-datasets: [(t5-small-finetuned, 32887.00), (chest-imagenome, 11073.00), (gpt-3.5-turbo-0613, 625.00)]
# Label: interstitial lung disease
# 	Number of idxs: 42142
# 	Weight: 3625.98
# 	Sub-datasets: [(t5-small-finetuned, 38697.00), (chest-imagenome, 2510.00), (gpt-3.5-turbo-0613, 902.00), (gpt-4-0613, 33.00)]
# Label: subcutaneous air
# 	Number of idxs: 39092
# 	Weight: 3549.78
# 	Sub-datasets: [(t5-small-finetuned, 34777.00), (chest-imagenome, 3502.00), (gpt-3.5-turbo-0613, 793.00), (gpt-4-0613, 20.00)]
# Label: vascular calcification
# 	Number of idxs: 38130
# 	Weight: 3524.74
# 	Sub-datasets: [(t5-small-finetuned, 32240.00), (chest-imagenome, 5088.00), (gpt-3.5-turbo-0613, 770.00), (gpt-4-0613, 32.00)]
# Label: spinal fracture
# 	Number of idxs: 37418
# 	Weight: 3505.88
# 	Sub-datasets: [(t5-small-finetuned, 33415.00), (chest-imagenome, 3542.00), (gpt-3.5-turbo-0613, 444.00), (gpt-4-0613, 17.00)]
# Label: low lung volumes
# 	Number of idxs: 36300
# 	Weight: 3475.67
# 	Sub-datasets: [(t5-small-finetuned, 18106.00), (chest-imagenome, 17780.00), (gpt-3.5-turbo-0613, 403.00), (gpt-4-0613, 11.00)]
# Label: chest port
# 	Number of idxs: 36235
# 	Weight: 3473.89
# 	Sub-datasets: [(t5-small-finetuned, 29925.00), (chest-imagenome, 5519.00), (gpt-3.5-turbo-0613, 756.00), (gpt-4-0613, 35.00)]
# Label: aspiration
# 	Number of idxs: 33964
# 	Weight: 3410.03
# 	Sub-datasets: [(t5-small-finetuned, 22482.00), (chest-imagenome, 10910.00), (gpt-3.5-turbo-0613, 552.00), (gpt-4-0613, 20.00)]
# Label: costophrenic angle blunting
# 	Number of idxs: 32080
# 	Weight: 3354.38
# 	Sub-datasets: [(t5-small-finetuned, 25891.00), (chest-imagenome, 5642.00), (gpt-3.5-turbo-0613, 531.00), (gpt-4-0613, 16.00)]
# Label: mediastinal displacement
# 	Number of idxs: 31796
# 	Weight: 3345.76
# 	Sub-datasets: [(t5-small-finetuned, 27301.00), (chest-imagenome, 3864.00), (gpt-3.5-turbo-0613, 603.00), (gpt-4-0613, 28.00)]
# Label: bone lesion
# 	Number of idxs: 29957
# 	Weight: 3288.41
# 	Sub-datasets: [(t5-small-finetuned, 27222.00), (chest-imagenome, 2096.00), (gpt-3.5-turbo-0613, 639.00)]
# Label: spinal degenerative changes
# 	Number of idxs: 28662
# 	Weight: 3246.30
# 	Sub-datasets: [(t5-small-finetuned, 24834.00), (chest-imagenome, 3370.00), (gpt-3.5-turbo-0613, 443.00), (gpt-4-0613, 15.00)]
# Label: swan-ganz catheter
# 	Number of idxs: 27164
# 	Weight: 3195.63
# 	Sub-datasets: [(t5-small-finetuned, 24748.00), (chest-imagenome, 2007.00), (gpt-3.5-turbo-0613, 386.00), (gpt-4-0613, 23.00)]
# Label: vascular redistribution
# 	Number of idxs: 25856
# 	Weight: 3149.51
# 	Sub-datasets: [(t5-small-finetuned, 22691.00), (chest-imagenome, 2765.00), (gpt-3.5-turbo-0613, 400.00)]
# Label: fluid overload/heart failure
# 	Number of idxs: 24827
# 	Weight: 3111.89
# 	Sub-datasets: [(t5-small-finetuned, 18765.00), (chest-imagenome, 5621.00), (gpt-3.5-turbo-0613, 404.00), (gpt-4-0613, 37.00)]
# Label: bronchiectasis
# 	Number of idxs: 24721
# 	Weight: 3107.95
# 	Sub-datasets: [(t5-small-finetuned, 23174.00), (chest-imagenome, 1160.00), (gpt-3.5-turbo-0613, 377.00), (gpt-4-0613, 10.00)]
# Label: pigtail catheter
# 	Number of idxs: 23163
# 	Weight: 3048.33
# 	Sub-datasets: [(t5-small-finetuned, 19248.00), (chest-imagenome, 3446.00), (gpt-3.5-turbo-0613, 469.00)]
# Label: calcified nodule
# 	Number of idxs: 23009
# 	Weight: 3042.27
# 	Sub-datasets: [(t5-small-finetuned, 19828.00), (chest-imagenome, 2728.00), (gpt-3.5-turbo-0613, 435.00), (gpt-4-0613, 18.00)]
# Label: tortuous aorta
# 	Number of idxs: 22484
# 	Weight: 3021.34
# 	Sub-datasets: [(t5-small-finetuned, 16574.00), (chest-imagenome, 5622.00), (gpt-3.5-turbo-0613, 274.00), (gpt-4-0613, 14.00)]
# Label: superior mediastinal mass/enlargement
# 	Number of idxs: 20637
# 	Weight: 2944.46
# 	Sub-datasets: [(t5-small-finetuned, 16756.00), (chest-imagenome, 3559.00), (gpt-3.5-turbo-0613, 322.00)]
# Label: tracheostomy tube
# 	Number of idxs: 19723
# 	Weight: 2904.37
# 	Sub-datasets: [(t5-small-finetuned, 16638.00), (chest-imagenome, 2793.00), (gpt-3.5-turbo-0613, 270.00), (gpt-4-0613, 22.00)]
# Label: mediastinal drain
# 	Number of idxs: 19398
# 	Weight: 2889.76
# 	Sub-datasets: [(t5-small-finetuned, 18746.00), (chest-imagenome, 400.00), (gpt-3.5-turbo-0613, 252.00)]
# Label: aortic graft/repair
# 	Number of idxs: 19318
# 	Weight: 2886.13
# 	Sub-datasets: [(t5-small-finetuned, 18937.00), (gpt-3.5-turbo-0613, 266.00), (chest-imagenome, 115.00)]
# Label: elevated hemidiaphragm
# 	Number of idxs: 18894
# 	Weight: 2866.70
# 	Sub-datasets: [(t5-small-finetuned, 13155.00), (chest-imagenome, 5345.00), (gpt-3.5-turbo-0613, 372.00), (gpt-4-0613, 22.00)]
# Label: copd/emphysema
# 	Number of idxs: 17414
# 	Weight: 2796.05
# 	Sub-datasets: [(t5-small-finetuned, 10856.00), (chest-imagenome, 6264.00), (gpt-3.5-turbo-0613, 281.00), (gpt-4-0613, 13.00)]
# Label: clavicle fracture
# 	Number of idxs: 16925
# 	Weight: 2771.65
# 	Sub-datasets: [(t5-small-finetuned, 15689.00), (chest-imagenome, 905.00), (gpt-3.5-turbo-0613, 312.00), (gpt-4-0613, 19.00)]
# Label: hernia
# 	Number of idxs: 16471
# 	Weight: 2748.50
# 	Sub-datasets: [(t5-small-finetuned, 13157.00), (chest-imagenome, 2922.00), (gpt-3.5-turbo-0613, 365.00), (gpt-4-0613, 27.00)]
# Label: lung cancer
# 	Number of idxs: 16365
# 	Weight: 2743.02
# 	Sub-datasets: [(t5-small-finetuned, 14018.00), (chest-imagenome, 2148.00), (gpt-3.5-turbo-0613, 187.00), (gpt-4-0613, 12.00)]
# Label: shoulder osteoarthritis
# 	Number of idxs: 15168
# 	Weight: 2679.10
# 	Sub-datasets: [(t5-small-finetuned, 13182.00), (chest-imagenome, 1805.00), (gpt-3.5-turbo-0613, 167.00), (gpt-4-0613, 14.00)]
# Label: alveolar hemorrhage
# 	Number of idxs: 14365
# 	Weight: 2633.94
# 	Sub-datasets: [(t5-small-finetuned, 12104.00), (chest-imagenome, 2054.00), (gpt-3.5-turbo-0613, 207.00)]
# Label: granulomatous disease
# 	Number of idxs: 14354
# 	Weight: 2633.31
# 	Sub-datasets: [(t5-small-finetuned, 11640.00), (chest-imagenome, 2458.00), (gpt-3.5-turbo-0613, 237.00), (gpt-4-0613, 19.00)]
# Label: prosthetic valve
# 	Number of idxs: 12190
# 	Weight: 2500.73
# 	Sub-datasets: [(t5-small-finetuned, 9916.00), (chest-imagenome, 2079.00), (gpt-3.5-turbo-0613, 172.00), (gpt-4-0613, 23.00)]
# Label: intra-aortic balloon pump
# 	Number of idxs: 11723
# 	Weight: 2469.71
# 	Sub-datasets: [(t5-small-finetuned, 10936.00), (chest-imagenome, 630.00), (gpt-3.5-turbo-0613, 157.00)]
# Label: scoliosis
# 	Number of idxs: 11366
# 	Weight: 2445.34
# 	Sub-datasets: [(t5-small-finetuned, 8601.00), (chest-imagenome, 2467.00), (gpt-3.5-turbo-0613, 275.00), (gpt-4-0613, 23.00)]
# Label: cyst/bullae
# 	Number of idxs: 11118
# 	Weight: 2428.05
# 	Sub-datasets: [(t5-small-finetuned, 9962.00), (chest-imagenome, 972.00), (gpt-3.5-turbo-0613, 168.00), (gpt-4-0613, 16.00)]
# Label: multiple masses/nodules
# 	Number of idxs: 10852
# 	Weight: 2409.16
# 	Sub-datasets: [(t5-small-finetuned, 6159.00), (chest-imagenome, 4574.00), (gpt-3.5-turbo-0613, 106.00), (gpt-4-0613, 13.00)]
# Label: diaphragmatic eventration (benign)
# 	Number of idxs: 10148
# 	Weight: 2357.37
# 	Sub-datasets: [(t5-small-finetuned, 9928.00), (gpt-3.5-turbo-0613, 156.00), (chest-imagenome, 64.00)]
# Label: rotated
# 	Number of idxs: 9525
# 	Weight: 2309.13
# 	Sub-datasets: [(t5-small-finetuned, 7422.00), (chest-imagenome, 1955.00), (gpt-3.5-turbo-0613, 148.00)]
# Label: breast/nipple shadows
# 	Number of idxs: 9279
# 	Weight: 2289.40
# 	Sub-datasets: [(t5-small-finetuned, 7911.00), (chest-imagenome, 1173.00), (gpt-3.5-turbo-0613, 195.00)]
# Label: pericardial effusion
# 	Number of idxs: 9064
# 	Weight: 2271.82
# 	Sub-datasets: [(t5-small-finetuned, 7384.00), (chest-imagenome, 1528.00), (gpt-3.5-turbo-0613, 152.00)]
# Label: hydropneumothorax
# 	Number of idxs: 7550
# 	Weight: 2137.85
# 	Sub-datasets: [(t5-small-finetuned, 6166.00), (chest-imagenome, 1235.00), (gpt-3.5-turbo-0613, 139.00), (gpt-4-0613, 10.00)]
# Label: cabg grafts
# 	Number of idxs: 6906
# 	Weight: 2074.44
# 	Sub-datasets: [(t5-small-finetuned, 5032.00), (chest-imagenome, 1784.00), (gpt-3.5-turbo-0613, 90.00)]
# Label: goiter
# 	Number of idxs: 6208
# 	Weight: 2000.33
# 	Sub-datasets: [(t5-small-finetuned, 5402.00), (chest-imagenome, 695.00), (gpt-3.5-turbo-0613, 111.00)]
# Label: pneumomediastinum
# 	Number of idxs: 5481
# 	Weight: 1915.97
# 	Sub-datasets: [(t5-small-finetuned, 4266.00), (chest-imagenome, 1070.00), (gpt-3.5-turbo-0613, 145.00)]
# Label: skin fold
# 	Number of idxs: 3747
# 	Weight: 1673.09
# 	Sub-datasets: [(t5-small-finetuned, 3483.00), (chest-imagenome, 206.00), (gpt-3.5-turbo-0613, 58.00)]
# Label: "omitted"
# 	Number of idxs: 524915
# 	Weight: 6860.867585411526
# 	Sub-datasets: [(chest-imagenome, 87959.00), (t5-small-finetuned, 404598.00), (gpt-4-0613, 3070.00), (gpt-3.5-turbo-0613, 29288.00)]
# ----
# Building train chest imagenome anatomical_locations classification dataset and dataloader...
# Loading integrated chest imagenome anatomical_locations from /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_chest_imagenome_anatomical_locations(5).pkl...
# len(phrases): 3227289
# len(label_names): 38
# labels.shape: (3227289, 38)
# Label: right lower lung zone
# 	Number of idxs: 555020
# 	Weight: 6948.39
# 	Sub-datasets: [(t5-small-finetuned, 456357.00), (chest-imagenome, 90875.00), (gpt-3.5-turbo-0613, 7788.00)]
# Label: left lower lung zone
# 	Number of idxs: 546955
# 	Weight: 6925.34
# 	Sub-datasets: [(t5-small-finetuned, 439935.00), (chest-imagenome, 99703.00), (gpt-3.5-turbo-0613, 7317.00)]
# Label: left lung
# 	Number of idxs: 520158
# 	Weight: 6846.65
# 	Sub-datasets: [(chest-imagenome, 311503.00), (t5-small-finetuned, 202509.00), (gpt-3.5-turbo-0613, 6146.00)]
# Label: right lung
# 	Number of idxs: 513047
# 	Weight: 6825.19
# 	Sub-datasets: [(chest-imagenome, 312822.00), (t5-small-finetuned, 193968.00), (gpt-3.5-turbo-0613, 6257.00)]
# Label: mediastinum
# 	Number of idxs: 264770
# 	Weight: 5845.99
# 	Sub-datasets: [(t5-small-finetuned, 147604.00), (chest-imagenome, 112213.00), (gpt-3.5-turbo-0613, 4953.00)]
# Label: abdomen
# 	Number of idxs: 220127
# 	Weight: 5590.45
# 	Sub-datasets: [(t5-small-finetuned, 181031.00), (chest-imagenome, 32488.00), (gpt-3.5-turbo-0613, 6608.00)]
# Label: left chest wall
# 	Number of idxs: 219729
# 	Weight: 5587.98
# 	Sub-datasets: [(t5-small-finetuned, 199455.00), (chest-imagenome, 16271.00), (gpt-3.5-turbo-0613, 4003.00)]
# Label: right costophrenic angle
# 	Number of idxs: 210906
# 	Weight: 5532.31
# 	Sub-datasets: [(t5-small-finetuned, 133502.00), (chest-imagenome, 75688.00), (gpt-3.5-turbo-0613, 1716.00)]
# Label: right chest wall
# 	Number of idxs: 207195
# 	Weight: 5508.31
# 	Sub-datasets: [(t5-small-finetuned, 185188.00), (chest-imagenome, 18506.00), (gpt-3.5-turbo-0613, 3501.00)]
# Label: left costophrenic angle
# 	Number of idxs: 205253
# 	Weight: 5495.61
# 	Sub-datasets: [(t5-small-finetuned, 126179.00), (chest-imagenome, 77243.00), (gpt-3.5-turbo-0613, 1831.00)]
# Label: right hilar structures
# 	Number of idxs: 179787
# 	Weight: 5318.99
# 	Sub-datasets: [(chest-imagenome, 95325.00), (t5-small-finetuned, 83052.00), (gpt-3.5-turbo-0613, 1410.00)]
# Label: cardiac silhouette
# 	Number of idxs: 174409
# 	Weight: 5279.04
# 	Sub-datasets: [(t5-small-finetuned, 88313.00), (chest-imagenome, 83912.00), (gpt-3.5-turbo-0613, 2184.00)]
# Label: left hilar structures
# 	Number of idxs: 165061
# 	Weight: 5207.08
# 	Sub-datasets: [(chest-imagenome, 91729.00), (t5-small-finetuned, 72153.00), (gpt-3.5-turbo-0613, 1179.00)]
# Label: right upper lung zone
# 	Number of idxs: 149500
# 	Weight: 5079.39
# 	Sub-datasets: [(t5-small-finetuned, 130531.00), (chest-imagenome, 16434.00), (gpt-3.5-turbo-0613, 2535.00)]
# Label: spine
# 	Number of idxs: 131820
# 	Weight: 4920.12
# 	Sub-datasets: [(t5-small-finetuned, 114383.00), (chest-imagenome, 13474.00), (gpt-3.5-turbo-0613, 3963.00)]
# Label: right mid lung zone
# 	Number of idxs: 128412
# 	Weight: 4887.40
# 	Sub-datasets: [(t5-small-finetuned, 93987.00), (chest-imagenome, 32995.00), (gpt-3.5-turbo-0613, 1430.00)]
# Label: left upper lung zone
# 	Number of idxs: 124803
# 	Weight: 4851.95
# 	Sub-datasets: [(t5-small-finetuned, 110460.00), (chest-imagenome, 12425.00), (gpt-3.5-turbo-0613, 1918.00)]
# Label: left hemidiaphragm
# 	Number of idxs: 115401
# 	Weight: 4755.44
# 	Sub-datasets: [(t5-small-finetuned, 98769.00), (chest-imagenome, 14677.00), (gpt-3.5-turbo-0613, 1955.00)]
# Label: neck
# 	Number of idxs: 113526
# 	Weight: 4735.42
# 	Sub-datasets: [(chest-imagenome, 56152.00), (t5-small-finetuned, 55461.00), (gpt-3.5-turbo-0613, 1913.00)]
# Label: right hemidiaphragm
# 	Number of idxs: 111896
# 	Weight: 4717.79
# 	Sub-datasets: [(t5-small-finetuned, 96585.00), (chest-imagenome, 13788.00), (gpt-3.5-turbo-0613, 1523.00)]
# Label: left mid lung zone
# 	Number of idxs: 110606
# 	Weight: 4703.69
# 	Sub-datasets: [(t5-small-finetuned, 77120.00), (chest-imagenome, 32437.00), (gpt-3.5-turbo-0613, 1049.00)]
# Label: trachea
# 	Number of idxs: 98922
# 	Weight: 4569.34
# 	Sub-datasets: [(t5-small-finetuned, 70770.00), (chest-imagenome, 25717.00), (gpt-3.5-turbo-0613, 2435.00)]
# Label: svc
# 	Number of idxs: 82520
# 	Weight: 4356.67
# 	Sub-datasets: [(t5-small-finetuned, 67536.00), (chest-imagenome, 13556.00), (gpt-3.5-turbo-0613, 1428.00)]
# Label: right atrium
# 	Number of idxs: 78614
# 	Weight: 4300.92
# 	Sub-datasets: [(t5-small-finetuned, 69714.00), (chest-imagenome, 7547.00), (gpt-3.5-turbo-0613, 1353.00)]
# Label: aortic arch
# 	Number of idxs: 74185
# 	Weight: 4234.89
# 	Sub-datasets: [(t5-small-finetuned, 60626.00), (chest-imagenome, 12102.00), (gpt-3.5-turbo-0613, 1457.00)]
# Label: left apical zone
# 	Number of idxs: 61159
# 	Weight: 4019.89
# 	Sub-datasets: [(t5-small-finetuned, 48307.00), (chest-imagenome, 11994.00), (gpt-3.5-turbo-0613, 858.00)]
# Label: right apical zone
# 	Number of idxs: 59713
# 	Weight: 3993.76
# 	Sub-datasets: [(t5-small-finetuned, 44678.00), (chest-imagenome, 14074.00), (gpt-3.5-turbo-0613, 961.00)]
# Label: upper mediastinum
# 	Number of idxs: 58396
# 	Weight: 3969.52
# 	Sub-datasets: [(t5-small-finetuned, 31466.00), (chest-imagenome, 26127.00), (gpt-3.5-turbo-0613, 803.00)]
# Label: left arm
# 	Number of idxs: 54148
# 	Weight: 3888.13
# 	Sub-datasets: [(t5-small-finetuned, 52244.00), (gpt-3.5-turbo-0613, 987.00), (chest-imagenome, 917.00)]
# Label: carina
# 	Number of idxs: 52013
# 	Weight: 3845.24
# 	Sub-datasets: [(t5-small-finetuned, 38457.00), (chest-imagenome, 12361.00), (gpt-3.5-turbo-0613, 1195.00)]
# Label: right arm
# 	Number of idxs: 49507
# 	Weight: 3793.02
# 	Sub-datasets: [(t5-small-finetuned, 47507.00), (chest-imagenome, 1065.00), (gpt-3.5-turbo-0613, 935.00)]
# Label: left clavicle
# 	Number of idxs: 48398
# 	Weight: 3769.22
# 	Sub-datasets: [(t5-small-finetuned, 39527.00), (chest-imagenome, 8330.00), (gpt-3.5-turbo-0613, 541.00)]
# Label: right clavicle
# 	Number of idxs: 39797
# 	Weight: 3567.81
# 	Sub-datasets: [(t5-small-finetuned, 30385.00), (chest-imagenome, 8869.00), (gpt-3.5-turbo-0613, 543.00)]
# Label: cavoatrial junction
# 	Number of idxs: 35863
# 	Weight: 3463.66
# 	Sub-datasets: [(t5-small-finetuned, 31536.00), (chest-imagenome, 3807.00), (gpt-3.5-turbo-0613, 520.00)]
# Label: left shoulder
# 	Number of idxs: 26094
# 	Weight: 3158.04
# 	Sub-datasets: [(t5-small-finetuned, 18216.00), (chest-imagenome, 7340.00), (gpt-3.5-turbo-0613, 538.00)]
# Label: left breast
# 	Number of idxs: 25532
# 	Weight: 3137.80
# 	Sub-datasets: [(t5-small-finetuned, 24231.00), (chest-imagenome, 886.00), (gpt-3.5-turbo-0613, 415.00)]
# Label: right shoulder
# 	Number of idxs: 23347
# 	Weight: 3055.54
# 	Sub-datasets: [(t5-small-finetuned, 11918.00), (chest-imagenome, 10887.00), (gpt-3.5-turbo-0613, 542.00)]
# Label: right breast
# 	Number of idxs: 14892
# 	Weight: 2663.80
# 	Sub-datasets: [(t5-small-finetuned, 13666.00), (chest-imagenome, 945.00), (gpt-3.5-turbo-0613, 281.00)]
# Label: "omitted"
# 	Number of idxs: 449397
# 	Weight: 6620.981877988595
# 	Sub-datasets: [(chest-imagenome, 262.00), (t5-small-finetuned, 433804.00), (gpt-3.5-turbo-0613, 15331.00)]
# ----
# Number of RadNLI samples: 480
# Number of MS_CXR_T samples: 361
# Number of total samples: 841
# ----
# Building val NLI dataset and dataloader...
# ----
# Building val entailment/contradiction dataset and dataloader...
# EntailmentContradictionDataset: __init__
# Number of entailment samples: 243
# Number of contradiction samples: 318
# Example entailment/contradiction samples:
# {'ent_p': 'Lungs are clear.', 'ent_h': 'The lungs are unremarkable.', 'con_p': 'Cardiomediastinal and hilar contours are unremarkable with the exception of a tortuous aorta.', 'con_h': 'PA and lateral chest radiographs demonstrate a normal cardiomediastinal silhouette.'}
# {'ent_p': 'moderate right pleural effusion is larger today than on ___.', 'ent_h': 'moderate right pleural effusion is worse today than on ___.', 'con_p': 'PA and lateral chest radiographs demonstrate a normal cardiomediastinal silhouette.', 'con_h': 'Cardiomediastinal and hilar contours are unremarkable with the exception of a tortuous aorta.'}
# {'ent_p': 'The lungs are unremarkable.', 'ent_h': 'The lungs are clear.', 'con_p': 'Known small left pneumothorax is not well seen.', 'con_h': 'No pneumothorax.'}
# {'ent_p': 'Loculated left pneumothorax is unchanged.', 'ent_h': 'The loculated left pneumothorax is not significantly changed.', 'con_p': 'No pneumothorax.', 'con_h': 'Known small left pneumothorax is not well seen.'}
# ----
# Loading integrated NLI from /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(265719,34150895).jsonl...
# Number of samples: 265719
# Loading integrated sentence facts from /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_sentence_facts(58655550,50990861).jsonl...
# Number of integrated sentence facts: 677694
# Number of entailment samples added: 1309458
# ----
# Building train NLI dataset and dataloader...
# Source: 0 | Label: 0 -> 13185 (2563.82)
# Source: 1 | Label: 0 -> 35146 (3443.68)
# Source: 2 | Label: 0 -> 1770 (1256.05)
# Source: 3 | Label: 0 -> 3744 (1672.60)
# Source: 4 | Label: 0 -> 465 (695.76)
# Source: 5 | Label: 0 -> 473 (701.58)
# Source: 6 | Label: 0 -> 93 (279.62)
# Source: 7 | Label: 0 -> 1309458 (8390.84)
# Source: 0 | Label: 1 -> 19123 (2877.24)
# Source: 1 | Label: 1 -> 47440 (3748.30)
# Source: 2 | Label: 1 -> 3968 (1708.29)
# Source: 3 | Label: 1 -> 3743 (1672.44)
# Source: 4 | Label: 1 -> 465 (695.76)
# Source: 5 | Label: 1 -> 474 (702.30)
# Source: 6 | Label: 1 -> 281 (538.25)
# Source: 0 | Label: 2 -> 79430 (4312.76)
# Source: 1 | Label: 2 -> 46960 (3737.69)
# Source: 2 | Label: 2 -> 4170 (1739.18)
# Source: 3 | Label: 2 -> 3744 (1672.60)
# Source: 4 | Label: 2 -> 465 (695.76)
# Source: 5 | Label: 2 -> 474 (702.30)
# Source: 6 | Label: 2 -> 106 (304.54)
# NLI dataset examples:
# Example 0:
# Premise: Endotracheal tube measures 2.4 cm above the carina likely unchanged given chin-down positioning.
# Hypothesis: likely unchanged endotracheal tube position due to chin-down positioning
# Label: 0
# Example 1:
# Premise: Lungs are adequately expanded without focal consolidation concerning for pneumonia.
# Hypothesis: Lungs are slightly hyperinflated but essentially clear.
# Label: 1
# Example 2:
# Premise: The patient's upper lungs are completely healthy with no signs of emphysema.
# Hypothesis: Relative lucency of the bilateral upper lungs suggests background emphysematous changes.
# Label: 2
# Example 3:
# Premise: multiple tiny pulmonary nodules better characterized on previous CT
# Hypothesis: small lung nodules better seen in prior CT
# Label: 0
# Example 4:
# Premise: Moderate cardiomegaly is chronic and mild pulmonary edema is worse today than on , though less severe than on or .
# Hypothesis: There are no signs of pneumothorax or pleural effusion in the patient's chest X-ray.
# Label: 1
# ----
# Building train entailment/contradiction dataset and dataloader...
# EntailmentContradictionDataset: __init__
# Number of entailment samples: 13185
# Number of contradiction samples: 135349
# Source: 0 -> (len(ent_premises), len(cont_premises)): (13185, 135349)
# EntailmentContradictionDataset: __init__
# Number of entailment samples: 35146
# Number of contradiction samples: 135349
# Source: 1 -> (len(ent_premises), len(cont_premises)): (35146, 135349)
# EntailmentContradictionDataset: __init__
# Number of entailment samples: 1770
# Number of contradiction samples: 135349
# Source: 2 -> (len(ent_premises), len(cont_premises)): (1770, 135349)
# EntailmentContradictionDataset: __init__
# Number of entailment samples: 3744
# Number of contradiction samples: 135349
# Source: 3 -> (len(ent_premises), len(cont_premises)): (3744, 135349)
# EntailmentContradictionDataset: __init__
# Number of entailment samples: 465
# Number of contradiction samples: 135349
# Source: 4 -> (len(ent_premises), len(cont_premises)): (465, 135349)
# EntailmentContradictionDataset: __init__
# Number of entailment samples: 473
# Number of contradiction samples: 135349
# Source: 5 -> (len(ent_premises), len(cont_premises)): (473, 135349)
# EntailmentContradictionDataset: __init__
# Number of entailment samples: 93
# Number of contradiction samples: 135349
# Source: 6 -> (len(ent_premises), len(cont_premises)): (93, 135349)
# EntailmentContradictionDataset: __init__
# Number of entailment samples: 1309458
# Number of contradiction samples: 135349
# Source: 7 -> (len(ent_premises), len(cont_premises)): (1309458, 135349)
# Number of datasets: 8
# Example entailment/contradiction samples:
# {'ent_p': 'There are unchanged air space opacities which are more confluent within the right upper lobe.', 'ent_h': 'The right upper lobe of the lung shows more confluent air space opacities that have not changed.', 'con_p': 'In comparison with the study , the opacification along the right lateral chest wall has decreased.', 'con_h': 'The opacification along the right lateral chest wall has remained the same.'}
# {'ent_p': 'It is difficult to assess the presence of right hilar lymphadenopathy on the current study that was seen on the prior examination.', 'ent_h': '2. Mediastinal contours demonstrate the lymphadenopathy and contained dissection/pseudoaneurysm better seen on prior CT.', 'con_p': 'Mild interstitial edema in the left upper lung is new.', 'con_h': 'Bilateral interstitial abnormality appears unchanged compared to most recent prior exam.'}
# {'ent_p': 'No focal consolidation concerning for pneumonia is seen.', 'ent_h': 'No convincing evidence of pneumonia.', 'con_p': 'A left subclavian central venous catheter tip terminates in the SVC.', 'con_h': 'Right subclavian central venous catheter with tip terminating in the mid SVC.'}
# ...
# 2025-06-02 17:31:04,858 - INFO - ignite.engine.engine.Engine - Engine run starting with max_epochs=1.
# Validation: [93/93] 100%|███████████ [00:10<00:00]
# 2025-06-02 17:31:16,041 - INFO - medvqa.utils.handlers_utils - tacc(al0) 0.98900, tacc(al1) 0.98200, tacc(al2) 0.90100, tacc(ob0) 0.99900, tacc(ob1) 0.99000, tacc(ob2) 0.95000, tacc(ob3) 0.99000, tacc(ob4) 0.98700, tacc(ob5) 0.92200, tacc(ob6) 0.98000, tacc(ob7) 0.96400, tacc(ob8) 0.98100, nli_acc 0.84304, entcon_acc 0.96855, sae_loss 1.56274, 11.18 secs
# 2025-06-02 17:31:16,042 - INFO - ignite.engine.engine.Engine - Epoch[1] Complete. Time taken: 00:00:11.184
# 2025-06-02 17:31:16,042 - INFO - ignite.engine.engine.Engine - Engine run complete. Time taken: 00:00:11.184
# 2025-06-02 17:31:16,043 - INFO - ignite.engine.engine.Engine - Epoch[191] Complete. Time taken: 00:01:35.089
# 2025-06-02 17:31:16,044 - INFO - medvqa.utils.handlers_utils - ==================== Epoch 192/200 ====================
# 2025-06-02 17:31:16,044 - INFO - medvqa.training.utils - (1) Training stage (lr = 0.000030) ...
# Training [192/200]: [800/800] 100%|█████████, loss=0.991 [01:25<00:00]
# 2025-06-02 17:32:41,970 - INFO - medvqa.utils.handlers_utils - loss 0.97002, triplet_loss 0.84885, c_loss 0.11642, hs_loss 0.28813, cs_loss 0.74449, cacc 0.95484, hsacc 0.90516, csacc 0.72774, chstimgn_obs_loss 0.22874, chestimg_obs_macf1 0.85921, chstimgn_anatloc_loss 0.37686, chestimg_anatloc_macf1 0.88141, nli_loss 0.25486, nli_acc 0.90049, entcon_loss 0.33836, entcon_acc 0.95290, sae_loss 2.88239, 85.93 secs
# 2025-06-02 17:32:41,970 - INFO - medvqa.training.utils - (2) Validation stage ...
# 2025-06-02 17:32:41,971 - INFO - ignite.engine.engine.Engine - Engine run starting with max_epochs=1.
# Validation: [93/93] 100%|███████████ [00:10<00:00]
# 2025-06-02 17:32:53,402 - INFO - medvqa.utils.handlers_utils - tacc(al0) 0.98900, tacc(al1) 0.98500, tacc(al2) 0.90100, tacc(ob0) 0.99900, tacc(ob1) 0.99000, tacc(ob2) 0.94700, tacc(ob3) 0.99000, tacc(ob4) 0.98800, tacc(ob5) 0.92300, tacc(ob6) 0.97700, tacc(ob7) 0.96500, tacc(ob8) 0.98400, nli_acc 0.87039, entcon_acc 0.98113, sae_loss 1.55485, 11.43 secs
# 2025-06-02 17:32:55,056 - INFO - medvqa.utils.handlers_utils - New checkpoint saved: checkpoint_192_cacc+chf1+chf1+cscc+encc+hscc+nlcc+sass+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)+ta8)=0.9072.pt
# 2025-06-02 17:32:55,056 - INFO - ignite.engine.engine.Engine - Epoch[1] Complete. Time taken: 00:00:13.085
# 2025-06-02 17:32:55,056 - INFO - ignite.engine.engine.Engine - Engine run complete. Time taken: 00:00:13.086
# 2025-06-02 17:32:55,057 - INFO - ignite.engine.engine.Engine - Epoch[192] Complete. Time taken: 00:01:39.014
# 2025-06-02 17:32:55,057 - INFO - medvqa.utils.handlers_utils - ==================== Epoch 193/200 ====================
# 2025-06-02 17:32:55,057 - INFO - medvqa.training.utils - (1) Training stage (lr = 0.000013) ...
# Training [193/200]: [800/800] 100%|█████████, loss=0.461 [01:27<00:00]
# 2025-06-02 17:34:22,644 - INFO - medvqa.utils.handlers_utils - loss 0.95939, triplet_loss 0.84614, c_loss 0.11841, hs_loss 0.26465, cs_loss 0.74599, cacc 0.95869, hsacc 0.90361, csacc 0.73443, chstimgn_obs_loss 0.22301, chestimg_obs_macf1 0.85926, chstimgn_anatloc_loss 0.36976, chestimg_anatloc_macf1 0.88304, nli_loss 0.23466, nli_acc 0.91057, entcon_loss 0.33505, entcon_acc 0.95475, sae_loss 2.86158, 87.59 secs
# 2025-06-02 17:34:22,644 - INFO - medvqa.training.utils - (2) Validation stage ...
# 2025-06-02 17:34:22,645 - INFO - ignite.engine.engine.Engine - Engine run starting with max_epochs=1.
# Validation: [93/93] 100%|███████████ [00:09<00:00]
# 2025-06-02 17:34:33,775 - INFO - medvqa.utils.handlers_utils - tacc(al0) 0.99000, tacc(al1) 0.98500, tacc(al2) 0.90100, tacc(ob0) 1.00000, tacc(ob1) 0.99000, tacc(ob2) 0.94300, tacc(ob3) 0.99000, tacc(ob4) 0.98800, tacc(ob5) 0.92000, tacc(ob6) 0.97800, tacc(ob7) 0.96300, tacc(ob8) 0.98400, nli_acc 0.86445, entcon_acc 0.98113, sae_loss 1.55496, 11.13 secs
# 2025-06-02 17:34:35,389 - INFO - medvqa.utils.handlers_utils - New checkpoint saved: checkpoint_193_cacc+chf1+chf1+cscc+encc+hscc+nlcc+sass+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)+ta8)=0.9073.pt
# 2025-06-02 17:34:35,389 - INFO - ignite.engine.engine.Engine - Epoch[1] Complete. Time taken: 00:00:12.744
# 2025-06-02 17:34:35,389 - INFO - ignite.engine.engine.Engine - Engine run complete. Time taken: 00:00:12.744
# 2025-06-02 17:34:35,390 - INFO - ignite.engine.engine.Engine - Epoch[193] Complete. Time taken: 00:01:40.333
# 2025-06-02 17:34:35,390 - INFO - medvqa.utils.handlers_utils - ==================== Epoch 194/200 ====================
# 2025-06-02 17:34:35,390 - INFO - medvqa.training.utils - (1) Training stage (lr = 0.000005) ...
# Training [194/200]: [800/800] 100%|█████████, loss=0.836 [01:21<00:00]
# 2025-06-02 17:35:56,692 - INFO - medvqa.utils.handlers_utils - loss 0.94918, triplet_loss 0.84647, c_loss 0.09730, hs_loss 0.26401, cs_loss 0.71589, cacc 0.96194, hsacc 0.90645, csacc 0.74194, chstimgn_obs_loss 0.22912, chestimg_obs_macf1 0.85685, chstimgn_anatloc_loss 0.35748, chestimg_anatloc_macf1 0.87868, nli_loss 0.27404, nli_acc 0.89333, entcon_loss 0.33430, entcon_acc 0.95613, sae_loss 2.77746, 81.30 secs
# 2025-06-02 17:35:56,693 - INFO - medvqa.training.utils - (2) Validation stage ...
# 2025-06-02 17:35:56,693 - INFO - ignite.engine.engine.Engine - Engine run starting with max_epochs=1.
# Validation: [93/93] 100%|███████████ [00:10<00:00]
# 2025-06-02 17:36:07,914 - INFO - medvqa.utils.handlers_utils - tacc(al0) 0.99000, tacc(al1) 0.98500, tacc(al2) 0.90100, tacc(ob0) 0.99900, tacc(ob1) 0.99000, tacc(ob2) 0.94500, tacc(ob3) 0.99000, tacc(ob4) 0.98800, tacc(ob5) 0.92000, tacc(ob6) 0.97700, tacc(ob7) 0.96400, tacc(ob8) 0.98400, nli_acc 0.86564, entcon_acc 0.98113, sae_loss 1.55432, 11.22 secs
# 2025-06-02 17:36:07,915 - INFO - ignite.engine.engine.Engine - Epoch[1] Complete. Time taken: 00:00:11.222
# 2025-06-02 17:36:07,916 - INFO - ignite.engine.engine.Engine - Engine run complete. Time taken: 00:00:11.222
# 2025-06-02 17:36:07,916 - INFO - ignite.engine.engine.Engine - Epoch[194] Complete. Time taken: 00:01:32.526
# 2025-06-02 17:36:07,917 - INFO - medvqa.utils.handlers_utils - ==================== Epoch 195/200 ====================
# 2025-06-02 17:36:07,917 - INFO - medvqa.training.utils - (1) Training stage (lr = 0.000002) ...
# Training [195/200]: [800/800] 100%|█████████, loss=0.345 [01:25<00:00]
# 2025-06-02 17:37:33,470 - INFO - medvqa.utils.handlers_utils - loss 0.96468, triplet_loss 0.84965, c_loss 0.14070, hs_loss 0.24373, cs_loss 0.72296, cacc 0.94426, hsacc 0.90689, csacc 0.72656, chstimgn_obs_loss 0.24369, chestimg_obs_macf1 0.84658, chstimgn_anatloc_loss 0.36317, chestimg_anatloc_macf1 0.86971, nli_loss 0.23932, nli_acc 0.90829, entcon_loss 0.32936, entcon_acc 0.95290, sae_loss 2.89325, 85.55 secs
# 2025-06-02 17:37:33,471 - INFO - medvqa.training.utils - (2) Validation stage ...
# 2025-06-02 17:37:33,471 - INFO - ignite.engine.engine.Engine - Engine run starting with max_epochs=1.
# Validation: [93/93] 100%|███████████ [00:10<00:00]
# 2025-06-02 17:37:45,606 - INFO - medvqa.utils.handlers_utils - tacc(al0) 0.99000, tacc(al1) 0.98500, tacc(al2) 0.90100, tacc(ob0) 0.99800, tacc(ob1) 0.99000, tacc(ob2) 0.94600, tacc(ob3) 0.99000, tacc(ob4) 0.98800, tacc(ob5) 0.92100, tacc(ob6) 0.97700, tacc(ob7) 0.96400, tacc(ob8) 0.98400, nli_acc 0.86445, entcon_acc 0.98113, sae_loss 1.55358, 12.13 secs
# 2025-06-02 17:37:45,608 - INFO - ignite.engine.engine.Engine - Epoch[1] Complete. Time taken: 00:00:12.136
# 2025-06-02 17:37:45,608 - INFO - ignite.engine.engine.Engine - Engine run complete. Time taken: 00:00:12.136
# 2025-06-02 17:37:45,608 - INFO - ignite.engine.engine.Engine - Epoch[195] Complete. Time taken: 00:01:37.692
# 2025-06-02 17:37:45,609 - INFO - medvqa.utils.handlers_utils - ==================== Epoch 196/200 ====================
# 2025-06-02 17:37:45,609 - INFO - medvqa.training.utils - (1) Training stage (lr = 0.000001) ...
# Training [196/200]: [800/800] 100%|█████████, loss=0.286 [01:27<00:00]
# 2025-06-02 17:39:12,897 - INFO - medvqa.utils.handlers_utils - loss 0.97428, triplet_loss 0.84730, c_loss 0.13733, hs_loss 0.24766, cs_loss 0.76213, cacc 0.94903, hsacc 0.91226, csacc 0.72258, chstimgn_obs_loss 0.22762, chestimg_obs_macf1 0.86297, chstimgn_anatloc_loss 0.36545, chestimg_anatloc_macf1 0.88952, nli_loss 0.26322, nli_acc 0.90049, entcon_loss 0.32702, entcon_acc 0.95607, sae_loss 2.91552, 87.29 secs
# 2025-06-02 17:39:12,897 - INFO - medvqa.training.utils - (2) Validation stage ...
# 2025-06-02 17:39:12,898 - INFO - ignite.engine.engine.Engine - Engine run starting with max_epochs=1.
# Validation: [93/93] 100%|███████████ [00:09<00:00]
# 2025-06-02 17:39:24,062 - INFO - medvqa.utils.handlers_utils - tacc(al0) 0.99000, tacc(al1) 0.98500, tacc(al2) 0.90100, tacc(ob0) 0.99800, tacc(ob1) 0.99000, tacc(ob2) 0.94600, tacc(ob3) 0.99000, tacc(ob4) 0.98800, tacc(ob5) 0.92100, tacc(ob6) 0.97700, tacc(ob7) 0.96400, tacc(ob8) 0.98400, nli_acc 0.86326, entcon_acc 0.98113, sae_loss 1.55340, 11.16 secs
# 2025-06-02 17:39:24,063 - INFO - ignite.engine.engine.Engine - Epoch[1] Complete. Time taken: 00:00:11.165
# 2025-06-02 17:39:24,064 - INFO - ignite.engine.engine.Engine - Engine run complete. Time taken: 00:00:11.166
# 2025-06-02 17:39:24,064 - INFO - ignite.engine.engine.Engine - Epoch[196] Complete. Time taken: 00:01:38.456
# 2025-06-02 17:39:24,065 - INFO - medvqa.utils.handlers_utils - ==================== Epoch 197/200 ====================
# 2025-06-02 17:39:24,065 - INFO - medvqa.training.utils - (1) Training stage (lr = 0.000070) ...
# Training [197/200]: [800/800] 100%|█████████, loss=0.825 [01:25<00:00]
# 2025-06-02 17:40:50,060 - INFO - medvqa.utils.handlers_utils - loss 0.96380, triplet_loss 0.85174, c_loss 0.16651, hs_loss 0.26119, cs_loss 0.80738, cacc 0.94295, hsacc 0.89443, csacc 0.71279, chstimgn_obs_loss 0.23216, chestimg_obs_macf1 0.85586, chstimgn_anatloc_loss 0.36585, chestimg_anatloc_macf1 0.88247, nli_loss 0.25676, nli_acc 0.90081, entcon_loss 0.33267, entcon_acc 0.96000, sae_loss 2.79931, 86.00 secs
# 2025-06-02 17:40:50,060 - INFO - medvqa.training.utils - (2) Validation stage ...
# 2025-06-02 17:40:50,061 - INFO - ignite.engine.engine.Engine - Engine run starting with max_epochs=1.
# Validation: [93/93] 100%|███████████ [00:10<00:00]
# 2025-06-02 17:41:01,363 - INFO - medvqa.utils.handlers_utils - tacc(al0) 0.99100, tacc(al1) 0.98200, tacc(al2) 0.90600, tacc(ob0) 0.99900, tacc(ob1) 0.98900, tacc(ob2) 0.94700, tacc(ob3) 0.99000, tacc(ob4) 0.98700, tacc(ob5) 0.91400, tacc(ob6) 0.98000, tacc(ob7) 0.95600, tacc(ob8) 0.98500, nli_acc 0.87158, entcon_acc 0.97484, sae_loss 1.54776, 11.30 secs
# 2025-06-02 17:41:01,364 - INFO - ignite.engine.engine.Engine - Epoch[1] Complete. Time taken: 00:00:11.303
# 2025-06-02 17:41:01,365 - INFO - ignite.engine.engine.Engine - Engine run complete. Time taken: 00:00:11.304
# 2025-06-02 17:41:01,365 - INFO - ignite.engine.engine.Engine - Epoch[197] Complete. Time taken: 00:01:37.301
# 2025-06-02 17:41:01,366 - INFO - medvqa.utils.handlers_utils - ==================== Epoch 198/200 ====================
# 2025-06-02 17:41:01,366 - INFO - medvqa.training.utils - (1) Training stage (lr = 0.000030) ...
# Training [198/200]: [800/800] 100%|█████████, loss=0.814 [01:27<00:00]
# 2025-06-02 17:42:28,463 - INFO - medvqa.utils.handlers_utils - loss 0.96733, triplet_loss 0.84268, c_loss 0.12874, hs_loss 0.29247, cs_loss 0.75755, cacc 0.94774, hsacc 0.88903, csacc 0.72774, chstimgn_obs_loss 0.25792, chestimg_obs_macf1 0.83976, chstimgn_anatloc_loss 0.36969, chestimg_anatloc_macf1 0.87645, nli_loss 0.28295, nli_acc 0.88780, entcon_loss 0.33370, entcon_acc 0.95541, sae_loss 2.82548, 87.10 secs
# 2025-06-02 17:42:28,463 - INFO - medvqa.training.utils - (2) Validation stage ...
# 2025-06-02 17:42:28,463 - INFO - ignite.engine.engine.Engine - Engine run starting with max_epochs=1.
# Validation: [93/93] 100%|███████████ [00:10<00:00]
# 2025-06-02 17:42:39,893 - INFO - medvqa.utils.handlers_utils - tacc(al0) 0.99000, tacc(al1) 0.98200, tacc(al2) 0.90400, tacc(ob0) 0.99800, tacc(ob1) 0.98900, tacc(ob2) 0.95000, tacc(ob3) 0.99000, tacc(ob4) 0.98600, tacc(ob5) 0.91300, tacc(ob6) 0.98100, tacc(ob7) 0.95800, tacc(ob8) 0.98000, nli_acc 0.85731, entcon_acc 0.97799, sae_loss 1.54536, 11.43 secs
# 2025-06-02 17:42:39,894 - INFO - ignite.engine.engine.Engine - Epoch[1] Complete. Time taken: 00:00:11.430
# 2025-06-02 17:42:39,894 - INFO - ignite.engine.engine.Engine - Engine run complete. Time taken: 00:00:11.431
# 2025-06-02 17:42:39,895 - INFO - ignite.engine.engine.Engine - Epoch[198] Complete. Time taken: 00:01:38.529
# 2025-06-02 17:42:39,895 - INFO - medvqa.utils.handlers_utils - ==================== Epoch 199/200 ====================
# 2025-06-02 17:42:39,895 - INFO - medvqa.training.utils - (1) Training stage (lr = 0.000013) ...
# Training [199/200]: [800/800] 100%|█████████, loss=0.241 [01:19<00:00]
# 2025-06-02 17:43:59,792 - INFO - medvqa.utils.handlers_utils - loss 0.96326, triplet_loss 0.84837, c_loss 0.13642, hs_loss 0.25112, cs_loss 0.77075, cacc 0.94951, hsacc 0.89902, csacc 0.72656, chstimgn_obs_loss 0.24799, chestimg_obs_macf1 0.84764, chstimgn_anatloc_loss 0.34431, chestimg_anatloc_macf1 0.88736, nli_loss 0.27295, nli_acc 0.89968, entcon_loss 0.32809, entcon_acc 0.95484, sae_loss 2.83611, 79.90 secs
# 2025-06-02 17:43:59,793 - INFO - medvqa.training.utils - (2) Validation stage ...
# 2025-06-02 17:43:59,793 - INFO - ignite.engine.engine.Engine - Engine run starting with max_epochs=1.
# Validation: [93/93] 100%|███████████ [00:10<00:00]
# 2025-06-02 17:44:11,030 - INFO - medvqa.utils.handlers_utils - tacc(al0) 0.99000, tacc(al1) 0.98200, tacc(al2) 0.90600, tacc(ob0) 0.99700, tacc(ob1) 0.98800, tacc(ob2) 0.95100, tacc(ob3) 0.99000, tacc(ob4) 0.98600, tacc(ob5) 0.91400, tacc(ob6) 0.98000, tacc(ob7) 0.95900, tacc(ob8) 0.98000, nli_acc 0.86207, entcon_acc 0.98113, sae_loss 1.54138, 11.24 secs
# 2025-06-02 17:44:11,032 - INFO - ignite.engine.engine.Engine - Epoch[1] Complete. Time taken: 00:00:11.238
# 2025-06-02 17:44:11,032 - INFO - ignite.engine.engine.Engine - Engine run complete. Time taken: 00:00:11.239
# 2025-06-02 17:44:11,033 - INFO - ignite.engine.engine.Engine - Epoch[199] Complete. Time taken: 00:01:31.137
# 2025-06-02 17:44:11,033 - INFO - medvqa.utils.handlers_utils - ==================== Epoch 200/200 ====================
# 2025-06-02 17:44:11,033 - INFO - medvqa.training.utils - (1) Training stage (lr = 0.000005) ...
# Training [200/200]: [800/800] 100%|█████████, loss=0.318 [01:26<00:00]
# 2025-06-02 17:45:37,603 - INFO - medvqa.utils.handlers_utils - loss 0.96872, triplet_loss 0.84865, c_loss 0.12623, hs_loss 0.25622, cs_loss 0.75427, cacc 0.95226, hsacc 0.90516, csacc 0.72323, chstimgn_obs_loss 0.22018, chestimg_obs_macf1 0.85740, chstimgn_anatloc_loss 0.37502, chestimg_anatloc_macf1 0.87712, nli_loss 0.26943, nli_acc 0.89724, entcon_loss 0.33564, entcon_acc 0.94689, sae_loss 2.86972, 86.57 secs
# 2025-06-02 17:45:37,603 - INFO - medvqa.training.utils - (2) Validation stage ...
# 2025-06-02 17:45:37,604 - INFO - ignite.engine.engine.Engine - Engine run starting with max_epochs=1.
# Validation: [93/93] 100%|███████████ [00:10<00:00]
# 2025-06-02 17:45:48,824 - INFO - medvqa.utils.handlers_utils - tacc(al0) 0.99000, tacc(al1) 0.98200, tacc(al2) 0.90500, tacc(ob0) 0.99700, tacc(ob1) 0.98800, tacc(ob2) 0.95200, tacc(ob3) 0.99000, tacc(ob4) 0.98700, tacc(ob5) 0.91400, tacc(ob6) 0.98000, tacc(ob7) 0.96000, tacc(ob8) 0.98100, nli_acc 0.86326, entcon_acc 0.98113, sae_loss 1.54044, 11.22 secs
# 2025-06-02 17:45:48,826 - INFO - ignite.engine.engine.Engine - Epoch[1] Complete. Time taken: 00:00:11.221
# 2025-06-02 17:45:48,826 - INFO - ignite.engine.engine.Engine - Engine run complete. Time taken: 00:00:11.222
# 2025-06-02 17:45:48,827 - INFO - ignite.engine.engine.Engine - Epoch[200] Complete. Time taken: 00:01:37.794
# 2025-06-02 17:45:48,827 - INFO - ignite.engine.engine.Engine - Engine run complete. Time taken: 05:20:53.805

# %%
# !python ../../train_fact_embedding.py \
--pretrained_checkpoint_folder_paths \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20250602_122454_MIMIC-CXR(triplets+classif+entcont+nli+autoencoder)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)" \
--epochs 200 \
--batches_per_epoch 800 \
--batch_size 25 \
--val_batch_size 150 \
--num_workers 3 \
--iters_to_accumulate 20 \
--optimizer_name "adamw" \
--scheduler "exp-warmup+decay+cyclicdecay" \
--lr 1e-6 \
--warmup_decay_and_cyclic_decay_args "1e-6,3,7e-5,6,1e-6,7e-5,6,1e-6" \
--triplets_filepath \
"/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/mimiccxr/triplets(4550211,318620,2395255,637929,208058,3002000,1000,1000,274,1091231605151220188).pkl" \
--triplet_rule_weights \
"{'anatomical_locations': [1., 2., 1.], 'observations': [1., 2., 1.5, 1., 1., 1., 1., 2., 2.]}" \
--integrated_facts_metadata_jsonl_filepath \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_fact_metadata(595880,60579117).improved_comparison(6741113).jsonl" \
--paraphrases_jsonl_filepaths \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_anatomical_locations__part1.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_anatomical_locations__part2.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-16k-0613_paraphrased_anatomical_locations__part3.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__single-words.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words__part1.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-16k-0613_paraphrased_observations__two-or-more-words__part2.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words__part3.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-16k-0613_paraphrased_observations__two-or-more-words__part4.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_paraphrased_observations__two-or-more-words_cluster-balanced.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words_cluster-balanced_1of5.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words_cluster-balanced_2of5.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words_cluster-balanced_3of5.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words_cluster-balanced_4of5.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_hard_triplets_from_facts(cluster-balanced,hardest)-part1.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_hard_triplets_from_facts(cluster-balanced,hardest)-part2.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_hard_triplets_from_facts(cluster-balanced,hardest)-part3.jsonl" \
--integrated_chest_imagenome_observations_filepath \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_chest_imagenome_observations(9).pkl" \
--integrated_chest_imagenome_anatomical_locations_filepath \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_chest_imagenome_anatomical_locations(5).pkl" \
--integrated_nli_jsonl_filepath \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(265719,34150895).jsonl" \
--integrated_sentence_facts_jsonl_filepath \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_sentence_facts(58655550,50990861).jsonl" \
--sentences_and_cluster_ids_filepath \
"/mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/sentence_cluster_ids(2506, 2260387000448473611).pkl" \
--n_chest_imagenome_observations 74 \
--n_chest_imagenome_anatomical_locations 38 \
--triplets_weight 5.0 \
--metadata_classification_weight 1.0 \
--chest_imagenome_observations_classification_weight 1.0 \
--chest_imagenome_anatomical_locations_classification_weight 1.0 \
--nli_weight 2.0 \
--entcon_weight 1.0 \
--sentence_autoencoder_weight 2.0 \
--triplet_loss_weight 2.0 \
--sentence_autoencoder_loss_weight 1.5 \
--dataset_name "MIMIC-CXR(triplets+classif+entcont+nli+autoencoder)" \
--huggingface_model_name "microsoft/BiomedVLP-CXR-BERT-specialized" \
--embedding_size 128 \
--use_aux_task_hidden_layer \
--aux_task_hidden_layer_size 512 \
--nli_hidden_layer_size 128 \
--train_metrics_weight 0.25 \
--use_amp \
--save
# Out:
# 2025-06-10 21:36:54,954 - INFO - root - Logging configured (Color: True).
# 2025-06-10 21:36:54,958 - INFO - medvqa.utils.common -
# script's arguments:
#    epochs: 200
#    batches_per_epoch: 800
#    batch_size: 25
#    train_metrics_weight: 0.25
#    val_batch_size: 150
#    radgraph_spert_batch_size: None
#    checkpoint_folder: None
#    huggingface_model_name: microsoft/BiomedVLP-CXR-BERT-specialized
#    embedding_size: 128
#    n_chest_imagenome_observations: 74
#    n_chest_imagenome_anatomical_locations: 38
#    use_aux_task_hidden_layer: True
#    aux_task_hidden_layer_size: 512
#    nli_hidden_layer_size: 128
#    pretrained_checkpoint_folder_path: None
#    pretrained_checkpoint_folder_paths: ['/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20250602_122454_MIMIC-CXR(triplets+classif+entcont+nli+autoencoder)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)']
#    freeze_huggingface_model: False
#    spert_size_embedding: 25
#    spert_max_pairs: 1000
#    spert_prop_drop: 0.1
#    fact_decoder_embed_size: 256
#    fact_decoder_hidden_size: 256
#    fact_decoder_nhead: 1
#    fact_decoder_dim_feedforward: 256
#    fact_decoder_num_layers: 1
#    optimizer_name: adamw
#    lr: 1e-06
#    scheduler: exp-warmup+decay+cyclicdecay
#    lr_decay: 0.76
#    lr_decay_patience: 2
#    warmup_and_decay_args: None
#    warmup_and_cosine_args: None
#    warmup_decay_and_cyclic_decay_args: 1e-6,3,7e-5,6,1e-6,7e-5,6,1e-6
#    iters_to_accumulate: 20
#    override_lr: False
#    max_grad_norm: None
#    triplet_loss_weight: 2.0
#    category_classif_loss_weight: 1.0
#    health_status_classif_loss_weight: 1.0
#    comparison_status_classif_loss_weight: 1.0
#    chest_imagenome_obs_classif_loss_weight: 1.0
#    chest_imagenome_anatloc_classif_loss_weight: 1.0
#    nli_loss_weight: 1.0
#    entcon_loss_weight: 1.0
#    sentence_autoencoder_loss_weight: 1.5
#    triplets_filepath: /mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/mimiccxr/triplets(4550211,318620,2395255,637929,208058,3002000,1000,1000,274,1091231605151220188).pkl
#    triplet_rule_weights: {'anatomical_locations': [1.0, 2.0, 1.0], 'observations': [1.0, 2.0, 1.5, 1.0, 1.0, 1.0, 1.0, 2.0, 2.0]}
#    integrated_facts_metadata_jsonl_filepath: /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_fact_metadata(595880,60579117).improved_comparison(6741113).jsonl
#    paraphrases_jsonl_filepaths: ['/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_anatomical_locations__part1.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_anatomical_locations__part2.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-16k-0613_paraphrased_anatomical_locations__part3.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__single-words.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words__part1.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-16k-0613_paraphrased_observations__two-or-more-words__part2.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words__part3.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-16k-0613_paraphrased_observations__two-or-more-words__part4.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_paraphrased_observations__two-or-more-words_cluster-balanced.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words_cluster-balanced_1of5.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words_cluster-balanced_2of5.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words_cluster-balanced_3of5.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words_cluster-balanced_4of5.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_hard_triplets_from_facts(cluster-balanced,hardest)-part1.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_hard_triplets_from_facts(cluster-balanced,hardest)-part2.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_hard_triplets_from_facts(cluster-balanced,hardest)-part3.jsonl']
#    integrated_chest_imagenome_observations_filepath: /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_chest_imagenome_observations(9).pkl
#    integrated_chest_imagenome_anatomical_locations_filepath: /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_chest_imagenome_anatomical_locations(5).pkl
#    integrated_nli_jsonl_filepath: /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(265719,34150895).jsonl
#    integrated_sentence_facts_jsonl_filepath: /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_sentence_facts(58655550,50990861).jsonl
#    sentences_and_cluster_ids_filepath: /mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/sentence_cluster_ids(2506, 2260387000448473611).pkl
#    dataset_name: MIMIC-CXR(triplets+classif+entcont+nli+autoencoder)
#    triplets_weight: 5.0
#    metadata_classification_weight: 1.0
#    chest_imagenome_observations_classification_weight: 1.0
#    chest_imagenome_anatomical_locations_classification_weight: 1.0
#    nli_weight: 2.0
#    entcon_weight: 1.0
#    radgraph_ner_re_weight: 0
#    sentence_autoencoder_weight: 2.0
#    use_nli_val_in_train: False
#    use_anli: False
#    use_multinli: False
#    use_snli: False
#    num_workers: 3
#    device: GPU
#    use_amp: True
#    save: True
# 2025-06-10 21:36:54,958 - INFO - __main__ - ========== Training model from scratch ==========
# 2025-06-10 21:36:54,958 - INFO - __main__ - train_metrics_weight = 0.25
# 2025-06-10 21:36:54,958 - INFO - __main__ - ========== Defining collate batch functions ==========
# 2025-06-10 21:36:55,474 - INFO - medvqa.datasets.dataloading_utils - Using tokenizer microsoft/BiomedVLP-CXR-BERT-specialized for collate_fn. Task: triplet_ranking. Augmentation probability: 0.5
# 2025-06-10 21:36:55,872 - INFO - medvqa.datasets.dataloading_utils - Using tokenizer microsoft/BiomedVLP-CXR-BERT-specialized for collate_fn. Task: metadata_classification. Augmentation probability: 0.5
# 2025-06-10 21:36:56,293 - INFO - medvqa.datasets.dataloading_utils - Using tokenizer microsoft/BiomedVLP-CXR-BERT-specialized for collate_fn. Task: chest_imagenome_observation_classification. Augmentation probability: 0.5
# 2025-06-10 21:36:56,684 - INFO - medvqa.datasets.dataloading_utils - Using tokenizer microsoft/BiomedVLP-CXR-BERT-specialized for collate_fn. Task: chest_imagenome_anatomical_location_classification. Augmentation probability: 0.5
# 2025-06-10 21:36:57,062 - INFO - medvqa.datasets.dataloading_utils - Using tokenizer microsoft/BiomedVLP-CXR-BERT-specialized for collate_fn. Task: nli. Augmentation probability: 0.5
# 2025-06-10 21:36:57,445 - INFO - medvqa.datasets.dataloading_utils - Using tokenizer microsoft/BiomedVLP-CXR-BERT-specialized for collate_fn. Task: entcon. Augmentation probability: 0.5
# 2025-06-10 21:36:58,016 - INFO - medvqa.datasets.dataloading_utils - Using tokenizer microsoft/BiomedVLP-CXR-BERT-specialized for collate_fn. Task: sentence_autoencoder. Augmentation probability: 0.5
# Loading triplets from /mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/mimiccxr/triplets(4550211,318620,2395255,637929,208058,3002000,1000,1000,274,1091231605151220188).pkl...
# ----
# Building train triplet ranking dataset and dataloader...
# anatomical_locations -> rule 0: "Rank paraphrases very highly"
# 	Number of triplets: 3440250
# 	Weight: 1.0
# anatomical_locations -> rule 1: "Rank paraphrases very highly - Hard negative"
# 	Number of triplets: 3419308
# 	Weight: 2.0
# anatomical_locations -> rule 2: "Rule 3 (AnatLoc): Rank triplets by Embedding, BLEU-1, & Leveinshtein consensus"
# 	Number of triplets: 3184200
# 	Weight: 1.0
# observations -> rule 0: "Rank paraphrases very highly"
# 	Number of triplets: 4057104
# 	Weight: 1.0
# observations -> rule 1: "Rank paraphrases very highly - Hard negative"
# 	Number of triplets: 4048671
# 	Weight: 2.0
# observations -> rule 2: "Rank triplets by Embedding, BLEU-1, Leveinshtein consensus, A&P same health status"
# 	Number of triplets: 4427826
# 	Weight: 1.5
# observations -> rule 3: "Hard health-status-vs-others triplets"
# 	Number of triplets: 2688197
# 	Weight: 1.0
# observations -> rule 4: "Short observation, detailed observation, and fact must be close to each other"
# 	Number of triplets: 6247265
# 	Weight: 1.0
# observations -> rule 5: "Rank triplets according to Chest ImaGenome labels"
# 	Number of triplets: 3222723
# 	Weight: 1.0
# observations -> rule 6: "RadGraph-based triplets"
# 	Number of triplets: 3173422
# 	Weight: 1.0
# observations -> rule 7: "Hard negative triplets generated by ChatGPT"
# 	Number of triplets: 3044784
# 	Weight: 2.0
# observations -> rule 8: "Abnormal visual findings triplets"
# 	Number of triplets: 3108268
# 	Weight: 2.0
# ----
# Building train metadata classification dataset and dataloader...
# Loading paraphrases from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_anatomical_locations__part1.jsonl...
# Input:
# B
# Paraphrases:
# bilateral
# both sides
# both
# on both sides
# symmetrical
# equally on both sides
# present on both sides
# seen on both sides
# occurring on both sides
# appearing on both sides
# found on both sides
# noted on both sides
# noted bilaterally
# seen bilaterally
# observed bilaterally
# detected bilaterally
# Loading paraphrases from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_anatomical_locations__part2.jsonl...
# Input:
# left of the left hilus
# Paraphrases:
# left of the left hilum
# left to the left hilum
# left side of the left hilum
# leftward to the left hilum
# left of the hilum on the left side
# left of the pulmonary hilum on the left
# leftward to the pulmonary hilum on the left
# left to the hilum on the left side
# left side of the pulmonary hilum on the left
# leftward to the hilum on the left side
# Loading paraphrases from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-16k-0613_paraphrased_anatomical_locations__part3.jsonl...
# Input:
# peripheral pulmonary vasculature
# Paraphrases:
# peripheral lung vessels
# peripheral pulmonary blood vessels
# lung periphery vasculature
# vasculature of the peripheral lung
# blood vessels in the outer regions of the lung
# pulmonary vessels in the lung periphery
# vascular network in the peripheral lung
# peripheral pulmonary circulation
# blood vessels supplying the outer areas of the lung
# vasculature in the peripheral regions of the lung
# pulmonary vessels in the lung periphery
# vascular system in the outer regions of the lung
# Loading paraphrases from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__single-words.jsonl...
# Input:
# a
# Paraphrases:
# one
# single
# sole
# only
# individual
# lone
# solitary
# unique
# distinct
# singular
# Loading paraphrases from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words__part1.jsonl...
# Input:
# 5 cm
# Paraphrases:
# 5 centimeters
# 5 cm
# 5 centimetres
# 5 cm in size
# a length of 5 cm
# a measurement of 5 cm
# measuring 5 cm
# 5 centimeters in length
# a size of 5 cm
# 5 cm in dimension
# Loading paraphrases from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-16k-0613_paraphrased_observations__two-or-more-words__part2.jsonl...
# Input:
# limited base
# Paraphrases:
# restricted base
# constrained base
# narrowed base
# limited foundation
# restricted support
# constricted base
# reduced base
# diminished base
# restricted bottom
# constrained footing
# Loading paraphrases from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words__part3.jsonl...
# Input:
# not visible
# Paraphrases:
# not visualized
# not seen
# not apparent
# not detectable
# absent
# not present
# unable to visualize
# not observable
# not evident
# not identifiable
# Loading paraphrases from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-16k-0613_paraphrased_observations__two-or-more-words__part4.jsonl...
# Input:
# bowel loops
# Paraphrases:
# intestinal loops
# intestinal segments
# bowel segments
# intestinal coils
# intestinal twists
# intestinal convolutions
# intestinal turns
# intestinal curvatures
# intestinal windings
# intestinal meanders
# Loading paraphrases from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_paraphrased_observations__two-or-more-words_cluster-balanced.jsonl...
# Input:
# 5th rib
# Paraphrases:
# The fifth rib
# Rib number five
# Rib 5
# 5th rib bone
# Bone of the fifth rib
# Fifth rib structure
# Structure of the 5th rib
# 5th costal bone
# Fifth costal bone
# Costal bone number five
# 5th costae
# Costae number five
# Fifth costae structure
# Structure of the 5th costae
# Loading paraphrases from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words_cluster-balanced_1of5.jsonl...
# Input:
# CT 2
# Paraphrases:
# Computed tomography scan
# CT imaging
# CT examination
# CT scan
# CT imaging study
# Computed tomography imaging
# Computed tomography exam
# CT scan procedure
# CT scan test
# CT diagnostic imaging
# CT imaging technique
# CT scan investigation
# CT radiographic study
# Computed tomography imaging procedure
# CT scan evaluation
# Loading paraphrases from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words_cluster-balanced_2of5.jsonl...
# Input:
# line location
# Paraphrases:
# The line is located
# The position of the line is
# The line can be seen
# The line is situated
# The line is found
# The line appears
# The line is detected
# The line is identified
# The line is visible
# The line is present
# The line is observed
# The line is noted
# The line is seen
# The line is evident
# Loading paraphrases from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words_cluster-balanced_3of5.jsonl...
# Input:
# not apparent
# Paraphrases:
# No evidence of
# Not visible
# Not observable
# Not detected
# Not seen
# Not present
# Absence of
# Lack of
# Negative for
# No signs of
# No findings of
# No indications of
# No evidence suggesting
# No abnormalities detected
# Loading paraphrases from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words_cluster-balanced_4of5.jsonl...
# Input:
# CT on
# Paraphrases:
# Computed tomography performed
# CT scan done
# Imaging study using computed tomography
# Radiological examination using CT
# CT imaging conducted
# CT scan taken
# CT imaging performed
# Computed tomography examination
# CT scan carried out
# CT imaging study performed
# CT scan conducted
# Computed tomography study done
# CT imaging examination
# CT scan performed
# Loading paraphrases from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_hard_triplets_from_facts(cluster-balanced,hardest)-part1.jsonl...
# Input:
# no evidence of all-trans retinoic acid syndrome
# Paraphrases:
# no indication of all-trans retinoic acid syndrome
# absence of all-trans retinoic acid syndrome
# no signs of all-trans retinoic acid syndrome
# no presence of all-trans retinoic acid syndrome
# all-trans retinoic acid syndrome not detected
# all-trans retinoic acid syndrome is not observed
# Loading paraphrases from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_hard_triplets_from_facts(cluster-balanced,hardest)-part2.jsonl...
# Input:
# no evidence of significant constriction
# Paraphrases:
# no indication of notable narrowing
# absence of significant constriction
# no signs of substantial narrowing
# no evidence of significant narrowing
# lack of significant constriction
# no presence of notable constriction
# Loading paraphrases from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_hard_triplets_from_facts(cluster-balanced,hardest)-part3.jsonl...
# Input:
# no evidence of wheezing
# Paraphrases:
# no signs of wheezing
# absence of wheezing
# no wheezing detected
# no wheezing observed
# no wheezing present
# no wheezing found
# Number of sentences with paraphrases: 190085
# Number of paraphrases: 2093173
# Loading integrated facts metadata...
# Number of facts: 2829627
# Number of sources: 2
# Number of improved comparisons: 538573/595880
# Category: anatomical finding -> 2047605
# Category: tubes and lines -> 288612
# Category: technical assessment -> 178206
# Category: disease -> 163951
# Category: device -> 145682
# Category: other -> 5571
# Health status: abnormal -> 1718135
# Health status: unknown -> 681307
# Health status: normal -> 277984
# Health status: ambiguous -> 150972
# Health status: other -> 1229
# Comparison status: no comparison -> 1672099
# Comparison status: stable/unchanged -> 296144
# Comparison status: worsened -> 145020
# Comparison status: improved -> 115910
# Comparison status: resolved -> 111802
# Comparison status: new finding -> 102734
# Comparison status: unclear comparison -> 96372
# Comparison status: position changed -> 70304
# Comparison status: increase -> 62671
# Comparison status: decrease -> 40961
# Comparison status: progressed -> 35661
# Comparison status: smaller -> 29576
# Comparison status: larger -> 28278
# Comparison status: reappeared -> 21333
# Comparison status: other -> 762
# Example fact: The previously dilated bowel has exhibited improvement
# Category: anatomical finding
# Health status: abnormal
# Comparison status: improved
# Example fact: compression of the remaining right lung content
# Category: anatomical finding
# Health status: abnormal
# Comparison status: no comparison
# Example fact: consolidated lung shadow
# Category: anatomical finding
# Health status: abnormal
# Comparison status: new finding
# Example fact: The right costophrenic angle shows evidence of small to moderate pleural effusion
# Category: anatomical finding
# Health status: abnormal
# Comparison status: no comparison
# Example fact: small inward collapse
# Category: anatomical finding
# Health status: ambiguous
# Comparison status: position changed
# Example fact: improvement of the atelectasis in the left
# Category: anatomical finding
# Health status: abnormal
# Comparison status: improved
# Example fact: A fracture caused by a disease or abnormality in the bone
# Category: anatomical finding
# Health status: abnormal
# Comparison status: no comparison
# Example fact: consolidation in the lateral right upper lung
# Category: anatomical finding
# Health status: abnormal
# Comparison status: no comparison
# Example fact: increasing patchy opacities in the bilateral lower lobes
# Category: anatomical finding
# Health status: abnormal
# Comparison status: worsened
# Example fact: bibasilar hazy opacities concerning for aspiration
# Category: anatomical finding
# Health status: abnormal
# Comparison status: no comparison
# Comparison status: no comparison
# Number of samples: 1672099
# 	Source: gpt-3.5-turbo-0613
# 		Number of samples: 373949
# 	Source: t5-small-finetuned
# 		Number of samples: 1298150
# 	Weight: 8835.37396061336
# Comparison status: worsened
# Number of samples: 145020
# 	Source: gpt-3.5-turbo-0613
# 		Number of samples: 8360
# 	Source: t5-small-finetuned
# 		Number of samples: 136660
# 	Weight: 5040.577289150058
# Comparison status: resolved
# Number of samples: 111802
# 	Source: gpt-3.5-turbo-0613
# 		Number of samples: 31751
# 	Source: t5-small-finetuned
# 		Number of samples: 80051
# 	Weight: 4716.770555027595
# Comparison status: stable/unchanged
# Number of samples: 296144
# 	Source: gpt-3.5-turbo-0613
# 		Number of samples: 15182
# 	Source: t5-small-finetuned
# 		Number of samples: 280962
# 	Weight: 6004.6900271393515
# Comparison status: progressed
# Number of samples: 35661
# 	Source: gpt-3.5-turbo-0613
# 		Number of samples: 1287
# 	Source: t5-small-finetuned
# 		Number of samples: 34374
# 	Weight: 3458.062441162537
# Comparison status: larger
# Number of samples: 28278
# 	Source: gpt-3.5-turbo-0613
# 		Number of samples: 3635
# 	Source: t5-small-finetuned
# 		Number of samples: 24643
# 	Weight: 3233.5143931132666
# Comparison status: improved
# Number of samples: 115910
# 	Source: gpt-3.5-turbo-0613
# 		Number of samples: 13043
# 	Source: t5-small-finetuned
# 		Number of samples: 102867
# 	Weight: 4760.832266455671
# Comparison status: reappeared
# Number of samples: 21333
# 	Source: gpt-3.5-turbo-0613
# 		Number of samples: 321
# 	Source: t5-small-finetuned
# 		Number of samples: 21012
# 	Weight: 2974.0555116759224
# Comparison status: smaller
# Number of samples: 29576
# 	Source: gpt-3.5-turbo-0613
# 		Number of samples: 1227
# 	Source: t5-small-finetuned
# 		Number of samples: 28349
# 	Weight: 3276.1746389034083
# Comparison status: position changed
# Number of samples: 70304
# 	Source: gpt-3.5-turbo-0613
# 		Number of samples: 644
# 	Source: t5-small-finetuned
# 		Number of samples: 69660
# 	Weight: 4174.306898106601
# Comparison status: new finding
# Number of samples: 102734
# 	Source: gpt-3.5-turbo-0613
# 		Number of samples: 1777
# 	Source: t5-small-finetuned
# 		Number of samples: 100957
# 	Weight: 4614.552302549111
# Comparison status: unclear comparison
# Number of samples: 96372
# 	Source: gpt-3.5-turbo-0613
# 		Number of samples: 1316
# 	Source: t5-small-finetuned
# 		Number of samples: 95056
# 	Weight: 4538.2868333666065
# Comparison status: increase
# Number of samples: 62671
# 	Source: gpt-3.5-turbo-0613
# 		Number of samples: 263
# 	Source: t5-small-finetuned
# 		Number of samples: 62408
# 	Weight: 4046.6713412668914
# Comparison status: decrease
# Number of samples: 40961
# 	Source: gpt-3.5-turbo-0613
# 		Number of samples: 420
# 	Source: t5-small-finetuned
# 		Number of samples: 40541
# 	Weight: 3597.0233304520843
# Comparison status: other
# Number of samples: 762
# 	Source: t5-small-finetuned
# 		Number of samples: 762
# 	Weight: 877.4699568538347
# ----
# Building train chest imagenome observations classification dataset and dataloader...
# Loading integrated chest imagenome observations from /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_chest_imagenome_observations(9).pkl...
# len(phrases): 3462801
# len(label_names): 74
# labels.shape: (3462801, 74)
# Label: lung opacity
# 	Number of idxs: 588071
# 	Weight: 7039.95
# 	Sub-datasets: [(t5-small-finetuned, 291982.00), (chest-imagenome, 286405.00), (gpt-3.5-turbo-0613, 9492.00), (gpt-4-0613, 192.00)]
# Label: pleural effusion
# 	Number of idxs: 270526
# 	Weight: 5876.25
# 	Sub-datasets: [(t5-small-finetuned, 183558.00), (chest-imagenome, 81683.00), (gpt-3.5-turbo-0613, 5191.00), (gpt-4-0613, 94.00)]
# Label: atelectasis
# 	Number of idxs: 178891
# 	Weight: 5312.40
# 	Sub-datasets: [(t5-small-finetuned, 88199.00), (chest-imagenome, 87994.00), (gpt-3.5-turbo-0613, 2653.00), (gpt-4-0613, 45.00)]
# Label: lung lesion
# 	Number of idxs: 168279
# 	Weight: 5232.22
# 	Sub-datasets: [(t5-small-finetuned, 147433.00), (chest-imagenome, 17973.00), (gpt-3.5-turbo-0613, 2798.00), (gpt-4-0613, 75.00)]
# Label: pneumonia
# 	Number of idxs: 133413
# 	Weight: 4935.18
# 	Sub-datasets: [(t5-small-finetuned, 89098.00), (chest-imagenome, 42282.00), (gpt-3.5-turbo-0613, 1949.00), (gpt-4-0613, 84.00)]
# Label: airspace opacity
# 	Number of idxs: 126491
# 	Weight: 4868.64
# 	Sub-datasets: [(t5-small-finetuned, 115908.00), (chest-imagenome, 9387.00), (gpt-3.5-turbo-0613, 1174.00), (gpt-4-0613, 22.00)]
# Label: consolidation
# 	Number of idxs: 120940
# 	Weight: 4813.05
# 	Sub-datasets: [(t5-small-finetuned, 97762.00), (chest-imagenome, 20613.00), (gpt-3.5-turbo-0613, 2540.00), (gpt-4-0613, 25.00)]
# Label: pulmonary edema/hazy opacity
# 	Number of idxs: 109715
# 	Weight: 4693.87
# 	Sub-datasets: [(t5-small-finetuned, 67972.00), (chest-imagenome, 40115.00), (gpt-3.5-turbo-0613, 1567.00), (gpt-4-0613, 61.00)]
# Label: mass/nodule (not otherwise specified)
# 	Number of idxs: 108657
# 	Weight: 4682.12
# 	Sub-datasets: [(t5-small-finetuned, 96494.00), (chest-imagenome, 10296.00), (gpt-3.5-turbo-0613, 1812.00), (gpt-4-0613, 55.00)]
# Label: enteric tube
# 	Number of idxs: 108021
# 	Weight: 4675.02
# 	Sub-datasets: [(t5-small-finetuned, 82792.00), (chest-imagenome, 23240.00), (gpt-3.5-turbo-0613, 1875.00), (gpt-4-0613, 114.00)]
# Label: increased reticular markings/ild pattern
# 	Number of idxs: 100126
# 	Weight: 4583.77
# 	Sub-datasets: [(t5-small-finetuned, 96814.00), (chest-imagenome, 1728.00), (gpt-3.5-turbo-0613, 1560.00), (gpt-4-0613, 24.00)]
# Label: ij line
# 	Number of idxs: 95012
# 	Weight: 4521.45
# 	Sub-datasets: [(t5-small-finetuned, 84277.00), (chest-imagenome, 8992.00), (gpt-3.5-turbo-0613, 1695.00), (gpt-4-0613, 48.00)]
# Label: vascular congestion
# 	Number of idxs: 94906
# 	Weight: 4520.13
# 	Sub-datasets: [(t5-small-finetuned, 70730.00), (chest-imagenome, 22801.00), (gpt-3.5-turbo-0613, 1348.00), (gpt-4-0613, 27.00)]
# Label: enlarged cardiac silhouette
# 	Number of idxs: 85028
# 	Weight: 4391.33
# 	Sub-datasets: [(t5-small-finetuned, 51304.00), (chest-imagenome, 32665.00), (gpt-3.5-turbo-0613, 1033.00), (gpt-4-0613, 26.00)]
# Label: pleural/parenchymal scarring
# 	Number of idxs: 75175
# 	Weight: 4249.93
# 	Sub-datasets: [(t5-small-finetuned, 58143.00), (chest-imagenome, 15563.00), (gpt-3.5-turbo-0613, 1431.00), (gpt-4-0613, 38.00)]
# Label: infiltration
# 	Number of idxs: 73266
# 	Weight: 4220.78
# 	Sub-datasets: [(t5-small-finetuned, 68627.00), (chest-imagenome, 3460.00), (gpt-3.5-turbo-0613, 1149.00), (gpt-4-0613, 30.00)]
# Label: endotracheal tube
# 	Number of idxs: 73212
# 	Weight: 4219.95
# 	Sub-datasets: [(t5-small-finetuned, 52977.00), (chest-imagenome, 18994.00), (gpt-3.5-turbo-0613, 1159.00), (gpt-4-0613, 82.00)]
# Label: picc
# 	Number of idxs: 72349
# 	Weight: 4206.56
# 	Sub-datasets: [(t5-small-finetuned, 59562.00), (chest-imagenome, 11375.00), (gpt-3.5-turbo-0613, 1357.00), (gpt-4-0613, 55.00)]
# Label: cardiac pacer and wires
# 	Number of idxs: 71225
# 	Weight: 4188.93
# 	Sub-datasets: [(t5-small-finetuned, 59149.00), (chest-imagenome, 10754.00), (gpt-3.5-turbo-0613, 1265.00), (gpt-4-0613, 57.00)]
# Label: rib fracture
# 	Number of idxs: 68569
# 	Weight: 4146.33
# 	Sub-datasets: [(t5-small-finetuned, 60071.00), (chest-imagenome, 6984.00), (gpt-3.5-turbo-0613, 1445.00), (gpt-4-0613, 69.00)]
# Label: pneumothorax
# 	Number of idxs: 68103
# 	Weight: 4138.72
# 	Sub-datasets: [(t5-small-finetuned, 53208.00), (chest-imagenome, 13285.00), (gpt-3.5-turbo-0613, 1559.00), (gpt-4-0613, 51.00)]
# Label: mediastinal widening
# 	Number of idxs: 63696
# 	Weight: 4064.53
# 	Sub-datasets: [(t5-small-finetuned, 57715.00), (chest-imagenome, 4859.00), (gpt-3.5-turbo-0613, 1108.00), (gpt-4-0613, 14.00)]
# Label: artifact
# 	Number of idxs: 62070
# 	Weight: 4036.09
# 	Sub-datasets: [(t5-small-finetuned, 60987.00), (gpt-3.5-turbo-0613, 567.00), (chest-imagenome, 486.00), (gpt-4-0613, 30.00)]
# Label: lobar/segmental collapse
# 	Number of idxs: 60370
# 	Weight: 4005.70
# 	Sub-datasets: [(t5-small-finetuned, 48794.00), (chest-imagenome, 10554.00), (gpt-3.5-turbo-0613, 1005.00), (gpt-4-0613, 17.00)]
# Label: chest tube
# 	Number of idxs: 58194
# 	Weight: 3965.76
# 	Sub-datasets: [(t5-small-finetuned, 47496.00), (chest-imagenome, 9523.00), (gpt-3.5-turbo-0613, 1133.00), (gpt-4-0613, 42.00)]
# Label: sub-diaphragmatic air
# 	Number of idxs: 51974
# 	Weight: 3844.44
# 	Sub-datasets: [(t5-small-finetuned, 49591.00), (chest-imagenome, 1569.00), (gpt-3.5-turbo-0613, 804.00), (gpt-4-0613, 10.00)]
# Label: subclavian line
# 	Number of idxs: 49016
# 	Weight: 3782.54
# 	Sub-datasets: [(t5-small-finetuned, 45312.00), (chest-imagenome, 2907.00), (gpt-3.5-turbo-0613, 797.00)]
# Label: enlarged hilum
# 	Number of idxs: 47903
# 	Weight: 3758.45
# 	Sub-datasets: [(t5-small-finetuned, 37127.00), (chest-imagenome, 9915.00), (gpt-3.5-turbo-0613, 833.00), (gpt-4-0613, 28.00)]
# Label: hyperaeration
# 	Number of idxs: 45517
# 	Weight: 3705.25
# 	Sub-datasets: [(t5-small-finetuned, 38156.00), (chest-imagenome, 6728.00), (gpt-3.5-turbo-0613, 633.00)]
# Label: linear/patchy atelectasis
# 	Number of idxs: 44585
# 	Weight: 3683.85
# 	Sub-datasets: [(t5-small-finetuned, 32887.00), (chest-imagenome, 11073.00), (gpt-3.5-turbo-0613, 625.00)]
# Label: interstitial lung disease
# 	Number of idxs: 42142
# 	Weight: 3625.98
# 	Sub-datasets: [(t5-small-finetuned, 38697.00), (chest-imagenome, 2510.00), (gpt-3.5-turbo-0613, 902.00), (gpt-4-0613, 33.00)]
# Label: subcutaneous air
# 	Number of idxs: 39092
# 	Weight: 3549.78
# 	Sub-datasets: [(t5-small-finetuned, 34777.00), (chest-imagenome, 3502.00), (gpt-3.5-turbo-0613, 793.00), (gpt-4-0613, 20.00)]
# Label: vascular calcification
# 	Number of idxs: 38130
# 	Weight: 3524.74
# 	Sub-datasets: [(t5-small-finetuned, 32240.00), (chest-imagenome, 5088.00), (gpt-3.5-turbo-0613, 770.00), (gpt-4-0613, 32.00)]
# Label: spinal fracture
# 	Number of idxs: 37418
# 	Weight: 3505.88
# 	Sub-datasets: [(t5-small-finetuned, 33415.00), (chest-imagenome, 3542.00), (gpt-3.5-turbo-0613, 444.00), (gpt-4-0613, 17.00)]
# Label: low lung volumes
# 	Number of idxs: 36300
# 	Weight: 3475.67
# 	Sub-datasets: [(t5-small-finetuned, 18106.00), (chest-imagenome, 17780.00), (gpt-3.5-turbo-0613, 403.00), (gpt-4-0613, 11.00)]
# Label: chest port
# 	Number of idxs: 36235
# 	Weight: 3473.89
# 	Sub-datasets: [(t5-small-finetuned, 29925.00), (chest-imagenome, 5519.00), (gpt-3.5-turbo-0613, 756.00), (gpt-4-0613, 35.00)]
# Label: aspiration
# 	Number of idxs: 33964
# 	Weight: 3410.03
# 	Sub-datasets: [(t5-small-finetuned, 22482.00), (chest-imagenome, 10910.00), (gpt-3.5-turbo-0613, 552.00), (gpt-4-0613, 20.00)]
# Label: costophrenic angle blunting
# 	Number of idxs: 32080
# 	Weight: 3354.38
# 	Sub-datasets: [(t5-small-finetuned, 25891.00), (chest-imagenome, 5642.00), (gpt-3.5-turbo-0613, 531.00), (gpt-4-0613, 16.00)]
# Label: mediastinal displacement
# 	Number of idxs: 31796
# 	Weight: 3345.76
# 	Sub-datasets: [(t5-small-finetuned, 27301.00), (chest-imagenome, 3864.00), (gpt-3.5-turbo-0613, 603.00), (gpt-4-0613, 28.00)]
# Label: bone lesion
# 	Number of idxs: 29957
# 	Weight: 3288.41
# 	Sub-datasets: [(t5-small-finetuned, 27222.00), (chest-imagenome, 2096.00), (gpt-3.5-turbo-0613, 639.00)]
# Label: spinal degenerative changes
# 	Number of idxs: 28662
# 	Weight: 3246.30
# 	Sub-datasets: [(t5-small-finetuned, 24834.00), (chest-imagenome, 3370.00), (gpt-3.5-turbo-0613, 443.00), (gpt-4-0613, 15.00)]
# Label: swan-ganz catheter
# 	Number of idxs: 27164
# 	Weight: 3195.63
# 	Sub-datasets: [(t5-small-finetuned, 24748.00), (chest-imagenome, 2007.00), (gpt-3.5-turbo-0613, 386.00), (gpt-4-0613, 23.00)]
# Label: vascular redistribution
# 	Number of idxs: 25856
# 	Weight: 3149.51
# 	Sub-datasets: [(t5-small-finetuned, 22691.00), (chest-imagenome, 2765.00), (gpt-3.5-turbo-0613, 400.00)]
# Label: fluid overload/heart failure
# 	Number of idxs: 24827
# 	Weight: 3111.89
# 	Sub-datasets: [(t5-small-finetuned, 18765.00), (chest-imagenome, 5621.00), (gpt-3.5-turbo-0613, 404.00), (gpt-4-0613, 37.00)]
# Label: bronchiectasis
# 	Number of idxs: 24721
# 	Weight: 3107.95
# 	Sub-datasets: [(t5-small-finetuned, 23174.00), (chest-imagenome, 1160.00), (gpt-3.5-turbo-0613, 377.00), (gpt-4-0613, 10.00)]
# Label: pigtail catheter
# 	Number of idxs: 23163
# 	Weight: 3048.33
# 	Sub-datasets: [(t5-small-finetuned, 19248.00), (chest-imagenome, 3446.00), (gpt-3.5-turbo-0613, 469.00)]
# Label: calcified nodule
# 	Number of idxs: 23009
# 	Weight: 3042.27
# 	Sub-datasets: [(t5-small-finetuned, 19828.00), (chest-imagenome, 2728.00), (gpt-3.5-turbo-0613, 435.00), (gpt-4-0613, 18.00)]
# Label: tortuous aorta
# 	Number of idxs: 22484
# 	Weight: 3021.34
# 	Sub-datasets: [(t5-small-finetuned, 16574.00), (chest-imagenome, 5622.00), (gpt-3.5-turbo-0613, 274.00), (gpt-4-0613, 14.00)]
# Label: superior mediastinal mass/enlargement
# 	Number of idxs: 20637
# 	Weight: 2944.46
# 	Sub-datasets: [(t5-small-finetuned, 16756.00), (chest-imagenome, 3559.00), (gpt-3.5-turbo-0613, 322.00)]
# Label: tracheostomy tube
# 	Number of idxs: 19723
# 	Weight: 2904.37
# 	Sub-datasets: [(t5-small-finetuned, 16638.00), (chest-imagenome, 2793.00), (gpt-3.5-turbo-0613, 270.00), (gpt-4-0613, 22.00)]
# Label: mediastinal drain
# 	Number of idxs: 19398
# 	Weight: 2889.76
# 	Sub-datasets: [(t5-small-finetuned, 18746.00), (chest-imagenome, 400.00), (gpt-3.5-turbo-0613, 252.00)]
# Label: aortic graft/repair
# 	Number of idxs: 19318
# 	Weight: 2886.13
# 	Sub-datasets: [(t5-small-finetuned, 18937.00), (gpt-3.5-turbo-0613, 266.00), (chest-imagenome, 115.00)]
# Label: elevated hemidiaphragm
# 	Number of idxs: 18894
# 	Weight: 2866.70
# 	Sub-datasets: [(t5-small-finetuned, 13155.00), (chest-imagenome, 5345.00), (gpt-3.5-turbo-0613, 372.00), (gpt-4-0613, 22.00)]
# Label: copd/emphysema
# 	Number of idxs: 17414
# 	Weight: 2796.05
# 	Sub-datasets: [(t5-small-finetuned, 10856.00), (chest-imagenome, 6264.00), (gpt-3.5-turbo-0613, 281.00), (gpt-4-0613, 13.00)]
# Label: clavicle fracture
# 	Number of idxs: 16925
# 	Weight: 2771.65
# 	Sub-datasets: [(t5-small-finetuned, 15689.00), (chest-imagenome, 905.00), (gpt-3.5-turbo-0613, 312.00), (gpt-4-0613, 19.00)]
# Label: hernia
# 	Number of idxs: 16471
# 	Weight: 2748.50
# 	Sub-datasets: [(t5-small-finetuned, 13157.00), (chest-imagenome, 2922.00), (gpt-3.5-turbo-0613, 365.00), (gpt-4-0613, 27.00)]
# Label: lung cancer
# 	Number of idxs: 16365
# 	Weight: 2743.02
# 	Sub-datasets: [(t5-small-finetuned, 14018.00), (chest-imagenome, 2148.00), (gpt-3.5-turbo-0613, 187.00), (gpt-4-0613, 12.00)]
# Label: shoulder osteoarthritis
# 	Number of idxs: 15168
# 	Weight: 2679.10
# 	Sub-datasets: [(t5-small-finetuned, 13182.00), (chest-imagenome, 1805.00), (gpt-3.5-turbo-0613, 167.00), (gpt-4-0613, 14.00)]
# Label: alveolar hemorrhage
# 	Number of idxs: 14365
# 	Weight: 2633.94
# 	Sub-datasets: [(t5-small-finetuned, 12104.00), (chest-imagenome, 2054.00), (gpt-3.5-turbo-0613, 207.00)]
# Label: granulomatous disease
# 	Number of idxs: 14354
# 	Weight: 2633.31
# 	Sub-datasets: [(t5-small-finetuned, 11640.00), (chest-imagenome, 2458.00), (gpt-3.5-turbo-0613, 237.00), (gpt-4-0613, 19.00)]
# Label: prosthetic valve
# 	Number of idxs: 12190
# 	Weight: 2500.73
# 	Sub-datasets: [(t5-small-finetuned, 9916.00), (chest-imagenome, 2079.00), (gpt-3.5-turbo-0613, 172.00), (gpt-4-0613, 23.00)]
# Label: intra-aortic balloon pump
# 	Number of idxs: 11723
# 	Weight: 2469.71
# 	Sub-datasets: [(t5-small-finetuned, 10936.00), (chest-imagenome, 630.00), (gpt-3.5-turbo-0613, 157.00)]
# Label: scoliosis
# 	Number of idxs: 11366
# 	Weight: 2445.34
# 	Sub-datasets: [(t5-small-finetuned, 8601.00), (chest-imagenome, 2467.00), (gpt-3.5-turbo-0613, 275.00), (gpt-4-0613, 23.00)]
# Label: cyst/bullae
# 	Number of idxs: 11118
# 	Weight: 2428.05
# 	Sub-datasets: [(t5-small-finetuned, 9962.00), (chest-imagenome, 972.00), (gpt-3.5-turbo-0613, 168.00), (gpt-4-0613, 16.00)]
# Label: multiple masses/nodules
# 	Number of idxs: 10852
# 	Weight: 2409.16
# 	Sub-datasets: [(t5-small-finetuned, 6159.00), (chest-imagenome, 4574.00), (gpt-3.5-turbo-0613, 106.00), (gpt-4-0613, 13.00)]
# Label: diaphragmatic eventration (benign)
# 	Number of idxs: 10148
# 	Weight: 2357.37
# 	Sub-datasets: [(t5-small-finetuned, 9928.00), (gpt-3.5-turbo-0613, 156.00), (chest-imagenome, 64.00)]
# Label: rotated
# 	Number of idxs: 9525
# 	Weight: 2309.13
# 	Sub-datasets: [(t5-small-finetuned, 7422.00), (chest-imagenome, 1955.00), (gpt-3.5-turbo-0613, 148.00)]
# Label: breast/nipple shadows
# 	Number of idxs: 9279
# 	Weight: 2289.40
# 	Sub-datasets: [(t5-small-finetuned, 7911.00), (chest-imagenome, 1173.00), (gpt-3.5-turbo-0613, 195.00)]
# Label: pericardial effusion
# 	Number of idxs: 9064
# 	Weight: 2271.82
# 	Sub-datasets: [(t5-small-finetuned, 7384.00), (chest-imagenome, 1528.00), (gpt-3.5-turbo-0613, 152.00)]
# Label: hydropneumothorax
# 	Number of idxs: 7550
# 	Weight: 2137.85
# 	Sub-datasets: [(t5-small-finetuned, 6166.00), (chest-imagenome, 1235.00), (gpt-3.5-turbo-0613, 139.00), (gpt-4-0613, 10.00)]
# Label: cabg grafts
# 	Number of idxs: 6906
# 	Weight: 2074.44
# 	Sub-datasets: [(t5-small-finetuned, 5032.00), (chest-imagenome, 1784.00), (gpt-3.5-turbo-0613, 90.00)]
# Label: goiter
# 	Number of idxs: 6208
# 	Weight: 2000.33
# 	Sub-datasets: [(t5-small-finetuned, 5402.00), (chest-imagenome, 695.00), (gpt-3.5-turbo-0613, 111.00)]
# Label: pneumomediastinum
# 	Number of idxs: 5481
# 	Weight: 1915.97
# 	Sub-datasets: [(t5-small-finetuned, 4266.00), (chest-imagenome, 1070.00), (gpt-3.5-turbo-0613, 145.00)]
# Label: skin fold
# 	Number of idxs: 3747
# 	Weight: 1673.09
# 	Sub-datasets: [(t5-small-finetuned, 3483.00), (chest-imagenome, 206.00), (gpt-3.5-turbo-0613, 58.00)]
# Label: "omitted"
# 	Number of idxs: 524915
# 	Weight: 6860.867585411526
# 	Sub-datasets: [(chest-imagenome, 87959.00), (t5-small-finetuned, 404598.00), (gpt-4-0613, 3070.00), (gpt-3.5-turbo-0613, 29288.00)]
# ----
# Building train chest imagenome anatomical_locations classification dataset and dataloader...
# Loading integrated chest imagenome anatomical_locations from /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_chest_imagenome_anatomical_locations(5).pkl...
# len(phrases): 3227289
# len(label_names): 38
# labels.shape: (3227289, 38)
# Label: right lower lung zone
# 	Number of idxs: 555020
# 	Weight: 6948.39
# 	Sub-datasets: [(t5-small-finetuned, 456357.00), (chest-imagenome, 90875.00), (gpt-3.5-turbo-0613, 7788.00)]
# Label: left lower lung zone
# 	Number of idxs: 546955
# 	Weight: 6925.34
# 	Sub-datasets: [(t5-small-finetuned, 439935.00), (chest-imagenome, 99703.00), (gpt-3.5-turbo-0613, 7317.00)]
# Label: left lung
# 	Number of idxs: 520158
# 	Weight: 6846.65
# 	Sub-datasets: [(chest-imagenome, 311503.00), (t5-small-finetuned, 202509.00), (gpt-3.5-turbo-0613, 6146.00)]
# Label: right lung
# 	Number of idxs: 513047
# 	Weight: 6825.19
# 	Sub-datasets: [(chest-imagenome, 312822.00), (t5-small-finetuned, 193968.00), (gpt-3.5-turbo-0613, 6257.00)]
# Label: mediastinum
# 	Number of idxs: 264770
# 	Weight: 5845.99
# 	Sub-datasets: [(t5-small-finetuned, 147604.00), (chest-imagenome, 112213.00), (gpt-3.5-turbo-0613, 4953.00)]
# Label: abdomen
# 	Number of idxs: 220127
# 	Weight: 5590.45
# 	Sub-datasets: [(t5-small-finetuned, 181031.00), (chest-imagenome, 32488.00), (gpt-3.5-turbo-0613, 6608.00)]
# Label: left chest wall
# 	Number of idxs: 219729
# 	Weight: 5587.98
# 	Sub-datasets: [(t5-small-finetuned, 199455.00), (chest-imagenome, 16271.00), (gpt-3.5-turbo-0613, 4003.00)]
# Label: right costophrenic angle
# 	Number of idxs: 210906
# 	Weight: 5532.31
# 	Sub-datasets: [(t5-small-finetuned, 133502.00), (chest-imagenome, 75688.00), (gpt-3.5-turbo-0613, 1716.00)]
# Label: right chest wall
# 	Number of idxs: 207195
# 	Weight: 5508.31
# 	Sub-datasets: [(t5-small-finetuned, 185188.00), (chest-imagenome, 18506.00), (gpt-3.5-turbo-0613, 3501.00)]
# Label: left costophrenic angle
# 	Number of idxs: 205253
# 	Weight: 5495.61
# 	Sub-datasets: [(t5-small-finetuned, 126179.00), (chest-imagenome, 77243.00), (gpt-3.5-turbo-0613, 1831.00)]
# Label: right hilar structures
# 	Number of idxs: 179787
# 	Weight: 5318.99
# 	Sub-datasets: [(chest-imagenome, 95325.00), (t5-small-finetuned, 83052.00), (gpt-3.5-turbo-0613, 1410.00)]
# Label: cardiac silhouette
# 	Number of idxs: 174409
# 	Weight: 5279.04
# 	Sub-datasets: [(t5-small-finetuned, 88313.00), (chest-imagenome, 83912.00), (gpt-3.5-turbo-0613, 2184.00)]
# Label: left hilar structures
# 	Number of idxs: 165061
# 	Weight: 5207.08
# 	Sub-datasets: [(chest-imagenome, 91729.00), (t5-small-finetuned, 72153.00), (gpt-3.5-turbo-0613, 1179.00)]
# Label: right upper lung zone
# 	Number of idxs: 149500
# 	Weight: 5079.39
# 	Sub-datasets: [(t5-small-finetuned, 130531.00), (chest-imagenome, 16434.00), (gpt-3.5-turbo-0613, 2535.00)]
# Label: spine
# 	Number of idxs: 131820
# 	Weight: 4920.12
# 	Sub-datasets: [(t5-small-finetuned, 114383.00), (chest-imagenome, 13474.00), (gpt-3.5-turbo-0613, 3963.00)]
# Label: right mid lung zone
# 	Number of idxs: 128412
# 	Weight: 4887.40
# 	Sub-datasets: [(t5-small-finetuned, 93987.00), (chest-imagenome, 32995.00), (gpt-3.5-turbo-0613, 1430.00)]
# Label: left upper lung zone
# 	Number of idxs: 124803
# 	Weight: 4851.95
# 	Sub-datasets: [(t5-small-finetuned, 110460.00), (chest-imagenome, 12425.00), (gpt-3.5-turbo-0613, 1918.00)]
# Label: left hemidiaphragm
# 	Number of idxs: 115401
# 	Weight: 4755.44
# 	Sub-datasets: [(t5-small-finetuned, 98769.00), (chest-imagenome, 14677.00), (gpt-3.5-turbo-0613, 1955.00)]
# Label: neck
# 	Number of idxs: 113526
# 	Weight: 4735.42
# 	Sub-datasets: [(chest-imagenome, 56152.00), (t5-small-finetuned, 55461.00), (gpt-3.5-turbo-0613, 1913.00)]
# Label: right hemidiaphragm
# 	Number of idxs: 111896
# 	Weight: 4717.79
# 	Sub-datasets: [(t5-small-finetuned, 96585.00), (chest-imagenome, 13788.00), (gpt-3.5-turbo-0613, 1523.00)]
# Label: left mid lung zone
# 	Number of idxs: 110606
# 	Weight: 4703.69
# 	Sub-datasets: [(t5-small-finetuned, 77120.00), (chest-imagenome, 32437.00), (gpt-3.5-turbo-0613, 1049.00)]
# Label: trachea
# 	Number of idxs: 98922
# 	Weight: 4569.34
# 	Sub-datasets: [(t5-small-finetuned, 70770.00), (chest-imagenome, 25717.00), (gpt-3.5-turbo-0613, 2435.00)]
# Label: svc
# 	Number of idxs: 82520
# 	Weight: 4356.67
# 	Sub-datasets: [(t5-small-finetuned, 67536.00), (chest-imagenome, 13556.00), (gpt-3.5-turbo-0613, 1428.00)]
# Label: right atrium
# 	Number of idxs: 78614
# 	Weight: 4300.92
# 	Sub-datasets: [(t5-small-finetuned, 69714.00), (chest-imagenome, 7547.00), (gpt-3.5-turbo-0613, 1353.00)]
# Label: aortic arch
# 	Number of idxs: 74185
# 	Weight: 4234.89
# 	Sub-datasets: [(t5-small-finetuned, 60626.00), (chest-imagenome, 12102.00), (gpt-3.5-turbo-0613, 1457.00)]
# Label: left apical zone
# 	Number of idxs: 61159
# 	Weight: 4019.89
# 	Sub-datasets: [(t5-small-finetuned, 48307.00), (chest-imagenome, 11994.00), (gpt-3.5-turbo-0613, 858.00)]
# Label: right apical zone
# 	Number of idxs: 59713
# 	Weight: 3993.76
# 	Sub-datasets: [(t5-small-finetuned, 44678.00), (chest-imagenome, 14074.00), (gpt-3.5-turbo-0613, 961.00)]
# Label: upper mediastinum
# 	Number of idxs: 58396
# 	Weight: 3969.52
# 	Sub-datasets: [(t5-small-finetuned, 31466.00), (chest-imagenome, 26127.00), (gpt-3.5-turbo-0613, 803.00)]
# Label: left arm
# 	Number of idxs: 54148
# 	Weight: 3888.13
# 	Sub-datasets: [(t5-small-finetuned, 52244.00), (gpt-3.5-turbo-0613, 987.00), (chest-imagenome, 917.00)]
# Label: carina
# 	Number of idxs: 52013
# 	Weight: 3845.24
# 	Sub-datasets: [(t5-small-finetuned, 38457.00), (chest-imagenome, 12361.00), (gpt-3.5-turbo-0613, 1195.00)]
# Label: right arm
# 	Number of idxs: 49507
# 	Weight: 3793.02
# 	Sub-datasets: [(t5-small-finetuned, 47507.00), (chest-imagenome, 1065.00), (gpt-3.5-turbo-0613, 935.00)]
# Label: left clavicle
# 	Number of idxs: 48398
# 	Weight: 3769.22
# 	Sub-datasets: [(t5-small-finetuned, 39527.00), (chest-imagenome, 8330.00), (gpt-3.5-turbo-0613, 541.00)]
# Label: right clavicle
# 	Number of idxs: 39797
# 	Weight: 3567.81
# 	Sub-datasets: [(t5-small-finetuned, 30385.00), (chest-imagenome, 8869.00), (gpt-3.5-turbo-0613, 543.00)]
# Label: cavoatrial junction
# 	Number of idxs: 35863
# 	Weight: 3463.66
# 	Sub-datasets: [(t5-small-finetuned, 31536.00), (chest-imagenome, 3807.00), (gpt-3.5-turbo-0613, 520.00)]
# Label: left shoulder
# 	Number of idxs: 26094
# 	Weight: 3158.04
# 	Sub-datasets: [(t5-small-finetuned, 18216.00), (chest-imagenome, 7340.00), (gpt-3.5-turbo-0613, 538.00)]
# Label: left breast
# 	Number of idxs: 25532
# 	Weight: 3137.80
# 	Sub-datasets: [(t5-small-finetuned, 24231.00), (chest-imagenome, 886.00), (gpt-3.5-turbo-0613, 415.00)]
# Label: right shoulder
# 	Number of idxs: 23347
# 	Weight: 3055.54
# 	Sub-datasets: [(t5-small-finetuned, 11918.00), (chest-imagenome, 10887.00), (gpt-3.5-turbo-0613, 542.00)]
# Label: right breast
# 	Number of idxs: 14892
# 	Weight: 2663.80
# 	Sub-datasets: [(t5-small-finetuned, 13666.00), (chest-imagenome, 945.00), (gpt-3.5-turbo-0613, 281.00)]
# Label: "omitted"
# 	Number of idxs: 449397
# 	Weight: 6620.981877988595
# 	Sub-datasets: [(chest-imagenome, 262.00), (t5-small-finetuned, 433804.00), (gpt-3.5-turbo-0613, 15331.00)]
# ----
# Number of RadNLI samples: 480
# Number of MS_CXR_T samples: 361
# Number of total samples: 841
# ----
# Building val NLI dataset and dataloader...
# ----
# Building val entailment/contradiction dataset and dataloader...
# EntailmentContradictionDataset: __init__
# Number of entailment samples: 243
# Number of contradiction samples: 318
# Example entailment/contradiction samples:
# {'ent_p': 'The extensive bilateral parenchymal opacities are unchanged in extent and severity.', 'ent_h': 'The extensive bilateral parenchymal opacities are constant in extent and severity.', 'con_p': 'Cardiomediastinal and hilar contours are unremarkable with the exception of a tortuous aorta.', 'con_h': 'PA and lateral chest radiographs demonstrate a normal cardiomediastinal silhouette.'}
# {'ent_p': 'No pleural effusion or pneumothorax is seen.', 'ent_h': 'There is no pleural effusion', 'con_p': 'PA and lateral chest radiographs demonstrate a normal cardiomediastinal silhouette.', 'con_h': 'Cardiomediastinal and hilar contours are unremarkable with the exception of a tortuous aorta.'}
# {'ent_p': 'Allowing for this, the lungs are clear.', 'ent_h': 'The lungs are clear.', 'con_p': 'Known small left pneumothorax is not well seen.', 'con_h': 'No pneumothorax.'}
# {'ent_p': 'There is no effusion.', 'ent_h': 'There is no pleural effusion.', 'con_p': 'No pneumothorax.', 'con_h': 'Known small left pneumothorax is not well seen.'}
# ----
# Loading integrated NLI from /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(265719,34150895).jsonl...
# Number of samples: 265719
# Loading integrated sentence facts from /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_sentence_facts(58655550,50990861).jsonl...
# Number of integrated sentence facts: 677694
# Number of entailment samples added: 1309458
# ----
# Building train NLI dataset and dataloader...
# Source: 0 | Label: 0 -> 13185 (2563.82)
# Source: 1 | Label: 0 -> 35146 (3443.68)
# Source: 2 | Label: 0 -> 1770 (1256.05)
# Source: 3 | Label: 0 -> 3744 (1672.60)
# Source: 4 | Label: 0 -> 465 (695.76)
# Source: 5 | Label: 0 -> 473 (701.58)
# Source: 6 | Label: 0 -> 93 (279.62)
# Source: 7 | Label: 0 -> 1309458 (8390.84)
# Source: 0 | Label: 1 -> 19123 (2877.24)
# Source: 1 | Label: 1 -> 47440 (3748.30)
# Source: 2 | Label: 1 -> 3968 (1708.29)
# Source: 3 | Label: 1 -> 3743 (1672.44)
# Source: 4 | Label: 1 -> 465 (695.76)
# Source: 5 | Label: 1 -> 474 (702.30)
# Source: 6 | Label: 1 -> 281 (538.25)
# Source: 0 | Label: 2 -> 79430 (4312.76)
# Source: 1 | Label: 2 -> 46960 (3737.69)
# Source: 2 | Label: 2 -> 4170 (1739.18)
# Source: 3 | Label: 2 -> 3744 (1672.60)
# Source: 4 | Label: 2 -> 465 (695.76)
# Source: 5 | Label: 2 -> 474 (702.30)
# Source: 6 | Label: 2 -> 106 (304.54)
# NLI dataset examples:
# Example 0:
# Premise: Right supraclavicular central venous line ends at the origin of the SVC.
# Hypothesis: right supraclavicular central venous line ends at the origin of the SVC
# Label: 0
# Example 1:
# Premise: Suggestion of panacinar emphysema in the lung bases due to alpha one antitrypsin deficiency
# Hypothesis: left upper lobe opacity inconsistent with pneumonia
# Label: 1
# Example 2:
# Premise: Right IJ tip in the right atrium.
# Hypothesis: Right IJ tip is in the right ventricle.
# Label: 2
# Example 3:
# Premise: The alignment of the sternal wires, the valvular replacement and the right internal jugular vein catheter are in correct position.
# Hypothesis: Status post mitral valve replacement with intact sternotomy wires.
# Label: 0
# Example 4:
# Premise: Blunting of the left costophrenic angle on the lateral view is compatible with a small pleural effusion, seen on the prior CT. No pneumothorax is identified.
# Hypothesis: There is no evidence of a lung mass in the current X-ray.
# Label: 1
# ----
# Building train entailment/contradiction dataset and dataloader...
# EntailmentContradictionDataset: __init__
# Number of entailment samples: 13185
# Number of contradiction samples: 135349
# Source: 0 -> (len(ent_premises), len(cont_premises)): (13185, 135349)
# EntailmentContradictionDataset: __init__
# Number of entailment samples: 35146
# Number of contradiction samples: 135349
# Source: 1 -> (len(ent_premises), len(cont_premises)): (35146, 135349)
# EntailmentContradictionDataset: __init__
# Number of entailment samples: 1770
# Number of contradiction samples: 135349
# Source: 2 -> (len(ent_premises), len(cont_premises)): (1770, 135349)
# EntailmentContradictionDataset: __init__
# Number of entailment samples: 3744
# Number of contradiction samples: 135349
# Source: 3 -> (len(ent_premises), len(cont_premises)): (3744, 135349)
# EntailmentContradictionDataset: __init__
# Number of entailment samples: 465
# Number of contradiction samples: 135349
# Source: 4 -> (len(ent_premises), len(cont_premises)): (465, 135349)
# EntailmentContradictionDataset: __init__
# Number of entailment samples: 473
# Number of contradiction samples: 135349
# Source: 5 -> (len(ent_premises), len(cont_premises)): (473, 135349)
# EntailmentContradictionDataset: __init__
# ...
# 2025-06-11 01:50:32,090 - INFO - medvqa.training.utils - (2) Validation stage ...
# 2025-06-11 01:50:32,091 - INFO - ignite.engine.engine.Engine - Engine run starting with max_epochs=1.
# Validation: [93/93] 100%|███████████ [00:07<00:00]
# 2025-06-11 01:50:39,850 - INFO - medvqa.utils.handlers_utils - tacc(al0) 0.99300, tacc(al1) 0.98500, tacc(al2) 0.91100, tacc(ob0) 0.99300, tacc(ob1) 0.99100, tacc(ob2) 0.95000, tacc(ob3) 0.99200, tacc(ob4) 0.98600, tacc(ob5) 0.91300, tacc(ob6) 0.96600, tacc(ob7) 0.95500, tacc(ob8) 0.98200, nli_acc 0.85256, entcon_acc 0.97170, sae_loss 1.36703, 7.76 secs
# 2025-06-11 01:50:39,850 - INFO - ignite.engine.engine.Engine - Epoch[1] Complete. Time taken: 00:00:07.760
# 2025-06-11 01:50:39,850 - INFO - ignite.engine.engine.Engine - Engine run complete. Time taken: 00:00:07.760
# 2025-06-11 01:50:39,851 - INFO - ignite.engine.engine.Engine - Epoch[162] Complete. Time taken: 00:01:31.313
# 2025-06-11 01:50:39,851 - INFO - medvqa.utils.handlers_utils - ==================== Epoch 163/200 ====================
# 2025-06-11 01:50:39,851 - INFO - medvqa.training.utils - (1) Training stage (lr = 0.000013) ...
# Training [163/200]: [800/800] 100%|██████████, loss=2.45 [01:03<00:00]
# 2025-06-11 01:51:43,847 - INFO - medvqa.utils.handlers_utils - loss 0.91785, triplet_loss 0.85132, c_loss 0.11393, hs_loss 0.25450, cs_loss 0.75836, cacc 0.95161, hsacc 0.91032, csacc 0.72839, chstimgn_obs_loss 0.22971, chestimg_obs_macf1 0.85565, chstimgn_anatloc_loss 0.41101, chestimg_anatloc_macf1 0.86045, nli_loss 0.27548, nli_acc 0.90309, entcon_loss 0.35111, entcon_acc 0.95016, sae_loss 2.48751, 64.00 secs
# 2025-06-11 01:51:43,847 - INFO - medvqa.training.utils - (2) Validation stage ...
# 2025-06-11 01:51:43,848 - INFO - ignite.engine.engine.Engine - Engine run starting with max_epochs=1.
# Validation: [93/93] 100%|███████████ [00:07<00:00]
# 2025-06-11 01:51:51,919 - INFO - medvqa.utils.handlers_utils - tacc(al0) 0.99300, tacc(al1) 0.98600, tacc(al2) 0.91000, tacc(ob0) 0.99500, tacc(ob1) 0.98800, tacc(ob2) 0.94800, tacc(ob3) 0.99000, tacc(ob4) 0.98500, tacc(ob5) 0.90500, tacc(ob6) 0.97100, tacc(ob7) 0.95400, tacc(ob8) 0.98200, nli_acc 0.85256, entcon_acc 0.96541, sae_loss 1.36575, 8.07 secs
# 2025-06-11 01:51:51,920 - INFO - ignite.engine.engine.Engine - Epoch[1] Complete. Time taken: 00:00:08.072
# 2025-06-11 01:51:51,920 - INFO - ignite.engine.engine.Engine - Engine run complete. Time taken: 00:00:08.072
# 2025-06-11 01:51:51,921 - INFO - ignite.engine.engine.Engine - Epoch[163] Complete. Time taken: 00:01:12.070
# 2025-06-11 01:51:51,921 - INFO - medvqa.utils.handlers_utils - ==================== Epoch 164/200 ====================
# 2025-06-11 01:51:51,921 - INFO - medvqa.training.utils - (1) Training stage (lr = 0.000005) ...
# Training [164/200]: [800/800] 100%|██████████, loss=2.01 [01:23<00:00]
# 2025-06-11 01:53:15,051 - INFO - medvqa.utils.handlers_utils - loss 0.90785, triplet_loss 0.84632, c_loss 0.15769, hs_loss 0.22436, cs_loss 0.76370, cacc 0.95344, hsacc 0.91148, csacc 0.73115, chstimgn_obs_loss 0.23614, chestimg_obs_macf1 0.85351, chstimgn_anatloc_loss 0.38223, chestimg_anatloc_macf1 0.86990, nli_loss 0.28714, nli_acc 0.88976, entcon_loss 0.35225, entcon_acc 0.95871, sae_loss 2.44279, 83.13 secs
# 2025-06-11 01:53:15,052 - INFO - medvqa.training.utils - (2) Validation stage ...
# 2025-06-11 01:53:15,052 - INFO - ignite.engine.engine.Engine - Engine run starting with max_epochs=1.
# Validation: [93/93] 100%|███████████ [00:07<00:00]
# 2025-06-11 01:53:22,975 - INFO - medvqa.utils.handlers_utils - tacc(al0) 0.99300, tacc(al1) 0.98400, tacc(al2) 0.90700, tacc(ob0) 0.99700, tacc(ob1) 0.99100, tacc(ob2) 0.94800, tacc(ob3) 0.99100, tacc(ob4) 0.98500, tacc(ob5) 0.90500, tacc(ob6) 0.96900, tacc(ob7) 0.95900, tacc(ob8) 0.98100, nli_acc 0.85612, entcon_acc 0.96541, sae_loss 1.36294, 7.92 secs
# 2025-06-11 01:53:22,975 - INFO - ignite.engine.engine.Engine - Epoch[1] Complete. Time taken: 00:00:07.922
# 2025-06-11 01:53:22,975 - INFO - ignite.engine.engine.Engine - Engine run complete. Time taken: 00:00:07.923
# 2025-06-11 01:53:22,976 - INFO - ignite.engine.engine.Engine - Epoch[164] Complete. Time taken: 00:01:31.055
# 2025-06-11 01:53:22,976 - INFO - medvqa.utils.handlers_utils - ==================== Epoch 165/200 ====================
# 2025-06-11 01:53:22,976 - INFO - medvqa.training.utils - (1) Training stage (lr = 0.000002) ...
# Training [165/200]: [800/800] 100%|██████████, loss=0.83 [01:04<00:00]
# 2025-06-11 01:54:27,649 - INFO - medvqa.utils.handlers_utils - loss 0.91375, triplet_loss 0.85065, c_loss 0.11827, hs_loss 0.30415, cs_loss 0.73648, cacc 0.96323, hsacc 0.90581, csacc 0.71742, chstimgn_obs_loss 0.25128, chestimg_obs_macf1 0.83488, chstimgn_anatloc_loss 0.38102, chestimg_anatloc_macf1 0.87239, nli_loss 0.28177, nli_acc 0.88813, entcon_loss 0.34634, entcon_acc 0.96000, sae_loss 2.45966, 64.67 secs
# 2025-06-11 01:54:27,649 - INFO - medvqa.training.utils - (2) Validation stage ...
# 2025-06-11 01:54:27,650 - INFO - ignite.engine.engine.Engine - Engine run starting with max_epochs=1.
# Validation: [93/93] 100%|███████████ [00:07<00:00]
# 2025-06-11 01:54:35,566 - INFO - medvqa.utils.handlers_utils - tacc(al0) 0.99300, tacc(al1) 0.98500, tacc(al2) 0.91000, tacc(ob0) 0.99800, tacc(ob1) 0.99100, tacc(ob2) 0.95200, tacc(ob3) 0.99200, tacc(ob4) 0.98400, tacc(ob5) 0.90500, tacc(ob6) 0.97300, tacc(ob7) 0.95700, tacc(ob8) 0.98100, nli_acc 0.85375, entcon_acc 0.96541, sae_loss 1.36574, 7.92 secs
# 2025-06-11 01:54:35,567 - INFO - ignite.engine.engine.Engine - Epoch[1] Complete. Time taken: 00:00:07.917
# 2025-06-11 01:54:35,567 - INFO - ignite.engine.engine.Engine - Engine run complete. Time taken: 00:00:07.917
# 2025-06-11 01:54:35,567 - INFO - ignite.engine.engine.Engine - Epoch[165] Complete. Time taken: 00:01:12.591
# 2025-06-11 01:54:35,567 - INFO - medvqa.utils.handlers_utils - ==================== Epoch 166/200 ====================
# 2025-06-11 01:54:35,567 - INFO - medvqa.training.utils - (1) Training stage (lr = 0.000001) ...
# Training [166/200]: [800/800] 100%|█████████, loss=0.766 [01:18<00:00]
# 2025-06-11 01:55:53,908 - INFO - medvqa.utils.handlers_utils - loss 0.91305, triplet_loss 0.85184, c_loss 0.13850, hs_loss 0.23370, cs_loss 0.74130, cacc 0.95226, hsacc 0.89871, csacc 0.72516, chstimgn_obs_loss 0.23546, chestimg_obs_macf1 0.85326, chstimgn_anatloc_loss 0.40826, chestimg_anatloc_macf1 0.86825, nli_loss 0.29375, nli_acc 0.88748, entcon_loss 0.34731, entcon_acc 0.95677, sae_loss 2.45972, 78.34 secs
# 2025-06-11 01:55:53,908 - INFO - medvqa.training.utils - (2) Validation stage ...
# 2025-06-11 01:55:53,909 - INFO - ignite.engine.engine.Engine - Engine run starting with max_epochs=1.
# Validation: [93/93] 100%|███████████ [00:07<00:00]
# 2025-06-11 01:56:01,874 - INFO - medvqa.utils.handlers_utils - tacc(al0) 0.99300, tacc(al1) 0.98600, tacc(al2) 0.90800, tacc(ob0) 0.99700, tacc(ob1) 0.99100, tacc(ob2) 0.95200, tacc(ob3) 0.99200, tacc(ob4) 0.98600, tacc(ob5) 0.90400, tacc(ob6) 0.96800, tacc(ob7) 0.96000, tacc(ob8) 0.98000, nli_acc 0.86683, entcon_acc 0.96226, sae_loss 1.36614, 7.97 secs
# 2025-06-11 01:56:01,874 - INFO - ignite.engine.engine.Engine - Epoch[1] Complete. Time taken: 00:00:07.966
# 2025-06-11 01:56:01,875 - INFO - ignite.engine.engine.Engine - Engine run complete. Time taken: 00:00:07.966
# 2025-06-11 01:56:01,875 - INFO - ignite.engine.engine.Engine - Epoch[166] Complete. Time taken: 00:01:26.308
# 2025-06-11 01:56:01,875 - INFO - medvqa.utils.handlers_utils - ==================== Epoch 167/200 ====================
# 2025-06-11 01:56:01,875 - INFO - medvqa.training.utils - (1) Training stage (lr = 0.000070) ...
# Training [167/200]: [800/800] 100%|█████████, loss=0.396 [01:27<00:00]
# 2025-06-11 01:57:29,365 - INFO - medvqa.utils.handlers_utils - loss 0.91705, triplet_loss 0.85382, c_loss 0.09550, hs_loss 0.26348, cs_loss 0.77711, cacc 0.94951, hsacc 0.90754, csacc 0.71016, chstimgn_obs_loss 0.24650, chestimg_obs_macf1 0.84625, chstimgn_anatloc_loss 0.43089, chestimg_anatloc_macf1 0.86004, nli_loss 0.28771, nli_acc 0.89073, entcon_loss 0.35460, entcon_acc 0.95541, sae_loss 2.45809, 87.49 secs
# 2025-06-11 01:57:29,365 - INFO - medvqa.training.utils - (2) Validation stage ...
# 2025-06-11 01:57:29,366 - INFO - ignite.engine.engine.Engine - Engine run starting with max_epochs=1.
# Validation: [93/93] 100%|███████████ [00:07<00:00]
# 2025-06-11 01:57:37,133 - INFO - medvqa.utils.handlers_utils - tacc(al0) 0.99300, tacc(al1) 0.98500, tacc(al2) 0.91300, tacc(ob0) 0.99600, tacc(ob1) 0.99000, tacc(ob2) 0.94400, tacc(ob3) 0.99000, tacc(ob4) 0.98200, tacc(ob5) 0.90500, tacc(ob6) 0.97000, tacc(ob7) 0.95400, tacc(ob8) 0.98000, nli_acc 0.85018, entcon_acc 0.94969, sae_loss 1.36681, 7.77 secs
# 2025-06-11 01:57:37,133 - INFO - ignite.engine.engine.Engine - Epoch[1] Complete. Time taken: 00:00:07.767
# 2025-06-11 01:57:37,133 - INFO - ignite.engine.engine.Engine - Engine run complete. Time taken: 00:00:07.767
# 2025-06-11 01:57:37,134 - INFO - ignite.engine.engine.Engine - Epoch[167] Complete. Time taken: 00:01:35.258
# 2025-06-11 01:57:37,134 - INFO - medvqa.utils.handlers_utils - ==================== Epoch 168/200 ====================
# 2025-06-11 01:57:37,134 - INFO - medvqa.training.utils - (1) Training stage (lr = 0.000030) ...
# Training [168/200]: [800/800] 100%|█████████, loss=0.828 [01:26<00:00]
# 2025-06-11 01:59:03,585 - INFO - medvqa.utils.handlers_utils - loss 0.91221, triplet_loss 0.84871, c_loss 0.08204, hs_loss 0.22835, cs_loss 0.82296, cacc 0.95742, hsacc 0.91355, csacc 0.69226, chstimgn_obs_loss 0.22609, chestimg_obs_macf1 0.85461, chstimgn_anatloc_loss 0.43707, chestimg_anatloc_macf1 0.85500, nli_loss 0.29972, nli_acc 0.88618, entcon_loss 0.34239, entcon_acc 0.96194, sae_loss 2.43536, 86.45 secs
# 2025-06-11 01:59:03,585 - INFO - medvqa.training.utils - (2) Validation stage ...
# 2025-06-11 01:59:03,586 - INFO - ignite.engine.engine.Engine - Engine run starting with max_epochs=1.
# Validation: [93/93] 100%|███████████ [00:07<00:00]
# 2025-06-11 01:59:11,553 - INFO - medvqa.utils.handlers_utils - tacc(al0) 0.99400, tacc(al1) 0.98400, tacc(al2) 0.91200, tacc(ob0) 0.99600, tacc(ob1) 0.99100, tacc(ob2) 0.95200, tacc(ob3) 0.99000, tacc(ob4) 0.98200, tacc(ob5) 0.91000, tacc(ob6) 0.97400, tacc(ob7) 0.95800, tacc(ob8) 0.97900, nli_acc 0.84423, entcon_acc 0.96226, sae_loss 1.36043, 7.97 secs
# 2025-06-11 01:59:11,554 - INFO - ignite.engine.engine.Engine - Epoch[1] Complete. Time taken: 00:00:07.968
# 2025-06-11 01:59:11,554 - INFO - ignite.engine.engine.Engine - Engine run complete. Time taken: 00:00:07.968
# 2025-06-11 01:59:11,554 - INFO - ignite.engine.engine.Engine - Epoch[168] Complete. Time taken: 00:01:34.421
# 2025-06-11 01:59:11,554 - INFO - medvqa.utils.handlers_utils - ==================== Epoch 169/200 ====================
# 2025-06-11 01:59:11,554 - INFO - medvqa.training.utils - (1) Training stage (lr = 0.000013) ...
# Training [169/200]: [800/800] 100%|█████████, loss=0.304 [01:24<00:00]
# 2025-06-11 02:00:35,954 - INFO - medvqa.utils.handlers_utils - loss 0.91530, triplet_loss 0.84836, c_loss 0.11541, hs_loss 0.27460, cs_loss 0.76616, cacc 0.94820, hsacc 0.90164, csacc 0.72066, chstimgn_obs_loss 0.24036, chestimg_obs_macf1 0.85706, chstimgn_anatloc_loss 0.38313, chestimg_anatloc_macf1 0.86857, nli_loss 0.29299, nli_acc 0.89138, entcon_loss 0.34907, entcon_acc 0.96000, sae_loss 2.47914, 84.40 secs
# 2025-06-11 02:00:35,954 - INFO - medvqa.training.utils - (2) Validation stage ...
# 2025-06-11 02:00:35,955 - INFO - ignite.engine.engine.Engine - Engine run starting with max_epochs=1.
# Validation: [93/93] 100%|███████████ [00:07<00:00]
# 2025-06-11 02:00:43,855 - INFO - medvqa.utils.handlers_utils - tacc(al0) 0.99400, tacc(al1) 0.98400, tacc(al2) 0.91100, tacc(ob0) 0.99600, tacc(ob1) 0.98900, tacc(ob2) 0.95400, tacc(ob3) 0.99000, tacc(ob4) 0.98200, tacc(ob5) 0.91200, tacc(ob6) 0.97700, tacc(ob7) 0.95500, tacc(ob8) 0.98000, nli_acc 0.84423, entcon_acc 0.97799, sae_loss 1.35982, 7.90 secs
# 2025-06-11 02:00:43,856 - INFO - ignite.engine.engine.Engine - Epoch[1] Complete. Time taken: 00:00:07.901
# 2025-06-11 02:00:43,856 - INFO - ignite.engine.engine.Engine - Engine run complete. Time taken: 00:00:07.901
# 2025-06-11 02:00:43,856 - INFO - ignite.engine.engine.Engine - Epoch[169] Complete. Time taken: 00:01:32.302
# 2025-06-11 02:00:43,856 - INFO - medvqa.utils.handlers_utils - ==================== Epoch 170/200 ====================
# 2025-06-11 02:00:43,856 - INFO - medvqa.training.utils - (1) Training stage (lr = 0.000005) ...
# Training [170/200]: [800/800] 100%|█████████, loss=0.199 [01:26<00:00]
# 2025-06-11 02:02:10,136 - INFO - medvqa.utils.handlers_utils - loss 0.90754, triplet_loss 0.85720, c_loss 0.12030, hs_loss 0.19611, cs_loss 0.73635, cacc 0.95613, hsacc 0.91935, csacc 0.73742, chstimgn_obs_loss 0.24500, chestimg_obs_macf1 0.85746, chstimgn_anatloc_loss 0.38300, chestimg_anatloc_macf1 0.86765, nli_loss 0.29955, nli_acc 0.88846, entcon_loss 0.34584, entcon_acc 0.95738, sae_loss 2.44106, 86.28 secs
# 2025-06-11 02:02:10,137 - INFO - medvqa.training.utils - (2) Validation stage ...
# 2025-06-11 02:02:10,137 - INFO - ignite.engine.engine.Engine - Engine run starting with max_epochs=1.
# Validation: [93/93] 100%|███████████ [00:07<00:00]
# 2025-06-11 02:02:17,958 - INFO - medvqa.utils.handlers_utils - tacc(al0) 0.99400, tacc(al1) 0.98500, tacc(al2) 0.91400, tacc(ob0) 0.99600, tacc(ob1) 0.98900, tacc(ob2) 0.95000, tacc(ob3) 0.98900, tacc(ob4) 0.98100, tacc(ob5) 0.90700, tacc(ob6) 0.97200, tacc(ob7) 0.95700, tacc(ob8) 0.97900, nli_acc 0.85731, entcon_acc 0.96855, sae_loss 1.35738, 7.82 secs
# 2025-06-11 02:02:17,959 - INFO - ignite.engine.engine.Engine - Epoch[1] Complete. Time taken: 00:00:07.821
# 2025-06-11 02:02:17,959 - INFO - ignite.engine.engine.Engine - Engine run complete. Time taken: 00:00:07.821
# 2025-06-11 02:02:17,959 - INFO - ignite.engine.engine.Engine - Epoch[170] Complete. Time taken: 00:01:34.103
# 2025-06-11 02:02:17,959 - INFO - medvqa.utils.handlers_utils - ==================== Epoch 171/200 ====================
# 2025-06-11 02:02:17,959 - INFO - medvqa.training.utils - (1) Training stage (lr = 0.000002) ...
# Training [171/200]: [800/800] 100%|█████████, loss=0.805 [01:26<00:00]
# 2025-06-11 02:03:44,555 - INFO - medvqa.utils.handlers_utils - loss 0.91588, triplet_loss 0.85362, c_loss 0.18084, hs_loss 0.25750, cs_loss 0.70402, cacc 0.93639, hsacc 0.91016, csacc 0.74885, chstimgn_obs_loss 0.23293, chestimg_obs_macf1 0.84482, chstimgn_anatloc_loss 0.39347, chestimg_anatloc_macf1 0.86923, nli_loss 0.29258, nli_acc 0.88976, entcon_loss 0.35426, entcon_acc 0.95161, sae_loss 2.46792, 86.60 secs
# 2025-06-11 02:03:44,556 - INFO - medvqa.training.utils - (2) Validation stage ...
# 2025-06-11 02:03:44,556 - INFO - ignite.engine.engine.Engine - Engine run starting with max_epochs=1.
# Validation: [93/93] 100%|███████████ [00:07<00:00]
# 2025-06-11 02:03:52,427 - INFO - medvqa.utils.handlers_utils - tacc(al0) 0.99200, tacc(al1) 0.98300, tacc(al2) 0.91400, tacc(ob0) 0.99700, tacc(ob1) 0.99000, tacc(ob2) 0.95200, tacc(ob3) 0.99000, tacc(ob4) 0.98300, tacc(ob5) 0.90500, tacc(ob6) 0.97400, tacc(ob7) 0.95600, tacc(ob8) 0.98000, nli_acc 0.86088, entcon_acc 0.97170, sae_loss 1.35710, 7.87 secs
# 2025-06-11 02:03:52,428 - INFO - ignite.engine.engine.Engine - Epoch[1] Complete. Time taken: 00:00:07.871
# 2025-06-11 02:03:52,428 - INFO - ignite.engine.engine.Engine - Engine run complete. Time taken: 00:00:07.872
# 2025-06-11 02:03:52,429 - INFO - ignite.engine.engine.Engine - Epoch[171] Complete. Time taken: 00:01:34.470
# 2025-06-11 02:03:52,429 - INFO - medvqa.utils.handlers_utils - ==================== Epoch 172/200 ====================
# 2025-06-11 02:03:52,429 - INFO - medvqa.training.utils - (1) Training stage (lr = 0.000001) ...
# Training [172/200]: [376/800]  47%|████▏    , loss=0.788 [00:39<00:44]

# %%
from medvqa.utils.files_utils import list_filepaths_with_prefix_and_timestamps

# %%
list_filepaths_with_prefix_and_timestamps('/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_sentence_facts')
# Out:
# [('/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_sentence_facts(58655550,50990861).jsonl',
#   '2025-01-29 19:26:10'),
#  ('/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_sentence_facts(59349684,50956825).jsonl',
#   '2025-01-04 10:45:13'),
#  ('/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_sentence_facts(58655550,50135857).jsonl',
#   '2023-09-09 21:42:41'),
#  ('/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_sentence_facts(58655550,49840052).jsonl',
#   '2023-07-12 14:51:01'),
#  ('/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_sentence_facts(58655550,49840759).jsonl',
#   '2023-07-12 14:14:27'),
#  ('/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_sentence_facts(58655550,49843061).jsonl',
#   '2023-07-10 10:56:53'),
#  ('/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_sentence_facts(58655550,46441815).jsonl',
#   '2023-07-08 14:14:29'),
#  ('/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_sentence_facts(68493868,63882717).jsonl',
#   '2023-06-28 11:17:07'),
#  ('/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_sentence_facts(68493868,63886474).jsonl',
#   '2023-06-26 17:31:31')]

# %%
list_filepaths_with_prefix_and_timestamps('/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_fact_metadata(')
# Out:
# [('/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_fact_metadata(606074,61621903).jsonl',
#   '2025-01-04 10:45:21'),
#  ('/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_fact_metadata(595880,60579117).improved_comparison(6741113).jsonl',
#   '2023-09-10 16:30:58'),
#  ('/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_fact_metadata(595880,60579117).jsonl',
#   '2023-09-09 21:42:49'),
#  ('/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_fact_metadata(578733,58628071).improved_comparison(6526297).jsonl',
#   '2023-07-18 11:46:52'),
#  ('/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_fact_metadata(578733,58628071).improved_comparison(6595181).jsonl',
#   '2023-07-18 00:18:14'),
#  ('/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_fact_metadata(578733,58628071).jsonl',
#   '2023-07-12 14:51:08'),
#  ('/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_fact_metadata(578733,58628252).jsonl',
#   '2023-07-12 14:14:39'),
#  ('/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_fact_metadata(578718,58626719).jsonl',
#   '2023-07-12 12:55:34'),
#  ('/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_fact_metadata(578718,58628868).jsonl',
#   '2023-07-10 10:57:01')]

# %%
list_filepaths_with_prefix_and_timestamps('/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(')
# Out:
# [('/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(265719,34150895).jsonl',
#   '2024-06-27 11:35:52'),
#  ('/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(169025,21838032).jsonl',
#   '2024-01-16 11:00:17'),
#  ('/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(157742,20319191).jsonl',
#   '2024-01-05 17:58:36'),
#  ('/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(136946,17908799).jsonl',
#   '2024-01-05 16:17:03'),
#  ('/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(188008,24487305).jsonl',
#   '2024-01-05 12:29:53'),
#  ('/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(188008,24539249).jsonl',
#   '2024-01-05 12:29:15'),
#  ('/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(162036,21465751).jsonl',
#   '2023-09-25 01:29:03'),
#  ('/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(96629,13236055).jsonl',
#   '2023-09-23 09:51:34'),
#  ('/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(60858,8391955).jsonl',
#   '2023-09-22 10:26:26'),
#  ('/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(59424,8648302).jsonl',
#   '2023-09-21 04:51:27')]
