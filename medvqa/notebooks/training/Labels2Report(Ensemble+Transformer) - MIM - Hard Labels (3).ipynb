# %%
# %env CUDA_VISIBLE_DEVICES=0
# Out:
# env: CUDA_VISIBLE_DEVICES=0

# %%
# !/home/pamessina/venv2/bin/python ../train_labels2report.py \
    --generation-mode "pred2rep" \
    --use-ensemble \
    --ensemble-model-checkpoint-folder-paths \
        "/mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/" \
    --ensemble-batch-size 160 \
    --ensemble-num-workers 3 \
    --use-hard-predictions \
    --filter-labels \
    --label-score-threshold 0.5 \
    --epochs 68 \
    --batches-per-epoch 300 \
    --batch-size 200 \
    --num-workers 2 \
    --iters-to-accumulate 2 \
    --optimizer-name "adamw" \
    --scheduler "exp-warmup+decay+cyclicdecay" \
    --lr 1e-6 \
    --warmup-decay-and-cyclic-decay-args "1e-6,3,4e-4,8,3e-6,4e-4,8,3e-6" \
    --use-mimiccxr \
    --mimiccxr-weight 1.0 \
    --mimiccxr-view-mode "chest_imagenome" \
    --mimiccxr-balanced-sampling-mode "balanced_chest_imagenome_global_labels_batchwise" \
    --mimiccxr-balanced-batch-size 30 \
    --mimiccxr-qa-adapted-reports-filename "qa_adapted_reports__20220904_095810.json" \
    --use-chest-imagenome \
    --use-chest-imagenome-decent-images-only \
    --chest-imagenome-label-names-filename "labels(min_freq=100).pkl" \
    --chest-imagenome-labels-filename "imageId2labels(min_freq=100).pkl" \
    --use-chexpert \
    --mimiccxr-chexpert-labels-filename "chexpert_labels_per_report__20220904_113605.pkl" \
    --use-medical-tokenization \
    --medical-terms-frequency-filename "medical_terms_frequency__20220918_184255.pkl" \
    --binary-loss-name "focal+bce+wbce-c" \
    --labels-hidden-dim 1024 \
    --embedding-dim 512 \
    --transf-dec-num-memory-vecs 10 \
    --transf-dec-hidden-dim 512 \
    --transf-dec-nhead 4 \
    --transf-dec-dim-forward 512 \
    --transf-dec-num-layers 3 \
    --use-amp \
    --save
# Out:
# script's arguments:
#    epochs: 68
#    batches_per_epoch: 300
#    batch_size: 200
#    checkpoint_folder: None
#    generation_mode: pred2rep
#    use_ensemble: True
#    ensemble_model_checkpoint_folder_paths: ['/mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/']
#    ensemble_batch_size: 160
#    ensemble_num_workers: 3
#    use_hard_predictions: True
#    pretrained_checkpoint_folder_path: None
#    labels_hidden_dim: 1024
#    embedding_dim: 512
#    transf_dec_num_memory_vecs: 10
#    transf_dec_hidden_dim: 512
#    transf_dec_nhead: 4
#    transf_dec_dim_forward: 512
#    transf_dec_num_layers: 3
#    dropout_prob: 0
#    vocab_min_freq: 10
#    use_medical_tokenization: True
#    medical_terms_frequency_filename: medical_terms_frequency__20220918_184255.pkl
#    optimizer_name: adamw
#    lr: 1e-06
#    scheduler: exp-warmup+decay+cyclicdecay
#    lr_decay: 0.76
#    lr_decay_patience: 2
#    warmup_and_decay_args: None
#    warmup_and_cosine_args: None
#    warmup_decay_and_cyclic_decay_args: 1e-6,3,4e-4,8,3e-6,4e-4,8,3e-6
#    iters_to_accumulate: 2
#    override_lr: False
#    binary_loss_name: focal+bce+wbce-c
#    focal_loss_weight: 1
#    bce_loss_weight: 1
#    wbce_loss_weight: 1
#    num_workers: 2
#    device: GPU
#    use_amp: True
#    train_mimiccxr: True
#    mimiccxr_weight: 1.0
#    mimiccxr_view_mode: chest_imagenome
#    mimiccxr_balanced_sampling_mode: balanced_chest_imagenome_global_labels_batchwise
#    mimiccxr_balanced_batch_size: 30
#    mimiccxr_qa_adapted_reports_filename: qa_adapted_reports__20220904_095810.json
#    chest_imagenome_labels_filename: imageId2labels(min_freq=100).pkl
#    chest_imagenome_label_names_filename: labels(min_freq=100).pkl
#    use_chest_imagenome_decent_images_only: True
#    save: True
#    use_gender: False
#    use_chexpert: True
#    mimiccxr_chexpert_labels_filename: chexpert_labels_per_report__20220904_113605.pkl
#    use_chest_imagenome: True
#    filter_labels: True
#    top_k_chexpert_labels: None
#    top_k_chest_imagenome_labels: None
#    label_score_threshold: 0.5
#    debug: False
# ----- Training model from scratch ------
# Computing number of labels and ranges for ensemble ...
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/metadata.json
# chest_imagenome_range: (0, 627)
# chexpert_range: (627, 641)
# ============================================================
# Precomputing sigmoid activations for ensemble ...
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/metadata.json
# ============================================================
# Model 1/1
# model_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/
# checkpoint_names = ['checkpoint_79_chou+chuc+chuc+chuc+chuc+cD+gacc+wmmp=0.6677.pt', 'checkpoint_135_chou+chuc+chuc+chuc+chuc+cD+gacc+wmmp=0.6689.pt']
# model_checkpoint_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/checkpoint_135_chou+chuc+chuc+chuc+chuc+cD+gacc+wmmp=0.6689.pt
# precomputed_chexpert_sigmoids_path = /mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/precomputed_chexpert_sigmoids(hash=340,3716123060218160099).pkl
# Precomputed sigmoids for CheXpert already exist.
# File size = 56.39 MB
# precomputed_chest_imagenome_sigmoids_path = /mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/precomputed_chest_imagenome_sigmoids(hash=347,2103260294420767687).pkl
# Precomputed sigmoids for Chest ImaGenome already exist.
# File size = 339.66 MB
# Skipping...
# precomputed_sigmoid_paths: [{'model_folder_path': '/mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/', 'chexpert_sigmoids_path': '/mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/precomputed_chexpert_sigmoids(hash=340,3716123060218160099).pkl', 'chest_imagenome_sigmoids_path': '/mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/precomputed_chest_imagenome_sigmoids(hash=347,2103260294420767687).pkl'}]
# ============================================================
# Precomputing thresholds (for hard predictions) for ensemble ...
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/metadata.json
# ============================================================
# Model 1/1
# model_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/
# checkpoint_names = ['checkpoint_79_chou+chuc+chuc+chuc+chuc+cD+gacc+wmmp=0.6677.pt', 'checkpoint_135_chou+chuc+chuc+chuc+chuc+cD+gacc+wmmp=0.6689.pt']
# model_checkpoint_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/checkpoint_135_chou+chuc+chuc+chuc+chuc+cD+gacc+wmmp=0.6689.pt
# results_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/results/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/
# get_image_transform()
#   Using bounding box aware transforms
#     Returning default transform (no augmentation)
# Calibrating thresholds on MIMIC-CXR validation set
# score_name: f1
# Thresholds for CheXpert already cached at /mnt/data/pamessina/workspaces/medvqa-workspace/results/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/thresholds_chexpert(f1).pkl
# Thresholds for Chest ImaGenome already cached at /mnt/data/pamessina/workspaces/medvqa-workspace/results/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/thresholds_chest_imagenome(f1).pkl
# precomputed_thresholds_paths: [{'chexpert': '/mnt/data/pamessina/workspaces/medvqa-workspace/results/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/thresholds_chexpert(f1).pkl', 'chest_imagenome': '/mnt/data/pamessina/workspaces/medvqa-workspace/results/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/thresholds_chest_imagenome(f1).pkl'}]
# ============================================================
# Precomputing filtered labels for ensemble ...
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/metadata.json
# ============================================================
# Model 1/1
# model_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/
# results_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/results/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/
# get_image_transform()
#   Using bounding box aware transforms
#     Returning default transform (no augmentation)
# Loading cached chexpert predictions and ground truth...
# len(dicom_id_to_pred_chexpert_probs): 3389
# len(dicom_id_to_gt_chexpert_labels): 3389
# Loading cached chest imagenome predictions and ground truth...
# len(dicom_id_to_pred_chest_imagenome_probs): 3389
# len(dicom_id_to_gt_chest_imagenome_labels): 3389
# Top 6 label classes with the highest f1 scores:
# 1. Support Devices: 0.8737220226581928
# 2. Pleural Effusion: 0.743933588761175
# 3. Cardiomegaly: 0.7198264171413074
# 4. Lung Opacity: 0.6673640167364017
# 5. Edema: 0.6276923076923075
# 6. Atelectasis: 0.6112539274493003
# Top 68 label classes with the highest f1 scores:
# 1. ('nlp', 'abnormal'): 0.9645215788665336
# 4. ('left lung', 'nlp', 'abnormal'): 0.8949362728212196
# 8. ('cardiac silhouette', 'device', 'cardiac pacer and wires'): 0.8446115288220551
# 11. ('device', 'cardiac pacer and wires'): 0.7708333333333333
# 15. ('abdomen', 'tubesandlines', 'enteric tube'): 0.7364085667215815
# 18. ('mediastinum', 'tubesandlines', 'enteric tube'): 0.7274233637116817
# 22. ('anatomicalfinding', 'enlarged cardiac silhouette'): 0.7153047989623865
# 25. ('right costophrenic angle', 'anatomicalfinding', 'lung opacity'): 0.7143381004767144
# 29. ('left costophrenic angle', 'anatomicalfinding', 'pleural effusion'): 0.6901408450704226
# 32. ('right hilar structures', 'nlp', 'abnormal'): 0.674488567990373
# 36. ('left hilar structures', 'anatomicalfinding', 'lung opacity'): 0.6514327167210737
# 39. ('anatomicalfinding', 'atelectasis'): 0.636920384951881
# 43. ('tubesandlines', 'swan-ganz catheter'): 0.6153846153846153
# 46. ('trachea', 'tubesandlines', 'tracheostomy tube'): 0.6046511627906976
# 50. ('neck', 'tubesandlines', 'ij line'): 0.5802816901408451
# 53. ('left hilar structures', 'anatomicalfinding', 'pulmonary edema/hazy opacity'): 0.5747592498732894
# 57. ('tubesandlines', 'chest tube'): 0.5493827160493827
# 60. ('anatomicalfinding', 'hyperaeration'): 0.5324675324675324
# 64. ('right lung', 'anatomicalfinding', 'atelectasis'): 0.5201032829214312
# 68. ('left lung', 'technicalassessment', 'low lung volumes'): 0.5041095890410959
# precomputed_filtered_labels_paths: [{'chexpert_indices_path': '/mnt/data/pamessina/workspaces/medvqa-workspace/results/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/chexpert_top_6_out_of_14_labels_f1_(score_threshold_0.50)_indices.pkl', 'chexpert_num_indices': 6, 'chest_imagenome_indices_path': '/mnt/data/pamessina/workspaces/medvqa-workspace/results/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/chest_imagenome_top_68_out_of_627_labels_f1_(score_threshold_0.50)_indices.pkl', 'chest_imagenome_num_indices': 68}]
# num_input_labels (after update): 74
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Initializing tokenizer ...
# Loading /mnt/data/pamessina/workspaces/medvqa-workspace/cache/vocab(min_freq=10;mode=report;qa_adapted_reports__20220904_095810.json).pkl ...
# --------------------------------------------------
# 3) Creating instance of Labels2ReportModel ...
# Labels2ReportModel
#   gen_mode: pred2rep
#   vocab_size: 4833
#   embedding_dim: 512
#   num_input_labels: 74
#   labels_hidden_dim: 1024
#   num_output_labels: 641
#   transf_dec_num_memory_vecs: 10
#   transf_dec_hidden_dim: 512
#   transf_dec_nhead: 4
#   transf_dec_dim_forward: 512
#   transf_dec_num_layers: 3
#   start_idx: 1
#   dropout_prob: 0
# --------------------------------------------------
# 4) Defining optimizer ...
# create_optimizer(): name = adamw
# --------------------------------------------------
# 5) Defining scheduler ...
# Using exp-warmup+decay+cyclicdecay scheduler: 1e-6,3,4e-4,8,3e-6,4e-4,8,3e-6
# 1e-06 3 0.0004 8 3e-06 0.0004 8 3e-06
# self.steps_to_restart = 8
# self.steps = -1
# self.initial_lr = 0.0004
# --------------------------------------------------
# 6) Creating trainer and validator engines ...
# Using focal+bce+wbce-c loss
# binary_loss_kwargs: {'focal_weight': 1, 'bce_weight': 1, 'wbce_weight': 1}
# --------------------------------------------------
# 7) Defining collate_batch_fn ...
# --------------------------------------------------
# 8) Creating MIMIC-CXR_Labels2ReportTrainer ...
# 227835it [00:14, 15379.69it/s]
# max_idx_count = 377110
# actual_idx_count = 239513
# ** NOTE: 137597 images were skipped because they were not in the allowed DICOM IDs
# Random report:
# <s> cardiomediastinal hilar contours normal . aorta tortuous . lower lung volumes elevation right hemidiaphragm . clear lungs . no pneumothorax . no cardiopulmonary process </s>
# len(self.train_indices) = 234217
# len(self.val_indices) = 1934
# Loading CheXpert labels...
# Loading Chest Imagenome labels...
# Loading precomputed sigmoid paths for ensemble predictions...
#   Loading /mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/precomputed_chexpert_sigmoids(hash=340,3716123060218160099).pkl
#     _probs.shape = (242280, 14)
#     len(_dids) = 242280
#     _thresholds.shape = (14,)
#     _probs has been thresholded
#     _label_indices.shape = (6,)
#     _probs has been filtered
#     Sanity checking chexpert labels
#     len(self.val_indices) = 1934
#     f1_score(_gt_labels, _pred_labels, average="micro") = 0.6929647111710497
#     f1_score(_gt_labels, _pred_labels, average="macro") = 0.6880602240473702
#   Loading /mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/precomputed_chest_imagenome_sigmoids(hash=347,2103260294420767687).pkl
#     _probs.shape = (242280, 627)
#     len(_dids) = 242280
#     _thresholds.shape = (627,)
#     _probs has been thresholded
#     _label_indices.shape = (68,)
#     _probs has been filtered
#     Sanity checking chest_imagenome labels
#     len(self.val_indices) = 1934
#     f1_score(_gt_labels, _pred_labels, average="micro") = 0.7082005701827939
#     f1_score(_gt_labels, _pred_labels, average="macro") = 0.6519597097150478
# Done loading precomputed sigmoid paths for ensemble predictions
# Balanced sampling mode: balanced_chest_imagenome_global_labels_batchwise
# Regrouping indices by Chest Imagenome labels for balanced sampling...
# 627it [01:03,  9.89it/s]
# Global: airspace opacity                        , # images: 8595 (other: 225622)
# Global: atelectasis                             , # images: 79106 (other: 155111)
# Global: bone lesion                             , # images: 1692 (other: 232525)
# Global: bronchiectasis                          , # images: 905 (other: 233312)
# Global: calcified nodule                        , # images: 2708 (other: 231509)
# Global: clavicle fracture                       , # images: 862 (other: 233355)
# Global: consolidation                           , # images: 17769 (other: 216448)
# Global: costophrenic angle blunting             , # images: 5723 (other: 228494)
# Global: cyst/bullae                             , # images: 874 (other: 233343)
# Global: elevated hemidiaphragm                  , # images: 6412 (other: 227805)
# Global: enlarged cardiac silhouette             , # images: 57654 (other: 176563)
# Global: enlarged hilum                          , # images: 8983 (other: 225234)
# Global: hernia                                  , # images: 3025 (other: 231192)
# Global: hydropneumothorax                       , # images: 954 (other: 233263)
# Global: hyperaeration                           , # images: 10306 (other: 223911)
# Global: increased reticular markings/ild pattern, # images: 1373 (other: 232844)
# Global: infiltration                            , # images: 2977 (other: 231240)
# Global: linear/patchy atelectasis               , # images: 12797 (other: 221420)
# Global: lobar/segmental collapse                , # images: 9531 (other: 224686)
# Global: lung lesion                             , # images: 13455 (other: 220762)
# Global: lung opacity                            , # images: 154881 (other: 79336)
# Global: mass/nodule (not otherwise specified)   , # images: 7782 (other: 226435)
# Global: mediastinal displacement                , # images: 3438 (other: 230779)
# Global: mediastinal widening                    , # images: 5070 (other: 229147)
# Global: multiple masses/nodules                 , # images: 3730 (other: 230487)
# Global: pleural effusion                        , # images: 72076 (other: 162141)
# Global: pleural/parenchymal scarring            , # images: 14199 (other: 220018)
# Global: pneumomediastinum                       , # images: 864 (other: 233353)
# Global: pneumothorax                            , # images: 10640 (other: 223577)
# Global: pulmonary edema/hazy opacity            , # images: 35280 (other: 198937)
# Global: rib fracture                            , # images: 7080 (other: 227137)
# Global: scoliosis                               , # images: 3201 (other: 231016)
# Global: shoulder osteoarthritis                 , # images: 2178 (other: 232039)
# Global: spinal degenerative changes             , # images: 6810 (other: 227407)
# Global: spinal fracture                         , # images: 3101 (other: 231116)
# Global: sub-diaphragmatic air                   , # images: 1234 (other: 232983)
# Global: subcutaneous air                        , # images: 3377 (other: 230840)
# Global: superior mediastinal mass/enlargement   , # images: 3295 (other: 230922)
# Global: tortuous aorta                          , # images: 13462 (other: 220755)
# Global: vascular calcification                  , # images: 10172 (other: 224045)
# Global: vascular congestion                     , # images: 24614 (other: 209603)
# Global: vascular redistribution                 , # images: 3199 (other: 231018)
# Global: aortic graft/repair                     , # images: 115 (other: 234102)
# Global: cabg grafts                             , # images: 3839 (other: 230378)
# Global: cardiac pacer and wires                 , # images: 12453 (other: 221764)
# Global: prosthetic valve                        , # images: 2891 (other: 231326)
# Global: alveolar hemorrhage                     , # images: 1766 (other: 232451)
# Global: aspiration                              , # images: 8915 (other: 225302)
# Global: copd/emphysema                          , # images: 6553 (other: 227664)
# Global: fluid overload/heart failure            , # images: 6458 (other: 227759)
# Global: goiter                                  , # images: 614 (other: 233603)
# Global: granulomatous disease                   , # images: 2423 (other: 231794)
# Global: interstitial lung disease               , # images: 1943 (other: 232274)
# Global: lung cancer                             , # images: 1752 (other: 232465)
# Global: pericardial effusion                    , # images: 1400 (other: 232817)
# Global: pneumonia                               , # images: 34201 (other: 200016)
# Global: abnormal                                , # images: 184517 (other: 49700)
# Global: artifact                                , # images: 299 (other: 233918)
# Global: breast/nipple shadows                   , # images: 1020 (other: 233197)
# Global: low lung volumes                        , # images: 28214 (other: 206003)
# Global: rotated                                 , # images: 2036 (other: 232181)
# Global: skin fold                               , # images: 216 (other: 234001)
# Global: chest port                              , # images: 7247 (other: 226970)
# Global: chest tube                              , # images: 10271 (other: 223946)
# Global: endotracheal tube                       , # images: 22541 (other: 211676)
# Global: enteric tube                            , # images: 27915 (other: 206302)
# Global: ij line                                 , # images: 12109 (other: 222108)
# Global: intra-aortic balloon pump               , # images: 562 (other: 233655)
# Global: mediastinal drain                       , # images: 436 (other: 233781)
# Global: picc                                    , # images: 14281 (other: 219936)
# Global: pigtail catheter                        , # images: 3538 (other: 230679)
# Global: subclavian line                         , # images: 3883 (other: 230334)
# Global: swan-ganz catheter                      , # images: 2197 (other: 232020)
# Global: tracheostomy tube                       , # images: 4756 (other: 229461)
# --------------------------------------------------
# 9) Creating dataloaders ...
# len(_train_dataloaders) = 1
# len(_val_dataloaders) = 1
# _train_weights = [1.0]
# merged_dataset_name = mim
# --------------------------------------------------
# 10) Attaching metrics, losses, timer and events to engines ...
# --------------------------------------------------
# 11) Defining learning rate scheduler handler ...
# --------------------------------------------------
# 12) Defining checkpoint folder path ...
# checkpoint_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/report_gen/20230505_052756_mim_Labels2ReportModel(74,10,TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))
# metadata saved to /mnt/data/pamessina/workspaces/medvqa-workspace/models/report_gen/20230505_052756_mim_Labels2ReportModel(74,10,TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/metadata.json
# --------------------------------------------------
# 13) Defining log_metrics_handler ...
# MetricsLogger :: we'll be logging to /mnt/data/pamessina/workspaces/medvqa-workspace/models/report_gen/20230505_052756_mim_Labels2ReportModel(74,10,TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/metrics_logs.csv
# --------------------------------------------------
# 14) Running trainer engine ...
# ---- Epoch 1/68
# (1) Training stage (lr = 0.000001) ...
# loss 8.57286, wmdcmp 0.00387, report_loss 8.34282, 180.81 secs
# (2) Validation stage ...
# wmdcmp 0.00349, cD 0.00021, 16.86 secs
# ---- Epoch 2/68
# (1) Training stage (lr = 0.000007) ...
# loss 8.10859, wmdcmp 0.00164, report_loss 6.79789, 162.50 secs
# (2) Validation stage ...
# wmdcmp 0.01030, cD 0.00041, 16.47 secs
# ---- Epoch 3/68
# (1) Training stage (lr = 0.000054) ...
# loss 5.97777, wmdcmp 0.06347, report_loss 4.51340, 157.65 secs
# (2) Validation stage ...
# wmdcmp 0.05982, cD 0.15217, 16.95 secs
# ---- Epoch 4/68
# (1) Training stage (lr = 0.000400) ...
# loss 3.80367, wmdcmp 0.17003, report_loss 2.95103, 144.92 secs
# (2) Validation stage ...
# wmdcmp 0.12851, cD 0.37414, 14.76 secs
# ---- Epoch 5/68
# (1) Training stage (lr = 0.000217) ...
# loss 2.49229, wmdcmp 0.21620, report_loss 2.48806, 138.68 secs
# (2) Validation stage ...
# wmdcmp 0.13038, cD 0.39880, 14.58 secs
# ---- Epoch 6/68
# (1) Training stage (lr = 0.000118) ...
# loss 2.41379, wmdcmp 0.22756, report_loss 2.38542, 132.70 secs
# (2) Validation stage ...
# wmdcmp 0.11586, cD 0.34715, 14.66 secs
# ---- Epoch 7/68
# (1) Training stage (lr = 0.000064) ...
# loss 2.35904, wmdcmp 0.23203, report_loss 2.34379, 133.58 secs
# (2) Validation stage ...
# wmdcmp 0.13299, cD 0.40040, 14.50 secs
# ---- Epoch 8/68
# (1) Training stage (lr = 0.000035) ...
# loss 2.32241, wmdcmp 0.23473, report_loss 2.32077, 131.85 secs
# (2) Validation stage ...
# wmdcmp 0.13312, cD 0.39896, 14.22 secs
# ---- Epoch 9/68
# (1) Training stage (lr = 0.000019) ...
# loss 2.39505, wmdcmp 0.23503, report_loss 2.30634, 131.47 secs
# (2) Validation stage ...
# wmdcmp 0.12028, cD 0.35481, 14.56 secs
# ---- Epoch 10/68
# (1) Training stage (lr = 0.000010) ...
# loss 2.41153, wmdcmp 0.23675, report_loss 2.30315, 131.54 secs
# (2) Validation stage ...
# wmdcmp 0.12863, cD 0.37031, 15.95 secs
# ---- Epoch 11/68
# (1) Training stage (lr = 0.000006) ...
# loss 2.29486, wmdcmp 0.23660, report_loss 2.29744, 131.03 secs
# (2) Validation stage ...
# wmdcmp 0.12263, cD 0.35686, 14.77 secs
# ---- Epoch 12/68
# (1) Training stage (lr = 0.000003) ...
# loss 2.51682, wmdcmp 0.23772, report_loss 2.29715, 130.60 secs
# (2) Validation stage ...
# wmdcmp 0.13529, cD 0.41413, 14.99 secs
# ---- Epoch 13/68
# (1) Training stage (lr = 0.000400) ...
# loss 2.37388, wmdcmp 0.23852, report_loss 2.27539, 129.89 secs
# (2) Validation stage ...
# wmdcmp 0.12263, cD 0.39558, 14.40 secs
# ---- Epoch 14/68
# (1) Training stage (lr = 0.000199) ...
# loss 2.22631, wmdcmp 0.25130, report_loss 2.18021, 127.46 secs
# (2) Validation stage ...
# wmdcmp 0.13281, cD 0.36671, 14.42 secs
# ---- Epoch 15/68
# (1) Training stage (lr = 0.000099) ...
# loss 2.10258, wmdcmp 0.25751, report_loss 2.14512, 127.38 secs
# (2) Validation stage ...
# wmdcmp 0.12511, cD 0.38442, 14.66 secs
# ---- Epoch 16/68
# (1) Training stage (lr = 0.000049) ...
# loss 2.04213, wmdcmp 0.25906, report_loss 2.12421, 127.69 secs
# (2) Validation stage ...
# wmdcmp 0.12515, cD 0.34016, 14.61 secs
# ---- Epoch 17/68
# (1) Training stage (lr = 0.000024) ...
# loss 2.07212, wmdcmp 0.26018, report_loss 2.11738, 125.53 secs
# (2) Validation stage ...
# wmdcmp 0.12316, cD 0.35435, 14.78 secs
# ---- Epoch 18/68
# (1) Training stage (lr = 0.000012) ...
# loss 2.18316, wmdcmp 0.26178, report_loss 2.10896, 127.74 secs
# (2) Validation stage ...
# wmdcmp 0.12969, cD 0.37342, 14.70 secs
# ---- Epoch 19/68
# (1) Training stage (lr = 0.000006) ...
# loss 2.05084, wmdcmp 0.26195, report_loss 2.10363, 127.11 secs
# (2) Validation stage ...
# wmdcmp 0.13106, cD 0.38621, 14.38 secs
# ---- Epoch 20/68
# (1) Training stage (lr = 0.000003) ...
# loss 2.07298, wmdcmp 0.26161, report_loss 2.10807, 127.41 secs
# (2) Validation stage ...
# wmdcmp 0.13050, cD 0.37798, 14.50 secs
# ---- Epoch 21/68
# (1) Training stage (lr = 0.000400) ...
# loss 1.99725, wmdcmp 0.25854, report_loss 2.12262, 128.31 secs
# (2) Validation stage ...
# wmdcmp 0.13694, cD 0.42530, 14.96 secs
# ---- Epoch 22/68
# (1) Training stage (lr = 0.000199) ...
# loss 2.01784, wmdcmp 0.26774, report_loss 2.06081, 127.97 secs
# (2) Validation stage ...
# wmdcmp 0.13604, cD 0.38447, 16.00 secs
# ---- Epoch 23/68
# (1) Training stage (lr = 0.000099) ...
# loss 2.12358, wmdcmp 0.27215, report_loss 2.03145, 125.85 secs
# (2) Validation stage ...
# wmdcmp 0.13272, cD 0.37554, 14.63 secs
# ---- Epoch 24/68
# (1) Training stage (lr = 0.000049) ...
# loss 2.04897, wmdcmp 0.27460, report_loss 2.01618, 125.81 secs
# (2) Validation stage ...
# wmdcmp 0.11907, cD 0.34168, 16.07 secs
# ---- Epoch 25/68
# (1) Training stage (lr = 0.000024) ...
# loss 1.98024, wmdcmp 0.27433, report_loss 2.01112, 128.08 secs
# (2) Validation stage ...
# wmdcmp 0.13205, cD 0.36018, 14.63 secs
# ---- Epoch 26/68
# (1) Training stage (lr = 0.000012) ...
# loss 1.99060, wmdcmp 0.27526, report_loss 2.01104, 125.55 secs
# (2) Validation stage ...
# wmdcmp 0.12951, cD 0.35397, 14.65 secs
# ---- Epoch 27/68
# (1) Training stage (lr = 0.000006) ...
# loss 1.99855, wmdcmp 0.27515, report_loss 2.00512, 127.05 secs
# (2) Validation stage ...
# wmdcmp 0.12830, cD 0.35831, 14.58 secs
# ---- Epoch 28/68
# (1) Training stage (lr = 0.000003) ...
# loss 1.96642, wmdcmp 0.27569, report_loss 2.00281, 127.08 secs
# (2) Validation stage ...
# wmdcmp 0.12942, cD 0.35549, 14.72 secs
# ---- Epoch 29/68
# (1) Training stage (lr = 0.000400) ...
# loss 1.94654, wmdcmp 0.27065, report_loss 2.03287, 126.72 secs
# (2) Validation stage ...
# wmdcmp 0.13529, cD 0.43276, 14.64 secs
# ---- Epoch 30/68
# (1) Training stage (lr = 0.000199) ...
# loss 2.01722, wmdcmp 0.27835, report_loss 1.98341, 127.75 secs
# (2) Validation stage ...
# wmdcmp 0.13321, cD 0.36622, 14.68 secs
# ---- Epoch 31/68
# (1) Training stage (lr = 0.000099) ...
# loss 1.92078, wmdcmp 0.28257, report_loss 1.95708, 126.43 secs
# (2) Validation stage ...
# wmdcmp 0.12273, cD 0.34603, 14.80 secs
# ---- Epoch 32/68
# (1) Training stage (lr = 0.000049) ...
# loss 1.93376, wmdcmp 0.28410, report_loss 1.94705, 125.57 secs
# (2) Validation stage ...
# wmdcmp 0.13270, cD 0.35865, 14.61 secs
# ---- Epoch 33/68
# (1) Training stage (lr = 0.000024) ...
# loss 1.92623, wmdcmp 0.28667, report_loss 1.93564, 127.39 secs
# (2) Validation stage ...
# wmdcmp 0.12648, cD 0.35155, 14.58 secs
# ---- Epoch 34/68
# (1) Training stage (lr = 0.000012) ...
# loss 1.93860, wmdcmp 0.28651, report_loss 1.93192, 125.80 secs
# (2) Validation stage ...
# wmdcmp 0.13073, cD 0.35957, 15.35 secs
# ---- Epoch 35/68
# (1) Training stage (lr = 0.000006) ...
# loss 1.95623, wmdcmp 0.28706, report_loss 1.93051, 127.83 secs
# (2) Validation stage ...
# wmdcmp 0.13078, cD 0.36222, 15.34 secs
# ---- Epoch 36/68
# (1) Training stage (lr = 0.000003) ...
# loss 1.90515, wmdcmp 0.28729, report_loss 1.92745, 126.49 secs
# (2) Validation stage ...
# wmdcmp 0.12735, cD 0.36300, 14.69 secs
# ---- Epoch 37/68
# (1) Training stage (lr = 0.000400) ...
# loss 1.91440, wmdcmp 0.27981, report_loss 1.96465, 129.68 secs
# (2) Validation stage ...
# wmdcmp 0.13634, cD 0.40142, 14.60 secs
# ---- Epoch 38/68
# (1) Training stage (lr = 0.000199) ...
# loss 1.94418, wmdcmp 0.28672, report_loss 1.92814, 126.06 secs
# (2) Validation stage ...
# wmdcmp 0.13736, cD 0.40552, 14.90 secs
# ---- Epoch 39/68
# (1) Training stage (lr = 0.000099) ...
# loss 1.96979, wmdcmp 0.29031, report_loss 1.90121, 127.65 secs
# (2) Validation stage ...
# wmdcmp 0.11803, cD 0.33080, 14.72 secs
# ---- Epoch 40/68
# (1) Training stage (lr = 0.000049) ...
# loss 1.93320, wmdcmp 0.29113, report_loss 1.89263, 125.68 secs
# (2) Validation stage ...
# wmdcmp 0.12961, cD 0.40523, 14.77 secs
# ---- Epoch 41/68
# (1) Training stage (lr = 0.000024) ...
# loss 1.83097, wmdcmp 0.29384, report_loss 1.88478, 127.21 secs
# (2) Validation stage ...
# wmdcmp 0.13365, cD 0.41364, 14.56 secs
# ---- Epoch 42/68
# (1) Training stage (lr = 0.000012) ...
# loss 1.91135, wmdcmp 0.29349, report_loss 1.88070, 127.37 secs
# (2) Validation stage ...
# wmdcmp 0.12409, cD 0.36041, 14.66 secs
# ---- Epoch 43/68
# (1) Training stage (lr = 0.000006) ...
# loss 1.87621, wmdcmp 0.29426, report_loss 1.87700, 127.58 secs
# (2) Validation stage ...
# wmdcmp 0.12509, cD 0.35745, 14.43 secs
# ---- Epoch 44/68
# (1) Training stage (lr = 0.000003) ...
# loss 1.93032, wmdcmp 0.29515, report_loss 1.87455, 126.44 secs
# (2) Validation stage ...
# wmdcmp 0.12816, cD 0.36993, 14.67 secs
# ---- Epoch 45/68
# (1) Training stage (lr = 0.000400) ...
# loss 1.84517, wmdcmp 0.28771, report_loss 1.91059, 125.95 secs
# (2) Validation stage ...
# wmdcmp 0.13079, cD 0.39061, 14.63 secs
# ---- Epoch 46/68
# (1) Training stage (lr = 0.000199) ...
# loss 1.91241, wmdcmp 0.29462, report_loss 1.87708, 125.38 secs
# (2) Validation stage ...
# wmdcmp 0.13370, cD 0.36251, 14.33 secs
# ---- Epoch 47/68
# (1) Training stage (lr = 0.000099) ...
# loss 1.97354, wmdcmp 0.29791, report_loss 1.85726, 125.21 secs
# (2) Validation stage ...
# wmdcmp 0.11847, cD 0.34128, 16.19 secs
# ---- Epoch 48/68
# (1) Training stage (lr = 0.000049) ...
# loss 1.94404, wmdcmp 0.29906, report_loss 1.84596, 126.51 secs
# (2) Validation stage ...
# wmdcmp 0.12057, cD 0.32549, 15.66 secs
# ---- Epoch 49/68
# (1) Training stage (lr = 0.000024) ...
# loss 2.00095, wmdcmp 0.30014, report_loss 1.84002, 127.02 secs
# (2) Validation stage ...
# wmdcmp 0.13002, cD 0.37010, 15.58 secs
# ---- Epoch 50/68
# (1) Training stage (lr = 0.000012) ...
# loss 1.89366, wmdcmp 0.30234, report_loss 1.83027, 127.66 secs
# (2) Validation stage ...
# wmdcmp 0.13568, cD 0.41269, 14.77 secs
# ---- Epoch 51/68
# (1) Training stage (lr = 0.000006) ...
# loss 1.83300, wmdcmp 0.30079, report_loss 1.83375, 127.19 secs
# (2) Validation stage ...
# wmdcmp 0.12451, cD 0.35541, 14.60 secs
# ---- Epoch 52/68
# (1) Training stage (lr = 0.000003) ...
# loss 1.79728, wmdcmp 0.30164, report_loss 1.82891, 123.45 secs
# (2) Validation stage ...
# wmdcmp 0.12844, cD 0.35544, 14.57 secs
# ---- Epoch 53/68
# (1) Training stage (lr = 0.000400) ...
# loss 1.69351, wmdcmp 0.29274, report_loss 1.87306, 124.52 secs
# (2) Validation stage ...
# wmdcmp 0.13714, cD 0.41397, 14.46 secs
# ---- Epoch 54/68
# (1) Training stage (lr = 0.000199) ...
# loss 1.82997, wmdcmp 0.29877, report_loss 1.84250, 123.40 secs
# (2) Validation stage ...
# wmdcmp 0.12064, cD 0.34160, 14.40 secs
# ---- Epoch 55/68
# (1) Training stage (lr = 0.000099) ...
# loss 1.83822, wmdcmp 0.30283, report_loss 1.82056, 122.43 secs
# (2) Validation stage ...
# wmdcmp 0.12164, cD 0.34718, 14.08 secs
# ---- Epoch 56/68
# (1) Training stage (lr = 0.000049) ...
# loss 1.83097, wmdcmp 0.30322, report_loss 1.81333, 122.98 secs
# (2) Validation stage ...
# wmdcmp 0.12413, cD 0.35694, 14.27 secs
# ---- Epoch 57/68
# (1) Training stage (lr = 0.000024) ...
# loss 1.64818, wmdcmp 0.30572, report_loss 1.80326, 122.91 secs
# (2) Validation stage ...
# wmdcmp 0.13014, cD 0.42097, 14.27 secs
# ---- Epoch 58/68
# (1) Training stage (lr = 0.000012) ...
# loss 1.75274, wmdcmp 0.30696, report_loss 1.79349, 121.31 secs
# (2) Validation stage ...
# wmdcmp 0.12404, cD 0.35592, 14.24 secs
# ---- Epoch 59/68
# (1) Training stage (lr = 0.000006) ...
# loss 1.71149, wmdcmp 0.30687, report_loss 1.79308, 123.77 secs
# (2) Validation stage ...
# wmdcmp 0.12538, cD 0.36268, 14.40 secs
# ---- Epoch 60/68
# (1) Training stage (lr = 0.000003) ...
# loss 1.81381, wmdcmp 0.30782, report_loss 1.79153, 123.05 secs
# (2) Validation stage ...
# wmdcmp 0.12771, cD 0.36747, 14.19 secs
# ---- Epoch 61/68
# (1) Training stage (lr = 0.000400) ...
# loss 1.86134, wmdcmp 0.29794, report_loss 1.83584, 122.96 secs
# (2) Validation stage ...
# wmdcmp 0.13293, cD 0.36776, 14.34 secs
# ---- Epoch 62/68
# (1) Training stage (lr = 0.000199) ...
# loss 1.89273, wmdcmp 0.30308, report_loss 1.81148, 123.91 secs
# (2) Validation stage ...
# wmdcmp 0.11650, cD 0.33920, 13.79 secs
# ---- Epoch 63/68
# (1) Training stage (lr = 0.000099) ...
# loss 1.85422, wmdcmp 0.30614, report_loss 1.78968, 117.90 secs
# (2) Validation stage ...
# wmdcmp 0.11787, cD 0.35063, 17.94 secs
# ---- Epoch 64/68
# (1) Training stage (lr = 0.000049) ...
# loss 1.84588, wmdcmp 0.30782, report_loss 1.78388, 128.01 secs
# (2) Validation stage ...
# wmdcmp 0.13620, cD 0.39905, 13.74 secs
# ---- Epoch 65/68
# (1) Training stage (lr = 0.000024) ...
# loss 1.69162, wmdcmp 0.31193, report_loss 1.76724, 123.56 secs
# (2) Validation stage ...
# wmdcmp 0.12996, cD 0.36120, 12.50 secs
# ---- Epoch 66/68
# (1) Training stage (lr = 0.000012) ...
# loss 1.63026, wmdcmp 0.31241, report_loss 1.76078, 123.61 secs
# (2) Validation stage ...
# wmdcmp 0.12533, cD 0.35944, 15.00 secs
# ---- Epoch 67/68
# (1) Training stage (lr = 0.000006) ...
# loss 1.78883, wmdcmp 0.31120, report_loss 1.76315, 111.18 secs
# (2) Validation stage ...
# wmdcmp 0.13000, cD 0.41592, 14.40 secs
# ---- Epoch 68/68
# (1) Training stage (lr = 0.000003) ...
# loss 1.71269, wmdcmp 0.31198, report_loss 1.75961, 131.52 secs
# (2) Validation stage ...
# wmdcmp 0.13376, cD 0.41044, 16.96 secs

# %%
# !/home/pamessina/venv2/bin/python ../train_labels2report.py \
    --generation-mode "pred2rep" \
    --use-ensemble \
    --ensemble-model-checkpoint-folder-paths \
        "/mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/" \
    --ensemble-batch-size 160 \
    --ensemble-num-workers 3 \
    --use-hard-predictions \
    --filter-labels \
    --label-score-threshold 0.3 \
    --epochs 68 \
    --batches-per-epoch 300 \
    --batch-size 200 \
    --num-workers 2 \
    --iters-to-accumulate 2 \
    --optimizer-name "adamw" \
    --scheduler "exp-warmup+decay+cyclicdecay" \
    --lr 1e-6 \
    --warmup-decay-and-cyclic-decay-args "1e-6,3,4e-4,8,3e-6,4e-4,8,3e-6" \
    --use-mimiccxr \
    --mimiccxr-weight 1.0 \
    --mimiccxr-view-mode "chest_imagenome" \
    --mimiccxr-balanced-sampling-mode "balanced_chest_imagenome_global_labels_batchwise" \
    --mimiccxr-balanced-batch-size 30 \
    --mimiccxr-qa-adapted-reports-filename "qa_adapted_reports__20220904_095810.json" \
    --use-chest-imagenome \
    --use-chest-imagenome-decent-images-only \
    --chest-imagenome-label-names-filename "labels(min_freq=100).pkl" \
    --chest-imagenome-labels-filename "imageId2labels(min_freq=100).pkl" \
    --use-chexpert \
    --mimiccxr-chexpert-labels-filename "chexpert_labels_per_report__20220904_113605.pkl" \
    --use-medical-tokenization \
    --medical-terms-frequency-filename "medical_terms_frequency__20220918_184255.pkl" \
    --binary-loss-name "focal+bce+wbce-c" \
    --labels-hidden-dim 1024 \
    --embedding-dim 512 \
    --transf-dec-num-memory-vecs 10 \
    --transf-dec-hidden-dim 512 \
    --transf-dec-nhead 4 \
    --transf-dec-dim-forward 512 \
    --transf-dec-num-layers 3 \
    --use-amp \
    --save
# Out:
# script's arguments:
#    epochs: 68
#    batches_per_epoch: 300
#    batch_size: 200
#    checkpoint_folder: None
#    generation_mode: pred2rep
#    use_ensemble: True
#    ensemble_model_checkpoint_folder_paths: ['/mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/']
#    ensemble_batch_size: 160
#    ensemble_num_workers: 3
#    use_hard_predictions: True
#    pretrained_checkpoint_folder_path: None
#    labels_hidden_dim: 1024
#    embedding_dim: 512
#    transf_dec_num_memory_vecs: 10
#    transf_dec_hidden_dim: 512
#    transf_dec_nhead: 4
#    transf_dec_dim_forward: 512
#    transf_dec_num_layers: 3
#    dropout_prob: 0
#    vocab_min_freq: 10
#    use_medical_tokenization: True
#    medical_terms_frequency_filename: medical_terms_frequency__20220918_184255.pkl
#    optimizer_name: adamw
#    lr: 1e-06
#    scheduler: exp-warmup+decay+cyclicdecay
#    lr_decay: 0.76
#    lr_decay_patience: 2
#    warmup_and_decay_args: None
#    warmup_and_cosine_args: None
#    warmup_decay_and_cyclic_decay_args: 1e-6,3,4e-4,8,3e-6,4e-4,8,3e-6
#    iters_to_accumulate: 2
#    override_lr: False
#    binary_loss_name: focal+bce+wbce-c
#    focal_loss_weight: 1
#    bce_loss_weight: 1
#    wbce_loss_weight: 1
#    num_workers: 2
#    device: GPU
#    use_amp: True
#    train_mimiccxr: True
#    mimiccxr_weight: 1.0
#    mimiccxr_view_mode: chest_imagenome
#    mimiccxr_balanced_sampling_mode: balanced_chest_imagenome_global_labels_batchwise
#    mimiccxr_balanced_batch_size: 30
#    mimiccxr_qa_adapted_reports_filename: qa_adapted_reports__20220904_095810.json
#    chest_imagenome_labels_filename: imageId2labels(min_freq=100).pkl
#    chest_imagenome_label_names_filename: labels(min_freq=100).pkl
#    use_chest_imagenome_decent_images_only: True
#    save: True
#    use_gender: False
#    use_chexpert: True
#    mimiccxr_chexpert_labels_filename: chexpert_labels_per_report__20220904_113605.pkl
#    use_chest_imagenome: True
#    filter_labels: True
#    top_k_chexpert_labels: None
#    top_k_chest_imagenome_labels: None
#    label_score_threshold: 0.3
#    debug: False
# ----- Training model from scratch ------
# Computing number of labels and ranges for ensemble ...
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/metadata.json
# chest_imagenome_range: (0, 627)
# chexpert_range: (627, 641)
# ============================================================
# Precomputing sigmoid activations for ensemble ...
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/metadata.json
# ============================================================
# Model 1/1
# model_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/
# checkpoint_names = ['checkpoint_79_chou+chuc+chuc+chuc+chuc+cD+gacc+wmmp=0.6677.pt', 'checkpoint_135_chou+chuc+chuc+chuc+chuc+cD+gacc+wmmp=0.6689.pt']
# model_checkpoint_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/checkpoint_135_chou+chuc+chuc+chuc+chuc+cD+gacc+wmmp=0.6689.pt
# precomputed_chexpert_sigmoids_path = /mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/precomputed_chexpert_sigmoids(hash=340,3716123060218160099).pkl
# Precomputed sigmoids for CheXpert already exist.
# File size = 56.39 MB
# precomputed_chest_imagenome_sigmoids_path = /mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/precomputed_chest_imagenome_sigmoids(hash=347,2103260294420767687).pkl
# Precomputed sigmoids for Chest ImaGenome already exist.
# File size = 339.66 MB
# Skipping...
# precomputed_sigmoid_paths: [{'model_folder_path': '/mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/', 'chexpert_sigmoids_path': '/mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/precomputed_chexpert_sigmoids(hash=340,3716123060218160099).pkl', 'chest_imagenome_sigmoids_path': '/mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/precomputed_chest_imagenome_sigmoids(hash=347,2103260294420767687).pkl'}]
# ============================================================
# Precomputing thresholds (for hard predictions) for ensemble ...
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/metadata.json
# ============================================================
# Model 1/1
# model_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/
# checkpoint_names = ['checkpoint_79_chou+chuc+chuc+chuc+chuc+cD+gacc+wmmp=0.6677.pt', 'checkpoint_135_chou+chuc+chuc+chuc+chuc+cD+gacc+wmmp=0.6689.pt']
# model_checkpoint_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/checkpoint_135_chou+chuc+chuc+chuc+chuc+cD+gacc+wmmp=0.6689.pt
# results_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/results/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/
# get_image_transform()
#   Using bounding box aware transforms
#     Returning default transform (no augmentation)
# Calibrating thresholds on MIMIC-CXR validation set
# score_name: f1
# Thresholds for CheXpert already cached at /mnt/data/pamessina/workspaces/medvqa-workspace/results/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/thresholds_chexpert(f1).pkl
# Thresholds for Chest ImaGenome already cached at /mnt/data/pamessina/workspaces/medvqa-workspace/results/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/thresholds_chest_imagenome(f1).pkl
# precomputed_thresholds_paths: [{'chexpert': '/mnt/data/pamessina/workspaces/medvqa-workspace/results/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/thresholds_chexpert(f1).pkl', 'chest_imagenome': '/mnt/data/pamessina/workspaces/medvqa-workspace/results/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/thresholds_chest_imagenome(f1).pkl'}]
# ============================================================
# Precomputing filtered labels for ensemble ...
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/metadata.json
# ============================================================
# Model 1/1
# model_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/
# results_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/results/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/
# get_image_transform()
#   Using bounding box aware transforms
#     Returning default transform (no augmentation)
# Loading cached chexpert predictions and ground truth...
# len(dicom_id_to_pred_chexpert_probs): 3389
# len(dicom_id_to_gt_chexpert_labels): 3389
# Loading cached chest imagenome predictions and ground truth...
# len(dicom_id_to_pred_chest_imagenome_probs): 3389
# len(dicom_id_to_gt_chest_imagenome_labels): 3389
# Top 9 label classes with the highest f1 scores:
# 1. Support Devices: 0.8737220226581928
# 2. Pleural Effusion: 0.743933588761175
# 3. Cardiomegaly: 0.7198264171413074
# 4. Lung Opacity: 0.6673640167364017
# 5. Edema: 0.6276923076923075
# 6. Atelectasis: 0.6112539274493003
# 7. Pneumonia: 0.45472363778910235
# 8. Enlarged Cardiomediastinum: 0.44780145670353394
# 9. No Finding: 0.37368421052631584
# Top 122 label classes with the highest f1 scores:
# 1. ('nlp', 'abnormal'): 0.9645215788665336
# 7. ('mediastinum', 'device', 'cardiac pacer and wires'): 0.84472049689441
# 13. ('anatomicalfinding', 'pleural effusion'): 0.7588336192109778
# 20. ('right costophrenic angle', 'nlp', 'abnormal'): 0.7209039548022601
# 26. ('right chest wall', 'anatomicalfinding', 'subcutaneous air'): 0.6962962962962962
# 32. ('right hilar structures', 'nlp', 'abnormal'): 0.674488567990373
# 39. ('anatomicalfinding', 'atelectasis'): 0.636920384951881
# 45. ('tubesandlines', 'ij line'): 0.6063694267515923
# 51. ('right lung', 'anatomicalfinding', 'pulmonary edema/hazy opacity'): 0.5773718924403857
# 58. ('neck', 'tubesandlines', 'tracheostomy tube'): 0.5405405405405405
# 64. ('right lung', 'anatomicalfinding', 'atelectasis'): 0.5201032829214312
# 71. ('right chest wall', 'nlp', 'abnormal'): 0.4830917874396135
# 77. ('right hilar structures', 'tubesandlines', 'swan-ganz catheter'): 0.4444444444444444
# 83. ('right hemidiaphragm', 'anatomicalfinding', 'elevated hemidiaphragm'): 0.425
# 90. ('svc', 'tubesandlines', 'ij line'): 0.39819004524886875
# 96. ('cardiac silhouette', 'device', 'prosthetic valve'): 0.3867403314917127
# 102. ('right lower lung zone', 'anatomicalfinding', 'pleural effusion'): 0.3741293532338309
# 109. ('aortic arch', 'nlp', 'abnormal'): 0.33807266982622436
# 115. ('mediastinum', 'anatomicalfinding', 'tortuous aorta'): 0.3180592991913746
# 122. ('anatomicalfinding', 'tortuous aorta'): 0.3
# precomputed_filtered_labels_paths: [{'chexpert_indices_path': '/mnt/data/pamessina/workspaces/medvqa-workspace/results/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/chexpert_top_9_out_of_14_labels_f1_(score_threshold_0.30)_indices.pkl', 'chexpert_num_indices': 9, 'chest_imagenome_indices_path': '/mnt/data/pamessina/workspaces/medvqa-workspace/results/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/chest_imagenome_top_122_out_of_627_labels_f1_(score_threshold_0.30)_indices.pkl', 'chest_imagenome_num_indices': 122}]
# num_input_labels (after update): 131
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Initializing tokenizer ...
# Loading /mnt/data/pamessina/workspaces/medvqa-workspace/cache/vocab(min_freq=10;mode=report;qa_adapted_reports__20220904_095810.json).pkl ...
# --------------------------------------------------
# 3) Creating instance of Labels2ReportModel ...
# Labels2ReportModel
#   gen_mode: pred2rep
#   vocab_size: 4833
#   embedding_dim: 512
#   num_input_labels: 131
#   labels_hidden_dim: 1024
#   num_output_labels: 641
#   transf_dec_num_memory_vecs: 10
#   transf_dec_hidden_dim: 512
#   transf_dec_nhead: 4
#   transf_dec_dim_forward: 512
#   transf_dec_num_layers: 3
#   start_idx: 1
#   dropout_prob: 0
# --------------------------------------------------
# 4) Defining optimizer ...
# create_optimizer(): name = adamw
# --------------------------------------------------
# 5) Defining scheduler ...
# Using exp-warmup+decay+cyclicdecay scheduler: 1e-6,3,4e-4,8,3e-6,4e-4,8,3e-6
# 1e-06 3 0.0004 8 3e-06 0.0004 8 3e-06
# self.steps_to_restart = 8
# self.steps = -1
# self.initial_lr = 0.0004
# --------------------------------------------------
# 6) Creating trainer and validator engines ...
# Using focal+bce+wbce-c loss
# binary_loss_kwargs: {'focal_weight': 1, 'bce_weight': 1, 'wbce_weight': 1}
# --------------------------------------------------
# 7) Defining collate_batch_fn ...
# --------------------------------------------------
# 8) Creating MIMIC-CXR_Labels2ReportTrainer ...
# 227835it [00:22, 10318.38it/s]
# max_idx_count = 377110
# actual_idx_count = 239513
# ** NOTE: 137597 images were skipped because they were not in the allowed DICOM IDs
# Random report:
# <s> semi upright . right picc tip terminates upper svc . cardiac , mediastinal hilar contours normal heart size normal . lungs clear . no pleural effusion pneumothorax . no osseous abnormality . right picc tip upper svc </s>
# len(self.train_indices) = 234217
# len(self.val_indices) = 1934
# Loading CheXpert labels...
# Loading Chest Imagenome labels...
# Loading precomputed sigmoid paths for ensemble predictions...
#   Loading /mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/precomputed_chexpert_sigmoids(hash=340,3716123060218160099).pkl
#     _probs.shape = (242280, 14)
#     len(_dids) = 242280
#     _thresholds.shape = (14,)
#     _probs has been thresholded
#     _label_indices.shape = (9,)
#     _probs has been filtered
#     Sanity checking chexpert labels
#     len(self.val_indices) = 1934
#     f1_score(_gt_labels, _pred_labels, average="micro") = 0.6198093391501049
#     f1_score(_gt_labels, _pred_labels, average="macro") = 0.6130891345703472
#   Loading /mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/precomputed_chest_imagenome_sigmoids(hash=347,2103260294420767687).pkl
#     _probs.shape = (242280, 627)
#     len(_dids) = 242280
#     _thresholds.shape = (627,)
#     _probs has been thresholded
#     _label_indices.shape = (122,)
#     _probs has been filtered
#     Sanity checking chest_imagenome labels
#     len(self.val_indices) = 1934
#     f1_score(_gt_labels, _pred_labels, average="micro") = 0.6411629482971685
#     f1_score(_gt_labels, _pred_labels, average="macro") = 0.5273377674096739
# Done loading precomputed sigmoid paths for ensemble predictions
# Balanced sampling mode: balanced_chest_imagenome_global_labels_batchwise
# Regrouping indices by Chest Imagenome labels for balanced sampling...
# 627it [01:11,  8.76it/s]
# Global: airspace opacity                        , # images: 8595 (other: 225622)
# Global: atelectasis                             , # images: 79106 (other: 155111)
# Global: bone lesion                             , # images: 1692 (other: 232525)
# Global: bronchiectasis                          , # images: 905 (other: 233312)
# Global: calcified nodule                        , # images: 2708 (other: 231509)
# Global: clavicle fracture                       , # images: 862 (other: 233355)
# Global: consolidation                           , # images: 17769 (other: 216448)
# Global: costophrenic angle blunting             , # images: 5723 (other: 228494)
# Global: cyst/bullae                             , # images: 874 (other: 233343)
# Global: elevated hemidiaphragm                  , # images: 6412 (other: 227805)
# Global: enlarged cardiac silhouette             , # images: 57654 (other: 176563)
# Global: enlarged hilum                          , # images: 8983 (other: 225234)
# Global: hernia                                  , # images: 3025 (other: 231192)
# Global: hydropneumothorax                       , # images: 954 (other: 233263)
# Global: hyperaeration                           , # images: 10306 (other: 223911)
# Global: increased reticular markings/ild pattern, # images: 1373 (other: 232844)
# Global: infiltration                            , # images: 2977 (other: 231240)
# Global: linear/patchy atelectasis               , # images: 12797 (other: 221420)
# Global: lobar/segmental collapse                , # images: 9531 (other: 224686)
# Global: lung lesion                             , # images: 13455 (other: 220762)
# Global: lung opacity                            , # images: 154881 (other: 79336)
# Global: mass/nodule (not otherwise specified)   , # images: 7782 (other: 226435)
# Global: mediastinal displacement                , # images: 3438 (other: 230779)
# Global: mediastinal widening                    , # images: 5070 (other: 229147)
# Global: multiple masses/nodules                 , # images: 3730 (other: 230487)
# Global: pleural effusion                        , # images: 72076 (other: 162141)
# Global: pleural/parenchymal scarring            , # images: 14199 (other: 220018)
# Global: pneumomediastinum                       , # images: 864 (other: 233353)
# Global: pneumothorax                            , # images: 10640 (other: 223577)
# Global: pulmonary edema/hazy opacity            , # images: 35280 (other: 198937)
# Global: rib fracture                            , # images: 7080 (other: 227137)
# Global: scoliosis                               , # images: 3201 (other: 231016)
# Global: shoulder osteoarthritis                 , # images: 2178 (other: 232039)
# Global: spinal degenerative changes             , # images: 6810 (other: 227407)
# Global: spinal fracture                         , # images: 3101 (other: 231116)
# Global: sub-diaphragmatic air                   , # images: 1234 (other: 232983)
# Global: subcutaneous air                        , # images: 3377 (other: 230840)
# Global: superior mediastinal mass/enlargement   , # images: 3295 (other: 230922)
# Global: tortuous aorta                          , # images: 13462 (other: 220755)
# Global: vascular calcification                  , # images: 10172 (other: 224045)
# Global: vascular congestion                     , # images: 24614 (other: 209603)
# Global: vascular redistribution                 , # images: 3199 (other: 231018)
# Global: aortic graft/repair                     , # images: 115 (other: 234102)
# Global: cabg grafts                             , # images: 3839 (other: 230378)
# Global: cardiac pacer and wires                 , # images: 12453 (other: 221764)
# Global: prosthetic valve                        , # images: 2891 (other: 231326)
# Global: alveolar hemorrhage                     , # images: 1766 (other: 232451)
# Global: aspiration                              , # images: 8915 (other: 225302)
# Global: copd/emphysema                          , # images: 6553 (other: 227664)
# Global: fluid overload/heart failure            , # images: 6458 (other: 227759)
# Global: goiter                                  , # images: 614 (other: 233603)
# Global: granulomatous disease                   , # images: 2423 (other: 231794)
# Global: interstitial lung disease               , # images: 1943 (other: 232274)
# Global: lung cancer                             , # images: 1752 (other: 232465)
# Global: pericardial effusion                    , # images: 1400 (other: 232817)
# Global: pneumonia                               , # images: 34201 (other: 200016)
# Global: abnormal                                , # images: 184517 (other: 49700)
# Global: artifact                                , # images: 299 (other: 233918)
# Global: breast/nipple shadows                   , # images: 1020 (other: 233197)
# Global: low lung volumes                        , # images: 28214 (other: 206003)
# Global: rotated                                 , # images: 2036 (other: 232181)
# Global: skin fold                               , # images: 216 (other: 234001)
# Global: chest port                              , # images: 7247 (other: 226970)
# Global: chest tube                              , # images: 10271 (other: 223946)
# Global: endotracheal tube                       , # images: 22541 (other: 211676)
# Global: enteric tube                            , # images: 27915 (other: 206302)
# Global: ij line                                 , # images: 12109 (other: 222108)
# Global: intra-aortic balloon pump               , # images: 562 (other: 233655)
# Global: mediastinal drain                       , # images: 436 (other: 233781)
# Global: picc                                    , # images: 14281 (other: 219936)
# Global: pigtail catheter                        , # images: 3538 (other: 230679)
# Global: subclavian line                         , # images: 3883 (other: 230334)
# Global: swan-ganz catheter                      , # images: 2197 (other: 232020)
# Global: tracheostomy tube                       , # images: 4756 (other: 229461)
# --------------------------------------------------
# 9) Creating dataloaders ...
# len(_train_dataloaders) = 1
# len(_val_dataloaders) = 1
# _train_weights = [1.0]
# merged_dataset_name = mim
# --------------------------------------------------
# 10) Attaching metrics, losses, timer and events to engines ...
# --------------------------------------------------
# 11) Defining learning rate scheduler handler ...
# --------------------------------------------------
# 12) Defining checkpoint folder path ...
# checkpoint_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/report_gen/20230505_081502_mim_Labels2ReportModel(131,10,TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))
# metadata saved to /mnt/data/pamessina/workspaces/medvqa-workspace/models/report_gen/20230505_081502_mim_Labels2ReportModel(131,10,TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/metadata.json
# --------------------------------------------------
# 13) Defining log_metrics_handler ...
# MetricsLogger :: we'll be logging to /mnt/data/pamessina/workspaces/medvqa-workspace/models/report_gen/20230505_081502_mim_Labels2ReportModel(131,10,TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/metrics_logs.csv
# --------------------------------------------------
# 14) Running trainer engine ...
# ---- Epoch 1/68
# (1) Training stage (lr = 0.000001) ...
# loss 8.58075, wmdcmp 0.00608, report_loss 8.34058, 178.46 secs
# (2) Validation stage ...
# wmdcmp 0.00052, cD 0.00025, 13.92 secs
# ---- Epoch 2/68
# (1) Training stage (lr = 0.000007) ...
# loss 8.09347, wmdcmp 0.00049, report_loss 6.81285, 161.15 secs
# (2) Validation stage ...
# wmdcmp 0.00052, cD 0.00042, 15.20 secs
# ---- Epoch 3/68
# (1) Training stage (lr = 0.000054) ...
# loss 6.00904, wmdcmp 0.05661, report_loss 4.54850, 159.15 secs
# (2) Validation stage ...
# wmdcmp 0.03507, cD 0.00345, 15.01 secs
# ---- Epoch 4/68
# (1) Training stage (lr = 0.000400) ...
# loss 3.84964, wmdcmp 0.16660, report_loss 2.98905, 147.10 secs
# (2) Validation stage ...
# wmdcmp 0.12333, cD 0.36021, 14.27 secs
# ---- Epoch 5/68
# (1) Training stage (lr = 0.000217) ...
# loss 2.59379, wmdcmp 0.21351, report_loss 2.49110, 143.48 secs
# (2) Validation stage ...
# wmdcmp 0.12890, cD 0.35149, 14.47 secs
# ---- Epoch 6/68
# (1) Training stage (lr = 0.000118) ...
# loss 2.43907, wmdcmp 0.22530, report_loss 2.38770, 139.67 secs
# (2) Validation stage ...
# wmdcmp 0.13325, cD 0.40179, 14.23 secs
# ---- Epoch 7/68
# (1) Training stage (lr = 0.000064) ...
# loss 2.29028, wmdcmp 0.23137, report_loss 2.33709, 133.82 secs
# (2) Validation stage ...
# wmdcmp 0.13873, cD 0.44087, 14.39 secs
# ---- Epoch 8/68
# (1) Training stage (lr = 0.000035) ...
# loss 2.24920, wmdcmp 0.23488, report_loss 2.31061, 133.55 secs
# (2) Validation stage ...
# wmdcmp 0.13704, cD 0.41337, 14.22 secs
# ---- Epoch 9/68
# (1) Training stage (lr = 0.000019) ...
# loss 2.33198, wmdcmp 0.23562, report_loss 2.30278, 132.41 secs
# (2) Validation stage ...
# wmdcmp 0.13302, cD 0.41759, 14.35 secs
# ---- Epoch 10/68
# (1) Training stage (lr = 0.000010) ...
# loss 2.39258, wmdcmp 0.23653, report_loss 2.29456, 131.51 secs
# (2) Validation stage ...
# wmdcmp 0.13099, cD 0.38260, 14.24 secs
# ---- Epoch 11/68
# (1) Training stage (lr = 0.000006) ...
# loss 2.33236, wmdcmp 0.23657, report_loss 2.28979, 132.39 secs
# (2) Validation stage ...
# wmdcmp 0.13692, cD 0.43043, 14.44 secs
# ---- Epoch 12/68
# (1) Training stage (lr = 0.000003) ...
# loss 2.27294, wmdcmp 0.23743, report_loss 2.28917, 132.20 secs
# (2) Validation stage ...
# wmdcmp 0.13748, cD 0.42872, 14.44 secs
# ---- Epoch 13/68
# (1) Training stage (lr = 0.000400) ...
# loss 2.38594, wmdcmp 0.23999, report_loss 2.25870, 128.55 secs
# (2) Validation stage ...
# wmdcmp 0.13041, cD 0.42617, 14.43 secs
# ---- Epoch 14/68
# (1) Training stage (lr = 0.000199) ...
# loss 2.14672, wmdcmp 0.25049, report_loss 2.17549, 124.19 secs
# (2) Validation stage ...
# wmdcmp 0.13141, cD 0.36861, 14.29 secs
# ---- Epoch 15/68
# (1) Training stage (lr = 0.000099) ...
# loss 2.02941, wmdcmp 0.25734, report_loss 2.13504, 122.95 secs
# (2) Validation stage ...
# wmdcmp 0.13059, cD 0.38428, 14.27 secs
# ---- Epoch 16/68
# (1) Training stage (lr = 0.000049) ...
# loss 2.07059, wmdcmp 0.25977, report_loss 2.11226, 123.04 secs
# (2) Validation stage ...
# wmdcmp 0.13797, cD 0.41265, 14.35 secs
# ---- Epoch 17/68
# (1) Training stage (lr = 0.000024) ...
# loss 2.08235, wmdcmp 0.26184, report_loss 2.10198, 123.60 secs
# (2) Validation stage ...
# wmdcmp 0.12568, cD 0.37146, 14.30 secs
# ---- Epoch 18/68
# (1) Training stage (lr = 0.000012) ...
# loss 2.03729, wmdcmp 0.26233, report_loss 2.09660, 124.01 secs
# (2) Validation stage ...
# wmdcmp 0.13879, cD 0.42742, 14.26 secs
# ---- Epoch 19/68
# (1) Training stage (lr = 0.000006) ...
# loss 2.02260, wmdcmp 0.26202, report_loss 2.09836, 124.22 secs
# (2) Validation stage ...
# wmdcmp 0.12448, cD 0.36809, 14.53 secs
# ---- Epoch 20/68
# (1) Training stage (lr = 0.000003) ...
# loss 2.11606, wmdcmp 0.26235, report_loss 2.09521, 124.25 secs
# (2) Validation stage ...
# wmdcmp 0.13682, cD 0.42413, 14.37 secs
# ---- Epoch 21/68
# (1) Training stage (lr = 0.000400) ...
# loss 2.03282, wmdcmp 0.25844, report_loss 2.11136, 124.11 secs
# (2) Validation stage ...
# wmdcmp 0.12610, cD 0.32536, 14.39 secs
# ---- Epoch 22/68
# (1) Training stage (lr = 0.000199) ...
# loss 2.10070, wmdcmp 0.26790, report_loss 2.04979, 123.04 secs
# (2) Validation stage ...
# wmdcmp 0.13206, cD 0.38549, 14.06 secs
# ---- Epoch 23/68
# (1) Training stage (lr = 0.000099) ...
# loss 2.05446, wmdcmp 0.27245, report_loss 2.01958, 123.18 secs
# (2) Validation stage ...
# wmdcmp 0.12315, cD 0.34872, 14.40 secs
# ---- Epoch 24/68
# (1) Training stage (lr = 0.000049) ...
# loss 1.94476, wmdcmp 0.27412, report_loss 2.01032, 122.69 secs
# (2) Validation stage ...
# wmdcmp 0.13257, cD 0.37668, 15.50 secs
# ---- Epoch 25/68
# (1) Training stage (lr = 0.000024) ...
# loss 2.03204, wmdcmp 0.27690, report_loss 1.99278, 121.26 secs
# (2) Validation stage ...
# wmdcmp 0.12352, cD 0.37051, 14.46 secs
# ---- Epoch 26/68
# (1) Training stage (lr = 0.000012) ...
# loss 1.95796, wmdcmp 0.27673, report_loss 1.99134, 121.25 secs
# (2) Validation stage ...
# wmdcmp 0.12188, cD 0.35600, 14.45 secs
# ---- Epoch 27/68
# (1) Training stage (lr = 0.000006) ...
# loss 2.04745, wmdcmp 0.27740, report_loss 1.98790, 121.67 secs
# (2) Validation stage ...
# wmdcmp 0.12354, cD 0.36305, 14.25 secs
# ---- Epoch 28/68
# (1) Training stage (lr = 0.000003) ...
# loss 1.96577, wmdcmp 0.27753, report_loss 1.98692, 121.20 secs
# (2) Validation stage ...
# wmdcmp 0.12371, cD 0.35937, 14.10 secs
# ---- Epoch 29/68
# (1) Training stage (lr = 0.000400) ...
# loss 1.94290, wmdcmp 0.27080, report_loss 2.01704, 123.55 secs
# (2) Validation stage ...
# wmdcmp 0.12311, cD 0.32860, 14.41 secs
# ---- Epoch 30/68
# (1) Training stage (lr = 0.000199) ...
# loss 1.97629, wmdcmp 0.27887, report_loss 1.97186, 122.98 secs
# (2) Validation stage ...
# wmdcmp 0.13432, cD 0.41650, 13.98 secs
# ---- Epoch 31/68
# (1) Training stage (lr = 0.000099) ...
# loss 1.89198, wmdcmp 0.28339, report_loss 1.94027, 123.52 secs
# (2) Validation stage ...
# wmdcmp 0.12317, cD 0.37078, 14.31 secs
# ---- Epoch 32/68
# (1) Training stage (lr = 0.000049) ...
# loss 1.96792, wmdcmp 0.28551, report_loss 1.93212, 124.37 secs
# (2) Validation stage ...
# wmdcmp 0.12159, cD 0.33971, 14.37 secs
# ---- Epoch 33/68
# (1) Training stage (lr = 0.000024) ...
# loss 1.85895, wmdcmp 0.28809, report_loss 1.91859, 122.66 secs
# (2) Validation stage ...
# wmdcmp 0.12196, cD 0.34608, 14.31 secs
# ---- Epoch 34/68
# (1) Training stage (lr = 0.000012) ...
# loss 1.89377, wmdcmp 0.28775, report_loss 1.91781, 122.47 secs
# (2) Validation stage ...
# wmdcmp 0.12623, cD 0.35987, 14.23 secs
# ---- Epoch 35/68
# (1) Training stage (lr = 0.000006) ...
# loss 1.85911, wmdcmp 0.28757, report_loss 1.91532, 122.11 secs
# (2) Validation stage ...
# wmdcmp 0.12326, cD 0.35424, 14.41 secs
# ---- Epoch 36/68
# (1) Training stage (lr = 0.000003) ...
# loss 1.86817, wmdcmp 0.28847, report_loss 1.91254, 124.16 secs
# (2) Validation stage ...
# wmdcmp 0.12302, cD 0.35070, 14.34 secs
# ---- Epoch 37/68
# (1) Training stage (lr = 0.000400) ...
# loss 1.95758, wmdcmp 0.28002, report_loss 1.95190, 122.16 secs
# (2) Validation stage ...
# wmdcmp 0.12946, cD 0.38598, 14.44 secs
# ---- Epoch 38/68
# (1) Training stage (lr = 0.000199) ...
# loss 1.94698, wmdcmp 0.28901, report_loss 1.90713, 122.78 secs
# (2) Validation stage ...
# wmdcmp 0.12276, cD 0.35725, 14.27 secs
# ---- Epoch 39/68
# (1) Training stage (lr = 0.000099) ...
# loss 1.92615, wmdcmp 0.29179, report_loss 1.88201, 122.36 secs
# (2) Validation stage ...
# wmdcmp 0.12812, cD 0.39095, 14.06 secs
# ---- Epoch 40/68
# (1) Training stage (lr = 0.000049) ...
# loss 1.78318, wmdcmp 0.29460, report_loss 1.86952, 121.90 secs
# (2) Validation stage ...
# wmdcmp 0.12639, cD 0.36540, 14.17 secs
# ---- Epoch 41/68
# (1) Training stage (lr = 0.000024) ...
# loss 1.81007, wmdcmp 0.29479, report_loss 1.86649, 122.71 secs
# (2) Validation stage ...
# wmdcmp 0.12241, cD 0.34664, 14.15 secs
# ---- Epoch 42/68
# (1) Training stage (lr = 0.000012) ...
# loss 1.84003, wmdcmp 0.29544, report_loss 1.86452, 122.54 secs
# (2) Validation stage ...
# wmdcmp 0.12624, cD 0.35555, 14.12 secs
# ---- Epoch 43/68
# (1) Training stage (lr = 0.000006) ...
# loss 1.98565, wmdcmp 0.29541, report_loss 1.85886, 121.89 secs
# (2) Validation stage ...
# wmdcmp 0.12293, cD 0.35189, 14.24 secs
# ---- Epoch 44/68
# (1) Training stage (lr = 0.000003) ...
# loss 1.88558, wmdcmp 0.29711, report_loss 1.85485, 122.51 secs
# (2) Validation stage ...
# wmdcmp 0.12435, cD 0.35495, 14.34 secs
# ---- Epoch 45/68
# (1) Training stage (lr = 0.000400) ...
# loss 1.88137, wmdcmp 0.28891, report_loss 1.89625, 123.21 secs
# (2) Validation stage ...
# wmdcmp 0.12593, cD 0.35166, 14.31 secs
# ---- Epoch 46/68
# (1) Training stage (lr = 0.000199) ...
# loss 1.96257, wmdcmp 0.29461, report_loss 1.86382, 123.52 secs
# (2) Validation stage ...
# wmdcmp 0.12689, cD 0.35971, 14.21 secs
# ---- Epoch 47/68
# (1) Training stage (lr = 0.000099) ...
# loss 1.98521, wmdcmp 0.29870, report_loss 1.83934, 123.10 secs
# (2) Validation stage ...
# wmdcmp 0.12648, cD 0.40164, 15.37 secs
# ---- Epoch 48/68
# (1) Training stage (lr = 0.000049) ...
# loss 1.99313, wmdcmp 0.30041, report_loss 1.82544, 123.36 secs
# (2) Validation stage ...
# wmdcmp 0.13286, cD 0.40509, 14.32 secs
# ---- Epoch 49/68
# (1) Training stage (lr = 0.000024) ...
# loss 1.90826, wmdcmp 0.30173, report_loss 1.81896, 121.65 secs
# (2) Validation stage ...
# wmdcmp 0.12567, cD 0.36284, 14.16 secs
# ---- Epoch 50/68
# (1) Training stage (lr = 0.000012) ...
# loss 1.88459, wmdcmp 0.30361, report_loss 1.81261, 123.01 secs
# (2) Validation stage ...
# wmdcmp 0.12201, cD 0.33637, 14.27 secs
# ---- Epoch 51/68
# (1) Training stage (lr = 0.000006) ...
# loss 1.85535, wmdcmp 0.30265, report_loss 1.81427, 123.52 secs
# (2) Validation stage ...
# wmdcmp 0.12610, cD 0.34635, 14.16 secs
# ---- Epoch 52/68
# (1) Training stage (lr = 0.000003) ...
# loss 1.83245, wmdcmp 0.30306, report_loss 1.81540, 123.92 secs
# (2) Validation stage ...
# wmdcmp 0.12747, cD 0.36826, 14.30 secs
# ---- Epoch 53/68
# (1) Training stage (lr = 0.000400) ...
# loss 1.75773, wmdcmp 0.29382, report_loss 1.85554, 122.99 secs
# (2) Validation stage ...
# wmdcmp 0.12009, cD 0.37590, 14.23 secs
# ---- Epoch 54/68
# (1) Training stage (lr = 0.000199) ...
# loss 1.82045, wmdcmp 0.30065, report_loss 1.82494, 123.48 secs
# (2) Validation stage ...
# wmdcmp 0.13819, cD 0.41682, 14.17 secs
# ---- Epoch 55/68
# (1) Training stage (lr = 0.000099) ...
# loss 1.82982, wmdcmp 0.30386, report_loss 1.80021, 123.38 secs
# (2) Validation stage ...
# wmdcmp 0.13059, cD 0.37436, 14.27 secs
# ---- Epoch 56/68
# (1) Training stage (lr = 0.000049) ...
# loss 1.79707, wmdcmp 0.30636, report_loss 1.78658, 123.16 secs
# (2) Validation stage ...
# wmdcmp 0.13638, cD 0.40554, 14.29 secs
# ---- Epoch 57/68
# (1) Training stage (lr = 0.000024) ...
# loss 1.75608, wmdcmp 0.30689, report_loss 1.78351, 122.57 secs
# (2) Validation stage ...
# wmdcmp 0.12575, cD 0.35634, 14.24 secs
# ---- Epoch 58/68
# (1) Training stage (lr = 0.000012) ...
# loss 1.60833, wmdcmp 0.30882, report_loss 1.77302, 122.67 secs
# (2) Validation stage ...
# wmdcmp 0.12832, cD 0.37496, 13.99 secs
# ---- Epoch 59/68
# (1) Training stage (lr = 0.000006) ...
# loss 1.59811, wmdcmp 0.30926, report_loss 1.77683, 124.36 secs
# (2) Validation stage ...
# wmdcmp 0.12258, cD 0.34944, 14.00 secs
# ---- Epoch 60/68
# (1) Training stage (lr = 0.000003) ...
# loss 1.75177, wmdcmp 0.30975, report_loss 1.77014, 123.67 secs
# (2) Validation stage ...
# wmdcmp 0.12289, cD 0.34408, 14.11 secs
# ---- Epoch 61/68
# (1) Training stage (lr = 0.000400) ...
# loss 1.82903, wmdcmp 0.29976, report_loss 1.82072, 123.90 secs
# (2) Validation stage ...
# wmdcmp 0.12304, cD 0.35206, 13.99 secs
# ---- Epoch 62/68
# (1) Training stage (lr = 0.000199) ...
# loss 1.94499, wmdcmp 0.30451, report_loss 1.79340, 124.28 secs
# (2) Validation stage ...
# wmdcmp 0.13337, cD 0.40645, 14.05 secs
# ---- Epoch 63/68
# (1) Training stage (lr = 0.000099) ...
# loss 1.73473, wmdcmp 0.30908, report_loss 1.76647, 124.57 secs
# (2) Validation stage ...
# wmdcmp 0.13657, cD 0.40479, 13.88 secs
# ---- Epoch 64/68
# (1) Training stage (lr = 0.000049) ...
# loss 1.75132, wmdcmp 0.31092, report_loss 1.75517, 125.83 secs
# (2) Validation stage ...
# wmdcmp 0.11974, cD 0.32945, 13.70 secs
# ---- Epoch 65/68
# (1) Training stage (lr = 0.000024) ...
# loss 1.60947, wmdcmp 0.31314, report_loss 1.74905, 125.22 secs
# (2) Validation stage ...
# wmdcmp 0.13076, cD 0.37446, 14.26 secs
# ---- Epoch 66/68
# (1) Training stage (lr = 0.000012) ...
# loss 1.57303, wmdcmp 0.31308, report_loss 1.74349, 124.24 secs
# (2) Validation stage ...
# wmdcmp 0.12596, cD 0.36578, 14.08 secs
# ---- Epoch 67/68
# (1) Training stage (lr = 0.000006) ...
# loss 1.64493, wmdcmp 0.31444, report_loss 1.74177, 121.10 secs
# (2) Validation stage ...
# wmdcmp 0.12579, cD 0.35991, 14.28 secs
# ---- Epoch 68/68
# (1) Training stage (lr = 0.000003) ...
# loss 1.75354, wmdcmp 0.31371, report_loss 1.74093, 122.79 secs
# (2) Validation stage ...
# wmdcmp 0.12701, cD 0.36121, 14.35 secs

# %%
# !/home/pamessina/venv2/bin/python ../train_labels2report.py \
    --generation-mode "pred2rep" \
    --use-ensemble \
    --ensemble-model-checkpoint-folder-paths \
        "/mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/" \
    --ensemble-batch-size 160 \
    --ensemble-num-workers 3 \
    --use-hard-predictions \
    --filter-labels \
    --label-score-threshold 0.3 \
    --epochs 68 \
    --batches-per-epoch 300 \
    --batch-size 200 \
    --num-workers 2 \
    --iters-to-accumulate 2 \
    --optimizer-name "adamw" \
    --scheduler "exp-warmup+decay+cyclicdecay" \
    --lr 1e-6 \
    --warmup-decay-and-cyclic-decay-args "1e-6,3,4e-4,8,3e-6,4e-4,8,3e-6" \
    --use-mimiccxr \
    --mimiccxr-weight 1.0 \
    --mimiccxr-view-mode "chest_imagenome" \
    --mimiccxr-balanced-sampling-mode "balanced_chest_imagenome_global_labels_batchwise" \
    --mimiccxr-balanced-batch-size 30 \
    --mimiccxr-qa-adapted-reports-filename "qa_adapted_reports__20220904_095810.json" \
    --use-chest-imagenome \
    --use-chest-imagenome-decent-images-only \
    --chest-imagenome-label-names-filename "labels(min_freq=100).pkl" \
    --chest-imagenome-labels-filename "imageId2labels(min_freq=100).pkl" \
    --use-chexpert \
    --mimiccxr-chexpert-labels-filename "chexpert_labels_per_report__20220904_113605.pkl" \
    --use-medical-tokenization \
    --medical-terms-frequency-filename "medical_terms_frequency__20220918_184255.pkl" \
    --binary-loss-name "focal+bce+wbce-c" \
    --labels-hidden-dim 1024 \
    --embedding-dim 512 \
    --transf-dec-num-memory-vecs 10 \
    --transf-dec-hidden-dim 512 \
    --transf-dec-nhead 4 \
    --transf-dec-dim-forward 512 \
    --transf-dec-num-layers 3 \
    --use-amp \
    --save
# Out:
# script's arguments:
#    epochs: 68
#    batches_per_epoch: 300
#    batch_size: 200
#    checkpoint_folder: None
#    generation_mode: pred2rep
#    use_ensemble: True
#    ensemble_model_checkpoint_folder_paths: ['/mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/']
#    ensemble_batch_size: 160
#    ensemble_num_workers: 3
#    use_hard_predictions: True
#    pretrained_checkpoint_folder_path: None
#    labels_hidden_dim: 1024
#    embedding_dim: 512
#    transf_dec_num_memory_vecs: 10
#    transf_dec_hidden_dim: 512
#    transf_dec_nhead: 4
#    transf_dec_dim_forward: 512
#    transf_dec_num_layers: 3
#    dropout_prob: 0
#    vocab_min_freq: 10
#    use_medical_tokenization: True
#    medical_terms_frequency_filename: medical_terms_frequency__20220918_184255.pkl
#    optimizer_name: adamw
#    lr: 1e-06
#    scheduler: exp-warmup+decay+cyclicdecay
#    lr_decay: 0.76
#    lr_decay_patience: 2
#    warmup_and_decay_args: None
#    warmup_and_cosine_args: None
#    warmup_decay_and_cyclic_decay_args: 1e-6,3,4e-4,8,3e-6,4e-4,8,3e-6
#    iters_to_accumulate: 2
#    override_lr: False
#    binary_loss_name: focal+bce+wbce-c
#    focal_loss_weight: 1
#    bce_loss_weight: 1
#    wbce_loss_weight: 1
#    num_workers: 2
#    device: GPU
#    use_amp: True
#    train_mimiccxr: True
#    mimiccxr_weight: 1.0
#    mimiccxr_view_mode: chest_imagenome
#    mimiccxr_balanced_sampling_mode: balanced_chest_imagenome_global_labels_batchwise
#    mimiccxr_balanced_batch_size: 30
#    mimiccxr_qa_adapted_reports_filename: qa_adapted_reports__20220904_095810.json
#    chest_imagenome_labels_filename: imageId2labels(min_freq=100).pkl
#    chest_imagenome_label_names_filename: labels(min_freq=100).pkl
#    use_chest_imagenome_decent_images_only: True
#    save: True
#    use_gender: False
#    use_chexpert: True
#    mimiccxr_chexpert_labels_filename: chexpert_labels_per_report__20220904_113605.pkl
#    use_chest_imagenome: True
#    filter_labels: True
#    top_k_chexpert_labels: None
#    top_k_chest_imagenome_labels: None
#    label_score_threshold: 0.3
#    debug: False
# ----- Training model from scratch ------
# Computing number of labels and ranges for ensemble ...
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/metadata.json
# chest_imagenome_range: (0, 627)
# chexpert_range: (627, 641)
# ============================================================
# Precomputing sigmoid activations for ensemble ...
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/metadata.json
# ============================================================
# Model 1/1
# model_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/
# checkpoint_names = ['checkpoint_79_chou+chuc+chuc+chuc+chuc+cD+gacc+wmmp=0.6677.pt', 'checkpoint_135_chou+chuc+chuc+chuc+chuc+cD+gacc+wmmp=0.6689.pt']
# model_checkpoint_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/checkpoint_135_chou+chuc+chuc+chuc+chuc+cD+gacc+wmmp=0.6689.pt
# precomputed_chexpert_sigmoids_path = /mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/precomputed_chexpert_sigmoids(hash=340,3716123060218160099).pkl
# Precomputed sigmoids for CheXpert already exist.
# File size = 56.39 MB
# precomputed_chest_imagenome_sigmoids_path = /mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/precomputed_chest_imagenome_sigmoids(hash=347,2103260294420767687).pkl
# Precomputed sigmoids for Chest ImaGenome already exist.
# File size = 339.66 MB
# Skipping...
# precomputed_sigmoid_paths: [{'model_folder_path': '/mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/', 'chexpert_sigmoids_path': '/mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/precomputed_chexpert_sigmoids(hash=340,3716123060218160099).pkl', 'chest_imagenome_sigmoids_path': '/mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/precomputed_chest_imagenome_sigmoids(hash=347,2103260294420767687).pkl'}]
# ============================================================
# Precomputing thresholds (for hard predictions) for ensemble ...
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/metadata.json
# ============================================================
# Model 1/1
# model_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/
# checkpoint_names = ['checkpoint_79_chou+chuc+chuc+chuc+chuc+cD+gacc+wmmp=0.6677.pt', 'checkpoint_135_chou+chuc+chuc+chuc+chuc+cD+gacc+wmmp=0.6689.pt']
# model_checkpoint_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/checkpoint_135_chou+chuc+chuc+chuc+chuc+cD+gacc+wmmp=0.6689.pt
# results_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/results/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/
# get_image_transform()
#   Using bounding box aware transforms
#     Returning default transform (no augmentation)
# Calibrating thresholds on MIMIC-CXR validation set
# score_name: f1
# Thresholds for CheXpert already cached at /mnt/data/pamessina/workspaces/medvqa-workspace/results/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/thresholds_chexpert(f1).pkl
# Thresholds for Chest ImaGenome already cached at /mnt/data/pamessina/workspaces/medvqa-workspace/results/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/thresholds_chest_imagenome(f1).pkl
# precomputed_thresholds_paths: [{'chexpert': '/mnt/data/pamessina/workspaces/medvqa-workspace/results/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/thresholds_chexpert(f1).pkl', 'chest_imagenome': '/mnt/data/pamessina/workspaces/medvqa-workspace/results/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/thresholds_chest_imagenome(f1).pkl'}]
# ============================================================
# Precomputing filtered labels for ensemble ...
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/metadata.json
# ============================================================
# Model 1/1
# model_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/
# results_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/results/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/
# get_image_transform()
#   Using bounding box aware transforms
#     Returning default transform (no augmentation)
# Loading cached chexpert predictions and ground truth...
# len(dicom_id_to_pred_chexpert_probs): 3389
# len(dicom_id_to_gt_chexpert_labels): 3389
# Loading cached chest imagenome predictions and ground truth...
# len(dicom_id_to_pred_chest_imagenome_probs): 3389
# len(dicom_id_to_gt_chest_imagenome_labels): 3389
# Top 9 label classes with the highest f1 scores:
# 1. Support Devices: 0.8737220226581928
# 2. Pleural Effusion: 0.743933588761175
# 3. Cardiomegaly: 0.7198264171413074
# 4. Lung Opacity: 0.6673640167364017
# 5. Edema: 0.6276923076923075
# 6. Atelectasis: 0.6112539274493003
# 7. Pneumonia: 0.45472363778910235
# 8. Enlarged Cardiomediastinum: 0.44780145670353394
# 9. No Finding: 0.37368421052631584
# Top 122 label classes with the highest f1 scores:
# 1. ('nlp', 'abnormal'): 0.9645215788665336
# 7. ('mediastinum', 'device', 'cardiac pacer and wires'): 0.84472049689441
# 13. ('anatomicalfinding', 'pleural effusion'): 0.7588336192109778
# 20. ('right costophrenic angle', 'nlp', 'abnormal'): 0.7209039548022601
# 26. ('right chest wall', 'anatomicalfinding', 'subcutaneous air'): 0.6962962962962962
# 32. ('right hilar structures', 'nlp', 'abnormal'): 0.674488567990373
# 39. ('anatomicalfinding', 'atelectasis'): 0.636920384951881
# 45. ('tubesandlines', 'ij line'): 0.6063694267515923
# 51. ('right lung', 'anatomicalfinding', 'pulmonary edema/hazy opacity'): 0.5773718924403857
# 58. ('neck', 'tubesandlines', 'tracheostomy tube'): 0.5405405405405405
# 64. ('right lung', 'anatomicalfinding', 'atelectasis'): 0.5201032829214312
# 71. ('right chest wall', 'nlp', 'abnormal'): 0.4830917874396135
# 77. ('right hilar structures', 'tubesandlines', 'swan-ganz catheter'): 0.4444444444444444
# 83. ('right hemidiaphragm', 'anatomicalfinding', 'elevated hemidiaphragm'): 0.425
# 90. ('svc', 'tubesandlines', 'ij line'): 0.39819004524886875
# 96. ('cardiac silhouette', 'device', 'prosthetic valve'): 0.3867403314917127
# 102. ('right lower lung zone', 'anatomicalfinding', 'pleural effusion'): 0.3741293532338309
# 109. ('aortic arch', 'nlp', 'abnormal'): 0.33807266982622436
# 115. ('mediastinum', 'anatomicalfinding', 'tortuous aorta'): 0.3180592991913746
# 122. ('anatomicalfinding', 'tortuous aorta'): 0.3
# precomputed_filtered_labels_paths: [{'chexpert_indices_path': '/mnt/data/pamessina/workspaces/medvqa-workspace/results/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/chexpert_top_9_out_of_14_labels_f1_(score_threshold_0.30)_indices.pkl', 'chexpert_num_indices': 9, 'chest_imagenome_indices_path': '/mnt/data/pamessina/workspaces/medvqa-workspace/results/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/chest_imagenome_top_122_out_of_627_labels_f1_(score_threshold_0.30)_indices.pkl', 'chest_imagenome_num_indices': 122}]
# num_input_labels (after update): 131
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Initializing tokenizer ...
# Loading /mnt/data/pamessina/workspaces/medvqa-workspace/cache/vocab(min_freq=10;mode=report;qa_adapted_reports__20220904_095810.json).pkl ...
# --------------------------------------------------
# 3) Creating instance of Labels2ReportModel ...
# Labels2ReportModel
#   gen_mode: pred2rep
#   vocab_size: 4833
#   embedding_dim: 512
#   num_input_labels: 131
#   labels_hidden_dim: 1024
#   num_output_labels: 641
#   transf_dec_num_memory_vecs: 10
#   transf_dec_hidden_dim: 512
#   transf_dec_nhead: 4
#   transf_dec_dim_forward: 512
#   transf_dec_num_layers: 3
#   start_idx: 1
#   dropout_prob: 0
# --------------------------------------------------
# 4) Defining optimizer ...
# create_optimizer(): name = adamw
# --------------------------------------------------
# 5) Defining scheduler ...
# Using exp-warmup+decay+cyclicdecay scheduler: 1e-6,3,4e-4,8,3e-6,4e-4,8,3e-6
# 1e-06 3 0.0004 8 3e-06 0.0004 8 3e-06
# self.steps_to_restart = 8
# self.steps = -1
# self.initial_lr = 0.0004
# --------------------------------------------------
# 6) Creating trainer and validator engines ...
# Using focal+bce+wbce-c loss
# binary_loss_kwargs: {'focal_weight': 1, 'bce_weight': 1, 'wbce_weight': 1}
# --------------------------------------------------
# 7) Defining collate_batch_fn ...
# --------------------------------------------------
# 8) Creating MIMIC-CXR_Labels2ReportTrainer ...
# 227835it [00:22, 10318.38it/s]
# max_idx_count = 377110
# actual_idx_count = 239513
# ** NOTE: 137597 images were skipped because they were not in the allowed DICOM IDs
# Random report:
# <s> semi upright . right picc tip terminates upper svc . cardiac , mediastinal hilar contours normal heart size normal . lungs clear . no pleural effusion pneumothorax . no osseous abnormality . right picc tip upper svc </s>
# len(self.train_indices) = 234217
# len(self.val_indices) = 1934
# Loading CheXpert labels...
# Loading Chest Imagenome labels...
# Loading precomputed sigmoid paths for ensemble predictions...
#   Loading /mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/precomputed_chexpert_sigmoids(hash=340,3716123060218160099).pkl
#     _probs.shape = (242280, 14)
#     len(_dids) = 242280
#     _thresholds.shape = (14,)
#     _probs has been thresholded
#     _label_indices.shape = (9,)
#     _probs has been filtered
#     Sanity checking chexpert labels
#     len(self.val_indices) = 1934
#     f1_score(_gt_labels, _pred_labels, average="micro") = 0.6198093391501049
#     f1_score(_gt_labels, _pred_labels, average="macro") = 0.6130891345703472
#   Loading /mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/precomputed_chest_imagenome_sigmoids(hash=347,2103260294420767687).pkl
#     _probs.shape = (242280, 627)
#     len(_dids) = 242280
#     _thresholds.shape = (627,)
#     _probs has been thresholded
#     _label_indices.shape = (122,)
#     _probs has been filtered
#     Sanity checking chest_imagenome labels
#     len(self.val_indices) = 1934
#     f1_score(_gt_labels, _pred_labels, average="micro") = 0.6411629482971685
#     f1_score(_gt_labels, _pred_labels, average="macro") = 0.5273377674096739
# Done loading precomputed sigmoid paths for ensemble predictions
# Balanced sampling mode: balanced_chest_imagenome_global_labels_batchwise
# Regrouping indices by Chest Imagenome labels for balanced sampling...
# 627it [01:11,  8.76it/s]
# Global: airspace opacity                        , # images: 8595 (other: 225622)
# Global: atelectasis                             , # images: 79106 (other: 155111)
# Global: bone lesion                             , # images: 1692 (other: 232525)
# Global: bronchiectasis                          , # images: 905 (other: 233312)
# Global: calcified nodule                        , # images: 2708 (other: 231509)
# Global: clavicle fracture                       , # images: 862 (other: 233355)
# Global: consolidation                           , # images: 17769 (other: 216448)
# Global: costophrenic angle blunting             , # images: 5723 (other: 228494)
# Global: cyst/bullae                             , # images: 874 (other: 233343)
# Global: elevated hemidiaphragm                  , # images: 6412 (other: 227805)
# Global: enlarged cardiac silhouette             , # images: 57654 (other: 176563)
# Global: enlarged hilum                          , # images: 8983 (other: 225234)
# Global: hernia                                  , # images: 3025 (other: 231192)
# Global: hydropneumothorax                       , # images: 954 (other: 233263)
# Global: hyperaeration                           , # images: 10306 (other: 223911)
# Global: increased reticular markings/ild pattern, # images: 1373 (other: 232844)
# Global: infiltration                            , # images: 2977 (other: 231240)
# Global: linear/patchy atelectasis               , # images: 12797 (other: 221420)
# Global: lobar/segmental collapse                , # images: 9531 (other: 224686)
# Global: lung lesion                             , # images: 13455 (other: 220762)
# Global: lung opacity                            , # images: 154881 (other: 79336)
# Global: mass/nodule (not otherwise specified)   , # images: 7782 (other: 226435)
# Global: mediastinal displacement                , # images: 3438 (other: 230779)
# Global: mediastinal widening                    , # images: 5070 (other: 229147)
# Global: multiple masses/nodules                 , # images: 3730 (other: 230487)
# Global: pleural effusion                        , # images: 72076 (other: 162141)
# Global: pleural/parenchymal scarring            , # images: 14199 (other: 220018)
# Global: pneumomediastinum                       , # images: 864 (other: 233353)
# Global: pneumothorax                            , # images: 10640 (other: 223577)
# Global: pulmonary edema/hazy opacity            , # images: 35280 (other: 198937)
# Global: rib fracture                            , # images: 7080 (other: 227137)
# Global: scoliosis                               , # images: 3201 (other: 231016)
# Global: shoulder osteoarthritis                 , # images: 2178 (other: 232039)
# Global: spinal degenerative changes             , # images: 6810 (other: 227407)
# Global: spinal fracture                         , # images: 3101 (other: 231116)
# Global: sub-diaphragmatic air                   , # images: 1234 (other: 232983)
# Global: subcutaneous air                        , # images: 3377 (other: 230840)
# Global: superior mediastinal mass/enlargement   , # images: 3295 (other: 230922)
# Global: tortuous aorta                          , # images: 13462 (other: 220755)
# Global: vascular calcification                  , # images: 10172 (other: 224045)
# Global: vascular congestion                     , # images: 24614 (other: 209603)
# Global: vascular redistribution                 , # images: 3199 (other: 231018)
# Global: aortic graft/repair                     , # images: 115 (other: 234102)
# Global: cabg grafts                             , # images: 3839 (other: 230378)
# Global: cardiac pacer and wires                 , # images: 12453 (other: 221764)
# Global: prosthetic valve                        , # images: 2891 (other: 231326)
# Global: alveolar hemorrhage                     , # images: 1766 (other: 232451)
# Global: aspiration                              , # images: 8915 (other: 225302)
# Global: copd/emphysema                          , # images: 6553 (other: 227664)
# Global: fluid overload/heart failure            , # images: 6458 (other: 227759)
# Global: goiter                                  , # images: 614 (other: 233603)
# Global: granulomatous disease                   , # images: 2423 (other: 231794)
# Global: interstitial lung disease               , # images: 1943 (other: 232274)
# Global: lung cancer                             , # images: 1752 (other: 232465)
# Global: pericardial effusion                    , # images: 1400 (other: 232817)
# Global: pneumonia                               , # images: 34201 (other: 200016)
# Global: abnormal                                , # images: 184517 (other: 49700)
# Global: artifact                                , # images: 299 (other: 233918)
# Global: breast/nipple shadows                   , # images: 1020 (other: 233197)
# Global: low lung volumes                        , # images: 28214 (other: 206003)
# Global: rotated                                 , # images: 2036 (other: 232181)
# Global: skin fold                               , # images: 216 (other: 234001)
# Global: chest port                              , # images: 7247 (other: 226970)
# Global: chest tube                              , # images: 10271 (other: 223946)
# Global: endotracheal tube                       , # images: 22541 (other: 211676)
# Global: enteric tube                            , # images: 27915 (other: 206302)
# Global: ij line                                 , # images: 12109 (other: 222108)
# Global: intra-aortic balloon pump               , # images: 562 (other: 233655)
# Global: mediastinal drain                       , # images: 436 (other: 233781)
# Global: picc                                    , # images: 14281 (other: 219936)
# Global: pigtail catheter                        , # images: 3538 (other: 230679)
# Global: subclavian line                         , # images: 3883 (other: 230334)
# Global: swan-ganz catheter                      , # images: 2197 (other: 232020)
# Global: tracheostomy tube                       , # images: 4756 (other: 229461)
# --------------------------------------------------
# 9) Creating dataloaders ...
# len(_train_dataloaders) = 1
# len(_val_dataloaders) = 1
# _train_weights = [1.0]
# merged_dataset_name = mim
# --------------------------------------------------
# 10) Attaching metrics, losses, timer and events to engines ...
# --------------------------------------------------
# 11) Defining learning rate scheduler handler ...
# --------------------------------------------------
# 12) Defining checkpoint folder path ...
# checkpoint_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/report_gen/20230505_081502_mim_Labels2ReportModel(131,10,TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))
# metadata saved to /mnt/data/pamessina/workspaces/medvqa-workspace/models/report_gen/20230505_081502_mim_Labels2ReportModel(131,10,TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/metadata.json
# --------------------------------------------------
# 13) Defining log_metrics_handler ...
# MetricsLogger :: we'll be logging to /mnt/data/pamessina/workspaces/medvqa-workspace/models/report_gen/20230505_081502_mim_Labels2ReportModel(131,10,TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/metrics_logs.csv
# --------------------------------------------------
# 14) Running trainer engine ...
# ---- Epoch 1/68
# (1) Training stage (lr = 0.000001) ...
# loss 8.58075, wmdcmp 0.00608, report_loss 8.34058, 178.46 secs
# (2) Validation stage ...
# wmdcmp 0.00052, cD 0.00025, 13.92 secs
# ---- Epoch 2/68
# (1) Training stage (lr = 0.000007) ...
# loss 8.09347, wmdcmp 0.00049, report_loss 6.81285, 161.15 secs
# (2) Validation stage ...
# wmdcmp 0.00052, cD 0.00042, 15.20 secs
# ---- Epoch 3/68
# (1) Training stage (lr = 0.000054) ...
# loss 6.00904, wmdcmp 0.05661, report_loss 4.54850, 159.15 secs
# (2) Validation stage ...
# wmdcmp 0.03507, cD 0.00345, 15.01 secs
# ---- Epoch 4/68
# (1) Training stage (lr = 0.000400) ...
# loss 3.84964, wmdcmp 0.16660, report_loss 2.98905, 147.10 secs
# (2) Validation stage ...
# wmdcmp 0.12333, cD 0.36021, 14.27 secs
# ---- Epoch 5/68
# (1) Training stage (lr = 0.000217) ...
# loss 2.59379, wmdcmp 0.21351, report_loss 2.49110, 143.48 secs
# (2) Validation stage ...
# wmdcmp 0.12890, cD 0.35149, 14.47 secs
# ---- Epoch 6/68
# (1) Training stage (lr = 0.000118) ...
# loss 2.43907, wmdcmp 0.22530, report_loss 2.38770, 139.67 secs
# (2) Validation stage ...
# wmdcmp 0.13325, cD 0.40179, 14.23 secs
# ---- Epoch 7/68
# (1) Training stage (lr = 0.000064) ...
# loss 2.29028, wmdcmp 0.23137, report_loss 2.33709, 133.82 secs
# (2) Validation stage ...
# wmdcmp 0.13873, cD 0.44087, 14.39 secs
# ---- Epoch 8/68
# (1) Training stage (lr = 0.000035) ...
# loss 2.24920, wmdcmp 0.23488, report_loss 2.31061, 133.55 secs
# (2) Validation stage ...
# wmdcmp 0.13704, cD 0.41337, 14.22 secs
# ---- Epoch 9/68
# (1) Training stage (lr = 0.000019) ...
# loss 2.33198, wmdcmp 0.23562, report_loss 2.30278, 132.41 secs
# (2) Validation stage ...
# wmdcmp 0.13302, cD 0.41759, 14.35 secs
# ---- Epoch 10/68
# (1) Training stage (lr = 0.000010) ...
# loss 2.39258, wmdcmp 0.23653, report_loss 2.29456, 131.51 secs
# (2) Validation stage ...
# wmdcmp 0.13099, cD 0.38260, 14.24 secs
# ---- Epoch 11/68
# (1) Training stage (lr = 0.000006) ...
# loss 2.33236, wmdcmp 0.23657, report_loss 2.28979, 132.39 secs
# (2) Validation stage ...
# wmdcmp 0.13692, cD 0.43043, 14.44 secs
# ---- Epoch 12/68
# (1) Training stage (lr = 0.000003) ...
# loss 2.27294, wmdcmp 0.23743, report_loss 2.28917, 132.20 secs
# (2) Validation stage ...
# wmdcmp 0.13748, cD 0.42872, 14.44 secs
# ---- Epoch 13/68
# (1) Training stage (lr = 0.000400) ...
# loss 2.38594, wmdcmp 0.23999, report_loss 2.25870, 128.55 secs
# (2) Validation stage ...
# wmdcmp 0.13041, cD 0.42617, 14.43 secs
# ---- Epoch 14/68
# (1) Training stage (lr = 0.000199) ...
# loss 2.14672, wmdcmp 0.25049, report_loss 2.17549, 124.19 secs
# (2) Validation stage ...
# wmdcmp 0.13141, cD 0.36861, 14.29 secs
# ---- Epoch 15/68
# (1) Training stage (lr = 0.000099) ...
# loss 2.02941, wmdcmp 0.25734, report_loss 2.13504, 122.95 secs
# (2) Validation stage ...
# wmdcmp 0.13059, cD 0.38428, 14.27 secs
# ---- Epoch 16/68
# (1) Training stage (lr = 0.000049) ...
# loss 2.07059, wmdcmp 0.25977, report_loss 2.11226, 123.04 secs
# (2) Validation stage ...
# wmdcmp 0.13797, cD 0.41265, 14.35 secs
# ---- Epoch 17/68
# (1) Training stage (lr = 0.000024) ...
# loss 2.08235, wmdcmp 0.26184, report_loss 2.10198, 123.60 secs
# (2) Validation stage ...
# wmdcmp 0.12568, cD 0.37146, 14.30 secs
# ---- Epoch 18/68
# (1) Training stage (lr = 0.000012) ...
# loss 2.03729, wmdcmp 0.26233, report_loss 2.09660, 124.01 secs
# (2) Validation stage ...
# wmdcmp 0.13879, cD 0.42742, 14.26 secs
# ---- Epoch 19/68
# (1) Training stage (lr = 0.000006) ...
# loss 2.02260, wmdcmp 0.26202, report_loss 2.09836, 124.22 secs
# (2) Validation stage ...
# wmdcmp 0.12448, cD 0.36809, 14.53 secs
# ---- Epoch 20/68
# (1) Training stage (lr = 0.000003) ...
# loss 2.11606, wmdcmp 0.26235, report_loss 2.09521, 124.25 secs
# (2) Validation stage ...
# wmdcmp 0.13682, cD 0.42413, 14.37 secs
# ---- Epoch 21/68
# (1) Training stage (lr = 0.000400) ...
# loss 2.03282, wmdcmp 0.25844, report_loss 2.11136, 124.11 secs
# (2) Validation stage ...
# wmdcmp 0.12610, cD 0.32536, 14.39 secs
# ---- Epoch 22/68
# (1) Training stage (lr = 0.000199) ...
# loss 2.10070, wmdcmp 0.26790, report_loss 2.04979, 123.04 secs
# (2) Validation stage ...
# wmdcmp 0.13206, cD 0.38549, 14.06 secs
# ---- Epoch 23/68
# (1) Training stage (lr = 0.000099) ...
# loss 2.05446, wmdcmp 0.27245, report_loss 2.01958, 123.18 secs
# (2) Validation stage ...
# wmdcmp 0.12315, cD 0.34872, 14.40 secs
# ---- Epoch 24/68
# (1) Training stage (lr = 0.000049) ...
# loss 1.94476, wmdcmp 0.27412, report_loss 2.01032, 122.69 secs
# (2) Validation stage ...
# wmdcmp 0.13257, cD 0.37668, 15.50 secs
# ---- Epoch 25/68
# (1) Training stage (lr = 0.000024) ...
# loss 2.03204, wmdcmp 0.27690, report_loss 1.99278, 121.26 secs
# (2) Validation stage ...
# wmdcmp 0.12352, cD 0.37051, 14.46 secs
# ---- Epoch 26/68
# (1) Training stage (lr = 0.000012) ...
# loss 1.95796, wmdcmp 0.27673, report_loss 1.99134, 121.25 secs
# (2) Validation stage ...
# wmdcmp 0.12188, cD 0.35600, 14.45 secs
# ---- Epoch 27/68
# (1) Training stage (lr = 0.000006) ...
# loss 2.04745, wmdcmp 0.27740, report_loss 1.98790, 121.67 secs
# (2) Validation stage ...
# wmdcmp 0.12354, cD 0.36305, 14.25 secs
# ---- Epoch 28/68
# (1) Training stage (lr = 0.000003) ...
# loss 1.96577, wmdcmp 0.27753, report_loss 1.98692, 121.20 secs
# (2) Validation stage ...
# wmdcmp 0.12371, cD 0.35937, 14.10 secs
# ---- Epoch 29/68
# (1) Training stage (lr = 0.000400) ...
# loss 1.94290, wmdcmp 0.27080, report_loss 2.01704, 123.55 secs
# (2) Validation stage ...
# wmdcmp 0.12311, cD 0.32860, 14.41 secs
# ---- Epoch 30/68
# (1) Training stage (lr = 0.000199) ...
# loss 1.97629, wmdcmp 0.27887, report_loss 1.97186, 122.98 secs
# (2) Validation stage ...
# wmdcmp 0.13432, cD 0.41650, 13.98 secs
# ---- Epoch 31/68
# (1) Training stage (lr = 0.000099) ...
# loss 1.89198, wmdcmp 0.28339, report_loss 1.94027, 123.52 secs
# (2) Validation stage ...
# wmdcmp 0.12317, cD 0.37078, 14.31 secs
# ---- Epoch 32/68
# (1) Training stage (lr = 0.000049) ...
# loss 1.96792, wmdcmp 0.28551, report_loss 1.93212, 124.37 secs
# (2) Validation stage ...
# wmdcmp 0.12159, cD 0.33971, 14.37 secs
# ---- Epoch 33/68
# (1) Training stage (lr = 0.000024) ...
# loss 1.85895, wmdcmp 0.28809, report_loss 1.91859, 122.66 secs
# (2) Validation stage ...
# wmdcmp 0.12196, cD 0.34608, 14.31 secs
# ---- Epoch 34/68
# (1) Training stage (lr = 0.000012) ...
# loss 1.89377, wmdcmp 0.28775, report_loss 1.91781, 122.47 secs
# (2) Validation stage ...
# wmdcmp 0.12623, cD 0.35987, 14.23 secs
# ---- Epoch 35/68
# (1) Training stage (lr = 0.000006) ...
# loss 1.85911, wmdcmp 0.28757, report_loss 1.91532, 122.11 secs
# (2) Validation stage ...
# wmdcmp 0.12326, cD 0.35424, 14.41 secs
# ---- Epoch 36/68
# (1) Training stage (lr = 0.000003) ...
# loss 1.86817, wmdcmp 0.28847, report_loss 1.91254, 124.16 secs
# (2) Validation stage ...
# wmdcmp 0.12302, cD 0.35070, 14.34 secs
# ---- Epoch 37/68
# (1) Training stage (lr = 0.000400) ...
# loss 1.95758, wmdcmp 0.28002, report_loss 1.95190, 122.16 secs
# (2) Validation stage ...
# wmdcmp 0.12946, cD 0.38598, 14.44 secs
# ---- Epoch 38/68
# (1) Training stage (lr = 0.000199) ...
# loss 1.94698, wmdcmp 0.28901, report_loss 1.90713, 122.78 secs
# (2) Validation stage ...
# wmdcmp 0.12276, cD 0.35725, 14.27 secs
# ---- Epoch 39/68
# (1) Training stage (lr = 0.000099) ...
# loss 1.92615, wmdcmp 0.29179, report_loss 1.88201, 122.36 secs
# (2) Validation stage ...
# wmdcmp 0.12812, cD 0.39095, 14.06 secs
# ---- Epoch 40/68
# (1) Training stage (lr = 0.000049) ...
# loss 1.78318, wmdcmp 0.29460, report_loss 1.86952, 121.90 secs
# (2) Validation stage ...
# wmdcmp 0.12639, cD 0.36540, 14.17 secs
# ---- Epoch 41/68
# (1) Training stage (lr = 0.000024) ...
# loss 1.81007, wmdcmp 0.29479, report_loss 1.86649, 122.71 secs
# (2) Validation stage ...
# wmdcmp 0.12241, cD 0.34664, 14.15 secs
# ---- Epoch 42/68
# (1) Training stage (lr = 0.000012) ...
# loss 1.84003, wmdcmp 0.29544, report_loss 1.86452, 122.54 secs
# (2) Validation stage ...
# wmdcmp 0.12624, cD 0.35555, 14.12 secs
# ---- Epoch 43/68
# (1) Training stage (lr = 0.000006) ...
# loss 1.98565, wmdcmp 0.29541, report_loss 1.85886, 121.89 secs
# (2) Validation stage ...
# wmdcmp 0.12293, cD 0.35189, 14.24 secs
# ---- Epoch 44/68
# (1) Training stage (lr = 0.000003) ...
# loss 1.88558, wmdcmp 0.29711, report_loss 1.85485, 122.51 secs
# (2) Validation stage ...
# wmdcmp 0.12435, cD 0.35495, 14.34 secs
# ---- Epoch 45/68
# (1) Training stage (lr = 0.000400) ...
# loss 1.88137, wmdcmp 0.28891, report_loss 1.89625, 123.21 secs
# (2) Validation stage ...
# wmdcmp 0.12593, cD 0.35166, 14.31 secs
# ---- Epoch 46/68
# (1) Training stage (lr = 0.000199) ...
# loss 1.96257, wmdcmp 0.29461, report_loss 1.86382, 123.52 secs
# (2) Validation stage ...
# wmdcmp 0.12689, cD 0.35971, 14.21 secs
# ---- Epoch 47/68
# (1) Training stage (lr = 0.000099) ...
# loss 1.98521, wmdcmp 0.29870, report_loss 1.83934, 123.10 secs
# (2) Validation stage ...
# wmdcmp 0.12648, cD 0.40164, 15.37 secs
# ---- Epoch 48/68
# (1) Training stage (lr = 0.000049) ...
# loss 1.99313, wmdcmp 0.30041, report_loss 1.82544, 123.36 secs
# (2) Validation stage ...
# wmdcmp 0.13286, cD 0.40509, 14.32 secs
# ---- Epoch 49/68
# (1) Training stage (lr = 0.000024) ...
# loss 1.90826, wmdcmp 0.30173, report_loss 1.81896, 121.65 secs
# (2) Validation stage ...
# wmdcmp 0.12567, cD 0.36284, 14.16 secs
# ---- Epoch 50/68
# (1) Training stage (lr = 0.000012) ...
# loss 1.88459, wmdcmp 0.30361, report_loss 1.81261, 123.01 secs
# (2) Validation stage ...
# wmdcmp 0.12201, cD 0.33637, 14.27 secs
# ---- Epoch 51/68
# (1) Training stage (lr = 0.000006) ...
# loss 1.85535, wmdcmp 0.30265, report_loss 1.81427, 123.52 secs
# (2) Validation stage ...
# wmdcmp 0.12610, cD 0.34635, 14.16 secs
# ---- Epoch 52/68
# (1) Training stage (lr = 0.000003) ...
# loss 1.83245, wmdcmp 0.30306, report_loss 1.81540, 123.92 secs
# (2) Validation stage ...
# wmdcmp 0.12747, cD 0.36826, 14.30 secs
# ---- Epoch 53/68
# (1) Training stage (lr = 0.000400) ...
# loss 1.75773, wmdcmp 0.29382, report_loss 1.85554, 122.99 secs
# (2) Validation stage ...
# wmdcmp 0.12009, cD 0.37590, 14.23 secs
# ---- Epoch 54/68
# (1) Training stage (lr = 0.000199) ...
# loss 1.82045, wmdcmp 0.30065, report_loss 1.82494, 123.48 secs
# (2) Validation stage ...
# wmdcmp 0.13819, cD 0.41682, 14.17 secs
# ---- Epoch 55/68
# (1) Training stage (lr = 0.000099) ...
# loss 1.82982, wmdcmp 0.30386, report_loss 1.80021, 123.38 secs
# (2) Validation stage ...
# wmdcmp 0.13059, cD 0.37436, 14.27 secs
# ---- Epoch 56/68
# (1) Training stage (lr = 0.000049) ...
# loss 1.79707, wmdcmp 0.30636, report_loss 1.78658, 123.16 secs
# (2) Validation stage ...
# wmdcmp 0.13638, cD 0.40554, 14.29 secs
# ---- Epoch 57/68
# (1) Training stage (lr = 0.000024) ...
# loss 1.75608, wmdcmp 0.30689, report_loss 1.78351, 122.57 secs
# (2) Validation stage ...
# wmdcmp 0.12575, cD 0.35634, 14.24 secs
# ---- Epoch 58/68
# (1) Training stage (lr = 0.000012) ...
# loss 1.60833, wmdcmp 0.30882, report_loss 1.77302, 122.67 secs
# (2) Validation stage ...
# wmdcmp 0.12832, cD 0.37496, 13.99 secs
# ---- Epoch 59/68
# (1) Training stage (lr = 0.000006) ...
# loss 1.59811, wmdcmp 0.30926, report_loss 1.77683, 124.36 secs
# (2) Validation stage ...
# wmdcmp 0.12258, cD 0.34944, 14.00 secs
# ---- Epoch 60/68
# (1) Training stage (lr = 0.000003) ...
# loss 1.75177, wmdcmp 0.30975, report_loss 1.77014, 123.67 secs
# (2) Validation stage ...
# wmdcmp 0.12289, cD 0.34408, 14.11 secs
# ---- Epoch 61/68
# (1) Training stage (lr = 0.000400) ...
# loss 1.82903, wmdcmp 0.29976, report_loss 1.82072, 123.90 secs
# (2) Validation stage ...
# wmdcmp 0.12304, cD 0.35206, 13.99 secs
# ---- Epoch 62/68
# (1) Training stage (lr = 0.000199) ...
# loss 1.94499, wmdcmp 0.30451, report_loss 1.79340, 124.28 secs
# (2) Validation stage ...
# wmdcmp 0.13337, cD 0.40645, 14.05 secs
# ---- Epoch 63/68
# (1) Training stage (lr = 0.000099) ...
# loss 1.73473, wmdcmp 0.30908, report_loss 1.76647, 124.57 secs
# (2) Validation stage ...
# wmdcmp 0.13657, cD 0.40479, 13.88 secs
# ---- Epoch 64/68
# (1) Training stage (lr = 0.000049) ...
# loss 1.75132, wmdcmp 0.31092, report_loss 1.75517, 125.83 secs
# (2) Validation stage ...
# wmdcmp 0.11974, cD 0.32945, 13.70 secs
# ---- Epoch 65/68
# (1) Training stage (lr = 0.000024) ...
# loss 1.60947, wmdcmp 0.31314, report_loss 1.74905, 125.22 secs
# (2) Validation stage ...
# wmdcmp 0.13076, cD 0.37446, 14.26 secs
# ---- Epoch 66/68
# (1) Training stage (lr = 0.000012) ...
# loss 1.57303, wmdcmp 0.31308, report_loss 1.74349, 124.24 secs
# (2) Validation stage ...
# wmdcmp 0.12596, cD 0.36578, 14.08 secs
# ---- Epoch 67/68
# (1) Training stage (lr = 0.000006) ...
# loss 1.64493, wmdcmp 0.31444, report_loss 1.74177, 121.10 secs
# (2) Validation stage ...
# wmdcmp 0.12579, cD 0.35991, 14.28 secs
# ---- Epoch 68/68
# (1) Training stage (lr = 0.000003) ...
# loss 1.75354, wmdcmp 0.31371, report_loss 1.74093, 122.79 secs
# (2) Validation stage ...
# wmdcmp 0.12701, cD 0.36121, 14.35 secs

# %%
# !/home/pamessina/venv2/bin/python ../train_labels2report.py \
    --generation-mode "pred2rep" \
    --use-ensemble \
    --ensemble-model-checkpoint-folder-paths \
        "/mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/" \
    --ensemble-batch-size 160 \
    --ensemble-num-workers 3 \
    --use-hard-predictions \
    --use-gt-labels \
    --train-on-gt-and-eval-on-predictions \
    --randomly-drop-labels \
    --epochs 84 \
    --batches-per-epoch 300 \
    --batch-size 200 \
    --num-workers 3 \
    --iters-to-accumulate 2 \
    --optimizer-name "adamw" \
    --scheduler "exp-warmup+decay+cyclicdecay" \
    --lr 1e-6 \
    --warmup-decay-and-cyclic-decay-args "1e-6,3,4e-4,8,3e-6,4e-4,8,3e-6" \
    --use-mimiccxr \
    --mimiccxr-weight 1.0 \
    --mimiccxr-view-mode "chest_imagenome" \
    --mimiccxr-balanced-sampling-mode "balanced_chest_imagenome_global_labels_batchwise" \
    --mimiccxr-balanced-batch-size 30 \
    --mimiccxr-qa-adapted-reports-filename "qa_adapted_reports__20220904_095810.json" \
    --use-chest-imagenome \
    --use-chest-imagenome-decent-images-only \
    --chest-imagenome-label-names-filename "labels(min_freq=100).pkl" \
    --chest-imagenome-labels-filename "imageId2labels(min_freq=100).pkl" \
    --use-chexpert \
    --mimiccxr-chexpert-labels-filename "chexpert_labels_per_report__20220904_113605.pkl" \
    --use-medical-tokenization \
    --medical-terms-frequency-filename "medical_terms_frequency__20220918_184255.pkl" \
    --binary-loss-name "focal+bce+wbce-c" \
    --labels-hidden-dim 1024 \
    --embedding-dim 512 \
    --transf-dec-num-memory-vecs 10 \
    --transf-dec-hidden-dim 512 \
    --transf-dec-nhead 4 \
    --transf-dec-dim-forward 512 \
    --transf-dec-num-layers 3 \
    --use-amp \
    --save
# Out:
# script's arguments:
#    epochs: 84
#    batches_per_epoch: 300
#    batch_size: 200
#    checkpoint_folder: None
#    generation_mode: pred2rep
#    use_ensemble: True
#    ensemble_model_checkpoint_folder_paths: ['/mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/']
#    ensemble_batch_size: 160
#    ensemble_num_workers: 3
#    use_hard_predictions: True
#    use_gt_labels: True
#    train_on_gt_and_eval_on_predictions: True
#    randomly_drop_labels: True
#    pretrained_checkpoint_folder_path: None
#    labels_hidden_dim: 1024
#    embedding_dim: 512
#    transf_dec_num_memory_vecs: 10
#    transf_dec_hidden_dim: 512
#    transf_dec_nhead: 4
#    transf_dec_dim_forward: 512
#    transf_dec_num_layers: 3
#    dropout_prob: 0
#    vocab_min_freq: 10
#    use_medical_tokenization: True
#    medical_terms_frequency_filename: medical_terms_frequency__20220918_184255.pkl
#    optimizer_name: adamw
#    lr: 1e-06
#    scheduler: exp-warmup+decay+cyclicdecay
#    lr_decay: 0.76
#    lr_decay_patience: 2
#    warmup_and_decay_args: None
#    warmup_and_cosine_args: None
#    warmup_decay_and_cyclic_decay_args: 1e-6,3,4e-4,8,3e-6,4e-4,8,3e-6
#    iters_to_accumulate: 2
#    override_lr: False
#    binary_loss_name: focal+bce+wbce-c
#    focal_loss_weight: 1
#    bce_loss_weight: 1
#    wbce_loss_weight: 1
#    num_workers: 3
#    device: GPU
#    use_amp: True
#    train_mimiccxr: True
#    mimiccxr_weight: 1.0
#    mimiccxr_view_mode: chest_imagenome
#    mimiccxr_balanced_sampling_mode: balanced_chest_imagenome_global_labels_batchwise
#    mimiccxr_balanced_batch_size: 30
#    mimiccxr_qa_adapted_reports_filename: qa_adapted_reports__20220904_095810.json
#    chest_imagenome_labels_filename: imageId2labels(min_freq=100).pkl
#    chest_imagenome_label_names_filename: labels(min_freq=100).pkl
#    use_chest_imagenome_decent_images_only: True
#    save: True
#    use_gender: False
#    use_chexpert: True
#    mimiccxr_chexpert_labels_filename: chexpert_labels_per_report__20220904_113605.pkl
#    use_chest_imagenome: True
#    filter_labels: False
#    top_k_chexpert_labels: None
#    top_k_chest_imagenome_labels: None
#    label_score_threshold: None
#    debug: False
# ----- Training model from scratch ------
# Computing number of labels and ranges for ensemble ...
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/metadata.json
# ensemble_chest_imagenome_range: (0, 627)
# ensemble_chexpert_range: (627, 641)
# Computing number of labels and ranges assuming ground truth labels as input ...
# gt_chest_imagenome_range: (0, 627)
# gt_chexpert_range: (627, 641)
# ============================================================
# Precomputing sigmoid activations for ensemble ...
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/metadata.json
# ============================================================
# Model 1/1
# model_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/
# checkpoint_names = ['checkpoint_79_chou+chuc+chuc+chuc+chuc+cD+gacc+wmmp=0.6677.pt', 'checkpoint_135_chou+chuc+chuc+chuc+chuc+cD+gacc+wmmp=0.6689.pt']
# model_checkpoint_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/checkpoint_135_chou+chuc+chuc+chuc+chuc+cD+gacc+wmmp=0.6689.pt
# precomputed_chexpert_sigmoids_path = /mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/precomputed_chexpert_sigmoids(hash=340,3716123060218160099).pkl
# Precomputed sigmoids for CheXpert already exist.
# File size = 56.39 MB
# precomputed_chest_imagenome_sigmoids_path = /mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/precomputed_chest_imagenome_sigmoids(hash=347,2103260294420767687).pkl
# Precomputed sigmoids for Chest ImaGenome already exist.
# File size = 339.66 MB
# Skipping...
# precomputed_sigmoid_paths: [{'model_folder_path': '/mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/', 'chexpert_sigmoids_path': '/mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/precomputed_chexpert_sigmoids(hash=340,3716123060218160099).pkl', 'chest_imagenome_sigmoids_path': '/mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/precomputed_chest_imagenome_sigmoids(hash=347,2103260294420767687).pkl'}]
# ============================================================
# Precomputing thresholds (for hard predictions) for ensemble ...
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/metadata.json
# ============================================================
# Model 1/1
# model_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/
# checkpoint_names = ['checkpoint_79_chou+chuc+chuc+chuc+chuc+cD+gacc+wmmp=0.6677.pt', 'checkpoint_135_chou+chuc+chuc+chuc+chuc+cD+gacc+wmmp=0.6689.pt']
# model_checkpoint_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/checkpoint_135_chou+chuc+chuc+chuc+chuc+cD+gacc+wmmp=0.6689.pt
# results_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/results/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/
# get_image_transform()
#   Using bounding box aware transforms
#     Returning default transform (no augmentation)
# Calibrating thresholds on MIMIC-CXR validation set
# score_name: f1
# Thresholds for CheXpert already cached at /mnt/data/pamessina/workspaces/medvqa-workspace/results/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/thresholds_chexpert(f1).pkl
# Thresholds for Chest ImaGenome already cached at /mnt/data/pamessina/workspaces/medvqa-workspace/results/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/thresholds_chest_imagenome(f1).pkl
# precomputed_thresholds_paths: [{'chexpert': '/mnt/data/pamessina/workspaces/medvqa-workspace/results/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/thresholds_chexpert(f1).pkl', 'chest_imagenome': '/mnt/data/pamessina/workspaces/medvqa-workspace/results/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/thresholds_chest_imagenome(f1).pkl'}]
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Initializing tokenizer ...
# Loading /mnt/data/pamessina/workspaces/medvqa-workspace/cache/vocab(min_freq=10;mode=report;qa_adapted_reports__20220904_095810.json).pkl ...
# --------------------------------------------------
# 3) Creating instance of Labels2ReportModel ...
# Labels2ReportModel
#   gen_mode: pred2rep
#   vocab_size: 4833
#   embedding_dim: 512
#   num_input_labels: 641
#   labels_hidden_dim: 1024
#   num_output_labels: 641
#   transf_dec_num_memory_vecs: 10
#   transf_dec_hidden_dim: 512
#   transf_dec_nhead: 4
#   transf_dec_dim_forward: 512
#   transf_dec_num_layers: 3
#   start_idx: 1
#   dropout_prob: 0
#   support_two_label_sources: False
#   num_input_labels_2: None
#   labels_hidden_dim_2: 1024
#   num_output_labels_2: None
# WARNING: Unused kwargs: {'device': device(type='cuda'), 'pretrained_checkpoint_folder_path': None}
# --------------------------------------------------
# 4) Defining optimizer ...
# create_optimizer(): name = adamw
# --------------------------------------------------
# 5) Defining scheduler ...
# Using exp-warmup+decay+cyclicdecay scheduler: 1e-6,3,4e-4,8,3e-6,4e-4,8,3e-6
# 1e-06 3 0.0004 8 3e-06 0.0004 8 3e-06
# self.steps_to_restart = 8
# self.steps = -1
# self.initial_lr = 0.0004
# --------------------------------------------------
# 6) Creating trainer and validator engines ...
# Using focal+bce+wbce-c loss
# binary_loss_kwargs: {'focal_weight': 1, 'bce_weight': 1, 'wbce_weight': 1}
# GradientAccumulator.__init__(): num_accumulation_steps = 2
# --------------------------------------------------
# 7) Defining collate_batch_fn ...
# --------------------------------------------------
# 8) Creating MIMIC-CXR_Labels2ReportTrainer ...
# 227835it [00:17, 12674.41it/s]
# max_idx_count = 377110
# actual_idx_count = 239513
# ** NOTE: 137597 images were skipped because they were not in the allowed DICOM IDs
# Random report:
# <s> worsening perihilar opacity upper lobe . small left effusion right . moderate cardiomegaly . no pneumothorax . left sided picc line below carina right atrium . endotracheal tube carina nasogastric tube normal position . worsening perihilar opacity , worsening superimposed edema , worsening infection upper lobe </s>
# len(self.train_indices) = 234217
# len(self.val_indices) = 1934
# Loading CheXpert labels...
# Loading Chest Imagenome labels...
# Loading precomputed sigmoid paths for ensemble predictions...
#   Loading /mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/precomputed_chexpert_sigmoids(hash=340,3716123060218160099).pkl
#     _probs.shape = (242280, 14)
#     len(_dids) = 242280
#     _thresholds.shape = (14,)
#     _probs has been thresholded
#     Sanity checking chexpert labels
#     len(self.val_indices) = 1934
#     f1_score(_gt_labels, _pred_labels, average="micro") = 0.5885286783042394
#     f1_score(_gt_labels, _pred_labels, average="macro") = 0.48877588205948314
# Label order inferred from labels(min_freq=100).pkl
#   Loading /mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/precomputed_chest_imagenome_sigmoids(hash=347,2103260294420767687).pkl
#     _probs.shape = (242280, 627)
#     len(_dids) = 242280
#     _thresholds.shape = (627,)
#     _probs has been thresholded
#     Sanity checking chest_imagenome labels
#     len(self.val_indices) = 1934
#     f1_score(_gt_labels, _pred_labels, average="micro") = 0.2304808503177002
#     f1_score(_gt_labels, _pred_labels, average="macro") = 0.22673751197996303
# Done loading precomputed sigmoid paths for ensemble predictions
# Creating MIMIC-CXR_Labels2ReportTrainer for second label source ...
# 227835it [00:17, 12673.56it/s]
# max_idx_count = 377110
# actual_idx_count = 227835
# ** NOTE: 149275 images were skipped because they were not in the allowed DICOM IDs
# Random report:
# <s> mild elevation left hemidiaphragm . heart size normal . mediastinal hilar contours normal . pulmonary vasculature normal . lungs clear . no pleural effusion pneumothorax . no osseous abnormality . no cardiopulmonary abnormality . mild elevation left hemidiaphragm </s>
# len(self.train_indices) = 222758
# len(self.val_indices) = 1808
# Loading CheXpert labels...
# Loading Chest Imagenome labels...
# Reordering Chest Imagenome labels...
# Balanced sampling mode: balanced_chest_imagenome_global_labels_batchwise
# Regrouping indices by Chest Imagenome labels for balanced sampling...
# 627it [00:59, 10.48it/s]
# Global: abnormal                                , # images: 168425 (other: 54333)
# Global: lung opacity                            , # images: 141722 (other: 81036)
# Global: atelectasis                             , # images: 72861 (other: 149897)
# Global: pleural effusion                        , # images: 66227 (other: 156531)
# Global: enlarged cardiac silhouette             , # images: 52931 (other: 169827)
# Global: pulmonary edema/hazy opacity            , # images: 32381 (other: 190377)
# Global: pneumonia                               , # images: 31494 (other: 191264)
# Global: low lung volumes                        , # images: 26283 (other: 196475)
# Global: enteric tube                            , # images: 24273 (other: 198485)
# Global: vascular congestion                     , # images: 22671 (other: 200087)
# Global: endotracheal tube                       , # images: 20404 (other: 202354)
# Global: consolidation                           , # images: 16184 (other: 206574)
# Global: picc                                    , # images: 12972 (other: 209786)
# Global: pleural/parenchymal scarring            , # images: 12849 (other: 209909)
# Global: tortuous aorta                          , # images: 12349 (other: 210409)
# Global: lung lesion                             , # images: 12246 (other: 210512)
# Global: linear/patchy atelectasis               , # images: 11808 (other: 210950)
# Global: cardiac pacer and wires                 , # images: 11259 (other: 211499)
# Global: ij line                                 , # images: 11065 (other: 211693)
# Global: pneumothorax                            , # images: 9708 (other: 213050)
# Global: chest tube                              , # images: 9464 (other: 213294)
# Global: vascular calcification                  , # images: 9425 (other: 213333)
# Global: hyperaeration                           , # images: 9107 (other: 213651)
# Global: lobar/segmental collapse                , # images: 8771 (other: 213987)
# Global: enlarged hilum                          , # images: 8201 (other: 214557)
# Global: aspiration                              , # images: 8152 (other: 214606)
# Global: airspace opacity                        , # images: 7878 (other: 214880)
# Global: mass/nodule (not otherwise specified)   , # images: 7127 (other: 215631)
# Global: chest port                              , # images: 6601 (other: 216157)
# Global: rib fracture                            , # images: 6353 (other: 216405)
# Global: spinal degenerative changes             , # images: 6069 (other: 216689)
# Global: fluid overload/heart failure            , # images: 5970 (other: 216788)
# Global: elevated hemidiaphragm                  , # images: 5869 (other: 216889)
# Global: copd/emphysema                          , # images: 5812 (other: 216946)
# Global: costophrenic angle blunting             , # images: 5298 (other: 217460)
# Global: mediastinal widening                    , # images: 4604 (other: 218154)
# Global: tracheostomy tube                       , # images: 4265 (other: 218493)
# Global: subclavian line                         , # images: 3502 (other: 219256)
# Global: cabg grafts                             , # images: 3433 (other: 219325)
# Global: multiple masses/nodules                 , # images: 3380 (other: 219378)
# Global: pigtail catheter                        , # images: 3240 (other: 219518)
# Global: mediastinal displacement                , # images: 3183 (other: 219575)
# Global: subcutaneous air                        , # images: 3077 (other: 219681)
# Global: superior mediastinal mass/enlargement   , # images: 2996 (other: 219762)
# Global: vascular redistribution                 , # images: 2975 (other: 219783)
# Global: scoliosis                               , # images: 2946 (other: 219812)
# Global: spinal fracture                         , # images: 2873 (other: 219885)
# Global: hernia                                  , # images: 2805 (other: 219953)
# Global: infiltration                            , # images: 2732 (other: 220026)
# Global: prosthetic valve                        , # images: 2623 (other: 220135)
# Global: calcified nodule                        , # images: 2437 (other: 220321)
# Global: granulomatous disease                   , # images: 2174 (other: 220584)
# Global: shoulder osteoarthritis                 , # images: 2016 (other: 220742)
# Global: swan-ganz catheter                      , # images: 1939 (other: 220819)
# Global: interstitial lung disease               , # images: 1817 (other: 220941)
# Global: rotated                                 , # images: 1809 (other: 220949)
# Global: alveolar hemorrhage                     , # images: 1642 (other: 221116)
# Global: lung cancer                             , # images: 1581 (other: 221177)
# Global: bone lesion                             , # images: 1523 (other: 221235)
# Global: pericardial effusion                    , # images: 1302 (other: 221456)
# Global: increased reticular markings/ild pattern, # images: 1274 (other: 221484)
# Global: sub-diaphragmatic air                   , # images: 1117 (other: 221641)
# Global: breast/nipple shadows                   , # images: 898 (other: 221860)
# Global: hydropneumothorax                       , # images: 879 (other: 221879)
# Global: bronchiectasis                          , # images: 835 (other: 221923)
# Global: pneumomediastinum                       , # images: 792 (other: 221966)
# Global: clavicle fracture                       , # images: 789 (other: 221969)
# Global: cyst/bullae                             , # images: 766 (other: 221992)
# Global: goiter                                  , # images: 565 (other: 222193)
# Global: intra-aortic balloon pump               , # images: 501 (other: 222257)
# Global: mediastinal drain                       , # images: 397 (other: 222361)
# Global: artifact                                , # images: 286 (other: 222472)
# Global: skin fold                               , # images: 195 (other: 222563)
# Global: aortic graft/repair                     , # images: 101 (other: 222657)
# --------------------------------------------------
# 9) Creating dataloaders ...
# len(_train_dataloaders) = 1
# len(_val_dataloaders) = 2
# _train_weights = [1.0]
# merged_dataset_name = mim(gt)
# --------------------------------------------------
# 10) Attaching metrics, losses, timer and events to engines ...
# --------------------------------------------------
# 11) Defining learning rate scheduler handler ...
# --------------------------------------------------
# 12) Defining checkpoint folder path ...
# checkpoint_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/report_gen/20230509_100819_mim(gt)_Labels2ReportModel(641,10,TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512)))
# metadata saved to /mnt/data/pamessina/workspaces/medvqa-workspace/models/report_gen/20230509_100819_mim(gt)_Labels2ReportModel(641,10,TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512)))/metadata.json
# --------------------------------------------------
# 13) Defining log_metrics_handler ...
# MetricsLogger :: we'll be logging to /mnt/data/pamessina/workspaces/medvqa-workspace/models/report_gen/20230509_100819_mim(gt)_Labels2ReportModel(641,10,TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512)))/metrics_logs.csv
# --------------------------------------------------
# 14) Running trainer engine ...
# ---- Epoch 1/84
# (1) Training stage (lr = 0.000001) ...
# loss 8.73507, wmdcmp_gt 0.00485, report_loss 8.52323, 181.17 secs
# (2) Validation stage ...
# wmdcmp 0.00723, wmdcmp_gt 0.00642, cD 0.00047, cD_gt 0.00038, 32.95 secs
# ---- Epoch 2/84
# (1) Training stage (lr = 0.000007) ...
# loss 8.29658, wmdcmp_gt 0.00169, report_loss 6.87290, 165.74 secs
# (2) Validation stage ...
# wmdcmp 0.00052, wmdcmp_gt 0.00055, cD 0.00042, cD_gt 0.00040, 24.92 secs
# ---- Epoch 3/84
# (1) Training stage (lr = 0.000054) ...
# loss 6.00892, wmdcmp_gt 0.05411, report_loss 4.58005, 161.27 secs
# (2) Validation stage ...
# wmdcmp 0.03155, wmdcmp_gt 0.03365, cD 0.00174, cD_gt 0.00212, 29.91 secs
# ---- Epoch 4/84
# (1) Training stage (lr = 0.000400) ...
# loss 3.72039, wmdcmp_gt 0.17088, report_loss 2.94449, 137.50 secs
# (2) Validation stage ...
# wmdcmp 0.06879, wmdcmp_gt 0.15221, cD 0.09774, cD_gt 0.49273, 27.69 secs
# ---- Epoch 5/84
# (1) Training stage (lr = 0.000217) ...
# loss 2.36932, wmdcmp_gt 0.22656, report_loss 2.40954, 138.40 secs
# (2) Validation stage ...
# wmdcmp 0.04980, wmdcmp_gt 0.16178, cD 0.04445, cD_gt 0.52781, 28.44 secs
# ---- Epoch 6/84
# (1) Training stage (lr = 0.000118) ...
# loss 2.26761, wmdcmp_gt 0.24136, report_loss 2.29220, 141.01 secs
# (2) Validation stage ...
# wmdcmp 0.03836, wmdcmp_gt 0.16149, cD 0.00996, cD_gt 0.54201, 29.66 secs
# ---- Epoch 7/84
# (1) Training stage (lr = 0.000064) ...
# loss 2.33140, wmdcmp_gt 0.24882, report_loss 2.24101, 142.27 secs
# (2) Validation stage ...
# wmdcmp 0.03288, wmdcmp_gt 0.17729, cD 0.00431, cD_gt 0.62536, 29.34 secs
# ---- Epoch 8/84
# (1) Training stage (lr = 0.000035) ...
# loss 2.27900, wmdcmp_gt 0.25132, report_loss 2.21759, 139.94 secs
# (2) Validation stage ...
# wmdcmp 0.03305, wmdcmp_gt 0.17124, cD 0.00441, cD_gt 0.60466, 30.49 secs
# ---- Epoch 9/84
# (1) Training stage (lr = 0.000019) ...
# loss 2.25884, wmdcmp_gt 0.25423, report_loss 2.19536, 145.87 secs
# (2) Validation stage ...
# wmdcmp 0.03460, wmdcmp_gt 0.17309, cD 0.00422, cD_gt 0.63708, 31.30 secs
# ---- Epoch 10/84
# (1) Training stage (lr = 0.000010) ...
# loss 2.29551, wmdcmp_gt 0.25498, report_loss 2.19370, 145.55 secs
# (2) Validation stage ...
# wmdcmp 0.03358, wmdcmp_gt 0.17134, cD 0.00480, cD_gt 0.61147, 30.81 secs
# ---- Epoch 11/84
# (1) Training stage (lr = 0.000006) ...
# loss 2.26200, wmdcmp_gt 0.25371, report_loss 2.19041, 145.93 secs
# (2) Validation stage ...
# wmdcmp 0.03235, wmdcmp_gt 0.17273, cD 0.00349, cD_gt 0.61222, 30.53 secs
# ---- Epoch 12/84
# (1) Training stage (lr = 0.000003) ...
# loss 2.24877, wmdcmp_gt 0.25484, report_loss 2.18335, 149.27 secs
# (2) Validation stage ...
# wmdcmp 0.03196, wmdcmp_gt 0.17267, cD 0.00279, cD_gt 0.61891, 30.61 secs
# ---- Epoch 13/84
# (1) Training stage (lr = 0.000400) ...
# loss 2.20837, wmdcmp_gt 0.25780, report_loss 2.16580, 146.07 secs
# (2) Validation stage ...
# wmdcmp 0.02332, wmdcmp_gt 0.17942, cD 0.00287, cD_gt 0.64800, 29.36 secs
# ---- Epoch 14/84
# (1) Training stage (lr = 0.000199) ...
# loss 2.19031, wmdcmp_gt 0.27286, report_loss 2.06819, 143.44 secs
# (2) Validation stage ...
# wmdcmp 0.02494, wmdcmp_gt 0.17999, cD 0.00102, cD_gt 0.65176, 30.59 secs
# ---- Epoch 15/84
# (1) Training stage (lr = 0.000099) ...
# loss 2.04061, wmdcmp_gt 0.27916, report_loss 2.02839, 146.68 secs
# (2) Validation stage ...
# wmdcmp 0.02202, wmdcmp_gt 0.18700, cD 0.00121, cD_gt 0.71329, 30.45 secs
# ---- Epoch 16/84
# (1) Training stage (lr = 0.000049) ...
# loss 2.06444, wmdcmp_gt 0.28259, report_loss 1.99714, 145.81 secs
# (2) Validation stage ...
# wmdcmp 0.02453, wmdcmp_gt 0.18980, cD 0.00110, cD_gt 0.72413, 30.85 secs
# ---- Epoch 17/84
# (1) Training stage (lr = 0.000024) ...
# loss 2.07947, wmdcmp_gt 0.28313, report_loss 1.99671, 145.88 secs
# (2) Validation stage ...
# wmdcmp 0.02426, wmdcmp_gt 0.18439, cD 0.00088, cD_gt 0.69833, 29.64 secs
# ---- Epoch 18/84
# (1) Training stage (lr = 0.000012) ...
# loss 1.91688, wmdcmp_gt 0.28467, report_loss 1.98355, 147.49 secs
# (2) Validation stage ...
# wmdcmp 0.02337, wmdcmp_gt 0.18823, cD 0.00097, cD_gt 0.71983, 32.02 secs
# ---- Epoch 19/84
# (1) Training stage (lr = 0.000006) ...
# loss 2.06570, wmdcmp_gt 0.28594, report_loss 1.98610, 148.22 secs
# (2) Validation stage ...
# wmdcmp 0.02372, wmdcmp_gt 0.18840, cD 0.00098, cD_gt 0.73442, 31.19 secs
# ---- Epoch 20/84
# (1) Training stage (lr = 0.000003) ...
# loss 1.95311, wmdcmp_gt 0.28572, report_loss 1.98118, 148.83 secs
# (2) Validation stage ...
# wmdcmp 0.02350, wmdcmp_gt 0.18725, cD 0.00124, cD_gt 0.71657, 30.53 secs
# ---- Epoch 21/84
# (1) Training stage (lr = 0.000400) ...
# loss 1.86744, wmdcmp_gt 0.28195, report_loss 1.99485, 150.52 secs
# (2) Validation stage ...
# wmdcmp 0.04414, wmdcmp_gt 0.18940, cD 0.00273, cD_gt 0.75895, 31.88 secs
# ---- Epoch 22/84
# (1) Training stage (lr = 0.000199) ...
# loss 1.93762, wmdcmp_gt 0.29351, report_loss 1.93517, 152.67 secs
# (2) Validation stage ...
# wmdcmp 0.02325, wmdcmp_gt 0.19217, cD 0.00121, cD_gt 0.77730, 31.12 secs
# ---- Epoch 23/84
# (1) Training stage (lr = 0.000099) ...
# loss 1.86435, wmdcmp_gt 0.29750, report_loss 1.90702, 155.43 secs
# (2) Validation stage ...
# wmdcmp 0.02619, wmdcmp_gt 0.19587, cD 0.00126, cD_gt 0.80617, 47.59 secs
# ---- Epoch 24/84
# (1) Training stage (lr = 0.000049) ...
# loss 1.85167, wmdcmp_gt 0.30067, report_loss 1.88581, 150.64 secs
# (2) Validation stage ...
# wmdcmp 0.02707, wmdcmp_gt 0.19513, cD 0.00088, cD_gt 0.78131, 31.76 secs
# ---- Epoch 25/84
# (1) Training stage (lr = 0.000024) ...
# loss 1.76043, wmdcmp_gt 0.30173, report_loss 1.88247, 151.42 secs
# (2) Validation stage ...
# wmdcmp 0.02735, wmdcmp_gt 0.19271, cD 0.00092, cD_gt 0.77127, 33.31 secs
# ---- Epoch 26/84
# (1) Training stage (lr = 0.000012) ...
# loss 1.83846, wmdcmp_gt 0.30293, report_loss 1.87505, 153.54 secs
# (2) Validation stage ...
# wmdcmp 0.02597, wmdcmp_gt 0.19790, cD 0.00083, cD_gt 0.80949, 31.98 secs
# ---- Epoch 27/84
# (1) Training stage (lr = 0.000006) ...
# loss 1.92763, wmdcmp_gt 0.30221, report_loss 1.87231, 150.25 secs
# (2) Validation stage ...
# wmdcmp 0.02684, wmdcmp_gt 0.19790, cD 0.00085, cD_gt 0.82415, 32.48 secs
# ---- Epoch 28/84
# (1) Training stage (lr = 0.000003) ...
# loss 1.92760, wmdcmp_gt 0.30319, report_loss 1.87510, 151.98 secs
# (2) Validation stage ...
# wmdcmp 0.02734, wmdcmp_gt 0.19781, cD 0.00111, cD_gt 0.81731, 34.34 secs
# ---- Epoch 29/84
# (1) Training stage (lr = 0.000400) ...
# loss 1.80903, wmdcmp_gt 0.29668, report_loss 1.89943, 150.45 secs
# (2) Validation stage ...
# wmdcmp 0.04109, wmdcmp_gt 0.19381, cD 0.00434, cD_gt 0.75415, 35.65 secs
# ---- Epoch 30/84
# (1) Training stage (lr = 0.000199) ...
# loss 1.81585, wmdcmp_gt 0.30527, report_loss 1.85355, 149.67 secs
# (2) Validation stage ...
# wmdcmp 0.03605, wmdcmp_gt 0.19192, cD 0.00595, cD_gt 0.78045, 35.90 secs
# ---- Epoch 31/84
# (1) Training stage (lr = 0.000099) ...
# loss 1.68682, wmdcmp_gt 0.30958, report_loss 1.82666, 150.40 secs
# (2) Validation stage ...
# wmdcmp 0.04328, wmdcmp_gt 0.19324, cD 0.00480, cD_gt 0.79628, 31.90 secs
# ---- Epoch 32/84
# (1) Training stage (lr = 0.000049) ...
# loss 1.77428, wmdcmp_gt 0.31355, report_loss 1.80979, 150.45 secs
# (2) Validation stage ...
# wmdcmp 0.04073, wmdcmp_gt 0.20540, cD 0.00592, cD_gt 0.84631, 35.08 secs
# ---- Epoch 33/84
# (1) Training stage (lr = 0.000024) ...
# loss 1.85965, wmdcmp_gt 0.31502, report_loss 1.80421, 152.57 secs
# (2) Validation stage ...
# wmdcmp 0.04052, wmdcmp_gt 0.20393, cD 0.00615, cD_gt 0.84916, 31.19 secs
# ---- Epoch 34/84
# (1) Training stage (lr = 0.000012) ...
# loss 1.75435, wmdcmp_gt 0.31552, report_loss 1.79773, 148.97 secs
# (2) Validation stage ...
# wmdcmp 0.03945, wmdcmp_gt 0.20485, cD 0.00475, cD_gt 0.85741, 32.25 secs
# ---- Epoch 35/84
# (1) Training stage (lr = 0.000006) ...
# loss 1.69640, wmdcmp_gt 0.31518, report_loss 1.79847, 148.93 secs
# (2) Validation stage ...
# wmdcmp 0.03824, wmdcmp_gt 0.20343, cD 0.00317, cD_gt 0.82744, 31.44 secs
# ---- Epoch 36/84
# (1) Training stage (lr = 0.000003) ...
# loss 1.84117, wmdcmp_gt 0.31627, report_loss 1.79124, 148.17 secs
# (2) Validation stage ...
# wmdcmp 0.03852, wmdcmp_gt 0.20425, cD 0.00402, cD_gt 0.84631, 30.23 secs
# ---- Epoch 37/84
# (1) Training stage (lr = 0.000400) ...
# loss 1.80192, wmdcmp_gt 0.30629, report_loss 1.83216, 150.80 secs
# (2) Validation stage ...
# wmdcmp 0.04467, wmdcmp_gt 0.19166, cD 0.01095, cD_gt 0.73519, 30.87 secs
# ---- Epoch 38/84
# (1) Training stage (lr = 0.000199) ...
# loss 1.79204, wmdcmp_gt 0.31523, report_loss 1.79547, 146.55 secs
# (2) Validation stage ...
# wmdcmp 0.04696, wmdcmp_gt 0.20047, cD 0.01042, cD_gt 0.80785, 30.93 secs
# ---- Epoch 39/84
# (1) Training stage (lr = 0.000099) ...
# loss 1.74163, wmdcmp_gt 0.31958, report_loss 1.76735, 148.73 secs
# (2) Validation stage ...
# wmdcmp 0.04253, wmdcmp_gt 0.20015, cD 0.01039, cD_gt 0.85060, 30.44 secs
# ---- Epoch 40/84
# (1) Training stage (lr = 0.000049) ...
# loss 1.75816, wmdcmp_gt 0.32364, report_loss 1.75015, 146.80 secs
# (2) Validation stage ...
# wmdcmp 0.04030, wmdcmp_gt 0.19749, cD 0.00620, cD_gt 0.83964, 30.64 secs
# ---- Epoch 41/84
# (1) Training stage (lr = 0.000024) ...
# loss 1.63187, wmdcmp_gt 0.32456, report_loss 1.74511, 144.66 secs
# (2) Validation stage ...
# wmdcmp 0.04157, wmdcmp_gt 0.20445, cD 0.00708, cD_gt 0.86653, 31.75 secs
# ---- Epoch 42/84
# (1) Training stage (lr = 0.000012) ...
# loss 1.79570, wmdcmp_gt 0.32536, report_loss 1.74000, 146.51 secs
# (2) Validation stage ...
# wmdcmp 0.04052, wmdcmp_gt 0.20628, cD 0.00637, cD_gt 0.88438, 30.76 secs
# ---- Epoch 43/84
# (1) Training stage (lr = 0.000006) ...
# loss 1.77182, wmdcmp_gt 0.32580, report_loss 1.73593, 147.32 secs
# (2) Validation stage ...
# wmdcmp 0.04164, wmdcmp_gt 0.20525, cD 0.00699, cD_gt 0.86955, 30.06 secs
# ---- Epoch 44/84
# (1) Training stage (lr = 0.000003) ...
# loss 1.86342, wmdcmp_gt 0.32603, report_loss 1.73515, 145.83 secs
# (2) Validation stage ...
# wmdcmp 0.04162, wmdcmp_gt 0.20041, cD 0.00745, cD_gt 0.84312, 30.51 secs
# ---- Epoch 45/84
# (1) Training stage (lr = 0.000400) ...
# loss 1.82600, wmdcmp_gt 0.31629, report_loss 1.77835, 144.00 secs
# (2) Validation stage ...
# wmdcmp 0.03999, wmdcmp_gt 0.20070, cD 0.01460, cD_gt 0.84430, 29.99 secs
# ---- Epoch 46/84
# (1) Training stage (lr = 0.000199) ...
# loss 1.85509, wmdcmp_gt 0.32291, report_loss 1.74744, 145.68 secs
# (2) Validation stage ...
# wmdcmp 0.03959, wmdcmp_gt 0.20503, cD 0.00656, cD_gt 0.88074, 32.86 secs
# ---- Epoch 47/84
# (1) Training stage (lr = 0.000099) ...
# loss 1.83905, wmdcmp_gt 0.32830, report_loss 1.71836, 145.34 secs
# (2) Validation stage ...
# wmdcmp 0.03681, wmdcmp_gt 0.20051, cD 0.00383, cD_gt 0.85505, 32.37 secs
# ---- Epoch 48/84
# (1) Training stage (lr = 0.000049) ...
# loss 1.72016, wmdcmp_gt 0.33153, report_loss 1.70680, 146.72 secs
# (2) Validation stage ...
# wmdcmp 0.03661, wmdcmp_gt 0.20829, cD 0.00565, cD_gt 0.88314, 30.80 secs
# ---- Epoch 49/84
# (1) Training stage (lr = 0.000024) ...
# loss 1.68687, wmdcmp_gt 0.33367, report_loss 1.69858, 149.15 secs
# (2) Validation stage ...
# wmdcmp 0.03727, wmdcmp_gt 0.20979, cD 0.00457, cD_gt 0.89786, 31.16 secs
# ---- Epoch 50/84
# (1) Training stage (lr = 0.000012) ...
# loss 1.69354, wmdcmp_gt 0.33365, report_loss 1.69305, 149.19 secs
# (2) Validation stage ...
# wmdcmp 0.03740, wmdcmp_gt 0.20976, cD 0.00605, cD_gt 0.90100, 31.70 secs
# ---- Epoch 51/84
# (1) Training stage (lr = 0.000006) ...
# loss 1.75972, wmdcmp_gt 0.33397, report_loss 1.69073, 148.61 secs
# (2) Validation stage ...
# wmdcmp 0.03635, wmdcmp_gt 0.20992, cD 0.00410, cD_gt 0.89288, 31.59 secs
# ---- Epoch 52/84
# (1) Training stage (lr = 0.000003) ...
# loss 1.73221, wmdcmp_gt 0.33491, report_loss 1.68827, 148.08 secs
# (2) Validation stage ...
# wmdcmp 0.03673, wmdcmp_gt 0.21052, cD 0.00424, cD_gt 0.89814, 32.04 secs
# ---- Epoch 53/84
# (1) Training stage (lr = 0.000400) ...
# loss 1.77627, wmdcmp_gt 0.32327, report_loss 1.73444, 147.76 secs
# (2) Validation stage ...
# wmdcmp 0.03446, wmdcmp_gt 0.18699, cD 0.00519, cD_gt 0.79561, 32.11 secs
# ---- Epoch 54/84
# (1) Training stage (lr = 0.000199) ...
# loss 1.68768, wmdcmp_gt 0.33004, report_loss 1.70795, 151.87 secs
# (2) Validation stage ...
# wmdcmp 0.03811, wmdcmp_gt 0.19976, cD 0.00217, cD_gt 0.83391, 33.47 secs
# ---- Epoch 55/84
# (1) Training stage (lr = 0.000099) ...
# loss 1.63316, wmdcmp_gt 0.33387, report_loss 1.68281, 152.49 secs
# (2) Validation stage ...
# wmdcmp 0.03915, wmdcmp_gt 0.21152, cD 0.00277, cD_gt 0.94885, 56.99 secs
# ---- Epoch 56/84
# (1) Training stage (lr = 0.000049) ...
# loss 1.76883, wmdcmp_gt 0.33625, report_loss 1.67204, 148.95 secs
# (2) Validation stage ...
# wmdcmp 0.03733, wmdcmp_gt 0.20370, cD 0.00305, cD_gt 0.87991, 33.97 secs
# ---- Epoch 57/84
# (1) Training stage (lr = 0.000024) ...
# loss 1.69637, wmdcmp_gt 0.34000, report_loss 1.65727, 150.63 secs
# (2) Validation stage ...
# wmdcmp 0.03811, wmdcmp_gt 0.20074, cD 0.00402, cD_gt 0.87772, 35.46 secs
# ---- Epoch 58/84
# (1) Training stage (lr = 0.000012) ...
# loss 1.68753, wmdcmp_gt 0.34034, report_loss 1.65755, 147.71 secs
# (2) Validation stage ...
# wmdcmp 0.03801, wmdcmp_gt 0.21008, cD 0.00338, cD_gt 0.90992, 34.20 secs
# ---- Epoch 59/84
# (1) Training stage (lr = 0.000006) ...
# loss 1.70301, wmdcmp_gt 0.34201, report_loss 1.65288, 147.99 secs
# (2) Validation stage ...
# wmdcmp 0.03726, wmdcmp_gt 0.20215, cD 0.00308, cD_gt 0.87445, 35.69 secs
# ---- Epoch 60/84
# (1) Training stage (lr = 0.000003) ...
# loss 1.70301, wmdcmp_gt 0.34128, report_loss 1.64981, 148.60 secs
# (2) Validation stage ...
# wmdcmp 0.03812, wmdcmp_gt 0.20968, cD 0.00365, cD_gt 0.90706, 30.51 secs
# ---- Epoch 61/84
# (1) Training stage (lr = 0.000400) ...
# loss 1.58692, wmdcmp_gt 0.33044, report_loss 1.69388, 150.55 secs
# (2) Validation stage ...
# wmdcmp 0.04244, wmdcmp_gt 0.21372, cD 0.01046, cD_gt 0.91090, 32.24 secs
# ---- Epoch 62/84
# (1) Training stage (lr = 0.000199) ...
# loss 1.60062, wmdcmp_gt 0.33559, report_loss 1.67587, 149.89 secs
# (2) Validation stage ...
# wmdcmp 0.04081, wmdcmp_gt 0.20849, cD 0.00733, cD_gt 0.88057, 32.19 secs
# ---- Epoch 63/84
# (1) Training stage (lr = 0.000099) ...
# loss 1.62801, wmdcmp_gt 0.34080, report_loss 1.65043, 148.10 secs
# (2) Validation stage ...
# wmdcmp 0.04044, wmdcmp_gt 0.20725, cD 0.00541, cD_gt 0.89344, 31.06 secs
# ---- Epoch 64/84
# (1) Training stage (lr = 0.000049) ...
# loss 1.67371, wmdcmp_gt 0.34460, report_loss 1.63244, 148.30 secs
# (2) Validation stage ...
# wmdcmp 0.03714, wmdcmp_gt 0.21128, cD 0.00591, cD_gt 0.91168, 30.95 secs
# ---- Epoch 65/84
# (1) Training stage (lr = 0.000024) ...
# loss 1.58513, wmdcmp_gt 0.34477, report_loss 1.62690, 147.14 secs
# (2) Validation stage ...
# wmdcmp 0.03495, wmdcmp_gt 0.21151, cD 0.00384, cD_gt 0.90587, 31.45 secs
# ---- Epoch 66/84
# (1) Training stage (lr = 0.000012) ...
# loss 1.56028, wmdcmp_gt 0.34687, report_loss 1.62139, 147.46 secs
# (2) Validation stage ...
# wmdcmp 0.03623, wmdcmp_gt 0.21163, cD 0.00545, cD_gt 0.92611, 32.37 secs
# ---- Epoch 67/84
# (1) Training stage (lr = 0.000006) ...
# loss 1.54390, wmdcmp_gt 0.34807, report_loss 1.61711, 147.83 secs
# (2) Validation stage ...
# wmdcmp 0.03605, wmdcmp_gt 0.21222, cD 0.00453, cD_gt 0.92569, 31.36 secs
# ---- Epoch 68/84
# (1) Training stage (lr = 0.000003) ...
# loss 1.46215, wmdcmp_gt 0.34692, report_loss 1.61538, 145.87 secs
# (2) Validation stage ...
# wmdcmp 0.03579, wmdcmp_gt 0.21110, cD 0.00462, cD_gt 0.91643, 30.76 secs
# ---- Epoch 69/84
# (1) Training stage (lr = 0.000400) ...
# loss 1.57235, wmdcmp_gt 0.33523, report_loss 1.66641, 147.06 secs
# (2) Validation stage ...
# wmdcmp 0.03680, wmdcmp_gt 0.20646, cD 0.00434, cD_gt 0.86910, 31.22 secs
# ---- Epoch 70/84
# (1) Training stage (lr = 0.000199) ...
# loss 1.64271, wmdcmp_gt 0.34144, report_loss 1.64139, 145.35 secs
# (2) Validation stage ...
# wmdcmp 0.03369, wmdcmp_gt 0.21553, cD 0.00172, cD_gt 0.91507, 32.04 secs
# ---- Epoch 71/84
# (1) Training stage (lr = 0.000099) ...
# loss 1.61827, wmdcmp_gt 0.34562, report_loss 1.61912, 148.21 secs
# (2) Validation stage ...
# wmdcmp 0.03597, wmdcmp_gt 0.21244, cD 0.00477, cD_gt 0.93946, 32.39 secs
# ---- Epoch 72/84
# (1) Training stage (lr = 0.000049) ...
# loss 1.56046, wmdcmp_gt 0.34818, report_loss 1.60450, 146.16 secs
# (2) Validation stage ...
# wmdcmp 0.03436, wmdcmp_gt 0.20312, cD 0.00265, cD_gt 0.88815, 32.06 secs
# ---- Epoch 73/84
# (1) Training stage (lr = 0.000024) ...
# loss 1.64410, wmdcmp_gt 0.35032, report_loss 1.59697, 145.56 secs
# (2) Validation stage ...
# wmdcmp 0.03441, wmdcmp_gt 0.21201, cD 0.00336, cD_gt 0.91595, 30.35 secs
# ---- Epoch 74/84
# (1) Training stage (lr = 0.000012) ...
# loss 1.53860, wmdcmp_gt 0.35113, report_loss 1.59410, 144.82 secs
# (2) Validation stage ...
# wmdcmp 0.03468, wmdcmp_gt 0.21078, cD 0.00378, cD_gt 0.89817, 31.82 secs
# ---- Epoch 75/84
# (1) Training stage (lr = 0.000006) ...
# loss 1.61890, wmdcmp_gt 0.35249, report_loss 1.59036, 146.40 secs
# (2) Validation stage ...
# wmdcmp 0.03473, wmdcmp_gt 0.21160, cD 0.00345, cD_gt 0.92038, 31.01 secs
# ---- Epoch 76/84
# (1) Training stage (lr = 0.000003) ...
# loss 1.67356, wmdcmp_gt 0.35192, report_loss 1.58766, 147.14 secs
# (2) Validation stage ...
# wmdcmp 0.03439, wmdcmp_gt 0.21053, cD 0.00306, cD_gt 0.90421, 31.87 secs
# ---- Epoch 77/84
# (1) Training stage (lr = 0.000400) ...
# loss 1.61744, wmdcmp_gt 0.33972, report_loss 1.64060, 142.97 secs
# (2) Validation stage ...
# wmdcmp 0.03902, wmdcmp_gt 0.20651, cD 0.00325, cD_gt 0.86089, 30.26 secs
# ---- Epoch 78/84
# (1) Training stage (lr = 0.000199) ...
# loss 1.58200, wmdcmp_gt 0.34513, report_loss 1.61511, 143.58 secs
# (2) Validation stage ...
# wmdcmp 0.03516, wmdcmp_gt 0.20933, cD 0.00729, cD_gt 0.90849, 30.15 secs
# ---- Epoch 79/84
# (1) Training stage (lr = 0.000099) ...
# loss 1.57628, wmdcmp_gt 0.35026, report_loss 1.59536, 140.96 secs
# (2) Validation stage ...
# wmdcmp 0.04073, wmdcmp_gt 0.20442, cD 0.01113, cD_gt 0.89250, 35.26 secs
# ---- Epoch 80/84
# (1) Training stage (lr = 0.000049) ...
# loss 1.66529, wmdcmp_gt 0.35376, report_loss 1.57938, 148.73 secs
# (2) Validation stage ...
# wmdcmp 0.03937, wmdcmp_gt 0.21310, cD 0.00866, cD_gt 0.92586, 35.22 secs
# ---- Epoch 81/84
# (1) Training stage (lr = 0.000024) ...
# loss 1.67469, wmdcmp_gt 0.35523, report_loss 1.57107, 175.67 secs
# (2) Validation stage ...
# wmdcmp 0.04083, wmdcmp_gt 0.21296, cD 0.00886, cD_gt 0.92976, 42.41 secs
# ---- Epoch 82/84
# (1) Training stage (lr = 0.000012) ...
# loss 1.56396, wmdcmp_gt 0.35570, report_loss 1.56996, 175.19 secs
# (2) Validation stage ...
# wmdcmp 0.03962, wmdcmp_gt 0.20705, cD 0.00774, cD_gt 0.91287, 45.02 secs
# ---- Epoch 83/84
# (1) Training stage (lr = 0.000006) ...
# loss 1.65299, wmdcmp_gt 0.35777, report_loss 1.56068, 174.63 secs
# (2) Validation stage ...
# wmdcmp 0.03978, wmdcmp_gt 0.20489, cD 0.00892, cD_gt 0.89655, 47.62 secs
# ---- Epoch 84/84
# (1) Training stage (lr = 0.000003) ...
# loss 1.58421, wmdcmp_gt 0.35660, report_loss 1.56493, 170.32 secs
# (2) Validation stage ...
# wmdcmp 0.03924, wmdcmp_gt 0.21346, cD 0.00892, cD_gt 0.93288, 44.29 secs
