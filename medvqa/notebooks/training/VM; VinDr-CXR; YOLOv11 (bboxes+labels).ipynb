# %%
# %env CUDA_VISIBLE_DEVICES=1
# Out:
# env: CUDA_VISIBLE_DEVICES=1

# %%
# !python ../train_visual_module.py \
--epochs 150 \
--batches_per_epoch 800 \
--batch_size 14 \
--num_workers 3 \
--gradient_accumulation_steps 10 \
--optimizer_name "adamw" \
--scheduler "exp-warmup+decay+cyclicdecay" \
--lr 1e-6 \
--warmup_decay_and_cyclic_decay_args "1e-6,3,8e-5,6,1e-6,8e-5,6,1e-6" \
--use_vinbig \
--vinbig_training_data_mode "train" \
--vinbig_use_validation \
--predict_bboxes_vinbig \
--classify_labels_vinbig \
--binary_loss_name "focal+bce+wbcbce" \
--raw_image_encoding "yolov11-for-det-mlc" \
--yolov11_model_name_or_path "yolo11l.pt" \
--yolov11_model_alias "yolo11l" \
--image_size 416 416 \
--image_local_feat_size 512 \
--num_regions 169 \
--classification_mlp_hidden_dims 256 128 \
--query_embed_size 128 \
--local_attention_hidden_size 256 \
--img_aug_mode "random-color-and-spatial" \
--use_amp \
--save
# Out:
# script's arguments:
#    epochs: 150
#    batches_per_epoch: 800
#    checkpoint_folder: None
#    visual_input_mode: raw-image
#    raw_image_encoding: yolov11-for-det-mlc
#    image_local_feat_size: 512
#    image_encoder_pretrained_weights_path: None
#    freeze_image_encoder: False
#    imagenet_pretrained: False
#    visual_features_mlp_in_dim: None
#    visual_features_mlp_out_dim: None
#    visual_features_mlp_hidden_dims: None
#    classification_mlp_hidden_dims: [256, 128]
#    iuxray_precomputed_visual_features_path: None
#    mimiccxr_precomputed_visual_features_path: None
#    chexpert_precomputed_visual_features_path: None
#    vinbig_precomputed_visual_features_path: None
#    clip_version: None
#    huggingface_model_name: None
#    chexpert_mlc_version: None
#    chexpert_mlc_hidden_size: 128
#    chest_imagenome_bbox_hidden_size: 128
#    chest_imagenome_bbox_regressor_version: None
#    chest_imagenome_mlc_version: None
#    chest_imagenome_mlc_hidden_size: 128
#    vinbig_mlc_hidden_size: 128
#    torchxrayvision_weights_name: None
#    detectron2_model_yaml: None
#    num_regions: 169
#    roi_heads_batch_size_per_image: 128
#    rpn_batch_size_per_image: 128
#    roi_align_output_size: None
#    yolov8_model_name_or_path: None
#    yolov8_model_alias: None
#    yolov8_use_one_detector_per_dataset: False
#    yolov11_model_name_or_path: yolo11l.pt
#    yolov11_model_alias: yolo11l
#    query_embed_size: 128
#    local_attention_hidden_size: 256
#    optimizer_name: adamw
#    lr: 1e-06
#    scheduler: exp-warmup+decay+cyclicdecay
#    lr_decay: 0.76
#    lr_decay_patience: 2
#    warmup_and_decay_args: None
#    warmup_and_cosine_args: None
#    warmup_decay_and_cyclic_decay_args: 1e-6,3,8e-5,6,1e-6,8e-5,6,1e-6
#    batch_size: 14
#    gradient_accumulation_steps: 10
#    num_workers: 3
#    device: GPU
#    img_aug_mode: random-color-and-spatial
#    image_size: [416, 416]
#    horizontal_flip_prob: 0
#    mimiccxr_weight: 1
#    chexpert_weight: 0.3
#    cxr14_weight: 0.3
#    vinbig_weight: 0.3
#    iuxray_weight: 0.05
#    padchest_weight: 0.4
#    mimiccxr_view_mode: any_single
#    mimiccxr_balanced_sampling_mode: None
#    mimiccxr_balanced_batch_size: None
#    chest_imagenome_labels_filename: None
#    chest_imagenome_label_names_filename: None
#    use_chest_imagenome_decent_images_only: False
#    use_amp: True
#    pretrained_checkpoint_folder_path: None
#    save: True
#    override_lr: False
#    train_mimiccxr: False
#    train_iuxray: False
#    train_chexpert: False
#    train_cxr14: False
#    train_vinbig: True
#    vinbig_training_data_mode: train
#    vinbig_use_validation: True
#    train_padchest: False
#    padchest_training_data_mode: train
#    padchest_use_validation: False
#    padchest_train_study_ids_path: None
#    padchest_val_study_ids_path: None
#    padchest_test_study_ids_path: None
#    binary_loss_name: focal+bce+wbcbce
#    focal_loss_weight: 1
#    bce_loss_weight: 1
#    wbce_loss_weight: 1
#    classify_tags: False
#    n_medical_tags: None
#    iuxray_medical_tags_per_report_filename: None
#    mimiccxr_medical_tags_per_report_filename: None
#    classify_orientation: False
#    classify_gender: False
#    classify_chexpert: False
#    iuxray_chexpert_labels_filename: None
#    mimiccxr_chexpert_labels_filename: None
#    classify_chest_imagenome: False
#    predict_bboxes_chest_imagenome: False
#    predict_labels_and_bboxes_chest_imagenome: False
#    clamp_bboxes_chest_imagenome: False
#    use_anaxnet_bbox_subset: False
#    chest_imagenome_bbox_loss_weight: 1.0
#    pass_pred_bbox_coords_as_input: False
#    use_gt_bboxes_as_predictions: False
#    predict_bboxes_vinbig: True
#    classify_labels_vinbig: True
#    classify_questions: False
#    n_mined_questions: None
#    iuxray_question_labels_filename: None
#    mimiccxr_question_labels_filename: None
#    merge_findings: False
# ----- Training model from scratch ------
# vinbig_class_id_offset: 0
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Creating instance of MultiPurposeVisualModule ...
# MultiPurposeVisualModule()
#   Initializing raw_image_encoder: yolov11-for-det-mlc
# Overriding model.yaml nc=80 with nc=22
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  2    173824  ultralytics.nn.modules.block.C3k2            [128, 256, 2, True, 0.25]
#   3                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   4                  -1  2    691712  ultralytics.nn.modules.block.C3k2            [256, 512, 2, True, 0.25]
#   5                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   6                  -1  2   2234368  ultralytics.nn.modules.block.C3k2            [512, 512, 2, True]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  2   2234368  ultralytics.nn.modules.block.C3k2            [512, 512, 2, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  2   1455616  ultralytics.nn.modules.block.C2PSA           [512, 512, 2]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  2   2496512  ultralytics.nn.modules.block.C3k2            [1024, 512, 2, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  2    756736  ultralytics.nn.modules.block.C3k2            [1024, 256, 2, True]
#  17                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  2   2365440  ultralytics.nn.modules.block.C3k2            [768, 512, 2, True]
#  20                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  2   2496512  ultralytics.nn.modules.block.C3k2            [1024, 512, 2, True]
#  23        [16, 19, 22]  1   1427986  ultralytics.nn.modules.head.Detect           [22, [256, 512, 512]]
# YOLO11l summary: 631 layers, 25,327,442 parameters, 25,327,426 gradients, 87.4 GFLOPs
#
# Transferred 1009/1015 items from pretrained weights
# feature_dims: [256, 512, 512]
#   Initializing auxiliary tasks
#     Skipping auxiliary tasks initialization for YOLOV11_FOR_DET_MLC
# --------------------------------------------------
# 3) Defining optimizer ...
# create_optimizer(): name = adamw
# --------------------------------------------------
# 4) Defining scheduler ...
# Using exp-warmup+decay+cyclicdecay scheduler: 1e-6,3,8e-5,6,1e-6,8e-5,6,1e-6
# 1e-06 3 8e-05 6 1e-06 8e-05 6 1e-06
# self.steps_to_restart = 6
# self.steps = -1
# self.initial_lr = 8e-05
# --------------------------------------------------
# 5) Creating trainer and validator engines ...
# get_engine(): shift_answer=False
# Focal_BCE_WBCBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 wbcbce_weight = 0.3333333333333333
# GradientAccumulator.__init__(): num_accumulation_steps = 1, max_grad_norm = None
# get_engine(): shift_answer=False
# --------------------------------------------------
# 6) Defining collate_batch_fn ...
# --------------------------------------------------
# 7) Creating VinBig visual module trainer ...
# get_image_transform()
#   image_size = [416, 416]
#   mean = [0.0, 0.0, 0.0]
#   std = [1.0, 1.0, 1.0]
#   Using bounding box aware transforms
#     for_vinbig: returning vinbig transform
#     augmentation_mode = random-color-and-spatial
#     default_prob = 0.35
# get_train_transform(): Using bbox-aware transforms for VinBigData
#     Returning augmented transform with mode random-color-and-spatial
# get_image_transform()
#   image_size = [416, 416]
#   mean = [0.0, 0.0, 0.0]
#   std = [1.0, 1.0, 1.0]
#   Using bounding box aware transforms
#     Returning default transform (no augmentation)
# Loading bounding boxes
# Anomalous bboxes found: 29 of 37367
# class_id_offset: 0
# Anomalous bboxes found: 0 of 2697
# class_id_offset: 0
#   Loaded 18000 bounding boxes
# Generating train dataset and dataloader
# No finding        , #pos=10601, #neg=4399
# Other disease     , #pos=4288, #neg=10712
# Aortic enlargement, #pos=3067, #neg=11933
# Cardiomegaly      , #pos=2300, #neg=12700
# Pleural thickening, #pos=1981, #neg=13019
# Pulmonary fibrosis, #pos=1617, #neg=13383
# Lung Opacity      , #pos=1322, #neg=13678
# Other lesion      , #pos=1134, #neg=13866
# Pleural effusion  , #pos=1032, #neg=13968
# Pneumonia         , #pos=917, #neg=14083
# Nodule/Mass       , #pos=830, #neg=14170
# Tuberculosis      , #pos=750, #neg=14250
# Infiltration      , #pos=613, #neg=14387
# Calcification     , #pos=452, #neg=14548
# ILD               , #pos=386, #neg=14614
# Consolidation     , #pos=353, #neg=14647
# Lung tumor        , #pos=291, #neg=14709
# Atelectasis       , #pos=186, #neg=14814
# Mediastinal shift , #pos=150, #neg=14850
# Enlarged PA       , #pos=131, #neg=14869
# Pneumothorax      , #pos=96, #neg=14904
# Rib fracture      , #pos=90, #neg=14910
# Emphysema         , #pos=78, #neg=14922
# Lung cavity       , #pos=50, #neg=14950
# COPD              , #pos=35, #neg=14965
# Lung cyst         , #pos=32, #neg=14968
# Clavicle fracture , #pos=27, #neg=14973
# Edema             , #pos=13, #neg=14987
# len(train_indices) = 15000
# len(self.test_indices) = 3000
# --------------------------------------------------
# 8) Creating dataloaders ...
# len(_train_dataloaders) = 1
# len(_val_dataloaders) = 1
# _train_weights = [0.3]
# merged_dataset_name = vinbig
# --------------------------------------------------
# 9) Attaching metrics, losses, timer and events to engines ...
# --------------------------------------------------
# 10) Defining learning rate scheduler handler ...
# --------------------------------------------------
# 11) Defining checkpoint folder path ...
# checkpoint_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20241121_193806_vinbig_yolo11l(c:vinbig;d:vinbig)
# metadata saved to /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20241121_193806_vinbig_yolo11l(c:vinbig;d:vinbig)/metadata.json
# --------------------------------------------------
# 12) Defining log_metrics_handler ...
# MetricsLogger :: we'll be logging to /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20241121_193806_vinbig_yolo11l(c:vinbig;d:vinbig)/metrics_logs.csv
# --------------------------------------------------
# 13) Running trainer engine ...
# ---- Epoch 1/150
# (1) Training stage (lr = 0.000001) ...
# loss 12.72287, vnb_y11_loss 10.98923, vnb_y11_box_loss 3.01519, vnb_y11_cls_loss 5.09227, vnb_y11_dfl_loss 2.88177, vnb_macro_prcauc 0.14300, vnb_label_loss 1.73364, 177.30 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.00000, vnb_macro_prcauc 0.08216, 48.00 secs
# New checkpoint saved: checkpoint_1_vnb_macro_prcauc+vnb_y11_bbox_iou=0.0513.pt
# ---- Epoch 2/150
# (1) Training stage (lr = 0.000004) ...
# loss 11.19050, vnb_y11_loss 9.80548, vnb_y11_box_loss 2.81466, vnb_y11_cls_loss 4.36820, vnb_y11_dfl_loss 2.62262, vnb_macro_prcauc 0.14452, vnb_label_loss 1.38502, 179.43 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.00491, vnb_macro_prcauc 0.09664, 47.72 secs
# New checkpoint saved: checkpoint_2_vnb_macro_prcauc+vnb_y11_bbox_iou=0.0602.pt
# ---- Epoch 3/150
# (1) Training stage (lr = 0.000019) ...
# loss 10.14725, vnb_y11_loss 8.82203, vnb_y11_box_loss 2.61372, vnb_y11_cls_loss 3.81768, vnb_y11_dfl_loss 2.39063, vnb_macro_prcauc 0.15834, vnb_label_loss 1.32522, 177.92 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.01080, vnb_macro_prcauc 0.11408, 47.83 secs
# New checkpoint saved: checkpoint_3_vnb_macro_prcauc+vnb_y11_bbox_iou=0.0720.pt
# ---- Epoch 4/150
# (1) Training stage (lr = 0.000080) ...
# loss 9.56478, vnb_y11_loss 8.24971, vnb_y11_box_loss 2.48889, vnb_y11_cls_loss 3.48386, vnb_y11_dfl_loss 2.27696, vnb_macro_prcauc 0.16995, vnb_label_loss 1.31508, 180.26 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.01760, vnb_macro_prcauc 0.12479, 47.60 secs
# New checkpoint saved: checkpoint_4_vnb_macro_prcauc+vnb_y11_bbox_iou=0.0811.pt
# ---- Epoch 5/150
# (1) Training stage (lr = 0.000039) ...
# loss 9.12939, vnb_y11_loss 7.82808, vnb_y11_box_loss 2.39120, vnb_y11_cls_loss 3.23938, vnb_y11_dfl_loss 2.19749, vnb_macro_prcauc 0.18461, vnb_label_loss 1.30132, 178.82 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.02321, vnb_macro_prcauc 0.12682, 48.01 secs
# New checkpoint saved: checkpoint_5_vnb_macro_prcauc+vnb_y11_bbox_iou=0.0860.pt
# ---- Epoch 6/150
# (1) Training stage (lr = 0.000019) ...
# loss 8.96075, vnb_y11_loss 7.66852, vnb_y11_box_loss 2.34673, vnb_y11_cls_loss 3.16163, vnb_y11_dfl_loss 2.16016, vnb_macro_prcauc 0.19331, vnb_label_loss 1.29223, 179.58 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.02708, vnb_macro_prcauc 0.12727, 47.81 secs
# New checkpoint saved: checkpoint_6_vnb_macro_prcauc+vnb_y11_bbox_iou=0.0888.pt
# ---- Epoch 7/150
# (1) Training stage (lr = 0.000009) ...
# loss 8.84798, vnb_y11_loss 7.55634, vnb_y11_box_loss 2.32444, vnb_y11_cls_loss 3.09369, vnb_y11_dfl_loss 2.13820, vnb_macro_prcauc 0.20051, vnb_label_loss 1.29164, 167.98 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.02714, vnb_macro_prcauc 0.12745, 47.76 secs
# New checkpoint saved: checkpoint_7_vnb_macro_prcauc+vnb_y11_bbox_iou=0.0896.pt
# ---- Epoch 8/150
# (1) Training stage (lr = 0.000004) ...
# loss 8.81454, vnb_y11_loss 7.52642, vnb_y11_box_loss 2.31890, vnb_y11_cls_loss 3.07569, vnb_y11_dfl_loss 2.13183, vnb_macro_prcauc 0.20286, vnb_label_loss 1.28811, 178.72 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.02523, vnb_macro_prcauc 0.12694, 47.67 secs
# ---- Epoch 9/150
# (1) Training stage (lr = 0.000002) ...
# loss 8.77392, vnb_y11_loss 7.49182, vnb_y11_box_loss 2.30920, vnb_y11_cls_loss 3.05539, vnb_y11_dfl_loss 2.12722, vnb_macro_prcauc 0.20499, vnb_label_loss 1.28210, 179.46 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.02645, vnb_macro_prcauc 0.12697, 47.41 secs
# ---- Epoch 10/150
# (1) Training stage (lr = 0.000001) ...
# loss 8.81237, vnb_y11_loss 7.51950, vnb_y11_box_loss 2.31373, vnb_y11_cls_loss 3.07640, vnb_y11_dfl_loss 2.12937, vnb_macro_prcauc 0.20638, vnb_label_loss 1.29287, 179.97 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.02715, vnb_macro_prcauc 0.13140, 47.73 secs
# New checkpoint saved: checkpoint_10_vnb_macro_prcauc+vnb_y11_bbox_iou=0.0920.pt
# ---- Epoch 11/150
# (1) Training stage (lr = 0.000080) ...
# loss 8.88896, vnb_y11_loss 7.61391, vnb_y11_box_loss 2.34943, vnb_y11_cls_loss 3.10998, vnb_y11_dfl_loss 2.15451, vnb_macro_prcauc 0.20039, vnb_label_loss 1.27505, 180.12 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.01889, vnb_macro_prcauc 0.13074, 47.97 secs
# ---- Epoch 12/150
# (1) Training stage (lr = 0.000033) ...
# loss 8.69992, vnb_y11_loss 7.42266, vnb_y11_box_loss 2.29091, vnb_y11_cls_loss 3.01393, vnb_y11_dfl_loss 2.11781, vnb_macro_prcauc 0.21350, vnb_label_loss 1.27726, 177.01 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.02681, vnb_macro_prcauc 0.13346, 47.99 secs
# New checkpoint saved: checkpoint_12_vnb_macro_prcauc+vnb_y11_bbox_iou=0.0935.pt
# ---- Epoch 13/150
# (1) Training stage (lr = 0.000014) ...
# loss 8.61251, vnb_y11_loss 7.35297, vnb_y11_box_loss 2.27622, vnb_y11_cls_loss 2.97652, vnb_y11_dfl_loss 2.10022, vnb_macro_prcauc 0.21737, vnb_label_loss 1.25954, 181.68 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.03111, vnb_macro_prcauc 0.13218, 47.46 secs
# New checkpoint saved: checkpoint_13_vnb_macro_prcauc+vnb_y11_bbox_iou=0.0952.pt
# ---- Epoch 14/150
# (1) Training stage (lr = 0.000006) ...
# loss 8.55322, vnb_y11_loss 7.29192, vnb_y11_box_loss 2.26167, vnb_y11_cls_loss 2.94033, vnb_y11_dfl_loss 2.08991, vnb_macro_prcauc 0.22434, vnb_label_loss 1.26130, 164.60 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.03123, vnb_macro_prcauc 0.13224, 47.96 secs
# New checkpoint saved: checkpoint_14_vnb_macro_prcauc+vnb_y11_bbox_iou=0.0960.pt
# ---- Epoch 15/150
# (1) Training stage (lr = 0.000002) ...
# loss 8.53097, vnb_y11_loss 7.27378, vnb_y11_box_loss 2.25265, vnb_y11_cls_loss 2.93948, vnb_y11_dfl_loss 2.08164, vnb_macro_prcauc 0.22221, vnb_label_loss 1.25719, 175.38 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.03179, vnb_macro_prcauc 0.13334, 48.03 secs
# New checkpoint saved: checkpoint_15_vnb_macro_prcauc+vnb_y11_bbox_iou=0.0965.pt
# ---- Epoch 16/150
# (1) Training stage (lr = 0.000001) ...
# loss 8.50767, vnb_y11_loss 7.24619, vnb_y11_box_loss 2.24954, vnb_y11_cls_loss 2.91669, vnb_y11_dfl_loss 2.07996, vnb_macro_prcauc 0.22393, vnb_label_loss 1.26148, 165.94 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.03321, vnb_macro_prcauc 0.13383, 47.64 secs
# New checkpoint saved: checkpoint_16_vnb_macro_prcauc+vnb_y11_bbox_iou=0.0976.pt
# ---- Epoch 17/150
# (1) Training stage (lr = 0.000080) ...
# loss 8.71919, vnb_y11_loss 7.44615, vnb_y11_box_loss 2.30334, vnb_y11_cls_loss 3.02323, vnb_y11_dfl_loss 2.11958, vnb_macro_prcauc 0.21621, vnb_label_loss 1.27305, 181.26 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.02303, vnb_macro_prcauc 0.13484, 47.31 secs
# ---- Epoch 18/150
# (1) Training stage (lr = 0.000033) ...
# loss 8.56692, vnb_y11_loss 7.31291, vnb_y11_box_loss 2.27012, vnb_y11_cls_loss 2.94719, vnb_y11_dfl_loss 2.09559, vnb_macro_prcauc 0.22644, vnb_label_loss 1.25402, 177.44 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.03951, vnb_macro_prcauc 0.13541, 47.47 secs
# New checkpoint saved: checkpoint_18_vnb_macro_prcauc+vnb_y11_bbox_iou=0.1014.pt
# ---- Epoch 19/150
# (1) Training stage (lr = 0.000014) ...
# loss 8.43267, vnb_y11_loss 7.19357, vnb_y11_box_loss 2.24013, vnb_y11_cls_loss 2.87963, vnb_y11_dfl_loss 2.07382, vnb_macro_prcauc 0.23542, vnb_label_loss 1.23910, 176.71 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.03288, vnb_macro_prcauc 0.13653, 47.41 secs
# ---- Epoch 20/150
# (1) Training stage (lr = 0.000006) ...
# loss 8.41347, vnb_y11_loss 7.17711, vnb_y11_box_loss 2.23544, vnb_y11_cls_loss 2.87870, vnb_y11_dfl_loss 2.06296, vnb_macro_prcauc 0.23360, vnb_label_loss 1.23636, 177.54 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.03562, vnb_macro_prcauc 0.13574, 47.56 secs
# ---- Epoch 21/150
# (1) Training stage (lr = 0.000002) ...
# loss 8.37169, vnb_y11_loss 7.13018, vnb_y11_box_loss 2.22418, vnb_y11_cls_loss 2.84806, vnb_y11_dfl_loss 2.05794, vnb_macro_prcauc 0.23498, vnb_label_loss 1.24150, 178.26 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.03504, vnb_macro_prcauc 0.13524, 47.75 secs
# ---- Epoch 22/150
# (1) Training stage (lr = 0.000001) ...
# loss 8.37886, vnb_y11_loss 7.13919, vnb_y11_box_loss 2.22851, vnb_y11_cls_loss 2.85366, vnb_y11_dfl_loss 2.05702, vnb_macro_prcauc 0.23722, vnb_label_loss 1.23967, 176.63 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.04035, vnb_macro_prcauc 0.13438, 47.72 secs
# New checkpoint saved: checkpoint_22_vnb_macro_prcauc+vnb_y11_bbox_iou=0.1023.pt
# ---- Epoch 23/150
# (1) Training stage (lr = 0.000080) ...
# loss 8.53244, vnb_y11_loss 7.28510, vnb_y11_box_loss 2.26202, vnb_y11_cls_loss 2.94119, vnb_y11_dfl_loss 2.08189, vnb_macro_prcauc 0.22715, vnb_label_loss 1.24735, 179.05 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.03417, vnb_macro_prcauc 0.13786, 47.80 secs
# ---- Epoch 24/150
# (1) Training stage (lr = 0.000033) ...
# loss 8.41362, vnb_y11_loss 7.17535, vnb_y11_box_loss 2.23656, vnb_y11_cls_loss 2.86811, vnb_y11_dfl_loss 2.07068, vnb_macro_prcauc 0.23907, vnb_label_loss 1.23827, 179.51 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.03856, vnb_macro_prcauc 0.13684, 47.92 secs
# New checkpoint saved: checkpoint_24_vnb_macro_prcauc+vnb_y11_bbox_iou=0.1028.pt
# ---- Epoch 25/150
# (1) Training stage (lr = 0.000014) ...
# loss 8.33967, vnb_y11_loss 7.10885, vnb_y11_box_loss 2.21933, vnb_y11_cls_loss 2.83660, vnb_y11_dfl_loss 2.05293, vnb_macro_prcauc 0.24261, vnb_label_loss 1.23081, 179.42 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.04176, vnb_macro_prcauc 0.13704, 47.89 secs
# New checkpoint saved: checkpoint_25_vnb_macro_prcauc+vnb_y11_bbox_iou=0.1047.pt
# ---- Epoch 26/150
# (1) Training stage (lr = 0.000006) ...
# loss 8.29507, vnb_y11_loss 7.07474, vnb_y11_box_loss 2.21421, vnb_y11_cls_loss 2.80791, vnb_y11_dfl_loss 2.05262, vnb_macro_prcauc 0.24488, vnb_label_loss 1.22033, 179.72 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.04260, vnb_macro_prcauc 0.13615, 47.77 secs
# New checkpoint saved: checkpoint_26_vnb_macro_prcauc+vnb_y11_bbox_iou=0.1049.pt
# ---- Epoch 27/150
# (1) Training stage (lr = 0.000002) ...
# loss 8.30270, vnb_y11_loss 7.08311, vnb_y11_box_loss 2.20602, vnb_y11_cls_loss 2.83739, vnb_y11_dfl_loss 2.03970, vnb_macro_prcauc 0.24661, vnb_label_loss 1.21959, 178.99 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.04484, vnb_macro_prcauc 0.13788, 48.13 secs
# New checkpoint saved: checkpoint_27_vnb_macro_prcauc+vnb_y11_bbox_iou=0.1069.pt
# ---- Epoch 28/150
# (1) Training stage (lr = 0.000001) ...
# loss 8.28632, vnb_y11_loss 7.05505, vnb_y11_box_loss 2.20555, vnb_y11_cls_loss 2.80499, vnb_y11_dfl_loss 2.04451, vnb_macro_prcauc 0.24687, vnb_label_loss 1.23127, 179.47 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.05101, vnb_macro_prcauc 0.13533, 47.86 secs
# New checkpoint saved: checkpoint_28_vnb_macro_prcauc+vnb_y11_bbox_iou=0.1085.pt
# ---- Epoch 29/150
# (1) Training stage (lr = 0.000080) ...
# loss 8.43107, vnb_y11_loss 7.19891, vnb_y11_box_loss 2.24983, vnb_y11_cls_loss 2.87800, vnb_y11_dfl_loss 2.07108, vnb_macro_prcauc 0.23824, vnb_label_loss 1.23216, 180.85 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.03776, vnb_macro_prcauc 0.13748, 48.16 secs
# ---- Epoch 30/150
# (1) Training stage (lr = 0.000033) ...
# loss 8.28675, vnb_y11_loss 7.06018, vnb_y11_box_loss 2.20846, vnb_y11_cls_loss 2.80731, vnb_y11_dfl_loss 2.04440, vnb_macro_prcauc 0.24457, vnb_label_loss 1.22657, 182.69 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.04356, vnb_macro_prcauc 0.14056, 48.02 secs
# ---- Epoch 31/150
# (1) Training stage (lr = 0.000014) ...
# loss 8.27068, vnb_y11_loss 7.05190, vnb_y11_box_loss 2.20977, vnb_y11_cls_loss 2.79544, vnb_y11_dfl_loss 2.04668, vnb_macro_prcauc 0.24982, vnb_label_loss 1.21878, 182.61 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.04328, vnb_macro_prcauc 0.13862, 47.92 secs
# ---- Epoch 32/150
# (1) Training stage (lr = 0.000006) ...
# loss 8.21263, vnb_y11_loss 6.99039, vnb_y11_box_loss 2.19524, vnb_y11_cls_loss 2.76151, vnb_y11_dfl_loss 2.03363, vnb_macro_prcauc 0.25373, vnb_label_loss 1.22224, 182.55 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.04602, vnb_macro_prcauc 0.14140, 48.17 secs
# New checkpoint saved: checkpoint_32_vnb_macro_prcauc+vnb_y11_bbox_iou=0.1097.pt
# ---- Epoch 33/150
# (1) Training stage (lr = 0.000002) ...
# loss 8.18240, vnb_y11_loss 6.97273, vnb_y11_box_loss 2.18683, vnb_y11_cls_loss 2.75852, vnb_y11_dfl_loss 2.02738, vnb_macro_prcauc 0.25454, vnb_label_loss 1.20967, 181.21 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.03934, vnb_macro_prcauc 0.13955, 48.09 secs
# ---- Epoch 34/150
# (1) Training stage (lr = 0.000001) ...
# loss 8.19730, vnb_y11_loss 6.98968, vnb_y11_box_loss 2.18868, vnb_y11_cls_loss 2.76795, vnb_y11_dfl_loss 2.03304, vnb_macro_prcauc 0.25915, vnb_label_loss 1.20763, 180.54 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.04157, vnb_macro_prcauc 0.13835, 48.18 secs
# ---- Epoch 35/150
# (1) Training stage (lr = 0.000080) ...
# loss 8.31611, vnb_y11_loss 7.09569, vnb_y11_box_loss 2.21636, vnb_y11_cls_loss 2.82210, vnb_y11_dfl_loss 2.05723, vnb_macro_prcauc 0.24564, vnb_label_loss 1.22042, 180.61 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.03528, vnb_macro_prcauc 0.13929, 47.96 secs
# ---- Epoch 36/150
# (1) Training stage (lr = 0.000033) ...
# loss 8.24127, vnb_y11_loss 7.02356, vnb_y11_box_loss 2.20492, vnb_y11_cls_loss 2.78041, vnb_y11_dfl_loss 2.03823, vnb_macro_prcauc 0.24943, vnb_label_loss 1.21771, 181.46 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.03908, vnb_macro_prcauc 0.14178, 48.30 secs
# ---- Epoch 37/150
# (1) Training stage (lr = 0.000014) ...
# loss 8.16552, vnb_y11_loss 6.96387, vnb_y11_box_loss 2.18616, vnb_y11_cls_loss 2.74929, vnb_y11_dfl_loss 2.02842, vnb_macro_prcauc 0.25834, vnb_label_loss 1.20166, 181.66 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.03794, vnb_macro_prcauc 0.14140, 47.93 secs
# ---- Epoch 38/150
# (1) Training stage (lr = 0.000006) ...
# loss 8.11970, vnb_y11_loss 6.92390, vnb_y11_box_loss 2.17742, vnb_y11_cls_loss 2.72336, vnb_y11_dfl_loss 2.02312, vnb_macro_prcauc 0.26169, vnb_label_loss 1.19581, 181.38 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.04704, vnb_macro_prcauc 0.14101, 47.77 secs
# New checkpoint saved: checkpoint_38_vnb_macro_prcauc+vnb_y11_bbox_iou=0.1108.pt
# ---- Epoch 39/150
# (1) Training stage (lr = 0.000002) ...
# loss 8.12924, vnb_y11_loss 6.92786, vnb_y11_box_loss 2.17673, vnb_y11_cls_loss 2.72405, vnb_y11_dfl_loss 2.02708, vnb_macro_prcauc 0.26108, vnb_label_loss 1.20138, 181.06 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.04184, vnb_macro_prcauc 0.14114, 48.03 secs
# ---- Epoch 40/150
# (1) Training stage (lr = 0.000001) ...
# loss 8.13667, vnb_y11_loss 6.93359, vnb_y11_box_loss 2.17501, vnb_y11_cls_loss 2.73531, vnb_y11_dfl_loss 2.02327, vnb_macro_prcauc 0.26225, vnb_label_loss 1.20309, 180.55 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.03994, vnb_macro_prcauc 0.14011, 48.06 secs
# ---- Epoch 41/150
# (1) Training stage (lr = 0.000080) ...
# loss 8.25608, vnb_y11_loss 7.04682, vnb_y11_box_loss 2.20650, vnb_y11_cls_loss 2.79586, vnb_y11_dfl_loss 2.04447, vnb_macro_prcauc 0.24765, vnb_label_loss 1.20926, 179.73 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.04105, vnb_macro_prcauc 0.14565, 47.85 secs
# ---- Epoch 42/150
# (1) Training stage (lr = 0.000033) ...
# loss 8.16683, vnb_y11_loss 6.96829, vnb_y11_box_loss 2.18991, vnb_y11_cls_loss 2.74505, vnb_y11_dfl_loss 2.03333, vnb_macro_prcauc 0.26203, vnb_label_loss 1.19853, 177.98 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.05544, vnb_macro_prcauc 0.14285, 47.57 secs
# New checkpoint saved: checkpoint_42_vnb_macro_prcauc+vnb_y11_bbox_iou=0.1154.pt
# ---- Epoch 43/150
# (1) Training stage (lr = 0.000014) ...
# loss 8.09972, vnb_y11_loss 6.90383, vnb_y11_box_loss 2.17081, vnb_y11_cls_loss 2.71143, vnb_y11_dfl_loss 2.02159, vnb_macro_prcauc 0.26386, vnb_label_loss 1.19589, 178.46 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.05393, vnb_macro_prcauc 0.14192, 47.63 secs
# ---- Epoch 44/150
# (1) Training stage (lr = 0.000006) ...
# loss 8.08998, vnb_y11_loss 6.89793, vnb_y11_box_loss 2.17279, vnb_y11_cls_loss 2.70390, vnb_y11_dfl_loss 2.02124, vnb_macro_prcauc 0.26557, vnb_label_loss 1.19205, 179.44 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.05774, vnb_macro_prcauc 0.14630, 47.44 secs
# New checkpoint saved: checkpoint_44_vnb_macro_prcauc+vnb_y11_bbox_iou=0.1184.pt
# ---- Epoch 45/150
# (1) Training stage (lr = 0.000002) ...
# loss 8.05148, vnb_y11_loss 6.86861, vnb_y11_box_loss 2.16986, vnb_y11_cls_loss 2.68632, vnb_y11_dfl_loss 2.01242, vnb_macro_prcauc 0.26796, vnb_label_loss 1.18287, 178.65 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.05118, vnb_macro_prcauc 0.14233, 47.51 secs
# ---- Epoch 46/150
# (1) Training stage (lr = 0.000001) ...
# loss 8.02194, vnb_y11_loss 6.82694, vnb_y11_box_loss 2.15298, vnb_y11_cls_loss 2.67350, vnb_y11_dfl_loss 2.00047, vnb_macro_prcauc 0.27359, vnb_label_loss 1.19500, 179.63 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.05438, vnb_macro_prcauc 0.14525, 47.32 secs
# ---- Epoch 47/150
# (1) Training stage (lr = 0.000080) ...
# ^C
# Engine run is terminating due to exception:
# Traceback (most recent call last):
#   File "/home/pamessina/medvqa/medvqa/notebooks/../train_visual_module.py", line 1529, in <module>
#     train_from_scratch(**args)
#   File "/home/pamessina/medvqa/medvqa/notebooks/../train_visual_module.py", line 1403, in train_from_scratch
#     return train_model(
#   File "/home/pamessina/medvqa/medvqa/notebooks/../train_visual_module.py", line 845, in train_model
#     trainer_engine.run(train_dataloader, max_epochs = epochs, epoch_length = batches_per_epoch)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 892, in run
#     return self._internal_run()
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 935, in _internal_run
#     return next(self._internal_run_generator)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 993, in _internal_run_as_gen
#     self._handle_exception(e)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 638, in _handle_exception
#     raise e
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 959, in _internal_run_as_gen
#     epoch_time_taken += yield from self._run_once_on_dataset_as_gen()
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 1068, in _run_once_on_dataset_as_gen
#     self.state.output = self._process_function(self, self.state.batch)
#   File "/home/pamessina/medvqa/medvqa/training/vqa.py", line 928, in step_fn
#     output = flag_to_step_fn[flag](batch)
#   File "/home/pamessina/medvqa/medvqa/training/vqa.py", line 731, in step_fn__vinbig
#     gradient_accumulator.step(batch_loss, model)
#   File "/home/pamessina/medvqa/medvqa/losses/optimizers.py", line 29, in step
#     self.scaler.scale(batch_loss).backward()
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/_tensor.py", line 525, in backward
#     torch.autograd.backward(
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/autograd/__init__.py", line 267, in backward
#     _engine_run_backward(
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/autograd/graph.py", line 744, in _engine_run_backward
#     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# KeyboardInterrupt
