# %%
# %env CUDA_VISIBLE_DEVICES=1
# Out:
# env: CUDA_VISIBLE_DEVICES=1

# %%
# !python ../train_phrase_grounding.py \
--pretrained_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20241021_151424_vinbig_PhraseGrounder(dn121,FiLM_SigmoidAttention_ObjectDetection,128,256,256,256-128)" \
--epochs 200 \
--batches_per_epoch 800 \
--max_images_per_batch 20 \
--max_phrases_per_batch 400 \
--max_phrases_per_image 45 \
--val_batch_size_factor 2.0 \
--raw_image_encoding "densenet-121" \
--image_size 416 416 \
--image_local_feat_size 1024 \
--num_regions 169 \
--regions_width 13 \
--regions_height 13 \
--img_aug_mode "random-color-and-spatial" \
--phrase_embedding_size 128 \
--phrase_grounding_mode "film_layers_sigmoid_attention_custom_classifier_object_detection" \
--visual_feature_proj_size 256 \
--visual_grounding_hidden_size 256 \
--phrase_mlp_hidden_dims 256 128 \
--num_train_workers 2 \
--num_val_workers 2 \
--gradient_accumulation_steps 10 \
--optimizer_name "adamw" \
--scheduler "exp-warmup+decay+cyclicdecay" \
--lr 1e-6 \
--warmup_decay_and_cyclic_decay_args "1e-6,3,8e-5,5,1e-6,8e-5,5,1e-6" \
--do_visual_grounding_with_bbox_regression \
--binary_multilabel_classif_loss_name "focal+bce+npbbce" \
--use_vinbig_for_train \
--use_vinbig_for_test \
--vinbig_phrase_embeddings_filepath \
"/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/vinbig/label_phrase_embeddings(hash=514,3911788164261367088).pkl" \
--use_chest_imagenome_for_train \
--use_chest_imagenome_gold_for_test \
--chest_imagenome_bbox_phrase_embeddings_filepath \
"/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/chest_imagenome/bbox_phrase_embeddings(hash=522,1261303459192373044).pkl" \
--use_mimiccxr_facts_for_train \
--use_mimiccxr_facts_for_test \
--dicom_id_to_pos_neg_facts_filepath \
"/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/mimiccxr_dicom_id_to_fact_based_pos_neg_facts(hash=1360,3939902508813076616).pkl" \
--mimiccxr_exclude_noisy_images \
--use_cxrlt2024_custom_labels \
--cxrlt2024_custom_dicom_id_to_pos_neg_facts_filepath \
"/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/mimiccxr/cxrlt2024_integrated_nli_queries_for_fact_classification.pkl" \
--save
# Out:
# script's arguments:
#    epochs: 200
#    batches_per_epoch: 800
#    max_images_per_batch: 20
#    max_phrases_per_batch: 400
#    max_phrases_per_image: 45
#    val_batch_size_factor: 2.0
#    checkpoint_folder: None
#    pretrained_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20241021_151424_vinbig_PhraseGrounder(dn121,FiLM_SigmoidAttention_ObjectDetection,128,256,256,256-128)
#    pretrained_checkpoint_folder_paths: None
#    freeze_image_encoder: False
#    raw_image_encoding: densenet-121
#    huggingface_model_name: None
#    num_regions: 169
#    image_local_feat_size: 1024
#    image_encoder_pretrained_weights_path: None
#    image_encoder_dropout_p: 0
#    yolov8_model_name_or_path: None
#    yolov8_model_alias: None
#    phrase_embedding_size: 128
#    regions_width: 13
#    regions_height: 13
#    qkv_size: None
#    phrase_grounding_mode: film_layers_sigmoid_attention_custom_classifier_object_detection
# ...

# %%
# !python ../train_phrase_grounding.py \
--pretrained_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20241022_161835_mim-facts+chst-img-anat+cxrlt2024(GPT4)+vinbig_PhraseGrounder(dn121,FiLM_SigmoidAttention_ObjectDetection,128,256,256,256-128)" \
--epochs 150 \
--batches_per_epoch 1000 \
--max_images_per_batch 18 \
--max_phrases_per_batch 400 \
--max_phrases_per_image 45 \
--val_batch_size_factor 2.5 \
--raw_image_encoding "densenet-121" \
--image_size 416 416 \
--image_local_feat_size 1024 \
--num_regions 169 \
--regions_width 13 \
--regions_height 13 \
--img_aug_mode "random-color-and-spatial" \
--phrase_embedding_size 128 \
--phrase_grounding_mode "film_layers_sigmoid_attention_custom_classifier_object_detection" \
--visual_feature_proj_size 256 \
--visual_grounding_hidden_size 256 \
--phrase_mlp_hidden_dims 256 128 \
--num_train_workers 2 \
--num_val_workers 2 \
--gradient_accumulation_steps 10 \
--optimizer_name "adamw" \
--scheduler "exp-warmup+decay+cyclicdecay" \
--lr 1e-6 \
--warmup_decay_and_cyclic_decay_args "1e-6,3,8e-5,5,1e-6,8e-5,5,1e-6" \
--do_visual_grounding_with_bbox_regression \
--binary_multilabel_classif_loss_name "focal+bce+npbbce" \
--use_vinbig_for_train \
--use_vinbig_for_test \
--vinbig_phrase_embeddings_filepath \
"/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/vinbig/label_phrase_embeddings(hash=514,3911788164261367088).pkl" \
--use_chest_imagenome_for_train \
--use_chest_imagenome_gold_for_test \
--chest_imagenome_bbox_phrase_embeddings_filepath \
"/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/chest_imagenome/bbox_phrase_embeddings(hash=522,1261303459192373044).pkl" \
--use_mimiccxr_facts_for_train \
--use_mimiccxr_facts_for_test \
--dicom_id_to_pos_neg_facts_filepath \
"/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/mimiccxr_dicom_id_to_fact_based_pos_neg_facts(hash=1360,3939902508813076616).pkl" \
--mimiccxr_exclude_noisy_images \
--use_cxrlt2024_custom_labels \
--cxrlt2024_custom_dicom_id_to_pos_neg_facts_filepath \
"/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/mimiccxr/cxrlt2024_integrated_nli_queries_for_fact_classification.pkl" \
--chest_imagenome_anatlocs_weight 1.5 \
--vinbig_weight 2.0 \
--save
# Out:
# script's arguments:
#    epochs: 150
#    batches_per_epoch: 1000
#    max_images_per_batch: 18
#    max_phrases_per_batch: 400
#    max_phrases_per_image: 45
#    val_batch_size_factor: 2.5
#    checkpoint_folder: None
#    pretrained_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20241022_161835_mim-facts+chst-img-anat+cxrlt2024(GPT4)+vinbig_PhraseGrounder(dn121,FiLM_SigmoidAttention_ObjectDetection,128,256,256,256-128)
#    pretrained_checkpoint_folder_paths: None
#    freeze_image_encoder: False
#    raw_image_encoding: densenet-121
#    huggingface_model_name: None
#    num_regions: 169
#    image_local_feat_size: 1024
#    image_encoder_pretrained_weights_path: None
#    image_encoder_dropout_p: 0
#    yolov8_model_name_or_path: None
#    yolov8_model_alias: None
#    phrase_embedding_size: 128
#    regions_width: 13
#    regions_height: 13
#    qkv_size: None
# ...
