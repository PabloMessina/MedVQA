# %%
# %env CUDA_VISIBLE_DEVICES=1
# Out:
# env: CUDA_VISIBLE_DEVICES=1

# %%
# !python ../../train_phrase_grounding.py \
--pretrained_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250805_052035_mscxr+chst-img-alg+chst-img-pg+vinbig+padchest-gr_PhraseGrounder(microsoft-rad-dino-maira-2,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)" \
--epochs 100 \
--batches_per_epoch 1000 \
--max_images_per_batch 15 \
--max_phrases_per_batch 1000 \
--max_phrases_per_image 40 \
--val_batch_size_factor 1 \
--use_train_data_augmentations \
--raw_image_encoding "rad-dino-huggingface" \
--huggingface_model_name "microsoft/rad-dino-maira-2" \
--image_size 384 384 \
--image_local_feat_size 768 \
--num_regions 729 \
--regions_width 27 \
--regions_height 27 \
--phrase_embedding_size 128 \
--phrase_grounding_mode "film_based_phrase_grounding_and_classification_v2" \
--phrase_mlp_hidden_dims 256 128 \
--visual_grounding_hidden_size 256 \
--bbox_format "cxcywh" \
--predict_relative_bbox_coords \
--freeze_config "phrase_grounding_freeze_config_v1.yaml" \
--num_train_workers 2 \
--num_val_workers 2 \
--gradient_accumulation_steps 4 \
--optimizer_name "adamw" \
--scheduler "exp-warmup+decay+cyclicdecay" \
--lr 1e-6 \
--warmup_decay_and_cyclic_decay_args "1e-6,3,8e-5,5,3e-6,8e-5,5,3e-6" \
--binary_multilabel_classif_loss_name "focal+bce+npbbce" \
--do_visual_grounding_with_bbox_regression \
--use_vinbig_for_train \
--use_vinbig_for_test \
--vinbig_phrase_embeddings_filepath \
"/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/vinbig/label_phrase_embeddings(hash=553,547344555309613415).pkl" \
--vinbig_training_data_mode "train" \
--vinbig_task_mode "classification" \
--use_amp \
--save
# Out:
# 2025-09-12 09:44:12,952 - INFO - root - Logging configured (Color: True).
# 2025-09-12 09:44:13,381 - INFO - medvqa.utils.common - Total RAM: 125.61 GB
# 2025-09-12 09:44:13,381 - INFO - medvqa.utils.common - Available RAM: 117.12 GB
# 2025-09-12 09:44:13,382 - INFO - medvqa.utils.common - Used RAM: 7.32 GB (6.8%)
# 2025-09-12 09:44:13,387 - INFO - medvqa.utils.common -
# script's arguments:
#    epochs: 100
#    batches_per_epoch: 1000
#    max_images_per_batch: 15
#    max_phrases_per_batch: 1000
#    max_phrases_per_image: 40
#    val_batch_size_factor: 1.0
#    checkpoint_folder: None
#    pretrained_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250805_052035_mscxr+chst-img-alg+chst-img-pg+vinbig+padchest-gr_PhraseGrounder(microsoft-rad-dino-maira-2,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)
#    pretrained_checkpoint_folder_paths: None
#    raw_image_encoding: rad-dino-huggingface
#    huggingface_model_name: microsoft/rad-dino-maira-2
#    num_regions: 729
#    image_local_feat_size: 768
#    image_encoder_pretrained_weights_path: None
#    image_encoder_dropout_p: 0
#    yolov8_model_name_or_path: None
#    yolov8_model_alias: None
#    phrase_embedding_size: 128
#    regions_width: 27
#    regions_height: 27
#    qkv_size: None
#    phrase_grounding_mode: film_based_phrase_grounding_and_classification_v2
#    phrase_classifier_hidden_size: None
#    transf_d_model: None
#    transf_nhead: None
#    transf_dim_feedforward: None
#    transf_dropout: 0
#    transf_num_layers: None
#    visual_feature_proj_size: None
#    visual_grounding_hidden_size: 256
#    phrase_mlp_hidden_dims: [256, 128]
#    predict_global_alignment: False
#    alignment_proj_size: None
#    yolov11_model_name_or_path: None
#    yolov11_model_alias: None
#    bbox_format: cxcywh
#    predict_relative_bbox_coords: True
#    freeze_config: phrase_grounding_freeze_config_v1.yaml
#    optimizer_name: adamw
#    lr: 1e-06
#    scheduler: exp-warmup+decay+cyclicdecay
#    lr_decay: 0.76
#    lr_decay_patience: 2
#    warmup_and_decay_args: None
#    warmup_and_cosine_args: None
#    warmup_decay_and_cyclic_decay_args: 1e-6,3,8e-5,5,3e-6,8e-5,5,3e-6
#    gradient_accumulation_steps: 4
#    override_lr: False
#    max_grad_norm: None
#    attention_supervision_loss_weight: 1.0
#    phrase_classifier_loss_weight: 1.0
#    foreground_loss_weight: 1.0
#    background_loss_weight: 1.0
#    focal_loss_weight: 1.0
#    bce_loss_weight: 1.0
#    wbce_loss_weight: 1.0
#    binary_multilabel_classif_loss_name: focal+bce+npbbce
#    use_weighted_phrase_classifier_loss: False
#    cluster_and_label_weights_for_facts_filepath: None
#    use_attention_regularization_loss: False
#    use_contrastive_phrase_grounding_loss: False
#    nt_xent_temperature: 0.1
#    num_train_workers: 2
#    num_val_workers: 2
#    device: cuda
#    use_amp: True
#    use_train_data_augmentations: True
#    image_size: [384, 384]
#    dicom_id_to_pos_neg_facts_filepath: None
#    iuxray_image_id_to_pos_neg_facts_filepath: None
#    mscxr_phrase2embedding_filepath: None
#    chest_imagenome_augmented_phrase_groundings_filepath: None
#    chest_imagenome_phrase_embeddings_filepath: None
#    chest_imagenome_bbox_phrase_embeddings_filepath: None
#    vinbig_phrase_embeddings_filepath: /mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/vinbig/label_phrase_embeddings(hash=553,547344555309613415).pkl
#    chexlocalize_class_phrase_embeddings_filepath: None
#    chexpert_class_phrase_embeddings_filepath: None
#    padchest_gr_phrase_embeddings_filepath: None
#    mimiccxr_exclude_noisy_images: False
#    mimiccxr_facts_weight: 1.0
#    chest_imagenome_pg_weight: 1.0
#    chest_imagenome_alg_weight: 1.0
#    mscxr_weight: 1.0
#    cxrlt2024_weight: 1.0
#    vinbig_weight: 1.0
#    chexlocalize_weight: 1.0
#    chexpert_weight: 1.0
#    iuxray_weight: 1.0
#    padchest_gr_weight: 1.0
#    pos_area_prior: 0.4
#    neg_area_prior: 0.0
#    use_mimiccxr_facts_for_train: False
#    use_mimiccxr_facts_for_test: False
#    use_mscxr_for_train: False
#    use_mscxr_for_val: False
#    use_chest_imagenome_for_train: False
#    use_chest_imagenome_for_val: False
#    use_vinbig_for_train: True
#    use_vinbig_for_test: True
#    use_chexlocalize_for_train: False
#    use_chexlocalize_for_test: False
#    use_chexpert_for_train: False
#    use_chexpert_for_test: False
#    use_iuxray_for_train: False
#    use_iuxray_for_test: False
#    use_padchest_gr_for_train: False
#    use_padchest_gr_for_val: False
#    use_cxrlt2024_challenge_split: False
#    use_cxrlt2024_custom_labels: False
#    use_cxrlt2024_official_labels: False
#    use_all_cxrlt2024_official_labels_for_training: False
#    vinbig_training_data_mode: train
#    vinbig_task_mode: classification
#    chexpert_training_data_mode: all
#    mimiccxr_balance_long_middle_short_tail: False
#    mimiccxr_long_middle_short_tail_thresholds: (0.02, 0.05)
#    mimiccxr_report_fact_nli_integrated_data_filepath: None
#    mimiccxr_use_interpret_cxr_challenge_split: False
#    mimiccxr_interpret_cxr_challenge_split_filepath: None
#    iuxray_use_interpret_cxr_challenge_split: False
#    iuxray_interpret_cxr_challenge_split_filepath: None
#    chexpert_use_interpret_cxr_challenge_split: False
#    chexpert_interpret_cxr_challenge_split_filepath: None
#    chexlocalize_use_interpret_cxr_challenge_split: False
#    chexlocalize_interpret_cxr_challenge_split_filepath: None
#    cxrlt2024_custom_dicom_id_to_pos_neg_facts_filepath: None
#    cxrlt2024_official_training_labels_for_fact_classification_filepath: None
#    cxrlt2024_do_balanced_sampling: False
#    do_visual_grounding_with_bbox_regression: True
#    replace_phrase_embeddings_with_random_vectors: False
#    use_vinbig_with_modified_labels: False
#    mscxr_training_data_mode: train
#    mscxr_do_grounding_only: False
#    padchest_gr_training_split: train
#    skip_nms: False
#    use_cnr_metric: False
#    use_soft_dice_metric: False
#    save: True
#    override_metric_weights: None
# 2025-09-12 09:44:13,387 - INFO - __main__ - ========== Training model from scratch ==========
# 2025-09-12 09:44:13,443 - INFO - __main__ - device = cuda
# 2025-09-12 09:44:13,443 - INFO - __main__ - ========== Creating instance of PhraseGrounder ==========
# 2025-09-12 09:44:13,443 - WARNING - medvqa.models.phrase_grounding.phrase_grounder - Unused kwargs: {'pretrained_checkpoint_folder_path': '/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250805_052035_mscxr+chst-img-alg+chst-img-pg+vinbig+padchest-gr_PhraseGrounder(microsoft-rad-dino-maira-2,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)', 'pretrained_checkpoint_folder_paths': None, 'freeze_config': 'phrase_grounding_freeze_config_v1.yaml'}
# 2025-09-12 09:44:13,443 - INFO - medvqa.models.vision.visual_modules - MultiPurposeVisualModule()
# 2025-09-12 09:44:13,444 - INFO - medvqa.models.vision.visual_modules -   Initializing raw_image_encoder: rad-dino-huggingface
# 2025-09-12 09:44:14,235 - INFO - medvqa.models.vision.visual_modules -   self.global_feat_size = 768
# 2025-09-12 09:44:14,236 - INFO - medvqa.models.vision.visual_modules -   self.local_feat_size = 768
# 2025-09-12 09:44:14,236 - INFO - medvqa.models.vision.visual_modules -   Initializing auxiliary tasks
# 2025-09-12 09:44:14,251 - INFO - medvqa.models.vision.bbox_regression - MultiClassBoundingBoxRegressor
# 2025-09-12 09:44:14,251 - INFO - medvqa.models.vision.bbox_regression -   local_feat_dim: 256
# 2025-09-12 09:44:14,251 - INFO - medvqa.models.vision.bbox_regression -   bbox_format: cxcywh
# 2025-09-12 09:44:14,251 - INFO - medvqa.models.vision.bbox_regression -   predict_relative: True
# 2025-09-12 09:44:14,396 - INFO - medvqa.utils.torch_utils - Initial freeze state (freeze_all=True): All params require_grad = False
# 2025-09-12 09:44:14,398 - INFO - medvqa.utils.torch_utils - Parameter freezing applied. 613634/87590407 parameters are trainable.
# 2025-09-12 09:44:14,398 - INFO - medvqa.utils.torch_utils - Frozen parameters/prefixes: raw_image_encoder, visual_grounding_bbox_regressor, local_attention_hidden_layer, local_film...
# 2025-09-12 09:44:14,399 - INFO - medvqa.utils.torch_utils - --- Checking for fully frozen and fully trainable modules ---
# 2025-09-12 09:44:14,401 - INFO - medvqa.utils.torch_utils - Module fully frozen ❄️: raw_image_encoder
# 2025-09-12 09:44:14,401 - INFO - medvqa.utils.torch_utils - Module fully frozen ❄️: local_film
# 2025-09-12 09:44:14,401 - INFO - medvqa.utils.torch_utils - Module fully frozen ❄️: local_attention_hidden_layer
# 2025-09-12 09:44:14,401 - INFO - medvqa.utils.torch_utils - Module fully trainable 💪: classifier_attention_hidden_layer
# 2025-09-12 09:44:14,401 - INFO - medvqa.utils.torch_utils - Module fully trainable 💪: classifier_attention_final_layer
# 2025-09-12 09:44:14,401 - INFO - medvqa.utils.torch_utils - Module fully trainable 💪: classifier_mlp
# 2025-09-12 09:44:14,401 - INFO - medvqa.utils.torch_utils - Module fully frozen ❄️: visual_grounding_bbox_regressor
# 2025-09-12 09:44:14,401 - INFO - medvqa.utils.torch_utils - --- Finished checking ---
# 2025-09-12 09:44:14,401 - INFO - __main__ - ========== Defining optimizer ==========
# 2025-09-12 09:44:14,401 - INFO - medvqa.losses.optimizers - create_optimizer(): name = adamw, lr = 1e-06
# 2025-09-12 09:44:14,403 - INFO - __main__ - ========== Defining scheduler ==========
# 2025-09-12 09:44:14,403 - INFO - medvqa.losses.schedulers - Using exp-warmup+decay+cyclicdecay scheduler: 1e-6,3,8e-5,5,3e-6,8e-5,5,3e-6
# 2025-09-12 09:44:14,403 - INFO - medvqa.losses.schedulers - lr0 = 1e-06, epochs01 = 3, lr1 = 8e-05, epochs12 = 5, lr2 = 3e-06, lr3 = 8e-05, restart_epochs = 5, lr4 = 3e-06
# 2025-09-12 09:44:14,403 - INFO - medvqa.losses.schedulers - self.steps_to_restart = 5
# 2025-09-12 09:44:14,403 - INFO - medvqa.losses.schedulers - self.steps = -1
# 2025-09-12 09:44:14,403 - INFO - medvqa.losses.schedulers - self.initial_lr = 8e-05
# 2025-09-12 09:44:14,404 - INFO - __main__ - ========== Creating trainer and validator engines ==========
# 2025-09-12 09:44:14,404 - INFO - medvqa.losses - Focal_BCE_NPBBCE_Loss(): focal_weight = 0.3333333333333333, bce_weight = 0.3333333333333333, npbbce_weight = 0.3333333333333333
# 2025-09-12 09:44:14,404 - INFO - medvqa.losses - Focal_BCE_NPBBCE_Loss(): focal_weight = 0.3333333333333333, bce_weight = 0.3333333333333333, npbbce_weight = 0.3333333333333333
# 2025-09-12 09:44:14,404 - INFO - medvqa.losses - Focal_BCE_WBCBCE_Loss(): focal_weight = 0.3333333333333333, bce_weight = 0.3333333333333333, wbcbce_weight = 0.3333333333333333
# 2025-09-12 09:44:14,405 - INFO - medvqa.training.phrase_grounding - foreground_loss_weight: 1.0
# 2025-09-12 09:44:14,405 - INFO - medvqa.training.phrase_grounding - background_loss_weight: 1.0
# 2025-09-12 09:44:14,405 - INFO - medvqa.losses.optimizers - GradientAccumulator.__init__(): num_accumulation_steps = 4, max_grad_norm = None
# 2025-09-12 09:44:14,405 - INFO - medvqa.losses - Focal_BCE_NPBBCE_Loss(): focal_weight = 0.3333333333333333, bce_weight = 0.3333333333333333, npbbce_weight = 0.3333333333333333
# 2025-09-12 09:44:14,406 - INFO - medvqa.losses - Focal_BCE_NPBBCE_Loss(): focal_weight = 0.3333333333333333, bce_weight = 0.3333333333333333, npbbce_weight = 0.3333333333333333
# 2025-09-12 09:44:14,406 - INFO - medvqa.losses - Focal_BCE_WBCBCE_Loss(): focal_weight = 0.3333333333333333, bce_weight = 0.3333333333333333, wbcbce_weight = 0.3333333333333333
# 2025-09-12 09:44:14,406 - INFO - medvqa.training.phrase_grounding - foreground_loss_weight: 1.0
# 2025-09-12 09:44:14,406 - INFO - medvqa.training.phrase_grounding - background_loss_weight: 1.0
# 2025-09-12 09:44:14,406 - INFO - __main__ - ========== Creating VinBig Phrase Grounding Trainer ==========
# 2025-09-12 09:44:14,406 - INFO - medvqa.datasets.image_transforms_factory - Building general image transform pipeline (is_train=True, bbox_format=yolo)
# 2025-09-12 09:44:14,408 - INFO - medvqa.datasets.image_transforms_factory - Building general image transform pipeline (is_train=False, bbox_format=None)
# 2025-09-12 09:44:14,408 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management - Initializing VinBigPhraseTrainer (Task: classification)
# 2025-09-12 09:44:14,409 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management - Loading image-level labels...
# 2025-09-12 09:44:15,224 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management - Loaded labels for 18000 images.
# 2025-09-12 09:44:15,224 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management - Determining image paths...
# 2025-09-12 09:44:15,257 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management - Using medium-size image paths.
# 2025-09-12 09:44:15,257 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management - Loading bounding boxes...
# 2025-09-12 09:44:16,230 - WARNING - medvqa.datasets.vinbig - Anomalous bboxes found/processed: 29 of 37367
# 2025-09-12 09:44:16,230 - INFO - medvqa.datasets.vinbig - class_id_offset: 0
# 2025-09-12 09:44:16,335 - INFO - medvqa.datasets.vinbig - class_id_offset: 0
# 2025-09-12 09:44:16,338 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management - Expecting 22 bbox classes.
# 2025-09-12 09:44:16,352 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management - Performing bounding box sanity checks...
# 2025-09-12 09:44:16,471 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management - Sanity checks complete.
# 2025-09-12 09:44:16,471 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management - Loaded bounding box data for 18000 images.
# 2025-09-12 09:44:16,471 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management - VinBigTrainerBase initialization complete.
# 2025-09-12 09:44:16,474 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management - Base trainer initialized. Bbox format: cxcywh
# 2025-09-12 09:44:16,474 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management - Loading phrase embeddings and phrases from /mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/vinbig/label_phrase_embeddings(hash=553,547344555309613415).pkl...
# 2025-09-12 09:44:16,475 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -   Initial phrase_embeddings shape: (28, 128)
# 2025-09-12 09:44:16,475 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -   Initial number of phrases: 28
# 2025-09-12 09:44:16,475 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management - Reordering labels, phrases, and embeddings...
# 2025-09-12 09:44:16,475 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -   Desired label order: ['Aortic enlargement', 'Atelectasis', 'Calcification', 'Cardiomegaly', 'Clavicle fracture', 'Consolidation', 'Edema', 'Emphysema', 'Enlarged PA', 'ILD', 'Infiltration', 'Lung Opacity', 'Lung cavity', 'Lung cyst', 'Mediastinal shift', 'Nodule/Mass', 'Other lesion', 'Pleural effusion', 'Pleural thickening', 'Pneumothorax', 'Pulmonary fibrosis', 'Rib fracture', 'COPD', 'Lung tumor', 'Pneumonia', 'Tuberculosis', 'Other disease', 'No finding']
# 2025-09-12 09:44:16,476 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -   Reordered phrase_classification_labels shape: (18000, 28)
# 2025-09-12 09:44:16,476 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -   Reordered number of phrases: 28
# 2025-09-12 09:44:16,476 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -   Reordered phrase_embeddings shape: (28, 128)
# 2025-09-12 09:44:16,476 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -
# Final phrases mapped to labels (in order):
# 	0: "aortic enlargement seen" (Aortic enlargement)
# 	1: "atelectasis seen" (Atelectasis)
# 	2: "calcification seen" (Calcification)
# 	3: "cardiomegaly seen" (Cardiomegaly)
# 	4: "clavicle fracture seen" (Clavicle fracture)
# 	5: "consolidation seen" (Consolidation)
# 	6: "edema seen" (Edema)
# 	7: "emphysema seen" (Emphysema)
# 	8: "enlarged pulmonary artery seen" (Enlarged PA)
# 	9: "interstitial lung disease seen" (ILD)
# 	10: "infiltration seen" (Infiltration)
# 	11: "lung opacity seen" (Lung Opacity)
# 	12: "lung cavity seen" (Lung cavity)
# 	13: "lung cyst seen" (Lung cyst)
# 	14: "mediastinal shift seen" (Mediastinal shift)
# 	15: "nodule/mass seen" (Nodule/Mass)
# 	16: "other lesion seen" (Other lesion)
# 	17: "pleural effusion seen" (Pleural effusion)
# 	18: "pleural thickening seen" (Pleural thickening)
# 	19: "pneumothorax seen" (Pneumothorax)
# 	20: "pulmonary fibrosis seen" (Pulmonary fibrosis)
# 	21: "rib fracture seen" (Rib fracture)
# 	22: "copd seen" (COPD)
# 	23: "lung tumor seen" (Lung tumor)
# 	24: "pneumonia seen" (Pneumonia)
# 	25: "tuberculosis seen" (Tuberculosis)
# 	26: "other disease seen" (Other disease)
# 	27: "no abnormalities seen" (No finding)
# 2025-09-12 09:44:16,476 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management - Determining training and validation indices...
# 2025-09-12 09:44:16,476 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -   Using TRAIN split indices (15000) for training.
# 2025-09-12 09:44:16,476 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -   Using TEST split indices (3000) for validation.
# 2025-09-12 09:44:16,476 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management - Setting up DataLoaders for task: classification...
# 2025-09-12 09:44:16,476 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management - Setting up TRAINING classification dataloader...
# No labels: 0
# Edema: 13
# Clavicle fracture: 27
# Lung cyst: 33
# COPD: 36
# Lung cavity: 51
# Emphysema: 81
# Rib fracture: 90
# Pneumothorax: 96
# Enlarged PA: 131
# Mediastinal shift: 150
# Atelectasis: 187
# Lung tumor: 291
# Consolidation: 353
# ILD: 397
# Calcification: 458
# Infiltration: 613
# Tuberculosis: 750
# Nodule/Mass: 841
# Pneumonia: 919
# Pleural effusion: 1038
# Other lesion: 1154
# Lung Opacity: 1331
# Pulmonary fibrosis: 1621
# Pleural thickening: 2010
# Cardiomegaly: 2316
# Aortic enlargement: 3098
# Other disease: 4377
# No finding: 10478
# Group sizes: [10478, 771, 323, 312, 286, 278, 258, 243, 241, 218, 215, 167, 159, 156, 122, 119, 117, 114, 102, 83, 82, 79, 77]
# 2025-09-12 09:44:17,743 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -   Creating balanced sampling groups for training:
# 2025-09-12 09:44:17,753 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -     Group size: 10478 , weight: 2381.99
# 2025-09-12 09:44:17,754 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -     Group size: 771   , weight: 882.14
# 2025-09-12 09:44:17,754 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -     Group size: 323   , weight: 579.13
# 2025-09-12 09:44:17,754 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -     Group size: 312   , weight: 568.78
# 2025-09-12 09:44:17,755 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -     Group size: 286   , weight: 543.31
# 2025-09-12 09:44:17,755 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -     Group size: 278   , weight: 535.18
# 2025-09-12 09:44:17,755 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -     Group size: 258   , weight: 514.16
# 2025-09-12 09:44:17,756 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -     Group size: 243   , weight: 497.70
# 2025-09-12 09:44:17,756 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -     Group size: 241   , weight: 495.46
# 2025-09-12 09:44:17,756 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -     Group size: 218   , weight: 468.77
# 2025-09-12 09:44:17,757 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -     Group size: 215   , weight: 465.16
# 2025-09-12 09:44:17,757 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -     Group size: 167   , weight: 402.55
# 2025-09-12 09:44:17,757 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -     Group size: 159   , weight: 391.08
# 2025-09-12 09:44:17,757 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -     Group size: 156   , weight: 386.69
# 2025-09-12 09:44:17,757 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -     Group size: 122   , weight: 332.92
# 2025-09-12 09:44:17,758 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -     Group size: 119   , weight: 327.77
# 2025-09-12 09:44:17,758 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -     Group size: 117   , weight: 324.29
# 2025-09-12 09:44:17,758 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -     Group size: 114   , weight: 319.02
# 2025-09-12 09:44:17,758 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -     Group size: 102   , weight: 297.06
# 2025-09-12 09:44:17,758 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -     Group size: 83    , weight: 259.09
# 2025-09-12 09:44:17,759 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -     Group size: 82    , weight: 256.96
# 2025-09-12 09:44:17,759 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -     Group size: 79    , weight: 250.50
# 2025-09-12 09:44:17,759 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -     Group size: 77    , weight: 246.11
# 2025-09-12 09:44:17,846 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -   Training classification DataLoader ready (Batch size: 15, Workers: 2).
# 2025-09-12 09:44:17,846 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management - Setting up VALIDATION classification dataloader...
# 2025-09-12 09:44:17,847 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -   Validation classification DataLoader ready (Batch size: 15, Workers: 2).
# 2025-09-12 09:44:17,847 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management - VinBigPhraseTrainer initialization complete.
# 2025-09-12 09:44:17,847 - INFO - __main__ - ========== Creating dataloaders ==========
# 2025-09-12 09:44:17,847 - INFO - __main__ - len(vinbig_trainer.train_dataloader) = 66666666666666667
# 2025-09-12 09:44:17,847 - INFO - __main__ - len(vinbig_trainer.val_dataloader) = 200
# 2025-09-12 09:44:17,847 - INFO - __main__ - len(_train_dataloaders) = 1
# 2025-09-12 09:44:17,847 - INFO - __main__ - len(_val_dataloaders) = 1
# 2025-09-12 09:44:17,847 - INFO - __main__ - _train_weights = [1.0]
# 2025-09-12 09:44:17,847 - INFO - __main__ - merged_dataset_name = vinbig
# 2025-09-12 09:44:17,847 - INFO - __main__ - ========== Attaching metrics, losses, timer and events to engines ==========
# 2025-09-12 09:44:17,853 - INFO - medvqa.training.utils - ========== Defining learning rate scheduler handler ==========
# 2025-09-12 09:44:17,853 - INFO - medvqa.training.utils - ========== Defining checkpoint folder path ==========
# 2025-09-12 09:44:17,854 - INFO - medvqa.training.utils - checkpoint_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250912_094417_vinbig_PhraseGrounder(microsoft-rad-dino-maira-2,FiLM_PhraseGroundingAndClassification_v2,128,256,256,256-128)
# 2025-09-12 09:44:17,854 - INFO - medvqa.models.checkpoint - metadata saved to /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250912_094417_vinbig_PhraseGrounder(microsoft-rad-dino-maira-2,FiLM_PhraseGroundingAndClassification_v2,128,256,256,256-128)/metadata.json
# 2025-09-12 09:44:17,854 - INFO - medvqa.training.utils - ========== Loading pretrained weights ==========
# 2025-09-12 09:44:17,854 - INFO - medvqa.models.checkpoint - checkpoint_names = ['checkpoint_143_ciss+ciss+ciss+msce+msss+msss+pcce+pcss+pcss+vbce+vbss+vbss=0.5286.pt']
# 2025-09-12 09:44:17,854 - INFO - medvqa.training.utils - pretrained_checkpoint_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250805_052035_mscxr+chst-img-alg+chst-img-pg+vinbig+padchest-gr_PhraseGrounder(microsoft-rad-dino-maira-2,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/checkpoint_143_ciss+ciss+ciss+msce+msss+msss+pcce+pcss+pcss+vbce+vbss+vbss=0.5286.pt
# 2025-09-12 09:44:18,615 - WARNING - medvqa.models.checkpoint - model state dict has 243 keys, loaded state dict has 239 keys, intersection has 239 keys, union has 243 keys.
# Examples of keys in model but not in loaded state dict:
#   classifier_attention_final_layer.bias
#   classifier_attention_hidden_layer.weight
#   classifier_attention_final_layer.weight
#   classifier_attention_hidden_layer.bias
# 2025-09-12 09:44:18,625 - INFO - medvqa.training.utils - Checkpoint successfully loaded!
# 2025-09-12 09:44:18,626 - INFO - medvqa.training.utils - ========== Defining log_metrics_handler ==========
# 2025-09-12 09:44:18,626 - INFO - medvqa.utils.logging_utils - MetricsLogger: we'll be logging to /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250912_094417_vinbig_PhraseGrounder(microsoft-rad-dino-maira-2,FiLM_PhraseGroundingAndClassification_v2,128,256,256,256-128)/metrics_logs.csv
# 2025-09-12 09:44:18,627 - INFO - medvqa.training.utils - ========== Running trainer engine ==========
# 2025-09-12 09:44:18,627 - INFO - ignite.engine.engine.Engine - Engine run starting with max_epochs=100.
# 2025-09-12 09:44:18,627 - INFO - medvqa.utils.handlers_utils - ==================== Epoch 1/100 ====================
# 2025-09-12 09:44:18,627 - INFO - medvqa.training.utils - (1) Training stage (lr = 0.000001) ...
# Training [1/100]: [1000/1000] 100%|██████████, loss=1.85 [03:23<00:00]
# 2025-09-12 09:47:43,115 - INFO - medvqa.utils.handlers_utils - loss 1.81307, vbg_phrcls_loss 1.81307, vbg_prc_auc 0.15989, 204.49 secs
# 2025-09-12 09:47:43,116 - INFO - medvqa.training.utils - (2) Validation stage ...
# 2025-09-12 09:47:43,120 - INFO - ignite.engine.engine.Engine - Engine run starting with max_epochs=1.
# Validation: [200/200] 100%|█████████ [01:32<00:00]
# 2025-09-12 09:49:16,239 - INFO - medvqa.utils.handlers_utils - vbg_prc_auc 0.07082, 93.12 secs
# Train metrics:
# vbg_prc_auc: 0.1599, weight = 10.0
# num = 1.5989, den = 10.0000, score = 0.1599
# Val metrics:
# vbg_prc_auc: 0.0708, weight = 10.0
# num = 0.7082, den = 10.0000, score = 0.0708
# Train score = 0.1599, Val score = 0.0708, Final score = 0.0753
# w_train = 0.05, w_val = 0.95
# 2025-09-12 09:49:16,566 - INFO - medvqa.utils.handlers_utils - New checkpoint saved: checkpoint_1_vbg_prc_auc=0.0753.pt
# 2025-09-12 09:49:16,567 - INFO - ignite.engine.engine.Engine - Epoch[1] Complete. Time taken: 00:01:33.446
# 2025-09-12 09:49:16,567 - INFO - ignite.engine.engine.Engine - Engine run complete. Time taken: 00:01:33.446
# 2025-09-12 09:49:16,568 - INFO - ignite.engine.engine.Engine - Epoch[1] Complete. Time taken: 00:04:57.852
# 2025-09-12 09:49:16,572 - INFO - medvqa.utils.handlers_utils - ==================== Epoch 2/100 ====================
# 2025-09-12 09:49:16,572 - INFO - medvqa.training.utils - (1) Training stage (lr = 0.000004) ...
# Training [2/100]: [1000/1000] 100%|██████████, loss=1.67 [03:38<00:00]
# 2025-09-12 09:52:55,636 - INFO - medvqa.utils.handlers_utils - loss 1.71965, vbg_phrcls_loss 1.71965, vbg_prc_auc 0.14204, 219.06 secs
# 2025-09-12 09:52:55,637 - INFO - medvqa.training.utils - (2) Validation stage ...
# 2025-09-12 09:52:55,639 - INFO - ignite.engine.engine.Engine - Engine run starting with max_epochs=1.
# Validation: [135/200]  68%|██████    [01:15<00:38]

# %%
# !python ../../train_phrase_grounding.py \
--pretrained_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250912_094417_vinbig_PhraseGrounder(microsoft-rad-dino-maira-2,FiLM_PhraseGroundingAndClassification_v2,128,256,256,256-128)" \
--epochs 60 \
--batches_per_epoch 1300 \
--max_images_per_batch 5 \
--max_phrases_per_batch 1000 \
--max_phrases_per_image 40 \
--val_batch_size_factor 2.0 \
--use_train_data_augmentations \
--raw_image_encoding "rad-dino-huggingface" \
--huggingface_model_name "microsoft/rad-dino-maira-2" \
--image_size 384 384 \
--image_local_feat_size 768 \
--num_regions 729 \
--regions_width 27 \
--regions_height 27 \
--phrase_embedding_size 128 \
--phrase_grounding_mode "film_based_phrase_grounding_and_classification_v2" \
--phrase_mlp_hidden_dims 256 128 \
--visual_grounding_hidden_size 256 \
--bbox_format "cxcywh" \
--predict_relative_bbox_coords \
--num_train_workers 2 \
--num_val_workers 2 \
--gradient_accumulation_steps 4 \
--optimizer_name "adamw" \
--scheduler "exp-warmup+decay+cyclicdecay" \
--lr 1e-6 \
--warmup_decay_and_cyclic_decay_args "1e-6,3,2e-5,5,1e-6,2e-5,5,1e-6" \
--binary_multilabel_classif_loss_name "focal+bce+npbbce" \
--do_visual_grounding_with_bbox_regression \
--use_vinbig_for_train \
--use_vinbig_for_test \
--vinbig_phrase_embeddings_filepath \
"/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/vinbig/label_phrase_embeddings(hash=553,547344555309613415).pkl" \
--vinbig_training_data_mode "train" \
--vinbig_task_mode "classification_and_grounding" \
--skip_nms \
--use_soft_dice \
--use_amp \
--save
# Out:
# 2025-09-14 01:21:03,450 - INFO - root - Logging configured (Color: True).
# 2025-09-14 01:21:03,898 - INFO - medvqa.utils.common - Total RAM: 125.61 GB
# 2025-09-14 01:21:03,899 - INFO - medvqa.utils.common - Available RAM: 113.38 GB
# 2025-09-14 01:21:03,899 - INFO - medvqa.utils.common - Used RAM: 10.89 GB (9.7%)
# 2025-09-14 01:21:03,904 - INFO - medvqa.utils.common -
# script's arguments:
#    epochs: 60
#    batches_per_epoch: 1300
#    max_images_per_batch: 5
#    max_phrases_per_batch: 1000
#    max_phrases_per_image: 40
#    val_batch_size_factor: 2.0
#    checkpoint_folder: None
#    pretrained_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250912_094417_vinbig_PhraseGrounder(microsoft-rad-dino-maira-2,FiLM_PhraseGroundingAndClassification_v2,128,256,256,256-128)
#    pretrained_checkpoint_folder_paths: None
#    raw_image_encoding: rad-dino-huggingface
#    huggingface_model_name: microsoft/rad-dino-maira-2
#    num_regions: 729
#    image_local_feat_size: 768
#    image_encoder_pretrained_weights_path: None
#    image_encoder_dropout_p: 0
#    yolov8_model_name_or_path: None
#    yolov8_model_alias: None
#    phrase_embedding_size: 128
#    regions_width: 27
#    regions_height: 27
#    qkv_size: None
#    phrase_grounding_mode: film_based_phrase_grounding_and_classification_v2
#    phrase_classifier_hidden_size: None
#    transf_d_model: None
#    transf_nhead: None
#    transf_dim_feedforward: None
#    transf_dropout: 0
#    transf_num_layers: None
#    visual_feature_proj_size: None
#    visual_grounding_hidden_size: 256
#    phrase_mlp_hidden_dims: [256, 128]
#    predict_global_alignment: False
#    alignment_proj_size: None
#    yolov11_model_name_or_path: None
#    yolov11_model_alias: None
#    bbox_format: cxcywh
#    predict_relative_bbox_coords: True
#    freeze_config: None
#    optimizer_name: adamw
#    lr: 1e-06
#    scheduler: exp-warmup+decay+cyclicdecay
#    lr_decay: 0.76
#    lr_decay_patience: 2
#    warmup_and_decay_args: None
#    warmup_and_cosine_args: None
#    warmup_decay_and_cyclic_decay_args: 1e-6,3,2e-5,5,1e-6,2e-5,5,1e-6
#    gradient_accumulation_steps: 4
#    override_lr: False
#    max_grad_norm: None
#    attention_supervision_loss_weight: 1.0
#    phrase_classifier_loss_weight: 1.0
#    foreground_loss_weight: 1.0
#    background_loss_weight: 1.0
#    focal_loss_weight: 1.0
#    bce_loss_weight: 1.0
#    wbce_loss_weight: 1.0
#    binary_multilabel_classif_loss_name: focal+bce+npbbce
#    use_weighted_phrase_classifier_loss: False
#    cluster_and_label_weights_for_facts_filepath: None
#    use_attention_regularization_loss: False
#    use_contrastive_phrase_grounding_loss: False
#    nt_xent_temperature: 0.1
#    num_train_workers: 2
#    num_val_workers: 2
#    device: cuda
#    use_amp: True
#    use_train_data_augmentations: True
#    image_size: [384, 384]
#    dicom_id_to_pos_neg_facts_filepath: None
#    iuxray_image_id_to_pos_neg_facts_filepath: None
#    mscxr_phrase2embedding_filepath: None
#    chest_imagenome_augmented_phrase_groundings_filepath: None
#    chest_imagenome_phrase_embeddings_filepath: None
#    chest_imagenome_bbox_phrase_embeddings_filepath: None
#    vinbig_phrase_embeddings_filepath: /mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/vinbig/label_phrase_embeddings(hash=553,547344555309613415).pkl
#    chexlocalize_class_phrase_embeddings_filepath: None
#    chexpert_class_phrase_embeddings_filepath: None
#    padchest_gr_phrase_embeddings_filepath: None
#    mimiccxr_exclude_noisy_images: False
#    mimiccxr_facts_weight: 1.0
#    chest_imagenome_pg_weight: 1.0
#    chest_imagenome_alg_weight: 1.0
#    mscxr_weight: 1.0
#    cxrlt2024_weight: 1.0
#    vinbig_weight: 1.0
#    chexlocalize_weight: 1.0
#    chexpert_weight: 1.0
#    iuxray_weight: 1.0
#    padchest_gr_weight: 1.0
#    pos_area_prior: 0.4
#    neg_area_prior: 0.0
#    use_mimiccxr_facts_for_train: False
#    use_mimiccxr_facts_for_test: False
#    use_mscxr_for_train: False
#    use_mscxr_for_val: False
#    use_chest_imagenome_for_train: False
#    use_chest_imagenome_for_val: False
#    use_vinbig_for_train: True
#    use_vinbig_for_test: True
#    use_chexlocalize_for_train: False
#    use_chexlocalize_for_test: False
#    use_chexpert_for_train: False
#    use_chexpert_for_test: False
#    use_iuxray_for_train: False
#    use_iuxray_for_test: False
#    use_padchest_gr_for_train: False
#    use_padchest_gr_for_val: False
#    use_cxrlt2024_challenge_split: False
#    use_cxrlt2024_custom_labels: False
#    use_cxrlt2024_official_labels: False
#    use_all_cxrlt2024_official_labels_for_training: False
#    vinbig_training_data_mode: train
#    vinbig_task_mode: classification_and_grounding
#    chexpert_training_data_mode: all
#    mimiccxr_balance_long_middle_short_tail: False
#    mimiccxr_long_middle_short_tail_thresholds: (0.02, 0.05)
#    mimiccxr_report_fact_nli_integrated_data_filepath: None
#    mimiccxr_use_interpret_cxr_challenge_split: False
#    mimiccxr_interpret_cxr_challenge_split_filepath: None
#    iuxray_use_interpret_cxr_challenge_split: False
#    iuxray_interpret_cxr_challenge_split_filepath: None
#    chexpert_use_interpret_cxr_challenge_split: False
#    chexpert_interpret_cxr_challenge_split_filepath: None
#    chexlocalize_use_interpret_cxr_challenge_split: False
#    chexlocalize_interpret_cxr_challenge_split_filepath: None
#    cxrlt2024_custom_dicom_id_to_pos_neg_facts_filepath: None
#    cxrlt2024_official_training_labels_for_fact_classification_filepath: None
#    cxrlt2024_do_balanced_sampling: False
#    do_visual_grounding_with_bbox_regression: True
#    replace_phrase_embeddings_with_random_vectors: False
#    use_vinbig_with_modified_labels: False
#    mscxr_training_data_mode: train
#    mscxr_do_grounding_only: False
#    padchest_gr_training_split: train
#    skip_nms: True
#    use_cnr_metric: False
#    use_soft_dice_metric: True
#    save: True
#    override_metric_weights: None
# 2025-09-14 01:21:03,905 - INFO - __main__ - ========== Training model from scratch ==========
# 2025-09-14 01:21:03,961 - INFO - __main__ - device = cuda
# 2025-09-14 01:21:03,961 - INFO - __main__ - ========== Creating instance of PhraseGrounder ==========
# 2025-09-14 01:21:03,961 - WARNING - medvqa.models.phrase_grounding.phrase_grounder - Unused kwargs: {'pretrained_checkpoint_folder_path': '/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250912_094417_vinbig_PhraseGrounder(microsoft-rad-dino-maira-2,FiLM_PhraseGroundingAndClassification_v2,128,256,256,256-128)', 'pretrained_checkpoint_folder_paths': None, 'freeze_config': None}
# 2025-09-14 01:21:03,961 - INFO - medvqa.models.vision.visual_modules - MultiPurposeVisualModule()
# 2025-09-14 01:21:03,961 - INFO - medvqa.models.vision.visual_modules -   Initializing raw_image_encoder: rad-dino-huggingface
# 2025-09-14 01:21:04,951 - INFO - medvqa.models.vision.visual_modules -   self.global_feat_size = 768
# 2025-09-14 01:21:04,952 - INFO - medvqa.models.vision.visual_modules -   self.local_feat_size = 768
# 2025-09-14 01:21:04,952 - INFO - medvqa.models.vision.visual_modules -   Initializing auxiliary tasks
# 2025-09-14 01:21:04,967 - INFO - medvqa.models.vision.bbox_regression - MultiClassBoundingBoxRegressor
# 2025-09-14 01:21:04,967 - INFO - medvqa.models.vision.bbox_regression -   local_feat_dim: 256
# 2025-09-14 01:21:04,968 - INFO - medvqa.models.vision.bbox_regression -   bbox_format: cxcywh
# 2025-09-14 01:21:04,968 - INFO - medvqa.models.vision.bbox_regression -   predict_relative: True
# 2025-09-14 01:21:05,110 - INFO - medvqa.utils.torch_utils - --- Checking for fully frozen and fully trainable modules ---
# 2025-09-14 01:21:05,112 - INFO - medvqa.utils.torch_utils - Module fully trainable 💪: model (root)
# 2025-09-14 01:21:05,112 - INFO - medvqa.utils.torch_utils - --- Finished checking ---
# 2025-09-14 01:21:05,112 - INFO - __main__ - ========== Defining optimizer ==========
# 2025-09-14 01:21:05,112 - INFO - medvqa.losses.optimizers - create_optimizer(): name = adamw, lr = 1e-06
# 2025-09-14 01:21:05,113 - INFO - __main__ - ========== Defining scheduler ==========
# 2025-09-14 01:21:05,114 - INFO - medvqa.losses.schedulers - Using exp-warmup+decay+cyclicdecay scheduler: 1e-6,3,2e-5,5,1e-6,2e-5,5,1e-6
# 2025-09-14 01:21:05,114 - INFO - medvqa.losses.schedulers - lr0 = 1e-06, epochs01 = 3, lr1 = 2e-05, epochs12 = 5, lr2 = 1e-06, lr3 = 2e-05, restart_epochs = 5, lr4 = 1e-06
# 2025-09-14 01:21:05,114 - INFO - medvqa.losses.schedulers - self.steps_to_restart = 5
# 2025-09-14 01:21:05,114 - INFO - medvqa.losses.schedulers - self.steps = -1
# 2025-09-14 01:21:05,114 - INFO - medvqa.losses.schedulers - self.initial_lr = 2e-05
# 2025-09-14 01:21:05,114 - INFO - __main__ - ========== Creating trainer and validator engines ==========
# 2025-09-14 01:21:05,114 - WARNING - medvqa.training.phrase_grounding - unused_kwargs: {'vinbig_task_mode': 'classification_and_grounding'}
# 2025-09-14 01:21:05,114 - INFO - medvqa.losses - Focal_BCE_NPBBCE_Loss(): focal_weight = 0.3333333333333333, bce_weight = 0.3333333333333333, npbbce_weight = 0.3333333333333333
# 2025-09-14 01:21:05,115 - INFO - medvqa.losses - Focal_BCE_NPBBCE_Loss(): focal_weight = 0.3333333333333333, bce_weight = 0.3333333333333333, npbbce_weight = 0.3333333333333333
# 2025-09-14 01:21:05,115 - INFO - medvqa.losses - Focal_BCE_WBCBCE_Loss(): focal_weight = 0.3333333333333333, bce_weight = 0.3333333333333333, wbcbce_weight = 0.3333333333333333
# 2025-09-14 01:21:05,115 - INFO - medvqa.training.phrase_grounding - foreground_loss_weight: 1.0
# 2025-09-14 01:21:05,115 - INFO - medvqa.training.phrase_grounding - background_loss_weight: 1.0
# 2025-09-14 01:21:05,115 - INFO - medvqa.losses.optimizers - GradientAccumulator.__init__(): num_accumulation_steps = 4, max_grad_norm = None
# 2025-09-14 01:21:05,116 - WARNING - medvqa.training.phrase_grounding - unused_kwargs: {'vinbig_task_mode': 'classification_and_grounding'}
# 2025-09-14 01:21:05,116 - INFO - medvqa.losses - Focal_BCE_NPBBCE_Loss(): focal_weight = 0.3333333333333333, bce_weight = 0.3333333333333333, npbbce_weight = 0.3333333333333333
# 2025-09-14 01:21:05,116 - INFO - medvqa.losses - Focal_BCE_NPBBCE_Loss(): focal_weight = 0.3333333333333333, bce_weight = 0.3333333333333333, npbbce_weight = 0.3333333333333333
# 2025-09-14 01:21:05,116 - INFO - medvqa.losses - Focal_BCE_WBCBCE_Loss(): focal_weight = 0.3333333333333333, bce_weight = 0.3333333333333333, wbcbce_weight = 0.3333333333333333
# 2025-09-14 01:21:05,117 - INFO - medvqa.training.phrase_grounding - foreground_loss_weight: 1.0
# 2025-09-14 01:21:05,117 - INFO - medvqa.training.phrase_grounding - background_loss_weight: 1.0
# 2025-09-14 01:21:05,117 - INFO - __main__ - ========== Creating VinBig Phrase Grounding Trainer ==========
# 2025-09-14 01:21:05,117 - INFO - medvqa.datasets.image_transforms_factory - Building general image transform pipeline (is_train=True, bbox_format=yolo)
# 2025-09-14 01:21:05,119 - INFO - medvqa.datasets.image_transforms_factory - Building general image transform pipeline (is_train=False, bbox_format=None)
# 2025-09-14 01:21:05,119 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management - Initializing VinBigPhraseTrainer (Task: classification_and_grounding)
# 2025-09-14 01:21:05,119 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management - Loading image-level labels...
# 2025-09-14 01:21:05,978 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management - Loaded labels for 18000 images.
# 2025-09-14 01:21:05,978 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management - Determining image paths...
# 2025-09-14 01:21:06,013 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management - Using medium-size image paths.
# 2025-09-14 01:21:06,014 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management - Loading bounding boxes...
# 2025-09-14 01:21:07,043 - WARNING - medvqa.datasets.vinbig - Anomalous bboxes found/processed: 29 of 37367
# 2025-09-14 01:21:07,043 - INFO - medvqa.datasets.vinbig - class_id_offset: 0
# 2025-09-14 01:21:07,153 - INFO - medvqa.datasets.vinbig - class_id_offset: 0
# 2025-09-14 01:21:07,156 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management - Expecting 22 bbox classes.
# 2025-09-14 01:21:07,171 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management - Performing bounding box sanity checks...
# 2025-09-14 01:21:07,297 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management - Sanity checks complete.
# 2025-09-14 01:21:07,297 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management - Loaded bounding box data for 18000 images.
# 2025-09-14 01:21:07,297 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management - VinBigTrainerBase initialization complete.
# 2025-09-14 01:21:07,300 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management - Base trainer initialized. Bbox format: cxcywh
# 2025-09-14 01:21:07,300 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management - Loading phrase embeddings and phrases from /mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/vinbig/label_phrase_embeddings(hash=553,547344555309613415).pkl...
# 2025-09-14 01:21:07,301 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -   Initial phrase_embeddings shape: (28, 128)
# 2025-09-14 01:21:07,301 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -   Initial number of phrases: 28
# 2025-09-14 01:21:07,301 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management - Reordering labels, phrases, and embeddings...
# 2025-09-14 01:21:07,301 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -   Desired label order: ['Aortic enlargement', 'Atelectasis', 'Calcification', 'Cardiomegaly', 'Clavicle fracture', 'Consolidation', 'Edema', 'Emphysema', 'Enlarged PA', 'ILD', 'Infiltration', 'Lung Opacity', 'Lung cavity', 'Lung cyst', 'Mediastinal shift', 'Nodule/Mass', 'Other lesion', 'Pleural effusion', 'Pleural thickening', 'Pneumothorax', 'Pulmonary fibrosis', 'Rib fracture', 'COPD', 'Lung tumor', 'Pneumonia', 'Tuberculosis', 'Other disease', 'No finding']
# 2025-09-14 01:21:07,302 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -   Reordered phrase_classification_labels shape: (18000, 28)
# 2025-09-14 01:21:07,302 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -   Reordered number of phrases: 28
# 2025-09-14 01:21:07,302 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -   Reordered phrase_embeddings shape: (28, 128)
# 2025-09-14 01:21:07,302 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -
# Final phrases mapped to labels (in order):
# 	0: "aortic enlargement seen" (Aortic enlargement)
# 	1: "atelectasis seen" (Atelectasis)
# 	2: "calcification seen" (Calcification)
# 	3: "cardiomegaly seen" (Cardiomegaly)
# 	4: "clavicle fracture seen" (Clavicle fracture)
# 	5: "consolidation seen" (Consolidation)
# 	6: "edema seen" (Edema)
# 	7: "emphysema seen" (Emphysema)
# 	8: "enlarged pulmonary artery seen" (Enlarged PA)
# 	9: "interstitial lung disease seen" (ILD)
# 	10: "infiltration seen" (Infiltration)
# 	11: "lung opacity seen" (Lung Opacity)
# 	12: "lung cavity seen" (Lung cavity)
# 	13: "lung cyst seen" (Lung cyst)
# 	14: "mediastinal shift seen" (Mediastinal shift)
# 	15: "nodule/mass seen" (Nodule/Mass)
# 	16: "other lesion seen" (Other lesion)
# 	17: "pleural effusion seen" (Pleural effusion)
# 	18: "pleural thickening seen" (Pleural thickening)
# 	19: "pneumothorax seen" (Pneumothorax)
# 	20: "pulmonary fibrosis seen" (Pulmonary fibrosis)
# 	21: "rib fracture seen" (Rib fracture)
# 	22: "copd seen" (COPD)
# 	23: "lung tumor seen" (Lung tumor)
# 	24: "pneumonia seen" (Pneumonia)
# 	25: "tuberculosis seen" (Tuberculosis)
# 	26: "other disease seen" (Other disease)
# 	27: "no abnormalities seen" (No finding)
# 2025-09-14 01:21:07,302 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management - Determining training and validation indices...
# 2025-09-14 01:21:07,302 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -   Using TRAIN split indices (15000) for training.
# 2025-09-14 01:21:07,302 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -   Using TEST split indices (3000) for validation.
# 2025-09-14 01:21:07,302 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management - Setting up DataLoaders for task: classification_and_grounding...
# 2025-09-14 01:21:07,302 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management - Setting up TRAINING classification dataloader...
# No labels: 0
# Edema: 13
# Clavicle fracture: 27
# Lung cyst: 33
# COPD: 36
# Lung cavity: 51
# Emphysema: 81
# Rib fracture: 90
# Pneumothorax: 96
# Enlarged PA: 131
# Mediastinal shift: 150
# Atelectasis: 187
# Lung tumor: 291
# Consolidation: 353
# ILD: 397
# Calcification: 458
# Infiltration: 613
# Tuberculosis: 750
# Nodule/Mass: 841
# Pneumonia: 919
# Pleural effusion: 1038
# Other lesion: 1154
# Lung Opacity: 1331
# Pulmonary fibrosis: 1621
# Pleural thickening: 2010
# Cardiomegaly: 2316
# Aortic enlargement: 3098
# Other disease: 4377
# No finding: 10478
# Group sizes: [10478, 771, 323, 312, 286, 278, 258, 243, 241, 218, 215, 167, 159, 156, 122, 119, 117, 114, 102, 83, 82, 79, 77]
# 2025-09-14 01:21:08,664 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -   Creating balanced sampling groups for training:
# 2025-09-14 01:21:08,674 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -     Group size: 10478 , weight: 2381.99
# 2025-09-14 01:21:08,675 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -     Group size: 771   , weight: 882.14
# 2025-09-14 01:21:08,676 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -     Group size: 323   , weight: 579.13
# 2025-09-14 01:21:08,676 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -     Group size: 312   , weight: 568.78
# 2025-09-14 01:21:08,676 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -     Group size: 286   , weight: 543.31
# 2025-09-14 01:21:08,677 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -     Group size: 278   , weight: 535.18
# 2025-09-14 01:21:08,677 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -     Group size: 258   , weight: 514.16
# 2025-09-14 01:21:08,677 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -     Group size: 243   , weight: 497.70
# 2025-09-14 01:21:08,678 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -     Group size: 241   , weight: 495.46
# 2025-09-14 01:21:08,678 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -     Group size: 218   , weight: 468.77
# 2025-09-14 01:21:08,678 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -     Group size: 215   , weight: 465.16
# 2025-09-14 01:21:08,678 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -     Group size: 167   , weight: 402.55
# 2025-09-14 01:21:08,679 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -     Group size: 159   , weight: 391.08
# 2025-09-14 01:21:08,679 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -     Group size: 156   , weight: 386.69
# 2025-09-14 01:21:08,679 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -     Group size: 122   , weight: 332.92
# 2025-09-14 01:21:08,679 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -     Group size: 119   , weight: 327.77
# 2025-09-14 01:21:08,679 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -     Group size: 117   , weight: 324.29
# 2025-09-14 01:21:08,680 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -     Group size: 114   , weight: 319.02
# 2025-09-14 01:21:08,680 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -     Group size: 102   , weight: 297.06
# 2025-09-14 01:21:08,680 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -     Group size: 83    , weight: 259.09
# 2025-09-14 01:21:08,680 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -     Group size: 82    , weight: 256.96
# 2025-09-14 01:21:08,680 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -     Group size: 79    , weight: 250.50
# 2025-09-14 01:21:08,680 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -     Group size: 77    , weight: 246.11
# 2025-09-14 01:21:08,774 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -   Training classification DataLoader ready (Batch size: 5, Workers: 2).
# 2025-09-14 01:21:08,774 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management - Setting up VALIDATION classification dataloader...
# 2025-09-14 01:21:08,775 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -   Validation classification DataLoader ready (Batch size: 10, Workers: 2).
# 2025-09-14 01:21:08,775 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management - Preprocessing data for grounding...
# Processing images for grounding: 100%|██| 18000/18000 [00:04<00:00, 3857.80it/s]
# 2025-09-14 01:21:13,442 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -   Processed 40063 bounding boxes.
# 2025-09-14 01:21:13,442 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -   Created 18197 phrase-image grounding samples.
# 2025-09-14 01:21:13,449 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management - Setting up TRAINING grounding dataloader...
# 2025-09-14 01:21:13,449 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -   Using 16089 grounding samples for training.
# 2025-09-14 01:21:13,466 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -   Training grounding DataLoader ready (Batch size: 5, Workers: 2).
# 2025-09-14 01:21:13,466 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management - Setting up VALIDATION grounding dataloader...
# 2025-09-14 01:21:13,466 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -   Using 2108 grounding samples for validation.
# 2025-09-14 01:21:13,466 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management -   Validation grounding DataLoader ready (Batch size: 10, Workers: 2).
# 2025-09-14 01:21:13,467 - INFO - medvqa.datasets.vinbig.vinbig_dataset_management - VinBigPhraseTrainer initialization complete.
# 2025-09-14 01:21:13,467 - INFO - __main__ - ========== Creating dataloaders ==========
# 2025-09-14 01:21:13,467 - INFO - __main__ - len(vinbig_trainer.train_classification_dataloader) = 200000000000000000
# 2025-09-14 01:21:13,467 - INFO - __main__ - len(vinbig_trainer.train_grounding_dataloader) = 3218
# 2025-09-14 01:21:13,467 - INFO - __main__ - len(vinbig_trainer.val_classification_dataloader) = 300
# 2025-09-14 01:21:13,467 - INFO - __main__ - len(vinbig_trainer.val_grounding_dataloader) = 211
# 2025-09-14 01:21:13,467 - INFO - __main__ - len(_train_dataloaders) = 2
# 2025-09-14 01:21:13,467 - INFO - __main__ - len(_val_dataloaders) = 2
# 2025-09-14 01:21:13,467 - INFO - __main__ - _train_weights = [0.5, 0.5]
# 2025-09-14 01:21:13,467 - INFO - __main__ - merged_dataset_name = vinbig
# 2025-09-14 01:21:13,467 - INFO - __main__ - ========== Attaching metrics, losses, timer and events to engines ==========
# 2025-09-14 01:21:13,474 - INFO - medvqa.training.utils - ========== Defining learning rate scheduler handler ==========
# 2025-09-14 01:21:13,474 - INFO - medvqa.training.utils - ========== Defining checkpoint folder path ==========
# 2025-09-14 01:21:13,474 - INFO - medvqa.training.utils - checkpoint_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250914_012113_vinbig_PhraseGrounder(microsoft-rad-dino-maira-2,FiLM_PhraseGroundingAndClassification_v2,128,256,256,256-128)
# 2025-09-14 01:21:13,475 - INFO - medvqa.models.checkpoint - metadata saved to /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250914_012113_vinbig_PhraseGrounder(microsoft-rad-dino-maira-2,FiLM_PhraseGroundingAndClassification_v2,128,256,256,256-128)/metadata.json
# 2025-09-14 01:21:13,475 - INFO - medvqa.training.utils - ========== Loading pretrained weights ==========
# 2025-09-14 01:21:13,475 - INFO - medvqa.models.checkpoint - checkpoint_names = ['checkpoint_95_vbg_prc_auc=0.4159.pt']
# 2025-09-14 01:21:13,475 - INFO - medvqa.training.utils - pretrained_checkpoint_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250912_094417_vinbig_PhraseGrounder(microsoft-rad-dino-maira-2,FiLM_PhraseGroundingAndClassification_v2,128,256,256,256-128)/checkpoint_95_vbg_prc_auc=0.4159.pt
# 2025-09-14 01:21:13,680 - INFO - medvqa.training.utils - Checkpoint successfully loaded!
# 2025-09-14 01:21:13,680 - INFO - medvqa.training.utils - ========== Defining log_metrics_handler ==========
# 2025-09-14 01:21:13,680 - INFO - medvqa.utils.logging_utils - MetricsLogger: we'll be logging to /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250914_012113_vinbig_PhraseGrounder(microsoft-rad-dino-maira-2,FiLM_PhraseGroundingAndClassification_v2,128,256,256,256-128)/metrics_logs.csv
# 2025-09-14 01:21:13,681 - INFO - medvqa.training.utils - ========== Running trainer engine ==========
# 2025-09-14 01:21:13,681 - INFO - ignite.engine.engine.Engine - Engine run starting with max_epochs=60.
# 2025-09-14 01:21:13,682 - INFO - medvqa.utils.handlers_utils - ==================== Epoch 1/60 ====================
# 2025-09-14 01:21:13,682 - INFO - medvqa.training.utils - (1) Training stage (lr = 0.000001) ...
# Training [1/60]: [1300/1300] 100%|██████████, loss=0.147 [04:20<00:00]
# 2025-09-14 01:25:34,999 - INFO - medvqa.utils.handlers_utils - loss 0.34866, vbg_phrcls_loss 0.56795, vbg_vgconf_loss 0.12141, vbg_vgbbox_loss 0.00796, vbg_prc_auc 0.62351, 261.32 secs
# 2025-09-14 01:25:35,000 - INFO - medvqa.training.utils - (2) Validation stage ...
# 2025-09-14 01:25:35,006 - INFO - ignite.engine.engine.Engine - Engine run starting with max_epochs=1.
# Validation: [511/511] 100%|█████████ [02:56<00:00]
# 2025-09-14 01:28:31,931 - INFO - medvqa.utils.handlers_utils - vbg_soft_dice 0.36346, vbg_prc_auc 0.40633, 176.93 secs
# Train metrics:
# vbg_vgconf_loss: 0.8917, weight = 1.0
# vbg_vgbbox_loss: 0.9921, weight = 1.0
# vbg_prc_auc: 0.6235, weight = 5.0
# num = 5.0014, den = 7.0000, score = 0.7145
# Val metrics:
# vbg_soft_dice: 0.3635, weight = 1.0
# vbg_prc_auc: 0.4063, weight = 5.0
# num = 2.3951, den = 6.0000, score = 0.3992
# Train score = 0.7145, Val score = 0.3992, Final score = 0.4150
# w_train = 0.05, w_val = 0.95
# 2025-09-14 01:28:32,873 - INFO - medvqa.utils.handlers_utils - New checkpoint saved: checkpoint_1_vbuc+vbce+vbss+vbss=0.4150.pt
# 2025-09-14 01:28:32,874 - INFO - ignite.engine.engine.Engine - Epoch[1] Complete. Time taken: 00:02:57.867
# 2025-09-14 01:28:32,874 - INFO - ignite.engine.engine.Engine - Engine run complete. Time taken: 00:02:57.868
# 2025-09-14 01:28:32,874 - INFO - ignite.engine.engine.Engine - Epoch[1] Complete. Time taken: 00:07:19.193
# 2025-09-14 01:28:32,877 - INFO - medvqa.utils.handlers_utils - ==================== Epoch 2/60 ====================
# 2025-09-14 01:28:32,877 - INFO - medvqa.training.utils - (1) Training stage (lr = 0.000003) ...
# Training [2/60]: [1300/1300] 100%|███████████, loss=0.12 [04:51<00:00]
# 2025-09-14 01:33:24,465 - INFO - medvqa.utils.handlers_utils - loss 0.33648, vbg_phrcls_loss 0.54973, vbg_vgconf_loss 0.11607, vbg_vgbbox_loss 0.00717, vbg_prc_auc 0.64158, 291.59 secs
# 2025-09-14 01:33:24,466 - INFO - medvqa.training.utils - (2) Validation stage ...
# 2025-09-14 01:33:24,468 - INFO - ignite.engine.engine.Engine - Engine run starting with max_epochs=1.
# Validation: [511/511] 100%|█████████ [03:08<00:00]
# 2025-09-14 01:36:33,840 - INFO - medvqa.utils.handlers_utils - vbg_soft_dice 0.37199, vbg_prc_auc 0.40875, 189.36 secs
# 2025-09-14 01:36:34,927 - INFO - medvqa.utils.handlers_utils - New checkpoint saved: checkpoint_2_vbuc+vbce+vbss+vbss=0.4189.pt
# 2025-09-14 01:36:34,927 - INFO - ignite.engine.engine.Engine - Epoch[1] Complete. Time taken: 00:03:10.458
# 2025-09-14 01:36:34,927 - INFO - ignite.engine.engine.Engine - Engine run complete. Time taken: 00:03:10.459
# 2025-09-14 01:36:34,928 - INFO - ignite.engine.engine.Engine - Epoch[2] Complete. Time taken: 00:08:02.054
# 2025-09-14 01:36:34,931 - INFO - medvqa.utils.handlers_utils - ==================== Epoch 3/60 ====================
# 2025-09-14 01:36:34,931 - INFO - medvqa.training.utils - (1) Training stage (lr = 0.000007) ...
# Training [3/60]: [1300/1300] 100%|█████████, loss=0.0833 [05:00<00:00]
# 2025-09-14 01:41:35,500 - INFO - medvqa.utils.handlers_utils - loss 0.34291, vbg_phrcls_loss 0.55680, vbg_vgconf_loss 0.12187, vbg_vgbbox_loss 0.00716, vbg_prc_auc 0.61993, 300.57 secs
# 2025-09-14 01:41:35,502 - INFO - medvqa.training.utils - (2) Validation stage ...
# 2025-09-14 01:41:35,504 - INFO - ignite.engine.engine.Engine - Engine run starting with max_epochs=1.
# Validation: [511/511] 100%|█████████ [03:13<00:00]
# 2025-09-14 01:44:49,784 - INFO - medvqa.utils.handlers_utils - vbg_soft_dice 0.36312, vbg_prc_auc 0.40920, 194.27 secs
# 2025-09-14 01:44:49,785 - INFO - ignite.engine.engine.Engine - Epoch[1] Complete. Time taken: 00:03:14.280
# 2025-09-14 01:44:49,785 - INFO - ignite.engine.engine.Engine - Engine run complete. Time taken: 00:03:14.281
# 2025-09-14 01:44:49,786 - INFO - ignite.engine.engine.Engine - Epoch[3] Complete. Time taken: 00:08:14.858
# 2025-09-14 01:44:49,790 - INFO - medvqa.utils.handlers_utils - ==================== Epoch 4/60 ====================
# 2025-09-14 01:44:49,790 - INFO - medvqa.training.utils - (1) Training stage (lr = 0.000020) ...
# Training [4/60]: [346/1300]  27%|██▉        , loss=0.615 [01:20<03:40]
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Training [8/60]: [1300/1300] 100%|██████████, loss=0.131 [05:12<00:00]
# 2025-09-14 02:23:52,672 - INFO - medvqa.utils.handlers_utils - loss 0.26608, vbg_phrcls_loss 0.40891, vbg_vgconf_loss 0.11532, vbg_vgbbox_loss 0.00792, vbg_prc_auc 0.79386, 312.23 secs
# 2025-09-14 02:23:52,673 - INFO - medvqa.training.utils - (2) Validation stage ...
# 2025-09-14 02:23:52,675 - INFO - ignite.engine.engine.Engine - Engine run starting with max_epochs=1.
# Validation: [511/511] 100%|█████████ [03:19<00:00]
# 2025-09-14 02:27:12,323 - INFO - medvqa.utils.handlers_utils - vbg_soft_dice 0.36504, vbg_prc_auc 0.41871, 199.64 secs
# 2025-09-14 02:27:13,493 - INFO - medvqa.utils.handlers_utils - New checkpoint saved: checkpoint_8_vbuc+vbce+vbss+vbss=0.4311.pt
# 2025-09-14 02:27:13,493 - INFO - ignite.engine.engine.Engine - Epoch[1] Complete. Time taken: 00:03:20.818
# 2025-09-14 02:27:13,494 - INFO - ignite.engine.engine.Engine - Engine run complete. Time taken: 00:03:20.818
# 2025-09-14 02:27:13,494 - INFO - ignite.engine.engine.Engine - Epoch[8] Complete. Time taken: 00:08:33.052
# 2025-09-14 02:27:13,497 - INFO - medvqa.utils.handlers_utils - ==================== Epoch 9/60 ====================
# 2025-09-14 02:27:13,498 - INFO - medvqa.training.utils - (1) Training stage (lr = 0.000001) ...
# Training [9/60]: [1300/1300] 100%|█████████, loss=0.0866 [05:11<00:00]
# 2025-09-14 02:32:25,714 - INFO - medvqa.utils.handlers_utils - loss 0.25925, vbg_phrcls_loss 0.39343, vbg_vgconf_loss 0.11721, vbg_vgbbox_loss 0.00787, vbg_prc_auc 0.81712, 312.22 secs
# 2025-09-14 02:32:25,715 - INFO - medvqa.training.utils - (2) Validation stage ...
# 2025-09-14 02:32:25,717 - INFO - ignite.engine.engine.Engine - Engine run starting with max_epochs=1.
# Validation: [511/511] 100%|█████████ [03:13<00:00]
# 2025-09-14 02:35:39,577 - INFO - medvqa.utils.handlers_utils - vbg_soft_dice 0.36358, vbg_prc_auc 0.42284, 193.85 secs
# 2025-09-14 02:35:40,712 - INFO - medvqa.utils.handlers_utils - New checkpoint saved: checkpoint_9_vbuc+vbce+vbss+vbss=0.4350.pt
# 2025-09-14 02:35:40,712 - INFO - ignite.engine.engine.Engine - Epoch[1] Complete. Time taken: 00:03:14.994
# 2025-09-14 02:35:40,712 - INFO - ignite.engine.engine.Engine - Engine run complete. Time taken: 00:03:14.994
# 2025-09-14 02:35:40,713 - INFO - ignite.engine.engine.Engine - Epoch[9] Complete. Time taken: 00:08:27.218
# 2025-09-14 02:35:40,715 - INFO - medvqa.utils.handlers_utils - ==================== Epoch 10/60 ====================
# 2025-09-14 02:35:40,716 - INFO - medvqa.training.utils - (1) Training stage (lr = 0.000020) ...
# Training [10/60]: [199/1300]  15%|█▌        , loss=0.578 [00:48<04:31]
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Training [14/60]: [1300/1300] 100%|█████████, loss=0.155 [05:19<00:00]
# 2025-09-14 03:15:04,280 - INFO - medvqa.utils.handlers_utils - loss 0.22678, vbg_phrcls_loss 0.33623, vbg_vgconf_loss 0.11012, vbg_vgbbox_loss 0.00722, vbg_prc_auc 0.87494, 319.72 secs
# 2025-09-14 03:15:04,281 - INFO - medvqa.training.utils - (2) Validation stage ...
# 2025-09-14 03:15:04,283 - INFO - ignite.engine.engine.Engine - Engine run starting with max_epochs=1.
# Validation: [511/511] 100%|█████████ [03:24<00:00]
# 2025-09-14 03:18:29,753 - INFO - medvqa.utils.handlers_utils - vbg_soft_dice 0.36771, vbg_prc_auc 0.42012, 205.46 secs
# 2025-09-14 03:18:29,754 - INFO - ignite.engine.engine.Engine - Epoch[1] Complete. Time taken: 00:03:25.470
# 2025-09-14 03:18:29,754 - INFO - ignite.engine.engine.Engine - Engine run complete. Time taken: 00:03:25.470
# 2025-09-14 03:18:29,755 - INFO - ignite.engine.engine.Engine - Epoch[14] Complete. Time taken: 00:08:45.194
# 2025-09-14 03:18:29,759 - INFO - medvqa.utils.handlers_utils - ==================== Epoch 15/60 ====================
# 2025-09-14 03:18:29,759 - INFO - medvqa.training.utils - (1) Training stage (lr = 0.000020) ...
# Training [15/60]: [1300/1300] 100%|████████, loss=0.0729 [04:57<00:00]
# 2025-09-14 03:23:27,120 - INFO - medvqa.utils.handlers_utils - loss 0.29571, vbg_phrcls_loss 0.45023, vbg_vgconf_loss 0.13221, vbg_vgbbox_loss 0.00898, vbg_prc_auc 0.73827, 297.36 secs
# 2025-09-14 03:23:27,122 - INFO - medvqa.training.utils - (2) Validation stage ...
# 2025-09-14 03:23:27,125 - INFO - ignite.engine.engine.Engine - Engine run starting with max_epochs=1.
# Validation: [418/511]  82%|███████▎  [02:48<00:34]
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Training [20/60]: [1300/1300] 100%|████████, loss=0.0621 [05:09<00:00]
# 2025-09-14 04:06:35,054 - INFO - medvqa.utils.handlers_utils - loss 0.26681, vbg_phrcls_loss 0.40334, vbg_vgconf_loss 0.12193, vbg_vgbbox_loss 0.00836, vbg_prc_auc 0.79844, 309.24 secs
# 2025-09-14 04:06:35,056 - INFO - medvqa.training.utils - (2) Validation stage ...
# 2025-09-14 04:06:35,058 - INFO - ignite.engine.engine.Engine - Engine run starting with max_epochs=1.
# Validation: [511/511] 100%|█████████ [03:27<00:00]
# 2025-09-14 04:10:03,390 - INFO - medvqa.utils.handlers_utils - vbg_soft_dice 0.35146, vbg_prc_auc 0.41148, 208.32 secs
# 2025-09-14 04:10:03,391 - INFO - ignite.engine.engine.Engine - Epoch[1] Complete. Time taken: 00:03:28.332
# 2025-09-14 04:10:03,391 - INFO - ignite.engine.engine.Engine - Engine run complete. Time taken: 00:03:28.333
# 2025-09-14 04:10:03,392 - INFO - ignite.engine.engine.Engine - Epoch[20] Complete. Time taken: 00:08:37.578
# 2025-09-14 04:10:03,396 - INFO - medvqa.utils.handlers_utils - ==================== Epoch 21/60 ====================
# 2025-09-14 04:10:03,397 - INFO - medvqa.training.utils - (1) Training stage (lr = 0.000009) ...
# Training [21/60]: [1300/1300] 100%|█████████, loss=0.116 [05:10<00:00]
# 2025-09-14 04:15:13,857 - INFO - medvqa.utils.handlers_utils - loss 0.23591, vbg_phrcls_loss 0.34659, vbg_vgconf_loss 0.11729, vbg_vgbbox_loss 0.00794, vbg_prc_auc 0.85801, 310.46 secs
# 2025-09-14 04:15:13,859 - INFO - medvqa.training.utils - (2) Validation stage ...
# 2025-09-14 04:15:13,861 - INFO - ignite.engine.engine.Engine - Engine run starting with max_epochs=1.
# Validation: [127/511]  25%|██▏       [00:51<02:36]
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Validation: [511/511] 100%|█████████ [03:27<00:00]
# 2025-09-14 04:52:38,206 - INFO - medvqa.utils.handlers_utils - vbg_soft_dice 0.33529, vbg_prc_auc 0.39239, 208.55 secs
# 2025-09-14 04:52:38,207 - INFO - ignite.engine.engine.Engine - Epoch[1] Complete. Time taken: 00:03:28.559
# 2025-09-14 04:52:38,207 - INFO - ignite.engine.engine.Engine - Engine run complete. Time taken: 00:03:28.559
# 2025-09-14 04:52:38,208 - INFO - ignite.engine.engine.Engine - Epoch[25] Complete. Time taken: 00:08:33.711
# 2025-09-14 04:52:38,212 - INFO - medvqa.utils.handlers_utils - ==================== Epoch 26/60 ====================
# 2025-09-14 04:52:38,212 - INFO - medvqa.training.utils - (1) Training stage (lr = 0.000009) ...
# Training [26/60]: [1300/1300] 100%|█████████, loss=0.075 [04:44<00:00]
# 2025-09-14 04:57:23,157 - INFO - medvqa.utils.handlers_utils - loss 0.21893, vbg_phrcls_loss 0.30976, vbg_vgconf_loss 0.11943, vbg_vgbbox_loss 0.00868, vbg_prc_auc 0.89831, 284.95 secs
# 2025-09-14 04:57:23,157 - INFO - medvqa.training.utils - (2) Validation stage ...
# 2025-09-14 04:57:23,158 - INFO - ignite.engine.engine.Engine - Engine run starting with max_epochs=1.
# Validation: [511/511] 100%|█████████ [03:30<00:00]
# 2025-09-14 05:00:54,032 - INFO - medvqa.utils.handlers_utils - vbg_soft_dice 0.36405, vbg_prc_auc 0.41130, 210.87 secs
# 2025-09-14 05:00:54,033 - INFO - ignite.engine.engine.Engine - Epoch[1] Complete. Time taken: 00:03:30.874
# 2025-09-14 05:00:54,033 - INFO - ignite.engine.engine.Engine - Engine run complete. Time taken: 00:03:30.875
# 2025-09-14 05:00:54,034 - INFO - ignite.engine.engine.Engine - Epoch[26] Complete. Time taken: 00:08:15.826
# 2025-09-14 05:00:54,038 - INFO - medvqa.utils.handlers_utils - ==================== Epoch 27/60 ====================
# 2025-09-14 05:00:54,038 - INFO - medvqa.training.utils - (1) Training stage (lr = 0.000004) ...
# Training [27/60]: [1087/1300]  84%|██████▋ , loss=0.0593 [04:10<00:49]
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
