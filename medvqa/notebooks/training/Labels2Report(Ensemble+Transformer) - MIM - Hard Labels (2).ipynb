# %%
# %env CUDA_VISIBLE_DEVICES=2
# Out:
# env: CUDA_VISIBLE_DEVICES=2

# %%
# !/home/pamessina/venv2/bin/python ../train_labels2report.py \
    --generation-mode "pred2rep" \
    --use-ensemble \
    --ensemble-model-checkpoint-folder-paths \
        "/mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/" \
    --ensemble-batch-size 160 \
    --ensemble-num-workers 3 \
    --use-hard-predictions \
    --filter-labels \
    --label-score-threshold 0.6 \
    --epochs 68 \
    --batches-per-epoch 300 \
    --batch-size 200 \
    --num-workers 3 \
    --iters-to-accumulate 2 \
    --optimizer-name "adamw" \
    --scheduler "exp-warmup+decay+cyclicdecay" \
    --lr 1e-6 \
    --warmup-decay-and-cyclic-decay-args "1e-6,3,4e-4,8,3e-6,4e-4,8,3e-6" \
    --use-mimiccxr \
    --mimiccxr-weight 1.0 \
    --mimiccxr-view-mode "chest_imagenome" \
    --mimiccxr-balanced-sampling-mode "balanced_chest_imagenome_global_labels_batchwise" \
    --mimiccxr-balanced-batch-size 30 \
    --mimiccxr-qa-adapted-reports-filename "qa_adapted_reports__20220904_095810.json" \
    --use-chest-imagenome \
    --use-chest-imagenome-decent-images-only \
    --chest-imagenome-label-names-filename "labels(min_freq=100).pkl" \
    --chest-imagenome-labels-filename "imageId2labels(min_freq=100).pkl" \
    --use-chexpert \
    --mimiccxr-chexpert-labels-filename "chexpert_labels_per_report__20220904_113605.pkl" \
    --use-medical-tokenization \
    --medical-terms-frequency-filename "medical_terms_frequency__20220918_184255.pkl" \
    --binary-loss-name "focal+bce+wbce-c" \
    --labels-hidden-dim 1024 \
    --embedding-dim 512 \
    --transf-dec-num-memory-vecs 10 \
    --transf-dec-hidden-dim 512 \
    --transf-dec-nhead 4 \
    --transf-dec-dim-forward 512 \
    --transf-dec-num-layers 3 \
    --use-amp \
    --save
# Out:
# script's arguments:
#    epochs: 68
#    batches_per_epoch: 300
#    batch_size: 200
#    checkpoint_folder: None
#    generation_mode: pred2rep
#    use_ensemble: True
#    ensemble_model_checkpoint_folder_paths: ['/mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/']
#    ensemble_batch_size: 160
#    ensemble_num_workers: 3
#    use_hard_predictions: True
#    pretrained_checkpoint_folder_path: None
#    labels_hidden_dim: 1024
#    embedding_dim: 512
#    transf_dec_num_memory_vecs: 10
#    transf_dec_hidden_dim: 512
#    transf_dec_nhead: 4
#    transf_dec_dim_forward: 512
#    transf_dec_num_layers: 3
#    dropout_prob: 0
#    vocab_min_freq: 10
#    use_medical_tokenization: True
#    medical_terms_frequency_filename: medical_terms_frequency__20220918_184255.pkl
#    optimizer_name: adamw
#    lr: 1e-06
#    scheduler: exp-warmup+decay+cyclicdecay
#    lr_decay: 0.76
#    lr_decay_patience: 2
#    warmup_and_decay_args: None
#    warmup_and_cosine_args: None
#    warmup_decay_and_cyclic_decay_args: 1e-6,3,4e-4,8,3e-6,4e-4,8,3e-6
#    iters_to_accumulate: 2
#    override_lr: False
#    binary_loss_name: focal+bce+wbce-c
#    focal_loss_weight: 1
#    bce_loss_weight: 1
#    wbce_loss_weight: 1
#    num_workers: 3
#    device: GPU
#    use_amp: True
#    train_mimiccxr: True
#    mimiccxr_weight: 1.0
#    mimiccxr_view_mode: chest_imagenome
#    mimiccxr_balanced_sampling_mode: balanced_chest_imagenome_global_labels_batchwise
#    mimiccxr_balanced_batch_size: 30
#    mimiccxr_qa_adapted_reports_filename: qa_adapted_reports__20220904_095810.json
#    chest_imagenome_labels_filename: imageId2labels(min_freq=100).pkl
#    chest_imagenome_label_names_filename: labels(min_freq=100).pkl
#    use_chest_imagenome_decent_images_only: True
#    save: True
#    use_gender: False
#    use_chexpert: True
#    mimiccxr_chexpert_labels_filename: chexpert_labels_per_report__20220904_113605.pkl
#    use_chest_imagenome: True
#    filter_labels: True
#    top_k_chexpert_labels: None
#    top_k_chest_imagenome_labels: None
#    label_score_threshold: 0.6
#    debug: False
# ----- Training model from scratch ------
# Computing number of labels and ranges for ensemble ...
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/metadata.json
# chest_imagenome_range: (0, 627)
# chexpert_range: (627, 641)
# ============================================================
# Precomputing sigmoid activations for ensemble ...
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/metadata.json
# ============================================================
# Model 1/1
# model_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/
# checkpoint_names = ['checkpoint_79_chou+chuc+chuc+chuc+chuc+cD+gacc+wmmp=0.6677.pt', 'checkpoint_135_chou+chuc+chuc+chuc+chuc+cD+gacc+wmmp=0.6689.pt']
# model_checkpoint_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/checkpoint_135_chou+chuc+chuc+chuc+chuc+cD+gacc+wmmp=0.6689.pt
# precomputed_chexpert_sigmoids_path = /mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/precomputed_chexpert_sigmoids(hash=340,3716123060218160099).pkl
# Precomputed sigmoids for CheXpert already exist.
# File size = 56.39 MB
# precomputed_chest_imagenome_sigmoids_path = /mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/precomputed_chest_imagenome_sigmoids(hash=347,2103260294420767687).pkl
# Precomputed sigmoids for Chest ImaGenome already exist.
# File size = 339.66 MB
# Skipping...
# precomputed_sigmoid_paths: [{'model_folder_path': '/mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/', 'chexpert_sigmoids_path': '/mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/precomputed_chexpert_sigmoids(hash=340,3716123060218160099).pkl', 'chest_imagenome_sigmoids_path': '/mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/precomputed_chest_imagenome_sigmoids(hash=347,2103260294420767687).pkl'}]
# ============================================================
# Precomputing thresholds (for hard predictions) for ensemble ...
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/metadata.json
# ============================================================
# Model 1/1
# model_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/
# checkpoint_names = ['checkpoint_79_chou+chuc+chuc+chuc+chuc+cD+gacc+wmmp=0.6677.pt', 'checkpoint_135_chou+chuc+chuc+chuc+chuc+cD+gacc+wmmp=0.6689.pt']
# model_checkpoint_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/checkpoint_135_chou+chuc+chuc+chuc+chuc+cD+gacc+wmmp=0.6689.pt
# results_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/results/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/
# get_image_transform()
#   Using bounding box aware transforms
#     Returning default transform (no augmentation)
# Calibrating thresholds on MIMIC-CXR validation set
# score_name: f1
# Thresholds for CheXpert already cached at /mnt/data/pamessina/workspaces/medvqa-workspace/results/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/thresholds_chexpert(f1).pkl
# Thresholds for Chest ImaGenome already cached at /mnt/data/pamessina/workspaces/medvqa-workspace/results/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/thresholds_chest_imagenome(f1).pkl
# precomputed_thresholds_paths: [{'chexpert': '/mnt/data/pamessina/workspaces/medvqa-workspace/results/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/thresholds_chexpert(f1).pkl', 'chest_imagenome': '/mnt/data/pamessina/workspaces/medvqa-workspace/results/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/thresholds_chest_imagenome(f1).pkl'}]
# ============================================================
# Precomputing filtered labels for ensemble ...
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/metadata.json
# ============================================================
# Model 1/1
# model_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/
# results_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/results/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/
# get_image_transform()
#   Using bounding box aware transforms
#     Returning default transform (no augmentation)
# Loading cached chexpert predictions and ground truth...
# len(dicom_id_to_pred_chexpert_probs): 3389
# len(dicom_id_to_gt_chexpert_labels): 3389
# Loading cached chest imagenome predictions and ground truth...
# len(dicom_id_to_pred_chest_imagenome_probs): 3389
# len(dicom_id_to_gt_chest_imagenome_labels): 3389
# Top 6 label classes with the highest f1 scores:
# 1. Support Devices: 0.8737220226581928
# 2. Pleural Effusion: 0.743933588761175
# 3. Cardiomegaly: 0.7198264171413074
# 4. Lung Opacity: 0.6673640167364017
# 5. Edema: 0.6276923076923075
# 6. Atelectasis: 0.6112539274493003
# Top 46 label classes with the highest f1 scores:
# 1. ('nlp', 'abnormal'): 0.9645215788665336
# 3. ('right lung', 'nlp', 'abnormal'): 0.902990264255911
# 5. ('right lung', 'anatomicalfinding', 'lung opacity'): 0.8907380607814762
# 8. ('cardiac silhouette', 'device', 'cardiac pacer and wires'): 0.8446115288220551
# 10. ('neck', 'tubesandlines', 'endotracheal tube'): 0.7756813417190775
# 12. ('tubesandlines', 'endotracheal tube'): 0.7704918032786885
# 15. ('abdomen', 'tubesandlines', 'enteric tube'): 0.7364085667215815
# 17. ('tubesandlines', 'enteric tube'): 0.7296849087893864
# 19. ('right costophrenic angle', 'anatomicalfinding', 'pleural effusion'): 0.7223903177004539
# 22. ('anatomicalfinding', 'enlarged cardiac silhouette'): 0.7153047989623865
# 24. ('cardiac silhouette', 'anatomicalfinding', 'enlarged cardiac silhouette'): 0.7143803843605036
# 27. ('left costophrenic angle', 'nlp', 'abnormal'): 0.6942647692971108
# 29. ('left costophrenic angle', 'anatomicalfinding', 'pleural effusion'): 0.6901408450704226
# 31. ('left lung', 'anatomicalfinding', 'pleural effusion'): 0.689430894308943
# 34. ('right hilar structures', 'anatomicalfinding', 'lung opacity'): 0.6697829716193656
# 36. ('left hilar structures', 'anatomicalfinding', 'lung opacity'): 0.6514327167210737
# 38. ('tubesandlines', 'picc'): 0.6485507246376812
# 41. ('mediastinum', 'tubesandlines', 'picc'): 0.6245733788395904
# 43. ('tubesandlines', 'swan-ganz catheter'): 0.6153846153846153
# 46. ('trachea', 'tubesandlines', 'tracheostomy tube'): 0.6046511627906976
# precomputed_filtered_labels_paths: [{'chexpert_indices_path': '/mnt/data/pamessina/workspaces/medvqa-workspace/results/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/chexpert_top_6_out_of_14_labels_f1_(score_threshold_0.60)_indices.pkl', 'chexpert_num_indices': 6, 'chest_imagenome_indices_path': '/mnt/data/pamessina/workspaces/medvqa-workspace/results/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/chest_imagenome_top_46_out_of_627_labels_f1_(score_threshold_0.60)_indices.pkl', 'chest_imagenome_num_indices': 46}]
# num_input_labels (after update): 52
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Initializing tokenizer ...
# Loading /mnt/data/pamessina/workspaces/medvqa-workspace/cache/vocab(min_freq=10;mode=report;qa_adapted_reports__20220904_095810.json).pkl ...
# --------------------------------------------------
# 3) Creating instance of Labels2ReportModel ...
# Labels2ReportModel
#   gen_mode: pred2rep
#   vocab_size: 4833
#   embedding_dim: 512
#   num_input_labels: 52
#   labels_hidden_dim: 1024
#   num_output_labels: 641
#   transf_dec_num_memory_vecs: 10
#   transf_dec_hidden_dim: 512
#   transf_dec_nhead: 4
#   transf_dec_dim_forward: 512
#   transf_dec_num_layers: 3
#   start_idx: 1
#   dropout_prob: 0
# --------------------------------------------------
# 4) Defining optimizer ...
# create_optimizer(): name = adamw
# --------------------------------------------------
# 5) Defining scheduler ...
# Using exp-warmup+decay+cyclicdecay scheduler: 1e-6,3,4e-4,8,3e-6,4e-4,8,3e-6
# 1e-06 3 0.0004 8 3e-06 0.0004 8 3e-06
# self.steps_to_restart = 8
# self.steps = -1
# self.initial_lr = 0.0004
# --------------------------------------------------
# 6) Creating trainer and validator engines ...
# Using focal+bce+wbce-c loss
# binary_loss_kwargs: {'focal_weight': 1, 'bce_weight': 1, 'wbce_weight': 1}
# --------------------------------------------------
# 7) Defining collate_batch_fn ...
# --------------------------------------------------
# 8) Creating MIMIC-CXR_Labels2ReportTrainer ...
# 227835it [00:17, 13270.73it/s]
# max_idx_count = 377110
# actual_idx_count = 239513
# ** NOTE: 137597 images were skipped because they were not in the allowed DICOM IDs
# Random report:
# <s> frontal lateral . trace pleural unilateral pleural effusion lateral , left side . no focal consolidation pneumothorax . heart mediastinal contours normal . trace unilateral pleural effusion , not specific , pulmonary embolism </s>
# len(self.train_indices) = 234217
# len(self.val_indices) = 1934
# Loading CheXpert labels...
# Loading Chest Imagenome labels...
# Loading precomputed sigmoid paths for ensemble predictions...
#   Loading /mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/precomputed_chexpert_sigmoids(hash=340,3716123060218160099).pkl
#     _probs.shape = (242280, 14)
#     len(_dids) = 242280
#     _thresholds.shape = (14,)
#     _probs has been thresholded
#     _label_indices.shape = (6,)
#     _probs has been filtered
#     Sanity checking chexpert labels
#     len(self.val_indices) = 1934
#     f1_score(_gt_labels, _pred_labels, average="micro") = 0.6929647111710497
#     f1_score(_gt_labels, _pred_labels, average="macro") = 0.6880602240473702
#   Loading /mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/precomputed_chest_imagenome_sigmoids(hash=347,2103260294420767687).pkl
#     _probs.shape = (242280, 627)
#     len(_dids) = 242280
#     _thresholds.shape = (627,)
#     _probs has been thresholded
#     _label_indices.shape = (46,)
#     _probs has been filtered
#     Sanity checking chest_imagenome labels
#     len(self.val_indices) = 1934
#     f1_score(_gt_labels, _pred_labels, average="micro") = 0.7399520894330582
#     f1_score(_gt_labels, _pred_labels, average="macro") = 0.695082438344295
# Done loading precomputed sigmoid paths for ensemble predictions
# Balanced sampling mode: balanced_chest_imagenome_global_labels_batchwise
# Regrouping indices by Chest Imagenome labels for balanced sampling...
# 627it [01:02,  9.98it/s]
# Global: airspace opacity                        , # images: 8595 (other: 225622)
# Global: atelectasis                             , # images: 79106 (other: 155111)
# Global: bone lesion                             , # images: 1692 (other: 232525)
# Global: bronchiectasis                          , # images: 905 (other: 233312)
# Global: calcified nodule                        , # images: 2708 (other: 231509)
# Global: clavicle fracture                       , # images: 862 (other: 233355)
# Global: consolidation                           , # images: 17769 (other: 216448)
# Global: costophrenic angle blunting             , # images: 5723 (other: 228494)
# Global: cyst/bullae                             , # images: 874 (other: 233343)
# Global: elevated hemidiaphragm                  , # images: 6412 (other: 227805)
# Global: enlarged cardiac silhouette             , # images: 57654 (other: 176563)
# Global: enlarged hilum                          , # images: 8983 (other: 225234)
# Global: hernia                                  , # images: 3025 (other: 231192)
# Global: hydropneumothorax                       , # images: 954 (other: 233263)
# Global: hyperaeration                           , # images: 10306 (other: 223911)
# Global: increased reticular markings/ild pattern, # images: 1373 (other: 232844)
# Global: infiltration                            , # images: 2977 (other: 231240)
# Global: linear/patchy atelectasis               , # images: 12797 (other: 221420)
# Global: lobar/segmental collapse                , # images: 9531 (other: 224686)
# Global: lung lesion                             , # images: 13455 (other: 220762)
# Global: lung opacity                            , # images: 154881 (other: 79336)
# Global: mass/nodule (not otherwise specified)   , # images: 7782 (other: 226435)
# Global: mediastinal displacement                , # images: 3438 (other: 230779)
# Global: mediastinal widening                    , # images: 5070 (other: 229147)
# Global: multiple masses/nodules                 , # images: 3730 (other: 230487)
# Global: pleural effusion                        , # images: 72076 (other: 162141)
# Global: pleural/parenchymal scarring            , # images: 14199 (other: 220018)
# Global: pneumomediastinum                       , # images: 864 (other: 233353)
# Global: pneumothorax                            , # images: 10640 (other: 223577)
# Global: pulmonary edema/hazy opacity            , # images: 35280 (other: 198937)
# Global: rib fracture                            , # images: 7080 (other: 227137)
# Global: scoliosis                               , # images: 3201 (other: 231016)
# Global: shoulder osteoarthritis                 , # images: 2178 (other: 232039)
# Global: spinal degenerative changes             , # images: 6810 (other: 227407)
# Global: spinal fracture                         , # images: 3101 (other: 231116)
# Global: sub-diaphragmatic air                   , # images: 1234 (other: 232983)
# Global: subcutaneous air                        , # images: 3377 (other: 230840)
# Global: superior mediastinal mass/enlargement   , # images: 3295 (other: 230922)
# Global: tortuous aorta                          , # images: 13462 (other: 220755)
# Global: vascular calcification                  , # images: 10172 (other: 224045)
# Global: vascular congestion                     , # images: 24614 (other: 209603)
# Global: vascular redistribution                 , # images: 3199 (other: 231018)
# Global: aortic graft/repair                     , # images: 115 (other: 234102)
# Global: cabg grafts                             , # images: 3839 (other: 230378)
# Global: cardiac pacer and wires                 , # images: 12453 (other: 221764)
# Global: prosthetic valve                        , # images: 2891 (other: 231326)
# Global: alveolar hemorrhage                     , # images: 1766 (other: 232451)
# Global: aspiration                              , # images: 8915 (other: 225302)
# Global: copd/emphysema                          , # images: 6553 (other: 227664)
# Global: fluid overload/heart failure            , # images: 6458 (other: 227759)
# Global: goiter                                  , # images: 614 (other: 233603)
# Global: granulomatous disease                   , # images: 2423 (other: 231794)
# Global: interstitial lung disease               , # images: 1943 (other: 232274)
# Global: lung cancer                             , # images: 1752 (other: 232465)
# Global: pericardial effusion                    , # images: 1400 (other: 232817)
# Global: pneumonia                               , # images: 34201 (other: 200016)
# Global: abnormal                                , # images: 184517 (other: 49700)
# Global: artifact                                , # images: 299 (other: 233918)
# Global: breast/nipple shadows                   , # images: 1020 (other: 233197)
# Global: low lung volumes                        , # images: 28214 (other: 206003)
# Global: rotated                                 , # images: 2036 (other: 232181)
# Global: skin fold                               , # images: 216 (other: 234001)
# Global: chest port                              , # images: 7247 (other: 226970)
# Global: chest tube                              , # images: 10271 (other: 223946)
# Global: endotracheal tube                       , # images: 22541 (other: 211676)
# Global: enteric tube                            , # images: 27915 (other: 206302)
# Global: ij line                                 , # images: 12109 (other: 222108)
# Global: intra-aortic balloon pump               , # images: 562 (other: 233655)
# Global: mediastinal drain                       , # images: 436 (other: 233781)
# Global: picc                                    , # images: 14281 (other: 219936)
# Global: pigtail catheter                        , # images: 3538 (other: 230679)
# Global: subclavian line                         , # images: 3883 (other: 230334)
# Global: swan-ganz catheter                      , # images: 2197 (other: 232020)
# Global: tracheostomy tube                       , # images: 4756 (other: 229461)
# --------------------------------------------------
# 9) Creating dataloaders ...
# len(_train_dataloaders) = 1
# len(_val_dataloaders) = 1
# _train_weights = [1.0]
# merged_dataset_name = mim
# --------------------------------------------------
# 10) Attaching metrics, losses, timer and events to engines ...
# --------------------------------------------------
# 11) Defining learning rate scheduler handler ...
# --------------------------------------------------
# 12) Defining checkpoint folder path ...
# checkpoint_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/report_gen/20230505_051959_mim_Labels2ReportModel(52,10,TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))
# metadata saved to /mnt/data/pamessina/workspaces/medvqa-workspace/models/report_gen/20230505_051959_mim_Labels2ReportModel(52,10,TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/metadata.json
# --------------------------------------------------
# 13) Defining log_metrics_handler ...
# MetricsLogger :: we'll be logging to /mnt/data/pamessina/workspaces/medvqa-workspace/models/report_gen/20230505_051959_mim_Labels2ReportModel(52,10,TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/metrics_logs.csv
# --------------------------------------------------
# 14) Running trainer engine ...
# ---- Epoch 1/68
# (1) Training stage (lr = 0.000001) ...
# loss 8.66502, wmdcmp 0.00233, report_loss 8.44673, 185.40 secs
# (2) Validation stage ...
# wmdcmp 0.00283, cD 0.00004, 19.50 secs
# ---- Epoch 2/68
# (1) Training stage (lr = 0.000007) ...
# loss 8.22501, wmdcmp 0.00251, report_loss 6.86143, 164.75 secs
# (2) Validation stage ...
# wmdcmp 0.00213, cD 0.00114, 16.48 secs
# ---- Epoch 3/68
# (1) Training stage (lr = 0.000054) ...
# loss 6.03725, wmdcmp 0.06291, report_loss 4.51159, 162.30 secs
# (2) Validation stage ...
# wmdcmp 0.05702, cD 0.09417, 15.41 secs
# ---- Epoch 4/68
# (1) Training stage (lr = 0.000400) ...
# loss 3.76498, wmdcmp 0.16871, report_loss 2.97065, 143.94 secs
# (2) Validation stage ...
# wmdcmp 0.11544, cD 0.36316, 14.93 secs
# ---- Epoch 5/68
# (1) Training stage (lr = 0.000217) ...
# loss 2.63706, wmdcmp 0.21375, report_loss 2.50029, 141.74 secs
# (2) Validation stage ...
# wmdcmp 0.11402, cD 0.30713, 14.78 secs
# ---- Epoch 6/68
# (1) Training stage (lr = 0.000118) ...
# loss 2.50596, wmdcmp 0.22533, report_loss 2.39786, 140.38 secs
# (2) Validation stage ...
# wmdcmp 0.13196, cD 0.39891, 17.45 secs
# ---- Epoch 7/68
# (1) Training stage (lr = 0.000064) ...
# loss 2.37994, wmdcmp 0.22897, report_loss 2.35771, 142.67 secs
# (2) Validation stage ...
# wmdcmp 0.13127, cD 0.38525, 15.87 secs
# ---- Epoch 8/68
# (1) Training stage (lr = 0.000035) ...
# loss 2.38357, wmdcmp 0.23263, report_loss 2.33623, 139.47 secs
# (2) Validation stage ...
# wmdcmp 0.11919, cD 0.33936, 15.00 secs
# ---- Epoch 9/68
# (1) Training stage (lr = 0.000019) ...
# loss 2.40201, wmdcmp 0.23432, report_loss 2.32042, 140.67 secs
# (2) Validation stage ...
# wmdcmp 0.13382, cD 0.42225, 14.66 secs
# ---- Epoch 10/68
# (1) Training stage (lr = 0.000010) ...
# loss 2.40946, wmdcmp 0.23593, report_loss 2.30728, 140.05 secs
# (2) Validation stage ...
# wmdcmp 0.12426, cD 0.35892, 15.03 secs
# ---- Epoch 11/68
# (1) Training stage (lr = 0.000006) ...
# loss 2.43989, wmdcmp 0.23547, report_loss 2.30838, 139.33 secs
# (2) Validation stage ...
# wmdcmp 0.12333, cD 0.36204, 15.83 secs
# ---- Epoch 12/68
# (1) Training stage (lr = 0.000003) ...
# loss 2.36255, wmdcmp 0.23536, report_loss 2.30941, 138.20 secs
# (2) Validation stage ...
# wmdcmp 0.12457, cD 0.36365, 15.11 secs
# ---- Epoch 13/68
# (1) Training stage (lr = 0.000400) ...
# loss 2.25097, wmdcmp 0.23815, report_loss 2.28395, 135.22 secs
# (2) Validation stage ...
# wmdcmp 0.12261, cD 0.30471, 15.36 secs
# ---- Epoch 14/68
# (1) Training stage (lr = 0.000199) ...
# loss 2.09747, wmdcmp 0.24950, report_loss 2.19409, 130.10 secs
# (2) Validation stage ...
# wmdcmp 0.13344, cD 0.39975, 15.16 secs
# ---- Epoch 15/68
# (1) Training stage (lr = 0.000099) ...
# loss 2.16821, wmdcmp 0.25490, report_loss 2.15648, 128.80 secs
# (2) Validation stage ...
# wmdcmp 0.11579, cD 0.33076, 14.73 secs
# ---- Epoch 16/68
# (1) Training stage (lr = 0.000049) ...
# loss 2.07564, wmdcmp 0.25801, report_loss 2.13663, 129.51 secs
# (2) Validation stage ...
# wmdcmp 0.12890, cD 0.36310, 14.50 secs
# ---- Epoch 17/68
# (1) Training stage (lr = 0.000024) ...
# loss 2.10392, wmdcmp 0.25895, report_loss 2.12757, 127.96 secs
# (2) Validation stage ...
# wmdcmp 0.12827, cD 0.36040, 14.87 secs
# ---- Epoch 18/68
# (1) Training stage (lr = 0.000012) ...
# loss 2.15692, wmdcmp 0.25974, report_loss 2.12677, 128.80 secs
# (2) Validation stage ...
# wmdcmp 0.12683, cD 0.36087, 14.54 secs
# ---- Epoch 19/68
# (1) Training stage (lr = 0.000006) ...
# loss 2.13436, wmdcmp 0.25964, report_loss 2.11582, 127.33 secs
# (2) Validation stage ...
# wmdcmp 0.12916, cD 0.36570, 14.55 secs
# ---- Epoch 20/68
# (1) Training stage (lr = 0.000003) ...
# loss 2.02555, wmdcmp 0.25957, report_loss 2.11876, 127.17 secs
# (2) Validation stage ...
# wmdcmp 0.12379, cD 0.36679, 16.34 secs
# ---- Epoch 21/68
# (1) Training stage (lr = 0.000400) ...
# loss 2.05165, wmdcmp 0.25653, report_loss 2.12842, 128.01 secs
# (2) Validation stage ...
# wmdcmp 0.13156, cD 0.38623, 16.00 secs
# ---- Epoch 22/68
# (1) Training stage (lr = 0.000199) ...
# loss 2.06996, wmdcmp 0.26542, report_loss 2.07916, 128.02 secs
# (2) Validation stage ...
# wmdcmp 0.11719, cD 0.36278, 14.82 secs
# ---- Epoch 23/68
# (1) Training stage (lr = 0.000099) ...
# loss 2.10475, wmdcmp 0.26773, report_loss 2.05229, 128.45 secs
# (2) Validation stage ...
# wmdcmp 0.13396, cD 0.39984, 14.80 secs
# ---- Epoch 24/68
# (1) Training stage (lr = 0.000049) ...
# loss 2.02844, wmdcmp 0.27187, report_loss 2.03286, 126.04 secs
# (2) Validation stage ...
# wmdcmp 0.13162, cD 0.39789, 16.28 secs
# ---- Epoch 25/68
# (1) Training stage (lr = 0.000024) ...
# loss 2.03973, wmdcmp 0.27250, report_loss 2.02670, 126.75 secs
# (2) Validation stage ...
# wmdcmp 0.11821, cD 0.34074, 14.92 secs
# ---- Epoch 26/68
# (1) Training stage (lr = 0.000012) ...
# loss 2.00107, wmdcmp 0.27344, report_loss 2.01573, 129.84 secs
# (2) Validation stage ...
# wmdcmp 0.12670, cD 0.35861, 14.80 secs
# ---- Epoch 27/68
# (1) Training stage (lr = 0.000006) ...
# loss 2.02598, wmdcmp 0.27368, report_loss 2.01810, 129.37 secs
# (2) Validation stage ...
# wmdcmp 0.12539, cD 0.36466, 14.80 secs
# ---- Epoch 28/68
# (1) Training stage (lr = 0.000003) ...
# loss 1.98959, wmdcmp 0.27277, report_loss 2.01827, 127.95 secs
# (2) Validation stage ...
# wmdcmp 0.12468, cD 0.35872, 14.58 secs
# ---- Epoch 29/68
# (1) Training stage (lr = 0.000400) ...
# loss 2.00234, wmdcmp 0.26782, report_loss 2.04415, 129.03 secs
# (2) Validation stage ...
# wmdcmp 0.12880, cD 0.35545, 15.07 secs
# ---- Epoch 30/68
# (1) Training stage (lr = 0.000199) ...
# loss 1.93064, wmdcmp 0.27405, report_loss 2.00321, 129.72 secs
# (2) Validation stage ...
# wmdcmp 0.12223, cD 0.38749, 14.98 secs
# ---- Epoch 31/68
# (1) Training stage (lr = 0.000099) ...
# loss 1.96296, wmdcmp 0.27764, report_loss 1.98071, 128.66 secs
# (2) Validation stage ...
# wmdcmp 0.11656, cD 0.33093, 16.40 secs
# ---- Epoch 32/68
# (1) Training stage (lr = 0.000049) ...
# loss 1.91684, wmdcmp 0.28036, report_loss 1.96589, 128.65 secs
# (2) Validation stage ...
# wmdcmp 0.11581, cD 0.34216, 15.60 secs
# ---- Epoch 33/68
# (1) Training stage (lr = 0.000024) ...
# loss 1.81640, wmdcmp 0.28271, report_loss 1.95294, 128.99 secs
# (2) Validation stage ...
# wmdcmp 0.12597, cD 0.36407, 14.92 secs
# ---- Epoch 34/68
# (1) Training stage (lr = 0.000012) ...
# loss 1.91574, wmdcmp 0.28141, report_loss 1.95420, 127.37 secs
# (2) Validation stage ...
# wmdcmp 0.12675, cD 0.36321, 15.11 secs
# ---- Epoch 35/68
# (1) Training stage (lr = 0.000006) ...
# loss 1.93872, wmdcmp 0.28314, report_loss 1.94610, 129.27 secs
# (2) Validation stage ...
# wmdcmp 0.12755, cD 0.36560, 14.64 secs
# ---- Epoch 36/68
# (1) Training stage (lr = 0.000003) ...
# loss 1.95055, wmdcmp 0.28251, report_loss 1.94827, 128.89 secs
# (2) Validation stage ...
# wmdcmp 0.12729, cD 0.36345, 14.99 secs
# ---- Epoch 37/68
# (1) Training stage (lr = 0.000400) ...
# loss 1.97324, wmdcmp 0.27616, report_loss 1.98471, 130.45 secs
# (2) Validation stage ...
# wmdcmp 0.12788, cD 0.34879, 15.05 secs
# ---- Epoch 38/68
# (1) Training stage (lr = 0.000199) ...
# loss 1.93950, wmdcmp 0.28215, report_loss 1.94712, 128.43 secs
# (2) Validation stage ...
# wmdcmp 0.12726, cD 0.38751, 15.17 secs
# ---- Epoch 39/68
# (1) Training stage (lr = 0.000099) ...
# loss 1.97954, wmdcmp 0.28568, report_loss 1.92315, 129.76 secs
# (2) Validation stage ...
# wmdcmp 0.11447, cD 0.32419, 15.14 secs
# ---- Epoch 40/68
# (1) Training stage (lr = 0.000049) ...
# loss 1.82988, wmdcmp 0.28803, report_loss 1.90782, 128.61 secs
# (2) Validation stage ...
# wmdcmp 0.12672, cD 0.36007, 13.43 secs
# ---- Epoch 41/68
# (1) Training stage (lr = 0.000024) ...
# loss 1.91931, wmdcmp 0.28901, report_loss 1.90473, 128.02 secs
# (2) Validation stage ...
# wmdcmp 0.12739, cD 0.36503, 15.01 secs
# ---- Epoch 42/68
# (1) Training stage (lr = 0.000012) ...
# loss 1.89269, wmdcmp 0.28922, report_loss 1.90267, 128.86 secs
# (2) Validation stage ...
# wmdcmp 0.12664, cD 0.36819, 15.46 secs
# ---- Epoch 43/68
# (1) Training stage (lr = 0.000006) ...
# loss 1.98819, wmdcmp 0.28932, report_loss 1.89862, 128.05 secs
# (2) Validation stage ...
# wmdcmp 0.12014, cD 0.35401, 15.99 secs
# ---- Epoch 44/68
# (1) Training stage (lr = 0.000003) ...
# loss 1.92533, wmdcmp 0.28980, report_loss 1.89718, 127.71 secs
# (2) Validation stage ...
# wmdcmp 0.12666, cD 0.37229, 14.62 secs
# ---- Epoch 45/68
# (1) Training stage (lr = 0.000400) ...
# loss 1.95670, wmdcmp 0.28399, report_loss 1.93294, 128.61 secs
# (2) Validation stage ...
# wmdcmp 0.13186, cD 0.38031, 15.12 secs
# ---- Epoch 46/68
# (1) Training stage (lr = 0.000199) ...
# loss 2.08706, wmdcmp 0.28745, report_loss 1.90659, 129.71 secs
# (2) Validation stage ...
# wmdcmp 0.12380, cD 0.34974, 16.62 secs
# ---- Epoch 47/68
# (1) Training stage (lr = 0.000099) ...
# loss 1.94626, wmdcmp 0.29173, report_loss 1.88072, 127.74 secs
# (2) Validation stage ...
# wmdcmp 0.12049, cD 0.33191, 14.79 secs
# ---- Epoch 48/68
# (1) Training stage (lr = 0.000049) ...
# loss 1.93444, wmdcmp 0.29398, report_loss 1.86902, 129.65 secs
# (2) Validation stage ...
# wmdcmp 0.11097, cD 0.31992, 14.86 secs
# ---- Epoch 49/68
# (1) Training stage (lr = 0.000024) ...
# loss 1.98219, wmdcmp 0.29581, report_loss 1.85882, 127.69 secs
# (2) Validation stage ...
# wmdcmp 0.12498, cD 0.35182, 15.00 secs
# ---- Epoch 50/68
# (1) Training stage (lr = 0.000012) ...
# loss 1.92293, wmdcmp 0.29570, report_loss 1.85633, 129.95 secs
# (2) Validation stage ...
# wmdcmp 0.12588, cD 0.35093, 13.89 secs
# ---- Epoch 51/68
# (1) Training stage (lr = 0.000006) ...
# loss 1.88372, wmdcmp 0.29508, report_loss 1.85849, 129.05 secs
# (2) Validation stage ...
# wmdcmp 0.12573, cD 0.35619, 14.95 secs
# ---- Epoch 52/68
# (1) Training stage (lr = 0.000003) ...
# loss 1.82559, wmdcmp 0.29642, report_loss 1.85033, 128.67 secs
# (2) Validation stage ...
# wmdcmp 0.12471, cD 0.35377, 14.91 secs
# ---- Epoch 53/68
# (1) Training stage (lr = 0.000400) ...
# loss 1.73872, wmdcmp 0.28656, report_loss 1.89831, 127.64 secs
# (2) Validation stage ...
# wmdcmp 0.13215, cD 0.39898, 14.16 secs
# ---- Epoch 54/68
# (1) Training stage (lr = 0.000199) ...
# loss 1.89291, wmdcmp 0.29313, report_loss 1.86192, 127.72 secs
# (2) Validation stage ...
# wmdcmp 0.10636, cD 0.32081, 14.68 secs
# ---- Epoch 55/68
# (1) Training stage (lr = 0.000099) ...
# loss 1.82212, wmdcmp 0.29778, report_loss 1.84164, 127.04 secs
# (2) Validation stage ...
# wmdcmp 0.12028, cD 0.34553, 14.58 secs
# ---- Epoch 56/68
# (1) Training stage (lr = 0.000049) ...
# loss 1.71237, wmdcmp 0.29931, report_loss 1.82955, 125.99 secs
# (2) Validation stage ...
# wmdcmp 0.12690, cD 0.37071, 14.17 secs
# ---- Epoch 57/68
# (1) Training stage (lr = 0.000024) ...
# loss 1.66908, wmdcmp 0.30115, report_loss 1.82268, 124.09 secs
# (2) Validation stage ...
# wmdcmp 0.12698, cD 0.37028, 14.40 secs
# ---- Epoch 58/68
# (1) Training stage (lr = 0.000012) ...
# loss 1.79487, wmdcmp 0.30097, report_loss 1.82024, 125.41 secs
# (2) Validation stage ...
# wmdcmp 0.12625, cD 0.36855, 14.27 secs
# ---- Epoch 59/68
# (1) Training stage (lr = 0.000006) ...
# loss 1.71788, wmdcmp 0.30162, report_loss 1.81733, 125.60 secs
# (2) Validation stage ...
# wmdcmp 0.12574, cD 0.36233, 14.35 secs
# ---- Epoch 60/68
# (1) Training stage (lr = 0.000003) ...
# loss 1.81678, wmdcmp 0.30206, report_loss 1.81289, 124.99 secs
# (2) Validation stage ...
# wmdcmp 0.12621, cD 0.36116, 14.44 secs
# ---- Epoch 61/68
# (1) Training stage (lr = 0.000400) ...
# loss 1.79031, wmdcmp 0.29276, report_loss 1.86153, 126.38 secs
# (2) Validation stage ...
# wmdcmp 0.11513, cD 0.31787, 14.58 secs
# ---- Epoch 62/68
# (1) Training stage (lr = 0.000199) ...
# loss 1.92316, wmdcmp 0.29651, report_loss 1.83822, 124.26 secs
# (2) Validation stage ...
# wmdcmp 0.12992, cD 0.37133, 14.57 secs
# ---- Epoch 63/68
# (1) Training stage (lr = 0.000099) ...
# loss 1.78408, wmdcmp 0.30159, report_loss 1.81170, 124.86 secs
# (2) Validation stage ...
# wmdcmp 0.12036, cD 0.34278, 14.19 secs
# ---- Epoch 64/68
# (1) Training stage (lr = 0.000049) ...
# loss 1.78156, wmdcmp 0.30368, report_loss 1.79955, 126.33 secs
# (2) Validation stage ...
# wmdcmp 0.12586, cD 0.38123, 14.08 secs
# ---- Epoch 65/68
# (1) Training stage (lr = 0.000024) ...
# loss 1.71668, wmdcmp 0.30484, report_loss 1.79240, 119.63 secs
# (2) Validation stage ...
# wmdcmp 0.12025, cD 0.34748, 18.64 secs
# ---- Epoch 66/68
# (1) Training stage (lr = 0.000012) ...
# loss 1.69046, wmdcmp 0.30483, report_loss 1.79065, 129.72 secs
# (2) Validation stage ...
# wmdcmp 0.12403, cD 0.36305, 13.95 secs
# ---- Epoch 67/68
# (1) Training stage (lr = 0.000006) ...
# loss 1.80625, wmdcmp 0.30618, report_loss 1.78627, 126.98 secs
# (2) Validation stage ...
# wmdcmp 0.12550, cD 0.38787, 13.83 secs
# ---- Epoch 68/68
# (1) Training stage (lr = 0.000003) ...
# loss 1.80730, wmdcmp 0.30584, report_loss 1.78812, 126.26 secs
# (2) Validation stage ...
# wmdcmp 0.12489, cD 0.38214, 15.10 secs

# %%
# !/home/pamessina/venv2/bin/python ../train_labels2report.py \
    --generation-mode "pred2rep" \
    --use-ensemble \
    --ensemble-model-checkpoint-folder-paths \
        "/mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/" \
    --ensemble-batch-size 160 \
    --ensemble-num-workers 3 \
    --use-hard-predictions \
    --use-gt-labels \
    --epochs 84 \
    --batches-per-epoch 300 \
    --batch-size 200 \
    --num-workers 2 \
    --iters-to-accumulate 2 \
    --optimizer-name "adamw" \
    --scheduler "exp-warmup+decay+cyclicdecay" \
    --lr 1e-6 \
    --warmup-decay-and-cyclic-decay-args "1e-6,3,4e-4,8,3e-6,4e-4,8,3e-6" \
    --use-mimiccxr \
    --mimiccxr-weight 1.0 \
    --mimiccxr-view-mode "chest_imagenome" \
    --mimiccxr-balanced-sampling-mode "balanced_chest_imagenome_global_labels_batchwise" \
    --mimiccxr-balanced-batch-size 30 \
    --mimiccxr-qa-adapted-reports-filename "qa_adapted_reports__20220904_095810.json" \
    --use-chest-imagenome \
    --use-chest-imagenome-decent-images-only \
    --chest-imagenome-label-names-filename "labels(min_freq=100).pkl" \
    --chest-imagenome-labels-filename "imageId2labels(min_freq=100).pkl" \
    --use-chexpert \
    --mimiccxr-chexpert-labels-filename "chexpert_labels_per_report__20220904_113605.pkl" \
    --use-medical-tokenization \
    --medical-terms-frequency-filename "medical_terms_frequency__20220918_184255.pkl" \
    --binary-loss-name "focal+bce+wbce-c" \
    --labels-hidden-dim 1024 \
    --embedding-dim 512 \
    --transf-dec-num-memory-vecs 10 \
    --transf-dec-hidden-dim 512 \
    --transf-dec-nhead 4 \
    --transf-dec-dim-forward 512 \
    --transf-dec-num-layers 3 \
    --use-amp \
    --save
# Out:
# script's arguments:
#    epochs: 84
#    batches_per_epoch: 300
#    batch_size: 200
#    checkpoint_folder: None
#    generation_mode: pred2rep
#    use_ensemble: True
#    ensemble_model_checkpoint_folder_paths: ['/mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/']
#    ensemble_batch_size: 160
#    ensemble_num_workers: 3
#    use_hard_predictions: True
#    use_gt_labels: True
#    pretrained_checkpoint_folder_path: None
#    labels_hidden_dim: 1024
#    embedding_dim: 512
#    transf_dec_num_memory_vecs: 10
#    transf_dec_hidden_dim: 512
#    transf_dec_nhead: 4
#    transf_dec_dim_forward: 512
#    transf_dec_num_layers: 3
#    dropout_prob: 0
#    vocab_min_freq: 10
#    use_medical_tokenization: True
#    medical_terms_frequency_filename: medical_terms_frequency__20220918_184255.pkl
#    optimizer_name: adamw
#    lr: 1e-06
#    scheduler: exp-warmup+decay+cyclicdecay
#    lr_decay: 0.76
#    lr_decay_patience: 2
#    warmup_and_decay_args: None
#    warmup_and_cosine_args: None
#    warmup_decay_and_cyclic_decay_args: 1e-6,3,4e-4,8,3e-6,4e-4,8,3e-6
#    iters_to_accumulate: 2
#    override_lr: False
#    binary_loss_name: focal+bce+wbce-c
#    focal_loss_weight: 1
#    bce_loss_weight: 1
#    wbce_loss_weight: 1
#    num_workers: 2
#    device: GPU
#    use_amp: True
#    train_mimiccxr: True
#    mimiccxr_weight: 1.0
#    mimiccxr_view_mode: chest_imagenome
#    mimiccxr_balanced_sampling_mode: balanced_chest_imagenome_global_labels_batchwise
#    mimiccxr_balanced_batch_size: 30
#    mimiccxr_qa_adapted_reports_filename: qa_adapted_reports__20220904_095810.json
#    chest_imagenome_labels_filename: imageId2labels(min_freq=100).pkl
#    chest_imagenome_label_names_filename: labels(min_freq=100).pkl
#    use_chest_imagenome_decent_images_only: True
#    save: True
#    use_gender: False
#    use_chexpert: True
#    mimiccxr_chexpert_labels_filename: chexpert_labels_per_report__20220904_113605.pkl
#    use_chest_imagenome: True
#    filter_labels: False
#    top_k_chexpert_labels: None
#    top_k_chest_imagenome_labels: None
#    label_score_threshold: None
#    debug: False
# ----- Training model from scratch ------
# Computing number of labels and ranges for ensemble ...
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/metadata.json
# ensemble_chest_imagenome_range: (0, 627)
# ensemble_chexpert_range: (627, 641)
# Computing number of labels and ranges assuming ground truth labels as input ...
# gt_chest_imagenome_range: (0, 627)
# gt_chexpert_range: (627, 641)
# ============================================================
# Precomputing sigmoid activations for ensemble ...
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/metadata.json
# ============================================================
# Model 1/1
# model_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/
# checkpoint_names = ['checkpoint_79_chou+chuc+chuc+chuc+chuc+cD+gacc+wmmp=0.6677.pt', 'checkpoint_135_chou+chuc+chuc+chuc+chuc+cD+gacc+wmmp=0.6689.pt']
# model_checkpoint_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/checkpoint_135_chou+chuc+chuc+chuc+chuc+cD+gacc+wmmp=0.6689.pt
# precomputed_chexpert_sigmoids_path = /mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/precomputed_chexpert_sigmoids(hash=340,3716123060218160099).pkl
# Precomputed sigmoids for CheXpert already exist.
# File size = 56.39 MB
# precomputed_chest_imagenome_sigmoids_path = /mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/precomputed_chest_imagenome_sigmoids(hash=347,2103260294420767687).pkl
# Precomputed sigmoids for Chest ImaGenome already exist.
# File size = 339.66 MB
# Skipping...
# precomputed_sigmoid_paths: [{'model_folder_path': '/mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/', 'chexpert_sigmoids_path': '/mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/precomputed_chexpert_sigmoids(hash=340,3716123060218160099).pkl', 'chest_imagenome_sigmoids_path': '/mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/precomputed_chest_imagenome_sigmoids(hash=347,2103260294420767687).pkl'}]
# ============================================================
# Precomputing thresholds (for hard predictions) for ensemble ...
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/metadata.json
# ============================================================
# Model 1/1
# model_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/
# checkpoint_names = ['checkpoint_79_chou+chuc+chuc+chuc+chuc+cD+gacc+wmmp=0.6677.pt', 'checkpoint_135_chou+chuc+chuc+chuc+chuc+cD+gacc+wmmp=0.6689.pt']
# model_checkpoint_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/checkpoint_135_chou+chuc+chuc+chuc+chuc+cD+gacc+wmmp=0.6689.pt
# results_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/results/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/
# get_image_transform()
#   Using bounding box aware transforms
#     Returning default transform (no augmentation)
# Calibrating thresholds on MIMIC-CXR validation set
# score_name: f1
# Thresholds for CheXpert already cached at /mnt/data/pamessina/workspaces/medvqa-workspace/results/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/thresholds_chexpert(f1).pkl
# Thresholds for Chest ImaGenome already cached at /mnt/data/pamessina/workspaces/medvqa-workspace/results/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/thresholds_chest_imagenome(f1).pkl
# precomputed_thresholds_paths: [{'chexpert': '/mnt/data/pamessina/workspaces/medvqa-workspace/results/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/thresholds_chexpert(f1).pkl', 'chest_imagenome': '/mnt/data/pamessina/workspaces/medvqa-workspace/results/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/thresholds_chest_imagenome(f1).pkl'}]
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Initializing tokenizer ...
# Loading /mnt/data/pamessina/workspaces/medvqa-workspace/cache/vocab(min_freq=10;mode=report;qa_adapted_reports__20220904_095810.json).pkl ...
# --------------------------------------------------
# 3) Creating instance of Labels2ReportModel ...
# Labels2ReportModel
#   gen_mode: pred2rep
#   vocab_size: 4833
#   embedding_dim: 512
#   num_input_labels: 641
#   labels_hidden_dim: 1024
#   num_output_labels: 641
#   transf_dec_num_memory_vecs: 10
#   transf_dec_hidden_dim: 512
#   transf_dec_nhead: 4
#   transf_dec_dim_forward: 512
#   transf_dec_num_layers: 3
#   start_idx: 1
#   dropout_prob: 0
#   support_two_label_sources: True
#   num_input_labels_2: 641
#   labels_hidden_dim_2: 1024
#   num_output_labels_2: 641
# WARNING: Unused kwargs: {'device': device(type='cuda'), 'pretrained_checkpoint_folder_path': None}
# --------------------------------------------------
# 4) Defining optimizer ...
# create_optimizer(): name = adamw
# --------------------------------------------------
# 5) Defining scheduler ...
# Using exp-warmup+decay+cyclicdecay scheduler: 1e-6,3,4e-4,8,3e-6,4e-4,8,3e-6
# 1e-06 3 0.0004 8 3e-06 0.0004 8 3e-06
# self.steps_to_restart = 8
# self.steps = -1
# self.initial_lr = 0.0004
# --------------------------------------------------
# 6) Creating trainer and validator engines ...
# Using focal+bce+wbce-c loss
# binary_loss_kwargs: {'focal_weight': 1, 'bce_weight': 1, 'wbce_weight': 1}
# --------------------------------------------------
# 7) Defining collate_batch_fn ...
# --------------------------------------------------
# 8) Creating MIMIC-CXR_Labels2ReportTrainer ...
# 227835it [00:17, 13297.66it/s]
# max_idx_count = 377110
# actual_idx_count = 239513
# ** NOTE: 137597 images were skipped because they were not in the allowed DICOM IDs
# Random report:
# <s> cardiac silhouette size mild enlarged . moderate size hiatal hernia . increased interstitial opacity diffuse , more pronounced lung base , interstitial lung disease . mild superimposed interstitial pulmonary edema not . more focal opacity right upper lobe areas infection . no pleural effusion pneumothorax . no osseous abnormality . diffuse increased interstitial opacity interstitial lung disease , component superimposed interstitial pulmonary edema not . more focal patchy opacity right upper lobe infection . moderate size hiatal hernia . no , high resolved </s>
# len(self.train_indices) = 234217
# len(self.val_indices) = 1934
# Loading CheXpert labels...
# Loading Chest Imagenome labels...
# Loading precomputed sigmoid paths for ensemble predictions...
#   Loading /mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/precomputed_chexpert_sigmoids(hash=340,3716123060218160099).pkl
#     _probs.shape = (242280, 14)
#     len(_dids) = 242280
#     _thresholds.shape = (14,)
#     _probs has been thresholded
#     Sanity checking chexpert labels
#     len(self.val_indices) = 1934
#     f1_score(_gt_labels, _pred_labels, average="micro") = 0.5885286783042394
#     f1_score(_gt_labels, _pred_labels, average="macro") = 0.48877588205948314
#   Loading /mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/precomputed_chest_imagenome_sigmoids(hash=347,2103260294420767687).pkl
#     _probs.shape = (242280, 627)
#     len(_dids) = 242280
#     _thresholds.shape = (627,)
#     _probs has been thresholded
#     Sanity checking chest_imagenome labels
#     len(self.val_indices) = 1934
#     f1_score(_gt_labels, _pred_labels, average="micro") = 0.2304808503177002
#     f1_score(_gt_labels, _pred_labels, average="macro") = 0.22673751197996303
# Done loading precomputed sigmoid paths for ensemble predictions
# Balanced sampling mode: balanced_chest_imagenome_global_labels_batchwise
# Regrouping indices by Chest Imagenome labels for balanced sampling...
# 627it [01:00, 10.36it/s]
# Global: abnormal                                , # images: 184517 (other: 49700)
# Global: lung opacity                            , # images: 154881 (other: 79336)
# Global: atelectasis                             , # images: 79106 (other: 155111)
# Global: pleural effusion                        , # images: 72076 (other: 162141)
# Global: enlarged cardiac silhouette             , # images: 57654 (other: 176563)
# Global: pulmonary edema/hazy opacity            , # images: 35280 (other: 198937)
# Global: pneumonia                               , # images: 34201 (other: 200016)
# Global: low lung volumes                        , # images: 28214 (other: 206003)
# Global: enteric tube                            , # images: 27915 (other: 206302)
# Global: vascular congestion                     , # images: 24614 (other: 209603)
# Global: endotracheal tube                       , # images: 22541 (other: 211676)
# Global: consolidation                           , # images: 17769 (other: 216448)
# Global: picc                                    , # images: 14281 (other: 219936)
# Global: pleural/parenchymal scarring            , # images: 14199 (other: 220018)
# Global: tortuous aorta                          , # images: 13462 (other: 220755)
# Global: lung lesion                             , # images: 13455 (other: 220762)
# Global: linear/patchy atelectasis               , # images: 12797 (other: 221420)
# Global: cardiac pacer and wires                 , # images: 12453 (other: 221764)
# Global: ij line                                 , # images: 12109 (other: 222108)
# Global: pneumothorax                            , # images: 10640 (other: 223577)
# Global: hyperaeration                           , # images: 10306 (other: 223911)
# Global: chest tube                              , # images: 10271 (other: 223946)
# Global: vascular calcification                  , # images: 10172 (other: 224045)
# Global: lobar/segmental collapse                , # images: 9531 (other: 224686)
# Global: enlarged hilum                          , # images: 8983 (other: 225234)
# Global: aspiration                              , # images: 8915 (other: 225302)
# Global: airspace opacity                        , # images: 8595 (other: 225622)
# Global: mass/nodule (not otherwise specified)   , # images: 7782 (other: 226435)
# Global: chest port                              , # images: 7247 (other: 226970)
# Global: rib fracture                            , # images: 7080 (other: 227137)
# Global: spinal degenerative changes             , # images: 6810 (other: 227407)
# Global: copd/emphysema                          , # images: 6553 (other: 227664)
# Global: fluid overload/heart failure            , # images: 6458 (other: 227759)
# Global: elevated hemidiaphragm                  , # images: 6412 (other: 227805)
# Global: costophrenic angle blunting             , # images: 5723 (other: 228494)
# Global: mediastinal widening                    , # images: 5070 (other: 229147)
# Global: tracheostomy tube                       , # images: 4756 (other: 229461)
# Global: subclavian line                         , # images: 3883 (other: 230334)
# Global: cabg grafts                             , # images: 3839 (other: 230378)
# Global: multiple masses/nodules                 , # images: 3730 (other: 230487)
# Global: pigtail catheter                        , # images: 3538 (other: 230679)
# Global: mediastinal displacement                , # images: 3438 (other: 230779)
# Global: subcutaneous air                        , # images: 3377 (other: 230840)
# Global: superior mediastinal mass/enlargement   , # images: 3295 (other: 230922)
# Global: scoliosis                               , # images: 3201 (other: 231016)
# Global: vascular redistribution                 , # images: 3199 (other: 231018)
# Global: spinal fracture                         , # images: 3101 (other: 231116)
# Global: hernia                                  , # images: 3025 (other: 231192)
# Global: infiltration                            , # images: 2977 (other: 231240)
# Global: prosthetic valve                        , # images: 2891 (other: 231326)
# Global: calcified nodule                        , # images: 2708 (other: 231509)
# Global: granulomatous disease                   , # images: 2423 (other: 231794)
# Global: swan-ganz catheter                      , # images: 2197 (other: 232020)
# Global: shoulder osteoarthritis                 , # images: 2178 (other: 232039)
# Global: rotated                                 , # images: 2036 (other: 232181)
# Global: interstitial lung disease               , # images: 1943 (other: 232274)
# Global: alveolar hemorrhage                     , # images: 1766 (other: 232451)
# Global: lung cancer                             , # images: 1752 (other: 232465)
# Global: bone lesion                             , # images: 1692 (other: 232525)
# Global: pericardial effusion                    , # images: 1400 (other: 232817)
# Global: increased reticular markings/ild pattern, # images: 1373 (other: 232844)
# Global: sub-diaphragmatic air                   , # images: 1234 (other: 232983)
# Global: breast/nipple shadows                   , # images: 1020 (other: 233197)
# Global: hydropneumothorax                       , # images: 954 (other: 233263)
# Global: bronchiectasis                          , # images: 905 (other: 233312)
# Global: cyst/bullae                             , # images: 874 (other: 233343)
# Global: pneumomediastinum                       , # images: 864 (other: 233353)
# Global: clavicle fracture                       , # images: 862 (other: 233355)
# Global: goiter                                  , # images: 614 (other: 233603)
# Global: intra-aortic balloon pump               , # images: 562 (other: 233655)
# Global: mediastinal drain                       , # images: 436 (other: 233781)
# Global: artifact                                , # images: 299 (other: 233918)
# Global: skin fold                               , # images: 216 (other: 234001)
# Global: aortic graft/repair                     , # images: 115 (other: 234102)
# Creating MIMIC-CXR_Labels2ReportTrainer for second label source ...
# 227835it [00:18, 12405.65it/s]
# max_idx_count = 377110
# actual_idx_count = 227835
# ** NOTE: 149275 images were skipped because they were not in the allowed DICOM IDs
# Random report:
# <s> upright . chin obscured upper lungs . remainder lungs clear . consolidation right middle lobe resolved . no large effusion . heart size . osseous structures intact . resolved pneumonia . lung apical . no pneumonia edema </s>
# len(self.train_indices) = 222758
# len(self.val_indices) = 1808
# Loading CheXpert labels...
# Loading Chest Imagenome labels...
# Balanced sampling mode: balanced_chest_imagenome_global_labels_batchwise
# Regrouping indices by Chest Imagenome labels for balanced sampling...
# 627it [00:57, 10.96it/s]
# Global: abnormal                                , # images: 168425 (other: 54333)
# Global: lung opacity                            , # images: 141722 (other: 81036)
# Global: atelectasis                             , # images: 72861 (other: 149897)
# Global: pleural effusion                        , # images: 66227 (other: 156531)
# Global: enlarged cardiac silhouette             , # images: 52931 (other: 169827)
# Global: pulmonary edema/hazy opacity            , # images: 32381 (other: 190377)
# Global: pneumonia                               , # images: 31494 (other: 191264)
# Global: low lung volumes                        , # images: 26283 (other: 196475)
# Global: enteric tube                            , # images: 24273 (other: 198485)
# Global: vascular congestion                     , # images: 22671 (other: 200087)
# Global: endotracheal tube                       , # images: 20404 (other: 202354)
# Global: consolidation                           , # images: 16184 (other: 206574)
# Global: picc                                    , # images: 12972 (other: 209786)
# Global: pleural/parenchymal scarring            , # images: 12849 (other: 209909)
# Global: tortuous aorta                          , # images: 12349 (other: 210409)
# Global: lung lesion                             , # images: 12246 (other: 210512)
# Global: linear/patchy atelectasis               , # images: 11808 (other: 210950)
# Global: cardiac pacer and wires                 , # images: 11259 (other: 211499)
# Global: ij line                                 , # images: 11065 (other: 211693)
# Global: pneumothorax                            , # images: 9708 (other: 213050)
# Global: chest tube                              , # images: 9464 (other: 213294)
# Global: vascular calcification                  , # images: 9425 (other: 213333)
# Global: hyperaeration                           , # images: 9107 (other: 213651)
# Global: lobar/segmental collapse                , # images: 8771 (other: 213987)
# Global: enlarged hilum                          , # images: 8201 (other: 214557)
# Global: aspiration                              , # images: 8152 (other: 214606)
# Global: airspace opacity                        , # images: 7878 (other: 214880)
# Global: mass/nodule (not otherwise specified)   , # images: 7127 (other: 215631)
# Global: chest port                              , # images: 6601 (other: 216157)
# Global: rib fracture                            , # images: 6353 (other: 216405)
# Global: spinal degenerative changes             , # images: 6069 (other: 216689)
# Global: fluid overload/heart failure            , # images: 5970 (other: 216788)
# Global: elevated hemidiaphragm                  , # images: 5869 (other: 216889)
# Global: copd/emphysema                          , # images: 5812 (other: 216946)
# Global: costophrenic angle blunting             , # images: 5298 (other: 217460)
# Global: mediastinal widening                    , # images: 4604 (other: 218154)
# Global: tracheostomy tube                       , # images: 4265 (other: 218493)
# Global: subclavian line                         , # images: 3502 (other: 219256)
# Global: cabg grafts                             , # images: 3433 (other: 219325)
# Global: multiple masses/nodules                 , # images: 3380 (other: 219378)
# Global: pigtail catheter                        , # images: 3240 (other: 219518)
# Global: mediastinal displacement                , # images: 3183 (other: 219575)
# Global: subcutaneous air                        , # images: 3077 (other: 219681)
# Global: superior mediastinal mass/enlargement   , # images: 2996 (other: 219762)
# Global: vascular redistribution                 , # images: 2975 (other: 219783)
# Global: scoliosis                               , # images: 2946 (other: 219812)
# Global: spinal fracture                         , # images: 2873 (other: 219885)
# Global: hernia                                  , # images: 2805 (other: 219953)
# Global: infiltration                            , # images: 2732 (other: 220026)
# Global: prosthetic valve                        , # images: 2623 (other: 220135)
# Global: calcified nodule                        , # images: 2437 (other: 220321)
# Global: granulomatous disease                   , # images: 2174 (other: 220584)
# Global: shoulder osteoarthritis                 , # images: 2016 (other: 220742)
# Global: swan-ganz catheter                      , # images: 1939 (other: 220819)
# Global: interstitial lung disease               , # images: 1817 (other: 220941)
# Global: rotated                                 , # images: 1809 (other: 220949)
# Global: alveolar hemorrhage                     , # images: 1642 (other: 221116)
# Global: lung cancer                             , # images: 1581 (other: 221177)
# Global: bone lesion                             , # images: 1523 (other: 221235)
# Global: pericardial effusion                    , # images: 1302 (other: 221456)
# Global: increased reticular markings/ild pattern, # images: 1274 (other: 221484)
# Global: sub-diaphragmatic air                   , # images: 1117 (other: 221641)
# Global: breast/nipple shadows                   , # images: 898 (other: 221860)
# Global: hydropneumothorax                       , # images: 879 (other: 221879)
# Global: bronchiectasis                          , # images: 835 (other: 221923)
# Global: pneumomediastinum                       , # images: 792 (other: 221966)
# Global: clavicle fracture                       , # images: 789 (other: 221969)
# Global: cyst/bullae                             , # images: 766 (other: 221992)
# Global: goiter                                  , # images: 565 (other: 222193)
# Global: intra-aortic balloon pump               , # images: 501 (other: 222257)
# Global: mediastinal drain                       , # images: 397 (other: 222361)
# Global: artifact                                , # images: 286 (other: 222472)
# Global: skin fold                               , # images: 195 (other: 222563)
# Global: aortic graft/repair                     , # images: 101 (other: 222657)
# --------------------------------------------------
# 9) Creating dataloaders ...
# len(_train_dataloaders) = 2
# len(_val_dataloaders) = 2
# _train_weights = [1.0, 1.0]
# merged_dataset_name = mim+mim(gt)
# --------------------------------------------------
# 10) Attaching metrics, losses, timer and events to engines ...
# --------------------------------------------------
# 11) Defining learning rate scheduler handler ...
# --------------------------------------------------
# 12) Defining checkpoint folder path ...
# checkpoint_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/report_gen/20230506_133503_mim+mim(gt)_Labels2ReportModel(641,(2nd:641),10,TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512)))_dws=1.0,1.0
# metadata saved to /mnt/data/pamessina/workspaces/medvqa-workspace/models/report_gen/20230506_133503_mim+mim(gt)_Labels2ReportModel(641,(2nd:641),10,TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512)))_dws=1.0,1.0/metadata.json
# --------------------------------------------------
# 13) Defining log_metrics_handler ...
# MetricsLogger :: we'll be logging to /mnt/data/pamessina/workspaces/medvqa-workspace/models/report_gen/20230506_133503_mim+mim(gt)_Labels2ReportModel(641,(2nd:641),10,TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512)))_dws=1.0,1.0/metrics_logs.csv
# --------------------------------------------------
# 14) Running trainer engine ...
# ---- Epoch 1/84
# (1) Training stage (lr = 0.000001) ...
# loss 8.54683, wmdcmp 0.00619, wmdcmp_gt 0.00593, report_loss 8.30695, 175.22 secs
# (2) Validation stage ...
# wmdcmp 0.00549, wmdcmp_gt 0.00410, cD 0.00037, cD_gt 0.00048, 31.15 secs
# ---- Epoch 2/84
# (1) Training stage (lr = 0.000007) ...
# loss 8.07560, wmdcmp 0.00052, wmdcmp_gt 0.00056, report_loss 6.80643, 161.60 secs
# (2) Validation stage ...
# wmdcmp 0.00437, wmdcmp_gt 0.01158, cD 0.00270, cD_gt 0.00118, 30.66 secs
# ---- Epoch 3/84
# (1) Training stage (lr = 0.000054) ...
# loss 6.01239, wmdcmp 0.05924, wmdcmp_gt 0.05983, report_loss 4.55046, 150.68 secs
# (2) Validation stage ...
# wmdcmp 0.04255, wmdcmp_gt 0.04657, cD 0.01115, cD_gt 0.01917, 28.68 secs
# ---- Epoch 4/84
# (1) Training stage (lr = 0.000400) ...
# loss 3.83750, wmdcmp 0.16654, wmdcmp_gt 0.17070, report_loss 2.96999, 140.65 secs
# (2) Validation stage ...
# wmdcmp 0.11896, wmdcmp_gt 0.12896, cD 0.32106, cD_gt 0.34594, 28.56 secs
# ---- Epoch 5/84
# (1) Training stage (lr = 0.000217) ...
# loss 2.55268, wmdcmp 0.21452, wmdcmp_gt 0.22716, report_loss 2.44073, 130.53 secs
# (2) Validation stage ...
# wmdcmp 0.12112, wmdcmp_gt 0.14731, cD 0.34277, cD_gt 0.45625, 28.38 secs
# ---- Epoch 6/84
# (1) Training stage (lr = 0.000118) ...
# loss 2.34194, wmdcmp 0.22780, wmdcmp_gt 0.24452, report_loss 2.31728, 124.55 secs
# (2) Validation stage ...
# wmdcmp 0.14024, wmdcmp_gt 0.15855, cD 0.41281, cD_gt 0.53781, 28.20 secs
# ---- Epoch 7/84
# (1) Training stage (lr = 0.000064) ...
# loss 2.36828, wmdcmp 0.23281, wmdcmp_gt 0.25061, report_loss 2.27035, 124.02 secs
# (2) Validation stage ...
# wmdcmp 0.14025, wmdcmp_gt 0.16558, cD 0.42103, cD_gt 0.60580, 28.29 secs
# ---- Epoch 8/84
# (1) Training stage (lr = 0.000035) ...
# loss 2.31809, wmdcmp 0.23415, wmdcmp_gt 0.25536, report_loss 2.23954, 124.21 secs
# (2) Validation stage ...
# wmdcmp 0.13812, wmdcmp_gt 0.16513, cD 0.38765, cD_gt 0.61016, 28.29 secs
# ---- Epoch 9/84
# (1) Training stage (lr = 0.000019) ...
# loss 2.44657, wmdcmp 0.23695, wmdcmp_gt 0.25711, report_loss 2.22719, 124.04 secs
# (2) Validation stage ...
# wmdcmp 0.13453, wmdcmp_gt 0.16489, cD 0.38012, cD_gt 0.62117, 28.46 secs
# ---- Epoch 10/84
# (1) Training stage (lr = 0.000010) ...
# loss 2.18061, wmdcmp 0.23758, wmdcmp_gt 0.25738, report_loss 2.22505, 124.98 secs
# (2) Validation stage ...
# wmdcmp 0.13888, wmdcmp_gt 0.16540, cD 0.40162, cD_gt 0.61616, 28.37 secs
# ---- Epoch 11/84
# (1) Training stage (lr = 0.000006) ...
# loss 2.36825, wmdcmp 0.23896, wmdcmp_gt 0.25954, report_loss 2.21313, 124.20 secs
# (2) Validation stage ...
# wmdcmp 0.13744, wmdcmp_gt 0.15977, cD 0.38934, cD_gt 0.56305, 28.40 secs
# ---- Epoch 12/84
# (1) Training stage (lr = 0.000003) ...
# loss 2.28965, wmdcmp 0.23665, wmdcmp_gt 0.26011, report_loss 2.21725, 123.93 secs
# (2) Validation stage ...
# wmdcmp 0.13676, wmdcmp_gt 0.16583, cD 0.38669, cD_gt 0.62594, 28.35 secs
# ---- Epoch 13/84
# (1) Training stage (lr = 0.000400) ...
# loss 2.35053, wmdcmp 0.23762, wmdcmp_gt 0.26402, report_loss 2.18978, 124.43 secs
# (2) Validation stage ...
# wmdcmp 0.13406, wmdcmp_gt 0.17158, cD 0.43196, cD_gt 0.68476, 27.94 secs
# ---- Epoch 14/84
# (1) Training stage (lr = 0.000199) ...
# loss 2.17055, wmdcmp 0.25008, wmdcmp_gt 0.27842, report_loss 2.09568, 122.19 secs
# (2) Validation stage ...
# wmdcmp 0.13523, wmdcmp_gt 0.18033, cD 0.40717, cD_gt 0.69141, 28.14 secs
# ---- Epoch 15/84
# (1) Training stage (lr = 0.000099) ...
# loss 2.16483, wmdcmp 0.25619, wmdcmp_gt 0.28672, report_loss 2.05107, 125.40 secs
# (2) Validation stage ...
# wmdcmp 0.13058, wmdcmp_gt 0.17356, cD 0.37624, cD_gt 0.65640, 28.47 secs
# ---- Epoch 16/84
# (1) Training stage (lr = 0.000049) ...
# loss 2.13789, wmdcmp 0.25870, wmdcmp_gt 0.29136, report_loss 2.02694, 127.76 secs
# (2) Validation stage ...
# wmdcmp 0.12902, wmdcmp_gt 0.17391, cD 0.37193, cD_gt 0.66642, 28.41 secs
# ---- Epoch 17/84
# (1) Training stage (lr = 0.000024) ...
# loss 2.18599, wmdcmp 0.25982, wmdcmp_gt 0.29056, report_loss 2.02432, 120.59 secs
# (2) Validation stage ...
# wmdcmp 0.13070, wmdcmp_gt 0.17299, cD 0.37337, cD_gt 0.66088, 30.09 secs
# ---- Epoch 18/84
# (1) Training stage (lr = 0.000012) ...
# loss 2.04846, wmdcmp 0.26206, wmdcmp_gt 0.29281, report_loss 2.01244, 123.37 secs
# (2) Validation stage ...
# wmdcmp 0.13009, wmdcmp_gt 0.17439, cD 0.37653, cD_gt 0.67357, 28.26 secs
# ---- Epoch 19/84
# (1) Training stage (lr = 0.000006) ...
# loss 2.12762, wmdcmp 0.26294, wmdcmp_gt 0.29421, report_loss 2.00817, 122.55 secs
# (2) Validation stage ...
# wmdcmp 0.13257, wmdcmp_gt 0.17515, cD 0.38276, cD_gt 0.67103, 28.29 secs
# ---- Epoch 20/84
# (1) Training stage (lr = 0.000003) ...
# loss 1.96433, wmdcmp 0.26127, wmdcmp_gt 0.29498, report_loss 2.01019, 124.85 secs
# (2) Validation stage ...
# wmdcmp 0.13315, wmdcmp_gt 0.17458, cD 0.38476, cD_gt 0.66774, 28.66 secs
# ---- Epoch 21/84
# (1) Training stage (lr = 0.000400) ...
# loss 2.15686, wmdcmp 0.25768, wmdcmp_gt 0.29001, report_loss 2.02474, 125.14 secs
# (2) Validation stage ...
# wmdcmp 0.13578, wmdcmp_gt 0.17322, cD 0.42638, cD_gt 0.65447, 28.59 secs
# ---- Epoch 22/84
# (1) Training stage (lr = 0.000199) ...
# loss 2.05253, wmdcmp 0.26541, wmdcmp_gt 0.30208, report_loss 1.96699, 122.28 secs
# (2) Validation stage ...
# wmdcmp 0.14150, wmdcmp_gt 0.17758, cD 0.42530, cD_gt 0.68176, 28.31 secs
# ---- Epoch 23/84
# (1) Training stage (lr = 0.000099) ...
# loss 2.10845, wmdcmp 0.27124, wmdcmp_gt 0.30689, report_loss 1.93373, 123.11 secs
# (2) Validation stage ...
# wmdcmp 0.13328, wmdcmp_gt 0.18909, cD 0.38358, cD_gt 0.76045, 28.09 secs
# ---- Epoch 24/84
# (1) Training stage (lr = 0.000049) ...
# loss 2.04624, wmdcmp 0.27217, wmdcmp_gt 0.31085, report_loss 1.91318, 123.85 secs
# (2) Validation stage ...
# wmdcmp 0.13654, wmdcmp_gt 0.19505, cD 0.42182, cD_gt 0.81627, 28.29 secs
# ---- Epoch 25/84
# (1) Training stage (lr = 0.000024) ...
# loss 1.98717, wmdcmp 0.27498, wmdcmp_gt 0.31394, report_loss 1.90493, 123.74 secs
# (2) Validation stage ...
# wmdcmp 0.13167, wmdcmp_gt 0.18380, cD 0.38722, cD_gt 0.74517, 28.31 secs
# ---- Epoch 26/84
# (1) Training stage (lr = 0.000012) ...
# loss 2.07316, wmdcmp 0.27595, wmdcmp_gt 0.31387, report_loss 1.90368, 123.39 secs
# (2) Validation stage ...
# wmdcmp 0.13182, wmdcmp_gt 0.19689, cD 0.39444, cD_gt 0.83771, 28.02 secs
# ---- Epoch 27/84
# (1) Training stage (lr = 0.000006) ...
# loss 2.01192, wmdcmp 0.27639, wmdcmp_gt 0.31445, report_loss 1.89464, 122.24 secs
# (2) Validation stage ...
# wmdcmp 0.13233, wmdcmp_gt 0.19575, cD 0.39604, cD_gt 0.82483, 28.34 secs
# ---- Epoch 28/84
# (1) Training stage (lr = 0.000003) ...
# loss 2.01159, wmdcmp 0.27645, wmdcmp_gt 0.31303, report_loss 1.89838, 121.19 secs
# (2) Validation stage ...
# wmdcmp 0.13139, wmdcmp_gt 0.19531, cD 0.39677, cD_gt 0.82573, 28.31 secs
# ---- Epoch 29/84
# (1) Training stage (lr = 0.000400) ...
# loss 1.90367, wmdcmp 0.26942, wmdcmp_gt 0.30704, report_loss 1.93409, 123.21 secs
# (2) Validation stage ...
# wmdcmp 0.13345, wmdcmp_gt 0.18474, cD 0.38262, cD_gt 0.71400, 28.51 secs
# ---- Epoch 30/84
# (1) Training stage (lr = 0.000199) ...
# loss 1.96944, wmdcmp 0.27601, wmdcmp_gt 0.31692, report_loss 1.88581, 123.24 secs
# (2) Validation stage ...
# wmdcmp 0.13510, wmdcmp_gt 0.18932, cD 0.39128, cD_gt 0.76636, 28.18 secs
# ---- Epoch 31/84
# (1) Training stage (lr = 0.000099) ...
# loss 1.90478, wmdcmp 0.28030, wmdcmp_gt 0.32143, report_loss 1.85621, 125.75 secs
# (2) Validation stage ...
# wmdcmp 0.13253, wmdcmp_gt 0.19505, cD 0.38310, cD_gt 0.79417, 30.35 secs
# ---- Epoch 32/84
# (1) Training stage (lr = 0.000049) ...
# loss 1.85075, wmdcmp 0.28443, wmdcmp_gt 0.32359, report_loss 1.84151, 126.94 secs
# (2) Validation stage ...
# wmdcmp 0.13179, wmdcmp_gt 0.19690, cD 0.38145, cD_gt 0.81470, 28.05 secs
# ---- Epoch 33/84
# (1) Training stage (lr = 0.000024) ...
# loss 1.90065, wmdcmp 0.28624, wmdcmp_gt 0.32544, report_loss 1.83076, 122.60 secs
# (2) Validation stage ...
# wmdcmp 0.13098, wmdcmp_gt 0.20368, cD 0.37881, cD_gt 0.88815, 28.22 secs
# ---- Epoch 34/84
# (1) Training stage (lr = 0.000012) ...
# loss 1.92220, wmdcmp 0.28523, wmdcmp_gt 0.32886, report_loss 1.82355, 127.16 secs
# (2) Validation stage ...
# wmdcmp 0.13349, wmdcmp_gt 0.20325, cD 0.39931, cD_gt 0.88052, 28.20 secs
# ---- Epoch 35/84
# (1) Training stage (lr = 0.000006) ...
# loss 1.85107, wmdcmp 0.28656, wmdcmp_gt 0.32770, report_loss 1.82023, 122.66 secs
# (2) Validation stage ...
# wmdcmp 0.13171, wmdcmp_gt 0.19522, cD 0.38256, cD_gt 0.79969, 28.31 secs
# ---- Epoch 36/84
# (1) Training stage (lr = 0.000003) ...
# loss 1.87105, wmdcmp 0.28520, wmdcmp_gt 0.32686, report_loss 1.82467, 121.96 secs
# (2) Validation stage ...
# wmdcmp 0.13247, wmdcmp_gt 0.19746, cD 0.39260, cD_gt 0.80629, 27.72 secs
# ---- Epoch 37/84
# (1) Training stage (lr = 0.000400) ...
# loss 1.82224, wmdcmp 0.27720, wmdcmp_gt 0.31983, report_loss 1.86368, 122.76 secs
# (2) Validation stage ...
# wmdcmp 0.12492, wmdcmp_gt 0.18887, cD 0.35533, cD_gt 0.75560, 27.96 secs
# ---- Epoch 38/84
# (1) Training stage (lr = 0.000199) ...
# loss 1.92758, wmdcmp 0.28491, wmdcmp_gt 0.32681, report_loss 1.82659, 121.00 secs
# (2) Validation stage ...
# wmdcmp 0.12951, wmdcmp_gt 0.19026, cD 0.37472, cD_gt 0.76046, 28.14 secs
# ---- Epoch 39/84
# (1) Training stage (lr = 0.000099) ...
# loss 1.77448, wmdcmp 0.29031, wmdcmp_gt 0.33174, report_loss 1.79459, 121.48 secs
# (2) Validation stage ...
# wmdcmp 0.12939, wmdcmp_gt 0.19085, cD 0.37859, cD_gt 0.80966, 28.38 secs
# ---- Epoch 40/84
# (1) Training stage (lr = 0.000049) ...
# loss 1.86207, wmdcmp 0.29111, wmdcmp_gt 0.33418, report_loss 1.78911, 122.74 secs
# (2) Validation stage ...
# wmdcmp 0.12712, wmdcmp_gt 0.19375, cD 0.37635, cD_gt 0.78272, 28.33 secs
# ---- Epoch 41/84
# (1) Training stage (lr = 0.000024) ...
# loss 1.79635, wmdcmp 0.29345, wmdcmp_gt 0.33620, report_loss 1.77303, 125.90 secs
# (2) Validation stage ...
# wmdcmp 0.13558, wmdcmp_gt 0.19860, cD 0.41871, cD_gt 0.82062, 28.25 secs
# ---- Epoch 42/84
# (1) Training stage (lr = 0.000012) ...
# loss 1.75180, wmdcmp 0.29397, wmdcmp_gt 0.33759, report_loss 1.77085, 127.63 secs
# (2) Validation stage ...
# wmdcmp 0.13843, wmdcmp_gt 0.20204, cD 0.41101, cD_gt 0.84472, 28.17 secs
# ---- Epoch 43/84
# (1) Training stage (lr = 0.000006) ...
# loss 1.79761, wmdcmp 0.29533, wmdcmp_gt 0.33634, report_loss 1.76222, 125.78 secs
# (2) Validation stage ...
# wmdcmp 0.13651, wmdcmp_gt 0.20350, cD 0.40880, cD_gt 0.88502, 28.17 secs
# ---- Epoch 44/84
# (1) Training stage (lr = 0.000003) ...
# loss 1.94348, wmdcmp 0.29342, wmdcmp_gt 0.33687, report_loss 1.76754, 122.11 secs
# (2) Validation stage ...
# wmdcmp 0.13571, wmdcmp_gt 0.19973, cD 0.41123, cD_gt 0.82236, 28.19 secs
# ---- Epoch 45/84
# (1) Training stage (lr = 0.000400) ...
# loss 1.88537, wmdcmp 0.28237, wmdcmp_gt 0.32847, report_loss 1.81409, 121.28 secs
# (2) Validation stage ...
# wmdcmp 0.13492, wmdcmp_gt 0.19732, cD 0.39871, cD_gt 0.79334, 28.18 secs
# ---- Epoch 46/84
# (1) Training stage (lr = 0.000199) ...
# loss 1.87329, wmdcmp 0.29121, wmdcmp_gt 0.33450, report_loss 1.77788, 121.24 secs
# (2) Validation stage ...
# wmdcmp 0.13273, wmdcmp_gt 0.19518, cD 0.39522, cD_gt 0.82297, 30.34 secs
# ---- Epoch 47/84
# (1) Training stage (lr = 0.000099) ...
# loss 1.79730, wmdcmp 0.29534, wmdcmp_gt 0.34093, report_loss 1.74629, 126.85 secs
# (2) Validation stage ...
# wmdcmp 0.12996, wmdcmp_gt 0.19691, cD 0.39702, cD_gt 0.80973, 28.35 secs
# ---- Epoch 48/84
# (1) Training stage (lr = 0.000049) ...
# loss 1.82714, wmdcmp 0.29838, wmdcmp_gt 0.34253, report_loss 1.73997, 126.09 secs
# (2) Validation stage ...
# wmdcmp 0.13484, wmdcmp_gt 0.20110, cD 0.38979, cD_gt 0.84102, 28.34 secs
# ---- Epoch 49/84
# (1) Training stage (lr = 0.000024) ...
# loss 1.86340, wmdcmp 0.29925, wmdcmp_gt 0.34650, report_loss 1.72686, 121.30 secs
# (2) Validation stage ...
# wmdcmp 0.13203, wmdcmp_gt 0.19538, cD 0.39429, cD_gt 0.83383, 28.39 secs
# ---- Epoch 50/84
# (1) Training stage (lr = 0.000012) ...
# loss 1.88205, wmdcmp 0.29951, wmdcmp_gt 0.34670, report_loss 1.72601, 121.58 secs
# (2) Validation stage ...
# wmdcmp 0.13345, wmdcmp_gt 0.20366, cD 0.39814, cD_gt 0.84958, 28.20 secs
# ---- Epoch 51/84
# (1) Training stage (lr = 0.000006) ...
# loss 1.83958, wmdcmp 0.29973, wmdcmp_gt 0.34541, report_loss 1.72469, 120.97 secs
# (2) Validation stage ...
# wmdcmp 0.13619, wmdcmp_gt 0.19682, cD 0.41841, cD_gt 0.83005, 28.15 secs
# ---- Epoch 52/84
# (1) Training stage (lr = 0.000003) ...
# loss 1.90538, wmdcmp 0.30135, wmdcmp_gt 0.34679, report_loss 1.72090, 121.86 secs
# (2) Validation stage ...
# wmdcmp 0.13289, wmdcmp_gt 0.19741, cD 0.39301, cD_gt 0.83944, 28.27 secs
# ---- Epoch 53/84
# (1) Training stage (lr = 0.000400) ...
# loss 1.79784, wmdcmp 0.28979, wmdcmp_gt 0.33560, report_loss 1.77229, 119.87 secs
# (2) Validation stage ...
# wmdcmp 0.13917, wmdcmp_gt 0.20509, cD 0.43159, cD_gt 0.83044, 28.39 secs
# ---- Epoch 54/84
# (1) Training stage (lr = 0.000199) ...
# loss 1.99484, wmdcmp 0.29564, wmdcmp_gt 0.34213, report_loss 1.74053, 121.91 secs
# (2) Validation stage ...
# wmdcmp 0.12792, wmdcmp_gt 0.20168, cD 0.36745, cD_gt 0.85723, 28.12 secs
# ---- Epoch 55/84
# (1) Training stage (lr = 0.000099) ...
# loss 1.72565, wmdcmp 0.30035, wmdcmp_gt 0.34817, report_loss 1.71064, 121.38 secs
# (2) Validation stage ...
# wmdcmp 0.13317, wmdcmp_gt 0.20627, cD 0.38138, cD_gt 0.86539, 28.27 secs
# ---- Epoch 56/84
# (1) Training stage (lr = 0.000049) ...
# loss 1.88510, wmdcmp 0.30131, wmdcmp_gt 0.35038, report_loss 1.69911, 121.57 secs
# (2) Validation stage ...
# wmdcmp 0.13061, wmdcmp_gt 0.19957, cD 0.38114, cD_gt 0.84121, 28.29 secs
# ---- Epoch 57/84
# (1) Training stage (lr = 0.000024) ...
# loss 1.62123, wmdcmp 0.30347, wmdcmp_gt 0.35105, report_loss 1.69526, 126.29 secs
# (2) Validation stage ...
# wmdcmp 0.13154, wmdcmp_gt 0.20545, cD 0.39356, cD_gt 0.86850, 28.10 secs
# ---- Epoch 58/84
# (1) Training stage (lr = 0.000012) ...
# loss 1.92340, wmdcmp 0.30494, wmdcmp_gt 0.35317, report_loss 1.68427, 124.90 secs
# (2) Validation stage ...
# wmdcmp 0.13298, wmdcmp_gt 0.20484, cD 0.40058, cD_gt 0.86724, 24.78 secs
# ---- Epoch 59/84
# (1) Training stage (lr = 0.000006) ...
# loss 1.72972, wmdcmp 0.30786, wmdcmp_gt 0.35370, report_loss 1.68296, 122.01 secs
# (2) Validation stage ...
# wmdcmp 0.13223, wmdcmp_gt 0.20536, cD 0.38221, cD_gt 0.85962, 28.26 secs
# ---- Epoch 60/84
# (1) Training stage (lr = 0.000003) ...
# loss 1.88835, wmdcmp 0.30650, wmdcmp_gt 0.35408, report_loss 1.68292, 126.13 secs
# (2) Validation stage ...
# wmdcmp 0.13312, wmdcmp_gt 0.20582, cD 0.38754, cD_gt 0.87779, 28.26 secs
# ---- Epoch 61/84
# (1) Training stage (lr = 0.000400) ...
# loss 1.78721, wmdcmp 0.29450, wmdcmp_gt 0.34393, report_loss 1.73296, 122.41 secs
# (2) Validation stage ...
# wmdcmp 0.12945, wmdcmp_gt 0.19405, cD 0.38349, cD_gt 0.79469, 30.47 secs
# ---- Epoch 62/84
# (1) Training stage (lr = 0.000199) ...
# loss 1.87792, wmdcmp 0.30193, wmdcmp_gt 0.35113, report_loss 1.70139, 122.37 secs
# (2) Validation stage ...
# wmdcmp 0.12610, wmdcmp_gt 0.19516, cD 0.35931, cD_gt 0.80666, 28.66 secs
# ---- Epoch 63/84
# (1) Training stage (lr = 0.000099) ...
# loss 1.74274, wmdcmp 0.30686, wmdcmp_gt 0.35358, report_loss 1.68020, 127.82 secs
# (2) Validation stage ...
# wmdcmp 0.13788, wmdcmp_gt 0.21309, cD 0.42667, cD_gt 0.93797, 28.21 secs
# ---- Epoch 64/84
# (1) Training stage (lr = 0.000049) ...
# loss 1.77144, wmdcmp 0.30681, wmdcmp_gt 0.35890, report_loss 1.65953, 126.16 secs
# (2) Validation stage ...
# wmdcmp 0.13472, wmdcmp_gt 0.20557, cD 0.41860, cD_gt 0.87056, 28.30 secs
# ---- Epoch 65/84
# (1) Training stage (lr = 0.000024) ...
# loss 1.69484, wmdcmp 0.30891, wmdcmp_gt 0.35888, report_loss 1.65779, 120.81 secs
# (2) Validation stage ...
# wmdcmp 0.13181, wmdcmp_gt 0.20909, cD 0.40686, cD_gt 0.90758, 27.97 secs
# ---- Epoch 66/84
# (1) Training stage (lr = 0.000012) ...
# loss 1.64136, wmdcmp 0.31122, wmdcmp_gt 0.36096, report_loss 1.64872, 122.16 secs
# (2) Validation stage ...
# wmdcmp 0.13378, wmdcmp_gt 0.20801, cD 0.41240, cD_gt 0.90723, 28.29 secs
# ---- Epoch 67/84
# (1) Training stage (lr = 0.000006) ...
# loss 1.69549, wmdcmp 0.31041, wmdcmp_gt 0.35972, report_loss 1.65184, 122.24 secs
# (2) Validation stage ...
# wmdcmp 0.13057, wmdcmp_gt 0.20326, cD 0.38028, cD_gt 0.90114, 28.41 secs
# ---- Epoch 68/84
# (1) Training stage (lr = 0.000003) ...
# loss 1.80405, wmdcmp 0.31071, wmdcmp_gt 0.35992, report_loss 1.64992, 122.95 secs
# (2) Validation stage ...
# wmdcmp 0.13021, wmdcmp_gt 0.20329, cD 0.38383, cD_gt 0.89914, 28.26 secs
# ---- Epoch 69/84
# (1) Training stage (lr = 0.000400) ...
# loss 1.77754, wmdcmp 0.30007, wmdcmp_gt 0.34607, report_loss 1.70768, 123.22 secs
# (2) Validation stage ...
# wmdcmp 0.12716, wmdcmp_gt 0.19606, cD 0.36864, cD_gt 0.79544, 28.11 secs
# ---- Epoch 70/84
# (1) Training stage (lr = 0.000199) ...
# loss 1.79397, wmdcmp 0.30554, wmdcmp_gt 0.35518, report_loss 1.67304, 126.00 secs
# (2) Validation stage ...
# wmdcmp 0.13358, wmdcmp_gt 0.19967, cD 0.42481, cD_gt 0.87940, 28.48 secs
# ---- Epoch 71/84
# (1) Training stage (lr = 0.000099) ...
# loss 1.76879, wmdcmp 0.31092, wmdcmp_gt 0.35928, report_loss 1.64905, 124.72 secs
# (2) Validation stage ...
# wmdcmp 0.13037, wmdcmp_gt 0.19983, cD 0.37914, cD_gt 0.87738, 28.69 secs
# ---- Epoch 72/84
# (1) Training stage (lr = 0.000049) ...
# loss 1.72390, wmdcmp 0.31470, wmdcmp_gt 0.36441, report_loss 1.63075, 125.85 secs
# (2) Validation stage ...
# wmdcmp 0.12997, wmdcmp_gt 0.20092, cD 0.37859, cD_gt 0.87627, 28.40 secs
# ---- Epoch 73/84
# (1) Training stage (lr = 0.000024) ...
# loss 1.77581, wmdcmp 0.31608, wmdcmp_gt 0.36470, report_loss 1.62636, 124.28 secs
# (2) Validation stage ...
# wmdcmp 0.13103, wmdcmp_gt 0.20205, cD 0.39010, cD_gt 0.87232, 28.63 secs
# ---- Epoch 74/84
# (1) Training stage (lr = 0.000012) ...
# loss 1.68633, wmdcmp 0.31634, wmdcmp_gt 0.36645, report_loss 1.62068, 123.91 secs
# (2) Validation stage ...
# wmdcmp 0.13433, wmdcmp_gt 0.21245, cD 0.40623, cD_gt 0.91709, 28.37 secs
# ---- Epoch 75/84
# (1) Training stage (lr = 0.000006) ...
# loss 1.70743, wmdcmp 0.31653, wmdcmp_gt 0.36581, report_loss 1.62010, 122.33 secs
# (2) Validation stage ...
# wmdcmp 0.13217, wmdcmp_gt 0.21224, cD 0.39963, cD_gt 0.91779, 30.35 secs
# ---- Epoch 76/84
# (1) Training stage (lr = 0.000003) ...
# loss 1.51322, wmdcmp 0.31664, wmdcmp_gt 0.36568, report_loss 1.61762, 123.65 secs
# (2) Validation stage ...
# wmdcmp 0.13274, wmdcmp_gt 0.21230, cD 0.39982, cD_gt 0.92322, 28.34 secs
# ---- Epoch 77/84
# (1) Training stage (lr = 0.000400) ...
# loss 1.72567, wmdcmp 0.30535, wmdcmp_gt 0.35344, report_loss 1.67594, 124.03 secs
# (2) Validation stage ...
# wmdcmp 0.13719, wmdcmp_gt 0.20357, cD 0.41293, cD_gt 0.86745, 28.31 secs
# ---- Epoch 78/84
# (1) Training stage (lr = 0.000199) ...
# loss 1.72553, wmdcmp 0.31286, wmdcmp_gt 0.35937, report_loss 1.64268, 124.41 secs
# (2) Validation stage ...
# wmdcmp 0.12954, wmdcmp_gt 0.20239, cD 0.41900, cD_gt 0.81987, 28.45 secs
# ---- Epoch 79/84
# (1) Training stage (lr = 0.000099) ...
# loss 1.64784, wmdcmp 0.31391, wmdcmp_gt 0.36367, report_loss 1.62526, 123.42 secs
# (2) Validation stage ...
# wmdcmp 0.13432, wmdcmp_gt 0.20877, cD 0.41745, cD_gt 0.90695, 28.05 secs
# ---- Epoch 80/84
# (1) Training stage (lr = 0.000049) ...
# loss 1.59395, wmdcmp 0.31833, wmdcmp_gt 0.36917, report_loss 1.60423, 123.62 secs
# (2) Validation stage ...
# wmdcmp 0.13254, wmdcmp_gt 0.21060, cD 0.39375, cD_gt 0.90041, 28.40 secs
# ---- Epoch 81/84
# (1) Training stage (lr = 0.000024) ...
# loss 1.80799, wmdcmp 0.31978, wmdcmp_gt 0.37082, report_loss 1.59813, 125.13 secs
# (2) Validation stage ...
# wmdcmp 0.13075, wmdcmp_gt 0.21262, cD 0.39088, cD_gt 0.92132, 28.46 secs
# ---- Epoch 82/84
# (1) Training stage (lr = 0.000012) ...
# loss 1.72417, wmdcmp 0.32055, wmdcmp_gt 0.37024, report_loss 1.59516, 124.46 secs
# (2) Validation stage ...
# wmdcmp 0.13005, wmdcmp_gt 0.21099, cD 0.38165, cD_gt 0.91157, 28.46 secs
# ---- Epoch 83/84
# (1) Training stage (lr = 0.000006) ...
# loss 1.58925, wmdcmp 0.32278, wmdcmp_gt 0.37173, report_loss 1.59204, 124.37 secs
# (2) Validation stage ...
# wmdcmp 0.13080, wmdcmp_gt 0.21204, cD 0.38987, cD_gt 0.92281, 28.45 secs
# ---- Epoch 84/84
# (1) Training stage (lr = 0.000003) ...
# loss 1.70059, wmdcmp 0.32085, wmdcmp_gt 0.37247, report_loss 1.58902, 126.89 secs
# (2) Validation stage ...
# wmdcmp 0.13076, wmdcmp_gt 0.21160, cD 0.39107, cD_gt 0.91948, 28.73 secs

# %%
# !/home/pamessina/venv2/bin/python ../train_labels2report.py \
    --checkpoint-folder "models/report_gen/20230506_133503_mim+mim(gt)_Labels2ReportModel(641,(2nd:641),10,TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512)))_dws=1.0,1.0" \
    --epochs 84 \
    --batches-per-epoch 300 \
    --batch-size 200 \
    --num-workers 2 \
    --iters-to-accumulate 2 \
    --override-lr \
    --optimizer-name "adamw" \
    --scheduler "exp-warmup+decay+cyclicdecay" \
    --lr 1e-6 \
    --warmup-decay-and-cyclic-decay-args "1e-6,3,5e-4,8,1e-5,5e-4,8,1e-5" \
    --use-amp \
    --save
# Out:
# script's arguments:
#    epochs: 84
#    batches_per_epoch: 300
#    batch_size: 200
#    checkpoint_folder: models/report_gen/20230506_133503_mim+mim(gt)_Labels2ReportModel(641,(2nd:641),10,TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512)))_dws=1.0,1.0
#    generation_mode: pred2rep
#    use_ensemble: False
#    ensemble_model_checkpoint_folder_paths: None
#    ensemble_batch_size: None
#    ensemble_num_workers: None
#    use_hard_predictions: False
#    use_gt_labels: False
#    pretrained_checkpoint_folder_path: None
#    labels_hidden_dim: 256
#    embedding_dim: 256
#    transf_dec_num_memory_vecs: 1
#    transf_dec_hidden_dim: 256
#    transf_dec_nhead: 2
#    transf_dec_dim_forward: 256
#    transf_dec_num_layers: 2
#    dropout_prob: 0
#    vocab_min_freq: 10
#    use_medical_tokenization: False
#    medical_terms_frequency_filename: None
#    optimizer_name: adamw
#    lr: 1e-06
#    scheduler: exp-warmup+decay+cyclicdecay
#    lr_decay: 0.76
#    lr_decay_patience: 2
#    warmup_and_decay_args: None
#    warmup_and_cosine_args: None
#    warmup_decay_and_cyclic_decay_args: 1e-6,3,5e-4,8,1e-5,5e-4,8,1e-5
#    iters_to_accumulate: 2
#    override_lr: True
#    binary_loss_name: bce
#    focal_loss_weight: 1
#    bce_loss_weight: 1
#    wbce_loss_weight: 1
#    num_workers: 2
#    device: GPU
#    use_amp: True
#    train_mimiccxr: False
#    mimiccxr_weight: 1
#    mimiccxr_view_mode: any_single
#    mimiccxr_balanced_sampling_mode: None
#    mimiccxr_balanced_batch_size: None
#    mimiccxr_qa_adapted_reports_filename: None
#    chest_imagenome_labels_filename: None
#    chest_imagenome_label_names_filename: None
#    use_chest_imagenome_decent_images_only: False
#    save: True
#    use_gender: False
#    use_chexpert: False
#    mimiccxr_chexpert_labels_filename: None
#    use_chest_imagenome: False
#    filter_labels: False
#    top_k_chexpert_labels: None
#    top_k_chest_imagenome_labels: None
#    label_score_threshold: None
#    debug: False
# ----- Resuming training ------
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/report_gen/20230506_133503_mim+mim(gt)_Labels2ReportModel(641,(2nd:641),10,TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512)))_dws=1.0,1.0/metadata.json
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Initializing tokenizer ...
# Loading /mnt/data/pamessina/workspaces/medvqa-workspace/cache/vocab(min_freq=10;mode=report;qa_adapted_reports__20220904_095810.json).pkl ...
# --------------------------------------------------
# 3) Creating instance of Labels2ReportModel ...
# Labels2ReportModel
#   gen_mode: pred2rep
#   vocab_size: 4833
#   embedding_dim: 512
#   num_input_labels: 641
#   labels_hidden_dim: 1024
#   num_output_labels: 641
#   transf_dec_num_memory_vecs: 10
#   transf_dec_hidden_dim: 512
#   transf_dec_nhead: 4
#   transf_dec_dim_forward: 512
#   transf_dec_num_layers: 3
#   start_idx: 1
#   dropout_prob: 0
#   support_two_label_sources: True
#   num_input_labels_2: 641
#   labels_hidden_dim_2: 1024
#   num_output_labels_2: 641
# WARNING: Unused kwargs: {'device': device(type='cuda'), 'pretrained_checkpoint_folder_path': None}
# --------------------------------------------------
# 4) Defining optimizer ...
# create_optimizer(): name = adamw
# --------------------------------------------------
# 5) Defining scheduler ...
# Using exp-warmup+decay+cyclicdecay scheduler: 1e-6,3,5e-4,8,1e-5,5e-4,8,1e-5
# 1e-06 3 0.0005 8 1e-05 0.0005 8 1e-05
# self.steps_to_restart = 8
# self.steps = -1
# self.initial_lr = 0.0005
# --------------------------------------------------
# 6) Creating trainer and validator engines ...
# Using focal+bce+wbce-c loss
# binary_loss_kwargs: {'focal_weight': 1, 'bce_weight': 1, 'wbce_weight': 1}
# --------------------------------------------------
# 7) Defining collate_batch_fn ...
# --------------------------------------------------
# 8) Creating MIMIC-CXR_Labels2ReportTrainer ...
# 227835it [00:17, 12702.96it/s]
# max_idx_count = 377110
# actual_idx_count = 239513
# ** NOTE: 137597 images were skipped because they were not in the allowed DICOM IDs
# Random report:
# <s> frontal lateral clear , expanded lungs no pleural effusion pneumothorax . cardiac silhouette . hilar prominent lymphadenopathy . hilar lymphadenopathy , no abnormality </s>
# len(self.train_indices) = 234217
# len(self.val_indices) = 1934
# Loading CheXpert labels...
# Loading Chest Imagenome labels...
# Loading precomputed sigmoid paths for ensemble predictions...
#   Loading /mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/precomputed_chexpert_sigmoids(hash=340,3716123060218160099).pkl
#     _probs.shape = (242280, 14)
#     len(_dids) = 242280
#     _thresholds.shape = (14,)
#     _probs has been thresholded
#     Sanity checking chexpert labels
#     len(self.val_indices) = 1934
#     f1_score(_gt_labels, _pred_labels, average="micro") = 0.5885286783042394
#     f1_score(_gt_labels, _pred_labels, average="macro") = 0.48877588205948314
#   Loading /mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/precomputed_chest_imagenome_sigmoids(hash=347,2103260294420767687).pkl
#     _probs.shape = (242280, 627)
#     len(_dids) = 242280
#     _thresholds.shape = (627,)
#     _probs has been thresholded
#     Sanity checking chest_imagenome labels
#     len(self.val_indices) = 1934
#     f1_score(_gt_labels, _pred_labels, average="micro") = 0.2304808503177002
#     f1_score(_gt_labels, _pred_labels, average="macro") = 0.22673751197996303
# Done loading precomputed sigmoid paths for ensemble predictions
# Balanced sampling mode: balanced_chest_imagenome_global_labels_batchwise
# Regrouping indices by Chest Imagenome labels for balanced sampling...
# 627it [00:25, 25.02it/s]
# Global: abnormal                                , # images: 184517 (other: 49700)
# Global: lung opacity                            , # images: 154881 (other: 79336)
# Global: atelectasis                             , # images: 79106 (other: 155111)
# Global: pleural effusion                        , # images: 72076 (other: 162141)
# Global: enlarged cardiac silhouette             , # images: 57654 (other: 176563)
# Global: pulmonary edema/hazy opacity            , # images: 35280 (other: 198937)
# Global: pneumonia                               , # images: 34201 (other: 200016)
# Global: low lung volumes                        , # images: 28214 (other: 206003)
# Global: enteric tube                            , # images: 27915 (other: 206302)
# Global: vascular congestion                     , # images: 24614 (other: 209603)
# Global: endotracheal tube                       , # images: 22541 (other: 211676)
# Global: consolidation                           , # images: 17769 (other: 216448)
# Global: picc                                    , # images: 14281 (other: 219936)
# Global: pleural/parenchymal scarring            , # images: 14199 (other: 220018)
# Global: tortuous aorta                          , # images: 13462 (other: 220755)
# Global: lung lesion                             , # images: 13455 (other: 220762)
# Global: linear/patchy atelectasis               , # images: 12797 (other: 221420)
# Global: cardiac pacer and wires                 , # images: 12453 (other: 221764)
# Global: ij line                                 , # images: 12109 (other: 222108)
# Global: pneumothorax                            , # images: 10640 (other: 223577)
# Global: hyperaeration                           , # images: 10306 (other: 223911)
# Global: chest tube                              , # images: 10271 (other: 223946)
# Global: vascular calcification                  , # images: 10172 (other: 224045)
# Global: lobar/segmental collapse                , # images: 9531 (other: 224686)
# Global: enlarged hilum                          , # images: 8983 (other: 225234)
# Global: aspiration                              , # images: 8915 (other: 225302)
# Global: airspace opacity                        , # images: 8595 (other: 225622)
# Global: mass/nodule (not otherwise specified)   , # images: 7782 (other: 226435)
# Global: chest port                              , # images: 7247 (other: 226970)
# Global: rib fracture                            , # images: 7080 (other: 227137)
# Global: spinal degenerative changes             , # images: 6810 (other: 227407)
# Global: copd/emphysema                          , # images: 6553 (other: 227664)
# Global: fluid overload/heart failure            , # images: 6458 (other: 227759)
# Global: elevated hemidiaphragm                  , # images: 6412 (other: 227805)
# Global: costophrenic angle blunting             , # images: 5723 (other: 228494)
# Global: mediastinal widening                    , # images: 5070 (other: 229147)
# Global: tracheostomy tube                       , # images: 4756 (other: 229461)
# Global: subclavian line                         , # images: 3883 (other: 230334)
# Global: cabg grafts                             , # images: 3839 (other: 230378)
# Global: multiple masses/nodules                 , # images: 3730 (other: 230487)
# Global: pigtail catheter                        , # images: 3538 (other: 230679)
# Global: mediastinal displacement                , # images: 3438 (other: 230779)
# Global: subcutaneous air                        , # images: 3377 (other: 230840)
# Global: superior mediastinal mass/enlargement   , # images: 3295 (other: 230922)
# Global: scoliosis                               , # images: 3201 (other: 231016)
# Global: vascular redistribution                 , # images: 3199 (other: 231018)
# Global: spinal fracture                         , # images: 3101 (other: 231116)
# Global: hernia                                  , # images: 3025 (other: 231192)
# Global: infiltration                            , # images: 2977 (other: 231240)
# Global: prosthetic valve                        , # images: 2891 (other: 231326)
# Global: calcified nodule                        , # images: 2708 (other: 231509)
# Global: granulomatous disease                   , # images: 2423 (other: 231794)
# Global: swan-ganz catheter                      , # images: 2197 (other: 232020)
# Global: shoulder osteoarthritis                 , # images: 2178 (other: 232039)
# Global: rotated                                 , # images: 2036 (other: 232181)
# Global: interstitial lung disease               , # images: 1943 (other: 232274)
# Global: alveolar hemorrhage                     , # images: 1766 (other: 232451)
# Global: lung cancer                             , # images: 1752 (other: 232465)
# Global: bone lesion                             , # images: 1692 (other: 232525)
# Global: pericardial effusion                    , # images: 1400 (other: 232817)
# Global: increased reticular markings/ild pattern, # images: 1373 (other: 232844)
# Global: sub-diaphragmatic air                   , # images: 1234 (other: 232983)
# Global: breast/nipple shadows                   , # images: 1020 (other: 233197)
# Global: hydropneumothorax                       , # images: 954 (other: 233263)
# Global: bronchiectasis                          , # images: 905 (other: 233312)
# Global: cyst/bullae                             , # images: 874 (other: 233343)
# Global: pneumomediastinum                       , # images: 864 (other: 233353)
# Global: clavicle fracture                       , # images: 862 (other: 233355)
# Global: goiter                                  , # images: 614 (other: 233603)
# Global: intra-aortic balloon pump               , # images: 562 (other: 233655)
# Global: mediastinal drain                       , # images: 436 (other: 233781)
# Global: artifact                                , # images: 299 (other: 233918)
# Global: skin fold                               , # images: 216 (other: 234001)
# Global: aortic graft/repair                     , # images: 115 (other: 234102)
# Creating MIMIC-CXR_Labels2ReportTrainer for second label source ...
# 227835it [00:19, 11968.83it/s]
# max_idx_count = 377110
# actual_idx_count = 227835
# ** NOTE: 149275 images were skipped because they were not in the allowed DICOM IDs
# Random report:
# <s> lungs clear . mediastinal cardiac contours normal . no pleural effusion pneumothorax . no tuberculosis </s>
# len(self.train_indices) = 222758
# len(self.val_indices) = 1808
# Loading CheXpert labels...
# Loading Chest Imagenome labels...
# Balanced sampling mode: balanced_chest_imagenome_global_labels_batchwise
# Regrouping indices by Chest Imagenome labels for balanced sampling...
# 627it [01:04,  9.77it/s]
# Global: abnormal                                , # images: 168425 (other: 54333)
# Global: lung opacity                            , # images: 141722 (other: 81036)
# Global: atelectasis                             , # images: 72861 (other: 149897)
# Global: pleural effusion                        , # images: 66227 (other: 156531)
# Global: enlarged cardiac silhouette             , # images: 52931 (other: 169827)
# Global: pulmonary edema/hazy opacity            , # images: 32381 (other: 190377)
# Global: pneumonia                               , # images: 31494 (other: 191264)
# Global: low lung volumes                        , # images: 26283 (other: 196475)
# Global: enteric tube                            , # images: 24273 (other: 198485)
# Global: vascular congestion                     , # images: 22671 (other: 200087)
# Global: endotracheal tube                       , # images: 20404 (other: 202354)
# Global: consolidation                           , # images: 16184 (other: 206574)
# Global: picc                                    , # images: 12972 (other: 209786)
# Global: pleural/parenchymal scarring            , # images: 12849 (other: 209909)
# Global: tortuous aorta                          , # images: 12349 (other: 210409)
# Global: lung lesion                             , # images: 12246 (other: 210512)
# Global: linear/patchy atelectasis               , # images: 11808 (other: 210950)
# Global: cardiac pacer and wires                 , # images: 11259 (other: 211499)
# Global: ij line                                 , # images: 11065 (other: 211693)
# Global: pneumothorax                            , # images: 9708 (other: 213050)
# Global: chest tube                              , # images: 9464 (other: 213294)
# Global: vascular calcification                  , # images: 9425 (other: 213333)
# Global: hyperaeration                           , # images: 9107 (other: 213651)
# Global: lobar/segmental collapse                , # images: 8771 (other: 213987)
# Global: enlarged hilum                          , # images: 8201 (other: 214557)
# Global: aspiration                              , # images: 8152 (other: 214606)
# Global: airspace opacity                        , # images: 7878 (other: 214880)
# Global: mass/nodule (not otherwise specified)   , # images: 7127 (other: 215631)
# Global: chest port                              , # images: 6601 (other: 216157)
# Global: rib fracture                            , # images: 6353 (other: 216405)
# Global: spinal degenerative changes             , # images: 6069 (other: 216689)
# Global: fluid overload/heart failure            , # images: 5970 (other: 216788)
# Global: elevated hemidiaphragm                  , # images: 5869 (other: 216889)
# Global: copd/emphysema                          , # images: 5812 (other: 216946)
# Global: costophrenic angle blunting             , # images: 5298 (other: 217460)
# Global: mediastinal widening                    , # images: 4604 (other: 218154)
# Global: tracheostomy tube                       , # images: 4265 (other: 218493)
# Global: subclavian line                         , # images: 3502 (other: 219256)
# Global: cabg grafts                             , # images: 3433 (other: 219325)
# Global: multiple masses/nodules                 , # images: 3380 (other: 219378)
# Global: pigtail catheter                        , # images: 3240 (other: 219518)
# Global: mediastinal displacement                , # images: 3183 (other: 219575)
# Global: subcutaneous air                        , # images: 3077 (other: 219681)
# Global: superior mediastinal mass/enlargement   , # images: 2996 (other: 219762)
# Global: vascular redistribution                 , # images: 2975 (other: 219783)
# Global: scoliosis                               , # images: 2946 (other: 219812)
# Global: spinal fracture                         , # images: 2873 (other: 219885)
# Global: hernia                                  , # images: 2805 (other: 219953)
# Global: infiltration                            , # images: 2732 (other: 220026)
# Global: prosthetic valve                        , # images: 2623 (other: 220135)
# Global: calcified nodule                        , # images: 2437 (other: 220321)
# Global: granulomatous disease                   , # images: 2174 (other: 220584)
# Global: shoulder osteoarthritis                 , # images: 2016 (other: 220742)
# Global: swan-ganz catheter                      , # images: 1939 (other: 220819)
# Global: interstitial lung disease               , # images: 1817 (other: 220941)
# Global: rotated                                 , # images: 1809 (other: 220949)
# Global: alveolar hemorrhage                     , # images: 1642 (other: 221116)
# Global: lung cancer                             , # images: 1581 (other: 221177)
# Global: bone lesion                             , # images: 1523 (other: 221235)
# Global: pericardial effusion                    , # images: 1302 (other: 221456)
# Global: increased reticular markings/ild pattern, # images: 1274 (other: 221484)
# Global: sub-diaphragmatic air                   , # images: 1117 (other: 221641)
# Global: breast/nipple shadows                   , # images: 898 (other: 221860)
# Global: hydropneumothorax                       , # images: 879 (other: 221879)
# Global: bronchiectasis                          , # images: 835 (other: 221923)
# Global: pneumomediastinum                       , # images: 792 (other: 221966)
# Global: clavicle fracture                       , # images: 789 (other: 221969)
# Global: cyst/bullae                             , # images: 766 (other: 221992)
# Global: goiter                                  , # images: 565 (other: 222193)
# Global: intra-aortic balloon pump               , # images: 501 (other: 222257)
# Global: mediastinal drain                       , # images: 397 (other: 222361)
# Global: artifact                                , # images: 286 (other: 222472)
# Global: skin fold                               , # images: 195 (other: 222563)
# Global: aortic graft/repair                     , # images: 101 (other: 222657)
# --------------------------------------------------
# 9) Creating dataloaders ...
# len(_train_dataloaders) = 2
# len(_val_dataloaders) = 2
# _train_weights = [1.0, 1.0]
# merged_dataset_name = mim+mim(gt)
# --------------------------------------------------
# 10) Attaching metrics, losses, timer and events to engines ...
# --------------------------------------------------
# 11) Defining learning rate scheduler handler ...
# checkpoint_names = ['checkpoint_63_cD+wmdcmp=0.1784.pt']
# --------------------------------------------------
# 12) Loading model from checkpoint ...
# checkpoint_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/report_gen/20230506_133503_mim+mim(gt)_Labels2ReportModel(641,(2nd:641),10,TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512)))_dws=1.0,1.0/checkpoint_63_cD+wmdcmp=0.1784.pt
# Loading model and epoch only
# Checkpoint successfully loaded!
# --------------------------------------------------
# 13) Defining log_metrics_handler ...
# MetricsLogger :: we'll be logging to /mnt/data/pamessina/workspaces/medvqa-workspace/models/report_gen/20230506_133503_mim+mim(gt)_Labels2ReportModel(641,(2nd:641),10,TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512)))_dws=1.0,1.0/metrics_logs.csv
# --------------------------------------------------
# 14) Running trainer engine ...
# ---- Epoch 64/147
# (1) Training stage (lr = 0.000001) ...
# loss 1.80260, wmdcmp 0.31052, wmdcmp_gt 0.35782, report_loss 1.66230, 126.76 secs
# (2) Validation stage ...
# wmdcmp 0.13795, wmdcmp_gt 0.21461, cD 0.43537, cD_gt 0.94727, 27.94 secs
# ---- Epoch 65/147
# (1) Training stage (lr = 0.000008) ...
# loss 1.60827, wmdcmp 0.31122, wmdcmp_gt 0.35680, report_loss 1.65955, 124.39 secs
# (2) Validation stage ...
# wmdcmp 0.13506, wmdcmp_gt 0.20974, cD 0.41199, cD_gt 0.92607, 28.20 secs
# ---- Epoch 66/147
# (1) Training stage (lr = 0.000063) ...
# loss 1.75301, wmdcmp 0.31041, wmdcmp_gt 0.35770, report_loss 1.65720, 124.41 secs
# (2) Validation stage ...
# wmdcmp 0.14206, wmdcmp_gt 0.20174, cD 0.44100, cD_gt 0.86526, 28.30 secs
# ---- Epoch 67/147
# (1) Training stage (lr = 0.000500) ...
# loss 1.64578, wmdcmp 0.29635, wmdcmp_gt 0.34408, report_loss 1.71876, 122.44 secs
# (2) Validation stage ...
# wmdcmp 0.13886, wmdcmp_gt 0.20326, cD 0.42629, cD_gt 0.83406, 28.29 secs
# ---- Epoch 68/147
# (1) Training stage (lr = 0.000307) ...
# loss 1.81208, wmdcmp 0.30271, wmdcmp_gt 0.35228, report_loss 1.68760, 122.15 secs
# (2) Validation stage ...
# wmdcmp 0.13912, wmdcmp_gt 0.20956, cD 0.43687, cD_gt 0.94070, 28.09 secs
# ---- Epoch 69/147
# (1) Training stage (lr = 0.000188) ...
# loss 1.69761, wmdcmp 0.31147, wmdcmp_gt 0.35730, report_loss 1.65846, 123.78 secs
# (2) Validation stage ...
# wmdcmp 0.13454, wmdcmp_gt 0.20906, cD 0.41372, cD_gt 0.90923, 28.10 secs
# ---- Epoch 70/147
# (1) Training stage (lr = 0.000115) ...
# loss 1.76332, wmdcmp 0.31334, wmdcmp_gt 0.36259, report_loss 1.63699, 124.82 secs
# (2) Validation stage ...
# wmdcmp 0.13244, wmdcmp_gt 0.20839, cD 0.37723, cD_gt 0.92751, 28.14 secs
# ---- Epoch 71/147
# (1) Training stage (lr = 0.000071) ...
# loss 1.75448, wmdcmp 0.31464, wmdcmp_gt 0.36404, report_loss 1.62671, 125.93 secs
# (2) Validation stage ...
# wmdcmp 0.13379, wmdcmp_gt 0.20307, cD 0.39343, cD_gt 0.88635, 28.27 secs
# ---- Epoch 72/147
# (1) Training stage (lr = 0.000043) ...
# loss 1.69983, wmdcmp 0.31620, wmdcmp_gt 0.36483, report_loss 1.61938, 123.60 secs
# (2) Validation stage ...
# wmdcmp 0.13123, wmdcmp_gt 0.21059, cD 0.38568, cD_gt 0.92901, 28.17 secs
# ---- Epoch 73/147
# (1) Training stage (lr = 0.000027) ...
# loss 1.62244, wmdcmp 0.31743, wmdcmp_gt 0.36851, report_loss 1.60893, 123.88 secs
# (2) Validation stage ...
# wmdcmp 0.13162, wmdcmp_gt 0.21571, cD 0.41644, cD_gt 0.98436, 28.27 secs
# ---- Epoch 74/147
# (1) Training stage (lr = 0.000016) ...
# loss 1.74891, wmdcmp 0.31884, wmdcmp_gt 0.36934, report_loss 1.60964, 122.46 secs
# (2) Validation stage ...
# wmdcmp 0.13154, wmdcmp_gt 0.20262, cD 0.38999, cD_gt 0.88379, 28.37 secs
# ---- Epoch 75/147
# (1) Training stage (lr = 0.000010) ...
# loss 1.73056, wmdcmp 0.31756, wmdcmp_gt 0.37032, report_loss 1.60602, 123.94 secs
# (2) Validation stage ...
# wmdcmp 0.13442, wmdcmp_gt 0.20911, cD 0.40483, cD_gt 0.91172, 28.21 secs
# ---- Epoch 76/147
# (1) Training stage (lr = 0.000500) ...
# loss 1.70101, wmdcmp 0.30294, wmdcmp_gt 0.35213, report_loss 1.67682, 122.98 secs
# (2) Validation stage ...
# wmdcmp 0.13040, wmdcmp_gt 0.19666, cD 0.38023, cD_gt 0.83485, 30.86 secs
# ---- Epoch 77/147
# (1) Training stage (lr = 0.000286) ...
# loss 1.76513, wmdcmp 0.30959, wmdcmp_gt 0.35862, report_loss 1.64736, 122.02 secs
# (2) Validation stage ...
# wmdcmp 0.12973, wmdcmp_gt 0.20042, cD 0.37742, cD_gt 0.84689, 28.24 secs
# ---- Epoch 78/147
# (1) Training stage (lr = 0.000164) ...
# loss 1.82984, wmdcmp 0.31516, wmdcmp_gt 0.36743, report_loss 1.61438, 122.17 secs
# (2) Validation stage ...
# wmdcmp 0.12905, wmdcmp_gt 0.19871, cD 0.40580, cD_gt 0.86368, 28.61 secs
# ---- Epoch 79/147
# (1) Training stage (lr = 0.000094) ...
# loss 1.72484, wmdcmp 0.31940, wmdcmp_gt 0.37024, report_loss 1.59531, 122.80 secs
# (2) Validation stage ...
# wmdcmp 0.13770, wmdcmp_gt 0.21241, cD 0.42870, cD_gt 0.92621, 28.06 secs
# ---- Epoch 80/147
# (1) Training stage (lr = 0.000053) ...
# loss 1.76546, wmdcmp 0.32305, wmdcmp_gt 0.37169, report_loss 1.58488, 122.22 secs
# (2) Validation stage ...
# wmdcmp 0.13313, wmdcmp_gt 0.21115, cD 0.39798, cD_gt 0.89329, 27.93 secs
# ---- Epoch 81/147
# (1) Training stage (lr = 0.000031) ...
# loss 1.71975, wmdcmp 0.32219, wmdcmp_gt 0.37407, report_loss 1.57862, 121.54 secs
# (2) Validation stage ...
# wmdcmp 0.12817, wmdcmp_gt 0.21291, cD 0.39285, cD_gt 0.95826, 28.14 secs
# ---- Epoch 82/147
# (1) Training stage (lr = 0.000017) ...
# loss 1.68012, wmdcmp 0.32540, wmdcmp_gt 0.37324, report_loss 1.57504, 127.08 secs
# (2) Validation stage ...
# wmdcmp 0.13155, wmdcmp_gt 0.20554, cD 0.38790, cD_gt 0.89215, 28.54 secs
# ---- Epoch 83/147
# (1) Training stage (lr = 0.000010) ...
# loss 1.48540, wmdcmp 0.32517, wmdcmp_gt 0.37858, report_loss 1.56505, 123.07 secs
# (2) Validation stage ...
# wmdcmp 0.12798, wmdcmp_gt 0.20264, cD 0.38113, cD_gt 0.87864, 28.29 secs
# ---- Epoch 84/147
# (1) Training stage (lr = 0.000500) ...
# loss 1.74275, wmdcmp 0.30863, wmdcmp_gt 0.36055, report_loss 1.63937, 126.25 secs
# (2) Validation stage ...
# wmdcmp 0.13142, wmdcmp_gt 0.20797, cD 0.40267, cD_gt 0.94768, 28.58 secs
# ---- Epoch 85/147
# (1) Training stage (lr = 0.000286) ...
# loss 1.65436, wmdcmp 0.31466, wmdcmp_gt 0.36427, report_loss 1.61727, 124.96 secs
# (2) Validation stage ...
# wmdcmp 0.12700, wmdcmp_gt 0.19975, cD 0.39377, cD_gt 0.84636, 29.54 secs
# ---- Epoch 86/147
# (1) Training stage (lr = 0.000164) ...
# loss 1.75944, wmdcmp 0.32235, wmdcmp_gt 0.37221, report_loss 1.58191, 124.62 secs
# (2) Validation stage ...
# wmdcmp 0.12537, wmdcmp_gt 0.20097, cD 0.37112, cD_gt 0.89998, 29.83 secs
# ---- Epoch 87/147
# (1) Training stage (lr = 0.000094) ...
# loss 1.60569, wmdcmp 0.32479, wmdcmp_gt 0.37488, report_loss 1.57100, 128.04 secs
# (2) Validation stage ...
# wmdcmp 0.12590, wmdcmp_gt 0.20380, cD 0.38490, cD_gt 0.88529, 29.68 secs
# ---- Epoch 88/147
# (1) Training stage (lr = 0.000053) ...
# loss 1.71512, wmdcmp 0.32749, wmdcmp_gt 0.37836, report_loss 1.55795, 127.62 secs
# (2) Validation stage ...
# wmdcmp 0.13532, wmdcmp_gt 0.20592, cD 0.40104, cD_gt 0.91845, 26.14 secs
# ---- Epoch 89/147
# (1) Training stage (lr = 0.000031) ...
# loss 1.53498, wmdcmp 0.32766, wmdcmp_gt 0.38094, report_loss 1.54775, 124.54 secs
# (2) Validation stage ...
# wmdcmp 0.13062, wmdcmp_gt 0.20584, cD 0.38356, cD_gt 0.91371, 30.11 secs
# ---- Epoch 90/147
# (1) Training stage (lr = 0.000017) ...
# loss 1.69870, wmdcmp 0.33103, wmdcmp_gt 0.38205, report_loss 1.54196, 124.09 secs
# (2) Validation stage ...
# wmdcmp 0.13209, wmdcmp_gt 0.21560, cD 0.38700, cD_gt 0.96093, 30.33 secs
# ---- Epoch 91/147
# (1) Training stage (lr = 0.000010) ...
# loss 1.61131, wmdcmp 0.32944, wmdcmp_gt 0.38275, report_loss 1.54339, 124.30 secs
# (2) Validation stage ...
# wmdcmp 0.12959, wmdcmp_gt 0.21355, cD 0.36901, cD_gt 0.93258, 31.88 secs
# ---- Epoch 92/147
# (1) Training stage (lr = 0.000500) ...
# loss 1.63965, wmdcmp 0.31006, wmdcmp_gt 0.36504, report_loss 1.61740, 128.64 secs
# (2) Validation stage ...
# wmdcmp 0.13517, wmdcmp_gt 0.20871, cD 0.41594, cD_gt 0.91498, 30.02 secs
# ---- Epoch 93/147
# (1) Training stage (lr = 0.000286) ...
# loss 1.69544, wmdcmp 0.31880, wmdcmp_gt 0.37157, report_loss 1.58800, 126.63 secs
# (2) Validation stage ...
# wmdcmp 0.13755, wmdcmp_gt 0.20763, cD 0.42866, cD_gt 0.88129, 29.49 secs
# ---- Epoch 94/147
# (1) Training stage (lr = 0.000164) ...
# loss 1.69859, wmdcmp 0.32417, wmdcmp_gt 0.37771, report_loss 1.56133, 125.46 secs
# (2) Validation stage ...
# wmdcmp 0.13886, wmdcmp_gt 0.21810, cD 0.43554, cD_gt 0.95459, 30.13 secs
# ---- Epoch 95/147
# (1) Training stage (lr = 0.000094) ...
# loss 1.66274, wmdcmp 0.32942, wmdcmp_gt 0.38096, report_loss 1.54008, 125.60 secs
# (2) Validation stage ...
# wmdcmp 0.12663, wmdcmp_gt 0.20335, cD 0.36121, cD_gt 0.88117, 30.04 secs
# ---- Epoch 96/147
# (1) Training stage (lr = 0.000053) ...
# loss 1.64152, wmdcmp 0.33292, wmdcmp_gt 0.38520, report_loss 1.52315, 125.45 secs
# (2) Validation stage ...
# wmdcmp 0.13331, wmdcmp_gt 0.21301, cD 0.40012, cD_gt 0.94082, 30.04 secs
# ---- Epoch 97/147
# (1) Training stage (lr = 0.000031) ...
# loss 1.65457, wmdcmp 0.33305, wmdcmp_gt 0.38560, report_loss 1.51884, 124.99 secs
# (2) Validation stage ...
# wmdcmp 0.13342, wmdcmp_gt 0.21107, cD 0.40370, cD_gt 0.92510, 30.02 secs
# ---- Epoch 98/147
# (1) Training stage (lr = 0.000017) ...
# loss 1.62128, wmdcmp 0.33512, wmdcmp_gt 0.38633, report_loss 1.51667, 124.38 secs
# (2) Validation stage ...
# wmdcmp 0.12752, wmdcmp_gt 0.21044, cD 0.37497, cD_gt 0.91693, 30.39 secs
# ---- Epoch 99/147
# (1) Training stage (lr = 0.000010) ...
# loss 1.69625, wmdcmp 0.33552, wmdcmp_gt 0.38728, report_loss 1.51282, 125.87 secs
# (2) Validation stage ...
# wmdcmp 0.13452, wmdcmp_gt 0.21297, cD 0.41606, cD_gt 0.93466, 30.29 secs
# ---- Epoch 100/147
# (1) Training stage (lr = 0.000500) ...
# loss 1.56493, wmdcmp 0.31875, wmdcmp_gt 0.37045, report_loss 1.58498, 128.43 secs
# (2) Validation stage ...
# wmdcmp 0.13680, wmdcmp_gt 0.21597, cD 0.42051, cD_gt 0.94049, 30.49 secs
# ---- Epoch 101/147
# (1) Training stage (lr = 0.000286) ...
# loss 1.76412, wmdcmp 0.32297, wmdcmp_gt 0.37624, report_loss 1.56278, 125.08 secs
# (2) Validation stage ...
# wmdcmp 0.12863, wmdcmp_gt 0.20820, cD 0.38739, cD_gt 0.89239, 30.03 secs
# ---- Epoch 102/147
# (1) Training stage (lr = 0.000164) ...
# loss 1.59747, wmdcmp 0.33063, wmdcmp_gt 0.38469, report_loss 1.52699, 125.09 secs
# (2) Validation stage ...
# wmdcmp 0.13486, wmdcmp_gt 0.21111, cD 0.42283, cD_gt 0.90655, 30.25 secs
# ---- Epoch 103/147
# (1) Training stage (lr = 0.000094) ...
# loss 1.62955, wmdcmp 0.33519, wmdcmp_gt 0.38837, report_loss 1.51125, 128.84 secs
# (2) Validation stage ...
# wmdcmp 0.13945, wmdcmp_gt 0.20839, cD 0.41914, cD_gt 0.92422, 30.31 secs
# ---- Epoch 104/147
# (1) Training stage (lr = 0.000053) ...
# loss 1.53635, wmdcmp 0.33642, wmdcmp_gt 0.38864, report_loss 1.50183, 124.91 secs
# (2) Validation stage ...
# wmdcmp 0.12477, wmdcmp_gt 0.20781, cD 0.37936, cD_gt 0.92287, 30.27 secs
# ---- Epoch 105/147
# (1) Training stage (lr = 0.000031) ...
# loss 1.56613, wmdcmp 0.33872, wmdcmp_gt 0.39101, report_loss 1.49467, 125.87 secs
# (2) Validation stage ...
# wmdcmp 0.13549, wmdcmp_gt 0.21377, cD 0.41788, cD_gt 0.94717, 31.28 secs
# ---- Epoch 106/147
# (1) Training stage (lr = 0.000017) ...
# loss 1.55708, wmdcmp 0.34003, wmdcmp_gt 0.39312, report_loss 1.48568, 127.12 secs
# (2) Validation stage ...
# wmdcmp 0.12998, wmdcmp_gt 0.21433, cD 0.39348, cD_gt 0.95212, 30.10 secs
# ---- Epoch 107/147
# (1) Training stage (lr = 0.000010) ...
# loss 1.70850, wmdcmp 0.33788, wmdcmp_gt 0.39549, report_loss 1.48901, 128.12 secs
# (2) Validation stage ...
# wmdcmp 0.12753, wmdcmp_gt 0.21384, cD 0.37074, cD_gt 0.94747, 30.75 secs
# ---- Epoch 108/147
# (1) Training stage (lr = 0.000500) ...
# loss 1.58508, wmdcmp 0.32053, wmdcmp_gt 0.37358, report_loss 1.56425, 125.77 secs
# (2) Validation stage ...
# wmdcmp 0.11985, wmdcmp_gt 0.20742, cD 0.36239, cD_gt 0.91219, 30.40 secs
# ---- Epoch 109/147
# (1) Training stage (lr = 0.000286) ...
# loss 1.70049, wmdcmp 0.32612, wmdcmp_gt 0.38012, report_loss 1.53959, 124.06 secs
# (2) Validation stage ...
# wmdcmp 0.12691, wmdcmp_gt 0.20769, cD 0.38032, cD_gt 0.87638, 30.04 secs
# ---- Epoch 110/147
# (1) Training stage (lr = 0.000164) ...
# loss 1.60453, wmdcmp 0.33405, wmdcmp_gt 0.38633, report_loss 1.50943, 124.24 secs
# (2) Validation stage ...
# wmdcmp 0.12928, wmdcmp_gt 0.20474, cD 0.39476, cD_gt 0.89947, 30.10 secs
# ---- Epoch 111/147
# (1) Training stage (lr = 0.000094) ...
# loss 1.60491, wmdcmp 0.33718, wmdcmp_gt 0.39038, report_loss 1.49616, 128.00 secs
# (2) Validation stage ...
# wmdcmp 0.13175, wmdcmp_gt 0.21388, cD 0.38540, cD_gt 0.92251, 30.13 secs
# ---- Epoch 112/147
# (1) Training stage (lr = 0.000053) ...
# loss 1.60082, wmdcmp 0.34066, wmdcmp_gt 0.39616, report_loss 1.47570, 124.89 secs
# (2) Validation stage ...
# wmdcmp 0.12967, wmdcmp_gt 0.21528, cD 0.39312, cD_gt 0.97709, 29.91 secs
# ---- Epoch 113/147
# (1) Training stage (lr = 0.000031) ...
# loss 1.71360, wmdcmp 0.34363, wmdcmp_gt 0.39519, report_loss 1.47119, 124.30 secs
# (2) Validation stage ...
# wmdcmp 0.13431, wmdcmp_gt 0.21702, cD 0.42711, cD_gt 1.00527, 30.27 secs
# ---- Epoch 114/147
# (1) Training stage (lr = 0.000017) ...
# loss 1.46509, wmdcmp 0.34465, wmdcmp_gt 0.39746, report_loss 1.46484, 125.53 secs
# (2) Validation stage ...
# wmdcmp 0.13078, wmdcmp_gt 0.21476, cD 0.39100, cD_gt 0.96394, 30.04 secs
# ---- Epoch 115/147
# (1) Training stage (lr = 0.000010) ...
# loss 1.66720, wmdcmp 0.34450, wmdcmp_gt 0.39679, report_loss 1.46642, 125.21 secs
# (2) Validation stage ...
# wmdcmp 0.13056, wmdcmp_gt 0.20784, cD 0.40041, cD_gt 0.93656, 30.06 secs
# ---- Epoch 116/147
# (1) Training stage (lr = 0.000500) ...
# loss 1.50662, wmdcmp 0.32322, wmdcmp_gt 0.37933, report_loss 1.54207, 126.10 secs
# (2) Validation stage ...
# wmdcmp 0.12829, wmdcmp_gt 0.20972, cD 0.41712, cD_gt 0.94365, 30.71 secs
# ---- Epoch 117/147
# (1) Training stage (lr = 0.000286) ...
# loss 1.74686, wmdcmp 0.33014, wmdcmp_gt 0.38505, report_loss 1.51649, 126.29 secs
# (2) Validation stage ...
# wmdcmp 0.11995, wmdcmp_gt 0.20211, cD 0.37427, cD_gt 0.90472, 30.58 secs
# ---- Epoch 118/147
# (1) Training stage (lr = 0.000164) ...
# loss 1.57996, wmdcmp 0.33743, wmdcmp_gt 0.39193, report_loss 1.48742, 126.00 secs
# (2) Validation stage ...
# wmdcmp 0.13455, wmdcmp_gt 0.20407, cD 0.41210, cD_gt 0.89984, 29.94 secs
# ---- Epoch 119/147
# (1) Training stage (lr = 0.000094) ...
# loss 1.58622, wmdcmp 0.34427, wmdcmp_gt 0.39463, report_loss 1.46950, 126.28 secs
# (2) Validation stage ...
# wmdcmp 0.12988, wmdcmp_gt 0.20609, cD 0.39335, cD_gt 0.92772, 30.26 secs
# ---- Epoch 120/147
# (1) Training stage (lr = 0.000053) ...
# loss 1.36694, wmdcmp 0.34545, wmdcmp_gt 0.39993, report_loss 1.45403, 125.36 secs
# (2) Validation stage ...
# wmdcmp 0.13057, wmdcmp_gt 0.21554, cD 0.41527, cD_gt 0.98821, 31.99 secs
# ---- Epoch 121/147
# (1) Training stage (lr = 0.000031) ...
# loss 1.66556, wmdcmp 0.34776, wmdcmp_gt 0.39841, report_loss 1.45012, 130.37 secs
# (2) Validation stage ...
# wmdcmp 0.13286, wmdcmp_gt 0.21371, cD 0.39644, cD_gt 0.93227, 30.22 secs
# ---- Epoch 122/147
# (1) Training stage (lr = 0.000017) ...
# loss 1.39957, wmdcmp 0.34861, wmdcmp_gt 0.40300, report_loss 1.44032, 128.51 secs
# (2) Validation stage ...
# wmdcmp 0.13165, wmdcmp_gt 0.21429, cD 0.38478, cD_gt 0.94840, 30.13 secs
# ---- Epoch 123/147
# (1) Training stage (lr = 0.000010) ...
# loss 1.63275, wmdcmp 0.34854, wmdcmp_gt 0.40482, report_loss 1.43680, 128.73 secs
# (2) Validation stage ...
# wmdcmp 0.13047, wmdcmp_gt 0.21474, cD 0.38427, cD_gt 0.96267, 29.96 secs
# ---- Epoch 124/147
# (1) Training stage (lr = 0.000500) ...
# loss 1.63922, wmdcmp 0.32648, wmdcmp_gt 0.38411, report_loss 1.52021, 127.33 secs
# (2) Validation stage ...
# wmdcmp 0.11726, wmdcmp_gt 0.20768, cD 0.34072, cD_gt 0.88788, 30.00 secs
# ---- Epoch 125/147
# (1) Training stage (lr = 0.000286) ...
# loss 1.71974, wmdcmp 0.33477, wmdcmp_gt 0.38871, report_loss 1.49708, 127.22 secs
# (2) Validation stage ...
# wmdcmp 0.12757, wmdcmp_gt 0.21303, cD 0.36722, cD_gt 0.92818, 29.88 secs
# ---- Epoch 126/147
# (1) Training stage (lr = 0.000164) ...
# loss 1.63728, wmdcmp 0.34115, wmdcmp_gt 0.39629, report_loss 1.46727, 125.34 secs
# (2) Validation stage ...
# wmdcmp 0.13537, wmdcmp_gt 0.21410, cD 0.39198, cD_gt 0.94658, 29.99 secs
# ---- Epoch 127/147
# (1) Training stage (lr = 0.000094) ...
# loss 1.58935, wmdcmp 0.34366, wmdcmp_gt 0.40048, report_loss 1.45610, 125.66 secs
# (2) Validation stage ...
# wmdcmp 0.12977, wmdcmp_gt 0.20841, cD 0.36817, cD_gt 0.91602, 30.28 secs
# ---- Epoch 128/147
# (1) Training stage (lr = 0.000053) ...
# loss 1.50702, wmdcmp 0.34833, wmdcmp_gt 0.40287, report_loss 1.43543, 126.72 secs
# (2) Validation stage ...
# wmdcmp 0.12921, wmdcmp_gt 0.21459, cD 0.37575, cD_gt 0.94365, 29.87 secs
# ---- Epoch 129/147
# (1) Training stage (lr = 0.000031) ...
# loss 1.51581, wmdcmp 0.35155, wmdcmp_gt 0.40469, report_loss 1.42819, 127.92 secs
# (2) Validation stage ...
# wmdcmp 0.13168, wmdcmp_gt 0.21506, cD 0.38846, cD_gt 0.94597, 29.80 secs
# ---- Epoch 130/147
# (1) Training stage (lr = 0.000017) ...
# loss 1.45602, wmdcmp 0.35286, wmdcmp_gt 0.40405, report_loss 1.42505, 126.55 secs
# (2) Validation stage ...
# wmdcmp 0.13397, wmdcmp_gt 0.21486, cD 0.38851, cD_gt 0.93566, 30.11 secs
# ---- Epoch 131/147
# (1) Training stage (lr = 0.000010) ...
# loss 1.48855, wmdcmp 0.35263, wmdcmp_gt 0.40919, report_loss 1.41578, 127.83 secs
# (2) Validation stage ...
# wmdcmp 0.12903, wmdcmp_gt 0.21617, cD 0.37017, cD_gt 0.95194, 29.60 secs
# ---- Epoch 132/147
# (1) Training stage (lr = 0.000500) ...
# loss 1.53736, wmdcmp 0.33048, wmdcmp_gt 0.38628, report_loss 1.50476, 124.90 secs
# (2) Validation stage ...
# wmdcmp 0.12931, wmdcmp_gt 0.20475, cD 0.38685, cD_gt 0.87023, 29.76 secs
# ---- Epoch 133/147
# (1) Training stage (lr = 0.000286) ...
# loss 1.63602, wmdcmp 0.33559, wmdcmp_gt 0.39360, report_loss 1.47896, 125.57 secs
# (2) Validation stage ...
# wmdcmp 0.13886, wmdcmp_gt 0.21617, cD 0.43241, cD_gt 0.94060, 30.28 secs
# ---- Epoch 134/147
# (1) Training stage (lr = 0.000164) ...
# loss 1.59289, wmdcmp 0.34483, wmdcmp_gt 0.40067, report_loss 1.44458, 125.88 secs
# (2) Validation stage ...
# wmdcmp 0.13524, wmdcmp_gt 0.21281, cD 0.42534, cD_gt 0.92371, 39.75 secs
# ---- Epoch 135/147
# (1) Training stage (lr = 0.000094) ...
# loss 1.53957, wmdcmp 0.35293, wmdcmp_gt 0.40639, report_loss 1.42304, 129.17 secs
# (2) Validation stage ...
# wmdcmp 0.13257, wmdcmp_gt 0.21290, cD 0.40737, cD_gt 0.92936, 31.63 secs
# ---- Epoch 136/147
# (1) Training stage (lr = 0.000053) ...
# loss 1.58394, wmdcmp 0.35194, wmdcmp_gt 0.40679, report_loss 1.41918, 125.87 secs
# (2) Validation stage ...
# wmdcmp 0.13178, wmdcmp_gt 0.20977, cD 0.40009, cD_gt 0.93595, 30.56 secs
# ---- Epoch 137/147
# (1) Training stage (lr = 0.000031) ...
# loss 1.46251, wmdcmp 0.35561, wmdcmp_gt 0.41033, report_loss 1.40756, 126.05 secs
# (2) Validation stage ...
# wmdcmp 0.13333, wmdcmp_gt 0.21637, cD 0.39448, cD_gt 0.96570, 30.27 secs
# ---- Epoch 138/147
# (1) Training stage (lr = 0.000017) ...
# loss 1.48192, wmdcmp 0.35489, wmdcmp_gt 0.40895, report_loss 1.41065, 129.42 secs
# (2) Validation stage ...
# wmdcmp 0.13383, wmdcmp_gt 0.21635, cD 0.39710, cD_gt 0.95510, 29.87 secs
# ---- Epoch 139/147
# (1) Training stage (lr = 0.000010) ...
# loss 1.39741, wmdcmp 0.35546, wmdcmp_gt 0.41186, report_loss 1.40266, 125.75 secs
# (2) Validation stage ...
# wmdcmp 0.13184, wmdcmp_gt 0.21392, cD 0.39543, cD_gt 0.96071, 29.90 secs
# ---- Epoch 140/147
# (1) Training stage (lr = 0.000500) ...
# loss 1.49726, wmdcmp 0.33338, wmdcmp_gt 0.39198, report_loss 1.48354, 125.73 secs
# (2) Validation stage ...
# wmdcmp 0.13571, wmdcmp_gt 0.21388, cD 0.41674, cD_gt 0.93788, 30.55 secs
# ---- Epoch 141/147
# (1) Training stage (lr = 0.000286) ...
# loss 1.50900, wmdcmp 0.34029, wmdcmp_gt 0.39749, report_loss 1.45929, 125.62 secs
# (2) Validation stage ...
# wmdcmp 0.13032, wmdcmp_gt 0.21085, cD 0.41442, cD_gt 0.94340, 30.46 secs
# ---- Epoch 142/147
# (1) Training stage (lr = 0.000164) ...
# loss 1.58105, wmdcmp 0.34979, wmdcmp_gt 0.40253, report_loss 1.42960, 126.44 secs
# (2) Validation stage ...
# wmdcmp 0.12563, wmdcmp_gt 0.21517, cD 0.35707, cD_gt 0.95565, 30.09 secs
# ---- Epoch 143/147
# (1) Training stage (lr = 0.000094) ...
# loss 1.39667, wmdcmp 0.35431, wmdcmp_gt 0.40831, report_loss 1.40997, 124.07 secs
# (2) Validation stage ...
# wmdcmp 0.13666, wmdcmp_gt 0.21535, cD 0.41715, cD_gt 0.95100, 30.25 secs
# ---- Epoch 144/147
# (1) Training stage (lr = 0.000053) ...
# loss 1.60204, wmdcmp 0.35287, wmdcmp_gt 0.41119, report_loss 1.40452, 124.94 secs
# (2) Validation stage ...
# wmdcmp 0.13186, wmdcmp_gt 0.21500, cD 0.39186, cD_gt 0.95826, 30.09 secs
# ---- Epoch 145/147
# (1) Training stage (lr = 0.000031) ...
# loss 1.50062, wmdcmp 0.35701, wmdcmp_gt 0.41218, report_loss 1.39665, 127.77 secs
# (2) Validation stage ...
# wmdcmp 0.12956, wmdcmp_gt 0.20790, cD 0.38997, cD_gt 0.93084, 30.40 secs
# ---- Epoch 146/147
# (1) Training stage (lr = 0.000017) ...
# loss 1.48250, wmdcmp 0.35805, wmdcmp_gt 0.41264, report_loss 1.39159, 129.04 secs
# (2) Validation stage ...
# wmdcmp 0.12931, wmdcmp_gt 0.21708, cD 0.37789, cD_gt 0.98689, 29.85 secs
# ---- Epoch 147/147
# (1) Training stage (lr = 0.000010) ...
# loss 1.48624, wmdcmp 0.35975, wmdcmp_gt 0.41520, report_loss 1.38364, 127.51 secs
# (2) Validation stage ...
# wmdcmp 0.13081, wmdcmp_gt 0.21735, cD 0.39093, cD_gt 0.97203, 29.84 secs

# %%
# !/home/pamessina/venv2/bin/python ../train_labels2report.py \
    --generation-mode "pred2rep" \
    --use-ensemble \
    --ensemble-model-checkpoint-folder-paths \
        "/mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/" \
    --ensemble-batch-size 160 \
    --ensemble-num-workers 3 \
    --use-hard-predictions \
    --use-gt-labels \
    --train-on-gt-and-eval-on-predictions \
    --epochs 84 \
    --batches-per-epoch 300 \
    --batch-size 200 \
    --num-workers 2 \
    --iters-to-accumulate 2 \
    --optimizer-name "adamw" \
    --scheduler "exp-warmup+decay+cyclicdecay" \
    --lr 1e-6 \
    --warmup-decay-and-cyclic-decay-args "1e-6,3,4e-4,8,3e-6,4e-4,8,3e-6" \
    --use-mimiccxr \
    --mimiccxr-weight 1.0 \
    --mimiccxr-view-mode "chest_imagenome" \
    --mimiccxr-balanced-sampling-mode "balanced_chest_imagenome_global_labels_batchwise" \
    --mimiccxr-balanced-batch-size 30 \
    --mimiccxr-qa-adapted-reports-filename "qa_adapted_reports__20220904_095810.json" \
    --use-chest-imagenome \
    --use-chest-imagenome-decent-images-only \
    --chest-imagenome-label-names-filename "labels(min_freq=100).pkl" \
    --chest-imagenome-labels-filename "imageId2labels(min_freq=100).pkl" \
    --use-chexpert \
    --mimiccxr-chexpert-labels-filename "chexpert_labels_per_report__20220904_113605.pkl" \
    --use-medical-tokenization \
    --medical-terms-frequency-filename "medical_terms_frequency__20220918_184255.pkl" \
    --binary-loss-name "focal+bce+wbce-c" \
    --labels-hidden-dim 1024 \
    --embedding-dim 512 \
    --transf-dec-num-memory-vecs 10 \
    --transf-dec-hidden-dim 512 \
    --transf-dec-nhead 4 \
    --transf-dec-dim-forward 512 \
    --transf-dec-num-layers 3 \
    --use-amp \
    --save
# Out:
# script's arguments:
#    epochs: 84
#    batches_per_epoch: 300
#    batch_size: 200
#    checkpoint_folder: None
#    generation_mode: pred2rep
#    use_ensemble: True
#    ensemble_model_checkpoint_folder_paths: ['/mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/']
#    ensemble_batch_size: 160
#    ensemble_num_workers: 3
#    use_hard_predictions: True
#    use_gt_labels: True
#    train_on_gt_and_eval_on_predictions: True
#    pretrained_checkpoint_folder_path: None
#    labels_hidden_dim: 1024
#    embedding_dim: 512
#    transf_dec_num_memory_vecs: 10
#    transf_dec_hidden_dim: 512
#    transf_dec_nhead: 4
#    transf_dec_dim_forward: 512
#    transf_dec_num_layers: 3
#    dropout_prob: 0
#    vocab_min_freq: 10
#    use_medical_tokenization: True
#    medical_terms_frequency_filename: medical_terms_frequency__20220918_184255.pkl
#    optimizer_name: adamw
#    lr: 1e-06
#    scheduler: exp-warmup+decay+cyclicdecay
#    lr_decay: 0.76
#    lr_decay_patience: 2
#    warmup_and_decay_args: None
#    warmup_and_cosine_args: None
#    warmup_decay_and_cyclic_decay_args: 1e-6,3,4e-4,8,3e-6,4e-4,8,3e-6
#    iters_to_accumulate: 2
#    override_lr: False
#    binary_loss_name: focal+bce+wbce-c
#    focal_loss_weight: 1
#    bce_loss_weight: 1
#    wbce_loss_weight: 1
#    num_workers: 2
#    device: GPU
#    use_amp: True
#    train_mimiccxr: True
#    mimiccxr_weight: 1.0
#    mimiccxr_view_mode: chest_imagenome
#    mimiccxr_balanced_sampling_mode: balanced_chest_imagenome_global_labels_batchwise
#    mimiccxr_balanced_batch_size: 30
#    mimiccxr_qa_adapted_reports_filename: qa_adapted_reports__20220904_095810.json
#    chest_imagenome_labels_filename: imageId2labels(min_freq=100).pkl
#    chest_imagenome_label_names_filename: labels(min_freq=100).pkl
#    use_chest_imagenome_decent_images_only: True
#    save: True
#    use_gender: False
#    use_chexpert: True
#    mimiccxr_chexpert_labels_filename: chexpert_labels_per_report__20220904_113605.pkl
#    use_chest_imagenome: True
#    filter_labels: False
#    top_k_chexpert_labels: None
#    top_k_chest_imagenome_labels: None
#    label_score_threshold: None
#    debug: False
# ----- Training model from scratch ------
# Computing number of labels and ranges for ensemble ...
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/metadata.json
# ensemble_chest_imagenome_range: (0, 627)
# ensemble_chexpert_range: (627, 641)
# Computing number of labels and ranges assuming ground truth labels as input ...
# gt_chest_imagenome_range: (0, 627)
# gt_chexpert_range: (627, 641)
# ============================================================
# Precomputing sigmoid activations for ensemble ...
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/metadata.json
# ============================================================
# Model 1/1
# model_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/
# checkpoint_names = ['checkpoint_79_chou+chuc+chuc+chuc+chuc+cD+gacc+wmmp=0.6677.pt', 'checkpoint_135_chou+chuc+chuc+chuc+chuc+cD+gacc+wmmp=0.6689.pt']
# model_checkpoint_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/checkpoint_135_chou+chuc+chuc+chuc+chuc+cD+gacc+wmmp=0.6689.pt
# precomputed_chexpert_sigmoids_path = /mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/precomputed_chexpert_sigmoids(hash=340,3716123060218160099).pkl
# Precomputed sigmoids for CheXpert already exist.
# File size = 56.39 MB
# precomputed_chest_imagenome_sigmoids_path = /mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/precomputed_chest_imagenome_sigmoids(hash=347,2103260294420767687).pkl
# Precomputed sigmoids for Chest ImaGenome already exist.
# File size = 339.66 MB
# Skipping...
# precomputed_sigmoid_paths: [{'model_folder_path': '/mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/', 'chexpert_sigmoids_path': '/mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/precomputed_chexpert_sigmoids(hash=340,3716123060218160099).pkl', 'chest_imagenome_sigmoids_path': '/mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/precomputed_chest_imagenome_sigmoids(hash=347,2103260294420767687).pkl'}]
# ============================================================
# Precomputing thresholds (for hard predictions) for ensemble ...
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/metadata.json
# ============================================================
# Model 1/1
# model_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/
# checkpoint_names = ['checkpoint_79_chou+chuc+chuc+chuc+chuc+cD+gacc+wmmp=0.6677.pt', 'checkpoint_135_chou+chuc+chuc+chuc+chuc+cD+gacc+wmmp=0.6689.pt']
# model_checkpoint_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/checkpoint_135_chou+chuc+chuc+chuc+chuc+cD+gacc+wmmp=0.6689.pt
# results_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/results/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/
# get_image_transform()
#   Using bounding box aware transforms
#     Returning default transform (no augmentation)
# Calibrating thresholds on MIMIC-CXR validation set
# score_name: f1
# Thresholds for CheXpert already cached at /mnt/data/pamessina/workspaces/medvqa-workspace/results/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/thresholds_chexpert(f1).pkl
# Thresholds for Chest ImaGenome already cached at /mnt/data/pamessina/workspaces/medvqa-workspace/results/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/thresholds_chest_imagenome(f1).pkl
# precomputed_thresholds_paths: [{'chexpert': '/mnt/data/pamessina/workspaces/medvqa-workspace/results/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/thresholds_chexpert(f1).pkl', 'chest_imagenome': '/mnt/data/pamessina/workspaces/medvqa-workspace/results/visual_module/20230428_223926_mim_Image2ReportModel(yolov8l->TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512))/thresholds_chest_imagenome(f1).pkl'}]
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Initializing tokenizer ...
# Loading /mnt/data/pamessina/workspaces/medvqa-workspace/cache/vocab(min_freq=10;mode=report;qa_adapted_reports__20220904_095810.json).pkl ...
# --------------------------------------------------
# 3) Creating instance of Labels2ReportModel ...
# Labels2ReportModel
#   gen_mode: pred2rep
#   vocab_size: 4833
#   embedding_dim: 512
#   num_input_labels: 641
#   labels_hidden_dim: 1024
#   num_output_labels: 641
#   transf_dec_num_memory_vecs: 10
#   transf_dec_hidden_dim: 512
#   transf_dec_nhead: 4
#   transf_dec_dim_forward: 512
#   transf_dec_num_layers: 3
#   start_idx: 1
#   dropout_prob: 0
#   support_two_label_sources: False
#   num_input_labels_2: None
#   labels_hidden_dim_2: 1024
#   num_output_labels_2: None
# WARNING: Unused kwargs: {'device': device(type='cuda'), 'pretrained_checkpoint_folder_path': None}
# --------------------------------------------------
# 4) Defining optimizer ...
# create_optimizer(): name = adamw
# --------------------------------------------------
# 5) Defining scheduler ...
# Using exp-warmup+decay+cyclicdecay scheduler: 1e-6,3,4e-4,8,3e-6,4e-4,8,3e-6
# 1e-06 3 0.0004 8 3e-06 0.0004 8 3e-06
# self.steps_to_restart = 8
# self.steps = -1
# self.initial_lr = 0.0004
# --------------------------------------------------
# 6) Creating trainer and validator engines ...
# Using focal+bce+wbce-c loss
# binary_loss_kwargs: {'focal_weight': 1, 'bce_weight': 1, 'wbce_weight': 1}
# GradientAccumulator.__init__(): num_accumulation_steps = 2
# --------------------------------------------------
# 7) Defining collate_batch_fn ...
# --------------------------------------------------
# 8) Creating MIMIC-CXR_Labels2ReportTrainer ...
# 227835it [00:17, 12995.50it/s]
# max_idx_count = 377110
# actual_idx_count = 239513
# ** NOTE: 137597 images were skipped because they were not in the allowed DICOM IDs
# Random report:
# <s> cardiac silhouette normal no vascular congestion , pleural effusion , focal pneumonia </s>
# len(self.train_indices) = 234217
# len(self.val_indices) = 1934
# Loading CheXpert labels...
# Loading Chest Imagenome labels...
# Loading precomputed sigmoid paths for ensemble predictions...
#   Loading /mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/precomputed_chexpert_sigmoids(hash=340,3716123060218160099).pkl
#     _probs.shape = (242280, 14)
#     len(_dids) = 242280
#     _thresholds.shape = (14,)
#     _probs has been thresholded
#     Sanity checking chexpert labels
#     len(self.val_indices) = 1934
#     f1_score(_gt_labels, _pred_labels, average="micro") = 0.5885286783042394
#     f1_score(_gt_labels, _pred_labels, average="macro") = 0.48877588205948314
# Label order inferred from labels(min_freq=100).pkl
#   Loading /mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/precomputed_chest_imagenome_sigmoids(hash=347,2103260294420767687).pkl
#     _probs.shape = (242280, 627)
#     len(_dids) = 242280
#     _thresholds.shape = (627,)
#     _probs has been thresholded
#     Sanity checking chest_imagenome labels
#     len(self.val_indices) = 1934
#     f1_score(_gt_labels, _pred_labels, average="micro") = 0.2304808503177002
#     f1_score(_gt_labels, _pred_labels, average="macro") = 0.22673751197996303
# Done loading precomputed sigmoid paths for ensemble predictions
# Creating MIMIC-CXR_Labels2ReportTrainer for second label source ...
# 227835it [00:17, 13068.34it/s]
# max_idx_count = 377110
# actual_idx_count = 227835
# ** NOTE: 149275 images were skipped because they were not in the allowed DICOM IDs
# Random report:
# <s> lung volumes lower . bilateral small pleural effusion mild left atelectasis . lungs clear . heart size normal . mediastinum hilar contours normal . right sided port position . vertebral fracture kyphoplasty not . bilateral small pleural effusion . contrast cement embolization paraspinal infection </s>
# len(self.train_indices) = 222758
# len(self.val_indices) = 1808
# Loading CheXpert labels...
# Loading Chest Imagenome labels...
# Reordering Chest Imagenome labels...
# Balanced sampling mode: balanced_chest_imagenome_global_labels_batchwise
# Regrouping indices by Chest Imagenome labels for balanced sampling...
# 627it [01:00, 10.44it/s]
# Global: abnormal                                , # images: 168425 (other: 54333)
# Global: lung opacity                            , # images: 141722 (other: 81036)
# Global: atelectasis                             , # images: 72861 (other: 149897)
# Global: pleural effusion                        , # images: 66227 (other: 156531)
# Global: enlarged cardiac silhouette             , # images: 52931 (other: 169827)
# Global: pulmonary edema/hazy opacity            , # images: 32381 (other: 190377)
# Global: pneumonia                               , # images: 31494 (other: 191264)
# Global: low lung volumes                        , # images: 26283 (other: 196475)
# Global: enteric tube                            , # images: 24273 (other: 198485)
# Global: vascular congestion                     , # images: 22671 (other: 200087)
# Global: endotracheal tube                       , # images: 20404 (other: 202354)
# Global: consolidation                           , # images: 16184 (other: 206574)
# Global: picc                                    , # images: 12972 (other: 209786)
# Global: pleural/parenchymal scarring            , # images: 12849 (other: 209909)
# Global: tortuous aorta                          , # images: 12349 (other: 210409)
# Global: lung lesion                             , # images: 12246 (other: 210512)
# Global: linear/patchy atelectasis               , # images: 11808 (other: 210950)
# Global: cardiac pacer and wires                 , # images: 11259 (other: 211499)
# Global: ij line                                 , # images: 11065 (other: 211693)
# Global: pneumothorax                            , # images: 9708 (other: 213050)
# Global: chest tube                              , # images: 9464 (other: 213294)
# Global: vascular calcification                  , # images: 9425 (other: 213333)
# Global: hyperaeration                           , # images: 9107 (other: 213651)
# Global: lobar/segmental collapse                , # images: 8771 (other: 213987)
# Global: enlarged hilum                          , # images: 8201 (other: 214557)
# Global: aspiration                              , # images: 8152 (other: 214606)
# Global: airspace opacity                        , # images: 7878 (other: 214880)
# Global: mass/nodule (not otherwise specified)   , # images: 7127 (other: 215631)
# Global: chest port                              , # images: 6601 (other: 216157)
# Global: rib fracture                            , # images: 6353 (other: 216405)
# Global: spinal degenerative changes             , # images: 6069 (other: 216689)
# Global: fluid overload/heart failure            , # images: 5970 (other: 216788)
# Global: elevated hemidiaphragm                  , # images: 5869 (other: 216889)
# Global: copd/emphysema                          , # images: 5812 (other: 216946)
# Global: costophrenic angle blunting             , # images: 5298 (other: 217460)
# Global: mediastinal widening                    , # images: 4604 (other: 218154)
# Global: tracheostomy tube                       , # images: 4265 (other: 218493)
# Global: subclavian line                         , # images: 3502 (other: 219256)
# Global: cabg grafts                             , # images: 3433 (other: 219325)
# Global: multiple masses/nodules                 , # images: 3380 (other: 219378)
# Global: pigtail catheter                        , # images: 3240 (other: 219518)
# Global: mediastinal displacement                , # images: 3183 (other: 219575)
# Global: subcutaneous air                        , # images: 3077 (other: 219681)
# Global: superior mediastinal mass/enlargement   , # images: 2996 (other: 219762)
# Global: vascular redistribution                 , # images: 2975 (other: 219783)
# Global: scoliosis                               , # images: 2946 (other: 219812)
# Global: spinal fracture                         , # images: 2873 (other: 219885)
# Global: hernia                                  , # images: 2805 (other: 219953)
# Global: infiltration                            , # images: 2732 (other: 220026)
# Global: prosthetic valve                        , # images: 2623 (other: 220135)
# Global: calcified nodule                        , # images: 2437 (other: 220321)
# Global: granulomatous disease                   , # images: 2174 (other: 220584)
# Global: shoulder osteoarthritis                 , # images: 2016 (other: 220742)
# Global: swan-ganz catheter                      , # images: 1939 (other: 220819)
# Global: interstitial lung disease               , # images: 1817 (other: 220941)
# Global: rotated                                 , # images: 1809 (other: 220949)
# Global: alveolar hemorrhage                     , # images: 1642 (other: 221116)
# Global: lung cancer                             , # images: 1581 (other: 221177)
# Global: bone lesion                             , # images: 1523 (other: 221235)
# Global: pericardial effusion                    , # images: 1302 (other: 221456)
# Global: increased reticular markings/ild pattern, # images: 1274 (other: 221484)
# Global: sub-diaphragmatic air                   , # images: 1117 (other: 221641)
# Global: breast/nipple shadows                   , # images: 898 (other: 221860)
# Global: hydropneumothorax                       , # images: 879 (other: 221879)
# Global: bronchiectasis                          , # images: 835 (other: 221923)
# Global: pneumomediastinum                       , # images: 792 (other: 221966)
# Global: clavicle fracture                       , # images: 789 (other: 221969)
# Global: cyst/bullae                             , # images: 766 (other: 221992)
# Global: goiter                                  , # images: 565 (other: 222193)
# Global: intra-aortic balloon pump               , # images: 501 (other: 222257)
# Global: mediastinal drain                       , # images: 397 (other: 222361)
# Global: artifact                                , # images: 286 (other: 222472)
# Global: skin fold                               , # images: 195 (other: 222563)
# Global: aortic graft/repair                     , # images: 101 (other: 222657)
# --------------------------------------------------
# 9) Creating dataloaders ...
# len(_train_dataloaders) = 1
# len(_val_dataloaders) = 2
# _train_weights = [1.0]
# merged_dataset_name = mim(gt)
# --------------------------------------------------
# 10) Attaching metrics, losses, timer and events to engines ...
# --------------------------------------------------
# 11) Defining learning rate scheduler handler ...
# --------------------------------------------------
# 12) Defining checkpoint folder path ...
# checkpoint_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/report_gen/20230509_093144_mim(gt)_Labels2ReportModel(641,10,TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512)))
# metadata saved to /mnt/data/pamessina/workspaces/medvqa-workspace/models/report_gen/20230509_093144_mim(gt)_Labels2ReportModel(641,10,TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512)))/metadata.json
# --------------------------------------------------
# 13) Defining log_metrics_handler ...
# MetricsLogger :: we'll be logging to /mnt/data/pamessina/workspaces/medvqa-workspace/models/report_gen/20230509_093144_mim(gt)_Labels2ReportModel(641,10,TransfTextDec(es=512,hs=512,nl=3,nh=4,dff=512)))/metrics_logs.csv
# --------------------------------------------------
# 14) Running trainer engine ...
# ---- Epoch 1/84
# (1) Training stage (lr = 0.000001) ...
# loss 8.58370, wmdcmp_gt 0.00529, report_loss 8.38730, 189.38 secs
# (2) Validation stage ...
# wmdcmp 0.00267, wmdcmp_gt 0.00218, cD 0.00051, cD_gt 0.00084, 30.94 secs
# ---- Epoch 2/84
# (1) Training stage (lr = 0.000007) ...
# loss 8.15164, wmdcmp_gt 0.00115, report_loss 6.84693, 167.16 secs
# (2) Validation stage ...
# wmdcmp 0.01235, wmdcmp_gt 0.01083, cD 0.00604, cD_gt 0.00086, 28.54 secs
# ---- Epoch 3/84
# (1) Training stage (lr = 0.000054) ...
# loss 6.04221, wmdcmp_gt 0.06024, report_loss 4.55220, 158.76 secs
# (2) Validation stage ...
# wmdcmp 0.04213, wmdcmp_gt 0.05791, cD 0.00573, cD_gt 0.05386, 31.98 secs
# ---- Epoch 4/84
# (1) Training stage (lr = 0.000400) ...
# loss 3.73807, wmdcmp_gt 0.17544, report_loss 2.90575, 130.32 secs
# (2) Validation stage ...
# wmdcmp 0.09279, wmdcmp_gt 0.14880, cD 0.23958, cD_gt 0.44974, 30.01 secs
# ---- Epoch 5/84
# (1) Training stage (lr = 0.000217) ...
# loss 2.31669, wmdcmp_gt 0.23634, report_loss 2.34243, 128.41 secs
# (2) Validation stage ...
# wmdcmp 0.09806, wmdcmp_gt 0.16423, cD 0.21880, cD_gt 0.58603, 38.75 secs
# ---- Epoch 6/84
# (1) Training stage (lr = 0.000118) ...
# loss 2.21774, wmdcmp_gt 0.25327, report_loss 2.21425, 124.26 secs
# (2) Validation stage ...
# wmdcmp 0.07496, wmdcmp_gt 0.17197, cD 0.04516, cD_gt 0.60902, 30.78 secs
# ---- Epoch 7/84
# (1) Training stage (lr = 0.000064) ...
# loss 2.24814, wmdcmp_gt 0.26067, report_loss 2.16595, 126.79 secs
# (2) Validation stage ...
# wmdcmp 0.06616, wmdcmp_gt 0.17496, cD 0.03010, cD_gt 0.67984, 30.87 secs
# ---- Epoch 8/84
# (1) Training stage (lr = 0.000035) ...
# loss 2.20184, wmdcmp_gt 0.26691, report_loss 2.13168, 127.27 secs
# (2) Validation stage ...
# wmdcmp 0.06688, wmdcmp_gt 0.17384, cD 0.03339, cD_gt 0.60834, 31.34 secs
# ---- Epoch 9/84
# (1) Training stage (lr = 0.000019) ...
# loss 2.14102, wmdcmp_gt 0.26781, report_loss 2.11486, 126.71 secs
# (2) Validation stage ...
# wmdcmp 0.06882, wmdcmp_gt 0.17433, cD 0.03984, cD_gt 0.63409, 31.34 secs
# ---- Epoch 10/84
# (1) Training stage (lr = 0.000010) ...
# loss 2.14120, wmdcmp_gt 0.26786, report_loss 2.11048, 125.14 secs
# (2) Validation stage ...
# wmdcmp 0.06492, wmdcmp_gt 0.18579, cD 0.02098, cD_gt 0.71743, 31.10 secs
# ---- Epoch 11/84
# (1) Training stage (lr = 0.000006) ...
# loss 2.24612, wmdcmp_gt 0.27032, report_loss 2.10602, 125.10 secs
# (2) Validation stage ...
# wmdcmp 0.06319, wmdcmp_gt 0.18656, cD 0.01977, cD_gt 0.71681, 30.97 secs
# ---- Epoch 12/84
# (1) Training stage (lr = 0.000003) ...
# loss 2.16817, wmdcmp_gt 0.26906, report_loss 2.10061, 125.49 secs
# (2) Validation stage ...
# wmdcmp 0.06324, wmdcmp_gt 0.17441, cD 0.02012, cD_gt 0.62905, 30.71 secs
# ---- Epoch 13/84
# (1) Training stage (lr = 0.000400) ...
# loss 2.08028, wmdcmp_gt 0.27298, report_loss 2.07281, 126.69 secs
# (2) Validation stage ...
# wmdcmp 0.04764, wmdcmp_gt 0.19199, cD 0.00907, cD_gt 0.74018, 31.26 secs
# ---- Epoch 14/84
# (1) Training stage (lr = 0.000199) ...
# loss 2.07251, wmdcmp_gt 0.28897, report_loss 1.97421, 127.01 secs
# (2) Validation stage ...
# wmdcmp 0.04298, wmdcmp_gt 0.19539, cD 0.00322, cD_gt 0.81416, 31.22 secs
# ---- Epoch 15/84
# (1) Training stage (lr = 0.000099) ...
# loss 2.04866, wmdcmp_gt 0.29623, report_loss 1.93025, 127.58 secs
# (2) Validation stage ...
# wmdcmp 0.04106, wmdcmp_gt 0.20512, cD 0.00883, cD_gt 0.84697, 32.04 secs
# ---- Epoch 16/84
# (1) Training stage (lr = 0.000049) ...
# loss 1.97112, wmdcmp_gt 0.30024, report_loss 1.90742, 129.83 secs
# (2) Validation stage ...
# wmdcmp 0.04334, wmdcmp_gt 0.20432, cD 0.01101, cD_gt 0.88161, 33.05 secs
# ---- Epoch 17/84
# (1) Training stage (lr = 0.000024) ...
# loss 2.02265, wmdcmp_gt 0.30189, report_loss 1.89602, 135.19 secs
# (2) Validation stage ...
# wmdcmp 0.03958, wmdcmp_gt 0.20612, cD 0.00837, cD_gt 0.85536, 32.04 secs
# ---- Epoch 18/84
# (1) Training stage (lr = 0.000012) ...
# loss 1.86120, wmdcmp_gt 0.30307, report_loss 1.88881, 137.99 secs
# (2) Validation stage ...
# wmdcmp 0.04350, wmdcmp_gt 0.20124, cD 0.00891, cD_gt 0.81887, 34.81 secs
# ---- Epoch 19/84
# (1) Training stage (lr = 0.000006) ...
# loss 1.98153, wmdcmp_gt 0.30298, report_loss 1.88276, 139.22 secs
# (2) Validation stage ...
# wmdcmp 0.04224, wmdcmp_gt 0.20488, cD 0.00772, cD_gt 0.87103, 34.49 secs
# ---- Epoch 20/84
# (1) Training stage (lr = 0.000003) ...
# loss 1.85625, wmdcmp_gt 0.30311, report_loss 1.88467, 139.29 secs
# (2) Validation stage ...
# wmdcmp 0.04142, wmdcmp_gt 0.20517, cD 0.00832, cD_gt 0.88051, 34.00 secs
# ---- Epoch 21/84
# (1) Training stage (lr = 0.000400) ...
# loss 1.84653, wmdcmp_gt 0.29965, report_loss 1.90030, 138.12 secs
# (2) Validation stage ...
# wmdcmp 0.04371, wmdcmp_gt 0.19318, cD 0.00782, cD_gt 0.76112, 33.93 secs
# ---- Epoch 22/84
# (1) Training stage (lr = 0.000199) ...
# loss 1.78395, wmdcmp_gt 0.30957, report_loss 1.83864, 143.54 secs
# (2) Validation stage ...
# wmdcmp 0.05201, wmdcmp_gt 0.19411, cD 0.01239, cD_gt 0.81254, 34.68 secs
# ---- Epoch 23/84
# (1) Training stage (lr = 0.000099) ...
# loss 1.88487, wmdcmp_gt 0.31661, report_loss 1.80583, 146.48 secs
# (2) Validation stage ...
# wmdcmp 0.05215, wmdcmp_gt 0.20760, cD 0.00819, cD_gt 0.87820, 34.89 secs
# ---- Epoch 24/84
# (1) Training stage (lr = 0.000049) ...
# loss 1.83300, wmdcmp_gt 0.31946, report_loss 1.78675, 148.35 secs
# (2) Validation stage ...
# wmdcmp 0.04738, wmdcmp_gt 0.19688, cD 0.00577, cD_gt 0.81643, 34.91 secs
# ---- Epoch 25/84
# (1) Training stage (lr = 0.000024) ...
# loss 1.79142, wmdcmp_gt 0.32090, report_loss 1.77508, 146.68 secs
# (2) Validation stage ...
# wmdcmp 0.04637, wmdcmp_gt 0.20504, cD 0.00555, cD_gt 0.83778, 35.45 secs
# ---- Epoch 26/84
# (1) Training stage (lr = 0.000012) ...
# loss 1.80205, wmdcmp_gt 0.32285, report_loss 1.77395, 145.94 secs
# (2) Validation stage ...
# wmdcmp 0.04574, wmdcmp_gt 0.20783, cD 0.00631, cD_gt 0.86364, 34.74 secs
# ---- Epoch 27/84
# (1) Training stage (lr = 0.000006) ...
# loss 1.71815, wmdcmp_gt 0.32406, report_loss 1.76599, 148.72 secs
# (2) Validation stage ...
# wmdcmp 0.04697, wmdcmp_gt 0.20759, cD 0.00714, cD_gt 0.86541, 35.63 secs
# ---- Epoch 28/84
# (1) Training stage (lr = 0.000003) ...
# loss 1.70342, wmdcmp_gt 0.32373, report_loss 1.76317, 148.84 secs
# (2) Validation stage ...
# wmdcmp 0.04697, wmdcmp_gt 0.20779, cD 0.00584, cD_gt 0.87742, 34.63 secs
# ---- Epoch 29/84
# (1) Training stage (lr = 0.000400) ...
# loss 1.79220, wmdcmp_gt 0.31457, report_loss 1.79954, 149.05 secs
# (2) Validation stage ...
# wmdcmp 0.05658, wmdcmp_gt 0.19816, cD 0.00730, cD_gt 0.82963, 36.18 secs
# ---- Epoch 30/84
# (1) Training stage (lr = 0.000199) ...
# loss 1.66171, wmdcmp_gt 0.32628, report_loss 1.74655, 147.17 secs
# (2) Validation stage ...
# wmdcmp 0.04362, wmdcmp_gt 0.21321, cD 0.00821, cD_gt 0.93893, 35.44 secs
# ---- Epoch 31/84
# (1) Training stage (lr = 0.000099) ...
# loss 1.69916, wmdcmp_gt 0.33252, report_loss 1.71762, 150.69 secs
# (2) Validation stage ...
# wmdcmp 0.05125, wmdcmp_gt 0.22021, cD 0.00963, cD_gt 0.98272, 34.76 secs
# ---- Epoch 32/84
# (1) Training stage (lr = 0.000049) ...
# loss 1.71949, wmdcmp_gt 0.33541, report_loss 1.70101, 149.32 secs
# (2) Validation stage ...
# wmdcmp 0.05058, wmdcmp_gt 0.21469, cD 0.01184, cD_gt 0.91705, 35.47 secs
# ---- Epoch 33/84
# (1) Training stage (lr = 0.000024) ...
# loss 1.66546, wmdcmp_gt 0.33543, report_loss 1.69474, 150.38 secs
# (2) Validation stage ...
# wmdcmp 0.05083, wmdcmp_gt 0.21621, cD 0.01179, cD_gt 0.94572, 35.41 secs
# ---- Epoch 34/84
# (1) Training stage (lr = 0.000012) ...
# loss 1.64087, wmdcmp_gt 0.33786, report_loss 1.68610, 152.28 secs
# (2) Validation stage ...
# wmdcmp 0.05199, wmdcmp_gt 0.21483, cD 0.01050, cD_gt 0.92513, 35.92 secs
# ---- Epoch 35/84
# (1) Training stage (lr = 0.000006) ...
# loss 1.56351, wmdcmp_gt 0.33793, report_loss 1.68404, 148.52 secs
# (2) Validation stage ...
# wmdcmp 0.05152, wmdcmp_gt 0.21509, cD 0.01194, cD_gt 0.92696, 34.71 secs
# ---- Epoch 36/84
# (1) Training stage (lr = 0.000003) ...
# loss 1.69479, wmdcmp_gt 0.33700, report_loss 1.68564, 154.04 secs
# (2) Validation stage ...
# wmdcmp 0.05133, wmdcmp_gt 0.21718, cD 0.01188, cD_gt 0.94854, 54.16 secs
# ---- Epoch 37/84
# (1) Training stage (lr = 0.000400) ...
# loss 1.65796, wmdcmp_gt 0.32866, report_loss 1.72149, 152.89 secs
# (2) Validation stage ...
# wmdcmp 0.05737, wmdcmp_gt 0.20655, cD 0.00684, cD_gt 0.89022, 35.33 secs
# ---- Epoch 38/84
# (1) Training stage (lr = 0.000199) ...
# loss 1.71429, wmdcmp_gt 0.33624, report_loss 1.68235, 151.89 secs
# (2) Validation stage ...
# wmdcmp 0.05244, wmdcmp_gt 0.21444, cD 0.00634, cD_gt 0.95281, 35.77 secs
# ---- Epoch 39/84
# (1) Training stage (lr = 0.000099) ...
# loss 1.70941, wmdcmp_gt 0.34205, report_loss 1.65656, 150.47 secs
# (2) Validation stage ...
# wmdcmp 0.05169, wmdcmp_gt 0.20963, cD 0.00538, cD_gt 0.90508, 37.93 secs
# ---- Epoch 40/84
# (1) Training stage (lr = 0.000049) ...
# loss 1.65773, wmdcmp_gt 0.34597, report_loss 1.63960, 149.75 secs
# (2) Validation stage ...
# wmdcmp 0.05054, wmdcmp_gt 0.20878, cD 0.00497, cD_gt 0.92224, 37.91 secs
# ---- Epoch 41/84
# (1) Training stage (lr = 0.000024) ...
# loss 1.55503, wmdcmp_gt 0.34711, report_loss 1.62577, 151.12 secs
# (2) Validation stage ...
# wmdcmp 0.05045, wmdcmp_gt 0.21870, cD 0.00679, cD_gt 0.96162, 37.79 secs
# ---- Epoch 42/84
# (1) Training stage (lr = 0.000012) ...
# loss 1.57749, wmdcmp_gt 0.34846, report_loss 1.62377, 151.74 secs
# (2) Validation stage ...
# wmdcmp 0.05117, wmdcmp_gt 0.21732, cD 0.00585, cD_gt 0.94583, 38.18 secs
# ---- Epoch 43/84
# (1) Training stage (lr = 0.000006) ...
# loss 1.66070, wmdcmp_gt 0.34970, report_loss 1.62416, 153.63 secs
# (2) Validation stage ...
# wmdcmp 0.05119, wmdcmp_gt 0.21762, cD 0.00613, cD_gt 0.95960, 37.95 secs
# ---- Epoch 44/84
# (1) Training stage (lr = 0.000003) ...
# loss 1.65450, wmdcmp_gt 0.34924, report_loss 1.61812, 152.79 secs
# (2) Validation stage ...
# wmdcmp 0.05122, wmdcmp_gt 0.22286, cD 0.00621, cD_gt 1.01150, 38.20 secs
# ---- Epoch 45/84
# (1) Training stage (lr = 0.000400) ...
# loss 1.74075, wmdcmp_gt 0.33920, report_loss 1.66048, 155.01 secs
# (2) Validation stage ...
# wmdcmp 0.04589, wmdcmp_gt 0.20923, cD 0.00712, cD_gt 0.88209, 35.51 secs
# ---- Epoch 46/84
# (1) Training stage (lr = 0.000199) ...
# loss 1.71675, wmdcmp_gt 0.34598, report_loss 1.62801, 152.53 secs
# (2) Validation stage ...
# wmdcmp 0.05057, wmdcmp_gt 0.22242, cD 0.00848, cD_gt 1.01147, 37.42 secs
# ---- Epoch 47/84
# (1) Training stage (lr = 0.000099) ...
# loss 1.66697, wmdcmp_gt 0.35146, report_loss 1.60593, 151.47 secs
# (2) Validation stage ...
# wmdcmp 0.04810, wmdcmp_gt 0.22292, cD 0.00738, cD_gt 1.01394, 37.12 secs
# ---- Epoch 48/84
# (1) Training stage (lr = 0.000049) ...
# loss 1.68422, wmdcmp_gt 0.35565, report_loss 1.58723, 151.36 secs
# (2) Validation stage ...
# wmdcmp 0.04481, wmdcmp_gt 0.21869, cD 0.00554, cD_gt 0.96307, 36.22 secs
# ---- Epoch 49/84
# (1) Training stage (lr = 0.000024) ...
# loss 1.67989, wmdcmp_gt 0.35709, report_loss 1.57823, 149.71 secs
# (2) Validation stage ...
# wmdcmp 0.04740, wmdcmp_gt 0.21922, cD 0.00704, cD_gt 0.95695, 36.14 secs
# ---- Epoch 50/84
# (1) Training stage (lr = 0.000012) ...
# loss 1.50184, wmdcmp_gt 0.35776, report_loss 1.57389, 149.05 secs
# (2) Validation stage ...
# wmdcmp 0.04742, wmdcmp_gt 0.22567, cD 0.00742, cD_gt 1.01745, 35.85 secs
# ---- Epoch 51/84
# (1) Training stage (lr = 0.000006) ...
# loss 1.57958, wmdcmp_gt 0.35925, report_loss 1.56743, 148.81 secs
# (2) Validation stage ...
# wmdcmp 0.04615, wmdcmp_gt 0.21984, cD 0.00884, cD_gt 0.97527, 35.91 secs
# ---- Epoch 52/84
# (1) Training stage (lr = 0.000003) ...
# loss 1.65680, wmdcmp_gt 0.35871, report_loss 1.56766, 153.49 secs
# (2) Validation stage ...
# wmdcmp 0.04691, wmdcmp_gt 0.22011, cD 0.00726, cD_gt 0.97172, 36.03 secs
# ---- Epoch 53/84
# (1) Training stage (lr = 0.000400) ...
# loss 1.69829, wmdcmp_gt 0.34592, report_loss 1.61809, 149.72 secs
# (2) Validation stage ...
# wmdcmp 0.05245, wmdcmp_gt 0.21015, cD 0.00702, cD_gt 0.89119, 36.44 secs
# ---- Epoch 54/84
# (1) Training stage (lr = 0.000199) ...
# loss 1.64404, wmdcmp_gt 0.35371, report_loss 1.58734, 148.96 secs
# (2) Validation stage ...
# wmdcmp 0.04099, wmdcmp_gt 0.21307, cD 0.01207, cD_gt 0.91801, 34.97 secs
# ---- Epoch 55/84
# (1) Training stage (lr = 0.000099) ...
# loss 1.56668, wmdcmp_gt 0.35984, report_loss 1.56477, 149.07 secs
# (2) Validation stage ...
# wmdcmp 0.04515, wmdcmp_gt 0.21400, cD 0.00687, cD_gt 0.96544, 35.77 secs
# ---- Epoch 56/84
# (1) Training stage (lr = 0.000049) ...
# loss 1.58593, wmdcmp_gt 0.36429, report_loss 1.54144, 147.72 secs
# (2) Validation stage ...
# wmdcmp 0.04461, wmdcmp_gt 0.21386, cD 0.00984, cD_gt 0.93578, 36.05 secs
# ---- Epoch 57/84
# (1) Training stage (lr = 0.000024) ...
# loss 1.60624, wmdcmp_gt 0.36487, report_loss 1.53404, 147.24 secs
# (2) Validation stage ...
# wmdcmp 0.04374, wmdcmp_gt 0.21991, cD 0.00852, cD_gt 0.97679, 36.49 secs
# ---- Epoch 58/84
# (1) Training stage (lr = 0.000012) ...
# loss 1.52628, wmdcmp_gt 0.36638, report_loss 1.52930, 150.53 secs
# (2) Validation stage ...
# wmdcmp 0.04503, wmdcmp_gt 0.21539, cD 0.00837, cD_gt 0.96963, 35.58 secs
# ---- Epoch 59/84
# (1) Training stage (lr = 0.000006) ...
# loss 1.59569, wmdcmp_gt 0.36787, report_loss 1.52432, 148.43 secs
# (2) Validation stage ...
# wmdcmp 0.04435, wmdcmp_gt 0.22286, cD 0.00998, cD_gt 1.02516, 35.51 secs
# ---- Epoch 60/84
# (1) Training stage (lr = 0.000003) ...
# loss 1.58242, wmdcmp_gt 0.36778, report_loss 1.52272, 145.30 secs
# (2) Validation stage ...
# wmdcmp 0.04452, wmdcmp_gt 0.22390, cD 0.00987, cD_gt 1.04056, 36.18 secs
# ---- Epoch 61/84
# (1) Training stage (lr = 0.000400) ...
# loss 1.49779, wmdcmp_gt 0.35422, report_loss 1.57614, 148.29 secs
# (2) Validation stage ...
# wmdcmp 0.03757, wmdcmp_gt 0.21773, cD 0.01174, cD_gt 0.95942, 36.00 secs
# ---- Epoch 62/84
# (1) Training stage (lr = 0.000199) ...
# loss 1.56033, wmdcmp_gt 0.36041, report_loss 1.54821, 150.51 secs
# (2) Validation stage ...
# wmdcmp 0.04195, wmdcmp_gt 0.21450, cD 0.00843, cD_gt 0.95121, 37.57 secs
# ---- Epoch 63/84
# (1) Training stage (lr = 0.000099) ...
# loss 1.47100, wmdcmp_gt 0.36975, report_loss 1.51729, 148.34 secs
# (2) Validation stage ...
# wmdcmp 0.03942, wmdcmp_gt 0.21825, cD 0.01225, cD_gt 1.00044, 36.28 secs
# ---- Epoch 64/84
# (1) Training stage (lr = 0.000049) ...
# loss 1.56391, wmdcmp_gt 0.37155, report_loss 1.50728, 150.02 secs
# (2) Validation stage ...
# wmdcmp 0.03943, wmdcmp_gt 0.22599, cD 0.00959, cD_gt 1.03605, 35.71 secs
# ---- Epoch 65/84
# (1) Training stage (lr = 0.000024) ...
# loss 1.51195, wmdcmp_gt 0.37389, report_loss 1.49208, 152.08 secs
# (2) Validation stage ...
# wmdcmp 0.03944, wmdcmp_gt 0.22526, cD 0.01173, cD_gt 1.02841, 34.93 secs
# ---- Epoch 66/84
# (1) Training stage (lr = 0.000012) ...
# loss 1.46894, wmdcmp_gt 0.37351, report_loss 1.49245, 155.57 secs
# (2) Validation stage ...
# wmdcmp 0.04054, wmdcmp_gt 0.21549, cD 0.00996, cD_gt 0.96601, 34.34 secs
# ---- Epoch 67/84
# (1) Training stage (lr = 0.000006) ...
# loss 1.35833, wmdcmp_gt 0.37488, report_loss 1.48811, 152.40 secs
# (2) Validation stage ...
# wmdcmp 0.04087, wmdcmp_gt 0.22368, cD 0.01036, cD_gt 0.98762, 65.41 secs
# ---- Epoch 68/84
# (1) Training stage (lr = 0.000003) ...
# loss 1.32777, wmdcmp_gt 0.37521, report_loss 1.48241, 149.39 secs
# (2) Validation stage ...
# wmdcmp 0.04047, wmdcmp_gt 0.22460, cD 0.01070, cD_gt 1.02717, 35.34 secs
# ---- Epoch 69/84
# (1) Training stage (lr = 0.000400) ...
# loss 1.31856, wmdcmp_gt 0.36147, report_loss 1.53741, 150.55 secs
# (2) Validation stage ...
# wmdcmp 0.03655, wmdcmp_gt 0.20378, cD 0.01562, cD_gt 0.87086, 36.27 secs
# ---- Epoch 70/84
# (1) Training stage (lr = 0.000199) ...
# loss 1.55095, wmdcmp_gt 0.36737, report_loss 1.51554, 152.85 secs
# (2) Validation stage ...
# wmdcmp 0.03407, wmdcmp_gt 0.22851, cD 0.01592, cD_gt 1.03689, 38.15 secs
# ---- Epoch 71/84
# (1) Training stage (lr = 0.000099) ...
# loss 1.47499, wmdcmp_gt 0.37469, report_loss 1.48166, 153.35 secs
# (2) Validation stage ...
# wmdcmp 0.04041, wmdcmp_gt 0.21704, cD 0.01061, cD_gt 0.98886, 38.19 secs
# ---- Epoch 72/84
# (1) Training stage (lr = 0.000049) ...
# loss 1.46150, wmdcmp_gt 0.37721, report_loss 1.47121, 151.58 secs
# (2) Validation stage ...
# wmdcmp 0.03902, wmdcmp_gt 0.22567, cD 0.00905, cD_gt 1.03942, 37.81 secs
# ---- Epoch 73/84
# (1) Training stage (lr = 0.000024) ...
# loss 1.44946, wmdcmp_gt 0.37878, report_loss 1.46115, 150.17 secs
# (2) Validation stage ...
# wmdcmp 0.03988, wmdcmp_gt 0.21534, cD 0.00963, cD_gt 0.97238, 36.55 secs
# ---- Epoch 74/84
# (1) Training stage (lr = 0.000012) ...
# loss 1.42418, wmdcmp_gt 0.38090, report_loss 1.45634, 150.43 secs
# (2) Validation stage ...
# wmdcmp 0.03993, wmdcmp_gt 0.22520, cD 0.00925, cD_gt 1.00367, 36.83 secs
# ---- Epoch 75/84
# (1) Training stage (lr = 0.000006) ...
# loss 1.42673, wmdcmp_gt 0.38033, report_loss 1.45387, 148.52 secs
# (2) Validation stage ...
# wmdcmp 0.03986, wmdcmp_gt 0.22437, cD 0.00920, cD_gt 1.01433, 35.70 secs
# ---- Epoch 76/84
# (1) Training stage (lr = 0.000003) ...
# loss 1.49674, wmdcmp_gt 0.38215, report_loss 1.44818, 148.27 secs
# (2) Validation stage ...
# wmdcmp 0.04016, wmdcmp_gt 0.22475, cD 0.00965, cD_gt 1.01345, 35.81 secs
# ---- Epoch 77/84
# (1) Training stage (lr = 0.000400) ...
# loss 1.52004, wmdcmp_gt 0.36647, report_loss 1.51007, 152.04 secs
# (2) Validation stage ...
# wmdcmp 0.03589, wmdcmp_gt 0.21520, cD 0.01059, cD_gt 0.98831, 37.68 secs
# ---- Epoch 78/84
# (1) Training stage (lr = 0.000199) ...
# loss 1.51540, wmdcmp_gt 0.37250, report_loss 1.48540, 150.11 secs
# (2) Validation stage ...
# wmdcmp 0.03721, wmdcmp_gt 0.21529, cD 0.00987, cD_gt 0.89963, 36.04 secs
# ---- Epoch 79/84
# (1) Training stage (lr = 0.000099) ...
# loss 1.47497, wmdcmp_gt 0.38110, report_loss 1.45452, 149.17 secs
# (2) Validation stage ...
# wmdcmp 0.03557, wmdcmp_gt 0.21299, cD 0.00869, cD_gt 0.93373, 36.47 secs
# ---- Epoch 80/84
# (1) Training stage (lr = 0.000049) ...
# loss 1.52206, wmdcmp_gt 0.38378, report_loss 1.44221, 150.16 secs
# (2) Validation stage ...
# wmdcmp 0.03482, wmdcmp_gt 0.22066, cD 0.00834, cD_gt 0.99947, 35.23 secs
# ---- Epoch 81/84
# (1) Training stage (lr = 0.000024) ...
# loss 1.45686, wmdcmp_gt 0.38372, report_loss 1.43273, 149.27 secs
# (2) Validation stage ...
# wmdcmp 0.03334, wmdcmp_gt 0.22470, cD 0.00916, cD_gt 1.02876, 36.05 secs
# ---- Epoch 82/84
# (1) Training stage (lr = 0.000012) ...
# loss 1.43700, wmdcmp_gt 0.38680, report_loss 1.42390, 150.03 secs
# (2) Validation stage ...
# wmdcmp 0.03469, wmdcmp_gt 0.22412, cD 0.00963, cD_gt 0.97927, 37.08 secs
# ---- Epoch 83/84
# (1) Training stage (lr = 0.000006) ...
# loss 1.43266, wmdcmp_gt 0.38756, report_loss 1.42258, 149.14 secs
# (2) Validation stage ...
# wmdcmp 0.03492, wmdcmp_gt 0.22464, cD 0.00844, cD_gt 0.97636, 35.99 secs
# ---- Epoch 84/84
# (1) Training stage (lr = 0.000003) ...
# loss 1.49063, wmdcmp_gt 0.38767, report_loss 1.41743, 149.05 secs
# (2) Validation stage ...
# wmdcmp 0.03481, wmdcmp_gt 0.22456, cD 0.00814, cD_gt 0.99421, 36.62 secs
