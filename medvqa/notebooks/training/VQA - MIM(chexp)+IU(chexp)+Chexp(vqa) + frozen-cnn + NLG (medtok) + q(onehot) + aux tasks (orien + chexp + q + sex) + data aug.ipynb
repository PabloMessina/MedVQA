# %%
# %env CUDA_VISIBLE_DEVICES=0
# Out:
# env: CUDA_VISIBLE_DEVICES=0

# %%
# !python ../train_vqa.py \
        --pretrained-checkpoint-folder-path "/home/pamessina/medvqa-workspace/models/vqa/20220630_162749_mimiccxr+iuxray+chexpert(vqa)_oevqa(densenet121+bilstm+lstm)_voc-minf=5_model-args=(densenet-121,128,None,512,1,128,1024,0,qenc=one-hot)_cnn-pretr=0_dataset_weights=0.73,0.07,0.2_medtok=1_tags=0_orien=1_chx=1_ql=1_use_amp" \
        --epochs 80 \
        --batches-per-epoch 300 \
        --batch-size 150 \
        --num-workers 7 \
        --lr-decay-patience 3 \
        --answer-hidden-size 512 \
        --n-lstm-layers 1 \
        --iuxray-qa-adapted-reports-filename "qa_adapted_reports__20220629_042239.json" \
        --mimiccxr-qa-adapted-reports-filename "qa_adapted_reports__20220629_050643.json" \
        --classify-chexpert \
        --iuxray-chexpert-labels-filename "chexpert_labels_per_report__20220629_055107.pkl" \
        --mimiccxr-chexpert-labels-filename "chexpert_labels_per_report__20220629_055159.pkl" \
        --classify-questions \
        --n-questions 97 \
        --iuxray-question-labels-filename "question_labels_per_report__20220629_052841.pkl" \
        --mimiccxr-question-labels-filename "question_labels_per_report__20220629_052842.pkl" \
        --balanced-split \
        --iuxray-balanced-metadata-filename "balanced_dataloading_metadata__20220629_123626.pkl" \
        --mimiccxr-balanced-metadata-filename "balanced_dataloading_metadata__20220629_123956.pkl" \
        --balanced-dataloading \
        --medical-tokenization \
        --medical-terms-frequency-filename "medical_terms_frequency__20220629_052724.pkl" \
        --question-encoding "one-hot" \
        --binary-loss-name "wbce-c" \
        --img-aug-mode "random-color-and-spatial" \
        --chexpert-mode "vqa" \
        --mimiccxr-include-chexpert-mode \
        --iuxray-include-chexpert-mode \
        --freeze-cnn \
        --use-amp \
        --save
# Out:
# script's arguments:
#    epochs: 80
#    batches_per_epoch: 300
#    checkpoint_folder: None
#    iuxray_qa_adapted_reports_filename: qa_adapted_reports__20220629_042239.json
#    mimiccxr_qa_adapted_reports_filename: qa_adapted_reports__20220629_050643.json
#    vocab_min_freq: 5
#    embed_size: 128
#    question_encoding: one-hot
#    question_hidden_size: 128
#    answer_hidden_size: 512
#    n_lstm_layers: 1
#    question_vec_size: 128
#    image_local_feat_size: 1024
#    dropout_prob: 0
#    densenet_pretrained_weights_path:
#    lr: 0.001
#    lr_decay: 0.76
#    lr_decay_patience: 3
#    n_val_examples_per_question: 10
#    min_train_examples_per_question: 100
#    batch_size: 150
#    num_workers: 7
#    device: GPU
#    img_aug_mode: random-color-and-spatial
#    freeze_cnn: True
#    mimiccxr_weight: 0.73
#    chexpert_weight: 0.2
#    iuxray_weight: 0.07
#    mimiccxr_weight_chexpert_mode: 0.15
#    iuxray_weight_chexpert_mode: 0.03
# ...

# %%
# !python ../train_vqa.py \
        --checkpoint-folder "models/vqa/20220717_155233_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(dense121+onehot+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretr,frozen)_cnn-pretr=0_dws=0.73,0.15,0.07,0.03,0.2_medtok_chx_ql_amp" \
        --epochs 30 \
        --batches-per-epoch 300 \
        --batch-size 150 \
        --num-workers 7 \
        --save
# Out:
# script's arguments:
#    epochs: 30
#    batches_per_epoch: 300
#    checkpoint_folder: models/vqa/20220717_155233_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(dense121+onehot+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretr,frozen)_cnn-pretr=0_dws=0.73,0.15,0.07,0.03,0.2_medtok_chx_ql_amp
#    iuxray_qa_adapted_reports_filename: None
#    mimiccxr_qa_adapted_reports_filename: None
#    vocab_min_freq: 5
#    embed_size: 128
#    question_encoding: bilstm
#    question_hidden_size: 128
#    answer_hidden_size: 128
#    n_lstm_layers: 1
#    question_vec_size: 128
#    image_local_feat_size: 1024
#    dropout_prob: 0
#    densenet_pretrained_weights_path:
#    lr: 0.001
#    lr_decay: 0.76
#    lr_decay_patience: 2
#    n_val_examples_per_question: 10
#    min_train_examples_per_question: 100
#    batch_size: 150
#    num_workers: 7
#    device: GPU
#    img_aug_mode: None
#    freeze_cnn: False
#    mimiccxr_weight: 0.73
#    chexpert_weight: 0.2
# ...

# %% [markdown]
# ### Training-Validation plots

# %%
from medvqa.evaluation.plots import plot_train_val_curves
from medvqa.utils.constants import MetricNames

# %%
plot_train_val_curves('/home/pamessina/medvqa-workspace/models/vqa/20220717_155233_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(dense121+onehot+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretr,frozen)_cnn-pretr=0_dws=0.73,0.15,0.07,0.03,0.2_medtok_chx_ql_amp/metrics_logs.csv',
                 [MetricNames.WMEDCOMP, MetricNames.CIDER_D, MetricNames.EXACTMATCH_ANSWER,
                  MetricNames.CHXLABELMACROAVGF1, MetricNames.CHXLABELMICROAVGF1,
                  MetricNames.CHXLABELACC,
                  MetricNames.CHXLABEL_ROCAUC_MACRO, MetricNames.CHXLABEL_ROCAUC_MICRO,
                 ],
                 ['Weighted Medical Completeness (QA)', 'cider-D (QA)', 'Exact Match (QA)',
                  'Chexpert-F1 (Macro Avg)', 'Chexpert-F1 (Micro Avg)',
                  'Chexpert Acc',
                  'Chexpert ROC-AUC (Macro Avg)', 'Chexpert ROC-AUC (Micro Avg)',
                 ],
                 single_plot_figsize=(8,6))

# %% [markdown]
# # Test Set Evaluation

# %% [markdown]
# # Report-level Results

# %%
# !python ../eval_report_generation.py \
        --checkpoint-folder "models/vqa/20220717_155233_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(dense121+onehot+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretr,frozen)_cnn-pretr=0_dws=0.73,0.15,0.07,0.03,0.2_medtok_chx_ql_amp" \
        --eval-mode "ground-truth" \
        --no-iuxray \
        --batch-size 160
# Out:
# script's arguments:
#    checkpoint_folder: models/vqa/20220717_155233_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(dense121+onehot+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretr,frozen)_cnn-pretr=0_dws=0.73,0.15,0.07,0.03,0.2_medtok_chx_ql_amp
#    eval_mode: ground-truth
#    n_questions_per_report: None
#    qclass_threshold: 0
#    batch_size: 160
#    device: GPU
#    num_workers: 0
#    answer_decoding: greedy-search
#    eval_checkpoint_folder: None
#    eval_iuxray: False
#    eval_mimiccxr: True
#    use_amp: False
# ----- Evaluating model ------
# metadata loaded from /home/pamessina/medvqa-workspace/models/vqa/20220717_155233_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(dense121+onehot+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretr,frozen)_cnn-pretr=0_dws=0.73,0.15,0.07,0.03,0.2_medtok_chx_ql_amp/metadata.json
# 1) device = cuda
# 2) Loading iuxray and mimiccxr QA adapted reports ...
# 3) Initializing tokenizer ...
# ...

# %%
# !python ../eval_report_generation.py \
        --checkpoint-folder "models/vqa/20220717_155233_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(dense121+onehot+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretr,frozen)_cnn-pretr=0_dws=0.73,0.15,0.07,0.03,0.2_medtok_chx_ql_amp" \
        --eval-mode "chexpert-labels" \
        --no-iuxray \
        --batch-size 160
# Out:
# script's arguments:
#    checkpoint_folder: models/vqa/20220717_155233_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(dense121+onehot+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretr,frozen)_cnn-pretr=0_dws=0.73,0.15,0.07,0.03,0.2_medtok_chx_ql_amp
#    eval_mode: chexpert-labels
#    n_questions_per_report: None
#    qclass_threshold: 0
#    batch_size: 160
#    device: GPU
#    num_workers: 0
#    answer_decoding: greedy-search
#    eval_checkpoint_folder: None
#    eval_iuxray: False
#    eval_mimiccxr: True
#    use_amp: False
# ----- Evaluating model ------
# metadata loaded from /home/pamessina/medvqa-workspace/models/vqa/20220717_155233_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(dense121+onehot+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretr,frozen)_cnn-pretr=0_dws=0.73,0.15,0.07,0.03,0.2_medtok_chx_ql_amp/metadata.json
# 1) device = cuda
# 2) Loading iuxray and mimiccxr QA adapted reports ...
# 3) Initializing tokenizer ...
# ...

# %%
# !python ../eval_report_generation.py \
        --checkpoint-folder "models/vqa/20220717_155233_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(dense121+onehot+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretr,frozen)_cnn-pretr=0_dws=0.73,0.15,0.07,0.03,0.2_medtok_chx_ql_amp" \
        --eval-mode "question-classification" \
        --n-questions-per-report 20 \
        --qclass-threshold 0.25 \
        --no-iuxray \
        --batch-size 160
# Out:
# script's arguments:
#    checkpoint_folder: models/vqa/20220717_155233_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(dense121+onehot+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretr,frozen)_cnn-pretr=0_dws=0.73,0.15,0.07,0.03,0.2_medtok_chx_ql_amp
#    eval_mode: question-classification
#    n_questions_per_report: 20
#    qclass_threshold: 0.25
#    batch_size: 160
#    device: GPU
#    num_workers: 0
#    answer_decoding: greedy-search
#    eval_checkpoint_folder: None
#    eval_iuxray: False
#    eval_mimiccxr: True
#    use_amp: False
# ----- Evaluating model ------
# metadata loaded from /home/pamessina/medvqa-workspace/models/vqa/20220717_155233_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(dense121+onehot+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretr,frozen)_cnn-pretr=0_dws=0.73,0.15,0.07,0.03,0.2_medtok_chx_ql_amp/metadata.json
# 1) device = cuda
# 2) Loading iuxray and mimiccxr QA adapted reports ...
# ...

# %%
# !python ../eval_report_generation.py \
        --checkpoint-folder "models/vqa/20220717_155233_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(dense121+onehot+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretr,frozen)_cnn-pretr=0_dws=0.73,0.15,0.07,0.03,0.2_medtok_chx_ql_amp" \
        --eval-mode "question-classification" \
        --n-questions-per-report 20 \
        --qclass-threshold 0.45 \
        --no-iuxray \
        --batch-size 160
# Out:
# script's arguments:
#    checkpoint_folder: models/vqa/20220717_155233_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(dense121+onehot+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretr,frozen)_cnn-pretr=0_dws=0.73,0.15,0.07,0.03,0.2_medtok_chx_ql_amp
#    eval_mode: question-classification
#    n_questions_per_report: 20
#    qclass_threshold: 0.45
#    batch_size: 160
#    device: GPU
#    num_workers: 0
#    answer_decoding: greedy-search
#    eval_checkpoint_folder: None
#    eval_iuxray: False
#    eval_mimiccxr: True
#    use_amp: False
# ----- Evaluating model ------
# metadata loaded from /home/pamessina/medvqa-workspace/models/vqa/20220717_155233_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(dense121+onehot+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretr,frozen)_cnn-pretr=0_dws=0.73,0.15,0.07,0.03,0.2_medtok_chx_ql_amp/metadata.json
# 1) device = cuda
# 2) Loading iuxray and mimiccxr QA adapted reports ...
# ...

# %%
# !python ../eval_report_generation.py \
        --checkpoint-folder "models/vqa/20220717_155233_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(dense121+onehot+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretr,frozen)_cnn-pretr=0_dws=0.73,0.15,0.07,0.03,0.2_medtok_chx_ql_amp" \
        --eval-mode "question-classification" \
        --n-questions-per-report 20 \
        --qclass-threshold 0.7 \
        --no-iuxray \
        --batch-size 160
# Out:
# script's arguments:
#    checkpoint_folder: models/vqa/20220717_155233_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(dense121+onehot+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretr,frozen)_cnn-pretr=0_dws=0.73,0.15,0.07,0.03,0.2_medtok_chx_ql_amp
#    eval_mode: question-classification
#    n_questions_per_report: 20
#    qclass_threshold: 0.7
#    batch_size: 160
#    device: GPU
#    num_workers: 0
#    answer_decoding: greedy-search
#    eval_checkpoint_folder: None
#    eval_iuxray: False
#    eval_mimiccxr: True
#    use_amp: False
# ----- Evaluating model ------
# metadata loaded from /home/pamessina/medvqa-workspace/models/vqa/20220717_155233_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(dense121+onehot+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretr,frozen)_cnn-pretr=0_dws=0.73,0.15,0.07,0.03,0.2_medtok_chx_ql_amp/metadata.json
# 1) device = cuda
# 2) Loading iuxray and mimiccxr QA adapted reports ...
# ...

# %%
from medvqa.evaluation.report_generation import get_report_level_metrics_dataframe

# %% [markdown]
# ### MIMIC-CXR metrics

# %%
df = get_report_level_metrics_dataframe([
    '/home/pamessina/medvqa-workspace/results/vqa/20220717_155233_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(dense121+onehot+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretr,frozen)_cnn-pretr=0_dws=0.73,0.15,0.07,0.03,0.2_medtok_chx_ql_amp/mimiccxr_report_level_metrics(eval_mode=ground-truth).pkl',
    '/home/pamessina/medvqa-workspace/results/vqa/20220717_155233_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(dense121+onehot+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretr,frozen)_cnn-pretr=0_dws=0.73,0.15,0.07,0.03,0.2_medtok_chx_ql_amp/mimiccxr_report_level_metrics(eval_mode=chexpert-labels).pkl',
    '/home/pamessina/medvqa-workspace/results/vqa/20220717_155233_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(dense121+onehot+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretr,frozen)_cnn-pretr=0_dws=0.73,0.15,0.07,0.03,0.2_medtok_chx_ql_amp/mimiccxr_report_level_metrics(eval_mode=question-classification;n_q_per_report=20;qclass_threshold=0.25;chkpt=20220717_155233).pkl',
    '/home/pamessina/medvqa-workspace/results/vqa/20220717_155233_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(dense121+onehot+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretr,frozen)_cnn-pretr=0_dws=0.73,0.15,0.07,0.03,0.2_medtok_chx_ql_amp/mimiccxr_report_level_metrics(eval_mode=question-classification;n_q_per_report=20;qclass_threshold=0.45;chkpt=20220717_155233).pkl',
    '/home/pamessina/medvqa-workspace/results/vqa/20220717_155233_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(dense121+onehot+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretr,frozen)_cnn-pretr=0_dws=0.73,0.15,0.07,0.03,0.2_medtok_chx_ql_amp/mimiccxr_report_level_metrics(eval_mode=question-classification;n_q_per_report=20;qclass_threshold=0.7;chkpt=20220717_155233).pkl',
])
# Out:
#    ** Not cached key: ('/home/pamessina/medvqa-workspace/results/vqa/20220717_155233_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(dense121+onehot+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretr,frozen)_cnn-pretr=0_dws=0.73,0.15,0.07,0.03,0.2_medtok_chx_ql_amp/mimiccxr_report_level_metrics(eval_mode=question-classification;n_q_per_report=20;qclass_threshold=0.7;chkpt=20220717_155233).pkl', 1658106210.7721803)
# Report level metrics updated and saved to /home/pamessina/medvqa-workspace/cache/report_level_metrics_cache.pkl

# %%
df[df.columns[:20]]
# Out:
#                                         metrics_path        b1        b2  \
# 0  /home/pamessina/medvqa-workspace/results/vqa/2...  0.319685  0.189216
# 1  /home/pamessina/medvqa-workspace/results/vqa/2...  0.294169  0.161948
# 2  /home/pamessina/medvqa-workspace/results/vqa/2...  0.156336  0.090119
# 3  /home/pamessina/medvqa-workspace/results/vqa/2...  0.177413  0.100660
# 4  /home/pamessina/medvqa-workspace/results/vqa/2...  0.191388  0.099844
#
#          b3        b4        cD      rg-L       met     mdcmp    wmdcmp  \
# 0  0.108182  0.059751  0.154893  0.266929  0.236349  0.180798  0.162336
# 1  0.091068  0.048143  0.041529  0.197319  0.184132  0.086538  0.065829
# 2  0.049499  0.025834  0.006841  0.162961  0.182722  0.097383  0.083445
# 3  0.054697  0.028416  0.020364  0.172003  0.179341  0.103649  0.088689
# 4  0.051534  0.025385  0.048037  0.175196  0.138827  0.106919  0.090478
#
#    chxlabf1(hard)  p(micro)  r(micro)  f1(micro)  p(macro)  r(macro)  \
# ...
