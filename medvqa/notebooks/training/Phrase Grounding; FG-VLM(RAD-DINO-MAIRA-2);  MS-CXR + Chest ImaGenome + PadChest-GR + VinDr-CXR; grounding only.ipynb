# %%
# %env CUDA_VISIBLE_DEVICES=0
# Out:
# env: CUDA_VISIBLE_DEVICES=0

# %%
# !python ../../train_phrase_grounding.py \
--pretrained_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250726_184906_chst-img-alg+chst-img-pg_PhraseGrounder(microsoft-rad-dino-maira-2,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)" \
--epochs 200 \
--batches_per_epoch 700 \
--max_images_per_batch 8 \
--max_phrases_per_batch 1000 \
--max_phrases_per_image 45 \
--val_batch_size_factor 4 \
--raw_image_encoding "rad-dino-huggingface" \
--huggingface_model_name "microsoft/rad-dino-maira-2" \
--image_size 384 384 \
--image_local_feat_size 768 \
--num_regions 729 \
--regions_width 27 \
--regions_height 27 \
--use_train_data_augmentations \
--phrase_embedding_size 128 \
--phrase_grounding_mode "adaptive_film_based_pooling_mlp_with_bbox_regression" \
--phrase_mlp_hidden_dims 256 128 \
--visual_grounding_hidden_size 256 \
--bbox_format "cxcywh" \
--predict_relative_bbox_coords \
--num_train_workers 4 \
--num_val_workers 4 \
--gradient_accumulation_steps 4 \
--optimizer_name "adamw" \
--scheduler "exp-warmup+decay+cyclicdecay" \
--lr 1e-6 \
--warmup_decay_and_cyclic_decay_args "1e-6,3,2e-5,5,1e-6,2e-5,5,1e-6" \
--binary_multilabel_classif_loss_name "focal+bce+npbbce" \
--do_visual_grounding_with_bbox_regression \
--mimiccxr_exclude_noisy_images \
--use_chest_imagenome_for_train \
--chest_imagenome_augmented_phrase_groundings_filepath \
"/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/chest_imagenome/augmented_groundings_(hash=328,857478564560124280).pkl" \
--chest_imagenome_phrase_embeddings_filepath \
"/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/chest_imagenome/chest_imagenome_phrase_embeddings_(hash=531,1962336077955156067).pkl" \
--chest_imagenome_bbox_phrase_embeddings_filepath \
"/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/chest_imagenome/bbox_phrase_embeddings_hybrid(hash=493,1727013299556214953).pkl" \
--use_mscxr_for_train \
--use_mscxr_for_val \
--mscxr_training_data_mode "train" \
--mscxr_do_grounding_only \
--mscxr_phrase2embedding_filepath \
"/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/mimiccxr/mscxr_phrase2embedding(hash=36540,735014075025888377).pkl" \
--use_padchest_gr_for_train \
--use_padchest_gr_for_val \
--padchest_gr_phrase_embeddings_filepath \
"/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/padchest/padchest_gr_phrase2embedding(hash=197637,3883807560112046018).pkl" \
--padchest_gr_training_split "train" \
--use_vinbig_for_train \
--use_vinbig_for_test \
--vinbig_phrase_embeddings_filepath \
"/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/vinbig/label_phrase_embeddings(hash=553,547344555309613415).pkl" \
--vinbig_training_data_mode "train" \
--vinbig_task_mode "grounding" \
--chest_imagenome_pg_weight 1.0 \
--chest_imagenome_alg_weight 1.0 \
--mscxr_weight  1.0 \
--vinbig_weight 1.0 \
--padchest_gr_weight 1.0 \
--skip_nms \
--use_amp \
--save
# Out:
# 2025-07-27 06:02:37,525 - INFO - root - Logging configured (Color: True).
# 2025-07-27 06:02:37,949 - INFO - medvqa.utils.common -
# script's arguments:
#    epochs: 200
#    batches_per_epoch: 700
#    max_images_per_batch: 8
#    max_phrases_per_batch: 1000
#    max_phrases_per_image: 45
#    val_batch_size_factor: 4.0
#    checkpoint_folder: None
#    pretrained_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250726_184906_chst-img-alg+chst-img-pg_PhraseGrounder(microsoft-rad-dino-maira-2,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)
#    pretrained_checkpoint_folder_paths: None
#    freeze_image_encoder: False
#    raw_image_encoding: rad-dino-huggingface
#    huggingface_model_name: microsoft/rad-dino-maira-2
#    num_regions: 729
#    image_local_feat_size: 768
#    image_encoder_pretrained_weights_path: None
#    image_encoder_dropout_p: 0
#    yolov8_model_name_or_path: None
#    yolov8_model_alias: None
# ...

# %%
# !python ../../train_phrase_grounding.py \
--pretrained_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250726_184906_chst-img-alg+chst-img-pg_PhraseGrounder(microsoft-rad-dino-maira-2,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)" \
--epochs 60 \
--batches_per_epoch 400 \
--max_images_per_batch 8 \
--max_phrases_per_batch 1000 \
--max_phrases_per_image 45 \
--val_batch_size_factor 4 \
--raw_image_encoding "rad-dino-huggingface" \
--huggingface_model_name "microsoft/rad-dino-maira-2" \
--image_size 384 384 \
--image_local_feat_size 768 \
--num_regions 729 \
--regions_width 27 \
--regions_height 27 \
--use_train_data_augmentations \
--phrase_embedding_size 128 \
--phrase_grounding_mode "adaptive_film_based_pooling_mlp_with_bbox_regression" \
--phrase_mlp_hidden_dims 256 128 \
--visual_grounding_hidden_size 256 \
--bbox_format "cxcywh" \
--predict_relative_bbox_coords \
--num_train_workers 4 \
--num_val_workers 4 \
--gradient_accumulation_steps 4 \
--optimizer_name "adamw" \
--scheduler "exp-warmup+decay+cyclicdecay" \
--lr 1e-6 \
--warmup_decay_and_cyclic_decay_args "1e-6,3,2e-5,5,1e-6,2e-5,5,1e-6" \
--binary_multilabel_classif_loss_name "focal+bce+npbbce" \
--do_visual_grounding_with_bbox_regression \
--mimiccxr_exclude_noisy_images \
--use_chest_imagenome_for_train \
--chest_imagenome_augmented_phrase_groundings_filepath \
"/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/chest_imagenome/augmented_groundings_(hash=328,857478564560124280).pkl" \
--chest_imagenome_phrase_embeddings_filepath \
"/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/chest_imagenome/chest_imagenome_phrase_embeddings_(hash=531,1962336077955156067).pkl" \
--chest_imagenome_bbox_phrase_embeddings_filepath \
"/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/chest_imagenome/bbox_phrase_embeddings_hybrid(hash=493,1727013299556214953).pkl" \
--use_mscxr_for_train \
--use_mscxr_for_val \
--mscxr_training_data_mode "train" \
--mscxr_do_grounding_only \
--mscxr_phrase2embedding_filepath \
"/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/mimiccxr/mscxr_phrase2embedding(hash=36540,735014075025888377).pkl" \
--use_padchest_gr_for_train \
--padchest_gr_phrase_embeddings_filepath \
"/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/padchest/padchest_gr_phrase2embedding(hash=197637,3883807560112046018).pkl" \
--padchest_gr_training_split "train" \
--use_vinbig_for_train \
--vinbig_phrase_embeddings_filepath \
"/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/vinbig/label_phrase_embeddings(hash=553,547344555309613415).pkl" \
--vinbig_training_data_mode "train" \
--vinbig_task_mode "grounding" \
--chest_imagenome_pg_weight 1.0 \
--chest_imagenome_alg_weight 1.0 \
--mscxr_weight  0.5 \
--vinbig_weight 1.0 \
--padchest_gr_weight 1.0 \
--skip_nms \
--use_amp \
--save
# Out:
# 2025-07-27 12:54:28,980 - INFO - root - Logging configured (Color: True).
# 2025-07-27 12:54:29,427 - INFO - medvqa.utils.common -
# script's arguments:
#    epochs: 60
#    batches_per_epoch: 400
#    max_images_per_batch: 8
#    max_phrases_per_batch: 1000
#    max_phrases_per_image: 45
#    val_batch_size_factor: 4.0
#    checkpoint_folder: None
#    pretrained_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250726_184906_chst-img-alg+chst-img-pg_PhraseGrounder(microsoft-rad-dino-maira-2,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)
#    pretrained_checkpoint_folder_paths: None
#    freeze_image_encoder: False
#    raw_image_encoding: rad-dino-huggingface
#    huggingface_model_name: microsoft/rad-dino-maira-2
#    num_regions: 729
#    image_local_feat_size: 768
#    image_encoder_pretrained_weights_path: None
#    image_encoder_dropout_p: 0
#    yolov8_model_name_or_path: None
#    yolov8_model_alias: None
# ...

# %%
# !python ../../train_phrase_grounding.py \
--checkpoint_folder \
"models/phrase_grounding/20250727_125948_mscxr+chst-img-alg+chst-img-pg+vinbig+padchest-gr_PhraseGrounder(microsoft-rad-dino-maira-2,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)" \
--epochs 100 \
--batches_per_epoch 400 \
--max_images_per_batch 8 \
--max_phrases_per_batch 1000 \
--max_phrases_per_image 45 \
--val_batch_size_factor 4 \
--raw_image_encoding "rad-dino-huggingface" \
--huggingface_model_name "microsoft/rad-dino-maira-2" \
--image_size 384 384 \
--image_local_feat_size 768 \
--num_regions 729 \
--regions_width 27 \
--regions_height 27 \
--use_train_data_augmentations \
--phrase_embedding_size 128 \
--phrase_grounding_mode "adaptive_film_based_pooling_mlp_with_bbox_regression" \
--phrase_mlp_hidden_dims 256 128 \
--visual_grounding_hidden_size 256 \
--bbox_format "cxcywh" \
--predict_relative_bbox_coords \
--num_train_workers 4 \
--num_val_workers 4 \
--gradient_accumulation_steps 4 \
--optimizer_name "adamw" \
--scheduler "exp-warmup+decay+cyclicdecay" \
--lr 1e-6 \
--warmup_decay_and_cyclic_decay_args "1e-6,3,2e-5,5,1e-6,2e-5,5,1e-6" \
--binary_multilabel_classif_loss_name "focal+bce+npbbce" \
--do_visual_grounding_with_bbox_regression \
--mimiccxr_exclude_noisy_images \
--use_chest_imagenome_for_train \
--chest_imagenome_augmented_phrase_groundings_filepath \
"/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/chest_imagenome/augmented_groundings_(hash=328,857478564560124280).pkl" \
--chest_imagenome_phrase_embeddings_filepath \
"/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/chest_imagenome/chest_imagenome_phrase_embeddings_(hash=531,1962336077955156067).pkl" \
--chest_imagenome_bbox_phrase_embeddings_filepath \
"/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/chest_imagenome/bbox_phrase_embeddings_hybrid(hash=493,1727013299556214953).pkl" \
--use_mscxr_for_train \
--use_mscxr_for_val \
--mscxr_training_data_mode "train" \
--mscxr_do_grounding_only \
--mscxr_phrase2embedding_filepath \
"/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/mimiccxr/mscxr_phrase2embedding(hash=36540,735014075025888377).pkl" \
--use_padchest_gr_for_train \
--padchest_gr_phrase_embeddings_filepath \
"/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/padchest/padchest_gr_phrase2embedding(hash=197637,3883807560112046018).pkl" \
--padchest_gr_training_split "train" \
--use_vinbig_for_train \
--vinbig_phrase_embeddings_filepath \
"/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/vinbig/label_phrase_embeddings(hash=553,547344555309613415).pkl" \
--vinbig_training_data_mode "train" \
--vinbig_task_mode "grounding" \
--chest_imagenome_pg_weight 1.0 \
--chest_imagenome_alg_weight 1.0 \
--mscxr_weight  0.5 \
--vinbig_weight 1.0 \
--padchest_gr_weight 1.0 \
--skip_nms \
--use_amp \
--save
# Out:
# 2025-07-27 15:31:57,076 - INFO - root - Logging configured (Color: True).
# 2025-07-27 15:31:57,499 - INFO - medvqa.utils.common -
# script's arguments:
#    epochs: 100
#    batches_per_epoch: 400
#    max_images_per_batch: 8
#    max_phrases_per_batch: 1000
#    max_phrases_per_image: 45
#    val_batch_size_factor: 4.0
#    checkpoint_folder: models/phrase_grounding/20250727_125948_mscxr+chst-img-alg+chst-img-pg+vinbig+padchest-gr_PhraseGrounder(microsoft-rad-dino-maira-2,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)
#    pretrained_checkpoint_folder_path: None
#    pretrained_checkpoint_folder_paths: None
#    freeze_image_encoder: False
#    raw_image_encoding: rad-dino-huggingface
#    huggingface_model_name: microsoft/rad-dino-maira-2
#    num_regions: 729
#    image_local_feat_size: 768
#    image_encoder_pretrained_weights_path: None
#    image_encoder_dropout_p: 0
#    yolov8_model_name_or_path: None
#    yolov8_model_alias: None
#    phrase_embedding_size: 128
# ...

# %%
# !python ../../train_phrase_grounding.py \
# --pretrained_checkpoint_folder_path \
# "/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250726_184906_chst-img-alg+chst-img-pg_PhraseGrounder(microsoft-rad-dino-maira-2,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)" \
# --epochs 300 \
# --batches_per_epoch 700 \
# --max_images_per_batch 8 \
# --max_phrases_per_batch 1000 \
# --max_phrases_per_image 45 \
# --val_batch_size_factor 4 \
# --raw_image_encoding "rad-dino-huggingface" \
# --huggingface_model_name "microsoft/rad-dino-maira-2" \
# --image_size 448 448 \
# --image_local_feat_size 768 \
# --num_regions 1024 \
# --regions_width 32 \
# --regions_height 32 \
# --use_train_data_augmentations \
# --phrase_embedding_size 128 \
# --phrase_grounding_mode "adaptive_film_based_pooling_mlp_with_bbox_regression" \
# --phrase_mlp_hidden_dims 256 128 \
# --visual_grounding_hidden_size 256 \
# --bbox_format "cxcywh" \
# --predict_relative_bbox_coords \
# --num_train_workers 4 \
# --num_val_workers 4 \
# --gradient_accumulation_steps 4 \
# --optimizer_name "adamw" \
# --scheduler "exp-warmup+decay+cyclicdecay" \
# --lr 1e-6 \
# --warmup_decay_and_cyclic_decay_args "1e-6,3,2e-5,5,1e-6,2e-5,5,1e-6" \
# --binary_multilabel_classif_loss_name "focal+bce+npbbce" \
# --do_visual_grounding_with_bbox_regression \
# --mimiccxr_exclude_noisy_images \
# --use_chest_imagenome_for_train \
# --chest_imagenome_augmented_phrase_groundings_filepath \
# "/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/chest_imagenome/augmented_groundings_(hash=328,857478564560124280).pkl" \
# --chest_imagenome_phrase_embeddings_filepath \
# "/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/chest_imagenome/chest_imagenome_phrase_embeddings_(hash=531,1962336077955156067).pkl" \
# --chest_imagenome_bbox_phrase_embeddings_filepath \
# "/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/chest_imagenome/bbox_phrase_embeddings_hybrid(hash=493,1727013299556214953).pkl" \
# --use_mscxr_for_train \
# --use_mscxr_for_val \
# --mscxr_training_data_mode "train" \
# --mscxr_do_grounding_only \
# --mscxr_phrase2embedding_filepath \
# "/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/mimiccxr/mscxr_phrase2embedding(hash=36540,735014075025888377).pkl" \
# --use_padchest_gr_for_train \
# --use_padchest_gr_for_val \
# --padchest_gr_phrase_embeddings_filepath \
# "/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/padchest/padchest_gr_phrase2embedding(hash=197637,3883807560112046018).pkl" \
# --padchest_gr_training_split "train" \
# --use_vinbig_for_train \
# --use_vinbig_for_test \
# --vinbig_phrase_embeddings_filepath \
# "/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/vinbig/label_phrase_embeddings(hash=553,547344555309613415).pkl" \
# --vinbig_training_data_mode "train" \
# --vinbig_task_mode "grounding" \
# --chest_imagenome_pg_weight 1.0 \
# --chest_imagenome_alg_weight 1.0 \
# --mscxr_weight  0.5 \
# --vinbig_weight 1.0 \
# --padchest_gr_weight 1.0 \
# --skip_nms \
# --use_soft_dice \
# --use_amp \
# --save


# --use_chest_imagenome_for_train \
# --chest_imagenome_augmented_phrase_groundings_filepath \
# "/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/chest_imagenome/augmented_groundings_(hash=328,857478564560124280).pkl" \
# --chest_imagenome_phrase_embeddings_filepath \
# "/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/chest_imagenome/chest_imagenome_phrase_embeddings_(hash=531,1962336077955156067).pkl" \
# --chest_imagenome_bbox_phrase_embeddings_filepath \
# "/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/chest_imagenome/bbox_phrase_embeddings_hybrid(hash=493,1727013299556214953).pkl" \

# --use_mscxr_for_train \
# --use_mscxr_for_val \
# --mscxr_training_data_mode "train" \
# --mscxr_do_grounding_only \
# --mscxr_phrase2embedding_filepath \
# "/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/mimiccxr/mscxr_phrase2embedding(hash=36540,735014075025888377).pkl" \

# --use_padchest_gr_for_train \
# --use_padchest_gr_for_val \
# --padchest_gr_phrase_embeddings_filepath \
# "/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/padchest/padchest_gr_phrase2embedding(hash=197637,3883807560112046018).pkl" \
# --padchest_gr_training_split "train" \

# --use_vinbig_for_train \
# --use_vinbig_for_test \
# --vinbig_phrase_embeddings_filepath \
# "/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/vinbig/label_phrase_embeddings(hash=553,547344555309613415).pkl" \
# --vinbig_training_data_mode "train" \
# --vinbig_task_mode "grounding" \

# --chest_imagenome_pg_weight 1.0 \
# --chest_imagenome_alg_weight 1.0 \
# --mscxr_weight  0.5 \
# --vinbig_weight 1.0 \
# --padchest_gr_weight 1.0 \


# !python ../../train_phrase_grounding.py \
--pretrained_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250726_184906_chst-img-alg+chst-img-pg_PhraseGrounder(microsoft-rad-dino-maira-2,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)" \
--epochs 200 \
--batches_per_epoch 1000 \
--max_images_per_batch 5 \
--max_phrases_per_batch 1000 \
--max_phrases_per_image 45 \
--val_batch_size_factor 4 \
--raw_image_encoding "rad-dino-huggingface" \
--huggingface_model_name "microsoft/rad-dino-maira-2" \
--image_size 448 448 \
--image_local_feat_size 768 \
--num_regions 1024 \
--regions_width 32 \
--regions_height 32 \
--use_train_data_augmentations \
--phrase_embedding_size 128 \
--phrase_grounding_mode "adaptive_film_based_pooling_mlp_with_bbox_regression" \
--phrase_mlp_hidden_dims 256 128 \
--visual_grounding_hidden_size 256 \
--bbox_format "cxcywh" \
--predict_relative_bbox_coords \
--num_train_workers 4 \
--num_val_workers 4 \
--gradient_accumulation_steps 4 \
--optimizer_name "adamw" \
--scheduler "exp-warmup+decay+cyclicdecay" \
--lr 1e-6 \
--warmup_decay_and_cyclic_decay_args "1e-6,3,2e-5,5,1e-6,2e-5,5,1e-6" \
--binary_multilabel_classif_loss_name "focal+bce+npbbce" \
--do_visual_grounding_with_bbox_regression \
--mimiccxr_exclude_noisy_images \
--use_chest_imagenome_for_train \
--chest_imagenome_augmented_phrase_groundings_filepath \
"/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/chest_imagenome/augmented_groundings_(hash=328,857478564560124280).pkl" \
--chest_imagenome_phrase_embeddings_filepath \
"/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/chest_imagenome/chest_imagenome_phrase_embeddings_(hash=531,1962336077955156067).pkl" \
--chest_imagenome_bbox_phrase_embeddings_filepath \
"/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/chest_imagenome/bbox_phrase_embeddings_hybrid(hash=493,1727013299556214953).pkl" \
--use_mscxr_for_train \
--use_mscxr_for_val \
--mscxr_training_data_mode "train" \
--mscxr_do_grounding_only \
--mscxr_phrase2embedding_filepath \
"/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/mimiccxr/mscxr_phrase2embedding(hash=36540,735014075025888377).pkl" \
--use_padchest_gr_for_train \
--use_padchest_gr_for_val \
--padchest_gr_phrase_embeddings_filepath \
"/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/padchest/padchest_gr_phrase2embedding(hash=197637,3883807560112046018).pkl" \
--padchest_gr_training_split "train" \
--use_vinbig_for_train \
--use_vinbig_for_test \
--vinbig_phrase_embeddings_filepath \
"/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/vinbig/label_phrase_embeddings(hash=553,547344555309613415).pkl" \
--vinbig_training_data_mode "train" \
--vinbig_task_mode "grounding" \
--chest_imagenome_pg_weight 1.0 \
--chest_imagenome_alg_weight 1.0 \
--mscxr_weight  0.5 \
--vinbig_weight 1.0 \
--padchest_gr_weight 1.0 \
--skip_nms \
--use_soft_dice \
--use_amp \
--save
# Out:
# 2025-08-17 14:33:58,776 - INFO - root - Logging configured (Color: True).
# 2025-08-17 14:33:59,219 - INFO - medvqa.utils.common -
# script's arguments:
#    epochs: 200
#    batches_per_epoch: 1000
#    max_images_per_batch: 5
#    max_phrases_per_batch: 1000
#    max_phrases_per_image: 45
#    val_batch_size_factor: 4.0
#    checkpoint_folder: None
#    pretrained_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250726_184906_chst-img-alg+chst-img-pg_PhraseGrounder(microsoft-rad-dino-maira-2,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)
#    pretrained_checkpoint_folder_paths: None
#    freeze_image_encoder: False
#    raw_image_encoding: rad-dino-huggingface
#    huggingface_model_name: microsoft/rad-dino-maira-2
#    num_regions: 1024
#    image_local_feat_size: 768
#    image_encoder_pretrained_weights_path: None
#    image_encoder_dropout_p: 0
#    yolov8_model_name_or_path: None
#    yolov8_model_alias: None
# ...

# %%
# !python ../../train_phrase_grounding.py \
--checkpoint_folder \
"models/phrase_grounding/20250817_143800_mscxr+chst-img-alg+chst-img-pg+vinbig+padchest-gr_PhraseGrounder(microsoft-rad-dino-maira-2,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)" \
--epochs 100 \
--batches_per_epoch 1000 \
--max_images_per_batch 5 \
--max_phrases_per_batch 1000 \
--max_phrases_per_image 45 \
--val_batch_size_factor 4 \
--raw_image_encoding "rad-dino-huggingface" \
--huggingface_model_name "microsoft/rad-dino-maira-2" \
--image_size 448 448 \
--image_local_feat_size 768 \
--num_regions 1024 \
--regions_width 32 \
--regions_height 32 \
--use_train_data_augmentations \
--phrase_embedding_size 128 \
--phrase_grounding_mode "adaptive_film_based_pooling_mlp_with_bbox_regression" \
--phrase_mlp_hidden_dims 256 128 \
--visual_grounding_hidden_size 256 \
--bbox_format "cxcywh" \
--predict_relative_bbox_coords \
--num_train_workers 4 \
--num_val_workers 4 \
--gradient_accumulation_steps 4 \
--optimizer_name "adamw" \
--scheduler "exp-warmup+decay+cyclicdecay" \
--lr 1e-6 \
--warmup_decay_and_cyclic_decay_args "1e-6,3,2e-5,5,1e-6,2e-5,5,1e-6" \
--binary_multilabel_classif_loss_name "focal+bce+npbbce" \
--do_visual_grounding_with_bbox_regression \
--mimiccxr_exclude_noisy_images \
--use_chest_imagenome_for_train \
--chest_imagenome_augmented_phrase_groundings_filepath \
"/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/chest_imagenome/augmented_groundings_(hash=328,857478564560124280).pkl" \
--chest_imagenome_phrase_embeddings_filepath \
"/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/chest_imagenome/chest_imagenome_phrase_embeddings_(hash=531,1962336077955156067).pkl" \
--chest_imagenome_bbox_phrase_embeddings_filepath \
"/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/chest_imagenome/bbox_phrase_embeddings_hybrid(hash=493,1727013299556214953).pkl" \
--use_mscxr_for_train \
--use_mscxr_for_val \
--mscxr_training_data_mode "train" \
--mscxr_do_grounding_only \
--mscxr_phrase2embedding_filepath \
"/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/mimiccxr/mscxr_phrase2embedding(hash=36540,735014075025888377).pkl" \
--use_padchest_gr_for_train \
--use_padchest_gr_for_val \
--padchest_gr_phrase_embeddings_filepath \
"/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/padchest/padchest_gr_phrase2embedding(hash=197637,3883807560112046018).pkl" \
--padchest_gr_training_split "train" \
--use_vinbig_for_train \
--use_vinbig_for_test \
--vinbig_phrase_embeddings_filepath \
"/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/vinbig/label_phrase_embeddings(hash=553,547344555309613415).pkl" \
--vinbig_training_data_mode "train" \
--vinbig_task_mode "grounding" \
--chest_imagenome_pg_weight 1.0 \
--chest_imagenome_alg_weight 1.0 \
--mscxr_weight  0.5 \
--vinbig_weight 1.0 \
--padchest_gr_weight 1.0 \
--skip_nms \
--use_soft_dice \
--use_amp \
--save
# Out:
# 2025-08-18 09:39:23,294 - INFO - root - Logging configured (Color: True).
# 2025-08-18 09:39:23,733 - INFO - medvqa.utils.common -
# script's arguments:
#    epochs: 100
#    batches_per_epoch: 1000
#    max_images_per_batch: 5
#    max_phrases_per_batch: 1000
#    max_phrases_per_image: 45
#    val_batch_size_factor: 4.0
#    checkpoint_folder: models/phrase_grounding/20250817_143800_mscxr+chst-img-alg+chst-img-pg+vinbig+padchest-gr_PhraseGrounder(microsoft-rad-dino-maira-2,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)
#    pretrained_checkpoint_folder_path: None
#    pretrained_checkpoint_folder_paths: None
#    freeze_image_encoder: False
#    raw_image_encoding: rad-dino-huggingface
#    huggingface_model_name: microsoft/rad-dino-maira-2
#    num_regions: 1024
#    image_local_feat_size: 768
#    image_encoder_pretrained_weights_path: None
#    image_encoder_dropout_p: 0
#    yolov8_model_name_or_path: None
#    yolov8_model_alias: None
#    phrase_embedding_size: 128
# ...
