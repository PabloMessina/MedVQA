# %%
# %env CUDA_VISIBLE_DEVICES=2
# Out:
# env: CUDA_VISIBLE_DEVICES=2

# %%
# !python ../train_phrase_grounding.py \
--pretrained_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240825_115146_mim-facts+chst-img-anat+cxrlt2024(Off)+cxrlt2024(GPT4)+vinbig+chexloc+chxp+iuxray_PhraseGrounder(aehrc-cxrmate-rrg24,FiLM_SigmoidAttention,128,256,256,256,1,256-128)/" \
--epochs 100 \
--batches_per_epoch 1200 \
--max_images_per_batch 10 \
--max_phrases_per_batch 400 \
--max_phrases_per_image 45 \
--val_batch_size_factor 5.0 \
--raw_image_encoding "cxrmate-rrg24-uniformer-huggingface" \
--huggingface_model_name "aehrc/cxrmate-rrg24" \
--img_aug_mode "random-color-and-spatial" \
--image_size 384 384 \
--image_local_feat_size 512 \
--num_regions 144 \
--regions_width 12 \
--regions_height 12 \
--phrase_embedding_size 128 \
--phrase_grounding_mode "film_layers_plus_sigmoid_attention_and_custom_classifier" \
--visual_feature_proj_size 256 \
--visual_grounding_hidden_size 256 \
--phrase_mlp_hidden_dims 256 128 \
--predict_global_alignment \
--alignment_proj_size 128 \
--num_train_workers 2 \
--num_val_workers 2 \
--gradient_accumulation_steps 10 \
--optimizer_name "adamw" \
--scheduler "exp-warmup+decay+cyclicdecay" \
--lr 1e-6 \
--warmup_decay_and_cyclic_decay_args "1e-6,3,8e-5,5,1e-6,8e-5,5,1e-6" \
--mimiccxr_exclude_noisy_images \
--binary_multilabel_classif_loss_name "focal+bce+npbbce" \
--use_attention_regularization_loss \
--attention_supervision_loss_weight 2.0 \
--phrase_classifier_loss_weight 2.0 \
--foreground_loss_weight 1.5 \
--use_cxrlt2024_challenge_split \
--cxrlt2024_do_balanced_sampling \
--use_cxrlt2024_official_labels \
--use_all_cxrlt2024_official_labels_for_training \
--cxrlt2024_official_training_labels_for_fact_classification_filepath \
"/mnt/workspace/pamessina/medvqa-workspace/cache/mimiccxr/cxrlt2024_official_training_labels_for_fact_classification(n_train=240529,n_val=18342,pf=0.03).pkl" \
--use_cxrlt2024_custom_labels \
--cxrlt2024_custom_dicom_id_to_pos_neg_facts_filepath \
"/mnt/workspace/pamessina/medvqa-workspace/cache/mimiccxr/cxrlt2024_integrated_nli_queries_for_fact_classification.pkl" \
--use_mimiccxr_facts_for_train \
--dicom_id_to_pos_neg_facts_filepath \
"/mnt/workspace/pamessina/medvqa-workspace/cache/mimiccxr_dicom_id_to_fact_based_pos_neg_facts(hash=1360,3939902508813076616).pkl" \
--mimiccxr_exclude_noisy_images \
--use_chest_imagenome_for_train \
--chest_imagenome_bbox_phrase_embeddings_filepath \
"/mnt/workspace/pamessina/medvqa-workspace/cache/chest_imagenome/bbox_phrase_embeddings(hash=333,1643894111267724539).pkl" \
--use_vinbig_for_train \
--vinbig_phrase_embeddings_filepath \
"/mnt/workspace/pamessina/medvqa-workspace/cache/vinbig/label_phrase_embeddings(hash=325,2238524744738711392).pkl" \
--vinbig_training_data_mode "all" \
--use_chexlocalize_for_train \
--chexlocalize_class_phrase_embeddings_filepath \
"/mnt/workspace/pamessina/medvqa-workspace/cache/chexlocalize/class_phrase_embeddings(hash=528,2353352898845085012).pkl" \
--use_chexpert_for_train \
--chexpert_class_phrase_embeddings_filepath \
"/mnt/workspace/pamessina/medvqa-workspace/cache/chexpert/class_phrase_embeddings(hash=592,2793798096738783992).pkl" \
--use_iuxray_for_train \
--iuxray_image_id_to_pos_neg_facts_filepath \
"/mnt/workspace/pamessina/medvqa-workspace/cache/iuxray/image_id_to_pos_neg_facts(hash=450,1832071235913899237).pkl" \
--cxrlt2024_weight 6.0 \
--mimiccxr_facts_weight 2.5 \
--chest_imagenome_anatlocs_weight 1.0 \
--iuxray_weight 0.5 \
--vinbig_weight 1.5 \
--chexpert_weight 0.5 \
--chexlocalize_weight 0.4 \
--save
# Out:
# script's arguments:
#    epochs: 100
#    batches_per_epoch: 1200
#    max_images_per_batch: 10
#    max_phrases_per_batch: 400
#    max_phrases_per_image: 45
#    val_batch_size_factor: 5.0
#    checkpoint_folder: None
#    pretrained_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240825_115146_mim-facts+chst-img-anat+cxrlt2024(Off)+cxrlt2024(GPT4)+vinbig+chexloc+chxp+iuxray_PhraseGrounder(aehrc-cxrmate-rrg24,FiLM_SigmoidAttention,128,256,256,256,1,256-128)/
#    pretrained_checkpoint_folder_paths: None
#    freeze_image_encoder: False
#    raw_image_encoding: cxrmate-rrg24-uniformer-huggingface
#    huggingface_model_name: aehrc/cxrmate-rrg24
#    num_regions: 144
#    image_local_feat_size: 512
#    image_encoder_pretrained_weights_path: None
#    image_encoder_dropout_p: 0
#    yolov8_model_name_or_path: None
#    yolov8_model_alias: None
#    phrase_embedding_size: 128
#    regions_width: 12
#    regions_height: 12
#    qkv_size: None
#    phrase_grounding_mode: film_layers_plus_sigmoid_attention_and_custom_classifier
#    phrase_classifier_hidden_size: None
#    transf_d_model: None
#    transf_nhead: None
#    transf_dim_feedforward: None
#    transf_dropout: 0
#    transf_num_layers: None
#    visual_feature_proj_size: 256
#    visual_grounding_hidden_size: 256
#    phrase_mlp_hidden_dims: [256, 128]
#    predict_global_alignment: True
#    alignment_proj_size: 128
#    optimizer_name: adamw
#    lr: 1e-06
#    scheduler: exp-warmup+decay+cyclicdecay
#    lr_decay: 0.76
#    lr_decay_patience: 2
#    warmup_and_decay_args: None
#    warmup_and_cosine_args: None
#    warmup_decay_and_cyclic_decay_args: 1e-6,3,8e-5,5,1e-6,8e-5,5,1e-6
#    gradient_accumulation_steps: 10
#    override_lr: False
#    max_grad_norm: None
#    attention_supervision_loss_weight: 2.0
#    phrase_classifier_loss_weight: 2.0
#    foreground_loss_weight: 1.5
#    background_loss_weight: 1.0
#    focal_loss_weight: 1.0
#    bce_loss_weight: 1.0
#    wbce_loss_weight: 1.0
#    binary_multilabel_classif_loss_name: focal+bce+npbbce
#    use_weighted_phrase_classifier_loss: False
#    cluster_and_label_weights_for_facts_filepath: None
#    use_attention_regularization_loss: True
#    use_contrastive_phrase_grounding_loss: False
#    nt_xent_temperature: 0.1
#    num_train_workers: 2
#    num_val_workers: 2
#    device: GPU
#    use_amp: False
#    image_size: [384, 384]
#    dicom_id_to_pos_neg_facts_filepath: /mnt/workspace/pamessina/medvqa-workspace/cache/mimiccxr_dicom_id_to_fact_based_pos_neg_facts(hash=1360,3939902508813076616).pkl
#    iuxray_image_id_to_pos_neg_facts_filepath: /mnt/workspace/pamessina/medvqa-workspace/cache/iuxray/image_id_to_pos_neg_facts(hash=450,1832071235913899237).pkl
#    mscxr_phrase2embedding_filepath: None
#    chest_imagenome_bbox_phrase_embeddings_filepath: /mnt/workspace/pamessina/medvqa-workspace/cache/chest_imagenome/bbox_phrase_embeddings(hash=333,1643894111267724539).pkl
#    vinbig_phrase_embeddings_filepath: /mnt/workspace/pamessina/medvqa-workspace/cache/vinbig/label_phrase_embeddings(hash=325,2238524744738711392).pkl
#    chexlocalize_class_phrase_embeddings_filepath: /mnt/workspace/pamessina/medvqa-workspace/cache/chexlocalize/class_phrase_embeddings(hash=528,2353352898845085012).pkl
#    chexpert_class_phrase_embeddings_filepath: /mnt/workspace/pamessina/medvqa-workspace/cache/chexpert/class_phrase_embeddings(hash=592,2793798096738783992).pkl
#    mimiccxr_exclude_noisy_images: True
#    mimiccxr_facts_weight: 2.5
#    chest_imagenome_anatlocs_weight: 1.0
#    mscxr_weight: 1.0
#    cxrlt2024_weight: 6.0
#    vinbig_weight: 1.5
#    chexlocalize_weight: 0.4
#    chexpert_weight: 0.5
#    iuxray_weight: 0.5
#    img_aug_mode: random-color-and-spatial
#    pos_area_prior: 0.4
#    neg_area_prior: 0.0
#    use_mimiccxr_facts_for_train: True
#    use_mimiccxr_facts_for_test: False
#    use_mscxr_for_train: False
#    use_mscxr_for_test: False
#    use_chest_imagenome_for_train: True
#    use_chest_imagenome_gold_for_test: False
#    use_vinbig_for_train: True
#    use_vinbig_for_test: False
#    use_chexlocalize_for_train: True
#    use_chexlocalize_for_test: False
#    use_chexpert_for_train: True
#    use_chexpert_for_test: False
#    use_iuxray_for_train: True
#    use_iuxray_for_test: False
#    use_cxrlt2024_challenge_split: True
#    use_cxrlt2024_custom_labels: True
#    use_cxrlt2024_official_labels: True
#    use_all_cxrlt2024_official_labels_for_training: True
#    vinbig_training_data_mode: all
#    chexpert_training_data_mode: all
#    mimiccxr_balance_long_middle_short_tail: False
#    mimiccxr_long_middle_short_tail_thresholds: (0.02, 0.05)
#    mimiccxr_report_fact_nli_integrated_data_filepath: None
#    mimiccxr_use_interpret_cxr_challenge_split: False
#    mimiccxr_interpret_cxr_challenge_split_filepath: None
#    iuxray_use_interpret_cxr_challenge_split: False
#    iuxray_interpret_cxr_challenge_split_filepath: None
#    chexpert_use_interpret_cxr_challenge_split: False
#    chexpert_interpret_cxr_challenge_split_filepath: None
#    chexlocalize_use_interpret_cxr_challenge_split: False
#    chexlocalize_interpret_cxr_challenge_split_filepath: None
#    cxrlt2024_custom_dicom_id_to_pos_neg_facts_filepath: /mnt/workspace/pamessina/medvqa-workspace/cache/mimiccxr/cxrlt2024_integrated_nli_queries_for_fact_classification.pkl
#    cxrlt2024_official_training_labels_for_fact_classification_filepath: /mnt/workspace/pamessina/medvqa-workspace/cache/mimiccxr/cxrlt2024_official_training_labels_for_fact_classification(n_train=240529,n_val=18342,pf=0.03).pkl
#    cxrlt2024_do_balanced_sampling: True
#    save: True
# ----- Training model from scratch ------
# include_loss_weights = False
# source_image_size_mode: medium_512
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Creating instance of PhraseGrounder ...
# WARNING: Unused kwargs: {'pretrained_checkpoint_folder_path': '/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240825_115146_mim-facts+chst-img-anat+cxrlt2024(Off)+cxrlt2024(GPT4)+vinbig+chexloc+chxp+iuxray_PhraseGrounder(aehrc-cxrmate-rrg24,FiLM_SigmoidAttention,128,256,256,256,1,256-128)/', 'pretrained_checkpoint_folder_paths': None}
# MultiPurposeVisualModule()
#   Initializing raw_image_encoder: cxrmate-rrg24-uniformer-huggingface
#   self.global_feat_size = 1024
#   self.local_feat_size = 512
#   Initializing auxiliary tasks
# --------------------------------------------------
# 3) Defining optimizer ...
# create_optimizer(): name = adamw
# --------------------------------------------------
# 4) Defining scheduler ...
# Using exp-warmup+decay+cyclicdecay scheduler: 1e-6,3,8e-5,5,1e-6,8e-5,5,1e-6
# 1e-06 3 8e-05 5 1e-06 8e-05 5 1e-06
# self.steps_to_restart = 5
# self.steps = -1
# self.initial_lr = 8e-05
# --------------------------------------------------
# 5) Creating trainer and validator engines ...
# Focal_BCE_NPBBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 npbbce_weight = 0.3333333333333333
# Focal_BCE_NPBBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 npbbce_weight = 0.3333333333333333
# Focal_BCE_WBCBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 wbcbce_weight = 0.3333333333333333
# foreground_loss_weight: 1.5
# background_loss_weight: 1.0
# GradientAccumulator.__init__(): num_accumulation_steps = 10, max_grad_norm = None
# Focal_BCE_NPBBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 npbbce_weight = 0.3333333333333333
# Focal_BCE_NPBBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 npbbce_weight = 0.3333333333333333
# Focal_BCE_WBCBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 wbcbce_weight = 0.3333333333333333
# foreground_loss_weight: 1.0
# background_loss_weight: 1.0
# --------------------------------------------------
# 6) Creating CheXLocalize Phrase Grounding Trainer ...
# get_image_transform()
#   Using segmentation mask aware transforms
#     len(_augmented_mask_transforms) = 10
#     augmentation_mode = random-color-and-spatial
#     default_prob = 0.4
#     Returning augmented transforms with mode random-color-and-spatial
# get_image_transform()
#   Using segmentation mask aware transforms
#     Returning default transform (no augmentation)
# Loding class_phrase_embeddings_filepath and bbox_phrases from /mnt/workspace/pamessina/medvqa-workspace/cache/chexlocalize/class_phrase_embeddings(hash=528,2353352898845085012).pkl...
# class_phrase_embeddings.shape = (10, 128)
# len(class_phrases) = 10
# 	 enlarged cardiomediastinum seen
# 	 cardiomegaly seen
# 	 lung lesion seen
# 	 airspace opacity seen
# 	 edema seen
# 	 consolidation seen
# 	 atelectasis seen
# 	 pneumothorax seen
# 	 pleural effusion seen
# 	 support devices seen
# Compute phrase grounding masks and labels
# Without masks: 216/902
# Generating train dataset and dataloader
# len(train_indices) = 902
# batch_size = 10
# --------------------------------------------------
# 7) Creating CheXpert Phrase Grounding Trainer ...
# get_image_transform()
#   Using segmentation mask aware transforms
#     len(_augmented_mask_transforms) = 10
#     augmentation_mode = random-color-and-spatial
#     default_prob = 0.4
#     Returning augmented transforms with mode random-color-and-spatial
# get_image_transform()
#   Using segmentation mask aware transforms
#     Returning default transform (no augmentation)
# Loading dataframe from /mnt/workspace/chexpert/CheXpert-v1.0-small/train_visualCheXbert.csv
# len(df_train_visualchexbert) = 223414
# Loading dataframe from /mnt/workspace/chexpert/CheXpert-v1.0-small/valid.csv
# len(df_valid) = 234
# len(df) = 223648
# Loading images
# Loading chexpert labels
# Loading test set
# len(self.test_image_paths) = 668
# self.test_labels.shape = (668, 14)
# Loding phrase_embeddings and phrases from /mnt/workspace/pamessina/medvqa-workspace/cache/chexpert/class_phrase_embeddings(hash=592,2793798096738783992).pkl...
# phrase_embeddings.shape = (14, 128)
# len(phrases) = 14
# 	 no findings
# 	 enlarged cardiomediastinum seen
# 	 cardiomegaly seen
# 	 lung lesion seen
# 	 lung opacity seen
# 	 edema seen
# 	 consolidation seen
# 	 pneumonia seen
# 	 atelectasis seen
# 	 pneumothorax seen
# 	 pleural effusion seen
# 	 other pleural abnormality seen
# 	 fracture seen
# 	 support devices seen
# len(all_image_paths) = 224316
# all_labels.shape = (224316, 14)
# Generating train dataset and dataloader
# len(train_indices) = 224316
# No labels: 3246
# Pneumothorax: 25357
# Pleural Other: 26334
# Lung Lesion: 31042
# No Finding: 35673
# Pneumonia: 52248
# Fracture: 61696
# Edema: 94500
# Pleural Effusion: 103837
# Consolidation: 107297
# Cardiomegaly: 122164
# Atelectasis: 124182
# Support Devices: 136382
# Enlarged Cardiomediastinum: 144377
# Lung Opacity: 151937
# Group sizes: [61397, 30579, 25357, 21626, 18526, 17225, 11525, 11092, 10885, 7083, 4085, 3246, 1170, 347, 173]
#   len(indices) = 61397, weight = 4024.1406302660666
#   len(indices) = 30579, weight = 3308.1179132413095
#   len(indices) = 25357, weight = 3131.4217784165476
#   len(indices) = 21626, weight = 2986.2821261955132
#   len(indices) = 18526, weight = 2849.5564265118087
#   len(indices) = 17225, weight = 2786.68263628706
#   len(indices) = 11525, weight = 2456.265254834705
#   len(indices) = 11092, weight = 2426.215857884437
#   len(indices) = 10885, weight = 2411.5238383991996
#   len(indices) = 7083, weight = 2092.3117139635237
#   len(indices) = 4085, weight = 1726.3245386288693
#   len(indices) = 3246, weight = 1587.0568876515586
#   len(indices) = 1170, weight = 1058.8042504564921
#   len(indices) = 347, weight = 600.9534388852762
#   len(indices) = 173, weight = 410.9393870934724
# --------------------------------------------------
# 8) Creating VinBig Phrase Grounding Trainer ...
# get_image_transform()
#   Using segmentation mask aware transforms
#     len(_augmented_mask_transforms) = 10
#     augmentation_mode = random-color-and-spatial
#     default_prob = 0.4
#     Returning augmented transforms with mode random-color-and-spatial
# get_image_transform()
#   Using segmentation mask aware transforms
#     Returning default transform (no augmentation)
# Loading bounding boxes
# Anomalous bboxes found: 29 of 37367
# class_id_offset: 0
# Anomalous bboxes found: 0 of 2697
# class_id_offset: 0
#   Loaded 18000 bounding boxes
# Loding phrase_embeddings and phrases from /mnt/workspace/pamessina/medvqa-workspace/cache/vinbig/label_phrase_embeddings(hash=325,2238524744738711392).pkl...
# phrase_embeddings.shape = (28, 128)
# len(phrases) = 28
# 	 aortic enlargement seen
# 	 atelectasis seen
# 	 calcification seen
# 	 cardiomegaly seen
# 	 clavicle fracture seen
# 	 consolidation seen
# 	 edema seen
# 	 emphysema seen
# 	 enlarged pulmonary artery seen
# 	 interstitial lung disease seen
# 	 infiltration seen
# 	 lung opacity seen
# 	 lung cavity seen
# 	 lung cyst seen
# 	 mediastinal shift seen
# 	 nodule/mass seen
# 	 pleural effusion seen
# 	 pleural thickening seen
# 	 pneumothorax seen
# 	 pulmonary fibrosis seen
# 	 rib fracture seen
# 	 other lesion seen
# 	 copd seen
# 	 lung tumor seen
# 	 pneumonia seen
# 	 tuberculosis seen
# 	 other disease seen
# 	 no abnormalities seen
# Compute phrase grounding masks and labels
# self.phrase_grounding_masks.shape = (18000, 22, 144)
# self.phrase_classification_labels.shape = (18000, 22)
# Append additional labels to phrase_classification_labels
# len(non_bbox_labels) = 6
# non_bbox_labels = ['COPD', 'Lung tumor', 'Pneumonia', 'Tuberculosis', 'Other disease', 'No finding']
# self.phrase_classification_labels.shape = (18000, 28)
# Reorder phrases and phrase_embeddings
# len(phrases) = 28
# len(actual_phrases) = 28
# phrase_embeddings.shape = (28, 128)
# Generating train dataset and dataloader
# len(train_indices) = 18000
# No labels: 0
# Edema: 13
# Clavicle fracture: 29
# Lung cyst: 35
# COPD: 37
# Lung cavity: 60
# Emphysema: 84
# Rib fracture: 101
# Pneumothorax: 114
# Enlarged PA: 139
# Mediastinal shift: 170
# Atelectasis: 273
# Lung tumor: 371
# Consolidation: 449
# ILD: 618
# Calcification: 652
# Infiltration: 671
# Tuberculosis: 914
# Nodule/Mass: 1017
# Pleural effusion: 1149
# Pneumonia: 1163
# Other lesion: 1248
# Lung Opacity: 1415
# Pulmonary fibrosis: 1838
# Pleural thickening: 2179
# Cardiomegaly: 2625
# Aortic enlargement: 3318
# Other disease: 4945
# No finding: 12652
# Group sizes: [12529, 891, 444, 428, 364, 344, 307, 283, 273, 267, 245, 236, 206, 193, 170, 138, 127, 100, 99, 90, 56, 54, 49, 34, 73]
#   len(indices) = 12529, weight = 2522.6672479595745
#   len(indices) = 891, weight = 940.9850359649141
#   len(indices) = 444, weight = 680.1755171156125
#   len(indices) = 428, weight = 667.9638591411331
#   len(indices) = 364, weight = 615.8160380252455
#   len(indices) = 344, weight = 598.2811252947056
#   len(indices) = 307, weight = 563.9888635691133
#   len(indices) = 283, weight = 540.2796339164162
#   len(indices) = 273, weight = 530.0166624211873
#   len(indices) = 267, weight = 523.7422583945496
#   len(indices) = 245, weight = 499.93058392418243
#   len(indices) = 236, weight = 489.7963928535281
#   len(indices) = 206, weight = 454.1360559561945
#   len(indices) = 193, weight = 437.6702522239849
#   len(indices) = 170, weight = 406.7687016278156
#   len(indices) = 138, weight = 359.20170201154343
#   len(indices) = 127, weight = 341.33933626931963
#   len(indices) = 100, weight = 293.26529386579296
#   len(indices) = 99, weight = 291.34941227248714
#   len(indices) = 90, weight = 273.5936736738282
#   len(indices) = 56, weight = 195.85520038280242
#   len(indices) = 54, weight = 190.5945663000252
#   len(indices) = 49, weight = 177.00354049310113
#   len(indices) = 34, weight = 131.67512839151652
#   len(indices) = 73, weight = 237.15649291307946
# --------------------------------------------------
# 9) Creating MIMIC-CXR Phrase Grounding Trainer ...
# get_image_transform()
#   Using segmentation mask aware transforms
#     len(_augmented_mask_transforms) = 10
#     augmentation_mode = random-color-and-spatial
#     default_prob = 0.4
#     Returning augmented transforms with mode random-color-and-spatial
# get_image_transform()
#   Using segmentation mask aware transforms
#     Returning default transform (no augmentation)
# len(cxrlt2024_train_dicom_ids) = 258871
# len(cxrlt2024_dev_dicom_ids) = 39293
# len(forbidden_train_dicom_ids) = 40220
# Preparing CXR-LT-2024 challenge datasets and dataloaders for training/testing...
# Using image size mode: medium_512
# len(cxrlt2024_dicom_id_to_pos_neg_facts["train"]) = 145680
# len(cxrlt2024_dicom_id_to_pos_neg_facts["dev"]) = 39352
# Total number of images: 184650
# Building cxrlt2024 train phrase classifier dataloader...
# num_phrases = 2, len(indices) = 38366
# num_phrases = 1, len(indices) = 89231
# num_phrases = 3, len(indices) = 12488
# num_phrases = 4, len(indices) = 3658
# num_phrases = 11, len(indices) = 97
# num_phrases = 6, len(indices) = 281
# num_phrases = 5, len(indices) = 937
# num_phrases = 20, len(indices) = 97
# num_phrases = 7, len(indices) = 52
# num_phrases = 16, len(indices) = 48
# num_phrases = 17, len(indices) = 26
# num_phrases = 10, len(indices) = 2
# num_phrases = 8, len(indices) = 13
# num_phrases = 12, len(indices) = 2
# Building cxrlt2024 dev phrase classifier dataloader...
# num_phrases = 2, len(indices) = 7030
# num_phrases = 1, len(indices) = 29823
# num_phrases = 3, len(indices) = 1393
# num_phrases = 12, len(indices) = 77
# num_phrases = 6, len(indices) = 25
# num_phrases = 8, len(indices) = 34
# num_phrases = 14, len(indices) = 74
# num_phrases = 11, len(indices) = 124
# num_phrases = 16, len(indices) = 53
# num_phrases = 4, len(indices) = 294
# num_phrases = 15, len(indices) = 51
# num_phrases = 10, len(indices) = 77
# num_phrases = 9, len(indices) = 32
# num_phrases = 7, len(indices) = 36
# num_phrases = 13, len(indices) = 92
# num_phrases = 20, len(indices) = 54
# num_phrases = 5, len(indices) = 54
# num_phrases = 18, len(indices) = 7
# num_phrases = 17, len(indices) = 18
# num_phrases = 19, len(indices) = 4
# Building cxrlt2024 train/val dataloader for fact classifier using official labels...
# len(dicom_ids) = 258871
# len(train_indices) = 240529
# len(val_indices) = 18342
# labels.shape = (258871, 40)
# class_embeddings.shape = (40, 128)
# Using all CXR-LT-2024 official labels for training the fact classifier
# len(train_indices) = 258871
# len(val_indices) = 0
# 707 train indices removed due to forbidden_train_dicom_ids
# Balanced sampling is enabled for CXR-LT-2024 fact classifier training
# Lobar Atelectasis: 129
# Clavicle Fracture: 167
# Round(ed) Atelectasis: 171
# Azygos Lobe: 198
# Pneumoperitoneum: 515
# Pleural Other: 614
# Hydropneumothorax: 645
# Pneumomediastinum: 704
# Infarction: 725
# Kyphosis: 777
# Pulmonary Hypertension: 900
# Fibrosis: 1168
# Pulmonary Embolism: 1628
# Subcutaneous Emphysema: 2045
# Tuberculosis: 2074
# Lung Lesion: 2324
# Fissure: 2799
# Granuloma: 2959
# Pleural Thickening: 3262
# Tortuous Aorta: 3328
# Adenopathy: 3403
# Emphysema: 3650
# Hernia: 3976
# Calcification of the Aorta: 4231
# Mass: 5267
# Nodule: 7512
# Rib Fracture: 8901
# Infiltration: 10064
# Fracture: 11542
# Pneumothorax: 13822
# No labels: 13915
# Consolidation: 15317
# Enlarged Cardiomediastinum: 29540
# Normal: 34205
# Edema: 37140
# Pneumonia: 46530
# Atelectasis: 65148
# Pleural Effusion: 66132
# Cardiomegaly: 74542
# Lung Opacity: 77197
# Support Devices: 85689
# Group sizes: [34205, 24884, 24150, 22748, 19196, 14441, 13915, 10656, 9421, 9182, 8327, 8127, 7090, 5005, 3785, 3748, 3497, 3382, 3033, 2881, 2809, 2734, 2637, 2532, 2132, 2007, 1892, 1721, 1434, 1133, 875, 770, 718, 666, 641, 610, 515, 198, 171, 167, 129]
#   len(indices) = 34205, weight = 3416.968505575188
#   len(indices) = 24884, weight = 3114.0105584213015
#   len(indices) = 24150, weight = 3086.458645767619
#   len(indices) = 22748, weight = 3031.91054482965
#   len(indices) = 19196, weight = 2880.5738366725595
#   len(indices) = 14441, weight = 2638.3021770753585
#   len(indices) = 13915, weight = 2607.758881815128
#   len(indices) = 10656, weight = 2395.0126251246966
#   len(indices) = 9421, weight = 2300.838171256539
#   len(indices) = 9182, weight = 2281.5095060487456
#   len(indices) = 8327, weight = 2208.9773218632636
#   len(indices) = 8127, weight = 2191.1782895085344
#   len(indices) = 7090, weight = 2093.0111715585585
#   len(indices) = 5005, weight = 1855.94882572346
#   len(indices) = 3785, weight = 1679.251257544058
#   len(indices) = 3748, weight = 1673.2516585085702
#   len(indices) = 3497, weight = 1631.322863020584
#   len(indices) = 3382, weight = 1611.3495036813902
#   len(indices) = 3033, weight = 1547.4236900442331
#   len(indices) = 2881, weight = 1517.8434442395078
#   len(indices) = 2809, weight = 1503.4220704576376
#   len(indices) = 2734, weight = 1488.1026745697216
#   len(indices) = 2637, weight = 1467.8167780082722
#   len(indices) = 2532, weight = 1445.2202972163147
#   len(indices) = 2132, weight = 1352.1621707070422
#   len(indices) = 2007, weight = 1320.4375035117398
#   len(indices) = 1892, weight = 1289.9374456380835
#   len(indices) = 1721, weight = 1241.9610975177739
#   len(indices) = 1434, weight = 1152.9443664750534
#   len(indices) = 1133, weight = 1044.4216372805452
#   len(indices) = 875, weight = 933.4740610250955
#   len(indices) = 770, weight = 881.6194889606477
#   len(indices) = 718, weight = 854.086901505717
#   len(indices) = 666, weight = 825.1296008730636
#   len(indices) = 641, weight = 810.6474536669926
#   len(indices) = 610, weight = 792.1375053617213
#   len(indices) = 515, weight = 731.0500738870246
#   len(indices) = 198, weight = 444.08258972130596
#   len(indices) = 171, weight = 408.1638922480593
#   len(indices) = 167, weight = 402.55283205217046
#   len(indices) = 129, weight = 344.6530550389792
# Preparing MIMIC-CXR-Facts datasets and dataloaders for training/testing...
# fact_embeddings.shape = (596408, 128)
# Using image size mode: medium_512
# 227835it [00:01, 177351.70it/s]
# Total number of images: 258164
# len(train_indices) = 258164
# avg_facts_per_image = 436.5657372832773
# train_num_facts_per_image = 45
# Building train fact dataloader...
# batch_size = 8
# Normal (unbalanced) training...
# len(self.train_fact_dataloader) = 32271
# Preparing Chest Imagenome dataset and dataloader for training...
# Loading bbox_phrase_embeddings and bbox_phrases from /mnt/workspace/pamessina/medvqa-workspace/cache/chest_imagenome/bbox_phrase_embeddings(hash=333,1643894111267724539).pkl...
# bbox_phrase_embeddings.shape = (36, 128)
# len(bbox_phrases) = 36
# 	 right lung
# 	 right upper lung zone
# 	 right mid lung zone
# 	 right lower lung zone
# 	 right hilar structures
# 	 right apical zone
# 	 right costophrenic angle
# 	 right cardiophrenic angle
# 	 right hemidiaphragm
# 	 left lung
# 	 left upper lung zone
# 	 left mid lung zone
# 	 left lower lung zone
# 	 left hilar structures
# 	 left apical zone
# 	 left costophrenic angle
# 	 left hemidiaphragm
# 	 trachea
# 	 spine
# 	 right clavicle
# 	 left clavicle
# 	 aortic arch
# 	 mediastinum
# 	 upper mediastinum
# 	 svc
# 	 cardiac silhouette
# 	 left cardiac silhouette
# 	 right cardiac silhouette
# 	 cavoatrial junction
# 	 right atrium
# 	 descending aorta
# 	 carina
# 	 left upper abdomen
# 	 right upper abdomen
# 	 abdomen
# 	 left cardiophrenic angle
# Using image size mode: medium_512
# Loading precomputed bbox_coords_and_presence_and_mask from /mnt/workspace/pamessina/medvqa-workspace/cache/mimiccxr/bbox_coords_and_presence_and_mask(12,12,243310).pkl...
# File size: 1447940262 bytes (1414004.16 KB, 1380.86 MB, 1.35 GB)
# 227835it [00:00, 334759.18it/s]
# Total number of images: 165768
# --------------------------------------------------
# 10) Creating IU X-Ray Phrase Grounding Trainer ...
# get_image_transform()
#   Using segmentation mask aware transforms
#     len(_augmented_mask_transforms) = 10
#     augmentation_mode = random-color-and-spatial
#     default_prob = 0.4
#     Returning augmented transforms with mode random-color-and-spatial
# get_image_transform()
#   Using segmentation mask aware transforms
#     Returning default transform (no augmentation)
# Preparing data for training/testing...
# fact_embeddings.shape = (2331, 128)
# Number of invalid images removed: 111
# avg_facts_per_image = 2327.3329256692487
# train_num_facts_per_image = 45
# Building train dataloader...
# len(self.train_dataloader) = 920
# --------------------------------------------------
# 11) Creating dataloaders ...
# len(mimiccxr_trainer.train_fact_dataloader) = 32271
# len(mimiccxr_trainer.train_chest_imagenome_dataloader) = 16577
# len(mimiccxr_trainer.cxrlt2024_official_train_dataloader) = 100000000000000000
# len(mimiccxr_trainer.cxrlt2024_custom_train_dataloader) = 14537
# len(mimiccxr_trainer.cxrlt2024_custom_dev_dataloader) = 798
# len(vinbig_trainer.train_dataloader) = 100000000000000000
# len(chexlocalize_trainer.train_dataloader) = 91
# len(chexpert_trainer.train_dataloader) = 100000000000000000
# len(iuxray_trainer.train_dataloader) = 920
# len(_train_dataloaders) = 8
# len(_val_dataloaders) = 1
# _train_weights = [2.5, 1.0, 3.0, 3.0, 1.5, 0.4, 0.5, 0.5]
# merged_dataset_name = mim-facts+chst-img-anat+cxrlt2024(Off)+cxrlt2024(GPT4)+vinbig+chexloc+chxp+iuxray
# --------------------------------------------------
# 12) Attaching metrics, losses, timer and events to engines ...
# --------------------------------------------------
# 13) Defining learning rate scheduler handler ...
# --------------------------------------------------
# 14) Defining learning rate scheduler handler ...
# --------------------------------------------------
# 15) Defining checkpoint folder path ...
# checkpoint_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240909_220146_mim-facts+chst-img-anat+cxrlt2024(Off)+cxrlt2024(GPT4)+vinbig+chexloc+chxp+iuxray_PhraseGrounder(aehrc-cxrmate-rrg24-uniformer,FiLM_SigmoidAttention,128,256,256,256,1,256-128)
# metadata saved to /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240909_220146_mim-facts+chst-img-anat+cxrlt2024(Off)+cxrlt2024(GPT4)+vinbig+chexloc+chxp+iuxray_PhraseGrounder(aehrc-cxrmate-rrg24-uniformer,FiLM_SigmoidAttention,128,256,256,256,1,256-128)/metadata.json
# --------------------------------------------------
# 16) Loading pretrained weights ...
# checkpoint_names = ['checkpoint_149_chss+chss+chuc+ciss+ciou+clss+clcc+clou+cxss+cxss+cxuc+cxuc+iuss+iuss+iuuc+miss+miss+miuc+vbss+vbuc+vbou=0.6855.pt', 'checkpoint_214_chss+chss+chuc+ciss+ciou+clss+clcc+clou+cxss+cxss+cxuc+cxuc+iuss+iuss+iuuc+miss+miss+miuc+vbss+vbuc+vbou=0.6923.pt']
# pretrained_checkpoint_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240825_115146_mim-facts+chst-img-anat+cxrlt2024(Off)+cxrlt2024(GPT4)+vinbig+chexloc+chxp+iuxray_PhraseGrounder(aehrc-cxrmate-rrg24,FiLM_SigmoidAttention,128,256,256,256,1,256-128)/checkpoint_214_chss+chss+chuc+ciss+ciou+clss+clcc+clou+cxss+cxss+cxuc+cxuc+iuss+iuss+iuuc+miss+miss+miuc+vbss+vbuc+vbou=0.6923.pt
# Warning: model state dict has 711 keys, loaded state dict has 707 keys, intersection has 707 keys, union has 711 keys.
# Examples of keys in model but not in loaded state dict:
#   phrase_emb_align_proj.bias
#   global_vf_align_proj.weight
#   phrase_emb_align_proj.weight
#   global_vf_align_proj.bias
# Checkpoint successfully loaded!
# --------------------------------------------------
# 17) Defining log_metrics_handler ...
# MetricsLogger :: we'll be logging to /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240909_220146_mim-facts+chst-img-anat+cxrlt2024(Off)+cxrlt2024(GPT4)+vinbig+chexloc+chxp+iuxray_PhraseGrounder(aehrc-cxrmate-rrg24-uniformer,FiLM_SigmoidAttention,128,256,256,256,1,256-128)/metrics_logs.csv
# --------------------------------------------------
# 18) Running trainer engine ...
# ---- Epoch 1/100
# (1) Training stage (lr = 0.000001) ...
# loss 6.47770, mimfg_att_reg_loss 0.18084, mimfg_gac_loss 6.17987, mimfg_phrcls_loss 1.96550, mimfg_prc_auc 0.79869, cibg_att_sup_loss 0.77800, cibg_segmask_iou 0.28490, vbg_phrcls_loss 1.30602, vbg_gac_loss 5.46395, vbg_prc_auc 0.67012, vbg_att_reg_loss 0.07121, vbg_att_sup_loss 0.36171, vbg_segmask_iou 0.20724, cl_att_sup_loss 0.34349, cl_segmask_iou 0.39233, cl_phrcls_loss 0.81835, cl_phrase_acc 0.96816, cl_gac_loss 4.20880, chxp_att_reg_loss 0.17419, chxp_gac_loss 4.82657, chxp_phrcls_loss 2.19975, chxp_prc_auc 0.78120, iufg_att_reg_loss 0.22147, iufg_gac_loss 6.56138, iufg_phrcls_loss 2.71380, iufg_prc_auc 0.54175, cxrlt2024c_att_reg_loss 0.22652, cxrlt2024c_gac_loss 2.58430, cxrlt2024c_phrcls_loss 1.86111, cxrlt2024c_prc_auc 0.76762, cxrlt2024o_att_reg_loss 0.19793, cxrlt2024o_gac_loss 6.06407, cxrlt2024o_phrcls_loss 1.56180, cxrlt2024o_prc_auc 0.27063, 458.94 secs
# (2) Validation stage ...
# cxrlt2024c_att_reg_loss 0.13278, cxrlt2024c_gac_loss 3.69744, cxrlt2024c_phrcls_loss 1.10629, cxrlt2024c_prc_auc 0.71781, 465.05 secs
# New checkpoint saved: checkpoint_1_chss+chss+chss+chuc+ciss+ciou+clss+clss+clcc+clou+cxss+cxss+cxss+cxuc+cxuc+iuss+iuss+iuss+iuuc+miss+miss+miss+miuc+vbss+vbss+vbuc+vbou=0.6306.pt
# ---- Epoch 2/100
# (1) Training stage (lr = 0.000004) ...
# loss 6.22715, mimfg_att_reg_loss 0.18408, mimfg_gac_loss 6.10117, mimfg_phrcls_loss 1.99517, mimfg_prc_auc 0.79083, cibg_att_sup_loss 0.78044, cibg_segmask_iou 0.28854, vbg_phrcls_loss 1.32290, vbg_gac_loss 5.06493, vbg_prc_auc 0.66604, vbg_att_reg_loss 0.07823, vbg_att_sup_loss 0.36074, vbg_segmask_iou 0.20015, cl_att_sup_loss 0.34766, cl_segmask_iou 0.39001, cl_phrcls_loss 0.82688, cl_phrase_acc 0.95641, cl_gac_loss 3.85484, chxp_att_reg_loss 0.16693, chxp_gac_loss 4.47404, chxp_phrcls_loss 2.10407, chxp_prc_auc 0.80640, iufg_att_reg_loss 0.21912, iufg_gac_loss 6.33087, iufg_phrcls_loss 2.53782, iufg_prc_auc 0.57447, cxrlt2024c_att_reg_loss 0.21691, cxrlt2024c_gac_loss 2.33586, cxrlt2024c_phrcls_loss 1.77867, cxrlt2024c_prc_auc 0.78310, cxrlt2024o_att_reg_loss 0.19720, cxrlt2024o_gac_loss 5.78034, cxrlt2024o_phrcls_loss 1.54088, cxrlt2024o_prc_auc 0.26852, 482.75 secs
# (2) Validation stage ...
# cxrlt2024c_att_reg_loss 0.13502, cxrlt2024c_gac_loss 3.50057, cxrlt2024c_phrcls_loss 1.11203, cxrlt2024c_prc_auc 0.71777, 469.69 secs
# New checkpoint saved: checkpoint_2_chss+chss+chss+chuc+ciss+ciou+clss+clss+clcc+clou+cxss+cxss+cxss+cxuc+cxuc+iuss+iuss+iuss+iuuc+miss+miss+miss+miuc+vbss+vbss+vbuc+vbou=0.6318.pt
# ---- Epoch 3/100
# (1) Training stage (lr = 0.000019) ...
# loss 6.01835, mimfg_att_reg_loss 0.18371, mimfg_gac_loss 5.87519, mimfg_phrcls_loss 2.01338, mimfg_prc_auc 0.78864, cibg_att_sup_loss 0.78400, cibg_segmask_iou 0.28460, vbg_phrcls_loss 1.33117, vbg_gac_loss 4.49753, vbg_prc_auc 0.65390, vbg_att_reg_loss 0.07393, vbg_att_sup_loss 0.36873, vbg_segmask_iou 0.20845, cl_att_sup_loss 0.31669, cl_segmask_iou 0.39531, cl_phrcls_loss 0.79595, cl_phrase_acc 0.96623, cl_gac_loss 3.42386, chxp_att_reg_loss 0.17769, chxp_gac_loss 4.04689, chxp_phrcls_loss 2.22951, chxp_prc_auc 0.77785, iufg_att_reg_loss 0.22351, iufg_gac_loss 6.04216, iufg_phrcls_loss 2.82554, iufg_prc_auc 0.53608, cxrlt2024c_att_reg_loss 0.22350, cxrlt2024c_gac_loss 2.19324, cxrlt2024c_phrcls_loss 1.90963, cxrlt2024c_prc_auc 0.75290, cxrlt2024o_att_reg_loss 0.19844, cxrlt2024o_gac_loss 5.45934, cxrlt2024o_phrcls_loss 1.57373, cxrlt2024o_prc_auc 0.25635, 480.77 secs
# (2) Validation stage ...
# cxrlt2024c_att_reg_loss 0.13698, cxrlt2024c_gac_loss 3.31799, cxrlt2024c_phrcls_loss 1.11511, cxrlt2024c_prc_auc 0.71557, 472.68 secs
# ---- Epoch 4/100
# (1) Training stage (lr = 0.000080) ...
# loss 5.67831, mimfg_att_reg_loss 0.18514, mimfg_gac_loss 5.54384, mimfg_phrcls_loss 2.03442, mimfg_prc_auc 0.78141, cibg_att_sup_loss 0.79943, cibg_segmask_iou 0.28542, vbg_phrcls_loss 1.39585, vbg_gac_loss 3.71006, vbg_prc_auc 0.61018, vbg_att_reg_loss 0.07080, vbg_att_sup_loss 0.39018, vbg_segmask_iou 0.19435, cl_att_sup_loss 0.36081, cl_segmask_iou 0.37224, cl_phrcls_loss 0.92566, cl_phrase_acc 0.95436, cl_gac_loss 2.66687, chxp_att_reg_loss 0.18687, chxp_gac_loss 3.67396, chxp_phrcls_loss 2.31614, chxp_prc_auc 0.74623, iufg_att_reg_loss 0.22678, iufg_gac_loss 5.62779, iufg_phrcls_loss 2.72475, iufg_prc_auc 0.54669, cxrlt2024c_att_reg_loss 0.21977, cxrlt2024c_gac_loss 1.93091, cxrlt2024c_phrcls_loss 1.85198, cxrlt2024c_prc_auc 0.74483, cxrlt2024o_att_reg_loss 0.20101, cxrlt2024o_gac_loss 5.17462, cxrlt2024o_phrcls_loss 1.56468, cxrlt2024o_prc_auc 0.26246, 486.94 secs
# (2) Validation stage ...
# cxrlt2024c_att_reg_loss 0.13181, cxrlt2024c_gac_loss 3.10159, cxrlt2024c_phrcls_loss 1.13162, cxrlt2024c_prc_auc 0.71371, 474.30 secs
# ---- Epoch 5/100
# (1) Training stage (lr = 0.000033) ...
# loss 5.49440, mimfg_att_reg_loss 0.18126, mimfg_gac_loss 5.37286, mimfg_phrcls_loss 2.00095, mimfg_prc_auc 0.78980, cibg_att_sup_loss 0.78620, cibg_segmask_iou 0.28294, vbg_phrcls_loss 1.37067, vbg_gac_loss 3.39511, vbg_prc_auc 0.65116, vbg_att_reg_loss 0.07527, vbg_att_sup_loss 0.37541, vbg_segmask_iou 0.19747, cl_att_sup_loss 0.35960, cl_segmask_iou 0.36656, cl_phrcls_loss 0.91711, cl_phrase_acc 0.96021, cl_gac_loss 2.21454, chxp_att_reg_loss 0.17446, chxp_gac_loss 3.42079, chxp_phrcls_loss 2.30833, chxp_prc_auc 0.75778, iufg_att_reg_loss 0.22688, iufg_gac_loss 5.44814, iufg_phrcls_loss 2.75634, iufg_prc_auc 0.55778, cxrlt2024c_att_reg_loss 0.21575, cxrlt2024c_gac_loss 1.84048, cxrlt2024c_phrcls_loss 1.83346, cxrlt2024c_prc_auc 0.75004, cxrlt2024o_att_reg_loss 0.20297, cxrlt2024o_gac_loss 5.02934, cxrlt2024o_phrcls_loss 1.56143, cxrlt2024o_prc_auc 0.26748, 482.54 secs
# (2) Validation stage ...
# cxrlt2024c_att_reg_loss 0.13536, cxrlt2024c_gac_loss 3.00213, cxrlt2024c_phrcls_loss 1.12676, cxrlt2024c_prc_auc 0.71442, 478.41 secs
# New checkpoint saved: checkpoint_5_chss+chss+chss+chuc+ciss+ciou+clss+clss+clcc+clou+cxss+cxss+cxss+cxuc+cxuc+iuss+iuss+iuss+iuuc+miss+miss+miss+miuc+vbss+vbss+vbuc+vbou=0.6325.pt
# ---- Epoch 6/100
# (1) Training stage (lr = 0.000014) ...
# loss 5.44727, mimfg_att_reg_loss 0.17996, mimfg_gac_loss 5.30760, mimfg_phrcls_loss 1.98712, mimfg_prc_auc 0.79448, cibg_att_sup_loss 0.77507, cibg_segmask_iou 0.28810, vbg_phrcls_loss 1.33349, vbg_gac_loss 3.31023, vbg_prc_auc 0.66259, vbg_att_reg_loss 0.07095, vbg_att_sup_loss 0.38244, vbg_segmask_iou 0.20590, cl_att_sup_loss 0.36200, cl_segmask_iou 0.37157, cl_phrcls_loss 0.86616, cl_phrase_acc 0.96342, cl_gac_loss 2.06422, chxp_att_reg_loss 0.17961, chxp_gac_loss 3.40342, chxp_phrcls_loss 2.29918, chxp_prc_auc 0.76505, iufg_att_reg_loss 0.23512, iufg_gac_loss 5.41153, iufg_phrcls_loss 2.85223, iufg_prc_auc 0.53061, cxrlt2024c_att_reg_loss 0.22101, cxrlt2024c_gac_loss 1.82025, cxrlt2024c_phrcls_loss 1.87765, cxrlt2024c_prc_auc 0.75719, cxrlt2024o_att_reg_loss 0.19714, cxrlt2024o_gac_loss 4.94725, cxrlt2024o_phrcls_loss 1.56230, cxrlt2024o_prc_auc 0.26885, 484.61 secs
# (2) Validation stage ...
# cxrlt2024c_att_reg_loss 0.13241, cxrlt2024c_gac_loss 3.00868, cxrlt2024c_phrcls_loss 1.12823, cxrlt2024c_prc_auc 0.71677, 479.20 secs
# New checkpoint saved: checkpoint_6_chss+chss+chss+chuc+ciss+ciou+clss+clss+clcc+clou+cxss+cxss+cxss+cxuc+cxuc+iuss+iuss+iuss+iuuc+miss+miss+miss+miuc+vbss+vbss+vbuc+vbou=0.6342.pt
# ---- Epoch 7/100
# (1) Training stage (lr = 0.000006) ...
# loss 5.38669, mimfg_att_reg_loss 0.18108, mimfg_gac_loss 5.27579, mimfg_phrcls_loss 1.97361, mimfg_prc_auc 0.79761, cibg_att_sup_loss 0.77667, cibg_segmask_iou 0.28984, vbg_phrcls_loss 1.33735, vbg_gac_loss 3.26858, vbg_prc_auc 0.63806, vbg_att_reg_loss 0.07243, vbg_att_sup_loss 0.37917, vbg_segmask_iou 0.19865, cl_att_sup_loss 0.34132, cl_segmask_iou 0.38593, cl_phrcls_loss 0.79461, cl_phrase_acc 0.96700, cl_gac_loss 1.91553, chxp_att_reg_loss 0.17378, chxp_gac_loss 3.32024, chxp_phrcls_loss 2.22873, chxp_prc_auc 0.77239, iufg_att_reg_loss 0.22125, iufg_gac_loss 5.16304, iufg_phrcls_loss 2.68303, iufg_prc_auc 0.54773, cxrlt2024c_att_reg_loss 0.21705, cxrlt2024c_gac_loss 1.78089, cxrlt2024c_phrcls_loss 1.83524, cxrlt2024c_prc_auc 0.76339, cxrlt2024o_att_reg_loss 0.20093, cxrlt2024o_gac_loss 4.98026, cxrlt2024o_phrcls_loss 1.57468, cxrlt2024o_prc_auc 0.26562, 485.15 secs
# (2) Validation stage ...
# cxrlt2024c_att_reg_loss 0.13432, cxrlt2024c_gac_loss 2.95314, cxrlt2024c_phrcls_loss 1.11471, cxrlt2024c_prc_auc 0.71716, 482.62 secs
# New checkpoint saved: checkpoint_7_chss+chss+chss+chuc+ciss+ciou+clss+clss+clcc+clou+cxss+cxss+cxss+cxuc+cxuc+iuss+iuss+iuss+iuuc+miss+miss+miss+miuc+vbss+vbss+vbuc+vbou=0.6353.pt
# ---- Epoch 8/100
# (1) Training stage (lr = 0.000002) ...
# loss 5.38250, mimfg_att_reg_loss 0.18132, mimfg_gac_loss 5.28351, mimfg_phrcls_loss 1.98266, mimfg_prc_auc 0.79121, cibg_att_sup_loss 0.77198, cibg_segmask_iou 0.29041, vbg_phrcls_loss 1.31881, vbg_gac_loss 3.22777, vbg_prc_auc 0.65505, vbg_att_reg_loss 0.06629, vbg_att_sup_loss 0.36636, vbg_segmask_iou 0.19940, cl_att_sup_loss 0.33048, cl_segmask_iou 0.38803, cl_phrcls_loss 0.76169, cl_phrase_acc 0.96667, cl_gac_loss 1.93894, chxp_att_reg_loss 0.17287, chxp_gac_loss 3.32600, chxp_phrcls_loss 2.21107, chxp_prc_auc 0.77890, iufg_att_reg_loss 0.23120, iufg_gac_loss 5.40705, iufg_phrcls_loss 2.82348, iufg_prc_auc 0.52584, cxrlt2024c_att_reg_loss 0.21358, cxrlt2024c_gac_loss 1.74697, cxrlt2024c_phrcls_loss 1.85029, cxrlt2024c_prc_auc 0.77675, cxrlt2024o_att_reg_loss 0.19751, cxrlt2024o_gac_loss 4.95230, cxrlt2024o_phrcls_loss 1.56345, cxrlt2024o_prc_auc 0.26860, 489.44 secs
# (2) Validation stage ...
# cxrlt2024c_att_reg_loss 0.13143, cxrlt2024c_gac_loss 2.97728, cxrlt2024c_phrcls_loss 1.10759, cxrlt2024c_prc_auc 0.71786, 478.78 secs
# New checkpoint saved: checkpoint_8_chss+chss+chss+chuc+ciss+ciou+clss+clss+clcc+clou+cxss+cxss+cxss+cxuc+cxuc+iuss+iuss+iuss+iuuc+miss+miss+miss+miuc+vbss+vbss+vbuc+vbou=0.6362.pt
# ---- Epoch 9/100
# (1) Training stage (lr = 0.000001) ...
# loss 5.36135, mimfg_att_reg_loss 0.17923, mimfg_gac_loss 5.22660, mimfg_phrcls_loss 1.94836, mimfg_prc_auc 0.80076, cibg_att_sup_loss 0.77076, cibg_segmask_iou 0.28894, vbg_phrcls_loss 1.31281, vbg_gac_loss 3.18734, vbg_prc_auc 0.65710, vbg_att_reg_loss 0.06646, vbg_att_sup_loss 0.37598, vbg_segmask_iou 0.20648, cl_att_sup_loss 0.34328, cl_segmask_iou 0.36901, cl_phrcls_loss 0.79822, cl_phrase_acc 0.96821, cl_gac_loss 1.97730, chxp_att_reg_loss 0.16960, chxp_gac_loss 3.26504, chxp_phrcls_loss 2.22206, chxp_prc_auc 0.76440, iufg_att_reg_loss 0.23087, iufg_gac_loss 5.29333, iufg_phrcls_loss 2.78174, iufg_prc_auc 0.54003, cxrlt2024c_att_reg_loss 0.21685, cxrlt2024c_gac_loss 1.77048, cxrlt2024c_phrcls_loss 1.83004, cxrlt2024c_prc_auc 0.76200, cxrlt2024o_att_reg_loss 0.19987, cxrlt2024o_gac_loss 4.96757, cxrlt2024o_phrcls_loss 1.56024, cxrlt2024o_prc_auc 0.26387, 482.88 secs
# (2) Validation stage ...
# cxrlt2024c_att_reg_loss 0.13071, cxrlt2024c_gac_loss 2.95890, cxrlt2024c_phrcls_loss 1.11236, cxrlt2024c_prc_auc 0.71773, 483.82 secs
# ---- Epoch 10/100
# (1) Training stage (lr = 0.000080) ...
# loss 5.39533, mimfg_att_reg_loss 0.17995, mimfg_gac_loss 5.20642, mimfg_phrcls_loss 1.98538, mimfg_prc_auc 0.79149, cibg_att_sup_loss 0.77200, cibg_segmask_iou 0.28873, vbg_phrcls_loss 1.37167, vbg_gac_loss 3.24818, vbg_prc_auc 0.64758, vbg_att_reg_loss 0.07353, vbg_att_sup_loss 0.38749, vbg_segmask_iou 0.19927, cl_att_sup_loss 0.37249, cl_segmask_iou 0.37353, cl_phrcls_loss 0.88374, cl_phrase_acc 0.95366, cl_gac_loss 1.88477, chxp_att_reg_loss 0.17758, chxp_gac_loss 3.37819, chxp_phrcls_loss 2.28088, chxp_prc_auc 0.78301, iufg_att_reg_loss 0.22530, iufg_gac_loss 5.26203, iufg_phrcls_loss 2.72871, iufg_prc_auc 0.53675, cxrlt2024c_att_reg_loss 0.22170, cxrlt2024c_gac_loss 1.77902, cxrlt2024c_phrcls_loss 1.88690, cxrlt2024c_prc_auc 0.75932, cxrlt2024o_att_reg_loss 0.19779, cxrlt2024o_gac_loss 4.95723, cxrlt2024o_phrcls_loss 1.57146, cxrlt2024o_prc_auc 0.26112, 492.86 secs
# (2) Validation stage ...
# cxrlt2024c_att_reg_loss 0.13692, cxrlt2024c_gac_loss 2.97382, cxrlt2024c_phrcls_loss 1.14656, cxrlt2024c_prc_auc 0.71086, 481.31 secs
# ---- Epoch 11/100
# (1) Training stage (lr = 0.000027) ...
# loss 5.32957, mimfg_att_reg_loss 0.18290, mimfg_gac_loss 5.08450, mimfg_phrcls_loss 2.00357, mimfg_prc_auc 0.79004, cibg_att_sup_loss 0.75993, cibg_segmask_iou 0.28968, vbg_phrcls_loss 1.35812, vbg_gac_loss 3.14339, vbg_prc_auc 0.64097, vbg_att_reg_loss 0.07430, vbg_att_sup_loss 0.38152, vbg_segmask_iou 0.19577, cl_att_sup_loss 0.33048, cl_segmask_iou 0.37804, cl_phrcls_loss 0.82635, cl_phrase_acc 0.96410, cl_gac_loss 1.85941, chxp_att_reg_loss 0.17448, chxp_gac_loss 3.25527, chxp_phrcls_loss 2.25874, chxp_prc_auc 0.78723, iufg_att_reg_loss 0.23246, iufg_gac_loss 5.22082, iufg_phrcls_loss 2.75383, iufg_prc_auc 0.53203, cxrlt2024c_att_reg_loss 0.21473, cxrlt2024c_gac_loss 1.73511, cxrlt2024c_phrcls_loss 1.86992, cxrlt2024c_prc_auc 0.76274, cxrlt2024o_att_reg_loss 0.19800, cxrlt2024o_gac_loss 4.91460, cxrlt2024o_phrcls_loss 1.58429, cxrlt2024o_prc_auc 0.25904, 492.75 secs
# (2) Validation stage ...
# cxrlt2024c_att_reg_loss 0.13293, cxrlt2024c_gac_loss 2.92065, cxrlt2024c_phrcls_loss 1.12531, cxrlt2024c_prc_auc 0.71504, 477.95 secs
# ---- Epoch 12/100
# (1) Training stage (lr = 0.000009) ...
# loss 5.26246, mimfg_att_reg_loss 0.18173, mimfg_gac_loss 5.06810, mimfg_phrcls_loss 1.98947, mimfg_prc_auc 0.79281, cibg_att_sup_loss 0.75327, cibg_segmask_iou 0.29546, vbg_phrcls_loss 1.33148, vbg_gac_loss 3.10184, vbg_prc_auc 0.64510, vbg_att_reg_loss 0.06989, vbg_att_sup_loss 0.38617, vbg_segmask_iou 0.20233, cl_att_sup_loss 0.33606, cl_segmask_iou 0.36520, cl_phrcls_loss 0.76804, cl_phrase_acc 0.96754, cl_gac_loss 1.65617, chxp_att_reg_loss 0.18200, chxp_gac_loss 3.25674, chxp_phrcls_loss 2.27246, chxp_prc_auc 0.76118, iufg_att_reg_loss 0.21395, iufg_gac_loss 5.06770, iufg_phrcls_loss 2.55169, iufg_prc_auc 0.60053, cxrlt2024c_att_reg_loss 0.21859, cxrlt2024c_gac_loss 1.70785, cxrlt2024c_phrcls_loss 1.86671, cxrlt2024c_prc_auc 0.77366, cxrlt2024o_att_reg_loss 0.19563, cxrlt2024o_gac_loss 4.85497, cxrlt2024o_phrcls_loss 1.55339, cxrlt2024o_prc_auc 0.26502, 496.00 secs
# (2) Validation stage ...
# cxrlt2024c_att_reg_loss 0.13026, cxrlt2024c_gac_loss 2.90681, cxrlt2024c_phrcls_loss 1.10893, cxrlt2024c_prc_auc 0.71660, 483.61 secs
# New checkpoint saved: checkpoint_12_chss+chss+chss+chuc+ciss+ciou+clss+clss+clcc+clou+cxss+cxss+cxss+cxuc+cxuc+iuss+iuss+iuss+iuuc+miss+miss+miss+miuc+vbss+vbss+vbuc+vbou=0.6363.pt
# ---- Epoch 13/100
# (1) Training stage (lr = 0.000003) ...
# loss 5.28818, mimfg_att_reg_loss 0.18517, mimfg_gac_loss 5.05020, mimfg_phrcls_loss 1.99425, mimfg_prc_auc 0.79167, cibg_att_sup_loss 0.74955, cibg_segmask_iou 0.29481, vbg_phrcls_loss 1.32080, vbg_gac_loss 3.06324, vbg_prc_auc 0.64789, vbg_att_reg_loss 0.06911, vbg_att_sup_loss 0.36459, vbg_segmask_iou 0.19821, cl_att_sup_loss 0.34090, cl_segmask_iou 0.37699, cl_phrcls_loss 0.75925, cl_phrase_acc 0.96615, cl_gac_loss 1.64146, chxp_att_reg_loss 0.17562, chxp_gac_loss 3.26381, chxp_phrcls_loss 2.23501, chxp_prc_auc 0.75769, iufg_att_reg_loss 0.22424, iufg_gac_loss 5.11937, iufg_phrcls_loss 2.70758, iufg_prc_auc 0.55303, cxrlt2024c_att_reg_loss 0.22347, cxrlt2024c_gac_loss 1.73317, cxrlt2024c_phrcls_loss 1.90790, cxrlt2024c_prc_auc 0.76759, cxrlt2024o_att_reg_loss 0.19803, cxrlt2024o_gac_loss 4.88663, cxrlt2024o_phrcls_loss 1.56374, cxrlt2024o_prc_auc 0.26572, 492.36 secs
# (2) Validation stage ...
#    iteration 250
