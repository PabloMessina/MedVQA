# %%
# %env CUDA_VISIBLE_DEVICES=1
# Out:
# env: CUDA_VISIBLE_DEVICES=1

# %%
# !python ../train_vqa.py \
        --pretrained-checkpoint-folder-path "/home/pamessina/medvqa-workspace/models/vqa/20220706_135511_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(densenet121+bilstm+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretrained)_cnn-pretr=0_dataset_weights=0.73,0.15,0.07,0.03,0.2_medtok_orien_chx_ql_use_amp" \
        --epochs 100 \
        --batches-per-epoch 350 \
        --batch-size 70 \
        --num-workers 5 \
        --lr-decay-patience 3 \
        --answer-hidden-size 512 \
        --n-lstm-layers 1 \
        --iuxray-qa-adapted-reports-filename "qa_adapted_reports__20220629_042239.json" \
        --mimiccxr-qa-adapted-reports-filename "qa_adapted_reports__20220629_050643.json" \
        --classify-orientation \
        --classify-chexpert \
        --iuxray-chexpert-labels-filename "chexpert_labels_per_report__20220629_055107.pkl" \
        --mimiccxr-chexpert-labels-filename "chexpert_labels_per_report__20220629_055159.pkl" \
        --classify-questions \
        --n-questions 97 \
        --iuxray-question-labels-filename "question_labels_per_report__20220629_052841.pkl" \
        --mimiccxr-question-labels-filename "question_labels_per_report__20220629_052842.pkl" \
        --balanced-split \
        --iuxray-balanced-metadata-filename "balanced_dataloading_metadata__20220629_123626.pkl" \
        --mimiccxr-balanced-metadata-filename "balanced_dataloading_metadata__20220629_123956.pkl" \
        --balanced-dataloading \
        --medical-tokenization \
        --medical-terms-frequency-filename "medical_terms_frequency__20220629_052724.pkl" \
        --question-encoding "one-hot" \
        --binary-loss-name "wbce-c" \
        --img-aug-mode "random-color-and-spatial" \
        --chexpert-mode "vqa" \
        --mimiccxr-include-chexpert-mode \
        --iuxray-include-chexpert-mode \
        --use-amp \
        --save
# Out:
# script's arguments:
#    epochs: 100
#    batches_per_epoch: 350
#    checkpoint_folder: None
#    iuxray_qa_adapted_reports_filename: qa_adapted_reports__20220629_042239.json
#    mimiccxr_qa_adapted_reports_filename: qa_adapted_reports__20220629_050643.json
#    vocab_min_freq: 5
#    embed_size: 128
#    question_encoding: one-hot
#    question_hidden_size: 128
#    answer_hidden_size: 512
#    n_lstm_layers: 1
#    question_vec_size: 128
#    image_local_feat_size: 1024
#    dropout_prob: 0
#    densenet_pretrained_weights_path:
#    lr: 0.001
#    lr_decay: 0.76
#    lr_decay_patience: 3
#    n_val_examples_per_question: 10
#    min_train_examples_per_question: 100
#    batch_size: 70
#    num_workers: 5
#    device: GPU
#    img_aug_mode: random-color-and-spatial
#    freeze_cnn: False
#    mimiccxr_weight: 0.73
#    chexpert_weight: 0.2
#    iuxray_weight: 0.07
#    mimiccxr_weight_chexpert_mode: 0.15
#    iuxray_weight_chexpert_mode: 0.03
# ...

# %% [markdown]
# ### Training-Validation plots

# %%
from medvqa.evaluation.plots import plot_train_val_curves
from medvqa.utils.constants import MetricNames

# %%
plot_train_val_curves('/home/pamessina/medvqa-workspace/models/vqa/20220708_142221_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(densenet121+bilstm+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretr)_cnn-pretr=0_dws=0.73,0.15,0.07,0.03,0.2_medtok_orien_chx_ql_amp/metrics_logs.csv',
                 [MetricNames.WMEDCOMP, MetricNames.CIDER_D,
                  MetricNames.CHXLABELMACROAVGF1, MetricNames.CHXLABELMICROAVGF1,
                  MetricNames.CHXLABELACC,
                  MetricNames.CHXLABEL_ROCAUC_MACRO, MetricNames.CHXLABEL_ROCAUC_MICRO,
                  MetricNames.QLABELSF1, MetricNames.ORIENACC,
                 ],
                 ['Weighted Medical Completeness (QA)', 'cider-D (QA)',
                  'Chexpert-F1 (Macro Avg)', 'Chexpert-F1 (Micro Avg)',
                  'Chexpert Acc',
                  'Chexpert ROC-AUC (Macro Avg)', 'Chexpert ROC-AUC (Micro Avg)',
                  'Question Labels F1', 'Orientation Acc',
                 ],
                 single_plot_figsize=(8,6))

# %% [markdown]
# # Test Set Evaluation

# %% [markdown]
# # 1) Question-level Results

# %%
# !python ../eval_vqa.py \
        --checkpoint-folder "models/vqa/20220708_142221_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(densenet121+bilstm+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretr)_cnn-pretr=0_dws=0.73,0.15,0.07,0.03,0.2_medtok_orien_chx_ql_amp" \
        --batch-size 160
# Out:
# script's arguments:
#    checkpoint_folder: models/vqa/20220708_142221_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(densenet121+bilstm+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretr)_cnn-pretr=0_dws=0.73,0.15,0.07,0.03,0.2_medtok_orien_chx_ql_amp
#    answer_decoding: greedy-search
#    beam_search_k: None
#    batch_size: 160
#    device: GPU
#    num_workers: 0
#    eval_iuxray: True
#    eval_mimiccxr: True
#    use_amp: False
# ----- Evaluating model ------
# metadata loaded from /home/pamessina/medvqa-workspace/models/vqa/20220708_142221_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(densenet121+bilstm+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretr)_cnn-pretr=0_dws=0.73,0.15,0.07,0.03,0.2_medtok_orien_chx_ql_amp/metadata.json
# 1) device = cuda
# 2) Loading iuxray and mimiccxr QA adapted reports ...
# 3) Initializing tokenizer ...
# ...

# %%
from medvqa.utils.files import load_pickle
from medvqa.evaluation.vqa import (
    get_overall_metrics_dataframe,
    get_per_question_metrics_dataframe,
)

# %% [markdown]
# ### IU X-Ray metrics

# %%
iuxray_agg_metrics = load_pickle('/home/pamessina/medvqa-workspace/results/vqa/20220708_142221_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(densenet121+bilstm+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretr)_cnn-pretr=0_dws=0.73,0.15,0.07,0.03,0.2_medtok_orien_chx_ql_amp/iuxray_metrics.pkl')

# %%
get_overall_metrics_dataframe(iuxray_agg_metrics)
# Out:
#          b1        b2        b3        b4      rg-L        cD       met  \
# 0  0.172776  0.090987  0.044072  0.019228  0.295246  0.706886  0.209554
#
#       mdcmp    wmdcmp  oracc  ...      qlf1   chx_acc   chx_p_0   chx_p_1  \
# 0  0.233608  0.219475    1.0  ...  0.481339  0.935027  0.949741  0.466638
#
#     chx_r_0   chx_r_1  chx_f1_0  chx_f1_1  chx_s_0  chx_s_1
# 0  0.950862  0.278213  0.948356    0.3122    15379     1351
#
# [1 rows x 25 columns]

# %%
get_per_question_metrics_dataframe(iuxray_agg_metrics, metrics_to_rank=['wmedcomp'])
# Out:
#                                      Q        b1            b2            b3  \
# 0                           tortuosity  0.262138  3.688556e-02  3.798619e-07
# 1                         pneumothorax  0.376002  1.829351e-01  2.267017e-02
# 2                        pleural space  0.343865  1.726601e-01  5.237187e-02
# 3                        consolidation  0.398025  2.339814e-01  7.801382e-02
# 4                          soft tissue  0.252149  6.181723e-09  2.005634e-11
# 5                         cardiomegaly  0.260308  1.079861e-01  1.282060e-02
# 6                          mediastinum  0.179522  8.981510e-02  9.291953e-05
# 7                                heart  0.265242  1.391870e-01  4.056374e-02
# 8                           infiltrate  0.254436  1.474649e-01  1.333335e-01
# 9                                edema  0.263521  1.016868e-01  1.045881e-02
# 10                  cardiac silhouette  0.203440  6.070150e-02  6.069957e-07
# ...

# %% [markdown]
# ### MIMIC-CXR metrics

# %%
mimiccxr_agg_metrics = load_pickle('/home/pamessina/medvqa-workspace/results/vqa/20220708_142221_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(densenet121+bilstm+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretr)_cnn-pretr=0_dws=0.73,0.15,0.07,0.03,0.2_medtok_orien_chx_ql_amp/mimiccxr_metrics.pkl')

# %%
get_overall_metrics_dataframe(mimiccxr_agg_metrics)
# Out:
#          b1        b2       b3        b4      rg-L        cD       met  \
# 0  0.074324  0.042097  0.02283  0.012122  0.231557  0.520735  0.155769
#
#       mdcmp  wmdcmp     oracc  ...     qlf1   chx_acc   chx_p_0   chx_p_1  \
# 0  0.208501  0.1957  0.997453  ...  0.49937  0.916954  0.940877  0.552098
#
#    chx_r_0   chx_r_1  chx_f1_0  chx_f1_1  chx_s_0  chx_s_1
# 0  0.95427  0.375871  0.946643  0.427228   384215    46425
#
# [1 rows x 25 columns]

# %%
get_per_question_metrics_dataframe(mimiccxr_agg_metrics, metrics_to_rank=['wmedcomp'])[:40]
# Out:
#                                Q        b1            b2            b3  \
# 0                    azygos lobe  0.067668  3.026189e-09  1.074157e-08
# 1                       free air  0.405814  3.420064e-01  2.672331e-01
# 2               pneumoperitoneum  0.166043  1.111119e-01  1.111193e-03
# 3                   pneumothorax  0.328596  2.355399e-01  2.123559e-02
# 4                       blurring  0.169117  1.265903e-01  7.844700e-02
# 5                           copd  0.144520  1.066425e-02  7.527695e-03
# 6       bronchovascular crowding  0.222985  1.220735e-01  1.332534e-02
# 7                     tortuosity  0.128220  6.669861e-03  8.502783e-07
# 8                        hernias  0.224770  1.713974e-01  8.248187e-02
# 9                    soft tissue  0.202767  1.429204e-01  6.175028e-02
# 10                fluid overload  0.236152  1.885115e-01  9.360458e-02
# 11                        carina  0.208820  9.020130e-02  2.556514e-02
# ...

# %% [markdown]
# # 2) Report-level Results

# %%
# !python ../eval_report_generation.py \
        --checkpoint-folder "models/vqa/20220708_142221_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(densenet121+bilstm+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretr)_cnn-pretr=0_dws=0.73,0.15,0.07,0.03,0.2_medtok_orien_chx_ql_amp" \
        --eval-mode "ground-truth" \
        --no-iuxray \
        --batch-size 160
# Out:
# script's arguments:
#    checkpoint_folder: models/vqa/20220708_142221_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(densenet121+bilstm+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretr)_cnn-pretr=0_dws=0.73,0.15,0.07,0.03,0.2_medtok_orien_chx_ql_amp
#    eval_mode: ground-truth
#    n_questions_per_report: None
#    batch_size: 160
#    device: GPU
#    num_workers: 0
#    answer_decoding: greedy-search
#    eval_iuxray: False
#    eval_mimiccxr: True
#    use_amp: False
# ----- Evaluating model ------
# metadata loaded from /home/pamessina/medvqa-workspace/models/vqa/20220708_142221_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(densenet121+bilstm+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretr)_cnn-pretr=0_dws=0.73,0.15,0.07,0.03,0.2_medtok_orien_chx_ql_amp/metadata.json
# 1) device = cuda
# 2) Loading iuxray and mimiccxr QA adapted reports ...
# 3) Initializing tokenizer ...
# ...

# %%
# !python ../eval_report_generation.py \
        --checkpoint-folder "models/vqa/20220708_142221_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(densenet121+bilstm+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretr)_cnn-pretr=0_dws=0.73,0.15,0.07,0.03,0.2_medtok_orien_chx_ql_amp" \
        --eval-mode "chexpert-labels" \
        --no-iuxray \
        --batch-size 160
# Out:
# script's arguments:
#    checkpoint_folder: models/vqa/20220708_142221_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(densenet121+bilstm+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretr)_cnn-pretr=0_dws=0.73,0.15,0.07,0.03,0.2_medtok_orien_chx_ql_amp
#    eval_mode: chexpert-labels
#    n_questions_per_report: None
#    batch_size: 160
#    device: GPU
#    num_workers: 0
#    answer_decoding: greedy-search
#    eval_iuxray: False
#    eval_mimiccxr: True
#    use_amp: False
# ----- Evaluating model ------
# metadata loaded from /home/pamessina/medvqa-workspace/models/vqa/20220708_142221_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(densenet121+bilstm+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretr)_cnn-pretr=0_dws=0.73,0.15,0.07,0.03,0.2_medtok_orien_chx_ql_amp/metadata.json
# 1) device = cuda
# 2) Loading iuxray and mimiccxr QA adapted reports ...
# 3) Initializing tokenizer ...
# ...

# %%
# !python ../eval_report_generation.py \
#         --checkpoint-folder "models/vqa/20220630_162749_mimiccxr+iuxray+chexpert(vqa)_oevqa(densenet121+bilstm+lstm)_voc-minf=5_model-args=(densenet-121,128,None,512,1,128,1024,0,qenc=one-hot)_cnn-pretr=0_dataset_weights=0.73,0.07,0.2_medtok=1_tags=0_orien=1_chx=1_ql=1_use_amp" \
#         --eval-mode "chexpert-labels" \
#         --no-iuxray \
#         --batch-size 160

# %%
from medvqa.evaluation.report_generation import get_report_level_metrics_dataframe
from medvqa.utils.files import load_pickle

# %% [markdown]
# ### MIMIC-CXR metrics

# %%
mimiccxr_report_metrics = load_pickle('/home/pamessina/medvqa-workspace/results/vqa/20220708_142221_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(densenet121+bilstm+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretr)_cnn-pretr=0_dws=0.73,0.15,0.07,0.03,0.2_medtok_orien_chx_ql_amp/mimiccxr_report_level_metrics(eval_mode=ground-truth).pkl')
mimiccxr_report_level_df = get_report_level_metrics_dataframe(mimiccxr_report_metrics, 'gt')
mimiccxr_report_level_df[mimiccxr_report_level_df.columns[:20]]
# Out:
# 1it [00:00,  1.01it/s]
#   method_name        b1        b2        b3        b4        cD      rg-L  \
# 0          gt  0.319083  0.188863  0.106373  0.056771  0.150993  0.219521
#
#         met     mdcmp    wmdcmp  chxlabf1(hard)  p(micro)  r(micro)  \
# 0  0.230951  0.175082  0.155187        0.660806  0.647382  0.793239
#
#    f1(micro)  p(macro)  r(macro)  f1(macro)       acc     p(NF)     p(EC)
# 0   0.712927  0.573649  0.671399   0.607056  0.843969  0.560811  0.509267

# %%
mimiccxr_report_metrics = load_pickle('/home/pamessina/medvqa-workspace/results/vqa/20220708_142221_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(densenet121+bilstm+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretr)_cnn-pretr=0_dws=0.73,0.15,0.07,0.03,0.2_medtok_orien_chx_ql_amp/mimiccxr_report_level_metrics(eval_mode=chexpert-labels).pkl')
mimiccxr_report_level_df = get_report_level_metrics_dataframe(mimiccxr_report_metrics, 'chexpert')
mimiccxr_report_level_df[mimiccxr_report_level_df.columns[:20]]
# Out:
# 1it [00:01,  1.09s/it]
#   method_name        b1        b2        b3        b4        cD      rg-L  \
# 0    chexpert  0.298338  0.167815  0.092833  0.048079  0.040911  0.195917
#
#         met     mdcmp    wmdcmp  chxlabf1(hard)  p(micro)  r(micro)  \
# 0  0.186842  0.084427  0.063829        0.435456  0.353341  0.704734
#
#    f1(micro)  p(macro)  r(macro)  f1(macro)       acc     p(NF)     p(EC)
# 0   0.470687  0.326277  0.647771   0.385044  0.615468  0.166667  0.306471

# %%
mimiccxr_report_metrics = load_pickle('/home/pamessina/medvqa-workspace/results/vqa/20220708_142221_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(densenet121+bilstm+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretr)_cnn-pretr=0_dws=0.73,0.15,0.07,0.03,0.2_medtok_orien_chx_ql_amp/mimiccxr_report_level_metrics(eval_mode=chexpert-labels).pkl')
mimiccxr_report_level_df = get_report_level_metrics_dataframe(mimiccxr_report_metrics, 'chexpert')
mimiccxr_report_level_df[mimiccxr_report_level_df.columns[:20]]
# Out:
# 1it [00:01,  1.10s/it]
#   method_name        b1        b2        b3        b4        cD      rg-L  \
# 0    chexpert  0.295508  0.165003  0.089891  0.046072  0.038843  0.195757
#
#         met    mdcmp    wmdcmp  chxlabf1(hard)  p(micro)  r(micro)  f1(micro)  \
# 0  0.183646  0.08285  0.062588        0.443518  0.352958  0.707069   0.470866
#
#    p(macro)  r(macro)  f1(macro)       acc  p(NF)     p(EC)
# 0   0.30767  0.658384    0.38158  0.614471    0.0  0.317744
