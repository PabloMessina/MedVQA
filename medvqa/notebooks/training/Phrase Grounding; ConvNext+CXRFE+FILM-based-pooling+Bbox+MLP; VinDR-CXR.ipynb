# %%
# %env CUDA_VISIBLE_DEVICES=2
# Out:
# env: CUDA_VISIBLE_DEVICES=2

# %%
# !python ../train_phrase_grounding.py \
--epochs 130 \
--batches_per_epoch 800 \
--max_images_per_batch 16 \
--max_phrases_per_batch 1000 \
--max_phrases_per_image 45 \
--val_batch_size_factor 6 \
--raw_image_encoding "convnextmodel-huggingface" \
--huggingface_model_name "facebook/convnext-small-224" \
--image_size 416 416 \
--image_local_feat_size 768 \
--num_regions 169 \
--regions_width 13 \
--regions_height 13 \
--img_aug_mode "random-color-and-spatial" \
--phrase_embedding_size 128 \
--phrase_grounding_mode "adaptive_film_based_pooling_mlp_with_bbox_regression" \
--phrase_mlp_hidden_dims 256 128 \
--visual_grounding_hidden_size 256 \
--num_train_workers 2 \
--num_val_workers 3 \
--gradient_accumulation_steps 2 \
--optimizer_name "adamw" \
--scheduler "exp-warmup+decay+cyclicdecay" \
--lr 1e-6 \
--warmup_decay_and_cyclic_decay_args "1e-6,3,8e-5,5,1e-6,8e-5,5,1e-6" \
--binary_multilabel_classif_loss_name "focal+bce+npbbce" \
--do_visual_grounding_with_bbox_regression \
--use_vinbig_for_train \
--use_vinbig_for_test \
--vinbig_phrase_embeddings_filepath \
"/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/vinbig/label_phrase_embeddings(hash=353,2491289492560726319).pkl" \
--use_amp \
--save
# Out:
# script's arguments:
#    epochs: 130
#    batches_per_epoch: 800
#    max_images_per_batch: 16
#    max_phrases_per_batch: 1000
#    max_phrases_per_image: 45
#    val_batch_size_factor: 6.0
#    checkpoint_folder: None
#    pretrained_checkpoint_folder_path: None
#    pretrained_checkpoint_folder_paths: None
#    freeze_image_encoder: False
#    raw_image_encoding: convnextmodel-huggingface
#    huggingface_model_name: facebook/convnext-small-224
#    num_regions: 169
#    image_local_feat_size: 768
#    image_encoder_pretrained_weights_path: None
#    image_encoder_dropout_p: 0
#    yolov8_model_name_or_path: None
#    yolov8_model_alias: None
#    phrase_embedding_size: 128
#    regions_width: 13
#    regions_height: 13
#    qkv_size: None
#    phrase_grounding_mode: adaptive_film_based_pooling_mlp_with_bbox_regression
#    phrase_classifier_hidden_size: None
#    transf_d_model: None
#    transf_nhead: None
#    transf_dim_feedforward: None
#    transf_dropout: 0
#    transf_num_layers: None
#    visual_feature_proj_size: None
#    visual_grounding_hidden_size: 256
#    phrase_mlp_hidden_dims: [256, 128]
#    predict_global_alignment: False
#    alignment_proj_size: None
#    yolov11_model_name_or_path: None
#    yolov11_model_alias: None
#    optimizer_name: adamw
#    lr: 1e-06
#    scheduler: exp-warmup+decay+cyclicdecay
#    lr_decay: 0.76
#    lr_decay_patience: 2
#    warmup_and_decay_args: None
#    warmup_and_cosine_args: None
#    warmup_decay_and_cyclic_decay_args: 1e-6,3,8e-5,5,1e-6,8e-5,5,1e-6
#    gradient_accumulation_steps: 2
#    override_lr: False
#    max_grad_norm: None
#    attention_supervision_loss_weight: 1.0
#    phrase_classifier_loss_weight: 1.0
#    foreground_loss_weight: 1.0
#    background_loss_weight: 1.0
#    focal_loss_weight: 1.0
#    bce_loss_weight: 1.0
#    wbce_loss_weight: 1.0
#    binary_multilabel_classif_loss_name: focal+bce+npbbce
#    use_weighted_phrase_classifier_loss: False
#    cluster_and_label_weights_for_facts_filepath: None
#    use_attention_regularization_loss: False
#    use_contrastive_phrase_grounding_loss: False
#    nt_xent_temperature: 0.1
#    num_train_workers: 2
#    num_val_workers: 3
#    device: GPU
#    use_amp: True
#    image_size: [416, 416]
#    dicom_id_to_pos_neg_facts_filepath: None
#    iuxray_image_id_to_pos_neg_facts_filepath: None
#    mscxr_phrase2embedding_filepath: None
#    chest_imagenome_bbox_phrase_embeddings_filepath: None
#    vinbig_phrase_embeddings_filepath: /mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/vinbig/label_phrase_embeddings(hash=353,2491289492560726319).pkl
#    chexlocalize_class_phrase_embeddings_filepath: None
#    chexpert_class_phrase_embeddings_filepath: None
#    mimiccxr_exclude_noisy_images: False
#    mimiccxr_facts_weight: 1.0
#    chest_imagenome_anatlocs_weight: 1.0
#    mscxr_weight: 1.0
#    cxrlt2024_weight: 1.0
#    vinbig_weight: 1.0
#    chexlocalize_weight: 1.0
#    chexpert_weight: 1.0
#    iuxray_weight: 1.0
#    img_aug_mode: random-color-and-spatial
#    pos_area_prior: 0.4
#    neg_area_prior: 0.0
#    use_mimiccxr_facts_for_train: False
#    use_mimiccxr_facts_for_test: False
#    use_mscxr_for_train: False
#    use_mscxr_for_test: False
#    use_chest_imagenome_for_train: False
#    use_chest_imagenome_gold_for_test: False
#    use_vinbig_for_train: True
#    use_vinbig_for_test: True
#    use_chexlocalize_for_train: False
#    use_chexlocalize_for_test: False
#    use_chexpert_for_train: False
#    use_chexpert_for_test: False
#    use_iuxray_for_train: False
#    use_iuxray_for_test: False
#    use_cxrlt2024_challenge_split: False
#    use_cxrlt2024_custom_labels: False
#    use_cxrlt2024_official_labels: False
#    use_all_cxrlt2024_official_labels_for_training: False
#    vinbig_training_data_mode: train
#    chexpert_training_data_mode: all
#    mimiccxr_balance_long_middle_short_tail: False
#    mimiccxr_long_middle_short_tail_thresholds: (0.02, 0.05)
#    mimiccxr_report_fact_nli_integrated_data_filepath: None
#    mimiccxr_use_interpret_cxr_challenge_split: False
#    mimiccxr_interpret_cxr_challenge_split_filepath: None
#    iuxray_use_interpret_cxr_challenge_split: False
#    iuxray_interpret_cxr_challenge_split_filepath: None
#    chexpert_use_interpret_cxr_challenge_split: False
#    chexpert_interpret_cxr_challenge_split_filepath: None
#    chexlocalize_use_interpret_cxr_challenge_split: False
#    chexlocalize_interpret_cxr_challenge_split_filepath: None
#    cxrlt2024_custom_dicom_id_to_pos_neg_facts_filepath: None
#    cxrlt2024_official_training_labels_for_fact_classification_filepath: None
#    cxrlt2024_do_balanced_sampling: False
#    do_visual_grounding_with_bbox_regression: True
#    do_visual_grounding_with_segmentation: False
#    replace_phrase_embeddings_with_random_vectors: False
#    use_vinbig_with_modified_labels: False
#    save: True
# ----- Training model from scratch ------
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Creating instance of PhraseGrounder ...
# WARNING: Unused kwargs: {'pretrained_checkpoint_folder_path': None, 'pretrained_checkpoint_folder_paths': None}
# MultiPurposeVisualModule()
#   Initializing raw_image_encoder: convnextmodel-huggingface
#   self.global_feat_size = 768
#   self.local_feat_size = 768
#   Initializing auxiliary tasks
# Using positional encoding for local features
# BoundingBoxRegressorSingleClass
#   local_feat_dim: 256
# --------------------------------------------------
# 3) Defining optimizer ...
# create_optimizer(): name = adamw
# --------------------------------------------------
# 4) Defining scheduler ...
# Using exp-warmup+decay+cyclicdecay scheduler: 1e-6,3,8e-5,5,1e-6,8e-5,5,1e-6
# 1e-06 3 8e-05 5 1e-06 8e-05 5 1e-06
# self.steps_to_restart = 5
# self.steps = -1
# self.initial_lr = 8e-05
# --------------------------------------------------
# 5) Creating trainer and validator engines ...
# Focal_BCE_NPBBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 npbbce_weight = 0.3333333333333333
# Focal_BCE_NPBBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 npbbce_weight = 0.3333333333333333
# Focal_BCE_WBCBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 wbcbce_weight = 0.3333333333333333
# foreground_loss_weight: 1.0
# background_loss_weight: 1.0
# GradientAccumulator.__init__(): num_accumulation_steps = 2, max_grad_norm = None
# Focal_BCE_NPBBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 npbbce_weight = 0.3333333333333333
# Focal_BCE_NPBBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 npbbce_weight = 0.3333333333333333
# Focal_BCE_WBCBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 wbcbce_weight = 0.3333333333333333
# foreground_loss_weight: 1.0
# background_loss_weight: 1.0
# --------------------------------------------------
# 6) Creating VinBig Phrase Grounding Trainer ...
# get_image_transform()
#   image_size = [416, 416]
#   mean = [0.485, 0.456, 0.406]
#   std = [0.229, 0.224, 0.225]
#   Using bounding box aware transforms
#     augmentation_mode = random-color-and-spatial
#     default_prob = 0.35
#     for_vinbig: returning vinbig transform
# get_train_transform(): Using bbox-aware transforms for VinBigData
#     Returning augmented transform with mode random-color-and-spatial
# get_image_transform()
#   image_size = [416, 416]
#   mean = [0.485, 0.456, 0.406]
#   std = [0.229, 0.224, 0.225]
#   Using bounding box aware transforms
#     Returning default transform (no augmentation)
# Loading bounding boxes
# Anomalous bboxes found: 29 of 37367
# class_id_offset: 0
# Anomalous bboxes found: 0 of 2697
# class_id_offset: 0
#   Loaded 18000 bounding boxes
# Loding phrase_embeddings and phrases from /mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/vinbig/label_phrase_embeddings(hash=353,2491289492560726319).pkl...
# phrase_embeddings.shape = (28, 128)
# phrase_embeddings.dtype = float32
# len(phrases) = 28
# Compute phrase grounding masks and labels
# vinbig_bbox_names = ['Aortic enlargement', 'Atelectasis', 'Calcification', 'Cardiomegaly', 'Clavicle fracture', 'Consolidation', 'Edema', 'Emphysema', 'Enlarged PA', 'ILD', 'Infiltration', 'Lung Opacity', 'Lung cavity', 'Lung cyst', 'Mediastinal shift', 'Nodule/Mass', 'Other lesion', 'Pleural effusion', 'Pleural thickening', 'Pneumothorax', 'Pulmonary fibrosis', 'Rib fracture']
# vinbig_labels = ['Aortic enlargement', 'Atelectasis', 'Calcification', 'Cardiomegaly', 'Clavicle fracture', 'Consolidation', 'Edema', 'Emphysema', 'Enlarged PA', 'ILD', 'Infiltration', 'Lung Opacity', 'Lung cavity', 'Lung cyst', 'Mediastinal shift', 'Nodule/Mass', 'Pleural effusion', 'Pleural thickening', 'Pneumothorax', 'Pulmonary fibrosis', 'Rib fracture', 'Other lesion', 'COPD', 'Lung tumor', 'Pneumonia', 'Tuberculosis', 'Other disease', 'No finding']
# num_bbox_classes = 22
# self.phrase_grounding_masks.shape = (18000, 22, 169)
# self.phrase_classification_labels.shape = (18000, 22)
# Append additional labels to phrase_classification_labels
# len(non_bbox_labels) = 6
# non_bbox_labels = ['COPD', 'Lung tumor', 'Pneumonia', 'Tuberculosis', 'Other disease', 'No finding']
# self.phrase_classification_labels.shape = (18000, 28)
# Reorder phrases and phrase_embeddings
# len(phrases) = 28
# len(sorted_phrases) = 28
# phrase_embeddings.shape = (28, 128)
# 	aortic enlargement seen (Aortic enlargement)
# 	atelectasis seen (Atelectasis)
# 	calcification seen (Calcification)
# 	cardiomegaly seen (Cardiomegaly)
# 	clavicle fracture seen (Clavicle fracture)
# 	consolidation seen (Consolidation)
# 	edema seen (Edema)
# 	emphysema seen (Emphysema)
# 	enlarged pulmonary artery seen (Enlarged PA)
# 	interstitial lung disease seen (ILD)
# 	infiltration seen (Infiltration)
# 	lung opacity seen (Lung Opacity)
# 	lung cavity seen (Lung cavity)
# 	lung cyst seen (Lung cyst)
# 	mediastinal shift seen (Mediastinal shift)
# 	nodule/mass seen (Nodule/Mass)
# 	other lesion seen (Other lesion)
# 	pleural effusion seen (Pleural effusion)
# 	pleural thickening seen (Pleural thickening)
# 	pneumothorax seen (Pneumothorax)
# 	pulmonary fibrosis seen (Pulmonary fibrosis)
# 	rib fracture seen (Rib fracture)
# 	copd seen (COPD)
# 	lung tumor seen (Lung tumor)
# 	pneumonia seen (Pneumonia)
# 	tuberculosis seen (Tuberculosis)
# 	other disease seen (Other disease)
# 	no abnormalities seen (No finding)
# Generating train dataset and dataloader
# len(train_indices) = 15000
# No labels: 0
# Edema: 13
# Clavicle fracture: 27
# Lung cyst: 33
# COPD: 36
# Lung cavity: 51
# Emphysema: 81
# Rib fracture: 90
# Pneumothorax: 96
# Enlarged PA: 131
# Mediastinal shift: 150
# Atelectasis: 187
# Lung tumor: 291
# Consolidation: 353
# ILD: 397
# Calcification: 458
# Infiltration: 613
# Tuberculosis: 750
# Nodule/Mass: 841
# Pneumonia: 919
# Pleural effusion: 1038
# Other lesion: 1154
# Lung Opacity: 1331
# Pulmonary fibrosis: 1621
# Pleural thickening: 2010
# Cardiomegaly: 2316
# Aortic enlargement: 3098
# Other disease: 4377
# No finding: 10478
# Group sizes: [10478, 771, 323, 312, 286, 278, 258, 243, 241, 218, 215, 167, 159, 156, 122, 119, 117, 114, 102, 83, 82, 79, 77]
#   len(indices) = 10478, weight = 2381.9852437292775
#   len(indices) = 771, weight = 882.1360585110112
#   len(indices) = 323, weight = 579.1323556126193
#   len(indices) = 312, weight = 568.7753795323758
#   len(indices) = 286, weight = 543.3127950518186
#   len(indices) = 278, weight = 535.1778961104801
#   len(indices) = 258, weight = 514.1586596868186
#   len(indices) = 243, weight = 497.69925147612867
#   len(indices) = 241, weight = 495.4562099629317
#   len(indices) = 218, weight = 468.76865710351854
#   len(indices) = 215, weight = 465.15882500917724
#   len(indices) = 167, weight = 402.55283205217046
#   len(indices) = 159, weight = 391.0802349542582
#   len(indices) = 156, weight = 386.6879164039802
#   len(indices) = 122, weight = 332.9187999914028
#   len(indices) = 119, weight = 327.76937690454827
#   len(indices) = 117, weight = 324.29434664271645
#   len(indices) = 114, weight = 319.0166061056533
#   len(indices) = 102, weight = 297.0647831080699
#   len(indices) = 83, weight = 259.088791948487
#   len(indices) = 82, weight = 256.9625090236898
#   len(indices) = 79, weight = 250.497443897163
#   len(indices) = 77, weight = 246.11308599196298
# batch_size = 16
# Generating val dataset and dataloader
# len(test_indices) = 3000
# batch_size = 96
# --------------------------------------------------
# 7) Creating dataloaders ...
# len(vinbig_trainer.train_dataloader) = 62500000000000000
# len(vinbig_trainer.val_dataloader) = 32
# len(_train_dataloaders) = 1
# len(_val_dataloaders) = 1
# _train_weights = [1.0]
# merged_dataset_name = vinbig
# --------------------------------------------------
# 8) Attaching metrics, losses, timer and events to engines ...
# --------------------------------------------------
# 9) Defining learning rate scheduler handler ...
# --------------------------------------------------
# 10) Defining checkpoint folder path ...
# checkpoint_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250212_175945_vinbig_PhraseGrounder(facebook-convnext-small-224,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)
# metadata saved to /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250212_175945_vinbig_PhraseGrounder(facebook-convnext-small-224,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/metadata.json
# --------------------------------------------------
# 11) Defining log_metrics_handler ...
# MetricsLogger :: we'll be logging to /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250212_175945_vinbig_PhraseGrounder(facebook-convnext-small-224,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/metrics_logs.csv
# --------------------------------------------------
# 12) Running trainer engine ...
# ---- Epoch 1/130
# (1) Training stage (lr = 0.000001) ...
# loss 4.50710, vbg_vgbbox_loss 1.41504, vbg_att_sup_loss 1.36192, vbg_phrcls_loss 1.73015, vbg_prc_auc 0.15706, 285.52 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.05295, vbg_prc_auc 0.08308, 47.97 secs
# Train metrics:
# vbg_vgbbox_loss: 0.4141, weight = 1.0
# vbg_att_sup_loss: 0.4234, weight = 1.0
# vbg_prc_auc: 0.1571, weight = 10.0
# num = 2.4081, den = 12.0000, score = 0.2007
# Val metrics:
# vbg_bbox_iou: 0.0529, weight = 1.0
# vbg_prc_auc: 0.0831, weight = 10.0
# num = 0.8837, den = 11.0000, score = 0.0803
# Train score = 0.2007, Val score = 0.0803, Final score = 0.0864
# w_train = 0.05, w_val = 0.95
# New checkpoint saved: checkpoint_1_vbss+vbou+vbuc+vbss=0.0864.pt
# ---- Epoch 2/130
# (1) Training stage (lr = 0.000004) ...
# loss 3.20383, vbg_vgbbox_loss 0.47243, vbg_att_sup_loss 1.21504, vbg_phrcls_loss 1.51635, vbg_prc_auc 0.15843, 285.49 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.09235, vbg_prc_auc 0.11862, 50.75 secs
# New checkpoint saved: checkpoint_2_vbss+vbou+vbuc+vbss=0.1217.pt
# ---- Epoch 3/130
# (1) Training stage (lr = 0.000019) ...
# loss 2.39150, vbg_vgbbox_loss 0.31029, vbg_att_sup_loss 0.77650, vbg_phrcls_loss 1.30472, vbg_prc_auc 0.27991, 279.59 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.13730, vbg_prc_auc 0.24656, 49.46 secs
# New checkpoint saved: checkpoint_3_vbss+vbou+vbuc+vbss=0.2420.pt
# ---- Epoch 4/130
# (1) Training stage (lr = 0.000080) ...
# loss 2.00291, vbg_vgbbox_loss 0.29202, vbg_att_sup_loss 0.56966, vbg_phrcls_loss 1.14123, vbg_prc_auc 0.35576, 285.32 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.15829, vbg_prc_auc 0.30626, 49.06 secs
# New checkpoint saved: checkpoint_4_vbss+vbou+vbuc+vbss=0.2989.pt
# ---- Epoch 5/130
# (1) Training stage (lr = 0.000033) ...
# loss 1.71962, vbg_vgbbox_loss 0.23287, vbg_att_sup_loss 0.46662, vbg_phrcls_loss 1.02013, vbg_prc_auc 0.41722, 285.72 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.18385, vbg_prc_auc 0.32315, 48.20 secs
# New checkpoint saved: checkpoint_5_vbss+vbou+vbuc+vbss=0.3186.pt
# ---- Epoch 6/130
# (1) Training stage (lr = 0.000014) ...
# loss 1.62371, vbg_vgbbox_loss 0.21788, vbg_att_sup_loss 0.43382, vbg_phrcls_loss 0.97201, vbg_prc_auc 0.44853, 286.34 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.18267, vbg_prc_auc 0.33598, 47.67 secs
# New checkpoint saved: checkpoint_6_vbss+vbou+vbuc+vbss=0.3310.pt
# ---- Epoch 7/130
# (1) Training stage (lr = 0.000006) ...
# loss 1.57752, vbg_vgbbox_loss 0.21019, vbg_att_sup_loss 0.41902, vbg_phrcls_loss 0.94832, vbg_prc_auc 0.46663, 276.70 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.18563, vbg_prc_auc 0.33959, 48.17 secs
# New checkpoint saved: checkpoint_7_vbss+vbou+vbuc+vbss=0.3351.pt
# ---- Epoch 8/130
# (1) Training stage (lr = 0.000002) ...
# loss 1.56407, vbg_vgbbox_loss 0.20959, vbg_att_sup_loss 0.41480, vbg_phrcls_loss 0.93968, vbg_prc_auc 0.47481, 280.71 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.18533, vbg_prc_auc 0.34224, 48.42 secs
# New checkpoint saved: checkpoint_8_vbss+vbou+vbuc+vbss=0.3378.pt
# ---- Epoch 9/130
# (1) Training stage (lr = 0.000001) ...
# loss 1.55241, vbg_vgbbox_loss 0.20849, vbg_att_sup_loss 0.41087, vbg_phrcls_loss 0.93305, vbg_prc_auc 0.47783, 276.51 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.18720, vbg_prc_auc 0.34200, 47.27 secs
# New checkpoint saved: checkpoint_9_vbss+vbou+vbuc+vbss=0.3378.pt
# ---- Epoch 10/130
# (1) Training stage (lr = 0.000080) ...
# loss 1.61465, vbg_vgbbox_loss 0.24517, vbg_att_sup_loss 0.41972, vbg_phrcls_loss 0.94976, vbg_prc_auc 0.47082, 284.34 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.17401, vbg_prc_auc 0.35344, 47.60 secs
# New checkpoint saved: checkpoint_10_vbss+vbou+vbuc+vbss=0.3462.pt
# ---- Epoch 11/130
# (1) Training stage (lr = 0.000027) ...
# loss 1.43203, vbg_vgbbox_loss 0.20815, vbg_att_sup_loss 0.36885, vbg_phrcls_loss 0.85503, vbg_prc_auc 0.55261, 286.17 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.18192, vbg_prc_auc 0.37363, 47.48 secs
# New checkpoint saved: checkpoint_11_vbss+vbou+vbuc+vbss=0.3679.pt
# ---- Epoch 12/130
# (1) Training stage (lr = 0.000009) ...
# loss 1.35527, vbg_vgbbox_loss 0.20091, vbg_att_sup_loss 0.34973, vbg_phrcls_loss 0.80463, vbg_prc_auc 0.59709, 276.94 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.18727, vbg_prc_auc 0.37091, 46.99 secs
# New checkpoint saved: checkpoint_12_vbss+vbou+vbuc+vbss=0.3679.pt
# ---- Epoch 13/130
# (1) Training stage (lr = 0.000003) ...
# loss 1.31822, vbg_vgbbox_loss 0.19726, vbg_att_sup_loss 0.33834, vbg_phrcls_loss 0.78262, vbg_prc_auc 0.61171, 285.85 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.18669, vbg_prc_auc 0.37288, 47.39 secs
# New checkpoint saved: checkpoint_13_vbss+vbou+vbuc+vbss=0.3702.pt
# ---- Epoch 14/130
# (1) Training stage (lr = 0.000001) ...
# loss 1.31089, vbg_vgbbox_loss 0.19659, vbg_att_sup_loss 0.33826, vbg_phrcls_loss 0.77603, vbg_prc_auc 0.62035, 287.24 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.18790, vbg_prc_auc 0.37122, 47.60 secs
# ---- Epoch 15/130
# (1) Training stage (lr = 0.000080) ...
# loss 1.40134, vbg_vgbbox_loss 0.22581, vbg_att_sup_loss 0.35432, vbg_phrcls_loss 0.82121, vbg_prc_auc 0.57771, 286.60 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.18597, vbg_prc_auc 0.38237, 46.80 secs
# New checkpoint saved: checkpoint_15_vbss+vbou+vbuc+vbss=0.3768.pt
# ---- Epoch 16/130
# (1) Training stage (lr = 0.000027) ...
# loss 1.21772, vbg_vgbbox_loss 0.19982, vbg_att_sup_loss 0.31030, vbg_phrcls_loss 0.70760, vbg_prc_auc 0.67844, 285.54 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.17907, vbg_prc_auc 0.41483, 46.07 secs
# New checkpoint saved: checkpoint_16_vbss+vbou+vbuc+vbss=0.4086.pt
# ---- Epoch 17/130
# (1) Training stage (lr = 0.000009) ...
# loss 1.13570, vbg_vgbbox_loss 0.19227, vbg_att_sup_loss 0.29104, vbg_phrcls_loss 0.65238, vbg_prc_auc 0.72225, 285.85 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.18922, vbg_prc_auc 0.39021, 47.29 secs
# ---- Epoch 18/130
# (1) Training stage (lr = 0.000003) ...
# loss 1.10584, vbg_vgbbox_loss 0.19082, vbg_att_sup_loss 0.28354, vbg_phrcls_loss 0.63148, vbg_prc_auc 0.74496, 285.80 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.19057, vbg_prc_auc 0.38852, 45.16 secs
# ---- Epoch 19/130
# (1) Training stage (lr = 0.000001) ...
# loss 1.09209, vbg_vgbbox_loss 0.18942, vbg_att_sup_loss 0.28284, vbg_phrcls_loss 0.61983, vbg_prc_auc 0.74920, 278.81 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.19374, vbg_prc_auc 0.40582, 45.87 secs
# ---- Epoch 20/130
# (1) Training stage (lr = 0.000080) ...
# loss 1.21840, vbg_vgbbox_loss 0.21521, vbg_att_sup_loss 0.30733, vbg_phrcls_loss 0.69586, vbg_prc_auc 0.68072, 286.54 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.16353, vbg_prc_auc 0.38251, 45.42 secs
# ---- Epoch 21/130
# (1) Training stage (lr = 0.000027) ...
# loss 1.04449, vbg_vgbbox_loss 0.19420, vbg_att_sup_loss 0.26884, vbg_phrcls_loss 0.58145, vbg_prc_auc 0.77694, 287.67 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.18156, vbg_prc_auc 0.39782, 45.94 secs
# ---- Epoch 22/130
# (1) Training stage (lr = 0.000009) ...
# loss 0.95144, vbg_vgbbox_loss 0.18521, vbg_att_sup_loss 0.24869, vbg_phrcls_loss 0.51754, vbg_prc_auc 0.83077, 286.54 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.18990, vbg_prc_auc 0.41517, 46.08 secs
# New checkpoint saved: checkpoint_22_vbss+vbou+vbuc+vbss=0.4164.pt
# ---- Epoch 23/130
# (1) Training stage (lr = 0.000003) ...
# loss 0.92542, vbg_vgbbox_loss 0.18260, vbg_att_sup_loss 0.24380, vbg_phrcls_loss 0.49902, vbg_prc_auc 0.84529, 287.07 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.18723, vbg_prc_auc 0.41703, 45.10 secs
# New checkpoint saved: checkpoint_23_vbss+vbou+vbuc+vbss=0.4184.pt
# ---- Epoch 24/130
# (1) Training stage (lr = 0.000001) ...
# loss 0.90901, vbg_vgbbox_loss 0.18175, vbg_att_sup_loss 0.24031, vbg_phrcls_loss 0.48695, vbg_prc_auc 0.84943, 287.12 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.18564, vbg_prc_auc 0.41493, 45.95 secs
# ---- Epoch 25/130
# (1) Training stage (lr = 0.000080) ...
# loss 1.04570, vbg_vgbbox_loss 0.20616, vbg_att_sup_loss 0.26602, vbg_phrcls_loss 0.57352, vbg_prc_auc 0.77646, 287.46 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.16449, vbg_prc_auc 0.39709, 45.80 secs
# ---- Epoch 26/130
# (1) Training stage (lr = 0.000027) ...
# loss 0.88793, vbg_vgbbox_loss 0.18868, vbg_att_sup_loss 0.23326, vbg_phrcls_loss 0.46599, vbg_prc_auc 0.86732, 289.34 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.18254, vbg_prc_auc 0.43715, 45.98 secs
# New checkpoint saved: checkpoint_26_vbss+vbou+vbuc+vbss=0.4363.pt
# ---- Epoch 27/130
# (1) Training stage (lr = 0.000009) ...
# loss 0.80705, vbg_vgbbox_loss 0.18085, vbg_att_sup_loss 0.21878, vbg_phrcls_loss 0.40742, vbg_prc_auc 0.90726, 288.09 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.18286, vbg_prc_auc 0.43402, 46.03 secs
# ---- Epoch 28/130
# (1) Training stage (lr = 0.000003) ...
# loss 0.77833, vbg_vgbbox_loss 0.17768, vbg_att_sup_loss 0.21283, vbg_phrcls_loss 0.38782, vbg_prc_auc 0.91346, 290.79 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.17949, vbg_prc_auc 0.43049, 46.25 secs
# ---- Epoch 29/130
# (1) Training stage (lr = 0.000001) ...
# loss 0.76262, vbg_vgbbox_loss 0.17682, vbg_att_sup_loss 0.20970, vbg_phrcls_loss 0.37610, vbg_prc_auc 0.91937, 289.09 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.18074, vbg_prc_auc 0.43089, 45.90 secs
# ---- Epoch 30/130
# (1) Training stage (lr = 0.000080) ...
# loss 0.92829, vbg_vgbbox_loss 0.20320, vbg_att_sup_loss 0.24164, vbg_phrcls_loss 0.48345, vbg_prc_auc 0.84531, 288.69 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.18675, vbg_prc_auc 0.40495, 46.80 secs
# ---- Epoch 31/130
# (1) Training stage (lr = 0.000027) ...
# loss 0.76596, vbg_vgbbox_loss 0.18174, vbg_att_sup_loss 0.20865, vbg_phrcls_loss 0.37557, vbg_prc_auc 0.91851, 287.07 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.17642, vbg_prc_auc 0.42168, 45.35 secs
# ---- Epoch 32/130
# (1) Training stage (lr = 0.000009) ...
# loss 0.68722, vbg_vgbbox_loss 0.17473, vbg_att_sup_loss 0.19345, vbg_phrcls_loss 0.31904, vbg_prc_auc 0.94394, 287.12 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.18165, vbg_prc_auc 0.42844, 45.77 secs
# ---- Epoch 33/130
# (1) Training stage (lr = 0.000003) ...
# loss 0.65788, vbg_vgbbox_loss 0.17309, vbg_att_sup_loss 0.18897, vbg_phrcls_loss 0.29581, vbg_prc_auc 0.95291, 287.17 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.18097, vbg_prc_auc 0.42848, 45.20 secs
# ---- Epoch 34/130
# (1) Training stage (lr = 0.000001) ...
# loss 0.65311, vbg_vgbbox_loss 0.17311, vbg_att_sup_loss 0.18789, vbg_phrcls_loss 0.29211, vbg_prc_auc 0.95345, 288.40 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.17691, vbg_prc_auc 0.42603, 45.73 secs
# ---- Epoch 35/130
# (1) Training stage (lr = 0.000080) ...
# ^C iteration 27225
# Engine run is terminating due to exception:
# Traceback (most recent call last):
#   File "/home/pamessina/medvqa/medvqa/notebooks/../train_phrase_grounding.py", line 1552, in <module>
#     train_from_scratch(**args)
#   File "/home/pamessina/medvqa/medvqa/notebooks/../train_phrase_grounding.py", line 1418, in train_from_scratch
#     return train_model(
#   File "/home/pamessina/medvqa/medvqa/notebooks/../train_phrase_grounding.py", line 926, in train_model
#     run_common_boilerplate_code_and_start_training(
#   File "/home/pamessina/medvqa/medvqa/training/utils.py", line 137, in run_common_boilerplate_code_and_start_training
#     trainer_engine.run(train_dataloader, max_epochs=epochs, epoch_length=batches_per_epoch)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 892, in run
#     return self._internal_run()
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 935, in _internal_run
#     return next(self._internal_run_generator)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 993, in _internal_run_as_gen
#     self._handle_exception(e)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 638, in _handle_exception
#     raise e
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 959, in _internal_run_as_gen
#     epoch_time_taken += yield from self._run_once_on_dataset_as_gen()
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 1068, in _run_once_on_dataset_as_gen
#     self.state.output = self._process_function(self, self.state.batch)
#   File "/home/pamessina/medvqa/medvqa/training/phrase_grounding.py", line 991, in step_fn
#     output = flag_to_step_fn[flag](batch)
#   File "/home/pamessina/medvqa/medvqa/training/phrase_grounding.py", line 622, in step_fn__vinbig_bbox_grounding
#     gradient_accumulator.step(batch_loss, model)
#   File "/home/pamessina/medvqa/medvqa/losses/optimizers.py", line 35, in step
#     self.scaler.step(self.optimizer)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/amp/grad_scaler.py", line 453, in step
#     retval = self._maybe_opt_step(optimizer, optimizer_state, *args, **kwargs)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/amp/grad_scaler.py", line 350, in _maybe_opt_step
#     if not sum(v.item() for v in optimizer_state["found_inf_per_device"].values()):
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/amp/grad_scaler.py", line 350, in <genexpr>
#     if not sum(v.item() for v in optimizer_state["found_inf_per_device"].values()):
# KeyboardInterrupt
