# %%
# %env CUDA_VISIBLE_DEVICES=2
# Out:
# env: CUDA_VISIBLE_DEVICES=2

# %%
# !python ../train_phrase_grounding.py \
--checkpoint_folder "models/phrase_grounding/20240825_115146_mim-facts+chst-img-anat+cxrlt2024(Off)+cxrlt2024(GPT4)+vinbig+chexloc+chxp+iuxray_PhraseGrounder(aehrc-cxrmate-rrg24,FiLM_SigmoidAttention,128,256,256,256,1,256-128)" \
--epochs 100 \
--batches_per_epoch 1200 \
--max_images_per_batch 10 \
--max_phrases_per_batch 400 \
--max_phrases_per_image 45 \
--val_batch_size_factor 5.0 \
--raw_image_encoding "cxrmate-rrg24-uniformer-huggingface" \
--huggingface_model_name "aehrc/cxrmate-rrg24" \
--img_aug_mode "random-color-and-spatial" \
--image_size 384 384 \
--image_local_feat_size 512 \
--num_regions 144 \
--regions_width 12 \
--regions_height 12 \
--phrase_embedding_size 128 \
--phrase_grounding_mode "film_layers_plus_sigmoid_attention_and_custom_classifier" \
--visual_feature_proj_size 256 \
--visual_grounding_hidden_size 256 \
--phrase_mlp_hidden_dims 256 128 \
--num_train_workers 2 \
--num_val_workers 2 \
--gradient_accumulation_steps 10 \
--optimizer_name "adamw" \
--scheduler "exp-warmup+decay+cyclicdecay" \
--lr 1e-6 \
--warmup_decay_and_cyclic_decay_args "1e-6,3,8e-5,5,1e-6,8e-5,5,1e-6" \
--mimiccxr_exclude_noisy_images \
--binary_multilabel_classif_loss_name "focal+bce+npbbce" \
--use_attention_regularization_loss \
--attention_supervision_loss_weight 2.0 \
--phrase_classifier_loss_weight 2.0 \
--foreground_loss_weight 1.5 \
--use_cxrlt2024_challenge_split \
--cxrlt2024_do_balanced_sampling \
--use_cxrlt2024_official_labels \
--use_all_cxrlt2024_official_labels_for_training \
--cxrlt2024_official_training_labels_for_fact_classification_filepath \
"/mnt/workspace/pamessina/medvqa-workspace/cache/mimiccxr/cxrlt2024_official_training_labels_for_fact_classification(n_train=240529,n_val=18342,pf=0.03).pkl" \
--use_cxrlt2024_custom_labels \
--cxrlt2024_custom_dicom_id_to_pos_neg_facts_filepath \
"/mnt/workspace/pamessina/medvqa-workspace/cache/mimiccxr/cxrlt2024_integrated_nli_queries_for_fact_classification.pkl" \
--use_mimiccxr_facts_for_train \
--dicom_id_to_pos_neg_facts_filepath \
"/mnt/workspace/pamessina/medvqa-workspace/cache/mimiccxr_dicom_id_to_fact_based_pos_neg_facts(hash=1360,3939902508813076616).pkl" \
--mimiccxr_exclude_noisy_images \
--use_chest_imagenome_for_train \
--chest_imagenome_bbox_phrase_embeddings_filepath \
"/mnt/workspace/pamessina/medvqa-workspace/cache/chest_imagenome/bbox_phrase_embeddings(hash=333,1643894111267724539).pkl" \
--use_vinbig_for_train \
--vinbig_phrase_embeddings_filepath \
"/mnt/workspace/pamessina/medvqa-workspace/cache/vinbig/label_phrase_embeddings(hash=325,2238524744738711392).pkl" \
--vinbig_training_data_mode "all" \
--use_chexlocalize_for_train \
--chexlocalize_class_phrase_embeddings_filepath \
"/mnt/workspace/pamessina/medvqa-workspace/cache/chexlocalize/class_phrase_embeddings(hash=528,2353352898845085012).pkl" \
--use_chexpert_for_train \
--chexpert_class_phrase_embeddings_filepath \
"/mnt/workspace/pamessina/medvqa-workspace/cache/chexpert/class_phrase_embeddings(hash=592,2793798096738783992).pkl" \
--use_iuxray_for_train \
--iuxray_image_id_to_pos_neg_facts_filepath \
"/mnt/workspace/pamessina/medvqa-workspace/cache/iuxray/image_id_to_pos_neg_facts(hash=450,1832071235913899237).pkl" \
--cxrlt2024_weight 6.0 \
--mimiccxr_facts_weight 2.5 \
--chest_imagenome_anatlocs_weight 1.0 \
--iuxray_weight 0.5 \
--vinbig_weight 1.5 \
--chexpert_weight 0.5 \
--chexlocalize_weight 0.4 \
--save
# Out:
# script's arguments:
#    epochs: 100
#    batches_per_epoch: 1200
#    max_images_per_batch: 10
#    max_phrases_per_batch: 400
#    max_phrases_per_image: 45
#    val_batch_size_factor: 5.0
#    checkpoint_folder: models/phrase_grounding/20240825_115146_mim-facts+chst-img-anat+cxrlt2024(Off)+cxrlt2024(GPT4)+vinbig+chexloc+chxp+iuxray_PhraseGrounder(aehrc-cxrmate-rrg24,FiLM_SigmoidAttention,128,256,256,256,1,256-128)
#    pretrained_checkpoint_folder_path: None
#    pretrained_checkpoint_folder_paths: None
#    freeze_image_encoder: False
#    raw_image_encoding: cxrmate-rrg24-uniformer-huggingface
#    huggingface_model_name: aehrc/cxrmate-rrg24
#    num_regions: 144
#    image_local_feat_size: 512
#    image_encoder_pretrained_weights_path: None
#    image_encoder_dropout_p: 0
#    yolov8_model_name_or_path: None
#    yolov8_model_alias: None
#    phrase_embedding_size: 128
#    regions_width: 12
#    regions_height: 12
#    qkv_size: None
#    phrase_grounding_mode: film_layers_plus_sigmoid_attention_and_custom_classifier
#    phrase_classifier_hidden_size: None
#    transf_d_model: None
#    transf_nhead: None
#    transf_dim_feedforward: None
#    transf_dropout: 0
#    transf_num_layers: None
#    visual_feature_proj_size: 256
#    visual_grounding_hidden_size: 256
#    phrase_mlp_hidden_dims: [256, 128]
#    optimizer_name: adamw
#    lr: 1e-06
#    scheduler: exp-warmup+decay+cyclicdecay
#    lr_decay: 0.76
#    lr_decay_patience: 2
#    warmup_and_decay_args: None
#    warmup_and_cosine_args: None
#    warmup_decay_and_cyclic_decay_args: 1e-6,3,8e-5,5,1e-6,8e-5,5,1e-6
#    gradient_accumulation_steps: 10
#    override_lr: False
#    max_grad_norm: None
#    attention_supervision_loss_weight: 2.0
#    phrase_classifier_loss_weight: 2.0
#    foreground_loss_weight: 1.5
#    background_loss_weight: 1.0
#    focal_loss_weight: 1.0
#    bce_loss_weight: 1.0
#    wbce_loss_weight: 1.0
#    binary_multilabel_classif_loss_name: focal+bce+npbbce
#    use_weighted_phrase_classifier_loss: False
#    cluster_and_label_weights_for_facts_filepath: None
#    use_attention_regularization_loss: True
#    use_contrastive_phrase_grounding_loss: False
#    num_train_workers: 2
#    num_val_workers: 2
#    device: GPU
#    use_amp: False
#    image_size: [384, 384]
#    dicom_id_to_pos_neg_facts_filepath: /mnt/workspace/pamessina/medvqa-workspace/cache/mimiccxr_dicom_id_to_fact_based_pos_neg_facts(hash=1360,3939902508813076616).pkl
#    iuxray_image_id_to_pos_neg_facts_filepath: /mnt/workspace/pamessina/medvqa-workspace/cache/iuxray/image_id_to_pos_neg_facts(hash=450,1832071235913899237).pkl
#    mscxr_phrase2embedding_filepath: None
#    chest_imagenome_bbox_phrase_embeddings_filepath: /mnt/workspace/pamessina/medvqa-workspace/cache/chest_imagenome/bbox_phrase_embeddings(hash=333,1643894111267724539).pkl
#    vinbig_phrase_embeddings_filepath: /mnt/workspace/pamessina/medvqa-workspace/cache/vinbig/label_phrase_embeddings(hash=325,2238524744738711392).pkl
#    chexlocalize_class_phrase_embeddings_filepath: /mnt/workspace/pamessina/medvqa-workspace/cache/chexlocalize/class_phrase_embeddings(hash=528,2353352898845085012).pkl
#    chexpert_class_phrase_embeddings_filepath: /mnt/workspace/pamessina/medvqa-workspace/cache/chexpert/class_phrase_embeddings(hash=592,2793798096738783992).pkl
#    mimiccxr_exclude_noisy_images: True
#    mimiccxr_facts_weight: 2.5
#    chest_imagenome_anatlocs_weight: 1.0
#    mscxr_weight: 1.0
#    cxrlt2024_weight: 6.0
#    vinbig_weight: 1.5
#    chexlocalize_weight: 0.4
#    chexpert_weight: 0.5
#    iuxray_weight: 0.5
#    img_aug_mode: random-color-and-spatial
#    pos_area_prior: 0.4
#    neg_area_prior: 0.0
#    use_mimiccxr_facts_for_train: True
#    use_mimiccxr_facts_for_test: False
#    use_mscxr_for_train: False
#    use_mscxr_for_test: False
#    use_chest_imagenome_for_train: True
#    use_chest_imagenome_gold_for_test: False
#    use_vinbig_for_train: True
#    use_vinbig_for_test: False
#    use_chexlocalize_for_train: True
#    use_chexlocalize_for_test: False
#    use_chexpert_for_train: True
#    use_chexpert_for_test: False
#    use_iuxray_for_train: True
#    use_iuxray_for_test: False
#    use_cxrlt2024_challenge_split: True
#    use_cxrlt2024_custom_labels: True
#    use_cxrlt2024_official_labels: True
#    use_all_cxrlt2024_official_labels_for_training: True
#    vinbig_training_data_mode: all
#    chexpert_training_data_mode: all
#    mimiccxr_balance_long_middle_short_tail: False
#    mimiccxr_long_middle_short_tail_thresholds: (0.02, 0.05)
#    mimiccxr_report_fact_nli_integrated_data_filepath: None
#    mimiccxr_use_interpret_cxr_challenge_split: False
#    mimiccxr_interpret_cxr_challenge_split_filepath: None
#    iuxray_use_interpret_cxr_challenge_split: False
#    iuxray_interpret_cxr_challenge_split_filepath: None
#    chexpert_use_interpret_cxr_challenge_split: False
#    chexpert_interpret_cxr_challenge_split_filepath: None
#    chexlocalize_use_interpret_cxr_challenge_split: False
#    chexlocalize_interpret_cxr_challenge_split_filepath: None
#    cxrlt2024_custom_dicom_id_to_pos_neg_facts_filepath: /mnt/workspace/pamessina/medvqa-workspace/cache/mimiccxr/cxrlt2024_integrated_nli_queries_for_fact_classification.pkl
#    cxrlt2024_official_training_labels_for_fact_classification_filepath: /mnt/workspace/pamessina/medvqa-workspace/cache/mimiccxr/cxrlt2024_official_training_labels_for_fact_classification(n_train=240529,n_val=18342,pf=0.03).pkl
#    cxrlt2024_do_balanced_sampling: True
#    save: True
# ----- Resuming training ------
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240825_115146_mim-facts+chst-img-anat+cxrlt2024(Off)+cxrlt2024(GPT4)+vinbig+chexloc+chxp+iuxray_PhraseGrounder(aehrc-cxrmate-rrg24,FiLM_SigmoidAttention,128,256,256,256,1,256-128)/metadata.json
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Creating instance of PhraseGrounder ...
# WARNING: Unused kwargs: {'pretrained_checkpoint_folder_path': None, 'pretrained_checkpoint_folder_paths': None}
# MultiPurposeVisualModule()
#   Initializing raw_image_encoder: cxrmate-rrg24-uniformer-huggingface
#   self.global_feat_size = 1024
#   self.local_feat_size = 512
#   Initializing auxiliary tasks
# --------------------------------------------------
# 3) Defining optimizer ...
# create_optimizer(): name = adamw
# --------------------------------------------------
# 4) Defining scheduler ...
# Using exp-warmup+decay+cyclicdecay scheduler: 1e-6,3,8e-5,5,1e-6,8e-5,5,1e-6
# 1e-06 3 8e-05 5 1e-06 8e-05 5 1e-06
# self.steps_to_restart = 5
# self.steps = -1
# self.initial_lr = 8e-05
# --------------------------------------------------
# 5) Creating trainer and validator engines ...
# Focal_BCE_NPBBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 npbbce_weight = 0.3333333333333333
# Focal_BCE_NPBBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 npbbce_weight = 0.3333333333333333
# Focal_BCE_WBCBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 wbcbce_weight = 0.3333333333333333
# foreground_loss_weight: 1.5
# background_loss_weight: 1.0
# GradientAccumulator.__init__(): num_accumulation_steps = 10, max_grad_norm = None
# Focal_BCE_NPBBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 npbbce_weight = 0.3333333333333333
# Focal_BCE_NPBBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 npbbce_weight = 0.3333333333333333
# Focal_BCE_WBCBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 wbcbce_weight = 0.3333333333333333
# foreground_loss_weight: 1.0
# background_loss_weight: 1.0
# --------------------------------------------------
# 6) Creating CheXLocalize Phrase Grounding Trainer ...
# get_image_transform()
#   Using segmentation mask aware transforms
#     len(_augmented_mask_transforms) = 10
#     augmentation_mode = random-color-and-spatial
#     default_prob = 0.4
#     Returning augmented transforms with mode random-color-and-spatial
# get_image_transform()
#   Using segmentation mask aware transforms
#     Returning default transform (no augmentation)
# Loding class_phrase_embeddings_filepath and bbox_phrases from /mnt/workspace/pamessina/medvqa-workspace/cache/chexlocalize/class_phrase_embeddings(hash=528,2353352898845085012).pkl...
# class_phrase_embeddings.shape = (10, 128)
# len(class_phrases) = 10
# 	 enlarged cardiomediastinum seen
# 	 cardiomegaly seen
# 	 lung lesion seen
# 	 airspace opacity seen
# 	 edema seen
# 	 consolidation seen
# 	 atelectasis seen
# 	 pneumothorax seen
# 	 pleural effusion seen
# 	 support devices seen
# Compute phrase grounding masks and labels
# Without masks: 216/902
# Generating train dataset and dataloader
# len(train_indices) = 902
# batch_size = 10
# --------------------------------------------------
# 7) Creating CheXpert Phrase Grounding Trainer ...
# get_image_transform()
#   Using segmentation mask aware transforms
#     len(_augmented_mask_transforms) = 10
#     augmentation_mode = random-color-and-spatial
#     default_prob = 0.4
#     Returning augmented transforms with mode random-color-and-spatial
# get_image_transform()
#   Using segmentation mask aware transforms
#     Returning default transform (no augmentation)
# Loading dataframe from /mnt/workspace/chexpert/CheXpert-v1.0-small/train_visualCheXbert.csv
# len(df_train_visualchexbert) = 223414
# Loading dataframe from /mnt/workspace/chexpert/CheXpert-v1.0-small/valid.csv
# len(df_valid) = 234
# len(df) = 223648
# Loading images
# Loading chexpert labels
# Loading test set
# len(self.test_image_paths) = 668
# self.test_labels.shape = (668, 14)
# Loding phrase_embeddings and phrases from /mnt/workspace/pamessina/medvqa-workspace/cache/chexpert/class_phrase_embeddings(hash=592,2793798096738783992).pkl...
# phrase_embeddings.shape = (14, 128)
# len(phrases) = 14
# 	 no findings
# 	 enlarged cardiomediastinum seen
# 	 cardiomegaly seen
# 	 lung lesion seen
# 	 lung opacity seen
# 	 edema seen
# 	 consolidation seen
# 	 pneumonia seen
# 	 atelectasis seen
# 	 pneumothorax seen
# 	 pleural effusion seen
# 	 other pleural abnormality seen
# 	 fracture seen
# 	 support devices seen
# len(all_image_paths) = 224316
# all_labels.shape = (224316, 14)
# Generating train dataset and dataloader
# len(train_indices) = 224316
# No labels: 3246
# Pneumothorax: 25357
# Pleural Other: 26334
# Lung Lesion: 31042
# No Finding: 35673
# Pneumonia: 52248
# Fracture: 61696
# Edema: 94500
# Pleural Effusion: 103837
# Consolidation: 107297
# Cardiomegaly: 122164
# Atelectasis: 124182
# Support Devices: 136382
# Enlarged Cardiomediastinum: 144377
# Lung Opacity: 151937
# Group sizes: [61397, 30579, 25357, 21626, 18526, 17225, 11525, 11092, 10885, 7083, 4085, 3246, 1170, 347, 173]
#   len(indices) = 61397, weight = 4024.1406302660666
#   len(indices) = 30579, weight = 3308.1179132413095
#   len(indices) = 25357, weight = 3131.4217784165476
#   len(indices) = 21626, weight = 2986.2821261955132
#   len(indices) = 18526, weight = 2849.5564265118087
#   len(indices) = 17225, weight = 2786.68263628706
#   len(indices) = 11525, weight = 2456.265254834705
#   len(indices) = 11092, weight = 2426.215857884437
#   len(indices) = 10885, weight = 2411.5238383991996
#   len(indices) = 7083, weight = 2092.3117139635237
#   len(indices) = 4085, weight = 1726.3245386288693
#   len(indices) = 3246, weight = 1587.0568876515586
#   len(indices) = 1170, weight = 1058.8042504564921
#   len(indices) = 347, weight = 600.9534388852762
#   len(indices) = 173, weight = 410.9393870934724
# --------------------------------------------------
# 8) Creating VinBig Phrase Grounding Trainer ...
# get_image_transform()
#   Using segmentation mask aware transforms
#     len(_augmented_mask_transforms) = 10
#     augmentation_mode = random-color-and-spatial
#     default_prob = 0.4
#     Returning augmented transforms with mode random-color-and-spatial
# get_image_transform()
#   Using segmentation mask aware transforms
#     Returning default transform (no augmentation)
# Loading bounding boxes
# Anomalous bboxes found: 29 of 37367
# class_id_offset: 0
# Anomalous bboxes found: 0 of 2697
# class_id_offset: 0
#   Loaded 18000 bounding boxes
# Loding phrase_embeddings and phrases from /mnt/workspace/pamessina/medvqa-workspace/cache/vinbig/label_phrase_embeddings(hash=325,2238524744738711392).pkl...
# phrase_embeddings.shape = (28, 128)
# len(phrases) = 28
# 	 aortic enlargement seen
# 	 atelectasis seen
# 	 calcification seen
# 	 cardiomegaly seen
# 	 clavicle fracture seen
# 	 consolidation seen
# 	 edema seen
# 	 emphysema seen
# 	 enlarged pulmonary artery seen
# 	 interstitial lung disease seen
# 	 infiltration seen
# 	 lung opacity seen
# 	 lung cavity seen
# 	 lung cyst seen
# 	 mediastinal shift seen
# 	 nodule/mass seen
# 	 pleural effusion seen
# 	 pleural thickening seen
# 	 pneumothorax seen
# 	 pulmonary fibrosis seen
# 	 rib fracture seen
# 	 other lesion seen
# 	 copd seen
# 	 lung tumor seen
# 	 pneumonia seen
# 	 tuberculosis seen
# 	 other disease seen
# 	 no abnormalities seen
# Compute phrase grounding masks and labels
# self.phrase_grounding_masks.shape = (18000, 22, 144)
# self.phrase_classification_labels.shape = (18000, 22)
# Append additional labels to phrase_classification_labels
# len(non_bbox_labels) = 6
# non_bbox_labels = ['COPD', 'Lung tumor', 'Pneumonia', 'Tuberculosis', 'Other disease', 'No finding']
# self.phrase_classification_labels.shape = (18000, 28)
# Reorder phrases and phrase_embeddings
# len(phrases) = 28
# len(actual_phrases) = 28
# phrase_embeddings.shape = (28, 128)
# Generating train dataset and dataloader
# len(train_indices) = 18000
# No labels: 0
# Edema: 13
# Clavicle fracture: 29
# Lung cyst: 35
# COPD: 37
# Lung cavity: 60
# Emphysema: 84
# Rib fracture: 101
# Pneumothorax: 114
# Enlarged PA: 139
# Mediastinal shift: 170
# Atelectasis: 273
# Lung tumor: 371
# Consolidation: 449
# ILD: 618
# Calcification: 652
# Infiltration: 671
# Tuberculosis: 914
# Nodule/Mass: 1017
# Pleural effusion: 1149
# Pneumonia: 1163
# Other lesion: 1248
# Lung Opacity: 1415
# Pulmonary fibrosis: 1838
# Pleural thickening: 2179
# Cardiomegaly: 2625
# Aortic enlargement: 3318
# Other disease: 4945
# No finding: 12652
# Group sizes: [12529, 891, 444, 428, 364, 344, 307, 283, 273, 267, 245, 236, 206, 193, 170, 138, 127, 100, 99, 90, 56, 54, 49, 34, 73]
#   len(indices) = 12529, weight = 2522.6672479595745
#   len(indices) = 891, weight = 940.9850359649141
#   len(indices) = 444, weight = 680.1755171156125
#   len(indices) = 428, weight = 667.9638591411331
#   len(indices) = 364, weight = 615.8160380252455
#   len(indices) = 344, weight = 598.2811252947056
#   len(indices) = 307, weight = 563.9888635691133
#   len(indices) = 283, weight = 540.2796339164162
#   len(indices) = 273, weight = 530.0166624211873
#   len(indices) = 267, weight = 523.7422583945496
#   len(indices) = 245, weight = 499.93058392418243
#   len(indices) = 236, weight = 489.7963928535281
#   len(indices) = 206, weight = 454.1360559561945
#   len(indices) = 193, weight = 437.6702522239849
#   len(indices) = 170, weight = 406.7687016278156
#   len(indices) = 138, weight = 359.20170201154343
#   len(indices) = 127, weight = 341.33933626931963
#   len(indices) = 100, weight = 293.26529386579296
#   len(indices) = 99, weight = 291.34941227248714
#   len(indices) = 90, weight = 273.5936736738282
#   len(indices) = 56, weight = 195.85520038280242
#   len(indices) = 54, weight = 190.5945663000252
#   len(indices) = 49, weight = 177.00354049310113
#   len(indices) = 34, weight = 131.67512839151652
#   len(indices) = 73, weight = 237.15649291307946
# --------------------------------------------------
# 9) Creating MIMIC-CXR Phrase Grounding Trainer ...
# get_image_transform()
#   Using segmentation mask aware transforms
#     len(_augmented_mask_transforms) = 10
#     augmentation_mode = random-color-and-spatial
#     default_prob = 0.4
#     Returning augmented transforms with mode random-color-and-spatial
# get_image_transform()
#   Using segmentation mask aware transforms
#     Returning default transform (no augmentation)
# len(cxrlt2024_train_dicom_ids) = 258871
# len(cxrlt2024_dev_dicom_ids) = 39293
# len(forbidden_train_dicom_ids) = 40220
# Preparing CXR-LT-2024 challenge datasets and dataloaders for training/testing...
# Using image size mode: medium_512
# len(cxrlt2024_dicom_id_to_pos_neg_facts["train"]) = 145680
# len(cxrlt2024_dicom_id_to_pos_neg_facts["dev"]) = 39352
# Total number of images: 184650
# Building cxrlt2024 train phrase classifier dataloader...
# num_phrases = 2, len(indices) = 38366
# num_phrases = 1, len(indices) = 89231
# num_phrases = 3, len(indices) = 12488
# num_phrases = 4, len(indices) = 3658
# num_phrases = 11, len(indices) = 97
# num_phrases = 6, len(indices) = 281
# num_phrases = 5, len(indices) = 937
# num_phrases = 20, len(indices) = 97
# num_phrases = 7, len(indices) = 52
# num_phrases = 16, len(indices) = 48
# num_phrases = 17, len(indices) = 26
# num_phrases = 10, len(indices) = 2
# num_phrases = 8, len(indices) = 13
# num_phrases = 12, len(indices) = 2
# Building cxrlt2024 dev phrase classifier dataloader...
# num_phrases = 2, len(indices) = 7030
# num_phrases = 1, len(indices) = 29823
# num_phrases = 3, len(indices) = 1393
# num_phrases = 12, len(indices) = 77
# num_phrases = 6, len(indices) = 25
# num_phrases = 8, len(indices) = 34
# num_phrases = 14, len(indices) = 74
# num_phrases = 11, len(indices) = 124
# num_phrases = 16, len(indices) = 53
# num_phrases = 4, len(indices) = 294
# num_phrases = 15, len(indices) = 51
# num_phrases = 10, len(indices) = 77
# num_phrases = 9, len(indices) = 32
# num_phrases = 7, len(indices) = 36
# num_phrases = 13, len(indices) = 92
# num_phrases = 20, len(indices) = 54
# num_phrases = 5, len(indices) = 54
# num_phrases = 18, len(indices) = 7
# num_phrases = 17, len(indices) = 18
# num_phrases = 19, len(indices) = 4
# Building cxrlt2024 train/val dataloader for fact classifier using official labels...
# len(dicom_ids) = 258871
# len(train_indices) = 240529
# len(val_indices) = 18342
# labels.shape = (258871, 40)
# class_embeddings.shape = (40, 128)
# Using all CXR-LT-2024 official labels for training the fact classifier
# len(train_indices) = 258871
# len(val_indices) = 0
# 707 train indices removed due to forbidden_train_dicom_ids
# Balanced sampling is enabled for CXR-LT-2024 fact classifier training
# Lobar Atelectasis: 129
# Clavicle Fracture: 167
# Round(ed) Atelectasis: 171
# Azygos Lobe: 198
# Pneumoperitoneum: 515
# Pleural Other: 614
# Hydropneumothorax: 645
# Pneumomediastinum: 704
# Infarction: 725
# Kyphosis: 777
# Pulmonary Hypertension: 900
# Fibrosis: 1168
# Pulmonary Embolism: 1628
# Subcutaneous Emphysema: 2045
# Tuberculosis: 2074
# Lung Lesion: 2324
# Fissure: 2799
# Granuloma: 2959
# Pleural Thickening: 3262
# Tortuous Aorta: 3328
# Adenopathy: 3403
# Emphysema: 3650
# Hernia: 3976
# Calcification of the Aorta: 4231
# Mass: 5267
# Nodule: 7512
# Rib Fracture: 8901
# Infiltration: 10064
# Fracture: 11542
# Pneumothorax: 13822
# No labels: 13915
# Consolidation: 15317
# Enlarged Cardiomediastinum: 29540
# Normal: 34205
# Edema: 37140
# Pneumonia: 46530
# Atelectasis: 65148
# Pleural Effusion: 66132
# Cardiomegaly: 74542
# Lung Opacity: 77197
# Support Devices: 85689
# Group sizes: [34205, 24884, 24150, 22748, 19196, 14441, 13915, 10656, 9421, 9182, 8327, 8127, 7090, 5005, 3785, 3748, 3497, 3382, 3033, 2881, 2809, 2734, 2637, 2532, 2132, 2007, 1892, 1721, 1434, 1133, 875, 770, 718, 666, 641, 610, 515, 198, 171, 167, 129]
#   len(indices) = 34205, weight = 3416.968505575188
#   len(indices) = 24884, weight = 3114.0105584213015
#   len(indices) = 24150, weight = 3086.458645767619
#   len(indices) = 22748, weight = 3031.91054482965
#   len(indices) = 19196, weight = 2880.5738366725595
#   len(indices) = 14441, weight = 2638.3021770753585
#   len(indices) = 13915, weight = 2607.758881815128
#   len(indices) = 10656, weight = 2395.0126251246966
#   len(indices) = 9421, weight = 2300.838171256539
#   len(indices) = 9182, weight = 2281.5095060487456
#   len(indices) = 8327, weight = 2208.9773218632636
#   len(indices) = 8127, weight = 2191.1782895085344
#   len(indices) = 7090, weight = 2093.0111715585585
#   len(indices) = 5005, weight = 1855.94882572346
#   len(indices) = 3785, weight = 1679.251257544058
#   len(indices) = 3748, weight = 1673.2516585085702
#   len(indices) = 3497, weight = 1631.322863020584
#   len(indices) = 3382, weight = 1611.3495036813902
#   len(indices) = 3033, weight = 1547.4236900442331
#   len(indices) = 2881, weight = 1517.8434442395078
#   len(indices) = 2809, weight = 1503.4220704576376
#   len(indices) = 2734, weight = 1488.1026745697216
#   len(indices) = 2637, weight = 1467.8167780082722
#   len(indices) = 2532, weight = 1445.2202972163147
#   len(indices) = 2132, weight = 1352.1621707070422
#   len(indices) = 2007, weight = 1320.4375035117398
#   len(indices) = 1892, weight = 1289.9374456380835
#   len(indices) = 1721, weight = 1241.9610975177739
#   len(indices) = 1434, weight = 1152.9443664750534
#   len(indices) = 1133, weight = 1044.4216372805452
#   len(indices) = 875, weight = 933.4740610250955
#   len(indices) = 770, weight = 881.6194889606477
#   len(indices) = 718, weight = 854.086901505717
#   len(indices) = 666, weight = 825.1296008730636
#   len(indices) = 641, weight = 810.6474536669926
#   len(indices) = 610, weight = 792.1375053617213
#   len(indices) = 515, weight = 731.0500738870246
#   len(indices) = 198, weight = 444.08258972130596
#   len(indices) = 171, weight = 408.1638922480593
#   len(indices) = 167, weight = 402.55283205217046
#   len(indices) = 129, weight = 344.6530550389792
# Preparing MIMIC-CXR-Facts datasets and dataloaders for training/testing...
# fact_embeddings.shape = (596408, 128)
# Using image size mode: medium_512
# 227835it [00:01, 179827.97it/s]
# Total number of images: 258164
# len(train_indices) = 258164
# avg_facts_per_image = 436.5657372832773
# train_num_facts_per_image = 45
# Building train fact dataloader...
# batch_size = 8
# Normal (unbalanced) training...
# len(self.train_fact_dataloader) = 32271
# Preparing Chest Imagenome dataset and dataloader for training...
# Loading bbox_phrase_embeddings and bbox_phrases from /mnt/workspace/pamessina/medvqa-workspace/cache/chest_imagenome/bbox_phrase_embeddings(hash=333,1643894111267724539).pkl...
# bbox_phrase_embeddings.shape = (36, 128)
# len(bbox_phrases) = 36
# 	 right lung
# 	 right upper lung zone
# 	 right mid lung zone
# 	 right lower lung zone
# 	 right hilar structures
# 	 right apical zone
# 	 right costophrenic angle
# 	 right cardiophrenic angle
# 	 right hemidiaphragm
# 	 left lung
# 	 left upper lung zone
# 	 left mid lung zone
# 	 left lower lung zone
# 	 left hilar structures
# 	 left apical zone
# 	 left costophrenic angle
# 	 left hemidiaphragm
# 	 trachea
# 	 spine
# 	 right clavicle
# 	 left clavicle
# 	 aortic arch
# 	 mediastinum
# 	 upper mediastinum
# 	 svc
# 	 cardiac silhouette
# 	 left cardiac silhouette
# 	 right cardiac silhouette
# 	 cavoatrial junction
# 	 right atrium
# 	 descending aorta
# 	 carina
# 	 left upper abdomen
# 	 right upper abdomen
# 	 abdomen
# 	 left cardiophrenic angle
# Using image size mode: medium_512
# Loading precomputed bbox_coords_and_presence_and_mask from /mnt/workspace/pamessina/medvqa-workspace/cache/mimiccxr/bbox_coords_and_presence_and_mask(12,12,243310).pkl...
# File size: 1447940262 bytes (1414004.16 KB, 1380.86 MB, 1.35 GB)
# 227835it [00:01, 209469.40it/s]
# Total number of images: 165768
# --------------------------------------------------
# 10) Creating IU X-Ray Phrase Grounding Trainer ...
# get_image_transform()
#   Using segmentation mask aware transforms
#     len(_augmented_mask_transforms) = 10
#     augmentation_mode = random-color-and-spatial
#     default_prob = 0.4
#     Returning augmented transforms with mode random-color-and-spatial
# get_image_transform()
#   Using segmentation mask aware transforms
#     Returning default transform (no augmentation)
# Preparing data for training/testing...
# fact_embeddings.shape = (2331, 128)
# Number of invalid images removed: 111
# avg_facts_per_image = 2327.3329256692487
# train_num_facts_per_image = 45
# Building train dataloader...
# len(self.train_dataloader) = 920
# --------------------------------------------------
# 11) Creating dataloaders ...
# len(mimiccxr_trainer.train_fact_dataloader) = 32271
# len(mimiccxr_trainer.train_chest_imagenome_dataloader) = 16577
# len(mimiccxr_trainer.cxrlt2024_official_train_dataloader) = 100000000000000000
# len(mimiccxr_trainer.cxrlt2024_custom_train_dataloader) = 14537
# len(mimiccxr_trainer.cxrlt2024_custom_dev_dataloader) = 798
# len(vinbig_trainer.train_dataloader) = 100000000000000000
# len(chexlocalize_trainer.train_dataloader) = 91
# len(chexpert_trainer.train_dataloader) = 100000000000000000
# len(iuxray_trainer.train_dataloader) = 920
# len(_train_dataloaders) = 8
# len(_val_dataloaders) = 1
# _train_weights = [2.5, 1.0, 3.0, 3.0, 1.5, 0.4, 0.5, 0.5]
# merged_dataset_name = mim-facts+chst-img-anat+cxrlt2024(Off)+cxrlt2024(GPT4)+vinbig+chexloc+chxp+iuxray
# --------------------------------------------------
# 12) Attaching metrics, losses, timer and events to engines ...
# --------------------------------------------------
# 13) Defining learning rate scheduler handler ...
# --------------------------------------------------
# 14) Defining learning rate scheduler handler ...
# checkpoint_names = ['checkpoint_149_chss+chss+chuc+ciss+ciou+clss+clcc+clou+cxss+cxss+cxuc+cxuc+iuss+iuss+iuuc+miss+miss+miuc+vbss+vbuc+vbou=0.6855.pt']
# --------------------------------------------------
# 15) Loading model from checkpoint ...
# checkpoint_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240825_115146_mim-facts+chst-img-anat+cxrlt2024(Off)+cxrlt2024(GPT4)+vinbig+chexloc+chxp+iuxray_PhraseGrounder(aehrc-cxrmate-rrg24,FiLM_SigmoidAttention,128,256,256,256,1,256-128)/checkpoint_149_chss+chss+chuc+ciss+ciou+clss+clcc+clou+cxss+cxss+cxuc+cxuc+iuss+iuss+iuuc+miss+miss+miuc+vbss+vbuc+vbou=0.6855.pt
# Checkpoint successfully loaded!
# --------------------------------------------------
# 16) Defining log_metrics_handler ...
# MetricsLogger :: we'll be logging to /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240825_115146_mim-facts+chst-img-anat+cxrlt2024(Off)+cxrlt2024(GPT4)+vinbig+chexloc+chxp+iuxray_PhraseGrounder(aehrc-cxrmate-rrg24,FiLM_SigmoidAttention,128,256,256,256,1,256-128)/metrics_logs.csv
# --------------------------------------------------
# 17) Running trainer engine ...
# ---- Epoch 150/249
# (1) Training stage (lr = 0.000080) ...
# loss 2.08236, mimfg_att_reg_loss 0.19051, mimfg_phrcls_loss 2.09874, mimfg_prc_auc 0.77203, cibg_att_sup_loss 1.10215, cibg_segmask_iou 0.21223, vbg_phrcls_loss 1.52079, vbg_prc_auc 0.57429, vbg_att_reg_loss 0.09502, vbg_att_sup_loss 0.45095, vbg_segmask_iou 0.18728, cl_att_sup_loss 0.42858, cl_segmask_iou 0.39396, cl_phrcls_loss 1.19595, cl_phrase_acc 0.93263, chxp_att_reg_loss 0.19656, chxp_phrcls_loss 2.43248, chxp_prc_auc 0.73406, iufg_att_reg_loss 0.23633, iufg_phrcls_loss 2.98997, iufg_prc_auc 0.46152, cxrlt2024c_att_reg_loss 0.24435, cxrlt2024c_phrcls_loss 2.05050, cxrlt2024c_prc_auc 0.72229, cxrlt2024o_att_reg_loss 0.21179, cxrlt2024o_phrcls_loss 1.60201, cxrlt2024o_prc_auc 0.23319, 461.37 secs
# (2) Validation stage ...
# cxrlt2024c_att_reg_loss 0.13982, cxrlt2024c_phrcls_loss 1.18669, cxrlt2024c_prc_auc 0.70115, 460.76 secs
# New checkpoint saved: checkpoint_150_chss+chss+chuc+ciss+ciou+clss+clcc+clou+cxss+cxss+cxuc+cxuc+iuss+iuss+iuuc+miss+miss+miuc+vbss+vbuc+vbou=0.6754.pt
# ---- Epoch 151/249
# (1) Training stage (lr = 0.000027) ...
# loss 2.03215, mimfg_att_reg_loss 0.18649, mimfg_phrcls_loss 2.05441, mimfg_prc_auc 0.78033, cibg_att_sup_loss 1.08836, cibg_segmask_iou 0.21626, vbg_phrcls_loss 1.53386, vbg_prc_auc 0.54940, vbg_att_reg_loss 0.09179, vbg_att_sup_loss 0.43494, vbg_segmask_iou 0.19323, cl_att_sup_loss 0.41997, cl_segmask_iou 0.40062, cl_phrcls_loss 1.22669, cl_phrase_acc 0.93026, chxp_att_reg_loss 0.19080, chxp_phrcls_loss 2.33649, chxp_prc_auc 0.76146, iufg_att_reg_loss 0.22999, iufg_phrcls_loss 2.84356, iufg_prc_auc 0.51392, cxrlt2024c_att_reg_loss 0.22749, cxrlt2024c_phrcls_loss 1.94182, cxrlt2024c_prc_auc 0.73201, cxrlt2024o_att_reg_loss 0.21005, cxrlt2024o_phrcls_loss 1.60554, cxrlt2024o_prc_auc 0.23014, 474.78 secs
# (2) Validation stage ...
# cxrlt2024c_att_reg_loss 0.14203, cxrlt2024c_phrcls_loss 1.15734, cxrlt2024c_prc_auc 0.70344, 464.65 secs
# New checkpoint saved: checkpoint_151_chss+chss+chuc+ciss+ciou+clss+clcc+clou+cxss+cxss+cxuc+cxuc+iuss+iuss+iuuc+miss+miss+miuc+vbss+vbuc+vbou=0.6781.pt
# ---- Epoch 152/249
# (1) Training stage (lr = 0.000009) ...
# loss 2.04821, mimfg_att_reg_loss 0.18952, mimfg_phrcls_loss 2.08967, mimfg_prc_auc 0.77230, cibg_att_sup_loss 1.08407, cibg_segmask_iou 0.21571, vbg_phrcls_loss 1.53224, vbg_prc_auc 0.57159, vbg_att_reg_loss 0.09229, vbg_att_sup_loss 0.42306, vbg_segmask_iou 0.19001, cl_att_sup_loss 0.41783, cl_segmask_iou 0.39178, cl_phrcls_loss 1.21787, cl_phrase_acc 0.93377, chxp_att_reg_loss 0.17759, chxp_phrcls_loss 2.23151, chxp_prc_auc 0.78697, iufg_att_reg_loss 0.23736, iufg_phrcls_loss 2.98825, iufg_prc_auc 0.48800, cxrlt2024c_att_reg_loss 0.23131, cxrlt2024c_phrcls_loss 1.98416, cxrlt2024c_prc_auc 0.72820, cxrlt2024o_att_reg_loss 0.21141, cxrlt2024o_phrcls_loss 1.59840, cxrlt2024o_prc_auc 0.24731, 473.46 secs
# (2) Validation stage ...
# cxrlt2024c_att_reg_loss 0.14034, cxrlt2024c_phrcls_loss 1.15189, cxrlt2024c_prc_auc 0.70507, 467.51 secs
# New checkpoint saved: checkpoint_152_chss+chss+chuc+ciss+ciou+clss+clcc+clou+cxss+cxss+cxuc+cxuc+iuss+iuss+iuuc+miss+miss+miuc+vbss+vbuc+vbou=0.6797.pt
# ---- Epoch 153/249
# (1) Training stage (lr = 0.000003) ...
# loss 2.04539, mimfg_att_reg_loss 0.18689, mimfg_phrcls_loss 2.02652, mimfg_prc_auc 0.78518, cibg_att_sup_loss 1.09328, cibg_segmask_iou 0.21502, vbg_phrcls_loss 1.49621, vbg_prc_auc 0.57537, vbg_att_reg_loss 0.08902, vbg_att_sup_loss 0.44779, vbg_segmask_iou 0.19355, cl_att_sup_loss 0.39496, cl_segmask_iou 0.39514, cl_phrcls_loss 1.18408, cl_phrase_acc 0.94513, chxp_att_reg_loss 0.18589, chxp_phrcls_loss 2.33629, chxp_prc_auc 0.76556, iufg_att_reg_loss 0.24099, iufg_phrcls_loss 2.98327, iufg_prc_auc 0.49236, cxrlt2024c_att_reg_loss 0.23463, cxrlt2024c_phrcls_loss 1.99923, cxrlt2024c_prc_auc 0.73171, cxrlt2024o_att_reg_loss 0.20941, cxrlt2024o_phrcls_loss 1.61601, cxrlt2024o_prc_auc 0.24191, 475.83 secs
# (2) Validation stage ...
# cxrlt2024c_att_reg_loss 0.14234, cxrlt2024c_phrcls_loss 1.14395, cxrlt2024c_prc_auc 0.70467, 466.48 secs
# ---- Epoch 154/249
# (1) Training stage (lr = 0.000001) ...
# loss 2.02743, mimfg_att_reg_loss 0.18630, mimfg_phrcls_loss 2.07578, mimfg_prc_auc 0.77778, cibg_att_sup_loss 1.08657, cibg_segmask_iou 0.21513, vbg_phrcls_loss 1.47144, vbg_prc_auc 0.57118, vbg_att_reg_loss 0.08942, vbg_att_sup_loss 0.42108, vbg_segmask_iou 0.19291, cl_att_sup_loss 0.40247, cl_segmask_iou 0.39139, cl_phrcls_loss 1.13410, cl_phrase_acc 0.94188, chxp_att_reg_loss 0.18328, chxp_phrcls_loss 2.31095, chxp_prc_auc 0.74407, iufg_att_reg_loss 0.23208, iufg_phrcls_loss 2.85414, iufg_prc_auc 0.51319, cxrlt2024c_att_reg_loss 0.22899, cxrlt2024c_phrcls_loss 1.96996, cxrlt2024c_prc_auc 0.74121, cxrlt2024o_att_reg_loss 0.21128, cxrlt2024o_phrcls_loss 1.59275, cxrlt2024o_prc_auc 0.24607, 484.81 secs
# (2) Validation stage ...
# cxrlt2024c_att_reg_loss 0.14027, cxrlt2024c_phrcls_loss 1.14401, cxrlt2024c_prc_auc 0.70465, 467.95 secs
# New checkpoint saved: checkpoint_154_chss+chss+chuc+ciss+ciou+clss+clcc+clou+cxss+cxss+cxuc+cxuc+iuss+iuss+iuuc+miss+miss+miuc+vbss+vbuc+vbou=0.6799.pt
# ---- Epoch 155/249
# (1) Training stage (lr = 0.000080) ...
# loss 2.07531, mimfg_att_reg_loss 0.19008, mimfg_phrcls_loss 2.10071, mimfg_prc_auc 0.77129, cibg_att_sup_loss 1.08385, cibg_segmask_iou 0.21463, vbg_phrcls_loss 1.49690, vbg_prc_auc 0.58761, vbg_att_reg_loss 0.09064, vbg_att_sup_loss 0.44080, vbg_segmask_iou 0.19154, cl_att_sup_loss 0.43282, cl_segmask_iou 0.39212, cl_phrcls_loss 1.22725, cl_phrase_acc 0.93684, chxp_att_reg_loss 0.18663, chxp_phrcls_loss 2.37527, chxp_prc_auc 0.74835, iufg_att_reg_loss 0.23055, iufg_phrcls_loss 2.88627, iufg_prc_auc 0.49759, cxrlt2024c_att_reg_loss 0.24024, cxrlt2024c_phrcls_loss 2.04021, cxrlt2024c_prc_auc 0.70644, cxrlt2024o_att_reg_loss 0.21301, cxrlt2024o_phrcls_loss 1.62777, cxrlt2024o_prc_auc 0.23104, 478.29 secs
# (2) Validation stage ...
# cxrlt2024c_att_reg_loss 0.14220, cxrlt2024c_phrcls_loss 1.17836, cxrlt2024c_prc_auc 0.70082, 473.38 secs
# ---- Epoch 156/249
# (1) Training stage (lr = 0.000027) ...
# loss 2.05251, mimfg_att_reg_loss 0.18963, mimfg_phrcls_loss 2.08142, mimfg_prc_auc 0.77480, cibg_att_sup_loss 1.07366, cibg_segmask_iou 0.21761, vbg_phrcls_loss 1.52561, vbg_prc_auc 0.57659, vbg_att_reg_loss 0.09210, vbg_att_sup_loss 0.43728, vbg_segmask_iou 0.19559, cl_att_sup_loss 0.40612, cl_segmask_iou 0.39930, cl_phrcls_loss 1.20902, cl_phrase_acc 0.93300, chxp_att_reg_loss 0.18499, chxp_phrcls_loss 2.31899, chxp_prc_auc 0.74860, iufg_att_reg_loss 0.23846, iufg_phrcls_loss 2.92802, iufg_prc_auc 0.49812, cxrlt2024c_att_reg_loss 0.23034, cxrlt2024c_phrcls_loss 2.00849, cxrlt2024c_prc_auc 0.74456, cxrlt2024o_att_reg_loss 0.20993, cxrlt2024o_phrcls_loss 1.60054, cxrlt2024o_prc_auc 0.24526, 470.79 secs
# (2) Validation stage ...
# cxrlt2024c_att_reg_loss 0.14089, cxrlt2024c_phrcls_loss 1.13709, cxrlt2024c_prc_auc 0.70408, 464.32 secs
# ---- Epoch 157/249
# (1) Training stage (lr = 0.000009) ...
# loss 2.04429, mimfg_att_reg_loss 0.18928, mimfg_phrcls_loss 2.07088, mimfg_prc_auc 0.77569, cibg_att_sup_loss 1.06806, cibg_segmask_iou 0.21859, vbg_phrcls_loss 1.49236, vbg_prc_auc 0.57282, vbg_att_reg_loss 0.08670, vbg_att_sup_loss 0.42451, vbg_segmask_iou 0.19319, cl_att_sup_loss 0.40477, cl_segmask_iou 0.39652, cl_phrcls_loss 1.16905, cl_phrase_acc 0.94032, chxp_att_reg_loss 0.18559, chxp_phrcls_loss 2.33254, chxp_prc_auc 0.76733, iufg_att_reg_loss 0.22671, iufg_phrcls_loss 2.85747, iufg_prc_auc 0.50652, cxrlt2024c_att_reg_loss 0.24067, cxrlt2024c_phrcls_loss 2.01575, cxrlt2024c_prc_auc 0.71627, cxrlt2024o_att_reg_loss 0.20835, cxrlt2024o_phrcls_loss 1.59879, cxrlt2024o_prc_auc 0.23331, 484.75 secs
# (2) Validation stage ...
# cxrlt2024c_att_reg_loss 0.14229, cxrlt2024c_phrcls_loss 1.13703, cxrlt2024c_prc_auc 0.70447, 471.61 secs
# ---- Epoch 158/249
# (1) Training stage (lr = 0.000003) ...
# loss 2.03256, mimfg_att_reg_loss 0.18841, mimfg_phrcls_loss 2.07773, mimfg_prc_auc 0.77868, cibg_att_sup_loss 1.06669, cibg_segmask_iou 0.21949, vbg_phrcls_loss 1.48151, vbg_prc_auc 0.57928, vbg_att_reg_loss 0.08959, vbg_att_sup_loss 0.42228, vbg_segmask_iou 0.19108, cl_att_sup_loss 0.41071, cl_segmask_iou 0.38564, cl_phrcls_loss 1.15973, cl_phrase_acc 0.94487, chxp_att_reg_loss 0.17467, chxp_phrcls_loss 2.21345, chxp_prc_auc 0.77340, iufg_att_reg_loss 0.23837, iufg_phrcls_loss 2.97747, iufg_prc_auc 0.50965, cxrlt2024c_att_reg_loss 0.23055, cxrlt2024c_phrcls_loss 1.98347, cxrlt2024c_prc_auc 0.73947, cxrlt2024o_att_reg_loss 0.20721, cxrlt2024o_phrcls_loss 1.59345, cxrlt2024o_prc_auc 0.24066, 483.67 secs
# (2) Validation stage ...
# cxrlt2024c_att_reg_loss 0.14006, cxrlt2024c_phrcls_loss 1.13957, cxrlt2024c_prc_auc 0.70504, 467.61 secs
# New checkpoint saved: checkpoint_158_chss+chss+chuc+ciss+ciou+clss+clcc+clou+cxss+cxss+cxuc+cxuc+iuss+iuss+iuuc+miss+miss+miuc+vbss+vbuc+vbou=0.6803.pt
# ---- Epoch 159/249
# (1) Training stage (lr = 0.000001) ...
# loss 2.01949, mimfg_att_reg_loss 0.18751, mimfg_phrcls_loss 2.05682, mimfg_prc_auc 0.77920, cibg_att_sup_loss 1.07586, cibg_segmask_iou 0.21776, vbg_phrcls_loss 1.45309, vbg_prc_auc 0.61317, vbg_att_reg_loss 0.08921, vbg_att_sup_loss 0.41489, vbg_segmask_iou 0.19896, cl_att_sup_loss 0.39772, cl_segmask_iou 0.38633, cl_phrcls_loss 1.15256, cl_phrase_acc 0.94372, chxp_att_reg_loss 0.18319, chxp_phrcls_loss 2.32470, chxp_prc_auc 0.75985, iufg_att_reg_loss 0.23161, iufg_phrcls_loss 2.97475, iufg_prc_auc 0.48550, cxrlt2024c_att_reg_loss 0.22792, cxrlt2024c_phrcls_loss 1.96406, cxrlt2024c_prc_auc 0.73431, cxrlt2024o_att_reg_loss 0.20716, cxrlt2024o_phrcls_loss 1.58549, cxrlt2024o_prc_auc 0.25590, 484.36 secs
# (2) Validation stage ...
# cxrlt2024c_att_reg_loss 0.14203, cxrlt2024c_phrcls_loss 1.13512, cxrlt2024c_prc_auc 0.70497, 464.83 secs
# New checkpoint saved: checkpoint_159_chss+chss+chuc+ciss+ciou+clss+clcc+clou+cxss+cxss+cxuc+cxuc+iuss+iuss+iuuc+miss+miss+miuc+vbss+vbuc+vbou=0.6804.pt
# ---- Epoch 160/249
# (1) Training stage (lr = 0.000080) ...
# loss 2.01226, mimfg_att_reg_loss 0.18202, mimfg_phrcls_loss 2.01058, mimfg_prc_auc 0.78689, cibg_att_sup_loss 1.06588, cibg_segmask_iou 0.22179, vbg_phrcls_loss 1.46310, vbg_prc_auc 0.57385, vbg_att_reg_loss 0.08579, vbg_att_sup_loss 0.42230, vbg_segmask_iou 0.19576, cl_att_sup_loss 0.39938, cl_segmask_iou 0.38921, cl_phrcls_loss 1.14674, cl_phrase_acc 0.93744, chxp_att_reg_loss 0.17823, chxp_phrcls_loss 2.26250, chxp_prc_auc 0.76293, iufg_att_reg_loss 0.22956, iufg_phrcls_loss 2.82501, iufg_prc_auc 0.51256, cxrlt2024c_att_reg_loss 0.23264, cxrlt2024c_phrcls_loss 1.97285, cxrlt2024c_prc_auc 0.72193, cxrlt2024o_att_reg_loss 0.21192, cxrlt2024o_phrcls_loss 1.60774, cxrlt2024o_prc_auc 0.24178, 477.84 secs
# (2) Validation stage ...
# cxrlt2024c_att_reg_loss 0.15043, cxrlt2024c_phrcls_loss 1.15237, cxrlt2024c_prc_auc 0.69858, 461.12 secs
# ---- Epoch 161/249
# (1) Training stage (lr = 0.000027) ...
# loss 2.01214, mimfg_att_reg_loss 0.18759, mimfg_phrcls_loss 2.05259, mimfg_prc_auc 0.78141, cibg_att_sup_loss 1.05432, cibg_segmask_iou 0.22129, vbg_phrcls_loss 1.48771, vbg_prc_auc 0.58270, vbg_att_reg_loss 0.08514, vbg_att_sup_loss 0.43559, vbg_segmask_iou 0.18885, cl_att_sup_loss 0.41174, cl_segmask_iou 0.39794, cl_phrcls_loss 1.12916, cl_phrase_acc 0.94136, chxp_att_reg_loss 0.18064, chxp_phrcls_loss 2.26100, chxp_prc_auc 0.76635, iufg_att_reg_loss 0.22803, iufg_phrcls_loss 2.80485, iufg_prc_auc 0.53943, cxrlt2024c_att_reg_loss 0.23465, cxrlt2024c_phrcls_loss 1.94240, cxrlt2024c_prc_auc 0.70514, cxrlt2024o_att_reg_loss 0.20725, cxrlt2024o_phrcls_loss 1.59296, cxrlt2024o_prc_auc 0.24986, 483.48 secs
# (2) Validation stage ...
# cxrlt2024c_att_reg_loss 0.14122, cxrlt2024c_phrcls_loss 1.13601, cxrlt2024c_prc_auc 0.70642, 466.56 secs
# New checkpoint saved: checkpoint_161_chss+chss+chuc+ciss+ciou+clss+clcc+clou+cxss+cxss+cxuc+cxuc+iuss+iuss+iuuc+miss+miss+miuc+vbss+vbuc+vbou=0.6809.pt
# ---- Epoch 162/249
# (1) Training stage (lr = 0.000009) ...
# loss 2.01202, mimfg_att_reg_loss 0.18208, mimfg_phrcls_loss 2.01697, mimfg_prc_auc 0.78933, cibg_att_sup_loss 1.04713, cibg_segmask_iou 0.22213, vbg_phrcls_loss 1.48485, vbg_prc_auc 0.58549, vbg_att_reg_loss 0.08916, vbg_att_sup_loss 0.41971, vbg_segmask_iou 0.18920, cl_att_sup_loss 0.38480, cl_segmask_iou 0.40248, cl_phrcls_loss 1.08551, cl_phrase_acc 0.94846, chxp_att_reg_loss 0.18117, chxp_phrcls_loss 2.26097, chxp_prc_auc 0.77883, iufg_att_reg_loss 0.24120, iufg_phrcls_loss 2.93329, iufg_prc_auc 0.50748, cxrlt2024c_att_reg_loss 0.22681, cxrlt2024c_phrcls_loss 1.96834, cxrlt2024c_prc_auc 0.73287, cxrlt2024o_att_reg_loss 0.20983, cxrlt2024o_phrcls_loss 1.59943, cxrlt2024o_prc_auc 0.24049, 483.00 secs
# (2) Validation stage ...
#    iteration 400
