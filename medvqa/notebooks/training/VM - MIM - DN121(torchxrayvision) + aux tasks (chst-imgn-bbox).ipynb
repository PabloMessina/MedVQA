# %%
# %env CUDA_VISIBLE_DEVICES=1
# Out:
# env: CUDA_VISIBLE_DEVICES=1

# %%
# !python ../train_visual_module.py \
        --epochs 30 \
        --batches-per-epoch 300 \
        --batch-size 80 \
        --num-workers 3 \
        --iters-to-accumulate 2 \
        --optimizer-name "adamw" \
        --scheduler "warmup+decay" \
        --lr 1e-6 \
        --warmup-and-decay-args "1e-6,4,4e-4,26,1e-6" \
        --use-mimiccxr \
        --mimiccxr-weight 1.0 \
        --mimiccxr-qa-adapted-reports-filename "qa_adapted_reports__20220904_095810.json" \
        --mimiccxr-view-mode "chest_imagenome" \
        --predict-bboxes-chest-imagenome \
        --clamp-bboxes-chest-imagenome \
        --chest-imagenome-bbox-regressor-version "v2" \
        --raw-image-encoding "densenet-121-torchxrayvision" \
        --torchxrayvision-weights-name "densenet121-res224-all" \
        --image-size 224 224 \
        --image-local-feat-size 1024 \
        --num-regions 49 \
        --use-amp \
        --save
# Out:
# script's arguments:
#    epochs: 30
#    batches_per_epoch: 300
#    checkpoint_folder: None
#    mimiccxr_qa_adapted_reports_filename: qa_adapted_reports__20220904_095810.json
#    visual_input_mode: raw-image
#    raw_image_encoding: densenet-121-torchxrayvision
#    image_local_feat_size: 1024
#    image_encoder_pretrained_weights_path: None
#    freeze_image_encoder: False
#    imagenet_pretrained: False
#    visual_features_mlp_in_dim: None
#    visual_features_mlp_out_dim: None
#    visual_features_mlp_hidden_dims: None
#    iuxray_precomputed_visual_features_path: None
#    mimiccxr_precomputed_visual_features_path: None
#    chexpert_precomputed_visual_features_path: None
#    vinbig_precomputed_visual_features_path: None
#    clip_version: None
#    huggingface_model_name: None
#    chest_imagenome_bbox_hidden_size: 128
#    chest_imagenome_bbox_regressor_version: v2
#    torchxrayvision_weights_name: densenet121-res224-all
#    num_regions: 49
#    optimizer_name: adamw
#    lr: 1e-06
#    scheduler: warmup+decay
#    lr_decay: 0.76
#    lr_decay_patience: 2
#    warmup_and_decay_args: 1e-6,4,4e-4,26,1e-6
#    warmup_and_cosine_args: None
#    batch_size: 80
#    iters_to_accumulate: 2
#    num_workers: 3
#    device: GPU
#    img_aug_mode: None
#    image_size: [224, 224]
#    mimiccxr_weight: 1.0
#    chexpert_weight: 0.3
#    cxr14_weight: 0.3
#    vinbig_weight: 0.3
#    iuxray_weight: 0.05
#    padchest_weight: 0.4
#    mimiccxr_view_mode: chest_imagenome
#    chest_imagenome_labels_filename: None
#    chest_imagenome_label_names_filename: None
#    use_amp: True
#    pretrained_checkpoint_folder_path: None
#    save: True
#    override_lr: False
#    train_mimiccxr: True
#    train_iuxray: False
#    train_chexpert: False
#    train_cxr14: False
#    train_vinbig: False
#    vinbig_training_data_mode: all
#    vinbig_use_validation: False
#    train_padchest: False
#    padchest_training_data_mode: train
#    padchest_use_validation: False
#    padchest_train_study_ids_path: None
#    padchest_val_study_ids_path: None
#    padchest_test_study_ids_path: None
#    binary_loss_name: bce
#    classify_tags: False
#    n_medical_tags: None
#    iuxray_medical_tags_per_report_filename: None
#    mimiccxr_medical_tags_per_report_filename: None
#    classify_orientation: False
#    classify_gender: False
#    classify_chexpert: False
#    iuxray_chexpert_labels_filename: None
#    mimiccxr_chexpert_labels_filename: None
#    classify_chest_imagenome: False
#    predict_bboxes_chest_imagenome: True
#    clamp_bboxes_chest_imagenome: True
#    chest_imagenome_bbox_loss_weight: 1.0
#    classify_questions: False
#    n_mined_questions: None
#    iuxray_question_labels_filename: None
#    mimiccxr_question_labels_filename: None
#    merge_findings: False
# ----- Training model from scratch ------
# Loading /mnt/data/pamessina/workspaces/medvqa-workspace/cache/chest_imagenome/chest_imagenome_train_average_bbox_coords(qa_adapted_reports__20220904_095810.json,clamped.pkl...
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Creating instance of MultiPurposeVisualModel ...
# create_torchxrayvision_densenet121_feature_extractor()
#   self.global_feat_size = 2048
# BoundingBoxRegressor_v2:
#   local_feat_dim: 1024
#   global_feat_dim: 2048
#   hidden_dim: 128
#   num_classes: 36
#   num_regions: 49
# --------------------------------------------------
# 3) Defining optimizer ...
# create_optimizer(): name = adamw
# --------------------------------------------------
# 4) Defining scheduler ...
# Using warmup+decay scheduler: 1e-6,4,4e-4,26,1e-6
# 1e-06 4 0.0004 26 1e-06
# Adjusting learning rate of group 0 to 1.0000e-06.
# Adjusting learning rate of group 0 to 1.0000e-06.
# --------------------------------------------------
# 5) Creating trainer and validator engines ...
# get_engine(): shift_answer=False
# chest_imagenome_bbox_loss_weight:  1.0
# get_engine(): shift_answer=False
# chest_imagenome_bbox_loss_weight:  1.0
# --------------------------------------------------
# 6) Defining image transform ...
# train_image_transform_kwargs: {'image_size': [224, 224], 'augmentation_mode': None, 'use_clip_transform': False, 'clip_version': None, 'use_huggingface_vitmodel_transform': False, 'huggingface_vitmodel_name': None, 'use_torchxrayvision_transform': True}
# Using torchxrayvision transform (image_size = [224, 224])
# val_image_transform_kwargs: {'image_size': [224, 224], 'augmentation_mode': None, 'use_clip_transform': False, 'clip_version': None, 'use_huggingface_vitmodel_transform': False, 'huggingface_vitmodel_name': None, 'use_torchxrayvision_transform': True}
# Using torchxrayvision transform (image_size = [224, 224])
# --------------------------------------------------
# 7) Defining collate_batch_fn ...
# --------------------------------------------------
# 8) Creating MIMIC-CXR visual module trainer ...
# Loading cached detailed metadata from /mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/qa_adapted_reports__20220904_095810.json__detailed_metadata.pkl
# Loaded 240530 non-gold DICOM IDs from Chest Imagenome
# 227835it [00:00, 473995.36it/s]
# len(self.train_indices) = 235209
# len(self.val_indices) = 1945
# Loading Chest Imagenome bounding boxes...
# --------------------------------------------------
# 9) Creating dataloaders ...
# len(_train_dataloaders) = 1
# len(_val_dataloaders) = 1
# _train_weights = [1.0]
# merged_dataset_name = mim
# --------------------------------------------------
# 10) Attaching metrics, losses, timer and events to engines ...
# --------------------------------------------------
# 11) Defining learning rate scheduler handler ...
# --------------------------------------------------
# 12) Defining checkpoint folder path ...
# checkpoint_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230215_163739_mim_dn121-txv(densenet121-res224-all)
# metadata saved to /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230215_163739_mim_dn121-txv(densenet121-res224-all)/metadata.json
# --------------------------------------------------
# 13) Defining log_metrics_handler ...
# MetricsLogger :: we'll be logging to /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230215_163739_mim_dn121-txv(densenet121-res224-all)/metrics_logs.csv
# --------------------------------------------------
# 14) Running trainer engine ...
# ---- Epoch 1/30
# (1) Training stage (lr = 0.000001) ...
# loss 0.71644, chestimgbbmf1 0.05362, chestimgbb_loss 0.62896, chestimgbbiou 0.74124, chestimgbbmae 0.09886, 228.05 secs
# (2) Validation stage ...
# chestimgbbmf1 0.08233, chestimgbbiou 0.76130, chestimgbbmae 0.09019, 17.22 secs
# Adjusting learning rate of group 0 to 4.4721e-06.
# ---- Epoch 2/30
# (1) Training stage (lr = 0.000004) ...
# loss 0.54606, chestimgbbmf1 0.13447, chestimgbb_loss 0.30801, chestimgbbiou 0.78870, chestimgbbmae 0.07809, 237.63 secs
# (2) Validation stage ...
# chestimgbbmf1 0.17410, chestimgbbiou 0.80125, chestimgbbmae 0.07304, 17.13 secs
# Adjusting learning rate of group 0 to 2.0000e-05.
# ---- Epoch 3/30
# (1) Training stage (lr = 0.000020) ...
# loss 0.13363, chestimgbbmf1 0.28687, chestimgbb_loss 0.05500, chestimgbbiou 0.83184, chestimgbbmae 0.06022, 238.80 secs
# (2) Validation stage ...
# chestimgbbmf1 0.35134, chestimgbbiou 0.84122, chestimgbbmae 0.05686, 17.56 secs
# Adjusting learning rate of group 0 to 8.9443e-05.
# ---- Epoch 4/30
# (1) Training stage (lr = 0.000089) ...
# loss 0.02050, chestimgbbmf1 0.45281, chestimgbb_loss 0.03649, chestimgbbiou 0.85826, chestimgbbmae 0.05004, 237.29 secs
# (2) Validation stage ...
# chestimgbbmf1 0.53232, chestimgbbiou 0.86689, chestimgbbmae 0.04710, 17.62 secs
# Adjusting learning rate of group 0 to 4.0000e-04.
# ---- Epoch 5/30
# (1) Training stage (lr = 0.000400) ...
# loss 0.02328, chestimgbbmf1 0.57497, chestimgbb_loss 0.04569, chestimgbbiou 0.82657, chestimgbbmae 0.07046, 239.05 secs
# (2) Validation stage ...
# chestimgbbmf1 0.76815, chestimgbbiou 0.89537, chestimgbbmae 0.03672, 17.22 secs
# Adjusting learning rate of group 0 to 3.1767e-04.
# ---- Epoch 6/30
# (1) Training stage (lr = 0.000318) ...
# loss 0.03327, chestimgbbmf1 0.81271, chestimgbb_loss 0.02447, chestimgbbiou 0.90414, chestimgbbmae 0.03322, 237.26 secs
# (2) Validation stage ...
# chestimgbbmf1 0.82097, chestimgbbiou 0.90338, chestimgbbmae 0.03385, 17.50 secs
# Adjusting learning rate of group 0 to 2.5229e-04.
# ---- Epoch 7/30
# (1) Training stage (lr = 0.000252) ...
# loss 0.01937, chestimgbbmf1 0.84351, chestimgbb_loss 0.02290, chestimgbbiou 0.90949, chestimgbbmae 0.03134, 238.07 secs
# (2) Validation stage ...
# chestimgbbmf1 0.84718, chestimgbbiou 0.90903, chestimgbbmae 0.03184, 17.13 secs
# Adjusting learning rate of group 0 to 2.0037e-04.
# ---- Epoch 8/30
# (1) Training stage (lr = 0.000200) ...
# loss 0.02001, chestimgbbmf1 0.86070, chestimgbb_loss 0.02188, chestimgbbiou 0.91316, chestimgbbmae 0.03003, 229.20 secs
# (2) Validation stage ...
# chestimgbbmf1 0.85641, chestimgbbiou 0.91108, chestimgbbmae 0.03107, 16.48 secs
# Adjusting learning rate of group 0 to 1.5913e-04.
# ---- Epoch 9/30
# (1) Training stage (lr = 0.000159) ...
# loss 0.01660, chestimgbbmf1 0.87178, chestimgbb_loss 0.02102, chestimgbbiou 0.91564, chestimgbbmae 0.02914, 226.77 secs
# (2) Validation stage ...
# chestimgbbmf1 0.86290, chestimgbbiou 0.91237, chestimgbbmae 0.03062, 16.44 secs
# Adjusting learning rate of group 0 to 1.2638e-04.
# ---- Epoch 10/30
# (1) Training stage (lr = 0.000126) ...
# loss 0.02368, chestimgbbmf1 0.87716, chestimgbb_loss 0.01894, chestimgbbiou 0.91770, chestimgbbmae 0.02829, 228.71 secs
# (2) Validation stage ...
# chestimgbbmf1 0.86611, chestimgbbiou 0.91319, chestimgbbmae 0.03032, 17.03 secs
# Adjusting learning rate of group 0 to 1.0037e-04.
# ---- Epoch 11/30
# (1) Training stage (lr = 0.000100) ...
# loss 0.04796, chestimgbbmf1 0.88384, chestimgbb_loss 0.01855, chestimgbbiou 0.91930, chestimgbbmae 0.02774, 231.44 secs
# (2) Validation stage ...
# chestimgbbmf1 0.87146, chestimgbbiou 0.91477, chestimgbbmae 0.02977, 16.49 secs
# Adjusting learning rate of group 0 to 7.9709e-05.
# ---- Epoch 12/30
# (1) Training stage (lr = 0.000080) ...
# loss 0.01321, chestimgbbmf1 0.88358, chestimgbb_loss 0.02018, chestimgbbiou 0.91868, chestimgbbmae 0.02808, 232.03 secs
# (2) Validation stage ...
# chestimgbbmf1 0.87524, chestimgbbiou 0.91563, chestimgbbmae 0.02944, 16.48 secs
# Adjusting learning rate of group 0 to 6.3303e-05.
# ---- Epoch 13/30
# (1) Training stage (lr = 0.000063) ...
# loss 0.02687, chestimgbbmf1 0.88879, chestimgbb_loss 0.01893, chestimgbbiou 0.92055, chestimgbbmae 0.02732, 231.82 secs
# (2) Validation stage ...
# chestimgbbmf1 0.87874, chestimgbbiou 0.91672, chestimgbbmae 0.02906, 16.77 secs
# Adjusting learning rate of group 0 to 5.0274e-05.
# ---- Epoch 14/30
# (1) Training stage (lr = 0.000050) ...
# loss 0.01868, chestimgbbmf1 0.88932, chestimgbb_loss 0.02065, chestimgbbiou 0.92006, chestimgbbmae 0.02765, 232.98 secs
# (2) Validation stage ...
# chestimgbbmf1 0.88082, chestimgbbiou 0.91694, chestimgbbmae 0.02897, 16.53 secs
# Adjusting learning rate of group 0 to 3.9927e-05.
# ---- Epoch 15/30
# (1) Training stage (lr = 0.000040) ...
# loss 0.02411, chestimgbbmf1 0.89195, chestimgbb_loss 0.01834, chestimgbbiou 0.92160, chestimgbbmae 0.02695, 233.03 secs
# (2) Validation stage ...
# chestimgbbmf1 0.87594, chestimgbbiou 0.91608, chestimgbbmae 0.02928, 16.36 secs
# Adjusting learning rate of group 0 to 3.1709e-05.
# ---- Epoch 16/30
# (1) Training stage (lr = 0.000032) ...
# loss 0.02696, chestimgbbmf1 0.89172, chestimgbb_loss 0.01885, chestimgbbiou 0.92169, chestimgbbmae 0.02692, 233.26 secs
# (2) Validation stage ...
# chestimgbbmf1 0.87873, chestimgbbiou 0.91697, chestimgbbmae 0.02893, 16.42 secs
# Adjusting learning rate of group 0 to 2.5183e-05.
# ---- Epoch 17/30
# (1) Training stage (lr = 0.000025) ...
# loss 0.01964, chestimgbbmf1 0.89587, chestimgbb_loss 0.01817, chestimgbbiou 0.92287, chestimgbbmae 0.02646, 233.75 secs
# (2) Validation stage ...
# chestimgbbmf1 0.88325, chestimgbbiou 0.91815, chestimgbbmae 0.02855, 16.47 secs
# Adjusting learning rate of group 0 to 2.0000e-05.
# ---- Epoch 18/30
# (1) Training stage (lr = 0.000020) ...
# loss 0.03774, chestimgbbmf1 0.89513, chestimgbb_loss 0.01903, chestimgbbiou 0.92237, chestimgbbmae 0.02672, 233.33 secs
# (2) Validation stage ...
# chestimgbbmf1 0.88455, chestimgbbiou 0.91839, chestimgbbmae 0.02844, 16.56 secs
# Adjusting learning rate of group 0 to 1.5884e-05.
# ---- Epoch 19/30
# (1) Training stage (lr = 0.000016) ...
# loss 0.02367, chestimgbbmf1 0.89545, chestimgbb_loss 0.01844, chestimgbbiou 0.92268, chestimgbbmae 0.02660, 232.76 secs
# (2) Validation stage ...
# chestimgbbmf1 0.88252, chestimgbbiou 0.91796, chestimgbbmae 0.02859, 16.57 secs
# Adjusting learning rate of group 0 to 1.2615e-05.
# ---- Epoch 20/30
# (1) Training stage (lr = 0.000013) ...
# loss 0.01122, chestimgbbmf1 0.89514, chestimgbb_loss 0.01827, chestimgbbiou 0.92266, chestimgbbmae 0.02659, 231.26 secs
# (2) Validation stage ...
# chestimgbbmf1 0.88345, chestimgbbiou 0.91816, chestimgbbmae 0.02852, 16.64 secs
# Adjusting learning rate of group 0 to 1.0018e-05.
# ---- Epoch 21/30
# (1) Training stage (lr = 0.000010) ...
# loss 0.01270, chestimgbbmf1 0.89611, chestimgbb_loss 0.01870, chestimgbbiou 0.92259, chestimgbbmae 0.02665, 231.82 secs
# (2) Validation stage ...
# chestimgbbmf1 0.88437, chestimgbbiou 0.91849, chestimgbbmae 0.02840, 16.53 secs
# Adjusting learning rate of group 0 to 7.9563e-06.
# ---- Epoch 22/30
# (1) Training stage (lr = 0.000008) ...
# loss 0.02064, chestimgbbmf1 0.89610, chestimgbb_loss 0.01798, chestimgbbiou 0.92291, chestimgbbmae 0.02648, 233.96 secs
# (2) Validation stage ...
# chestimgbbmf1 0.88390, chestimgbbiou 0.91832, chestimgbbmae 0.02847, 16.84 secs
# Adjusting learning rate of group 0 to 6.3188e-06.
# ---- Epoch 23/30
# (1) Training stage (lr = 0.000006) ...
# loss 0.02177, chestimgbbmf1 0.89703, chestimgbb_loss 0.01909, chestimgbbiou 0.92288, chestimgbbmae 0.02656, 232.63 secs
# (2) Validation stage ...
# chestimgbbmf1 0.88637, chestimgbbiou 0.91899, chestimgbbmae 0.02823, 16.49 secs
# Adjusting learning rate of group 0 to 5.0183e-06.
# ---- Epoch 24/30
# (1) Training stage (lr = 0.000005) ...
# loss 0.04065, chestimgbbmf1 0.89876, chestimgbb_loss 0.01845, chestimgbbiou 0.92355, chestimgbbmae 0.02626, 233.03 secs
# (2) Validation stage ...
# chestimgbbmf1 0.88511, chestimgbbiou 0.91865, chestimgbbmae 0.02835, 16.43 secs
# Adjusting learning rate of group 0 to 3.9854e-06.
# ---- Epoch 25/30
# (1) Training stage (lr = 0.000004) ...
# loss 0.02457, chestimgbbmf1 0.89738, chestimgbb_loss 0.01780, chestimgbbiou 0.92349, chestimgbbmae 0.02628, 233.36 secs
# (2) Validation stage ...
# chestimgbbmf1 0.88554, chestimgbbiou 0.91875, chestimgbbmae 0.02831, 16.57 secs
# Adjusting learning rate of group 0 to 3.1652e-06.
# ---- Epoch 26/30
# (1) Training stage (lr = 0.000003) ...
# loss 0.02102, chestimgbbmf1 0.89854, chestimgbb_loss 0.01793, chestimgbbiou 0.92351, chestimgbbmae 0.02628, 231.29 secs
# (2) Validation stage ...
# chestimgbbmf1 0.88434, chestimgbbiou 0.91849, chestimgbbmae 0.02841, 16.48 secs
# Adjusting learning rate of group 0 to 2.5137e-06.
# ---- Epoch 27/30
# (1) Training stage (lr = 0.000003) ...
# loss 0.01980, chestimgbbmf1 0.89715, chestimgbb_loss 0.01821, chestimgbbiou 0.92327, chestimgbbmae 0.02638, 231.42 secs
# (2) Validation stage ...
# chestimgbbmf1 0.88523, chestimgbbiou 0.91877, chestimgbbmae 0.02831, 16.47 secs
# Adjusting learning rate of group 0 to 1.9964e-06.
# ---- Epoch 28/30
# (1) Training stage (lr = 0.000002) ...
# loss 0.01582, chestimgbbmf1 0.89847, chestimgbb_loss 0.01839, chestimgbbiou 0.92336, chestimgbbmae 0.02637, 231.42 secs
# (2) Validation stage ...
# chestimgbbmf1 0.88566, chestimgbbiou 0.91888, chestimgbbmae 0.02827, 16.52 secs
# Adjusting learning rate of group 0 to 1.5855e-06.
# ---- Epoch 29/30
# (1) Training stage (lr = 0.000002) ...
# loss 0.00417, chestimgbbmf1 0.89773, chestimgbb_loss 0.01801, chestimgbbiou 0.92354, chestimgbbmae 0.02628, 230.95 secs
# (2) Validation stage ...
# chestimgbbmf1 0.88629, chestimgbbiou 0.91908, chestimgbbmae 0.02820, 16.49 secs
# Adjusting learning rate of group 0 to 1.2592e-06.
# ---- Epoch 30/30
# (1) Training stage (lr = 0.000001) ...
# loss 0.00741, chestimgbbmf1 0.89913, chestimgbb_loss 0.01773, chestimgbbiou 0.92384, chestimgbbmae 0.02616, 233.04 secs
# (2) Validation stage ...
# chestimgbbmf1 0.88567, chestimgbbiou 0.91890, chestimgbbmae 0.02827, 16.73 secs
# Adjusting learning rate of group 0 to 1.0000e-06.
