# %%
# %env CUDA_VISIBLE_DEVICES=0
# Out:
# env: CUDA_VISIBLE_DEVICES=0

# %%
# !python ../scripts/chest_imagenome/precompute_bbox_phrase_embeddings.py \
--model_name "microsoft/BiomedVLP-CXR-BERT-specialized" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240207_184445_MIMIC-CXR(triplets+classif+entcont+nli+radgraph+autoencoder)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)"
# Out:
# Obtaining embeddings for each sentence...
# checkpoint_names = ['checkpoint_91_cacc+chf1+chf1+cscc+encc+hscc+nlcc+sass+spss+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9337.pt']
#   0%|                                                    | 0/36 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=440,3465006188639683439).pkl
# len(self.cache["hashes"]) = 4767354
# self.cache["embeddings"].shape = (4767354, 128)
# 100%|███████████████████████████████████████████| 36/36 [00:06<00:00,  5.38it/s]
# Saving output to: /mnt/workspace/pamessina/medvqa-workspace/cache/chest_imagenome/bbox_phrase_embeddings(hash=333,2614535641242304201).pkl
# Done!

# %%
# !python ../train_phrase_grounding.py \
--pretrained_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240505_224220_mim-facts+vinbig+chexloc+chxp_PhraseGrounder(dn121,128,256)/" \
--epochs 100 \
--batches_per_epoch 400 \
--max_images_per_batch 13 \
--max_phrases_per_batch 200 \
--max_phrases_per_image 40 \
--val_batch_size_factor 2.0 \
--raw_image_encoding "densenet-121" \
--image_size 416 416 \
--image_local_feat_size 1024 \
--num_regions 169 \
--regions_width 13 \
--regions_height 13 \
--phrase_embedding_size 128 \
--phrase_grounding_mode "transformer_encoder" \
--phrase_classifier_hidden_size 256 \
--transf_d_model 256 \
--transf_nhead 4 \
--transf_dim_feedforward 512 \
--transf_num_layers 3 \
--num_train_workers 2 \
--num_val_workers 2 \
--gradient_accumulation_steps 10 \
--optimizer_name "adamw" \
--scheduler "exp-warmup+decay+cyclicdecay" \
--lr 1e-6 \
--warmup_decay_and_cyclic_decay_args "1e-6,3,8e-5,8,1e-6,8e-5,8,1e-6" \
--mimiccxr_exclude_noisy_images \
--binary_multilabel_classif_loss_name "focal+bce+wbce" \
--use_vinbig_for_train \
--vinbig_phrase_embeddings_filepath \
"/mnt/workspace/pamessina/medvqa-workspace/cache/vinbig/label_phrase_embeddings(hash=325,3209166273642513277).pkl" \
--vinbig_training_data_mode "all" \
--use_chexlocalize_for_train \
--use_chexlocalize_for_test \
--chexlocalize_class_phrase_embeddings_filepath \
"/mnt/workspace/pamessina/medvqa-workspace/cache/chexlocalize/class_phrase_embeddings(hash=528,1823213522699794899).pkl" \
--use_chest_imagenome_for_train \
--chest_imagenome_bbox_phrase_embeddings_filepath \
"/mnt/workspace/pamessina/medvqa-workspace/cache/chest_imagenome/bbox_phrase_embeddings(hash=333,2614535641242304201).pkl" \
--use_mscxr_for_train \
--use_mscxr_for_test \
--mscxr_phrase2embedding_filepath \
"/mnt/workspace/pamessina/medvqa-workspace/cache/mimiccxr/mscxr_phrase2embedding(hash=36521,3206715123524916204).pkl" \
--use_attention_regularization_loss \
--use_contrastive_phrase_grounding_loss \
--attention_supervision_loss_weight 2.0 \
--phrase_classifier_loss_weight 2.0 \
--foreground_loss_weight 1.5 \
--mask_exponent 0.4 \
--chest_imagenome_anatlocs_weight 1.0 \
--vinbig_weight 1.0 \
--mscxr_weight 0.5 \
--chexlocalize_weight 0.5 \
--save
# Out:
# script's arguments:
#    epochs: 100
#    batches_per_epoch: 400
#    max_images_per_batch: 13
#    max_phrases_per_batch: 200
#    max_phrases_per_image: 40
#    val_batch_size_factor: 2.0
#    checkpoint_folder: None
#    pretrained_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240505_224220_mim-facts+vinbig+chexloc+chxp_PhraseGrounder(dn121,128,256)/
#    pretrained_checkpoint_folder_paths: None
#    freeze_image_encoder: False
#    raw_image_encoding: densenet-121
#    num_regions: 169
#    image_local_feat_size: 1024
#    image_encoder_pretrained_weights_path: None
#    yolov8_model_name_or_path: None
#    yolov8_model_alias: None
#    phrase_embedding_size: 128
#    regions_width: 13
#    regions_height: 13
#    qkv_size: None
#    phrase_grounding_mode: transformer_encoder
#    phrase_classifier_hidden_size: 256
#    transf_d_model: 256
#    transf_nhead: 4
#    transf_dim_feedforward: 512
#    transf_dropout: 0
# ...

# %%
# !python ../train_phrase_grounding.py \
--checkpoint_folder \
"models/phrase_grounding/20240618_093614_mscxr+chst-img-anat+vinbig+chexloc_PhraseGrounder(dn121,TransformerEncoder,128,256,4,512,3)" \
--epochs 100 \
--batches_per_epoch 400 \
--max_images_per_batch 13 \
--max_phrases_per_batch 200 \
--max_phrases_per_image 40 \
--val_batch_size_factor 2.0 \
--save
# Out:
# script's arguments:
#    epochs: 100
#    batches_per_epoch: 400
#    max_images_per_batch: 13
#    max_phrases_per_batch: 200
#    max_phrases_per_image: 40
#    val_batch_size_factor: 2.0
#    checkpoint_folder: models/phrase_grounding/20240618_093614_mscxr+chst-img-anat+vinbig+chexloc_PhraseGrounder(dn121,TransformerEncoder,128,256,4,512,3)
#    pretrained_checkpoint_folder_path: None
#    pretrained_checkpoint_folder_paths: None
#    freeze_image_encoder: False
#    raw_image_encoding: yolov8
#    num_regions: None
#    image_local_feat_size: None
#    image_encoder_pretrained_weights_path: None
#    yolov8_model_name_or_path: None
#    yolov8_model_alias: None
#    phrase_embedding_size: None
#    regions_width: None
#    regions_height: None
#    qkv_size: None
#    phrase_grounding_mode: None
#    phrase_classifier_hidden_size: None
#    transf_d_model: None
#    transf_nhead: None
#    transf_dim_feedforward: None
#    transf_dropout: 0
#    transf_num_layers: None
# ...

# %%
# !python ../train_phrase_grounding.py \
--pretrained_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240618_093614_mscxr+chst-img-anat+vinbig+chexloc_PhraseGrounder(dn121,TransformerEncoder,128,256,4,512,3)/" \
--epochs 100 \
--batches_per_epoch 400 \
--max_images_per_batch 13 \
--max_phrases_per_batch 200 \
--max_phrases_per_image 40 \
--val_batch_size_factor 2.0 \
--raw_image_encoding "densenet-121" \
--image_size 416 416 \
--image_local_feat_size 1024 \
--num_regions 169 \
--regions_width 13 \
--regions_height 13 \
--phrase_embedding_size 128 \
--phrase_grounding_mode "transformer_encoder" \
--phrase_classifier_hidden_size 256 \
--transf_d_model 256 \
--transf_nhead 2 \
--transf_dim_feedforward 512 \
--transf_num_layers 2 \
--num_train_workers 2 \
--num_val_workers 2 \
--gradient_accumulation_steps 10 \
--optimizer_name "adamw" \
--scheduler "exp-warmup+decay+cyclicdecay" \
--lr 1e-6 \
--warmup_decay_and_cyclic_decay_args "1e-6,3,8e-5,8,1e-6,8e-5,8,1e-6" \
--mimiccxr_exclude_noisy_images \
--binary_multilabel_classif_loss_name "focal+bce+wbce" \
--use_vinbig_for_train \
--vinbig_phrase_embeddings_filepath \
"/mnt/workspace/pamessina/medvqa-workspace/cache/vinbig/label_phrase_embeddings(hash=325,3209166273642513277).pkl" \
--vinbig_training_data_mode "all" \
--use_chexlocalize_for_train \
--use_chexlocalize_for_test \
--chexlocalize_class_phrase_embeddings_filepath \
"/mnt/workspace/pamessina/medvqa-workspace/cache/chexlocalize/class_phrase_embeddings(hash=528,1823213522699794899).pkl" \
--use_chest_imagenome_for_train \
--chest_imagenome_bbox_phrase_embeddings_filepath \
"/mnt/workspace/pamessina/medvqa-workspace/cache/chest_imagenome/bbox_phrase_embeddings(hash=333,2614535641242304201).pkl" \
--use_mscxr_for_train \
--use_mscxr_for_test \
--mscxr_phrase2embedding_filepath \
"/mnt/workspace/pamessina/medvqa-workspace/cache/mimiccxr/mscxr_phrase2embedding(hash=36521,3206715123524916204).pkl" \
--use_attention_regularization_loss \
--use_contrastive_phrase_grounding_loss \
--attention_supervision_loss_weight 2.0 \
--phrase_classifier_loss_weight 2.0 \
--foreground_loss_weight 1.5 \
--mask_exponent 0.4 \
--chest_imagenome_anatlocs_weight 1.0 \
--vinbig_weight 1.0 \
--mscxr_weight 0.5 \
--chexlocalize_weight 0.5 \
--save
# Out:
# script's arguments:
#    epochs: 100
#    batches_per_epoch: 400
#    max_images_per_batch: 13
#    max_phrases_per_batch: 200
#    max_phrases_per_image: 40
#    val_batch_size_factor: 2.0
#    checkpoint_folder: None
#    pretrained_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240618_093614_mscxr+chst-img-anat+vinbig+chexloc_PhraseGrounder(dn121,TransformerEncoder,128,256,4,512,3)/
#    pretrained_checkpoint_folder_paths: None
#    freeze_image_encoder: False
#    raw_image_encoding: densenet-121
#    num_regions: 169
#    image_local_feat_size: 1024
#    image_encoder_pretrained_weights_path: None
#    yolov8_model_name_or_path: None
#    yolov8_model_alias: None
#    phrase_embedding_size: 128
#    regions_width: 13
#    regions_height: 13
#    qkv_size: None
#    phrase_grounding_mode: transformer_encoder
#    phrase_classifier_hidden_size: 256
#    transf_d_model: 256
#    transf_nhead: 2
#    transf_dim_feedforward: 512
# ...

# %%
# !python ../train_phrase_grounding.py \
--pretrained_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240619_114746_mscxr+chst-img-anat+vinbig+chexloc_PhraseGrounder(dn121,TransformerEncoder,128,256,2,512,2)/" \
--epochs 100 \
--batches_per_epoch 400 \
--max_images_per_batch 13 \
--max_phrases_per_batch 200 \
--max_phrases_per_image 40 \
--val_batch_size_factor 2.0 \
--raw_image_encoding "densenet-121" \
--image_size 416 416 \
--image_local_feat_size 1024 \
--num_regions 169 \
--regions_width 13 \
--regions_height 13 \
--phrase_embedding_size 128 \
--phrase_grounding_mode "transformer_encoder" \
--phrase_classifier_hidden_size 256 \
--transf_d_model 256 \
--transf_nhead 1 \
--transf_dim_feedforward 512 \
--transf_num_layers 1 \
--num_train_workers 2 \
--num_val_workers 2 \
--gradient_accumulation_steps 10 \
--optimizer_name "adamw" \
--scheduler "exp-warmup+decay+cyclicdecay" \
--lr 1e-6 \
--warmup_decay_and_cyclic_decay_args "1e-6,3,8e-5,8,1e-6,8e-5,8,1e-6" \
--mimiccxr_exclude_noisy_images \
--binary_multilabel_classif_loss_name "focal+bce+wbce" \
--use_vinbig_for_train \
--vinbig_phrase_embeddings_filepath \
"/mnt/workspace/pamessina/medvqa-workspace/cache/vinbig/label_phrase_embeddings(hash=325,3209166273642513277).pkl" \
--vinbig_training_data_mode "all" \
--use_chexlocalize_for_train \
--use_chexlocalize_for_test \
--chexlocalize_class_phrase_embeddings_filepath \
"/mnt/workspace/pamessina/medvqa-workspace/cache/chexlocalize/class_phrase_embeddings(hash=528,1823213522699794899).pkl" \
--use_chest_imagenome_for_train \
--chest_imagenome_bbox_phrase_embeddings_filepath \
"/mnt/workspace/pamessina/medvqa-workspace/cache/chest_imagenome/bbox_phrase_embeddings(hash=333,2614535641242304201).pkl" \
--use_mscxr_for_train \
--use_mscxr_for_test \
--mscxr_phrase2embedding_filepath \
"/mnt/workspace/pamessina/medvqa-workspace/cache/mimiccxr/mscxr_phrase2embedding(hash=36521,3206715123524916204).pkl" \
--use_attention_regularization_loss \
--use_contrastive_phrase_grounding_loss \
--attention_supervision_loss_weight 2.0 \
--phrase_classifier_loss_weight 2.0 \
--foreground_loss_weight 1.5 \
--mask_exponent 0.4 \
--chest_imagenome_anatlocs_weight 1.0 \
--vinbig_weight 1.0 \
--mscxr_weight 0.5 \
--chexlocalize_weight 0.5 \
--save
# Out:
# script's arguments:
#    epochs: 100
#    batches_per_epoch: 400
#    max_images_per_batch: 13
#    max_phrases_per_batch: 200
#    max_phrases_per_image: 40
#    val_batch_size_factor: 2.0
#    checkpoint_folder: None
#    pretrained_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240619_114746_mscxr+chst-img-anat+vinbig+chexloc_PhraseGrounder(dn121,TransformerEncoder,128,256,2,512,2)/
#    pretrained_checkpoint_folder_paths: None
#    freeze_image_encoder: False
#    raw_image_encoding: densenet-121
#    num_regions: 169
#    image_local_feat_size: 1024
#    image_encoder_pretrained_weights_path: None
#    yolov8_model_name_or_path: None
#    yolov8_model_alias: None
#    phrase_embedding_size: 128
#    regions_width: 13
#    regions_height: 13
#    qkv_size: None
#    phrase_grounding_mode: transformer_encoder
#    phrase_classifier_hidden_size: 256
#    transf_d_model: 256
#    transf_nhead: 1
#    transf_dim_feedforward: 512
# ...
