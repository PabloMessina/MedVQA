# %%
# %env CUDA_VISIBLE_DEVICES=0
# Out:
# env: CUDA_VISIBLE_DEVICES=0

# %%
# !python ../train_visual_module.py \
        --epochs 30 \
        --batches-per-epoch 300 \
        --batch-size 140 \
        --num-workers 3 \
        --iters-to-accumulate 2 \
        --optimizer-name "adamw" \
        --scheduler "warmup+decay" \
        --lr 1e-6 \
        --warmup-and-decay-args "1e-6,5,2e-4,25,3e-6" \
        --use-mimiccxr \
        --mimiccxr-weight 1.0 \
        --mimiccxr-qa-adapted-reports-filename "qa_adapted_reports__20220904_095810.json" \
        --mimiccxr-view-mode "chest_imagenome" \
        --predict-bboxes-chest-imagenome \
        --clamp-bboxes-chest-imagenome \
        --chest-imagenome-bbox-regressor-version "v2" \
        --raw-image-encoding "resnet-autoencoder-torchxrayvision" \
        --torchxrayvision-weights-name "101-elastic" \
        --image-size 224 224 \
        --image-local-feat-size 512 \
        --num-regions 9 \
        --use-amp \
        --save
# Out:
# script's arguments:
#    epochs: 30
#    batches_per_epoch: 300
#    checkpoint_folder: None
#    mimiccxr_qa_adapted_reports_filename: qa_adapted_reports__20220904_095810.json
#    visual_input_mode: raw-image
#    raw_image_encoding: resnet-autoencoder-torchxrayvision
#    image_local_feat_size: 512
#    image_encoder_pretrained_weights_path: None
#    freeze_image_encoder: False
#    imagenet_pretrained: False
#    visual_features_mlp_in_dim: None
#    visual_features_mlp_out_dim: None
#    visual_features_mlp_hidden_dims: None
#    iuxray_precomputed_visual_features_path: None
#    mimiccxr_precomputed_visual_features_path: None
#    chexpert_precomputed_visual_features_path: None
#    vinbig_precomputed_visual_features_path: None
#    clip_version: None
#    huggingface_model_name: None
#    chest_imagenome_bbox_hidden_size: 128
#    chest_imagenome_bbox_regressor_version: v2
#    torchxrayvision_weights_name: 101-elastic
#    num_regions: 9
#    optimizer_name: adamw
#    lr: 1e-06
#    scheduler: warmup+decay
#    lr_decay: 0.76
#    lr_decay_patience: 2
#    warmup_and_decay_args: 1e-6,5,2e-4,25,3e-6
#    warmup_and_cosine_args: None
#    batch_size: 140
#    iters_to_accumulate: 2
#    num_workers: 3
#    device: GPU
#    img_aug_mode: None
#    image_size: [224, 224]
#    mimiccxr_weight: 1.0
#    chexpert_weight: 0.3
#    cxr14_weight: 0.3
#    vinbig_weight: 0.3
#    iuxray_weight: 0.05
#    padchest_weight: 0.4
#    mimiccxr_view_mode: chest_imagenome
#    chest_imagenome_labels_filename: None
#    chest_imagenome_label_names_filename: None
#    use_amp: True
#    pretrained_checkpoint_folder_path: None
#    save: True
#    override_lr: False
#    train_mimiccxr: True
#    train_iuxray: False
#    train_chexpert: False
#    train_cxr14: False
#    train_vinbig: False
#    vinbig_training_data_mode: all
#    vinbig_use_validation: False
#    train_padchest: False
#    padchest_training_data_mode: train
#    padchest_use_validation: False
#    padchest_train_study_ids_path: None
#    padchest_val_study_ids_path: None
#    padchest_test_study_ids_path: None
#    binary_loss_name: bce
#    classify_tags: False
#    n_medical_tags: None
#    iuxray_medical_tags_per_report_filename: None
#    mimiccxr_medical_tags_per_report_filename: None
#    classify_orientation: False
#    classify_gender: False
#    classify_chexpert: False
#    iuxray_chexpert_labels_filename: None
#    mimiccxr_chexpert_labels_filename: None
#    classify_chest_imagenome: False
#    predict_bboxes_chest_imagenome: True
#    clamp_bboxes_chest_imagenome: True
#    chest_imagenome_bbox_loss_weight: 1.0
#    classify_questions: False
#    n_mined_questions: None
#    iuxray_question_labels_filename: None
#    mimiccxr_question_labels_filename: None
#    merge_findings: False
# ----- Training model from scratch ------
# Loading /mnt/data/pamessina/workspaces/medvqa-workspace/cache/chest_imagenome/chest_imagenome_train_average_bbox_coords(qa_adapted_reports__20220904_095810.json,clamped.pkl...
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Creating instance of MultiPurposeVisualModel ...
# create_torchxrayvision_resnet_autoencoder_feature_extractor()
#   self.global_feat_size = 1024
# BoundingBoxRegressor_v2:
#   local_feat_dim: 512
#   global_feat_dim: 1024
#   hidden_dim: 128
#   num_classes: 36
#   num_regions: 9
# MultiPurposeVisualModule: self.name=resnet-ae-txv(101-elastic)
# --------------------------------------------------
# 3) Defining optimizer ...
# create_optimizer(): name = adamw
# --------------------------------------------------
# 4) Defining scheduler ...
# Using warmup+decay scheduler: 1e-6,5,2e-4,25,3e-6
# 1e-06 5 0.0002 25 3e-06
# Adjusting learning rate of group 0 to 1.0000e-06.
# Adjusting learning rate of group 0 to 1.0000e-06.
# --------------------------------------------------
# 5) Creating trainer and validator engines ...
# get_engine(): shift_answer=False
# chest_imagenome_bbox_loss_weight:  1.0
# get_engine(): shift_answer=False
# chest_imagenome_bbox_loss_weight:  1.0
# --------------------------------------------------
# 6) Defining collate_batch_fn ...
# --------------------------------------------------
# 7) Creating MIMIC-CXR visual module trainer ...
# get_image_transform()
# Using torchxrayvision transform (image_size = [224, 224])
# Setting XRayResizer engine to cv2 could increase performance.
# get_image_transform()
# Using torchxrayvision transform (image_size = [224, 224])
# Setting XRayResizer engine to cv2 could increase performance.
# Loading cached detailed metadata from /mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/qa_adapted_reports__20220904_095810.json__detailed_metadata.pkl
# Loaded 240530 non-gold DICOM IDs from Chest Imagenome
# 227835it [00:00, 493860.53it/s]
# len(self.train_indices) = 235209
# len(self.val_indices) = 1945
# Loading Chest Imagenome bounding boxes...
# --------------------------------------------------
# 8) Creating dataloaders ...
# len(_train_dataloaders) = 1
# len(_val_dataloaders) = 1
# _train_weights = [1.0]
# merged_dataset_name = mim
# --------------------------------------------------
# 9) Attaching metrics, losses, timer and events to engines ...
# --------------------------------------------------
# 10) Defining learning rate scheduler handler ...
# --------------------------------------------------
# 11) Defining checkpoint folder path ...
# checkpoint_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230217_023459_mim_resnet-ae-txv(101-elastic)
# metadata saved to /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230217_023459_mim_resnet-ae-txv(101-elastic)/metadata.json
# --------------------------------------------------
# 12) Defining log_metrics_handler ...
# MetricsLogger :: we'll be logging to /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230217_023459_mim_resnet-ae-txv(101-elastic)/metrics_logs.csv
# --------------------------------------------------
# 13) Running trainer engine ...
# ---- Epoch 1/30
# (1) Training stage (lr = 0.000001) ...
# loss 2.00633, chestimgbbmf1 0.00017, chestimgbb_loss 1.33593, chestimgbbiou 0.22003, chestimgbbmae 0.56732, 263.85 secs
# (2) Validation stage ...
# chestimgbbmf1 0.00066, chestimgbbiou 0.34054, chestimgbbmae 0.38853, 11.86 secs
# Adjusting learning rate of group 0 to 2.8854e-06.
# ---- Epoch 2/30
# (1) Training stage (lr = 0.000003) ...
# loss 0.83648, chestimgbbmf1 0.00483, chestimgbb_loss 0.35128, chestimgbbiou 0.52723, chestimgbbmae 0.22389, 275.76 secs
# (2) Validation stage ...
# chestimgbbmf1 0.00771, chestimgbbiou 0.60213, chestimgbbmae 0.16891, 12.23 secs
# Adjusting learning rate of group 0 to 8.3255e-06.
# ---- Epoch 3/30
# (1) Training stage (lr = 0.000008) ...
# loss 0.14601, chestimgbbmf1 0.01033, chestimgbb_loss 0.09985, chestimgbbiou 0.62593, chestimgbbmae 0.15585, 275.78 secs
# (2) Validation stage ...
# chestimgbbmf1 0.01313, chestimgbbiou 0.64181, chestimgbbmae 0.14752, 12.34 secs
# Adjusting learning rate of group 0 to 2.4022e-05.
# ---- Epoch 4/30
# (1) Training stage (lr = 0.000024) ...
# loss 0.07161, chestimgbbmf1 0.02046, chestimgbb_loss 0.06852, chestimgbbiou 0.67458, chestimgbbmae 0.13030, 280.27 secs
# (2) Validation stage ...
# chestimgbbmf1 0.02758, chestimgbbiou 0.69771, chestimgbbmae 0.11908, 12.28 secs
# Adjusting learning rate of group 0 to 6.9314e-05.
# ---- Epoch 5/30
# (1) Training stage (lr = 0.000069) ...
# loss 0.10398, chestimgbbmf1 0.05854, chestimgbb_loss 0.05255, chestimgbbiou 0.73905, chestimgbbmae 0.09954, 276.40 secs
# (2) Validation stage ...
# chestimgbbmf1 0.09069, chestimgbbiou 0.76346, chestimgbbmae 0.08868, 12.36 secs
# Adjusting learning rate of group 0 to 2.0000e-04.
# ---- Epoch 6/30
# (1) Training stage (lr = 0.000200) ...
# loss 0.03701, chestimgbbmf1 0.15924, chestimgbb_loss 0.04411, chestimgbbiou 0.79556, chestimgbbmae 0.07495, 276.92 secs
# (2) Validation stage ...
# chestimgbbmf1 0.22584, chestimgbbiou 0.81366, chestimgbbmae 0.06774, 12.29 secs
# Adjusting learning rate of group 0 to 1.6907e-04.
# ---- Epoch 7/30
# (1) Training stage (lr = 0.000169) ...
# loss 0.04021, chestimgbbmf1 0.30668, chestimgbb_loss 0.03636, chestimgbbiou 0.83394, chestimgbbmae 0.05939, 277.44 secs
# (2) Validation stage ...
# chestimgbbmf1 0.37099, chestimgbbiou 0.84190, chestimgbbmae 0.05658, 12.31 secs
# Adjusting learning rate of group 0 to 1.4293e-04.
# ---- Epoch 8/30
# (1) Training stage (lr = 0.000143) ...
# loss 0.04642, chestimgbbmf1 0.40343, chestimgbb_loss 0.03376, chestimgbbiou 0.84952, chestimgbbmae 0.05335, 277.15 secs
# (2) Validation stage ...
# chestimgbbmf1 0.43507, chestimgbbiou 0.85136, chestimgbbmae 0.05303, 12.35 secs
# Adjusting learning rate of group 0 to 1.2083e-04.
# ---- Epoch 9/30
# (1) Training stage (lr = 0.000121) ...
# loss 0.03685, chestimgbbmf1 0.47568, chestimgbb_loss 0.03119, chestimgbbiou 0.85972, chestimgbbmae 0.04942, 276.89 secs
# (2) Validation stage ...
# chestimgbbmf1 0.50566, chestimgbbiou 0.86084, chestimgbbmae 0.04940, 12.38 secs
# Adjusting learning rate of group 0 to 1.0214e-04.
# ---- Epoch 10/30
# (1) Training stage (lr = 0.000102) ...
# loss 0.01893, chestimgbbmf1 0.52532, chestimgbb_loss 0.02964, chestimgbbiou 0.86618, chestimgbbmae 0.04696, 276.98 secs
# (2) Validation stage ...
# chestimgbbmf1 0.52881, chestimgbbiou 0.86357, chestimgbbmae 0.04832, 12.21 secs
# Adjusting learning rate of group 0 to 8.6347e-05.
# ---- Epoch 11/30
# (1) Training stage (lr = 0.000086) ...
# loss 0.01757, chestimgbbmf1 0.55969, chestimgbb_loss 0.03052, chestimgbbiou 0.87003, chestimgbbmae 0.04562, 274.60 secs
# (2) Validation stage ...
# chestimgbbmf1 0.54143, chestimgbbiou 0.86560, chestimgbbmae 0.04748, 12.29 secs
# Adjusting learning rate of group 0 to 7.2995e-05.
# ---- Epoch 12/30
# (1) Training stage (lr = 0.000073) ...
# loss 0.01987, chestimgbbmf1 0.58541, chestimgbb_loss 0.02839, chestimgbbiou 0.87358, chestimgbbmae 0.04424, 275.41 secs
# (2) Validation stage ...
# chestimgbbmf1 0.57823, chestimgbbiou 0.86986, chestimgbbmae 0.04601, 12.36 secs
# Adjusting learning rate of group 0 to 6.1707e-05.
# ---- Epoch 13/30
# (1) Training stage (lr = 0.000062) ...
# loss 0.02776, chestimgbbmf1 0.60254, chestimgbb_loss 0.02797, chestimgbbiou 0.87570, chestimgbbmae 0.04345, 277.16 secs
# (2) Validation stage ...
# chestimgbbmf1 0.59528, chestimgbbiou 0.87285, chestimgbbmae 0.04506, 12.42 secs
# Adjusting learning rate of group 0 to 5.2165e-05.
# ---- Epoch 14/30
# (1) Training stage (lr = 0.000052) ...
# loss 0.02649, chestimgbbmf1 0.62188, chestimgbb_loss 0.02753, chestimgbbiou 0.87790, chestimgbbmae 0.04264, 277.60 secs
# (2) Validation stage ...
# chestimgbbmf1 0.62295, chestimgbbiou 0.87600, chestimgbbmae 0.04376, 12.34 secs
# Adjusting learning rate of group 0 to 4.4098e-05.
# ---- Epoch 15/30
# (1) Training stage (lr = 0.000044) ...
# loss 0.02393, chestimgbbmf1 0.63778, chestimgbb_loss 0.02724, chestimgbbiou 0.87973, chestimgbbmae 0.04197, 275.65 secs
# (2) Validation stage ...
# chestimgbbmf1 0.62088, chestimgbbiou 0.87519, chestimgbbmae 0.04402, 12.38 secs
# Adjusting learning rate of group 0 to 3.7279e-05.
# ---- Epoch 16/30
# (1) Training stage (lr = 0.000037) ...
# loss 0.02010, chestimgbbmf1 0.64719, chestimgbb_loss 0.02712, chestimgbbiou 0.88093, chestimgbbmae 0.04157, 276.48 secs
# (2) Validation stage ...
# chestimgbbmf1 0.64082, chestimgbbiou 0.87785, chestimgbbmae 0.04318, 12.39 secs
# Adjusting learning rate of group 0 to 3.1514e-05.
# ---- Epoch 17/30
# (1) Training stage (lr = 0.000032) ...
# loss 0.03909, chestimgbbmf1 0.65420, chestimgbb_loss 0.02710, chestimgbbiou 0.88189, chestimgbbmae 0.04121, 276.29 secs
# (2) Validation stage ...
# chestimgbbmf1 0.64683, chestimgbbiou 0.87850, chestimgbbmae 0.04277, 12.36 secs
# Adjusting learning rate of group 0 to 2.6641e-05.
# ---- Epoch 18/30
# (1) Training stage (lr = 0.000027) ...
# loss 0.01445, chestimgbbmf1 0.66447, chestimgbb_loss 0.02673, chestimgbbiou 0.88320, chestimgbbmae 0.04071, 279.46 secs
# (2) Validation stage ...
# chestimgbbmf1 0.65411, chestimgbbiou 0.87967, chestimgbbmae 0.04240, 12.45 secs
# Adjusting learning rate of group 0 to 2.2522e-05.
# ---- Epoch 19/30
# (1) Training stage (lr = 0.000023) ...
# loss 0.03188, chestimgbbmf1 0.67172, chestimgbb_loss 0.02647, chestimgbbiou 0.88408, chestimgbbmae 0.04039, 280.44 secs
# (2) Validation stage ...
# chestimgbbmf1 0.66266, chestimgbbiou 0.88036, chestimgbbmae 0.04217, 12.36 secs
# Adjusting learning rate of group 0 to 1.9039e-05.
# ---- Epoch 20/30
# (1) Training stage (lr = 0.000019) ...
# loss 0.01848, chestimgbbmf1 0.67824, chestimgbb_loss 0.02580, chestimgbbiou 0.88482, chestimgbbmae 0.04014, 287.75 secs
# (2) Validation stage ...
# chestimgbbmf1 0.67271, chestimgbbiou 0.88176, chestimgbbmae 0.04162, 12.82 secs
# Adjusting learning rate of group 0 to 1.6095e-05.
# ---- Epoch 21/30
# (1) Training stage (lr = 0.000016) ...
# loss 0.02074, chestimgbbmf1 0.68404, chestimgbb_loss 0.02604, chestimgbbiou 0.88554, chestimgbbmae 0.03985, 290.37 secs
# (2) Validation stage ...
# chestimgbbmf1 0.67634, chestimgbbiou 0.88211, chestimgbbmae 0.04155, 12.85 secs
# Adjusting learning rate of group 0 to 1.3606e-05.
# ---- Epoch 22/30
# (1) Training stage (lr = 0.000014) ...
# loss 0.00882, chestimgbbmf1 0.68676, chestimgbb_loss 0.02533, chestimgbbiou 0.88596, chestimgbbmae 0.03970, 288.48 secs
# (2) Validation stage ...
# chestimgbbmf1 0.66891, chestimgbbiou 0.88133, chestimgbbmae 0.04175, 13.09 secs
# Adjusting learning rate of group 0 to 1.1502e-05.
# ---- Epoch 23/30
# (1) Training stage (lr = 0.000012) ...
# loss 0.03645, chestimgbbmf1 0.69085, chestimgbb_loss 0.02525, chestimgbbiou 0.88691, chestimgbbmae 0.03933, 291.20 secs
# (2) Validation stage ...
# chestimgbbmf1 0.68335, chestimgbbiou 0.88309, chestimgbbmae 0.04116, 13.17 secs
# Adjusting learning rate of group 0 to 9.7233e-06.
# ---- Epoch 24/30
# (1) Training stage (lr = 0.000010) ...
# loss 0.02229, chestimgbbmf1 0.69119, chestimgbb_loss 0.02577, chestimgbbiou 0.88656, chestimgbbmae 0.03949, 292.71 secs
# (2) Validation stage ...
# chestimgbbmf1 0.68126, chestimgbbiou 0.88268, chestimgbbmae 0.04132, 12.95 secs
# Adjusting learning rate of group 0 to 8.2198e-06.
# ---- Epoch 25/30
# (1) Training stage (lr = 0.000008) ...
# loss 0.01623, chestimgbbmf1 0.69673, chestimgbb_loss 0.02599, chestimgbbiou 0.88713, chestimgbbmae 0.03931, 290.20 secs
# (2) Validation stage ...
# chestimgbbmf1 0.68716, chestimgbbiou 0.88360, chestimgbbmae 0.04101, 12.98 secs
# Adjusting learning rate of group 0 to 6.9487e-06.
# ---- Epoch 26/30
# (1) Training stage (lr = 0.000007) ...
# loss 0.03264, chestimgbbmf1 0.69916, chestimgbb_loss 0.02589, chestimgbbiou 0.88748, chestimgbbmae 0.03915, 288.33 secs
# (2) Validation stage ...
# chestimgbbmf1 0.69144, chestimgbbiou 0.88423, chestimgbbmae 0.04073, 13.17 secs
# Adjusting learning rate of group 0 to 5.8742e-06.
# ---- Epoch 27/30
# (1) Training stage (lr = 0.000006) ...
# loss 0.04193, chestimgbbmf1 0.69976, chestimgbb_loss 0.02484, chestimgbbiou 0.88767, chestimgbbmae 0.03906, 288.13 secs
# (2) Validation stage ...
# chestimgbbmf1 0.69169, chestimgbbiou 0.88415, chestimgbbmae 0.04078, 12.96 secs
# Adjusting learning rate of group 0 to 4.9658e-06.
# ---- Epoch 28/30
# (1) Training stage (lr = 0.000005) ...
# loss 0.04415, chestimgbbmf1 0.70397, chestimgbb_loss 0.02503, chestimgbbiou 0.88833, chestimgbbmae 0.03884, 288.90 secs
# (2) Validation stage ...
# chestimgbbmf1 0.69338, chestimgbbiou 0.88429, chestimgbbmae 0.04073, 13.01 secs
# Adjusting learning rate of group 0 to 4.1979e-06.
# ---- Epoch 29/30
# (1) Training stage (lr = 0.000004) ...
# loss 0.03158, chestimgbbmf1 0.70462, chestimgbb_loss 0.02501, chestimgbbiou 0.88852, chestimgbbmae 0.03876, 289.36 secs
# (2) Validation stage ...
# chestimgbbmf1 0.69335, chestimgbbiou 0.88427, chestimgbbmae 0.04073, 13.21 secs
# Adjusting learning rate of group 0 to 3.5488e-06.
# ---- Epoch 30/30
# (1) Training stage (lr = 0.000004) ...
# loss 0.02811, chestimgbbmf1 0.70560, chestimgbb_loss 0.02578, chestimgbbiou 0.88846, chestimgbbmae 0.03879, 289.04 secs
# (2) Validation stage ...
# chestimgbbmf1 0.69602, chestimgbbiou 0.88472, chestimgbbmae 0.04057, 13.26 secs
# Adjusting learning rate of group 0 to 3.0000e-06.
