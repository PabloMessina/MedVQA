# %%
# %env CUDA_VISIBLE_DEVICES=1
# Out:
# env: CUDA_VISIBLE_DEVICES=1

# %%
# !python ../train_visual_module.py \
--epochs 100 \
--batches_per_epoch 250 \
--batch_size 100 \
--num_workers 3 \
--gradient_accumulation_steps 4 \
--optimizer_name "adamw" \
--scheduler "exp-warmup+decay+cyclicdecay" \
--lr 1e-6 \
--warmup_decay_and_cyclic_decay_args "1e-6,3,1e-4,6,1e-6,1e-4,6,1e-6" \
--use_vinbig \
--vinbig_training_data_mode "train" \
--vinbig_use_validation \
--predict_bboxes_vinbig \
--binary_loss_name "focal+bce+wbcbce" \
--raw_image_encoding "yolov11-for-det-mlc" \
--yolov11_model_name_or_path "/mnt/data/pamessina/workspaces/medvqa-workspace/cache/vinbig/yolov11/train4/weights/best.pt" \
--yolov11_model_alias "yolo11l" \
--image_size 416 416 \
--image_local_feat_size 512 \
--num_regions 169 \
--classification_mlp_hidden_dims 256 128 \
--query_embed_size 128 \
--local_attention_hidden_size 256 \
--img_aug_mode "random-color-and-spatial" \
--use_amp \
--save
# Out:
# script's arguments:
#    epochs: 100
#    batches_per_epoch: 250
#    checkpoint_folder: None
#    visual_input_mode: raw-image
#    raw_image_encoding: yolov11-for-det-mlc
#    image_local_feat_size: 512
#    image_encoder_pretrained_weights_path: None
#    freeze_image_encoder: False
#    imagenet_pretrained: False
#    visual_features_mlp_in_dim: None
#    visual_features_mlp_out_dim: None
#    visual_features_mlp_hidden_dims: None
#    classification_mlp_hidden_dims: [256, 128]
#    iuxray_precomputed_visual_features_path: None
#    mimiccxr_precomputed_visual_features_path: None
#    chexpert_precomputed_visual_features_path: None
#    vinbig_precomputed_visual_features_path: None
#    clip_version: None
#    huggingface_model_name: None
#    chexpert_mlc_version: None
#    chexpert_mlc_hidden_size: 128
#    chest_imagenome_bbox_hidden_size: 128
#    chest_imagenome_bbox_regressor_version: None
#    chest_imagenome_mlc_version: None
#    chest_imagenome_mlc_hidden_size: 128
#    vinbig_mlc_hidden_size: 128
#    torchxrayvision_weights_name: None
#    detectron2_model_yaml: None
#    num_regions: 169
#    roi_heads_batch_size_per_image: 128
#    rpn_batch_size_per_image: 128
#    roi_align_output_size: None
#    yolov8_model_name_or_path: None
#    yolov8_model_alias: None
#    yolov8_use_one_detector_per_dataset: False
#    yolov11_model_name_or_path: /mnt/data/pamessina/workspaces/medvqa-workspace/cache/vinbig/yolov11/train4/weights/best.pt
#    yolov11_model_alias: yolo11l
#    query_embed_size: 128
#    local_attention_hidden_size: 256
#    optimizer_name: adamw
#    lr: 1e-06
#    scheduler: exp-warmup+decay+cyclicdecay
#    lr_decay: 0.76
#    lr_decay_patience: 2
#    warmup_and_decay_args: None
#    warmup_and_cosine_args: None
#    warmup_decay_and_cyclic_decay_args: 1e-6,3,1e-4,6,1e-6,1e-4,6,1e-6
#    batch_size: 100
#    gradient_accumulation_steps: 4
#    num_workers: 3
#    device: GPU
#    img_aug_mode: random-color-and-spatial
#    image_size: [416, 416]
#    horizontal_flip_prob: 0
#    mimiccxr_weight: 1
#    chexpert_weight: 0.3
#    cxr14_weight: 0.3
#    vinbig_weight: 0.3
#    iuxray_weight: 0.05
#    padchest_weight: 0.4
#    mimiccxr_view_mode: any_single
#    mimiccxr_balanced_sampling_mode: None
#    mimiccxr_balanced_batch_size: None
#    chest_imagenome_labels_filename: None
#    chest_imagenome_label_names_filename: None
#    use_chest_imagenome_decent_images_only: False
#    use_amp: True
#    pretrained_checkpoint_folder_path: None
#    pretrained_checkpoint_path: None
#    save: True
#    override_lr: False
#    train_mimiccxr: False
#    train_iuxray: False
#    train_chexpert: False
#    train_cxr14: False
#    train_vinbig: True
#    vinbig_training_data_mode: train
#    vinbig_use_validation: True
#    train_padchest: False
#    padchest_training_data_mode: train
#    padchest_use_validation: False
#    padchest_train_study_ids_path: None
#    padchest_val_study_ids_path: None
#    padchest_test_study_ids_path: None
#    binary_loss_name: focal+bce+wbcbce
#    focal_loss_weight: 1
#    bce_loss_weight: 1
#    wbce_loss_weight: 1
#    classify_tags: False
#    n_medical_tags: None
#    iuxray_medical_tags_per_report_filename: None
#    mimiccxr_medical_tags_per_report_filename: None
#    classify_orientation: False
#    classify_gender: False
#    classify_chexpert: False
#    iuxray_chexpert_labels_filename: None
#    mimiccxr_chexpert_labels_filename: None
#    classify_chest_imagenome: False
#    predict_bboxes_chest_imagenome: False
#    predict_labels_and_bboxes_chest_imagenome: False
#    clamp_bboxes_chest_imagenome: False
#    use_anaxnet_bbox_subset: False
#    chest_imagenome_bbox_loss_weight: 1.0
#    pass_pred_bbox_coords_as_input: False
#    use_gt_bboxes_as_predictions: False
#    predict_bboxes_vinbig: True
#    classify_labels_vinbig: False
#    classify_questions: False
#    n_mined_questions: None
#    iuxray_question_labels_filename: None
#    mimiccxr_question_labels_filename: None
#    merge_findings: False
# ----- Training model from scratch ------
# vinbig_class_id_offset: 0
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Creating instance of MultiPurposeVisualModule ...
# MultiPurposeVisualModule()
#   Initializing raw_image_encoder: yolov11-for-det-mlc
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  2    173824  ultralytics.nn.modules.block.C3k2            [128, 256, 2, True, 0.25]
#   3                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   4                  -1  2    691712  ultralytics.nn.modules.block.C3k2            [256, 512, 2, True, 0.25]
#   5                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   6                  -1  2   2234368  ultralytics.nn.modules.block.C3k2            [512, 512, 2, True]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  2   2234368  ultralytics.nn.modules.block.C3k2            [512, 512, 2, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  2   1455616  ultralytics.nn.modules.block.C2PSA           [512, 512, 2]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  2   2496512  ultralytics.nn.modules.block.C3k2            [1024, 512, 2, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  2    756736  ultralytics.nn.modules.block.C3k2            [1024, 256, 2, True]
#  17                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  2   2365440  ultralytics.nn.modules.block.C3k2            [768, 512, 2, True]
#  20                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  2   2496512  ultralytics.nn.modules.block.C3k2            [1024, 512, 2, True]
#  23        [16, 19, 22]  1   1427986  ultralytics.nn.modules.head.Detect           [22, [256, 512, 512]]
# YOLO11l summary: 631 layers, 25,327,442 parameters, 25,327,426 gradients, 87.4 GFLOPs
#
# Transferred 1015/1015 items from pretrained weights
#   Initializing auxiliary tasks
#     Skipping auxiliary tasks initialization for YOLOV11_FOR_DET_MLC
# --------------------------------------------------
# 3) Defining optimizer ...
# create_optimizer(): name = adamw
# --------------------------------------------------
# 4) Defining scheduler ...
# Using exp-warmup+decay+cyclicdecay scheduler: 1e-6,3,1e-4,6,1e-6,1e-4,6,1e-6
# 1e-06 3 0.0001 6 1e-06 0.0001 6 1e-06
# self.steps_to_restart = 6
# self.steps = -1
# self.initial_lr = 0.0001
# --------------------------------------------------
# 5) Creating trainer and validator engines ...
# get_engine(): shift_answer=False
# Focal_BCE_WBCBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 wbcbce_weight = 0.3333333333333333
# GradientAccumulator.__init__(): num_accumulation_steps = 1, max_grad_norm = None
# get_engine(): shift_answer=False
# --------------------------------------------------
# 6) Defining collate_batch_fn ...
# --------------------------------------------------
# 7) Creating VinBig visual module trainer ...
# get_image_transform()
#   image_size = [416, 416]
#   mean = [0.0, 0.0, 0.0]
#   std = [1.0, 1.0, 1.0]
#   Using bounding box aware transforms
#     augmentation_mode = random-color-and-spatial
#     default_prob = 0.35
#     for_vinbig: returning vinbig transform
# get_train_transform(): Using bbox-aware transforms for VinBigData
#     Returning augmented transform with mode random-color-and-spatial
# get_image_transform()
#   image_size = [416, 416]
#   mean = [0.0, 0.0, 0.0]
#   std = [1.0, 1.0, 1.0]
#   Using bounding box aware transforms
#     Returning default transform (no augmentation)
# Loading bounding boxes
# Anomalous bboxes found: 29 of 37367
# class_id_offset: 0
# Anomalous bboxes found: 0 of 2697
# class_id_offset: 0
#   Loaded 18000 bounding boxes
# Generating train dataset and dataloader
# No finding        , #pos=10601, #neg=4399
# Other disease     , #pos=4288, #neg=10712
# Aortic enlargement, #pos=3067, #neg=11933
# Cardiomegaly      , #pos=2300, #neg=12700
# Pleural thickening, #pos=1981, #neg=13019
# Pulmonary fibrosis, #pos=1617, #neg=13383
# Lung Opacity      , #pos=1322, #neg=13678
# Other lesion      , #pos=1134, #neg=13866
# Pleural effusion  , #pos=1032, #neg=13968
# Pneumonia         , #pos=917, #neg=14083
# Nodule/Mass       , #pos=830, #neg=14170
# Tuberculosis      , #pos=750, #neg=14250
# Infiltration      , #pos=613, #neg=14387
# Calcification     , #pos=452, #neg=14548
# ILD               , #pos=386, #neg=14614
# Consolidation     , #pos=353, #neg=14647
# Lung tumor        , #pos=291, #neg=14709
# Atelectasis       , #pos=186, #neg=14814
# Mediastinal shift , #pos=150, #neg=14850
# Enlarged PA       , #pos=131, #neg=14869
# Pneumothorax      , #pos=96, #neg=14904
# Rib fracture      , #pos=90, #neg=14910
# Emphysema         , #pos=78, #neg=14922
# Lung cavity       , #pos=50, #neg=14950
# COPD              , #pos=35, #neg=14965
# Lung cyst         , #pos=32, #neg=14968
# Clavicle fracture , #pos=27, #neg=14973
# Edema             , #pos=13, #neg=14987
# len(train_indices) = 15000
# len(self.test_indices) = 3000
# --------------------------------------------------
# 8) Creating dataloaders ...
# len(_train_dataloaders) = 1
# len(_val_dataloaders) = 1
# _train_weights =
secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.11010, 19.61 secs
# ---- Epoch 91/100
# (1) Training stage (lr = 0.000016) ...
# loss 4.89962, vnb_y11_loss 4.89962, vnb_y11_box_loss 1.64837, vnb_y11_cls_loss 1.64753, vnb_y11_dfl_loss 1.60372, 152.54 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.11444, 19.52 secs
# ---- Epoch 92/100
# (1) Training stage (lr = 0.000006) ...
# loss 4.88695, vnb_y11_loss 4.88695, vnb_y11_box_loss 1.64272, vnb_y11_cls_loss 1.64075, vnb_y11_dfl_loss 1.60347, 152.65 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.11177, 19.39 secs
# ---- Epoch 93/100
# (1) Training stage (lr = 0.000003) ...
# loss 4.89417, vnb_y11_loss 4.89417, vnb_y11_box_loss 1.64532, vnb_y11_cls_loss 1.64376, vnb_y11_dfl_loss 1.60509, 154.88 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.10960, 19.42 secs
# ---- Epoch 94/100
# (1) Training stage (lr = 0.000001) ...
# loss 4.90918, vnb_y11_loss 4.90918, vnb_y11_box_loss 1.64982, vnb_y11_cls_loss 1.65058, vnb_y11_dfl_loss 1.60878, 153.04 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.10678, 19.73 secs
# ---- Epoch 95/100
# (1) Training stage (lr = 0.000100) ...
# loss 4.90809, vnb_y11_loss 4.90809, vnb_y11_box_loss 1.65048, vnb_y11_cls_loss 1.64841, vnb_y11_dfl_loss 1.60919, 154.38 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.11643, 19.72 secs
# ---- Epoch 96/100
# (1) Training stage (lr = 0.000040) ...
# loss 4.88660, vnb_y11_loss 4.88660, vnb_y11_box_loss 1.64199, vnb_y11_cls_loss 1.64310, vnb_y11_dfl_loss 1.60151, 152.48 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.11415, 19.78 secs
# ---- Epoch 97/100
# (1) Training stage (lr = 0.000016) ...
# loss 4.90001, vnb_y11_loss 4.90001, vnb_y11_box_loss 1.64979, vnb_y11_cls_loss 1.64379, vnb_y11_dfl_loss 1.60643, 157.08 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.11311, 19.62 secs
# ---- Epoch 98/100
# (1) Training stage (lr = 0.000006) ...
# loss 4.86724, vnb_y11_loss 4.86724, vnb_y11_box_loss 1.63644, vnb_y11_cls_loss 1.63163, vnb_y11_dfl_loss 1.59917, 153.47 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.11262, 19.41 secs
# ---- Epoch 99/100
# (1) Training stage (lr = 0.000003) ...
# loss 4.87922, vnb_y11_loss 4.87922, vnb_y11_box_loss 1.64298, vnb_y11_cls_loss 1.63522, vnb_y11_dfl_loss 1.60102, 151.93 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.11447, 19.77 secs
# ---- Epoch 100/100
# (1) Training stage (lr = 0.000001) ...
# loss 4.86971, vnb_y11_loss 4.86971, vnb_y11_box_loss 1.63835, vnb_y11_cls_loss 1.63235, vnb_y11_dfl_loss 1.59901, 156.21 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.11218, 19.35 secs

# %%
# !python ../train_visual_module.py \
--pretrained_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20241123_031630_vinbig_yolo11l(d:vinbig)" \
--epochs 50 \
--batches_per_epoch 200 \
--train_batch_size 100 \
--val_batch_size 150 \
--num_workers 3 \
--gradient_accumulation_steps 2 \
--optimizer_name "adamw" \
--scheduler "exp-warmup+decay+cyclicdecay" \
--lr 1e-6 \
--warmup_decay_and_cyclic_decay_args "1e-6,3,1e-4,6,1e-6,1e-4,6,1e-6" \
--use_vinbig \
--vinbig_training_data_mode "train" \
--vinbig_use_validation \
--predict_bboxes_vinbig \
--binary_loss_name "focal+bce+wbcbce" \
--raw_image_encoding "yolov11-for-det-mlc" \
--yolov11_model_name_or_path "/mnt/data/pamessina/workspaces/medvqa-workspace/cache/vinbig/yolov11/train4/weights/best.pt" \
--yolov11_model_alias "yolo11l" \
--image_size 416 416 \
--image_local_feat_size 512 \
--num_regions 169 \
--classification_mlp_hidden_dims 256 128 \
--query_embed_size 128 \
--local_attention_hidden_size 256 \
--img_aug_mode "random-color-and-spatial" \
--use_amp \
--save
# Out:
# script's arguments:
#    epochs: 50
#    batches_per_epoch: 200
#    checkpoint_folder: None
#    visual_input_mode: raw-image
#    raw_image_encoding: yolov11-for-det-mlc
#    image_local_feat_size: 512
#    image_encoder_pretrained_weights_path: None
#    freeze_image_encoder: False
#    imagenet_pretrained: False
#    visual_features_mlp_in_dim: None
#    visual_features_mlp_out_dim: None
#    visual_features_mlp_hidden_dims: None
#    classification_mlp_hidden_dims: [256, 128]
#    iuxray_precomputed_visual_features_path: None
#    mimiccxr_precomputed_visual_features_path: None
#    chexpert_precomputed_visual_features_path: None
#    vinbig_precomputed_visual_features_path: None
#    clip_version: None
#    huggingface_model_name: None
#    chexpert_mlc_version: None
#    chexpert_mlc_hidden_size: 128
#    chest_imagenome_bbox_hidden_size: 128
#    chest_imagenome_bbox_regressor_version: None
#    chest_imagenome_mlc_version: None
#    chest_imagenome_mlc_hidden_size: 128
#    vinbig_mlc_hidden_size: 128
#    torchxrayvision_weights_name: None
#    detectron2_model_yaml: None
#    num_regions: 169
#    roi_heads_batch_size_per_image: 128
#    rpn_batch_size_per_image: 128
#    roi_align_output_size: None
#    yolov8_model_name_or_path: None
#    yolov8_model_alias: None
#    yolov8_use_one_detector_per_dataset: False
#    yolov11_model_name_or_path: /mnt/data/pamessina/workspaces/medvqa-workspace/cache/vinbig/yolov11/train4/weights/best.pt
#    yolov11_model_alias: yolo11l
#    query_embed_size: 128
#    local_attention_hidden_size: 256
#    use_linear_head_for_classification: False
#    optimizer_name: adamw
#    lr: 1e-06
#    scheduler: exp-warmup+decay+cyclicdecay
#    lr_decay: 0.76
#    lr_decay_patience: 2
#    warmup_and_decay_args: None
#    warmup_and_cosine_args: None
#    warmup_decay_and_cyclic_decay_args: 1e-6,3,1e-4,6,1e-6,1e-4,6,1e-6
#    train_batch_size: 100
#    val_batch_size: 150
#    gradient_accumulation_steps: 2
#    num_workers: 3
#    device: GPU
#    img_aug_mode: random-color-and-spatial
#    image_size: [416, 416]
#    horizontal_flip_prob: 0
#    mimiccxr_weight: 1
#    chexpert_weight: 0.3
#    cxr14_weight: 0.3
#    vinbig_weight: 0.3
#    iuxray_weight: 0.05
#    padchest_weight: 0.4
#    mimiccxr_view_mode: any_single
#    mimiccxr_balanced_sampling_mode: None
#    mimiccxr_balanced_batch_size: None
#    chest_imagenome_labels_filename: None
#    chest_imagenome_label_names_filename: None
#    use_chest_imagenome_decent_images_only: False
#    use_amp: True
#    pretrained_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20241123_031630_vinbig_yolo11l(d:vinbig)
#    pretrained_checkpoint_path: None
#    save: True
#    override_lr: False
#    train_mimiccxr: False
#    train_iuxray: False
#    train_chexpert: False
#    train_cxr14: False
#    train_vinbig: True
#    vinbig_training_data_mode: train
#    vinbig_use_validation: True
#    train_padchest: False
#    padchest_training_data_mode: train
#    padchest_use_validation: False
#    padchest_train_study_ids_path: None
#    padchest_val_study_ids_path: None
#    padchest_test_study_ids_path: None
#    binary_loss_name: focal+bce+wbcbce
#    focal_loss_weight: 1
#    bce_loss_weight: 1
#    wbce_loss_weight: 1
#    classify_tags: False
#    n_medical_tags: None
#    iuxray_medical_tags_per_report_filename: None
#    mimiccxr_medical_tags_per_report_filename: None
#    classify_orientation: False
#    classify_gender: False
#    classify_chexpert: False
#    iuxray_chexpert_labels_filename: None
#    mimiccxr_chexpert_labels_filename: None
#    classify_chest_imagenome: False
#    predict_bboxes_chest_imagenome: False
#    predict_labels_and_bboxes_chest_imagenome: False
#    clamp_bboxes_chest_imagenome: False
#    use_anaxnet_bbox_subset: False
#    chest_imagenome_bbox_loss_weight: 1.0
#    pass_pred_bbox_coords_as_input: False
#    use_gt_bboxes_as_predictions: False
#    predict_bboxes_vinbig: True
#    classify_labels_vinbig: False
#    classify_questions: False
#    n_mined_questions: None
#    iuxray_question_labels_filename: None
#    mimiccxr_question_labels_filename: None
#    merge_findings: False
# ----- Training model from scratch ------
# vinbig_class_id_offset: 0
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Creating instance of MultiPurposeVisualModule ...
# MultiPurposeVisualModule()
#   Initializing raw_image_encoder: yolov11-for-det-mlc
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  2    173824  ultralytics.nn.modules.block.C3k2            [128, 256, 2, True, 0.25]
#   3                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   4                  -1  2    691712  ultralytics.nn.modules.block.C3k2            [256, 512, 2, True, 0.25]
#   5                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   6                  -1  2   2234368  ultralytics.nn.modules.block.C3k2            [512, 512, 2, True]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  2   2234368  ultralytics.nn.modules.block.C3k2            [512, 512, 2, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  2   1455616  ultralytics.nn.modules.block.C2PSA           [512, 512, 2]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  2   2496512  ultralytics.nn.modules.block.C3k2            [1024, 512, 2, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  2    756736  ultralytics.nn.modules.block.C3k2            [1024, 256, 2, True]
#  17                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  2   2365440  ultralytics.nn.modules.block.C3k2            [768, 512, 2, True]
#  20                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  2   2496512  ultralytics.nn.modules.block.C3k2            [1024, 512, 2, True]
#  23        [16, 19, 22]  1   1427986  ultralytics.nn.modules.head.Detect           [22, [256, 512, 512]]
# YOLO11l summary: 631 layers, 25,327,442 parameters, 25,327,426 gradients, 87.4 GFLOPs
#
# Transferred 1015/1015 items from pretrained weights
# From YOLOv11CustomLoss:
# device: cuda
#   Initializing auxiliary tasks
#     Skipping auxiliary tasks initialization for YOLOv11 models
# --------------------------------------------------
# 3) Defining optimizer ...
# create_optimizer(): name = adamw
# --------------------------------------------------
# 4) Defining scheduler ...
# Using exp-warmup+decay+cyclicdecay scheduler: 1e-6,3,1e-4,6,1e-6,1e-4,6,1e-6
# 1e-06 3 0.0001 6 1e-06 0.0001 6 1e-06
# self.steps_to_restart = 6
# self.steps = -1
# self.initial_lr = 0.0001
# --------------------------------------------------
# 5) Creating trainer and validator engines ...
# get_engine(): shift_answer=False
# Focal_BCE_WBCBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 wbcbce_weight = 0.3333333333333333
# GradientAccumulator.__init__(): num_accumulation_steps = 1, max_grad_norm = None
# get_engine(): shift_answer=False
# --------------------------------------------------
# 6) Defining collate_batch_fn ...
# --------------------------------------------------
# 7) Creating VinBig visual module trainer ...
# get_image_transform()
#   image_size = [416, 416]
#   mean = [0.0, 0.0, 0.0]
#   std = [1.0, 1.0, 1.0]
#   Using bounding box aware transforms
#     augmentation_mode = random-color-and-spatial
#     default_prob = 0.35
#     for_vinbig: returning vinbig transform
# get_train_transform(): Using bbox-aware transforms for VinBigData
#     Returning augmented transform with mode random-color-and-spatial
# get_image_transform()
#   image_size = [416, 416]
#   mean = [0.0, 0.0, 0.0]
#   std = [1.0, 1.0, 1.0]
#   Using bounding box aware transforms
#     Returning default transform (no augmentation)
# Loading bounding boxes
# Anomalous bboxes found: 29 of 37367
# class_id_offset: 0
# Anomalous bboxes found: 0 of 2697
# class_id_offset: 0
#   Loaded 18000 bounding boxes
# Generating train dataset and dataloader
# No finding        , #pos=10478, #neg=4522
# Other disease     , #pos=4377, #neg=10623
# Aortic enlargement, #pos=3098, #neg=11902
# Cardiomegaly      , #pos=2316, #neg=12684
# Pleural thickening, #pos=2010, #neg=12990
# Pulmonary fibrosis, #pos=1621, #neg=13379
# Lung Opacity      , #pos=1331, #neg=13669
# Other lesion      , #pos=1154, #neg=13846
# Pleural effusion  , #pos=1038, #neg=13962
# Pneumonia         , #pos=919, #neg=14081
# Nodule/Mass       , #pos=841, #neg=14159
# Tuberculosis      , #pos=750, #neg=14250
# Infiltration      , #pos=613, #neg=14387
# Calcification     , #pos=458, #neg=14542
# ILD               , #pos=397, #neg=14603
# Consolidation     , #pos=353, #neg=14647
# Lung tumor        , #pos=291, #neg=14709
# Atelectasis       , #pos=187, #neg=14813
# Mediastinal shift , #pos=150, #neg=14850
# Enlarged PA       , #pos=131, #neg=14869
# Pneumothorax      , #pos=96, #neg=14904
# Rib fracture      , #pos=90, #neg=14910
# Emphysema         , #pos=81, #neg=14919
# Lung cavity       , #pos=51, #neg=14949
# COPD              , #pos=36, #neg=14964
# Lung cyst         , #pos=33, #neg=14967
# Clavicle fracture , #pos=27, #neg=14973
# Edema             , #pos=13, #neg=14987
# len(train_indices) = 15000
# Generating val dataset and dataloader
# len(test_indices) = 3000
# --------------------------------------------------
# 8) Creating dataloaders ...
# len(_train_dataloaders) = 1
# len(_val_dataloaders) = 1
# _train_weights = [0.3]
# merged_dataset_name = vinbig
# --------------------------------------------------
# 9) Attaching metrics, losses, timer and events to engines ...
# NOTE: Using only validation metrics
# --------------------------------------------------
# 10) Defining learning rate scheduler handler ...
# --------------------------------------------------
# 11) Defining checkpoint folder path ...
# checkpoint_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20250216_150203_vinbig_yolo11l(d:vinbig)
# metadata saved to /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20250216_150203_vinbig_yolo11l(d:vinbig)/metadata.json
# --------------------------------------------------
# 12) Loading pretrained weights ...
# checkpoint_names = ['checkpoint_72_vnb_y11_bbox_iou=0.1165.pt']
# pretrained_checkpoint_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20241123_031630_vinbig_yolo11l(d:vinbig)/checkpoint_72_vnb_y11_bbox_iou=0.1165.pt
# Checkpoint successfully loaded!
# --------------------------------------------------
# 13) Defining log_metrics_handler ...
# MetricsLogger :: we'll be logging to /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20250216_150203_vinbig_yolo11l(d:vinbig)/metrics_logs.csv
# --------------------------------------------------
# 14) Running trainer engine ...
# ---- Epoch 1/50
# (1) Training stage (lr = 0.000001) ...
# loss 5.17262, vnb_y11_loss 5.17262, vnb_y11_box_loss 1.71843, vnb_y11_cls_loss 1.79292, vnb_y11_dfl_loss 1.66127, 126.58 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.16449, 21.17 secs
# Val metrics:
# vnb_y11_bbox_iou: 0.1645, weight = 1.0
# num = 0.1645, den = 1.0000, score = 0.1645
# Final val score = 0.1645
# New checkpoint saved: checkpoint_1_vnb_y11_bbox_iou=0.1645.pt
# ---- Epoch 2/50
# (1) Training stage (lr = 0.000005) ...
# loss 5.12845, vnb_y11_loss 5.12845, vnb_y11_box_loss 1.70960, vnb_y11_cls_loss 1.76962, vnb_y11_dfl_loss 1.64923, 123.14 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.16434, 20.66 secs
# ---- Epoch 3/50
# (1) Training stage (lr = 0.000022) ...
# loss 5.13661, vnb_y11_loss 5.13661, vnb_y11_box_loss 1.71084, vnb_y11_cls_loss 1.77251, vnb_y11_dfl_loss 1.65327, 123.25 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.16952, 20.91 secs
# New checkpoint saved: checkpoint_3_vnb_y11_bbox_iou=0.1695.pt
# ---- Epoch 4/50
# (1) Training stage (lr = 0.000100) ...
# loss 5.11637, vnb_y11_loss 5.11637, vnb_y11_box_loss 1.70340, vnb_y11_cls_loss 1.76708, vnb_y11_dfl_loss 1.64590, 123.55 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.16467, 20.82 secs
# ---- Epoch 5/50
# (1) Training stage (lr = 0.000046) ...
# loss 5.09930, vnb_y11_loss 5.09930, vnb_y11_box_loss 1.70097, vnb_y11_cls_loss 1.75449, vnb_y11_dfl_loss 1.64384, 124.82 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.16362, 20.92 secs
# ---- Epoch 6/50
# (1) Training stage (lr = 0.000022) ...
# loss 5.08391, vnb_y11_loss 5.08391, vnb_y11_box_loss 1.69388, vnb_y11_cls_loss 1.75227, vnb_y11_dfl_loss 1.63776, 124.32 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.16351, 20.97 secs
# ---- Epoch 7/50
# (1) Training stage (lr = 0.000010) ...
# loss 5.07905, vnb_y11_loss 5.07905, vnb_y11_box_loss 1.69200, vnb_y11_cls_loss 1.74759, vnb_y11_dfl_loss 1.63946, 124.94 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.16874, 21.20 secs
# ---- Epoch 8/50
# (1) Training stage (lr = 0.000005) ...
# loss 5.07168, vnb_y11_loss 5.07168, vnb_y11_box_loss 1.69014, vnb_y11_cls_loss 1.74279, vnb_y11_dfl_loss 1.63875, 125.20 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.17592, 21.17 secs
# New checkpoint saved: checkpoint_8_vnb_y11_bbox_iou=0.1759.pt
# ---- Epoch 9/50
# (1) Training stage (lr = 0.000002) ...
# loss 5.06722, vnb_y11_loss 5.06722, vnb_y11_box_loss 1.68909, vnb_y11_cls_loss 1.74225, vnb_y11_dfl_loss 1.63587, 125.07 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.16569, 21.36 secs
# ---- Epoch 10/50
# (1) Training stage (lr = 0.000001) ...
# loss 5.07151, vnb_y11_loss 5.07151, vnb_y11_box_loss 1.69219, vnb_y11_cls_loss 1.74213, vnb_y11_dfl_loss 1.63719, 125.15 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.16637, 20.96 secs
# ---- Epoch 11/50
# (1) Training stage (lr = 0.000100) ...
# loss 5.08401, vnb_y11_loss 5.08401, vnb_y11_box_loss 1.69091, vnb_y11_cls_loss 1.75261, vnb_y11_dfl_loss 1.64048, 126.96 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.16492, 21.10 secs
# ---- Epoch 12/50
# (1) Training stage (lr = 0.000040) ...
# loss 5.08482, vnb_y11_loss 5.08482, vnb_y11_box_loss 1.69366, vnb_y11_cls_loss 1.74775, vnb_y11_dfl_loss 1.64341, 126.55 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.17175, 21.31 secs
# ---- Epoch 13/50
# (1) Training stage (lr = 0.000016) ...
# loss 5.06305, vnb_y11_loss 5.06305, vnb_y11_box_loss 1.68822, vnb_y11_cls_loss 1.73803, vnb_y11_dfl_loss 1.63680, 124.34 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.17321, 21.17 secs
# ---- Epoch 14/50
# (1) Training stage (lr = 0.000006) ...
# loss 5.03645, vnb_y11_loss 5.03645, vnb_y11_box_loss 1.68028, vnb_y11_cls_loss 1.72594, vnb_y11_dfl_loss 1.63024, 126.01 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.16894, 21.25 secs
# ---- Epoch 15/50
# (1) Training stage (lr = 0.000003) ...
# loss 5.06900, vnb_y11_loss 5.06900, vnb_y11_box_loss 1.68969, vnb_y11_cls_loss 1.73931, vnb_y11_dfl_loss 1.63999, 128.10 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.16827, 21.21 secs
# ---- Epoch 16/50
# (1) Training stage (lr = 0.000001) ...
# loss 5.05422, vnb_y11_loss 5.05422, vnb_y11_box_loss 1.68579, vnb_y11_cls_loss 1.73260, vnb_y11_dfl_loss 1.63583, 126.86 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.16190, 21.45 secs
# ---- Epoch 17/50
# (1) Training stage (lr = 0.000100) ...
# loss 5.06188, vnb_y11_loss 5.06188, vnb_y11_box_loss 1.68784, vnb_y11_cls_loss 1.73775, vnb_y11_dfl_loss 1.63628, 125.69 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.16226, 21.14 secs
# ---- Epoch 18/50
# (1) Training stage (lr = 0.000040) ...
# loss 5.06216, vnb_y11_loss 5.06216, vnb_y11_box_loss 1.68818, vnb_y11_cls_loss 1.73660, vnb_y11_dfl_loss 1.63737, 125.43 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.16146, 21.34 secs
# ---- Epoch 19/50
# (1) Training stage (lr = 0.000016) ...
# loss 5.04283, vnb_y11_loss 5.04283, vnb_y11_box_loss 1.68278, vnb_y11_cls_loss 1.72587, vnb_y11_dfl_loss 1.63418, 126.06 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.17025, 21.37 secs
# ---- Epoch 20/50
# (1) Training stage (lr = 0.000006) ...
# loss 5.03471, vnb_y11_loss 5.03471, vnb_y11_box_loss 1.68145, vnb_y11_cls_loss 1.72369, vnb_y11_dfl_loss 1.62957, 126.77 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.16481, 21.25 secs
# ---- Epoch 21/50
# (1) Training stage (lr = 0.000003) ...
# loss 5.02943, vnb_y11_loss 5.02943, vnb_y11_box_loss 1.67776, vnb_y11_cls_loss 1.72096, vnb_y11_dfl_loss 1.63071, 128.71 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.17842, 21.62 secs
# New checkpoint saved: checkpoint_21_vnb_y11_bbox_iou=0.1784.pt
# ---- Epoch 22/50
# (1) Training stage (lr = 0.000001) ...
# loss 5.04579, vnb_y11_loss 5.04579, vnb_y11_box_loss 1.68310, vnb_y11_cls_loss 1.72965, vnb_y11_dfl_loss 1.63304, 126.24 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.16727, 21.39 secs
# ---- Epoch 23/50
# (1) Training stage (lr = 0.000100) ...
# loss 5.04559, vnb_y11_loss 5.04559, vnb_y11_box_loss 1.68581, vnb_y11_cls_loss 1.72951, vnb_y11_dfl_loss 1.63028, 127.78 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.15977, 21.29 secs
# ---- Epoch 24/50
# (1) Training stage (lr = 0.000040) ...
# loss 5.02030, vnb_y11_loss 5.02030, vnb_y11_box_loss 1.67347, vnb_y11_cls_loss 1.71754, vnb_y11_dfl_loss 1.62929, 126.13 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.17288, 21.26 secs
# ---- Epoch 25/50
# (1) Training stage (lr = 0.000016) ...
# loss 5.04042, vnb_y11_loss 5.04042, vnb_y11_box_loss 1.68309, vnb_y11_cls_loss 1.72415, vnb_y11_dfl_loss 1.63318, 126.70 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.17465, 21.35 secs
# ---- Epoch 26/50
# (1) Training stage (lr = 0.000006) ...
# loss 5.01498, vnb_y11_loss 5.01498, vnb_y11_box_loss 1.67257, vnb_y11_cls_loss 1.71477, vnb_y11_dfl_loss 1.62763, 126.85 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.16787, 21.52 secs
# ---- Epoch 27/50
# (1) Training stage (lr = 0.000003) ...
# loss 5.00706, vnb_y11_loss 5.00706, vnb_y11_box_loss 1.67358, vnb_y11_cls_loss 1.70993, vnb_y11_dfl_loss 1.62355, 130.17 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.17376, 21.26 secs
# ---- Epoch 28/50
# (1) Training stage (lr = 0.000001) ...
# loss 5.02084, vnb_y11_loss 5.02084, vnb_y11_box_loss 1.67712, vnb_y11_cls_loss 1.71473, vnb_y11_dfl_loss 1.62899, 126.91 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.17349, 21.40 secs
# ---- Epoch 29/50
# (1) Training stage (lr = 0.000100) ...
# loss 5.02850, vnb_y11_loss 5.02850, vnb_y11_box_loss 1.67625, vnb_y11_cls_loss 1.72477, vnb_y11_dfl_loss 1.62748, 124.22 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.17098, 21.81 secs
# ---- Epoch 30/50
# (1) Training stage (lr = 0.000040) ...
# loss 5.03837, vnb_y11_loss 5.03837, vnb_y11_box_loss 1.68266, vnb_y11_cls_loss 1.72218, vnb_y11_dfl_loss 1.63354, 129.13 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.18022, 21.38 secs
# New checkpoint saved: checkpoint_30_vnb_y11_bbox_iou=0.1802.pt
# ---- Epoch 31/50
# (1) Training stage (lr = 0.000016) ...
# loss 5.00306, vnb_y11_loss 5.00306, vnb_y11_box_loss 1.67244, vnb_y11_cls_loss 1.70729, vnb_y11_dfl_loss 1.62332, 128.30 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.17474, 21.80 secs
# ---- Epoch 32/50
# (1) Training stage (lr = 0.000006) ...
# loss 5.00141, vnb_y11_loss 5.00141, vnb_y11_box_loss 1.67089, vnb_y11_cls_loss 1.70634, vnb_y11_dfl_loss 1.62418, 130.68 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.17341, 21.22 secs
# ---- Epoch 33/50
# (1) Training stage (lr = 0.000003) ...
# loss 4.99731, vnb_y11_loss 4.99731, vnb_y11_box_loss 1.66972, vnb_y11_cls_loss 1.70410, vnb_y11_dfl_loss 1.62349, 128.19 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.17422, 21.35 secs
# ---- Epoch 34/50
# (1) Training stage (lr = 0.000001) ...
# loss 4.99505, vnb_y11_loss 4.99505, vnb_y11_box_loss 1.66874, vnb_y11_cls_loss 1.70262, vnb_y11_dfl_loss 1.62369, 128.77 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.17701, 21.64 secs
# ---- Epoch 35/50
# (1) Training stage (lr = 0.000100) ...
# loss 5.02291, vnb_y11_loss 5.02291, vnb_y11_box_loss 1.67904, vnb_y11_cls_loss 1.71416, vnb_y11_dfl_loss 1.62971, 131.23 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.17479, 21.64 secs
# ---- Epoch 36/50
# (1) Training stage (lr = 0.000040) ...
# loss 5.00743, vnb_y11_loss 5.00743, vnb_y11_box_loss 1.67299, vnb_y11_cls_loss 1.70836, vnb_y11_dfl_loss 1.62608, 130.57 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.17140, 22.00 secs
# ---- Epoch 37/50
# (1) Training stage (lr = 0.000016) ...
# loss 4.98884, vnb_y11_loss 4.98884, vnb_y11_box_loss 1.66582, vnb_y11_cls_loss 1.70030, vnb_y11_dfl_loss 1.62271, 131.01 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.17003, 21.60 secs
# ---- Epoch 38/50
# (1) Training stage (lr = 0.000006) ...
# loss 4.99485, vnb_y11_loss 4.99485, vnb_y11_box_loss 1.66895, vnb_y11_cls_loss 1.70278, vnb_y11_dfl_loss 1.62312, 127.91 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.16852, 21.60 secs
# ---- Epoch 39/50
# (1) Training stage (lr = 0.000003) ...
# loss 4.97812, vnb_y11_loss 4.97812, vnb_y11_box_loss 1.66227, vnb_y11_cls_loss 1.69839, vnb_y11_dfl_loss 1.61746, 127.33 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.17416, 21.56 secs
# ---- Epoch 40/50
# (1) Training stage (lr = 0.000001) ...
# loss 4.98900, vnb_y11_loss 4.98900, vnb_y11_box_loss 1.66781, vnb_y11_cls_loss 1.69871, vnb_y11_dfl_loss 1.62248, 128.89 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.17848, 21.91 secs
# ---- Epoch 41/50
# (1) Training stage (lr = 0.000100) ...
# loss 4.99932, vnb_y11_loss 4.99932, vnb_y11_box_loss 1.67138, vnb_y11_cls_loss 1.70195, vnb_y11_dfl_loss 1.62600, 130.81 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.16943, 21.61 secs
# ---- Epoch 42/50
# (1) Training stage (lr = 0.000040) ...
# loss 4.98508, vnb_y11_loss 4.98508, vnb_y11_box_loss 1.66642, vnb_y11_cls_loss 1.69572, vnb_y11_dfl_loss 1.62294, 131.34 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.17101, 21.76 secs
# ---- Epoch 43/50
# (1) Training stage (lr = 0.000016) ...
# loss 4.96992, vnb_y11_loss 4.96992, vnb_y11_box_loss 1.66485, vnb_y11_cls_loss 1.68769, vnb_y11_dfl_loss 1.61738, 130.90 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.18098, 22.09 secs
# New checkpoint saved: checkpoint_43_vnb_y11_bbox_iou=0.1810.pt
# ---- Epoch 44/50
# (1) Training stage (lr = 0.000006) ...
# loss 4.97974, vnb_y11_loss 4.97974, vnb_y11_box_loss 1.66318, vnb_y11_cls_loss 1.69628, vnb_y11_dfl_loss 1.62027, 127.04 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.16860, 21.75 secs
# ---- Epoch 45/50
# (1) Training stage (lr = 0.000003) ...
# loss 4.97839, vnb_y11_loss 4.97839, vnb_y11_box_loss 1.66698, vnb_y11_cls_loss 1.69130, vnb_y11_dfl_loss 1.62011, 124.95 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.17411, 21.56 secs
# ---- Epoch 46/50
# (1) Training stage (lr = 0.000001) ...
# loss 4.97344, vnb_y11_loss 4.97344, vnb_y11_box_loss 1.66404, vnb_y11_cls_loss 1.68971, vnb_y11_dfl_loss 1.61969, 126.82 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.17759, 21.86 secs
# ---- Epoch 47/50
# (1) Training stage (lr = 0.000100) ...
# ^C iteration 9225
# Engine run is terminating due to exception:
# Traceback (most recent call last):
#   File "/home/pamessina/medvqa/medvqa/notebooks/../train_visual_module.py", line 1515, in <module>
#     else:
#   File "/home/pamessina/medvqa/medvqa/notebooks/../train_visual_module.py", line 1389, in train_from_scratch
#     # question labels
#   File "/home/pamessina/medvqa/medvqa/notebooks/../train_visual_module.py", line 779, in train_model
#     # Score function
#   File "/home/pamessina/medvqa/medvqa/training/utils.py", line 137, in run_common_boilerplate_code_and_start_training
#     trainer_engine.run(train_dataloader, max_epochs=epochs, epoch_length=batches_per_epoch)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 892, in run
#     return self._internal_run()
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 935, in _internal_run
#     return next(self._internal_run_generator)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 993, in _internal_run_as_gen
#     self._handle_exception(e)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 638, in _handle_exception
#     raise e
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 959, in _internal_run_as_gen
#     epoch_time_taken += yield from self._run_once_on_dataset_as_gen()
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 1032, in _run_once_on_dataset_as_gen
#     self.state.batch = next(self._dataloader_iter)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 631, in __next__
#     data = self._next_data()
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1329, in _next_data
#     idx, data = self._get_data()
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1285, in _get_data
#     success, data = self._try_get_data()
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1133, in _try_get_data
#     data = self._data_queue.get(timeout=timeout)
#   File "/usr/lib/python3.10/queue.py", line 180, in get
#     self.not_empty.wait(remaining)
#   File "/usr/lib/python3.10/threading.py", line 324, in wait
#     gotit = waiter.acquire(True, timeout)
# KeyboardInterrupt
