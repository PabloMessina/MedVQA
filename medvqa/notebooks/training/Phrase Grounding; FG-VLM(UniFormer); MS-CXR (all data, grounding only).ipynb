# %%
# %env CUDA_VISIBLE_DEVICES=1
# Out:
# env: CUDA_VISIBLE_DEVICES=1

# %%
# !python ../train_phrase_grounding.py \
--pretrained_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250323_172425_mim-facts+mscxr+vinbig_PhraseGrounder(aehrc-cxrmate-rrg24-uniformer,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)" \
--epochs 100 \
--batches_per_epoch 200 \
--max_images_per_batch 11 \
--max_phrases_per_batch 1000 \
--max_phrases_per_image 40 \
--val_batch_size_factor 2.0 \
--raw_image_encoding "cxrmate-rrg24-uniformer-huggingface" \
--huggingface_model_name "aehrc/cxrmate-rrg24" \
--image_size 384 384 \
--image_local_feat_size 512 \
--num_regions 144 \
--regions_width 12 \
--regions_height 12 \
--img_aug_mode "random-color-and-spatial" \
--phrase_embedding_size 128 \
--phrase_grounding_mode "adaptive_film_based_pooling_mlp_with_bbox_regression" \
--phrase_mlp_hidden_dims 256 128 \
--visual_grounding_hidden_size 256 \
--bbox_format "cxcywh" \
--predict_relative_bbox_coords \
--num_train_workers 2 \
--num_val_workers 2 \
--gradient_accumulation_steps 4 \
--optimizer_name "adamw" \
--scheduler "exp-warmup+decay+cyclicdecay" \
--lr 1e-6 \
--warmup_decay_and_cyclic_decay_args "1e-6,3,8e-5,5,3e-6,8e-5,5,3e-6" \
--binary_multilabel_classif_loss_name "focal+bce+npbbce" \
--do_visual_grounding_with_bbox_regression \
--use_mscxr_for_train \
--use_mscxr_for_val \
--mscxr_training_data_mode "all" \
--mscxr_do_grounding_only \
--mscxr_phrase2embedding_filepath \
"/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/mimiccxr/mscxr_phrase2embedding(hash=36549,2076639799495206637).pkl" \
--apply_ignore_band \
--save
# Out:
# script's arguments:
#    epochs: 100
#    batches_per_epoch: 200
#    max_images_per_batch: 11
#    max_phrases_per_batch: 1000
#    max_phrases_per_image: 40
#    val_batch_size_factor: 2.0
#    checkpoint_folder: None
#    pretrained_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250323_172425_mim-facts+mscxr+vinbig_PhraseGrounder(aehrc-cxrmate-rrg24-uniformer,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)
#    pretrained_checkpoint_folder_paths: None
#    freeze_image_encoder: False
#    raw_image_encoding: cxrmate-rrg24-uniformer-huggingface
#    huggingface_model_name: aehrc/cxrmate-rrg24
#    num_regions: 144
#    image_local_feat_size: 512
#    image_encoder_pretrained_weights_path: None
#    image_encoder_dropout_p: 0
#    yolov8_model_name_or_path: None
#    yolov8_model_alias: None
#    phrase_embedding_size: 128
#    regions_width: 12
#    regions_height: 12
#    qkv_size: None
#    phrase_grounding_mode: adaptive_film_based_pooling_mlp_with_bbox_regression
#    phrase_classifier_hidden_size: None
#    transf_d_model: None
#    transf_nhead: None
#    transf_dim_feedforward: None
#    transf_dropout: 0
#    transf_num_layers: None
#    visual_feature_proj_size: None
#    visual_grounding_hidden_size: 256
#    phrase_mlp_hidden_dims: [256, 128]
#    predict_global_alignment: False
#    alignment_proj_size: None
#    yolov11_model_name_or_path: None
#    yolov11_model_alias: None
#    bbox_format: cxcywh
#    predict_relative_bbox_coords: True
#    optimizer_name: adamw
#    lr: 1e-06
#    scheduler: exp-warmup+decay+cyclicdecay
#    lr_decay: 0.76
#    lr_decay_patience: 2
#    warmup_and_decay_args: None
#    warmup_and_cosine_args: None
#    warmup_decay_and_cyclic_decay_args: 1e-6,3,8e-5,5,3e-6,8e-5,5,3e-6
#    gradient_accumulation_steps: 4
#    override_lr: False
#    max_grad_norm: None
#    attention_supervision_loss_weight: 1.0
#    phrase_classifier_loss_weight: 1.0
#    foreground_loss_weight: 1.0
#    background_loss_weight: 1.0
#    focal_loss_weight: 1.0
#    bce_loss_weight: 1.0
#    wbce_loss_weight: 1.0
#    binary_multilabel_classif_loss_name: focal+bce+npbbce
#    use_weighted_phrase_classifier_loss: False
#    cluster_and_label_weights_for_facts_filepath: None
#    use_attention_regularization_loss: False
#    use_contrastive_phrase_grounding_loss: False
#    nt_xent_temperature: 0.1
#    apply_ignore_band: True
#    num_train_workers: 2
#    num_val_workers: 2
#    device: GPU
#    use_amp: False
#    image_size: [384, 384]
#    dicom_id_to_pos_neg_facts_filepath: None
#    iuxray_image_id_to_pos_neg_facts_filepath: None
#    mscxr_phrase2embedding_filepath: /mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/mimiccxr/mscxr_phrase2embedding(hash=36549,2076639799495206637).pkl
#    chest_imagenome_bbox_phrase_embeddings_filepath: None
#    vinbig_phrase_embeddings_filepath: None
#    chexlocalize_class_phrase_embeddings_filepath: None
#    chexpert_class_phrase_embeddings_filepath: None
#    mimiccxr_exclude_noisy_images: False
#    mimiccxr_facts_weight: 1.0
#    chest_imagenome_anatlocs_weight: 1.0
#    mscxr_weight: 1.0
#    cxrlt2024_weight: 1.0
#    vinbig_weight: 1.0
#    chexlocalize_weight: 1.0
#    chexpert_weight: 1.0
#    iuxray_weight: 1.0
#    img_aug_mode: random-color-and-spatial
#    pos_area_prior: 0.4
#    neg_area_prior: 0.0
#    use_mimiccxr_facts_for_train: False
#    use_mimiccxr_facts_for_test: False
#    use_mscxr_for_train: True
#    use_mscxr_for_val: True
#    use_chest_imagenome_for_train: False
#    use_chest_imagenome_gold_for_test: False
#    use_vinbig_for_train: False
#    use_vinbig_for_test: False
#    use_chexlocalize_for_train: False
#    use_chexlocalize_for_test: False
#    use_chexpert_for_train: False
#    use_chexpert_for_test: False
#    use_iuxray_for_train: False
#    use_iuxray_for_test: False
#    use_cxrlt2024_challenge_split: False
#    use_cxrlt2024_custom_labels: False
#    use_cxrlt2024_official_labels: False
#    use_all_cxrlt2024_official_labels_for_training: False
#    vinbig_training_data_mode: train
#    chexpert_training_data_mode: all
#    mimiccxr_balance_long_middle_short_tail: False
#    mimiccxr_long_middle_short_tail_thresholds: (0.02, 0.05)
#    mimiccxr_report_fact_nli_integrated_data_filepath: None
#    mimiccxr_use_interpret_cxr_challenge_split: False
#    mimiccxr_interpret_cxr_challenge_split_filepath: None
#    iuxray_use_interpret_cxr_challenge_split: False
#    iuxray_interpret_cxr_challenge_split_filepath: None
#    chexpert_use_interpret_cxr_challenge_split: False
#    chexpert_interpret_cxr_challenge_split_filepath: None
#    chexlocalize_use_interpret_cxr_challenge_split: False
#    chexlocalize_interpret_cxr_challenge_split_filepath: None
#    cxrlt2024_custom_dicom_id_to_pos_neg_facts_filepath: None
#    cxrlt2024_official_training_labels_for_fact_classification_filepath: None
#    cxrlt2024_do_balanced_sampling: False
#    do_visual_grounding_with_bbox_regression: True
#    do_visual_grounding_with_segmentation: False
#    replace_phrase_embeddings_with_random_vectors: False
#    use_vinbig_with_modified_labels: False
#    mscxr_training_data_mode: all
#    mscxr_do_grounding_only: True
#    save: True
#    override_metric_weights: None
# ----- Training model from scratch ------
# include_loss_weights = False
# source_image_size_mode: medium_512
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Creating instance of PhraseGrounder ...
# WARNING: Unused kwargs: {'pretrained_checkpoint_folder_path': '/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250323_172425_mim-facts+mscxr+vinbig_PhraseGrounder(aehrc-cxrmate-rrg24-uniformer,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)', 'pretrained_checkpoint_folder_paths': None}
# MultiPurposeVisualModule()
#   Initializing raw_image_encoder: cxrmate-rrg24-uniformer-huggingface
#   self.global_feat_size = 1024
#   self.local_feat_size = 512
#   Initializing auxiliary tasks
# MultiClassBoundingBoxRegressor
#   local_feat_dim: 256
#   bbox_format: cxcywh
#   predict_relative: True
# --------------------------------------------------
# 3) Defining optimizer ...
# create_optimizer(): name = adamw
# --------------------------------------------------
# 4) Defining scheduler ...
# Using exp-warmup+decay+cyclicdecay scheduler: 1e-6,3,8e-5,5,3e-6,8e-5,5,3e-6
# 1e-06 3 8e-05 5 3e-06 8e-05 5 3e-06
# self.steps_to_restart = 5
# self.steps = -1
# self.initial_lr = 8e-05
# --------------------------------------------------
# 5) Creating trainer and validator engines ...
# Focal_BCE_NPBBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 npbbce_weight = 0.3333333333333333
# Focal_BCE_NPBBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 npbbce_weight = 0.3333333333333333
# Focal_BCE_WBCBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 wbcbce_weight = 0.3333333333333333
# foreground_loss_weight: 1.0
# background_loss_weight: 1.0
# GradientAccumulator.__init__(): num_accumulation_steps = 4, max_grad_norm = None
# Focal_BCE_NPBBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 npbbce_weight = 0.3333333333333333
# Focal_BCE_NPBBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 npbbce_weight = 0.3333333333333333
# Focal_BCE_WBCBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 wbcbce_weight = 0.3333333333333333
# foreground_loss_weight: 1.0
# background_loss_weight: 1.0
# --------------------------------------------------
# 6) Creating MIMIC-CXR Phrase Grounding Trainer ...
# get_image_transform()
#   image_size = [384, 384]
#   mean = [0.485, 0.456, 0.406]
#   std = [0.229, 0.224, 0.225]
#   Using bounding box aware transforms
#     augmentation_mode = random-color-and-spatial
#     default_prob = 0.35
#     returning transform (not for vinbig)
# get_train_transform(): Using bbox-aware transforms for VinBigData
# get_train_transform(): Using normal transforms
#     Returning augmented transform with mode random-color-and-spatial
# get_image_transform()
#   image_size = [384, 384]
#   mean = [0.485, 0.456, 0.406]
#   std = [0.229, 0.224, 0.225]
#   Using bounding box aware transforms
#     Returning default transform (no augmentation)
# Warning: unused kwargs in MIMICCXR_VisualModuleTrainer: {'use_yolov8': False}
# len(forbidden_train_dicom_ids) = 310
# Preparing MS-CXR dataset and dataloaders for train, val (grounding only) ...
# len(dicom_id_2_phrases_and_bboxes) = 1047
# len(phrase2embedding) = 715
# phrase_embeddings.shape = (715, 128)
# Using image size mode: medium_512
# 227835it [00:00, 473386.04it/s]
# Total number of instances: 1160
# len(train_indices) = 815
# Building train fact dataloader...
# batch_size = 11
# len(self.mscxr_train_dataset) = 1160
# len(self.mscxr_train_dataloader) = 106
# len(val_indices) = 169
# Building val fact dataloader...
# batch_size = 22
# len(self.mscxr_val_dataset) = 169
# len(self.mscxr_val_dataloader) = 8
# --------------------------------------------------
# 7) Creating dataloaders ...
# len(mimiccxr_trainer.mscxr_dataloader) = 106
# len(mimiccxr_trainer.mscxr_val_dataloader) = 8
# len(_train_dataloaders) = 1
# len(_val_dataloaders) = 1
# _train_weights = [1.0]
# merged_dataset_name = mscxr
# --------------------------------------------------
# 8) Attaching metrics, losses, timer and events to engines ...
# --------------------------------------------------
# 9) Defining learning rate scheduler handler ...
# --------------------------------------------------
# 10) Defining checkpoint folder path ...
# checkpoint_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250401_191427_mscxr_PhraseGrounder(aehrc-cxrmate-rrg24-uniformer,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)
# metadata saved to /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250401_191427_mscxr_PhraseGrounder(aehrc-cxrmate-rrg24-uniformer,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/metadata.json
# --------------------------------------------------
# 11) Loading pretrained weights ...
# checkpoint_names = ['checkpoint_147_miss+miuc+msss+msou+msuc+msss+vbss+vbuc+vbss=0.5432.pt']
# pretrained_checkpoint_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250323_172425_mim-facts+mscxr+vinbig_PhraseGrounder(aehrc-cxrmate-rrg24-uniformer,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/checkpoint_147_miss+miuc+msss+msou+msuc+msss+vbss+vbuc+vbss=0.5432.pt
# Checkpoint successfully loaded!
# --------------------------------------------------
# 12) Defining log_metrics_handler ...
# MetricsLogger :: we'll be logging to /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250401_191427_mscxr_PhraseGrounder(aehrc-cxrmate-rrg24-uniformer,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/metrics_logs.csv
# --------------------------------------------------
# 13) Running trainer engine ...
# ---- Epoch 1/100
# (1) Training stage (lr = 0.000001) ...
# grid_centers_cache: torch.Size([144, 2])
# loss 1.00878, mscxr_att_sup_loss 0.70202, mscxr_vgbbox_loss 0.30676, 92.15 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.04109, 3.35 secs
# Train metrics:
# mscxr_att_sup_loss: 0.5875, weight = 1.0
# mscxr_vgbbox_loss: 0.7652, weight = 1.0
# num = 1.3528, den = 2.0000, score = 0.6764
# Val metrics:
# mscxr_bbox_iou: 0.0411, weight = 1.0
# num = 0.0411, den = 1.0000, score = 0.0411
# Train score = 0.6764, Val score = 0.0411, Final score = 0.0729
# w_train = 0.05, w_val = 0.95
# New checkpoint saved: checkpoint_1_msss+msou+msss=0.0729.pt
# ---- Epoch 2/100
# (1) Training stage (lr = 0.000004) ...
# loss 0.87815, mscxr_att_sup_loss 0.62896, mscxr_vgbbox_loss 0.24919, 96.61 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.05362, 3.13 secs
# New checkpoint saved: checkpoint_2_msss+msou+msss=0.0863.pt
# ---- Epoch 3/100
# (1) Training stage (lr = 0.000019) ...
# loss 0.60658, mscxr_att_sup_loss 0.49030, mscxr_vgbbox_loss 0.11628, 94.72 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.20306, 3.15 secs
# New checkpoint saved: checkpoint_3_msss+msou+msss=0.2321.pt
# ---- Epoch 4/100
# (1) Training stage (lr = 0.000080) ...
# loss 0.39212, mscxr_att_sup_loss 0.35117, mscxr_vgbbox_loss 0.04095, 95.85 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.29423, 3.20 secs
# New checkpoint saved: checkpoint_4_msss+msou+msss=0.3220.pt
# ---- Epoch 5/100
# (1) Training stage (lr = 0.000041) ...
# loss 0.31596, mscxr_att_sup_loss 0.28791, mscxr_vgbbox_loss 0.02805, 96.42 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.34150, 3.18 secs
# New checkpoint saved: checkpoint_5_msss+msou+msss=0.3682.pt
# ---- Epoch 6/100
# (1) Training stage (lr = 0.000022) ...
# loss 0.28199, mscxr_att_sup_loss 0.25671, mscxr_vgbbox_loss 0.02529, 95.61 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.35765, 3.16 secs
# New checkpoint saved: checkpoint_6_msss+msou+msss=0.3840.pt
# ---- Epoch 7/100
# (1) Training stage (lr = 0.000011) ...
# loss 0.27445, mscxr_att_sup_loss 0.24975, mscxr_vgbbox_loss 0.02470, 93.94 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.36611, 3.15 secs
# New checkpoint saved: checkpoint_7_msss+msou+msss=0.3922.pt
# ---- Epoch 8/100
# (1) Training stage (lr = 0.000006) ...
# loss 0.26952, mscxr_att_sup_loss 0.24610, mscxr_vgbbox_loss 0.02343, 93.20 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.37110, 3.21 secs
# New checkpoint saved: checkpoint_8_msss+msou+msss=0.3970.pt
# ---- Epoch 9/100
# (1) Training stage (lr = 0.000003) ...
# loss 0.26671, mscxr_att_sup_loss 0.24287, mscxr_vgbbox_loss 0.02384, 94.72 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.37495, 3.19 secs
# New checkpoint saved: checkpoint_9_msss+msou+msss=0.4007.pt
# ---- Epoch 10/100
# (1) Training stage (lr = 0.000080) ...
# loss 0.25538, mscxr_att_sup_loss 0.23303, mscxr_vgbbox_loss 0.02235, 95.78 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.40983, 3.17 secs
# New checkpoint saved: checkpoint_10_msss+msou+msss=0.4341.pt
# ---- Epoch 11/100
# (1) Training stage (lr = 0.000035) ...
# loss 0.23571, mscxr_att_sup_loss 0.21684, mscxr_vgbbox_loss 0.01887, 95.43 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.41252, 3.16 secs
# New checkpoint saved: checkpoint_11_msss+msou+msss=0.4370.pt
# ---- Epoch 12/100
# (1) Training stage (lr = 0.000015) ...
# loss 0.21282, mscxr_att_sup_loss 0.19524, mscxr_vgbbox_loss 0.01758, 93.40 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.41967, 3.11 secs
# New checkpoint saved: checkpoint_12_msss+msou+msss=0.4442.pt
# ---- Epoch 13/100
# (1) Training stage (lr = 0.000007) ...
# loss 0.21419, mscxr_att_sup_loss 0.19673, mscxr_vgbbox_loss 0.01746, 92.78 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.42794, 3.08 secs
# New checkpoint saved: checkpoint_13_msss+msou+msss=0.4520.pt
# ---- Epoch 14/100
# (1) Training stage (lr = 0.000003) ...
# loss 0.20621, mscxr_att_sup_loss 0.18922, mscxr_vgbbox_loss 0.01699, 93.59 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.43101, 3.19 secs
# New checkpoint saved: checkpoint_14_msss+msou+msss=0.4551.pt
# ---- Epoch 15/100
# (1) Training stage (lr = 0.000080) ...
# loss 0.20711, mscxr_att_sup_loss 0.19038, mscxr_vgbbox_loss 0.01673, 94.56 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.44993, 3.16 secs
# New checkpoint saved: checkpoint_15_msss+msou+msss=0.4730.pt
# ---- Epoch 16/100
# (1) Training stage (lr = 0.000035) ...
# loss 0.18793, mscxr_att_sup_loss 0.17293, mscxr_vgbbox_loss 0.01500, 93.78 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.44974, 3.13 secs
# New checkpoint saved: checkpoint_16_msss+msou+msss=0.4732.pt
# ---- Epoch 17/100
# (1) Training stage (lr = 0.000015) ...
# loss 0.17916, mscxr_att_sup_loss 0.16470, mscxr_vgbbox_loss 0.01446, 93.96 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.45584, 3.04 secs
# New checkpoint saved: checkpoint_17_msss+msou+msss=0.4792.pt
# ---- Epoch 18/100
# (1) Training stage (lr = 0.000007) ...
# loss 0.16605, mscxr_att_sup_loss 0.15195, mscxr_vgbbox_loss 0.01410, 92.40 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.46175, 3.06 secs
# New checkpoint saved: checkpoint_18_msss+msou+msss=0.4850.pt
# ---- Epoch 19/100
# (1) Training stage (lr = 0.000003) ...
# loss 0.16810, mscxr_att_sup_loss 0.15429, mscxr_vgbbox_loss 0.01381, 92.13 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.45998, 3.06 secs
# ---- Epoch 20/100
# (1) Training stage (lr = 0.000080) ...
# loss 0.17693, mscxr_att_sup_loss 0.16308, mscxr_vgbbox_loss 0.01385, 91.55 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.47126, 3.10 secs
# New checkpoint saved: checkpoint_20_msss+msou+msss=0.4939.pt
# ---- Epoch 21/100
# (1) Training stage (lr = 0.000035) ...
# loss 0.15483, mscxr_att_sup_loss 0.14195, mscxr_vgbbox_loss 0.01288, 93.44 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.47029, 3.12 secs
# ---- Epoch 22/100
# (1) Training stage (lr = 0.000015) ...
# loss 0.15018, mscxr_att_sup_loss 0.13754, mscxr_vgbbox_loss 0.01265, 94.96 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.48268, 3.13 secs
# New checkpoint saved: checkpoint_22_msss+msou+msss=0.5052.pt
# ---- Epoch 23/100
# (1) Training stage (lr = 0.000007) ...
# loss 0.14373, mscxr_att_sup_loss 0.13150, mscxr_vgbbox_loss 0.01224, 93.92 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.47474, 3.12 secs
# ---- Epoch 24/100
# (1) Training stage (lr = 0.000003) ...
# loss 0.14181, mscxr_att_sup_loss 0.12960, mscxr_vgbbox_loss 0.01221, 93.65 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.47821, 3.10 secs
# ---- Epoch 25/100
# (1) Training stage (lr = 0.000080) ...
# loss 0.14774, mscxr_att_sup_loss 0.13575, mscxr_vgbbox_loss 0.01200, 93.44 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.47951, 3.08 secs
# ---- Epoch 26/100
# (1) Training stage (lr = 0.000035) ...
# loss 0.13937, mscxr_att_sup_loss 0.12791, mscxr_vgbbox_loss 0.01146, 93.61 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.49702, 3.02 secs
# New checkpoint saved: checkpoint_26_msss+msou+msss=0.5191.pt
# ---- Epoch 27/100
# (1) Training stage (lr = 0.000015) ...
# loss 0.12388, mscxr_att_sup_loss 0.11326, mscxr_vgbbox_loss 0.01061, 94.90 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.50641, 3.15 secs
# New checkpoint saved: checkpoint_27_msss+msou+msss=0.5283.pt
# ---- Epoch 28/100
# (1) Training stage (lr = 0.000007) ...
# loss 0.12675, mscxr_att_sup_loss 0.11608, mscxr_vgbbox_loss 0.01067, 95.06 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.50849, 3.09 secs
# New checkpoint saved: checkpoint_28_msss+msou+msss=0.5302.pt
# ---- Epoch 29/100
# (1) Training stage (lr = 0.000003) ...
# loss 0.12084, mscxr_att_sup_loss 0.11001, mscxr_vgbbox_loss 0.01083, 95.09 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.50766, 3.15 secs
# ---- Epoch 30/100
# (1) Training stage (lr = 0.000080) ...
# loss 0.12929, mscxr_att_sup_loss 0.11837, mscxr_vgbbox_loss 0.01092, 93.89 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.51196, 3.02 secs
# New checkpoint saved: checkpoint_30_msss+msou+msss=0.5334.pt
# ---- Epoch 31/100
# (1) Training stage (lr = 0.000035) ...
# loss 0.11646, mscxr_att_sup_loss 0.10626, mscxr_vgbbox_loss 0.01021, 93.32 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.51507, 3.13 secs
# New checkpoint saved: checkpoint_31_msss+msou+msss=0.5367.pt
# ---- Epoch 32/100
# (1) Training stage (lr = 0.000015) ...
# loss 0.11024, mscxr_att_sup_loss 0.09999, mscxr_vgbbox_loss 0.01025, 94.78 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.51832, 3.06 secs
# New checkpoint saved: checkpoint_32_msss+msou+msss=0.5399.pt
# ---- Epoch 33/100
# (1) Training stage (lr = 0.000007) ...
# loss 0.11083, mscxr_att_sup_loss 0.10099, mscxr_vgbbox_loss 0.00984, 95.16 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.51361, 3.16 secs
# ---- Epoch 34/100
# (1) Training stage (lr = 0.000003) ...
# loss 0.10579, mscxr_att_sup_loss 0.09633, mscxr_vgbbox_loss 0.00947, 94.47 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.51815, 3.08 secs
# ---- Epoch 35/100
# (1) Training stage (lr = 0.000080) ...
# loss 0.11044, mscxr_att_sup_loss 0.10046, mscxr_vgbbox_loss 0.00998, 93.63 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.51966, 2.99 secs
# New checkpoint saved: checkpoint_35_msss+msou+msss=0.5411.pt
# ---- Epoch 36/100
# (1) Training stage (lr = 0.000035) ...
# loss 0.10523, mscxr_att_sup_loss 0.09589, mscxr_vgbbox_loss 0.00934, 92.48 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.51965, 3.12 secs
# New checkpoint saved: checkpoint_36_msss+msou+msss=0.5412.pt
# ---- Epoch 37/100
# (1) Training stage (lr = 0.000015) ...
# loss 0.10807, mscxr_att_sup_loss 0.09845, mscxr_vgbbox_loss 0.00963, 93.01 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.52914, 3.06 secs
# New checkpoint saved: checkpoint_37_msss+msou+msss=0.5502.pt
# ---- Epoch 38/100
# (1) Training stage (lr = 0.000007) ...
# loss 0.09692, mscxr_att_sup_loss 0.08794, mscxr_vgbbox_loss 0.00898, 93.08 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.53289, 3.10 secs
# New checkpoint saved: checkpoint_38_msss+msou+msss=0.5540.pt
# ---- Epoch 39/100
# (1) Training stage (lr = 0.000003) ...
# loss 0.09535, mscxr_att_sup_loss 0.08625, mscxr_vgbbox_loss 0.00909, 88.87 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.53279, 3.04 secs
# ---- Epoch 40/100
# (1) Training stage (lr = 0.000080) ...
# loss 0.10305, mscxr_att_sup_loss 0.09372, mscxr_vgbbox_loss 0.00933, 89.33 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.55114, 3.07 secs
# New checkpoint saved: checkpoint_40_msss+msou+msss=0.5712.pt
# ---- Epoch 41/100
# (1) Training stage (lr = 0.000035) ...
# loss 0.10339, mscxr_att_sup_loss 0.09421, mscxr_vgbbox_loss 0.00918, 93.14 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.54920, 3.06 secs
# ---- Epoch 42/100
# (1) Training stage (lr = 0.000015) ...
# loss 0.09158, mscxr_att_sup_loss 0.08306, mscxr_vgbbox_loss 0.00853, 92.86 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.54828, 3.04 secs
# ---- Epoch 43/100
# (1) Training stage (lr = 0.000007) ...
# loss 0.08662, mscxr_att_sup_loss 0.07831, mscxr_vgbbox_loss 0.00830, 92.68 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.55616, 3.06 secs
# New checkpoint saved: checkpoint_43_msss+msou+msss=0.5763.pt
# ---- Epoch 44/100
# (1) Training stage (lr = 0.000003) ...
# loss 0.08599, mscxr_att_sup_loss 0.07768, mscxr_vgbbox_loss 0.00832, 93.58 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.55124, 2.98 secs
# ---- Epoch 45/100
# (1) Training stage (lr = 0.000080) ...
# loss 0.08997, mscxr_att_sup_loss 0.08123, mscxr_vgbbox_loss 0.00874, 92.45 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.55081, 3.09 secs
# ---- Epoch 46/100
# (1) Training stage (lr = 0.000035) ...
# loss 0.08053, mscxr_att_sup_loss 0.07241, mscxr_vgbbox_loss 0.00812, 93.51 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.55029, 3.07 secs
# ---- Epoch 47/100
# (1) Training stage (lr = 0.000015) ...
# loss 0.07996, mscxr_att_sup_loss 0.07210, mscxr_vgbbox_loss 0.00786, 92.82 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.56125, 3.09 secs
# New checkpoint saved: checkpoint_47_msss+msou+msss=0.5813.pt
# ---- Epoch 48/100
# (1) Training stage (lr = 0.000007) ...
# loss 0.07928, mscxr_att_sup_loss 0.07153, mscxr_vgbbox_loss 0.00775, 93.33 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.55987, 2.99 secs
# ---- Epoch 49/100
# (1) Training stage (lr = 0.000003) ...
# loss 0.07857, mscxr_att_sup_loss 0.07068, mscxr_vgbbox_loss 0.00789, 92.48 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.56080, 3.07 secs
# ---- Epoch 50/100
# (1) Training stage (lr = 0.000080) ...
# loss 0.08354, mscxr_att_sup_loss 0.07548, mscxr_vgbbox_loss 0.00806, 93.87 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.56594, 3.10 secs
# New checkpoint saved: checkpoint_50_msss+msou+msss=0.5857.pt
# ---- Epoch 51/100
# (1) Training stage (lr = 0.000035) ...
# loss 0.08342, mscxr_att_sup_loss 0.07559, mscxr_vgbbox_loss 0.00783, 93.10 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.55649, 3.08 secs
# ---- Epoch 52/100
# (1) Training stage (lr = 0.000015) ...
# loss 0.07464, mscxr_att_sup_loss 0.06722, mscxr_vgbbox_loss 0.00742, 92.84 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.56957, 3.11 secs
# New checkpoint saved: checkpoint_52_msss+msou+msss=0.5893.pt
# ---- Epoch 53/100
# (1) Training stage (lr = 0.000007) ...
# loss 0.07295, mscxr_att_sup_loss 0.06539, mscxr_vgbbox_loss 0.00756, 91.13 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.57030, 3.10 secs
# New checkpoint saved: checkpoint_53_msss+msou+msss=0.5901.pt
# ---- Epoch 54/100
# (1) Training stage (lr = 0.000003) ...
# loss 0.07286, mscxr_att_sup_loss 0.06531, mscxr_vgbbox_loss 0.00755, 92.88 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.56500, 3.01 secs
# ---- Epoch 55/100
# (1) Training stage (lr = 0.000080) ...
# loss 0.07653, mscxr_att_sup_loss 0.06890, mscxr_vgbbox_loss 0.00763, 93.42 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.57934, 3.08 secs
# New checkpoint saved: checkpoint_55_msss+msou+msss=0.5986.pt
# ---- Epoch 56/100
# (1) Training stage (lr = 0.000035) ...
# loss 0.07634, mscxr_att_sup_loss 0.06908, mscxr_vgbbox_loss 0.00726, 95.23 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.58179, 3.08 secs
# New checkpoint saved: checkpoint_56_msss+msou+msss=0.6009.pt
# ---- Epoch 57/100
# (1) Training stage (lr = 0.000015) ...
# loss 0.06824, mscxr_att_sup_loss 0.06093, mscxr_vgbbox_loss 0.00731, 95.28 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.58015, 3.11 secs
# ---- Epoch 58/100
# (1) Training stage (lr = 0.000007) ...
# loss 0.06472, mscxr_att_sup_loss 0.05784, mscxr_vgbbox_loss 0.00688, 94.27 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.58727, 3.10 secs
# New checkpoint saved: checkpoint_58_msss+msou+msss=0.6064.pt
# ---- Epoch 59/100
# (1) Training stage (lr = 0.000003) ...
# loss 0.06816, mscxr_att_sup_loss 0.06093, mscxr_vgbbox_loss 0.00722, 93.69 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.58667, 3.02 secs
# ---- Epoch 60/100
# (1) Training stage (lr = 0.000080) ...
# loss 0.07540, mscxr_att_sup_loss 0.06773, mscxr_vgbbox_loss 0.00767, 93.55 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.59195, 3.08 secs
# New checkpoint saved: checkpoint_60_msss+msou+msss=0.6106.pt
# ---- Epoch 61/100
# (1) Training stage (lr = 0.000035) ...
# loss 0.06699, mscxr_att_sup_loss 0.06011, mscxr_vgbbox_loss 0.00688, 93.02 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.58863, 3.04 secs
# ---- Epoch 62/100
# (1) Training stage (lr = 0.000015) ...
# loss 0.06752, mscxr_att_sup_loss 0.06030, mscxr_vgbbox_loss 0.00722, 93.01 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.59501, 3.09 secs
# New checkpoint saved: checkpoint_62_msss+msou+msss=0.6137.pt
# ---- Epoch 63/100
# (1) Training stage (lr = 0.000007) ...
# loss 0.06072, mscxr_att_sup_loss 0.05391, mscxr_vgbbox_loss 0.00681, 94.12 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.59923, 3.06 secs
# New checkpoint saved: checkpoint_63_msss+msou+msss=0.6178.pt
# ---- Epoch 64/100
# (1) Training stage (lr = 0.000003) ...
# loss 0.05827, mscxr_att_sup_loss 0.05158, mscxr_vgbbox_loss 0.00669, 93.57 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.59236, 3.01 secs
# ---- Epoch 65/100
# (1) Training stage (lr = 0.000080) ...
# loss 0.06214, mscxr_att_sup_loss 0.05531, mscxr_vgbbox_loss 0.00683, 92.66 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.59192, 3.10 secs
# ---- Epoch 66/100
# (1) Training stage (lr = 0.000035) ...
# loss 0.06445, mscxr_att_sup_loss 0.05753, mscxr_vgbbox_loss 0.00692, 93.27 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.61201, 3.11 secs
# New checkpoint saved: checkpoint_66_msss+msou+msss=0.6299.pt
# ---- Epoch 67/100
# (1) Training stage (lr = 0.000015) ...
# loss 0.06075, mscxr_att_sup_loss 0.05417, mscxr_vgbbox_loss 0.00657, 93.10 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.60042, 3.08 secs
# ---- Epoch 68/100
# (1) Training stage (lr = 0.000007) ...
# loss 0.05969, mscxr_att_sup_loss 0.05321, mscxr_vgbbox_loss 0.00647, 94.59 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.60127, 3.10 secs
# ---- Epoch 69/100
# (1) Training stage (lr = 0.000003) ...
# loss 0.05337, mscxr_att_sup_loss 0.04699, mscxr_vgbbox_loss 0.00639, 93.74 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.60078, 3.05 secs
# ---- Epoch 70/100
# (1) Training stage (lr = 0.000080) ...
# loss 0.06667, mscxr_att_sup_loss 0.05975, mscxr_vgbbox_loss 0.00692, 92.59 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.60947, 3.04 secs
# ---- Epoch 71/100
# (1) Training stage (lr = 0.000035) ...
# loss 0.05778, mscxr_att_sup_loss 0.05120, mscxr_vgbbox_loss 0.00658, 92.93 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.60897, 3.12 secs
# ---- Epoch 72/100
# (1) Training stage (lr = 0.000015) ...
# loss 0.05765, mscxr_att_sup_loss 0.05136, mscxr_vgbbox_loss 0.00629, 93.93 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.61082, 3.13 secs
# ---- Epoch 73/100
# (1) Training stage (lr = 0.000007) ...
# loss 0.05564, mscxr_att_sup_loss 0.04909, mscxr_vgbbox_loss 0.00655, 93.90 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.61074, 3.12 secs
# ---- Epoch 74/100
# (1) Training stage (lr = 0.000003) ...
# loss 0.05504, mscxr_att_sup_loss 0.04870, mscxr_vgbbox_loss 0.00634, 93.70 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.61172, 3.00 secs
# ---- Epoch 75/100
# (1) Training stage (lr = 0.000080) ...
# loss 0.05722, mscxr_att_sup_loss 0.05093, mscxr_vgbbox_loss 0.00629, 92.84 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.61210, 3.10 secs
# New checkpoint saved: checkpoint_75_msss+msou+msss=0.6301.pt
# ---- Epoch 76/100
# (1) Training stage (lr = 0.000035) ...
# loss 0.05819, mscxr_att_sup_loss 0.05166, mscxr_vgbbox_loss 0.00652, 92.01 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.59845, 3.06 secs
# ---- Epoch 77/100
# (1) Training stage (lr = 0.000015) ...
# loss 0.05490, mscxr_att_sup_loss 0.04856, mscxr_vgbbox_loss 0.00634, 93.23 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.60904, 3.13 secs
# ---- Epoch 78/100
# (1) Training stage (lr = 0.000007) ...
# loss 0.05242, mscxr_att_sup_loss 0.04645, mscxr_vgbbox_loss 0.00597, 93.78 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.62465, 3.09 secs
# New checkpoint saved: checkpoint_78_msss+msou+msss=0.6422.pt
# ---- Epoch 79/100
# (1) Training stage (lr = 0.000003) ...
# loss 0.05049, mscxr_att_sup_loss 0.04418, mscxr_vgbbox_loss 0.00632, 92.90 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.61756, 3.02 secs
# ---- Epoch 80/100
# (1) Training stage (lr = 0.000080) ...
# loss 0.05724, mscxr_att_sup_loss 0.05058, mscxr_vgbbox_loss 0.00666, 93.22 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.57715, 3.06 secs
# ---- Epoch 81/100
# (1) Training stage (lr = 0.000035) ...
# loss 0.05435, mscxr_att_sup_loss 0.04827, mscxr_vgbbox_loss 0.00608, 92.64 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.62525, 3.05 secs
# New checkpoint saved: checkpoint_81_msss+msou+msss=0.6427.pt
# ---- Epoch 82/100
# (1) Training stage (lr = 0.000015) ...
# loss 0.05146, mscxr_att_sup_loss 0.04542, mscxr_vgbbox_loss 0.00604, 92.41 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.63164, 3.04 secs
# New checkpoint saved: checkpoint_82_msss+msou+msss=0.6488.pt
# ---- Epoch 83/100
# (1) Training stage (lr = 0.000007) ...
# loss 0.05015, mscxr_att_sup_loss 0.04420, mscxr_vgbbox_loss 0.00595, 93.87 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.62757, 3.11 secs
# ---- Epoch 84/100
# (1) Training stage (lr = 0.000003) ...
# loss 0.04558, mscxr_att_sup_loss 0.03999, mscxr_vgbbox_loss 0.00559, 93.18 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.63210, 3.07 secs
# New checkpoint saved: checkpoint_84_msss+msou+msss=0.6494.pt
# ---- Epoch 85/100
# (1) Training stage (lr = 0.000080) ...
# loss 0.05076, mscxr_att_sup_loss 0.04474, mscxr_vgbbox_loss 0.00603, 93.88 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.60461, 3.00 secs
# ---- Epoch 86/100
# (1) Training stage (lr = 0.000035) ...
# loss 0.05391, mscxr_att_sup_loss 0.04778, mscxr_vgbbox_loss 0.00613, 93.46 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.62403, 3.09 secs
# ---- Epoch 87/100
# (1) Training stage (lr = 0.000015) ...
# loss 0.05069, mscxr_att_sup_loss 0.04479, mscxr_vgbbox_loss 0.00590, 91.45 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.62206, 3.04 secs
# ---- Epoch 88/100
# (1) Training stage (lr = 0.000007) ...
# loss 0.04762, mscxr_att_sup_loss 0.04168, mscxr_vgbbox_loss 0.00595, 91.93 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.62644, 3.04 secs
# ---- Epoch 89/100
# (1) Training stage (lr = 0.000003) ...
# loss 0.04214, mscxr_att_sup_loss 0.03650, mscxr_vgbbox_loss 0.00565, 91.78 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.62762, 3.04 secs
# ---- Epoch 90/100
# (1) Training stage (lr = 0.000080) ...
# loss 0.05272, mscxr_att_sup_loss 0.04676, mscxr_vgbbox_loss 0.00596, 93.07 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.62990, 3.08 secs
# ---- Epoch 91/100
# (1) Training stage (lr = 0.000035) ...
# loss 0.04835, mscxr_att_sup_loss 0.04274, mscxr_vgbbox_loss 0.00561, 93.27 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.62916, 3.00 secs
# ---- Epoch 92/100
# (1) Training stage (lr = 0.000015) ...
# loss 0.04694, mscxr_att_sup_loss 0.04144, mscxr_vgbbox_loss 0.00550, 92.58 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.63433, 3.01 secs
# New checkpoint saved: checkpoint_92_msss+msou+msss=0.6515.pt
# ---- Epoch 93/100
# (1) Training stage (lr = 0.000007) ...
# loss 0.04239, mscxr_att_sup_loss 0.03711, mscxr_vgbbox_loss 0.00528, 92.08 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.64262, 3.10 secs
# New checkpoint saved: checkpoint_93_msss+msou+msss=0.6595.pt
# ---- Epoch 94/100
# (1) Training stage (lr = 0.000003) ...
# loss 0.04105, mscxr_att_sup_loss 0.03567, mscxr_vgbbox_loss 0.00538, 92.61 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.64043, 3.09 secs
# ---- Epoch 95/100
# (1) Training stage (lr = 0.000080) ...
# loss 0.04738, mscxr_att_sup_loss 0.04180, mscxr_vgbbox_loss 0.00558, 95.19 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.63311, 3.13 secs
# ---- Epoch 96/100
# (1) Training stage (lr = 0.000035) ...
# loss 0.04720, mscxr_att_sup_loss 0.04145, mscxr_vgbbox_loss 0.00574, 94.78 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.64759, 3.07 secs
# New checkpoint saved: checkpoint_96_msss+msou+msss=0.6641.pt
# ---- Epoch 97/100
# (1) Training stage (lr = 0.000015) ...
# loss 0.04102, mscxr_att_sup_loss 0.03573, mscxr_vgbbox_loss 0.00529, 91.39 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.64748, 3.03 secs
# New checkpoint saved: checkpoint_97_msss+msou+msss=0.6641.pt
# ---- Epoch 98/100
# (1) Training stage (lr = 0.000007) ...
# loss 0.04161, mscxr_att_sup_loss 0.03639, mscxr_vgbbox_loss 0.00521, 93.29 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.64288, 3.12 secs
# ---- Epoch 99/100
# (1) Training stage (lr = 0.000003) ...
# loss 0.03901, mscxr_att_sup_loss 0.03391, mscxr_vgbbox_loss 0.00510, 92.55 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.65066, 3.08 secs
# New checkpoint saved: checkpoint_99_msss+msou+msss=0.6672.pt
# ---- Epoch 100/100
# (1) Training stage (lr = 0.000080) ...
# ^C
# Engine run is terminating due to exception:
# Traceback (most recent call last):
#   File "/home/pamessina/medvqa/medvqa/notebooks/../train_phrase_grounding.py", line 1614, in <module>
#     train_from_scratch(**args)
#   File "/home/pamessina/medvqa/medvqa/notebooks/../train_phrase_grounding.py", line 1477, in train_from_scratch
#     return train_model(
#   File "/home/pamessina/medvqa/medvqa/notebooks/../train_phrase_grounding.py", line 957, in train_model
#     run_common_boilerplate_code_and_start_training(
#   File "/home/pamessina/medvqa/medvqa/training/utils.py", line 142, in run_common_boilerplate_code_and_start_training
#     trainer_engine.run(train_dataloader, max_epochs=epochs, epoch_length=batches_per_epoch)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 892, in run
#     return self._internal_run()
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 935, in _internal_run
#     return next(self._internal_run_generator)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 993, in _internal_run_as_gen
#     self._handle_exception(e)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 638, in _handle_exception
#     raise e
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 959, in _internal_run_as_gen
#     epoch_time_taken += yield from self._run_once_on_dataset_as_gen()
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 1068, in _run_once_on_dataset_as_gen
#     self.state.output = self._process_function(self, self.state.batch)
#   File "/home/pamessina/medvqa/medvqa/training/phrase_grounding.py", line 1187, in step_fn
#     output = flag_to_step_fn[flag](batch)
#   File "/home/pamessina/medvqa/medvqa/training/phrase_grounding.py", line 869, in step_fn__mscxr_grounding
#     return _step_fn__mscxr_grounding_only(batch)
#   File "/home/pamessina/medvqa/medvqa/training/phrase_grounding.py", line 847, in _step_fn__mscxr_grounding_only
#     gradient_accumulator.step(batch_loss, model)
#   File "/home/pamessina/medvqa/medvqa/losses/optimizers.py", line 29, in step
#     self.scaler.scale(batch_loss).backward()
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/_tensor.py", line 525, in backward
#     torch.autograd.backward(
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/autograd/__init__.py", line 267, in backward
#     _engine_run_backward(
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/autograd/graph.py", line 744, in _engine_run_backward
#     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# KeyboardInterrupt

# %%
# !python ../train_phrase_grounding.py \
--checkpoint_folder \
"models/phrase_grounding/20250401_191427_mscxr_PhraseGrounder(aehrc-cxrmate-rrg24-uniformer,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)" \
--epochs 60 \
--batches_per_epoch 200 \
--max_images_per_batch 11 \
--max_phrases_per_batch 1000 \
--max_phrases_per_image 40 \
--val_batch_size_factor 2.0 \
--raw_image_encoding "cxrmate-rrg24-uniformer-huggingface" \
--huggingface_model_name "aehrc/cxrmate-rrg24" \
--image_size 384 384 \
--image_local_feat_size 512 \
--num_regions 144 \
--regions_width 12 \
--regions_height 12 \
--img_aug_mode "random-color-and-spatial" \
--phrase_embedding_size 128 \
--phrase_grounding_mode "adaptive_film_based_pooling_mlp_with_bbox_regression" \
--phrase_mlp_hidden_dims 256 128 \
--visual_grounding_hidden_size 256 \
--bbox_format "cxcywh" \
--predict_relative_bbox_coords \
--num_train_workers 2 \
--num_val_workers 2 \
--gradient_accumulation_steps 4 \
--optimizer_name "adamw" \
--scheduler "exp-warmup+decay+cyclicdecay" \
--lr 1e-6 \
--warmup_decay_and_cyclic_decay_args "1e-6,3,8e-5,5,3e-6,8e-5,5,3e-6" \
--binary_multilabel_classif_loss_name "focal+bce+npbbce" \
--do_visual_grounding_with_bbox_regression \
--use_mscxr_for_train \
--use_mscxr_for_val \
--mscxr_training_data_mode "all" \
--mscxr_do_grounding_only \
--mscxr_phrase2embedding_filepath \
"/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/mimiccxr/mscxr_phrase2embedding(hash=36549,2076639799495206637).pkl" \
--apply_ignore_band \
--save
# Out:
# script's arguments:
#    epochs: 60
#    batches_per_epoch: 200
#    max_images_per_batch: 11
#    max_phrases_per_batch: 1000
#    max_phrases_per_image: 40
#    val_batch_size_factor: 2.0
#    checkpoint_folder: models/phrase_grounding/20250401_191427_mscxr_PhraseGrounder(aehrc-cxrmate-rrg24-uniformer,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)
#    pretrained_checkpoint_folder_path: None
#    pretrained_checkpoint_folder_paths: None
#    freeze_image_encoder: False
#    raw_image_encoding: cxrmate-rrg24-uniformer-huggingface
#    huggingface_model_name: aehrc/cxrmate-rrg24
#    num_regions: 144
#    image_local_feat_size: 512
#    image_encoder_pretrained_weights_path: None
#    image_encoder_dropout_p: 0
#    yolov8_model_name_or_path: None
#    yolov8_model_alias: None
#    phrase_embedding_size: 128
#    regions_width: 12
#    regions_height: 12
#    qkv_size: None
#    phrase_grounding_mode: adaptive_film_based_pooling_mlp_with_bbox_regression
#    phrase_classifier_hidden_size: None
#    transf_d_model: None
#    transf_nhead: None
#    transf_dim_feedforward: None
#    transf_dropout: 0
#    transf_num_layers: None
#    visual_feature_proj_size: None
#    visual_grounding_hidden_size: 256
#    phrase_mlp_hidden_dims: [256, 128]
#    predict_global_alignment: False
#    alignment_proj_size: None
#    yolov11_model_name_or_path: None
#    yolov11_model_alias: None
#    bbox_format: cxcywh
#    predict_relative_bbox_coords: True
#    optimizer_name: adamw
#    lr: 1e-06
#    scheduler: exp-warmup+decay+cyclicdecay
#    lr_decay: 0.76
#    lr_decay_patience: 2
#    warmup_and_decay_args: None
#    warmup_and_cosine_args: None
#    warmup_decay_and_cyclic_decay_args: 1e-6,3,8e-5,5,3e-6,8e-5,5,3e-6
#    gradient_accumulation_steps: 4
#    override_lr: False
#    max_grad_norm: None
#    attention_supervision_loss_weight: 1.0
#    phrase_classifier_loss_weight: 1.0
#    foreground_loss_weight: 1.0
#    background_loss_weight: 1.0
#    focal_loss_weight: 1.0
#    bce_loss_weight: 1.0
#    wbce_loss_weight: 1.0
#    binary_multilabel_classif_loss_name: focal+bce+npbbce
#    use_weighted_phrase_classifier_loss: False
#    cluster_and_label_weights_for_facts_filepath: None
#    use_attention_regularization_loss: False
#    use_contrastive_phrase_grounding_loss: False
#    nt_xent_temperature: 0.1
#    apply_ignore_band: True
#    num_train_workers: 2
#    num_val_workers: 2
#    device: GPU
#    use_amp: False
#    image_size: [384, 384]
#    dicom_id_to_pos_neg_facts_filepath: None
#    iuxray_image_id_to_pos_neg_facts_filepath: None
#    mscxr_phrase2embedding_filepath: /mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/mimiccxr/mscxr_phrase2embedding(hash=36549,2076639799495206637).pkl
#    chest_imagenome_bbox_phrase_embeddings_filepath: None
#    vinbig_phrase_embeddings_filepath: None
#    chexlocalize_class_phrase_embeddings_filepath: None
#    chexpert_class_phrase_embeddings_filepath: None
#    mimiccxr_exclude_noisy_images: False
#    mimiccxr_facts_weight: 1.0
#    chest_imagenome_anatlocs_weight: 1.0
#    mscxr_weight: 1.0
#    cxrlt2024_weight: 1.0
#    vinbig_weight: 1.0
#    chexlocalize_weight: 1.0
#    chexpert_weight: 1.0
#    iuxray_weight: 1.0
#    img_aug_mode: random-color-and-spatial
#    pos_area_prior: 0.4
#    neg_area_prior: 0.0
#    use_mimiccxr_facts_for_train: False
#    use_mimiccxr_facts_for_test: False
#    use_mscxr_for_train: True
#    use_mscxr_for_val: True
#    use_chest_imagenome_for_train: False
#    use_chest_imagenome_gold_for_test: False
#    use_vinbig_for_train: False
#    use_vinbig_for_test: False
#    use_chexlocalize_for_train: False
#    use_chexlocalize_for_test: False
#    use_chexpert_for_train: False
#    use_chexpert_for_test: False
#    use_iuxray_for_train: False
#    use_iuxray_for_test: False
#    use_cxrlt2024_challenge_split: False
#    use_cxrlt2024_custom_labels: False
#    use_cxrlt2024_official_labels: False
#    use_all_cxrlt2024_official_labels_for_training: False
#    vinbig_training_data_mode: train
#    chexpert_training_data_mode: all
#    mimiccxr_balance_long_middle_short_tail: False
#    mimiccxr_long_middle_short_tail_thresholds: (0.02, 0.05)
#    mimiccxr_report_fact_nli_integrated_data_filepath: None
#    mimiccxr_use_interpret_cxr_challenge_split: False
#    mimiccxr_interpret_cxr_challenge_split_filepath: None
#    iuxray_use_interpret_cxr_challenge_split: False
#    iuxray_interpret_cxr_challenge_split_filepath: None
#    chexpert_use_interpret_cxr_challenge_split: False
#    chexpert_interpret_cxr_challenge_split_filepath: None
#    chexlocalize_use_interpret_cxr_challenge_split: False
#    chexlocalize_interpret_cxr_challenge_split_filepath: None
#    cxrlt2024_custom_dicom_id_to_pos_neg_facts_filepath: None
#    cxrlt2024_official_training_labels_for_fact_classification_filepath: None
#    cxrlt2024_do_balanced_sampling: False
#    do_visual_grounding_with_bbox_regression: True
#    do_visual_grounding_with_segmentation: False
#    replace_phrase_embeddings_with_random_vectors: False
#    use_vinbig_with_modified_labels: False
#    mscxr_training_data_mode: all
#    mscxr_do_grounding_only: True
#    save: True
#    override_metric_weights: None
# ----- Resuming training ------
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250401_191427_mscxr_PhraseGrounder(aehrc-cxrmate-rrg24-uniformer,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/metadata.json
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Creating instance of PhraseGrounder ...
# WARNING: Unused kwargs: {'pretrained_checkpoint_folder_path': '/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250323_172425_mim-facts+mscxr+vinbig_PhraseGrounder(aehrc-cxrmate-rrg24-uniformer,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)', 'pretrained_checkpoint_folder_paths': None}
# MultiPurposeVisualModule()
#   Initializing raw_image_encoder: cxrmate-rrg24-uniformer-huggingface
#   self.global_feat_size = 1024
#   self.local_feat_size = 512
#   Initializing auxiliary tasks
# MultiClassBoundingBoxRegressor
#   local_feat_dim: 256
#   bbox_format: cxcywh
#   predict_relative: True
# --------------------------------------------------
# 3) Defining optimizer ...
# create_optimizer(): name = adamw
# --------------------------------------------------
# 4) Defining scheduler ...
# Using exp-warmup+decay+cyclicdecay scheduler: 1e-6,3,8e-5,5,3e-6,8e-5,5,3e-6
# 1e-06 3 8e-05 5 3e-06 8e-05 5 3e-06
# self.steps_to_restart = 5
# self.steps = -1
# self.initial_lr = 8e-05
# --------------------------------------------------
# 5) Creating trainer and validator engines ...
# Focal_BCE_NPBBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 npbbce_weight = 0.3333333333333333
# Focal_BCE_NPBBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 npbbce_weight = 0.3333333333333333
# Focal_BCE_WBCBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 wbcbce_weight = 0.3333333333333333
# foreground_loss_weight: 1.0
# background_loss_weight: 1.0
# GradientAccumulator.__init__(): num_accumulation_steps = 4, max_grad_norm = None
# Focal_BCE_NPBBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 npbbce_weight = 0.3333333333333333
# Focal_BCE_NPBBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 npbbce_weight = 0.3333333333333333
# Focal_BCE_WBCBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 wbcbce_weight = 0.3333333333333333
# foreground_loss_weight: 1.0
# background_loss_weight: 1.0
# --------------------------------------------------
# 6) Creating MIMIC-CXR Phrase Grounding Trainer ...
# get_image_transform()
#   image_size = [384, 384]
#   mean = [0.485, 0.456, 0.406]
#   std = [0.229, 0.224, 0.225]
#   Using bounding box aware transforms
#     augmentation_mode = random-color-and-spatial
#     default_prob = 0.35
#     returning transform (not for vinbig)
# get_train_transform(): Using bbox-aware transforms for VinBigData
# get_train_transform(): Using normal transforms
#     Returning augmented transform with mode random-color-and-spatial
# get_image_transform()
#   image_size = [384, 384]
#   mean = [0.485, 0.456, 0.406]
#   std = [0.229, 0.224, 0.225]
#   Using bounding box aware transforms
#     Returning default transform (no augmentation)
# Warning: unused kwargs in MIMICCXR_VisualModuleTrainer: {'use_yolov8': False}
# len(forbidden_train_dicom_ids) = 310
# Preparing MS-CXR dataset and dataloaders for train, val (grounding only) ...
# len(dicom_id_2_phrases_and_bboxes) = 1047
# len(phrase2embedding) = 715
# phrase_embeddings.shape = (715, 128)
# Using image size mode: medium_512
# 227835it [00:00, 474354.64it/s]
# Total number of instances: 1160
# len(train_indices) = 815
# Building train fact dataloader...
# batch_size = 11
# len(self.mscxr_train_dataset) = 1160
# len(self.mscxr_train_dataloader) = 106
# len(val_indices) = 169
# Building val fact dataloader...
# batch_size = 22
# len(self.mscxr_val_dataset) = 169
# len(self.mscxr_val_dataloader) = 8
# --------------------------------------------------
# 7) Creating dataloaders ...
# len(mimiccxr_trainer.mscxr_dataloader) = 106
# len(mimiccxr_trainer.mscxr_val_dataloader) = 8
# len(_train_dataloaders) = 1
# len(_val_dataloaders) = 1
# _train_weights = [1.0]
# merged_dataset_name = mscxr
# --------------------------------------------------
# 8) Attaching metrics, losses, timer and events to engines ...
# --------------------------------------------------
# 9) Defining learning rate scheduler handler ...
# checkpoint_names = ['checkpoint_99_msss+msou+msss=0.6672.pt', 'checkpoint_134_msss+msou+msss=0.6989.pt']
# --------------------------------------------------
# 10) Loading model from checkpoint ...
# checkpoint_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250401_191427_mscxr_PhraseGrounder(aehrc-cxrmate-rrg24-uniformer,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/checkpoint_134_msss+msou+msss=0.6989.pt
# Checkpoint successfully loaded!
# --------------------------------------------------
# 11) Defining log_metrics_handler ...
# MetricsLogger :: we'll be logging to /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250401_191427_mscxr_PhraseGrounder(aehrc-cxrmate-rrg24-uniformer,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/metrics_logs.csv
# --------------------------------------------------
# 12) Running trainer engine ...
# ---- Epoch 135/194
# (1) Training stage (lr = 0.000080) ...
# loss 0.03101, mscxr_att_sup_loss 0.02635, mscxr_vgbbox_loss 0.00466, 83.70 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.67919, 3.04 secs
# Train metrics:
# mscxr_att_sup_loss: 0.9743, weight = 1.0
# mscxr_vgbbox_loss: 0.9954, weight = 1.0
# num = 1.9697, den = 2.0000, score = 0.9848
# Val metrics:
# mscxr_bbox_iou: 0.6792, weight = 1.0
# num = 0.6792, den = 1.0000, score = 0.6792
# Train score = 0.9848, Val score = 0.6792, Final score = 0.6945
# w_train = 0.05, w_val = 0.95
# New checkpoint saved: checkpoint_135_msss+msou+msss=0.6945.pt
# ---- Epoch 136/194
# (1) Training stage (lr = 0.000035) ...
# loss 0.03219, mscxr_att_sup_loss 0.02784, mscxr_vgbbox_loss 0.00435, 90.89 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.66737, 2.82 secs
# ---- Epoch 137/194
# (1) Training stage (lr = 0.000015) ...
# loss 0.02989, mscxr_att_sup_loss 0.02557, mscxr_vgbbox_loss 0.00432, 92.53 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.67988, 2.86 secs
# New checkpoint saved: checkpoint_137_msss+msou+msss=0.6952.pt
# ---- Epoch 138/194
# (1) Training stage (lr = 0.000007) ...
# loss 0.02966, mscxr_att_sup_loss 0.02529, mscxr_vgbbox_loss 0.00438, 92.96 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.67716, 2.92 secs
# ---- Epoch 139/194
# (1) Training stage (lr = 0.000003) ...
# loss 0.02669, mscxr_att_sup_loss 0.02264, mscxr_vgbbox_loss 0.00405, 94.71 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.68377, 2.93 secs
# New checkpoint saved: checkpoint_139_msss+msou+msss=0.6989.pt
# ---- Epoch 140/194
# (1) Training stage (lr = 0.000080) ...
# loss 0.03186, mscxr_att_sup_loss 0.02744, mscxr_vgbbox_loss 0.00442, 95.02 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.66796, 2.89 secs
# ---- Epoch 141/194
# (1) Training stage (lr = 0.000035) ...
# loss 0.03363, mscxr_att_sup_loss 0.02916, mscxr_vgbbox_loss 0.00447, 94.96 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.67419, 2.89 secs
# ---- Epoch 142/194
# (1) Training stage (lr = 0.000015) ...
# loss 0.02962, mscxr_att_sup_loss 0.02549, mscxr_vgbbox_loss 0.00414, 95.45 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.68660, 3.03 secs
# New checkpoint saved: checkpoint_142_msss+msou+msss=0.7015.pt
# ---- Epoch 143/194
# (1) Training stage (lr = 0.000007) ...
# loss 0.02978, mscxr_att_sup_loss 0.02552, mscxr_vgbbox_loss 0.00426, 99.54 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.68703, 3.19 secs
# New checkpoint saved: checkpoint_143_msss+msou+msss=0.7020.pt
# ---- Epoch 144/194
# (1) Training stage (lr = 0.000003) ...
# loss 0.02755, mscxr_att_sup_loss 0.02340, mscxr_vgbbox_loss 0.00415, 97.15 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.69095, 3.18 secs
# New checkpoint saved: checkpoint_144_msss+msou+msss=0.7057.pt
# ---- Epoch 145/194
# (1) Training stage (lr = 0.000080) ...
# loss 0.03399, mscxr_att_sup_loss 0.02920, mscxr_vgbbox_loss 0.00479, 96.59 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.63468, 3.07 secs
# ---- Epoch 146/194
# (1) Training stage (lr = 0.000035) ...
# loss 0.03887, mscxr_att_sup_loss 0.03426, mscxr_vgbbox_loss 0.00461, 95.02 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.67702, 3.08 secs
# ---- Epoch 147/194
# (1) Training stage (lr = 0.000015) ...
# loss 0.02986, mscxr_att_sup_loss 0.02551, mscxr_vgbbox_loss 0.00435, 95.71 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.68807, 3.11 secs
# ---- Epoch 148/194
# (1) Training stage (lr = 0.000007) ...
# loss 0.02688, mscxr_att_sup_loss 0.02272, mscxr_vgbbox_loss 0.00417, 95.29 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.69397, 3.14 secs
# New checkpoint saved: checkpoint_148_msss+msou+msss=0.7086.pt
# ---- Epoch 149/194
# (1) Training stage (lr = 0.000003) ...
# loss 0.02764, mscxr_att_sup_loss 0.02361, mscxr_vgbbox_loss 0.00403, 94.92 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.69028, 3.13 secs
# ---- Epoch 150/194
# (1) Training stage (lr = 0.000080) ...
# loss 0.03173, mscxr_att_sup_loss 0.02735, mscxr_vgbbox_loss 0.00439, 94.16 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.65964, 3.13 secs
# ---- Epoch 151/194
# (1) Training stage (lr = 0.000035) ...
# loss 0.02916, mscxr_att_sup_loss 0.02494, mscxr_vgbbox_loss 0.00422, 94.45 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.68327, 3.11 secs
# ---- Epoch 152/194
# (1) Training stage (lr = 0.000015) ...
# loss 0.02729, mscxr_att_sup_loss 0.02320, mscxr_vgbbox_loss 0.00410, 94.06 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.68638, 3.12 secs
# ---- Epoch 153/194
# (1) Training stage (lr = 0.000007) ...
# loss 0.02931, mscxr_att_sup_loss 0.02525, mscxr_vgbbox_loss 0.00406, 95.41 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.69492, 3.20 secs
# New checkpoint saved: checkpoint_153_msss+msou+msss=0.7095.pt
# ---- Epoch 154/194
# (1) Training stage (lr = 0.000003) ...
# loss 0.02458, mscxr_att_sup_loss 0.02059, mscxr_vgbbox_loss 0.00399, 94.64 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.69651, 3.08 secs
# New checkpoint saved: checkpoint_154_msss+msou+msss=0.7111.pt
# ---- Epoch 155/194
# (1) Training stage (lr = 0.000080) ...
# loss 0.02832, mscxr_att_sup_loss 0.02422, mscxr_vgbbox_loss 0.00410, 94.55 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.67950, 3.10 secs
# ---- Epoch 156/194
# (1) Training stage (lr = 0.000035) ...
# loss 0.03024, mscxr_att_sup_loss 0.02601, mscxr_vgbbox_loss 0.00423, 94.54 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.68545, 3.04 secs
# ---- Epoch 157/194
# (1) Training stage (lr = 0.000015) ...
# loss 0.02734, mscxr_att_sup_loss 0.02315, mscxr_vgbbox_loss 0.00419, 95.10 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.70021, 3.03 secs
# New checkpoint saved: checkpoint_157_msss+msou+msss=0.7145.pt
# ---- Epoch 158/194
# (1) Training stage (lr = 0.000007) ...
# loss 0.02619, mscxr_att_sup_loss 0.02219, mscxr_vgbbox_loss 0.00400, 95.31 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.69865, 3.07 secs
# ---- Epoch 159/194
# (1) Training stage (lr = 0.000003) ...
# loss 0.02622, mscxr_att_sup_loss 0.02210, mscxr_vgbbox_loss 0.00412, 95.90 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.69620, 3.10 secs
# ---- Epoch 160/194
# (1) Training stage (lr = 0.000080) ...
# loss 0.02821, mscxr_att_sup_loss 0.02412, mscxr_vgbbox_loss 0.00409, 94.82 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.67330, 3.08 secs
# ---- Epoch 161/194
# (1) Training stage (lr = 0.000035) ...
# loss 0.02736, mscxr_att_sup_loss 0.02335, mscxr_vgbbox_loss 0.00402, 94.75 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.69766, 3.16 secs
# ---- Epoch 162/194
# (1) Training stage (lr = 0.000015) ...
# loss 0.02623, mscxr_att_sup_loss 0.02232, mscxr_vgbbox_loss 0.00391, 94.63 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.70385, 3.13 secs
# New checkpoint saved: checkpoint_162_msss+msou+msss=0.7180.pt
# ---- Epoch 163/194
# (1) Training stage (lr = 0.000007) ...
# loss 0.02222, mscxr_att_sup_loss 0.01847, mscxr_vgbbox_loss 0.00375, 95.08 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.70448, 3.13 secs
# New checkpoint saved: checkpoint_163_msss+msou+msss=0.7187.pt
# ---- Epoch 164/194
# (1) Training stage (lr = 0.000003) ...
# loss 0.02451, mscxr_att_sup_loss 0.02059, mscxr_vgbbox_loss 0.00391, 95.60 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.70446, 3.10 secs
# ---- Epoch 165/194
# (1) Training stage (lr = 0.000080) ...
# loss 0.03015, mscxr_att_sup_loss 0.02606, mscxr_vgbbox_loss 0.00409, 95.16 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.65247, 3.16 secs
# ---- Epoch 166/194
# (1) Training stage (lr = 0.000035) ...
# loss 0.03186, mscxr_att_sup_loss 0.02753, mscxr_vgbbox_loss 0.00434, 94.11 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.70644, 3.13 secs
# New checkpoint saved: checkpoint_166_msss+msou+msss=0.7203.pt
# ---- Epoch 167/194
# (1) Training stage (lr = 0.000015) ...
# loss 0.02753, mscxr_att_sup_loss 0.02362, mscxr_vgbbox_loss 0.00392, 94.81 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.70476, 3.07 secs
# ---- Epoch 168/194
# (1) Training stage (lr = 0.000007) ...
# loss 0.02288, mscxr_att_sup_loss 0.01909, mscxr_vgbbox_loss 0.00378, 94.21 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.70689, 3.06 secs
# New checkpoint saved: checkpoint_168_msss+msou+msss=0.7210.pt
# ---- Epoch 169/194
# (1) Training stage (lr = 0.000003) ...
# loss 0.02316, mscxr_att_sup_loss 0.01935, mscxr_vgbbox_loss 0.00382, 93.01 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.70774, 3.12 secs
# New checkpoint saved: checkpoint_169_msss+msou+msss=0.7218.pt
# ---- Epoch 170/194
# (1) Training stage (lr = 0.000080) ...
# loss 0.02875, mscxr_att_sup_loss 0.02463, mscxr_vgbbox_loss 0.00412, 93.56 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.68489, 3.10 secs
# ---- Epoch 171/194
# (1) Training stage (lr = 0.000035) ...
# loss 0.02637, mscxr_att_sup_loss 0.02232, mscxr_vgbbox_loss 0.00406, 94.49 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.69826, 3.14 secs
# ---- Epoch 172/194
# (1) Training stage (lr = 0.000015) ...
# loss 0.02454, mscxr_att_sup_loss 0.02064, mscxr_vgbbox_loss 0.00390, 95.22 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.70286, 3.11 secs
# ---- Epoch 173/194
# (1) Training stage (lr = 0.000007) ...
# loss 0.02430, mscxr_att_sup_loss 0.02047, mscxr_vgbbox_loss 0.00383, 95.09 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.70259, 3.11 secs
# ---- Epoch 174/194
# (1) Training stage (lr = 0.000003) ...
# loss 0.02168, mscxr_att_sup_loss 0.01796, mscxr_vgbbox_loss 0.00372, 95.05 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.70901, 3.05 secs
# New checkpoint saved: checkpoint_174_msss+msou+msss=0.7230.pt
# ---- Epoch 175/194
# (1) Training stage (lr = 0.000080) ...
# loss 0.02594, mscxr_att_sup_loss 0.02186, mscxr_vgbbox_loss 0.00409, 94.98 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.68842, 3.12 secs
# ---- Epoch 176/194
# (1) Training stage (lr = 0.000035) ...
# loss 0.02739, mscxr_att_sup_loss 0.02349, mscxr_vgbbox_loss 0.00390, 94.59 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.69760, 3.09 secs
# ---- Epoch 177/194
# (1) Training stage (lr = 0.000015) ...
# loss 0.02533, mscxr_att_sup_loss 0.02144, mscxr_vgbbox_loss 0.00389, 94.38 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.70621, 3.11 secs
# ---- Epoch 178/194
# (1) Training stage (lr = 0.000007) ...
# loss 0.02295, mscxr_att_sup_loss 0.01920, mscxr_vgbbox_loss 0.00374, 94.44 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.70460, 3.11 secs
# ---- Epoch 179/194
# (1) Training stage (lr = 0.000003) ...
# loss 0.02043, mscxr_att_sup_loss 0.01676, mscxr_vgbbox_loss 0.00366, 89.59 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.70868, 3.11 secs
# ---- Epoch 180/194
# (1) Training stage (lr = 0.000080) ...
# loss 0.02760, mscxr_att_sup_loss 0.02374, mscxr_vgbbox_loss 0.00386, 93.66 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.69725, 3.09 secs
# ---- Epoch 181/194
# (1) Training stage (lr = 0.000035) ...
# loss 0.02628, mscxr_att_sup_loss 0.02253, mscxr_vgbbox_loss 0.00375, 93.54 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.70112, 3.12 secs
# ---- Epoch 182/194
# (1) Training stage (lr = 0.000015) ...
# loss 0.02273, mscxr_att_sup_loss 0.01911, mscxr_vgbbox_loss 0.00363, 93.58 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.69770, 3.09 secs
# ---- Epoch 183/194
# (1) Training stage (lr = 0.000007) ...
# loss 0.02179, mscxr_att_sup_loss 0.01821, mscxr_vgbbox_loss 0.00358, 94.36 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.69797, 3.12 secs
# ---- Epoch 184/194
# (1) Training stage (lr = 0.000003) ...
# loss 0.02214, mscxr_att_sup_loss 0.01845, mscxr_vgbbox_loss 0.00368, 94.51 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.70368, 3.07 secs
# ---- Epoch 185/194
# (1) Training stage (lr = 0.000080) ...
# loss 0.02559, mscxr_att_sup_loss 0.02165, mscxr_vgbbox_loss 0.00394, 93.57 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.68742, 3.07 secs
# ---- Epoch 186/194
# (1) Training stage (lr = 0.000035) ...
# loss 0.02672, mscxr_att_sup_loss 0.02294, mscxr_vgbbox_loss 0.00377, 94.72 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.69250, 3.07 secs
# ---- Epoch 187/194
# (1) Training stage (lr = 0.000015) ...
# loss 0.02268, mscxr_att_sup_loss 0.01905, mscxr_vgbbox_loss 0.00363, 93.80 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.70489, 3.00 secs
# ---- Epoch 188/194
# (1) Training stage (lr = 0.000007) ...
# loss 0.02047, mscxr_att_sup_loss 0.01717, mscxr_vgbbox_loss 0.00330, 94.62 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.70690, 3.16 secs
# ---- Epoch 189/194
# (1) Training stage (lr = 0.000003) ...
# loss 0.01949, mscxr_att_sup_loss 0.01601, mscxr_vgbbox_loss 0.00348, 92.29 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.70481, 3.13 secs
# ---- Epoch 190/194
# (1) Training stage (lr = 0.000080) ...
# loss 0.02513, mscxr_att_sup_loss 0.02129, mscxr_vgbbox_loss 0.00385, 90.57 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.66550, 3.11 secs
# ---- Epoch 191/194
# (1) Training stage (lr = 0.000035) ...
# loss 0.02669, mscxr_att_sup_loss 0.02276, mscxr_vgbbox_loss 0.00393, 90.08 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.70198, 3.19 secs
# ---- Epoch 192/194
# (1) Training stage (lr = 0.000015) ...
# loss 0.02394, mscxr_att_sup_loss 0.02019, mscxr_vgbbox_loss 0.00375, 90.84 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.71219, 3.14 secs
# New checkpoint saved: checkpoint_192_msss+msou+msss=0.7260.pt
# ---- Epoch 193/194
# (1) Training stage (lr = 0.000007) ...
# loss 0.02290, mscxr_att_sup_loss 0.01935, mscxr_vgbbox_loss 0.00355, 93.63 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.71379, 3.09 secs
# New checkpoint saved: checkpoint_193_msss+msou+msss=0.7275.pt
# ---- Epoch 194/194
# (1) Training stage (lr = 0.000003) ...
# loss 0.02194, mscxr_att_sup_loss 0.01836, mscxr_vgbbox_loss 0.00359, 94.71 secs
# (2) Validation stage ...
# mscxr_bbox_iou 0.71664, 3.09 secs
# New checkpoint saved: checkpoint_194_msss+msou+msss=0.7303.pt

# %%
from medvqa.train_phrase_grounding import debug_main

# %%
out = debug_main("""
--pretrained_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250323_172425_mim-facts+mscxr+vinbig_PhraseGrounder(aehrc-cxrmate-rrg24-uniformer,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)" \
--epochs 10 \
--batches_per_epoch 50 \
--max_images_per_batch 11 \
--max_phrases_per_batch 1000 \
--max_phrases_per_image 40 \
--val_batch_size_factor 2.0 \
--raw_image_encoding "cxrmate-rrg24-uniformer-huggingface" \
--huggingface_model_name "aehrc/cxrmate-rrg24" \
--image_size 384 384 \
--image_local_feat_size 512 \
--num_regions 144 \
--regions_width 12 \
--regions_height 12 \
--img_aug_mode "random-color-and-spatial" \
--phrase_embedding_size 128 \
--phrase_grounding_mode "adaptive_film_based_pooling_mlp_with_bbox_regression" \
--phrase_mlp_hidden_dims 256 128 \
--visual_grounding_hidden_size 256 \
--bbox_format "cxcywh" \
--predict_relative_bbox_coords \
--num_train_workers 2 \
--num_val_workers 2 \
--gradient_accumulation_steps 4 \
--optimizer_name "adamw" \
--scheduler "exp-warmup+decay+cyclicdecay" \
--lr 1e-6 \
--warmup_decay_and_cyclic_decay_args "1e-6,3,8e-5,5,1e-6,8e-5,5,1e-6" \
--binary_multilabel_classif_loss_name "focal+bce+npbbce" \
--do_visual_grounding_with_bbox_regression \
--use_mscxr_for_train \
--use_mscxr_for_val \
--mscxr_training_data_mode "all" \
--mscxr_do_grounding_only \
--mscxr_phrase2embedding_filepath \
"/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/mimiccxr/mscxr_phrase2embedding(hash=36549,2076639799495206637).pkl" \
--apply_ignore_band \
--no_save
""")
# Out:
# script's arguments:
#    epochs: 10
#    batches_per_epoch: 50
#    max_images_per_batch: 11
#    max_phrases_per_batch: 1000
#    max_phrases_per_image: 40
#    val_batch_size_factor: 2.0
#    checkpoint_folder: None
#    pretrained_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250323_172425_mim-facts+mscxr+vinbig_PhraseGrounder(aehrc-cxrmate-rrg24-uniformer,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)
#    pretrained_checkpoint_folder_paths: None
#    freeze_image_encoder: False
#    raw_image_encoding: cxrmate-rrg24-uniformer-huggingface
#    huggingface_model_name: aehrc/cxrmate-rrg24
#    num_regions: 144
#    image_local_feat_size: 512
#    image_encoder_pretrained_weights_path: None
#    image_encoder_dropout_p: 0
#    yolov8_model_name_or_path: None
#    yolov8_model_alias: None
#    phrase_embedding_size: 128
#    regions_width: 12
#    regions_height: 12
#    qkv_size: None
#    phrase_grounding_mode: adaptive_film_based_pooling_mlp_with_bbox_regression
#    phrase_classifier_hidden_size: None
#    transf_d_model: None
#    transf_nhead: None
#    transf_dim_feedforward: None
#    transf_dropout: 0
#    transf_num_layers: None
#    visual_feature_proj_size: None
#    visual_grounding_hidden_size: 256
#    phrase_mlp_hidden_dims: [256, 128]
#    predict_global_alignment: False
#    alignment_proj_size: None
#    yolov11_model_name_or_path: None
#    yolov11_model_alias: None
#    bbox_format: cxcywh
#    predict_relative_bbox_coords: True
#    optimizer_name: adamw
#    lr: 1e-06
#    scheduler: exp-warmup+decay+cyclicdecay
#    lr_decay: 0.76
#    lr_decay_patience: 2
#    warmup_and_decay_args: None
#    warmup_and_cosine_args: None
#    warmup_decay_and_cyclic_decay_args: 1e-6,3,8e-5,5,1e-6,8e-5,5,1e-6
#    gradient_accumulation_steps: 4
#    override_lr: False
#    max_grad_norm: None
#    attention_supervision_loss_weight: 1.0
#    phrase_classifier_loss_weight: 1.0
#    foreground_loss_weight: 1.0
#    background_loss_weight: 1.0
#    focal_loss_weight: 1.0
#    bce_loss_weight: 1.0
#    wbce_loss_weight: 1.0
#    binary_multilabel_classif_loss_name: focal+bce+npbbce
#    use_weighted_phrase_classifier_loss: False
#    cluster_and_label_weights_for_facts_filepath: None
#    use_attention_regularization_loss: False
#    use_contrastive_phrase_grounding_loss: False
#    nt_xent_temperature: 0.1
#    apply_ignore_band: True
#    num_train_workers: 2
#    num_val_workers: 2
#    device: GPU
#    use_amp: False
#    image_size: [384, 384]
#    dicom_id_to_pos_neg_facts_filepath: None
#    iuxray_image_id_to_pos_neg_facts_filepath: None
#    mscxr_phrase2embedding_filepath: /mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/mimiccxr/mscxr_phrase2embedding(hash=36549,2076639799495206637).pkl
#    chest_imagenome_bbox_phrase_embeddings_filepath: None
#    vinbig_phrase_embeddings_filepath: None
#    chexlocalize_class_phrase_embeddings_filepath: None
#    chexpert_class_phrase_embeddings_filepath: None
#    mimiccxr_exclude_noisy_images: False
#    mimiccxr_facts_weight: 1.0
#    chest_imagenome_anatlocs_weight: 1.0
#    mscxr_weight: 1.0
#    cxrlt2024_weight: 1.0
#    vinbig_weight: 1.0
#    chexlocalize_weight: 1.0
#    chexpert_weight: 1.0
#    iuxray_weight: 1.0
#    img_aug_mode: random-color-and-spatial
#    pos_area_prior: 0.4
#    neg_area_prior: 0.0
#    use_mimiccxr_facts_for_train: False
#    use_mimiccxr_facts_for_test: False
#    use_mscxr_for_train: True
#    use_mscxr_for_val: True
#    use_chest_imagenome_for_train: False
#    use_chest_imagenome_gold_for_test: False
#    use_vinbig_for_train: False
#    use_vinbig_for_test: False
#    use_chexlocalize_for_train: False
#    use_chexlocalize_for_test: False
#    use_chexpert_for_train: False
#    use_chexpert_for_test: False
#    use_iuxray_for_train: False
#    use_iuxray_for_test: False
#    use_cxrlt2024_challenge_split: False
#    use_cxrlt2024_custom_labels: False
#    use_cxrlt2024_official_labels: False
#    use_all_cxrlt2024_official_labels_for_training: False
#    vinbig_training_data_mode: train
#    chexpert_training_data_mode: all
#    mimiccxr_balance_long_middle_short_tail: False
#    mimiccxr_long_middle_short_tail_thresholds: (0.02, 0.05)
#    mimiccxr_report_fact_nli_integrated_data_filepath: None
#    mimiccxr_use_interpret_cxr_challenge_split: False
#    mimiccxr_interpret_cxr_challenge_split_filepath: None
#    iuxray_use_interpret_cxr_challenge_split: False
#    iuxray_interpret_cxr_challenge_split_filepath: None
#    chexpert_use_interpret_cxr_challenge_split: False
#    chexpert_interpret_cxr_challenge_split_filepath: None
#    chexlocalize_use_interpret_cxr_challenge_split: False
#    chexlocalize_interpret_cxr_challenge_split_filepath: None
#    cxrlt2024_custom_dicom_id_to_pos_neg_facts_filepath: None
#    cxrlt2024_official_training_labels_for_fact_classification_filepath: None
#    cxrlt2024_do_balanced_sampling: False
#    do_visual_grounding_with_bbox_regression: True
#    do_visual_grounding_with_segmentation: False
#    replace_phrase_embeddings_with_random_vectors: False
#    use_vinbig_with_modified_labels: False
#    mscxr_training_data_mode: all
#    mscxr_do_grounding_only: True
#    save: False
#    override_metric_weights: None
# ----- Training model from scratch ------
# include_loss_weights = False
# source_image_size_mode: medium_512
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Creating instance of PhraseGrounder ...
# WARNING: Unused kwargs: {'pretrained_checkpoint_folder_path': '/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250323_172425_mim-facts+mscxr+vinbig_PhraseGrounder(aehrc-cxrmate-rrg24-uniformer,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)', 'pretrained_checkpoint_folder_paths': None}
# MultiPurposeVisualModule()
#   Initializing raw_image_encoder: cxrmate-rrg24-uniformer-huggingface
#   self.global_feat_size = 1024
#   self.local_feat_size = 512
#   Initializing auxiliary tasks
# MultiClassBoundingBoxRegressor
#   local_feat_dim: 256
#   bbox_format: cxcywh
#   predict_relative: True
# --------------------------------------------------
# 3) Defining optimizer ...
# create_optimizer(): name = adamw
# --------------------------------------------------
# 4) Defining scheduler ...
# Using exp-warmup+decay+cyclicdecay scheduler: 1e-6,3,8e-5,5,1e-6,8e-5,5,1e-6
# 1e-06 3 8e-05 5 1e-06 8e-05 5 1e-06
# self.steps_to_restart = 5
# self.steps = -1
# self.initial_lr = 8e-05
# --------------------------------------------------
# 5) Creating trainer and validator engines ...
# Focal_BCE_NPBBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 npbbce_weight = 0.3333333333333333
# Focal_BCE_NPBBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 npbbce_weight = 0.3333333333333333
# Focal_BCE_WBCBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 wbcbce_weight = 0.3333333333333333
# foreground_loss_weight: 1.0
# background_loss_weight: 1.0
# GradientAccumulator.__init__(): num_accumulation_steps = 4, max_grad_norm = None
# Focal_BCE_NPBBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 npbbce_weight = 0.3333333333333333
# Focal_BCE_NPBBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 npbbce_weight = 0.3333333333333333
# Focal_BCE_WBCBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 wbcbce_weight = 0.3333333333333333
# foreground_loss_weight: 1.0
# background_loss_weight: 1.0
# --------------------------------------------------
# 6) Creating MIMIC-CXR Phrase Grounding Trainer ...
# get_image_transform()
#   image_size = [384, 384]
#   mean = [0.485, 0.456, 0.406]
#   std = [0.229, 0.224, 0.225]
#   Using bounding box aware transforms
#     augmentation_mode = random-color-and-spatial
#     default_prob = 0.35
#     returning transform (not for vinbig)
# get_train_transform(): Using bbox-aware transforms for VinBigData
# get_train_transform(): Using normal transforms
#     Returning augmented transform with mode random-color-and-spatial
# get_image_transform()
#   image_size = [384, 384]
#   mean = [0.485, 0.456, 0.406]
#   std = [0.229, 0.224, 0.225]
#   Using bounding box aware transforms
#     Returning default transform (no augmentation)
# Warning: unused kwargs in MIMICCXR_VisualModuleTrainer: {'use_yolov8': False}
# len(forbidden_train_dicom_ids) = 310
# Preparing MS-CXR dataset and dataloaders for train, val (grounding only) ...
# len(dicom_id_2_phrases_and_bboxes) = 1047
# len(phrase2embedding) = 715
# phrase_embeddings.shape = (715, 128)
# Using image size mode: medium_512
# 227835it [00:00, 475409.04it/s]
# Total number of instances: 1160
# len(train_indices) = 815
# Building train fact dataloader...
# batch_size = 11
# len(self.mscxr_train_dataset) = 1160
# len(self.mscxr_train_dataloader) = 106
# len(val_indices) = 169
# Building val fact dataloader...
# batch_size = 22
# len(self.mscxr_val_dataset) = 169
# len(self.mscxr_val_dataloader) = 8

# %%
from importlib import reload
import medvqa

# %%
reload(medvqa.datasets.data_inspection_utils)
# Out:
# <module 'medvqa.datasets.data_inspection_utils' from '/home/pamessina/medvqa/medvqa/datasets/data_inspection_utils.py'>

# %%
from medvqa.datasets.data_inspection_utils import inspect_mscxr_dataset

# %%
inspect_mscxr_dataset(out['mimiccxr_trainer'], 1, grounding_only_mode=True)
# Out:
# idx: 1
# dicom_id: 1c9e6619-dd867388-03bc56ee-5262ce09-6fee1070
# image_path: /mnt/workspace/physionet.org/files/mimic-cxr-jpg/2.0.0/files/p10/p10935371/s55612091/1c9e6619-dd867388-03bc56ee-5262ce09-6fee1070.jpg
# report:
#                                  FINAL REPORT
#  REASON FOR EXAMINATION:  Hypertension.
#
#  Portable AP radiograph of the chest was reviewed with comparison to CT torso
#  from ___.
#
#  Heart size is normal.  There is small left apical pneumothorax but appears to
#  be slightly increased since the prior study.  Left basal opacity has increased
#  and might potentially reflect contusion or lung hemorrhage.  There is no
#  interval development of pleural effusion.  No definitive rib fractures
#  identified.  The fractures noted on the prior study are not clearly seen on
#  the current study.
#
# metadata:
# {'report_index': 89, 'part_id': 10, 'subject_id': 10935371, 'study_id': 55612091, 'dicom_id': '1c9e6619-dd867388-03bc56ee-5262ce09-6fee1070', 'view_pos': 'AP', 'split': 'train', 'filepath': '/mnt/data/mimic-cxr/files/p10/p10935371/s55612091.txt', 'dicom_id_view_pos_pairs': [('1c9e6619-dd867388-03bc56ee-5262ce09-6fee1070', 'AP')]}
# image_tensor: torch.Size([3, 384, 384])
# num_regions: 144, feat_W: 12, feat_H: 12
# phrase_embedding: (128,)
# bbox_target_coords: torch.Size([144, 4])
# bbox_target_presence: torch.Size([144])
# ignore_band_mask: torch.Size([144])
# bbox_coords: [(0.16267001628875732, 0.31633424758911133, 0.2574061155319214, 0.18570275604724884)]
# bbox_format: cxcywh
# Transformed image:
# Original image:
# Phrase bboxes: [(0.6965340685309176, 0.2737704918032787, 0.2288302481291847, 0.11868852459016394)]
# Phrase idx: 630
# Phrase: small left apical pneumothorax

# %%
inspect_mscxr_dataset(out['mimiccxr_trainer'], 0, grounding_only_mode=True)
# Out:
# idx: 0
# dicom_id: 4a050186-c6320c70-b83046e2-f2c1f2b6-85c0f190
# image_path: /mnt/workspace/physionet.org/files/mimic-cxr-jpg/2.0.0/files/p10/p10483304/s50076705/4a050186-c6320c70-b83046e2-f2c1f2b6-85c0f190.jpg
# report:
#                                  FINAL REPORT
#  EXAMINATION:   CHEST (PA AND LAT)
#
#  INDICATION:  History: ___M with dizziness  // pna
#
#  TECHNIQUE:  Chest PA and lateral
#
#  COMPARISON:  None.
#
#  FINDINGS:
#
#  The cardiomediastinal silhouette and pulmonary vasculature are unremarkable.
#  There is opacification in the left base.  Though this may be atelectasis,
#  pneumonia is not excluded.  Possible mild bronchial wall thickening is noted,
#  particularly in the right lower lung field.  There is no pleural effusion or
#  pneumothorax.
#
#  IMPRESSION:
#
#  Possible left lower lobe pneumonia in the appropriate clinical context.
#
# metadata:
# {'report_index': 2, 'part_id': 10, 'subject_id': 10483304, 'study_id': 50076705, 'dicom_id': '4a050186-c6320c70-b83046e2-f2c1f2b6-85c0f190', 'view_pos': 'PA', 'split': 'train', 'filepath': '/mnt/data/mimic-cxr/files/p10/p10483304/s50076705.txt', 'dicom_id_view_pos_pairs': [('4a050186-c6320c70-b83046e2-f2c1f2b6-85c0f190', 'PA'), ('9a497beb-f5fe51a3-c34c2a30-87e625fa-61256512', 'LATERAL')]}
# image_tensor: torch.Size([3, 384, 384])
# num_regions: 144, feat_W: 12, feat_H: 12
# phrase_embedding: (128,)
# bbox_target_coords: torch.Size([144, 4])
# bbox_target_presence: torch.Size([144])
# ignore_band_mask: torch.Size([144])
# bbox_coords: [(0.7029153108596802, 0.6413577198982239, 0.24115674197673798, 0.31777557730674744)]
# bbox_format: cxcywh
# Transformed image:
# Original image:
# Phrase bboxes: [(0.6971531413612565, 0.6434748427672956, 0.23527486910994763, 0.2830188679245283)]
# Phrase idx: 487
# Phrase: opacification in the left base

# %%
out['mimiccxr_trainer'].mscxr_val_dataset.bbox_format
# Out:
# 'cxcywh'

# %%
inspect_mscxr_dataset(out['mimiccxr_trainer'], 1, train=False, grounding_only_mode=True)
# Out:
# idx: 14
# dicom_id: 078257e1-ad7b92c9-ed39606b-6f8c7787-d6e77290
# image_path: /mnt/workspace/physionet.org/files/mimic-cxr-jpg/2.0.0/files/p10/p10209431/s50872013/078257e1-ad7b92c9-ed39606b-6f8c7787-d6e77290.jpg
# report:
#                                  FINAL REPORT
#  INDICATION:  Cough.
#
#  TECHNIQUE:  Chest PA and lateral
#
#  COMPARISON:  None.
#
#  FINDINGS:
#
#  There are consolidations in the right middle and lower lobes with a elevation
#  of the right hemidiaphragm.  There may be a more subtle consolidation at the
#  left base.  Heart size is mildly prominent. Mediastinal and left hilar
#  contours are unremarkable.  Right hilar contours are partially obscured.
#  There are degenerative changes in the spine.
#
#  IMPRESSION:
#
#  Multifocal pneumonia.
#
#  NOTIFICATION:  Results were documented in PACS by Dr. ___ on ___ at 15:36.
#
# metadata:
# {'report_index': 910, 'part_id': 10, 'subject_id': 10209431, 'study_id': 50872013, 'dicom_id': '078257e1-ad7b92c9-ed39606b-6f8c7787-d6e77290', 'view_pos': 'PA', 'split': 'train', 'filepath': '/mnt/data/mimic-cxr/files/p10/p10209431/s50872013.txt', 'dicom_id_view_pos_pairs': [('078257e1-ad7b92c9-ed39606b-6f8c7787-d6e77290', 'PA'), ('8f11da13-7d009456-53b2be2f-ed487c14-ee28184a', 'LATERAL')]}
# image_tensor: torch.Size([3, 384, 384])
# phrase_embedding: (128,)
# phrase_bboxes: [(0.27028795811518325, 0.5457940251572326, 0.26112565445026176, 0.2244496855345912)]
# bbox_format: cxcywh
# Transformed image:
# Original image:
# Phrase idx: 350
# Phrase: consolidations in the right middle and lower lobes

# %%
from medvqa.train_phrase_grounding import debug_main
# Out:
# 2025-05-03 14:35:48,915 - root - INFO - Logging configured (Color: True).

# %%
out = debug_main("""
--pretrained_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250323_172425_mim-facts+mscxr+vinbig_PhraseGrounder(aehrc-cxrmate-rrg24-uniformer,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)" \
--epochs 10 \
--batches_per_epoch 50 \
--max_images_per_batch 11 \
--max_phrases_per_batch 1000 \
--max_phrases_per_image 40 \
--val_batch_size_factor 2.0 \
--raw_image_encoding "cxrmate-rrg24-uniformer-huggingface" \
--huggingface_model_name "aehrc/cxrmate-rrg24" \
--image_size 384 384 \
--image_local_feat_size 512 \
--num_regions 144 \
--regions_width 12 \
--regions_height 12 \
--img_aug_mode "random-color-and-spatial" \
--phrase_embedding_size 128 \
--phrase_grounding_mode "adaptive_film_based_pooling_mlp_with_bbox_regression" \
--phrase_mlp_hidden_dims 256 128 \
--visual_grounding_hidden_size 256 \
--bbox_format "cxcywh" \
--predict_relative_bbox_coords \
--num_train_workers 2 \
--num_val_workers 2 \
--gradient_accumulation_steps 4 \
--optimizer_name "adamw" \
--scheduler "exp-warmup+decay+cyclicdecay" \
--lr 1e-6 \
--warmup_decay_and_cyclic_decay_args "1e-6,3,8e-5,5,3e-6,8e-5,5,3e-6" \
--binary_multilabel_classif_loss_name "focal+bce+npbbce" \
--do_visual_grounding_with_bbox_regression \
--use_mscxr_for_train \
--use_mscxr_for_val \
--mscxr_training_data_mode "all" \
--mscxr_do_grounding_only \
--mscxr_phrase2embedding_filepath \
"/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/mimiccxr/mscxr_phrase2embedding(hash=36549,2076639799495206637).pkl" \
--no_save
""")
# Out:
# 2025-05-03 14:36:33,505 - medvqa.utils.common - INFO -
# script's arguments:
#    epochs: 10
#    batches_per_epoch: 50
#    max_images_per_batch: 11
#    max_phrases_per_batch: 1000
#    max_phrases_per_image: 40
#    val_batch_size_factor: 2.0
#    checkpoint_folder: None
#    pretrained_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250323_172425_mim-facts+mscxr+vinbig_PhraseGrounder(aehrc-cxrmate-rrg24-uniformer,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)
#    pretrained_checkpoint_folder_paths: None
#    freeze_image_encoder: False
#    raw_image_encoding: cxrmate-rrg24-uniformer-huggingface
#    huggingface_model_name: aehrc/cxrmate-rrg24
#    num_regions: 144
#    image_local_feat_size: 512
#    image_encoder_pretrained_weights_path: None
#    image_encoder_dropout_p: 0
#    yolov8_model_name_or_path: None
#    yolov8_model_alias: None
#    phrase_embedding_size: 128
#    regions_width: 12
#    regions_height: 12
#    qkv_size: None
#    phrase_grounding_mode: adaptive_film_based_pooling_mlp_with_bbox_regression
#    phrase_classifier_hidden_size: None
#    transf_d_model: None
#    transf_nhead: None
#    transf_dim_feedforward: None
#    transf_dropout: 0
#    transf_num_layers: None
#    visual_feature_proj_size: None
#    visual_grounding_hidden_size: 256
#    phrase_mlp_hidden_dims: [256, 128]
#    predict_global_alignment: False
#    alignment_proj_size: None
#    yolov11_model_name_or_path: None
#    yolov11_model_alias: None
#    bbox_format: cxcywh
#    predict_relative_bbox_coords: True
#    optimizer_name: adamw
#    lr: 1e-06
#    scheduler: exp-warmup+decay+cyclicdecay
#    lr_decay: 0.76
#    lr_decay_patience: 2
#    warmup_and_decay_args: None
#    warmup_and_cosine_args: None
#    warmup_decay_and_cyclic_decay_args: 1e-6,3,8e-5,5,3e-6,8e-5,5,3e-6
#    gradient_accumulation_steps: 4
#    override_lr: False
#    max_grad_norm: None
#    attention_supervision_loss_weight: 1.0
#    phrase_classifier_loss_weight: 1.0
#    foreground_loss_weight: 1.0
#    background_loss_weight: 1.0
#    focal_loss_weight: 1.0
#    bce_loss_weight: 1.0
#    wbce_loss_weight: 1.0
#    binary_multilabel_classif_loss_name: focal+bce+npbbce
#    use_weighted_phrase_classifier_loss: False
#    cluster_and_label_weights_for_facts_filepath: None
#    use_attention_regularization_loss: False
#    use_contrastive_phrase_grounding_loss: False
#    nt_xent_temperature: 0.1
#    num_train_workers: 2
#    num_val_workers: 2
#    device: GPU
#    use_amp: False
#    image_size: [384, 384]
#    dicom_id_to_pos_neg_facts_filepath: None
#    iuxray_image_id_to_pos_neg_facts_filepath: None
#    mscxr_phrase2embedding_filepath: /mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/mimiccxr/mscxr_phrase2embedding(hash=36549,2076639799495206637).pkl
#    chest_imagenome_bbox_phrase_embeddings_filepath: None
#    vinbig_phrase_embeddings_filepath: None
#    chexlocalize_class_phrase_embeddings_filepath: None
#    chexpert_class_phrase_embeddings_filepath: None
#    mimiccxr_exclude_noisy_images: False
#    mimiccxr_facts_weight: 1.0
#    chest_imagenome_anatlocs_weight: 1.0
#    mscxr_weight: 1.0
#    cxrlt2024_weight: 1.0
#    vinbig_weight: 1.0
#    chexlocalize_weight: 1.0
#    chexpert_weight: 1.0
#    iuxray_weight: 1.0
#    img_aug_mode: random-color-and-spatial
#    pos_area_prior: 0.4
#    neg_area_prior: 0.0
#    use_mimiccxr_facts_for_train: False
#    use_mimiccxr_facts_for_test: False
#    use_mscxr_for_train: True
#    use_mscxr_for_val: True
#    use_chest_imagenome_for_train: False
#    use_chest_imagenome_gold_for_test: False
#    use_vinbig_for_train: False
#    use_vinbig_for_test: False
#    use_chexlocalize_for_train: False
#    use_chexlocalize_for_test: False
#    use_chexpert_for_train: False
#    use_chexpert_for_test: False
#    use_iuxray_for_train: False
#    use_iuxray_for_test: False
#    use_cxrlt2024_challenge_split: False
#    use_cxrlt2024_custom_labels: False
#    use_cxrlt2024_official_labels: False
#    use_all_cxrlt2024_official_labels_for_training: False
#    vinbig_training_data_mode: train
#    chexpert_training_data_mode: all
#    mimiccxr_balance_long_middle_short_tail: False
#    mimiccxr_long_middle_short_tail_thresholds: (0.02, 0.05)
#    mimiccxr_report_fact_nli_integrated_data_filepath: None
#    mimiccxr_use_interpret_cxr_challenge_split: False
#    mimiccxr_interpret_cxr_challenge_split_filepath: None
#    iuxray_use_interpret_cxr_challenge_split: False
#    iuxray_interpret_cxr_challenge_split_filepath: None
#    chexpert_use_interpret_cxr_challenge_split: False
#    chexpert_interpret_cxr_challenge_split_filepath: None
#    chexlocalize_use_interpret_cxr_challenge_split: False
#    chexlocalize_interpret_cxr_challenge_split_filepath: None
#    cxrlt2024_custom_dicom_id_to_pos_neg_facts_filepath: None
#    cxrlt2024_official_training_labels_for_fact_classification_filepath: None
#    cxrlt2024_do_balanced_sampling: False
#    do_visual_grounding_with_bbox_regression: True
#    do_visual_grounding_with_segmentation: False
#    replace_phrase_embeddings_with_random_vectors: False
#    use_vinbig_with_modified_labels: False
#    mscxr_training_data_mode: all
#    mscxr_do_grounding_only: True
#    save: False
#    override_metric_weights: None
# 2025-05-03 14:36:33,506 - medvqa.train_phrase_grounding - INFO - ========== Training model from scratch ==========
# 2025-05-03 14:36:33,508 - medvqa.train_phrase_grounding - INFO - include_loss_weights = False
# 2025-05-03 14:36:33,509 - medvqa.train_phrase_grounding - INFO - source_image_size_mode: medium_512
# 2025-05-03 14:36:33,571 - medvqa.train_phrase_grounding - INFO - device = cuda
# 2025-05-03 14:36:33,573 - medvqa.train_phrase_grounding - INFO - ========== Creating instance of PhraseGrounder ==========
# 2025-05-03 14:36:33,574 - medvqa.models.phrase_grounding.phrase_grounder - WARNING - Unused kwargs: {'pretrained_checkpoint_folder_path': '/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250323_172425_mim-facts+mscxr+vinbig_PhraseGrounder(aehrc-cxrmate-rrg24-uniformer,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)', 'pretrained_checkpoint_folder_paths': None}
# 2025-05-03 14:36:33,575 - medvqa.models.vision.visual_modules - INFO - MultiPurposeVisualModule()
# 2025-05-03 14:36:33,576 - medvqa.models.vision.visual_modules - INFO -   Initializing raw_image_encoder: cxrmate-rrg24-uniformer-huggingface
# 2025-05-03 14:36:39,245 - medvqa.models.vision.visual_modules - INFO -   self.global_feat_size = 1024
# 2025-05-03 14:36:39,247 - medvqa.models.vision.visual_modules - INFO -   self.local_feat_size = 512
# 2025-05-03 14:36:39,248 - medvqa.models.vision.visual_modules - INFO -   Initializing auxiliary tasks
# 2025-05-03 14:36:39,257 - medvqa.models.vision.bbox_regression - INFO - MultiClassBoundingBoxRegressor
# 2025-05-03 14:36:39,258 - medvqa.models.vision.bbox_regression - INFO -   local_feat_dim: 256
# 2025-05-03 14:36:39,259 - medvqa.models.vision.bbox_regression - INFO -   bbox_format: cxcywh
# 2025-05-03 14:36:39,260 - medvqa.models.vision.bbox_regression - INFO -   predict_relative: True
# 2025-05-03 14:36:39,409 - medvqa.train_phrase_grounding - INFO - ========== Defining optimizer ==========
# 2025-05-03 14:36:39,411 - medvqa.losses.optimizers - INFO - create_optimizer(): name = adamw, lr = 1e-06
# 2025-05-03 14:36:39,415 - medvqa.train_phrase_grounding - INFO - ========== Defining scheduler ==========
# 2025-05-03 14:36:39,416 - medvqa.losses.schedulers - INFO - Using exp-warmup+decay+cyclicdecay scheduler: 1e-6,3,8e-5,5,3e-6,8e-5,5,3e-6
# 2025-05-03 14:36:39,417 - medvqa.losses.schedulers - INFO - lr0 = 1e-06, epochs01 = 3, lr1 = 8e-05, epochs12 = 5, lr2 = 3e-06, lr3 = 8e-05, restart_epochs = 5, lr4 = 3e-06
# 2025-05-03 14:36:39,418 - medvqa.losses.schedulers - INFO - self.steps_to_restart = 5
# 2025-05-03 14:36:39,419 - medvqa.losses.schedulers - INFO - self.steps = -1
# 2025-05-03 14:36:39,420 - medvqa.losses.schedulers - INFO - self.initial_lr = 8e-05
# 2025-05-03 14:36:39,421 - medvqa.train_phrase_grounding - INFO - ========== Creating trainer and validator engines ==========
# 2025-05-03 14:36:39,422 - medvqa.losses - INFO - Focal_BCE_NPBBCE_Loss(): focal_weight = 0.3333333333333333, bce_weight = 0.3333333333333333, npbbce_weight = 0.3333333333333333
# 2025-05-03 14:36:39,423 - medvqa.losses - INFO - Focal_BCE_NPBBCE_Loss(): focal_weight = 0.3333333333333333, bce_weight = 0.3333333333333333, npbbce_weight = 0.3333333333333333
# 2025-05-03 14:36:39,424 - medvqa.losses - INFO - Focal_BCE_WBCBCE_Loss(): focal_weight = 0.3333333333333333, bce_weight = 0.3333333333333333, wbcbce_weight = 0.3333333333333333
# 2025-05-03 14:36:39,425 - medvqa.training.phrase_grounding - INFO - foreground_loss_weight: 1.0
# 2025-05-03 14:36:39,426 - medvqa.training.phrase_grounding - INFO - background_loss_weight: 1.0
# 2025-05-03 14:36:39,427 - medvqa.losses.optimizers - INFO - GradientAccumulator.__init__(): num_accumulation_steps = 4, max_grad_norm = None
# 2025-05-03 14:36:39,428 - medvqa.losses - INFO - Focal_BCE_NPBBCE_Loss(): focal_weight = 0.3333333333333333, bce_weight = 0.3333333333333333, npbbce_weight = 0.3333333333333333
# 2025-05-03 14:36:39,429 - medvqa.losses - INFO - Focal_BCE_NPBBCE_Loss(): focal_weight = 0.3333333333333333, bce_weight = 0.3333333333333333, npbbce_weight = 0.3333333333333333
# 2025-05-03 14:36:39,431 - medvqa.losses - INFO - Focal_BCE_WBCBCE_Loss(): focal_weight = 0.3333333333333333, bce_weight = 0.3333333333333333, wbcbce_weight = 0.3333333333333333
# 2025-05-03 14:36:39,432 - medvqa.training.phrase_grounding - INFO - foreground_loss_weight: 1.0
# 2025-05-03 14:36:39,433 - medvqa.training.phrase_grounding - INFO - background_loss_weight: 1.0
# 2025-05-03 14:36:39,434 - medvqa.train_phrase_grounding - INFO - ========== Creating MIMIC-CXR Phrase Grounding Trainer ==========
# 2025-05-03 14:36:39,435 - medvqa.datasets.image_transforms_factory - INFO - Building general image transform pipeline (is_train=True, bbox_format=yolo)
# 2025-05-03 14:36:39,437 - medvqa.datasets.image_transforms_factory - INFO - Building general image transform pipeline (is_train=False, bbox_format=None)
# 2025-05-03 14:36:39,439 - medvqa.datasets.mimiccxr.mimiccxr_phrase_grounding_dataset_management - WARNING - unused kwargs in MIMICCXR_PhraseGroundingTrainer: {'use_yolov8': False}
# 2025-05-03 14:36:39,483 - medvqa.datasets.mimiccxr.mimiccxr_phrase_grounding_dataset_management - INFO - len(forbidden_train_dicom_ids) = 310
# 2025-05-03 14:36:39,484 - medvqa.datasets.mimiccxr.mimiccxr_phrase_grounding_dataset_management - INFO - Preparing MS-CXR dataset and dataloaders for train, val (grounding only) ...
# 2025-05-03 14:36:39,612 - medvqa.datasets.mimiccxr.mimiccxr_phrase_grounding_dataset_management - INFO - len(dicom_id_2_phrases_and_bboxes) = 1047
# 2025-05-03 14:36:39,616 - medvqa.datasets.mimiccxr.mimiccxr_phrase_grounding_dataset_management - INFO - len(phrase2embedding) = 715
# 2025-05-03 14:36:39,618 - medvqa.datasets.mimiccxr.mimiccxr_phrase_grounding_dataset_management - INFO - phrase_embeddings.shape = (715, 128)
# 2025-05-03 14:36:39,622 - medvqa.datasets.mimiccxr - INFO - Using image size mode: medium_512
# 227835it [00:00, 329304.00it/s]
# 2025-05-03 14:36:41,261 - medvqa.datasets.mimiccxr.mimiccxr_phrase_grounding_dataset_management - INFO - Total number of instances: 1160
# 2025-05-03 14:36:41,263 - medvqa.datasets.mimiccxr.mimiccxr_phrase_grounding_dataset_management - INFO - len(train_indices) = 815
# 2025-05-03 14:36:41,264 - medvqa.datasets.mimiccxr.mimiccxr_phrase_grounding_dataset_management - INFO - Building train fact dataloader...
# 2025-05-03 14:36:41,265 - medvqa.datasets.mimiccxr.mimiccxr_phrase_grounding_dataset_management - INFO - batch_size = 11
# 2025-05-03 14:36:41,266 - medvqa.datasets.mimiccxr.mimiccxr_phrase_grounding_dataset_management - INFO - len(self.mscxr_train_dataset) = 1160
# 2025-05-03 14:36:41,267 - medvqa.datasets.mimiccxr.mimiccxr_phrase_grounding_dataset_management - INFO - len(self.mscxr_train_dataloader) = 106
# 2025-05-03 14:36:41,268 - medvqa.datasets.mimiccxr.mimiccxr_phrase_grounding_dataset_management - INFO - len(val_indices) = 169
# 2025-05-03 14:36:41,269 - medvqa.datasets.mimiccxr.mimiccxr_phrase_grounding_dataset_management - INFO - Building val fact dataloader...
# 2025-05-03 14:36:41,270 - medvqa.datasets.mimiccxr.mimiccxr_phrase_grounding_dataset_management - INFO - batch_size = 22
# 2025-05-03 14:36:41,271 - medvqa.datasets.mimiccxr.mimiccxr_phrase_grounding_dataset_management - INFO - len(self.mscxr_val_dataset) = 169
# 2025-05-03 14:36:41,272 - medvqa.datasets.mimiccxr.mimiccxr_phrase_grounding_dataset_management - INFO - len(self.mscxr_val_dataloader) = 8

# %%
from importlib import reload
import medvqa

# %%
reload(medvqa.datasets.data_inspection_utils)
# Out:
# <module 'medvqa.datasets.data_inspection_utils' from '/home/pamessina/medvqa/medvqa/datasets/data_inspection_utils.py'>

# %%
from medvqa.datasets.data_inspection_utils import inspect_mscxr_dataset

# %%
inspect_mscxr_dataset(out['mimiccxr_trainer'], 3, grounding_only_mode=True)
# Out:
# idx: 3
# dicom_id: 15121178-e63e820e-da95905a-6bee3266-9f834ca5
# image_path: /mnt/workspace/physionet.org/files/mimic-cxr-jpg/2.0.0/files/p10/p10476869/s59527010/15121178-e63e820e-da95905a-6bee3266-9f834ca5.jpg
# report:
#                                  FINAL REPORT
#  INDICATION:  ___ year old man with spontanous pneumothorax, s/p chest tube,
#  re-evaluate.  // ___ year old man with spontanous pneumothorax, s/p chest tube,
#  re-evaluate.
#
#  COMPARISON:  Compared to prior radiograph ___.
#
#  IMPRESSION:
#
#  There is a pigtail pleural catheter at the left base. There remains a left
#  basilar pneumothorax, unchanged. Heart size is within normal limits. Lungs are
#  grossly clear.
#
# metadata:
# {'report_index': 126, 'part_id': 10, 'subject_id': 10476869, 'study_id': 59527010, 'dicom_id': '15121178-e63e820e-da95905a-6bee3266-9f834ca5', 'view_pos': 'AP', 'split': 'train', 'filepath': '/mnt/data/mimic-cxr/files/p10/p10476869/s59527010.txt', 'dicom_id_view_pos_pairs': [('15121178-e63e820e-da95905a-6bee3266-9f834ca5', 'AP')]}
# image_tensor: torch.Size([3, 384, 384])
# num_regions: 144, feat_W: 12, feat_H: 12
# phrase_embedding: torch.Size([128])
# target_bbox_coords: torch.Size([144, 4])
# target_bbox_presence: torch.Size([144])
# target_prob_mask: torch.Size([144])
# bbox_coords: [(0.1735951006412506, 0.7633621692657471, 0.3471902012825012, 0.39623045921325684)]
# bbox_format: cxcywh
# Transformed image:
# Original image:
# Phrase bboxes: [(0.7212041884816753, 0.7360455974842767, 0.35471204188481675, 0.26375786163522014)]
# Phrase idx: 416
# Phrase: left basilar pneumothorax

# %%
# !python ../../train_phrase_grounding.py \
--pretrained_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250401_191427_mscxr_PhraseGrounder(aehrc-cxrmate-rrg24-uniformer,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/" \
--epochs 30 \
--batches_per_epoch 200 \
--max_images_per_batch 11 \
--max_phrases_per_batch 1000 \
--max_phrases_per_image 40 \
--val_batch_size_factor 2.0 \
--raw_image_encoding "cxrmate-rrg24-uniformer-huggingface" \
--huggingface_model_name "aehrc/cxrmate-rrg24" \
--image_size 384 384 \
--image_local_feat_size 512 \
--num_regions 144 \
--regions_width 12 \
--regions_height 12 \
--img_aug_mode "random-color-and-spatial" \
--phrase_embedding_size 128 \
--phrase_grounding_mode "adaptive_film_based_pooling_mlp_with_bbox_regression" \
--phrase_mlp_hidden_dims 256 128 \
--visual_grounding_hidden_size 256 \
--bbox_format "cxcywh" \
--predict_relative_bbox_coords \
--num_train_workers 2 \
--num_val_workers 2 \
--gradient_accumulation_steps 4 \
--optimizer_name "adamw" \
--scheduler "exp-warmup+decay+cyclicdecay" \
--lr 1e-6 \
--warmup_decay_and_cyclic_decay_args "1e-6,3,8e-5,5,3e-6,8e-5,5,3e-6" \
--binary_multilabel_classif_loss_name "focal+bce+npbbce" \
--do_visual_grounding_with_bbox_regression \
--use_mscxr_for_train \
--use_mscxr_for_val \
--mscxr_training_data_mode "all" \
--mscxr_do_grounding_only \
--mscxr_phrase2embedding_filepath \
"/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/mimiccxr/mscxr_phrase2embedding(hash=36549,2076639799495206637).pkl" \
--save
# Out:
# 2025-05-03 15:33:23,331 - root - INFO - Logging configured (Color: True).
# 2025-05-03 15:33:27,751 - medvqa.utils.common - INFO -
# script's arguments:
#    epochs: 30
#    batches_per_epoch: 200
#    max_images_per_batch: 11
#    max_phrases_per_batch: 1000
#    max_phrases_per_image: 40
#    val_batch_size_factor: 2.0
#    checkpoint_folder: None
#    pretrained_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250401_191427_mscxr_PhraseGrounder(aehrc-cxrmate-rrg24-uniformer,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/
#    pretrained_checkpoint_folder_paths: None
#    freeze_image_encoder: False
#    raw_image_encoding: cxrmate-rrg24-uniformer-huggingface
#    huggingface_model_name: aehrc/cxrmate-rrg24
#    num_regions: 144
#    image_local_feat_size: 512
#    image_encoder_pretrained_weights_path: None
#    image_encoder_dropout_p: 0
#    yolov8_model_name_or_path: None
#    yolov8_model_alias: None
#    phrase_embedding_size: 128
#    regions_width: 12
#    regions_height: 12
#    qkv_size: None
#    phrase_grounding_mode: adaptive_film_based_pooling_mlp_with_bbox_regression
#    phrase_classifier_hidden_size: None
#    transf_d_model: None
#    transf_nhead: None
#    transf_dim_feedforward: None
#    transf_dropout: 0
#    transf_num_layers: None
#    visual_feature_proj_size: None
#    visual_grounding_hidden_size: 256
#    phrase_mlp_hidden_dims: [256, 128]
#    predict_global_alignment: False
#    alignment_proj_size: None
#    yolov11_model_name_or_path: None
#    yolov11_model_alias: None
#    bbox_format: cxcywh
#    predict_relative_bbox_coords: True
#    optimizer_name: adamw
#    lr: 1e-06
#    scheduler: exp-warmup+decay+cyclicdecay
#    lr_decay: 0.76
#    lr_decay_patience: 2
#    warmup_and_decay_args: None
#    warmup_and_cosine_args: None
#    warmup_decay_and_cyclic_decay_args: 1e-6,3,8e-5,5,3e-6,8e-5,5,3e-6
#    gradient_accumulation_steps: 4
#    override_lr: False
#    max_grad_norm: None
#    attention_supervision_loss_weight: 1.0
#    phrase_classifier_loss_weight: 1.0
#    foreground_loss_weight: 1.0
#    background_loss_weight: 1.0
#    focal_loss_weight: 1.0
#    bce_loss_weight: 1.0
#    wbce_loss_weight: 1.0
#    binary_multilabel_classif_loss_name: focal+bce+npbbce
#    use_weighted_phrase_classifier_loss: False
#    cluster_and_label_weights_for_facts_filepath: None
#    use_attention_regularization_loss: False
#    use_contrastive_phrase_grounding_loss: False
#    nt_xent_temperature: 0.1
#    num_train_workers: 2
#    num_val_workers: 2
#    device: GPU
#    use_amp: False
#    image_size: [384, 384]
#    dicom_id_to_pos_neg_facts_filepath: None
#    iuxray_image_id_to_pos_neg_facts_filepath: None
#    mscxr_phrase2embedding_filepath: /mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/mimiccxr/mscxr_phrase2embedding(hash=36549,2076639799495206637).pkl
#    chest_imagenome_bbox_phrase_embeddings_filepath: None
#    vinbig_phrase_embeddings_filepath: None
#    chexlocalize_class_phrase_embeddings_filepath: None
#    chexpert_class_phrase_embeddings_filepath: None
#    mimiccxr_exclude_noisy_images: False
#    mimiccxr_facts_weight: 1.0
#    chest_imagenome_anatlocs_weight: 1.0
#    mscxr_weight: 1.0
#    cxrlt2024_weight: 1.0
#    vinbig_weight: 1.0
#    chexlocalize_weight: 1.0
#    chexpert_weight: 1.0
#    iuxray_weight: 1.0
#    img_aug_mode: random-color-and-spatial
#    pos_area_prior: 0.4
#    neg_area_prior: 0.0
#    use_mimiccxr_facts_for_train: False
#    use_mimiccxr_facts_for_test: False
#    use_mscxr_for_train: True
#    use_mscxr_for_val: True
#    use_chest_imagenome_for_train: False
#    use_chest_imagenome_gold_for_test: False
#    use_vinbig_for_train: False
#    use_vinbig_for_test: False
#    use_chexlocalize_for_train: False
#    use_chexlocalize_for_test: False
#    use_chexpert_for_train: False
#    use_chexpert_for_test: False
#    use_iuxray_for_train: False
#    use_iuxray_for_test: False
#    use_cxrlt2024_challenge_split: False
#    use_cxrlt2024_custom_labels: False
#    use_cxrlt2024_official_labels: False
#    use_all_cxrlt2024_official_labels_for_training: False
#    vinbig_training_data_mode: train
#    chexpert_training_data_mode: all
#    mimiccxr_balance_long_middle_short_tail: False
#    mimiccxr_long_middle_short_tail_thresholds: (0.02, 0.05)
#    mimiccxr_report_fact_nli_integrated_data_filepath: None
#    mimiccxr_use_interpret_cxr_challenge_split: False
#    mimiccxr_interpret_cxr_challenge_split_filepath: None
#    iuxray_use_interpret_cxr_challenge_split: False
#    iuxray_interpret_cxr_challenge_split_filepath: None
#    chexpert_use_interpret_cxr_challenge_split: False
#    chexpert_interpret_cxr_challenge_split_filepath: None
#    chexlocalize_use_interpret_cxr_challenge_split: False
#    chexlocalize_interpret_cxr_challenge_split_filepath: None
#    cxrlt2024_custom_dicom_id_to_pos_neg_facts_filepath: None
#    cxrlt2024_official_training_labels_for_fact_classification_filepath: None
#    cxrlt2024_do_balanced_sampling: False
#    do_visual_grounding_with_bbox_regression: True
#    do_visual_grounding_with_segmentation: False
#    replace_phrase_embeddings_with_random_vectors: False
#    use_vinbig_with_modified_labels: False
#    mscxr_training_data_mode: all
#    mscxr_do_grounding_only: True
#    save: True
#    override_metric_weights: None
# 2025-05-03 15:33:27,751 - __main__ - INFO - ========== Training model from scratch ==========
# 2025-05-03 15:33:27,752 - __main__ - INFO - include_loss_weights = False
# 2025-05-03 15:33:27,752 - __main__ - INFO - source_image_size_mode: medium_512
# 2025-05-03 15:33:27,795 - __main__ - INFO - device = cuda
# 2025-05-03 15:33:27,795 - __main__ - INFO - ========== Creating instance of PhraseGrounder ==========
# 2025-05-03 15:33:27,795 - medvqa.models.phrase_grounding.phrase_grounder - WARNING - Unused kwargs: {'pretrained_checkpoint_folder_path': '/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250401_191427_mscxr_PhraseGrounder(aehrc-cxrmate-rrg24-uniformer,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/', 'pretrained_checkpoint_folder_paths': None}
# 2025-05-03 15:33:27,796 - medvqa.models.vision.visual_modules - INFO - MultiPurposeVisualModule()
# 2025-05-03 15:33:27,796 - medvqa.models.vision.visual_modules - INFO -   Initializing raw_image_encoder: cxrmate-rrg24-uniformer-huggingface
# 2025-05-03 15:33:33,485 - medvqa.models.vision.visual_modules - INFO -   self.global_feat_size = 1024
# 2025-05-03 15:33:33,486 - medvqa.models.vision.visual_modules - INFO -   self.local_feat_size = 512
# 2025-05-03 15:33:33,486 - medvqa.models.vision.visual_modules - INFO -   Initializing auxiliary tasks
# 2025-05-03 15:33:33,493 - medvqa.models.vision.bbox_regression - INFO - MultiClassBoundingBoxRegressor
# 2025-05-03 15:33:33,493 - medvqa.models.vision.bbox_regression - INFO -   local_feat_dim: 256
# 2025-05-03 15:33:33,493 - medvqa.models.vision.bbox_regression - INFO -   bbox_format: cxcywh
# 2025-05-03 15:33:33,493 - medvqa.models.vision.bbox_regression - INFO -   predict_relative: True
# 2025-05-03 15:33:33,638 - __main__ - INFO - ========== Defining optimizer ==========
# 2025-05-03 15:33:33,638 - medvqa.losses.optimizers - INFO - create_optimizer(): name = adamw, lr = 1e-06
# 2025-05-03 15:33:33,642 - __main__ - INFO - ========== Defining scheduler ==========
# 2025-05-03 15:33:33,642 - medvqa.losses.schedulers - INFO - Using exp-warmup+decay+cyclicdecay scheduler: 1e-6,3,8e-5,5,3e-6,8e-5,5,3e-6
# 2025-05-03 15:33:33,642 - medvqa.losses.schedulers - INFO - lr0 = 1e-06, epochs01 = 3, lr1 = 8e-05, epochs12 = 5, lr2 = 3e-06, lr3 = 8e-05, restart_epochs = 5, lr4 = 3e-06
# 2025-05-03 15:33:33,642 - medvqa.losses.schedulers - INFO - self.steps_to_restart = 5
# 2025-05-03 15:33:33,642 - medvqa.losses.schedulers - INFO - self.steps = -1
# 2025-05-03 15:33:33,642 - medvqa.losses.schedulers - INFO - self.initial_lr = 8e-05
# 2025-05-03 15:33:33,642 - __main__ - INFO - ========== Creating trainer and validator engines ==========
# 2025-05-03 15:33:33,642 - medvqa.losses - INFO - Focal_BCE_NPBBCE_Loss(): focal_weight = 0.3333333333333333, bce_weight = 0.3333333333333333, npbbce_weight = 0.3333333333333333
# 2025-05-03 15:33:33,643 - medvqa.losses - INFO - Focal_BCE_NPBBCE_Loss(): focal_weight = 0.3333333333333333, bce_weight = 0.3333333333333333, npbbce_weight = 0.3333333333333333
# 2025-05-03 15:33:33,643 - medvqa.losses - INFO - Focal_BCE_WBCBCE_Loss(): focal_weight = 0.3333333333333333, bce_weight = 0.3333333333333333, wbcbce_weight = 0.3333333333333333
# 2025-05-03 15:33:33,643 - medvqa.training.phrase_grounding - INFO - foreground_loss_weight: 1.0
# 2025-05-03 15:33:33,643 - medvqa.training.phrase_grounding - INFO - background_loss_weight: 1.0
# 2025-05-03 15:33:33,643 - medvqa.losses.optimizers - INFO - GradientAccumulator.__init__(): num_accumulation_steps = 4, max_grad_norm = None
# 2025-05-03 15:33:33,644 - medvqa.losses - INFO - Focal_BCE_NPBBCE_Loss(): focal_weight = 0.3333333333333333, bce_weight = 0.3333333333333333, npbbce_weight = 0.3333333333333333
# 2025-05-03 15:33:33,644 - medvqa.losses - INFO - Focal_BCE_NPBBCE_Loss(): focal_weight = 0.3333333333333333, bce_weight = 0.3333333333333333, npbbce_weight = 0.3333333333333333
# 2025-05-03 15:33:33,644 - medvqa.losses - INFO - Focal_BCE_WBCBCE_Loss(): focal_weight = 0.3333333333333333, bce_weight = 0.3333333333333333, wbcbce_weight = 0.3333333333333333
# 2025-05-03 15:33:33,645 - medvqa.training.phrase_grounding - INFO - foreground_loss_weight: 1.0
# 2025-05-03 15:33:33,645 - medvqa.training.phrase_grounding - INFO - background_loss_weight: 1.0
# 2025-05-03 15:33:33,645 - __main__ - INFO - ========== Creating MIMIC-CXR Phrase Grounding Trainer ==========
# 2025-05-03 15:33:33,645 - medvqa.datasets.image_transforms_factory - INFO - Building general image transform pipeline (is_train=True, bbox_format=yolo)
# 2025-05-03 15:33:33,646 - medvqa.datasets.image_transforms_factory - INFO - Building general image transform pipeline (is_train=False, bbox_format=None)
# 2025-05-03 15:33:33,646 - medvqa.datasets.mimiccxr.mimiccxr_phrase_grounding_dataset_management - WARNING - unused kwargs in MIMICCXR_PhraseGroundingTrainer: {'use_yolov8': False}
# 2025-05-03 15:33:33,663 - medvqa.datasets.mimiccxr.mimiccxr_phrase_grounding_dataset_management - INFO - len(forbidden_train_dicom_ids) = 310
# 2025-05-03 15:33:33,663 - medvqa.datasets.mimiccxr.mimiccxr_phrase_grounding_dataset_management - INFO - Preparing MS-CXR dataset and dataloaders for train, val (grounding only) ...
# 2025-05-03 15:33:33,790 - medvqa.datasets.mimiccxr.mimiccxr_phrase_grounding_dataset_management - INFO - len(dicom_id_2_phrases_and_bboxes) = 1047
# 2025-05-03 15:33:33,793 - medvqa.datasets.mimiccxr.mimiccxr_phrase_grounding_dataset_management - INFO - len(phrase2embedding) = 715
# 2025-05-03 15:33:33,793 - medvqa.datasets.mimiccxr.mimiccxr_phrase_grounding_dataset_management - INFO - phrase_embeddings.shape = (715, 128)
# 2025-05-03 15:33:33,796 - medvqa.datasets.mimiccxr - INFO - Using image size mode: medium_512
# 227835it [00:00, 334180.40it/s]
# 2025-05-03 15:33:35,639 - medvqa.datasets.mimiccxr.mimiccxr_phrase_grounding_dataset_management - INFO - Total number of instances: 1160
# 2025-05-03 15:33:35,639 - medvqa.datasets.mimiccxr.mimiccxr_phrase_grounding_dataset_management - INFO - len(train_indices) = 815
# 2025-05-03 15:33:35,639 - medvqa.datasets.mimiccxr.mimiccxr_phrase_grounding_dataset_management - INFO - Building train fact dataloader...
# 2025-05-03 15:33:35,639 - medvqa.datasets.mimiccxr.mimiccxr_phrase_grounding_dataset_management - INFO - batch_size = 11
# 2025-05-03 15:33:35,640 - medvqa.datasets.mimiccxr.mimiccxr_phrase_grounding_dataset_management - INFO - len(self.mscxr_train_dataset) = 1160
# 2025-05-03 15:33:35,640 - medvqa.datasets.mimiccxr.mimiccxr_phrase_grounding_dataset_management - INFO - len(self.mscxr_train_dataloader) = 106
# 2025-05-03 15:33:35,640 - medvqa.datasets.mimiccxr.mimiccxr_phrase_grounding_dataset_management - INFO - len(val_indices) = 169
# 2025-05-03 15:33:35,640 - medvqa.datasets.mimiccxr.mimiccxr_phrase_grounding_dataset_management - INFO - Building val fact dataloader...
# 2025-05-03 15:33:35,640 - medvqa.datasets.mimiccxr.mimiccxr_phrase_grounding_dataset_management - INFO - batch_size = 22
# 2025-05-03 15:33:35,640 - medvqa.datasets.mimiccxr.mimiccxr_phrase_grounding_dataset_management - INFO - len(self.mscxr_val_dataset) = 169
# 2025-05-03 15:33:35,640 - medvqa.datasets.mimiccxr.mimiccxr_phrase_grounding_dataset_management - INFO - len(self.mscxr_val_dataloader) = 8
# 2025-05-03 15:33:35,641 - __main__ - INFO - ========== Creating dataloaders ==========
# 2025-05-03 15:33:35,641 - __main__ - INFO - len(mimiccxr_trainer.mscxr_dataloader) = 106
# 2025-05-03 15:33:35,641 - __main__ - INFO - len(mimiccxr_trainer.mscxr_val_dataloader) = 8
# 2025-05-03 15:33:35,641 - __main__ - INFO - len(_train_dataloaders) = 1
# 2025-05-03 15:33:35,641 - __main__ - INFO - len(_val_dataloaders) = 1
# 2025-05-03 15:33:35,641 - __main__ - INFO - _train_weights = [1.0]
# 2025-05-03 15:33:35,641 - __main__ - INFO - merged_dataset_name = mscxr
# 2025-05-03 15:33:35,641 - __main__ - INFO - ========== Attaching metrics, losses, timer and events to engines ==========
# 2025-05-03 15:33:35,647 - medvqa.training.utils - INFO - ========== Defining learning rate scheduler handler ==========
# 2025-05-03 15:33:35,647 - medvqa.training.utils - INFO - ========== Defining checkpoint folder path ==========
# 2025-05-03 15:33:35,648 - medvqa.training.utils - INFO - checkpoint_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250503_153335_mscxr_PhraseGrounder(aehrc-cxrmate-rrg24-uniformer,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)
# metadata saved to /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250503_153335_mscxr_PhraseGrounder(aehrc-cxrmate-rrg24-uniformer,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/metadata.json
# 2025-05-03 15:33:35,648 - medvqa.training.utils - INFO - ========== Loading pretrained weights ==========
# checkpoint_names = ['checkpoint_99_msss+msou+msss=0.6672.pt', 'checkpoint_134_msss+msou+msss=0.6989.pt', 'checkpoint_194_msss+msou+msss=0.7303.pt']
# 2025-05-03 15:33:35,648 - medvqa.training.utils - INFO - pretrained_checkpoint_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250401_191427_mscxr_PhraseGrounder(aehrc-cxrmate-rrg24-uniformer,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/checkpoint_194_msss+msou+msss=0.7303.pt
# 2025-05-03 15:33:36,221 - medvqa.training.utils - INFO - Checkpoint successfully loaded!
# 2025-05-03 15:33:36,221 - medvqa.training.utils - INFO - ========== Defining log_metrics_handler ==========
# MetricsLogger :: we'll be logging to /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250503_153335_mscxr_PhraseGrounder(aehrc-cxrmate-rrg24-uniformer,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/metrics_logs.csv
# 2025-05-03 15:33:36,222 - medvqa.training.utils - INFO - ========== Running trainer engine ==========
# 2025-05-03 15:33:36,222 - ignite.engine.engine.Engine - INFO - Engine run starting with max_epochs=30.
# 2025-05-03 15:33:36,222 - medvqa.utils.handlers_utils - INFO - ==================== Epoch 1/30 ====================
# 2025-05-03 15:33:36,223 - medvqa.training.utils - INFO - (1) Training stage (lr = 0.000001) ...
# Training [1/30]: [200/200] 100%|███████████, loss=0.0951 [01:30<00:00]
# 2025-05-03 15:35:08,408 - medvqa.utils.handlers_utils - INFO - loss 0.08819, mscxr_vgconf_loss 0.08427, mscxr_vgbbox_loss 0.00393, 92.19 secs
# 2025-05-03 15:35:08,408 - medvqa.training.utils - INFO - (2) Validation stage ...
# 2025-05-03 15:35:08,410 - ignite.engine.engine.Engine - INFO - Engine run starting with max_epochs=1.
# Validation: [8/8] 100%|█████████████ [00:02<00:00]
# 2025-05-03 15:35:11,616 - medvqa.utils.handlers_utils - INFO - mscxr_bbox_iou 0.71549, 3.21 secs
# Train metrics:
# mscxr_vgconf_loss: 0.9223, weight = 1.0
# mscxr_vgbbox_loss: 0.9961, weight = 1.0
# num = 1.9184, den = 2.0000, score = 0.9592
# Val metrics:
# mscxr_bbox_iou: 0.7155, weight = 1.0
# num = 0.7155, den = 1.0000, score = 0.7155
# Train score = 0.9592, Val score = 0.7155, Final score = 0.7277
# w_train = 0.05, w_val = 0.95
# 2025-05-03 15:35:12,329 - medvqa.utils.handlers_utils - INFO - New checkpoint saved: checkpoint_1_mscxr_bbox_iou+mscxr_vgbbox_loss+mscxr_vgconf_loss=0.7277.pt
# 2025-05-03 15:35:12,329 - ignite.engine.engine.Engine - INFO - Epoch[1] Complete. Time taken: 00:00:03.919
# 2025-05-03 15:35:12,329 - ignite.engine.engine.Engine - INFO - Engine run complete. Time taken: 00:00:03.919
# 2025-05-03 15:35:12,330 - ignite.engine.engine.Engine - INFO - Epoch[1] Complete. Time taken: 00:01:36.038
# 2025-05-03 15:35:12,330 - medvqa.utils.handlers_utils - INFO - ==================== Epoch 2/30 ====================
# 2025-05-03 15:35:12,330 - medvqa.training.utils - INFO - (1) Training stage (lr = 0.000004) ...
# Training [2/30]: [200/200] 100%|███████████, loss=0.0657 [01:27<00:00]
# 2025-05-03 15:36:40,489 - medvqa.utils.handlers_utils - INFO - loss 0.07900, mscxr_vgconf_loss 0.07449, mscxr_vgbbox_loss 0.00450, 88.16 secs
# 2025-05-03 15:36:40,490 - medvqa.training.utils - INFO - (2) Validation stage ...
# 2025-05-03 15:36:40,491 - ignite.engine.engine.Engine - INFO - Engine run starting with max_epochs=1.
# Validation: [8/8] 100%|█████████████ [00:02<00:00]
# 2025-05-03 15:36:43,601 - medvqa.utils.handlers_utils - INFO - mscxr_bbox_iou 0.70853, 3.11 secs
# 2025-05-03 15:36:43,602 - ignite.engine.engine.Engine - INFO - Epoch[1] Complete. Time taken: 00:00:03.111
# 2025-05-03 15:36:43,602 - ignite.engine.engine.Engine - INFO - Engine run complete. Time taken: 00:00:03.112
# 2025-05-03 15:36:43,603 - ignite.engine.engine.Engine - INFO - Epoch[2] Complete. Time taken: 00:01:31.273
# 2025-05-03 15:36:43,603 - medvqa.utils.handlers_utils - INFO - ==================== Epoch 3/30 ====================
# 2025-05-03 15:36:43,603 - medvqa.training.utils - INFO - (1) Training stage (lr = 0.000019) ...
# Training [3/30]: [200/200] 100%|███████████, loss=0.0861 [01:27<00:00]
# 2025-05-03 15:38:12,025 - medvqa.utils.handlers_utils - INFO - loss 0.06749, mscxr_vgconf_loss 0.06323, mscxr_vgbbox_loss 0.00426, 88.42 secs
# 2025-05-03 15:38:12,025 - medvqa.training.utils - INFO - (2) Validation stage ...
# 2025-05-03 15:38:12,026 - ignite.engine.engine.Engine - INFO - Engine run starting with max_epochs=1.
# Validation: [8/8] 100%|█████████████ [00:02<00:00]
# 2025-05-03 15:38:15,014 - medvqa.utils.handlers_utils - INFO - mscxr_bbox_iou 0.70711, 2.99 secs
# 2025-05-03 15:38:15,015 - ignite.engine.engine.Engine - INFO - Epoch[1] Complete. Time taken: 00:00:02.988
# 2025-05-03 15:38:15,015 - ignite.engine.engine.Engine - INFO - Engine run complete. Time taken: 00:00:02.989
# 2025-05-03 15:38:15,015 - ignite.engine.engine.Engine - INFO - Epoch[3] Complete. Time taken: 00:01:31.412
# 2025-05-03 15:38:15,016 - medvqa.utils.handlers_utils - INFO - ==================== Epoch 4/30 ====================
# 2025-05-03 15:38:15,016 - medvqa.training.utils - INFO - (1) Training stage (lr = 0.000080) ...
# Training [4/30]: [200/200] 100%|████████████, loss=0.046 [01:27<00:00]
# 2025-05-03 15:39:43,024 - medvqa.utils.handlers_utils - INFO - loss 0.05846, mscxr_vgconf_loss 0.05444, mscxr_vgbbox_loss 0.00402, 88.01 secs
# 2025-05-03 15:39:43,025 - medvqa.training.utils - INFO - (2) Validation stage ...
# 2025-05-03 15:39:43,025 - ignite.engine.engine.Engine - INFO - Engine run starting with max_epochs=1.
# Validation: [8/8] 100%|█████████████ [00:02<00:00]
# 2025-05-03 15:39:46,064 - medvqa.utils.handlers_utils - INFO - mscxr_bbox_iou 0.71225, 3.04 secs
# 2025-05-03 15:39:46,065 - ignite.engine.engine.Engine - INFO - Epoch[1] Complete. Time taken: 00:00:03.039
# 2025-05-03 15:39:46,065 - ignite.engine.engine.Engine - INFO - Engine run complete. Time taken: 00:00:03.039
# 2025-05-03 15:39:46,066 - ignite.engine.engine.Engine - INFO - Epoch[4] Complete. Time taken: 00:01:31.050
# 2025-05-03 15:39:46,066 - medvqa.utils.handlers_utils - INFO - ==================== Epoch 5/30 ====================
# 2025-05-03 15:39:46,066 - medvqa.training.utils - INFO - (1) Training stage (lr = 0.000041) ...
# Training [5/30]: [200/200] 100%|███████████, loss=0.0469 [01:27<00:00]
# 2025-05-03 15:41:13,590 - medvqa.utils.handlers_utils - INFO - loss 0.05251, mscxr_vgconf_loss 0.04828, mscxr_vgbbox_loss 0.00423, 87.52 secs
# 2025-05-03 15:41:13,591 - medvqa.training.utils - INFO - (2) Validation stage ...
# 2025-05-03 15:41:13,591 - ignite.engine.engine.Engine - INFO - Engine run starting with max_epochs=1.
# Validation: [8/8] 100%|█████████████ [00:02<00:00]
# 2025-05-03 15:41:16,672 - medvqa.utils.handlers_utils - INFO - mscxr_bbox_iou 0.72185, 3.08 secs
# 2025-05-03 15:41:17,430 - medvqa.utils.handlers_utils - INFO - New checkpoint saved: checkpoint_5_mscxr_bbox_iou+mscxr_vgbbox_loss+mscxr_vgconf_loss=0.7345.pt
# 2025-05-03 15:41:17,430 - ignite.engine.engine.Engine - INFO - Epoch[1] Complete. Time taken: 00:00:03.839
# 2025-05-03 15:41:17,431 - ignite.engine.engine.Engine - INFO - Engine run complete. Time taken: 00:00:03.839
# 2025-05-03 15:41:17,431 - ignite.engine.engine.Engine - INFO - Epoch[5] Complete. Time taken: 00:01:31.365
# 2025-05-03 15:41:17,431 - medvqa.utils.handlers_utils - INFO - ==================== Epoch 6/30 ====================
# 2025-05-03 15:41:17,432 - medvqa.training.utils - INFO - (1) Training stage (lr = 0.000022) ...
# Training [6/30]: [200/200] 100%|███████████, loss=0.0494 [01:27<00:00]
# 2025-05-03 15:42:45,200 - medvqa.utils.handlers_utils - INFO - loss 0.04631, mscxr_vgconf_loss 0.04237, mscxr_vgbbox_loss 0.00394, 87.77 secs
# 2025-05-03 15:42:45,201 - medvqa.training.utils - INFO - (2) Validation stage ...
# 2025-05-03 15:42:45,201 - ignite.engine.engine.Engine - INFO - Engine run starting with max_epochs=1.
# Validation: [8/8] 100%|█████████████ [00:02<00:00]
# 2025-05-03 15:42:48,220 - medvqa.utils.handlers_utils - INFO - mscxr_bbox_iou 0.71996, 3.02 secs
# 2025-05-03 15:42:48,221 - ignite.engine.engine.Engine - INFO - Epoch[1] Complete. Time taken: 00:00:03.019
# 2025-05-03 15:42:48,221 - ignite.engine.engine.Engine - INFO - Engine run complete. Time taken: 00:00:03.020
# 2025-05-03 15:42:48,222 - ignite.engine.engine.Engine - INFO - Epoch[6] Complete. Time taken: 00:01:30.791
# 2025-05-03 15:42:48,222 - medvqa.utils.handlers_utils - INFO - ==================== Epoch 7/30 ====================
# 2025-05-03 15:42:48,222 - medvqa.training.utils - INFO - (1) Training stage (lr = 0.000011) ...
# Training [7/30]: [200/200] 100%|███████████, loss=0.0429 [01:27<00:00]
# 2025-05-03 15:44:16,259 - medvqa.utils.handlers_utils - INFO - loss 0.04648, mscxr_vgconf_loss 0.04236, mscxr_vgbbox_loss 0.00412, 88.04 secs
# 2025-05-03 15:44:16,259 - medvqa.training.utils - INFO - (2) Validation stage ...
# 2025-05-03 15:44:16,260 - ignite.engine.engine.Engine - INFO - Engine run starting with max_epochs=1.
# Validation: [8/8] 100%|█████████████ [00:02<00:00]
# 2025-05-03 15:44:19,353 - medvqa.utils.handlers_utils - INFO - mscxr_bbox_iou 0.72142, 3.09 secs
# 2025-05-03 15:44:19,354 - ignite.engine.engine.Engine - INFO - Epoch[1] Complete. Time taken: 00:00:03.094
# 2025-05-03 15:44:19,354 - ignite.engine.engine.Engine - INFO - Engine run complete. Time taken: 00:00:03.094
# 2025-05-03 15:44:19,355 - ignite.engine.engine.Engine - INFO - Epoch[7] Complete. Time taken: 00:01:31.133
# 2025-05-03 15:44:19,355 - medvqa.utils.handlers_utils - INFO - ==================== Epoch 8/30 ====================
# 2025-05-03 15:44:19,355 - medvqa.training.utils - INFO - (1) Training stage (lr = 0.000006) ...
# Training [8/30]: [200/200] 100%|████████████, loss=0.063 [01:27<00:00]
# 2025-05-03 15:45:47,387 - medvqa.utils.handlers_utils - INFO - loss 0.04501, mscxr_vgconf_loss 0.04106, mscxr_vgbbox_loss 0.00395, 88.03 secs
# 2025-05-03 15:45:47,388 - medvqa.training.utils - INFO - (2) Validation stage ...
# 2025-05-03 15:45:47,388 - ignite.engine.engine.Engine - INFO - Engine run starting with max_epochs=1.
# Validation: [8/8] 100%|█████████████ [00:02<00:00]
# 2025-05-03 15:45:50,435 - medvqa.utils.handlers_utils - INFO - mscxr_bbox_iou 0.72666, 3.05 secs
# 2025-05-03 15:45:51,200 - medvqa.utils.handlers_utils - INFO - New checkpoint saved: checkpoint_8_mscxr_bbox_iou+mscxr_vgbbox_loss+mscxr_vgconf_loss=0.7392.pt
# 2025-05-03 15:45:51,201 - ignite.engine.engine.Engine - INFO - Epoch[1] Complete. Time taken: 00:00:03.812
# 2025-05-03 15:45:51,201 - ignite.engine.engine.Engine - INFO - Engine run complete. Time taken: 00:00:03.812
# 2025-05-03 15:45:51,201 - ignite.engine.engine.Engine - INFO - Epoch[8] Complete. Time taken: 00:01:31.846
# 2025-05-03 15:45:51,202 - medvqa.utils.handlers_utils - INFO - ==================== Epoch 9/30 ====================
# 2025-05-03 15:45:51,202 - medvqa.training.utils - INFO - (1) Training stage (lr = 0.000003) ...
# Training [9/30]: [200/200] 100%|███████████, loss=0.0327 [01:30<00:00]
# 2025-05-03 15:47:22,274 - medvqa.utils.handlers_utils - INFO - loss 0.04408, mscxr_vgconf_loss 0.04009, mscxr_vgbbox_loss 0.00400, 91.07 secs
# 2025-05-03 15:47:22,275 - medvqa.training.utils - INFO - (2) Validation stage ...
# 2025-05-03 15:47:22,275 - ignite.engine.engine.Engine - INFO - Engine run starting with max_epochs=1.
# Validation: [8/8] 100%|█████████████ [00:02<00:00]
# 2025-05-03 15:47:25,310 - medvqa.utils.handlers_utils - INFO - mscxr_bbox_iou 0.72295, 3.03 secs
# 2025-05-03 15:47:25,311 - ignite.engine.engine.Engine - INFO - Epoch[1] Complete. Time taken: 00:00:03.036
# 2025-05-03 15:47:25,311 - ignite.engine.engine.Engine - INFO - Engine run complete. Time taken: 00:00:03.036
# 2025-05-03 15:47:25,312 - ignite.engine.engine.Engine - INFO - Epoch[9] Complete. Time taken: 00:01:34.110
# 2025-05-03 15:47:25,312 - medvqa.utils.handlers_utils - INFO - ==================== Epoch 10/30 ====================
# 2025-05-03 15:47:25,312 - medvqa.training.utils - INFO - (1) Training stage (lr = 0.000080) ...
# Training [10/30]: [200/200] 100%|██████████, loss=0.0489 [01:31<00:00]
# 2025-05-03 15:48:57,461 - medvqa.utils.handlers_utils - INFO - loss 0.04635, mscxr_vgconf_loss 0.04223, mscxr_vgbbox_loss 0.00412, 92.15 secs
# 2025-05-03 15:48:57,461 - medvqa.training.utils - INFO - (2) Validation stage ...
# 2025-05-03 15:48:57,462 - ignite.engine.engine.Engine - INFO - Engine run starting with max_epochs=1.
# Validation: [8/8] 100%|█████████████ [00:02<00:00]
# 2025-05-03 15:49:00,541 - medvqa.utils.handlers_utils - INFO - mscxr_bbox_iou 0.67712, 3.08 secs
# 2025-05-03 15:49:00,542 - ignite.engine.engine.Engine - INFO - Epoch[1] Complete. Time taken: 00:00:03.080
# 2025-05-03 15:49:00,542 - ignite.engine.engine.Engine - INFO - Engine run complete. Time taken: 00:00:03.080
# 2025-05-03 15:49:00,543 - ignite.engine.engine.Engine - INFO - Epoch[10] Complete. Time taken: 00:01:35.231
# 2025-05-03 15:49:00,543 - medvqa.utils.handlers_utils - INFO - ==================== Epoch 11/30 ====================
# 2025-05-03 15:49:00,543 - medvqa.training.utils - INFO - (1) Training stage (lr = 0.000035) ...
# Training [11/30]: [200/200] 100%|███████████, loss=0.039 [01:31<00:00]
# 2025-05-03 15:50:32,712 - medvqa.utils.handlers_utils - INFO - loss 0.04328, mscxr_vgconf_loss 0.03935, mscxr_vgbbox_loss 0.00393, 92.17 secs
# 2025-05-03 15:50:32,712 - medvqa.training.utils - INFO - (2) Validation stage ...
# 2025-05-03 15:50:32,713 - ignite.engine.engine.Engine - INFO - Engine run starting with max_epochs=1.
# Validation: [8/8] 100%|█████████████ [00:02<00:00]
# 2025-05-03 15:50:35,772 - medvqa.utils.handlers_utils - INFO - mscxr_bbox_iou 0.71097, 3.06 secs
# 2025-05-03 15:50:35,773 - ignite.engine.engine.Engine - INFO - Epoch[1] Complete. Time taken: 00:00:03.060
# 2025-05-03 15:50:35,773 - ignite.engine.engine.Engine - INFO - Engine run complete. Time taken: 00:00:03.060
# 2025-05-03 15:50:35,774 - ignite.engine.engine.Engine - INFO - Epoch[11] Complete. Time taken: 00:01:35.231
# 2025-05-03 15:50:35,774 - medvqa.utils.handlers_utils - INFO - ==================== Epoch 12/30 ====================
# 2025-05-03 15:50:35,774 - medvqa.training.utils - INFO - (1) Training stage (lr = 0.000015) ...
# Training [12/30]: [200/200] 100%|██████████, loss=0.0395 [01:31<00:00]
# 2025-05-03 15:52:07,575 - medvqa.utils.handlers_utils - INFO - loss 0.04002, mscxr_vgconf_loss 0.03608, mscxr_vgbbox_loss 0.00394, 91.80 secs
# 2025-05-03 15:52:07,575 - medvqa.training.utils - INFO - (2) Validation stage ...
# 2025-05-03 15:52:07,576 - ignite.engine.engine.Engine - INFO - Engine run starting with max_epochs=1.
# Validation: [8/8] 100%|█████████████ [00:02<00:00]
# 2025-05-03 15:52:10,603 - medvqa.utils.handlers_utils - INFO - mscxr_bbox_iou 0.71937, 3.03 secs
# 2025-05-03 15:52:10,604 - ignite.engine.engine.Engine - INFO - Epoch[1] Complete. Time taken: 00:00:03.028
# 2025-05-03 15:52:10,604 - ignite.engine.engine.Engine - INFO - Engine run complete. Time taken: 00:00:03.028
# 2025-05-03 15:52:10,605 - ignite.engine.engine.Engine - INFO - Epoch[12] Complete. Time taken: 00:01:34.831
# 2025-05-03 15:52:10,605 - medvqa.utils.handlers_utils - INFO - ==================== Epoch 13/30 ====================
# 2025-05-03 15:52:10,605 - medvqa.training.utils - INFO - (1) Training stage (lr = 0.000007) ...
# Training [13/30]: [200/200] 100%|██████████, loss=0.0293 [01:32<00:00]
# 2025-05-03 15:53:43,294 - medvqa.utils.handlers_utils - INFO - loss 0.03964, mscxr_vgconf_loss 0.03571, mscxr_vgbbox_loss 0.00394, 92.69 secs
# 2025-05-03 15:53:43,294 - medvqa.training.utils - INFO - (2) Validation stage ...
# 2025-05-03 15:53:43,295 - ignite.engine.engine.Engine - INFO - Engine run starting with max_epochs=1.
# Validation: [8/8] 100%|█████████████ [00:02<00:00]
# 2025-05-03 15:53:46,344 - medvqa.utils.handlers_utils - INFO - mscxr_bbox_iou 0.72032, 3.05 secs
# 2025-05-03 15:53:46,345 - ignite.engine.engine.Engine - INFO - Epoch[1] Complete. Time taken: 00:00:03.050
# 2025-05-03 15:53:46,345 - ignite.engine.engine.Engine - INFO - Engine run complete. Time taken: 00:00:03.050
# 2025-05-03 15:53:46,346 - ignite.engine.engine.Engine - INFO - Epoch[13] Complete. Time taken: 00:01:35.741
# 2025-05-03 15:53:46,346 - medvqa.utils.handlers_utils - INFO - ==================== Epoch 14/30 ====================
# 2025-05-03 15:53:46,346 - medvqa.training.utils - INFO - (1) Training stage (lr = 0.000003) ...
# Training [14/30]: [200/200] 100%|██████████, loss=0.0373 [01:32<00:00]
# 2025-05-03 15:55:18,835 - medvqa.utils.handlers_utils - INFO - loss 0.03914, mscxr_vgconf_loss 0.03546, mscxr_vgbbox_loss 0.00368, 92.49 secs
# 2025-05-03 15:55:18,836 - medvqa.training.utils - INFO - (2) Validation stage ...
# 2025-05-03 15:55:18,837 - ignite.engine.engine.Engine - INFO - Engine run starting with max_epochs=1.
# Validation: [8/8] 100%|█████████████ [00:02<00:00]
# 2025-05-03 15:55:21,875 - medvqa.utils.handlers_utils - INFO - mscxr_bbox_iou 0.72217, 3.04 secs
# 2025-05-03 15:55:21,876 - ignite.engine.engine.Engine - INFO - Epoch[1] Complete. Time taken: 00:00:03.039
# 2025-05-03 15:55:21,876 - ignite.engine.engine.Engine - INFO - Engine run complete. Time taken: 00:00:03.039
# 2025-05-03 15:55:21,876 - ignite.engine.engine.Engine - INFO - Epoch[14] Complete. Time taken: 00:01:35.530
# 2025-05-03 15:55:21,877 - medvqa.utils.handlers_utils - INFO - ==================== Epoch 15/30 ====================
# 2025-05-03 15:55:21,877 - medvqa.training.utils - INFO - (1) Training stage (lr = 0.000080) ...
# Training [15/30]: [200/200] 100%|██████████, loss=0.0585 [01:32<00:00]
# 2025-05-03 15:56:54,393 - medvqa.utils.handlers_utils - INFO - loss 0.04171, mscxr_vgconf_loss 0.03752, mscxr_vgbbox_loss 0.00418, 92.52 secs
# 2025-05-03 15:56:54,393 - medvqa.training.utils - INFO - (2) Validation stage ...
# 2025-05-03 15:56:54,394 - ignite.engine.engine.Engine - INFO - Engine run starting with max_epochs=1.
# Validation: [8/8] 100%|█████████████ [00:02<00:00]
# 2025-05-03 15:56:57,423 - medvqa.utils.handlers_utils - INFO - mscxr_bbox_iou 0.70834, 3.03 secs
# 2025-05-03 15:56:57,423 - ignite.engine.engine.Engine - INFO - Epoch[1] Complete. Time taken: 00:00:03.029
# 2025-05-03 15:56:57,423 - ignite.engine.engine.Engine - INFO - Engine run complete. Time taken: 00:00:03.030
# 2025-05-03 15:56:57,424 - ignite.engine.engine.Engine - INFO - Epoch[15] Complete. Time taken: 00:01:35.547
# 2025-05-03 15:56:57,424 - medvqa.utils.handlers_utils - INFO - ==================== Epoch 16/30 ====================
# 2025-05-03 15:56:57,424 - medvqa.training.utils - INFO - (1) Training stage (lr = 0.000035) ...
# Training [16/30]: [200/200] 100%|███████████, loss=0.032 [01:32<00:00]
# 2025-05-03 15:58:30,059 - medvqa.utils.handlers_utils - INFO - loss 0.03857, mscxr_vgconf_loss 0.03452, mscxr_vgbbox_loss 0.00405, 92.64 secs
# 2025-05-03 15:58:30,060 - medvqa.training.utils - INFO - (2) Validation stage ...
# 2025-05-03 15:58:30,060 - ignite.engine.engine.Engine - INFO - Engine run starting with max_epochs=1.
# Validation: [8/8] 100%|█████████████ [00:02<00:00]
# 2025-05-03 15:58:33,161 - medvqa.utils.handlers_utils - INFO - mscxr_bbox_iou 0.71251, 3.10 secs
# 2025-05-03 15:58:33,162 - ignite.engine.engine.Engine - INFO - Epoch[1] Complete. Time taken: 00:00:03.101
# 2025-05-03 15:58:33,162 - ignite.engine.engine.Engine - INFO - Engine run complete. Time taken: 00:00:03.101
# 2025-05-03 15:58:33,163 - ignite.engine.engine.Engine - INFO - Epoch[16] Complete. Time taken: 00:01:35.738
# 2025-05-03 15:58:33,163 - medvqa.utils.handlers_utils - INFO - ==================== Epoch 17/30 ====================
# 2025-05-03 15:58:33,163 - medvqa.training.utils - INFO - (1) Training stage (lr = 0.000015) ...
# Training [17/30]: [200/200] 100%|██████████, loss=0.0367 [01:32<00:00]
# 2025-05-03 16:00:05,902 - medvqa.utils.handlers_utils - INFO - loss 0.03679, mscxr_vgconf_loss 0.03304, mscxr_vgbbox_loss 0.00375, 92.74 secs
# 2025-05-03 16:00:05,903 - medvqa.training.utils - INFO - (2) Validation stage ...
# 2025-05-03 16:00:05,904 - ignite.engine.engine.Engine - INFO - Engine run starting with max_epochs=1.
# Validation: [8/8] 100%|█████████████ [00:02<00:00]
# 2025-05-03 16:00:09,008 - medvqa.utils.handlers_utils - INFO - mscxr_bbox_iou 0.72287, 3.10 secs
# 2025-05-03 16:00:09,008 - ignite.engine.engine.Engine - INFO - Epoch[1] Complete. Time taken: 00:00:03.104
# 2025-05-03 16:00:09,008 - ignite.engine.engine.Engine - INFO - Engine run complete. Time taken: 00:00:03.105
# 2025-05-03 16:00:09,009 - ignite.engine.engine.Engine - INFO - Epoch[17] Complete. Time taken: 00:01:35.846
# 2025-05-03 16:00:09,009 - medvqa.utils.handlers_utils - INFO - ==================== Epoch 18/30 ====================
# 2025-05-03 16:00:09,009 - medvqa.training.utils - INFO - (1) Training stage (lr = 0.000007) ...
# Training [18/30]: [200/200] 100%|██████████, loss=0.0616 [01:32<00:00]
# 2025-05-03 16:01:41,957 - medvqa.utils.handlers_utils - INFO - loss 0.03412, mscxr_vgconf_loss 0.03047, mscxr_vgbbox_loss 0.00365, 92.95 secs
# 2025-05-03 16:01:41,957 - medvqa.training.utils - INFO - (2) Validation stage ...
# 2025-05-03 16:01:41,958 - ignite.engine.engine.Engine - INFO - Engine run starting with max_epochs=1.
# Validation: [8/8] 100%|█████████████ [00:02<00:00]
# 2025-05-03 16:01:45,088 - medvqa.utils.handlers_utils - INFO - mscxr_bbox_iou 0.72324, 3.13 secs
# 2025-05-03 16:01:45,089 - ignite.engine.engine.Engine - INFO - Epoch[1] Complete. Time taken: 00:00:03.131
# 2025-05-03 16:01:45,089 - ignite.engine.engine.Engine - INFO - Engine run complete. Time taken: 00:00:03.131
# 2025-05-03 16:01:45,090 - ignite.engine.engine.Engine - INFO - Epoch[18] Complete. Time taken: 00:01:36.080
# 2025-05-03 16:01:45,090 - medvqa.utils.handlers_utils - INFO - ==================== Epoch 19/30 ====================
# 2025-05-03 16:01:45,090 - medvqa.training.utils - INFO - (1) Training stage (lr = 0.000003) ...
# Training [19/30]: [200/200] 100%|██████████, loss=0.0247 [01:33<00:00]
# 2025-05-03 16:03:19,044 - medvqa.utils.handlers_utils - INFO - loss 0.03541, mscxr_vgconf_loss 0.03176, mscxr_vgbbox_loss 0.00365, 93.95 secs
# 2025-05-03 16:03:19,044 - medvqa.training.utils - INFO - (2) Validation stage ...
# 2025-05-03 16:03:19,045 - ignite.engine.engine.Engine - INFO - Engine run starting with max_epochs=1.
# Validation: [8/8] 100%|█████████████ [00:02<00:00]
# 2025-05-03 16:03:22,123 - medvqa.utils.handlers_utils - INFO - mscxr_bbox_iou 0.72321, 3.08 secs
# 2025-05-03 16:03:22,124 - ignite.engine.engine.Engine - INFO - Epoch[1] Complete. Time taken: 00:00:03.079
# 2025-05-03 16:03:22,124 - ignite.engine.engine.Engine - INFO - Engine run complete. Time taken: 00:00:03.079
# 2025-05-03 16:03:22,125 - ignite.engine.engine.Engine - INFO - Epoch[19] Complete. Time taken: 00:01:37.035
# 2025-05-03 16:03:22,125 - medvqa.utils.handlers_utils - INFO - ==================== Epoch 20/30 ====================
# 2025-05-03 16:03:22,125 - medvqa.training.utils - INFO - (1) Training stage (lr = 0.000080) ...
# Training [20/30]: [200/200] 100%|██████████, loss=0.0256 [01:33<00:00]
# 2025-05-03 16:04:55,990 - medvqa.utils.handlers_utils - INFO - loss 0.03954, mscxr_vgconf_loss 0.03541, mscxr_vgbbox_loss 0.00413, 93.86 secs
# 2025-05-03 16:04:55,991 - medvqa.training.utils - INFO - (2) Validation stage ...
# 2025-05-03 16:04:55,991 - ignite.engine.engine.Engine - INFO - Engine run starting with max_epochs=1.
# Validation: [8/8] 100%|█████████████ [00:02<00:00]
# 2025-05-03 16:04:58,996 - medvqa.utils.handlers_utils - INFO - mscxr_bbox_iou 0.71419, 3.00 secs
# 2025-05-03 16:04:58,997 - ignite.engine.engine.Engine - INFO - Epoch[1] Complete. Time taken: 00:00:03.005
# 2025-05-03 16:04:58,997 - ignite.engine.engine.Engine - INFO - Engine run complete. Time taken: 00:00:03.005
# 2025-05-03 16:04:58,997 - ignite.engine.engine.Engine - INFO - Epoch[20] Complete. Time taken: 00:01:36.872
# 2025-05-03 16:04:58,998 - medvqa.utils.handlers_utils - INFO - ==================== Epoch 21/30 ====================
# 2025-05-03 16:04:58,998 - medvqa.training.utils - INFO - (1) Training stage (lr = 0.000035) ...
# Training [21/30]: [200/200] 100%|██████████, loss=0.0373 [01:33<00:00]
# 2025-05-03 16:06:32,562 - medvqa.utils.handlers_utils - INFO - loss 0.03826, mscxr_vgconf_loss 0.03445, mscxr_vgbbox_loss 0.00381, 93.56 secs
# 2025-05-03 16:06:32,562 - medvqa.training.utils - INFO - (2) Validation stage ...
# 2025-05-03 16:06:32,563 - ignite.engine.engine.Engine - INFO - Engine run starting with max_epochs=1.
# Validation: [8/8] 100%|█████████████ [00:02<00:00]
# 2025-05-03 16:06:35,666 - medvqa.utils.handlers_utils - INFO - mscxr_bbox_iou 0.72868, 3.10 secs
# 2025-05-03 16:06:36,444 - medvqa.utils.handlers_utils - INFO - New checkpoint saved: checkpoint_21_mscxr_bbox_iou+mscxr_vgbbox_loss+mscxr_vgconf_loss=0.7413.pt
# 2025-05-03 16:06:36,444 - ignite.engine.engine.Engine - INFO - Epoch[1] Complete. Time taken: 00:00:03.881
# 2025-05-03 16:06:36,444 - ignite.engine.engine.Engine - INFO - Engine run complete. Time taken: 00:00:03.881
# 2025-05-03 16:06:36,445 - ignite.engine.engine.Engine - INFO - Epoch[21] Complete. Time taken: 00:01:37.448
# 2025-05-03 16:06:36,445 - medvqa.utils.handlers_utils - INFO - ==================== Epoch 22/30 ====================
# 2025-05-03 16:06:36,445 - medvqa.training.utils - INFO - (1) Training stage (lr = 0.000015) ...
# Training [22/30]: [200/200] 100%|██████████, loss=0.0118 [01:32<00:00]
# 2025-05-03 16:08:09,791 - medvqa.utils.handlers_utils - INFO - loss 0.03455, mscxr_vgconf_loss 0.03088, mscxr_vgbbox_loss 0.00367, 93.35 secs
# 2025-05-03 16:08:09,791 - medvqa.training.utils - INFO - (2) Validation stage ...
# 2025-05-03 16:08:09,792 - ignite.engine.engine.Engine - INFO - Engine run starting with max_epochs=1.
# Validation: [8/8] 100%|█████████████ [00:02<00:00]
# 2025-05-03 16:08:12,839 - medvqa.utils.handlers_utils - INFO - mscxr_bbox_iou 0.72911, 3.05 secs
# 2025-05-03 16:08:13,602 - medvqa.utils.handlers_utils - INFO - New checkpoint saved: checkpoint_22_mscxr_bbox_iou+mscxr_vgbbox_loss+mscxr_vgconf_loss=0.7418.pt
# 2025-05-03 16:08:13,602 - ignite.engine.engine.Engine - INFO - Epoch[1] Complete. Time taken: 00:00:03.810
# 2025-05-03 16:08:13,602 - ignite.engine.engine.Engine - INFO - Engine run complete. Time taken: 00:00:03.810
# 2025-05-03 16:08:13,603 - ignite.engine.engine.Engine - INFO - Epoch[22] Complete. Time taken: 00:01:37.158
# 2025-05-03 16:08:13,603 - medvqa.utils.handlers_utils - INFO - ==================== Epoch 23/30 ====================
# 2025-05-03 16:08:13,603 - medvqa.training.utils - INFO - (1) Training stage (lr = 0.000007) ...
# Training [23/30]: [200/200] 100%|██████████, loss=0.0634 [01:32<00:00]
# 2025-05-03 16:09:46,798 - medvqa.utils.handlers_utils - INFO - loss 0.03472, mscxr_vgconf_loss 0.03109, mscxr_vgbbox_loss 0.00363, 93.19 secs
# 2025-05-03 16:09:46,799 - medvqa.training.utils - INFO - (2) Validation stage ...
# 2025-05-03 16:09:46,799 - ignite.engine.engine.Engine - INFO - Engine run starting with max_epochs=1.
# Validation: [8/8] 100%|█████████████ [00:02<00:00]
# 2025-05-03 16:09:49,808 - medvqa.utils.handlers_utils - INFO - mscxr_bbox_iou 0.72848, 3.01 secs
# 2025-05-03 16:09:49,808 - ignite.engine.engine.Engine - INFO - Epoch[1] Complete. Time taken: 00:00:03.009
# 2025-05-03 16:09:49,809 - ignite.engine.engine.Engine - INFO - Engine run complete. Time taken: 00:00:03.009
# 2025-05-03 16:09:49,809 - ignite.engine.engine.Engine - INFO - Epoch[23] Complete. Time taken: 00:01:36.206
# 2025-05-03 16:09:49,809 - medvqa.utils.handlers_utils - INFO - ==================== Epoch 24/30 ====================
# 2025-05-03 16:09:49,810 - medvqa.training.utils - INFO - (1) Training stage (lr = 0.000003) ...
# Training [24/30]: [200/200] 100%|██████████, loss=0.0185 [01:32<00:00]
# 2025-05-03 16:11:22,984 - medvqa.utils.handlers_utils - INFO - loss 0.03315, mscxr_vgconf_loss 0.02950, mscxr_vgbbox_loss 0.00365, 93.17 secs
# 2025-05-03 16:11:22,984 - medvqa.training.utils - INFO - (2) Validation stage ...
# 2025-05-03 16:11:22,985 - ignite.engine.engine.Engine - INFO - Engine run starting with max_epochs=1.
# Validation: [8/8] 100%|█████████████ [00:02<00:00]
# 2025-05-03 16:11:26,074 - medvqa.utils.handlers_utils - INFO - mscxr_bbox_iou 0.73168, 3.09 secs
# 2025-05-03 16:11:26,836 - medvqa.utils.handlers_utils - INFO - New checkpoint saved: checkpoint_24_mscxr_bbox_iou+mscxr_vgbbox_loss+mscxr_vgconf_loss=0.7443.pt
# 2025-05-03 16:11:26,836 - ignite.engine.engine.Engine - INFO - Epoch[1] Complete. Time taken: 00:00:03.852
# 2025-05-03 16:11:26,837 - ignite.engine.engine.Engine - INFO - Engine run complete. Time taken: 00:00:03.852
# 2025-05-03 16:11:26,837 - ignite.engine.engine.Engine - INFO - Epoch[24] Complete. Time taken: 00:01:37.028
# 2025-05-03 16:11:26,837 - medvqa.utils.handlers_utils - INFO - ==================== Epoch 25/30 ====================
# 2025-05-03 16:11:26,838 - medvqa.training.utils - INFO - (1) Training stage (lr = 0.000080) ...
# Training [25/30]: [200/200] 100%|██████████, loss=0.0354 [01:32<00:00]
# 2025-05-03 16:13:00,007 - medvqa.utils.handlers_utils - INFO - loss 0.03701, mscxr_vgconf_loss 0.03315, mscxr_vgbbox_loss 0.00386, 93.17 secs
# 2025-05-03 16:13:00,007 - medvqa.training.utils - INFO - (2) Validation stage ...
# 2025-05-03 16:13:00,008 - ignite.engine.engine.Engine - INFO - Engine run starting with max_epochs=1.
# Validation: [8/8] 100%|█████████████ [00:02<00:00]
# 2025-05-03 16:13:03,046 - medvqa.utils.handlers_utils - INFO - mscxr_bbox_iou 0.70525, 3.04 secs
# 2025-05-03 16:13:03,047 - ignite.engine.engine.Engine - INFO - Epoch[1] Complete. Time taken: 00:00:03.039
# 2025-05-03 16:13:03,047 - ignite.engine.engine.Engine - INFO - Engine run complete. Time taken: 00:00:03.039
# 2025-05-03 16:13:03,048 - ignite.engine.engine.Engine - INFO - Epoch[25] Complete. Time taken: 00:01:36.210
# 2025-05-03 16:13:03,048 - medvqa.utils.handlers_utils - INFO - ==================== Epoch 26/30 ====================
# 2025-05-03 16:13:03,048 - medvqa.training.utils - INFO - (1) Training stage (lr = 0.000035) ...
# Training [26/30]: [200/200] 100%|██████████, loss=0.0205 [01:33<00:00]
# 2025-05-03 16:14:36,706 - medvqa.utils.handlers_utils - INFO - loss 0.03641, mscxr_vgconf_loss 0.03267, mscxr_vgbbox_loss 0.00374, 93.66 secs
# 2025-05-03 16:14:36,706 - medvqa.training.utils - INFO - (2) Validation stage ...
# 2025-05-03 16:14:36,707 - ignite.engine.engine.Engine - INFO - Engine run starting with max_epochs=1.
# Validation: [8/8] 100%|█████████████ [00:02<00:00]
# 2025-05-03 16:14:39,713 - medvqa.utils.handlers_utils - INFO - mscxr_bbox_iou 0.72124, 3.01 secs
# 2025-05-03 16:14:39,714 - ignite.engine.engine.Engine - INFO - Epoch[1] Complete. Time taken: 00:00:03.007
# 2025-05-03 16:14:39,714 - ignite.engine.engine.Engine - INFO - Engine run complete. Time taken: 00:00:03.007
# 2025-05-03 16:14:39,715 - ignite.engine.engine.Engine - INFO - Epoch[26] Complete. Time taken: 00:01:36.667
# 2025-05-03 16:14:39,715 - medvqa.utils.handlers_utils - INFO - ==================== Epoch 27/30 ====================
# 2025-05-03 16:14:39,715 - medvqa.training.utils - INFO - (1) Training stage (lr = 0.000015) ...
# Training [27/30]: [200/200] 100%|██████████, loss=0.0347 [01:33<00:00]
# 2025-05-03 16:16:13,367 - medvqa.utils.handlers_utils - INFO - loss 0.03316, mscxr_vgconf_loss 0.02944, mscxr_vgbbox_loss 0.00371, 93.65 secs
# 2025-05-03 16:16:13,368 - medvqa.training.utils - INFO - (2) Validation stage ...
# 2025-05-03 16:16:13,369 - ignite.engine.engine.Engine - INFO - Engine run starting with max_epochs=1.
# Validation: [8/8] 100%|█████████████ [00:02<00:00]
# 2025-05-03 16:16:16,478 - medvqa.utils.handlers_utils - INFO - mscxr_bbox_iou 0.72531, 3.11 secs
# 2025-05-03 16:16:16,479 - ignite.engine.engine.Engine - INFO - Epoch[1] Complete. Time taken: 00:00:03.110
# 2025-05-03 16:16:16,479 - ignite.engine.engine.Engine - INFO - Engine run complete. Time taken: 00:00:03.111
# 2025-05-03 16:16:16,480 - ignite.engine.engine.Engine - INFO - Epoch[27] Complete. Time taken: 00:01:36.765
# 2025-05-03 16:16:16,480 - medvqa.utils.handlers_utils - INFO - ==================== Epoch 28/30 ====================
# 2025-05-03 16:16:16,480 - medvqa.training.utils - INFO - (1) Training stage (lr = 0.000007) ...
# Training [28/30]: [200/200] 100%|███████████, loss=0.025 [01:33<00:00]
# 2025-05-03 16:17:50,561 - medvqa.utils.handlers_utils - INFO - loss 0.03257, mscxr_vgconf_loss 0.02893, mscxr_vgbbox_loss 0.00363, 94.08 secs
# 2025-05-03 16:17:50,561 - medvqa.training.utils - INFO - (2) Validation stage ...
# 2025-05-03 16:17:50,562 - ignite.engine.engine.Engine - INFO - Engine run starting with max_epochs=1.
# Validation: [8/8] 100%|█████████████ [00:02<00:00]
# 2025-05-03 16:17:53,658 - medvqa.utils.handlers_utils - INFO - mscxr_bbox_iou 0.73130, 3.10 secs
# 2025-05-03 16:17:53,658 - ignite.engine.engine.Engine - INFO - Epoch[1] Complete. Time taken: 00:00:03.096
# 2025-05-03 16:17:53,658 - ignite.engine.engine.Engine - INFO - Engine run complete. Time taken: 00:00:03.097
# 2025-05-03 16:17:53,659 - ignite.engine.engine.Engine - INFO - Epoch[28] Complete. Time taken: 00:01:37.179
# 2025-05-03 16:17:53,659 - medvqa.utils.handlers_utils - INFO - ==================== Epoch 29/30 ====================
# 2025-05-03 16:17:53,659 - medvqa.training.utils - INFO - (1) Training stage (lr = 0.000003) ...
# Training [29/30]: [200/200] 100%|██████████, loss=0.0347 [01:33<00:00]
# 2025-05-03 16:19:27,810 - medvqa.utils.handlers_utils - INFO - loss 0.03152, mscxr_vgconf_loss 0.02807, mscxr_vgbbox_loss 0.00345, 94.15 secs
# 2025-05-03 16:19:27,811 - medvqa.training.utils - INFO - (2) Validation stage ...
# 2025-05-03 16:19:27,811 - ignite.engine.engine.Engine - INFO - Engine run starting with max_epochs=1.
# Validation: [8/8] 100%|█████████████ [00:02<00:00]
# 2025-05-03 16:19:30,847 - medvqa.utils.handlers_utils - INFO - mscxr_bbox_iou 0.73225, 3.04 secs
# 2025-05-03 16:19:31,978 - medvqa.utils.handlers_utils - INFO - New checkpoint saved: checkpoint_29_mscxr_bbox_iou+mscxr_vgbbox_loss+mscxr_vgconf_loss=0.7449.pt
# 2025-05-03 16:19:31,978 - ignite.engine.engine.Engine - INFO - Epoch[1] Complete. Time taken: 00:00:04.166
# 2025-05-03 16:19:31,978 - ignite.engine.engine.Engine - INFO - Engine run complete. Time taken: 00:00:04.167
# 2025-05-03 16:19:31,979 - ignite.engine.engine.Engine - INFO - Epoch[29] Complete. Time taken: 00:01:38.319
# 2025-05-03 16:19:31,979 - medvqa.utils.handlers_utils - INFO - ==================== Epoch 30/30 ====================
# 2025-05-03 16:19:31,979 - medvqa.training.utils - INFO - (1) Training stage (lr = 0.000080) ...
# Training [30/30]: [200/200] 100%|██████████, loss=0.0389 [01:32<00:00]
# 2025-05-03 16:21:04,984 - medvqa.utils.handlers_utils - INFO - loss 0.03299, mscxr_vgconf_loss 0.02920, mscxr_vgbbox_loss 0.00380, 93.01 secs
# 2025-05-03 16:21:04,984 - medvqa.training.utils - INFO - (2) Validation stage ...
# 2025-05-03 16:21:04,985 - ignite.engine.engine.Engine - INFO - Engine run starting with max_epochs=1.
# Validation: [8/8] 100%|█████████████ [00:02<00:00]
# 2025-05-03 16:21:08,135 - medvqa.utils.handlers_utils - INFO - mscxr_bbox_iou 0.72234, 3.15 secs
# 2025-05-03 16:21:08,135 - ignite.engine.engine.Engine - INFO - Epoch[1] Complete. Time taken: 00:00:03.150
# 2025-05-03 16:21:08,135 - ignite.engine.engine.Engine - INFO - Engine run complete. Time taken: 00:00:03.150
# 2025-05-03 16:21:08,136 - ignite.engine.engine.Engine - INFO - Epoch[30] Complete. Time taken: 00:01:36.157
# 2025-05-03 16:21:08,136 - ignite.engine.engine.Engine - INFO - Engine run complete. Time taken: 00:47:31.914
