# %%
# %env CUDA_VISIBLE_DEVICES=2
# Out:
# env: CUDA_VISIBLE_DEVICES=2

# %%
# !python ../train_fact_embedding_NLI.py \
--epochs 200 \
--batches_per_epoch 500 \
--batch_size 1000 \
--num_workers 4 \
--iters_to_accumulate 1 \
--optimizer_name "adamw" \
--scheduler "exp-warmup+decay+cyclicdecay" \
--lr 1e-6 \
--warmup_decay_and_cyclic_decay_args "1e-6,3,9e-5,10,2e-6,9e-5,10,2e-6" \
--fact_embedding_model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240207_184445_MIMIC-CXR(triplets+classif+entcont+nli+radgraph+autoencoder)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)" \
--fact_embedding_batch_size 50 \
--fact_embedding_num_workers 4 \
--use_report_nli \
--use_report_nli_entailment_dataset \
--use_sentence2facts_for_nli \
--integrated_nli_jsonl_filepath \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(169025,21838032).jsonl" \
--sentence_to_facts_input_output_jsonl_filepaths \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_parsed_sentences__v2.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_parsed_sentences__v2(uniform).jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_facts_from_sentences(cluster-balanced,hardest)_part1.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_facts_from_sentences(cluster-balanced,hardest)_part2.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_parsed_sentences__v2.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_facts_from_sentences(cluster-balanced,hardest).jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_facts_from_sentences(cluster-balanced,hardest,conditional).jsonl" \
--integrated_report_facts_jsonl_filepath \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_report_facts(79040140).jsonl" \
--report_nli_input_output_jsonl_filepaths \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-1106-preview_fact_based_report_nli_queries(from_labels).jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-1106-preview_fact_based_report_nli_queries(from_facts).jsonl" \
--embedding_dim 128 \
--mlp_hidden_dims 512 128 \
--dropout 0 \
--use_amp \
--save
# Out:
# script's arguments:
#    epochs: 200
#    batches_per_epoch: 500
#    batch_size: 1000
#    num_workers: 4
#    checkpoint_folder: None
#    embedding_dim: 128
#    mlp_hidden_dims: [512, 128]
#    dropout: 0.0
#    optimizer_name: adamw
#    lr: 1e-06
#    scheduler: exp-warmup+decay+cyclicdecay
#    warmup_decay_and_cyclic_decay_args: 1e-6,3,9e-5,10,2e-6,9e-5,10,2e-6
#    iters_to_accumulate: 1
#    override_lr: False
#    device: GPU
#    use_amp: True
#    integrated_nli_jsonl_filepath: /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(169025,21838032).jsonl
#    use_sentence2facts_for_nli: True
#    sentence_to_facts_input_output_jsonl_filepaths: ['/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_parsed_sentences__v2.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_parsed_sentences__v2(uniform).jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_facts_from_sentences(cluster-balanced,hardest)_part1.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_facts_from_sentences(cluster-balanced,hardest)_part2.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_parsed_sentences__v2.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_facts_from_sentences(cluster-balanced,hardest).jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_facts_from_sentences(cluster-balanced,hardest,conditional).jsonl']
#    use_anli: False
#    use_multinli: False
#    use_snli: False
#    use_report_nli: True
#    report_nli_input_output_jsonl_filepaths: ['/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-1106-preview_fact_based_report_nli_queries(from_labels).jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-1106-preview_fact_based_report_nli_queries(from_facts).jsonl']
#    use_report_nli_entailment_dataset: True
#    integrated_report_facts_jsonl_filepath: /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_report_facts(79040140).jsonl
#    fact_embedding_model_name: microsoft/BiomedVLP-CXR-BERT-specialized
#    fact_embedding_model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240207_184445_MIMIC-CXR(triplets+classif+entcont+nli+radgraph+autoencoder)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)
#    fact_embedding_batch_size: 50
#    fact_embedding_num_workers: 4
#    save: True
# ----- Training model from scratch ------
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Creating instance of BertBasedNLI ...
# EmbeddingBasedNLI
#   embedding_dim: 128
#   mlp_hidden_dims: [512, 128]
#   dropout: 0.0
# --------------------------------------------------
# 3) Defining optimizer ...
# create_optimizer(): name = adamw
# --------------------------------------------------
# 4) Defining scheduler ...
# Using exp-warmup+decay+cyclicdecay scheduler: 1e-6,3,9e-5,10,2e-6,9e-5,10,2e-6
# 1e-06 3 9e-05 10 2e-06 9e-05 10 2e-06
# self.steps_to_restart = 10
# self.steps = -1
# self.initial_lr = 9e-05
# --------------------------------------------------
# 5) Creating trainer and validator engines ...
# GradientAccumulator.__init__(): num_accumulation_steps = 1, max_grad_norm = None
# --------------------------------------------------
# 6) Defining collate batch functions ...
# Loaded 19971 input/output pairs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_parsed_sentences__v2.jsonl
# Loaded 19984 input/output pairs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_parsed_sentences__v2(uniform).jsonl
# Loaded 14990 input/output pairs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_facts_from_sentences(cluster-balanced,hardest)_part1.jsonl
# Loaded 14991 input/output pairs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_facts_from_sentences(cluster-balanced,hardest)_part2.jsonl
# Loaded 9999 input/output pairs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_parsed_sentences__v2.jsonl
# Loaded 5000 input/output pairs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_facts_from_sentences(cluster-balanced,hardest).jsonl
# Loaded 9999 input/output pairs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_facts_from_sentences(cluster-balanced,hardest,conditional).jsonl
# Number of sentence2facts pairs: 90614
# Input/output example:
# Input:
# Evolving paramediastinal opacity in the left upper lobe and elevation of the left hemidiaphragm may relate to radiation therapy or pneumonia, however tumor growth cannot be excluded.
# Output:
# ["evolving paramediastinal opacity in the left upper lobe", "elevation of the left hemidiaphragm", "opacity may relate to radiation therapy", "opacity may relate to pneumonia", "opacity may relate to tumor growth"]
# ----
# Loading integrated NLI from /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(169025,21838032).jsonl...
# Number of samples: 169025
# Number of sources: 7
# ----
# Loading sentence2facts input/output pairs for NLI...
# Number of entailment samples added: 214191
# ----
# Loading report NLI datasets...
# Loaded 80000 input/output pairs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-1106-preview_fact_based_report_nli_queries(from_facts).jsonl
# Loaded 58072 input/output pairs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-1106-preview_fact_based_report_nli_queries(from_labels).jsonl
# ----
# Building train NLI dataset...
# Source: gpt-4-0613 | Label: contradiction -> 79430 (4312.76)
# Example:
# Input:
# NLI1: In comparison with the study of , the hazy opacification at the right base has substantially decreased. #H: The hazy opacification at the right base has worsened since the last study.
# Output:
# contradiction
# Source: gpt-4-1106-preview_reasoning-prompt | Label: contradiction -> 10732 (2400.52)
# Example:
# Input:
# NLI1: Alternatively, there may be a developing right upper lobe and/or a left lower lobe pneumonia. #H: Since the prior study, there is a resolution of right and left lower lobe consolidations as well as right upper lobe opacities.
# Output:
# contradiction
# Source: gpt-4-0613_reasoning-prompt | Label: contradiction -> 4170 (1739.18)
# Example:
# Input:
# NLI1: Interval increase in small right pleural effusion. #H: The small right pleural effusion is constant.
# Output:
# contradiction
# Source: mednli_train | Label: contradiction -> 3744 (1672.60)
# Example:
# Input:
# NLI1: A femoral line was placed. #H:  no central access was available
# Output:
# contradiction
# Source: mednli_dev | Label: contradiction -> 465 (695.76)
# Example:
# Input:
# NLI1: Last night, he began having chest pain at rest. #H:  patient denies chest pain
# Output:
# contradiction
# Source: mednli_test | Label: contradiction -> 474 (702.30)
# Example:
# Input:
# NLI1: His amiodarone dose has been increased (200-->300). #H:  Patient has no medical history
# Output:
# contradiction
# Source: radnli_dev | Label: contradiction -> 106 (304.54)
# Example:
# Input:
# NLI1: Large left pleural effusion persists. #H: No pleural effusion, focal consolidation or pneumothorax.
# Output:
# contradiction
# Source: report_nli_from_facts | Label: contradiction -> 14141 (2620.99)
# Example:
# Input:
# NLI1: no acute findings. 6 mm right lower lobe nodule. chest CT needed nonurgently for further evaluation. normal cardiac contours. normal mediastinal contours. well inflated lungs. lungs without evidence of focal airspace consolidation. lungs without evidence of pleural effusions. lungs without evidence of pneumothorax. faint 6 mm nodular opacity projecting over the right ninth posterolateral rib. comparison to remote chest films advised. assessment for stability. absence of further imaging evaluation with CT. no pleural effusions. no pneumothorax. no pulmonary edema. no acute bony abnormality. mild degenerative changes in the lower thoracic spine. mild degenerative changes in the upper lumbar spine #H: absence of remote prior studies
# Output:
# contradiction
# Source: report_nli_from_labels | Label: contradiction -> 11641 (2464.16)
# Example:
# Input:
# NLI1: standard thoracostomy tube replaced the left pigtail pleural drainage catheter. standard thoracostomy tube curving over the apex of the lung. decrease in pneumothorax from moderate to slightly smaller. resolved left lower lobe collapse. mediastinum returned of midline. clear right lung. normal heart size #H: enlarged cardiomediastinum seen
# Output:
# contradiction
# Medical datasets for label contradiction: 7
# Medical report from facts datasets for label contradiction: 1
# Medical report from labels datasets for label contradiction: 1
# Source: gpt-4-0613 | Label: entailment -> 13185 (2563.82)
# Example:
# Input:
# NLI1: The hilar and mediastinal contours are unremarkable. #H: The hilar and mediastinal silhouettes are unremarkable.
# Output:
# entailment
# Source: gpt-4-1106-preview_reasoning-prompt | Label: entailment -> 5445 (1911.57)
# Example:
# Input:
# NLI1: Otherwise, the right hemithorax is clear. #H: There is no pneumothorax ..
# Output:
# entailment
# Source: gpt-4-0613_reasoning-prompt | Label: entailment -> 1770 (1256.05)
# Example:
# Input:
# NLI1: There is no pleural effusion, pneumothorax or pulmonary edema. #H: No pleural effusion, edema, or pneumothorax is seen.
# Output:
# entailment
# Source: mednli_train | Label: entailment -> 3744 (1672.60)
# Example:
# Input:
# NLI1: This infant emerged with a cry and was resuscitated with bulb suction, drying, stimulation and positive pressure ventilation. #H:  the patient was treated with positive pressure ventilation
# Output:
# entailment
# Source: mednli_dev | Label: entailment -> 465 (695.76)
# Example:
# Input:
# NLI1: Cardiac History: CABG, in [**2777**] anatomy as follows:  LIMA to LAD, saphenous vein graft to obtuse marginal and PDA. . #H:  the patient has a history of CABG
# Output:
# entailment
# Source: mednli_test | Label: entailment -> 473 (701.58)
# Example:
# Input:
# NLI1: Briefly, 79 yo M NH resident, h/o dementia, remote h/o saddle PE, MRSA, Afib not on coumadin presumable due to temporal lobe hemorrhage, urinary retention with recurrent UTIs who presents with urosepsis. #H:  patient is septic
# Output:
# entailment
# Source: radnli_dev | Label: entailment -> 93 (279.62)
# Example:
# Input:
# NLI1: No focal consolidation, pleural effusion or pneumothorax is seen. #H: No definite focal consolidation or pneumothorax is seen.
# Output:
# entailment
# Source: s2f | Label: entailment -> 214191 (5553.26)
# Example:
# Input:
# NLI1: 10:42 AM Low lung volumes contribute to focal atelectasis in the right middle and lower lobe. #H: focal atelectasis in the right middle lobe
# Output:
# entailment
# Source: report_nli_from_facts | Label: entailment -> 43411 (3656.37)
# Example:
# Input:
# NLI1: mild interstitial abnormality suggesting very mild pulmonary vascular congestion. clear lungs. no pleural effusion. no pneumothorax. mildly enlarged heart. unchanged mediastinal contours. unchanged hilar contours. mild degenerative changes along the thoracic spine. slight pulmonary vascular congestion. improved with resolution of pleural effusions #H: mild reticular edema
# Output:
# entailment
# Source: report_nli_from_labels | Label: entailment -> 33940 (3409.34)
# Example:
# Input:
# NLI1: decreased small right pneumothorax in the basal component. decreased small right pneumothorax in the apical component. right thoracostomy tube unchanged in position. right thoracostomy tube was anterior on when chest CT was performed. no appreciable right pleural effusion. unchanged right basal atelectasis. subcutaneous emphysema in the chest wall bilaterally. subcutaneous emphysema in both sides of the neck. subcutaneous emphysema not worsening. no left pneumothorax. normal heart size. severe emphysema #H: subcutaneous air seen
# Output:
# entailment
# Medical datasets for label entailment: 8
# Loaded 227835 reports from /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_report_facts(79040140).jsonl
# FactBasedReportEntailmentDataset
# Loaded 227835 reports from /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_report_facts(79040140).jsonl
# Medical report from facts datasets for label entailment: 2
# Medical report from labels datasets for label entailment: 1
# Source: gpt-4-0613 | Label: neutral -> 19123 (2877.24)
# Example:
# Input:
# NLI1: The pulmonary vasculature is normal. #H: There is no evidence of rib fractures.
# Output:
# neutral
# Source: gpt-4-1106-preview_reasoning-prompt | Label: neutral -> 16675 (2758.96)
# Example:
# Input:
# NLI1: The atelectasis on the left has also increased. #H: Unchanged elevation of the right hemidiaphragm with associated right basilar atelectasis.
# Output:
# neutral
# Source: gpt-4-0613_reasoning-prompt | Label: neutral -> 3968 (1708.29)
# Example:
# Input:
# NLI1: Low lung volumes remain. #H: Otherwise, clear lungs.
# Output:
# neutral
# Source: mednli_train | Label: neutral -> 3743 (1672.44)
# Example:
# Input:
# NLI1: Her blood pressure is in the 110-120s systolic. #H:  She is on anti-hypertensive medication
# Output:
# neutral
# Source: mednli_dev | Label: neutral -> 465 (695.76)
# Example:
# Input:
# NLI1: Migraines with visual aura. #H:  the patient is on sumatriptan
# Output:
# neutral
# Source: mednli_test | Label: neutral -> 474 (702.30)
# Example:
# Input:
# NLI1: COPD: 1 ppd / 40 years. #H:  The patient has emphysema.
# Output:
# neutral
# Source: radnli_dev | Label: neutral -> 281 (538.25)
# Example:
# Input:
# NLI1: The heart size is normal. #H: The chest is hyperinflated.
# Output:
# neutral
# Source: report_nli_from_facts | Label: neutral -> 22448 (3019.89)
# Example:
# Input:
# NLI1: normal heart size. normal mediastinal contours. normal hilar contours. normal pulmonary vascularity. minimal streaky opacity within the left lower lobe. atelectasis in the left lower lobe. blunting of the left costophrenic angle on the lateral view posteriorly. small left pleural effusion. no right-sided pleural effusion. no pneumothorax. mildly displaced fractures of the left lateral rib. mildly displaced fractures of the likely 9th rib. mildly displaced fractures of the likely lateral rib. mild left lower lobe atelectasis. probable trace left pleural effusion #H: irregularity may represent a nondisplaced fracture
# Output:
# neutral
# Source: report_nli_from_labels | Label: neutral -> 12491 (2520.23)
# Example:
# Input:
# NLI1: PA chest view obtained with patient in upright position. lateral chest view obtained with patient in upright position. analysis performed in direct comparison with the next preceding chest examination. diminished extensive chest wall emphysema on the left side. no evidence of remaining emphysema in the chest wall. small amount of soft tissue emphysema in the left lower neck area. no pneumothorax. no acute parenchymal infiltrates. normal heart size. no pulmonary vascular congestion. multiple rib fractures involving the posterior mid portions of ribs #2 through #5 on the frontal chest view. no significant interval change in position. no evidence of callus formation #H: spinal fracture seen
# Output:
# neutral
# Medical datasets for label neutral: 7
# Medical report from facts datasets for label neutral: 1
# Medical report from labels datasets for label neutral: 1
# ----
# Number of RadNLI test samples: 480
# Number of MS_CXR_T samples: 361
# Number of report NLI samples added to val: 300
# Number of report NLI samples added to val: 300
# Number of val NLI samples: 1441
# Input:
# NLI1: frontal view of the chest obtained. lateral view of the chest obtained. clear lungs. lungs without focal consolidation. no pleural effusion. no pneumothorax. unremarkable cardiomediastinal silhouettes. no acute cardiopulmonary process #H: edema seen
# Output:
# contradiction
# Input:
# NLI1: Allowing for these limitation, there are no focal parenchymal opacities. #H: Since the prior radiograph, no significant change in the widespread parenchymal opacities and moderate cardiomegaly.
# Output:
# contradiction
# Input:
# NLI1: frontal chest radiograph obtained. lateral chest radiograph obtained. extensive subcutaneous emphysema in the chest. extensive subcutaneous emphysema in the neck. left chest tube remains in place. tiny 1-2mm left pneumothorax. unchanged pneumomediastinum. unchanged pneumopericardium. persistent left basilar opacity. no pleural effusion. small left pneumothorax without tension. persistent pneumomediastinum. persistent pneumopericardium. left basilar opacity concerning for infection. left basilar opacity concerning for parenchymal bleeding #H: new left lower lobe parenchymal opacity
# Output:
# neutral
# Input:
# NLI1: retrocardiac atelectasis have increased. #H: retrocardiac atelectasis have improved.
# Output:
# contradiction
# Input:
# NLI1: the widespread bilateral diffuse parenchymal opacities are unchanged. #H: the widespread bilateral diffuse parenchymal opacities are improved.
# Output:
# contradiction
# ----
# Building val NLI dataset...
# Number of general sentences: 0
# Number of medical sentences: 1076067
# Number of whole sentences: 824560
# Number of splittable sentences: 251694
# Number of unique sentences (after sent_tokenize): 1390772
# Example train texts:
# {'input_text': 'NLI1: hyperinflated lungs. clear lungs. no focal consolidation. no effusion. no edema. cardiomediastinal silhouette within normal limits. no acute osseous abnormalities. hyperinflation without acute cardiopulmonary process #H: lung opacity seen', 'output_text': 'contradiction'}
# {'input_text': 'NLI1: low lung volume. lungs without consolidation. lungs without pulmonary edema. mildly enlarged heart. minimal left base atelectasis. no pleural effusion. no pneumothorax #H: rotated seen', 'output_text': 'neutral'}
# {'input_text': 'NLI1: cardiomegaly. no evidence of CHF. no evidence of pneumothorax. no evidence of pneumomediastinum. no evidence of effusion. extensive arthropathy in the spine #H: spinal fracture seen', 'output_text': 'neutral'}
# Examples dev texts:
# {'input_text': 'NLI1: PA view of the chest obtained. lateral view of the chest obtained. clear lungs bilaterally. no focal consolidation. no effusion. no pneumothorax. azygos fissure is noted. stable cardiomediastinal silhouette. intact bony structures. no definite displaced fractures. no acute intrathoracic process #H: superior mediastinal mass/enlargement seen', 'output_text': 'contradiction'}
# {'input_text': 'NLI1: There is a large right-sided pneumothorax which has developed since the previous study. #H: As compared to the previous radiograph, the patient has developed a large right-sided pneumothorax.', 'output_text': 'entailment'}
# {'input_text': 'NLI1: Stable appearance of moderate pulmonary edema since ___. #H: Stable, moderate pulmonary edema.', 'output_text': 'entailment'}
# checkpoint_names = ['checkpoint_91_cacc+chf1+chf1+cscc+encc+hscc+nlcc+sass+spss+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9337.pt']
#   0%|                                               | 0/1390772 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=440,3465006188639683439).pkl
# len(self.cache["hashes"]) = 2863612
# self.cache["embeddings"].shape = (2863612, 128)
# 100%|█████████████████████████████| 1390772/1390772 [00:05<00:00, 272857.93it/s]
# embeddings.shape: (1390772, 128)
# Example train text (after wrapping):
# {'h_emb': array([ 2.54894346e-02,  1.16291702e-01,  1.13899544e-01, -1.25148803e-01,
#        -2.24356689e-02,  2.77660880e-02, -1.05897458e-02, -1.17185585e-01,
#         7.80476108e-02, -2.00710464e-02, -1.19022690e-02, -1.39061240e-02,
#         8.41711760e-02,  5.75094968e-02,  1.14280015e-01,  4.48447093e-02,
#        -1.28392324e-01, -1.84023064e-02, -9.24378540e-03, -1.77910939e-01,
#        -1.19156666e-01,  7.83527046e-02,  1.50572723e-02, -1.24601781e-01,
#        -6.84456825e-02,  7.40560666e-02, -5.14804535e-02,  1.09588653e-01,
#         3.12414300e-02, -1.04821123e-01, -1.53294966e-01, -8.54447931e-02,
#        -1.12745024e-01, -1.15547314e-01, -9.77955684e-02,  6.70783035e-03,
#        -1.52684405e-01,  5.82216633e-03,  8.79673194e-03, -1.59620687e-01,
#        -5.31933159e-02, -9.72139835e-03, -5.13086393e-02, -8.45350474e-02,
#         1.62054226e-01,  4.81617749e-02,  7.64698088e-02, -6.62389025e-03,
#        -1.85074389e-01, -9.90042463e-02,  7.07135797e-02, -5.39681129e-02,
#         6.26353323e-02, -5.73587455e-02, -1.13315485e-01,  2.10524648e-02,
#        -3.56242396e-02,  3.66540439e-02, -6.67221099e-02, -8.74803141e-02,
#        -6.70951903e-02, -9.44329128e-02, -1.34258077e-01, -3.06478087e-02,
#        -9.91918333e-03,  5.82228974e-03, -9.72488616e-03,  2.29551308e-02,
#         8.45684931e-02,  1.14234470e-01, -1.23911276e-01, -1.52149737e-01,
#         4.77415361e-02,  5.24301343e-02, -1.18338957e-01,  8.94937292e-02,
#         3.26378345e-02,  7.80072138e-02,  4.02876809e-02,  1.14176057e-01,
#        -2.17368007e-02,  3.85081545e-02, -1.06103808e-01,  1.80136174e-01,
#         1.44045586e-02, -2.32092850e-02,  1.71922043e-01,  8.02641176e-03,
#        -8.03966299e-02,  1.06322654e-01,  7.01304227e-02,  8.99678767e-02,
#         1.58682378e-04,  8.16708505e-02, -6.46012798e-02,  1.03425439e-02,
#        -4.83109988e-02, -6.09854534e-02,  8.74397457e-02, -3.61993909e-02,
#        -1.78077281e-01, -2.07395241e-01, -7.25101586e-03, -1.26170799e-01,
#        -0.03817635, -0.02449685,  0.02042484, -0.02550706, -0.03672472,
#        -0.02385373,  0.0241554 , -0.02859511,  0.08134863,  0.02915946,
#        -0.06597126,  0.01863777,  0.03043333, -0.01165081, -0.03913845,
#        -0.03461769, -0.01304781,  0.02629137,  0.03056451,  0.07980709,
#        -0.07589693,  0.04532002, -0.00304412,  0.00913005, -0.02616508,
#         0.12262801,  0.03919247,  0.03188303, -0.01070668, -0.04780038,
#        -0.0716968 , -0.02807477,  0.07543683, -0.00687494, -0.01146313,
#        -0.07425087,  0.04886491,  0.0454309 ], dtype=float32), 'l': 0}
# nli_trainer.name =  NLI(Embedding-based)
# --------------------------------------------------
# 7) Attaching metrics, losses, timer and events to engines ...
# --------------------------------------------------
# 8) Defining learning rate scheduler handler ...
# --------------------------------------------------
# 9) Defining learning rate scheduler handler ...
# --------------------------------------------------
# 10) Defining checkpoint folder path ...
# checkpoint_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240405_083840_NLI(Embedding-based)_EmbeddingBasedNLI(128,512-128)
# metadata saved to /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240405_083840_NLI(Embedding-based)_EmbeddingBasedNLI(128,512-128)/metadata.json
# --------------------------------------------------
# 11) Defining log_metrics_handler ...
# MetricsLogger :: we'll be logging to /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240405_083840_NLI(Embedding-based)_EmbeddingBasedNLI(128,512-128)/metrics_logs.csv
# --------------------------------------------------
# 12) Running trainer engine ...
# ---- Epoch 1/200
# (1) Training stage (lr = 0.000001) ...
# loss 1.09905, nli_loss 1.09905, nli_acc 0.33448, 65.74 secs
# (2) Validation stage ...
# nli_acc 0.34282, 0.59 secs
# New checkpoint saved: checkpoint_1_nli_acc=0.3420.pt
# ---- Epoch 2/200
# (1) Training stage (lr = 0.000004) ...
# loss 1.08725, nli_loss 1.08725, nli_acc 0.43898, 63.85 secs
# (2) Validation stage ...
# nli_acc 0.55378, 0.60 secs
# New checkpoint saved: checkpoint_2_nli_acc=0.5423.pt
# ---- Epoch 3/200
# (1) Training stage (lr = 0.000020) ...
# loss 0.91050, nli_loss 0.91050, nli_acc 0.60819, 63.74 secs
# (2) Validation stage ...
# nli_acc 0.66273, 0.59 secs
# New checkpoint saved: checkpoint_3_nli_acc=0.6573.pt
# ---- Epoch 4/200
# (1) Training stage (lr = 0.000090) ...
# loss 0.64306, nli_loss 0.64306, nli_acc 0.72298, 64.15 secs
# (2) Validation stage ...
# nli_acc 0.76336, 0.60 secs
# New checkpoint saved: checkpoint_4_nli_acc=0.7593.pt
# ---- Epoch 5/200
# (1) Training stage (lr = 0.000062) ...
# loss 0.56210, nli_loss 0.56210, nli_acc 0.75952, 64.22 secs
# (2) Validation stage ...
# nli_acc 0.78487, 0.63 secs
# New checkpoint saved: checkpoint_5_nli_acc=0.7823.pt
# ---- Epoch 6/200
# (1) Training stage (lr = 0.000042) ...
# loss 0.54192, nli_loss 0.54192, nli_acc 0.76807, 63.70 secs
# (2) Validation stage ...
# nli_acc 0.78626, 0.60 secs
# New checkpoint saved: checkpoint_6_nli_acc=0.7844.pt
# ---- Epoch 7/200
# (1) Training stage (lr = 0.000029) ...
# loss 0.53152, nli_loss 0.53152, nli_acc 0.77305, 63.54 secs
# (2) Validation stage ...
# nli_acc 0.78001, 0.60 secs
# ---- Epoch 8/200
# (1) Training stage (lr = 0.000020) ...
# loss 0.52551, nli_loss 0.52551, nli_acc 0.77578, 63.66 secs
# (2) Validation stage ...
# nli_acc 0.78973, 0.60 secs
# New checkpoint saved: checkpoint_8_nli_acc=0.7883.pt
# ---- Epoch 9/200
# (1) Training stage (lr = 0.000013) ...
# loss 0.52092, nli_loss 0.52092, nli_acc 0.77771, 64.18 secs
# (2) Validation stage ...
# nli_acc 0.79112, 0.61 secs
# New checkpoint saved: checkpoint_9_nli_acc=0.7898.pt
# ---- Epoch 10/200
# (1) Training stage (lr = 0.000009) ...
# loss 0.51965, nli_loss 0.51965, nli_acc 0.77838, 63.59 secs
# (2) Validation stage ...
# nli_acc 0.78695, 0.60 secs
# ---- Epoch 11/200
# (1) Training stage (lr = 0.000006) ...
# loss 0.51806, nli_loss 0.51806, nli_acc 0.77931, 63.66 secs
# (2) Validation stage ...
# nli_acc 0.78973, 0.61 secs
# ---- Epoch 12/200
# (1) Training stage (lr = 0.000004) ...
# loss 0.51661, nli_loss 0.51661, nli_acc 0.77975, 63.82 secs
# (2) Validation stage ...
# nli_acc 0.78834, 0.59 secs
# ---- Epoch 13/200
# (1) Training stage (lr = 0.000003) ...
# loss 0.51555, nli_loss 0.51555, nli_acc 0.78060, 63.92 secs
# (2) Validation stage ...
# nli_acc 0.78904, 0.60 secs
# ---- Epoch 14/200
# (1) Training stage (lr = 0.000002) ...
# loss 0.51607, nli_loss 0.51607, nli_acc 0.78011, 63.61 secs
# (2) Validation stage ...
# nli_acc 0.78904, 0.62 secs
# ---- Epoch 15/200
# (1) Training stage (lr = 0.000090) ...
# loss 0.51276, nli_loss 0.51276, nli_acc 0.78160, 64.38 secs
# (2) Validation stage ...
# nli_acc 0.78904, 0.61 secs
# ---- Epoch 16/200
# (1) Training stage (lr = 0.000059) ...
# loss 0.50079, nli_loss 0.50079, nli_acc 0.78737, 63.71 secs
# (2) Validation stage ...
# nli_acc 0.79736, 0.60 secs
# New checkpoint saved: checkpoint_16_nli_acc=0.7964.pt
# ---- Epoch 17/200
# (1) Training stage (lr = 0.000039) ...
# loss 0.49399, nli_loss 0.49399, nli_acc 0.79077, 64.10 secs
# (2) Validation stage ...
# nli_acc 0.79320, 0.62 secs
# ---- Epoch 18/200
# (1) Training stage (lr = 0.000025) ...
# loss 0.48943, nli_loss 0.48943, nli_acc 0.79268, 63.69 secs
# (2) Validation stage ...
# nli_acc 0.79598, 0.60 secs
# ---- Epoch 19/200
# (1) Training stage (lr = 0.000017) ...
# loss 0.48702, nli_loss 0.48702, nli_acc 0.79437, 64.20 secs
# (2) Validation stage ...
# nli_acc 0.79875, 0.60 secs
# New checkpoint saved: checkpoint_19_nli_acc=0.7983.pt
# ---- Epoch 20/200
# (1) Training stage (lr = 0.000011) ...
# loss 0.48508, nli_loss 0.48508, nli_acc 0.79491, 63.79 secs
# (2) Validation stage ...
# nli_acc 0.79389, 0.60 secs
# ---- Epoch 21/200
# (1) Training stage (lr = 0.000007) ...
# loss 0.48361, nli_loss 0.48361, nli_acc 0.79611, 63.69 secs
# (2) Validation stage ...
# nli_acc 0.79667, 0.60 secs
# ---- Epoch 22/200
# (1) Training stage (lr = 0.000005) ...
# loss 0.48289, nli_loss 0.48289, nli_acc 0.79600, 63.75 secs
# (2) Validation stage ...
# nli_acc 0.79320, 0.60 secs
# ---- Epoch 23/200
# (1) Training stage (lr = 0.000003) ...
# loss 0.48270, nli_loss 0.48270, nli_acc 0.79655, 63.53 secs
# (2) Validation stage ...
# nli_acc 0.79459, 0.61 secs
# ---- Epoch 24/200
# (1) Training stage (lr = 0.000002) ...
# loss 0.48142, nli_loss 0.48142, nli_acc 0.79717, 63.71 secs
# (2) Validation stage ...
# nli_acc 0.79459, 0.60 secs
# ---- Epoch 25/200
# (1) Training stage (lr = 0.000090) ...
# loss 0.48329, nli_loss 0.48329, nli_acc 0.79584, 63.74 secs
# (2) Validation stage ...
# nli_acc 0.80569, 0.59 secs
# New checkpoint saved: checkpoint_25_nli_acc=0.8047.pt
# ---- Epoch 26/200
# (1) Training stage (lr = 0.000059) ...
# loss 0.47492, nli_loss 0.47492, nli_acc 0.79993, 63.65 secs
# (2) Validation stage ...
# nli_acc 0.79875, 0.61 secs
# ---- Epoch 27/200
# (1) Training stage (lr = 0.000039) ...
# loss 0.46925, nli_loss 0.46925, nli_acc 0.80286, 63.69 secs
# (2) Validation stage ...
# nli_acc 0.80569, 0.61 secs
# New checkpoint saved: checkpoint_27_nli_acc=0.8054.pt
# ---- Epoch 28/200
# (1) Training stage (lr = 0.000025) ...
# loss 0.46566, nli_loss 0.46566, nli_acc 0.80401, 63.68 secs
# (2) Validation stage ...
# nli_acc 0.80361, 0.59 secs
# ---- Epoch 29/200
# (1) Training stage (lr = 0.000017) ...
# loss 0.46346, nli_loss 0.46346, nli_acc 0.80484, 63.49 secs
# (2) Validation stage ...
# nli_acc 0.80500, 0.59 secs
# ---- Epoch 30/200
# (1) Training stage (lr = 0.000011) ...
# loss 0.46174, nli_loss 0.46174, nli_acc 0.80608, 63.60 secs
# (2) Validation stage ...
# nli_acc 0.80361, 0.64 secs
# ---- Epoch 31/200
# (1) Training stage (lr = 0.000007) ...
# loss 0.46092, nli_loss 0.46092, nli_acc 0.80596, 64.47 secs
# (2) Validation stage ...
# nli_acc 0.80569, 0.60 secs
# New checkpoint saved: checkpoint_31_nli_acc=0.8057.pt
# ---- Epoch 32/200
# (1) Training stage (lr = 0.000005) ...
# loss 0.46024, nli_loss 0.46024, nli_acc 0.80648, 63.53 secs
# (2) Validation stage ...
# nli_acc 0.80500, 0.59 secs
# ---- Epoch 33/200
# (1) Training stage (lr = 0.000003) ...
# loss 0.45968, nli_loss 0.45968, nli_acc 0.80670, 65.06 secs
# (2) Validation stage ...
# nli_acc 0.80500, 0.60 secs
# ---- Epoch 34/200
# (1) Training stage (lr = 0.000002) ...
# loss 0.45945, nli_loss 0.45945, nli_acc 0.80677, 64.09 secs
# (2) Validation stage ...
# nli_acc 0.80638, 0.61 secs
# New checkpoint saved: checkpoint_34_nli_acc=0.8064.pt
# ---- Epoch 35/200
# (1) Training stage (lr = 0.000090) ...
# loss 0.46149, nli_loss 0.46149, nli_acc 0.80604, 63.49 secs
# (2) Validation stage ...
# nli_acc 0.80291, 0.60 secs
# ---- Epoch 36/200
# (1) Training stage (lr = 0.000059) ...
# loss 0.45500, nli_loss 0.45500, nli_acc 0.80947, 64.12 secs
# (2) Validation stage ...
# nli_acc 0.80777, 0.64 secs
# New checkpoint saved: checkpoint_36_nli_acc=0.8079.pt
# ---- Epoch 37/200
# (1) Training stage (lr = 0.000039) ...
# loss 0.45021, nli_loss 0.45021, nli_acc 0.81144, 63.49 secs
# (2) Validation stage ...
# nli_acc 0.80916, 0.60 secs
# New checkpoint saved: checkpoint_37_nli_acc=0.8094.pt
# ---- Epoch 38/200
# (1) Training stage (lr = 0.000025) ...
# loss 0.44678, nli_loss 0.44678, nli_acc 0.81369, 63.75 secs
# (2) Validation stage ...
# nli_acc 0.80708, 0.61 secs
# ---- Epoch 39/200
# (1) Training stage (lr = 0.000017) ...
# loss 0.44422, nli_loss 0.44422, nli_acc 0.81430, 63.68 secs
# (2) Validation stage ...
# nli_acc 0.80500, 0.60 secs
# ---- Epoch 40/200
# (1) Training stage (lr = 0.000011) ...
# loss 0.44390, nli_loss 0.44390, nli_acc 0.81473, 64.01 secs
# (2) Validation stage ...
# nli_acc 0.81055, 0.59 secs
# New checkpoint saved: checkpoint_40_nli_acc=0.8110.pt
# ---- Epoch 41/200
# (1) Training stage (lr = 0.000007) ...
# loss 0.44161, nli_loss 0.44161, nli_acc 0.81594, 63.61 secs
# (2) Validation stage ...
# nli_acc 0.80777, 0.61 secs
# ---- Epoch 42/200
# (1) Training stage (lr = 0.000005) ...
# loss 0.44154, nli_loss 0.44154, nli_acc 0.81560, 63.72 secs
# (2) Validation stage ...
# nli_acc 0.81055, 0.63 secs
# ...
# nli_acc 0.83831, 0.65 secs
# ---- Epoch 112/200
# (1) Training stage (lr = 0.000005) ...
# loss 0.34552, nli_loss 0.34552, nli_acc 0.86560, 76.97 secs
# (2) Validation stage ...
# nli_acc 0.83484, 0.69 secs
# ---- Epoch 113/200
# (1) Training stage (lr = 0.000003) ...
# loss 0.34551, nli_loss 0.34551, nli_acc 0.86510, 77.01 secs
# (2) Validation stage ...
# nli_acc 0.83761, 0.67 secs
# ---- Epoch 114/200
# (1) Training stage (lr = 0.000002) ...
# loss 0.34445, nli_loss 0.34445, nli_acc 0.86607, 79.16 secs
# (2) Validation stage ...
# nli_acc 0.83761, 0.69 secs
# ---- Epoch 115/200
# (1) Training stage (lr = 0.000090) ...
# loss 0.35510, nli_loss 0.35510, nli_acc 0.85985, 76.42 secs
# (2) Validation stage ...
# nli_acc 0.82998, 0.71 secs
# ---- Epoch 116/200
# (1) Training stage (lr = 0.000059) ...
# loss 0.34788, nli_loss 0.34788, nli_acc 0.86366, 76.77 secs
# (2) Validation stage ...
# nli_acc 0.83345, 0.69 secs
# ---- Epoch 117/200
# (1) Training stage (lr = 0.000039) ...
# loss 0.34325, nli_loss 0.34325, nli_acc 0.86655, 76.25 secs
# (2) Validation stage ...
# nli_acc 0.83414, 0.70 secs
# ---- Epoch 118/200
# (1) Training stage (lr = 0.000025) ...
# loss 0.33987, nli_loss 0.33987, nli_acc 0.86836, 76.06 secs
# (2) Validation stage ...
# nli_acc 0.83900, 0.68 secs
# ---- Epoch 119/200
# (1) Training stage (lr = 0.000017) ...
# loss 0.33746, nli_loss 0.33746, nli_acc 0.86903, 76.68 secs
# (2) Validation stage ...
# nli_acc 0.83553, 0.68 secs
# ---- Epoch 120/200
# (1) Training stage (lr = 0.000011) ...
# loss 0.33581, nli_loss 0.33581, nli_acc 0.87013, 75.04 secs
# (2) Validation stage ...
# nli_acc 0.84108, 0.72 secs
# New checkpoint saved: checkpoint_120_nli_acc=0.8440.pt
# ---- Epoch 121/200
# (1) Training stage (lr = 0.000007) ...
# loss 0.33484, nli_loss 0.33484, nli_acc 0.87073, 78.36 secs
# (2) Validation stage ...
# nli_acc 0.84178, 0.70 secs
# New checkpoint saved: checkpoint_121_nli_acc=0.8447.pt
# ---- Epoch 122/200
# (1) Training stage (lr = 0.000005) ...
# loss 0.33448, nli_loss 0.33448, nli_acc 0.87092, 76.60 secs
# (2) Validation stage ...
# nli_acc 0.83900, 0.66 secs
# ---- Epoch 123/200
# (1) Training stage (lr = 0.000003) ...
# loss 0.33300, nli_loss 0.33300, nli_acc 0.87168, 75.00 secs
# (2) Validation stage ...
# nli_acc 0.83900, 0.71 secs
# ---- Epoch 124/200
# (1) Training stage (lr = 0.000002) ...
# loss 0.33304, nli_loss 0.33304, nli_acc 0.87168, 76.67 secs
# (2) Validation stage ...
# nli_acc 0.84247, 0.68 secs
# New checkpoint saved: checkpoint_124_nli_acc=0.8454.pt
# ---- Epoch 125/200
# (1) Training stage (lr = 0.000090) ...
# loss 0.34450, nli_loss 0.34450, nli_acc 0.86468, 78.42 secs
# (2) Validation stage ...
# nli_acc 0.84316, 0.69 secs
# ---- Epoch 126/200
# (1) Training stage (lr = 0.000059) ...
# loss 0.33770, nli_loss 0.33770, nli_acc 0.86856, 76.27 secs
# (2) Validation stage ...
# nli_acc 0.83761, 0.69 secs
# ---- Epoch 127/200
# (1) Training stage (lr = 0.000039) ...
# loss 0.33169, nli_loss 0.33169, nli_acc 0.87201, 76.52 secs
# (2) Validation stage ...
# nli_acc 0.83137, 0.70 secs
# ---- Epoch 128/200
# (1) Training stage (lr = 0.000025) ...
# loss 0.32894, nli_loss 0.32894, nli_acc 0.87344, 79.15 secs
# (2) Validation stage ...
# nli_acc 0.83761, 0.69 secs
# ---- Epoch 129/200
# (1) Training stage (lr = 0.000017) ...
# loss 0.32629, nli_loss 0.32629, nli_acc 0.87495, 78.92 secs
# (2) Validation stage ...
# nli_acc 0.84316, 0.71 secs
# New checkpoint saved: checkpoint_129_nli_acc=0.8463.pt
# ---- Epoch 130/200
# (1) Training stage (lr = 0.000011) ...
# loss 0.32529, nli_loss 0.32529, nli_acc 0.87546, 78.06 secs
# (2) Validation stage ...
# nli_acc 0.84039, 0.73 secs
# ---- Epoch 131/200
# (1) Training stage (lr = 0.000007) ...
# loss 0.32377, nli_loss 0.32377, nli_acc 0.87664, 75.66 secs
# (2) Validation stage ...
# nli_acc 0.84178, 0.69 secs
# ---- Epoch 132/200
# (1) Training stage (lr = 0.000005) ...
# loss 0.32282, nli_loss 0.32282, nli_acc 0.87696, 75.44 secs
# (2) Validation stage ...
# nli_acc 0.84316, 0.75 secs
# New checkpoint saved: checkpoint_132_nli_acc=0.8465.pt
# ---- Epoch 133/200
# (1) Training stage (lr = 0.000003) ...
# loss 0.32259, nli_loss 0.32259, nli_acc 0.87687, 77.90 secs
# (2) Validation stage ...
# nli_acc 0.84247, 0.65 secs
# ---- Epoch 134/200
# (1) Training stage (lr = 0.000002) ...
# loss 0.32237, nli_loss 0.32237, nli_acc 0.87754, 76.40 secs
# (2) Validation stage ...
# nli_acc 0.84316, 0.68 secs
# New checkpoint saved: checkpoint_134_nli_acc=0.8466.pt
# ---- Epoch 135/200
# (1) Training stage (lr = 0.000090) ...
# loss 0.33376, nli_loss 0.33376, nli_acc 0.87010, 76.06 secs
# (2) Validation stage ...
# nli_acc 0.84802, 0.70 secs
# New checkpoint saved: checkpoint_135_nli_acc=0.8502.pt
# ---- Epoch 136/200
# (1) Training stage (lr = 0.000059) ...
# loss 0.32735, nli_loss 0.32735, nli_acc 0.87392, 76.04 secs
# (2) Validation stage ...
# nli_acc 0.84108, 0.70 secs
# ---- Epoch 137/200
# (1) Training stage (lr = 0.000039) ...
# loss 0.32175, nli_loss 0.32175, nli_acc 0.87751, 77.07 secs
# (2) Validation stage ...
# nli_acc 0.84941, 0.67 secs
# New checkpoint saved: checkpoint_137_nli_acc=0.8522.pt
# ---- Epoch 138/200
# (1) Training stage (lr = 0.000025) ...
# loss 0.31809, nli_loss 0.31809, nli_acc 0.87893, 76.22 secs
# (2) Validation stage ...
# nli_acc 0.84178, 0.67 secs
# ---- Epoch 139/200
# (1) Training stage (lr = 0.000017) ...
# loss 0.31613, nli_loss 0.31613, nli_acc 0.88047, 78.97 secs
# (2) Validation stage ...
# nli_acc 0.84525, 0.73 secs
# ---- Epoch 140/200
# (1) Training stage (lr = 0.000011) ...
# loss 0.31424, nli_loss 0.31424, nli_acc 0.88165, 75.58 secs
# (2) Validation stage ...
# nli_acc 0.84525, 0.68 secs
# ---- Epoch 141/200
# (1) Training stage (lr = 0.000007) ...
# loss 0.31308, nli_loss 0.31308, nli_acc 0.88205, 77.27 secs
# (2) Validation stage ...
# nli_acc 0.84108, 0.68 secs
# ---- Epoch 142/200
# (1) Training stage (lr = 0.000005) ...
# loss 0.31231, nli_loss 0.31231, nli_acc 0.88255, 76.83 secs
# (2) Validation stage ...
# nli_acc 0.84663, 0.70 secs
# ---- Epoch 143/200
# (1) Training stage (lr = 0.000003) ...
# loss 0.31229, nli_loss 0.31229, nli_acc 0.88258, 78.96 secs
# (2) Validation stage ...
# nli_acc 0.84455, 0.69 secs
# ---- Epoch 144/200
# (1) Training stage (lr = 0.000002) ...
# loss 0.31120, nli_loss 0.31120, nli_acc 0.88301, 78.33 secs
# (2) Validation stage ...
# nli_acc 0.84386, 0.67 secs
# ---- Epoch 145/200
# (1) Training stage (lr = 0.000090) ...
# loss 0.32450, nli_loss 0.32450, nli_acc 0.87507, 76.54 secs
# (2) Validation stage ...
# nli_acc 0.83761, 0.68 secs
# ---- Epoch 146/200
# (1) Training stage (lr = 0.000059) ...
# loss 0.31647, nli_loss 0.31647, nli_acc 0.87895, 75.10 secs
# (2) Validation stage ...
# nli_acc 0.84525, 0.72 secs
# ---- Epoch 147/200
# (1) Training stage (lr = 0.000039) ...
# loss 0.31167, nli_loss 0.31167, nli_acc 0.88212, 76.63 secs
# (2) Validation stage ...
# nli_acc 0.84802, 0.72 secs
# ---- Epoch 148/200
# (1) Training stage (lr = 0.000025) ...
# loss 0.30813, nli_loss 0.30813, nli_acc 0.88440, 77.14 secs
# (2) Validation stage ...
# nli_acc 0.85080, 0.67 secs
# New checkpoint saved: checkpoint_148_nli_acc=0.8542.pt
# ---- Epoch 149/200
# (1) Training stage (lr = 0.000017) ...
# loss 0.30515, nli_loss 0.30515, nli_acc 0.88578, 81.59 secs
# (2) Validation stage ...
# nli_acc 0.84525, 0.66 secs
# ---- Epoch 150/200
# (1) Training stage (lr = 0.000011) ...
# loss 0.30366, nli_loss 0.30366, nli_acc 0.88714, 77.48 secs
# (2) Validation stage ...
# nli_acc 0.84733, 0.68 secs
# ---- Epoch 151/200
# (1) Training stage (lr = 0.000007) ...
# loss 0.30331, nli_loss 0.30331, nli_acc 0.88715, 81.50 secs
# (2) Validation stage ...
# nli_acc 0.85080, 0.70 secs
# New checkpoint saved: checkpoint_151_nli_acc=0.8544.pt
# ---- Epoch 152/200
# (1) Training stage (lr = 0.000005) ...
# loss 0.30229, nli_loss 0.30229, nli_acc 0.88755, 76.60 secs
# (2) Validation stage ...
# nli_acc 0.84663, 0.67 secs
# ---- Epoch 153/200
# (1) Training stage (lr = 0.000003) ...
# loss 0.30203, nli_loss 0.30203, nli_acc 0.88806, 76.08 secs
# (2) Validation stage ...
# nli_acc 0.84663, 0.70 secs
# ---- Epoch 154/200
# (1) Training stage (lr = 0.000002) ...
# loss 0.30103, nli_loss 0.30103, nli_acc 0.88861, 77.08 secs
# (2) Validation stage ...
# nli_acc 0.84802, 0.69 secs
# ---- Epoch 155/200
# (1) Training stage (lr = 0.000090) ...
# loss 0.31470, nli_loss 0.31470, nli_acc 0.87955, 78.39 secs
# (2) Validation stage ...
# nli_acc 0.84386, 0.68 secs
# ---- Epoch 156/200
# (1) Training stage (lr = 0.000059) ...
# loss 0.30691, nli_loss 0.30691, nli_acc 0.88426, 78.67 secs
# (2) Validation stage ...
# nli_acc 0.85913, 0.67 secs
# New checkpoint saved: checkpoint_156_nli_acc=0.8616.pt
# ---- Epoch 157/200
# (1) Training stage (lr = 0.000039) ...
# loss 0.30165, nli_loss 0.30165, nli_acc 0.88716, 80.31 secs
# (2) Validation stage ...
# nli_acc 0.84663, 0.65 secs
# ---- Epoch 158/200
# (1) Training stage (lr = 0.000025) ...
# loss 0.29784, nli_loss 0.29784, nli_acc 0.88965, 78.49 secs
# (2) Validation stage ...
# nli_acc 0.84733, 0.72 secs
# ---- Epoch 159/200
# (1) Training stage (lr = 0.000017) ...
# loss 0.29624, nli_loss 0.29624, nli_acc 0.89067, 78.27 secs
# (2) Validation stage ...
# nli_acc 0.85288, 0.71 secs
# ---- Epoch 160/200
# (1) Training stage (lr = 0.000011) ...
# loss 0.29364, nli_loss 0.29364, nli_acc 0.89188, 76.89 secs
# (2) Validation stage ...
# nli_acc 0.85288, 0.65 secs
# ---- Epoch 161/200
# (1) Training stage (lr = 0.000007) ...
# loss 0.29349, nli_loss 0.29349, nli_acc 0.89218, 77.47 secs
# (2) Validation stage ...
# nli_acc 0.85080, 0.68 secs
# ---- Epoch 162/200
# (1) Training stage (lr = 0.000005) ...
# loss 0.29231, nli_loss 0.29231, nli_acc 0.89266, 78.71 secs
# (2) Validation stage ...
# nli_acc 0.84941, 0.66 secs
# ---- Epoch 163/200
# (1) Training stage (lr = 0.000003) ...
# loss 0.29137, nli_loss 0.29137, nli_acc 0.89336, 77.27 secs
# (2) Validation stage ...
# nli_acc 0.85219, 0.71 secs
# ---- Epoch 164/200
# (1) Training stage (lr = 0.000002) ...
# loss 0.29100, nli_loss 0.29100, nli_acc 0.89349, 77.68 secs
# (2) Validation stage ...
# nli_acc 0.85288, 0.73 secs
# ---- Epoch 165/200
# (1) Training stage (lr = 0.000090) ...
# loss 0.30586, nli_loss 0.30586, nli_acc 0.88416, 79.54 secs
# (2) Validation stage ...
# nli_acc 0.86051, 0.68 secs
# New checkpoint saved: checkpoint_165_nli_acc=0.8629.pt
# ---- Epoch 166/200
# (1) Training stage (lr = 0.000059) ...
# loss 0.29723, nli_loss 0.29723, nli_acc 0.88860, 76.91 secs
# (2) Validation stage ...
# nli_acc 0.84108, 0.73 secs
# ---- Epoch 167/200
# (1) Training stage (lr = 0.000039) ...
# loss 0.29225, nli_loss 0.29225, nli_acc 0.89207, 80.01 secs
# (2) Validation stage ...
# nli_acc 0.85357, 0.70 secs
# ---- Epoch 168/200
# (1) Training stage (lr = 0.000025) ...
# loss 0.28843, nli_loss 0.28843, nli_acc 0.89431, 79.37 secs
# (2) Validation stage ...
# nli_acc 0.85080, 0.71 secs
# ---- Epoch 169/200
# (1) Training stage (lr = 0.000017) ...
# loss 0.28604, nli_loss 0.28604, nli_acc 0.89571, 82.01 secs
# (2) Validation stage ...
# nli_acc 0.85496, 0.71 secs
# ---- Epoch 170/200
# (1) Training stage (lr = 0.000011) ...
# loss 0.28464, nli_loss 0.28464, nli_acc 0.89652, 81.01 secs
# (2) Validation stage ...
# nli_acc 0.85774, 0.64 secs
# ---- Epoch 171/200
# (1) Training stage (lr = 0.000007) ...
# loss 0.28304, nli_loss 0.28304, nli_acc 0.89735, 79.87 secs
# (2) Validation stage ...
# nli_acc 0.85010, 0.67 secs
# ---- Epoch 172/200
# (1) Training stage (lr = 0.000005) ...
# loss 0.28283, nli_loss 0.28283, nli_acc 0.89745, 78.94 secs
# (2) Validation stage ...
# nli_acc 0.85288, 0.70 secs
# ---- Epoch 173/200
# (1) Training stage (lr = 0.000003) ...
# loss 0.28211, nli_loss 0.28211, nli_acc 0.89774, 79.11 secs
# (2) Validation stage ...
# nli_acc 0.85427, 0.71 secs
# ---- Epoch 174/200
# (1) Training stage (lr = 0.000002) ...
# loss 0.28136, nli_loss 0.28136, nli_acc 0.89806, 79.05 secs
# (2) Validation stage ...
# nli_acc 0.84872, 0.67 secs
# ---- Epoch 175/200
# (1) Training stage (lr = 0.000090) ...
# loss 0.29696, nli_loss 0.29696, nli_acc 0.88808, 78.29 secs
# (2) Validation stage ...
# nli_acc 0.85427, 0.70 secs
# ---- Epoch 176/200
# (1) Training stage (lr = 0.000059) ...
# loss 0.28891, nli_loss 0.28891, nli_acc 0.89308, 78.74 secs
# (2) Validation stage ...
# nli_acc 0.84663, 0.71 secs
# ---- Epoch 177/200
# (1) Training stage (lr = 0.000039) ...
# loss 0.28300, nli_loss 0.28300, nli_acc 0.89654, 77.27 secs
# (2) Validation stage ...
# nli_acc 0.84941, 0.67 secs
# ---- Epoch 178/200
# (1) Training stage (lr = 0.000025) ...
# loss 0.27967, nli_loss 0.27967, nli_acc 0.89850, 78.35 secs
# (2) Validation stage ...
# nli_acc 0.85496, 0.67 secs
# ---- Epoch 179/200
# (1) Training stage (lr = 0.000017) ...
# loss 0.27663, nli_loss 0.27663, nli_acc 0.90073, 79.15 secs
# (2) Validation stage ...
# nli_acc 0.86051, 0.66 secs
# New checkpoint saved: checkpoint_179_nli_acc=0.8645.pt
# ---- Epoch 180/200
# (1) Training stage (lr = 0.000011) ...
# loss 0.27516, nli_loss 0.27516, nli_acc 0.90123, 78.36 secs
# (2) Validation stage ...
# nli_acc 0.85704, 0.67 secs
# ---- Epoch 181/200
# (1) Training stage (lr = 0.000007) ...
# loss 0.27403, nli_loss 0.27403, nli_acc 0.90188, 79.15 secs
# (2) Validation stage ...
# nli_acc 0.85080, 0.67 secs
# ---- Epoch 182/200
# (1) Training stage (lr = 0.000005) ...
# loss 0.27356, nli_loss 0.27356, nli_acc 0.90207, 79.29 secs
# (2) Validation stage ...
# nli_acc 0.85566, 0.69 secs
# ---- Epoch 183/200
# (1) Training stage (lr = 0.000003) ...
# loss 0.27275, nli_loss 0.27275, nli_acc 0.90270, 79.19 secs
# (2) Validation stage ...
# nli_acc 0.85219, 0.70 secs
# ---- Epoch 184/200
# (1) Training stage (lr = 0.000002) ...
# loss 0.27249, nli_loss 0.27249, nli_acc 0.90292, 78.33 secs
# (2) Validation stage ...
# nli_acc 0.85427, 0.68 secs
# ---- Epoch 185/200
# (1) Training stage (lr = 0.000090) ...
# loss 0.28867, nli_loss 0.28867, nli_acc 0.89190, 77.31 secs
# (2) Validation stage ...
# nli_acc 0.85427, 0.67 secs
# ---- Epoch 186/200
# (1) Training stage (lr = 0.000059) ...
# loss 0.28050, nli_loss 0.28050, nli_acc 0.89710, 80.71 secs
# (2) Validation stage ...
# nli_acc 0.85288, 0.67 secs
# ---- Epoch 187/200
# (1) Training stage (lr = 0.000039) ...
# loss 0.27467, nli_loss 0.27467, nli_acc 0.90088, 78.09 secs
# (2) Validation stage ...
# nli_acc 0.84733, 0.68 secs
# ---- Epoch 188/200
# (1) Training stage (lr = 0.000025) ...
# loss 0.27030, nli_loss 0.27030, nli_acc 0.90293, 80.42 secs
# (2) Validation stage ...
# nli_acc 0.86260, 0.69 secs
# New checkpoint saved: checkpoint_188_nli_acc=0.8666.pt
# ---- Epoch 189/200
# (1) Training stage (lr = 0.000017) ...
# loss 0.26814, nli_loss 0.26814, nli_acc 0.90435, 78.36 secs
# (2) Validation stage ...
# nli_acc 0.85774, 0.75 secs
# ---- Epoch 190/200
# (1) Training stage (lr = 0.000011) ...
# loss 0.26700, nli_loss 0.26700, nli_acc 0.90530, 76.18 secs
# (2) Validation stage ...
# nli_acc 0.85774, 0.69 secs
# ---- Epoch 191/200
# (1) Training stage (lr = 0.000007) ...
# loss 0.26532, nli_loss 0.26532, nli_acc 0.90608, 79.77 secs
# (2) Validation stage ...
# nli_acc 0.85704, 0.67 secs
# ---- Epoch 192/200
# (1) Training stage (lr = 0.000005) ...
# loss 0.26464, nli_loss 0.26464, nli_acc 0.90664, 81.14 secs
# (2) Validation stage ...
# nli_acc 0.86051, 0.67 secs
# ---- Epoch 193/200
# (1) Training stage (lr = 0.000003) ...
# loss 0.26452, nli_loss 0.26452, nli_acc 0.90684, 79.37 secs
# (2) Validation stage ...
# nli_acc 0.85496, 0.68 secs
# ---- Epoch 194/200
# (1) Training stage (lr = 0.000002) ...
# loss 0.26383, nli_loss 0.26383, nli_acc 0.90703, 82.21 secs
# (2) Validation stage ...
# nli_acc 0.85496, 0.71 secs
# ---- Epoch 195/200
# (1) Training stage (lr = 0.000090) ...
# loss 0.28113, nli_loss 0.28113, nli_acc 0.89549, 82.89 secs
# (2) Validation stage ...
# nli_acc 0.84594, 0.70 secs
# ---- Epoch 196/200
# (1) Training stage (lr = 0.000059) ...
# loss 0.27099, nli_loss 0.27099, nli_acc 0.90176, 78.76 secs
# (2) Validation stage ...
# nli_acc 0.86190, 0.69 secs
# ---- Epoch 197/200
# (1) Training stage (lr = 0.000039) ...
# loss 0.26670, nli_loss 0.26670, nli_acc 0.90477, 80.54 secs
# (2) Validation stage ...
# nli_acc 0.85566, 0.67 secs
# ---- Epoch 198/200
# (1) Training stage (lr = 0.000025) ...
# loss 0.26299, nli_loss 0.26299, nli_acc 0.90698, 80.90 secs
# (2) Validation stage ...
# nli_acc 0.85774, 0.67 secs
# ---- Epoch 199/200
# (1) Training stage (lr = 0.000017) ...
# loss 0.25956, nli_loss 0.25956, nli_acc 0.90894, 79.05 secs
# (2) Validation stage ...
# nli_acc 0.86329, 0.76 secs
# New checkpoint saved: checkpoint_199_nli_acc=0.8679.pt
# ---- Epoch 200/200
# (1) Training stage (lr = 0.000011) ...
# loss 0.25816, nli_loss 0.25816, nli_acc 0.90960, 81.04 secs
# (2) Validation stage ...
# nli_acc 0.85566, 0.70 secs

# %%
# !python ../train_fact_embedding_NLI.py \
--epochs 300 \
--batches_per_epoch 500 \
--batch_size 1000 \
--num_workers 4 \
--iters_to_accumulate 1 \
--optimizer_name "adamw" \
--scheduler "exp-warmup+decay+cyclicdecay" \
--lr 1e-6 \
--warmup_decay_and_cyclic_decay_args "1e-6,3,9e-5,10,2e-6,9e-5,10,2e-6" \
--fact_embedding_model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240207_184445_MIMIC-CXR(triplets+classif+entcont+nli+radgraph+autoencoder)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)" \
--fact_embedding_batch_size 50 \
--fact_embedding_num_workers 4 \
--use_report_nli \
--use_report_nli_entailment_dataset \
--use_report_nli_paraphrases_dataset \
--use_sentence2facts_for_nli \
--integrated_nli_jsonl_filepath \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(169025,21838032).jsonl" \
--sentence_to_facts_input_output_jsonl_filepaths \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_parsed_sentences__v2.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_parsed_sentences__v2(uniform).jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_facts_from_sentences(cluster-balanced,hardest)_part1.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_facts_from_sentences(cluster-balanced,hardest)_part2.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_parsed_sentences__v2.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_facts_from_sentences(cluster-balanced,hardest).jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_facts_from_sentences(cluster-balanced,hardest,conditional).jsonl" \
--integrated_report_facts_jsonl_filepath \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_report_facts(79040140).jsonl" \
--report_nli_input_output_train_jsonl_filepaths \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-1106-preview_fact_based_report_nli_queries(from_labels).jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-1106-preview_fact_based_report_nli_queries(from_facts).jsonl" \
--report_nli_input_output_val_jsonl_filepaths \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-1106-preview_fact_based_report_nli_queries(from_labels,v2).jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-1106-preview_fact_based_report_nli_queries(from_facts,v2).jsonl" \
--paraphrased_inputs_jsonl_filepaths \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_anatomical_locations__part1.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_anatomical_locations__part2.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-16k-0613_paraphrased_anatomical_locations__part3.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__single-words.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words__part1.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-16k-0613_paraphrased_observations__two-or-more-words__part2.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words__part3.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-16k-0613_paraphrased_observations__two-or-more-words__part4.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_paraphrased_observations__two-or-more-words_cluster-balanced.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words_cluster-balanced_1of5.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words_cluster-balanced_2of5.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words_cluster-balanced_3of5.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words_cluster-balanced_4of5.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_hard_triplets_from_facts(cluster-balanced,hardest)-part1.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_hard_triplets_from_facts(cluster-balanced,hardest)-part2.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_hard_triplets_from_facts(cluster-balanced,hardest)-part3.jsonl" \
--embedding_dim 128 \
--mlp_hidden_dims 256 128 \
--dropout 0.1 \
--use_amp \
--save
# Out:
# script's arguments:
#    epochs: 300
#    batches_per_epoch: 500
#    batch_size: 1000
#    num_workers: 4
#    checkpoint_folder: None
#    embedding_dim: 128
#    mlp_hidden_dims: [256, 128]
#    dropout: 0.1
#    optimizer_name: adamw
#    lr: 1e-06
#    scheduler: exp-warmup+decay+cyclicdecay
#    warmup_decay_and_cyclic_decay_args: 1e-6,3,9e-5,10,2e-6,9e-5,10,2e-6
#    iters_to_accumulate: 1
#    override_lr: False
#    device: GPU
#    use_amp: True
#    integrated_nli_jsonl_filepath: /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(169025,21838032).jsonl
#    use_sentence2facts_for_nli: True
#    sentence_to_facts_input_output_jsonl_filepaths: ['/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_parsed_sentences__v2.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_parsed_sentences__v2(uniform).jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_facts_from_sentences(cluster-balanced,hardest)_part1.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_facts_from_sentences(cluster-balanced,hardest)_part2.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_parsed_sentences__v2.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_facts_from_sentences(cluster-balanced,hardest).jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_facts_from_sentences(cluster-balanced,hardest,conditional).jsonl']
#    use_anli: False
#    use_multinli: False
#    use_snli: False
#    use_report_nli: True
#    report_nli_input_output_train_jsonl_filepaths: ['/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-1106-preview_fact_based_report_nli_queries(from_labels).jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-1106-preview_fact_based_report_nli_queries(from_facts).jsonl']
#    report_nli_input_output_val_jsonl_filepaths: ['/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-1106-preview_fact_based_report_nli_queries(from_labels,v2).jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-1106-preview_fact_based_report_nli_queries(from_facts,v2).jsonl']
#    use_report_nli_entailment_dataset: True
#    use_report_nli_paraphrases_dataset: True
#    integrated_report_facts_jsonl_filepath: /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_report_facts(79040140).jsonl
#    paraphrased_inputs_jsonl_filepaths: ['/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_anatomical_locations__part1.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_anatomical_locations__part2.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-16k-0613_paraphrased_anatomical_locations__part3.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__single-words.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words__part1.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-16k-0613_paraphrased_observations__two-or-more-words__part2.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words__part3.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-16k-0613_paraphrased_observations__two-or-more-words__part4.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_paraphrased_observations__two-or-more-words_cluster-balanced.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words_cluster-balanced_1of5.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words_cluster-balanced_2of5.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words_cluster-balanced_3of5.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words_cluster-balanced_4of5.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_hard_triplets_from_facts(cluster-balanced,hardest)-part1.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_hard_triplets_from_facts(cluster-balanced,hardest)-part2.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_hard_triplets_from_facts(cluster-balanced,hardest)-part3.jsonl']
#    fact_embedding_model_name: microsoft/BiomedVLP-CXR-BERT-specialized
#    fact_embedding_model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240207_184445_MIMIC-CXR(triplets+classif+entcont+nli+radgraph+autoencoder)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)
#    fact_embedding_batch_size: 50
#    fact_embedding_num_workers: 4
#    save: True
# ----- Training model from scratch ------
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Creating instance of BertBasedNLI ...
# EmbeddingBasedNLI
#   embedding_dim: 128
#   mlp_hidden_dims: [256, 128]
#   dropout: 0.1
# --------------------------------------------------
# 3) Defining optimizer ...
# create_optimizer(): name = adamw
# --------------------------------------------------
# 4) Defining scheduler ...
# Using exp-warmup+decay+cyclicdecay scheduler: 1e-6,3,9e-5,10,2e-6,9e-5,10,2e-6
# 1e-06 3 9e-05 10 2e-06 9e-05 10 2e-06
# self.steps_to_restart = 10
# self.steps = -1
# self.initial_lr = 9e-05
# --------------------------------------------------
# 5) Creating trainer and validator engines ...
# GradientAccumulator.__init__(): num_accumulation_steps = 1, max_grad_norm = None
# --------------------------------------------------
# 6) Defining collate batch functions ...
# Loaded 19971 input/output pairs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_parsed_sentences__v2.jsonl
# Loaded 19984 input/output pairs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_parsed_sentences__v2(uniform).jsonl
# Loaded 14990 input/output pairs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_facts_from_sentences(cluster-balanced,hardest)_part1.jsonl
# Loaded 14991 input/output pairs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_facts_from_sentences(cluster-balanced,hardest)_part2.jsonl
# Loaded 9999 input/output pairs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_parsed_sentences__v2.jsonl
# Loaded 5000 input/output pairs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_facts_from_sentences(cluster-balanced,hardest).jsonl
# Loaded 9999 input/output pairs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_facts_from_sentences(cluster-balanced,hardest,conditional).jsonl
# Number of sentence2facts pairs: 90614
# Input/output example:
# Input:
# A large-bore introducing catheter projecting over the left neck may not be in a central vein.
# Output:
# ["a large-bore introducing catheter projecting over the left neck", "the catheter may not be in a central vein"]
# --------
# Loaded 9891 paraphrased inputs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_anatomical_locations__part1.jsonl
# Input:
# B
# Paraphrases:
# bilateral
# both sides
# both
# on both sides
# symmetrical
# equally on both sides
# present on both sides
# seen on both sides
# occurring on both sides
# appearing on both sides
# found on both sides
# noted on both sides
# noted bilaterally
# seen bilaterally
# observed bilaterally
# detected bilaterally
# --------
# Loaded 9890 paraphrased inputs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_anatomical_locations__part2.jsonl
# Input:
# left of the left hilus
# Paraphrases:
# left of the left hilum
# left to the left hilum
# left side of the left hilum
# leftward to the left hilum
# left of the hilum on the left side
# left of the pulmonary hilum on the left
# leftward to the pulmonary hilum on the left
# left to the hilum on the left side
# left side of the pulmonary hilum on the left
# leftward to the hilum on the left side
# --------
# Loaded 8511 paraphrased inputs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-16k-0613_paraphrased_anatomical_locations__part3.jsonl
# Input:
# peripheral pulmonary vasculature
# Paraphrases:
# peripheral lung vessels
# peripheral pulmonary blood vessels
# lung periphery vasculature
# vasculature of the peripheral lung
# blood vessels in the outer regions of the lung
# pulmonary vessels in the lung periphery
# vascular network in the peripheral lung
# peripheral pulmonary circulation
# blood vessels supplying the outer areas of the lung
# vasculature in the peripheral regions of the lung
# pulmonary vessels in the lung periphery
# vascular system in the outer regions of the lung
# --------
# Loaded 1864 paraphrased inputs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__single-words.jsonl
# Input:
# a
# Paraphrases:
# one
# single
# sole
# only
# individual
# lone
# solitary
# unique
# distinct
# singular
# --------
# Loaded 14993 paraphrased inputs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words__part1.jsonl
# Input:
# 5 cm
# Paraphrases:
# 5 centimeters
# 5 cm
# 5 centimetres
# 5 cm in size
# a length of 5 cm
# a measurement of 5 cm
# measuring 5 cm
# 5 centimeters in length
# a size of 5 cm
# 5 cm in dimension
# --------
# Loaded 14971 paraphrased inputs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-16k-0613_paraphrased_observations__two-or-more-words__part2.jsonl
# Input:
# limited base
# Paraphrases:
# restricted base
# constrained base
# narrowed base
# limited foundation
# restricted support
# constricted base
# reduced base
# diminished base
# restricted bottom
# constrained footing
# --------
# Loaded 14972 paraphrased inputs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words__part3.jsonl
# Input:
# not visible
# Paraphrases:
# not visualized
# not seen
# not apparent
# not detectable
# absent
# not present
# unable to visualize
# not observable
# not evident
# not identifiable
# --------
# Loaded 14965 paraphrased inputs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-16k-0613_paraphrased_observations__two-or-more-words__part4.jsonl
# Input:
# bowel loops
# Paraphrases:
# intestinal loops
# intestinal segments
# bowel segments
# intestinal coils
# intestinal twists
# intestinal convolutions
# intestinal turns
# intestinal curvatures
# intestinal windings
# intestinal meanders
# --------
# Loaded 10000 paraphrased inputs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_paraphrased_observations__two-or-more-words_cluster-balanced.jsonl
# Input:
# 5th rib
# Paraphrases:
# The fifth rib
# Rib number five
# Rib 5
# 5th rib bone
# Bone of the fifth rib
# Fifth rib structure
# Structure of the 5th rib
# 5th costal bone
# Fifth costal bone
# Costal bone number five
# 5th costae
# Costae number five
# Fifth costae structure
# Structure of the 5th costae
# --------
# Loaded 9999 paraphrased inputs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words_cluster-balanced_1of5.jsonl
# Input:
# CT 2
# Paraphrases:
# Computed tomography scan
# CT imaging
# CT examination
# CT scan
# CT imaging study
# Computed tomography imaging
# Computed tomography exam
# CT scan procedure
# CT scan test
# CT diagnostic imaging
# CT imaging technique
# CT scan investigation
# CT radiographic study
# Computed tomography imaging procedure
# CT scan evaluation
# --------
# Loaded 9997 paraphrased inputs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words_cluster-balanced_2of5.jsonl
# Input:
# line location
# Paraphrases:
# The line is located
# The position of the line is
# The line can be seen
# The line is situated
# The line is found
# The line appears
# The line is detected
# The line is identified
# The line is visible
# The line is present
# The line is observed
# The line is noted
# The line is seen
# The line is evident
# --------
# Loaded 9994 paraphrased inputs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words_cluster-balanced_3of5.jsonl
# Input:
# not apparent
# Paraphrases:
# No evidence of
# Not visible
# Not observable
# Not detected
# Not seen
# Not present
# Absence of
# Lack of
# Negative for
# No signs of
# No findings of
# No indications of
# No evidence suggesting
# No abnormalities detected
# --------
# Loaded 9996 paraphrased inputs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_paraphrased_observations__two-or-more-words_cluster-balanced_4of5.jsonl
# Input:
# CT on
# Paraphrases:
# Computed tomography performed
# CT scan done
# Imaging study using computed tomography
# Radiological examination using CT
# CT imaging conducted
# CT scan taken
# CT imaging performed
# Computed tomography examination
# CT scan carried out
# CT imaging study performed
# CT scan conducted
# Computed tomography study done
# CT imaging examination
# CT scan performed
# --------
# Loaded 19937 paraphrased inputs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_hard_triplets_from_facts(cluster-balanced,hardest)-part1.jsonl
# Input:
# no evidence of all-trans retinoic acid syndrome
# Paraphrases:
# no indication of all-trans retinoic acid syndrome
# absence of all-trans retinoic acid syndrome
# no signs of all-trans retinoic acid syndrome
# no presence of all-trans retinoic acid syndrome
# all-trans retinoic acid syndrome not detected
# all-trans retinoic acid syndrome is not observed
# --------
# Loaded 19937 paraphrased inputs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_hard_triplets_from_facts(cluster-balanced,hardest)-part2.jsonl
# Input:
# no evidence of significant constriction
# Paraphrases:
# no indication of notable narrowing
# absence of significant constriction
# no signs of substantial narrowing
# no evidence of significant narrowing
# lack of significant constriction
# no presence of notable constriction
# --------
# Loaded 19943 paraphrased inputs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_hard_triplets_from_facts(cluster-balanced,hardest)-part3.jsonl
# Input:
# no evidence of wheezing
# Paraphrases:
# no signs of wheezing
# absence of wheezing
# no wheezing detected
# no wheezing observed
# no wheezing present
# no wheezing found
# --------
# Number of unique inputs: 190083
# Number of total paraphrases: 2093173
# WARNING: Number of empty paraphrases: 2
# ----
# Loading integrated NLI from /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(169025,21838032).jsonl...
# Number of samples: 169025
# Number of sources: 7
# ----
# Loading sentence2facts input/output pairs for NLI...
# Number of entailment samples added: 214191
# ----
# Loading report NLI datasets...
# Loaded 85996 input/output pairs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-1106-preview_fact_based_report_nli_queries(from_facts).jsonl
# Loaded 63993 input/output pairs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-1106-preview_fact_based_report_nli_queries(from_labels).jsonl
# ----
# Building train NLI dataset...
# Source: gpt-4-0613 | Label: contradiction -> 79430 (4312.76)
# Example:
# Input:
# NLI1: Left chest wall pacer device is seen with leads extending into the region of the right atrium and right ventricle. #H: There is no pacemaker device present in the patient's body.
# Output:
# contradiction
# Source: gpt-4-1106-preview_reasoning-prompt | Label: contradiction -> 10732 (2400.52)
# Example:
# Input:
# NLI1: Cardiomediastinal contour is normal. #H: Cardiomegaly, tiny pleural effusions.
# Output:
# contradiction
# Source: gpt-4-0613_reasoning-prompt | Label: contradiction -> 4170 (1739.18)
# Example:
# Input:
# NLI1: There has been interval increasing in consolidation in the left lower lobe. #H: Persistent consolidation in the left lower lobe which has not significantly changed since prior.
# Output:
# contradiction
# Source: mednli_train | Label: contradiction -> 3744 (1672.60)
# Example:
# Input:
# NLI1: He developed acute-onset chest pain at  midnight on the day of transfer. #H:  Patient has normal exam
# Output:
# contradiction
# Source: mednli_dev | Label: contradiction -> 465 (695.76)
# Example:
# Input:
# NLI1: Diabetes type 2. #H:  Patient has no medical history
# Output:
# contradiction
# Source: mednli_test | Label: contradiction -> 474 (702.30)
# Example:
# Input:
# NLI1: She had a BP of 191/120, HR 102, Sat 91% on ra (98% on 2L n.c.), and was afebrile. #H:  The patient is hypotensive.
# Output:
# contradiction
# Source: radnli_dev | Label: contradiction -> 106 (304.54)
# Example:
# Input:
# NLI1: No large pleural effusion or evidence of pneumothorax is seen. #H: Right pleural effusion is likely increased since prior exam.
# Output:
# contradiction
# Source: report_nli_from_facts | Label: contradiction -> 15168 (2679.10)
# Example:
# Input:
# NLI1: right chest tube in unchanged position. visualized portion of the small right pneumothorax at the right lung base. underestimates in its size. extensive subcutaneous emphysema is unchanged. increased interstitial markings in bilateral lung bases. dependent edema in a patient with severe upper lobe predominant emphysema. no large pleural effusion. normal size cardiomediastinal silhouette. stable visualized portion of small right basal pneumothorax. extensive subcutaneous emphysema is stable. persistent mild bibasilar pulmonary edema #H: smaller compared to the prior exam
# Output:
# contradiction
# Source: report_nli_from_labels | Label: contradiction -> 12772 (2538.11)
# Example:
# Input:
# NLI1: PA chest radiograph provided. lateral chest radiograph provided. no focal consolidation. no pleural effusion. no pneumothorax. normal cardiomediastinal silhouette. hyperdense linear-appearing lesion projecting over the left heart border. lesion between the eighth and ninth posterior ribs. lesion only seen on the PA view. stable lesion since previous study. lesion may be within the chest wall. intact osseous structures. no acute cardiopulmonary process #H: cabg grafts seen
# Output:
# contradiction
# Medical datasets for label contradiction: 7
# Medical report from facts datasets for label contradiction: 1
# Medical report from labels datasets for label contradiction: 1
# Source: gpt-4-0613 | Label: entailment -> 13185 (2563.82)
# Example:
# Input:
# NLI1: The only available material is a CTA from . #H: The patient has undergone a CTA scan.
# Output:
# entailment
# Source: gpt-4-1106-preview_reasoning-prompt | Label: entailment -> 5445 (1911.57)
# Example:
# Input:
# NLI1: The cardiac silhouette is enlarged secondary to AP radiograph technique and low lung volumes. #H: Cardiac silhouette is enlarged but likely accentuated due to low lung volumes.
# Output:
# entailment
# Source: gpt-4-0613_reasoning-prompt | Label: entailment -> 1770 (1256.05)
# Example:
# Input:
# NLI1: There is evidence of mild to moderate pulmonary edema. #H: Overall, picture corresponds to moderate pulmonary edema.
# Output:
# entailment
# Source: mednli_train | Label: entailment -> 3744 (1672.60)
# Example:
# Input:
# NLI1: Pt is a 53 Y M with Hx of DM2, HTN who is transferred from [**Hospital3 2826**] after being hospitalized from [**6-13**] - [**6-20**] with bilateral pneumonia and concern for new malignancy. #H:  History of hyperglycemia
# Output:
# entailment
# Source: mednli_dev | Label: entailment -> 465 (695.76)
# Example:
# Input:
# NLI1: On weaning to 6L NC, his O2 sat decreased to 81-82% #H:  Patient has poor O2 sats
# Output:
# entailment
# Source: mednli_test | Label: entailment -> 473 (701.58)
# Example:
# Input:
# NLI1: Congestive heart failure. #H:  Patient has a chronic condition
# Output:
# entailment
# Source: radnli_dev | Label: entailment -> 93 (279.62)
# Example:
# Input:
# NLI1: The lungs are clear. #H: Left lung is clear.
# Output:
# entailment
# Source: s2f | Label: entailment -> 214191 (5553.26)
# Example:
# Input:
# NLI1: Heart size and mediastinum are unchanged but the res interval development of increased left pleural effusion as well as left basal consolidation, concerning for aspiration. #H: increased left pleural effusion
# Output:
# entailment
# Source: report_nli_from_facts | Label: entailment -> 46465 (3726.66)
# Example:
# Input:
# NLI1: compared to chest radiographs since common on. compared to chest radiographs most recently on 02:21 on. substantially improved aeration in the previously collapsed left upper lobe. substantially atelectatic lower lobe. significant evacuation of previously large left hemothorax. moderate left hemothorax. improved moderate to severe leftward mediastinal shift. very elevated left hemidiaphragm. small amount of left pleural air seen laterally. small amount of left pleural air seen probably inferiorly. unchanged positions of the 3 left thoracostomy tubes. unchanged positions of the fissural right pleural drainage tube. small right pneumothorax. ET tube tip 9.5 cm from the carina. ET tube tip remains 4 or 5 cm above standard placement #H: pleural drains remain in unchanged position
# Output:
# entailment
# Source: report_nli_from_labels | Label: entailment -> 37159 (3498.95)
# Example:
# Input:
# NLI1: heterogeneous opacification in the left lung base. resolved opacification in the left lung base. right basal pleural tube without appreciable pleural effusion. right basal pleural tube without pneumothorax. right-sided chest tube remains in place. no visible pneumothorax. nearly resolved left lower lobe opacity. rapid improvement. aspiration as a likely etiology. small left pleural effusion #H: pleural effusion seen
# Output:
# entailment
# Medical datasets for label entailment: 8
# Loaded 227835 reports from /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_report_facts(79040140).jsonl
# FactBasedReportEntailmentDataset
# Loaded 227835 reports from /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_report_facts(79040140).jsonl
# FactBasedReportParaphrasesDataset
# Loaded 227835 reports from /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_report_facts(79040140).jsonl
# Number of facts: 586352
# Number of inputs with reports: 97257
# Number of inputs without reports: 92826
# Example:
# {'input_text': 'NLI1: postsurgical changes of the left lateral chest cage. chain sutures seen in the left mid lung. clear lungs. lungs without focal consolidation. lungs without pleural effusion. lungs without pneumothorax. status post left lobe upper lobe resection. postoperative pleural in chest wall changes. no acute cardiopulmonary process #H: alterations in the chest wall and pleural space post-surgery', 'output_text': 'entailment'}
# Example:
# {'input_text': 'NLI1: sudden consolidation #H: rapid consolidation', 'output_text': 'entailment'}
# Example:
# {'input_text': 'NLI1: single frontal radiograph of the chest was acquired. redemonstration of a left-sided pacemaker. associated right atrial lead. associated right ventricular lead. not significantly changed. new consolidation at the left lung base. atelectasis at the left lung base. infection at the left lung base. streaky opacities in the right lower lung. atelectasis in the right lower lung. small layering pleural effusion on the right. no pneumothorax. mildly enlarged heart. heart slightly increased compared to prior study. engorgement of the pulmonary vasculature. findings consistent with left lower lung atelectasis. findings consistent with left lower lung pneumonia. new small left pleural effusion. possible small right layering pleural effusion. increased mild-to-moderate cardiomegaly. pulmonary vascular congestion #H: A single anterior posterior radiograph of the chest was taken', 'output_text': 'entailment'}
# Medical report from facts datasets for label entailment: 2
# Medical report from labels datasets for label entailment: 2
# Source: gpt-4-0613 | Label: neutral -> 19123 (2877.24)
# Example:
# Input:
# NLI1: No evidence of pleural effusion, pneumothorax, or lung cancer. #H: There are no pleural effusion, pneumothorax, or signs of pulmonary edema.
# Output:
# neutral
# Source: gpt-4-1106-preview_reasoning-prompt | Label: neutral -> 16675 (2758.96)
# Example:
# Input:
# NLI1: There is slight interval improvement in the right basal consolidation. #H: Right basal consolidation is persistent.
# Output:
# neutral
# Source: gpt-4-0613_reasoning-prompt | Label: neutral -> 3968 (1708.29)
# Example:
# Input:
# NLI1: Loculated right pleural effusion. #H: Small bilateral pleural effusions are better appreciated on the lateral view.
# Output:
# neutral
# Source: mednli_train | Label: neutral -> 3743 (1672.44)
# Example:
# Input:
# NLI1: Has had L sided abd pain x several weeks. #H:  Patient has kidney stone.
# Output:
# neutral
# Source: mednli_dev | Label: neutral -> 465 (695.76)
# Example:
# Input:
# NLI1: Upon presentation to the ED, he was given Vanco and Unasyn, was intermittently hypoxic with O2 sats 85% while sleeping and was placed on 2L NC and admitted to floor. #H:  History of COPD
# Output:
# neutral
# Source: mednli_test | Label: neutral -> 474 (702.30)
# Example:
# Input:
# NLI1: In the ED initial vitals were: 96.8 72 97/68 20 93% 3L. #H:  The patient has a history of COPD
# Output:
# neutral
# Source: radnli_dev | Label: neutral -> 281 (538.25)
# Example:
# Input:
# NLI1: Subtotal collapse has resolved with minimal residual atelectasis of the apex and lung base. #H: Increased areas of atelectasis are seen at both lung bases.
# Output:
# neutral
# Source: report_nli_from_facts | Label: neutral -> 24363 (3094.52)
# Example:
# Input:
# NLI1: no focal consolidation. no pneumothorax. 1 cm nodular opacity just superior to the right hilus. no vascular congestion. no pleural effusions. convex contour arising from the descending thoracic aorta. convex contour arising from the ascending thoracic aorta. unchanged convex contour compared to prior. convex contour corresponds with known aneurysmal dilatation of the ascending thoracic aorta. convex contour corresponds with known aneurysmal dilatation of the descending thoracic aorta. known aortic valvular calcifications not well seen. underlying aortic stenosis. remainder of the mediastinal contours within normal limits. remainder of the hilar contours within normal limits. 1 cm nodular opacity in the medial right upper lobe. parenchymal nodule. overlapping vasculature. aneurysmal dilation of the ascending thoracic aorta. aneurysmal dilation of the descending thoracic aorta. dedicated chest CT should be completed. assessment of stability since prior CT was from year prior #H: patient's known pseudoaneursym of the aortic arch
# Output:
# neutral
# Source: report_nli_from_labels | Label: neutral -> 14062 (2616.39)
# Example:
# Input:
# NLI1: ET tube ends at 2.6 cm from carina. withdrawn at least 2 cm. Right IJ catheter ends in lower SVC. unchanged left lung base pigtail. unchanged bilateral pulmonary edema in the right lung. minimally improved bilateral pulmonary edema in the left lung. no pleural effusion on the left. small pleural effusion on the right. unchanged cardiomediastinal silhouette. normal cardiomediastinal silhouette. improved bilateral pulmonary edema to the left. unchanged bilateral pulmonary edema to the right. severe bilateral pulmonary edema to the right. small pleural effusion to the right. ET tube should be withdrawn 2 cm #H: pneumothorax seen
# Output:
# neutral
# Medical datasets for label neutral: 7
# Medical report from facts datasets for label neutral: 1
# Medical report from labels datasets for label neutral: 1
# ----
# Number of RadNLI test samples: 480
# Number of MS_CXR_T samples: 361
# Loaded 934 input/output pairs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-1106-preview_fact_based_report_nli_queries(from_labels,v2).jsonl
# Loaded 1198 input/output pairs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-1106-preview_fact_based_report_nli_queries(from_facts,v2).jsonl
# Number of val NLI samples: 2973
# Input:
# NLI1: frontal view. lateral view. Chest: Frontal. Chest: Lateral. narrowing in the lower trachea. improved appearance of the upper trachea. right greater than left effusion. fluid in the right major fissure. fluid in the right minor fissure. no pneumothorax. unchanged postoperative appearance of cardiac silhouette. unchanged postoperative appearance of mediastinal silhouette. left PICC tip in low SVC. calcified aortic knob. vertebral hardware unchanged. increased bilateral pleural effusions. increased bibasilar atelectasis. narrowing of lower trachea #H: chronic tracheal deviation of trachea
# Output:
# contradiction
# Input:
# NLI1: heterogeneous opacification in the left lower lung. opacification due to atelectasis. opacification due to small amount of pulmonary hemorrhage. left hilar mass unchanged. contiguous tubular left upper lobe mass unchanged. predominantly basilar pulmonary fibrosis. no acute abnormality in the right lung. no pneumothorax. no appreciable pleural effusion. stable moderate enlargement of the cardiomediastinal silhouette. enlargement of the cardiomediastinal silhouette due to adenopathy. enlargement of the cardiomediastinal silhouette due to pericardial effusion #H: alveolar hemorrhage seen
# Output:
# contradiction
# Input:
# NLI1: no opacity concerning for pneumonia. enlargement of the cardiac silhouette. tortuosity of the aorta. single-lead pacer device extending to the apex of the right ventricle. no evidence of appreciable vascular congestion. no evidence of acute focal pneumonia. no evidence of pleural effusion #H: tortuous aorta seen
# Output:
# entailment
# Input:
# NLI1: persistent opacification in the posterior left lower lobe. increased opacification in the posterior left lower lobe. atelectasis in the posterior left lower lobe. large rounded mass in the left posterior costophrenic sulcus. similar size of the mass in the left posterior costophrenic sulcus. hard to compare to the prior CT for small possible changes. lungs remain clear elsewhere. nodules not well seen on radiography. no definite pleural effusion. mild increase in opacification in the left lower lobe. atelectasis in the vicinity of a large known metastasis #H: suggesting possible cardiomyopathy
# Output:
# contradiction
# Input:
# NLI1: minimal left pleural effusion. blunting of the left costophrenic sinus. areas of atelectasis at the left lung base. moderate fluid overload. slightly increased size of the cardiac silhouette. patient has been extubated. nasogastric tube has been removed. pleural drains in place. mediastinal drains in place. Swan-Ganz catheter in place. no evidence of pneumothorax #H: linear/patchy atelectasis seen
# Output:
# entailment
# ----
# Building val NLI dataset...
# Number of general sentences: 0
# Number of medical sentences: 3002384
# Number of whole sentences: 2750291
# Number of splittable sentences: 252280
# Number of unique sentences (after sent_tokenize): 3316516
# Example train texts:
# {'input_text': 'NLI1: removal of Swan-Ganz catheter. no visible pneumothorax. enlarging left pleural effusion. moderate-to-large left pleural effusion. adjacent left lower lobe atelectasis. Hemothorax should be considered. Hemothorax given recent surgery. clear right lung. clear pleural surfaces #H: residual loculated pyopneumothorax', 'output_text': 'contradiction'}
# {'input_text': 'NLI1: homogeneous opacification in the right lower hemithorax medially. consolidation in the right lower lobe. layering pleural effusion posteriorly. clear left lung. normal heart size. normal mediastinal silhouette. normal hilar silhouette. unremarkable costopleural surfaces. no evidence of pneumothorax. ET tube in standard placement. nasogastric tube passing into the stomach. intraaortic balloon pump ends midway between the upper margin of the left main bronchus and the apex of the aortic knob. intraaortic balloon pump ends approximately 3.5 cm from the apex of the aortic knob #H: calcified texture seen', 'output_text': 'neutral'}
# {'input_text': 'NLI1: There are no relevant changes since . #H: Overall, no interval change since .', 'output_text': 'entailment'}
# Examples dev texts:
# {'input_text': 'NLI1: well-expanded lungs. lungs without focal opacities concerning for pneumonia. engorgement of the superior vena cava. right atrial enlargement suggestive of fluid overload. mild cardiomegaly. moderate cardiomegaly. no pleural effusion. no pneumothorax. right atrial engorgement of the azygos vein. no evidence of pneumonia #H: tip seen to the level of the upper SVC', 'output_text': 'neutral'}
# {'input_text': 'NLI1: reviewed PA upright chest radiograph. reviewed lateral upright chest radiograph. normal heart size. stable appearance of the mediastinum. calcifications in the prevascular. calcifications in the aortopulmonic window. hilar calcifications. prior granulomatous exposure. no new consolidations. left upper hemithorax pacemaker with leads continuing towards the neck. unchanged appearance of pacemaker. pacemaker consistent with vagal stimulator. pacemaker consistent with deep brain stimulator. no pleural effusion. no pneumothorax. no evidence of acute cardiopulmonary process #H: calcification in the hilar lymph nodes', 'output_text': 'entailment'}
# {'input_text': 'NLI1: coiled Dobbhoff tube tip in the stomach. Dobbhoff tube tip in the prepyloric location. moderate cardiomegaly. unchanged cardiomegaly. patient in pulmonary edema. pulmonary edema grossly unchanged since :18 a.m. #H: unchanged persistent pulmonary edema', 'output_text': 'entailment'}
# checkpoint_names = ['checkpoint_91_cacc+chf1+chf1+cscc+encc+hscc+nlcc+sass+spss+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.
#         0.0285621 ,  0.10360503,  0.1355963 ,  0.18449809,  0.10883575,
#        -0.04638825, -0.11690387,  0.07218589,  0.05113071, -0.05363827,
# ...
#         0.02179232,  0.01526017, -0.03097724, -0.02682166,  0.04124473,
#         0.04260886,  0.01029275,  0.01865325,  0.0365586 , -0.02317956,
#         0.02793415,  0.02115443,  0.06035962,  0.08725479,  0.07469641,
#        -0.03432589, -0.056043  ,  0.01079462, -0.00062024, -0.03699103,
#         0.11391769, -0.03561715,  0.00328194, -0.11200655, -0.02694872,
#        -0.08400176, -0.01344299, -0.01369956, -0.01604017, -0.00293589,
#         0.02015931,  0.05740069, -0.01436212], dtype=float32), 'l': 1}
# nli_trainer.name =  NLI(Embedding-based)
# --------------------------------------------------
# 7) Attaching metrics, losses, timer and events to engines ...
# --------------------------------------------------
# 8) Defining learning rate scheduler handler ...
# --------------------------------------------------
# 9) Defining learning rate scheduler handler ...
# --------------------------------------------------
# 10) Defining checkpoint folder path ...
# checkpoint_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240407_215819_NLI(Embedding-based)_EmbeddingBasedNLI(128,256-128)
# metadata saved to /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240407_215819_NLI(Embedding-based)_EmbeddingBasedNLI(128,256-128)/metadata.json
# --------------------------------------------------
# 11) Defining log_metrics_handler ...
# MetricsLogger :: we'll be logging to /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240407_215819_NLI(Embedding-based)_EmbeddingBasedNLI(128,256-128)/metrics_logs.csv
# --------------------------------------------------
# 12) Running trainer engine ...
# ---- Epoch 1/300
# (1) Training stage (lr = 0.000001) ...
# loss 1.09840, nli_loss 1.09840, nli_acc 0.33334, 64.98 secs
# (2) Validation stage ...
# nli_acc 0.26539, 1.05 secs
# New checkpoint saved: checkpoint_1_nli_acc=0.2722.pt
# ---- Epoch 2/300
# (1) Training stage (lr = 0.000004) ...
# loss 1.09279, nli_loss 1.09279, nli_acc 0.37369, 63.41 secs
# (2) Validation stage ...
# nli_acc 0.36798, 1.07 secs
# New checkpoint saved: checkpoint_2_nli_acc=0.3685.pt
# ---- Epoch 3/300
# (1) Training stage (lr = 0.000020) ...
# loss 0.98141, nli_loss 0.98141, nli_acc 0.57896, 63.37 secs
# (2) Validation stage ...
# nli_acc 0.51430, 1.06 secs
# New checkpoint saved: checkpoint_3_nli_acc=0.5208.pt
# ---- Epoch 4/300
# (1) Training stage (lr = 0.000090) ...
# loss 0.68130, nli_loss 0.68130, nli_acc 0.70096, 63.57 secs
# (2) Validation stage ...
# nli_acc 0.67205, 1.08 secs
# New checkpoint saved: checkpoint_4_nli_acc=0.6749.pt
# ---- Epoch 5/300
# (1) Training stage (lr = 0.000062) ...
# loss 0.58282, nli_loss 0.58282, nli_acc 0.74602, 63.09 secs
# (2) Validation stage ...
# nli_acc 0.70098, 1.06 secs
# New checkpoint saved: checkpoint_5_nli_acc=0.7055.pt
# ---- Epoch 6/300
# (1) Training stage (lr = 0.000042) ...
# loss 0.56050, nli_loss 0.56050, nli_acc 0.75622, 63.03 secs
# (2) Validation stage ...
# nli_acc 0.71544, 1.05 secs
# New checkpoint saved: checkpoint_6_nli_acc=0.7195.pt
# ---- Epoch 7/300
# (1) Training stage (lr = 0.000029) ...
# loss 0.54978, nli_loss 0.54978, nli_acc 0.76102, 63.33 secs
# (2) Validation stage ...
# nli_acc 0.71578, 1.06 secs
# New checkpoint saved: checkpoint_7_nli_acc=0.7203.pt
# ---- Epoch 8/300
# (1) Training stage (lr = 0.000020) ...
# loss 0.54396, nli_loss 0.54396, nli_acc 0.76409, 63.31 secs
# (2) Validation stage ...
# nli_acc 0.72721, 1.07 secs
# New checkpoint saved: checkpoint_8_nli_acc=0.7309.pt
# ---- Epoch 9/300
# (1) Training stage (lr = 0.000013) ...
# loss 0.54037, nli_loss 0.54037, nli_acc 0.76588, 63.23 secs
# (2) Validation stage ...
# nli_acc 0.72318, 1.06 secs
# ---- Epoch 10/300
# (1) Training stage (lr = 0.000009) ...
# loss 0.53883, nli_loss 0.53883, nli_acc 0.76645, 62.90 secs
# (2) Validation stage ...
# nli_acc 0.72452, 1.06 secs
# ---- Epoch 11/300
# (1) Training stage (lr = 0.000006) ...
# loss 0.53647, nli_loss 0.53647, nli_acc 0.76807, 63.24 secs
# (2) Validation stage ...
# nli_acc 0.72889, 1.08 secs
# New checkpoint saved: checkpoint_11_nli_acc=0.7328.pt
# ---- Epoch 12/300
# (1) Training stage (lr = 0.000004) ...
# loss 0.53634, nli_loss 0.53634, nli_acc 0.76788, 63.21 secs
# (2) Validation stage ...
# nli_acc 0.72822, 1.06 secs
# ---- Epoch 13/300
# (1) Training stage (lr = 0.000003) ...
# loss 0.53520, nli_loss 0.53520, nli_acc 0.76846, 62.78 secs
# (2) Validation stage ...
# nli_acc 0.72486, 1.06 secs
# ---- Epoch 14/300
# (1) Training stage (lr = 0.000002) ...
# loss 0.53444, nli_loss 0.53444, nli_acc 0.76893, 62.82 secs
# (2) Validation stage ...
# nli_acc 0.72587, 1.06 secs
# ---- Epoch 15/300
# (1) Training stage (lr = 0.000090) ...
# loss 0.53036, nli_loss 0.53036, nli_acc 0.77080, 63.44 secs
# (2) Validation stage ...
# nli_acc 0.72822, 1.09 secs
# ---- Epoch 16/300
# (1) Training stage (lr = 0.000059) ...
# loss 0.52101, nli_loss 0.52101, nli_acc 0.77552, 63.14 secs
# (2) Validation stage ...
# nli_acc 0.73596, 1.06 secs
# New checkpoint saved: checkpoint_16_nli_acc=0.7399.pt
# ---- Epoch 17/300
# (1) Training stage (lr = 0.000039) ...
# loss 0.51443, nli_loss 0.51443, nli_acc 0.77887, 63.51 secs
# (2) Validation stage ...
# nli_acc 0.73764, 1.06 secs
# New checkpoint saved: checkpoint_17_nli_acc=0.7418.pt
# ---- Epoch 18/300
# (1) Training stage (lr = 0.000025) ...
# loss 0.51133, nli_loss 0.51133, nli_acc 0.78071, 63.12 secs
# (2) Validation stage ...
# nli_acc 0.74302, 1.06 secs
# New checkpoint saved: checkpoint_18_nli_acc=0.7468.pt
# ---- Epoch 19/300
# (1) Training stage (lr = 0.000017) ...
# loss 0.50859, nli_loss 0.50859, nli_acc 0.78193, 63.63 secs
# (2) Validation stage ...
# nli_acc 0.74033, 1.06 secs
# ---- Epoch 20/300
# (1) Training stage (lr = 0.000011) ...
# loss 0.50667, nli_loss 0.50667, nli_acc 0.78299, 62.81 secs
# (2) Validation stage ...
# nli_acc 0.74302, 1.05 secs
# New checkpoint saved: checkpoint_20_nli_acc=0.7470.pt
# ---- Epoch 21/300
# (1) Training stage (lr = 0.000007) ...
# loss 0.50622, nli_loss 0.50622, nli_acc 0.78300, 63.41 secs
# (2) Validation stage ...
# nli_acc 0.73629, 1.05 secs
# ---- Epoch 22/300
# (1) Training stage (lr = 0.000005) ...
# loss 0.50512, nli_loss 0.50512, nli_acc 0.78364, 63.32 secs
# (2) Validation stage ...
# nli_acc 0.73528, 1.06 secs
# ---- Epoch 23/300
# (1) Training stage (lr = 0.000003) ...
# loss 0.50471, nli_loss 0.50471, nli_acc 0.78362, 63.35 secs
# (2) Validation stage ...
# nli_acc 0.73562, 1.06 secs
# ---- Epoch 24/300
# (1) Training stage (lr = 0.000002) ...
# loss 0.50494, nli_loss 0.50494, nli_acc 0.78386, 63.13 secs
# (2) Validation stage ...
# nli_acc 0.73697, 1.09 secs
# ---- Epoch 25/300
# (1) Training stage (lr = 0.000090) ...
# loss 0.50423, nli_loss 0.50423, nli_acc 0.78442, 63.29 secs
# (2) Validation stage ...
# nli_acc 0.73192, 1.06 secs
# ---- Epoch 26/300
# (1) Training stage (lr = 0.000059) ...
# loss 0.49658, nli_loss 0.49658, nli_acc 0.78846, 63.04 secs
# (2) Validation stage ...
# nli_acc 0.73596, 1.06 secs
# ---- Epoch 27/300
# (1) Training stage (lr = 0.000039) ...
# loss 0.49332, nli_loss 0.49332, nli_acc 0.79046, 63.49 secs
# (2) Validation stage ...
# nli_acc 0.73461, 1.06 secs
# ---- Epoch 28/300
# (1) Training stage (lr = 0.000025) ...
# loss 0.49072, nli_loss 0.49072, nli_acc 0.79111, 62.98 secs
# (2) Validation stage ...
# nli_acc 0.73898, 1.06 secs
# ---- Epoch 29/300
# (1) Training stage (lr = 0.000017) ...
# loss 0.48842, nli_loss 0.48842, nli_acc 0.79265, 63.66 secs
# (2) Validation stage ...
# nli_acc 0.73865, 1.07 secs
# ---- Epoch 30/300
# (1) Training stage (lr = 0.000011) ...
# loss 0.48703, nli_loss 0.48703, nli_acc 0.79278, 63.41 secs
# (2) Validation stage ...
# nli_acc 0.73730, 1.05 secs
# ---- Epoch 31/300
# (1) Training stage (lr = 0.000007) ...
# loss 0.48649, nli_loss 0.48649, nli_acc 0.79346, 63.21 secs
# (2) Validation stage ...
# nli_acc 0.73697, 1.08 secs
# ---- Epoch 32/300
# (1) Training stage (lr = 0.000005) ...
# loss 0.48697, nli_loss 0.48697, nli_acc 0.79313, 63.66 secs
# (2) Validation stage ...
# nli_acc 0.73730, 1.06 secs
# ---- Epoch 33/300
# (1) Training stage (lr = 0.000003) ...
# loss 0.48562, nli_loss 0.48562, nli_acc 0.79376, 63.25 secs
# (2) Validation stage ...
# nli_acc 0.73697, 1.06 secs
# ---- Epoch 34/300
# (1) Training stage (lr = 0.000002) ...
# loss 0.48532, nli_loss 0.48532, nli_acc 0.79451, 63.38 secs
# (2) Validation stage ...
# nli_acc 0.73596, 1.06 secs
# ---- Epoch 35/300
# (1) Training stage (lr = 0.000090) ...
# loss 0.48623, nli_loss 0.48623, nli_acc 0.79365, 63.44 secs
# (2) Validation stage ...
# nli_acc 0.73360, 1.03 secs
# ---- Epoch 36/300
# (1) Training stage (lr = 0.000059) ...
# loss 0.48151, nli_loss 0.48151, nli_acc 0.79639, 63.37 secs
# (2) Validation stage ...
# nli_acc 0.73327, 1.06 secs
# ---- Epoch 37/300
# (1) Training stage (lr = 0.000039) ...
# loss 0.47686, nli_loss 0.47686, nli_acc 0.79837, 63.22 secs
# (2) Validation stage ...
# nli_acc 0.74807, 1.07 secs
# New checkpoint saved: checkpoint_37_nli_acc=0.7531.pt
# ---- Epoch 38/300
# (1) Training stage (lr = 0.000025) ...
# loss 0.47487, nli_loss 0.47487, nli_acc 0.79941, 62.94 secs
# (2) Validation stage ...
# nli_acc 0.74235, 1.06 secs
# ---- Epoch 39/300
# (1) Training stage (lr = 0.000017) ...
# loss 0.47341, nli_loss 0.47341, nli_acc 0.80012, 63.32 secs
# (2) Validation stage ...
# nli_acc 0.74235, 1.06 secs
# ---- Epoch 40/300
# (1) Training stage (lr = 0.000011) ...
# loss 0.47219, nli_loss 0.47219, nli_acc 0.80097, 63.85 secs
# (2) Validation stage ...
# nli_acc 0.74201, 1.07 secs
# ---- Epoch 41/300
# (1) Training stage (lr = 0.000007) ...
# loss 0.47165, nli_loss 0.47165, nli_acc 0.80107, 63.20 secs
# (2) Validation stage ...
# nli_acc 0.74100, 1.06 secs
# ---- Epoch 42/300
# (1) Training stage (lr = 0.000005) ...
# loss 0.47054, nli_loss 0.47054, nli_acc 0.80176, 63.31 secs
# (2) Validation stage ...
# nli_acc 0.74033, 1.06 secs
# ---- Epoch 43/300
# (1) Training stage (lr = 0.000003) ...
# loss 0.47037, nli_loss 0.47037, nli_acc 0.80189, 62.90 secs
# (2) Validation stage ...
# nli_acc 0.74268, 1.06 secs
# ---- Epoch 44/300
# (1) Training stage (lr = 0.000002) ...
# loss 0.47071, nli_loss 0.47071, nli_acc 0.80184, 63.20 secs
# (2) Validation stage ...
# nli_acc 0.74201, 1.05 secs
# ---- Epoch 45/300
# (1) Training stage (lr = 0.000090) ...
# loss 0.47282, nli_loss 0.47282, nli_acc 0.80047, 63.60 secs
# (2) Validation stage ...
# nli_acc 0.75076, 1.07 secs
# New checkpoint saved: checkpoint_45_nli_acc=0.7557.pt
# ---- Epoch 46/300
# (1) Training stage (lr = 0.000059) ...
# loss 0.46772, nli_loss 0.46772, nli_acc 0.80318, 63.40 secs
# (2) Validation stage ...
# nli_acc 0.74908, 1.06 secs
# ---- Epoch 47/300
# (1) Training stage (lr = 0.000039) ...
# loss 0.46496, nli_loss 0.46496, nli_acc 0.80454, 63.27 secs
# (2) Validation stage ...
# nli_acc 0.74807, 1.06 secs
# ---- Epoch 48/300
# (1) Training stage (lr = 0.000025) ...
# loss 0.46264, nli_loss 0.46264, nli_acc 0.80573, 63.33 secs
# (2) Validation stage ...
# nli_acc 0.74571, 1.10 secs
# ---- Epoch 49/300
# (1) Training stage (lr = 0.000017) ...
# loss 0.46040, nli_loss 0.46040, nli_acc 0.80706, 63.22 secs
# (2) Validation stage ...
# nli_acc 0.74067, 1.09 secs
# ---- Epoch 50/300
# (1) Training stage (lr = 0.000011) ...
# loss 0.45921, nli_loss 0.45921, nli_acc 0.80755, 63.11 secs
# (2) Validation stage ...
# nli_acc 0.74302, 1.06 secs
# ---- Epoch 51/300
# (1) Training stage (lr = 0.000007) ...
# loss 0.45954, nli_loss 0.45954, nli_acc 0.80689, 63.41 secs
# (2) Validation stage ...
# nli_acc 0.74672, 1.06 secs
# ---- Epoch 52/300
# (1) Training stage (lr = 0.000005) ...
# loss 0.45813, nli_loss 0.45813, nli_acc 0.80794, 63.24 secs
# (2) Validation stage ...
# nli_acc 0.74504, 1.06 secs
# ---- Epoch 53/300
# (1) Training stage (lr = 0.000003) ...
# loss 0.45826, nli_loss 0.45826, nli_acc 0.80799, 63.50 secs
# (2) Validation stage ...
# nli_acc 0.74638, 1.06 secs
# ---- Epoch 54/300
# (1) Training stage (lr = 0.000002) ...
# loss 0.45771, nli_loss 0.45771, nli_acc 0.80844, 63.23 secs
# (2) Validation stage ...
# nli_acc 0.74504, 1.06 secs
# ---- Epoch 55/300
# (1) Training stage (lr = 0.000090) ...
# loss 0.46122, nli_loss 0.46122, nli_acc 0.80665, 63.47 secs
# (2) Validation stage ...
# nli_acc 0.74302, 1.06 secs
# ---- Epoch 56/300
# (1) Training stage (lr = 0.000059) ...
# loss 0.45689, nli_loss 0.45689, nli_acc 0.80867, 63.54 secs
# (2) Validation stage ...
# nli_acc 0.74504, 1.07 secs
# ---- Epoch 57/300
# (1) Training stage (lr = 0.000039) ...
# loss 0.45298, nli_loss 0.45298, nli_acc 0.81028, 63.28 secs
# (2) Validation stage ...
# nli_acc 0.75244, 1.06 secs
# New checkpoint saved: checkpoint_57_nli_acc=0.7582.pt
# ---- Epoch 58/300
# (1) Training stage (lr = 0.000025) ...
# loss 0.45077, nli_loss 0.45077, nli_acc 0.81132, 63.36 secs
# (2) Validation stage ...
# nli_acc 0.74437, 1.07 secs
# ---- Epoch 59/300
# (1) Training stage (lr = 0.000017) ...
# loss 0.45010, nli_loss 0.45010, nli_acc 0.81216, 63.47 secs
# (2) Validation stage ...
# nli_acc 0.74605, 1.06 secs
# ---- Epoch 60/300
# (1) Training stage (lr = 0.000011) ...
# loss 0.44904, nli_loss 0.44904, nli_acc 0.81199, 63.49 secs
# (2) Validation stage ...
# nli_acc 0.74538, 1.06 secs
# ---- Epoch 61/300
# (1) Training stage (lr = 0.000007) ...
# loss 0.44819, nli_loss 0.44819, nli_acc 0.81302, 62.68 secs
# (2) Validation stage ...
# nli_acc 0.74739, 1.03 secs
# ---- Epoch 62/300
# (1) Training stage (lr = 0.000005) ...
# loss 0.44695, nli_loss 0.44695, nli_acc 0.81323, 63.45 secs
# (2) Validation stage ...
# nli_acc 0.74773, 1.06 secs
# ---- Epoch 63/300
# (1) Training stage (lr = 0.000003) ...
# loss 0.44730, nli_loss 0.44730, nli_acc 0.81380, 63.48 secs
# (2) Validation stage ...
# nli_acc 0.74739, 1.09 secs
# ---- Epoch 64/300
# (1) Training stage (lr = 0.000002) ...
# loss 0.44729, nli_loss 0.44729, nli_acc 0.81333, 63.32 secs
# (2) Validation stage ...
# nli_acc 0.74672, 1.06 secs
# ---- Epoch 65/300
# (1) Training stage (lr = 0.000090) ...
# loss 0.45030, nli_loss 0.45030, nli_acc 0.81144, 63.10 secs
# (2) Validation stage ...
# nli_acc 0.73764, 1.07 secs
# ---- Epoch 66/300
# (1) Training stage (lr = 0.000059) ...
# loss 0.44647, nli_loss 0.44647, nli_acc 0.81424, 63.28 secs
# (2) Validation stage ...
# nli_acc 0.74739, 1.06 secs
# ---- Epoch 67/300
# (1) Training stage (lr = 0.000039) ...
# loss 0.44339, nli_loss 0.44339, nli_acc 0.81533, 63.32 secs
# (2) Validation stage ...
# nli_acc 0.73999, 1.07 secs
# ---- Epoch 68/300
# (1) Training stage (lr = 0.000025) ...
# loss 0.44074, nli_loss 0.44074, nli_acc 0.81667, 63.71 secs
# (2) Validation stage ...
# nli_acc 0.74908, 1.06 secs
# ---- Epoch 69/300
# (1) Training stage (lr = 0.000017) ...
# loss 0.43942, nli_loss 0.43942, nli_acc 0.81707, 63.15 secs
# (2) Validation stage ...
# nli_acc 0.74840, 1.05 secs
# ---- Epoch 70/300
# (1) Training stage (lr = 0.000011) ...
# loss 0.43852, nli_loss 0.43852, nli_acc 0.81794, 62.77 secs
# (2) Validation stage ...
# nli_acc 0.74975, 1.06 secs
# ---- Epoch 71/300
# (1) Training stage (lr = 0.000007) ...
# loss 0.43816, nli_loss 0.43816, nli_acc 0.81818, 63.49 secs
# (2) Validation stage ...
# nli_acc 0.74706, 1.05 secs
# ---- Epoch 72/300
# (1) Training stage (lr = 0.000005) ...
# loss 0.43779, nli_loss 0.43779, nli_acc 0.81821, 63.37 secs
# (2) Validation stage ...
# nli_acc 0.74672, 1.07 secs
# ---- Epoch 73/300
# (1) Training stage (lr = 0.000003) ...
# loss 0.43686, nli_loss 0.43686, nli_acc 0.81920, 63.54 secs
# (2) Validation stage ...
# nli_acc 0.74773, 1.06 secs
# ---- Epoch 74/300
# (1) Training stage (lr = 0.000002) ...
# loss 0.43689, nli_loss 0.43689, nli_acc 0.81865, 63.50 secs
# (2) Validation stage ...
# nli_acc 0.74739, 1.06 secs
# ---- Epoch 75/300
# (1) Training stage (lr = 0.000090) ...
# loss 0.44181, nli_loss 0.44181, nli_acc 0.81623, 63.83 secs
# (2) Validation stage ...
# nli_acc 0.74908, 1.06 secs
# ---- Epoch 76/300
# (1) Training stage (lr = 0.000059) ...
# loss 0.43721, nli_loss 0.43721, nli_acc 0.81858, 63.22 secs
# (2) Validation stage ...
# nli_acc 0.73798, 1.06 secs
# ---- Epoch 77/300
# (1) Training stage (lr = 0.000039) ...
# loss 0.43394, nli_loss 0.43394, nli_acc 0.82021, 63.14 secs
# (2) Validation stage ...
# nli_acc 0.75008, 1.10 secs
# ---- Epoch 78/300
# (1) Training stage (lr = 0.000025) ...
# loss 0.43189, nli_loss 0.43189, nli_acc 0.82098, 63.81 secs
# (2) Validation stage ...
# nli_acc 0.75210, 1.06 secs
# New checkpoint saved: checkpoint_78_nli_acc=0.7590.pt
# ---- Epoch 79/300
# (1) Training stage (lr = 0.000017) ...
# loss 0.43100, nli_loss 0.43100, nli_acc 0.82129, 63.59 secs
# (2) Validation stage ...
# nli_acc 0.74538, 1.09 secs
# ---- Epoch 80/300
# (1) Training stage (lr = 0.000011) ...
#    iteration 39775

# %%
f'EmbeddingBasedNLI({10},{[10, 20]})'
# Out:
# 'EmbeddingBasedNLI(10,[10, 20])'

# %%
from medvqa.utils.files import load_jsonl

# %%
from medvqa.train_fact_embedding_NLI import debug_trainer

# %%
trainer = debug_trainer(
"""
--epochs 300 \
--batches_per_epoch 100 \
--batch_size 50 \
--num_workers 3 \
--iters_to_accumulate 1 \
--optimizer_name "adamw" \
--scheduler "exp-warmup+decay+cyclicdecay" \
--lr 1e-6 \
--warmup_decay_and_cyclic_decay_args "1e-6,3,9e-5,10,2e-6,9e-5,10,2e-6" \
--fact_embedding_model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240207_184445_MIMIC-CXR(triplets+classif+entcont+nli+radgraph+autoencoder)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)" \
--fact_embedding_batch_size 50 \
--fact_embedding_num_workers 4 \
--use_anli \
--use_multinli \
--use_snli \
--use_report_nli \
--use_report_nli_entailment_dataset \
--use_sentence2facts_for_nli \
--integrated_nli_jsonl_filepath \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(169025,21838032).jsonl" \
--sentence_to_facts_input_output_jsonl_filepaths \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_parsed_sentences__v2.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_parsed_sentences__v2(uniform).jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_facts_from_sentences(cluster-balanced,hardest)_part1.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_facts_from_sentences(cluster-balanced,hardest)_part2.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_parsed_sentences__v2.jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_facts_from_sentences(cluster-balanced,hardest).jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_facts_from_sentences(cluster-balanced,hardest,conditional).jsonl" \
--integrated_report_facts_jsonl_filepath \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_report_facts(79040140).jsonl" \
--report_nli_input_output_jsonl_filepaths \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-1106-preview_fact_based_report_nli_queries(from_labels).jsonl" \
"/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-1106-preview_fact_based_report_nli_queries(from_facts).jsonl" \
--embedding_size 128 \
--transf_nhead 1 \
--transf_d_ff 128 \
--transf_nlayers 3 \
--transf_dropout 0 \
--use_amp \
--no_save
"""
)
# Out:
# script's arguments:
#    epochs: 300
#    batches_per_epoch: 100
#    batch_size: 50
#    num_workers: 3
#    checkpoint_folder: None
#    embedding_size: 128
#    transf_nhead: 1
#    transf_d_ff: 128
#    transf_nlayers: 3
#    transf_dropout: 0.0
#    optimizer_name: adamw
#    lr: 1e-06
#    scheduler: exp-warmup+decay+cyclicdecay
#    warmup_decay_and_cyclic_decay_args: 1e-6,3,9e-5,10,2e-6,9e-5,10,2e-6
#    iters_to_accumulate: 1
#    override_lr: False
#    device: GPU
#    use_amp: True
#    integrated_nli_jsonl_filepath: /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(169025,21838032).jsonl
#    use_sentence2facts_for_nli: True
#    sentence_to_facts_input_output_jsonl_filepaths: ['/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_parsed_sentences__v2.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_parsed_sentences__v2(uniform).jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_facts_from_sentences(cluster-balanced,hardest)_part1.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_facts_from_sentences(cluster-balanced,hardest)_part2.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_parsed_sentences__v2.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_facts_from_sentences(cluster-balanced,hardest).jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_facts_from_sentences(cluster-balanced,hardest,conditional).jsonl']
#    use_anli: True
#    use_multinli: True
#    use_snli: True
#    use_report_nli: True
#    report_nli_input_output_jsonl_filepaths: ['/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-1106-preview_fact_based_report_nli_queries(from_labels).jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-1106-preview_fact_based_report_nli_queries(from_facts).jsonl']
#    use_report_nli_entailment_dataset: True
#    integrated_report_facts_jsonl_filepath: /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_report_facts(79040140).jsonl
#    fact_embedding_model_name: microsoft/BiomedVLP-CXR-BERT-specialized
#    fact_embedding_model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240207_184445_MIMIC-CXR(triplets+classif+entcont+nli+radgraph+autoencoder)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)
#    fact_embedding_batch_size: 50
#    fact_embedding_num_workers: 4
#    save: False
# ----- Training model from scratch ------
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Creating instance of BertBasedNLI ...
# EmbeddingBasedNLI
#   embedding_size: 128
#   transf_nhead: 1
#   transf_d_ff: 128
#   transf_nlayers: 3
#   transf_dropout: 0.0
# --------------------------------------------------
# 3) Defining optimizer ...
# create_optimizer(): name = adamw
# --------------------------------------------------
# 4) Defining scheduler ...
# Using exp-warmup+decay+cyclicdecay scheduler: 1e-6,3,9e-5,10,2e-6,9e-5,10,2e-6
# 1e-06 3 9e-05 10 2e-06 9e-05 10 2e-06
# self.steps_to_restart = 10
# self.steps = -1
# self.initial_lr = 9e-05
# --------------------------------------------------
# 5) Creating trainer and validator engines ...
# GradientAccumulator.__init__(): num_accumulation_steps = 1, max_grad_norm = None
# --------------------------------------------------
# 6) Defining collate batch functions ...
# Loaded 19971 input/output pairs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_parsed_sentences__v2.jsonl
# Loaded 19984 input/output pairs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_parsed_sentences__v2(uniform).jsonl
# Loaded 14990 input/output pairs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_facts_from_sentences(cluster-balanced,hardest)_part1.jsonl
# Loaded 14991 input/output pairs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo-0613_facts_from_sentences(cluster-balanced,hardest)_part2.jsonl
# Loaded 9999 input/output pairs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_parsed_sentences__v2.jsonl
# Loaded 5000 input/output pairs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_facts_from_sentences(cluster-balanced,hardest).jsonl
# Loaded 9999 input/output pairs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_facts_from_sentences(cluster-balanced,hardest,conditional).jsonl
# Number of sentence2facts pairs: 90614
# Input/output example:
# Input:
# Branching hypodensities in the right upper quadrant are compatible with portal venous gas seen on prior CT. Massively distended loops of bowel seen in the abdomen without definite free intraperitoneal air based on this supine film.
# Output:
# ["branching hypodensities in the right upper quadrant", "portal venous gas seen on prior CT", "massively distended loops of bowel seen in the abdomen", "no definite free intraperitoneal air based on this supine film"]
# ----
# Loading integrated NLI from /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_nli_examples(169025,21838032).jsonl...
# Number of samples: 169025
# Number of sources: 7
# ----
# Loading sentence2facts input/output pairs for NLI...
# Number of entailment samples added: 214191
# ----
# Loading general domain datasets...
# Loading ANLI...
# Number of ANLI R1 samples: 18946
# Number of ANLI R2 samples: 47460
# Number of ANLI R3 samples: 102859
# Loading MultiNLI...
# Number of MultiNLI train samples: 392702
# Number of MultiNLI dev_matched samples: 10000
# Number of MultiNLI dev_mismatched samples: 10000
# Loading SNLI...
# Number of SNLI train samples: 550152
# Number of SNLI dev samples: 10000
# Number of SNLI test samples: 10000
# ----
# Loading report NLI datasets...
# Loaded 80000 input/output pairs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-1106-preview_fact_based_report_nli_queries(from_facts).jsonl
# Loaded 58072 input/output pairs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-1106-preview_fact_based_report_nli_queries(from_labels).jsonl
# ----
# Building train NLI dataset...
# Source: gpt-4-0613 | Label: contradiction -> 79430 (4312.76)
# Example:
# Input:
# NLI1: A right pigtail is unchanged in position. #H: There is no right pigtail present.
# Output:
# contradiction
# Source: gpt-4-1106-preview_reasoning-prompt | Label: contradiction -> 10732 (2400.52)
# Example:
# Input:
# NLI1: Unchanged median sternotomy wires, mediastinal clips and aortic valve replacement. #H: Patient has had median sternotomy and tricuspid and mitral valve replacements.
# Output:
# contradiction
# Source: gpt-4-0613_reasoning-prompt | Label: contradiction -> 4170 (1739.18)
# Example:
# Input:
# NLI1: Interval increase in the air component of the known right hydropneumothorax. #H: Large right hydropneumothorax is grossly unchanged allowing the difference in technique and positioning of the patient.
# Output:
# contradiction
# Source: mednli_train | Label: contradiction -> 3744 (1672.60)
# Example:
# Input:
# NLI1: Has had L sided abd pain x several weeks. #H:  Patient denies pain.
# Output:
# contradiction
# Source: mednli_dev | Label: contradiction -> 465 (695.76)
# Example:
# Input:
# NLI1: PMH: AAA, PVD w/ L iliac aneurysm, R [**Doctor Last Name **] aneurysm approx 5cm, L [**Doctor Last Name **] aneurysm approx 3 cm, chronic Afib, HTN, benign prostatic hyperplasia (no surgical history) #H:  The patient is at low risk for a stroke.
# Output:
# contradiction
# Source: mednli_test | Label: contradiction -> 474 (702.30)
# Example:
# Input:
# NLI1: He was admitted to the Neonatal Intensive Care Unit for a sepsis evaluation with less than four hours of treatment prior to delivery. #H:  patient is a healthy newborn
# Output:
# contradiction
# Source: radnli_dev | Label: contradiction -> 106 (304.54)
# Example:
# Input:
# NLI1: The lungs are low in volume but clear. #H: Lungs: The lungs are well inflated.
# Output:
# contradiction
# Source: anli | Label: contradiction -> 44089 (3672.32)
# Example:
# Input:
# NLI1: As the U.S. military evacuated Saigon in the Spring of 1975, President Gerald Ford approved Operation Babylift, the plan to transport thousands of Vietnamese children to adoptive parents in the West, hundreds of them at a time, before the U.S. was forced out of the country. #H: The U.S. military never evacuated Saigon.
# Output:
# contradiction
# Source: multinli | Label: contradiction -> 137356 (4971.81)
# Example:
# Input:
# NLI1: Part of the National Portrait Collection from the National Gallery is displayed here. #H: No art is displayed.
# Output:
# contradiction
# Source: snli | Label: contradiction -> 189702 (5390.10)
# Example:
# Input:
# NLI1: A man standing in a crowded area. #H: A man stands alone.
# Output:
# contradiction
# Source: report_nli_from_facts | Label: contradiction -> 14141 (2620.99)
# Example:
# Input:
# NLI1: left internal jugular central venous catheter tip course may be intra-arterial. position of the catheter tip overlying the inferior aspect of the aortic knob. catheter tip does not course in the expected region of the left brachiocephalic vein. endotracheal tube remains low lying. endotracheal tube terminating approximately 2.5 cm from the carina. enteric tube within the stomach. unchanged cardiac contours. unchanged mediastinal contours. mild to moderately enlarged heart size. mild upper zone vascular redistribution. vascular redistribution due to supine positioning. atelectasis in both lung bases. no large pleural effusion identified. no pneumothorax identified. no displaced fractures. concerning course of left internal jugular central venous catheter. intra-arterial location of left internal jugular central venous catheter. endotracheal tube should be withdrawn by at least 1 cm #H: left internal jugular catheter terminating in the left brachiocephalic vein just proximal to the superior vena cava
# Output:
# contradiction
# Source: report_nli_from_labels | Label: contradiction -> 11641 (2464.16)
# Example:
# Input:
# NLI1: normal cardiomediastinal silhouette. no pleural effusion. no pneumothorax. no overt pulmonary edema. no focal lung consolidation. no radiographic evidence of pulmonary edema #H: lung lesion seen
# Output:
# contradiction
# General datasets for label contradiction: 3
# Medical datasets for label contradiction: 7
# Medical report from facts datasets for label contradiction: 1
# Medical report from labels datasets for label contradiction: 1
# Source: gpt-4-0613 | Label: entailment -> 13185 (2563.82)
# Example:
# Input:
# NLI1: No definite focal consolidation is seen although this would be difficult to exclude at the right lung base. #H: The right lung base does not show clear signs of focal consolidation.
# Output:
# entailment
# Source: gpt-4-1106-preview_reasoning-prompt | Label: entailment -> 5445 (1911.57)
# Example:
# Input:
# NLI1: Lung volumes slightly improved with associated improved aeration at both lung bases. #H: There is improvement in lung volumes with better aeration of the lung bases.
# Output:
# entailment
# Source: gpt-4-0613_reasoning-prompt | Label: entailment -> 1770 (1256.05)
# Example:
# Input:
# NLI1: There is no evidence of consolidation, effusion or pneumothorax. #H: No gross consolidation is identified.
# Output:
# entailment
# Source: mednli_train | Label: entailment -> 3744 (1672.60)
# Example:
# Input:
# NLI1: Otherwise pt feels well, denies PND or orthopnea or palpitations. #H:  Pt denies paroxysmal nocturnal dyspnea
# Output:
# entailment
# Source: mednli_dev | Label: entailment -> 465 (695.76)
# Example:
# Input:
# NLI1: Also INR of 2.6 on coumadin. #H:  Patient has elevated PT
# Output:
# entailment
# Source: mednli_test | Label: entailment -> 473 (701.58)
# Example:
# Input:
# NLI1: 84-year-old female with CAD s/p CABG in [**8-27**] (LIMA-LAD, SVG-OM1), CHF, ESRD on HD, DMII, PAF who is transferred from outside hospital for cardiac catheterization. . #H:  Patient has multiple medical conditions
# Output:
# entailment
# Source: radnli_dev | Label: entailment -> 93 (279.62)
# Example:
# Input:
# NLI1: No focal consolidation, pleural effusion or pneumothorax is present. #H: No large pleural effusion or pneumothorax is visualized.
# Output:
# entailment
# Source: s2f | Label: entailment -> 214191 (5553.26)
# Example:
# Input:
# NLI1: New heterogeneous opacification in the right lower lung at least some of which is in the middle lobe, obscuring the right heart border, the remainder at the base, is all new since , considered pneumonia until proved otherwise. #H: possible pneumonia
# Output:
# entailment
# Source: anli | Label: entailment -> 54251 (3890.16)
# Example:
# Input:
# NLI1: O'Sullivan Army Heliport (ICAO: KCSL, FAA LID: CSL) is a U.S. Army heliport at Camp San Luis Obispo in San Luis Obispo County, California, United States. It is located just off California State Route 1, northwest of the city of San Luis Obispo, about halfway between it and Morro Bay. O'Sullivan AHP has one helipad designated H1 with a 2,430 by 75 ft (741 by 23 m) asphalt surface. #H: There is a heliport off of California State Route 1.
# Output:
# entailment
# Source: multinli | Label: entailment -> 137841 (4976.25)
# Example:
# Input:
# NLI1: Consultant access to agency decision makers may be limited, resulting in #H: Consultants may not have a lot of access to the decision makers in the agency.
# Output:
# entailment
# Source: snli | Label: entailment -> 190113 (5392.98)
# Example:
# Input:
# NLI1: Two construction workers wearing yellow rubber boots are sitting next to some pipes. #H: Somebody in the frame has footwear on their feet.
# Output:
# entailment
# Source: report_nli_from_facts | Label: entailment -> 43411 (3656.37)
# Example:
# Input:
# NLI1: Left pigtail in unchanged position. no definite pneumothorax remaining. left-sided pigtail pleural catheter remains in place. interval decrease in size of a tiny left apical pneumothorax. no obvious pneumothorax identified on the current examination. subcutaneous emphysema within the lateral chest wall soft tissues. patchy opacity at the left base. atelectasis at the left base. slightly elevated left hemidiaphragm. relatively lower lung volumes. stable cardiac contours. stable mediastinal contours. skin overlying the epigastric region #H: tiny pneumothorax at the left lung apex
# Output:
# entailment
# Source: report_nli_from_labels | Label: entailment -> 33940 (3409.34)
# Example:
# Input:
# NLI1: normal heart size. unchanged mediastinal contours. unchanged hilar contours. mild rightward shift of mediastinal structures. right-sided volume loss. opacity reflecting post-treatment changes in the paramediastinal region of the right upper lobe. no new focal consolidation in the paramediastinal region of the right upper lobe. no pleural effusion in the paramediastinal region of the right upper lobe. no pneumothorax in the paramediastinal region of the right upper lobe. pulmonary vascularity not engorged. degenerative changes of the thoracic spine. post-treatment changes within the right upper lobe. no radiographic evidence for pneumonia #H: mediastinal displacement seen
# Output:
# entailment
# General datasets for label entailment: 3
# Medical datasets for label entailment: 8
# Loaded 227835 reports from /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_report_facts(79040140).jsonl
# FactBasedReportEntailmentDataset
# Loaded 227835 reports from /home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_report_facts(79040140).jsonl
# Medical report from facts datasets for label entailment: 2
# Medical report from labels datasets for label entailment: 1
# Source: gpt-4-0613 | Label: neutral -> 19123 (2877.24)
# Example:
# Input:
# NLI1: Lung base opacities are increased, likely due to atelectasis, which is accentuated by low lung volumes. #H: There is no evidence of a pneumothorax in the patient's chest X-ray.
# Output:
# neutral
# Source: gpt-4-1106-preview_reasoning-prompt | Label: neutral -> 16675 (2758.96)
# Example:
# Input:
# NLI1: Decreased moderate left pleural effusion. #H: Small left pleural effusion posteriorly.
# Output:
# neutral
# Source: gpt-4-0613_reasoning-prompt | Label: neutral -> 3968 (1708.29)
# Example:
# Input:
# NLI1: There is no mediastinal contour abnormality. #H: Interval resolution of previously seen layering effusions.
# Output:
# neutral
# Source: mednli_train | Label: neutral -> 3743 (1672.44)
# Example:
# Input:
# NLI1: He then had a head CT, which revealed lesions read as subacute to acute infarcts of the right cerebellar hemisphere and the right occipital lobe. #H:  the patient is hypertensive
# Output:
# neutral
# Source: mednli_dev | Label: neutral -> 465 (695.76)
# Example:
# Input:
# NLI1: In the course of routine workup for conversion from Prograf to Rapamune, a liver duplex to evaluate for Hepatic Artery thrombosis was done on [**8-11**] per protocol. #H:  Patient has prior liver imaging
# Output:
# neutral
# Source: mednli_test | Label: neutral -> 474 (702.30)
# Example:
# Input:
# NLI1: The baby was noted to have gradual resolution of the ascites and improved MCA blood flow. #H:  The baby has congestive heart failure.
# Output:
# neutral
# Source: radnli_dev | Label: neutral -> 281 (538.25)
# Example:
# Input:
# NLI1: Heart size cannot be assessed. #H: The heart size remains within normal limits.
# Output:
# neutral
# Source: anli | Label: neutral -> 70925 (4184.18)
# Example:
# Input:
# NLI1: Kylie Kristen Jenner (born August 10, 1997) is an American reality television personality, model, entrepreneur, socialite, and social media personality. She is best known for starring in the E! reality television series "Keeping Up with the Kardashians" since age nine, her eponymous brand of cosmetics, and her large social media presence. #H: Kylie Kristen Jenner has many kids
# Output:
# neutral
# Source: multinli | Label: neutral -> 137152 (4969.93)
# Example:
# Input:
# NLI1: Let me try it." She began snapping her fingers and saying the word eagerly, but nothing happened. #H: She became frustrated when the spell didn't work.
# Output:
# neutral
# Source: snli | Label: neutral -> 189218 (5386.70)
# Example:
# Input:
# NLI1: A female singer and male guitarist on stage. #H: They are preforming a song.
# Output:
# neutral
# Source: report_nli_from_facts | Label: neutral -> 22448 (3019.89)
# Example:
# Input:
# NLI1: left pectoral pacer defibrillator with leads ending in the right atrium. right internal jugular line ends in the cavoatrial junction. right subclavian Port-A-Cath ends in the mid SVC. multiple other wires. presumably external wires. markedly increased heart size. moderately to severely enlarged heart. pulmonary vascular congestion. perihilar interstitial opacities consistent with moderate pulmonary edema. no large pleural effusions. no pneumothorax. development of moderate to severe cardiomegaly. course of the nasogastric tube cannot be followed throughout the mediastinum. course of the nasogastric tube likely ends in the stomach #H: redundancy of the left PICC in the left axillary region
# Output:
# neutral
# Source: report_nli_from_labels | Label: neutral -> 12491 (2520.23)
# Example:
# Input:
# NLI1: PA view of the chest provided. lateral view of the chest provided. midline sternotomy wires. mediastinal clips. less conspicuous nodular opacity in the left mid lung than on prior exam. nodular opacity could represent a focus of scarring. nodular opacity may be obtained to further characterize if it is not completely resolved on followup exams. bibasilar opacities. bronchovascular crowding. low lung volumes. no large effusion. no pneumothorax. heart size is top normal. stable mediastinal contour. unfolded thoracic aorta. intact bony structures. no free air below the right hemidiaphragm. lower lung opacities. less conspicuous left mid lung nodular opacity. opacity does not resolve #H: calcification of the aorta seen
# Output:
# neutral
# General datasets for label neutral: 3
# Medical datasets for label neutral: 7
# Medical report from facts datasets for label neutral: 1
# Medical report from labels datasets for label neutral: 1
# ----
# Number of RadNLI test samples: 480
# Number of MS_CXR_T samples: 361
# Number of report NLI samples added to val: 300
# Number of report NLI samples added to val: 300
# Number of val NLI samples: 1441
# Input:
# NLI1: No pleural effusions. #H: There is no focal consolidation, pleural effusion, pneumothorax, or pulmonary edema.
# Output:
# neutral
# Input:
# NLI1: GE junction stent in the expected location in the left upper quadrant. no acute findings. stent appears to cross the GE junction. segmental narrowing in the GE junction. distal portion of the stent overlies the upper stomach. stent extending to the left lateral edge of the gas distended portion of the stomach. stent presumably extending to the lateral gastric wall. unchanged cardiomediastinal silhouette. normal limits of cardiomediastinal silhouette. mild unfolding of the aorta. left subclavian PICC line tip overlies the distal SVC. no CHF. no focal infiltrate. no effusion. trace subsegmental atelectasis at the left base. GE junction stent placed. no evidence of pneumomediastinum. no evidence of pneumothorax. no evidence of free subdiaphragmatic air. no acute pulmonary process #H: pneumomediastinum seen
# Output:
# contradiction
# Input:
# NLI1: The heart remains mildly enlarged. #H: The lungs are clear.
# Output:
# neutral
# Input:
# NLI1: The cardiac silhouette remains enlarged. #H: The lungs are symmetrically expanded.
# Output:
# neutral
# Input:
# NLI1: No evidence of complications, notably no pneumothorax. #H: There is no focal consolidation, pleural effusion or pneumothorax.
# Output:
# neutral
# ----
# Building val NLI dataset...
# Number of general sentences: 1377099
# Number of medical sentences: 1076067
# Number of whole sentences: 2201653
# Number of splittable sentences: 251694
# Number of unique sentences (after sent_tokenize): 2767410
# Example train texts:
# {'input_text': 'NLI1: increased opacification at the right base laterally. appearance consistent with pleural effusion. possible supervening pneumonia. condition of the patient permits. lateral view would be most helpful for further evaluation #H: increased opacification at the right base laterally', 'output_text': 'entailment'}
# {'input_text': 'NLI1: trachea has been extubated. improved lung volumes. residual opacity at the base of the left lung. atelectasis at the base of the left lung. very small pneumonia not excluded. no pulmonary edema. no large region of atelectasis. no hypoxia. no suggestion of pulmonary embolism. no exclusion of pulmonary embolism. normal cardiomediastinal silhouette. normal hilar silhouette. healed severe right rib fractures #H: calcified texture seen', 'output_text': 'neutral'}
# {'input_text': "NLI1: That we spent -- the top 1% receive 223 as opposed to 445 billion in new spending. The top -- let's talk about my tax plan. The top 1% will pay one-third of all the federal income taxes. And in return, get one-fifth of the benefits, because most of the tax reductions go to the people at the bottom end of the economic ladder. #H: federal income taxes have been filed by carl", 'output_text': 'neutral'}
# Examples dev texts:
# {'input_text': 'NLI1: ET tube 3 cm above the level of the carina. ET tube in correct position. NG tube in proximal stomach. right PICC tip in upper right atrium. interval increase in the right upper lobe of pulmonary consolidation. widespread pulmonary consolidation with air bronchograms. no pneumothorax. no left pleural effusion. obscured heart size by pulmonary pathology. no bony abnormality. interval increase in widespread pulmonary consolidation. predominant increase in right upper lobe. concern about tip placement. consider lateral view for further assessment #H: request for additional images', 'output_text': 'entailment'}
# {'input_text': 'NLI1: No pleural effusions. #H: There is no focal consolidation, pleural effusion, pneumothorax, or pulmonary edema.', 'output_text': 'neutral'}
# {'input_text': 'NLI1: upright AP view of the chest. upright lateral view of the chest. borderline enlarged heart. accentuated heart size due to low lung volumes. unremarkable mediastinal contours. unremarkable hilar contours. mild atherosclerotic calcifications at the aortic knob. normal pulmonary vasculature. patchy opacities in the lung bases. atelectasis in the lung bases. no focal consolidation. no pleural effusion. no pneumothorax. no acute osseous abnormalities. bibasilar patchy opacities #H: vascular calcification seen', 'output_text': 'entailment'}
# checkpoint_names = ['checkpoint_91_cacc+chf1+chf1+cscc+encc+hscc+nlcc+sass+spss+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9337.pt']
#   0%|                                                                                       | 0/2767410 [00:00<?, ?it/s]
# Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=440,3465006188639683439).pkl
# len(self.cache["hashes"]) = 2863612
# self.cache["embeddings"].shape = (2863612, 128)
# 100%|█████████████████████████████████████████████████████████████████████| 2767410/2767410 [00:07<00:00, 355712.05it/s]
# embeddings.shape: (2767410, 128)
# Example train text (after wrapping):
# {'e': array([[ 0.06947376, -0.11569537,  0.02730236, ...,  0.13122353,
#          0.01214379, -0.01574784],
#        [-0.06390562,  0.08499207,  0.16205028, ..., -0.19739988,
#          0.04201943,  0.05115848],
#        [ 0.07100305, -0.1185552 ,  0.10183356, ...,  0.01097044,
#         -0.02625308, -0.10482252],
#        ...,
#        [ 0.00032887, -0.00176735,  0.09371229, ..., -0.09643622,
#          0.05951408,  0.01350049],
#        [-0.08134138, -0.01020508,  0.07723943, ..., -0.10380471,
#          0.0173781 ,  0.02979034],
#        [-0.01445407,  0.06164164,  0.13464022, ..., -0.1730845 ,
#          0.07160009,  0.04752427]], dtype=float32), 'l': 0}
# Example dev text (after wrapping):
# {'e': array([[ 4.18721177e-02, -1.80788692e-02, -8.55513383e-03,
#         -5.89948008e-03,  4.42525893e-02, -6.80771545e-02,
#         -3.74441370e-02, -9.77936909e-02, -1.61957592e-01,
#          8.31012707e-03, -8.44252184e-02, -6.02660477e-02,
#          7.58693367e-03, -2.13913508e-02, -1.83292932e-03,
#         -9.02519897e-02, -1.70488544e-02,  6.20361418e-02,
#         -1.26456425e-01,  2.06949450e-02, -1.43645788e-02,
#          1.39621422e-01, -1.09687619e-01,  3.98585945e-02,
#         -1.12684600e-01,  5.96553870e-02, -1.13222348e-02,
#         -8.04864690e-02,  7.42021054e-02, -3.80097032e-02,
#          7.44052045e-03,  1.05258606e-01,  1.80001289e-01,
#         -1.25580560e-02,  9.72537547e-02,  1.27335414e-01,
#         -7.21429884e-02, -1.77221168e-02,  6.13567159e-02,
#          9.48300213e-02,  2.01794282e-02,  7.29809981e-03,
#         -5.43330684e-02, -6.28646649e-03,  3.75710288e-03,
#         -5.34332320e-02, -1.37972966e-01,  2.99794488e-02,
#         -2.97009619e-03,  1.75083820e-02,  1.66566879e-01,
#          2.34322846e-02, -5.93996532e-02,  6.74132779e-02,
#         -8.86020064e-02, -1.38568297e-01,  5.56587949e-02,
#          4.26498465e-02,  1.65958107e-01,  2.29689386e-02,
#          2.58026607e-02,  2.62739882e-02, -1.08827785e-01,
#         -1.18301123e-01, -1.40981629e-01, -1.21040000e-02,
#          4.03850228e-02,  8.15904979e-03, -2.46238299e-02,
#          4.85514617e-03, -3.41321267e-02, -1.51422709e-01,
#          1.14284381e-01,  1.32694110e-01,  6.14759959e-02,
#         -1.56957760e-01, -1.60497874e-01, -8.81532952e-02,
#          8.39564502e-02,  5.97695541e-03,  3.68891545e-02,
#          1.85140014e-01, -4.82936427e-02,  9.74789858e-02,
#          9.27712545e-02, -9.66368709e-03, -3.57349380e-03,
#          5.77675737e-02,  1.58840809e-02, -7.55783245e-02,
#         -6.09608628e-02, -4.29418199e-02,  9.46188867e-02,
#          6.66603297e-02,  2.98340023e-02, -1.54472172e-01,
#          1.98374510e-01,  5.29608801e-02, -5.40589802e-02,
#         -4.33053114e-02,  1.84720248e-01, -5.14022559e-02,
#         -4.22358438e-02,  1.24350235e-01, -3.61249298e-02,
#         -7.80107751e-02, -4.74754674e-03,  7.90535584e-02,
#          9.52037722e-02, -1.79683734e-02,  2.49121208e-02,
#         -5.74075654e-02, -1.19126692e-01]], dtype=float32), 'l': 0}

# %%
trainer.train_dataset.embeddings.shape
# Out:
# (2767410, 128)

# %%
i2s = {i:s for s,i in trainer.train_dataset.sentence2idx.items()}

# %%
i2s[10]
# Out:
# 'stable position of multiple other support devices'

# %%
trainer.train_dataset._d[12]
# Out:
# {'input_text': "NLI1: The blonde on the left is said to be Rubens's second wife, Helena. #H: Helena is said to be Ruben's third wife.",
#  'output_text': 'contradiction'}

# %%
x = trainer.train_dataset[12]['e'][1]

# %%
from medvqa.utils.math import rank_vectors_by_dot_product

# %%
idxs = rank_vectors_by_dot_product(trainer.train_dataset.embeddings, x)

# %%
for i in range(40):
    print(i2s[idxs[i]])
# Out:
# The blonde on the left is said to be Rubens's second wife, Helena.
# The train left at 3.30 carrying our intrepid heroes.
# Staff were interviewed when they left to understand why they were leaving.
# Greenwood left Radiohead after this project.
# A crossdressing man and his wife are laughing at a story she just told him.
# Laura bush is speaking to people.
# The bandits parted with laughter as the man with the sword swung.
# Club de Fútbol Extremadura is a Spanish football team based in Almendralejo that currently plays in La Liga.
# Laura Bush is speaking about farming.
# Someone throws lugggage on his face.
# Laura bush is speaking at a conference for a topic she is passionate about.
# Anse's face was green-white under the weathering, save for the wound on his jaw, he said to give them room, an' they'll do it again now!
# A person does a skateboarding trick in the air while holding the board with his left hand.
# A human in red and gray clothing is indoors laughing.
# I was left in her wake; Natalia was already speaking on the phone, organising another round.
# A laughing young boy is near a swimming pool.
# Boris Cabrera left the entertainment industry in 2000.
# A woman and a young man laughing in a bedroom.
# Laura Ellen Ziskin has starred at a film what name is "Pretty Woman" .
# A woman stands next to her luggage.
# The kids were left at the hotdog stand while their parents rode the bus home.
# Tuppence relied on him heavily, and when he left abruptly, she felt abandoned.
# Larry King took over for Stephen Colbert when Colbert left "The Colbert Report".
# People are laughing at a joke.
# The baby was just lain down for an afternoon nap.
# Shortly after, he left us to go into battle.
# Three newscasters sitting at a desk laughing at their producer.
# A young girl is laughing at a clown.
# A man does a skateboarding trick in the air while holding the board with his left hand.
# A boy is laughing at a joke.
# three men stand on stage in tuxedos, the man on the left can be seen shaking the hand of someone.
# A person lying down outside, head rested on a Luis Vuitton bag.
# At the eastern entrance to the Tuileries, the pink Arc de Triomphe du Carrousel was built at roughly the same time as its bigger brother at l'Etoile.
# The sylph in the corner laughed at his difficulty breathing.
# Left Hand Spring was named after a chief.
# Laura Bush speaking at a conference on global literacy.
# I suppose you'll eat it if he cooks it.
# Our kids have left the house.
# They knew three people were left.
# The kids are laughing at the joke.

# %%
trainer.train_dataset[0]
# Out:
# {'e': array([[-0.13858256, -0.06861142, -0.17228346, -0.11336186,  0.0400812 ,
#           0.08874234, -0.07521567, -0.04085606, -0.05105262,  0.01178886,
#           0.05466969, -0.03142704, -0.15987802,  0.03566264, -0.14865671,
#           0.11194872, -0.11043618, -0.1350608 ,  0.02653655,  0.11165243,
#           0.06965756, -0.07191975,  0.09141474,  0.08290543, -0.0217727 ,
#          -0.15112035,  0.02948457, -0.08637141, -0.03201618, -0.09343565,
#          -0.00468594,  0.06056854,  0.18041934,  0.03820131, -0.08187714,
#           0.09080541, -0.05969145, -0.18229175,  0.0305312 , -0.07081801,
#          -0.00528316, -0.11177354,  0.14568502,  0.03141407,  0.01569823,
#          -0.01887536, -0.04668215, -0.02933347,  0.00031198,  0.09451644,
#          -0.0405928 ,  0.05675154, -0.06098381, -0.0473812 ,  0.06737979,
#           0.05883843,  0.03541643, -0.12877788, -0.11544305, -0.07644878,
#           0.10127471, -0.22610256, -0.07919751, -0.021795  ,  0.0077221 ,
#          -0.16562255, -0.14280644, -0.06973083,  0.00649192, -0.08721433,
#          -0.05228379, -0.13737148, -0.08131926,  0.01044641, -0.00385273,
#          -0.03687707, -0.01945736, -0.17834793, -0.15749326, -0.03234813,
#          -0.01313605, -0.043361  ,  0.05567628, -0.04534279,  0.0654632 ,
#          -0.01142202, -0.12229386, -0.01474702,  0.0718767 , -0.14377333,
#           0.0733418 ,  0.02657275,  0.01638866, -0.00486807, -0.07149123,
#           0.07920908, -0.08438853, -0.09587438,  0.00295251, -0.08526119,
#           0.0686584 , -0.02571896, -0.07747131, -0.06618606,  0.16927263,
#           0.03970378, -0.03625484,  0.0139589 , -0.08861487,  0.19247203,
#           0.01594697,  0.01998208,  0.1173173 ,  0.08405209,  0.00420521,
#           0.08225862,  0.08052719, -0.00693838, -0.14922397,  0.03071631,
#          -0.22697137,  0.02153638, -0.04330228,  0.0554089 ,  0.01425676,
#           0.07624459,  0.01376912, -0.12639049],
#         [-0.08407961,  0.04924752, -0.01465571, -0.10165387,  0.04209574,
#          -0.00683209, -0.01243839, -0.20515142, -0.05687309, -0.00656555,
#           0.10214991, -0.00651222, -0.05511868,  0.08689578, -0.05526815,
#           0.10025462, -0.09001148,  0.01599307,  0.00663113, -0.10753608,
#          -0.17621307,  0.09524582,  0.09450149,  0.04036135, -0.00354821,
#          -0.04140305, -0.00971567,  0.03503117,  0.01073684, -0.04944884,
#          -0.042022  , -0.07969199,  0.05290981, -0.05383032, -0.13864775,
#           0.01096958, -0.11379295, -0.06639765, -0.000318  , -0.07661818,
#          -0.03765237,  0.00274281,  0.08549041,  0.05134761,  0.23585398,
#          -0.05222903,  0.21260053,  0.05658545, -0.09503622, -0.01911604,
#           0.04702178, -0.03058503,  0.05761638, -0.02174836,  0.00915177,
#           0.0364214 , -0.05038064, -0.09467568, -0.14607714, -0.07760599,
#          -0.01419355, -0.0420659 , -0.23297216, -0.07393294, -0.00956387,
#           0.00031583,  0.09290527,  0.01087673,  0.04956362,  0.08631447,
#          -0.09113455, -0.1063752 ,  0.0154297 , -0.00345132, -0.17452079,
#           0.09300984,  0.04995976, -0.02748649,  0.01468639,  0.0730065 ,
#          -0.03549544, -0.02940788, -0.02468948,  0.28392762,  0.04300684,
#          -0.10891624, -0.00068251,  0.02289694, -0.02160407,  0.2421337 ,
#          -0.11813236, -0.00523679, -0.04083032,  0.13903736, -0.03764807,
#           0.07588287, -0.09657405, -0.01606813,  0.16179295, -0.11264308,
#          -0.14347482, -0.04097146, -0.03835926, -0.11885288,  0.09209517,
#          -0.09164044, -0.0226638 , -0.02806066, -0.03765957,  0.05167195,
#          -0.07218167,  0.16239041,  0.01599038,  0.10351484,  0.05040708,
#           0.03365805,  0.18824029,  0.04424221,  0.06407443,  0.02602995,
#          -0.09811262, -0.06197625,  0.0904339 ,  0.03978372,  0.01175087,
#          -0.15066297,  0.02532662, -0.01747165]], dtype=float32),
#  'l': 2}

# %%
tmp = load_jsonl("/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-1106-preview_fact_based_report_nli_queries(from_labels).jsonl")

# %%
tmp[0]
# Out:
# {'metadata': {'query': "#F mild cardiomegaly. tortuous aorta. low lung volumes. ill-defined opacity in the left upper lung. opacity worrisome for aspiration. opacity worrisome for pneumonia. superimposed to patient's known emphysema. superimposed to patient's subpleural interstitial abnormality. no pneumothorax. no pleural effusion | #H tortuous aorta seen"},
#  'parsed_response': 'definitely true'}

# %%
from nltk import sent_tokenize

# %%
sent_tokenize('No pneumothorax.).')
# Out:
# ['No pneumothorax.', ').']
