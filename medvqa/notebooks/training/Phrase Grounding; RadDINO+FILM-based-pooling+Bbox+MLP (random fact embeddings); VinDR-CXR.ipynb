# %%
# %env CUDA_VISIBLE_DEVICES=2
# Out:
# env: CUDA_VISIBLE_DEVICES=2

# %%
# !python ../train_phrase_grounding.py \
--epochs 100 \
--batches_per_epoch 1000 \
--max_images_per_batch 6 \
--max_phrases_per_batch 1000 \
--max_phrases_per_image 45 \
--val_batch_size_factor 4 \
--raw_image_encoding "rad-dino-huggingface" \
--huggingface_model_name "microsoft/rad-dino" \
--image_size 416 416 \
--image_local_feat_size 768 \
--num_regions 841 \
--regions_width 29 \
--regions_height 29 \
--img_aug_mode "random-color-and-spatial" \
--phrase_embedding_size 128 \
--phrase_grounding_mode "adaptive_film_based_pooling_mlp_with_bbox_regression" \
--phrase_mlp_hidden_dims 256 128 \
--visual_grounding_hidden_size 256 \
--num_train_workers 2 \
--num_val_workers 2 \
--gradient_accumulation_steps 5 \
--optimizer_name "adamw" \
--scheduler "exp-warmup+decay+cyclicdecay" \
--lr 1e-6 \
--warmup_decay_and_cyclic_decay_args "1e-6,3,8e-5,5,1e-6,8e-5,5,1e-6" \
--binary_multilabel_classif_loss_name "focal+bce+npbbce" \
--do_visual_grounding_with_bbox_regression \
--use_vinbig_for_train \
--use_vinbig_for_test \
--vinbig_phrase_embeddings_filepath \
"/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/vinbig/label_phrase_embeddings(hash=353,2491289492560726319).pkl" \
--replace_phrase_embeddings_with_random_vectors \
--use_amp \
--save
# Out:
# script's arguments:
#    epochs: 100
#    batches_per_epoch: 1000
#    max_images_per_batch: 6
#    max_phrases_per_batch: 1000
#    max_phrases_per_image: 45
#    val_batch_size_factor: 4.0
#    checkpoint_folder: None
#    pretrained_checkpoint_folder_path: None
#    pretrained_checkpoint_folder_paths: None
#    freeze_image_encoder: False
#    raw_image_encoding: rad-dino-huggingface
#    huggingface_model_name: microsoft/rad-dino
#    num_regions: 841
#    image_local_feat_size: 768
#    image_encoder_pretrained_weights_path: None
#    image_encoder_dropout_p: 0
#    yolov8_model_name_or_path: None
#    yolov8_model_alias: None
#    phrase_embedding_size: 128
#    regions_width: 29
#    regions_height: 29
#    qkv_size: None
#    phrase_grounding_mode: adaptive_film_based_pooling_mlp_with_bbox_regression
#    phrase_classifier_hidden_size: None
#    transf_d_model: None
#    transf_nhead: None
#    transf_dim_feedforward: None
#    transf_dropout: 0
#    transf_num_layers: None
#    visual_feature_proj_size: None
#    visual_grounding_hidden_size: 256
#    phrase_mlp_hidden_dims: [256, 128]
#    predict_global_alignment: False
#    alignment_proj_size: None
#    yolov11_model_name_or_path: None
#    yolov11_model_alias: None
#    optimizer_name: adamw
#    lr: 1e-06
#    scheduler: exp-warmup+decay+cyclicdecay
#    lr_decay: 0.76
#    lr_decay_patience: 2
#    warmup_and_decay_args: None
#    warmup_and_cosine_args: None
#    warmup_decay_and_cyclic_decay_args: 1e-6,3,8e-5,5,1e-6,8e-5,5,1e-6
#    gradient_accumulation_steps: 5
#    override_lr: False
#    max_grad_norm: None
#    attention_supervision_loss_weight: 1.0
#    phrase_classifier_loss_weight: 1.0
#    foreground_loss_weight: 1.0
#    background_loss_weight: 1.0
#    focal_loss_weight: 1.0
#    bce_loss_weight: 1.0
#    wbce_loss_weight: 1.0
#    binary_multilabel_classif_loss_name: focal+bce+npbbce
#    use_weighted_phrase_classifier_loss: False
#    cluster_and_label_weights_for_facts_filepath: None
#    use_attention_regularization_loss: False
#    use_contrastive_phrase_grounding_loss: False
#    nt_xent_temperature: 0.1
#    num_train_workers: 2
#    num_val_workers: 2
#    device: GPU
#    use_amp: True
#    image_size: [416, 416]
#    dicom_id_to_pos_neg_facts_filepath: None
#    iuxray_image_id_to_pos_neg_facts_filepath: None
#    mscxr_phrase2embedding_filepath: None
#    chest_imagenome_bbox_phrase_embeddings_filepath: None
#    vinbig_phrase_embeddings_filepath: /mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/vinbig/label_phrase_embeddings(hash=353,2491289492560726319).pkl
#    chexlocalize_class_phrase_embeddings_filepath: None
#    chexpert_class_phrase_embeddings_filepath: None
#    mimiccxr_exclude_noisy_images: False
#    mimiccxr_facts_weight: 1.0
#    chest_imagenome_anatlocs_weight: 1.0
#    mscxr_weight: 1.0
#    cxrlt2024_weight: 1.0
#    vinbig_weight: 1.0
#    chexlocalize_weight: 1.0
#    chexpert_weight: 1.0
#    iuxray_weight: 1.0
#    img_aug_mode: random-color-and-spatial
#    pos_area_prior: 0.4
#    neg_area_prior: 0.0
#    use_mimiccxr_facts_for_train: False
#    use_mimiccxr_facts_for_test: False
#    use_mscxr_for_train: False
#    use_mscxr_for_test: False
#    use_chest_imagenome_for_train: False
#    use_chest_imagenome_gold_for_test: False
#    use_vinbig_for_train: True
#    use_vinbig_for_test: True
#    use_chexlocalize_for_train: False
#    use_chexlocalize_for_test: False
#    use_chexpert_for_train: False
#    use_chexpert_for_test: False
#    use_iuxray_for_train: False
#    use_iuxray_for_test: False
#    use_cxrlt2024_challenge_split: False
#    use_cxrlt2024_custom_labels: False
#    use_cxrlt2024_official_labels: False
#    use_all_cxrlt2024_official_labels_for_training: False
#    vinbig_training_data_mode: train
#    chexpert_training_data_mode: all
#    mimiccxr_balance_long_middle_short_tail: False
#    mimiccxr_long_middle_short_tail_thresholds: (0.02, 0.05)
#    mimiccxr_report_fact_nli_integrated_data_filepath: None
#    mimiccxr_use_interpret_cxr_challenge_split: False
#    mimiccxr_interpret_cxr_challenge_split_filepath: None
#    iuxray_use_interpret_cxr_challenge_split: False
#    iuxray_interpret_cxr_challenge_split_filepath: None
#    chexpert_use_interpret_cxr_challenge_split: False
#    chexpert_interpret_cxr_challenge_split_filepath: None
#    chexlocalize_use_interpret_cxr_challenge_split: False
#    chexlocalize_interpret_cxr_challenge_split_filepath: None
#    cxrlt2024_custom_dicom_id_to_pos_neg_facts_filepath: None
#    cxrlt2024_official_training_labels_for_fact_classification_filepath: None
#    cxrlt2024_do_balanced_sampling: False
#    do_visual_grounding_with_bbox_regression: True
#    do_visual_grounding_with_segmentation: False
#    replace_phrase_embeddings_with_random_vectors: True
#    save: True
# ----- Training model from scratch ------
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Creating instance of PhraseGrounder ...
# WARNING: Unused kwargs: {'pretrained_checkpoint_folder_path': None, 'pretrained_checkpoint_folder_paths': None}
# MultiPurposeVisualModule()
#   Initializing raw_image_encoder: rad-dino-huggingface
#   self.global_feat_size = 768
#   self.local_feat_size = 768
#   Initializing auxiliary tasks
# BoundingBoxRegressorSingleClass
#   local_feat_dim: 256
# --------------------------------------------------
# 3) Defining optimizer ...
# create_optimizer(): name = adamw
# --------------------------------------------------
# 4) Defining scheduler ...
# Using exp-warmup+decay+cyclicdecay scheduler: 1e-6,3,8e-5,5,1e-6,8e-5,5,1e-6
# 1e-06 3 8e-05 5 1e-06 8e-05 5 1e-06
# self.steps_to_restart = 5
# self.steps = -1
# self.initial_lr = 8e-05
# --------------------------------------------------
# 5) Creating trainer and validator engines ...
# Focal_BCE_NPBBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 npbbce_weight = 0.3333333333333333
# Focal_BCE_NPBBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 npbbce_weight = 0.3333333333333333
# Focal_BCE_WBCBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 wbcbce_weight = 0.3333333333333333
# foreground_loss_weight: 1.0
# background_loss_weight: 1.0
# GradientAccumulator.__init__(): num_accumulation_steps = 5, max_grad_norm = None
# Focal_BCE_NPBBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 npbbce_weight = 0.3333333333333333
# Focal_BCE_NPBBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 npbbce_weight = 0.3333333333333333
# Focal_BCE_WBCBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 wbcbce_weight = 0.3333333333333333
# foreground_loss_weight: 1.0
# background_loss_weight: 1.0
# --------------------------------------------------
# 6) Creating VinBig Phrase Grounding Trainer ...
# get_image_transform()
#   image_size = [416, 416]
#   mean = [0.5307, 0.5307, 0.5307]
#   std = [0.2583, 0.2583, 0.2583]
#   Using bounding box aware transforms
#     augmentation_mode = random-color-and-spatial
#     default_prob = 0.35
#     for_vinbig: returning vinbig transform
# get_train_transform(): Using bbox-aware transforms for VinBigData
#     Returning augmented transform with mode random-color-and-spatial
# get_image_transform()
#   image_size = [416, 416]
#   mean = [0.5307, 0.5307, 0.5307]
#   std = [0.2583, 0.2583, 0.2583]
#   Using bounding box aware transforms
#     Returning default transform (no augmentation)
# Loading bounding boxes
# Anomalous bboxes found: 29 of 37367
# class_id_offset: 0
# Anomalous bboxes found: 0 of 2697
# class_id_offset: 0
#   Loaded 18000 bounding boxes
# Loding phrase_embeddings and phrases from /mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/vinbig/label_phrase_embeddings(hash=353,2491289492560726319).pkl...
# NOTE: Replacing phrase embeddings with random vectors
# Random vectors already saved at /mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/vinbig/label_phrase_embeddings(hash=353,2491289492560726319).pkl.random_vectors.pkl
# phrase_embeddings.shape = (28, 128)
# phrase_embeddings.dtype = float32
# len(phrases) = 28
# 	 aortic enlargement seen
# 	 atelectasis seen
# 	 calcification seen
# 	 cardiomegaly seen
# 	 clavicle fracture seen
# 	 consolidation seen
# 	 edema seen
# 	 emphysema seen
# 	 enlarged pulmonary artery seen
# 	 interstitial lung disease seen
# 	 infiltration seen
# 	 lung opacity seen
# 	 lung cavity seen
# 	 lung cyst seen
# 	 mediastinal shift seen
# 	 nodule/mass seen
# 	 pleural effusion seen
# 	 pleural thickening seen
# 	 pneumothorax seen
# 	 pulmonary fibrosis seen
# 	 rib fracture seen
# 	 other lesion seen
# 	 copd seen
# 	 lung tumor seen
# 	 pneumonia seen
# 	 tuberculosis seen
# 	 other disease seen
# 	 no abnormalities seen
# Compute phrase grounding masks and labels
# self.phrase_grounding_masks.shape = (18000, 22, 841)
# self.phrase_classification_labels.shape = (18000, 22)
# Append additional labels to phrase_classification_labels
# len(non_bbox_labels) = 6
# non_bbox_labels = ['COPD', 'Lung tumor', 'Pneumonia', 'Tuberculosis', 'Other disease', 'No finding']
# self.phrase_classification_labels.shape = (18000, 28)
# Reorder phrases and phrase_embeddings
# len(phrases) = 28
# len(actual_phrases) = 28
# phrase_embeddings.shape = (28, 128)
# Generating train dataset and dataloader
# len(train_indices) = 15000
# No labels: 0
# Edema: 13
# Clavicle fracture: 27
# Lung cyst: 33
# COPD: 35
# Lung cavity: 51
# Emphysema: 81
# Rib fracture: 90
# Pneumothorax: 96
# Enlarged PA: 131
# Mediastinal shift: 150
# Atelectasis: 187
# Lung tumor: 291
# Consolidation: 353
# ILD: 397
# Calcification: 458
# Infiltration: 613
# Tuberculosis: 750
# Nodule/Mass: 841
# Pneumonia: 917
# Pleural effusion: 1038
# Other lesion: 1154
# Lung Opacity: 1331
# Pulmonary fibrosis: 1621
# Pleural thickening: 2010
# Cardiomegaly: 2316
# Aortic enlargement: 3098
# Other disease: 4288
# No finding: 10601
# Group sizes: [10478, 771, 323, 312, 286, 278, 258, 243, 241, 218, 215, 167, 159, 156, 122, 119, 112, 102, 84, 83, 79, 47, 45, 32, 70]
#   len(indices) = 10478, weight = 2381.9852437292775
#   len(indices) = 771, weight = 882.1360585110112
#   len(indices) = 323, weight = 579.1323556126193
#   len(indices) = 312, weight = 568.7753795323758
#   len(indices) = 286, weight = 543.3127950518186
#   len(indices) = 278, weight = 535.1778961104801
#   len(indices) = 258, weight = 514.1586596868186
#   len(indices) = 243, weight = 497.69925147612867
#   len(indices) = 241, weight = 495.4562099629317
#   len(indices) = 218, weight = 468.76865710351854
#   len(indices) = 215, weight = 465.15882500917724
#   len(indices) = 167, weight = 402.55283205217046
#   len(indices) = 159, weight = 391.0802349542582
#   len(indices) = 156, weight = 386.6879164039802
#   len(indices) = 122, weight = 332.9187999914028
#   len(indices) = 119, weight = 327.76937690454827
#   len(indices) = 112, weight = 315.45337872121524
#   len(indices) = 102, weight = 297.0647831080699
#   len(indices) = 84, weight = 261.20109767987407
#   len(indices) = 83, weight = 259.088791948487
#   len(indices) = 79, weight = 250.497443897163
#   len(indices) = 47, weight = 171.37827001640065
#   len(indices) = 45, weight = 165.6367630898417
#   len(indices) = 32, weight = 125.0
#   len(indices) = 70, weight = 230.2655804515992
# batch_size = 6
# Generating val dataset and dataloader
# len(test_indices) = 3000
# batch_size = 24
# --------------------------------------------------
# 7) Creating dataloaders ...
# len(vinbig_trainer.train_dataloader) = 166666666666666667
# len(vinbig_trainer.val_dataloader) = 125
# len(_train_dataloaders) = 1
# len(_val_dataloaders) = 1
# _train_weights = [1.0]
# merged_dataset_name = vinbig
# --------------------------------------------------
# 8) Attaching metrics, losses, timer and events to engines ...
# --------------------------------------------------
# 9) Defining learning rate scheduler handler ...
# --------------------------------------------------
# 10) Defining learning rate scheduler handler ...
# --------------------------------------------------
# 11) Defining checkpoint folder path ...
# checkpoint_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250131_014546_vinbig_PhraseGrounder(microsoft-rad-dino,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)
# metadata saved to /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250131_014546_vinbig_PhraseGrounder(microsoft-rad-dino,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/metadata.json
# --------------------------------------------------
# 12) Defining log_metrics_handler ...
# MetricsLogger :: we'll be logging to /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250131_014546_vinbig_PhraseGrounder(microsoft-rad-dino,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/metrics_logs.csv
# --------------------------------------------------
# 13) Running trainer engine ...
# ---- Epoch 1/100
# (1) Training stage (lr = 0.000001) ...
# loss 4.87935, vbg_vgbbox_loss 1.91780, vbg_att_sup_loss 1.37325, vbg_phrcls_loss 1.58830, vbg_prc_auc 0.15692, 245.73 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.00000, vbg_prc_auc 0.08275, 118.14 secs
# New checkpoint saved: checkpoint_1_vbss+vbou+vbuc+vbss=0.0659.pt
# ---- Epoch 2/100
# (1) Training stage (lr = 0.000004) ...
# loss 3.94148, vbg_vgbbox_loss 1.20051, vbg_att_sup_loss 1.36738, vbg_phrcls_loss 1.37359, vbg_prc_auc 0.15740, 251.80 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.05789, vbg_prc_auc 0.07983, 97.87 secs
# New checkpoint saved: checkpoint_2_vbss+vbou+vbuc+vbss=0.0838.pt
# ---- Epoch 3/100
# (1) Training stage (lr = 0.000019) ...
# loss 3.07587, vbg_vgbbox_loss 0.49358, vbg_att_sup_loss 1.33675, vbg_phrcls_loss 1.24554, vbg_prc_auc 0.15844, 254.64 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.08150, vbg_prc_auc 0.09995, 98.44 secs
# New checkpoint saved: checkpoint_3_vbss+vbou+vbuc+vbss=0.1068.pt
# ---- Epoch 4/100
# (1) Training stage (lr = 0.000080) ...
# loss 2.42076, vbg_vgbbox_loss 0.31405, vbg_att_sup_loss 1.01055, vbg_phrcls_loss 1.09616, vbg_prc_auc 0.17681, 250.40 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.12098, vbg_prc_auc 0.16337, 97.98 secs
# New checkpoint saved: checkpoint_4_vbss+vbou+vbuc+vbss=0.1619.pt
# ---- Epoch 5/100
# (1) Training stage (lr = 0.000033) ...
# loss 1.90455, vbg_vgbbox_loss 0.25226, vbg_att_sup_loss 0.68060, vbg_phrcls_loss 0.97168, vbg_prc_auc 0.28929, 252.05 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.15615, vbg_prc_auc 0.22982, 98.46 secs
# New checkpoint saved: checkpoint_5_vbss+vbou+vbuc+vbss=0.2197.pt
# ---- Epoch 6/100
# (1) Training stage (lr = 0.000014) ...
# loss 1.69711, vbg_vgbbox_loss 0.22398, vbg_att_sup_loss 0.58403, vbg_phrcls_loss 0.88911, vbg_prc_auc 0.34195, 255.68 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.16205, vbg_prc_auc 0.25001, 98.41 secs
# New checkpoint saved: checkpoint_6_vbss+vbou+vbuc+vbss=0.2363.pt
# ---- Epoch 7/100
# (1) Training stage (lr = 0.000006) ...
# loss 1.60414, vbg_vgbbox_loss 0.21190, vbg_att_sup_loss 0.54200, vbg_phrcls_loss 0.85024, vbg_prc_auc 0.36095, 255.07 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.16570, vbg_prc_auc 0.25303, 98.43 secs
# New checkpoint saved: checkpoint_7_vbss+vbou+vbuc+vbss=0.2402.pt
# ---- Epoch 8/100
# (1) Training stage (lr = 0.000002) ...
# loss 1.58501, vbg_vgbbox_loss 0.21112, vbg_att_sup_loss 0.53338, vbg_phrcls_loss 0.84051, vbg_prc_auc 0.36564, 253.97 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.17145, vbg_prc_auc 0.25649, 97.72 secs
# New checkpoint saved: checkpoint_8_vbss+vbou+vbuc+vbss=0.2443.pt
# ---- Epoch 9/100
# (1) Training stage (lr = 0.000001) ...
# loss 1.56701, vbg_vgbbox_loss 0.20808, vbg_att_sup_loss 0.52639, vbg_phrcls_loss 0.83254, vbg_prc_auc 0.37160, 250.34 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.16740, vbg_prc_auc 0.25802, 98.01 secs
# ---- Epoch 10/100
# (1) Training stage (lr = 0.000080) ...
# loss 1.63596, vbg_vgbbox_loss 0.23137, vbg_att_sup_loss 0.54910, vbg_phrcls_loss 0.85549, vbg_prc_auc 0.35055, 250.44 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.15420, vbg_prc_auc 0.27842, 98.15 secs
# New checkpoint saved: checkpoint_10_vbss+vbou+vbuc+vbss=0.2521.pt
# ---- Epoch 11/100
# (1) Training stage (lr = 0.000027) ...
# loss 1.43220, vbg_vgbbox_loss 0.20343, vbg_att_sup_loss 0.46022, vbg_phrcls_loss 0.76855, vbg_prc_auc 0.40554, 249.76 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.18963, vbg_prc_auc 0.30273, 96.68 secs
# New checkpoint saved: checkpoint_11_vbss+vbou+vbuc+vbss=0.2809.pt
# ---- Epoch 12/100
# (1) Training stage (lr = 0.000009) ...
# loss 1.34133, vbg_vgbbox_loss 0.18985, vbg_att_sup_loss 0.41926, vbg_phrcls_loss 0.73222, vbg_prc_auc 0.43307, 248.56 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.19070, vbg_prc_auc 0.30905, 95.97 secs
# New checkpoint saved: checkpoint_12_vbss+vbou+vbuc+vbss=0.2863.pt
# ---- Epoch 13/100
# (1) Training stage (lr = 0.000003) ...
# loss 1.31272, vbg_vgbbox_loss 0.18713, vbg_att_sup_loss 0.40746, vbg_phrcls_loss 0.71813, vbg_prc_auc 0.43898, 245.32 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.18944, vbg_prc_auc 0.30670, 96.07 secs
# ---- Epoch 14/100
# (1) Training stage (lr = 0.000001) ...
# loss 1.30697, vbg_vgbbox_loss 0.18584, vbg_att_sup_loss 0.40681, vbg_phrcls_loss 0.71433, vbg_prc_auc 0.44600, 246.45 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.19537, vbg_prc_auc 0.31014, 96.70 secs
# New checkpoint saved: checkpoint_14_vbss+vbou+vbuc+vbss=0.2889.pt
# ---- Epoch 15/100
# (1) Training stage (lr = 0.000080) ...
# loss 1.41146, vbg_vgbbox_loss 0.21367, vbg_att_sup_loss 0.43831, vbg_phrcls_loss 0.75947, vbg_prc_auc 0.40841, 251.23 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.18823, vbg_prc_auc 0.31262, 97.13 secs
# ---- Epoch 16/100
# (1) Training stage (lr = 0.000027) ...
# loss 1.26843, vbg_vgbbox_loss 0.18766, vbg_att_sup_loss 0.38334, vbg_phrcls_loss 0.69744, vbg_prc_auc 0.46888, 257.12 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.18536, vbg_prc_auc 0.32652, 98.41 secs
# New checkpoint saved: checkpoint_16_vbss+vbou+vbuc+vbss=0.2968.pt
# ---- Epoch 17/100
# (1) Training stage (lr = 0.000009) ...
# loss 1.19871, vbg_vgbbox_loss 0.17986, vbg_att_sup_loss 0.35613, vbg_phrcls_loss 0.66272, vbg_prc_auc 0.49807, 250.38 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.19125, vbg_prc_auc 0.32884, 98.01 secs
# New checkpoint saved: checkpoint_17_vbss+vbou+vbuc+vbss=0.3011.pt
# ---- Epoch 18/100
# (1) Training stage (lr = 0.000003) ...
# loss 1.16842, vbg_vgbbox_loss 0.17656, vbg_att_sup_loss 0.34129, vbg_phrcls_loss 0.65056, vbg_prc_auc 0.51202, 248.77 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.19307, vbg_prc_auc 0.33435, 97.69 secs
# New checkpoint saved: checkpoint_18_vbss+vbou+vbuc+vbss=0.3056.pt
# ---- Epoch 19/100
# (1) Training stage (lr = 0.000001) ...
# loss 1.16020, vbg_vgbbox_loss 0.17676, vbg_att_sup_loss 0.34151, vbg_phrcls_loss 0.64193, vbg_prc_auc 0.52379, 253.14 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.19540, vbg_prc_auc 0.33761, 97.52 secs
# New checkpoint saved: checkpoint_19_vbss+vbou+vbuc+vbss=0.3087.pt
# ---- Epoch 20/100
# (1) Training stage (lr = 0.000080) ...
# loss 1.26804, vbg_vgbbox_loss 0.19867, vbg_att_sup_loss 0.37787, vbg_phrcls_loss 0.69149, vbg_prc_auc 0.47723, 254.28 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.17672, vbg_prc_auc 0.31699, 97.96 secs
# ---- Epoch 21/100
# (1) Training stage (lr = 0.000027) ...
# loss 1.14369, vbg_vgbbox_loss 0.18025, vbg_att_sup_loss 0.32975, vbg_phrcls_loss 0.63369, vbg_prc_auc 0.54357, 254.34 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.20086, vbg_prc_auc 0.33630, 96.87 secs
# New checkpoint saved: checkpoint_21_vbss+vbou+vbuc+vbss=0.3102.pt
# ---- Epoch 22/100
# (1) Training stage (lr = 0.000009) ...
# loss 1.08569, vbg_vgbbox_loss 0.17250, vbg_att_sup_loss 0.31057, vbg_phrcls_loss 0.60263, vbg_prc_auc 0.57467, 249.20 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.19859, vbg_prc_auc 0.34329, 96.79 secs
# New checkpoint saved: checkpoint_22_vbss+vbou+vbuc+vbss=0.3149.pt
# ---- Epoch 23/100
# (1) Training stage (lr = 0.000003) ...
# loss 1.05438, vbg_vgbbox_loss 0.16934, vbg_att_sup_loss 0.30109, vbg_phrcls_loss 0.58394, vbg_prc_auc 0.60115, 251.51 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.20117, vbg_prc_auc 0.34685, 95.85 secs
# New checkpoint saved: checkpoint_23_vbss+vbou+vbuc+vbss=0.3187.pt
# ---- Epoch 24/100
# (1) Training stage (lr = 0.000001) ...
# loss 1.04036, vbg_vgbbox_loss 0.16791, vbg_att_sup_loss 0.29496, vbg_phrcls_loss 0.57749, vbg_prc_auc 0.60522, 246.96 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.20250, vbg_prc_auc 0.34348, 95.86 secs
# ---- Epoch 25/100
# (1) Training stage (lr = 0.000080) ...
# loss 1.19706, vbg_vgbbox_loss 0.19451, vbg_att_sup_loss 0.34982, vbg_phrcls_loss 0.65273, vbg_prc_auc 0.52822, 248.69 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.20049, vbg_prc_auc 0.33094, 95.58 secs
# ---- Epoch 26/100
# (1) Training stage (lr = 0.000027) ...
# loss 1.06423, vbg_vgbbox_loss 0.17478, vbg_att_sup_loss 0.29747, vbg_phrcls_loss 0.59199, vbg_prc_auc 0.60655, 248.34 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.20983, vbg_prc_auc 0.35906, 95.85 secs
# New checkpoint saved: checkpoint_26_vbss+vbou+vbuc+vbss=0.3293.pt
# ---- Epoch 27/100
# (1) Training stage (lr = 0.000009) ...
# loss 0.99874, vbg_vgbbox_loss 0.16733, vbg_att_sup_loss 0.27633, vbg_phrcls_loss 0.55507, vbg_prc_auc 0.64516, 246.83 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.21284, vbg_prc_auc 0.35588, 95.21 secs
# New checkpoint saved: checkpoint_27_vbss+vbou+vbuc+vbss=0.3294.pt
# ---- Epoch 28/100
# (1) Training stage (lr = 0.000003) ...
# loss 0.96798, vbg_vgbbox_loss 0.16386, vbg_att_sup_loss 0.26726, vbg_phrcls_loss 0.53686, vbg_prc_auc 0.67082, 246.80 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.21179, vbg_prc_auc 0.36115, 94.34 secs
# New checkpoint saved: checkpoint_28_vbss+vbou+vbuc+vbss=0.3332.pt
# ---- Epoch 29/100
# (1) Training stage (lr = 0.000001) ...
# loss 0.96725, vbg_vgbbox_loss 0.16466, vbg_att_sup_loss 0.26707, vbg_phrcls_loss 0.53552, vbg_prc_auc 0.66829, 245.99 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.21097, vbg_prc_auc 0.35695, 94.53 secs
# ---- Epoch 30/100
# (1) Training stage (lr = 0.000080) ...
# loss 1.10587, vbg_vgbbox_loss 0.18734, vbg_att_sup_loss 0.31413, vbg_phrcls_loss 0.60439, vbg_prc_auc 0.58363, 247.53 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.19588, vbg_prc_auc 0.34289, 96.05 secs
# ---- Epoch 31/100
# (1) Training stage (lr = 0.000027) ...
# loss 0.98579, vbg_vgbbox_loss 0.16977, vbg_att_sup_loss 0.27221, vbg_phrcls_loss 0.54381, vbg_prc_auc 0.66094, 249.83 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.20568, vbg_prc_auc 0.34180, 96.57 secs
# ---- Epoch 32/100
# (1) Training stage (lr = 0.000009) ...
# loss 0.91400, vbg_vgbbox_loss 0.16256, vbg_att_sup_loss 0.25092, vbg_phrcls_loss 0.50052, vbg_prc_auc 0.70629, 250.63 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.21419, vbg_prc_auc 0.35905, 96.64 secs
# New checkpoint saved: checkpoint_32_vbss+vbou+vbuc+vbss=0.3336.pt
# ---- Epoch 33/100
# (1) Training stage (lr = 0.000003) ...
# loss 0.88552, vbg_vgbbox_loss 0.15889, vbg_att_sup_loss 0.24129, vbg_phrcls_loss 0.48533, vbg_prc_auc 0.72768, 249.82 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.21234, vbg_prc_auc 0.35970, 96.75 secs
# New checkpoint saved: checkpoint_33_vbss+vbou+vbuc+vbss=0.3341.pt
# ---- Epoch 34/100
# (1) Training stage (lr = 0.000001) ...
# loss 0.87574, vbg_vgbbox_loss 0.15880, vbg_att_sup_loss 0.23632, vbg_phrcls_loss 0.48063, vbg_prc_auc 0.73151, 249.36 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.21627, vbg_prc_auc 0.36030, 96.84 secs
# New checkpoint saved: checkpoint_34_vbss+vbou+vbuc+vbss=0.3359.pt
# ---- Epoch 35/100
# (1) Training stage (lr = 0.000080) ...
# loss 1.02939, vbg_vgbbox_loss 0.17921, vbg_att_sup_loss 0.28431, vbg_phrcls_loss 0.56587, vbg_prc_auc 0.63960, 253.28 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.19658, vbg_prc_auc 0.32571, 97.16 secs
# ---- Epoch 36/100
# (1) Training stage (lr = 0.000027) ...
# loss 0.92209, vbg_vgbbox_loss 0.16718, vbg_att_sup_loss 0.25008, vbg_phrcls_loss 0.50484, vbg_prc_auc 0.71265, 255.27 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.20714, vbg_prc_auc 0.35271, 96.71 secs
# ---- Epoch 37/100
# (1) Training stage (lr = 0.000009) ...
# loss 0.84650, vbg_vgbbox_loss 0.15921, vbg_att_sup_loss 0.22757, vbg_phrcls_loss 0.45972, vbg_prc_auc 0.76485, 249.74 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.21706, vbg_prc_auc 0.36597, 96.00 secs
# New checkpoint saved: checkpoint_37_vbss+vbou+vbuc+vbss=0.3406.pt
# ---- Epoch 38/100
# (1) Training stage (lr = 0.000003) ...
# loss 0.81595, vbg_vgbbox_loss 0.15602, vbg_att_sup_loss 0.21802, vbg_phrcls_loss 0.44190, vbg_prc_auc 0.78142, 247.61 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.21399, vbg_prc_auc 0.36286, 95.49 secs
# ---- Epoch 39/100
# (1) Training stage (lr = 0.000001) ...
# loss 0.81046, vbg_vgbbox_loss 0.15681, vbg_att_sup_loss 0.21837, vbg_phrcls_loss 0.43528, vbg_prc_auc 0.78499, 247.27 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.21580, vbg_prc_auc 0.36370, 94.90 secs
# ---- Epoch 40/100
# (1) Training stage (lr = 0.000080) ...
# loss 0.96573, vbg_vgbbox_loss 0.17771, vbg_att_sup_loss 0.26314, vbg_phrcls_loss 0.52487, vbg_prc_auc 0.68338, 247.16 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.19510, vbg_prc_auc 0.35157, 95.75 secs
# ---- Epoch 41/100
# (1) Training stage (lr = 0.000027) ...
# loss 0.84554, vbg_vgbbox_loss 0.16249, vbg_att_sup_loss 0.22539, vbg_phrcls_loss 0.45766, vbg_prc_auc 0.77759, 247.76 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.21216, vbg_prc_auc 0.36574, 95.48 secs
# ---- Epoch 42/100
# (1) Training stage (lr = 0.000009) ...
# loss 0.76879, vbg_vgbbox_loss 0.15381, vbg_att_sup_loss 0.20205, vbg_phrcls_loss 0.41294, vbg_prc_auc 0.82081, 247.47 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.21632, vbg_prc_auc 0.37551, 95.29 secs
# New checkpoint saved: checkpoint_42_vbss+vbou+vbuc+vbss=0.3481.pt
# ---- Epoch 43/100
# (1) Training stage (lr = 0.000003) ...
# loss 0.74886, vbg_vgbbox_loss 0.15296, vbg_att_sup_loss 0.19912, vbg_phrcls_loss 0.39679, vbg_prc_auc 0.82823, 246.83 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.21843, vbg_prc_auc 0.37532, 95.02 secs
# New checkpoint saved: checkpoint_43_vbss+vbou+vbuc+vbss=0.3488.pt
# ---- Epoch 44/100
# (1) Training stage (lr = 0.000001) ...
# loss 0.74069, vbg_vgbbox_loss 0.15166, vbg_att_sup_loss 0.19650, vbg_phrcls_loss 0.39253, vbg_prc_auc 0.84065, 243.19 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.21757, vbg_prc_auc 0.37766, 94.34 secs
# New checkpoint saved: checkpoint_44_vbss+vbou+vbuc+vbss=0.3504.pt
# ---- Epoch 45/100
# (1) Training stage (lr = 0.000080) ...
# loss 0.88415, vbg_vgbbox_loss 0.17154, vbg_att_sup_loss 0.23845, vbg_phrcls_loss 0.47415, vbg_prc_auc 0.73738, 245.03 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.19005, vbg_prc_auc 0.35251, 93.02 secs
# ---- Epoch 46/100
# (1) Training stage (lr = 0.000027) ...
# loss 0.78152, vbg_vgbbox_loss 0.15813, vbg_att_sup_loss 0.20610, vbg_phrcls_loss 0.41729, vbg_prc_auc 0.82647, 244.98 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.20941, vbg_prc_auc 0.37423, 92.95 secs
# ---- Epoch 47/100
# (1) Training stage (lr = 0.000009) ...
# loss 0.71458, vbg_vgbbox_loss 0.15352, vbg_att_sup_loss 0.19208, vbg_phrcls_loss 0.36898, vbg_prc_auc 0.86557, 245.59 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.20937, vbg_prc_auc 0.37692, 91.92 secs
# ---- Epoch 48/100
# (1) Training stage (lr = 0.000003) ...
# loss 0.67452, vbg_vgbbox_loss 0.14938, vbg_att_sup_loss 0.18006, vbg_phrcls_loss 0.34508, vbg_prc_auc 0.88193, 245.88 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.21004, vbg_prc_auc 0.38086, 91.91 secs
# New checkpoint saved: checkpoint_48_vbss+vbou+vbuc+vbss=0.3512.pt
# ---- Epoch 49/100
# (1) Training stage (lr = 0.000001) ...
# loss 0.67567, vbg_vgbbox_loss 0.15048, vbg_att_sup_loss 0.18204, vbg_phrcls_loss 0.34315, vbg_prc_auc 0.88863, 247.22 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.20968, vbg_prc_auc 0.37941, 91.19 secs
# ---- Epoch 50/100
# (1) Training stage (lr = 0.000080) ...
# loss 0.83049, vbg_vgbbox_loss 0.16631, vbg_att_sup_loss 0.22689, vbg_phrcls_loss 0.43729, vbg_prc_auc 0.79006, 246.21 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.19233, vbg_prc_auc 0.35531, 91.22 secs
# ---- Epoch 51/100
# (1) Training stage (lr = 0.000027) ...
# loss 0.71256, vbg_vgbbox_loss 0.15510, vbg_att_sup_loss 0.18971, vbg_phrcls_loss 0.36774, vbg_prc_auc 0.87142, 246.98 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.20795, vbg_prc_auc 0.39557, 91.34 secs
# New checkpoint saved: checkpoint_51_vbss+vbou+vbuc+vbss=0.3595.pt
# ---- Epoch 52/100
# (1) Training stage (lr = 0.000009) ...
# loss 0.64687, vbg_vgbbox_loss 0.15108, vbg_att_sup_loss 0.17433, vbg_phrcls_loss 0.32146, vbg_prc_auc 0.90903, 245.70 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.20882, vbg_prc_auc 0.38333, 91.96 secs
# ---- Epoch 53/100
# (1) Training stage (lr = 0.000003) ...
# loss 0.61634, vbg_vgbbox_loss 0.14893, vbg_att_sup_loss 0.16665, vbg_phrcls_loss 0.30076, vbg_prc_auc 0.92777, 245.42 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.20324, vbg_prc_auc 0.38264, 91.98 secs
# ---- Epoch 54/100
# (1) Training stage (lr = 0.000001) ...
# loss 0.60722, vbg_vgbbox_loss 0.14675, vbg_att_sup_loss 0.16499, vbg_phrcls_loss 0.29548, vbg_prc_auc 0.92784, 246.49 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.20577, vbg_prc_auc 0.39966, 92.51 secs
# New checkpoint saved: checkpoint_54_vbss+vbou+vbuc+vbss=0.3631.pt
# ---- Epoch 55/100
# (1) Training stage (lr = 0.000080) ...
# loss 0.78174, vbg_vgbbox_loss 0.16677, vbg_att_sup_loss 0.21089, vbg_phrcls_loss 0.40407, vbg_prc_auc 0.83233, 238.66 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.20001, vbg_prc_auc 0.36362, 93.21 secs
# ---- Epoch 56/100
# (1) Training stage (lr = 0.000027) ...
# loss 0.66233, vbg_vgbbox_loss 0.15337, vbg_att_sup_loss 0.17645, vbg_phrcls_loss 0.33251, vbg_prc_auc 0.90300, 245.66 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.20634, vbg_prc_auc 0.37695, 93.41 secs
# ---- Epoch 57/100
# (1) Training stage (lr = 0.000009) ...
# loss 0.59121, vbg_vgbbox_loss 0.14770, vbg_att_sup_loss 0.16216, vbg_phrcls_loss 0.28134, vbg_prc_auc 0.93485, 245.94 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.20314, vbg_prc_auc 0.37630, 94.11 secs
# ---- Epoch 58/100
# (1) Training stage (lr = 0.000003) ...
# loss 0.56592, vbg_vgbbox_loss 0.14659, vbg_att_sup_loss 0.15576, vbg_phrcls_loss 0.26357, vbg_prc_auc 0.94826, 242.91 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.20946, vbg_prc_auc 0.37665, 94.98 secs
# ---- Epoch 59/100
# (1) Training stage (lr = 0.000001) ...
# loss 0.56218, vbg_vgbbox_loss 0.14748, vbg_att_sup_loss 0.15468, vbg_phrcls_loss 0.26002, vbg_prc_auc 0.94894, 244.29 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.20634, vbg_prc_auc 0.37726, 94.79 secs
# ---- Epoch 60/100
# (1) Training stage (lr = 0.000080) ...
# ^C iteration 59050
# Engine run is terminating due to exception:
# Traceback (most recent call last):
#   File "/home/pamessina/medvqa/medvqa/notebooks/../train_phrase_grounding.py", line 1539, in <module>
#     train_from_scratch(**args)
#   File "/home/pamessina/medvqa/medvqa/notebooks/../train_phrase_grounding.py", line 1405, in train_from_scratch
#     return train_model(
#   File "/home/pamessina/medvqa/medvqa/notebooks/../train_phrase_grounding.py", line 918, in train_model
#     run_common_boilerplate_code_and_start_training(
#   File "/home/pamessina/medvqa/medvqa/training/utils.py", line 142, in run_common_boilerplate_code_and_start_training
#     trainer_engine.run(train_dataloader, max_epochs=epochs, epoch_length=batches_per_epoch)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 892, in run
#     return self._internal_run()
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 935, in _internal_run
#     return next(self._internal_run_generator)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 993, in _internal_run_as_gen
#     self._handle_exception(e)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 638, in _handle_exception
#     raise e
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 959, in _internal_run_as_gen
#     epoch_time_taken += yield from self._run_once_on_dataset_as_gen()
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 1068, in _run_once_on_dataset_as_gen
#     self.state.output = self._process_function(self, self.state.batch)
#   File "/home/pamessina/medvqa/medvqa/training/phrase_grounding.py", line 984, in step_fn
#     output = flag_to_step_fn[flag](batch)
#   File "/home/pamessina/medvqa/medvqa/training/phrase_grounding.py", line 615, in step_fn__vinbig_bbox_grounding
#     gradient_accumulator.step(batch_loss, model)
#   File "/home/pamessina/medvqa/medvqa/losses/optimizers.py", line 29, in step
#     self.scaler.scale(batch_loss).backward()
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/_tensor.py", line 525, in backward
#     torch.autograd.backward(
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/autograd/__init__.py", line 267, in backward
#     _engine_run_backward(
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/autograd/graph.py", line 744, in _engine_run_backward
#     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# KeyboardInterrupt

# %%
# !python ../train_phrase_grounding.py \
--pretrained_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250131_014546_vinbig_PhraseGrounder(microsoft-rad-dino,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)" \
--epochs 20 \
--batches_per_epoch 1000 \
--max_images_per_batch 6 \
--max_phrases_per_batch 1000 \
--max_phrases_per_image 45 \
--val_batch_size_factor 4 \
--raw_image_encoding "rad-dino-huggingface" \
--huggingface_model_name "microsoft/rad-dino" \
--image_size 416 416 \
--image_local_feat_size 768 \
--num_regions 841 \
--regions_width 29 \
--regions_height 29 \
--img_aug_mode "random-color-and-spatial" \
--phrase_embedding_size 128 \
--phrase_grounding_mode "adaptive_film_based_pooling_mlp_with_bbox_regression" \
--phrase_mlp_hidden_dims 256 128 \
--visual_grounding_hidden_size 256 \
--num_train_workers 2 \
--num_val_workers 2 \
--gradient_accumulation_steps 5 \
--optimizer_name "adamw" \
--scheduler "exp-warmup+decay+cyclicdecay" \
--lr 1e-6 \
--warmup_decay_and_cyclic_decay_args "1e-6,3,8e-5,5,1e-6,8e-5,5,1e-6" \
--binary_multilabel_classif_loss_name "focal+bce+npbbce" \
--do_visual_grounding_with_bbox_regression \
--use_vinbig_for_train \
--use_vinbig_for_test \
--vinbig_phrase_embeddings_filepath \
"/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/vinbig/label_phrase_embeddings(hash=353,2491289492560726319).pkl" \
--replace_phrase_embeddings_with_random_vectors \
--use_amp \
--save
# Out:
# script's arguments:
#    epochs: 20
#    batches_per_epoch: 1000
#    max_images_per_batch: 6
#    max_phrases_per_batch: 1000
#    max_phrases_per_image: 45
#    val_batch_size_factor: 4.0
#    checkpoint_folder: None
#    pretrained_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250131_014546_vinbig_PhraseGrounder(microsoft-rad-dino,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)
#    pretrained_checkpoint_folder_paths: None
#    freeze_image_encoder: False
#    raw_image_encoding: rad-dino-huggingface
#    huggingface_model_name: microsoft/rad-dino
#    num_regions: 841
#    image_local_feat_size: 768
#    image_encoder_pretrained_weights_path: None
#    image_encoder_dropout_p: 0
#    yolov8_model_name_or_path: None
#    yolov8_model_alias: None
#    phrase_embedding_size: 128
#    regions_width: 29
#    regions_height: 29
#    qkv_size: None
#    phrase_grounding_mode: adaptive_film_based_pooling_mlp_with_bbox_regression
#    phrase_classifier_hidden_size: None
#    transf_d_model: None
#    transf_nhead: None
#    transf_dim_feedforward: None
#    transf_dropout: 0
#    transf_num_layers: None
#    visual_feature_proj_size: None
#    visual_grounding_hidden_size: 256
#    phrase_mlp_hidden_dims: [256, 128]
#    predict_global_alignment: False
#    alignment_proj_size: None
#    yolov11_model_name_or_path: None
#    yolov11_model_alias: None
#    optimizer_name: adamw
#    lr: 1e-06
#    scheduler: exp-warmup+decay+cyclicdecay
#    lr_decay: 0.76
#    lr_decay_patience: 2
#    warmup_and_decay_args: None
#    warmup_and_cosine_args: None
#    warmup_decay_and_cyclic_decay_args: 1e-6,3,8e-5,5,1e-6,8e-5,5,1e-6
#    gradient_accumulation_steps: 5
#    override_lr: False
#    max_grad_norm: None
#    attention_supervision_loss_weight: 1.0
#    phrase_classifier_loss_weight: 1.0
#    foreground_loss_weight: 1.0
#    background_loss_weight: 1.0
#    focal_loss_weight: 1.0
#    bce_loss_weight: 1.0
#    wbce_loss_weight: 1.0
#    binary_multilabel_classif_loss_name: focal+bce+npbbce
#    use_weighted_phrase_classifier_loss: False
#    cluster_and_label_weights_for_facts_filepath: None
#    use_attention_regularization_loss: False
#    use_contrastive_phrase_grounding_loss: False
#    nt_xent_temperature: 0.1
#    num_train_workers: 2
#    num_val_workers: 2
#    device: GPU
#    use_amp: True
#    image_size: [416, 416]
#    dicom_id_to_pos_neg_facts_filepath: None
#    iuxray_image_id_to_pos_neg_facts_filepath: None
#    mscxr_phrase2embedding_filepath: None
#    chest_imagenome_bbox_phrase_embeddings_filepath: None
#    vinbig_phrase_embeddings_filepath: /mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/vinbig/label_phrase_embeddings(hash=353,2491289492560726319).pkl
#    chexlocalize_class_phrase_embeddings_filepath: None
#    chexpert_class_phrase_embeddings_filepath: None
#    mimiccxr_exclude_noisy_images: False
#    mimiccxr_facts_weight: 1.0
#    chest_imagenome_anatlocs_weight: 1.0
#    mscxr_weight: 1.0
#    cxrlt2024_weight: 1.0
#    vinbig_weight: 1.0
#    chexlocalize_weight: 1.0
#    chexpert_weight: 1.0
#    iuxray_weight: 1.0
#    img_aug_mode: random-color-and-spatial
#    pos_area_prior: 0.4
#    neg_area_prior: 0.0
#    use_mimiccxr_facts_for_train: False
#    use_mimiccxr_facts_for_test: False
#    use_mscxr_for_train: False
#    use_mscxr_for_test: False
#    use_chest_imagenome_for_train: False
#    use_chest_imagenome_gold_for_test: False
#    use_vinbig_for_train: True
#    use_vinbig_for_test: True
#    use_chexlocalize_for_train: False
#    use_chexlocalize_for_test: False
#    use_chexpert_for_train: False
#    use_chexpert_for_test: False
#    use_iuxray_for_train: False
#    use_iuxray_for_test: False
#    use_cxrlt2024_challenge_split: False
#    use_cxrlt2024_custom_labels: False
#    use_cxrlt2024_official_labels: False
#    use_all_cxrlt2024_official_labels_for_training: False
#    vinbig_training_data_mode: train
#    chexpert_training_data_mode: all
#    mimiccxr_balance_long_middle_short_tail: False
#    mimiccxr_long_middle_short_tail_thresholds: (0.02, 0.05)
#    mimiccxr_report_fact_nli_integrated_data_filepath: None
#    mimiccxr_use_interpret_cxr_challenge_split: False
#    mimiccxr_interpret_cxr_challenge_split_filepath: None
#    iuxray_use_interpret_cxr_challenge_split: False
#    iuxray_interpret_cxr_challenge_split_filepath: None
#    chexpert_use_interpret_cxr_challenge_split: False
#    chexpert_interpret_cxr_challenge_split_filepath: None
#    chexlocalize_use_interpret_cxr_challenge_split: False
#    chexlocalize_interpret_cxr_challenge_split_filepath: None
#    cxrlt2024_custom_dicom_id_to_pos_neg_facts_filepath: None
#    cxrlt2024_official_training_labels_for_fact_classification_filepath: None
#    cxrlt2024_do_balanced_sampling: False
#    do_visual_grounding_with_bbox_regression: True
#    do_visual_grounding_with_segmentation: False
#    replace_phrase_embeddings_with_random_vectors: True
#    use_vinbig_with_modified_labels: False
#    save: True
# ----- Training model from scratch ------
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Creating instance of PhraseGrounder ...
# WARNING: Unused kwargs: {'pretrained_checkpoint_folder_path': '/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250131_014546_vinbig_PhraseGrounder(microsoft-rad-dino,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)', 'pretrained_checkpoint_folder_paths': None}
# MultiPurposeVisualModule()
#   Initializing raw_image_encoder: rad-dino-huggingface
#   self.global_feat_size = 768
#   self.local_feat_size = 768
#   Initializing auxiliary tasks
# BoundingBoxRegressorSingleClass
#   local_feat_dim: 256
# --------------------------------------------------
# 3) Defining optimizer ...
# create_optimizer(): name = adamw
# --------------------------------------------------
# 4) Defining scheduler ...
# Using exp-warmup+decay+cyclicdecay scheduler: 1e-6,3,8e-5,5,1e-6,8e-5,5,1e-6
# 1e-06 3 8e-05 5 1e-06 8e-05 5 1e-06
# self.steps_to_restart = 5
# self.steps = -1
# self.initial_lr = 8e-05
# --------------------------------------------------
# 5) Creating trainer and validator engines ...
# Focal_BCE_NPBBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 npbbce_weight = 0.3333333333333333
# Focal_BCE_NPBBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 npbbce_weight = 0.3333333333333333
# Focal_BCE_WBCBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 wbcbce_weight = 0.3333333333333333
# foreground_loss_weight: 1.0
# background_loss_weight: 1.0
# GradientAccumulator.__init__(): num_accumulation_steps = 5, max_grad_norm = None
# Focal_BCE_NPBBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 npbbce_weight = 0.3333333333333333
# Focal_BCE_NPBBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 npbbce_weight = 0.3333333333333333
# Focal_BCE_WBCBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 wbcbce_weight = 0.3333333333333333
# foreground_loss_weight: 1.0
# background_loss_weight: 1.0
# --------------------------------------------------
# 6) Creating VinBig Phrase Grounding Trainer ...
# get_image_transform()
#   image_size = [416, 416]
#   mean = [0.5307, 0.5307, 0.5307]
#   std = [0.2583, 0.2583, 0.2583]
#   Using bounding box aware transforms
#     augmentation_mode = random-color-and-spatial
#     default_prob = 0.35
#     for_vinbig: returning vinbig transform
# get_train_transform(): Using bbox-aware transforms for VinBigData
#     Returning augmented transform with mode random-color-and-spatial
# get_image_transform()
#   image_size = [416, 416]
#   mean = [0.5307, 0.5307, 0.5307]
#   std = [0.2583, 0.2583, 0.2583]
#   Using bounding box aware transforms
#     Returning default transform (no augmentation)
# Loading bounding boxes
# Anomalous bboxes found: 29 of 37367
# class_id_offset: 0
# Anomalous bboxes found: 0 of 2697
# class_id_offset: 0
#   Loaded 18000 bounding boxes
# Loding phrase_embeddings and phrases from /mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/vinbig/label_phrase_embeddings(hash=353,2491289492560726319).pkl...
# NOTE: Replacing phrase embeddings with random vectors
# Random vectors already saved at /mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/vinbig/label_phrase_embeddings(hash=353,2491289492560726319).pkl.random_vectors.pkl
# phrase_embeddings.shape = (28, 128)
# phrase_embeddings.dtype = float32
# len(phrases) = 28
# Compute phrase grounding masks and labels
# vinbig_bbox_names = ['Aortic enlargement', 'Atelectasis', 'Calcification', 'Cardiomegaly', 'Clavicle fracture', 'Consolidation', 'Edema', 'Emphysema', 'Enlarged PA', 'ILD', 'Infiltration', 'Lung Opacity', 'Lung cavity', 'Lung cyst', 'Mediastinal shift', 'Nodule/Mass', 'Other lesion', 'Pleural effusion', 'Pleural thickening', 'Pneumothorax', 'Pulmonary fibrosis', 'Rib fracture']
# vinbig_labels = ['Aortic enlargement', 'Atelectasis', 'Calcification', 'Cardiomegaly', 'Clavicle fracture', 'Consolidation', 'Edema', 'Emphysema', 'Enlarged PA', 'ILD', 'Infiltration', 'Lung Opacity', 'Lung cavity', 'Lung cyst', 'Mediastinal shift', 'Nodule/Mass', 'Pleural effusion', 'Pleural thickening', 'Pneumothorax', 'Pulmonary fibrosis', 'Rib fracture', 'Other lesion', 'COPD', 'Lung tumor', 'Pneumonia', 'Tuberculosis', 'Other disease', 'No finding']
# num_bbox_classes = 22
# self.phrase_grounding_masks.shape = (18000, 22, 841)
# self.phrase_classification_labels.shape = (18000, 22)
# Append additional labels to phrase_classification_labels
# len(non_bbox_labels) = 6
# non_bbox_labels = ['COPD', 'Lung tumor', 'Pneumonia', 'Tuberculosis', 'Other disease', 'No finding']
# self.phrase_classification_labels.shape = (18000, 28)
# Reorder phrases and phrase_embeddings
# len(phrases) = 28
# len(sorted_phrases) = 28
# phrase_embeddings.shape = (28, 128)
# 	aortic enlargement seen (Aortic enlargement)
# 	atelectasis seen (Atelectasis)
# 	calcification seen (Calcification)
# 	cardiomegaly seen (Cardiomegaly)
# 	clavicle fracture seen (Clavicle fracture)
# 	consolidation seen (Consolidation)
# 	edema seen (Edema)
# 	emphysema seen (Emphysema)
# 	enlarged pulmonary artery seen (Enlarged PA)
# 	interstitial lung disease seen (ILD)
# 	infiltration seen (Infiltration)
# 	lung opacity seen (Lung Opacity)
# 	lung cavity seen (Lung cavity)
# 	lung cyst seen (Lung cyst)
# 	mediastinal shift seen (Mediastinal shift)
# 	nodule/mass seen (Nodule/Mass)
# 	other lesion seen (Other lesion)
# 	pleural effusion seen (Pleural effusion)
# 	pleural thickening seen (Pleural thickening)
# 	pneumothorax seen (Pneumothorax)
# 	pulmonary fibrosis seen (Pulmonary fibrosis)
# 	rib fracture seen (Rib fracture)
# 	copd seen (COPD)
# 	lung tumor seen (Lung tumor)
# 	pneumonia seen (Pneumonia)
# 	tuberculosis seen (Tuberculosis)
# 	other disease seen (Other disease)
# 	no abnormalities seen (No finding)
# Generating train dataset and dataloader
# len(train_indices) = 15000
# No labels: 0
# Edema: 13
# Clavicle fracture: 27
# Lung cyst: 33
# COPD: 36
# Lung cavity: 51
# Emphysema: 81
# Rib fracture: 90
# Pneumothorax: 96
# Enlarged PA: 131
# Mediastinal shift: 150
# Atelectasis: 187
# Lung tumor: 291
# Consolidation: 353
# ILD: 397
# Calcification: 458
# Infiltration: 613
# Tuberculosis: 750
# Nodule/Mass: 841
# Pneumonia: 919
# Pleural effusion: 1038
# Other lesion: 1154
# Lung Opacity: 1331
# Pulmonary fibrosis: 1621
# Pleural thickening: 2010
# Cardiomegaly: 2316
# Aortic enlargement: 3098
# Other disease: 4377
# No finding: 10478
# Group sizes: [10478, 771, 323, 312, 286, 278, 258, 243, 241, 218, 215, 167, 159, 156, 122, 119, 117, 114, 102, 83, 82, 79, 77]
#   len(indices) = 10478, weight = 2381.9852437292775
#   len(indices) = 771, weight = 882.1360585110112
#   len(indices) = 323, weight = 579.1323556126193
#   len(indices) = 312, weight = 568.7753795323758
#   len(indices) = 286, weight = 543.3127950518186
#   len(indices) = 278, weight = 535.1778961104801
#   len(indices) = 258, weight = 514.1586596868186
#   len(indices) = 243, weight = 497.69925147612867
#   len(indices) = 241, weight = 495.4562099629317
#   len(indices) = 218, weight = 468.76865710351854
#   len(indices) = 215, weight = 465.15882500917724
#   len(indices) = 167, weight = 402.55283205217046
#   len(indices) = 159, weight = 391.0802349542582
#   len(indices) = 156, weight = 386.6879164039802
#   len(indices) = 122, weight = 332.9187999914028
#   len(indices) = 119, weight = 327.76937690454827
#   len(indices) = 117, weight = 324.29434664271645
#   len(indices) = 114, weight = 319.0166061056533
#   len(indices) = 102, weight = 297.0647831080699
#   len(indices) = 83, weight = 259.088791948487
#   len(indices) = 82, weight = 256.9625090236898
#   len(indices) = 79, weight = 250.497443897163
#   len(indices) = 77, weight = 246.11308599196298
# batch_size = 6
# Generating val dataset and dataloader
# len(test_indices) = 3000
# batch_size = 24
# --------------------------------------------------
# 7) Creating dataloaders ...
# len(vinbig_trainer.train_dataloader) = 166666666666666667
# len(vinbig_trainer.val_dataloader) = 125
# len(_train_dataloaders) = 1
# len(_val_dataloaders) = 1
# _train_weights = [1.0]
# merged_dataset_name = vinbig
# --------------------------------------------------
# 8) Attaching metrics, losses, timer and events to engines ...
# --------------------------------------------------
# 9) Defining learning rate scheduler handler ...
# --------------------------------------------------
# 10) Defining checkpoint folder path ...
# checkpoint_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250217_183138_vinbig_PhraseGrounder(microsoft-rad-dino,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)
# metadata saved to /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250217_183138_vinbig_PhraseGrounder(microsoft-rad-dino,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/metadata.json
# --------------------------------------------------
# 11) Loading pretrained weights ...
# checkpoint_names = ['checkpoint_54_vbss+vbou+vbuc+vbss=0.3631.pt']
# pretrained_checkpoint_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250131_014546_vinbig_PhraseGrounder(microsoft-rad-dino,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/checkpoint_54_vbss+vbou+vbuc+vbss=0.3631.pt
# Checkpoint successfully loaded!
# --------------------------------------------------
# 12) Defining log_metrics_handler ...
# MetricsLogger :: we'll be logging to /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250217_183138_vinbig_PhraseGrounder(microsoft-rad-dino,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/metrics_logs.csv
# --------------------------------------------------
# 13) Running trainer engine ...
# ---- Epoch 1/20
# (1) Training stage (lr = 0.000001) ...
# loss 0.79523, vbg_vgbbox_loss 0.15557, vbg_att_sup_loss 0.21910, vbg_phrcls_loss 0.42056, vbg_prc_auc 0.83679, 249.91 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.22984, vbg_prc_auc 0.41092, 104.17 secs
# Train metrics:
# vbg_vgbbox_loss: 0.8654, weight = 1.0
# vbg_att_sup_loss: 0.8203, weight = 1.0
# vbg_prc_auc: 0.8368, weight = 10.0
# num = 10.0536, den = 12.0000, score = 0.8378
# Val metrics:
# vbg_bbox_iou: 0.2298, weight = 1.0
# vbg_prc_auc: 0.4109, weight = 10.0
# num = 4.3391, den = 11.0000, score = 0.3945
# Train score = 0.8378, Val score = 0.3945, Final score = 0.4166
# w_train = 0.05, w_val = 0.95
# New checkpoint saved: checkpoint_1_vbss+vbou+vbuc+vbss=0.4166.pt
# ---- Epoch 2/20
# (1) Training stage (lr = 0.000004) ...
# loss 0.74823, vbg_vgbbox_loss 0.15314, vbg_att_sup_loss 0.20197, vbg_phrcls_loss 0.39311, vbg_prc_auc 0.84500, 246.01 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.22877, vbg_prc_auc 0.41529, 103.72 secs
# New checkpoint saved: checkpoint_2_vbss+vbou+vbuc+vbss=0.4207.pt
# ---- Epoch 3/20
# (1) Training stage (lr = 0.000019) ...
# loss 0.73103, vbg_vgbbox_loss 0.15255, vbg_att_sup_loss 0.19327, vbg_phrcls_loss 0.38522, vbg_prc_auc 0.85270, 254.92 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.23626, vbg_prc_auc 0.41977, 100.71 secs
# New checkpoint saved: checkpoint_3_vbss+vbou+vbuc+vbss=0.4256.pt
# ---- Epoch 4/20
# (1) Training stage (lr = 0.000080) ...
# loss 0.82348, vbg_vgbbox_loss 0.16529, vbg_att_sup_loss 0.21542, vbg_phrcls_loss 0.44277, vbg_prc_auc 0.79143, 246.25 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.21723, vbg_prc_auc 0.41576, 100.11 secs
# ---- Epoch 5/20
# (1) Training stage (lr = 0.000033) ...
# loss 0.70843, vbg_vgbbox_loss 0.15229, vbg_att_sup_loss 0.18420, vbg_phrcls_loss 0.37194, vbg_prc_auc 0.87224, 254.86 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.22186, vbg_prc_auc 0.41333, 100.31 secs
# ---- Epoch 6/20
# (1) Training stage (lr = 0.000014) ...
# loss 0.63053, vbg_vgbbox_loss 0.14769, vbg_att_sup_loss 0.16547, vbg_phrcls_loss 0.31737, vbg_prc_auc 0.91907, 252.39 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.22156, vbg_prc_auc 0.41544, 99.41 secs
# ---- Epoch 7/20
# (1) Training stage (lr = 0.000006) ...
# loss 0.60598, vbg_vgbbox_loss 0.14609, vbg_att_sup_loss 0.16145, vbg_phrcls_loss 0.29845, vbg_prc_auc 0.93206, 253.96 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.22360, vbg_prc_auc 0.41236, 100.77 secs
# ---- Epoch 8/20
# (1) Training stage (lr = 0.000002) ...
# loss 0.58638, vbg_vgbbox_loss 0.14384, vbg_att_sup_loss 0.15608, vbg_phrcls_loss 0.28646, vbg_prc_auc 0.94013, 253.71 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.22176, vbg_prc_auc 0.41461, 100.59 secs
# ---- Epoch 9/20
# (1) Training stage (lr = 0.000001) ...
# loss 0.57806, vbg_vgbbox_loss 0.14373, vbg_att_sup_loss 0.15464, vbg_phrcls_loss 0.27969, vbg_prc_auc 0.93987, 253.69 secs
# (2) Validation stage ...
# vbg_bbox_iou 0.22226, vbg_prc_auc 0.41365, 101.81 secs
# ---- Epoch 10/20
# (1) Training stage (lr = 0.000080) ...
# ^C iteration 9475
# Engine run is terminating due to exception:
# Traceback (most recent call last):
#   File "/home/pamessina/medvqa/medvqa/notebooks/../train_phrase_grounding.py", line 1553, in <module>
#     train_from_scratch(**args)
#   File "/home/pamessina/medvqa/medvqa/notebooks/../train_phrase_grounding.py", line 1419, in train_from_scratch
#     return train_model(
#   File "/home/pamessina/medvqa/medvqa/notebooks/../train_phrase_grounding.py", line 926, in train_model
#     run_common_boilerplate_code_and_start_training(
#   File "/home/pamessina/medvqa/medvqa/training/utils.py", line 137, in run_common_boilerplate_code_and_start_training
#     trainer_engine.run(train_dataloader, max_epochs=epochs, epoch_length=batches_per_epoch)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 892, in run
#     return self._internal_run()
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 935, in _internal_run
#     return next(self._internal_run_generator)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 993, in _internal_run_as_gen
#     self._handle_exception(e)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 638, in _handle_exception
#     raise e
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 959, in _internal_run_as_gen
#     epoch_time_taken += yield from self._run_once_on_dataset_as_gen()
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 1068, in _run_once_on_dataset_as_gen
#     self.state.output = self._process_function(self, self.state.batch)
#   File "/home/pamessina/medvqa/medvqa/training/phrase_grounding.py", line 991, in step_fn
#     output = flag_to_step_fn[flag](batch)
#   File "/home/pamessina/medvqa/medvqa/training/phrase_grounding.py", line 622, in step_fn__vinbig_bbox_grounding
#     gradient_accumulator.step(batch_loss, model)
#   File "/home/pamessina/medvqa/medvqa/losses/optimizers.py", line 39, in step
#     self.optimizer.zero_grad()
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/_compile.py", line 24, in inner
#     return torch._dynamo.disable(fn, recursive)(*args, **kwargs)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/_dynamo/eval_frame.py", line 451, in _fn
#     return fn(*args, **kwargs)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/optim/optimizer.py", line 825, in zero_grad
#     p.grad = None
# KeyboardInterrupt
