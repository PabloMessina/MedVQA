# %%
# %env CUDA_VISIBLE_DEVICES=0
# Out:
# env: CUDA_VISIBLE_DEVICES=0

# %%
# !python ../scripts/vinbig/precompute_phrase_embeddings.py \
--model_name "microsoft/BiomedVLP-CXR-BERT-specialized" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240629_084405_MIMIC-CXR(triplets+classif+entcont+nli+radgraph+autoencoder)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)"
# Out:
# Obtaining embeddings for each sentence...
# checkpoint_names = ['checkpoint_196_cacc+chf1+chf1+cscc+encc+hscc+nlcc+sass+spss+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9189.pt']
#   0%|                                                    | 0/28 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=441,505879158912416539).pkl
# len(self.cache["hashes"]) = 1059
# self.cache["embeddings"].shape = (1059, 128)
# 100%|████████████████████████████████████████| 28/28 [00:00<00:00, 20078.73it/s]
# Computing embeddings for 28 new texts
# checkpoint_names = ['checkpoint_196_cacc+chf1+chf1+cscc+encc+hscc+nlcc+sass+spss+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9189.pt']
# Loading model weights from /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240629_084405_MIMIC-CXR(triplets+classif+entcont+nli+radgraph+autoencoder)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/checkpoint_196_cacc+chf1+chf1+cscc+encc+hscc+nlcc+sass+spss+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9189.pt
# Warning: model state dict has 210 keys, loaded state dict has 257 keys, intersection has 210 keys, union has 257 keys.
# Examples of keys in loaded state dict but not in model:
#   nli_classifier.bias
#   fact_decoder.embedding_table.weight
#   health_status_classifier.weight
#   spert_entity_classifier.weight
#   fact_decoder.decoder.layers.0.norm2.bias
#   fact_decoder.decoder.layers.0.norm3.bias
#   fact_decoder.pos_encoder.pe
#   category_classifier.bias
#   comparison_status_classifier.bias
#   fact_decoder.decoder.layers.0.norm3.weight
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00,  8.50it/s]
# Saving updated cache to /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=441,505879158912416539).pkl
# 100%|███████████████████████████████████████| 28/28 [00:00<00:00, 271853.04it/s]
# Saving output to: /mnt/workspace/pamessina/medvqa-workspace/cache/vinbig/label_phrase_embeddings(hash=325,2238524744738711392).pkl
# Done!

# %%
# !python ../scripts/chexlocalize/precompute_phrase_embeddings.py \
--model_name "microsoft/BiomedVLP-CXR-BERT-specialized" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240629_084405_MIMIC-CXR(triplets+classif+entcont+nli+radgraph+autoencoder)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)"
# Out:
# Obtaining embeddings for each sentence...
# checkpoint_names = ['checkpoint_196_cacc+chf1+chf1+cscc+encc+hscc+nlcc+sass+spss+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9189.pt']
#   0%|                                                    | 0/10 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=441,505879158912416539).pkl
# len(self.cache["hashes"]) = 1087
# self.cache["embeddings"].shape = (1087, 128)
# 100%|█████████████████████████████████████████| 10/10 [00:00<00:00, 8813.41it/s]
# Computing embeddings for 4 new texts
# checkpoint_names = ['checkpoint_196_cacc+chf1+chf1+cscc+encc+hscc+nlcc+sass+spss+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9189.pt']
# Loading model weights from /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240629_084405_MIMIC-CXR(triplets+classif+entcont+nli+radgraph+autoencoder)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/checkpoint_196_cacc+chf1+chf1+cscc+encc+hscc+nlcc+sass+spss+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9189.pt
# Warning: model state dict has 210 keys, loaded state dict has 257 keys, intersection has 210 keys, union has 257 keys.
# Examples of keys in loaded state dict but not in model:
#   fact_decoder.decoder.layers.0.norm3.weight
#   chest_imagenome_anatloc_classifier.bias
#   chest_imagenome_obs_classifier.weight
#   spert_entity_classifier.bias
#   aux_task_hidden_layer.weight
#   spert_rel_classifier.bias
#   nli_hidden_layer.weight
#   spert_size_embeddings.weight
#   fact_decoder_input_layer.bias
#   health_status_classifier.weight
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00,  8.80it/s]
# Saving updated cache to /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=441,505879158912416539).pkl
# 100%|██████████████████████████████████████████| 4/4 [00:00<00:00, 69905.07it/s]
# Saving output to: /mnt/workspace/pamessina/medvqa-workspace/cache/chexlocalize/class_phrase_embeddings(hash=528,2353352898845085012).pkl
# Done!

# %%
# !python ../scripts/chest_imagenome/precompute_bbox_phrase_embeddings.py \
--model_name "microsoft/BiomedVLP-CXR-BERT-specialized" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240629_084405_MIMIC-CXR(triplets+classif+entcont+nli+radgraph+autoencoder)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)"
# Out:
# Obtaining embeddings for each sentence...
# checkpoint_names = ['checkpoint_196_cacc+chf1+chf1+cscc+encc+hscc+nlcc+sass+spss+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9189.pt']
#   0%|                                                    | 0/36 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=441,505879158912416539).pkl
# len(self.cache["hashes"]) = 1091
# self.cache["embeddings"].shape = (1091, 128)
# 100%|████████████████████████████████████████| 36/36 [00:00<00:00, 26583.62it/s]
# Computing embeddings for 36 new texts
# checkpoint_names = ['checkpoint_196_cacc+chf1+chf1+cscc+encc+hscc+nlcc+sass+spss+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9189.pt']
# Loading model weights from /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240629_084405_MIMIC-CXR(triplets+classif+entcont+nli+radgraph+autoencoder)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/checkpoint_196_cacc+chf1+chf1+cscc+encc+hscc+nlcc+sass+spss+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9189.pt
# Warning: model state dict has 210 keys, loaded state dict has 257 keys, intersection has 210 keys, union has 257 keys.
# Examples of keys in loaded state dict but not in model:
#   fact_decoder.decoder.layers.0.norm1.weight
#   nli_hidden_layer.bias
#   category_classifier.weight
#   health_status_classifier.bias
#   fact_decoder.decoder.layers.0.norm1.bias
#   spert_entity_classifier.bias
#   fact_decoder.decoder.layers.0.self_attn.out_proj.bias
#   nli_classifier.weight
#   fact_decoder.decoder.layers.0.norm3.weight
#   category_classifier.bias
# 100%|█████████████████████████████████████████████| 2/2 [00:00<00:00,  4.72it/s]
# Saving updated cache to /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=441,505879158912416539).pkl
# 100%|███████████████████████████████████████| 36/36 [00:00<00:00, 319904.54it/s]
# Saving output to: /mnt/workspace/pamessina/medvqa-workspace/cache/chest_imagenome/bbox_phrase_embeddings(hash=333,1643894111267724539).pkl
# Done!

# %%
# !python ../scripts/mscxr/precompute_phrase_embeddings.py \
--model_name "microsoft/BiomedVLP-CXR-BERT-specialized" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240629_084405_MIMIC-CXR(triplets+classif+entcont+nli+radgraph+autoencoder)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)"
# Out:
# len(phrases): 715
# Obtaining embeddings for each phrase...
# checkpoint_names = ['checkpoint_196_cacc+chf1+chf1+cscc+encc+hscc+nlcc+sass+spss+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9189.pt']
#   0%|                                                   | 0/715 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=441,505879158912416539).pkl
# len(self.cache["hashes"]) = 1127
# self.cache["embeddings"].shape = (1127, 128)
# 100%|█████████████████████████████████████| 715/715 [00:00<00:00, 266595.02it/s]
# Computing embeddings for 696 new texts
# checkpoint_names = ['checkpoint_196_cacc+chf1+chf1+cscc+encc+hscc+nlcc+sass+spss+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9189.pt']
# Loading model weights from /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240629_084405_MIMIC-CXR(triplets+classif+entcont+nli+radgraph+autoencoder)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/checkpoint_196_cacc+chf1+chf1+cscc+encc+hscc+nlcc+sass+spss+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9189.pt
# Warning: model state dict has 210 keys, loaded state dict has 257 keys, intersection has 210 keys, union has 257 keys.
# Examples of keys in loaded state dict but not in model:
#   comparison_status_classifier.bias
#   fact_decoder.decoder.layers.0.multihead_attn.out_proj.bias
#   fact_decoder.decoder.layers.0.linear1.bias
#   fact_decoder.decoder.layers.0.norm2.weight
#   fact_decoder_input_layer.weight
#   fact_decoder.embedding_table.weight
#   health_status_classifier.bias
#   aux_task_hidden_layer.bias
#   fact_decoder.W_vocab.bias
#   spert_size_embeddings.weight
# 100%|███████████████████████████████████████████| 22/22 [00:00<00:00, 30.83it/s]
# Saving updated cache to /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=441,505879158912416539).pkl
# 100%|█████████████████████████████████████| 696/696 [00:00<00:00, 550487.57it/s]
# phrase_embeddings.shape: (715, 128)
# len(phrase2embedding): 715
# Saving output to: /mnt/workspace/pamessina/medvqa-workspace/cache/mimiccxr/mscxr_phrase2embedding(hash=36521,3567052674817879091).pkl
# Done!

# %%
from medvqa.utils.files import list_filepaths_with_prefix_and_timestamps

# %%
list_filepaths_with_prefix_and_timestamps("/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/")[:10]
# Out:
# [('/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240705_131322_mscxr+chst-img-anat+vinbig+chexloc_PhraseGrounder(dn121,FiLM_SigmoidAttention,128,256,256,256,1,256-128)/metrics_logs.csv',
#   '2024-07-05 16:47:29'),
#  ('/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240705_131322_mscxr+chst-img-anat+vinbig+chexloc_PhraseGrounder(dn121,FiLM_SigmoidAttention,128,256,256,256,1,256-128)/checkpoint_98_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.7372.pt',
#   '2024-07-05 16:43:10'),
#  ('/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240705_131322_mscxr+chst-img-anat+vinbig+chexloc_PhraseGrounder(dn121,FiLM_SigmoidAttention,128,256,256,256,1,256-128)/metadata.json',
#   '2024-07-05 13:13:22'),
#  ('/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240705_093632_mscxr+chst-img-anat+vinbig+chexloc_PhraseGrounder(dn121,FiLM_SigmoidAttention,128,256,256,256,1,256-128)/checkpoint_101_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.7232.pt',
#   '2024-07-05 13:10:22'),
#  ('/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240705_093632_mscxr+chst-img-anat+vinbig+chexloc_PhraseGrounder(dn121,FiLM_SigmoidAttention,128,256,256,256,1,256-128)/metrics_logs.csv',
#   '2024-07-05 13:10:22'),
#  ('/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240705_093632_mscxr+chst-img-anat+vinbig+chexloc_PhraseGrounder(dn121,FiLM_SigmoidAttention,128,256,256,256,1,256-128)/metadata.json',
#   '2024-07-05 09:36:32'),
#  ('/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240619_155740_mscxr+chst-img-anat+vinbig+chexloc_PhraseGrounder(dn121,TransformerEncoder,128,256,1,512,1)/metrics_logs.csv',
#   '2024-06-19 18:18:29'),
#  ('/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240619_155740_mscxr+chst-img-anat+vinbig+chexloc_PhraseGrounder(dn121,TransformerEncoder,128,256,1,512,1)/checkpoint_69_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.6454.pt',
#   '2024-06-19 17:30:40'),
#  ('/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240619_155740_mscxr+chst-img-anat+vinbig+chexloc_PhraseGrounder(dn121,TransformerEncoder,128,256,1,512,1)/metadata.json',
#   '2024-06-19 15:57:40'),
#  ('/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240618_175951_mscxr+chst-img-anat+vinbig+chexloc_PhraseGrounder(dn121,SigmoidAttention,128,256,256,1)/metrics_logs.csv',
#   '2024-06-19 14:50:12')]

# %%
# !python ../train_phrase_grounding.py \
--pretrained_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240705_131322_mscxr+chst-img-anat+vinbig+chexloc_PhraseGrounder(dn121,FiLM_SigmoidAttention,128,256,256,256,1,256-128)/" \
--epochs 100 \
--batches_per_epoch 700 \
--max_images_per_batch 25 \
--max_phrases_per_batch 400 \
--max_phrases_per_image 40 \
--val_batch_size_factor 2.0 \
--raw_image_encoding "densenet-121" \
--image_size 416 416 \
--image_local_feat_size 1024 \
--num_regions 169 \
--regions_width 13 \
--regions_height 13 \
--phrase_embedding_size 128 \
--phrase_grounding_mode "film_layers_plus_sigmoid_attention_and_custom_classifier" \
--visual_feature_proj_size 256 \
--visual_grounding_hidden_size 256 \
--phrase_mlp_hidden_dims 256 128 \
--num_train_workers 2 \
--num_val_workers 2 \
--gradient_accumulation_steps 10 \
--optimizer_name "adamw" \
--scheduler "exp-warmup+decay+cyclicdecay" \
--lr 1e-6 \
--warmup_decay_and_cyclic_decay_args "1e-6,3,8e-5,8,1e-6,8e-5,8,1e-6" \
--mimiccxr_exclude_noisy_images \
--binary_multilabel_classif_loss_name "focal+bce+wbce" \
--use_vinbig_for_train \
--use_vinbig_for_test \
--vinbig_phrase_embeddings_filepath \
"/mnt/workspace/pamessina/medvqa-workspace/cache/vinbig/label_phrase_embeddings(hash=325,2238524744738711392).pkl" \
--vinbig_training_data_mode "all" \
--use_chexlocalize_for_train \
--use_chexlocalize_for_test \
--chexlocalize_class_phrase_embeddings_filepath \
"/mnt/workspace/pamessina/medvqa-workspace/cache/chexlocalize/class_phrase_embeddings(hash=528,2353352898845085012).pkl" \
--use_chest_imagenome_for_train \
--use_chest_imagenome_gold_for_test \
--chest_imagenome_bbox_phrase_embeddings_filepath \
"/mnt/workspace/pamessina/medvqa-workspace/cache/chest_imagenome/bbox_phrase_embeddings(hash=333,1643894111267724539).pkl" \
--use_mscxr_for_train \
--use_mscxr_for_test \
--mscxr_phrase2embedding_filepath \
"/mnt/workspace/pamessina/medvqa-workspace/cache/mimiccxr/mscxr_phrase2embedding(hash=36521,3567052674817879091).pkl" \
--use_attention_regularization_loss \
--use_contrastive_phrase_grounding_loss \
--attention_supervision_loss_weight 2.0 \
--phrase_classifier_loss_weight 2.0 \
--foreground_loss_weight 1.5 \
--mask_exponent 0.4 \
--chest_imagenome_anatlocs_weight 1.0 \
--vinbig_weight 1.3 \
--mscxr_weight 0.5 \
--chexlocalize_weight 0.5 \
--save
# Out:
# script's arguments:
#    epochs: 100
#    batches_per_epoch: 700
#    max_images_per_batch: 25
#    max_phrases_per_batch: 400
#    max_phrases_per_image: 40
#    val_batch_size_factor: 2.0
#    checkpoint_folder: None
#    pretrained_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240705_131322_mscxr+chst-img-anat+vinbig+chexloc_PhraseGrounder(dn121,FiLM_SigmoidAttention,128,256,256,256,1,256-128)/
#    pretrained_checkpoint_folder_paths: None
#    freeze_image_encoder: False
#    raw_image_encoding: densenet-121
#    num_regions: 169
#    image_local_feat_size: 1024
#    image_encoder_pretrained_weights_path: None
#    yolov8_model_name_or_path: None
#    yolov8_model_alias: None
#    phrase_embedding_size: 128
#    regions_width: 13
#    regions_height: 13
#    qkv_size: None
#    phrase_grounding_mode: film_layers_plus_sigmoid_attention_and_custom_classifier
#    phrase_classifier_hidden_size: None
#    transf_d_model: None
#    transf_nhead: None
#    transf_dim_feedforward: None
#    transf_dropout: 0
#    transf_num_layers: None
#    visual_feature_proj_size: 256
#    visual_grounding_hidden_size: 256
#    phrase_mlp_hidden_dims: [256, 128]
#    optimizer_name: adamw
#    lr: 1e-06
#    scheduler: exp-warmup+decay+cyclicdecay
#    lr_decay: 0.76
#    lr_decay_patience: 2
#    warmup_and_decay_args: None
#    warmup_and_cosine_args: None
#    warmup_decay_and_cyclic_decay_args: 1e-6,3,8e-5,8,1e-6,8e-5,8,1e-6
#    gradient_accumulation_steps: 10
#    override_lr: False
#    max_grad_norm: None
#    attention_supervision_loss_weight: 2.0
#    phrase_classifier_loss_weight: 2.0
#    foreground_loss_weight: 1.5
#    background_loss_weight: 1.0
#    focal_loss_weight: 1.0
#    bce_loss_weight: 1.0
#    wbce_loss_weight: 1.0
#    binary_multilabel_classif_loss_name: focal+bce+wbce
#    use_weighted_phrase_classifier_loss: False
#    cluster_and_label_weights_for_facts_filepath: None
#    use_attention_regularization_loss: True
#    use_contrastive_phrase_grounding_loss: True
#    num_train_workers: 2
#    num_val_workers: 2
#    device: GPU
#    use_amp: False
#    image_size: [416, 416]
#    dicom_id_to_pos_neg_facts_filepath: None
#    iuxray_image_id_to_pos_neg_facts_filepath: None
#    mscxr_phrase2embedding_filepath: /mnt/workspace/pamessina/medvqa-workspace/cache/mimiccxr/mscxr_phrase2embedding(hash=36521,3567052674817879091).pkl
#    chest_imagenome_bbox_phrase_embeddings_filepath: /mnt/workspace/pamessina/medvqa-workspace/cache/chest_imagenome/bbox_phrase_embeddings(hash=333,1643894111267724539).pkl
#    vinbig_phrase_embeddings_filepath: /mnt/workspace/pamessina/medvqa-workspace/cache/vinbig/label_phrase_embeddings(hash=325,2238524744738711392).pkl
#    chexlocalize_class_phrase_embeddings_filepath: /mnt/workspace/pamessina/medvqa-workspace/cache/chexlocalize/class_phrase_embeddings(hash=528,2353352898845085012).pkl
#    chexpert_class_phrase_embeddings_filepath: None
#    mimiccxr_exclude_noisy_images: True
#    mimiccxr_facts_weight: 1.0
#    chest_imagenome_anatlocs_weight: 1.0
#    mscxr_weight: 0.5
#    vinbig_weight: 1.3
#    chexlocalize_weight: 0.5
#    chexpert_weight: 1.0
#    iuxray_weight: 1.0
#    img_aug_mode: None
#    pos_area_prior: 0.4
#    neg_area_prior: 0.0
#    use_mimiccxr_facts_for_train: False
#    use_mimiccxr_facts_for_test: False
#    use_mscxr_for_train: True
#    use_mscxr_for_test: True
#    use_chest_imagenome_for_train: True
#    use_chest_imagenome_gold_for_test: True
#    use_vinbig_for_train: True
#    use_vinbig_for_test: True
#    use_chexlocalize_for_train: True
#    use_chexlocalize_for_test: True
#    use_chexpert_for_train: False
#    use_chexpert_for_test: False
#    use_iuxray_for_train: False
#    use_iuxray_for_test: False
#    vinbig_training_data_mode: all
#    chexpert_training_data_mode: all
#    mask_exponent: 0.4
#    mimiccxr_balance_long_middle_short_tail: False
#    mimiccxr_long_middle_short_tail_thresholds: (0.02, 0.05)
#    mimiccxr_report_fact_nli_integrated_data_filepath: None
#    mimiccxr_use_interpret_cxr_challenge_split: False
#    mimiccxr_interpret_cxr_challenge_split_filepath: None
#    iuxray_use_interpret_cxr_challenge_split: False
#    iuxray_interpret_cxr_challenge_split_filepath: None
#    chexpert_use_interpret_cxr_challenge_split: False
#    chexpert_interpret_cxr_challenge_split_filepath: None
#    chexlocalize_use_interpret_cxr_challenge_split: False
#    chexlocalize_interpret_cxr_challenge_split_filepath: None
#    save: True
# ----- Training model from scratch ------
# include_loss_weights = True
# source_image_size_mode: medium_512
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Creating instance of PhraseGrounder ...
# WARNING: Unused kwargs: {'pretrained_checkpoint_folder_path': '/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240705_131322_mscxr+chst-img-anat+vinbig+chexloc_PhraseGrounder(dn121,FiLM_SigmoidAttention,128,256,256,256,1,256-128)/', 'pretrained_checkpoint_folder_paths': None}
# MultiPurposeVisualModule()
#   Initializing raw_image_encoder: densenet-121
# create_densenet121_feature_extractor()
#    drop_rate: 0.0
# DenseNet121's pretrained weights loaded from ImageNet
#   self.global_feat_size = 2048
#   self.local_feat_size = 1024
#   Initializing auxiliary tasks
# Using positional encoding for local features
# --------------------------------------------------
# 3) Defining optimizer ...
# create_optimizer(): name = adamw
# --------------------------------------------------
# 4) Defining scheduler ...
# Using exp-warmup+decay+cyclicdecay scheduler: 1e-6,3,8e-5,8,1e-6,8e-5,8,1e-6
# 1e-06 3 8e-05 8 1e-06 8e-05 8 1e-06
# self.steps_to_restart = 8
# self.steps = -1
# self.initial_lr = 8e-05
# --------------------------------------------------
# 5) Creating trainer and validator engines ...
# binary_loss_kwargs: {'focal_weight': 1.0, 'bce_weight': 1.0, 'wbce_weight': 1.0}
# Focal_BCE_WBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 wbce_weight = 0.3333333333333333
# Focal_BCE_Loss(): focal_weight = 0.5 bce_weight = 0.5
# Focal_BCE_WBCBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 wbcbce_weight = 0.3333333333333333
# foreground_loss_weight: 1.5
# background_loss_weight: 1.0
# GradientAccumulator.__init__(): num_accumulation_steps = 10, max_grad_norm = None
# binary_loss_kwargs: {'focal_weight': 1.0, 'bce_weight': 1.0, 'wbce_weight': 1.0}
# Focal_BCE_WBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 wbce_weight = 0.3333333333333333
# Focal_BCE_Loss(): focal_weight = 0.5 bce_weight = 0.5
# Focal_BCE_WBCBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 wbcbce_weight = 0.3333333333333333
# foreground_loss_weight: 1.0
# background_loss_weight: 1.0
# --------------------------------------------------
# 6) Creating CheXLocalize Phrase Grounding Trainer ...
# get_image_transform()
# Using standard transform
# mean = (0.485, 0.456, 0.406), std = (0.229, 0.224, 0.225), image_size = [416, 416], use_center_crop = False
# Returning transform without augmentation
# get_image_transform()
# Using standard transform
# mean = (0.485, 0.456, 0.406), std = (0.229, 0.224, 0.225), image_size = [416, 416], use_center_crop = False
# Returning transform without augmentation
# Loding class_phrase_embeddings_filepath and bbox_phrases from /mnt/workspace/pamessina/medvqa-workspace/cache/chexlocalize/class_phrase_embeddings(hash=528,2353352898845085012).pkl...
# class_phrase_embeddings.shape = (10, 128)
# len(class_phrases) = 10
# 	 enlarged cardiomediastinum seen
# 	 cardiomegaly seen
# 	 lung lesion seen
# 	 airspace opacity seen
# 	 edema seen
# 	 consolidation seen
# 	 atelectasis seen
# 	 pneumothorax seen
# 	 pleural effusion seen
# 	 support devices seen
# Compute phrase grounding masks and labels
# Without masks: 216/902
# Generating train dataset and dataloader
# len(train_indices) = 902
# batch_size = 25
# Generating val dataset and dataloader
# len(val_indices) = 902
# batch_size = 50
# --------------------------------------------------
# 7) Creating VinBig Phrase Grounding Trainer ...
# get_image_transform()
# Using standard transform
# mean = (0.485, 0.456, 0.406), std = (0.229, 0.224, 0.225), image_size = [416, 416], use_center_crop = False
# Returning transform without augmentation
# get_image_transform()
# Using standard transform
# mean = (0.485, 0.456, 0.406), std = (0.229, 0.224, 0.225), image_size = [416, 416], use_center_crop = False
# Returning transform without augmentation
# Loading bounding boxes
# Anomalous bboxes found: 29 of 37367
# class_id_offset: 0
# Anomalous bboxes found: 0 of 2697
# class_id_offset: 0
#   Loaded 18000 bounding boxes
# Loding phrase_embeddings and phrases from /mnt/workspace/pamessina/medvqa-workspace/cache/vinbig/label_phrase_embeddings(hash=325,2238524744738711392).pkl...
# phrase_embeddings.shape = (28, 128)
# len(phrases) = 28
# 	 aortic enlargement seen
# 	 atelectasis seen
# 	 calcification seen
# 	 cardiomegaly seen
# 	 clavicle fracture seen
# 	 consolidation seen
# 	 edema seen
# 	 emphysema seen
# 	 enlarged pulmonary artery seen
# 	 interstitial lung disease seen
# 	 infiltration seen
# 	 lung opacity seen
# 	 lung cavity seen
# 	 lung cyst seen
# 	 mediastinal shift seen
# 	 nodule/mass seen
# 	 pleural effusion seen
# 	 pleural thickening seen
# 	 pneumothorax seen
# 	 pulmonary fibrosis seen
# 	 rib fracture seen
# 	 other lesion seen
# 	 copd seen
# 	 lung tumor seen
# 	 pneumonia seen
# 	 tuberculosis seen
# 	 other disease seen
# 	 no abnormalities seen
# Compute phrase grounding masks and labels
# self.phrase_grounding_masks.shape = (18000, 22, 169)
# self.phrase_classification_labels.shape = (18000, 22)
# Append additional labels to phrase_classification_labels
# len(non_bbox_labels) = 6
# non_bbox_labels = ['COPD', 'Lung tumor', 'Pneumonia', 'Tuberculosis', 'Other disease', 'No finding']
# self.phrase_classification_labels.shape = (18000, 28)
# Reorder phrases and phrase_embeddings
# len(phrases) = 28
# len(actual_phrases) = 28
# phrase_embeddings.shape = (28, 128)
# Generating train dataset and dataloader
# len(train_indices) = 18000
# No labels: 0
# Edema: 13
# Clavicle fracture: 29
# Lung cyst: 35
# COPD: 37
# Lung cavity: 60
# Emphysema: 84
# Rib fracture: 101
# Pneumothorax: 114
# Enlarged PA: 139
# Mediastinal shift: 170
# Atelectasis: 273
# Lung tumor: 371
# Consolidation: 449
# ILD: 618
# Calcification: 652
# Infiltration: 671
# Tuberculosis: 914
# Nodule/Mass: 1017
# Pleural effusion: 1149
# Pneumonia: 1163
# Other lesion: 1248
# Lung Opacity: 1415
# Pulmonary fibrosis: 1838
# Pleural thickening: 2179
# Cardiomegaly: 2625
# Aortic enlargement: 3318
# Other disease: 4945
# No finding: 12652
# Group sizes: [12529, 891, 444, 428, 364, 344, 307, 283, 273, 267, 245, 236, 206, 193, 170, 138, 127, 100, 99, 90, 56, 54, 49, 34, 73]
#   len(indices) = 12529, weight = 2522.6672479595745
#   len(indices) = 891, weight = 940.9850359649141
#   len(indices) = 444, weight = 680.1755171156125
#   len(indices) = 428, weight = 667.9638591411331
#   len(indices) = 364, weight = 615.8160380252455
#   len(indices) = 344, weight = 598.2811252947056
#   len(indices) = 307, weight = 563.9888635691133
#   len(indices) = 283, weight = 540.2796339164162
#   len(indices) = 273, weight = 530.0166624211873
#   len(indices) = 267, weight = 523.7422583945496
#   len(indices) = 245, weight = 499.93058392418243
#   len(indices) = 236, weight = 489.7963928535281
#   len(indices) = 206, weight = 454.1360559561945
#   len(indices) = 193, weight = 437.6702522239849
#   len(indices) = 170, weight = 406.7687016278156
#   len(indices) = 138, weight = 359.20170201154343
#   len(indices) = 127, weight = 341.33933626931963
#   len(indices) = 100, weight = 293.26529386579296
#   len(indices) = 99, weight = 291.34941227248714
#   len(indices) = 90, weight = 273.5936736738282
#   len(indices) = 56, weight = 195.85520038280242
#   len(indices) = 54, weight = 190.5945663000252
#   len(indices) = 49, weight = 177.00354049310113
#   len(indices) = 34, weight = 131.67512839151652
#   len(indices) = 73, weight = 237.15649291307946
# Generating val dataset and dataloader
# len(self.test_indices) = 3000
# --------------------------------------------------
# 8) Creating MIMIC-CXR Phrase Grounding Trainer ...
# get_image_transform()
# Using standard transform
# mean = (0.485, 0.456, 0.406), std = (0.229, 0.224, 0.225), image_size = [416, 416], use_center_crop = False
# Returning transform without augmentation
# get_image_transform()
# Using standard transform
# mean = (0.485, 0.456, 0.406), std = (0.229, 0.224, 0.225), image_size = [416, 416], use_center_crop = False
# Returning transform without augmentation
# mask_exponent = 0.4
# len(forbidden_train_dicom_ids) = 2030
# Preparing MS-CXR dataset and dataloader for training/testing...
# len(dicom_id_2_phrases_and_masks) = 1047
# len(phrase2embedding) = 715
# Using image size mode: medium_512
# 227835it [00:00, 433161.68it/s]
# Total number of images: 1047
# Number of phrases: 1, # images: 939
# Number of phrases: 2, # images: 103
# Number of phrases: 3, # images: 5
# Preparing Chest Imagenome dataset and dataloader for training...
# Loding bbox_phrase_embeddings and bbox_phrases from /mnt/workspace/pamessina/medvqa-workspace/cache/chest_imagenome/bbox_phrase_embeddings(hash=333,1643894111267724539).pkl...
# bbox_phrase_embeddings.shape = (36, 128)
# len(bbox_phrases) = 36
# 	 right lung
# 	 right upper lung zone
# 	 right mid lung zone
# 	 right lower lung zone
# 	 right hilar structures
# 	 right apical zone
# 	 right costophrenic angle
# 	 right cardiophrenic angle
# 	 right hemidiaphragm
# 	 left lung
# 	 left upper lung zone
# 	 left mid lung zone
# 	 left lower lung zone
# 	 left hilar structures
# 	 left apical zone
# 	 left costophrenic angle
# 	 left hemidiaphragm
# 	 trachea
# 	 spine
# 	 right clavicle
# 	 left clavicle
# 	 aortic arch
# 	 mediastinum
# 	 upper mediastinum
# 	 svc
# 	 cardiac silhouette
# 	 left cardiac silhouette
# 	 right cardiac silhouette
# 	 cavoatrial junction
# 	 right atrium
# 	 descending aorta
# 	 carina
# 	 left upper abdomen
# 	 right upper abdomen
# 	 abdomen
# 	 left cardiophrenic angle
# Using image size mode: medium_512
# Loading precomputed bbox_coords_and_presence_and_mask from /mnt/workspace/pamessina/medvqa-workspace/cache/mimiccxr/bbox_coords_and_presence_and_mask(13,13,243310).pkl...
# 227835it [00:29, 7811.32it/s]
# Total number of images: 241280
# Preparing Chest Imagenome dataset and dataloader for testing...
# Loding bbox_phrase_embeddings and bbox_phrases from /mnt/workspace/pamessina/medvqa-workspace/cache/chest_imagenome/bbox_phrase_embeddings(hash=333,1643894111267724539).pkl...
# bbox_phrase_embeddings.shape = (26, 128)
# len(bbox_phrases) = 26
# 	 right lung
# 	 right upper lung zone
# 	 right mid lung zone
# 	 right lower lung zone
# 	 right hilar structures
# 	 right apical zone
# 	 right costophrenic angle
# 	 right hemidiaphragm
# 	 left lung
# 	 left upper lung zone
# 	 left mid lung zone
# 	 left lower lung zone
# 	 left hilar structures
# 	 left apical zone
# 	 left costophrenic angle
# 	 left hemidiaphragm
# 	 trachea
# 	 right clavicle
# 	 left clavicle
# 	 aortic arch
# 	 upper mediastinum
# 	 svc
# 	 cardiac silhouette
# 	 cavoatrial junction
# 	 right atrium
# 	 carina
# Using image size mode: medium_512
# 227835it [00:02, 94676.26it/s]
# Total number of images: 1000
# --------------------------------------------------
# 9) Creating dataloaders ...
# len(mimiccxr_trainer.train_mscxr_dataloader) = 44
# len(mimiccxr_trainer.test_mscxr_dataloader) = 23
# len(mimiccxr_trainer.train_chest_imagenome_dataloader) = 21935
# len(mimiccxr_trainer.test_chest_imagenome_gold_dataloader) = 34
# len(vinbig_trainer.train_dataloader) = 71428571428571429
# len(vinbig_trainer.val_dataloader) = 108
# len(chexlocalize_trainer.train_dataloader) = 37
# len(chexlocalize_trainer.val_dataloader) = 19
# len(_train_dataloaders) = 4
# len(_val_dataloaders) = 4
# _train_weights = [0.5, 1.0, 1.3, 0.5]
# merged_dataset_name = mscxr+chst-img-anat+vinbig+chexloc
# --------------------------------------------------
# 10) Attaching metrics, losses, timer and events to engines ...
# --------------------------------------------------
# 11) Defining learning rate scheduler handler ...
# --------------------------------------------------
# 12) Defining learning rate scheduler handler ...
# --------------------------------------------------
# 13) Defining checkpoint folder path ...
# checkpoint_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240709_154812_mscxr+chst-img-anat+vinbig+chexloc_PhraseGrounder(dn121,FiLM_SigmoidAttention,128,256,256,256,1,256-128)
# metadata saved to /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240709_154812_mscxr+chst-img-anat+vinbig+chexloc_PhraseGrounder(dn121,FiLM_SigmoidAttention,128,256,256,256,1,256-128)/metadata.json
# --------------------------------------------------
# 14) Loading pretrained weights ...
# checkpoint_names = ['checkpoint_98_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.7372.pt']
# pretrained_checkpoint_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240705_131322_mscxr+chst-img-anat+vinbig+chexloc_PhraseGrounder(dn121,FiLM_SigmoidAttention,128,256,256,256,1,256-128)/checkpoint_98_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.7372.pt
# Checkpoint successfully loaded!
# --------------------------------------------------
# 15) Defining log_metrics_handler ...
# MetricsLogger :: we'll be logging to /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240709_154812_mscxr+chst-img-anat+vinbig+chexloc_PhraseGrounder(dn121,FiLM_SigmoidAttention,128,256,256,256,1,256-128)/metrics_logs.csv
# --------------------------------------------------
# 16) Running trainer engine ...
# ---- Epoch 1/100
# (1) Training stage (lr = 0.000001) ...
# loss 0.37893, cibg_att_sup_loss 0.42094, cibg_segmask_iou 0.59406, pg_att_sup_loss 0.20230, pg_segmask_iou 0.78911, vbg_phrcls_loss 0.02606, vbg_prc_auc 0.99972, vbg_att_reg_loss 0.09007, vbg_att_sup_loss 0.39881, vbg_segmask_iou 0.38941, cl_att_sup_loss 0.11591, cl_segmask_iou 0.58986, cl_phrcls_loss 0.00149, cl_phrase_acc 1.00000, 144.34 secs
# (2) Validation stage ...
# cibg_att_sup_loss 0.31678, cibg_segmask_iou 0.37510, pg_att_sup_loss 0.17753, pg_segmask_iou 0.61533, vbg_prc_auc 0.94681, vbg_att_sup_loss 0.07790, vbg_segmask_iou 0.29339, cl_att_sup_loss 0.14313, cl_segmask_iou 0.57006, cl_phrase_acc 0.99778, 36.34 secs
# New checkpoint saved: checkpoint_1_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.7240.pt
# ---- Epoch 2/100
# (1) Training stage (lr = 0.000004) ...
# loss 0.38072, cibg_att_sup_loss 0.42190, cibg_segmask_iou 0.59369, pg_att_sup_loss 0.20289, pg_segmask_iou 0.79095, vbg_phrcls_loss 0.02517, vbg_prc_auc 0.99981, vbg_att_reg_loss 0.09031, vbg_att_sup_loss 0.40196, vbg_segmask_iou 0.39077, cl_att_sup_loss 0.11663, cl_segmask_iou 0.58893, cl_phrcls_loss 0.00357, cl_phrase_acc 0.99992, 138.54 secs
# (2) Validation stage ...
# cibg_att_sup_loss 0.31471, cibg_segmask_iou 0.37764, pg_att_sup_loss 0.17701, pg_segmask_iou 0.61566, vbg_prc_auc 0.95112, vbg_att_sup_loss 0.07727, vbg_segmask_iou 0.29497, cl_att_sup_loss 0.15415, cl_segmask_iou 0.56360, cl_phrase_acc 0.99678, 38.00 secs
# ---- Epoch 3/100
# (1) Training stage (lr = 0.000019) ...
# loss 0.37648, cibg_att_sup_loss 0.41808, cibg_segmask_iou 0.59546, pg_att_sup_loss 0.20265, pg_segmask_iou 0.78734, vbg_phrcls_loss 0.02651, vbg_prc_auc 0.99971, vbg_att_reg_loss 0.09073, vbg_att_sup_loss 0.39385, vbg_segmask_iou 0.39263, cl_att_sup_loss 0.11583, cl_segmask_iou 0.58999, cl_phrcls_loss 0.00078, cl_phrase_acc 1.00000, 143.01 secs
# (2) Validation stage ...
# cibg_att_sup_loss 0.33388, cibg_segmask_iou 0.35940, pg_att_sup_loss 0.17810, pg_segmask_iou 0.61379, vbg_prc_auc 0.94691, vbg_att_sup_loss 0.07467, vbg_segmask_iou 0.30099, cl_att_sup_loss 0.15668, cl_segmask_iou 0.56855, cl_phrase_acc 0.99767, 40.43 secs
# ---- Epoch 4/100
# (1) Training stage (lr = 0.000080) ...
# loss 0.46413, cibg_att_sup_loss 0.42276, cibg_segmask_iou 0.59209, pg_att_sup_loss 0.25520, pg_segmask_iou 0.76656, vbg_phrcls_loss 0.16300, vbg_prc_auc 0.99587, vbg_att_reg_loss 0.09843, vbg_att_sup_loss 0.44394, vbg_segmask_iou 0.37642, cl_att_sup_loss 0.12315, cl_segmask_iou 0.58858, cl_phrcls_loss 0.00447, cl_phrase_acc 0.99973, 139.94 secs
# (2) Validation stage ...
# cibg_att_sup_loss 0.33428, cibg_segmask_iou 0.34688, pg_att_sup_loss 0.19469, pg_segmask_iou 0.58552, vbg_prc_auc 0.93846, vbg_att_sup_loss 0.07837, vbg_segmask_iou 0.29645, cl_att_sup_loss 0.18159, cl_segmask_iou 0.54819, cl_phrase_acc 0.99412, 41.67 secs
# ---- Epoch 5/100
# (1) Training stage (lr = 0.000046) ...
# loss 0.47702, cibg_att_sup_loss 0.42236, cibg_segmask_iou 0.59114, pg_att_sup_loss 0.26270, pg_segmask_iou 0.75940, vbg_phrcls_loss 0.18432, vbg_prc_auc 0.99517, vbg_att_reg_loss 0.09522, vbg_att_sup_loss 0.45329, vbg_segmask_iou 0.36653, cl_att_sup_loss 0.12999, cl_segmask_iou 0.58127, cl_phrcls_loss 0.00750, cl_phrase_acc 0.99950, 144.50 secs
# (2) Validation stage ...
# cibg_att_sup_loss 0.29908, cibg_segmask_iou 0.39545, pg_att_sup_loss 0.17585, pg_segmask_iou 0.61907, vbg_prc_auc 0.89757, vbg_att_sup_loss 0.08262, vbg_segmask_iou 0.28460, cl_att_sup_loss 0.16694, cl_segmask_iou 0.55570, cl_phrase_acc 0.99479, 42.36 secs
# ---- Epoch 6/100
# (1) Training stage (lr = 0.000027) ...
# loss 0.42689, cibg_att_sup_loss 0.42386, cibg_segmask_iou 0.59172, pg_att_sup_loss 0.22654, pg_segmask_iou 0.77782, vbg_phrcls_loss 0.10016, vbg_prc_auc 0.99836, vbg_att_reg_loss 0.09199, vbg_att_sup_loss 0.42953, vbg_segmask_iou 0.37613, cl_att_sup_loss 0.12400, cl_segmask_iou 0.58258, cl_phrcls_loss 0.00210, cl_phrase_acc 0.99996, 141.34 secs
# (2) Validation stage ...
# cibg_att_sup_loss 0.29408, cibg_segmask_iou 0.39836, pg_att_sup_loss 0.17489, pg_segmask_iou 0.62043, vbg_prc_auc 0.95240, vbg_att_sup_loss 0.07848, vbg_segmask_iou 0.29149, cl_att_sup_loss 0.16376, cl_segmask_iou 0.56172, cl_phrase_acc 0.99512, 43.40 secs
# New checkpoint saved: checkpoint_6_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.7250.pt
# ---- Epoch 7/100
# (1) Training stage (lr = 0.000015) ...
# loss 0.39568, cibg_att_sup_loss 0.42747, cibg_segmask_iou 0.59303, pg_att_sup_loss 0.21135, pg_segmask_iou 0.78560, vbg_phrcls_loss 0.04522, vbg_prc_auc 0.99972, vbg_att_reg_loss 0.08847, vbg_att_sup_loss 0.40982, vbg_segmask_iou 0.38783, cl_att_sup_loss 0.12198, cl_segmask_iou 0.58624, cl_phrcls_loss 0.00957, cl_phrase_acc 0.99996, 141.23 secs
# (2) Validation stage ...
# cibg_att_sup_loss 0.31989, cibg_segmask_iou 0.37095, pg_att_sup_loss 0.17730, pg_segmask_iou 0.61426, vbg_prc_auc 0.95848, vbg_att_sup_loss 0.07406, vbg_segmask_iou 0.30106, cl_att_sup_loss 0.16967, cl_segmask_iou 0.55991, cl_phrase_acc 0.99645, 47.42 secs
# ---- Epoch 8/100
# (1) Training stage (lr = 0.000009) ...
# loss 0.38168, cibg_att_sup_loss 0.42043, cibg_segmask_iou 0.59719, pg_att_sup_loss 0.20655, pg_segmask_iou 0.78486, vbg_phrcls_loss 0.03519, vbg_prc_auc 0.99975, vbg_att_reg_loss 0.08722, vbg_att_sup_loss 0.39941, vbg_segmask_iou 0.38974, cl_att_sup_loss 0.11237, cl_segmask_iou 0.58722, cl_phrcls_loss 0.00204, cl_phrase_acc 1.00000, 146.54 secs
# (2) Validation stage ...
# cibg_att_sup_loss 0.33231, cibg_segmask_iou 0.35816, pg_att_sup_loss 0.18009, pg_segmask_iou 0.60946, vbg_prc_auc 0.97076, vbg_att_sup_loss 0.07174, vbg_segmask_iou 0.30774, cl_att_sup_loss 0.16486, cl_segmask_iou 0.56509, cl_phrase_acc 0.99678, 51.83 secs
# ---- Epoch 9/100
# (1) Training stage (lr = 0.000005) ...
# loss 0.37562, cibg_att_sup_loss 0.42107, cibg_segmask_iou 0.59875, pg_att_sup_loss 0.19997, pg_segmask_iou 0.79415, vbg_phrcls_loss 0.02772, vbg_prc_auc 0.99981, vbg_att_reg_loss 0.08670, vbg_att_sup_loss 0.39477, vbg_segmask_iou 0.39397, cl_att_sup_loss 0.11270, cl_segmask_iou 0.58948, cl_phrcls_loss 0.00283, cl_phrase_acc 0.99996, 146.11 secs
# (2) Validation stage ...
# cibg_att_sup_loss 0.28531, cibg_segmask_iou 0.40761, pg_att_sup_loss 0.16590, pg_segmask_iou 0.63446, vbg_prc_auc 0.93715, vbg_att_sup_loss 0.07709, vbg_segmask_iou 0.29587, cl_att_sup_loss 0.18035, cl_segmask_iou 0.56045, cl_phrase_acc 0.99678, 53.69 secs
# New checkpoint saved: checkpoint_9_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.7272.pt
# ---- Epoch 10/100
# (1) Training stage (lr = 0.000003) ...
# loss 0.37518, cibg_att_sup_loss 0.41689, cibg_segmask_iou 0.59848, pg_att_sup_loss 0.20006, pg_segmask_iou 0.78919, vbg_phrcls_loss 0.02273, vbg_prc_auc 0.99995, vbg_att_reg_loss 0.08690, vbg_att_sup_loss 0.39298, vbg_segmask_iou 0.39086, cl_att_sup_loss 0.11443, cl_segmask_iou 0.59090, cl_phrcls_loss 0.02064, cl_phrase_acc 0.99996, 150.48 secs
# (2) Validation stage ...
# cibg_att_sup_loss 0.29921, cibg_segmask_iou 0.39235, pg_att_sup_loss 0.17340, pg_segmask_iou 0.62054, vbg_prc_auc 0.94511, vbg_att_sup_loss 0.07754, vbg_segmask_iou 0.29402, cl_att_sup_loss 0.17216, cl_segmask_iou 0.55917, cl_phrase_acc 0.99667, 53.15 secs
# ---- Epoch 11/100
# (1) Training stage (lr = 0.000002) ...
# loss 0.36898, cibg_att_sup_loss 0.41381, cibg_segmask_iou 0.60138, pg_att_sup_loss 0.19244, pg_segmask_iou 0.79527, vbg_phrcls_loss 0.02243, vbg_prc_auc 0.99994, vbg_att_reg_loss 0.08517, vbg_att_sup_loss 0.39378, vbg_segmask_iou 0.39629, cl_att_sup_loss 0.11018, cl_segmask_iou 0.59393, cl_phrcls_loss 0.00090, cl_phrase_acc 1.00000, 148.25 secs
# (2) Validation stage ...
# cibg_att_sup_loss 0.31375, cibg_segmask_iou 0.37682, pg_att_sup_loss 0.17737, pg_segmask_iou 0.61523, vbg_prc_auc 0.96128, vbg_att_sup_loss 0.07505, vbg_segmask_iou 0.29978, cl_att_sup_loss 0.16706, cl_segmask_iou 0.56210, cl_phrase_acc 0.99645, 52.43 secs
# ---- Epoch 12/100
# (1) Training stage (lr = 0.000001) ...
# loss 0.36930, cibg_att_sup_loss 0.41885, cibg_segmask_iou 0.59870, pg_att_sup_loss 0.20194, pg_segmask_iou 0.79172, vbg_phrcls_loss 0.02147, vbg_prc_auc 0.99994, vbg_att_reg_loss 0.08703, vbg_att_sup_loss 0.38690, vbg_segmask_iou 0.39193, cl_att_sup_loss 0.10852, cl_segmask_iou 0.59222, cl_phrcls_loss 0.00069, cl_phrase_acc 1.00000, 152.60 secs
# (2) Validation stage ...
# cibg_att_sup_loss 0.31923, cibg_segmask_iou 0.37219, pg_att_sup_loss 0.17521, pg_segmask_iou 0.61986, vbg_prc_auc 0.96368, vbg_att_sup_loss 0.07283, vbg_segmask_iou 0.30600, cl_att_sup_loss 0.17175, cl_segmask_iou 0.56609, cl_phrase_acc 0.99667, 53.16 secs
# ---- Epoch 13/100
# (1) Training stage (lr = 0.000080) ...
# loss 0.41236, cibg_att_sup_loss 0.41816, cibg_segmask_iou 0.59638, pg_att_sup_loss 0.23362, pg_segmask_iou 0.77551, vbg_phrcls_loss 0.07711, vbg_prc_auc 0.99904, vbg_att_reg_loss 0.08989, vbg_att_sup_loss 0.42184, vbg_segmask_iou 0.38608, cl_att_sup_loss 0.11682, cl_segmask_iou 0.59081, cl_phrcls_loss 0.00476, cl_phrase_acc 0.99985, 153.65 secs
# (2) Validation stage ...
# cibg_att_sup_loss 0.28648, cibg_segmask_iou 0.40489, pg_att_sup_loss 0.17507, pg_segmask_iou 0.61465, vbg_prc_auc 0.91290, vbg_att_sup_loss 0.08208, vbg_segmask_iou 0.28526, cl_att_sup_loss 0.18983, cl_segmask_iou 0.54731, cl_phrase_acc 0.99324, 55.85 secs
# ---- Epoch 14/100
# (1) Training stage (lr = 0.000043) ...
# loss 0.42987, cibg_att_sup_loss 0.42217, cibg_segmask_iou 0.59501, pg_att_sup_loss 0.23637, pg_segmask_iou 0.77391, vbg_phrcls_loss 0.10314, vbg_prc_auc 0.99819, vbg_att_reg_loss 0.08987, vbg_att_sup_loss 0.42623, vbg_segmask_iou 0.37932, cl_att_sup_loss 0.13160, cl_segmask_iou 0.58251, cl_phrcls_loss 0.01412, cl_phrase_acc 0.99957, 152.09 secs
# (2) Validation stage ...
# cibg_att_sup_loss 0.27754, cibg_segmask_iou 0.41382, pg_att_sup_loss 0.16683, pg_segmask_iou 0.62505, vbg_prc_auc 0.94328, vbg_att_sup_loss 0.07881, vbg_segmask_iou 0.29024, cl_att_sup_loss 0.18445, cl_segmask_iou 0.54563, cl_phrase_acc 0.99324, 56.50 secs
# ---- Epoch 15/100
# (1) Training stage (lr = 0.000023) ...
# loss 0.39701, cibg_att_sup_loss 0.41883, cibg_segmask_iou 0.59591, pg_att_sup_loss 0.22129, pg_segmask_iou 0.78081, vbg_phrcls_loss 0.06024, vbg_prc_auc 0.99922, vbg_att_reg_loss 0.08434, vbg_att_sup_loss 0.40567, vbg_segmask_iou 0.38794, cl_att_sup_loss 0.11924, cl_segmask_iou 0.58553, cl_phrcls_loss 0.01090, cl_phrase_acc 0.99946, 153.34 secs
# (2) Validation stage ...
# cibg_att_sup_loss 0.29465, cibg_segmask_iou 0.39767, pg_att_sup_loss 0.16990, pg_segmask_iou 0.62235, vbg_prc_auc 0.94522, vbg_att_sup_loss 0.07592, vbg_segmask_iou 0.29695, cl_att_sup_loss 0.18095, cl_segmask_iou 0.55494, cl_phrase_acc 0.99468, 57.10 secs
# ---- Epoch 16/100
# (1) Training stage (lr = 0.000012) ...
# loss 0.37374, cibg_att_sup_loss 0.41809, cibg_segmask_iou 0.59966, pg_att_sup_loss 0.19725, pg_segmask_iou 0.79284, vbg_phrcls_loss 0.02929, vbg_prc_auc 0.99981, vbg_att_reg_loss 0.08284, vbg_att_sup_loss 0.39238, vbg_segmask_iou 0.39330, cl_att_sup_loss 0.11613, cl_segmask_iou 0.58709, cl_phrcls_loss 0.00490, cl_phrase_acc 0.99988, 154.12 secs
# (2) Validation stage ...
# cibg_att_sup_loss 0.30306, cibg_segmask_iou 0.38776, pg_att_sup_loss 0.17227, pg_segmask_iou 0.61986, vbg_prc_auc 0.96869, vbg_att_sup_loss 0.07353, vbg_segmask_iou 0.30348, cl_att_sup_loss 0.16587, cl_segmask_iou 0.56535, cl_phrase_acc 0.99712, 57.09 secs
# New checkpoint saved: checkpoint_16_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.7279.pt
# ---- Epoch 17/100
# (1) Training stage (lr = 0.000007) ...
# loss 0.36407, cibg_att_sup_loss 0.41353, cibg_segmask_iou 0.59948, pg_att_sup_loss 0.19909, pg_segmask_iou 0.79051, vbg_phrcls_loss 0.02270, vbg_prc_auc 0.99986, vbg_att_reg_loss 0.08230, vbg_att_sup_loss 0.38408, vbg_segmask_iou 0.39521, cl_att_sup_loss 0.10720, cl_segmask_iou 0.59083, cl_phrcls_loss 0.00100, cl_phrase_acc 0.99996, 156.94 secs
# (2) Validation stage ...
# cibg_att_sup_loss 0.31227, cibg_segmask_iou 0.38477, pg_att_sup_loss 0.16969, pg_segmask_iou 0.62724, vbg_prc_auc 0.95676, vbg_att_sup_loss 0.07313, vbg_segmask_iou 0.30677, cl_att_sup_loss 0.15535, cl_segmask_iou 0.57525, cl_phrase_acc 0.99800, 58.56 secs
# New checkpoint saved: checkpoint_17_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.7291.pt
# ---- Epoch 18/100
# (1) Training stage (lr = 0.000003) ...
# loss 0.36187, cibg_att_sup_loss 0.41716, cibg_segmask_iou 0.60184, pg_att_sup_loss 0.18997, pg_segmask_iou 0.79744, vbg_phrcls_loss 0.01731, vbg_prc_auc 0.99994, vbg_att_reg_loss 0.08157, vbg_att_sup_loss 0.38321, vbg_segmask_iou 0.39737, cl_att_sup_loss 0.10925, cl_segmask_iou 0.59028, cl_phrcls_loss 0.00094, cl_phrase_acc 0.99996, 156.02 secs
# (2) Validation stage ...
# cibg_att_sup_loss 0.31961, cibg_segmask_iou 0.37426, pg_att_sup_loss 0.17729, pg_segmask_iou 0.61249, vbg_prc_auc 0.95991, vbg_att_sup_loss 0.07421, vbg_segmask_iou 0.30082, cl_att_sup_loss 0.15126, cl_segmask_iou 0.56979, cl_phrase_acc 0.99756, 57.33 secs
# ---- Epoch 19/100
# (1) Training stage (lr = 0.000002) ...
# loss 0.35982, cibg_att_sup_loss 0.41450, cibg_segmask_iou 0.60033, pg_att_sup_loss 0.18996, pg_segmask_iou 0.79839, vbg_phrcls_loss 0.01707, vbg_prc_auc 0.99993, vbg_att_reg_loss 0.08217, vbg_att_sup_loss 0.37924, vbg_segmask_iou 0.39537, cl_att_sup_loss 0.10914, cl_segmask_iou 0.59396, cl_phrcls_loss 0.00220, cl_phrase_acc 0.99996, 154.17 secs
# (2) Validation stage ...
# cibg_att_sup_loss 0.32968, cibg_segmask_iou 0.36477, pg_att_sup_loss 0.17765, pg_segmask_iou 0.61249, vbg_prc_auc 0.96978, vbg_att_sup_loss 0.07188, vbg_segmask_iou 0.30705, cl_att_sup_loss 0.15154, cl_segmask_iou 0.57128, cl_phrase_acc 0.99712, 59.20 secs
# ---- Epoch 20/100
# (1) Training stage (lr = 0.000001) ...
# loss 0.35940, cibg_att_sup_loss 0.41403, cibg_segmask_iou 0.60205, pg_att_sup_loss 0.19204, pg_segmask_iou 0.79405, vbg_phrcls_loss 0.01549, vbg_prc_auc 0.99997, vbg_att_reg_loss 0.08087, vbg_att_sup_loss 0.38100, vbg_segmask_iou 0.39962, cl_att_sup_loss 0.10954, cl_segmask_iou 0.59265, cl_phrcls_loss 0.00083, cl_phrase_acc 1.00000, 155.05 secs
# (2) Validation stage ...
# cibg_att_sup_loss 0.34138, cibg_segmask_iou 0.35178, pg_att_sup_loss 0.18069, pg_segmask_iou 0.60607, vbg_prc_auc 0.97546, vbg_att_sup_loss 0.07085, vbg_segmask_iou 0.30819, cl_att_sup_loss 0.15197, cl_segmask_iou 0.56947, cl_phrase_acc 0.99756, 58.47 secs
# ---- Epoch 21/100
# (1) Training stage (lr = 0.000080) ...
# loss 0.39003, cibg_att_sup_loss 0.41927, cibg_segmask_iou 0.59966, pg_att_sup_loss 0.22686, pg_segmask_iou 0.78244, vbg_phrcls_loss 0.04665, vbg_prc_auc 0.99960, vbg_att_reg_loss 0.08524, vbg_att_sup_loss 0.40151, vbg_segmask_iou 0.38914, cl_att_sup_loss 0.12027, cl_segmask_iou 0.59214, cl_phrcls_loss 0.00224, cl_phrase_acc 0.99996, 156.39 secs
# (2) Validation stage ...
# cibg_att_sup_loss 0.30291, cibg_segmask_iou 0.38567, pg_att_sup_loss 0.17583, pg_segmask_iou 0.61300, vbg_prc_auc 0.94921, vbg_att_sup_loss 0.07427, vbg_segmask_iou 0.30307, cl_att_sup_loss 0.18869, cl_segmask_iou 0.55400, cl_phrase_acc 0.98891, 58.55 secs
# ---- Epoch 22/100
# (1) Training stage (lr = 0.000043) ...
# loss 0.40199, cibg_att_sup_loss 0.41919, cibg_segmask_iou 0.59862, pg_att_sup_loss 0.23263, pg_segmask_iou 0.77727, vbg_phrcls_loss 0.06665, vbg_prc_auc 0.99920, vbg_att_reg_loss 0.08396, vbg_att_sup_loss 0.40672, vbg_segmask_iou 0.38980, cl_att_sup_loss 0.11725, cl_segmask_iou 0.58798, cl_phrcls_loss 0.01523, cl_phrase_acc 0.99973, 160.07 secs
# (2) Validation stage ...
# cibg_att_sup_loss 0.30619, cibg_segmask_iou 0.38443, pg_att_sup_loss 0.17555, pg_segmask_iou 0.61713, vbg_prc_auc 0.95998, vbg_att_sup_loss 0.07508, vbg_segmask_iou 0.29861, cl_att_sup_loss 0.16158, cl_segmask_iou 0.55891, cl_phrase_acc 0.99401, 60.30 secs
# ---- Epoch 23/100
# (1) Training stage (lr = 0.000023) ...
# loss 0.38688, cibg_att_sup_loss 0.41223, cibg_segmask_iou 0.60285, pg_att_sup_loss 0.20586, pg_segmask_iou 0.78959, vbg_phrcls_loss 0.05804, vbg_prc_auc 0.99926, vbg_att_reg_loss 0.08267, vbg_att_sup_loss 0.39287, vbg_segmask_iou 0.39049, cl_att_sup_loss 0.11307, cl_segmask_iou 0.58861, cl_phrcls_loss 0.02217, cl_phrase_acc 0.99946, 156.14 secs
# (2) Validation stage ...
# cibg_att_sup_loss 0.29499, cibg_segmask_iou 0.39218, pg_att_sup_loss 0.17450, pg_segmask_iou 0.61468, vbg_prc_auc 0.96354, vbg_att_sup_loss 0.07586, vbg_segmask_iou 0.29279, cl_att_sup_loss 0.16010, cl_segmask_iou 0.55311, cl_phrase_acc 0.99534, 63.22 secs
# ---- Epoch 24/100
# (1) Training stage (lr = 0.000012) ...
# loss 0.36963, cibg_att_sup_loss 0.41374, cibg_segmask_iou 0.60173, pg_att_sup_loss 0.20218, pg_segmask_iou 0.79361, vbg_phrcls_loss 0.03166, vbg_prc_auc 0.99970, vbg_att_reg_loss 0.07792, vbg_att_sup_loss 0.38177, vbg_segmask_iou 0.39656, cl_att_sup_loss 0.12188, cl_segmask_iou 0.59164, cl_phrcls_loss 0.01007, cl_phrase_acc 0.99985, 157.50 secs
# (2) Validation stage ...
# cibg_att_sup_loss 0.32943, cibg_segmask_iou 0.35516, pg_att_sup_loss 0.18095, pg_segmask_iou 0.60725, vbg_prc_auc 0.97324, vbg_att_sup_loss 0.07258, vbg_segmask_iou 0.30288, cl_att_sup_loss 0.17164, cl_segmask_iou 0.55862, cl_phrase_acc 0.99302, 61.94 secs
# ---- Epoch 25/100
# (1) Training stage (lr = 0.000007) ...
# loss 0.35461, cibg_att_sup_loss 0.41017, cibg_segmask_iou 0.60474, pg_att_sup_loss 0.19378, pg_segmask_iou 0.79441, vbg_phrcls_loss 0.01767, vbg_prc_auc 0.99992, vbg_att_reg_loss 0.07759, vbg_att_sup_loss 0.37224, vbg_segmask_iou 0.39572, cl_att_sup_loss 0.11013, cl_segmask_iou 0.59611, cl_phrcls_loss 0.00287, cl_phrase_acc 0.99996, 163.92 secs
# (2) Validation stage ...
# cibg_att_sup_loss 0.28960, cibg_segmask_iou 0.39746, pg_att_sup_loss 0.16818, pg_segmask_iou 0.62687, vbg_prc_auc 0.94246, vbg_att_sup_loss 0.07615, vbg_segmask_iou 0.29501, cl_att_sup_loss 0.17309, cl_segmask_iou 0.56015, cl_phrase_acc 0.99523, 62.07 secs
# ---- Epoch 26/100
# (1) Training stage (lr = 0.000003) ...
# loss 0.35149, cibg_att_sup_loss 0.41261, cibg_segmask_iou 0.60264, pg_att_sup_loss 0.18502, pg_segmask_iou 0.80258, vbg_phrcls_loss 0.01593, vbg_prc_auc 0.99992, vbg_att_reg_loss 0.07600, vbg_att_sup_loss 0.36848, vbg_segmask_iou 0.39966, cl_att_sup_loss 0.11057, cl_segmask_iou 0.59910, cl_phrcls_loss 0.00156, cl_phrase_acc 1.00000, 152.25 secs
# (2) Validation stage ...
# cibg_att_sup_loss 0.29270, cibg_segmask_iou 0.39194, pg_att_sup_loss 0.17073, pg_segmask_iou 0.62177, vbg_prc_auc 0.95435, vbg_att_sup_loss 0.07580, vbg_segmask_iou 0.29466, cl_att_sup_loss 0.17511, cl_segmask_iou 0.55612, cl_phrase_acc 0.99501, 54.97 secs
# ---- Epoch 27/100
# (1) Training stage (lr = 0.000002) ...
# loss 0.35001, cibg_att_sup_loss 0.40869, cibg_segmask_iou 0.60596, pg_att_sup_loss 0.18509, pg_segmask_iou 0.79774, vbg_phrcls_loss 0.01436, vbg_prc_auc 0.99994, vbg_att_reg_loss 0.07717, vbg_att_sup_loss 0.37088, vbg_segmask_iou 0.39859, cl_att_sup_loss 0.10430, cl_segmask_iou 0.59690, cl_phrcls_loss 0.00058, cl_phrase_acc 0.99996, 149.91 secs
# (2) Validation stage ...
# cibg_att_sup_loss 0.30496, cibg_segmask_iou 0.38099, pg_att_sup_loss 0.17216, pg_segmask_iou 0.62003, vbg_prc_auc 0.96346, vbg_att_sup_loss 0.07345, vbg_segmask_iou 0.30086, cl_att_sup_loss 0.17356, cl_segmask_iou 0.55713, cl_phrase_acc 0.99512, 50.44 secs
# ---- Epoch 28/100
# (1) Training stage (lr = 0.000001) ...
# loss 0.34799, cibg_att_sup_loss 0.40520, cibg_segmask_iou 0.60652, pg_att_sup_loss 0.18189, pg_segmask_iou 0.80383, vbg_phrcls_loss 0.01342, vbg_prc_auc 0.99993, vbg_att_reg_loss 0.07663, vbg_att_sup_loss 0.36887, vbg_segmask_iou 0.40006, cl_att_sup_loss 0.10987, cl_segmask_iou 0.59565, cl_phrcls_loss 0.00097, cl_phrase_acc 0.99996, 147.58 secs
# (2) Validation stage ...
# cibg_att_sup_loss 0.30934, cibg_segmask_iou 0.37764, pg_att_sup_loss 0.17169, pg_segmask_iou 0.62166, vbg_prc_auc 0.96860, vbg_att_sup_loss 0.07274, vbg_segmask_iou 0.30326, cl_att_sup_loss 0.17519, cl_segmask_iou 0.56015, cl_phrase_acc 0.99512, 54.64 secs
# ---- Epoch 29/100
# (1) Training stage (lr = 0.000080) ...
# loss 0.37329, cibg_att_sup_loss 0.41489, cibg_segmask_iou 0.60297, pg_att_sup_loss 0.21519, pg_segmask_iou 0.78824, vbg_phrcls_loss 0.03806, vbg_prc_auc 0.99964, vbg_att_reg_loss 0.08138, vbg_att_sup_loss 0.38453, vbg_segmask_iou 0.39383, cl_att_sup_loss 0.10816, cl_segmask_iou 0.59655, cl_phrcls_loss 0.00062, cl_phrase_acc 1.00000, 152.18 secs
# (2) Validation stage ...
# cibg_att_sup_loss 0.25021, cibg_segmask_iou 0.44530, pg_att_sup_loss 0.16513, pg_segmask_iou 0.63784, vbg_prc_auc 0.90098, vbg_att_sup_loss 0.08346, vbg_segmask_iou 0.28008, cl_att_sup_loss 0.19138, cl_segmask_iou 0.54842, cl_phrase_acc 0.99279, 55.06 secs
# ---- Epoch 30/100
# (1) Training stage (lr = 0.000043) ...
# loss 0.38234, cibg_att_sup_loss 0.40816, cibg_segmask_iou 0.60625, pg_att_sup_loss 0.21962, pg_segmask_iou 0.78618, vbg_phrcls_loss 0.05150, vbg_prc_auc 0.99948, vbg_att_reg_loss 0.07986, vbg_att_sup_loss 0.39682, vbg_segmask_iou 0.39124, cl_att_sup_loss 0.10888, cl_segmask_iou 0.59502, cl_phrcls_loss 0.00478, cl_phrase_acc 0.99973, 156.64 secs
# (2) Validation stage ...
# cibg_att_sup_loss 0.27818, cibg_segmask_iou 0.41204, pg_att_sup_loss 0.16895, pg_segmask_iou 0.62722, vbg_prc_auc 0.90909, vbg_att_sup_loss 0.07952, vbg_segmask_iou 0.29120, cl_att_sup_loss 0.18280, cl_segmask_iou 0.55310, cl_phrase_acc 0.99501, 57.77 secs
# ---- Epoch 31/100
# (1) Training stage (lr = 0.000023) ...
# loss 0.36498, cibg_att_sup_loss 0.41474, cibg_segmask_iou 0.60497, pg_att_sup_loss 0.19947, pg_segmask_iou 0.79799, vbg_phrcls_loss 0.03296, vbg_prc_auc 0.99981, vbg_att_reg_loss 0.07566, vbg_att_sup_loss 0.37959, vbg_segmask_iou 0.39529, cl_att_sup_loss 0.10893, cl_segmask_iou 0.59517, cl_phrcls_loss 0.00117, cl_phrase_acc 0.99996, 154.77 secs
# (2) Validation stage ...
# cibg_att_sup_loss 0.29130, cibg_segmask_iou 0.39528, pg_att_sup_loss 0.16786, pg_segmask_iou 0.62771, vbg_prc_auc 0.96098, vbg_att_sup_loss 0.07516, vbg_segmask_iou 0.29590, cl_att_sup_loss 0.18024, cl_segmask_iou 0.55463, cl_phrase_acc 0.99557, 58.92 secs
# ---- Epoch 32/100
# (1) Training stage (lr = 0.000012) ...
# loss 0.36069, cibg_att_sup_loss 0.41320, cibg_segmask_iou 0.60478, pg_att_sup_loss 0.19615, pg_segmask_iou 0.79693, vbg_phrcls_loss 0.02614, vbg_prc_auc 0.99971, vbg_att_reg_loss 0.07393, vbg_att_sup_loss 0.36812, vbg_segmask_iou 0.40200, cl_att_sup_loss 0.10948, cl_segmask_iou 0.60098, cl_phrcls_loss 0.03083, cl_phrase_acc 0.99992, 155.17 secs
# (2) Validation stage ...
# cibg_att_sup_loss 0.34695, cibg_segmask_iou 0.33977, pg_att_sup_loss 0.18305, pg_segmask_iou 0.60651, vbg_prc_auc 0.97719, vbg_att_sup_loss 0.07254, vbg_segmask_iou 0.30187, cl_att_sup_loss 0.14303, cl_segmask_iou 0.57027, cl_phrase_acc 0.99634, 51.55 secs
# ---- Epoch 33/100
# (1) Training stage (lr = 0.000007) ...
# loss 0.35242, cibg_att_sup_loss 0.41792, cibg_segmask_iou 0.60200, pg_att_sup_loss 0.18993, pg_segmask_iou 0.80250, vbg_phrcls_loss 0.01378, vbg_prc_auc 0.99997, vbg_att_reg_loss 0.07364, vbg_att_sup_loss 0.36396, vbg_segmask_iou 0.40107, cl_att_sup_loss 0.12254, cl_segmask_iou 0.59958, cl_phrcls_loss 0.00673, cl_phrase_acc 0.99996, 144.38 secs
# (2) Validation stage ...
# cibg_att_sup_loss 0.29727, cibg_segmask_iou 0.39159, pg_att_sup_loss 0.16984, pg_segmask_iou 0.62786, vbg_prc_auc 0.94868, vbg_att_sup_loss 0.07587, vbg_segmask_iou 0.29488, cl_att_sup_loss 0.16967, cl_segmask_iou 0.56313, cl_phrase_acc 0.99678, 47.06 secs
# ---- Epoch 34/100
# (1) Training stage (lr = 0.000003) ...
# loss 0.34281, cibg_att_sup_loss 0.40828, cibg_segmask_iou 0.60700, pg_att_sup_loss 0.18469, pg_segmask_iou 0.80134, vbg_phrcls_loss 0.01136, vbg_prc_auc 0.99997, vbg_att_reg_loss 0.07293, vbg_att_sup_loss 0.36136, vbg_segmask_iou 0.40100, cl_att_sup_loss 0.10160, cl_segmask_iou 0.59808, cl_phrcls_loss 0.00065, cl_phrase_acc 1.00000, 144.49 secs
# (2) Validation stage ...
# cibg_att_sup_loss 0.32517, cibg_segmask_iou 0.36366, pg_att_sup_loss 0.17608, pg_segmask_iou 0.61927, vbg_prc_auc 0.96486, vbg_att_sup_loss 0.07295, vbg_segmask_iou 0.30238, cl_att_sup_loss 0.15095, cl_segmask_iou 0.57391, cl_phrase_acc 0.99734, 45.94 secs
# ---- Epoch 35/100
# (1) Training stage (lr = 0.000002) ...
# loss 0.33972, cibg_att_sup_loss 0.40725, cibg_segmask_iou 0.60609, pg_att_sup_loss 0.17928, pg_segmask_iou 0.80674, vbg_phrcls_loss 0.00999, vbg_prc_auc 0.99999, vbg_att_reg_loss 0.07259, vbg_att_sup_loss 0.35611, vbg_segmask_iou 0.40459, cl_att_sup_loss 0.10705, cl_segmask_iou 0.60233, cl_phrcls_loss 0.00035, cl_phrase_acc 1.00000, 143.83 secs
# (2) Validation stage ...
# cibg_att_sup_loss 0.32664, cibg_segmask_iou 0.36156, pg_att_sup_loss 0.17625, pg_segmask_iou 0.61820, vbg_prc_auc 0.97003, vbg_att_sup_loss 0.07199, vbg_segmask_iou 0.30463, cl_att_sup_loss 0.15303, cl_segmask_iou 0.57216, cl_phrase_acc 0.99701, 46.40 secs
# ---- Epoch 36/100
# (1) Training stage (lr = 0.000001) ...
# loss 0.33960, cibg_att_sup_loss 0.40501, cibg_segmask_iou 0.61007, pg_att_sup_loss 0.18108, pg_segmask_iou 0.80664, vbg_phrcls_loss 0.00931, vbg_prc_auc 0.99998, vbg_att_reg_loss 0.07409, vbg_att_sup_loss 0.35725, vbg_segmask_iou 0.40140, cl_att_sup_loss 0.10374, cl_segmask_iou 0.59950, cl_phrcls_loss 0.00045, cl_phrase_acc 1.00000, 142.42 secs
# (2) Validation stage ...
# cibg_att_sup_loss 0.33904, cibg_segmask_iou 0.35017, pg_att_sup_loss 0.18046, pg_segmask_iou 0.61223, vbg_prc_auc 0.97295, vbg_att_sup_loss 0.07147, vbg_segmask_iou 0.30574, cl_att_sup_loss 0.13889, cl_segmask_iou 0.57733, cl_phrase_acc 0.99778, 49.84 secs
# ---- Epoch 37/100
# (1) Training stage (lr = 0.000080) ...
# loss 0.40593, cibg_att_sup_loss 0.41790, cibg_segmask_iou 0.60068, pg_att_sup_loss 0.23251, pg_segmask_iou 0.77997, vbg_phrcls_loss 0.06458, vbg_prc_auc 0.99914, vbg_att_reg_loss 0.07692, vbg_att_sup_loss 0.38922, vbg_segmask_iou 0.39489, cl_att_sup_loss 0.12991, cl_segmask_iou 0.59465, cl_phrcls_loss 0.10056, cl_phrase_acc 0.99764, 148.00 secs
# (2) Validation stage ...
# cibg_att_sup_loss 0.30971, cibg_segmask_iou 0.36491, pg_att_sup_loss 0.19824, pg_segmask_iou 0.58059, vbg_prc_auc 0.85311, vbg_att_sup_loss 0.08466, vbg_segmask_iou 0.27586, cl_att_sup_loss 0.17890, cl_segmask_iou 0.53940, cl_phrase_acc 0.95288, 50.98 secs
# ---- Epoch 38/100
# (1) Training stage (lr = 0.000043) ...
# loss 0.46464, cibg_att_sup_loss 0.42275, cibg_segmask_iou 0.59498, pg_att_sup_loss 0.26760, pg_segmask_iou 0.76224, vbg_phrcls_loss 0.15037, vbg_prc_auc 0.99613, vbg_att_reg_loss 0.08389, vbg_att_sup_loss 0.42710, vbg_segmask_iou 0.37638, cl_att_sup_loss 0.15249, cl_segmask_iou 0.57390, cl_phrcls_loss 0.08299, cl_phrase_acc 0.99666, 143.95 secs
# (2) Validation stage ...
# cibg_att_sup_loss 0.29229, cibg_segmask_iou 0.38553, pg_att_sup_loss 0.17817, pg_segmask_iou 0.60972, vbg_prc_auc 0.96151, vbg_att_sup_loss 0.07660, vbg_segmask_iou 0.29547, cl_att_sup_loss 0.16587, cl_segmask_iou 0.55677, cl_phrase_acc 0.99346, 49.60 secs
# ---- Epoch 39/100
# (1) Training stage (lr = 0.000023) ...
# loss 0.39605, cibg_att_sup_loss 0.41388, cibg_segmask_iou 0.60348, pg_att_sup_loss 0.22535, pg_segmask_iou 0.77819, vbg_phrcls_loss 0.06471, vbg_prc_auc 0.99920, vbg_att_reg_loss 0.07554, vbg_att_sup_loss 0.39529, vbg_segmask_iou 0.38705, cl_att_sup_loss 0.13939, cl_segmask_iou 0.57768, cl_phrcls_loss 0.02848, cl_phrase_acc 0.99969, 147.83 secs
# (2) Validation stage ...
# cibg_att_sup_loss 0.30115, cibg_segmask_iou 0.37824, pg_att_sup_loss 0.17867, pg_segmask_iou 0.61007, vbg_prc_auc 0.96456, vbg_att_sup_loss 0.07462, vbg_segmask_iou 0.29792, cl_att_sup_loss 0.15491, cl_segmask_iou 0.56537, cl_phrase_acc 0.99279, 52.27 secs
# ---- Epoch 40/100
# (1) Training stage (lr = 0.000012) ...
# loss 0.36736, cibg_att_sup_loss 0.41569, cibg_segmask_iou 0.60395, pg_att_sup_loss 0.20382, pg_segmask_iou 0.79268, vbg_phrcls_loss 0.03055, vbg_prc_auc 0.99990, vbg_att_reg_loss 0.07449, vbg_att_sup_loss 0.38168, vbg_segmask_iou 0.39731, cl_att_sup_loss 0.11912, cl_segmask_iou 0.58092, cl_phrcls_loss 0.00432, cl_phrase_acc 0.99985, 148.63 secs
# (2) Validation stage ...
# cibg_att_sup_loss 0.31207, cibg_segmask_iou 0.37090, pg_att_sup_loss 0.18103, pg_segmask_iou 0.60774, vbg_prc_auc 0.96696, vbg_att_sup_loss 0.07493, vbg_segmask_iou 0.29937, cl_att_sup_loss 0.15172, cl_segmask_iou 0.56318, cl_phrase_acc 0.99612, 53.85 secs
# ---- Epoch 41/100
# (1) Training stage (lr = 0.000007) ...
# loss 0.35498, cibg_att_sup_loss 0.40972, cibg_segmask_iou 0.60526, pg_att_sup_loss 0.19496, pg_segmask_iou 0.79658, vbg_phrcls_loss 0.01942, vbg_prc_auc 0.99995, vbg_att_reg_loss 0.07163, vbg_att_sup_loss 0.37400, vbg_segmask_iou 0.39740, cl_att_sup_loss 0.11751, cl_segmask_iou 0.58429, cl_phrcls_loss 0.00142, cl_phrase_acc 1.00000, 147.27 secs
# (2) Validation stage ...
# cibg_att_sup_loss 0.31015, cibg_segmask_iou 0.37214, pg_att_sup_loss 0.17630, pg_segmask_iou 0.61526, vbg_prc_auc 0.97048, vbg_att_sup_loss 0.07264, vbg_segmask_iou 0.30507, cl_att_sup_loss 0.16615, cl_segmask_iou 0.56253, cl_phrase_acc 0.99468, 52.15 secs
# ---- Epoch 42/100
# (1) Training stage (lr = 0.000003) ...
# loss 0.35362, cibg_att_sup_loss 0.40431, cibg_segmask_iou 0.60891, pg_att_sup_loss 0.19357, pg_segmask_iou 0.79442, vbg_phrcls_loss 0.01667, vbg_prc_auc 0.99995, vbg_att_reg_loss 0.07135, vbg_att_sup_loss 0.36818, vbg_segmask_iou 0.40079, cl_att_sup_loss 0.12100, cl_segmask_iou 0.58653, cl_phrcls_loss 0.02667, cl_phrase_acc 0.99992, 149.72 secs
# (2) Validation stage ...
# cibg_att_sup_loss 0.27648, cibg_segmask_iou 0.41036, pg_att_sup_loss 0.16801, pg_segmask_iou 0.62941, vbg_prc_auc 0.94670, vbg_att_sup_loss 0.07650, vbg_segmask_iou 0.29613, cl_att_sup_loss 0.17857, cl_segmask_iou 0.55696, cl_phrase_acc 0.99246, 50.43 secs
# ---- Epoch 43/100
# (1) Training stage (lr = 0.000002) ...
# loss 0.34850, cibg_att_sup_loss 0.40910, cibg_segmask_iou 0.60750, pg_att_sup_loss 0.18682, pg_segmask_iou 0.80105, vbg_phrcls_loss 0.01663, vbg_prc_auc 0.99993, vbg_att_reg_loss 0.07192, vbg_att_sup_loss 0.36466, vbg_segmask_iou 0.40124, cl_att_sup_loss 0.11370, cl_segmask_iou 0.58442, cl_phrcls_loss 0.00262, cl_phrase_acc 0.99996, 146.54 secs
# (2) Validation stage ...
# cibg_att_sup_loss 0.29926, cibg_segmask_iou 0.38372, pg_att_sup_loss 0.17538, pg_segmask_iou 0.61879, vbg_prc_auc 0.96387, vbg_att_sup_loss 0.07433, vbg_segmask_iou 0.30283, cl_att_sup_loss 0.15619, cl_segmask_iou 0.56892, cl_phrase_acc 0.99545, 51.60 secs
# ---- Epoch 44/100
# (1) Training stage (lr = 0.000001) ...
# loss 0.35033, cibg_att_sup_loss 0.40655, cibg_segmask_iou 0.60802, pg_att_sup_loss 0.19305, pg_segmask_iou 0.79610, vbg_phrcls_loss 0.01433, vbg_prc_auc 0.99996, vbg_att_reg_loss 0.07186, vbg_att_sup_loss 0.37045, vbg_segmask_iou 0.40116, cl_att_sup_loss 0.11715, cl_segmask_iou 0.58634, cl_phrcls_loss 0.00124, cl_phrase_acc 0.99996, 151.25 secs
# (2) Validation stage ...
# cibg_att_sup_loss 0.30464, cibg_segmask_iou 0.37756, pg_att_sup_loss 0.17398, pg_segmask_iou 0.61997, vbg_prc_auc 0.97130, vbg_att_sup_loss 0.07235, vbg_segmask_iou 0.30667, cl_att_sup_loss 0.16918, cl_segmask_iou 0.56427, cl_phrase_acc 0.99468, 53.09 secs
# ---- Epoch 45/100
# (1) Training stage (lr = 0.000080) ...
# ...
# ---- Epoch 78/100
# (1) Training stage (lr = 0.000043) ...
# loss 0.35703, cibg_att_sup_loss 0.39952, cibg_segmask_iou 0.61800, pg_att_sup_loss 0.20000, pg_segmask_iou 0.80033, vbg_phrcls_loss 0.04430, vbg_prc_auc 0.99953, vbg_att_reg_loss 0.06472, vbg_att_sup_loss 0.36889, vbg_segmask_iou 0.39973, cl_att_sup_loss 0.10713, cl_segmask_iou 0.60388, cl_phrcls_loss 0.00719, cl_phrase_acc 0.99965, 143.90 secs
# (2) Validation stage ...
# cibg_att_sup_loss 0.29994, cibg_segmask_iou 0.38965, pg_att_sup_loss 0.17198, pg_segmask_iou 0.62465, vbg_prc_auc 0.95081, vbg_att_sup_loss 0.07177, vbg_segmask_iou 0.30765, cl_att_sup_loss 0.16957, cl_segmask_iou 0.57668, cl_phrase_acc 0.99501, 42.44 secs
# ---- Epoch 79/100
# (1) Training stage (lr = 0.000023) ...
# loss 0.34317, cibg_att_sup_loss 0.40060, cibg_segmask_iou 0.61912, pg_att_sup_loss 0.18945, pg_segmask_iou 0.80950, vbg_phrcls_loss 0.02713, vbg_prc_auc 0.99969, vbg_att_reg_loss 0.06058, vbg_att_sup_loss 0.35646, vbg_segmask_iou 0.40590, cl_att_sup_loss 0.10918, cl_segmask_iou 0.59886, cl_phrcls_loss 0.01024, cl_phrase_acc 0.99985, 141.37 secs
# (2) Validation stage ...
# cibg_att_sup_loss 0.24005, cibg_segmask_iou 0.45446, pg_att_sup_loss 0.15614, pg_segmask_iou 0.64859, vbg_prc_auc 0.90896, vbg_att_sup_loss 0.08198, vbg_segmask_iou 0.28451, cl_att_sup_loss 0.18658, cl_segmask_iou 0.56065, cl_phrase_acc 0.99290, 41.01 secs
# ---- Epoch 80/100
# (1) Training stage (lr = 0.000012) ...
# loss 0.33189, cibg_att_sup_loss 0.40287, cibg_segmask_iou 0.61797, pg_att_sup_loss 0.17463, pg_segmask_iou 0.81474, vbg_phrcls_loss 0.01670, vbg_prc_auc 0.99977, vbg_att_reg_loss 0.05931, vbg_att_sup_loss 0.34391, vbg_segmask_iou 0.40786, cl_att_sup_loss 0.10760, cl_segmask_iou 0.60278, cl_phrcls_loss 0.01039, cl_phrase_acc 0.99988, 141.42 secs
# (2) Validation stage ...
# cibg_att_sup_loss 0.24719, cibg_segmask_iou 0.44870, pg_att_sup_loss 0.15700, pg_segmask_iou 0.64619, vbg_prc_auc 0.93428, vbg_att_sup_loss 0.07930, vbg_segmask_iou 0.28931, cl_att_sup_loss 0.17809, cl_segmask_iou 0.56690, cl_phrase_acc 0.99047, 43.54 secs
# ---- Epoch 81/100
# (1) Training stage (lr = 0.000007) ...
# loss 0.32575, cibg_att_sup_loss 0.40393, cibg_segmask_iou 0.61565, pg_att_sup_loss 0.17396, pg_segmask_iou 0.81398, vbg_phrcls_loss 0.00946, vbg_prc_auc 0.99995, vbg_att_reg_loss 0.05945, vbg_att_sup_loss 0.33585, vbg_segmask_iou 0.40912, cl_att_sup_loss 0.10610, cl_segmask_iou 0.60118, cl_phrcls_loss 0.00934, cl_phrase_acc 0.99981, 143.36 secs
# (2) Validation stage ...
# cibg_att_sup_loss 0.28110, cibg_segmask_iou 0.40251, pg_att_sup_loss 0.16584, pg_segmask_iou 0.63144, vbg_prc_auc 0.96903, vbg_att_sup_loss 0.07372, vbg_segmask_iou 0.30072, cl_att_sup_loss 0.17066, cl_segmask_iou 0.57153, cl_phrase_acc 0.99545, 41.20 secs
# ---- Epoch 82/100
# (1) Training stage (lr = 0.000003) ...
# loss 0.32055, cibg_att_sup_loss 0.39895, cibg_segmask_iou 0.61919, pg_att_sup_loss 0.16394, pg_segmask_iou 0.81888, vbg_phrcls_loss 0.00933, vbg_prc_auc 0.99991, vbg_att_reg_loss 0.05731, vbg_att_sup_loss 0.33740, vbg_segmask_iou 0.41133, cl_att_sup_loss 0.10110, cl_segmask_iou 0.60285, cl_phrcls_loss 0.00186, cl_phrase_acc 0.99992, 140.61 secs
# (2) Validation stage ...
# cibg_att_sup_loss 0.29716, cibg_segmask_iou 0.38776, pg_att_sup_loss 0.16729, pg_segmask_iou 0.62896, vbg_prc_auc 0.97750, vbg_att_sup_loss 0.07030, vbg_segmask_iou 0.30876, cl_att_sup_loss 0.17259, cl_segmask_iou 0.57172, cl_phrase_acc 0.99557, 42.71 secs
# ---- Epoch 83/100
# (1) Training stage (lr = 0.000002) ...
# loss 0.32206, cibg_att_sup_loss 0.40210, cibg_segmask_iou 0.61986, pg_att_sup_loss 0.16844, pg_segmask_iou 0.81711, vbg_phrcls_loss 0.00762, vbg_prc_auc 0.99993, vbg_att_reg_loss 0.05873, vbg_att_sup_loss 0.33028, vbg_segmask_iou 0.41111, cl_att_sup_loss 0.10068, cl_segmask_iou 0.60230, cl_phrcls_loss 0.02333, cl_phrase_acc 0.99996, 135.69 secs
# (2) Validation stage ...
# cibg_att_sup_loss 0.28051, cibg_segmask_iou 0.40981, pg_att_sup_loss 0.16388, pg_segmask_iou 0.63741, vbg_prc_auc 0.96188, vbg_att_sup_loss 0.07374, vbg_segmask_iou 0.30091, cl_att_sup_loss 0.15247, cl_segmask_iou 0.58051, cl_phrase_acc 0.99690, 42.44 secs
# ---- Epoch 84/100
# (1) Training stage (lr = 0.000001) ...
# loss 0.31565, cibg_att_sup_loss 0.39373, cibg_segmask_iou 0.62179, pg_att_sup_loss 0.16314, pg_segmask_iou 0.82034, vbg_phrcls_loss 0.00863, vbg_prc_auc 0.99993, vbg_att_reg_loss 0.05767, vbg_att_sup_loss 0.33079, vbg_segmask_iou 0.41330, cl_att_sup_loss 0.09963, cl_segmask_iou 0.60160, cl_phrcls_loss 0.00032, cl_phrase_acc 1.00000, 141.05 secs
# (2) Validation stage ...
# cibg_att_sup_loss 0.30071, cibg_segmask_iou 0.38669, pg_att_sup_loss 0.17069, pg_segmask_iou 0.62710, vbg_prc_auc 0.96927, vbg_att_sup_loss 0.07243, vbg_segmask_iou 0.30515, cl_att_sup_loss 0.13625, cl_segmask_iou 0.58901, cl_phrase_acc 0.99701, 44.63 secs
# ---- Epoch 85/100
# (1) Training stage (lr = 0.000080) ...
# loss 0.35023, cibg_att_sup_loss 0.40142, cibg_segmask_iou 0.61873, pg_att_sup_loss 0.20163, pg_segmask_iou 0.80560, vbg_phrcls_loss 0.02454, vbg_prc_auc 0.99983, vbg_att_reg_loss 0.06504, vbg_att_sup_loss 0.35333, vbg_segmask_iou 0.40349, cl_att_sup_loss 0.10986, cl_segmask_iou 0.60829, cl_phrcls_loss 0.04529, cl_phrase_acc 0.99872, 140.52 secs
# (2) Validation stage ...
# cibg_att_sup_loss 0.34041, cibg_segmask_iou 0.34683, pg_att_sup_loss 0.19003, pg_segmask_iou 0.60438, vbg_prc_auc 0.95846, vbg_att_sup_loss 0.06884, vbg_segmask_iou 0.31231, cl_att_sup_loss 0.17412, cl_segmask_iou 0.57646, cl_phrase_acc 0.99335, 45.73 secs
# ---- Epoch 86/100
# (1) Training stage (lr = 0.000043) ...
# loss 0.38637, cibg_att_sup_loss 0.40170, cibg_segmask_iou 0.61447, pg_att_sup_loss 0.23605, pg_segmask_iou 0.78240, vbg_phrcls_loss 0.06131, vbg_prc_auc 0.99924, vbg_att_reg_loss 0.06422, vbg_att_sup_loss 0.38215, vbg_segmask_iou 0.39914, cl_att_sup_loss 0.13910, cl_segmask_iou 0.59361, cl_phrcls_loss 0.05107, cl_phrase_acc 0.99802, 146.17 secs
# (2) Validation stage ...
# cibg_att_sup_loss 0.32180, cibg_segmask_iou 0.35938, pg_att_sup_loss 0.18497, pg_segmask_iou 0.60235, vbg_prc_auc 0.95461, vbg_att_sup_loss 0.07396, vbg_segmask_iou 0.29987, cl_att_sup_loss 0.13886, cl_segmask_iou 0.57152, cl_phrase_acc 0.99468, 44.96 secs
# ---- Epoch 87/100
# (1) Training stage (lr = 0.000023) ...
# loss 0.34806, cibg_att_sup_loss 0.40281, cibg_segmask_iou 0.61690, pg_att_sup_loss 0.19450, pg_segmask_iou 0.80367, vbg_phrcls_loss 0.03714, vbg_prc_auc 0.99959, vbg_att_reg_loss 0.06056, vbg_att_sup_loss 0.35626, vbg_segmask_iou 0.40111, cl_att_sup_loss 0.11109, cl_segmask_iou 0.59503, cl_phrcls_loss 0.00578, cl_phrase_acc 0.99988, 142.22 secs
# (2) Validation stage ...
# cibg_att_sup_loss 0.25877, cibg_segmask_iou 0.42934, pg_att_sup_loss 0.16217, pg_segmask_iou 0.63583, vbg_prc_auc 0.94259, vbg_att_sup_loss 0.07827, vbg_segmask_iou 0.28920, cl_att_sup_loss 0.16555, cl_segmask_iou 0.56992, cl_phrase_acc 0.99579, 43.45 secs
# ---- Epoch 88/100
# (1) Training stage (lr = 0.000012) ...
# loss 0.32770, cibg_att_sup_loss 0.39546, cibg_segmask_iou 0.61956, pg_att_sup_loss 0.18089, pg_segmask_iou 0.80891, vbg_phrcls_loss 0.01433, vbg_prc_auc 0.99989, vbg_att_reg_loss 0.05811, vbg_att_sup_loss 0.34121, vbg_segmask_iou 0.41117, cl_att_sup_loss 0.10840, cl_segmask_iou 0.59885, cl_phrcls_loss 0.00676, cl_phrase_acc 0.99985, 144.74 secs
# (2) Validation stage ...
# cibg_att_sup_loss 0.28811, cibg_segmask_iou 0.39798, pg_att_sup_loss 0.16850, pg_segmask_iou 0.62785, vbg_prc_auc 0.95581, vbg_att_sup_loss 0.07500, vbg_segmask_iou 0.29695, cl_att_sup_loss 0.15646, cl_segmask_iou 0.57567, cl_phrase_acc 0.99590, 43.72 secs
# ---- Epoch 89/100
# (1) Training stage (lr = 0.000007) ...
# loss 0.32245, cibg_att_sup_loss 0.39938, cibg_segmask_iou 0.62038, pg_att_sup_loss 0.16724, pg_segmask_iou 0.81683, vbg_phrcls_loss 0.01074, vbg_prc_auc 0.99995, vbg_att_reg_loss 0.05776, vbg_att_sup_loss 0.33515, vbg_segmask_iou 0.40959, cl_att_sup_loss 0.10414, cl_segmask_iou 0.60172, cl_phrcls_loss 0.00822, cl_phrase_acc 0.99981, 140.90 secs
# (2) Validation stage ...
# cibg_att_sup_loss 0.28653, cibg_segmask_iou 0.39902, pg_att_sup_loss 0.16927, pg_segmask_iou 0.62475, vbg_prc_auc 0.96461, vbg_att_sup_loss 0.07482, vbg_segmask_iou 0.29656, cl_att_sup_loss 0.16277, cl_segmask_iou 0.56939, cl_phrase_acc 0.99612, 44.27 secs
# ---- Epoch 90/100
# (1) Training stage (lr = 0.000003) ...
# loss 0.31809, cibg_att_sup_loss 0.39356, cibg_segmask_iou 0.62198, pg_att_sup_loss 0.16994, pg_segmask_iou 0.81430, vbg_phrcls_loss 0.00979, vbg_prc_auc 0.99996, vbg_att_reg_loss 0.05698, vbg_att_sup_loss 0.33150, vbg_segmask_iou 0.41481, cl_att_sup_loss 0.10246, cl_segmask_iou 0.60164, cl_phrcls_loss 0.00409, cl_phrase_acc 0.99992, 140.71 secs
# (2) Validation stage ...
# cibg_att_sup_loss 0.30413, cibg_segmask_iou 0.37983, pg_att_sup_loss 0.17299, pg_segmask_iou 0.61931, vbg_prc_auc 0.97249, vbg_att_sup_loss 0.07199, vbg_segmask_iou 0.30320, cl_att_sup_loss 0.15434, cl_segmask_iou 0.57562, cl_phrase_acc 0.99601, 44.06 secs
# ---- Epoch 91/100
# (1) Training stage (lr = 0.000002) ...
# loss 0.31864, cibg_att_sup_loss 0.39949, cibg_segmask_iou 0.62036, pg_att_sup_loss 0.16681, pg_segmask_iou 0.81798, vbg_phrcls_loss 0.00732, vbg_prc_auc 0.99999, vbg_att_reg_loss 0.05777, vbg_att_sup_loss 0.32793, vbg_segmask_iou 0.41227, cl_att_sup_loss 0.10353, cl_segmask_iou 0.60092, cl_phrcls_loss 0.01374, cl_phrase_acc 0.99985, 143.58 secs
# (2) Validation stage ...
# cibg_att_sup_loss 0.25751, cibg_segmask_iou 0.43328, pg_att_sup_loss 0.16006, pg_segmask_iou 0.64268, vbg_prc_auc 0.94816, vbg_att_sup_loss 0.07732, vbg_segmask_iou 0.29327, cl_att_sup_loss 0.16763, cl_segmask_iou 0.57129, cl_phrase_acc 0.99634, 43.00 secs
# ---- Epoch 92/100
# (1) Training stage (lr = 0.000001) ...
# loss 0.31359, cibg_att_sup_loss 0.38916, cibg_segmask_iou 0.62504, pg_att_sup_loss 0.16623, pg_segmask_iou 0.81758, vbg_phrcls_loss 0.00832, vbg_prc_auc 0.99999, vbg_att_reg_loss 0.05672, vbg_att_sup_loss 0.32648, vbg_segmask_iou 0.41312, cl_att_sup_loss 0.10131, cl_segmask_iou 0.60059, cl_phrcls_loss 0.00558, cl_phrase_acc 0.99988, 141.93 secs
# (2) Validation stage ...
# cibg_att_sup_loss 0.27112, cibg_segmask_iou 0.41494, pg_att_sup_loss 0.16454, pg_segmask_iou 0.63388, vbg_prc_auc 0.95614, vbg_att_sup_loss 0.07623, vbg_segmask_iou 0.29387, cl_att_sup_loss 0.16804, cl_segmask_iou 0.56913, cl_phrase_acc 0.99545, 42.74 secs
# ---- Epoch 93/100
# (1) Training stage (lr = 0.000080) ...
# loss 0.33912, cibg_att_sup_loss 0.39495, cibg_segmask_iou 0.62319, pg_att_sup_loss 0.20090, pg_segmask_iou 0.80325, vbg_phrcls_loss 0.03000, vbg_prc_auc 0.99963, vbg_att_reg_loss 0.06135, vbg_att_sup_loss 0.34575, vbg_segmask_iou 0.40864, cl_att_sup_loss 0.10688, cl_segmask_iou 0.60700, cl_phrcls_loss 0.00369, cl_phrase_acc 0.99988, 143.98 secs
# (2) Validation stage ...
# cibg_att_sup_loss 0.27557, cibg_segmask_iou 0.40878, pg_att_sup_loss 0.16955, pg_segmask_iou 0.62484, vbg_prc_auc 0.95506, vbg_att_sup_loss 0.07758, vbg_segmask_iou 0.29264, cl_att_sup_loss 0.16019, cl_segmask_iou 0.57186, cl_phrase_acc 0.99479, 43.18 secs
# ---- Epoch 94/100
# (1) Training stage (lr = 0.000043) ...
# loss 0.36842, cibg_att_sup_loss 0.39580, cibg_segmask_iou 0.61954, pg_att_sup_loss 0.20583, pg_segmask_iou 0.80029, vbg_phrcls_loss 0.05699, vbg_prc_auc 0.99944, vbg_att_reg_loss 0.06401, vbg_att_sup_loss 0.36914, vbg_segmask_iou 0.39902, cl_att_sup_loss 0.11651, cl_segmask_iou 0.60127, cl_phrcls_loss 0.04279, cl_phrase_acc 0.99907, 141.41 secs
# (2) Validation stage ...
# cibg_att_sup_loss 0.29005, cibg_segmask_iou 0.40532, pg_att_sup_loss 0.16947, pg_segmask_iou 0.62896, vbg_prc_auc 0.88600, vbg_att_sup_loss 0.07875, vbg_segmask_iou 0.29132, cl_att_sup_loss 0.17173, cl_segmask_iou 0.56788, cl_phrase_acc 0.99457, 43.25 secs
# ---- Epoch 95/100
# (1) Training stage (lr = 0.000023) ...
# loss 0.34157, cibg_att_sup_loss 0.39722, cibg_segmask_iou 0.62088, pg_att_sup_loss 0.19177, pg_segmask_iou 0.80473, vbg_phrcls_loss 0.03747, vbg_prc_auc 0.99967, vbg_att_reg_loss 0.06012, vbg_att_sup_loss 0.34790, vbg_segmask_iou 0.40627, cl_att_sup_loss 0.10688, cl_segmask_iou 0.60561, cl_phrcls_loss 0.00302, cl_phrase_acc 0.99985, 142.63 secs
# (2) Validation stage ...
# cibg_att_sup_loss 0.24765, cibg_segmask_iou 0.45183, pg_att_sup_loss 0.15205, pg_segmask_iou 0.65715, vbg_prc_auc 0.91173, vbg_att_sup_loss 0.07804, vbg_segmask_iou 0.29297, cl_att_sup_loss 0.19174, cl_segmask_iou 0.56744, cl_phrase_acc 0.99590, 42.98 secs
# ---- Epoch 96/100
# (1) Training stage (lr = 0.000012) ...
# loss 0.32114, cibg_att_sup_loss 0.39860, cibg_segmask_iou 0.62240, pg_att_sup_loss 0.17005, pg_segmask_iou 0.81754, vbg_phrcls_loss 0.01450, vbg_prc_auc 0.99994, vbg_att_reg_loss 0.05643, vbg_att_sup_loss 0.33191, vbg_segmask_iou 0.41091, cl_att_sup_loss 0.10065, cl_segmask_iou 0.60490, cl_phrcls_loss 0.00391, cl_phrase_acc 0.99992, 142.13 secs
# (2) Validation stage ...
# cibg_att_sup_loss 0.26981, cibg_segmask_iou 0.41886, pg_att_sup_loss 0.16099, pg_segmask_iou 0.63516, vbg_prc_auc 0.95159, vbg_att_sup_loss 0.07651, vbg_segmask_iou 0.29294, cl_att_sup_loss 0.19916, cl_segmask_iou 0.55686, cl_phrase_acc 0.99435, 43.19 secs
# ---- Epoch 97/100
# (1) Training stage (lr = 0.000007) ...
# loss 0.31779, cibg_att_sup_loss 0.39183, cibg_segmask_iou 0.62304, pg_att_sup_loss 0.16492, pg_segmask_iou 0.81950, vbg_phrcls_loss 0.00954, vbg_prc_auc 0.99997, vbg_att_reg_loss 0.05531, vbg_att_sup_loss 0.32831, vbg_segmask_iou 0.41364, cl_att_sup_loss 0.10132, cl_segmask_iou 0.60844, cl_phrcls_loss 0.02498, cl_phrase_acc 0.99992, 141.41 secs
# (2) Validation stage ...
# cibg_att_sup_loss 0.26661, cibg_segmask_iou 0.42279, pg_att_sup_loss 0.16265, pg_segmask_iou 0.63403, vbg_prc_auc 0.94234, vbg_att_sup_loss 0.07828, vbg_segmask_iou 0.29121, cl_att_sup_loss 0.18997, cl_segmask_iou 0.56052, cl_phrase_acc 0.99468, 42.49 secs
# ---- Epoch 98/100
# (1) Training stage (lr = 0.000003) ...
# loss 0.31283, cibg_att_sup_loss 0.39445, cibg_segmask_iou 0.62270, pg_att_sup_loss 0.16599, pg_segmask_iou 0.81763, vbg_phrcls_loss 0.00875, vbg_prc_auc 0.99996, vbg_att_reg_loss 0.05674, vbg_att_sup_loss 0.32318, vbg_segmask_iou 0.41724, cl_att_sup_loss 0.09857, cl_segmask_iou 0.60723, cl_phrcls_loss 0.00042, cl_phrase_acc 1.00000, 143.40 secs
# (2) Validation stage ...
# cibg_att_sup_loss 0.28724, cibg_segmask_iou 0.40103, pg_att_sup_loss 0.16815, pg_segmask_iou 0.62607, vbg_prc_auc 0.95681, vbg_att_sup_loss 0.07517, vbg_segmask_iou 0.29739, cl_att_sup_loss 0.17608, cl_segmask_iou 0.56749, cl_phrase_acc 0.99579, 42.65 secs
# ---- Epoch 99/100
# (1) Training stage (lr = 0.000002) ...
# loss 0.31089, cibg_att_sup_loss 0.39791, cibg_segmask_iou 0.62080, pg_att_sup_loss 0.15863, pg_segmask_iou 0.82226, vbg_phrcls_loss 0.00585, vbg_prc_auc 0.99999, vbg_att_reg_loss 0.05491, vbg_att_sup_loss 0.32282, vbg_segmask_iou 0.41546, cl_att_sup_loss 0.09741, cl_segmask_iou 0.61272, cl_phrcls_loss 0.00511, cl_phrase_acc 0.99992, 141.13 secs
# (2) Validation stage ...
# cibg_att_sup_loss 0.28978, cibg_segmask_iou 0.39906, pg_att_sup_loss 0.17168, pg_segmask_iou 0.62271, vbg_prc_auc 0.94634, vbg_att_sup_loss 0.07713, vbg_segmask_iou 0.29261, cl_att_sup_loss 0.15311, cl_segmask_iou 0.57669, cl_phrase_acc 0.99723, 42.30 secs
# ---- Epoch 100/100
# (1) Training stage (lr = 0.000001) ...
# loss 0.31220, cibg_att_sup_loss 0.39626, cibg_segmask_iou 0.62354, pg_att_sup_loss 0.16151, pg_segmask_iou 0.81936, vbg_phrcls_loss 0.01050, vbg_prc_auc 0.99993, vbg_att_reg_loss 0.05644, vbg_att_sup_loss 0.32206, vbg_segmask_iou 0.41738, cl_att_sup_loss 0.09442, cl_segmask_iou 0.60945, cl_phrcls_loss 0.00036, cl_phrase_acc 1.00000, 143.83 secs
# (2) Validation stage ...
# cibg_att_sup_loss 0.30220, cibg_segmask_iou 0.38997, pg_att_sup_loss 0.16932, pg_segmask_iou 0.62866, vbg_prc_auc 0.96093, vbg_att_sup_loss 0.07248, vbg_segmask_iou 0.30423, cl_att_sup_loss 0.15298, cl_segmask_iou 0.58479, cl_phrase_acc 0.99756, 41.95 secs
