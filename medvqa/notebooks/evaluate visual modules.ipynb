# %%
# %env CUDA_VISIBLE_DEVICES=0
# Out:
# env: CUDA_VISIBLE_DEVICES=0

# %%
reload(medvqa.eval_visual_module)
# Out:
# <module 'medvqa.eval_visual_module' from '/home/pamessina/medvqa/medvqa/eval_visual_module.py'>

# %%
import shlex
from importlib import reload
import medvqa
from medvqa.eval_visual_module import debug_main

# %%
output = debug_main(args=shlex.split(
    ' '.join([
        '--checkpoint-folder "models/vqa/20220630_162749_mimiccxr+iuxray+chexpert(vqa)_oevqa(densenet121+bilstm+lstm)_voc-minf=5_model-args=(densenet-121,128,None,512,1,128,1024,0,qenc=one-hot)_cnn-pretr=0_dataset_weights=0.73,0.07,0.2_medtok=1_tags=0_orien=1_chx=1_ql=1_use_amp"',
        '--mimiccxr-preprocessed-test-data-filename "mimiccxr_preprocessed_test_data__(dataset=qa_adapted_reports__20220629_050643.json;tokenizer=5329,43243,4002259961944187905).pkl"',
        '--iuxray-preprocessed-train-data-filename "iuxray_preprocessed_train_data__(hash=292,3913547687693191898).pkl"',
        '--batch-size 160',
    ])
))
# Out:
# script's arguments:
#    checkpoint_folder: models/vqa/20220630_162749_mimiccxr+iuxray+chexpert(vqa)_oevqa(densenet121+bilstm+lstm)_voc-minf=5_model-args=(densenet-121,128,None,512,1,128,1024,0,qenc=one-hot)_cnn-pretr=0_dataset_weights=0.73,0.07,0.2_medtok=1_tags=0_orien=1_chx=1_ql=1_use_amp
#    mimiccxr_preprocessed_test_data_filename: mimiccxr_preprocessed_test_data__(dataset=qa_adapted_reports__20220629_050643.json;tokenizer=5329,43243,4002259961944187905).pkl
#    iuxray_preprocessed_train_data_filename: iuxray_preprocessed_train_data__(hash=292,3913547687693191898).pkl
#    batch_size: 160
#    device: GPU
#    num_workers: 0
#    eval_iuxray: True
#    eval_mimiccxr: True
#    use_amp: False
# ----- Evaluating model ------
# ...

# %%
# !python ../eval_visual_module.py \
        --checkpoint-folder "models/vqa/20220630_162749_mimiccxr+iuxray+chexpert(vqa)_oevqa(densenet121+bilstm+lstm)_voc-minf=5_model-args=(densenet-121,128,None,512,1,128,1024,0,qenc=one-hot)_cnn-pretr=0_dataset_weights=0.73,0.07,0.2_medtok=1_tags=0_orien=1_chx=1_ql=1_use_amp" \
        --mimiccxr-preprocessed-test-data-filename "mimiccxr_preprocessed_test_data__(dataset=qa_adapted_reports__20220629_050643.json;tokenizer=5329,43243,4002259961944187905).pkl" \
        --iuxray-preprocessed-train-data-filename "iuxray_preprocessed_train_data__(hash=292,3913547687693191898).pkl" \
        --batch-size 160
# Out:
# script's arguments:
#    checkpoint_folder: models/vqa/20220630_162749_mimiccxr+iuxray+chexpert(vqa)_oevqa(densenet121+bilstm+lstm)_voc-minf=5_model-args=(densenet-121,128,None,512,1,128,1024,0,qenc=one-hot)_cnn-pretr=0_dataset_weights=0.73,0.07,0.2_medtok=1_tags=0_orien=1_chx=1_ql=1_use_amp
#    mimiccxr_preprocessed_test_data_filename: mimiccxr_preprocessed_test_data__(dataset=qa_adapted_reports__20220629_050643.json;tokenizer=5329,43243,4002259961944187905).pkl
#    iuxray_preprocessed_train_data_filename: iuxray_preprocessed_train_data__(hash=292,3913547687693191898).pkl
#    batch_size: 160
#    device: GPU
#    num_workers: 0
#    eval_iuxray: True
#    eval_mimiccxr: True
#    use_amp: False
# ----- Evaluating model ------
# ...

# %%
from medvqa.evaluation.visual_module import get_visual_module_metrics_dataframe
from medvqa.utils.files import load_pickle

# %%
get_visual_module_metrics_dataframe('/home/pamessina/medvqa-workspace/results/vqa/20220630_162749_mimiccxr+iuxray+chexpert(vqa)_oevqa(densenet121+bilstm+lstm)_voc-minf=5_model-args=(densenet-121,128,None,512,1,128,1024,0,qenc=one-hot)_cnn-pretr=0_dataset_weights=0.73,0.07,0.2_medtok=1_tags=0_orien=1_chx=1_ql=1_use_amp/iuxray_visual_module_metrics.pkl')
# Out:
# 1it [00:00, 683.45it/s]
#                                         metrics_path  oracc   chxlacc  ...  ql_f1(micro)  ql_p(micro)  ql_r(micro)
# 0  /home/pamessina/medvqa-workspace/results/vqa/2...    1.0  0.813411  ...      0.494085     0.422871     0.594142
#
# [1 rows x 73 columns]

# %%
get_visual_module_metrics_dataframe('/home/pamessina/medvqa-workspace/results/vqa/20220630_162749_mimiccxr+iuxray+chexpert(vqa)_oevqa(densenet121+bilstm+lstm)_voc-minf=5_model-args=(densenet-121,128,None,512,1,128,1024,0,qenc=one-hot)_cnn-pretr=0_dataset_weights=0.73,0.07,0.2_medtok=1_tags=0_orien=1_chx=1_ql=1_use_amp/mimiccxr_visual_module_metrics.pkl')
# Out:
# 1it [00:00, 1006.07it/s]
#                                         metrics_path     oracc   chxlacc  ...  ql_f1(micro)  ql_p(micro)  ql_r(micro)
# 0  /home/pamessina/medvqa-workspace/results/vqa/2...  0.997014  0.752893  ...      0.501282     0.426867      0.60712
#
# [1 rows x 73 columns]

# %%
# !python ../eval_visual_module.py \
        --checkpoint-folder "models/vqa/20220706_135511_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(densenet121+bilstm+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretrained)_cnn-pretr=0_dataset_weights=0.73,0.15,0.07,0.03,0.2_medtok_orien_chx_ql_use_amp" \
        --mimiccxr-preprocessed-test-data-filename "mimiccxr_preprocessed_test_data__(dataset=qa_adapted_reports__20220629_050643.json;tokenizer=5329,43243,4002259961944187905;report_eval_mode=ground-truth).pkl" \
        --iuxray-preprocessed-train-data-filename "iuxray_preprocessed_train_data__(hash=292,3913547687693191898).pkl" \
        --batch-size 160
# Out:
# script's arguments:
#    checkpoint_folder: models/vqa/20220706_135511_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(densenet121+bilstm+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretrained)_cnn-pretr=0_dataset_weights=0.73,0.15,0.07,0.03,0.2_medtok_orien_chx_ql_use_amp
#    mimiccxr_preprocessed_test_data_filename: mimiccxr_preprocessed_test_data__(dataset=qa_adapted_reports__20220629_050643.json;tokenizer=5329,43243,4002259961944187905;report_eval_mode=ground-truth).pkl
#    iuxray_preprocessed_train_data_filename: iuxray_preprocessed_train_data__(hash=292,3913547687693191898).pkl
#    batch_size: 160
#    device: GPU
#    num_workers: 0
#    eval_iuxray: True
#    eval_mimiccxr: True
#    use_amp: False
# ----- Evaluating model ------
# ...

# %%
get_visual_module_metrics_dataframe([
    '/home/pamessina/medvqa-workspace/results/vqa/20220706_135511_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(densenet121+bilstm+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretrained)_cnn-pretr=0_dataset_weights=0.73,0.15,0.07,0.03,0.2_medtok_orien_chx_ql_use_amp/iuxray_visual_module_metrics.pkl',
    '/home/pamessina/medvqa-workspace/results/vqa/20220706_135511_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(densenet121+bilstm+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretrained)_cnn-pretr=0_dataset_weights=0.73,0.15,0.07,0.03,0.2_medtok_orien_chx_ql_use_amp/mimiccxr_visual_module_metrics.pkl',    
])
# Out:
# 2it [00:00, 1495.03it/s]
#                                         metrics_path     oracc   chxlacc  ...  ql_f1(micro)  ql_p(micro)  ql_r(micro)
# 0  /home/pamessina/medvqa-workspace/results/vqa/2...  1.000000  0.830418  ...      0.476057     0.408764     0.569874
# 1  /home/pamessina/medvqa-workspace/results/vqa/2...  0.997014  0.762179  ...      0.486877     0.417251     0.584395
#
# [2 rows x 73 columns]

# %%
# !python ../eval_visual_module.py \
        --checkpoint-folder "models/vqa/20220717_155233_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(dense121+onehot+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretr,frozen)_cnn-pretr=0_dws=0.73,0.15,0.07,0.03,0.2_medtok_chx_ql_amp" \
        --mimiccxr-preprocessed-test-data-filename "mimiccxr_preprocessed_test_data__(dataset=qa_adapted_reports__20220629_050643.json;tokenizer=5329,43243,4002259961944187905;report_eval_mode=ground-truth).pkl" \
        --iuxray-preprocessed-train-data-filename "iuxray_preprocessed_train_data__(hash=292,3913547687693191898).pkl" \
        --batch-size 160
# Out:
# script's arguments:
#    checkpoint_folder: models/vqa/20220717_155233_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(dense121+onehot+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretr,frozen)_cnn-pretr=0_dws=0.73,0.15,0.07,0.03,0.2_medtok_chx_ql_amp
#    mimiccxr_preprocessed_test_data_filename: mimiccxr_preprocessed_test_data__(dataset=qa_adapted_reports__20220629_050643.json;tokenizer=5329,43243,4002259961944187905;report_eval_mode=ground-truth).pkl
#    iuxray_preprocessed_train_data_filename: iuxray_preprocessed_train_data__(hash=292,3913547687693191898).pkl
#    batch_size: 160
#    device: GPU
#    num_workers: 0
#    eval_iuxray: True
#    eval_mimiccxr: True
#    use_amp: False
# ----- Evaluating model ------
# ...

# %%
get_visual_module_metrics_dataframe([
    '/home/pamessina/medvqa-workspace/results/vqa/20220717_155233_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(dense121+onehot+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretr,frozen)_cnn-pretr=0_dws=0.73,0.15,0.07,0.03,0.2_medtok_chx_ql_amp/iuxray_visual_module_metrics.pkl',
    '/home/pamessina/medvqa-workspace/results/vqa/20220717_155233_mim+mim(chex)+iu+iu(chex)+chexp(vqa)_oevqa(dense121+onehot+lstm)_model-args=(densenet121,128,None,512,1,128,1024,0,qenc=one-hot,pretr,frozen)_cnn-pretr=0_dws=0.73,0.15,0.07,0.03,0.2_medtok_chx_ql_amp/mimiccxr_visual_module_metrics.pkl',
])
# Out:
# 2it [00:00, 3493.80it/s]
#                                         metrics_path oracc   chxlacc  \
# 0  /home/pamessina/medvqa-workspace/results/vqa/2...  None  0.809524
# 1  /home/pamessina/medvqa-workspace/results/vqa/2...  None  0.752070
#
#    f1(macro)  p(macro)  r(macro)  f1(micro)  p(micro)  r(micro)    f1(NF)  \
# 0   0.327508  0.326635  0.399969   0.369775  0.320334  0.437262  0.330435
# 1   0.482027  0.406717  0.627439   0.588771  0.495372  0.725573  0.349810
#
#    ...  rocauc(PE)  rocauc(PO)  rocauc(F)  rocauc(SD)  ql_f1(macro)  \
# 0  ...    0.711417    0.798980   0.732117    0.754321      0.141825
# 1  ...    0.852713    0.853053   0.747065    0.901377      0.231894
#
#    ql_p(macro)  ql_r(macro)  ql_f1(micro)  ql_p(micro)  ql_r(micro)
# 0     0.138291     0.179541      0.492894     0.420710     0.594979
# 1     0.199279     0.325482      0.499893     0.424761     0.607315
#
# [2 rows x 73 columns]
