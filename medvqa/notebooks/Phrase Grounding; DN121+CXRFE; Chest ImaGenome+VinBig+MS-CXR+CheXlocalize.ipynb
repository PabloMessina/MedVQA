# %%
# %env CUDA_VISIBLE_DEVICES=1
# Out:
# env: CUDA_VISIBLE_DEVICES=1

# %%
# !python ../train_phrase_grounding.py \
--pretrained_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240505_224220_mim-facts+vinbig+chexloc+chxp_PhraseGrounder(dn121,128,256)/" \
--epochs 100 \
--batches_per_epoch 400 \
--max_images_per_batch 13 \
--max_phrases_per_batch 200 \
--max_phrases_per_image 40 \
--val_batch_size_factor 2.0 \
--raw_image_encoding "densenet-121" \
--image_size 416 416 \
--image_local_feat_size 1024 \
--num_regions 169 \
--regions_width 13 \
--regions_height 13 \
--phrase_embedding_size 128 \
--phrase_grounding_mode "sigmoid_attention_plus_custom_classifier" \
--phrase_classifier_hidden_size 256 \
--qkv_size 256 \
--num_train_workers 2 \
--num_val_workers 2 \
--gradient_accumulation_steps 10 \
--optimizer_name "adamw" \
--scheduler "exp-warmup+decay+cyclicdecay" \
--lr 1e-6 \
--warmup_decay_and_cyclic_decay_args "1e-6,3,8e-5,8,1e-6,8e-5,8,1e-6" \
--mimiccxr_exclude_noisy_images \
--binary_multilabel_classif_loss_name "focal+bce+wbce" \
--use_vinbig_for_train \
--vinbig_phrase_embeddings_filepath \
"/mnt/workspace/pamessina/medvqa-workspace/cache/vinbig/label_phrase_embeddings(hash=325,3209166273642513277).pkl" \
--vinbig_training_data_mode "all" \
--use_chexlocalize_for_train \
--use_chexlocalize_for_test \
--chexlocalize_class_phrase_embeddings_filepath \
"/mnt/workspace/pamessina/medvqa-workspace/cache/chexlocalize/class_phrase_embeddings(hash=528,1823213522699794899).pkl" \
--use_chest_imagenome_for_train \
--chest_imagenome_bbox_phrase_embeddings_filepath \
"/mnt/workspace/pamessina/medvqa-workspace/cache/chest_imagenome/bbox_phrase_embeddings(hash=333,2614535641242304201).pkl" \
--use_mscxr_for_train \
--use_mscxr_for_test \
--mscxr_phrase2embedding_filepath \
"/mnt/workspace/pamessina/medvqa-workspace/cache/mimiccxr/mscxr_phrase2embedding(hash=36521,3206715123524916204).pkl" \
--use_attention_regularization_loss \
--use_contrastive_phrase_grounding_loss \
--attention_supervision_loss_weight 2.0 \
--phrase_classifier_loss_weight 2.0 \
--foreground_loss_weight 1.5 \
--mask_exponent 0.4 \
--chest_imagenome_anatlocs_weight 1.0 \
--vinbig_weight 1.0 \
--mscxr_weight 0.5 \
--chexlocalize_weight 0.5 \
--save
# Out:
# script's arguments:
#    epochs: 100
#    batches_per_epoch: 400
#    max_images_per_batch: 13
#    max_phrases_per_batch: 200
#    max_phrases_per_image: 40
#    val_batch_size_factor: 2.0
#    checkpoint_folder: None
#    pretrained_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240505_224220_mim-facts+vinbig+chexloc+chxp_PhraseGrounder(dn121,128,256)/
#    pretrained_checkpoint_folder_paths: None
#    freeze_image_encoder: False
#    raw_image_encoding: densenet-121
#    num_regions: 169
#    image_local_feat_size: 1024
#    image_encoder_pretrained_weights_path: None
#    yolov8_model_name_or_path: None
#    yolov8_model_alias: None
#    phrase_embedding_size: 128
#    regions_width: 13
#    regions_height: 13
#    qkv_size: 256
#    phrase_grounding_mode: sigmoid_attention_plus_custom_classifier
#    phrase_classifier_hidden_size: 256
#    transf_d_model: None
#    transf_nhead: None
#    transf_dim_feedforward: None
#    transf_dropout: 0
#    transf_num_layers: None
#    optimizer_name: adamw
#    lr: 1e-06
#    scheduler: exp-warmup+decay+cyclicdecay
#    lr_decay: 0.76
#    lr_decay_patience: 2
#    warmup_and_decay_args: None
#    warmup_and_cosine_args: None
#    warmup_decay_and_cyclic_decay_args: 1e-6,3,8e-5,8,1e-6,8e-5,8,1e-6
#    gradient_accumulation_steps: 10
#    override_lr: False
#    max_grad_norm: None
#    attention_supervision_loss_weight: 2.0
#    phrase_classifier_loss_weight: 2.0
#    foreground_loss_weight: 1.5
#    background_loss_weight: 1.0
#    focal_loss_weight: 1.0
#    bce_loss_weight: 1.0
#    wbce_loss_weight: 1.0
#    binary_multilabel_classif_loss_name: focal+bce+wbce
#    use_weighted_phrase_classifier_loss: False
#    cluster_and_label_weights_for_facts_filepath: None
#    use_attention_regularization_loss: True
#    use_contrastive_phrase_grounding_loss: True
#    num_train_workers: 2
#    num_val_workers: 2
#    device: GPU
#    use_amp: False
#    image_size: [416, 416]
#    dicom_id_to_pos_neg_facts_filepath: None
#    iuxray_image_id_to_pos_neg_facts_filepath: None
#    mscxr_phrase2embedding_filepath: /mnt/workspace/pamessina/medvqa-workspace/cache/mimiccxr/mscxr_phrase2embedding(hash=36521,3206715123524916204).pkl
#    chest_imagenome_bbox_phrase_embeddings_filepath: /mnt/workspace/pamessina/medvqa-workspace/cache/chest_imagenome/bbox_phrase_embeddings(hash=333,2614535641242304201).pkl
#    vinbig_phrase_embeddings_filepath: /mnt/workspace/pamessina/medvqa-workspace/cache/vinbig/label_phrase_embeddings(hash=325,3209166273642513277).pkl
#    chexlocalize_class_phrase_embeddings_filepath: /mnt/workspace/pamessina/medvqa-workspace/cache/chexlocalize/class_phrase_embeddings(hash=528,1823213522699794899).pkl
#    chexpert_class_phrase_embeddings_filepath: None
#    mimiccxr_exclude_noisy_images: True
#    mimiccxr_facts_weight: 1.0
#    chest_imagenome_anatlocs_weight: 1.0
#    mscxr_weight: 0.5
#    vinbig_weight: 1.0
#    chexlocalize_weight: 0.5
#    chexpert_weight: 1.0
#    iuxray_weight: 1.0
#    img_aug_mode: None
#    pos_area_prior: 0.4
#    neg_area_prior: 0.0
#    use_mimiccxr_facts_for_train: False
#    use_mimiccxr_facts_for_test: False
#    use_mscxr_for_train: True
#    use_mscxr_for_test: True
#    use_chest_imagenome_for_train: True
#    use_chest_imagenome_gold_for_test: False
#    use_vinbig_for_train: True
#    use_vinbig_for_test: False
#    use_chexlocalize_for_train: True
#    use_chexlocalize_for_test: True
#    use_chexpert_for_train: False
#    use_chexpert_for_test: False
#    use_iuxray_for_train: False
#    use_iuxray_for_test: False
#    vinbig_training_data_mode: all
#    chexpert_training_data_mode: all
#    mask_exponent: 0.4
#    mimiccxr_balance_long_middle_short_tail: False
#    mimiccxr_long_middle_short_tail_thresholds: (0.02, 0.05)
#    mimiccxr_report_fact_nli_integrated_data_filepath: None
#    mimiccxr_use_interpret_cxr_challenge_split: False
#    mimiccxr_interpret_cxr_challenge_split_filepath: None
#    iuxray_use_interpret_cxr_challenge_split: False
#    iuxray_interpret_cxr_challenge_split_filepath: None
#    chexpert_use_interpret_cxr_challenge_split: False
#    chexpert_interpret_cxr_challenge_split_filepath: None
#    chexlocalize_use_interpret_cxr_challenge_split: False
#    chexlocalize_interpret_cxr_challenge_split_filepath: None
#    save: True
# ----- Training model from scratch ------
# include_loss_weights = True
# source_image_size_mode: medium_512
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Creating instance of PhraseGrounder ...
# WARNING: Unused kwargs: {'pretrained_checkpoint_folder_path': '/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240505_224220_mim-facts+vinbig+chexloc+chxp_PhraseGrounder(dn121,128,256)/', 'pretrained_checkpoint_folder_paths': None}
# MultiPurposeVisualModule()
#   Initializing raw_image_encoder: densenet-121
# create_densenet121_feature_extractor()
#    drop_rate: 0.0
# DenseNet121's pretrained weights loaded from ImageNet
#   self.global_feat_size = 2048
#   self.local_feat_size = 1024
#   Initializing auxiliary tasks
# --------------------------------------------------
# 3) Defining optimizer ...
# create_optimizer(): name = adamw
# --------------------------------------------------
# 4) Defining scheduler ...
# Using exp-warmup+decay+cyclicdecay scheduler: 1e-6,3,8e-5,8,1e-6,8e-5,8,1e-6
# 1e-06 3 8e-05 8 1e-06 8e-05 8 1e-06
# self.steps_to_restart = 8
# self.steps = -1
# self.initial_lr = 8e-05
# --------------------------------------------------
# 5) Creating trainer and validator engines ...
# binary_loss_kwargs: {'focal_weight': 1.0, 'bce_weight': 1.0, 'wbce_weight': 1.0}
# Focal_BCE_WBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 wbce_weight = 0.3333333333333333
# Focal_BCE_Loss(): focal_weight = 0.5 bce_weight = 0.5
# Focal_BCE_WBCBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 wbcbce_weight = 0.3333333333333333
# foreground_loss_weight: 1.5
# background_loss_weight: 1.0
# GradientAccumulator.__init__(): num_accumulation_steps = 10, max_grad_norm = None
# binary_loss_kwargs: {'focal_weight': 1.0, 'bce_weight': 1.0, 'wbce_weight': 1.0}
# Focal_BCE_WBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 wbce_weight = 0.3333333333333333
# Focal_BCE_Loss(): focal_weight = 0.5 bce_weight = 0.5
# Focal_BCE_WBCBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 wbcbce_weight = 0.3333333333333333
# foreground_loss_weight: 1.0
# background_loss_weight: 1.0
# --------------------------------------------------
# 6) Creating CheXLocalize Phrase Grounding Trainer ...
# get_image_transform()
# Using standard transform
# mean = (0.485, 0.456, 0.406), std = (0.229, 0.224, 0.225), image_size = [416, 416], use_center_crop = False
# Returning transform without augmentation
# get_image_transform()
# Using standard transform
# mean = (0.485, 0.456, 0.406), std = (0.229, 0.224, 0.225), image_size = [416, 416], use_center_crop = False
# Returning transform without augmentation
# Loding class_phrase_embeddings_filepath and bbox_phrases from /mnt/workspace/pamessina/medvqa-workspace/cache/chexlocalize/class_phrase_embeddings(hash=528,1823213522699794899).pkl...
# class_phrase_embeddings.shape = (10, 128)
# len(class_phrases) = 10
# 	 enlarged cardiomediastinum seen
# 	 cardiomegaly seen
# 	 lung lesion seen
# 	 airspace opacity seen
# 	 edema seen
# 	 consolidation seen
# 	 atelectasis seen
# 	 pneumothorax seen
# 	 pleural effusion seen
# 	 support devices seen
# Compute phrase grounding masks and labels
# Without masks: 216/902
# Generating train dataset and dataloader
# len(train_indices) = 902
# batch_size = 13
# Generating val dataset and dataloader
# len(val_indices) = 902
# batch_size = 26
# --------------------------------------------------
# 7) Creating VinBig Phrase Grounding Trainer ...
# get_image_transform()
# Using standard transform
# mean = (0.485, 0.456, 0.406), std = (0.229, 0.224, 0.225), image_size = [416, 416], use_center_crop = False
# Returning transform without augmentation
# get_image_transform()
# Using standard transform
# mean = (0.485, 0.456, 0.406), std = (0.229, 0.224, 0.225), image_size = [416, 416], use_center_crop = False
# Returning transform without augmentation
# Loading bounding boxes
# Anomalous bboxes found: 29 of 37367
# class_id_offset: 0
# Anomalous bboxes found: 0 of 2697
# class_id_offset: 0
#   Loaded 18000 bounding boxes
# Loding phrase_embeddings and phrases from /mnt/workspace/pamessina/medvqa-workspace/cache/vinbig/label_phrase_embeddings(hash=325,3209166273642513277).pkl...
# phrase_embeddings.shape = (28, 128)
# len(phrases) = 28
# 	 aortic enlargement seen
# 	 atelectasis seen
# 	 calcification seen
# 	 cardiomegaly seen
# 	 clavicle fracture seen
# 	 consolidation seen
# 	 edema seen
# 	 emphysema seen
# 	 enlarged pulmonary artery seen
# 	 interstitial lung disease seen
# 	 infiltration seen
# 	 lung opacity seen
# 	 lung cavity seen
# 	 lung cyst seen
# 	 mediastinal shift seen
# 	 nodule/mass seen
# 	 pleural effusion seen
# 	 pleural thickening seen
# 	 pneumothorax seen
# 	 pulmonary fibrosis seen
# 	 rib fracture seen
# 	 other lesion seen
# 	 copd seen
# 	 lung tumor seen
# 	 pneumonia seen
# 	 tuberculosis seen
# 	 other disease seen
# 	 no abnormalities seen
# Compute phrase grounding masks and labels
# self.phrase_grounding_masks.shape = (18000, 22, 169)
# self.phrase_classification_labels.shape = (18000, 22)
# Append additional labels to phrase_classification_labels
# len(non_bbox_labels) = 6
# non_bbox_labels = ['COPD', 'Lung tumor', 'Pneumonia', 'Tuberculosis', 'Other disease', 'No finding']
# self.phrase_classification_labels.shape = (18000, 28)
# Reorder phrases and phrase_embeddings
# len(phrases) = 28
# len(actual_phrases) = 28
# phrase_embeddings.shape = (28, 128)
# Generating train dataset and dataloader
# len(train_indices) = 18000
# No labels: 0
# Edema: 13
# Clavicle fracture: 29
# Lung cyst: 35
# COPD: 37
# Lung cavity: 60
# Emphysema: 84
# Rib fracture: 101
# Pneumothorax: 114
# Enlarged PA: 139
# Mediastinal shift: 170
# Atelectasis: 273
# Lung tumor: 371
# Consolidation: 449
# ILD: 618
# Calcification: 652
# Infiltration: 671
# Tuberculosis: 914
# Nodule/Mass: 1017
# Pleural effusion: 1149
# Pneumonia: 1163
# Other lesion: 1248
# Lung Opacity: 1415
# Pulmonary fibrosis: 1838
# Pleural thickening: 2179
# Cardiomegaly: 2625
# Aortic enlargement: 3318
# Other disease: 4945
# No finding: 12652
# Group sizes: [12529, 891, 444, 428, 364, 344, 307, 283, 273, 267, 245, 236, 206, 193, 170, 138, 127, 100, 99, 90, 56, 54, 49, 34, 73]
#   len(indices) = 12529, weight = 2522.6672479595745
#   len(indices) = 891, weight = 940.9850359649141
#   len(indices) = 444, weight = 680.1755171156125
#   len(indices) = 428, weight = 667.9638591411331
#   len(indices) = 364, weight = 615.8160380252455
#   len(indices) = 344, weight = 598.2811252947056
#   len(indices) = 307, weight = 563.9888635691133
#   len(indices) = 283, weight = 540.2796339164162
#   len(indices) = 273, weight = 530.0166624211873
#   len(indices) = 267, weight = 523.7422583945496
#   len(indices) = 245, weight = 499.93058392418243
#   len(indices) = 236, weight = 489.7963928535281
#   len(indices) = 206, weight = 454.1360559561945
#   len(indices) = 193, weight = 437.6702522239849
#   len(indices) = 170, weight = 406.7687016278156
#   len(indices) = 138, weight = 359.20170201154343
#   len(indices) = 127, weight = 341.33933626931963
#   len(indices) = 100, weight = 293.26529386579296
#   len(indices) = 99, weight = 291.34941227248714
#   len(indices) = 90, weight = 273.5936736738282
#   len(indices) = 56, weight = 195.85520038280242
#   len(indices) = 54, weight = 190.5945663000252
#   len(indices) = 49, weight = 177.00354049310113
#   len(indices) = 34, weight = 131.67512839151652
#   len(indices) = 73, weight = 237.15649291307946
# --------------------------------------------------
# 8) Creating MIMIC-CXR Phrase Grounding Trainer ...
# get_image_transform()
# Using standard transform
# mean = (0.485, 0.456, 0.406), std = (0.229, 0.224, 0.225), image_size = [416, 416], use_center_crop = False
# Returning transform without augmentation
# get_image_transform()
# Using standard transform
# mean = (0.485, 0.456, 0.406), std = (0.229, 0.224, 0.225), image_size = [416, 416], use_center_crop = False
# Returning transform without augmentation
# mask_exponent = 0.4
# len(forbidden_train_dicom_ids) = 1030
# Preparing MS-CXR dataset and dataloader for training/testing...
# len(dicom_id_2_phrases_and_masks) = 1047
# len(phrase2embedding) = 715
# Using image size mode: medium_512
# 227835it [00:00, 452177.47it/s]
# Total number of images: 1047
# Number of phrases: 1, # images: 939
# Number of phrases: 2, # images: 103
# Number of phrases: 3, # images: 5
# Preparing Chest Imagenome dataset and dataloader for training...
# Loding bbox_phrase_embeddings and bbox_phrases from /mnt/workspace/pamessina/medvqa-workspace/cache/chest_imagenome/bbox_phrase_embeddings(hash=333,2614535641242304201).pkl...
# bbox_phrase_embeddings.shape = (36, 128)
# len(bbox_phrases) = 36
# 	 right lung
# 	 right upper lung zone
# 	 right mid lung zone
# 	 right lower lung zone
# 	 right hilar structures
# 	 right apical zone
# 	 right costophrenic angle
# 	 right cardiophrenic angle
# 	 right hemidiaphragm
# 	 left lung
# 	 left upper lung zone
# 	 left mid lung zone
# 	 left lower lung zone
# 	 left hilar structures
# 	 left apical zone
# 	 left costophrenic angle
# 	 left hemidiaphragm
# 	 trachea
# 	 spine
# 	 right clavicle
# 	 left clavicle
# 	 aortic arch
# 	 mediastinum
# 	 upper mediastinum
# 	 svc
# 	 cardiac silhouette
# 	 left cardiac silhouette
# 	 right cardiac silhouette
# 	 cavoatrial junction
# 	 right atrium
# 	 descending aorta
# 	 carina
# 	 left upper abdomen
# 	 right upper abdomen
# 	 abdomen
# 	 left cardiophrenic angle
# Using image size mode: medium_512
# Loading precomputed bbox_coords_and_presence_and_mask from /mnt/workspace/pamessina/medvqa-workspace/cache/mimiccxr/bbox_coords_and_presence_and_mask(13,13,243310).pkl...
# 227835it [00:50, 4477.41it/s]
# Total number of images: 242280
# --------------------------------------------------
# 9) Creating dataloaders ...
# len(mimiccxr_trainer.train_mscxr_dataloader) = 82
# len(mimiccxr_trainer.test_mscxr_dataloader) = 42
# len(mimiccxr_trainer.train_chest_imagenome_dataloader) = 48456
# len(vinbig_trainer.train_dataloader) = 142857142857142858
# len(chexlocalize_trainer.train_dataloader) = 70
# len(chexlocalize_trainer.val_dataloader) = 35
# len(_train_dataloaders) = 4
# len(_val_dataloaders) = 2
# _train_weights = [0.5, 1.0, 1.0, 0.5]
# merged_dataset_name = mscxr+chst-img-anat+vinbig+chexloc
# --------------------------------------------------
# 10) Attaching metrics, losses, timer and events to engines ...
# --------------------------------------------------
# 11) Defining learning rate scheduler handler ...
# --------------------------------------------------
# 12) Defining learning rate scheduler handler ...
# --------------------------------------------------
# 13) Defining checkpoint folder path ...
# checkpoint_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240618_175951_mscxr+chst-img-anat+vinbig+chexloc_PhraseGrounder(dn121,SigmoidAttention,128,256,256,1)
# metadata saved to /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240618_175951_mscxr+chst-img-anat+vinbig+chexloc_PhraseGrounder(dn121,SigmoidAttention,128,256,256,1)/metadata.json
# --------------------------------------------------
# 14) Loading pretrained weights ...
# checkpoint_names = ['checkpoint_171_chss+chuc+clss+clcc+clou+fgss+fguc+vbss+vbuc+vbou=0.7297.pt']
# pretrained_checkpoint_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240505_224220_mim-facts+vinbig+chexloc+chxp_PhraseGrounder(dn121,128,256)/checkpoint_171_chss+chuc+clss+clcc+clou+fgss+fguc+vbss+vbuc+vbou=0.7297.pt
# Checkpoint successfully loaded!
# --------------------------------------------------
# 15) Defining log_metrics_handler ...
# MetricsLogger :: we'll be logging to /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240618_175951_mscxr+chst-img-anat+vinbig+chexloc_PhraseGrounder(dn121,SigmoidAttention,128,256,256,1)/metrics_logs.csv
# --------------------------------------------------
# 16) Running trainer engine ...
# ---- Epoch 1/100
# (1) Training stage (lr = 0.000001) ...
# loss 1.30849, cibg_att_sup_loss 2.03769, cibg_segmask_iou 0.10047, pg_att_sup_loss 1.64382, pg_segmask_iou 0.22133, vbg_phrcls_loss 0.23879, vbg_prc_auc 0.99605, vbg_att_reg_loss 0.19536, vbg_att_sup_loss 0.46762, vbg_segmask_iou 0.34639, cl_att_sup_loss 0.23950, cl_segmask_iou 0.52809, cl_phrcls_loss 0.06772, cl_phrase_acc 0.99988, 85.53 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.48929, pg_segmask_iou 0.29422, cl_att_sup_loss 0.23003, cl_segmask_iou 0.47522, cl_phrase_acc 0.98426, 30.28 secs
# New checkpoint saved: checkpoint_1_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.6367.pt
# ---- Epoch 2/100
# (1) Training stage (lr = 0.000004) ...
# loss 1.27480, cibg_att_sup_loss 1.99902, cibg_segmask_iou 0.10520, pg_att_sup_loss 1.58738, pg_segmask_iou 0.23871, vbg_phrcls_loss 0.23758, vbg_prc_auc 0.99574, vbg_att_reg_loss 0.19439, vbg_att_sup_loss 0.45436, vbg_segmask_iou 0.34590, cl_att_sup_loss 0.24045, cl_segmask_iou 0.52577, cl_phrcls_loss 0.06572, cl_phrase_acc 0.99988, 81.68 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.43990, pg_segmask_iou 0.32967, cl_att_sup_loss 0.15833, cl_segmask_iou 0.51922, cl_phrase_acc 0.99634, 33.52 secs
# New checkpoint saved: checkpoint_2_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.6668.pt
# ---- Epoch 3/100
# (1) Training stage (lr = 0.000019) ...
# loss 1.20500, cibg_att_sup_loss 1.89447, cibg_segmask_iou 0.11728, pg_att_sup_loss 1.23141, pg_segmask_iou 0.33428, vbg_phrcls_loss 0.27222, vbg_prc_auc 0.99220, vbg_att_reg_loss 0.19321, vbg_att_sup_loss 0.47671, vbg_segmask_iou 0.33608, cl_att_sup_loss 0.26034, cl_segmask_iou 0.53536, cl_phrcls_loss 0.07141, cl_phrase_acc 0.99988, 81.60 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.40216, pg_segmask_iou 0.36350, cl_att_sup_loss 0.12701, cl_segmask_iou 0.53210, cl_phrase_acc 0.99911, 33.24 secs
# New checkpoint saved: checkpoint_3_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.6849.pt
# ---- Epoch 4/100
# (1) Training stage (lr = 0.000080) ...
# loss 1.15293, cibg_att_sup_loss 1.66899, cibg_segmask_iou 0.14901, pg_att_sup_loss 1.07311, pg_segmask_iou 0.36240, vbg_phrcls_loss 0.38522, vbg_prc_auc 0.98139, vbg_att_reg_loss 0.19478, vbg_att_sup_loss 0.48913, vbg_segmask_iou 0.33585, cl_att_sup_loss 0.27665, cl_segmask_iou 0.52784, cl_phrcls_loss 0.07841, cl_phrase_acc 0.99918, 86.48 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.36110, pg_segmask_iou 0.40527, cl_att_sup_loss 0.16228, cl_segmask_iou 0.54309, cl_phrase_acc 0.99368, 33.81 secs
# New checkpoint saved: checkpoint_4_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.6934.pt
# ---- Epoch 5/100
# (1) Training stage (lr = 0.000046) ...
# loss 1.06707, cibg_att_sup_loss 1.46093, cibg_segmask_iou 0.17924, pg_att_sup_loss 0.93794, pg_segmask_iou 0.42363, vbg_phrcls_loss 0.39271, vbg_prc_auc 0.98060, vbg_att_reg_loss 0.19251, vbg_att_sup_loss 0.50590, vbg_segmask_iou 0.33534, cl_att_sup_loss 0.29358, cl_segmask_iou 0.53177, cl_phrcls_loss 0.07078, cl_phrase_acc 0.99884, 82.19 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.35440, pg_segmask_iou 0.40715, cl_att_sup_loss 0.14914, cl_segmask_iou 0.54158, cl_phrase_acc 0.99889, 34.60 secs
# New checkpoint saved: checkpoint_5_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.6982.pt
# ---- Epoch 6/100
# (1) Training stage (lr = 0.000027) ...
# loss 1.00465, cibg_att_sup_loss 1.37392, cibg_segmask_iou 0.19321, pg_att_sup_loss 0.94423, pg_segmask_iou 0.41426, vbg_phrcls_loss 0.32159, vbg_prc_auc 0.98890, vbg_att_reg_loss 0.19054, vbg_att_sup_loss 0.49028, vbg_segmask_iou 0.33562, cl_att_sup_loss 0.28029, cl_segmask_iou 0.53378, cl_phrcls_loss 0.05624, cl_phrase_acc 0.99988, 86.46 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.34588, pg_segmask_iou 0.41606, cl_att_sup_loss 0.14489, cl_segmask_iou 0.54590, cl_phrase_acc 0.99967, 35.68 secs
# New checkpoint saved: checkpoint_6_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.7026.pt
# ---- Epoch 7/100
# (1) Training stage (lr = 0.000015) ...
# loss 0.98917, cibg_att_sup_loss 1.33266, cibg_segmask_iou 0.20239, pg_att_sup_loss 0.89818, pg_segmask_iou 0.43219, vbg_phrcls_loss 0.32600, vbg_prc_auc 0.98922, vbg_att_reg_loss 0.18854, vbg_att_sup_loss 0.50336, vbg_segmask_iou 0.33760, cl_att_sup_loss 0.27741, cl_segmask_iou 0.54334, cl_phrcls_loss 0.04887, cl_phrase_acc 1.00000, 89.06 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.34564, pg_segmask_iou 0.41394, cl_att_sup_loss 0.14007, cl_segmask_iou 0.53785, cl_phrase_acc 0.99956, 35.69 secs
# ---- Epoch 8/100
# (1) Training stage (lr = 0.000009) ...
# loss 0.96495, cibg_att_sup_loss 1.30536, cibg_segmask_iou 0.20514, pg_att_sup_loss 0.87905, pg_segmask_iou 0.44062, vbg_phrcls_loss 0.30523, vbg_prc_auc 0.98955, vbg_att_reg_loss 0.18754, vbg_att_sup_loss 0.49468, vbg_segmask_iou 0.33155, cl_att_sup_loss 0.28146, cl_segmask_iou 0.54933, cl_phrcls_loss 0.04737, cl_phrase_acc 1.00000, 81.69 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.34288, pg_segmask_iou 0.41872, cl_att_sup_loss 0.14724, cl_segmask_iou 0.54410, cl_phrase_acc 0.99933, 33.83 secs
# New checkpoint saved: checkpoint_8_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.7034.pt
# ---- Epoch 9/100
# (1) Training stage (lr = 0.000005) ...
# loss 0.95209, cibg_att_sup_loss 1.29382, cibg_segmask_iou 0.20805, pg_att_sup_loss 0.89491, pg_segmask_iou 0.42433, vbg_phrcls_loss 0.27884, vbg_prc_auc 0.99226, vbg_att_reg_loss 0.18817, vbg_att_sup_loss 0.49144, vbg_segmask_iou 0.33888, cl_att_sup_loss 0.27346, cl_segmask_iou 0.54010, cl_phrcls_loss 0.04481, cl_phrase_acc 1.00000, 91.34 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.33806, pg_segmask_iou 0.42257, cl_att_sup_loss 0.13726, cl_segmask_iou 0.55063, cl_phrase_acc 0.99967, 37.12 secs
# New checkpoint saved: checkpoint_9_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.7071.pt
# ---- Epoch 10/100
# (1) Training stage (lr = 0.000003) ...
# loss 0.93562, cibg_att_sup_loss 1.28845, cibg_segmask_iou 0.20874, pg_att_sup_loss 0.84778, pg_segmask_iou 0.46037, vbg_phrcls_loss 0.25690, vbg_prc_auc 0.99327, vbg_att_reg_loss 0.18890, vbg_att_sup_loss 0.48472, vbg_segmask_iou 0.33206, cl_att_sup_loss 0.27639, cl_segmask_iou 0.54292, cl_phrcls_loss 0.04230, cl_phrase_acc 1.00000, 82.23 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.33594, pg_segmask_iou 0.42587, cl_att_sup_loss 0.14749, cl_segmask_iou 0.55342, cl_phrase_acc 0.99900, 37.14 secs
# New checkpoint saved: checkpoint_10_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.7074.pt
# ---- Epoch 11/100
# (1) Training stage (lr = 0.000002) ...
# loss 0.93344, cibg_att_sup_loss 1.28311, cibg_segmask_iou 0.20915, pg_att_sup_loss 0.89911, pg_segmask_iou 0.42501, vbg_phrcls_loss 0.25076, vbg_prc_auc 0.99394, vbg_att_reg_loss 0.18280, vbg_att_sup_loss 0.48287, vbg_segmask_iou 0.34678, cl_att_sup_loss 0.26771, cl_segmask_iou 0.54814, cl_phrcls_loss 0.03944, cl_phrase_acc 1.00000, 96.32 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.33855, pg_segmask_iou 0.42363, cl_att_sup_loss 0.15041, cl_segmask_iou 0.55105, cl_phrase_acc 0.99922, 40.81 secs
# ---- Epoch 12/100
# (1) Training stage (lr = 0.000001) ...
# loss 0.92450, cibg_att_sup_loss 1.28621, cibg_segmask_iou 0.20958, pg_att_sup_loss 0.86260, pg_segmask_iou 0.44809, vbg_phrcls_loss 0.23656, vbg_prc_auc 0.99510, vbg_att_reg_loss 0.19052, vbg_att_sup_loss 0.47252, vbg_segmask_iou 0.34280, cl_att_sup_loss 0.27575, cl_segmask_iou 0.54613, cl_phrcls_loss 0.04206, cl_phrase_acc 1.00000, 92.65 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.33619, pg_segmask_iou 0.42535, cl_att_sup_loss 0.14469, cl_segmask_iou 0.55324, cl_phrase_acc 0.99967, 37.05 secs
# New checkpoint saved: checkpoint_12_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.7078.pt
# ---- Epoch 13/100
# (1) Training stage (lr = 0.000080) ...
# loss 0.94707, cibg_att_sup_loss 1.21830, cibg_segmask_iou 0.22233, pg_att_sup_loss 0.86898, pg_segmask_iou 0.44284, vbg_phrcls_loss 0.32027, vbg_prc_auc 0.98731, vbg_att_reg_loss 0.19049, vbg_att_sup_loss 0.50312, vbg_segmask_iou 0.33579, cl_att_sup_loss 0.29348, cl_segmask_iou 0.54227, cl_phrcls_loss 0.04756, cl_phrase_acc 1.00000, 86.12 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.32345, pg_segmask_iou 0.43612, cl_att_sup_loss 0.14925, cl_segmask_iou 0.54989, cl_phrase_acc 0.99856, 38.25 secs
# New checkpoint saved: checkpoint_13_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.7094.pt
# ---- Epoch 14/100
# (1) Training stage (lr = 0.000043) ...
# loss 0.90460, cibg_att_sup_loss 1.13257, cibg_segmask_iou 0.23793, pg_att_sup_loss 0.84262, pg_segmask_iou 0.44827, vbg_phrcls_loss 0.31892, vbg_prc_auc 0.98768, vbg_att_reg_loss 0.18000, vbg_att_sup_loss 0.50107, vbg_segmask_iou 0.33920, cl_att_sup_loss 0.27815, cl_segmask_iou 0.55015, cl_phrcls_loss 0.04418, cl_phrase_acc 0.99988, 95.19 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.31586, pg_segmask_iou 0.44510, cl_att_sup_loss 0.15447, cl_segmask_iou 0.55656, cl_phrase_acc 0.99800, 36.84 secs
# New checkpoint saved: checkpoint_14_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.7129.pt
# ---- Epoch 15/100
# (1) Training stage (lr = 0.000023) ...
# loss 0.88274, cibg_att_sup_loss 1.09773, cibg_segmask_iou 0.24587, pg_att_sup_loss 0.79368, pg_segmask_iou 0.47869, vbg_phrcls_loss 0.30254, vbg_prc_auc 0.98957, vbg_att_reg_loss 0.17868, vbg_att_sup_loss 0.51073, vbg_segmask_iou 0.33503, cl_att_sup_loss 0.28470, cl_segmask_iou 0.54641, cl_phrcls_loss 0.04356, cl_phrase_acc 0.99988, 86.19 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.31216, pg_segmask_iou 0.44841, cl_att_sup_loss 0.14335, cl_segmask_iou 0.55966, cl_phrase_acc 0.99956, 40.23 secs
# New checkpoint saved: checkpoint_15_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.7167.pt
# ---- Epoch 16/100
# (1) Training stage (lr = 0.000012) ...
# loss 0.85906, cibg_att_sup_loss 1.08428, cibg_segmask_iou 0.25029, pg_att_sup_loss 0.80841, pg_segmask_iou 0.45617, vbg_phrcls_loss 0.25997, vbg_prc_auc 0.99426, vbg_att_reg_loss 0.18164, vbg_att_sup_loss 0.48966, vbg_segmask_iou 0.33066, cl_att_sup_loss 0.27258, cl_segmask_iou 0.54983, cl_phrcls_loss 0.03512, cl_phrase_acc 1.00000, 94.46 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.30591, pg_segmask_iou 0.45562, cl_att_sup_loss 0.15280, cl_segmask_iou 0.56039, cl_phrase_acc 0.99889, 36.90 secs
# New checkpoint saved: checkpoint_16_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.7174.pt
# ---- Epoch 17/100
# (1) Training stage (lr = 0.000007) ...
# loss 0.85022, cibg_att_sup_loss 1.06537, cibg_segmask_iou 0.25358, pg_att_sup_loss 0.77019, pg_segmask_iou 0.48788, vbg_phrcls_loss 0.26873, vbg_prc_auc 0.99191, vbg_att_reg_loss 0.18257, vbg_att_sup_loss 0.49742, vbg_segmask_iou 0.34468, cl_att_sup_loss 0.27177, cl_segmask_iou 0.55060, cl_phrcls_loss 0.03319, cl_phrase_acc 1.00000, 90.93 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.30605, pg_segmask_iou 0.45587, cl_att_sup_loss 0.15394, cl_segmask_iou 0.56010, cl_phrase_acc 0.99933, 35.31 secs
# New checkpoint saved: checkpoint_17_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.7179.pt
# ---- Epoch 18/100
# (1) Training stage (lr = 0.000003) ...
# loss 0.84397, cibg_att_sup_loss 1.06977, cibg_segmask_iou 0.25436, pg_att_sup_loss 0.78442, pg_segmask_iou 0.47044, vbg_phrcls_loss 0.25184, vbg_prc_auc 0.99387, vbg_att_reg_loss 0.18018, vbg_att_sup_loss 0.48982, vbg_segmask_iou 0.33748, cl_att_sup_loss 0.27013, cl_segmask_iou 0.55768, cl_phrcls_loss 0.03059, cl_phrase_acc 1.00000, 89.94 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.30523, pg_segmask_iou 0.45665, cl_att_sup_loss 0.15087, cl_segmask_iou 0.56244, cl_phrase_acc 0.99978, 37.63 secs
# New checkpoint saved: checkpoint_18_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.7189.pt
# ---- Epoch 19/100
# (1) Training stage (lr = 0.000002) ...
# loss 0.83000, cibg_att_sup_loss 1.06212, cibg_segmask_iou 0.25471, pg_att_sup_loss 0.77859, pg_segmask_iou 0.47370, vbg_phrcls_loss 0.23118, vbg_prc_auc 0.99483, vbg_att_reg_loss 0.17838, vbg_att_sup_loss 0.47809, vbg_segmask_iou 0.34208, cl_att_sup_loss 0.26325, cl_segmask_iou 0.55369, cl_phrcls_loss 0.03148, cl_phrase_acc 1.00000, 97.01 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.30423, pg_segmask_iou 0.45661, cl_att_sup_loss 0.14236, cl_segmask_iou 0.56223, cl_phrase_acc 0.99945, 37.42 secs
# New checkpoint saved: checkpoint_19_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.7202.pt
# ---- Epoch 20/100
# (1) Training stage (lr = 0.000001) ...
# loss 0.82103, cibg_att_sup_loss 1.05155, cibg_segmask_iou 0.25607, pg_att_sup_loss 0.76649, pg_segmask_iou 0.48676, vbg_phrcls_loss 0.22641, vbg_prc_auc 0.99528, vbg_att_reg_loss 0.17987, vbg_att_sup_loss 0.47323, vbg_segmask_iou 0.34304, cl_att_sup_loss 0.26929, cl_segmask_iou 0.55141, cl_phrcls_loss 0.03091, cl_phrase_acc 1.00000, 85.15 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.30800, pg_segmask_iou 0.45271, cl_att_sup_loss 0.14795, cl_segmask_iou 0.55832, cl_phrase_acc 0.99945, 36.68 secs
# ---- Epoch 21/100
# (1) Training stage (lr = 0.000080) ...
# loss 0.85042, cibg_att_sup_loss 1.02405, cibg_segmask_iou 0.26579, pg_att_sup_loss 0.78728, pg_segmask_iou 0.46573, vbg_phrcls_loss 0.29545, vbg_prc_auc 0.98807, vbg_att_reg_loss 0.17935, vbg_att_sup_loss 0.50307, vbg_segmask_iou 0.34225, cl_att_sup_loss 0.27681, cl_segmask_iou 0.55291, cl_phrcls_loss 0.03913, cl_phrase_acc 1.00000, 89.29 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.29931, pg_segmask_iou 0.46686, cl_att_sup_loss 0.15793, cl_segmask_iou 0.56091, cl_phrase_acc 0.99767, 39.25 secs
# ---- Epoch 22/100
# (1) Training stage (lr = 0.000043) ...
# loss 0.82183, cibg_att_sup_loss 0.96339, cibg_segmask_iou 0.28096, pg_att_sup_loss 0.73592, pg_segmask_iou 0.50742, vbg_phrcls_loss 0.28494, vbg_prc_auc 0.99104, vbg_att_reg_loss 0.17750, vbg_att_sup_loss 0.50790, vbg_segmask_iou 0.33392, cl_att_sup_loss 0.27972, cl_segmask_iou 0.55820, cl_phrcls_loss 0.04262, cl_phrase_acc 0.99965, 89.05 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.28901, pg_segmask_iou 0.47468, cl_att_sup_loss 0.15415, cl_segmask_iou 0.56109, cl_phrase_acc 0.99767, 41.54 secs
# New checkpoint saved: checkpoint_22_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.7236.pt
# ---- Epoch 23/100
# (1) Training stage (lr = 0.000023) ...
# loss 0.80384, cibg_att_sup_loss 0.95415, cibg_segmask_iou 0.28522, pg_att_sup_loss 0.73930, pg_segmask_iou 0.49335, vbg_phrcls_loss 0.26352, vbg_prc_auc 0.99253, vbg_att_reg_loss 0.17427, vbg_att_sup_loss 0.49844, vbg_segmask_iou 0.34176, cl_att_sup_loss 0.26769, cl_segmask_iou 0.55941, cl_phrcls_loss 0.03658, cl_phrase_acc 1.00000, 92.08 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.29004, pg_segmask_iou 0.47667, cl_att_sup_loss 0.15706, cl_segmask_iou 0.56149, cl_phrase_acc 0.99922, 38.22 secs
# New checkpoint saved: checkpoint_23_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.7240.pt
# ---- Epoch 24/100
# (1) Training stage (lr = 0.000012) ...
# loss 0.78672, cibg_att_sup_loss 0.94113, cibg_segmask_iou 0.28547, pg_att_sup_loss 0.70982, pg_segmask_iou 0.50781, vbg_phrcls_loss 0.24559, vbg_prc_auc 0.99349, vbg_att_reg_loss 0.17661, vbg_att_sup_loss 0.49574, vbg_segmask_iou 0.34444, cl_att_sup_loss 0.26833, cl_segmask_iou 0.55597, cl_phrcls_loss 0.02829, cl_phrase_acc 1.00000, 94.54 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.28879, pg_segmask_iou 0.47404, cl_att_sup_loss 0.14542, cl_segmask_iou 0.56069, cl_phrase_acc 0.99956, 37.33 secs
# New checkpoint saved: checkpoint_24_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.7254.pt
# ---- Epoch 25/100
# (1) Training stage (lr = 0.000007) ...
# loss 0.78199, cibg_att_sup_loss 0.92617, cibg_segmask_iou 0.28918, pg_att_sup_loss 0.70389, pg_segmask_iou 0.51031, vbg_phrcls_loss 0.24748, vbg_prc_auc 0.99425, vbg_att_reg_loss 0.18046, vbg_att_sup_loss 0.48795, vbg_segmask_iou 0.33741, cl_att_sup_loss 0.26894, cl_segmask_iou 0.56001, cl_phrcls_loss 0.02977, cl_phrase_acc 1.00000, 88.01 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.28053, pg_segmask_iou 0.48479, cl_att_sup_loss 0.15918, cl_segmask_iou 0.56546, cl_phrase_acc 0.99922, 39.20 secs
# New checkpoint saved: checkpoint_25_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.7273.pt
# ---- Epoch 26/100
# (1) Training stage (lr = 0.000003) ...
# loss 0.77561, cibg_att_sup_loss 0.92817, cibg_segmask_iou 0.29169, pg_att_sup_loss 0.70820, pg_segmask_iou 0.49874, vbg_phrcls_loss 0.24394, vbg_prc_auc 0.99324, vbg_att_reg_loss 0.17084, vbg_att_sup_loss 0.49019, vbg_segmask_iou 0.34035, cl_att_sup_loss 0.25367, cl_segmask_iou 0.56078, cl_phrcls_loss 0.02676, cl_phrase_acc 1.00000, 94.44 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.28693, pg_segmask_iou 0.47795, cl_att_sup_loss 0.14562, cl_segmask_iou 0.56439, cl_phrase_acc 0.99967, 38.95 secs
# ---- Epoch 27/100
# (1) Training stage (lr = 0.000002) ...
# loss 0.74944, cibg_att_sup_loss 0.92471, cibg_segmask_iou 0.29220, pg_att_sup_loss 0.68609, pg_segmask_iou 0.52835, vbg_phrcls_loss 0.19517, vbg_prc_auc 0.99696, vbg_att_reg_loss 0.17046, vbg_att_sup_loss 0.47277, vbg_segmask_iou 0.35093, cl_att_sup_loss 0.26181, cl_segmask_iou 0.55997, cl_phrcls_loss 0.02643, cl_phrase_acc 1.00000, 89.98 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.28515, pg_segmask_iou 0.47919, cl_att_sup_loss 0.14557, cl_segmask_iou 0.56463, cl_phrase_acc 0.99945, 40.94 secs
# New checkpoint saved: checkpoint_27_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.7281.pt
# ---- Epoch 28/100
# (1) Training stage (lr = 0.000001) ...
# loss 0.76399, cibg_att_sup_loss 0.91759, cibg_segmask_iou 0.29195, pg_att_sup_loss 0.71002, pg_segmask_iou 0.49845, vbg_phrcls_loss 0.21680, vbg_prc_auc 0.99511, vbg_att_reg_loss 0.17375, vbg_att_sup_loss 0.48137, vbg_segmask_iou 0.34927, cl_att_sup_loss 0.26241, cl_segmask_iou 0.56513, cl_phrcls_loss 0.02701, cl_phrase_acc 1.00000, 93.79 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.28148, pg_segmask_iou 0.48403, cl_att_sup_loss 0.15317, cl_segmask_iou 0.56637, cl_phrase_acc 0.99933, 41.20 secs
# New checkpoint saved: checkpoint_28_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.7282.pt
# ---- Epoch 29/100
# (1) Training stage (lr = 0.000080) ...
# loss 0.78151, cibg_att_sup_loss 0.90293, cibg_segmask_iou 0.29812, pg_att_sup_loss 0.70087, pg_segmask_iou 0.51862, vbg_phrcls_loss 0.27436, vbg_prc_auc 0.99061, vbg_att_reg_loss 0.17227, vbg_att_sup_loss 0.49569, vbg_segmask_iou 0.34105, cl_att_sup_loss 0.26596, cl_segmask_iou 0.56175, cl_phrcls_loss 0.03236, cl_phrase_acc 0.99988, 98.59 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.27780, pg_segmask_iou 0.49005, cl_att_sup_loss 0.15627, cl_segmask_iou 0.56642, cl_phrase_acc 0.99889, 39.23 secs
# New checkpoint saved: checkpoint_29_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.7293.pt
# ---- Epoch 30/100
# (1) Training stage (lr = 0.000043) ...
# loss 0.76876, cibg_att_sup_loss 0.88518, cibg_segmask_iou 0.30478, pg_att_sup_loss 0.69126, pg_segmask_iou 0.51757, vbg_phrcls_loss 0.25301, vbg_prc_auc 0.99223, vbg_att_reg_loss 0.17219, vbg_att_sup_loss 0.50278, vbg_segmask_iou 0.34443, cl_att_sup_loss 0.26448, cl_segmask_iou 0.55467, cl_phrcls_loss 0.03463, cl_phrase_acc 0.99988, 84.52 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.27333, pg_segmask_iou 0.49398, cl_att_sup_loss 0.15806, cl_segmask_iou 0.56559, cl_phrase_acc 0.99900, 38.52 secs
# New checkpoint saved: checkpoint_30_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.7303.pt
# ---- Epoch 31/100
# (1) Training stage (lr = 0.000023) ...
# loss 0.75681, cibg_att_sup_loss 0.86283, cibg_segmask_iou 0.30959, pg_att_sup_loss 0.67356, pg_segmask_iou 0.51920, vbg_phrcls_loss 0.24453, vbg_prc_auc 0.99376, vbg_att_reg_loss 0.17430, vbg_att_sup_loss 0.49893, vbg_segmask_iou 0.34263, cl_att_sup_loss 0.27192, cl_segmask_iou 0.56160, cl_phrcls_loss 0.02979, cl_phrase_acc 0.99988, 89.98 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.26758, pg_segmask_iou 0.50085, cl_att_sup_loss 0.14873, cl_segmask_iou 0.57537, cl_phrase_acc 0.99956, 39.94 secs
# New checkpoint saved: checkpoint_31_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.7355.pt
# ---- Epoch 32/100
# (1) Training stage (lr = 0.000012) ...
# loss 0.73391, cibg_att_sup_loss 0.85825, cibg_segmask_iou 0.31255, pg_att_sup_loss 0.64109, pg_segmask_iou 0.54662, vbg_phrcls_loss 0.22279, vbg_prc_auc 0.99481, vbg_att_reg_loss 0.16942, vbg_att_sup_loss 0.48785, vbg_segmask_iou 0.34314, cl_att_sup_loss 0.26081, cl_segmask_iou 0.57121, cl_phrcls_loss 0.02541, cl_phrase_acc 1.00000, 84.64 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.27216, pg_segmask_iou 0.49499, cl_att_sup_loss 0.14706, cl_segmask_iou 0.56597, cl_phrase_acc 0.99945, 38.30 secs
# ---- Epoch 33/100
# (1) Training stage (lr = 0.000007) ...
# loss 0.73744, cibg_att_sup_loss 0.86380, cibg_segmask_iou 0.31178, pg_att_sup_loss 0.65892, pg_segmask_iou 0.52029, vbg_phrcls_loss 0.22608, vbg_prc_auc 0.99443, vbg_att_reg_loss 0.17128, vbg_att_sup_loss 0.48367, vbg_segmask_iou 0.34526, cl_att_sup_loss 0.25654, cl_segmask_iou 0.56467, cl_phrcls_loss 0.02356, cl_phrase_acc 0.99988, 92.45 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.26942, pg_segmask_iou 0.49755, cl_att_sup_loss 0.14194, cl_segmask_iou 0.57159, cl_phrase_acc 0.99967, 38.74 secs
# ---- Epoch 34/100
# (1) Training stage (lr = 0.000003) ...
# loss 0.71504, cibg_att_sup_loss 0.85426, cibg_segmask_iou 0.31402, pg_att_sup_loss 0.63335, pg_segmask_iou 0.55038, vbg_phrcls_loss 0.20369, vbg_prc_auc 0.99516, vbg_att_reg_loss 0.16734, vbg_att_sup_loss 0.46577, vbg_segmask_iou 0.34643, cl_att_sup_loss 0.24810, cl_segmask_iou 0.56283, cl_phrcls_loss 0.02182, cl_phrase_acc 1.00000, 88.93 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.25801, pg_segmask_iou 0.51452, cl_att_sup_loss 0.17020, cl_segmask_iou 0.57475, cl_phrase_acc 0.99933, 37.36 secs
# New checkpoint saved: checkpoint_34_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.7369.pt
# ---- Epoch 35/100
# (1) Training stage (lr = 0.000002) ...
# loss 0.72246, cibg_att_sup_loss 0.84743, cibg_segmask_iou 0.31643, pg_att_sup_loss 0.64426, pg_segmask_iou 0.53236, vbg_phrcls_loss 0.21084, vbg_prc_auc 0.99479, vbg_att_reg_loss 0.16821, vbg_att_sup_loss 0.48003, vbg_segmask_iou 0.35128, cl_att_sup_loss 0.25688, cl_segmask_iou 0.56858, cl_phrcls_loss 0.02132, cl_phrase_acc 1.00000, 93.10 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.27248, pg_segmask_iou 0.49456, cl_att_sup_loss 0.14821, cl_segmask_iou 0.56652, cl_phrase_acc 0.99933, 39.02 secs
# ---- Epoch 36/100
# (1) Training stage (lr = 0.000001) ...
# loss 0.71449, cibg_att_sup_loss 0.85043, cibg_segmask_iou 0.31398, pg_att_sup_loss 0.64021, pg_segmask_iou 0.53545, vbg_phrcls_loss 0.19133, vbg_prc_auc 0.99586, vbg_att_reg_loss 0.17172, vbg_att_sup_loss 0.47520, vbg_segmask_iou 0.35001, cl_att_sup_loss 0.25118, cl_segmask_iou 0.57022, cl_phrcls_loss 0.02210, cl_phrase_acc 1.00000, 85.60 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.26745, pg_segmask_iou 0.50022, cl_att_sup_loss 0.14476, cl_segmask_iou 0.57029, cl_phrase_acc 0.99967, 37.47 secs
# ---- Epoch 37/100
# (1) Training stage (lr = 0.000080) ...
# loss 0.74933, cibg_att_sup_loss 0.84040, cibg_segmask_iou 0.32075, pg_att_sup_loss 0.64714, pg_segmask_iou 0.54328, vbg_phrcls_loss 0.27038, vbg_prc_auc 0.99007, vbg_att_reg_loss 0.16662, vbg_att_sup_loss 0.49988, vbg_segmask_iou 0.34219, cl_att_sup_loss 0.25662, cl_segmask_iou 0.56035, cl_phrcls_loss 0.03359, cl_phrase_acc 0.99965, 83.75 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.26441, pg_segmask_iou 0.50502, cl_att_sup_loss 0.15692, cl_segmask_iou 0.56996, cl_phrase_acc 0.99856, 39.33 secs
# ---- Epoch 38/100
# (1) Training stage (lr = 0.000043) ...
# loss 0.75602, cibg_att_sup_loss 0.83633, cibg_segmask_iou 0.32280, pg_att_sup_loss 0.65563, pg_segmask_iou 0.52576, vbg_phrcls_loss 0.28796, vbg_prc_auc 0.98955, vbg_att_reg_loss 0.17002, vbg_att_sup_loss 0.49699, vbg_segmask_iou 0.34811, cl_att_sup_loss 0.25999, cl_segmask_iou 0.56477, cl_phrcls_loss 0.03761, cl_phrase_acc 0.99942, 93.89 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.26411, pg_segmask_iou 0.50576, cl_att_sup_loss 0.15998, cl_segmask_iou 0.56988, cl_phrase_acc 0.99823, 37.71 secs
# ---- Epoch 39/100
# (1) Training stage (lr = 0.000023) ...
# loss 0.71050, cibg_att_sup_loss 0.81309, cibg_segmask_iou 0.32850, pg_att_sup_loss 0.60681, pg_segmask_iou 0.56452, vbg_phrcls_loss 0.20955, vbg_prc_auc 0.99588, vbg_att_reg_loss 0.16696, vbg_att_sup_loss 0.49877, vbg_segmask_iou 0.34430, cl_att_sup_loss 0.25701, cl_segmask_iou 0.56971, cl_phrcls_loss 0.02644, cl_phrase_acc 0.99988, 87.27 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.25923, pg_segmask_iou 0.51002, cl_att_sup_loss 0.14425, cl_segmask_iou 0.57669, cl_phrase_acc 0.99967, 40.05 secs
# New checkpoint saved: checkpoint_39_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.7402.pt
# ---- Epoch 40/100
# (1) Training stage (lr = 0.000012) ...
# loss 0.70923, cibg_att_sup_loss 0.81459, cibg_segmask_iou 0.33257, pg_att_sup_loss 0.62287, pg_segmask_iou 0.54527, vbg_phrcls_loss 0.21283, vbg_prc_auc 0.99583, vbg_att_reg_loss 0.16859, vbg_att_sup_loss 0.48482, vbg_segmask_iou 0.34018, cl_att_sup_loss 0.24323, cl_segmask_iou 0.56249, cl_phrcls_loss 0.02333, cl_phrase_acc 1.00000, 90.28 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.25210, pg_segmask_iou 0.51992, cl_att_sup_loss 0.15116, cl_segmask_iou 0.57684, cl_phrase_acc 0.99978, 37.25 secs
# New checkpoint saved: checkpoint_40_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.7417.pt
# ---- Epoch 41/100
# (1) Training stage (lr = 0.000007) ...
# loss 0.68746, cibg_att_sup_loss 0.80395, cibg_segmask_iou 0.33075, pg_att_sup_loss 0.59916, pg_segmask_iou 0.55975, vbg_phrcls_loss 0.18754, vbg_prc_auc 0.99681, vbg_att_reg_loss 0.16482, vbg_att_sup_loss 0.47556, vbg_segmask_iou 0.35413, cl_att_sup_loss 0.24187, cl_segmask_iou 0.57080, cl_phrcls_loss 0.02040, cl_phrase_acc 1.00000, 87.37 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.25837, pg_segmask_iou 0.51091, cl_att_sup_loss 0.14421, cl_segmask_iou 0.57412, cl_phrase_acc 0.99967, 37.94 secs
# ---- Epoch 42/100
# (1) Training stage (lr = 0.000003) ...
# loss 0.68439, cibg_att_sup_loss 0.80934, cibg_segmask_iou 0.33181, pg_att_sup_loss 0.59609, pg_segmask_iou 0.56054, vbg_phrcls_loss 0.18651, vbg_prc_auc 0.99704, vbg_att_reg_loss 0.16120, vbg_att_sup_loss 0.46940, vbg_segmask_iou 0.34981, cl_att_sup_loss 0.24293, cl_segmask_iou 0.56825, cl_phrcls_loss 0.01831, cl_phrase_acc 1.00000, 80.85 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.25787, pg_segmask_iou 0.51156, cl_att_sup_loss 0.14726, cl_segmask_iou 0.57307, cl_phrase_acc 0.99978, 37.80 secs
# ---- Epoch 43/100
# (1) Training stage (lr = 0.000002) ...
# loss 0.68709, cibg_att_sup_loss 0.80821, cibg_segmask_iou 0.33142, pg_att_sup_loss 0.60109, pg_segmask_iou 0.54894, vbg_phrcls_loss 0.18963, vbg_prc_auc 0.99605, vbg_att_reg_loss 0.16637, vbg_att_sup_loss 0.46558, vbg_segmask_iou 0.35405, cl_att_sup_loss 0.23861, cl_segmask_iou 0.56883, cl_phrcls_loss 0.01883, cl_phrase_acc 1.00000, 90.44 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.25184, pg_segmask_iou 0.51971, cl_att_sup_loss 0.14344, cl_segmask_iou 0.57787, cl_phrase_acc 0.99989, 38.94 secs
# New checkpoint saved: checkpoint_43_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.7434.pt
# ---- Epoch 44/100
# (1) Training stage (lr = 0.000001) ...
# loss 0.69785, cibg_att_sup_loss 0.80944, cibg_segmask_iou 0.33305, pg_att_sup_loss 0.58097, pg_segmask_iou 0.57810, vbg_phrcls_loss 0.19971, vbg_prc_auc 0.99583, vbg_att_reg_loss 0.16887, vbg_att_sup_loss 0.49342, vbg_segmask_iou 0.35143, cl_att_sup_loss 0.24422, cl_segmask_iou 0.56500, cl_phrcls_loss 0.01897, cl_phrase_acc 1.00000, 87.43 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.25917, pg_segmask_iou 0.51071, cl_att_sup_loss 0.15416, cl_segmask_iou 0.57188, cl_phrase_acc 0.99956, 38.46 secs
# ---- Epoch 45/100
# (1) Training stage (lr = 0.000080) ...
# loss 0.71455, cibg_att_sup_loss 0.80213, cibg_segmask_iou 0.33761, pg_att_sup_loss 0.62164, pg_segmask_iou 0.54241, vbg_phrcls_loss 0.23540, vbg_prc_auc 0.99330, vbg_att_reg_loss 0.16594, vbg_att_sup_loss 0.49394, vbg_segmask_iou 0.33900, cl_att_sup_loss 0.25086, cl_segmask_iou 0.57146, cl_phrcls_loss 0.02399, cl_phrase_acc 1.00000, 95.64 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.25688, pg_segmask_iou 0.51676, cl_att_sup_loss 0.15123, cl_segmask_iou 0.57802, cl_phrase_acc 0.99956, 39.80 secs
# ---- Epoch 46/100
# (1) Training stage (lr = 0.000043) ...
# loss 0.71044, cibg_att_sup_loss 0.78812, cibg_segmask_iou 0.34159, pg_att_sup_loss 0.59921, pg_segmask_iou 0.56968, vbg_phrcls_loss 0.25172, vbg_prc_auc 0.99203, vbg_att_reg_loss 0.16438, vbg_att_sup_loss 0.49418, vbg_segmask_iou 0.34770, cl_att_sup_loss 0.23956, cl_segmask_iou 0.56460, cl_phrcls_loss 0.02337, cl_phrase_acc 1.00000, 95.33 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.25235, pg_segmask_iou 0.51912, cl_att_sup_loss 0.14690, cl_segmask_iou 0.57766, cl_phrase_acc 0.99989, 38.05 secs
# ---- Epoch 47/100
# (1) Training stage (lr = 0.000023) ...
# loss 0.69711, cibg_att_sup_loss 0.78572, cibg_segmask_iou 0.34524, pg_att_sup_loss 0.58916, pg_segmask_iou 0.56551, vbg_phrcls_loss 0.21916, vbg_prc_auc 0.99383, vbg_att_reg_loss 0.16868, vbg_att_sup_loss 0.48624, vbg_segmask_iou 0.35402, cl_att_sup_loss 0.25173, cl_segmask_iou 0.57603, cl_phrcls_loss 0.02187, cl_phrase_acc 1.00000, 87.13 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.25214, pg_segmask_iou 0.52122, cl_att_sup_loss 0.15406, cl_segmask_iou 0.57701, cl_phrase_acc 0.99989, 38.45 secs
# ---- Epoch 48/100
# (1) Training stage (lr = 0.000012) ...
# loss 0.67327, cibg_att_sup_loss 0.76527, cibg_segmask_iou 0.34856, pg_att_sup_loss 0.57556, pg_segmask_iou 0.56579, vbg_phrcls_loss 0.19101, vbg_prc_auc 0.99716, vbg_att_reg_loss 0.16110, vbg_att_sup_loss 0.48305, vbg_segmask_iou 0.35274, cl_att_sup_loss 0.24787, cl_segmask_iou 0.56457, cl_phrcls_loss 0.01915, cl_phrase_acc 1.00000, 96.08 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.24750, pg_segmask_iou 0.52525, cl_att_sup_loss 0.15713, cl_segmask_iou 0.57375, cl_phrase_acc 0.99933, 40.10 secs
# ---- Epoch 49/100
# (1) Training stage (lr = 0.000007) ...
# loss 0.66946, cibg_att_sup_loss 0.76738, cibg_segmask_iou 0.34749, pg_att_sup_loss 0.55270, pg_segmask_iou 0.58852, vbg_phrcls_loss 0.19132, vbg_prc_auc 0.99643, vbg_att_reg_loss 0.16565, vbg_att_sup_loss 0.47976, vbg_segmask_iou 0.34935, cl_att_sup_loss 0.23590, cl_segmask_iou 0.57007, cl_phrcls_loss 0.01623, cl_phrase_acc 1.00000, 88.00 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.23978, pg_segmask_iou 0.53483, cl_att_sup_loss 0.16715, cl_segmask_iou 0.57584, cl_phrase_acc 0.99945, 37.53 secs
# New checkpoint saved: checkpoint_49_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.7447.pt
# ---- Epoch 50/100
# (1) Training stage (lr = 0.000003) ...
# loss 0.66625, cibg_att_sup_loss 0.77794, cibg_segmask_iou 0.34614, pg_att_sup_loss 0.57110, pg_segmask_iou 0.56230, vbg_phrcls_loss 0.17904, vbg_prc_auc 0.99639, vbg_att_reg_loss 0.16157, vbg_att_sup_loss 0.46984, vbg_segmask_iou 0.34948, cl_att_sup_loss 0.23356, cl_segmask_iou 0.56658, cl_phrcls_loss 0.01631, cl_phrase_acc 1.00000, 92.88 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.24825, pg_segmask_iou 0.52442, cl_att_sup_loss 0.15402, cl_segmask_iou 0.57445, cl_phrase_acc 0.99978, 41.00 secs
# ---- Epoch 51/100
# (1) Training stage (lr = 0.000002) ...
# loss 0.66726, cibg_att_sup_loss 0.77575, cibg_segmask_iou 0.34939, pg_att_sup_loss 0.54955, pg_segmask_iou 0.59008, vbg_phrcls_loss 0.18958, vbg_prc_auc 0.99624, vbg_att_reg_loss 0.16372, vbg_att_sup_loss 0.47356, vbg_segmask_iou 0.35093, cl_att_sup_loss 0.23632, cl_segmask_iou 0.57493, cl_phrcls_loss 0.01651, cl_phrase_acc 1.00000, 91.77 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.24641, pg_segmask_iou 0.52616, cl_att_sup_loss 0.14731, cl_segmask_iou 0.57944, cl_phrase_acc 0.99967, 40.02 secs
# New checkpoint saved: checkpoint_51_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.7458.pt
# ---- Epoch 52/100
# (1) Training stage (lr = 0.000001) ...
# loss 0.66707, cibg_att_sup_loss 0.77216, cibg_segmask_iou 0.34840, pg_att_sup_loss 0.56203, pg_segmask_iou 0.57477, vbg_phrcls_loss 0.18521, vbg_prc_auc 0.99620, vbg_att_reg_loss 0.16405, vbg_att_sup_loss 0.47150, vbg_segmask_iou 0.35247, cl_att_sup_loss 0.23451, cl_segmask_iou 0.57044, cl_phrcls_loss 0.01613, cl_phrase_acc 1.00000, 94.13 secs
# (2) Validation stage ...
# ...
# ---- Epoch 74/100
# (1) Training stage (lr = 0.000003) ...
# loss 0.60311, cibg_att_sup_loss 0.69421, cibg_segmask_iou 0.38911, pg_att_sup_loss 0.47989, pg_segmask_iou 0.60976, vbg_phrcls_loss 0.14702, vbg_prc_auc 0.99810, vbg_att_reg_loss 0.15493, vbg_att_sup_loss 0.46521, vbg_segmask_iou 0.35609, cl_att_sup_loss 0.20434, cl_segmask_iou 0.57038, cl_phrcls_loss 0.01119, cl_phrase_acc 1.00000, 94.09 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.22855, pg_segmask_iou 0.54727, cl_att_sup_loss 0.15798, cl_segmask_iou 0.57800, cl_phrase_acc 0.99878, 39.79 secs
# ---- Epoch 75/100
# (1) Training stage (lr = 0.000002) ...
# loss 0.59761, cibg_att_sup_loss 0.68546, cibg_segmask_iou 0.38908, pg_att_sup_loss 0.46176, pg_segmask_iou 0.62598, vbg_phrcls_loss 0.14430, vbg_prc_auc 0.99784, vbg_att_reg_loss 0.15583, vbg_att_sup_loss 0.46290, vbg_segmask_iou 0.35795, cl_att_sup_loss 0.21860, cl_segmask_iou 0.57551, cl_phrcls_loss 0.01208, cl_phrase_acc 1.00000, 98.51 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.22484, pg_segmask_iou 0.55270, cl_att_sup_loss 0.14451, cl_segmask_iou 0.58741, cl_phrase_acc 0.99967, 39.51 secs
# New checkpoint saved: checkpoint_75_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.7567.pt
# ---- Epoch 76/100
# (1) Training stage (lr = 0.000001) ...
# loss 0.59504, cibg_att_sup_loss 0.69201, cibg_segmask_iou 0.38833, pg_att_sup_loss 0.45925, pg_segmask_iou 0.62604, vbg_phrcls_loss 0.14149, vbg_prc_auc 0.99801, vbg_att_reg_loss 0.15586, vbg_att_sup_loss 0.45447, vbg_segmask_iou 0.36262, cl_att_sup_loss 0.20931, cl_segmask_iou 0.57223, cl_phrcls_loss 0.01077, cl_phrase_acc 1.00000, 86.33 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.21367, pg_segmask_iou 0.56747, cl_att_sup_loss 0.16536, cl_segmask_iou 0.58663, cl_phrase_acc 0.99889, 37.50 secs
# New checkpoint saved: checkpoint_76_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.7577.pt
# ---- Epoch 77/100
# (1) Training stage (lr = 0.000080) ...
# loss 0.60977, cibg_att_sup_loss 0.68522, cibg_segmask_iou 0.39191, pg_att_sup_loss 0.49057, pg_segmask_iou 0.60846, vbg_phrcls_loss 0.16249, vbg_prc_auc 0.99665, vbg_att_reg_loss 0.15601, vbg_att_sup_loss 0.46703, vbg_segmask_iou 0.34890, cl_att_sup_loss 0.21367, cl_segmask_iou 0.57579, cl_phrcls_loss 0.01224, cl_phrase_acc 1.00000, 91.29 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.22655, pg_segmask_iou 0.55353, cl_att_sup_loss 0.19077, cl_segmask_iou 0.57170, cl_phrase_acc 0.99745, 37.65 secs
# ---- Epoch 78/100
# (1) Training stage (lr = 0.000043) ...
# loss 0.63018, cibg_att_sup_loss 0.67713, cibg_segmask_iou 0.39518, pg_att_sup_loss 0.47639, pg_segmask_iou 0.63125, vbg_phrcls_loss 0.21305, vbg_prc_auc 0.99447, vbg_att_reg_loss 0.15918, vbg_att_sup_loss 0.48611, vbg_segmask_iou 0.35258, cl_att_sup_loss 0.22161, cl_segmask_iou 0.56556, cl_phrcls_loss 0.01621, cl_phrase_acc 1.00000, 86.44 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.22992, pg_segmask_iou 0.54494, cl_att_sup_loss 0.14546, cl_segmask_iou 0.58460, cl_phrase_acc 0.99812, 40.75 secs
# ---- Epoch 79/100
# (1) Training stage (lr = 0.000023) ...
# loss 0.61678, cibg_att_sup_loss 0.68862, cibg_segmask_iou 0.39351, pg_att_sup_loss 0.47761, pg_segmask_iou 0.61191, vbg_phrcls_loss 0.16876, vbg_prc_auc 0.99630, vbg_att_reg_loss 0.15713, vbg_att_sup_loss 0.47553, vbg_segmask_iou 0.35679, cl_att_sup_loss 0.22342, cl_segmask_iou 0.57799, cl_phrcls_loss 0.01674, cl_phrase_acc 0.99988, 96.16 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.20853, pg_segmask_iou 0.57504, cl_att_sup_loss 0.17527, cl_segmask_iou 0.58272, cl_phrase_acc 0.99834, 39.31 secs
# ---- Epoch 80/100
# (1) Training stage (lr = 0.000012) ...
# loss 0.59560, cibg_att_sup_loss 0.67695, cibg_segmask_iou 0.39615, pg_att_sup_loss 0.44831, pg_segmask_iou 0.63972, vbg_phrcls_loss 0.14796, vbg_prc_auc 0.99793, vbg_att_reg_loss 0.15206, vbg_att_sup_loss 0.47623, vbg_segmask_iou 0.35719, cl_att_sup_loss 0.20527, cl_segmask_iou 0.57532, cl_phrcls_loss 0.01262, cl_phrase_acc 1.00000, 89.59 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.21838, pg_segmask_iou 0.56126, cl_att_sup_loss 0.14988, cl_segmask_iou 0.58665, cl_phrase_acc 0.99922, 41.34 secs
# New checkpoint saved: checkpoint_80_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.7584.pt
# ---- Epoch 81/100
# (1) Training stage (lr = 0.000007) ...
# loss 0.58204, cibg_att_sup_loss 0.66983, cibg_segmask_iou 0.39753, pg_att_sup_loss 0.44365, pg_segmask_iou 0.63240, vbg_phrcls_loss 0.13682, vbg_prc_auc 0.99852, vbg_att_reg_loss 0.15225, vbg_att_sup_loss 0.46062, vbg_segmask_iou 0.35875, cl_att_sup_loss 0.20276, cl_segmask_iou 0.57271, cl_phrcls_loss 0.01060, cl_phrase_acc 1.00000, 94.27 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.22269, pg_segmask_iou 0.55514, cl_att_sup_loss 0.13644, cl_segmask_iou 0.58929, cl_phrase_acc 0.99933, 43.40 secs
# New checkpoint saved: checkpoint_81_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.7592.pt
# ---- Epoch 82/100
# (1) Training stage (lr = 0.000003) ...
# loss 0.58037, cibg_att_sup_loss 0.67346, cibg_segmask_iou 0.39791, pg_att_sup_loss 0.44348, pg_segmask_iou 0.63047, vbg_phrcls_loss 0.12594, vbg_prc_auc 0.99848, vbg_att_reg_loss 0.15183, vbg_att_sup_loss 0.45591, vbg_segmask_iou 0.36098, cl_att_sup_loss 0.21039, cl_segmask_iou 0.57730, cl_phrcls_loss 0.01103, cl_phrase_acc 1.00000, 94.23 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.20786, pg_segmask_iou 0.57459, cl_att_sup_loss 0.17157, cl_segmask_iou 0.58327, cl_phrase_acc 0.99767, 43.58 secs
# ---- Epoch 83/100
# (1) Training stage (lr = 0.000002) ...
# loss 0.59100, cibg_att_sup_loss 0.67440, cibg_segmask_iou 0.39652, pg_att_sup_loss 0.42872, pg_segmask_iou 0.64715, vbg_phrcls_loss 0.14066, vbg_prc_auc 0.99755, vbg_att_reg_loss 0.15887, vbg_att_sup_loss 0.47802, vbg_segmask_iou 0.35075, cl_att_sup_loss 0.20218, cl_segmask_iou 0.57457, cl_phrcls_loss 0.01004, cl_phrase_acc 1.00000, 87.32 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.21888, pg_segmask_iou 0.56044, cl_att_sup_loss 0.15697, cl_segmask_iou 0.58446, cl_phrase_acc 0.99889, 39.00 secs
# ---- Epoch 84/100
# (1) Training stage (lr = 0.000001) ...
# loss 0.56872, cibg_att_sup_loss 0.66578, cibg_segmask_iou 0.39944, pg_att_sup_loss 0.44319, pg_segmask_iou 0.62252, vbg_phrcls_loss 0.11215, vbg_prc_auc 0.99930, vbg_att_reg_loss 0.15104, vbg_att_sup_loss 0.44830, vbg_segmask_iou 0.36571, cl_att_sup_loss 0.20775, cl_segmask_iou 0.57417, cl_phrcls_loss 0.01041, cl_phrase_acc 1.00000, 96.36 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.21705, pg_segmask_iou 0.56424, cl_att_sup_loss 0.16245, cl_segmask_iou 0.58339, cl_phrase_acc 0.99911, 39.84 secs
# ---- Epoch 85/100
# (1) Training stage (lr = 0.000080) ...
# loss 0.61061, cibg_att_sup_loss 0.68259, cibg_segmask_iou 0.39742, pg_att_sup_loss 0.45610, pg_segmask_iou 0.64097, vbg_phrcls_loss 0.17808, vbg_prc_auc 0.99559, vbg_att_reg_loss 0.15600, vbg_att_sup_loss 0.47139, vbg_segmask_iou 0.36036, cl_att_sup_loss 0.21199, cl_segmask_iou 0.57476, cl_phrcls_loss 0.01668, cl_phrase_acc 1.00000, 94.75 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.21294, pg_segmask_iou 0.57363, cl_att_sup_loss 0.17219, cl_segmask_iou 0.58709, cl_phrase_acc 0.99823, 42.01 secs
# ---- Epoch 86/100
# (1) Training stage (lr = 0.000043) ...
# loss 0.62654, cibg_att_sup_loss 0.68347, cibg_segmask_iou 0.40092, pg_att_sup_loss 0.47701, pg_segmask_iou 0.62108, vbg_phrcls_loss 0.19619, vbg_prc_auc 0.99415, vbg_att_reg_loss 0.15852, vbg_att_sup_loss 0.48370, vbg_segmask_iou 0.35070, cl_att_sup_loss 0.22012, cl_segmask_iou 0.57437, cl_phrcls_loss 0.01698, cl_phrase_acc 1.00000, 95.85 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.21488, pg_segmask_iou 0.56734, cl_att_sup_loss 0.17090, cl_segmask_iou 0.58564, cl_phrase_acc 0.99823, 43.49 secs
# ---- Epoch 87/100
# (1) Training stage (lr = 0.000023) ...
# loss 0.59029, cibg_att_sup_loss 0.66740, cibg_segmask_iou 0.40268, pg_att_sup_loss 0.45115, pg_segmask_iou 0.63294, vbg_phrcls_loss 0.14643, vbg_prc_auc 0.99796, vbg_att_reg_loss 0.15256, vbg_att_sup_loss 0.46895, vbg_segmask_iou 0.35662, cl_att_sup_loss 0.21020, cl_segmask_iou 0.57664, cl_phrcls_loss 0.01350, cl_phrase_acc 1.00000, 95.68 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.21723, pg_segmask_iou 0.56266, cl_att_sup_loss 0.15212, cl_segmask_iou 0.59059, cl_phrase_acc 0.99834, 41.94 secs
# ---- Epoch 88/100
# (1) Training stage (lr = 0.000012) ...
# loss 0.58874, cibg_att_sup_loss 0.66113, cibg_segmask_iou 0.40537, pg_att_sup_loss 0.42677, pg_segmask_iou 0.64489, vbg_phrcls_loss 0.15440, vbg_prc_auc 0.99686, vbg_att_reg_loss 0.15622, vbg_att_sup_loss 0.47245, vbg_segmask_iou 0.35916, cl_att_sup_loss 0.20471, cl_segmask_iou 0.57372, cl_phrcls_loss 0.00988, cl_phrase_acc 1.00000, 93.32 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.20899, pg_segmask_iou 0.57107, cl_att_sup_loss 0.17718, cl_segmask_iou 0.57678, cl_phrase_acc 0.99723, 39.26 secs
# ---- Epoch 89/100
# (1) Training stage (lr = 0.000007) ...
# loss 0.58021, cibg_att_sup_loss 0.65886, cibg_segmask_iou 0.40562, pg_att_sup_loss 0.43178, pg_segmask_iou 0.63046, vbg_phrcls_loss 0.14434, vbg_prc_auc 0.99780, vbg_att_reg_loss 0.15618, vbg_att_sup_loss 0.45364, vbg_segmask_iou 0.35812, cl_att_sup_loss 0.21205, cl_segmask_iou 0.57923, cl_phrcls_loss 0.01032, cl_phrase_acc 1.00000, 94.03 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.21669, pg_segmask_iou 0.56370, cl_att_sup_loss 0.15802, cl_segmask_iou 0.58542, cl_phrase_acc 0.99823, 38.83 secs
# ---- Epoch 90/100
# (1) Training stage (lr = 0.000003) ...
# loss 0.56974, cibg_att_sup_loss 0.65549, cibg_segmask_iou 0.40624, pg_att_sup_loss 0.40771, pg_segmask_iou 0.66411, vbg_phrcls_loss 0.12349, vbg_prc_auc 0.99877, vbg_att_reg_loss 0.15191, vbg_att_sup_loss 0.47046, vbg_segmask_iou 0.35536, cl_att_sup_loss 0.20336, cl_segmask_iou 0.57869, cl_phrcls_loss 0.00856, cl_phrase_acc 1.00000, 88.19 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.21835, pg_segmask_iou 0.56094, cl_att_sup_loss 0.14402, cl_segmask_iou 0.58688, cl_phrase_acc 0.99856, 38.73 secs
# New checkpoint saved: checkpoint_90_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.7597.pt
# ---- Epoch 91/100
# (1) Training stage (lr = 0.000002) ...
# loss 0.56525, cibg_att_sup_loss 0.65363, cibg_segmask_iou 0.40834, pg_att_sup_loss 0.42625, pg_segmask_iou 0.63400, vbg_phrcls_loss 0.12071, vbg_prc_auc 0.99866, vbg_att_reg_loss 0.15020, vbg_att_sup_loss 0.44983, vbg_segmask_iou 0.36733, cl_att_sup_loss 0.20434, cl_segmask_iou 0.57433, cl_phrcls_loss 0.00925, cl_phrase_acc 1.00000, 89.79 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.20531, pg_segmask_iou 0.57865, cl_att_sup_loss 0.17411, cl_segmask_iou 0.58303, cl_phrase_acc 0.99667, 40.10 secs
# ---- Epoch 92/100
# (1) Training stage (lr = 0.000001) ...
# loss 0.57348, cibg_att_sup_loss 0.66091, cibg_segmask_iou 0.40819, pg_att_sup_loss 0.41438, pg_segmask_iou 0.65109, vbg_phrcls_loss 0.12205, vbg_prc_auc 0.99827, vbg_att_reg_loss 0.15266, vbg_att_sup_loss 0.47012, vbg_segmask_iou 0.36011, cl_att_sup_loss 0.20496, cl_segmask_iou 0.57484, cl_phrcls_loss 0.00901, cl_phrase_acc 1.00000, 95.57 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.21323, pg_segmask_iou 0.56907, cl_att_sup_loss 0.17364, cl_segmask_iou 0.58275, cl_phrase_acc 0.99778, 36.65 secs
# ---- Epoch 93/100
# (1) Training stage (lr = 0.000080) ...
# loss 0.59336, cibg_att_sup_loss 0.65953, cibg_segmask_iou 0.40897, pg_att_sup_loss 0.43790, pg_segmask_iou 0.64084, vbg_phrcls_loss 0.17445, vbg_prc_auc 0.99584, vbg_att_reg_loss 0.15380, vbg_att_sup_loss 0.46863, vbg_segmask_iou 0.35858, cl_att_sup_loss 0.20220, cl_segmask_iou 0.57510, cl_phrcls_loss 0.01125, cl_phrase_acc 1.00000, 90.45 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.21761, pg_segmask_iou 0.56441, cl_att_sup_loss 0.16771, cl_segmask_iou 0.58795, cl_phrase_acc 0.99756, 40.06 secs
# ---- Epoch 94/100
# (1) Training stage (lr = 0.000043) ...
# loss 0.59984, cibg_att_sup_loss 0.64991, cibg_segmask_iou 0.40974, pg_att_sup_loss 0.45809, pg_segmask_iou 0.62858, vbg_phrcls_loss 0.17764, vbg_prc_auc 0.99597, vbg_att_reg_loss 0.15367, vbg_att_sup_loss 0.47170, vbg_segmask_iou 0.36237, cl_att_sup_loss 0.21766, cl_segmask_iou 0.58451, cl_phrcls_loss 0.01501, cl_phrase_acc 0.99988, 98.37 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.20871, pg_segmask_iou 0.57372, cl_att_sup_loss 0.17165, cl_segmask_iou 0.58306, cl_phrase_acc 0.99734, 40.82 secs
# ---- Epoch 95/100
# (1) Training stage (lr = 0.000023) ...
# loss 0.57562, cibg_att_sup_loss 0.64717, cibg_segmask_iou 0.41400, pg_att_sup_loss 0.41720, pg_segmask_iou 0.65966, vbg_phrcls_loss 0.14366, vbg_prc_auc 0.99733, vbg_att_reg_loss 0.15193, vbg_att_sup_loss 0.46598, vbg_segmask_iou 0.36126, cl_att_sup_loss 0.20695, cl_segmask_iou 0.57718, cl_phrcls_loss 0.01083, cl_phrase_acc 1.00000, 91.59 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.21205, pg_segmask_iou 0.57033, cl_att_sup_loss 0.17258, cl_segmask_iou 0.58675, cl_phrase_acc 0.99900, 37.06 secs
# ---- Epoch 96/100
# (1) Training stage (lr = 0.000012) ...
# loss 0.57219, cibg_att_sup_loss 0.64980, cibg_segmask_iou 0.41586, pg_att_sup_loss 0.42284, pg_segmask_iou 0.63711, vbg_phrcls_loss 0.13055, vbg_prc_auc 0.99840, vbg_att_reg_loss 0.15217, vbg_att_sup_loss 0.46838, vbg_segmask_iou 0.36081, cl_att_sup_loss 0.20229, cl_segmask_iou 0.57739, cl_phrcls_loss 0.01006, cl_phrase_acc 0.99988, 96.44 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.21426, pg_segmask_iou 0.56684, cl_att_sup_loss 0.15258, cl_segmask_iou 0.59092, cl_phrase_acc 0.99889, 39.70 secs
# New checkpoint saved: checkpoint_96_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.7607.pt
# ---- Epoch 97/100
# (1) Training stage (lr = 0.000007) ...
# loss 0.57431, cibg_att_sup_loss 0.64829, cibg_segmask_iou 0.41451, pg_att_sup_loss 0.40354, pg_segmask_iou 0.66340, vbg_phrcls_loss 0.13356, vbg_prc_auc 0.99811, vbg_att_reg_loss 0.15865, vbg_att_sup_loss 0.47914, vbg_segmask_iou 0.34838, cl_att_sup_loss 0.19096, cl_segmask_iou 0.57187, cl_phrcls_loss 0.00945, cl_phrase_acc 1.00000, 90.64 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.19747, pg_segmask_iou 0.59026, cl_att_sup_loss 0.17874, cl_segmask_iou 0.58838, cl_phrase_acc 0.99878, 41.00 secs
# New checkpoint saved: checkpoint_97_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.7633.pt
# ---- Epoch 98/100
# (1) Training stage (lr = 0.000003) ...
# loss 0.55711, cibg_att_sup_loss 0.65542, cibg_segmask_iou 0.41502, pg_att_sup_loss 0.39769, pg_segmask_iou 0.65477, vbg_phrcls_loss 0.10986, vbg_prc_auc 0.99912, vbg_att_reg_loss 0.14949, vbg_att_sup_loss 0.44802, vbg_segmask_iou 0.36109, cl_att_sup_loss 0.20873, cl_segmask_iou 0.58171, cl_phrcls_loss 0.00977, cl_phrase_acc 1.00000, 94.25 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.20937, pg_segmask_iou 0.57415, cl_att_sup_loss 0.16547, cl_segmask_iou 0.58777, cl_phrase_acc 0.99945, 39.90 secs
# ---- Epoch 99/100
# (1) Training stage (lr = 0.000002) ...
# loss 0.55994, cibg_att_sup_loss 0.64379, cibg_segmask_iou 0.41692, pg_att_sup_loss 0.40178, pg_segmask_iou 0.65301, vbg_phrcls_loss 0.12355, vbg_prc_auc 0.99813, vbg_att_reg_loss 0.14962, vbg_att_sup_loss 0.46367, vbg_segmask_iou 0.36229, cl_att_sup_loss 0.19239, cl_segmask_iou 0.57855, cl_phrcls_loss 0.00807, cl_phrase_acc 1.00000, 95.25 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.20794, pg_segmask_iou 0.57539, cl_att_sup_loss 0.15722, cl_segmask_iou 0.59058, cl_phrase_acc 0.99933, 39.45 secs
# ---- Epoch 100/100
# (1) Training stage (lr = 0.000001) ...
# loss 0.54898, cibg_att_sup_loss 0.64085, cibg_segmask_iou 0.41756, pg_att_sup_loss 0.38782, pg_segmask_iou 0.66792, vbg_phrcls_loss 0.11201, vbg_prc_auc 0.99880, vbg_att_reg_loss 0.14849, vbg_att_sup_loss 0.44613, vbg_segmask_iou 0.36364, cl_att_sup_loss 0.19907, cl_segmask_iou 0.57773, cl_phrcls_loss 0.00929, cl_phrase_acc 1.00000, 89.66 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.20043, pg_segmask_iou 0.58616, cl_att_sup_loss 0.17232, cl_segmask_iou 0.58793, cl_phrase_acc 0.99911, 39.29 secs
# New checkpoint saved: checkpoint_100_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.7635.pt

# %%
# !python ../train_phrase_grounding.py \
--checkpoint_folder \
"models/phrase_grounding/20240618_175951_mscxr+chst-img-anat+vinbig+chexloc_PhraseGrounder(dn121,SigmoidAttention,128,256,256,1)" \
--epochs 100 \
--batches_per_epoch 400 \
--max_images_per_batch 8 \
--max_phrases_per_batch 200 \
--max_phrases_per_image 40 \
--val_batch_size_factor 2.0 \
--save
# Out:
# script's arguments:
#    epochs: 100
#    batches_per_epoch: 400
#    max_images_per_batch: 8
#    max_phrases_per_batch: 200
#    max_phrases_per_image: 40
#    val_batch_size_factor: 2.0
#    checkpoint_folder: models/phrase_grounding/20240618_175951_mscxr+chst-img-anat+vinbig+chexloc_PhraseGrounder(dn121,SigmoidAttention,128,256,256,1)
#    pretrained_checkpoint_folder_path: None
#    pretrained_checkpoint_folder_paths: None
#    freeze_image_encoder: False
#    raw_image_encoding: yolov8
#    num_regions: None
#    image_local_feat_size: None
#    image_encoder_pretrained_weights_path: None
#    yolov8_model_name_or_path: None
#    yolov8_model_alias: None
#    phrase_embedding_size: None
#    regions_width: None
#    regions_height: None
#    qkv_size: None
#    phrase_grounding_mode: None
#    phrase_classifier_hidden_size: None
#    transf_d_model: None
#    transf_nhead: None
#    transf_dim_feedforward: None
#    transf_dropout: 0
#    transf_num_layers: None
#    optimizer_name: adamw
#    lr: 0.001
#    scheduler: reduce-lr-on-plateau
#    lr_decay: 0.76
#    lr_decay_patience: 2
#    warmup_and_decay_args: None
#    warmup_and_cosine_args: None
#    warmup_decay_and_cyclic_decay_args: None
#    gradient_accumulation_steps: 1
#    override_lr: False
#    max_grad_norm: None
#    attention_supervision_loss_weight: 1.0
#    phrase_classifier_loss_weight: 1.0
#    foreground_loss_weight: 1.0
#    background_loss_weight: 1.0
#    focal_loss_weight: 1.0
#    bce_loss_weight: 1.0
#    wbce_loss_weight: 1.0
#    binary_multilabel_classif_loss_name: bce
#    use_weighted_phrase_classifier_loss: False
#    cluster_and_label_weights_for_facts_filepath: None
#    use_attention_regularization_loss: False
#    use_contrastive_phrase_grounding_loss: False
#    num_train_workers: 0
#    num_val_workers: 0
#    device: GPU
#    use_amp: False
#    image_size: (416, 416)
#    dicom_id_to_pos_neg_facts_filepath: None
#    iuxray_image_id_to_pos_neg_facts_filepath: None
#    mscxr_phrase2embedding_filepath: None
#    chest_imagenome_bbox_phrase_embeddings_filepath: None
#    vinbig_phrase_embeddings_filepath: None
#    chexlocalize_class_phrase_embeddings_filepath: None
#    chexpert_class_phrase_embeddings_filepath: None
#    mimiccxr_exclude_noisy_images: False
#    mimiccxr_facts_weight: 1.0
#    chest_imagenome_anatlocs_weight: 1.0
#    mscxr_weight: 1.0
#    vinbig_weight: 1.0
#    chexlocalize_weight: 1.0
#    chexpert_weight: 1.0
#    iuxray_weight: 1.0
#    img_aug_mode: None
#    pos_area_prior: 0.4
#    neg_area_prior: 0.0
#    use_mimiccxr_facts_for_train: False
#    use_mimiccxr_facts_for_test: False
#    use_mscxr_for_train: False
#    use_mscxr_for_test: False
#    use_chest_imagenome_for_train: False
#    use_chest_imagenome_gold_for_test: False
#    use_vinbig_for_train: False
#    use_vinbig_for_test: False
#    use_chexlocalize_for_train: False
#    use_chexlocalize_for_test: False
#    use_chexpert_for_train: False
#    use_chexpert_for_test: False
#    use_iuxray_for_train: False
#    use_iuxray_for_test: False
#    vinbig_training_data_mode: train
#    chexpert_training_data_mode: all
#    mask_exponent: 1.0
#    mimiccxr_balance_long_middle_short_tail: False
#    mimiccxr_long_middle_short_tail_thresholds: (0.02, 0.05)
#    mimiccxr_report_fact_nli_integrated_data_filepath: None
#    mimiccxr_use_interpret_cxr_challenge_split: False
#    mimiccxr_interpret_cxr_challenge_split_filepath: None
#    iuxray_use_interpret_cxr_challenge_split: False
#    iuxray_interpret_cxr_challenge_split_filepath: None
#    chexpert_use_interpret_cxr_challenge_split: False
#    chexpert_interpret_cxr_challenge_split_filepath: None
#    chexlocalize_use_interpret_cxr_challenge_split: False
#    chexlocalize_interpret_cxr_challenge_split_filepath: None
#    save: True
# ----- Resuming training ------
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240618_175951_mscxr+chst-img-anat+vinbig+chexloc_PhraseGrounder(dn121,SigmoidAttention,128,256,256,1)/metadata.json
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Creating instance of PhraseGrounder ...
# WARNING: Unused kwargs: {'pretrained_checkpoint_folder_path': '/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240505_224220_mim-facts+vinbig+chexloc+chxp_PhraseGrounder(dn121,128,256)/', 'pretrained_checkpoint_folder_paths': None}
# MultiPurposeVisualModule()
#   Initializing raw_image_encoder: densenet-121
# create_densenet121_feature_extractor()
#    drop_rate: 0.0
# DenseNet121's pretrained weights loaded from ImageNet
#   self.global_feat_size = 2048
#   self.local_feat_size = 1024
#   Initializing auxiliary tasks
# --------------------------------------------------
# 3) Defining optimizer ...
# create_optimizer(): name = adamw
# --------------------------------------------------
# 4) Defining scheduler ...
# Using exp-warmup+decay+cyclicdecay scheduler: 1e-6,3,8e-5,8,1e-6,8e-5,8,1e-6
# 1e-06 3 8e-05 8 1e-06 8e-05 8 1e-06
# self.steps_to_restart = 8
# self.steps = -1
# self.initial_lr = 8e-05
# --------------------------------------------------
# 5) Creating trainer and validator engines ...
# binary_loss_kwargs: {'focal_weight': 1.0, 'bce_weight': 1.0, 'wbce_weight': 1.0}
# Focal_BCE_WBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 wbce_weight = 0.3333333333333333
# Focal_BCE_Loss(): focal_weight = 0.5 bce_weight = 0.5
# Focal_BCE_WBCBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 wbcbce_weight = 0.3333333333333333
# foreground_loss_weight: 1.5
# background_loss_weight: 1.0
# GradientAccumulator.__init__(): num_accumulation_steps = 10, max_grad_norm = None
# binary_loss_kwargs: {'focal_weight': 1.0, 'bce_weight': 1.0, 'wbce_weight': 1.0}
# Focal_BCE_WBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 wbce_weight = 0.3333333333333333
# Focal_BCE_Loss(): focal_weight = 0.5 bce_weight = 0.5
# Focal_BCE_WBCBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 wbcbce_weight = 0.3333333333333333
# foreground_loss_weight: 1.0
# background_loss_weight: 1.0
# --------------------------------------------------
# 6) Creating CheXLocalize Phrase Grounding Trainer ...
# get_image_transform()
# Using standard transform
# mean = (0.485, 0.456, 0.406), std = (0.229, 0.224, 0.225), image_size = [416, 416], use_center_crop = False
# Returning transform without augmentation
# get_image_transform()
# Using standard transform
# mean = (0.485, 0.456, 0.406), std = (0.229, 0.224, 0.225), image_size = [416, 416], use_center_crop = False
# Returning transform without augmentation
# Loding class_phrase_embeddings_filepath and bbox_phrases from /mnt/workspace/pamessina/medvqa-workspace/cache/chexlocalize/class_phrase_embeddings(hash=528,1823213522699794899).pkl...
# class_phrase_embeddings.shape = (10, 128)
# len(class_phrases) = 10
# 	 enlarged cardiomediastinum seen
# 	 cardiomegaly seen
# 	 lung lesion seen
# 	 airspace opacity seen
# 	 edema seen
# 	 consolidation seen
# 	 atelectasis seen
# 	 pneumothorax seen
# 	 pleural effusion seen
# 	 support devices seen
# Compute phrase grounding masks and labels
# Without masks: 216/902
# Generating train dataset and dataloader
# len(train_indices) = 902
# batch_size = 8
# Generating val dataset and dataloader
# len(val_indices) = 902
# batch_size = 16
# --------------------------------------------------
# 7) Creating VinBig Phrase Grounding Trainer ...
# get_image_transform()
# Using standard transform
# mean = (0.485, 0.456, 0.406), std = (0.229, 0.224, 0.225), image_size = [416, 416], use_center_crop = False
# Returning transform without augmentation
# get_image_transform()
# Using standard transform
# mean = (0.485, 0.456, 0.406), std = (0.229, 0.224, 0.225), image_size = [416, 416], use_center_crop = False
# Returning transform without augmentation
# Loading bounding boxes
# Anomalous bboxes found: 29 of 37367
# class_id_offset: 0
# Anomalous bboxes found: 0 of 2697
# class_id_offset: 0
#   Loaded 18000 bounding boxes
# Loding phrase_embeddings and phrases from /mnt/workspace/pamessina/medvqa-workspace/cache/vinbig/label_phrase_embeddings(hash=325,3209166273642513277).pkl...
# phrase_embeddings.shape = (28, 128)
# len(phrases) = 28
# 	 aortic enlargement seen
# 	 atelectasis seen
# 	 calcification seen
# 	 cardiomegaly seen
# 	 clavicle fracture seen
# 	 consolidation seen
# 	 edema seen
# 	 emphysema seen
# 	 enlarged pulmonary artery seen
# 	 interstitial lung disease seen
# 	 infiltration seen
# 	 lung opacity seen
# 	 lung cavity seen
# 	 lung cyst seen
# 	 mediastinal shift seen
# 	 nodule/mass seen
# 	 pleural effusion seen
# 	 pleural thickening seen
# 	 pneumothorax seen
# 	 pulmonary fibrosis seen
# 	 rib fracture seen
# 	 other lesion seen
# 	 copd seen
# 	 lung tumor seen
# 	 pneumonia seen
# 	 tuberculosis seen
# 	 other disease seen
# 	 no abnormalities seen
# Compute phrase grounding masks and labels
# self.phrase_grounding_masks.shape = (18000, 22, 169)
# self.phrase_classification_labels.shape = (18000, 22)
# Append additional labels to phrase_classification_labels
# len(non_bbox_labels) = 6
# non_bbox_labels = ['COPD', 'Lung tumor', 'Pneumonia', 'Tuberculosis', 'Other disease', 'No finding']
# self.phrase_classification_labels.shape = (18000, 28)
# Reorder phrases and phrase_embeddings
# len(phrases) = 28
# len(actual_phrases) = 28
# phrase_embeddings.shape = (28, 128)
# Generating train dataset and dataloader
# len(train_indices) = 18000
# No labels: 0
# Edema: 13
# Clavicle fracture: 29
# Lung cyst: 35
# COPD: 37
# Lung cavity: 60
# Emphysema: 84
# Rib fracture: 101
# Pneumothorax: 114
# Enlarged PA: 139
# Mediastinal shift: 170
# Atelectasis: 273
# Lung tumor: 371
# Consolidation: 449
# ILD: 618
# Calcification: 652
# Infiltration: 671
# Tuberculosis: 914
# Nodule/Mass: 1017
# Pleural effusion: 1149
# Pneumonia: 1163
# Other lesion: 1248
# Lung Opacity: 1415
# Pulmonary fibrosis: 1838
# Pleural thickening: 2179
# Cardiomegaly: 2625
# Aortic enlargement: 3318
# Other disease: 4945
# No finding: 12652
# Group sizes: [12529, 891, 444, 428, 364, 344, 307, 283, 273, 267, 245, 236, 206, 193, 170, 138, 127, 100, 99, 90, 56, 54, 49, 34, 73]
#   len(indices) = 12529, weight = 2522.6672479595745
#   len(indices) = 891, weight = 940.9850359649141
#   len(indices) = 444, weight = 680.1755171156125
#   len(indices) = 428, weight = 667.9638591411331
#   len(indices) = 364, weight = 615.8160380252455
#   len(indices) = 344, weight = 598.2811252947056
#   len(indices) = 307, weight = 563.9888635691133
#   len(indices) = 283, weight = 540.2796339164162
#   len(indices) = 273, weight = 530.0166624211873
#   len(indices) = 267, weight = 523.7422583945496
#   len(indices) = 245, weight = 499.93058392418243
#   len(indices) = 236, weight = 489.7963928535281
#   len(indices) = 206, weight = 454.1360559561945
#   len(indices) = 193, weight = 437.6702522239849
#   len(indices) = 170, weight = 406.7687016278156
#   len(indices) = 138, weight = 359.20170201154343
#   len(indices) = 127, weight = 341.33933626931963
#   len(indices) = 100, weight = 293.26529386579296
#   len(indices) = 99, weight = 291.34941227248714
#   len(indices) = 90, weight = 273.5936736738282
#   len(indices) = 56, weight = 195.85520038280242
#   len(indices) = 54, weight = 190.5945663000252
#   len(indices) = 49, weight = 177.00354049310113
#   len(indices) = 34, weight = 131.67512839151652
#   len(indices) = 73, weight = 237.15649291307946
# --------------------------------------------------
# 8) Creating MIMIC-CXR Phrase Grounding Trainer ...
# get_image_transform()
# Using standard transform
# mean = (0.485, 0.456, 0.406), std = (0.229, 0.224, 0.225), image_size = [416, 416], use_center_crop = False
# Returning transform without augmentation
# get_image_transform()
# Using standard transform
# mean = (0.485, 0.456, 0.406), std = (0.229, 0.224, 0.225), image_size = [416, 416], use_center_crop = False
# Returning transform without augmentation
# mask_exponent = 0.4
# len(forbidden_train_dicom_ids) = 1030
# Preparing MS-CXR dataset and dataloader for training/testing...
# len(dicom_id_2_phrases_and_masks) = 1047
# len(phrase2embedding) = 715
# Using image size mode: medium_512
# 227835it [00:00, 322441.83it/s]
# Total number of images: 1047
# Number of phrases: 1, # images: 939
# Number of phrases: 2, # images: 103
# Number of phrases: 3, # images: 5
# Preparing Chest Imagenome dataset and dataloader for training...
# Loding bbox_phrase_embeddings and bbox_phrases from /mnt/workspace/pamessina/medvqa-workspace/cache/chest_imagenome/bbox_phrase_embeddings(hash=333,2614535641242304201).pkl...
# bbox_phrase_embeddings.shape = (36, 128)
# len(bbox_phrases) = 36
# 	 right lung
# 	 right upper lung zone
# 	 right mid lung zone
# 	 right lower lung zone
# 	 right hilar structures
# 	 right apical zone
# 	 right costophrenic angle
# 	 right cardiophrenic angle
# 	 right hemidiaphragm
# 	 left lung
# 	 left upper lung zone
# 	 left mid lung zone
# 	 left lower lung zone
# 	 left hilar structures
# 	 left apical zone
# 	 left costophrenic angle
# 	 left hemidiaphragm
# 	 trachea
# 	 spine
# 	 right clavicle
# 	 left clavicle
# 	 aortic arch
# 	 mediastinum
# 	 upper mediastinum
# 	 svc
# 	 cardiac silhouette
# 	 left cardiac silhouette
# 	 right cardiac silhouette
# 	 cavoatrial junction
# 	 right atrium
# 	 descending aorta
# 	 carina
# 	 left upper abdomen
# 	 right upper abdomen
# 	 abdomen
# 	 left cardiophrenic angle
# Using image size mode: medium_512
# Loading precomputed bbox_coords_and_presence_and_mask from /mnt/workspace/pamessina/medvqa-workspace/cache/mimiccxr/bbox_coords_and_presence_and_mask(13,13,243310).pkl...
# 227835it [00:36, 6168.63it/s]
# Total number of images: 242280
# --------------------------------------------------
# 9) Creating dataloaders ...
# len(mimiccxr_trainer.train_mscxr_dataloader) = 132
# len(mimiccxr_trainer.test_mscxr_dataloader) = 67
# len(mimiccxr_trainer.train_chest_imagenome_dataloader) = 48456
# len(vinbig_trainer.train_dataloader) = 142857142857142858
# len(chexlocalize_trainer.train_dataloader) = 113
# len(chexlocalize_trainer.val_dataloader) = 57
# len(_train_dataloaders) = 4
# len(_val_dataloaders) = 2
# _train_weights = [0.5, 1.0, 1.0, 0.5]
# merged_dataset_name = mscxr+chst-img-anat+vinbig+chexloc
# --------------------------------------------------
# 10) Attaching metrics, losses, timer and events to engines ...
# --------------------------------------------------
# 11) Defining learning rate scheduler handler ...
# --------------------------------------------------
# 12) Defining learning rate scheduler handler ...
# checkpoint_names = ['checkpoint_100_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.7635.pt']
# --------------------------------------------------
# 13) Loading model from checkpoint ...
# checkpoint_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240618_175951_mscxr+chst-img-anat+vinbig+chexloc_PhraseGrounder(dn121,SigmoidAttention,128,256,256,1)/checkpoint_100_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.7635.pt
# Checkpoint successfully loaded!
# --------------------------------------------------
# 14) Defining log_metrics_handler ...
# MetricsLogger :: we'll be logging to /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240618_175951_mscxr+chst-img-anat+vinbig+chexloc_PhraseGrounder(dn121,SigmoidAttention,128,256,256,1)/metrics_logs.csv
# --------------------------------------------------
# 15) Running trainer engine ...
# ---- Epoch 101/200
# (1) Training stage (lr = 0.000080) ...
# loss 0.60080, cibg_att_sup_loss 0.64120, cibg_segmask_iou 0.41929, pg_att_sup_loss 0.47178, pg_segmask_iou 0.63249, vbg_phrcls_loss 0.17878, vbg_prc_auc 0.99524, vbg_att_reg_loss 0.15222, vbg_att_sup_loss 0.47450, vbg_segmask_iou 0.35981, cl_att_sup_loss 0.21933, cl_segmask_iou 0.57889, cl_phrcls_loss 0.01790, cl_phrase_acc 0.99981, 101.62 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.20719, pg_segmask_iou 0.57872, cl_att_sup_loss 0.16392, cl_segmask_iou 0.58464, cl_phrase_acc 0.99812, 29.44 secs
# New checkpoint saved: checkpoint_101_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.7605.pt
# ---- Epoch 102/200
# (1) Training stage (lr = 0.000043) ...
# loss 0.60064, cibg_att_sup_loss 0.63086, cibg_segmask_iou 0.42161, pg_att_sup_loss 0.46966, pg_segmask_iou 0.63332, vbg_phrcls_loss 0.18182, vbg_prc_auc 0.99579, vbg_att_reg_loss 0.15181, vbg_att_sup_loss 0.47657, vbg_segmask_iou 0.34890, cl_att_sup_loss 0.22440, cl_segmask_iou 0.57943, cl_phrcls_loss 0.02617, cl_phrase_acc 0.99963, 103.75 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.21764, pg_segmask_iou 0.56440, cl_att_sup_loss 0.15673, cl_segmask_iou 0.58189, cl_phrase_acc 0.99767, 34.39 secs
# ---- Epoch 103/200
# (1) Training stage (lr = 0.000023) ...
# loss 0.58803, cibg_att_sup_loss 0.64305, cibg_segmask_iou 0.42174, pg_att_sup_loss 0.44435, pg_segmask_iou 0.64307, vbg_phrcls_loss 0.15383, vbg_prc_auc 0.99741, vbg_att_reg_loss 0.14896, vbg_att_sup_loss 0.47305, vbg_segmask_iou 0.35269, cl_att_sup_loss 0.22984, cl_segmask_iou 0.57523, cl_phrcls_loss 0.01987, cl_phrase_acc 0.99925, 103.39 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.21148, pg_segmask_iou 0.56951, cl_att_sup_loss 0.14336, cl_segmask_iou 0.59123, cl_phrase_acc 0.99922, 30.31 secs
# New checkpoint saved: checkpoint_103_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.7626.pt
# ---- Epoch 104/200
# (1) Training stage (lr = 0.000012) ...
# loss 0.56717, cibg_att_sup_loss 0.63376, cibg_segmask_iou 0.41998, pg_att_sup_loss 0.42539, pg_segmask_iou 0.64986, vbg_phrcls_loss 0.13382, vbg_prc_auc 0.99803, vbg_att_reg_loss 0.14926, vbg_att_sup_loss 0.46067, vbg_segmask_iou 0.36149, cl_att_sup_loss 0.20556, cl_segmask_iou 0.56884, cl_phrcls_loss 0.01449, cl_phrase_acc 1.00000, 105.91 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.19833, pg_segmask_iou 0.58843, cl_att_sup_loss 0.17560, cl_segmask_iou 0.58546, cl_phrase_acc 0.99834, 33.49 secs
# ---- Epoch 105/200
# (1) Training stage (lr = 0.000007) ...
# loss 0.57172, cibg_att_sup_loss 0.63946, cibg_segmask_iou 0.42103, pg_att_sup_loss 0.41176, pg_segmask_iou 0.65423, vbg_phrcls_loss 0.13166, vbg_prc_auc 0.99771, vbg_att_reg_loss 0.15029, vbg_att_sup_loss 0.47129, vbg_segmask_iou 0.36234, cl_att_sup_loss 0.21656, cl_segmask_iou 0.58067, cl_phrcls_loss 0.01526, cl_phrase_acc 0.99944, 107.69 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.20464, pg_segmask_iou 0.58076, cl_att_sup_loss 0.16117, cl_segmask_iou 0.59204, cl_phrase_acc 0.99823, 33.99 secs
# New checkpoint saved: checkpoint_105_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.7636.pt
# ---- Epoch 106/200
# (1) Training stage (lr = 0.000003) ...
# loss 0.55804, cibg_att_sup_loss 0.62484, cibg_segmask_iou 0.42471, pg_att_sup_loss 0.40819, pg_segmask_iou 0.65656, vbg_phrcls_loss 0.12719, vbg_prc_auc 0.99837, vbg_att_reg_loss 0.15609, vbg_att_sup_loss 0.45605, vbg_segmask_iou 0.35817, cl_att_sup_loss 0.20408, cl_segmask_iou 0.57308, cl_phrcls_loss 0.01131, cl_phrase_acc 1.00000, 106.98 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.21040, pg_segmask_iou 0.57173, cl_att_sup_loss 0.13644, cl_segmask_iou 0.59364, cl_phrase_acc 0.99978, 31.85 secs
# New checkpoint saved: checkpoint_106_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.7654.pt
# ---- Epoch 107/200
# (1) Training stage (lr = 0.000002) ...
# loss 0.55687, cibg_att_sup_loss 0.62419, cibg_segmask_iou 0.42423, pg_att_sup_loss 0.40471, pg_segmask_iou 0.65835, vbg_phrcls_loss 0.11998, vbg_prc_auc 0.99808, vbg_att_reg_loss 0.15141, vbg_att_sup_loss 0.45906, vbg_segmask_iou 0.36082, cl_att_sup_loss 0.21263, cl_segmask_iou 0.57748, cl_phrcls_loss 0.01225, cl_phrase_acc 1.00000, 107.49 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.19579, pg_segmask_iou 0.59342, cl_att_sup_loss 0.17051, cl_segmask_iou 0.58956, cl_phrase_acc 0.99845, 34.04 secs
# New checkpoint saved: checkpoint_107_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.7655.pt
# ---- Epoch 108/200
# (1) Training stage (lr = 0.000001) ...
# loss 0.55623, cibg_att_sup_loss 0.63953, cibg_segmask_iou 0.42280, pg_att_sup_loss 0.39988, pg_segmask_iou 0.65876, vbg_phrcls_loss 0.11924, vbg_prc_auc 0.99857, vbg_att_reg_loss 0.14671, vbg_att_sup_loss 0.44816, vbg_segmask_iou 0.35480, cl_att_sup_loss 0.21636, cl_segmask_iou 0.58275, cl_phrcls_loss 0.01275, cl_phrase_acc 0.99981, 106.59 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.21078, pg_segmask_iou 0.57094, cl_att_sup_loss 0.16836, cl_segmask_iou 0.58250, cl_phrase_acc 0.99789, 31.15 secs
# ---- Epoch 109/200
# (1) Training stage (lr = 0.000080) ...
# loss 0.57700, cibg_att_sup_loss 0.64292, cibg_segmask_iou 0.42203, pg_att_sup_loss 0.42890, pg_segmask_iou 0.64948, vbg_phrcls_loss 0.15454, vbg_prc_auc 0.99667, vbg_att_reg_loss 0.14859, vbg_att_sup_loss 0.45900, vbg_segmask_iou 0.36314, cl_att_sup_loss 0.21041, cl_segmask_iou 0.57217, cl_phrcls_loss 0.01638, cl_phrase_acc 0.99981, 105.49 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.21746, pg_segmask_iou 0.56528, cl_att_sup_loss 0.15229, cl_segmask_iou 0.58882, cl_phrase_acc 0.99734, 33.06 secs
# ---- Epoch 110/200
# (1) Training stage (lr = 0.000043) ...
# loss 0.60676, cibg_att_sup_loss 0.63909, cibg_segmask_iou 0.42093, pg_att_sup_loss 0.44700, pg_segmask_iou 0.64313, vbg_phrcls_loss 0.20203, vbg_prc_auc 0.99426, vbg_att_reg_loss 0.15064, vbg_att_sup_loss 0.47686, vbg_segmask_iou 0.35468, cl_att_sup_loss 0.23239, cl_segmask_iou 0.56949, cl_phrcls_loss 0.02202, cl_phrase_acc 0.99962, 107.69 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.19201, pg_segmask_iou 0.60112, cl_att_sup_loss 0.19797, cl_segmask_iou 0.57858, cl_phrase_acc 0.99213, 34.23 secs
# ---- Epoch 111/200
# (1) Training stage (lr = 0.000023) ...
# loss 0.57802, cibg_att_sup_loss 0.63392, cibg_segmask_iou 0.42747, pg_att_sup_loss 0.42489, pg_segmask_iou 0.65321, vbg_phrcls_loss 0.14641, vbg_prc_auc 0.99775, vbg_att_reg_loss 0.15235, vbg_att_sup_loss 0.47347, vbg_segmask_iou 0.35890, cl_att_sup_loss 0.21244, cl_segmask_iou 0.57988, cl_phrcls_loss 0.01705, cl_phrase_acc 0.99981, 107.50 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.20305, pg_segmask_iou 0.58440, cl_att_sup_loss 0.18923, cl_segmask_iou 0.58420, cl_phrase_acc 0.99579, 30.84 secs
# ---- Epoch 112/200
# (1) Training stage (lr = 0.000012) ...
# loss 0.55888, cibg_att_sup_loss 0.62506, cibg_segmask_iou 0.42862, pg_att_sup_loss 0.40613, pg_segmask_iou 0.66067, vbg_phrcls_loss 0.12787, vbg_prc_auc 0.99845, vbg_att_reg_loss 0.14524, vbg_att_sup_loss 0.46653, vbg_segmask_iou 0.35461, cl_att_sup_loss 0.20837, cl_segmask_iou 0.57205, cl_phrcls_loss 0.01308, cl_phrase_acc 1.00000, 110.75 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.20823, pg_segmask_iou 0.57576, cl_att_sup_loss 0.14569, cl_segmask_iou 0.59309, cl_phrase_acc 0.99878, 32.06 secs
# ---- Epoch 113/200
# (1) Training stage (lr = 0.000007) ...
# loss 0.56327, cibg_att_sup_loss 0.63291, cibg_segmask_iou 0.42736, pg_att_sup_loss 0.39556, pg_segmask_iou 0.66490, vbg_phrcls_loss 0.12335, vbg_prc_auc 0.99778, vbg_att_reg_loss 0.14963, vbg_att_sup_loss 0.47555, vbg_segmask_iou 0.34653, cl_att_sup_loss 0.20737, cl_segmask_iou 0.57107, cl_phrcls_loss 0.01144, cl_phrase_acc 1.00000, 110.17 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.19812, pg_segmask_iou 0.58942, cl_att_sup_loss 0.16783, cl_segmask_iou 0.59070, cl_phrase_acc 0.99690, 36.07 secs
# ---- Epoch 114/200
# (1) Training stage (lr = 0.000003) ...
# loss 0.55423, cibg_att_sup_loss 0.62134, cibg_segmask_iou 0.43011, pg_att_sup_loss 0.38596, pg_segmask_iou 0.66849, vbg_phrcls_loss 0.12096, vbg_prc_auc 0.99809, vbg_att_reg_loss 0.15248, vbg_att_sup_loss 0.45815, vbg_segmask_iou 0.35712, cl_att_sup_loss 0.22024, cl_segmask_iou 0.58733, cl_phrcls_loss 0.01180, cl_phrase_acc 1.00000, 110.42 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.21066, pg_segmask_iou 0.57208, cl_att_sup_loss 0.15605, cl_segmask_iou 0.58762, cl_phrase_acc 0.99878, 33.42 secs
# ---- Epoch 115/200
# (1) Training stage (lr = 0.000002) ...
# loss 0.54542, cibg_att_sup_loss 0.61604, cibg_segmask_iou 0.43234, pg_att_sup_loss 0.38583, pg_segmask_iou 0.66851, vbg_phrcls_loss 0.11803, vbg_prc_auc 0.99865, vbg_att_reg_loss 0.14861, vbg_att_sup_loss 0.45385, vbg_segmask_iou 0.36404, cl_att_sup_loss 0.20722, cl_segmask_iou 0.57509, cl_phrcls_loss 0.01006, cl_phrase_acc 1.00000, 109.37 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.19966, pg_segmask_iou 0.58868, cl_att_sup_loss 0.16084, cl_segmask_iou 0.59444, cl_phrase_acc 0.99911, 34.47 secs
# New checkpoint saved: checkpoint_115_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.7669.pt
# ---- Epoch 116/200
# (1) Training stage (lr = 0.000001) ...
# loss 0.53490, cibg_att_sup_loss 0.62026, cibg_segmask_iou 0.43105, pg_att_sup_loss 0.38417, pg_segmask_iou 0.66917, vbg_phrcls_loss 0.09809, vbg_prc_auc 0.99890, vbg_att_reg_loss 0.14621, vbg_att_sup_loss 0.44205, vbg_segmask_iou 0.35871, cl_att_sup_loss 0.19700, cl_segmask_iou 0.57374, cl_phrcls_loss 0.01239, cl_phrase_acc 0.99962, 112.19 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.19662, pg_segmask_iou 0.59269, cl_att_sup_loss 0.15586, cl_segmask_iou 0.59538, cl_phrase_acc 0.99889, 36.15 secs
# New checkpoint saved: checkpoint_116_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.7688.pt
# ---- Epoch 117/200
# (1) Training stage (lr = 0.000080) ...
# loss 0.57164, cibg_att_sup_loss 0.62240, cibg_segmask_iou 0.43163, pg_att_sup_loss 0.41205, pg_segmask_iou 0.65928, vbg_phrcls_loss 0.16077, vbg_prc_auc 0.99616, vbg_att_reg_loss 0.14781, vbg_att_sup_loss 0.45686, vbg_segmask_iou 0.35499, cl_att_sup_loss 0.22330, cl_segmask_iou 0.58302, cl_phrcls_loss 0.01721, cl_phrase_acc 1.00000, 110.78 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.20768, pg_segmask_iou 0.57938, cl_att_sup_loss 0.18051, cl_segmask_iou 0.58189, cl_phrase_acc 0.99058, 33.95 secs
# ---- Epoch 118/200
# (1) Training stage (lr = 0.000043) ...
# loss 0.57840, cibg_att_sup_loss 0.61953, cibg_segmask_iou 0.43188, pg_att_sup_loss 0.42219, pg_segmask_iou 0.65632, vbg_phrcls_loss 0.15961, vbg_prc_auc 0.99648, vbg_att_reg_loss 0.15180, vbg_att_sup_loss 0.47537, vbg_segmask_iou 0.35323, cl_att_sup_loss 0.22349, cl_segmask_iou 0.57833, cl_phrcls_loss 0.01581, cl_phrase_acc 0.99981, 112.66 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.20949, pg_segmask_iou 0.57455, cl_att_sup_loss 0.14895, cl_segmask_iou 0.59086, cl_phrase_acc 0.99845, 35.06 secs
# ---- Epoch 119/200
# (1) Training stage (lr = 0.000023) ...
# loss 0.57210, cibg_att_sup_loss 0.62354, cibg_segmask_iou 0.43224, pg_att_sup_loss 0.40678, pg_segmask_iou 0.66115, vbg_phrcls_loss 0.14991, vbg_prc_auc 0.99744, vbg_att_reg_loss 0.14875, vbg_att_sup_loss 0.47593, vbg_segmask_iou 0.35797, cl_att_sup_loss 0.21061, cl_segmask_iou 0.57323, cl_phrcls_loss 0.01688, cl_phrase_acc 0.99981, 111.08 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.19712, pg_segmask_iou 0.59409, cl_att_sup_loss 0.16367, cl_segmask_iou 0.59359, cl_phrase_acc 0.99845, 37.46 secs
# ---- Epoch 120/200
# (1) Training stage (lr = 0.000012) ...
# loss 0.54367, cibg_att_sup_loss 0.60687, cibg_segmask_iou 0.43737, pg_att_sup_loss 0.38273, pg_segmask_iou 0.67449, vbg_phrcls_loss 0.11913, vbg_prc_auc 0.99844, vbg_att_reg_loss 0.15052, vbg_att_sup_loss 0.45848, vbg_segmask_iou 0.35123, cl_att_sup_loss 0.19816, cl_segmask_iou 0.57678, cl_phrcls_loss 0.00964, cl_phrase_acc 1.00000, 112.32 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.20490, pg_segmask_iou 0.57963, cl_att_sup_loss 0.16298, cl_segmask_iou 0.58732, cl_phrase_acc 0.99767, 32.35 secs
# ---- Epoch 121/200
# (1) Training stage (lr = 0.000007) ...
# loss 0.54155, cibg_att_sup_loss 0.60817, cibg_segmask_iou 0.43901, pg_att_sup_loss 0.37545, pg_segmask_iou 0.67434, vbg_phrcls_loss 0.11971, vbg_prc_auc 0.99840, vbg_att_reg_loss 0.14612, vbg_att_sup_loss 0.45318, vbg_segmask_iou 0.35792, cl_att_sup_loss 0.21142, cl_segmask_iou 0.57499, cl_phrcls_loss 0.01171, cl_phrase_acc 1.00000, 110.64 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.20457, pg_segmask_iou 0.58127, cl_att_sup_loss 0.14374, cl_segmask_iou 0.59663, cl_phrase_acc 0.99922, 35.49 secs
# ---- Epoch 122/200
# (1) Training stage (lr = 0.000003) ...
# loss 0.53976, cibg_att_sup_loss 0.60437, cibg_segmask_iou 0.43854, pg_att_sup_loss 0.37020, pg_segmask_iou 0.67635, vbg_phrcls_loss 0.12194, vbg_prc_auc 0.99837, vbg_att_reg_loss 0.14959, vbg_att_sup_loss 0.45181, vbg_segmask_iou 0.35954, cl_att_sup_loss 0.20167, cl_segmask_iou 0.57763, cl_phrcls_loss 0.00911, cl_phrase_acc 1.00000, 110.52 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.19314, pg_segmask_iou 0.59532, cl_att_sup_loss 0.16702, cl_segmask_iou 0.58491, cl_phrase_acc 0.99678, 37.70 secs
# ---- Epoch 123/200
# (1) Training stage (lr = 0.000002) ...
# loss 0.53365, cibg_att_sup_loss 0.60953, cibg_segmask_iou 0.43996, pg_att_sup_loss 0.36423, pg_segmask_iou 0.68142, vbg_phrcls_loss 0.10376, vbg_prc_auc 0.99895, vbg_att_reg_loss 0.14674, vbg_att_sup_loss 0.45214, vbg_segmask_iou 0.36526, cl_att_sup_loss 0.20226, cl_segmask_iou 0.57799, cl_phrcls_loss 0.00968, cl_phrase_acc 1.00000, 104.37 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.20654, pg_segmask_iou 0.57853, cl_att_sup_loss 0.14981, cl_segmask_iou 0.59444, cl_phrase_acc 0.99900, 31.25 secs
# ---- Epoch 124/200
# (1) Training stage (lr = 0.000001) ...
# loss 0.53654, cibg_att_sup_loss 0.61827, cibg_segmask_iou 0.43731, pg_att_sup_loss 0.36505, pg_segmask_iou 0.67819, vbg_phrcls_loss 0.10780, vbg_prc_auc 0.99894, vbg_att_reg_loss 0.14487, vbg_att_sup_loss 0.45051, vbg_segmask_iou 0.36106, cl_att_sup_loss 0.20450, cl_segmask_iou 0.57972, cl_phrcls_loss 0.01051, cl_phrase_acc 1.00000, 108.83 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.20852, pg_segmask_iou 0.57518, cl_att_sup_loss 0.13566, cl_segmask_iou 0.59343, cl_phrase_acc 0.99922, 34.83 secs
# ---- Epoch 125/200
# (1) Training stage (lr = 0.000080) ...
# loss 0.56044, cibg_att_sup_loss 0.61650, cibg_segmask_iou 0.43784, pg_att_sup_loss 0.40070, pg_segmask_iou 0.66582, vbg_phrcls_loss 0.14128, vbg_prc_auc 0.99735, vbg_att_reg_loss 0.14803, vbg_att_sup_loss 0.46268, vbg_segmask_iou 0.36196, cl_att_sup_loss 0.20648, cl_segmask_iou 0.57569, cl_phrcls_loss 0.01626, cl_phrase_acc 0.99943, 110.95 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.19882, pg_segmask_iou 0.59340, cl_att_sup_loss 0.19468, cl_segmask_iou 0.58024, cl_phrase_acc 0.99623, 36.34 secs
# ---- Epoch 126/200
# (1) Training stage (lr = 0.000043) ...
# loss 0.58182, cibg_att_sup_loss 0.61737, cibg_segmask_iou 0.43758, pg_att_sup_loss 0.41693, pg_segmask_iou 0.66113, vbg_phrcls_loss 0.16917, vbg_prc_auc 0.99494, vbg_att_reg_loss 0.15199, vbg_att_sup_loss 0.47663, vbg_segmask_iou 0.36519, cl_att_sup_loss 0.22123, cl_segmask_iou 0.58042, cl_phrcls_loss 0.02049, cl_phrase_acc 0.99981, 111.75 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.21060, pg_segmask_iou 0.57124, cl_att_sup_loss 0.17234, cl_segmask_iou 0.58180, cl_phrase_acc 0.99712, 34.16 secs
# ---- Epoch 127/200
# (1) Training stage (lr = 0.000023) ...
# loss 0.55519, cibg_att_sup_loss 0.61295, cibg_segmask_iou 0.44057, pg_att_sup_loss 0.38866, pg_segmask_iou 0.67122, vbg_phrcls_loss 0.12340, vbg_prc_auc 0.99784, vbg_att_reg_loss 0.15339, vbg_att_sup_loss 0.47009, vbg_segmask_iou 0.35449, cl_att_sup_loss 0.21074, cl_segmask_iou 0.57529, cl_phrcls_loss 0.01583, cl_phrase_acc 0.99981, 109.25 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.20141, pg_segmask_iou 0.58600, cl_att_sup_loss 0.15733, cl_segmask_iou 0.59364, cl_phrase_acc 0.99867, 34.09 secs
# ---- Epoch 128/200
# (1) Training stage (lr = 0.000012) ...
# loss 0.53661, cibg_att_sup_loss 0.60220, cibg_segmask_iou 0.44337, pg_att_sup_loss 0.37089, pg_segmask_iou 0.67913, vbg_phrcls_loss 0.10651, vbg_prc_auc 0.99849, vbg_att_reg_loss 0.14547, vbg_att_sup_loss 0.46067, vbg_segmask_iou 0.36989, cl_att_sup_loss 0.20563, cl_segmask_iou 0.57574, cl_phrcls_loss 0.01130, cl_phrase_acc 0.99981, 109.41 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.19343, pg_segmask_iou 0.59727, cl_att_sup_loss 0.16042, cl_segmask_iou 0.59167, cl_phrase_acc 0.99690, 32.68 secs
# ---- Epoch 129/200
# (1) Training stage (lr = 0.000007) ...
# loss 0.52508, cibg_att_sup_loss 0.60595, cibg_segmask_iou 0.44422, pg_att_sup_loss 0.36070, pg_segmask_iou 0.68275, vbg_phrcls_loss 0.10040, vbg_prc_auc 0.99910, vbg_att_reg_loss 0.14614, vbg_att_sup_loss 0.44171, vbg_segmask_iou 0.36383, cl_att_sup_loss 0.19227, cl_segmask_iou 0.57720, cl_phrcls_loss 0.00787, cl_phrase_acc 1.00000, 108.85 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.20365, pg_segmask_iou 0.58299, cl_att_sup_loss 0.15688, cl_segmask_iou 0.59207, cl_phrase_acc 0.99823, 36.76 secs
# ---- Epoch 130/200
# (1) Training stage (lr = 0.000003) ...
# loss 0.52707, cibg_att_sup_loss 0.60169, cibg_segmask_iou 0.44686, pg_att_sup_loss 0.35357, pg_segmask_iou 0.68547, vbg_phrcls_loss 0.10521, vbg_prc_auc 0.99868, vbg_att_reg_loss 0.14850, vbg_att_sup_loss 0.44625, vbg_segmask_iou 0.36031, cl_att_sup_loss 0.20090, cl_segmask_iou 0.58258, cl_phrcls_loss 0.00835, cl_phrase_acc 1.00000, 109.62 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.20241, pg_segmask_iou 0.58426, cl_att_sup_loss 0.15039, cl_segmask_iou 0.59715, cl_phrase_acc 0.99867, 34.60 secs
# ---- Epoch 131/200
# (1) Training stage (lr = 0.000002) ...
# loss 0.52709, cibg_att_sup_loss 0.60504, cibg_segmask_iou 0.44481, pg_att_sup_loss 0.35127, pg_segmask_iou 0.68582, vbg_phrcls_loss 0.09589, vbg_prc_auc 0.99905, vbg_att_reg_loss 0.14560, vbg_att_sup_loss 0.45413, vbg_segmask_iou 0.36496, cl_att_sup_loss 0.19911, cl_segmask_iou 0.57735, cl_phrcls_loss 0.00863, cl_phrase_acc 1.00000, 110.64 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.18913, pg_segmask_iou 0.60250, cl_att_sup_loss 0.17320, cl_segmask_iou 0.58896, cl_phrase_acc 0.99656, 32.55 secs
# ---- Epoch 132/200
# (1) Training stage (lr = 0.000001) ...
# loss 0.52254, cibg_att_sup_loss 0.60048, cibg_segmask_iou 0.44382, pg_att_sup_loss 0.35030, pg_segmask_iou 0.68643, vbg_phrcls_loss 0.09660, vbg_prc_auc 0.99875, vbg_att_reg_loss 0.14389, vbg_att_sup_loss 0.44724, vbg_segmask_iou 0.37307, cl_att_sup_loss 0.19775, cl_segmask_iou 0.57994, cl_phrcls_loss 0.00935, cl_phrase_acc 1.00000, 109.55 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.19574, pg_segmask_iou 0.59516, cl_att_sup_loss 0.16480, cl_segmask_iou 0.59416, cl_phrase_acc 0.99767, 32.18 secs
# ---- Epoch 133/200
# (1) Training stage (lr = 0.000080) ...
# loss 0.55545, cibg_att_sup_loss 0.60013, cibg_segmask_iou 0.44718, pg_att_sup_loss 0.38360, pg_segmask_iou 0.67489, vbg_phrcls_loss 0.15312, vbg_prc_auc 0.99597, vbg_att_reg_loss 0.14822, vbg_att_sup_loss 0.46606, vbg_segmask_iou 0.35977, cl_att_sup_loss 0.20527, cl_segmask_iou 0.58445, cl_phrcls_loss 0.01258, cl_phrase_acc 0.99981, 106.75 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.20622, pg_segmask_iou 0.57927, cl_att_sup_loss 0.16576, cl_segmask_iou 0.58774, cl_phrase_acc 0.99545, 29.02 secs
# ---- Epoch 134/200
# (1) Training stage (lr = 0.000043) ...
# loss 0.57098, cibg_att_sup_loss 0.61115, cibg_segmask_iou 0.44483, pg_att_sup_loss 0.40402, pg_segmask_iou 0.66946, vbg_phrcls_loss 0.17585, vbg_prc_auc 0.99538, vbg_att_reg_loss 0.14683, vbg_att_sup_loss 0.46215, vbg_segmask_iou 0.36434, cl_att_sup_loss 0.21217, cl_segmask_iou 0.57400, cl_phrcls_loss 0.01583, cl_phrase_acc 0.99981, 108.05 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.19863, pg_segmask_iou 0.58863, cl_att_sup_loss 0.17284, cl_segmask_iou 0.58184, cl_phrase_acc 0.99667, 32.13 secs
# ---- Epoch 135/200
# (1) Training stage (lr = 0.000023) ...
# loss 0.55192, cibg_att_sup_loss 0.60016, cibg_segmask_iou 0.44673, pg_att_sup_loss 0.38039, pg_segmask_iou 0.67628, vbg_phrcls_loss 0.14108, vbg_prc_auc 0.99720, vbg_att_reg_loss 0.14986, vbg_att_sup_loss 0.46988, vbg_segmask_iou 0.35430, cl_att_sup_loss 0.19532, cl_segmask_iou 0.57767, cl_phrcls_loss 0.01199, cl_phrase_acc 0.99981, 115.94 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.20197, pg_segmask_iou 0.58298, cl_att_sup_loss 0.15537, cl_segmask_iou 0.59090, cl_phrase_acc 0.99789, 35.09 secs
# ---- Epoch 136/200
# (1) Training stage (lr = 0.000012) ...
# loss 0.53050, cibg_att_sup_loss 0.59582, cibg_segmask_iou 0.44999, pg_att_sup_loss 0.35910, pg_segmask_iou 0.68623, vbg_phrcls_loss 0.11277, vbg_prc_auc 0.99867, vbg_att_reg_loss 0.14135, vbg_att_sup_loss 0.45354, vbg_segmask_iou 0.35950, cl_att_sup_loss 0.21167, cl_segmask_iou 0.58700, cl_phrcls_loss 0.00888, cl_phrase_acc 1.00000, 121.71 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.19923, pg_segmask_iou 0.58674, cl_att_sup_loss 0.15051, cl_segmask_iou 0.59633, cl_phrase_acc 0.99723, 36.64 secs
# ---- Epoch 137/200
# (1) Training stage (lr = 0.000007) ...
# loss 0.52520, cibg_att_sup_loss 0.60123, cibg_segmask_iou 0.44973, pg_att_sup_loss 0.34801, pg_segmask_iou 0.68954, vbg_phrcls_loss 0.10545, vbg_prc_auc 0.99869, vbg_att_reg_loss 0.14447, vbg_att_sup_loss 0.44518, vbg_segmask_iou 0.36223, cl_att_sup_loss 0.20022, cl_segmask_iou 0.58187, cl_phrcls_loss 0.00812, cl_phrase_acc 1.00000, 126.29 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.19758, pg_segmask_iou 0.58942, cl_att_sup_loss 0.14323, cl_segmask_iou 0.59353, cl_phrase_acc 0.99767, 38.28 secs
# New checkpoint saved: checkpoint_137_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.7700.pt
# ---- Epoch 138/200
# (1) Training stage (lr = 0.000003) ...
# loss 0.52039, cibg_att_sup_loss 0.59429, cibg_segmask_iou 0.45099, pg_att_sup_loss 0.34242, pg_segmask_iou 0.69164, vbg_phrcls_loss 0.11005, vbg_prc_auc 0.99848, vbg_att_reg_loss 0.14707, vbg_att_sup_loss 0.44479, vbg_segmask_iou 0.35971, cl_att_sup_loss 0.17811, cl_segmask_iou 0.57596, cl_phrcls_loss 0.00785, cl_phrase_acc 0.99981, 121.93 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.20176, pg_segmask_iou 0.58347, cl_att_sup_loss 0.15720, cl_segmask_iou 0.59088, cl_phrase_acc 0.99823, 38.67 secs
# ---- Epoch 139/200
# (1) Training stage (lr = 0.000002) ...
# loss 0.52408, cibg_att_sup_loss 0.58982, cibg_segmask_iou 0.45249, pg_att_sup_loss 0.33874, pg_segmask_iou 0.69360, vbg_phrcls_loss 0.11435, vbg_prc_auc 0.99850, vbg_att_reg_loss 0.14457, vbg_att_sup_loss 0.45027, vbg_segmask_iou 0.36668, cl_att_sup_loss 0.20292, cl_segmask_iou 0.57624, cl_phrcls_loss 0.00852, cl_phrase_acc 1.00000, 125.49 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.19718, pg_segmask_iou 0.59100, cl_att_sup_loss 0.15808, cl_segmask_iou 0.59441, cl_phrase_acc 0.99778, 39.19 secs
# ---- Epoch 140/200
# (1) Training stage (lr = 0.000001) ...
# loss 0.52261, cibg_att_sup_loss 0.58924, cibg_segmask_iou 0.45342, pg_att_sup_loss 0.33713, pg_segmask_iou 0.69431, vbg_phrcls_loss 0.09507, vbg_prc_auc 0.99888, vbg_att_reg_loss 0.14634, vbg_att_sup_loss 0.46344, vbg_segmask_iou 0.36108, cl_att_sup_loss 0.19911, cl_segmask_iou 0.58428, cl_phrcls_loss 0.00927, cl_phrase_acc 1.00000, 125.62 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.19430, pg_segmask_iou 0.59484, cl_att_sup_loss 0.15010, cl_segmask_iou 0.59706, cl_phrase_acc 0.99756, 37.44 secs
# New checkpoint saved: checkpoint_140_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.7712.pt
# ---- Epoch 141/200
# (1) Training stage (lr = 0.000080) ...
# loss 0.54181, cibg_att_sup_loss 0.59691, cibg_segmask_iou 0.44984, pg_att_sup_loss 0.36988, pg_segmask_iou 0.68224, vbg_phrcls_loss 0.13190, vbg_prc_auc 0.99594, vbg_att_reg_loss 0.14708, vbg_att_sup_loss 0.45728, vbg_segmask_iou 0.35971, cl_att_sup_loss 0.20041, cl_segmask_iou 0.57932, cl_phrcls_loss 0.01249, cl_phrase_acc 0.99944, 126.42 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.20339, pg_segmask_iou 0.58347, cl_att_sup_loss 0.17723, cl_segmask_iou 0.58553, cl_phrase_acc 0.99523, 39.67 secs
# ---- Epoch 142/200
# (1) Training stage (lr = 0.000043) ...
# loss 0.55588, cibg_att_sup_loss 0.58908, cibg_segmask_iou 0.45354, pg_att_sup_loss 0.39007, pg_segmask_iou 0.67645, vbg_phrcls_loss 0.16174, vbg_prc_auc 0.99553, vbg_att_reg_loss 0.14703, vbg_att_sup_loss 0.46548, vbg_segmask_iou 0.36118, cl_att_sup_loss 0.20617, cl_segmask_iou 0.58803, cl_phrcls_loss 0.01615, cl_phrase_acc 0.99963, 125.87 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.20004, pg_segmask_iou 0.58657, cl_att_sup_loss 0.16295, cl_segmask_iou 0.59529, cl_phrase_acc 0.99534, 37.07 secs
# ---- Epoch 143/200
# (1) Training stage (lr = 0.000023) ...
# loss 0.53163, cibg_att_sup_loss 0.58843, cibg_segmask_iou 0.45372, pg_att_sup_loss 0.36377, pg_segmask_iou 0.68618, vbg_phrcls_loss 0.11874, vbg_prc_auc 0.99846, vbg_att_reg_loss 0.14848, vbg_att_sup_loss 0.45170, vbg_segmask_iou 0.35762, cl_att_sup_loss 0.19846, cl_segmask_iou 0.57354, cl_phrcls_loss 0.01082, cl_phrase_acc 0.99981, 128.64 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.19214, pg_segmask_iou 0.60028, cl_att_sup_loss 0.15800, cl_segmask_iou 0.59713, cl_phrase_acc 0.99634, 38.19 secs
# ---- Epoch 144/200
# (1) Training stage (lr = 0.000012) ...
# loss 0.53019, cibg_att_sup_loss 0.58938, cibg_segmask_iou 0.45501, pg_att_sup_loss 0.34947, pg_segmask_iou 0.69205, vbg_phrcls_loss 0.11253, vbg_prc_auc 0.99821, vbg_att_reg_loss 0.14794, vbg_att_sup_loss 0.46149, vbg_segmask_iou 0.35993, cl_att_sup_loss 0.19765, cl_segmask_iou 0.58291, cl_phrcls_loss 0.00952, cl_phrase_acc 1.00000, 129.84 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.20002, pg_segmask_iou 0.58736, cl_att_sup_loss 0.15536, cl_segmask_iou 0.59757, cl_phrase_acc 0.99634, 39.00 secs
# ---- Epoch 145/200
# (1) Training stage (lr = 0.000007) ...
# loss 0.51994, cibg_att_sup_loss 0.58648, cibg_segmask_iou 0.45577, pg_att_sup_loss 0.33634, pg_segmask_iou 0.69800, vbg_phrcls_loss 0.11447, vbg_prc_auc 0.99769, vbg_att_reg_loss 0.14349, vbg_att_sup_loss 0.44537, vbg_segmask_iou 0.36691, cl_att_sup_loss 0.19644, cl_segmask_iou 0.58841, cl_phrcls_loss 0.01100, cl_phrase_acc 0.99963, 126.55 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.19609, pg_segmask_iou 0.59216, cl_att_sup_loss 0.15742, cl_segmask_iou 0.59681, cl_phrase_acc 0.99756, 38.95 secs
# ---- Epoch 146/200
# (1) Training stage (lr = 0.000003) ...
# loss 0.50511, cibg_att_sup_loss 0.57819, cibg_segmask_iou 0.45810, pg_att_sup_loss 0.32992, pg_segmask_iou 0.70008, vbg_phrcls_loss 0.09459, vbg_prc_auc 0.99902, vbg_att_reg_loss 0.14504, vbg_att_sup_loss 0.43709, vbg_segmask_iou 0.36740, cl_att_sup_loss 0.18105, cl_segmask_iou 0.57963, cl_phrcls_loss 0.00771, cl_phrase_acc 1.00000, 126.72 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.18975, pg_segmask_iou 0.60132, cl_att_sup_loss 0.17315, cl_segmask_iou 0.58925, cl_phrase_acc 0.99534, 37.16 secs
# ---- Epoch 147/200
# (1) Training stage (lr = 0.000002) ...
# loss 0.50981, cibg_att_sup_loss 0.59215, cibg_segmask_iou 0.45617, pg_att_sup_loss 0.32752, pg_segmask_iou 0.69951, vbg_phrcls_loss 0.08301, vbg_prc_auc 0.99925, vbg_att_reg_loss 0.14365, vbg_att_sup_loss 0.44680, vbg_segmask_iou 0.36183, cl_att_sup_loss 0.19132, cl_segmask_iou 0.58494, cl_phrcls_loss 0.00733, cl_phrase_acc 1.00000, 123.39 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.19959, pg_segmask_iou 0.58748, cl_att_sup_loss 0.16556, cl_segmask_iou 0.59223, cl_phrase_acc 0.99723, 39.89 secs
# ---- Epoch 148/200
# (1) Training stage (lr = 0.000001) ...
# loss 0.51367, cibg_att_sup_loss 0.57715, cibg_segmask_iou 0.45744, pg_att_sup_loss 0.32441, pg_segmask_iou 0.70181, vbg_phrcls_loss 0.09841, vbg_prc_auc 0.99863, vbg_att_reg_loss 0.14470, vbg_att_sup_loss 0.46238, vbg_segmask_iou 0.36334, cl_att_sup_loss 0.18934, cl_segmask_iou 0.58619, cl_phrcls_loss 0.00681, cl_phrase_acc 1.00000, 127.32 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.19933, pg_segmask_iou 0.58793, cl_att_sup_loss 0.14695, cl_segmask_iou 0.59600, cl_phrase_acc 0.99812, 37.67 secs
# ---- Epoch 149/200
# (1) Training stage (lr = 0.000080) ...
# loss 0.53980, cibg_att_sup_loss 0.59587, cibg_segmask_iou 0.45556, pg_att_sup_loss 0.36065, pg_segmask_iou 0.68911, vbg_phrcls_loss 0.13002, vbg_prc_auc 0.99744, vbg_att_reg_loss 0.14982, vbg_att_sup_loss 0.46172, vbg_segmask_iou 0.36191, cl_att_sup_loss 0.19181, cl_segmask_iou 0.57672, cl_phrcls_loss 0.00942, cl_phrase_acc 1.00000, 127.42 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.19456, pg_segmask_iou 0.59861, cl_att_sup_loss 0.17021, cl_segmask_iou 0.59350, cl_phrase_acc 0.99279, 38.49 secs
# ---- Epoch 150/200
# (1) Training stage (lr = 0.000043) ...
# loss 0.55359, cibg_att_sup_loss 0.58413, cibg_segmask_iou 0.45903, pg_att_sup_loss 0.39355, pg_segmask_iou 0.67593, vbg_phrcls_loss 0.16708, vbg_prc_auc 0.99610, vbg_att_reg_loss 0.14557, vbg_att_sup_loss 0.45233, vbg_segmask_iou 0.36287, cl_att_sup_loss 0.21043, cl_segmask_iou 0.57770, cl_phrcls_loss 0.01742, cl_phrase_acc 0.99981, 130.16 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.19788, pg_segmask_iou 0.59082, cl_att_sup_loss 0.17465, cl_segmask_iou 0.58942, cl_phrase_acc 0.99645, 38.22 secs
# ---- Epoch 151/200
# (1) Training stage (lr = 0.000023) ...
# loss 0.52651, cibg_att_sup_loss 0.58633, cibg_segmask_iou 0.46006, pg_att_sup_loss 0.36261, pg_segmask_iou 0.68815, vbg_phrcls_loss 0.11046, vbg_prc_auc 0.99841, vbg_att_reg_loss 0.14508, vbg_att_sup_loss 0.46202, vbg_segmask_iou 0.35384, cl_att_sup_loss 0.18392, cl_segmask_iou 0.58178, cl_phrcls_loss 0.00849, cl_phrase_acc 1.00000, 129.27 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.19382, pg_segmask_iou 0.59797, cl_att_sup_loss 0.17462, cl_segmask_iou 0.59025, cl_phrase_acc 0.99390, 39.43 secs
# ---- Epoch 152/200
# (1) Training stage (lr = 0.000012) ...
# loss 0.51842, cibg_att_sup_loss 0.57866, cibg_segmask_iou 0.46277, pg_att_sup_loss 0.34115, pg_segmask_iou 0.69670, vbg_phrcls_loss 0.11318, vbg_prc_auc 0.99834, vbg_att_reg_loss 0.13974, vbg_att_sup_loss 0.44969, vbg_segmask_iou 0.36491, cl_att_sup_loss 0.19550, cl_segmask_iou 0.57924, cl_phrcls_loss 0.00941, cl_phrase_acc 1.00000, 126.49 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.18348, pg_segmask_iou 0.61185, cl_att_sup_loss 0.18706, cl_segmask_iou 0.58615, cl_phrase_acc 0.99379, 38.51 secs
# ---- Epoch 153/200
# (1) Training stage (lr = 0.000007) ...
# loss 0.51194, cibg_att_sup_loss 0.57310, cibg_segmask_iou 0.46340, pg_att_sup_loss 0.32952, pg_segmask_iou 0.70059, vbg_phrcls_loss 0.10413, vbg_prc_auc 0.99866, vbg_att_reg_loss 0.14718, vbg_att_sup_loss 0.44956, vbg_segmask_iou 0.36347, cl_att_sup_loss 0.18519, cl_segmask_iou 0.57957, cl_phrcls_loss 0.00720, cl_phrase_acc 1.00000, 128.90 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.20201, pg_segmask_iou 0.58587, cl_att_sup_loss 0.15798, cl_segmask_iou 0.59248, cl_phrase_acc 0.99756, 37.29 secs
# ---- Epoch 154/200
# (1) Training stage (lr = 0.000003) ...
# loss 0.50627, cibg_att_sup_loss 0.58112, cibg_segmask_iou 0.46212, pg_att_sup_loss 0.32228, pg_segmask_iou 0.70546, vbg_phrcls_loss 0.08748, vbg_prc_auc 0.99924, vbg_att_reg_loss 0.14422, vbg_att_sup_loss 0.44981, vbg_segmask_iou 0.35965, cl_att_sup_loss 0.18682, cl_segmask_iou 0.58473, cl_phrcls_loss 0.00703, cl_phrase_acc 1.00000, 126.85 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.19835, pg_segmask_iou 0.59122, cl_att_sup_loss 0.15106, cl_segmask_iou 0.59791, cl_phrase_acc 0.99878, 39.23 secs
# ---- Epoch 155/200
# (1) Training stage (lr = 0.000002) ...
# loss 0.50512, cibg_att_sup_loss 0.58436, cibg_segmask_iou 0.46311, pg_att_sup_loss 0.31864, pg_segmask_iou 0.70642, vbg_phrcls_loss 0.08952, vbg_prc_auc 0.99873, vbg_att_reg_loss 0.14269, vbg_att_sup_loss 0.44257, vbg_segmask_iou 0.36402, cl_att_sup_loss 0.18547, cl_segmask_iou 0.58925, cl_phrcls_loss 0.00620, cl_phrase_acc 1.00000, 129.07 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.18627, pg_segmask_iou 0.60778, cl_att_sup_loss 0.17638, cl_segmask_iou 0.59198, cl_phrase_acc 0.99490, 36.45 secs
# ---- Epoch 156/200
# (1) Training stage (lr = 0.000001) ...
# loss 0.50438, cibg_att_sup_loss 0.56534, cibg_segmask_iou 0.46584, pg_att_sup_loss 0.31643, pg_segmask_iou 0.70726, vbg_phrcls_loss 0.10150, vbg_prc_auc 0.99826, vbg_att_reg_loss 0.14415, vbg_att_sup_loss 0.44439, vbg_segmask_iou 0.36253, cl_att_sup_loss 0.18923, cl_segmask_iou 0.57542, cl_phrcls_loss 0.00794, cl_phrase_acc 0.99981, 128.65 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.19676, pg_segmask_iou 0.59060, cl_att_sup_loss 0.17315, cl_segmask_iou 0.58534, cl_phrase_acc 0.99645, 37.76 secs
# ---- Epoch 157/200
# (1) Training stage (lr = 0.000080) ...
# loss 0.52908, cibg_att_sup_loss 0.58079, cibg_segmask_iou 0.46178, pg_att_sup_loss 0.35160, pg_segmask_iou 0.69443, vbg_phrcls_loss 0.13547, vbg_prc_auc 0.99659, vbg_att_reg_loss 0.14708, vbg_att_sup_loss 0.44645, vbg_segmask_iou 0.36857, cl_att_sup_loss 0.19623, cl_segmask_iou 0.57861, cl_phrcls_loss 0.01081, cl_phrase_acc 0.99963, 129.25 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.20026, pg_segmask_iou 0.58922, cl_att_sup_loss 0.14538, cl_segmask_iou 0.59331, cl_phrase_acc 0.99302, 40.32 secs
# ---- Epoch 158/200
# (1) Training stage (lr = 0.000043) ...
# ...
# (2) Validation stage ...
# pg_att_sup_loss 0.18878, pg_segmask_iou 0.60829, cl_att_sup_loss 0.19539, cl_segmask_iou 0.57552, cl_phrase_acc 0.99579, 41.24 secs
# ---- Epoch 174/200
# (1) Training stage (lr = 0.000043) ...
# loss 0.54252, cibg_att_sup_loss 0.55748, cibg_segmask_iou 0.47439, pg_att_sup_loss 0.36386, pg_segmask_iou 0.69265, vbg_phrcls_loss 0.16560, vbg_prc_auc 0.99578, vbg_att_reg_loss 0.14612, vbg_att_sup_loss 0.46763, vbg_segmask_iou 0.35511, cl_att_sup_loss 0.19806, cl_segmask_iou 0.58180, cl_phrcls_loss 0.01709, cl_phrase_acc 1.00000, 131.36 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.19679, pg_segmask_iou 0.59226, cl_att_sup_loss 0.17577, cl_segmask_iou 0.58710, cl_phrase_acc 0.99490, 38.84 secs
# ---- Epoch 175/200
# (1) Training stage (lr = 0.000023) ...
# loss 0.52082, cibg_att_sup_loss 0.56801, cibg_segmask_iou 0.47219, pg_att_sup_loss 0.33243, pg_segmask_iou 0.70595, vbg_phrcls_loss 0.13074, vbg_prc_auc 0.99741, vbg_att_reg_loss 0.14134, vbg_att_sup_loss 0.45722, vbg_segmask_iou 0.35914, cl_att_sup_loss 0.19050, cl_segmask_iou 0.57916, cl_phrcls_loss 0.01116, cl_phrase_acc 0.99963, 130.52 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.19738, pg_segmask_iou 0.59103, cl_att_sup_loss 0.15040, cl_segmask_iou 0.59258, cl_phrase_acc 0.99789, 39.15 secs
# ---- Epoch 176/200
# (1) Training stage (lr = 0.000012) ...
# loss 0.50348, cibg_att_sup_loss 0.55506, cibg_segmask_iou 0.47851, pg_att_sup_loss 0.31385, pg_segmask_iou 0.71450, vbg_phrcls_loss 0.10574, vbg_prc_auc 0.99880, vbg_att_reg_loss 0.13845, vbg_att_sup_loss 0.46234, vbg_segmask_iou 0.36127, cl_att_sup_loss 0.17369, cl_segmask_iou 0.58786, cl_phrcls_loss 0.00840, cl_phrase_acc 1.00000, 131.36 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.17864, pg_segmask_iou 0.61837, cl_att_sup_loss 0.19027, cl_segmask_iou 0.58419, cl_phrase_acc 0.99545, 35.69 secs
# ---- Epoch 177/200
# (1) Training stage (lr = 0.000007) ...
# loss 0.49372, cibg_att_sup_loss 0.56136, cibg_segmask_iou 0.47555, pg_att_sup_loss 0.30251, pg_segmask_iou 0.71973, vbg_phrcls_loss 0.08440, vbg_prc_auc 0.99953, vbg_att_reg_loss 0.14386, vbg_att_sup_loss 0.44392, vbg_segmask_iou 0.36455, cl_att_sup_loss 0.18261, cl_segmask_iou 0.58202, cl_phrcls_loss 0.00829, cl_phrase_acc 0.99981, 130.88 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.19480, pg_segmask_iou 0.59392, cl_att_sup_loss 0.17007, cl_segmask_iou 0.58830, cl_phrase_acc 0.99745, 39.05 secs
# ---- Epoch 178/200
# (1) Training stage (lr = 0.000003) ...
# loss 0.49006, cibg_att_sup_loss 0.56491, cibg_segmask_iou 0.47336, pg_att_sup_loss 0.29470, pg_segmask_iou 0.72212, vbg_phrcls_loss 0.07751, vbg_prc_auc 0.99946, vbg_att_reg_loss 0.14452, vbg_att_sup_loss 0.44115, vbg_segmask_iou 0.37181, cl_att_sup_loss 0.18512, cl_segmask_iou 0.59159, cl_phrcls_loss 0.00804, cl_phrase_acc 0.99963, 129.94 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.18898, pg_segmask_iou 0.60479, cl_att_sup_loss 0.16939, cl_segmask_iou 0.59827, cl_phrase_acc 0.99845, 40.63 secs
# ---- Epoch 179/200
# (1) Training stage (lr = 0.000002) ...
# loss 0.48452, cibg_att_sup_loss 0.55651, cibg_segmask_iou 0.47625, pg_att_sup_loss 0.29110, pg_segmask_iou 0.72346, vbg_phrcls_loss 0.07943, vbg_prc_auc 0.99913, vbg_att_reg_loss 0.13917, vbg_att_sup_loss 0.43588, vbg_segmask_iou 0.36765, cl_att_sup_loss 0.18446, cl_segmask_iou 0.58617, cl_phrcls_loss 0.00773, cl_phrase_acc 1.00000, 129.03 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.17960, pg_segmask_iou 0.61667, cl_att_sup_loss 0.18804, cl_segmask_iou 0.58570, cl_phrase_acc 0.99656, 39.53 secs
# ---- Epoch 180/200
# (1) Training stage (lr = 0.000001) ...
# loss 0.48203, cibg_att_sup_loss 0.54966, cibg_segmask_iou 0.48225, pg_att_sup_loss 0.29027, pg_segmask_iou 0.72316, vbg_phrcls_loss 0.07434, vbg_prc_auc 0.99929, vbg_att_reg_loss 0.14188, vbg_att_sup_loss 0.43569, vbg_segmask_iou 0.36591, cl_att_sup_loss 0.18914, cl_segmask_iou 0.59335, cl_phrcls_loss 0.00775, cl_phrase_acc 1.00000, 133.23 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.18899, pg_segmask_iou 0.60467, cl_att_sup_loss 0.17637, cl_segmask_iou 0.59031, cl_phrase_acc 0.99767, 36.55 secs
# ---- Epoch 181/200
# (1) Training stage (lr = 0.000080) ...
# loss 0.50583, cibg_att_sup_loss 0.55833, cibg_segmask_iou 0.47753, pg_att_sup_loss 0.32569, pg_segmask_iou 0.70943, vbg_phrcls_loss 0.11732, vbg_prc_auc 0.99813, vbg_att_reg_loss 0.14240, vbg_att_sup_loss 0.44154, vbg_segmask_iou 0.37012, cl_att_sup_loss 0.18713, cl_segmask_iou 0.58460, cl_phrcls_loss 0.00666, cl_phrase_acc 1.00000, 131.05 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.20334, pg_segmask_iou 0.58579, cl_att_sup_loss 0.15117, cl_segmask_iou 0.59948, cl_phrase_acc 0.99645, 38.98 secs
# ---- Epoch 182/200
# (1) Training stage (lr = 0.000043) ...
# loss 0.52916, cibg_att_sup_loss 0.55231, cibg_segmask_iou 0.48107, pg_att_sup_loss 0.35120, pg_segmask_iou 0.70195, vbg_phrcls_loss 0.15425, vbg_prc_auc 0.99627, vbg_att_reg_loss 0.14578, vbg_att_sup_loss 0.46318, vbg_segmask_iou 0.35860, cl_att_sup_loss 0.18066, cl_segmask_iou 0.57713, cl_phrcls_loss 0.01048, cl_phrase_acc 1.00000, 130.19 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.18382, pg_segmask_iou 0.61192, cl_att_sup_loss 0.19092, cl_segmask_iou 0.58115, cl_phrase_acc 0.99335, 39.37 secs
# ---- Epoch 183/200
# (1) Training stage (lr = 0.000023) ...
# loss 0.50988, cibg_att_sup_loss 0.55461, cibg_segmask_iou 0.48141, pg_att_sup_loss 0.32683, pg_segmask_iou 0.71013, vbg_phrcls_loss 0.11118, vbg_prc_auc 0.99842, vbg_att_reg_loss 0.14359, vbg_att_sup_loss 0.45680, vbg_segmask_iou 0.36148, cl_att_sup_loss 0.18681, cl_segmask_iou 0.59036, cl_phrcls_loss 0.01123, cl_phrase_acc 0.99944, 131.70 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.19283, pg_segmask_iou 0.59953, cl_att_sup_loss 0.18273, cl_segmask_iou 0.58704, cl_phrase_acc 0.99756, 41.36 secs
# ---- Epoch 184/200
# (1) Training stage (lr = 0.000012) ...
# loss 0.48889, cibg_att_sup_loss 0.55232, cibg_segmask_iou 0.48304, pg_att_sup_loss 0.30372, pg_segmask_iou 0.72026, vbg_phrcls_loss 0.08970, vbg_prc_auc 0.99936, vbg_att_reg_loss 0.14056, vbg_att_sup_loss 0.44473, vbg_segmask_iou 0.36129, cl_att_sup_loss 0.17212, cl_segmask_iou 0.58082, cl_phrcls_loss 0.00661, cl_phrase_acc 1.00000, 132.85 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.18579, pg_segmask_iou 0.60979, cl_att_sup_loss 0.16551, cl_segmask_iou 0.59650, cl_phrase_acc 0.99800, 37.46 secs
# New checkpoint saved: checkpoint_184_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.7740.pt
# ---- Epoch 185/200
# (1) Training stage (lr = 0.000007) ...
# loss 0.48700, cibg_att_sup_loss 0.55913, cibg_segmask_iou 0.48129, pg_att_sup_loss 0.29219, pg_segmask_iou 0.72455, vbg_phrcls_loss 0.08602, vbg_prc_auc 0.99894, vbg_att_reg_loss 0.13620, vbg_att_sup_loss 0.43634, vbg_segmask_iou 0.37427, cl_att_sup_loss 0.18232, cl_segmask_iou 0.59011, cl_phrcls_loss 0.01029, cl_phrase_acc 0.99962, 129.23 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.18223, pg_segmask_iou 0.61429, cl_att_sup_loss 0.17639, cl_segmask_iou 0.58893, cl_phrase_acc 0.99656, 41.83 secs
# ---- Epoch 186/200
# (1) Training stage (lr = 0.000003) ...
# loss 0.48338, cibg_att_sup_loss 0.54992, cibg_segmask_iou 0.48301, pg_att_sup_loss 0.28636, pg_segmask_iou 0.72700, vbg_phrcls_loss 0.07865, vbg_prc_auc 0.99935, vbg_att_reg_loss 0.14465, vbg_att_sup_loss 0.43928, vbg_segmask_iou 0.36699, cl_att_sup_loss 0.18136, cl_segmask_iou 0.58722, cl_phrcls_loss 0.00564, cl_phrase_acc 1.00000, 130.39 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.19519, pg_segmask_iou 0.59534, cl_att_sup_loss 0.16125, cl_segmask_iou 0.59621, cl_phrase_acc 0.99800, 39.39 secs
# ---- Epoch 187/200
# (1) Training stage (lr = 0.000002) ...
# loss 0.47729, cibg_att_sup_loss 0.55304, cibg_segmask_iou 0.48215, pg_att_sup_loss 0.28234, pg_segmask_iou 0.72905, vbg_phrcls_loss 0.07376, vbg_prc_auc 0.99964, vbg_att_reg_loss 0.14327, vbg_att_sup_loss 0.43108, vbg_segmask_iou 0.37096, cl_att_sup_loss 0.17729, cl_segmask_iou 0.58837, cl_phrcls_loss 0.00551, cl_phrase_acc 1.00000, 128.13 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.18695, pg_segmask_iou 0.60606, cl_att_sup_loss 0.18165, cl_segmask_iou 0.58811, cl_phrase_acc 0.99778, 34.85 secs
# ---- Epoch 188/200
# (1) Training stage (lr = 0.000001) ...
# loss 0.47859, cibg_att_sup_loss 0.54784, cibg_segmask_iou 0.48433, pg_att_sup_loss 0.28063, pg_segmask_iou 0.72963, vbg_phrcls_loss 0.07724, vbg_prc_auc 0.99939, vbg_att_reg_loss 0.13510, vbg_att_sup_loss 0.44393, vbg_segmask_iou 0.36558, cl_att_sup_loss 0.17480, cl_segmask_iou 0.59014, cl_phrcls_loss 0.00612, cl_phrase_acc 1.00000, 131.89 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.17934, pg_segmask_iou 0.61885, cl_att_sup_loss 0.18768, cl_segmask_iou 0.58488, cl_phrase_acc 0.99723, 41.68 secs
# ---- Epoch 189/200
# (1) Training stage (lr = 0.000080) ...
# loss 0.50272, cibg_att_sup_loss 0.57457, cibg_segmask_iou 0.47899, pg_att_sup_loss 0.31723, pg_segmask_iou 0.71402, vbg_phrcls_loss 0.10761, vbg_prc_auc 0.99833, vbg_att_reg_loss 0.13745, vbg_att_sup_loss 0.43719, vbg_segmask_iou 0.36794, cl_att_sup_loss 0.17426, cl_segmask_iou 0.58594, cl_phrcls_loss 0.00948, cl_phrase_acc 0.99963, 131.23 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.19097, pg_segmask_iou 0.60303, cl_att_sup_loss 0.15576, cl_segmask_iou 0.59615, cl_phrase_acc 0.99545, 36.40 secs
# ---- Epoch 190/200
# (1) Training stage (lr = 0.000043) ...
# loss 0.51841, cibg_att_sup_loss 0.55273, cibg_segmask_iou 0.48424, pg_att_sup_loss 0.34540, pg_segmask_iou 0.70392, vbg_phrcls_loss 0.13270, vbg_prc_auc 0.99753, vbg_att_reg_loss 0.14239, vbg_att_sup_loss 0.45888, vbg_segmask_iou 0.36654, cl_att_sup_loss 0.18322, cl_segmask_iou 0.58235, cl_phrcls_loss 0.01214, cl_phrase_acc 0.99944, 133.56 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.19236, pg_segmask_iou 0.59990, cl_att_sup_loss 0.14663, cl_segmask_iou 0.60049, cl_phrase_acc 0.99778, 35.57 secs
# New checkpoint saved: checkpoint_190_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.7741.pt
# ---- Epoch 191/200
# (1) Training stage (lr = 0.000023) ...
# loss 0.50237, cibg_att_sup_loss 0.54752, cibg_segmask_iou 0.48536, pg_att_sup_loss 0.32161, pg_segmask_iou 0.71578, vbg_phrcls_loss 0.10860, vbg_prc_auc 0.99836, vbg_att_reg_loss 0.14309, vbg_att_sup_loss 0.44610, vbg_segmask_iou 0.35682, cl_att_sup_loss 0.18447, cl_segmask_iou 0.59056, cl_phrcls_loss 0.01592, cl_phrase_acc 0.99962, 130.53 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.17855, pg_segmask_iou 0.62111, cl_att_sup_loss 0.16413, cl_segmask_iou 0.59610, cl_phrase_acc 0.99789, 39.87 secs
# New checkpoint saved: checkpoint_191_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.7769.pt
# ---- Epoch 192/200
# (1) Training stage (lr = 0.000012) ...
# loss 0.48867, cibg_att_sup_loss 0.55052, cibg_segmask_iou 0.48817, pg_att_sup_loss 0.29681, pg_segmask_iou 0.72480, vbg_phrcls_loss 0.08625, vbg_prc_auc 0.99900, vbg_att_reg_loss 0.14067, vbg_att_sup_loss 0.44782, vbg_segmask_iou 0.37038, cl_att_sup_loss 0.17443, cl_segmask_iou 0.59066, cl_phrcls_loss 0.00830, cl_phrase_acc 1.00000, 118.08 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.18942, pg_segmask_iou 0.60337, cl_att_sup_loss 0.16920, cl_segmask_iou 0.59235, cl_phrase_acc 0.99678, 33.72 secs
# ---- Epoch 193/200
# (1) Training stage (lr = 0.000007) ...
# loss 0.48000, cibg_att_sup_loss 0.55636, cibg_segmask_iou 0.48702, pg_att_sup_loss 0.28404, pg_segmask_iou 0.73050, vbg_phrcls_loss 0.07455, vbg_prc_auc 0.99941, vbg_att_reg_loss 0.13889, vbg_att_sup_loss 0.43813, vbg_segmask_iou 0.36805, cl_att_sup_loss 0.17837, cl_segmask_iou 0.58937, cl_phrcls_loss 0.00541, cl_phrase_acc 1.00000, 99.78 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.19146, pg_segmask_iou 0.60029, cl_att_sup_loss 0.15457, cl_segmask_iou 0.59631, cl_phrase_acc 0.99745, 26.14 secs
# ---- Epoch 194/200
# (1) Training stage (lr = 0.000003) ...
# loss 0.47612, cibg_att_sup_loss 0.54129, cibg_segmask_iou 0.48739, pg_att_sup_loss 0.27714, pg_segmask_iou 0.73291, vbg_phrcls_loss 0.08236, vbg_prc_auc 0.99922, vbg_att_reg_loss 0.13467, vbg_att_sup_loss 0.44277, vbg_segmask_iou 0.36855, cl_att_sup_loss 0.17048, cl_segmask_iou 0.58326, cl_phrcls_loss 0.00516, cl_phrase_acc 1.00000, 95.83 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.17458, pg_segmask_iou 0.62553, cl_att_sup_loss 0.18084, cl_segmask_iou 0.58865, cl_phrase_acc 0.99579, 24.87 secs
# ---- Epoch 195/200
# (1) Training stage (lr = 0.000002) ...
# loss 0.47180, cibg_att_sup_loss 0.54749, cibg_segmask_iou 0.48599, pg_att_sup_loss 0.27426, pg_segmask_iou 0.73313, vbg_phrcls_loss 0.07033, vbg_prc_auc 0.99942, vbg_att_reg_loss 0.13907, vbg_att_sup_loss 0.42918, vbg_segmask_iou 0.36621, cl_att_sup_loss 0.17752, cl_segmask_iou 0.59331, cl_phrcls_loss 0.00506, cl_phrase_acc 1.00000, 93.74 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.19191, pg_segmask_iou 0.60107, cl_att_sup_loss 0.16832, cl_segmask_iou 0.59346, cl_phrase_acc 0.99778, 24.14 secs
# ---- Epoch 196/200
# (1) Training stage (lr = 0.000001) ...
# loss 0.47503, cibg_att_sup_loss 0.54577, cibg_segmask_iou 0.48754, pg_att_sup_loss 0.27196, pg_segmask_iou 0.73485, vbg_phrcls_loss 0.08223, vbg_prc_auc 0.99887, vbg_att_reg_loss 0.14126, vbg_att_sup_loss 0.42767, vbg_segmask_iou 0.37994, cl_att_sup_loss 0.18179, cl_segmask_iou 0.59061, cl_phrcls_loss 0.00624, cl_phrase_acc 0.99981, 93.60 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.18549, pg_segmask_iou 0.61127, cl_att_sup_loss 0.15310, cl_segmask_iou 0.60676, cl_phrase_acc 0.99867, 23.72 secs
# New checkpoint saved: checkpoint_196_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.7787.pt
# ---- Epoch 197/200
# (1) Training stage (lr = 0.000080) ...
# loss 0.49686, cibg_att_sup_loss 0.54455, cibg_segmask_iou 0.48945, pg_att_sup_loss 0.31300, pg_segmask_iou 0.71889, vbg_phrcls_loss 0.10739, vbg_prc_auc 0.99836, vbg_att_reg_loss 0.14326, vbg_att_sup_loss 0.44695, vbg_segmask_iou 0.36625, cl_att_sup_loss 0.17253, cl_segmask_iou 0.58823, cl_phrcls_loss 0.00960, cl_phrase_acc 0.99981, 92.30 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.18253, pg_segmask_iou 0.61516, cl_att_sup_loss 0.17397, cl_segmask_iou 0.58920, cl_phrase_acc 0.99568, 23.56 secs
# ---- Epoch 198/200
# (1) Training stage (lr = 0.000043) ...
# loss 0.51867, cibg_att_sup_loss 0.54569, cibg_segmask_iou 0.49018, pg_att_sup_loss 0.34377, pg_segmask_iou 0.70822, vbg_phrcls_loss 0.14575, vbg_prc_auc 0.99650, vbg_att_reg_loss 0.13912, vbg_att_sup_loss 0.45489, vbg_segmask_iou 0.36783, cl_att_sup_loss 0.18569, cl_segmask_iou 0.58251, cl_phrcls_loss 0.00948, cl_phrase_acc 1.00000, 91.77 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.20051, pg_segmask_iou 0.59204, cl_att_sup_loss 0.15532, cl_segmask_iou 0.59865, cl_phrase_acc 0.99745, 23.27 secs
# ---- Epoch 199/200
# (1) Training stage (lr = 0.000023) ...
# loss 0.50110, cibg_att_sup_loss 0.54540, cibg_segmask_iou 0.49013, pg_att_sup_loss 0.31770, pg_segmask_iou 0.71767, vbg_phrcls_loss 0.11373, vbg_prc_auc 0.99820, vbg_att_reg_loss 0.13956, vbg_att_sup_loss 0.44982, vbg_segmask_iou 0.36601, cl_att_sup_loss 0.17950, cl_segmask_iou 0.58705, cl_phrcls_loss 0.01606, cl_phrase_acc 0.99981, 92.48 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.20086, pg_segmask_iou 0.58844, cl_att_sup_loss 0.15056, cl_segmask_iou 0.59626, cl_phrase_acc 0.99667, 23.09 secs
# ---- Epoch 200/200
# (1) Training stage (lr = 0.000012) ...
# loss 0.48518, cibg_att_sup_loss 0.55012, cibg_segmask_iou 0.48920, pg_att_sup_loss 0.29330, pg_segmask_iou 0.72769, vbg_phrcls_loss 0.08655, vbg_prc_auc 0.99916, vbg_att_reg_loss 0.14034, vbg_att_sup_loss 0.44173, vbg_segmask_iou 0.36247, cl_att_sup_loss 0.17097, cl_segmask_iou 0.58850, cl_phrcls_loss 0.00749, cl_phrase_acc 0.99981, 91.56 secs
# (2) Validation stage ...
# pg_att_sup_loss 0.17732, pg_segmask_iou 0.62331, cl_att_sup_loss 0.17815, cl_segmask_iou 0.59124, cl_phrase_acc 0.99579, 23.03 secs
