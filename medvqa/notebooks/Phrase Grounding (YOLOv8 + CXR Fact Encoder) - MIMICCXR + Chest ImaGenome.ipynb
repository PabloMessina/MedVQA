# %%
# %env CUDA_VISIBLE_DEVICES=0
# Out:
# env: CUDA_VISIBLE_DEVICES=0

# %%
# !python ../scripts/chest_imagenome/precompute_bbox_phrase_embeddings.py \
--model_name "microsoft/BiomedVLP-CXR-BERT-specialized" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20231018_230637_MIMIC-CXR(triplets+classif+entcont+nli+autoencoder)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)"
# Out:
# Obtaining embeddings for each sentence...
# checkpoint_names = ['checkpoint_91_cacc+chf1+chf1+cscc+encc+hscc+nlcc+sass+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9248.pt']
#   0%|                                                    | 0/36 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=426,702090393457262989).pkl
# len(self.cache["hashes"]) = 36
# self.cache["embeddings"].shape = (36, 128)
# 100%|████████████████████████████████████████| 36/36 [00:00<00:00, 80702.80it/s]
# Saving output to: /mnt/workspace/pamessina/medvqa-workspace/cache/chest_imagenome/bbox_phrase_embeddings.pkl
# Done!

# %%
# "/mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20230608_153404_mim+vinbig_yolov8l_dws=1.0,0.5" \

# %%
# !python ../train_phrase_grounding.py \
--pretrained_checkpoint_folder_paths \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20231122_073114_chst-img-anat_PhraseGrounder(yolov8l,128,256)" \
--epochs 200 \
--batches_per_epoch 250 \
--max_images_per_batch 100 \
--max_phrases_per_batch 2000 \
--max_phrases_per_image 20 \
--val_batch_size_factor 3 \
--image_size 416 416 \
--image_local_feat_size 512 \
--num_regions 169 \
--regions_width 13 \
--regions_height 13 \
--yolov8_model_name_or_path "yolov8l.pt" \
--yolov8_model_alias "yolov8l" \
--phrase_embedding_size 128 \
--qkv_size 256 \
--phrase_classifier_hidden_size 256 \
--num_train_workers 3 \
--num_val_workers 3 \
--iters_to_accumulate 10 \
--optimizer_name "adamw" \
--scheduler "exp-warmup+decay+cyclicdecay" \
--lr 1e-6 \
--warmup_decay_and_cyclic_decay_args "1e-6,3,1e-4,8,5e-6,1e-4,8,5e-6" \
--use_chest_imagenome_for_train \
--use_chest_imagenome_gold_for_test \
--chest_imagenome_bbox_phrase_embeddings_filepath \
"/mnt/workspace/pamessina/medvqa-workspace/cache/chest_imagenome/bbox_phrase_embeddings.pkl" \
--attention_supervision_loss_weight 3.0 \
--phrase_classifier_loss_weight 1.0 \
--use_amp \
--save
# Out:
# script's arguments:
#    epochs: 200
#    batches_per_epoch: 250
#    max_images_per_batch: 100
#    max_phrases_per_batch: 2000
#    max_phrases_per_image: 20
#    val_batch_size_factor: 3
#    checkpoint_folder: None
#    pretrained_checkpoint_folder_path: None
#    pretrained_checkpoint_folder_paths: ['/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20231122_073114_chst-img-anat_PhraseGrounder(yolov8l,128,256)']
#    freeze_image_encoder: False
#    raw_image_encoding: yolov8
#    num_regions: 169
#    image_local_feat_size: 512
#    image_encoder_pretrained_weights_path: None
#    yolov8_model_name_or_path: yolov8l.pt
#    yolov8_model_alias: yolov8l
#    yolov8_use_one_detector_per_dataset: False
#    phrase_embedding_size: 128
#    regions_width: 13
#    regions_height: 13
#    qkv_size: 256
#    phrase_classifier_hidden_size: 256
#    optimizer_name: adamw
#    lr: 1e-06
#    scheduler: exp-warmup+decay+cyclicdecay
#    lr_decay: 0.76
#    lr_decay_patience: 2
#    warmup_and_decay_args: None
#    warmup_and_cosine_args: None
#    warmup_decay_and_cyclic_decay_args: 1e-6,3,1e-4,8,5e-6,1e-4,8,5e-6
#    iters_to_accumulate: 10
#    override_lr: False
#    max_grad_norm: None
#    attention_supervision_loss_weight: 3.0
#    phrase_classifier_loss_weight: 1.0
#    num_train_workers: 3
#    num_val_workers: 3
#    device: GPU
#    use_amp: True
#    image_size: [416, 416]
#    dicom_id_to_pos_neg_facts_filepath: None
#    mscxr_phrase2embedding_filepath: None
#    chest_imagenome_bbox_phrase_embeddings_filepath: /mnt/workspace/pamessina/medvqa-workspace/cache/chest_imagenome/bbox_phrase_embeddings.pkl
#    exclude_noisy_images: False
#    mimiccxr_facts_weight: 1.0
#    chest_imagenome_anatlocs_weight: 1.0
#    img_aug_mode: None
#    pos_area_prior: 0.4
#    neg_area_prior: 0.0
#    use_mimiccxr_facts_for_train: False
#    use_mscxr_for_test: False
#    use_chest_imagenome_for_train: True
#    use_chest_imagenome_gold_for_test: True
#    save: True
# ----- Training model from scratch ------
# source_image_size_mode: medium_512
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Creating instance of PhraseGrounder ...
# WARNING: Unused kwargs: {'pretrained_checkpoint_folder_path': None, 'pretrained_checkpoint_folder_paths': ['/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20231122_073114_chst-img-anat_PhraseGrounder(yolov8l,128,256)']}
# MultiPurposeVisualModule()
#   Initializing raw_image_encoder: yolov8
#   num_bbox_classes: 36
# Overriding model.yaml nc=80 with nc=36
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.Conv                  [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.Conv                  [64, 128, 3, 2]
#   2                  -1  3    279808  ultralytics.nn.modules.C2f                   [128, 128, 3, True]
#   3                  -1  1    295424  ultralytics.nn.modules.Conv                  [128, 256, 3, 2]
#   4                  -1  6   2101248  ultralytics.nn.modules.C2f                   [256, 256, 6, True]
#   5                  -1  1   1180672  ultralytics.nn.modules.Conv                  [256, 512, 3, 2]
#   6                  -1  6   8396800  ultralytics.nn.modules.C2f                   [512, 512, 6, True]
#   7                  -1  1   2360320  ultralytics.nn.modules.Conv                  [512, 512, 3, 2]
#   8                  -1  3   4461568  ultralytics.nn.modules.C2f                   [512, 512, 3, True]
#   9                  -1  1    656896  ultralytics.nn.modules.SPPF                  [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.Concat                [1]
#  12                  -1  3   4723712  ultralytics.nn.modules.C2f                   [1024, 512, 3]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.Concat                [1]
#  15                  -1  3   1247744  ultralytics.nn.modules.C2f                   [768, 256, 3]
#  16                  -1  1    590336  ultralytics.nn.modules.Conv                  [256, 256, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.Concat                [1]
#  18                  -1  3   4592640  ultralytics.nn.modules.C2f                   [768, 512, 3]
#  19                  -1  1   2360320  ultralytics.nn.modules.Conv                  [512, 512, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.Concat                [1]
#  21                  -1  3   4723712  ultralytics.nn.modules.C2f                   [1024, 512, 3]
#  22        [15, 18, 21]  1   5610556  ultralytics.nn.modules.Detect                [36, [256, 512, 512]]
# Model summary: 365 layers, 43657596 parameters, 43657580 gradients, 165.6 GFLOPs
#
# Transferred 589/595 items from pretrained weights
#   self.global_feat_size = 1024
#   self.local_feat_size = 512
#   Initializing auxiliary tasks
# --------------------------------------------------
# 3) Defining optimizer ...
# create_optimizer(): name = adamw
# --------------------------------------------------
# 4) Defining scheduler ...
# Using exp-warmup+decay+cyclicdecay scheduler: 1e-6,3,1e-4,8,5e-6,1e-4,8,5e-6
# 1e-06 3 0.0001 8 5e-06 0.0001 8 5e-06
# self.steps_to_restart = 8
# self.steps = -1
# self.initial_lr = 0.0001
# --------------------------------------------------
# 5) Creating trainer and validator engines ...
# GradientAccumulator.__init__(): num_accumulation_steps = 10, max_grad_norm = None
# --------------------------------------------------
# 6) Creating MIMIC-CXR Phrase Grounding Trainer ...
# get_image_transform()
#   Using bounding box aware transforms
#     Returning default transform (no augmentation)
# get_image_transform()
#   Using bounding box aware transforms
#     Returning default transform (no augmentation)
# len(forbidden_train_dicom_ids) = 1000
# Preparing Chest Imagenome dataset and dataloader for training...
# bbox_phrase_embeddings.shape = (36, 128)
# len(bbox_phrases) = 36
# 	 right lung
# 	 right upper lung zone
# 	 right mid lung zone
# 	 right lower lung zone
# 	 right hilar structures
# 	 right apical zone
# 	 right costophrenic angle
# 	 right cardiophrenic angle
# 	 right hemidiaphragm
# 	 left lung
# 	 left upper lung zone
# 	 left mid lung zone
# 	 left lower lung zone
# 	 left hilar structures
# 	 left apical zone
# 	 left costophrenic angle
# 	 left hemidiaphragm
# 	 trachea
# 	 spine
# 	 right clavicle
# 	 left clavicle
# 	 aortic arch
# 	 mediastinum
# 	 upper mediastinum
# 	 svc
# 	 cardiac silhouette
# 	 left cardiac silhouette
# 	 right cardiac silhouette
# 	 cavoatrial junction
# 	 right atrium
# 	 descending aorta
# 	 carina
# 	 left upper abdomen
# 	 right upper abdomen
# 	 abdomen
# 	 left cardiophrenic angle
# Using image size mode: medium_512
# Loading precomputed bbox_coords_and_presence_and_mask from /mnt/workspace/pamessina/medvqa-workspace/cache/mimiccxr/bbox_coords_and_presence_and_mask(13,13,243310).pkl...
# 227835it [00:01, 168946.45it/s]
# Total number of images: 242310
# Preparing Chest Imagenome dataset and dataloader for testing...
# bbox_phrase_embeddings.shape = (26, 128)
# len(bbox_phrases) = 26
# 	 right lung
# 	 right upper lung zone
# 	 right mid lung zone
# 	 right lower lung zone
# 	 right hilar structures
# 	 right apical zone
# 	 right costophrenic angle
# 	 right hemidiaphragm
# 	 left lung
# 	 left upper lung zone
# 	 left mid lung zone
# 	 left lower lung zone
# 	 left hilar structures
# 	 left apical zone
# 	 left costophrenic angle
# 	 left hemidiaphragm
# 	 trachea
# 	 right clavicle
# 	 left clavicle
# 	 aortic arch
# 	 upper mediastinum
# 	 svc
# 	 cardiac silhouette
# 	 cavoatrial junction
# 	 right atrium
# 	 carina
# Using image size mode: medium_512
# 227835it [00:02, 81826.69it/s]
# Total number of images: 1000
# --------------------------------------------------
# 7) Creating dataloaders ...
# len(_train_dataloaders) = 1
# len(_val_dataloaders) = 1
# _train_weights = [1.0]
# merged_dataset_name = chst-img-anat
# --------------------------------------------------
# 8) Attaching metrics, losses, timer and events to engines ...
# --------------------------------------------------
# 9) Defining learning rate scheduler handler ...
# --------------------------------------------------
# 10) Defining learning rate scheduler handler ...
# --------------------------------------------------
# 11) Defining checkpoint folder path ...
# checkpoint_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20231122_083436_chst-img-anat_PhraseGrounder(yolov8l,128,256)
# metadata saved to /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20231122_083436_chst-img-anat_PhraseGrounder(yolov8l,128,256)/metadata.json
# --------------------------------------------------
# 12) Loading pretrained weights ...
# checkpoint_names = ['checkpoint_27_chestimgbbiou+phrase_acc+segmask_iou=0.7413.pt']
# pretrained_checkpoint_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20231122_073114_chst-img-anat_PhraseGrounder(yolov8l,128,256)/checkpoint_27_chestimgbbiou+phrase_acc+segmask_iou=0.7413.pt
# Warning: model state dict has 610 keys, loaded state dict has 608 keys, intersection has 608 keys, union has 610 keys.
# Examples of keys in model but not in loaded state dict:
#   att_proj.bias
#   att_proj.weight
# Checkpoint successfully loaded!
# --------------------------------------------------
# 13) Defining log_metrics_handler ...
# MetricsLogger :: we'll be logging to /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20231122_083436_chst-img-anat_PhraseGrounder(yolov8l,128,256)/metrics_logs.csv
# --------------------------------------------------
# 14) Running trainer engine ...
# ---- Epoch 1/200
# (1) Training stage (lr = 0.000001) ...
# loss 4.72712, y8_loss 2.39823, y8box_loss 0.83434, y8cls_loss 0.43006, y8dfl_loss 1.13383, phrase_acc 0.99250, phrcls_loss 0.05617, att_sup_loss 2.27272, segmask_iou 0.17011, 132.10 secs
# (2) Validation stage ...
# chestimgbbiou 0.97248, phrase_acc 0.99850, segmask_iou 0.12613, 17.49 secs
# New checkpoint saved: checkpoint_1_chestimgbbiou+phrase_acc+segmask_iou=0.6873.pt
# ---- Epoch 2/200
# (1) Training stage (lr = 0.000005) ...
# loss 4.67670, y8_loss 2.38946, y8box_loss 0.83007, y8cls_loss 0.42820, y8dfl_loss 1.13119, phrase_acc 0.99268, phrcls_loss 0.05509, att_sup_loss 2.23215, segmask_iou 0.18078, 124.61 secs
# (2) Validation stage ...
# chestimgbbiou 0.96930, phrase_acc 0.99850, segmask_iou 0.14141, 18.44 secs
# New checkpoint saved: checkpoint_2_chestimgbbiou+phrase_acc+segmask_iou=0.6914.pt
# ---- Epoch 3/200
# (1) Training stage (lr = 0.000022) ...
# loss 4.54856, y8_loss 2.40853, y8box_loss 0.83900, y8cls_loss 0.43387, y8dfl_loss 1.13565, phrase_acc 0.99270, phrcls_loss 0.05365, att_sup_loss 2.08639, segmask_iou 0.19242, 128.96 secs
# (2) Validation stage ...
# chestimgbbiou 0.95048, phrase_acc 0.99850, segmask_iou 0.12857, 19.04 secs
# ---- Epoch 4/200
# (1) Training stage (lr = 0.000100) ...
# loss 4.35258, y8_loss 2.56199, y8box_loss 0.90209, y8cls_loss 0.49062, y8dfl_loss 1.16928, phrase_acc 0.99305, phrcls_loss 0.04516, att_sup_loss 1.74542, segmask_iou 0.20370, 133.84 secs
# (2) Validation stage ...
# chestimgbbiou 0.91601, phrase_acc 0.99750, segmask_iou 0.05678, 16.59 secs
# ---- Epoch 5/200
# (1) Training stage (lr = 0.000069) ...
# loss 3.96490, y8_loss 2.45439, y8box_loss 0.86001, y8cls_loss 0.44766, y8dfl_loss 1.14672, phrase_acc 0.99208, phrcls_loss 0.03998, att_sup_loss 1.47052, segmask_iou 0.22189, 135.14 secs
# (2) Validation stage ...
# chestimgbbiou 0.95007, phrase_acc 0.99850, segmask_iou 0.17670, 21.14 secs
# New checkpoint saved: checkpoint_5_chestimgbbiou+phrase_acc+segmask_iou=0.6983.pt
# ---- Epoch 6/200
# (1) Training stage (lr = 0.000047) ...
# loss 3.80105, y8_loss 2.41401, y8box_loss 0.84569, y8cls_loss 0.43267, y8dfl_loss 1.13566, phrase_acc 0.99319, phrcls_loss 0.03515, att_sup_loss 1.35188, segmask_iou 0.23595, 134.56 secs
# (2) Validation stage ...
# chestimgbbiou 0.93735, phrase_acc 0.99846, segmask_iou 0.14684, 19.54 secs
# ---- Epoch 7/200
# (1) Training stage (lr = 0.000033) ...
# loss 3.70929, y8_loss 2.38715, y8box_loss 0.83224, y8cls_loss 0.42518, y8dfl_loss 1.12973, phrase_acc 0.99250, phrcls_loss 0.03481, att_sup_loss 1.28733, segmask_iou 0.24775, 135.00 secs
# (2) Validation stage ...
# chestimgbbiou 0.95711, phrase_acc 0.99850, segmask_iou 0.20260, 22.03 secs
# New checkpoint saved: checkpoint_7_chestimgbbiou+phrase_acc+segmask_iou=0.7095.pt
# ---- Epoch 8/200
# (1) Training stage (lr = 0.000022) ...
# loss 3.67758, y8_loss 2.39274, y8box_loss 0.83460, y8cls_loss 0.42640, y8dfl_loss 1.13174, phrase_acc 0.99206, phrcls_loss 0.03524, att_sup_loss 1.24960, segmask_iou 0.25483, 136.18 secs
# (2) Validation stage ...
# chestimgbbiou 0.95521, phrase_acc 0.99850, segmask_iou 0.20700, 22.79 secs
# New checkpoint saved: checkpoint_8_chestimgbbiou+phrase_acc+segmask_iou=0.7106.pt
# ---- Epoch 9/200
# (1) Training stage (lr = 0.000015) ...
# loss 3.63073, y8_loss 2.37648, y8box_loss 0.82860, y8cls_loss 0.42178, y8dfl_loss 1.12610, phrase_acc 0.99227, phrcls_loss 0.03326, att_sup_loss 1.22098, segmask_iou 0.25947, 136.53 secs
# (2) Validation stage ...
# chestimgbbiou 0.96368, phrase_acc 0.99846, segmask_iou 0.21613, 22.33 secs
# New checkpoint saved: checkpoint_9_chestimgbbiou+phrase_acc+segmask_iou=0.7161.pt
# ---- Epoch 10/200
# (1) Training stage (lr = 0.000011) ...
# loss 3.59496, y8_loss 2.35855, y8box_loss 0.82004, y8cls_loss 0.41633, y8dfl_loss 1.12218, phrase_acc 0.99251, phrcls_loss 0.03276, att_sup_loss 1.20365, segmask_iou 0.26284, 136.01 secs
# (2) Validation stage ...
# chestimgbbiou 0.96849, phrase_acc 0.99850, segmask_iou 0.22275, 22.97 secs
# New checkpoint saved: checkpoint_10_chestimgbbiou+phrase_acc+segmask_iou=0.7197.pt
# ---- Epoch 11/200
# (1) Training stage (lr = 0.000007) ...
# loss 3.60169, y8_loss 2.37224, y8box_loss 0.82553, y8cls_loss 0.42065, y8dfl_loss 1.12607, phrase_acc 0.99186, phrcls_loss 0.03387, att_sup_loss 1.19558, segmask_iou 0.26428, 139.60 secs
# (2) Validation stage ...
# chestimgbbiou 0.97037, phrase_acc 0.99850, segmask_iou 0.22295, 22.07 secs
# New checkpoint saved: checkpoint_11_chestimgbbiou+phrase_acc+segmask_iou=0.7204.pt
# ---- Epoch 12/200
# (1) Training stage (lr = 0.000005) ...
# loss 3.57543, y8_loss 2.35815, y8box_loss 0.81932, y8cls_loss 0.41706, y8dfl_loss 1.12177, phrase_acc 0.99275, phrcls_loss 0.03247, att_sup_loss 1.18480, segmask_iou 0.26559, 137.47 secs
# (2) Validation stage ...
# chestimgbbiou 0.95840, phrase_acc 0.99846, segmask_iou 0.21534, 21.71 secs
# ---- Epoch 13/200
# (1) Training stage (lr = 0.000100) ...
# loss 3.62304, y8_loss 2.46007, y8box_loss 0.86780, y8cls_loss 0.44431, y8dfl_loss 1.14796, phrase_acc 0.99236, phrcls_loss 0.03213, att_sup_loss 1.13084, segmask_iou 0.27227, 136.83 secs
# (2) Validation stage ...
# chestimgbbiou 0.83338, phrase_acc 0.75888, segmask_iou 0.03228, 12.11 secs
# ---- Epoch 14/200
# (1) Training stage (lr = 0.000065) ...
# loss 3.49017, y8_loss 2.41592, y8box_loss 0.84711, y8cls_loss 0.43282, y8dfl_loss 1.13600, phrase_acc 0.99253, phrcls_loss 0.02995, att_sup_loss 1.04430, segmask_iou 0.28094, 137.49 secs
# (2) Validation stage ...
# chestimgbbiou 0.89790, phrase_acc 0.99358, segmask_iou 0.19422, 17.19 secs
# ---- Epoch 15/200
# (1) Training stage (lr = 0.000042) ...
# loss 3.42907, y8_loss 2.40033, y8box_loss 0.84027, y8cls_loss 0.42707, y8dfl_loss 1.13299, phrase_acc 0.99227, phrcls_loss 0.02869, att_sup_loss 1.00005, segmask_iou 0.28530, 136.91 secs
# (2) Validation stage ...
# chestimgbbiou 0.94582, phrase_acc 0.99573, segmask_iou 0.22102, 20.74 secs
# ---- Epoch 16/200
# (1) Training stage (lr = 0.000028) ...
# loss 3.37430, y8_loss 2.37355, y8box_loss 0.82945, y8cls_loss 0.41870, y8dfl_loss 1.12540, phrase_acc 0.99226, phrcls_loss 0.02764, att_sup_loss 0.97312, segmask_iou 0.28722, 138.58 secs
# (2) Validation stage ...
# chestimgbbiou 0.96331, phrase_acc 0.99831, segmask_iou 0.24042, 21.80 secs
# New checkpoint saved: checkpoint_16_chestimgbbiou+phrase_acc+segmask_iou=0.7246.pt
# ---- Epoch 17/200
# (1) Training stage (lr = 0.000018) ...
# loss 3.34299, y8_loss 2.35910, y8box_loss 0.82261, y8cls_loss 0.41430, y8dfl_loss 1.12219, phrase_acc 0.99238, phrcls_loss 0.02717, att_sup_loss 0.95673, segmask_iou 0.28852, 136.03 secs
# (2) Validation stage ...
# chestimgbbiou 0.96937, phrase_acc 0.99842, segmask_iou 0.24602, 22.99 secs
# New checkpoint saved: checkpoint_17_chestimgbbiou+phrase_acc+segmask_iou=0.7282.pt
# ---- Epoch 18/200
# (1) Training stage (lr = 0.000012) ...
# loss 3.31731, y8_loss 2.34599, y8box_loss 0.81596, y8cls_loss 0.41155, y8dfl_loss 1.11848, phrase_acc 0.99292, phrcls_loss 0.02574, att_sup_loss 0.94559, segmask_iou 0.28951, 143.48 secs
# (2) Validation stage ...
# chestimgbbiou 0.97002, phrase_acc 0.99846, segmask_iou 0.24619, 23.57 secs
# New checkpoint saved: checkpoint_18_chestimgbbiou+phrase_acc+segmask_iou=0.7285.pt
# ---- Epoch 19/200
# (1) Training stage (lr = 0.000008) ...
# loss 3.27797, y8_loss 2.31356, y8box_loss 0.80062, y8cls_loss 0.40331, y8dfl_loss 1.10962, phrase_acc 0.99281, phrcls_loss 0.02594, att_sup_loss 0.93848, segmask_iou 0.29012, 139.96 secs
# (2) Validation stage ...
# chestimgbbiou 0.96763, phrase_acc 0.99842, segmask_iou 0.24540, 23.27 secs
# ---- Epoch 20/200
# (1) Training stage (lr = 0.000005) ...
# loss 3.26476, y8_loss 2.30478, y8box_loss 0.79693, y8cls_loss 0.40078, y8dfl_loss 1.10708, phrase_acc 0.99232, phrcls_loss 0.02597, att_sup_loss 0.93401, segmask_iou 0.29082, 130.57 secs
# (2) Validation stage ...
# chestimgbbiou 0.97292, phrase_acc 0.99846, segmask_iou 0.24931, 22.10 secs
# New checkpoint saved: checkpoint_20_chestimgbbiou+phrase_acc+segmask_iou=0.7304.pt
# ---- Epoch 21/200
# (1) Training stage (lr = 0.000100) ...
# loss 3.36211, y8_loss 2.42428, y8box_loss 0.85593, y8cls_loss 0.43112, y8dfl_loss 1.13722, phrase_acc 0.99283, phrcls_loss 0.02520, att_sup_loss 0.91263, segmask_iou 0.29236, 138.12 secs
# (2) Validation stage ...
# chestimgbbiou 0.84411, phrase_acc 0.63965, segmask_iou 0.07229, 13.34 secs
# ---- Epoch 22/200
# (1) Training stage (lr = 0.000065) ...
# loss 3.28988, y8_loss 2.39247, y8box_loss 0.83838, y8cls_loss 0.42419, y8dfl_loss 1.12991, phrase_acc 0.99282, phrcls_loss 0.02478, att_sup_loss 0.87262, segmask_iou 0.29691, 141.33 secs
# (2) Validation stage ...
# chestimgbbiou 0.93721, phrase_acc 0.99188, segmask_iou 0.20602, 21.51 secs
# ---- Epoch 23/200
# (1) Training stage (lr = 0.000042) ...
# loss 3.22357, y8_loss 2.35341, y8box_loss 0.82075, y8cls_loss 0.41316, y8dfl_loss 1.11950, phrase_acc 0.99298, phrcls_loss 0.02450, att_sup_loss 0.84566, segmask_iou 0.30062, 142.07 secs
# (2) Validation stage ...
# chestimgbbiou 0.96670, phrase_acc 0.99827, segmask_iou 0.25295, 23.87 secs
# ---- Epoch 24/200
# (1) Training stage (lr = 0.000028) ...
# loss 3.19779, y8_loss 2.34135, y8box_loss 0.81551, y8cls_loss 0.40864, y8dfl_loss 1.11720, phrase_acc 0.99262, phrcls_loss 0.02439, att_sup_loss 0.83204, segmask_iou 0.30244, 138.99 secs
# (2) Validation stage ...
# chestimgbbiou 0.95122, phrase_acc 0.99781, segmask_iou 0.23796, 22.04 secs
# ---- Epoch 25/200
# (1) Training stage (lr = 0.000018) ...
# loss 3.17081, y8_loss 2.32158, y8box_loss 0.80600, y8cls_loss 0.40428, y8dfl_loss 1.11130, phrase_acc 0.99204, phrcls_loss 0.02536, att_sup_loss 0.82387, segmask_iou 0.30409, 141.60 secs
# (2) Validation stage ...
# chestimgbbiou 0.95777, phrase_acc 0.99815, segmask_iou 0.24998, 22.44 secs
# ---- Epoch 26/200
# (1) Training stage (lr = 0.000012) ...
# loss 3.16285, y8_loss 2.32212, y8box_loss 0.80683, y8cls_loss 0.40347, y8dfl_loss 1.11182, phrase_acc 0.99242, phrcls_loss 0.02376, att_sup_loss 0.81697, segmask_iou 0.30555, 138.43 secs
# (2) Validation stage ...
# chestimgbbiou 0.96592, phrase_acc 0.99838, segmask_iou 0.25564, 21.91 secs
# New checkpoint saved: checkpoint_26_chestimgbbiou+phrase_acc+segmask_iou=0.7309.pt
# ---- Epoch 27/200
# (1) Training stage (lr = 0.000008) ...
# loss 3.14287, y8_loss 2.30694, y8box_loss 0.80017, y8cls_loss 0.39970, y8dfl_loss 1.10707, phrase_acc 0.99250, phrcls_loss 0.02399, att_sup_loss 0.81194, segmask_iou 0.30615, 136.11 secs
# (2) Validation stage ...
# chestimgbbiou 0.96754, phrase_acc 0.99831, segmask_iou 0.25702, 20.60 secs
# New checkpoint saved: checkpoint_27_chestimgbbiou+phrase_acc+segmask_iou=0.7318.pt
# ---- Epoch 28/200
# (1) Training stage (lr = 0.000005) ...
# loss 3.15150, y8_loss 2.31642, y8box_loss 0.80440, y8cls_loss 0.40146, y8dfl_loss 1.11056, phrase_acc 0.99245, phrcls_loss 0.02411, att_sup_loss 0.81097, segmask_iou 0.30604, 136.67 secs
# (2) Validation stage ...
# chestimgbbiou 0.96917, phrase_acc 0.99850, segmask_iou 0.26178, 22.12 secs
# New checkpoint saved: checkpoint_28_chestimgbbiou+phrase_acc+segmask_iou=0.7338.pt
# ---- Epoch 29/200
# (1) Training stage (lr = 0.000100) ...
# loss 3.22534, y8_loss 2.40085, y8box_loss 0.84719, y8cls_loss 0.42261, y8dfl_loss 1.13105, phrase_acc 0.99275, phrcls_loss 0.02335, att_sup_loss 0.80114, segmask_iou 0.30822, 138.33 secs
# (2) Validation stage ...
# chestimgbbiou 0.77777, phrase_acc 0.43700, segmask_iou 0.02940, 11.60 secs
# ---- Epoch 30/200
# (1) Training stage (lr = 0.000065) ...
# loss 3.18848, y8_loss 2.38542, y8box_loss 0.83536, y8cls_loss 0.42198, y8dfl_loss 1.12809, phrase_acc 0.99219, phrcls_loss 0.02523, att_sup_loss 0.77783, segmask_iou 0.31257, 140.08 secs
# (2) Validation stage ...
# chestimgbbiou 0.95483, phrase_acc 0.99819, segmask_iou 0.25574, 22.10 secs
# ---- Epoch 31/200
# (1) Training stage (lr = 0.000042) ...
# loss 3.11495, y8_loss 2.33615, y8box_loss 0.81474, y8cls_loss 0.40713, y8dfl_loss 1.11428, phrase_acc 0.99294, phrcls_loss 0.02252, att_sup_loss 0.75629, segmask_iou 0.31611, 138.89 secs
# (2) Validation stage ...
# chestimgbbiou 0.95899, phrase_acc 0.99808, segmask_iou 0.25695, 21.82 secs
# ---- Epoch 32/200
# (1) Training stage (lr = 0.000028) ...
# loss 3.09569, y8_loss 2.32619, y8box_loss 0.81070, y8cls_loss 0.40302, y8dfl_loss 1.11248, phrase_acc 0.99250, phrcls_loss 0.02255, att_sup_loss 0.74695, segmask_iou 0.31877, 139.79 secs
# (2) Validation stage ...
# chestimgbbiou 0.96133, phrase_acc 0.99812, segmask_iou 0.26633, 20.74 secs
# ---- Epoch 33/200
# (1) Training stage (lr = 0.000018) ...
# loss 3.08283, y8_loss 2.32023, y8box_loss 0.80747, y8cls_loss 0.40138, y8dfl_loss 1.11138, phrase_acc 0.99296, phrcls_loss 0.02197, att_sup_loss 0.74063, segmask_iou 0.32025, 138.83 secs
# (2) Validation stage ...
# chestimgbbiou 0.96802, phrase_acc 0.99842, segmask_iou 0.27828, 23.82 secs
# New checkpoint saved: checkpoint_33_chestimgbbiou+phrase_acc+segmask_iou=0.7391.pt
# ---- Epoch 34/200
# (1) Training stage (lr = 0.000012) ...
# loss 3.07106, y8_loss 2.31355, y8box_loss 0.80407, y8cls_loss 0.40087, y8dfl_loss 1.10860, phrase_acc 0.99320, phrcls_loss 0.02128, att_sup_loss 0.73624, segmask_iou 0.32122, 142.66 secs
# (2) Validation stage ...
# chestimgbbiou 0.96615, phrase_acc 0.99777, segmask_iou 0.27244, 22.26 secs
# ---- Epoch 35/200
# (1) Training stage (lr = 0.000008) ...
# loss 3.04686, y8_loss 2.29456, y8box_loss 0.79643, y8cls_loss 0.39452, y8dfl_loss 1.10362, phrase_acc 0.99313, phrcls_loss 0.02110, att_sup_loss 0.73120, segmask_iou 0.32260, 137.60 secs
# (2) Validation stage ...
# chestimgbbiou 0.96661, phrase_acc 0.99712, segmask_iou 0.27635, 22.53 secs
# ---- Epoch 36/200
# (1) Training stage (lr = 0.000005) ...
# loss 3.02436, y8_loss 2.27391, y8box_loss 0.78433, y8cls_loss 0.39151, y8dfl_loss 1.09807, phrase_acc 0.99322, phrcls_loss 0.02059, att_sup_loss 0.72987, segmask_iou 0.32288, 142.35 secs
# (2) Validation stage ...
# chestimgbbiou 0.97212, phrase_acc 0.99796, segmask_iou 0.28048, 23.36 secs
# New checkpoint saved: checkpoint_36_chestimgbbiou+phrase_acc+segmask_iou=0.7410.pt
# ---- Epoch 37/200
# (1) Training stage (lr = 0.000100) ...
# loss 3.10274, y8_loss 2.35865, y8box_loss 0.82688, y8cls_loss 0.41126, y8dfl_loss 1.12050, phrase_acc 0.99342, phrcls_loss 0.02088, att_sup_loss 0.72322, segmask_iou 0.32564, 139.77 secs
# (2) Validation stage ...
# chestimgbbiou 0.90290, phrase_acc 0.90004, segmask_iou 0.16878, 17.81 secs
# ---- Epoch 38/200
# (1) Training stage (lr = 0.000065) ...
# loss 3.05903, y8_loss 2.33872, y8box_loss 0.81700, y8cls_loss 0.40698, y8dfl_loss 1.11473, phrase_acc 0.99346, phrcls_loss 0.02060, att_sup_loss 0.69971, segmask_iou 0.33736, 140.53 secs
# (2) Validation stage ...
# chestimgbbiou 0.93299, phrase_acc 0.98665, segmask_iou 0.22886, 19.96 secs
# ---- Epoch 39/200
# (1) Training stage (lr = 0.000042) ...
# loss 3.02550, y8_loss 2.31752, y8box_loss 0.80671, y8cls_loss 0.40165, y8dfl_loss 1.10916, phrase_acc 0.99295, phrcls_loss 0.02149, att_sup_loss 0.68650, segmask_iou 0.34739, 140.54 secs
# (2) Validation stage ...
# chestimgbbiou 0.96314, phrase_acc 0.99631, segmask_iou 0.30799, 20.99 secs
# New checkpoint saved: checkpoint_39_chestimgbbiou+phrase_acc+segmask_iou=0.7472.pt
# ---- Epoch 40/200
# (1) Training stage (lr = 0.000028) ...
# loss 2.98509, y8_loss 2.29117, y8box_loss 0.79482, y8cls_loss 0.39436, y8dfl_loss 1.10198, phrase_acc 0.99345, phrcls_loss 0.02008, att_sup_loss 0.67384, segmask_iou 0.35276, 142.38 secs
# (2) Validation stage ...
# chestimgbbiou 0.96633, phrase_acc 0.99688, segmask_iou 0.31501, 23.14 secs
# New checkpoint saved: checkpoint_40_chestimgbbiou+phrase_acc+segmask_iou=0.7508.pt
# ---- Epoch 41/200
# (1) Training stage (lr = 0.000018) ...
# loss 2.96901, y8_loss 2.28117, y8box_loss 0.79048, y8cls_loss 0.39019, y8dfl_loss 1.10050, phrase_acc 0.99331, phrcls_loss 0.02037, att_sup_loss 0.66747, segmask_iou 0.35603, 137.97 secs
# (2) Validation stage ...
# chestimgbbiou 0.96658, phrase_acc 0.99819, segmask_iou 0.31927, 21.28 secs
# New checkpoint saved: checkpoint_41_chestimgbbiou+phrase_acc+segmask_iou=0.7527.pt
# ---- Epoch 42/200
# (1) Training stage (lr = 0.000012) ...
# loss 2.95127, y8_loss 2.26925, y8box_loss 0.78483, y8cls_loss 0.38817, y8dfl_loss 1.09625, phrase_acc 0.99347, phrcls_loss 0.02002, att_sup_loss 0.66200, segmask_iou 0.35736, 136.96 secs
# (2) Validation stage ...
# chestimgbbiou 0.96609, phrase_acc 0.99638, segmask_iou 0.31995, 22.88 secs
# ---- Epoch 43/200
# (1) Training stage (lr = 0.000008) ...
# loss 2.93405, y8_loss 2.25795, y8box_loss 0.78041, y8cls_loss 0.38372, y8dfl_loss 1.09382, phrase_acc 0.99425, phrcls_loss 0.01882, att_sup_loss 0.65728, segmask_iou 0.35933, 142.59 secs
# (2) Validation stage ...
# chestimgbbiou 0.96907, phrase_acc 0.99781, segmask_iou 0.32167, 23.06 secs
# New checkpoint saved: checkpoint_43_chestimgbbiou+phrase_acc+segmask_iou=0.7542.pt
# ---- Epoch 44/200
# (1) Training stage (lr = 0.000005) ...
# loss 2.94887, y8_loss 2.27243, y8box_loss 0.78606, y8cls_loss 0.38841, y8dfl_loss 1.09797, phrase_acc 0.99385, phrcls_loss 0.01944, att_sup_loss 0.65700, segmask_iou 0.35980, 141.18 secs
# (2) Validation stage ...
# chestimgbbiou 0.97019, phrase_acc 0.99619, segmask_iou 0.32720, 20.73 secs
# New checkpoint saved: checkpoint_44_chestimgbbiou+phrase_acc+segmask_iou=0.7558.pt
# ---- Epoch 45/200
# (1) Training stage (lr = 0.000100) ...
# loss 3.03333, y8_loss 2.35695, y8box_loss 0.82629, y8cls_loss 0.41168, y8dfl_loss 1.11898, phrase_acc 0.99357, phrcls_loss 0.02128, att_sup_loss 0.65510, segmask_iou 0.36501, 137.79 secs
# (2) Validation stage ...
# chestimgbbiou 0.90368, phrase_acc 0.90385, segmask_iou 0.18519, 18.21 secs
# ---- Epoch 46/200
# (1) Training stage (lr = 0.000065) ...
# loss 2.99700, y8_loss 2.34652, y8box_loss 0.82189, y8cls_loss 0.40801, y8dfl_loss 1.11662, phrase_acc 0.99368, phrcls_loss 0.01988, att_sup_loss 0.63059, segmask_iou 0.37748, 136.34 secs
# (2) Validation stage ...
# chestimgbbiou 0.95526, phrase_acc 0.99735, segmask_iou 0.33423, 22.52 secs
# ---- Epoch 47/200
# (1) Training stage (lr = 0.000042) ...
# loss 2.94499, y8_loss 2.31181, y8box_loss 0.80502, y8cls_loss 0.39949, y8dfl_loss 1.10730, phrase_acc 0.99418, phrcls_loss 0.01894, att_sup_loss 0.61424, segmask_iou 0.38503, 137.10 secs
# (2) Validation stage ...
# chestimgbbiou 0.96901, phrase_acc 0.99596, segmask_iou 0.35734, 21.82 secs
# New checkpoint saved: checkpoint_47_chestimgbbiou+phrase_acc+segmask_iou=0.7657.pt
# ---- Epoch 48/200
# (1) Training stage (lr = 0.000028) ...
# loss 2.91816, y8_loss 2.29551, y8box_loss 0.79791, y8cls_loss 0.39444, y8dfl_loss 1.10316, phrase_acc 0.99378, phrcls_loss 0.01945, att_sup_loss 0.60321, segmask_iou 0.39074, 137.83 secs
# (2) Validation stage ...
# chestimgbbiou 0.96042, phrase_acc 0.99235, segmask_iou 0.35112, 22.62 secs
# ---- Epoch 49/200
# (1) Training stage (lr = 0.000018) ...
# loss 2.89094, y8_loss 2.27910, y8box_loss 0.79052, y8cls_loss 0.39015, y8dfl_loss 1.09843, phrase_acc 0.99474, phrcls_loss 0.01708, att_sup_loss 0.59476, segmask_iou 0.39388, 137.72 secs
# (2) Validation stage ...
# chestimgbbiou 0.95993, phrase_acc 0.99469, segmask_iou 0.34917, 20.58 secs
# ---- Epoch 50/200
# (1) Training stage (lr = 0.000012) ...
# loss 2.87968, y8_loss 2.27169, y8box_loss 0.78645, y8cls_loss 0.38757, y8dfl_loss 1.09767, phrase_acc 0.99451, phrcls_loss 0.01748, att_sup_loss 0.59052, segmask_iou 0.39692, 135.17 secs
# (2) Validation stage ...
# chestimgbbiou 0.95514, phrase_acc 0.99665, segmask_iou 0.34013, 21.30 secs
# ---- Epoch 51/200
# (1) Training stage (lr = 0.000008) ...
# loss 2.86905, y8_loss 2.26378, y8box_loss 0.78280, y8cls_loss 0.38547, y8dfl_loss 1.09551, phrase_acc 0.99439, phrcls_loss 0.01799, att_sup_loss 0.58729, segmask_iou 0.39794, 136.89 secs
# (2) Validation stage ...
# chestimgbbiou 0.96128, phrase_acc 0.99269, segmask_iou 0.36047, 22.05 secs
# ---- Epoch 52/200
# (1) Training stage (lr = 0.000005) ...
# loss 2.86740, y8_loss 2.26388, y8box_loss 0.78282, y8cls_loss 0.38581, y8dfl_loss 1.09525, phrase_acc 0.99463, phrcls_loss 0.01738, att_sup_loss 0.58614, segmask_iou 0.39853, 136.14 secs
# (2) Validation stage ...
# chestimgbbiou 0.97084, phrase_acc 0.99769, segmask_iou 0.37177, 22.01 secs
# New checkpoint saved: checkpoint_52_chestimgbbiou+phrase_acc+segmask_iou=0.7717.pt
# ---- Epoch 53/200
# (1) Training stage (lr = 0.000100) ...
# loss 2.96510, y8_loss 2.35811, y8box_loss 0.82771, y8cls_loss 0.41073, y8dfl_loss 1.11967, phrase_acc 0.99412, phrcls_loss 0.01927, att_sup_loss 0.58772, segmask_iou 0.40348, 138.80 secs
# (2) Validation stage ...
# chestimgbbiou 0.83188, phrase_acc 0.09400, segmask_iou 0.03289, 10.16 secs
# ---- Epoch 54/200
# (1) Training stage (lr = 0.000065) ...
# loss 2.88477, y8_loss 2.30442, y8box_loss 0.80087, y8cls_loss 0.39933, y8dfl_loss 1.10423, phrase_acc 0.99402, phrcls_loss 0.01827, att_sup_loss 0.56208, segmask_iou 0.41645, 135.51 secs
# (2) Validation stage ...
# chestimgbbiou 0.94800, phrase_acc 0.98681, segmask_iou 0.36057, 21.36 secs
# ---- Epoch 55/200
# (1) Training stage (lr = 0.000042) ...
# loss 2.82425, y8_loss 2.26642, y8box_loss 0.78480, y8cls_loss 0.38677, y8dfl_loss 1.09485, phrase_acc 0.99485, phrcls_loss 0.01632, att_sup_loss 0.54151, segmask_iou 0.42542, 135.77 secs
# (2) Validation stage ...
# chestimgbbiou 0.92678, phrase_acc 0.87758, segmask_iou 0.25654, 17.89 secs
# ---- Epoch 56/200
# (1) Training stage (lr = 0.000028) ...
# loss 2.80787, y8_loss 2.25507, y8box_loss 0.77926, y8cls_loss 0.38399, y8dfl_loss 1.09183, phrase_acc 0.99438, phrcls_loss 0.01763, att_sup_loss 0.53517, segmask_iou 0.42978, 135.86 secs
# (2) Validation stage ...
# chestimgbbiou 0.92972, phrase_acc 0.91912, segmask_iou 0.29139, 19.13 secs
# ---- Epoch 57/200
# (1) Training stage (lr = 0.000018) ...
# loss 2.77015, y8_loss 2.22978, y8box_loss 0.76837, y8cls_loss 0.37681, y8dfl_loss 1.08460, phrase_acc 0.99495, phrcls_loss 0.01566, att_sup_loss 0.52471, segmask_iou 0.43384, 137.90 secs
# (2) Validation stage ...
# chestimgbbiou 0.96676, phrase_acc 0.99327, segmask_iou 0.40650, 21.48 secs
# New checkpoint saved: checkpoint_57_chestimgbbiou+phrase_acc+segmask_iou=0.7814.pt
# ---- Epoch 58/200
# (1) Training stage (lr = 0.000012) ...
# loss 2.76046, y8_loss 2.22399, y8box_loss 0.76525, y8cls_loss 0.37452, y8dfl_loss 1.08422, phrase_acc 0.99546, phrcls_loss 0.01413, att_sup_loss 0.52234, segmask_iou 0.43626, 135.75 secs
# (2) Validation stage ...
# chestimgbbiou 0.97027, phrase_acc 0.99588, segmask_iou 0.41078, 21.98 secs
# New checkpoint saved: checkpoint_58_chestimgbbiou+phrase_acc+segmask_iou=0.7847.pt
# ---- Epoch 59/200
# (1) Training stage (lr = 0.000008) ...
# loss 2.75587, y8_loss 2.22149, y8box_loss 0.76427, y8cls_loss 0.37342, y8dfl_loss 1.08380, phrase_acc 0.99521, phrcls_loss 0.01497, att_sup_loss 0.51941, segmask_iou 0.43695, 135.29 secs
# (2) Validation stage ...
# chestimgbbiou 0.97313, phrase_acc 0.99627, segmask_iou 0.41369, 22.59 secs
# New checkpoint saved: checkpoint_59_chestimgbbiou+phrase_acc+segmask_iou=0.7865.pt
# ---- Epoch 60/200
# (1) Training stage (lr = 0.000005) ...
# loss 2.75185, y8_loss 2.21847, y8box_loss 0.76288, y8cls_loss 0.37275, y8dfl_loss 1.08283, phrase_acc 0.99521, phrcls_loss 0.01518, att_sup_loss 0.51820, segmask_iou 0.43746, 134.10 secs
# (2) Validation stage ...
# chestimgbbiou 0.97312, phrase_acc 0.99515, segmask_iou 0.41447, 22.46 secs
# ---- Epoch 61/200
# (1) Training stage (lr = 0.000100) ...
# loss 2.86357, y8_loss 2.32670, y8box_loss 0.81613, y8cls_loss 0.39959, y8dfl_loss 1.11098, phrase_acc 0.99485, phrcls_loss 0.01689, att_sup_loss 0.51998, segmask_iou 0.44204, 135.47 secs
# (2) Validation stage ...
# chestimgbbiou 0.93849, phrase_acc 0.98604, segmask_iou 0.35718, 19.44 secs
# ---- Epoch 62/200
# (1) Training stage (lr = 0.000065) ...
# loss 2.83132, y8_loss 2.30800, y8box_loss 0.80367, y8cls_loss 0.39864, y8dfl_loss 1.10569, phrase_acc 0.99407, phrcls_loss 0.01832, att_sup_loss 0.50500, segmask_iou 0.45090, 135.40 secs
# (2) Validation stage ...
# chestimgbbiou 0.95689, phrase_acc 0.99312, segmask_iou 0.40465, 21.76 secs
# ---- Epoch 63/200
# (1) Training stage (lr = 0.000042) ...
# loss 2.77964, y8_loss 2.27366, y8box_loss 0.78921, y8cls_loss 0.38834, y8dfl_loss 1.09610, phrase_acc 0.99494, phrcls_loss 0.01599, att_sup_loss 0.48999, segmask_iou 0.45725, 137.91 secs
# (2) Validation stage ...
# chestimgbbiou 0.95980, phrase_acc 0.99292, segmask_iou 0.41727, 21.97 secs
# ---- Epoch 64/200
# (1) Training stage (lr = 0.000028) ...
# loss 2.73994, y8_loss 2.24558, y8box_loss 0.77627, y8cls_loss 0.37917, y8dfl_loss 1.09014, phrase_acc 0.99550, phrcls_loss 0.01450, att_sup_loss 0.47987, segmask_iou 0.46206, 137.02 secs
# (2) Validation stage ...
# chestimgbbiou 0.95076, phrase_acc 0.99600, segmask_iou 0.39342, 20.77 secs
# ---- Epoch 65/200
# (1) Training stage (lr = 0.000018) ...
# loss 2.72997, y8_loss 2.23843, y8box_loss 0.77290, y8cls_loss 0.37755, y8dfl_loss 1.08799, phrase_acc 0.99484, phrcls_loss 0.01596, att_sup_loss 0.47558, segmask_iou 0.46417, 135.17 secs
# (2) Validation stage ...
# chestimgbbiou 0.94851, phrase_acc 0.97804, segmask_iou 0.39189, 19.98 secs
# ---- Epoch 66/200
# (1) Training stage (lr = 0.000012) ...
# loss 2.71555, y8_loss 2.22940, y8box_loss 0.76903, y8cls_loss 0.37480, y8dfl_loss 1.08558, phrase_acc 0.99484, phrcls_loss 0.01537, att_sup_loss 0.47077, segmask_iou 0.46624, 133.06 secs
# (2) Validation stage ...
# chestimgbbiou 0.95971, phrase_acc 0.99742, segmask_iou 0.42065, 21.74 secs
# ---- Epoch 67/200
# (1) Training stage (lr = 0.000008) ...
# loss 2.70661, y8_loss 2.22302, y8box_loss 0.76531, y8cls_loss 0.37368, y8dfl_loss 1.08403, phrase_acc 0.99520, phrcls_loss 0.01492, att_sup_loss 0.46867, segmask_iou 0.46743, 138.29 secs
# (2) Validation stage ...
# chestimgbbiou 0.97022, phrase_acc 0.99546, segmask_iou 0.44297, 22.05 secs
# New checkpoint saved: checkpoint_67_chestimgbbiou+phrase_acc+segmask_iou=0.7957.pt
# ---- Epoch 68/200
# (1) Training stage (lr = 0.000005) ...
# loss 2.69561, y8_loss 2.21474, y8box_loss 0.76166, y8cls_loss 0.37128, y8dfl_loss 1.08180, phrase_acc 0.99543, phrcls_loss 0.01412, att_sup_loss 0.46675, segmask_iou 0.46818, 136.53 secs
# (2) Validation stage ...
# chestimgbbiou 0.97022, phrase_acc 0.99558, segmask_iou 0.44084, 20.61 secs
# ---- Epoch 69/200
# (1) Training stage (lr = 0.000100) ...
# loss 2.80886, y8_loss 2.32005, y8box_loss 0.81299, y8cls_loss 0.39821, y8dfl_loss 1.10885, phrase_acc 0.99448, phrcls_loss 0.01686, att_sup_loss 0.47195, segmask_iou 0.47052, 133.20 secs
# (2) Validation stage ...
# chestimgbbiou 0.94431, phrase_acc 0.96215, segmask_iou 0.36306, 19.75 secs
# ---- Epoch 70/200
# (1) Training stage (lr = 0.000065) ...
# loss 2.78857, y8_loss 2.31542, y8box_loss 0.80859, y8cls_loss 0.39896, y8dfl_loss 1.10786, phrase_acc 0.99462, phrcls_loss 0.01649, att_sup_loss 0.45666, segmask_iou 0.47835, 136.66 secs
# (2) Validation stage ...
# chestimgbbiou 0.93576, phrase_acc 0.99154, segmask_iou 0.37548, 19.32 secs
# ---- Epoch 71/200
# (1) Training stage (lr = 0.000042) ...
# loss 2.70279, y8_loss 2.25164, y8box_loss 0.77866, y8cls_loss 0.38296, y8dfl_loss 1.09002, phrase_acc 0.99488, phrcls_loss 0.01497, att_sup_loss 0.43618, segmask_iou 0.48480, 138.52 secs
# (2) Validation stage ...
# chestimgbbiou 0.95557, phrase_acc 0.99219, segmask_iou 0.43785, 21.29 secs
# ---- Epoch 72/200
# (1) Training stage (lr = 0.000028) ...
# loss 2.64266, y8_loss 2.20671, y8box_loss 0.75867, y8cls_loss 0.36955, y8dfl_loss 1.07849, phrase_acc 0.99549, phrcls_loss 0.01344, att_sup_loss 0.42251, segmask_iou 0.48952, 136.69 secs
# (2) Validation stage ...
# chestimgbbiou 0.95762, phrase_acc 0.99173, segmask_iou 0.43781, 21.40 secs
# ---- Epoch 73/200
# (1) Training stage (lr = 0.000018) ...
# loss 2.61824, y8_loss 2.18907, y8box_loss 0.75023, y8cls_loss 0.36483, y8dfl_loss 1.07401, phrase_acc 0.99558, phrcls_loss 0.01347, att_sup_loss 0.41569, segmask_iou 0.49190, 139.78 secs
# (2) Validation stage ...
# chestimgbbiou 0.96346, phrase_acc 0.99838, segmask_iou 0.45427, 22.49 secs
# New checkpoint saved: checkpoint_73_chestimgbbiou+phrase_acc+segmask_iou=0.7992.pt
# ---- Epoch 74/200
# (1) Training stage (lr = 0.000012) ...
# loss 2.60775, y8_loss 2.18235, y8box_loss 0.74745, y8cls_loss 0.36229, y8dfl_loss 1.07261, phrase_acc 0.99554, phrcls_loss 0.01331, att_sup_loss 0.41209, segmask_iou 0.49281, 140.53 secs
# (2) Validation stage ...
# chestimgbbiou 0.97052, phrase_acc 0.99588, segmask_iou 0.46241, 21.84 secs
# New checkpoint saved: checkpoint_74_chestimgbbiou+phrase_acc+segmask_iou=0.8031.pt
# ---- Epoch 75/200
# (1) Training stage (lr = 0.000008) ...
# loss 2.60143, y8_loss 2.17742, y8box_loss 0.74498, y8cls_loss 0.36167, y8dfl_loss 1.07077, phrase_acc 0.99578, phrcls_loss 0.01311, att_sup_loss 0.41090, segmask_iou 0.49355, 134.87 secs
# (2) Validation stage ...
# chestimgbbiou 0.97257, phrase_acc 0.99650, segmask_iou 0.46772, 22.30 secs
# New checkpoint saved: checkpoint_75_chestimgbbiou+phrase_acc+segmask_iou=0.8055.pt
# ---- Epoch 76/200
# (1) Training stage (lr = 0.000005) ...
# loss 2.57968, y8_loss 2.16040, y8box_loss 0.73754, y8cls_loss 0.35648, y8dfl_loss 1.06638, phrase_acc 0.99566, phrcls_loss 0.01297, att_sup_loss 0.40631, segmask_iou 0.49500, 136.62 secs
# (2) Validation stage ...
# chestimgbbiou 0.97184, phrase_acc 0.99596, segmask_iou 0.46924, 21.36 secs
# New checkpoint saved: checkpoint_76_chestimgbbiou+phrase_acc+segmask_iou=0.8056.pt
# ---- Epoch 77/200
# (1) Training stage (lr = 0.000100) ...
# loss 2.70723, y8_loss 2.27607, y8box_loss 0.79317, y8cls_loss 0.38667, y8dfl_loss 1.09623, phrase_acc 0.99512, phrcls_loss 0.01444, att_sup_loss 0.41672, segmask_iou 0.49567, 137.15 secs
# (2) Validation stage ...
# chestimgbbiou 0.90102, phrase_acc 0.42708, segmask_iou 0.21198, 14.90 secs
# ---- Epoch 78/200
# (1) Training stage (lr = 0.000065) ...
# loss 2.68898, y8_loss 2.26640, y8box_loss 0.78565, y8cls_loss 0.38683, y8dfl_loss 1.09392, phrase_acc 0.99474, phrcls_loss 0.01569, att_sup_loss 0.40690, segmask_iou 0.50217, 139.07 secs
# (2) Validation stage ...
# chestimgbbiou 0.96230, phrase_acc 0.99777, segmask_iou 0.47246, 22.90 secs
# ---- Epoch 79/200
# (1) Training stage (lr = 0.000042) ...
# loss 2.65561, y8_loss 2.24587, y8box_loss 0.77792, y8cls_loss 0.37894, y8dfl_loss 1.08901, phrase_acc 0.99500, phrcls_loss 0.01513, att_sup_loss 0.39462, segmask_iou 0.50646, 139.66 secs
# (2) Validation stage ...
# chestimgbbiou 0.95139, phrase_acc 0.99665, segmask_iou 0.43250, 22.09 secs
# ---- Epoch 80/200
# (1) Training stage (lr = 0.000028) ...
# loss 2.60138, y8_loss 2.20464, y8box_loss 0.75858, y8cls_loss 0.36811, y8dfl_loss 1.07795, phrase_acc 0.99570, phrcls_loss 0.01277, att_sup_loss 0.38397, segmask_iou 0.51069, 137.45 secs
# (2) Validation stage ...
# chestimgbbiou 0.96821, phrase_acc 0.99658, segmask_iou 0.47640, 22.62 secs
# New checkpoint saved: checkpoint_80_chestimgbbiou+phrase_acc+segmask_iou=0.8077.pt
# ---- Epoch 81/200
# (1) Training stage (lr = 0.000018) ...
# loss 2.60171, y8_loss 2.20469, y8box_loss 0.75803, y8cls_loss 0.36803, y8dfl_loss 1.07863, phrase_acc 0.99535, phrcls_loss 0.01414, att_sup_loss 0.38288, segmask_iou 0.51094, 138.72 secs
# (2) Validation stage ...
# chestimgbbiou 0.95988, phrase_acc 0.99069, segmask_iou 0.46838, 22.12 secs
# ---- Epoch 82/200
# (1) Training stage (lr = 0.000012) ...
# loss 2.58346, y8_loss 2.19298, y8box_loss 0.75299, y8cls_loss 0.36439, y8dfl_loss 1.07561, phrase_acc 0.99575, phrcls_loss 0.01294, att_sup_loss 0.37754, segmask_iou 0.51301, 137.12 secs
# (2) Validation stage ...
# chestimgbbiou 0.97164, phrase_acc 0.99508, segmask_iou 0.48352, 22.35 secs
# New checkpoint saved: checkpoint_82_chestimgbbiou+phrase_acc+segmask_iou=0.8105.pt
# ---- Epoch 83/200
# (1) Training stage (lr = 0.000008) ...
# loss 2.58011, y8_loss 2.19081, y8box_loss 0.75234, y8cls_loss 0.36366, y8dfl_loss 1.07481, phrase_acc 0.99543, phrcls_loss 0.01316, att_sup_loss 0.37615, segmask_iou 0.51364, 139.32 secs
# (2) Validation stage ...
# chestimgbbiou 0.97138, phrase_acc 0.99538, segmask_iou 0.48496, 22.67 secs
# New checkpoint saved: checkpoint_83_chestimgbbiou+phrase_acc+segmask_iou=0.8110.pt
# ---- Epoch 84/200
# (1) Training stage (lr = 0.000005) ...
# loss 2.56758, y8_loss 2.18014, y8box_loss 0.74731, y8cls_loss 0.36102, y8dfl_loss 1.07181, phrase_acc 0.99570, phrcls_loss 0.01281, att_sup_loss 0.37463, segmask_iou 0.51393, 139.64 secs
# (2) Validation stage ...
# chestimgbbiou 0.96993, phrase_acc 0.99169, segmask_iou 0.48513, 20.44 secs
# ---- Epoch 85/200
# (1) Training stage (lr = 0.000100) ...
# loss 2.67198, y8_loss 2.27444, y8box_loss 0.79159, y8cls_loss 0.38560, y8dfl_loss 1.09725, phrase_acc 0.99562, phrcls_loss 0.01380, att_sup_loss 0.38375, segmask_iou 0.51432, 136.61 secs
# (2) Validation stage ...
# chestimgbbiou 0.88192, phrase_acc 0.31038, segmask_iou 0.16558, 14.29 secs
# ---- Epoch 86/200
# (1) Training stage (lr = 0.000065) ...
# loss 2.67494, y8_loss 2.28209, y8box_loss 0.79425, y8cls_loss 0.38911, y8dfl_loss 1.09873, phrase_acc 0.99476, phrcls_loss 0.01534, att_sup_loss 0.37751, segmask_iou 0.51789, 137.33 secs
# (2) Validation stage ...
# chestimgbbiou 0.92041, phrase_acc 0.98373, segmask_iou 0.33615, 18.72 secs
# ---- Epoch 87/200
# (1) Training stage (lr = 0.000042) ...
# loss 2.60863, y8_loss 2.23180, y8box_loss 0.77184, y8cls_loss 0.37520, y8dfl_loss 1.08477, phrase_acc 0.99596, phrcls_loss 0.01256, att_sup_loss 0.36427, segmask_iou 0.52323, 138.30 secs
# (2) Validation stage ...
# chestimgbbiou 0.95570, phrase_acc 0.99362, segmask_iou 0.47339, 22.11 secs
# ---- Epoch 88/200
# (1) Training stage (lr = 0.000028) ...
# loss 2.59078, y8_loss 2.21834, y8box_loss 0.76573, y8cls_loss 0.37011, y8dfl_loss 1.08249, phrase_acc 0.99522, phrcls_loss 0.01368, att_sup_loss 0.35876, segmask_iou 0.52547, 139.81 secs
# (2) Validation stage ...
# chestimgbbiou 0.91452, phrase_acc 0.85150, segmask_iou 0.31070, 19.35 secs
# ---- Epoch 89/200
# (1) Training stage (lr = 0.000018) ...
# loss 2.52665, y8_loss 2.16561, y8box_loss 0.73979, y8cls_loss 0.35818, y8dfl_loss 1.06764, phrase_acc 0.99611, phrcls_loss 0.01185, att_sup_loss 0.34920, segmask_iou 0.52853, 143.71 secs
# (2) Validation stage ...
# chestimgbbiou 0.97275, phrase_acc 0.99581, segmask_iou 0.50402, 23.85 secs
# New checkpoint saved: checkpoint_89_chestimgbbiou+phrase_acc+segmask_iou=0.8180.pt
# ---- Epoch 90/200
# (1) Training stage (lr = 0.000012) ...
# loss 2.51259, y8_loss 2.15424, y8box_loss 0.73496, y8cls_loss 0.35434, y8dfl_loss 1.06494, phrase_acc 0.99574, phrcls_loss 0.01276, att_sup_loss 0.34559, segmask_iou 0.52923, 142.20 secs
# (2) Validation stage ...
# chestimgbbiou 0.95847, phrase_acc 0.99335, segmask_iou 0.47875, 22.83 secs
# ---- Epoch 91/200
# (1) Training stage (lr = 0.000008) ...
# loss 2.49999, y8_loss 2.14353, y8box_loss 0.72991, y8cls_loss 0.35224, y8dfl_loss 1.06138, phrase_acc 0.99562, phrcls_loss 0.01269, att_sup_loss 0.34377, segmask_iou 0.53024, 142.07 secs
# (2) Validation stage ...
# chestimgbbiou 0.97056, phrase_acc 0.99365, segmask_iou 0.50340, 22.83 secs
# ---- Epoch 92/200
# (1) Training stage (lr = 0.000005) ...
# loss 2.48158, y8_loss 2.12977, y8box_loss 0.72402, y8cls_loss 0.34816, y8dfl_loss 1.05759, phrase_acc 0.99584, phrcls_loss 0.01208, att_sup_loss 0.33972, segmask_iou 0.53128, 142.08 secs
# (2) Validation stage ...
# chestimgbbiou 0.97250, phrase_acc 0.99565, segmask_iou 0.50759, 24.22 secs
# New checkpoint saved: checkpoint_92_chestimgbbiou+phrase_acc+segmask_iou=0.8191.pt
# ---- Epoch 93/200
# (1) Training stage (lr = 0.000100) ...
# loss 2.59379, y8_loss 2.22907, y8box_loss 0.77278, y8cls_loss 0.37238, y8dfl_loss 1.08390, phrase_acc 0.99590, phrcls_loss 0.01274, att_sup_loss 0.35199, segmask_iou 0.53101, 138.77 secs
# (2) Validation stage ...
# chestimgbbiou 0.92911, phrase_acc 0.60773, segmask_iou 0.25115, 16.40 secs
# ---- Epoch 94/200
# (1) Training stage (lr = 0.000065) ...
# loss 2.60128, y8_loss 2.23963, y8box_loss 0.77586, y8cls_loss 0.37715, y8dfl_loss 1.08662, phrase_acc 0.99514, phrcls_loss 0.01405, att_sup_loss 0.34760, segmask_iou 0.53480, 139.31 secs
# (2) Validation stage ...
# chestimgbbiou 0.91734, phrase_acc 0.92912, segmask_iou 0.34803, 19.67 secs
# ---- Epoch 95/200
# (1) Training stage (lr = 0.000042) ...
# loss 2.55015, y8_loss 2.20066, y8box_loss 0.75821, y8cls_loss 0.36582, y8dfl_loss 1.07663, phrase_acc 0.99565, phrcls_loss 0.01328, att_sup_loss 0.33622, segmask_iou 0.53882, 140.07 secs
# (2) Validation stage ...
# chestimgbbiou 0.96335, phrase_acc 0.99377, segmask_iou 0.50074, 23.72 secs
# ---- Epoch 96/200
# (1) Training stage (lr = 0.000028) ...
# loss 2.51509, y8_loss 2.17416, y8box_loss 0.74632, y8cls_loss 0.35740, y8dfl_loss 1.07044, phrase_acc 0.99604, phrcls_loss 0.01174, att_sup_loss 0.32919, segmask_iou 0.54112, 138.99 secs
# (2) Validation stage ...
# chestimgbbiou 0.96429, phrase_acc 0.99058, segmask_iou 0.50565, 21.78 secs
# ---- Epoch 97/200
# (1) Training stage (lr = 0.000018) ...
# loss 2.49914, y8_loss 2.16141, y8box_loss 0.74024, y8cls_loss 0.35489, y8dfl_loss 1.06628, phrase_acc 0.99594, phrcls_loss 0.01176, att_sup_loss 0.32597, segmask_iou 0.54194, 143.36 secs
# (2) Validation stage ...
# chestimgbbiou 0.96795, phrase_acc 0.99369, segmask_iou 0.51395, 23.53 secs
# New checkpoint saved: checkpoint_97_chestimgbbiou+phrase_acc+segmask_iou=0.8196.pt
# ---- Epoch 98/200
# (1) Training stage (lr = 0.000012) ...
# loss 2.49023, y8_loss 2.15432, y8box_loss 0.73659, y8cls_loss 0.35303, y8dfl_loss 1.06470, phrase_acc 0.99614, phrcls_loss 0.01118, att_sup_loss 0.32473, segmask_iou 0.54296, 138.91 secs
# (2) Validation stage ...
# chestimgbbiou 0.96716, phrase_acc 0.99112, segmask_iou 0.50838, 21.75 secs
# ---- Epoch 99/200
# (1) Training stage (lr = 0.000008) ...
# loss 2.47510, y8_loss 2.14459, y8box_loss 0.73324, y8cls_loss 0.34930, y8dfl_loss 1.06205, phrase_acc 0.99648, phrcls_loss 0.01048, att_sup_loss 0.32003, segmask_iou 0.54364, 136.26 secs
# (2) Validation stage ...
# chestimgbbiou 0.96983, phrase_acc 0.99419, segmask_iou 0.51401, 22.61 secs
# New checkpoint saved: checkpoint_99_chestimgbbiou+phrase_acc+segmask_iou=0.8204.pt
# ---- Epoch 100/200
# (1) Training stage (lr = 0.000005) ...
# loss 2.47512, y8_loss 2.14260, y8box_loss 0.73129, y8cls_loss 0.34915, y8dfl_loss 1.06216, phrase_acc 0.99591, phrcls_loss 0.01192, att_sup_loss 0.32059, segmask_iou 0.54409, 136.56 secs
# (2) Validation stage ...
# chestimgbbiou 0.97050, phrase_acc 0.99342, segmask_iou 0.51778, 22.92 secs
# New checkpoint saved: checkpoint_100_chestimgbbiou+phrase_acc+segmask_iou=0.8215.pt
# ---- Epoch 101/200
# (1) Training stage (lr = 0.000100) ...
# loss 2.61025, y8_loss 2.25700, y8box_loss 0.78485, y8cls_loss 0.37986, y8dfl_loss 1.09228, phrase_acc 0.99529, phrcls_loss 0.01430, att_sup_loss 0.33896, segmask_iou 0.54137, 137.28 secs
# (2) Validation stage ...
# chestimgbbiou 0.90129, phrase_acc 0.45935, segmask_iou 0.13709, 13.36 secs
# ---- Epoch 102/200
# (1) Training stage (lr = 0.000065) ...
# loss 2.59445, y8_loss 2.24989, y8box_loss 0.78195, y8cls_loss 0.37755, y8dfl_loss 1.09039, phrase_acc 0.99526, phrcls_loss 0.01409, att_sup_loss 0.33047, segmask_iou 0.54511, 141.01 secs
# (2) Validation stage ...
# chestimgbbiou 0.93831, phrase_acc 0.88935, segmask_iou 0.40482, 22.58 secs
# ---- Epoch 103/200
# (1) Training stage (lr = 0.000042) ...
# loss 2.54465, y8_loss 2.21120, y8box_loss 0.76333, y8cls_loss 0.36859, y8dfl_loss 1.07928, phrase_acc 0.99568, phrcls_loss 0.01225, att_sup_loss 0.32120, segmask_iou 0.54843, 141.23 secs
# (2) Validation stage ...
# chestimgbbiou 0.91736, phrase_acc 0.88815, segmask_iou 0.33198, 17.98 secs
# ---- Epoch 104/200
# (1) Training stage (lr = 0.000028) ...
# loss 2.50527, y8_loss 2.18021, y8box_loss 0.74927, y8cls_loss 0.35994, y8dfl_loss 1.07101, phrase_acc 0.99597, phrcls_loss 0.01190, att_sup_loss 0.31315, segmask_iou 0.55031, 140.49 secs
# (2) Validation stage ...
# chestimgbbiou 0.96740, phrase_acc 0.99369, segmask_iou 0.52496, 24.91 secs
# New checkpoint saved: checkpoint_104_chestimgbbiou+phrase_acc+segmask_iou=0.8231.pt
# ---- Epoch 105/200
# (1) Training stage (lr = 0.000018) ...
# loss 2.50129, y8_loss 2.17827, y8box_loss 0.74828, y8cls_loss 0.35817, y8dfl_loss 1.07182, phrase_acc 0.99606, phrcls_loss 0.01119, att_sup_loss 0.31184, segmask_iou 0.55087, 141.08 secs
# (2) Validation stage ...
# chestimgbbiou 0.96577, phrase_acc 0.99488, segmask_iou 0.52116, 23.67 secs
# ---- Epoch 106/200
# (1) Training stage (lr = 0.000012) ...
# loss 2.45636, y8_loss 2.13892, y8box_loss 0.72997, y8cls_loss 0.34913, y8dfl_loss 1.05982, phrase_acc 0.99613, phrcls_loss 0.01106, att_sup_loss 0.30638, segmask_iou 0.55259, 141.30 secs
# (2) Validation stage ...
# chestimgbbiou 0.97074, phrase_acc 0.99458, segmask_iou 0.52608, 23.49 secs
# New checkpoint saved: checkpoint_106_chestimgbbiou+phrase_acc+segmask_iou=0.8249.pt
# ---- Epoch 107/200
# (1) Training stage (lr = 0.000008) ...
# loss 2.41659, y8_loss 2.10429, y8box_loss 0.71233, y8cls_loss 0.34149, y8dfl_loss 1.05047, phrase_acc 0.99639, phrcls_loss 0.01031, att_sup_loss 0.30199, segmask_iou 0.55379, 143.18 secs
# (2) Validation stage ...
# chestimgbbiou 0.96684, phrase_acc 0.99477, segmask_iou 0.51836, 22.96 secs
# ---- Epoch 108/200
# (1) Training stage (lr = 0.000005) ...
# loss 2.39996, y8_loss 2.09198, y8box_loss 0.70712, y8cls_loss 0.33809, y8dfl_loss 1.04677, phrase_acc 0.99654, phrcls_loss 0.01034, att_sup_loss 0.29764, segmask_iou 0.55477, 137.85 secs
# (2) Validation stage ...
# chestimgbbiou 0.96958, phrase_acc 0.99588, segmask_iou 0.52470, 23.86 secs
# ---- Epoch 109/200
# (1) Training stage (lr = 0.000100) ...
# loss 2.51967, y8_loss 2.19459, y8box_loss 0.75799, y8cls_loss 0.36238, y8dfl_loss 1.07421, phrase_acc 0.99586, phrcls_loss 0.01227, att_sup_loss 0.31280, segmask_iou 0.55253, 140.95 secs
# (2) Validation stage ...
# chestimgbbiou 0.87941, phrase_acc 0.37981, segmask_iou 0.18333, 14.65 secs
# ---- Epoch 110/200
# (1) Training stage (lr = 0.000065) ...
# loss 2.53155, y8_loss 2.20835, y8box_loss 0.76273, y8cls_loss 0.36746, y8dfl_loss 1.07816, phrase_acc 0.99577, phrcls_loss 0.01218, att_sup_loss 0.31102, segmask_iou 0.55366, 141.51 secs
# (2) Validation stage ...
# chestimgbbiou 0.90743, phrase_acc 0.61196, segmask_iou 0.27366, 17.65 secs
# ---- Epoch 111/200
# (1) Training stage (lr = 0.000042) ...
# loss 2.50032, y8_loss 2.18301, y8box_loss 0.75104, y8cls_loss 0.36015, y8dfl_loss 1.07182, phrase_acc 0.99567, phrcls_loss 0.01253, att_sup_loss 0.30478, segmask_iou 0.55538, 140.29 secs
# (2) Validation stage ...
# chestimgbbiou 0.96030, phrase_acc 0.99769, segmask_iou 0.52058, 21.47 secs
# ---- Epoch 112/200
# (1) Training stage (lr = 0.000028) ...
# loss 2.46409, y8_loss 2.15409, y8box_loss 0.73743, y8cls_loss 0.35215, y8dfl_loss 1.06451, phrase_acc 0.99591, phrcls_loss 0.01144, att_sup_loss 0.29855, segmask_iou 0.55722, 142.16 secs
# (2) Validation stage ...
# chestimgbbiou 0.94427, phrase_acc 0.99635, segmask_iou 0.48287, 22.10 secs
# ---- Epoch 113/200
# (1) Training stage (lr = 0.000018) ...
# loss 2.44798, y8_loss 2.14220, y8box_loss 0.73145, y8cls_loss 0.34881, y8dfl_loss 1.06194, phrase_acc 0.99623, phrcls_loss 0.01117, att_sup_loss 0.29461, segmask_iou 0.55791, 141.62 secs
# (2) Validation stage ...
# chestimgbbiou 0.96836, phrase_acc 0.99269, segmask_iou 0.53259, 23.53 secs
# New checkpoint saved: checkpoint_113_chestimgbbiou+phrase_acc+segmask_iou=0.8258.pt
# ---- Epoch 114/200
# (1) Training stage (lr = 0.000012) ...
# loss 2.42841, y8_loss 2.12546, y8box_loss 0.72367, y8cls_loss 0.34440, y8dfl_loss 1.05740, phrase_acc 0.99613, phrcls_loss 0.01046, att_sup_loss 0.29248, segmask_iou 0.55830, 141.14 secs
# (2) Validation stage ...
# chestimgbbiou 0.96283, phrase_acc 0.99612, segmask_iou 0.51535, 23.54 secs
# ---- Epoch 115/200
# (1) Training stage (lr = 0.000008) ...
# loss 2.41682, y8_loss 2.11734, y8box_loss 0.72036, y8cls_loss 0.34196, y8dfl_loss 1.05502, phrase_acc 0.99641, phrcls_loss 0.01033, att_sup_loss 0.28915, segmask_iou 0.55986, 140.55 secs
# (2) Validation stage ...
# chestimgbbiou 0.96488, phrase_acc 0.99385, segmask_iou 0.52135, 22.99 secs
# ---- Epoch 116/200
# (1) Training stage (lr = 0.000005) ...
# loss 2.39243, y8_loss 2.09766, y8box_loss 0.71255, y8cls_loss 0.33619, y8dfl_loss 1.04892, phrase_acc 0.99654, phrcls_loss 0.01008, att_sup_loss 0.28469, segmask_iou 0.56080, 140.89 secs
# (2) Validation stage ...
# chestimgbbiou 0.97129, phrase_acc 0.99392, segmask_iou 0.53662, 22.55 secs
# New checkpoint saved: checkpoint_116_chestimgbbiou+phrase_acc+segmask_iou=0.8284.pt
# ---- Epoch 117/200
# (1) Training stage (lr = 0.000100) ...
# loss 2.52275, y8_loss 2.20655, y8box_loss 0.76405, y8cls_loss 0.36437, y8dfl_loss 1.07812, phrase_acc 0.99586, phrcls_loss 0.01221, att_sup_loss 0.30399, segmask_iou 0.55771, 140.91 secs
# (2) Validation stage ...
# chestimgbbiou 0.90704, phrase_acc 0.80085, segmask_iou 0.32223, 18.70 secs
# ---- Epoch 118/200
# (1) Training stage (lr = 0.000065) ...
# loss 2.52718, y8_loss 2.21251, y8box_loss 0.76499, y8cls_loss 0.36815, y8dfl_loss 1.07937, phrase_acc 0.99578, phrcls_loss 0.01238, att_sup_loss 0.30230, segmask_iou 0.55871, 140.38 secs
# (2) Validation stage ...
# chestimgbbiou 0.94744, phrase_acc 0.99042, segmask_iou 0.48468, 21.85 secs
# ---- Epoch 119/200
# (1) Training stage (lr = 0.000042) ...
# loss 2.48813, y8_loss 2.18308, y8box_loss 0.75173, y8cls_loss 0.35961, y8dfl_loss 1.07174, phrase_acc 0.99580, phrcls_loss 0.01183, att_sup_loss 0.29322, segmask_iou 0.56087, 141.05 secs
# (2) Validation stage ...
# chestimgbbiou 0.95702, phrase_acc 0.99846, segmask_iou 0.52399, 22.85 secs
# ---- Epoch 120/200
# (1) Training stage (lr = 0.000028) ...
# loss 2.46168, y8_loss 2.16007, y8box_loss 0.74143, y8cls_loss 0.35285, y8dfl_loss 1.06579, phrase_acc 0.99561, phrcls_loss 0.01227, att_sup_loss 0.28934, segmask_iou 0.56196, 139.86 secs
# (2) Validation stage ...
# chestimgbbiou 0.94773, phrase_acc 0.98746, segmask_iou 0.48267, 20.78 secs
# ---- Epoch 121/200
# (1) Training stage (lr = 0.000018) ...
# loss 2.45543, y8_loss 2.15636, y8box_loss 0.73939, y8cls_loss 0.35097, y8dfl_loss 1.06599, phrase_acc 0.99616, phrcls_loss 0.01101, att_sup_loss 0.28807, segmask_iou 0.56216, 140.96 secs
# (2) Validation stage ...
# chestimgbbiou 0.96739, phrase_acc 0.99519, segmask_iou 0.53762, 23.28 secs
# ---- Epoch 122/200
# (1) Training stage (lr = 0.000012) ...
# loss 2.41968, y8_loss 2.12649, y8box_loss 0.72551, y8cls_loss 0.34303, y8dfl_loss 1.05795, phrase_acc 0.99636, phrcls_loss 0.01075, att_sup_loss 0.28244, segmask_iou 0.56409, 141.49 secs
# (2) Validation stage ...
# chestimgbbiou 0.97151, phrase_acc 0.99623, segmask_iou 0.54174, 18.27 secs
# New checkpoint saved: checkpoint_122_chestimgbbiou+phrase_acc+segmask_iou=0.8309.pt
# ---- Epoch 123/200
# (1) Training stage (lr = 0.000008) ...
# loss 2.41840, y8_loss 2.12505, y8box_loss 0.72509, y8cls_loss 0.34322, y8dfl_loss 1.05674, phrase_acc 0.99618, phrcls_loss 0.01079, att_sup_loss 0.28256, segmask_iou 0.56386, 142.15 secs
# (2) Validation stage ...
# chestimgbbiou 0.97239, phrase_acc 0.99554, segmask_iou 0.54485, 24.69 secs
# New checkpoint saved: checkpoint_123_chestimgbbiou+phrase_acc+segmask_iou=0.8318.pt
# ---- Epoch 124/200
# (1) Training stage (lr = 0.000005) ...
# loss 2.35681, y8_loss 2.07387, y8box_loss 0.69956, y8cls_loss 0.33118, y8dfl_loss 1.04313, phrase_acc 0.99652, phrcls_loss 0.00974, att_sup_loss 0.27320, segmask_iou 0.56641, 144.88 secs
# (2) Validation stage ...
# chestimgbbiou 0.97143, phrase_acc 0.99335, segmask_iou 0.54101, 23.78 secs
# ---- Epoch 125/200
# (1) Training stage (lr = 0.000100) ...
# loss 2.48119, y8_loss 2.17713, y8box_loss 0.74997, y8cls_loss 0.35821, y8dfl_loss 1.06895, phrase_acc 0.99611, phrcls_loss 0.01116, att_sup_loss 0.29289, segmask_iou 0.56266, 145.49 secs
# (2) Validation stage ...
# chestimgbbiou 0.79471, phrase_acc 0.00635, segmask_iou 0.04382, 11.59 secs
# ---- Epoch 126/200
# (1) Training stage (lr = 0.000065) ...
# loss 2.46704, y8_loss 2.16938, y8box_loss 0.74499, y8cls_loss 0.35743, y8dfl_loss 1.06697, phrase_acc 0.99605, phrcls_loss 0.01123, att_sup_loss 0.28643, segmask_iou 0.56451, 136.25 secs
# (2) Validation stage ...
# chestimgbbiou 0.93342, phrase_acc 0.98662, segmask_iou 0.43718, 22.10 secs
# ---- Epoch 127/200
# (1) Training stage (lr = 0.000042) ...
# ^C

# %%
# !python ../train_phrase_grounding.py \
--pretrained_checkpoint_folder_paths \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20231122_083436_chst-img-anat_PhraseGrounder(yolov8l,128,256)" \
--epochs 80 \
--batches_per_epoch 250 \
--max_images_per_batch 100 \
--max_phrases_per_batch 2000 \
--max_phrases_per_image 20 \
--val_batch_size_factor 3 \
--image_size 416 416 \
--image_local_feat_size 512 \
--num_regions 169 \
--regions_width 13 \
--regions_height 13 \
--yolov8_model_name_or_path "yolov8l.pt" \
--yolov8_model_alias "yolov8l" \
--phrase_embedding_size 128 \
--qkv_size 256 \
--phrase_classifier_hidden_size 256 \
--num_train_workers 3 \
--num_val_workers 3 \
--iters_to_accumulate 10 \
--optimizer_name "adamw" \
--scheduler "exp-warmup+decay+cyclicdecay" \
--lr 1e-6 \
--warmup_decay_and_cyclic_decay_args "1e-6,3,7e-5,8,2e-6,7e-5,8,2e-6" \
--use_chest_imagenome_for_train \
--use_chest_imagenome_gold_for_test \
--chest_imagenome_bbox_phrase_embeddings_filepath \
"/mnt/workspace/pamessina/medvqa-workspace/cache/chest_imagenome/bbox_phrase_embeddings.pkl" \
--attention_supervision_loss_weight 3.0 \
--phrase_classifier_loss_weight 1.0 \
--use_amp \
--save
# Out:
# script's arguments:
#    epochs: 80
#    batches_per_epoch: 250
#    max_images_per_batch: 100
#    max_phrases_per_batch: 2000
#    max_phrases_per_image: 20
#    val_batch_size_factor: 3
#    checkpoint_folder: None
#    pretrained_checkpoint_folder_path: None
#    pretrained_checkpoint_folder_paths: ['/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20231122_083436_chst-img-anat_PhraseGrounder(yolov8l,128,256)']
#    freeze_image_encoder: False
#    raw_image_encoding: yolov8
#    num_regions: 169
#    image_local_feat_size: 512
#    image_encoder_pretrained_weights_path: None
#    yolov8_model_name_or_path: yolov8l.pt
#    yolov8_model_alias: yolov8l
#    yolov8_use_one_detector_per_dataset: False
#    phrase_embedding_size: 128
#    regions_width: 13
#    regions_height: 13
#    qkv_size: 256
#    phrase_classifier_hidden_size: 256
#    optimizer_name: adamw
#    lr: 1e-06
#    scheduler: exp-warmup+decay+cyclicdecay
#    lr_decay: 0.76
#    lr_decay_patience: 2
#    warmup_and_decay_args: None
#    warmup_and_cosine_args: None
#    warmup_decay_and_cyclic_decay_args: 1e-6,3,7e-5,8,2e-6,7e-5,8,2e-6
#    iters_to_accumulate: 10
#    override_lr: False
#    max_grad_norm: None
#    attention_supervision_loss_weight: 3.0
#    phrase_classifier_loss_weight: 1.0
#    num_train_workers: 3
#    num_val_workers: 3
#    device: GPU
#    use_amp: True
#    image_size: [416, 416]
#    dicom_id_to_pos_neg_facts_filepath: None
#    mscxr_phrase2embedding_filepath: None
#    chest_imagenome_bbox_phrase_embeddings_filepath: /mnt/workspace/pamessina/medvqa-workspace/cache/chest_imagenome/bbox_phrase_embeddings.pkl
#    exclude_noisy_images: False
#    mimiccxr_facts_weight: 1.0
#    chest_imagenome_anatlocs_weight: 1.0
#    img_aug_mode: None
#    pos_area_prior: 0.4
#    neg_area_prior: 0.0
#    use_mimiccxr_facts_for_train: False
#    use_mscxr_for_test: False
#    use_chest_imagenome_for_train: True
#    use_chest_imagenome_gold_for_test: True
#    save: True
# ----- Training model from scratch ------
# source_image_size_mode: medium_512
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Creating instance of PhraseGrounder ...
# WARNING: Unused kwargs: {'pretrained_checkpoint_folder_path': None, 'pretrained_checkpoint_folder_paths': ['/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20231122_083436_chst-img-anat_PhraseGrounder(yolov8l,128,256)']}
# MultiPurposeVisualModule()
#   Initializing raw_image_encoder: yolov8
#   num_bbox_classes: 36
# Overriding model.yaml nc=80 with nc=36
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.Conv                  [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.Conv                  [64, 128, 3, 2]
#   2                  -1  3    279808  ultralytics.nn.modules.C2f                   [128, 128, 3, True]
#   3                  -1  1    295424  ultralytics.nn.modules.Conv                  [128, 256, 3, 2]
#   4                  -1  6   2101248  ultralytics.nn.modules.C2f                   [256, 256, 6, True]
#   5                  -1  1   1180672  ultralytics.nn.modules.Conv                  [256, 512, 3, 2]
#   6                  -1  6   8396800  ultralytics.nn.modules.C2f                   [512, 512, 6, True]
#   7                  -1  1   2360320  ultralytics.nn.modules.Conv                  [512, 512, 3, 2]
#   8                  -1  3   4461568  ultralytics.nn.modules.C2f                   [512, 512, 3, True]
#   9                  -1  1    656896  ultralytics.nn.modules.SPPF                  [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.Concat                [1]
#  12                  -1  3   4723712  ultralytics.nn.modules.C2f                   [1024, 512, 3]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.Concat                [1]
#  15                  -1  3   1247744  ultralytics.nn.modules.C2f                   [768, 256, 3]
#  16                  -1  1    590336  ultralytics.nn.modules.Conv                  [256, 256, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.Concat                [1]
#  18                  -1  3   4592640  ultralytics.nn.modules.C2f                   [768, 512, 3]
#  19                  -1  1   2360320  ultralytics.nn.modules.Conv                  [512, 512, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.Concat                [1]
#  21                  -1  3   4723712  ultralytics.nn.modules.C2f                   [1024, 512, 3]
#  22        [15, 18, 21]  1   5610556  ultralytics.nn.modules.Detect                [36, [256, 512, 512]]
# Model summary: 365 layers, 43657596 parameters, 43657580 gradients, 165.6 GFLOPs
#
# Transferred 589/595 items from pretrained weights
#   self.global_feat_size = 1024
#   self.local_feat_size = 512
#   Initializing auxiliary tasks
# --------------------------------------------------
# 3) Defining optimizer ...
# create_optimizer(): name = adamw
# --------------------------------------------------
# 4) Defining scheduler ...
# Using exp-warmup+decay+cyclicdecay scheduler: 1e-6,3,7e-5,8,2e-6,7e-5,8,2e-6
# 1e-06 3 7e-05 8 2e-06 7e-05 8 2e-06
# self.steps_to_restart = 8
# self.steps = -1
# self.initial_lr = 7e-05
# --------------------------------------------------
# 5) Creating trainer and validator engines ...
# GradientAccumulator.__init__(): num_accumulation_steps = 10, max_grad_norm = None
# --------------------------------------------------
# 6) Creating MIMIC-CXR Phrase Grounding Trainer ...
# get_image_transform()
#   Using bounding box aware transforms
#     Returning default transform (no augmentation)
# get_image_transform()
#   Using bounding box aware transforms
#     Returning default transform (no augmentation)
# len(forbidden_train_dicom_ids) = 1000
# Preparing Chest Imagenome dataset and dataloader for training...
# bbox_phrase_embeddings.shape = (36, 128)
# len(bbox_phrases) = 36
# 	 right lung
# 	 right upper lung zone
# 	 right mid lung zone
# 	 right lower lung zone
# 	 right hilar structures
# 	 right apical zone
# 	 right costophrenic angle
# 	 right cardiophrenic angle
# 	 right hemidiaphragm
# 	 left lung
# 	 left upper lung zone
# 	 left mid lung zone
# 	 left lower lung zone
# 	 left hilar structures
# 	 left apical zone
# 	 left costophrenic angle
# 	 left hemidiaphragm
# 	 trachea
# 	 spine
# 	 right clavicle
# 	 left clavicle
# 	 aortic arch
# 	 mediastinum
# 	 upper mediastinum
# 	 svc
# 	 cardiac silhouette
# 	 left cardiac silhouette
# 	 right cardiac silhouette
# 	 cavoatrial junction
# 	 right atrium
# 	 descending aorta
# 	 carina
# 	 left upper abdomen
# 	 right upper abdomen
# 	 abdomen
# 	 left cardiophrenic angle
# Using image size mode: medium_512
# Loading precomputed bbox_coords_and_presence_and_mask from /mnt/workspace/pamessina/medvqa-workspace/cache/mimiccxr/bbox_coords_and_presence_and_mask(13,13,243310).pkl...
# 227835it [00:01, 155497.04it/s]
# Total number of images: 242310
# Preparing Chest Imagenome dataset and dataloader for testing...
# bbox_phrase_embeddings.shape = (26, 128)
# len(bbox_phrases) = 26
# 	 right lung
# 	 right upper lung zone
# 	 right mid lung zone
# 	 right lower lung zone
# 	 right hilar structures
# 	 right apical zone
# 	 right costophrenic angle
# 	 right hemidiaphragm
# 	 left lung
# 	 left upper lung zone
# 	 left mid lung zone
# 	 left lower lung zone
# 	 left hilar structures
# 	 left apical zone
# 	 left costophrenic angle
# 	 left hemidiaphragm
# 	 trachea
# 	 right clavicle
# 	 left clavicle
# 	 aortic arch
# 	 upper mediastinum
# 	 svc
# 	 cardiac silhouette
# 	 cavoatrial junction
# 	 right atrium
# 	 carina
# Using image size mode: medium_512
# 227835it [00:03, 59883.09it/s]
# Total number of images: 1000
# --------------------------------------------------
# 7) Creating dataloaders ...
# len(_train_dataloaders) = 1
# len(_val_dataloaders) = 1
# _train_weights = [1.0]
# merged_dataset_name = chst-img-anat
# --------------------------------------------------
# 8) Attaching metrics, losses, timer and events to engines ...
# --------------------------------------------------
# 9) Defining learning rate scheduler handler ...
# --------------------------------------------------
# 10) Defining learning rate scheduler handler ...
# --------------------------------------------------
# 11) Defining checkpoint folder path ...
# checkpoint_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20231122_141052_chst-img-anat_PhraseGrounder(yolov8l,128,256)
# metadata saved to /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20231122_141052_chst-img-anat_PhraseGrounder(yolov8l,128,256)/metadata.json
# --------------------------------------------------
# 12) Loading pretrained weights ...
# checkpoint_names = ['checkpoint_123_chestimgbbiou+phrase_acc+segmask_iou=0.8318.pt']
# pretrained_checkpoint_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20231122_083436_chst-img-anat_PhraseGrounder(yolov8l,128,256)/checkpoint_123_chestimgbbiou+phrase_acc+segmask_iou=0.8318.pt
# Checkpoint successfully loaded!
# --------------------------------------------------
# 13) Defining log_metrics_handler ...
# MetricsLogger :: we'll be logging to /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20231122_141052_chst-img-anat_PhraseGrounder(yolov8l,128,256)/metrics_logs.csv
# --------------------------------------------------
# 14) Running trainer engine ...
# ---- Epoch 1/80
# (1) Training stage (lr = 0.000001) ...
# loss 2.34455, y8_loss 2.06307, y8box_loss 0.69349, y8cls_loss 0.33062, y8dfl_loss 1.03895, phrase_acc 0.99699, phrcls_loss 0.00881, att_sup_loss 0.27267, segmask_iou 0.56579, 144.78 secs
# (2) Validation stage ...
# chestimgbbiou 0.97271, phrase_acc 0.99500, segmask_iou 0.54239, 22.15 secs
# New checkpoint saved: checkpoint_1_chestimgbbiou+phrase_acc+segmask_iou=0.8312.pt
# ---- Epoch 2/80
# (1) Training stage (lr = 0.000004) ...
# loss 2.33970, y8_loss 2.05905, y8box_loss 0.69272, y8cls_loss 0.32830, y8dfl_loss 1.03803, phrase_acc 0.99674, phrcls_loss 0.00912, att_sup_loss 0.27152, segmask_iou 0.56657, 135.29 secs
# (2) Validation stage ...
# chestimgbbiou 0.97089, phrase_acc 0.99515, segmask_iou 0.54310, 21.96 secs
# ---- Epoch 3/80
# (1) Training stage (lr = 0.000017) ...
# loss 2.35131, y8_loss 2.06904, y8box_loss 0.69738, y8cls_loss 0.33115, y8dfl_loss 1.04052, phrase_acc 0.99668, phrcls_loss 0.00949, att_sup_loss 0.27278, segmask_iou 0.56653, 135.63 secs
# (2) Validation stage ...
# chestimgbbiou 0.95858, phrase_acc 0.99781, segmask_iou 0.51796, 22.74 secs
# ---- Epoch 4/80
# (1) Training stage (lr = 0.000070) ...
# loss 2.42722, y8_loss 2.13402, y8box_loss 0.72903, y8cls_loss 0.34764, y8dfl_loss 1.05736, phrase_acc 0.99614, phrcls_loss 0.01102, att_sup_loss 0.28218, segmask_iou 0.56525, 136.54 secs
# (2) Validation stage ...
# chestimgbbiou 0.95330, phrase_acc 0.99712, segmask_iou 0.50858, 22.16 secs
# ---- Epoch 5/80
# (1) Training stage (lr = 0.000045) ...
# loss 2.43629, y8_loss 2.14417, y8box_loss 0.73333, y8cls_loss 0.34955, y8dfl_loss 1.06130, phrase_acc 0.99625, phrcls_loss 0.01074, att_sup_loss 0.28138, segmask_iou 0.56581, 136.22 secs
# (2) Validation stage ...
# chestimgbbiou 0.95416, phrase_acc 0.99196, segmask_iou 0.50414, 22.82 secs
# ---- Epoch 6/80
# (1) Training stage (lr = 0.000029) ...
# loss 2.40153, y8_loss 2.11552, y8box_loss 0.71993, y8cls_loss 0.34152, y8dfl_loss 1.05407, phrase_acc 0.99628, phrcls_loss 0.01111, att_sup_loss 0.27490, segmask_iou 0.56753, 135.96 secs
# (2) Validation stage ...
# chestimgbbiou 0.95644, phrase_acc 0.99592, segmask_iou 0.51291, 22.91 secs
# ---- Epoch 7/80
# (1) Training stage (lr = 0.000018) ...
# loss 2.36759, y8_loss 2.09032, y8box_loss 0.70882, y8cls_loss 0.33381, y8dfl_loss 1.04769, phrase_acc 0.99657, phrcls_loss 0.00975, att_sup_loss 0.26752, segmask_iou 0.56957, 141.14 secs
# (2) Validation stage ...
# chestimgbbiou 0.95346, phrase_acc 0.99342, segmask_iou 0.50713, 23.92 secs
# ---- Epoch 8/80
# (1) Training stage (lr = 0.000012) ...
# loss 2.35416, y8_loss 2.07975, y8box_loss 0.70427, y8cls_loss 0.33145, y8dfl_loss 1.04403, phrase_acc 0.99687, phrcls_loss 0.00863, att_sup_loss 0.26578, segmask_iou 0.56969, 141.33 secs
# (2) Validation stage ...
# chestimgbbiou 0.96967, phrase_acc 0.99192, segmask_iou 0.54269, 24.49 secs
# ---- Epoch 9/80
# (1) Training stage (lr = 0.000008) ...
# loss 2.34480, y8_loss 2.07167, y8box_loss 0.70006, y8cls_loss 0.32926, y8dfl_loss 1.04235, phrase_acc 0.99683, phrcls_loss 0.00904, att_sup_loss 0.26409, segmask_iou 0.57022, 139.86 secs
# (2) Validation stage ...
# chestimgbbiou 0.97023, phrase_acc 0.99604, segmask_iou 0.54105, 24.00 secs
# ---- Epoch 10/80
# (1) Training stage (lr = 0.000005) ...
# loss 2.34019, y8_loss 2.06680, y8box_loss 0.69754, y8cls_loss 0.32816, y8dfl_loss 1.04110, phrase_acc 0.99690, phrcls_loss 0.00897, att_sup_loss 0.26441, segmask_iou 0.57031, 139.79 secs
# (2) Validation stage ...
# chestimgbbiou 0.97286, phrase_acc 0.99588, segmask_iou 0.54976, 22.29 secs
# New checkpoint saved: checkpoint_10_chestimgbbiou+phrase_acc+segmask_iou=0.8339.pt
# ---- Epoch 11/80
# (1) Training stage (lr = 0.000003) ...
# loss 2.35562, y8_loss 2.08026, y8box_loss 0.70434, y8cls_loss 0.33125, y8dfl_loss 1.04467, phrase_acc 0.99684, phrcls_loss 0.00931, att_sup_loss 0.26606, segmask_iou 0.57008, 137.86 secs
# (2) Validation stage ...
# chestimgbbiou 0.97314, phrase_acc 0.99585, segmask_iou 0.54973, 23.07 secs
# New checkpoint saved: checkpoint_11_chestimgbbiou+phrase_acc+segmask_iou=0.8340.pt
# ---- Epoch 12/80
# (1) Training stage (lr = 0.000002) ...
# loss 2.33751, y8_loss 2.06502, y8box_loss 0.69684, y8cls_loss 0.32748, y8dfl_loss 1.04069, phrase_acc 0.99693, phrcls_loss 0.00877, att_sup_loss 0.26371, segmask_iou 0.57066, 138.55 secs
# (2) Validation stage ...
# chestimgbbiou 0.97335, phrase_acc 0.99542, segmask_iou 0.54924, 21.28 secs
# ---- Epoch 13/80
# (1) Training stage (lr = 0.000070) ...
# loss 2.41209, y8_loss 2.12896, y8box_loss 0.72860, y8cls_loss 0.34377, y8dfl_loss 1.05659, phrase_acc 0.99659, phrcls_loss 0.00965, att_sup_loss 0.27348, segmask_iou 0.56946, 145.43 secs
# (2) Validation stage ...
# chestimgbbiou 0.86319, phrase_acc 0.16962, segmask_iou 0.09467, 13.46 secs
# ---- Epoch 14/80
# (1) Training stage (lr = 0.000042) ...
# loss 2.41211, y8_loss 2.12999, y8box_loss 0.72878, y8cls_loss 0.34450, y8dfl_loss 1.05672, phrase_acc 0.99646, phrcls_loss 0.01035, att_sup_loss 0.27176, segmask_iou 0.56957, 144.58 secs
# (2) Validation stage ...
# chestimgbbiou 0.91378, phrase_acc 0.90796, segmask_iou 0.39880, 21.93 secs
# ---- Epoch 15/80
# (1) Training stage (lr = 0.000025) ...
# loss 2.37337, y8_loss 2.09897, y8box_loss 0.71339, y8cls_loss 0.33606, y8dfl_loss 1.04952, phrase_acc 0.99644, phrcls_loss 0.00981, att_sup_loss 0.26459, segmask_iou 0.57151, 144.44 secs
# (2) Validation stage ...
# chestimgbbiou 0.96158, phrase_acc 0.99750, segmask_iou 0.53436, 24.06 secs
# ---- Epoch 16/80
# (1) Training stage (lr = 0.000015) ...
# loss 2.35846, y8_loss 2.08631, y8box_loss 0.70715, y8cls_loss 0.33274, y8dfl_loss 1.04642, phrase_acc 0.99649, phrcls_loss 0.01043, att_sup_loss 0.26172, segmask_iou 0.57204, 142.05 secs
# (2) Validation stage ...
# chestimgbbiou 0.95956, phrase_acc 0.99627, segmask_iou 0.51980, 24.70 secs
# ---- Epoch 17/80
# (1) Training stage (lr = 0.000009) ...
# loss 2.35472, y8_loss 2.08419, y8box_loss 0.70667, y8cls_loss 0.33200, y8dfl_loss 1.04553, phrase_acc 0.99696, phrcls_loss 0.00874, att_sup_loss 0.26179, segmask_iou 0.57165, 142.97 secs
# (2) Validation stage ...
# chestimgbbiou 0.97021, phrase_acc 0.99627, segmask_iou 0.55036, 23.17 secs
# ---- Epoch 18/80
# (1) Training stage (lr = 0.000006) ...
# loss 2.32512, y8_loss 2.05825, y8box_loss 0.69324, y8cls_loss 0.32662, y8dfl_loss 1.03839, phrase_acc 0.99676, phrcls_loss 0.00884, att_sup_loss 0.25803, segmask_iou 0.57294, 143.91 secs
# (2) Validation stage ...
# chestimgbbiou 0.97001, phrase_acc 0.99262, segmask_iou 0.54652, 23.01 secs
# ---- Epoch 19/80
# (1) Training stage (lr = 0.000003) ...
# loss 2.28307, y8_loss 2.02276, y8box_loss 0.67550, y8cls_loss 0.31856, y8dfl_loss 1.02870, phrase_acc 0.99709, phrcls_loss 0.00859, att_sup_loss 0.25172, segmask_iou 0.57422, 142.09 secs
# (2) Validation stage ...
# chestimgbbiou 0.97210, phrase_acc 0.99477, segmask_iou 0.54789, 23.17 secs
# ---- Epoch 20/80
# (1) Training stage (lr = 0.000002) ...
# loss 2.28141, y8_loss 2.02323, y8box_loss 0.67588, y8cls_loss 0.31812, y8dfl_loss 1.02922, phrase_acc 0.99756, phrcls_loss 0.00728, att_sup_loss 0.25089, segmask_iou 0.57470, 141.50 secs
# (2) Validation stage ...
# chestimgbbiou 0.97308, phrase_acc 0.99573, segmask_iou 0.54965, 22.88 secs
# New checkpoint saved: checkpoint_20_chestimgbbiou+phrase_acc+segmask_iou=0.8342.pt
# ---- Epoch 21/80
# (1) Training stage (lr = 0.000070) ...
# loss 2.36016, y8_loss 2.08744, y8box_loss 0.70765, y8cls_loss 0.33451, y8dfl_loss 1.04529, phrase_acc 0.99649, phrcls_loss 0.00963, att_sup_loss 0.26310, segmask_iou 0.57260, 145.79 secs
# (2) Validation stage ...
# chestimgbbiou 0.87867, phrase_acc 0.18446, segmask_iou 0.11810, 14.67 secs
# ---- Epoch 22/80
# (1) Training stage (lr = 0.000042) ...
# loss 2.37076, y8_loss 2.09824, y8box_loss 0.71293, y8cls_loss 0.33672, y8dfl_loss 1.04859, phrase_acc 0.99693, phrcls_loss 0.00900, att_sup_loss 0.26352, segmask_iou 0.57243, 143.03 secs
# (2) Validation stage ...
# chestimgbbiou 0.94841, phrase_acc 0.99715, segmask_iou 0.49834, 23.21 secs
# ---- Epoch 23/80
# (1) Training stage (lr = 0.000025) ...
# loss 2.34838, y8_loss 2.08059, y8box_loss 0.70475, y8cls_loss 0.33142, y8dfl_loss 1.04442, phrase_acc 0.99676, phrcls_loss 0.00924, att_sup_loss 0.25855, segmask_iou 0.57350, 143.69 secs
# (2) Validation stage ...
# chestimgbbiou 0.95330, phrase_acc 0.98488, segmask_iou 0.51190, 23.55 secs
# ---- Epoch 24/80
# (1) Training stage (lr = 0.000015) ...
# loss 2.31996, y8_loss 2.05720, y8box_loss 0.69350, y8cls_loss 0.32583, y8dfl_loss 1.03787, phrase_acc 0.99674, phrcls_loss 0.00902, att_sup_loss 0.25374, segmask_iou 0.57458, 145.02 secs
# (2) Validation stage ...
# chestimgbbiou 0.96913, phrase_acc 0.99342, segmask_iou 0.54487, 17.58 secs
# ---- Epoch 25/80
# (1) Training stage (lr = 0.000009) ...
# loss 2.31216, y8_loss 2.05187, y8box_loss 0.69100, y8cls_loss 0.32372, y8dfl_loss 1.03715, phrase_acc 0.99706, phrcls_loss 0.00820, att_sup_loss 0.25209, segmask_iou 0.57457, 140.09 secs
# (2) Validation stage ...
# chestimgbbiou 0.97126, phrase_acc 0.99515, segmask_iou 0.54978, 22.21 secs
# ---- Epoch 26/80
# (1) Training stage (lr = 0.000006) ...
# loss 2.29712, y8_loss 2.03966, y8box_loss 0.68594, y8cls_loss 0.32026, y8dfl_loss 1.03345, phrase_acc 0.99721, phrcls_loss 0.00797, att_sup_loss 0.24949, segmask_iou 0.57561, 144.28 secs
# (2) Validation stage ...
# chestimgbbiou 0.97115, phrase_acc 0.99415, segmask_iou 0.54607, 25.03 secs
# ---- Epoch 27/80
# (1) Training stage (lr = 0.000003) ...
# loss 2.29363, y8_loss 2.03599, y8box_loss 0.68414, y8cls_loss 0.31930, y8dfl_loss 1.03255, phrase_acc 0.99707, phrcls_loss 0.00836, att_sup_loss 0.24928, segmask_iou 0.57547, 144.43 secs
# (2) Validation stage ...
# chestimgbbiou 0.97106, phrase_acc 0.99627, segmask_iou 0.55201, 24.30 secs
# New checkpoint saved: checkpoint_27_chestimgbbiou+phrase_acc+segmask_iou=0.8344.pt
# ---- Epoch 28/80
# (1) Training stage (lr = 0.000002) ...
# loss 2.29265, y8_loss 2.03620, y8box_loss 0.68378, y8cls_loss 0.31932, y8dfl_loss 1.03309, phrase_acc 0.99723, phrcls_loss 0.00811, att_sup_loss 0.24835, segmask_iou 0.57565, 141.06 secs
# (2) Validation stage ...
# chestimgbbiou 0.97318, phrase_acc 0.99592, segmask_iou 0.55204, 21.40 secs
# New checkpoint saved: checkpoint_28_chestimgbbiou+phrase_acc+segmask_iou=0.8350.pt
# ---- Epoch 29/80
# (1) Training stage (lr = 0.000070) ...
# loss 2.37230, y8_loss 2.10229, y8box_loss 0.71783, y8cls_loss 0.33651, y8dfl_loss 1.04795, phrase_acc 0.99689, phrcls_loss 0.00900, att_sup_loss 0.26100, segmask_iou 0.57304, 139.15 secs
# (2) Validation stage ...
# chestimgbbiou 0.91903, phrase_acc 0.95327, segmask_iou 0.41698, 20.81 secs
# ---- Epoch 30/80
# (1) Training stage (lr = 0.000042) ...
# loss 2.37175, y8_loss 2.10332, y8box_loss 0.71637, y8cls_loss 0.33701, y8dfl_loss 1.04995, phrase_acc 0.99672, phrcls_loss 0.00992, att_sup_loss 0.25851, segmask_iou 0.57465, 140.32 secs
# (2) Validation stage ...
# chestimgbbiou 0.95539, phrase_acc 0.99773, segmask_iou 0.52790, 23.33 secs
# ---- Epoch 31/80
# (1) Training stage (lr = 0.000025) ...
# loss 2.33587, y8_loss 2.07449, y8box_loss 0.70329, y8cls_loss 0.32886, y8dfl_loss 1.04234, phrase_acc 0.99715, phrcls_loss 0.00824, att_sup_loss 0.25313, segmask_iou 0.57495, 143.29 secs
# (2) Validation stage ...
# chestimgbbiou 0.96253, phrase_acc 0.99419, segmask_iou 0.53075, 22.15 secs
# ---- Epoch 32/80
# (1) Training stage (lr = 0.000015) ...
# loss 2.31915, y8_loss 2.06157, y8box_loss 0.69736, y8cls_loss 0.32539, y8dfl_loss 1.03883, phrase_acc 0.99707, phrcls_loss 0.00845, att_sup_loss 0.24913, segmask_iou 0.57585, 143.76 secs
# (2) Validation stage ...
# chestimgbbiou 0.96881, phrase_acc 0.99723, segmask_iou 0.54644, 23.10 secs
# ---- Epoch 33/80
# (1) Training stage (lr = 0.000009) ...
# loss 2.31489, y8_loss 2.05841, y8box_loss 0.69539, y8cls_loss 0.32398, y8dfl_loss 1.03905, phrase_acc 0.99720, phrcls_loss 0.00834, att_sup_loss 0.24814, segmask_iou 0.57595, 143.63 secs
# (2) Validation stage ...
# chestimgbbiou 0.96919, phrase_acc 0.99223, segmask_iou 0.54436, 24.05 secs
# ---- Epoch 34/80
# (1) Training stage (lr = 0.000006) ...
# loss 2.30634, y8_loss 2.05101, y8box_loss 0.69155, y8cls_loss 0.32228, y8dfl_loss 1.03718, phrase_acc 0.99713, phrcls_loss 0.00828, att_sup_loss 0.24705, segmask_iou 0.57619, 139.43 secs
# (2) Validation stage ...
# chestimgbbiou 0.97156, phrase_acc 0.99600, segmask_iou 0.55210, 22.41 secs
# ---- Epoch 35/80
# (1) Training stage (lr = 0.000003) ...
# loss 2.29212, y8_loss 2.03923, y8box_loss 0.68618, y8cls_loss 0.31944, y8dfl_loss 1.03361, phrase_acc 0.99717, phrcls_loss 0.00811, att_sup_loss 0.24478, segmask_iou 0.57672, 144.97 secs
# (2) Validation stage ...
# chestimgbbiou 0.97322, phrase_acc 0.99569, segmask_iou 0.55351, 24.51 secs
# New checkpoint saved: checkpoint_35_chestimgbbiou+phrase_acc+segmask_iou=0.8354.pt
# ---- Epoch 36/80
# (1) Training stage (lr = 0.000002) ...
# loss 2.24786, y8_loss 2.00071, y8box_loss 0.66594, y8cls_loss 0.31222, y8dfl_loss 1.02254, phrase_acc 0.99741, phrcls_loss 0.00738, att_sup_loss 0.23977, segmask_iou 0.57780, 143.81 secs
# (2) Validation stage ...
# chestimgbbiou 0.97294, phrase_acc 0.99577, segmask_iou 0.55111, 24.79 secs
# ---- Epoch 37/80
# (1) Training stage (lr = 0.000070) ...
# loss 2.32264, y8_loss 2.06364, y8box_loss 0.69785, y8cls_loss 0.32686, y8dfl_loss 1.03894, phrase_acc 0.99719, phrcls_loss 0.00797, att_sup_loss 0.25103, segmask_iou 0.57563, 144.65 secs
# (2) Validation stage ...
# chestimgbbiou 0.95461, phrase_acc 0.99062, segmask_iou 0.51471, 21.29 secs
# ---- Epoch 38/80
# (1) Training stage (lr = 0.000042) ...
# loss 2.32759, y8_loss 2.06860, y8box_loss 0.70045, y8cls_loss 0.32915, y8dfl_loss 1.03899, phrase_acc 0.99700, phrcls_loss 0.00850, att_sup_loss 0.25049, segmask_iou 0.57582, 140.43 secs
# (2) Validation stage ...
# chestimgbbiou 0.91998, phrase_acc 0.88650, segmask_iou 0.37528, 19.34 secs
# ---- Epoch 39/80
# (1) Training stage (lr = 0.000025) ...
# loss 2.30272, y8_loss 2.04866, y8box_loss 0.69050, y8cls_loss 0.32321, y8dfl_loss 1.03496, phrase_acc 0.99723, phrcls_loss 0.00796, att_sup_loss 0.24610, segmask_iou 0.57623, 143.24 secs
# (2) Validation stage ...
# chestimgbbiou 0.95477, phrase_acc 0.99658, segmask_iou 0.51260, 16.80 secs
# ---- Epoch 40/80
# (1) Training stage (lr = 0.000015) ...
# loss 2.28164, y8_loss 2.03050, y8box_loss 0.68171, y8cls_loss 0.31819, y8dfl_loss 1.03060, phrase_acc 0.99697, phrcls_loss 0.00850, att_sup_loss 0.24264, segmask_iou 0.57700, 142.72 secs
# (2) Validation stage ...
# chestimgbbiou 0.95743, phrase_acc 0.99700, segmask_iou 0.51931, 22.19 secs
# ---- Epoch 41/80
# (1) Training stage (lr = 0.000009) ...
# loss 2.26205, y8_loss 2.01575, y8box_loss 0.67481, y8cls_loss 0.31366, y8dfl_loss 1.02728, phrase_acc 0.99735, phrcls_loss 0.00749, att_sup_loss 0.23881, segmask_iou 0.57836, 144.49 secs
# (2) Validation stage ...
# chestimgbbiou 0.96940, phrase_acc 0.99731, segmask_iou 0.55189, 24.81 secs
# ---- Epoch 42/80
# (1) Training stage (lr = 0.000006) ...
# loss 2.26256, y8_loss 2.01580, y8box_loss 0.67484, y8cls_loss 0.31453, y8dfl_loss 1.02643, phrase_acc 0.99740, phrcls_loss 0.00757, att_sup_loss 0.23919, segmask_iou 0.57768, 144.71 secs
# (2) Validation stage ...
# chestimgbbiou 0.97306, phrase_acc 0.99581, segmask_iou 0.55173, 24.98 secs
# ---- Epoch 43/80
# (1) Training stage (lr = 0.000003) ...
# loss 2.26039, y8_loss 2.01448, y8box_loss 0.67379, y8cls_loss 0.31344, y8dfl_loss 1.02725, phrase_acc 0.99759, phrcls_loss 0.00733, att_sup_loss 0.23858, segmask_iou 0.57804, 144.74 secs
# (2) Validation stage ...
# chestimgbbiou 0.96988, phrase_acc 0.99288, segmask_iou 0.54599, 23.69 secs
# ---- Epoch 44/80
# (1) Training stage (lr = 0.000002) ...
# loss 2.25605, y8_loss 2.01052, y8box_loss 0.67219, y8cls_loss 0.31227, y8dfl_loss 1.02606, phrase_acc 0.99743, phrcls_loss 0.00738, att_sup_loss 0.23815, segmask_iou 0.57823, 144.62 secs
# (2) Validation stage ...
# chestimgbbiou 0.97288, phrase_acc 0.99635, segmask_iou 0.55195, 22.76 secs
# ---- Epoch 45/80
# (1) Training stage (lr = 0.000070) ...
# loss 2.33903, y8_loss 2.07973, y8box_loss 0.70659, y8cls_loss 0.32990, y8dfl_loss 1.04324, phrase_acc 0.99707, phrcls_loss 0.00830, att_sup_loss 0.25100, segmask_iou 0.57622, 144.14 secs
# (2) Validation stage ...
# chestimgbbiou 0.92234, phrase_acc 0.97119, segmask_iou 0.42646, 21.75 secs
# ---- Epoch 46/80
# (1) Training stage (lr = 0.000042) ...
# loss 2.33847, y8_loss 2.07990, y8box_loss 0.70502, y8cls_loss 0.33151, y8dfl_loss 1.04337, phrase_acc 0.99673, phrcls_loss 0.00941, att_sup_loss 0.24916, segmask_iou 0.57589, 146.28 secs
# (2) Validation stage ...
# chestimgbbiou 0.95119, phrase_acc 0.99354, segmask_iou 0.50277, 24.48 secs
# ---- Epoch 47/80
# (1) Training stage (lr = 0.000025) ...
# loss 2.31278, y8_loss 2.05979, y8box_loss 0.69656, y8cls_loss 0.32419, y8dfl_loss 1.03904, phrase_acc 0.99718, phrcls_loss 0.00820, att_sup_loss 0.24479, segmask_iou 0.57726, 147.92 secs
# (2) Validation stage ...
# chestimgbbiou 0.93046, phrase_acc 0.94981, segmask_iou 0.43818, 21.74 secs
# ---- Epoch 48/80
# (1) Training stage (lr = 0.000015) ...
# loss 2.28203, y8_loss 2.03537, y8box_loss 0.68547, y8cls_loss 0.31777, y8dfl_loss 1.03212, phrase_acc 0.99718, phrcls_loss 0.00835, att_sup_loss 0.23831, segmask_iou 0.57855, 143.36 secs
# (2) Validation stage ...
# chestimgbbiou 0.96404, phrase_acc 0.99831, segmask_iou 0.54772, 25.07 secs
# ---- Epoch 49/80
# (1) Training stage (lr = 0.000009) ...
# loss 2.28696, y8_loss 2.03864, y8box_loss 0.68610, y8cls_loss 0.31950, y8dfl_loss 1.03305, phrase_acc 0.99695, phrcls_loss 0.00876, att_sup_loss 0.23956, segmask_iou 0.57759, 144.05 secs
# (2) Validation stage ...
# chestimgbbiou 0.97081, phrase_acc 0.99588, segmask_iou 0.55135, 24.33 secs
# ---- Epoch 50/80
# (1) Training stage (lr = 0.000006) ...
# loss 2.27124, y8_loss 2.02547, y8box_loss 0.67983, y8cls_loss 0.31552, y8dfl_loss 1.03012, phrase_acc 0.99712, phrcls_loss 0.00783, att_sup_loss 0.23795, segmask_iou 0.57903, 143.67 secs
# (2) Validation stage ...
# chestimgbbiou 0.97317, phrase_acc 0.99565, segmask_iou 0.55161, 22.72 secs
# ---- Epoch 51/80
# (1) Training stage (lr = 0.000003) ...
# loss 2.25627, y8_loss 2.01406, y8box_loss 0.67479, y8cls_loss 0.31301, y8dfl_loss 1.02626, phrase_acc 0.99742, phrcls_loss 0.00756, att_sup_loss 0.23465, segmask_iou 0.57934, 143.36 secs
# (2) Validation stage ...
# chestimgbbiou 0.97288, phrase_acc 0.99550, segmask_iou 0.55149, 24.93 secs
# ---- Epoch 52/80
# (1) Training stage (lr = 0.000002) ...
# loss 2.25503, y8_loss 2.01386, y8box_loss 0.67498, y8cls_loss 0.31237, y8dfl_loss 1.02651, phrase_acc 0.99744, phrcls_loss 0.00737, att_sup_loss 0.23380, segmask_iou 0.57969, 148.08 secs
# (2) Validation stage ...
# chestimgbbiou 0.97322, phrase_acc 0.99504, segmask_iou 0.55325, 25.27 secs
# ---- Epoch 53/80
# (1) Training stage (lr = 0.000070) ...
# loss 2.32223, y8_loss 2.06902, y8box_loss 0.70222, y8cls_loss 0.32677, y8dfl_loss 1.04003, phrase_acc 0.99711, phrcls_loss 0.00856, att_sup_loss 0.24465, segmask_iou 0.57753, 148.13 secs
# (2) Validation stage ...
# chestimgbbiou 0.93797, phrase_acc 0.99231, segmask_iou 0.47206, 23.60 secs
# ---- Epoch 54/80
# (1) Training stage (lr = 0.000042) ...
# loss 2.28496, y8_loss 2.03683, y8box_loss 0.68467, y8cls_loss 0.32072, y8dfl_loss 1.03144, phrase_acc 0.99701, phrcls_loss 0.00844, att_sup_loss 0.23969, segmask_iou 0.57887, 143.85 secs
# (2) Validation stage ...
# chestimgbbiou 0.93723, phrase_acc 0.97246, segmask_iou 0.45959, 23.46 secs
# ---- Epoch 55/80
# (1) Training stage (lr = 0.000025) ...
# loss 2.25741, y8_loss 2.01569, y8box_loss 0.67478, y8cls_loss 0.31490, y8dfl_loss 1.02601, phrase_acc 0.99729, phrcls_loss 0.00755, att_sup_loss 0.23417, segmask_iou 0.58008, 144.22 secs
# (2) Validation stage ...
# chestimgbbiou 0.93303, phrase_acc 0.98015, segmask_iou 0.45572, 22.76 secs
# ---- Epoch 56/80
# (1) Training stage (lr = 0.000015) ...
# loss 2.23689, y8_loss 1.99756, y8box_loss 0.66628, y8cls_loss 0.31006, y8dfl_loss 1.02122, phrase_acc 0.99730, phrcls_loss 0.00762, att_sup_loss 0.23171, segmask_iou 0.58042, 141.69 secs
# (2) Validation stage ...
# chestimgbbiou 0.96581, phrase_acc 0.99850, segmask_iou 0.54978, 22.78 secs
# ---- Epoch 57/80
# (1) Training stage (lr = 0.000009) ...
# loss 2.22388, y8_loss 1.98877, y8box_loss 0.66225, y8cls_loss 0.30708, y8dfl_loss 1.01943, phrase_acc 0.99773, phrcls_loss 0.00672, att_sup_loss 0.22839, segmask_iou 0.58088, 141.82 secs
# (2) Validation stage ...
# chestimgbbiou 0.96919, phrase_acc 0.99281, segmask_iou 0.54515, 24.68 secs
# ---- Epoch 58/80
# (1) Training stage (lr = 0.000006) ...
# loss 2.22695, y8_loss 1.99007, y8box_loss 0.66253, y8cls_loss 0.30771, y8dfl_loss 1.01984, phrase_acc 0.99772, phrcls_loss 0.00691, att_sup_loss 0.22997, segmask_iou 0.57992, 144.93 secs
# (2) Validation stage ...
# chestimgbbiou 0.97141, phrase_acc 0.99596, segmask_iou 0.55395, 22.42 secs
# ---- Epoch 59/80
# (1) Training stage (lr = 0.000003) ...
# loss 2.22003, y8_loss 1.98449, y8box_loss 0.65981, y8cls_loss 0.30676, y8dfl_loss 1.01792, phrase_acc 0.99756, phrcls_loss 0.00671, att_sup_loss 0.22883, segmask_iou 0.58040, 142.46 secs
# (2) Validation stage ...
# chestimgbbiou 0.97137, phrase_acc 0.99550, segmask_iou 0.54880, 23.48 secs
# ---- Epoch 60/80
# (1) Training stage (lr = 0.000002) ...
# loss 2.21526, y8_loss 1.97994, y8box_loss 0.65730, y8cls_loss 0.30565, y8dfl_loss 1.01699, phrase_acc 0.99755, phrcls_loss 0.00696, att_sup_loss 0.22836, segmask_iou 0.58026, 141.33 secs
# (2) Validation stage ...
# chestimgbbiou 0.97261, phrase_acc 0.99565, segmask_iou 0.55291, 22.59 secs
# ---- Epoch 61/80
# (1) Training stage (lr = 0.000070) ...
# loss 2.29580, y8_loss 2.04717, y8box_loss 0.69208, y8cls_loss 0.32209, y8dfl_loss 1.03299, phrase_acc 0.99730, phrcls_loss 0.00780, att_sup_loss 0.24083, segmask_iou 0.57846, 142.21 secs
# (2) Validation stage ...
# chestimgbbiou 0.93127, phrase_acc 0.90358, segmask_iou 0.41257, 21.45 secs
# ---- Epoch 62/80
# (1) Training stage (lr = 0.000042) ...
# loss 2.30247, y8_loss 2.05465, y8box_loss 0.69422, y8cls_loss 0.32439, y8dfl_loss 1.03604, phrase_acc 0.99719, phrcls_loss 0.00802, att_sup_loss 0.23981, segmask_iou 0.57860, 142.30 secs
# (2) Validation stage ...
# chestimgbbiou 0.93996, phrase_acc 0.98362, segmask_iou 0.47826, 22.86 secs
# ---- Epoch 63/80
# (1) Training stage (lr = 0.000025) ...
# loss 2.27989, y8_loss 2.03703, y8box_loss 0.68562, y8cls_loss 0.31925, y8dfl_loss 1.03216, phrase_acc 0.99742, phrcls_loss 0.00715, att_sup_loss 0.23572, segmask_iou 0.57975, 142.69 secs
# (2) Validation stage ...
# chestimgbbiou 0.95978, phrase_acc 0.99673, segmask_iou 0.52327, 22.98 secs
# ---- Epoch 64/80
# (1) Training stage (lr = 0.000015) ...
# loss 2.25277, y8_loss 2.01436, y8box_loss 0.67558, y8cls_loss 0.31303, y8dfl_loss 1.02574, phrase_acc 0.99748, phrcls_loss 0.00716, att_sup_loss 0.23126, segmask_iou 0.58030, 143.02 secs
# (2) Validation stage ...
# chestimgbbiou 0.96307, phrase_acc 0.99262, segmask_iou 0.53757, 24.85 secs
# ---- Epoch 65/80
# (1) Training stage (lr = 0.000009) ...
# loss 2.23643, y8_loss 1.99991, y8box_loss 0.66761, y8cls_loss 0.30955, y8dfl_loss 1.02275, phrase_acc 0.99735, phrcls_loss 0.00748, att_sup_loss 0.22905, segmask_iou 0.58089, 145.09 secs
# (2) Validation stage ...
# chestimgbbiou 0.97115, phrase_acc 0.99627, segmask_iou 0.54747, 23.41 secs
# ---- Epoch 66/80
# (1) Training stage (lr = 0.000006) ...
# loss 2.22693, y8_loss 1.99217, y8box_loss 0.66434, y8cls_loss 0.30750, y8dfl_loss 1.02032, phrase_acc 0.99738, phrcls_loss 0.00757, att_sup_loss 0.22719, segmask_iou 0.58078, 145.42 secs
# (2) Validation stage ...
# chestimgbbiou 0.96998, phrase_acc 0.99631, segmask_iou 0.55296, 24.52 secs
# ---- Epoch 67/80
# (1) Training stage (lr = 0.000003) ...
# loss 2.22444, y8_loss 1.98980, y8box_loss 0.66347, y8cls_loss 0.30683, y8dfl_loss 1.01949, phrase_acc 0.99726, phrcls_loss 0.00758, att_sup_loss 0.22706, segmask_iou 0.58096, 141.93 secs
# (2) Validation stage ...
# chestimgbbiou 0.96752, phrase_acc 0.99688, segmask_iou 0.54075, 24.50 secs
# ---- Epoch 68/80
# (1) Training stage (lr = 0.000002) ...
# loss 2.21672, y8_loss 1.98257, y8box_loss 0.65884, y8cls_loss 0.30539, y8dfl_loss 1.01834, phrase_acc 0.99748, phrcls_loss 0.00716, att_sup_loss 0.22698, segmask_iou 0.58106, 141.72 secs
# (2) Validation stage ...
# chestimgbbiou 0.97245, phrase_acc 0.99565, segmask_iou 0.55400, 24.45 secs
# New checkpoint saved: checkpoint_68_chestimgbbiou+phrase_acc+segmask_iou=0.8356.pt
# ---- Epoch 69/80
# (1) Training stage (lr = 0.000070) ...
# loss 2.31632, y8_loss 2.06605, y8box_loss 0.70156, y8cls_loss 0.32578, y8dfl_loss 1.03870, phrase_acc 0.99708, phrcls_loss 0.00840, att_sup_loss 0.24187, segmask_iou 0.57825, 144.49 secs
# (2) Validation stage ...
# chestimgbbiou 0.94818, phrase_acc 0.99004, segmask_iou 0.50468, 23.69 secs
# ---- Epoch 70/80
# (1) Training stage (lr = 0.000042) ...
# loss 2.31544, y8_loss 2.06644, y8box_loss 0.70006, y8cls_loss 0.32693, y8dfl_loss 1.03946, phrase_acc 0.99715, phrcls_loss 0.00826, att_sup_loss 0.24073, segmask_iou 0.57857, 141.27 secs
# (2) Validation stage ...
# chestimgbbiou 0.86286, phrase_acc 0.55792, segmask_iou 0.20717, 15.07 secs
# ---- Epoch 71/80
# (1) Training stage (lr = 0.000025) ...
# loss 2.25066, y8_loss 2.01174, y8box_loss 0.67315, y8cls_loss 0.31450, y8dfl_loss 1.02409, phrase_acc 0.99705, phrcls_loss 0.00800, att_sup_loss 0.23093, segmask_iou 0.58049, 144.02 secs
# (2) Validation stage ...
# chestimgbbiou 0.95929, phrase_acc 0.99096, segmask_iou 0.52761, 22.79 secs
# ---- Epoch 72/80
# (1) Training stage (lr = 0.000015) ...
# loss 2.20182, y8_loss 1.97206, y8box_loss 0.65405, y8cls_loss 0.30407, y8dfl_loss 1.01394, phrase_acc 0.99755, phrcls_loss 0.00686, att_sup_loss 0.22289, segmask_iou 0.58230, 143.81 secs
# (2) Validation stage ...
# chestimgbbiou 0.95267, phrase_acc 0.99462, segmask_iou 0.50745, 23.94 secs
# ---- Epoch 73/80
# (1) Training stage (lr = 0.000009) ...
# loss 2.18931, y8_loss 1.96165, y8box_loss 0.64866, y8cls_loss 0.30128, y8dfl_loss 1.01172, phrase_acc 0.99785, phrcls_loss 0.00614, att_sup_loss 0.22152, segmask_iou 0.58259, 140.43 secs
# (2) Validation stage ...
# chestimgbbiou 0.96739, phrase_acc 0.99835, segmask_iou 0.55219, 28.68 secs
# ---- Epoch 74/80
# (1) Training stage (lr = 0.000006) ...
# loss 2.18667, y8_loss 1.95861, y8box_loss 0.64710, y8cls_loss 0.30097, y8dfl_loss 1.01054, phrase_acc 0.99760, phrcls_loss 0.00710, att_sup_loss 0.22096, segmask_iou 0.58279, 142.23 secs
# (2) Validation stage ...
# chestimgbbiou 0.96733, phrase_acc 0.99396, segmask_iou 0.54146, 23.85 secs
# ---- Epoch 75/80
# (1) Training stage (lr = 0.000003) ...
# loss 2.17828, y8_loss 1.95161, y8box_loss 0.64389, y8cls_loss 0.29879, y8dfl_loss 1.00893, phrase_acc 0.99768, phrcls_loss 0.00648, att_sup_loss 0.22019, segmask_iou 0.58310, 138.55 secs
# (2) Validation stage ...
# chestimgbbiou 0.97178, phrase_acc 0.99515, segmask_iou 0.55053, 23.06 secs
# ---- Epoch 76/80
# (1) Training stage (lr = 0.000002) ...
# loss 2.18642, y8_loss 1.95803, y8box_loss 0.64632, y8cls_loss 0.30037, y8dfl_loss 1.01135, phrase_acc 0.99769, phrcls_loss 0.00654, att_sup_loss 0.22185, segmask_iou 0.58218, 140.28 secs
# (2) Validation stage ...
# chestimgbbiou 0.97158, phrase_acc 0.99577, segmask_iou 0.55272, 23.17 secs
# ---- Epoch 77/80
# (1) Training stage (lr = 0.000070) ...
# loss 2.26027, y8_loss 2.01949, y8box_loss 0.67771, y8cls_loss 0.31581, y8dfl_loss 1.02597, phrase_acc 0.99746, phrcls_loss 0.00727, att_sup_loss 0.23352, segmask_iou 0.58107, 139.96 secs
# (2) Validation stage ...
# chestimgbbiou 0.92385, phrase_acc 0.84015, segmask_iou 0.41774, 20.53 secs
# ---- Epoch 78/80
# (1) Training stage (lr = 0.000042) ...
# loss 2.27924, y8_loss 2.03627, y8box_loss 0.68476, y8cls_loss 0.32068, y8dfl_loss 1.03083, phrase_acc 0.99709, phrcls_loss 0.00838, att_sup_loss 0.23458, segmask_iou 0.58009, 141.61 secs
# (2) Validation stage ...
# chestimgbbiou 0.91494, phrase_acc 0.96065, segmask_iou 0.40693, 23.57 secs
# ---- Epoch 79/80
# (1) Training stage (lr = 0.000025) ...
# loss 2.23155, y8_loss 2.00032, y8box_loss 0.66932, y8cls_loss 0.31000, y8dfl_loss 1.02100, phrase_acc 0.99777, phrcls_loss 0.00628, att_sup_loss 0.22495, segmask_iou 0.58249, 143.29 secs
# (2) Validation stage ...
# chestimgbbiou 0.94180, phrase_acc 0.99623, segmask_iou 0.48178, 22.79 secs
# ---- Epoch 80/80
# (1) Training stage (lr = 0.000015) ...
# loss 2.22211, y8_loss 1.98992, y8box_loss 0.66288, y8cls_loss 0.30732, y8dfl_loss 1.01973, phrase_acc 0.99746, phrcls_loss 0.00728, att_sup_loss 0.22490, segmask_iou 0.58183, 140.92 secs
# (2) Validation stage ...
# chestimgbbiou 0.95441, phrase_acc 0.99054, segmask_iou 0.51368, 21.70 secs
