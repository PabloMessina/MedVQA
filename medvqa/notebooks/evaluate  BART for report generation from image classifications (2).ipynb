# %%
# %env CUDA_VISIBLE_DEVICES=0
# Out:
# env: CUDA_VISIBLE_DEVICES=0

# %%
# %env TOKENIZERS_PARALLELISM=false
# Out:
# env: TOKENIZERS_PARALLELISM=false

# %%
from importlib import reload
import medvqa

# %%
reload(medvqa.eval_templates2report)
# Out:
# <module 'medvqa.eval_templates2report' from '/home/pamessina/medvqa/medvqa/eval_templates2report.py'>

# %%
from medvqa.eval_templates2report import ReportGenerationVisualizer

# %%
rgv = ReportGenerationVisualizer(
    metrics_filepath='/mnt/data/pamessina/workspaces/medvqa-workspace/results/seq2seq/20240511_231851_fact_classifier_predictions2report_section(sigmoids2findings)_Seq2Seq(facebook-bart-base)/interpret_cxr_test_public_report_gen_metrics(findings,fmt2024-05-12 03:03:02,first75).pkl',
    gen_reports_filepath='/mnt/data/pamessina/workspaces/medvqa-workspace/results/seq2seq/20240511_231851_fact_classifier_predictions2report_section(sigmoids2findings)_Seq2Seq(facebook-bart-base)/interpret_cxr_test_public_gen_reports(findings,fmt2024-05-12 03:03:02,first75).pkl',
)

# %%
rgv.visualize(100)
# Out:
# Number of images: 2
# 1: /mnt/workspace/interpret-cxr-test-public-jpg/test_public/image_130_view_0.jpg
# 2: /mnt/workspace/interpret-cxr-test-public-jpg/test_public/image_130_view_1.jpg
# Input:
# views: 2
# cardiac pacer and wires:yes 3,no 1
# pleural effusion:yes 7,no 4
# pleural abnormalities:yes 7,yes 6
# lung opacity:yes 8,yes 7
# opacity texture:yes 6,yes 5
# edema:yes 5,yes 4
# airspace opacity:yes 6,yes 3
# vascular congestion:yes 6,yes 6
# linear/patchy atelectasis:yes 3,no 2
# atelectasis:yes 6,no 4
# enlarged cardiomediastinum:yes 5,yes 5
# lobar/segmental collapse:yes 5,no 2
# pneumonia:yes 6,no 4
# consolidation:yes 6,yes 3
# interstitial texture:no 3,yes 4
# infiltration:yes 5,no 5
# tortuous aorta:no 2,yes 5
# prosthetic valve:no 3,yes 3
# lung cancer:yes 6,yes 2
# calcification of the aorta:no 2,yes 4
# vascular calcification:no 2,yes 3
# multiple masses/nodules:yes 6,yes 4
# vascular redistribution:no 3,yes 5
# mediastinal displacement:yes 6,yes 4
# mass:yes 5,yes 5
# ...
