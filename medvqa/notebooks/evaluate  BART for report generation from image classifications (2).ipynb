# %%
# %env CUDA_VISIBLE_DEVICES=0
# Out:
# env: CUDA_VISIBLE_DEVICES=0

# %%
# %env TOKENIZERS_PARALLELISM=false
# Out:
# env: TOKENIZERS_PARALLELISM=false

# %%
from importlib import reload
import medvqa

# %%
reload(medvqa.eval_templates2report)
# Out:
# <module 'medvqa.eval_templates2report' from '/home/pamessina/medvqa/medvqa/eval_templates2report.py'>

# %%
from medvqa.eval_templates2report import ReportGenerationVisualizer

# %%
rgv = ReportGenerationVisualizer(
#     metrics_filepath='/mnt/data/pamessina/workspaces/medvqa-workspace/results/seq2seq/20240511_231851_fact_classifier_predictions2report_section(sigmoids2findings)_Seq2Seq(facebook-bart-base)/interpret_cxr_test_public_report_gen_metrics(findings,fmt2024-05-12 03:03:02,first75).pkl',
#     metrics_filepath='/mnt/data/pamessina/workspaces/medvqa-workspace/results/seq2seq/20240511_232138_fact_classifier_predictions2report_section(sigmoids2impression)_Seq2Seq(facebook-bart-base)/interpret_cxr_test_public_report_gen_metrics(impression,fmt2024-05-12 02:28:52,first75).pkl',
    metrics_filepath='/mnt/data/pamessina/workspaces/medvqa-workspace/results/seq2seq/20240511_231851_fact_classifier_predictions2report_section(sigmoids2findings)_Seq2Seq(facebook-bart-base)/interpret_cxr_test_public_report_gen_metrics(findings,fmt2024-05-13 01:29:50,first75).pkl',
#     gen_reports_filepath='/mnt/data/pamessina/workspaces/medvqa-workspace/results/seq2seq/20240511_231851_fact_classifier_predictions2report_section(sigmoids2findings)_Seq2Seq(facebook-bart-base)/interpret_cxr_test_public_gen_reports(findings,fmt2024-05-12 03:03:02,first75).pkl',
#     gen_reports_filepath='/mnt/data/pamessina/workspaces/medvqa-workspace/results/seq2seq/20240511_232138_fact_classifier_predictions2report_section(sigmoids2impression)_Seq2Seq(facebook-bart-base)/interpret_cxr_test_public_gen_reports(impression,fmt2024-05-12 02:28:52,first75).pkl',
    gen_reports_filepath='/mnt/data/pamessina/workspaces/medvqa-workspace/results/seq2seq/20240511_231851_fact_classifier_predictions2report_section(sigmoids2findings)_Seq2Seq(facebook-bart-base)/interpret_cxr_test_public_gen_reports(findings,fmt2024-05-13 01:29:50,first75).pkl',
)

# %%
rgv.visualize(5)
# Out:
# Number of images: 1
# 1: /mnt/workspace/interpret-cxr-test-public-jpg/test_public/image_10_view_0.jpg
# Input:
# views: 1
# no abnormalities:yes 6
# Gen:
# normal heart size. normal mediastinal contours. normal hilar contours normal pulmonary vasculature. clear lungs. no pleural effusion. no pneumothorax. no acute osseous abnormalities.
# GT:
# the lungs are clear without focal consolidation. no pleural effusion or pneumothorax is seen. the cardiac and mediastinal silhouettes are unremarkable. no evidence of free air is seen beneath the diaphragms.
# Metrics:
# bleu-1: 0.154
# bleu-2: 0.070
# bleu-3: 0.000
# bleu-4: 0.000
# ciderD: 0.061
# rougeL: 0.144
# meteor: 0.247
# Chexpert labels:
# Accuracy: 1.000
# GT: ['No Finding']
# Gen: ['No Finding']
# Chexbert labels:
# Accuracy: 1.000
# GT: ['No Finding']
# Gen: ['No Finding']
# Radgraph F1:
# 0.22535211267605634
