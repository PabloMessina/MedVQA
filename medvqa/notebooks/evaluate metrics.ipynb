# %%
# %env CUDA_VISIBLE_DEVICES=1
# Out:
# env: CUDA_VISIBLE_DEVICES=1

# %%
from importlib import reload
import medvqa

# %%
# reload(medvqa.metrics.medical.radgraph)
# reload(medvqa.eval_report_gen_metrics)

# %%
from medvqa.eval_report_gen_metrics import (
    evaluate_metrics__chest_imagenome_gold,
    evaluate_metrics__chest_imagenome_gold__report_level,
    evaluate_metrics__custom_mimiccxr_radiologist_annotations,
    evaluate_metrics__NLI,
    evaluate_metrics__iuxray_tags__report_level,
)
from medvqa.utils.files import load_pickle

# %%
tmp = load_pickle('/mnt/data/pamessina/workspaces/medvqa-workspace/cache/chest_imagenome/phrases2labels_gold(num_obs=70,num_anat=38,num_phrases=2412).pkl')

# %%
tmp2 = load_pickle('/mnt/data/pamessina/workspaces/medvqa-workspace/cache/chest_imagenome/phrases2labels(num_obs=76,num_anat=39,num_phrases=556111).pkl')

# %%
tmp2.keys()
# Out:
# dict_keys(['phrases', 'observation_labels', 'anatomy_labels', 'anatomy_names', 'observation_names'])

# %%
len(tmp2['observation_names'])
# Out:
# 76

# %%
tmp.keys()
# Out:
# dict_keys(['phrases', 'observation_labels', 'observation_names', 'anatomy_labels', 'anatomy_names'])

# %%
tmp2['observation_names']
# Out:
# ['anatomicalfinding|airspace opacity',
#  'anatomicalfinding|atelectasis',
#  'anatomicalfinding|bone lesion',
#  'anatomicalfinding|bronchiectasis',
#  'anatomicalfinding|calcified nodule',
#  'anatomicalfinding|clavicle fracture',
#  'anatomicalfinding|consolidation',
#  'anatomicalfinding|costophrenic angle blunting',
#  'anatomicalfinding|cyst/bullae',
#  'anatomicalfinding|diaphragmatic eventration (benign)',
#  'anatomicalfinding|elevated hemidiaphragm',
#  'anatomicalfinding|enlarged cardiac silhouette',
#  'anatomicalfinding|enlarged hilum',
#  'anatomicalfinding|hernia',
#  'anatomicalfinding|hydropneumothorax',
#  'anatomicalfinding|hyperaeration',
#  'anatomicalfinding|increased reticular markings/ild pattern',
#  'anatomicalfinding|infiltration',
#  'anatomicalfinding|linear/patchy atelectasis',
#  'anatomicalfinding|lobar/segmental collapse',
#  'anatomicalfinding|lung lesion',
#  'anatomicalfinding|lung opacity',
# ...

# %%
tmp['anatomy_names']
# Out:
# ['abdomen',
#  'aortic arch',
#  'cardiac silhouette',
#  'carina',
#  'cavoatrial junction',
#  'left apical zone',
#  'left arm',
#  'left breast',
#  'left chest wall',
#  'left clavicle',
#  'left costophrenic angle',
#  'left hemidiaphragm',
#  'left hilar structures',
#  'left lower lung zone',
#  'left lung',
#  'left mid lung zone',
#  'left shoulder',
#  'left upper lung zone',
#  'mediastinum',
#  'neck',
#  'right apical zone',
#  'right arm',
#  'right atrium',
#  'right breast',
#  'right chest wall',
#  'right clavicle',
#  'right costophrenic angle',
#  'right hemidiaphragm',
#  'right hilar structures',
#  'right lower lung zone',
#  'right lung',
#  'right mid lung zone',
#  'right shoulder',
#  'right upper lung zone',
#  'spine',
#  'svc',
#  'trachea',
#  'upper mediastinum']

# %%
evaluate_metrics__chest_imagenome_gold('/mnt/data/pamessina/workspaces/medvqa-workspace/cache/chest_imagenome/phrases2labels_gold(num_obs=70,num_anat=38,num_phrases=2412).pkl')
# Out:
# Loading sentence2labels_gold from /mnt/data/pamessina/workspaces/medvqa-workspace/cache/chest_imagenome/phrases2labels_gold(num_obs=70,num_anat=38,num_phrases=2412).pkl
# Number of sentences: 2412
# label.shape: (2412, 108)
# Loaded gold_accuracy matrix from /mnt/workspace/pamessina/medvqa-workspace/cache/score_matrix(gold_accuracy,2412,108).pkl
# Loaded chest_imagenome_gold_relevance matrix from /mnt/workspace/pamessina/medvqa-workspace/cache/score_matrix(chest_imagenome_gold_relevance,2412,70,2412,38).pkl
# Loaded bleu matrix from /mnt/workspace/pamessina/medvqa-workspace/cache/score_matrix(bleu,2412,179378).pkl
# Loaded rougel matrix from /mnt/workspace/pamessina/medvqa-workspace/cache/score_matrix(rougel,2412,179378).pkl
# Loaded meteor matrix from /mnt/workspace/pamessina/medvqa-workspace/cache/score_matrix(meteor,2412,179378).pkl
# Loaded ciderd matrix from /mnt/workspace/pamessina/medvqa-workspace/cache/score_matrix(ciderd,2412,179378).pkl
# ...

# %%
# %env TOKENIZERS_PARALLELISM=false
# Out:
# env: TOKENIZERS_PARALLELISM=false

# %%
evaluate_metrics__chest_imagenome_gold(
    '/mnt/data/pamessina/workspaces/medvqa-workspace/cache/chest_imagenome/phrases2labels_gold(num_obs=70,num_anat=38,num_phrases=2412).pkl',
    fact_embedding_model_checkpoint_folder_paths=[
        '/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240207_235928_MIMIC-CXR(triplets+classif+entcont+nli)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)',
        '/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240129_213433_MIMIC-CXR(triplets+classif+entcont+nli+radgraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)',
        '/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240129_151525_MIMIC-CXR(triplets+classif+entcont+nli+autoencoder)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)',
        '/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240207_184445_MIMIC-CXR(triplets+classif+entcont+nli+radgraph+autoencoder)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)',
    ], fact_embedding_model_names = [
        'CXRFEScore(T+C+EC+NLI)',
        'CXRFEScore(T+C+EC+NLI+ER)',
        'CXRFEScore(T+C+EC+NLI+SD)',
        'CXRFEScore(T+C+EC+NLI+ER+SD)',
    ]
)
# Out:
# Loading sentence2labels_gold from /mnt/data/pamessina/workspaces/medvqa-workspace/cache/chest_imagenome/phrases2labels_gold(num_obs=70,num_anat=38,num_phrases=2412).pkl
# Number of sentences: 2412
# label.shape: (2412, 108)
# Loaded gold_accuracy matrix from /mnt/workspace/pamessina/medvqa-workspace/cache/score_matrix(gold_accuracy,2412,108).pkl
# Loaded chest_imagenome_gold_relevance matrix from /mnt/workspace/pamessina/medvqa-workspace/cache/score_matrix(chest_imagenome_gold_relevance,2412,70,2412,38).pkl
# Loaded bleu matrix from /mnt/workspace/pamessina/medvqa-workspace/cache/score_matrix(bleu,2412,179378).pkl
# Loaded rougel matrix from /mnt/workspace/pamessina/medvqa-workspace/cache/score_matrix(rougel,2412,179378).pkl
# Loaded meteor matrix from /mnt/workspace/pamessina/medvqa-workspace/cache/score_matrix(meteor,2412,179378).pkl
# Loaded ciderd matrix from /mnt/workspace/pamessina/medvqa-workspace/cache/score_matrix(ciderd,2412,179378).pkl
# ...

# %%
# %env TOKENIZERS_PARALLELISM=false
# Out:
# env: TOKENIZERS_PARALLELISM=false

# %%
evaluate_metrics__NLI(
    fact_embedding_model_checkpoint_folder_paths=[
        '/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240207_235928_MIMIC-CXR(triplets+classif+entcont+nli)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)',
        '/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240129_213433_MIMIC-CXR(triplets+classif+entcont+nli+radgraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)',
        '/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240129_151525_MIMIC-CXR(triplets+classif+entcont+nli+autoencoder)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)',
        '/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240207_184445_MIMIC-CXR(triplets+classif+entcont+nli+radgraph+autoencoder)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)',
    ], fact_embedding_model_names = [
        'CXR Fact Encoder Score (T+C+EC+NLI)',
        'CXR Fact Encoder Score (T+C+EC+NLI+ER)',
        'CXR Fact Encoder Score (T+C+EC+NLI+SD)',
        'CXR Fact Encoder Score (T+C+EC+NLI+ER+SD)',
    ],
    radcliq_device_id='1',
)
# Out:
# Number of MS_CXR_T samples: 361
# Number of entailment samples: 141
# Number of contradiction samples: 220
# Number of RadNLI dev samples: 480
# Number of RadNLI test samples: 480
# Number of RadNLI samples: 399
# Number of entailment samples: 195
# Number of contradiction samples: 204
# Cache successfully loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/cache/chexpert_labeler_cache.pkl
# (*) Chexpert: labeling 1520 texts ...
# Chexpert: found 984 unique sentences from 1520 texts
# All labels found in cache, no need to invoke chexpert labeler
# Chexpert: merged 984 texts into 1520 texts
# out.shape = (1520, 14)
# Cache successfully loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/cache/chexpert_labeler_cache.pkl
# (*) Chexpert: labeling 1520 texts ...
# Chexpert: found 984 unique sentences from 1520 texts
# All labels found in cache, no need to invoke chexpert labeler
# Chexpert: merged 984 texts into 1520 texts
# out.shape = (1520, 14)
# ...

# %%
evaluate_metrics__chest_imagenome_gold__report_level('/mnt/data/pamessina/workspaces/medvqa-workspace/cache/chest_imagenome/reports2labels_gold(num_obs=70,num_anat=38,num_reports=500).pkl',
    fact_embedding_model_checkpoint_folder_paths=[
        '/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240207_235928_MIMIC-CXR(triplets+classif+entcont+nli)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)',
        '/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240129_213433_MIMIC-CXR(triplets+classif+entcont+nli+radgraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)',
        '/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240129_151525_MIMIC-CXR(triplets+classif+entcont+nli+autoencoder)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)',
        '/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240207_184445_MIMIC-CXR(triplets+classif+entcont+nli+radgraph+autoencoder)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)',
    ], fact_embedding_model_names = [
        'CXRFEScore(T+C+EC+NLI)',
        'CXRFEScore(T+C+EC+NLI+ER)',
        'CXRFEScore(T+C+EC+NLI+SD)',
        'CXRFEScore(T+C+EC+NLI+ER+SD)',
    ]
)
# Out:
# Loading report2labels_gold from /mnt/data/pamessina/workspaces/medvqa-workspace/cache/chest_imagenome/reports2labels_gold(num_obs=70,num_anat=38,num_reports=500).pkl
# Number of reports: 500
# label.shape: (500, 108)
# Loaded gold_accuracy matrix from /mnt/workspace/pamessina/medvqa-workspace/cache/score_matrix(gold_accuracy,500,108).pkl
# Loaded chest_imagenome_gold_jaccard matrix from /mnt/workspace/pamessina/medvqa-workspace/cache/score_matrix(chest_imagenome_gold_jaccard,500,70,500,38).pkl
# Loaded bleu matrix from /mnt/workspace/pamessina/medvqa-workspace/cache/score_matrix(bleu,500,211674).pkl
# Loaded rougel matrix from /mnt/workspace/pamessina/medvqa-workspace/cache/score_matrix(rougel,500,211674).pkl
# Loaded meteor matrix from /mnt/workspace/pamessina/medvqa-workspace/cache/score_matrix(meteor,500,211674).pkl
# Loaded ciderd matrix from /mnt/workspace/pamessina/medvqa-workspace/cache/score_matrix(ciderd,500,211674).pkl
# ...

# %%
evaluate_metrics__iuxray_tags__report_level(
    fact_embedding_model_checkpoint_folder_paths=[
        '/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240207_235928_MIMIC-CXR(triplets+classif+entcont+nli)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)',
        '/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240129_213433_MIMIC-CXR(triplets+classif+entcont+nli+radgraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)',
        '/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240129_151525_MIMIC-CXR(triplets+classif+entcont+nli+autoencoder)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)',
        '/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20240207_184445_MIMIC-CXR(triplets+classif+entcont+nli+radgraph+autoencoder)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)',
    ], fact_embedding_model_names = [
        'CXRFEScore(T+C+EC+NLI)',
        'CXRFEScore(T+C+EC+NLI+ER)',
        'CXRFEScore(T+C+EC+NLI+SD)',
        'CXRFEScore(T+C+EC+NLI+ER+SD)',
    ]
)
# Out:
# Number of reports: 3955
# Number of tag_sets: 3955
# Loaded iuxray_gold_tags_jaccard matrix from /mnt/workspace/pamessina/medvqa-workspace/cache/score_matrix(iuxray_gold_tags_jaccard).pkl
# Loaded bleu matrix from /mnt/workspace/pamessina/medvqa-workspace/cache/score_matrix(bleu,3955,1063413).pkl
# Loaded rougel matrix from /mnt/workspace/pamessina/medvqa-workspace/cache/score_matrix(rougel,3955,1063413).pkl
# Loaded meteor matrix from /mnt/workspace/pamessina/medvqa-workspace/cache/score_matrix(meteor,3955,1063413).pkl
# Loaded ciderd matrix from /mnt/workspace/pamessina/medvqa-workspace/cache/score_matrix(ciderd,3955,1063413).pkl
# Loaded bertscore matrix from /mnt/workspace/pamessina/medvqa-workspace/cache/score_matrix(bertscore,3955,1063413).pkl
# Loaded chexpert_accuracy matrix from /mnt/workspace/pamessina/medvqa-workspace/cache/score_matrix(chexpert_accuracy,3955,1063413).pkl
# ...

# %%
tmp = load_pickle('/mnt/data/pamessina/workspaces/medvqa-workspace/cache/chest_imagenome/phrases2labels_gold(num_obs=70,num_anat=38,num_phrases=2412).pkl')

# %%
sent = tmp['phrases']

# %%
goldacc_mat = load_pickle('/mnt/workspace/pamessina/medvqa-workspace/cache/score_matrix(gold_accuracy,2412).pkl')

# %%
goldrev_mat = load_pickle('/mnt/workspace/pamessina/medvqa-workspace/cache/score_matrix(chest_imagenome_gold_relevance,2412,70,2412,38).pkl')

# %%
ciderd_mat = load_pickle('/mnt/workspace/pamessina/medvqa-workspace/cache/score_matrix(ciderd,2412,179378).pkl')

# %%
rougel_mat = load_pickle('/mnt/workspace/pamessina/medvqa-workspace/cache/score_matrix(rougel,2412,179378).pkl')

# %%
factemb_mat = load_pickle('/mnt/workspace/pamessina/medvqa-workspace/cache/score_matrix(fact_embedding_score,2412,179378).pkl')

# %%
radgraph_mat = load_pickle('/mnt/workspace/pamessina/medvqa-workspace/cache/score_matrix(radgraph_jaccard,2412,179378).pkl')

# %%
bertscore_mat = load_pickle('/mnt/workspace/pamessina/medvqa-workspace/cache/score_matrix(bertscore,2412,179378).pkl')

# %%
factemb_mat.shape
# Out:
# (2412, 2412)

# %%
tmp.keys()
# Out:
# dict_keys(['phrases', 'observation_labels', 'observation_names', 'anatomy_labels', 'anatomy_names'])

# %%
bleu_mat.shape
# Out:
# (2412, 2412)

# %%
acc_mat.shape
# Out:
# (2412, 2412)

# %%
import numpy as np

# %%
q = '6 mm rounded calcified right upper lobe granuloma is stable.'
# q = 'Pulmonary edema.'
# q = ', likely reflecting improved ventilation'
idx = tmp['phrases'].index(q)
print(idx)
print(q)
print()
for j, x in enumerate(tmp['observation_labels'][idx]):
    if x != -1:
        print(tmp['observation_names'][j], x)
for j, x in enumerate(tmp['anatomy_labels'][idx]):
    if x:
        print(tmp['anatomy_names'][j])
# Out:
# 100
# 6 mm rounded calcified right upper lobe granuloma is stable.
#
# abnormal 1
# calcified nodule 1
# granulomatous disease 1
# lung lesion 1
# lung opacity 1
# right lung
# right mid lung zone
# right upper lung zone

# %%
q = '2. Stable postoperative appearance of the chest status post resection of a Pancoast tumor.'
# q = 'Pulmonary edema.'
# q = ', likely reflecting improved ventilation'
idx = tmp['phrases'].index(q)
print(idx)
print(q)
print()
for j, x in enumerate(tmp['observation_labels'][idx]):
    if x != -1:
        print(tmp['observation_names'][j], x)
for j, x in enumerate(tmp['anatomy_labels'][idx]):
    if x:
        print(tmp['anatomy_names'][j])
# Out:
# 73
# 2. Stable postoperative appearance of the chest status post resection of a Pancoast tumor.
#
# abnormal 1
# right lung

# %%
import numpy as np

i = 74
# mat = factemb_mat
mat = bertscore_mat
# mat = goldacc_mat
# mat = goldrev_mat
# mat = radgraph_mat
# mat = ciderd_mat
idxs = np.argsort(mat[i])[::-1]
print(sent[i])
print()
for j in range(30):
    print(mat[i][idxs[j]])
    print(sent[idxs[j]])
    print()
# Out:
# 2. Subpleural opacity in the left lower lobe appears more prominent on the current exam, and corresponds to an area of pleural fat as noted on the prior chest CT.
#
# 1.0
# 2. Subpleural opacity in the left lower lobe appears more prominent on the current exam, and corresponds to an area of pleural fat as noted on the prior chest CT.
#
# 0.945819079875946
# Previously described subpleural left lower lobe opacity seen on prior chest radiograph which corresponds to an area of pleural fat on CT appears more prominent on the current exam.
#
# 0.914481520652771
# Patchy opacity is seen within the right lung base corresponding to the area of infarction seen on the prior CT.
#
# 0.9050331115722656
# There is increased opacity in the left lower lobe, best seen on the lateral.
#
# 0.9027479290962219
# There is however new nodular opacity projecting over the left upper lung not clearly seen on the previous exam.
#
# 0.9025329351425171
# ...

# %%
from medvqa.metrics.nlp import Bleu
bleu = Bleu(device='cpu', record_scores=True, using_ids=False)
gen_texts = [
    '8 cm right upper lobe mass as seen on recent imaging.',
    ', likely reflecting improved ventilation',
]
gt_texts = [
    '8 cm right upper lobe mass as seen on recent imaging.',
    '8 cm right upper lobe mass as seen on recent imaging.',
]
bleu.update((gen_texts, gt_texts))
bleu.compute()
# Out:
# ([0.4725113791097295,
#   0.4816281945690355,
#   0.4926534698647002,
#   0.506364847212299],
#  [[0.999999999818182, 6.02388423583449e-17],
#   [0.9999999998136365, 6.734907319789274e-17],
#   [0.9999999998084177, 7.693598848807851e-17],
#   [0.9999999998023361, 9.100207812238193e-17]])

# %%
from medvqa.metrics.nlp import CiderD
metric = CiderD(device='cpu', record_scores=True, using_ids=False)
gt_texts = [sent[0]] * len(sent)
gen_texts = sent
metric.update((gen_texts, gt_texts))
metric.compute()
# Out:
# (0.0, array([0., 0., 0., ..., 0., 0., 0.]))

# %%
from pycocoevalcap.cider import cider_scorer

cdscorer = cider_scorer.CiderScorer(n=4)
gt_texts = [sent[0]] * len(sent)
gen_texts = sent
for gen_text, gt_text in zip(gen_texts, gt_texts):
    cdscorer += (gt_text, [gen_text])
_, scores = cdscorer.compute_score()

# %%
idxs = np.argsort(scores)[::-1]

# %%
print(sent[0])

for i in range(10):
    print(scores[idxs[i]])
    print(sent[idxs[i]])
# Out:
# , likely reflecting improved ventilation
# 10.0
# , likely reflecting improved ventilation
# 0.481229719213627
# The lungs are hyperlucent reflecting known severe emphysema.
# 0.41879035370081397
# Mild pulmonary edema has improved substantially since ___.
# 0.21567854784526388
# Mild retrocardiac opacity likely atelectasis.
# 0.19373211237426677
# Mild right basilar opacity, likely atelectasis.
# 0.17757459837756845
# Left basilar opacity likely represents atelectasis.
# 0.17330981683787605
# There are likely small pleural effusions bilaterally.
# 0.16790079934709967
# Right basilar opacity is likely due to atelectasis.
# 0.14979077280681163
# Small bilateral pleural effusions are most likely present.
# 0.1452051655599579
# Streaky bibasilar opacities most likely reflect atelectasis.

# %%
# %env TOKENIZERS_PARALLELISM=false
# Out:
# env: TOKENIZERS_PARALLELISM=false

# %%
evaluate_metrics__custom_mimiccxr_radiologist_annotations()
# Out:
# Number of sentences: 1165
# label.shape: (1165, 14)
# Loaded gold_accuracy matrix from /mnt/workspace/pamessina/medvqa-workspace/cache/score_matrix(gold_accuracy,1165,14).pkl
# Loaded custom_mimiccxr_radiologist_annotations_relevance matrix from /mnt/workspace/pamessina/medvqa-workspace/cache/score_matrix(custom_mimiccxr_radiologist_annotations_relevance,1165,14).pkl
# Loaded bleu matrix from /mnt/workspace/pamessina/medvqa-workspace/cache/score_matrix(bleu,1165,119235).pkl
# Loaded rougel matrix from /mnt/workspace/pamessina/medvqa-workspace/cache/score_matrix(rougel,1165,119235).pkl
# Loaded meteor matrix from /mnt/workspace/pamessina/medvqa-workspace/cache/score_matrix(meteor,1165,119235).pkl
# Loaded ciderd matrix from /mnt/workspace/pamessina/medvqa-workspace/cache/score_matrix(ciderd,1165,119235).pkl
# Loaded bertscore matrix from /mnt/workspace/pamessina/medvqa-workspace/cache/score_matrix(bertscore,1165,119235).pkl
# ...

# %%
from medvqa.eval_fact_embedding_on_ranking import _load_mimiccxr_radiologist_annotations

# %%
sent2, labels2 = _load_mimiccxr_radiologist_annotations()

# %%
goldacc_mat_2 = load_pickle('/mnt/workspace/pamessina/medvqa-workspace/cache/score_matrix(gold_accuracy,1165,14).pkl')

# %%
factemb_mat_2 = load_pickle('/mnt/workspace/pamessina/medvqa-workspace/cache/score_matrix(fact_embedding_score,1165,119235).pkl')

# %%
chexbert_mat_2 = load_pickle('/mnt/workspace/pamessina/medvqa-workspace/cache/score_matrix(chexbert_accuracy,1165,119235).pkl')

# %%
import numpy as np

i = 1
# mat = goldacc_mat_2
mat = factemb_mat_2
# mat = chexbert_mat_2

idxs = np.argsort(mat[i])[::-1]
print(sent2[i])
print()
for j in range(30):
    print(mat[i][idxs[j]])
    print(sent2[idxs[j]])
    print()
# Out:
# right pleural effusion with bibasilar atelectasis and expected postoperative changes .
#
# 1.0
# right pleural effusion with bibasilar atelectasis and expected postoperative changes .
#
# 0.7245555
# small to moderate right pleural effusion with adjacent atelectasis is grossly unchanged .
#
# 0.71931744
# new small right sided pleural effusion with adjacent atelectasis .
#
# 0.70019865
# new large right pleural effusion with associated atelectasis .
#
# 0.6485096
# bibasal atelectasis and small bilateral pleural effusions , left more than right , has worsened since xxxx .
#
# 0.64457905
# right pleural effusion , adjacent atelectasis , and mild vascular congestion are stable .
#
# 0.6410997
# bilateral pleural effusion , bibasilar atelectasis are suspected as well .
#
# 0.6298203
# lungs are essentially clear with bibasal atelectasis .
#
# 0.6257866
# ...

# %%
import numpy as np

i = 1
# mat = goldacc_mat_2
# mat = factemb_mat_2
mat = chexbert_mat_2

idxs = np.argsort(mat[i])[::-1]
print(sent2[i])
print()
for j in range(30):
    print(mat[i][idxs[j]])
    print(sent2[idxs[j]])
    print()
# Out:
# right pleural effusion with bibasilar atelectasis and expected postoperative changes .
#
# 1.0
# possible trace pleural effusion and left basilar atelectasis .
#
# 1.0
# probable small right pleural effusion and right basal atelectasis .
#
# 1.0
# suspected pleural effusions and patchy parenchymal densities likely due to atelectasis .
#
# 1.0
# new small right sided pleural effusion with adjacent atelectasis .
#
# 1.0
# bibasal atelectasis and small bilateral pleural effusions , left more than right , has worsened since xxxx .
#
# 1.0
# perhaps trace pleural effusion or atelectasis on the left , but generally speaking , clear lungs .
#
# 1.0
# improved right lower lobe atelectasis with minimal residual linear atelectasis remaining , as well as an apparent small right pleural effusion .
#
# 1.0
# in the interval , the patient has developed a small right basal atelectasis and mild to moderate left pleural effusion .
#
# 1.0
# ...
