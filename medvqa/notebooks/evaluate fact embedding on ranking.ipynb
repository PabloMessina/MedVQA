# %%
# %env CUDA_VISIBLE_DEVICES=2
# Out:
# env: CUDA_VISIBLE_DEVICES=2

# %%
# !ls "/home/pdpino/workspace-medical-ai/report_generation/nlp-chex-gold-sentences"
# Out:
# cxr-sentence-assessment-expert1.csv  iu-empty.csv     mimic-expert1.csv
# cxr-sentence-assessment-expert2.csv  iu-sorted.txt    mimic-expert2.csv
# docfreq-mimic.data		     mimic-empty.csv  mimic-sorted.txt

# %%
import pandas as pd

# %%
df = pd.read_csv("/home/pdpino/workspace-medical-ai/report_generation/nlp-chex-gold-sentences/cxr-sentence-assessment-expert1.csv")

# %%
df
# Out:
#                                                Sentence Atelectasis  \
# 0     band of atelectasis crossing the left hilus ha...    Abnormal
# 1     right pleural effusion with bibasilar atelecta...    Abnormal
# 2          atelectasis at both lung bases are present .    Abnormal
# 3     in addition to severe bibasilar atelectasis an...    Abnormal
# 4     increase of the pre existing retrocardiac atel...    Abnormal
# ...                                                 ...         ...
# 1160  there is no pneumothorax , appreciable pleural...         NaN
# 1161  continued substantial enlargement of the cardi...         NaN
# 1162  there is no vascular congestion or pleural eff...         NaN
# 1163  almost complete resolution of left pleural eff...         NaN
# 1164  both lungs are clear with no focal consolidati...         NaN
#
#      Cardiomegaly Consolidation Edema Lung Opacity Pleural Effusion  \
# 0             NaN           NaN   NaN          NaN              NaN
# 1             NaN           NaN   NaN          NaN         Abnormal
# 2             NaN           NaN   NaN          NaN              NaN
# 3             NaN      Abnormal   NaN          NaN         Abnormal
# 4             NaN           NaN   NaN          NaN              NaN
# ...           ...           ...   ...          ...              ...
# 1160          NaN           NaN   NaN          NaN           Normal
# 1161     Abnormal           NaN   NaN          NaN           Normal
# 1162          NaN           NaN   NaN          NaN           Normal
# 1163          NaN           NaN   NaN          NaN           Normal
# 1164          NaN        Normal   NaN          NaN           Normal
#
#      Any other finding Not understood or malformed
# 0                  NaN                       False
# 1                  NaN                       False
# 2                  NaN                       False
# 3                  NaN                       False
# 4                  NaN                       False
# ...                ...                         ...
# 1160            Normal                       False
# 1161            Normal                       False
# 1162            Normal                       False
# 1163               NaN                       False
# 1164               NaN                       False
#
# [1165 rows x 9 columns]

# %%
df['Atelectasis'].fillna(-2)
# Out:
# 0       Abnormal
# 1       Abnormal
# 2       Abnormal
# 3       Abnormal
# 4       Abnormal
#           ...
# 1160          -2
# 1161          -2
# 1162          -2
# 1163          -2
# 1164          -2
# Name: Atelectasis, Length: 1165, dtype: object

# %%
import numpy as np

df['Sentence'].values
# Out:
# array(['band of atelectasis crossing the left hilus has been present for several days .',
#        'right pleural effusion with bibasilar atelectasis and expected postoperative changes .',
#        'atelectasis at both lung bases are present .', ...,
#        'there is no vascular congestion or pleural effusion .',
#        'almost complete resolution of left pleural effusion .',
#        'both lungs are clear with no focal consolidation , or pleural effusion .'],
#       dtype=object)

# %%
df.columns
# Out:
# Index(['Sentence', 'Atelectasis', 'Cardiomegaly', 'Consolidation', 'Edema',
#        'Lung Opacity', 'Pleural Effusion', 'Any other finding',
#        'Not understood or malformed'],
#       dtype='object')

# %%
df2 = pd.read_csv("/home/pdpino/workspace-medical-ai/report_generation/nlp-chex-gold-sentences/cxr-sentence-assessment-expert2.csv")

# %%
df2
# Out:
#                                                Sentence Atelectasis  \
# 0     band of atelectasis crossing the left hilus ha...    Abnormal
# 1     right pleural effusion with bibasilar atelecta...    Abnormal
# 2          atelectasis at both lung bases are present .    Abnormal
# 3     in addition to severe bibasilar atelectasis an...    Abnormal
# 4     increase of the pre existing retrocardiac atel...    Abnormal
# ...                                                 ...         ...
# 1160  there is no pneumothorax , appreciable pleural...      Normal
# 1161  continued substantial enlargement of the cardi...         NaN
# 1162  there is no vascular congestion or pleural eff...         NaN
# 1163  almost complete resolution of left pleural eff...         NaN
# 1164  both lungs are clear with no focal consolidati...         NaN
#
#      Cardiomegaly Consolidation Edema Lung Opacity Pleural Effusion  \
# 0             NaN           NaN   NaN          NaN              NaN
# 1             NaN           NaN   NaN          NaN         Abnormal
# 2             NaN           NaN   NaN          NaN              NaN
# 3             NaN      Abnormal   NaN          NaN         Abnormal
# 4             NaN           NaN   NaN          NaN              NaN
# ...           ...           ...   ...          ...              ...
# 1160          NaN           NaN   NaN          NaN           Normal
# 1161     Abnormal           NaN   NaN          NaN           Normal
# 1162          NaN           NaN   NaN          NaN           Normal
# 1163          NaN           NaN   NaN          NaN         Abnormal
# 1164          NaN        Normal   NaN          NaN           Normal
#
#      Any other finding  Not understood or malformed
# 0                  NaN                        False
# 1                  NaN                        False
# 2                  NaN                        False
# 3                  NaN                        False
# 4                  NaN                        False
# ...                ...                          ...
# 1160            Normal                        False
# 1161            Normal                        False
# 1162            Normal                        False
# 1163               NaN                        False
# 1164               NaN                        False
#
# [1165 rows x 9 columns]

# %%
df.columns
# Out:
# Index(['Sentence', 'Atelectasis', 'Cardiomegaly', 'Consolidation', 'Edema',
#        'Lung Opacity', 'Pleural Effusion', 'Any other finding',
#        'Not understood or malformed'],
#       dtype='object')

# %%
df[df['Any other finding'] == 'Abnormal']['Sentence'].tolist()
# Out:
# ['low lung volumes with atelectasis at the right lung bases .',
#  'because this patient emphysema is so severe , it may be important to document the extent of atelectasis and pleural effusion , both of which can be treated .',
#  'otherwise , there is little overall change with some residual atelectasis at the bases and subcutaneous gas along the right lateral chest wall .',
#  'continued bibasilar opacification with atelectatic changes , more prominent on the left , where there is also retrocardiac opacification consistent with volume loss in the lower lobe .',
#  'interval increase in right pleural effusion with complete atelectasis of the right middle and lower lobes , raising concern for bronchial obstruction .',
#  'lung volumes remain extremely low , exaggerating what is probably mild pulmonary edema on the right and persistent left lower lobe atelectasis .',
#  'low lung volumes with atelectasis and prominent hila .',
#  'left sided loculated hydropneumothorax with compressive atelectasis .',
#  'posterior opacity is noted , and might represent part of the atelectasis in combination with elevated right hemidiaphragm .',
#  'there is atelectasis at the lung bases and low lung volumes .',
#  'lung volumes are slightly decreased with interval appearance of a patchy opacity at both bases , likely reflecting patchy atelectasis .',
#  'bibasilar streaky opacities , likely atelectasis in the setting of low lung volumes .',
#  'right lower lobe collapse is persistent .',
#  'lung volumes lower today than in xxxx or more recently compared to xxxx , is explained by persistent bibasilar atelectasis , more severe on the right .',
#  'persistent retrocardiac opacification likely represents a combination of pleural effusion and collapse .',
#  'although overall lung volumes appear larger , there is probably more atelectasis , perhaps near collapse of both lower lobes .',
#  'region of that atelectasis and bronchial dilatation in the right mid lung and left perihilar consolidation are unchanged .',
#  'there is increasing opacification of the partially collapsed right lung .',
#  'low lung volumes with areas of basilar atelectasis as well as mild fluid overload persist .',
#  'unchanged mild cardiomegaly , elevation of the left hemidiaphragm and atelectasis at the left lung bases .',
#  'stable appearance of support devices and left pleural effusion with atelectasis .',
#  'bilateral calcified pleural plaques and moderate cardiomegaly .',
#  'persistent cardiomegaly and hiatal hernia .',
#  'low lung volumes and a large mediastinal fat collection exaggerate the size of the heart , probably normal .',
#  'there is unchanged cardiomegaly and tortuosity of the thoracic aorta .',
#  'lung volumes remain low , there is mild cardiomegaly and mild to moderate pulmonary edema .',
#  'unchanged borderline size of the cardiac silhouette , unchanged mild bronchiectatic changes in the dorsal aspects of the lung , best seen on the lateral radiograph .',
#  'there is stable cardiomegaly and postoperative change .',
#  'the patient is status post sternotomy , with cardiomegaly .',
#  'in comparison with the study of xxxx , there is continued enlargement of the cardiac silhouette with increased opacification at both bases consistent with substantial volume loss in the lower lungs .',
#  'the heart remains mildly enlarged and pulmonary vascular engorged , but i cannot be sure whether there is or is not mild edema because of the very large pleural effusions obscuring large parts of both lungs .',
#  'enlargement of the cardiac silhouette with elevated pulmonary venous pressure persists .',
#  'mild pulmonary vascular congestion with continued cardiomegaly .',
#  'mild cardiomegaly and widened mediastinum are unchanged due to a large right upper mediastinal mass .',
#  'the heart remains enlarged with left ventricular prominence suggesting underlying hypertension .',
#  'unchanged moderate cardiomegaly without evidence of fluid overload , no parenchymal changes except for the known parenchymal calcifications .',
#  'severe enlargement of the cardiac silhouette is longstanding , accompanied by azygos distention , suggest a strong component of right heart failure .',
#  'in comparison with the study xxxx , the cardiac silhouette remains at the upper limits of normal in size and there is again tortuosity of the descending thoracic aorta .',
#  'cardiomegaly unchanged with mild pulmonary congestion , new from prior .',
#  'the size of the cardiac silhouette is minimally enlarged and the monitoring and support devices are constant .',
#  'continued enlargement of the cardiac silhouette with substantial tortuosity of the descending aorta .',
#  'continued enlargement of the cardiac silhouette with double lumen catheter in place .',
#  'cardiac silhouette is mildly enlarged , and accompanied by pulmonary vascular congestion and minimal interstitial edema .',
#  'severe cardiomegaly and vascular hilar enlargement is unchanged .',
#  'cardiac silhouette is prominent and there is evidence of elevated pulmonary venous pressure .',
#  'cardiomegaly and mild vascular plethora .',
#  'there is mild to moderate cardiomegaly with evidence of mild pulmonary vascular congestion .',
#  'heart size and mediastinum are mildly enlarged .',
#  'low lung volumes with moderate cardiomegaly and minimal fluid overload .',
#  'more extra pleural and mediastinal fat has been deposited , obscuring more of the cardiac silhouette .',
#  'continued enlargement of cardiac silhouette with indistinctness of pulmonary vessels consistent with elevation of pulmonary venous pressure .',
#  'there is enlargement of the cardiac silhouette with engorgement of indistinct pulmonary vessels consistent with some elevated pulmonary venous pressure .',
#  'cardiomegaly , copd , bilateral small pleural effusions .',
#  'low lung volumes are noted with accentuation of the cardiac silhouette .',
#  'moderate cardiomegaly and increased interstitial markings and cephalization is concerning for congestive heart failure .',
#  'mediastinal and hilar lymphadenopathy , lingular consolidation , left lower lobe lung nodule , right upper lobe perihilar mass , and right upper lobe nodule are better seen in prior ct from xxxx .',
#  'right lower lobe collapse has improved , but the lower lobe is still severely atelectatic and / or consolidated .',
#  'right pigtail pleural catheter remains in place with persistent small to moderate right pleural effusion , and adjacent right mid and lower lung consolidation and atelectasis .',
#  'extent of bibasilar consolidation difficult to assess given the overlying heavy asbestos related calcified pleural plaque .',
#  'widespread involvement of the lungs by metastatic disease is redemonstrated but no interval development of new consolidations seen .',
#  'left ij central venous line terminates in the upper right atrium and may pull back NUMBER for standard positioning at cavoatrial junction improved right lower lobe consolidation .',
#  'moderate pulmonary vascular congestion and minimal edema .',
#  'right upper lobe consolidation , pulmonary vascular congestion and mild edema .',
#  'pulmonary vascular congestion is accompanied by minimal interstitial edema and a small right pleural effusion .',
#  'in comparison to previous radiograph of NUMBER days earlier , pulmonary vascular congestion persists , but mild edemahas resolved in the interval .',
#  'there is substantial interval improvement in pulmonary edema with only minimal vascular and interstitial congestion currently seen .',
#  'mild interstitial pulmonary edema superimposed on a background of chronic interstitial lung disease with evidence of severe emphysema and fibrosis .',
#  'lower lung volumes with stable mild pulmonary edema and left lower lobe collapse .',
#  'probable slight increase in chf findings .',
#  'lung volumes are quite low , but nevertheless increasing opacification in the lungs , more readily seen on the right , is probably due to pulmonary edema .',
#  'pulmonary vascular engorgement with minimal interstitial edema .',
#  'in comparison to xxxx radiograph , pulmonary vascular congestion and mild edema are new , with accompanying small right pleural effusion .',
#  'ap chest reviewed in the absence of prior chest radiographs heart is moderately enlarged , and pulmonary vasculature is engorged , but edema , if present , is minimal .',
#  'findings indicating early congestive heart failure .',
#  'there is again a large right pleural effusion with compressive basilar atelectasis as well as volume loss in the left lower lobe with smaller effusion .',
#  'diffuse opacification and volume loss of the right lung is likely due to a combination of post surgical changes , the known hilar mass , and possible worsening atelectasis .',
#  'there are bilateral small to moderate effusions with underlying collapse and / or consolidation .',
#  'bilateral perihilar vascular enlargement is noted as well as bibasal consolidation that appear to be new and might reflect atelectasis due to termination of mechanical ventilation .',
#  'except for persistent right lower lobe opacity , concerning for atelectasis or infectious process note is made that the right pigtail catheter is outside of the chest wall , finding which is new as compared to xxxx but in retrospect can be seen on the study from .',
#  'mild cardiomegaly with small left pleural effusion with underlying collapse and / or consolidation .',
#  'new ett is seen with tip in the right mainstem bronchus with probable diffuse atelectasis of the left lung .',
#  'bibasilar opacities likely secondary to atelectasis in the setting of low lung volumes .',
#  'heart size and mediastinum are unchanged as well as mild vascular congestion / minimal interstitial edema .',
#  'mild upper zone redistribution pattern suggests the possibility of some mild degree of chf .',
#  'these findings are consistent with heart failure .',
#  'cardiac silhouette is stable and there is again some elevation of pulmonary venous pressure .',
#  'marked interval worsening of chf findings .',
#  'mild congestive heart failure with small to moderate sized bilateral pleural effusions , right greater than left .',
#  'probable slight worsening of chf findings .',
#  'overall findings suggest chronic congestive heart failure , recently improved , and basal pneumonia at least in the right lower lobe , also improving .',
#  'findings suggestive of early congestive heart failure .',
#  'moderate congestive heart failure with moderate pulmonary edema and moderate size bilateral pleural effusions .',
#  'chain sutures and multiple surgical clips overlying stable postop mediastinal and cardiac contours .',
#  'allowing for slightly low volumes , doubt overt chf .',
#  'moderate congestive heart failure with moderate size right and trace left pleural effusions .',
#  'heart size and mediastinum are stable in appearance including prominence of the main pulmonary artery , most likely related to pulmonary hypertension .',
#  'mild congestive heart failure with possible trace bilateral pleural effusions .',
#  'heart size and mediastinum are unchanged but there is interval development of vascular enlargement in interstitial opacities consistent with interval development of pulmonary edema .',
#  'heart size is not clearly identifiable because of the high positioned diaphragms but probably unchanged in comparison with the previous study three days ago .',
#  'heart size is obscured by the elevated diaphragm , but azygos vein is mildly distended suggesting elevated central venous pressure or volume .',
#  'the overall impression is that of mild chf .',
#  'heart size and mediastinum are stable in appearance including tortuous descending aorta .',
#  'heart size and mediastinum are stable including the post sternotomy wires .',
#  'findings suggestive of decompensated congestive heart failure .',
#  'there is upper zone redistribution , but given low lung volumes , i doubt overt chf .',
#  'findings consistent with mild congestive heart failure but no frank pulmonary edema is seen .',
#  'there is mild upper zone re distribution , though i doubt other evidence of chf .',
#  'no substantial change in the enlargement of the cardiac silhouette with pulmonary vascular congestion and bilateral pleural effusions .',
#  'while this could represent an atypical distribution of chf , including changes associated with valve dysfunction , in the appropriate clinical setting , the upper lobe predominance would also raise the question of infectious or inflammatory etiologies .',
#  'new radiographic findings which could reflect an asymmetrical pattern of congestive heart failure superimposed upon chronic emphysema .',
#  'as compared to the previous radiograph , the signs indicative of chronic heart failure , notably the signs of pulmonary edema have substantially decreased in severity .',
#  'bronchial inflammation or , less likely , mild congestive heart failure .',
#  'leftward mediastinal shift is accordingly less pronounced , but still obscures the cardiac contours .',
#  'chf with pulmonary edema .',
#  'heart size and mediastinum are unchanged in appearance including prominence of the aortic arch .',
#  'taken together , compared with less than NUMBER hr earlier , the findings are suggestive of worsening of chf , with new or significantly increased left greater right pleural effusions and underlying bibasilar collapse and / or consolidation , particularly on the left .',
#  'heart size is obscured by lung nodules .',
#  'upper zone redistribution , doubt overt chf .',
#  'probable slight interval increase in degree of chf findings .',
#  'upper zone redistribution suggests the presence of chf .',
#  'interval improvement in chf findings .',
#  'findings suggest severe bilateral pneumonia and secondary heart failure .',
#  'in the appropriate clinical situation , this could be manifestation of acute pulmonary embolus or alternatively atypical heart failure .',
#  'chf findings and opacities at the right base are slightly improved .',
#  'mild congestive heart failure and small bilateral pleural effusions .',
#  'findings consistent with congestive heart failure but no overt pulmonary edema .',
#  'upper zone redistribution and diffuse vascular blurring is consistent with chf , also slightly worse .',
#  'this is consistent with significant congestive heart failure , though the possibility of some chronic pulmonary disease could be considered .',
#  'there are probable bilateral layering pleural effusions , relatively large on the left , with underlying collapse and / or consolidation .',
#  'there is prominence of pulmonary interstitial markings without signs for overt pulmonary edema or focal consolidation .',
#  'lung volumes remain quite low and there is greater radioopacity in the left lower lobe did atelectasis or persisting consolidation .',
#  'on the current exam , the left hemidiaphragm is less well seen , consistent with interval obscuration / increased left lower lobe collapse and / or consolidation , though the degree of opacity in the left mid zone is slightly improved .',
#  'left lower lobe is persistently airless , either due to consolidation or atelectasis .',
#  'as compared to xxxx chest radiograph , left chest tube continues to terminate at the left apex , with increased small pleural effusion and adjacent increasing left basilar atelectasis and or consolidation .',
#  'there is some coarsening of the bronchovascular markings without signs for pulmonary edema , focal consolidation or pleural effusions .',
#  'pulmonary vascular congestion has improved , severe cardiomegaly has not .',
#  'vascular congestion is mild and stable .',
#  'slight interval improvement in mild pulmonary vascular congestion , small bilateral pleural effusions , and bibasilar airspace opacities likely reflecting atelectasis .',
#  'there is minimal vascular congestion .',
#  'bilateral left greater than right effusions with pulmonary vascular congestion .',
#  'cardiac silhouette is mildly enlarged , and is accompanied by mild pulmonary vascular congestion and a small right pleural effusion with adjacent atelectasis .',
#  'there is continued pulmonary vascular congestion with hazy opacification on the left consistent with substantial layering effusion with volume loss in the left lower lobe .',
#  'moderate stable cardiomegaly center vascular congestion and upper zone redistribution .',
#  'low lung volumes and mild pulmonary vascular congestion .',
#  'in comparison with the study of xxxx , there is again substantial enlargement of the cardiac silhouette with minimal vascular prominence .',
#  'in comparison with the study of xxxx , there is continued enlargement of the cardiac silhouette with decreasing pulmonary vascular congestion .',
#  'an comparison study xxxx , there has been some improvement in the degree of bilateral opacities with enlarged cardiac silhouette , consistent with some improvement in pulmonary vascular congestion .',
#  'new small right apical pneumothorax with grossly stable right pleural effusion and worsening of pulmonary vascular congestion .',
#  'right pleural effusion , adjacent atelectasis , and mild vascular congestion are stable .',
#  'since xxxx , an increase in pulmonary vascular congestion is noted with unchanged severe cardiomegaly .',
#  'improvement in left lower lobe opacity with improvement in pulmonary vascular congestion since xxxx .',
#  'continued enlargement of the cardiac silhouette with mild indistinctness of pulmonary vessels consistent with mild elevation of pulmonary venous pressure .',
#  'cardiomediastinal contours have decreased in width , with accompanying involution of pulmonary vascular congestion .',
#  'in comparison with the study of xxxx , there is again enlargement of the cardiac silhouette , though the pulmonary vascular congestion has substantially decreased .',
#  'bibasal opacities , bilateral pleural effusion and vascular congestion are unchanged .',
#  'there is improvement in vascular congestion , widened mediastinum , and enlargement of the cardiac silhouette .',
#  'exam is otherwise remarkable for persistent cardiomegaly , new pulmonary vascular congestion , and worsening left lower lobe atelectasis with adjacent pleural effusion .',
#  'minimal indistinctness of pulmonary vessels could reflect some elevated pulmonary venous pressure or merely be a manifestation of low lung volumes .',
#  'there is persistent enlargement of the cardiac silhouette with pulmonary vascular congestion .',
#  'the differential would also include superimposed chf .',
#  'left pleural effusion is stable and there is mild vascular congestion .',
#  'although the pulmonary vessels are difficult to assess , their indistinctness and engorgement are consistent with elevated pulmonary venous pressure .',
#  'findings most consistent with mild to moderate pulmonary vascular congestion .',
#  'new moderately severe pulmonary edema obscures some of the pulmonary nodules seen on xxxx and is accompanied by additional nodules .',
#  'in comparison with the study xxxx , the pulmonary vascular congestion has substantially decreased .',
#  'low lung volumes with superimposed vascular congestion and bibasilar atelectasis .',
#  'the vascular congestion on in the left hemithorax appears less prominent .',
#  'there are bilateral effusions with compressive atelectasis at the bases and some indistinctness of pulmonary vessels suggesting elevated pulmonary venous pressure .',
#  'pulmonary vascular congestion show slight improvement , and previously evident left pleural effusion is no longer visible .',
#  'minimal indistinctness of pulmonary vessels raises the possibility of increased pulmonary venous pressure .',
#  'left lung appears to have prominent vasculature , raising concern for an element of perihilar edema or fluid overload .',
#  'mild cardiomegaly and borderline pulmonary vascular congestion unchanged .',
#  'the overlying impression is that of chf , volume loss and cannot exclude infectious infiltrate .',
#  'possible bilateral pleural effusions with pleural based thickening and / or prominent extrapleural fat .',
#  'mild pulmonary vascular congestion and possible trace left pleural effusion .',
#  'the hemidiaphragm is obscured , which could reflect substantial volume loss in the left lower lobe and possible small effusion .',
#  'upper zone redistribution and probable trace bilateral effusions , without other evidence of chf .',
#  'pulmonary vasculature is mildly engorged and there may be a tiny left pleural effusion , but i do not see pulmonary edema .',
#  'the degree of pulmonary vascular congestion has improved with continued bibasilar atelectatic changes and probable left effusion .',
#  'residual left pleural effusion and pneumothorax or small if any .',
#  'there is enlargement of the cardiac silhouette with pulmonary vascular congestion and probable bilateral effusions with compressive atelectasis at the bases .',
#  'mild blunting of the left costophrenic angle on the frontal view may be due to pleural thickening , but a trace pleural effusion is not excluded .',
#  'small amount of pleural effusion cannot be excluded in particular on the right although it might represent atelectasis due to elevated right hemidiaphragm .',
#  'possible mild increased pulmonary vascular prominence and possible tiny right pleural effusion .',
#  'increased bibasilar opacities , could reflect a combination of pleural effusion and atelectasis .',
#  'unchanged cardiomegaly and prominence of hilar vessel with , likely loculated tiny right pleural effusion versus pleural thickening along the right lateral chest wall .',
#  'numerous calcified pleural plaques are present bilaterally , suggestive of prior asbestos exposure , there are also possible small bilateral pleural effusions .',
#  'there is some volume loss , but none appreciably changed since xxxx left lung is fully expanded and right upper and middle lobes are not atelectatic .',
#  'right lung is low in volume , but there is no discrete atelectasis .',
#  'aside from mild platelike atelectasis and lower lung volumes compared to xxxx , lungs are clear .',
#  'there is vascular engorgement on the left but no appreciable atelectasis or edema .',
#  'normal postoperative appearance of the mediastinum and right lower lobe atelectasis following esophagectomy and gastric pull up .',
#  'no suspicious interval change from baseline hyperinflation with blunted costophrenic angles and in posterior pleural based mass / rounded atelectasis .',
#  'left upper lobe atelectasis has resolved following removal of the endotracheal tube which ended in the right main bronchus , but lung volumes are still quite low .',
#  'low lung volumes with minor bibasilar atelectasis but no findings to suggest acute pneumonia .',
#  'right basal consolidation which persisted following clearing of right lower lobe collapse after xxxx has subsequently improved , though not cleared .',
#  'left lung shows expected vascular engorgement , but no edema or pneumonia or collapse .',
#  'lung volumes are lower but there is no focal atelectasis .',
#  'the lung volumes continue to be low , with mild atelectatic changes at both lung bases , right more than left , and a normal sized cardiac silhouette .',
#  'interval increase in both heart size and mediastinal caliber is due to vascular engorgement , lungs are low in volume but there is no lobar collapse , edema or pneumonia .',
#  'low lung volumes , but no bibasilar atelectasis .',
#  'normal size of the heart , status post aortic valve replacement .',
#  'cardiac silhouette is within upper limits of normal in size and there is tortuosity of the descending thoracic aorta .',
#  'top normal heart size , mild pulmonary congestion without frank edema .',
#  'the heart is normal size , pulmonary vasculature is chronically engorged .',
#  'heart size top normal , exaggerated by very low lung volumes .',
#  'cardiac silhouette is normal , but new pulmonary vascular congestion and minimal interstitial edema have developed .',
#  'cardiac silhouette is at the upper limits of normal in size and there is tortuosity of the aorta .',
#  'heart size is normal , mild aortosclerosis .',
#  'there may be some mild residual elevation of pulmonary venous pressure , though the cardiac size is within normal limits .',
#  'again there is tortuosity of the aorta , though the overall cardiac size is within normal limits and there is no vascular congestion or pleural effusion .',
#  'lung volumes are low , and the heart appears top normal in size .',
#  'cardiac silhouette is at the upper limits of normal in size and there is moderate pulmonary vascular congestion that may be slightly increasing .',
#  'in comparison with the study of xxxx , there again are low lung volumes with enlargement of the cardiac silhouette but no vascular congestion or acute focal pneumonia .',
#  'heart size is top normal or slightly enlarged , but greatly exaggerated by low lung volumes .',
#  'there is a mild rightward scoliosis and a normal size of the cardiac silhouette .',
#  'there are low lung volumes cardiac size is normal .',
#  'heart size normal , though rightward mediastinal shift suggests possibility of hemodynamic tension .',
#  'cardiac silhouette is at the upper limits of normal in size or slightly enlarged , mild prominence of interstitial markings is consistent with elevation of pulmonary venous pressure .',
#  'mild overinflation , normal size of the cardiac silhouette , moderate tortuosity of the thoracic aorta without aneurysmatic dilatation .',
#  'cardiac silhouette is within normal limits and dual channel pacer wires are in good position .',
#  'cardiac silhouette is within normal limits in a patient with intact midline sternal wires .',
#  'hyperinflated lungs , but no focal consolidation seen .',
#  'no definite consolidation is identified , however , there is some mild prominence of pulmonary interstitial markings .',
#  'interval increase in lung volumes since xxxx with continued bronchovascular crowding and no pleural effusions or consolidations .',
#  'lungs are slightly low in volume but no focal airspace consolidation is seen to suggest pneumonia .',
#  'mild pulmonary vascular congestion without focal consolidation .',
#  'ap single view portable chest xray in upright position shows low lung volume without consolidation or nodules .',
#  'bronchial wall thickening without focal consolidation .',
#  'upper lungs show vascular congestion but no edema or consolidation .',
#  'extremely heavy mitral anulus calcification may account for left atrial enlargement due to regurgitation , but there is no pulmonary vascular engorgement or edema .',
#  'continued enlargement of the cardiac silhouette with tortuosity of the aorta , but no evidence of acute pneumonia or vascular congestion .',
#  'there is no consolidation to suggest pneumonia , and although pulmonary vasculature is borderline engorged , no edema or appreciable pleural effusion .',
#  'left lung clear aside from vascular congestion .',
#  'no pulmonary edema is noted , but vascular engorgement has developed in the interim .',
#  'evidence of previous cabg procedure been no vascular congestion or pleural effusion .',
#  'upper zone redistribution , but no overt chf , ? due to low lung volumes .',
#  'there continues to be some mild interstitial prominence but no overt pulmonary edema .',
#  'improved appearance of right pleural effusion with small pneumothorax no evidence of tension .',
#  'ap chest compared to xxxx no appreciable left pneumothorax or pleural effusion , pigtail pleural drainage catheter still positioned in the lateral left costal pleural space .',
#  'there is no appreciable right pleural effusion , upper thoracostomy tube in place position .',
#  'minimal emphysema without acute pneumothorax or pleural effusions .',
#  'there is no change in the widespread consolidations , pleural effusion , position of pigtail catheter .',
#  'removal of NUMBER of the NUMBER right chest tubes with no increased pleural effusion or pneumothorax .',
#  'ap and lateral chest compared to xxxx moderate cardiomegaly and generalized pulmonary vascular engorgement have worsened , but there is no pulmonary edema or appreciable pleural effusion visible on the frontal view .',
#  'in comparison with study of xxxx , there is a left pigtail catheter at the left base with clearing of the pleural effusion .']

# %%
df2 = pd.read_csv("/home/pdpino/workspace-medical-ai/report_generation/nlp-chex-gold-sentences/mimic-expert1.csv")

# %%
df2
# Out:
#                                                sentence  Atelectasis  \
# 0     band of atelectasis crossing the left hilus ha...            1
# 1     right pleural effusion with bibasilar atelecta...            1
# 2          atelectasis at both lung bases are present .            1
# 3     in addition to severe bibasilar atelectasis an...            1
# 4     increase of the pre existing retrocardiac atel...            1
# ...                                                 ...          ...
# 1147  there is no pneumothorax , appreciable pleural...           -2
# 1148  continued substantial enlargement of the cardi...           -2
# 1149  there is no vascular congestion or pleural eff...           -2
# 1150  almost complete resolution of left pleural eff...           -2
# 1151  both lungs are clear with no focal consolidati...           -2
#
#       Cardiomegaly  Consolidation  Edema  Pleural Effusion  Lung Opacity
# 0               -2             -2     -2                -2            -2
# 1               -2             -2     -2                 1            -2
# 2               -2             -2     -2                -2            -2
# 3               -2              1     -2                 1            -2
# 4               -2             -2     -2                -2            -2
# ...            ...            ...    ...               ...           ...
# 1147            -2             -2     -2                 0            -2
# 1148             1             -2     -2                 0            -2
# 1149            -2             -2     -2                 0            -2
# 1150            -2             -2     -2                 0            -2
# 1151            -2              0     -2                 0            -2
#
# [1152 rows x 7 columns]

# %%
df['Ate']

# %%
import numpy as np
np.array(['asdfasd', 'sfasdf', ])
# Out:
# array(['asdfasd', 'sfasdf', 'nan'], dtype='<U32')

# %% [markdown]
# ## Fact Embedding (BiomedVLP CXR-BERT specialized fine-tuned)

# %%
# !python ../eval_fact_embedding.py \
--evaluation_mode "mimiccxr_radiologist_annotations" \
--method "cxr-bert-specialized" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230730_012705_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)" \
--batch_size 100 \
--top_k 500 \
--save_embeddings
# Out:
# script's arguments:
#    evaluation_mode: mimiccxr_radiologist_annotations
#    method: cxr_bert
#    device: GPU
#    batch_size: 100
#    num_workers: 4
#    model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230730_012705_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)
#    top_k: 500
#    save_embeddings: True
# Explicitly passing a `revision` is encouraged when loading a configuration with custom code to ensure no malicious code has been contributed in a newer revision.
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# checkpoint_names = ['checkpoint_100_cacc+chf1+cscc+hscc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)=0.9559.pt']
# Loading model weights from /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230730_012705_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/checkpoint_100_cacc+chf1+cscc+hscc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)=0.9559.pt
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# 100%|███████████████████████████████████████████| 12/12 [00:03<00:00,  3.15it/s]
# Embeddings shape: (1165, 128)
# 100%|███████████████████████████████████████| 1165/1165 [00:37<00:00, 30.85it/s]
# Saving embeddings to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230730_012705_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/embeddings(mimiccxr_rad_annotations).pkl
# Saving mean average accuracy up to 500 to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230730_012705_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/mean_average_accuracy_up_to_500(mimiccxr_rad_annotations).pkl

# %%
# !python ../eval_fact_embedding.py \
--evaluation_mode "mimiccxr_radiologist_annotations" \
--method "cxr-bert-specialized" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230815_111024_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/" \
--batch_size 100 \
--top_k 500 \
--save_embeddings
# Out:
# script's arguments:
#    evaluation_mode: mimiccxr_radiologist_annotations
#    method: cxr-bert-specialized
#    device: GPU
#    batch_size: 100
#    num_workers: 4
#    model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230815_111024_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/
#    top_k: 500
#    save_embeddings: True
# len(sentences): 1165
# len(labels): 1165
# Explicitly passing a `revision` is encouraged when loading a configuration with custom code to ensure no malicious code has been contributed in a newer revision.
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# checkpoint_names = ['checkpoint_57_cacc+chf1+cscc+hscc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9533.pt', 'checkpoint_60_cacc+chf1+cscc+hscc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9535.pt']
# Loading model weights from /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230815_111024_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/checkpoint_60_cacc+chf1+cscc+hscc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9535.pt
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# 100%|███████████████████████████████████████████| 12/12 [00:02<00:00,  5.17it/s]
# Embeddings shape: (1165, 128)
# 100%|███████████████████████████████████████| 1165/1165 [00:12<00:00, 96.09it/s]
# Saving embeddings to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230815_111024_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/embeddings(mimiccxr_rad_annotations).pkl
# Saving metrics to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230815_111024_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/mean_average_accuracy_up_to_500(mimiccxr_rad_annotations).pkl

# %%
# !python ../eval_fact_embedding.py \
--evaluation_mode "mimiccxr_radiologist_annotations" \
--method "biovil-t" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230820_223655_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph)_FactEncoder(microsoft-BiomedVLP-BioViL-T)/" \
--batch_size 100 \
--top_k 500 \
--save_embeddings
# Out:
# script's arguments:
#    evaluation_mode: mimiccxr_radiologist_annotations
#    method: biovil-t
#    device: GPU
#    batch_size: 100
#    num_workers: 4
#    model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230820_223655_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph)_FactEncoder(microsoft-BiomedVLP-BioViL-T)/
#    top_k: 500
#    save_embeddings: True
# len(sentences): 1165
# len(labels): 1165
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# checkpoint_names = ['checkpoint_298_cacc+chf1+chf1+cscc+hscc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)=0.9518.pt', 'checkpoint_410_cacc+chf1+chf1+cscc+hscc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)=0.9546.pt']
# Loading model weights from /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230820_223655_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph)_FactEncoder(microsoft-BiomedVLP-BioViL-T)/checkpoint_410_cacc+chf1+chf1+cscc+hscc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)=0.9546.pt
# 100%|███████████████████████████████████████████| 12/12 [00:02<00:00,  5.45it/s]
# Embeddings shape: (1165, 128)
# 100%|███████████████████████████████████████| 1165/1165 [00:12<00:00, 96.06it/s]
# Saving embeddings to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230820_223655_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph)_FactEncoder(microsoft-BiomedVLP-BioViL-T)/embeddings(mimiccxr_rad_annotations).pkl
# Saving metrics to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230820_223655_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph)_FactEncoder(microsoft-BiomedVLP-BioViL-T)/mean_average_accuracy_up_to_500(mimiccxr_rad_annotations).pkl

# %%
# !python ../eval_fact_embedding.py \
--evaluation_mode "mimiccxr_radiologist_annotations" \
--method "cxr-bert-specialized" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230823_124048_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)" \
--batch_size 100 \
--top_k 500 \
--save_embeddings
# Out:
# script's arguments:
#    evaluation_mode: mimiccxr_radiologist_annotations
#    method: cxr-bert-specialized
#    device: GPU
#    batch_size: 100
#    num_workers: 4
#    model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230823_124048_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)
#    top_k: 500
#    save_embeddings: True
# len(sentences): 1165
# len(labels): 1165
# Explicitly passing a `revision` is encouraged when loading a configuration with custom code to ensure no malicious code has been contributed in a newer revision.
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# checkpoint_names = ['checkpoint_92_cacc+chf1+chf1+cscc+hscc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)=0.9587.pt', 'checkpoint_129_cacc+chf1+chf1+cscc+hscc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)=0.9601.pt']
# Loading model weights from /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230823_124048_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/checkpoint_129_cacc+chf1+chf1+cscc+hscc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)=0.9601.pt
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# 100%|███████████████████████████████████████████| 12/12 [00:02<00:00,  5.17it/s]
# Embeddings shape: (1165, 128)
# 100%|███████████████████████████████████████| 1165/1165 [00:11<00:00, 97.13it/s]
# Saving embeddings to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230823_124048_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/embeddings(mimiccxr_rad_annotations).pkl
# Saving metrics to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230823_124048_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/mean_average_accuracy_up_to_500(mimiccxr_rad_annotations).pkl

# %%
# !python ../eval_fact_embedding.py \
--evaluation_mode "mimiccxr_radiologist_annotations" \
--method "cxr-bert-specialized" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230916_194059_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)" \
--batch_size 100 \
--top_k 500 \
--save_embeddings
# Out:
# script's arguments:
#    evaluation_mode: mimiccxr_radiologist_annotations
#    method: cxr-bert-specialized
#    device: GPU
#    batch_size: 100
#    num_workers: 4
#    model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230916_194059_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)
#    top_k: 500
#    save_embeddings: True
# len(sentences): 1165
# len(labels): 1165
# Explicitly passing a `revision` is encouraged when loading a configuration with custom code to ensure no malicious code has been contributed in a newer revision.
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# checkpoint_names = ['checkpoint_81_cacc+chf1+chf1+cscc+hscc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9542.pt']
# Loading model weights from /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230916_194059_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/checkpoint_81_cacc+chf1+chf1+cscc+hscc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9542.pt
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# 100%|███████████████████████████████████████████| 12/12 [00:02<00:00,  5.08it/s]
# Embeddings shape: (1165, 128)
# 100%|███████████████████████████████████████| 1165/1165 [00:12<00:00, 97.08it/s]
# Saving embeddings to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230916_194059_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/embeddings(mimiccxr_rad_annotations).pkl
# Saving metrics to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230916_194059_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/mean_average_accuracy_up_to_500(mimiccxr_rad_annotations).pkl

# %%
# !python ../eval_fact_embedding_on_ranking.py \
--evaluation_mode "mimiccxr_radiologist_annotations" \
--method "microsoft/BiomedVLP-CXR-BERT-specialized" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230925_020631_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph,NLI)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)" \
--batch_size 100 \
--top_k 500 \
--save_embeddings
# Out:
# script's arguments:
#    evaluation_mode: mimiccxr_radiologist_annotations
#    method: microsoft/BiomedVLP-CXR-BERT-specialized
#    device: GPU
#    batch_size: 100
#    num_workers: 4
#    model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230925_020631_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph,NLI)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)
#    top_k: 500
#    save_embeddings: True
#    distance_metric: cosine
#    average_token_embeddings: False
# len(sentences): 1165
# len(labels): 1165
# checkpoint_names = ['checkpoint_38_cacc+chf1+chf1+cscc+encc+hscc+nlcc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9311.pt']
#   0%|                                                  | 0/1165 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=442,4081940466550139603).pkl
# len(self.cache["hashes"]) = 102464
# self.cache["embeddings"].shape = (102464, 128)
# 100%|█████████████████████████████████████| 1165/1165 [00:00<00:00, 5937.27it/s]
# Computing embeddings for 1165 new texts
# Explicitly passing a `revision` is encouraged when loading a configuration with custom code to ensure no malicious code has been contributed in a newer revision.
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# checkpoint_names = ['checkpoint_38_cacc+chf1+chf1+cscc+encc+hscc+nlcc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9311.pt']
# Loading model weights from /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230925_020631_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph,NLI)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/checkpoint_38_cacc+chf1+chf1+cscc+encc+hscc+nlcc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9311.pt
# Warning: model state dict has 211 keys, loaded state dict has 227 keys, intersection has 211 keys, union has 227 keys.
# Examples of keys in loaded state dict but not in model:
#   health_status_classifier.weight
#   chest_imagenome_obs_classifier.bias
#   chest_imagenome_obs_classifier.weight
#   nli_classifier.bias
#   nli_hidden_layer.weight
#   aux_task_hidden_layer.weight
#   comparison_status_classifier.bias
#   chest_imagenome_anatloc_classifier.bias
#   category_classifier.weight
#   health_status_classifier.bias
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# 100%|███████████████████████████████████████████| 12/12 [00:02<00:00,  5.05it/s]
# Saving updated cache to /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=442,4081940466550139603).pkl
# 100%|███████████████████████████████████| 1165/1165 [00:00<00:00, 297441.21it/s]
# Embeddings shape: (1165, 128)
# 100%|███████████████████████████████████████| 1165/1165 [00:20<00:00, 55.89it/s]
# Saving embeddings to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230925_020631_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph,NLI)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/embeddings(mimiccxr_rad_annotations).pkl
# Saving metrics to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230925_020631_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph,NLI)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/mean_average_accuracy_up_to_500(mimiccxr_rad_annotations,cosine).pkl

# %% [markdown]
# ## BiomedVLP CXR-BERT specialized

# %%
# !python ../eval_fact_embedding.py \
--evaluation_mode "mimiccxr_radiologist_annotations" \
--method "cxr-bert-specialized" \
--batch_size 100 \
--top_k 500 \
--save_embeddings
# Out:
# script's arguments:
#    evaluation_mode: mimiccxr_radiologist_annotations
#    method: cxr-bert-specialized
#    device: GPU
#    batch_size: 100
#    num_workers: 4
#    model_checkpoint_folder_path: None
#    top_k: 500
#    save_embeddings: True
# Explicitly passing a `revision` is encouraged when loading a configuration with custom code to ensure no malicious code has been contributed in a newer revision.
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# 100%|███████████████████████████████████████████| 12/12 [00:03<00:00,  3.98it/s]
# Embeddings shape: (1165, 128)
# 100%|██████████████████████████████████████| 1165/1165 [00:11<00:00, 100.04it/s]
# Saving embeddings to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230803_152109_mimiccxr_rad_annotations_cxr-bert-specialized/embeddings(mimiccxr_rad_annotations).pkl
# Saving mean average accuracy up to 500 to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230803_152109_mimiccxr_rad_annotations_cxr-bert-specialized/mean_average_accuracy_up_to_500(mimiccxr_rad_annotations).pkl

# %% [markdown]
# ## BiomedVLP-BioViL-T

# %%
# !python ../eval_fact_embedding.py \
--evaluation_mode "mimiccxr_radiologist_annotations" \
--method "biovil-t" \
--batch_size 100 \
--top_k 500 \
--save_embeddings
# Out:
# script's arguments:
#    evaluation_mode: mimiccxr_radiologist_annotations
#    method: biovil-t
#    device: GPU
#    batch_size: 100
#    num_workers: 4
#    model_checkpoint_folder_path: None
#    top_k: 500
#    save_embeddings: True
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# 100%|███████████████████████████████████████████| 12/12 [00:01<00:00,  6.09it/s]
# Embeddings shape: (1165, 128)
# 100%|███████████████████████████████████████| 1165/1165 [00:12<00:00, 96.54it/s]
# Saving embeddings to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230803_152228_mimiccxr_rad_annotations_biovil-t/embeddings(mimiccxr_rad_annotations).pkl
# Saving mean average accuracy up to 500 to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230803_152228_mimiccxr_rad_annotations_biovil-t/mean_average_accuracy_up_to_500(mimiccxr_rad_annotations).pkl

# %% [markdown]
# ## BioLinkBERT-large

# %%
# !python ../eval_fact_embedding_on_ranking.py \
--evaluation_mode "mimiccxr_radiologist_annotations" \
--method "BioLinkBERT-large" \
--batch_size 100 \
--top_k 500 \
--distance_metric "euclidean" \
--save_embeddings
# Out:
# script's arguments:
#    evaluation_mode: mimiccxr_radiologist_annotations
#    method: BioLinkBERT-large
#    device: GPU
#    batch_size: 100
#    num_workers: 4
#    model_checkpoint_folder_path: None
#    top_k: 500
#    save_embeddings: True
#    distance_metric: euclidean
# len(sentences): 1165
# len(labels): 1165
#   0%|                                                  | 0/1165 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=93,2426007785506037214).pkl
# len(self.cache["hashes"]) = 1165
# self.cache["embeddings"].shape = (1165, 1024)
# 100%|███████████████████████████████████| 1165/1165 [00:00<00:00, 180255.43it/s]
# Embeddings shape: (1165, 1024)
# 100%|██████████████████████████████████████| 1165/1165 [00:08<00:00, 135.34it/s]
# Saving embeddings to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230919_144634_mimiccxr_rad_annotations_BioLinkBERT-large/embeddings(mimiccxr_rad_annotations).pkl
# Saving metrics to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230919_144634_mimiccxr_rad_annotations_BioLinkBERT-large/mean_average_accuracy_up_to_500(mimiccxr_rad_annotations,euclidean).pkl

# %%
# !python ../eval_fact_embedding_on_ranking.py \
--evaluation_mode "mimiccxr_radiologist_annotations" \
--method "BioLinkBERT-large" \
--batch_size 100 \
--top_k 500 \
--distance_metric "cosine" \
--save_embeddings
# Out:
# script's arguments:
#    evaluation_mode: mimiccxr_radiologist_annotations
#    method: BioLinkBERT-large
#    device: GPU
#    batch_size: 100
#    num_workers: 4
#    model_checkpoint_folder_path: None
#    top_k: 500
#    save_embeddings: True
#    distance_metric: cosine
# len(sentences): 1165
# len(labels): 1165
#   0%|                                                  | 0/1165 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=93,2426007785506037214).pkl
# len(self.cache["hashes"]) = 1165
# self.cache["embeddings"].shape = (1165, 1024)
# 100%|███████████████████████████████████| 1165/1165 [00:00<00:00, 162651.09it/s]
# Embeddings shape: (1165, 1024)
# 100%|███████████████████████████████████████| 1165/1165 [00:17<00:00, 67.73it/s]
# Saving embeddings to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230919_144838_mimiccxr_rad_annotations_BioLinkBERT-large/embeddings(mimiccxr_rad_annotations).pkl
# Saving metrics to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230919_144838_mimiccxr_rad_annotations_BioLinkBERT-large/mean_average_accuracy_up_to_500(mimiccxr_rad_annotations,cosine).pkl

# %% [markdown]
# ## BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext

# %%
# !python ../eval_fact_embedding_on_ranking.py \
--evaluation_mode "mimiccxr_radiologist_annotations" \
--method "BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext" \
--batch_size 100 \
--top_k 500 \
--distance_metric "cosine" \
--save_embeddings
# Out:
# script's arguments:
#    evaluation_mode: mimiccxr_radiologist_annotations
#    method: BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext
#    device: GPU
#    batch_size: 100
#    num_workers: 4
#    model_checkpoint_folder_path: None
#    top_k: 500
#    save_embeddings: True
#    distance_metric: cosine
# len(sentences): 1165
# len(labels): 1165
# 100%|███████████████████████████████████| 1165/1165 [00:00<00:00, 330830.34it/s]
# Computing embeddings for 1165 new texts
# Some weights of the model checkpoint at microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext were not used when initializing BertModel: ['cls.predictions.decoder.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 100%|███████████████████████████████████████████| 12/12 [00:01<00:00,  6.16it/s]
# Saving updated cache to /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=127,2153880556179949937).pkl
# 100%|███████████████████████████████████| 1165/1165 [00:00<00:00, 556596.90it/s]
# Embeddings shape: (1165, 768)
# 100%|███████████████████████████████████████| 1165/1165 [00:15<00:00, 72.93it/s]
# Saving embeddings to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230919_145149_mimiccxr_rad_annotations_BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext/embeddings(mimiccxr_rad_annotations).pkl
# Saving metrics to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230919_145149_mimiccxr_rad_annotations_BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext/mean_average_accuracy_up_to_500(mimiccxr_rad_annotations,cosine).pkl

# %% [markdown]
# ## Bio_ClinicalBERT

# %%
# !python ../eval_fact_embedding_on_ranking.py \
--evaluation_mode "mimiccxr_radiologist_annotations" \
--method "Bio_ClinicalBERT" \
--batch_size 100 \
--top_k 500 \
--distance_metric "cosine" \
--save_embeddings
# Out:
# script's arguments:
#    evaluation_mode: mimiccxr_radiologist_annotations
#    method: Bio_ClinicalBERT
#    device: GPU
#    batch_size: 100
#    num_workers: 4
#    model_checkpoint_folder_path: None
#    top_k: 500
#    save_embeddings: True
#    distance_metric: cosine
# len(sentences): 1165
# len(labels): 1165
# 100%|███████████████████████████████████| 1165/1165 [00:00<00:00, 313731.25it/s]
# Computing embeddings for 1165 new texts
# Some weights of the model checkpoint at emilyalsentzer/Bio_ClinicalBERT were not used when initializing BertModel: ['cls.predictions.transform.dense.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 100%|███████████████████████████████████████████| 12/12 [00:02<00:00,  5.60it/s]
# Saving updated cache to /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=92,1378835921707653686).pkl
# 100%|███████████████████████████████████| 1165/1165 [00:00<00:00, 671019.52it/s]
# Embeddings shape: (1165, 768)
# 100%|███████████████████████████████████████| 1165/1165 [00:16<00:00, 71.41it/s]
# Saving embeddings to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230919_145825_mimiccxr_rad_annotations_Bio_ClinicalBERT/embeddings(mimiccxr_rad_annotations).pkl
# Saving metrics to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230919_145825_mimiccxr_rad_annotations_Bio_ClinicalBERT/mean_average_accuracy_up_to_500(mimiccxr_rad_annotations,cosine).pkl

# %% [markdown]
# ## Oracle

# %%
# !python ../eval_fact_embedding.py \
--evaluation_mode "mimiccxr_radiologist_annotations" \
--method "oracle" \
--batch_size 100 \
--top_k 500 \
--save_embeddings
# Out:
# script's arguments:
#    evaluation_mode: mimiccxr_radiologist_annotations
#    method: oracle
#    device: GPU
#    batch_size: 100
#    num_workers: 4
#    model_checkpoint_folder_path: None
#    top_k: 500
#    save_embeddings: True
# 100%|███████████████████████████████████████| 1165/1165 [00:12<00:00, 94.35it/s]
# Saving labels to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230802_093204_mimiccxr_rad_annotations_oracle/labels.pkl
# Saving mean average accuracy up to 500 to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230802_093204_mimiccxr_rad_annotations_oracle/mean_average_accuracy_up_to_500(mimiccxr_rad_annotations).pkl

# %%
from importlib import reload
import medvqa

# %%
reload(medvqa.evaluation.plots)
# Out:
# <module 'medvqa.evaluation.plots' from '/home/pamessina/medvqa/medvqa/evaluation/plots.py'>

# %%
from medvqa.utils.files import load_pickle
from medvqa.evaluation.plots import plot_metric_lists

metric_paths = [
    '/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230730_012705_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/mean_average_accuracy_up_to_500(mimiccxr_rad_annotations).pkl',
    '/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230815_111024_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/mean_average_accuracy_up_to_500(mimiccxr_rad_annotations).pkl',
    '/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230820_223655_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph)_FactEncoder(microsoft-BiomedVLP-BioViL-T)/mean_average_accuracy_up_to_500(mimiccxr_rad_annotations).pkl',
    '/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230823_124048_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/mean_average_accuracy_up_to_500(mimiccxr_rad_annotations).pkl',
    '/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230916_194059_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/mean_average_accuracy_up_to_500(mimiccxr_rad_annotations).pkl',
    '/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230925_020631_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph,NLI)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/mean_average_accuracy_up_to_500(mimiccxr_rad_annotations,cosine).pkl',
    
    '/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230803_152109_mimiccxr_rad_annotations_cxr-bert-specialized/mean_average_accuracy_up_to_500(mimiccxr_rad_annotations).pkl',
    '/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230803_152228_mimiccxr_rad_annotations_biovil-t/mean_average_accuracy_up_to_500(mimiccxr_rad_annotations).pkl',
    '/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230802_093204_mimiccxr_rad_annotations_oracle/mean_average_accuracy_up_to_500(mimiccxr_rad_annotations).pkl',
#     '/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230919_131909_mimiccxr_rad_annotations_BioLinkBERT-large/mean_average_accuracy_up_to_500(mimiccxr_rad_annotations).pkl',
#     '/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230919_144634_mimiccxr_rad_annotations_BioLinkBERT-large/mean_average_accuracy_up_to_500(mimiccxr_rad_annotations,euclidean).pkl',
    '/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230919_144838_mimiccxr_rad_annotations_BioLinkBERT-large/mean_average_accuracy_up_to_500(mimiccxr_rad_annotations,cosine).pkl',
    '/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230919_145149_mimiccxr_rad_annotations_BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext/mean_average_accuracy_up_to_500(mimiccxr_rad_annotations,cosine).pkl',
    '/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230919_145825_mimiccxr_rad_annotations_Bio_ClinicalBERT/mean_average_accuracy_up_to_500(mimiccxr_rad_annotations,cosine).pkl',
]
metric_lists = [load_pickle(x) for x in metric_paths]
method_names = [
    'Fact Embedding (CXR-BERT-specialized fine-tuned)',
    'Fact Embedding (CXR-BERT-specialized fine-tuned) (+ RadGraph triplets)',
    'Fact Embedding (BioViL-T fine-tuned) (+ RadGraph triplets + Anatomy classification)',
    'Fact Embedding (CXR-BERT-specialized fine-tuned) (+ RadGraph triplets + Anatomy classification)',
    'Fact Embedding (20230916_194059)',
    'Fact Embedding (20230925_020631)',
    
    'CXR-BERT-specialized (ECCV 2022)',
    'BioViL-T (CVPR 2023)',
    'Theoretical Upper Bound',
#     'BioLinkBERT-large (dot product)',
#     'BioLinkBERT-large (euclidean)',
    'BioLinkBERT-large (cosine)',
    'PubMedBERT (cosine)',
    'BioClinicalBERT (cosine)',
]
plot_metric_lists(
    metric_lists=metric_lists,
    method_names=method_names,
    title="Mean Average Ranking Accuracy @ K (MIMIC-CXR, 2 Radiologist Annotators, 1165 sentences)",
    metric_name='Mean Average Ranking Accuracy @ K',
    xlabel="K",
    figsize=(10, 5),
)

# %%
from medvqa.utils.files import load_pickle
from medvqa.evaluation.plots import plot_metric_lists

metric_paths = [
#     '/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230730_012705_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/mean_average_accuracy_up_to_500(mimiccxr_rad_annotations).pkl',
#     '/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230815_111024_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/mean_average_accuracy_up_to_500(mimiccxr_rad_annotations).pkl',
#     '/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230820_223655_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph)_FactEncoder(microsoft-BiomedVLP-BioViL-T)/mean_average_accuracy_up_to_500(mimiccxr_rad_annotations).pkl',
    '/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230823_124048_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/mean_average_accuracy_up_to_500(mimiccxr_rad_annotations).pkl',
    '/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230916_194059_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/mean_average_accuracy_up_to_500(mimiccxr_rad_annotations).pkl',
    '/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230803_152109_mimiccxr_rad_annotations_cxr-bert-specialized/mean_average_accuracy_up_to_500(mimiccxr_rad_annotations).pkl',
    '/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230803_152228_mimiccxr_rad_annotations_biovil-t/mean_average_accuracy_up_to_500(mimiccxr_rad_annotations).pkl',
    '/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230802_093204_mimiccxr_rad_annotations_oracle/mean_average_accuracy_up_to_500(mimiccxr_rad_annotations).pkl',
#     '/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230919_131909_mimiccxr_rad_annotations_BioLinkBERT-large/mean_average_accuracy_up_to_500(mimiccxr_rad_annotations).pkl',
#     '/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230919_144634_mimiccxr_rad_annotations_BioLinkBERT-large/mean_average_accuracy_up_to_500(mimiccxr_rad_annotations,euclidean).pkl',
    '/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230919_144838_mimiccxr_rad_annotations_BioLinkBERT-large/mean_average_accuracy_up_to_500(mimiccxr_rad_annotations,cosine).pkl',
    '/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230919_145149_mimiccxr_rad_annotations_BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext/mean_average_accuracy_up_to_500(mimiccxr_rad_annotations,cosine).pkl',
    '/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230919_145825_mimiccxr_rad_annotations_Bio_ClinicalBERT/mean_average_accuracy_up_to_500(mimiccxr_rad_annotations,cosine).pkl',
]
metric_lists = [load_pickle(x) for x in metric_paths]
method_names = [
#     'Fact Embedding (CXR-BERT-specialized fine-tuned)',
#     'Fact Embedding (CXR-BERT-specialized fine-tuned) (+ RadGraph triplets)',
#     'Fact Embedding (BioViL-T fine-tuned) (+ RadGraph triplets + Anatomy classification)',
    'CXR Fact Embedding (w/o ChatGPT hard triplets)', # 'Fact Embedding (CXR-BERT-specialized fine-tuned) (+ RadGraph triplets + Anatomy classification)',
    'CXR Fact Embedding (with ChatGPT hard triplets)', # 'CXR Fact Embedding (20230916_194059)',
    'CXR-BERT-specialized (ECCV 2022)',
    'BioViL-T (CVPR 2023)',
    'Theoretical Upper Bound',
#     'BioLinkBERT-large (dot product)',
#     'BioLinkBERT-large (euclidean)',
    'BioLinkBERT-large (ACL 2022)',
    'BioClinicalBERT (NAACL 2019)',
    'PubMedBERT (ACM trans. comput. healthc. 2020)',
]
plot_metric_lists(
    metric_lists=metric_lists,
    method_names=method_names,
    title="Mean Average Ranking Accuracy @ K (MIMIC-CXR, 2 Radiologist Annotators, 1165 sentences)",
    metric_name='Mean Average Ranking Accuracy @ K',
    xlabel="K",
    figsize=(10, 8),
)

# %%
tmp = load_pickle('/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230730_012705_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/embeddings.pkl')

# %%
from medvqa.utils.logging import print_bold
import numpy as np
import random
from medvqa.utils.math import rank_vectors_by_dot_product
from medvqa.utils.metrics import jaccard_between_dicts

def rank_sentences(embeddings_list, method_names, labels, metric='acc', top_k=20, qi=None):
    assert len(embeddings_list) == len(method_names)
    assert metric in ('acc', 'jaccard')
    n = len(embeddings_list[0]['sentences'])
    if qi is None:
        qi = random.randint(0, n-1)
    print('qi =', qi)
    for i, tmp in enumerate(embeddings_list):
        print('-------------')
        print(method_names[i])
        q = tmp['sentences'][qi]
        print_bold("Query:", q)
        if 'embeddings' in tmp:
            idxs = rank_vectors_by_dot_product(tmp['embeddings'], tmp['embeddings'][qi])
        else:
            if metric == 'acc':
                idxs = np.argsort(np.mean(tmp['labels'] == tmp['labels'][qi], axis=1))[::-1]
            elif metric == 'jaccard':
                idxs = np.argsort([jaccard_between_dicts(tmp['labels'][j], tmp['labels'][qi]) for j in range(n)])[::-1]
            else: assert False
        for j in range(top_k):            
            print('****', tmp['sentences'][idxs[j]])
            if metric == 'acc':
                print(f'Acc: {np.mean(labels[qi] == labels[idxs[j]]):.2f}')
            elif metric == 'jaccard':
                print(f'Jaccard: {jaccard_between_dicts(labels[qi], labels[idxs[j]]):.2f}')
            else: assert False

# %%
embeddings_list = [
    load_pickle('/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230802_092426_mimiccxr_rad_annotations_cxr_bert/embeddings(mimiccxr_rad_annotations).pkl'),
    load_pickle('/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230730_012705_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/embeddings(mimiccxr_rad_annotations).pkl'),
    load_pickle('/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230802_093204_mimiccxr_rad_annotations_oracle/labels.pkl'),
]
method_names = [
    'CXR-BERT',
    'Fact Embedding (CXR-BERT fine-tuned)',
    'Theoretical Upper Bound',
]

# %%
rank_sentences(embeddings_list, method_names, embeddings_list[-1]['labels'])
# Out:
# qi = 329
# -------------
# CXR-BERT
# Query: there is also vascular enlargement , consistent with pulmonary edema .
# **** there is also vascular enlargement , consistent with pulmonary edema .
# Acc: 1.00
# **** cardiomediastinal silhouette is unchanged , but there is interval progression of interstitial pulmonary edema .
# Acc: 0.79
# **** cardiac silhouette is at the upper limits of normal in size and there is moderate pulmonary vascular congestion that may be slightly increasing .
# Acc: 0.64
# **** overall , the findings are suggesting mild to moderate pulmonary edema .
# Acc: 0.86
# **** chf with pulmonary edema .
# Acc: 0.93
# **** heart size and mediastinum are unchanged but there is interval development of vascular enlargement in interstitial opacities consistent with interval development of pulmonary edema .
# Acc: 0.71
# **** marked cardiomegaly is accompanied by development of bilateral perihilar airspace opacities suggestive of pulmonary edema .
# Acc: 0.57
# **** bilateral increased interstitial opacities concerning for worsening mild pulmonary edema .
# Acc: 0.79
# **** moderate pulmonary edema with moderate cardiomegaly .
# Acc: 0.79
# **** upper zone redistribution and diffuse vascular blurring is consistent with chf , also slightly worse .
# Acc: 0.79
# **** right perihilar and left basilar opacities may reflect pulmonary edema .
# Acc: 0.71
# **** heart size and mediastinum are unchanged but there is interval progression of pulmonary edema .
# Acc: 0.79
# **** moderate pulmonary edema and severe cardiomegaly .
# Acc: 0.79
# **** lung volumes remain low , there is mild cardiomegaly and mild to moderate pulmonary edema .
# Acc: 0.79
# **** moderate pulmonary edema appears slightly improved since the xxxx examination .
# Acc: 0.93
# **** findings suggests mild pulmonary edema , however , superimposed infection is difficult to exclude .
# Acc: 0.79
# **** in comparison to xxxx radiograph , pulmonary vascular congestion and mild edema are new , with accompanying small right pleural effusion .
# Acc: 0.79
# **** otherwise , little change in the cardiomegaly with pulmonary edema .
# Acc: 0.79
# **** an comparison study xxxx , there has been some improvement in the degree of bilateral opacities with enlarged cardiac silhouette , consistent with some improvement in pulmonary vascular congestion .
# Acc: 0.50
# **** moderate interstitial edema and cardiomegaly .
# Acc: 0.79
# -------------
# Fact Embedding (CXR-BERT fine-tuned)
# Query: there is also vascular enlargement , consistent with pulmonary edema .
# **** there is also vascular enlargement , consistent with pulmonary edema .
# Acc: 1.00
# **** heart size and mediastinum are unchanged as well as mild vascular congestion / minimal interstitial edema .
# Acc: 0.71
# **** although the pulmonary vessels are difficult to assess , their indistinctness and engorgement are consistent with elevated pulmonary venous pressure .
# Acc: 0.79
# **** there is substantial interval improvement in pulmonary edema with only minimal vascular and interstitial congestion currently seen .
# Acc: 0.93
# **** moderate pulmonary vascular congestion and minimal edema .
# Acc: 0.93
# **** pulmonary vascular engorgement with minimal interstitial edema .
# Acc: 0.93
# **** ap chest reviewed in the absence of prior chest radiographs heart is moderately enlarged , and pulmonary vasculature is engorged , but edema , if present , is minimal .
# Acc: 0.57
# **** cardiomegaly is accompanied by pulmonary vascular congestion and mild edema .
# Acc: 0.86
# **** cardiomegaly unchanged with mild pulmonary congestion , new from prior .
# Acc: 0.64
# **** cardiac silhouette is mildly enlarged , and accompanied by pulmonary vascular congestion and minimal interstitial edema .
# Acc: 0.79
# **** previous interstitial edema has improved .
# Acc: 0.93
# **** ap chest radiograph as compared to the prior study obtained the same day earlier , there is interval progression of interstitial opacities in the right hemithorax , that potentially may reflect asymmetric edema .
# Acc: 0.64
# **** cardiomediastinal silhouette is unchanged , but there is interval progression of interstitial pulmonary edema .
# Acc: 0.79
# **** pulmonary vascular congestion is accompanied by minimal interstitial edema and a small right pleural effusion .
# Acc: 0.79
# **** bilateral increased interstitial opacities concerning for worsening mild pulmonary edema .
# Acc: 0.79
# **** minimal interstitial pulmonary edema remains .
# Acc: 0.93
# **** in comparison to xxxx radiograph , pulmonary vascular congestion and mild edema are new , with accompanying small right pleural effusion .
# Acc: 0.79
# **** bilateral perihilar opacities are worrisome for pulmonary edema .
# Acc: 0.71
# **** heart size and mediastinum are unchanged but there is interval development of vascular enlargement in interstitial opacities consistent with interval development of pulmonary edema .
# Acc: 0.71
# **** increased bilateral hazy opacities diffusely raises the concern for pulmonary edema .
# Acc: 0.71
# -------------
# Theoretical Upper Bound
# Query: there is also vascular enlargement , consistent with pulmonary edema .
# **** there is also vascular enlargement , consistent with pulmonary edema .
# Acc: 1.00
# **** the appearance is compatible with chf and pulmonary edema .
# Acc: 1.00
# **** slight improvement in the pulmonary edema .
# Acc: 0.93
# **** as compared to the previous radiograph , the signs indicative of pulmonary edema have decreased in severity and extent .
# Acc: 0.93
# **** moderate pulmonary vascular congestion and minimal edema .
# Acc: 0.93
# **** there is substantial interval improvement in pulmonary edema with only minimal vascular and interstitial congestion currently seen .
# Acc: 0.93
# **** moderate pulmonary edema is minimally improved .
# Acc: 0.93
# **** pulmonary vascular engorgement with minimal interstitial edema .
# Acc: 0.93
# **** since a recent radiograph of NUMBER day earlier , an asymmetrical pattern of pulmonary edema has substantially improved .
# Acc: 0.93
# **** minimal interstitial pulmonary edema remains .
# Acc: 0.93
# **** previous interstitial edema has improved .
# Acc: 0.93
# **** chf with pulmonary edema .
# Acc: 0.93
# **** interval improvement of pulmonary edema since xxxx .
# Acc: 0.93
# **** mild pulmonary edema has slightly improved and remains mild .
# Acc: 0.93
# **** interval improvement in chf / interstitial edema .
# Acc: 0.93
# **** moderate pulmonary edema has increased .
# Acc: 0.93
# **** moderate pulmonary edema , slightly increased .
# Acc: 0.93
# **** mild interstitial pulmonary edema superimposed on a background of chronic interstitial lung disease with evidence of severe emphysema and fibrosis .
# Acc: 0.93
# **** there is moderate pulmonary edema which has worsened slightly .
# Acc: 0.93
# **** mild pulmonary edema has decreased .
# Acc: 0.93

# %%
# !python ../eval_fact_embedding.py \
--evaluation_mode "iuxray_chexpert_labeler" \
--method "cxr-bert-specialized" \
--batch_size 100 \
--top_k 500 \
--save_embeddings
# Out:
# script's arguments:
#    evaluation_mode: iuxray_chexpert_labeler
#    method: cxr-bert-specialized
#    device: GPU
#    batch_size: 100
#    num_workers: 4
#    model_checkpoint_folder_path: None
#    top_k: 500
#    save_embeddings: True
# Loading iuxray sentences and chexpert labels from /mnt/data/pamessina/workspaces/medvqa-workspace/cache/iuxray_sentences_and_chexpert_labels.pkl
# Explicitly passing a `revision` is encouraged when loading a configuration with custom code to ensure no malicious code has been contributed in a newer revision.
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# 100%|███████████████████████████████████████████| 87/87 [00:03<00:00, 23.85it/s]
# Embeddings shape: (8617, 128)
# 100%|███████████████████████████████████████| 8617/8617 [01:51<00:00, 77.00it/s]
# Saving embeddings to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230803_153021_iuxray_chexpert_labeler_cxr-bert-specialized/embeddings(iuxray_chexpert_labeler).pkl
# Saving mean average accuracy up to 500 to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230803_153021_iuxray_chexpert_labeler_cxr-bert-specialized/mean_average_accuracy_up_to_500(iuxray_chexpert_labeler).pkl

# %%
# !python ../eval_fact_embedding.py \
--evaluation_mode "iuxray_chexpert_labeler" \
--method "biovil-t" \
--batch_size 100 \
--top_k 500 \
--save_embeddings
# Out:
# script's arguments:
#    evaluation_mode: iuxray_chexpert_labeler
#    method: biovil-t
#    device: GPU
#    batch_size: 100
#    num_workers: 4
#    model_checkpoint_folder_path: None
#    top_k: 500
#    save_embeddings: True
# Loading iuxray sentences and chexpert labels from /mnt/data/pamessina/workspaces/medvqa-workspace/cache/iuxray_sentences_and_chexpert_labels.pkl
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# 100%|███████████████████████████████████████████| 87/87 [00:03<00:00, 24.23it/s]
# Embeddings shape: (8617, 128)
# 100%|███████████████████████████████████████| 8617/8617 [01:46<00:00, 80.96it/s]
# Saving embeddings to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230803_153222_iuxray_chexpert_labeler_biovil-t/embeddings(iuxray_chexpert_labeler).pkl
# Saving mean average accuracy up to 500 to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230803_153222_iuxray_chexpert_labeler_biovil-t/mean_average_accuracy_up_to_500(iuxray_chexpert_labeler).pkl

# %%
# !python ../eval_fact_embedding.py \
--evaluation_mode "iuxray_chexpert_labeler" \
--method "cxr-bert-specialized" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230730_012705_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)" \
--batch_size 100 \
--top_k 500 \
--save_embeddings
# Out:
# script's arguments:
#    evaluation_mode: iuxray_chexpert_labeler
#    method: cxr_bert
#    device: GPU
#    batch_size: 100
#    num_workers: 4
#    model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230730_012705_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)
#    top_k: 500
#    save_embeddings: True
# Loading iuxray sentences and chexpert labels from /mnt/data/pamessina/workspaces/medvqa-workspace/cache/iuxray_sentences_and_chexpert_labels.pkl
# Explicitly passing a `revision` is encouraged when loading a configuration with custom code to ensure no malicious code has been contributed in a newer revision.
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# checkpoint_names = ['checkpoint_100_cacc+chf1+cscc+hscc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)=0.9559.pt']
# Loading model weights from /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230730_012705_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/checkpoint_100_cacc+chf1+cscc+hscc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)=0.9559.pt
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# 100%|███████████████████████████████████████████| 87/87 [00:03<00:00, 22.91it/s]
# Embeddings shape: (8617, 128)
# 100%|███████████████████████████████████████| 8617/8617 [01:54<00:00, 75.40it/s]
# Saving embeddings to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230730_012705_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/embeddings(iuxray_chexpert_labeler).pkl
# Saving mean average accuracy up to 500 to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230730_012705_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/mean_average_accuracy_up_to_500(iuxray_chexpert_labeler).pkl

# %%
# !python ../eval_fact_embedding.py \
--evaluation_mode "iuxray_chexpert_labeler" \
--method "cxr-bert-specialized" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230815_111024_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/" \
--batch_size 100 \
--top_k 500 \
--save_embeddings
# Out:
# script's arguments:
#    evaluation_mode: iuxray_chexpert_labeler
#    method: cxr-bert-specialized
#    device: GPU
#    batch_size: 100
#    num_workers: 4
#    model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230815_111024_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/
#    top_k: 500
#    save_embeddings: True
# Loading iuxray sentences and chexpert labels from /mnt/data/pamessina/workspaces/medvqa-workspace/cache/iuxray_sentences_and_chexpert_labels.pkl
# len(sentences): 8617
# len(labels): 8617
# Explicitly passing a `revision` is encouraged when loading a configuration with custom code to ensure no malicious code has been contributed in a newer revision.
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# checkpoint_names = ['checkpoint_57_cacc+chf1+cscc+hscc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9533.pt', 'checkpoint_60_cacc+chf1+cscc+hscc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9535.pt']
# Loading model weights from /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230815_111024_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/checkpoint_60_cacc+chf1+cscc+hscc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9535.pt
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# 100%|███████████████████████████████████████████| 87/87 [00:03<00:00, 22.81it/s]
# Embeddings shape: (8617, 128)
# 100%|███████████████████████████████████████| 8617/8617 [01:44<00:00, 82.23it/s]
# Saving embeddings to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230815_111024_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/embeddings(iuxray_chexpert_labeler).pkl
# Saving metrics to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230815_111024_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/mean_average_accuracy_up_to_500(iuxray_chexpert_labeler).pkl

# %%
# !python ../eval_fact_embedding.py \
--evaluation_mode "iuxray_chexpert_labeler" \
--method "biovil-t" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230820_223655_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph)_FactEncoder(microsoft-BiomedVLP-BioViL-T)/" \
--batch_size 100 \
--top_k 500 \
--save_embeddings
# Out:
# script's arguments:
#    evaluation_mode: iuxray_chexpert_labeler
#    method: biovil-t
#    device: GPU
#    batch_size: 32
#    num_workers: 4
#    model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230820_223655_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph)_FactEncoder(microsoft-BiomedVLP-BioViL-T)/
#    top_k: 500
#    save_embeddings: True
# Loading iuxray sentences and chexpert labels from /mnt/data/pamessina/workspaces/medvqa-workspace/cache/iuxray_sentences_and_chexpert_labels.pkl
# len(sentences): 8617
# len(labels): 8617
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# checkpoint_names = ['checkpoint_298_cacc+chf1+chf1+cscc+hscc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)=0.9518.pt', 'checkpoint_410_cacc+chf1+chf1+cscc+hscc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)=0.9546.pt']
# Loading model weights from /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230820_223655_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph)_FactEncoder(microsoft-BiomedVLP-BioViL-T)/checkpoint_410_cacc+chf1+chf1+cscc+hscc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)=0.9546.pt
# 100%|█████████████████████████████████████████| 270/270 [00:04<00:00, 54.37it/s]
# Embeddings shape: (8617, 128)
# 100%|███████████████████████████████████████| 8617/8617 [01:40<00:00, 85.95it/s]
# Saving embeddings to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230820_223655_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph)_FactEncoder(microsoft-BiomedVLP-BioViL-T)/embeddings(iuxray_chexpert_labeler).pkl
# Saving metrics to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230820_223655_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph)_FactEncoder(microsoft-BiomedVLP-BioViL-T)/mean_average_accuracy_up_to_500(iuxray_chexpert_labeler).pkl

# %%
# !python ../eval_fact_embedding.py \
--evaluation_mode "iuxray_chexpert_labeler" \
--method "cxr-bert-specialized" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230823_124048_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)" \
--batch_size 100 \
--top_k 500 \
--save_embeddings
# Out:
# script's arguments:
#    evaluation_mode: iuxray_chexpert_labeler
#    method: cxr-bert-specialized
#    device: GPU
#    batch_size: 100
#    num_workers: 4
#    model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230823_124048_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)
#    top_k: 500
#    save_embeddings: True
# Loading iuxray sentences and chexpert labels from /mnt/data/pamessina/workspaces/medvqa-workspace/cache/iuxray_sentences_and_chexpert_labels.pkl
# len(sentences): 8617
# len(labels): 8617
# Explicitly passing a `revision` is encouraged when loading a configuration with custom code to ensure no malicious code has been contributed in a newer revision.
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# checkpoint_names = ['checkpoint_92_cacc+chf1+chf1+cscc+hscc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)=0.9587.pt', 'checkpoint_129_cacc+chf1+chf1+cscc+hscc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)=0.9601.pt']
# Loading model weights from /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230823_124048_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/checkpoint_129_cacc+chf1+chf1+cscc+hscc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)=0.9601.pt
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# 100%|███████████████████████████████████████████| 87/87 [00:03<00:00, 23.39it/s]
# Embeddings shape: (8617, 128)
# 100%|███████████████████████████████████████| 8617/8617 [01:39<00:00, 86.17it/s]
# WARNING: embeddings save path /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230823_124048_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/embeddings(iuxray_chexpert_labeler).pkl already exists. Skipping.
# Saving metrics to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230823_124048_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/mean_average_accuracy_up_to_500(iuxray_chexpert_labeler).pkl

# %%
# !python ../eval_fact_embedding.py \
--evaluation_mode "iuxray_chexpert_labeler" \
--method "cxr-bert-specialized" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230916_194059_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/" \
--batch_size 100 \
--top_k 500 \
--save_embeddings
# Out:
# script's arguments:
#    evaluation_mode: iuxray_chexpert_labeler
#    method: cxr-bert-specialized
#    device: GPU
#    batch_size: 100
#    num_workers: 4
#    model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230916_194059_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/
#    top_k: 500
#    save_embeddings: True
# Loading iuxray sentences and chexpert labels from /mnt/data/pamessina/workspaces/medvqa-workspace/cache/iuxray_sentences_and_chexpert_labels.pkl
# len(sentences): 8617
# len(labels): 8617
# Explicitly passing a `revision` is encouraged when loading a configuration with custom code to ensure no malicious code has been contributed in a newer revision.
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# checkpoint_names = ['checkpoint_81_cacc+chf1+chf1+cscc+hscc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9542.pt']
# Loading model weights from /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230916_194059_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/checkpoint_81_cacc+chf1+chf1+cscc+hscc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9542.pt
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# 100%|███████████████████████████████████████████| 87/87 [00:03<00:00, 22.28it/s]
# Embeddings shape: (8617, 128)
# 100%|███████████████████████████████████████| 8617/8617 [01:39<00:00, 86.28it/s]
# Saving embeddings to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230916_194059_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/embeddings(iuxray_chexpert_labeler).pkl
# Saving metrics to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230916_194059_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/mean_average_accuracy_up_to_500(iuxray_chexpert_labeler).pkl

# %%
# !python ../eval_fact_embedding.py \
--evaluation_mode "iuxray_chexpert_labeler" \
--method "oracle" \
--batch_size 100 \
--top_k 500 \
--save_embeddings
# Out:
# script's arguments:
#    evaluation_mode: iuxray_chexpert_labeler
#    method: oracle
#    device: GPU
#    batch_size: 100
#    num_workers: 4
#    model_checkpoint_folder_path: None
#    top_k: 500
#    save_embeddings: True
# Loading iuxray sentences and chexpert labels from /mnt/data/pamessina/workspaces/medvqa-workspace/cache/iuxray_sentences_and_chexpert_labels.pkl
# 100%|██████████████████████████████████████| 8617/8617 [01:08<00:00, 125.80it/s]
# Saving labels to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230801_222333_iuxray_chexpert_labeler_oracle/labels.pkl
# Saving mean average accuracy up to 500 to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230801_222333_iuxray_chexpert_labeler_oracle/mean_average_accuracy_up_to_500(iuxray_chexpert_labeler).pkl

# %%
from medvqa.utils.files import load_pickle
from medvqa.evaluation.plots import plot_metric_lists

metric_paths = [
    '/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230730_012705_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/mean_average_accuracy_up_to_500(iuxray_chexpert_labeler).pkl',
    '/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230815_111024_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/mean_average_accuracy_up_to_500(iuxray_chexpert_labeler).pkl',
    '/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230820_223655_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph)_FactEncoder(microsoft-BiomedVLP-BioViL-T)/mean_average_accuracy_up_to_500(iuxray_chexpert_labeler).pkl',
    '/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230823_124048_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/mean_average_accuracy_up_to_500(iuxray_chexpert_labeler).pkl',
    '/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230916_194059_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/mean_average_accuracy_up_to_500(iuxray_chexpert_labeler).pkl',
    '/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230803_153021_iuxray_chexpert_labeler_cxr-bert-specialized/mean_average_accuracy_up_to_500(iuxray_chexpert_labeler).pkl',
    '/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230803_153222_iuxray_chexpert_labeler_biovil-t/mean_average_accuracy_up_to_500(iuxray_chexpert_labeler).pkl',
    '/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230801_222333_iuxray_chexpert_labeler_oracle/mean_average_accuracy_up_to_500(iuxray_chexpert_labeler).pkl'
]
metric_lists = [load_pickle(x) for x in metric_paths]
method_names = [
    'Fact Embedding (CXR-BERT-specialized fine-tuned)',
    'Fact Embedding (CXR-BERT-specialized fine-tuned) (+ RadGraph triplets)',
    'Fact Embedding (BioViL-T fine-tuned) (+ RadGraph triplets + Anatomy classification)',
    'Fact Embedding (CXR-BERT-specialized fine-tuned) (+ RadGraph triplets + Anatomy classification)',
    'Fact Embedding (20230916_194059)',
    'CXR-BERT-specialized (ECCV 2022)',
    'BioViL-T (CVPR 2023)',
    'Theoretical Upper Bound',
]
plot_metric_lists(
    metric_lists=metric_lists,
    method_names=method_names,
    title="Mean Average Ranking Accuracy @ K (IU X-ray, CheXpert labeler, 8617 sentences)",
    metric_name='Mean Average Ranking Accuracy @ K',
    xlabel="K",
    figsize=(10, 5),
)

# %%
embeddings_list_2 = [
    load_pickle('/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230730_012705_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/embeddings(iuxray_chexpert_labeler).pkl'),
    load_pickle('/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230803_153021_iuxray_chexpert_labeler_cxr-bert-specialized/embeddings(iuxray_chexpert_labeler).pkl'),
    load_pickle('/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230803_153222_iuxray_chexpert_labeler_biovil-t/embeddings(iuxray_chexpert_labeler).pkl'),
    load_pickle('/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230801_222333_iuxray_chexpert_labeler_oracle/labels.pkl'),
]
method_names_2 = [
    'Fact Embedding (CXR-BERT-specialized fine-tuned)',
    'CXR-BERT-specialized',
    'BioViL-T',
    'Theoretical Upper Bound',
]

# %%
rank_sentences(embeddings_list_2, method_names_2, embeddings_list_2[-1]['labels'])
# Out:
# qi = 6792
# -------------
# Fact Embedding (CXR-BERT-specialized fine-tuned)
# Query: Minimal residual opacities remain which may represent small areas of scarring.
# **** Minimal residual opacities remain which may represent small areas of scarring.
# Acc: 1.00
# **** There are biapical opacities, possibly scarring.
# Acc: 1.00
# **** There are mild right apical opacities, XXXX scarring.
# Acc: 1.00
# **** Stable biapical opacities, possibly scarring.
# Acc: 1.00
# **** Streaky left basilar opacities are favored to represent scarring.
# Acc: 1.00
# **** Some continued right lung opacities are present which may represent areas of scarring.
# Acc: 1.00
# **** Biapical opacities, XXXX scarring.
# Acc: 1.00
# **** Minimal residuals from opacities remaining most XXXX represent small areas of scarring.
# Acc: 1.00
# **** Right apical opacities; the appearance XXXX scarring.
# Acc: 1.00
# **** There are XXXX biapical opacities, XXXX scarring.
# Acc: 1.00
# **** Opacity in the right lung base also appears unchanged, XXXX scarring.
# Acc: 1.00
# **** There are stable scattered XXXX bilateral opacities, most notable in the left upper lobe, XXXX scarring.
# Acc: 1.00
# **** XXXX XXXX opacities in the left lung base are compatible with scarring.
# Acc: 1.00
# **** There is minimal scarring within the left lung base.
# Acc: 1.00
# **** Strandy scarring in the left lower lobe is unchanged.
# Acc: 1.00
# **** Stable left lower lobe scarring.
# Acc: 1.00
# **** There is minimal scarring in the lung apices.
# Acc: 1.00
# **** Scattered right upper lung scarring as before.
# Acc: 1.00
# **** Stable appearance of scarring at lung bases.
# Acc: 1.00
# **** Stable right lung base scarring.
# Acc: 1.00
# -------------
# CXR-BERT-specialized
# Query: Minimal residual opacities remain which may represent small areas of scarring.
# **** Minimal residual opacities remain which may represent small areas of scarring.
# Acc: 1.00
# **** A few bandlike opacities are present on the lateral view which appear to represent small areas of scarring.
# Acc: 1.00
# **** A followup exam in 4 to 6 weeks should be considered to ensure resolution of this process.
# Acc: 0.86
# **** Correlation with prior radiographs would be helpful to identify the location of the previously described nodule.
# Acc: 0.86
# **** Healed right 10th and left 9th posterolateral rib fracture.
# Acc: 0.86
# **** There is a 1 cm nodule within one of the lung bases, seen only on the lateral view.
# Acc: 0.86
# **** This may represent resolving or developing pneumonia given the patient's history.
# Acc: 0.86
# **** Minimal residuals from opacities remaining most XXXX represent small areas of scarring.
# Acc: 1.00
# **** Based on patient's age, a followup chest x-XXXX to document resolution is recommended.
# Acc: 0.86
# **** Stable calcified mediastinal and hilar lymph XXXX and a left basilar calcified granuloma.
# Acc: 0.93
# **** Ill-defined opacity projecting over midthoracic spine on lateral view corresponding with residual mass/nodularity seen XXXX scan from XXXX.
# Acc: 0.93
# **** This may represent scarring but is incompletely evaluated on the outside study, without coronal and sagittal reformats.
# Acc: 1.00
# **** In the left lung base, there is a 9 mm nodule that not definitively calcified.
# Acc: 0.86
# **** Stable right infrahilar nodular density (lateral view).
# Acc: 0.86
# **** Another nodule is present near the right hilum.
# Acc: 0.86
# **** These are not well appreciated on the lateral projection.
# Acc: 0.86
# **** Redemonstrated are endplate depressions of the vertebral bodies, compatible with XXXX cell changes.
# Acc: 0.79
# **** Recommend followup with chest CT.
# Acc: 0.86
# **** There is corticated deformity of the right anterior 7th rib, XXXX remote fracture.
# Acc: 0.86
# **** This could represent healing fracture or superimposed structures.
# Acc: 0.86
# -------------
# BioViL-T
# Query: Minimal residual opacities remain which may represent small areas of scarring.
# **** Minimal residual opacities remain which may represent small areas of scarring.
# Acc: 1.00
# **** Minimal residuals from opacities remaining most XXXX represent small areas of scarring.
# Acc: 1.00
# **** This may represent resolving or developing pneumonia given the patient's history.
# Acc: 0.86
# **** These small nodules are relatively dense, suggestive of chronic granulomatous disease.
# Acc: 0.86
# **** Bilateral granulomas are seen scattered throughout the lungs.
# Acc: 0.93
# **** A followup exam in 4 to 6 weeks should be considered to ensure resolution of this process.
# Acc: 0.86
# **** Currently, there are only minimal streaky opacities in the bilateral midlung, which may represent mild residual airspace disease, atelectasis, or underlying changes of chronic lung disease.
# Acc: 0.93
# **** Multiple scattered calcified granulomas are present bilaterally.
# Acc: 0.93
# **** Comparison XXXX, XXXX Bilateral calcified granulomas and some left basilar XXXX scarring as before.
# Acc: 1.00
# **** Scattered calcified pulmonary nodules, XXXX represents calcified granulomas.
# Acc: 0.86
# **** Followup radiographs after appropriate therapy in 8-12 weeks are indicated to exclude an underlying abnormality.
# Acc: 0.86
# **** Scattered calcified granulomas are stable as are calcified mediastinal lymph XXXX.
# Acc: 0.93
# **** There are small round calcific densities in the bilateral lobes which are unchanged from prior exam and XXXX represent sequelae from old granulomatous disease.
# Acc: 0.93
# **** Multiple scattered small 4 mm nodules throughout the chest.
# Acc: 0.86
# **** Correlation with prior radiographs would be helpful to identify the location of the previously described nodule.
# Acc: 0.86
# **** Scattered granulomas and bilateral perihilar calcified lymph XXXX.
# Acc: 0.93
# **** Followup radiographs in 8-12 weeks after appropriate therapy are indicated to exclude an underlying abnormality.
# Acc: 0.86
# **** A followup study and 4 to 6 weeks could be considered to evaluate for resolution.
# Acc: 0.86
# **** Multiple calcified granulomas in the bilateral XXXX and lung parenchyma.
# Acc: 0.93
# **** Granulomatous sequela are noted.
# Acc: 0.93
# -------------
# Theoretical Upper Bound
# Query: Minimal residual opacities remain which may represent small areas of scarring.
# **** There is scarring in the right mid and upper lung zone with surgical clips identified as well.
# Acc: 1.00
# **** Patchy right lower lung opacification is noted.
# Acc: 1.00
# **** There is streaky airspace opacities in the left suprahilar and lingular regions.
# Acc: 1.00
# **** Patchy opacities are demonstrated in the left lung base.
# Acc: 1.00
# **** Some continued right lung opacities are present which may represent areas of scarring.
# Acc: 1.00
# **** Midline retrocardiac opacity suggestive of a small hiatal hernia.
# Acc: 1.00
# **** Small right juxtahilar opacity may represent infiltrate.
# Acc: 1.00
# **** Some prominent perihilar opacities are present.
# Acc: 1.00
# **** Subtle opacities are present within the lingula as well.
# Acc: 1.00
# **** Prominent increased interstitial markings in both lungs are unchanged in the interval.
# Acc: 1.00
# **** There is a XXXX airspace opacity in the left upper lung.
# Acc: 1.00
# **** No active airspace disease/infiltrate.
# Acc: 1.00
# **** There is increased opacity in the left upper lobe, peripherally.
# Acc: 1.00
# **** There is a small amount of scarring in the left midlung.
# Acc: 1.00
# **** Minimally increased air space opacities bilaterally, most prominent in the lung bases.
# Acc: 1.00
# **** There is a vague opacity in the right infrahilar region.
# Acc: 1.00
# **** Airspace disease in expected location of right middle lobe also noted on the lateral view to No pleural effusion.
# Acc: 1.00
# **** Crowded bronchovascular and interstitial markings XXXX related to low lung volumes and technique.
# Acc: 1.00
# **** There are chronic appearing right basilar interstitial markings.
# Acc: 1.00
# **** Mild XXXX opacities in the retrocardiac region.
# Acc: 1.00

# %%
# !python ../eval_fact_embedding.py \
--evaluation_mode "iuxray_chexbert_labeler" \
--method "cxr-bert-specialized" \
--batch_size 100 \
--top_k 500 \
--save_embeddings
# Out:
# script's arguments:
#    evaluation_mode: iuxray_chexbert_labeler
#    method: cxr-bert-specialized
#    device: GPU
#    batch_size: 100
#    num_workers: 4
#    model_checkpoint_folder_path: None
#    top_k: 500
#    save_embeddings: True
# Loading iuxray reports from /mnt/workspace/iu-x-ray/dataset/reports/reports.min.json
# Number of sentences: 8617
# Shortest sentence: KUB.
# Longest sentence: The infrahilar pulmonary markings appear slightly prominent bilaterally, which XXXX represents XXXX appearance for the patient but difficult to completely exclude some reactive airway/bronchitic changes in the absence of comparison radiographs.. No airspace consolidation or lobar atelectasis.
# Loading CheXbert labeler
# (*) Chexbert: labeling 8617 texts ...
# Chexbert: 8617 texts not found in cache, invoking chexbert labeler ...
# 100%|███████████████████████████████████████| 8617/8617 [01:36<00:00, 89.12it/s]
# Cache successfully updated and saved to /mnt/data/pamessina/workspaces/medvqa-workspace/cache/chexbert_labeler_cache.pkl
# Saving iuxray sentences and chexpert labels to /mnt/data/pamessina/workspaces/medvqa-workspace/cache/iuxray_sentences_and_chexbert_labels.pkl
# Explicitly passing a `revision` is encouraged when loading a configuration with custom code to ensure no malicious code has been contributed in a newer revision.
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# 100%|███████████████████████████████████████████| 87/87 [00:02<00:00, 31.77it/s]
# Embeddings shape: (8617, 128)
# 100%|███████████████████████████████████████| 8617/8617 [01:43<00:00, 83.09it/s]
# Saving embeddings to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230804_193515_iuxray_chexbert_labeler_cxr-bert-specialized/embeddings(iuxray_chexbert_labeler).pkl
# Saving mean average accuracy up to 500 to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230804_193515_iuxray_chexbert_labeler_cxr-bert-specialized/mean_average_accuracy_up_to_500(iuxray_chexbert_labeler).pkl

# %%
# !python ../eval_fact_embedding.py \
--evaluation_mode "iuxray_chexbert_labeler" \
--method "biovil-t" \
--batch_size 100 \
--top_k 500 \
--save_embeddings
# Out:
# script's arguments:
#    evaluation_mode: iuxray_chexbert_labeler
#    method: biovil-t
#    device: GPU
#    batch_size: 100
#    num_workers: 4
#    model_checkpoint_folder_path: None
#    top_k: 500
#    save_embeddings: True
# Loading iuxray sentences and chexbert labels from /mnt/data/pamessina/workspaces/medvqa-workspace/cache/iuxray_sentences_and_chexbert_labels.pkl
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# 100%|███████████████████████████████████████████| 87/87 [00:03<00:00, 24.32it/s]
# Embeddings shape: (8617, 128)
# 100%|███████████████████████████████████████| 8617/8617 [01:53<00:00, 76.11it/s]
# Saving embeddings to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230804_194003_iuxray_chexbert_labeler_biovil-t/embeddings(iuxray_chexbert_labeler).pkl
# Saving mean average accuracy up to 500 to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230804_194003_iuxray_chexbert_labeler_biovil-t/mean_average_accuracy_up_to_500(iuxray_chexbert_labeler).pkl

# %%
# !python ../eval_fact_embedding.py \
--evaluation_mode "iuxray_chexbert_labeler" \
--method "cxr-bert-specialized" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230730_012705_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)" \
--batch_size 100 \
--top_k 500 \
--save_embeddings
# Out:
# script's arguments:
#    evaluation_mode: iuxray_chexbert_labeler
#    method: cxr-bert-specialized
#    device: GPU
#    batch_size: 100
#    num_workers: 4
#    model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230730_012705_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)
#    top_k: 500
#    save_embeddings: True
# Loading iuxray sentences and chexbert labels from /mnt/data/pamessina/workspaces/medvqa-workspace/cache/iuxray_sentences_and_chexbert_labels.pkl
# Explicitly passing a `revision` is encouraged when loading a configuration with custom code to ensure no malicious code has been contributed in a newer revision.
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# checkpoint_names = ['checkpoint_100_cacc+chf1+cscc+hscc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)=0.9559.pt']
# Loading model weights from /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230730_012705_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/checkpoint_100_cacc+chf1+cscc+hscc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)=0.9559.pt
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# 100%|███████████████████████████████████████████| 87/87 [00:03<00:00, 22.78it/s]
# Embeddings shape: (8617, 128)
# 100%|███████████████████████████████████████| 8617/8617 [01:48<00:00, 79.65it/s]
# Saving embeddings to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230730_012705_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/embeddings(iuxray_chexbert_labeler).pkl
# Saving mean average accuracy up to 500 to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230730_012705_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/mean_average_accuracy_up_to_500(iuxray_chexbert_labeler).pkl

# %%
# !python ../eval_fact_embedding.py \
--evaluation_mode "iuxray_chexbert_labeler" \
--method "cxr-bert-specialized" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230815_111024_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/" \
--batch_size 100 \
--top_k 500 \
--save_embeddings
# Out:
# script's arguments:
#    evaluation_mode: iuxray_chexbert_labeler
#    method: cxr-bert-specialized
#    device: GPU
#    batch_size: 100
#    num_workers: 4
#    model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230815_111024_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/
#    top_k: 500
#    save_embeddings: True
# Loading iuxray sentences and chexbert labels from /mnt/data/pamessina/workspaces/medvqa-workspace/cache/iuxray_sentences_and_chexbert_labels.pkl
# len(sentences): 8617
# len(labels): 8617
# Explicitly passing a `revision` is encouraged when loading a configuration with custom code to ensure no malicious code has been contributed in a newer revision.
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# checkpoint_names = ['checkpoint_57_cacc+chf1+cscc+hscc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9533.pt', 'checkpoint_60_cacc+chf1+cscc+hscc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9535.pt']
# Loading model weights from /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230815_111024_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/checkpoint_60_cacc+chf1+cscc+hscc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9535.pt
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# 100%|███████████████████████████████████████████| 87/87 [00:03<00:00, 22.83it/s]
# Embeddings shape: (8617, 128)
# 100%|███████████████████████████████████████| 8617/8617 [01:42<00:00, 84.38it/s]
# Saving embeddings to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230815_111024_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/embeddings(iuxray_chexbert_labeler).pkl
# Saving metrics to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230815_111024_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/mean_average_accuracy_up_to_500(iuxray_chexbert_labeler).pkl

# %%
# !python ../eval_fact_embedding.py \
--evaluation_mode "iuxray_chexbert_labeler" \
--method "biovil-t" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230820_223655_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph)_FactEncoder(microsoft-BiomedVLP-BioViL-T)/" \
--batch_size 100 \
--top_k 500 \
--save_embeddings
# Out:
# script's arguments:
#    evaluation_mode: iuxray_chexbert_labeler
#    method: biovil-t
#    device: GPU
#    batch_size: 100
#    num_workers: 4
#    model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230820_223655_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph)_FactEncoder(microsoft-BiomedVLP-BioViL-T)/
#    top_k: 500
#    save_embeddings: True
# Loading iuxray sentences and chexbert labels from /mnt/data/pamessina/workspaces/medvqa-workspace/cache/iuxray_sentences_and_chexbert_labels.pkl
# len(sentences): 8617
# len(labels): 8617
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# checkpoint_names = ['checkpoint_298_cacc+chf1+chf1+cscc+hscc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)=0.9518.pt', 'checkpoint_410_cacc+chf1+chf1+cscc+hscc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)=0.9546.pt']
# Loading model weights from /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230820_223655_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph)_FactEncoder(microsoft-BiomedVLP-BioViL-T)/checkpoint_410_cacc+chf1+chf1+cscc+hscc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)=0.9546.pt
# 100%|███████████████████████████████████████████| 87/87 [00:03<00:00, 23.29it/s]
# Embeddings shape: (8617, 128)
# 100%|███████████████████████████████████████| 8617/8617 [01:41<00:00, 84.89it/s]
# Saving embeddings to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230820_223655_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph)_FactEncoder(microsoft-BiomedVLP-BioViL-T)/embeddings(iuxray_chexbert_labeler).pkl
# Saving metrics to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230820_223655_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph)_FactEncoder(microsoft-BiomedVLP-BioViL-T)/mean_average_accuracy_up_to_500(iuxray_chexbert_labeler).pkl

# %%
# !python ../eval_fact_embedding.py \
--evaluation_mode "iuxray_chexbert_labeler" \
--method "cxr-bert-specialized" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230823_124048_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)" \
--batch_size 100 \
--top_k 500 \
--save_embeddings
# Out:
# script's arguments:
#    evaluation_mode: iuxray_chexbert_labeler
#    method: cxr-bert-specialized
#    device: GPU
#    batch_size: 100
#    num_workers: 4
#    model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230823_124048_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)
#    top_k: 500
#    save_embeddings: True
# Loading iuxray sentences and chexbert labels from /mnt/data/pamessina/workspaces/medvqa-workspace/cache/iuxray_sentences_and_chexbert_labels.pkl
# len(sentences): 8617
# len(labels): 8617
# Explicitly passing a `revision` is encouraged when loading a configuration with custom code to ensure no malicious code has been contributed in a newer revision.
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# checkpoint_names = ['checkpoint_92_cacc+chf1+chf1+cscc+hscc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)=0.9587.pt', 'checkpoint_129_cacc+chf1+chf1+cscc+hscc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)=0.9601.pt']
# Loading model weights from /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230823_124048_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/checkpoint_129_cacc+chf1+chf1+cscc+hscc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)=0.9601.pt
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# 100%|███████████████████████████████████████████| 87/87 [00:03<00:00, 23.40it/s]
# Embeddings shape: (8617, 128)
# 100%|███████████████████████████████████████| 8617/8617 [01:44<00:00, 82.07it/s]
# Saving embeddings to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230823_124048_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/embeddings(iuxray_chexbert_labeler).pkl
# Saving metrics to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230823_124048_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/mean_average_accuracy_up_to_500(iuxray_chexbert_labeler).pkl

# %%
# !python ../eval_fact_embedding.py \
--evaluation_mode "iuxray_chexbert_labeler" \
--method "oracle" \
--batch_size 100 \
--top_k 500 \
--save_embeddings
# Out:
# script's arguments:
#    evaluation_mode: iuxray_chexbert_labeler
#    method: oracle
#    device: GPU
#    batch_size: 100
#    num_workers: 4
#    model_checkpoint_folder_path: None
#    top_k: 500
#    save_embeddings: True
# Loading iuxray sentences and chexbert labels from /mnt/data/pamessina/workspaces/medvqa-workspace/cache/iuxray_sentences_and_chexbert_labels.pkl
# 100%|██████████████████████████████████████| 8617/8617 [01:08<00:00, 126.55it/s]
# Saving labels to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230804_194335_iuxray_chexbert_labeler_oracle/labels.pkl
# Saving mean average accuracy up to 500 to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230804_194335_iuxray_chexbert_labeler_oracle/mean_average_accuracy_up_to_500(iuxray_chexbert_labeler).pkl

# %%
from medvqa.utils.files import load_pickle
from medvqa.evaluation.plots import plot_metric_lists

metric_paths = [
    '/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230804_193515_iuxray_chexbert_labeler_cxr-bert-specialized/mean_average_accuracy_up_to_500(iuxray_chexbert_labeler).pkl',
    '/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230804_194003_iuxray_chexbert_labeler_biovil-t/mean_average_accuracy_up_to_500(iuxray_chexbert_labeler).pkl',
    '/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230730_012705_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/mean_average_accuracy_up_to_500(iuxray_chexbert_labeler).pkl',
    '/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230815_111024_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/mean_average_accuracy_up_to_500(iuxray_chexbert_labeler).pkl',
    '/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230820_223655_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph)_FactEncoder(microsoft-BiomedVLP-BioViL-T)/mean_average_accuracy_up_to_500(iuxray_chexbert_labeler).pkl',
    '/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230823_124048_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/mean_average_accuracy_up_to_500(iuxray_chexbert_labeler).pkl',
    '/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230804_194335_iuxray_chexbert_labeler_oracle/mean_average_accuracy_up_to_500(iuxray_chexbert_labeler).pkl'
]
metric_lists = [load_pickle(x) for x in metric_paths]
method_names = [
    'CXR-BERT-specialized (ECCV 2022)',
    'BioViL-T (CVPR 2023)',
    'Fact Embedding (CXR-BERT-specialized fine-tuned)',
    'Fact Embedding (CXR-BERT-specialized fine-tuned) (+ RadGraph triplets)',
    'Fact Embedding (BioViL-T fine-tuned) (+ RadGraph triplets + Anatomy classification)',
    'Fact Embedding (CXR-BERT-specialized fine-tuned) (+ RadGraph triplets + Anatomy classification)',
    'Theoretical Upper Bound',
]
plot_metric_lists(
    metric_lists=metric_lists,
    method_names=method_names,
    title="Mean Average Ranking Accuracy @ K (IU X-ray, CheXbert, 8617 sentences)",
    metric_name='Mean Average Ranking Accuracy @ K',
    xlabel="K",
    figsize=(10, 5),
)

# %%
embeddings_list_3 = [
    load_pickle('/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230804_193515_iuxray_chexbert_labeler_cxr-bert-specialized/embeddings(iuxray_chexbert_labeler).pkl'),
    load_pickle('/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230804_194003_iuxray_chexbert_labeler_biovil-t/embeddings(iuxray_chexbert_labeler).pkl'),
    load_pickle('/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230730_012705_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/embeddings(iuxray_chexbert_labeler).pkl'),
    load_pickle('/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230804_194335_iuxray_chexbert_labeler_oracle/labels.pkl'),
]
method_names_3 = [
    'CXR-BERT-specialized (ECCV 2022)',
    'BioViL-T (CVPR 2023)',
    'Fact Embedding (CXR-BERT-specialized fine-tuned)',
    'Theoretical Upper Bound',
]

# %%
rank_sentences(embeddings_list_3, method_names_3, embeddings_list_3[-1]['labels'])
# Out:
# qi = 88
# -------------
# CXR-BERT-specialized (ECCV 2022)
# Query: No adenopathy.
# **** No adenopathy.
# Acc: 1.00
# **** No lymphadenopathy.
# Acc: 1.00
# **** No hilar lymphadenopathy.
# Acc: 1.00
# **** No obvious mediastinal lymphadenopathy is appreciated.
# Acc: 1.00
# **** The lungs are free of active disease.
# Acc: 1.00
# **** No adenopathy or effusion.
# Acc: 1.00
# **** No active pulmonary disease.
# Acc: 1.00
# **** No XXXX of active tuberculosis.
# Acc: 1.00
# **** No active or acute cardiopulmonary disease.
# Acc: 1.00
# **** No active tuberculosis.
# Acc: 1.00
# **** No pneumonia, effusions, edema, pneumothorax, adenopathy, nodules or masses.
# Acc: 1.00
# **** No active infectious/tuberculous process.
# Acc: 0.93
# **** There is no acute osseous abnormality.
# Acc: 1.00
# **** The bony structures show no acute abnormalities.
# Acc: 1.00
# **** Specifically, no radiographic evidence for tuberculosis.
# Acc: 1.00
# **** No acute or active cardiac, pulmonary or pleural disease.
# Acc: 1.00
# **** No osseous abnormalities.
# Acc: 1.00
# **** No evidence of active tuberculosis.
# Acc: 1.00
# **** No evidence of active infection.
# Acc: 1.00
# **** No radiographic evidence for active tuberculosis a .
# Acc: 1.00
# -------------
# BioViL-T (CVPR 2023)
# Query: No adenopathy.
# **** No adenopathy.
# Acc: 1.00
# **** No lymphadenopathy.
# Acc: 1.00
# **** No acute radiographic cardiopulmonary process.
# Acc: 1.00
# **** No active disease.
# Acc: 1.00
# **** No hilar lymphadenopathy.
# Acc: 1.00
# **** No evidence of active disease
# Acc: 1.00
# **** No acute bone abnormality.
# Acc: 1.00
# **** No adenopathy or effusion.
# Acc: 1.00
# **** The lungs are clear, without evidence of focal acute infiltrate or effusion.
# Acc: 1.00
# **** The lungs are clear, without evidence of focal infiltrate or effusion.
# Acc: 1.00
# **** No acute pulmonary abnormality demonstrated.
# Acc: 1.00
# **** No active/acute cardiopulmonary disease.
# Acc: 1.00
# **** No osseous abnormalities.
# Acc: 1.00
# **** No acute pulmonary disease process identified.
# Acc: 1.00
# **** No evidence of active disease.
# Acc: 1.00
# **** The lungs are clear, without evidence of acute infiltrate or effusion.
# Acc: 1.00
# **** Clear lungs.
# Acc: 1.00
# **** The mediastinum and pulmonary XXXX are normal.
# Acc: 1.00
# **** The lungs are clear, without evidence of focal consolidations or pleural effusion.
# Acc: 1.00
# **** No active disease..
# Acc: 1.00
# -------------
# Fact Embedding (CXR-BERT-specialized fine-tuned)
# Query: No adenopathy.
# **** No adenopathy.
# Acc: 1.00
# **** No lymphadenopathy.
# Acc: 1.00
# **** No adenopathy is seen.
# Acc: 1.00
# **** No hilar lymphadenopathy.
# Acc: 1.00
# **** No obvious mediastinal lymphadenopathy is appreciated.
# Acc: 1.00
# **** No discrete nodules or adenopathy identified.
# Acc: 1.00
# **** No nodules or adenopathy is identified.
# Acc: 1.00
# **** No discrete nodules or adenopathy are noted.
# Acc: 1.00
# **** No osseous abnormalities.
# Acc: 1.00
# **** No nodules, masses or adenopathy.
# Acc: 1.00
# **** No cavitary lesions.
# Acc: 1.00
# **** No bony abnormality.
# Acc: 1.00
# **** No bony abnormalities.
# Acc: 1.00
# **** No focal opacities.
# Acc: 1.00
# **** No focal airspace opacities.
# Acc: 1.00
# **** No evidence of airspace opacity.
# Acc: 1.00
# **** No suspicious bony opacities.
# Acc: 1.00
# **** No pulmonary nodules.
# Acc: 1.00
# **** No abnormal mediastinal widening.
# Acc: 1.00
# **** Lungs clear, no airspace disease.
# Acc: 1.00
# -------------
# Theoretical Upper Bound
# Query: No adenopathy.
# **** KUB.
# Acc: 1.00
# **** Lungs are mildly hyperexpanded but clear.
# Acc: 1.00
# **** Chest: The heart size and cardiomediastinal silhouette are normal.
# Acc: 1.00
# **** Age-indeterminate wedging of several midthoracic vertebral bodies.
# Acc: 1.00
# **** Heart and pulmonary XXXX appear normal 5.
# Acc: 1.00
# **** Heart size and pulmonary XXXX are normal.
# Acc: 1.00
# **** Heart size at the upper limits of normal.
# Acc: 1.00
# **** XXXX chest if warranted clinically given recent onset of dyspnea.
# Acc: 1.00
# **** XXXX XXXX and lateral views of the chest were obtained XXXX/XXXX.
# Acc: 1.00
# **** Heart size is normal and lungs are clear.
# Acc: 1.00
# **** Lumbar vertebral body stabilization XXXX.
# Acc: 1.00
# **** This appears relatively stable compared to the prior examination.
# Acc: 1.00
# **** Lungs are free of focal airspace disease.
# Acc: 1.00
# **** There is no visible free intraperitoneal air under the diaphragm.
# Acc: 1.00
# **** There is no evidence for obstruction or free intraperitoneal air.
# Acc: 1.00
# **** Lungs otherwise are believed to be clear.
# Acc: 1.00
# **** There are no acute osseous abnormalities.
# Acc: 1.00
# **** There is an interim XXXX cervical spinal fusion partly evaluated.
# Acc: 1.00
# **** Mediastinal contour within normal limits.
# Acc: 1.00
# **** There are no focal airspace opacities to suggest lobar pneumonia.
# Acc: 1.00

# %%
# !python ../eval_fact_embedding.py \
--evaluation_mode "iuxray_radgraph_labeler" \
--method "cxr-bert-specialized" \
--batch_size 100 \
--top_k 500 \
--save_embeddings
# Out:
# script's arguments:
#    evaluation_mode: iuxray_radgraph_labeler
#    method: cxr-bert-specialized
#    device: GPU
#    batch_size: 100
#    num_workers: 4
#    model_checkpoint_folder_path: None
#    top_k: 500
#    save_embeddings: True
# Loading iuxray sentences and radgraph labels from /mnt/data/pamessina/workspaces/medvqa-workspace/cache/iuxray_sentences_and_radgraph_labels.pkl
# len(sentences): 8617
# len(labels): 8617
# Explicitly passing a `revision` is encouraged when loading a configuration with custom code to ensure no malicious code has been contributed in a newer revision.
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# 100%|███████████████████████████████████████████| 87/87 [00:03<00:00, 23.37it/s]
# Embeddings shape: (8617, 128)
# 100%|██████████████████████████████████████| 8617/8617 [00:37<00:00, 229.73it/s]
# Saving embeddings to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230806_201914_iuxray_radgraph_cxr-bert-specialized/embeddings(iuxray_radgraph).pkl
# Saving metrics to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230806_201914_iuxray_radgraph_cxr-bert-specialized/mean_average_jaccard_up_to_500(iuxray_radgraph).pkl

# %%
# !python ../eval_fact_embedding.py \
--evaluation_mode "iuxray_radgraph_labeler" \
--method "biovil-t" \
--batch_size 100 \
--top_k 500 \
--save_embeddings
# Out:
# script's arguments:
#    evaluation_mode: iuxray_radgraph_labeler
#    method: biovil-t
#    device: GPU
#    batch_size: 100
#    num_workers: 4
#    model_checkpoint_folder_path: None
#    top_k: 500
#    save_embeddings: True
# Loading iuxray sentences and radgraph labels from /mnt/data/pamessina/workspaces/medvqa-workspace/cache/iuxray_sentences_and_radgraph_labels.pkl
# len(sentences): 8617
# len(labels): 8617
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# 100%|███████████████████████████████████████████| 87/87 [00:03<00:00, 23.13it/s]
# Embeddings shape: (8617, 128)
# 100%|██████████████████████████████████████| 8617/8617 [00:46<00:00, 184.35it/s]
# Saving embeddings to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230806_202054_iuxray_radgraph_biovil-t/embeddings(iuxray_radgraph).pkl
# Saving metrics to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230806_202054_iuxray_radgraph_biovil-t/mean_average_jaccard_up_to_500(iuxray_radgraph).pkl

# %%
# !python ../eval_fact_embedding.py \
--evaluation_mode "iuxray_radgraph_labeler" \
--method "cxr-bert-specialized" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230730_012705_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)" \
--batch_size 100 \
--top_k 500 \
--save_embeddings
# Out:
# script's arguments:
#    evaluation_mode: iuxray_radgraph_labeler
#    method: cxr-bert-specialized
#    device: GPU
#    batch_size: 100
#    num_workers: 4
#    model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230730_012705_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)
#    top_k: 500
#    save_embeddings: True
# Loading iuxray sentences and radgraph labels from /mnt/data/pamessina/workspaces/medvqa-workspace/cache/iuxray_sentences_and_radgraph_labels.pkl
# len(sentences): 8617
# len(labels): 8617
# Explicitly passing a `revision` is encouraged when loading a configuration with custom code to ensure no malicious code has been contributed in a newer revision.
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# checkpoint_names = ['checkpoint_100_cacc+chf1+cscc+hscc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)=0.9559.pt']
# Loading model weights from /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230730_012705_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/checkpoint_100_cacc+chf1+cscc+hscc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)=0.9559.pt
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# 100%|███████████████████████████████████████████| 87/87 [00:03<00:00, 22.02it/s]
# Embeddings shape: (8617, 128)
# 100%|██████████████████████████████████████| 8617/8617 [00:35<00:00, 241.95it/s]
# Saving embeddings to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230730_012705_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/embeddings(iuxray_radgraph).pkl
# Saving metrics to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230730_012705_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/mean_average_jaccard_up_to_500(iuxray_radgraph).pkl

# %%
# !python ../eval_fact_embedding.py \
--evaluation_mode "iuxray_radgraph_labeler" \
--method "cxr-bert-specialized" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230815_111024_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/" \
--batch_size 100 \
--top_k 500 \
--save_embeddings
# Out:
# script's arguments:
#    evaluation_mode: iuxray_radgraph_labeler
#    method: cxr-bert-specialized
#    device: GPU
#    batch_size: 100
#    num_workers: 4
#    model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230815_111024_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/
#    top_k: 500
#    save_embeddings: True
# Loading iuxray sentences and radgraph labels from /mnt/data/pamessina/workspaces/medvqa-workspace/cache/iuxray_sentences_and_radgraph_labels.pkl
# len(sentences): 8617
# len(labels): 8617
# Explicitly passing a `revision` is encouraged when loading a configuration with custom code to ensure no malicious code has been contributed in a newer revision.
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# checkpoint_names = ['checkpoint_57_cacc+chf1+cscc+hscc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9533.pt', 'checkpoint_60_cacc+chf1+cscc+hscc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9535.pt']
# Loading model weights from /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230815_111024_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/checkpoint_60_cacc+chf1+cscc+hscc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9535.pt
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# 100%|███████████████████████████████████████████| 87/87 [00:03<00:00, 22.72it/s]
# Embeddings shape: (8617, 128)
# 100%|██████████████████████████████████████| 8617/8617 [00:18<00:00, 476.58it/s]
# Saving embeddings to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230815_111024_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/embeddings(iuxray_radgraph).pkl
# Saving metrics to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230815_111024_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/mean_average_jaccard_up_to_500(iuxray_radgraph).pkl

# %%
# !python ../eval_fact_embedding.py \
--evaluation_mode "iuxray_radgraph_labeler" \
--method "biovil-t" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230820_223655_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph)_FactEncoder(microsoft-BiomedVLP-BioViL-T)/" \
--batch_size 100 \
--top_k 500 \
--save_embeddings
# Out:
# script's arguments:
#    evaluation_mode: iuxray_radgraph_labeler
#    method: biovil-t
#    device: GPU
#    batch_size: 100
#    num_workers: 4
#    model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230820_223655_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph)_FactEncoder(microsoft-BiomedVLP-BioViL-T)/
#    top_k: 500
#    save_embeddings: True
# Loading iuxray sentences and radgraph labels from /mnt/data/pamessina/workspaces/medvqa-workspace/cache/iuxray_sentences_and_radgraph_labels.pkl
# len(sentences): 8617
# len(labels): 8617
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# checkpoint_names = ['checkpoint_298_cacc+chf1+chf1+cscc+hscc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)=0.9518.pt', 'checkpoint_410_cacc+chf1+chf1+cscc+hscc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)=0.9546.pt']
# Loading model weights from /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230820_223655_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph)_FactEncoder(microsoft-BiomedVLP-BioViL-T)/checkpoint_410_cacc+chf1+chf1+cscc+hscc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)=0.9546.pt
# 100%|███████████████████████████████████████████| 87/87 [00:03<00:00, 23.22it/s]
# Embeddings shape: (8617, 128)
# 100%|██████████████████████████████████████| 8617/8617 [00:18<00:00, 461.44it/s]
# Saving embeddings to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230820_223655_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph)_FactEncoder(microsoft-BiomedVLP-BioViL-T)/embeddings(iuxray_radgraph).pkl
# Saving metrics to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230820_223655_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph)_FactEncoder(microsoft-BiomedVLP-BioViL-T)/mean_average_jaccard_up_to_500(iuxray_radgraph).pkl

# %%
# !python ../eval_fact_embedding.py \
--evaluation_mode "iuxray_radgraph_labeler" \
--method "cxr-bert-specialized" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230823_124048_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)" \
--batch_size 100 \
--top_k 500 \
--save_embeddings
# Out:
# script's arguments:
#    evaluation_mode: iuxray_radgraph_labeler
#    method: cxr-bert-specialized
#    device: GPU
#    batch_size: 100
#    num_workers: 4
#    model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230823_124048_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)
#    top_k: 500
#    save_embeddings: True
# Loading iuxray sentences and radgraph labels from /mnt/data/pamessina/workspaces/medvqa-workspace/cache/iuxray_sentences_and_radgraph_labels.pkl
# len(sentences): 8617
# len(labels): 8617
# Explicitly passing a `revision` is encouraged when loading a configuration with custom code to ensure no malicious code has been contributed in a newer revision.
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# checkpoint_names = ['checkpoint_92_cacc+chf1+chf1+cscc+hscc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)=0.9587.pt', 'checkpoint_129_cacc+chf1+chf1+cscc+hscc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)=0.9601.pt']
# Loading model weights from /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230823_124048_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/checkpoint_129_cacc+chf1+chf1+cscc+hscc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)=0.9601.pt
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# 100%|███████████████████████████████████████████| 87/87 [00:03<00:00, 23.21it/s]
# Embeddings shape: (8617, 128)
# 100%|██████████████████████████████████████| 8617/8617 [00:18<00:00, 471.31it/s]
# Saving embeddings to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230823_124048_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/embeddings(iuxray_radgraph).pkl
# Saving metrics to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230823_124048_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/mean_average_jaccard_up_to_500(iuxray_radgraph).pkl

# %%
# !python ../eval_fact_embedding.py \
--evaluation_mode "iuxray_radgraph_labeler" \
--method "cxr-bert-specialized" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230916_194059_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/" \
--batch_size 100 \
--top_k 500 \
--save_embeddings
# Out:
# script's arguments:
#    evaluation_mode: iuxray_radgraph_labeler
#    method: cxr-bert-specialized
#    device: GPU
#    batch_size: 100
#    num_workers: 4
#    model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230916_194059_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/
#    top_k: 500
#    save_embeddings: True
# Loading iuxray reports from /mnt/workspace/iu-x-ray/dataset/reports/reports.min.json
# Number of sentences: 8617
# Shortest sentence: KUB.
# Longest sentence: The infrahilar pulmonary markings appear slightly prominent bilaterally, which XXXX represents XXXX appearance for the patient but difficult to completely exclude some reactive airway/bronchitic changes in the absence of comparison radiographs.. No airspace consolidation or lobar atelectasis.
# Loading RadGraph labeler
# Cache successfully loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/cache/radgraph_labeler_cache_.pkl
# (*) RadGraph: labeling 8617 texts ...
# RadGraph: 8617 texts not found in cache, invoking RadGraph labeler ...
# RadGraph: invoking command conda run -n dygiepp python3 /home/pamessina/medvqa/medvqa/scripts/radgraph/radgraph_allennlp_inference.py --model_path /mnt/data/radgraph/data/models/model_checkpoint/model.tar.gz --dygie_package_parent_folder /home/pamessina/dygiepp --data_path /mnt/data/pamessina/workspaces/medvqa-workspace/tmp/radgraph/20230917_113603 --out_path /mnt/data/pamessina/workspaces/medvqa-workspace/tmp/radgraph/results/20230917_113603.jsonl --temp_folder /mnt/data/pamessina/workspaces/medvqa-workspace/tmp/radgraph/temp ...
# Getting paths to all the reports...
# Got all the paths.
# Preprocessing all the reports...
# 1 reports done
# 1001 reports done
# 2001 reports done
# 3001 reports done
# 4001 reports done
# 5001 reports done
# 6001 reports done
# 7001 reports done
# 8001 reports done
# 8617 reports done
# Done with preprocessing.
# Running the inference now... This can take a bit of time
# dygie_package_parent_folder: /home/pamessina/dygiepp
# Imported dygie successfully
# /home/pamessina/dygiepp/dygie/__init__.py
# Running command:  PYTHONPATH=/home/pamessina/dygiepp:$PYTHONPATH conda run -n dygiepp allennlp predict /mnt/data/radgraph/data/models/model_checkpoint/model.tar.gz /mnt/data/pamessina/workspaces/medvqa-workspace/tmp/radgraph/temp/temp_dygie_input.json             --predictor dygie             --include-package dygie             --use-dataset-reader             --output-file /mnt/data/pamessina/workspaces/medvqa-workspace/tmp/radgraph/temp/temp_dygie_output.json             --cuda-device -1             --silent
# Done with inference
# Inference completed.
# Postprocessing output file...
# Done postprocessing.
# Saving results and performing final cleanup...
#
# 2023-09-17 11:36:08,521 - INFO - allennlp.common.plugins - Plugin allennlp_models available
# 2023-09-17 11:36:08,544 - INFO - allennlp.models.archival - loading archive file /mnt/data/radgraph/data/models/model_checkpoint/model.tar.gz
# 2023-09-17 11:36:08,544 - INFO - allennlp.models.archival - extracting archive file /mnt/data/radgraph/data/models/model_checkpoint/model.tar.gz to temp dir /tmp/tmpysyrwfv9
# 2023-09-17 11:36:11,534 - INFO - allennlp.common.params - type = from_instances
# 2023-09-17 11:36:11,534 - INFO - allennlp.data.vocabulary - Loading token dictionary from /tmp/tmpysyrwfv9/vocabulary.
# 2023-09-17 11:36:11,535 - INFO - allennlp.common.params - model.type = dygie
# 2023-09-17 11:36:11,536 - INFO - allennlp.common.params - model.embedder.type = basic
# 2023-09-17 11:36:11,536 - INFO - allennlp.common.params - model.embedder.token_embedders.bert.type = pretrained_transformer_mismatched
# 2023-09-17 11:36:11,536 - INFO - allennlp.common.params - model.embedder.token_embedders.bert.model_name = microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext
# 2023-09-17 11:36:11,536 - INFO - allennlp.common.params - model.embedder.token_embedders.bert.max_length = 512
# 2023-09-17 11:36:11,536 - INFO - allennlp.common.params - model.embedder.token_embedders.bert.train_parameters = True
# 2023-09-17 11:36:11,536 - INFO - allennlp.common.params - model.embedder.token_embedders.bert.last_layer_only = True
# 2023-09-17 11:36:11,536 - INFO - allennlp.common.params - model.embedder.token_embedders.bert.gradient_checkpointing = None
# 2023-09-17 11:36:12,278 - INFO - transformers.configuration_utils - loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext/config.json from cache at /home/pamessina/.cache/torch/transformers/d6259b1a11dbf51cd20925d777803c76163bb3a51a1a2f51dc546051f2fafd89.dcaad90251a770a0bf072b529202dd8ed31e8d64f6198c8e9ae8de194e29d227
# 2023-09-17 11:36:12,280 - INFO - transformers.configuration_utils - Model config BertConfig {
#   "attention_probs_dropout_prob": 0.1,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "type_vocab_size": 2,
#   "vocab_size": 30522
# }
#
# 2023-09-17 11:36:12,925 - INFO - transformers.modeling_utils - loading weights file https://cdn.huggingface.co/microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext/pytorch_model.bin from cache at /home/pamessina/.cache/torch/transformers/b37e65e3b849ec2eaf7af4c77b653dcdb3fa19df5fccc86ff0ffa16f126f5b75.a6a084e84faf3eb5eba47a0a81a786cbf5635e8b5fb67072ad3c918042935a30
# 2023-09-17 11:36:17,574 - INFO - transformers.modeling_utils - All model checkpoint weights were used when initializing BertModel.
#
# 2023-09-17 11:36:17,574 - INFO - transformers.modeling_utils - All the weights of BertModel were initialized from the model checkpoint at microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext.
# If your task is similar to the task the model of the ckeckpoint was trained on, you can already use BertModel for predictions without further training.
# 2023-09-17 11:36:18,388 - INFO - transformers.configuration_utils - loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext/config.json from cache at /home/pamessina/.cache/torch/transformers/d6259b1a11dbf51cd20925d777803c76163bb3a51a1a2f51dc546051f2fafd89.dcaad90251a770a0bf072b529202dd8ed31e8d64f6198c8e9ae8de194e29d227
# 2023-09-17 11:36:18,389 - INFO - transformers.configuration_utils - Model config BertConfig {
#   "attention_probs_dropout_prob": 0.1,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "type_vocab_size": 2,
#   "vocab_size": 30522
# }
#
# 2023-09-17 11:36:18,390 - INFO - transformers.tokenization_utils_base - Model name 'microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext' not found in model shortcut name list (bert-base-uncased, bert-large-uncased, bert-base-cased, bert-large-cased, bert-base-multilingual-uncased, bert-base-multilingual-cased, bert-base-chinese, bert-base-german-cased, bert-large-uncased-whole-word-masking, bert-large-cased-whole-word-masking, bert-large-uncased-whole-word-masking-finetuned-squad, bert-large-cased-whole-word-masking-finetuned-squad, bert-base-cased-finetuned-mrpc, bert-base-german-dbmdz-cased, bert-base-german-dbmdz-uncased, TurkuNLP/bert-base-finnish-cased-v1, TurkuNLP/bert-base-finnish-uncased-v1, wietsedv/bert-base-dutch-cased). Assuming 'microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext' is a path, a model identifier, or url to a directory containing tokenizer files.
# 2023-09-17 11:36:21,463 - INFO - transformers.tokenization_utils_base - loading file https://s3.amazonaws.com/models.huggingface.co/bert/microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext/vocab.txt from cache at /home/pamessina/.cache/torch/transformers/b5cd04b1472559c44d90fe1a1f3e8813538c0774130f99287bb3ef2f71574c34.3acf5667a44623ef633872cc290168316f7124c3bc23562e163aee8dcae4bb30
# 2023-09-17 11:36:21,464 - INFO - transformers.tokenization_utils_base - loading file https://s3.amazonaws.com/models.huggingface.co/bert/microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext/added_tokens.json from cache at None
# 2023-09-17 11:36:21,464 - INFO - transformers.tokenization_utils_base - loading file https://s3.amazonaws.com/models.huggingface.co/bert/microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext/special_tokens_map.json from cache at None
# 2023-09-17 11:36:21,464 - INFO - transformers.tokenization_utils_base - loading file https://s3.amazonaws.com/models.huggingface.co/bert/microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext/tokenizer_config.json from cache at None
# 2023-09-17 11:36:21,464 - INFO - transformers.tokenization_utils_base - loading file https://s3.amazonaws.com/models.huggingface.co/bert/microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext/tokenizer.json from cache at None
# 2023-09-17 11:36:22,127 - INFO - transformers.configuration_utils - loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext/config.json from cache at /home/pamessina/.cache/torch/transformers/d6259b1a11dbf51cd20925d777803c76163bb3a51a1a2f51dc546051f2fafd89.dcaad90251a770a0bf072b529202dd8ed31e8d64f6198c8e9ae8de194e29d227
# 2023-09-17 11:36:22,128 - INFO - transformers.configuration_utils - Model config BertConfig {
#   "attention_probs_dropout_prob": 0.1,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "type_vocab_size": 2,
#   "vocab_size": 30522
# }
#
# 2023-09-17 11:36:22,128 - INFO - transformers.tokenization_utils_base - Model name 'microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext' not found in model shortcut name list (bert-base-uncased, bert-large-uncased, bert-base-cased, bert-large-cased, bert-base-multilingual-uncased, bert-base-multilingual-cased, bert-base-chinese, bert-base-german-cased, bert-large-uncased-whole-word-masking, bert-large-cased-whole-word-masking, bert-large-uncased-whole-word-masking-finetuned-squad, bert-large-cased-whole-word-masking-finetuned-squad, bert-base-cased-finetuned-mrpc, bert-base-german-dbmdz-cased, bert-base-german-dbmdz-uncased, TurkuNLP/bert-base-finnish-cased-v1, TurkuNLP/bert-base-finnish-uncased-v1, wietsedv/bert-base-dutch-cased). Assuming 'microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext' is a path, a model identifier, or url to a directory containing tokenizer files.
# 2023-09-17 11:36:25,332 - INFO - transformers.tokenization_utils_base - loading file https://s3.amazonaws.com/models.huggingface.co/bert/microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext/vocab.txt from cache at /home/pamessina/.cache/torch/transformers/b5cd04b1472559c44d90fe1a1f3e8813538c0774130f99287bb3ef2f71574c34.3acf5667a44623ef633872cc290168316f7124c3bc23562e163aee8dcae4bb30
# 2023-09-17 11:36:25,332 - INFO - transformers.tokenization_utils_base - loading file https://s3.amazonaws.com/models.huggingface.co/bert/microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext/added_tokens.json from cache at None
# 2023-09-17 11:36:25,333 - INFO - transformers.tokenization_utils_base - loading file https://s3.amazonaws.com/models.huggingface.co/bert/microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext/special_tokens_map.json from cache at None
# 2023-09-17 11:36:25,333 - INFO - transformers.tokenization_utils_base - loading file https://s3.amazonaws.com/models.huggingface.co/bert/microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext/tokenizer_config.json from cache at None
# 2023-09-17 11:36:25,333 - INFO - transformers.tokenization_utils_base - loading file https://s3.amazonaws.com/models.huggingface.co/bert/microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext/tokenizer.json from cache at None
# 2023-09-17 11:36:25,364 - INFO - allennlp.common.params - model.feature_size = 20
# 2023-09-17 11:36:25,364 - INFO - allennlp.common.params - model.max_span_width = 8
# 2023-09-17 11:36:25,364 - INFO - allennlp.common.params - model.target_task = relation
# 2023-09-17 11:36:25,365 - INFO - allennlp.common.params - model.initializer.regexes.0.1.type = xavier_normal
# 2023-09-17 11:36:25,365 - INFO - allennlp.common.params - model.initializer.regexes.0.1.gain = 1.0
# 2023-09-17 11:36:25,365 - INFO - allennlp.common.params - model.initializer.prevent_regexes = None
# 2023-09-17 11:36:25,365 - INFO - allennlp.common.params - model.module_initializer.regexes.0.1.type = xavier_normal
# 2023-09-17 11:36:25,366 - INFO - allennlp.common.params - model.module_initializer.regexes.0.1.gain = 1.0
# 2023-09-17 11:36:25,366 - INFO - allennlp.common.params - model.module_initializer.regexes.1.1.type = xavier_normal
# 2023-09-17 11:36:25,366 - INFO - allennlp.common.params - model.module_initializer.regexes.1.1.gain = 1.0
# 2023-09-17 11:36:25,366 - INFO - allennlp.common.params - model.module_initializer.prevent_regexes = None
# 2023-09-17 11:36:25,366 - INFO - allennlp.common.params - model.regularizer = None
# 2023-09-17 11:36:25,366 - INFO - allennlp.common.params - model.display_metrics = None
# 2023-09-17 11:36:25,367 - INFO - allennlp.common.params - ner.regularizer = None
# 2023-09-17 11:36:25,371 - INFO - allennlp.common.params - coref.spans_per_word = 0.3
# 2023-09-17 11:36:25,371 - INFO - allennlp.common.params - coref.max_antecedents = 100
# 2023-09-17 11:36:25,371 - INFO - allennlp.common.params - coref.coref_prop = 0
# 2023-09-17 11:36:25,371 - INFO - allennlp.common.params - coref.coref_prop_dropout_f = 0.0
# 2023-09-17 11:36:25,371 - INFO - allennlp.common.params - coref.regularizer = None
# 2023-09-17 11:36:25,454 - INFO - allennlp.common.params - relation.spans_per_word = 0.5
# 2023-09-17 11:36:25,454 - INFO - allennlp.common.params - relation.positive_label_weight = 1.0
# 2023-09-17 11:36:25,454 - INFO - allennlp.common.params - relation.regularizer = None
# 2023-09-17 11:36:25,470 - INFO - allennlp.common.params - events.trigger_spans_per_word = 0.3
# 2023-09-17 11:36:25,470 - INFO - allennlp.common.params - events.argument_spans_per_word = 0.8
# 2023-09-17 11:36:25,470 - INFO - allennlp.common.params - events.regularizer = None
# 2023-09-17 11:36:25,470 - INFO - allennlp.nn.initializers - Initializing parameters
# 2023-09-17 11:36:25,470 - INFO - allennlp.nn.initializers - Initializing _ner_scorers.None__ner_labels.0._module._linear_layers.0.weight using .*weight initializer
# 2023-09-17 11:36:25,475 - INFO - allennlp.nn.initializers - Initializing _ner_scorers.None__ner_labels.0._module._linear_layers.1.weight using .*weight initializer
# 2023-09-17 11:36:25,475 - INFO - allennlp.nn.initializers - Initializing _ner_scorers.None__ner_labels.1._module.weight using .*weight initializer
# 2023-09-17 11:36:25,475 - WARNING - allennlp.nn.initializers - Did not use initialization regex that was passed: .*weight_matrix
# 2023-09-17 11:36:25,475 - INFO - allennlp.nn.initializers - Done initializing parameters; the following parameters are using their default initialization from their code
# 2023-09-17 11:36:25,475 - INFO - allennlp.nn.initializers -    _ner_scorers.None__ner_labels.0._module._linear_layers.0.bias
# 2023-09-17 11:36:25,475 - INFO - allennlp.nn.initializers -    _ner_scorers.None__ner_labels.0._module._linear_layers.1.bias
# 2023-09-17 11:36:25,475 - INFO - allennlp.nn.initializers -    _ner_scorers.None__ner_labels.1._module.bias
# 2023-09-17 11:36:25,475 - INFO - allennlp.nn.initializers - Initializing parameters
# 2023-09-17 11:36:25,476 - INFO - allennlp.nn.initializers - Initializing _distance_embedding.weight using .*weight initializer
# 2023-09-17 11:36:25,476 - INFO - allennlp.nn.initializers - Initializing _antecedent_feedforward._module._linear_layers.0.weight using .*weight initializer
# 2023-09-17 11:36:25,487 - INFO - allennlp.nn.initializers - Initializing _antecedent_feedforward._module._linear_layers.1.weight using .*weight initializer
# 2023-09-17 11:36:25,488 - INFO - allennlp.nn.initializers - Initializing _mention_pruner._scorer.0._module._linear_layers.0.weight using .*weight initializer
# 2023-09-17 11:36:25,492 - INFO - allennlp.nn.initializers - Initializing _mention_pruner._scorer.0._module._linear_layers.1.weight using .*weight initializer
# 2023-09-17 11:36:25,493 - INFO - allennlp.nn.initializers - Initializing _mention_pruner._scorer.1._module.weight using .*weight initializer
# 2023-09-17 11:36:25,493 - INFO - allennlp.nn.initializers - Initializing _antecedent_scorer._module.weight using .*weight initializer
# 2023-09-17 11:36:25,493 - INFO - allennlp.nn.initializers - Initializing _f_network._linear_layers.0.weight using .*weight initializer
# 2023-09-17 11:36:25,574 - WARNING - allennlp.nn.initializers - Did not use initialization regex that was passed: .*weight_matrix
# 2023-09-17 11:36:25,574 - INFO - allennlp.nn.initializers - Done initializing parameters; the following parameters are using their default initialization from their code
# 2023-09-17 11:36:25,574 - INFO - allennlp.nn.initializers -    _antecedent_feedforward._module._linear_layers.0.bias
# 2023-09-17 11:36:25,574 - INFO - allennlp.nn.initializers -    _antecedent_feedforward._module._linear_layers.1.bias
# 2023-09-17 11:36:25,574 - INFO - allennlp.nn.initializers -    _antecedent_scorer._module.bias
# 2023-09-17 11:36:25,574 - INFO - allennlp.nn.initializers -    _f_network._linear_layers.0.bias
# 2023-09-17 11:36:25,574 - INFO - allennlp.nn.initializers -    _mention_pruner._scorer.0._module._linear_layers.0.bias
# 2023-09-17 11:36:25,574 - INFO - allennlp.nn.initializers -    _mention_pruner._scorer.0._module._linear_layers.1.bias
# 2023-09-17 11:36:25,574 - INFO - allennlp.nn.initializers -    _mention_pruner._scorer.1._module.bias
# 2023-09-17 11:36:25,574 - INFO - allennlp.nn.initializers - Initializing parameters
# 2023-09-17 11:36:25,574 - INFO - allennlp.nn.initializers - Initializing _mention_pruners.None__relation_labels._scorer.0._module._linear_layers.0.weight using .*weight initializer
# 2023-09-17 11:36:25,578 - INFO - allennlp.nn.initializers - Initializing _mention_pruners.None__relation_labels._scorer.0._module._linear_layers.1.weight using .*weight initializer
# 2023-09-17 11:36:25,579 - INFO - allennlp.nn.initializers - Initializing _mention_pruners.None__relation_labels._scorer.1._module.weight using .*weight initializer
# 2023-09-17 11:36:25,579 - INFO - allennlp.nn.initializers - Initializing _relation_feedforwards.None__relation_labels._linear_layers.0.weight using .*weight initializer
# 2023-09-17 11:36:25,591 - INFO - allennlp.nn.initializers - Initializing _relation_feedforwards.None__relation_labels._linear_layers.1.weight using .*weight initializer
# 2023-09-17 11:36:25,591 - INFO - allennlp.nn.initializers - Initializing _relation_scorers.None__relation_labels.weight using .*weight initializer
# 2023-09-17 11:36:25,591 - WARNING - allennlp.nn.initializers - Did not use initialization regex that was passed: .*weight_matrix
# 2023-09-17 11:36:25,591 - INFO - allennlp.nn.initializers - Done initializing parameters; the following parameters are using their default initialization from their code
# 2023-09-17 11:36:25,591 - INFO - allennlp.nn.initializers -    _mention_pruners.None__relation_labels._scorer.0._module._linear_layers.0.bias
# 2023-09-17 11:36:25,591 - INFO - allennlp.nn.initializers -    _mention_pruners.None__relation_labels._scorer.0._module._linear_layers.1.bias
# 2023-09-17 11:36:25,591 - INFO - allennlp.nn.initializers -    _mention_pruners.None__relation_labels._scorer.1._module.bias
# 2023-09-17 11:36:25,591 - INFO - allennlp.nn.initializers -    _relation_feedforwards.None__relation_labels._linear_layers.0.bias
# 2023-09-17 11:36:25,591 - INFO - allennlp.nn.initializers -    _relation_feedforwards.None__relation_labels._linear_layers.1.bias
# 2023-09-17 11:36:25,592 - INFO - allennlp.nn.initializers -    _relation_scorers.None__relation_labels.bias
# 2023-09-17 11:36:25,592 - INFO - allennlp.nn.initializers - Initializing parameters
# 2023-09-17 11:36:25,592 - INFO - allennlp.nn.initializers - Initializing _distance_embedding.weight using .*weight initializer
# 2023-09-17 11:36:25,592 - WARNING - allennlp.nn.initializers - Did not use initialization regex that was passed: .*weight_matrix
# 2023-09-17 11:36:25,592 - INFO - allennlp.nn.initializers - Done initializing parameters; the following parameters are using their default initialization from their code
# 2023-09-17 11:36:25,592 - INFO - allennlp.nn.initializers - Initializing parameters
# 2023-09-17 11:36:25,592 - INFO - allennlp.nn.initializers - Initializing _endpoint_span_extractor._span_width_embedding.weight using _span_width_embedding.weight initializer
# 2023-09-17 11:36:25,594 - INFO - allennlp.nn.initializers - Done initializing parameters; the following parameters are using their default initialization from their code
# 2023-09-17 11:36:25,594 - INFO - allennlp.nn.initializers -    _coref._antecedent_feedforward._module._linear_layers.0.bias
# 2023-09-17 11:36:25,594 - INFO - allennlp.nn.initializers -    _coref._antecedent_feedforward._module._linear_layers.0.weight
# 2023-09-17 11:36:25,594 - INFO - allennlp.nn.initializers -    _coref._antecedent_feedforward._module._linear_layers.1.bias
# 2023-09-17 11:36:25,594 - INFO - allennlp.nn.initializers -    _coref._antecedent_feedforward._module._linear_layers.1.weight
# 2023-09-17 11:36:25,594 - INFO - allennlp.nn.initializers -    _coref._antecedent_scorer._module.bias
# 2023-09-17 11:36:25,594 - INFO - allennlp.nn.initializers -    _coref._antecedent_scorer._module.weight
# 2023-09-17 11:36:25,594 - INFO - allennlp.nn.initializers -    _coref._distance_embedding.weight
# 2023-09-17 11:36:25,594 - INFO - allennlp.nn.initializers -    _coref._f_network._linear_layers.0.bias
# 2023-09-17 11:36:25,594 - INFO - allennlp.nn.initializers -    _coref._f_network._linear_layers.0.weight
# 2023-09-17 11:36:25,594 - INFO - allennlp.nn.initializers -    _coref._mention_pruner._scorer.0._module._linear_layers.0.bias
# 2023-09-17 11:36:25,594 - INFO - allennlp.nn.initializers -    _coref._mention_pruner._scorer.0._module._linear_layers.0.weight
# 2023-09-17 11:36:25,594 - INFO - allennlp.nn.initializers -    _coref._mention_pruner._scorer.0._module._linear_layers.1.bias
# 2023-09-17 11:36:25,594 - INFO - allennlp.nn.initializers -    _coref._mention_pruner._scorer.0._module._linear_layers.1.weight
# 2023-09-17 11:36:25,594 - INFO - allennlp.nn.initializers -    _coref._mention_pruner._scorer.1._module.bias
# 2023-09-17 11:36:25,594 - INFO - allennlp.nn.initializers -    _coref._mention_pruner._scorer.1._module.weight
# 2023-09-17 11:36:25,594 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.embeddings.LayerNorm.bias
# 2023-09-17 11:36:25,594 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.embeddings.LayerNorm.weight
# 2023-09-17 11:36:25,594 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.embeddings.position_embeddings.weight
# 2023-09-17 11:36:25,594 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.embeddings.token_type_embeddings.weight
# 2023-09-17 11:36:25,594 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.embeddings.word_embeddings.weight
# 2023-09-17 11:36:25,594 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.0.attention.output.LayerNorm.bias
# 2023-09-17 11:36:25,594 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.0.attention.output.LayerNorm.weight
# 2023-09-17 11:36:25,594 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.0.attention.output.dense.bias
# 2023-09-17 11:36:25,594 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.0.attention.output.dense.weight
# 2023-09-17 11:36:25,594 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.0.attention.self.key.bias
# 2023-09-17 11:36:25,594 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.0.attention.self.key.weight
# 2023-09-17 11:36:25,594 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.0.attention.self.query.bias
# 2023-09-17 11:36:25,594 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.0.attention.self.query.weight
# 2023-09-17 11:36:25,594 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.0.attention.self.value.bias
# 2023-09-17 11:36:25,594 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.0.attention.self.value.weight
# 2023-09-17 11:36:25,594 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.0.intermediate.dense.bias
# 2023-09-17 11:36:25,594 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.0.intermediate.dense.weight
# 2023-09-17 11:36:25,594 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.0.output.LayerNorm.bias
# 2023-09-17 11:36:25,594 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.0.output.LayerNorm.weight
# 2023-09-17 11:36:25,595 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.0.output.dense.bias
# 2023-09-17 11:36:25,595 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.0.output.dense.weight
# 2023-09-17 11:36:25,595 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.1.attention.output.LayerNorm.bias
# 2023-09-17 11:36:25,595 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.1.attention.output.LayerNorm.weight
# 2023-09-17 11:36:25,595 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.1.attention.output.dense.bias
# 2023-09-17 11:36:25,595 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.1.attention.output.dense.weight
# 2023-09-17 11:36:25,595 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.1.attention.self.key.bias
# 2023-09-17 11:36:25,595 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.1.attention.self.key.weight
# 2023-09-17 11:36:25,595 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.1.attention.self.query.bias
# 2023-09-17 11:36:25,595 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.1.attention.self.query.weight
# 2023-09-17 11:36:25,595 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.1.attention.self.value.bias
# 2023-09-17 11:36:25,595 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.1.attention.self.value.weight
# 2023-09-17 11:36:25,595 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.1.intermediate.dense.bias
# 2023-09-17 11:36:25,595 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.1.intermediate.dense.weight
# 2023-09-17 11:36:25,595 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.1.output.LayerNorm.bias
# 2023-09-17 11:36:25,595 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.1.output.LayerNorm.weight
# 2023-09-17 11:36:25,595 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.1.output.dense.bias
# 2023-09-17 11:36:25,595 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.1.output.dense.weight
# 2023-09-17 11:36:25,595 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.10.attention.output.LayerNorm.bias
# 2023-09-17 11:36:25,595 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.10.attention.output.LayerNorm.weight
# 2023-09-17 11:36:25,595 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.10.attention.output.dense.bias
# 2023-09-17 11:36:25,595 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.10.attention.output.dense.weight
# 2023-09-17 11:36:25,595 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.10.attention.self.key.bias
# 2023-09-17 11:36:25,595 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.10.attention.self.key.weight
# 2023-09-17 11:36:25,595 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.10.attention.self.query.bias
# 2023-09-17 11:36:25,595 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.10.attention.self.query.weight
# 2023-09-17 11:36:25,595 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.10.attention.self.value.bias
# 2023-09-17 11:36:25,595 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.10.attention.self.value.weight
# 2023-09-17 11:36:25,595 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.10.intermediate.dense.bias
# 2023-09-17 11:36:25,595 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.10.intermediate.dense.weight
# 2023-09-17 11:36:25,595 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.10.output.LayerNorm.bias
# 2023-09-17 11:36:25,595 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.10.output.LayerNorm.weight
# 2023-09-17 11:36:25,595 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.10.output.dense.bias
# 2023-09-17 11:36:25,595 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.10.output.dense.weight
# 2023-09-17 11:36:25,595 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.11.attention.output.LayerNorm.bias
# 2023-09-17 11:36:25,595 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.11.attention.output.LayerNorm.weight
# 2023-09-17 11:36:25,595 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.11.attention.output.dense.bias
# 2023-09-17 11:36:25,595 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.11.attention.output.dense.weight
# 2023-09-17 11:36:25,595 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.11.attention.self.key.bias
# 2023-09-17 11:36:25,595 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.11.attention.self.key.weight
# 2023-09-17 11:36:25,596 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.11.attention.self.query.bias
# 2023-09-17 11:36:25,596 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.11.attention.self.query.weight
# 2023-09-17 11:36:25,596 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.11.attention.self.value.bias
# 2023-09-17 11:36:25,596 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.11.attention.self.value.weight
# 2023-09-17 11:36:25,596 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.11.intermediate.dense.bias
# 2023-09-17 11:36:25,596 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.11.intermediate.dense.weight
# 2023-09-17 11:36:25,596 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.11.output.LayerNorm.bias
# 2023-09-17 11:36:25,596 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.11.output.LayerNorm.weight
# 2023-09-17 11:36:25,596 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.11.output.dense.bias
# 2023-09-17 11:36:25,596 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.11.output.dense.weight
# 2023-09-17 11:36:25,596 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.2.attention.output.LayerNorm.bias
# 2023-09-17 11:36:25,596 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.2.attention.output.LayerNorm.weight
# 2023-09-17 11:36:25,596 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.2.attention.output.dense.bias
# 2023-09-17 11:36:25,596 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.2.attention.output.dense.weight
# 2023-09-17 11:36:25,596 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.2.attention.self.key.bias
# 2023-09-17 11:36:25,596 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.2.attention.self.key.weight
# 2023-09-17 11:36:25,596 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.2.attention.self.query.bias
# 2023-09-17 11:36:25,596 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.2.attention.self.query.weight
# 2023-09-17 11:36:25,596 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.2.attention.self.value.bias
# 2023-09-17 11:36:25,596 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.2.attention.self.value.weight
# 2023-09-17 11:36:25,596 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.2.intermediate.dense.bias
# 2023-09-17 11:36:25,596 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.2.intermediate.dense.weight
# 2023-09-17 11:36:25,596 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.2.output.LayerNorm.bias
# 2023-09-17 11:36:25,596 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.2.output.LayerNorm.weight
# 2023-09-17 11:36:25,596 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.2.output.dense.bias
# 2023-09-17 11:36:25,596 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.2.output.dense.weight
# 2023-09-17 11:36:25,596 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.3.attention.output.LayerNorm.bias
# 2023-09-17 11:36:25,596 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.3.attention.output.LayerNorm.weight
# 2023-09-17 11:36:25,596 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.3.attention.output.dense.bias
# 2023-09-17 11:36:25,596 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.3.attention.output.dense.weight
# 2023-09-17 11:36:25,596 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.3.attention.self.key.bias
# 2023-09-17 11:36:25,596 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.3.attention.self.key.weight
# 2023-09-17 11:36:25,596 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.3.attention.self.query.bias
# 2023-09-17 11:36:25,596 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.3.attention.self.query.weight
# 2023-09-17 11:36:25,596 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.3.attention.self.value.bias
# 2023-09-17 11:36:25,596 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.3.attention.self.value.weight
# 2023-09-17 11:36:25,596 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.3.intermediate.dense.bias
# 2023-09-17 11:36:25,596 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.3.intermediate.dense.weight
# 2023-09-17 11:36:25,596 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.3.output.LayerNorm.bias
# 2023-09-17 11:36:25,596 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.3.output.LayerNorm.weight
# 2023-09-17 11:36:25,597 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.3.output.dense.bias
# 2023-09-17 11:36:25,597 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.3.output.dense.weight
# 2023-09-17 11:36:25,597 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.4.attention.output.LayerNorm.bias
# 2023-09-17 11:36:25,597 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.4.attention.output.LayerNorm.weight
# 2023-09-17 11:36:25,597 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.4.attention.output.dense.bias
# 2023-09-17 11:36:25,597 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.4.attention.output.dense.weight
# 2023-09-17 11:36:25,597 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.4.attention.self.key.bias
# 2023-09-17 11:36:25,597 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.4.attention.self.key.weight
# 2023-09-17 11:36:25,597 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.4.attention.self.query.bias
# 2023-09-17 11:36:25,597 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.4.attention.self.query.weight
# 2023-09-17 11:36:25,597 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.4.attention.self.value.bias
# 2023-09-17 11:36:25,597 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.4.attention.self.value.weight
# 2023-09-17 11:36:25,597 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.4.intermediate.dense.bias
# 2023-09-17 11:36:25,597 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.4.intermediate.dense.weight
# 2023-09-17 11:36:25,597 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.4.output.LayerNorm.bias
# 2023-09-17 11:36:25,597 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.4.output.LayerNorm.weight
# 2023-09-17 11:36:25,597 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.4.output.dense.bias
# 2023-09-17 11:36:25,597 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.4.output.dense.weight
# 2023-09-17 11:36:25,597 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.5.attention.output.LayerNorm.bias
# 2023-09-17 11:36:25,597 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.5.attention.output.LayerNorm.weight
# 2023-09-17 11:36:25,597 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.5.attention.output.dense.bias
# 2023-09-17 11:36:25,597 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.5.attention.output.dense.weight
# 2023-09-17 11:36:25,597 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.5.attention.self.key.bias
# 2023-09-17 11:36:25,597 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.5.attention.self.key.weight
# 2023-09-17 11:36:25,597 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.5.attention.self.query.bias
# 2023-09-17 11:36:25,597 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.5.attention.self.query.weight
# 2023-09-17 11:36:25,597 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.5.attention.self.value.bias
# 2023-09-17 11:36:25,597 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.5.attention.self.value.weight
# 2023-09-17 11:36:25,597 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.5.intermediate.dense.bias
# 2023-09-17 11:36:25,597 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.5.intermediate.dense.weight
# 2023-09-17 11:36:25,597 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.5.output.LayerNorm.bias
# 2023-09-17 11:36:25,597 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.5.output.LayerNorm.weight
# 2023-09-17 11:36:25,597 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.5.output.dense.bias
# 2023-09-17 11:36:25,597 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.5.output.dense.weight
# 2023-09-17 11:36:25,597 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.6.attention.output.LayerNorm.bias
# 2023-09-17 11:36:25,597 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.6.attention.output.LayerNorm.weight
# 2023-09-17 11:36:25,597 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.6.attention.output.dense.bias
# 2023-09-17 11:36:25,598 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.6.attention.output.dense.weight
# 2023-09-17 11:36:25,598 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.6.attention.self.key.bias
# 2023-09-17 11:36:25,598 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.6.attention.self.key.weight
# 2023-09-17 11:36:25,598 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.6.attention.self.query.bias
# 2023-09-17 11:36:25,598 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.6.attention.self.query.weight
# 2023-09-17 11:36:25,598 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.6.attention.self.value.bias
# 2023-09-17 11:36:25,598 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.6.attention.self.value.weight
# 2023-09-17 11:36:25,598 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.6.intermediate.dense.bias
# 2023-09-17 11:36:25,598 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.6.intermediate.dense.weight
# ...
# 2023-09-17 11:36:25,598 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.7.attention.output.dense.bias
# 2023-09-17 11:36:25,598 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.7.attention.output.dense.weight
# 2023-09-17 11:36:25,598 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.7.attention.self.key.bias
# 2023-09-17 11:36:25,598 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.7.attention.self.key.weight
# 2023-09-17 11:36:25,598 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.7.attention.self.query.bias
# 2023-09-17 11:36:25,598 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.7.attention.self.query.weight
# 2023-09-17 11:36:25,598 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.7.attention.self.value.bias
# 2023-09-17 11:36:25,598 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.7.attention.self.value.weight
# 2023-09-17 11:36:25,598 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.7.intermediate.dense.bias
# 2023-09-17 11:36:25,598 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.7.intermediate.dense.weight
# 2023-09-17 11:36:25,598 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.7.output.LayerNorm.bias
# 2023-09-17 11:36:25,598 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.7.output.LayerNorm.weight
# 2023-09-17 11:36:25,598 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.7.output.dense.bias
# 2023-09-17 11:36:25,598 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.7.output.dense.weight
# 2023-09-17 11:36:25,598 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.8.attention.output.LayerNorm.bias
# 2023-09-17 11:36:25,598 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.8.attention.output.LayerNorm.weight
# 2023-09-17 11:36:25,598 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.8.attention.output.dense.bias
# 2023-09-17 11:36:25,598 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.8.attention.output.dense.weight
# 2023-09-17 11:36:25,598 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.8.attention.self.key.bias
# 2023-09-17 11:36:25,598 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.8.attention.self.key.weight
# 2023-09-17 11:36:25,598 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.8.attention.self.query.bias
# 2023-09-17 11:36:25,598 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.8.attention.self.query.weight
# 2023-09-17 11:36:25,598 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.8.attention.self.value.bias
# 2023-09-17 11:36:25,598 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.8.attention.self.value.weight
# 2023-09-17 11:36:25,598 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.8.intermediate.dense.bias
# 2023-09-17 11:36:25,598 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.8.intermediate.dense.weight
# 2023-09-17 11:36:25,599 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.8.output.LayerNorm.bias
# 2023-09-17 11:36:25,599 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.8.output.LayerNorm.weight
# 2023-09-17 11:36:25,599 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.8.output.dense.bias
# 2023-09-17 11:36:25,599 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.8.output.dense.weight
# 2023-09-17 11:36:25,599 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.9.attention.output.LayerNorm.bias
# 2023-09-17 11:36:25,599 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.9.attention.output.LayerNorm.weight
# 2023-09-17 11:36:25,599 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.9.attention.output.dense.bias
# 2023-09-17 11:36:25,599 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.9.attention.output.dense.weight
# 2023-09-17 11:36:25,599 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.9.attention.self.key.bias
# 2023-09-17 11:36:25,599 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.9.attention.self.key.weight
# 2023-09-17 11:36:25,599 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.9.attention.self.query.bias
# 2023-09-17 11:36:25,599 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.9.attention.self.query.weight
# 2023-09-17 11:36:25,599 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.9.attention.self.value.bias
# 2023-09-17 11:36:25,599 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.9.attention.self.value.weight
# 2023-09-17 11:36:25,599 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.9.intermediate.dense.bias
# 2023-09-17 11:36:25,599 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.9.intermediate.dense.weight
# 2023-09-17 11:36:25,599 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.9.output.LayerNorm.bias
# 2023-09-17 11:36:25,599 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.9.output.LayerNorm.weight
# 2023-09-17 11:36:25,599 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.9.output.dense.bias
# 2023-09-17 11:36:25,599 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.encoder.layer.9.output.dense.weight
# 2023-09-17 11:36:25,599 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.pooler.dense.bias
# 2023-09-17 11:36:25,599 - INFO - allennlp.nn.initializers -    _embedder.token_embedder_bert._matched_embedder.transformer_model.pooler.dense.weight
# 2023-09-17 11:36:25,599 - INFO - allennlp.nn.initializers -    _events._distance_embedding.weight
# 2023-09-17 11:36:25,599 - INFO - allennlp.nn.initializers -    _ner._ner_scorers.None__ner_labels.0._module._linear_layers.0.bias
# 2023-09-17 11:36:25,599 - INFO - allennlp.nn.initializers -    _ner._ner_scorers.None__ner_labels.0._module._linear_layers.0.weight
# 2023-09-17 11:36:25,599 - INFO - allennlp.nn.initializers -    _ner._ner_scorers.None__ner_labels.0._module._linear_layers.1.bias
# 2023-09-17 11:36:25,599 - INFO - allennlp.nn.initializers -    _ner._ner_scorers.None__ner_labels.0._module._linear_layers.1.weight
# 2023-09-17 11:36:25,599 - INFO - allennlp.nn.initializers -    _ner._ner_scorers.None__ner_labels.1._module.bias
# 2023-09-17 11:36:25,599 - INFO - allennlp.nn.initializers -    _ner._ner_scorers.None__ner_labels.1._module.weight
# 2023-09-17 11:36:25,599 - INFO - allennlp.nn.initializers -    _relation._mention_pruners.None__relation_labels._scorer.0._module._linear_layers.0.bias
# 2023-09-17 11:36:25,599 - INFO - allennlp.nn.initializers -    _relation._mention_pruners.None__relation_labels._scorer.0._module._linear_layers.0.weight
# 2023-09-17 11:36:25,599 - INFO - allennlp.nn.initializers -    _relation._mention_pruners.None__relation_labels._scorer.0._module._linear_layers.1.bias
# 2023-09-17 11:36:25,599 - INFO - allennlp.nn.initializers -    _relation._mention_pruners.None__relation_labels._scorer.0._module._linear_layers.1.weight
# 2023-09-17 11:36:25,599 - INFO - allennlp.nn.initializers -    _relation._mention_pruners.None__relation_labels._scorer.1._module.bias
# 2023-09-17 11:36:25,599 - INFO - allennlp.nn.initializers -    _relation._mention_pruners.None__relation_labels._scorer.1._module.weight
# 2023-09-17 11:36:25,599 - INFO - allennlp.nn.initializers -    _relation._relation_feedforwards.None__relation_labels._linear_layers.0.bias
# 2023-09-17 11:36:25,599 - INFO - allennlp.nn.initializers -    _relation._relation_feedforwards.None__relation_labels._linear_layers.0.weight
# 2023-09-17 11:36:25,599 - INFO - allennlp.nn.initializers -    _relation._relation_feedforwards.None__relation_labels._linear_layers.1.bias
# 2023-09-17 11:36:25,599 - INFO - allennlp.nn.initializers -    _relation._relation_feedforwards.None__relation_labels._linear_layers.1.weight
# 2023-09-17 11:36:25,600 - INFO - allennlp.nn.initializers -    _relation._relation_scorers.None__relation_labels.bias
# 2023-09-17 11:36:25,600 - INFO - allennlp.nn.initializers -    _relation._relation_scorers.None__relation_labels.weight
# 2023-09-17 11:36:25,626 - INFO - root - Loading a model trained before embedding extension was implemented; pass an explicit vocab namespace if you want to extend the vocabulary.
# 2023-09-17 11:36:25,628 - INFO - root - Loading a model trained before embedding extension was implemented; pass an explicit vocab namespace if you want to extend the vocabulary.
# 2023-09-17 11:36:25,629 - INFO - root - Loading a model trained before embedding extension was implemented; pass an explicit vocab namespace if you want to extend the vocabulary.
# 2023-09-17 11:36:25,872 - INFO - allennlp.common.params - dataset_reader.type = dygie
# 2023-09-17 11:36:25,872 - INFO - allennlp.common.params - dataset_reader.lazy = False
# 2023-09-17 11:36:25,872 - INFO - allennlp.common.params - dataset_reader.cache_directory = None
# 2023-09-17 11:36:25,872 - INFO - allennlp.common.params - dataset_reader.max_instances = None
# 2023-09-17 11:36:25,872 - INFO - allennlp.common.params - dataset_reader.manual_distributed_sharding = False
# 2023-09-17 11:36:25,872 - INFO - allennlp.common.params - dataset_reader.manual_multi_process_sharding = False
# 2023-09-17 11:36:25,872 - INFO - allennlp.common.params - dataset_reader.max_span_width = 8
# 2023-09-17 11:36:25,872 - INFO - allennlp.common.params - dataset_reader.token_indexers.bert.type = pretrained_transformer_mismatched
# 2023-09-17 11:36:25,872 - INFO - allennlp.common.params - dataset_reader.token_indexers.bert.token_min_padding_length = 0
# 2023-09-17 11:36:25,873 - INFO - allennlp.common.params - dataset_reader.token_indexers.bert.model_name = microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext
# 2023-09-17 11:36:25,873 - INFO - allennlp.common.params - dataset_reader.token_indexers.bert.namespace = tags
# 2023-09-17 11:36:25,873 - INFO - allennlp.common.params - dataset_reader.token_indexers.bert.max_length = 512
# reading instances: 2416it [00:00, 3455.65it/s]/home/pamessina/dygiepp/dygie/data/dataset_readers/dygie.py:195: UserWarning: Document /mnt/data/pamessina/workspaces/medvqa-workspace/tmp/radgraph/20230917_113603/10.txt has a sentence with a single token or no tokens. This may break the modeling code.
#   warnings.warn(msg)
# reading instances: 7198it [00:02, 2407.00it/s]/home/pamessina/dygiepp/dygie/data/dataset_readers/dygie.py:195: UserWarning: Document /mnt/data/pamessina/workspaces/medvqa-workspace/tmp/radgraph/20230917_113603/11.txt has a sentence with a single token or no tokens. This may break the modeling code.
#   warnings.warn(msg)
# reading instances: 7587it [00:02, 2730.42it/s]/home/pamessina/dygiepp/dygie/data/dataset_readers/dygie.py:195: UserWarning: Document /mnt/data/pamessina/workspaces/medvqa-workspace/tmp/radgraph/20230917_113603/53.txt has a sentence with a single token or no tokens. This may break the modeling code.
#   warnings.warn(msg)
# reading instances: 8617it [00:02, 2961.19it/s]
# 2023-09-17 11:43:25,071 - INFO - allennlp.models.archival - removing temporary unarchived model dir at /tmp/tmpysyrwfv9
# RadGraph labeler took 443.6417920589447 seconds
# Cache successfully updated and saved to /mnt/data/pamessina/workspaces/medvqa-workspace/cache/radgraph_labeler_cache_.pkl
# RadGraph: deleting temporary folder /mnt/data/pamessina/workspaces/medvqa-workspace/tmp/radgraph/20230917_113603 ...
# RadGraph: deleting output file /mnt/data/pamessina/workspaces/medvqa-workspace/tmp/radgraph/results/20230917_113603.jsonl ...
# Saving iuxray sentences and radgraph labels to /mnt/data/pamessina/workspaces/medvqa-workspace/cache/iuxray_sentences_and_radgraph_labels.pkl
# len(sentences): 8617
# len(labels): 8617
# Explicitly passing a `revision` is encouraged when loading a configuration with custom code to ensure no malicious code has been contributed in a newer revision.
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# checkpoint_names = ['checkpoint_81_cacc+chf1+chf1+cscc+hscc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9542.pt']
# Loading model weights from /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230916_194059_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/checkpoint_81_cacc+chf1+chf1+cscc+hscc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9542.pt
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# 100%|███████████████████████████████████████████| 87/87 [00:03<00:00, 22.43it/s]
# Embeddings shape: (8617, 128)
# 100%|██████████████████████████████████████| 8617/8617 [00:57<00:00, 150.19it/s]
# Saving embeddings to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230916_194059_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/embeddings(iuxray_radgraph).pkl
# Saving metrics to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230916_194059_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/mean_average_jaccard_up_to_500(iuxray_radgraph).pkl

# %%
# !python ../eval_fact_embedding_on_ranking.py \
--evaluation_mode "iuxray_radgraph_labeler" \
--method "microsoft/BiomedVLP-CXR-BERT-specialized" \
--model_checkpoint_folder_path \
"/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230925_020631_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph,NLI)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/" \
--batch_size 100 \
--top_k 500 \
--save_embeddings
# Out:
# script's arguments:
#    evaluation_mode: iuxray_radgraph_labeler
#    method: microsoft/BiomedVLP-CXR-BERT-specialized
#    device: GPU
#    batch_size: 100
#    num_workers: 4
#    model_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230925_020631_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph,NLI)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/
#    top_k: 500
#    save_embeddings: True
#    distance_metric: cosine
#    average_token_embeddings: False
# Loading iuxray sentences and radgraph labels from /mnt/data/pamessina/workspaces/medvqa-workspace/cache/iuxray_sentences_and_radgraph_labels.pkl
# len(sentences): 8617
# len(labels): 8617
# checkpoint_names = ['checkpoint_38_cacc+chf1+chf1+cscc+encc+hscc+nlcc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9311.pt']
#   0%|                                                  | 0/8617 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=442,4081940466550139603).pkl
# len(self.cache["hashes"]) = 103629
# self.cache["embeddings"].shape = (103629, 128)
# 100%|████████████████████████████████████| 8617/8617 [00:00<00:00, 93961.32it/s]
# Computing embeddings for 8266 new texts
# Explicitly passing a `revision` is encouraged when loading a configuration with custom code to ensure no malicious code has been contributed in a newer revision.
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# checkpoint_names = ['checkpoint_38_cacc+chf1+chf1+cscc+encc+hscc+nlcc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9311.pt']
# Loading model weights from /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20230925_020631_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph,NLI)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/checkpoint_38_cacc+chf1+chf1+cscc+encc+hscc+nlcc+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9311.pt
# Warning: model state dict has 211 keys, loaded state dict has 227 keys, intersection has 211 keys, union has 227 keys.
# Examples of keys in loaded state dict but not in model:
#   chest_imagenome_anatloc_classifier.weight
#   nli_classifier.bias
#   comparison_status_classifier.weight
#   category_classifier.weight
#   category_classifier.bias
#   nli_hidden_layer.bias
#   comparison_status_classifier.bias
#   health_status_classifier.weight
#   chest_imagenome_anatloc_classifier.bias
#   aux_task_hidden_layer.weight
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# 100%|███████████████████████████████████████████| 83/83 [00:07<00:00, 11.65it/s]
# Saving updated cache to /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=442,4081940466550139603).pkl
# 100%|███████████████████████████████████| 8266/8266 [00:00<00:00, 335359.32it/s]
# Embeddings shape: (8617, 128)
# 100%|███████████████████████████████████████| 8617/8617 [02:23<00:00, 60.15it/s]
# Saving embeddings to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230925_020631_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph,NLI)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/embeddings(iuxray_radgraph).pkl
# Saving metrics to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230925_020631_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph,NLI)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/mean_average_jaccard_up_to_500(iuxray_radgraph,cosine).pkl

# %%
# !python ../eval_fact_embedding_on_ranking.py \
--evaluation_mode "iuxray_radgraph_labeler" \
--method "BioLinkBERT-large" \
--batch_size 100 \
--top_k 500 \
--distance_metric "cosine" \
--save_embeddings
# Out:
# script's arguments:
#    evaluation_mode: iuxray_radgraph_labeler
#    method: BioLinkBERT-large
#    device: GPU
#    batch_size: 100
#    num_workers: 4
#    model_checkpoint_folder_path: None
#    top_k: 500
#    save_embeddings: True
#    distance_metric: cosine
# Loading iuxray sentences and radgraph labels from /mnt/data/pamessina/workspaces/medvqa-workspace/cache/iuxray_sentences_and_radgraph_labels.pkl
# len(sentences): 8617
# len(labels): 8617
#   0%|                                                  | 0/8617 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=93,2426007785506037214).pkl
# len(self.cache["hashes"]) = 1165
# self.cache["embeddings"].shape = (1165, 1024)
# 100%|███████████████████████████████████| 8617/8617 [00:00<00:00, 508202.11it/s]
# Computing embeddings for 8617 new texts
# 100%|███████████████████████████████████████████| 87/87 [00:13<00:00,  6.65it/s]
# Saving updated cache to /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=93,2426007785506037214).pkl
# 100%|███████████████████████████████████| 8617/8617 [00:00<00:00, 489169.89it/s]
# Embeddings shape: (8617, 1024)
# 100%|███████████████████████████████████████| 8617/8617 [07:12<00:00, 19.94it/s]
# Saving embeddings to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230919_150339_iuxray_radgraph_BioLinkBERT-large/embeddings(iuxray_radgraph).pkl
# Saving metrics to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230919_150339_iuxray_radgraph_BioLinkBERT-large/mean_average_jaccard_up_to_500(iuxray_radgraph,cosine).pkl

# %%
# !python ../eval_fact_embedding_on_ranking.py \
--evaluation_mode "iuxray_radgraph_labeler" \
--method "BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext" \
--batch_size 100 \
--top_k 500 \
--distance_metric "cosine" \
--save_embeddings
# Out:
# script's arguments:
#    evaluation_mode: iuxray_radgraph_labeler
#    method: BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext
#    device: GPU
#    batch_size: 100
#    num_workers: 4
#    model_checkpoint_folder_path: None
#    top_k: 500
#    save_embeddings: True
#    distance_metric: cosine
# Loading iuxray sentences and radgraph labels from /mnt/data/pamessina/workspaces/medvqa-workspace/cache/iuxray_sentences_and_radgraph_labels.pkl
# len(sentences): 8617
# len(labels): 8617
#   0%|                                                  | 0/8617 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=127,2153880556179949937).pkl
# len(self.cache["hashes"]) = 1165
# self.cache["embeddings"].shape = (1165, 768)
# 100%|███████████████████████████████████| 8617/8617 [00:00<00:00, 529038.42it/s]
# Computing embeddings for 8617 new texts
# Some weights of the model checkpoint at microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext were not used when initializing BertModel: ['cls.predictions.decoder.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 100%|███████████████████████████████████████████| 87/87 [00:04<00:00, 17.63it/s]
# Saving updated cache to /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=127,2153880556179949937).pkl
# 100%|███████████████████████████████████| 8617/8617 [00:00<00:00, 517375.75it/s]
# Embeddings shape: (8617, 768)
# 100%|███████████████████████████████████████| 8617/8617 [04:55<00:00, 29.19it/s]
# Saving embeddings to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230919_151642_iuxray_radgraph_BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext/embeddings(iuxray_radgraph).pkl
# Saving metrics to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230919_151642_iuxray_radgraph_BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext/mean_average_jaccard_up_to_500(iuxray_radgraph,cosine).pkl

# %%
# !python ../eval_fact_embedding_on_ranking.py \
--evaluation_mode "iuxray_radgraph_labeler" \
--method "Bio_ClinicalBERT" \
--batch_size 100 \
--top_k 500 \
--distance_metric "cosine" \
--save_embeddings
# Out:
# script's arguments:
#    evaluation_mode: iuxray_radgraph_labeler
#    method: Bio_ClinicalBERT
#    device: GPU
#    batch_size: 100
#    num_workers: 4
#    model_checkpoint_folder_path: None
#    top_k: 500
#    save_embeddings: True
#    distance_metric: cosine
# Loading iuxray sentences and radgraph labels from /mnt/data/pamessina/workspaces/medvqa-workspace/cache/iuxray_sentences_and_radgraph_labels.pkl
# len(sentences): 8617
# len(labels): 8617
#   0%|                                                  | 0/8617 [00:00<?, ?it/s]Loading cached text embeddings from /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=92,1378835921707653686).pkl
# len(self.cache["hashes"]) = 1165
# self.cache["embeddings"].shape = (1165, 768)
# 100%|███████████████████████████████████| 8617/8617 [00:00<00:00, 517516.50it/s]
# Computing embeddings for 8617 new texts
# Some weights of the model checkpoint at emilyalsentzer/Bio_ClinicalBERT were not used when initializing BertModel: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 100%|███████████████████████████████████████████| 87/87 [00:05<00:00, 15.21it/s]
# Saving updated cache to /mnt/workspace/pamessina/medvqa-workspace/cache/text_embeddings_cache(hash=92,1378835921707653686).pkl
# 100%|███████████████████████████████████| 8617/8617 [00:00<00:00, 576395.73it/s]
# Embeddings shape: (8617, 768)
# 100%|███████████████████████████████████████| 8617/8617 [04:53<00:00, 29.40it/s]
# Saving embeddings to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230919_151132_iuxray_radgraph_Bio_ClinicalBERT/embeddings(iuxray_radgraph).pkl
# Saving metrics to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230919_151132_iuxray_radgraph_Bio_ClinicalBERT/mean_average_jaccard_up_to_500(iuxray_radgraph,cosine).pkl

# %%
# !python ../eval_fact_embedding.py \
--evaluation_mode "iuxray_radgraph_labeler" \
--method "oracle" \
--batch_size 100 \
--top_k 500 \
--save_embeddings
# Out:
# script's arguments:
#    evaluation_mode: iuxray_radgraph_labeler
#    method: oracle
#    device: GPU
#    batch_size: 100
#    num_workers: 4
#    model_checkpoint_folder_path: None
#    top_k: 500
#    save_embeddings: True
# Loading iuxray sentences and radgraph labels from /mnt/data/pamessina/workspaces/medvqa-workspace/cache/iuxray_sentences_and_radgraph_labels.pkl
# len(sentences): 8617
# len(labels): 8617
# 100%|███████████████████████████████████████| 8617/8617 [01:40<00:00, 85.90it/s]
# Saving labels to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230806_202920_iuxray_radgraph_oracle/labels.pkl
# Saving metrics to /mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230806_202920_iuxray_radgraph_oracle/mean_average_jaccard_up_to_500(iuxray_radgraph).pkl

# %%
from medvqa.utils.files import load_pickle
from medvqa.evaluation.plots import plot_metric_lists

metric_paths = [
    '/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230806_201914_iuxray_radgraph_cxr-bert-specialized/mean_average_jaccard_up_to_500(iuxray_radgraph).pkl',
    '/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230806_202054_iuxray_radgraph_biovil-t/mean_average_jaccard_up_to_500(iuxray_radgraph).pkl',
    '/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230730_012705_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/mean_average_jaccard_up_to_500(iuxray_radgraph).pkl',
    '/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230815_111024_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/mean_average_jaccard_up_to_500(iuxray_radgraph).pkl',
    '/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230820_223655_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph)_FactEncoder(microsoft-BiomedVLP-BioViL-T)/mean_average_jaccard_up_to_500(iuxray_radgraph).pkl',
    '/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230823_124048_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/mean_average_jaccard_up_to_500(iuxray_radgraph).pkl',
    '/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230916_194059_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/mean_average_jaccard_up_to_500(iuxray_radgraph).pkl',
    '/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230925_020631_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph,NLI)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/mean_average_jaccard_up_to_500(iuxray_radgraph,cosine).pkl',
    
    '/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230806_202920_iuxray_radgraph_oracle/mean_average_jaccard_up_to_500(iuxray_radgraph).pkl',
    '/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230919_150339_iuxray_radgraph_BioLinkBERT-large/mean_average_jaccard_up_to_500(iuxray_radgraph,cosine).pkl',
    '/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230919_151132_iuxray_radgraph_Bio_ClinicalBERT/mean_average_jaccard_up_to_500(iuxray_radgraph,cosine).pkl',
    '/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230919_151642_iuxray_radgraph_BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext/mean_average_jaccard_up_to_500(iuxray_radgraph,cosine).pkl',
]
metric_lists = [load_pickle(x) for x in metric_paths]
method_names = [
    'CXR-BERT-specialized (ECCV 2022)',
    'BioViL-T (CVPR 2023)',
    'Fact Embedding (CXR-BERT-specialized fine-tuned)',
    'Fact Embedding (CXR-BERT-specialized fine-tuned) (+ RadGraph triplets)',
    'Fact Embedding (BioViL-T fine-tuned) (+ RadGraph triplets + Anatomy classification)',
    'Fact Embedding (CXR-BERT-specialized fine-tuned) (+ RadGraph triplets + Anatomy classification)',
    'Fact Embedding (20230916_194059)',
    'Fact Embedding (20230925_020631)',
    
    'Theoretical Upper Bound',
    'BioLinkBERT-large',
    'BioClinicalBERT',
    'PubMedBERT',
]
plot_metric_lists(
    metric_lists=metric_lists,
    method_names=method_names,
    title="Mean Average Jaccard Score @ K (IU X-ray, RadGraph, 8617 sentences)",
    metric_name='Mean Average Jaccard Score @ K',
    xlabel="K",
    figsize=(10, 5),
)

# %%
from medvqa.utils.files import load_pickle
from medvqa.evaluation.plots import plot_metric_lists

metric_paths = [
    '/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230806_201914_iuxray_radgraph_cxr-bert-specialized/mean_average_jaccard_up_to_500(iuxray_radgraph).pkl',
    '/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230806_202054_iuxray_radgraph_biovil-t/mean_average_jaccard_up_to_500(iuxray_radgraph).pkl',
#     '/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230730_012705_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/mean_average_jaccard_up_to_500(iuxray_radgraph).pkl',
#     '/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230815_111024_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/mean_average_jaccard_up_to_500(iuxray_radgraph).pkl',
#     '/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230820_223655_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph)_FactEncoder(microsoft-BiomedVLP-BioViL-T)/mean_average_jaccard_up_to_500(iuxray_radgraph).pkl',
    '/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230823_124048_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/mean_average_jaccard_up_to_500(iuxray_radgraph).pkl',
    '/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230916_194059_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/mean_average_jaccard_up_to_500(iuxray_radgraph).pkl',
    '/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230806_202920_iuxray_radgraph_oracle/mean_average_jaccard_up_to_500(iuxray_radgraph).pkl',
    '/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230919_150339_iuxray_radgraph_BioLinkBERT-large/mean_average_jaccard_up_to_500(iuxray_radgraph,cosine).pkl',
    '/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230919_151132_iuxray_radgraph_Bio_ClinicalBERT/mean_average_jaccard_up_to_500(iuxray_radgraph,cosine).pkl',
    '/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230919_151642_iuxray_radgraph_BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext/mean_average_jaccard_up_to_500(iuxray_radgraph,cosine).pkl',
]
metric_lists = [load_pickle(x) for x in metric_paths]
method_names = [
    'CXR-BERT-specialized (ECCV 2022)',
    'BioViL-T (CVPR 2023)',
#     'Fact Embedding (CXR-BERT-specialized fine-tuned)',
#     'Fact Embedding (CXR-BERT-specialized fine-tuned) (+ RadGraph triplets)',
#     'Fact Embedding (BioViL-T fine-tuned) (+ RadGraph triplets + Anatomy classification)',
    'CXR Fact Embedding (w/o ChatGPT hard triplets)', # 'Fact Embedding (CXR-BERT-specialized fine-tuned) (+ RadGraph triplets + Anatomy classification)',
    'CXR Fact Embedding (with ChatGPT hard triplets)', # 'CXR Fact Embedding (20230916_194059)',
    'Theoretical Upper Bound',
    'BioLinkBERT-large (ACL 2022)',
    'BioClinicalBERT (NAACL 2019)',
    'PubMedBERT (ACM trans. comput. healthc. 2020)',
]
plot_metric_lists(
    metric_lists=metric_lists,
    method_names=method_names,
    title="Mean Average RadGraph Jaccard Score @ K (IU X-ray, 8617 sentences)",
    metric_name='Mean Average RadGraph Jaccard Score @ K',
    xlabel="K",
    figsize=(10, 8),
)

# %%
embeddings_list_4 = [
#     load_pickle('/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230806_201914_iuxray_radgraph_cxr-bert-specialized/embeddings(iuxray_radgraph).pkl'),
#     load_pickle('/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230806_202054_iuxray_radgraph_biovil-t/embeddings(iuxray_radgraph).pkl'),
#     load_pickle('/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230730_012705_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/embeddings(iuxray_radgraph).pkl'),
#     load_pickle('/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230823_124048_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/embeddings(iuxray_radgraph).pkl'),
    load_pickle('/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230916_194059_MIMIC-CXR(GPT3.5,GPT4,CXR-BERT,triplet_loss,ChestImaGenome,RadGraph)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/embeddings(iuxray_radgraph).pkl'),
#     load_pickle('/mnt/data/pamessina/workspaces/medvqa-workspace/results/fact_embedding/20230806_202920_iuxray_radgraph_oracle/labels.pkl'),
]
method_names_4 = [
#     'CXR-BERT-specialized (ECCV 2022)',
#     'BioViL-T (CVPR 2023)',
#     'Fact Embedding (CXR-BERT-specialized fine-tuned)',
#     'Fact Embedding (CXR-BERT-specialized fine-tuned) (+ RadGraph triplets + Anatomy classification)',
    'Fact Embedding (20230916_194059)',
#     'Theoretical Upper Bound',
]

# %%
rank_sentences(embeddings_list_4, method_names_4, embeddings_list_4[-1]['labels'], metric='jaccard')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 rank_sentences(embeddings_list_4, method_names_4, embeddings_list_4[-1]['labels'], metric='jaccard')
#
# KeyError: 'labels'

# %%
from medvqa.utils.files import load_pickle

# %%
tmp = load_pickle('/mnt/data/pamessina/workspaces/medvqa-workspace/cache/radgraph_labeler_cache.pkl')

# %%
# tmp['hash2labels']

# %%
len(tmp['label2string'])
# Out:
# 13040

# %%
tmp2 = load_pickle('/mnt/data/pamessina/workspaces/medvqa-workspace/cache/iuxray_sentences_and_radgraph_labels.pkl')

# %%
x = -104
print(tmp2['sentences'][x])
# print()
# print(tmp2['labels'][x])
print()
strings = []
for y in tmp2['labels'][x]:
    strings.append(tmp['label2string'][y])
for x in sorted(strings, key=lambda x:(len(x), x)):
    print(x)
# Out:
# This may irregular pleural-parenchymal scarring, however, recommend comparison with more remote outside imaging, if available to determine long-term stability.
#
# scarring|OBS-U
# irregular|OBS-U
