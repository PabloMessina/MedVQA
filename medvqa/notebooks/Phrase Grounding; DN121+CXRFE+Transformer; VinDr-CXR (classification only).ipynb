# %%
# %env CUDA_VISIBLE_DEVICES=1
# Out:
# env: CUDA_VISIBLE_DEVICES=1

# %%
# !python ../train_phrase_grounding.py \
--epochs 120 \
--batches_per_epoch 600 \
--max_images_per_batch 20 \
--max_phrases_per_batch 400 \
--max_phrases_per_image 45 \
--val_batch_size_factor 2.0 \
--raw_image_encoding "densenet-121" \
--image_size 416 416 \
--image_local_feat_size 1024 \
--num_regions 169 \
--regions_width 13 \
--regions_height 13 \
--img_aug_mode "random-color-and-spatial" \
--phrase_embedding_size 128 \
--phrase_grounding_mode "transformer_encoder__no_grounding" \
--transf_d_model 256 \
--transf_nhead 4 \
--transf_dim_feedforward 256 \
--transf_num_layers 2 \
--num_train_workers 2 \
--num_val_workers 2 \
--gradient_accumulation_steps 10 \
--optimizer_name "adamw" \
--scheduler "exp-warmup+decay+cyclicdecay" \
--lr 1e-6 \
--warmup_decay_and_cyclic_decay_args "1e-6,3,8e-5,5,1e-6,8e-5,5,1e-6" \
--binary_multilabel_classif_loss_name "focal+bce+npbbce" \
--use_vinbig_for_train \
--use_vinbig_for_test \
--vinbig_phrase_embeddings_filepath \
"/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/vinbig/label_phrase_embeddings(hash=353,2491289492560726319).pkl" \
--save
# Out:
# script's arguments:
#    epochs: 120
#    batches_per_epoch: 600
#    max_images_per_batch: 20
#    max_phrases_per_batch: 400
#    max_phrases_per_image: 45
#    val_batch_size_factor: 2.0
#    checkpoint_folder: None
#    pretrained_checkpoint_folder_path: None
#    pretrained_checkpoint_folder_paths: None
#    freeze_image_encoder: False
#    raw_image_encoding: densenet-121
#    huggingface_model_name: None
#    num_regions: 169
#    image_local_feat_size: 1024
#    image_encoder_pretrained_weights_path: None
#    image_encoder_dropout_p: 0
#    yolov8_model_name_or_path: None
#    yolov8_model_alias: None
#    phrase_embedding_size: 128
#    regions_width: 13
#    regions_height: 13
#    qkv_size: None
#    phrase_grounding_mode: transformer_encoder__no_grounding
#    phrase_classifier_hidden_size: None
#    transf_d_model: 256
#    transf_nhead: 4
#    transf_dim_feedforward: 256
#    transf_dropout: 0
#    transf_num_layers: 2
#    visual_feature_proj_size: None
#    visual_grounding_hidden_size: None
#    phrase_mlp_hidden_dims: None
#    predict_global_alignment: False
#    alignment_proj_size: None
#    optimizer_name: adamw
#    lr: 1e-06
#    scheduler: exp-warmup+decay+cyclicdecay
#    lr_decay: 0.76
#    lr_decay_patience: 2
#    warmup_and_decay_args: None
#    warmup_and_cosine_args: None
#    warmup_decay_and_cyclic_decay_args: 1e-6,3,8e-5,5,1e-6,8e-5,5,1e-6
#    gradient_accumulation_steps: 10
#    override_lr: False
#    max_grad_norm: None
#    attention_supervision_loss_weight: 1.0
#    phrase_classifier_loss_weight: 1.0
#    foreground_loss_weight: 1.0
#    background_loss_weight: 1.0
#    focal_loss_weight: 1.0
#    bce_loss_weight: 1.0
#    wbce_loss_weight: 1.0
#    binary_multilabel_classif_loss_name: focal+bce+npbbce
#    use_weighted_phrase_classifier_loss: False
#    cluster_and_label_weights_for_facts_filepath: None
#    use_attention_regularization_loss: False
#    use_contrastive_phrase_grounding_loss: False
#    nt_xent_temperature: 0.1
#    num_train_workers: 2
#    num_val_workers: 2
#    device: GPU
#    use_amp: False
#    image_size: [416, 416]
#    dicom_id_to_pos_neg_facts_filepath: None
#    iuxray_image_id_to_pos_neg_facts_filepath: None
#    mscxr_phrase2embedding_filepath: None
#    chest_imagenome_bbox_phrase_embeddings_filepath: None
#    vinbig_phrase_embeddings_filepath: /mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/vinbig/label_phrase_embeddings(hash=353,2491289492560726319).pkl
#    chexlocalize_class_phrase_embeddings_filepath: None
#    chexpert_class_phrase_embeddings_filepath: None
#    mimiccxr_exclude_noisy_images: False
#    mimiccxr_facts_weight: 1.0
#    chest_imagenome_anatlocs_weight: 1.0
#    mscxr_weight: 1.0
#    cxrlt2024_weight: 1.0
#    vinbig_weight: 1.0
#    chexlocalize_weight: 1.0
#    chexpert_weight: 1.0
#    iuxray_weight: 1.0
#    img_aug_mode: random-color-and-spatial
#    pos_area_prior: 0.4
#    neg_area_prior: 0.0
#    use_mimiccxr_facts_for_train: False
#    use_mimiccxr_facts_for_test: False
#    use_mscxr_for_train: False
#    use_mscxr_for_test: False
#    use_chest_imagenome_for_train: False
#    use_chest_imagenome_gold_for_test: False
#    use_vinbig_for_train: True
#    use_vinbig_for_test: True
#    use_chexlocalize_for_train: False
#    use_chexlocalize_for_test: False
#    use_chexpert_for_train: False
#    use_chexpert_for_test: False
#    use_iuxray_for_train: False
#    use_iuxray_for_test: False
#    use_cxrlt2024_challenge_split: False
#    use_cxrlt2024_custom_labels: False
#    use_cxrlt2024_official_labels: False
#    use_all_cxrlt2024_official_labels_for_training: False
#    vinbig_training_data_mode: train
#    chexpert_training_data_mode: all
#    mimiccxr_balance_long_middle_short_tail: False
#    mimiccxr_long_middle_short_tail_thresholds: (0.02, 0.05)
#    mimiccxr_report_fact_nli_integrated_data_filepath: None
#    mimiccxr_use_interpret_cxr_challenge_split: False
#    mimiccxr_interpret_cxr_challenge_split_filepath: None
#    iuxray_use_interpret_cxr_challenge_split: False
#    iuxray_interpret_cxr_challenge_split_filepath: None
#    chexpert_use_interpret_cxr_challenge_split: False
#    chexpert_interpret_cxr_challenge_split_filepath: None
#    chexlocalize_use_interpret_cxr_challenge_split: False
#    chexlocalize_interpret_cxr_challenge_split_filepath: None
#    cxrlt2024_custom_dicom_id_to_pos_neg_facts_filepath: None
#    cxrlt2024_official_training_labels_for_fact_classification_filepath: None
#    cxrlt2024_do_balanced_sampling: False
#    do_visual_grounding_with_bbox_regression: False
#    do_visual_grounding_with_segmentation: False
#    save: True
# ----- Training model from scratch ------
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Creating instance of PhraseGrounder ...
# WARNING: Unused kwargs: {'pretrained_checkpoint_folder_path': None, 'pretrained_checkpoint_folder_paths': None}
# MultiPurposeVisualModule()
#   Initializing raw_image_encoder: densenet-121
# create_densenet121_feature_extractor()
#    drop_rate: 0
# DenseNet121's default weights loaded
#   self.global_feat_size = 2048
#   self.local_feat_size = 1024
#   Initializing auxiliary tasks
# --------------------------------------------------
# 3) Defining optimizer ...
# create_optimizer(): name = adamw
# --------------------------------------------------
# 4) Defining scheduler ...
# Using exp-warmup+decay+cyclicdecay scheduler: 1e-6,3,8e-5,5,1e-6,8e-5,5,1e-6
# 1e-06 3 8e-05 5 1e-06 8e-05 5 1e-06
# self.steps_to_restart = 5
# self.steps = -1
# self.initial_lr = 8e-05
# --------------------------------------------------
# 5) Creating trainer and validator engines ...
# Focal_BCE_NPBBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 npbbce_weight = 0.3333333333333333
# Focal_BCE_NPBBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 npbbce_weight = 0.3333333333333333
# Focal_BCE_WBCBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 wbcbce_weight = 0.3333333333333333
# foreground_loss_weight: 1.0
# background_loss_weight: 1.0
# GradientAccumulator.__init__(): num_accumulation_steps = 10, max_grad_norm = None
# Focal_BCE_NPBBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 npbbce_weight = 0.3333333333333333
# Focal_BCE_NPBBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 npbbce_weight = 0.3333333333333333
# Focal_BCE_WBCBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 wbcbce_weight = 0.3333333333333333
# foreground_loss_weight: 1.0
# background_loss_weight: 1.0
# --------------------------------------------------
# 6) Creating VinBig Phrase Grounding Trainer ...
# get_image_transform()
# Using standard transform (only images, no bounding boxes, no masks)
# mean = (0.485, 0.456, 0.406), std = (0.229, 0.224, 0.225), image_size = [416, 416]
# default_prob = 0.35
# Returning augmented transforms with mode random-color-and-spatial
# get_image_transform()
# Using standard transform (only images, no bounding boxes, no masks)
# mean = (0.485, 0.456, 0.406), std = (0.229, 0.224, 0.225), image_size = [416, 416]
# Returning transform without augmentation
# Loading bounding boxes
# Anomalous bboxes found: 29 of 37367
# class_id_offset: 0
# Anomalous bboxes found: 0 of 2697
# class_id_offset: 0
#   Loaded 18000 bounding boxes
# Loding phrase_embeddings and phrases from /mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/vinbig/label_phrase_embeddings(hash=353,2491289492560726319).pkl...
# phrase_embeddings.shape = (28, 128)
# len(phrases) = 28
# 	 aortic enlargement seen
# 	 atelectasis seen
# 	 calcification seen
# 	 cardiomegaly seen
# 	 clavicle fracture seen
# 	 consolidation seen
# 	 edema seen
# 	 emphysema seen
# 	 enlarged pulmonary artery seen
# 	 interstitial lung disease seen
# 	 infiltration seen
# 	 lung opacity seen
# 	 lung cavity seen
# 	 lung cyst seen
# 	 mediastinal shift seen
# 	 nodule/mass seen
# 	 pleural effusion seen
# 	 pleural thickening seen
# 	 pneumothorax seen
# 	 pulmonary fibrosis seen
# 	 rib fracture seen
# 	 other lesion seen
# 	 copd seen
# 	 lung tumor seen
# 	 pneumonia seen
# 	 tuberculosis seen
# 	 other disease seen
# 	 no abnormalities seen
# Compute phrase grounding masks and labels
# self.phrase_grounding_masks.shape = (18000, 22, 169)
# self.phrase_classification_labels.shape = (18000, 22)
# Append additional labels to phrase_classification_labels
# len(non_bbox_labels) = 6
# non_bbox_labels = ['COPD', 'Lung tumor', 'Pneumonia', 'Tuberculosis', 'Other disease', 'No finding']
# self.phrase_classification_labels.shape = (18000, 28)
# Reorder phrases and phrase_embeddings
# len(phrases) = 28
# len(actual_phrases) = 28
# phrase_embeddings.shape = (28, 128)
# Generating train dataset and dataloader
# len(train_indices) = 15000
# No labels: 0
# Edema: 13
# Clavicle fracture: 27
# Lung cyst: 33
# COPD: 35
# Lung cavity: 51
# Emphysema: 81
# Rib fracture: 90
# Pneumothorax: 96
# Enlarged PA: 131
# Mediastinal shift: 150
# Atelectasis: 187
# Lung tumor: 291
# Consolidation: 353
# ILD: 397
# Calcification: 458
# Infiltration: 613
# Tuberculosis: 750
# Nodule/Mass: 841
# Pneumonia: 917
# Pleural effusion: 1038
# Other lesion: 1154
# Lung Opacity: 1331
# Pulmonary fibrosis: 1621
# Pleural thickening: 2010
# Cardiomegaly: 2316
# Aortic enlargement: 3098
# Other disease: 4288
# No finding: 10601
# Group sizes: [10478, 771, 323, 312, 286, 278, 258, 243, 241, 218, 215, 167, 159, 156, 122, 119, 112, 102, 84, 83, 79, 47, 45, 32, 70]
#   len(indices) = 10478, weight = 2381.9852437292775
#   len(indices) = 771, weight = 882.1360585110112
#   len(indices) = 323, weight = 579.1323556126193
#   len(indices) = 312, weight = 568.7753795323758
#   len(indices) = 286, weight = 543.3127950518186
#   len(indices) = 278, weight = 535.1778961104801
#   len(indices) = 258, weight = 514.1586596868186
#   len(indices) = 243, weight = 497.69925147612867
#   len(indices) = 241, weight = 495.4562099629317
#   len(indices) = 218, weight = 468.76865710351854
#   len(indices) = 215, weight = 465.15882500917724
#   len(indices) = 167, weight = 402.55283205217046
#   len(indices) = 159, weight = 391.0802349542582
#   len(indices) = 156, weight = 386.6879164039802
#   len(indices) = 122, weight = 332.9187999914028
#   len(indices) = 119, weight = 327.76937690454827
#   len(indices) = 112, weight = 315.45337872121524
#   len(indices) = 102, weight = 297.0647831080699
#   len(indices) = 84, weight = 261.20109767987407
#   len(indices) = 83, weight = 259.088791948487
#   len(indices) = 79, weight = 250.497443897163
#   len(indices) = 47, weight = 171.37827001640065
#   len(indices) = 45, weight = 165.6367630898417
#   len(indices) = 32, weight = 125.0
#   len(indices) = 70, weight = 230.2655804515992
# Generating val dataset and dataloader
# len(test_indices) = 3000
# --------------------------------------------------
# 7) Creating dataloaders ...
# len(vinbig_trainer.train_dataloader) = 71428571428571429
# len(vinbig_trainer.val_dataloader) = 108
# len(_train_dataloaders) = 1
# len(_val_dataloaders) = 1
# _train_weights = [1.0]
# merged_dataset_name = vinbig
# --------------------------------------------------
# 8) Attaching metrics, losses, timer and events to engines ...
# --------------------------------------------------
# 9) Defining learning rate scheduler handler ...
# --------------------------------------------------
# 10) Defining learning rate scheduler handler ...
# --------------------------------------------------
# 11) Defining checkpoint folder path ...
# checkpoint_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20241027_005334_vinbig_PhraseGrounder(dn121,TransformerEncoder_NoGrounding,128,256,4,256,2)
# metadata saved to /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20241027_005334_vinbig_PhraseGrounder(dn121,TransformerEncoder_NoGrounding,128,256,4,256,2)/metadata.json
# --------------------------------------------------
# 12) Defining log_metrics_handler ...
# MetricsLogger :: we'll be logging to /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20241027_005334_vinbig_PhraseGrounder(dn121,TransformerEncoder_NoGrounding,128,256,4,256,2)/metrics_logs.csv
# --------------------------------------------------
# 13) Running trainer engine ...
# ---- Epoch 1/120
# (1) Training stage (lr = 0.000001) ...
# loss 2.09770, vbg_phrcls_loss 2.09770, vbg_prc_auc 0.16382, 206.10 secs
# (2) Validation stage ...
# vbg_prc_auc 0.09259, 23.56 secs
# New checkpoint saved: checkpoint_1_vbg_prc_auc=0.0997.pt
# ---- Epoch 2/120
# (1) Training stage (lr = 0.000004) ...
# loss 1.57382, vbg_phrcls_loss 1.57382, vbg_prc_auc 0.16419, 208.68 secs
# (2) Validation stage ...
# vbg_prc_auc 0.11343, 24.16 secs
# New checkpoint saved: checkpoint_2_vbg_prc_auc=0.1185.pt
# ---- Epoch 3/120
# (1) Training stage (lr = 0.000019) ...
# loss 1.45220, vbg_phrcls_loss 1.45220, vbg_prc_auc 0.21551, 208.70 secs
# (2) Validation stage ...
# vbg_prc_auc 0.14894, 24.74 secs
# New checkpoint saved: checkpoint_3_vbg_prc_auc=0.1556.pt
# ---- Epoch 4/120
# (1) Training stage (lr = 0.000080) ...
# loss 1.40736, vbg_phrcls_loss 1.40736, vbg_prc_auc 0.24652, 210.83 secs
# (2) Validation stage ...
# vbg_prc_auc 0.16220, 25.51 secs
# New checkpoint saved: checkpoint_4_vbg_prc_auc=0.1706.pt
# ---- Epoch 5/120
# (1) Training stage (lr = 0.000033) ...
# loss 1.33046, vbg_phrcls_loss 1.33046, vbg_prc_auc 0.24674, 211.44 secs
# (2) Validation stage ...
# vbg_prc_auc 0.16554, 25.69 secs
# New checkpoint saved: checkpoint_5_vbg_prc_auc=0.1737.pt
# ---- Epoch 6/120
# (1) Training stage (lr = 0.000014) ...
# loss 1.29081, vbg_phrcls_loss 1.29081, vbg_prc_auc 0.26138, 211.72 secs
# (2) Validation stage ...
# vbg_prc_auc 0.16865, 25.49 secs
# New checkpoint saved: checkpoint_6_vbg_prc_auc=0.1779.pt
# ---- Epoch 7/120
# (1) Training stage (lr = 0.000006) ...
# loss 1.27240, vbg_phrcls_loss 1.27240, vbg_prc_auc 0.26658, 211.24 secs
# (2) Validation stage ...
# vbg_prc_auc 0.17324, 25.73 secs
# New checkpoint saved: checkpoint_7_vbg_prc_auc=0.1826.pt
# ---- Epoch 8/120
# (1) Training stage (lr = 0.000002) ...
# loss 1.26340, vbg_phrcls_loss 1.26340, vbg_prc_auc 0.27044, 211.59 secs
# (2) Validation stage ...
# vbg_prc_auc 0.17290, 25.77 secs
# New checkpoint saved: checkpoint_8_vbg_prc_auc=0.1827.pt
# ---- Epoch 9/120
# (1) Training stage (lr = 0.000001) ...
# loss 1.25785, vbg_phrcls_loss 1.25785, vbg_prc_auc 0.27460, 213.09 secs
# (2) Validation stage ...
# vbg_prc_auc 0.17944, 26.02 secs
# New checkpoint saved: checkpoint_9_vbg_prc_auc=0.1890.pt
# ---- Epoch 10/120
# (1) Training stage (lr = 0.000080) ...
# loss 1.26679, vbg_phrcls_loss 1.26679, vbg_prc_auc 0.25481, 212.11 secs
# (2) Validation stage ...
# vbg_prc_auc 0.17894, 25.96 secs
# ---- Epoch 11/120
# (1) Training stage (lr = 0.000027) ...
# loss 1.18262, vbg_phrcls_loss 1.18262, vbg_prc_auc 0.31248, 212.43 secs
# (2) Validation stage ...
# vbg_prc_auc 0.19447, 25.94 secs
# ---- Epoch 13/120
# (1) Training stage (lr = 0.000003) ...
# loss 1.17602, vbg_phrcls_loss 1.17602, vbg_prc_auc 0.31846, 211.66 secs
# (2) Validation stage ...
# vbg_prc_auc 0.19550, 26.71 secs
# ---- Epoch 14/120
# (1) Training stage (lr = 0.000001) ...
# loss 1.17071, vbg_phrcls_loss 1.17071, vbg_prc_auc 0.31815, 211.77 secs
# (2) Validation stage ...
# vbg_prc_auc 0.19988, 26.87 secs
# New checkpoint saved: checkpoint_14_vbg_prc_auc=0.2117.pt
# ---- Epoch 15/120
# (1) Training stage (lr = 0.000080) ...
# loss 1.17012, vbg_phrcls_loss 1.17012, vbg_prc_auc 0.31223, 211.35 secs
# (2) Validation stage ...
# vbg_prc_auc 0.19787, 25.83 secs
# ---- Epoch 16/120
# (1) Training stage (lr = 0.000027) ...
# loss 1.12634, vbg_phrcls_loss 1.12634, vbg_prc_auc 0.33854, 211.67 secs
# (2) Validation stage ...
# vbg_prc_auc 0.21307, 25.91 secs
# New checkpoint saved: checkpoint_16_vbg_prc_auc=0.2256.pt
# ---- Epoch 17/120
# (1) Training stage (lr = 0.000009) ...
# loss 1.10978, vbg_phrcls_loss 1.10978, vbg_prc_auc 0.34881, 211.48 secs
# (2) Validation stage ...
# vbg_prc_auc 0.21497, 26.25 secs
# New checkpoint saved: checkpoint_17_vbg_prc_auc=0.2284.pt
# ---- Epoch 18/120
# (1) Training stage (lr = 0.000003) ...
# loss 1.10109, vbg_phrcls_loss 1.10109, vbg_prc_auc 0.35273, 211.41 secs
# (2) Validation stage ...
# vbg_prc_auc 0.21457, 26.78 secs
# New checkpoint saved: checkpoint_18_vbg_prc_auc=0.2284.pt
# ---- Epoch 19/120
# (1) Training stage (lr = 0.000001) ...
# loss 1.10541, vbg_phrcls_loss 1.10541, vbg_prc_auc 0.35273, 211.61 secs
# (2) Validation stage ...
# vbg_prc_auc 0.21296, 25.34 secs
# ---- Epoch 20/120
# (1) Training stage (lr = 0.000080) ...
# loss 1.12038, vbg_phrcls_loss 1.12038, vbg_prc_auc 0.33050, 209.59 secs
# (2) Validation stage ...
# vbg_prc_auc 0.21607, 26.54 secs
# ---- Epoch 21/120
# (1) Training stage (lr = 0.000027) ...
# loss 1.07799, vbg_phrcls_loss 1.07799, vbg_prc_auc 0.36209, 210.53 secs
# (2) Validation stage ...
# vbg_prc_auc 0.22490, 26.08 secs
# New checkpoint saved: checkpoint_21_vbg_prc_auc=0.2386.pt
# ---- Epoch 22/120
# (1) Training stage (lr = 0.000009) ...
# loss 1.06177, vbg_phrcls_loss 1.06177, vbg_prc_auc 0.37250, 213.25 secs
# (2) Validation stage ...
# vbg_prc_auc 0.22219, 26.27 secs
# ---- Epoch 23/120
# (1) Training stage (lr = 0.000003) ...
# loss 1.05616, vbg_phrcls_loss 1.05616, vbg_prc_auc 0.37643, 212.60 secs
# (2) Validation stage ...
# vbg_prc_auc 0.22363, 27.47 secs
# New checkpoint saved: checkpoint_23_vbg_prc_auc=0.2389.pt
# ---- Epoch 24/120
# (1) Training stage (lr = 0.000001) ...
# loss 1.04942, vbg_phrcls_loss 1.04942, vbg_prc_auc 0.37676, 212.16 secs
# (2) Validation stage ...
# vbg_prc_auc 0.22556, 26.16 secs
# New checkpoint saved: checkpoint_24_vbg_prc_auc=0.2407.pt
# ---- Epoch 25/120
# (1) Training stage (lr = 0.000080) ...
# loss 1.06696, vbg_phrcls_loss 1.06696, vbg_prc_auc 0.36765, 211.81 secs
# (2) Validation stage ...
# vbg_prc_auc 0.22365, 25.75 secs
# ---- Epoch 26/120
# (1) Training stage (lr = 0.000027) ...
# loss 1.03763, vbg_phrcls_loss 1.03763, vbg_prc_auc 0.38418, 210.98 secs
# (2) Validation stage ...
# vbg_prc_auc 0.23032, 26.52 secs
# New checkpoint saved: checkpoint_26_vbg_prc_auc=0.2457.pt
# ---- Epoch 27/120
# (1) Training stage (lr = 0.000009) ...
# loss 1.01870, vbg_phrcls_loss 1.01870, vbg_prc_auc 0.39243, 211.64 secs
# (2) Validation stage ...
# vbg_prc_auc 0.23446, 25.87 secs
# New checkpoint saved: checkpoint_27_vbg_prc_auc=0.2503.pt
# ---- Epoch 28/120
# (1) Training stage (lr = 0.000003) ...
# loss 1.01031, vbg_phrcls_loss 1.01031, vbg_prc_auc 0.39999, 211.41 secs
# (2) Validation stage ...
# vbg_prc_auc 0.23325, 26.51 secs
# ---- Epoch 29/120
# (1) Training stage (lr = 0.000001) ...
# loss 1.00794, vbg_phrcls_loss 1.00794, vbg_prc_auc 0.40153, 212.16 secs
# (2) Validation stage ...
# vbg_prc_auc 0.23367, 26.13 secs
# New checkpoint saved: checkpoint_29_vbg_prc_auc=0.2505.pt
# ---- Epoch 30/120
# (1) Training stage (lr = 0.000080) ...
# loss 1.03257, vbg_phrcls_loss 1.03257, vbg_prc_auc 0.37692, 211.50 secs
# (2) Validation stage ...
# vbg_prc_auc 0.23196, 25.97 secs
# ---- Epoch 31/120
# (1) Training stage (lr = 0.000027) ...
# loss 0.99658, vbg_phrcls_loss 0.99658, vbg_prc_auc 0.40499, 211.70 secs
# (2) Validation stage ...
# vbg_prc_auc 0.24989, 26.33 secs
# New checkpoint saved: checkpoint_31_vbg_prc_auc=0.2654.pt
# ---- Epoch 32/120
# (1) Training stage (lr = 0.000009) ...
# loss 0.98298, vbg_phrcls_loss 0.98298, vbg_prc_auc 0.41248, 212.35 secs
# (2) Validation stage ...
# vbg_prc_auc 0.24793, 26.23 secs
# ---- Epoch 33/120
# (1) Training stage (lr = 0.000003) ...
# loss 0.97045, vbg_phrcls_loss 0.97045, vbg_prc_auc 0.41898, 212.37 secs
# (2) Validation stage ...
# vbg_prc_auc 0.25085, 26.53 secs
# New checkpoint saved: checkpoint_33_vbg_prc_auc=0.2677.pt
# ---- Epoch 34/120
# (1) Training stage (lr = 0.000001) ...
# loss 0.97369, vbg_phrcls_loss 0.97369, vbg_prc_auc 0.42165, 211.48 secs
# (2) Validation stage ...
# vbg_prc_auc 0.24928, 26.57 secs
# ---- Epoch 35/120
# (1) Training stage (lr = 0.000080) ...
# loss 0.99498, vbg_phrcls_loss 0.99498, vbg_prc_auc 0.40231, 211.41 secs
# (2) Validation stage ...
# vbg_prc_auc 0.25563, 26.05 secs
# New checkpoint saved: checkpoint_35_vbg_prc_auc=0.2703.pt
# ---- Epoch 36/120
# (1) Training stage (lr = 0.000027) ...
# loss 0.96094, vbg_phrcls_loss 0.96094, vbg_prc_auc 0.42932, 211.97 secs
# (2) Validation stage ...
# vbg_prc_auc 0.25724, 26.67 secs
# New checkpoint saved: checkpoint_36_vbg_prc_auc=0.2745.pt
# ---- Epoch 37/120
# (1) Training stage (lr = 0.000009) ...
# loss 0.94435, vbg_phrcls_loss 0.94435, vbg_prc_auc 0.43460, 211.64 secs
# (2) Validation stage ...
# vbg_prc_auc 0.25669, 26.91 secs
# New checkpoint saved: checkpoint_37_vbg_prc_auc=0.2745.pt
# ---- Epoch 38/120
# (1) Training stage (lr = 0.000003) ...
# loss 0.94269, vbg_phrcls_loss 0.94269, vbg_prc_auc 0.43866, 211.83 secs
# (2) Validation stage ...
# vbg_prc_auc 0.25618, 25.87 secs
# ---- Epoch 39/120
# (1) Training stage (lr = 0.000001) ...
# loss 0.94045, vbg_phrcls_loss 0.94045, vbg_prc_auc 0.44185, 212.10 secs
# (2) Validation stage ...
# vbg_prc_auc 0.25716, 26.11 secs
# New checkpoint saved: checkpoint_39_vbg_prc_auc=0.2756.pt
# ---- Epoch 40/120
# (1) Training stage (lr = 0.000080) ...
# loss 0.96131, vbg_phrcls_loss 0.96131, vbg_prc_auc 0.41543, 212.51 secs
# (2) Validation stage ...
# vbg_prc_auc 0.26143, 25.77 secs
# New checkpoint saved: checkpoint_40_vbg_prc_auc=0.2768.pt
# ---- Epoch 41/120
# (1) Training stage (lr = 0.000027) ...
# loss 0.93144, vbg_phrcls_loss 0.93144, vbg_prc_auc 0.44015, 212.51 secs
# (2) Validation stage ...
# vbg_prc_auc 0.27122, 26.53 secs
# New checkpoint saved: checkpoint_41_vbg_prc_auc=0.2881.pt
# ---- Epoch 42/120
# (1) Training stage (lr = 0.000009) ...
# loss 0.91167, vbg_phrcls_loss 0.91167, vbg_prc_auc 0.45741, 212.47 secs
# (2) Validation stage ...
# vbg_prc_auc 0.27021, 27.62 secs
# New checkpoint saved: checkpoint_42_vbg_prc_auc=0.2889.pt
# ---- Epoch 43/120
# (1) Training stage (lr = 0.000003) ...
# loss 0.90224, vbg_phrcls_loss 0.90224, vbg_prc_auc 0.46212, 212.30 secs
# (2) Validation stage ...
# vbg_prc_auc 0.27140, 26.08 secs
# New checkpoint saved: checkpoint_43_vbg_prc_auc=0.2905.pt
# ---- Epoch 44/120
# (1) Training stage (lr = 0.000001) ...
# loss 0.90005, vbg_phrcls_loss 0.90005, vbg_prc_auc 0.46432, 211.81 secs
# (2) Validation stage ...
# vbg_prc_auc 0.26840, 26.29 secs
# ---- Epoch 45/120
# (1) Training stage (lr = 0.000080) ...
# loss 0.92403, vbg_phrcls_loss 0.92403, vbg_prc_auc 0.44611, 213.19 secs
# (2) Validation stage ...
# vbg_prc_auc 0.26569, 26.61 secs
# ---- Epoch 46/120
# (1) Training stage (lr = 0.000027) ...
# loss 0.89022, vbg_phrcls_loss 0.89022, vbg_prc_auc 0.47749, 211.63 secs
# (2) Validation stage ...
# vbg_prc_auc 0.27652, 25.61 secs
# New checkpoint saved: checkpoint_46_vbg_prc_auc=0.2966.pt
# ---- Epoch 47/120
# (1) Training stage (lr = 0.000009) ...
# loss 0.86584, vbg_phrcls_loss 0.86584, vbg_prc_auc 0.49123, 212.75 secs
# (2) Validation stage ...
# vbg_prc_auc 0.27399, 25.98 secs
# ---- Epoch 48/120
# (1) Training stage (lr = 0.000003) ...
# loss 0.85650, vbg_phrcls_loss 0.85650, vbg_prc_auc 0.49635, 214.31 secs
# (2) Validation stage ...
# vbg_prc_auc 0.27879, 26.77 secs
# New checkpoint saved: checkpoint_48_vbg_prc_auc=0.3005.pt
# ---- Epoch 49/120
# (1) Training stage (lr = 0.000001) ...
# loss 0.85604, vbg_phrcls_loss 0.85604, vbg_prc_auc 0.49594, 214.01 secs
# (2) Validation stage ...
# vbg_prc_auc 0.27699, 25.61 secs
# ---- Epoch 50/120
# (1) Training stage (lr = 0.000080) ...
# loss 0.89600, vbg_phrcls_loss 0.89600, vbg_prc_auc 0.46337, 214.11 secs
# (2) Validation stage ...
# vbg_prc_auc 0.27381, 26.22 secs
# ---- Epoch 51/120
# (1) Training stage (lr = 0.000027) ...
# loss 0.84725, vbg_phrcls_loss 0.84725, vbg_prc_auc 0.50896, 213.64 secs
# (2) Validation stage ...
# vbg_prc_auc 0.28300, 27.59 secs
# New checkpoint saved: checkpoint_51_vbg_prc_auc=0.3056.pt
# ---- Epoch 52/120
# (1) Training stage (lr = 0.000009) ...
# loss 0.82720, vbg_phrcls_loss 0.82720, vbg_prc_auc 0.52461, 213.66 secs
# (2) Validation stage ...
# vbg_prc_auc 0.28993, 26.03 secs
# New checkpoint saved: checkpoint_52_vbg_prc_auc=0.3134.pt
# ---- Epoch 53/120
# (1) Training stage (lr = 0.000003) ...
# loss 0.81689, vbg_phrcls_loss 0.81689, vbg_prc_auc 0.53505, 213.28 secs
# (2) Validation stage ...
# vbg_prc_auc 0.29288, 25.94 secs
# New checkpoint saved: checkpoint_53_vbg_prc_auc=0.3171.pt
# ---- Epoch 54/120
# (1) Training stage (lr = 0.000001) ...
# loss 0.81499, vbg_phrcls_loss 0.81499, vbg_prc_auc 0.54295, 213.36 secs
# (2) Validation stage ...
# vbg_prc_auc 0.29221, 25.71 secs
# New checkpoint saved: checkpoint_54_vbg_prc_auc=0.3173.pt
# ---- Epoch 55/120
# (1) Training stage (lr = 0.000080) ...
# loss 0.85653, vbg_phrcls_loss 0.85653, vbg_prc_auc 0.48806, 212.12 secs
# (2) Validation stage ...
# vbg_prc_auc 0.29041, 25.94 secs
# ---- Epoch 56/120
# (1) Training stage (lr = 0.000027) ...
# loss 0.81759, vbg_phrcls_loss 0.81759, vbg_prc_auc 0.53419, 211.59 secs
# (2) Validation stage ...
# vbg_prc_auc 0.29714, 27.00 secs
# New checkpoint saved: checkpoint_56_vbg_prc_auc=0.3208.pt
# ---- Epoch 57/120
# (1) Training stage (lr = 0.000009) ...
# loss 0.78684, vbg_phrcls_loss 0.78684, vbg_prc_auc 0.55659, 211.41 secs
# (2) Validation stage ...
# vbg_prc_auc 0.31556, 25.40 secs
# New checkpoint saved: checkpoint_57_vbg_prc_auc=0.3397.pt
# ---- Epoch 58/120
# (1) Training stage (lr = 0.000003) ...
# loss 0.78169, vbg_phrcls_loss 0.78169, vbg_prc_auc 0.56539, 211.07 secs
# (2) Validation stage ...
# vbg_prc_auc 0.30625, 25.21 secs
# ---- Epoch 59/120
# (1) Training stage (lr = 0.000001) ...
# loss 0.77548, vbg_phrcls_loss 0.77548, vbg_prc_auc 0.56463, 210.96 secs
# (2) Validation stage ...
# vbg_prc_auc 0.30131, 25.38 secs
# ---- Epoch 60/120
# (1) Training stage (lr = 0.000080) ...
# loss 0.82523, vbg_phrcls_loss 0.82523, vbg_prc_auc 0.51050, 210.93 secs
# (2) Validation stage ...
# vbg_prc_auc 0.30242, 26.14 secs
# ---- Epoch 61/120
# (1) Training stage (lr = 0.000027) ...
# loss 0.78426, vbg_phrcls_loss 0.78426, vbg_prc_auc 0.56119, 210.80 secs
# (2) Validation stage ...
# vbg_prc_auc 0.30369, 26.42 secs
# ---- Epoch 62/120
# (1) Training stage (lr = 0.000009) ...
# loss 0.75043, vbg_phrcls_loss 0.75043, vbg_prc_auc 0.58781, 209.72 secs
# (2) Validation stage ...
# vbg_prc_auc 0.30588, 25.48 secs
# ---- Epoch 63/120
# (1) Training stage (lr = 0.000003) ...
# loss 0.73954, vbg_phrcls_loss 0.73954, vbg_prc_auc 0.60516, 210.88 secs
# (2) Validation stage ...
# vbg_prc_auc 0.30386, 26.11 secs
# ---- Epoch 64/120
# (1) Training stage (lr = 0.000001) ...
# loss 0.73106, vbg_phrcls_loss 0.73106, vbg_prc_auc 0.60071, 210.62 secs
# (2) Validation stage ...
# vbg_prc_auc 0.30433, 26.45 secs
# ---- Epoch 65/120
# (1) Training stage (lr = 0.000080) ...
# loss 0.77892, vbg_phrcls_loss 0.77892, vbg_prc_auc 0.55894, 210.81 secs
# (2) Validation stage ...
# vbg_prc_auc 0.30136, 26.39 secs
# ---- Epoch 66/120
# (1) Training stage (lr = 0.000027) ...
# loss 0.73193, vbg_phrcls_loss 0.73193, vbg_prc_auc 0.59812, 210.72 secs
# (2) Validation stage ...
# vbg_prc_auc 0.30649, 25.70 secs
# ---- Epoch 67/120
# (1) Training stage (lr = 0.000009) ...
# loss 0.70549, vbg_phrcls_loss 0.70549, vbg_prc_auc 0.62667, 209.63 secs
# (2) Validation stage ...
# vbg_prc_auc 0.33435, 26.21 secs
# New checkpoint saved: checkpoint_67_vbg_prc_auc=0.3636.pt
# ---- Epoch 68/120
# (1) Training stage (lr = 0.000003) ...
# loss 0.69496, vbg_phrcls_loss 0.69496, vbg_prc_auc 0.63707, 210.68 secs
# (2) Validation stage ...
# vbg_prc_auc 0.30883, 25.45 secs
# ---- Epoch 69/120
# (1) Training stage (lr = 0.000001) ...
# loss 0.69614, vbg_phrcls_loss 0.69614, vbg_prc_auc 0.63382, 210.70 secs
# (2) Validation stage ...
# vbg_prc_auc 0.30630, 26.17 secs
# ---- Epoch 70/120
# (1) Training stage (lr = 0.000080) ...
# loss 0.74881, vbg_phrcls_loss 0.74881, vbg_prc_auc 0.58134, 210.37 secs
# (2) Validation stage ...
# vbg_prc_auc 0.29632, 26.89 secs
# ---- Epoch 71/120
# (1) Training stage (lr = 0.000027) ...
# loss 0.69871, vbg_phrcls_loss 0.69871, vbg_prc_auc 0.62768, 210.42 secs
# (2) Validation stage ...
# vbg_prc_auc 0.31572, 25.87 secs
# ---- Epoch 72/120
# (1) Training stage (lr = 0.000009) ...
# loss 0.66408, vbg_phrcls_loss 0.66408, vbg_prc_auc 0.65199, 209.58 secs
# (2) Validation stage ...
# vbg_prc_auc 0.31113, 26.52 secs
# ---- Epoch 73/120
# (1) Training stage (lr = 0.000003) ...
# loss 0.65597, vbg_phrcls_loss 0.65597, vbg_prc_auc 0.66151, 210.52 secs
# (2) Validation stage ...
# vbg_prc_auc 0.30881, 25.55 secs
# ---- Epoch 74/120
# (1) Training stage (lr = 0.000001) ...
# loss 0.70142, vbg_phrcls_loss 0.70142, vbg_prc_auc 0.62472, 210.61 secs
# (2) Validation stage ...
# vbg_prc_auc 0.30620, 25.64 secs
# ---- Epoch 76/120
# (1) Training stage (lr = 0.000027) ...
# loss 0.65490, vbg_phrcls_loss 0.65490, vbg_prc_auc 0.66338, 210.74 secs
# (2) Validation stage ...
# vbg_prc_auc 0.31377, 26.15 secs
# ---- Epoch 77/120
# (1) Training stage (lr = 0.000009) ...
# loss 0.62836, vbg_phrcls_loss 0.62836, vbg_prc_auc 0.68171, 209.83 secs
# (2) Validation stage ...
# vbg_prc_auc 0.31116, 26.10 secs
# ---- Epoch 78/120
# (1) Training stage (lr = 0.000003) ...
# loss 0.61732, vbg_phrcls_loss 0.61732, vbg_prc_auc 0.69636, 208.94 secs
# (2) Validation stage ...
# vbg_prc_auc 0.31184, 25.37 secs
# ---- Epoch 79/120
# (1) Training stage (lr = 0.000001) ...
# loss 0.61174, vbg_phrcls_loss 0.61174, vbg_prc_auc 0.69821, 210.67 secs
# (2) Validation stage ...
# vbg_prc_auc 0.31505, 26.29 secs
# ---- Epoch 80/120
# (1) Training stage (lr = 0.000080) ...
# loss 0.68969, vbg_phrcls_loss 0.68969, vbg_prc_auc 0.62059, 210.58 secs
# (2) Validation stage ...
# vbg_prc_auc 0.31452, 25.92 secs
# ---- Epoch 81/120
# (1) Training stage (lr = 0.000027) ...
# loss 0.63633, vbg_phrcls_loss 0.63633, vbg_prc_auc 0.67827, 210.49 secs
# (2) Validation stage ...
# vbg_prc_auc 0.31268, 25.06 secs
# ---- Epoch 82/120
# (1) Training stage (lr = 0.000009) ...
# loss 0.59717, vbg_phrcls_loss 0.59717, vbg_prc_auc 0.71584, 210.17 secs
# (2) Validation stage ...
# vbg_prc_auc 0.31377, 25.81 secs
# ---- Epoch 83/120
# (1) Training stage (lr = 0.000003) ...
# loss 0.58544, vbg_phrcls_loss 0.58544, vbg_prc_auc 0.72041, 210.15 secs
# (2) Validation stage ...
# vbg_prc_auc 0.31330, 25.97 secs
# ---- Epoch 84/120
# (1) Training stage (lr = 0.000001) ...
# loss 0.58246, vbg_phrcls_loss 0.58246, vbg_prc_auc 0.72853, 210.41 secs
# (2) Validation stage ...
# vbg_prc_auc 0.31484, 26.18 secs
# ---- Epoch 85/120
# (1) Training stage (lr = 0.000080) ...
# loss 0.62959, vbg_phrcls_loss 0.62959, vbg_prc_auc 0.67827, 210.57 secs
# (2) Validation stage ...
# vbg_prc_auc 0.31178, 25.56 secs
# ---- Epoch 86/120
# (1) Training stage (lr = 0.000027) ...
# loss 0.59405, vbg_phrcls_loss 0.59405, vbg_prc_auc 0.71777, 210.48 secs
# (2) Validation stage ...
# vbg_prc_auc 0.30955, 26.37 secs
# ---- Epoch 87/120
# (1) Training stage (lr = 0.000009) ...
# loss 0.55700, vbg_phrcls_loss 0.55700, vbg_prc_auc 0.74558, 208.89 secs
# (2) Validation stage ...
# vbg_prc_auc 0.30739, 25.82 secs
# ---- Epoch 88/120
# (1) Training stage (lr = 0.000003) ...
# loss 0.55429, vbg_phrcls_loss 0.55429, vbg_prc_auc 0.75434, 210.48 secs
# (2) Validation stage ...
# vbg_prc_auc 0.30877, 26.71 secs
# ---- Epoch 89/120
# (1) Training stage (lr = 0.000001) ...
# loss 0.54516, vbg_phrcls_loss 0.54516, vbg_prc_auc 0.75839, 208.90 secs
# (2) Validation stage ...
# vbg_prc_auc 0.31011, 26.30 secs
# ---- Epoch 90/120
# (1) Training stage (lr = 0.000080) ...
# loss 0.60914, vbg_phrcls_loss 0.60914, vbg_prc_auc 0.69531, 209.18 secs
# (2) Validation stage ...
# vbg_prc_auc 0.30913, 26.01 secs
# ---- Epoch 91/120
# (1) Training stage (lr = 0.000027) ...
# loss 0.56037, vbg_phrcls_loss 0.56037, vbg_prc_auc 0.74994, 210.43 secs
# (2) Validation stage ...
# vbg_prc_auc 0.31432, 26.28 secs
# ---- Epoch 92/120
# (1) Training stage (lr = 0.000009) ...
# loss 0.53374, vbg_phrcls_loss 0.53374, vbg_prc_auc 0.76412, 210.52 secs
# (2) Validation stage ...
# vbg_prc_auc 0.30518, 26.16 secs
# ---- Epoch 93/120
# (1) Training stage (lr = 0.000003) ...
# loss 0.51823, vbg_phrcls_loss 0.51823, vbg_prc_auc 0.78266, 210.41 secs
# (2) Validation stage ...
# vbg_prc_auc 0.31025, 25.41 secs
# ---- Epoch 94/120
# (1) Training stage (lr = 0.000001) ...
# loss 0.51632, vbg_phrcls_loss 0.51632, vbg_prc_auc 0.78152, 210.54 secs
# (2) Validation stage ...
# vbg_prc_auc 0.31223, 25.64 secs
# ---- Epoch 95/120
# (1) Training stage (lr = 0.000080) ...
# loss 0.58389, vbg_phrcls_loss 0.58389, vbg_prc_auc 0.73000, 208.22 secs
# (2) Validation stage ...
# vbg_prc_auc 0.30706, 26.31 secs
# ---- Epoch 96/120
# (1) Training stage (lr = 0.000027) ...
# loss 0.54450, vbg_phrcls_loss 0.54450, vbg_prc_auc 0.76422, 210.02 secs
# (2) Validation stage ...
# vbg_prc_auc 0.31363, 25.91 secs
# ---- Epoch 97/120
# (1) Training stage (lr = 0.000009) ...
# loss 0.49856, vbg_phrcls_loss 0.49856, vbg_prc_auc 0.80490, 210.12 secs
# (2) Validation stage ...
# vbg_prc_auc 0.31021, 25.58 secs
# ---- Epoch 98/120
# (1) Training stage (lr = 0.000003) ...
# loss 0.49196, vbg_phrcls_loss 0.49196, vbg_prc_auc 0.80831, 210.40 secs
# (2) Validation stage ...
# vbg_prc_auc 0.31650, 25.93 secs
# New checkpoint saved: checkpoint_98_vbg_prc_auc=0.3657.pt
# ---- Epoch 99/120
# (1) Training stage (lr = 0.000001) ...
# loss 0.48241, vbg_phrcls_loss 0.48241, vbg_prc_auc 0.80834, 208.98 secs
# (2) Validation stage ...
# vbg_prc_auc 0.31429, 23.58 secs
# ---- Epoch 100/120
# (1) Training stage (lr = 0.000080) ...
# loss 0.55498, vbg_phrcls_loss 0.55498, vbg_prc_auc 0.75266, 206.64 secs
# (2) Validation stage ...
# vbg_prc_auc 0.31169, 23.07 secs
# ---- Epoch 101/120
# (1) Training stage (lr = 0.000027) ...
# loss 0.50355, vbg_phrcls_loss 0.50355, vbg_prc_auc 0.79941, 207.32 secs
# (2) Validation stage ...
# vbg_prc_auc 0.31528, 23.27 secs
# ---- Epoch 102/120
# (1) Training stage (lr = 0.000009) ...
# loss 0.47347, vbg_phrcls_loss 0.47347, vbg_prc_auc 0.81598, 212.30 secs
# (2) Validation stage ...
# vbg_prc_auc 0.32053, 23.08 secs
# New checkpoint saved: checkpoint_102_vbg_prc_auc=0.3701.pt
# ---- Epoch 103/120
# (1) Training stage (lr = 0.000003) ...
# loss 0.45880, vbg_phrcls_loss 0.45880, vbg_prc_auc 0.83215, 212.00 secs
# (2) Validation stage ...
# vbg_prc_auc 0.31123, 22.97 secs
# ---- Epoch 104/120
# (1) Training stage (lr = 0.000001) ...
# loss 0.45561, vbg_phrcls_loss 0.45561, vbg_prc_auc 0.83111, 215.19 secs
# (2) Validation stage ...
# vbg_prc_auc 0.31291, 23.07 secs
# ---- Epoch 105/120
# (1) Training stage (lr = 0.000080) ...
# loss 0.52158, vbg_phrcls_loss 0.52158, vbg_prc_auc 0.78037, 215.90 secs
# (2) Validation stage ...
# vbg_prc_auc 0.30530, 23.03 secs
# ---- Epoch 106/120
# (1) Training stage (lr = 0.000027) ...
# loss 0.48529, vbg_phrcls_loss 0.48529, vbg_prc_auc 0.80683, 214.94 secs
# (2) Validation stage ...
# vbg_prc_auc 0.31260, 22.94 secs
# ---- Epoch 107/120
# (1) Training stage (lr = 0.000009) ...
# loss 0.44645, vbg_phrcls_loss 0.44645, vbg_prc_auc 0.84149, 215.54 secs
# (2) Validation stage ...
# vbg_prc_auc 0.33123, 23.13 secs
# New checkpoint saved: checkpoint_107_vbg_prc_auc=0.3823.pt
# ---- Epoch 108/120
# (1) Training stage (lr = 0.000003) ...
# loss 0.43457, vbg_phrcls_loss 0.43457, vbg_prc_auc 0.85274, 213.98 secs
# (2) Validation stage ...
# vbg_prc_auc 0.33166, 23.01 secs
# New checkpoint saved: checkpoint_108_vbg_prc_auc=0.3838.pt
# ---- Epoch 109/120
# (1) Training stage (lr = 0.000001) ...
# loss 0.43152, vbg_phrcls_loss 0.43152, vbg_prc_auc 0.85280, 215.25 secs
# (2) Validation stage ...
# vbg_prc_auc 0.31227, 22.99 secs
# ---- Epoch 110/120
# (1) Training stage (lr = 0.000080) ...
# loss 0.49877, vbg_phrcls_loss 0.49877, vbg_prc_auc 0.79654, 216.19 secs
# (2) Validation stage ...
# vbg_prc_auc 0.31060, 23.04 secs
# ---- Epoch 111/120
# (1) Training stage (lr = 0.000027) ...
# loss 0.46312, vbg_phrcls_loss 0.46312, vbg_prc_auc 0.82314, 215.52 secs
# (2) Validation stage ...
# vbg_prc_auc 0.31660, 23.13 secs
# ---- Epoch 112/120
# (1) Training stage (lr = 0.000009) ...
# loss 0.42216, vbg_phrcls_loss 0.42216, vbg_prc_auc 0.85719, 215.90 secs
# (2) Validation stage ...
# vbg_prc_auc 0.31794, 23.09 secs
# ---- Epoch 113/120
# (1) Training stage (lr = 0.000003) ...
# loss 0.41033, vbg_phrcls_loss 0.41033, vbg_prc_auc 0.87045, 216.05 secs
# (2) Validation stage ...
# vbg_prc_auc 0.31864, 23.13 secs
# ---- Epoch 114/120
# (1) Training stage (lr = 0.000001) ...
# loss 0.40719, vbg_phrcls_loss 0.40719, vbg_prc_auc 0.87653, 215.60 secs
# (2) Validation stage ...
# vbg_prc_auc 0.31650, 23.01 secs
# ---- Epoch 115/120
# (1) Training stage (lr = 0.000080) ...
# loss 0.48545, vbg_phrcls_loss 0.48545, vbg_prc_auc 0.80502, 216.24 secs
# (2) Validation stage ...
# vbg_prc_auc 0.33333, 23.09 secs
# ---- Epoch 116/120
# (1) Training stage (lr = 0.000027) ...
# loss 0.43880, vbg_phrcls_loss 0.43880, vbg_prc_auc 0.85079, 217.58 secs
# (2) Validation stage ...
# vbg_prc_auc 0.32013, 22.93 secs
# ---- Epoch 117/120
# (1) Training stage (lr = 0.000009) ...
# loss 0.39736, vbg_phrcls_loss 0.39736, vbg_prc_auc 0.87928, 215.40 secs
# (2) Validation stage ...
# vbg_prc_auc 0.31651, 23.02 secs
# ---- Epoch 118/120
# (1) Training stage (lr = 0.000003) ...
# loss 0.39235, vbg_phrcls_loss 0.39235, vbg_prc_auc 0.88625, 216.35 secs
# (2) Validation stage ...
# vbg_prc_auc 0.32016, 22.93 secs
# ---- Epoch 119/120
# (1) Training stage (lr = 0.000001) ...
# loss 0.38219, vbg_phrcls_loss 0.38219, vbg_prc_auc 0.88595, 216.88 secs
# (2) Validation stage ...
# vbg_prc_auc 0.32120, 23.02 secs
# ---- Epoch 120/120
# (1) Training stage (lr = 0.000080) ...
# loss 0.45610, vbg_phrcls_loss 0.45610, vbg_prc_auc 0.83348, 217.42 secs
# (2) Validation stage ...
# vbg_prc_auc 0.32587, 23.04 secs
