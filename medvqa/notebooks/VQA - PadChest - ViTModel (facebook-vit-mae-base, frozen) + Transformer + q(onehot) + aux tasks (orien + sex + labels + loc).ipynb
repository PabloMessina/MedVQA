# %%
# %env CUDA_VISIBLE_DEVICES=2
# Out:
# env: CUDA_VISIBLE_DEVICES=2

# %%
# !python ../train_vqa.py \
        --epochs 60 \
        --batches-per-epoch 200 \
        --batch-size 150 \
        --iters-to-accumulate 2 \
        --num-workers 4 \
        --optimizer-name "adamw" \
        --scheduler "warmup+decay" \
        --lr 1e-6 \
        --warmup-and-decay-args "1e-6,4,4e-4,56,1e-6" \
        --use-padchest \
        --padchest-use-validation \
        --padchest-weight 1 \
        --padchest-train-study-ids-path "/mnt/data/pamessina/workspaces/medvqa-workspace/cache/padchest/train_study_ids_20221226_161248.txt" \
        --padchest-val-study-ids-path "/mnt/data/pamessina/workspaces/medvqa-workspace/cache/padchest/val_study_ids_20221226_161248.txt" \
        --padchest-test-study-ids-path "/mnt/data/pamessina/workspaces/medvqa-workspace/cache/padchest/test_study_ids_20221226_161248.txt" \
        --classify-orientation \
        --raw-image-encoding "vitmodel-huggingface" \
        --huggingface-model-name "facebook/vit-mae-base" \
        --image-size 224 224 \
        --image-local-feat-size 768 \
        --freeze-image-encoder \
        --question-encoding "one-hot" \
        --answer-decoding "transformer" \
        --binary-loss-name "wbce-c" \
        --use-amp \
        --save
# Out:
# script's arguments:
#    epochs: 60
#    batches_per_epoch: 200
#    checkpoint_folder: None
#    iuxray_qa_adapted_reports_filename: None
#    mimiccxr_qa_adapted_reports_filename: None
#    vocab_min_freq: 10
#    embed_size: 256
#    question_encoding: one-hot
#    answer_decoding: transformer
#    question_hidden_size: 128
#    answer_hidden_size: 256
#    visual_input_mode: raw-image
#    raw_image_encoding: vitmodel-huggingface
#    image_local_feat_size: 768
#    image_encoder_pretrained_weights_path: None
#    freeze_image_encoder: True
#    imagenet_pretrained: False
#    visual_features_mlp_in_dim: None
#    visual_features_mlp_out_dim: None
#    visual_features_mlp_hidden_dims: None
#    iuxray_precomputed_visual_features_path: None
#    mimiccxr_precomputed_visual_features_path: None
#    chexpert_precomputed_visual_features_path: None
#    vinbig_precomputed_visual_features_path: None
#    clip_version: None
#    huggingface_model_name: facebook/vit-mae-base
#    n_lstm_layers: 1
#    transf_dec_nhead: 2
#    transf_dec_dim_forward: 256
#    transf_dec_num_layers: 2
#    question_vec_size: 128
#    dropout_prob: 0
#    optimizer_name: adamw
#    lr: 1e-06
#    scheduler: warmup+decay
#    lr_decay: 0.76
#    lr_decay_patience: 2
#    warmup_and_decay_args: 1e-6,4,4e-4,56,1e-6
#    warmup_and_cosine_args: None
#    n_val_examples_per_question: 10
#    min_train_examples_per_question: 100
#    batch_size: 150
#    iters_to_accumulate: 2
#    num_workers: 4
#    device: GPU
#    img_aug_mode: None
#    image_size: [224, 224]
#    mimiccxr_weight: 1
#    chexpert_weight: 0.3
#    cxr14_weight: 0.3
#    vinbig_weight: 0.3
#    iuxray_weight: 0.05
#    mimiccxr_weight_chexpert_mode: 0.2
#    iuxray_weight_chexpert_mode: 0.05
#    padchest_weight: 1.0
#    mimiccxr_include_chexpert_mode: False
#    iuxray_include_chexpert_mode: False
#    use_chexpert_mode_only: False
#    val_answer_decoding: greedy-search
#    beam_search_k: None
#    use_amp: True
#    medical_tokenization: False
#    medical_terms_frequency_filename: None
#    allowed_questions: None
#    pretrained_checkpoint_folder_path: None
#    balanced_split: False
#    balanced_dataloading: False
#    imbalance_reduction_coef: 0.5
#    n_healthy_per_question: 2
#    n_unhealthy_per_question: 3
#    n_positive_per_chexpert_label: 7
#    min_question_count: 100
#    iuxray_balanced_metadata_filename: None
#    mimiccxr_balanced_metadata_filename: None
#    one_question_per_batch: False
#    save: True
#    override_lr: False
#    train_mimiccxr: False
#    train_iuxray: False
#    iuxray_train_with_all: False
#    train_chexpert: False
#    chexpert_mode: None
#    train_cxr14: False
#    train_vinbig: False
#    vinbig_training_data: all
#    vinbig_use_validation: False
#    train_padchest: True
#    padchest_training_data_mode: all
#    padchest_use_validation: True
#    padchest_train_study_ids_path: /mnt/data/pamessina/workspaces/medvqa-workspace/cache/padchest/train_study_ids_20221226_161248.txt
#    padchest_val_study_ids_path: /mnt/data/pamessina/workspaces/medvqa-workspace/cache/padchest/val_study_ids_20221226_161248.txt
#    padchest_test_study_ids_path: /mnt/data/pamessina/workspaces/medvqa-workspace/cache/padchest/test_study_ids_20221226_161248.txt
#    binary_loss_name: wbce-c
#    classify_tags: False
#    n_medical_tags: None
#    iuxray_medical_tags_per_report_filename: None
#    mimiccxr_medical_tags_per_report_filename: None
#    classify_orientation: True
#    classify_chexpert: False
#    iuxray_chexpert_labels_filename: None
#    mimiccxr_chexpert_labels_filename: None
#    classify_questions: False
#    n_questions: None
#    iuxray_question_labels_filename: None
#    mimiccxr_question_labels_filename: None
#    merge_findings: False
# ----- Training model from scratch ------
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Initializing tokenizer ...
# Loading /mnt/data/pamessina/workspaces/medvqa-workspace/cache/vocab(_mnt_data_padchest_PADCHEST_chest_x_ray_images_labels_160K_01.02.19.csv).pkl ...
# --------------------------------------------------
# 3) Creating instance of OpenEndedVQA model ...
# OpenEndedVQA():
#   image_encoder_pretrained_weights_path None
# You are using a model of type vit_mae to instantiate a model of type vit. This is not supported for all configurations of models and can yield errors.
# Some weights of the model checkpoint at facebook/vit-mae-base were not used when initializing ViTModel: ['decoder.decoder_layers.7.intermediate.dense.weight', 'decoder.decoder_layers.6.attention.output.dense.weight', 'decoder.decoder_layers.4.layernorm_after.weight', 'decoder.decoder_layers.2.layernorm_before.weight', 'decoder.decoder_layers.6.intermediate.dense.bias', 'decoder.decoder_layers.1.output.dense.weight', 'decoder.decoder_layers.3.intermediate.dense.weight', 'decoder.decoder_norm.weight', 'decoder.decoder_layers.3.attention.attention.key.weight', 'decoder.decoder_layers.3.layernorm_after.weight', 'decoder.decoder_layers.0.output.dense.bias', 'decoder.decoder_layers.6.output.dense.weight', 'decoder.decoder_layers.0.layernorm_before.weight', 'decoder.decoder_layers.2.layernorm_after.weight', 'decoder.decoder_layers.7.attention.attention.query.weight', 'decoder.decoder_layers.4.output.dense.bias', 'decoder.decoder_layers.4.attention.attention.query.bias', 'decoder.decoder_layers.3.attention.output.dense.bias', 'decoder.decoder_layers.6.attention.attention.key.weight', 'decoder.decoder_layers.1.output.dense.bias', 'decoder.decoder_layers.7.output.dense.weight', 'decoder.decoder_layers.7.output.dense.bias', 'decoder.decoder_layers.1.layernorm_before.weight', 'decoder.decoder_layers.1.attention.attention.key.bias', 'decoder.decoder_layers.4.attention.attention.value.weight', 'decoder.decoder_pred.bias', 'decoder.decoder_layers.0.attention.attention.query.bias', 'decoder.decoder_layers.4.attention.output.dense.bias', 'decoder.decoder_layers.5.attention.attention.query.weight', 'decoder.decoder_layers.3.attention.output.dense.weight', 'decoder.decoder_layers.5.attention.attention.query.bias', 'decoder.decoder_layers.3.attention.attention.value.weight', 'decoder.decoder_layers.5.attention.output.dense.bias', 'decoder.decoder_layers.7.attention.attention.value.weight', 'decoder.decoder_layers.7.attention.output.dense.weight', 'decoder.decoder_layers.1.intermediate.dense.weight', 'decoder.decoder_layers.4.layernorm_before.bias', 'decoder.decoder_layers.4.attention.attention.key.weight', 'decoder.decoder_layers.4.output.dense.weight', 'decoder.decoder_layers.7.attention.attention.key.weight', 'decoder.decoder_layers.3.output.dense.weight', 'decoder.decoder_layers.2.output.dense.bias', 'decoder.decoder_layers.6.attention.attention.value.weight', 'decoder.decoder_layers.0.attention.attention.query.weight', 'decoder.decoder_layers.4.intermediate.dense.bias', 'decoder.decoder_layers.7.attention.output.dense.bias', 'decoder.decoder_layers.5.attention.attention.key.weight', 'decoder.decoder_layers.6.output.dense.bias', 'decoder.decoder_pred.weight', 'decoder.decoder_layers.3.layernorm_before.bias', 'decoder.decoder_layers.5.intermediate.dense.weight', 'decoder.decoder_layers.5.layernorm_before.weight', 'decoder.decoder_norm.bias', 'decoder.decoder_layers.5.output.dense.bias', 'decoder.decoder_layers.6.layernorm_after.bias', 'decoder.decoder_layers.7.attention.attention.query.bias', 'decoder.decoder_layers.0.layernorm_after.bias', 'decoder.decoder_layers.1.intermediate.dense.bias', 'decoder.decoder_layers.1.attention.attention.query.bias', 'decoder.decoder_layers.4.layernorm_before.weight', 'decoder.decoder_layers.1.attention.attention.value.weight', 'decoder.decoder_layers.5.layernorm_before.bias', 'decoder.decoder_layers.0.attention.attention.value.bias', 'decoder.decoder_layers.5.layernorm_after.bias', 'decoder.decoder_layers.5.output.dense.weight', 'decoder.decoder_layers.4.layernorm_after.bias', 'decoder.decoder_layers.5.layernorm_after.weight', 'decoder.decoder_layers.2.attention.attention.key.bias', 'decoder.decoder_layers.2.attention.attention.query.weight', 'decoder.decoder_layers.3.attention.attention.query.bias', 'decoder.decoder_layers.0.attention.attention.key.bias', 'decoder.decoder_layers.5.attention.attention.value.bias', 'decoder.decoder_layers.1.attention.attention.query.weight', 'decoder.decoder_layers.1.layernorm_b ...
# - This IS expected if you are initializing ViTModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing ViTModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of ViTModel were not initialized from the model checkpoint at facebook/vit-mae-base and are newly initialized: ['vit.pooler.dense.bias', 'vit.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Ignore freezing parameter: pooler.dense.weight
# Ignore freezing parameter: pooler.dense.bias
#   self.global_feat_size = 768
#   n_questions = 196
#   n_questions_aux_task = None
#   question_encoding = one-hot
#   answer_decoding = transformer
#   visual_input_mode = raw-image
#   name = oevqa(facebook/vit-mae-base+onehot+transf)
# --------------------------------------------------
# 4) Defining optimizer ...
# create_optimizer(): name = adamw
# --------------------------------------------------
# 5) Defining scheduler ...
# Using warmup+decay scheduler: 1e-6,4,4e-4,56,1e-6
# 1e-06 4 0.0004 56 1e-06
# Adjusting learning rate of group 0 to 1.0000e-06.
# Adjusting learning rate of group 0 to 1.0000e-06.
# --------------------------------------------------
# 6) Creating trainer and validator engines ...
# get_engine(): shift_answer=True
# get_engine(): shift_answer=False
# --------------------------------------------------
# 7) Defining image transform ...
# Using Huggingface ViT model transform for facebook/vit-mae-base
# mean = (0.485, 0.456, 0.406), std = (0.229, 0.224, 0.225), image_size = (224, 224), use_center_crop = False
# Returning transform without augmentation
# --------------------------------------------------
# 8) Defining collate_batch_fn ...
# get_vqa_collate_batch_fn(): dataset_id=7, one_hot_question_offset=0
# --------------------------------------------------
# 9) Creating PadChest vqa trainer ...
# ../train_vqa.py:1497: DtypeWarning: Columns (19,20) have mixed types.Specify dtype option on import or set low_memory=False.
#   debug=debug)
# Number of rows before filtering: 160861
# Number of rows after filtering: 160754 (dropped nan rows)
# Number of rows after filtering: 160741 (dropped study ids not in all_study_ids_set)
# Number of rows after filtering: 160723 (dropped rows with unexpected PatientSex_DICOM)
# Number of rows after filtering: 160704 (dropped rows with unexpected Projection)
# Number of rows after filtering: 160692 (dropped rows with broken images)
# Number of rows after filtering: 109821 (dropped rows with duplicate StudyID)
# Number of labels: 193
# Number of localizations: 104
# Generating answers based on labels...
# 100%|███████████████████████████████| 109821/109821 [00:01<00:00, 105089.13it/s]
# Done. Example answer: <s> normal </s>
# Generating answers based on localizations...
# 100%|███████████████████████████████| 109821/109821 [00:00<00:00, 109921.58it/s]
# Done. Example answer: <s> loc diaphragm , loc left </s>
# Number of non-empty answers: 63528
# Generating answers based on labels localizations by sentence...
# 100%|████████████████████████████████| 109821/109821 [00:01<00:00, 61705.99it/s]
# Done. Example answer: <s> cardiomegaly loc cardiac aortic elongation supra aortic elongation loc supra aortic loc aortic normal </s>
# Creating dataset and dataloader...
# Example of positive localization answer: <s> loc infradiaphragm , loc right , loc cardiac , loc basal bilateral , loc hilar , loc central </s>
# Example of negative localization answer: <s> </s>
# 193it [00:30,  6.30it/s]
# Done!
# len(self.train_dataset) = 1000000000000000000
# Creating dataset and dataloader...
# Example of positive localization answer: <s> loc lobar , loc bilateral , loc upper lobe , loc pleural </s>
# Example of negative localization answer: <s> </s>
# 193it [00:00, 214.91it/s]
# Done!
# len(self.val_dataset) = 4398
# --------------------------------------------------
# 10) Creating dataloaders ...
# len(_train_dataloaders) = 1
# len(_val_dataloaders) = 1
# _train_weights = [1.0]
# merged_dataset_name = padchest(vqa)
# --------------------------------------------------
# 11) Attaching metrics, losses, timer and events to engines ...
# --------------------------------------------------
# 12) Defining learning rate scheduler handler ...
# --------------------------------------------------
# 13) Defining checkpoint folder path ...
# checkpoint_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/vqa/20221228_100704_padchest(vqa)_oevqa(facebook-vit-mae-base+onehot+transf)_visenc-pretr=0_orien_amp
# metadata saved to /mnt/data/pamessina/workspaces/medvqa-workspace/models/vqa/20221228_100704_padchest(vqa)_oevqa(facebook-vit-mae-base+onehot+transf)_visenc-pretr=0_orien_amp/metadata.json
# --------------------------------------------------
# 14) Defining log_metrics_handler ...
# MetricsLogger :: we'll be logging to /mnt/data/pamessina/workspaces/medvqa-workspace/models/vqa/20221228_100704_padchest(vqa)_oevqa(facebook-vit-mae-base+onehot+transf)_visenc-pretr=0_orien_amp/metrics_logs.csv
# --------------------------------------------------
# 15) Running trainer engine ...
# ---- Epoch 1/60
# (1) Training stage (lr = 0.000001) ...
# loss 12.56361, a_loss 8.15579, ema 0.00000, oracc 0.23723, orien_loss 1.58313, gacc 0.49173, gloss 0.69594, b1 0.00054, b2 0.00000, b3 0.00000, b4 0.00000, padchxlmacf1 0.01225, padchxlmicf1 0.01169, padchxlzmacf1 0.02518, padchxlzmicf1 0.02861, padchxl_loss 0.95894, padchxlz_loss 1.02720, 129.89 secs
# (2) Validation stage ...
# ema 0.00000, oracc 0.74420, gacc 0.47658, b1 0.00042, b2 0.00000, b3 0.00000, b4 0.00000, padchxlmacf1 0.01621, padchxlmicf1 0.01422, padchxlzmacf1 0.03263, padchxlzmicf1 0.03751, 34.35 secs
# Adjusting learning rate of group 0 to 4.4721e-06.
# ---- Epoch 2/60
# (1) Training stage (lr = 0.000004) ...
# loss 12.29826, a_loss 7.75683, ema 0.00000, oracc 0.81420, orien_loss 1.29355, gacc 0.49710, gloss 0.69453, b1 0.01549, b2 0.00232, b3 0.00051, b4 0.00019, padchxlmacf1 0.01253, padchxlmicf1 0.01324, padchxlzmacf1 0.02525, padchxlzmicf1 0.03136, padchxl_loss 0.94751, padchxlz_loss 1.01173, 128.16 secs
# (2) Validation stage ...
# ema 0.00000, oracc 0.80491, gacc 0.47954, b1 0.01646, b2 0.00000, b3 0.00000, b4 0.00000, padchxlmacf1 0.01591, padchxlmicf1 0.01634, padchxlzmacf1 0.03049, padchxlzmicf1 0.04177, 33.97 secs
# Adjusting learning rate of group 0 to 2.0000e-05.
# ---- Epoch 3/60
# (1) Training stage (lr = 0.000020) ...
# loss 11.14636, a_loss 5.99333, ema 0.10610, oracc 0.81753, orien_loss 0.75695, gacc 0.58007, gloss 0.68969, b1 0.00000, b2 0.00000, b3 0.00000, b4 0.00000, padchxlmacf1 0.01537, padchxlmicf1 0.02192, padchxlzmacf1 0.02660, padchxlzmicf1 0.03981, padchxl_loss 0.89324, padchxlz_loss 0.97138, 122.08 secs
# (2) Validation stage ...
# ema 0.07549, oracc 0.80491, gacc 0.71260, b1 0.00000, b2 0.00000, b3 0.00000, b4 0.00000, padchxlmacf1 0.01620, padchxlmicf1 0.06644, padchxlzmacf1 0.02808, padchxlzmicf1 0.05899, 33.68 secs
# Adjusting learning rate of group 0 to 8.9443e-05.
# ---- Epoch 4/60
# (1) Training stage (lr = 0.000089) ...
# loss 8.12716, a_loss 4.08446, ema 0.10497, oracc 0.81557, orien_loss 0.53085, gacc 0.67947, gloss 0.66547, b1 0.00014, b2 0.00011, b3 0.00007, b4 0.00005, padchxlmacf1 0.02197, padchxlmicf1 0.08943, padchxlzmacf1 0.04060, padchxlzmicf1 0.07580, padchxl_loss 0.73356, padchxlz_loss 0.84955, 122.06 secs
# (2) Validation stage ...
# ema 0.12165, oracc 0.80582, gacc 0.67417, b1 0.00109, b2 0.00053, b3 0.00024, b4 0.00014, padchxlmacf1 0.02599, padchxlmicf1 0.09821, padchxlzmacf1 0.04670, padchxlzmicf1 0.10386, 33.30 secs
# Adjusting learning rate of group 0 to 4.0000e-04.
# ---- Epoch 5/60
# (1) Training stage (lr = 0.000400) ...
# loss 6.06837, a_loss 2.37459, ema 0.26340, oracc 0.90123, orien_loss 0.30518, gacc 0.80223, gloss 0.52097, b1 0.24809, b2 0.17465, b3 0.11714, b4 0.08032, padchxlmacf1 0.03111, padchxlmicf1 0.08531, padchxlzmacf1 0.05166, padchxlzmicf1 0.08596, padchxl_loss 0.65864, padchxlz_loss 0.78675, 122.99 secs
# (2) Validation stage ...
# ema 0.36130, oracc 0.91792, gacc 0.84288, b1 0.09587, b2 0.06729, b3 0.04358, b4 0.03073, padchxlmacf1 0.03921, padchxlmicf1 0.09465, padchxlzmacf1 0.05934, padchxlzmicf1 0.09419, 33.07 secs
# Adjusting learning rate of group 0 to 3.5941e-04.
# ---- Epoch 6/60
# (1) Training stage (lr = 0.000359) ...
# loss 3.78680, a_loss 1.74970, ema 0.34567, oracc 0.93983, orien_loss 0.18827, gacc 0.85823, gloss 0.36189, b1 0.40397, b2 0.29554, b3 0.21099, b4 0.15369, padchxlmacf1 0.03592, padchxlmicf1 0.08777, padchxlzmacf1 0.05570, padchxlzmicf1 0.08802, padchxl_loss 0.63735, padchxlz_loss 0.76983, 122.91 secs
# (2) Validation stage ...
# ema 0.31719, oracc 0.94088, gacc 0.86471, b1 0.25463, b2 0.18650, b3 0.13507, b4 0.10280, padchxlmacf1 0.04524, padchxlmicf1 0.10191, padchxlzmacf1 0.06755, padchxlzmicf1 0.10997, 33.29 secs
# Adjusting learning rate of group 0 to 3.2295e-04.
# ---- Epoch 7/60
# (1) Training stage (lr = 0.000323) ...
# loss 3.75726, a_loss 1.59974, ema 0.35247, oracc 0.94953, orien_loss 0.16857, gacc 0.87620, gloss 0.30942, b1 0.44399, b2 0.33441, b3 0.24842, b4 0.18650, padchxlmacf1 0.03962, padchxlmicf1 0.09388, padchxlzmacf1 0.06023, padchxlzmicf1 0.09719, padchxl_loss 0.62551, padchxlz_loss 0.76484, 122.98 secs
# (2) Validation stage ...
# ema 0.32765, oracc 0.95634, gacc 0.87221, b1 0.23405, b2 0.17615, b3 0.13286, b4 0.10212, padchxlmacf1 0.04981, padchxlmicf1 0.10731, padchxlzmacf1 0.07235, padchxlzmicf1 0.12365, 32.98 secs
# Adjusting learning rate of group 0 to 2.9018e-04.
# ---- Epoch 8/60
# (1) Training stage (lr = 0.000290) ...
# loss 3.34259, a_loss 1.50257, ema 0.36410, oracc 0.96007, orien_loss 0.14229, gacc 0.88790, gloss 0.28774, b1 0.47035, b2 0.36175, b3 0.27585, b4 0.21173, padchxlmacf1 0.04285, padchxlmicf1 0.10043, padchxlzmacf1 0.06202, padchxlzmicf1 0.10099, padchxl_loss 0.60800, padchxlz_loss 0.75656, 123.31 secs
# (2) Validation stage ...
# ema 0.35425, oracc 0.95930, gacc 0.87881, b1 0.23366, b2 0.16944, b3 0.12605, b4 0.09707, padchxlmacf1 0.05333, padchxlmicf1 0.11600, padchxlzmacf1 0.07515, padchxlzmicf1 0.13064, 33.15 secs
# Adjusting learning rate of group 0 to 2.6073e-04.
# ---- Epoch 9/60
# (1) Training stage (lr = 0.000261) ...
# loss 3.42715, a_loss 1.46434, ema 0.35717, oracc 0.96250, orien_loss 0.13636, gacc 0.89247, gloss 0.27415, b1 0.48295, b2 0.37555, b3 0.28909, b4 0.22453, padchxlmacf1 0.04512, padchxlmicf1 0.10156, padchxlzmacf1 0.06332, padchxlzmicf1 0.10375, padchxl_loss 0.60596, padchxlz_loss 0.74396, 123.33 secs
# (2) Validation stage ...
# ema 0.33720, oracc 0.96180, gacc 0.89063, b1 0.29049, b2 0.21528, b3 0.16555, b4 0.12879, padchxlmacf1 0.05471, padchxlmicf1 0.11219, padchxlzmacf1 0.07514, padchxlzmicf1 0.12580, 33.18 secs
# Adjusting learning rate of group 0 to 2.3428e-04.
# ---- Epoch 10/60
# (1) Training stage (lr = 0.000234) ...
# loss 2.99497, a_loss 1.42212, ema 0.36177, oracc 0.96133, orien_loss 0.13719, gacc 0.89440, gloss 0.26006, b1 0.47990, b2 0.37637, b3 0.29281, b4 0.22968, padchxlmacf1 0.04540, padchxlmicf1 0.10215, padchxlzmacf1 0.06444, padchxlzmicf1 0.10459, padchxl_loss 0.59861, padchxlz_loss 0.74371, 123.12 secs
# (2) Validation stage ...
# ema 0.33856, oracc 0.96658, gacc 0.89018, b1 0.31770, b2 0.23216, b3 0.17643, b4 0.13703, padchxlmacf1 0.05667, padchxlmicf1 0.11533, padchxlzmacf1 0.07799, padchxlzmicf1 0.12564, 33.26 secs
# Adjusting learning rate of group 0 to 2.1051e-04.
# ---- Epoch 11/60
# (1) Training stage (lr = 0.000211) ...
# loss 3.11739, a_loss 1.39442, ema 0.36907, oracc 0.96453, orien_loss 0.13433, gacc 0.90160, gloss 0.25075, b1 0.49296, b2 0.38667, b3 0.30106, b4 0.23600, padchxlmacf1 0.04613, padchxlmicf1 0.10269, padchxlzmacf1 0.06462, padchxlzmicf1 0.10280, padchxl_loss 0.59470, padchxlz_loss 0.73564, 124.11 secs
# (2) Validation stage ...
# ema 0.34447, oracc 0.96817, gacc 0.88836, b1 0.31365, b2 0.23921, b3 0.18686, b4 0.14819, padchxlmacf1 0.05758, padchxlmicf1 0.11495, padchxlzmacf1 0.07822, padchxlzmicf1 0.12922, 33.26 secs
# Adjusting learning rate of group 0 to 1.8915e-04.
# ---- Epoch 12/60
# (1) Training stage (lr = 0.000189) ...
# loss 3.10965, a_loss 1.37208, ema 0.36590, oracc 0.96497, orien_loss 0.12936, gacc 0.90247, gloss 0.24749, b1 0.49655, b2 0.39185, b3 0.30575, b4 0.24040, padchxlmacf1 0.04703, padchxlmicf1 0.10365, padchxlzmacf1 0.06510, padchxlzmicf1 0.10738, padchxl_loss 0.58343, padchxlz_loss 0.73285, 130.78 secs
# (2) Validation stage ...
# ema 0.34834, oracc 0.96726, gacc 0.89995, b1 0.26030, b2 0.19915, b3 0.15462, b4 0.12038, padchxlmacf1 0.05741, padchxlmicf1 0.11492, padchxlzmacf1 0.07816, padchxlzmicf1 0.12696, 33.47 secs
# Adjusting learning rate of group 0 to 1.6996e-04.
# ---- Epoch 13/60
# (1) Training stage (lr = 0.000170) ...
# loss 3.02543, a_loss 1.35466, ema 0.36543, oracc 0.96657, orien_loss 0.12344, gacc 0.90497, gloss 0.23930, b1 0.49517, b2 0.39126, b3 0.30620, b4 0.24172, padchxlmacf1 0.04769, padchxlmicf1 0.10408, padchxlzmacf1 0.06706, padchxlzmicf1 0.10679, padchxl_loss 0.58559, padchxlz_loss 0.73219, 123.84 secs
# (2) Validation stage ...
# ema 0.34993, oracc 0.96658, gacc 0.90155, b1 0.30630, b2 0.23611, b3 0.18660, b4 0.14906, padchxlmacf1 0.05769, padchxlmicf1 0.11528, padchxlzmacf1 0.07760, padchxlzmicf1 0.12791, 32.95 secs
# Adjusting learning rate of group 0 to 1.5271e-04.
# ---- Epoch 14/60
# (1) Training stage (lr = 0.000153) ...
# loss 3.27603, a_loss 1.33685, ema 0.37253, oracc 0.96523, orien_loss 0.12449, gacc 0.90597, gloss 0.23941, b1 0.49835, b2 0.39601, b3 0.31244, b4 0.24874, padchxlmacf1 0.04830, padchxlmicf1 0.10222, padchxlzmacf1 0.06625, padchxlzmicf1 0.10544, padchxl_loss 0.58637, padchxlz_loss 0.73521, 123.49 secs
# (2) Validation stage ...
# ema 0.35016, oracc 0.96976, gacc 0.90223, b1 0.32414, b2 0.25426, b3 0.20206, b4 0.16096, padchxlmacf1 0.05827, padchxlmicf1 0.11449, padchxlzmacf1 0.07871, padchxlzmicf1 0.13198, 32.97 secs
# Adjusting learning rate of group 0 to 1.3722e-04.
# ---- Epoch 15/60
# (1) Training stage (lr = 0.000137) ...
# loss 3.01488, a_loss 1.32315, ema 0.36780, oracc 0.96887, orien_loss 0.11931, gacc 0.90457, gloss 0.23683, b1 0.50704, b2 0.40362, b3 0.31936, b4 0.25501, padchxlmacf1 0.04882, padchxlmicf1 0.10315, padchxlzmacf1 0.06714, padchxlzmicf1 0.10729, padchxl_loss 0.58176, padchxlz_loss 0.73057, 130.32 secs
# (2) Validation stage ...
# ema 0.34743, oracc 0.96930, gacc 0.90496, b1 0.30734, b2 0.23742, b3 0.18741, b4 0.15008, padchxlmacf1 0.05885, padchxlmicf1 0.11223, padchxlzmacf1 0.07791, padchxlzmicf1 0.13383, 34.41 secs
# Adjusting learning rate of group 0 to 1.2329e-04.
# ---- Epoch 16/60
# (1) Training stage (lr = 0.000123) ...
# loss 2.90772, a_loss 1.31885, ema 0.37227, oracc 0.96793, orien_loss 0.11615, gacc 0.90420, gloss 0.23726, b1 0.49988, b2 0.39947, b3 0.31680, b4 0.25318, padchxlmacf1 0.04819, padchxlmicf1 0.10131, padchxlzmacf1 0.06742, padchxlzmicf1 0.10731, padchxl_loss 0.57935, padchxlz_loss 0.73262, 135.45 secs
# (2) Validation stage ...
# ema 0.34516, oracc 0.96658, gacc 0.90291, b1 0.31245, b2 0.23934, b3 0.18655, b4 0.14499, padchxlmacf1 0.05954, padchxlmicf1 0.11419, padchxlzmacf1 0.07812, padchxlzmicf1 0.12761, 35.33 secs
# Adjusting learning rate of group 0 to 1.1078e-04.
# ---- Epoch 17/60
# (1) Training stage (lr = 0.000111) ...
# loss 2.77736, a_loss 1.30068, ema 0.37270, oracc 0.97057, orien_loss 0.11048, gacc 0.90913, gloss 0.22821, b1 0.50778, b2 0.40607, b3 0.32276, b4 0.25890, padchxlmacf1 0.04807, padchxlmicf1 0.10225, padchxlzmacf1 0.06645, padchxlzmicf1 0.10704, padchxl_loss 0.57793, padchxlz_loss 0.72857, 139.69 secs
# (2) Validation stage ...
# ema 0.34493, oracc 0.96930, gacc 0.90496, b1 0.31786, b2 0.24406, b3 0.19099, b4 0.14971, padchxlmacf1 0.06035, padchxlmicf1 0.11504, padchxlzmacf1 0.07823, padchxlzmicf1 0.12870, 35.70 secs
# Adjusting learning rate of group 0 to 9.9543e-05.
# ---- Epoch 18/60
# (1) Training stage (lr = 0.000100) ...
# loss 3.08374, a_loss 1.29060, ema 0.37743, oracc 0.96853, orien_loss 0.11460, gacc 0.90957, gloss 0.23024, b1 0.51100, b2 0.40891, b3 0.32476, b4 0.25977, padchxlmacf1 0.05055, padchxlmicf1 0.10677, padchxlzmacf1 0.06849, padchxlzmicf1 0.10955, padchxl_loss 0.56562, padchxlz_loss 0.73150, 134.72 secs
# (2) Validation stage ...
# ema 0.34834, oracc 0.96658, gacc 0.90791, b1 0.35191, b2 0.27108, b3 0.21394, b4 0.17058, padchxlmacf1 0.06161, padchxlmicf1 0.11786, padchxlzmacf1 0.07873, padchxlzmicf1 0.13004, 33.98 secs
# Adjusting learning rate of group 0 to 8.9443e-05.
# ---- Epoch 19/60
# (1) Training stage (lr = 0.000089) ...
# loss 2.87389, a_loss 1.27829, ema 0.37053, oracc 0.96863, orien_loss 0.11483, gacc 0.90777, gloss 0.23454, b1 0.52205, b2 0.41887, b3 0.33280, b4 0.26641, padchxlmacf1 0.04924, padchxlmicf1 0.10456, padchxlzmacf1 0.06774, padchxlzmicf1 0.10657, padchxl_loss 0.57214, padchxlz_loss 0.72789, 125.64 secs
# (2) Validation stage ...
# ema 0.34766, oracc 0.96976, gacc 0.90700, b1 0.32981, b2 0.25342, b3 0.19982, b4 0.15875, padchxlmacf1 0.06024, padchxlmicf1 0.11595, padchxlzmacf1 0.07985, padchxlzmicf1 0.13038, 33.37 secs
# Adjusting learning rate of group 0 to 8.0367e-05.
# ---- Epoch 20/60
# (1) Training stage (lr = 0.000080) ...
# loss 3.01602, a_loss 1.27665, ema 0.37537, oracc 0.96870, orien_loss 0.10939, gacc 0.90920, gloss 0.22596, b1 0.50937, b2 0.40760, b3 0.32320, b4 0.25844, padchxlmacf1 0.04973, padchxlmicf1 0.10281, padchxlzmacf1 0.06711, padchxlzmicf1 0.10654, padchxl_loss 0.57124, padchxlz_loss 0.72883, 132.26 secs
# (2) Validation stage ...
# ema 0.34084, oracc 0.97181, gacc 0.90723, b1 0.32454, b2 0.25322, b3 0.20026, b4 0.15899, padchxlmacf1 0.06149, padchxlmicf1 0.11592, padchxlzmacf1 0.07971, padchxlzmicf1 0.12950, 34.86 secs
# Adjusting learning rate of group 0 to 7.2213e-05.
# ---- Epoch 21/60
# (1) Training stage (lr = 0.000072) ...
# loss 2.80651, a_loss 1.27395, ema 0.37533, oracc 0.96807, orien_loss 0.11895, gacc 0.90783, gloss 0.22946, b1 0.50878, b2 0.40798, b3 0.32477, b4 0.26056, padchxlmacf1 0.04915, padchxlmicf1 0.10385, padchxlzmacf1 0.06663, padchxlzmicf1 0.10460, padchxl_loss 0.56638, padchxlz_loss 0.72677, 137.45 secs
# (2) Validation stage ...
# ema 0.35198, oracc 0.97067, gacc 0.91064, b1 0.30541, b2 0.23835, b3 0.18908, b4 0.15088, padchxlmacf1 0.06077, padchxlmicf1 0.11677, padchxlzmacf1 0.07996, padchxlzmicf1 0.13141, 35.18 secs
# Adjusting learning rate of group 0 to 6.4886e-05.
# ---- Epoch 22/60
# (1) Training stage (lr = 0.000065) ...
# loss 2.79705, a_loss 1.26694, ema 0.37347, oracc 0.96863, orien_loss 0.11771, gacc 0.91020, gloss 0.22400, b1 0.51435, b2 0.41160, b3 0.32552, b4 0.25915, padchxlmacf1 0.04897, padchxlmicf1 0.10388, padchxlzmacf1 0.06781, padchxlzmicf1 0.10767, padchxl_loss 0.56987, padchxlz_loss 0.72237, 140.32 secs
# (2) Validation stage ...
# ema 0.35061, oracc 0.97294, gacc 0.90996, b1 0.28999, b2 0.22505, b3 0.17893, b4 0.14237, padchxlmacf1 0.06120, padchxlmicf1 0.11598, padchxlzmacf1 0.08014, padchxlzmicf1 0.12745, 35.54 secs
# Adjusting learning rate of group 0 to 5.8302e-05.
# ---- Epoch 23/60
# (1) Training stage (lr = 0.000058) ...
# loss 2.75919, a_loss 1.24825, ema 0.37990, oracc 0.97217, orien_loss 0.10523, gacc 0.91777, gloss 0.21655, b1 0.51567, b2 0.41581, b3 0.33334, b4 0.26968, padchxlmacf1 0.05102, padchxlmicf1 0.10552, padchxlzmacf1 0.06858, padchxlzmicf1 0.10744, padchxl_loss 0.56272, padchxlz_loss 0.72439, 142.57 secs
# (2) Validation stage ...
# ema 0.34993, oracc 0.97067, gacc 0.90882, b1 0.30241, b2 0.23414, b3 0.18667, b4 0.14955, padchxlmacf1 0.06109, padchxlmicf1 0.11654, padchxlzmacf1 0.08095, padchxlzmicf1 0.12802, 35.86 secs
# Adjusting learning rate of group 0 to 5.2386e-05.
# ---- Epoch 24/60
# (1) Training stage (lr = 0.000052) ...
# loss 2.95562, a_loss 1.25752, ema 0.38273, oracc 0.96887, orien_loss 0.11272, gacc 0.91260, gloss 0.22311, b1 0.51884, b2 0.41721, b3 0.33294, b4 0.26776, padchxlmacf1 0.05110, padchxlmicf1 0.10362, padchxlzmacf1 0.06786, padchxlzmicf1 0.10547, padchxl_loss 0.56932, padchxlz_loss 0.72506, 143.63 secs
# (2) Validation stage ...
# ema 0.34925, oracc 0.97181, gacc 0.90814, b1 0.33283, b2 0.26150, b3 0.20842, b4 0.16689, padchxlmacf1 0.06118, padchxlmicf1 0.11603, padchxlzmacf1 0.08179, padchxlzmicf1 0.12845, 35.50 secs
# Adjusting learning rate of group 0 to 4.7071e-05.
# ---- Epoch 25/60
# (1) Training stage (lr = 0.000047) ...
# loss 2.74767, a_loss 1.25376, ema 0.37987, oracc 0.96897, orien_loss 0.10959, gacc 0.91300, gloss 0.22176, b1 0.51194, b2 0.41222, b3 0.32972, b4 0.26575, padchxlmacf1 0.05059, padchxlmicf1 0.10233, padchxlzmacf1 0.06760, padchxlzmicf1 0.10423, padchxl_loss 0.56741, padchxlz_loss 0.72629, 142.93 secs
# (2) Validation stage ...
# ema 0.35107, oracc 0.97203, gacc 0.90882, b1 0.30278, b2 0.23485, b3 0.18515, b4 0.14564, padchxlmacf1 0.06154, padchxlmicf1 0.11612, padchxlzmacf1 0.08213, padchxlzmicf1 0.13007, 35.45 secs
# Adjusting learning rate of group 0 to 4.2295e-05.
# ---- Epoch 26/60
# (1) Training stage (lr = 0.000042) ...
# loss 2.55921, a_loss 1.24552, ema 0.38487, oracc 0.96870, orien_loss 0.11763, gacc 0.91307, gloss 0.22073, b1 0.51684, b2 0.41593, b3 0.33123, b4 0.26558, padchxlmacf1 0.04976, padchxlmicf1 0.10374, padchxlzmacf1 0.06749, padchxlzmicf1 0.10749, padchxl_loss 0.56481, padchxlz_loss 0.72042, 144.31 secs
# (2) Validation stage ...
# ema 0.34970, oracc 0.97294, gacc 0.91041, b1 0.29568, b2 0.22926, b3 0.18283, b4 0.14643, padchxlmacf1 0.06244, padchxlmicf1 0.11569, padchxlzmacf1 0.08243, padchxlzmicf1 0.12995, 35.97 secs
# Adjusting learning rate of group 0 to 3.8003e-05.
# ---- Epoch 27/60
# (1) Training stage (lr = 0.000038) ...
# loss 3.09880, a_loss 1.25635, ema 0.37463, oracc 0.96893, orien_loss 0.11312, gacc 0.91417, gloss 0.22131, b1 0.51497, b2 0.41438, b3 0.33045, b4 0.26558, padchxlmacf1 0.05065, padchxlmicf1 0.10278, padchxlzmacf1 0.06913, padchxlzmicf1 0.10739, padchxl_loss 0.56552, padchxlz_loss 0.72499, 143.00 secs
# (2) Validation stage ...
# ema 0.35880, oracc 0.97249, gacc 0.90950, b1 0.26630, b2 0.21071, b3 0.16616, b4 0.13033, padchxlmacf1 0.06215, padchxlmicf1 0.11594, padchxlzmacf1 0.08199, padchxlzmicf1 0.13147, 37.04 secs
# Adjusting learning rate of group 0 to 3.4147e-05.
# ---- Epoch 28/60
# (1) Training stage (lr = 0.000034) ...
# loss 2.86523, a_loss 1.24466, ema 0.37653, oracc 0.96967, orien_loss 0.10800, gacc 0.91660, gloss 0.21350, b1 0.51801, b2 0.41825, b3 0.33462, b4 0.27017, padchxlmacf1 0.05170, padchxlmicf1 0.10416, padchxlzmacf1 0.06892, padchxlzmicf1 0.10809, padchxl_loss 0.56351, padchxlz_loss 0.71904, 144.53 secs
# (2) Validation stage ...
# ema 0.35539, oracc 0.97112, gacc 0.91041, b1 0.32697, b2 0.25709, b3 0.20395, b4 0.16179, padchxlmacf1 0.06304, padchxlmicf1 0.11670, padchxlzmacf1 0.08215, padchxlzmicf1 0.13003, 37.81 secs
# Adjusting learning rate of group 0 to 3.0683e-05.
# ---- Epoch 29/60
# (1) Training stage (lr = 0.000031) ...
# loss 2.85630, a_loss 1.24167, ema 0.37910, oracc 0.97063, orien_loss 0.10317, gacc 0.91447, gloss 0.21623, b1 0.51745, b2 0.41770, b3 0.33396, b4 0.26949, padchxlmacf1 0.05160, padchxlmicf1 0.10565, padchxlzmacf1 0.06899, padchxlzmicf1 0.10894, padchxl_loss 0.56620, padchxlz_loss 0.72035, 144.70 secs
# (2) Validation stage ...
# ema 0.35630, oracc 0.97112, gacc 0.91291, b1 0.31417, b2 0.24672, b3 0.19684, b4 0.15699, padchxlmacf1 0.06235, padchxlmicf1 0.11630, padchxlzmacf1 0.08187, padchxlzmicf1 0.13083, 37.56 secs
# Adjusting learning rate of group 0 to 2.7569e-05.
# ---- Epoch 30/60
# (1) Training stage (lr = 0.000028) ...
# loss 2.81536, a_loss 1.24864, ema 0.37603, oracc 0.97070, orien_loss 0.10967, gacc 0.91340, gloss 0.21651, b1 0.51725, b2 0.41740, b3 0.33426, b4 0.26959, padchxlmacf1 0.05047, padchxlmicf1 0.10363, padchxlzmacf1 0.06860, padchxlzmicf1 0.10713, padchxl_loss 0.56496, padchxlz_loss 0.72101, 143.84 secs
# (2) Validation stage ...
# ema 0.35198, oracc 0.97044, gacc 0.91246, b1 0.29022, b2 0.22590, b3 0.17860, b4 0.14082, padchxlmacf1 0.06386, padchxlmicf1 0.11778, padchxlzmacf1 0.08228, padchxlzmicf1 0.12841, 38.43 secs
# Adjusting learning rate of group 0 to 2.4772e-05.
# ---- Epoch 31/60
# (1) Training stage (lr = 0.000025) ...
# loss 2.50331, a_loss 1.24211, ema 0.38033, oracc 0.96977, orien_loss 0.10875, gacc 0.91397, gloss 0.21540, b1 0.51773, b2 0.41899, b3 0.33634, b4 0.27231, padchxlmacf1 0.05040, padchxlmicf1 0.10299, padchxlzmacf1 0.06816, padchxlzmicf1 0.10687, padchxl_loss 0.56320, padchxlz_loss 0.71594, 143.27 secs
# (2) Validation stage ...
# ema 0.35357, oracc 0.97112, gacc 0.91110, b1 0.32505, b2 0.25608, b3 0.20401, b4 0.16227, padchxlmacf1 0.06418, padchxlmicf1 0.11836, padchxlzmacf1 0.08201, padchxlzmicf1 0.12928, 37.58 secs
# Adjusting learning rate of group 0 to 2.2258e-05.
# ---- Epoch 32/60
# (1) Training stage (lr = 0.000022) ...
# loss 3.17721, a_loss 1.24028, ema 0.37887, oracc 0.97193, orien_loss 0.10418, gacc 0.91203, gloss 0.22057, b1 0.51350, b2 0.41479, b3 0.33220, b4 0.26812, padchxlmacf1 0.05090, padchxlmicf1 0.10422, padchxlzmacf1 0.06839, padchxlzmicf1 0.10752, padchxl_loss 0.56472, padchxlz_loss 0.71962, 144.67 secs
# (2) Validation stage ...
# ema 0.35175, oracc 0.96999, gacc 0.91405, b1 0.33912, b2 0.26502, b3 0.21116, b4 0.16859, padchxlmacf1 0.06312, padchxlmicf1 0.11670, padchxlzmacf1 0.08227, padchxlzmicf1 0.12957, 38.03 secs
# Adjusting learning rate of group 0 to 2.0000e-05.
# ---- Epoch 33/60
# (1) Training stage (lr = 0.000020) ...
# loss 2.81095, a_loss 1.23699, ema 0.38070, oracc 0.97057, orien_loss 0.10643, gacc 0.91470, gloss 0.21937, b1 0.51947, b2 0.42018, b3 0.33693, b4 0.27232, padchxlmacf1 0.05111, padchxlmicf1 0.10544, padchxlzmacf1 0.06893, padchxlzmicf1 0.10884, padchxl_loss 0.56108, padchxlz_loss 0.72886, 144.51 secs
# (2) Validation stage ...
# ema 0.35243, oracc 0.97021, gacc 0.91201, b1 0.31866, b2 0.25072, b3 0.19944, b4 0.15841, padchxlmacf1 0.06274, padchxlmicf1 0.11642, padchxlzmacf1 0.08160, padchxlzmicf1 0.12992, 37.59 secs
# Adjusting learning rate of group 0 to 1.7971e-05.
# ---- Epoch 34/60
# (1) Training stage (lr = 0.000018) ...
# loss 2.92169, a_loss 1.23099, ema 0.38010, oracc 0.97093, orien_loss 0.10743, gacc 0.91280, gloss 0.22002, b1 0.52412, b2 0.42351, b3 0.33923, b4 0.27415, padchxlmacf1 0.05134, padchxlmicf1 0.10371, padchxlzmacf1 0.06870, padchxlzmicf1 0.10691, padchxl_loss 0.56495, padchxlz_loss 0.71881, 145.05 secs
# (2) Validation stage ...
# ema 0.35471, oracc 0.97112, gacc 0.91223, b1 0.30000, b2 0.23628, b3 0.18843, b4 0.15060, padchxlmacf1 0.06348, padchxlmicf1 0.11762, padchxlzmacf1 0.08257, padchxlzmicf1 0.12922, 37.11 secs
# Adjusting learning rate of group 0 to 1.6147e-05.
# ---- Epoch 35/60
# (1) Training stage (lr = 0.000016) ...
# loss 3.19330, a_loss 1.23133, ema 0.38157, oracc 0.97050, orien_loss 0.10616, gacc 0.91410, gloss 0.21623, b1 0.51745, b2 0.41741, b3 0.33347, b4 0.26792, padchxlmacf1 0.05091, padchxlmicf1 0.10532, padchxlzmacf1 0.06783, padchxlzmicf1 0.10751, padchxl_loss 0.56273, padchxlz_loss 0.72124, 145.47 secs
# (2) Validation stage ...
# ema 0.35539, oracc 0.97112, gacc 0.91246, b1 0.32548, b2 0.25738, b3 0.20590, b4 0.16458, padchxlmacf1 0.06280, padchxlmicf1 0.11598, padchxlzmacf1 0.08242, padchxlzmicf1 0.13124, 36.47 secs
# Adjusting learning rate of group 0 to 1.4509e-05.
# ---- Epoch 36/60
# (1) Training stage (lr = 0.000015) ...
# loss 2.69648, a_loss 1.23492, ema 0.38003, oracc 0.96950, orien_loss 0.11136, gacc 0.91267, gloss 0.21865, b1 0.51774, b2 0.41808, b3 0.33433, b4 0.26977, padchxlmacf1 0.05046, padchxlmicf1 0.10373, padchxlzmacf1 0.06870, padchxlzmicf1 0.10832, padchxl_loss 0.56182, padchxlz_loss 0.72248, 145.25 secs
# (2) Validation stage ...
# ema 0.35425, oracc 0.97135, gacc 0.91314, b1 0.31754, b2 0.25146, b3 0.20004, b4 0.15856, padchxlmacf1 0.06299, padchxlmicf1 0.11680, padchxlzmacf1 0.08244, padchxlzmicf1 0.12879, 36.14 secs
# Adjusting learning rate of group 0 to 1.3037e-05.
# ---- Epoch 37/60
# (1) Training stage (lr = 0.000013) ...
# loss 2.94440, a_loss 1.21616, ema 0.38337, oracc 0.97167, orien_loss 0.10546, gacc 0.91497, gloss 0.21529, b1 0.52165, b2 0.42259, b3 0.33943, b4 0.27427, padchxlmacf1 0.05094, padchxlmicf1 0.10698, padchxlzmacf1 0.06957, padchxlzmicf1 0.11051, padchxl_loss 0.55807, padchxlz_loss 0.71368, 144.62 secs
# (2) Validation stage ...
# ema 0.35266, oracc 0.97135, gacc 0.91201, b1 0.31650, b2 0.24992, b3 0.20002, b4 0.16047, padchxlmacf1 0.06277, padchxlmicf1 0.11685, padchxlzmacf1 0.08219, padchxlzmicf1 0.13014, 36.26 secs
# Adjusting learning rate of group 0 to 1.1714e-05.
# ---- Epoch 38/60
# (1) Training stage (lr = 0.000012) ...
# loss 2.92239, a_loss 1.22621, ema 0.37860, oracc 0.97157, orien_loss 0.10712, gacc 0.91703, gloss 0.21509, b1 0.52370, b2 0.42497, b3 0.34185, b4 0.27699, padchxlmacf1 0.05130, padchxlmicf1 0.10400, padchxlzmacf1 0.06845, padchxlzmicf1 0.10646, padchxl_loss 0.55962, padchxlz_loss 0.71660, 145.30 secs
# (2) Validation stage ...
# ema 0.35584, oracc 0.97112, gacc 0.91178, b1 0.31427, b2 0.24787, b3 0.19810, b4 0.15845, padchxlmacf1 0.06313, padchxlmicf1 0.11719, padchxlzmacf1 0.08280, padchxlzmicf1 0.13043, 35.86 secs
# Adjusting learning rate of group 0 to 1.0525e-05.
# ---- Epoch 39/60
# (1) Training stage (lr = 0.000011) ...
# loss 2.89302, a_loss 1.23065, ema 0.38547, oracc 0.96913, orien_loss 0.11220, gacc 0.91653, gloss 0.21491, b1 0.52457, b2 0.42358, b3 0.33917, b4 0.27373, padchxlmacf1 0.05138, padchxlmicf1 0.10407, padchxlzmacf1 0.06848, padchxlzmicf1 0.10733, padchxl_loss 0.56412, padchxlz_loss 0.71912, 144.98 secs
# (2) Validation stage ...
# ema 0.35516, oracc 0.97112, gacc 0.91223, b1 0.31854, b2 0.25143, b3 0.20087, b4 0.16075, padchxlmacf1 0.06418, padchxlmicf1 0.11722, padchxlzmacf1 0.08285, padchxlzmicf1 0.12938, 36.26 secs
# Adjusting learning rate of group 0 to 9.4574e-06.
# ---- Epoch 40/60
# (1) Training stage (lr = 0.000009) ...
# loss 3.08886, a_loss 1.22651, ema 0.37977, oracc 0.97073, orien_loss 0.10890, gacc 0.91607, gloss 0.21419, b1 0.51798, b2 0.41906, b3 0.33693, b4 0.27321, padchxlmacf1 0.05146, padchxlmicf1 0.10421, padchxlzmacf1 0.06772, padchxlzmicf1 0.10533, padchxl_loss 0.56059, padchxlz_loss 0.72029, 145.06 secs
# (2) Validation stage ...
# ema 0.35175, oracc 0.97135, gacc 0.91246, b1 0.32388, b2 0.25460, b3 0.20357, b4 0.16295, padchxlmacf1 0.06407, padchxlmicf1 0.11701, padchxlzmacf1 0.08255, padchxlzmicf1 0.12973, 36.65 secs
# Adjusting learning rate of group 0 to 8.4978e-06.
# ---- Epoch 41/60
# (1) Training stage (lr = 0.000008) ...
# loss 2.98901, a_loss 1.23181, ema 0.38490, oracc 0.96927, orien_loss 0.11206, gacc 0.91330, gloss 0.21889, b1 0.51910, b2 0.41881, b3 0.33442, b4 0.26865, padchxlmacf1 0.04976, padchxlmicf1 0.10186, padchxlzmacf1 0.06810, padchxlzmicf1 0.10701, padchxl_loss 0.56400, padchxlz_loss 0.72169, 145.26 secs
# (2) Validation stage ...
# ema 0.35266, oracc 0.97226, gacc 0.91178, b1 0.32639, b2 0.25623, b3 0.20438, b4 0.16335, padchxlmacf1 0.06391, padchxlmicf1 0.11701, padchxlzmacf1 0.08261, padchxlzmicf1 0.13037, 36.09 secs
# Adjusting learning rate of group 0 to 7.6356e-06.
# ---- Epoch 42/60
# (1) Training stage (lr = 0.000008) ...
# loss 2.93151, a_loss 1.23472, ema 0.37733, oracc 0.96997, orien_loss 0.10764, gacc 0.91330, gloss 0.21455, b1 0.52028, b2 0.41949, b3 0.33464, b4 0.26864, padchxlmacf1 0.05117, padchxlmicf1 0.10427, padchxlzmacf1 0.06911, padchxlzmicf1 0.10826, padchxl_loss 0.56173, padchxlz_loss 0.72056, 140.00 secs
# (2) Validation stage ...
# ema 0.35266, oracc 0.97226, gacc 0.91269, b1 0.32321, b2 0.25392, b3 0.20180, b4 0.16042, padchxlmacf1 0.06361, padchxlmicf1 0.11671, padchxlzmacf1 0.08244, padchxlzmicf1 0.13029, 33.94 secs
# Adjusting learning rate of group 0 to 6.8608e-06.
# ---- Epoch 43/60
# (1) Training stage (lr = 0.000007) ...
# loss 2.63535, a_loss 1.22446, ema 0.38093, oracc 0.97133, orien_loss 0.10317, gacc 0.91673, gloss 0.21465, b1 0.52053, b2 0.42142, b3 0.33724, b4 0.27256, padchxlmacf1 0.05226, padchxlmicf1 0.10407, padchxlzmacf1 0.06947, padchxlzmicf1 0.10820, padchxl_loss 0.56254, padchxlz_loss 0.72419, 126.62 secs
# (2) Validation stage ...
# ema 0.35562, oracc 0.97181, gacc 0.91223, b1 0.31460, b2 0.24872, b3 0.19904, b4 0.15944, padchxlmacf1 0.06353, padchxlmicf1 0.11668, padchxlzmacf1 0.08281, padchxlzmicf1 0.13017, 33.43 secs
# Adjusting learning rate of group 0 to 6.1647e-06.
# ---- Epoch 44/60
# (1) Training stage (lr = 0.000006) ...
# loss 2.78738, a_loss 1.23117, ema 0.37803, oracc 0.97300, orien_loss 0.10130, gacc 0.91473, gloss 0.21458, b1 0.51599, b2 0.41670, b3 0.33332, b4 0.26860, padchxlmacf1 0.05124, padchxlmicf1 0.10343, padchxlzmacf1 0.06925, padchxlzmicf1 0.10649, padchxl_loss 0.56194, padchxlz_loss 0.72044, 123.55 secs
# (2) Validation stage ...
# ema 0.35016, oracc 0.97226, gacc 0.91269, b1 0.33547, b2 0.26415, b3 0.21042, b4 0.16711, padchxlmacf1 0.06331, padchxlmicf1 0.11621, padchxlzmacf1 0.08250, padchxlzmicf1 0.13096, 33.17 secs
# Adjusting learning rate of group 0 to 5.5392e-06.
# ---- Epoch 45/60
# (1) Training stage (lr = 0.000006) ...
# loss 3.07719, a_loss 1.22515, ema 0.37917, oracc 0.97060, orien_loss 0.10784, gacc 0.91563, gloss 0.21303, b1 0.52092, b2 0.42202, b3 0.33943, b4 0.27489, padchxlmacf1 0.05161, padchxlmicf1 0.10259, padchxlzmacf1 0.06822, padchxlzmicf1 0.10674, padchxl_loss 0.56710, padchxlz_loss 0.72095, 123.57 secs
# (2) Validation stage ...
# ema 0.35334, oracc 0.97226, gacc 0.91223, b1 0.31955, b2 0.25134, b3 0.20003, b4 0.15906, padchxlmacf1 0.06326, padchxlmicf1 0.11603, padchxlzmacf1 0.08258, padchxlzmicf1 0.13044, 33.05 secs
# Adjusting learning rate of group 0 to 4.9771e-06.
# ---- Epoch 46/60
# (1) Training stage (lr = 0.000005) ...
# loss 2.74430, a_loss 1.23097, ema 0.38300, oracc 0.97047, orien_loss 0.10487, gacc 0.91587, gloss 0.21029, b1 0.51795, b2 0.41964, b3 0.33691, b4 0.27209, padchxlmacf1 0.05059, padchxlmicf1 0.10312, padchxlzmacf1 0.06850, padchxlzmicf1 0.10766, padchxl_loss 0.56310, padchxlz_loss 0.72150, 123.28 secs
# (2) Validation stage ...
# ema 0.35630, oracc 0.97249, gacc 0.91360, b1 0.32097, b2 0.25287, b3 0.20165, b4 0.16063, padchxlmacf1 0.06373, padchxlmicf1 0.11672, padchxlzmacf1 0.08243, padchxlzmicf1 0.12965, 33.50 secs
# Adjusting learning rate of group 0 to 4.4721e-06.
# ---- Epoch 47/60
# (1) Training stage (lr = 0.000004) ...
# loss 2.64292, a_loss 1.22407, ema 0.38033, oracc 0.97197, orien_loss 0.10185, gacc 0.91447, gloss 0.21828, b1 0.51972, b2 0.42199, b3 0.33998, b4 0.27579, padchxlmacf1 0.05094, padchxlmicf1 0.10467, padchxlzmacf1 0.06926, padchxlzmicf1 0.10840, padchxl_loss 0.55987, padchxlz_loss 0.71186, 123.83 secs
# (2) Validation stage ...
# ema 0.35334, oracc 0.97203, gacc 0.91382, b1 0.32560, b2 0.25536, b3 0.20374, b4 0.16287, padchxlmacf1 0.06366, padchxlmicf1 0.11671, padchxlzmacf1 0.08258, padchxlzmicf1 0.13016, 33.34 secs
# Adjusting learning rate of group 0 to 4.0184e-06.
# ---- Epoch 48/60
# (1) Training stage (lr = 0.000004) ...
# loss 3.01091, a_loss 1.23138, ema 0.37977, oracc 0.97087, orien_loss 0.10564, gacc 0.91660, gloss 0.21370, b1 0.52318, b2 0.42231, b3 0.33755, b4 0.27202, padchxlmacf1 0.05177, padchxlmicf1 0.10600, padchxlzmacf1 0.06971, padchxlzmicf1 0.11023, padchxl_loss 0.55984, padchxlz_loss 0.71432, 123.65 secs
# (2) Validation stage ...
# ema 0.35334, oracc 0.97158, gacc 0.91382, b1 0.33318, b2 0.26140, b3 0.20792, b4 0.16519, padchxlmacf1 0.06364, padchxlmicf1 0.11708, padchxlzmacf1 0.08278, padchxlzmicf1 0.13086, 32.83 secs
# Adjusting learning rate of group 0 to 3.6106e-06.
# ---- Epoch 49/60
# (1) Training stage (lr = 0.000004) ...
# loss 2.90605, a_loss 1.21828, ema 0.38640, oracc 0.97330, orien_loss 0.10088, gacc 0.91483, gloss 0.21702, b1 0.52208, b2 0.42169, b3 0.33789, b4 0.27319, padchxlmacf1 0.05100, padchxlmicf1 0.10450, padchxlzmacf1 0.06828, padchxlzmicf1 0.10713, padchxl_loss 0.55947, padchxlz_loss 0.71250, 121.52 secs
# (2) Validation stage ...
# ema 0.35198, oracc 0.97021, gacc 0.91269, b1 0.33337, b2 0.26281, b3 0.20942, b4 0.16658, padchxlmacf1 0.06355, padchxlmicf1 0.11713, padchxlzmacf1 0.08295, padchxlzmicf1 0.13002, 32.85 secs
# Adjusting learning rate of group 0 to 3.2443e-06.
# ---- Epoch 50/60
# (1) Training stage (lr = 0.000003) ...
# loss 2.65237, a_loss 1.23065, ema 0.38250, oracc 0.96920, orien_loss 0.10764, gacc 0.91270, gloss 0.22019, b1 0.51384, b2 0.41576, b3 0.33277, b4 0.26871, padchxlmacf1 0.05038, padchxlmicf1 0.10400, padchxlzmacf1 0.06730, padchxlzmicf1 0.10518, padchxl_loss 0.56595, padchxlz_loss 0.73189, 123.48 secs
# (2) Validation stage ...
# ema 0.35334, oracc 0.97158, gacc 0.91337, b1 0.32750, b2 0.25840, b3 0.20646, b4 0.16495, padchxlmacf1 0.06334, padchxlmicf1 0.11584, padchxlzmacf1 0.08264, padchxlzmicf1 0.13110, 32.62 secs
# Adjusting learning rate of group 0 to 2.9151e-06.
# ---- Epoch 51/60
# (1) Training stage (lr = 0.000003) ...
# loss 2.81848, a_loss 1.22406, ema 0.37390, oracc 0.96987, orien_loss 0.10897, gacc 0.91287, gloss 0.21625, b1 0.52135, b2 0.42255, b3 0.33890, b4 0.27387, padchxlmacf1 0.05078, padchxlmicf1 0.10312, padchxlzmacf1 0.06857, padchxlzmicf1 0.10788, padchxl_loss 0.56305, padchxlz_loss 0.72359, 121.90 secs
# (2) Validation stage ...
# ema 0.35175, oracc 0.97226, gacc 0.91246, b1 0.32708, b2 0.25772, b3 0.20560, b4 0.16397, padchxlmacf1 0.06335, padchxlmicf1 0.11605, padchxlzmacf1 0.08252, padchxlzmicf1 0.13104, 32.86 secs
# Adjusting learning rate of group 0 to 2.6193e-06.
# ---- Epoch 52/60
# (1) Training stage (lr = 0.000003) ...
# loss 2.71135, a_loss 1.20703, ema 0.38717, oracc 0.97187, orien_loss 0.10422, gacc 0.91587, gloss 0.21305, b1 0.52489, b2 0.42552, b3 0.34204, b4 0.27695, padchxlmacf1 0.05164, padchxlmicf1 0.10670, padchxlzmacf1 0.07052, padchxlzmicf1 0.11032, padchxl_loss 0.55474, padchxlz_loss 0.71893, 121.26 secs
# (2) Validation stage ...
# ema 0.35334, oracc 0.97249, gacc 0.91269, b1 0.32929, b2 0.25977, b3 0.20735, b4 0.16539, padchxlmacf1 0.06355, padchxlmicf1 0.11625, padchxlzmacf1 0.08262, padchxlzmicf1 0.13056, 32.98 secs
# Adjusting learning rate of group 0 to 2.3535e-06.
# ---- Epoch 53/60
# (1) Training stage (lr = 0.000002) ...
# loss 2.87235, a_loss 1.22031, ema 0.38350, oracc 0.97100, orien_loss 0.10763, gacc 0.91513, gloss 0.21717, b1 0.52483, b2 0.42539, b3 0.34150, b4 0.27630, padchxlmacf1 0.05228, padchxlmicf1 0.10465, padchxlzmacf1 0.06969, padchxlzmicf1 0.10977, padchxl_loss 0.56038, padchxlz_loss 0.71759, 121.43 secs
# (2) Validation stage ...
# ema 0.35221, oracc 0.97158, gacc 0.91428, b1 0.32918, b2 0.25932, b3 0.20686, b4 0.16475, padchxlmacf1 0.06402, padchxlmicf1 0.11648, padchxlzmacf1 0.08274, padchxlzmicf1 0.13019, 33.06 secs
# Adjusting learning rate of group 0 to 2.1147e-06.
# ---- Epoch 54/60
# (1) Training stage (lr = 0.000002) ...
# loss 2.62926, a_loss 1.21988, ema 0.38253, oracc 0.97043, orien_loss 0.10449, gacc 0.91587, gloss 0.21023, b1 0.52328, b2 0.42375, b3 0.34079, b4 0.27612, padchxlmacf1 0.05115, padchxlmicf1 0.10285, padchxlzmacf1 0.06873, padchxlzmicf1 0.10740, padchxl_loss 0.56420, padchxlz_loss 0.72220, 122.63 secs
# (2) Validation stage ...
# ema 0.35266, oracc 0.97249, gacc 0.91314, b1 0.32938, b2 0.25958, b3 0.20697, b4 0.16515, padchxlmacf1 0.06373, padchxlmicf1 0.11620, padchxlzmacf1 0.08267, padchxlzmicf1 0.13041, 32.71 secs
# Adjusting learning rate of group 0 to 1.9002e-06.
# ---- Epoch 55/60
# (1) Training stage (lr = 0.000002) ...
# loss 2.57415, a_loss 1.22264, ema 0.38617, oracc 0.97033, orien_loss 0.10996, gacc 0.91443, gloss 0.21601, b1 0.51869, b2 0.41860, b3 0.33435, b4 0.26924, padchxlmacf1 0.05102, padchxlmicf1 0.10548, padchxlzmacf1 0.06819, padchxlzmicf1 0.10720, padchxl_loss 0.55569, padchxlz_loss 0.71363, 121.51 secs
# (2) Validation stage ...
# ema 0.35289, oracc 0.97203, gacc 0.91428, b1 0.32344, b2 0.25541, b3 0.20379, b4 0.16260, padchxlmacf1 0.06377, padchxlmicf1 0.11665, padchxlzmacf1 0.08259, padchxlzmicf1 0.13007, 32.67 secs
# Adjusting learning rate of group 0 to 1.7074e-06.
# ---- Epoch 56/60
# (1) Training stage (lr = 0.000002) ...
# loss 2.96250, a_loss 1.22712, ema 0.37943, oracc 0.97083, orien_loss 0.10754, gacc 0.91680, gloss 0.21487, b1 0.52153, b2 0.42201, b3 0.33844, b4 0.27309, padchxlmacf1 0.05002, padchxlmicf1 0.10245, padchxlzmacf1 0.06862, padchxlzmicf1 0.10803, padchxl_loss 0.55832, padchxlz_loss 0.71480, 121.70 secs
# (2) Validation stage ...
# ema 0.35425, oracc 0.97249, gacc 0.91382, b1 0.32467, b2 0.25564, b3 0.20362, b4 0.16187, padchxlmacf1 0.06366, padchxlmicf1 0.11695, padchxlzmacf1 0.08251, padchxlzmicf1 0.12997, 32.99 secs
# Adjusting learning rate of group 0 to 1.5341e-06.
# ---- Epoch 57/60
# (1) Training stage (lr = 0.000002) ...
# loss 2.86628, a_loss 1.22883, ema 0.37670, oracc 0.96970, orien_loss 0.11152, gacc 0.91737, gloss 0.21247, b1 0.51729, b2 0.41805, b3 0.33431, b4 0.26949, padchxlmacf1 0.05123, padchxlmicf1 0.10374, padchxlzmacf1 0.06911, padchxlzmicf1 0.10724, padchxl_loss 0.56671, padchxlz_loss 0.72323, 121.95 secs
# (2) Validation stage ...
# ema 0.35334, oracc 0.97249, gacc 0.91337, b1 0.32615, b2 0.25659, b3 0.20429, b4 0.16252, padchxlmacf1 0.06383, padchxlmicf1 0.11701, padchxlzmacf1 0.08268, padchxlzmicf1 0.13008, 33.39 secs
# Adjusting learning rate of group 0 to 1.3785e-06.
# ---- Epoch 58/60
# (1) Training stage (lr = 0.000001) ...
# loss 2.98722, a_loss 1.21969, ema 0.38633, oracc 0.97217, orien_loss 0.09870, gacc 0.91577, gloss 0.21119, b1 0.52191, b2 0.42270, b3 0.33922, b4 0.27464, padchxlmacf1 0.05205, padchxlmicf1 0.10431, padchxlzmacf1 0.06978, padchxlzmicf1 0.10738, padchxl_loss 0.56068, padchxlz_loss 0.72098, 122.91 secs
# (2) Validation stage ...
# ema 0.35357, oracc 0.97249, gacc 0.91269, b1 0.32620, b2 0.25686, b3 0.20492, b4 0.16348, padchxlmacf1 0.06388, padchxlmicf1 0.11654, padchxlzmacf1 0.08266, padchxlzmicf1 0.13055, 32.90 secs
# Adjusting learning rate of group 0 to 1.2386e-06.
# ---- Epoch 59/60
# (1) Training stage (lr = 0.000001) ...
# loss 2.51830, a_loss 1.22940, ema 0.37560, oracc 0.97160, orien_loss 0.10631, gacc 0.91810, gloss 0.20922, b1 0.51991, b2 0.42048, b3 0.33789, b4 0.27368, padchxlmacf1 0.05097, padchxlmicf1 0.10389, padchxlzmacf1 0.06909, padchxlzmicf1 0.10789, padchxl_loss 0.56302, padchxlz_loss 0.71885, 121.94 secs
# (2) Validation stage ...
# ema 0.35289, oracc 0.97271, gacc 0.91382, b1 0.33175, b2 0.26175, b3 0.20906, b4 0.16674, padchxlmacf1 0.06393, padchxlmicf1 0.11668, padchxlzmacf1 0.08264, padchxlzmicf1 0.13044, 32.72 secs
# Adjusting learning rate of group 0 to 1.1129e-06.
# ---- Epoch 60/60
# (1) Training stage (lr = 0.000001) ...
# loss 2.56575, a_loss 1.22963, ema 0.37907, oracc 0.97070, orien_loss 0.10442, gacc 0.91273, gloss 0.21660, b1 0.51574, b2 0.41764, b3 0.33490, b4 0.27023, padchxlmacf1 0.05042, padchxlmicf1 0.10263, padchxlzmacf1 0.06894, padchxlzmicf1 0.10794, padchxl_loss 0.56371, padchxlz_loss 0.72371, 121.12 secs
# (2) Validation stage ...
# ema 0.35289, oracc 0.97249, gacc 0.91291, b1 0.32479, b2 0.25614, b3 0.20444, b4 0.16282, padchxlmacf1 0.06376, padchxlmicf1 0.11627, padchxlzmacf1 0.08261, padchxlzmicf1 0.13038, 32.82 secs
# Adjusting learning rate of group 0 to 1.0000e-06.
