# %%
# %env CUDA_VISIBLE_DEVICES=0
# Out:
# env: CUDA_VISIBLE_DEVICES=0

# %%
# !python ../train_vqa.py \
        --pretrained-checkpoint-folder-path "/home/pamessina/medvqa-workspace/models/visual_module/20220613_180648_mimiccxr+iuxray+chexpert_densenet121_model-args=(densenet-121,1024)_cnn-pretr=0_dataset_weights=1.0,0.08,0.8_img-aug=random-spatial_tags=0_orien=1_chx=1_ql=1" \
        --epochs 100 \
        --batches-per-epoch 300 \
        --batch-size 140 \
        --num-workers 7 \
        --lr-decay-patience 3 \
        --answer-hidden-size 512 \
        --n-lstm-layers 2 \
        --iuxray-qa-adapted-reports-filename "qa_adapted_reports__20220607_170656.json" \
        --mimiccxr-qa-adapted-reports-filename "qa_adapted_reports__20220607_184201.json" \
        --classify-orientation \
        --classify-chexpert \
        --iuxray-chexpert-labels-filename "chexpert_labels_per_report__20220607_231729.pkl" \
        --mimiccxr-chexpert-labels-filename "chexpert_labels_per_report__20220607_231820.pkl" \
        --classify-questions \
        --n-questions 97 \
        --iuxray-question-labels-filename "question_labels_per_report__20220607_225035.pkl" \
        --mimiccxr-question-labels-filename "question_labels_per_report__20220607_225036.pkl" \
        --balanced-split \
        --iuxray-balanced-metadata-filename "balanced_dataloading_metadata__20220608_025543.pkl" \
        --mimiccxr-balanced-metadata-filename "balanced_dataloading_metadata__20220608_025910.pkl" \
        --balanced-dataloading \
        --medical-tokenization \
        --medical-terms-frequency-filename "medical_terms_frequency__20220607_224903.pkl" \
        --question-encoding "one-hot" \
        --binary-loss-name "wbce-c" \
        --img-aug-mode "random-spatial" \
        --use-amp \
        --save
# Out:
# script's arguments:
#    epochs: 100
#    batches_per_epoch: 300
#    checkpoint_folder: None
#    iuxray_qa_adapted_reports_filename: qa_adapted_reports__20220607_170656.json
#    mimiccxr_qa_adapted_reports_filename: qa_adapted_reports__20220607_184201.json
#    vocab_min_freq: 5
#    embed_size: 128
#    question_encoding: one-hot
#    question_hidden_size: 128
#    answer_hidden_size: 512
#    n_lstm_layers: 2
#    question_vec_size: 128
#    image_local_feat_size: 1024
#    dropout_prob: 0
#    densenet_pretrained_weights_path:
#    lr: 0.001
#    lr_decay: 0.76
#    lr_decay_patience: 3
#    n_val_examples_per_question: 10
#    min_train_examples_per_question: 100
#    batch_size: 140
#    num_workers: 7
#    device: GPU
#    img_aug_mode: random-spatial
#    mimiccxr_weight: 0.83
#    chexpert_weight: 0.1
#    iuxray_weight: 0.07
#    val_answer_decoding: greedy-search
#    beam_search_k: None
#    use_amp: True
#    medical_tokenization: True
# ...

# %%
# !python ../train_vqa.py \
        --checkpoint-folder "models/vqa/20220622_071455_mimiccxr+iuxray+chexpert_oevqa(densenet121+bilstm+lstm)_voc-minf=5_model-args=(densenet-121,128,None,512,2,128,1024,0,qenc=one-hot,pretrained)_cnn-pretr=0_dataset_weights=0.83,0.07,0.1_medtok=1_tags=0_orien=1_chx=1_ql=1_use_amp" \
        --epochs 80 \
        --batches-per-epoch 300 \
        --batch-size 140 \
        --num-workers 7 \
        --save
# Out:
# script's arguments:
#    epochs: 80
#    batches_per_epoch: 300
#    checkpoint_folder: models/vqa/20220622_071455_mimiccxr+iuxray+chexpert_oevqa(densenet121+bilstm+lstm)_voc-minf=5_model-args=(densenet-121,128,None,512,2,128,1024,0,qenc=one-hot,pretrained)_cnn-pretr=0_dataset_weights=0.83,0.07,0.1_medtok=1_tags=0_orien=1_chx=1_ql=1_use_amp
#    iuxray_qa_adapted_reports_filename: None
#    mimiccxr_qa_adapted_reports_filename: None
#    vocab_min_freq: 5
#    embed_size: 128
#    question_encoding: bilstm
#    question_hidden_size: 128
#    answer_hidden_size: 128
#    n_lstm_layers: 1
#    question_vec_size: 128
#    image_local_feat_size: 1024
#    dropout_prob: 0
#    densenet_pretrained_weights_path:
#    lr: 0.001
#    lr_decay: 0.76
#    lr_decay_patience: 2
#    n_val_examples_per_question: 10
#    min_train_examples_per_question: 100
#    batch_size: 140
#    num_workers: 7
#    device: GPU
#    img_aug_mode: None
#    mimiccxr_weight: 0.83
#    chexpert_weight: 0.1
# ...

# %% [markdown]
# ### Training-Validation plots

# %%
from medvqa.evaluation.plots import plot_train_val_curves
from medvqa.utils.constants import MetricNames

# %%
plot_train_val_curves('/home/pamessina/medvqa-workspace/models/vqa/20220622_071455_mimiccxr+iuxray+chexpert_oevqa(densenet121+bilstm+lstm)_voc-minf=5_model-args=(densenet-121,128,None,512,2,128,1024,0,qenc=one-hot,pretrained)_cnn-pretr=0_dataset_weights=0.83,0.07,0.1_medtok=1_tags=0_orien=1_chx=1_ql=1_use_amp/metrics_logs.csv',
                 [MetricNames.WMEDCOMP, MetricNames.CIDER_D,
                  MetricNames.CHXLABELMACROAVGF1, MetricNames.CHXLABELMICROAVGF1,
                  MetricNames.CHXLABELACC,
                  MetricNames.CHXLABEL_ROCAUC_MACRO, MetricNames.CHXLABEL_ROCAUC_MICRO,
                  MetricNames.QLABELSF1, MetricNames.ORIENACC,
                 ],
                 ['Weighted Medical Completeness (QA)', 'cider-D (QA)',
                  'Chexpert-F1 (Macro Avg)', 'Chexpert-F1 (Micro Avg)',
                  'Chexpert Acc',
                  'Chexpert ROC-AUC (Macro Avg)', 'Chexpert ROC-AUC (Micro Avg)',
                  'Question Labels F1', 'Orientation Acc',
                 ],
                 single_plot_figsize=(8,6))

# %% [markdown]
# # Test Set Evaluation

# %% [markdown]
# # 1) Question-level Results

# %%
# !python ../eval_vqa.py \
        --checkpoint-folder "models/vqa/20220622_071455_mimiccxr+iuxray+chexpert_oevqa(densenet121+bilstm+lstm)_voc-minf=5_model-args=(densenet-121,128,None,512,2,128,1024,0,qenc=one-hot,pretrained)_cnn-pretr=0_dataset_weights=0.83,0.07,0.1_medtok=1_tags=0_orien=1_chx=1_ql=1_use_amp" \
        --batch-size 160
# Out:
# script's arguments:
#    checkpoint_folder: models/vqa/20220622_071455_mimiccxr+iuxray+chexpert_oevqa(densenet121+bilstm+lstm)_voc-minf=5_model-args=(densenet-121,128,None,512,2,128,1024,0,qenc=one-hot,pretrained)_cnn-pretr=0_dataset_weights=0.83,0.07,0.1_medtok=1_tags=0_orien=1_chx=1_ql=1_use_amp
#    answer_decoding: greedy-search
#    beam_search_k: None
#    batch_size: 160
#    device: GPU
#    num_workers: 0
#    eval_iuxray: True
#    eval_mimiccxr: True
#    use_amp: False
# ----- Evaluating model ------
# metadata loaded from /home/pamessina/medvqa-workspace/models/vqa/20220622_071455_mimiccxr+iuxray+chexpert_oevqa(densenet121+bilstm+lstm)_voc-minf=5_model-args=(densenet-121,128,None,512,2,128,1024,0,qenc=one-hot,pretrained)_cnn-pretr=0_dataset_weights=0.83,0.07,0.1_medtok=1_tags=0_orien=1_chx=1_ql=1_use_amp/metadata.json
# 1) device = cuda
# 2) Loading iuxray and mimiccxr QA adapted reports ...
# 3) Initializing tokenizer ...
# ...

# %%
from medvqa.utils.files import load_pickle
from medvqa.evaluation.vqa import (
    get_overall_metrics_dataframe,
    get_per_question_metrics_dataframe,
)

# %% [markdown]
# ### IU X-Ray metrics

# %%
iuxray_agg_metrics = load_pickle('/home/pamessina/medvqa-workspace/results/vqa/20220622_071455_mimiccxr+iuxray+chexpert_oevqa(densenet121+bilstm+lstm)_voc-minf=5_model-args=(densenet-121,128,None,512,2,128,1024,0,qenc=one-hot,pretrained)_cnn-pretr=0_dataset_weights=0.83,0.07,0.1_medtok=1_tags=0_orien=1_chx=1_ql=1_use_amp/iuxray_metrics.pkl')

# %%
get_overall_metrics_dataframe(iuxray_agg_metrics)
# Out:
#          b1        b2        b3        b4      rg-L        cD       met  \
# 0  0.382487  0.251192  0.164662  0.107707  0.400212  1.454866  0.352886
#
#       mdcmp    wmdcmp  oracc  ...      qlf1   chx_acc   chx_p_0   chx_p_1  \
# 0  0.223268  0.208986    1.0  ...  0.475724  0.924666  0.946098  0.314837
#
#     chx_r_0   chx_r_1  chx_f1_0  chx_f1_1  chx_s_0  chx_s_1
# 0  0.943528  0.235023  0.942246  0.254624    16223     1445
#
# [1 rows x 25 columns]

# %%
get_per_question_metrics_dataframe(iuxray_agg_metrics, metrics_to_rank=['wmedcomp'])
# Out:
#                                      Q        b1        b2            b3  \
# 0                        pleural space  0.596557  0.451322  2.996498e-01
# 1                         pneumothorax  0.493898  0.317538  1.190783e-01
# 2                         cardiomegaly  0.286869  0.076113  2.210332e-02
# 3                           tortuosity  0.442990  0.146201  5.575001e-02
# 4                        consolidation  0.470825  0.349346  2.049011e-01
# 5                   cardiac silhouette  0.446029  0.258484  1.664942e-01
# 6                               masses  0.687500  0.250000  2.500023e-06
# 7                                edema  0.384680  0.200159  1.442748e-01
# 8                                heart  0.377275  0.239361  1.212167e-01
# 9                            emphysema  0.344142  0.062679  6.172347e-07
# 10                          infiltrate  0.271326  0.157556  1.499032e-01
# 11                         soft tissue  0.525831  0.384998  3.316811e-06
# ...

# %% [markdown]
# ### MIMIC-CXR metrics

# %%
mimiccxr_agg_metrics = load_pickle('/home/pamessina/medvqa-workspace/results/vqa/20220622_071455_mimiccxr+iuxray+chexpert_oevqa(densenet121+bilstm+lstm)_voc-minf=5_model-args=(densenet-121,128,None,512,2,128,1024,0,qenc=one-hot,pretrained)_cnn-pretr=0_dataset_weights=0.83,0.07,0.1_medtok=1_tags=0_orien=1_chx=1_ql=1_use_amp/mimiccxr_metrics.pkl')

# %%
get_overall_metrics_dataframe(mimiccxr_agg_metrics)
# Out:
#          b1       b2       b3        b4      rg-L        cD       met  \
# 0  0.101351  0.05669  0.03151  0.017783  0.232957  0.539548  0.160629
#
#       mdcmp    wmdcmp     oracc  ...      qlf1   chx_acc   chx_p_0   chx_p_1  \
# 0  0.204755  0.191802  0.996355  ...  0.496243  0.917733  0.943928  0.527035
#
#     chx_r_0   chx_r_1  chx_f1_0  chx_f1_1  chx_s_0  chx_s_1
# 0  0.952259  0.384827  0.947206  0.431455   381822    45920
#
# [1 rows x 25 columns]

# %%
get_per_question_metrics_dataframe(mimiccxr_agg_metrics, metrics_to_rank=['wmedcomp'])[:40]
# Out:
#                            Q        b1            b2            b3  \
# 0                azygos lobe  0.067668  3.026189e-09  1.074157e-08
# 1                   free air  0.415798  3.360869e-01  2.621404e-01
# 2           pneumoperitoneum  0.206835  1.111111e-01  1.111117e-03
# 3               pneumothorax  0.322775  2.334928e-01  2.660026e-02
# 4                   blurring  0.187688  1.423057e-01  1.023318e-01
# 5                soft tissue  0.203203  1.436952e-01  7.508451e-02
# 6             fluid overload  0.255678  2.041786e-01  1.047187e-01
# 7                 tortuosity  0.154205  9.487358e-03  9.797715e-08
# 8               cardiomegaly  0.173969  8.076487e-02  5.307683e-03
# 9   bronchovascular crowding  0.225774  1.031186e-01  1.332519e-02
# 10                   hernias  0.201172  1.359760e-01  6.675515e-02
# 11             consolidation  0.262865  1.740447e-01  1.143111e-01
# 12                 diaphragm  0.155465  9.200338e-02  5.000352e-02
# ...

# %% [markdown]
# # 2) Report-level Results

# %%
# !python ../eval_report_generation.py \
        --checkpoint-folder "models/vqa/20220622_071455_mimiccxr+iuxray+chexpert_oevqa(densenet121+bilstm+lstm)_voc-minf=5_model-args=(densenet-121,128,None,512,2,128,1024,0,qenc=one-hot,pretrained)_cnn-pretr=0_dataset_weights=0.83,0.07,0.1_medtok=1_tags=0_orien=1_chx=1_ql=1_use_amp" \
        --eval-mode "ground-truth" \
        --no-iuxray \
        --batch-size 160
# Out:
# script's arguments:
#    checkpoint_folder: models/vqa/20220622_071455_mimiccxr+iuxray+chexpert_oevqa(densenet121+bilstm+lstm)_voc-minf=5_model-args=(densenet-121,128,None,512,2,128,1024,0,qenc=one-hot,pretrained)_cnn-pretr=0_dataset_weights=0.83,0.07,0.1_medtok=1_tags=0_orien=1_chx=1_ql=1_use_amp
#    eval_mode: ground-truth
#    n_questions_per_report: None
#    batch_size: 160
#    device: GPU
#    num_workers: 0
#    answer_decoding: greedy-search
#    eval_iuxray: False
#    eval_mimiccxr: True
#    use_amp: False
# ----- Evaluating model ------
# metadata loaded from /home/pamessina/medvqa-workspace/models/vqa/20220622_071455_mimiccxr+iuxray+chexpert_oevqa(densenet121+bilstm+lstm)_voc-minf=5_model-args=(densenet-121,128,None,512,2,128,1024,0,qenc=one-hot,pretrained)_cnn-pretr=0_dataset_weights=0.83,0.07,0.1_medtok=1_tags=0_orien=1_chx=1_ql=1_use_amp/metadata.json
# 1) device = cuda
# 2) Loading iuxray and mimiccxr QA adapted reports ...
# 3) Initializing tokenizer ...
# ...

# %%
# !python ../eval_report_generation.py \
        --checkpoint-folder "models/vqa/20220622_071455_mimiccxr+iuxray+chexpert_oevqa(densenet121+bilstm+lstm)_voc-minf=5_model-args=(densenet-121,128,None,512,2,128,1024,0,qenc=one-hot,pretrained)_cnn-pretr=0_dataset_weights=0.83,0.07,0.1_medtok=1_tags=0_orien=1_chx=1_ql=1_use_amp" \
        --eval-mode "question-classification" \
        --n-questions-per-report 15 \
        --no-iuxray \
        --batch-size 160
# Out:
# script's arguments:
#    checkpoint_folder: models/vqa/20220622_071455_mimiccxr+iuxray+chexpert_oevqa(densenet121+bilstm+lstm)_voc-minf=5_model-args=(densenet-121,128,None,512,2,128,1024,0,qenc=one-hot,pretrained)_cnn-pretr=0_dataset_weights=0.83,0.07,0.1_medtok=1_tags=0_orien=1_chx=1_ql=1_use_amp
#    eval_mode: question-classification
#    n_questions_per_report: 15
#    batch_size: 160
#    device: GPU
#    num_workers: 0
#    answer_decoding: greedy-search
#    eval_iuxray: False
#    eval_mimiccxr: True
#    use_amp: False
# ----- Evaluating model ------
# metadata loaded from /home/pamessina/medvqa-workspace/models/vqa/20220622_071455_mimiccxr+iuxray+chexpert_oevqa(densenet121+bilstm+lstm)_voc-minf=5_model-args=(densenet-121,128,None,512,2,128,1024,0,qenc=one-hot,pretrained)_cnn-pretr=0_dataset_weights=0.83,0.07,0.1_medtok=1_tags=0_orien=1_chx=1_ql=1_use_amp/metadata.json
# 1) device = cuda
# 2) Loading iuxray and mimiccxr QA adapted reports ...
# 3) Initializing tokenizer ...
# ...

# %%
from medvqa.evaluation.report_generation import get_report_level_metrics_dataframe
from medvqa.utils.files import load_pickle

# %% [markdown]
# ### MIMIC-CXR metrics

# %%
mimiccxr_report_metrics = load_pickle('/home/pamessina/medvqa-workspace/results/vqa/20220622_071455_mimiccxr+iuxray+chexpert_oevqa(densenet121+bilstm+lstm)_voc-minf=5_model-args=(densenet-121,128,None,512,2,128,1024,0,qenc=one-hot,pretrained)_cnn-pretr=0_dataset_weights=0.83,0.07,0.1_medtok=1_tags=0_orien=1_chx=1_ql=1_use_amp/mimiccxr_report_level_metrics(eval_mode=ground-truth).pkl')
mimiccxr_report_level_df = get_report_level_metrics_dataframe(mimiccxr_report_metrics, 'gt')
mimiccxr_report_level_df[mimiccxr_report_level_df.columns[:20]]
# Out:
# 1it [00:00,  1.03it/s]
#   method_name        b1        b2        b3       b4        cD      rg-L  \
# 0     asdfads  0.306829  0.179708  0.102726  0.05676  0.137853  0.222944
#
#         met     mdcmp    wmdcmp  chxlabf1(hard)  p(micro)  r(micro)  \
# 0  0.241564  0.170277  0.150533        0.650737  0.626488       0.8
#
#    f1(micro)  p(macro)  r(macro)  f1(macro)       acc     p(NF)     p(EC)
# 0   0.702691  0.553958  0.671073   0.600409  0.836137  0.586667  0.533828

# %%
mimiccxr_report_metrics = load_pickle('/home/pamessina/medvqa-workspace/results/vqa/20220622_071455_mimiccxr+iuxray+chexpert_oevqa(densenet121+bilstm+lstm)_voc-minf=5_model-args=(densenet-121,128,None,512,2,128,1024,0,qenc=one-hot,pretrained)_cnn-pretr=0_dataset_weights=0.83,0.07,0.1_medtok=1_tags=0_orien=1_chx=1_ql=1_use_amp/mimiccxr_report_level_metrics(eval_mode=question-classification;n_questions_per_report=15).pkl')
mimiccxr_report_level_df = get_report_level_metrics_dataframe(mimiccxr_report_metrics, 'qc-top15')
mimiccxr_report_level_df[mimiccxr_report_level_df.columns[:20]]
# Out:
# 1it [00:01,  1.07s/it]
#   method_name        b1        b2        b3       b4        cD      rg-L  \
# 0    qc-top15  0.180012  0.100442  0.055286  0.02978  0.016474  0.170115
#
#         met     mdcmp    wmdcmp  chxlabf1(hard)  p(micro)  r(micro)  \
# 0  0.189114  0.101566  0.086037        0.502839  0.463584  0.702581
#
#    f1(micro)  p(macro)  r(macro)  f1(macro)       acc     p(NF)     p(EC)
# 0   0.558592  0.365312  0.525847   0.411852  0.732907  0.411765  0.287261
