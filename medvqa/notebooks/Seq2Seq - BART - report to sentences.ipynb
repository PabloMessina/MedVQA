# %%
# %env CUDA_VISIBLE_DEVICES=0
# Out:
# env: CUDA_VISIBLE_DEVICES=0

# %%
# !ls /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/
# Out:
#  gpt-3.5-turbo_parsed_backgrounds.jsonl
#  gpt-3.5-turbo_parsed_reports__backup.jsonl
#  gpt-3.5-turbo_parsed_reports.jsonl
# 'gpt-3.5-turbo_parsed_reports(old).jsonl'
#  gpt-3.5-turbo_parsed_sentences.jsonl
#  gpt-4-0613_parsed_reports.jsonl
#  gpt-4-0613_parsed_sentences.jsonl

# %%
# !python ../train_seq2seq.py \
        --epochs 60 \
        --batches_per_epoch 1000 \
        --batch_size 10 \
        --num_workers 3 \
        --iters_to_accumulate 10 \
        --optimizer_name "adamw" \
        --scheduler "exp-warmup+decay+cyclicdecay" \
        --lr 1e-6 \
        --warmup_decay_and_cyclic_decay_args "1e-6,3,1e-4,8,1e-6,1e-4,8,1e-6" \
        --task_name "report2sentences" \
        --input_output_jsonl_filepaths \
            "/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo_parsed_reports.jsonl" \
            "/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_parsed_reports.jsonl" \
        --seq2seq_model_name "bart" \
        --bart_model_name "facebook/bart-base" \
        --use_amp \
        --save
# Out:
# script's arguments:
#    epochs: 60
#    batches_per_epoch: 1000
#    batch_size: 10
#    checkpoint_folder: None
#    seq2seq_model_name: bart
#    t5_model_name: t5-small
#    bart_model_name: facebook/bart-base
#    pretrained_checkpoint_folder_path: None
#    optimizer_name: adamw
#    lr: 1e-06
#    scheduler: exp-warmup+decay+cyclicdecay
#    lr_decay: 0.76
#    lr_decay_patience: 2
#    warmup_and_decay_args: None
#    warmup_and_cosine_args: None
#    warmup_decay_and_cyclic_decay_args: 1e-6,3,1e-4,8,1e-6,1e-4,8,1e-6
#    iters_to_accumulate: 10
#    override_lr: False
#    task_name: report2sentences
#    val_size: 200
#    input_output_jsonl_filepaths: ['/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo_parsed_reports.jsonl', '/home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_parsed_reports.jsonl']
#    num_workers: 3
#    device: GPU
#    use_amp: True
#    save: True
# ----- Training model from scratch ------
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Creating instance of Seq2SeqModel ...
# Seq2Seq model:
#   model_name: facebook/bart-base
# --------------------------------------------------
# 3) Defining optimizer ...
# create_optimizer(): name = adamw
# --------------------------------------------------
# 4) Defining scheduler ...
# Using exp-warmup+decay+cyclicdecay scheduler: 1e-6,3,1e-4,8,1e-6,1e-4,8,1e-6
# 1e-06 3 0.0001 8 1e-06 0.0001 8 1e-06
# self.steps_to_restart = 8
# self.steps = -1
# self.initial_lr = 0.0001
# --------------------------------------------------
# 5) Creating trainer and validator engines ...
# GradientAccumulator.__init__(): num_accumulation_steps = 10
# --------------------------------------------------
# 6) Defining collate_batch_fn ...
# Loaded 9314 input/output pairs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-3.5-turbo_parsed_reports.jsonl
# Loaded 15322 input/output pairs from /home/pamessina/medvqa-workspace/cache/mimiccxr/openai/gpt-4-0613_parsed_reports.jsonl
# Number of train examples: 24436
# Number of val examples: 200
# Number of total examples: 24636
# Input/output example:
# Input:
# PA and lateral upright chest radiographs were reviewed in comparison to . Heart size is top normal, stable. Tortuous aorta is redemonstrated, unchanged. Minimal amount of left basal atelectasis is noted associated with small amount of pleural effusion. Nodular opacity projecting over the first rib is redemonstrated and not clearly seen on the prior studies from , thus correlation with cross-sectional imaging is recommended. Right basal opacity appears to be more pronounced than on the prior study and might reflect atelectasis, but right lower lobe infection is a possibility especially given the patient's described history.
#
# Output:
# PA and lateral upright chest radiographs were reviewed #neg
# Heart size is top normal, stable #neg
# Tortuous aorta is redemonstrated, unchanged #pos
# Minimal amount of left basal atelectasis is noted #pos
# Small amount of pleural effusion is present #pos
# Nodular opacity projecting over the first rib is redemonstrated #pos
# Nodular opacity was not clearly seen on the prior studies #pos
# Correlation with cross-sectional imaging is recommended #pos
# Right basal opacity appears to be more pronounced than on the prior study #pos
# Right basal opacity might reflect atelectasis #pos
# Right lower lobe infection is a possibility #pos
# Patient has a described history #neg
# seq2seq_trainer.name =  report2sentences(gpt-3.5-turbo_parsed_repo;gpt-4-0613_parsed_reports)
# --------------------------------------------------
# 7) Attaching metrics, losses, timer and events to engines ...
# --------------------------------------------------
# 8) Defining learning rate scheduler handler ...
# --------------------------------------------------
# 9) Defining checkpoint folder path ...
# checkpoint_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/seq2seq/20230615_110019_report2sentences(gpt-3.5-turbo_parsed_repo;gpt-4-0613_parsed_reports)_Seq2Seq(facebook-bart-base)
# metadata saved to /mnt/data/pamessina/workspaces/medvqa-workspace/models/seq2seq/20230615_110019_report2sentences(gpt-3.5-turbo_parsed_repo;gpt-4-0613_parsed_reports)_Seq2Seq(facebook-bart-base)/metadata.json
# --------------------------------------------------
# 10) Defining log_metrics_handler ...
# MetricsLogger :: we'll be logging to /mnt/data/pamessina/workspaces/medvqa-workspace/models/seq2seq/20230615_110019_report2sentences(gpt-3.5-turbo_parsed_repo;gpt-4-0613_parsed_reports)_Seq2Seq(facebook-bart-base)/metrics_logs.csv
# --------------------------------------------------
# 11) Running trainer engine ...
# ---- Epoch 1/60
# (1) Training stage (lr = 0.000001) ...
# loss 4.04888, s2s_loss 2.73097, 104.20 secs
# (2) Validation stage ...
# Random output:
# PAinent of theastinum with lobulated left mediastinal border compatible2itional #odular left projecting the suprahilar region # approximately.9 x 2.7 cm #pos436Theclusions for malignancy #pospositionThe lower lobe nodular opacity, seen seen on #poslectedL super consolidation, effusion, or pneumothorax #posnegNo superimposed pneumonia, effusion, or pneumothorax #posraughtNo superomediastinum # pneumothorax #pos #Noony structures are intact #pos11 pneumusiform aneurysm # the descending thoracic aorta #neg11 pneum air below the right hemidiaphragm #neg1RightNoNoNo # # # # # # # # # # # # # # # # # # #NoNoNo
# s2s_loss 1.62170, 0.82 secs
# New checkpoint saved: checkpoint_1_s2s_loss=0.3701.pt
# ---- Epoch 2/60
# (1) Training stage (lr = 0.000005) ...
# loss 2.05410, s2s_loss 1.03676, 103.94 secs
# (2) Validation stage ...
# Random output:
# No change is position of theG leads # of and,pos
# Noerate cardiomegaly persists #neg
# No pulmonary edema #negModModMod Moderate Moderate Moderate Moderate Moderate ModerateNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNo
# s2s_loss 0.49926, 0.80 secs
# New checkpoint saved: checkpoint_2_s2s_loss=0.6494.pt
# ---- Epoch 3/60
# (1) Training stage (lr = 0.000022) ...
# loss 0.64064, s2s_loss 0.51771, 103.17 secs
# (2) Validation stage ...
# Random output:
# Heart size normal #neg
# Pulmonary vasculature engorged #pos
# Lungs are #neg
# No edema #neg
# No pleural effusion #neg
# Normal mediastinal silhouette #neg
# Tipra-aortic balloon pump in standard position midwaypos
# Position pneumothorax #negnormalnormalnormalnormalnormalnormalnormalnormal
# s2s_loss 0.32290, 0.83 secs
# New checkpoint saved: checkpoint_3_s2s_loss=0.7462.pt
# ---- Epoch 4/60
# (1) Training stage (lr = 0.000100) ...
# loss 0.41030, s2s_loss 0.35175, 103.11 secs
# (2) Validation stage ...
# Random output:
# No change in position of ECG leads # monitoring and #neg
# Aerate cardiomegaly persists #pos
# No pulmonary edema #negNoNoNo # # # # # # # # # # # # # #No monitoring monitoring monitoring monitoring monitoring monitoring monitoring monitoring monitoring monitoring monitoring monitoring monitoring monitoring a aModModModModModMod persists persists persists is is is is is is is is is is is is is is is is is is is is is is is is is is is is iscomplex hypertension is is is is is
# s2s_loss 0.24510, 0.83 secs
# New checkpoint saved: checkpoint_4_s2s_loss=0.7968.pt
# ---- Epoch 5/60
# (1) Training stage (lr = 0.000056) ...
# loss 0.30441, s2s_loss 0.29006, 103.90 secs
# (2) Validation stage ...
# Random output:
# Small volume free peritoneal air consistent consistent with abdominal surgical procedure #pos
# Shallow inspiration accentuates heart size #pos
# No pulmonary edema or venous congestion #neg
# Small right basilar opacity, likely atelectasis, consider pneumonitis in the appropriate clinical setting #pos
# Degenerative changes left shoulder #pos
# neg isFree # # # # # # # # #IncreasedDDDD degener degener degener degener degener degener degener degener degener degener degener degener degener degener degener degener degener degener degener degenerDDDDDDD
# s2s_loss 0.21977, 0.78 secs
# New checkpoint saved: checkpoint_5_s2s_loss=0.8154.pt
# ---- Epoch 6/60
# (1) Training stage (lr = 0.000032) ...
# loss 0.21962, s2s_loss 0.26685, 103.17 secs
# (2) Validation stage ...
# Random output:
# Heart size normal #neg
# Pulmonary vasculature engorged #pos
# Lungs are #neg
# No edema #neg
# No pleural effusion #neg
# Normal mediastinal silhouette #neg
# Tipra-aortic balloon pump in standard position midwaypos
# Tip pneumothorax #neg b is is is is is is is is is is is is is is is is is is is is is is is is is
# s2s_loss 0.21122, 0.80 secs
# New checkpoint saved: checkpoint_6_s2s_loss=0.8220.pt
# ---- Epoch 7/60
# (1) Training stage (lr = 0.000018) ...
# loss 0.26390, s2s_loss 0.25509, 103.13 secs
# (2) Validation stage ...
# Random output:
# Small volume free peritoneal air consistent consistent with abdominal surgical procedure #pos
# Shallow inspiration accentuates heart size #pos
# No pulmonary edema or venous congestion #neg
# Small right basilar opacity, likely atelectasis, consider pneumonitis in the appropriate clinical setting #pos
# Degenerative changes left shoulder #posneg is is # # # # # # # # # #D left left degener degener degener degener degener degener degener degener degener degener degener degener degener degener degener degener degener degener degener degener left left left left left left left left
# s2s_loss 0.20479, 0.80 secs
# New checkpoint saved: checkpoint_7_s2s_loss=0.8267.pt
# ---- Epoch 8/60
# (1) Training stage (lr = 0.000010) ...
# loss 0.19145, s2s_loss 0.25141, 102.83 secs
# (2) Validation stage ...
# Random output:
# No change in position of ECG leads # monitoring and #neg
# Aerate cardiomegaly persists #pos
# No pulmonary edema #negNoNo # # # # # # # # # # # monitoring monitoring monitoring monitoring monitoring monitoring monitoring monitoring monitoring monitoring monitoring monitoring a a a a a aModModModMod # persists persists persists #No no.. is is is is is is is is is....
# s2s_loss 0.20121, 0.81 secs
# New checkpoint saved: checkpoint_8_s2s_loss=0.8292.pt
# ---- Epoch 9/60
# (1) Training stage (lr = 0.000006) ...
# loss 0.35865, s2s_loss 0.24492, 103.53 secs
# (2) Validation stage ...
# Random output:
# Heart size normal #neg
# Pulmonary vasculature engorged #pos
# Lungs are #neg
# No edema #neg
# No pleural effusion #neg
# Normal mediastinal silhouette #neg
# Tipra-aortic balloon pump in standard position midwaypos
# Tip pneumothorax #neg is b b is is is is is is is is is is is is is is is is is is is is is is is is is is is is is is
# s2s_loss 0.20191, 0.83 secs
# ---- Epoch 10/60
# (1) Training stage (lr = 0.000003) ...
# loss 0.26057, s2s_loss 0.24650, 103.68 secs
# (2) Validation stage ...
# Random output:
# Fronterate-sized right pleural effusion ispos
# Mild interstitial edema #pos
# Lung volumes are low # exaggerating heart and mediastinal contours #pos
# Likeild cardiomegaly is likely #pos
# Theorta is tortuous #pos
# Increased density at the lung base likely represents atelectasis #pos
# Infection cannot be excluded #pos
# Follow-up imaging after treatment is recommended #posFindFindFindFindFindFindIncreasedIncreasedIncreasedIncreasedIncreasedIncreasedIncreasedIncreasedIncreasedIncreasedIncreasedIncreasedInInIn cannot cannot cannot cannot consolidation consolidation consolidation consolidation consolidation consolidation consolidation consolidation consolidation consolidation consolidation consolidation consolidation consolidation consolidation consolidation consolidation consolidation consolidationinterstitial is is is is is is
# s2s_loss 0.19992, 0.79 secs
# New checkpoint saved: checkpoint_10_s2s_loss=0.8303.pt
# ---- Epoch 11/60
# (1) Training stage (lr = 0.000002) ...
# loss 0.27905, s2s_loss 0.24241, 103.64 secs
# (2) Validation stage ...
# Random output:
# Small volume free peritoneal air consistent consistent with abdominal surgical procedure #pos
# Shallow inspiration accentuates heart size #pos
# No pulmonary edema or venous congestion #neg
# Small right basilar opacity, likely atelectasis, consider pneumonitis in the appropriate clinical setting #pos
# Degenerative changes left shoulder #posneg is is # # # # # # # # # #D left left degener degener degener degener degener degener degener degener degener degener degener degener degener degener degener degener degener degener degener degener degener degener degener left left left left left left
# s2s_loss 0.20015, 0.80 secs
# New checkpoint saved: checkpoint_11_s2s_loss=0.8304.pt
# ---- Epoch 12/60
# (1) Training stage (lr = 0.000001) ...
# loss 0.26921, s2s_loss 0.24235, 104.01 secs
# (2) Validation stage ...
# Random output:
# Tr tracheostomy tube is enteric feeding tube, right IJ central venous catheter, and right pleural pigtail catheter are unchanged in position #neg
# A small-to-moderate right apical pneumothorax is not significantly changed #pos
# Mass-like opacities in the right lung base are re-demonstrated #pos
# Small bilateral pleural effusions are unchanged #pos
# There is moderate subcutaneous emphysema along the right chest wall #pos
# The cardiomediastinal contours are within normal limits and unchanged #neg
# UnSmallSmallSmallSmallSmallSmallSmallSmallSmallSmallMassMassMassMassMassMassMassMassMassMassMassMassMass mass is is is is card card card card card card card card card card card card card card card card card card card card
# s2s_loss 0.19966, 0.78 secs
# New checkpoint saved: checkpoint_12_s2s_loss=0.8307.pt
# ---- Epoch 13/60
# (1) Training stage (lr = 0.000100) ...
# loss 0.22673, s2s_loss 0.24336, 103.20 secs
# (2) Validation stage ...
# Random output:
# Heart size normal #neg
# Pulmonary vasculature engorged #pos
# Lungs are #neg
# No edema #neg
# No pleural effusion #neg
# Normal mediastinal silhouette #neg
# Tipra-aortic balloon pump in standard position midwaypos
# Tip pneumothorax #neg # # # # # # # # # # # is is is is is is is # # is is is # is is is is is left left # # # # # # is is is is is is is is is is is is is is is is is is is is is is is is is is is is is is is is is is is
# s2s_loss 0.19692, 0.80 secs
# New checkpoint saved: checkpoint_13_s2s_loss=0.8324.pt
# ---- Epoch 14/60
# (1) Training stage (lr = 0.000052) ...
# loss 0.36803, s2s_loss 0.22405, 104.20 secs
# (2) Validation stage ...
# Random output:
# No change in position of ECG leads # monitoring and #neg
# Aerate cardiomegaly persists #pos
# No pulmonary edema #neg isNoNo # # # # # # # # # # # # # # # monitoring monitoring monitoring monitoring monitoring monitoring monitoring monitoring # a a a a a a # # # # # # # # # # # # # # # # # is is is is is is is is is is is is is
# s2s_loss 0.17951, 0.81 secs
# New checkpoint saved: checkpoint_14_s2s_loss=0.8447.pt
# ---- Epoch 15/60
# (1) Training stage (lr = 0.000027) ...
# loss 0.18806, s2s_loss 0.20829, 103.24 secs
# (2) Validation stage ...
# Random output:
# Heart size normal #neg
# Pulmonary vasculature engorged #pos
# Lungs are #neg
# No edema #neg
# No pleural effusion #neg
# Normal mediastinal silhouette #neg
# Tipra-aortic balloon pump in standard position midwaypos
# Ball pneumothorax #neg is # # # # # # # # # # # # # # # # # is is # is is # # # # # # # # # left left left left left left left # # # # is is is # # #.... # # is is
# s2s_loss 0.17631, 0.86 secs
# New checkpoint saved: checkpoint_15_s2s_loss=0.8479.pt
# ---- Epoch 16/60
# (1) Training stage (lr = 0.000014) ...
# loss 0.16188, s2s_loss 0.20068, 102.48 secs
# (2) Validation stage ...
# Random output:
# Little change compared comparison with previous study #neg
# No evidence of pulmonary vascular congestion #neg
# Cardiac silhouette remains upper limits of normal or slightly enlarged # to previous CABG procedure #pos
# No acute focal pneumonia #neg
# Calcifications seen in right breast #pos isCal # # # # # # # # # #NoNoNo # # # # # # # # # # # # # # # # # # # # # # in in in in in in in in in in in in in in in is # # # # # #
# s2s_loss 0.17336, 0.79 secs
# New checkpoint saved: checkpoint_16_s2s_loss=0.8503.pt
# ---- Epoch 17/60
# (1) Training stage (lr = 0.000007) ...
# loss 0.16969, s2s_loss 0.20116, 103.64 secs
# (2) Validation stage ...
# Random output:
# Heart size normal #neg
# Pulmonary vasculature engorged #pos
# Lungs are #neg
# No edema #neg
# No pleural effusion #neg
# Normal mediastinal silhouette #neg
# Tipra-aortic balloon pump in standard position midwaypos
# Int pneumothorax #neg # # # # # # # # # # # # # # # # # # is is # is is # # # # # # # # left left left left left left left left left # # is is is is is is is is is is is # # is is is is # hypertension is is is
# s2s_loss 0.17421, 0.85 secs
# ---- Epoch 18/60
# (1) Training stage (lr = 0.000004) ...
# loss 0.23054, s2s_loss 0.19356, 102.63 secs
# (2) Validation stage ...
# Random output:
# Fronterate-sized right pleural effusion ispos
# Mild interstitial edema #pos
# Lowung volumes are low # exaggerating heart and mediastinal contours #pos
# Likeild cardiomegaly is likely #pos
# Theorta is tortuous #pos
# Increased density at the lung base likely represents atelectasis #pos
# Infection cannot be excluded #pos
# Follow-up imaging after treatment is recommended #neg
# FindFindFindFindFindFind was wasFindFindFindFindFindFindFindAAAAAAIncreasedIncreasedIncreasedIncreasedIncreasedIncreasedIncreasedIncreasedIncreasedIncreasedIncreasedIncreasedIncreasedIncreasedIncreased is cannot cannot cannot cannot consolidation consolidation consolidation consolidation consolidation consolidation consolidation consolidation consolidation consolidation consolidation consolidation consolidation consolidation consolidation consolidation consolidation consolidation follow follow is is is is #
# s2s_loss 0.17372, 0.78 secs
# New checkpoint saved: checkpoint_18_s2s_loss=0.8506.pt
# ---- Epoch 19/60
# (1) Training stage (lr = 0.000002) ...
# loss 0.20020, s2s_loss 0.19668, 103.29 secs
# (2) Validation stage ...
# Random output:
# PAinence of theastinum with lobulated left mediastinal border #pos
# Knownodular left in right suprahilar region # 1.9 x 2.7 cm #pos
# Leftcerning for malignancy #pos
# Left lower lobe nodular opacity cannot clearly seen today #pos
# No super consolidation, effusion, or pneumothorax #neg
# No pneumimposed pneumonia, effusion or or pneumothorax #neg
# No freeomediastinum # pneumothorax #neg
# Bony structures intact intact #negRight fusiform aneurysm of descending descending thoracic aorta #pos
# No free air below right right hemidiaphragm #neg
# NoNoNo pneum # # # # right rightRightRightRightRight right rightRightRightRightRight right right # # # #
# s2s_loss 0.17317, 0.81 secs
# New checkpoint saved: checkpoint_19_s2s_loss=0.8507.pt
# ---- Epoch 20/60
# (1) Training stage (lr = 0.000001) ...
# loss 0.23256, s2s_loss 0.19361, 102.35 secs
# (2) Validation stage ...
# Random output:
# Little change compared comparison with previous study #neg
# No evidence of pulmonary vascular congestion #neg
# Cardiac silhouette remains upper limits of normal or slightly enlarged # to previous CABG procedure #pos
# No acute focal pneumonia #neg
# Calcifications seen in right breast #pos isCal # # # # # # # # # #No # # # # # # # # # # # # # # # # # # # # # # # # in in in in in in in in in in in in in in in # is # # # # # # # #
# s2s_loss 0.17319, 0.81 secs
# New checkpoint saved: checkpoint_20_s2s_loss=0.8509.pt
# ---- Epoch 21/60
# (1) Training stage (lr = 0.000100) ...
# loss 0.28903, s2s_loss 0.20231, 102.56 secs
# (2) Validation stage ...
# Random output:
# Normal size normal #neg
# Pulmonary vasculature engorged #pos
# Lungs are #neg
# No edema #neg
# No pleural effusion #neg
# Normal mediastinal silhouette #neg
# Tipra-aortic balloon pump in standard position midwaypos
# Int pneumothorax #neg # # # # # # # # # # # # # # # # # pump is is is is is is # # # is # # # # is # # is left left left # # # # # hypertension is is is hypertension hypertension hypertension hypertension hypertension hypertension is is is is is is is is # # hypertension hypertension hypertension is hypertension # hypertension hypertension hypertension hypertension hypertension hypertension hypertension hypertension hypertension is
# s2s_loss 0.16975, 0.83 secs
# New checkpoint saved: checkpoint_21_s2s_loss=0.8526.pt
# ---- Epoch 22/60
# (1) Training stage (lr = 0.000052) ...
# loss 0.28945, s2s_loss 0.19450, 104.58 secs
# (2) Validation stage ...
# Random output:
# Patamination in in sitting upright position using AP frontal and left lateral views #neg
# Compar size unchanged enlarged # relative left ventricular contour prominence #pos
# No significant of significant pulmonary vascular congestion #neg
# Thoracic aorta unchanged without local contour abnormalities #neg
# Right-sided internal jugular approach double-lumen line unchanged in unchanged position terminatingneg
# Pulmonary infiltrates in left left upper lobe area have further regressed and are practically resolved #pos
# Small detectable fluid blunting of the right lateral pleural sinus # lateral lateral view discloses small amounts of fluid blunting the posterior pleural sinuses in the lower posterior region #pos
# No new pulmonary parenchymal abnormalities are # no pneumothorax present #neg
# Amount of pleural effusions in the posterior sinuses remains stable and unchanged #neg
# s2s_loss 0.16519, 0.90 secs
# New checkpoint saved: checkpoint_22_s2s_loss=0.8561.pt
# ---- Epoch 23/60
# (1) Training stage (lr = 0.000027) ...
# loss 0.23114, s2s_loss 0.17604, 105.91 secs
# (2) Validation stage ...
# Random output:
# No change in position of ECG leads # monitoring and #neg
# Aerate cardiomegaly persists #pos
# No pulmonary edema #negnegNoNoNo # # # # # # # # # # monitoring monitoring monitoring monitoring monitoring monitoring monitoring monitoring monitoring monitoring monitoring monitoring # # # # # # # # # # # # # # # # # # # # # # # #. # # is present present present present present present present present present
# s2s_loss 0.16283, 0.87 secs
# New checkpoint saved: checkpoint_23_s2s_loss=0.8590.pt
# ---- Epoch 24/60
# (1) Training stage (lr = 0.000014) ...
# loss 0.13878, s2s_loss 0.17320, 110.92 secs
# (2) Validation stage ...
# Random output:
# Single interval change in chest appearance #neg
# Stable large right pleural effusion with adjacent atelectasis #pos
# Multifocal consolidations in right upper, left upper and left lower lobes #pos
# No pneumothorax #neg
# Cardiac size cannot be evaluated #neg
# Uniomediastinum is unchanged, shifted towards the left #neg
# Tracheostomy tube in standard position #neg
# Left PICC tip in mid mid SVC #posneg card card card card card card card card card card card card card card card card unchanged card unchanged unchanged unchanged shifted shifted shifted shifted shifted shifted shifted shifted shifted in in in in in in in left left present present present left left left left present present present present present hypertension card
# s2s_loss 0.16057, 1.17 secs
# New checkpoint saved: checkpoint_24_s2s_loss=0.8607.pt
# ---- Epoch 25/60
# (1) Training stage (lr = 0.000007) ...
# loss 0.18523, s2s_loss 0.17070, 115.84 secs
# (2) Validation stage ...
# Random output:
# Patamination in in sitting upright position using AP frontal and left lateral views #neg
# Compar size unchanged enlarged # relative left ventricular contour prominence #pos
# No significant of significant pulmonary vascular congestion #neg
# Thoracic aorta unchanged without local contour abnormalities #neg
# Right-sided internal jugular approach double-lumen line unchanged in unchanged position terminatingneg
# Previouslyulmonary infiltrates in left left upper lobe area have further regressed and are practically resolved #pos
# Small detectable fluid blunting of the right lateral pleural sinus # lateral lateral view discloses small amounts of fluid blunting the posterior pleural sinuses in the lower posterior region #pos
# No new pulmonary parenchymal abnormalities are # no pneumothorax present #neg
# Amount of pleural effusions in the posterior sinuses remains stable and unchanged #neg
# s2s_loss 0.16117, 1.02 secs
# ---- Epoch 26/60
# (1) Training stage (lr = 0.000004) ...
# loss 0.23325, s2s_loss 0.16402, 118.88 secs
# (2) Validation stage ...
# Random output:
# Heart size normal #neg
# Pulmonary vasculature engorged #pos
# Lungs are #neg
# No edema #neg
# No pleural effusion #neg
# Normal mediastinal silhouette #neg
# Tipra-aortic balloon pump in standard position midwaypos
# No pneumothorax #neg # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # left left left left left # # # # hypertension is # hypertension hypertension hypertension # hypertension # hypertension hypertension hypertension hypertension hypertension
# s2s_loss 0.15962, 1.13 secs
# New checkpoint saved: checkpoint_26_s2s_loss=0.8620.pt
# ---- Epoch 27/60
# (1) Training stage (lr = 0.000002) ...
# loss 0.14287, s2s_loss 0.17080, 119.41 secs
# (2) Validation stage ...
# Random output:
# Normal size normal #neg
# Pulmonary vasculature engorged #pos
# Lungs are #neg
# No edema #neg
# No pleural effusion #neg
# Normal mediastinal silhouette #neg
# Tipra-aortic balloon pump in standard position midwaypos
# No pneumothorax #neg # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # left left left left # # # # # hypertension is # hypertension hypertension # # hypertension # hypertension hypertension hypertension hypertension hypertension
# s2s_loss 0.15904, 1.51 secs
# ---- Epoch 28/60
# (1) Training stage (lr = 0.000001) ...
# loss 0.14007, s2s_loss 0.16256, 119.09 secs
# (2) Validation stage ...
# Random output:
# No change in position of ECG leads # monitoring and #neg
# Aerate cardiomegaly persists #pos
# No pulmonary edema #negnegNoNoNo # # # # # # # # # # # monitoring monitoring monitoring monitoring monitoring monitoring monitoring monitoring monitoring # monitoring # # # # # # # # # # # # # # # # # # # # # # # # # # # present present present present present present present present present present
# s2s_loss 0.15981, 1.24 secs
# ---- Epoch 29/60
# (1) Training stage (lr = 0.000100) ...
# loss 0.18617, s2s_loss 0.18133, 122.50 secs
# (2) Validation stage ...
# Random output:
# Normal size normal #neg
# Pulmonary vasculature engorged #pos
# Lungs are #neg
# No edema #neg
# No pleural effusion #neg
# Normal mediastinal silhouette #neg
# Tipra-aortic balloon pump in standard position midwayneg
# Int pneumothorax #neg # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# s2s_loss 0.16245, 1.34 secs
# ---- Epoch 30/60
# (1) Training stage (lr = 0.000052) ...
# loss 0.14432, s2s_loss 0.17130, 125.44 secs
# (2) Validation stage ...
# Random output:
# Mild to moderate cardiomegaly is evidence CABG and intact sternotomy wires #pos
# Left sided ICD device with appropriate in appropriate position #pos
# Mild pulmonary vascular congestion with asymmetric increased opacity at right lower lung base #pos
# Superimposed pneumonia difficult to exclude #neg
# Hilar and mediastinal contours unremarkable #neg
# Trace bilateral pleural effusions #pos
# No pneumothorax #neg
# Pulmonary edema with possible superimposed pneumonia in right lung base #pos # super difficult super difficult difficult difficult difficult # # # # #PPP # #PPP
# s2s_loss 0.16053, 1.17 secs
# ---- Epoch 31/60
# (1) Training stage (lr = 0.000027) ...
# loss 0.12859, s2s_loss 0.15405, 126.48 secs
# (2) Validation stage ...
# Random output:
# Single interval change in chest appearance #neg
# Stable large right pleural effusion with adjacent atelectasis #pos
# Multifocal consolidations in right upper, left upper and left lower lobes #pos
# No pneumothorax #neg
# Cardiac size cannot be evaluated #neg
# Uniomediastinum is unchanged, shifted towards the left #neg
# Tracheostomy tube in standard position #neg
# Left PICC tip in mid mid SVC #pos # # # # card card card card card card card card card card card cardCard card shifted shifted shifted shifted shifted shifted shifted shifted shifted shifted shifted shifted shifted shifted shifted shifted shifted in in in in in in in in in in left present present present present left tip # tip tip
# s2s_loss 0.15895, 1.58 secs
# New checkpoint saved: checkpoint_31_s2s_loss=0.8632.pt
# ---- Epoch 32/60
# (1) Training stage (lr = 0.000014) ...
# loss 0.15216, s2s_loss 0.15412, 124.02 secs
# (2) Validation stage ...
# Random output:
# Single interval change in chest appearance #neg
# Stable large right pleural effusion with adjacent atelectasis #pos
# Multifocal consolidations in right upper, left upper and left lower lobes #pos
# No pneumothorax #neg
# Cardiac size cannot be evaluated #neg
# Uniomediastinum is unchanged, shifted towards the left #neg
# Tracheostomy tube in standard position #neg
# Left PICC tip in mid mid SVC #pos # # card card card card card card card card card card card card card card card shifted shifted shifted shifted shifted shifted shifted shifted shifted shifted shifted shifted shifted shifted shifted shifted shifted shifted shifted in in in in in in in in in noted noted left left left noted noted noted noted noted
# s2s_loss 0.15380, 1.12 secs
# New checkpoint saved: checkpoint_32_s2s_loss=0.8667.pt
# ---- Epoch 33/60
# (1) Training stage (lr = 0.000007) ...
# loss 0.15282, s2s_loss 0.14829, 119.47 secs
# (2) Validation stage ...
# Random output:
# Patamination in in sitting upright position using AP frontal and left lateral views #neg
# Compar size mildly enlarged # relative left ventricular contour prominence #pos
# No significant of significant pulmonary vascular congestion #neg
# Thoracic aorta unchanged without local contour abnormalities #neg
# Right-sided internal jugular approach double-lumen line unchanged in unchanged position terminatingneg
# Previouslyulmonary infiltrates in left left upper lobe area have further regressed and are practically resolved #pos
# Small detectable fluid blunting of the right lateral pleural sinus remains lateral lateral view discloses small amounts of fluid blunting the posterior pleural sinuses in the lower posterior region #pos
# No new pulmonary parenchymal abnormalities are # no pneumothorax present #neg
# Amount of pleural effusions in the posterior sinuses remains stable and unchanged #neg
# s2s_loss 0.15493, 1.18 secs
# ---- Epoch 34/60
# (1) Training stage (lr = 0.000004) ...
# loss 0.13892, s2s_loss 0.14469, 122.00 secs
# (2) Validation stage ...
# Random output:
# No change in position of ECG leads # monitoring and #neg
# Aerate cardiomegaly persists #pos
# No pulmonary edema #negnegNoNoNo #No # # # # # # # monitoring monitoring monitoring monitoring monitoring monitoring monitoring # # # # # a # # # # # # # # # # # # # # # # # # # # # # # # # # # present present present # #
# s2s_loss 0.15370, 1.09 secs
# New checkpoint saved: checkpoint_34_s2s_loss=0.8675.pt
# ---- Epoch 35/60
# (1) Training stage (lr = 0.000002) ...
# loss 0.13490, s2s_loss 0.14794, 127.03 secs
# (2) Validation stage ...
# Random output:
# Patamination in in sitting upright position using AP frontal and left lateral views #neg
# Compar size mildly enlarged # relative left ventricular contour prominence #pos
# No evidence of significant pulmonary vascular congestion #neg
# Thoracic aorta unchanged without local contour abnormalities #neg
# Right-sided internal jugular approach double-lumen line unchanged in unchanged position terminatingneg
# Previouslyulmonary infiltrates in left left upper lobe area have further regressed and are practically resolved #pos
# Small detectable fluid blunting of the right lateral pleural sinus remains lateral lateral view discloses small amounts of fluid blunting the posterior pleural sinuses in the lower posterior region #pos
# No new pulmonary parenchymal abnormalities are # no pneumothorax present #neg
# Amount of pleural effusions in the posterior sinuses remains stable and unchanged #neg
# s2s_loss 0.15313, 1.68 secs
# New checkpoint saved: checkpoint_35_s2s_loss=0.8676.pt
# ---- Epoch 36/60
# (1) Training stage (lr = 0.000001) ...
# loss 0.08431, s2s_loss 0.14147, 129.20 secs
# (2) Validation stage ...
# Random output:
# Port tracheostomy tube is enteric feeding tube, right IJ central venous catheter, and right pleural pigtail catheter are unchanged in position #pos
# A small-to-moderate right apical pneumothorax is not significantly changed #pos
# Mass-like opacities in the right lung base are re-demonstrated #pos
# Small bilateral pleural effusions are unchanged #neg
# There is moderate subcutaneous emphysema along the right chest wall #pos
# The cardiomediastinal contours are within normal limits and unchanged #negnegUn small # # # # # and and and and card card is card card card card card card card card card card card card card card card card card card card card card card cont cont cont cont
# s2s_loss 0.15380, 1.18 secs
# New checkpoint saved: checkpoint_36_s2s_loss=0.8676.pt
# ---- Epoch 37/60
# (1) Training stage (lr = 0.000100) ...
# loss 0.12656, s2s_loss 0.16243, 122.94 secs
# (2) Validation stage ...
# Random output:
# Fronterate-sized right pleural effusion #pos
# Mild interstitial edema #pos
# Lowung volumes are low # exaggerating heart and mediastinal contours #neg
# Likeild cardiomegaly likely likely #pos
# Aorta is tortuous #pos
# Increased density at the lung base likely represents atelectasis,pos
# Infection cannot be excluded #pos
# Follow-up imaging after treatment is recommended #neg
# negFindFindFindFindFind findingsFind findings findings findings findings findings findings findingsIncreasedIncreasedIncreased increasedIncreasedIncreasedIncreasedIncreasedIncreasedIncreasedIncreasedIncreased consolidation consolidation consolidation consolidation consolidation consolidation consolidation consolidation consolidation consolidation consolidation consolidation consolidation consolidation consolidation consolidation consolidation
# s2s_loss 0.16227, 0.94 secs
# ---- Epoch 38/60
# (1) Training stage (lr = 0.000052) ...
# loss 0.16399, s2s_loss 0.15338, 120.72 secs
# (2) Validation stage ...
# Random output:
# Normal size normal #neg
# Pulmonary vasculature engorged #pos
# Lungs are #neg
# No edema #neg
# No pleural effusion #neg
# Normal mediastinal silhouette #neg
# Tipra-aortic balloon pump in standard position #pos
# No pneumothorax #neg # # # # # # # # # # # # # # # # # # in # # # # # # # # standard standard # # # patent #
# s2s_loss 0.15774, 0.89 secs
# ---- Epoch 39/60
# (1) Training stage (lr = 0.000027) ...
# loss 0.13823, s2s_loss 0.13987, 123.75 secs
# (2) Validation stage ...
# Random output:
# PAinence of theastinum with lobulated left mediastinal border #pos
# Fodular left in right suprahilar region concerning 1.9 x 2.7 cm,pos
# Leftcerning for malignancy inpos
# Left lower lobe nodular opacity cannot clearly seen today #neg
# No super consolidation, effusion, or pneumothorax #neg
# No pneumimposed pneumonia, effusion, or pneumothorax #neg
# No pneumomediastinum # pneumothorax #neg
# Bony structures intact intact #negRight fusiform aneurysm of descending descending thoracic aorta #neg
# No free air below the right hemidiaphragm #neg
# NoNo pneum pneum pneumBB b b lobLLLL leftLLLL left left left left leftLL
# s2s_loss 0.15244, 0.94 secs
# New checkpoint saved: checkpoint_39_s2s_loss=0.8687.pt
# ---- Epoch 40/60
# (1) Training stage (lr = 0.000014) ...
# loss 0.15772, s2s_loss 0.13654, 128.45 secs
# (2) Validation stage ...
# Random output:
# Port tracheostomy tube is enteric feeding tube, right IJ central venous catheter, and right pleural pigtail catheter are unchanged in position #pos
# A small-to-moderate right apical pneumothorax is not significantly changed #pos
# Mass-like opacities in the right lung base are re-demonstrated #pos
# Small bilateral pleural effusions are unchanged #neg
# There is moderate subcutaneous emphysema along the right chest wall #pos
# The cardiomediastinal contours are within normal limits and unchanged #neg small and and and and and and and and cat card card card card card card card card card card card card card card card card card card card card card card card card card card card card card card card card card card card card card card card card unchanged card card
# s2s_loss 0.14984, 1.22 secs
# New checkpoint saved: checkpoint_40_s2s_loss=0.8707.pt
# ---- Epoch 41/60
# (1) Training stage (lr = 0.000007) ...
# loss 0.13344, s2s_loss 0.13211, 129.20 secs
# (2) Validation stage ...
# Random output:
# Mild to moderate cardiomegaly with evidence CABG and intact sternotomy wires #pos
# Left sided ICD device with leads in appropriate position #pos
# Mild pulmonary vascular congestion with asymmetric increased opacity at right lower lung base #pos
# Superimposed pneumonia difficult to exclude #neg
# Hilar and mediastinal contours unremarkable #neg
# Trace bilateral pleural effusions #pos
# No pneumothorax #neg
# Pulmonary edema with possible superimposed pneumonia in right lung base #pos # # # # # # difficult difficult difficult difficult difficult difficult difficult difficult # # # # # #PPPPPPP
# s2s_loss 0.15230, 0.95 secs
# ---- Epoch 42/60
# (1) Training stage (lr = 0.000004) ...
# loss 0.12872, s2s_loss 0.12905, 125.08 secs
# (2) Validation stage ...
# Random output:
# Patamination in in sitting upright position using AP frontal and left lateral views #neg
# Compar size mildly enlarged # relative left ventricular contour prominence #pos
# No significant of significant pulmonary vascular congestion #neg
# Thoracic aorta unchanged without local contour abnormalities #neg
# Right-sided internal jugular approach double-lumen line unchanged in unchanged position terminatingneg
# Previouslyulmonary infiltrates in left left upper lobe area have further regressed and are practically resolved #pos
# Small detectable fluid blunting of the right lateral pleural sinus remains lateral lateral view discloses small amounts of fluid blunting the posterior pleural sinuses in the lower posterior region #pos
# No new pulmonary parenchymal abnormalities are # no pneumothorax present #neg
# Amount of pleural effusions in the posterior sinuses remains stable and unchanged #neg
# s2s_loss 0.15083, 0.99 secs
# ---- Epoch 43/60
# (1) Training stage (lr = 0.000002) ...
# loss 0.13535, s2s_loss 0.13076, 125.37 secs
# (2) Validation stage ...
# Random output:
# PAinence of theastinum with lobulated left mediastinal border #pos
# Fodular left in right suprahilar region concerning 1.9 x 2.7 cm,pos
# Leftcerning for malignancy ofpos
# Left lower lobe nodular opacity cannot clearly seen today #neg
# No super consolidation, effusion, or pneumothorax #neg
# No freeimposed pneumonia, effusion or or pneumothorax #neg
# B pneumomediastinum # pneumothorax #neg
# Bony structures intact intact #negRight fusiform aneurysm of descending descending thoracic aorta #pos
# Right free air below the right hemidiaphragm #neg
# NoNo pneum pneum pneumBBB lob lobLLLL left leftLLL left left left left #L
# s2s_loss 0.15058, 0.96 secs
# ---- Epoch 44/60
# (1) Training stage (lr = 0.000001) ...
# loss 0.12364, s2s_loss 0.12634, 126.99 secs
# (2) Validation stage ...
# Random output:
# Small volume free peritoneal air, consistent with abdominal surgical procedure #pos
# Shallow inspiration accentuates heart size #pos
# No pulmonary edema or venous congestion #neg
# Small right basilar opacity, likely atelectasis, consider pneumonitis in the appropriate clinical setting #pos
# Degenerative changes left shoulder #pos # # # # # # # # # # # # # # degener degener # # # consider # # # considerConsider degener degener degenerConsider degener degener degener degener present degener degener present left left left left left
# s2s_loss 0.15178, 1.57 secs
# ---- Epoch 45/60
# (1) Training stage (lr = 0.000100) ...
# loss 0.13914, s2s_loss 0.14715, 135.52 secs
# (2) Validation stage ...
# Random output:
# Prominence of theastinum with lobulated left mediastinal border #pos
# Fodular density in right suprahilar region concerning 1.9 x 2.7 cm,pos
# Leftcerning for malignancy ofpos
# Left lower lobe nodular opacity cannot clearly seen today #neg
# No super consolidation, effusion, or pneumothorax #neg
# No superimposed pneumonia, effusion or or pneumothorax #neg
# No freeomediastinum # pneumothorax #neg
# Bony structures intact intact #neg
# Right fusiform aneurysm of the descending thoracic aorta cannotneg
# Right free air below the right hemidiaphragm #neg
# NoNo pneum no no #BB bBBBB left left leftB left left left left # # # # #
# s2s_loss 0.16258, 1.58 secs
# ---- Epoch 46/60
# (1) Training stage (lr = 0.000052) ...
# loss 0.13679, s2s_loss 0.14016, 134.83 secs
# (2) Validation stage ...
# Random output:
# Small volume free peritoneal air # consistent with abdominal surgical procedure #pos
# Shallow inspiration accentuates heart size #neg
# No pulmonary edema or venous congestion #neg
# Small right basilar opacity, likely atelectasis, consider pneumonitis in the appropriate clinical setting #pos
# Degenerative changes left shoulder #pos # # # # # # # # # # # # # # # # # # # # # # #Consider # # #ConsiderConsider # # # # degener degener left left leftD
# s2s_loss 0.15715, 1.09 secs
# ---- Epoch 47/60
# (1) Training stage (lr = 0.000027) ...
# loss 0.15663, s2s_loss 0.12522, 128.91 secs
# (2) Validation stage ...
# Random output:
# Single interval change in chest appearance #neg
# Stable large right pleural effusion with adjacent atelectasis #pos
# Multifocal consolidations in right upper, left upper and left lower lobes #pos
# No pneumothorax #neg
# Cardiac size cannot be evaluated #neg
# Uniomediastinum is unchanged, shifted towards the left #neg
# Tracheostomy tube in standard position #neg
# Left PICC tip in the mid SVC #pos # # # card card # card card card card card card card card card card card card card card card shifted shifted shifted shifted shifted shifted shifted shifted present present result in present present in in in in present present in in assay present left left left left left left leftrity left left left left left
# s2s_loss 0.15637, 1.28 secs
# ---- Epoch 48/60
# (1) Training stage (lr = 0.000014) ...
# loss 0.12986, s2s_loss 0.12212, 125.00 secs
# (2) Validation stage ...
# Random output:
# No change in position of ECG leads # monitoring and #neg
# Aerate cardiomegaly persists #pos
# No pulmonary edema #negneg # # # #NoNo # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # b b b b b # #ins b b b detected
# s2s_loss 0.15116, 1.04 secs
# New checkpoint saved: checkpoint_48_s2s_loss=0.8709.pt
# ---- Epoch 49/60
# (1) Training stage (lr = 0.000007) ...
# loss 0.14775, s2s_loss 0.11864, 125.70 secs
# (2) Validation stage ...
# Random output:
# Fronterate-sized right pleural effusion andpos
# Mild interstitial edema #pos
# Lowung volumes are low # exaggerating heart and mediastinal contours #neg
# Likeild cardiomegaly likely likely #pos
# Aorta is tortuous #pos
# Increased density at the lung base likely represents atelectasis #pos
# Infection cannot be excluded #neg
# Follow-up imaging after treatment is recommended #neg
#  findingsFindFindFindFind findingsFind findingsFind findings findingsFind findingsTTTTIncreasedIncreasedIncreasedIncreasedIncreasedIncreasedIncreasedIncreasedIncreasedIncreasedIncreasedIncreasedIncreasedIncreasedIncreased consolidation
# s2s_loss 0.15155, 1.58 secs
# New checkpoint saved: checkpoint_49_s2s_loss=0.8709.pt
# ---- Epoch 50/60
# (1) Training stage (lr = 0.000004) ...
# loss 0.14499, s2s_loss 0.11345, 134.37 secs
# (2) Validation stage ...
# Random output:
# Little change compared comparison with previous study #neg
# No evidence of pulmonary vascular congestion #neg
# Cardiac silhouette is upper limits of normal or slightly enlarged # to previous CABG procedure #pos
# No acute focal pneumonia #neg
# Calcifications seen in right breast #pos # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # observed seen seen seen seen present present detected present present present # detected seen
# s2s_loss 0.15019, 1.19 secs
# New checkpoint saved: checkpoint_50_s2s_loss=0.8723.pt
# ---- Epoch 51/60
# (1) Training stage (lr = 0.000002) ...
# loss 0.10176, s2s_loss 0.11795, 132.55 secs
# (2) Validation stage ...
# Random output:
# Little change compared comparison with previous study #neg
# No evidence of pulmonary vascular congestion #neg
# Cardiac silhouette is upper limits of normal or slightly enlarged # to previous CABG procedure #pos
# No acute focal pneumonia #neg
# Calcifications seen in right breast #pos # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # observed observed seen seen present present present detected present present present detected detected noted seen
# s2s_loss 0.14975, 1.19 secs
# ---- Epoch 52/60
# (1) Training stage (lr = 0.000001) ...
# loss 0.10280, s2s_loss 0.11156, 124.70 secs
# (2) Validation stage ...
# Random output:
# Little change compared comparison with previous study #neg
# No evidence of pulmonary vascular congestion #neg
# Cardiac silhouette is upper limits of normal or slightly enlarged # to previous CABG procedure #pos
# No acute focal pneumonia #neg
# Calcifications seen in right breast #pos # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # observed seen seen seen seen present present detected present present present detected detected noted seen noted
# s2s_loss 0.15064, 1.46 secs
# ---- Epoch 53/60
# (1) Training stage (lr = 0.000100) ...
# loss 0.10267, s2s_loss 0.13489, 123.21 secs
# (2) Validation stage ...
# Random output:
# Prominence of theastinum with lobulated left mediastinal border #pos
# Fodular density in right suprahilar region concerning 1.9 x 2.7 cm,pos
# Leftcerning for malignancy inpos
# Left lower lobe nodular opacity cannot clearly seen today #neg
# No super consolidation, effusion or or pneumothorax #neg
# No freeimposed pneumonia, effusion or or pneumomedorax #neg
# No freeomediastinum # pneumothorax #neg
# Bony structures are intact #negRight fusiform aneurysm of descending descending thoracic aorta #neg
# Right free air below the right hemidiaphragm #neg
# NoRight right right rightRight lob lob lobLLLLL left leftLL left left left left left left left left
# s2s_loss 0.16216, 1.01 secs
# ---- Epoch 54/60
# (1) Training stage (lr = 0.000052) ...
# loss 0.15444, s2s_loss 0.12857, 129.82 secs
# (2) Validation stage ...
# Random output:
# Single interval change in chest appearance #neg
# Stable large right pleural effusion with adjacent atelectasis #pos
# Multifocal consolidations in right upper, left upper and left lower lobes #pos
# No pneumothorax #neg
# Cardiac size cannot be evaluated #neg
# Cardiomediastinum is unchanged, shifted towards the left #neg
# Tracheostomy tube in standard position #neg
# Left PICC tip in the mid SVC #pos # # # # #Card card card card card card card card card card card shifted shifted shifted shifted shifted shifted shifted shifted shifted noted noted noted # noted # in noted in tube # # # # left left left left left left noted left left left card
# s2s_loss 0.15493, 1.10 secs
# ---- Epoch 55/60
# (1) Training stage (lr = 0.000027) ...
# loss 0.12676, s2s_loss 0.11285, 139.57 secs
# (2) Validation stage ...
# Random output:
# Single interval change in chest appearance #neg
# Stable large right pleural effusion with adjacent atelectasis #pos
# Multifocal consolidations in right upper, left upper and left lower lobes #pos
# No pneumothorax #neg
# Cardiac size cannot be evaluated #neg
# Uniomediastinum is unchanged, shifted towards the left #neg
# Tracheostomy tube in standard position #neg
# Left PICC tip in the mid SVC #pos # # # # # # # #Card card card cardannot card card card card shifted shifted shifted shifted shifted shifted shifted shifted shifted shifted shifted shifted shifted shifted shifted shifted shifted shifted shifted shifted shifted in in in in standard tube in # # # # left left left left left left left left left left left in left fund left left
# s2s_loss 0.15611, 1.22 secs
# ---- Epoch 56/60
# (1) Training stage (lr = 0.000014) ...
# loss 0.12431, s2s_loss 0.11106, 138.62 secs
# (2) Validation stage ...
# Random output:
# Patamination done in sitting upright position using AP frontal and left lateral views #neg
# Compar size mildly enlarged # relative left ventricular contour prominence #pos
# No significant of significant pulmonary vascular congestion #neg
# Thoracic aorta unchanged without local contour abnormalities #neg
# Right-sided internal jugular approach double-lumen line unchanged in unchanged position terminatingneg
# Previouslyulmonary infiltrates in left left upper lobe area have further regressed and are practically resolved #pos
# Small detectable fluid blunting of the right lateral pleural sinus remains lateral lateral view discloses small amounts of fluid blunting the posterior pleural sinuses in the lower posterior region #pos
# No new pulmonary parenchymal abnormalities seen # no pneumothorax present #neg
# P of pleural effusions in the posterior sinuses remains stable and unchanged #neg
# s2s_loss 0.14993, 1.12 secs
# New checkpoint saved: checkpoint_56_s2s_loss=0.8727.pt
# ---- Epoch 57/60
# (1) Training stage (lr = 0.000007) ...
# loss 0.10438, s2s_loss 0.10628, 127.77 secs
# (2) Validation stage ...
# Random output:
# Little change compared comparison with previous study #neg
# No evidence of pulmonary vascular congestion #neg
# Cardiac silhouette at upper limits of normal or slightly enlarged # to previous CABG procedure #pos
# No acute focal pneumonia #neg
# Calcifications seen in right breast #pos card # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # observed observed observed present # # noted # # noted noted
# s2s_loss 0.15244, 1.06 secs
# ---- Epoch 58/60
# (1) Training stage (lr = 0.000004) ...
# loss 0.09810, s2s_loss 0.10169, 123.21 secs
# (2) Validation stage ...
# Random output:
# Mild to moderate cardiomegaly with prior CABG and intact sternotomy wires #pos
# Left sided ICD device with appropriate in appropriate position #pos
# Mild pulmonary vascular congestion with asymmetric increased opacity at right lower lung base #pos
# Superimposed pneumonia difficult to exclude #neg
# Hilar and mediastinal contours unremarkable #neg
# Trace bilateral pleural effusions #pos
# No pneumothorax #neg
# Pulmonary edema with possible superimposed pneumonia in right lung base #pos # # # is # difficult possible difficult difficult difficult difficult difficult difficult # # # # #P # # # # #P # # # # #PPP # # # # # #
# s2s_loss 0.15073, 1.02 secs
# New checkpoint saved: checkpoint_58_s2s_loss=0.8729.pt
# ---- Epoch 59/60
# (1) Training stage (lr = 0.000002) ...
# loss 0.10407, s2s_loss 0.10644, 123.42 secs
# (2) Validation stage ...
# Random output:
# Port tracheostomy tube is enteric feeding tube, right IJ central venous catheter, and right pleural pigtail catheter are unchanged in position #pos
# A small-to-moderate right apical pneumothorax is not significantly changed #neg
# Mass-like opacities in the right lung base are re-demonstrated #pos
# Small bilateral pleural effusions are unchanged #neg
# There is moderate subcutaneous emphysema along the right chest wall #pos
# The cardiomediastinal contours are within normal limits and unchanged #neg card small # # # # cat cat cat cat cat right cat right card card card card card card card card card card card card card card card card card card card card card card cardCard card card card card card card card card card card card card card
# s2s_loss 0.15062, 1.11 secs
# ---- Epoch 60/60
# (1) Training stage (lr = 0.000001) ...
# loss 0.10122, s2s_loss 0.09886, 131.80 secs
# (2) Validation stage ...
# Random output:
# No change in position of ECG leads # monitoring and #neg
# Aerate cardiomegaly persists #pos
# No pulmonary edema #negneg # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # system system
# s2s_loss 0.15223, 1.37 secs
