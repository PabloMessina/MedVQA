# %%
from medvqa.utils.files_utils import list_filepaths_with_prefix_and_timestamps, print_directory_tree
# Out:
# PROJECT_ROOT: /home/pamessina/medvqa
# DOTENV_PATH: /home/pamessina/medvqa/.env

# %%
list_filepaths_with_prefix_and_timestamps('/mnt/workspace/pamessina/slurm-out/')[:10]
# Out:
# [('/mnt/workspace/pamessina/slurm-out/eval/pg_metrics-79516.out',
#   '2025-12-26 11:03:04'),
#  ('/mnt/workspace/pamessina/slurm-out/eval/pg_metrics-79513.out',
#   '2025-12-26 11:03:02'),
#  ('/mnt/workspace/pamessina/slurm-out/eval/pg_metrics-79514.out',
#   '2025-12-26 11:03:01'),
#  ('/mnt/workspace/pamessina/slurm-out/eval/pg_metrics-79515.out',
#   '2025-12-26 11:02:59'),
#  ('/mnt/workspace/pamessina/slurm-out/eval/pg_metrics-79512.out',
#   '2025-12-26 11:02:56'),
#  ('/mnt/workspace/pamessina/slurm-out/eval/eval_phrase_grounding_inference_chestxdet__fgvlm_medsiglip-79510.out',
#   '2025-12-26 09:57:01'),
#  ('/mnt/workspace/pamessina/slurm-out/eval/eval_phrase_grounding_inference_chestxdet__fgvlm_medsiglip-79509.out',
#   '2025-12-26 09:56:56'),
#  ('/mnt/workspace/pamessina/slurm-out/eval/eval_phrase_grounding_inference_chestxdet__fgvlm_medsiglip-79507.out',
#   '2025-12-26 09:49:03'),
# ...

# %%
print_directory_tree(start_path='/home/pamessina/medvqa/medvqa/')
# Out:
# medvqa/
# ├── __init__.py
# ├── configs/
# │   ├── evaluation/
# │   │   ├── phrase_grounding_inference_chestimagenome__fgvlm_medsiglip.yaml
# │   │   ├── phrase_grounding_inference_chestxdet__fgvlm_medsiglip.yaml
# │   │   ├── phrase_grounding_inference_mscxr__fgvlm_medsiglip.yaml
# │   │   ├── phrase_grounding_inference_padchest-gr__fgvlm_medsiglip.yaml
# │   │   └── phrase_grounding_inference_vindrcxr__fgvlm_medsiglip.yaml
# │   ├── freezing/
# │   │   └── phrase_grounding_freeze_config_v1.yaml
# │   └── training/
# │       ├── Untitled
# │       ├── fgvlm_medsiglip_pg_chestimagenome+mscxr+padchest-gr+vindrcxr_cnr.yaml
# │       ├── fgvlm_medsiglip_pg_chestimagenome_cnr.yaml
# │       ├── fgvlm_medsiglip_pg_mscxr_cnr.yaml
# │       ├── fgvlm_medsiglip_pg_padchest-gr_cnr.yaml
# │       └── fgvlm_medsiglip_pg_vindrcxr_cnr.yaml
# ├── datasets/
# │   ├── __init__.py
# │   ├── augmentation.py
# │   ├── chest_imagenome/
# │   │   ├── __init__.py
# ...
