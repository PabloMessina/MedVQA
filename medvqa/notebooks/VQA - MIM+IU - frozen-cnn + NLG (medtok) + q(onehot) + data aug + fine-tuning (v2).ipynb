# %%
# %env CUDA_VISIBLE_DEVICES=1
# Out:
# env: CUDA_VISIBLE_DEVICES=1

# %%
# !python ../train_vqa.py \
        --pretrained-checkpoint-folder-path "/home/pamessina/medvqa-workspace/models/visual_module/20220613_180648_mimiccxr+iuxray+chexpert_densenet121_model-args=(densenet-121,1024)_cnn-pretr=0_dataset_weights=1.0,0.08,0.8_img-aug=random-spatial_tags=0_orien=1_chx=1_ql=1" \
        --epochs 100 \
        --batches-per-epoch 200 \
        --batch-size 200 \
        --num-workers 7 \
        --lr-decay-patience 3 \
        --answer-hidden-size 512 \
        --n-lstm-layers 2 \
        --iuxray-qa-adapted-reports-filename "qa_adapted_reports__20220607_170656.json" \
        --mimiccxr-qa-adapted-reports-filename "qa_adapted_reports__20220607_184201.json" \
        --balanced-split \
        --iuxray-balanced-metadata-filename "balanced_dataloading_metadata__20220608_025543.pkl" \
        --mimiccxr-balanced-metadata-filename "balanced_dataloading_metadata__20220608_025910.pkl" \
        --iuxray-chexpert-labels-filename "chexpert_labels_per_report__20220607_231729.pkl" \
        --mimiccxr-chexpert-labels-filename "chexpert_labels_per_report__20220607_231820.pkl" \
        --balanced-dataloading \
        --medical-tokenization \
        --medical-terms-frequency-filename "medical_terms_frequency__20220607_224903.pkl" \
        --question-encoding "one-hot" \
        --n-questions 97 \
        --img-aug-mode "random-spatial" \
        --no-chexpert \
        --use-amp \
        --freeze-cnn \
        --save
# Out:
# script's arguments:
#    epochs: 100
#    batches_per_epoch: 200
#    checkpoint_folder: None
#    iuxray_qa_adapted_reports_filename: qa_adapted_reports__20220607_170656.json
#    mimiccxr_qa_adapted_reports_filename: qa_adapted_reports__20220607_184201.json
#    vocab_min_freq: 5
#    embed_size: 128
#    question_encoding: one-hot
#    question_hidden_size: 128
#    answer_hidden_size: 512
#    n_lstm_layers: 2
#    question_vec_size: 128
#    image_local_feat_size: 1024
#    dropout_prob: 0
#    densenet_pretrained_weights_path:
#    lr: 0.001
#    lr_decay: 0.76
#    lr_decay_patience: 3
#    n_val_examples_per_question: 10
#    min_train_examples_per_question: 100
#    batch_size: 200
#    num_workers: 7
#    device: GPU
#    img_aug_mode: random-spatial
#    freeze_cnn: True
#    mimiccxr_weight: 0.83
#    chexpert_weight: 0.1
#    iuxray_weight: 0.07
#    val_answer_decoding: greedy-search
#    beam_search_k: None
#    use_amp: True
#    medical_tokenization: True
#    medical_terms_frequency_filename: medical_terms_frequency__20220607_224903.pkl
#    allowed_questions: None
#    pretrained_checkpoint_folder_path: /home/pamessina/medvqa-workspace/models/visual_module/20220613_180648_mimiccxr+iuxray+chexpert_densenet121_model-args=(densenet-121,1024)_cnn-pretr=0_dataset_weights=1.0,0.08,0.8_img-aug=random-spatial_tags=0_orien=1_chx=1_ql=1
#    balanced_split: True
#    balanced_dataloading: True
#    n_healthy_per_question: 2
#    n_unhealthy_per_question: 3
#    n_positive_per_chexpert_label: 7
#    min_question_count: 100
#    iuxray_balanced_metadata_filename: balanced_dataloading_metadata__20220608_025543.pkl
#    mimiccxr_balanced_metadata_filename: balanced_dataloading_metadata__20220608_025910.pkl
#    one_question_per_batch: False
#    save: True
#    override_lr: False
#    train_mimiccxr: True
#    train_iuxray: True
#    train_chexpert: False
#    binary_loss_name: bce
#    classify_tags: False
#    n_medical_tags: None
#    iuxray_medical_tags_per_report_filename: None
#    mimiccxr_medical_tags_per_report_filename: None
#    classify_orientation: False
#    classify_chexpert: False
#    iuxray_chexpert_labels_filename: chexpert_labels_per_report__20220607_231729.pkl
#    mimiccxr_chexpert_labels_filename: chexpert_labels_per_report__20220607_231820.pkl
#    classify_questions: False
#    n_questions: 97
#    iuxray_question_labels_filename: None
#    mimiccxr_question_labels_filename: None
# ----- Training model from scratch ------
# 1) device = cuda
# 2) Loading iuxray and mimiccxr QA adapted reports ...
# 3) Initializing tokenizer ...
# Loading /home/pamessina/medvqa-workspace/cache/vocab__min_freq=5__from(qa_adapted_reports__20220607_170656.json;qa_adapted_reports__20220607_184201.json).pkl ...
# 4) Creating instance of OpenEndedVQA model ...
# Using densenet121 with ImageNet pretrained weights
# 5) Defining Adam optimizer ...
# 6) Defining ReduceLROnPlateau scheduler ...
# 7) Creating trainer and validator engines ...
# 8) Defining image transform ...
# len(final_transforms) = 4
# default_prob = 0.3
# Returning augmented transforms with mode random-spatial
# 9) Creating MIMIC-CXR vqa trainer ...
# Checking if data is already cached in path /home/pamessina/medvqa-workspace/cache/mimiccxr/mimiccxr_preprocessed_train_data__(hash=292,4086290602689741595).pkl ...
# 	Yes, it is, data successfully loaded :)
# batch_size = 200
# Balanced train data loaded from /home/pamessina/medvqa-workspace/cache/mimiccxr/mimiccxr_preprocessed_train_data__(hash=292,4086290602689741595).pkl.balanced_train_data(bs=200).pkl
# 	len(question_datasets) = 91
# len(self.val_indices) = 5499
# len(val_indices) = 5499
# generating training and validation dataloaders ...
# num_workers = 7
# done!
# 10) Creating IU X-Ray vqa trainer ...
# Checking if data is already cached in path /home/pamessina/medvqa-workspace/cache/iuxray/iuxray_preprocessed_train_data__(hash=292,2871459686648763669).pkl ...
# 	Yes, it is, data successfully loaded :)
# batch_size = 200
# Balanced train data loaded from /home/pamessina/medvqa-workspace/cache/iuxray/iuxray_preprocessed_train_data__(hash=292,2871459686648763669).pkl.balanced_train_data(bs=200).pkl
# 	len(question_datasets) = 36
# len(self.val_indices) = 1262
# len(val_indices) = 1262
# generating training and validation dataloaders ...
# num_workers = 7
# done!
# 11) Creating dataloaders ...
# 12) Attaching metrics, losses, timer and events to engines ...
# checkpoint_folder_path = /home/pamessina/medvqa-workspace/models/vqa/20220626_123045_mimiccxr+iuxray_oevqa(densenet121+bilstm+lstm)_voc-minf=5_model-args=(densenet-121,128,None,512,2,128,1024,0,qenc=one-hot,pretrained)_cnn-pretr=0_dataset_weights=0.83,0.07_medtok=1_tags=0_orien=0_chx=0_ql=0_use_amp
# metadata saved to /home/pamessina/medvqa-workspace/models/vqa/20220626_123045_mimiccxr+iuxray_oevqa(densenet121+bilstm+lstm)_voc-minf=5_model-args=(densenet-121,128,None,512,2,128,1024,0,qenc=one-hot,pretrained)_cnn-pretr=0_dataset_weights=0.83,0.07_medtok=1_tags=0_orien=0_chx=0_ql=0_use_amp/metadata.json
# checkpoint_names = ['checkpoint_128_oracc+chxlmicf1+chxlmacf1+chxlrocauc+qlf1+gacc=0.7063.pt', 'checkpoint_127_oracc+chxlmicf1+chxlmacf1+chxlrocauc+qlf1+gacc=0.7126.pt']
# 13) Loading pretrained weights from /home/pamessina/medvqa-workspace/models/visual_module/20220613_180648_mimiccxr+iuxray+chexpert_densenet121_model-args=(densenet-121,1024)_cnn-pretr=0_dataset_weights=1.0,0.08,0.8_img-aug=random-spatial_tags=0_orien=1_chx=1_ql=1/checkpoint_127_oracc+chxlmicf1+chxlmacf1+chxlrocauc+qlf1+gacc=0.7126.pt ...
# Checkpoint successfully loaded!
# MetricsLogger :: we'll be logging to /home/pamessina/medvqa-workspace/models/vqa/20220626_123045_mimiccxr+iuxray_oevqa(densenet121+bilstm+lstm)_voc-minf=5_model-args=(densenet-121,128,None,512,2,128,1024,0,qenc=one-hot,pretrained)_cnn-pretr=0_dataset_weights=0.83,0.07_medtok=1_tags=0_orien=0_chx=0_ql=0_use_amp/metrics_logs.csv
# 14) Running trainer engine ...
# ---- Epoch 1/100
# (1) Training stage (lr = 0.001000) ...
# loss 8.59741, a_loss 4.46501, cD 0.15532, wmdcmp 0.02554, 84.26 secs
# (2) Validation stage ...
# cD 0.59223, wmdcmp 0.09912, 21.76 secs
# ---- Epoch 2/100
# (1) Training stage (lr = 0.001000) ...
# loss 4.00649, a_loss 3.30041, cD 0.75251, wmdcmp 0.11016, 82.23 secs
# (2) Validation stage ...
# cD 1.22691, wmdcmp 0.17728, 21.30 secs
# ---- Epoch 3/100
# (1) Training stage (lr = 0.001000) ...
# loss 2.95121, a_loss 2.64870, cD 1.14881, wmdcmp 0.15873, 81.87 secs
# (2) Validation stage ...
# cD 1.28638, wmdcmp 0.18511, 21.33 secs
# ---- Epoch 4/100
# (1) Training stage (lr = 0.001000) ...
# loss 2.60290, a_loss 2.41878, cD 1.30933, wmdcmp 0.17671, 82.33 secs
# (2) Validation stage ...
# cD 1.36150, wmdcmp 0.19170, 21.51 secs
# ---- Epoch 5/100
# (1) Training stage (lr = 0.001000) ...
# loss 2.47464, a_loss 2.31490, cD 1.41366, wmdcmp 0.18926, 81.80 secs
# (2) Validation stage ...
# cD 1.24887, wmdcmp 0.18152, 21.64 secs
# ---- Epoch 6/100
# (1) Training stage (lr = 0.001000) ...
# loss 2.30492, a_loss 2.22816, cD 1.49474, wmdcmp 0.19840, 82.05 secs
# (2) Validation stage ...
# cD 1.24205, wmdcmp 0.18130, 22.19 secs
# ---- Epoch 7/100
# (1) Training stage (lr = 0.001000) ...
# loss 2.23311, a_loss 2.17835, cD 1.54558, wmdcmp 0.20370, 83.33 secs
# (2) Validation stage ...
# cD 1.36284, wmdcmp 0.19120, 21.72 secs
# ---- Epoch 8/100
# (1) Training stage (lr = 0.001000) ...
# loss 2.24185, a_loss 2.12709, cD 1.58549, wmdcmp 0.20838, 82.77 secs
# (2) Validation stage ...
# cD 1.40894, wmdcmp 0.19716, 21.78 secs
# ---- Epoch 9/100
# (1) Training stage (lr = 0.001000) ...
# loss 2.18910, a_loss 2.09961, cD 1.61088, wmdcmp 0.21233, 83.74 secs
# (2) Validation stage ...
# cD 1.33087, wmdcmp 0.18914, 21.49 secs
# ---- Epoch 10/100
# (1) Training stage (lr = 0.001000) ...
# loss 2.14003, a_loss 2.06729, cD 1.63694, wmdcmp 0.21465, 82.24 secs
# (2) Validation stage ...
# cD 1.27265, wmdcmp 0.18389, 21.61 secs
# ---- Epoch 11/100
# (1) Training stage (lr = 0.001000) ...
# loss 2.01678, a_loss 2.05098, cD 1.66082, wmdcmp 0.21736, 81.55 secs
# (2) Validation stage ...
# cD 1.39990, wmdcmp 0.19604, 21.88 secs
# ---- Epoch 12/100
# (1) Training stage (lr = 0.001000) ...
# loss 2.12185, a_loss 2.02770, cD 1.67917, wmdcmp 0.21927, 82.12 secs
# (2) Validation stage ...
# cD 1.23602, wmdcmp 0.17817, 21.76 secs
# ---- Epoch 13/100
# (1) Training stage (lr = 0.001000) ...
# loss 1.95957, a_loss 2.00195, cD 1.69833, wmdcmp 0.22097, 82.98 secs
# (2) Validation stage ...
# cD 1.21678, wmdcmp 0.17809, 21.79 secs
# ---- Epoch 14/100
# (1) Training stage (lr = 0.001000) ...
# loss 2
secs
# ---- Epoch 46/100
# (1) Training stage (lr = 0.000334) ...
# loss 1.71140, a_loss 1.67650, cD 2.09819, wmdcmp 0.26647, 82.30 secs
# (2) Validation stage ...
# cD 1.39313, wmdcmp 0.19607, 21.87 secs
# ---- Epoch 47/100
# (1) Training stage (lr = 0.000334) ...
# loss 1.71940, a_loss 1.67410, cD 2.09739, wmdcmp 0.26553, 83.25 secs
# (2) Validation stage ...
# cD 1.39662, wmdcmp 0.19593, 21.72 secs
# ---- Epoch 48/100
# (1) Training stage (lr = 0.000334) ...
# loss 1.79169, a_loss 1.67219, cD 2.10460, wmdcmp 0.26698, 81.83 secs
# (2) Validation stage ...
# cD 1.40600, wmdcmp 0.19924, 21.68 secs
# ---- Epoch 49/100
# (1) Training stage (lr = 0.000334) ...
# loss 1.61044, a_loss 1.66648, cD 2.10168, wmdcmp 0.26642, 81.73 secs
# (2) Validation stage ...
# cD 1.44698, wmdcmp 0.20083, 21.83 secs
# ---- Epoch 50/100
# (1) Training stage (lr = 0.000334) ...
# loss 1.60461, a_loss 1.65937, cD 2.11703, wmdcmp 0.26828, 82.85 secs
# (2) Validation stage ...
# cD 1.32354, wmdcmp 0.19006, 21.85 secs
# ---- Epoch 51/100
# (1) Training stage (lr = 0.000334) ...
# loss 1.70160, a_loss 1.65855, cD 2.12358, wmdcmp 0.26870, 83.64 secs
# (2) Validation stage ...
# cD 1.35740, wmdcmp 0.19308, 21.79 secs
# ---- Epoch 52/100
# (1) Training stage (lr = 0.000334) ...
# loss 1.78028, a_loss 1.65955, cD 2.11839, wmdcmp 0.26824, 84.50 secs
# (2) Validation stage ...
# cD 1.45701, wmdcmp 0.20351, 21.50 secs
# ---- Epoch 53/100
# (1) Training stage (lr = 0.000334) ...
# loss 1.74753, a_loss 1.64874, cD 2.13373, wmdcmp 0.26947, 82.08 secs
# (2) Validation stage ...
# cD 1.40975, wmdcmp 0.19795, 21.81 secs
# ---- Epoch 54/100
# (1) Training stage (lr = 0.000334) ...
# loss 1.75139, a_loss 1.64665, cD 2.12161, wmdcmp 0.26909, 83.88 secs
# (2) Validation stage ...
# cD 1.24626, wmdcmp 0.18469, 21.98 secs
# ---- Epoch 55/100
# (1) Training stage (lr = 0.000334) ...
# loss 1.74729, a_loss 1.64667, cD 2.12600, wmdcmp 0.26910, 82.63 secs
# (2) Validation stage ...
# cD 1.34239, wmdcmp 0.19428, 22.00 secs
# ---- Epoch 56/100
# (1) Training stage (lr = 0.000334) ...
# loss 1.69542, a_loss 1.63967, cD 2.14313, wmdcmp 0.27101, 83.38 secs
# (2) Validation stage ...
# cD 1.39337, wmdcmp 0.19623, 21.80 secs
# Epoch    56: reducing learning rate of group 0 to 2.5355e-04.
# ---- Epoch 57/100
# (1) Training stage (lr = 0.000254) ...
# loss 1.77710, a_loss 1.63746, cD 2.14091, wmdcmp 0.27093, 82.20 secs
# (2) Validation stage ...
# cD 1.42623, wmdcmp 0.20085, 21.49 secs
# ---- Epoch 58/100
# (1) Training stage (lr = 0.000254) ...
# loss 1.71075, a_loss 1.62717, cD 2.15296, wmdcmp 0.27165, 83.48 secs
# (2) Validation stage ...
# cD 1.32268, wmdcmp 0.19136, 21.73 secs
# ---- Epoch 59/100
# (1) Training stage (lr = 0.000254) ...
# loss 1.71744, a_loss 1.61843, cD 2.18194, wmdcmp 0.27519, 84.99 secs
# (2) Validation stage ...
# cD 1.36714, wmdcmp 0.19535, 21.76 secs
# ---- Epoch 60/100
# (1) Training stage (lr = 0.000254) ...
# loss 1.59428, a_loss 1.61887, cD 2.18056, wmdcmp 0.27446, 83.04 secs
# (2) Validation stage ...
# cD 1.36946, wmdcmp 0.19495, 21.48 secs
# Epoch    60: reducing learning rate of group 0 to 1.9270e-04.
# ---- Epoch 61/100
# (1) Training stage (lr = 0.000193) ...
# loss 1
# ---- Epoch 76/100
# (1) Training stage (lr = 0.000146) ...
# loss 1.66740, a_loss 1.57115, cD 2.25682, wmdcmp 0.28311, 81.89 secs
# (2) Validation stage ...
# cD 1.41388, wmdcmp 0.19907, 21.52 secs
# ---- Epoch 77/100
# (1) Training stage (lr = 0.000146) ...
# loss 1.69557, a_loss 1.56227, cD 2.27887, wmdcmp 0.28577, 82.08 secs
# (2) Validation stage ...
# cD 1.39935, wmdcmp 0.19760, 21.57 secs
# ---- Epoch 78/100
# (1) Training stage (lr = 0.000146) ...
# loss 1.61842, a_loss 1.56298, cD 2.27710, wmdcmp 0.28508, 82.92 secs
# (2) Validation stage ...
# cD 1.43165, wmdcmp 0.20176, 21.63 secs
# ---- Epoch 79/100
# (1) Training stage (lr = 0.000146) ...
# loss 1.68162, a_loss 1.56327, cD 2.28464, wmdcmp 0.28623, 81.70 secs
# (2) Validation stage ...
# cD 1.41236, wmdcmp 0.19953, 21.41 secs
# ---- Epoch 80/100
# (1) Training stage (lr = 0.000146) ...
# loss 1.58499, a_loss 1.56152, cD 2.27444, wmdcmp 0.28455, 82.11 secs
# (2) Validation stage ...
# cD 1.39491, wmdcmp 0.19785, 21.32 secs
# ---- Epoch 81/100
# (1) Training stage (lr = 0.000146) ...
# loss 1.56336, a_loss 1.55698, cD 2.29949, wmdcmp 0.28765, 83.13 secs
# (2) Validation stage ...
# cD 1.39219, wmdcmp 0.19766, 21.26 secs
# ---- Epoch 82/100
# (1) Training stage (lr = 0.000146) ...
# loss 1.64993, a_loss 1.56123, cD 2.26211, wmdcmp 0.28417, 80.63 secs
# (2) Validation stage ...
# cD 1.40396, wmdcmp 0.19741, 21.51 secs
# Epoch    82: reducing learning rate of group 0 to 1.1130e-04.
# ---- Epoch 83/100
# (1) Training stage (lr = 0.000111) ...
# loss 1.70885, a_loss 1.55067, cD 2.29184, wmdcmp 0.28641, 82.53 secs
# (2) Validation stage ...
# cD 1.40384, wmdcmp 0.19875, 21.51 secs
# ---- Epoch 84/100
# (1) Training stage (lr = 0.000111) ...
# loss 1.64550, a_loss 1.55179, cD 2.30948, wmdcmp 0.28915, 81.47 secs
# (2) Validation stage ...
# cD 1.38939, wmdcmp 0.19830, 21.44 secs
# ---- Epoch 85/100
# (1) Training stage (lr = 0.000111) ...
# loss 1.62452, a_loss 1.54866, cD 2.29887, wmdcmp 0.28764, 81.67 secs
# (2) Validation stage ...
# cD 1.41695, wmdcmp 0.20009, 21.53 secs
# ---- Epoch 86/100
# (1) Training stage (lr = 0.000111) ...
# loss 1.64126, a_loss 1.54836, cD 2.30859, wmdcmp 0.28792, 81.99 secs
# (2) Validation stage ...
# cD 1.42269, wmdcmp 0.20005, 21.69 secs
# ---- Epoch 87/100
# (1) Training stage (lr = 0.000111) ...
# loss 1.61052, a_loss 1.54174, cD 2.31912, wmdcmp 0.28967, 81.89 secs
# (2) Validation stage ...
# cD 1.43355, wmdcmp 0.20066, 21.61 secs
# ---- Epoch 88/100
# (1) Training stage (lr = 0.000111) ...
# loss 1.62035, a_loss 1.54305, cD 2.30526, wmdcmp 0.28848, 82.37 secs
# (2) Validation stage ...
# cD 1.39523, wmdcmp 0.19756, 21.42 secs
# ---- Epoch 89/100
# (1) Training stage (lr = 0.000111) ...
# loss 1.65897, a_loss 1.54021, cD 2.31365, wmdcmp 0.28821, 81.67 secs
# (2) Validation stage ...
# cD 1.42848, wmdcmp 0.20025, 21.31 secs
# ---- Epoch 90/100
# (1) Training stage (lr = 0.000111) ...
# loss 1.56100, a_loss 1.53610, cD 2.32453, wmdcmp 0.28949, 82.28 secs
# (2) Validation stage ...
# cD 1.44419, wmdcmp 0.20272, 21.32 secs
# ---- Epoch 91/100
# (1) Training stage (lr = 0.000111) ...
# loss 1.54328, a_loss 1.53611, cD 2.31802, wmdcmp 0.28926, 81.85 secs
# (2) Validation stage ...
# cD 1.40496, wmdcmp 0.19862, 21.44 secs
# ---- Epoch 92/100
# (1) Training stage (lr = 0.000111) ...
# loss 1.61826, a_loss 1.53392, cD 2.33028, wmdcmp 0.29004, 80.86 secs
# (2) Validation stage ...
# cD 1.35396, wmdcmp 0.19395, 21.28 secs
# ---- Epoch 93/100
# (1) Training stage (lr = 0.000111) ...
# loss 1.63655, a_loss 1.53722, cD 2.33757, wmdcmp 0.29138, 81.69 secs
# (2) Validation stage ...
# cD 1.40385, wmdcmp 0.19959, 21.38 secs
# ---- Epoch 94/100
# (1) Training stage (lr = 0.000111) ...
# loss 1.56875, a_loss 1.54332, cD 2.31637, wmdcmp 0.28889, 82.18 secs
# (2) Validation stage ...
# cD 1.37246, wmdcmp 0.19550, 21.33 secs
# Epoch    94: reducing learning rate of group 0 to 8.4591e-05.
# ---- Epoch 95/100
# (1) Training stage (lr = 0.000085) ...
# loss 1.57089, a_loss 1.53314, cD 2.33694, wmdcmp 0.29142, 82.75 secs
# (2) Validation stage ...
# cD 1.37723, wmdcmp 0.19607, 21.39 secs
# ---- Epoch 96/100
# (1) Training stage (lr = 0.000085) ...
# loss 1.58540, a_loss 1.53022, cD 2.32924, wmdcmp 0.29052, 82.90 secs
# (2) Validation stage ...
# cD 1.43391, wmdcmp 0.20099, 21.36 secs
# ---- Epoch 97/100
# (1) Training stage (lr = 0.000085) ...
# loss 1.56594, a_loss 1.52432, cD 2.35362, wmdcmp 0.29323, 81.66 secs
# (2) Validation stage ...
# cD 1.40743, wmdcmp 0.19856, 21.36 secs
# ---- Epoch 98/100
# (1) Training stage (lr = 0.000085) ...
# loss 1.56812, a_loss 1.52610, cD 2.35650, wmdcmp 0.29343, 81.38 secs
# (2) Validation stage ...
# cD 1.42892, wmdcmp 0.20098, 21.55 secs
# ---- Epoch 99/100
# (1) Training stage (lr = 0.000085) ...
# loss 1.65946, a_loss 1.52569, cD 2.34055, wmdcmp 0.29131, 82.32 secs
# (2) Validation stage ...
# cD 1.43400, wmdcmp 0.20085, 21.39 secs
# ---- Epoch 100/100
# (1) Training stage (lr = 0.000085) ...
# loss 1.56555, a_loss 1.52832, cD 2.33418, wmdcmp 0.29101, 81.97 secs
# (2) Validation stage ...
# cD 1.41965, wmdcmp 0.19969, 21.40 secs

# %%
# !python ../train_vqa.py \
        --checkpoint-folder "models/vqa/20220626_123045_mimiccxr+iuxray_oevqa(densenet121+bilstm+lstm)_voc-minf=5_model-args=(densenet-121,128,None,512,2,128,1024,0,qenc=one-hot,pretrained)_cnn-pretr=0_dataset_weights=0.83,0.07_medtok=1_tags=0_orien=0_chx=0_ql=0_use_amp" \
        --epochs 20 \
        --batches-per-epoch 220 \
        --batch-size 200 \
        --num-workers 7 \
        --save
# Out:
# script's arguments:
#    epochs: 20
#    batches_per_epoch: 220
#    checkpoint_folder: models/vqa/20220626_123045_mimiccxr+iuxray_oevqa(densenet121+bilstm+lstm)_voc-minf=5_model-args=(densenet-121,128,None,512,2,128,1024,0,qenc=one-hot,pretrained)_cnn-pretr=0_dataset_weights=0.83,0.07_medtok=1_tags=0_orien=0_chx=0_ql=0_use_amp
#    iuxray_qa_adapted_reports_filename: None
#    mimiccxr_qa_adapted_reports_filename: None
#    vocab_min_freq: 5
#    embed_size: 128
#    question_encoding: bilstm
#    question_hidden_size: 128
#    answer_hidden_size: 128
#    n_lstm_layers: 1
#    question_vec_size: 128
#    image_local_feat_size: 1024
#    dropout_prob: 0
#    densenet_pretrained_weights_path:
#    lr: 0.001
#    lr_decay: 0.76
#    lr_decay_patience: 2
#    n_val_examples_per_question: 10
#    min_train_examples_per_question: 100
#    batch_size: 200
#    num_workers: 7
#    device: GPU
#    img_aug_mode: None
#    freeze_cnn: False
#    mimiccxr_weight: 0.83
#    chexpert_weight: 0.1
#    iuxray_weight: 0.07
#    val_answer_decoding: greedy-search
#    beam_search_k: None
#    use_amp: False
#    medical_tokenization: False
#    medical_terms_frequency_filename: None
#    allowed_questions: None
#    pretrained_checkpoint_folder_path: None
#    balanced_split: False
#    balanced_dataloading: False
#    n_healthy_per_question: 2
#    n_unhealthy_per_question: 3
#    n_positive_per_chexpert_label: 7
#    min_question_count: 100
#    iuxray_balanced_metadata_filename: None
#    mimiccxr_balanced_metadata_filename: None
#    one_question_per_batch: False
#    save: True
#    override_lr: False
#    train_mimiccxr: True
#    train_iuxray: True
#    train_chexpert: True
#    binary_loss_name: bce
#    classify_tags: False
#    n_medical_tags: None
#    iuxray_medical_tags_per_report_filename: None
#    mimiccxr_medical_tags_per_report_filename: None
#    classify_orientation: False
#    classify_chexpert: False
#    iuxray_chexpert_labels_filename: None
#    mimiccxr_chexpert_labels_filename: None
#    classify_questions: False
#    n_questions: None
#    iuxray_question_labels_filename: None
#    mimiccxr_question_labels_filename: None
# ----- Resuming training ------
# metadata loaded from /home/pamessina/medvqa-workspace/models/vqa/20220626_123045_mimiccxr+iuxray_oevqa(densenet121+bilstm+lstm)_voc-minf=5_model-args=(densenet-121,128,None,512,2,128,1024,0,qenc=one-hot,pretrained)_cnn-pretr=0_dataset_weights=0.83,0.07_medtok=1_tags=0_orien=0_chx=0_ql=0_use_amp/metadata.json
# 1) device = cuda
# 2) Loading iuxray and mimiccxr QA adapted reports ...
# 3) Initializing tokenizer ...
# Loading /home/pamessina/medvqa-workspace/cache/vocab__min_freq=5__from(qa_adapted_reports__20220607_170656.json;qa_adapted_reports__20220607_184201.json).pkl ...
# 4) Creating instance of OpenEndedVQA model ...
# Using densenet121 with ImageNet pretrained weights
# 5) Defining Adam optimizer ...
# 6) Defining ReduceLROnPlateau scheduler ...
# 7) Creating trainer and validator engines ...
# 8) Defining image transform ...
# len(final_transforms) = 4
# default_prob = 0.3
# Returning augmented transforms with mode random-spatial
# 9) Creating MIMIC-CXR vqa trainer ...
# Checking if data is already cached in path /home/pamessina/medvqa-workspace/cache/mimiccxr/mimiccxr_preprocessed_train_data__(hash=292,4086290602689741595).pkl ...
# 	Yes, it is, data successfully loaded :)
# batch_size = 200
# Balanced train data loaded from /home/pamessina/medvqa-workspace/cache/mimiccxr/mimiccxr_preprocessed_train_data__(hash=292,4086290602689741595).pkl.balanced_train_data(bs=200).pkl
# 	len(question_datasets) = 91
# len(self.val_indices) = 5499
# len(val_indices) = 5499
# generating training and validation dataloaders ...
# num_workers = 7
# done!
# 10) Creating IU X-Ray vqa trainer ...
# Checking if data is already cached in path /home/pamessina/medvqa-workspace/cache/iuxray/iuxray_preprocessed_train_data__(hash=292,2871459686648763669).pkl ...
# 	Yes, it is, data successfully loaded :)
# batch_size = 200
# Balanced train data loaded from /home/pamessina/medvqa-workspace/cache/iuxray/iuxray_preprocessed_train_data__(hash=292,2871459686648763669).pkl.balanced_train_data(bs=200).pkl
# 	len(question_datasets) = 36
# len(self.val_indices) = 1262
# len(val_indices) = 1262
# generating training and validation dataloaders ...
# num_workers = 7
# done!
# 11) Creating dataloaders ...
# 12) Attaching metrics, losses, timer and events to engines ...
# checkpoint_names = ['checkpoint_128_cD+wmdcmp=0.3945.pt', 'checkpoint_98_cD+wmdcmp=0.3884.pt']
# 13) Loading model from checkpoint ...
# checkpoint_path = /home/pamessina/medvqa-workspace/models/vqa/20220626_123045_mimiccxr+iuxray_oevqa(densenet121+bilstm+lstm)_voc-minf=5_model-args=(densenet-121,128,None,512,2,128,1024,0,qenc=one-hot,pretrained)_cnn-pretr=0_dataset_weights=0.83,0.07_medtok=1_tags=0_orien=0_chx=0_ql=0_use_amp/checkpoint_128_cD+wmdcmp=0.3945.pt
# Checkpoint successfully loaded!
# MetricsLogger :: we'll be logging to /home/pamessina/medvqa-workspace/models/vqa/20220626_123045_mimiccxr+iuxray_oevqa(densenet121+bilstm+lstm)_voc-minf=5_model-args=(densenet-121,128,None,512,2,128,1024,0,qenc=one-hot,pretrained)_cnn-pretr=0_dataset_weights=0.83,0.07_medtok=1_tags=0_orien=0_chx=0_ql=0_use_amp/metrics_logs.csv
# 14) Running trainer engine ...
# ---- Epoch 129/148
# (1) Training stage (lr = 0.000016) ...
# loss 1.39659, a_loss 1.47850, cD 2.41991, wmdcmp 0.30083, 95.77 secs
# (2) Validation stage ...
# cD 1.38904, wmdcmp 0.19668, 22.91 secs
# ---- Epoch 130/148
# (1) Training stage (lr = 0.000016) ...
# loss 1.69511, a_loss 1.49239, cD 2.40182, wmdcmp 0.29872, 90.92 secs
# (2) Validation stage ...
# cD 1.43306, wmdcmp 0.20193, 21.75 secs
# ---- Epoch 131/148
# (1) Training stage (lr = 0.000016) ...
# loss 1.53034, a_loss 1.49091, cD 2.41740, wmdcmp 0.30036, 90.91 secs
# (2) Validation stage ...
# cD 1.40311, wmdcmp 0.19843, 21.56 secs
# ---- Epoch 132/148
# (1) Training stage (lr = 0.000016) ...
# loss 1.48181, a_loss 1.49210, cD 2.41903, wmdcmp 0.29965, 92.12 secs
# (2) Validation stage ...
# cD 1.41693, wmdcmp 0.19969, 21.51 secs
# Epoch   132: reducing learning rate of group 0 to 1.2388e-05.
# ---- Epoch 133/148
# (1) Training stage (lr = 0.000012) ...
# loss 1.55448, a_loss 1.49144, cD 2.40402, wmdcmp 0.29882, 92.36 secs
# (2) Validation stage ...
# cD 1.41937, wmdcmp 0.20037, 21.52 secs
# ---- Epoch 134/148
# (1) Training stage (lr = 0.000012) ...
# loss 1.58962, a_loss 1.49110, cD 2.41946, wmdcmp 0.29996, 91.56 secs
# (2) Validation stage ...
# cD 1.38773, wmdcmp 0.19755, 21.37 secs
# ---- Epoch 135/148
# (1) Training stage (lr = 0.000012) ...
# loss 1.51836, a_loss 1.49203, cD 2.41707, wmdcmp 0.29961, 89.94 secs
# (2) Validation stage ...
# cD 1.44770, wmdcmp 0.20268, 21.65 secs
# ---- Epoch 136/148
# (1) Training stage (lr = 0.000012) ...
# loss 1.49521, a_loss 1.48839, cD 2.42585, wmdcmp 0.30147, 91.73 secs
# (2) Validation stage ...
# cD 1.40580, wmdcmp 0.19915, 21.35 secs
# ---- Epoch 137/148
# (1) Training stage (lr = 0.000012) ...
# loss 1.54670, a_loss 1.49258, cD 2.40461, wmdcmp 0.29861, 92.14 secs
# (2) Validation stage ...
# cD 1.40794, wmdcmp 0.19910, 21.45 secs
# ---- Epoch 138/148
# (1) Training stage (lr = 0.000012) ...
# loss 1.54001, a_loss 1.49083, cD 2.41755, wmdcmp 0.30057, 91.78 secs
# (2) Validation stage ...
# cD 1.41825, wmdcmp 0.20070, 21.70 secs
# ---- Epoch 139/148
# (1) Training stage (lr = 0.000012) ...
# loss 1.61252, a_loss 1.49343, cD 2.40398, wmdcmp 0.29769, 91.83 secs
# (2) Validation stage ...
# cD 1.42624, wmdcmp 0.20097, 21.42 secs
# Epoch   139: reducing learning rate of group 0 to 9.4152e-06.
# ---- Epoch 140/148
# (1) Training stage (lr = 0.000009) ...
# loss 1.54404, a_loss 1.48717, cD 2.42230, wmdcmp 0.29985, 91.02 secs
# (2) Validation stage ...
# cD 1.40114, wmdcmp 0.19769, 21.50 secs
# ---- Epoch 141/148
# (1) Training stage (lr = 0.000009) ...
# loss 1.54892, a_loss 1.49049, cD 2.40831, wmdcmp 0.29907, 91.63 secs
# (2) Validation stage ...
# cD 1.39453, wmdcmp 0.19764, 21.76 secs
# ---- Epoch 142/148
# (1) Training stage (lr = 0.000009) ...
# loss 1.52969, a_loss 1.49030, cD 2.40846, wmdcmp 0.29960, 91.71 secs
# (2) Validation stage ...
# cD 1.43596, wmdcmp 0.20212, 21.65 secs
# ---- Epoch 143/148
# (1) Training stage (lr = 0.000009) ...
# loss 1.54528, a_loss 1.48758, cD 2.43661, wmdcmp 0.30196, 93.60 secs
# (2) Validation stage ...
# cD 1.41656, wmdcmp 0.20001, 21.83 secs
# Epoch   143: reducing learning rate of group 0 to 7.1556e-06.
# ---- Epoch 144/148
# (1) Training stage (lr = 0.000007) ...
# loss 1.53461, a_loss 1.48844, cD 2.41205, wmdcmp 0.29961, 90.88 secs
# (2) Validation stage ...
# cD 1.42848, wmdcmp 0.20024, 21.74 secs
# ---- Epoch 145/148
# (1) Training stage (lr = 0.000007) ...
# loss 1.56351, a_loss 1.48773, cD 2.41851, wmdcmp 0.30002, 91.29 secs
# (2) Validation stage ...
# cD 1.42929, wmdcmp 0.20069, 21.60 secs
# ---- Epoch 146/148
# (1) Training stage (lr = 0.000007) ...
# loss 1.60098, a_loss 1.48778, cD 2.42561, wmdcmp 0.30083, 92.75 secs
# (2) Validation stage ...
# cD 1.41200, wmdcmp 0.19901, 21.71 secs
# ---- Epoch 147/148
# (1) Training stage (lr = 0.000007) ...
# loss 1.64668, a_loss 1.48606, cD 2.42469, wmdcmp 0.30100, 91.87 secs
# (2) Validation stage ...
# cD 1.42814, wmdcmp 0.20074, 21.78 secs
# Epoch   147: reducing learning rate of group 0 to 5.4382e-06.
# ---- Epoch 148/148
# (1) Training stage (lr = 0.000005) ...
# loss 1.57886, a_loss 1.49006, cD 2.42811, wmdcmp 0.30134, 91.55 secs
# (2) Validation stage ...
# cD 1.42190, wmdcmp 0.20028, 21.67 secs

# %% [markdown]
# ### Training-Validation plots

# %%
from medvqa.evaluation.plots import plot_train_val_curves
from medvqa.utils.constants import MetricNames

# %%
plot_train_val_curves('/home/pamessina/medvqa-workspace/models/vqa/20220626_123045_mimiccxr+iuxray_oevqa(densenet121+bilstm+lstm)_voc-minf=5_model-args=(densenet-121,128,None,512,2,128,1024,0,qenc=one-hot,pretrained)_cnn-pretr=0_dataset_weights=0.83,0.07_medtok=1_tags=0_orien=0_chx=0_ql=0_use_amp/metrics_logs.csv',
                 [MetricNames.WMEDCOMP, MetricNames.CIDER_D],
                 ['Weighted Medical Completeness (QA)', 'cider-D (QA)'],
                 single_plot_figsize=(8,6))

# %% [markdown]
# # Test Set Evaluation

# %% [markdown]
# # 1) Question-level Results

# %%
# !python ../eval_vqa.py \
        --checkpoint-folder "models/vqa/20220626_123045_mimiccxr+iuxray_oevqa(densenet121+bilstm+lstm)_voc-minf=5_model-args=(densenet-121,128,None,512,2,128,1024,0,qenc=one-hot,pretrained)_cnn-pretr=0_dataset_weights=0.83,0.07_medtok=1_tags=0_orien=0_chx=0_ql=0_use_amp" \
        --batch-size 160
# Out:
# script's arguments:
#    checkpoint_folder: models/vqa/20220626_123045_mimiccxr+iuxray_oevqa(densenet121+bilstm+lstm)_voc-minf=5_model-args=(densenet-121,128,None,512,2,128,1024,0,qenc=one-hot,pretrained)_cnn-pretr=0_dataset_weights=0.83,0.07_medtok=1_tags=0_orien=0_chx=0_ql=0_use_amp
#    answer_decoding: greedy-search
#    beam_search_k: None
#    batch_size: 160
#    device: GPU
#    num_workers: 0
#    eval_iuxray: True
#    eval_mimiccxr: True
#    use_amp: False
# ----- Evaluating model ------
# metadata loaded from /home/pamessina/medvqa-workspace/models/vqa/20220626_123045_mimiccxr+iuxray_oevqa(densenet121+bilstm+lstm)_voc-minf=5_model-args=(densenet-121,128,None,512,2,128,1024,0,qenc=one-hot,pretrained)_cnn-pretr=0_dataset_weights=0.83,0.07_medtok=1_tags=0_orien=0_chx=0_ql=0_use_amp/metadata.json
# 1) device = cuda
# 2) Loading iuxray and mimiccxr QA adapted reports ...
# 3) Initializing tokenizer ...
# Loading /home/pamessina/medvqa-workspace/cache/vocab__min_freq=5__from(qa_adapted_reports__20220607_170656.json;qa_adapted_reports__20220607_184201.json).pkl ...
# 4) Creating instance of OpenEndedVQA model ...
# Using densenet121 with ImageNet pretrained weights
# 5) Creating evaluator engine ...
# 6) Defining image transform ...
# Returning default transform
# 7) Creating MIMIC-CXR vqa evaluator ...
# report_eval_mode = None
# Checking if data is already cached in path /home/pamessina/medvqa-workspace/cache/mimiccxr/mimiccxr_preprocessed_test_data__(dataset=qa_adapted_reports__20220607_184201.json;tokenizer=5292,42867,1646630074169161515).pkl ...
# 	Yes, it is, data successfully loaded :)
# batch_size = 160
# generating test dataset ...
# generating test dataloader ...
# done!
# 8) Creating IU X-Ray vqa trainer ...
# Checking if data is already cached in path /home/pamessina/medvqa-workspace/cache/iuxray/iuxray_preprocessed_train_data__(hash=247,1338506350569278595).pkl ...
# 	Yes, it is, data successfully loaded :)
# Train-val split indices successfully loaded from /home/pamessina/medvqa-workspace/cache/iuxray/iuxray_preprocessed_train_data__(hash=292,2871459686648763669).pkl
# batch_size = 160
# len(self.val_indices) = 1262
# len(val_indices) = 1262
# generating training and validation dataloaders ...
# num_workers = 0
# done!
# 9) Attaching metrics, timer and events to engines ...
# checkpoint_names = ['checkpoint_135_cD+wmdcmp=0.3952.pt', 'checkpoint_128_cD+wmdcmp=0.3945.pt', 'checkpoint_98_cD+wmdcmp=0.3884.pt']
# 10) Loading model from checkpoint ...
# checkpoint_path =  /home/pamessina/medvqa-workspace/models/vqa/20220626_123045_mimiccxr+iuxray_oevqa(densenet121+bilstm+lstm)_voc-minf=5_model-args=(densenet-121,128,None,512,2,128,1024,0,qenc=one-hot,pretrained)_cnn-pretr=0_dataset_weights=0.83,0.07_medtok=1_tags=0_orien=0_chx=0_ql=0_use_amp/checkpoint_135_cD+wmdcmp=0.3952.pt
# Loading model and epoch only
# Checkpoint successfully loaded!
#
# ========================
# 11) Running evaluator engine on IU X-Ray validation split ...
# len(dataset) = 1262
# len(dataloader) = 8
# ---- Epoch 136/136
# Evaluating model ...
# b1 0.38664, b2 0.25657, b3 0.17014, b4 0.11373, rg-L 0.41184, met 0.36182, cD 1.54388, mdcmp 0.23168, wmdcmp 0.21780, 9.97 secs
# Cache successfully loaded from /home/pamessina/medvqa-workspace/cache/chexpert_labeler_cache.pkl
# (*) Chexpert: labeling 1262 texts ...
# All labels found in cache, no need to invoke chexpert labeler
# (*) Chexpert: labeling 1262 texts ...
# Chexpert labeler: running a maximum of 10 concurrent processes over 3 chunks
# chunk: i=0, b=0, e=22, chunk_size=22
# chunk: i=1, b=22, e=44, chunk_size=22
# chunk: i=2, b=44, e=66, chunk_size=20
# 	#### process 1: running chexpert labeler over 22 texts ...
# 	Command = docker run -v /home/pamessina/medvqa-workspace/tmp/chexpert-labeler:/data chexpert-labeler:latest python label.py --reports_path /data/labeler-input_0.csv --output_path /data/labeler-output_0.csv
# 	#### process 2: running chexpert labeler over 22 texts ...
# 	Command = docker run -v /home/pamessina/medvqa-workspace/tmp/chexpert-labeler:/data chexpert-labeler:latest python label.py --reports_path /data/labeler-input_1.csv --output_path /data/labeler-output_1.csv
# 	#### process 3: running chexpert labeler over 20 texts ...
# 	Command = docker run -v /home/pamessina/medvqa-workspace/tmp/chexpert-labeler:/data chexpert-labeler:latest python label.py --reports_path /data/labeler-input_2.csv --output_path /data/labeler-output_2.csv
# Generating LALR tables
# Downloading 'http://search.maven.org/remotecontent?filepath=edu/stanford/nlp/stanford-corenlp/3.5.2/stanford-corenlp-3.5.2.jar' -> '/root/.local/share/pystanforddeps/stanford-corenlp-3.5.2.jar'
# 	**** process 1 finished, elapsed time = 12.388143539428711
# Generating LALR tables
# Downloading 'http://search.maven.org/remotecontent?filepath=edu/stanford/nlp/stanford-corenlp/3.5.2/stanford-corenlp-3.5.2.jar' -> '/root/.local/share/pystanforddeps/stanford-corenlp-3.5.2.jar'
# Generating LALR tables
# Downloading 'http://search.maven.org/remotecontent?filepath=edu/stanford/nlp/stanford-corenlp/3.5.2/stanford-corenlp-3.5.2.jar' -> '/root/.local/share/pystanforddeps/stanford-corenlp-3.5.2.jar'
# 	**** process 2 finished, elapsed time = 15.802681922912598
# 	**** process 3 finished, elapsed time = 15.802804946899414
# Aggregated metrics successfully saved to /home/pamessina/medvqa-workspace/results/vqa/20220626_123045_mimiccxr+iuxray_oevqa(densenet121+bilstm+lstm)_voc-minf=5_model-args=(densenet-121,128,None,512,2,128,1024,0,qenc=one-hot,pretrained)_cnn-pretr=0_dataset_weights=0.83,0.07_medtok=1_tags=0_orien=0_chx=0_ql=0_use_amp/iuxray_metrics.pkl
#
# ========================
# 12) Running evaluator engine on MIMIC-CXR test split ...
# len(dataset) = 30553
# len(dataloader) = 191
# ---- Epoch 136/136
# Evaluating model ...
# b1 0.09692, b2 0.05411, b3 0.03000, b4 0.01726, rg-L 0.22764, met 0.15714, cD 0.53279, mdcmp 0.20083, wmdcmp 0.18854, 130.90 secs
# Cache successfully loaded from /home/pamessina/medvqa-workspace/cache/chexpert_labeler_cache.pkl
# (*) Chexpert: labeling 30553 texts ...
# All labels found in cache, no need to invoke chexpert labeler
# (*) Chexpert: labeling 30553 texts ...
# Chexpert labeler: running a maximum of 10 concurrent processes over 10 chunks
# chunk: i=0, b=0, e=280, chunk_size=280
# chunk: i=1, b=280, e=560, chunk_size=280
# chunk: i=2, b=560, e=840, chunk_size=280
# chunk: i=3, b=840, e=1120, chunk_size=280
# chunk: i=4, b=1120, e=1400, chunk_size=280
# chunk: i=5, b=1400, e=1680, chunk_size=280
# chunk: i=6, b=1680, e=1960, chunk_size=280
# chunk: i=7, b=1960, e=2240, chunk_size=280
# chunk: i=8, b=2240, e=2520, chunk_size=280
# chunk: i=9, b=2520, e=2800, chunk_size=274
# 	#### process 1: running chexpert labeler over 280 texts ...
# 	Command = docker run -v /home/pamessina/medvqa-workspace/tmp/chexpert-labeler:/data chexpert-labeler:latest python label.py --reports_path /data/labeler-input_0.csv --output_path /data/labeler-output_0.csv
# 	#### process 2: running chexpert labeler over 280 texts ...
# 	Command = docker run -v /home/pamessina/medvqa-workspace/tmp/chexpert-labeler:/data chexpert-labeler:latest python label.py --reports_path /data/labeler-input_1.csv --output_path /data/labeler-output_1.csv
# 	#### process 3: running chexpert labeler over 280 texts ...
# 	Command = docker run -v /home/pamessina/medvqa-workspace/tmp/chexpert-labeler:/data chexpert-labeler:latest python label.py --reports_path /data/labeler-input_2.csv --output_path /data/labeler-output_2.csv
# 	#### process 4: running chexpert labeler over 280 texts ...
# 	Command = docker run -v /home/pamessina/medvqa-workspace/tmp/chexpert-labeler:/data chexpert-labeler:latest python label.py --reports_path /data/labeler-input_3.csv --output_path /data/labeler-output_3.csv
# 	#### process 5: running chexpert labeler over 280 texts ...
# 	Command = docker run -v /home/pamessina/medvqa-workspace/tmp/chexpert-labeler:/data chexpert-labeler:latest python label.py --reports_path /data/labeler-input_4.csv --output_path /data/labeler-output_4.csv
# 	#### process 6: running chexpert labeler over 280 texts ...
# 	Command = docker run -v /home/pamessina/medvqa-workspace/tmp/chexpert-labeler:/data chexpert-labeler:latest python label.py --reports_path /data/labeler-input_5.csv --output_path /data/labeler-output_5.csv
# 	#### process 7: running chexpert labeler over 280 texts ...
# 	Command = docker run -v /home/pamessina/medvqa-workspace/tmp/chexpert-labeler:/data chexpert-labeler:latest python label.py --reports_path /data/labeler-input_6.csv --output_path /data/labeler-output_6.csv
# 	#### process 8: running chexpert labeler over 280 texts ...
# 	Command = docker run -v /home/pamessina/medvqa-workspace/tmp/chexpert-labeler:/data chexpert-labeler:latest python label.py --reports_path /data/labeler-input_7.csv --output_path /data/labeler-output_7.csv
# 	#### process 9: running chexpert labeler over 280 texts ...
# 	Command = docker run -v /home/pamessina/medvqa-workspace/tmp/chexpert-labeler:/data chexpert-labeler:latest python label.py --reports_path /data/labeler-input_8.csv --output_path /data/labeler-output_8.csv
# 	#### process 10: running chexpert labeler over 274 texts ...
# 	Command = docker run -v /home/pamessina/medvqa-workspace/tmp/chexpert-labeler:/data chexpert-labeler:latest python label.py --reports_path /data/labeler-input_9.csv --output_path /data/labeler-output_9.csv
# Generating LALR tables
# Downloading 'http://search.maven.org/remotecontent?filepath=edu/stanford/nlp/stanford-corenlp/3.5.2/stanford-corenlp-3.5.2.jar' -> '/root/.local/share/pystanforddeps/stanford-corenlp-3.5.2.jar'
# Generating LALR tables
# Downloading 'http://search.maven.org/remotecontent?filepath=edu/stanford/nlp/stanford-corenlp/3.5.2/stanford-corenlp-3.5.2.jar' -> '/root/.local/share/pystanforddeps/stanford-corenlp-3.5.2.jar'
# Generating LALR tables
# Downloading 'http://search.maven.org/remotecontent?filepath=edu/stanford/nlp/stanford-corenlp/3.5.2/stanford-corenlp-3.5.2.jar' -> '/root/.local/share/pystanforddeps/stanford-corenlp-3.5.2.jar'
# 	**** process 1 finished, elapsed time = 74.15671157836914
# Generating LALR tables
# Downloading 'http://search.maven.org/remotecontent?filepath=edu/stanford/nlp/stanford-corenlp/3.5.2/stanford-corenlp-3.5.2.jar' -> '/root/.local/share/pystanforddeps/stanford-corenlp-3.5.2.jar'
# Generating LALR tables
# Downloading 'http://search.maven.org/remotecontent?filepath=edu/stanford/nlp/stanford-corenlp/3.5.2/stanford-corenlp-3.5.2.jar' -> '/root/.local/share/pystanforddeps/stanford-corenlp-3.5.2.jar'
# Downloading 'http://search.maven.org/remotecontent?filepath=edu/stanford/nlp/stanford-corenlp/3.5.2/stanford-corenlp-3.5.2.jar' -> '/root/.local/share/pystanforddeps/stanford-corenlp-3.5.2.jar'
# Generating LALR tables
# Generating LALR tables
# Downloading 'http://search.maven.org/remotecontent?filepath=edu/stanford/nlp/stanford-corenlp/3.5.2/stanford-corenlp-3.5.2.jar' -> '/root/.local/share/pystanforddeps/stanford-corenlp-3.5.2.jar'
# Generating LALR tables
# Downloading 'http://search.maven.org/remotecontent?filepath=edu/stanford/nlp/stanford-corenlp/3.5.2/stanford-corenlp-3.5.2.jar' -> '/root/.local/share/pystanforddeps/stanford-corenlp-3.5.2.jar'
# Generating LALR tables
# Downloading 'http://search.maven.org/remotecontent?filepath=edu/stanford/nlp/stanford-corenlp/3.5.2/stanford-corenlp-3.5.2.jar' -> '/root/.local/share/pystanforddeps/stanford-corenlp-3.5.2.jar'
# 	**** process 2 finished, elapsed time = 117.58372521400452
# 	**** process 3 finished, elapsed time = 117.58382940292358
# 	**** process 4 finished, elapsed time = 117.58388829231262
# 	**** process 5 finished, elapsed time = 117.58394193649292
# 	**** process 6 finished, elapsed time = 117.58399534225464
# 	**** process 7 finished, elapsed time = 117.58404779434204
# Generating LALR tables
# Downloading 'http://search.maven.org/remotecontent?filepath=edu/stanford/nlp/stanford-corenlp/3.5.2/stanford-corenlp-3.5.2.jar' -> '/root/.local/share/pystanforddeps/stanford-corenlp-3.5.2.jar'
# 	**** process 8 finished, elapsed time = 120.4025866985321
# 	**** process 9 finished, elapsed time = 120.40271306037903
# 	**** process 10 finished, elapsed time = 120.40278005599976
# Aggregated metrics successfully saved to /home/pamessina/medvqa-workspace/results/vqa/20220626_123045_mimiccxr+iuxray_oevqa(densenet121+bilstm+lstm)_voc-minf=5_model-args=(densenet-121,128,None,512,2,128,1024,0,qenc=one-hot,pretrained)_cnn-pretr=0_dataset_weights=0.83,0.07_medtok=1_tags=0_orien=0_chx=0_ql=0_use_amp/mimiccxr_metrics.pkl

# %%
from medvqa.utils.files import load_pickle
from medvqa.evaluation.vqa import (
    get_overall_metrics_dataframe,
    get_per_question_metrics_dataframe,
)

# %% [markdown]
# ### IU X-Ray metrics

# %%
iuxray_agg_metrics = load_pickle('/home/pamessina/medvqa-workspace/results/vqa/20220626_123045_mimiccxr+iuxray_oevqa(densenet121+bilstm+lstm)_voc-minf=5_model-args=(densenet-121,128,None,512,2,128,1024,0,qenc=one-hot,pretrained)_cnn-pretr=0_dataset_weights=0.83,0.07_medtok=1_tags=0_orien=0_chx=0_ql=0_use_amp
# 37  0.836364  0.873403  0.163776  0.911996  0.118420  0.881027  0.120126
# 38  0.984154  0.984154  0.000000  1.000000  0.000000  0.991893  0.000000
# 39  0.974548  0.950995  0.138502  0.925985  0.157048  0.935940  0.145434
#
#     chx_s_0  chx_s_1
# 0        13        1
# 1       989       75
# 2       123        3
# 3        14        0
# 4     23802     2000
# 5        84       14
# 6      1880      108
# 7       938       84
# 8       965       71
# 9       272        8
# 10      466       10
# 11     8300      940
# 12    10779     1359
# 13      117        9
# 14    31186     3772
# 15      533       41
# 16     4522      406
# 17      631       13
# 18      175       21
# 19      414       20
# 20       13        1
# 21      181       15
# 22     2671      283
# 23     8688      818
# 24     3905      183
# 25    14134     1826
# 26     1653       41
# 27    15445     1397
# 28     2493      391
# 29    18318     1646
# 30      297       25
# 31      918       20
# 32      143       11
# 33    10758     1156
# 34     9651     1311
# 35     4938      760
# 36    22022     2520
# 37     1325      215
# 38     4037       65
# 39     3206      448

# %% [markdown]
# # 2) Report-level Results

# %%
# !python ../eval_report_generation.py \
        --checkpoint-folder "models/vqa/20220626_123045_mimiccxr+iuxray_oevqa(densenet121+bilstm+lstm)_voc-minf=5_model-args=(densenet-121,128,None,512,2,128,1024,0,qenc=one-hot,pretrained)_cnn-pretr=0_dataset_weights=0.83,0.07_medtok=1_tags=0_orien=0_chx=0_ql=0_use_amp" \
        --eval-mode "ground-truth" \
        --no-iuxray \
        --batch-size 160
# Out:
# script's arguments:
#    checkpoint_folder: models/vqa/20220626_123045_mimiccxr+iuxray_oevqa(densenet121+bilstm+lstm)_voc-minf=5_model-args=(densenet-121,128,None,512,2,128,1024,0,qenc=one-hot,pretrained)_cnn-pretr=0_dataset_weights=0.83,0.07_medtok=1_tags=0_orien=0_chx=0_ql=0_use_amp
#    eval_mode: ground-truth
#    n_questions_per_report: None
#    batch_size: 160
#    device: GPU
#    num_workers: 0
#    answer_decoding: greedy-search
#    eval_iuxray: False
#    eval_mimiccxr: True
#    use_amp: False
# ----- Evaluating model ------
# metadata loaded from /home/pamessina/medvqa-workspace/models/vqa/20220626_123045_mimiccxr+iuxray_oevqa(densenet121+bilstm+lstm)_voc-minf=5_model-args=(densenet-121,128,None,512,2,128,1024,0,qenc=one-hot,pretrained)_cnn-pretr=0_dataset_weights=0.83,0.07_medtok=1_tags=0_orien=0_chx=0_ql=0_use_amp/metadata.json
# 1) device = cuda
# 2) Loading iuxray and mimiccxr QA adapted reports ...
# 3) Initializing tokenizer ...
# Loading /home/pamessina/medvqa-workspace/cache/vocab__min_freq=5__from(qa_adapted_reports__20220607_170656.json;qa_adapted_reports__20220607_184201.json).pkl ...
# 4) Estimating maximum answer length ...
# max_answer_length = 15
# 5) Defining image transform ...
# Returning default transform
# checkpoint_names = ['checkpoint_135_cD+wmdcmp=0.3952.pt', 'checkpoint_128_cD+wmdcmp=0.3945.pt', 'checkpoint_98_cD+wmdcmp=0.3884.pt']
# 6) Loading model from checkpoint ...
# checkpoint_path =  /home/pamessina/medvqa-workspace/models/vqa/20220626_123045_mimiccxr+iuxray_oevqa(densenet121+bilstm+lstm)_voc-minf=5_model-args=(densenet-121,128,None,512,2,128,1024,0,qenc=one-hot,pretrained)_cnn-pretr=0_dataset_weights=0.83,0.07_medtok=1_tags=0_orien=0_chx=0_ql=0_use_amp/checkpoint_135_cD+wmdcmp=0.3952.pt
# 7) Creating MIMIC-CXR vqa evaluator ...
# report_eval_mode = ground-truth
# Checking if data is already cached in path /home/pamessina/medvqa-workspace/cache/mimiccxr/mimiccxr_preprocessed_test_data__(dataset=qa_adapted_reports__20220607_184201.json;tokenizer=5292,42867,1646630074169161515;report_eval_mode=ground-truth).pkl ...
# 	Yes, it is, data successfully loaded :)
# batch_size = 160
# generating test dataset ...
# generating test dataloader ...
# done!
# 8) Creating instance of OpenEndedVQA model ...
# Using densenet121 with ImageNet pretrained weights
# 9) Creating evaluator engine ...
# 10) Attaching metrics, losses, timer and events to engines ...
#
# ========================
# 11) Running evaluator engine on MIMIC-CXR test split ...
# len(dataset) = 30553
# len(dataloader) = 191
# Evaluating model ...
# , 81.29 secs 190
# Cache successfully loaded from /home/pamessina/medvqa-workspace/cache/chexpert_labeler_cache.pkl
# (*) Chexpert: labeling 3125 texts ...
# All labels found in cache, no need to invoke chexpert labeler
# (*) Chexpert: labeling 3125 texts ...
# Chexpert labeler: running a maximum of 10 concurrent processes over 10 chunks
# chunk: i=0, b=0, e=311, chunk_size=311
# chunk: i=1, b=311, e=622, chunk_size=311
# chunk: i=2, b=622, e=933, chunk_size=311
# chunk: i=3, b=933, e=1244, chunk_size=311
# chunk: i=4, b=1244, e=1555, chunk_size=311
# chunk: i=5, b=1555, e=1866, chunk_size=311
# chunk: i=6, b=1866, e=2177, chunk_size=311
# chunk: i=7, b=2177, e=2488, chunk_size=311
# chunk: i=8, b=2488, e=2799, chunk_size=311
# chunk: i=9, b=2799, e=3110, chunk_size=308
# 	#### process 1: running chexpert labeler over 311 texts ...
# 	Command = docker run -v /home/pamessina/medvqa-workspace/tmp/chexpert-labeler:/data chexpert-labeler:latest python label.py --reports_path /data/labeler-input_gen_0.csv --output_path /data/labeler-output_gen_0.csv
# 	#### process 2: running chexpert labeler over 311 texts ...
# 	Command = docker run -v /home/pamessina/medvqa-workspace/tmp/chexpert-labeler:/data chexpert-labeler:latest python label.py --reports_path /data/labeler-input_gen_1.csv --output_path /data/labeler-output_gen_1.csv
# 	#### process 3: running chexpert labeler over 311 texts ...
# 	Command = docker run -v /home/pamessina/medvqa-workspace/tmp/chexpert-labeler:/data chexpert-labeler:latest python label.py --reports_path /data/labeler-input_gen_2.csv --output_path /data/labeler-output_gen_2.csv
# 	#### process 4: running chexpert labeler over 311 texts ...
# 	Command = docker run -v /home/pamessina/medvqa-workspace/tmp/chexpert-labeler:/data chexpert-labeler:latest python label.py --reports_path /data/labeler-input_gen_3.csv --output_path /data/labeler-output_gen_3.csv
# 	#### process 5: running chexpert labeler over 311 texts ...
# 	Command = docker run -v /home/pamessina/medvqa-workspace/tmp/chexpert-labeler:/data chexpert-labeler:latest python label.py --reports_path /data/labeler-input_gen_4.csv --output_path /data/labeler-output_gen_4.csv
# 	#### process 6: running chexpert labeler over 311 texts ...
# 	Command = docker run -v /home/pamessina/medvqa-workspace/tmp/chexpert-labeler:/data chexpert-labeler:latest python label.py --reports_path /data/labeler-input_gen_5.csv --output_path /data/labeler-output_gen_5.csv
# 	#### process 7: running chexpert labeler over 311 texts ...
# 	Command = docker run -v /home/pamessina/medvqa-workspace/tmp/chexpert-labeler:/data chexpert-labeler:latest python label.py --reports_path /data/labeler-input_gen_6.csv --output_path /data/labeler-output_gen_6.csv
# 	#### process 8: running chexpert labeler over 311 texts ...
# 	Command = docker run -v /home/pamessina/medvqa-workspace/tmp/chexpert-labeler:/data chexpert-labeler:latest python label.py --reports_path /data/labeler-input_gen_7.csv --output_path /data/labeler-output_gen_7.csv
# 	#### process 9: running chexpert labeler over 311 texts ...
# 	Command = docker run -v /home/pamessina/medvqa-workspace/tmp/chexpert-labeler:/data chexpert-labeler:latest python label.py --reports_path /data/labeler-input_gen_8.csv --output_path /data/labeler-output_gen_8.csv
# 	#### process 10: running chexpert labeler over 308 texts ...
# 	Command = docker run -v /home/pamessina/medvqa-workspace/tmp/chexpert-labeler:/data chexpert-labeler:latest python label.py --reports_path /data/labeler-input_gen_9.csv --output_path /data/labeler-output_gen_9.csv
# Generating LALR tables
# Downloading 'http://search.maven.org/remotecontent?filepath=edu/stanford/nlp/stanford-corenlp/3.5.2/stanford-corenlp-3.5.2.jar' -> '/root/.local/share/pystanforddeps/stanford-corenlp-3.5.2.jar'
# Downloading 'http://search.maven.org/remotecontent?filepath=edu/stanford/nlp/stanford-corenlp/3.5.2/stanford-corenlp-3.5.2.jar' -> '/root/.local/share/pystanforddeps/stanford-corenlp-3.5.2.jar'
# Generating LALR tables
# Generating LALR tables
# Downloading 'http://search.maven.org/remotecontent?filepath=edu/stanford/nlp/stanford-corenlp/3.5.2/stanford-corenlp-3.5.2.jar' -> '/root/.local/share/pystanforddeps/stanford-corenlp-3.5.2.jar'
# Generating LALR tables
# Downloading 'http://search.maven.org/remotecontent?filepath=edu/stanford/nlp/stanford-corenlp/3.5.2/stanford-corenlp-3.5.2.jar' -> '/root/.local/share/pystanforddeps/stanford-corenlp-3.5.2.jar'
# Generating LALR tables
# Downloading 'http://search.maven.org/remotecontent?filepath=edu/stanford/nlp/stanford-corenlp/3.5.2/stanford-corenlp-3.5.2.jar' -> '/root/.local/share/pystanforddeps/stanford-corenlp-3.5.2.jar'
# Generating LALR tables
# Downloading 'http://search.maven.org/remotecontent?filepath=edu/stanford/nlp/stanford-corenlp/3.5.2/stanford-corenlp-3.5.2.jar' -> '/root/.local/share/pystanforddeps/stanford-corenlp-3.5.2.jar'
# Downloading 'http://search.maven.org/remotecontent?filepath=edu/stanford/nlp/stanford-corenlp/3.5.2/stanford-corenlp-3.5.2.jar' -> '/root/.local/share/pystanforddeps/stanford-corenlp-3.5.2.jar'
# Generating LALR tables
# Generating LALR tables
# Downloading 'http://search.maven.org/remotecontent?filepath=edu/stanford/nlp/stanford-corenlp/3.5.2/stanford-corenlp-3.5.2.jar' -> '/root/.local/share/pystanforddeps/stanford-corenlp-3.5.2.jar'
# Generating LALR tables
# Downloading 'http://search.maven.org/remotecontent?filepath=edu/stanford/nlp/stanford-corenlp/3.5.2/stanford-corenlp-3.5.2.jar' -> '/root/.local/share/pystanforddeps/stanford-corenlp-3.5.2.jar'
# 	**** process 1 finished, elapsed time = 287.9027419090271
# 	**** process 2 finished, elapsed time = 287.9029152393341
# Downloading 'http://search.maven.org/remotecontent?filepath=edu/stanford/nlp/stanford-corenlp/3.5.2/stanford-corenlp-3.5.2.jar' -> '/root/.local/share/pystanforddeps/stanford-corenlp-3.5.2.jar'
# Generating LALR tables
# 	**** process 3 finished, elapsed time = 289.596581697464
# 	**** process 4 finished, elapsed time = 289.5967321395874
# 	**** process 5 finished, elapsed time = 289.5968134403229
# 	**** process 6 finished, elapsed time = 289.59688425064087
# 	**** process 7 finished, elapsed time = 289.59695839881897
# 	**** process 8 finished, elapsed time = 289.59704303741455
# 	**** process 9 finished, elapsed time = 289.59711384773254
# 	**** process 10 finished, elapsed time = 289.59718441963196
# Cache successfully updated and saved to /home/pamessina/medvqa-workspace/cache/chexpert_labeler_cache.pkl
# Report-level metrics successfully saved to /home/pamessina/medvqa-workspace/results/vqa/20220626_123045_mimiccxr+iuxray_oevqa(densenet121+bilstm+lstm)_voc-minf=5_model-args=(densenet-121,128,None,512,2,128,1024,0,qenc=one-hot,pretrained)_cnn-pretr=0_dataset_weights=0.83,0.07_medtok=1_tags=0_orien=0_chx=0_ql=0_use_amp/mimiccxr_report_level_metrics(eval_mode=ground-truth).pkl

# %%
from medvqa.evaluation.report_generation import get_report_level_metrics_dataframe
from medvqa.utils.files import load_pickle

# %% [markdown]
# ### MIMIC-CXR metrics

# %%
mimiccxr_report_metrics = load_pickle('/home/pamessina/medvqa-workspace/results/vqa/20220626_123045_mimiccxr+iuxray_oevqa(densenet121+bilstm+lstm)_voc-minf=5_model-args=(densenet-121,128,None,512,2,128,1024,0,qenc=one-hot,pretrained)_cnn-pretr=0_dataset_weights=0.83,0.07_medtok=1_tags=0_orien=0_chx=0_ql=0_use_amp/mimiccxr_report_level_metrics(eval_mode=ground-truth).pkl')
mimiccxr_report_level_df = get_report_level_metrics_dataframe(mimiccxr_report_metrics, 'gt')
mimiccxr_report_level_df[mimiccxr_report_level_df.columns[:20]]
# Out:
# 1it [00:00,  1.03it/s]
#   method_name        b1        b2        b3        b4        cD      rg-L  \
# 0          gt  0.304718  0.178233  0.101774  0.056504  0.129922  0.219189
#
#         met     mdcmp    wmdcmp  chxlabf1(hard)  p(micro)  r(micro)  \
# 0  0.238176  0.168203  0.148884        0.657358  0.633653  0.810765
#
#    f1(micro)  p(macro)  r(macro)  f1(macro)       acc     p(NF)     p(EC)
# 0    0.71135  0.569115  0.691977   0.614878  0.840731  0.508197  0.580442
