# %%
# %env CUDA_VISIBLE_DEVICES=0
# Out:
# env: CUDA_VISIBLE_DEVICES=0

# %%
from medvqa.utils.files import load_pickle
from medvqa.evaluation.plots import plot_metrics, visualize_image_and_polygons
from medvqa.datasets.chexlocalize import CHEXLOCALIZE_CLASS_NAMES, extract_images_segmentation_masks_and_binary_labels
import numpy as np
import medvqa
from importlib import reload

# %%
reload(medvqa.evaluation.plots)
# Out:
# <module 'medvqa.evaluation.plots' from '/home/pamessina/medvqa/medvqa/evaluation/plots.py'>

# %% [markdown]
# # 1) Phrase Grounding: DenseNet121 + CXRFE + Sigmoid-based attention

# %%
# !python ../eval_phrase_grounding.py \
--checkpoint_folder_path "/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240618_175951_mscxr+chst-img-anat+vinbig+chexloc_PhraseGrounder(dn121,SigmoidAttention,128,256,256,1)" \
--max_images_per_batch 100 \
--max_phrases_per_batch 2000 \
--max_phrases_per_image 30 \
--eval_chexlocalize
# Out:
# script's arguments:
#    checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240618_175951_mscxr+chst-img-anat+vinbig+chexloc_PhraseGrounder(dn121,SigmoidAttention,128,256,256,1)
#    max_images_per_batch: 100
#    max_phrases_per_batch: 2000
#    max_phrases_per_image: 30
#    num_workers: 0
#    device: GPU
#    mscxr_phrase2embedding_filepath: None
#    eval_chest_imagenome_gold: False
#    eval_mscxr: False
#    eval_chexlocalize: True
# ----- Evaluating model -----
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240618_175951_mscxr+chst-img-anat+vinbig+chexloc_PhraseGrounder(dn121,SigmoidAttention,128,256,256,1)/metadata.json
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Creating instance of PhraseGrounder ...
# WARNING: Unused kwargs: {'pretrained_checkpoint_folder_path': '/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240505_224220_mim-facts+vinbig+chexloc+chxp_PhraseGrounder(dn121,128,256)/', 'pretrained_checkpoint_folder_paths': None}
# MultiPurposeVisualModule()
#   Initializing raw_image_encoder: densenet-121
# create_densenet121_feature_extractor()
#    drop_rate: 0.0
# DenseNet121's pretrained weights loaded from ImageNet
#   self.global_feat_size = 2048
#   self.local_feat_size = 1024
#   Initializing auxiliary tasks
# checkpoint_names = ['checkpoint_100_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.7635.pt', 'checkpoint_196_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.7787.pt']
# --------------------------------------------------
# 3) Loading model from checkpoint ...
# checkpoint_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240618_175951_mscxr+chst-img-anat+vinbig+chexloc_PhraseGrounder(dn121,SigmoidAttention,128,256,256,1)/checkpoint_196_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.7787.pt
# Loading model and epoch only
# Checkpoint successfully loaded!
# --------------------------------------------------
# 4) Creating CheXlocalize Phrase Grounding Trainer ...
# get_image_transform()
# Using standard transform
# mean = (0.485, 0.456, 0.406), std = (0.229, 0.224, 0.225), image_size = [416, 416], use_center_crop = False
# Returning transform without augmentation
# Loding class_phrase_embeddings_filepath and bbox_phrases from /mnt/workspace/pamessina/medvqa-workspace/cache/chexlocalize/class_phrase_embeddings(hash=528,1823213522699794899).pkl...
# class_phrase_embeddings.shape = (10, 128)
# len(class_phrases) = 10
# 	 enlarged cardiomediastinum seen
# 	 cardiomegaly seen
# 	 lung lesion seen
# 	 airspace opacity seen
# 	 edema seen
# 	 consolidation seen
# 	 atelectasis seen
# 	 pneumothorax seen
# 	 pleural effusion seen
# 	 support devices seen
# Compute phrase grounding masks and labels
# Without masks: 216/902
# Generating val dataset and dataloader
# len(val_indices) = 902
# batch_size = 100
# --------------------------------------------------
# 5) ----- Evaluating on CheXlocalize Phrase Grounding -----
# Creating evaluation engine ...
# binary_loss_kwargs: {'focal_weight': 1.0, 'bce_weight': 1.0, 'wbce_weight': 1.0}
# Focal_BCE_WBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 wbce_weight = 0.3333333333333333
# Focal_BCE_Loss(): focal_weight = 0.5 bce_weight = 0.5
# Focal_BCE_WBCBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 wbcbce_weight = 0.3333333333333333
# foreground_loss_weight: 1.0
# background_loss_weight: 1.0
# Defining log_metrics_handler ...
# Running engine ...
# segmask_iou 0.23713, classif_acc 0.99867, 9.62 secs
# Final metrics:
# segmask_iou: [0.34544925079544053, 0.2031554045831427, 0.021545607604007783, 0.4079099114024962, 0.14522603372680631, 0.2694007412174269, 0.4197284026768364, 0.08838255078160719, 0.24560468151200907, 0.2249142335166666]
# classif_acc: 0.998669623059867
#   PRC-AUC(Enlarged Cardiomediastinum): 1.0
#   PRC-AUC(Cardiomegaly): 1.0
#   PRC-AUC(Lung Lesion): 1.0
#   PRC-AUC(Airspace Opacity): 1.0
#   PRC-AUC(Edema): 1.0
#   PRC-AUC(Consolidation): 0.9999999999999998
#   PRC-AUC(Atelectasis): 0.9999999999999999
#   PRC-AUC(Pneumothorax): 1.0000000000000002
#   PRC-AUC(Pleural Effusion): 1.0000000000000002
#   PRC-AUC(Support Devices): 1.0
# PRC-AUC(macro_avg): 1.0
# PRC-AUC(micro_avg): 0.9999882134283687
# Saving metrics to file ...
# mean_iou = 0.6067651675105332
# Saved metrics to /mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20240618_175951_mscxr+chst-img-anat+vinbig+chexloc_PhraseGrounder(dn121,SigmoidAttention,128,256,256,1)/chexlocalize_metrics.pkl

# %%
tmp1 = load_pickle('/mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20240618_175951_mscxr+chst-img-anat+vinbig+chexloc_PhraseGrounder(dn121,SigmoidAttention,128,256,256,1)/chexlocalize_metrics.pkl')

# %%
tmp = tmp1

# %%
tmp.keys()
# Out:
# dict_keys(['image_paths', 'phrases', 'pred_masks', 'gt_masks', 'ious', 'segmask_iou', 'classif_acc', 'prc_auc'])

# %%
from medvqa.datasets.chexlocalize import CHEXLOCALIZE_CLASS_NAME2PHRASE

chexlocalize_phrases = list(CHEXLOCALIZE_CLASS_NAME2PHRASE.values())
phrase2idxs = { x:[] for x in chexlocalize_phrases }
for idx, phrase in enumerate(tmp['phrases']):
    phrase2idxs[phrase].append(idx)

phrase2mean_iou = {}
for phrase, idxs in phrase2idxs.items():
    phrase2mean_iou[phrase] = np.mean([tmp['ious'][idx] for idx in idxs])

plot_metrics(
    metric_names=[f'{name} ({len(phrase2idxs[name])})' for name in chexlocalize_phrases],
    metric_values=[phrase2mean_iou[phrase] for phrase in chexlocalize_phrases],
    title='Mean IOU per class - CheXlocalize',
    ylabel='Class',
    xlabel='Mean IOU',
    horizontal=True,
    sort_metrics=True,
    show_metrics_above_bars=True,
    draw_grid=True,
    figsize=(12, 8),
    append_average_to_title=True,
)

# %%
from medvqa.evaluation.plots import visualize_attention_maps

# %%
idxs = np.argsort(tmp['ious'])[::-1]

# %%
# idx = idxs[-200]
idx = idxs[0]
print(tmp['ious'][idx])
print()
print(tmp['image_paths'][idx])
print()
print(tmp['phrases'][idx])
# Out:
# 0.9133356912897177
#
# /mnt/workspace/CheXlocalize/CheXpert_512x512/test/patient65031/study1/view1_frontal.jpg
#
# airspace opacity seen

# %%
image_paths, masks, labels, polygons, polygon_names = extract_images_segmentation_masks_and_binary_labels(13, 13, return_polygons=True)
# Out:
# Without masks: 216/902

# %%
i = image_paths.index(tmp['image_paths'][idx])
print(image_paths[i])
visualize_image_and_polygons(
    image_path=image_paths[i],
    polygons_list=polygons[i],
    polygon_names=polygon_names[i],
    figsize=(10, 10),
    as_segmentation=True,
#     mask_resolution=(100, 100),
)
# Out:
# /mnt/workspace/CheXlocalize/CheXpert_512x512/test/patient65031/study1/view1_frontal.jpg

# %%
visualize_attention_maps(
    image_path=tmp['image_paths'][idx],
    figsize=(10,10),
    attention_factor=0.5,
    attention_maps=[
        tmp['gt_masks'][idx].reshape(13,13),
        tmp['pred_masks'][idx].reshape(13,13),
    ],
    titles=[
        f"{tmp['phrases'][idx]} (gt)",
        f"{tmp['phrases'][idx]} (pred)",
    ],
)

# %% [markdown]
# # 2) Phrase Grounding: DenseNet121 + CXRFE + Transformer Encoder

# %%
# !python ../eval_phrase_grounding.py \
--checkpoint_folder_path "/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240618_093614_mscxr+chst-img-anat+vinbig+chexloc_PhraseGrounder(dn121,TransformerEncoder,128,256,4,512,3)" \
--max_images_per_batch 100 \
--max_phrases_per_batch 2000 \
--max_phrases_per_image 30 \
--eval_chexlocalize
# Out:
# script's arguments:
#    checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240618_093614_mscxr+chst-img-anat+vinbig+chexloc_PhraseGrounder(dn121,TransformerEncoder,128,256,4,512,3)
#    max_images_per_batch: 100
#    max_phrases_per_batch: 2000
#    max_phrases_per_image: 30
#    num_workers: 0
#    device: GPU
#    mscxr_phrase2embedding_filepath: None
#    eval_chest_imagenome_gold: False
#    eval_mscxr: False
#    eval_chexlocalize: True
# ----- Evaluating model -----
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240618_093614_mscxr+chst-img-anat+vinbig+chexloc_PhraseGrounder(dn121,TransformerEncoder,128,256,4,512,3)/metadata.json
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Creating instance of PhraseGrounder ...
# WARNING: Unused kwargs: {'pretrained_checkpoint_folder_path': '/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240505_224220_mim-facts+vinbig+chexloc+chxp_PhraseGrounder(dn121,128,256)/', 'pretrained_checkpoint_folder_paths': None}
# MultiPurposeVisualModule()
#   Initializing raw_image_encoder: densenet-121
# create_densenet121_feature_extractor()
#    drop_rate: 0.0
# DenseNet121's pretrained weights loaded from ImageNet
#   self.global_feat_size = 2048
#   self.local_feat_size = 1024
#   Initializing auxiliary tasks
# checkpoint_names = ['checkpoint_152_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.6493.pt', 'checkpoint_99_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.6363.pt']
# --------------------------------------------------
# 3) Loading model from checkpoint ...
# checkpoint_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240618_093614_mscxr+chst-img-anat+vinbig+chexloc_PhraseGrounder(dn121,TransformerEncoder,128,256,4,512,3)/checkpoint_152_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.6493.pt
# Loading model and epoch only
# Checkpoint successfully loaded!
# --------------------------------------------------
# 4) Creating CheXlocalize Phrase Grounding Trainer ...
# get_image_transform()
# Using standard transform
# mean = (0.485, 0.456, 0.406), std = (0.229, 0.224, 0.225), image_size = [416, 416], use_center_crop = False
# Returning transform without augmentation
# Loding class_phrase_embeddings_filepath and bbox_phrases from /mnt/workspace/pamessina/medvqa-workspace/cache/chexlocalize/class_phrase_embeddings(hash=528,1823213522699794899).pkl...
# class_phrase_embeddings.shape = (10, 128)
# len(class_phrases) = 10
# 	 enlarged cardiomediastinum seen
# 	 cardiomegaly seen
# 	 lung lesion seen
# 	 airspace opacity seen
# 	 edema seen
# 	 consolidation seen
# 	 atelectasis seen
# 	 pneumothorax seen
# 	 pleural effusion seen
# 	 support devices seen
# Compute phrase grounding masks and labels
# Without masks: 216/902
# Generating val dataset and dataloader
# len(val_indices) = 902
# batch_size = 100
# --------------------------------------------------
# 5) ----- Evaluating on CheXlocalize Phrase Grounding -----
# Creating evaluation engine ...
# binary_loss_kwargs: {'focal_weight': 1.0, 'bce_weight': 1.0, 'wbce_weight': 1.0}
# Focal_BCE_WBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 wbce_weight = 0.3333333333333333
# Focal_BCE_Loss(): focal_weight = 0.5 bce_weight = 0.5
# Focal_BCE_WBCBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 wbcbce_weight = 0.3333333333333333
# foreground_loss_weight: 1.0
# background_loss_weight: 1.0
# Defining log_metrics_handler ...
# Running engine ...
# segmask_iou 0.11761, classif_acc 0.88958, 10.12 secs
# Final metrics:
# segmask_iou: [0.2552964964641949, 0.16318033325668935, 0.0314701421199346, 0.2099741036431746, 0.10239380661586585, 0.06098890727701989, 0.14358768587189105, 0.03182269790645591, 0.07239073739217776, 0.1050338529685536]
# classif_acc: 0.8895787139689578
#   PRC-AUC(Enlarged Cardiomediastinum): 0.9558380717656433
#   PRC-AUC(Cardiomegaly): 0.924762702855935
#   PRC-AUC(Lung Lesion): 0.21263287373406817
#   PRC-AUC(Airspace Opacity): 0.9622513833612847
#   PRC-AUC(Edema): 0.7716280043300945
#   PRC-AUC(Consolidation): 0.5252617292868633
#   PRC-AUC(Atelectasis): 0.7254446636310152
#   PRC-AUC(Pneumothorax): 0.5948962582082105
#   PRC-AUC(Pleural Effusion): 0.7266142419948944
#   PRC-AUC(Support Devices): 0.8591791149647301
# PRC-AUC(macro_avg): 0.725850904413274
# PRC-AUC(micro_avg): 0.8546809145480018
# Saving metrics to file ...
# mean_iou = 0.3821208841026148
# Saved metrics to /mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20240618_093614_mscxr+chst-img-anat+vinbig+chexloc_PhraseGrounder(dn121,TransformerEncoder,128,256,4,512,3)/chexlocalize_metrics.pkl

# %%
tmp2 = load_pickle('/mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20240618_093614_mscxr+chst-img-anat+vinbig+chexloc_PhraseGrounder(dn121,TransformerEncoder,128,256,4,512,3)/chexlocalize_metrics.pkl')

# %%
tmp = tmp2

# %%
tmp.keys()
# Out:
# dict_keys(['image_paths', 'phrases', 'pred_masks', 'gt_masks', 'ious', 'segmask_iou', 'classif_acc', 'prc_auc'])

# %%
from medvqa.datasets.chexlocalize import CHEXLOCALIZE_CLASS_NAME2PHRASE

chexlocalize_phrases = list(CHEXLOCALIZE_CLASS_NAME2PHRASE.values())
phrase2idxs = { x:[] for x in chexlocalize_phrases }
for idx, phrase in enumerate(tmp['phrases']):
    phrase2idxs[phrase].append(idx)

phrase2mean_iou = {}
for phrase, idxs in phrase2idxs.items():
    phrase2mean_iou[phrase] = np.mean([tmp['ious'][idx] for idx in idxs])

plot_metrics(
    metric_names=[f'{name} ({len(phrase2idxs[name])})' for name in chexlocalize_phrases],
    metric_values=[phrase2mean_iou[phrase] for phrase in chexlocalize_phrases],
    title='Mean IOU per class - CheXlocalize',
    ylabel='Class',
    xlabel='Mean IOU',
    horizontal=True,
    sort_metrics=True,
    show_metrics_above_bars=True,
    draw_grid=True,
    figsize=(12, 8),
    append_average_to_title=True,
)

# %%
idxs = np.argsort(tmp['ious'])[::-1]

# %%
idx = idxs[0]
print(tmp['ious'][idx])
print()
print(tmp['image_paths'][idx])
print()
print(tmp['phrases'][idx])
# Out:
# 0.8287440009622546
#
# /mnt/workspace/CheXlocalize/CheXpert_512x512/val/patient64739/study1/view1_frontal.jpg
#
# enlarged cardiomediastinum seen

# %%
i = image_paths.index(tmp['image_paths'][idx])
print(image_paths[i])
visualize_image_and_polygons(
    image_path=image_paths[i],
    polygons_list=polygons[i],
    polygon_names=polygon_names[i],
    figsize=(10, 10),
    as_segmentation=True,
#     mask_resolution=(100, 100),
)
# Out:
# /mnt/workspace/CheXlocalize/CheXpert_512x512/val/patient64739/study1/view1_frontal.jpg

# %%
visualize_attention_maps(
    image_path=tmp['image_paths'][idx],
    figsize=(10,10),
    attention_factor=0.5,
    attention_maps=[
        tmp['gt_masks'][idx].reshape(13,13),
        tmp['pred_masks'][idx].reshape(13,13),
    ],
    titles=[
        f"{tmp['phrases'][idx]} (gt)",
        f"{tmp['phrases'][idx]} (pred)",
    ],
)

# %% [markdown]
# # 3) Phrase Grounding: DenseNet121 + CXRFE + FiLM-based attention

# %%
# !python ../eval_phrase_grounding.py \
--checkpoint_folder_path "/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240705_131322_mscxr+chst-img-anat+vinbig+chexloc_PhraseGrounder(dn121,FiLM_SigmoidAttention,128,256,256,256,1,256-128)" \
--max_images_per_batch 100 \
--max_phrases_per_batch 2000 \
--max_phrases_per_image 30 \
--eval_chexlocalize
# Out:
# script's arguments:
#    checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240705_131322_mscxr+chst-img-anat+vinbig+chexloc_PhraseGrounder(dn121,FiLM_SigmoidAttention,128,256,256,256,1,256-128)
#    max_images_per_batch: 100
#    max_phrases_per_batch: 2000
#    max_phrases_per_image: 30
#    num_workers: 0
#    device: GPU
#    mscxr_phrase2embedding_filepath: None
#    eval_chest_imagenome_gold: False
#    eval_mscxr: False
#    eval_chexlocalize: True
#    eval_vinbig: False
# ----- Evaluating model -----
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240705_131322_mscxr+chst-img-anat+vinbig+chexloc_PhraseGrounder(dn121,FiLM_SigmoidAttention,128,256,256,256,1,256-128)/metadata.json
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Creating instance of PhraseGrounder ...
# WARNING: Unused kwargs: {'pretrained_checkpoint_folder_path': '/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240705_093632_mscxr+chst-img-anat+vinbig+chexloc_PhraseGrounder(dn121,FiLM_SigmoidAttention,128,256,256,256,1,256-128)', 'pretrained_checkpoint_folder_paths': None}
# MultiPurposeVisualModule()
#   Initializing raw_image_encoder: densenet-121
# create_densenet121_feature_extractor()
#    drop_rate: 0.0
# DenseNet121's pretrained weights loaded from ImageNet
#   self.global_feat_size = 2048
#   self.local_feat_size = 1024
#   Initializing auxiliary tasks
# Using positional encoding for local features
# checkpoint_names = ['checkpoint_98_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.7372.pt']
# --------------------------------------------------
# 3) Loading model from checkpoint ...
# checkpoint_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20240705_131322_mscxr+chst-img-anat+vinbig+chexloc_PhraseGrounder(dn121,FiLM_SigmoidAttention,128,256,256,256,1,256-128)/checkpoint_98_ciss+ciou+clss+clcc+clou+pgss+pgou+vbss+vbuc+vbou=0.7372.pt
# Loading model and epoch only
# Checkpoint successfully loaded!
# --------------------------------------------------
# 4) Creating CheXlocalize Phrase Grounding Trainer ...
# get_image_transform()
# Using standard transform
# mean = (0.485, 0.456, 0.406), std = (0.229, 0.224, 0.225), image_size = [416, 416], use_center_crop = False
# Returning transform without augmentation
# Loding class_phrase_embeddings_filepath and bbox_phrases from /mnt/workspace/pamessina/medvqa-workspace/cache/chexlocalize/class_phrase_embeddings(hash=528,2353352898845085012).pkl...
# class_phrase_embeddings.shape = (10, 128)
# len(class_phrases) = 10
# 	 enlarged cardiomediastinum seen
# 	 cardiomegaly seen
# 	 lung lesion seen
# 	 airspace opacity seen
# 	 edema seen
# 	 consolidation seen
# 	 atelectasis seen
# 	 pneumothorax seen
# 	 pleural effusion seen
# 	 support devices seen
# Compute phrase grounding masks and labels
# Without masks: 216/902
# Generating val dataset and dataloader
# len(val_indices) = 902
# batch_size = 100
# --------------------------------------------------
# 5) ----- Evaluating on CheXlocalize Phrase Grounding -----
# Creating evaluation engine ...
# binary_loss_kwargs: {'focal_weight': 1.0, 'bce_weight': 1.0, 'wbce_weight': 1.0}
# Focal_BCE_WBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 wbce_weight = 0.3333333333333333
# Focal_BCE_Loss(): focal_weight = 0.5 bce_weight = 0.5
# Focal_BCE_WBCBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 wbcbce_weight = 0.3333333333333333
# foreground_loss_weight: 1.0
# background_loss_weight: 1.0
# Defining log_metrics_handler ...
# Running engine ...
# segmask_iou 0.25040, classif_acc 0.99313, 9.76 secs
# Final metrics:
# segmask_iou: [0.3259169194522219, 0.1864988070819159, 0.30383859294019183, 0.24556618981306386, 0.21397348710803982, 0.453889813917486, 0.3585538813871409, 0.10958643334927443, 0.11306503403492019, 0.19306670848278837]
# classif_acc: 0.9931263858093127
#   PRC-AUC(Enlarged Cardiomediastinum): 0.9999879113722927
#   PRC-AUC(Cardiomegaly): 0.9999323270507029
#   PRC-AUC(Lung Lesion): 1.0
#   PRC-AUC(Airspace Opacity): 1.0
#   PRC-AUC(Edema): 0.99987934183065
#   PRC-AUC(Consolidation): 0.99827109874895
#   PRC-AUC(Atelectasis): 0.9977955681564543
#   PRC-AUC(Pneumothorax): 0.9841203703703705
#   PRC-AUC(Pleural Effusion): 0.9996829520140117
#   PRC-AUC(Support Devices): 0.9995998961099178
# PRC-AUC(macro_avg): 0.9979269465653351
# PRC-AUC(micro_avg): 0.9992904269838097
# Saving metrics to file ...
# mean_iou = 0.5546937035119306
# Saved metrics to /mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20240705_131322_mscxr+chst-img-anat+vinbig+chexloc_PhraseGrounder(dn121,FiLM_SigmoidAttention,128,256,256,256,1,256-128)/chexlocalize_metrics.pkl

# %%
tmp3 = load_pickle('/mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20240705_131322_mscxr+chst-img-anat+vinbig+chexloc_PhraseGrounder(dn121,FiLM_SigmoidAttention,128,256,256,256,1,256-128)/chexlocalize_metrics.pkl')

# %%
tmp = tmp3

# %%
tmp.keys()
# Out:
# dict_keys(['image_paths', 'phrases', 'pred_masks', 'gt_masks', 'ious', 'segmask_iou', 'classif_acc', 'prc_auc'])

# %%
from medvqa.datasets.chexlocalize import CHEXLOCALIZE_CLASS_NAME2PHRASE

chexlocalize_phrases = list(CHEXLOCALIZE_CLASS_NAME2PHRASE.values())
phrase2idxs = { x:[] for x in chexlocalize_phrases }
for idx, phrase in enumerate(tmp['phrases']):
    phrase2idxs[phrase].append(idx)

phrase2mean_iou = {}
for phrase, idxs in phrase2idxs.items():
    phrase2mean_iou[phrase] = np.mean([tmp['ious'][idx] for idx in idxs])

plot_metrics(
    metric_names=[f'{name} ({len(phrase2idxs[name])})' for name in chexlocalize_phrases],
    metric_values=[phrase2mean_iou[phrase] for phrase in chexlocalize_phrases],
    title='Mean IOU per class - CheXlocalize',
    ylabel='Class',
    xlabel='Mean IOU',
    horizontal=True,
    sort_metrics=True,
    show_metrics_above_bars=True,
    draw_grid=True,
    figsize=(12, 8),
    append_average_to_title=True,
)

# %%
idxs = np.argsort(tmp['ious'])[::-1]

# %%
idx = idxs[-1]
print(tmp['ious'][idx])
print()
print(tmp['image_paths'][idx])
print()
print(tmp['phrases'][idx])
# Out:
# 0.0008611820529855559
#
# /mnt/workspace/CheXlocalize/CheXpert_512x512/val/patient64659/study1/view1_frontal.jpg
#
# pleural effusion seen

# %%
i = image_paths.index(tmp['image_paths'][idx])
print(image_paths[i])
visualize_image_and_polygons(
    image_path=image_paths[i],
    polygons_list=polygons[i],
    polygon_names=polygon_names[i],
    figsize=(10, 10),
    as_segmentation=True,
#     mask_resolution=(100, 100),
)
# Out:
# /mnt/workspace/CheXlocalize/CheXpert_512x512/val/patient64659/study1/view1_frontal.jpg

# %%
visualize_attention_maps(
    image_path=tmp['image_paths'][idx],
    figsize=(10,10),
    attention_factor=0.5,
    attention_maps=[
        tmp['gt_masks'][idx].reshape(13,13),
        tmp['pred_masks'][idx].reshape(13,13),
    ],
    titles=[
        f"{tmp['phrases'][idx]} (gt)",
        f"{tmp['phrases'][idx]} (pred)",
    ],
)
