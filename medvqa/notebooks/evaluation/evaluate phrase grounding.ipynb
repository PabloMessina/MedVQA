# %%
# %env CUDA_VISIBLE_DEVICES=0
# Out:
# env: CUDA_VISIBLE_DEVICES=0

# %%
# --checkpoint_folder_path "/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20231122_141052_chst-img-anat_PhraseGrounder(yolov8l,128,256)" \
# --checkpoint_folder_path "/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20231201_095118_mscxr+chst-img-anat_PhraseGrounder(yolov8l,128,256)" \
# --checkpoint_folder_path "/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20231205_180625_mscxr+chst-img-anat_PhraseGrounder(yolov8l,128,256)" \
# --checkpoint_folder_path "/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20231205_232713_mscxr+chst-img-anat_PhraseGrounder(yolov8l,128,256)" \
# --checkpoint_folder_path "/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20231206_083213_mscxr+chst-img-anat_PhraseGrounder(yolov8l,128,256)" \
# !python ../eval_phrase_grounding.py \
--checkpoint_folder_path "/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20231206_112155_mscxr+chst-img-anat_PhraseGrounder(yolov8l,128,256)" \
--max_images_per_batch 100 \
--max_phrases_per_batch 2000 \
--max_phrases_per_image 30 \
--eval_chest_imagenome_gold
# Out:
# script's arguments:
#    checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20231206_112155_mscxr+chst-img-anat_PhraseGrounder(yolov8l,128,256)
#    max_images_per_batch: 100
#    max_phrases_per_batch: 2000
#    max_phrases_per_image: 30
#    num_workers: 0
#    device: GPU
#    eval_chest_imagenome_gold: True
#    eval_mscxr: False
# ----- Evaluating model -----
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20231206_112155_mscxr+chst-img-anat_PhraseGrounder(yolov8l,128,256)/metadata.json
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Creating instance of PhraseGrounder ...
# ...

# %%
from importlib import reload
import medvqa

# %%
reload(medvqa)
reload(medvqa.evaluation.plots)
# Out:
# <module 'medvqa.evaluation.plots' from '/home/pamessina/medvqa/medvqa/evaluation/plots.py'>

# %%
from medvqa.utils.files import load_pickle
from medvqa.evaluation.plots import plot_metrics
from medvqa.datasets.chest_imagenome import CHEST_IMAGENOME_GOLD_BBOX_NAMES__SORTED

# %%
# metrics = load_pickle('/mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20231122_141052_chst-img-anat_PhraseGrounder(yolov8l,128,256)/chest_imagenome_gold_metrics.pkl')
# metrics = load_pickle("/mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20231201_095118_mscxr+chst-img-anat_PhraseGrounder(yolov8l,128,256)/chest_imagenome_gold_metrics.pkl")
# metrics = load_pickle("/mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20231205_180625_mscxr+chst-img-anat_PhraseGrounder(yolov8l,128,256)/chest_imagenome_gold_metrics.pkl")
# metrics = load_pickle("/mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20231205_232713_mscxr+chst-img-anat_PhraseGrounder(yolov8l,128,256)/chest_imagenome_gold_metrics.pkl")
# metrics = load_pickle("/mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20231206_083213_mscxr+chst-img-anat_PhraseGrounder(yolov8l,128,256)/chest_imagenome_gold_metrics.pkl")
metrics = load_pickle("/mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20231206_112155_mscxr+chst-img-anat_PhraseGrounder(yolov8l,128,256)/chest_imagenome_gold_metrics.pkl")

# %%
metrics.keys()
# Out:
# dict_keys(['chestimagenome_bbox_iou', 'phrase_acc', 'segmask_iou'])

# %%
# %matplotlib inline

# %%
plot_metrics(
    metric_names=CHEST_IMAGENOME_GOLD_BBOX_NAMES__SORTED,
    metric_aliases=CHEST_IMAGENOME_GOLD_BBOX_NAMES__SORTED,
    metric_values=metrics['segmask_iou'],
    title='Chest ImaGenome Gold - Attention Map IoU',
    ylabel='Bbox class',
    xlabel='IOU',
    horizontal=True,
    sort_metrics=True,
    show_metrics_above_bars=True,
    draw_grid=True,
    figsize=(12, 8),
    append_average_to_title=True,
)

# %%
plot_metrics(
    metric_names=CHEST_IMAGENOME_GOLD_BBOX_NAMES__SORTED,
    metric_aliases=CHEST_IMAGENOME_GOLD_BBOX_NAMES__SORTED,
    metric_values=metrics['segmask_iou'],
    title='Chest ImaGenome Gold - Attention Map IoU',
    ylabel='Bbox class',
    xlabel='IOU',
    horizontal=True,
    sort_metrics=True,
    show_metrics_above_bars=True,
    draw_grid=True,
    figsize=(12, 8),
    append_average_to_title=True,
)

# %%
plot_metrics(
    metric_names=CHEST_IMAGENOME_GOLD_BBOX_NAMES__SORTED,
    metric_aliases=CHEST_IMAGENOME_GOLD_BBOX_NAMES__SORTED,
    metric_values=metrics['segmask_iou'],
    title='Chest ImaGenome Gold - Attention Map IoU',
    ylabel='Bbox class',
    xlabel='IOU',
    horizontal=True,
    sort_metrics=True,
    show_metrics_above_bars=True,
    draw_grid=True,
    figsize=(12, 8),
    append_average_to_title=True,
)

# %%
plot_metrics(
    metric_names=CHEST_IMAGENOME_GOLD_BBOX_NAMES__SORTED,
    metric_aliases=CHEST_IMAGENOME_GOLD_BBOX_NAMES__SORTED,
    metric_values=metrics['segmask_iou'],
    title='Segmentation Mask IOU',
    ylabel='Bbox class',
    xlabel='IOU',
    horizontal=True,
    sort_metrics=True,
    show_metrics_above_bars=True,
    draw_grid=True,
    figsize=(12, 8),
    append_average_to_title=True,
)

# %%
plot_metrics(
    metric_names=CHEST_IMAGENOME_GOLD_BBOX_NAMES__SORTED,
    metric_aliases=CHEST_IMAGENOME_GOLD_BBOX_NAMES__SORTED,
    metric_values=metrics['segmask_iou'],
    title='Segmentation Mask IOU',
    ylabel='Bbox class',
    xlabel='IOU',
    horizontal=True,
    sort_metrics=True,
    show_metrics_above_bars=True,
    draw_grid=True,
    figsize=(12, 8),
    append_average_to_title=True,
)

# %%
plot_metrics(
    metric_names=CHEST_IMAGENOME_GOLD_BBOX_NAMES__SORTED,
    metric_aliases=CHEST_IMAGENOME_GOLD_BBOX_NAMES__SORTED,
    metric_values=metrics['segmask_iou'],
    title='Segmentation Mask IOU',
    ylabel='Bbox class',
    xlabel='IOU',
    horizontal=True,
    sort_metrics=True,
)

# %%
from medvqa.utils.files import load_jsonl, list_filepaths_with_prefix_and_timestamps

# %%
list_filepaths_with_prefix_and_timestamps("/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_fact_metadata")
# Out:
# [('/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_fact_metadata(595880,60579117).improved_comparison(6741113).jsonl',
#   '2023-09-10 16:30:58'),
#  ('/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_fact_metadata(595880,60579117).jsonl',
#   '2023-09-09 21:42:49'),
#  ('/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_fact_metadata(578733,58628071).improved_comparison(6526297).jsonl',
#   '2023-07-18 11:46:52'),
#  ('/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_fact_metadata(578733,58628071).improved_comparison(6595181).jsonl',
#   '2023-07-18 00:18:14'),
#  ('/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_fact_metadata(578733,58628071).jsonl',
#   '2023-07-12 14:51:08'),
#  ('/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_fact_metadata(578733,58628252).jsonl',
#   '2023-07-12 14:14:39'),
#  ('/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_fact_metadata(578718,58626719).jsonl',
# ...

# %%
integrated_fact_metadata = load_jsonl('/home/pamessina/medvqa-workspace/cache/mimiccxr/integrated_fact_metadata(595880,60579117).improved_comparison(6741113).jsonl')

# %%
integrated_fact_metadata[0]
# Out:
# {'fact': 'A BENIGN CALCIFICATION IN LUNG OR RIB, OR VESSEL, EITHER ON END OR CROSSING in the right lower lung',
#  'metadata': {'anatomical location': 'right lower lung',
#   'detailed observation': 'benign calcification in lung or rib, or vessel, either on end or crossing',
#   'short observation': 'benign calcification',
#   'category': 'anatomical finding',
#   'health status': 'ambiguous',
#   'prev_study_comparison?': 'no',
#   'comparison status': ''},
#  'extraction_method': 'gpt-3.5-turbo-0613'}

# %%
anatomical_locations = set()
for row in integrated_fact_metadata:
    anatloc = row['metadata']['anatomical location']
    if anatloc:
        anatomical_locations.add(anatloc)
anatomical_locations = list(anatomical_locations)
anatomical_locations.sort()

# %%
len(anatomical_locations)
# Out:
# 28858

# %%
from medvqa.models.huggingface_utils import CachedTextEmbeddingExtractor

# %%
embedding_extractor = CachedTextEmbeddingExtractor(
    model_name='microsoft/BiomedVLP-CXR-BERT-specialized',
    model_checkpoint_folder_path="/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20231018_230637_MIMIC-CXR(triplets+classif+entcont+nli+autoencoder)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)",
    num_workers=2,
    batch_size=200,
)
# Out:
# checkpoint_names = ['checkpoint_91_cacc+chf1+chf1+cscc+encc+hscc+nlcc+sass+ta0)+ta1)+ta2)+ta0)+ta1)+ta2)+ta3)+ta4)+ta5)+ta6)+ta7)=0.9248.pt']

# %%
anatloc_embeddings = embedding_extractor.compute_text_embeddings(anatomical_locations)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████| 28858/28858 [00:00<00:00, 387835.60it/s]

# %%
anatloc_embeddings.shape
# Out:
# (28858, 128)

# %%
from medvqa.utils.math import rank_vectors_by_dot_product

# %%
query = 'aortic arch'
query_idx = anatomical_locations.index(query)
idxs = rank_vectors_by_dot_product(anatloc_embeddings, anatloc_embeddings[query_idx])

print(query)
print('-' * 50)
for i in range(30):
    print(anatomical_locations[idxs[i]])
# Out:
# aortic arch
# --------------------------------------------------
# aortic arch
# aortic arch area
# arch aorta
# aorta arch
# in aortic arch
# aortic arch roof
# aortic arch branches
# arch of aorta
# arch of the aorta
# aortic
# aorto
# aortic bulb
# aorta at arch
# arch
# aorta along the arch
# aortic ring
# aortic arch vessels
# aortic roof
# region of the aortic arch
# area of the aortic arch
# aortic notch
# aortic knot
# ascending aortic arch
# aortic groove
# transverse aortic arch
# roof of aortic arch
# aortic saccular
# aortic isthmus
# ascending aortic
# aortic window

# %%
reload(medvqa.datasets.chest_imagenome.chest_imagenome_dataset_management)
# Out:
# <module 'medvqa.datasets.chest_imagenome.chest_imagenome_dataset_management' from '/home/pamessina/medvqa/medvqa/datasets/chest_imagenome/chest_imagenome_dataset_management.py'>

# %%
from medvqa.datasets.chest_imagenome.chest_imagenome_dataset_management import visualize_ground_truth_bounding_boxes

# %%
visualize_ground_truth_bounding_boxes(
    dicom_id='dabbe740-cc74af46-650d75f1-247e969d-be7fa64a',
    apply_clamping=True,
    bbox_names_to_highlight=['carina', 'aortic arch', 'cavoatrial junction', 'left costophrenic angle'])
# Out:
# Image path: /mnt/data/mimic-cxr-jpg/images/p12/p12298456/s57175681/dabbe740-cc74af46-650d75f1-247e969d-be7fa64a.jpg
# Object: right lung (191.0, 204.0, 1227.0, 2169.0) (valid)
# Object: right upper lung zone (518.0, 272.0, 900.0, 833.0) (valid)
# Object: right mid lung zone (409.0, 1105.0, 914.0, 463.0) (valid)
# Object: right lower lung zone (191.0, 1568.0, 1077.0, 805.0) (valid)
# Object: right hilar structures (859.0, 1009.0, 505.0, 641.0) (valid)
# Object: right apical zone (627.0, 204.0, 791.0, 450.0) (valid)
# Object: right costophrenic angle (54.0, 2155.0, 273.0, 273.0) (valid)
# Object: right cardiophrenic angle (927.0, 2019.0, 178.0, 273.0) (valid)
# Object: right hemidiaphragm (191.0, 2114.0, 1268.0, 259.0) (valid)
# Object: left lung (1555.0, 218.0, 1050.0, 2128.0) (valid)
# Object: left upper lung zone (1555.0, 286.0, 873.0, 819.0) (valid)
# Object: left mid lung zone (1582.0, 1105.0, 873.0, 450.0) (valid)
# ...

# %%
visualize_ground_truth_bounding_boxes(
    apply_clamping=True,
    bbox_names_to_highlight=['carina', 'aortic arch', 'cavoatrial junction', 'left costophrenic angle'])
# Out:
# Image path: /mnt/data/mimic-cxr-jpg/images/p15/p15497447/s54728731/8d149e20-43596014-602f726a-df7a3dc2-bdf440ad.jpg
# Object: right lung (272.0, 300.0, 805.0, 2114.0) (valid)
# Object: right upper lung zone (313.0, 354.0, 751.0, 628.0) (valid)
# Object: right mid lung zone (272.0, 982.0, 805.0, 518.0) (valid)
# Object: right lower lung zone (272.0, 1500.0, 805.0, 914.0) (valid)
# Object: right hilar structures (668.0, 873.0, 409.0, 723.0) (valid)
# Object: right apical zone (409.0, 300.0, 655.0, 395.0) (valid)
# Object: right costophrenic angle (136.0, 2196.0, 273.0, 273.0) (valid)
# Object: right cardiophrenic angle (682.0, 1828.0, 218.0, 286.0) (valid)
# Object: right hemidiaphragm (272.0, 1937.0, 1024.0, 477.0) (valid)
# Object: left lung (1241.0, 218.0, 1064.0, 2183.0) (valid)
# Object: left upper lung zone (1241.0, 286.0, 846.0, 696.0) (valid)
# Object: left mid lung zone (1282.0, 982.0, 887.0, 518.0) (valid)
# ...

# %%
# %run -n ../datasets/ms_cxr/__init__.py

# %%
pgav = PhraseGroundingAnnotationsVisualizer()

# %%
# --checkpoint_folder_path "/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20231122_141052_chst-img-anat_PhraseGrounder(yolov8l,128,256)" \
# --checkpoint_folder_path "/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20231201_095118_mscxr+chst-img-anat_PhraseGrounder(yolov8l,128,256)" \
# --checkpoint_folder_path "/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20231205_232713_mscxr+chst-img-anat_PhraseGrounder(yolov8l,128,256)" \
# !python ../eval_phrase_grounding.py \
--checkpoint_folder_path "/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20231206_112155_mscxr+chst-img-anat_PhraseGrounder(yolov8l,128,256)" \
--max_images_per_batch 100 \
--max_phrases_per_batch 2000 \
--max_phrases_per_image 30 \
--eval_mscxr
# Out:
# script's arguments:
#    checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20231206_112155_mscxr+chst-img-anat_PhraseGrounder(yolov8l,128,256)
#    max_images_per_batch: 100
#    max_phrases_per_batch: 2000
#    max_phrases_per_image: 30
#    num_workers: 0
#    device: GPU
#    eval_chest_imagenome_gold: False
#    eval_mscxr: True
# ----- Evaluating model -----
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20231206_112155_mscxr+chst-img-anat_PhraseGrounder(yolov8l,128,256)/metadata.json
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Creating instance of PhraseGrounder ...
# ...

# %%
# tmp = load_pickle('/mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20231201_095118_mscxr+chst-img-anat_PhraseGrounder(yolov8l,128,256)/mscxr_metrics.pkl')
# tmp = load_pickle('/mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20231205_232713_mscxr+chst-img-anat_PhraseGrounder(yolov8l,128,256)/mscxr_metrics.pkl')
tmp = load_pickle('/mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20231206_112155_mscxr+chst-img-anat_PhraseGrounder(yolov8l,128,256)/mscxr_metrics.pkl')

# %%
tmp.keys()
# Out:
# dict_keys(['image_paths', 'phrases', 'pred_masks', 'gt_masks', 'ious', 'pg_segmask_iou'])

# %%
import numpy as np

# %%
idxs = np.argsort(tmp['ious'])[::-1]

# %%
for i in range(50):
    print(tmp['ious'][idxs[i]], tmp['phrases'][idxs[i]])
# Out:
# 0.9866828918457031 cardiac silhouette is enlarged
# 0.9865643978118896 cardiac silhouette is enlarged
# 0.9853097200393677 cardiac silhouette is enlarged
# 0.9812071323394775 cardiac silhouette is enlarged
# 0.9809903502464294 enlarged cardiac silhouette
# 0.9807764291763306 cardiac silhouette enlarged
# 0.9802067875862122 enlarged cardiac silhouette
# 0.980191707611084 cardiac silhouette enlarged
# 0.9800922274589539 mild cardiomegaly
# 0.9799005389213562 cardiac silhouette is enlarged
# 0.9798660278320312 cardiac silhouette enlarged
# 0.9795817732810974 mild cardiomegaly
# 0.9793705344200134 cardiac silhouette is enlarged
# 0.9790433049201965 enlarged cardiac silhouette
# 0.9779139757156372 cardiac silhouette is enlarged
# 0.9775183200836182 cardiac silhouette is markedly enlarged
# 0.9773622751235962 cardiac silhouette is markedly enlarged
# 0.9773356914520264 enlarged cardiac silhouette
# 0.9770265221595764 moderate cardiomegaly
# 0.9767967462539673 mild cardiomegaly is present
# ...

# %%
i = -100
print(tmp['ious'][idxs[i]])
print()
print(tmp['image_paths'][idxs[i]])
print()
print(tmp['phrases'][idxs[i]])

dicom_id = tmp['image_paths'][idxs[i]].split('/')[-1].split('.')[0]
# Out:
# 0.5030443072319031
#
# /mnt/workspace/mimic-cxr-jpg/images-medium(512)/p10/p10623425/s51875181/5da15491-389464db-4c8172ca-55a0b1b2-2459a2be.jpg
#
# parenchymal opacity at the left lung base

# %%
pgav.visualize_dicom_id(dicom_id)
# Out:
# Found 1 rows for dicom_id 5da15491-389464db-4c8172ca-55a0b1b2-2459a2be
# Image path: /mnt/data/mimic-cxr-jpg/images/p10/p10623425/s51875181/5da15491-389464db-4c8172ca-55a0b1b2-2459a2be.jpg
# Label text: parenchymal opacity at the left lung base
# Category name: Pneumonia
# x: 1616, y: 1662, w: 692, h: 659

# %%
# %run -n ../evaluation/plots.py

# %%
visualize_attention_maps(
    image_path=tmp['image_paths'][idxs[i]],
    figsize=(10,10),
    attention_factor=0.5,
    attention_maps=[
        tmp['gt_masks'][idxs[i]].reshape(13,13),
        tmp['pred_masks'][idxs[i]].reshape(13,13),
    ],
    titles=[
        f"{tmp['phrases'][idxs[i]]} (gt)",
        f"{tmp['phrases'][idxs[i]]} (pred)",
    ],
)
