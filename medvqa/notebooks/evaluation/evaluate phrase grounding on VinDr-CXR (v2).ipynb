# %%
from medvqa.evaluation.phrase_grounding_visualization import PhraseGroundingResultsVisualizer

# %%
experiment_results = [
    # FG-VLM (AEHRC-CXR-MATE-RRG24-UNIFORMER)
    # fgvlm_aehrc-cxrmate-rrg24-uniformer_pg_mscxr_cnr__20250723_163744
    # fgvlm_aehrc-cxrmate-rrg24-uniformer_pg_padchest-gr_cnr__20250724_031812,
    # fgvlm_aehrc-cxrmate-rrg24-uniformer_pg_vinbig_cnr__20250724_032801,
    # fgvlm_aehrc-cxrmate-rrg24-uniformer_pg_chestimagenome_cnr__20250614_180013
    # fgvlm_aehrc-cxrmate-rrg24-uniformer_pg_chestimagenome+mscxr+padchest-gr+vindrcxr_cnr__20250614_151415
    # fgvlm_aehrc-cxrmate-rrg24-uniformer_pg_chestimagenome+mscxr+padchest-gr+vindrcxr_sd__20250804_141741
    # fgvlm_aehrc-cxrmate-rrg24-uniformer_pg_chestimagenome+mscxr+padchest-gr+vindrcxr_sd__20250907_220145
    {
        "pred_and_gt_path": "/mnt/researchers/denis-parra/workspace_pamessina/medvqa/experiments/fgvlm_aehrc-cxrmate-rrg24-uniformer_pg_mscxr_cnr__20250723_163744/results/vindrcxr_predictions_and_gt.pkl",
        "metrics_path": "/mnt/researchers/denis-parra/workspace_pamessina/medvqa/experiments/fgvlm_aehrc-cxrmate-rrg24-uniformer_pg_mscxr_cnr__20250723_163744/results/vindrcxr_predictions_and_gt.pkl.metrics.pkl",
        "experiment_name": "FG-VLM (CXRMate-RRG24-UniFormer); 384x384; tr: MSCXR; metrics: CNR",
    },
    {
        "pred_and_gt_path": "/mnt/researchers/denis-parra/workspace_pamessina/medvqa/experiments/fgvlm_aehrc-cxrmate-rrg24-uniformer_pg_padchest-gr_cnr__20250724_031812/results/vindrcxr_predictions_and_gt.pkl",
        "metrics_path": "/mnt/researchers/denis-parra/workspace_pamessina/medvqa/experiments/fgvlm_aehrc-cxrmate-rrg24-uniformer_pg_padchest-gr_cnr__20250724_031812/results/vindrcxr_predictions_and_gt.pkl.metrics.pkl",
        "experiment_name": "FG-VLM (CXRMate-RRG24-UniFormer); 384x384; tr: PGR; metrics: CNR",
    },
    {
        "pred_and_gt_path": "/mnt/researchers/denis-parra/workspace_pamessina/medvqa/experiments/fgvlm_aehrc-cxrmate-rrg24-uniformer_pg_vinbig_cnr__20250724_032801/results/vindrcxr_predictions_and_gt.pkl",
        "metrics_path": "/mnt/researchers/denis-parra/workspace_pamessina/medvqa/experiments/fgvlm_aehrc-cxrmate-rrg24-uniformer_pg_vinbig_cnr__20250724_032801/results/vindrcxr_predictions_and_gt.pkl.metrics.pkl",
        "experiment_name": "FG-VLM (CXRMate-RRG24-UniFormer); 384x384; tr: VDCXR; metrics: CNR",
    },
    {
        "pred_and_gt_path": "/mnt/researchers/denis-parra/workspace_pamessina/medvqa/experiments/fgvlm_aehrc-cxrmate-rrg24-uniformer_pg_chestimagenome_cnr__20250614_180013/results/vindrcxr_predictions_and_gt.pkl",
        "metrics_path": "/mnt/researchers/denis-parra/workspace_pamessina/medvqa/experiments/fgvlm_aehrc-cxrmate-rrg24-uniformer_pg_chestimagenome_cnr__20250614_180013/results/vindrcxr_predictions_and_gt.pkl.metrics.pkl",
        "experiment_name": "FG-VLM (CXRMate-RRG24-UniFormer); 384x384; tr: CIG; metrics: CNR",
    },
    {
        "pred_and_gt_path": "/mnt/researchers/denis-parra/workspace_pamessina/medvqa/experiments/fgvlm_aehrc-cxrmate-rrg24-uniformer_pg_chestimagenome+mscxr+padchest-gr+vindrcxr_cnr__20250614_151415/results/vindrcxr_predictions_and_gt.pkl",
        "metrics_path": "/mnt/researchers/denis-parra/workspace_pamessina/medvqa/experiments/fgvlm_aehrc-cxrmate-rrg24-uniformer_pg_chestimagenome+mscxr+padchest-gr+vindrcxr_cnr__20250614_151415/results/vindrcxr_predictions_and_gt.pkl.metrics.pkl",
        "experiment_name": "FG-VLM (CXRMate-RRG24-UniFormer); 384x384; tr: CIG+MSCXR+PGR+VDCXR; metrics: CNR",
    },
    {
        "pred_and_gt_path": "/mnt/researchers/denis-parra/workspace_pamessina/medvqa/experiments/fgvlm_aehrc-cxrmate-rrg24-uniformer_pg_chestimagenome+mscxr+padchest-gr+vindrcxr_sd__20250804_141741/results/vindrcxr_predictions_and_gt.pkl",
        "metrics_path": "/mnt/researchers/denis-parra/workspace_pamessina/medvqa/experiments/fgvlm_aehrc-cxrmate-rrg24-uniformer_pg_chestimagenome+mscxr+padchest-gr+vindrcxr_sd__20250804_141741/results/vindrcxr_predictions_and_gt.pkl.metrics.pkl",
        "experiment_name": "FG-VLM (CXRMate-RRG24-UniFormer); 384x384; tr: CIG+MSCXR+PGR+VDCXR; metrics: SD",
    },
    {
        "pred_and_gt_path": "/mnt/researchers/denis-parra/workspace_pamessina/medvqa/experiments/fgvlm_aehrc-cxrmate-rrg24-uniformer_pg_chestimagenome+mscxr+padchest-gr+vindrcxr_sd__20250907_220145/results/vindrcxr_predictions_and_gt.pkl",
        "metrics_path": "/mnt/researchers/denis-parra/workspace_pamessina/medvqa/experiments/fgvlm_aehrc-cxrmate-rrg24-uniformer_pg_chestimagenome+mscxr+padchest-gr+vindrcxr_sd__20250907_220145/results/vindrcxr_predictions_and_gt.pkl.metrics.pkl",
        "experiment_name": "FG-VLM (CXRMate-RRG24-UniFormer); 448x448; tr: CIG+MSCXR+PGR+VDCXR; metrics: SD",
    },
    # FG-VLM (Microsoft-RAD-DINO-MAIRA-2)
    # fgvlm_microsoft-rad-dino-maira-2_pg_mscxr_cnr__20250726_102335
    # fgvlm_microsoft-rad-dino-maira-2_pg_padchest-gr_cnr__20250726_102936
    # fgvlm_microsoft-rad-dino-maira-2_pg_vinbig_cnr__20250727_172941
    # fgvlm_microsoft-rad-dino-maira-2_pg_chestimagenome_cnr__20250726_184906
    # fgvlm_microsoft-rad-dino-maira-2_pg_chestimagenome+mscxr+padchest-gr+vindrcxr_cnr__20250727_060714
    # fgvlm_microsoft-rad-dino-maira-2_pg_chestimagenome+mscxr+padchest-gr+vindrcxr_sd__20250805_052035
    # fgvlm_microsoft-rad-dino-maira-2_pg_chestimagenome+mscxr+padchest-gr+vindrcxr_cnr__20250727_125948
    # fgvlm_microsoft-rad-dino-maira-2_pg_chestimagenome+mscxr+padchest-gr+vindrcxr_sd__20250817_143800
    {
        "pred_and_gt_path": "/mnt/researchers/denis-parra/workspace_pamessina/medvqa/experiments/fgvlm_microsoft-rad-dino-maira-2_pg_mscxr_cnr__20250726_102335/results/vindrcxr_predictions_and_gt.pkl",
        "metrics_path": "/mnt/researchers/denis-parra/workspace_pamessina/medvqa/experiments/fgvlm_microsoft-rad-dino-maira-2_pg_mscxr_cnr__20250726_102335/results/vindrcxr_predictions_and_gt.pkl.metrics.pkl",
        "experiment_name": "FG-VLM (Microsoft-RAD-DINO-MAIRA-2); 384x384; tr: MSCXR; metrics: CNR",
    },
    {
        "pred_and_gt_path": "/mnt/researchers/denis-parra/workspace_pamessina/medvqa/experiments/fgvlm_microsoft-rad-dino-maira-2_pg_padchest-gr_cnr__20250726_102936/results/vindrcxr_predictions_and_gt.pkl",
        "metrics_path": "/mnt/researchers/denis-parra/workspace_pamessina/medvqa/experiments/fgvlm_microsoft-rad-dino-maira-2_pg_padchest-gr_cnr__20250726_102936/results/vindrcxr_predictions_and_gt.pkl.metrics.pkl",
        "experiment_name": "FG-VLM (Microsoft-RAD-DINO-MAIRA-2); 384x384; tr: PGR; metrics: CNR",
    },
    {
        "pred_and_gt_path": "/mnt/researchers/denis-parra/workspace_pamessina/medvqa/experiments/fgvlm_microsoft-rad-dino-maira-2_pg_vinbig_cnr__20250727_172941/results/vindrcxr_predictions_and_gt.pkl",
        "metrics_path": "/mnt/researchers/denis-parra/workspace_pamessina/medvqa/experiments/fgvlm_microsoft-rad-dino-maira-2_pg_vinbig_cnr__20250727_172941/results/vindrcxr_predictions_and_gt.pkl.metrics.pkl",
        "experiment_name": "FG-VLM (Microsoft-RAD-DINO-MAIRA-2); 384x384; tr: VDCXR; metrics: CNR",
    },
    {
        "pred_and_gt_path": "/mnt/researchers/denis-parra/workspace_pamessina/medvqa/experiments/fgvlm_microsoft-rad-dino-maira-2_pg_chestimagenome_cnr__20250726_184906/results/vindrcxr_predictions_and_gt.pkl",
        "metrics_path": "/mnt/researchers/denis-parra/workspace_pamessina/medvqa/experiments/fgvlm_microsoft-rad-dino-maira-2_pg_chestimagenome_cnr__20250726_184906/results/vindrcxr_predictions_and_gt.pkl.metrics.pkl",
        "experiment_name": "FG-VLM (Microsoft-RAD-DINO-MAIRA-2); 384x384; tr: CIG; metrics: CNR",
    },
    {
        "pred_and_gt_path": "/mnt/researchers/denis-parra/workspace_pamessina/medvqa/experiments/fgvlm_microsoft-rad-dino-maira-2_pg_chestimagenome+mscxr+padchest-gr+vindrcxr_cnr__20250727_060714/results/vindrcxr_predictions_and_gt.pkl",
        "metrics_path": "/mnt/researchers/denis-parra/workspace_pamessina/medvqa/experiments/fgvlm_microsoft-rad-dino-maira-2_pg_chestimagenome+mscxr+padchest-gr+vindrcxr_cnr__20250727_060714/results/vindrcxr_predictions_and_gt.pkl.metrics.pkl",
        "experiment_name": "FG-VLM (Microsoft-RAD-DINO-MAIRA-2); 384x384; tr: CIG+MSCXR+PGR+VDCXR; metrics: CNR",
    },
    {
        "pred_and_gt_path": "/mnt/researchers/denis-parra/workspace_pamessina/medvqa/experiments/fgvlm_microsoft-rad-dino-maira-2_pg_chestimagenome+mscxr+padchest-gr+vindrcxr_sd__20250805_052035/results/vindrcxr_predictions_and_gt.pkl",
        "metrics_path": "/mnt/researchers/denis-parra/workspace_pamessina/medvqa/experiments/fgvlm_microsoft-rad-dino-maira-2_pg_chestimagenome+mscxr+padchest-gr+vindrcxr_sd__20250805_052035/results/vindrcxr_predictions_and_gt.pkl.metrics.pkl",
        "experiment_name": "FG-VLM (Microsoft-RAD-DINO-MAIRA-2); 384x384; tr: CIG+MSCXR+PGR+VDCXR; metrics: SD",
    },
    {
        "pred_and_gt_path": "/mnt/researchers/denis-parra/workspace_pamessina/medvqa/experiments/fgvlm_microsoft-rad-dino-maira-2_pg_chestimagenome+mscxr+padchest-gr+vindrcxr_cnr__20250727_125948/results/vindrcxr_predictions_and_gt.pkl",
        "metrics_path": "/mnt/researchers/denis-parra/workspace_pamessina/medvqa/experiments/fgvlm_microsoft-rad-dino-maira-2_pg_chestimagenome+mscxr+padchest-gr+vindrcxr_cnr__20250727_125948/results/vindrcxr_predictions_and_gt.pkl.metrics.pkl",
        "experiment_name": "FG-VLM (Microsoft-RAD-DINO-MAIRA-2); 384x384; tr: CIG+MSCXR+PGR+VDCXR; metrics: CNR (mscxr only)",
    },
    {
        "pred_and_gt_path": "/mnt/researchers/denis-parra/workspace_pamessina/medvqa/experiments/fgvlm_microsoft-rad-dino-maira-2_pg_chestimagenome+mscxr+padchest-gr+vindrcxr_sd__20250817_143800/results/vindrcxr_predictions_and_gt.pkl",
        "metrics_path": "/mnt/researchers/denis-parra/workspace_pamessina/medvqa/experiments/fgvlm_microsoft-rad-dino-maira-2_pg_chestimagenome+mscxr+padchest-gr+vindrcxr_sd__20250817_143800/results/vindrcxr_predictions_and_gt.pkl.metrics.pkl",
        "experiment_name": "FG-VLM (Microsoft-RAD-DINO-MAIRA-2); 448x448; tr: CIG+MSCXR+PGR+VDCXR; metrics: SD",
    },
    # FG-VLM (MedSigLIP)
    # fgvlm_medsiglip_pg_mscxr_cnr__20251218_171159
    # fgvlm_medsiglip_pg_padchest-gr_cnr__20251219_095056
    # fgvlm_medsiglip_pg_vindrcxr_cnr__20251219_165240
    # fgvlm_medsiglip_pg_chestimagenome_cnr__20251223_164800
    # fgvlm_medsiglip_pg_chestimagenome+mscxr+padchest-gr+vindrcxr_cnr__20251224_174844
    {
        "pred_and_gt_path": "/mnt/researchers/denis-parra/workspace_pamessina/medvqa/experiments/fgvlm_medsiglip_pg_mscxr_cnr__20251218_171159/results/vindrcxr_predictions_and_gt.pkl",
        "metrics_path": "/mnt/researchers/denis-parra/workspace_pamessina/medvqa/experiments/fgvlm_medsiglip_pg_mscxr_cnr__20251218_171159/results/vindrcxr_predictions_and_gt.pkl.metrics.pkl",
        "experiment_name": "FG-VLM (MedSigLIP); 448x448; tr: MS-CXR; metrics: CNR",
    },
    {
        "pred_and_gt_path": "/mnt/researchers/denis-parra/workspace_pamessina/medvqa/experiments/fgvlm_medsiglip_pg_padchest-gr_cnr__20251219_095056/results/vindrcxr_predictions_and_gt.pkl",
        "metrics_path": "/mnt/researchers/denis-parra/workspace_pamessina/medvqa/experiments/fgvlm_medsiglip_pg_padchest-gr_cnr__20251219_095056/results/vindrcxr_predictions_and_gt.pkl.metrics.pkl",
        "experiment_name": "FG-VLM (MedSigLIP); 448x448; tr: PGR; metrics: CNR",
    },
    {
        "pred_and_gt_path": "/mnt/researchers/denis-parra/workspace_pamessina/medvqa/experiments/fgvlm_medsiglip_pg_vindrcxr_cnr__20251219_165240/results/vindrcxr_predictions_and_gt.pkl",
        "metrics_path": "/mnt/researchers/denis-parra/workspace_pamessina/medvqa/experiments/fgvlm_medsiglip_pg_vindrcxr_cnr__20251219_165240/results/vindrcxr_predictions_and_gt.pkl.metrics.pkl",
        "experiment_name": "FG-VLM (MedSigLIP); 448x448; tr: VDCXR; metrics: CNR",
    },
    {
        "pred_and_gt_path": "/mnt/researchers/denis-parra/workspace_pamessina/medvqa/experiments/fgvlm_medsiglip_pg_chestimagenome_cnr__20251223_164800/results/vindrcxr_predictions_and_gt.pkl",
        "metrics_path": "/mnt/researchers/denis-parra/workspace_pamessina/medvqa/experiments/fgvlm_medsiglip_pg_chestimagenome_cnr__20251223_164800/results/vindrcxr_predictions_and_gt.pkl.metrics.pkl",
        "experiment_name": "FG-VLM (MedSigLIP); 448x448; tr: CIG; metrics: CNR",
    },
    {
        "pred_and_gt_path": "/mnt/researchers/denis-parra/workspace_pamessina/medvqa/experiments/fgvlm_medsiglip_pg_chestimagenome+mscxr+padchest-gr+vindrcxr_cnr__20251224_174844/results/vindrcxr_predictions_and_gt.pkl",
        "metrics_path": "/mnt/researchers/denis-parra/workspace_pamessina/medvqa/experiments/fgvlm_medsiglip_pg_chestimagenome+mscxr+padchest-gr+vindrcxr_cnr__20251224_174844/results/vindrcxr_predictions_and_gt.pkl.metrics.pkl",
        "experiment_name": "FG-VLM (MedSigLIP); 448x448; tr: CIG+MSCXR+PGR+VDCXR; metrics: CNR",
    },
    # MAIRA-2
    {
        "pred_and_gt_path": "/mnt/researchers/denis-parra/workspace_pamessina/medvqa/experiments/maira2/maira2_phrase_grounding_predictions/vindrcxr_phrase_grounding_results.jsonl",
        "experiment_name": "MAIRA-2",
        "model_type": "maira-2",
    },
    # BioViL-T
    {
        "pred_and_gt_path": "/mnt/researchers/denis-parra/workspace_pamessina/medvqa/experiments/biovil-t/biovil-t_phrase_grounding_predictions/vindrcxr_phrase_grounding_results.pkl",
        "experiment_name": "BioViL-T",
        "model_type": "biovil-t",
    },
]

# %%
viz = PhraseGroundingResultsVisualizer(experiment_results)
# Out:
# Computing metrics for MAIRA-2...
# Loading precomputed metrics for MAIRA-2 at /mnt/researchers/denis-parra/workspace_pamessina/medvqa/experiments/maira2/maira2_phrase_grounding_predictions/vindrcxr_phrase_grounding_results.jsonl.metrics.pkl...
# Computing metrics for BioViL-T...
# Loading precomputed metrics for BioViL-T at /mnt/researchers/denis-parra/workspace_pamessina/medvqa/experiments/biovil-t/biovil-t_phrase_grounding_predictions/vindrcxr_phrase_grounding_results.pkl.metrics.pkl...

# %%
viz.plot_gradient_table(split='test', cmap='RdYlGn')
# Out:
# <style type="text/css">
# #T_97459 th.row_heading {
#   text-align: left;
#   padding-left: 10px;
# }
# #T_97459 td {
#   text-align: center;
# }
# #T_97459 th.col_heading {
#   text-align: center;
# }
# #T_97459_row0_col0, #T_97459_row7_col4 {
#   background-color: #f47044;
#   color: #f1f1f1;
# }
# #T_97459_row0_col1, #T_97459_row10_col6 {
#   background-color: #d62f27;
#   color: #f1f1f1;
# }
# #T_97459_row0_col2 {
#   background-color: #feca79;
#   color: #000000;
# }
# #T_97459_row0_col3 {
#   background-color: #fdc574;
#   color: #000000;
# }
# #T_97459_row0_col4, #T_97459_row3_col7, #T_97459_row7_col1 {
#   background-color: #f16640;
#   color: #f1f1f1;
# }
# #T_97459_row0_col5 {
#   background-color: #ee613e;
#   color: #f1f1f1;
# }
# #T_97459_row0_col6, #T_97459_row10_col0 {
#   background-color: #c21c27;
#   color: #f1f1f1;
# }
# #T_97459_row0_col7, #T_97459_row4_col0 {
#   background-color: #4eb15d;
#   color: #f1f1f1;
# }
# #T_97459_row1_col0 {
# ...

# %%
viz.visualize_example(
    example_idx=0, 
    method_aliases=[
        "FG-VLM (MedSigLIP); 448x448; tr: CIG+MSCXR+PGR+VDCXR; metrics: CNR",
        "FG-VLM (MedSigLIP); 448x448; tr: VDCXR; metrics: CNR",
        "FG-VLM (Microsoft-RAD-DINO-MAIRA-2); 448x448; tr: CIG+MSCXR+PGR+VDCXR; metrics: SD",
        "FG-VLM (Microsoft-RAD-DINO-MAIRA-2); 384x384; tr: VDCXR; metrics: CNR",
        "FG-VLM (CXRMate-RRG24-UniFormer); 448x448; tr: CIG+MSCXR+PGR+VDCXR; metrics: SD",
        "FG-VLM (CXRMate-RRG24-UniFormer); 384x384; tr: VDCXR; metrics: CNR",
        "MAIRA-2",
        "BioViL-T",
    ],
    split='test',
    max_cols=4,
    figsize=(3.2,6.6)
)
# Out:
# Loading predictions for FG-VLM (MedSigLIP); 448x448; tr: CIG+MSCXR+PGR+VDCXR; metrics: CNR...
# Key: ('008bdde2af2462e86fd373a445d0f4cd', 'calcification seen')
# image_path = /mnt/researchers/denis-parra/datasets/vindr/physionet.org/files/vindr-cxr/1.0.0/images_jpg_hq/test/008bdde2af2462e86fd373a445d0f4cd.jpg
# phrase = calcification seen
# gt_bbox_coords = [[0.69099612 0.31079    0.09248684 0.04025898]]
# Loading predictions for FG-VLM (MedSigLIP); 448x448; tr: VDCXR; metrics: CNR...
# Loading predictions for FG-VLM (Microsoft-RAD-DINO-MAIRA-2); 448x448; tr: CIG+MSCXR+PGR+VDCXR; metrics: SD...
# Loading predictions for FG-VLM (Microsoft-RAD-DINO-MAIRA-2); 384x384; tr: VDCXR; metrics: CNR...
# Loading predictions for FG-VLM (CXRMate-RRG24-UniFormer); 448x448; tr: CIG+MSCXR+PGR+VDCXR; metrics: SD...
# Loading predictions for FG-VLM (CXRMate-RRG24-UniFormer); 384x384; tr: VDCXR; metrics: CNR...
# Loading/Adapting MAIRA-2 predictions for MAIRA-2...
# MAIRA-2's specific outputs:
# ...

# %%
viz.visualize_example(
    example_idx=501, 
    method_aliases=[
        "FG-VLM (MedSigLIP); 448x448; tr: CIG+MSCXR+PGR+VDCXR; metrics: CNR",
        "FG-VLM (MedSigLIP); 448x448; tr: VDCXR; metrics: CNR",
        "FG-VLM (Microsoft-RAD-DINO-MAIRA-2); 448x448; tr: CIG+MSCXR+PGR+VDCXR; metrics: SD",
        "FG-VLM (Microsoft-RAD-DINO-MAIRA-2); 384x384; tr: VDCXR; metrics: CNR",
        "FG-VLM (CXRMate-RRG24-UniFormer); 448x448; tr: CIG+MSCXR+PGR+VDCXR; metrics: SD",
        "FG-VLM (CXRMate-RRG24-UniFormer); 384x384; tr: VDCXR; metrics: CNR",
        "MAIRA-2",
        "BioViL-T",
    ],
    split='test',
    max_cols=4,
    figsize=(3.2,6.6)
)
# Out:
# Key: ('435c653f95dd47326063ff145a0fa82e', 'pulmonary fibrosis seen')
# image_path = /mnt/researchers/denis-parra/datasets/vindr/physionet.org/files/vindr-cxr/1.0.0/images_jpg_hq/test/435c653f95dd47326063ff145a0fa82e.jpg
# phrase = pulmonary fibrosis seen
# gt_bbox_coords = [[0.32763617 0.41279064 0.25476898 0.40859491]]
# MAIRA-2's specific outputs:
# 	preds['maira_decoded_text'] = <obj> Pulmonary fibrosis.<box><x15><y9><x46><y73></box><box><x55><y7><x85><y73></box></obj>
# 	preds['maira_raw_output'] = [['Pulmonary fibrosis.', [[0.155, 0.095, 0.465, 0.735], [0.555, 0.075, 0.855, 0.735]]]]
