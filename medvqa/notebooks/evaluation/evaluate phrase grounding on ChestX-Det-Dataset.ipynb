# %%
# %env CUDA_VISIBLE_DEVICES=0
# Out:
# env: CUDA_VISIBLE_DEVICES=0

# %%
from medvqa.utils.files_utils import load_pickle

def print_results(results_filepath):
    results = load_pickle(results_filepath)
    print(f"prob_iou: {results['test_metrics']['prob_iou_with_bootstrapping']['iou']['mean']}")
    print(f"cnr: {results['test_metrics']['cnr_with_bootstrapping']['cnr']['mean']}")
    print(f"soft_dice: {results['test_metrics']['soft_dice_with_bootstrapping']['soft_dice']['mean']}")
    print(f"dice: {results['test_metrics']['dice_with_bootstrapping']['dice']['mean']}")
    print(f"rand_index: {results['test_metrics']['rand_index_with_bootstrapping']['rand_index']['mean']}")
    print(f"precision: {results['test_metrics']['precision_with_bootstrapping']['precision']['mean']}")
    print(f"recall: {results['test_metrics']['recall_with_bootstrapping']['recall']['mean']}")

# %% [markdown]
# #### FGVLM_g (UniFormer, CXRFE); tr: MS-CXR

# %%
# !python ../../eval_phrase_grounding.py inference\
--dataset_name "chest-x-det" \
--checkpoint_folder_path "/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250723_163744_mscxr_PhraseGrounder(aehrc-cxrmate-rrg24-uniformer,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)" \
--max_images_per_batch 150 \
--max_phrases_per_batch 100 \
--max_phrases_per_image 1 \
--num_workers 4 \
--chestxdet_train_json_path \
"/mnt/workspace/ChestX-Det-Dataset/ChestX_Det_train.json" \
--chestxdet_train_image_dir \
"/mnt/workspace/ChestX-Det-Dataset/train/" \
--chestxdet_test_json_path \
"/mnt/workspace/ChestX-Det-Dataset/ChestX_Det_test.json" \
--chestxdet_test_image_dir \
"/mnt/workspace/ChestX-Det-Dataset/test/" \
--chestxdet_label2embedding_path \
"/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/chestxdet/chestxdet_label2embedding(hash=498,3630461608310564345).pkl" \
--override_bbox_format "cxcywh" \
--use_amp
# Out:
# 2025-07-24 01:28:54,082 - INFO - root - Logging configured (Color: True).
# ----- Running Inference -----
# Activating determinism(seed=42)...
# 2025-07-24 01:28:54,087 - INFO - medvqa.models.checkpoint - metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250723_163744_mscxr_PhraseGrounder(aehrc-cxrmate-rrg24-uniformer,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/metadata.json
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Creating instance of PhraseGrounder ...
# 2025-07-24 01:28:54,130 - WARNING - medvqa.models.phrase_grounding.phrase_grounder - Unused kwargs: {'pretrained_checkpoint_folder_path': '/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250507_130735_mscxr_PhraseGrounder(aehrc-cxrmate-rrg24-uniformer,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)', 'pretrained_checkpoint_folder_paths': None}
# ...

# %%
# !python ../../eval_phrase_grounding.py metrics\
--dataset_name "chest-x-det" \
--predictions_and_gt_filepath "/mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20250723_163744_mscxr_PhraseGrounder(aehrc-cxrmate-rrg24-uniformer,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/chestxdet_predictions_and_gt.pkl"
# Out:
# 2025-07-24 01:30:53,825 - INFO - root - Logging configured (Color: True).
# ----- Computing metrics on Chest-X-Det Phrase Grounding -----
# Loading predictions and ground truth from /mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20250723_163744_mscxr_PhraseGrounder(aehrc-cxrmate-rrg24-uniformer,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/chestxdet_predictions_and_gt.pkl ...
# Computing average classification probability on train and test sets ...
# Computing average classification probability on the train set ...
# Train Avg Classification Prob with bootstrapping:
# {'avg_classification_prob': {'mean': 0.49692553, 'std': 1.960573e-05},
#  'avg_classification_prob(Atelectasis)': {'mean': 0.49849868,
#                                           'std': 9.693228e-05},
#  'avg_classification_prob(Calcification)': {'mean': 0.4976405,
#                                             'std': 6.0182123e-05},
# ...

# %%
print_results('/mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20250723_163744_mscxr_PhraseGrounder(aehrc-cxrmate-rrg24-uniformer,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/chestxdet_predictions_and_gt.pkl.metrics.pkl')
# Out:
# prob_iou: 0.20666425939573968
# cnr: 1.5209852457046509
# soft_dice: 0.2737241520691635
# dice: 0.2998745780045756
# rand_index: 0.9191288677474403
# precision: 0.30053631207789583
# recall: 0.4678792399493828

# %% [markdown]
# #### FGVLM_g (UniFormer, CXRFE); tr: ChestImaGenome

# %%
# !python ../../eval_phrase_grounding.py inference\
--dataset_name "chest-x-det" \
--checkpoint_folder_path "/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250614_180013_chst-img-alg+chst-img-pg_PhraseGrounder(aehrc-cxrmate-rrg24-uniformer,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)" \
--max_images_per_batch 150 \
--max_phrases_per_batch 100 \
--max_phrases_per_image 1 \
--num_workers 4 \
--chestxdet_train_json_path \
"/mnt/workspace/ChestX-Det-Dataset/ChestX_Det_train.json" \
--chestxdet_train_image_dir \
"/mnt/workspace/ChestX-Det-Dataset/train/" \
--chestxdet_test_json_path \
"/mnt/workspace/ChestX-Det-Dataset/ChestX_Det_test.json" \
--chestxdet_test_image_dir \
"/mnt/workspace/ChestX-Det-Dataset/test/" \
--chestxdet_label2embedding_path \
"/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/chestxdet/chestxdet_label2embedding(hash=498,3630461608310564345).pkl" \
--override_bbox_format "cxcywh" \
--use_amp
# Out:
# 2025-07-23 22:51:38,357 - INFO - root - Logging configured (Color: True).
# ----- Running Inference -----
# Activating determinism(seed=42)...
# 2025-07-23 22:51:38,362 - INFO - medvqa.models.checkpoint - metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250614_180013_chst-img-alg+chst-img-pg_PhraseGrounder(aehrc-cxrmate-rrg24-uniformer,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/metadata.json
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Creating instance of PhraseGrounder ...
# 2025-07-23 22:51:38,406 - WARNING - medvqa.models.phrase_grounding.phrase_grounder - Unused kwargs: {'pretrained_checkpoint_folder_path': None, 'pretrained_checkpoint_folder_paths': None}
# 2025-07-23 22:51:38,406 - INFO - medvqa.models.vision.visual_modules - MultiPurposeVisualModule()
# ...

# %%
# !python ../../eval_phrase_grounding.py metrics\
--dataset_name "chest-x-det" \
--predictions_and_gt_filepath "/mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20250614_180013_chst-img-alg+chst-img-pg_PhraseGrounder(aehrc-cxrmate-rrg24-uniformer,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/chestxdet_predictions_and_gt.pkl"
# Out:
# 2025-07-23 22:53:26,131 - INFO - root - Logging configured (Color: True).
# ----- Computing metrics on Chest-X-Det Phrase Grounding -----
# Loading predictions and ground truth from /mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20250614_180013_chst-img-alg+chst-img-pg_PhraseGrounder(aehrc-cxrmate-rrg24-uniformer,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/chestxdet_predictions_and_gt.pkl ...
# Computing average classification probability on train and test sets ...
# Computing average classification probability on the train set ...
# Train Avg Classification Prob with bootstrapping:
# {'avg_classification_prob': {'mean': 0.499452, 'std': 2.301812e-05},
#  'avg_classification_prob(Atelectasis)': {'mean': 0.50023675,
#                                           'std': 5.1689163e-05},
#  'avg_classification_prob(Calcification)': {'mean': 0.49755713,
#                                             'std': 4.4010467e-05},
# ...

# %%
print_results('/mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20250614_180013_chst-img-alg+chst-img-pg_PhraseGrounder(aehrc-cxrmate-rrg24-uniformer,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/chestxdet_predictions_and_gt.pkl.metrics.pkl')
# Out:
# prob_iou: 0.1527428063276062
# cnr: 0.8732950687408447
# soft_dice: 0.20373655140812083
# dice: 0.23028960202211562
# rand_index: 0.8831568527303755
# precision: 0.22013942426237582
# recall: 0.3835004498753581

# %% [markdown]
# #### FGVLM_g (UniFormer, CXRFE); tr: PadChest-GR

# %%
# !python ../../eval_phrase_grounding.py inference\
--dataset_name "chest-x-det" \
--checkpoint_folder_path "/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250724_031812_padchest-gr_PhraseGrounder(aehrc-cxrmate-rrg24-uniformer,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)" \
--max_images_per_batch 150 \
--max_phrases_per_batch 100 \
--max_phrases_per_image 1 \
--num_workers 4 \
--chestxdet_train_json_path \
"/mnt/workspace/ChestX-Det-Dataset/ChestX_Det_train.json" \
--chestxdet_train_image_dir \
"/mnt/workspace/ChestX-Det-Dataset/train/" \
--chestxdet_test_json_path \
"/mnt/workspace/ChestX-Det-Dataset/ChestX_Det_test.json" \
--chestxdet_test_image_dir \
"/mnt/workspace/ChestX-Det-Dataset/test/" \
--chestxdet_label2embedding_path \
"/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/chestxdet/chestxdet_label2embedding(hash=498,3630461608310564345).pkl" \
--override_bbox_format "cxcywh" \
--use_amp
# Out:
# 2025-07-26 13:21:00,651 - INFO - root - Logging configured (Color: True).
# ----- Running Inference -----
# Activating determinism(seed=42)...
# 2025-07-26 13:21:00,656 - INFO - medvqa.models.checkpoint - metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250724_031812_padchest-gr_PhraseGrounder(aehrc-cxrmate-rrg24-uniformer,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/metadata.json
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Creating instance of PhraseGrounder ...
# 2025-07-26 13:21:00,712 - WARNING - medvqa.models.phrase_grounding.phrase_grounder - Unused kwargs: {'pretrained_checkpoint_folder_path': None, 'pretrained_checkpoint_folder_paths': None}
# 2025-07-26 13:21:00,712 - INFO - medvqa.models.vision.visual_modules - MultiPurposeVisualModule()
# ...

# %%
# !python ../../eval_phrase_grounding.py metrics\
--dataset_name "chest-x-det" \
--predictions_and_gt_filepath "/mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20250724_031812_padchest-gr_PhraseGrounder(aehrc-cxrmate-rrg24-uniformer,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/chestxdet_predictions_and_gt.pkl"
# Out:
# 2025-07-26 14:11:47,329 - INFO - root - Logging configured (Color: True).
# ----- Computing metrics on Chest-X-Det Phrase Grounding -----
# Loading predictions and ground truth from /mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20250724_031812_padchest-gr_PhraseGrounder(aehrc-cxrmate-rrg24-uniformer,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/chestxdet_predictions_and_gt.pkl ...
# Computing average classification probability on train and test sets ...
# Computing average classification probability on the train set ...
# Train Avg Classification Prob with bootstrapping:
# {'avg_classification_prob': {'mean': 0.4853458, 'std': 2.9084458e-05},
#  'avg_classification_prob(Atelectasis)': {'mean': 0.48524258,
#                                           'std': 0.000111787915},
#  'avg_classification_prob(Calcification)': {'mean': 0.48545867,
#                                             'std': 8.9803536e-05},
# ...

# %%
print_results('/mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20250724_031812_padchest-gr_PhraseGrounder(aehrc-cxrmate-rrg24-uniformer,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/chestxdet_predictions_and_gt.pkl.metrics.pkl')
# Out:
# prob_iou: 0.2272178236507991
# cnr: 1.8409494161605835
# soft_dice: 0.26590974041392507
# dice: 0.32871320899503753
# rand_index: 0.9125648576791809
# precision: 0.30844990650782855
# recall: 0.5487362364071073

# %% [markdown]
# #### FGVLM_g (UniFormer, CXRFE); tr: VinDr-CXR

# %%
# !python ../../eval_phrase_grounding.py inference\
--dataset_name "chest-x-det" \
--checkpoint_folder_path "/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250724_032801_vinbig_PhraseGrounder(aehrc-cxrmate-rrg24-uniformer,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)" \
--max_images_per_batch 150 \
--max_phrases_per_batch 100 \
--max_phrases_per_image 1 \
--num_workers 4 \
--chestxdet_train_json_path \
"/mnt/workspace/ChestX-Det-Dataset/ChestX_Det_train.json" \
--chestxdet_train_image_dir \
"/mnt/workspace/ChestX-Det-Dataset/train/" \
--chestxdet_test_json_path \
"/mnt/workspace/ChestX-Det-Dataset/ChestX_Det_test.json" \
--chestxdet_test_image_dir \
"/mnt/workspace/ChestX-Det-Dataset/test/" \
--chestxdet_label2embedding_path \
"/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/chestxdet/chestxdet_label2embedding(hash=498,3630461608310564345).pkl" \
--override_bbox_format "cxcywh" \
--use_amp
# Out:
# 2025-07-26 14:30:19,277 - INFO - root - Logging configured (Color: True).
# ----- Running Inference -----
# Activating determinism(seed=42)...
# 2025-07-26 14:30:19,282 - INFO - medvqa.models.checkpoint - metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250724_032801_vinbig_PhraseGrounder(aehrc-cxrmate-rrg24-uniformer,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/metadata.json
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Creating instance of PhraseGrounder ...
# 2025-07-26 14:30:19,328 - WARNING - medvqa.models.phrase_grounding.phrase_grounder - Unused kwargs: {'pretrained_checkpoint_folder_path': None, 'pretrained_checkpoint_folder_paths': None}
# 2025-07-26 14:30:19,328 - INFO - medvqa.models.vision.visual_modules - MultiPurposeVisualModule()
# ...

# %%
# !python ../../eval_phrase_grounding.py metrics\
--dataset_name "chest-x-det" \
--predictions_and_gt_filepath "/mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20250724_032801_vinbig_PhraseGrounder(aehrc-cxrmate-rrg24-uniformer,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/chestxdet_predictions_and_gt.pkl"
# Out:
# 2025-07-26 14:32:36,580 - INFO - root - Logging configured (Color: True).
# ----- Computing metrics on Chest-X-Det Phrase Grounding -----
# Loading predictions and ground truth from /mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20250724_032801_vinbig_PhraseGrounder(aehrc-cxrmate-rrg24-uniformer,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/chestxdet_predictions_and_gt.pkl ...
# Computing average classification probability on train and test sets ...
# Computing average classification probability on the train set ...
# Train Avg Classification Prob with bootstrapping:
# {'avg_classification_prob': {'mean': 0.4886826, 'std': 2.7080507e-05},
#  'avg_classification_prob(Atelectasis)': {'mean': 0.48888114,
#                                           'std': 0.00011616517},
#  'avg_classification_prob(Calcification)': {'mean': 0.48694295,
#                                             'std': 0.00010142758},
# ...

# %%
print_results('/mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20250724_032801_vinbig_PhraseGrounder(aehrc-cxrmate-rrg24-uniformer,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/chestxdet_predictions_and_gt.pkl.metrics.pkl')
# Out:
# prob_iou: 0.22586560944195833
# cnr: 2.0909745693206787
# soft_dice: 0.2693179309192287
# dice: 0.3218486599339425
# rand_index: 0.9272488175767918
# precision: 0.33888900382084836
# recall: 0.4978597353876211

# %% [markdown]
# #### FGVLM_g (UniFormer, CXRFE); tr: MS-CXR + PadChest-GR + VinDr-CXR + Chest ImaGenome

# %%
# !python ../../eval_phrase_grounding.py inference\
--dataset_name "chest-x-det" \
--checkpoint_folder_path "/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250614_151415_mscxr+chst-img-alg+chst-img-pg+vinbig+padchest-gr_PhraseGrounder(aehrc-cxrmate-rrg24-uniformer,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)" \
--max_images_per_batch 150 \
--max_phrases_per_batch 100 \
--max_phrases_per_image 1 \
--num_workers 4 \
--chestxdet_train_json_path \
"/mnt/workspace/ChestX-Det-Dataset/ChestX_Det_train.json" \
--chestxdet_train_image_dir \
"/mnt/workspace/ChestX-Det-Dataset/train/" \
--chestxdet_test_json_path \
"/mnt/workspace/ChestX-Det-Dataset/ChestX_Det_test.json" \
--chestxdet_test_image_dir \
"/mnt/workspace/ChestX-Det-Dataset/test/" \
--chestxdet_label2embedding_path \
"/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/chestxdet/chestxdet_label2embedding(hash=498,3630461608310564345).pkl" \
--override_bbox_format "cxcywh" \
--use_amp
# Out:
# 2025-07-26 15:18:38,364 - INFO - root - Logging configured (Color: True).
# ----- Running Inference -----
# Activating determinism(seed=42)...
# 2025-07-26 15:18:38,368 - INFO - medvqa.models.checkpoint - metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250614_151415_mscxr+chst-img-alg+chst-img-pg+vinbig+padchest-gr_PhraseGrounder(aehrc-cxrmate-rrg24-uniformer,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/metadata.json
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Creating instance of PhraseGrounder ...
# ...

# %%
# !python ../../eval_phrase_grounding.py metrics\
--dataset_name "chest-x-det" \
--predictions_and_gt_filepath "/mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20250614_151415_mscxr+chst-img-alg+chst-img-pg+vinbig+padchest-gr_PhraseGrounder(aehrc-cxrmate-rrg24-uniformer,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/chestxdet_predictions_and_gt.pkl"
# Out:
# 2025-07-26 15:24:12,089 - INFO - root - Logging configured (Color: True).
# ----- Computing metrics on Chest-X-Det Phrase Grounding -----
# Loading predictions and ground truth from /mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20250614_151415_mscxr+chst-img-alg+chst-img-pg+vinbig+padchest-gr_PhraseGrounder(aehrc-cxrmate-rrg24-uniformer,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/chestxdet_predictions_and_gt.pkl ...
# Computing average classification probability on train and test sets ...
# Computing average classification probability on the train set ...
# Train Avg Classification Prob with bootstrapping:
# {'avg_classification_prob': {'mean': 0.4898592, 'std': 2.3405213e-05},
#  'avg_classification_prob(Atelectasis)': {'mean': 0.48958978,
#                                           'std': 9.7836804e-05},
#  'avg_classification_prob(Calcification)': {'mean': 0.48893163,
#                                             'std': 9.065078e-05},
# ...

# %%
print_results('/mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20250614_151415_mscxr+chst-img-alg+chst-img-pg+vinbig+padchest-gr_PhraseGrounder(aehrc-cxrmate-rrg24-uniformer,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/chestxdet_predictions_and_gt.pkl.metrics.pkl')
# Out:
# prob_iou: 0.24051868520502523
# cnr: 2.1067004203796387
# soft_dice: 0.27925495112474047
# dice: 0.34614368890623143
# rand_index: 0.9271549469283277
# precision: 0.35205892070465794
# recall: 0.5350212220756779

# %% [markdown]
# #### FGVLM_g (RAD-DINO-MAIRA-2, CXRFE); tr: MS-CXR

# %%
# !python ../../eval_phrase_grounding.py inference\
--dataset_name "chest-x-det" \
--checkpoint_folder_path "/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250726_102335_mscxr_PhraseGrounder(microsoft-rad-dino-maira-2,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)" \
--max_images_per_batch 150 \
--max_phrases_per_batch 100 \
--max_phrases_per_image 1 \
--num_workers 4 \
--chestxdet_train_json_path \
"/mnt/workspace/ChestX-Det-Dataset/ChestX_Det_train.json" \
--chestxdet_train_image_dir \
"/mnt/workspace/ChestX-Det-Dataset/train/" \
--chestxdet_test_json_path \
"/mnt/workspace/ChestX-Det-Dataset/ChestX_Det_test.json" \
--chestxdet_test_image_dir \
"/mnt/workspace/ChestX-Det-Dataset/test/" \
--chestxdet_label2embedding_path \
"/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/chestxdet/chestxdet_label2embedding(hash=498,3630461608310564345).pkl" \
--override_bbox_format "cxcywh" \
--use_amp
# Out:
# 2025-07-29 11:38:55,733 - INFO - root - Logging configured (Color: True).
# ----- Running Inference -----
# Activating determinism(seed=42)...
# 2025-07-29 11:38:55,738 - INFO - medvqa.models.checkpoint - metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250726_102335_mscxr_PhraseGrounder(microsoft-rad-dino-maira-2,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/metadata.json
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Creating instance of PhraseGrounder ...
# 2025-07-29 11:38:55,784 - WARNING - medvqa.models.phrase_grounding.phrase_grounder - Unused kwargs: {'pretrained_checkpoint_folder_path': None, 'pretrained_checkpoint_folder_paths': None}
# 2025-07-29 11:38:55,784 - INFO - medvqa.models.vision.visual_modules - MultiPurposeVisualModule()
# ...

# %%
# !python ../../eval_phrase_grounding.py metrics\
--dataset_name "chest-x-det" \
--predictions_and_gt_filepath "/mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20250726_102335_mscxr_PhraseGrounder(microsoft-rad-dino-maira-2,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/chestxdet_predictions_and_gt.pkl"
# Out:
# 2025-07-29 11:43:04,992 - INFO - root - Logging configured (Color: True).
# ----- Computing metrics on Chest-X-Det Phrase Grounding -----
# Loading predictions and ground truth from /mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20250726_102335_mscxr_PhraseGrounder(microsoft-rad-dino-maira-2,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/chestxdet_predictions_and_gt.pkl ...
# Computing average classification probability on train and test sets ...
# Computing average classification probability on the train set ...
# Train Avg Classification Prob with bootstrapping:
# {'avg_classification_prob': {'mean': 0.51286393, 'std': 2.5827703e-05},
#  'avg_classification_prob(Atelectasis)': {'mean': 0.5117535,
#                                           'std': 0.00012177987},
#  'avg_classification_prob(Calcification)': {'mean': 0.51359767,
#                                             'std': 6.4946646e-05},
# ...

# %%
print_results('/mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20250726_102335_mscxr_PhraseGrounder(microsoft-rad-dino-maira-2,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/chestxdet_predictions_and_gt.pkl.metrics.pkl')
# Out:
# prob_iou: 0.221020944710827
# cnr: 1.583231806755066
# soft_dice: 0.29878412321597425
# dice: 0.3187802258358872
# rand_index: 0.916310623890785
# precision: 0.311540210579514
# recall: 0.5053348770428924

# %% [markdown]
# #### FGVLM_g (RAD-DINO-MAIRA-2, CXRFE); tr: PadChest-GR

# %%
# !python ../../eval_phrase_grounding.py inference\
--dataset_name "chest-x-det" \
--checkpoint_folder_path "/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250726_102936_padchest-gr_PhraseGrounder(microsoft-rad-dino-maira-2,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)" \
--max_images_per_batch 150 \
--max_phrases_per_batch 100 \
--max_phrases_per_image 1 \
--num_workers 4 \
--chestxdet_train_json_path \
"/mnt/workspace/ChestX-Det-Dataset/ChestX_Det_train.json" \
--chestxdet_train_image_dir \
"/mnt/workspace/ChestX-Det-Dataset/train/" \
--chestxdet_test_json_path \
"/mnt/workspace/ChestX-Det-Dataset/ChestX_Det_test.json" \
--chestxdet_test_image_dir \
"/mnt/workspace/ChestX-Det-Dataset/test/" \
--chestxdet_label2embedding_path \
"/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/chestxdet/chestxdet_label2embedding(hash=498,3630461608310564345).pkl" \
--override_bbox_format "cxcywh" \
--use_amp
# Out:
# 2025-07-29 11:52:21,751 - INFO - root - Logging configured (Color: True).
# ----- Running Inference -----
# Activating determinism(seed=42)...
# 2025-07-29 11:52:21,755 - INFO - medvqa.models.checkpoint - metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250726_102936_padchest-gr_PhraseGrounder(microsoft-rad-dino-maira-2,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/metadata.json
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Creating instance of PhraseGrounder ...
# 2025-07-29 11:52:21,810 - WARNING - medvqa.models.phrase_grounding.phrase_grounder - Unused kwargs: {'pretrained_checkpoint_folder_path': None, 'pretrained_checkpoint_folder_paths': None}
# 2025-07-29 11:52:21,810 - INFO - medvqa.models.vision.visual_modules - MultiPurposeVisualModule()
# ...

# %%
# !python ../../eval_phrase_grounding.py metrics\
--dataset_name "chest-x-det" \
--predictions_and_gt_filepath "/mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20250726_102936_padchest-gr_PhraseGrounder(microsoft-rad-dino-maira-2,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/chestxdet_predictions_and_gt.pkl"
# Out:
# 2025-07-29 11:58:00,580 - INFO - root - Logging configured (Color: True).
# ----- Computing metrics on Chest-X-Det Phrase Grounding -----
# Loading predictions and ground truth from /mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20250726_102936_padchest-gr_PhraseGrounder(microsoft-rad-dino-maira-2,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/chestxdet_predictions_and_gt.pkl ...
# Computing average classification probability on train and test sets ...
# Computing average classification probability on the train set ...
# Train Avg Classification Prob with bootstrapping:
# {'avg_classification_prob': {'mean': 0.48280403, 'std': 3.048675e-05},
#  'avg_classification_prob(Atelectasis)': {'mean': 0.48320648,
#                                           'std': 0.000115188144},
#  'avg_classification_prob(Calcification)': {'mean': 0.48077896,
#                                             'std': 0.000100857476},
# ...

# %%
print_results('/mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20250726_102936_padchest-gr_PhraseGrounder(microsoft-rad-dino-maira-2,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/chestxdet_predictions_and_gt.pkl.metrics.pkl')
# Out:
# prob_iou: 0.23935485514665236
# cnr: 1.905026912689209
# soft_dice: 0.29824180155159824
# dice: 0.34282328613679575
# rand_index: 0.9149985831058021
# precision: 0.31396281659775993
# recall: 0.5743131563464098

# %% [markdown]
# #### FGVLM_g (RAD-DINO-MAIRA-2, CXRFE); tr: Chest ImaGenome

# %%
# !python ../../eval_phrase_grounding.py inference\
--dataset_name "chest-x-det" \
--checkpoint_folder_path "/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250726_184906_chst-img-alg+chst-img-pg_PhraseGrounder(microsoft-rad-dino-maira-2,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)" \
--max_images_per_batch 150 \
--max_phrases_per_batch 100 \
--max_phrases_per_image 1 \
--num_workers 4 \
--chestxdet_train_json_path \
"/mnt/workspace/ChestX-Det-Dataset/ChestX_Det_train.json" \
--chestxdet_train_image_dir \
"/mnt/workspace/ChestX-Det-Dataset/train/" \
--chestxdet_test_json_path \
"/mnt/workspace/ChestX-Det-Dataset/ChestX_Det_test.json" \
--chestxdet_test_image_dir \
"/mnt/workspace/ChestX-Det-Dataset/test/" \
--chestxdet_label2embedding_path \
"/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/chestxdet/chestxdet_label2embedding(hash=498,3630461608310564345).pkl" \
--override_bbox_format "cxcywh" \
--use_amp
# Out:
# 2025-07-29 12:11:56,334 - INFO - root - Logging configured (Color: True).
# ----- Running Inference -----
# Activating determinism(seed=42)...
# 2025-07-29 12:11:56,338 - INFO - medvqa.models.checkpoint - metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250726_184906_chst-img-alg+chst-img-pg_PhraseGrounder(microsoft-rad-dino-maira-2,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/metadata.json
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Creating instance of PhraseGrounder ...
# 2025-07-29 12:11:56,385 - WARNING - medvqa.models.phrase_grounding.phrase_grounder - Unused kwargs: {'pretrained_checkpoint_folder_path': None, 'pretrained_checkpoint_folder_paths': None}
# 2025-07-29 12:11:56,386 - INFO - medvqa.models.vision.visual_modules - MultiPurposeVisualModule()
# ...

# %%
# !python ../../eval_phrase_grounding.py metrics\
--dataset_name "chest-x-det" \
--predictions_and_gt_filepath "/mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20250726_184906_chst-img-alg+chst-img-pg_PhraseGrounder(microsoft-rad-dino-maira-2,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/chestxdet_predictions_and_gt.pkl"
# Out:
# 2025-07-29 12:33:24,179 - INFO - root - Logging configured (Color: True).
# ----- Computing metrics on Chest-X-Det Phrase Grounding -----
# Loading predictions and ground truth from /mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20250726_184906_chst-img-alg+chst-img-pg_PhraseGrounder(microsoft-rad-dino-maira-2,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/chestxdet_predictions_and_gt.pkl ...
# Computing average classification probability on train and test sets ...
# Computing average classification probability on the train set ...
# Train Avg Classification Prob with bootstrapping:
# {'avg_classification_prob': {'mean': 0.5153369, 'std': 3.200095e-05},
#  'avg_classification_prob(Atelectasis)': {'mean': 0.5159193,
#                                           'std': 7.832017e-05},
#  'avg_classification_prob(Calcification)': {'mean': 0.5174661,
#                                             'std': 6.822419e-05},
# ...

# %%
print_results('/mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20250726_184906_chst-img-alg+chst-img-pg_PhraseGrounder(microsoft-rad-dino-maira-2,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/chestxdet_predictions_and_gt.pkl.metrics.pkl')
# Out:
# prob_iou: 0.17368590639763562
# cnr: 1.1090998649597168
# soft_dice: 0.2436102160695629
# dice: 0.2598795267539442
# rand_index: 0.8803884566552902
# precision: 0.23935356207072694
# recall: 0.48252420054700995

# %% [markdown]
# #### FGVLM_g (RAD-DINO-MAIRA-2, CXRFE); tr: VinDr-CXR

# %%
# !python ../../eval_phrase_grounding.py inference\
--dataset_name "chest-x-det" \
--checkpoint_folder_path "/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250727_172941_vinbig_PhraseGrounder(microsoft-rad-dino-maira-2,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)" \
--max_images_per_batch 150 \
--max_phrases_per_batch 100 \
--max_phrases_per_image 1 \
--num_workers 4 \
--chestxdet_train_json_path \
"/mnt/workspace/ChestX-Det-Dataset/ChestX_Det_train.json" \
--chestxdet_train_image_dir \
"/mnt/workspace/ChestX-Det-Dataset/train/" \
--chestxdet_test_json_path \
"/mnt/workspace/ChestX-Det-Dataset/ChestX_Det_test.json" \
--chestxdet_test_image_dir \
"/mnt/workspace/ChestX-Det-Dataset/test/" \
--chestxdet_label2embedding_path \
"/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/chestxdet/chestxdet_label2embedding(hash=498,3630461608310564345).pkl" \
--override_bbox_format "cxcywh" \
--use_amp
# Out:
# 2025-07-29 12:42:04,038 - INFO - root - Logging configured (Color: True).
# ----- Running Inference -----
# Activating determinism(seed=42)...
# 2025-07-29 12:42:04,043 - INFO - medvqa.models.checkpoint - metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250727_172941_vinbig_PhraseGrounder(microsoft-rad-dino-maira-2,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/metadata.json
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Creating instance of PhraseGrounder ...
# 2025-07-29 12:42:04,085 - WARNING - medvqa.models.phrase_grounding.phrase_grounder - Unused kwargs: {'pretrained_checkpoint_folder_path': None, 'pretrained_checkpoint_folder_paths': None}
# 2025-07-29 12:42:04,086 - INFO - medvqa.models.vision.visual_modules - MultiPurposeVisualModule()
# ...

# %%
# !python ../../eval_phrase_grounding.py metrics\
--dataset_name "chest-x-det" \
--predictions_and_gt_filepath "/mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20250727_172941_vinbig_PhraseGrounder(microsoft-rad-dino-maira-2,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/chestxdet_predictions_and_gt.pkl"
# Out:
# 2025-07-29 12:50:58,205 - INFO - root - Logging configured (Color: True).
# ----- Computing metrics on Chest-X-Det Phrase Grounding -----
# Loading predictions and ground truth from /mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20250727_172941_vinbig_PhraseGrounder(microsoft-rad-dino-maira-2,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/chestxdet_predictions_and_gt.pkl ...
# Computing average classification probability on train and test sets ...
# Computing average classification probability on the train set ...
# Train Avg Classification Prob with bootstrapping:
# {'avg_classification_prob': {'mean': 0.4804069, 'std': 2.5160076e-05},
#  'avg_classification_prob(Atelectasis)': {'mean': 0.4794261,
#                                           'std': 9.9295175e-05},
#  'avg_classification_prob(Calcification)': {'mean': 0.47954655,
#                                             'std': 8.803521e-05},
# ...

# %%
print_results('/mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20250727_172941_vinbig_PhraseGrounder(microsoft-rad-dino-maira-2,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/chestxdet_predictions_and_gt.pkl.metrics.pkl')
# Out:
# prob_iou: 0.26074124357504247
# cnr: 2.352698564529419
# soft_dice: 0.31390283239381905
# dice: 0.3623009797326886
# rand_index: 0.9373722721843003
# precision: 0.392634951362606
# recall: 0.5120735335344297

# %% [markdown]
# #### FGVLM_g (RAD-DINO-MAIRA-2, CXRFE); tr: MS-CXR + PadChest-GR + VinDr-CXR + Chest ImaGenome

# %%
# !python ../../eval_phrase_grounding.py inference\
--dataset_name "chest-x-det" \
--checkpoint_folder_path "/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250727_060714_mscxr+chst-img-alg+chst-img-pg+vinbig+padchest-gr_PhraseGrounder(microsoft-rad-dino-maira-2,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)" \
--max_images_per_batch 150 \
--max_phrases_per_batch 100 \
--max_phrases_per_image 1 \
--num_workers 4 \
--chestxdet_train_json_path \
"/mnt/workspace/ChestX-Det-Dataset/ChestX_Det_train.json" \
--chestxdet_train_image_dir \
"/mnt/workspace/ChestX-Det-Dataset/train/" \
--chestxdet_test_json_path \
"/mnt/workspace/ChestX-Det-Dataset/ChestX_Det_test.json" \
--chestxdet_test_image_dir \
"/mnt/workspace/ChestX-Det-Dataset/test/" \
--chestxdet_label2embedding_path \
"/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/chestxdet/chestxdet_label2embedding(hash=498,3630461608310564345).pkl" \
--override_bbox_format "cxcywh" \
--use_amp
# Out:
# 2025-07-29 12:53:44,458 - INFO - root - Logging configured (Color: True).
# ----- Running Inference -----
# Activating determinism(seed=42)...
# 2025-07-29 12:53:44,462 - INFO - medvqa.models.checkpoint - metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250727_060714_mscxr+chst-img-alg+chst-img-pg+vinbig+padchest-gr_PhraseGrounder(microsoft-rad-dino-maira-2,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/metadata.json
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Creating instance of PhraseGrounder ...
# ...

# %%
# !python ../../eval_phrase_grounding.py metrics\
--dataset_name "chest-x-det" \
--predictions_and_gt_filepath "/mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20250727_060714_mscxr+chst-img-alg+chst-img-pg+vinbig+padchest-gr_PhraseGrounder(microsoft-rad-dino-maira-2,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/chestxdet_predictions_and_gt.pkl"
# Out:
# 2025-07-29 13:00:53,467 - INFO - root - Logging configured (Color: True).
# ----- Computing metrics on Chest-X-Det Phrase Grounding -----
# Loading predictions and ground truth from /mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20250727_060714_mscxr+chst-img-alg+chst-img-pg+vinbig+padchest-gr_PhraseGrounder(microsoft-rad-dino-maira-2,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/chestxdet_predictions_and_gt.pkl ...
# Computing average classification probability on train and test sets ...
# Computing average classification probability on the train set ...
# Train Avg Classification Prob with bootstrapping:
# {'avg_classification_prob': {'mean': 0.5151715, 'std': 3.273162e-05},
#  'avg_classification_prob(Atelectasis)': {'mean': 0.51477623,
#                                           'std': 0.00011829783},
#  'avg_classification_prob(Calcification)': {'mean': 0.51660144,
#                                             'std': 0.00013094304},
# ...

# %%
print_results('/mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20250727_060714_mscxr+chst-img-alg+chst-img-pg+vinbig+padchest-gr_PhraseGrounder(microsoft-rad-dino-maira-2,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/chestxdet_predictions_and_gt.pkl.metrics.pkl')
# Out:
# prob_iou: 0.25324749508452105
# cnr: 2.115088939666748
# soft_dice: 0.29236965623166417
# dice: 0.3586232635897894
# rand_index: 0.9252421704778158
# precision: 0.3379331197620644
# recall: 0.577666112304402

# %% [markdown]
# #### FGVLM_g (RAD-DINO-MAIRA-2, CXRFE); tr: MS-CXR + PadChest-GR + VinDr-CXR + Chest ImaGenome (2)

# %%
# !python ../../eval_phrase_grounding.py inference\
--dataset_name "chest-x-det" \
--checkpoint_folder_path "/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250727_125948_mscxr+chst-img-alg+chst-img-pg+vinbig+padchest-gr_PhraseGrounder(microsoft-rad-dino-maira-2,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)" \
--max_images_per_batch 150 \
--max_phrases_per_batch 100 \
--max_phrases_per_image 1 \
--num_workers 4 \
--chestxdet_train_json_path \
"/mnt/workspace/ChestX-Det-Dataset/ChestX_Det_train.json" \
--chestxdet_train_image_dir \
"/mnt/workspace/ChestX-Det-Dataset/train/" \
--chestxdet_test_json_path \
"/mnt/workspace/ChestX-Det-Dataset/ChestX_Det_test.json" \
--chestxdet_test_image_dir \
"/mnt/workspace/ChestX-Det-Dataset/test/" \
--chestxdet_label2embedding_path \
"/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/chestxdet/chestxdet_label2embedding(hash=498,3630461608310564345).pkl" \
--override_bbox_format "cxcywh" \
--use_amp
# Out:
# 2025-07-29 13:04:13,034 - INFO - root - Logging configured (Color: True).
# ----- Running Inference -----
# Activating determinism(seed=42)...
# 2025-07-29 13:04:13,039 - INFO - medvqa.models.checkpoint - metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250727_125948_mscxr+chst-img-alg+chst-img-pg+vinbig+padchest-gr_PhraseGrounder(microsoft-rad-dino-maira-2,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/metadata.json
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Creating instance of PhraseGrounder ...
# ...

# %%
# !python ../../eval_phrase_grounding.py metrics\
--dataset_name "chest-x-det" \
--predictions_and_gt_filepath "/mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20250727_125948_mscxr+chst-img-alg+chst-img-pg+vinbig+padchest-gr_PhraseGrounder(microsoft-rad-dino-maira-2,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/chestxdet_predictions_and_gt.pkl"
# Out:
# 2025-07-29 13:19:40,254 - INFO - root - Logging configured (Color: True).
# ----- Computing metrics on Chest-X-Det Phrase Grounding -----
# Loading predictions and ground truth from /mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20250727_125948_mscxr+chst-img-alg+chst-img-pg+vinbig+padchest-gr_PhraseGrounder(microsoft-rad-dino-maira-2,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/chestxdet_predictions_and_gt.pkl ...
# Computing average classification probability on train and test sets ...
# Computing average classification probability on the train set ...
# Train Avg Classification Prob with bootstrapping:
# {'avg_classification_prob': {'mean': 0.5160963, 'std': 3.235053e-05},
#  'avg_classification_prob(Atelectasis)': {'mean': 0.51550174,
#                                           'std': 0.0001230886},
#  'avg_classification_prob(Calcification)': {'mean': 0.51701844,
#                                             'std': 9.6889366e-05},
# ...

# %%
print_results('/mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20250727_125948_mscxr+chst-img-alg+chst-img-pg+vinbig+padchest-gr_PhraseGrounder(microsoft-rad-dino-maira-2,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/chestxdet_predictions_and_gt.pkl.metrics.pkl')
# Out:
# prob_iou: 0.25946449459351684
# cnr: 2.1619608402252197
# soft_dice: 0.27497252310369896
# dice: 0.36263466137621153
# rand_index: 0.9299301382252558
# precision: 0.3439513106864002
# recall: 0.5906540193405119

# %% [markdown]
# #### FGVLM_g (RAD-DINO-MAIRA-2, CXRFE); tr: ChestImaGenome + MS-CXR + PadChest-GR + VinDr-CXR (optimizing SD)

# %%
# !python ../../eval_phrase_grounding.py inference\
--dataset_name "chest-x-det" \
--checkpoint_folder_path "/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250805_052035_mscxr+chst-img-alg+chst-img-pg+vinbig+padchest-gr_PhraseGrounder(microsoft-rad-dino-maira-2,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)" \
--max_images_per_batch 150 \
--max_phrases_per_batch 100 \
--max_phrases_per_image 1 \
--num_workers 4 \
--chestxdet_train_json_path \
"/mnt/workspace/ChestX-Det-Dataset/ChestX_Det_train.json" \
--chestxdet_train_image_dir \
"/mnt/workspace/ChestX-Det-Dataset/train/" \
--chestxdet_test_json_path \
"/mnt/workspace/ChestX-Det-Dataset/ChestX_Det_test.json" \
--chestxdet_test_image_dir \
"/mnt/workspace/ChestX-Det-Dataset/test/" \
--chestxdet_label2embedding_path \
"/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/chestxdet/chestxdet_label2embedding(hash=498,3630461608310564345).pkl" \
--override_bbox_format "cxcywh" \
--use_amp
# Out:
# 2025-08-05 13:59:29,424 - INFO - root - Logging configured (Color: True).
# ----- Running Inference -----
# Activating determinism(seed=42)...
# 2025-08-05 13:59:29,429 - INFO - medvqa.models.checkpoint - metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250805_052035_mscxr+chst-img-alg+chst-img-pg+vinbig+padchest-gr_PhraseGrounder(microsoft-rad-dino-maira-2,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/metadata.json
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Creating instance of PhraseGrounder ...
# ...

# %%
# !python ../../eval_phrase_grounding.py metrics\
--dataset_name "chest-x-det" \
--predictions_and_gt_filepath "/mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20250805_052035_mscxr+chst-img-alg+chst-img-pg+vinbig+padchest-gr_PhraseGrounder(microsoft-rad-dino-maira-2,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/chestxdet_predictions_and_gt.pkl"
# Out:
# 2025-08-05 14:05:00,184 - INFO - root - Logging configured (Color: True).
# ----- Computing metrics on Chest-X-Det Phrase Grounding -----
# Loading predictions and ground truth from /mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20250805_052035_mscxr+chst-img-alg+chst-img-pg+vinbig+padchest-gr_PhraseGrounder(microsoft-rad-dino-maira-2,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/chestxdet_predictions_and_gt.pkl ...
# Computing average classification probability on train and test sets ...
# Computing average classification probability on the train set ...
# Train Avg Classification Prob with bootstrapping:
# {'avg_classification_prob': {'mean': 0.51513505, 'std': 3.1581956e-05},
#  'avg_classification_prob(Atelectasis)': {'mean': 0.51460505,
#                                           'std': 0.00012219834},
#  'avg_classification_prob(Calcification)': {'mean': 0.5156408,
#                                             'std': 0.00012679017},
# ...

# %%
print_results('/mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20250805_052035_mscxr+chst-img-alg+chst-img-pg+vinbig+padchest-gr_PhraseGrounder(microsoft-rad-dino-maira-2,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/chestxdet_predictions_and_gt.pkl.metrics.pkl')
# Out:
# prob_iou: 0.2568695128615166
# cnr: 2.148737907409668
# soft_dice: 0.30923082940404745
# dice: 0.3643729799320412
# rand_index: 0.9286297945392491
# precision: 0.34825538038817194
# recall: 0.5660578057191924

# %% [markdown]
# #### FGVLM_g (UniFormer, CXRFE); tr: ChestImaGenome + MS-CXR + PadChest-GR + VinDr-CXR (optimizing SD)

# %%
# !python ../../eval_phrase_grounding.py inference\
--dataset_name "chest-x-det" \
--checkpoint_folder_path "/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250804_141741_mscxr+chst-img-alg+chst-img-pg+vinbig+padchest-gr_PhraseGrounder(aehrc-cxrmate-rrg24-uniformer,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)" \
--max_images_per_batch 150 \
--max_phrases_per_batch 100 \
--max_phrases_per_image 1 \
--num_workers 4 \
--chestxdet_train_json_path \
"/mnt/workspace/ChestX-Det-Dataset/ChestX_Det_train.json" \
--chestxdet_train_image_dir \
"/mnt/workspace/ChestX-Det-Dataset/train/" \
--chestxdet_test_json_path \
"/mnt/workspace/ChestX-Det-Dataset/ChestX_Det_test.json" \
--chestxdet_test_image_dir \
"/mnt/workspace/ChestX-Det-Dataset/test/" \
--chestxdet_label2embedding_path \
"/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/chestxdet/chestxdet_label2embedding(hash=498,3630461608310564345).pkl" \
--override_bbox_format "cxcywh" \
--use_amp
# Out:
# 2025-08-05 14:08:07,932 - INFO - root - Logging configured (Color: True).
# ----- Running Inference -----
# Activating determinism(seed=42)...
# 2025-08-05 14:08:07,937 - INFO - medvqa.models.checkpoint - metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250804_141741_mscxr+chst-img-alg+chst-img-pg+vinbig+padchest-gr_PhraseGrounder(aehrc-cxrmate-rrg24-uniformer,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/metadata.json
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Creating instance of PhraseGrounder ...
# ...

# %%
# !python ../../eval_phrase_grounding.py metrics\
--dataset_name "chest-x-det" \
--predictions_and_gt_filepath "/mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20250804_141741_mscxr+chst-img-alg+chst-img-pg+vinbig+padchest-gr_PhraseGrounder(aehrc-cxrmate-rrg24-uniformer,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/chestxdet_predictions_and_gt.pkl"
# Out:
# 2025-08-05 14:11:09,286 - INFO - root - Logging configured (Color: True).
# ----- Computing metrics on Chest-X-Det Phrase Grounding -----
# Loading predictions and ground truth from /mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20250804_141741_mscxr+chst-img-alg+chst-img-pg+vinbig+padchest-gr_PhraseGrounder(aehrc-cxrmate-rrg24-uniformer,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/chestxdet_predictions_and_gt.pkl ...
# Computing average classification probability on train and test sets ...
# Computing average classification probability on the train set ...
# Train Avg Classification Prob with bootstrapping:
# {'avg_classification_prob': {'mean': 0.48985332, 'std': 2.2881784e-05},
#  'avg_classification_prob(Atelectasis)': {'mean': 0.4895629,
#                                           'std': 0.000107181986},
#  'avg_classification_prob(Calcification)': {'mean': 0.48912662,
#                                             'std': 7.4700496e-05},
# ...

# %%
print_results('/mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20250804_141741_mscxr+chst-img-alg+chst-img-pg+vinbig+padchest-gr_PhraseGrounder(aehrc-cxrmate-rrg24-uniformer,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/chestxdet_predictions_and_gt.pkl.metrics.pkl')
# Out:
# prob_iou: 0.24197770514289202
# cnr: 2.1523730754852295
# soft_dice: 0.27986392731718845
# dice: 0.3477141056514252
# rand_index: 0.9287681394197953
# precision: 0.35654682627191286
# recall: 0.52774206052175

# %% [markdown]
# #### FGVLM_g (RAD-DINO-MAIRA-2, CXRFE, 448x448); tr: ChestImaGenome + MS-CXR + PadChest-GR + VinDr-CXR (optimizing SD)

# %%
# !python ../../eval_phrase_grounding.py inference\
--dataset_name "chest-x-det" \
--checkpoint_folder_path "/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250817_143800_mscxr+chst-img-alg+chst-img-pg+vinbig+padchest-gr_PhraseGrounder(microsoft-rad-dino-maira-2,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)" \
--max_images_per_batch 150 \
--max_phrases_per_batch 100 \
--max_phrases_per_image 1 \
--num_workers 4 \
--chestxdet_train_json_path \
"/mnt/workspace/ChestX-Det-Dataset/ChestX_Det_train.json" \
--chestxdet_train_image_dir \
"/mnt/workspace/ChestX-Det-Dataset/train/" \
--chestxdet_test_json_path \
"/mnt/workspace/ChestX-Det-Dataset/ChestX_Det_test.json" \
--chestxdet_test_image_dir \
"/mnt/workspace/ChestX-Det-Dataset/test/" \
--chestxdet_label2embedding_path \
"/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/chestxdet/chestxdet_label2embedding(hash=498,3630461608310564345).pkl" \
--override_bbox_format "cxcywh" \
--use_amp
# Out:
# 2025-08-19 11:59:43,806 - INFO - root - Logging configured (Color: True).
# ----- Running Inference -----
# Activating determinism(seed=42)...
# 2025-08-19 11:59:43,811 - INFO - medvqa.models.checkpoint - metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250817_143800_mscxr+chst-img-alg+chst-img-pg+vinbig+padchest-gr_PhraseGrounder(microsoft-rad-dino-maira-2,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/metadata.json
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Creating instance of PhraseGrounder ...
# ...

# %%
# !python ../../eval_phrase_grounding.py metrics\
--dataset_name "chest-x-det" \
--predictions_and_gt_filepath "/mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20250817_143800_mscxr+chst-img-alg+chst-img-pg+vinbig+padchest-gr_PhraseGrounder(microsoft-rad-dino-maira-2,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/chestxdet_predictions_and_gt.pkl"
# Out:
# 2025-08-19 12:11:01,182 - INFO - root - Logging configured (Color: True).
# ----- Computing metrics on Chest-X-Det Phrase Grounding -----
# Loading predictions and ground truth from /mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20250817_143800_mscxr+chst-img-alg+chst-img-pg+vinbig+padchest-gr_PhraseGrounder(microsoft-rad-dino-maira-2,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/chestxdet_predictions_and_gt.pkl ...
# Computing average classification probability on train and test sets ...
# Computing average classification probability on the train set ...
# Train Avg Classification Prob with bootstrapping:
# {'avg_classification_prob': {'mean': 0.5133165, 'std': 3.5011362e-05},
#  'avg_classification_prob(Atelectasis)': {'mean': 0.5133608,
#                                           'std': 0.00014771069},
#  'avg_classification_prob(Calcification)': {'mean': 0.51386106,
#                                             'std': 0.0001310764},
# ...

# %%
print_results('/mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20250817_143800_mscxr+chst-img-alg+chst-img-pg+vinbig+padchest-gr_PhraseGrounder(microsoft-rad-dino-maira-2,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/chestxdet_predictions_and_gt.pkl.metrics.pkl')
# Out:
# prob_iou: 0.2584518020768577
# cnr: 2.103625535964966
# soft_dice: 0.3333438037458319
# dice: 0.3662820990894179
# rand_index: 0.9352257259385666
# precision: 0.3708267219272341
# recall: 0.5265948545690353

# %% [markdown]
# #### FGVLM_g (UniFormer, CXRFE, 448x448); tr: ChestImaGenome + MS-CXR + PadChest-GR + VinDr-CXR (optimizing SD)

# %%
# !python ../../eval_phrase_grounding.py inference\
--dataset_name "chest-x-det" \
--checkpoint_folder_path "/mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250907_220145_mscxr+chst-img-alg+chst-img-pg+vinbig+padchest-gr_PhraseGrounder(aehrc-cxrmate-rrg24-uniformer,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)" \
--max_images_per_batch 150 \
--max_phrases_per_batch 100 \
--max_phrases_per_image 1 \
--num_workers 4 \
--chestxdet_train_json_path \
"/mnt/workspace/ChestX-Det-Dataset/ChestX_Det_train.json" \
--chestxdet_train_image_dir \
"/mnt/workspace/ChestX-Det-Dataset/train/" \
--chestxdet_test_json_path \
"/mnt/workspace/ChestX-Det-Dataset/ChestX_Det_test.json" \
--chestxdet_test_image_dir \
"/mnt/workspace/ChestX-Det-Dataset/test/" \
--chestxdet_label2embedding_path \
"/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/chestxdet/chestxdet_label2embedding(hash=498,3630461608310564345).pkl" \
--override_bbox_format "cxcywh" \
--use_amp
# Out:
# 2025-09-12 08:28:24,020 - INFO - root - Logging configured (Color: True).
# ----- Running Inference -----
# Activating determinism(seed=42)...
# 2025-09-12 08:28:24,025 - INFO - medvqa.models.checkpoint - metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250907_220145_mscxr+chst-img-alg+chst-img-pg+vinbig+padchest-gr_PhraseGrounder(aehrc-cxrmate-rrg24-uniformer,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/metadata.json
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Creating instance of PhraseGrounder ...
# ...

# %%
# !python ../../eval_phrase_grounding.py metrics\
--dataset_name "chest-x-det" \
--predictions_and_gt_filepath "/mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20250907_220145_mscxr+chst-img-alg+chst-img-pg+vinbig+padchest-gr_PhraseGrounder(aehrc-cxrmate-rrg24-uniformer,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/chestxdet_predictions_and_gt.pkl"
# Out:
# 2025-09-12 08:31:37,268 - INFO - root - Logging configured (Color: True).
# ----- Computing metrics on Chest-X-Det Phrase Grounding -----
# Loading predictions and ground truth from /mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20250907_220145_mscxr+chst-img-alg+chst-img-pg+vinbig+padchest-gr_PhraseGrounder(aehrc-cxrmate-rrg24-uniformer,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/chestxdet_predictions_and_gt.pkl ...
# Computing average classification probability on train and test sets ...
# Computing average classification probability on the train set ...
# Train Avg Classification Prob with bootstrapping:
# {'avg_classification_prob': {'mean': 0.48909965, 'std': 2.7941884e-05},
#  'avg_classification_prob(Atelectasis)': {'mean': 0.48811865,
#                                           'std': 8.626216e-05},
#  'avg_classification_prob(Calcification)': {'mean': 0.4918183,
#                                             'std': 6.5923865e-05},
# ...

# %%
print_results('/mnt/data/pamessina/workspaces/medvqa-workspace/results/phrase_grounding/20250907_220145_mscxr+chst-img-alg+chst-img-pg+vinbig+padchest-gr_PhraseGrounder(aehrc-cxrmate-rrg24-uniformer,AdaptiveFiLM_MLP_BBoxRegression,128,256,256-128)/chestxdet_predictions_and_gt.pkl.metrics.pkl')
# Out:
# prob_iou: 0.24651047462946038
# cnr: 2.1663362979888916
# soft_dice: 0.29776567691420247
# dice: 0.3493532973031421
# rand_index: 0.9332763686006826
# precision: 0.37676790371460794
# recall: 0.4950402271358904

# %% [markdown]
# #### MAIRA-2

# %%
from medvqa.utils.files_utils import load_jsonl

# %%
maira2_predictions = load_jsonl('/home/pamessina/maira2_phrase_grounding_predictions/chestxdet_phrase_grounding_results.jsonl')

# %%
from collections import defaultdict

image_phrase_to_polygons = dict()
image_to_polygons = defaultdict(list)

for item in maira2_predictions:
    fn = item['file_name']
    key = (fn, item['phrase'])
    i = len(image_to_polygons[fn])
    polygons = item['polygons'][i]
    image_phrase_to_polygons[key] = polygons
    image_to_polygons[fn].append(polygons)
    assert len(polygons) ==  len(item['gt_bboxes'])

    # maira2_predictions[0]

# %%
maira2_predictions[0]
# Out:
# {'file_name': '36302.png',
#  'image_path': '/mnt/workspace/ChestX-Det-Dataset/test/36302.png',
#  'polygons': [[[[0.7802734375, 0.662109375],
#     [0.7802734375, 0.662109375],
#     [0.7802734375, 0.6640625],
#     [0.7822265625, 0.6650390625],
#     [0.7861328125, 0.66796875],
#     [0.7880859375, 0.66796875],
#     [0.7900390625, 0.6689453125],
#     [0.7919921875, 0.669921875],
#     [0.7939453125, 0.669921875],
#     [0.794921875, 0.669921875],
#     [0.7978515625, 0.6708984375],
#     [0.80078125, 0.6708984375],
#     [0.8046875, 0.673828125],
#     [0.8076171875, 0.673828125],
#     [0.810546875, 0.6748046875],
#     [0.8125, 0.6748046875],
#     [0.8134765625, 0.6748046875],
#     [0.81640625, 0.6767578125],
#     [0.8173828125, 0.6767578125],
#     [0.8203125, 0.6787109375],
#     [0.82421875, 0.6796875],
#     [0.828125, 0.6796875],
#     [0.8310546875, 0.6806640625],
#     [0.833984375, 0.6806640625],
#     [0.8349609375, 0.6806640625],
#     [0.8359375, 0.681640625],
# ...

# %%
from medvqa.evaluation.bootstrapping import apply_bootstrapping
from medvqa.utils.bbox_utils import convert_bboxes_into_presence_map
from medvqa.utils.metrics_utils import (
    calculate_cnr, calculate_dice, calculate_soft_dice, calculate_segmentation_precision,
    calculate_segmentation_recall, calculate_rand_index, calculate_segmentation_iou
)
from medvqa.datasets.chestxdet.chestxdet_phrase_grounding_dataset_management import polygons_to_mask
    
maira2_method_dict = {}
maira2_metrics = {}

ious_list = []
cnrs_list = []
dice_list = []
soft_dice_list = []
precision_list = []
recall_list = []
rand_index_list = []
for x in maira2_predictions:
    gt_polygons = image_phrase_to_polygons[(x['file_name'], x['phrase'])]
    pred_bboxes = x['predicted_bboxes']
    gt_mask = polygons_to_mask(gt_polygons, 200, 200)
    pred_mask = convert_bboxes_into_presence_map(pred_bboxes, (200, 200))
    iou = calculate_segmentation_iou(gt_mask, pred_mask)
    cnr = calculate_cnr(gt_mask, pred_mask)
    dice = calculate_dice(gt_mask, pred_mask)
    soft_dice = calculate_soft_dice(gt_mask, pred_mask)
    precision = calculate_segmentation_precision(gt_mask, pred_mask)
    recall = calculate_segmentation_recall(gt_mask, pred_mask)
    rand_index = calculate_rand_index(gt_mask, pred_mask)
    ious_list.append(iou)
    cnrs_list.append(cnr)
    dice_list.append(dice)
    soft_dice_list.append(soft_dice)
    precision_list.append(precision)
    recall_list.append(recall)
    rand_index_list.append(rand_index)

for metric, values in zip(
    ['cnr', 'iou', 'dice', 'soft_dice', 'precision', 'recall', 'rand_index'],
    [cnrs_list, ious_list, dice_list, soft_dice_list, precision_list, recall_list, rand_index_list]
):
    maira2_metrics[f'{metric}_list'] = values
    out = apply_bootstrapping(
            metric_values=values,
            metric_name=metric,
            use_tqdm=False,
        )
    maira2_metrics.update(out)
    maira2_method_dict.update(out)

aux = {}
for k, v in maira2_method_dict.items():
    aux[k] = v['mean']
    aux[f'{k}_std'] = v['std']
    
maira2_method_dict = aux

# %%
maira2_method_dict
# Out:
# {'cnr': 0.7904939669021396,
#  'cnr_std': 0.034611767718018084,
#  'iou': 0.15250516370993344,
#  'iou_std': 0.006051006596026585,
#  'dice': 0.22212208032467237,
#  'dice_std': 0.008067025424410063,
#  'soft_dice': 0.22212208032467237,
#  'soft_dice_std': 0.008067025424410063,
#  'precision': 0.21503598618550848,
#  'precision_std': 0.008248819451938512,
#  'recall': 0.4077970971310499,
#  'recall_std': 0.012967233653918287,
#  'rand_index': 0.8852244912542663,
#  'rand_index_std': 0.0031501672277107953}

# %%
from medvqa.evaluation.bootstrapping import apply_bootstrapping
from medvqa.utils.bbox_utils import convert_bboxes_into_presence_map
from medvqa.metrics.bbox.utils import compute_bbox_union_iou
from medvqa.utils.metrics_utils import (
    calculate_cnr, calculate_dice, calculate_soft_dice, calculate_segmentation_precision,
    calculate_segmentation_recall, calculate_rand_index,
)
    
maira2_method_dict = {}
maira2_metrics = {}

ious_list = []
cnrs_list = []
dice_list = []
soft_dice_list = []
precision_list = []
recall_list = []
rand_index_list = []
for x in maira2_predictions:
    gt_bboxes = x['gt_bboxes']
    pred_bboxes = x['predicted_bboxes']
    gt_mask = convert_bboxes_into_presence_map(gt_bboxes, (200, 200))
    pred_mask = convert_bboxes_into_presence_map(pred_bboxes, (200, 200))
    iou = compute_bbox_union_iou(gt_bboxes, pred_bboxes)
    cnr = calculate_cnr(gt_mask, pred_mask)
    dice = calculate_dice(gt_mask, pred_mask)
    soft_dice = calculate_soft_dice(gt_mask, pred_mask)
    precision = calculate_segmentation_precision(gt_mask, pred_mask)
    recall = calculate_segmentation_recall(gt_mask, pred_mask)
    rand_index = calculate_rand_index(gt_mask, pred_mask)
    ious_list.append(iou)
    cnrs_list.append(cnr)
    dice_list.append(dice)
    soft_dice_list.append(soft_dice)
    precision_list.append(precision)
    recall_list.append(recall)
    rand_index_list.append(rand_index)

for metric, values in zip(
    ['cnr', 'iou', 'dice', 'soft_dice', 'precision', 'recall', 'rand_index'],
    [cnrs_list, ious_list, dice_list, soft_dice_list, precision_list, recall_list, rand_index_list]
):
    maira2_metrics[f'{metric}_list'] = values
    out = apply_bootstrapping(
            metric_values=values,
            metric_name=metric,
            use_tqdm=False,
        )
    maira2_metrics.update(out)
    maira2_method_dict.update(out)

aux = {}
for k, v in maira2_method_dict.items():
    aux[k] = v['mean']
    aux[f'{k}_std'] = v['std']
    
maira2_method_dict = aux

# %%
maira2_method_dict
# Out:
# {'cnr': 0.7956164468649438,
#  'cnr_std': 0.03658790493024083,
#  'iou': 0.1942475645804355,
#  'iou_std': 0.007357848938799191,
#  'dice': 0.27213725171027586,
#  'dice_std': 0.009146145424152846,
#  'soft_dice': 0.27213725171027586,
#  'soft_dice_std': 0.009146145424152846,
#  'precision': 0.30619764194740434,
#  'precision_std': 0.010452920482290955,
#  'recall': 0.3873900014918457,
#  'recall_std': 0.01253177151937659,
#  'rand_index': 0.8793361655290103,
#  'rand_index_std': 0.003158745933317688}

# %% [markdown]
# #### BioViL-T

# %%
from medvqa.utils.files_utils import load_pickle

# %%
biovilt_predictions = load_pickle('/home/pamessina/biovil-t_phrase_grounding_predictions/chestxdet_phrase_grounding_results.pkl')

# %%
len(biovilt_predictions)
# Out:
# 1172

# %%
import numpy as  np
import random
from medvqa.evaluation.bootstrapping import apply_bootstrapping
from medvqa.utils.metrics_utils import (
    calculate_cnr, calculate_dice, calculate_soft_dice, calculate_segmentation_precision,
    calculate_segmentation_recall, calculate_rand_index, calculate_segmentation_iou,
    find_optimal_probability_map_conf_threshold_for_masks
)
from medvqa.datasets.chestxdet.chestxdet_phrase_grounding_dataset_management import polygons_to_mask

biovilt_method_dict = {}
biovilt_metrics = {}

pred_mask_list = []
gt_mask_list = []
for x in biovilt_predictions:
    if x['split'] == 'test':
        pred_mask_list.append(x['similarity_map'])
        gt_mask_list.append(polygons_to_mask(x['polygons'], 100, 100))
assert len(pred_mask_list) == len(gt_mask_list)
assert len(pred_mask_list) > 0
print(f'Number of test samples: {len(pred_mask_list)}')

# Sample subset for threshold optimization
idxs = random.sample(range(len(pred_mask_list)), min(500, len(pred_mask_list)))
pred_mask_list_sample = [pred_mask_list[i] for i in idxs]
gt_mask_list_sample = [gt_mask_list[i] for i in idxs]

out = find_optimal_probability_map_conf_threshold_for_masks(
    np.array(pred_mask_list_sample), gt_mask_list_sample,
)

print(out)
best_conf_th = out['best_conf_th']

ious_list = []
cnrs_list = []
dice_list = []
soft_dice_list = []
precision_list = []
recall_list = []
rand_index_list = []

for pred_mask, gt_mask in zip(pred_mask_list, gt_mask_list):
    iou = calculate_segmentation_iou(gt_mask, pred_mask, threshold=best_conf_th)
    cnr = calculate_cnr(gt_mask, pred_mask)
    dice = calculate_dice(gt_mask, pred_mask, threshold=best_conf_th)
    soft_dice = calculate_soft_dice(gt_mask, pred_mask)
    precision = calculate_segmentation_precision(gt_mask, pred_mask, threshold=best_conf_th)
    recall = calculate_segmentation_recall(gt_mask, pred_mask, threshold=best_conf_th)
    rand_index = calculate_rand_index(gt_mask, pred_mask, threshold=best_conf_th)
    ious_list.append(iou )
    cnrs_list.append(cnr)
    dice_list.append(dice)
    soft_dice_list.append(soft_dice)
    precision_list.append(precision)
    recall_list.append(recall)
    rand_index_list.append(rand_index)

for metric, values in zip(
    ['cnr', 'iou', 'dice', 'soft_dice', 'precision', 'recall', 'rand_index'],
    [cnrs_list, ious_list, dice_list, soft_dice_list, precision_list, recall_list, rand_index_list]
):
    biovilt_metrics[f'{metric}_list'] = values
    out = apply_bootstrapping(
            metric_values=values,
            metric_name=metric,
            use_tqdm=False,
        )
    biovilt_metrics.update(out)
    biovilt_method_dict.update(out)

aux = {}
for k, v in biovilt_method_dict.items():
    aux[k] = v['mean']
    aux[f'{k}_std'] = v['std']
    
biovilt_method_dict = aux
# Out:
# Number of test samples: 1172
# Optimizing threshold: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 23.01it/s]
# {'best_iou': 0.14901299432108225, 'best_conf_th': 0.6}

# %%
for metric in ['cnr', 'iou', 'soft_dice', 'dice', 'precision', 'recall', 'rand_index']:
    print(f'{metric}: {biovilt_method_dict[metric]}')
# Out:
# cnr: 0.8099584579467773
# iou: 0.1532772707205127
# soft_dice: 0.13586639712223347
# dice: 0.22791566128769158
# precision: 0.2215432715677058
# recall: 0.43002551310526826
# rand_index: 0.8752160445392492

# %% [markdown]
# #### Random

# %%
import numpy as  np
from medvqa.evaluation.bootstrapping import apply_bootstrapping
from medvqa.utils.metrics_utils import (
    calculate_cnr, calculate_dice, calculate_soft_dice, calculate_segmentation_precision,
    calculate_segmentation_recall, calculate_rand_index, calculate_segmentation_iou,
)
from medvqa.datasets.chestxdet.chestxdet_phrase_grounding_dataset_management import polygons_to_mask

random_method_dict = {}
random_metrics = {}

pred_mask_list = []
gt_mask_list = []
for x in biovilt_predictions:
    if x['split'] == 'test':
        pred_mask_list.append(np.random.random((100, 100))) # Random prediction
        gt_mask_list.append(polygons_to_mask(x['polygons'], 100, 100))
assert len(pred_mask_list) == len(gt_mask_list)
assert len(pred_mask_list) > 0
print(f'Number of test samples: {len(pred_mask_list)}')

best_conf_th = 0.5 # Default value for random predictions

ious_list = []
cnrs_list = []
dice_list = []
soft_dice_list = []
precision_list = []
recall_list = []
rand_index_list = []

for pred_mask, gt_mask in zip(pred_mask_list, gt_mask_list):
    iou = calculate_segmentation_iou(gt_mask, pred_mask, threshold=best_conf_th)
    cnr = calculate_cnr(gt_mask, pred_mask)
    dice = calculate_dice(gt_mask, pred_mask, threshold=best_conf_th)
    soft_dice = calculate_soft_dice(gt_mask, pred_mask)
    precision = calculate_segmentation_precision(gt_mask, pred_mask, threshold=best_conf_th)
    recall = calculate_segmentation_recall(gt_mask, pred_mask, threshold=best_conf_th)
    rand_index = calculate_rand_index(gt_mask, pred_mask, threshold=best_conf_th)
    ious_list.append(iou )
    cnrs_list.append(cnr)
    dice_list.append(dice)
    soft_dice_list.append(soft_dice)
    precision_list.append(precision)
    recall_list.append(recall)
    rand_index_list.append(rand_index)

for metric, values in zip(
    ['cnr', 'iou', 'dice', 'soft_dice', 'precision', 'recall', 'rand_index'],
    [cnrs_list, ious_list, dice_list, soft_dice_list, precision_list, recall_list, rand_index_list]
):
    random_metrics[f'{metric}_list'] = values
    out = apply_bootstrapping(
            metric_values=values,
            metric_name=metric,
            use_tqdm=False,
        )
    random_metrics.update(out)
    random_method_dict.update(out)

aux = {}
for k, v in random_method_dict.items():
    aux[k] = v['mean']
    aux[f'{k}_std'] = v['std']
    
random_method_dict = aux
# Out:
# Number of test samples: 1172

# %%
for metric in ['cnr', 'iou', 'soft_dice', 'dice', 'precision', 'recall', 'rand_index']:
    print(f'{metric}: {random_method_dict[metric]}')
# Out:
# cnr: 0.000676347461510006
# iou: 0.05544018629527345
# soft_dice: 0.09834898798991713
# dice: 0.09847203780547455
# precision: 0.06424946855721032
# recall: 0.5003101278889421
# rand_index: 0.5002050464163822
