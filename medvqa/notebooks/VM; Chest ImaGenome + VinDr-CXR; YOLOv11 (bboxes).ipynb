# %%
# %env CUDA_VISIBLE_DEVICES=1
# %env CUDA_LAUNCH_BLOCKING=1
# Out:
# env: CUDA_VISIBLE_DEVICES=1

# %%
# !python ../train_visual_module.py \
--epochs 200 \
--batches_per_epoch 500 \
--batch_size 100 \
--num_workers 3 \
--gradient_accumulation_steps 1 \
--optimizer_name "adamw" \
--scheduler "exp-warmup+decay+cyclicdecay" \
--lr 1e-6 \
--warmup_decay_and_cyclic_decay_args "1e-5,3,8e-4,6,1e-5,8e-4,6,1e-5" \
--use_mimiccxr \
--mimiccxr_view_mode "chest_imagenome" \
--predict_bboxes_chest_imagenome \
--clamp_bboxes_chest_imagenome \
--use_vinbig \
--vinbig_training_data_mode "train" \
--vinbig_use_validation \
--predict_bboxes_vinbig \
--binary_loss_name "focal+bce+wbcbce" \
--raw_image_encoding "yolov11-for-det-mlc" \
--yolov11_model_name_or_path "yolo11l.pt" \
--yolov11_model_alias "yolo11l" \
--image_size 416 416 \
--image_local_feat_size 512 \
--num_regions 169 \
--img_aug_mode "random-color-and-spatial" \
--use_amp \
--save
# Out:
# script's arguments:
#    epochs: 200
#    batches_per_epoch: 500
#    checkpoint_folder: None
#    visual_input_mode: raw-image
#    raw_image_encoding: yolov11-for-det-mlc
#    image_local_feat_size: 512
#    image_encoder_pretrained_weights_path: None
#    freeze_image_encoder: False
#    imagenet_pretrained: False
#    visual_features_mlp_in_dim: None
#    visual_features_mlp_out_dim: None
#    visual_features_mlp_hidden_dims: None
#    classification_mlp_hidden_dims: None
#    iuxray_precomputed_visual_features_path: None
#    mimiccxr_precomputed_visual_features_path: None
#    chexpert_precomputed_visual_features_path: None
#    vinbig_precomputed_visual_features_path: None
#    clip_version: None
#    huggingface_model_name: None
#    chexpert_mlc_version: None
#    chexpert_mlc_hidden_size: 128
#    chest_imagenome_bbox_hidden_size: 128
#    chest_imagenome_bbox_regressor_version: None
#    chest_imagenome_mlc_version: None
#    chest_imagenome_mlc_hidden_size: 128
#    vinbig_mlc_hidden_size: 128
#    torchxrayvision_weights_name: None
#    detectron2_model_yaml: None
#    num_regions: 169
#    roi_heads_batch_size_per_image: 128
#    rpn_batch_size_per_image: 128
#    roi_align_output_size: None
#    yolov8_model_name_or_path: None
#    yolov8_model_alias: None
#    yolov8_use_one_detector_per_dataset: False
#    yolov11_model_name_or_path: yolo11l.pt
#    yolov11_model_alias: yolo11l
#    query_embed_size: None
#    local_attention_hidden_size: None
#    optimizer_name: adamw
#    lr: 1e-06
#    scheduler: exp-warmup+decay+cyclicdecay
#    lr_decay: 0.76
#    lr_decay_patience: 2
#    warmup_and_decay_args: None
#    warmup_and_cosine_args: None
#    warmup_decay_and_cyclic_decay_args: 1e-5,3,8e-4,6,1e-5,8e-4,6,1e-5
#    batch_size: 100
#    gradient_accumulation_steps: 1
#    num_workers: 3
#    device: GPU
#    img_aug_mode: random-color-and-spatial
#    image_size: [416, 416]
#    horizontal_flip_prob: 0
#    mimiccxr_weight: 1
#    chexpert_weight: 0.3
#    cxr14_weight: 0.3
#    vinbig_weight: 0.3
#    iuxray_weight: 0.05
#    padchest_weight: 0.4
#    mimiccxr_view_mode: chest_imagenome
#    mimiccxr_balanced_sampling_mode: None
#    mimiccxr_balanced_batch_size: None
#    chest_imagenome_labels_filename: None
#    chest_imagenome_label_names_filename: None
#    use_chest_imagenome_decent_images_only: False
#    use_amp: True
#    pretrained_checkpoint_folder_path: None
#    save: True
#    override_lr: False
#    train_mimiccxr: True
#    train_iuxray: False
#    train_chexpert: False
#    train_cxr14: False
#    train_vinbig: True
#    vinbig_training_data_mode: train
#    vinbig_use_validation: True
#    train_padchest: False
#    padchest_training_data_mode: train
#    padchest_use_validation: False
#    padchest_train_study_ids_path: None
#    padchest_val_study_ids_path: None
#    padchest_test_study_ids_path: None
#    binary_loss_name: focal+bce+wbcbce
#    focal_loss_weight: 1
#    bce_loss_weight: 1
#    wbce_loss_weight: 1
#    classify_tags: False
#    n_medical_tags: None
#    iuxray_medical_tags_per_report_filename: None
#    mimiccxr_medical_tags_per_report_filename: None
#    classify_orientation: False
#    classify_gender: False
#    classify_chexpert: False
#    iuxray_chexpert_labels_filename: None
#    mimiccxr_chexpert_labels_filename: None
#    classify_chest_imagenome: False
#    predict_bboxes_chest_imagenome: True
#    predict_labels_and_bboxes_chest_imagenome: False
#    clamp_bboxes_chest_imagenome: True
#    use_anaxnet_bbox_subset: False
#    chest_imagenome_bbox_loss_weight: 1.0
#    pass_pred_bbox_coords_as_input: False
#    use_gt_bboxes_as_predictions: False
#    predict_bboxes_vinbig: True
#    classify_labels_vinbig: False
#    classify_questions: False
#    n_mined_questions: None
#    iuxray_question_labels_filename: None
#    mimiccxr_question_labels_filename: None
#    merge_findings: False
# ----- Training model from scratch ------
# Loading /mnt/data/pamessina/workspaces/medvqa-workspace/cache/chest_imagenome/chest_imagenome_train_average_bbox_coords(clamped).pkl...
# avg_coords.shape= (144,)
# source_image_size_mode: medium_512
# vinbig_class_id_offset: 0
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Creating instance of MultiPurposeVisualModule ...
# MultiPurposeVisualModule()
#   Initializing raw_image_encoder: yolov11-for-det-mlc
# Overriding model.yaml nc=80 with nc=36
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  2    173824  ultralytics.nn.modules.block.C3k2            [128, 256, 2, True, 0.25]
#   3                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   4                  -1  2    691712  ultralytics.nn.modules.block.C3k2            [256, 512, 2, True, 0.25]
#   5                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   6                  -1  2   2234368  ultralytics.nn.modules.block.C3k2            [512, 512, 2, True]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  2   2234368  ultralytics.nn.modules.block.C3k2            [512, 512, 2, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  2   1455616  ultralytics.nn.modules.block.C2PSA           [512, 512, 2]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  2   2496512  ultralytics.nn.modules.block.C3k2            [1024, 512, 2, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  2    756736  ultralytics.nn.modules.block.C3k2            [1024, 256, 2, True]
#  17                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  2   2365440  ultralytics.nn.modules.block.C3k2            [768, 512, 2, True]
#  20                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  2   2496512  ultralytics.nn.modules.block.C3k2            [1024, 512, 2, True]
#  23        [16, 19, 22]  1   1438780  ultralytics.nn.modules.head.Detect           [36, [256, 512, 512]]
# YOLO11l summary: 631 layers, 25,338,236 parameters, 25,338,220 gradients, 87.4 GFLOPs
#
# Transferred 1009/1015 items from pretrained weights
# Overriding model.yaml nc=80 with nc=22
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  2    173824  ultralytics.nn.modules.block.C3k2            [128, 256, 2, True, 0.25]
#   3                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   4                  -1  2    691712  ultralytics.nn.modules.block.C3k2            [256, 512, 2, True, 0.25]
#   5                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   6                  -1  2   2234368  ultralytics.nn.modules.block.C3k2            [512, 512, 2, True]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  2   2234368  ultralytics.nn.modules.block.C3k2            [512, 512, 2, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  2   1455616  ultralytics.nn.modules.block.C2PSA           [512, 512, 2]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  2   2496512  ultralytics.nn.modules.block.C3k2            [1024, 512, 2, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  2    756736  ultralytics.nn.modules.block.C3k2            [1024, 256, 2, True]
#  17                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  2   2365440  ultralytics.nn.modules.block.C3k2            [768, 512, 2, True]
#  20                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  2   2496512  ultralytics.nn.modules.block.C3k2            [1024, 512, 2, True]
#  23        [16, 19, 22]  1   1427986  ultralytics.nn.modules.head.Detect           [22, [256, 512, 512]]
# YOLO11l summary: 631 layers, 25,327,442 parameters, 25,327,426 gradients, 87.4 GFLOPs
#
# Transferred 1009/1015 items from pretrained weights
#   Initializing auxiliary tasks
#     Skipping auxiliary tasks initialization for YOLOV11_FOR_DET_MLC
# --------------------------------------------------
# 3) Defining optimizer ...
# create_optimizer(): name = adamw
# --------------------------------------------------
# 4) Defining scheduler ...
# Using exp-warmup+decay+cyclicdecay scheduler: 1e-5,3,8e-4,6,1e-5,8e-4,6,1e-5
# 1e-05 3 0.0008 6 1e-05 0.0008 6 1e-05
# self.steps_to_restart = 6
# self.steps = -1
# self.initial_lr = 0.0008
# --------------------------------------------------
# 5) Creating trainer and validator engines ...
# get_engine(): shift_answer=False
# Focal_BCE_WBCBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 wbcbce_weight = 0.3333333333333333
# GradientAccumulator.__init__(): num_accumulation_steps = 1, max_grad_norm = None
# chest_imagenome_bbox_loss_weight:  1.0
# get_engine(): shift_answer=False
# chest_imagenome_bbox_loss_weight:  1.0
# --------------------------------------------------
# 6) Defining collate_batch_fn ...
# --------------------------------------------------
# 7) Creating MIMIC-CXR visual module trainer ...
# get_image_transform()
#   image_size = [416, 416]
#   mean = [0.0, 0.0, 0.0]
#   std = [1.0, 1.0, 1.0]
#   Using bounding box aware transforms
#     augmentation_mode = random-color-and-spatial
#     default_prob = 0.35
#     returning transform (not for vinbig)
#     Returning augmented transform with mode random-color-and-spatial
# get_image_transform()
#   image_size = [416, 416]
#   mean = [0.0, 0.0, 0.0]
#   std = [1.0, 1.0, 1.0]
#   Using bounding box aware transforms
#     Returning default transform (no augmentation)
# Using image size mode: medium_512
# Allowed dicom ids: 240530
# 227835it [00:01, 223613.05it/s]
# max_idx_count = 377110
# actual_idx_count = 240530
# ** NOTE: 136580 images were skipped because they were not in the allowed DICOM IDs
# len(self.train_indices) = 235209
# len(self.val_indices) = 1945
# Loading Chest Imagenome bounding boxes...
# self.bbox_coords.shape = (243310, 36, 4)
# self.bbox_presence.shape = (243310, 36)
# --------------------------------------------------
# 8) Creating VinBig visual module trainer ...
# get_image_transform()
#   image_size = [416, 416]
#   mean = [0.0, 0.0, 0.0]
#   std = [1.0, 1.0, 1.0]
#   Using bounding box aware transforms
#     augmentation_mode = random-color-and-spatial
#     default_prob = 0.35
#     for_vinbig: returning vinbig transform
# get_train_transform(): Using bbox-aware transforms for VinBigData
#     Returning augmented transform with mode random-color-and-spatial
# get_image_transform()
#   image_size = [416, 416]
#   mean = [0.0, 0.0, 0.0]
#   std = [1.0, 1.0, 1.0]
#   Using bounding box aware transforms
#     Returning default transform (no augmentation)
# Loading bounding boxes
# Anomalous bboxes found: 29 of 37367
# class_id_offset: 0
# Anomalous bboxes found: 0 of 2697
# class_id_offset: 0
#   Loaded 18000 bounding boxes
# Generating train dataset and dataloader
# No finding        , #pos=10601, #neg=4399
# Other disease     , #pos=4288, #neg=10712
# Aortic enlargement, #pos=3067, #neg=11933
# Cardiomegaly      , #pos=2300, #neg=12700
# Pleural thickening, #pos=1981, #neg=13019
# Pulmonary fibrosis, #pos=1617, #neg=13383
# Lung Opacity      , #pos=1322, #neg=13678
# Other lesion      , #pos=1134, #neg=13866
# Pleural effusion  , #pos=1032, #neg=13968
# Pneumonia         , #pos=917, #neg=14083
# Nodule/Mass       , #pos=830, #neg=14170
# Tuberculosis      , #pos=750, #neg=14250
# Infiltration      , #pos=613, #neg=14387
# Calcification     , #pos=452, #neg=14548
# ILD               , #pos=386, #neg=14614
# Consolidation     , #pos=353, #neg=14647
# Lung tumor        , #pos=291, #neg=14709
# Atelectasis       , #pos=186, #neg=14814
# Mediastinal shift , #pos=150, #neg=14850
# Enlarged PA       , #pos=131, #neg=14869
# Pneumothorax      , #pos=96, #neg=14904
# Rib fracture      , #pos=90, #neg=14910
# Emphysema         , #pos=78, #neg=14922
# Lung cavity       , #pos=50, #neg=14950
# COPD              , #pos=35, #neg=14965
# Lung cyst         , #pos=32, #neg=14968
# Clavicle fracture , #pos=27, #neg=14973
# Edema             , #pos=13, #neg=14987
# len(train_indices) = 15000
# len(self.test_indices) = 3000
# --------------------------------------------------
# 9) Creating dataloaders ...
# len(_train_dataloaders) = 2
# len(_val_dataloaders) = 2
# _train_weights = [1, 0.3]
# merged_dataset_name = mim+vinbig
# --------------------------------------------------
# 10) Attaching metrics, losses, timer and events to engines ...
# NOTE: Using only validation metrics
# --------------------------------------------------
# 11) Defining learning rate scheduler handler ...
# --------------------------------------------------
# 12) Defining checkpoint folder path ...
# checkpoint_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20241122_141806_mim+vinbig_yolo11l(d:cig,vinbig)_dws=1,0.3
# metadata saved to /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20241122_141806_mim+vinbig_yolo11l(d:cig,vinbig)_dws=1,0.3/metadata.json
# --------------------------------------------------
# 13) Defining log_metrics_handler ...
# MetricsLogger :: we'll be logging to /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20241122_141806_mim+vinbig_yolo11l(d:cig,vinbig)_dws=1,0.3/metrics_logs.csv
# --------------------------------------------------
# 14) Running trainer engine ...
# ---- Epoch 1/200
# (1) Training stage (lr = 0.000010) ...
# loss 8.57546, vnb_y11_loss 10.54153, vnb_y11_box_loss 2.90863, vnb_y11_cls_loss 4.86318, vnb_y11_dfl_loss 2.76972, cig_y11_loss 7.98154, cig_y11_box_loss 2.45804, cig_y11_cls_loss 2.98263, cig_y11_dfl_loss 2.54087, 394.43 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.00000, cig_y11_bbox_iou 0.22413, 38.21 secs
# New checkpoint saved: checkpoint_1_cig_y11_bbox_iou+vnb_y11_bbox_iou=0.1121.pt
# ---- Epoch 2/200
# (1) Training stage (lr = 0.000043) ...
# loss 6.79799, vnb_y11_loss 9.05664, vnb_y11_box_loss 2.64396, vnb_y11_cls_loss 3.96115, vnb_y11_dfl_loss 2.45154, cig_y11_loss 6.11569, cig_y11_box_loss 2.09853, cig_y11_cls_loss 1.87220, cig_y11_dfl_loss 2.14496, 404.31 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.00825, cig_y11_bbox_iou 0.35707, 41.92 secs
# New checkpoint saved: checkpoint_2_cig_y11_bbox_iou+vnb_y11_bbox_iou=0.1827.pt
# ---- Epoch 3/200
# (1) Training stage (lr = 0.000186) ...
# loss 6.18340, vnb_y11_loss 8.26615, vnb_y11_box_loss 2.48904, vnb_y11_cls_loss 3.49047, vnb_y11_dfl_loss 2.28663, cig_y11_loss 5.55424, cig_y11_box_loss 1.95633, cig_y11_cls_loss 1.62866, cig_y11_dfl_loss 1.96925, 410.76 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.01273, cig_y11_bbox_iou 0.47603, 46.34 secs
# New checkpoint saved: checkpoint_3_cig_y11_bbox_iou+vnb_y11_bbox_iou=0.2444.pt
# ---- Epoch 4/200
# (1) Training stage (lr = 0.000800) ...
# loss 5.94399, vnb_y11_loss 7.96331, vnb_y11_box_loss 2.42772, vnb_y11_cls_loss 3.29248, vnb_y11_dfl_loss 2.24311, cig_y11_loss 5.32713, cig_y11_box_loss 1.89862, cig_y11_cls_loss 1.51678, cig_y11_dfl_loss 1.91173, 419.52 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.02959, cig_y11_bbox_iou 0.49848, 47.90 secs
# New checkpoint saved: checkpoint_4_cig_y11_bbox_iou+vnb_y11_bbox_iou=0.2640.pt
# ---- Epoch 5/200
# (1) Training stage (lr = 0.000385) ...
# loss 5.65521, vnb_y11_loss 7.50584, vnb_y11_box_loss 2.31571, vnb_y11_cls_loss 3.03466, vnb_y11_dfl_loss 2.15547, cig_y11_loss 5.09616, cig_y11_box_loss 1.82311, cig_y11_cls_loss 1.41571, cig_y11_dfl_loss 1.85734, 413.62 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.02412, cig_y11_bbox_iou 0.51974, 48.13 secs
# New checkpoint saved: checkpoint_5_cig_y11_bbox_iou+vnb_y11_bbox_iou=0.2719.pt
# ---- Epoch 6/200
# (1) Training stage (lr = 0.000186) ...
# loss 5.57587, vnb_y11_loss 7.36088, vnb_y11_box_loss 2.28689, vnb_y11_cls_loss 2.94956, vnb_y11_dfl_loss 2.12443, cig_y11_loss 5.03664, cig_y11_box_loss 1.80269, cig_y11_cls_loss 1.38874, cig_y11_dfl_loss 1.84521, 415.12 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.03051, cig_y11_bbox_iou 0.52580, 48.42 secs
# New checkpoint saved: checkpoint_6_cig_y11_bbox_iou+vnb_y11_bbox_iou=0.2782.pt
# ---- Epoch 7/200
# (1) Training stage (lr = 0.000089) ...
# loss 5.51247, vnb_y11_loss 7.25687, vnb_y11_box_loss 2.25430, vnb_y11_cls_loss 2.89763, vnb_y11_dfl_loss 2.10494, cig_y11_loss 4.98551, cig_y11_box_loss 1.78653, cig_y11_cls_loss 1.36725, cig_y11_dfl_loss 1.83173, 416.79 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.03435, cig_y11_bbox_iou 0.52130, 47.86 secs
# ---- Epoch 8/200
# (1) Training stage (lr = 0.000043) ...
# loss 5.49493, vnb_y11_loss 7.22272, vnb_y11_box_loss 2.24514, vnb_y11_cls_loss 2.88378, vnb_y11_dfl_loss 2.09380, cig_y11_loss 4.96712, cig_y11_box_loss 1.77957, cig_y11_cls_loss 1.35964, cig_y11_dfl_loss 1.82792, 422.11 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.03801, cig_y11_bbox_iou 0.52821, 48.02 secs
# New checkpoint saved: checkpoint_8_cig_y11_bbox_iou+vnb_y11_bbox_iou=0.2831.pt
# ---- Epoch 9/200
# (1) Training stage (lr = 0.000021) ...
# ^C iteration 4025
# Engine run is terminating due to exception:
# Traceback (most recent call last):
#   File "/home/pamessina/medvqa/medvqa/notebooks/../train_visual_module.py", line 1548, in <module>
#     train_from_scratch(**args)
#   File "/home/pamessina/medvqa/medvqa/notebooks/../train_visual_module.py", line 1422, in train_from_scratch
#     return train_model(
#   File "/home/pamessina/medvqa/medvqa/notebooks/../train_visual_module.py", line 863, in train_model
#     trainer_engine.run(train_dataloader, max_epochs = epochs, epoch_length = batches_per_epoch)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 892, in run
#     return self._internal_run()
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 935, in _internal_run
#     return next(self._internal_run_generator)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 993, in _internal_run_as_gen
#     self._handle_exception(e)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 638, in _handle_exception
#     raise e
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 959, in _internal_run_as_gen
#     epoch_time_taken += yield from self._run_once_on_dataset_as_gen()
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 1032, in _run_once_on_dataset_as_gen
#     self.state.batch = next(self._dataloader_iter)
#   File "/home/pamessina/medvqa/medvqa/datasets/dataloading_utils.py", line 208, in balanced_dataloaders_generator
#     yield next(cyclic_dataloaders[i])
#   File "/home/pamessina/medvqa/medvqa/datasets/dataloading_utils.py", line 174, in cyclic_dataloader_generator
#     for batch in dataloader:
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 631, in __next__
#     data = self._next_data()
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1329, in _next_data
#     idx, data = self._get_data()
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1285, in _get_data
#     success, data = self._try_get_data()
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1133, in _try_get_data
#     data = self._data_queue.get(timeout=timeout)
#   File "/usr/lib/python3.10/queue.py", line 180, in get
#     self.not_empty.wait(remaining)
#   File "/usr/lib/python3.10/threading.py", line 324, in wait
#     gotit = waiter.acquire(True, timeout)
# KeyboardInterrupt

# %%
# !python ../train_visual_module.py \
--epochs 100 \
--batches_per_epoch 250 \
--batch_size 100 \
--num_workers 3 \
--gradient_accumulation_steps 4 \
--optimizer_name "adamw" \
--scheduler "exp-warmup+decay+cyclicdecay" \
--lr 1e-6 \
--warmup_decay_and_cyclic_decay_args "5e-6,3,8e-4,6,5e-6,8e-4,6,5e-6" \
--use_mimiccxr \
--mimiccxr_view_mode "chest_imagenome" \
--predict_bboxes_chest_imagenome \
--clamp_bboxes_chest_imagenome \
--use_vinbig \
--vinbig_training_data_mode "train" \
--vinbig_use_validation \
--predict_bboxes_vinbig \
--binary_loss_name "focal+bce+wbcbce" \
--raw_image_encoding "yolov11-for-det-mlc" \
--yolov11_model_name_or_path "/mnt/data/pamessina/workspaces/medvqa-workspace/cache/chest_imagenome/yolov11/train4/weights/best.pt" \
--yolov11_model_alias "yolo11l" \
--image_size 416 416 \
--image_local_feat_size 512 \
--num_regions 169 \
--img_aug_mode "random-color-and-spatial" \
--use_amp \
--save
# Out:
# script's arguments:
#    epochs: 100
#    batches_per_epoch: 250
#    checkpoint_folder: None
#    visual_input_mode: raw-image
#    raw_image_encoding: yolov11-for-det-mlc
#    image_local_feat_size: 512
#    image_encoder_pretrained_weights_path: None
#    freeze_image_encoder: False
#    imagenet_pretrained: False
#    visual_features_mlp_in_dim: None
#    visual_features_mlp_out_dim: None
#    visual_features_mlp_hidden_dims: None
#    classification_mlp_hidden_dims: None
#    iuxray_precomputed_visual_features_path: None
#    mimiccxr_precomputed_visual_features_path: None
#    chexpert_precomputed_visual_features_path: None
#    vinbig_precomputed_visual_features_path: None
#    clip_version: None
#    huggingface_model_name: None
#    chexpert_mlc_version: None
#    chexpert_mlc_hidden_size: 128
#    chest_imagenome_bbox_hidden_size: 128
#    chest_imagenome_bbox_regressor_version: None
#    chest_imagenome_mlc_version: None
#    chest_imagenome_mlc_hidden_size: 128
#    vinbig_mlc_hidden_size: 128
#    torchxrayvision_weights_name: None
#    detectron2_model_yaml: None
#    num_regions: 169
#    roi_heads_batch_size_per_image: 128
#    rpn_batch_size_per_image: 128
#    roi_align_output_size: None
#    yolov8_model_name_or_path: None
#    yolov8_model_alias: None
#    yolov8_use_one_detector_per_dataset: False
#    yolov11_model_name_or_path: /mnt/data/pamessina/workspaces/medvqa-workspace/cache/chest_imagenome/yolov11/train4/weights/best.pt
#    yolov11_model_alias: yolo11l
#    query_embed_size: None
#    local_attention_hidden_size: None
#    optimizer_name: adamw
#    lr: 1e-06
#    scheduler: exp-warmup+decay+cyclicdecay
#    lr_decay: 0.76
#    lr_decay_patience: 2
#    warmup_and_decay_args: None
#    warmup_and_cosine_args: None
#    warmup_decay_and_cyclic_decay_args: 5e-6,3,8e-4,6,5e-6,8e-4,6,5e-6
#    batch_size: 100
#    gradient_accumulation_steps: 4
#    num_workers: 3
#    device: GPU
#    img_aug_mode: random-color-and-spatial
#    image_size: [416, 416]
#    horizontal_flip_prob: 0
#    mimiccxr_weight: 1
#    chexpert_weight: 0.3
#    cxr14_weight: 0.3
#    vinbig_weight: 0.3
#    iuxray_weight: 0.05
#    padchest_weight: 0.4
#    mimiccxr_view_mode: chest_imagenome
#    mimiccxr_balanced_sampling_mode: None
#    mimiccxr_balanced_batch_size: None
#    chest_imagenome_labels_filename: None
#    chest_imagenome_label_names_filename: None
#    use_chest_imagenome_decent_images_only: False
#    use_amp: True
#    pretrained_checkpoint_folder_path: None
#    save: True
#    override_lr: False
#    train_mimiccxr: True
#    train_iuxray: False
#    train_chexpert: False
#    train_cxr14: False
#    train_vinbig: True
#    vinbig_training_data_mode: train
#    vinbig_use_validation: True
#    train_padchest: False
#    padchest_training_data_mode: train
#    padchest_use_validation: False
#    padchest_train_study_ids_path: None
#    padchest_val_study_ids_path: None
#    padchest_test_study_ids_path: None
#    binary_loss_name: focal+bce+wbcbce
#    focal_loss_weight: 1
#    bce_loss_weight: 1
#    wbce_loss_weight: 1
#    classify_tags: False
#    n_medical_tags: None
#    iuxray_medical_tags_per_report_filename: None
#    mimiccxr_medical_tags_per_report_filename: None
#    classify_orientation: False
#    classify_gender: False
#    classify_chexpert: False
#    iuxray_chexpert_labels_filename: None
#    mimiccxr_chexpert_labels_filename: None
#    classify_chest_imagenome: False
#    predict_bboxes_chest_imagenome: True
#    predict_labels_and_bboxes_chest_imagenome: False
#    clamp_bboxes_chest_imagenome: True
#    use_anaxnet_bbox_subset: False
#    chest_imagenome_bbox_loss_weight: 1.0
#    pass_pred_bbox_coords_as_input: False
#    use_gt_bboxes_as_predictions: False
#    predict_bboxes_vinbig: True
#    classify_labels_vinbig: False
#    classify_questions: False
#    n_mined_questions: None
#    iuxray_question_labels_filename: None
#    mimiccxr_question_labels_filename: None
#    merge_findings: False
# ----- Training model from scratch ------
# Loading /mnt/data/pamessina/workspaces/medvqa-workspace/cache/chest_imagenome/chest_imagenome_train_average_bbox_coords(clamped).pkl...
# avg_coords.shape= (144,)
# source_image_size_mode: medium_512
# vinbig_class_id_offset: 0
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Creating instance of MultiPurposeVisualModule ...
# MultiPurposeVisualModule()
#   Initializing raw_image_encoder: yolov11-for-det-mlc
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  2    173824  ultralytics.nn.modules.block.C3k2            [128, 256, 2, True, 0.25]
#   3                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   4                  -1  2    691712  ultralytics.nn.modules.block.C3k2            [256, 512, 2, True, 0.25]
#   5                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   6                  -1  2   2234368  ultralytics.nn.modules.block.C3k2            [512, 512, 2, True]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  2   2234368  ultralytics.nn.modules.block.C3k2            [512, 512, 2, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  2   1455616  ultralytics.nn.modules.block.C2PSA           [512, 512, 2]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  2   2496512  ultralytics.nn.modules.block.C3k2            [1024, 512, 2, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  2    756736  ultralytics.nn.modules.block.C3k2            [1024, 256, 2, True]
#  17                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  2   2365440  ultralytics.nn.modules.block.C3k2            [768, 512, 2, True]
#  20                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  2   2496512  ultralytics.nn.modules.block.C3k2            [1024, 512, 2, True]
#  23        [16, 19, 22]  1   1438780  ultralytics.nn.modules.head.Detect           [36, [256, 512, 512]]
# YOLO11l summary: 631 layers, 25,338,236 parameters, 25,338,220 gradients, 87.4 GFLOPs
#
# Transferred 1015/1015 items from pretrained weights
# Overriding model.yaml nc=36 with nc=22
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  2    173824  ultralytics.nn.modules.block.C3k2            [128, 256, 2, True, 0.25]
#   3                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   4                  -1  2    691712  ultralytics.nn.modules.block.C3k2            [256, 512, 2, True, 0.25]
#   5                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   6                  -1  2   2234368  ultralytics.nn.modules.block.C3k2            [512, 512, 2, True]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  2   2234368  ultralytics.nn.modules.block.C3k2            [512, 512, 2, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  2   1455616  ultralytics.nn.modules.block.C2PSA           [512, 512, 2]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  2   2496512  ultralytics.nn.modules.block.C3k2            [1024, 512, 2, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  2    756736  ultralytics.nn.modules.block.C3k2            [1024, 256, 2, True]
#  17                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  2   2365440  ultralytics.nn.modules.block.C3k2            [768, 512, 2, True]
#  20                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  2   2496512  ultralytics.nn.modules.block.C3k2            [1024, 512, 2, True]
#  23        [16, 19, 22]  1   1427986  ultralytics.nn.modules.head.Detect           [22, [256, 512, 512]]
# YOLO11l summary: 631 layers, 25,327,442 parameters, 25,327,426 gradients, 87.4 GFLOPs
#
# Transferred 1009/1015 items from pretrained weights
#   Initializing auxiliary tasks
#     Skipping auxiliary tasks initialization for YOLOV11_FOR_DET_MLC
# --------------------------------------------------
# 3) Defining optimizer ...
# create_optimizer(): name = adamw
# --------------------------------------------------
# 4) Defining scheduler ...
# Using exp-warmup+decay+cyclicdecay scheduler: 5e-6,3,8e-4,6,5e-6,8e-4,6,5e-6
# 5e-06 3 0.0008 6 5e-06 0.0008 6 5e-06
# self.steps_to_restart = 6
# self.steps = -1
# self.initial_lr = 0.0008
# --------------------------------------------------
# 5) Creating trainer and validator engines ...
# get_engine(): shift_answer=False
# Focal_BCE_WBCBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 wbcbce_weight = 0.3333333333333333
# GradientAccumulator.__init__(): num_accumulation_steps = 1, max_grad_norm = None
# chest_imagenome_bbox_loss_weight:  1.0
# get_engine(): shift_answer=False
# chest_imagenome_bbox_loss_weight:  1.0
# --------------------------------------------------
# 6) Defining collate_batch_fn ...
# --------------------------------------------------
# 7) Creating MIMIC-CXR visual module trainer ...
# get_image_transform()
#   image_size = [416, 416]
#   mean = [0.0, 0.0, 0.0]
#   std = [1.0, 1.0, 1.0]
#   Using bounding box aware transforms
#     augmentation_mode = random-color-and-spatial
#     default_prob = 0.35
#     returning transform (not for vinbig)
#     Returning augmented transform with mode random-color-and-spatial
# get_image_transform()
#   image_size = [416, 416]
#   mean = [0.0, 0.0, 0.0]
#   std = [1.0, 1.0, 1.0]
#   Using bounding box aware transforms
#     Returning default transform (no augmentation)
# Using image size mode: medium_512
# Allowed dicom ids: 240530
# 227835it [00:01, 218772.56it/s]
# max_idx_count = 377110
# actual_idx_count = 240530
# ** NOTE: 136580 images were skipped because they were not in the allowed DICOM IDs
# len(self.train_indices) = 235209
# len(self.val_indices) = 1945
# Loading Chest Imagenome bounding boxes...
# self.bbox_coords.shape = (243310, 36, 4)
# self.bbox_presence.shape = (243310, 36)
# --------------------------------------------------
# 8) Creating VinBig visual module trainer ...
# get_image_transform()
#   image_size = [416, 416]
#   mean = [0.0, 0.0, 0.0]
#   std = [1.0, 1.0, 1.0]
#   Using bounding box aware transforms
#     augmentation_mode = random-color-and-spatial
#     default_prob = 0.35
#     for_vinbig: returning vinbig transform
# get_train_transform(): Using bbox-aware transforms for VinBigData
#     Returning augmented transform with mode random-color-and-spatial
# get_image_transform()
#   image_size = [416, 416]
#   mean = [0.0, 0.0, 0.0]
#   std = [1.0, 1.0, 1.0]
#   Using bounding box aware transforms
#     Returning default transform (no augmentation)
# Loading bounding boxes
# Anomalous bboxes found: 29 of 37367
# class_id_offset: 0
# Anomalous bboxes found: 0 of 2697
# class_id_offset: 0
#   Loaded 18000 bounding boxes
# Generating train dataset and dataloader
# No finding        , #pos=10601, #neg=4399
# Other disease     , #pos=4288, #neg=10712
# Aortic enlargement, #pos=3067, #neg=11933
# Cardiomegaly      , #pos=2300, #neg=12700
# Pleural thickening, #pos=1981, #neg=13019
# Pulmonary fibrosis, #pos=1617, #neg=13383
# Lung Opacity      , #pos=1322, #neg=13678
# Other lesion      , #pos=1134, #neg=13866
# Pleural effusion  , #pos=1032, #neg=13968
# Pneumonia         , #pos=917, #neg=14083
# Nodule/Mass       , #pos=830, #neg=14170
# Tuberculosis      , #pos=750, #neg=14250
# Infiltration      , #pos=613, #neg=14387
# Calcification     , #pos=452, #neg=14548
# ILD               , #pos=386, #neg=14614
# Consolidation     , #pos=353, #neg=14647
# Lung tumor        , #pos=291, #neg=14709
# Atelectasis       , #pos=186, #neg=14814
# Mediastinal shift , #pos=150, #neg=14850
# Enlarged PA       , #pos=131, #neg=14869
# Pneumothorax      , #pos=96, #neg=14904
# Rib fracture      , #pos=90, #neg=14910
# Emphysema         , #pos=78, #neg=14922
# Lung cavity       , #pos=50, #neg=14950
# COPD              , #pos=35, #neg=14965
# Lung cyst         , #pos=32, #neg=14968
# Clavicle fracture , #pos=27, #neg=14973
# Edema             , #pos=13, #neg=14987
# len(train_indices) = 15000
# len(self.test_indices) = 3000
# --------------------------------------------------
# 9) Creating dataloaders ...
# len(_train_dataloaders) = 2
# len(_val_dataloaders) = 2
# _train_weights = [1, 0.3]
# merged_dataset_name = mim+vinbig
# --------------------------------------------------
# 10) Attaching metrics, losses, timer and events to engines ...
# NOTE: Using only validation metrics
# --------------------------------------------------
# 11) Defining learning rate scheduler handler ...
# --------------------------------------------------
# 12) Defining checkpoint folder path ...
# checkpoint_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20241122_163237_mim+vinbig_yolo11l(d:cig,vinbig)_dws=1,0.3
# metadata saved to /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20241122_163237_mim+vinbig_yolo11l(d:cig,vinbig)_dws=1,0.3/metadata.json
# --------------------------------------------------
# 13) Defining log_metrics_handler ...
# MetricsLogger :: we'll be logging to /mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20241122_163237_mim+vinbig_yolo11l(d:cig,vinbig)_dws=1,0.3/metrics_logs.csv
# --------------------------------------------------
# 14) Running trainer engine ...
# ---- Epoch 1/100
# (1) Training stage (lr = 0.000005) ...
# loss 5.40087, vnb_y11_loss 10.72971, vnb_y11_box_loss 2.92602, vnb_y11_cls_loss 4.78559, vnb_y11_dfl_loss 3.01811, cig_y11_loss 3.79112, cig_y11_box_loss 1.35214, cig_y11_cls_loss 0.66161, cig_y11_dfl_loss 1.77736, 186.91 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.00076, cig_y11_bbox_iou 0.73057, 53.32 secs
# New checkpoint saved: checkpoint_1_cig_y11_bbox_iou+vnb_y11_bbox_iou=0.3657.pt
# ---- Epoch 2/100
# (1) Training stage (lr = 0.000027) ...
# loss 4.88845, vnb_y11_loss 8.96041, vnb_y11_box_loss 2.64506, vnb_y11_cls_loss 3.79012, vnb_y11_dfl_loss 2.52523, cig_y11_loss 3.65837, cig_y11_box_loss 1.29083, cig_y11_cls_loss 0.67122, cig_y11_dfl_loss 1.69633, 180.62 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0
secs
# ---- Epoch 55/100
# (1) Training stage (lr = 0.000105) ...
# loss 3.94227, vnb_y11_loss 6.02952, vnb_y11_box_loss 1.93666, vnb_y11_cls_loss 2.22220, vnb_y11_dfl_loss 1.87066, cig_y11_loss 3.31174, cig_y11_box_loss 1.14312, cig_y11_cls_loss 0.63106, cig_y11_dfl_loss 1.53757, 174.89 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.07669, cig_y11_bbox_iou 0.74187, 52.86 secs
# ---- Epoch 56/100
# (1) Training stage (lr = 0.000038) ...
# loss 3.91685, vnb_y11_loss 5.96153, vnb_y11_box_loss 1.91528, vnb_y11_cls_loss 2.19122, vnb_y11_dfl_loss 1.85503, cig_y11_loss 3.29918, cig_y11_box_loss 1.13841, cig_y11_cls_loss 0.62877, cig_y11_dfl_loss 1.53200, 178.98 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.07781, cig_y11_bbox_iou 0.74348, 52.48 secs
# ---- Epoch 57/100
# (1) Training stage (lr = 0.000014) ...
# loss 3.91513, vnb_y11_loss 5.98415, vnb_y11_box_loss 1.92396, vnb_y11_cls_loss 2.19869, vnb_y11_dfl_loss 1.86150, cig_y11_loss 3.29012, cig_y11_box_loss 1.13455, cig_y11_cls_loss 0.62586, cig_y11_dfl_loss 1.52971, 180.75 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.08122, cig_y11_bbox_iou 0.74430, 52.25 secs
# ---- Epoch 58/100
# (1) Training stage (lr = 0.000005) ...
# loss 3.93438, vnb_y11_loss 5.99546, vnb_y11_box_loss 1.92244, vnb_y11_cls_loss 2.20183, vnb_y11_dfl_loss 1.87119, cig_y11_loss 3.29771, cig_y11_box_loss 1.13755, cig_y11_cls_loss 0.62840, cig_y11_dfl_loss 1.53175, 180.47 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.07847, cig_y11_bbox_iou 0.74348, 52.34 secs
# ---- Epoch 59/100
# (1) Training stage (lr = 0.000800) ...
# loss 4.01014, vnb_y11_loss 6.17798, vnb_y11_box_loss 1.97322, vnb_y11_cls_loss 2.30379, vnb_y11_dfl_loss 1.90097, cig_y11_loss 3.35527, cig_y11_box_loss 1.16071, cig_y11_cls_loss 0.64355, cig_y11_dfl_loss 1.55101, 175.56 secs
# (2) Validation stage ...
# vnb_y11_bbox_iou 0.07252, cig_y11_bbox_iou 0.74738, 52.83 secs
# ---- Epoch 60/100
# (1) Training stage (lr = 0.000290) ...
# loss 3.96575, vnb_y11_loss 6.08679, vnb_y11_box_loss 1.94485, vnb_y11_cls_loss 2.26093, vnb_y11_dfl_loss 1.88101, cig_y11_loss 3.32502, cig_y11_box_loss 1.14904, cig_y11_cls_loss 0.63499, cig_y11_dfl_loss 1.54100, 177.72 secs
# (2) Validation stage ...
# ^C iteration 25
# Engine run is terminating due to exception:
# Engine run is terminating due to exception:
# Traceback (most recent call last):
#   File "/home/pamessina/medvqa/medvqa/notebooks/../train_visual_module.py", line 1548, in <module>
#     train_from_scratch(**args)
#   File "/home/pamessina/medvqa/medvqa/notebooks/../train_visual_module.py", line 1422, in train_from_scratch
#     return train_model(
#   File "/home/pamessina/medvqa/medvqa/notebooks/../train_visual_module.py", line 863, in train_model
#     trainer_engine.run(train_dataloader, max_epochs = epochs, epoch_length = batches_per_epoch)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 892, in run
#     return self._internal_run()
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 935, in _internal_run
#     return next(self._internal_run_generator)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 993, in _internal_run_as_gen
#     self._handle_exception(e)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 638, in _handle_exception
#     raise e
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 965, in _internal_run_as_gen
#     self._fire_event(Events.EPOCH_COMPLETED)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 425, in _fire_event
#     func(*first, *(event_args + others), **kwargs)
#   File "/home/pamessina/medvqa/medvqa/notebooks/../train_visual_module.py", line 850, in <lambda>
#     trainer_engine.add_event_handler(Events.EPOCH_COMPLETED, lambda : validator_engine.run(val_dataloader,
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 892, in run
#     return self._internal_run()
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 935, in _internal_run
#     return next(self._internal_run_generator)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 993, in _internal_run_as_gen
#     self._handle_exception(e)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 638, in _handle_exception
#     raise e
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 959, in _internal_run_as_gen
#     epoch_time_taken += yield from self._run_once_on_dataset_as_gen()
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 1068, in _run_once_on_dataset_as_gen
#     self.state.output = self._process_function(self, self.state.batch)
#   File "/home/pamessina/medvqa/medvqa/training/vqa.py", line 943, in step_fn
#     output = flag_to_step_fn[flag](batch)
#   File "/home/pamessina/medvqa/medvqa/training/vqa.py", line 695, in step_fn__vinbig
#     model_output = model(**model_kwargs)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1532, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1541, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/home/pamessina/medvqa/medvqa/models/vision/visual_modules.py", line 800, in forward
#     return self.raw_image_encoder(
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1532, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1541, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/home/pamessina/medvqa/medvqa/models/vision/yolov11_modified.py", line 341, in forward
#     x = m(x) # run
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1532, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1541, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ultralytics/nn/modules/block.py", line 238, in forward
#     y.extend(m(y[-1]) for m in self.m)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ultralytics/nn/modules/block.py", line 238, in <genexpr>
#     y.extend(m(y[-1]) for m in self.m)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1532, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1541, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ultralytics/nn/modules/block.py", line 263, in forward
#     return self.cv3(torch.cat((self.m(self.cv1(x)), self.cv2(x)), 1))
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1532, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1541, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ultralytics/nn/modules/conv.py", line 50, in forward
#     return self.act(self.bn(self.conv(x)))
# KeyboardInterrupt

# %%
# !ls "/mnt/data/pamessina/workspaces/medvqa-workspace/models/visual_module/20241122_163237_mim+vinbig_yolo11l(d:cig,vinbig)_dws=1,0.3"
# Out:
# 'checkpoint_46_cig_y11_bbox_iou+vnb_y11_bbox_iou=0.4132.pt'   metrics_logs.csv
#  metadata.json
