# %%
# %env CUDA_VISIBLE_DEVICES=1
# Out:
# env: CUDA_VISIBLE_DEVICES=1

# %%
# !python ../train_vqa.py \
        --pretrained-checkpoint-folder-path "/mnt/data/pamessina/workspaces/medvqa-workspace/models/vqa/20230208_183723_mim+mim(chex)_oevqa(dense121+onehot+transf)_visenc-pretr=0_dws=1.0,1.0_medtok_chx_amp" \
        --epochs 20 \
        --batches-per-epoch 300 \
        --batch-size 80 \
        --num-workers 3 \
        --iters-to-accumulate 3 \
        --optimizer-name "adamw" \
        --scheduler "warmup+decay" \
        --lr 1e-6 \
        --warmup-and-decay-args "1e-6,4,1e-4,16,3e-6" \
        --use-mimiccxr \
        --mimiccxr-include-mined-questions-mode \
        --mimiccxr-include-chexpert-mode \
        --mimiccxr-weight 1.0 \
        --mimiccxr-weight-chexpert-mode 1.0 \
        --mimiccxr-qa-adapted-reports-filename "qa_adapted_reports__20220904_095810.json" \
        --mimiccxr-balanced-metadata-filename "balanced_dataloading_metadata__20220918_210415.pkl" \
        --mimiccxr-view-mode "chest_imagenome" \
        --classify-chest-imagenome \
        --chest-imagenome-label-names-filename "labels(min_freq=100).pkl" \
        --chest-imagenome-labels-filename "imageId2labels(min_freq=100).pkl" \
        --predict-bboxes-chest-imagenome \
        --clamp-bboxes-chest-imagenome \
        --chest-imagenome-bbox-regressor-version "v3" \
        --chest-imagenome-bbox-loss-weight 10.0 \
        --classify-chexpert \
        --mimiccxr-chexpert-labels-filename "chexpert_labels_per_report__20220904_113605.pkl" \
        --n-mined-questions 97 \
        --balanced-dataloading \
        --use-medical-tokenization \
        --medical-terms-frequency-filename "medical_terms_frequency__20220918_184255.pkl" \
        --raw-image-encoding "densenet-121" \
        --num-regions 64 \
        --image-size 256 256 \
        --image-local-feat-size 1024 \
        --question-encoding "one-hot" \
        --answer-decoding "transformer" \
        --binary-loss-name "wbce-c" \
        --use-amp \
        --save
# Out:
# script's arguments:
#    epochs: 20
#    batches_per_epoch: 300
#    checkpoint_folder: None
#    iuxray_qa_adapted_reports_filename: None
#    mimiccxr_qa_adapted_reports_filename: qa_adapted_reports__20220904_095810.json
#    vocab_min_freq: 10
#    embed_size: 256
#    question_encoding: one-hot
#    answer_decoding: transformer
#    question_hidden_size: 128
#    answer_hidden_size: 256
#    visual_input_mode: raw-image
#    raw_image_encoding: densenet-121
#    image_local_feat_size: 1024
#    image_encoder_pretrained_weights_path: None
#    freeze_image_encoder: False
#    imagenet_pretrained: False
#    visual_features_mlp_in_dim: None
#    visual_features_mlp_out_dim: None
#    visual_features_mlp_hidden_dims: None
#    iuxray_precomputed_visual_features_path: None
#    mimiccxr_precomputed_visual_features_path: None
#    chexpert_precomputed_visual_features_path: None
#    vinbig_precomputed_visual_features_path: None
#    clip_version: None
#    huggingface_model_name: None
#    chest_imagenome_bbox_hidden_size: 128
#    chest_imagenome_bbox_regressor_version: v3
#    num_regions: 64
#    n_lstm_layers: 1
#    transf_dec_nhead: 2
#    transf_dec_dim_forward: 256
#    transf_dec_num_layers: 2
#    question_vec_size: 128
#    dropout_prob: 0
#    optimizer_name: adamw
#    lr: 1e-06
#    scheduler: warmup+decay
#    lr_decay: 0.76
#    lr_decay_patience: 2
#    warmup_and_decay_args: 1e-6,4,1e-4,16,3e-6
#    warmup_and_cosine_args: None
#    batch_size: 80
#    iters_to_accumulate: 3
#    num_workers: 3
#    device: GPU
#    img_aug_mode: None
#    image_size: [256, 256]
#    mimiccxr_weight: 1.0
#    chexpert_weight: 0.3
#    cxr14_weight: 0.3
#    vinbig_weight: 0.3
#    iuxray_weight: 0.05
#    mimiccxr_weight_chexpert_mode: 1.0
#    iuxray_weight_chexpert_mode: 0.05
#    padchest_weight: 0.4
#    mimiccxr_weight_chest_imagenome_mode: 1
#    mimiccxr_include_chexpert_mode: True
#    mimiccxr_include_mined_questions_mode: True
#    mimiccxr_view_mode: chest_imagenome
#    mimiccxr_include_chest_imagenome_mode: False
#    chest_imagenome_labels_filename: imageId2labels(min_freq=100).pkl
#    chest_imagenome_label_names_filename: labels(min_freq=100).pkl
#    iuxray_include_chexpert_mode: False
#    iuxray_include_mined_questions_mode: False
#    val_answer_decoding: greedy-search
#    beam_search_k: None
#    use_amp: True
#    use_medical_tokenization: True
#    medical_terms_frequency_filename: medical_terms_frequency__20220918_184255.pkl
#    allowed_questions: None
#    pretrained_checkpoint_folder_path: /mnt/data/pamessina/workspaces/medvqa-workspace/models/vqa/20230208_183723_mim+mim(chex)_oevqa(dense121+onehot+transf)_visenc-pretr=0_dws=1.0,1.0_medtok_chx_amp
#    balanced_dataloading: True
#    imbalance_reduction_coef: 0.5
#    iuxray_balanced_metadata_filename: None
#    mimiccxr_balanced_metadata_filename: balanced_dataloading_metadata__20220918_210415.pkl
#    one_question_per_batch: False
#    save: True
#    override_lr: False
#    train_mimiccxr: True
#    train_iuxray: False
#    train_chexpert: False
#    chexpert_mode: None
#    train_cxr14: False
#    train_vinbig: False
#    vinbig_training_data: all
#    vinbig_use_validation: False
#    train_padchest: False
#    padchest_training_data_mode: train
#    padchest_use_validation: False
#    padchest_train_study_ids_path: None
#    padchest_val_study_ids_path: None
#    padchest_test_study_ids_path: None
#    binary_loss_name: wbce-c
#    classify_tags: False
#    n_medical_tags: None
#    iuxray_medical_tags_per_report_filename: None
#    mimiccxr_medical_tags_per_report_filename: None
#    classify_orientation: False
#    classify_chexpert: True
#    iuxray_chexpert_labels_filename: None
#    mimiccxr_chexpert_labels_filename: chexpert_labels_per_report__20220904_113605.pkl
#    classify_chest_imagenome: True
#    predict_bboxes_chest_imagenome: True
#    clamp_bboxes_chest_imagenome: True
#    chest_imagenome_bbox_loss_weight: 10.0
#    classify_questions: False
#    n_mined_questions: 97
#    iuxray_question_labels_filename: None
#    mimiccxr_question_labels_filename: None
#    merge_findings: False
# ----- Training model from scratch ------
# Computing one-hot question offsets
# one_hot_question_offsets = {'0': 0, '1': 0, '2': 97, '3': 97, '4': 97}
# Loading /mnt/data/pamessina/workspaces/medvqa-workspace/cache/chest_imagenome/chest_imagenome_train_average_bbox_coords(qa_adapted_reports__20220904_095810.json,clamped.pkl...
# Debug: balanced_dataloading = True
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Loading mimiccxr QA adapted reports ...
# --------------------------------------------------
# 3) Initializing tokenizer ...
# Loading /mnt/data/pamessina/workspaces/medvqa-workspace/cache/vocab(min_freq=10;mode=report;qa_adapted_reports__20220904_095810.json).pkl ...
# --------------------------------------------------
# 4) Creating instance of OpenEndedVQA model ...
# OpenEndedVQA():
#   image_encoder_pretrained_weights_path None
# create_densenet121_feature_extractor()
#    drop_rate: 0.0
#   self.global_feat_size = 2048
# BoundingBoxRegressor_v3:
#   local_feat_dim: 1024
#   global_feat_dim: 2048
#   hidden_dim: 128
#   num_classes: 36
#   num_regions: 64
#   n_questions = 111
#   n_questions_aux_task = 97
#   question_encoding = one-hot
#   answer_decoding = transformer
#   visual_input_mode = raw-image
#   name = oevqa(dense121+onehot+transf)
# --------------------------------------------------
# 5) Defining optimizer ...
# create_optimizer(): name = adamw
# --------------------------------------------------
# 6) Defining scheduler ...
# Using warmup+decay scheduler: 1e-6,4,1e-4,16,3e-6
# 1e-06 4 0.0001 16 3e-06
# Adjusting learning rate of group 0 to 1.0000e-06.
# Adjusting learning rate of group 0 to 1.0000e-06.
# --------------------------------------------------
# 7) Creating trainer and validator engines ...
# get_engine(): shift_answer=True
# chest_imagenome_bbox_loss_weight:  10.0
# get_engine(): shift_answer=False
# chest_imagenome_bbox_loss_weight:  1.0
# --------------------------------------------------
# 8) Defining image transform ...
# train_image_transform_kwargs: {'image_size': [256, 256], 'augmentation_mode': None, 'use_clip_transform': False, 'clip_version': None, 'use_huggingface_vitmodel_transform': False, 'huggingface_vitmodel_name': None}
# Using default transform
# mean = (0.485, 0.456, 0.406), std = (0.229, 0.224, 0.225), image_size = [256, 256], use_center_crop = False
# Returning transform without augmentation
# val_image_transform_kwargs: {'image_size': [256, 256], 'augmentation_mode': None, 'use_clip_transform': False, 'clip_version': None, 'use_huggingface_vitmodel_transform': False, 'huggingface_vitmodel_name': None}
# Using default transform
# mean = (0.485, 0.456, 0.406), std = (0.229, 0.224, 0.225), image_size = [256, 256], use_center_crop = False
# Returning transform without augmentation
# --------------------------------------------------
# 9) Defining collate_batch_fn ...
# get_vqa_collate_batch_fn(): dataset_id=1, one_hot_question_offset=0
# get_vqa_collate_batch_fn(): dataset_id=4, one_hot_question_offset=97
# --------------------------------------------------
# 10) Creating MIMIC-CXR vqa trainer ...
# MIMICCXR_VQA_Trainer: balanced_dataloading = True
# self.balanced_dataloading = True
# Checking if data is already cached in path /mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/mimiccxr_preprocessed_train_data__(hash=278,2530331200862576790).pkl ...
# 	Yes, it is, data successfully loaded :)
# batch_size = 80
# len(self.report_ids) = 2153951, len(set(self.report_ids)) = 211703
# _generate_datasets_and_dataloaders()
# self.balanced_dataloading = True
# Computing balanced datasets from scratch ...
# self.imbalance_reduction_coef = 0.5
# 100%|███████████████████████████████████████████| 97/97 [00:10<00:00,  8.90it/s]
#  *** merging from i=0 to j=3, acc_size = 143
# 	len(question_datasets) = 94
# len(self.val_indices) = 17722
# len(val_indices) = 3336
# generating training and validation dataloaders ...
# num_workers = 3
# Generating perfectly balanced train dataset in chexpert mode ...
#     label = 0, onehot=0, len(pos_indices)=40447, len(neg_indices)=169548
#     label = 1, onehot=1, len(pos_indices)=41277, len(neg_indices)=168718
#     label = 2, onehot=2, len(pos_indices)=67917, len(neg_indices)=142078
#     label = 3, onehot=3, len(pos_indices)=9072, len(neg_indices)=200923
#     label = 4, onehot=4, len(pos_indices)=70004, len(neg_indices)=139991
#     label = 5, onehot=5, len(pos_indices)=40951, len(neg_indices)=169044
#     label = 6, onehot=6, len(pos_indices)=18752, len(neg_indices)=191243
#     label = 7, onehot=7, len(pos_indices)=35212, len(neg_indices)=174783
#     label = 8, onehot=8, len(pos_indices)=66549, len(neg_indices)=143446
#     label = 9, onehot=9, len(pos_indices)=12644, len(neg_indices)=197351
#     label = 10, onehot=10, len(pos_indices)=65149, len(neg_indices)=144846
#     label = 11, onehot=11, len(pos_indices)=4669, len(neg_indices)=205326
#     label = 12, onehot=12, len(pos_indices)=8015, len(neg_indices)=201980
#     label = 13, onehot=13, len(pos_indices)=84236, len(neg_indices)=125759
# len(self.train_dataset__chexpert_mode) = 1000000000000000000
# Generating balanced validation dataset in chexpert mode ...
#     label = 0, onehot=0, len(pos_indices)=40, len(neg_indices)=40
#     label = 1, onehot=1, len(pos_indices)=40, len(neg_indices)=40
#     label = 2, onehot=2, len(pos_indices)=40, len(neg_indices)=40
#     label = 3, onehot=3, len(pos_indices)=40, len(neg_indices)=40
#     label = 4, onehot=4, len(pos_indices)=40, len(neg_indices)=40
#     label = 5, onehot=5, len(pos_indices)=40, len(neg_indices)=40
#     label = 6, onehot=6, len(pos_indices)=40, len(neg_indices)=40
#     label = 7, onehot=7, len(pos_indices)=40, len(neg_indices)=40
#     label = 8, onehot=8, len(pos_indices)=40, len(neg_indices)=40
#     label = 9, onehot=9, len(pos_indices)=40, len(neg_indices)=40
#     label = 10, onehot=10, len(pos_indices)=40, len(neg_indices)=40
#     label = 11, onehot=11, len(pos_indices)=40, len(neg_indices)=40
#     label = 12, onehot=12, len(pos_indices)=34, len(neg_indices)=40
#     label = 13, onehot=13, len(pos_indices)=40, len(neg_indices)=40
# len(self.val_dataset__chexpert_mode) = 1114
# done!
# Clamping Chest-Imagenome bounding boxes to [0, 1] in-place
# --------------------------------------------------
# 11) Creating dataloaders ...
# len(_train_dataloaders) = 2
# len(_val_dataloaders) = 2
# _train_weights = [1.0, 1.0]
# merged_dataset_name = mim+mim(chex)
# --------------------------------------------------
# 12) Attaching metrics, losses, timer and events to engines ...
# --------------------------------------------------
# 13) Defining learning rate scheduler handler ...
# --------------------------------------------------
# 14) Defining checkpoint folder path ...
# checkpoint_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/vqa/20230208_231344_mim+mim(chex)_oevqa(dense121+onehot+transf)_visenc-pretr=0_dws=1.0,1.0_medtok_chx_amp
# metadata saved to /mnt/data/pamessina/workspaces/medvqa-workspace/models/vqa/20230208_231344_mim+mim(chex)_oevqa(dense121+onehot+transf)_visenc-pretr=0_dws=1.0,1.0_medtok_chx_amp/metadata.json
# --------------------------------------------------
# 15) Loading pretrained weights ...
# checkpoint_names = ['checkpoint_17_chf1+chf1+chf1+chf1+chf1+cD+ema+wmmp=0.4092.pt']
# pretrained_checkpoint_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/vqa/20230208_183723_mim+mim(chex)_oevqa(dense121+onehot+transf)_visenc-pretr=0_dws=1.0,1.0_medtok_chx_amp/checkpoint_17_chf1+chf1+chf1+chf1+chf1+cD+ema+wmmp=0.4092.pt
# Checkpoint successfully loaded!
# --------------------------------------------------
# 16) Defining log_metrics_handler ...
# MetricsLogger :: we'll be logging to /mnt/data/pamessina/workspaces/medvqa-workspace/models/vqa/20230208_231344_mim+mim(chex)_oevqa(dense121+onehot+transf)_visenc-pretr=0_dws=1.0,1.0_medtok_chx_amp/metrics_logs.csv
# --------------------------------------------------
# 17) Running trainer engine ...
# ---- Epoch 1/20
# (1) Training stage (lr = 0.000001) ...
# loss 9.68520, a_loss 1.11760, cD 1.68585, wmdcmp 0.21731, ema 0.84683, chxlmicf1 0.72652, chxlmacf1 0.76859, chx_loss 0.40386, chxlacc 0.86084, chxlrocaucmic 0.93664, chxlrocaucmac 0.92172, chestimglmacf1 0.26597, chestimglmicf1 0.42610, chestimgl_loss 0.34487, chestimgl_acc 0.91094, chestimglrocaucmic 0.95588, chestimglrocaucmac 0.95260, chestimgbbmf1 0.00007, chestimgbb_loss 6.74127, chestimgbbiou 0.68067, chestimgbbmae 0.12574, 278.94 secs
# (2) Validation stage ...
# cD 1.50499, wmdcmp 0.19957, ema 0.68223, chxlmicf1 0.55637, chxlmacf1 0.42160, chxlacc 0.78058, chxlrocaucmic 0.80992, chxlrocaucmac 0.71845, chestimglmacf1 0.14292, chestimglmicf1 0.32448, chestimgl_acc 0.90917, chestimglrocaucmic 0.89294, chestimglrocaucmac 0.76754, chestimgbbmf1 0.00041, chestimgbbiou 0.66576, chestimgbbmae 0.13285, 48.96 secs
# Adjusting learning rate of group 0 to 3.1623e-06.
# ---- Epoch 2/20
# (1) Training stage (lr = 0.000003) ...
# loss 9.41075, a_loss 1.16359, cD 1.59529, wmdcmp 0.20833, ema 0.84625, chxlmicf1 0.72553, chxlmacf1 0.76699, chx_loss 0.40820, chxlacc 0.86044, chxlrocaucmic 0.93621, chxlrocaucmac 0.92117, chestimglmacf1 0.27668, chestimglmicf1 0.43293, chestimgl_loss 0.34591, chestimgl_acc 0.91294, chestimglrocaucmic 0.95668, chestimglrocaucmac 0.95279, chestimgbbmf1 0.00310, chestimgbb_loss 5.61625, chestimgbbiou 0.60736, chestimgbbmae 0.16126, 308.73 secs
# (2) Validation stage ...
# cD 1.48240, wmdcmp 0.19779, ema 0.68133, chxlmicf1 0.55603, chxlmacf1 0.42190, chxlacc 0.78104, chxlrocaucmic 0.80965, chxlrocaucmac 0.71791, chestimglmacf1 0.14148, chestimglmicf1 0.32612, chestimgl_acc 0.91080, chestimglrocaucmic 0.89360, chestimglrocaucmac 0.76658, chestimgbbmf1 0.00564, chestimgbbiou 0.56871, chestimgbbmae 0.18337, 58.29 secs
# Adjusting learning rate of group 0 to 1.0000e-05.
# ---- Epoch 3/20
# (1) Training stage (lr = 0.000010) ...
# loss 7.98062, a_loss 1.15631, cD 1.59746, wmdcmp 0.20813, ema 0.83658, chxlmicf1 0.71658, chxlmacf1 0.75495, chx_loss 0.42552, chxlacc 0.85515, chxlrocaucmic 0.93180, chxlrocaucmac 0.91682, chestimglmacf1 0.28015, chestimglmicf1 0.43286, chestimgl_loss 0.35486, chestimgl_acc 0.91359, chestimglrocaucmic 0.95609, chestimglrocaucmac 0.95100, chestimgbbmf1 0.00969, chestimgbb_loss 2.98364, chestimgbbiou 0.59155, chestimgbbmae 0.17374, 351.66 secs
# (2) Validation stage ...
# cD 1.47559, wmdcmp 0.19732, ema 0.67864, chxlmicf1 0.55114, chxlmacf1 0.41952, chxlacc 0.77507, chxlrocaucmic 0.80767, chxlrocaucmac 0.71816, chestimglmacf1 0.14319, chestimglmicf1 0.32668, chestimgl_acc 0.91044, chestimglrocaucmic 0.89443, chestimglrocaucmac 0.76754, chestimgbbmf1 0.02674, chestimgbbiou 0.67475, chestimgbbmae 0.13018, 64.75 secs
# Adjusting learning rate of group 0 to 3.1623e-05.
# ---- Epoch 4/20
# (1) Training stage (lr = 0.000032) ...
# loss 4.41837, a_loss 1.16297, cD 1.61421, wmdcmp 0.20987, ema 0.83667, chxlmicf1 0.71158, chxlmacf1 0.73899, chx_loss 0.43509, chxlacc 0.85096, chxlrocaucmic 0.92870, chxlrocaucmac 0.91507, chestimglmacf1 0.26436, chestimglmicf1 0.42273, chestimgl_loss 0.36549, chestimgl_acc 0.90928, chestimglrocaucmic 0.95346, chestimglrocaucmac 0.94830, chestimgbbmf1 0.05650, chestimgbb_loss 0.49404, chestimgbbiou 0.74690, chestimgbbmae 0.09516, 356.22 secs
# (2) Validation stage ...
# cD 1.46609, wmdcmp 0.19493, ema 0.67504, chxlmicf1 0.56229, chxlmacf1 0.43173, chxlacc 0.77544, chxlrocaucmic 0.80903, chxlrocaucmac 0.71728, chestimglmacf1 0.14162, chestimglmicf1 0.32657, chestimgl_acc 0.90559, chestimglrocaucmic 0.89505, chestimglrocaucmac 0.76404, chestimgbbmf1 0.06476, chestimgbbiou 0.74841, chestimgbbmae 0.09543, 64.68 secs
# Adjusting learning rate of group 0 to 1.0000e-04.
# ---- Epoch 5/20
# (1) Training stage (lr = 0.000100) ...
# loss 3.37305, a_loss 1.17739, cD 1.58637, wmdcmp 0.20595, ema 0.81275, chxlmicf1 0.68429, chxlmacf1 0.68893, chx_loss 0.49610, chxlacc 0.83377, chxlrocaucmic 0.91325, chxlrocaucmac 0.90279, chestimglmacf1 0.23984, chestimglmicf1 0.40244, chestimgl_loss 0.39034, chestimgl_acc 0.90343, chestimglrocaucmic 0.94784, chestimglrocaucmac 0.94087, chestimgbbmf1 0.04312, chestimgbb_loss 0.85973, chestimgbbiou 0.71399, chestimgbbmae 0.11153, 357.46 secs
# (2) Validation stage ...
# cD 1.40404, wmdcmp 0.18818, ema 0.66517, chxlmicf1 0.54493, chxlmacf1 0.42639, chxlacc 0.75547, chxlrocaucmic 0.79430, chxlrocaucmac 0.71482, chestimglmacf1 0.14244, chestimglmicf1 0.28404, chestimgl_acc 0.89113, chestimglrocaucmic 0.88503, chestimglrocaucmac 0.75849, chestimgbbmf1 0.02736, chestimgbbiou 0.70072, chestimgbbmae 0.11845, 64.80 secs
# Adjusting learning rate of group 0 to 8.0319e-05.
# ---- Epoch 6/20
# (1) Training stage (lr = 0.000080) ...
# loss 3.58713, a_loss 1.17448, cD 1.58582, wmdcmp 0.20684, ema 0.81233, chxlmicf1 0.68210, chxlmacf1 0.68454, chx_loss 0.49872, chxlacc 0.83223, chxlrocaucmic 0.91201, chxlrocaucmac 0.90218, chestimglmacf1 0.23550, chestimglmicf1 0.40002, chestimgl_loss 0.39367, chestimgl_acc 0.90248, chestimglrocaucmic 0.94705, chestimglrocaucmac 0.94013, chestimgbbmf1 0.08800, chestimgbb_loss 0.48043, chestimgbbiou 0.76735, chestimgbbmae 0.08652, 356.52 secs
# (2) Validation stage ...
# cD 1.45442, wmdcmp 0.19260, ema 0.68582, chxlmicf1 0.54978, chxlmacf1 0.42658, chxlacc 0.77339, chxlrocaucmic 0.80228, chxlrocaucmac 0.71893, chestimglmacf1 0.14093, chestimglmicf1 0.30637, chestimgl_acc 0.90487, chestimglrocaucmic 0.88930, chestimglrocaucmac 0.76234, chestimgbbmf1 0.08344, chestimgbbiou 0.76740, chestimgbbmae 0.08733, 64.75 secs
# Adjusting learning rate of group 0 to 6.4512e-05.
# ---- Epoch 7/20
# (1) Training stage (lr = 0.000065) ...
# loss 3.46890, a_loss 1.17713, cD 1.57029, wmdcmp 0.20583, ema 0.82075, chxlmicf1 0.69693, chxlmacf1 0.70966, chx_loss 0.46708, chxlacc 0.84187, chxlrocaucmic 0.92089, chxlrocaucmac 0.90903, chestimglmacf1 0.24956, chestimglmicf1 0.41147, chestimgl_loss 0.37749, chestimgl_acc 0.90624, chestimglrocaucmic 0.95035, chestimglrocaucmac 0.94483, chestimgbbmf1 0.09585, chestimgbb_loss 0.40271, chestimgbbiou 0.77281, chestimgbbmae 0.08465, 364.01 secs
# (2) Validation stage ...
# cD 1.44089, wmdcmp 0.19332, ema 0.67235, chxlmicf1 0.54773, chxlmacf1 0.42857, chxlacc 0.76925, chxlrocaucmic 0.80299, chxlrocaucmac 0.71019, chestimglmacf1 0.13776, chestimglmicf1 0.30458, chestimgl_acc 0.90423, chestimglrocaucmic 0.88821, chestimglrocaucmac 0.75639, chestimgbbmf1 0.11049, chestimgbbiou 0.77504, chestimgbbmae 0.08335, 65.83 secs
# Adjusting learning rate of group 0 to 5.1816e-05.
# ---- Epoch 8/20
# (1) Training stage (lr = 0.000052) ...
# loss 3.33547, a_loss 1.17147, cD 1.57802, wmdcmp 0.20598, ema 0.82883, chxlmicf1 0.70512, chxlmacf1 0.72656, chx_loss 0.44615, chxlacc 0.84654, chxlrocaucmic 0.92555, chxlrocaucmac 0.91271, chestimglmacf1 0.26110, chestimglmicf1 0.42126, chestimgl_loss 0.36672, chestimgl_acc 0.90888, chestimglrocaucmic 0.95264, chestimglrocaucmac 0.94756, chestimgbbmf1 0.14874, chestimgbb_loss 0.17763, chestimgbbiou 0.80162, chestimgbbmae 0.07146, 358.89 secs
# (2) Validation stage ...
# cD 1.43398, wmdcmp 0.19147, ema 0.66876, chxlmicf1 0.55261, chxlmacf1 0.42007, chxlacc 0.78005, chxlrocaucmic 0.80342, chxlrocaucmac 0.71569, chestimglmacf1 0.13974, chestimglmicf1 0.32143, chestimgl_acc 0.91382, chestimglrocaucmic 0.88931, chestimglrocaucmac 0.76141, chestimgbbmf1 0.11795, chestimgbbiou 0.78171, chestimgbbmae 0.08078, 64.95 secs
# Adjusting learning rate of group 0 to 4.1618e-05.
# ---- Epoch 9/20
# (1) Training stage (lr = 0.000042) ...
# loss 3.19153, a_loss 1.16985, cD 1.59263, wmdcmp 0.20786, ema 0.83425, chxlmicf1 0.71422, chxlmacf1 0.74049, chx_loss 0.43249, chxlacc 0.85195, chxlrocaucmic 0.92933, chxlrocaucmac 0.91605, chestimglmacf1 0.26302, chestimglmicf1 0.42411, chestimgl_loss 0.36202, chestimgl_acc 0.90959, chestimglrocaucmic 0.95357, chestimglrocaucmac 0.94891, chestimgbbmf1 0.14059, chestimgbb_loss 0.20224, chestimgbbiou 0.79631, chestimgbbmae 0.07400, 364.62 secs
# (2) Validation stage ...
# cD 1.48287, wmdcmp 0.19819, ema 0.67235, chxlmicf1 0.55798, chxlmacf1 0.42042, chxlacc 0.78053, chxlrocaucmic 0.80773, chxlrocaucmac 0.72109, chestimglmacf1 0.13962, chestimglmicf1 0.31999, chestimgl_acc 0.91149, chestimglrocaucmic 0.88972, chestimglrocaucmac 0.76481, chestimgbbmf1 0.14856, chestimgbbiou 0.79226, chestimgbbmae 0.07640, 65.83 secs
# Adjusting learning rate of group 0 to 3.3427e-05.
# ---- Epoch 10/20
# (1) Training stage (lr = 0.000033) ...
# loss 3.27063, a_loss 1.16386, cD 1.56263, wmdcmp 0.20566, ema 0.83992, chxlmicf1 0.71530, chxlmacf1 0.74730, chx_loss 0.42548, chxlacc 0.85418, chxlrocaucmic 0.93117, chxlrocaucmac 0.91740, chestimglmacf1 0.26670, chestimglmicf1 0.42668, chestimgl_loss 0.35540, chestimgl_acc 0.91108, chestimglrocaucmic 0.95458, chestimglrocaucmac 0.95039, chestimgbbmf1 0.13122, chestimgbb_loss 0.45550, chestimgbbiou 0.78904, chestimgbbmae 0.07754, 365.27 secs
# (2) Validation stage ...
# cD 1.45002, wmdcmp 0.19428, ema 0.68133, chxlmicf1 0.55887, chxlmacf1 0.42827, chxlacc 0.78008, chxlrocaucmic 0.80879, chxlrocaucmac 0.71884, chestimglmacf1 0.14066, chestimglmicf1 0.32364, chestimgl_acc 0.91056, chestimglrocaucmic 0.89158, chestimglrocaucmac 0.76257, chestimgbbmf1 0.16444, chestimgbbiou 0.79695, chestimgbbmae 0.07438, 67.02 secs
# Adjusting learning rate of group 0 to 2.6849e-05.
# ---- Epoch 11/20
# (1) Training stage (lr = 0.000027) ...
# loss 2.99744, a_loss 1.15830, cD 1.59789, wmdcmp 0.20918, ema 0.83883, chxlmicf1 0.71947, chxlmacf1 0.75280, chx_loss 0.41992, chxlacc 0.85674, chxlrocaucmic 0.93257, chxlrocaucmac 0.91865, chestimglmacf1 0.26849, chestimglmicf1 0.42962, chestimgl_loss 0.35290, chestimgl_acc 0.91223, chestimglrocaucmic 0.95524, chestimglrocaucmac 0.95060, chestimgbbmf1 0.16188, chestimgbb_loss 0.14434, chestimgbbiou 0.80813, chestimgbbmae 0.06844, 363.53 secs
# (2) Validation stage ...
# cD 1.47584, wmdcmp 0.19714, ema 0.68492, chxlmicf1 0.55990, chxlmacf1 0.42534, chxlacc 0.78329, chxlrocaucmic 0.80737, chxlrocaucmac 0.71716, chestimglmacf1 0.13848, chestimglmicf1 0.32531, chestimgl_acc 0.91170, chestimglrocaucmic 0.89148, chestimglrocaucmac 0.76285, chestimgbbmf1 0.15225, chestimgbbiou 0.79224, chestimgbbmae 0.07621, 66.22 secs
# Adjusting learning rate of group 0 to 2.1565e-05.
# ---- Epoch 12/20
# (1) Training stage (lr = 0.000022) ...
# loss 3.12425, a_loss 1.16158, cD 1.59423, wmdcmp 0.20858, ema 0.84400, chxlmicf1 0.72443, chxlmacf1 0.76175, chx_loss 0.41072, chxlacc 0.85925, chxlrocaucmic 0.93507, chxlrocaucmac 0.92061, chestimglmacf1 0.27044, chestimglmicf1 0.43209, chestimgl_loss 0.34841, chestimgl_acc 0.91265, chestimglrocaucmic 0.95611, chestimglrocaucmac 0.95194, chestimgbbmf1 0.16835, chestimgbb_loss 0.25865, chestimgbbiou 0.80737, chestimgbbmae 0.06935, 365.21 secs
# (2) Validation stage ...
# cD 1.47533, wmdcmp 0.19649, ema 0.68402, chxlmicf1 0.56068, chxlmacf1 0.42412, chxlacc 0.78284, chxlrocaucmic 0.81004, chxlrocaucmac 0.71937, chestimglmacf1 0.14104, chestimglmicf1 0.32835, chestimgl_acc 0.91167, chestimglrocaucmic 0.89334, chestimglrocaucmac 0.76188, chestimgbbmf1 0.15048, chestimgbbiou 0.79328, chestimgbbmae 0.07594, 66.18 secs
# Adjusting learning rate of group 0 to 1.7321e-05.
# ---- Epoch 13/20
# (1) Training stage (lr = 0.000017) ...
# loss 3.14848, a_loss 1.15487, cD 1.61088, wmdcmp 0.21010, ema 0.84450, chxlmicf1 0.72686, chxlmacf1 0.76484, chx_loss 0.40587, chxlacc 0.86088, chxlrocaucmic 0.93650, chxlrocaucmac 0.92190, chestimglmacf1 0.27079, chestimglmicf1 0.43254, chestimgl_loss 0.34823, chestimgl_acc 0.91286, chestimglrocaucmic 0.95635, chestimglrocaucmac 0.95168, chestimgbbmf1 0.18583, chestimgbb_loss 0.28797, chestimgbbiou 0.81317, chestimgbbmae 0.06726, 364.06 secs
# (2) Validation stage ...
# cD 1.48314, wmdcmp 0.19712, ema 0.68402, chxlmicf1 0.56664, chxlmacf1 0.43023, chxlacc 0.78368, chxlrocaucmic 0.81104, chxlrocaucmac 0.71813, chestimglmacf1 0.14347, chestimglmicf1 0.33266, chestimgl_acc 0.91031, chestimglrocaucmic 0.89380, chestimglrocaucmac 0.76420, chestimgbbmf1 0.17402, chestimgbbiou 0.80162, chestimgbbmae 0.07276, 66.33 secs
# Adjusting learning rate of group 0 to 1.3912e-05.
# ---- Epoch 14/20
# (1) Training stage (lr = 0.000014) ...
# loss 3.24028, a_loss 1.14927, cD 1.60288, wmdcmp 0.20896, ema 0.84500, chxlmicf1 0.72911, chxlmacf1 0.76843, chx_loss 0.40254, chxlacc 0.86152, chxlrocaucmic 0.93692, chxlrocaucmac 0.92221, chestimglmacf1 0.27655, chestimglmicf1 0.43657, chestimgl_loss 0.34380, chestimgl_acc 0.91347, chestimglrocaucmic 0.95696, chestimglrocaucmac 0.95310, chestimgbbmf1 0.17955, chestimgbb_loss 0.46053, chestimgbbiou 0.80368, chestimgbbmae 0.07170, 364.19 secs
# (2) Validation stage ...
# cD 1.46301, wmdcmp 0.19631, ema 0.68761, chxlmicf1 0.55973, chxlmacf1 0.42822, chxlacc 0.78319, chxlrocaucmic 0.81069, chxlrocaucmac 0.72021, chestimglmacf1 0.14253, chestimglmicf1 0.32994, chestimgl_acc 0.91152, chestimglrocaucmic 0.89365, chestimglrocaucmac 0.76659, chestimgbbmf1 0.17400, chestimgbbiou 0.80112, chestimgbbmae 0.07266, 66.53 secs
# Adjusting learning rate of group 0 to 1.1174e-05.
# ---- Epoch 15/20
# (1) Training stage (lr = 0.000011) ...
# loss 3.17133, a_loss 1.15591, cD 1.60569, wmdcmp 0.20920, ema 0.84483, chxlmicf1 0.73023, chxlmacf1 0.77021, chx_loss 0.39927, chxlacc 0.86279, chxlrocaucmic 0.93783, chxlrocaucmac 0.92325, chestimglmacf1 0.27925, chestimglmicf1 0.43824, chestimgl_loss 0.34262, chestimgl_acc 0.91438, chestimglrocaucmic 0.95736, chestimglrocaucmac 0.95324, chestimgbbmf1 0.19347, chestimgbb_loss 0.27861, chestimgbbiou 0.81030, chestimgbbmae 0.06838, 363.97 secs
# (2) Validation stage ...
# cD 1.47205, wmdcmp 0.19635, ema 0.68492, chxlmicf1 0.56496, chxlmacf1 0.42967, chxlacc 0.78335, chxlrocaucmic 0.81058, chxlrocaucmac 0.71748, chestimglmacf1 0.14216, chestimglmicf1 0.33502, chestimgl_acc 0.91205, chestimglrocaucmic 0.89439, chestimglrocaucmac 0.76367, chestimgbbmf1 0.18144, chestimgbbiou 0.80276, chestimgbbmae 0.07201, 65.85 secs
# Adjusting learning rate of group 0 to 8.9747e-06.
# ---- Epoch 16/20
# (1) Training stage (lr = 0.000009) ...
# loss 3.14845, a_loss 1.16397, cD 1.61367, wmdcmp 0.21002, ema 0.84808, chxlmicf1 0.72990, chxlmacf1 0.77195, chx_loss 0.40172, chxlacc 0.86262, chxlrocaucmic 0.93754, chxlrocaucmac 0.92263, chestimglmacf1 0.27784, chestimglmicf1 0.43756, chestimgl_loss 0.34212, chestimgl_acc 0.91453, chestimglrocaucmic 0.95736, chestimglrocaucmac 0.95319, chestimgbbmf1 0.20612, chestimgbb_loss 0.16560, chestimgbbiou 0.81730, chestimgbbmae 0.06507, 364.21 secs
# (2) Validation stage ...
# cD 1.47940, wmdcmp 0.19736, ema 0.68492, chxlmicf1 0.56395, chxlmacf1 0.42830, chxlacc 0.78449, chxlrocaucmic 0.80991, chxlrocaucmac 0.71943, chestimglmacf1 0.14044, chestimglmicf1 0.32887, chestimgl_acc 0.91120, chestimglrocaucmic 0.89272, chestimglrocaucmac 0.76438, chestimgbbmf1 0.18346, chestimgbbiou 0.80277, chestimgbbmae 0.07230, 67.39 secs
# Adjusting learning rate of group 0 to 7.2084e-06.
# ---- Epoch 17/20
# (1) Training stage (lr = 0.000007) ...
# loss 3.13641, a_loss 1.15070, cD 1.60423, wmdcmp 0.20940, ema 0.85183, chxlmicf1 0.73220, chxlmacf1 0.77243, chx_loss 0.39467, chxlacc 0.86440, chxlrocaucmic 0.93943, chxlrocaucmac 0.92474, chestimglmacf1 0.27923, chestimglmicf1 0.43841, chestimgl_loss 0.34201, chestimgl_acc 0.91456, chestimglrocaucmic 0.95782, chestimglrocaucmac 0.95371, chestimgbbmf1 0.21069, chestimgbb_loss 0.14368, chestimgbbiou 0.81684, chestimgbbmae 0.06512, 364.02 secs
# (2) Validation stage ...
# cD 1.48963, wmdcmp 0.19807, ema 0.67774, chxlmicf1 0.56272, chxlmacf1 0.42654, chxlacc 0.78576, chxlrocaucmic 0.81034, chxlrocaucmac 0.71778, chestimglmacf1 0.14122, chestimglmicf1 0.33051, chestimgl_acc 0.91328, chestimglrocaucmic 0.89227, chestimglrocaucmac 0.76335, chestimgbbmf1 0.18613, chestimgbbiou 0.80185, chestimgbbmae 0.07246, 66.22 secs
# Adjusting learning rate of group 0 to 5.7898e-06.
# ---- Epoch 18/20
# (1) Training stage (lr = 0.000006) ...
# loss 3.14436, a_loss 1.15357, cD 1.61745, wmdcmp 0.21131, ema 0.84875, chxlmicf1 0.73037, chxlmacf1 0.77298, chx_loss 0.39720, chxlacc 0.86310, chxlrocaucmic 0.93808, chxlrocaucmac 0.92299, chestimglmacf1 0.27787, chestimglmicf1 0.43693, chestimgl_loss 0.34312, chestimgl_acc 0.91411, chestimglrocaucmic 0.95732, chestimglrocaucmac 0.95314, chestimgbbmf1 0.22282, chestimgbb_loss 0.10534, chestimgbbiou 0.82089, chestimgbbmae 0.06357, 363.51 secs
# (2) Validation stage ...
# cD 1.47611, wmdcmp 0.19688, ema 0.68043, chxlmicf1 0.56391, chxlmacf1 0.42732, chxlacc 0.78228, chxlrocaucmic 0.81101, chxlrocaucmac 0.71879, chestimglmacf1 0.14183, chestimglmicf1 0.33015, chestimgl_acc 0.91040, chestimglrocaucmic 0.89309, chestimglrocaucmac 0.76232, chestimgbbmf1 0.18761, chestimgbbiou 0.80008, chestimgbbmae 0.07322, 66.32 secs
# Adjusting learning rate of group 0 to 4.6503e-06.
# ---- Epoch 19/20
# (1) Training stage (lr = 0.000005) ...
# loss 3.04590, a_loss 1.15363, cD 1.60162, wmdcmp 0.20936, ema 0.84333, chxlmicf1 0.73528, chxlmacf1 0.77783, chx_loss 0.39079, chxlacc 0.86540, chxlrocaucmic 0.94005, chxlrocaucmac 0.92529, chestimglmacf1 0.27882, chestimglmicf1 0.43895, chestimgl_loss 0.34312, chestimgl_acc 0.91401, chestimglrocaucmic 0.95741, chestimglrocaucmac 0.95362, chestimgbbmf1 0.21548, chestimgbb_loss 0.24088, chestimgbbiou 0.81915, chestimgbbmae 0.06485, 366.41 secs
# (2) Validation stage ...
# cD 1.49166, wmdcmp 0.19797, ema 0.68941, chxlmicf1 0.56373, chxlmacf1 0.42670, chxlacc 0.78748, chxlrocaucmic 0.81173, chxlrocaucmac 0.72161, chestimglmacf1 0.14189, chestimglmicf1 0.32993, chestimgl_acc 0.91244, chestimglrocaucmic 0.89292, chestimglrocaucmac 0.76431, chestimgbbmf1 0.20211, chestimgbbiou 0.80780, chestimgbbmae 0.07021, 66.91 secs
# Adjusting learning rate of group 0 to 3.7351e-06.
# ---- Epoch 20/20
# (1) Training stage (lr = 0.000004) ...
# loss 3.15582, a_loss 1.15108, cD 1.61700, wmdcmp 0.21074, ema 0.85617, chxlmicf1 0.73373, chxlmacf1 0.77582, chx_loss 0.39343, chxlacc 0.86494, chxlrocaucmic 0.93954, chxlrocaucmac 0.92472, chestimglmacf1 0.28174, chestimglmicf1 0.43929, chestimgl_loss 0.34193, chestimgl_acc 0.91455, chestimglrocaucmic 0.95776, chestimglrocaucmac 0.95388, chestimgbbmf1 0.21270, chestimgbb_loss 0.11560, chestimgbbiou 0.81874, chestimgbbmae 0.06438, 364.01 secs
# (2) Validation stage ...
# cD 1.49803, wmdcmp 0.19809, ema 0.68671, chxlmicf1 0.56384, chxlmacf1 0.42833, chxlacc 0.78730, chxlrocaucmic 0.81080, chxlrocaucmac 0.72063, chestimglmacf1 0.14292, chestimglmicf1 0.33225, chestimgl_acc 0.91323, chestimglrocaucmic 0.89306, chestimglrocaucmac 0.76461, chestimgbbmf1 0.17169, chestimgbbiou 0.79734, chestimgbbmae 0.07406, 66.31 secs
# Adjusting learning rate of group 0 to 3.0000e-06.

# %%
# !python ../train_vqa.py \
        --checkpoint-folder "models/vqa/20230208_231344_mim+mim(chex)_oevqa(dense121+onehot+transf)_visenc-pretr=0_dws=1.0,1.0_medtok_chx_amp" \
        --epochs 20 \
        --batches-per-epoch 300 \
        --batch-size 80 \
        --num-workers 3 \
        --iters-to-accumulate 3 \
        --optimizer-name "adamw" \
        --scheduler "warmup+decay" \
        --lr 1e-6 \
        --warmup-and-decay-args "1e-6,4,1e-4,16,3e-6" \
        --override-lr \
        --save
# Out:
# script's arguments:
#    epochs: 20
#    batches_per_epoch: 300
#    checkpoint_folder: models/vqa/20230208_231344_mim+mim(chex)_oevqa(dense121+onehot+transf)_visenc-pretr=0_dws=1.0,1.0_medtok_chx_amp
#    iuxray_qa_adapted_reports_filename: None
#    mimiccxr_qa_adapted_reports_filename: None
#    vocab_min_freq: 10
#    embed_size: 256
#    question_encoding: bilstm
#    answer_decoding: lstm
#    question_hidden_size: 128
#    answer_hidden_size: 256
#    visual_input_mode: raw-image
#    raw_image_encoding: densenet-121
#    image_local_feat_size: 1024
#    image_encoder_pretrained_weights_path: None
#    freeze_image_encoder: False
#    imagenet_pretrained: False
#    visual_features_mlp_in_dim: None
#    visual_features_mlp_out_dim: None
#    visual_features_mlp_hidden_dims: None
#    iuxray_precomputed_visual_features_path: None
#    mimiccxr_precomputed_visual_features_path: None
#    chexpert_precomputed_visual_features_path: None
#    vinbig_precomputed_visual_features_path: None
#    clip_version: None
#    huggingface_model_name: None
#    chest_imagenome_bbox_hidden_size: 128
#    chest_imagenome_bbox_regressor_version: v1
#    num_regions: None
#    n_lstm_layers: 1
#    transf_dec_nhead: 2
#    transf_dec_dim_forward: 256
#    transf_dec_num_layers: 2
#    question_vec_size: 128
#    dropout_prob: 0
#    optimizer_name: adamw
#    lr: 1e-06
#    scheduler: warmup+decay
#    lr_decay: 0.76
#    lr_decay_patience: 2
#    warmup_and_decay_args: 1e-6,4,1e-4,16,3e-6
#    warmup_and_cosine_args: None
#    batch_size: 80
#    iters_to_accumulate: 3
#    num_workers: 3
#    device: GPU
#    img_aug_mode: None
#    image_size: (256, 256)
#    mimiccxr_weight: 1
#    chexpert_weight: 0.3
#    cxr14_weight: 0.3
#    vinbig_weight: 0.3
#    iuxray_weight: 0.05
#    mimiccxr_weight_chexpert_mode: 0.2
#    iuxray_weight_chexpert_mode: 0.05
#    padchest_weight: 0.4
#    mimiccxr_weight_chest_imagenome_mode: 1
#    mimiccxr_include_chexpert_mode: False
#    mimiccxr_include_mined_questions_mode: False
#    mimiccxr_view_mode: any_single
#    mimiccxr_include_chest_imagenome_mode: False
#    chest_imagenome_labels_filename: None
#    chest_imagenome_label_names_filename: None
#    iuxray_include_chexpert_mode: False
#    iuxray_include_mined_questions_mode: False
#    val_answer_decoding: greedy-search
#    beam_search_k: None
#    use_amp: False
#    use_medical_tokenization: False
#    medical_terms_frequency_filename: None
#    allowed_questions: None
#    pretrained_checkpoint_folder_path: None
#    balanced_dataloading: False
#    imbalance_reduction_coef: 0.5
#    iuxray_balanced_metadata_filename: None
#    mimiccxr_balanced_metadata_filename: None
#    one_question_per_batch: False
#    save: True
#    override_lr: True
#    train_mimiccxr: False
#    train_iuxray: False
#    train_chexpert: False
#    chexpert_mode: None
#    train_cxr14: False
#    train_vinbig: False
#    vinbig_training_data: all
#    vinbig_use_validation: False
#    train_padchest: False
#    padchest_training_data_mode: train
#    padchest_use_validation: False
#    padchest_train_study_ids_path: None
#    padchest_val_study_ids_path: None
#    padchest_test_study_ids_path: None
#    binary_loss_name: bce
#    classify_tags: False
#    n_medical_tags: None
#    iuxray_medical_tags_per_report_filename: None
#    mimiccxr_medical_tags_per_report_filename: None
#    classify_orientation: False
#    classify_chexpert: False
#    iuxray_chexpert_labels_filename: None
#    mimiccxr_chexpert_labels_filename: None
#    classify_chest_imagenome: False
#    predict_bboxes_chest_imagenome: False
#    clamp_bboxes_chest_imagenome: False
#    chest_imagenome_bbox_loss_weight: 1.0
#    classify_questions: False
#    n_mined_questions: None
#    iuxray_question_labels_filename: None
#    mimiccxr_question_labels_filename: None
#    merge_findings: False
# ----- Resuming training ------
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/vqa/20230208_231344_mim+mim(chex)_oevqa(dense121+onehot+transf)_visenc-pretr=0_dws=1.0,1.0_medtok_chx_amp/metadata.json
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Loading mimiccxr QA adapted reports ...
# --------------------------------------------------
# 3) Initializing tokenizer ...
# Loading /mnt/data/pamessina/workspaces/medvqa-workspace/cache/vocab(min_freq=10;mode=report;qa_adapted_reports__20220904_095810.json).pkl ...
# --------------------------------------------------
# 4) Creating instance of OpenEndedVQA model ...
# OpenEndedVQA():
#   image_encoder_pretrained_weights_path None
# create_densenet121_feature_extractor()
#    drop_rate: 0.0
#   self.global_feat_size = 2048
# BoundingBoxRegressor_v3:
#   local_feat_dim: 1024
#   global_feat_dim: 2048
#   hidden_dim: 128
#   num_classes: 36
#   num_regions: 64
#   n_questions = 111
#   n_questions_aux_task = 97
#   question_encoding = one-hot
#   answer_decoding = transformer
#   visual_input_mode = raw-image
#   name = oevqa(dense121+onehot+transf)
# --------------------------------------------------
# 5) Defining optimizer ...
# create_optimizer(): name = adamw
# --------------------------------------------------
# 6) Defining scheduler ...
# Using warmup+decay scheduler: 1e-6,4,1e-4,16,3e-6
# 1e-06 4 0.0001 16 3e-06
# Adjusting learning rate of group 0 to 1.0000e-06.
# Adjusting learning rate of group 0 to 1.0000e-06.
# --------------------------------------------------
# 7) Creating trainer and validator engines ...
# get_engine(): shift_answer=True
# chest_imagenome_bbox_loss_weight:  10.0
# get_engine(): shift_answer=False
# chest_imagenome_bbox_loss_weight:  1.0
# --------------------------------------------------
# 8) Defining image transform ...
# train_image_transform_kwargs: {'image_size': [256, 256], 'augmentation_mode': None, 'use_clip_transform': False, 'clip_version': None, 'use_huggingface_vitmodel_transform': False, 'huggingface_vitmodel_name': None}
# Using default transform
# mean = (0.485, 0.456, 0.406), std = (0.229, 0.224, 0.225), image_size = [256, 256], use_center_crop = False
# Returning transform without augmentation
# val_image_transform_kwargs: {'image_size': [256, 256], 'augmentation_mode': None, 'use_clip_transform': False, 'clip_version': None, 'use_huggingface_vitmodel_transform': False, 'huggingface_vitmodel_name': None}
# Using default transform
# mean = (0.485, 0.456, 0.406), std = (0.229, 0.224, 0.225), image_size = [256, 256], use_center_crop = False
# Returning transform without augmentation
# --------------------------------------------------
# 9) Defining collate_batch_fn ...
# get_vqa_collate_batch_fn(): dataset_id=1, one_hot_question_offset=0
# get_vqa_collate_batch_fn(): dataset_id=4, one_hot_question_offset=97
# --------------------------------------------------
# 10) Creating MIMIC-CXR vqa trainer ...
# MIMICCXR_VQA_Trainer: balanced_dataloading = True
# self.balanced_dataloading = True
# Checking if data is already cached in path /mnt/data/pamessina/workspaces/medvqa-workspace/cache/mimiccxr/mimiccxr_preprocessed_train_data__(hash=278,2530331200862576790).pkl ...
# 	Yes, it is, data successfully loaded :)
# batch_size = 80
# len(self.report_ids) = 2153951, len(set(self.report_ids)) = 211703
# _generate_datasets_and_dataloaders()
# self.balanced_dataloading = True
# Computing balanced datasets from scratch ...
# self.imbalance_reduction_coef = 0.5
# 100%|███████████████████████████████████████████| 97/97 [00:09<00:00,  9.80it/s]
#  *** merging from i=0 to j=3, acc_size = 143
# 	len(question_datasets) = 94
# len(self.val_indices) = 17722
# len(val_indices) = 3336
# generating training and validation dataloaders ...
# num_workers = 3
# Generating perfectly balanced train dataset in chexpert mode ...
#     label = 0, onehot=0, len(pos_indices)=40447, len(neg_indices)=169548
#     label = 1, onehot=1, len(pos_indices)=41277, len(neg_indices)=168718
#     label = 2, onehot=2, len(pos_indices)=67917, len(neg_indices)=142078
#     label = 3, onehot=3, len(pos_indices)=9072, len(neg_indices)=200923
#     label = 4, onehot=4, len(pos_indices)=70004, len(neg_indices)=139991
#     label = 5, onehot=5, len(pos_indices)=40951, len(neg_indices)=169044
#     label = 6, onehot=6, len(pos_indices)=18752, len(neg_indices)=191243
#     label = 7, onehot=7, len(pos_indices)=35212, len(neg_indices)=174783
#     label = 8, onehot=8, len(pos_indices)=66549, len(neg_indices)=143446
#     label = 9, onehot=9, len(pos_indices)=12644, len(neg_indices)=197351
#     label = 10, onehot=10, len(pos_indices)=65149, len(neg_indices)=144846
#     label = 11, onehot=11, len(pos_indices)=4669, len(neg_indices)=205326
#     label = 12, onehot=12, len(pos_indices)=8015, len(neg_indices)=201980
#     label = 13, onehot=13, len(pos_indices)=84236, len(neg_indices)=125759
# len(self.train_dataset__chexpert_mode) = 1000000000000000000
# Generating balanced validation dataset in chexpert mode ...
#     label = 0, onehot=0, len(pos_indices)=40, len(neg_indices)=40
#     label = 1, onehot=1, len(pos_indices)=40, len(neg_indices)=40
#     label = 2, onehot=2, len(pos_indices)=40, len(neg_indices)=40
#     label = 3, onehot=3, len(pos_indices)=40, len(neg_indices)=40
#     label = 4, onehot=4, len(pos_indices)=40, len(neg_indices)=40
#     label = 5, onehot=5, len(pos_indices)=40, len(neg_indices)=40
#     label = 6, onehot=6, len(pos_indices)=40, len(neg_indices)=40
#     label = 7, onehot=7, len(pos_indices)=40, len(neg_indices)=40
#     label = 8, onehot=8, len(pos_indices)=40, len(neg_indices)=40
#     label = 9, onehot=9, len(pos_indices)=40, len(neg_indices)=40
#     label = 10, onehot=10, len(pos_indices)=40, len(neg_indices)=40
#     label = 11, onehot=11, len(pos_indices)=40, len(neg_indices)=40
#     label = 12, onehot=12, len(pos_indices)=34, len(neg_indices)=40
#     label = 13, onehot=13, len(pos_indices)=40, len(neg_indices)=40
# len(self.val_dataset__chexpert_mode) = 1114
# done!
# Clamping Chest-Imagenome bounding boxes to [0, 1] in-place
# --------------------------------------------------
# 11) Creating dataloaders ...
# len(_train_dataloaders) = 2
# len(_val_dataloaders) = 2
# _train_weights = [1.0, 1.0]
# merged_dataset_name = mim+mim(chex)
# --------------------------------------------------
# 12) Attaching metrics, losses, timer and events to engines ...
# --------------------------------------------------
# 13) Defining learning rate scheduler handler ...
# checkpoint_names = ['checkpoint_39_chf1+chf1+chf1+chf1+chf1+cD+ema+wmmp=0.4784.pt', 'checkpoint_19_chf1+chf1+chf1+chf1+chf1+cD+ema+wmmp=0.4323.pt']
# --------------------------------------------------
# 14) Loading model from checkpoint ...
# checkpoint_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/vqa/20230208_231344_mim+mim(chex)_oevqa(dense121+onehot+transf)_visenc-pretr=0_dws=1.0,1.0_medtok_chx_amp/checkpoint_39_chf1+chf1+chf1+chf1+chf1+cD+ema+wmmp=0.4784.pt
# Loading model and epoch only
# Checkpoint successfully loaded!
# --------------------------------------------------
# 15) Defining log_metrics_handler ...
# MetricsLogger :: we'll be logging to /mnt/data/pamessina/workspaces/medvqa-workspace/models/vqa/20230208_231344_mim+mim(chex)_oevqa(dense121+onehot+transf)_visenc-pretr=0_dws=1.0,1.0_medtok_chx_amp/metrics_logs.csv
# --------------------------------------------------
# 16) Running trainer engine ...
# ---- Epoch 40/59
# (1) Training stage (lr = 0.000001) ...
# loss 24.14234, a_loss 1.10976, cD 1.71732, wmdcmp 0.22137, ema 0.84950, chxlmicf1 0.73658, chxlmacf1 0.77829, chx_loss 0.38972, chxlacc 0.86689, chxlrocaucmic 0.94132, chxlrocaucmac 0.92629, chestimglmacf1 0.27926, chestimglmicf1 0.44167, chestimgl_loss 0.34198, chestimgl_acc 0.91632, chestimglrocaucmic 0.95868, chestimglrocaucmac 0.95384, chestimgbbmf1 0.00000, chestimgbb_loss 16.84925, chestimgbbiou 0.09251, chestimgbbmae 0.98725, 346.85 secs
# (2) Validation stage ...
# cD 1.46133, wmdcmp 0.19583, ema 0.66158, chxlmicf1 0.55681, chxlmacf1 0.41463, chxlacc 0.78263, chxlrocaucmic 0.80528, chxlrocaucmac 0.70855, chestimglmacf1 0.13997, chestimglmicf1 0.32066, chestimgl_acc 0.91094, chestimglrocaucmic 0.88976, chestimglrocaucmac 0.74815, chestimgbbmf1 0.00000, chestimgbbiou 0.12596, chestimgbbmae 0.82726, 63.83 secs
# Adjusting learning rate of group 0 to 3.1623e-06.
# ---- Epoch 41/59
# (1) Training stage (lr = 0.000003) ...
# loss 15.78437, a_loss 1.16389, cD 1.58215, wmdcmp 0.20627, ema 0.82792, chxlmicf1 0.70388, chxlmacf1 0.73068, chx_loss 0.47695, chxlacc 0.84892, chxlrocaucmic 0.92417, chxlrocaucmac 0.90962, chestimglmacf1 0.27266, chestimglmicf1 0.43323, chestimgl_loss 0.39716, chestimgl_acc 0.91561, chestimglrocaucmic 0.95342, chestimglrocaucmac 0.94306, chestimgbbmf1 0.00000, chestimgbb_loss 8.20580, chestimgbbiou 0.20732, chestimgbbmae 0.61961, 344.45 secs
# (2) Validation stage ...
# cD 1.42595, wmdcmp 0.19156, ema 0.66248, chxlmicf1 0.54483, chxlmacf1 0.41034, chxlacc 0.76613, chxlrocaucmic 0.79103, chxlrocaucmac 0.69779, chestimglmacf1 0.13625, chestimglmicf1 0.30768, chestimgl_acc 0.90634, chestimglrocaucmic 0.88549, chestimglrocaucmac 0.73131, chestimgbbmf1 0.00011, chestimgbbiou 0.29790, chestimgbbmae 0.45171, 62.43 secs
# Adjusting learning rate of group 0 to 1.0000e-05.
# ---- Epoch 42/59
# (1) Training stage (lr = 0.000010) ...
# loss 9.08723, a_loss 1.16945, cD 1.59520, wmdcmp 0.20706, ema 0.81200, chxlmicf1 0.66820, chxlmacf1 0.67054, chx_loss 0.53135, chxlacc 0.82360, chxlrocaucmic 0.90337, chxlrocaucmac 0.89316, chestimglmacf1 0.23800, chestimglmicf1 0.39449, chestimgl_loss 0.43763, chestimgl_acc 0.90219, chestimglrocaucmic 0.94328, chestimglrocaucmac 0.93150, chestimgbbmf1 0.00010, chestimgbb_loss 4.28753, chestimgbbiou 0.40033, chestimgbbmae 0.32646, 339.31 secs
# (2) Validation stage ...
# cD 1.43950, wmdcmp 0.19311, ema 0.67864, chxlmicf1 0.54336, chxlmacf1 0.42355, chxlacc 0.75926, chxlrocaucmic 0.79099, chxlrocaucmac 0.71273, chestimglmacf1 0.13556, chestimglmicf1 0.28826, chestimgl_acc 0.89370, chestimglrocaucmic 0.88263, chestimglrocaucmac 0.74356, chestimgbbmf1 0.00020, chestimgbbiou 0.44971, chestimgbbmae 0.27520, 62.99 secs
# Adjusting learning rate of group 0 to 3.1623e-05.
# ---- Epoch 43/59
# (1) Training stage (lr = 0.000032) ...
# loss 7.21277, a_loss 1.16201, cD 1.61505, wmdcmp 0.21026, ema 0.82933, chxlmicf1 0.69592, chxlmacf1 0.70953, chx_loss 0.46207, chxlacc 0.84110, chxlrocaucmic 0.92120, chxlrocaucmac 0.91003, chestimglmacf1 0.24316, chestimglmicf1 0.40497, chestimgl_loss 0.39308, chestimgl_acc 0.90414, chestimglrocaucmic 0.94870, chestimglrocaucmac 0.94274, chestimgbbmf1 0.00113, chestimgbb_loss 2.68952, chestimgbbiou 0.50132, chestimgbbmae 0.24006, 347.35 secs
# (2) Validation stage ...
# cD 1.44250, wmdcmp 0.19347, ema 0.66248, chxlmicf1 0.55100, chxlmacf1 0.41754, chxlacc 0.77274, chxlrocaucmic 0.80391, chxlrocaucmac 0.71782, chestimglmacf1 0.14145, chestimglmicf1 0.31684, chestimgl_acc 0.90428, chestimglrocaucmic 0.88954, chestimglrocaucmac 0.75665, chestimgbbmf1 0.00819, chestimgbbiou 0.59649, chestimgbbmae 0.17695, 64.43 secs
# Adjusting learning rate of group 0 to 1.0000e-04.
# ---- Epoch 44/59
# (1) Training stage (lr = 0.000100) ...
# loss 4.65517, a_loss 1.16364, cD 1.57596, wmdcmp 0.20628, ema 0.83950, chxlmicf1 0.71560, chxlmacf1 0.74526, chx_loss 0.42357, chxlacc 0.85402, chxlrocaucmic 0.93165, chxlrocaucmac 0.91831, chestimglmacf1 0.25802, chestimglmicf1 0.42155, chestimgl_loss 0.36443, chestimgl_acc 0.90961, chestimglrocaucmic 0.95367, chestimglrocaucmac 0.94864, chestimgbbmf1 0.22242, chestimgbb_loss 0.50233, chestimgbbiou 0.79044, chestimgbbmae 0.07888, 363.34 secs
# (2) Validation stage ...
# cD 1.46731, wmdcmp 0.19529, ema 0.67235, chxlmicf1 0.56551, chxlmacf1 0.42820, chxlacc 0.78369, chxlrocaucmic 0.80908, chxlrocaucmac 0.71890, chestimglmacf1 0.14061, chestimglmicf1 0.32829, chestimgl_acc 0.90963, chestimglrocaucmic 0.89082, chestimglrocaucmac 0.75692, chestimgbbmf1 0.34743, chestimgbbiou 0.83759, chestimgbbmae 0.05817, 65.08 secs
# Adjusting learning rate of group 0 to 8.0319e-05.
# ---- Epoch 45/59
# (1) Training stage (lr = 0.000080) ...
# loss 3.41959, a_loss 1.15744, cD 1.61209, wmdcmp 0.21062, ema 0.83875, chxlmicf1 0.72809, chxlmacf1 0.76525, chx_loss 0.40297, chxlacc 0.86135, chxlrocaucmic 0.93666, chxlrocaucmac 0.92243, chestimglmacf1 0.26864, chestimglmicf1 0.43280, chestimgl_loss 0.35072, chestimgl_acc 0.91283, chestimglrocaucmic 0.95638, chestimglrocaucmac 0.95146, chestimgbbmf1 0.39985, chestimgbb_loss 0.28701, chestimgbbiou 0.84728, chestimgbbmae 0.05425, 352.71 secs
# (2) Validation stage ...
# cD 1.41819, wmdcmp 0.19002, ema 0.66697, chxlmicf1 0.55835, chxlmacf1 0.42090, chxlacc 0.78119, chxlrocaucmic 0.80580, chxlrocaucmac 0.71525, chestimglmacf1 0.14184, chestimglmicf1 0.32066, chestimgl_acc 0.90916, chestimglrocaucmic 0.88936, chestimglrocaucmac 0.75266, chestimgbbmf1 0.42850, chestimgbbiou 0.85146, chestimgbbmae 0.05290, 64.90 secs
# Adjusting learning rate of group 0 to 6.4512e-05.
# ---- Epoch 46/59
# (1) Training stage (lr = 0.000065) ...
# loss 3.44249, a_loss 1.15102, cD 1.61088, wmdcmp 0.20897, ema 0.84450, chxlmicf1 0.72981, chxlmacf1 0.76861, chx_loss 0.39700, chxlacc 0.86338, chxlrocaucmic 0.93871, chxlrocaucmac 0.92406, chestimglmacf1 0.27335, chestimglmicf1 0.43527, chestimgl_loss 0.34464, chestimgl_acc 0.91408, chestimglrocaucmic 0.95706, chestimglrocaucmac 0.95290, chestimgbbmf1 0.47037, chestimgbb_loss 0.25419, chestimgbbiou 0.85891, chestimgbbmae 0.04971, 354.78 secs
# (2) Validation stage ...
# cD 1.42188, wmdcmp 0.19279, ema 0.66786, chxlmicf1 0.56874, chxlmacf1 0.42714, chxlacc 0.78213, chxlrocaucmic 0.80898, chxlrocaucmac 0.71699, chestimglmacf1 0.14635, chestimglmicf1 0.33561, chestimgl_acc 0.91075, chestimglrocaucmic 0.89191, chestimglrocaucmac 0.75543, chestimgbbmf1 0.49439, chestimgbbiou 0.86207, chestimgbbmae 0.04882, 65.35 secs
# Adjusting learning rate of group 0 to 5.1816e-05.
# ---- Epoch 47/59
# (1) Training stage (lr = 0.000052) ...
# loss 3.25551, a_loss 1.15664, cD 1.57509, wmdcmp 0.20797, ema 0.84950, chxlmicf1 0.73535, chxlmacf1 0.77626, chx_loss 0.38970, chxlacc 0.86610, chxlrocaucmic 0.94028, chxlrocaucmac 0.92580, chestimglmacf1 0.27748, chestimglmicf1 0.43825, chestimgl_loss 0.34415, chestimgl_acc 0.91403, chestimglrocaucmic 0.95726, chestimglrocaucmac 0.95303, chestimgbbmf1 0.52604, chestimgbb_loss 0.26009, chestimgbbiou 0.86648, chestimgbbmae 0.04690, 350.85 secs
# (2) Validation stage ...
# cD 1.40985, wmdcmp 0.19096, ema 0.66697, chxlmicf1 0.56522, chxlmacf1 0.42125, chxlacc 0.78592, chxlrocaucmic 0.80733, chxlrocaucmac 0.71445, chestimglmacf1 0.14296, chestimglmicf1 0.32894, chestimgl_acc 0.91149, chestimglrocaucmic 0.88972, chestimglrocaucmac 0.75256, chestimgbbmf1 0.53702, chestimgbbiou 0.86730, chestimgbbmae 0.04682, 64.70 secs
# Adjusting learning rate of group 0 to 4.1618e-05.
# ---- Epoch 48/59
# (1) Training stage (lr = 0.000042) ...
# loss 3.50599, a_loss 1.15006, cD 1.61112, wmdcmp 0.21062, ema 0.85075, chxlmicf1 0.73668, chxlmacf1 0.77810, chx_loss 0.38778, chxlacc 0.86744, chxlrocaucmic 0.94089, chxlrocaucmac 0.92640, chestimglmacf1 0.27623, chestimglmicf1 0.43866, chestimgl_loss 0.33984, chestimgl_acc 0.91524, chestimglrocaucmic 0.95785, chestimglrocaucmac 0.95374, chestimgbbmf1 0.56533, chestimgbb_loss 0.22889, chestimgbbiou 0.87282, chestimgbbmae 0.04437, 351.50 secs
# (2) Validation stage ...
# cD 1.41017, wmdcmp 0.19145, ema 0.66697, chxlmicf1 0.56001, chxlmacf1 0.41899, chxlacc 0.78188, chxlrocaucmic 0.80767, chxlrocaucmac 0.71471, chestimglmacf1 0.14236, chestimglmicf1 0.32864, chestimgl_acc 0.90992, chestimglrocaucmic 0.89021, chestimglrocaucmac 0.75212, chestimgbbmf1 0.57088, chestimgbbiou 0.87167, chestimgbbmae 0.04516, 64.58 secs
# Adjusting learning rate of group 0 to 3.3427e-05.
# ---- Epoch 49/59
# (1) Training stage (lr = 0.000033) ...
# loss 3.21809, a_loss 1.15142, cD 1.61883, wmdcmp 0.21115, ema 0.84825, chxlmicf1 0.73834, chxlmacf1 0.78197, chx_loss 0.38192, chxlacc 0.86858, chxlrocaucmic 0.94253, chxlrocaucmac 0.92777, chestimglmacf1 0.28000, chestimglmicf1 0.44065, chestimgl_loss 0.33593, chestimgl_acc 0.91576, chestimglrocaucmic 0.95867, chestimglrocaucmac 0.95487, chestimgbbmf1 0.58906, chestimgbb_loss 0.24340, chestimgbbiou 0.87511, chestimgbbmae 0.04361, 353.48 secs
# (2) Validation stage ...
# cD 1.42961, wmdcmp 0.19172, ema 0.66966, chxlmicf1 0.56501, chxlmacf1 0.42111, chxlacc 0.78846, chxlrocaucmic 0.80933, chxlrocaucmac 0.71264, chestimglmacf1 0.14128, chestimglmicf1 0.33145, chestimgl_acc 0.91264, chestimglrocaucmic 0.89008, chestimglrocaucmac 0.75084, chestimgbbmf1 0.57706, chestimgbbiou 0.87276, chestimgbbmae 0.04477, 65.14 secs
# Adjusting learning rate of group 0 to 2.6849e-05.
# ---- Epoch 50/59
# (1) Training stage (lr = 0.000027) ...
# loss 2.94024, a_loss 1.14706, cD 1.59916, wmdcmp 0.20937, ema 0.85150, chxlmicf1 0.74286, chxlmacf1 0.78499, chx_loss 0.37757, chxlacc 0.87039, chxlrocaucmic 0.94339, chxlrocaucmac 0.92871, chestimglmacf1 0.28090, chestimglmicf1 0.44284, chestimgl_loss 0.33542, chestimgl_acc 0.91608, chestimglrocaucmic 0.95881, chestimglrocaucmac 0.95485, chestimgbbmf1 0.59891, chestimgbb_loss 0.23180, chestimgbbiou 0.87658, chestimgbbmae 0.04303, 355.77 secs
# (2) Validation stage ...
# cD 1.43322, wmdcmp 0.19304, ema 0.66607, chxlmicf1 0.56093, chxlmacf1 0.42158, chxlacc 0.78515, chxlrocaucmic 0.80929, chxlrocaucmac 0.71277, chestimglmacf1 0.14347, chestimglmicf1 0.33243, chestimgl_acc 0.91155, chestimglrocaucmic 0.89104, chestimglrocaucmac 0.74914, chestimgbbmf1 0.59004, chestimgbbiou 0.87407, chestimgbbmae 0.04426, 64.78 secs
# Adjusting learning rate of group 0 to 2.1565e-05.
# ---- Epoch 51/59
# (1) Training stage (lr = 0.000022) ...
# loss 3.36300, a_loss 1.14487, cD 1.62009, wmdcmp 0.21179, ema 0.85867, chxlmicf1 0.74353, chxlmacf1 0.78776, chx_loss 0.37732, chxlacc 0.87092, chxlrocaucmic 0.94381, chxlrocaucmac 0.92903, chestimglmacf1 0.28254, chestimglmicf1 0.44300, chestimgl_loss 0.33545, chestimgl_acc 0.91610, chestimglrocaucmic 0.95884, chestimglrocaucmac 0.95492, chestimgbbmf1 0.60992, chestimgbb_loss 0.23409, chestimgbbiou 0.87755, chestimgbbmae 0.04270, 348.65 secs
# (2) Validation stage ...
# cD 1.45372, wmdcmp 0.19606, ema 0.66786, chxlmicf1 0.55402, chxlmacf1 0.40886, chxlacc 0.78559, chxlrocaucmic 0.80753, chxlrocaucmac 0.70923, chestimglmacf1 0.14259, chestimglmicf1 0.33450, chestimgl_acc 0.91367, chestimglrocaucmic 0.89071, chestimglrocaucmac 0.74815, chestimgbbmf1 0.59904, chestimgbbiou 0.87533, chestimgbbmae 0.04384, 64.43 secs
# Adjusting learning rate of group 0 to 1.7321e-05.
# ---- Epoch 52/59
# (1) Training stage (lr = 0.000017) ...
# loss 3.17966, a_loss 1.14447, cD 1.61313, wmdcmp 0.21128, ema 0.85375, chxlmicf1 0.74318, chxlmacf1 0.78725, chx_loss 0.37340, chxlacc 0.87078, chxlrocaucmic 0.94439, chxlrocaucmac 0.92967, chestimglmacf1 0.28366, chestimglmicf1 0.44433, chestimgl_loss 0.33351, chestimgl_acc 0.91657, chestimglrocaucmic 0.95924, chestimglrocaucmac 0.95544, chestimgbbmf1 0.61832, chestimgbb_loss 0.23512, chestimgbbiou 0.87869, chestimgbbmae 0.04231, 348.53 secs
# (2) Validation stage ...
# cD 1.46514, wmdcmp 0.19799, ema 0.66607, chxlmicf1 0.56260, chxlmacf1 0.42020, chxlacc 0.78361, chxlrocaucmic 0.80887, chxlrocaucmac 0.71275, chestimglmacf1 0.14355, chestimglmicf1 0.33338, chestimgl_acc 0.91086, chestimglrocaucmic 0.89173, chestimglrocaucmac 0.75019, chestimgbbmf1 0.60798, chestimgbbiou 0.87629, chestimgbbmae 0.04346, 64.98 secs
# Adjusting learning rate of group 0 to 1.3912e-05.
# ---- Epoch 53/59
# (1) Training stage (lr = 0.000014) ...
# loss 3.05153, a_loss 1.13800, cD 1.65053, wmdcmp 0.21512, ema 0.85658, chxlmicf1 0.74485, chxlmacf1 0.78953, chx_loss 0.37333, chxlacc 0.87199, chxlrocaucmic 0.94470, chxlrocaucmac 0.92980, chestimglmacf1 0.28502, chestimglmicf1 0.44455, chestimgl_loss 0.33249, chestimgl_acc 0.91670, chestimglrocaucmic 0.95951, chestimglrocaucmac 0.95556, chestimgbbmf1 0.62329, chestimgbb_loss 0.22607, chestimgbbiou 0.87982, chestimgbbmae 0.04181, 350.23 secs
# (2) Validation stage ...
# cD 1.47059, wmdcmp 0.19813, ema 0.66248, chxlmicf1 0.56279, chxlmacf1 0.41743, chxlacc 0.78494, chxlrocaucmic 0.80918, chxlrocaucmac 0.71266, chestimglmacf1 0.14263, chestimglmicf1 0.33218, chestimgl_acc 0.91179, chestimglrocaucmic 0.89021, chestimglrocaucmac 0.74857, chestimgbbmf1 0.61416, chestimgbbiou 0.87692, chestimgbbmae 0.04320, 64.38 secs
# Adjusting learning rate of group 0 to 1.1174e-05.
# ---- Epoch 54/59
# (1) Training stage (lr = 0.000011) ...
# loss 3.26921, a_loss 1.14314, cD 1.61377, wmdcmp 0.21087, ema 0.85492, chxlmicf1 0.74539, chxlmacf1 0.78994, chx_loss 0.37312, chxlacc 0.87167, chxlrocaucmic 0.94414, chxlrocaucmac 0.92898, chestimglmacf1 0.28515, chestimglmicf1 0.44688, chestimgl_loss 0.33419, chestimgl_acc 0.91657, chestimglrocaucmic 0.95908, chestimglrocaucmac 0.95511, chestimgbbmf1 0.62930, chestimgbb_loss 0.22518, chestimgbbiou 0.88018, chestimgbbmae 0.04171, 354.90 secs
# (2) Validation stage ...
# cD 1.43332, wmdcmp 0.19445, ema 0.67056, chxlmicf1 0.56321, chxlmacf1 0.41931, chxlacc 0.78364, chxlrocaucmic 0.80866, chxlrocaucmac 0.71372, chestimglmacf1 0.14112, chestimglmicf1 0.32967, chestimgl_acc 0.91077, chestimglrocaucmic 0.88996, chestimglrocaucmac 0.74777, chestimgbbmf1 0.61698, chestimgbbiou 0.87751, chestimgbbmae 0.04298, 64.65 secs
# Adjusting learning rate of group 0 to 8.9747e-06.
# ---- Epoch 55/59
# (1) Training stage (lr = 0.000009) ...
# loss 3.20592, a_loss 1.14383, cD 1.63104, wmdcmp 0.21275, ema 0.85100, chxlmicf1 0.74513, chxlmacf1 0.79078, chx_loss 0.37253, chxlacc 0.87173, chxlrocaucmic 0.94490, chxlrocaucmac 0.92959, chestimglmacf1 0.28581, chestimglmicf1 0.44582, chestimgl_loss 0.33154, chestimgl_acc 0.91652, chestimglrocaucmic 0.95955, chestimglrocaucmac 0.95609, chestimgbbmf1 0.63308, chestimgbb_loss 0.22053, chestimgbbiou 0.88071, chestimgbbmae 0.04149, 354.78 secs
# (2) Validation stage ...
# cD 1.46626, wmdcmp 0.19758, ema 0.66158, chxlmicf1 0.56023, chxlmacf1 0.41641, chxlacc 0.78628, chxlrocaucmic 0.80760, chxlrocaucmac 0.71130, chestimglmacf1 0.14206, chestimglmicf1 0.33108, chestimgl_acc 0.91244, chestimglrocaucmic 0.88962, chestimglrocaucmac 0.74714, chestimgbbmf1 0.62087, chestimgbbiou 0.87810, chestimgbbmae 0.04277, 65.28 secs
# Adjusting learning rate of group 0 to 7.2084e-06.
# ---- Epoch 56/59
# (1) Training stage (lr = 0.000007) ...
# loss 2.99847, a_loss 1.14454, cD 1.61561, wmdcmp 0.21155, ema 0.86050, chxlmicf1 0.74718, chxlmacf1 0.79284, chx_loss 0.36896, chxlacc 0.87285, chxlrocaucmic 0.94550, chxlrocaucmac 0.93074, chestimglmacf1 0.28946, chestimglmicf1 0.44694, chestimgl_loss 0.33190, chestimgl_acc 0.91669, chestimglrocaucmic 0.95958, chestimglrocaucmac 0.95611, chestimgbbmf1 0.63476, chestimgbb_loss 0.21151, chestimgbbiou 0.88114, chestimgbbmae 0.04131, 354.52 secs
# (2) Validation stage ...
# cD 1.45341, wmdcmp 0.19594, ema 0.65978, chxlmicf1 0.56337, chxlmacf1 0.42087, chxlacc 0.78546, chxlrocaucmic 0.80862, chxlrocaucmac 0.71179, chestimglmacf1 0.14203, chestimglmicf1 0.32965, chestimgl_acc 0.91144, chestimglrocaucmic 0.88987, chestimglrocaucmac 0.74877, chestimgbbmf1 0.62389, chestimgbbiou 0.87805, chestimgbbmae 0.04278, 64.78 secs
# Adjusting learning rate of group 0 to 5.7898e-06.
# ---- Epoch 57/59
# (1) Training stage (lr = 0.000006) ...
# loss 2.99679, a_loss 1.14297, cD 1.65826, wmdcmp 0.21565, ema 0.85050, chxlmicf1 0.74768, chxlmacf1 0.79356, chx_loss 0.37008, chxlacc 0.87370, chxlrocaucmic 0.94551, chxlrocaucmac 0.93061, chestimglmacf1 0.28779, chestimglmicf1 0.44735, chestimgl_loss 0.32976, chestimgl_acc 0.91723, chestimglrocaucmic 0.95979, chestimglrocaucmac 0.95679, chestimgbbmf1 0.63692, chestimgbb_loss 0.21413, chestimgbbiou 0.88156, chestimgbbmae 0.04112, 354.46 secs
# (2) Validation stage ...
# cD 1.45936, wmdcmp 0.19649, ema 0.66607, chxlmicf1 0.56262, chxlmacf1 0.42084, chxlacc 0.78552, chxlrocaucmic 0.80842, chxlrocaucmac 0.71224, chestimglmacf1 0.14177, chestimglmicf1 0.33229, chestimgl_acc 0.91299, chestimglrocaucmic 0.89029, chestimglrocaucmac 0.74895, chestimgbbmf1 0.62551, chestimgbbiou 0.87835, chestimgbbmae 0.04268, 64.26 secs
# Adjusting learning rate of group 0 to 4.6503e-06.
# ---- Epoch 58/59
# (1) Training stage (lr = 0.000005) ...
# loss 3.17088, a_loss 1.14299, cD 1.65659, wmdcmp 0.21459, ema 0.85983, chxlmicf1 0.74706, chxlmacf1 0.79348, chx_loss 0.36947, chxlacc 0.87298, chxlrocaucmic 0.94548, chxlrocaucmac 0.93041, chestimglmacf1 0.28505, chestimglmicf1 0.44614, chestimgl_loss 0.33219, chestimgl_acc 0.91683, chestimglrocaucmic 0.95943, chestimglrocaucmac 0.95588, chestimgbbmf1 0.63868, chestimgbb_loss 0.22916, chestimgbbiou 0.88127, chestimgbbmae 0.04133, 357.61 secs
# (2) Validation stage ...
# cD 1.46159, wmdcmp 0.19720, ema 0.66068, chxlmicf1 0.56004, chxlmacf1 0.41609, chxlacc 0.78576, chxlrocaucmic 0.80792, chxlrocaucmac 0.71176, chestimglmacf1 0.14235, chestimglmicf1 0.32981, chestimgl_acc 0.91277, chestimglrocaucmic 0.88971, chestimglrocaucmac 0.74937, chestimgbbmf1 0.62596, chestimgbbiou 0.87830, chestimgbbmae 0.04270, 64.86 secs
# Adjusting learning rate of group 0 to 3.7351e-06.
# ---- Epoch 59/59
# (1) Training stage (lr = 0.000004) ...
# loss 3.11597, a_loss 1.14685, cD 1.61904, wmdcmp 0.21126, ema 0.85833, chxlmicf1 0.74722, chxlmacf1 0.79396, chx_loss 0.36957, chxlacc 0.87362, chxlrocaucmic 0.94564, chxlrocaucmac 0.93113, chestimglmacf1 0.28960, chestimglmicf1 0.44786, chestimgl_loss 0.33112, chestimgl_acc 0.91724, chestimglrocaucmic 0.95976, chestimglrocaucmac 0.95670, chestimgbbmf1 0.64093, chestimgbb_loss 0.21104, chestimgbbiou 0.88205, chestimgbbmae 0.04094, 351.68 secs
# (2) Validation stage ...
# cD 1.45607, wmdcmp 0.19575, ema 0.66248, chxlmicf1 0.56184, chxlmacf1 0.41778, chxlacc 0.78692, chxlrocaucmic 0.80787, chxlrocaucmac 0.71162, chestimglmacf1 0.14110, chestimglmicf1 0.33160, chestimgl_acc 0.91382, chestimglrocaucmic 0.88975, chestimglrocaucmac 0.74865, chestimgbbmf1 0.63083, chestimgbbiou 0.87895, chestimgbbmae 0.04247, 64.99 secs
# Adjusting learning rate of group 0 to 3.0000e-06.
