# %%
# %env CUDA_VISIBLE_DEVICES=1
# Out:
# env: CUDA_VISIBLE_DEVICES=1

# %%
# !python ../train_phrase_grounding.py \
--epochs 100 \
--batches_per_epoch 1000 \
--max_images_per_batch 5 \
--max_phrases_per_batch 1000 \
--max_phrases_per_image 45 \
--val_batch_size_factor 4 \
--raw_image_encoding "rad-dino-huggingface" \
--huggingface_model_name "microsoft/rad-dino" \
--image_size 416 416 \
--image_local_feat_size 768 \
--num_regions 841 \
--regions_width 29 \
--regions_height 29 \
--img_aug_mode "random-color-and-spatial" \
--phrase_embedding_size 128 \
--phrase_grounding_mode "adaptive_film_based_pooling_mlp__no_grounding" \
--visual_grounding_hidden_size 256 \
--phrase_mlp_hidden_dims 256 128 \
--num_train_workers 2 \
--num_val_workers 2 \
--gradient_accumulation_steps 5 \
--optimizer_name "adamw" \
--scheduler "exp-warmup+decay+cyclicdecay" \
--lr 1e-6 \
--warmup_decay_and_cyclic_decay_args "1e-6,3,8e-5,5,1e-6,8e-5,5,1e-6" \
--binary_multilabel_classif_loss_name "focal+bce+npbbce" \
--use_vinbig_for_train \
--use_vinbig_for_test \
--vinbig_phrase_embeddings_filepath \
"/mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/vinbig/label_phrase_embeddings(hash=353,2491289492560726319).pkl" \
--use_amp \
--save
# Out:
# script's arguments:
#    epochs: 100
#    batches_per_epoch: 1000
#    max_images_per_batch: 5
#    max_phrases_per_batch: 1000
#    max_phrases_per_image: 45
#    val_batch_size_factor: 4.0
#    checkpoint_folder: None
#    pretrained_checkpoint_folder_path: None
#    pretrained_checkpoint_folder_paths: None
#    freeze_image_encoder: False
#    raw_image_encoding: rad-dino-huggingface
#    huggingface_model_name: microsoft/rad-dino
#    num_regions: 841
#    image_local_feat_size: 768
#    image_encoder_pretrained_weights_path: None
#    image_encoder_dropout_p: 0
#    yolov8_model_name_or_path: None
#    yolov8_model_alias: None
#    phrase_embedding_size: 128
#    regions_width: 29
#    regions_height: 29
#    qkv_size: None
#    phrase_grounding_mode: adaptive_film_based_pooling_mlp__no_grounding
#    phrase_classifier_hidden_size: None
#    transf_d_model: None
#    transf_nhead: None
#    transf_dim_feedforward: None
#    transf_dropout: 0
#    transf_num_layers: None
#    visual_feature_proj_size: None
#    visual_grounding_hidden_size: 256
#    phrase_mlp_hidden_dims: [256, 128]
#    predict_global_alignment: False
#    alignment_proj_size: None
#    yolov11_model_name_or_path: None
#    yolov11_model_alias: None
#    optimizer_name: adamw
#    lr: 1e-06
#    scheduler: exp-warmup+decay+cyclicdecay
#    lr_decay: 0.76
#    lr_decay_patience: 2
#    warmup_and_decay_args: None
#    warmup_and_cosine_args: None
#    warmup_decay_and_cyclic_decay_args: 1e-6,3,8e-5,5,1e-6,8e-5,5,1e-6
#    gradient_accumulation_steps: 5
#    override_lr: False
#    max_grad_norm: None
#    attention_supervision_loss_weight: 1.0
#    phrase_classifier_loss_weight: 1.0
#    foreground_loss_weight: 1.0
#    background_loss_weight: 1.0
#    focal_loss_weight: 1.0
#    bce_loss_weight: 1.0
#    wbce_loss_weight: 1.0
#    binary_multilabel_classif_loss_name: focal+bce+npbbce
#    use_weighted_phrase_classifier_loss: False
#    cluster_and_label_weights_for_facts_filepath: None
#    use_attention_regularization_loss: False
#    use_contrastive_phrase_grounding_loss: False
#    nt_xent_temperature: 0.1
#    num_train_workers: 2
#    num_val_workers: 2
#    device: GPU
#    use_amp: True
#    image_size: [416, 416]
#    dicom_id_to_pos_neg_facts_filepath: None
#    iuxray_image_id_to_pos_neg_facts_filepath: None
#    mscxr_phrase2embedding_filepath: None
#    chest_imagenome_bbox_phrase_embeddings_filepath: None
#    vinbig_phrase_embeddings_filepath: /mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/vinbig/label_phrase_embeddings(hash=353,2491289492560726319).pkl
#    chexlocalize_class_phrase_embeddings_filepath: None
#    chexpert_class_phrase_embeddings_filepath: None
#    mimiccxr_exclude_noisy_images: False
#    mimiccxr_facts_weight: 1.0
#    chest_imagenome_anatlocs_weight: 1.0
#    mscxr_weight: 1.0
#    cxrlt2024_weight: 1.0
#    vinbig_weight: 1.0
#    chexlocalize_weight: 1.0
#    chexpert_weight: 1.0
#    iuxray_weight: 1.0
#    img_aug_mode: random-color-and-spatial
#    pos_area_prior: 0.4
#    neg_area_prior: 0.0
#    use_mimiccxr_facts_for_train: False
#    use_mimiccxr_facts_for_test: False
#    use_mscxr_for_train: False
#    use_mscxr_for_test: False
#    use_chest_imagenome_for_train: False
#    use_chest_imagenome_gold_for_test: False
#    use_vinbig_for_train: True
#    use_vinbig_for_test: True
#    use_chexlocalize_for_train: False
#    use_chexlocalize_for_test: False
#    use_chexpert_for_train: False
#    use_chexpert_for_test: False
#    use_iuxray_for_train: False
#    use_iuxray_for_test: False
#    use_cxrlt2024_challenge_split: False
#    use_cxrlt2024_custom_labels: False
#    use_cxrlt2024_official_labels: False
#    use_all_cxrlt2024_official_labels_for_training: False
#    vinbig_training_data_mode: train
#    chexpert_training_data_mode: all
#    mimiccxr_balance_long_middle_short_tail: False
#    mimiccxr_long_middle_short_tail_thresholds: (0.02, 0.05)
#    mimiccxr_report_fact_nli_integrated_data_filepath: None
#    mimiccxr_use_interpret_cxr_challenge_split: False
#    mimiccxr_interpret_cxr_challenge_split_filepath: None
#    iuxray_use_interpret_cxr_challenge_split: False
#    iuxray_interpret_cxr_challenge_split_filepath: None
#    chexpert_use_interpret_cxr_challenge_split: False
#    chexpert_interpret_cxr_challenge_split_filepath: None
#    chexlocalize_use_interpret_cxr_challenge_split: False
#    chexlocalize_interpret_cxr_challenge_split_filepath: None
#    cxrlt2024_custom_dicom_id_to_pos_neg_facts_filepath: None
#    cxrlt2024_official_training_labels_for_fact_classification_filepath: None
#    cxrlt2024_do_balanced_sampling: False
#    do_visual_grounding_with_bbox_regression: False
#    do_visual_grounding_with_segmentation: False
#    replace_phrase_embeddings_with_random_vectors: False
#    save: True
# ----- Training model from scratch ------
# --------------------------------------------------
# 1) device = cuda
# --------------------------------------------------
# 2) Creating instance of PhraseGrounder ...
# WARNING: Unused kwargs: {'pretrained_checkpoint_folder_path': None, 'pretrained_checkpoint_folder_paths': None}
# MultiPurposeVisualModule()
#   Initializing raw_image_encoder: rad-dino-huggingface
#   self.global_feat_size = 768
#   self.local_feat_size = 768
#   Initializing auxiliary tasks
# --------------------------------------------------
# 3) Defining optimizer ...
# create_optimizer(): name = adamw
# --------------------------------------------------
# 4) Defining scheduler ...
# Using exp-warmup+decay+cyclicdecay scheduler: 1e-6,3,8e-5,5,1e-6,8e-5,5,1e-6
# 1e-06 3 8e-05 5 1e-06 8e-05 5 1e-06
# self.steps_to_restart = 5
# self.steps = -1
# self.initial_lr = 8e-05
# --------------------------------------------------
# 5) Creating trainer and validator engines ...
# Focal_BCE_NPBBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 npbbce_weight = 0.3333333333333333
# Focal_BCE_NPBBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 npbbce_weight = 0.3333333333333333
# Focal_BCE_WBCBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 wbcbce_weight = 0.3333333333333333
# foreground_loss_weight: 1.0
# background_loss_weight: 1.0
# GradientAccumulator.__init__(): num_accumulation_steps = 5, max_grad_norm = None
# Focal_BCE_NPBBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 npbbce_weight = 0.3333333333333333
# Focal_BCE_NPBBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 npbbce_weight = 0.3333333333333333
# Focal_BCE_WBCBCE_Loss(): focal_weight = 0.3333333333333333 bce_weight = 0.3333333333333333 wbcbce_weight = 0.3333333333333333
# foreground_loss_weight: 1.0
# background_loss_weight: 1.0
# --------------------------------------------------
# 6) Creating VinBig Phrase Grounding Trainer ...
# get_image_transform()
#   image_size = [416, 416]
#   mean = [0.5307, 0.5307, 0.5307]
#   std = [0.2583, 0.2583, 0.2583]
# Using standard transform (only images, no bounding boxes, no masks)
# mean = [0.5307, 0.5307, 0.5307], std = [0.2583, 0.2583, 0.2583], image_size = [416, 416]
# get_train_transform(): Using normal transforms
# default_prob = 0.35
# Returning augmented transforms with mode random-color-and-spatial
# get_image_transform()
#   image_size = [416, 416]
#   mean = [0.5307, 0.5307, 0.5307]
#   std = [0.2583, 0.2583, 0.2583]
# Using standard transform (only images, no bounding boxes, no masks)
# mean = [0.5307, 0.5307, 0.5307], std = [0.2583, 0.2583, 0.2583], image_size = [416, 416]
# Returning transform without augmentation
# Loading bounding boxes
# Anomalous bboxes found: 29 of 37367
# class_id_offset: 0
# Anomalous bboxes found: 0 of 2697
# class_id_offset: 0
#   Loaded 18000 bounding boxes
# Loding phrase_embeddings and phrases from /mnt/data/pamessina_folder_backup_15_10_24/pamessina/medvqa-workspace/cache/vinbig/label_phrase_embeddings(hash=353,2491289492560726319).pkl...
# phrase_embeddings.shape = (28, 128)
# phrase_embeddings.dtype = float32
# len(phrases) = 28
# 	 aortic enlargement seen
# 	 atelectasis seen
# 	 calcification seen
# 	 cardiomegaly seen
# 	 clavicle fracture seen
# 	 consolidation seen
# 	 edema seen
# 	 emphysema seen
# 	 enlarged pulmonary artery seen
# 	 interstitial lung disease seen
# 	 infiltration seen
# 	 lung opacity seen
# 	 lung cavity seen
# 	 lung cyst seen
# 	 mediastinal shift seen
# 	 nodule/mass seen
# 	 pleural effusion seen
# 	 pleural thickening seen
# 	 pneumothorax seen
# 	 pulmonary fibrosis seen
# 	 rib fracture seen
# 	 other lesion seen
# 	 copd seen
# 	 lung tumor seen
# 	 pneumonia seen
# 	 tuberculosis seen
# 	 other disease seen
# 	 no abnormalities seen
# Compute phrase grounding masks and labels
# self.phrase_grounding_masks.shape = (18000, 22, 841)
# self.phrase_classification_labels.shape = (18000, 22)
# Append additional labels to phrase_classification_labels
# len(non_bbox_labels) = 6
# non_bbox_labels = ['COPD', 'Lung tumor', 'Pneumonia', 'Tuberculosis', 'Other disease', 'No finding']
# self.phrase_classification_labels.shape = (18000, 28)
# Reorder phrases and phrase_embeddings
# len(phrases) = 28
# len(actual_phrases) = 28
# phrase_embeddings.shape = (28, 128)
# Generating train dataset and dataloader
# len(train_indices) = 15000
# No labels: 0
# Edema: 13
# Clavicle fracture: 27
# Lung cyst: 33
# COPD: 35
# Lung cavity: 51
# Emphysema: 81
# Rib fracture: 90
# Pneumothorax: 96
# Enlarged PA: 131
# Mediastinal shift: 150
# Atelectasis: 187
# Lung tumor: 291
# Consolidation: 353
# ILD: 397
# Calcification: 458
# Infiltration: 613
# Tuberculosis: 750
# Nodule/Mass: 841
# Pneumonia: 917
# Pleural effusion: 1038
# Other lesion: 1154
# Lung Opacity: 1331
# Pulmonary fibrosis: 1621
# Pleural thickening: 2010
# Cardiomegaly: 2316
# Aortic enlargement: 3098
# Other disease: 4288
# No finding: 10601
# Group sizes: [10478, 771, 323, 312, 286, 278, 258, 243, 241, 218, 215, 167, 159, 156, 122, 119, 112, 102, 84, 83, 79, 47, 45, 32, 70]
#   len(indices) = 10478, weight = 2381.9852437292775
#   len(indices) = 771, weight = 882.1360585110112
#   len(indices) = 323, weight = 579.1323556126193
#   len(indices) = 312, weight = 568.7753795323758
#   len(indices) = 286, weight = 543.3127950518186
#   len(indices) = 278, weight = 535.1778961104801
#   len(indices) = 258, weight = 514.1586596868186
#   len(indices) = 243, weight = 497.69925147612867
#   len(indices) = 241, weight = 495.4562099629317
#   len(indices) = 218, weight = 468.76865710351854
#   len(indices) = 215, weight = 465.15882500917724
#   len(indices) = 167, weight = 402.55283205217046
#   len(indices) = 159, weight = 391.0802349542582
#   len(indices) = 156, weight = 386.6879164039802
#   len(indices) = 122, weight = 332.9187999914028
#   len(indices) = 119, weight = 327.76937690454827
#   len(indices) = 112, weight = 315.45337872121524
#   len(indices) = 102, weight = 297.0647831080699
#   len(indices) = 84, weight = 261.20109767987407
#   len(indices) = 83, weight = 259.088791948487
#   len(indices) = 79, weight = 250.497443897163
#   len(indices) = 47, weight = 171.37827001640065
#   len(indices) = 45, weight = 165.6367630898417
#   len(indices) = 32, weight = 125.0
#   len(indices) = 70, weight = 230.2655804515992
# batch_size = 5
# Generating val dataset and dataloader
# len(test_indices) = 3000
# batch_size = 20
# --------------------------------------------------
# 7) Creating dataloaders ...
# len(vinbig_trainer.train_dataloader) = 200000000000000000
# len(vinbig_trainer.val_dataloader) = 150
# len(_train_dataloaders) = 1
# len(_val_dataloaders) = 1
# _train_weights = [1.0]
# merged_dataset_name = vinbig
# --------------------------------------------------
# 8) Attaching metrics, losses, timer and events to engines ...
# --------------------------------------------------
# 9) Defining learning rate scheduler handler ...
# --------------------------------------------------
# 10) Defining learning rate scheduler handler ...
# --------------------------------------------------
# 11) Defining checkpoint folder path ...
# checkpoint_folder_path = /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250131_022916_vinbig_PhraseGrounder(microsoft-rad-dino,AdaptiveFiLM_MLP,128,256,256-128)
# metadata saved to /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250131_022916_vinbig_PhraseGrounder(microsoft-rad-dino,AdaptiveFiLM_MLP,128,256,256-128)/metadata.json
# --------------------------------------------------
# 12) Defining log_metrics_handler ...
# MetricsLogger :: we'll be logging to /mnt/data/pamessina/workspaces/medvqa-workspace/models/phrase_grounding/20250131_022916_vinbig_PhraseGrounder(microsoft-rad-dino,AdaptiveFiLM_MLP,128,256,256-128)/metrics_logs.csv
# --------------------------------------------------
# 13) Running trainer engine ...
# ---- Epoch 1/100
# (1) Training stage (lr = 0.000001) ...
# loss 1.58830, vbg_phrcls_loss 1.58830, vbg_prc_auc 0.15785, 225.90 secs
# (2) Validation stage ...
# vbg_prc_auc 0.08396, 97.49 secs
# New checkpoint saved: checkpoint_1_vbg_prc_auc=0.0877.pt
# ---- Epoch 2/100
# (1) Training stage (lr = 0.000004) ...
# loss 1.28511, vbg_phrcls_loss 1.28511, vbg_prc_auc 0.15852, 230.99 secs
# (2) Validation stage ...
# vbg_prc_auc 0.11277, 96.17 secs
# New checkpoint saved: checkpoint_2_vbg_prc_auc=0.1151.pt
# ---- Epoch 3/100
# (1) Training stage (lr = 0.000019) ...
# loss 1.10050, vbg_phrcls_loss 1.10050, vbg_prc_auc 0.17476, 225.38 secs
# (2) Validation stage ...
# vbg_prc_auc 0.12254, 96.31 secs
# New checkpoint saved: checkpoint_3_vbg_prc_auc=0.1252.pt
# ---- Epoch 4/100
# (1) Training stage (lr = 0.000080) ...
# loss 1.01973, vbg_phrcls_loss 1.01973, vbg_prc_auc 0.18941, 224.12 secs
# (2) Validation stage ...
# vbg_prc_auc 0.10869, 96.46 secs
# ---- Epoch 5/100
# (1) Training stage (lr = 0.000033) ...
# loss 0.97715, vbg_phrcls_loss 0.97715, vbg_prc_auc 0.21097, 224.19 secs
# (2) Validation stage ...
# vbg_prc_auc 0.12206, 96.03 secs
# New checkpoint saved: checkpoint_5_vbg_prc_auc=0.1265.pt
# ---- Epoch 6/100
# (1) Training stage (lr = 0.000014) ...
# loss 0.94237, vbg_phrcls_loss 0.94237, vbg_prc_auc 0.22679, 230.95 secs
# (2) Validation stage ...
# vbg_prc_auc 0.12806, 96.68 secs
# New checkpoint saved: checkpoint_6_vbg_prc_auc=0.1330.pt
# ---- Epoch 7/100
# (1) Training stage (lr = 0.000006) ...
# loss 0.92744, vbg_phrcls_loss 0.92744, vbg_prc_auc 0.23965, 229.82 secs
# (2) Validation stage ...
# vbg_prc_auc 0.13068, 99.60 secs
# New checkpoint saved: checkpoint_7_vbg_prc_auc=0.1361.pt
# ---- Epoch 8/100
# (1) Training stage (lr = 0.000002) ...
# loss 0.91747, vbg_phrcls_loss 0.91747, vbg_prc_auc 0.25099, 230.95 secs
# (2) Validation stage ...
# vbg_prc_auc 0.13563, 96.98 secs
# New checkpoint saved: checkpoint_8_vbg_prc_auc=0.1414.pt
# ---- Epoch 9/100
# (1) Training stage (lr = 0.000001) ...
# loss 0.91072, vbg_phrcls_loss 0.91072, vbg_prc_auc 0.25571, 231.11 secs
# (2) Validation stage ...
# vbg_prc_auc 0.13717, 99.79 secs
# New checkpoint saved: checkpoint_9_vbg_prc_auc=0.1431.pt
# ---- Epoch 10/100
# (1) Training stage (lr = 0.000080) ...
# vbg_prc_auc 0.14696, 101.54 secs
# New checkpoint saved: checkpoint_10_vbg_prc_auc=0.1509.pt
# ---- Epoch 11/100
# (1) Training stage (lr = 0.000027) ...
# loss 0.90432, vbg_phrcls_loss 0.90432, vbg_prc_auc 0.25661, 231.01 secs
# (2) Validation stage ...
# vbg_prc_auc 0.15354, 97.72 secs
# New checkpoint saved: checkpoint_11_vbg_prc_auc=0.1587.pt
# ---- Epoch 12/100
# (1) Training stage (lr = 0.000009) ...
# loss 0.86198, vbg_phrcls_loss 0.86198, vbg_prc_auc 0.29173, 224.35 secs
# (2) Validation stage ...
# vbg_prc_auc 0.15463, 98.86 secs
# New checkpoint saved: checkpoint_12_vbg_prc_auc=0.1615.pt
# ---- Epoch 13/100
# (1) Training stage (lr = 0.000003) ...
# loss 0.84713, vbg_phrcls_loss 0.84713, vbg_prc_auc 0.30755, 230.17 secs
# (2) Validation stage ...
# vbg_prc_auc 0.15921, 96.81 secs
# New checkpoint saved: checkpoint_13_vbg_prc_auc=0.1666.pt
# ---- Epoch 14/100
# (1) Training stage (lr = 0.000001) ...
# loss 0.84162, vbg_phrcls_loss 0.84162, vbg_prc_auc 0.31319, 224.82 secs
# (2) Validation stage ...
# vbg_prc_auc 0.15889, 97.64 secs
# ---- Epoch 15/100
# (1) Training stage (lr = 0.000080) ...
# loss 0.87113, vbg_phrcls_loss 0.87113, vbg_prc_auc 0.28032, 230.26 secs
# (2) Validation stage ...
# vbg_prc_auc 0.16770, 96.29 secs
# New checkpoint saved: checkpoint_15_vbg_prc_auc=0.1733.pt
# ---- Epoch 16/100
# (1) Training stage (lr = 0.000027) ...
# loss 0.81728, vbg_phrcls_loss 0.81728, vbg_prc_auc 0.33086, 230.48 secs
# (2) Validation stage ...
# vbg_prc_auc 0.21291, 96.37 secs
# New checkpoint saved: checkpoint_16_vbg_prc_auc=0.2188.pt
# ---- Epoch 17/100
# (1) Training stage (lr = 0.000009) ...
# loss 0.77277, vbg_phrcls_loss 0.77277, vbg_prc_auc 0.36562, 229.95 secs
# (2) Validation stage ...
# vbg_prc_auc 0.21598, 99.76 secs
# New checkpoint saved: checkpoint_17_vbg_prc_auc=0.2235.pt
# ---- Epoch 18/100
# (1) Training stage (lr = 0.000003) ...
# loss 0.75780, vbg_phrcls_loss 0.75780, vbg_prc_auc 0.38424, 228.42 secs
# (2) Validation stage ...
# vbg_prc_auc 0.22386, 96.74 secs
# New checkpoint saved: checkpoint_18_vbg_prc_auc=0.2319.pt
# ---- Epoch 19/100
# (1) Training stage (lr = 0.000001) ...
# loss 0.74809, vbg_phrcls_loss 0.74809, vbg_prc_auc 0.38658, 228.78 secs
# (2) Validation stage ...
# vbg_prc_auc 0.22596, 113.51 secs
# New checkpoint saved: checkpoint_19_vbg_prc_auc=0.2340.pt
# ---- Epoch 20/100
# (1) Training stage (lr = 0.000080) ...
# loss 0.79616, vbg_phrcls_loss 0.79616, vbg_prc_auc 0.35272, 225.91 secs
# (2) Validation stage ...
# vbg_prc_auc 0.22219, 96.52 secs
# ---- Epoch 21/100
# (1) Training stage (lr = 0.000027) ...
# loss 0.72284, vbg_phrcls_loss 0.72284, vbg_prc_auc 0.41706, 223.88 secs
# (2) Validation stage ...
# vbg_prc_auc 0.26666, 95.89 secs
# New checkpoint saved: checkpoint_21_vbg_prc_auc=0.2742.pt
# ---- Epoch 22/100
# (1) Training stage (lr = 0.000009) ...
# loss 0.67911, vbg_phrcls_loss 0.67911, vbg_prc_auc 0.45612, 228.70 secs
# (2) Validation stage ...
# vbg_prc_auc 0.28492, 98.59 secs
# New checkpoint saved: checkpoint_22_vbg_prc_auc=0.2935.pt
# ---- Epoch 23/100
# (1) Training stage (lr = 0.000003) ...
# loss 0.67034, vbg_phrcls_loss 0.67034, vbg_prc_auc 0.47156, 229.83 secs
# (2) Validation stage ...
# vbg_prc_auc 0.27427, 97.53 secs
# ---- Epoch 24/100
# (1) Training stage (lr = 0.000001) ...
# loss 0.65978, vbg_phrcls_loss 0.65978, vbg_prc_auc 0.47940, 228.26 secs
# (2) Validation stage ...
# vbg_prc_auc 0.27653, 97.92 secs
# ---- Epoch 25/100
# (1) Training stage (lr = 0.000080) ...
# loss 0.71716, vbg_phrcls_loss 0.71716, vbg_prc_auc 0.42850, 229.32 secs
# (2) Validation stage ...
# vbg_prc_auc 0.26759, 97.58 secs
# ---- Epoch 26/100
# (1) Training stage (lr = 0.000027) ...
# loss 0.64232, vbg_phrcls_loss 0.64232, vbg_prc_auc 0.49420, 231.17 secs
# (2) Validation stage ...
# vbg_prc_auc 0.26869, 98.57 secs
# ---- Epoch 27/100
# (1) Training stage (lr = 0.000009) ...
# loss 0.60901, vbg_phrcls_loss 0.60901, vbg_prc_auc 0.53471, 230.46 secs
# (2) Validation stage ...
# vbg_prc_auc 0.27319, 98.47 secs
# ---- Epoch 28/100
# (1) Training stage (lr = 0.000003) ...
# loss 0.59446, vbg_phrcls_loss 0.59446, vbg_prc_auc 0.56250, 231.20 secs
# (2) Validation stage ...
# vbg_prc_auc 0.28046, 96.35 secs
# New checkpoint saved: checkpoint_28_vbg_prc_auc=0.2946.pt
# ---- Epoch 29/100
# (1) Training stage (lr = 0.000001) ...
# loss 0.58565, vbg_phrcls_loss 0.58565, vbg_prc_auc 0.56490, 230.15 secs
# (2) Validation stage ...
# vbg_prc_auc 0.27886, 97.12 secs
# ---- Epoch 30/100
# (1) Training stage (lr = 0.000080) ...
# loss 0.65696, vbg_phrcls_loss 0.65696, vbg_prc_auc 0.49147, 231.12 secs
# (2) Validation stage ...
# vbg_prc_auc 0.28817, 104.02 secs
# New checkpoint saved: checkpoint_30_vbg_prc_auc=0.2983.pt
# ---- Epoch 31/100
# (1) Training stage (lr = 0.000027) ...
# loss 0.58311, vbg_phrcls_loss 0.58311, vbg_prc_auc 0.58204, 229.52 secs
# (2) Validation stage ...
# vbg_prc_auc 0.28476, 98.55 secs
# New checkpoint saved: checkpoint_31_vbg_prc_auc=0.2996.pt
# ---- Epoch 32/100
# (1) Training stage (lr = 0.000009) ...
# loss 0.54267, vbg_phrcls_loss 0.54267, vbg_prc_auc 0.61536, 230.48 secs
# (2) Validation stage ...
# vbg_prc_auc 0.28462, 96.65 secs
# New checkpoint saved: checkpoint_32_vbg_prc_auc=0.3012.pt
# ---- Epoch 33/100
# (1) Training stage (lr = 0.000003) ...
# loss 0.52444, vbg_phrcls_loss 0.52444, vbg_prc_auc 0.64189, 228.72 secs
# (2) Validation stage ...
# vbg_prc_auc 0.28873, 96.11 secs
# New checkpoint saved: checkpoint_33_vbg_prc_auc=0.3064.pt
# ---- Epoch 34/100
# (1) Training stage (lr = 0.000001) ...
# loss 0.51857, vbg_phrcls_loss 0.51857, vbg_prc_auc 0.65907, 227.80 secs
# (2) Validation stage ...
# vbg_prc_auc 0.28926, 98.91 secs
# New checkpoint saved: checkpoint_34_vbg_prc_auc=0.3078.pt
# ---- Epoch 35/100
# (1) Training stage (lr = 0.000080) ...
# loss 0.59279, vbg_phrcls_loss 0.59279, vbg_prc_auc 0.55830, 230.62 secs
# (2) Validation stage ...
# vbg_prc_auc 0.28409, 96.08 secs
# ---- Epoch 36/100
# (1) Training stage (lr = 0.000027) ...
# loss 0.52228, vbg_phrcls_loss 0.52228, vbg_prc_auc 0.64543, 230.10 secs
# (2) Validation stage ...
# vbg_prc_auc 0.33108, 101.23 secs
# New checkpoint saved: checkpoint_36_vbg_prc_auc=0.3468.pt
# ---- Epoch 37/100
# (1) Training stage (lr = 0.000009) ...
# loss 0.47761, vbg_phrcls_loss 0.47761, vbg_prc_auc 0.70411, 229.29 secs
# (2) Validation stage ...
# vbg_prc_auc 0.33469, 97.27 secs
# New checkpoint saved: checkpoint_37_vbg_prc_auc=0.3532.pt
# ---- Epoch 38/100
# (1) Training stage (lr = 0.000003) ...
# loss 0.46039, vbg_phrcls_loss 0.46039, vbg_prc_auc 0.72029, 228.69 secs
# (2) Validation stage ...
# vbg_prc_auc 0.33818, 96.61 secs
# New checkpoint saved: checkpoint_38_vbg_prc_auc=0.3573.pt
# ---- Epoch 39/100
# (1) Training stage (lr = 0.000001) ...
# loss 0.45416, vbg_phrcls_loss 0.45416, vbg_prc_auc 0.73510, 228.91 secs
# (2) Validation stage ...
# vbg_prc_auc 0.33765, 95.12 secs
# New checkpoint saved: checkpoint_39_vbg_prc_auc=0.3575.pt
# ---- Epoch 40/100
# (1) Training stage (lr = 0.000080) ...
# loss 0.54170, vbg_phrcls_loss 0.54170, vbg_prc_auc 0.62883, 228.82 secs
# (2) Validation stage ...
# vbg_prc_auc 0.31940, 96.29 secs
# ---- Epoch 41/100
# (1) Training stage (lr = 0.000027) ...
# loss 0.46105, vbg_phrcls_loss 0.46105, vbg_prc_auc 0.72361, 228.49 secs
# (2) Validation stage ...
# vbg_prc_auc 0.32927, 95.06 secs
# ---- Epoch 42/100
# (1) Training stage (lr = 0.000009) ...
# loss 0.40808, vbg_phrcls_loss 0.40808, vbg_prc_auc 0.78980, 228.02 secs
# (2) Validation stage ...
# vbg_prc_auc 0.33718, 109.71 secs
# New checkpoint saved: checkpoint_42_vbg_prc_auc=0.3598.pt
# ---- Epoch 43/100
# (1) Training stage (lr = 0.000003) ...
# loss 0.39152, vbg_phrcls_loss 0.39152, vbg_prc_auc 0.80286, 226.61 secs
# (2) Validation stage ...
# vbg_prc_auc 0.33930, 109.23 secs
# New checkpoint saved: checkpoint_43_vbg_prc_auc=0.3625.pt
# ---- Epoch 44/100
# (1) Training stage (lr = 0.000001) ...
# loss 0.38589, vbg_phrcls_loss 0.38589, vbg_prc_auc 0.81085, 226.92 secs
# (2) Validation stage ...
# vbg_prc_auc 0.33972, 108.58 secs
# New checkpoint saved: checkpoint_44_vbg_prc_auc=0.3633.pt
# ---- Epoch 45/100
# (1) Training stage (lr = 0.000080) ...
# loss 0.48159, vbg_phrcls_loss 0.48159, vbg_prc_auc 0.70622, 225.19 secs
# (2) Validation stage ...
# vbg_prc_auc 0.28656, 107.37 secs
# ---- Epoch 46/100
# (1) Training stage (lr = 0.000027) ...
# loss 0.40576, vbg_phrcls_loss 0.40576, vbg_prc_auc 0.78252, 225.77 secs
# (2) Validation stage ...
# vbg_prc_auc 0.33944, 109.31 secs
# ---- Epoch 47/100
# (1) Training stage (lr = 0.000009) ...
# loss 0.35267, vbg_phrcls_loss 0.35267, vbg_prc_auc 0.85185, 226.27 secs
# (2) Validation stage ...
# vbg_prc_auc 0.35227, 109.68 secs
# New checkpoint saved: checkpoint_47_vbg_prc_auc=0.3772.pt
# ---- Epoch 48/100
# (1) Training stage (lr = 0.000003) ...
# loss 0.33335, vbg_phrcls_loss 0.33335, vbg_prc_auc 0.88000, 227.84 secs
# (2) Validation stage ...
# vbg_prc_auc 0.31321, 109.41 secs
# ---- Epoch 49/100
# (1) Training stage (lr = 0.000001) ...
# loss 0.32672, vbg_phrcls_loss 0.32672, vbg_prc_auc 0.87431, 227.80 secs
# (2) Validation stage ...
# vbg_prc_auc 0.31844, 110.74 secs
# ---- Epoch 50/100
# (1) Training stage (lr = 0.000080) ...
# loss 0.42120, vbg_phrcls_loss 0.42120, vbg_prc_auc 0.77366, 226.84 secs
# (2) Validation stage ...
# vbg_prc_auc 0.30770, 111.53 secs
# ---- Epoch 51/100
# (1) Training stage (lr = 0.000027) ...
# loss 0.35089, vbg_phrcls_loss 0.35089, vbg_prc_auc 0.85089, 229.36 secs
# (2) Validation stage ...
# vbg_prc_auc 0.31543, 112.52 secs
# ---- Epoch 52/100
# (1) Training stage (lr = 0.000009) ...
# loss 0.29722, vbg_phrcls_loss 0.29722, vbg_prc_auc 0.90108, 228.95 secs
# (2) Validation stage ...
# vbg_prc_auc 0.32038, 95.68 secs
# ---- Epoch 53/100
# (1) Training stage (lr = 0.000003) ...
# loss 0.27396, vbg_phrcls_loss 0.27396, vbg_prc_auc 0.92328, 227.31 secs
# (2) Validation stage ...
# vbg_prc_auc 0.32150, 95.58 secs
# ---- Epoch 54/100
# (1) Training stage (lr = 0.000001) ...
# loss 0.26611, vbg_phrcls_loss 0.26611, vbg_prc_auc 0.92517, 230.01 secs
# (2) Validation stage ...
# vbg_prc_auc 0.31246, 98.36 secs
# ---- Epoch 55/100
# (1) Training stage (lr = 0.000080) ...
# ^C iteration 54050
# Engine run is terminating due to exception:
# Traceback (most recent call last):
#   File "/home/pamessina/medvqa/medvqa/notebooks/../train_phrase_grounding.py", line 1539, in <module>
#     train_from_scratch(**args)
#   File "/home/pamessina/medvqa/medvqa/notebooks/../train_phrase_grounding.py", line 1405, in train_from_scratch
#     return train_model(
#   File "/home/pamessina/medvqa/medvqa/notebooks/../train_phrase_grounding.py", line 918, in train_model
#     run_common_boilerplate_code_and_start_training(
#   File "/home/pamessina/medvqa/medvqa/training/utils.py", line 142, in run_common_boilerplate_code_and_start_training
#     trainer_engine.run(train_dataloader, max_epochs=epochs, epoch_length=batches_per_epoch)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 892, in run
#     return self._internal_run()
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 935, in _internal_run
#     return next(self._internal_run_generator)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 993, in _internal_run_as_gen
#     self._handle_exception(e)
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 638, in _handle_exception
#     raise e
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 959, in _internal_run_as_gen
#     epoch_time_taken += yield from self._run_once_on_dataset_as_gen()
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/ignite/engine/engine.py", line 1068, in _run_once_on_dataset_as_gen
#     self.state.output = self._process_function(self, self.state.batch)
#   File "/home/pamessina/medvqa/medvqa/training/phrase_grounding.py", line 984, in step_fn
#     output = flag_to_step_fn[flag](batch)
#   File "/home/pamessina/medvqa/medvqa/training/phrase_grounding.py", line 615, in step_fn__vinbig_bbox_grounding
#     gradient_accumulator.step(batch_loss, model)
#   File "/home/pamessina/medvqa/medvqa/losses/optimizers.py", line 29, in step
#     self.scaler.scale(batch_loss).backward()
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/_tensor.py", line 525, in backward
#     torch.autograd.backward(
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/autograd/__init__.py", line 267, in backward
#     _engine_run_backward(
#   File "/home/pamessina/venv2/lib/python3.10/site-packages/torch/autograd/graph.py", line 744, in _engine_run_backward
#     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# KeyboardInterrupt
