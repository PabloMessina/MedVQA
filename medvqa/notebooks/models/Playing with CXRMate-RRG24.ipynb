# %%
import torch  
from torchvision.transforms import v2
import transformers
import datasets
from torch.utils.data import Dataset, DataLoader

mbatch_size = 10

tokenizer = transformers.AutoTokenizer.from_pretrained('aehrc/cxrmate-rrg24')
model = transformers.AutoModel.from_pretrained('aehrc/cxrmate-rrg24', trust_remote_code=True)
transforms = v2.Compose(
    [
        v2.PILToTensor(),
        v2.Grayscale(num_output_channels=3),
        v2.Resize(size=model.config.encoder.image_size, antialias=True),
        v2.CenterCrop(size=[model.config.encoder.image_size]*2),
        v2.ToDtype(torch.float32, scale=True),
        v2.Normalize(mean=model.config.encoder.image_mean, std=model.config.encoder.image_std),
    ]
)

dataset = datasets.load_dataset('StanfordAIMI/interpret-cxr-test-public')['test']

def transform_batch(batch):
    batch['images'] = [torch.stack([transforms(j) for j in i]) for i in batch['images']]
    batch['images'] = torch.nn.utils.rnn.pad_sequence(batch['images'], batch_first=True, padding_value=0.0)  
    return batch

dataset = dataset.with_transform(transform_batch)
dataloader = DataLoader(dataset, batch_size=mbatch_size, shuffle=True)
batch = next(iter(dataloader))

output_ids = model.generate(
    pixel_values=batch['images'],
    max_length=512,
    num_beams=4,
    bad_words_ids=[[tokenizer.convert_tokens_to_ids('[NF]')], [tokenizer.convert_tokens_to_ids('[NI]')]],
)
findings, impression = model.split_and_decode_sections(output_ids, tokenizer)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 33
#      30 dataloader = DataLoader(dataset, batch_size=mbatch_size, shuffle=True)
#      31 batch = next(iter(dataloader))
# ---> 33 output_ids = model.generate(
#      34     pixel_values=batch['images'],
#      35     max_length=512,
#      36     num_beams=4,
#      37     bad_words_ids=[[tokenizer.convert_tokens_to_ids('[NF]')], [tokenizer.convert_tokens_to_ids('[NI]')]],
#      38 )
#      39 findings, impression = model.split_and_decode_sections(output_ids, tokenizer)
#
# File ~/venv2/lib/python3.10/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~/venv2/lib/python3.10/site-packages/transformers/generation/utils.py:1597, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    1591     model_kwargs["attention_mask"] = self._prepare_attention_mask_for_generation(
#    1592         inputs_tensor, generation_config.pad_token_id, generation_config.eos_token_id
#    1593     )
#    1595 if self.config.is_encoder_decoder and "encoder_outputs" not in model_kwargs:
#    1596     # if model is encoder decoder encoder_outputs are created and added to `model_kwargs`
# -> 1597     model_kwargs = self._prepare_encoder_decoder_kwargs_for_generation(
#    1598         inputs_tensor, model_kwargs, model_input_name, generation_config
#    1599     )
#    1601 # 5. Prepare `input_ids` which will be used for auto-regressive generation
#    1602 if self.config.is_encoder_decoder:
#
# File ~/venv2/lib/python3.10/site-packages/transformers/generation/utils.py:523, in GenerationMixin._prepare_encoder_decoder_kwargs_for_generation(self, inputs_tensor, model_kwargs, model_input_name, generation_config)
#     521 encoder_kwargs["return_dict"] = True
#     522 encoder_kwargs[model_input_name] = inputs_tensor
# --> 523 model_kwargs["encoder_outputs"]: ModelOutput = encoder(**encoder_kwargs)
#     525 return model_kwargs
#
# File ~/venv2/lib/python3.10/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/venv2/lib/python3.10/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# TypeError: MultiUniFormerWithProjectionHead.forward() got an unexpected keyword argument 'output_attentions'

# %%
model
# Out:
# CXRRGModel(
#   (encoder): MultiUniFormerWithProjectionHead(
#     (uniformer): UniFormer(
#       (patch_embed1): PatchEmbed(
#         (proj): Conv2d(3, 64, kernel_size=(4, 4), stride=(4, 4))
#         (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#       )
#       (patch_embed2): PatchEmbed(
#         (proj): Conv2d(64, 128, kernel_size=(2, 2), stride=(2, 2))
#         (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       )
#       (patch_embed3): PatchEmbed(
#         (proj): Conv2d(128, 320, kernel_size=(2, 2), stride=(2, 2))
#         (norm): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#       )
#       (patch_embed4): PatchEmbed(
#         (proj): Conv2d(320, 512, kernel_size=(2, 2), stride=(2, 2))
#         (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (pos_drop): Dropout(p=0.0, inplace=False)
#       (blocks1): ModuleList(
#         (0): CBlock(
#           (pos_embed): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#           (norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           (conv2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           (attn): Conv2d(64, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=64)
#           (drop_path): Identity()
#           (norm2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): CMlp(
#             (fc1): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): GELU(approximate='none')
#             (fc2): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (1): CBlock(
#           (pos_embed): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#           (norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           (conv2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           (attn): Conv2d(64, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=64)
#           (drop_path): DropPath(drop_prob=0.008)
#           (norm2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): CMlp(
#             (fc1): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): GELU(approximate='none')
#             (fc2): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (2): CBlock(
#           (pos_embed): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#           (norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           (conv2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           (attn): Conv2d(64, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=64)
#           (drop_path): DropPath(drop_prob=0.015)
#           (norm2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): CMlp(
#             (fc1): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): GELU(approximate='none')
#             (fc2): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (3): CBlock(
#           (pos_embed): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#           (norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           (conv2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           (attn): Conv2d(64, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=64)
#           (drop_path): DropPath(drop_prob=0.023)
#           (norm2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): CMlp(
#             (fc1): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): GELU(approximate='none')
#             (fc2): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (4): CBlock(
#           (pos_embed): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#           (norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           (conv2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           (attn): Conv2d(64, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=64)
#           (drop_path): DropPath(drop_prob=0.031)
#           (norm2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): CMlp(
#             (fc1): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): GELU(approximate='none')
#             (fc2): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#       )
#       (blocks2): ModuleList(
#         (0): CBlock(
#           (pos_embed): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128)
#           (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#           (conv2): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#           (attn): Conv2d(128, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=128)
#           (drop_path): DropPath(drop_prob=0.038)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): CMlp(
#             (fc1): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#             (act): GELU(approximate='none')
#             (fc2): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (1): CBlock(
#           (pos_embed): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128)
#           (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#           (conv2): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#           (attn): Conv2d(128, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=128)
#           (drop_path): DropPath(drop_prob=0.046)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): CMlp(
#             (fc1): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#             (act): GELU(approximate='none')
#             (fc2): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (2): CBlock(
#           (pos_embed): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128)
#           (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#           (conv2): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#           (attn): Conv2d(128, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=128)
#           (drop_path): DropPath(drop_prob=0.054)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): CMlp(
#             (fc1): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#             (act): GELU(approximate='none')
#             (fc2): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (3): CBlock(
#           (pos_embed): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128)
#           (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#           (conv2): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#           (attn): Conv2d(128, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=128)
#           (drop_path): DropPath(drop_prob=0.062)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): CMlp(
#             (fc1): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#             (act): GELU(approximate='none')
#             (fc2): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (4): CBlock(
#           (pos_embed): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128)
#           (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#           (conv2): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#           (attn): Conv2d(128, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=128)
#           (drop_path): DropPath(drop_prob=0.069)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): CMlp(
#             (fc1): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#             (act): GELU(approximate='none')
#             (fc2): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (5): CBlock(
#           (pos_embed): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128)
#           (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#           (conv2): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#           (attn): Conv2d(128, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=128)
#           (drop_path): DropPath(drop_prob=0.077)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): CMlp(
#             (fc1): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#             (act): GELU(approximate='none')
#             (fc2): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (6): CBlock(
#           (pos_embed): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128)
#           (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#           (conv2): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#           (attn): Conv2d(128, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=128)
#           (drop_path): DropPath(drop_prob=0.085)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): CMlp(
#             (fc1): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#             (act): GELU(approximate='none')
#             (fc2): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (7): CBlock(
#           (pos_embed): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128)
#           (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#           (conv2): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#           (attn): Conv2d(128, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=128)
#           (drop_path): DropPath(drop_prob=0.092)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): CMlp(
#             (fc1): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#             (act): GELU(approximate='none')
#             (fc2): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#       )
#       (blocks3): ModuleList(
#         (0): SABlock(
#           (pos_embed): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=320)
#           (norm1): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention(
#             (qkv): Linear(in_features=320, out_features=960, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=320, out_features=320, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(drop_prob=0.100)
#           (norm2): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=320, out_features=1280, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=1280, out_features=320, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (1): SABlock(
#           (pos_embed): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=320)
#           (norm1): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention(
#             (qkv): Linear(in_features=320, out_features=960, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=320, out_features=320, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(drop_prob=0.108)
#           (norm2): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=320, out_features=1280, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=1280, out_features=320, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (2): SABlock(
#           (pos_embed): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=320)
#           (norm1): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention(
#             (qkv): Linear(in_features=320, out_features=960, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=320, out_features=320, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(drop_prob=0.115)
#           (norm2): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=320, out_features=1280, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=1280, out_features=320, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (3): SABlock(
#           (pos_embed): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=320)
#           (norm1): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention(
#             (qkv): Linear(in_features=320, out_features=960, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=320, out_features=320, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(drop_prob=0.123)
#           (norm2): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=320, out_features=1280, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=1280, out_features=320, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (4): SABlock(
#           (pos_embed): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=320)
#           (norm1): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention(
#             (qkv): Linear(in_features=320, out_features=960, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=320, out_features=320, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(drop_prob=0.131)
#           (norm2): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=320, out_features=1280, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=1280, out_features=320, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (5): SABlock(
#           (pos_embed): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=320)
#           (norm1): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention(
#             (qkv): Linear(in_features=320, out_features=960, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=320, out_features=320, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(drop_prob=0.138)
#           (norm2): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=320, out_features=1280, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=1280, out_features=320, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (6): SABlock(
#           (pos_embed): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=320)
#           (norm1): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention(
#             (qkv): Linear(in_features=320, out_features=960, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=320, out_features=320, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(drop_prob=0.146)
#           (norm2): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=320, out_features=1280, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=1280, out_features=320, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (7): SABlock(
#           (pos_embed): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=320)
#           (norm1): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention(
#             (qkv): Linear(in_features=320, out_features=960, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=320, out_features=320, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(drop_prob=0.154)
#           (norm2): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=320, out_features=1280, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=1280, out_features=320, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (8): SABlock(
#           (pos_embed): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=320)
#           (norm1): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention(
#             (qkv): Linear(in_features=320, out_features=960, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=320, out_features=320, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(drop_prob=0.162)
#           (norm2): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=320, out_features=1280, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=1280, out_features=320, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (9): SABlock(
#           (pos_embed): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=320)
#           (norm1): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention(
#             (qkv): Linear(in_features=320, out_features=960, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=320, out_features=320, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(drop_prob=0.169)
#           (norm2): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=320, out_features=1280, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=1280, out_features=320, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (10): SABlock(
#           (pos_embed): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=320)
#           (norm1): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention(
#             (qkv): Linear(in_features=320, out_features=960, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=320, out_features=320, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(drop_prob=0.177)
#           (norm2): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=320, out_features=1280, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=1280, out_features=320, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (11): SABlock(
#           (pos_embed): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=320)
#           (norm1): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention(
#             (qkv): Linear(in_features=320, out_features=960, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=320, out_features=320, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(drop_prob=0.185)
#           (norm2): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=320, out_features=1280, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=1280, out_features=320, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (12): SABlock(
#           (pos_embed): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=320)
#           (norm1): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention(
#             (qkv): Linear(in_features=320, out_features=960, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=320, out_features=320, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(drop_prob=0.192)
#           (norm2): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=320, out_features=1280, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=1280, out_features=320, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (13): SABlock(
#           (pos_embed): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=320)
#           (norm1): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention(
#             (qkv): Linear(in_features=320, out_features=960, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=320, out_features=320, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(drop_prob=0.200)
#           (norm2): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=320, out_features=1280, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=1280, out_features=320, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (14): SABlock(
#           (pos_embed): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=320)
#           (norm1): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention(
#             (qkv): Linear(in_features=320, out_features=960, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=320, out_features=320, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(drop_prob=0.208)
#           (norm2): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=320, out_features=1280, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=1280, out_features=320, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (15): SABlock(
#           (pos_embed): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=320)
#           (norm1): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention(
#             (qkv): Linear(in_features=320, out_features=960, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=320, out_features=320, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(drop_prob=0.215)
#           (norm2): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=320, out_features=1280, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=1280, out_features=320, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (16): SABlock(
#           (pos_embed): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=320)
#           (norm1): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention(
#             (qkv): Linear(in_features=320, out_features=960, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=320, out_features=320, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(drop_prob=0.223)
#           (norm2): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=320, out_features=1280, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=1280, out_features=320, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (17): SABlock(
#           (pos_embed): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=320)
#           (norm1): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention(
#             (qkv): Linear(in_features=320, out_features=960, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=320, out_features=320, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(drop_prob=0.231)
#           (norm2): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=320, out_features=1280, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=1280, out_features=320, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (18): SABlock(
#           (pos_embed): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=320)
#           (norm1): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention(
#             (qkv): Linear(in_features=320, out_features=960, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=320, out_features=320, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(drop_prob=0.238)
#           (norm2): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=320, out_features=1280, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=1280, out_features=320, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (19): SABlock(
#           (pos_embed): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=320)
#           (norm1): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention(
#             (qkv): Linear(in_features=320, out_features=960, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=320, out_features=320, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(drop_prob=0.246)
#           (norm2): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=320, out_features=1280, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=1280, out_features=320, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#       )
#       (blocks4): ModuleList(
#         (0): SABlock(
#           (pos_embed): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#           (norm1): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention(
#             (qkv): Linear(in_features=512, out_features=1536, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=512, out_features=512, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(drop_prob=0.254)
#           (norm2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (1): SABlock(
#           (pos_embed): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#           (norm1): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention(
#             (qkv): Linear(in_features=512, out_features=1536, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=512, out_features=512, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(drop_prob=0.262)
#           (norm2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (2): SABlock(
#           (pos_embed): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#           (norm1): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention(
#             (qkv): Linear(in_features=512, out_features=1536, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=512, out_features=512, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(drop_prob=0.269)
#           (norm2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (3): SABlock(
#           (pos_embed): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#           (norm1): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention(
#             (qkv): Linear(in_features=512, out_features=1536, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=512, out_features=512, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(drop_prob=0.277)
#           (norm2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (4): SABlock(
#           (pos_embed): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#           (norm1): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention(
#             (qkv): Linear(in_features=512, out_features=1536, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=512, out_features=512, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(drop_prob=0.285)
#           (norm2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (5): SABlock(
#           (pos_embed): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#           (norm1): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention(
#             (qkv): Linear(in_features=512, out_features=1536, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=512, out_features=512, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(drop_prob=0.292)
#           (norm2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (6): SABlock(
#           (pos_embed): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#           (norm1): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention(
#             (qkv): Linear(in_features=512, out_features=1536, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=512, out_features=512, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath(drop_prob=0.300)
#           (norm2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (act): GELU(approximate='none')
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#       )
#       (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (pre_logits): Identity()
#     )
#     (projection_head): UniFormerProjectionHead(
#       (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       (projection): Linear(in_features=512, out_features=768, bias=False)
#     )
#   )
#   (decoder): LlamaForCausalLM(
#     (model): LlamaModel(
#       (embed_tokens): Embedding(30000, 768, padding_idx=4)
#       (layers): ModuleList(
#         (0-5): 6 x LlamaDecoderLayer(
#           (self_attn): LlamaSdpaAttention(
#             (q_proj): Linear(in_features=768, out_features=768, bias=False)
#             (k_proj): Linear(in_features=768, out_features=768, bias=False)
#             (v_proj): Linear(in_features=768, out_features=768, bias=False)
#             (o_proj): Linear(in_features=768, out_features=768, bias=False)
#             (rotary_emb): LlamaRotaryEmbedding()
#           )
#           (mlp): LlamaMLP(
#             (gate_proj): Linear(in_features=768, out_features=3072, bias=False)
#             (up_proj): Linear(in_features=768, out_features=3072, bias=False)
#             (down_proj): Linear(in_features=3072, out_features=768, bias=False)
#             (act_fn): SiLU()
#           )
#           (input_layernorm): LlamaRMSNorm()
#           (post_attention_layernorm): LlamaRMSNorm()
#         )
#       )
#       (norm): LlamaRMSNorm()
#     )
#     (lm_head): Linear(in_features=768, out_features=30000, bias=False)
#   )
#   (token_type_embeddings): Embedding(3, 768)
# )

# %%
model.encoder.uniformer.forward()
# Out:
# <bound method UniFormer.forward of UniFormer(
#   (patch_embed1): PatchEmbed(
#     (proj): Conv2d(3, 64, kernel_size=(4, 4), stride=(4, 4))
#     (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#   )
#   (patch_embed2): PatchEmbed(
#     (proj): Conv2d(64, 128, kernel_size=(2, 2), stride=(2, 2))
#     (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   )
#   (patch_embed3): PatchEmbed(
#     (proj): Conv2d(128, 320, kernel_size=(2, 2), stride=(2, 2))
#     (norm): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#   )
#   (patch_embed4): PatchEmbed(
#     (proj): Conv2d(320, 512, kernel_size=(2, 2), stride=(2, 2))
#     (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#   )
#   (pos_drop): Dropout(p=0.0, inplace=False)
#   (blocks1): ModuleList(
#     (0): CBlock(
#       (pos_embed): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#       (norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#       (conv2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#       (attn): Conv2d(64, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=64)
#       (drop_path): Identity()
#       (norm2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (mlp): CMlp(
#         (fc1): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#         (act): GELU(approximate='none')
#         (fc2): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#         (drop): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (1): CBlock(
#       (pos_embed): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#       (norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#       (conv2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#       (attn): Conv2d(64, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=64)
#       (drop_path): DropPath(drop_prob=0.008)
#       (norm2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (mlp): CMlp(
#         (fc1): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#         (act): GELU(approximate='none')
#         (fc2): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#         (drop): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (2): CBlock(
#       (pos_embed): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#       (norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#       (conv2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#       (attn): Conv2d(64, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=64)
#       (drop_path): DropPath(drop_prob=0.015)
#       (norm2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (mlp): CMlp(
#         (fc1): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#         (act): GELU(approximate='none')
#         (fc2): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#         (drop): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (3): CBlock(
#       (pos_embed): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#       (norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#       (conv2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#       (attn): Conv2d(64, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=64)
#       (drop_path): DropPath(drop_prob=0.023)
#       (norm2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (mlp): CMlp(
#         (fc1): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#         (act): GELU(approximate='none')
#         (fc2): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#         (drop): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (4): CBlock(
#       (pos_embed): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#       (norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#       (conv2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#       (attn): Conv2d(64, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=64)
#       (drop_path): DropPath(drop_prob=0.031)
#       (norm2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (mlp): CMlp(
#         (fc1): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#         (act): GELU(approximate='none')
#         (fc2): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#         (drop): Dropout(p=0.0, inplace=False)
#       )
#     )
#   )
#   (blocks2): ModuleList(
#     (0): CBlock(
#       (pos_embed): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128)
#       (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#       (conv2): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#       (attn): Conv2d(128, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=128)
#       (drop_path): DropPath(drop_prob=0.038)
#       (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (mlp): CMlp(
#         (fc1): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#         (act): GELU(approximate='none')
#         (fc2): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#         (drop): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (1): CBlock(
#       (pos_embed): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128)
#       (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#       (conv2): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#       (attn): Conv2d(128, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=128)
#       (drop_path): DropPath(drop_prob=0.046)
#       (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (mlp): CMlp(
#         (fc1): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#         (act): GELU(approximate='none')
#         (fc2): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#         (drop): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (2): CBlock(
#       (pos_embed): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128)
#       (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#       (conv2): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#       (attn): Conv2d(128, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=128)
#       (drop_path): DropPath(drop_prob=0.054)
#       (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (mlp): CMlp(
#         (fc1): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#         (act): GELU(approximate='none')
#         (fc2): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#         (drop): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (3): CBlock(
#       (pos_embed): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128)
#       (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#       (conv2): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#       (attn): Conv2d(128, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=128)
#       (drop_path): DropPath(drop_prob=0.062)
#       (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (mlp): CMlp(
#         (fc1): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#         (act): GELU(approximate='none')
#         (fc2): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#         (drop): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (4): CBlock(
#       (pos_embed): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128)
#       (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#       (conv2): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#       (attn): Conv2d(128, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=128)
#       (drop_path): DropPath(drop_prob=0.069)
#       (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (mlp): CMlp(
#         (fc1): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#         (act): GELU(approximate='none')
#         (fc2): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#         (drop): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (5): CBlock(
#       (pos_embed): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128)
#       (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#       (conv2): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#       (attn): Conv2d(128, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=128)
#       (drop_path): DropPath(drop_prob=0.077)
#       (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (mlp): CMlp(
#         (fc1): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#         (act): GELU(approximate='none')
#         (fc2): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#         (drop): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (6): CBlock(
#       (pos_embed): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128)
#       (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#       (conv2): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#       (attn): Conv2d(128, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=128)
#       (drop_path): DropPath(drop_prob=0.085)
#       (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (mlp): CMlp(
#         (fc1): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#         (act): GELU(approximate='none')
#         (fc2): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#         (drop): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (7): CBlock(
#       (pos_embed): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128)
#       (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#       (conv2): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#       (attn): Conv2d(128, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=128)
#       (drop_path): DropPath(drop_prob=0.092)
#       (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (mlp): CMlp(
#         (fc1): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#         (act): GELU(approximate='none')
#         (fc2): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#         (drop): Dropout(p=0.0, inplace=False)
#       )
#     )
#   )
#   (blocks3): ModuleList(
#     (0): SABlock(
#       (pos_embed): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=320)
#       (norm1): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=320, out_features=960, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=320, out_features=320, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path): DropPath(drop_prob=0.100)
#       (norm2): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=320, out_features=1280, bias=True)
#         (act): GELU(approximate='none')
#         (fc2): Linear(in_features=1280, out_features=320, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (1): SABlock(
#       (pos_embed): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=320)
#       (norm1): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=320, out_features=960, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=320, out_features=320, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path): DropPath(drop_prob=0.108)
#       (norm2): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=320, out_features=1280, bias=True)
#         (act): GELU(approximate='none')
#         (fc2): Linear(in_features=1280, out_features=320, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (2): SABlock(
#       (pos_embed): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=320)
#       (norm1): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=320, out_features=960, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=320, out_features=320, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path): DropPath(drop_prob=0.115)
#       (norm2): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=320, out_features=1280, bias=True)
#         (act): GELU(approximate='none')
#         (fc2): Linear(in_features=1280, out_features=320, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (3): SABlock(
#       (pos_embed): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=320)
#       (norm1): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=320, out_features=960, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=320, out_features=320, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path): DropPath(drop_prob=0.123)
#       (norm2): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=320, out_features=1280, bias=True)
#         (act): GELU(approximate='none')
#         (fc2): Linear(in_features=1280, out_features=320, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (4): SABlock(
#       (pos_embed): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=320)
#       (norm1): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=320, out_features=960, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=320, out_features=320, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path): DropPath(drop_prob=0.131)
#       (norm2): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=320, out_features=1280, bias=True)
#         (act): GELU(approximate='none')
#         (fc2): Linear(in_features=1280, out_features=320, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (5): SABlock(
#       (pos_embed): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=320)
#       (norm1): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=320, out_features=960, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=320, out_features=320, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path): DropPath(drop_prob=0.138)
#       (norm2): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=320, out_features=1280, bias=True)
#         (act): GELU(approximate='none')
#         (fc2): Linear(in_features=1280, out_features=320, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (6): SABlock(
#       (pos_embed): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=320)
#       (norm1): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=320, out_features=960, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=320, out_features=320, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path): DropPath(drop_prob=0.146)
#       (norm2): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=320, out_features=1280, bias=True)
#         (act): GELU(approximate='none')
#         (fc2): Linear(in_features=1280, out_features=320, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (7): SABlock(
#       (pos_embed): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=320)
#       (norm1): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=320, out_features=960, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=320, out_features=320, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path): DropPath(drop_prob=0.154)
#       (norm2): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=320, out_features=1280, bias=True)
#         (act): GELU(approximate='none')
#         (fc2): Linear(in_features=1280, out_features=320, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (8): SABlock(
#       (pos_embed): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=320)
#       (norm1): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=320, out_features=960, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=320, out_features=320, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path): DropPath(drop_prob=0.162)
#       (norm2): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=320, out_features=1280, bias=True)
#         (act): GELU(approximate='none')
#         (fc2): Linear(in_features=1280, out_features=320, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (9): SABlock(
#       (pos_embed): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=320)
#       (norm1): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=320, out_features=960, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=320, out_features=320, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path): DropPath(drop_prob=0.169)
#       (norm2): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=320, out_features=1280, bias=True)
#         (act): GELU(approximate='none')
#         (fc2): Linear(in_features=1280, out_features=320, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (10): SABlock(
#       (pos_embed): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=320)
#       (norm1): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=320, out_features=960, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=320, out_features=320, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path): DropPath(drop_prob=0.177)
#       (norm2): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=320, out_features=1280, bias=True)
#         (act): GELU(approximate='none')
#         (fc2): Linear(in_features=1280, out_features=320, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (11): SABlock(
#       (pos_embed): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=320)
#       (norm1): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=320, out_features=960, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=320, out_features=320, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path): DropPath(drop_prob=0.185)
#       (norm2): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=320, out_features=1280, bias=True)
#         (act): GELU(approximate='none')
#         (fc2): Linear(in_features=1280, out_features=320, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (12): SABlock(
#       (pos_embed): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=320)
#       (norm1): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=320, out_features=960, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=320, out_features=320, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path): DropPath(drop_prob=0.192)
#       (norm2): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=320, out_features=1280, bias=True)
#         (act): GELU(approximate='none')
#         (fc2): Linear(in_features=1280, out_features=320, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (13): SABlock(
#       (pos_embed): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=320)
#       (norm1): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=320, out_features=960, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=320, out_features=320, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path): DropPath(drop_prob=0.200)
#       (norm2): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=320, out_features=1280, bias=True)
#         (act): GELU(approximate='none')
#         (fc2): Linear(in_features=1280, out_features=320, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (14): SABlock(
#       (pos_embed): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=320)
#       (norm1): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=320, out_features=960, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=320, out_features=320, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path): DropPath(drop_prob=0.208)
#       (norm2): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=320, out_features=1280, bias=True)
#         (act): GELU(approximate='none')
#         (fc2): Linear(in_features=1280, out_features=320, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (15): SABlock(
#       (pos_embed): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=320)
#       (norm1): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=320, out_features=960, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=320, out_features=320, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path): DropPath(drop_prob=0.215)
#       (norm2): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=320, out_features=1280, bias=True)
#         (act): GELU(approximate='none')
#         (fc2): Linear(in_features=1280, out_features=320, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (16): SABlock(
#       (pos_embed): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=320)
#       (norm1): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=320, out_features=960, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=320, out_features=320, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path): DropPath(drop_prob=0.223)
#       (norm2): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=320, out_features=1280, bias=True)
#         (act): GELU(approximate='none')
#         (fc2): Linear(in_features=1280, out_features=320, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (17): SABlock(
#       (pos_embed): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=320)
#       (norm1): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=320, out_features=960, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=320, out_features=320, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path): DropPath(drop_prob=0.231)
#       (norm2): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=320, out_features=1280, bias=True)
#         (act): GELU(approximate='none')
#         (fc2): Linear(in_features=1280, out_features=320, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (18): SABlock(
#       (pos_embed): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=320)
#       (norm1): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=320, out_features=960, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=320, out_features=320, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path): DropPath(drop_prob=0.238)
#       (norm2): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=320, out_features=1280, bias=True)
#         (act): GELU(approximate='none')
#         (fc2): Linear(in_features=1280, out_features=320, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (19): SABlock(
#       (pos_embed): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=320)
#       (norm1): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=320, out_features=960, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=320, out_features=320, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path): DropPath(drop_prob=0.246)
#       (norm2): LayerNorm((320,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=320, out_features=1280, bias=True)
#         (act): GELU(approximate='none')
#         (fc2): Linear(in_features=1280, out_features=320, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#       )
#     )
#   )
#   (blocks4): ModuleList(
#     (0): SABlock(
#       (pos_embed): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#       (norm1): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=512, out_features=1536, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=512, out_features=512, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path): DropPath(drop_prob=0.254)
#       (norm2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (act): GELU(approximate='none')
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (1): SABlock(
#       (pos_embed): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#       (norm1): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=512, out_features=1536, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=512, out_features=512, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path): DropPath(drop_prob=0.262)
#       (norm2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (act): GELU(approximate='none')
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (2): SABlock(
#       (pos_embed): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#       (norm1): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=512, out_features=1536, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=512, out_features=512, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path): DropPath(drop_prob=0.269)
#       (norm2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (act): GELU(approximate='none')
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (3): SABlock(
#       (pos_embed): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#       (norm1): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=512, out_features=1536, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=512, out_features=512, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path): DropPath(drop_prob=0.277)
#       (norm2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (act): GELU(approximate='none')
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (4): SABlock(
#       (pos_embed): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#       (norm1): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=512, out_features=1536, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=512, out_features=512, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path): DropPath(drop_prob=0.285)
#       (norm2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (act): GELU(approximate='none')
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (5): SABlock(
#       (pos_embed): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#       (norm1): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=512, out_features=1536, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=512, out_features=512, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path): DropPath(drop_prob=0.292)
#       (norm2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (act): GELU(approximate='none')
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (6): SABlock(
#       (pos_embed): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#       (norm1): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=512, out_features=1536, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=512, out_features=512, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path): DropPath(drop_prob=0.300)
#       (norm2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (act): GELU(approximate='none')
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#       )
#     )
#   )
#   (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (pre_logits): Identity()
# )>

# %%
fake_image_batch = torch.randn(1, 3, 384, 384)  # (batch, channels, time, height, width)

# %%
output = model.encoder.uniformer(fake_image_batch)

# %%
output.shape
# Out:
# torch.Size([1, 512, 12, 12])
