# %%
# %env CUDA_VISIBLE_DEVICES=0
# Out:
# env: CUDA_VISIBLE_DEVICES=0

# %%
# %run ../../models/model_debugging_utils.py

# %%
pairs = [
    (
        'Lungs are well-expanded and clear without focal consolidation concerning for pneumonia.',
        'Lungs are hyperinflated but clear.',
    ), (
        'Elevation of the right hemidiaphragm is unchanged.',
        'Elevation of the right hemidiaphragm is unchanged.',
    ), (
        'No pneumothorax.',
        'There is no pleural effusion, focal consolidation or pneumothorax.',
    ), (
        'There is no pleural effusion, focal consolidation or pneumothorax.',
        'No pneumothorax.',
    ), (
        'masslike lesion in the right chest',
        'dual-lumen right IJ catheter overlying the distal SVC',
    ), (
        'interval progression of the right lower lobe airspace consolidation',
        'IABP tip is 5.1 cm below aortic arch',
    ), (
        'supine position of the patient makes evaluation of pleural effusion impossible',
        'dextroscoliosis of the spine',
    )
]
run_nli_model(
    premises=[x[0] for x in pairs],
    hypotheses=[x[1] for x in pairs],
    model_folder_path='/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20231003_105607_NLI(MedNLI+RadNLI+GPT-4)_BerBasedNLI(microsoft-BiomedVLP-CXR-BERT-specialized,128,128)',
    use_amp=False,
    device='GPU',
)
# Out:
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20231003_105607_NLI(MedNLI+RadNLI+GPT-4)_BerBasedNLI(microsoft-BiomedVLP-CXR-BERT-specialized,128,128)/metadata.json
# device =  GPU
# Create model
# BertBasedNLI
#   huggingface_model_name: microsoft/BiomedVLP-CXR-BERT-specialized
#   merged_input: False
#   hidden_size: 128
#   freeze_huggingface_model: False
# WARNING: unused_kwargs: {'pretrained_checkpoint_folder_path': '/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20231003_104023_NLI(MedNLI+RadNLI+GPT-4)_BerBasedNLI(microsoft-BiomedVLP-CXR-BERT-specialized,128,128)/'}
# Explicitly passing a `revision` is encouraged when loading a configuration with custom code to ensure no malicious code has been contributed in a newer revision.
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# Load model weights
# ...

# %%
pairs = [
    (
        'Lungs are well-expanded and clear without focal consolidation concerning for pneumonia.',
        'Lungs are hyperinflated but clear.',
    ), (
        'Elevation of the right hemidiaphragm is unchanged.',
        'Elevation of the right hemidiaphragm is unchanged.',
    ), (
        'No pneumothorax.',
        'There is no pleural effusion, focal consolidation or pneumothorax.',
    ), (
        'There is no pleural effusion, focal consolidation or pneumothorax.',
        'No pneumothorax.',
    ), (
        'masslike lesion in the right chest',
        'dual-lumen right IJ catheter overlying the distal SVC',
    ), (
        'interval progression of the right lower lobe airspace consolidation',
        'IABP tip is 5.1 cm below aortic arch',
    ), (
        'supine position of the patient makes evaluation of pleural effusion impossible',
        'dextroscoliosis of the spine',
    )
]
run_nli_model(
    premises=[x[0] for x in pairs],
    hypotheses=[x[1] for x in pairs],
    model_folder_path='/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20231003_105607_NLI(MedNLI+RadNLI+GPT-4)_BerBasedNLI(microsoft-BiomedVLP-CXR-BERT-specialized,128,128)',
    use_amp=False,
    device='GPU',
    use_precomputed_embeddings=True,
)
# Out:
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20231003_105607_NLI(MedNLI+RadNLI+GPT-4)_BerBasedNLI(microsoft-BiomedVLP-CXR-BERT-specialized,128,128)/metadata.json
# device =  GPU
# Create model
# BertBasedNLI
#   huggingface_model_name: microsoft/BiomedVLP-CXR-BERT-specialized
#   merged_input: False
#   hidden_size: 128
#   freeze_huggingface_model: False
# WARNING: unused_kwargs: {'pretrained_checkpoint_folder_path': '/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20231003_104023_NLI(MedNLI+RadNLI+GPT-4)_BerBasedNLI(microsoft-BiomedVLP-CXR-BERT-specialized,128,128)/'}
# Explicitly passing a `revision` is encouraged when loading a configuration with custom code to ensure no malicious code has been contributed in a newer revision.
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# Load model weights
# ...

# %%
pairs = [
    (
        'Lungs are well-expanded and clear without focal consolidation concerning for pneumonia.',
        'Lungs are hyperinflated but clear.',
    ), (
        'Elevation of the right hemidiaphragm is unchanged.',
        'Elevation of the right hemidiaphragm is unchanged.',
    ), (
        'No pneumothorax.',
        'There is no pleural effusion, focal consolidation or pneumothorax.',
    ), (
        'There is no pleural effusion, focal consolidation or pneumothorax.',
        'No pneumothorax.',
    ), (
        'masslike lesion in the right chest',
        'dual-lumen right IJ catheter overlying the distal SVC',
    ), (
        'interval progression of the right lower lobe airspace consolidation',
        'IABP tip is 5.1 cm below aortic arch',
    ), (
        'supine position of the patient makes evaluation of pleural effusion impossible',
        'dextroscoliosis of the spine',
    ), (
        'The car is outside the house',
        'The car is inside the house',
    ),
    
    ##########
    (
        'normal heart size',
        'normal shape heart',
    ), (
        'normal heart size',
        'normal cardiomediastinal contour',
        
    ),(
        'normal heart size',
        'no signs of cardiac decompensation',
        
    ),(
        'normal heart size',
        'normal-appearing mediastinum',
        
    ),(
        'normal heart size',
        'no disorganization',
        
    ),(
        'normal heart size',
        'top-normal size of the heart',
        
    ),(
        'normal heart size',
        'no focal lungs',
        
    ),(
        'normal heart size',
        'free lungs',
        
    ),(
        'normal heart size',
        'no new pulmonary opacifications',
        
    ),(
        'normal heart size',
        'no foreign body',
    ),
    #########
    (
        'right PICC tip remains in standard position',
        'diffuse parenchymal changes',
    ),(
        'right PICC tip remains in standard position',
        'diffuse bilateral lung opacities',
    ),(
        'right PICC tip remains in standard position',
        'focal nodular opacity',
    ),(
        'right PICC tip remains in standard position',
        'focal left basilar atelectasis',
    ),(
        'right PICC tip remains in standard position',
        'bilateral patchy opacities',
    ),(
        'right PICC tip remains in standard position',
        'streaky atelectasis in the lower left lung',
    ),(
        'right PICC tip remains in standard position',
        'opacity better assessed in prior CT',
    ),(
        'right PICC tip remains in standard position',
        'known nodular metastases',
    ),(
        'right PICC tip remains in standard position',
        'rounded opacity anterior to the heart',
    ),(
        'right PICC tip remains in standard position',
        'mildly distended pulmonary vessels',
    ),
]
run_fact_encoder_nli(
    premises=[x[0] for x in pairs],
    hypotheses=[x[1] for x in pairs],
#     model_folder_path='/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20231225_051135_MIMIC-CXR(classif+nli+autoencoder)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)',
#     model_folder_path='/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20231225_120218_MIMIC-CXR(classif+nli+autoencoder)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)',
    model_folder_path='/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20231226_084848_MIMIC-CXR(classif+nli+autoencoder)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)',
    use_amp=False,
    device='GPU',
)
# Out:
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20231226_084848_MIMIC-CXR(classif+nli+autoencoder)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/metadata.json
# device =  GPU
# Create model
# Fact encoder
#   huggingface_model_name: microsoft/BiomedVLP-CXR-BERT-specialized
#   embedding_size: 128
#   classify_category: True
#   n_categories: 6
#   classify_health_status: True
#   n_health_statuses: 5
#   classify_comparison_status: True
#   n_comparison_statuses: 15
#   classify_chest_imagenome_obs: True
#   n_chest_imagenome_observations: 74
#   classify_chest_imagenome_anatloc: True
#   n_chest_imagenome_anatomical_locations: 38
#   use_aux_task_hidden_layer: True
#   aux_task_hidden_layer_size: 512
#   do_nli: True
#   nli_hidden_layer_size: 128
#   use_spert: False
#   spert_size_embedding: None
#   spert_relation_types: None
#   spert_entity_types: None
#   spert_max_pairs: None
#   spert_prop_drop: None
# ...

# %%
run_nli_model(
    premises=[x[0] for x in pairs],
    hypotheses=[x[1] for x in pairs],
    model_folder_path='/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20231226_084848_MIMIC-CXR(classif+nli+autoencoder)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)',
    use_amp=False,
    device='GPU',
    use_precomputed_embeddings=False,
)
# Out:
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20231226_084848_MIMIC-CXR(classif+nli+autoencoder)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/metadata.json
# device =  GPU
# Create model
# BertBasedNLI
#   huggingface_model_name: microsoft/BiomedVLP-CXR-BERT-specialized
#   merged_input: False
#   hidden_size: 128
#   freeze_huggingface_model: False
# ...

# %%
run_nli_model(
    premises=[x[0] for x in pairs],
    hypotheses=[x[1] for x in pairs],
    model_folder_path='/mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20231226_084848_MIMIC-CXR(classif+nli+autoencoder)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)',
    use_amp=False,
    device='GPU',
    use_precomputed_embeddings=True,
)
# Out:
# metadata loaded from /mnt/data/pamessina/workspaces/medvqa-workspace/models/fact_embedding/20231226_084848_MIMIC-CXR(classif+nli+autoencoder)_FactEncoder(microsoft-BiomedVLP-CXR-BERT-specialized)/metadata.json
# device =  GPU
# Create model
# BertBasedNLI
#   huggingface_model_name: microsoft/BiomedVLP-CXR-BERT-specialized
#   merged_input: False
#   hidden_size: 128
#   freeze_huggingface_model: False
# ...
