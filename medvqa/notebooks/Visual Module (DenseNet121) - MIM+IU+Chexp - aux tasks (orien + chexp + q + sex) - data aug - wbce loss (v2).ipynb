# %%
# %env CUDA_VISIBLE_DEVICES=1
# Out:
# env: CUDA_VISIBLE_DEVICES=1

# %%
# !python ../train_visual_module.py \
        --pretrained-checkpoint-folder "/home/pamessina/medvqa-workspace/models/visual_module/20220613_180648_mimiccxr+iuxray+chexpert_densenet121_model-args=(densenet-121,1024)_cnn-pretr=0_dataset_weights=1.0,0.08,0.8_img-aug=random-spatial_tags=0_orien=1_chx=1_ql=1" \
        --iuxray-preprocessed-data-filename "iuxray_preprocessed_train_data__(hash=247,1338506350569278595).pkl" \
        --mimiccxr-preprocessed-data-filename "mimiccxr_preprocessed_train_data__(hash=292,4086290602689741595).pkl" \
        --epochs 50 \
        --batches-per-epoch 300 \
        --batch-size 80 \
        --num-workers 7 \
        --lr 0.0001 \
        --lr-decay-patience 3 \
        --classify-orientation \
        --classify-chexpert \
        --iuxray-chexpert-labels-filename "chexpert_labels_per_report__20220607_231729.pkl" \
        --mimiccxr-chexpert-labels-filename "chexpert_labels_per_report__20220607_231820.pkl" \
        --classify-questions \
        --n-questions 97 \
        --iuxray-question-labels-filename "question_labels_per_report__20220607_225035.pkl" \
        --mimiccxr-question-labels-filename "question_labels_per_report__20220607_225036.pkl" \
        --imagenet-pretrained \
        --img-aug-mode "random-spatial" \
        --binary-loss-name 'wbce-c' \
        --use-amp \
        --save
# Out:
# script's arguments:
#    epochs: 50
#    batches_per_epoch: 300
#    checkpoint_folder: None
#    iuxray_preprocessed_data_filename: iuxray_preprocessed_train_data__(hash=247,1338506350569278595).pkl
#    mimiccxr_preprocessed_data_filename: mimiccxr_preprocessed_train_data__(hash=292,4086290602689741595).pkl
#    image_local_feat_size: 1024
#    imagenet_pretrained: True
#    densenet_pretrained_weights_path: None
#    lr: 0.0001
#    lr_decay: 0.76
#    lr_decay_patience: 3
#    batch_size: 80
#    num_workers: 7
#    device: GPU
#    img_aug_mode: random-spatial
#    mimiccxr_weight: 1.0
#    chexpert_weight: 0.8
#    iuxray_weight: 0.08
#    use_amp: True
#    pretrained_checkpoint_folder_path: /home/pamessina/medvqa-workspace/models/visual_module/20220613_180648_mimiccxr+iuxray+chexpert_densenet121_model-args=(densenet-121,1024)_cnn-pretr=0_dataset_weights=1.0,0.08,0.8_img-aug=random-spatial_tags=0_orien=1_chx=1_ql=1
#    one_question_per_batch: False
#    save: True
#    override_lr: False
#    train_mimiccxr: True
#    train_iuxray: True
#    train_chexpert: True
#    binary_loss_name: wbce-c
#    classify_tags: False
#    n_medical_tags: None
#    iuxray_rid2tags_filename: None
#    mimiccxr_rid2tags_filename: None
#    classify_orientation: True
#    classify_chexpert: True
#    iuxray_chexpert_labels_filename: chexpert_labels_per_report__20220607_231729.pkl
#    mimiccxr_chexpert_labels_filename: chexpert_labels_per_report__20220607_231820.pkl
#    classify_questions: True
#    n_questions: 97
#    iuxray_question_labels_filename: question_labels_per_report__20220607_225035.pkl
#    mimiccxr_question_labels_filename: question_labels_per_report__20220607_225036.pkl
# ----- Training model from scratch ------
# 1) device = cuda
# 2) Creating instance of DensenetVisualModule model ...
# DenseNet121's pretrained weights loaded from ImageNet
# 3) Defining Adam optimizer ...
# 4) Defining ReduceLROnPlateau scheduler ...
# 5) Creating trainer and validator engines ...
# 6) Defining image transform ...
# len(final_transforms) = 4
# default_prob = 0.3
# Returning augmented transforms with mode random-spatial
# 7) Creating MIMIC-CXR visual module trainer ...
# Loading data from path /home/pamessina/medvqa-workspace/cache/mimiccxr/mimiccxr_preprocessed_train_data__(hash=292,4086290602689741595).pkl ...
# 	Done!
# batch_size = 80
# len(self.train_indices) = 97
#  *** merging from i=0 to j=3, acc_size = 122
#  *** merging from i=4 to j=5, acc_size = 173
# 	len(question_datasets) = 93
# len(self.val_indices) = 519
# generating training and validation dataloaders ...
# num_workers = 7
# 8) Creating IU X-Ray visual module trainer ...
# Loading data from path /home/pamessina/medvqa-workspace/cache/iuxray/iuxray_preprocessed_train_data__(hash=247,1338506350569278595).pkl ...
# 	Done!
# batch_size = 80
# len(self.train_indices) = 91
#  *** merging from i=0 to j=23, acc_size = 87
#  *** merging from i=24 to j=31, acc_size = 89
#  *** merging from i=32 to j=36, acc_size = 87
#  *** merging from i=37 to j=39, acc_size = 109
#  *** merging from i=40 to j=41, acc_size = 90
#  *** merging from i=42 to j=43, acc_size = 96
#  *** merging from i=44 to j=45, acc_size = 111
#  *** merging from i=46 to j=47, acc_size = 128
#  *** merging from i=48 to j=49, acc_size = 135
#  *** merging from i=50 to j=51, acc_size = 164
# 	len(question_datasets) = 49
# len(self.val_indices) = 152
# generating training and validation dataloaders ...
# num_workers = 7
# 9) Creating CheXpert visual module trainer ...
# Loading dataframe from /mnt/workspace/chexpert/CheXpert-v1.0-small/train-val.csv
# Loading images
# Loading orientations
# Loading genders
# Loading chexpert labels
# 10) Creating dataloaders ...
# 11) Attaching metrics, losses, timer and events to engines ...
# checkpoint_folder_path = /home/pamessina/medvqa-workspace/models/visual_module/20220614_103906_mimiccxr+iuxray+chexpert_densenet121_model-args=(densenet-121,1024,pretrained)_cnn-pretr=0_dataset_weights=1.0,0.08,0.8_img-aug=random-spatial_tags=0_orien=1_chx=1_ql=1_use_amp
# metadata saved to /home/pamessina/medvqa-workspace/models/visual_module/20220614_103906_mimiccxr+iuxray+chexpert_densenet121_model-args=(densenet-121,1024,pretrained)_cnn-pretr=0_dataset_weights=1.0,0.08,0.8_img-aug=random-spatial_tags=0_orien=1_chx=1_ql=1_use_amp/metadata.json
# checkpoint_names = ['checkpoint_128_oracc+chxlmicf1+chxlmacf1+chxlrocauc+qlf1+gacc=0.7063.pt', 'checkpoint_127_oracc+chxlmicf1+chxlmacf1+chxlrocauc+qlf1+gacc=0.7126.pt']
# 12) Loading pretrained weights from /home/pamessina/medvqa-workspace/models/visual_module/20220613_180648_mimiccxr+iuxray+chexpert_densenet121_model-args=(densenet-121,1024)_cnn-pretr=0_dataset_weights=1.0,0.08,0.8_img-aug=random-spatial_tags=0_orien=1_chx=1_ql=1/checkpoint_127_oracc+chxlmicf1+chxlmacf1+chxlrocauc+qlf1+gacc=0.7126.pt ...
# Checkpoint successfully loaded!
# MetricsLogger :: we'll be logging to /home/pamessina/medvqa-workspace/models/visual_module/20220614_103906_mimiccxr+iuxray+chexpert_densenet121_model-args=(densenet-121,1024,pretrained)_cnn-pretr=0_dataset_weights=1.0,0.08,0.8_img-aug=random-spatial_tags=0_orien=1_chx=1_ql=1_use_amp/metrics_logs.csv
# 13) Running trainer engine ...
# ---- Epoch 1/50
# (1) Training stage (lr = 0.000100) ...
# loss 0.24135, orien_loss 0.00047, oracc 0.99740, chx_loss 0.15509, chxlmicf1 0.53989, chxlmacf1 0.47788, chxlacc 0.72904, chxlrocauc 0.81945, ql_loss 0.07838, qlf1 0.37227, gloss 0.01444, gacc 0.99548, 95.58 secs
# (2) Validation stage ...
# oracc 0.99850, chxlmicf1 0.49991, chxlmacf1 0.45806, chxlacc 0.71822, chxlrocauc 0.77810, qlf1 0.32817, 4.13 secs
# ---- Epoch 2/50
# (1) Training stage (lr = 0.000100) ...
# loss 0.22722, orien_loss 0.00061, oracc 0.99782, chx_loss 0.14304, chxlmicf1 0.54065, chxlmacf1 0.47973, chxlacc 0.72789, chxlrocauc 0.81873, ql_loss 0.07833, qlf1 0.35817, gloss 0.01448, gacc 0.99433, 91.81 secs
# (2) Validation stage ...
# oracc 0.99850, chxlmicf1 0.49403, chxlmacf1 0.45312, chxlacc 0.72025, chxlrocauc 0.77295, qlf1 0.32733, 4.17 secs
# ---- Epoch 3/50
# (1) Training stage (lr = 0.000100) ...
# loss 0.16952, orien_loss 0.00666, oracc 0.99782, chx_loss 0.15079, chxlmicf1 0.53828, chxlmacf1 0.47575, chxlacc 0.72627, chxlrocauc 0.81808, ql_loss 0.07778, qlf1 0.35719, gloss 0.01311, gacc 0.99532, 90.66 secs
# (2) Validation stage ...
# oracc 0.99700, chxlmicf1 0.49657, chxlmacf1 0.45451, chxlacc 0.72653, chxlrocauc 0.77279, qlf1 0.33501, 4.18 secs
# ---- Epoch 4/50
# (1) Training stage (lr = 0.000100) ...
# loss 0.22681, orien_loss 0.00044, oracc 0.99769, chx_loss 0.14780, chxlmicf1 0.53950, chxlmacf1 0.47904, chxlacc 0.72707, chxlrocauc 0.81951, ql_loss 0.07810, qlf1 0.35781, gloss 0.01560, gacc 0.99481, 92.12 secs
# (2) Validation stage ...
# oracc 0.99850, chxlmicf1 0.48288, chxlmacf1 0.44786, chxlacc 0.71546, chxlrocauc 0.75756, qlf1 0.33369, 4.28 secs
# ---- Epoch 5/50
# (1) Training stage (lr = 0.000100) ...
# loss 0.23408, orien_loss 0.01630, oracc 0.99736, chx_loss 0.15117, chxlmicf1 0.53769, chxlmacf1 0.47650, chxlacc 0.72502, chxlrocauc 0.81828, ql_loss 0.07808, qlf1 0.35477, gloss 0.02154, gacc 0.99351, 92.25 secs
# (2) Validation stage ...
# oracc 0.99850, chxlmicf1 0.49436, chxlmacf1 0.45315, chxlacc 0.72780, chxlrocauc 0.77034, qlf1 0.33056, 4.00 secs
# Epoch     5: reducing learning rate of group 0 to 7.6000e-05.
# ---- Epoch 6/50
# (1) Training stage (lr = 0.000076) ...
# loss 0.23396, orien_loss 0.00043, oracc 0.99761, chx_loss 0.15450, chxlmicf1 0.53676, chxlmacf1 0.47668, chxlacc 0.72507, chxlrocauc 0.81767, ql_loss 0.07765, qlf1 0.35641, gloss 0.01503, gacc 0.99587, 90.77 secs
# (2) Validation stage ...
# oracc 0.99700, chxlmicf1 0.49156, chxlmacf1 0.45283, chxlacc 0.72121, chxlrocauc 0.76807, qlf1 0.32691, 4.34 secs
# ---- Epoch 7/50
# (1) Training stage (lr = 0.000076) ...
# loss 0.16993, orien_loss 0.01189, oracc 0.99736, chx_loss 0.15251, chxlmicf1 0.53846, chxlmacf1 0.47907, chxlacc 0.72629, chxlrocauc 0.81873, ql_loss 0.07807, qlf1 0.35822, gloss 0.01598, gacc 0.99523, 91.72 secs
# (2) Validation stage ...
# oracc 0.99700, chxlmicf1 0.48999, chxlmacf1 0.45049, chxlacc 0.71791, chxlrocauc 0.76999, qlf1 0.32558, 4.32 secs
# ---- Epoch 8/50
# (1) Training stage (lr = 0.000076) ...
# loss 0.22918, orien_loss 0.00120, oracc 0.99799, chx_loss 0.14910, chxlmicf1 0.53730, chxlmacf1 0.47663, chxlacc 0.72601, chxlrocauc 0.81924, ql_loss 0.07751, qlf1 0.35535, gloss 0.01549, gacc 0.99538, 92.66 secs
# (2) Validation stage ...
# oracc 0.99700, chxlmicf1 0.49234, chxlmacf1 0.45311, chxlacc 0.72142, chxlrocauc 0.77147, qlf1 0.33139, 4.27 secs
# ---- Epoch 9/50
# (1) Training stage (lr = 0.000076) ...
# loss 0.22189, orien_loss 0.05105, oracc 0.99778, chx_loss 0.16635, chxlmicf1 0.53962, chxlmacf1 0.47810, chxlacc 0.72761, chxlrocauc 0.81964, ql_loss 0.07797, qlf1 0.35594, gloss 0.01564, gacc 0.99427, 91.82 secs
# (2) Validation stage ...
# oracc 0.99700, chxlmicf1 0.48857, chxlmacf1 0.45040, chxlacc 0.72610, chxlrocauc 0.76438, qlf1 0.32759, 3.99 secs
# Epoch     9: reducing learning rate of group 0 to 5.7760e-05.
# ---- Epoch 10/50
# (1) Training stage (lr = 0.000058) ...
# loss 0.23401, orien_loss 0.00033, oracc 0.99778, chx_loss 0.15624, chxlmicf1 0.54038, chxlmacf1 0.48025, chxlacc 0.72806, chxlrocauc 0.81980, ql_loss 0.07776, qlf1 0.35652, gloss 0.01103, gacc 0.99654, 92.83 secs
# (2) Validation stage ...
# oracc 0.99850, chxlmicf1 0.49270, chxlmacf1 0.45161, chxlacc 0.73015, chxlrocauc 0.76806, qlf1 0.33256, 4.22 secs
# ---- Epoch 11/50
# (1) Training stage (lr = 0.000058) ...
# loss 0.20832, orien_loss 0.00290, oracc 0.99778, chx_loss 0.16279, chxlmicf1 0.54180, chxlmacf1 0.48178, chxlacc 0.72906, chxlrocauc 0.82093, ql_loss 0.07761, qlf1 0.35921, gloss 0.01503, gacc 0.99571, 92.46 secs
# (2) Validation stage ...
# oracc 0.99850, chxlmicf1 0.48584, chxlmacf1 0.44937, chxlacc 0.71588, chxlrocauc 0.76766, qlf1 0.32731, 4.39 secs
# ---- Epoch 12/50
# (1) Training stage (lr = 0.000058) ...
# loss 0.22608, orien_loss 0.00155, oracc 0.99786, chx_loss 0.14663, chxlmicf1 0.54210, chxlmacf1 0.48071, chxlacc 0.72936, chxlrocauc 0.82114, ql_loss 0.07742, qlf1 0.35900, gloss 0.01315, gacc 0.99625, 91.23 secs
# (2) Validation stage ...
# oracc 0.99850, chxlmicf1 0.48801, chxlmacf1 0.44936, chxlacc 0.71365, chxlrocauc 0.76699, qlf1 0.32924, 4.15 secs
# ---- Epoch 13/50
# (1) Training stage (lr = 0.000058) ...
# loss 0.16005, orien_loss 0.01124, oracc 0.99770, chx_loss 0.14094, chxlmicf1 0.54319, chxlmacf1 0.48269, chxlacc 0.72987, chxlrocauc 0.82169, ql_loss 0.07757, qlf1 0.35922, gloss 0.01507, gacc 0.99580, 92.12 secs
# (2) Validation stage ...
# oracc 0.99850, chxlmicf1 0.49990, chxlmacf1 0.45676, chxlacc 0.72546, chxlrocauc 0.77146, qlf1 0.32657, 4.33 secs
# Epoch    13: reducing learning rate of group 0 to 4.3898e-05.
# ---- Epoch 14/50
# (1) Training stage (lr = 0.000044) ...
# loss 0.23200, orien_loss 0.00269, oracc 0.99749, chx_loss 0.15012, chxlmicf1 0.54058, chxlmacf1 0.48086, chxlacc 0.72899, chxlrocauc 0.82020, ql_loss 0.07747, qlf1 0.35919, gloss 0.01120, gacc 0.99683, 92.26 secs
# (2) Validation stage ...
# oracc 0.99850, chxlmicf1 0.50030, chxlmacf1 0.45923, chxlacc 0.73121, chxlrocauc 0.77170, qlf1 0.33007, 4.31 secs
# ---- Epoch 15/50
# (1) Training stage (lr = 0.000044) ...
# loss 0.16596, orien_loss 0.00360, oracc 0.99828, chx_loss 0.16102, chxlmicf1 0.54160, chxlmacf1 0.48059, chxlacc 0.72985, chxlrocauc 0.82318, ql_loss 0.07709, qlf1 0.36138, gloss 0.01401, gacc 0.99485, 92.79 secs
# (2) Validation stage ...
# oracc 0.99850, chxlmicf1 0.48713, chxlmacf1 0.44941, chxlacc 0.71578, chxlrocauc 0.76617, qlf1 0.33378, 4.14 secs
# ---- Epoch 16/50
# (1) Training stage (lr = 0.000044) ...
# loss 0.23211, orien_loss 0.00019, oracc 0.99786, chx_loss 0.15397, chxlmicf1 0.54191, chxlmacf1 0.48134, chxlacc 0.72846, chxlrocauc 0.82024, ql_loss 0.07763, qlf1 0.35970, gloss 0.01060, gacc 0.99567, 92.83 secs
# (2) Validation stage ...
# oracc 0.99850, chxlmicf1 0.48979, chxlmacf1 0.45053, chxlacc 0.71546, chxlrocauc 0.76906, qlf1 0.32845, 4.06 secs
# ---- Epoch 17/50
# (1) Training stage (lr = 0.000044) ...
# loss 0.14326, orien_loss 0.00292, oracc 0.99803, chx_loss 0.13946, chxlmicf1 0.54384, chxlmacf1 0.48448, chxlacc 0.73028, chxlrocauc 0.82340, ql_loss 0.07752, qlf1 0.35972, gloss 0.01822, gacc 0.99523, 91.57 secs
# (2) Validation stage ...
# oracc 0.99850, chxlmicf1 0.48959, chxlmacf1 0.44999, chxlacc 0.72078, chxlrocauc 0.76763, qlf1 0.33262, 4.05 secs
# Epoch    17: reducing learning rate of group 0 to 3.3362e-05.
# ---- Epoch 18/50
# (1) Training stage (lr = 0.000033) ...
# loss 0.22373, orien_loss 0.00480, oracc 0.99815, chx_loss 0.14211, chxlmicf1 0.54241, chxlmacf1 0.48183, chxlacc 0.72914, chxlrocauc 0.82216, ql_loss 0.07702, qlf1 0.35779, gloss 0.01569, gacc 0.99529, 92.84 secs
# (2) Validation stage ...
# oracc 0.99850, chxlmicf1 0.49291, chxlmacf1 0.45392, chxlacc 0.72227, chxlrocauc 0.76993, qlf1 0.32840, 4.17 secs
# ---- Epoch 19/50
# (1) Training stage (lr = 0.000033) ...
# loss 0.17362, orien_loss 0.01988, oracc 0.99761, chx_loss 0.15245, chxlmicf1 0.54428, chxlmacf1 0.48370, chxlacc 0.73101, chxlrocauc 0.82422, ql_loss 0.07731, qlf1 0.36095, gloss 0.01614, gacc 0.99599, 92.75 secs
# (2) Validation stage ...
# oracc 0.99700, chxlmicf1 0.48403, chxlmacf1 0.44852, chxlacc 0.71791, chxlrocauc 0.76210, qlf1 0.33614, 4.27 secs
# ---- Epoch 20/50
# (1) Training stage (lr = 0.000033) ...
# loss 0.23588, orien_loss 0.00330, oracc 0.99791, chx_loss 0.15779, chxlmicf1 0.54235, chxlmacf1 0.48161, chxlacc 0.73011, chxlrocauc 0.82344, ql_loss 0.07742, qlf1 0.35862, gloss 0.01365, gacc 0.99548, 92.13 secs
# (2) Validation stage ...
# oracc 0.99850, chxlmicf1 0.48761, chxlmacf1 0.45084, chxlacc 0.71833, chxlrocauc 0.76389, qlf1 0.32881, 4.24 secs
# ---- Epoch 21/50
# (1) Training stage (lr = 0.000033) ...
# loss 0.16817, orien_loss 0.00601, oracc 0.99753, chx_loss 0.15183, chxlmicf1 0.54223, chxlmacf1 0.48248, chxlacc 0.72952, chxlrocauc 0.82229, ql_loss 0.07737, qlf1 0.35957, gloss 0.00857, gacc 0.99676, 90.53 secs
# (2) Validation stage ...
# oracc 0.99850, chxlmicf1 0.48540, chxlmacf1 0.44989, chxlacc 0.72238, chxlrocauc 0.76418, qlf1 0.32801, 4.20 secs
# Epoch    21: reducing learning rate of group 0 to 2.5355e-05.
# ---- Epoch 22/50
# (1) Training stage (lr = 0.000025) ...
# loss 0.25477, orien_loss 0.01152, oracc 0.99715, chx_loss 0.16393, chxlmicf1 0.54537, chxlmacf1 0.48572, chxlacc 0.73241, chxlrocauc 0.82457, ql_loss 0.07740, qlf1 0.36005, gloss 0.01084, gacc 0.99702, 92.58 secs
# (2) Validation stage ...
# oracc 0.99850, chxlmicf1 0.48795, chxlmacf1 0.44947, chxlacc 0.71961, chxlrocauc 0.76701, qlf1 0.32990, 4.05 secs
# ---- Epoch 23/50
# (1) Training stage (lr = 0.000025) ...
# loss 0.10264, orien_loss 0.00000, oracc 0.99761, chx_loss 0.04949, chxlmicf1 0.54256, chxlmacf1 0.48205, chxlacc 0.72985, chxlrocauc 0.82323, ql_loss 0.07707, qlf1 0.36235, gloss 0.00760, gacc 0.99731, 92.70 secs
# (2) Validation stage ...
# oracc 0.99550, chxlmicf1 0.49457, chxlmacf1 0.45196, chxlacc 0.71780, chxlrocauc 0.77317, qlf1 0.32793, 4.05 secs
# ---- Epoch 24/50
# (1) Training stage (lr = 0.000025) ...
# loss 0.22275, orien_loss 0.00054, oracc 0.99786, chx_loss 0.14315, chxlmicf1 0.54519, chxlmacf1 0.48398, chxlacc 0.73235, chxlrocauc 0.82439, ql_loss 0.07718, qlf1 0.36109, gloss 0.00824, gacc 0.99663, 91.63 secs
# (2) Validation stage ...
# oracc 0.99550, chxlmicf1 0.49057, chxlmacf1 0.44810, chxlacc 0.71812, chxlrocauc 0.77249, qlf1 0.32876, 4.26 secs
# ---- Epoch 25/50
# (1) Training stage (lr = 0.000025) ...
# loss 0.23705, orien_loss 0.00351, oracc 0.99832, chx_loss 0.15562, chxlmicf1 0.54533, chxlmacf1 0.48471, chxlacc 0.73200, chxlrocauc 0.82475, ql_loss 0.07715, qlf1 0.36332, gloss 0.00974, gacc 0.99731, 92.17 secs
# (2) Validation stage ...
# oracc 0.99550, chxlmicf1 0.49913, chxlmacf1 0.45508, chxlacc 0.72397, chxlrocauc 0.77504, qlf1 0.32920, 4.08 secs
# Epoch    25: reducing learning rate of group 0 to 1.9270e-05.
# ---- Epoch 26/50
# (1) Training stage (lr = 0.000019) ...
# loss 0.16144, orien_loss 0.00686, oracc 0.99791, chx_loss 0.15373, chxlmicf1 0.54618, chxlmacf1 0.48546, chxlacc 0.73200, chxlrocauc 0.82396, ql_loss 0.07741, qlf1 0.36107, gloss 0.00863, gacc 0.99723, 92.94 secs
# (2) Validation stage ...
# oracc 0.99700, chxlmicf1 0.49190, chxlmacf1 0.45028, chxlacc 0.71940, chxlrocauc 0.77094, qlf1 0.33019, 4.26 secs
# ---- Epoch 27/50
# (1) Training stage (lr = 0.000019) ...
# loss 0.23049, orien_loss 0.00041, oracc 0.99837, chx_loss 0.15061, chxlmicf1 0.54452, chxlmacf1 0.48305, chxlacc 0.73112, chxlrocauc 0.82438, ql_loss 0.07721, qlf1 0.36286, gloss 0.01177, gacc 0.99683, 92.36 secs
# (2) Validation stage ...
# oracc 0.99550, chxlmicf1 0.49421, chxlmacf1 0.45308, chxlacc 0.72089, chxlrocauc 0.77232, qlf1 0.32943, 4.18 secs
# ---- Epoch 28/50
# (1) Training stage (lr = 0.000019) ...
# loss 0.19751, orien_loss 0.04116, oracc 0.99795, chx_loss 0.14875, chxlmicf1 0.54552, chxlmacf1 0.48424, chxlacc 0.73187, chxlrocauc 0.82509, ql_loss 0.07743, qlf1 0.36250, gloss 0.01387, gacc 0.99656, 92.39 secs
# (2) Validation stage ...
# oracc 0.99700, chxlmicf1 0
secs
# (2) Validation stage ...
# oracc 0.99700, chxlmicf1 0.48986, chxlmacf1 0.45121, chxlacc 0.72152, chxlrocauc 0.76623, qlf1 0.33226, 4.24 secs
# ---- Epoch 43/50
# (1) Training stage (lr = 0.000011) ...
# loss 0.23053, orien_loss 0.00048, oracc 0.99770, chx_loss 0.15214, chxlmicf1 0.54811, chxlmacf1 0.48704, chxlacc 0.73426, chxlrocauc 0.82731, ql_loss 0.07679, qlf1 0.36520, gloss 0.00655, gacc 0.99760, 93.10 secs
# (2) Validation stage ...
# oracc 0.99850, chxlmicf1 0.49667, chxlmacf1 0.45547, chxlacc 0.72642, chxlrocauc 0.77487, qlf1 0.33334, 4.25 secs
# ---- Epoch 44/50
# (1) Training stage (lr = 0.000011) ...
# loss 0.15652, orien_loss 0.00871, oracc 0.99799, chx_loss 0.14464, chxlmicf1 0.54921, chxlmacf1 0.48870, chxlacc 0.73357, chxlrocauc 0.82688, ql_loss 0.07702, qlf1 0.36602, gloss 0.00908, gacc 0.99752, 92.32 secs
# (2) Validation stage ...
# oracc 0.99700, chxlmicf1 0.49010, chxlmacf1 0.44933, chxlacc 0.72025, chxlrocauc 0.77042, qlf1 0.33463, 4.22 secs
# ---- Epoch 45/50
# (1) Training stage (lr = 0.000011) ...
# loss 0.21426, orien_loss 0.00012, oracc 0.99820, chx_loss 0.14026, chxlmicf1 0.54463, chxlmacf1 0.48402, chxlacc 0.73138, chxlrocauc 0.82456, ql_loss 0.07735, qlf1 0.36350, gloss 0.00727, gacc 0.99750, 91.77 secs
# (2) Validation stage ...
# oracc 0.99550, chxlmicf1 0.49093, chxlmacf1 0.45294, chxlacc 0.72227, chxlrocauc 0.76737, qlf1 0.33280, 4.12 secs
# ---- Epoch 46/50
# (1) Training stage (lr = 0.000011) ...
# loss 0.09210, orien_loss 0.00034, oracc 0.99832, chx_loss 0.03897, chxlmicf1 0.54624, chxlmacf1 0.48500, chxlacc 0.73443, chxlrocauc 0.82778, ql_loss 0.07645, qlf1 0.36489, gloss 0.00807, gacc 0.99731, 92.64 secs
# (2) Validation stage ...
# oracc 0.99850, chxlmicf1 0.50009, chxlmacf1 0.45778, chxlacc 0.71971, chxlrocauc 0.77811, qlf1 0.32823, 4.15 secs
# ---- Epoch 47/50
# (1) Training stage (lr = 0.000011) ...
# loss 0.24456, orien_loss 0.00269, oracc 0.99824, chx_loss 0.16038, chxlmicf1 0.54829, chxlmacf1 0.48773, chxlacc 0.73334, chxlrocauc 0.82695, ql_loss 0.07711, qlf1 0.36448, gloss 0.00718, gacc 0.99798, 93.23 secs
# (2) Validation stage ...
# oracc 0.99550, chxlmicf1 0.49847, chxlmacf1 0.45689, chxlacc 0.72067, chxlrocauc 0.77233, qlf1 0.32874, 4.02 secs
# Epoch    47: reducing learning rate of group 0 to 8.4591e-06.
# ---- Epoch 48/50
# (1) Training stage (lr = 0.000008) ...
# loss 0.22224, orien_loss 0.00058, oracc 0.99845, chx_loss 0.14223, chxlmicf1 0.54750, chxlmacf1 0.48523, chxlacc 0.73301, chxlrocauc 0.82581, ql_loss 0.07692, qlf1 0.36404, gloss 0.01125, gacc 0.99779, 91.30 secs
# (2) Validation stage ...
# oracc 0.99700, chxlmicf1 0.49990, chxlmacf1 0.45681, chxlacc 0.72482, chxlrocauc 0.77359, qlf1 0.32755, 4.09 secs
# ---- Epoch 49/50
# (1) Training stage (lr = 0.000008) ...
# loss 0.14159, orien_loss 0.00359, oracc 0.99832, chx_loss 0.13742, chxlmicf1 0.54734, chxlmacf1 0.48580, chxlacc 0.73292, chxlrocauc 0.82695, ql_loss 0.07688, qlf1 0.36312, gloss 0.01092, gacc 0.99733, 91.73 secs
# (2) Validation stage ...
# oracc 0.99550, chxlmicf1 0.49866, chxlmacf1 0.45546, chxlacc 0.72174, chxlrocauc 0.77541, qlf1 0.32732, 4.31 secs
# ---- Epoch 50/50
# (1) Training stage (lr = 0.000008) ...
# loss 0.22443, orien_loss 0.00155, oracc 0.99786, chx_loss 0.14147, chxlmicf1 0.54848, chxlmacf1 0.48890, chxlacc 0.73464, chxlrocauc 0.82699, ql_loss 0.07661, qlf1 0.36587, gloss 0.01025, gacc 0.99750, 93.42 secs
# (2) Validation stage ...
# oracc 0.99700, chxlmicf1 0.50058, chxlmacf1 0.45800, chxlacc 0.72600, chxlrocauc 0.77490, qlf1 0.33312, 4.22 secs

# %% [markdown]
# ### Training-Validation plots

# %%
from medvqa.evaluation.plots import plot_train_val_curves
from medvqa.utils.constants import MetricNames

# %%
plot_train_val_curves('/home/pamessina/medvqa-workspace/models/visual_module/20220614_103906_mimiccxr+iuxray+chexpert_densenet121_model-args=(densenet-121,1024,pretrained)_cnn-pretr=0_dataset_weights=1.0,0.08,0.8_img-aug=random-spatial_tags=0_orien=1_chx=1_ql=1_use_amp/metrics_logs.csv',
                 [MetricNames.CHXLABELMACROAVGF1, MetricNames.CHXLABELMICROAVGF1,
                  MetricNames.CHXLABEL_ROCAUC, MetricNames.QLABELSF1, MetricNames.ORIENACC],
                 ['Chexpert-F1 (Macro Avg)', 'Chexpert-F1 (Micro Avg)', 'Chexpert ROC-AUC', 'Question Labels F1',
                  'Orientation Accuracy'],
                 single_plot_figsize=(8,6))

# %% [markdown]
# # Test Set Evaluation

# %%
# !python ../eval_visual_module.py \
        --checkpoint-folder "models/visual_module/20220614_103906_mimiccxr+iuxray+chexpert_densenet121_model-args=(densenet-121,1024,pretrained)_cnn-pretr=0_dataset_weights=1.0,0.08,0.8_img-aug=random-spatial_tags=0_orien=1_chx=1_ql=1_use_amp" \
        --mimiccxr-preprocessed-test-data-filename "mimiccxr_preprocessed_test_data__(dataset=qa_adapted_reports__20220416_083114.json;tokenizer=5251,42509,2730556597987494786).pkl" \
        --batch-size 160
# Out:
# script's arguments:
#    checkpoint_folder: models/visual_module/20220614_103906_mimiccxr+iuxray+chexpert_densenet121_model-args=(densenet-121,1024,pretrained)_cnn-pretr=0_dataset_weights=1.0,0.08,0.8_img-aug=random-spatial_tags=0_orien=1_chx=1_ql=1_use_amp
#    mimiccxr_preprocessed_test_data_filename: mimiccxr_preprocessed_test_data__(dataset=qa_adapted_reports__20220416_083114.json;tokenizer=5251,42509,2730556597987494786).pkl
#    batch_size: 160
#    device: GPU
#    num_workers: 0
#    eval_iuxray: True
#    eval_mimiccxr: True
#    use_amp: False
# ----- Evaluating model ------
# metadata loaded from /home/pamessina/medvqa-workspace/models/visual_module/20220614_103906_mimiccxr+iuxray+chexpert_densenet121_model-args=(densenet-121,1024,pretrained)_cnn-pretr=0_dataset_weights=1.0,0.08,0.8_img-aug=random-spatial_tags=0_orien=1_chx=1_ql=1_use_amp/metadata.json
# 1) device = cuda
# 2) Creating instance of DensenetVisualModule model ...
# DenseNet121's pretrained weights loaded from ImageNet
# 3) Creating evaluator engine ...
# 4) Defining image transform ...
# Returning default transform
# 5) Creating MIMIC-CXR visual module evaluator ...
# Loading data from path /home/pamessina/medvqa-workspace/cache/mimiccxr/mimiccxr_preprocessed_test_data__(dataset=qa_adapted_reports__20220416_083114.json;tokenizer=5251,42509,2730556597987494786).pkl ...
# 	Done!
# batch_size = 160
# generating test dataset ...
# generating test dataloader ...
# 6) Creating IU X-Ray visual module trainer ...
# Loading data from path /home/pamessina/medvqa-workspace/cache/iuxray/iuxray_preprocessed_train_data__(hash=247,1338506350569278595).pkl ...
# 	Done!
# batch_size = 160
# len(self.val_indices) = 152
# generating training and validation dataloaders ...
# num_workers = 0
# 7) Attaching metrics, timer and events to engines ...
# checkpoint_names = ['checkpoint_50_oracc+chxlmicf1+chxlmacf1+chxlrocauc+qlf1+gacc=0.6890.pt']
# 8) Loading model from checkpoint ...
# checkpoint_path =  /home/pamessina/medvqa-workspace/models/visual_module/20220614_103906_mimiccxr+iuxray+chexpert_densenet121_model-args=(densenet-121,1024,pretrained)_cnn-pretr=0_dataset_weights=1.0,0.08,0.8_img-aug=random-spatial_tags=0_orien=1_chx=1_ql=1_use_amp/checkpoint_50_oracc+chxlmicf1+chxlmacf1+chxlrocauc+qlf1+gacc=0.6890.pt
# Loading model and epoch only
# Checkpoint successfully loaded!
#
# ========================
# 9) Running evaluator engine on IU X-Ray validation split ...
# len(dataset) = 152
# len(dataloader) = 1
# ---- Epoch 51/51
# Evaluating model ...
# oracc 0.99342, chxlmacf1 0.31410, chxlmicf1 0.33291, chxlacc 0.75517, chxlrocaucmic 0.67100, chxlrocaucmac 0.68644, qlmacf1 0.14217, qlmicf1 0.31752, 1.09 secs
# Metrics successfully saved to /home/pamessina/medvqa-workspace/results/visual_module/20220614_103906_mimiccxr+iuxray+chexpert_densenet121_model-args=(densenet-121,1024,pretrained)_cnn-pretr=0_dataset_weights=1.0,0.08,0.8_img-aug=random-spatial_tags=0_orien=1_chx=1_ql=1_use_amp/iuxray_metrics.pkl
#
# ========================
# 10) Running evaluator engine on MIMIC-CXR test split ...
# len(dataset) = 3125
# len(dataloader) = 20
# ---- Epoch 51/51
# Evaluating model ...
# oracc 0.99701, chxlmacf1 0.45525, chxlmicf1 0.55232, chxlacc 0.70283, chxlrocaucmic 0.80046, chxlrocaucmac 0.74567, qlmacf1 0.18978, qlmicf1 0.32511, 9.31 secs
# Metrics successfully saved to /home/pamessina/medvqa-workspace/results/visual_module/20220614_103906_mimiccxr+iuxray+chexpert_densenet121_model-args=(densenet-121,1024,pretrained)_cnn-pretr=0_dataset_weights=1.0,0.08,0.8_img-aug=random-spatial_tags=0_orien=1_chx=1_ql=1_use_amp/mimiccxr_metrics.pkl
